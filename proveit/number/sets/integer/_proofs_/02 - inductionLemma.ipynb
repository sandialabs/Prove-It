# %%
from proveit.number.sets.integer._axioms_ import naturalsDef
from proveit.number.sets.integer._theorems_ import inductionLemma
from proveit.logic import InSet
from proveit.common import n
from proveit.number import Naturals

# %%
inductionLemma.beginProof(['proveit.logic'])
# Out:
# Beginning proof of
# forall_{n in Naturals} [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))]

# %%
naturalsDef
# Out:
# |= forall_{n} ((n in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))])

# %%
nInNats = InSet(n, Naturals)
nInNats
# Out:
# n in Naturals

# %%
lemmaInstance = naturalsDef.specialize().deriveRightViaEquivalence([nInNats])
lemmaInstance
# Out:
# {n in Naturals} |= forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))

# %%
lemmaInstance.generalize(n, domain=Naturals).qed()
# Out:
# proveit.number.sets.integer.inductionLemma has a proof
# <proveit._core_.proof.Generalization instance at 0x0000000005CB3DC8>

# %%
inductionLemma.printRequirements()
# Out:
# proveit.number.sets.integer.naturalsDef
#
# Unproven theorems:
# proveit.logic.equality.substitute
