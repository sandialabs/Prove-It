# %%
from proveit.number.sets.integer._axioms_ import naturalsDef
from proveit.number.sets.integer._theorems_ import zeroInNats
from proveit.common import n, S
from proveit.number import Naturals
from proveit.number.common import zero

# %%
zeroInNats.beginProof(['proveit.logic'])
# Out:
# Beginning proof of
# 0 in Naturals

# %%
naturalsDef
# Out:
# |= forall_{n} ((n in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))])

# %%
zeroInNatsDef = naturalsDef.specialize({n:zero})
zeroInNatsDef
# Out:
# |= (0 in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (0 in S))]

# %%
zeroInS_hypothesis = zeroInNatsDef.rhs.instanceExpr.hypothesis
zeroInS_hypothesis
# Out:
# (0 in S) and [forall_{x in S} ((x + 1) in S)]

# %%
zeroInS = zeroInS_hypothesis.deriveLeft([zeroInS_hypothesis])
zeroInS
# Out:
# {(0 in S) and [forall_{x in S} ((x + 1) in S)]} |= 0 in S

# %%
zeroInNatsDef_rhs = zeroInS.asImplication(zeroInS_hypothesis).generalize(S)
zeroInNatsDef_rhs
# Out:
# |= forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (0 in S))

# %%
zeroInNatsDef.deriveLeftViaEquivalence().qed()
# Out:
# proveit.number.sets.integer.zeroInNats has a proof
# <proveit._core_.proof.Specialization instance at 0x0000000005DBDC88>

# %%
zeroInNats.printRequirements()
# Out:
# proveit.logic.equality.equalsSymmetry
# proveit.number.sets.integer.naturalsDef
#
# Unproven theorems:
# proveit.logic.boolean.conjunction.andImpliesLeft
# proveit.logic.equality.substitute
