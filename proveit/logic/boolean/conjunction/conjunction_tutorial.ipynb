# %%
from proveit.logic import And, Or, TRUE, FALSE

# %%
And(TRUE, TRUE).evaluate().proof()
# Out:
# <proveit._core_.proof.Axiom instance at 0x0000000003FD95C8>

# %%
And(TRUE, TRUE, TRUE).evaluate().proof()
# Out:
# <proveit._core_.proof.Specialization instance at 0x00000000042D1888>

# %%
And(TRUE, Or(TRUE, FALSE)).evaluate().proof()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-3-9f81a5c9b62e> in <module>()
# ----> 1 And(TRUE, Or(TRUE, FALSE)).evaluate().proof()
#
# C:\users\wwitzel\proveit\proveit\_generic_\evaluatable.pyc in evaluate(self)
#      26             if not isIrreducibleValue(operand):
#      27                 # the operand is not an irreducible value so it must be evaluated
# ---> 28                 operandEval = operand.evaluate()
#      29                 if not isIrreducibleValue(operandEval.rhs):
#      30                     raise EvaluationError('Evaluations expected to be irreducible values')
#
# C:\users\wwitzel\proveit\proveit\_generic_\evaluatable.pyc in evaluate(self)
#      17         from proveit.lambda_map import globalRepl
#      18         from proveit.logic import Equals
# ---> 19         self.importBaseEvaluations()
#      20         # See if the Evaluatable already has a proven evaluation
#      21         if self in Evaluatable.evaluations:
#
# C:\users\wwitzel\proveit\proveit\_generic_\evaluatable.pyc in importBaseEvaluations(self)
#      41         This is specific to each kind of Evaluatable and must be overridden.
#      42         '''
# ---> 43         raise NotImplementedError('_baseEvaluate must be implemented to evaluate the Evaluatable when all operands are irreducible values')
#      44
#      45
#
# NotImplementedError: _baseEvaluate must be implemented to evaluate the Evaluatable when all operands are irreducible values

# %%
And(TRUE, Or(TRUE, FALSE), FALSE).evaluate().proof()
# Out:
# ---------------------------------------------------------------------------
# RelabelingFailure                         Traceback (most recent call last)
# <ipython-input-4-25b78d87f274> in <module>()
# ----> 1 And(TRUE, Or(TRUE, FALSE), FALSE).evaluate().proof()
#
# C:\users\wwitzel\proveit\proveit\_generic_\evaluatable.pyc in evaluate(self)
#      32             if not isIrreducibleValue(operand.isIrreducibleValue()):
#      33                 raise EvaluationError('All operands should not be irreducible values')
# ---> 34         return Equals(self, expr._baseEvaluate().rhs).prove()
#      35
#      36     def _baseEvaluate(self):
#
# C:\users\wwitzel\proveit\proveit\logic\boolean\conjunction\and_op.pyc in _baseEvaluate(self)
#      58         if len(self.operands) >= 3:
#      59             # A and B and ..C.. = A and (B and ..C..)
# ---> 60             compositionEquiv = andComposition.specialize({A:self.operands[0], B:self.operands[1], C:self.operands[2:]})
#      61             decomposedEval = compositionEquiv.rhs.evaluate()
#      62             return compositionEquiv.applyTransitivity(decomposedEval)
#
# C:\users\wwitzel\proveit\proveit\_core_\known_truth.pyc in call_method_with_known_truth_assumptions(*args, **kwargs)
#     193                     assumptions = tuple(assumptions) + self.assumptions
#     194                     kwargs['assumptions'] = defaults.checkedAssumptions(assumptions)
# --> 195                 return attr.__call__(*args, **kwargs)
#     196             return call_method_with_known_truth_assumptions
#     197
#
# C:\users\wwitzel\proveit\proveit\logic\boolean\quantification\universal\forall.pyc in specialize(self, subMap, assumptions, conditionAsHypothesis)
#      68         for var in iVarSet:
#      69             if var not in subVars: subMap[var] = var
# ---> 70         specialized = Specialization(self, subMap, relabelMap, assumptions).provenTruth
#      71         if conditionAsHypothesis and self.hasCondition():
#      72             return specialized.asImplication(self.conditions[0])
#
# C:\users\wwitzel\proveit\proveit\_core_\proof.pyc in __init__(self, generalExpr, subMap, relabelMap, assumptions)
#     212             raise Failure('Unproven general expression: ' + str(generalExpr) + ' assuming {' + ', '.join(str(assumption) for assumption in assumptions) + '}')
#     213         # perform the appropriate substitution/relabeling
# --> 214         specializedExpr, subbedConditions, subMap, relabelMap = Specialization._specialized_expr(generalExpr, assumptions, subMap, relabelMap)
#     215         # obtain the KnownTruths for the substituted conditions
#     216         conditionTruths = []
#
# C:\users\wwitzel\proveit\proveit\_core_\proof.pyc in _specialized_expr(generalExpr, assumptions, subMap, relabelMap)
#     275             if isinstance(key, Variable):
#     276                 if not isinstance(sub, Variable):
# --> 277                     raise RelabelingFailure('May only relabel a Variable to a Variable.')
#     278                 relabelVar = key
#     279             elif isBundledVar(key):
#
# RelabelingFailure: May only relabel a Variable to a Variable.

# %%
And(TRUE, Or(TRUE, FALSE), FALSE).evaluate()
# Out:
# ---------------------------------------------------------------------------
# RelabelingFailure                         Traceback (most recent call last)
# <ipython-input-8-23de5a76ff04> in <module>()
# ----> 1 And(TRUE, Or(TRUE, FALSE), FALSE).evaluate()
#
# C:\users\wwitzel\proveit\proveit\_generic_\evaluatable.pyc in evaluate(self)
#      32             if not isIrreducibleValue(operand.isIrreducibleValue()):
#      33                 raise EvaluationError('All operands should not be irreducible values')
# ---> 34         return Equals(self, expr._baseEvaluate().rhs).prove()
#      35
#      36     def _baseEvaluate(self):
#
# C:\users\wwitzel\proveit\proveit\logic\boolean\conjunction\and_op.pyc in _baseEvaluate(self)
#      58         if len(self.operands) >= 3:
#      59             # A and B and ..C.. = A and (B and ..C..)
# ---> 60             compositionEquiv = andComposition.specialize({A:self.operands[0], B:self.operands[1], C:self.operands[2:]})
#      61             decomposedEval = compositionEquiv.rhs.evaluate()
#      62             return compositionEquiv.applyTransitivity(decomposedEval)
#
# C:\users\wwitzel\proveit\proveit\_core_\known_truth.pyc in call_method_with_known_truth_assumptions(*args, **kwargs)
#     193                     assumptions = tuple(assumptions) + self.assumptions
#     194                     kwargs['assumptions'] = defaults.checkedAssumptions(assumptions)
# --> 195                 return attr.__call__(*args, **kwargs)
#     196             return call_method_with_known_truth_assumptions
#     197
#
# C:\users\wwitzel\proveit\proveit\logic\boolean\quantification\universal\forall.pyc in specialize(self, subMap, assumptions, conditionAsHypothesis)
#      68         for var in iVarSet:
#      69             if var not in subVars: subMap[var] = var
# ---> 70         specialized = Specialization(self, subMap, relabelMap, assumptions).provenTruth
#      71         if conditionAsHypothesis and self.hasCondition():
#      72             return specialized.asImplication(self.conditions[0])
#
# C:\users\wwitzel\proveit\proveit\_core_\proof.pyc in __init__(self, generalExpr, subMap, relabelMap, assumptions)
#     212             raise Failure('Unproven general expression: ' + str(generalExpr) + ' assuming {' + ', '.join(str(assumption) for assumption in assumptions) + '}')
#     213         # perform the appropriate substitution/relabeling
# --> 214         specializedExpr, subbedConditions, subMap, relabelMap = Specialization._specialized_expr(generalExpr, assumptions, subMap, relabelMap)
#     215         # obtain the KnownTruths for the substituted conditions
#     216         conditionTruths = []
#
# C:\users\wwitzel\proveit\proveit\_core_\proof.pyc in _specialized_expr(generalExpr, assumptions, subMap, relabelMap)
#     275             if isinstance(key, Variable):
#     276                 if not isinstance(sub, Variable):
# --> 277                     raise RelabelingFailure('May only relabel a Variable to a Variable.')
#     278                 relabelVar = key
#     279             elif isBundledVar(key):
#
# RelabelingFailure: May only relabel a Variable to a Variable.
