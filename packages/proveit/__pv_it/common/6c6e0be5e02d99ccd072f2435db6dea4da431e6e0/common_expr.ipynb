# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#fxy">fxy</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit import fxy

# %%
# check that the built expression is the same as the stored expression
assert fxy == stored_expr
assert fxy._style_id == stored_expr._style_id
print("Passed sanity check: fxy matches stored_expr")
# Out:
# Passed sanity check: fxy matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fxy.latex())
# Out:
# f(x, y)

# %%
# display the expression information
fxy.expr_info()
# Out:
# 0. f(x, y)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. f
#    core type: Variable
#    sub-expressions:
# 2. (x, y)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x
#    core type: Variable
#    sub-expressions:
# 4. y
#    core type: Variable
#    sub-expressions:
