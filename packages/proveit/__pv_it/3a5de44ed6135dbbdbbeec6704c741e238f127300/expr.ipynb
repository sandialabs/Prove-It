# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#d">d</a> of type <a class="ProveItLink" href="../../../../doc/html/api/proveit.Variable.html">Variable</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit</a>

# %%
# import the special expression
from proveit._common_ import d

# %%
# check that the built expression is the same as the stored expression
# %check_expr d
# Out:
# Passed sanity check: built 'd' is the same as the stored Expression.

# %%
# display the expression information
d.exprInfo()
# Out:
# 0. d
#    core type: Variable
#    sub-expressions:
