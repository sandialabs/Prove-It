# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#prob_of_all_def">prob_of_all_def</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.statistics import prob_of_all_def

# %%
# check that the built expression is the same as the stored expression
assert prob_of_all_def.expr == stored_expr
assert prob_of_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: prob_of_all_def matches stored_expr")
# Out:
# Passed sanity check: prob_of_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}}~\left[\forall_{X}~\left[\forall_{f \in \left[X \rightarrow \Omega\right]}~\left[\forall_{Q}~\left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \textrm{Pr}\left(\left\{f\left(x\right)~|~Q\left(x\right)\right\}_{x \in X}\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{Omega in_c SampleSpaces} [forall_{X} [forall_{f in [X -> Omega]} [forall_{Q} ([Prob_{x in X | Q(x)} f(x)] =  \\ Pr({f(x) s.t. Q(x)}_{x in X}))]]]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. (Omega -> {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q} ([Prob_{x in X | Q(x)} f(x)] =  \\ Pr({f(x) s.t. Q(x)}_{x in X}))]] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. Omega -> {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q} ([Prob_{x in X | Q(x)} f(x)] =  \\ Pr({f(x) s.t. Q(x)}_{x in X}))]] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 31
#    body: 4
# 3. (Omega)
#    core type: ExprTuple
#    sub-expressions: 31
# 4. {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q} ([Prob_{x in X | Q(x)} f(x)] =  \\ Pr({f(x) s.t. Q(x)}_{x in X}))]] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
