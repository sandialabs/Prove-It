# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Omega, Q, Qx, R, Rx, X, f, fx, x
from proveit.logic import Forall, Functions, Implies
from proveit.numbers import LessEq
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Rx, domain = X, condition = Qx), LessEq(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Rx)).with_wrapping_at(2)).with_wrapping_at(2)), domain = Functions(X, Omega)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{f \in \left[X \rightarrow \Omega\right]}~\\
# \left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X~|~Q\left(x\right)}~R\left(x\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] \leq  \\ \left[\textrm{Prob}_{x \in X~|~R\left(x\right)}~f\left(x\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. (f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#    core type: Lambda
#    parameter: 39
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 39
# 4. {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#    core type: Operation
#    operator: 20
#    operand: 9
# 6. f in [X -> Omega]
#    core type: Operation
#    operator: 46
#    operands: 8
# 7. ((Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (f, [X -> Omega])
#    core type: ExprTuple
#    sub-expressions: 39, 10
# 9. (Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. [X -> Omega]
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 45, 48
# 12. [forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. Functions
#     core type: Literal
#     sub-expressions:
# 14. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 50, 17
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (forall_{x in X | Q(x)} R(x), [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Omega
#     core type: Variable
#     sub-expressions:
# 18. forall_{x in X | Q(x)} R(x)
#     core type: Operation
#     operator: 20
#     operand: 24
# 19. [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. (x -> {R(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. <=
#     core type: Literal
#     sub-expressions:
# 23. (Prob_{x in X | Q(x)} f(x), Prob_{x in X | R(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. x -> {R(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 51
#     body: 27
# 25. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 29
#     operand: 31
# 26. Prob_{x in X | R(x)} f(x)
#     core type: Operation
#     operator: 29
#     operand: 32
# 27. {R(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 44
#     condition: 35
# 28. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. Prob
#     core type: Literal
#     sub-expressions:
# 30. (x -> {f(x) if x in X ,  R(x).)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 51
#     body: 33
# 32. x -> {f(x) if x in X ,  R(x).
#     core type: Lambda
#     parameter: 51
#     body: 34
# 33. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 36
#     condition: 35
# 34. {f(x) if x in X ,  R(x).
#     core type: Conditional
#     value: 36
#     condition: 37
# 35. (x in X) and Q(x)
#     core type: Operation
#     operator: 40
#     operands: 38
# 36. f(x)
#     core type: Operation
#     operator: 39
#     operand: 51
# 37. (x in X) and R(x)
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 43, 42
# 39. f
#     core type: Variable
#     sub-expressions:
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. (x in X, R(x))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. Q(x)
#     core type: Operation
#     operator: 45
#     operand: 51
# 43. x in X
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. R(x)
#     core type: Operation
#     operator: 48
#     operand: 51
# 45. Q
#     core type: Variable
#     sub-expressions:
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x, X)
#     core type: ExprTuple
#     sub-expressions: 51, 50
# 48. R
#     core type: Variable
#     sub-expressions:
# 49. (x)
#     core type: ExprTuple
#     sub-expressions: 51
# 50. X
#     core type: Variable
#     sub-expressions:
# 51. x
#     core type: Variable
#     sub-expressions:
