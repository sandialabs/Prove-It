# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Omega, Q, Qx, R, Rx, X, f, fx, x
from proveit.logic import Forall, Functions, Implies, InClass
from proveit.numbers import LessEq
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Rx, domain = X, condition = Qx), LessEq(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Rx)).with_wrapping_at(2)).with_wrapping_at(2)), domain = Functions(X, Omega)).with_wrapping()), InClass(Omega, SampleSpaces))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{X}~\left[\begin{array}{l}\forall_{f \in \left[X \rightarrow \Omega\right]}~\\
# \left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X~|~Q\left(x\right)}~R\left(x\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] \leq  \\ \left[\textrm{Prob}_{x \in X~|~R\left(x\right)}~f\left(x\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right] \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]]
#    core type: Operation
#    operator: 29
#    operand: 6
# 2. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (X -> [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]])
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 26, 7
# 6. X -> [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]]
#    core type: Lambda
#    parameter: 59
#    body: 9
# 7. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 8. (X)
#    core type: ExprTuple
#    sub-expressions: 59
# 9. forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]
#    core type: Operation
#    operator: 29
#    operand: 11
# 10. (f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#     core type: Lambda
#     parameter: 48
#     body: 13
# 12. (f)
#     core type: ExprTuple
#     sub-expressions: 48
# 13. {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#     core type: Operation
#     operator: 29
#     operand: 18
# 15. f in [X -> Omega]
#     core type: Operation
#     operator: 55
#     operands: 17
# 16. ((Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])))
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (f, [X -> Omega])
#     core type: ExprTuple
#     sub-expressions: 48, 19
# 18. (Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#     core type: Lambda
#     parameters: 20\n    body: 21
# 19. [X -> Omega]
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 21. [forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Functions
#     core type: Literal
#     sub-expressions:
# 23. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 59, 26
# 24. =>
#     core type: Literal
#     sub-expressions:
# 25. (forall_{x in X | Q(x)} R(x), [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. Omega
#     core type: Variable
#     sub-expressions:
# 27. forall_{x in X | Q(x)} R(x)
#     core type: Operation
#     operator: 29
#     operand: 33
# 28. [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. (x -> {R(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. <=
#     core type: Literal
#     sub-expressions:
# 32. (Prob_{x in X | Q(x)} f(x), Prob_{x in X | R(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. x -> {R(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 60
#     body: 36
# 34. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 38
#     operand: 40
# 35. Prob_{x in X | R(x)} f(x)
#     core type: Operation
#     operator: 38
#     operand: 41
# 36. {R(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 53
#     condition: 44
# 37. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. Prob
#     core type: Literal
#     sub-expressions:
# 39. (x -> {f(x) if x in X ,  R(x).)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 60
#     body: 42
# 41. x -> {f(x) if x in X ,  R(x).
#     core type: Lambda
#     parameter: 60
#     body: 43
# 42. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 45
#     condition: 44
# 43. {f(x) if x in X ,  R(x).
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. (x in X) and Q(x)
#     core type: Operation
#     operator: 49
#     operands: 47
# 45. f(x)
#     core type: Operation
#     operator: 48
#     operand: 60
# 46. (x in X) and R(x)
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. and
#     core type: Literal
#     sub-expressions:
# 50. (x in X, R(x))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 51. Q(x)
#     core type: Operation
#     operator: 54
#     operand: 60
# 52. x in X
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. R(x)
#     core type: Operation
#     operator: 57
#     operand: 60
# 54. Q
#     core type: Variable
#     sub-expressions:
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (x, X)
#     core type: ExprTuple
#     sub-expressions: 60, 59
# 57. R
#     core type: Variable
#     sub-expressions:
# 58. (x)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. X
#     core type: Variable
#     sub-expressions:
# 60. x
#     core type: Variable
#     sub-expressions:
