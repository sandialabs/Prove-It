# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Q, Qx, R, Rx, Ry, X, fx, fy, x, y
from proveit.logic import Equals, Forall, Implies, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda([Q, R], Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(Q, R\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (Q, R)
#    core type: ExprTuple
#    sub-expressions: 41, 54
# 3. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{x in X} (Q(x) = [not](R(x)))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (x -> {Q(x) = [not](R(x)) if x in X.)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. x -> {Q(x) = [not](R(x)) if x in X.
#     core type: Lambda
#     parameter: 44
#     body: 14
# 12. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 34
#     operand: 19
# 13. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 18
#     condition: 37
# 15. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 44
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 25
#     operand: 30
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 38, 27
# 24. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 30
# 27. [not](R(x))
#     core type: Operation
#     operator: 31
#     operand: 36
# 28. f(x)
#     core type: Operation
#     operator: 47
#     operand: 44
# 29. (x in X) and Q(x)
#     core type: Operation
#     operator: 48
#     operands: 33
# 30. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 34
#     operand: 39
# 31. not
#     core type: Literal
#     sub-expressions:
# 32. (R(x))
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. Prob
#     core type: Literal
#     sub-expressions:
# 35. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. R(x)
#     core type: Operation
#     operator: 54
#     operand: 44
# 37. x in X
#     core type: Operation
#     operator: 52
#     operands: 40
# 38. Q(x)
#     core type: Operation
#     operator: 41
#     operand: 44
# 39. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 57
#     body: 43
# 40. (x, X)
#     core type: ExprTuple
#     sub-expressions: 44, 56
# 41. Q
#     core type: Variable
#     sub-expressions:
# 42. (x)
#     core type: ExprTuple
#     sub-expressions: 44
# 43. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. x
#     core type: Variable
#     sub-expressions:
# 45. f(y)
#     core type: Operation
#     operator: 47
#     operand: 57
# 46. (y in X) and R(y)
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. f
#     core type: Variable
#     sub-expressions:
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. y in X
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. R(y)
#     core type: Operation
#     operator: 54
#     operand: 57
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (y, X)
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 54. R
#     core type: Variable
#     sub-expressions:
# 55. (y)
#     core type: ExprTuple
#     sub-expressions: 57
# 56. X
#     core type: Variable
#     sub-expressions:
# 57. y
#     core type: Variable
#     sub-expressions:
