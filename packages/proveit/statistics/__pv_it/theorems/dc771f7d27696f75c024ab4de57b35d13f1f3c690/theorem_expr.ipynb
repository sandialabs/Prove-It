# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#prob_of_disjoint_events_is_prob_sum">prob_of_disjoint_events_is_prob_sum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.statistics import prob_of_disjoint_events_is_prob_sum

# %%
# check that the built expression is the same as the stored expression
assert prob_of_disjoint_events_is_prob_sum.expr == stored_expr
assert prob_of_disjoint_events_is_prob_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: prob_of_disjoint_events_is_prob_sum matches stored_expr")
# Out:
# Passed sanity check: prob_of_disjoint_events_is_prob_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}}~\left[\begin{array}{l}\forall_{A, B, C, X, Q~|~C \subseteq X, C = \left(A \cup B\right), \textrm{disjoint}\left(A, B\right)}~\\
# \left[\forall_{f \in \left[X \xrightarrow[]{\text{1-to-1}} \Omega\right]}~\left(\left[\textrm{Prob}_{x \in C~|~Q\left(x\right)}~f\left(x\right)\right] = \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] + \left[\textrm{Prob}_{x \in B~|~Q\left(x\right)}~f\left(x\right)\right]\right)\right)\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{Omega in_c SampleSpaces} [forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))]]
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. (Omega -> {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. Omega -> {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 49
#    body: 4
# 3. (Omega)
#    core type: ExprTuple
#    sub-expressions: 49
# 4. {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))]
#    core type: Operation
#    operator: 16
#    operand: 10
# 6. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 49, 11
# 10. (A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. SampleSpaces
#     core type: Literal
#     sub-expressions:
# 12. (A, B, C, X, Q)
#     core type: ExprTuple
#     sub-expressions: 78, 79, 69, 48, 76
# 13. {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. (C subset_eq X) and (C = (A union B)) and disjoint(A, B)
#     core type: Operation
#     operator: 67
#     operands: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (C subset_eq X, C = (A union B), disjoint(A, B))
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 19. f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Lambda
#     parameter: 66
#     body: 24
# 20. C subset_eq X
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. C = (A union B)
#     core type: Operation
#     operator: 32
#     operands: 27
# 22. disjoint(A, B)
#     core type: Operation
#     operator: 28
#     operands: 36
# 23. (f)
#     core type: ExprTuple
#     sub-expressions: 66
# 24. {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. subset_eq
#     core type: Literal
#     sub-expressions:
# 26. (C, X)
#     core type: ExprTuple
#     sub-expressions: 69, 48
# 27. (C, A union B)
#     core type: ExprTuple
#     sub-expressions: 69, 31
# 28. disjoint
#     core type: Literal
#     sub-expressions:
# 29. [Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. f in Injections(X, Omega)
#     core type: Operation
#     operator: 74
#     operands: 34
# 31. A union B
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (Prob_{x in C | Q(x)} f(x), [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. (f, Injections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 66, 39
# 35. union
#     core type: Literal
#     sub-expressions:
# 36. (A, B)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 37. Prob_{x in C | Q(x)} f(x)
#     core type: Operation
#     operator: 52
#     operand: 45
# 38. [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. Injections(X, Omega)
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (x -> {f(x) if x in C ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 45
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (Prob_{x in A | Q(x)} f(x), Prob_{x in B | Q(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. Injections
#     core type: Literal
#     sub-expressions:
# 44. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. x -> {f(x) if x in C ,  Q(x).
#     core type: Lambda
#     parameter: 80
#     body: 50
# 46. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 52
#     operand: 55
# 47. Prob_{x in B | Q(x)} f(x)
#     core type: Operation
#     operator: 52
#     operand: 56
# 48. X
#     core type: Variable
#     sub-expressions:
# 49. Omega
#     core type: Variable
#     sub-expressions:
# 50. {f(x) if x in C ,  Q(x).
#     core type: Conditional
#     value: 62
#     condition: 54
# 51. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. Prob
#     core type: Literal
#     sub-expressions:
# 53. (x -> {f(x) if x in B ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 56
# 54. (x in C) and Q(x)
#     core type: Operation
#     operator: 67
#     operands: 57
# 55. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 80
#     body: 58
# 56. x -> {f(x) if x in B ,  Q(x).
#     core type: Lambda
#     parameter: 80
#     body: 59
# 57. (x in C, Q(x))
#     core type: ExprTuple
#     sub-expressions: 60, 72
# 58. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 62
#     condition: 61
# 59. {f(x) if x in B ,  Q(x).
#     core type: Conditional
#     value: 62
#     condition: 63
# 60. x in C
#     core type: Operation
#     operator: 74
#     operands: 64
# 61. (x in A) and Q(x)
#     core type: Operation
#     operator: 67
#     operands: 65
# 62. f(x)
#     core type: Operation
#     operator: 66
#     operand: 80
# 63. (x in B) and Q(x)
#     core type: Operation
#     operator: 67
#     operands: 68
# 64. (x, C)
#     core type: ExprTuple
#     sub-expressions: 80, 69
# 65. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 70, 72
# 66. f
#     core type: Variable
#     sub-expressions:
# 67. and
#     core type: Literal
#     sub-expressions:
# 68. (x in B, Q(x))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 69. C
#     core type: Variable
#     sub-expressions:
# 70. x in A
#     core type: Operation
#     operator: 74
#     operands: 73
# 71. x in B
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. Q(x)
#     core type: Operation
#     operator: 76
#     operand: 80
# 73. (x, A)
#     core type: ExprTuple
#     sub-expressions: 80, 78
# 74. in
#     core type: Literal
#     sub-expressions:
# 75. (x, B)
#     core type: ExprTuple
#     sub-expressions: 80, 79
# 76. Q
#     core type: Variable
#     sub-expressions:
# 77. (x)
#     core type: ExprTuple
#     sub-expressions: 80
# 78. A
#     core type: Variable
#     sub-expressions:
# 79. B
#     core type: Variable
#     sub-expressions:
# 80. x
#     core type: Variable
#     sub-expressions:
