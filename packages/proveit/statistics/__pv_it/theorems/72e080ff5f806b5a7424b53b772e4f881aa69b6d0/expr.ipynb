# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, ExprTuple, Lambda, Omega, Q, Qx, X, f, fx, x
from proveit.logic import And, Disjoint, Equals, Forall, Injections, SubsetEq, Union
from proveit.numbers import Add
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda([A, B, C, X, Q], Conditional(Forall(instance_param_or_params = [f], instance_expr = Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = C, condition = Qx), Add(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = B, condition = Qx))), domain = Injections(X, Omega)), And(SubsetEq(C, X), Equals(C, Union(A, B)), Disjoint(A, B)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(A, B, C, X, Q\right) \mapsto \left\{\forall_{f \in \left[X \xrightarrow[]{\text{1-to-1}} \Omega\right]}~\left(\left[\textrm{Prob}_{x \in C~|~Q\left(x\right)}~f\left(x\right)\right] = \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] + \left[\textrm{Prob}_{x \in B~|~Q\left(x\right)}~f\left(x\right)\right]\right)\right) \textrm{ if } C \subseteq X ,  C = \left(A \cup B\right) ,  \textrm{disjoint}\left(A, B\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (A, B, C, X, Q)
#    core type: ExprTuple
#    sub-expressions: 68, 69, 59, 38, 66
# 3. {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (C subset_eq X) and (C = (A union B)) and disjoint(A, B)
#    core type: Operation
#    operator: 57
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (C subset_eq X, C = (A union B), disjoint(A, B))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#    core type: Lambda
#    parameter: 56
#    body: 14
# 10. C subset_eq X
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. C = (A union B)
#     core type: Operation
#     operator: 22
#     operands: 17
# 12. disjoint(A, B)
#     core type: Operation
#     operator: 18
#     operands: 26
# 13. (f)
#     core type: ExprTuple
#     sub-expressions: 56
# 14. {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. subset_eq
#     core type: Literal
#     sub-expressions:
# 16. (C, X)
#     core type: ExprTuple
#     sub-expressions: 59, 38
# 17. (C, A union B)
#     core type: ExprTuple
#     sub-expressions: 59, 21
# 18. disjoint
#     core type: Literal
#     sub-expressions:
# 19. [Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. f in Injections(X, Omega)
#     core type: Operation
#     operator: 64
#     operands: 24
# 21. A union B
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (Prob_{x in C | Q(x)} f(x), [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. (f, Injections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 56, 29
# 25. union
#     core type: Literal
#     sub-expressions:
# 26. (A, B)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 27. Prob_{x in C | Q(x)} f(x)
#     core type: Operation
#     operator: 42
#     operand: 35
# 28. [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. Injections(X, Omega)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (x -> {f(x) if x in C ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (Prob_{x in A | Q(x)} f(x), Prob_{x in B | Q(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. Injections
#     core type: Literal
#     sub-expressions:
# 34. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. x -> {f(x) if x in C ,  Q(x).
#     core type: Lambda
#     parameter: 70
#     body: 40
# 36. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 42
#     operand: 45
# 37. Prob_{x in B | Q(x)} f(x)
#     core type: Operation
#     operator: 42
#     operand: 46
# 38. X
#     core type: Variable
#     sub-expressions:
# 39. Omega
#     core type: Variable
#     sub-expressions:
# 40. {f(x) if x in C ,  Q(x).
#     core type: Conditional
#     value: 52
#     condition: 44
# 41. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. Prob
#     core type: Literal
#     sub-expressions:
# 43. (x -> {f(x) if x in B ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. (x in C) and Q(x)
#     core type: Operation
#     operator: 57
#     operands: 47
# 45. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 70
#     body: 48
# 46. x -> {f(x) if x in B ,  Q(x).
#     core type: Lambda
#     parameter: 70
#     body: 49
# 47. (x in C, Q(x))
#     core type: ExprTuple
#     sub-expressions: 50, 62
# 48. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 52
#     condition: 51
# 49. {f(x) if x in B ,  Q(x).
#     core type: Conditional
#     value: 52
#     condition: 53
# 50. x in C
#     core type: Operation
#     operator: 64
#     operands: 54
# 51. (x in A) and Q(x)
#     core type: Operation
#     operator: 57
#     operands: 55
# 52. f(x)
#     core type: Operation
#     operator: 56
#     operand: 70
# 53. (x in B) and Q(x)
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. (x, C)
#     core type: ExprTuple
#     sub-expressions: 70, 59
# 55. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 56. f
#     core type: Variable
#     sub-expressions:
# 57. and
#     core type: Literal
#     sub-expressions:
# 58. (x in B, Q(x))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. C
#     core type: Variable
#     sub-expressions:
# 60. x in A
#     core type: Operation
#     operator: 64
#     operands: 63
# 61. x in B
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. Q(x)
#     core type: Operation
#     operator: 66
#     operand: 70
# 63. (x, A)
#     core type: ExprTuple
#     sub-expressions: 70, 68
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (x, B)
#     core type: ExprTuple
#     sub-expressions: 70, 69
# 66. Q
#     core type: Variable
#     sub-expressions:
# 67. (x)
#     core type: ExprTuple
#     sub-expressions: 70
# 68. A
#     core type: Variable
#     sub-expressions:
# 69. B
#     core type: Variable
#     sub-expressions:
# 70. x
#     core type: Variable
#     sub-expressions:
