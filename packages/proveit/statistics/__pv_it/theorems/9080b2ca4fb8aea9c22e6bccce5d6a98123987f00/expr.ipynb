# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Function, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, Injections
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = Forall(instance_param_or_params = [A, B, Q], instance_expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A, B, Q}~\left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, Q)
#    core type: ExprTuple
#    sub-expressions: 53, 55, 51
# 4. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 8. (f, g)
#    core type: ExprTuple
#    sub-expressions: 40, 57
# 9. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 41
#     operands: 14
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 20
#     operand: 24
# 16. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 20
#     operand: 25
# 17. f in Injections(A, Omega)
#     core type: Operation
#     operator: 49
#     operands: 22
# 18. g in Bijections(B, A)
#     core type: Operation
#     operator: 49
#     operands: 23
# 19. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. Prob
#     core type: Literal
#     sub-expressions:
# 21. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 40, 26
# 23. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 57, 27
# 24. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 54
#     body: 28
# 25. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 59
#     body: 29
# 26. Injections(A, Omega)
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. Bijections(B, A)
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 34
#     condition: 35
# 29. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 36
#     condition: 37
# 30. Injections
#     core type: Literal
#     sub-expressions:
# 31. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 53, 38
# 32. Bijections
#     core type: Literal
#     sub-expressions:
# 33. (B, A)
#     core type: ExprTuple
#     sub-expressions: 55, 53
# 34. f(x)
#     core type: Operation
#     operator: 40
#     operand: 54
# 35. (x in A) and Q(x)
#     core type: Operation
#     operator: 41
#     operands: 39
# 36. f(g(y))
#     core type: Operation
#     operator: 40
#     operand: 56
# 37. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. Omega
#     core type: Variable
#     sub-expressions:
# 39. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. and
#     core type: Literal
#     sub-expressions:
# 42. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. x in A
#     core type: Operation
#     operator: 49
#     operands: 47
# 44. Q(x)
#     core type: Operation
#     operator: 51
#     operand: 54
# 45. y in B
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. Q(g(y))
#     core type: Operation
#     operator: 51
#     operand: 56
# 47. (x, A)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 48. (x)
#     core type: ExprTuple
#     sub-expressions: 54
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (y, B)
#     core type: ExprTuple
#     sub-expressions: 59, 55
# 51. Q
#     core type: Variable
#     sub-expressions:
# 52. (g(y))
#     core type: ExprTuple
#     sub-expressions: 56
# 53. A
#     core type: Variable
#     sub-expressions:
# 54. x
#     core type: Variable
#     sub-expressions:
# 55. B
#     core type: Variable
#     sub-expressions:
# 56. g(y)
#     core type: Operation
#     operator: 57
#     operand: 59
# 57. g
#     core type: Variable
#     sub-expressions:
# 58. (y)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. y
#     core type: Variable
#     sub-expressions:
