# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Function, Lambda, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, InClass, Injections
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = ExprTuple(Lambda(Omega, Conditional(Forall(instance_param_or_params = [A, B, Q], instance_expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()), InClass(Omega, SampleSpaces))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\Omega \mapsto \left\{\forall_{A, B, Q}~\left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right] \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Omega -> {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Omega -> {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 46
#    body: 3
# 2. (Omega)
#    core type: ExprTuple
#    sub-expressions: 46
# 3. {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Operation
#    operator: 13
#    operand: 9
# 5. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 46, 10
# 9. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. SampleSpaces
#     core type: Literal
#     sub-expressions:
# 11. (A, B, Q)
#     core type: ExprTuple
#     sub-expressions: 61, 63, 59
# 12. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Lambda
#     parameters: 16\n    body: 17
# 16. (f, g)
#     core type: ExprTuple
#     sub-expressions: 48, 65
# 17. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 49
#     operands: 22
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 28
#     operand: 32
# 24. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 28
#     operand: 33
# 25. f in Injections(A, Omega)
#     core type: Operation
#     operator: 57
#     operands: 30
# 26. g in Bijections(B, A)
#     core type: Operation
#     operator: 57
#     operands: 31
# 27. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. Prob
#     core type: Literal
#     sub-expressions:
# 29. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 48, 34
# 31. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 65, 35
# 32. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 62
#     body: 36
# 33. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 67
#     body: 37
# 34. Injections(A, Omega)
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. Bijections(B, A)
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 42
#     condition: 43
# 37. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 44
#     condition: 45
# 38. Injections
#     core type: Literal
#     sub-expressions:
# 39. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 61, 46
# 40. Bijections
#     core type: Literal
#     sub-expressions:
# 41. (B, A)
#     core type: ExprTuple
#     sub-expressions: 63, 61
# 42. f(x)
#     core type: Operation
#     operator: 48
#     operand: 62
# 43. (x in A) and Q(x)
#     core type: Operation
#     operator: 49
#     operands: 47
# 44. f(g(y))
#     core type: Operation
#     operator: 48
#     operand: 64
# 45. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. Omega
#     core type: Variable
#     sub-expressions:
# 47. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. and
#     core type: Literal
#     sub-expressions:
# 50. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. x in A
#     core type: Operation
#     operator: 57
#     operands: 55
# 52. Q(x)
#     core type: Operation
#     operator: 59
#     operand: 62
# 53. y in B
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. Q(g(y))
#     core type: Operation
#     operator: 59
#     operand: 64
# 55. (x, A)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 56. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (y, B)
#     core type: ExprTuple
#     sub-expressions: 67, 63
# 59. Q
#     core type: Variable
#     sub-expressions:
# 60. (g(y))
#     core type: ExprTuple
#     sub-expressions: 64
# 61. A
#     core type: Variable
#     sub-expressions:
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. B
#     core type: Variable
#     sub-expressions:
# 64. g(y)
#     core type: Operation
#     operator: 65
#     operand: 67
# 65. g
#     core type: Variable
#     sub-expressions:
# 66. (y)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. y
#     core type: Variable
#     sub-expressions:
