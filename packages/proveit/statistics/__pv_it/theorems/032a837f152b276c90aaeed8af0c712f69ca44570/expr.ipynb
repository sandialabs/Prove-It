# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Function, Lambda, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, InClass, Injections
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = Lambda(Omega, Conditional(Forall(instance_param_or_params = [A, B, Q], instance_expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()), InClass(Omega, SampleSpaces)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \Omega \mapsto \left\{\forall_{A, B, Q}~\left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right] \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Omega -> {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 45
#    body: 2
# 1. (Omega)
#    core type: ExprTuple
#    sub-expressions: 45
# 2. {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Operation
#    operator: 12
#    operand: 8
# 4. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 45, 9
# 8. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 10. (A, B, Q)
#     core type: ExprTuple
#     sub-expressions: 60, 62, 58
# 11. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#     core type: Operation
#     operator: 12
#     operand: 14
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 15. (f, g)
#     core type: ExprTuple
#     sub-expressions: 47, 64
# 16. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Conditional
#     value: 17
#     condition: 18
# 17. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 48
#     operands: 21
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 27
#     operand: 31
# 23. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 27
#     operand: 32
# 24. f in Injections(A, Omega)
#     core type: Operation
#     operator: 56
#     operands: 29
# 25. g in Bijections(B, A)
#     core type: Operation
#     operator: 56
#     operands: 30
# 26. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. Prob
#     core type: Literal
#     sub-expressions:
# 28. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 47, 33
# 30. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 64, 34
# 31. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 61
#     body: 35
# 32. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 66
#     body: 36
# 33. Injections(A, Omega)
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. Bijections(B, A)
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 41
#     condition: 42
# 36. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 43
#     condition: 44
# 37. Injections
#     core type: Literal
#     sub-expressions:
# 38. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 39. Bijections
#     core type: Literal
#     sub-expressions:
# 40. (B, A)
#     core type: ExprTuple
#     sub-expressions: 62, 60
# 41. f(x)
#     core type: Operation
#     operator: 47
#     operand: 61
# 42. (x in A) and Q(x)
#     core type: Operation
#     operator: 48
#     operands: 46
# 43. f(g(y))
#     core type: Operation
#     operator: 47
#     operand: 63
# 44. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. Omega
#     core type: Variable
#     sub-expressions:
# 46. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. f
#     core type: Variable
#     sub-expressions:
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. x in A
#     core type: Operation
#     operator: 56
#     operands: 54
# 51. Q(x)
#     core type: Operation
#     operator: 58
#     operand: 61
# 52. y in B
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. Q(g(y))
#     core type: Operation
#     operator: 58
#     operand: 63
# 54. (x, A)
#     core type: ExprTuple
#     sub-expressions: 61, 60
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (y, B)
#     core type: ExprTuple
#     sub-expressions: 66, 62
# 58. Q
#     core type: Variable
#     sub-expressions:
# 59. (g(y))
#     core type: ExprTuple
#     sub-expressions: 63
# 60. A
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. B
#     core type: Variable
#     sub-expressions:
# 63. g(y)
#     core type: Operation
#     operator: 64
#     operand: 66
# 64. g
#     core type: Variable
#     sub-expressions:
# 65. (y)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. y
#     core type: Variable
#     sub-expressions:
