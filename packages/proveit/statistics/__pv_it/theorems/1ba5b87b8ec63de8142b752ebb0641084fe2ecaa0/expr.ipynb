# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Omega, Q, Qx, R, Rx, Ry, X, f, fx, fy, x, y
from proveit.logic import Bijections, Equals, Forall, Implies, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2)), domain = Bijections(X, Omega)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{X}~\left[\forall_{f \in \left[X \xrightarrow[\text{onto}]{\text{1-to-1}} \Omega\right]}~\left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{X} [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. (X -> [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. X -> [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]]
#    core type: Lambda
#    parameter: 72
#    body: 4
# 3. (X)
#    core type: ExprTuple
#    sub-expressions: 72
# 4. forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]
#    core type: Operation
#    operator: 24
#    operand: 6
# 5. (f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#    core type: Lambda
#    parameter: 63
#    body: 8
# 7. (f)
#    core type: ExprTuple
#    sub-expressions: 63
# 8. {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#    core type: Operation
#    operator: 24
#    operand: 13
# 10. f in Bijections(X, Omega)
#     core type: Operation
#     operator: 68
#     operands: 12
# 11. ((Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (f, Bijections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 63, 14
# 13. (Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#     core type: Lambda
#     parameters: 15\n    body: 16
# 14. Bijections(X, Omega)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 57, 70
# 16. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. Bijections
#     core type: Literal
#     sub-expressions:
# 18. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 72, 21
# 19. =>
#     core type: Literal
#     sub-expressions:
# 20. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. Omega
#     core type: Variable
#     sub-expressions:
# 22. forall_{x in X} (Q(x) = [not](R(x)))
#     core type: Operation
#     operator: 24
#     operand: 27
# 23. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#     core type: Operation
#     operator: 38
#     operands: 26
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. (x -> {Q(x) = [not](R(x)) if x in X.)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. x -> {Q(x) = [not](R(x)) if x in X.
#     core type: Lambda
#     parameter: 60
#     body: 30
# 28. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 50
#     operand: 35
# 29. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 34
#     condition: 53
# 31. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 60
#     body: 40
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 41
#     operand: 46
# 38. =
#     core type: Literal
#     sub-expressions:
# 39. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 54, 43
# 40. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 44
#     condition: 45
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 46
# 43. [not](R(x))
#     core type: Operation
#     operator: 47
#     operand: 52
# 44. f(x)
#     core type: Operation
#     operator: 63
#     operand: 60
# 45. (x in X) and Q(x)
#     core type: Operation
#     operator: 64
#     operands: 49
# 46. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 50
#     operand: 55
# 47. not
#     core type: Literal
#     sub-expressions:
# 48. (R(x))
#     core type: ExprTuple
#     sub-expressions: 52
# 49. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. Prob
#     core type: Literal
#     sub-expressions:
# 51. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. R(x)
#     core type: Operation
#     operator: 70
#     operand: 60
# 53. x in X
#     core type: Operation
#     operator: 68
#     operands: 56
# 54. Q(x)
#     core type: Operation
#     operator: 57
#     operand: 60
# 55. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 73
#     body: 59
# 56. (x, X)
#     core type: ExprTuple
#     sub-expressions: 60, 72
# 57. Q
#     core type: Variable
#     sub-expressions:
# 58. (x)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 61
#     condition: 62
# 60. x
#     core type: Variable
#     sub-expressions:
# 61. f(y)
#     core type: Operation
#     operator: 63
#     operand: 73
# 62. (y in X) and R(y)
#     core type: Operation
#     operator: 64
#     operands: 65
# 63. f
#     core type: Variable
#     sub-expressions:
# 64. and
#     core type: Literal
#     sub-expressions:
# 65. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. y in X
#     core type: Operation
#     operator: 68
#     operands: 69
# 67. R(y)
#     core type: Operation
#     operator: 70
#     operand: 73
# 68. in
#     core type: Literal
#     sub-expressions:
# 69. (y, X)
#     core type: ExprTuple
#     sub-expressions: 73, 72
# 70. R
#     core type: Variable
#     sub-expressions:
# 71. (y)
#     core type: ExprTuple
#     sub-expressions: 73
# 72. X
#     core type: Variable
#     sub-expressions:
# 73. y
#     core type: Variable
#     sub-expressions:
