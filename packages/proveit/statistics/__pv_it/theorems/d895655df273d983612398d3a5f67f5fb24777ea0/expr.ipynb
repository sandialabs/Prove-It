# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Omega, Q, Qx, R, Rx, Ry, X, f, fx, fy, x, y
from proveit.logic import Bijections, Equals, Forall, Implies, InClass, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2)), domain = Bijections(X, Omega))), InClass(Omega, SampleSpaces))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{X}~\left[\forall_{f \in \left[X \xrightarrow[\text{onto}]{\text{1-to-1}} \Omega\right]}~\left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\right] \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{X} [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{X} [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]]
#    core type: Operation
#    operator: 29
#    operand: 6
# 2. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (X -> [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]])
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 26, 7
# 6. X -> [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]]
#    core type: Lambda
#    parameter: 77
#    body: 9
# 7. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 8. (X)
#    core type: ExprTuple
#    sub-expressions: 77
# 9. forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]
#    core type: Operation
#    operator: 29
#    operand: 11
# 10. (f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#     core type: Lambda
#     parameter: 68
#     body: 13
# 12. (f)
#     core type: ExprTuple
#     sub-expressions: 68
# 13. {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#     core type: Operation
#     operator: 29
#     operand: 18
# 15. f in Bijections(X, Omega)
#     core type: Operation
#     operator: 73
#     operands: 17
# 16. ((Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))))
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (f, Bijections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 68, 19
# 18. (Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#     core type: Lambda
#     parameters: 20\n    body: 21
# 19. Bijections(X, Omega)
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 62, 75
# 21. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Bijections
#     core type: Literal
#     sub-expressions:
# 23. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 77, 26
# 24. =>
#     core type: Literal
#     sub-expressions:
# 25. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. Omega
#     core type: Variable
#     sub-expressions:
# 27. forall_{x in X} (Q(x) = [not](R(x)))
#     core type: Operation
#     operator: 29
#     operand: 32
# 28. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#     core type: Operation
#     operator: 43
#     operands: 31
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. (x -> {Q(x) = [not](R(x)) if x in X.)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. x -> {Q(x) = [not](R(x)) if x in X.
#     core type: Lambda
#     parameter: 65
#     body: 35
# 33. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 55
#     operand: 40
# 34. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 39
#     condition: 58
# 36. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 65
#     body: 45
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 46
#     operand: 51
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 59, 48
# 45. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 49
#     condition: 50
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 51
# 48. [not](R(x))
#     core type: Operation
#     operator: 52
#     operand: 57
# 49. f(x)
#     core type: Operation
#     operator: 68
#     operand: 65
# 50. (x in X) and Q(x)
#     core type: Operation
#     operator: 69
#     operands: 54
# 51. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 55
#     operand: 60
# 52. not
#     core type: Literal
#     sub-expressions:
# 53. (R(x))
#     core type: ExprTuple
#     sub-expressions: 57
# 54. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. Prob
#     core type: Literal
#     sub-expressions:
# 56. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. R(x)
#     core type: Operation
#     operator: 75
#     operand: 65
# 58. x in X
#     core type: Operation
#     operator: 73
#     operands: 61
# 59. Q(x)
#     core type: Operation
#     operator: 62
#     operand: 65
# 60. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 78
#     body: 64
# 61. (x, X)
#     core type: ExprTuple
#     sub-expressions: 65, 77
# 62. Q
#     core type: Variable
#     sub-expressions:
# 63. (x)
#     core type: ExprTuple
#     sub-expressions: 65
# 64. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 66
#     condition: 67
# 65. x
#     core type: Variable
#     sub-expressions:
# 66. f(y)
#     core type: Operation
#     operator: 68
#     operand: 78
# 67. (y in X) and R(y)
#     core type: Operation
#     operator: 69
#     operands: 70
# 68. f
#     core type: Variable
#     sub-expressions:
# 69. and
#     core type: Literal
#     sub-expressions:
# 70. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 71. y in X
#     core type: Operation
#     operator: 73
#     operands: 74
# 72. R(y)
#     core type: Operation
#     operator: 75
#     operand: 78
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (y, X)
#     core type: ExprTuple
#     sub-expressions: 78, 77
# 75. R
#     core type: Variable
#     sub-expressions:
# 76. (y)
#     core type: ExprTuple
#     sub-expressions: 78
# 77. X
#     core type: Variable
#     sub-expressions:
# 78. y
#     core type: Variable
#     sub-expressions:
