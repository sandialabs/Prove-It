# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Omega, Q, Qx, R, Rx, X, f, fx, x
from proveit.logic import Forall, Functions, Implies
from proveit.numbers import LessEq
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [Omega], instance_expr = Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Rx, domain = X, condition = Qx), LessEq(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Rx)).with_wrapping_at(2)).with_wrapping_at(2)), domain = Functions(X, Omega)).with_wrapping()), domain = SampleSpaces)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}}~\left[\forall_{X}~\left[\begin{array}{l}\forall_{f \in \left[X \rightarrow \Omega\right]}~\\
# \left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X~|~Q\left(x\right)}~R\left(x\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] \leq  \\ \left[\textrm{Prob}_{x \in X~|~R\left(x\right)}~f\left(x\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{Omega in_c SampleSpaces} [forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]]]
#    core type: Operation
#    operator: 33
#    operand: 2
# 1. (Omega -> {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. Omega -> {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 30
#    body: 4
# 3. (Omega)
#    core type: ExprTuple
#    sub-expressions: 30
# 4. {forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{X} [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]]
#    core type: Operation
#    operator: 33
#    operand: 10
# 6. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (X -> [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]])
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 30, 11
# 10. X -> [forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]]
#     core type: Lambda
#     parameter: 63
#     body: 13
# 11. SampleSpaces
#     core type: Literal
#     sub-expressions:
# 12. (X)
#     core type: ExprTuple
#     sub-expressions: 63
# 13. forall_{f in [X -> Omega]} [forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))]
#     core type: Operation
#     operator: 33
#     operand: 15
# 14. (f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. f -> {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#     core type: Lambda
#     parameter: 52
#     body: 17
# 16. (f)
#     core type: ExprTuple
#     sub-expressions: 52
# 17. {forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])) if f in [X -> Omega].
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. forall_{Q, R} ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#     core type: Operation
#     operator: 33
#     operand: 22
# 19. f in [X -> Omega]
#     core type: Operation
#     operator: 59
#     operands: 21
# 20. ((Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (f, [X -> Omega])
#     core type: ExprTuple
#     sub-expressions: 52, 23
# 22. (Q, R) -> ([forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]))
#     core type: Lambda
#     parameters: 24\n    body: 25
# 23. [X -> Omega]
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 58, 61
# 25. [forall_{x in X | Q(x)} R(x)] =>  \\ ([Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. Functions
#     core type: Literal
#     sub-expressions:
# 27. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 63, 30
# 28. =>
#     core type: Literal
#     sub-expressions:
# 29. (forall_{x in X | Q(x)} R(x), [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. Omega
#     core type: Variable
#     sub-expressions:
# 31. forall_{x in X | Q(x)} R(x)
#     core type: Operation
#     operator: 33
#     operand: 37
# 32. [Prob_{x in X | Q(x)} f(x)] <=  \\ [Prob_{x in X | R(x)} f(x)]
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. forall
#     core type: Literal
#     sub-expressions:
# 34. (x -> {R(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. <=
#     core type: Literal
#     sub-expressions:
# 36. (Prob_{x in X | Q(x)} f(x), Prob_{x in X | R(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. x -> {R(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 64
#     body: 40
# 38. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 42
#     operand: 44
# 39. Prob_{x in X | R(x)} f(x)
#     core type: Operation
#     operator: 42
#     operand: 45
# 40. {R(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 57
#     condition: 48
# 41. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. Prob
#     core type: Literal
#     sub-expressions:
# 43. (x -> {f(x) if x in X ,  R(x).)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 64
#     body: 46
# 45. x -> {f(x) if x in X ,  R(x).
#     core type: Lambda
#     parameter: 64
#     body: 47
# 46. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 49
#     condition: 48
# 47. {f(x) if x in X ,  R(x).
#     core type: Conditional
#     value: 49
#     condition: 50
# 48. (x in X) and Q(x)
#     core type: Operation
#     operator: 53
#     operands: 51
# 49. f(x)
#     core type: Operation
#     operator: 52
#     operand: 64
# 50. (x in X) and R(x)
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 52. f
#     core type: Variable
#     sub-expressions:
# 53. and
#     core type: Literal
#     sub-expressions:
# 54. (x in X, R(x))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. Q(x)
#     core type: Operation
#     operator: 58
#     operand: 64
# 56. x in X
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. R(x)
#     core type: Operation
#     operator: 61
#     operand: 64
# 58. Q
#     core type: Variable
#     sub-expressions:
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (x, X)
#     core type: ExprTuple
#     sub-expressions: 64, 63
# 61. R
#     core type: Variable
#     sub-expressions:
# 62. (x)
#     core type: ExprTuple
#     sub-expressions: 64
# 63. X
#     core type: Variable
#     sub-expressions:
# 64. x
#     core type: Variable
#     sub-expressions:
