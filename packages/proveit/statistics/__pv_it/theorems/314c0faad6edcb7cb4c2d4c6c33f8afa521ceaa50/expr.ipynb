# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, Lambda, Omega, Q, Qx, X, f, fx, x
from proveit.logic import Disjoint, Equals, Forall, InClass, Injections, SubsetEq, Union
from proveit.numbers import Add
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(Omega, Conditional(Forall(instance_param_or_params = [A, B, C, X, Q], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = C, condition = Qx), Add(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = B, condition = Qx))), domain = Injections(X, Omega)), conditions = [SubsetEq(C, X), Equals(C, Union(A, B)), Disjoint(A, B)]).with_wrapping(), InClass(Omega, SampleSpaces)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \Omega \mapsto \left\{\begin{array}{l}\forall_{A, B, C, X, Q~|~C \subseteq X, C = \left(A \cup B\right), \textrm{disjoint}\left(A, B\right)}~\\
# \left[\forall_{f \in \left[X \xrightarrow[]{\text{1-to-1}} \Omega\right]}~\left(\left[\textrm{Prob}_{x \in C~|~Q\left(x\right)}~f\left(x\right)\right] = \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] + \left[\textrm{Prob}_{x \in B~|~Q\left(x\right)}~f\left(x\right)\right]\right)\right)\right]\end{array} \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Omega -> {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 47
#    body: 2
# 1. (Omega)
#    core type: ExprTuple
#    sub-expressions: 47
# 2. {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))]
#    core type: Operation
#    operator: 14
#    operand: 8
# 4. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 47, 9
# 8. (A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 10. (A, B, C, X, Q)
#     core type: ExprTuple
#     sub-expressions: 76, 77, 67, 46, 74
# 11. {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (C subset_eq X) and (C = (A union B)) and disjoint(A, B)
#     core type: Operation
#     operator: 65
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (C subset_eq X, C = (A union B), disjoint(A, B))
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 17. f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Lambda
#     parameter: 64
#     body: 22
# 18. C subset_eq X
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. C = (A union B)
#     core type: Operation
#     operator: 30
#     operands: 25
# 20. disjoint(A, B)
#     core type: Operation
#     operator: 26
#     operands: 34
# 21. (f)
#     core type: ExprTuple
#     sub-expressions: 64
# 22. {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Conditional
#     value: 27
#     condition: 28
# 23. subset_eq
#     core type: Literal
#     sub-expressions:
# 24. (C, X)
#     core type: ExprTuple
#     sub-expressions: 67, 46
# 25. (C, A union B)
#     core type: ExprTuple
#     sub-expressions: 67, 29
# 26. disjoint
#     core type: Literal
#     sub-expressions:
# 27. [Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. f in Injections(X, Omega)
#     core type: Operation
#     operator: 72
#     operands: 32
# 29. A union B
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (Prob_{x in C | Q(x)} f(x), [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. (f, Injections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 64, 37
# 33. union
#     core type: Literal
#     sub-expressions:
# 34. (A, B)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 35. Prob_{x in C | Q(x)} f(x)
#     core type: Operation
#     operator: 50
#     operand: 43
# 36. [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. Injections(X, Omega)
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (x -> {f(x) if x in C ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 43
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (Prob_{x in A | Q(x)} f(x), Prob_{x in B | Q(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. Injections
#     core type: Literal
#     sub-expressions:
# 42. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. x -> {f(x) if x in C ,  Q(x).
#     core type: Lambda
#     parameter: 78
#     body: 48
# 44. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 50
#     operand: 53
# 45. Prob_{x in B | Q(x)} f(x)
#     core type: Operation
#     operator: 50
#     operand: 54
# 46. X
#     core type: Variable
#     sub-expressions:
# 47. Omega
#     core type: Variable
#     sub-expressions:
# 48. {f(x) if x in C ,  Q(x).
#     core type: Conditional
#     value: 60
#     condition: 52
# 49. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. Prob
#     core type: Literal
#     sub-expressions:
# 51. (x -> {f(x) if x in B ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 54
# 52. (x in C) and Q(x)
#     core type: Operation
#     operator: 65
#     operands: 55
# 53. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 78
#     body: 56
# 54. x -> {f(x) if x in B ,  Q(x).
#     core type: Lambda
#     parameter: 78
#     body: 57
# 55. (x in C, Q(x))
#     core type: ExprTuple
#     sub-expressions: 58, 70
# 56. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 60
#     condition: 59
# 57. {f(x) if x in B ,  Q(x).
#     core type: Conditional
#     value: 60
#     condition: 61
# 58. x in C
#     core type: Operation
#     operator: 72
#     operands: 62
# 59. (x in A) and Q(x)
#     core type: Operation
#     operator: 65
#     operands: 63
# 60. f(x)
#     core type: Operation
#     operator: 64
#     operand: 78
# 61. (x in B) and Q(x)
#     core type: Operation
#     operator: 65
#     operands: 66
# 62. (x, C)
#     core type: ExprTuple
#     sub-expressions: 78, 67
# 63. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 68, 70
# 64. f
#     core type: Variable
#     sub-expressions:
# 65. and
#     core type: Literal
#     sub-expressions:
# 66. (x in B, Q(x))
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 67. C
#     core type: Variable
#     sub-expressions:
# 68. x in A
#     core type: Operation
#     operator: 72
#     operands: 71
# 69. x in B
#     core type: Operation
#     operator: 72
#     operands: 73
# 70. Q(x)
#     core type: Operation
#     operator: 74
#     operand: 78
# 71. (x, A)
#     core type: ExprTuple
#     sub-expressions: 78, 76
# 72. in
#     core type: Literal
#     sub-expressions:
# 73. (x, B)
#     core type: ExprTuple
#     sub-expressions: 78, 77
# 74. Q
#     core type: Variable
#     sub-expressions:
# 75. (x)
#     core type: ExprTuple
#     sub-expressions: 78
# 76. A
#     core type: Variable
#     sub-expressions:
# 77. B
#     core type: Variable
#     sub-expressions:
# 78. x
#     core type: Variable
#     sub-expressions:
