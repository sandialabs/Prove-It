# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Omega, Q, Qx, R, Rx, Ry, X, f, fx, fy, x, y
from proveit.logic import Bijections, Equals, Forall, Implies, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(X, Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2)), domain = Bijections(X, Omega)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# X \mapsto \left[\forall_{f \in \left[X \xrightarrow[\text{onto}]{\text{1-to-1}} \Omega\right]}~\left[\forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. X -> [forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]]
#    core type: Lambda
#    parameter: 70
#    body: 2
# 1. (X)
#    core type: ExprTuple
#    sub-expressions: 70
# 2. forall_{f in Bijections(X, Omega)} [forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))]
#    core type: Operation
#    operator: 22
#    operand: 4
# 3. (f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. f -> {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#    core type: Lambda
#    parameter: 61
#    body: 6
# 5. (f)
#    core type: ExprTuple
#    sub-expressions: 61
# 6. {forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))) if f in Bijections(X, Omega).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#    core type: Operation
#    operator: 22
#    operand: 11
# 8. f in Bijections(X, Omega)
#    core type: Operation
#    operator: 66
#    operands: 10
# 9. ((Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (f, Bijections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 61, 12
# 11. (Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. Bijections(X, Omega)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (Q, R)
#     core type: ExprTuple
#     sub-expressions: 55, 68
# 14. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Bijections
#     core type: Literal
#     sub-expressions:
# 16. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 70, 19
# 17. =>
#     core type: Literal
#     sub-expressions:
# 18. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. Omega
#     core type: Variable
#     sub-expressions:
# 20. forall_{x in X} (Q(x) = [not](R(x)))
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#     core type: Operation
#     operator: 36
#     operands: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (x -> {Q(x) = [not](R(x)) if x in X.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. x -> {Q(x) = [not](R(x)) if x in X.
#     core type: Lambda
#     parameter: 58
#     body: 28
# 26. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 48
#     operand: 33
# 27. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 32
#     condition: 51
# 29. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 58
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 39
#     operand: 44
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 52, 41
# 38. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 42
#     condition: 43
# 39. -
#     core type: Literal
#     sub-expressions:
# 40. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 44
# 41. [not](R(x))
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. f(x)
#     core type: Operation
#     operator: 61
#     operand: 58
# 43. (x in X) and Q(x)
#     core type: Operation
#     operator: 62
#     operands: 47
# 44. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 48
#     operand: 53
# 45. not
#     core type: Literal
#     sub-expressions:
# 46. (R(x))
#     core type: ExprTuple
#     sub-expressions: 50
# 47. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. Prob
#     core type: Literal
#     sub-expressions:
# 49. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. R(x)
#     core type: Operation
#     operator: 68
#     operand: 58
# 51. x in X
#     core type: Operation
#     operator: 66
#     operands: 54
# 52. Q(x)
#     core type: Operation
#     operator: 55
#     operand: 58
# 53. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 71
#     body: 57
# 54. (x, X)
#     core type: ExprTuple
#     sub-expressions: 58, 70
# 55. Q
#     core type: Variable
#     sub-expressions:
# 56. (x)
#     core type: ExprTuple
#     sub-expressions: 58
# 57. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 59
#     condition: 60
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. f(y)
#     core type: Operation
#     operator: 61
#     operand: 71
# 60. (y in X) and R(y)
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. f
#     core type: Variable
#     sub-expressions:
# 62. and
#     core type: Literal
#     sub-expressions:
# 63. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 64. y in X
#     core type: Operation
#     operator: 66
#     operands: 67
# 65. R(y)
#     core type: Operation
#     operator: 68
#     operand: 71
# 66. in
#     core type: Literal
#     sub-expressions:
# 67. (y, X)
#     core type: ExprTuple
#     sub-expressions: 71, 70
# 68. R
#     core type: Variable
#     sub-expressions:
# 69. (y)
#     core type: ExprTuple
#     sub-expressions: 71
# 70. X
#     core type: Variable
#     sub-expressions:
# 71. y
#     core type: Variable
#     sub-expressions:
