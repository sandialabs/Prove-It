# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Qx, Rx, Ry, X, fx, fy, x, y
from proveit.logic import Equals, Forall, Implies, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x in X} (Q(x) = [not](R(x)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {Q(x) = [not](R(x)) if x in X.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x -> {Q(x) = [not](R(x)) if x in X.
#    core type: Lambda
#    parameter: 41
#    body: 11
# 9. Prob_{x in X | Q(x)} f(x)
#    core type: Operation
#    operator: 31
#    operand: 16
# 10. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 15
#     condition: 34
# 12. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 41
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 22
#     operand: 27
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 35, 24
# 21. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 27
# 24. [not](R(x))
#     core type: Operation
#     operator: 28
#     operand: 33
# 25. f(x)
#     core type: Operation
#     operator: 44
#     operand: 41
# 26. (x in X) and Q(x)
#     core type: Operation
#     operator: 45
#     operands: 30
# 27. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 31
#     operand: 36
# 28. not
#     core type: Literal
#     sub-expressions:
# 29. (R(x))
#     core type: ExprTuple
#     sub-expressions: 33
# 30. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. Prob
#     core type: Literal
#     sub-expressions:
# 32. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. R(x)
#     core type: Operation
#     operator: 51
#     operand: 41
# 34. x in X
#     core type: Operation
#     operator: 49
#     operands: 37
# 35. Q(x)
#     core type: Operation
#     operator: 38
#     operand: 41
# 36. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 54
#     body: 40
# 37. (x, X)
#     core type: ExprTuple
#     sub-expressions: 41, 53
# 38. Q
#     core type: Variable
#     sub-expressions:
# 39. (x)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 42
#     condition: 43
# 41. x
#     core type: Variable
#     sub-expressions:
# 42. f(y)
#     core type: Operation
#     operator: 44
#     operand: 54
# 43. (y in X) and R(y)
#     core type: Operation
#     operator: 45
#     operands: 46
# 44. f
#     core type: Variable
#     sub-expressions:
# 45. and
#     core type: Literal
#     sub-expressions:
# 46. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 47. y in X
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. R(y)
#     core type: Operation
#     operator: 51
#     operand: 54
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (y, X)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 51. R
#     core type: Variable
#     sub-expressions:
# 52. (y)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. X
#     core type: Variable
#     sub-expressions:
# 54. y
#     core type: Variable
#     sub-expressions:
