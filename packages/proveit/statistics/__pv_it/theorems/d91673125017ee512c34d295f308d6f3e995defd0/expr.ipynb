# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Function, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, Injections
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, g)
#    core type: ExprTuple
#    sub-expressions: 36, 53
# 5. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#    core type: Operation
#    operator: 37
#    operands: 10
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 16
#     operand: 20
# 12. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 16
#     operand: 21
# 13. f in Injections(A, Omega)
#     core type: Operation
#     operator: 45
#     operands: 18
# 14. g in Bijections(B, A)
#     core type: Operation
#     operator: 45
#     operands: 19
# 15. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. Prob
#     core type: Literal
#     sub-expressions:
# 17. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 36, 22
# 19. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 53, 23
# 20. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 50
#     body: 24
# 21. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 55
#     body: 25
# 22. Injections(A, Omega)
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Bijections(B, A)
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 30
#     condition: 31
# 25. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 32
#     condition: 33
# 26. Injections
#     core type: Literal
#     sub-expressions:
# 27. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 49, 34
# 28. Bijections
#     core type: Literal
#     sub-expressions:
# 29. (B, A)
#     core type: ExprTuple
#     sub-expressions: 51, 49
# 30. f(x)
#     core type: Operation
#     operator: 36
#     operand: 50
# 31. (x in A) and Q(x)
#     core type: Operation
#     operator: 37
#     operands: 35
# 32. f(g(y))
#     core type: Operation
#     operator: 36
#     operand: 52
# 33. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. Omega
#     core type: Variable
#     sub-expressions:
# 35. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. f
#     core type: Variable
#     sub-expressions:
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. x in A
#     core type: Operation
#     operator: 45
#     operands: 43
# 40. Q(x)
#     core type: Operation
#     operator: 47
#     operand: 50
# 41. y in B
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. Q(g(y))
#     core type: Operation
#     operator: 47
#     operand: 52
# 43. (x, A)
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 44. (x)
#     core type: ExprTuple
#     sub-expressions: 50
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (y, B)
#     core type: ExprTuple
#     sub-expressions: 55, 51
# 47. Q
#     core type: Variable
#     sub-expressions:
# 48. (g(y))
#     core type: ExprTuple
#     sub-expressions: 52
# 49. A
#     core type: Variable
#     sub-expressions:
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. B
#     core type: Variable
#     sub-expressions:
# 52. g(y)
#     core type: Operation
#     operator: 53
#     operand: 55
# 53. g
#     core type: Variable
#     sub-expressions:
# 54. (y)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. y
#     core type: Variable
#     sub-expressions:
