# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple, Function, Lambda, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, Injections
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = ExprTuple(Lambda([A, B, Q], Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(A, B, Q\right) \mapsto \left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (A, B, Q)
#    core type: ExprTuple
#    sub-expressions: 52, 54, 50
# 3. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 7. (f, g)
#    core type: ExprTuple
#    sub-expressions: 39, 56
# 8. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 40
#     operands: 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 19
#     operand: 23
# 15. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 19
#     operand: 24
# 16. f in Injections(A, Omega)
#     core type: Operation
#     operator: 48
#     operands: 21
# 17. g in Bijections(B, A)
#     core type: Operation
#     operator: 48
#     operands: 22
# 18. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. Prob
#     core type: Literal
#     sub-expressions:
# 20. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 39, 25
# 22. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 56, 26
# 23. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 53
#     body: 27
# 24. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 58
#     body: 28
# 25. Injections(A, Omega)
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. Bijections(B, A)
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 33
#     condition: 34
# 28. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 35
#     condition: 36
# 29. Injections
#     core type: Literal
#     sub-expressions:
# 30. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 31. Bijections
#     core type: Literal
#     sub-expressions:
# 32. (B, A)
#     core type: ExprTuple
#     sub-expressions: 54, 52
# 33. f(x)
#     core type: Operation
#     operator: 39
#     operand: 53
# 34. (x in A) and Q(x)
#     core type: Operation
#     operator: 40
#     operands: 38
# 35. f(g(y))
#     core type: Operation
#     operator: 39
#     operand: 55
# 36. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. Omega
#     core type: Variable
#     sub-expressions:
# 38. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. f
#     core type: Variable
#     sub-expressions:
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. x in A
#     core type: Operation
#     operator: 48
#     operands: 46
# 43. Q(x)
#     core type: Operation
#     operator: 50
#     operand: 53
# 44. y in B
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. Q(g(y))
#     core type: Operation
#     operator: 50
#     operand: 55
# 46. (x, A)
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 47. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (y, B)
#     core type: ExprTuple
#     sub-expressions: 58, 54
# 50. Q
#     core type: Variable
#     sub-expressions:
# 51. (g(y))
#     core type: ExprTuple
#     sub-expressions: 55
# 52. A
#     core type: Variable
#     sub-expressions:
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. B
#     core type: Variable
#     sub-expressions:
# 55. g(y)
#     core type: Operation
#     operator: 56
#     operand: 58
# 56. g
#     core type: Variable
#     sub-expressions:
# 57. (y)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. y
#     core type: Variable
#     sub-expressions:
