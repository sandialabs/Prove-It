# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Function, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, InClass, Injections
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = Conditional(Forall(instance_param_or_params = [A, B, Q], instance_expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()), InClass(Omega, SampleSpaces))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{A, B, Q}~\left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right] \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Operation
#    operator: 10
#    operand: 6
# 2. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 43, 7
# 6. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 8. (A, B, Q)
#    core type: ExprTuple
#    sub-expressions: 58, 60, 56
# 9. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#    core type: Operation
#    operator: 10
#    operand: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 13. (f, g)
#     core type: ExprTuple
#     sub-expressions: 45, 62
# 14. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 46
#     operands: 19
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 25
#     operand: 29
# 21. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 25
#     operand: 30
# 22. f in Injections(A, Omega)
#     core type: Operation
#     operator: 54
#     operands: 27
# 23. g in Bijections(B, A)
#     core type: Operation
#     operator: 54
#     operands: 28
# 24. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. Prob
#     core type: Literal
#     sub-expressions:
# 26. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 30
# 27. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 45, 31
# 28. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 62, 32
# 29. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 59
#     body: 33
# 30. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 64
#     body: 34
# 31. Injections(A, Omega)
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. Bijections(B, A)
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 39
#     condition: 40
# 34. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 41
#     condition: 42
# 35. Injections
#     core type: Literal
#     sub-expressions:
# 36. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 58, 43
# 37. Bijections
#     core type: Literal
#     sub-expressions:
# 38. (B, A)
#     core type: ExprTuple
#     sub-expressions: 60, 58
# 39. f(x)
#     core type: Operation
#     operator: 45
#     operand: 59
# 40. (x in A) and Q(x)
#     core type: Operation
#     operator: 46
#     operands: 44
# 41. f(g(y))
#     core type: Operation
#     operator: 45
#     operand: 61
# 42. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. Omega
#     core type: Variable
#     sub-expressions:
# 44. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. f
#     core type: Variable
#     sub-expressions:
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. x in A
#     core type: Operation
#     operator: 54
#     operands: 52
# 49. Q(x)
#     core type: Operation
#     operator: 56
#     operand: 59
# 50. y in B
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. Q(g(y))
#     core type: Operation
#     operator: 56
#     operand: 61
# 52. (x, A)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 53. (x)
#     core type: ExprTuple
#     sub-expressions: 59
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (y, B)
#     core type: ExprTuple
#     sub-expressions: 64, 60
# 56. Q
#     core type: Variable
#     sub-expressions:
# 57. (g(y))
#     core type: ExprTuple
#     sub-expressions: 61
# 58. A
#     core type: Variable
#     sub-expressions:
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. B
#     core type: Variable
#     sub-expressions:
# 61. g(y)
#     core type: Operation
#     operator: 62
#     operand: 64
# 62. g
#     core type: Variable
#     sub-expressions:
# 63. (y)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. y
#     core type: Variable
#     sub-expressions:
