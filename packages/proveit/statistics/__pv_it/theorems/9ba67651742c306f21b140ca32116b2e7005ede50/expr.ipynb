# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, ExprTuple, Lambda, Omega, Q, Qx, X, f, fx, x
from proveit.logic import Disjoint, Equals, Forall, InClass, Injections, SubsetEq, Union
from proveit.numbers import Add
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda(Omega, Conditional(Forall(instance_param_or_params = [A, B, C, X, Q], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = C, condition = Qx), Add(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = B, condition = Qx))), domain = Injections(X, Omega)), conditions = [SubsetEq(C, X), Equals(C, Union(A, B)), Disjoint(A, B)]).with_wrapping(), InClass(Omega, SampleSpaces))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\Omega \mapsto \left\{\begin{array}{l}\forall_{A, B, C, X, Q~|~C \subseteq X, C = \left(A \cup B\right), \textrm{disjoint}\left(A, B\right)}~\\
# \left[\forall_{f \in \left[X \xrightarrow[]{\text{1-to-1}} \Omega\right]}~\left(\left[\textrm{Prob}_{x \in C~|~Q\left(x\right)}~f\left(x\right)\right] = \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] + \left[\textrm{Prob}_{x \in B~|~Q\left(x\right)}~f\left(x\right)\right]\right)\right)\right]\end{array} \textrm{ if } \Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Omega -> {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Omega -> {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 48
#    body: 3
# 2. (Omega)
#    core type: ExprTuple
#    sub-expressions: 48
# 3. {forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A, B, C, X, Q | C subset_eq X, C = (A union B), disjoint(A, B)} [forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))]
#    core type: Operation
#    operator: 15
#    operand: 9
# 5. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 48, 10
# 9. (A, B, C, X, Q) -> {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. SampleSpaces
#     core type: Literal
#     sub-expressions:
# 11. (A, B, C, X, Q)
#     core type: ExprTuple
#     sub-expressions: 77, 78, 68, 47, 75
# 12. {forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])) if C subset_eq X ,  C = (A union B) ,  disjoint(A, B).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. forall_{f in Injections(X, Omega)} ([Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]))
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. (C subset_eq X) and (C = (A union B)) and disjoint(A, B)
#     core type: Operation
#     operator: 66
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (C subset_eq X, C = (A union B), disjoint(A, B))
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 18. f -> {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Lambda
#     parameter: 65
#     body: 23
# 19. C subset_eq X
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. C = (A union B)
#     core type: Operation
#     operator: 31
#     operands: 26
# 21. disjoint(A, B)
#     core type: Operation
#     operator: 27
#     operands: 35
# 22. (f)
#     core type: ExprTuple
#     sub-expressions: 65
# 23. {[Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]) if f in Injections(X, Omega).
#     core type: Conditional
#     value: 28
#     condition: 29
# 24. subset_eq
#     core type: Literal
#     sub-expressions:
# 25. (C, X)
#     core type: ExprTuple
#     sub-expressions: 68, 47
# 26. (C, A union B)
#     core type: ExprTuple
#     sub-expressions: 68, 30
# 27. disjoint
#     core type: Literal
#     sub-expressions:
# 28. [Prob_{x in C | Q(x)} f(x)] = ([Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. f in Injections(X, Omega)
#     core type: Operation
#     operator: 73
#     operands: 33
# 30. A union B
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (Prob_{x in C | Q(x)} f(x), [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)])
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. (f, Injections(X, Omega))
#     core type: ExprTuple
#     sub-expressions: 65, 38
# 34. union
#     core type: Literal
#     sub-expressions:
# 35. (A, B)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 36. Prob_{x in C | Q(x)} f(x)
#     core type: Operation
#     operator: 51
#     operand: 44
# 37. [Prob_{x in A | Q(x)} f(x)] + [Prob_{x in B | Q(x)} f(x)]
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. Injections(X, Omega)
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. (x -> {f(x) if x in C ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 44
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (Prob_{x in A | Q(x)} f(x), Prob_{x in B | Q(x)} f(x))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. Injections
#     core type: Literal
#     sub-expressions:
# 43. (X, Omega)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. x -> {f(x) if x in C ,  Q(x).
#     core type: Lambda
#     parameter: 79
#     body: 49
# 45. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 51
#     operand: 54
# 46. Prob_{x in B | Q(x)} f(x)
#     core type: Operation
#     operator: 51
#     operand: 55
# 47. X
#     core type: Variable
#     sub-expressions:
# 48. Omega
#     core type: Variable
#     sub-expressions:
# 49. {f(x) if x in C ,  Q(x).
#     core type: Conditional
#     value: 61
#     condition: 53
# 50. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. Prob
#     core type: Literal
#     sub-expressions:
# 52. (x -> {f(x) if x in B ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. (x in C) and Q(x)
#     core type: Operation
#     operator: 66
#     operands: 56
# 54. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 79
#     body: 57
# 55. x -> {f(x) if x in B ,  Q(x).
#     core type: Lambda
#     parameter: 79
#     body: 58
# 56. (x in C, Q(x))
#     core type: ExprTuple
#     sub-expressions: 59, 71
# 57. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 61
#     condition: 60
# 58. {f(x) if x in B ,  Q(x).
#     core type: Conditional
#     value: 61
#     condition: 62
# 59. x in C
#     core type: Operation
#     operator: 73
#     operands: 63
# 60. (x in A) and Q(x)
#     core type: Operation
#     operator: 66
#     operands: 64
# 61. f(x)
#     core type: Operation
#     operator: 65
#     operand: 79
# 62. (x in B) and Q(x)
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. (x, C)
#     core type: ExprTuple
#     sub-expressions: 79, 68
# 64. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 69, 71
# 65. f
#     core type: Variable
#     sub-expressions:
# 66. and
#     core type: Literal
#     sub-expressions:
# 67. (x in B, Q(x))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. C
#     core type: Variable
#     sub-expressions:
# 69. x in A
#     core type: Operation
#     operator: 73
#     operands: 72
# 70. x in B
#     core type: Operation
#     operator: 73
#     operands: 74
# 71. Q(x)
#     core type: Operation
#     operator: 75
#     operand: 79
# 72. (x, A)
#     core type: ExprTuple
#     sub-expressions: 79, 77
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (x, B)
#     core type: ExprTuple
#     sub-expressions: 79, 78
# 75. Q
#     core type: Variable
#     sub-expressions:
# 76. (x)
#     core type: ExprTuple
#     sub-expressions: 79
# 77. A
#     core type: Variable
#     sub-expressions:
# 78. B
#     core type: Variable
#     sub-expressions:
# 79. x
#     core type: Variable
#     sub-expressions:
