# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Function, Omega, Q, Qx, f, fx, g, gy, x, y
from proveit.logic import Bijections, Equals, Forall, Injections
from proveit.statistics import ProbOfAll, SampleSpaces

# %%
# build up the expression from sub-expressions
sub_expr1 = [gy]
expr = Forall(instance_param_or_params = [Omega], instance_expr = Forall(instance_param_or_params = [A, B, Q], instance_expr = Forall(instance_param_or_params = [f, g], instance_expr = Equals(ProbOfAll(instance_param_or_params = [x], instance_element = fx, domain = A, condition = Qx), ProbOfAll(instance_param_or_params = [y], instance_element = Function(f, sub_expr1), domain = B, condition = Function(Q, sub_expr1))), domains = [Injections(A, Omega), Bijections(B, A)]).with_wrapping()), domain = SampleSpaces)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\Omega \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces}}~\left[\forall_{A, B, Q}~\left[\begin{array}{l}\forall_{f \in \left[A \xrightarrow[]{\text{1-to-1}} \Omega\right], g \in \left[B \xrightarrow[\text{onto}]{\text{1-to-1}} A\right]}~\\
# \left(\left[\textrm{Prob}_{x \in A~|~Q\left(x\right)}~f\left(x\right)\right] = \left[\textrm{Prob}_{y \in B~|~Q\left(g\left(y\right)\right)}~f\left(g\left(y\right)\right)\right]\right)\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{Omega in_c SampleSpaces} [forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (Omega -> {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. Omega -> {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Lambda
#    parameter: 47
#    body: 4
# 3. (Omega)
#    core type: ExprTuple
#    sub-expressions: 47
# 4. {forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])] if Omega in_c SampleSpaces.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A, B, Q} [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#    core type: Operation
#    operator: 14
#    operand: 10
# 6. Omega in_c SampleSpaces
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])])
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (Omega, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 47, 11
# 10. (A, B, Q) -> [forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])]
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. SampleSpaces
#     core type: Literal
#     sub-expressions:
# 12. (A, B, Q)
#     core type: ExprTuple
#     sub-expressions: 62, 64, 60
# 13. forall_{f in Injections(A, Omega), g in Bijections(B, A)} ([Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))])
#     core type: Operation
#     operator: 14
#     operand: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. (f, g) -> {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 17. (f, g)
#     core type: ExprTuple
#     sub-expressions: 49, 66
# 18. {[Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))] if f in Injections(A, Omega) ,  g in Bijections(B, A).
#     core type: Conditional
#     value: 19
#     condition: 20
# 19. [Prob_{x in A | Q(x)} f(x)] = [Prob_{y in B | Q(g(y))} f(g(y))]
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (f in Injections(A, Omega)) and (g in Bijections(B, A))
#     core type: Operation
#     operator: 50
#     operands: 23
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (Prob_{x in A | Q(x)} f(x), Prob_{y in B | Q(g(y))} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. (f in Injections(A, Omega), g in Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. Prob_{x in A | Q(x)} f(x)
#     core type: Operation
#     operator: 29
#     operand: 33
# 25. Prob_{y in B | Q(g(y))} f(g(y))
#     core type: Operation
#     operator: 29
#     operand: 34
# 26. f in Injections(A, Omega)
#     core type: Operation
#     operator: 58
#     operands: 31
# 27. g in Bijections(B, A)
#     core type: Operation
#     operator: 58
#     operands: 32
# 28. (x -> {f(x) if x in A ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. Prob
#     core type: Literal
#     sub-expressions:
# 30. (y -> {f(g(y)) if y in B ,  Q(g(y)).)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. (f, Injections(A, Omega))
#     core type: ExprTuple
#     sub-expressions: 49, 35
# 32. (g, Bijections(B, A))
#     core type: ExprTuple
#     sub-expressions: 66, 36
# 33. x -> {f(x) if x in A ,  Q(x).
#     core type: Lambda
#     parameter: 63
#     body: 37
# 34. y -> {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Lambda
#     parameter: 68
#     body: 38
# 35. Injections(A, Omega)
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. Bijections(B, A)
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. {f(x) if x in A ,  Q(x).
#     core type: Conditional
#     value: 43
#     condition: 44
# 38. {f(g(y)) if y in B ,  Q(g(y)).
#     core type: Conditional
#     value: 45
#     condition: 46
# 39. Injections
#     core type: Literal
#     sub-expressions:
# 40. (A, Omega)
#     core type: ExprTuple
#     sub-expressions: 62, 47
# 41. Bijections
#     core type: Literal
#     sub-expressions:
# 42. (B, A)
#     core type: ExprTuple
#     sub-expressions: 64, 62
# 43. f(x)
#     core type: Operation
#     operator: 49
#     operand: 63
# 44. (x in A) and Q(x)
#     core type: Operation
#     operator: 50
#     operands: 48
# 45. f(g(y))
#     core type: Operation
#     operator: 49
#     operand: 65
# 46. (y in B) and Q(g(y))
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. Omega
#     core type: Variable
#     sub-expressions:
# 48. (x in A, Q(x))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. f
#     core type: Variable
#     sub-expressions:
# 50. and
#     core type: Literal
#     sub-expressions:
# 51. (y in B, Q(g(y)))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. x in A
#     core type: Operation
#     operator: 58
#     operands: 56
# 53. Q(x)
#     core type: Operation
#     operator: 60
#     operand: 63
# 54. y in B
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. Q(g(y))
#     core type: Operation
#     operator: 60
#     operand: 65
# 56. (x, A)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 57. (x)
#     core type: ExprTuple
#     sub-expressions: 63
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (y, B)
#     core type: ExprTuple
#     sub-expressions: 68, 64
# 60. Q
#     core type: Variable
#     sub-expressions:
# 61. (g(y))
#     core type: ExprTuple
#     sub-expressions: 65
# 62. A
#     core type: Variable
#     sub-expressions:
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. B
#     core type: Variable
#     sub-expressions:
# 65. g(y)
#     core type: Operation
#     operator: 66
#     operand: 68
# 66. g
#     core type: Variable
#     sub-expressions:
# 67. (y)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. y
#     core type: Variable
#     sub-expressions:
