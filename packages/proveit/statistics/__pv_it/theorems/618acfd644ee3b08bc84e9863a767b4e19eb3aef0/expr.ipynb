# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Q, Qx, R, Rx, Ry, X, fx, fy, x, y
from proveit.logic import Equals, Forall, Implies, Not
from proveit.numbers import one, subtract
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [Q, R], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Qx, Not(Rx)), domain = X), Equals(ProbOfAll(instance_param_or_params = sub_expr1, instance_element = fx, domain = X, condition = Qx), subtract(one, ProbOfAll(instance_param_or_params = [y], instance_element = fy, domain = X, condition = Ry))).with_wrapping_at(2)).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x \in X}~\left(Q\left(x\right) = (\lnot R\left(x\right))\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{x \in X~|~Q\left(x\right)}~f\left(x\right)\right] =  \\ \left(1 - \left[\textrm{Prob}_{y \in X~|~R\left(y\right)}~f\left(y\right)\right]\right) \end{array} \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{Q, R} ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (Q, R) -> ([forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (Q, R)
#    core type: ExprTuple
#    sub-expressions: 42, 55
# 4. [forall_{x in X} (Q(x) = [not](R(x)))] =>  \\ ([Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x in X} (Q(x) = [not](R(x))), [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)]))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x in X} (Q(x) = [not](R(x)))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. [Prob_{x in X | Q(x)} f(x)] =  \\ (1 - [Prob_{y in X | R(y)} f(y)])
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. (x -> {Q(x) = [not](R(x)) if x in X.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (Prob_{x in X | Q(x)} f(x), 1 - [Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. x -> {Q(x) = [not](R(x)) if x in X.
#     core type: Lambda
#     parameter: 45
#     body: 15
# 13. Prob_{x in X | Q(x)} f(x)
#     core type: Operation
#     operator: 35
#     operand: 20
# 14. 1 - [Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. {Q(x) = [not](R(x)) if x in X.
#     core type: Conditional
#     value: 19
#     condition: 38
# 16. (x -> {f(x) if x in X ,  Q(x).)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (1, -[Prob_{y in X | R(y)} f(y)])
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Q(x) = [not](R(x))
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. x -> {f(x) if x in X ,  Q(x).
#     core type: Lambda
#     parameter: 45
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. -[Prob_{y in X | R(y)} f(y)]
#     core type: Operation
#     operator: 26
#     operand: 31
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (Q(x), [not](R(x)))
#     core type: ExprTuple
#     sub-expressions: 39, 28
# 25. {f(x) if x in X ,  Q(x).
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. (Prob_{y in X | R(y)} f(y))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. [not](R(x))
#     core type: Operation
#     operator: 32
#     operand: 37
# 29. f(x)
#     core type: Operation
#     operator: 48
#     operand: 45
# 30. (x in X) and Q(x)
#     core type: Operation
#     operator: 49
#     operands: 34
# 31. Prob_{y in X | R(y)} f(y)
#     core type: Operation
#     operator: 35
#     operand: 40
# 32. not
#     core type: Literal
#     sub-expressions:
# 33. (R(x))
#     core type: ExprTuple
#     sub-expressions: 37
# 34. (x in X, Q(x))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. Prob
#     core type: Literal
#     sub-expressions:
# 36. (y -> {f(y) if y in X ,  R(y).)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. R(x)
#     core type: Operation
#     operator: 55
#     operand: 45
# 38. x in X
#     core type: Operation
#     operator: 53
#     operands: 41
# 39. Q(x)
#     core type: Operation
#     operator: 42
#     operand: 45
# 40. y -> {f(y) if y in X ,  R(y).
#     core type: Lambda
#     parameter: 58
#     body: 44
# 41. (x, X)
#     core type: ExprTuple
#     sub-expressions: 45, 57
# 42. Q
#     core type: Variable
#     sub-expressions:
# 43. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. {f(y) if y in X ,  R(y).
#     core type: Conditional
#     value: 46
#     condition: 47
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. f(y)
#     core type: Operation
#     operator: 48
#     operand: 58
# 47. (y in X) and R(y)
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. and
#     core type: Literal
#     sub-expressions:
# 50. (y in X, R(y))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. y in X
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. R(y)
#     core type: Operation
#     operator: 55
#     operand: 58
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (y, X)
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 55. R
#     core type: Variable
#     sub-expressions:
# 56. (y)
#     core type: ExprTuple
#     sub-expressions: 58
# 57. X
#     core type: Variable
#     sub-expressions:
# 58. y
#     core type: Variable
#     sub-expressions:
