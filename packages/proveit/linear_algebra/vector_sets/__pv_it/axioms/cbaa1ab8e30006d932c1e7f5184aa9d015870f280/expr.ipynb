# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, V
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, InSet, Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right), \begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#    core type: Operation
#    operator: 40
#    operands: 3
# 2. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. {x_{1}, x_{2}, ..., x_{n}}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. LinDepSets(V)
#    core type: Operation
#    operator: 11
#    operand: 36
# 8. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 9. Set
#    core type: Literal
#    sub-expressions:
# 10. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. LinDepSets
#     core type: Literal
#     sub-expressions:
# 12. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 43
#     end_index: 44
# 15. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 43
#     end_index: 44
# 16. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 52
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 53
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. 0(V)
#     core type: Operation
#     operator: 30
#     operand: 36
# 26. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 43
#     end_index: 44
# 27. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 35
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. (V)
#     core type: ExprTuple
#     sub-expressions: 36
# 32. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 58
#     body: 37
# 33. or
#     core type: Literal
#     sub-expressions:
# 34. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 38
# 35. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 43
#     end_index: 44
# 36. V
#     core type: Variable
#     sub-expressions:
# 37. a_{_a} in K
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 39. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 58
#     body: 45
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 53, 46
# 42. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 58
#     body: 47
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. K
#     core type: Variable
#     sub-expressions:
# 47. a_{_a} != 0
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 50. !=
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. x_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 53. a_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 54. 0
#     core type: Literal
#     sub-expressions:
# 55. x
#     core type: Variable
#     sub-expressions:
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
