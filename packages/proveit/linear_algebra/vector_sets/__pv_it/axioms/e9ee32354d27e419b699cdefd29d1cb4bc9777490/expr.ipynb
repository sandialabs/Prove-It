# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, LinDepSets, SpanningSets, VecSpaces
from proveit.logic import And, Equals, Forall, InClass, InSet, NotInSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, Bases(V)), And(InSet(sub_expr1, SpanningSets(V)), NotInSet(sub_expr1, LinDepSets(V))).with_wrapping_at(2)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(V\right)\right) =  \\ \left(\begin{array}{c} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \notin \textrm{LinDepSets}\left(V\right)\right) \end{array}\right) \end{array} \end{array}\right)\end{array}\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]
#    core type: Operation
#    operator: 15
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 52, 7
# 6. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 55
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 55
# 9. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))
#     core type: Operation
#     operator: 15
#     operand: 18
# 13. n in NaturalPos
#     core type: Operation
#     operator: 41
#     operands: 17
# 14. K
#     core type: Variable
#     sub-expressions:
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 55, 19
# 18. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 48\n    body: 20
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 30
#     operands: 25
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V), ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 28
# 26. {x_{1}, x_{2}, ..., x_{n}} in Bases(V)
#     core type: Operation
#     operator: 41
#     operands: 29
# 27. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 55
# 29. ({x_{1}, x_{2}, ..., x_{n}}, Bases(V))
#     core type: ExprTuple
#     sub-expressions: 44, 33
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 59
#     body: 36
# 33. Bases(V)
#     core type: Operation
#     operator: 37
#     operand: 52
# 34. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 41
#     operands: 38
# 35. {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. x_{_a} in V
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. Bases
#     core type: Literal
#     sub-expressions:
# 38. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 44, 43
# 39. not-in
#     core type: Literal
#     sub-expressions:
# 40. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 56, 52
# 43. SpanningSets(V)
#     core type: Operation
#     operator: 46
#     operand: 52
# 44. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. LinDepSets(V)
#     core type: Operation
#     operator: 49
#     operand: 52
# 46. SpanningSets
#     core type: Literal
#     sub-expressions:
# 47. Set
#     core type: Literal
#     sub-expressions:
# 48. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 51
# 49. LinDepSets
#     core type: Literal
#     sub-expressions:
# 50. (V)
#     core type: ExprTuple
#     sub-expressions: 52
# 51. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 52. V
#     core type: Variable
#     sub-expressions:
# 53. _a -> x_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 56
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. x_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. x
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
