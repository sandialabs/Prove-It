# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import Span, VecSpaces, lin_comb_axn
from proveit.logic import Equals, Forall, InClass, Set, SetOfAll
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(Span(Set(x_1_to_n)), SetOfAll(instance_param_or_params = [a_1_to_n], instance_element = lin_comb_axn, domain = K)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \textrm{Span}\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) =  \\ \left\{\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right\}_{a_{1}, a_{2}, \ldots, a_{n} \in K} \end{array} \end{array}\right)\end{array}\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 47
#    body: 2
# 1. (V)
#    core type: ExprTuple
#    sub-expressions: 47
# 2. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]
#    core type: Operation
#    operator: 16
#    operand: 8
# 4. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 47, 9
# 8. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#    core type: Lambda
#    parameter: 59
#    body: 11
# 9. VecSpaces(K)
#    core type: Operation
#    operator: 12
#    operand: 68
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 59
# 11. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. VecSpaces
#     core type: Literal
#     sub-expressions:
# 13. (K)
#     core type: ExprTuple
#     sub-expressions: 68
# 14. forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. n in NaturalPos
#     core type: Operation
#     operator: 64
#     operands: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 59, 20
# 19. (x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 39\n    body: 21
# 20. NaturalPos
#     core type: Literal
#     sub-expressions:
# 21. {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 52
#     operands: 26
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (Span({x_{1}, x_{2}, ..., x_{n}}), {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 29
# 27. Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 30
#     operand: 35
# 28. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 32
#     operand: 36
# 29. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 58
#     end_index: 59
# 30. Span
#     core type: Literal
#     sub-expressions:
# 31. ({x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. SetOfAll
#     core type: Literal
#     sub-expressions:
# 33. ((a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 72
#     body: 37
# 35. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. (a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 40\n    body: 41
# 37. x_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 42
# 38. Set
#     core type: Literal
#     sub-expressions:
# 39. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 40. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 41. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 45
#     condition: 46
# 42. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 66, 47
# 43. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 58
#     end_index: 59
# 44. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 58
#     end_index: 59
# 45. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. V
#     core type: Variable
#     sub-expressions:
# 48. _a -> x_{_a}
#     core type: Lambda
#     parameter: 72
#     body: 66
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 72
#     body: 67
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 54
# 52. and
#     core type: Literal
#     sub-expressions:
# 53. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 55
# 54. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 58
#     end_index: 59
# 55. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 56. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 72
#     body: 60
# 57. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 72
#     body: 61
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. a_{_a} in K
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 67, 66
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 66. x_{_a}
#     core type: IndexedVar
# variable: 69
# index: 72
# 67. a_{_a}
#     core type: IndexedVar
# variable: 70
# index: 72
# 68. K
#     core type: Variable
#     sub-expressions:
# 69. x
#     core type: Variable
#     sub-expressions:
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 72. _a
#     core type: Variable
#     sub-expressions:
