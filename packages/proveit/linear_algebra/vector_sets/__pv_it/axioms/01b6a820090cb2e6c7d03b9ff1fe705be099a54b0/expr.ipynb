# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, V, Variable, n, x
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(x, sub_expr1), V), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array} \textrm{ if } \left(x_{1} \in V\right) \land  \left(x_{2} \in V\right) \land  \ldots \land  \left(x_{n} \in V\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#    core type: Operation
#    operator: 28
#    operands: 3
# 2. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#    core type: Operation
#    operator: 30
#    operands: 4
# 3. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#    core type: Operation
#    operator: 48
#    operands: 8
# 6. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 51
#    end_index: 52
# 8. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 66
#     body: 15
# 12. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. LinDepSets(V)
#     core type: Operation
#     operator: 18
#     operand: 44
# 14. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 15. x_{_a} in V
#     core type: Operation
#     operator: 48
#     operands: 21
# 16. Set
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. LinDepSets
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 60, 44
# 22. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 51
#     end_index: 52
# 23. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 51
#     end_index: 52
# 24. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. _a -> x_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 60
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 61
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. 0(V)
#     core type: Operation
#     operator: 38
#     operand: 44
# 34. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 51
#     end_index: 52
# 35. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 43
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. (V)
#     core type: ExprTuple
#     sub-expressions: 44
# 40. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 66
#     body: 45
# 41. or
#     core type: Literal
#     sub-expressions:
# 42. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 46
# 43. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 51
#     end_index: 52
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. a_{_a} in K
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 47. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 66
#     body: 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 61, 54
# 50. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 66
#     body: 55
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. K
#     core type: Variable
#     sub-expressions:
# 55. a_{_a} != 0
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 61, 60
# 58. !=
#     core type: Literal
#     sub-expressions:
# 59. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 60. x_{_a}
#     core type: IndexedVar
# variable: 63
# index: 66
# 61. a_{_a}
#     core type: IndexedVar
# variable: 64
# index: 66
# 62. 0
#     core type: Literal
#     sub-expressions:
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. a
#     core type: Variable
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
