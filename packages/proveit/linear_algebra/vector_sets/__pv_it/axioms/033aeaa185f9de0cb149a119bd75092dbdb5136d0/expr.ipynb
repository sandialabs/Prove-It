# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecSpaces, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, Forall, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array}\right)\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 66
#    body: 3
# 3. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])]
#    core type: Operation
#    operator: 17
#    operand: 9
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 66, 10
# 9. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 74
#    body: 12
# 10. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 76
# 11. (n)
#     core type: ExprTuple
#     sub-expressions: 74
# 12. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 76
# 15. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. n in NaturalPos
#     core type: Operation
#     operator: 70
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 74, 21
# 20. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 39\n    body: 22
# 21. NaturalPos
#     core type: Literal
#     sub-expressions:
# 22. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 23
#     condition: 24
# 23. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#     core type: Operation
#     operator: 50
#     operands: 25
# 24. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 52
#     operands: 26
# 25. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 29
# 27. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#     core type: Operation
#     operator: 70
#     operands: 30
# 28. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#     core type: Operation
#     operator: 31
#     operand: 36
# 29. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 73
#     end_index: 74
# 30. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. exists
#     core type: Literal
#     sub-expressions:
# 32. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 88
#     body: 37
# 34. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. LinDepSets(V)
#     core type: Operation
#     operator: 40
#     operand: 66
# 36. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 41\n    body: 42
# 37. x_{_a} in V
#     core type: Operation
#     operator: 70
#     operands: 43
# 38. Set
#     core type: Literal
#     sub-expressions:
# 39. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 40. LinDepSets
#     core type: Literal
#     sub-expressions:
# 41. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 46
#     condition: 47
# 43. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 82, 66
# 44. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 73
#     end_index: 74
# 45. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 73
#     end_index: 74
# 46. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. _a -> x_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 82
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 83
# 50. =
#     core type: Literal
#     sub-expressions:
# 51. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. and
#     core type: Literal
#     sub-expressions:
# 53. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. 0(V)
#     core type: Operation
#     operator: 60
#     operand: 66
# 56. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 73
#     end_index: 74
# 57. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 63
#     operands: 64
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 65
# 60. 0
#     core type: Literal
#     sub-expressions:
# 61. (V)
#     core type: ExprTuple
#     sub-expressions: 66
# 62. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 88
#     body: 67
# 63. or
#     core type: Literal
#     sub-expressions:
# 64. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 68
# 65. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 73
#     end_index: 74
# 66. V
#     core type: Variable
#     sub-expressions:
# 67. a_{_a} in K
#     core type: Operation
#     operator: 70
#     operands: 71
# 68. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 73
#     end_index: 74
# 69. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 88
#     body: 75
# 70. in
#     core type: Literal
#     sub-expressions:
# 71. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 83, 76
# 72. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 88
#     body: 77
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. n
#     core type: Variable
#     sub-expressions:
# 75. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 78
#     operands: 79
# 76. K
#     core type: Variable
#     sub-expressions:
# 77. a_{_a} != 0
#     core type: Operation
#     operator: 80
#     operands: 81
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 83, 82
# 80. !=
#     core type: Literal
#     sub-expressions:
# 81. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 82. x_{_a}
#     core type: IndexedVar
# variable: 85
# index: 88
# 83. a_{_a}
#     core type: IndexedVar
# variable: 86
# index: 88
# 84. 0
#     core type: Literal
#     sub-expressions:
# 85. x
#     core type: Variable
#     sub-expressions:
# 86. a
#     core type: Variable
#     sub-expressions:
# 87. (_a)
#     core type: ExprTuple
#     sub-expressions: 88
# 88. _a
#     core type: Variable
#     sub-expressions:
