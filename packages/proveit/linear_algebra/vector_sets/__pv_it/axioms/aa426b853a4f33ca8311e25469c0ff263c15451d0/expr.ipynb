# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, LinDepSets, SpanningSets, VecSpaces
from proveit.logic import And, Equals, Forall, InClass, InSet, NotInSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, Bases(V)), And(InSet(sub_expr1, SpanningSets(V)), NotInSet(sub_expr1, LinDepSets(V))).with_wrapping_at(2)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(V\right)\right) =  \\ \left(\begin{array}{c} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \notin \textrm{LinDepSets}\left(V\right)\right) \end{array}\right) \end{array} \end{array}\right)\end{array}\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 53
#    body: 1
# 1. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]
#    core type: Operation
#    operator: 16
#    operand: 7
# 3. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 53, 8
# 7. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 56
#    body: 10
# 8. VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. (n)
#    core type: ExprTuple
#    sub-expressions: 56
# 10. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. VecSpaces
#     core type: Literal
#     sub-expressions:
# 12. (K)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))
#     core type: Operation
#     operator: 16
#     operand: 19
# 14. n in NaturalPos
#     core type: Operation
#     operator: 42
#     operands: 18
# 15. K
#     core type: Variable
#     sub-expressions:
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 19. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 49\n    body: 21
# 20. NaturalPos
#     core type: Literal
#     sub-expressions:
# 21. {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 31
#     operands: 26
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V), ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 29
# 27. {x_{1}, x_{2}, ..., x_{n}} in Bases(V)
#     core type: Operation
#     operator: 42
#     operands: 30
# 28. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 55
#     end_index: 56
# 30. ({x_{1}, x_{2}, ..., x_{n}}, Bases(V))
#     core type: ExprTuple
#     sub-expressions: 45, 34
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 60
#     body: 37
# 34. Bases(V)
#     core type: Operation
#     operator: 38
#     operand: 53
# 35. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 42
#     operands: 39
# 36. {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. x_{_a} in V
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. Bases
#     core type: Literal
#     sub-expressions:
# 39. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 40. not-in
#     core type: Literal
#     sub-expressions:
# 41. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 57, 53
# 44. SpanningSets(V)
#     core type: Operation
#     operator: 47
#     operand: 53
# 45. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. LinDepSets(V)
#     core type: Operation
#     operator: 50
#     operand: 53
# 47. SpanningSets
#     core type: Literal
#     sub-expressions:
# 48. Set
#     core type: Literal
#     sub-expressions:
# 49. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 50. LinDepSets
#     core type: Literal
#     sub-expressions:
# 51. (V)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 53. V
#     core type: Variable
#     sub-expressions:
# 54. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 57
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. x_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
