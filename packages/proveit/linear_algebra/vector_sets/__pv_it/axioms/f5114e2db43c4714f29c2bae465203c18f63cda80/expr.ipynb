# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Span, SpanningSets, VecSpaces
from proveit.logic import Equals, Forall, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, SpanningSets(V)), Equals(V, Span(sub_expr1))), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) = \left(V = \textrm{Span}\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right)\right)\right)\end{array}\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))]]]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))]]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 48
#    body: 5
# 5. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))]
#    core type: Operation
#    operator: 20
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}}))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 48, 12
# 11. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}}))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 54
#     body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (n)
#     core type: ExprTuple
#     sub-expressions: 54
# 14. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}}))) if n in NaturalPos.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. n in NaturalPos
#     core type: Operation
#     operator: 45
#     operands: 22
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 54, 24
# 23. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 50\n    body: 25
# 24. NaturalPos
#     core type: Literal
#     sub-expressions:
# 25. {({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) = (V = Span({x_{1}, x_{2}, ..., x_{n}}))
#     core type: Operation
#     operator: 35
#     operands: 28
# 27. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), V = Span({x_{1}, x_{2}, ..., x_{n}}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 33
# 31. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 45
#     operands: 34
# 32. V = Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 53
#     end_index: 54
# 34. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 47, 38
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (V, Span({x_{1}, x_{2}, ..., x_{n}}))
#     core type: ExprTuple
#     sub-expressions: 48, 39
# 37. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 58
#     body: 40
# 38. SpanningSets(V)
#     core type: Operation
#     operator: 41
#     operand: 48
# 39. Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 43
#     operand: 47
# 40. x_{_a} in V
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. SpanningSets
#     core type: Literal
#     sub-expressions:
# 42. (V)
#     core type: ExprTuple
#     sub-expressions: 48
# 43. Span
#     core type: Literal
#     sub-expressions:
# 44. ({x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 55, 48
# 47. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. V
#     core type: Variable
#     sub-expressions:
# 49. Set
#     core type: Literal
#     sub-expressions:
# 50. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 51
# 51. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 52. _a -> x_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 55
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. x_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 56. x
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
