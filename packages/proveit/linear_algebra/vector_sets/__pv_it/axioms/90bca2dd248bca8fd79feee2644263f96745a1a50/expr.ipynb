# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, Forall, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), domain = V).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Lambda
#    parameters: 21\n   body: 4
# 4. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#    core type: Operation
#    operator: 32
#    operands: 7
# 6. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#    core type: Operation
#    operator: 34
#    operands: 8
# 7. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#    core type: Operation
#    operator: 52
#    operands: 12
# 10. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 55
#     end_index: 56
# 12. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. exists
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 70
#     body: 19
# 16. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. LinDepSets(V)
#     core type: Operation
#     operator: 22
#     operand: 48
# 18. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 19. x_{_a} in V
#     core type: Operation
#     operator: 52
#     operands: 25
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 22. LinDepSets
#     core type: Literal
#     sub-expressions:
# 23. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 64, 48
# 26. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 55
#     end_index: 56
# 27. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 55
#     end_index: 56
# 28. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. _a -> x_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 64
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 65
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. 0(V)
#     core type: Operation
#     operator: 42
#     operand: 48
# 38. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 56
# 39. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 47
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. (V)
#     core type: ExprTuple
#     sub-expressions: 48
# 44. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 70
#     body: 49
# 45. or
#     core type: Literal
#     sub-expressions:
# 46. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 50
# 47. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 55
#     end_index: 56
# 48. V
#     core type: Variable
#     sub-expressions:
# 49. a_{_a} in K
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 70
#     body: 57
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 65, 58
# 54. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 70
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. K
#     core type: Variable
#     sub-expressions:
# 59. a_{_a} != 0
#     core type: Operation
#     operator: 62
#     operands: 63
# 60. *
#     core type: Literal
#     sub-expressions:
# 61. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 65, 64
# 62. !=
#     core type: Literal
#     sub-expressions:
# 63. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 64. x_{_a}
#     core type: IndexedVar
# variable: 67
# index: 70
# 65. a_{_a}
#     core type: IndexedVar
# variable: 68
# index: 70
# 66. 0
#     core type: Literal
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. a
#     core type: Variable
#     sub-expressions:
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. _a
#     core type: Variable
#     sub-expressions:
