# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, LinDepSets, SpanningSets, VecSpaces
from proveit.logic import And, Equals, Forall, InSet, NotInSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, Bases(V)), And(InSet(sub_expr1, SpanningSets(V)), NotInSet(sub_expr1, LinDepSets(V))).with_wrapping_at(2)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(V\right)\right) =  \\ \left(\begin{array}{c} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \notin \textrm{LinDepSets}\left(V\right)\right) \end{array}\right) \end{array} \end{array}\right)\end{array}\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]]]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 57
#    body: 5
# 5. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]
#    core type: Operation
#    operator: 20
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 57, 12
# 11. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 60
#     body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (n)
#     core type: ExprTuple
#     sub-expressions: 60
# 14. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. n in NaturalPos
#     core type: Operation
#     operator: 46
#     operands: 22
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 60, 24
# 23. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 53\n    body: 25
# 24. NaturalPos
#     core type: Literal
#     sub-expressions:
# 25. {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 35
#     operands: 30
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V), ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 33
# 31. {x_{1}, x_{2}, ..., x_{n}} in Bases(V)
#     core type: Operation
#     operator: 46
#     operands: 34
# 32. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 59
#     end_index: 60
# 34. ({x_{1}, x_{2}, ..., x_{n}}, Bases(V))
#     core type: ExprTuple
#     sub-expressions: 49, 38
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 64
#     body: 41
# 38. Bases(V)
#     core type: Operation
#     operator: 42
#     operand: 57
# 39. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 46
#     operands: 43
# 40. {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. x_{_a} in V
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. Bases
#     core type: Literal
#     sub-expressions:
# 43. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 44. not-in
#     core type: Literal
#     sub-expressions:
# 45. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 61, 57
# 48. SpanningSets(V)
#     core type: Operation
#     operator: 51
#     operand: 57
# 49. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. LinDepSets(V)
#     core type: Operation
#     operator: 54
#     operand: 57
# 51. SpanningSets
#     core type: Literal
#     sub-expressions:
# 52. Set
#     core type: Literal
#     sub-expressions:
# 53. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 54. LinDepSets
#     core type: Literal
#     sub-expressions:
# 55. (V)
#     core type: ExprTuple
#     sub-expressions: 57
# 56. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 57. V
#     core type: Variable
#     sub-expressions:
# 58. _a -> x_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 61
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. n
#     core type: Variable
#     sub-expressions:
# 61. x_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
