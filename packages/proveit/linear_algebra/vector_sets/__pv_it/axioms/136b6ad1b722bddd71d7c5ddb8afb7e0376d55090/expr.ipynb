# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecSpaces, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, Forall, InClass, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array}\right)\end{array}\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 64
#    body: 1
# 1. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])]
#    core type: Operation
#    operator: 15
#    operand: 7
# 3. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 64, 8
# 7. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 72
#    body: 10
# 8. VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operand: 74
# 9. (n)
#    core type: ExprTuple
#    sub-expressions: 72
# 10. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. VecSpaces
#     core type: Literal
#     sub-expressions:
# 12. (K)
#     core type: ExprTuple
#     sub-expressions: 74
# 13. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. n in NaturalPos
#     core type: Operation
#     operator: 68
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 72, 19
# 18. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 37\n    body: 20
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#     core type: Operation
#     operator: 48
#     operands: 23
# 22. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 50
#     operands: 24
# 23. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 27
# 25. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#     core type: Operation
#     operator: 68
#     operands: 28
# 26. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#     core type: Operation
#     operator: 29
#     operand: 34
# 27. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 71
#     end_index: 72
# 28. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. exists
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 86
#     body: 35
# 32. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. LinDepSets(V)
#     core type: Operation
#     operator: 38
#     operand: 64
# 34. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 39\n    body: 40
# 35. x_{_a} in V
#     core type: Operation
#     operator: 68
#     operands: 41
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. LinDepSets
#     core type: Literal
#     sub-expressions:
# 39. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 40. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 44
#     condition: 45
# 41. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 80, 64
# 42. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 71
#     end_index: 72
# 43. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 71
#     end_index: 72
# 44. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. _a -> x_{_a}
#     core type: Lambda
#     parameter: 86
#     body: 80
# 47. _a -> a_{_a}
#     core type: Lambda
#     parameter: 86
#     body: 81
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. and
#     core type: Literal
#     sub-expressions:
# 51. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. 0(V)
#     core type: Operation
#     operator: 58
#     operand: 64
# 54. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 71
#     end_index: 72
# 55. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 61
#     operands: 62
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 63
# 58. 0
#     core type: Literal
#     sub-expressions:
# 59. (V)
#     core type: ExprTuple
#     sub-expressions: 64
# 60. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 86
#     body: 65
# 61. or
#     core type: Literal
#     sub-expressions:
# 62. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 66
# 63. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 71
#     end_index: 72
# 64. V
#     core type: Variable
#     sub-expressions:
# 65. a_{_a} in K
#     core type: Operation
#     operator: 68
#     operands: 69
# 66. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 71
#     end_index: 72
# 67. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 86
#     body: 73
# 68. in
#     core type: Literal
#     sub-expressions:
# 69. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 81, 74
# 70. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 86
#     body: 75
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. n
#     core type: Variable
#     sub-expressions:
# 73. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 74. K
#     core type: Variable
#     sub-expressions:
# 75. a_{_a} != 0
#     core type: Operation
#     operator: 78
#     operands: 79
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 81, 80
# 78. !=
#     core type: Literal
#     sub-expressions:
# 79. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 80. x_{_a}
#     core type: IndexedVar
# variable: 83
# index: 86
# 81. a_{_a}
#     core type: IndexedVar
# variable: 84
# index: 86
# 82. 0
#     core type: Literal
#     sub-expressions:
# 83. x
#     core type: Variable
#     sub-expressions:
# 84. a
#     core type: Variable
#     sub-expressions:
# 85. (_a)
#     core type: ExprTuple
#     sub-expressions: 86
# 86. _a
#     core type: Variable
#     sub-expressions:
