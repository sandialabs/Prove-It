# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import Span, lin_comb_axn
from proveit.logic import Equals, Forall, InSet, Set, SetOfAll
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(Span(Set(x_1_to_n)), SetOfAll(instance_param_or_params = [a_1_to_n], instance_element = lin_comb_axn, domain = K)).with_wrapping_at(2), domain = V).with_wrapping(), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \textrm{Span}\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) =  \\ \left\{\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right\}_{a_{1}, a_{2}, \ldots, a_{n} \in K} \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 46, 7
# 6. (x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Lambda
#    parameters: 26\n   body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 39
#     operands: 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Span({x_{1}, x_{2}, ..., x_{n}}), {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 17
#     operand: 22
# 15. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 45
#     end_index: 46
# 17. Span
#     core type: Literal
#     sub-expressions:
# 18. ({x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. SetOfAll
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 59
#     body: 24
# 22. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 27\n    body: 28
# 24. x_{_a} in V
#     core type: Operation
#     operator: 51
#     operands: 29
# 25. Set
#     core type: Literal
#     sub-expressions:
# 26. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 27. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 32
#     condition: 33
# 29. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 53, 34
# 30. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 45
#     end_index: 46
# 31. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 45
#     end_index: 46
# 32. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. V
#     core type: Variable
#     sub-expressions:
# 35. _a -> x_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 53
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 54
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 41
# 39. and
#     core type: Literal
#     sub-expressions:
# 40. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 42
# 41. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 45
#     end_index: 46
# 42. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 43. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 59
#     body: 47
# 44. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 59
#     body: 48
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. a_{_a} in K
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 53. x_{_a}
#     core type: IndexedVar
# variable: 56
# index: 59
# 54. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 55. K
#     core type: Variable
#     sub-expressions:
# 56. x
#     core type: Variable
#     sub-expressions:
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
