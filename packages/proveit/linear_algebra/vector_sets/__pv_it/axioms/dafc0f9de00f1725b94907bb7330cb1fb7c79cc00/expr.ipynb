# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, Forall, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), domain = V).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 62
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 62
# 2. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 58
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 62, 9
# 8. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#    core type: Lambda
#    parameters: 27\n   body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#     core type: Operation
#     operator: 38
#     operands: 13
# 12. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 40
#     operands: 14
# 13. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 17
# 15. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#     core type: Operation
#     operator: 58
#     operands: 18
# 16. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 61
#     end_index: 62
# 18. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. exists
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 25
# 22. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. LinDepSets(V)
#     core type: Operation
#     operator: 28
#     operand: 54
# 24. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 29\n    body: 30
# 25. x_{_a} in V
#     core type: Operation
#     operator: 58
#     operands: 31
# 26. Set
#     core type: Literal
#     sub-expressions:
# 27. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. LinDepSets
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 34
#     condition: 35
# 31. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 70, 54
# 32. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 61
#     end_index: 62
# 33. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 61
#     end_index: 62
# 34. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. _a -> x_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 70
# 37. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 71
# 38. =
#     core type: Literal
#     sub-expressions:
# 39. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. 0(V)
#     core type: Operation
#     operator: 48
#     operand: 54
# 44. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 61
#     end_index: 62
# 45. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 53
# 48. 0
#     core type: Literal
#     sub-expressions:
# 49. (V)
#     core type: ExprTuple
#     sub-expressions: 54
# 50. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 76
#     body: 55
# 51. or
#     core type: Literal
#     sub-expressions:
# 52. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 56
# 53. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 61
#     end_index: 62
# 54. V
#     core type: Variable
#     sub-expressions:
# 55. a_{_a} in K
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 61
#     end_index: 62
# 57. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 76
#     body: 63
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 71, 64
# 60. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 76
#     body: 65
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. n
#     core type: Variable
#     sub-expressions:
# 63. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 66
#     operands: 67
# 64. K
#     core type: Variable
#     sub-expressions:
# 65. a_{_a} != 0
#     core type: Operation
#     operator: 68
#     operands: 69
# 66. *
#     core type: Literal
#     sub-expressions:
# 67. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 71, 70
# 68. !=
#     core type: Literal
#     sub-expressions:
# 69. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 70. x_{_a}
#     core type: IndexedVar
# variable: 73
# index: 76
# 71. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 76
# 72. 0
#     core type: Literal
#     sub-expressions:
# 73. x
#     core type: Variable
#     sub-expressions:
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 76. _a
#     core type: Variable
#     sub-expressions:
