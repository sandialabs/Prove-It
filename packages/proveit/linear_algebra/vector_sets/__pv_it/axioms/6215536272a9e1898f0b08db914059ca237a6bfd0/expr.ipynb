# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, LinDepSets, SpanningSets, VecSpaces
from proveit.logic import And, Equals, Forall, InSet, NotInSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, Bases(V)), And(InSet(sub_expr1, SpanningSets(V)), NotInSet(sub_expr1, LinDepSets(V))).with_wrapping_at(2)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(V\right)\right) =  \\ \left(\begin{array}{c} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \notin \textrm{LinDepSets}\left(V\right)\right) \end{array}\right) \end{array} \end{array}\right)\end{array}\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]]]
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]]
#    core type: Operation
#    operator: 19
#    operand: 3
# 2. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 56
#    body: 4
# 4. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]
#    core type: Operation
#    operator: 19
#    operand: 10
# 6. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 56, 11
# 10. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 59
#     body: 13
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. (n)
#     core type: ExprTuple
#     sub-expressions: 59
# 13. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. VecSpaces
#     core type: Literal
#     sub-expressions:
# 15. (K)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))
#     core type: Operation
#     operator: 19
#     operand: 22
# 17. n in NaturalPos
#     core type: Operation
#     operator: 45
#     operands: 21
# 18. K
#     core type: Variable
#     sub-expressions:
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 59, 23
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 52\n    body: 24
# 23. NaturalPos
#     core type: Literal
#     sub-expressions:
# 24. {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 25
#     condition: 26
# 25. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 34
#     operands: 29
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V), ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 32
# 30. {x_{1}, x_{2}, ..., x_{n}} in Bases(V)
#     core type: Operation
#     operator: 45
#     operands: 33
# 31. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 58
#     end_index: 59
# 33. ({x_{1}, x_{2}, ..., x_{n}}, Bases(V))
#     core type: ExprTuple
#     sub-expressions: 48, 37
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 63
#     body: 40
# 37. Bases(V)
#     core type: Operation
#     operator: 41
#     operand: 56
# 38. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 45
#     operands: 42
# 39. {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. x_{_a} in V
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. Bases
#     core type: Literal
#     sub-expressions:
# 42. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 43. not-in
#     core type: Literal
#     sub-expressions:
# 44. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 60, 56
# 47. SpanningSets(V)
#     core type: Operation
#     operator: 50
#     operand: 56
# 48. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. LinDepSets(V)
#     core type: Operation
#     operator: 53
#     operand: 56
# 50. SpanningSets
#     core type: Literal
#     sub-expressions:
# 51. Set
#     core type: Literal
#     sub-expressions:
# 52. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 55
# 53. LinDepSets
#     core type: Literal
#     sub-expressions:
# 54. (V)
#     core type: ExprTuple
#     sub-expressions: 56
# 55. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 56. V
#     core type: Variable
#     sub-expressions:
# 57. _a -> x_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 60
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. x_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
