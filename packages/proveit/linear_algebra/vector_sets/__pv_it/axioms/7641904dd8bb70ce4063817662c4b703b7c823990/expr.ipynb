# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import V, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, LinDepSets, SpanningSets
from proveit.logic import And, Equals, Forall, InSet, NotInSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, Bases(V)), And(InSet(sub_expr1, SpanningSets(V)), NotInSet(sub_expr1, LinDepSets(V))).with_wrapping_at(2)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(V\right)\right) =  \\ \left(\begin{array}{c} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{SpanningSets}\left(V\right)\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \notin \textrm{LinDepSets}\left(V\right)\right) \end{array}\right) \end{array} \end{array}\right)\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 47
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 47
# 4. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 47, 11
# 10. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 40\n    body: 12
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. {({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 22
#     operands: 17
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ({x_{1}, x_{2}, ..., x_{n}} in Bases(V), ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 20
# 18. {x_{1}, x_{2}, ..., x_{n}} in Bases(V)
#     core type: Operation
#     operator: 33
#     operands: 21
# 19. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)) and  \\ ({x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 46
#     end_index: 47
# 21. ({x_{1}, x_{2}, ..., x_{n}}, Bases(V))
#     core type: ExprTuple
#     sub-expressions: 36, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ({x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V), {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 51
#     body: 28
# 25. Bases(V)
#     core type: Operation
#     operator: 29
#     operand: 44
# 26. {x_{1}, x_{2}, ..., x_{n}} in SpanningSets(V)
#     core type: Operation
#     operator: 33
#     operands: 30
# 27. {x_{1}, x_{2}, ..., x_{n}} not-in LinDepSets(V)
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. x_{_a} in V
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. Bases
#     core type: Literal
#     sub-expressions:
# 30. ({x_{1}, x_{2}, ..., x_{n}}, SpanningSets(V))
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 31. not-in
#     core type: Literal
#     sub-expressions:
# 32. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 48, 44
# 35. SpanningSets(V)
#     core type: Operation
#     operator: 38
#     operand: 44
# 36. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. LinDepSets(V)
#     core type: Operation
#     operator: 41
#     operand: 44
# 38. SpanningSets
#     core type: Literal
#     sub-expressions:
# 39. Set
#     core type: Literal
#     sub-expressions:
# 40. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. LinDepSets
#     core type: Literal
#     sub-expressions:
# 42. (V)
#     core type: ExprTuple
#     sub-expressions: 44
# 43. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. _a -> x_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 48
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. x_{_a}
#     core type: IndexedVar
# variable: 49
# index: 51
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. (_a)
#     core type: ExprTuple
#     sub-expressions: 51
# 51. _a
#     core type: Variable
#     sub-expressions:
