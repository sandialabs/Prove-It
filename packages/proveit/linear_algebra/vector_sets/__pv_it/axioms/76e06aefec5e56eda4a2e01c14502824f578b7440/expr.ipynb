# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import LinDepSets, VecSpaces, VecZero, lin_comb_axn, some_nonzero_a
from proveit.logic import Equals, Exists, Forall, InClass, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(Set(x_1_to_n), LinDepSets(V)), Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(lin_comb_axn, VecZero(V)), domain = K, condition = some_nonzero_a).with_wrapping()).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{LinDepSets}\left(V\right)\right) =  \\ \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in K~|~\left(a_{1} \neq 0\right) \lor  \left(a_{2} \neq 0\right) \lor  \ldots \lor  \left(a_{n} \neq 0\right)}~\\
# \left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) = \vec{0}\left(V\right)\right)\end{array}\right] \end{array} \end{array}\right)\end{array}\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])]
#    core type: Operation
#    operator: 14
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 63, 7
# 6. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 71
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 73
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 71
# 9. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]) if n in NaturalPos.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 73
# 12. forall_{x_{1}, x_{2}, ..., x_{n} in V} (({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))])
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. n in NaturalPos
#     core type: Operation
#     operator: 67
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 71, 18
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 36\n    body: 19
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. {({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))] if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 20
#     condition: 21
# 20. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)) =  \\ [exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))]
#     core type: Operation
#     operator: 47
#     operands: 22
# 21. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 49
#     operands: 23
# 22. ({x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V), exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. {x_{1}, x_{2}, ..., x_{n}} in LinDepSets(V)
#     core type: Operation
#     operator: 67
#     operands: 27
# 25. exists_{a_{1}, a_{2}, ..., a_{n} in K | (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V))
#     core type: Operation
#     operator: 28
#     operand: 33
# 26. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 70
#     end_index: 71
# 27. ({x_{1}, x_{2}, ..., x_{n}}, LinDepSets(V))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. exists
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 85
#     body: 34
# 31. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. LinDepSets(V)
#     core type: Operation
#     operator: 37
#     operand: 63
# 33. (a_{1}, a_{2}, ..., a_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Lambda
#     parameters: 38\n    body: 39
# 34. x_{_a} in V
#     core type: Operation
#     operator: 67
#     operands: 40
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. LinDepSets
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 39. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V) if (a_{1} in K) ,  (a_{2} in K) ,  ... ,  (a_{n} in K) ,  (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0).
#     core type: Conditional
#     value: 43
#     condition: 44
# 40. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 79, 63
# 41. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 70
#     end_index: 71
# 42. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 70
#     end_index: 71
# 43. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) = 0(V)
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K) and ((a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. _a -> x_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 79
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 80
# 47. =
#     core type: Literal
#     sub-expressions:
# 48. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), 0(V))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. and
#     core type: Literal
#     sub-expressions:
# 50. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K), (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. 0(V)
#     core type: Operation
#     operator: 57
#     operand: 63
# 53. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 70
#     end_index: 71
# 54. (a_{1} != 0) or  (a_{2} != 0) or  ... or  (a_{n} != 0)
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 62
# 57. 0
#     core type: Literal
#     sub-expressions:
# 58. (V)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 85
#     body: 64
# 60. or
#     core type: Literal
#     sub-expressions:
# 61. ((a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 65
# 62. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 70
#     end_index: 71
# 63. V
#     core type: Variable
#     sub-expressions:
# 64. a_{_a} in K
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. (a_{1} != 0), (a_{2} != 0), ..., (a_{n} != 0)
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 70
#     end_index: 71
# 66. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 85
#     body: 72
# 67. in
#     core type: Literal
#     sub-expressions:
# 68. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 80, 73
# 69. _a -> (a_{_a} != 0)
#     core type: Lambda
#     parameter: 85
#     body: 74
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 75
#     operands: 76
# 73. K
#     core type: Variable
#     sub-expressions:
# 74. a_{_a} != 0
#     core type: Operation
#     operator: 77
#     operands: 78
# 75. *
#     core type: Literal
#     sub-expressions:
# 76. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 80, 79
# 77. !=
#     core type: Literal
#     sub-expressions:
# 78. (a_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 79. x_{_a}
#     core type: IndexedVar
# variable: 82
# index: 85
# 80. a_{_a}
#     core type: IndexedVar
# variable: 83
# index: 85
# 81. 0
#     core type: Literal
#     sub-expressions:
# 82. x
#     core type: Variable
#     sub-expressions:
# 83. a
#     core type: Variable
#     sub-expressions:
# 84. (_a)
#     core type: ExprTuple
#     sub-expressions: 85
# 85. _a
#     core type: Variable
#     sub-expressions:
