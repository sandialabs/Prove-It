# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import Span, VecSpaces, lin_comb_axn
from proveit.logic import Equals, Forall, Set, SetOfAll
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(Span(Set(x_1_to_n)), SetOfAll(instance_param_or_params = [a_1_to_n], instance_element = lin_comb_axn, domain = K)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \textrm{Span}\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) =  \\ \left\{\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right\}_{a_{1}, a_{2}, \ldots, a_{n} \in K} \end{array} \end{array}\right)\end{array}\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]]
#    core type: Lambda
#    parameter: 72
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 51
#    body: 6
# 5. (V)
#    core type: ExprTuple
#    sub-expressions: 51
# 6. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]
#    core type: Operation
#    operator: 20
#    operand: 12
# 8. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 51, 13
# 12. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#     core type: Lambda
#     parameter: 63
#     body: 15
# 13. VecSpaces(K)
#     core type: Operation
#     operator: 16
#     operand: 72
# 14. (n)
#     core type: ExprTuple
#     sub-expressions: 63
# 15. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. VecSpaces
#     core type: Literal
#     sub-expressions:
# 17. (K)
#     core type: ExprTuple
#     sub-expressions: 72
# 18. forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: Operation
#     operator: 20
#     operand: 23
# 19. n in NaturalPos
#     core type: Operation
#     operator: 68
#     operands: 22
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 63, 24
# 23. (x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 43\n    body: 25
# 24. NaturalPos
#     core type: Literal
#     sub-expressions:
# 25. {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 56
#     operands: 30
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (Span({x_{1}, x_{2}, ..., x_{n}}), {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 33
# 31. Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 34
#     operand: 39
# 32. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 36
#     operand: 40
# 33. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 62
#     end_index: 63
# 34. Span
#     core type: Literal
#     sub-expressions:
# 35. ({x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. SetOfAll
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 41
# 39. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. (a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 44\n    body: 45
# 41. x_{_a} in V
#     core type: Operation
#     operator: 68
#     operands: 46
# 42. Set
#     core type: Literal
#     sub-expressions:
# 43. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 49
#     condition: 50
# 46. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 70, 51
# 47. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 62
#     end_index: 63
# 48. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 62
#     end_index: 63
# 49. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. V
#     core type: Variable
#     sub-expressions:
# 52. _a -> x_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 70
# 53. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 71
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 58
# 56. and
#     core type: Literal
#     sub-expressions:
# 57. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 59
# 58. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 62
#     end_index: 63
# 59. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 60. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 76
#     body: 64
# 61. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 76
#     body: 65
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 66
#     operands: 67
# 65. a_{_a} in K
#     core type: Operation
#     operator: 68
#     operands: 69
# 66. *
#     core type: Literal
#     sub-expressions:
# 67. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 71, 70
# 68. in
#     core type: Literal
#     sub-expressions:
# 69. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 70. x_{_a}
#     core type: IndexedVar
# variable: 73
# index: 76
# 71. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 76
# 72. K
#     core type: Variable
#     sub-expressions:
# 73. x
#     core type: Variable
#     sub-expressions:
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 76. _a
#     core type: Variable
#     sub-expressions:
