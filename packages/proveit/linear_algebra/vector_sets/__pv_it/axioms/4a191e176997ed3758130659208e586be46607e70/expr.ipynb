# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.vector_sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import Span, VecSpaces, lin_comb_axn
from proveit.logic import Equals, Forall, Set, SetOfAll
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(Span(Set(x_1_to_n)), SetOfAll(instance_param_or_params = [a_1_to_n], instance_element = lin_comb_axn, domain = K)).with_wrapping_at(2), domain = V).with_wrapping(), domain = NaturalPos), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\\
# \left(\begin{array}{c} \begin{array}{l} \textrm{Span}\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) =  \\ \left\{\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right\}_{a_{1}, a_{2}, \ldots, a_{n} \in K} \end{array} \end{array}\right)\end{array}\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]]
#    core type: Operation
#    operator: 21
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]]
#    core type: Lambda
#    parameter: 73
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]]
#    core type: Operation
#    operator: 21
#    operand: 5
# 4. (V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 52
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 52
# 7. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})]
#    core type: Operation
#    operator: 21
#    operand: 13
# 9. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 52, 14
# 13. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#     core type: Lambda
#     parameter: 64
#     body: 16
# 14. VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operand: 73
# 15. (n)
#     core type: ExprTuple
#     sub-expressions: 64
# 16. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}) if n in NaturalPos.
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. VecSpaces
#     core type: Literal
#     sub-expressions:
# 18. (K)
#     core type: ExprTuple
#     sub-expressions: 73
# 19. forall_{x_{1}, x_{2}, ..., x_{n} in V} (Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. n in NaturalPos
#     core type: Operation
#     operator: 69
#     operands: 23
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 64, 25
# 24. (x_{1}, x_{2}, ..., x_{n}) -> {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 44\n    body: 26
# 25. NaturalPos
#     core type: Literal
#     sub-expressions:
# 26. {Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K} if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 27
#     condition: 28
# 27. Span({x_{1}, x_{2}, ..., x_{n}}) =  \\ {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 57
#     operands: 31
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (Span({x_{1}, x_{2}, ..., x_{n}}), {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 34
# 32. Span({x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 35
#     operand: 40
# 33. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})}_{a_{1}, a_{2}, ..., a_{n} in K}
#     core type: Operation
#     operator: 37
#     operand: 41
# 34. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 63
#     end_index: 64
# 35. Span
#     core type: Literal
#     sub-expressions:
# 36. ({x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. SetOfAll
#     core type: Literal
#     sub-expressions:
# 38. ((a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 77
#     body: 42
# 40. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (a_{1}, a_{2}, ..., a_{n}) -> {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 45\n    body: 46
# 42. x_{_a} in V
#     core type: Operation
#     operator: 69
#     operands: 47
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 49
# 46. {(a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 50
#     condition: 51
# 47. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 71, 52
# 48. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 63
#     end_index: 64
# 49. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 63
#     end_index: 64
# 50. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. V
#     core type: Variable
#     sub-expressions:
# 53. _a -> x_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 71
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 72
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 59
# 57. and
#     core type: Literal
#     sub-expressions:
# 58. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 60
# 59. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 63
#     end_index: 64
# 60. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 63
#     end_index: 64
# 61. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 77
#     body: 65
# 62. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 77
#     body: 66
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 67
#     operands: 68
# 66. a_{_a} in K
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 72, 71
# 69. in
#     core type: Literal
#     sub-expressions:
# 70. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 71. x_{_a}
#     core type: IndexedVar
# variable: 74
# index: 77
# 72. a_{_a}
#     core type: IndexedVar
# variable: 75
# index: 77
# 73. K
#     core type: Variable
#     sub-expressions:
# 74. x
#     core type: Variable
#     sub-expressions:
# 75. a
#     core type: Variable
#     sub-expressions:
# 76. (_a)
#     core type: ExprTuple
#     sub-expressions: 77
# 77. _a
#     core type: Variable
#     sub-expressions:
