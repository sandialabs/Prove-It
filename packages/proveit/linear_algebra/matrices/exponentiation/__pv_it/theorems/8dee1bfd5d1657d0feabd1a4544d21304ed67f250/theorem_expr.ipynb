# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unital2pi_eigen_exp_application">unital2pi_eigen_exp_application</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.matrices.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.matrices.exponentiation import unital2pi_eigen_exp_application

# %%
# check that the built expression is the same as the stored expression
assert unital2pi_eigen_exp_application.expr == stored_expr
assert unital2pi_eigen_exp_application.expr._style_id == stored_expr._style_id
print("Passed sanity check: unital2pi_eigen_exp_application matches stored_expr")
# Out:
# Passed sanity check: unital2pi_eigen_exp_application matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{\rho \in \mathbb{R}}~\left[\forall_{A, x~|~\left(A \thinspace x\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \rho} \cdot x\right)}~\left(\left(A^{m} \thinspace x\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(m \cdot \rho\right)} \cdot x\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{rho in Real} [forall_{A, x | (A . x) = (e^{2 * pi * i * rho} * x)} ((A^{m} . x) = (e^{2 * pi * i * (m * rho)} * x))]]
#    core type: Operation
#    operator: 15
#    operand: 2
# 1. (m -> {forall_{rho in Real} [forall_{A, x | (A . x) = (e^{2 * pi * i * rho} * x)} ((A^{m} . x) = (e^{2 * pi * i * (m * rho)} * x))] if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{rho in Real} [forall_{A, x | (A . x) = (e^{2 * pi * i * rho} * x)} ((A^{m} . x) = (e^{2 * pi * i * (m * rho)} * x))] if m in NaturalPos.
#    core type: Lambda
#    parameter: 58
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 58
# 4. {forall_{rho in Real} [forall_{A, x | (A . x) = (e^{2 * pi * i * rho} * x)} ((A^{m} . x) = (e^{2 * pi * i * (m * rho)} * x))] if m in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
