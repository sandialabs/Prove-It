# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import H, v, w
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, InnerProd, OrthoNormBases
from proveit.logic import And, Equals, Forall, InSet, Set
from proveit.numbers import KroneckerDelta

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, OrthoNormBases(H)), And(InSet(sub_expr1, Bases(H)), Forall(instance_param_or_params = [v, w], instance_expr = Equals(InnerProd(v, w), KroneckerDelta(v, w)), domain = sub_expr1))).with_wrapping_at(2), domain = H)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x_{1}, x_{2}, \ldots, x_{n} \in H}~\left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) =  \\ \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(H\right)\right) \land \left[\forall_{v, w \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}}~\left(\left \langle v, w\right \rangle = \delta_{v, w}\right)\right]\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#    core type: Lambda
#    parameters: 49\n   body: 3
# 3. {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#    core type: Operation
#    operator: 31
#    operands: 6
# 5. (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H)
#    core type: Operation
#    operator: 33
#    operands: 7
# 6. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H), ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ((x_{1} in H), (x_{2} in H), ..., (x_{n} in H))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 43
#    operands: 11
# 9. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]
#    core type: Operation
#    operator: 33
#    operands: 12
# 10. (x_{1} in H), (x_{2} in H), ..., (x_{n} in H)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 52
#     end_index: 53
# 11. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 47, 14
# 12. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H), forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. _a -> (x_{_a} in H)
#     core type: Lambda
#     parameter: 57
#     body: 17
# 14. O.N.Bases(H)
#     core type: Operation
#     operator: 18
#     operand: 28
# 15. {x_{1}, x_{2}, ..., x_{n}} in Bases(H)
#     core type: Operation
#     operator: 43
#     operands: 19
# 16. forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})
#     core type: Operation
#     operator: 20
#     operand: 24
# 17. x_{_a} in H
#     core type: Operation
#     operator: 43
#     operands: 22
# 18. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 19. ({x_{1}, x_{2}, ..., x_{n}}, Bases(H))
#     core type: ExprTuple
#     sub-expressions: 47, 23
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. (x_{_a}, H)
#     core type: ExprTuple
#     sub-expressions: 54, 28
# 23. Bases(H)
#     core type: Operation
#     operator: 25
#     operand: 28
# 24. (v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Lambda
#     parameters: 41\n    body: 27
# 25. Bases
#     core type: Literal
#     sub-expressions:
# 26. (H)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. H
#     core type: Variable
#     sub-expressions:
# 29. <v, w> = delta_{v, w}
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (v in {x_{1}, x_{2}, ..., x_{n}}) and (w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (<v, w>, delta_{v, w})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. (v in {x_{1}, x_{2}, ..., x_{n}}, w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. <v, w>
#     core type: Operation
#     operator: 39
#     operands: 41
# 36. delta_{v, w}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 43
#     operands: 42
# 38. w in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. InnerProd
#     core type: Literal
#     sub-expressions:
# 40. Kdelta
#     core type: Literal
#     sub-expressions:
# 41. (v, w)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 45, 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (w, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. v
#     core type: Variable
#     sub-expressions:
# 46. w
#     core type: Variable
#     sub-expressions:
# 47. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 48. Set
#     core type: Literal
#     sub-expressions:
# 49. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 50
# 50. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 51. _a -> x_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. n
#     core type: Variable
#     sub-expressions:
# 54. x_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. x
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
