# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, Py, X, x, y
from proveit.linear_algebra import HilbertSpaces, Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies, SubsetEq
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [Hspace, X], instance_expr = Forall(instance_param_or_params = [P], instance_expr = Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = SubsetEq(X, Hspace))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\mathcal{H}, X \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~X \subseteq \mathcal{H}}~\left[\forall_{P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H, X in_c HilbertSpaces | X subset_eq H} [forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]))]
#    core type: Operation
#    operator: 54
#    operand: 2
# 1. ((H, X) -> {forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])) if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (H, X) -> {forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])) if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  X subset_eq H.
#    core type: Lambda
#    parameters: 37\n   body: 3
# 3. {forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])) if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  X subset_eq H.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]))
#    core type: Operation
#    operator: 54
#    operand: 8
# 5. (H in_c HilbertSpaces) and (X in_c HilbertSpaces) and (X subset_eq H)
#    core type: Operation
#    operator: 29
#    operands: 7
# 6. (P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (H in_c HilbertSpaces, X in_c HilbertSpaces, X subset_eq H)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Lambda
#    parameter: 62
#    body: 13
# 9. H in_c HilbertSpaces
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. X in_c HilbertSpaces
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. X subset_eq H
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (P)
#     core type: ExprTuple
#     sub-expressions: 62
# 13. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#     core type: Conditional
#     value: 19
#     condition: 20
# 14. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 68, 21
# 15. in_c
#     core type: Literal
#     sub-expressions:
# 16. (X, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 75, 21
# 17. subset_eq
#     core type: Literal
#     sub-expressions:
# 18. (X, H)
#     core type: ExprTuple
#     sub-expressions: 75, 68
# 19. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. P in LINMAP(H, H)
#     core type: Operation
#     operator: 71
#     operands: 24
# 21. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 22. <=>
#     core type: Literal
#     sub-expressions:
# 23. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. (P, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 62, 27
# 25. P = OrthoProj(H, X)
#     core type: Operation
#     operator: 69
#     operands: 28
# 26. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. LINMAP(H, H)
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (P, OrthoProj(H, X))
#     core type: ExprTuple
#     sub-expressions: 62, 33
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. LINMAP
#     core type: Literal
#     sub-expressions:
# 32. (H, H)
#     core type: ExprTuple
#     sub-expressions: 68, 68
# 33. OrthoProj(H, X)
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 54
#     operand: 40
# 35. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 54
#     operand: 41
# 36. OrthoProj
#     core type: Literal
#     sub-expressions:
# 37. (H, X)
#     core type: ExprTuple
#     sub-expressions: 68, 75
# 38. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 40
# 39. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 78
#     body: 42
# 41. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 79
#     body: 43
# 42. {P(x) = x if x in X.
#     core type: Conditional
#     value: 44
#     condition: 67
# 43. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. P(x) = x
#     core type: Operation
#     operator: 69
#     operands: 47
# 45. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. y in H
#     core type: Operation
#     operator: 71
#     operands: 50
# 47. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 51, 78
# 48. =>
#     core type: Literal
#     sub-expressions:
# 49. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. (y, H)
#     core type: ExprTuple
#     sub-expressions: 79, 68
# 51. P(x)
#     core type: Operation
#     operator: 62
#     operand: 78
# 52. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 54
#     operand: 57
# 53. P(y) = 0(H)
#     core type: Operation
#     operator: 69
#     operands: 56
# 54. forall
#     core type: Literal
#     sub-expressions:
# 55. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 57
# 56. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 57. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 78
#     body: 61
# 58. P(y)
#     core type: Operation
#     operator: 62
#     operand: 79
# 59. 0(H)
#     core type: Operation
#     operator: 64
#     operand: 68
# 60. (x)
#     core type: ExprTuple
#     sub-expressions: 78
# 61. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 66
#     condition: 67
# 62. P
#     core type: Variable
#     sub-expressions:
# 63. (y)
#     core type: ExprTuple
#     sub-expressions: 79
# 64. 0
#     core type: Literal
#     sub-expressions:
# 65. (H)
#     core type: ExprTuple
#     sub-expressions: 68
# 66. <x, y> = 0
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. x in X
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. H
#     core type: Variable
#     sub-expressions:
# 69. =
#     core type: Literal
#     sub-expressions:
# 70. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 71. in
#     core type: Literal
#     sub-expressions:
# 72. (x, X)
#     core type: ExprTuple
#     sub-expressions: 78, 75
# 73. <x, y>
#     core type: Operation
#     operator: 76
#     operands: 77
# 74. 0
#     core type: Literal
#     sub-expressions:
# 75. X
#     core type: Variable
#     sub-expressions:
# 76. InnerProd
#     core type: Literal
#     sub-expressions:
# 77. (x, y)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 78. x
#     core type: Variable
#     sub-expressions:
# 79. y
#     core type: Variable
#     sub-expressions:
