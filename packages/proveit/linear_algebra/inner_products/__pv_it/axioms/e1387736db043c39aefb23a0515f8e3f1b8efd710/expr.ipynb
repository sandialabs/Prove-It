# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, H, K, Lambda, n, v, w
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, InnerProd, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Forall, InClass, InSet, Set
from proveit.numbers import KroneckerDelta, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Lambda(H, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, OrthoNormBases(H)), And(InSet(sub_expr1, Bases(H)), Forall(instance_param_or_params = [v, w], instance_expr = Equals(InnerProd(v, w), KroneckerDelta(v, w)), domain = sub_expr1))).with_wrapping_at(2), domain = H), domain = NaturalPos), InClass(H, InnerProdSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# H \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in H}~\left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) =  \\ \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(H\right)\right) \land \left[\forall_{v, w \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}}~\left(\left \langle v, w\right \rangle = \delta_{v, w}\right)\right]\right) \end{array} \end{array}\right)\right] \textrm{ if } H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Lambda
#    parameter: 45
#    body: 1
# 1. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]
#    core type: Operation
#    operator: 37
#    operand: 7
# 3. H in_c InnerProdSpaces(K)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. (H, InnerProdSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 45, 8
# 7. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#    core type: Lambda
#    parameter: 70
#    body: 10
# 8. InnerProdSpaces(K)
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. (n)
#    core type: ExprTuple
#    sub-expressions: 70
# 10. {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 12. (K)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))
#     core type: Operation
#     operator: 37
#     operand: 18
# 14. n in NaturalPos
#     core type: Operation
#     operator: 60
#     operands: 17
# 15. K
#     core type: Variable
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 70, 19
# 18. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Lambda
#     parameters: 66\n    body: 20
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: Operation
#     operator: 48
#     operands: 23
# 22. (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H)
#     core type: Operation
#     operator: 50
#     operands: 24
# 23. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H), ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. ((x_{1} in H), (x_{2} in H), ..., (x_{n} in H))
#     core type: ExprTuple
#     sub-expressions: 27
# 25. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 60
#     operands: 28
# 26. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]
#     core type: Operation
#     operator: 50
#     operands: 29
# 27. (x_{1} in H), (x_{2} in H), ..., (x_{n} in H)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 69
#     end_index: 70
# 28. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 64, 31
# 29. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H), forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. _a -> (x_{_a} in H)
#     core type: Lambda
#     parameter: 74
#     body: 34
# 31. O.N.Bases(H)
#     core type: Operation
#     operator: 35
#     operand: 45
# 32. {x_{1}, x_{2}, ..., x_{n}} in Bases(H)
#     core type: Operation
#     operator: 60
#     operands: 36
# 33. forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})
#     core type: Operation
#     operator: 37
#     operand: 41
# 34. x_{_a} in H
#     core type: Operation
#     operator: 60
#     operands: 39
# 35. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 36. ({x_{1}, x_{2}, ..., x_{n}}, Bases(H))
#     core type: ExprTuple
#     sub-expressions: 64, 40
# 37. forall
#     core type: Literal
#     sub-expressions:
# 38. ((v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. (x_{_a}, H)
#     core type: ExprTuple
#     sub-expressions: 71, 45
# 40. Bases(H)
#     core type: Operation
#     operator: 42
#     operand: 45
# 41. (v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Lambda
#     parameters: 58\n    body: 44
# 42. Bases
#     core type: Literal
#     sub-expressions:
# 43. (H)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 45. H
#     core type: Variable
#     sub-expressions:
# 46. <v, w> = delta_{v, w}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. (v in {x_{1}, x_{2}, ..., x_{n}}) and (w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (<v, w>, delta_{v, w})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. and
#     core type: Literal
#     sub-expressions:
# 51. (v in {x_{1}, x_{2}, ..., x_{n}}, w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. <v, w>
#     core type: Operation
#     operator: 56
#     operands: 58
# 53. delta_{v, w}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 60
#     operands: 59
# 55. w in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. InnerProd
#     core type: Literal
#     sub-expressions:
# 57. Kdelta
#     core type: Literal
#     sub-expressions:
# 58. (v, w)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 60. in
#     core type: Literal
#     sub-expressions:
# 61. (w, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 62. v
#     core type: Variable
#     sub-expressions:
# 63. w
#     core type: Variable
#     sub-expressions:
# 64. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 65
#     operands: 66
# 65. Set
#     core type: Literal
#     sub-expressions:
# 66. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 67
# 67. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 69
#     end_index: 70
# 68. _a -> x_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 71
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. n
#     core type: Variable
#     sub-expressions:
# 71. x_{_a}
#     core type: IndexedVar
# variable: 72
# index: 74
# 72. x
#     core type: Variable
#     sub-expressions:
# 73. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. _a
#     core type: Variable
#     sub-expressions:
