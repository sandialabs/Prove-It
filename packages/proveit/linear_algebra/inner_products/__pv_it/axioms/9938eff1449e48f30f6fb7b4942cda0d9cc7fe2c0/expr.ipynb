# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Px, Py, X, x, y
from proveit.linear_algebra import Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies, InSet
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), InSet(P, LinMap(Hspace, Hspace)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array} \textrm{ if } P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. P in LINMAP(H, H)
#    core type: Operation
#    operator: 52
#    operands: 5
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (P, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 43, 8
# 6. P = OrthoProj(H, X)
#    core type: Operation
#    operator: 50
#    operands: 9
# 7. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. LINMAP(H, H)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (P, OrthoProj(H, X))
#    core type: ExprTuple
#    sub-expressions: 43, 14
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. LINMAP
#     core type: Literal
#     sub-expressions:
# 13. (H, H)
#     core type: ExprTuple
#     sub-expressions: 49, 49
# 14. OrthoProj(H, X)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 35
#     operand: 21
# 16. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 35
#     operand: 22
# 17. OrthoProj
#     core type: Literal
#     sub-expressions:
# 18. (H, X)
#     core type: ExprTuple
#     sub-expressions: 49, 56
# 19. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 59
#     body: 23
# 22. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 60
#     body: 24
# 23. {P(x) = x if x in X.
#     core type: Conditional
#     value: 25
#     condition: 48
# 24. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. P(x) = x
#     core type: Operation
#     operator: 50
#     operands: 28
# 26. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. y in H
#     core type: Operation
#     operator: 52
#     operands: 31
# 28. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 32, 59
# 29. =>
#     core type: Literal
#     sub-expressions:
# 30. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. (y, H)
#     core type: ExprTuple
#     sub-expressions: 60, 49
# 32. P(x)
#     core type: Operation
#     operator: 43
#     operand: 59
# 33. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 35
#     operand: 38
# 34. P(y) = 0(H)
#     core type: Operation
#     operator: 50
#     operands: 37
# 35. forall
#     core type: Literal
#     sub-expressions:
# 36. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 59
#     body: 42
# 39. P(y)
#     core type: Operation
#     operator: 43
#     operand: 60
# 40. 0(H)
#     core type: Operation
#     operator: 45
#     operand: 49
# 41. (x)
#     core type: ExprTuple
#     sub-expressions: 59
# 42. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 47
#     condition: 48
# 43. P
#     core type: Variable
#     sub-expressions:
# 44. (y)
#     core type: ExprTuple
#     sub-expressions: 60
# 45. 0
#     core type: Literal
#     sub-expressions:
# 46. (H)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. <x, y> = 0
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. x in X
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. H
#     core type: Variable
#     sub-expressions:
# 50. =
#     core type: Literal
#     sub-expressions:
# 51. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (x, X)
#     core type: ExprTuple
#     sub-expressions: 59, 56
# 54. <x, y>
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. 0
#     core type: Literal
#     sub-expressions:
# 56. X
#     core type: Variable
#     sub-expressions:
# 57. InnerProd
#     core type: Literal
#     sub-expressions:
# 58. (x, y)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. y
#     core type: Variable
#     sub-expressions:
