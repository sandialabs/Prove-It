# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, P, Px, Py, X, x, y
from proveit.linear_algebra import Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies, InSet
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda(P, Conditional(Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), InSet(P, LinMap(Hspace, Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(P \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array} \textrm{ if } P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Lambda
#    parameter: 46
#    body: 3
# 2. (P)
#    core type: ExprTuple
#    sub-expressions: 46
# 3. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. P in LINMAP(H, H)
#    core type: Operation
#    operator: 55
#    operands: 8
# 6. <=>
#    core type: Literal
#    sub-expressions:
# 7. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (P, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 46, 11
# 9. P = OrthoProj(H, X)
#    core type: Operation
#    operator: 53
#    operands: 12
# 10. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. LINMAP(H, H)
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (P, OrthoProj(H, X))
#     core type: ExprTuple
#     sub-expressions: 46, 17
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. LINMAP
#     core type: Literal
#     sub-expressions:
# 16. (H, H)
#     core type: ExprTuple
#     sub-expressions: 52, 52
# 17. OrthoProj(H, X)
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 38
#     operand: 24
# 19. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 38
#     operand: 25
# 20. OrthoProj
#     core type: Literal
#     sub-expressions:
# 21. (H, X)
#     core type: ExprTuple
#     sub-expressions: 52, 59
# 22. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 62
#     body: 26
# 25. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 63
#     body: 27
# 26. {P(x) = x if x in X.
#     core type: Conditional
#     value: 28
#     condition: 51
# 27. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. P(x) = x
#     core type: Operation
#     operator: 53
#     operands: 31
# 29. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. y in H
#     core type: Operation
#     operator: 55
#     operands: 34
# 31. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 35, 62
# 32. =>
#     core type: Literal
#     sub-expressions:
# 33. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. (y, H)
#     core type: ExprTuple
#     sub-expressions: 63, 52
# 35. P(x)
#     core type: Operation
#     operator: 46
#     operand: 62
# 36. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 38
#     operand: 41
# 37. P(y) = 0(H)
#     core type: Operation
#     operator: 53
#     operands: 40
# 38. forall
#     core type: Literal
#     sub-expressions:
# 39. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 62
#     body: 45
# 42. P(y)
#     core type: Operation
#     operator: 46
#     operand: 63
# 43. 0(H)
#     core type: Operation
#     operator: 48
#     operand: 52
# 44. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 45. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 50
#     condition: 51
# 46. P
#     core type: Variable
#     sub-expressions:
# 47. (y)
#     core type: ExprTuple
#     sub-expressions: 63
# 48. 0
#     core type: Literal
#     sub-expressions:
# 49. (H)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. <x, y> = 0
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. x in X
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. H
#     core type: Variable
#     sub-expressions:
# 53. =
#     core type: Literal
#     sub-expressions:
# 54. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (x, X)
#     core type: ExprTuple
#     sub-expressions: 62, 59
# 57. <x, y>
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. 0
#     core type: Literal
#     sub-expressions:
# 59. X
#     core type: Variable
#     sub-expressions:
# 60. InnerProd
#     core type: Literal
#     sub-expressions:
# 61. (x, y)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. y
#     core type: Variable
#     sub-expressions:
