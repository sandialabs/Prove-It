# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, H, K, Lambda, n, v, w
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, InnerProd, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Forall, InClass, InSet, Set
from proveit.numbers import KroneckerDelta, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = ExprTuple(Lambda(H, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, OrthoNormBases(H)), And(InSet(sub_expr1, Bases(H)), Forall(instance_param_or_params = [v, w], instance_expr = Equals(InnerProd(v, w), KroneckerDelta(v, w)), domain = sub_expr1))).with_wrapping_at(2), domain = H), domain = NaturalPos), InClass(H, InnerProdSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(H \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in H}~\left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) =  \\ \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(H\right)\right) \land \left[\forall_{v, w \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}}~\left(\left \langle v, w\right \rangle = \delta_{v, w}\right)\right]\right) \end{array} \end{array}\right)\right] \textrm{ if } H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Lambda
#    parameter: 46
#    body: 2
# 2. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]
#    core type: Operation
#    operator: 38
#    operand: 8
# 4. H in_c InnerProdSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (H, InnerProdSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 46, 9
# 8. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#    core type: Lambda
#    parameter: 71
#    body: 11
# 9. InnerProdSpaces(K)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 71
# 11. {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 13. (K)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))
#     core type: Operation
#     operator: 38
#     operand: 19
# 15. n in NaturalPos
#     core type: Operation
#     operator: 61
#     operands: 18
# 16. K
#     core type: Variable
#     sub-expressions:
# 17. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 71, 20
# 19. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Lambda
#     parameters: 67\n    body: 21
# 20. NaturalPos
#     core type: Literal
#     sub-expressions:
# 21. {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: Operation
#     operator: 49
#     operands: 24
# 23. (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H)
#     core type: Operation
#     operator: 51
#     operands: 25
# 24. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H), ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. ((x_{1} in H), (x_{2} in H), ..., (x_{n} in H))
#     core type: ExprTuple
#     sub-expressions: 28
# 26. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 61
#     operands: 29
# 27. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]
#     core type: Operation
#     operator: 51
#     operands: 30
# 28. (x_{1} in H), (x_{2} in H), ..., (x_{n} in H)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 70
#     end_index: 71
# 29. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 65, 32
# 30. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H), forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. _a -> (x_{_a} in H)
#     core type: Lambda
#     parameter: 75
#     body: 35
# 32. O.N.Bases(H)
#     core type: Operation
#     operator: 36
#     operand: 46
# 33. {x_{1}, x_{2}, ..., x_{n}} in Bases(H)
#     core type: Operation
#     operator: 61
#     operands: 37
# 34. forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})
#     core type: Operation
#     operator: 38
#     operand: 42
# 35. x_{_a} in H
#     core type: Operation
#     operator: 61
#     operands: 40
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. ({x_{1}, x_{2}, ..., x_{n}}, Bases(H))
#     core type: ExprTuple
#     sub-expressions: 65, 41
# 38. forall
#     core type: Literal
#     sub-expressions:
# 39. ((v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. (x_{_a}, H)
#     core type: ExprTuple
#     sub-expressions: 72, 46
# 41. Bases(H)
#     core type: Operation
#     operator: 43
#     operand: 46
# 42. (v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Lambda
#     parameters: 59\n    body: 45
# 43. Bases
#     core type: Literal
#     sub-expressions:
# 44. (H)
#     core type: ExprTuple
#     sub-expressions: 46
# 45. {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Conditional
#     value: 47
#     condition: 48
# 46. H
#     core type: Variable
#     sub-expressions:
# 47. <v, w> = delta_{v, w}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. (v in {x_{1}, x_{2}, ..., x_{n}}) and (w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. =
#     core type: Literal
#     sub-expressions:
# 50. (<v, w>, delta_{v, w})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. and
#     core type: Literal
#     sub-expressions:
# 52. (v in {x_{1}, x_{2}, ..., x_{n}}, w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. <v, w>
#     core type: Operation
#     operator: 57
#     operands: 59
# 54. delta_{v, w}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 61
#     operands: 60
# 56. w in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. InnerProd
#     core type: Literal
#     sub-expressions:
# 58. Kdelta
#     core type: Literal
#     sub-expressions:
# 59. (v, w)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 63, 65
# 61. in
#     core type: Literal
#     sub-expressions:
# 62. (w, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 63. v
#     core type: Variable
#     sub-expressions:
# 64. w
#     core type: Variable
#     sub-expressions:
# 65. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 66
#     operands: 67
# 66. Set
#     core type: Literal
#     sub-expressions:
# 67. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 68
# 68. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 70
#     end_index: 71
# 69. _a -> x_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 72
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. x_{_a}
#     core type: IndexedVar
# variable: 73
# index: 75
# 73. x
#     core type: Variable
#     sub-expressions:
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. _a
#     core type: Variable
#     sub-expressions:
