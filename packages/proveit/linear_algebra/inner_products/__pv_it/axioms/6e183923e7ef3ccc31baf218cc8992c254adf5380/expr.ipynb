# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, H, K, Lambda, n, v, w
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, InnerProd, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Forall, InSet, Set
from proveit.numbers import KroneckerDelta, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [H], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, OrthoNormBases(H)), And(InSet(sub_expr1, Bases(H)), Forall(instance_param_or_params = [v, w], instance_expr = Equals(InnerProd(v, w), KroneckerDelta(v, w)), domain = sub_expr1))).with_wrapping_at(2), domain = H), domain = NaturalPos), domain = InnerProdSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in H}~\left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) =  \\ \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(H\right)\right) \land \left[\forall_{v, w \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}}~\left(\left \langle v, w\right \rangle = \delta_{v, w}\right)\right]\right) \end{array} \end{array}\right)\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]
#    core type: Operation
#    operator: 41
#    operand: 4
# 3. (H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Lambda
#    parameter: 49
#    body: 5
# 5. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]
#    core type: Operation
#    operator: 41
#    operand: 11
# 7. H in_c InnerProdSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (H, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 49, 12
# 11. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Lambda
#     parameter: 74
#     body: 14
# 12. InnerProdSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (n)
#     core type: ExprTuple
#     sub-expressions: 74
# 14. {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))
#     core type: Operation
#     operator: 41
#     operand: 22
# 18. n in NaturalPos
#     core type: Operation
#     operator: 64
#     operands: 21
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 74, 23
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Lambda
#     parameters: 70\n    body: 24
# 23. NaturalPos
#     core type: Literal
#     sub-expressions:
# 24. {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Conditional
#     value: 25
#     condition: 26
# 25. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: Operation
#     operator: 52
#     operands: 27
# 26. (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H)
#     core type: Operation
#     operator: 54
#     operands: 28
# 27. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H), ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. ((x_{1} in H), (x_{2} in H), ..., (x_{n} in H))
#     core type: ExprTuple
#     sub-expressions: 31
# 29. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 64
#     operands: 32
# 30. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]
#     core type: Operation
#     operator: 54
#     operands: 33
# 31. (x_{1} in H), (x_{2} in H), ..., (x_{n} in H)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 73
#     end_index: 74
# 32. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 68, 35
# 33. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H), forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. _a -> (x_{_a} in H)
#     core type: Lambda
#     parameter: 78
#     body: 38
# 35. O.N.Bases(H)
#     core type: Operation
#     operator: 39
#     operand: 49
# 36. {x_{1}, x_{2}, ..., x_{n}} in Bases(H)
#     core type: Operation
#     operator: 64
#     operands: 40
# 37. forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})
#     core type: Operation
#     operator: 41
#     operand: 45
# 38. x_{_a} in H
#     core type: Operation
#     operator: 64
#     operands: 43
# 39. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 40. ({x_{1}, x_{2}, ..., x_{n}}, Bases(H))
#     core type: ExprTuple
#     sub-expressions: 68, 44
# 41. forall
#     core type: Literal
#     sub-expressions:
# 42. ((v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. (x_{_a}, H)
#     core type: ExprTuple
#     sub-expressions: 75, 49
# 44. Bases(H)
#     core type: Operation
#     operator: 46
#     operand: 49
# 45. (v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Lambda
#     parameters: 62\n    body: 48
# 46. Bases
#     core type: Literal
#     sub-expressions:
# 47. (H)
#     core type: ExprTuple
#     sub-expressions: 49
# 48. {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Conditional
#     value: 50
#     condition: 51
# 49. H
#     core type: Variable
#     sub-expressions:
# 50. <v, w> = delta_{v, w}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. (v in {x_{1}, x_{2}, ..., x_{n}}) and (w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (<v, w>, delta_{v, w})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. and
#     core type: Literal
#     sub-expressions:
# 55. (v in {x_{1}, x_{2}, ..., x_{n}}, w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. <v, w>
#     core type: Operation
#     operator: 60
#     operands: 62
# 57. delta_{v, w}
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 64
#     operands: 63
# 59. w in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. InnerProd
#     core type: Literal
#     sub-expressions:
# 61. Kdelta
#     core type: Literal
#     sub-expressions:
# 62. (v, w)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 66, 68
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (w, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 66. v
#     core type: Variable
#     sub-expressions:
# 67. w
#     core type: Variable
#     sub-expressions:
# 68. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 69
#     operands: 70
# 69. Set
#     core type: Literal
#     sub-expressions:
# 70. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 71
# 71. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 73
#     end_index: 74
# 72. _a -> x_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 75
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. n
#     core type: Variable
#     sub-expressions:
# 75. x_{_a}
#     core type: IndexedVar
# variable: 76
# index: 78
# 76. x
#     core type: Variable
#     sub-expressions:
# 77. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 78. _a
#     core type: Variable
#     sub-expressions:
