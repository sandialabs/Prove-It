# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import H, K, n, v, w
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Bases, InnerProd, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Forall, InSet, Set
from proveit.numbers import KroneckerDelta, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [H], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(InSet(sub_expr1, OrthoNormBases(H)), And(InSet(sub_expr1, Bases(H)), Forall(instance_param_or_params = [v, w], instance_expr = Equals(InnerProd(v, w), KroneckerDelta(v, w)), domain = sub_expr1))).with_wrapping_at(2), domain = H), domain = NaturalPos), domain = InnerProdSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in H}~\left(\begin{array}{c} \begin{array}{l} \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) =  \\ \left(\left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{Bases}\left(H\right)\right) \land \left[\forall_{v, w \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}}~\left(\left \langle v, w\right \rangle = \delta_{v, w}\right)\right]\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]]
#    core type: Operation
#    operator: 42
#    operand: 2
# 1. (K -> [forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]]
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. forall_{H in_c InnerProdSpaces(K)} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]]
#    core type: Operation
#    operator: 42
#    operand: 5
# 4. (H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Lambda
#    parameter: 50
#    body: 6
# 6. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))] if H in_c InnerProdSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))]
#    core type: Operation
#    operator: 42
#    operand: 12
# 8. H in_c InnerProdSpaces(K)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (H, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 50, 13
# 12. n -> {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Lambda
#     parameter: 75
#     body: 15
# 13. InnerProdSpaces(K)
#     core type: Operation
#     operator: 16
#     operand: 20
# 14. (n)
#     core type: ExprTuple
#     sub-expressions: 75
# 15. {forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])) if n in NaturalPos.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 17. (K)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. forall_{x_{1}, x_{2}, ..., x_{n} in H} (({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]))
#     core type: Operation
#     operator: 42
#     operand: 23
# 19. n in NaturalPos
#     core type: Operation
#     operator: 65
#     operands: 22
# 20. K
#     core type: Variable
#     sub-expressions:
# 21. ((x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 75, 24
# 23. (x_{1}, x_{2}, ..., x_{n}) -> {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Lambda
#     parameters: 71\n    body: 25
# 24. NaturalPos
#     core type: Literal
#     sub-expressions:
# 25. {({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]) if (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H).
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)) =  \\ (({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: Operation
#     operator: 53
#     operands: 28
# 27. (x_{1} in H) and  (x_{2} in H) and  ... and  (x_{n} in H)
#     core type: Operation
#     operator: 55
#     operands: 29
# 28. ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H), ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})])
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. ((x_{1} in H), (x_{2} in H), ..., (x_{n} in H))
#     core type: ExprTuple
#     sub-expressions: 32
# 30. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 65
#     operands: 33
# 31. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H)) and [forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})]
#     core type: Operation
#     operator: 55
#     operands: 34
# 32. (x_{1} in H), (x_{2} in H), ..., (x_{n} in H)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 74
#     end_index: 75
# 33. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 69, 36
# 34. ({x_{1}, x_{2}, ..., x_{n}} in Bases(H), forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. _a -> (x_{_a} in H)
#     core type: Lambda
#     parameter: 79
#     body: 39
# 36. O.N.Bases(H)
#     core type: Operation
#     operator: 40
#     operand: 50
# 37. {x_{1}, x_{2}, ..., x_{n}} in Bases(H)
#     core type: Operation
#     operator: 65
#     operands: 41
# 38. forall_{v, w in {x_{1}, x_{2}, ..., x_{n}}} (<v, w> = delta_{v, w})
#     core type: Operation
#     operator: 42
#     operand: 46
# 39. x_{_a} in H
#     core type: Operation
#     operator: 65
#     operands: 44
# 40. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 41. ({x_{1}, x_{2}, ..., x_{n}}, Bases(H))
#     core type: ExprTuple
#     sub-expressions: 69, 45
# 42. forall
#     core type: Literal
#     sub-expressions:
# 43. ((v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. (x_{_a}, H)
#     core type: ExprTuple
#     sub-expressions: 76, 50
# 45. Bases(H)
#     core type: Operation
#     operator: 47
#     operand: 50
# 46. (v, w) -> {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Lambda
#     parameters: 63\n    body: 49
# 47. Bases
#     core type: Literal
#     sub-expressions:
# 48. (H)
#     core type: ExprTuple
#     sub-expressions: 50
# 49. {<v, w> = delta_{v, w} if v in {x_{1}, x_{2}, ..., x_{n}} ,  w in {x_{1}, x_{2}, ..., x_{n}}.
#     core type: Conditional
#     value: 51
#     condition: 52
# 50. H
#     core type: Variable
#     sub-expressions:
# 51. <v, w> = delta_{v, w}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. (v in {x_{1}, x_{2}, ..., x_{n}}) and (w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. =
#     core type: Literal
#     sub-expressions:
# 54. (<v, w>, delta_{v, w})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. and
#     core type: Literal
#     sub-expressions:
# 56. (v in {x_{1}, x_{2}, ..., x_{n}}, w in {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. <v, w>
#     core type: Operation
#     operator: 61
#     operands: 63
# 58. delta_{v, w}
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 65
#     operands: 64
# 60. w in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. InnerProd
#     core type: Literal
#     sub-expressions:
# 62. Kdelta
#     core type: Literal
#     sub-expressions:
# 63. (v, w)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 64. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (w, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 67. v
#     core type: Variable
#     sub-expressions:
# 68. w
#     core type: Variable
#     sub-expressions:
# 69. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 70
#     operands: 71
# 70. Set
#     core type: Literal
#     sub-expressions:
# 71. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 72
# 72. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 74
#     end_index: 75
# 73. _a -> x_{_a}
#     core type: Lambda
#     parameter: 79
#     body: 76
# 74. 1
#     core type: Literal
#     sub-expressions:
# 75. n
#     core type: Variable
#     sub-expressions:
# 76. x_{_a}
#     core type: IndexedVar
# variable: 77
# index: 79
# 77. x
#     core type: Variable
#     sub-expressions:
# 78. (_a)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. _a
#     core type: Variable
#     sub-expressions:
