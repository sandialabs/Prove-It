# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, Py, X, x, y
from proveit.linear_algebra import Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [P], instance_expr = Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), domain = LinMap(Hspace, Hspace))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]))
#    core type: Operation
#    operator: 39
#    operand: 2
# 1. (P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Lambda
#    parameter: 47
#    body: 4
# 3. (P)
#    core type: ExprTuple
#    sub-expressions: 47
# 4. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. P in LINMAP(H, H)
#    core type: Operation
#    operator: 56
#    operands: 9
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (P, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 47, 12
# 10. P = OrthoProj(H, X)
#     core type: Operation
#     operator: 54
#     operands: 13
# 11. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. LINMAP(H, H)
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (P, OrthoProj(H, X))
#     core type: ExprTuple
#     sub-expressions: 47, 18
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. LINMAP
#     core type: Literal
#     sub-expressions:
# 17. (H, H)
#     core type: ExprTuple
#     sub-expressions: 53, 53
# 18. OrthoProj(H, X)
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 39
#     operand: 25
# 20. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 39
#     operand: 26
# 21. OrthoProj
#     core type: Literal
#     sub-expressions:
# 22. (H, X)
#     core type: ExprTuple
#     sub-expressions: 53, 60
# 23. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 63
#     body: 27
# 26. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 64
#     body: 28
# 27. {P(x) = x if x in X.
#     core type: Conditional
#     value: 29
#     condition: 52
# 28. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 30
#     condition: 31
# 29. P(x) = x
#     core type: Operation
#     operator: 54
#     operands: 32
# 30. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. y in H
#     core type: Operation
#     operator: 56
#     operands: 35
# 32. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 36, 63
# 33. =>
#     core type: Literal
#     sub-expressions:
# 34. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. (y, H)
#     core type: ExprTuple
#     sub-expressions: 64, 53
# 36. P(x)
#     core type: Operation
#     operator: 47
#     operand: 63
# 37. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 39
#     operand: 42
# 38. P(y) = 0(H)
#     core type: Operation
#     operator: 54
#     operands: 41
# 39. forall
#     core type: Literal
#     sub-expressions:
# 40. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 42
# 41. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 63
#     body: 46
# 43. P(y)
#     core type: Operation
#     operator: 47
#     operand: 64
# 44. 0(H)
#     core type: Operation
#     operator: 49
#     operand: 53
# 45. (x)
#     core type: ExprTuple
#     sub-expressions: 63
# 46. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 51
#     condition: 52
# 47. P
#     core type: Variable
#     sub-expressions:
# 48. (y)
#     core type: ExprTuple
#     sub-expressions: 64
# 49. 0
#     core type: Literal
#     sub-expressions:
# 50. (H)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. <x, y> = 0
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. x in X
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. H
#     core type: Variable
#     sub-expressions:
# 54. =
#     core type: Literal
#     sub-expressions:
# 55. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (x, X)
#     core type: ExprTuple
#     sub-expressions: 63, 60
# 58. <x, y>
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. 0
#     core type: Literal
#     sub-expressions:
# 60. X
#     core type: Variable
#     sub-expressions:
# 61. InnerProd
#     core type: Literal
#     sub-expressions:
# 62. (x, y)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. y
#     core type: Variable
#     sub-expressions:
