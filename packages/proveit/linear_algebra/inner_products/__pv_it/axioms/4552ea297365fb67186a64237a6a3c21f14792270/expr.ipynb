# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, Py, X, x, y
from proveit.linear_algebra import Hspace, InnerProd, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. P = OrthoProj(H, X)
#    core type: Operation
#    operator: 44
#    operands: 5
# 4. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (P, OrthoProj(H, X))
#    core type: ExprTuple
#    sub-expressions: 37, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. OrthoProj(H, X)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. forall_{x in X} (P(x) = x)
#    core type: Operation
#    operator: 29
#    operand: 15
# 10. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 29
#     operand: 16
# 11. OrthoProj
#     core type: Literal
#     sub-expressions:
# 12. (H, X)
#     core type: ExprTuple
#     sub-expressions: 43, 50
# 13. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 53
#     body: 17
# 16. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 54
#     body: 18
# 17. {P(x) = x if x in X.
#     core type: Conditional
#     value: 19
#     condition: 42
# 18. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. P(x) = x
#     core type: Operation
#     operator: 44
#     operands: 22
# 20. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. y in H
#     core type: Operation
#     operator: 46
#     operands: 25
# 22. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 26, 53
# 23. =>
#     core type: Literal
#     sub-expressions:
# 24. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. (y, H)
#     core type: ExprTuple
#     sub-expressions: 54, 43
# 26. P(x)
#     core type: Operation
#     operator: 37
#     operand: 53
# 27. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 29
#     operand: 32
# 28. P(y) = 0(H)
#     core type: Operation
#     operator: 44
#     operands: 31
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 53
#     body: 36
# 33. P(y)
#     core type: Operation
#     operator: 37
#     operand: 54
# 34. 0(H)
#     core type: Operation
#     operator: 39
#     operand: 43
# 35. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 36. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 41
#     condition: 42
# 37. P
#     core type: Variable
#     sub-expressions:
# 38. (y)
#     core type: ExprTuple
#     sub-expressions: 54
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. (H)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. <x, y> = 0
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. x in X
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. H
#     core type: Variable
#     sub-expressions:
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x, X)
#     core type: ExprTuple
#     sub-expressions: 53, 50
# 48. <x, y>
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. 0
#     core type: Literal
#     sub-expressions:
# 50. X
#     core type: Variable
#     sub-expressions:
# 51. InnerProd
#     core type: Literal
#     sub-expressions:
# 52. (x, y)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. y
#     core type: Variable
#     sub-expressions:
