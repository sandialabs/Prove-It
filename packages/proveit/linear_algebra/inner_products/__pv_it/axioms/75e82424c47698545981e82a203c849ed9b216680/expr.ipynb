# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Px, Py, X, x, y
from proveit.linear_algebra import HilbertSpaces, Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies, InClass, SubsetEq
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([Hspace, X], Conditional(Forall(instance_param_or_params = [P], instance_expr = Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), And(InClass(Hspace, HilbertSpaces), InClass(X, HilbertSpaces), SubsetEq(X, Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\mathcal{H}, X\right) \mapsto \left\{\forall_{P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array}\right) \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  X \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  X \subseteq \mathcal{H}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (H, X) -> {forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])) if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  X subset_eq H.
#    core type: Lambda
#    parameters: 35\n   body: 1
# 1. {forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])) if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  X subset_eq H.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P in LINMAP(H, H)} ((P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]))
#    core type: Operation
#    operator: 52
#    operand: 6
# 3. (H in_c HilbertSpaces) and (X in_c HilbertSpaces) and (X subset_eq H)
#    core type: Operation
#    operator: 27
#    operands: 5
# 4. (P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (H in_c HilbertSpaces, X in_c HilbertSpaces, X subset_eq H)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Lambda
#    parameter: 60
#    body: 11
# 7. H in_c HilbertSpaces
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. X in_c HilbertSpaces
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. X subset_eq H
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (P)
#     core type: ExprTuple
#     sub-expressions: 60
# 11. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#     core type: Conditional
#     value: 17
#     condition: 18
# 12. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 66, 19
# 13. in_c
#     core type: Literal
#     sub-expressions:
# 14. (X, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 73, 19
# 15. subset_eq
#     core type: Literal
#     sub-expressions:
# 16. (X, H)
#     core type: ExprTuple
#     sub-expressions: 73, 66
# 17. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. P in LINMAP(H, H)
#     core type: Operation
#     operator: 69
#     operands: 22
# 19. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 20. <=>
#     core type: Literal
#     sub-expressions:
# 21. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. (P, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 60, 25
# 23. P = OrthoProj(H, X)
#     core type: Operation
#     operator: 67
#     operands: 26
# 24. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. LINMAP(H, H)
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (P, OrthoProj(H, X))
#     core type: ExprTuple
#     sub-expressions: 60, 31
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. LINMAP
#     core type: Literal
#     sub-expressions:
# 30. (H, H)
#     core type: ExprTuple
#     sub-expressions: 66, 66
# 31. OrthoProj(H, X)
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 52
#     operand: 38
# 33. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 52
#     operand: 39
# 34. OrthoProj
#     core type: Literal
#     sub-expressions:
# 35. (H, X)
#     core type: ExprTuple
#     sub-expressions: 66, 73
# 36. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 39
# 38. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 76
#     body: 40
# 39. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 77
#     body: 41
# 40. {P(x) = x if x in X.
#     core type: Conditional
#     value: 42
#     condition: 65
# 41. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. P(x) = x
#     core type: Operation
#     operator: 67
#     operands: 45
# 43. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. y in H
#     core type: Operation
#     operator: 69
#     operands: 48
# 45. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 49, 76
# 46. =>
#     core type: Literal
#     sub-expressions:
# 47. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. (y, H)
#     core type: ExprTuple
#     sub-expressions: 77, 66
# 49. P(x)
#     core type: Operation
#     operator: 60
#     operand: 76
# 50. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 52
#     operand: 55
# 51. P(y) = 0(H)
#     core type: Operation
#     operator: 67
#     operands: 54
# 52. forall
#     core type: Literal
#     sub-expressions:
# 53. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 55
# 54. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 76
#     body: 59
# 56. P(y)
#     core type: Operation
#     operator: 60
#     operand: 77
# 57. 0(H)
#     core type: Operation
#     operator: 62
#     operand: 66
# 58. (x)
#     core type: ExprTuple
#     sub-expressions: 76
# 59. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 64
#     condition: 65
# 60. P
#     core type: Variable
#     sub-expressions:
# 61. (y)
#     core type: ExprTuple
#     sub-expressions: 77
# 62. 0
#     core type: Literal
#     sub-expressions:
# 63. (H)
#     core type: ExprTuple
#     sub-expressions: 66
# 64. <x, y> = 0
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. x in X
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. H
#     core type: Variable
#     sub-expressions:
# 67. =
#     core type: Literal
#     sub-expressions:
# 68. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 69. in
#     core type: Literal
#     sub-expressions:
# 70. (x, X)
#     core type: ExprTuple
#     sub-expressions: 76, 73
# 71. <x, y>
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. 0
#     core type: Literal
#     sub-expressions:
# 73. X
#     core type: Variable
#     sub-expressions:
# 74. InnerProd
#     core type: Literal
#     sub-expressions:
# 75. (x, y)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 76. x
#     core type: Variable
#     sub-expressions:
# 77. y
#     core type: Variable
#     sub-expressions:
