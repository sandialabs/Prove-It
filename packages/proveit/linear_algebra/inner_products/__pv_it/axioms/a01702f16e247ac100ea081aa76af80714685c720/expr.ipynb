# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Px, Py, X, x, y
from proveit.linear_algebra import Hspace, InnerProd, LinMap, OrthoProj, VecZero
from proveit.logic import And, Equals, Forall, Iff, Implies, InSet
from proveit.numbers import zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(P, Conditional(Iff(Equals(P, OrthoProj(Hspace, X)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Px, x), domain = X), Forall(instance_param_or_params = [y], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(InnerProd(x, y), zero), domain = X), Equals(Py, VecZero(Hspace))), domain = Hspace)).with_wrapping_at(2)).with_wrapping_at(2), InSet(P, LinMap(Hspace, Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# P \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(P = \textrm{OrthoProj}\left(\mathcal{H}, X\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in X}~\left(P\left(x\right) = x\right)\right] \land  \\ \left[\forall_{y \in \mathcal{H}}~\left(\left[\forall_{x \in X}~\left(\left \langle x, y\right \rangle = 0\right)\right] \Rightarrow \left(P\left(y\right) = \vec{0}\left(\mathcal{H}\right)\right)\right)\right] \end{array}\right) \end{array} \end{array} \textrm{ if } P \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. P -> {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Lambda
#    parameter: 45
#    body: 2
# 1. (P)
#    core type: ExprTuple
#    sub-expressions: 45
# 2. {(P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]) if P in LINMAP(H, H).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (P = OrthoProj(H, X)) <=>  \\ ([forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. P in LINMAP(H, H)
#    core type: Operation
#    operator: 54
#    operands: 7
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. (P = OrthoProj(H, X), [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (P, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 45, 10
# 8. P = OrthoProj(H, X)
#    core type: Operation
#    operator: 52
#    operands: 11
# 9. [forall_{x in X} (P(x) = x)] and  \\ [forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))]
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. LINMAP(H, H)
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (P, OrthoProj(H, X))
#     core type: ExprTuple
#     sub-expressions: 45, 16
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (forall_{x in X} (P(x) = x), forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. LINMAP
#     core type: Literal
#     sub-expressions:
# 15. (H, H)
#     core type: ExprTuple
#     sub-expressions: 51, 51
# 16. OrthoProj(H, X)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. forall_{x in X} (P(x) = x)
#     core type: Operation
#     operator: 37
#     operand: 23
# 18. forall_{y in H} ([forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)))
#     core type: Operation
#     operator: 37
#     operand: 24
# 19. OrthoProj
#     core type: Literal
#     sub-expressions:
# 20. (H, X)
#     core type: ExprTuple
#     sub-expressions: 51, 58
# 21. (x -> {P(x) = x if x in X.)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. x -> {P(x) = x if x in X.
#     core type: Lambda
#     parameter: 61
#     body: 25
# 24. y -> {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Lambda
#     parameter: 62
#     body: 26
# 25. {P(x) = x if x in X.
#     core type: Conditional
#     value: 27
#     condition: 50
# 26. {[forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H)) if y in H.
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. P(x) = x
#     core type: Operation
#     operator: 52
#     operands: 30
# 28. [forall_{x in X} (<x, y> = 0)] => (P(y) = 0(H))
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. y in H
#     core type: Operation
#     operator: 54
#     operands: 33
# 30. (P(x), x)
#     core type: ExprTuple
#     sub-expressions: 34, 61
# 31. =>
#     core type: Literal
#     sub-expressions:
# 32. (forall_{x in X} (<x, y> = 0), P(y) = 0(H))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. (y, H)
#     core type: ExprTuple
#     sub-expressions: 62, 51
# 34. P(x)
#     core type: Operation
#     operator: 45
#     operand: 61
# 35. forall_{x in X} (<x, y> = 0)
#     core type: Operation
#     operator: 37
#     operand: 40
# 36. P(y) = 0(H)
#     core type: Operation
#     operator: 52
#     operands: 39
# 37. forall
#     core type: Literal
#     sub-expressions:
# 38. (x -> {<x, y> = 0 if x in X.)
#     core type: ExprTuple
#     sub-expressions: 40
# 39. (P(y), 0(H))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. x -> {<x, y> = 0 if x in X.
#     core type: Lambda
#     parameter: 61
#     body: 44
# 41. P(y)
#     core type: Operation
#     operator: 45
#     operand: 62
# 42. 0(H)
#     core type: Operation
#     operator: 47
#     operand: 51
# 43. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 44. {<x, y> = 0 if x in X.
#     core type: Conditional
#     value: 49
#     condition: 50
# 45. P
#     core type: Variable
#     sub-expressions:
# 46. (y)
#     core type: ExprTuple
#     sub-expressions: 62
# 47. 0
#     core type: Literal
#     sub-expressions:
# 48. (H)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. <x, y> = 0
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. x in X
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. H
#     core type: Variable
#     sub-expressions:
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (<x, y>, 0)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (x, X)
#     core type: ExprTuple
#     sub-expressions: 61, 58
# 56. <x, y>
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. 0
#     core type: Literal
#     sub-expressions:
# 58. X
#     core type: Variable
#     sub-expressions:
# 59. InnerProd
#     core type: Literal
#     sub-expressions:
# 60. (x, y)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. y
#     core type: Variable
#     sub-expressions:
