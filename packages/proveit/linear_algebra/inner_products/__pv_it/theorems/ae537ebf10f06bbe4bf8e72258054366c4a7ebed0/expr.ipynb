# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, ExprTuple, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.
#    core type: Lambda
#    parameter: 103
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 103
# 3. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])]
#    core type: Operation
#    operator: 13
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 88
#    operands: 7
# 6. (H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 103, 9
# 8. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 100
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 68
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Lambda
#     parameter: 71
#     body: 19
# 17. H in_c HilbertSpaces
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. Dim(H) = n
#     core type: Operation
#     operator: 66
#     operands: 22
# 19. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. in_c
#     core type: Literal
#     sub-expressions:
# 21. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 100, 25
# 22. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 26, 103
# 23. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. M in LINMAP(H, H)
#     core type: Operation
#     operator: 88
#     operands: 29
# 25. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 26. Dim(H)
#     core type: Operation
#     operator: 30
#     operand: 100
# 27. <=>
#     core type: Literal
#     sub-expressions:
# 28. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 71, 33
# 30. Dim
#     core type: Literal
#     sub-expressions:
# 31. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 66
#     operands: 34
# 32. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 50
#     operand: 40
# 33. LINMAP(H, H)
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. LINMAP
#     core type: Literal
#     sub-expressions:
# 37. (H, H)
#     core type: ExprTuple
#     sub-expressions: 100, 100
# 38. M* o M
#     core type: Operation
#     operator: 42
#     operands: 41
# 39. M o M*
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 58\n    body: 44
# 41. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 45, 71
# 42. o
#     core type: Literal
#     sub-expressions:
# 43. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 71, 45
# 44. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 46
#     condition: 47
# 45. M*
#     core type: Operation
#     operator: 48
#     operand: 71
# 46. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 50
#     operand: 53
# 47. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 88
#     operands: 52
# 48. Adj
#     core type: Literal
#     sub-expressions:
# 49. (M)
#     core type: ExprTuple
#     sub-expressions: 71
# 50. exists
#     core type: Literal
#     sub-expressions:
# 51. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 53. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 56\n    body: 57
# 54. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 107
#     operands: 58
# 55. O.N.Bases(H)
#     core type: Operation
#     operator: 59
#     operand: 100
# 56. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 57. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 62
#     condition: 63
# 58. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 64
# 59. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 60. (H)
#     core type: ExprTuple
#     sub-expressions: 100
# 61. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 102
#     end_index: 103
# 62. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 102
#     end_index: 103
# 65. _a -> a_{_a}
#     core type: Lambda
#     parameter: 94
#     body: 84
# 66. =
#     core type: Literal
#     sub-expressions:
# 67. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 68. and
#     core type: Literal
#     sub-expressions:
# 69. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 73
# 70. _a -> x_{_a}
#     core type: Lambda
#     parameter: 94
#     body: 74
# 71. M
#     core type: Variable
#     sub-expressions:
# 72. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 75
#     operand: 78
# 73. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 102
#     end_index: 103
# 74. x_{_a}
#     core type: IndexedVar
# variable: 110
# index: 94
# 75. Sum
#     core type: Literal
#     sub-expressions:
# 76. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 78
# 77. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 94
#     body: 79
# 78. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 112
#     body: 80
# 79. a_{_a} in Complex
#     core type: Operation
#     operator: 88
#     operands: 81
# 80. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 82
#     condition: 83
# 81. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 82. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 86
#     operands: 87
# 83. i in {1 .. n}
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. a_{_a}
#     core type: IndexedVar
# variable: 95
# index: 94
# 85. Complex
#     core type: Literal
#     sub-expressions:
# 86. *
#     core type: Literal
#     sub-expressions:
# 87. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 88. in
#     core type: Literal
#     sub-expressions:
# 89. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 112, 93
# 90. (_a)
#     core type: ExprTuple
#     sub-expressions: 94
# 91. a_{i}
#     core type: IndexedVar
# variable: 95
# index: 112
# 92. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 96
#     operands: 97
# 93. {1 .. n}
#     core type: Operation
#     operator: 98
#     operands: 99
# 94. _a
#     core type: Variable
#     sub-expressions:
# 95. a
#     core type: Variable
#     sub-expressions:
# 96. OrthoProj
#     core type: Literal
#     sub-expressions:
# 97. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 98. Interval
#     core type: Literal
#     sub-expressions:
# 99. (1, n)
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 100. H
#      core type: Variable
#      sub-expressions:
# 101. Span({x_{i}})
#      core type: Operation
#      operator: 104
#      operand: 106
# 102. 1
#      core type: Literal
#      sub-expressions:
# 103. n
#      core type: Variable
#      sub-expressions:
# 104. Span
#      core type: Literal
#      sub-expressions:
# 105. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 106
# 106. {x_{i}}
#      core type: Operation
#      operator: 107
#      operand: 109
# 107. Set
#      core type: Literal
#      sub-expressions:
# 108. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 109
# 109. x_{i}
#      core type: IndexedVar
# variable: 110
# index: 112
# 110. x
#      core type: Variable
#      sub-expressions:
# 111. (i)
#      core type: ExprTuple
#      sub-expressions: 112
# 112. i
#      core type: Variable
#      sub-expressions:
