# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, Forall, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), domain = TensorProd(A, B))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Lambda
#    parameter: 53
#    body: 5
# 4. (v)
#    core type: ExprTuple
#    sub-expressions: 53
# 5. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#    core type: Operation
#    operator: 28
#    operand: 10
# 7. v in (A otimes B)
#    core type: Operation
#    operator: 70
#    operands: 9
# 8. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (v, A otimes B)
#    core type: ExprTuple
#    sub-expressions: 53, 11
# 10. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 22\n    body: 12
# 11. A otimes B
#     core type: Operation
#     operator: 78
#     operands: 13
# 12. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 27, 46
# 14. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 28
#     operand: 18
# 15. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 70
#     operands: 17
# 16. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 39\n    body: 21
# 19. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 38
#     operands: 22
# 20. O.N.Bases(A)
#     core type: Operation
#     operator: 40
#     operand: 27
# 21. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 24
#     condition: 25
# 22. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. (A)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 28
#     operand: 32
# 25. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 70
#     operands: 30
# 26. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 84
#     end_index: 92
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. exists
#     core type: Literal
#     sub-expressions:
# 29. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 35
# 32. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 36\n    body: 37
# 33. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. O.N.Bases(B)
#     core type: Operation
#     operator: 40
#     operand: 46
# 35. a_{_a}
#     core type: IndexedVar
# variable: 86
# index: 76
# 36. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 43
#     condition: 44
# 38. Set
#     core type: Literal
#     sub-expressions:
# 39. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 40. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 41. (B)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 84
#     end_index: 85
# 43. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 50
#     operands: 51
# 45. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 84
#     end_index: 93
# 46. B
#     core type: Variable
#     sub-expressions:
# 47. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 66
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. and
#     core type: Literal
#     sub-expressions:
# 51. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 55
# 52. _a -> b_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 56
# 53. v
#     core type: Variable
#     sub-expressions:
# 54. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 57
#     operand: 60
# 55. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 84
#     end_index: 85
# 56. b_{_a}
#     core type: IndexedVar
# variable: 87
# index: 76
# 57. Sum
#     core type: Literal
#     sub-expressions:
# 58. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 76
#     body: 61
# 60. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 91
#     body: 62
# 61. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 70
#     operands: 63
# 62. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 64
#     condition: 65
# 63. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 68
#     operands: 69
# 65. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. lambda_{_a}
#     core type: IndexedVar
# variable: 77
# index: 76
# 67. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 68. *
#     core type: Literal
#     sub-expressions:
# 69. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 70. in
#     core type: Literal
#     sub-expressions:
# 71. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 91, 75
# 72. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 73. lambda_{i}
#     core type: IndexedVar
# variable: 77
# index: 91
# 74. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 80
#     operands: 81
# 76. _a
#     core type: Variable
#     sub-expressions:
# 77. lambda
#     core type: Variable
#     sub-expressions:
# 78. otimes
#     core type: Literal
#     sub-expressions:
# 79. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 80. Interval
#     core type: Literal
#     sub-expressions:
# 81. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 82. a_{i}
#     core type: IndexedVar
# variable: 86
# index: 91
# 83. b_{i}
#     core type: IndexedVar
# variable: 87
# index: 91
# 84. 1
#     core type: Literal
#     sub-expressions:
# 85. Min(m, n)
#     core type: Operation
#     operator: 89
#     operands: 90
# 86. a
#     core type: Variable
#     sub-expressions:
# 87. b
#     core type: Variable
#     sub-expressions:
# 88. (i)
#     core type: ExprTuple
#     sub-expressions: 91
# 89. Min
#     core type: Literal
#     sub-expressions:
# 90. (m, n)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 91. i
#     core type: Variable
#     sub-expressions:
# 92. m
#     core type: Variable
#     sub-expressions:
# 93. n
#     core type: Variable
#     sub-expressions:
