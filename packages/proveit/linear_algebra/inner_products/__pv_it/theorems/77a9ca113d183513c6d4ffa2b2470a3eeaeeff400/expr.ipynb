# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import Dim, HilbertSpaces, OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, Forall, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Forall(instance_param_or_params = [A, B], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), domain = TensorProd(A, B)), domain = HilbertSpaces, conditions = [Equals(Dim(A), m), Equals(Dim(B), n)]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{A, B \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(A\right) = m, \textrm{Dim}\left(B\right) = n}~\\
# \left[\forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Lambda
#    parameters: 32\n   body: 3
# 3. {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (A in_c HilbertSpaces) and (B in_c HilbertSpaces) and (Dim(A) = m) and (Dim(B) = n)
#    core type: Operation
#    operator: 69
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (A in_c HilbertSpaces, B in_c HilbertSpaces, Dim(A) = m, Dim(B) = n)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Lambda
#    parameter: 72
#    body: 15
# 10. A in_c HilbertSpaces
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. B in_c HilbertSpaces
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. Dim(A) = m
#     core type: Operation
#     operator: 67
#     operands: 19
# 13. Dim(B) = n
#     core type: Operation
#     operator: 67
#     operands: 20
# 14. (v)
#     core type: ExprTuple
#     sub-expressions: 72
# 15. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Conditional
#     value: 21
#     condition: 22
# 16. (A, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 46, 23
# 17. in_c
#     core type: Literal
#     sub-expressions:
# 18. (B, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 65, 23
# 19. (Dim(A), m)
#     core type: ExprTuple
#     sub-expressions: 24, 111
# 20. (Dim(B), n)
#     core type: ExprTuple
#     sub-expressions: 25, 112
# 21. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#     core type: Operation
#     operator: 47
#     operand: 29
# 22. v in (A otimes B)
#     core type: Operation
#     operator: 89
#     operands: 27
# 23. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 24. Dim(A)
#     core type: Operation
#     operator: 28
#     operand: 46
# 25. Dim(B)
#     core type: Operation
#     operator: 28
#     operand: 65
# 26. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. (v, A otimes B)
#     core type: ExprTuple
#     sub-expressions: 72, 30
# 28. Dim
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 41\n    body: 31
# 30. A otimes B
#     core type: Operation
#     operator: 97
#     operands: 32
# 31. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 33
#     condition: 34
# 32. (A, B)
#     core type: ExprTuple
#     sub-expressions: 46, 65
# 33. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 47
#     operand: 37
# 34. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 89
#     operands: 36
# 35. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 37
# 36. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 58\n    body: 40
# 38. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 57
#     operands: 41
# 39. O.N.Bases(A)
#     core type: Operation
#     operator: 59
#     operand: 46
# 40. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 43
#     condition: 44
# 41. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. (A)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 47
#     operand: 51
# 44. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 89
#     operands: 49
# 45. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 103
#     end_index: 111
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. exists
#     core type: Literal
#     sub-expressions:
# 48. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 54
# 51. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 55\n    body: 56
# 52. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. O.N.Bases(B)
#     core type: Operation
#     operator: 59
#     operand: 65
# 54. a_{_a}
#     core type: IndexedVar
# variable: 105
# index: 95
# 55. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 62
#     condition: 63
# 57. Set
#     core type: Literal
#     sub-expressions:
# 58. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 64
# 59. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 60. (B)
#     core type: ExprTuple
#     sub-expressions: 65
# 61. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 103
#     end_index: 104
# 62. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 69
#     operands: 70
# 64. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 103
#     end_index: 112
# 65. B
#     core type: Variable
#     sub-expressions:
# 66. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 85
# 67. =
#     core type: Literal
#     sub-expressions:
# 68. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 69. and
#     core type: Literal
#     sub-expressions:
# 70. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 74
# 71. _a -> b_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 75
# 72. v
#     core type: Variable
#     sub-expressions:
# 73. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 76
#     operand: 79
# 74. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 103
#     end_index: 104
# 75. b_{_a}
#     core type: IndexedVar
# variable: 106
# index: 95
# 76. Sum
#     core type: Literal
#     sub-expressions:
# 77. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 79
# 78. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 95
#     body: 80
# 79. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 110
#     body: 81
# 80. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 89
#     operands: 82
# 81. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 83
#     condition: 84
# 82. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 83. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 87
#     operands: 88
# 84. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 89
#     operands: 90
# 85. lambda_{_a}
#     core type: IndexedVar
# variable: 96
# index: 95
# 86. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 87. *
#     core type: Literal
#     sub-expressions:
# 88. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. in
#     core type: Literal
#     sub-expressions:
# 90. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 110, 94
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. lambda_{i}
#     core type: IndexedVar
# variable: 96
# index: 110
# 93. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. lambda
#     core type: Variable
#     sub-expressions:
# 97. otimes
#     core type: Literal
#     sub-expressions:
# 98. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. Interval
#     core type: Literal
#     sub-expressions:
# 100. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 101. a_{i}
#      core type: IndexedVar
# variable: 105
# index: 110
# 102. b_{i}
#      core type: IndexedVar
# variable: 106
# index: 110
# 103. 1
#      core type: Literal
#      sub-expressions:
# 104. Min(m, n)
#      core type: Operation
#      operator: 108
#      operands: 109
# 105. a
#      core type: Variable
#      sub-expressions:
# 106. b
#      core type: Variable
#      sub-expressions:
# 107. (i)
#      core type: ExprTuple
#      sub-expressions: 110
# 108. Min
#      core type: Literal
#      sub-expressions:
# 109. (m, n)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 110. i
#      core type: Variable
#      sub-expressions:
# 111. m
#      core type: Variable
#      sub-expressions:
# 112. n
#      core type: Variable
#      sub-expressions:
