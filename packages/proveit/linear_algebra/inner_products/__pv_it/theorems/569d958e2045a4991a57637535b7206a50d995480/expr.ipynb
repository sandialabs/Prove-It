# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Conditional(Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), InSet(Set(b_1_to_n), OrthoNormBases(B)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array} \textrm{ if } \left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#    core type: Operation
#    operator: 43
#    operands: 5
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. {b_{1}, b_{2}, ..., b_{n}}
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. O.N.Bases(B)
#    core type: Operation
#    operator: 13
#    operand: 19
# 9. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#    core type: ExprTuple
#    sub-expressions: 15
# 10. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 16
#     condition: 17
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 13. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 14. (B)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 57
#     end_index: 58
# 16. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 57
#     end_index: 66
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 39
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 28
# 25. _a -> b_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 29
# 26. v
#     core type: Variable
#     sub-expressions:
# 27. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 30
#     operand: 33
# 28. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 57
#     end_index: 58
# 29. b_{_a}
#     core type: IndexedVar
# variable: 60
# index: 49
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 32. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 49
#     body: 34
# 33. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 64
#     body: 35
# 34. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 43
#     operands: 36
# 35. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 37
#     condition: 38
# 36. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. lambda_{_a}
#     core type: IndexedVar
# variable: 50
# index: 49
# 40. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 64, 48
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. lambda_{i}
#     core type: IndexedVar
# variable: 50
# index: 64
# 47. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. _a
#     core type: Variable
#     sub-expressions:
# 50. lambda
#     core type: Variable
#     sub-expressions:
# 51. otimes
#     core type: Literal
#     sub-expressions:
# 52. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. a_{i}
#     core type: IndexedVar
# variable: 59
# index: 64
# 56. b_{i}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. Min(m, n)
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. b
#     core type: Variable
#     sub-expressions:
# 61. (i)
#     core type: ExprTuple
#     sub-expressions: 64
# 62. Min
#     core type: Literal
#     sub-expressions:
# 63. (m, n)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 64. i
#     core type: Variable
#     sub-expressions:
# 65. m
#     core type: Variable
#     sub-expressions:
# 66. n
#     core type: Variable
#     sub-expressions:
