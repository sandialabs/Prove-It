# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = OrthoProj(Hspace, Span(Set(x_i)))
expr = ExprTuple(Lambda([x_1_to_n], Conditional(Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), InSet(Set(x_1_to_n), OrthoNormBases(Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(x_{1}, x_{2}, \ldots, x_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \end{array}\right)\end{array} \textrm{ if } \left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 13\n   body: 2
# 2. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 63
#    operands: 7
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 9. {x_{1}, x_{2}, ..., x_{n}}
#    core type: Operation
#    operator: 82
#    operands: 13
# 10. O.N.Bases(H)
#     core type: Operation
#     operator: 14
#     operand: 75
# 11. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 18
#     condition: 19
# 13. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 14. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 15. (H)
#     core type: ExprTuple
#     sub-expressions: 75
# 16. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 77
#     end_index: 78
# 17. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 77
#     end_index: 78
# 18. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 24
#     operands: 23
# 19. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 77
#     end_index: 78
# 21. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 50
# 22. _a -> b_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 51
# 23. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))), B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. _a -> x_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 31
# 27. A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 77
#     end_index: 78
# 30. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 77
#     end_index: 78
# 31. x_{_a}
#     core type: IndexedVar
# variable: 85
# index: 59
# 32. (A, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (B, Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 41
# 36. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 42
# 37. A
#     core type: Variable
#     sub-expressions:
# 38. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 44
#     operand: 48
# 39. B
#     core type: Variable
#     sub-expressions:
# 40. Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 44
#     operand: 49
# 41. a_{_a} in Complex
#     core type: Operation
#     operator: 63
#     operands: 46
# 42. b_{_a} in Complex
#     core type: Operation
#     operator: 63
#     operands: 47
# 43. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 48
# 44. Sum
#     core type: Literal
#     sub-expressions:
# 45. (i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 47. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 53
# 49. i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 54
# 50. a_{_a}
#     core type: IndexedVar
# variable: 69
# index: 59
# 51. b_{_a}
#     core type: IndexedVar
# variable: 70
# index: 59
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 56
#     condition: 58
# 54. {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 57
#     condition: 58
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 56. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 61
#     operands: 60
# 57. b_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. i in {1 .. n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 65, 67
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (b_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 87, 68
# 65. a_{i}
#     core type: IndexedVar
# variable: 69
# index: 87
# 66. b_{i}
#     core type: IndexedVar
# variable: 70
# index: 87
# 67. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 74
# 69. a
#     core type: Variable
#     sub-expressions:
# 70. b
#     core type: Variable
#     sub-expressions:
# 71. OrthoProj
#     core type: Literal
#     sub-expressions:
# 72. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (1, n)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. H
#     core type: Variable
#     sub-expressions:
# 76. Span({x_{i}})
#     core type: Operation
#     operator: 79
#     operand: 81
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. n
#     core type: Variable
#     sub-expressions:
# 79. Span
#     core type: Literal
#     sub-expressions:
# 80. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 81
# 81. {x_{i}}
#     core type: Operation
#     operator: 82
#     operand: 84
# 82. Set
#     core type: Literal
#     sub-expressions:
# 83. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 84
# 84. x_{i}
#     core type: IndexedVar
# variable: 85
# index: 87
# 85. x
#     core type: Variable
#     sub-expressions:
# 86. (i)
#     core type: ExprTuple
#     sub-expressions: 87
# 87. i
#     core type: Variable
#     sub-expressions:
