# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Lambda, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import Dim, HilbertSpaces, OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import And, Equals, Exists, Forall, InClass, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Lambda([A, B], Conditional(Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), domain = TensorProd(A, B)), And(InClass(A, HilbertSpaces), InClass(B, HilbertSpaces), Equals(Dim(A), m), Equals(Dim(B), n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right] \textrm{ if } A \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  B \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  \textrm{Dim}\left(A\right) = m ,  \textrm{Dim}\left(B\right) = n\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Lambda
#    parameters: 30\n   body: 1
# 1. {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (A in_c HilbertSpaces) and (B in_c HilbertSpaces) and (Dim(A) = m) and (Dim(B) = n)
#    core type: Operation
#    operator: 67
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A in_c HilbertSpaces, B in_c HilbertSpaces, Dim(A) = m, Dim(B) = n)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Lambda
#    parameter: 70
#    body: 13
# 8. A in_c HilbertSpaces
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. B in_c HilbertSpaces
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. Dim(A) = m
#     core type: Operation
#     operator: 65
#     operands: 17
# 11. Dim(B) = n
#     core type: Operation
#     operator: 65
#     operands: 18
# 12. (v)
#     core type: ExprTuple
#     sub-expressions: 70
# 13. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Conditional
#     value: 19
#     condition: 20
# 14. (A, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 44, 21
# 15. in_c
#     core type: Literal
#     sub-expressions:
# 16. (B, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 63, 21
# 17. (Dim(A), m)
#     core type: ExprTuple
#     sub-expressions: 22, 109
# 18. (Dim(B), n)
#     core type: ExprTuple
#     sub-expressions: 23, 110
# 19. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#     core type: Operation
#     operator: 45
#     operand: 27
# 20. v in (A otimes B)
#     core type: Operation
#     operator: 87
#     operands: 25
# 21. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 22. Dim(A)
#     core type: Operation
#     operator: 26
#     operand: 44
# 23. Dim(B)
#     core type: Operation
#     operator: 26
#     operand: 63
# 24. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. (v, A otimes B)
#     core type: ExprTuple
#     sub-expressions: 70, 28
# 26. Dim
#     core type: Literal
#     sub-expressions:
# 27. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 39\n    body: 29
# 28. A otimes B
#     core type: Operation
#     operator: 95
#     operands: 30
# 29. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. (A, B)
#     core type: ExprTuple
#     sub-expressions: 44, 63
# 31. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 45
#     operand: 35
# 32. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 87
#     operands: 34
# 33. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 35
# 34. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 56\n    body: 38
# 36. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 55
#     operands: 39
# 37. O.N.Bases(A)
#     core type: Operation
#     operator: 57
#     operand: 44
# 38. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 41
#     condition: 42
# 39. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 43
# 40. (A)
#     core type: ExprTuple
#     sub-expressions: 44
# 41. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 45
#     operand: 49
# 42. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 87
#     operands: 47
# 43. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 101
#     end_index: 109
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. exists
#     core type: Literal
#     sub-expressions:
# 46. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. _a -> a_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 52
# 49. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 53\n    body: 54
# 50. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. O.N.Bases(B)
#     core type: Operation
#     operator: 57
#     operand: 63
# 52. a_{_a}
#     core type: IndexedVar
# variable: 103
# index: 93
# 53. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 59
# 54. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 60
#     condition: 61
# 55. Set
#     core type: Literal
#     sub-expressions:
# 56. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 57. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 58. (B)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 101
#     end_index: 102
# 60. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 101
#     end_index: 110
# 63. B
#     core type: Variable
#     sub-expressions:
# 64. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 83
# 65. =
#     core type: Literal
#     sub-expressions:
# 66. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 67. and
#     core type: Literal
#     sub-expressions:
# 68. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 72
# 69. _a -> b_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 73
# 70. v
#     core type: Variable
#     sub-expressions:
# 71. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 74
#     operand: 77
# 72. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 101
#     end_index: 102
# 73. b_{_a}
#     core type: IndexedVar
# variable: 104
# index: 93
# 74. Sum
#     core type: Literal
#     sub-expressions:
# 75. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 77
# 76. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 93
#     body: 78
# 77. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 108
#     body: 79
# 78. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 87
#     operands: 80
# 79. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 81
#     condition: 82
# 80. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 81. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 85
#     operands: 86
# 82. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 87
#     operands: 88
# 83. lambda_{_a}
#     core type: IndexedVar
# variable: 94
# index: 93
# 84. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 85. *
#     core type: Literal
#     sub-expressions:
# 86. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 87. in
#     core type: Literal
#     sub-expressions:
# 88. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 108, 92
# 89. (_a)
#     core type: ExprTuple
#     sub-expressions: 93
# 90. lambda_{i}
#     core type: IndexedVar
# variable: 94
# index: 108
# 91. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 95
#     operands: 96
# 92. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 97
#     operands: 98
# 93. _a
#     core type: Variable
#     sub-expressions:
# 94. lambda
#     core type: Variable
#     sub-expressions:
# 95. otimes
#     core type: Literal
#     sub-expressions:
# 96. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 97. Interval
#     core type: Literal
#     sub-expressions:
# 98. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. a_{i}
#     core type: IndexedVar
# variable: 103
# index: 108
# 100. b_{i}
#      core type: IndexedVar
# variable: 104
# index: 108
# 101. 1
#      core type: Literal
#      sub-expressions:
# 102. Min(m, n)
#      core type: Operation
#      operator: 106
#      operands: 107
# 103. a
#      core type: Variable
#      sub-expressions:
# 104. b
#      core type: Variable
#      sub-expressions:
# 105. (i)
#      core type: ExprTuple
#      sub-expressions: 108
# 106. Min
#      core type: Literal
#      sub-expressions:
# 107. (m, n)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 108. i
#      core type: Variable
#      sub-expressions:
# 109. m
#      core type: Variable
#      sub-expressions:
# 110. n
#      core type: Variable
#      sub-expressions:
