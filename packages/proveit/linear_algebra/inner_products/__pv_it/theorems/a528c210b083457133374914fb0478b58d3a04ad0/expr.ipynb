# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, ExprTuple, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Hspace, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = ExprTuple(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right), \begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (M* o M) = (M o M*)
#    core type: Operation
#    operator: 33
#    operands: 3
# 2. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#    core type: Operation
#    operator: 17
#    operand: 7
# 3. (M* o M, M o M*)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. M* o M
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. M o M*
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 25\n   body: 11
# 8. (M*, M)
#    core type: ExprTuple
#    sub-expressions: 12, 38
# 9. o
#    core type: Literal
#    sub-expressions:
# 10. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 38, 12
# 11. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. M*
#     core type: Operation
#     operator: 15
#     operand: 38
# 13. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 55
#     operands: 19
# 15. Adj
#     core type: Literal
#     sub-expressions:
# 16. (M)
#     core type: ExprTuple
#     sub-expressions: 38
# 17. exists
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 21. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 74
#     operands: 25
# 22. O.N.Bases(H)
#     core type: Operation
#     operator: 26
#     operand: 67
# 23. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 26. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 27. (H)
#     core type: ExprTuple
#     sub-expressions: 67
# 28. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 69
#     end_index: 70
# 29. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 69
#     end_index: 70
# 32. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 51
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 40
# 37. _a -> x_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 41
# 38. M
#     core type: Variable
#     sub-expressions:
# 39. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 42
#     operand: 45
# 40. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 69
#     end_index: 70
# 41. x_{_a}
#     core type: IndexedVar
# variable: 77
# index: 61
# 42. Sum
#     core type: Literal
#     sub-expressions:
# 43. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 46
# 45. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 79
#     body: 47
# 46. a_{_a} in Complex
#     core type: Operation
#     operator: 55
#     operands: 48
# 47. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 49
#     condition: 50
# 48. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. i in {1 .. n}
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. a_{_a}
#     core type: IndexedVar
# variable: 62
# index: 61
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 79, 60
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 58. a_{i}
#     core type: IndexedVar
# variable: 62
# index: 79
# 59. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. {1 .. n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. OrthoProj
#     core type: Literal
#     sub-expressions:
# 64. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (1, n)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 67. H
#     core type: Variable
#     sub-expressions:
# 68. Span({x_{i}})
#     core type: Operation
#     operator: 71
#     operand: 73
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. n
#     core type: Variable
#     sub-expressions:
# 71. Span
#     core type: Literal
#     sub-expressions:
# 72. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 73
# 73. {x_{i}}
#     core type: Operation
#     operator: 74
#     operand: 76
# 74. Set
#     core type: Literal
#     sub-expressions:
# 75. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 76
# 76. x_{i}
#     core type: IndexedVar
# variable: 77
# index: 79
# 77. x
#     core type: Variable
#     sub-expressions:
# 78. (i)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. i
#     core type: Variable
#     sub-expressions:
