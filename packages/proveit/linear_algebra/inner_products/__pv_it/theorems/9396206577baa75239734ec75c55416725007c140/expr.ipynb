# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Conditional(Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), InSet(M, LinMap(Hspace, Hspace)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. M in LINMAP(H, H)
#    core type: Operation
#    operator: 63
#    operands: 5
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (M, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 46, 8
# 6. (M* o M) = (M o M*)
#    core type: Operation
#    operator: 41
#    operands: 9
# 7. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#    core type: Operation
#    operator: 25
#    operand: 15
# 8. LINMAP(H, H)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (M* o M, M o M*)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. LINMAP
#     core type: Literal
#     sub-expressions:
# 12. (H, H)
#     core type: ExprTuple
#     sub-expressions: 75, 75
# 13. M* o M
#     core type: Operation
#     operator: 17
#     operands: 16
# 14. M o M*
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 33\n    body: 19
# 16. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 20, 46
# 17. o
#     core type: Literal
#     sub-expressions:
# 18. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 46, 20
# 19. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. M*
#     core type: Operation
#     operator: 23
#     operand: 46
# 21. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 25
#     operand: 28
# 22. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 63
#     operands: 27
# 23. Adj
#     core type: Literal
#     sub-expressions:
# 24. (M)
#     core type: ExprTuple
#     sub-expressions: 46
# 25. exists
#     core type: Literal
#     sub-expressions:
# 26. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 31\n    body: 32
# 29. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 82
#     operands: 33
# 30. O.N.Bases(H)
#     core type: Operation
#     operator: 34
#     operand: 75
# 31. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 37
#     condition: 38
# 33. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 35. (H)
#     core type: ExprTuple
#     sub-expressions: 75
# 36. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 77
#     end_index: 78
# 37. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 77
#     end_index: 78
# 40. _a -> a_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 59
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. and
#     core type: Literal
#     sub-expressions:
# 44. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 48
# 45. _a -> x_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 49
# 46. M
#     core type: Variable
#     sub-expressions:
# 47. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 50
#     operand: 53
# 48. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 77
#     end_index: 78
# 49. x_{_a}
#     core type: IndexedVar
# variable: 85
# index: 69
# 50. Sum
#     core type: Literal
#     sub-expressions:
# 51. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 54
# 53. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 55
# 54. a_{_a} in Complex
#     core type: Operation
#     operator: 63
#     operands: 56
# 55. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 57
#     condition: 58
# 56. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. i in {1 .. n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. a_{_a}
#     core type: IndexedVar
# variable: 70
# index: 69
# 60. Complex
#     core type: Literal
#     sub-expressions:
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 87, 68
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 66. a_{i}
#     core type: IndexedVar
# variable: 70
# index: 87
# 67. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 74
# 69. _a
#     core type: Variable
#     sub-expressions:
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. OrthoProj
#     core type: Literal
#     sub-expressions:
# 72. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (1, n)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. H
#     core type: Variable
#     sub-expressions:
# 76. Span({x_{i}})
#     core type: Operation
#     operator: 79
#     operand: 81
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. n
#     core type: Variable
#     sub-expressions:
# 79. Span
#     core type: Literal
#     sub-expressions:
# 80. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 81
# 81. {x_{i}}
#     core type: Operation
#     operator: 82
#     operand: 84
# 82. Set
#     core type: Literal
#     sub-expressions:
# 83. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 84
# 84. x_{i}
#     core type: IndexedVar
# variable: 85
# index: 87
# 85. x
#     core type: Variable
#     sub-expressions:
# 86. (i)
#     core type: ExprTuple
#     sub-expressions: 87
# 87. i
#     core type: Variable
#     sub-expressions:
