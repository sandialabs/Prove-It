# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda([x_1_to_n], Conditional(Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), InSet(Set(x_1_to_n), OrthoNormBases(Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(x_{1}, x_{2}, \ldots, x_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array} \textrm{ if } \left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 42
#    operands: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. {x_{1}, x_{2}, ..., x_{n}}
#    core type: Operation
#    operator: 61
#    operands: 12
# 9. O.N.Bases(H)
#    core type: Operation
#    operator: 13
#    operand: 54
# 10. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 11. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 16
#     condition: 17
# 12. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 13. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 14. (H)
#     core type: ExprTuple
#     sub-expressions: 54
# 15. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 56
#     end_index: 57
# 16. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 56
#     end_index: 57
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 38
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 27
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 28
# 25. M
#     core type: Variable
#     sub-expressions:
# 26. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 29
#     operand: 32
# 27. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 56
#     end_index: 57
# 28. x_{_a}
#     core type: IndexedVar
# variable: 64
# index: 48
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 48
#     body: 33
# 32. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 66
#     body: 34
# 33. a_{_a} in Complex
#     core type: Operation
#     operator: 42
#     operands: 35
# 34. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 36
#     condition: 37
# 35. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. i in {1 .. n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. a_{_a}
#     core type: IndexedVar
# variable: 49
# index: 48
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. *
#     core type: Literal
#     sub-expressions:
# 41. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 66, 47
# 44. (_a)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. a_{i}
#     core type: IndexedVar
# variable: 49
# index: 66
# 46. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. {1 .. n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. _a
#     core type: Variable
#     sub-expressions:
# 49. a
#     core type: Variable
#     sub-expressions:
# 50. OrthoProj
#     core type: Literal
#     sub-expressions:
# 51. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (1, n)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. H
#     core type: Variable
#     sub-expressions:
# 55. Span({x_{i}})
#     core type: Operation
#     operator: 58
#     operand: 60
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. Span
#     core type: Literal
#     sub-expressions:
# 59. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 60
# 60. {x_{i}}
#     core type: Operation
#     operator: 61
#     operand: 63
# 61. Set
#     core type: Literal
#     sub-expressions:
# 62. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 63
# 63. x_{i}
#     core type: IndexedVar
# variable: 64
# index: 66
# 64. x
#     core type: Variable
#     sub-expressions:
# 65. (i)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. i
#     core type: Variable
#     sub-expressions:
