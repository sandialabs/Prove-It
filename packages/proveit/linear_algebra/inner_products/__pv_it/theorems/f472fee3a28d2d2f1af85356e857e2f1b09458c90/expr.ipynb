# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import Dim, HilbertSpaces, OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import And, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Interval, Min, NaturalPos, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), domain = TensorProd(A, B)), domain = HilbertSpaces, conditions = [Equals(Dim(A), m), Equals(Dim(B), n)]).with_wrapping(), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{A, B \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(A\right) = m, \textrm{Dim}\left(B\right) = n}~\\
# \left[\forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\right]\end{array} \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]]
#    core type: Operation
#    operator: 14
#    operand: 5
# 2. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 77
#    operands: 4
# 3. ((A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Lambda
#    parameters: 40\n   body: 8
# 6. m in NaturalPos
#    core type: Operation
#    operator: 97
#    operands: 9
# 7. n in NaturalPos
#    core type: Operation
#    operator: 97
#    operands: 10
# 8. {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 119, 13
# 10. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 120, 13
# 11. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#     core type: Operation
#     operator: 14
#     operand: 17
# 12. (A in_c HilbertSpaces) and (B in_c HilbertSpaces) and (Dim(A) = m) and (Dim(B) = n)
#     core type: Operation
#     operator: 77
#     operands: 16
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (A in_c HilbertSpaces, B in_c HilbertSpaces, Dim(A) = m, Dim(B) = n)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20, 21
# 17. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Lambda
#     parameter: 80
#     body: 23
# 18. A in_c HilbertSpaces
#     core type: Operation
#     operator: 25
#     operands: 24
# 19. B in_c HilbertSpaces
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. Dim(A) = m
#     core type: Operation
#     operator: 75
#     operands: 27
# 21. Dim(B) = n
#     core type: Operation
#     operator: 75
#     operands: 28
# 22. (v)
#     core type: ExprTuple
#     sub-expressions: 80
# 23. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Conditional
#     value: 29
#     condition: 30
# 24. (A, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 54, 31
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (B, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 73, 31
# 27. (Dim(A), m)
#     core type: ExprTuple
#     sub-expressions: 32, 119
# 28. (Dim(B), n)
#     core type: ExprTuple
#     sub-expressions: 33, 120
# 29. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#     core type: Operation
#     operator: 55
#     operand: 37
# 30. v in (A otimes B)
#     core type: Operation
#     operator: 97
#     operands: 35
# 31. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 32. Dim(A)
#     core type: Operation
#     operator: 36
#     operand: 54
# 33. Dim(B)
#     core type: Operation
#     operator: 36
#     operand: 73
# 34. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. (v, A otimes B)
#     core type: ExprTuple
#     sub-expressions: 80, 38
# 36. Dim
#     core type: Literal
#     sub-expressions:
# 37. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 49\n    body: 39
# 38. A otimes B
#     core type: Operation
#     operator: 105
#     operands: 40
# 39. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 41
#     condition: 42
# 40. (A, B)
#     core type: ExprTuple
#     sub-expressions: 54, 73
# 41. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 55
#     operand: 45
# 42. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 97
#     operands: 44
# 43. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 66\n    body: 48
# 46. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 65
#     operands: 49
# 47. O.N.Bases(A)
#     core type: Operation
#     operator: 67
#     operand: 54
# 48. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 51
#     condition: 52
# 49. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. (A)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 55
#     operand: 59
# 52. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 97
#     operands: 57
# 53. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 111
#     end_index: 119
# 54. A
#     core type: Variable
#     sub-expressions:
# 55. exists
#     core type: Literal
#     sub-expressions:
# 56. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 59
# 57. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 103
#     body: 62
# 59. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 63\n    body: 64
# 60. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. O.N.Bases(B)
#     core type: Operation
#     operator: 67
#     operand: 73
# 62. a_{_a}
#     core type: IndexedVar
# variable: 113
# index: 103
# 63. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 69
# 64. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 70
#     condition: 71
# 65. Set
#     core type: Literal
#     sub-expressions:
# 66. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 72
# 67. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 68. (B)
#     core type: ExprTuple
#     sub-expressions: 73
# 69. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 111
#     end_index: 112
# 70. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 75
#     operands: 76
# 71. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 77
#     operands: 78
# 72. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 79
#     start_index: 111
#     end_index: 120
# 73. B
#     core type: Variable
#     sub-expressions:
# 74. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 103
#     body: 93
# 75. =
#     core type: Literal
#     sub-expressions:
# 76. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 77. and
#     core type: Literal
#     sub-expressions:
# 78. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 82
# 79. _a -> b_{_a}
#     core type: Lambda
#     parameter: 103
#     body: 83
# 80. v
#     core type: Variable
#     sub-expressions:
# 81. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 84
#     operand: 87
# 82. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 86
#     start_index: 111
#     end_index: 112
# 83. b_{_a}
#     core type: IndexedVar
# variable: 114
# index: 103
# 84. Sum
#     core type: Literal
#     sub-expressions:
# 85. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 87
# 86. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 103
#     body: 88
# 87. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 118
#     body: 89
# 88. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 97
#     operands: 90
# 89. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 91
#     condition: 92
# 90. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 91. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 95
#     operands: 96
# 92. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 97
#     operands: 98
# 93. lambda_{_a}
#     core type: IndexedVar
# variable: 104
# index: 103
# 94. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 95. *
#     core type: Literal
#     sub-expressions:
# 96. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 97. in
#     core type: Literal
#     sub-expressions:
# 98. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 118, 102
# 99. (_a)
#     core type: ExprTuple
#     sub-expressions: 103
# 100. lambda_{i}
#      core type: IndexedVar
# variable: 104
# index: 118
# 101. a_{i} otimes b_{i}
#      core type: Operation
#      operator: 105
#      operands: 106
# 102. {1 .. Min(m, n)}
#      core type: Operation
#      operator: 107
#      operands: 108
# 103. _a
#      core type: Variable
#      sub-expressions:
# 104. lambda
#      core type: Variable
#      sub-expressions:
# 105. otimes
#      core type: Literal
#      sub-expressions:
# 106. (a_{i}, b_{i})
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 107. Interval
#      core type: Literal
#      sub-expressions:
# 108. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 109. a_{i}
#      core type: IndexedVar
# variable: 113
# index: 118
# 110. b_{i}
#      core type: IndexedVar
# variable: 114
# index: 118
# 111. 1
#      core type: Literal
#      sub-expressions:
# 112. Min(m, n)
#      core type: Operation
#      operator: 116
#      operands: 117
# 113. a
#      core type: Variable
#      sub-expressions:
# 114. b
#      core type: Variable
#      sub-expressions:
# 115. (i)
#      core type: ExprTuple
#      sub-expressions: 118
# 116. Min
#      core type: Literal
#      sub-expressions:
# 117. (m, n)
#      core type: ExprTuple
#      sub-expressions: 119, 120
# 118. i
#      core type: Variable
#      sub-expressions:
# 119. m
#      core type: Variable
#      sub-expressions:
# 120. n
#      core type: Variable
#      sub-expressions:
