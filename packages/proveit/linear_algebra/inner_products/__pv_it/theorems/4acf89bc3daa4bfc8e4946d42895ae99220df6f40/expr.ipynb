# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Commutator, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = OrthoProj(Hspace, Span(Set(x_i)))
expr = Lambda([A, B], Conditional(Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), And(InSet(A, sub_expr2), InSet(B, sub_expr2), Equals(Adj(A), A), Equals(Adj(B), B))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# ...

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 25\n   body: 1
# 1. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 2
#    condition: 3
# ...
