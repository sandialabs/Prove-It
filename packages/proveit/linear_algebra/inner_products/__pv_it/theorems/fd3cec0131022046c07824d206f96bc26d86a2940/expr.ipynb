# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Commutator, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = OrthoProj(Hspace, Span(Set(x_i)))
expr = Conditional(Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), And(InSet(A, sub_expr2), InSet(B, sub_expr2), Equals(Adj(A), A), Equals(Adj(B), B)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } A \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right) ,  B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right) ,  A^{\dagger} = A ,  B^{\dagger} = B\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#    core type: Operation
#    operator: 55
#    operands: 5
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. ([A, B] = 0(LINMAP(H, H)), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 6. [A, B] = 0(LINMAP(H, H))
#    core type: Operation
#    operator: 64
#    operands: 12
# 7. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]
#    core type: Operation
#    operator: 36
#    operand: 20
# 8. A in LINMAP(H, H)
#    core type: Operation
#    operator: 94
#    operands: 14
# 9. B in LINMAP(H, H)
#    core type: Operation
#    operator: 94
#    operands: 15
# 10. A* = A
#     core type: Operation
#     operator: 64
#     operands: 16
# 11. B* = B
#     core type: Operation
#     operator: 64
#     operands: 17
# 12. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 20
# 14. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 68, 31
# 15. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 70, 31
# 16. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 21, 68
# 17. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 22, 70
# 18. [A, B]
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 25
#     operand: 31
# 20. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 44\n    body: 27
# 21. A*
#     core type: Operation
#     operator: 29
#     operand: 68
# 22. B*
#     core type: Operation
#     operator: 29
#     operand: 70
# 23. commutator
#     core type: Literal
#     sub-expressions:
# 24. (A, B)
#     core type: ExprTuple
#     sub-expressions: 68, 70
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 31
# 27. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 32
#     condition: 33
# 28. (A)
#     core type: ExprTuple
#     sub-expressions: 68
# 29. Adj
#     core type: Literal
#     sub-expressions:
# 30. (B)
#     core type: ExprTuple
#     sub-expressions: 70
# 31. LINMAP(H, H)
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))
#     core type: Operation
#     operator: 36
#     operand: 39
# 33. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 94
#     operands: 38
# 34. LINMAP
#     core type: Literal
#     sub-expressions:
# 35. (H, H)
#     core type: ExprTuple
#     sub-expressions: 106, 106
# 36. exists
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 39
# 38. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 42\n    body: 43
# 40. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 113
#     operands: 44
# 41. O.N.Bases(H)
#     core type: Operation
#     operator: 45
#     operand: 106
# 42. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 43. {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 49
#     condition: 50
# 44. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 51
# 45. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 46. (H)
#     core type: ExprTuple
#     sub-expressions: 106
# 47. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 108
#     end_index: 109
# 48. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 108
#     end_index: 109
# 49. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 55
#     operands: 54
# 50. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 108
#     end_index: 109
# 52. _a -> a_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 81
# 53. _a -> b_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 82
# 54. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))), B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. and
#     core type: Literal
#     sub-expressions:
# 56. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. _a -> x_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 62
# 58. A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 64
#     operands: 63
# 59. B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 108
#     end_index: 109
# 61. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 108
#     end_index: 109
# 62. x_{_a}
#     core type: IndexedVar
# variable: 116
# index: 90
# 63. (A, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. =
#     core type: Literal
#     sub-expressions:
# 65. (B, Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 66. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 90
#     body: 72
# 67. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 90
#     body: 73
# 68. A
#     core type: Variable
#     sub-expressions:
# 69. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 75
#     operand: 79
# 70. B
#     core type: Variable
#     sub-expressions:
# 71. Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 75
#     operand: 80
# 72. a_{_a} in Complex
#     core type: Operation
#     operator: 94
#     operands: 77
# 73. b_{_a} in Complex
#     core type: Operation
#     operator: 94
#     operands: 78
# 74. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 79
# 75. Sum
#     core type: Literal
#     sub-expressions:
# 76. (i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 80
# 77. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 81, 83
# 78. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 79. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 118
#     body: 84
# 80. i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 118
#     body: 85
# 81. a_{_a}
#     core type: IndexedVar
# variable: 100
# index: 90
# 82. b_{_a}
#     core type: IndexedVar
# variable: 101
# index: 90
# 83. Complex
#     core type: Literal
#     sub-expressions:
# 84. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 87
#     condition: 89
# 85. {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 88
#     condition: 89
# 86. (_a)
#     core type: ExprTuple
#     sub-expressions: 90
# 87. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 92
#     operands: 91
# 88. b_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 92
#     operands: 93
# 89. i in {1 .. n}
#     core type: Operation
#     operator: 94
#     operands: 95
# 90. _a
#     core type: Variable
#     sub-expressions:
# 91. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 96, 98
# 92. *
#     core type: Literal
#     sub-expressions:
# 93. (b_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 97, 98
# 94. in
#     core type: Literal
#     sub-expressions:
# 95. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 118, 99
# 96. a_{i}
#     core type: IndexedVar
# variable: 100
# index: 118
# 97. b_{i}
#     core type: IndexedVar
# variable: 101
# index: 118
# 98. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 102
#     operands: 103
# 99. {1 .. n}
#     core type: Operation
#     operator: 104
#     operands: 105
# 100. a
#      core type: Variable
#      sub-expressions:
# 101. b
#      core type: Variable
#      sub-expressions:
# 102. OrthoProj
#      core type: Literal
#      sub-expressions:
# 103. (H, Span({x_{i}}))
#      core type: ExprTuple
#      sub-expressions: 106, 107
# 104. Interval
#      core type: Literal
#      sub-expressions:
# 105. (1, n)
#      core type: ExprTuple
#      sub-expressions: 108, 109
# 106. H
#      core type: Variable
#      sub-expressions:
# 107. Span({x_{i}})
#      core type: Operation
#      operator: 110
#      operand: 112
# 108. 1
#      core type: Literal
#      sub-expressions:
# 109. n
#      core type: Variable
#      sub-expressions:
# 110. Span
#      core type: Literal
#      sub-expressions:
# 111. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 112
# 112. {x_{i}}
#      core type: Operation
#      operator: 113
#      operand: 115
# 113. Set
#      core type: Literal
#      sub-expressions:
# 114. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 115
# 115. x_{i}
#      core type: IndexedVar
# variable: 116
# index: 118
# 116. x
#      core type: Variable
#      sub-expressions:
# 117. (i)
#      core type: ExprTuple
#      sub-expressions: 118
# 118. i
#      core type: Variable
#      sub-expressions:
