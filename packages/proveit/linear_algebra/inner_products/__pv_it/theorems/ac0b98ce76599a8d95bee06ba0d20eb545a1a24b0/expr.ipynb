# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])]
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. n in NaturalPos
#    core type: Operation
#    operator: 85
#    operands: 4
# 3. (H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 100, 6
# 5. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 97
#    body: 7
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 65
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Lambda
#     parameter: 68
#     body: 16
# 14. H in_c HilbertSpaces
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Dim(H) = n
#     core type: Operation
#     operator: 63
#     operands: 19
# 16. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. in_c
#     core type: Literal
#     sub-expressions:
# 18. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 97, 22
# 19. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 23, 100
# 20. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. M in LINMAP(H, H)
#     core type: Operation
#     operator: 85
#     operands: 26
# 22. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 23. Dim(H)
#     core type: Operation
#     operator: 27
#     operand: 97
# 24. <=>
#     core type: Literal
#     sub-expressions:
# 25. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 68, 30
# 27. Dim
#     core type: Literal
#     sub-expressions:
# 28. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 63
#     operands: 31
# 29. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 47
#     operand: 37
# 30. LINMAP(H, H)
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. LINMAP
#     core type: Literal
#     sub-expressions:
# 34. (H, H)
#     core type: ExprTuple
#     sub-expressions: 97, 97
# 35. M* o M
#     core type: Operation
#     operator: 39
#     operands: 38
# 36. M o M*
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 55\n    body: 41
# 38. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 42, 68
# 39. o
#     core type: Literal
#     sub-expressions:
# 40. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 68, 42
# 41. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. M*
#     core type: Operation
#     operator: 45
#     operand: 68
# 43. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 47
#     operand: 50
# 44. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 85
#     operands: 49
# 45. Adj
#     core type: Literal
#     sub-expressions:
# 46. (M)
#     core type: ExprTuple
#     sub-expressions: 68
# 47. exists
#     core type: Literal
#     sub-expressions:
# 48. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 50
# 49. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 53\n    body: 54
# 51. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 104
#     operands: 55
# 52. O.N.Bases(H)
#     core type: Operation
#     operator: 56
#     operand: 97
# 53. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 58
# 54. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 59
#     condition: 60
# 55. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 57. (H)
#     core type: ExprTuple
#     sub-expressions: 97
# 58. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 99
#     end_index: 100
# 59. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 99
#     end_index: 100
# 62. _a -> a_{_a}
#     core type: Lambda
#     parameter: 91
#     body: 81
# 63. =
#     core type: Literal
#     sub-expressions:
# 64. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. and
#     core type: Literal
#     sub-expressions:
# 66. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 70
# 67. _a -> x_{_a}
#     core type: Lambda
#     parameter: 91
#     body: 71
# 68. M
#     core type: Variable
#     sub-expressions:
# 69. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 72
#     operand: 75
# 70. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 99
#     end_index: 100
# 71. x_{_a}
#     core type: IndexedVar
# variable: 107
# index: 91
# 72. Sum
#     core type: Literal
#     sub-expressions:
# 73. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 75
# 74. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 91
#     body: 76
# 75. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 109
#     body: 77
# 76. a_{_a} in Complex
#     core type: Operation
#     operator: 85
#     operands: 78
# 77. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 79
#     condition: 80
# 78. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 79. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 83
#     operands: 84
# 80. i in {1 .. n}
#     core type: Operation
#     operator: 85
#     operands: 86
# 81. a_{_a}
#     core type: IndexedVar
# variable: 92
# index: 91
# 82. Complex
#     core type: Literal
#     sub-expressions:
# 83. *
#     core type: Literal
#     sub-expressions:
# 84. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 85. in
#     core type: Literal
#     sub-expressions:
# 86. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 109, 90
# 87. (_a)
#     core type: ExprTuple
#     sub-expressions: 91
# 88. a_{i}
#     core type: IndexedVar
# variable: 92
# index: 109
# 89. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 93
#     operands: 94
# 90. {1 .. n}
#     core type: Operation
#     operator: 95
#     operands: 96
# 91. _a
#     core type: Variable
#     sub-expressions:
# 92. a
#     core type: Variable
#     sub-expressions:
# 93. OrthoProj
#     core type: Literal
#     sub-expressions:
# 94. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 97, 98
# 95. Interval
#     core type: Literal
#     sub-expressions:
# 96. (1, n)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 97. H
#     core type: Variable
#     sub-expressions:
# 98. Span({x_{i}})
#     core type: Operation
#     operator: 101
#     operand: 103
# 99. 1
#     core type: Literal
#     sub-expressions:
# 100. n
#      core type: Variable
#      sub-expressions:
# 101. Span
#      core type: Literal
#      sub-expressions:
# 102. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 103
# 103. {x_{i}}
#      core type: Operation
#      operator: 104
#      operand: 106
# 104. Set
#      core type: Literal
#      sub-expressions:
# 105. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 106
# 106. x_{i}
#      core type: IndexedVar
# variable: 107
# index: 109
# 107. x
#      core type: Variable
#      sub-expressions:
# 108. (i)
#      core type: ExprTuple
#      sub-expressions: 109
# 109. i
#      core type: Variable
#      sub-expressions:
