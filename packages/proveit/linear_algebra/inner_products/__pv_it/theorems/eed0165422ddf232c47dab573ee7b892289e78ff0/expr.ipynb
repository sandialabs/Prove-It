# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import H, K, n, v
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Dim, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Exists, Forall, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [H], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [x_1_to_n], instance_expr = And(InSet(v, sub_expr1), InSet(sub_expr1, OrthoNormBases(H))).with_wrapping_at(2)), domain = H), domain = InnerProdSpaces(K), condition = Equals(Dim(H), n)).with_wrapping(), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)~|~\textrm{Dim}\left(H\right) = n}~\\
# \left[\forall_{v \in H}~\left[\exists_{x_{1}, x_{2}, \ldots, x_{n}}~\left(\begin{array}{c} \left(v \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) \end{array}\right)\right]\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (K -> [forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]]
#    core type: Lambda
#    parameter: 40
#    body: 3
# 3. forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]
#    core type: Operation
#    operator: 17
#    operand: 5
# 4. (n -> {forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. n -> {forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 60
#    body: 7
# 6. (n)
#    core type: ExprTuple
#    sub-expressions: 60
# 7. {forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]] if n in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]
#    core type: Operation
#    operator: 17
#    operand: 12
# 9. n in NaturalPos
#    core type: Operation
#    operator: 47
#    operands: 11
# 10. (H -> {forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))] if H in_c InnerProdSpaces(K) ,  Dim(H) = n.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 60, 13
# 12. H -> {forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))] if H in_c InnerProdSpaces(K) ,  Dim(H) = n.
#     core type: Lambda
#     parameter: 57
#     body: 14
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. {forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))] if H in_c InnerProdSpaces(K) ,  Dim(H) = n.
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (H in_c InnerProdSpaces(K)) and (Dim(H) = n)
#     core type: Operation
#     operator: 42
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (v -> {exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))) if v in H.)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (H in_c InnerProdSpaces(K), Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. v -> {exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))) if v in H.
#     core type: Lambda
#     parameter: 49
#     body: 24
# 21. H in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. Dim(H) = n
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. (v)
#     core type: ExprTuple
#     sub-expressions: 49
# 24. {exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))) if v in H.
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (H, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 57, 31
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 32, 60
# 29. exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))
#     core type: Operation
#     operator: 33
#     operand: 39
# 30. v in H
#     core type: Operation
#     operator: 47
#     operands: 35
# 31. InnerProdSpaces(K)
#     core type: Operation
#     operator: 36
#     operand: 40
# 32. Dim(H)
#     core type: Operation
#     operator: 38
#     operand: 57
# 33. exists
#     core type: Literal
#     sub-expressions:
# 34. ((x_{1}, x_{2}, ..., x_{n}) -> ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))))
#     core type: ExprTuple
#     sub-expressions: 39
# 35. (v, H)
#     core type: ExprTuple
#     sub-expressions: 49, 57
# 36. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 37. (K)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. Dim
#     core type: Literal
#     sub-expressions:
# 39. (x_{1}, x_{2}, ..., x_{n}) -> ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))
#     core type: Lambda
#     parameters: 53\n    body: 41
# 40. K
#     core type: Variable
#     sub-expressions:
# 41. (v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. (v in {x_{1}, x_{2}, ..., x_{n}}, {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. v in {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 47
#     operands: 46
# 45. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. (v, {x_{1}, x_{2}, ..., x_{n}})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 49. v
#     core type: Variable
#     sub-expressions:
# 50. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. O.N.Bases(H)
#     core type: Operation
#     operator: 54
#     operand: 57
# 52. Set
#     core type: Literal
#     sub-expressions:
# 53. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 54. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 55. (H)
#     core type: ExprTuple
#     sub-expressions: 57
# 56. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 57. H
#     core type: Variable
#     sub-expressions:
# 58. _a -> x_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 61
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. n
#     core type: Variable
#     sub-expressions:
# 61. x_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
