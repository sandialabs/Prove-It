# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Lambda, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Lambda(v, Conditional(Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), InSet(v, TensorProd(A, B))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# v \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array} \textrm{ if } v \in \left(A {\otimes} B\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Lambda
#    parameter: 50
#    body: 2
# 1. (v)
#    core type: ExprTuple
#    sub-expressions: 50
# 2. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#    core type: Operation
#    operator: 25
#    operand: 7
# 4. v in (A otimes B)
#    core type: Operation
#    operator: 67
#    operands: 6
# 5. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (v, A otimes B)
#    core type: ExprTuple
#    sub-expressions: 50, 8
# 7. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#    core type: Lambda
#    parameters: 19\n   body: 9
# 8. A otimes B
#    core type: Operation
#    operator: 75
#    operands: 10
# 9. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 24, 43
# 11. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 25
#     operand: 15
# 12. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 67
#     operands: 14
# 13. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 36\n    body: 18
# 16. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 35
#     operands: 19
# 17. O.N.Bases(A)
#     core type: Operation
#     operator: 37
#     operand: 24
# 18. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (A)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 25
#     operand: 29
# 22. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 67
#     operands: 27
# 23. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 81
#     end_index: 89
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. exists
#     core type: Literal
#     sub-expressions:
# 26. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 32
# 29. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 30. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. O.N.Bases(B)
#     core type: Operation
#     operator: 37
#     operand: 43
# 32. a_{_a}
#     core type: IndexedVar
# variable: 83
# index: 73
# 33. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 40
#     condition: 41
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 38. (B)
#     core type: ExprTuple
#     sub-expressions: 43
# 39. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 81
#     end_index: 82
# 40. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 81
#     end_index: 90
# 43. B
#     core type: Variable
#     sub-expressions:
# 44. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 63
# 45. =
#     core type: Literal
#     sub-expressions:
# 46. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. and
#     core type: Literal
#     sub-expressions:
# 48. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 52
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 53
# 50. v
#     core type: Variable
#     sub-expressions:
# 51. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 54
#     operand: 57
# 52. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 81
#     end_index: 82
# 53. b_{_a}
#     core type: IndexedVar
# variable: 84
# index: 73
# 54. Sum
#     core type: Literal
#     sub-expressions:
# 55. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 57
# 56. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 73
#     body: 58
# 57. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 88
#     body: 59
# 58. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 67
#     operands: 60
# 59. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 61
#     condition: 62
# 60. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 65
#     operands: 66
# 62. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. lambda_{_a}
#     core type: IndexedVar
# variable: 74
# index: 73
# 64. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 67. in
#     core type: Literal
#     sub-expressions:
# 68. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 88, 72
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 70. lambda_{i}
#     core type: IndexedVar
# variable: 74
# index: 88
# 71. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 75
#     operands: 76
# 72. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 77
#     operands: 78
# 73. _a
#     core type: Variable
#     sub-expressions:
# 74. lambda
#     core type: Variable
#     sub-expressions:
# 75. otimes
#     core type: Literal
#     sub-expressions:
# 76. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. Interval
#     core type: Literal
#     sub-expressions:
# 78. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 79. a_{i}
#     core type: IndexedVar
# variable: 83
# index: 88
# 80. b_{i}
#     core type: IndexedVar
# variable: 84
# index: 88
# 81. 1
#     core type: Literal
#     sub-expressions:
# 82. Min(m, n)
#     core type: Operation
#     operator: 86
#     operands: 87
# 83. a
#     core type: Variable
#     sub-expressions:
# 84. b
#     core type: Variable
#     sub-expressions:
# 85. (i)
#     core type: ExprTuple
#     sub-expressions: 88
# 86. Min
#     core type: Literal
#     sub-expressions:
# 87. (m, n)
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 88. i
#     core type: Variable
#     sub-expressions:
# 89. m
#     core type: Variable
#     sub-expressions:
# 90. n
#     core type: Variable
#     sub-expressions:
