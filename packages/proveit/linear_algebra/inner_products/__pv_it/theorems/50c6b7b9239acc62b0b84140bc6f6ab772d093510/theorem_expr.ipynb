# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#schmidt_decomposition">schmidt_decomposition</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.inner_products import schmidt_decomposition

# %%
# check that the built expression is the same as the stored expression
assert schmidt_decomposition.expr == stored_expr
assert schmidt_decomposition.expr._style_id == stored_expr._style_id
print("Passed sanity check: schmidt_decomposition matches stored_expr")
# Out:
# Passed sanity check: schmidt_decomposition matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{A, B \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(A\right) = m, \textrm{Dim}\left(B\right) = n}~\\
# \left[\forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n in NaturalPos} [forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. ((m, n) -> {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 120\n   body: 3
# 3. {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]]
#    core type: Operation
#    operator: 17
#    operand: 8
# 5. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 80
#    operands: 7
# 6. ((A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Lambda
#    parameters: 43\n   body: 11
# 9. m in NaturalPos
#    core type: Operation
#    operator: 100
#    operands: 12
# 10. n in NaturalPos
#     core type: Operation
#     operator: 100
#     operands: 13
# 11. {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 122, 16
# 13. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 123, 16
# 14. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. (A in_c HilbertSpaces) and (B in_c HilbertSpaces) and (Dim(A) = m) and (Dim(B) = n)
#     core type: Operation
#     operator: 80
#     operands: 19
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (A in_c HilbertSpaces, B in_c HilbertSpaces, Dim(A) = m, Dim(B) = n)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23, 24
# 20. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Lambda
#     parameter: 83
#     body: 26
# 21. A in_c HilbertSpaces
#     core type: Operation
#     operator: 28
#     operands: 27
# 22. B in_c HilbertSpaces
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. Dim(A) = m
#     core type: Operation
#     operator: 78
#     operands: 30
# 24. Dim(B) = n
#     core type: Operation
#     operator: 78
#     operands: 31
# 25. (v)
#     core type: ExprTuple
#     sub-expressions: 83
# 26. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Conditional
#     value: 32
#     condition: 33
# 27. (A, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 57, 34
# 28. in_c
#     core type: Literal
#     sub-expressions:
# 29. (B, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 76, 34
# 30. (Dim(A), m)
#     core type: ExprTuple
#     sub-expressions: 35, 122
# 31. (Dim(B), n)
#     core type: ExprTuple
#     sub-expressions: 36, 123
# 32. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#     core type: Operation
#     operator: 58
#     operand: 40
# 33. v in (A otimes B)
#     core type: Operation
#     operator: 100
#     operands: 38
# 34. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 35. Dim(A)
#     core type: Operation
#     operator: 39
#     operand: 57
# 36. Dim(B)
#     core type: Operation
#     operator: 39
#     operand: 76
# 37. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. (v, A otimes B)
#     core type: ExprTuple
#     sub-expressions: 83, 41
# 39. Dim
#     core type: Literal
#     sub-expressions:
# 40. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 52\n    body: 42
# 41. A otimes B
#     core type: Operation
#     operator: 108
#     operands: 43
# 42. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 44
#     condition: 45
# 43. (A, B)
#     core type: ExprTuple
#     sub-expressions: 57, 76
# 44. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 58
#     operand: 48
# 45. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 100
#     operands: 47
# 46. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 48
# 47. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 48. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 69\n    body: 51
# 49. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 68
#     operands: 52
# 50. O.N.Bases(A)
#     core type: Operation
#     operator: 70
#     operand: 57
# 51. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 54
#     condition: 55
# 52. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. (A)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 58
#     operand: 62
# 55. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 100
#     operands: 60
# 56. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 114
#     end_index: 122
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. exists
#     core type: Literal
#     sub-expressions:
# 59. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. _a -> a_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 65
# 62. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 66\n    body: 67
# 63. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. O.N.Bases(B)
#     core type: Operation
#     operator: 70
#     operand: 76
# 65. a_{_a}
#     core type: IndexedVar
# variable: 116
# index: 106
# 66. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 72
# 67. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 73
#     condition: 74
# 68. Set
#     core type: Literal
#     sub-expressions:
# 69. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 75
# 70. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 71. (B)
#     core type: ExprTuple
#     sub-expressions: 76
# 72. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 114
#     end_index: 115
# 73. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 78
#     operands: 79
# 74. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 80
#     operands: 81
# 75. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 114
#     end_index: 123
# 76. B
#     core type: Variable
#     sub-expressions:
# 77. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 96
# 78. =
#     core type: Literal
#     sub-expressions:
# 79. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 80. and
#     core type: Literal
#     sub-expressions:
# 81. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 85
# 82. _a -> b_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 86
# 83. v
#     core type: Variable
#     sub-expressions:
# 84. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 87
#     operand: 90
# 85. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 89
#     start_index: 114
#     end_index: 115
# 86. b_{_a}
#     core type: IndexedVar
# variable: 117
# index: 106
# 87. Sum
#     core type: Literal
#     sub-expressions:
# 88. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 90
# 89. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 106
#     body: 91
# 90. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 121
#     body: 92
# 91. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 100
#     operands: 93
# 92. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 94
#     condition: 95
# 93. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 94. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 98
#     operands: 99
# 95. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 100
#     operands: 101
# 96. lambda_{_a}
#     core type: IndexedVar
# variable: 107
# index: 106
# 97. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 98. *
#     core type: Literal
#     sub-expressions:
# 99. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 103, 104
# 100. in
#      core type: Literal
#      sub-expressions:
# 101. (i, {1 .. Min(m, n)})
#      core type: ExprTuple
#      sub-expressions: 121, 105
# 102. (_a)
#      core type: ExprTuple
#      sub-expressions: 106
# 103. lambda_{i}
#      core type: IndexedVar
# variable: 107
# index: 121
# 104. a_{i} otimes b_{i}
#      core type: Operation
#      operator: 108
#      operands: 109
# 105. {1 .. Min(m, n)}
#      core type: Operation
#      operator: 110
#      operands: 111
# 106. _a
#      core type: Variable
#      sub-expressions:
# 107. lambda
#      core type: Variable
#      sub-expressions:
# 108. otimes
#      core type: Literal
#      sub-expressions:
# 109. (a_{i}, b_{i})
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 110. Interval
#      core type: Literal
#      sub-expressions:
# 111. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 114, 115
# 112. a_{i}
#      core type: IndexedVar
# variable: 116
# index: 121
# 113. b_{i}
#      core type: IndexedVar
# variable: 117
# index: 121
# 114. 1
#      core type: Literal
#      sub-expressions:
# 115. Min(m, n)
#      core type: Operation
#      operator: 119
#      operands: 120
# 116. a
#      core type: Variable
#      sub-expressions:
# 117. b
#      core type: Variable
#      sub-expressions:
# 118. (i)
#      core type: ExprTuple
#      sub-expressions: 121
# 119. Min
#      core type: Literal
#      sub-expressions:
# 120. (m, n)
#      core type: ExprTuple
#      sub-expressions: 122, 123
# 121. i
#      core type: Variable
#      sub-expressions:
# 122. m
#      core type: Variable
#      sub-expressions:
# 123. n
#      core type: Variable
#      sub-expressions:
