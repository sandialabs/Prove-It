# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, ExprTuple, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = ExprTuple(Lambda(M, Conditional(Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), InSet(M, LinMap(Hspace, Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(M \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 48
#    body: 2
# 2. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. M in LINMAP(H, H)
#    core type: Operation
#    operator: 65
#    operands: 7
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (M, LINMAP(H, H))
#    core type: ExprTuple
#    sub-expressions: 48, 10
# 8. (M* o M) = (M o M*)
#    core type: Operation
#    operator: 43
#    operands: 11
# 9. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#    core type: Operation
#    operator: 27
#    operand: 17
# 10. LINMAP(H, H)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. LINMAP
#     core type: Literal
#     sub-expressions:
# 14. (H, H)
#     core type: ExprTuple
#     sub-expressions: 77, 77
# 15. M* o M
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. M o M*
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 35\n    body: 21
# 18. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 22, 48
# 19. o
#     core type: Literal
#     sub-expressions:
# 20. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 48, 22
# 21. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. M*
#     core type: Operation
#     operator: 25
#     operand: 48
# 23. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 27
#     operand: 30
# 24. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 65
#     operands: 29
# 25. Adj
#     core type: Literal
#     sub-expressions:
# 26. (M)
#     core type: ExprTuple
#     sub-expressions: 48
# 27. exists
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 30
# 29. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 31. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 84
#     operands: 35
# 32. O.N.Bases(H)
#     core type: Operation
#     operator: 36
#     operand: 77
# 33. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 39
#     condition: 40
# 35. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (H)
#     core type: ExprTuple
#     sub-expressions: 77
# 38. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 79
#     end_index: 80
# 39. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 79
#     end_index: 80
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 61
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. and
#     core type: Literal
#     sub-expressions:
# 46. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 50
# 47. _a -> x_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 51
# 48. M
#     core type: Variable
#     sub-expressions:
# 49. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 52
#     operand: 55
# 50. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 79
#     end_index: 80
# 51. x_{_a}
#     core type: IndexedVar
# variable: 87
# index: 71
# 52. Sum
#     core type: Literal
#     sub-expressions:
# 53. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 55
# 54. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 71
#     body: 56
# 55. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 89
#     body: 57
# 56. a_{_a} in Complex
#     core type: Operation
#     operator: 65
#     operands: 58
# 57. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 59
#     condition: 60
# 58. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. i in {1 .. n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. a_{_a}
#     core type: IndexedVar
# variable: 72
# index: 71
# 62. Complex
#     core type: Literal
#     sub-expressions:
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 89, 70
# 67. (_a)
#     core type: ExprTuple
#     sub-expressions: 71
# 68. a_{i}
#     core type: IndexedVar
# variable: 72
# index: 89
# 69. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 73
#     operands: 74
# 70. {1 .. n}
#     core type: Operation
#     operator: 75
#     operands: 76
# 71. _a
#     core type: Variable
#     sub-expressions:
# 72. a
#     core type: Variable
#     sub-expressions:
# 73. OrthoProj
#     core type: Literal
#     sub-expressions:
# 74. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. Interval
#     core type: Literal
#     sub-expressions:
# 76. (1, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. H
#     core type: Variable
#     sub-expressions:
# 78. Span({x_{i}})
#     core type: Operation
#     operator: 81
#     operand: 83
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. Span
#     core type: Literal
#     sub-expressions:
# 82. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 83
# 83. {x_{i}}
#     core type: Operation
#     operator: 84
#     operand: 86
# 84. Set
#     core type: Literal
#     sub-expressions:
# 85. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 86
# 86. x_{i}
#     core type: IndexedVar
# variable: 87
# index: 89
# 87. x
#     core type: Variable
#     sub-expressions:
# 88. (i)
#     core type: ExprTuple
#     sub-expressions: 89
# 89. i
#     core type: Variable
#     sub-expressions:
