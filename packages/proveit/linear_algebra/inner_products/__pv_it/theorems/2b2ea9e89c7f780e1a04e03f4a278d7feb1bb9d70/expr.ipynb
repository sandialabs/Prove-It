# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Lambda, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Lambda([a_1_to_m], Conditional(Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), InSet(Set(a_1_to_m), OrthoNormBases(A))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a_{1}, a_{2}, \ldots, a_{m}\right) \mapsto \left\{\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } \left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#    core type: Operation
#    operator: 16
#    operand: 6
# 3. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#    core type: Operation
#    operator: 58
#    operands: 5
# 4. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Lambda
#    parameters: 27\n   body: 9
# 7. {a_{1}, a_{2}, ..., a_{m}}
#    core type: Operation
#    operator: 26
#    operands: 10
# 8. O.N.Bases(A)
#    core type: Operation
#    operator: 28
#    operand: 15
# 9. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. (A)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 16
#     operand: 20
# 13. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 58
#     operands: 18
# 14. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 72
#     end_index: 80
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 23
# 20. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 24\n    body: 25
# 21. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. O.N.Bases(B)
#     core type: Operation
#     operator: 28
#     operand: 34
# 23. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 64
# 24. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 30
# 25. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 31
#     condition: 32
# 26. Set
#     core type: Literal
#     sub-expressions:
# 27. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 29. (B)
#     core type: ExprTuple
#     sub-expressions: 34
# 30. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 72
#     end_index: 73
# 31. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 72
#     end_index: 81
# 34. B
#     core type: Variable
#     sub-expressions:
# 35. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 54
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 43
# 40. _a -> b_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 44
# 41. v
#     core type: Variable
#     sub-expressions:
# 42. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 45
#     operand: 48
# 43. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 72
#     end_index: 73
# 44. b_{_a}
#     core type: IndexedVar
# variable: 75
# index: 64
# 45. Sum
#     core type: Literal
#     sub-expressions:
# 46. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 48
# 47. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 64
#     body: 49
# 48. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 79
#     body: 50
# 49. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 58
#     operands: 51
# 50. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 52
#     condition: 53
# 51. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. lambda_{_a}
#     core type: IndexedVar
# variable: 65
# index: 64
# 55. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 79, 63
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 61. lambda_{i}
#     core type: IndexedVar
# variable: 65
# index: 79
# 62. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. _a
#     core type: Variable
#     sub-expressions:
# 65. lambda
#     core type: Variable
#     sub-expressions:
# 66. otimes
#     core type: Literal
#     sub-expressions:
# 67. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. Interval
#     core type: Literal
#     sub-expressions:
# 69. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 70. a_{i}
#     core type: IndexedVar
# variable: 74
# index: 79
# 71. b_{i}
#     core type: IndexedVar
# variable: 75
# index: 79
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. Min(m, n)
#     core type: Operation
#     operator: 77
#     operands: 78
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. b
#     core type: Variable
#     sub-expressions:
# 76. (i)
#     core type: ExprTuple
#     sub-expressions: 79
# 77. Min
#     core type: Literal
#     sub-expressions:
# 78. (m, n)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 79. i
#     core type: Variable
#     sub-expressions:
# 80. m
#     core type: Variable
#     sub-expressions:
# 81. n
#     core type: Variable
#     sub-expressions:
