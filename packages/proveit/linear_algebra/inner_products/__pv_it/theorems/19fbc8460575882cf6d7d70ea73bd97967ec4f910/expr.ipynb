# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, H, K, Lambda, a, b, x, y, z
from proveit.linear_algebra import InnerProd, InnerProdSpaces, ScalarMult, VecAdd
from proveit.logic import Equals, Forall, InClass

# %%
# build up the expression from sub-expressions
expr = Lambda(H, Conditional(Forall(instance_param_or_params = [a, b], instance_expr = Forall(instance_param_or_params = [x, y, z], instance_expr = Equals(InnerProd(VecAdd(ScalarMult(a, x), ScalarMult(b, y)), z), VecAdd(ScalarMult(a, InnerProd(x, z)), ScalarMult(b, InnerProd(y, z)))), domain = H), domain = K), InClass(H, InnerProdSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# H \mapsto \left\{\forall_{a, b \in K}~\left[\forall_{x, y, z \in H}~\left(\left \langle \left(a \cdot x\right) + \left(b \cdot y\right), z\right \rangle = \left(\left(a \cdot \left \langle x, z\right \rangle\right) + \left(b \cdot \left \langle y, z\right \rangle\right)\right)\right)\right] \textrm{ if } H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. H -> {forall_{a, b in K} [forall_{x, y, z in H} (<(a * x) + (b * y), z> = ((a * <x, z>) + (b * <y, z>)))] if H in_c InnerProdSpaces(K).
#    core type: Lambda
#    parameter: 47
#    body: 2
# 1. (H)
#    core type: ExprTuple
#    sub-expressions: 47
# 2. {forall_{a, b in K} [forall_{x, y, z in H} (<(a * x) + (b * y), z> = ((a * <x, z>) + (b * <y, z>)))] if H in_c InnerProdSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, b in K} [forall_{x, y, z in H} (<(a * x) + (b * y), z> = ((a * <x, z>) + (b * <y, z>)))]
#    core type: Operation
#    operator: 16
#    operand: 8
# 4. H in_c InnerProdSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a, b) -> {forall_{x, y, z in H} (<(a * x) + (b * y), z> = ((a * <x, z>) + (b * <y, z>))) if a in K ,  b in K.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (H, InnerProdSpaces(K))
#    core type: ExprTuple
# ...
