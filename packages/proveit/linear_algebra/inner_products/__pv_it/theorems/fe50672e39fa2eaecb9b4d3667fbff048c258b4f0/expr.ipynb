# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import And, Equals, Exists, Forall, Iff, InClass, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Lambda(Hspace, Conditional(Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), And(InClass(Hspace, HilbertSpaces), Equals(Dim(Hspace), n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \mathcal{H} \mapsto \left\{\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right) \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  \textrm{Dim}\left(\mathcal{H}\right) = n\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 91
#    body: 1
# 1. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 59
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 62
#    body: 10
# 8. H in_c HilbertSpaces
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Dim(H) = n
#    core type: Operation
#    operator: 57
#    operands: 13
# 10. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 91, 16
# 13. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 17, 94
# 14. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. M in LINMAP(H, H)
#     core type: Operation
#     operator: 79
#     operands: 20
# 16. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 17. Dim(H)
#     core type: Operation
#     operator: 21
#     operand: 91
# 18. <=>
#     core type: Literal
#     sub-expressions:
# 19. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 62, 24
# 21. Dim
#     core type: Literal
#     sub-expressions:
# 22. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 57
#     operands: 25
# 23. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 41
#     operand: 31
# 24. LINMAP(H, H)
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. LINMAP
#     core type: Literal
#     sub-expressions:
# 28. (H, H)
#     core type: ExprTuple
#     sub-expressions: 91, 91
# 29. M* o M
#     core type: Operation
#     operator: 33
#     operands: 32
# 30. M o M*
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 49\n    body: 35
# 32. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 36, 62
# 33. o
#     core type: Literal
#     sub-expressions:
# 34. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 62, 36
# 35. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 37
#     condition: 38
# 36. M*
#     core type: Operation
#     operator: 39
#     operand: 62
# 37. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 41
#     operand: 44
# 38. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 79
#     operands: 43
# 39. Adj
#     core type: Literal
#     sub-expressions:
# 40. (M)
#     core type: ExprTuple
#     sub-expressions: 62
# 41. exists
#     core type: Literal
#     sub-expressions:
# 42. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 44
# 43. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 44. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 47\n    body: 48
# 45. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 98
#     operands: 49
# 46. O.N.Bases(H)
#     core type: Operation
#     operator: 50
#     operand: 91
# 47. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 48. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 53
#     condition: 54
# 49. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 55
# 50. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 51. (H)
#     core type: ExprTuple
#     sub-expressions: 91
# 52. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 93
#     end_index: 94
# 53. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 93
#     end_index: 94
# 56. _a -> a_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 75
# 57. =
#     core type: Literal
#     sub-expressions:
# 58. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. and
#     core type: Literal
#     sub-expressions:
# 60. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 64
# 61. _a -> x_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 65
# 62. M
#     core type: Variable
#     sub-expressions:
# 63. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 66
#     operand: 69
# 64. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 93
#     end_index: 94
# 65. x_{_a}
#     core type: IndexedVar
# variable: 101
# index: 85
# 66. Sum
#     core type: Literal
#     sub-expressions:
# 67. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 69
# 68. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 85
#     body: 70
# 69. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 103
#     body: 71
# 70. a_{_a} in Complex
#     core type: Operation
#     operator: 79
#     operands: 72
# 71. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 73
#     condition: 74
# 72. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 77
#     operands: 78
# 74. i in {1 .. n}
#     core type: Operation
#     operator: 79
#     operands: 80
# 75. a_{_a}
#     core type: IndexedVar
# variable: 86
# index: 85
# 76. Complex
#     core type: Literal
#     sub-expressions:
# 77. *
#     core type: Literal
#     sub-expressions:
# 78. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 79. in
#     core type: Literal
#     sub-expressions:
# 80. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 103, 84
# 81. (_a)
#     core type: ExprTuple
#     sub-expressions: 85
# 82. a_{i}
#     core type: IndexedVar
# variable: 86
# index: 103
# 83. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 87
#     operands: 88
# 84. {1 .. n}
#     core type: Operation
#     operator: 89
#     operands: 90
# 85. _a
#     core type: Variable
#     sub-expressions:
# 86. a
#     core type: Variable
#     sub-expressions:
# 87. OrthoProj
#     core type: Literal
#     sub-expressions:
# 88. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 89. Interval
#     core type: Literal
#     sub-expressions:
# 90. (1, n)
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 91. H
#     core type: Variable
#     sub-expressions:
# 92. Span({x_{i}})
#     core type: Operation
#     operator: 95
#     operand: 97
# 93. 1
#     core type: Literal
#     sub-expressions:
# 94. n
#     core type: Variable
#     sub-expressions:
# 95. Span
#     core type: Literal
#     sub-expressions:
# 96. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 97
# 97. {x_{i}}
#     core type: Operation
#     operator: 98
#     operand: 100
# 98. Set
#     core type: Literal
#     sub-expressions:
# 99. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 100
# 100. x_{i}
#      core type: IndexedVar
# variable: 101
# index: 103
# 101. x
#      core type: Variable
#      sub-expressions:
# 102. (i)
#      core type: ExprTuple
#      sub-expressions: 103
# 103. i
#      core type: Variable
#      sub-expressions:
