# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = OrthoProj(Hspace, Span(Set(x_i)))
expr = Conditional(Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), InSet(Set(x_1_to_n), OrthoNormBases(Hspace)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \end{array}\right)\end{array} \textrm{ if } \left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 61
#    operands: 5
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. {x_{1}, x_{2}, ..., x_{n}}
#    core type: Operation
#    operator: 80
#    operands: 11
# 8. O.N.Bases(H)
#    core type: Operation
#    operator: 12
#    operand: 73
# 9. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 16
#     condition: 17
# 11. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 12. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 13. (H)
#     core type: ExprTuple
#     sub-expressions: 73
# 14. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 75
#     end_index: 76
# 15. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 75
#     end_index: 76
# 16. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 22
#     operands: 21
# 17. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 75
#     end_index: 76
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 48
# 20. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 49
# 21. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))), B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 29
# 25. A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 31
#     operands: 30
# 26. B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 75
#     end_index: 76
# 28. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 75
#     end_index: 76
# 29. x_{_a}
#     core type: IndexedVar
# variable: 83
# index: 57
# 30. (A, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (B, Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 39
# 34. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 40
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 42
#     operand: 46
# 37. B
#     core type: Variable
#     sub-expressions:
# 38. Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 42
#     operand: 47
# 39. a_{_a} in Complex
#     core type: Operation
#     operator: 61
#     operands: 44
# 40. b_{_a} in Complex
#     core type: Operation
#     operator: 61
#     operands: 45
# 41. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. Sum
#     core type: Literal
#     sub-expressions:
# 43. (i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 50
# 45. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 85
#     body: 51
# 47. i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 85
#     body: 52
# 48. a_{_a}
#     core type: IndexedVar
# variable: 67
# index: 57
# 49. b_{_a}
#     core type: IndexedVar
# variable: 68
# index: 57
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 54
#     condition: 56
# 52. {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 55
#     condition: 56
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 59
#     operands: 58
# 55. b_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. i in {1 .. n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. _a
#     core type: Variable
#     sub-expressions:
# 58. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 63, 65
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (b_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. in
#     core type: Literal
#     sub-expressions:
# 62. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 85, 66
# 63. a_{i}
#     core type: IndexedVar
# variable: 67
# index: 85
# 64. b_{i}
#     core type: IndexedVar
# variable: 68
# index: 85
# 65. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. {1 .. n}
#     core type: Operation
#     operator: 71
#     operands: 72
# 67. a
#     core type: Variable
#     sub-expressions:
# 68. b
#     core type: Variable
#     sub-expressions:
# 69. OrthoProj
#     core type: Literal
#     sub-expressions:
# 70. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 71. Interval
#     core type: Literal
#     sub-expressions:
# 72. (1, n)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. H
#     core type: Variable
#     sub-expressions:
# 74. Span({x_{i}})
#     core type: Operation
#     operator: 77
#     operand: 79
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. n
#     core type: Variable
#     sub-expressions:
# 77. Span
#     core type: Literal
#     sub-expressions:
# 78. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 79
# 79. {x_{i}}
#     core type: Operation
#     operator: 80
#     operand: 82
# 80. Set
#     core type: Literal
#     sub-expressions:
# 81. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 82
# 82. x_{i}
#     core type: IndexedVar
# variable: 83
# index: 85
# 83. x
#     core type: Variable
#     sub-expressions:
# 84. (i)
#     core type: ExprTuple
#     sub-expressions: 85
# 85. i
#     core type: Variable
#     sub-expressions:
