# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, Conditional, ExprTuple, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import And, Equals, Exists, Forall, Iff, InClass, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = ExprTuple(Lambda(Hspace, Conditional(Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), And(InClass(Hspace, HilbertSpaces), Equals(Dim(Hspace), n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\mathcal{H} \mapsto \left\{\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right) \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  \textrm{Dim}\left(\mathcal{H}\right) = n\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 92
#    body: 2
# 2. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 60
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 63
#    body: 11
# 9. H in_c HilbertSpaces
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Dim(H) = n
#     core type: Operation
#     operator: 58
#     operands: 14
# 11. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. in_c
#     core type: Literal
#     sub-expressions:
# 13. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 92, 17
# 14. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 18, 95
# 15. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. M in LINMAP(H, H)
#     core type: Operation
#     operator: 80
#     operands: 21
# 17. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 18. Dim(H)
#     core type: Operation
#     operator: 22
#     operand: 92
# 19. <=>
#     core type: Literal
#     sub-expressions:
# 20. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 63, 25
# 22. Dim
#     core type: Literal
#     sub-expressions:
# 23. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 58
#     operands: 26
# 24. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 42
#     operand: 32
# 25. LINMAP(H, H)
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. LINMAP
#     core type: Literal
#     sub-expressions:
# 29. (H, H)
#     core type: ExprTuple
#     sub-expressions: 92, 92
# 30. M* o M
#     core type: Operation
#     operator: 34
#     operands: 33
# 31. M o M*
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 50\n    body: 36
# 33. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 37, 63
# 34. o
#     core type: Literal
#     sub-expressions:
# 35. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 63, 37
# 36. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 38
#     condition: 39
# 37. M*
#     core type: Operation
#     operator: 40
#     operand: 63
# 38. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 42
#     operand: 45
# 39. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 80
#     operands: 44
# 40. Adj
#     core type: Literal
#     sub-expressions:
# 41. (M)
#     core type: ExprTuple
#     sub-expressions: 63
# 42. exists
#     core type: Literal
#     sub-expressions:
# 43. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 48\n    body: 49
# 46. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 99
#     operands: 50
# 47. O.N.Bases(H)
#     core type: Operation
#     operator: 51
#     operand: 92
# 48. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 54
#     condition: 55
# 50. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 51. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 52. (H)
#     core type: ExprTuple
#     sub-expressions: 92
# 53. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 94
#     end_index: 95
# 54. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 94
#     end_index: 95
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 86
#     body: 76
# 58. =
#     core type: Literal
#     sub-expressions:
# 59. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. and
#     core type: Literal
#     sub-expressions:
# 61. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 65
# 62. _a -> x_{_a}
#     core type: Lambda
#     parameter: 86
#     body: 66
# 63. M
#     core type: Variable
#     sub-expressions:
# 64. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 67
#     operand: 70
# 65. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 94
#     end_index: 95
# 66. x_{_a}
#     core type: IndexedVar
# variable: 102
# index: 86
# 67. Sum
#     core type: Literal
#     sub-expressions:
# 68. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 70
# 69. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 86
#     body: 71
# 70. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 104
#     body: 72
# 71. a_{_a} in Complex
#     core type: Operation
#     operator: 80
#     operands: 73
# 72. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 74
#     condition: 75
# 73. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 74. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. i in {1 .. n}
#     core type: Operation
#     operator: 80
#     operands: 81
# 76. a_{_a}
#     core type: IndexedVar
# variable: 87
# index: 86
# 77. Complex
#     core type: Literal
#     sub-expressions:
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 80. in
#     core type: Literal
#     sub-expressions:
# 81. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 104, 85
# 82. (_a)
#     core type: ExprTuple
#     sub-expressions: 86
# 83. a_{i}
#     core type: IndexedVar
# variable: 87
# index: 104
# 84. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 88
#     operands: 89
# 85. {1 .. n}
#     core type: Operation
#     operator: 90
#     operands: 91
# 86. _a
#     core type: Variable
#     sub-expressions:
# 87. a
#     core type: Variable
#     sub-expressions:
# 88. OrthoProj
#     core type: Literal
#     sub-expressions:
# 89. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. Interval
#     core type: Literal
#     sub-expressions:
# 91. (1, n)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 92. H
#     core type: Variable
#     sub-expressions:
# 93. Span({x_{i}})
#     core type: Operation
#     operator: 96
#     operand: 98
# 94. 1
#     core type: Literal
#     sub-expressions:
# 95. n
#     core type: Variable
#     sub-expressions:
# 96. Span
#     core type: Literal
#     sub-expressions:
# 97. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 98
# 98. {x_{i}}
#     core type: Operation
#     operator: 99
#     operand: 101
# 99. Set
#     core type: Literal
#     sub-expressions:
# 100. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 101
# 101. x_{i}
#      core type: IndexedVar
# variable: 102
# index: 104
# 102. x
#      core type: Variable
#      sub-expressions:
# 103. (i)
#      core type: ExprTuple
#      sub-expressions: 104
# 104. i
#      core type: Variable
#      sub-expressions:
