# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Commutator, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = OrthoProj(Hspace, Span(Set(x_i)))
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\begin{array}{l}\forall_{A, B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array}\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])] if n in NaturalPos.
#    core type: Lambda
#    parameter: 134
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 134
# 3. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])]
#    core type: Operation
#    operator: 13
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 119
#    operands: 7
# 6. (H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 134, 9
# 8. H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 131
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 80
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Lambda
#     parameters: 49\n    body: 19
# 17. H in_c HilbertSpaces
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. Dim(H) = n
#     core type: Operation
#     operator: 89
#     operands: 22
# 19. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. in_c
#     core type: Literal
#     sub-expressions:
# 21. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 131, 25
# 22. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 26, 134
# 23. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 80
#     operands: 29
# 25. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 26. Dim(H)
#     core type: Operation
#     operator: 30
#     operand: 131
# 27. <=>
#     core type: Literal
#     sub-expressions:
# 28. ([A, B] = 0(LINMAP(H, H)), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))])
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 33, 34, 35, 36
# 30. Dim
#     core type: Literal
#     sub-expressions:
# 31. [A, B] = 0(LINMAP(H, H))
#     core type: Operation
#     operator: 89
#     operands: 37
# 32. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]
#     core type: Operation
#     operator: 61
#     operand: 45
# 33. A in LINMAP(H, H)
#     core type: Operation
#     operator: 119
#     operands: 39
# 34. B in LINMAP(H, H)
#     core type: Operation
#     operator: 119
#     operands: 40
# 35. A* = A
#     core type: Operation
#     operator: 89
#     operands: 41
# 36. B* = B
#     core type: Operation
#     operator: 89
#     operands: 42
# 37. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 38. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 45
# 39. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 93, 56
# 40. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 95, 56
# 41. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 46, 93
# 42. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 47, 95
# 43. [A, B]
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 50
#     operand: 56
# 45. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 69\n    body: 52
# 46. A*
#     core type: Operation
#     operator: 54
#     operand: 93
# 47. B*
#     core type: Operation
#     operator: 54
#     operand: 95
# 48. commutator
#     core type: Literal
#     sub-expressions:
# 49. (A, B)
#     core type: ExprTuple
#     sub-expressions: 93, 95
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 56
# 52. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 57
#     condition: 58
# 53. (A)
#     core type: ExprTuple
#     sub-expressions: 93
# 54. Adj
#     core type: Literal
#     sub-expressions:
# 55. (B)
#     core type: ExprTuple
#     sub-expressions: 95
# 56. LINMAP(H, H)
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))
#     core type: Operation
#     operator: 61
#     operand: 64
# 58. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 119
#     operands: 63
# 59. LINMAP
#     core type: Literal
#     sub-expressions:
# 60. (H, H)
#     core type: ExprTuple
#     sub-expressions: 131, 131
# 61. exists
#     core type: Literal
#     sub-expressions:
# 62. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 64
# 63. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 64. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 67\n    body: 68
# 65. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 138
#     operands: 69
# 66. O.N.Bases(H)
#     core type: Operation
#     operator: 70
#     operand: 131
# 67. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 74
#     condition: 75
# 69. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 76
# 70. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 71. (H)
#     core type: ExprTuple
#     sub-expressions: 131
# 72. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 133
#     end_index: 134
# 73. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 133
#     end_index: 134
# 74. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 80
#     operands: 79
# 75. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 80
#     operands: 81
# 76. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 133
#     end_index: 134
# 77. _a -> a_{_a}
#     core type: Lambda
#     parameter: 115
#     body: 106
# 78. _a -> b_{_a}
#     core type: Lambda
#     parameter: 115
#     body: 107
# 79. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))), B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 80. and
#     core type: Literal
#     sub-expressions:
# 81. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 82. _a -> x_{_a}
#     core type: Lambda
#     parameter: 115
#     body: 87
# 83. A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 89
#     operands: 88
# 84. B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 89
#     operands: 90
# 85. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 91
#     start_index: 133
#     end_index: 134
# 86. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 92
#     start_index: 133
#     end_index: 134
# 87. x_{_a}
#     core type: IndexedVar
# variable: 141
# index: 115
# 88. (A, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 89. =
#     core type: Literal
#     sub-expressions:
# 90. (B, Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 91. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 115
#     body: 97
# 92. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 115
#     body: 98
# 93. A
#     core type: Variable
#     sub-expressions:
# 94. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 100
#     operand: 104
# 95. B
#     core type: Variable
#     sub-expressions:
# 96. Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 100
#     operand: 105
# 97. a_{_a} in Complex
#     core type: Operation
#     operator: 119
#     operands: 102
# 98. b_{_a} in Complex
#     core type: Operation
#     operator: 119
#     operands: 103
# 99. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 104
# 100. Sum
#      core type: Literal
#      sub-expressions:
# 101. (i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#      core type: ExprTuple
#      sub-expressions: 105
# 102. (a_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 106, 108
# 103. (b_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 104. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 143
#      body: 109
# 105. i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 143
#      body: 110
# 106. a_{_a}
#      core type: IndexedVar
# variable: 125
# index: 115
# 107. b_{_a}
#      core type: IndexedVar
# variable: 126
# index: 115
# 108. Complex
#      core type: Literal
#      sub-expressions:
# 109. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#      core type: Conditional
#      value: 112
#      condition: 114
# 110. {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#      core type: Conditional
#      value: 113
#      condition: 114
# 111. (_a)
#      core type: ExprTuple
#      sub-expressions: 115
# 112. a_{i} * OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 117
#      operands: 116
# 113. b_{i} * OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 117
#      operands: 118
# 114. i in {1 .. n}
#      core type: Operation
#      operator: 119
#      operands: 120
# 115. _a
#      core type: Variable
#      sub-expressions:
# 116. (a_{i}, OrthoProj(H, Span({x_{i}})))
#      core type: ExprTuple
#      sub-expressions: 121, 123
# 117. *
#      core type: Literal
#      sub-expressions:
# 118. (b_{i}, OrthoProj(H, Span({x_{i}})))
#      core type: ExprTuple
#      sub-expressions: 122, 123
# 119. in
#      core type: Literal
#      sub-expressions:
# 120. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 143, 124
# 121. a_{i}
#      core type: IndexedVar
# variable: 125
# index: 143
# 122. b_{i}
#      core type: IndexedVar
# variable: 126
# index: 143
# 123. OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 127
#      operands: 128
# 124. {1 .. n}
#      core type: Operation
#      operator: 129
#      operands: 130
# 125. a
#      core type: Variable
#      sub-expressions:
# 126. b
#      core type: Variable
#      sub-expressions:
# 127. OrthoProj
#      core type: Literal
#      sub-expressions:
# 128. (H, Span({x_{i}}))
#      core type: ExprTuple
#      sub-expressions: 131, 132
# 129. Interval
#      core type: Literal
#      sub-expressions:
# 130. (1, n)
#      core type: ExprTuple
#      sub-expressions: 133, 134
# 131. H
#      core type: Variable
#      sub-expressions:
# 132. Span({x_{i}})
#      core type: Operation
#      operator: 135
#      operand: 137
# 133. 1
#      core type: Literal
#      sub-expressions:
# 134. n
#      core type: Variable
#      sub-expressions:
# 135. Span
#      core type: Literal
#      sub-expressions:
# 136. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 137
# 137. {x_{i}}
#      core type: Operation
#      operator: 138
#      operand: 140
# 138. Set
#      core type: Literal
#      sub-expressions:
# 139. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 140
# 140. x_{i}
#      core type: IndexedVar
# variable: 141
# index: 143
# 141. x
#      core type: Variable
#      sub-expressions:
# 142. (i)
#      core type: ExprTuple
#      sub-expressions: 143
# 143. i
#      core type: Variable
#      sub-expressions:
