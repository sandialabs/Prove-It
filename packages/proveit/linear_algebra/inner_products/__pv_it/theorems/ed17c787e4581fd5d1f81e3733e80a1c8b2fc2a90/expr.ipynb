# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Composition, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Composition(sub_expr1, M), Composition(M, sub_expr1)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, OrthoProj(Hspace, Span(Set(x_i)))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 93
#    body: 3
# 3. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 61
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 64
#    body: 12
# 10. H in_c HilbertSpaces
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. Dim(H) = n
#     core type: Operation
#     operator: 59
#     operands: 15
# 12. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. in_c
#     core type: Literal
#     sub-expressions:
# 14. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 93, 18
# 15. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 19, 96
# 16. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. M in LINMAP(H, H)
#     core type: Operation
#     operator: 81
#     operands: 22
# 18. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 19. Dim(H)
#     core type: Operation
#     operator: 23
#     operand: 93
# 20. <=>
#     core type: Literal
#     sub-expressions:
# 21. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 64, 26
# 23. Dim
#     core type: Literal
#     sub-expressions:
# 24. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 59
#     operands: 27
# 25. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 43
#     operand: 33
# 26. LINMAP(H, H)
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. LINMAP
#     core type: Literal
#     sub-expressions:
# 30. (H, H)
#     core type: ExprTuple
#     sub-expressions: 93, 93
# 31. M* o M
#     core type: Operation
#     operator: 35
#     operands: 34
# 32. M o M*
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 51\n    body: 37
# 34. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 38, 64
# 35. o
#     core type: Literal
#     sub-expressions:
# 36. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 64, 38
# 37. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 39
#     condition: 40
# 38. M*
#     core type: Operation
#     operator: 41
#     operand: 64
# 39. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 43
#     operand: 46
# 40. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 81
#     operands: 45
# 41. Adj
#     core type: Literal
#     sub-expressions:
# 42. (M)
#     core type: ExprTuple
#     sub-expressions: 64
# 43. exists
#     core type: Literal
#     sub-expressions:
# 44. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 46
# 45. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 49\n    body: 50
# 47. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 100
#     operands: 51
# 48. O.N.Bases(H)
#     core type: Operation
#     operator: 52
#     operand: 93
# 49. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 50. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 55
#     condition: 56
# 51. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 57
# 52. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 53. (H)
#     core type: ExprTuple
#     sub-expressions: 93
# 54. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 95
#     end_index: 96
# 55. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 95
#     end_index: 96
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 77
# 59. =
#     core type: Literal
#     sub-expressions:
# 60. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. and
#     core type: Literal
#     sub-expressions:
# 62. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 66
# 63. _a -> x_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 67
# 64. M
#     core type: Variable
#     sub-expressions:
# 65. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 68
#     operand: 71
# 66. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 95
#     end_index: 96
# 67. x_{_a}
#     core type: IndexedVar
# variable: 103
# index: 87
# 68. Sum
#     core type: Literal
#     sub-expressions:
# 69. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 71
# 70. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 87
#     body: 72
# 71. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 105
#     body: 73
# 72. a_{_a} in Complex
#     core type: Operation
#     operator: 81
#     operands: 74
# 73. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 75
#     condition: 76
# 74. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 79
#     operands: 80
# 76. i in {1 .. n}
#     core type: Operation
#     operator: 81
#     operands: 82
# 77. a_{_a}
#     core type: IndexedVar
# variable: 88
# index: 87
# 78. Complex
#     core type: Literal
#     sub-expressions:
# 79. *
#     core type: Literal
#     sub-expressions:
# 80. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 81. in
#     core type: Literal
#     sub-expressions:
# 82. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 105, 86
# 83. (_a)
#     core type: ExprTuple
#     sub-expressions: 87
# 84. a_{i}
#     core type: IndexedVar
# variable: 88
# index: 105
# 85. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 89
#     operands: 90
# 86. {1 .. n}
#     core type: Operation
#     operator: 91
#     operands: 92
# 87. _a
#     core type: Variable
#     sub-expressions:
# 88. a
#     core type: Variable
#     sub-expressions:
# 89. OrthoProj
#     core type: Literal
#     sub-expressions:
# 90. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 91. Interval
#     core type: Literal
#     sub-expressions:
# 92. (1, n)
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 93. H
#     core type: Variable
#     sub-expressions:
# 94. Span({x_{i}})
#     core type: Operation
#     operator: 97
#     operand: 99
# 95. 1
#     core type: Literal
#     sub-expressions:
# 96. n
#     core type: Variable
#     sub-expressions:
# 97. Span
#     core type: Literal
#     sub-expressions:
# 98. ({x_{i}})
#     core type: ExprTuple
#     sub-expressions: 99
# 99. {x_{i}}
#     core type: Operation
#     operator: 100
#     operand: 102
# 100. Set
#      core type: Literal
#      sub-expressions:
# 101. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 102
# 102. x_{i}
#      core type: IndexedVar
# variable: 103
# index: 105
# 103. x
#      core type: Variable
#      sub-expressions:
# 104. (i)
#      core type: ExprTuple
#      sub-expressions: 105
# 105. i
#      core type: Variable
#      sub-expressions:
