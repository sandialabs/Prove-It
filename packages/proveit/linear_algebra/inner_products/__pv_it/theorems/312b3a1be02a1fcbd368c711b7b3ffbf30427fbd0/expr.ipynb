# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, x_1_to_n, x_i
from proveit.linear_algebra import Adj, Commutator, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, OrthoProj, ScalarMult, Span, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Forall, Iff, InClass, InSet, Set
from proveit.numbers import Complex, Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = OrthoProj(Hspace, Span(Set(x_i)))
expr = Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [x_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(x_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), And(InClass(Hspace, HilbertSpaces), Equals(Dim(Hspace), n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{A, B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array} \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  \textrm{Dim}\left(\mathcal{H}\right) = n\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]])
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 70
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 39\n   body: 9
# 7. H in_c HilbertSpaces
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. Dim(H) = n
#    core type: Operation
#    operator: 79
#    operands: 12
# 9. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 121, 15
# 12. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 16, 124
# 13. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]]
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 70
#     operands: 19
# 15. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 16. Dim(H)
#     core type: Operation
#     operator: 20
#     operand: 121
# 17. <=>
#     core type: Literal
#     sub-expressions:
# 18. ([A, B] = 0(LINMAP(H, H)), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))])
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26
# 20. Dim
#     core type: Literal
#     sub-expressions:
# 21. [A, B] = 0(LINMAP(H, H))
#     core type: Operation
#     operator: 79
#     operands: 27
# 22. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))]
#     core type: Operation
#     operator: 51
#     operand: 35
# 23. A in LINMAP(H, H)
#     core type: Operation
#     operator: 109
#     operands: 29
# 24. B in LINMAP(H, H)
#     core type: Operation
#     operator: 109
#     operands: 30
# 25. A* = A
#     core type: Operation
#     operator: 79
#     operands: 31
# 26. B* = B
#     core type: Operation
#     operator: 79
#     operands: 32
# 27. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 35
# 29. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 83, 46
# 30. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 85, 46
# 31. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 36, 83
# 32. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 37, 85
# 33. [A, B]
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 40
#     operand: 46
# 35. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 59\n    body: 42
# 36. A*
#     core type: Operation
#     operator: 44
#     operand: 83
# 37. B*
#     core type: Operation
#     operator: 44
#     operand: 85
# 38. commutator
#     core type: Literal
#     sub-expressions:
# 39. (A, B)
#     core type: ExprTuple
#     sub-expressions: 83, 85
# 40. 0
#     core type: Literal
#     sub-expressions:
# 41. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 46
# 42. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 47
#     condition: 48
# 43. (A)
#     core type: ExprTuple
#     sub-expressions: 83
# 44. Adj
#     core type: Literal
#     sub-expressions:
# 45. (B)
#     core type: ExprTuple
#     sub-expressions: 85
# 46. LINMAP(H, H)
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))))
#     core type: Operation
#     operator: 51
#     operand: 54
# 48. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 109
#     operands: 53
# 49. LINMAP
#     core type: Literal
#     sub-expressions:
# 50. (H, H)
#     core type: ExprTuple
#     sub-expressions: 121, 121
# 51. exists
#     core type: Literal
#     sub-expressions:
# 52. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 57\n    body: 58
# 55. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 128
#     operands: 59
# 56. O.N.Bases(H)
#     core type: Operation
#     operator: 60
#     operand: 121
# 57. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. {(A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 64
#     condition: 65
# 59. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 66
# 60. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 61. (H)
#     core type: ExprTuple
#     sub-expressions: 121
# 62. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 123
#     end_index: 124
# 63. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 123
#     end_index: 124
# 64. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 70
#     operands: 69
# 65. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 123
#     end_index: 124
# 67. _a -> a_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 96
# 68. _a -> b_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 97
# 69. (A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))), B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 70. and
#     core type: Literal
#     sub-expressions:
# 71. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. _a -> x_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 77
# 73. A = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 79
#     operands: 78
# 74. B = (Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 79
#     operands: 80
# 75. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 123
#     end_index: 124
# 76. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 123
#     end_index: 124
# 77. x_{_a}
#     core type: IndexedVar
# variable: 131
# index: 105
# 78. (A, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 79. =
#     core type: Literal
#     sub-expressions:
# 80. (B, Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 81. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 105
#     body: 87
# 82. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 105
#     body: 88
# 83. A
#     core type: Variable
#     sub-expressions:
# 84. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 90
#     operand: 94
# 85. B
#     core type: Variable
#     sub-expressions:
# 86. Sum_{i=1}^{n} (b_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 90
#     operand: 95
# 87. a_{_a} in Complex
#     core type: Operation
#     operator: 109
#     operands: 92
# 88. b_{_a} in Complex
#     core type: Operation
#     operator: 109
#     operands: 93
# 89. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 94
# 90. Sum
#     core type: Literal
#     sub-expressions:
# 91. (i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 96, 98
# 93. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 97, 98
# 94. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 133
#     body: 99
# 95. i -> {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 133
#     body: 100
# 96. a_{_a}
#     core type: IndexedVar
# variable: 115
# index: 105
# 97. b_{_a}
#     core type: IndexedVar
# variable: 116
# index: 105
# 98. Complex
#     core type: Literal
#     sub-expressions:
# 99. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 102
#     condition: 104
# 100. {b_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#      core type: Conditional
#      value: 103
#      condition: 104
# 101. (_a)
#      core type: ExprTuple
#      sub-expressions: 105
# 102. a_{i} * OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 107
#      operands: 106
# 103. b_{i} * OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 107
#      operands: 108
# 104. i in {1 .. n}
#      core type: Operation
#      operator: 109
#      operands: 110
# 105. _a
#      core type: Variable
#      sub-expressions:
# 106. (a_{i}, OrthoProj(H, Span({x_{i}})))
#      core type: ExprTuple
#      sub-expressions: 111, 113
# 107. *
#      core type: Literal
#      sub-expressions:
# 108. (b_{i}, OrthoProj(H, Span({x_{i}})))
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 109. in
#      core type: Literal
#      sub-expressions:
# 110. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 133, 114
# 111. a_{i}
#      core type: IndexedVar
# variable: 115
# index: 133
# 112. b_{i}
#      core type: IndexedVar
# variable: 116
# index: 133
# 113. OrthoProj(H, Span({x_{i}}))
#      core type: Operation
#      operator: 117
#      operands: 118
# 114. {1 .. n}
#      core type: Operation
#      operator: 119
#      operands: 120
# 115. a
#      core type: Variable
#      sub-expressions:
# 116. b
#      core type: Variable
#      sub-expressions:
# 117. OrthoProj
#      core type: Literal
#      sub-expressions:
# 118. (H, Span({x_{i}}))
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 119. Interval
#      core type: Literal
#      sub-expressions:
# 120. (1, n)
#      core type: ExprTuple
#      sub-expressions: 123, 124
# 121. H
#      core type: Variable
#      sub-expressions:
# 122. Span({x_{i}})
#      core type: Operation
#      operator: 125
#      operand: 127
# 123. 1
#      core type: Literal
#      sub-expressions:
# 124. n
#      core type: Variable
#      sub-expressions:
# 125. Span
#      core type: Literal
#      sub-expressions:
# 126. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 127
# 127. {x_{i}}
#      core type: Operation
#      operator: 128
#      operand: 130
# 128. Set
#      core type: Literal
#      sub-expressions:
# 129. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 130
# 130. x_{i}
#      core type: IndexedVar
# variable: 131
# index: 133
# 131. x
#      core type: Variable
#      sub-expressions:
# 132. (i)
#      core type: ExprTuple
#      sub-expressions: 133
# 133. i
#      core type: Variable
#      sub-expressions:
