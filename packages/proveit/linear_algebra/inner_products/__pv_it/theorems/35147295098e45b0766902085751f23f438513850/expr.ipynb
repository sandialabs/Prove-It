# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Conditional(Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), InSet(Set(a_1_to_m), OrthoNormBases(A)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } \left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#    core type: Operation
#    operator: 15
#    operand: 5
# 2. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#    core type: Operation
#    operator: 57
#    operands: 4
# 3. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Lambda
#    parameters: 26\n   body: 8
# 6. {a_{1}, a_{2}, ..., a_{m}}
#    core type: Operation
#    operator: 25
#    operands: 9
# 7. O.N.Bases(A)
#    core type: Operation
#    operator: 27
#    operand: 14
# 8. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. (a_{1}, a_{2}, ..., a_{m})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. (A)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 15
#     operand: 19
# 12. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 57
#     operands: 17
# 13. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 71
#     end_index: 79
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. exists
#     core type: Literal
#     sub-expressions:
# 16. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. _a -> a_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 22
# 19. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 20. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. O.N.Bases(B)
#     core type: Operation
#     operator: 27
#     operand: 33
# 22. a_{_a}
#     core type: IndexedVar
# variable: 73
# index: 63
# 23. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 29
# 24. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 30
#     condition: 31
# 25. Set
#     core type: Literal
#     sub-expressions:
# 26. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 27. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 28. (B)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 71
#     end_index: 72
# 30. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 71
#     end_index: 80
# 33. B
#     core type: Variable
#     sub-expressions:
# 34. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 53
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 42
# 39. _a -> b_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 43
# 40. v
#     core type: Variable
#     sub-expressions:
# 41. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 44
#     operand: 47
# 42. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 71
#     end_index: 72
# 43. b_{_a}
#     core type: IndexedVar
# variable: 74
# index: 63
# 44. Sum
#     core type: Literal
#     sub-expressions:
# 45. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 63
#     body: 48
# 47. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 78
#     body: 49
# 48. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 57
#     operands: 50
# 49. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 51
#     condition: 52
# 50. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. lambda_{_a}
#     core type: IndexedVar
# variable: 64
# index: 63
# 54. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 78, 62
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 60. lambda_{i}
#     core type: IndexedVar
# variable: 64
# index: 78
# 61. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 65
#     operands: 66
# 62. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. _a
#     core type: Variable
#     sub-expressions:
# 64. lambda
#     core type: Variable
#     sub-expressions:
# 65. otimes
#     core type: Literal
#     sub-expressions:
# 66. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 67. Interval
#     core type: Literal
#     sub-expressions:
# 68. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 69. a_{i}
#     core type: IndexedVar
# variable: 73
# index: 78
# 70. b_{i}
#     core type: IndexedVar
# variable: 74
# index: 78
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. Min(m, n)
#     core type: Operation
#     operator: 76
#     operands: 77
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. b
#     core type: Variable
#     sub-expressions:
# 75. (i)
#     core type: ExprTuple
#     sub-expressions: 78
# 76. Min
#     core type: Literal
#     sub-expressions:
# 77. (m, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 78. i
#     core type: Variable
#     sub-expressions:
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
