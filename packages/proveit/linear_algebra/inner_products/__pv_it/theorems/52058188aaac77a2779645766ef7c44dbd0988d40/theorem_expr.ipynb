# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#spectral_decomposition_as_ortho_ortho_projectors">spectral_decomposition_as_ortho_ortho_projectors</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.inner_products import spectral_decomposition_as_ortho_ortho_projectors

# %%
# check that the built expression is the same as the stored expression
assert spectral_decomposition_as_ortho_ortho_projectors.expr == stored_expr
assert spectral_decomposition_as_ortho_ortho_projectors.expr._style_id == stored_expr._style_id
print("Passed sanity check: spectral_decomposition_as_ortho_ortho_projectors matches stored_expr")
# Out:
# Passed sanity check: spectral_decomposition_as_ortho_ortho_projectors matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \circ M\right) = \left(M \circ M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \textrm{OrthoProj}\left(\mathcal{H}, \textrm{Span}\left(\left\{x_{i}\right\}\right)\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.
#    core type: Lambda
#    parameter: 104
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 104
# 4. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 89
#    operands: 8
# 7. (H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 104, 10
# 9. H -> {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 101
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{M in LINMAP(H, H)} (((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]])
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 69
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. M -> {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Lambda
#     parameter: 72
#     body: 20
# 18. H in_c HilbertSpaces
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Dim(H) = n
#     core type: Operation
#     operator: 67
#     operands: 23
# 20. {((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. in_c
#     core type: Literal
#     sub-expressions:
# 22. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 101, 26
# 23. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 27, 104
# 24. ((M* o M) = (M o M*)) <=>  \\ [exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]]
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. M in LINMAP(H, H)
#     core type: Operation
#     operator: 89
#     operands: 30
# 26. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 27. Dim(H)
#     core type: Operation
#     operator: 31
#     operand: 101
# 28. <=>
#     core type: Literal
#     sub-expressions:
# 29. ((M* o M) = (M o M*), exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))])
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 72, 34
# 31. Dim
#     core type: Literal
#     sub-expressions:
# 32. (M* o M) = (M o M*)
#     core type: Operation
#     operator: 67
#     operands: 35
# 33. exists_{x_{1}, x_{2}, ..., x_{n} | {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))]
#     core type: Operation
#     operator: 51
#     operand: 41
# 34. LINMAP(H, H)
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (M* o M, M o M*)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. ((x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. LINMAP
#     core type: Literal
#     sub-expressions:
# 38. (H, H)
#     core type: ExprTuple
#     sub-expressions: 101, 101
# 39. M* o M
#     core type: Operation
#     operator: 43
#     operands: 42
# 40. M o M*
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (x_{1}, x_{2}, ..., x_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 59\n    body: 45
# 42. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 46, 72
# 43. o
#     core type: Literal
#     sub-expressions:
# 44. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 72, 46
# 45. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))) if {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 47
#     condition: 48
# 46. M*
#     core type: Operation
#     operator: 49
#     operand: 72
# 47. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))))
#     core type: Operation
#     operator: 51
#     operand: 54
# 48. {x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 89
#     operands: 53
# 49. Adj
#     core type: Literal
#     sub-expressions:
# 50. (M)
#     core type: ExprTuple
#     sub-expressions: 72
# 51. exists
#     core type: Literal
#     sub-expressions:
# 52. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. ({x_{1}, x_{2}, ..., x_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 57\n    body: 58
# 55. {x_{1}, x_{2}, ..., x_{n}}
#     core type: Operation
#     operator: 108
#     operands: 59
# 56. O.N.Bases(H)
#     core type: Operation
#     operator: 60
#     operand: 101
# 57. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 58. {M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 63
#     condition: 64
# 59. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 65
# 60. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 61. (H)
#     core type: ExprTuple
#     sub-expressions: 101
# 62. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 103
#     end_index: 104
# 63. M = (Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: Operation
#     operator: 67
#     operands: 68
# 64. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 103
#     end_index: 104
# 66. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 85
# 67. =
#     core type: Literal
#     sub-expressions:
# 68. (M, Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}}))))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 69. and
#     core type: Literal
#     sub-expressions:
# 70. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 74
# 71. _a -> x_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 75
# 72. M
#     core type: Variable
#     sub-expressions:
# 73. Sum_{i=1}^{n} (a_{i} * OrthoProj(H, Span({x_{i}})))
#     core type: Operation
#     operator: 76
#     operand: 79
# 74. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 103
#     end_index: 104
# 75. x_{_a}
#     core type: IndexedVar
# variable: 111
# index: 95
# 76. Sum
#     core type: Literal
#     sub-expressions:
# 77. (i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 79
# 78. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 95
#     body: 80
# 79. i -> {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 113
#     body: 81
# 80. a_{_a} in Complex
#     core type: Operation
#     operator: 89
#     operands: 82
# 81. {a_{i} * OrthoProj(H, Span({x_{i}})) if i in {1 .. n}.
#     core type: Conditional
#     value: 83
#     condition: 84
# 82. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 83. a_{i} * OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 87
#     operands: 88
# 84. i in {1 .. n}
#     core type: Operation
#     operator: 89
#     operands: 90
# 85. a_{_a}
#     core type: IndexedVar
# variable: 96
# index: 95
# 86. Complex
#     core type: Literal
#     sub-expressions:
# 87. *
#     core type: Literal
#     sub-expressions:
# 88. (a_{i}, OrthoProj(H, Span({x_{i}})))
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. in
#     core type: Literal
#     sub-expressions:
# 90. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 113, 94
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. a_{i}
#     core type: IndexedVar
# variable: 96
# index: 113
# 93. OrthoProj(H, Span({x_{i}}))
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. {1 .. n}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. a
#     core type: Variable
#     sub-expressions:
# 97. OrthoProj
#     core type: Literal
#     sub-expressions:
# 98. (H, Span({x_{i}}))
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. Interval
#     core type: Literal
#     sub-expressions:
# 100. (1, n)
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 101. H
#      core type: Variable
#      sub-expressions:
# 102. Span({x_{i}})
#      core type: Operation
#      operator: 105
#      operand: 107
# 103. 1
#      core type: Literal
#      sub-expressions:
# 104. n
#      core type: Variable
#      sub-expressions:
# 105. Span
#      core type: Literal
#      sub-expressions:
# 106. ({x_{i}})
#      core type: ExprTuple
#      sub-expressions: 107
# 107. {x_{i}}
#      core type: Operation
#      operator: 108
#      operand: 110
# 108. Set
#      core type: Literal
#      sub-expressions:
# 109. (x_{i})
#      core type: ExprTuple
#      sub-expressions: 110
# 110. x_{i}
#      core type: IndexedVar
# variable: 111
# index: 113
# 111. x
#      core type: Variable
#      sub-expressions:
# 112. (i)
#      core type: ExprTuple
#      sub-expressions: 113
# 113. i
#      core type: Variable
#      sub-expressions:
