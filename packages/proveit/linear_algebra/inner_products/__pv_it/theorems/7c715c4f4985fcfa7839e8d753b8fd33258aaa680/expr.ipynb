# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import H, K, Lambda, n, v
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import Dim, InnerProdSpaces, OrthoNormBases
from proveit.logic import And, Equals, Exists, Forall, InSet, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(x_1_to_n)
expr = Lambda(K, Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [H], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [x_1_to_n], instance_expr = And(InSet(v, sub_expr1), InSet(sub_expr1, OrthoNormBases(H))).with_wrapping_at(2)), domain = H), domain = InnerProdSpaces(K), condition = Equals(Dim(H), n)).with_wrapping(), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{H \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)~|~\textrm{Dim}\left(H\right) = n}~\\
# \left[\forall_{v \in H}~\left[\exists_{x_{1}, x_{2}, \ldots, x_{n}}~\left(\begin{array}{c} \left(v \in \left\{x_{1}, x_{2}, \ldots, x_{n}\right\}\right) \land  \\ \left(\left\{x_{1}, x_{2}, \ldots, x_{n}\right\} \in \textrm{O.N.Bases}\left(H\right)\right) \end{array}\right)\right]\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]]
#    core type: Lambda
#    parameter: 38
#    body: 1
# 1. forall_{n in NaturalPos} [forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]]]
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (n -> {forall_{H in_c InnerProdSpaces(K) | Dim(H) = n} [forall_{v in H} [exists_{x_{1}, x_{2}, ..., x_{n}} ((v in {x_{1}, x_{2}, ..., x_{n}}) and  \\ ({x_{1}, x_{2}, ..., x_{n}} in O.N.Bases(H)))]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# ...
