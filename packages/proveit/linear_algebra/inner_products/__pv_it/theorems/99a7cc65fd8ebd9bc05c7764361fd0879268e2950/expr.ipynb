# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import Dim, HilbertSpaces, OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import And, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Interval, Min, NaturalPos, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = ExprTuple(Lambda([m, n], Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping(), condition = InSet(Set(a_1_to_m), OrthoNormBases(A))).with_wrapping(), domain = TensorProd(A, B)), domain = HilbertSpaces, conditions = [Equals(Dim(A), m), Equals(Dim(B), n)]).with_wrapping(), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(m, n\right) \mapsto \left\{\begin{array}{l}\forall_{A, B \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(A\right) = m, \textrm{Dim}\left(B\right) = n}~\\
# \left[\forall_{v \in A {\otimes} B}~\left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{a_{1}, a_{2}, \ldots, a_{m}\right\} \in \textrm{O.N.Bases}\left(A\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\right]\end{array} \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((m, n) -> {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (m, n) -> {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 119\n   body: 2
# 2. {forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A, B in_c HilbertSpaces | Dim(A) = m, Dim(B) = n} [forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]]
#    core type: Operation
#    operator: 16
#    operand: 7
# 4. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 79
#    operands: 6
# 5. ((A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (A, B) -> {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#    core type: Lambda
#    parameters: 42\n   body: 10
# 8. m in NaturalPos
#    core type: Operation
#    operator: 99
#    operands: 11
# 9. n in NaturalPos
#    core type: Operation
#    operator: 99
#    operands: 12
# 10. {forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]] if A in_c HilbertSpaces ,  B in_c HilbertSpaces ,  Dim(A) = m ,  Dim(B) = n.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 121, 15
# 12. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 122, 15
# 13. forall_{v in A otimes B} [exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]]
#     core type: Operation
#     operator: 16
#     operand: 19
# 14. (A in_c HilbertSpaces) and (B in_c HilbertSpaces) and (Dim(A) = m) and (Dim(B) = n)
#     core type: Operation
#     operator: 79
#     operands: 18
# 15. NaturalPos
#     core type: Literal
#     sub-expressions:
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (A in_c HilbertSpaces, B in_c HilbertSpaces, Dim(A) = m, Dim(B) = n)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22, 23
# 19. v -> {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Lambda
#     parameter: 82
#     body: 25
# 20. A in_c HilbertSpaces
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. B in_c HilbertSpaces
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. Dim(A) = m
#     core type: Operation
#     operator: 77
#     operands: 29
# 23. Dim(B) = n
#     core type: Operation
#     operator: 77
#     operands: 30
# 24. (v)
#     core type: ExprTuple
#     sub-expressions: 82
# 25. {exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]] if v in (A otimes B).
#     core type: Conditional
#     value: 31
#     condition: 32
# 26. (A, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 56, 33
# 27. in_c
#     core type: Literal
#     sub-expressions:
# 28. (B, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 75, 33
# 29. (Dim(A), m)
#     core type: ExprTuple
#     sub-expressions: 34, 121
# 30. (Dim(B), n)
#     core type: ExprTuple
#     sub-expressions: 35, 122
# 31. exists_{a_{1}, a_{2}, ..., a_{m} | {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)} [exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]]
#     core type: Operation
#     operator: 57
#     operand: 39
# 32. v in (A otimes B)
#     core type: Operation
#     operator: 99
#     operands: 37
# 33. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 34. Dim(A)
#     core type: Operation
#     operator: 38
#     operand: 56
# 35. Dim(B)
#     core type: Operation
#     operator: 38
#     operand: 75
# 36. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).)
#     core type: ExprTuple
#     sub-expressions: 39
# 37. (v, A otimes B)
#     core type: ExprTuple
#     sub-expressions: 82, 40
# 38. Dim
#     core type: Literal
#     sub-expressions:
# 39. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Lambda
#     parameters: 51\n    body: 41
# 40. A otimes B
#     core type: Operation
#     operator: 107
#     operands: 42
# 41. {exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))] if {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A).
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. (A, B)
#     core type: ExprTuple
#     sub-expressions: 56, 75
# 43. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#     core type: Operation
#     operator: 57
#     operand: 47
# 44. {a_{1}, a_{2}, ..., a_{m}} in O.N.Bases(A)
#     core type: Operation
#     operator: 99
#     operands: 46
# 45. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. ({a_{1}, a_{2}, ..., a_{m}}, O.N.Bases(A))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Lambda
#     parameters: 68\n    body: 50
# 48. {a_{1}, a_{2}, ..., a_{m}}
#     core type: Operation
#     operator: 67
#     operands: 51
# 49. O.N.Bases(A)
#     core type: Operation
#     operator: 69
#     operand: 56
# 50. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#     core type: Conditional
#     value: 53
#     condition: 54
# 51. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. (A)
#     core type: ExprTuple
#     sub-expressions: 56
# 53. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#     core type: Operation
#     operator: 57
#     operand: 61
# 54. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#     core type: Operation
#     operator: 99
#     operands: 59
# 55. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 113
#     end_index: 121
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. exists
#     core type: Literal
#     sub-expressions:
# 58. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 61
# 59. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. _a -> a_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 64
# 61. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 65\n    body: 66
# 62. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. O.N.Bases(B)
#     core type: Operation
#     operator: 69
#     operand: 75
# 64. a_{_a}
#     core type: IndexedVar
# variable: 115
# index: 105
# 65. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 71
# 66. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 72
#     condition: 73
# 67. Set
#     core type: Literal
#     sub-expressions:
# 68. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 74
# 69. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 70. (B)
#     core type: ExprTuple
#     sub-expressions: 75
# 71. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 113
#     end_index: 114
# 72. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 77
#     operands: 78
# 73. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 79
#     operands: 80
# 74. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 113
#     end_index: 122
# 75. B
#     core type: Variable
#     sub-expressions:
# 76. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 95
# 77. =
#     core type: Literal
#     sub-expressions:
# 78. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 79. and
#     core type: Literal
#     sub-expressions:
# 80. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 84
# 81. _a -> b_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 85
# 82. v
#     core type: Variable
#     sub-expressions:
# 83. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 86
#     operand: 89
# 84. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 88
#     start_index: 113
#     end_index: 114
# 85. b_{_a}
#     core type: IndexedVar
# variable: 116
# index: 105
# 86. Sum
#     core type: Literal
#     sub-expressions:
# 87. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 89
# 88. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 105
#     body: 90
# 89. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 120
#     body: 91
# 90. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 99
#     operands: 92
# 91. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 93
#     condition: 94
# 92. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 93. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. lambda_{_a}
#     core type: IndexedVar
# variable: 106
# index: 105
# 96. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 97. *
#     core type: Literal
#     sub-expressions:
# 98. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 99. in
#     core type: Literal
#     sub-expressions:
# 100. (i, {1 .. Min(m, n)})
#      core type: ExprTuple
#      sub-expressions: 120, 104
# 101. (_a)
#      core type: ExprTuple
#      sub-expressions: 105
# 102. lambda_{i}
#      core type: IndexedVar
# variable: 106
# index: 120
# 103. a_{i} otimes b_{i}
#      core type: Operation
#      operator: 107
#      operands: 108
# 104. {1 .. Min(m, n)}
#      core type: Operation
#      operator: 109
#      operands: 110
# 105. _a
#      core type: Variable
#      sub-expressions:
# 106. lambda
#      core type: Variable
#      sub-expressions:
# 107. otimes
#      core type: Literal
#      sub-expressions:
# 108. (a_{i}, b_{i})
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 109. Interval
#      core type: Literal
#      sub-expressions:
# 110. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 113, 114
# 111. a_{i}
#      core type: IndexedVar
# variable: 115
# index: 120
# 112. b_{i}
#      core type: IndexedVar
# variable: 116
# index: 120
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. Min(m, n)
#      core type: Operation
#      operator: 118
#      operands: 119
# 115. a
#      core type: Variable
#      sub-expressions:
# 116. b
#      core type: Variable
#      sub-expressions:
# 117. (i)
#      core type: ExprTuple
#      sub-expressions: 120
# 118. Min
#      core type: Literal
#      sub-expressions:
# 119. (m, n)
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 120. i
#      core type: Variable
#      sub-expressions:
# 121. m
#      core type: Variable
#      sub-expressions:
# 122. n
#      core type: Variable
#      sub-expressions:
