# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.inner_products</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprRange, IndexedVar, Variable, i, lambda_, m, n, v
from proveit.core_expr_types import a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Interval, Min, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(v, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, TensorProd(a_i, b_i)), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n), OrthoNormBases(B))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{b_{1}, b_{2}, \ldots, b_{n}\right\} \in \textrm{O.N.Bases}\left(B\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(v = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(a_{i} {\otimes} b_{i}\right)\right)\right)\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{b_{1}, b_{2}, ..., b_{n} | {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))) if {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. {b_{1}, b_{2}, ..., b_{n}} in O.N.Bases(B)
#    core type: Operation
#    operator: 46
#    operands: 8
# 6. exists
#    core type: Literal
#    sub-expressions:
# 7. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. ({b_{1}, b_{2}, ..., b_{n}}, O.N.Bases(B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 10. {b_{1}, b_{2}, ..., b_{n}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. O.N.Bases(B)
#     core type: Operation
#     operator: 16
#     operand: 22
# 12. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 18
# 13. {v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 19
#     condition: 20
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 17. (B)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 60
#     end_index: 61
# 19. v = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 60
#     end_index: 69
# 22. B
#     core type: Variable
#     sub-expressions:
# 23. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 42
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (v, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i})))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. _a -> b_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 32
# 29. v
#     core type: Variable
#     sub-expressions:
# 30. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (a_{i} otimes b_{i}))
#     core type: Operation
#     operator: 33
#     operand: 36
# 31. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 60
#     end_index: 61
# 32. b_{_a}
#     core type: IndexedVar
# variable: 63
# index: 52
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 35. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 52
#     body: 37
# 36. i -> {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 67
#     body: 38
# 37. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 46
#     operands: 39
# 38. {lambda_{i} * (a_{i} otimes b_{i}) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 39. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. lambda_{i} * (a_{i} otimes b_{i})
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. lambda_{_a}
#     core type: IndexedVar
# variable: 53
# index: 52
# 43. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (lambda_{i}, a_{i} otimes b_{i})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 67, 51
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. lambda_{i}
#     core type: IndexedVar
# variable: 53
# index: 67
# 50. a_{i} otimes b_{i}
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. _a
#     core type: Variable
#     sub-expressions:
# 53. lambda
#     core type: Variable
#     sub-expressions:
# 54. otimes
#     core type: Literal
#     sub-expressions:
# 55. (a_{i}, b_{i})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. a_{i}
#     core type: IndexedVar
# variable: 62
# index: 67
# 59. b_{i}
#     core type: IndexedVar
# variable: 63
# index: 67
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. Min(m, n)
#     core type: Operation
#     operator: 65
#     operands: 66
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. (i)
#     core type: ExprTuple
#     sub-expressions: 67
# 65. Min
#     core type: Literal
#     sub-expressions:
# 66. (m, n)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 67. i
#     core type: Variable
#     sub-expressions:
# 68. m
#     core type: Variable
#     sub-expressions:
# 69. n
#     core type: Variable
#     sub-expressions:
