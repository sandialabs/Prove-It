# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">inner_products</a>.<a class="ProveItLink" href="../../theorems.ipynb#inner_prod_field_membership">inner_prod_field_membership</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.linear_algebra.inner_products import inner_prod_space_def

theory = proveit.Theory() # the theorem's theory

# %%
# %proving inner_prod_field_membership
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="inner_prod_field_membership">inner_prod_field_membership:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7cf5d54b221e6363fc40e6ec5ab2eabf4b71fd070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a3461a1fb46cc9b0a44a5c8c560c39a2cacea8420/dependencies.ipynb">dependencies</a>)<br>
# inner_prod_field_membership may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = inner_prod_field_membership.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_inner_prod_field_membership/cb30bb916e1d56fb69d479f19b4d34a4be00f2860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
inner_prod_space_def
# Out:
# |- forall_{K, H} ((H in_c InnerProdSpaces(K)) = ((H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)]))

# %%
inner_prod_space_def_inst = inner_prod_space_def.instantiate()
# Out:
# <strong id="inner_prod_space_def_inst">inner_prod_space_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_inner_prod_field_membership/cbcbf26fd4377b1c7a8b81111562a3df51e2e1b20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/5b2c3925a53fa6a217eae2b91fd97cd2229316ae0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
inner_prod_space_def_inst.derive_right_via_equality()
# Out:
# {H in_c InnerProdSpaces(K)} |- (H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)]

# %%
# %qed
# Out:
# proveit.linear_algebra.inner_products.inner_prod_field_membership has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{K, H | H in_c InnerProdSpaces(K)} [forall_{x, y in H} (<x, y> in K)]
# 1	instantiation	2, 3	{H in_c InnerProdSpaces(K)} |- forall_{x, y in H} (<x, y> in K)
# 	A : H in_c VecSpaces(K), B : forall_{x, y in H} (<x, y> in K)
# 2	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 3	instantiation	4, 5, 6	{H in_c InnerProdSpaces(K)} |- (H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)]
# 	P : H in_c InnerProdSpaces(K), Q : (H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)]
# 4	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 5	assumption		{H in_c InnerProdSpaces(K)} |- H in_c InnerProdSpaces(K)
# 6	instantiation	7	|- (H in_c InnerProdSpaces(K)) = ((H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)])
# 	K : K, H : H
# 7	axiom		|- forall_{K, H} ((H in_c InnerProdSpaces(K)) = ((H in_c VecSpaces(K)) and [forall_{x, y in H} (<x, y> in K)]))
# 	proveit.linear_algebra.inner_products.inner_prod_space_def
