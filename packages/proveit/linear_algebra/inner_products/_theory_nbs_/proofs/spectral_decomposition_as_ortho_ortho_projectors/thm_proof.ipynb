# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">inner_products</a>.<a class="ProveItLink" href="../../theorems.ipynb#spectral_decomposition_as_ortho_ortho_projectors">spectral_decomposition_as_ortho_ortho_projectors</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving spectral_decomposition_as_ortho_ortho_projectors
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="spectral_decomposition_as_ortho_ortho_projectors">spectral_decomposition_as_ortho_ortho_projectors:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/41dc86d11c57d647f8a16a2e3d62e2c61dc87f1b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/52058188aaac77a2779645766ef7c44dbd0988d40/dependencies.ipynb">dependencies</a>)<br>
