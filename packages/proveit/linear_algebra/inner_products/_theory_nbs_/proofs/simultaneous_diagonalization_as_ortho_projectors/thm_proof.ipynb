# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">inner_products</a>.<a class="ProveItLink" href="../../theorems.ipynb#simultaneous_diagonalization_as_ortho_projectors">simultaneous_diagonalization_as_ortho_projectors</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving simultaneous_diagonalization_as_ortho_projectors
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="simultaneous_diagonalization_as_ortho_projectors">simultaneous_diagonalization_as_ortho_projectors:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f39bb5f57e5aa9a13866572ae7b6fe58c4a67a730/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ce0927b6d8023fd3f4faf63186a92a89fabd82e70/dependencies.ipynb">dependencies</a>)<br>
