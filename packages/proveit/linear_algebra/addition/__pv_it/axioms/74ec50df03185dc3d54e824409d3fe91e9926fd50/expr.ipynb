# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, i, v, vb, vi
from proveit.linear_algebra import VecAdd, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Integer, Interval, Less, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Forall(instance_param_or_params = [v], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, b)), VecAdd(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, subtract(b, one))), vb)), domain = Integer, condition = Less(a, b)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{v}~\left[\forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{i=a}^{b} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b - 1} v\left(i\right)\right) + v\left(b\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v} [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (v -> [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. v -> [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)))]
#    core type: Lambda
#    parameter: 42
#    body: 4
# 3. (v)
#    core type: ExprTuple
#    sub-expressions: 42
# 4. forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {(Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (a, b) -> {(Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Lambda
#    parameters: 41\n   body: 8
# 8. {(Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (Sum_{i=a}^{b} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + v(b))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in Integer) and (b in Integer) and (a < b)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Sum_{i=a}^{b} v(i), (Sum_{i=a}^{b - 1} v(i)) + v(b))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in Integer, b in Integer, a < b)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 15. Sum_{i=a}^{b} v(i)
#     core type: Operation
#     operator: 31
#     operand: 26
# 16. (Sum_{i=a}^{b - 1} v(i)) + v(b)
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. a in Integer
#     core type: Operation
#     operator: 44
#     operands: 23
# 18. b in Integer
#     core type: Operation
#     operator: 44
#     operands: 24
# 19. a < b
#     core type: Operation
#     operator: 25
#     operands: 41
# 20. (i -> {v(i) if i in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (Sum_{i=a}^{b - 1} v(i), v(b))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 50, 29
# 24. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 54, 29
# 25. <
#     core type: Literal
#     sub-expressions:
# 26. i -> {v(i) if i in {a .. b}.
#     core type: Lambda
#     parameter: 46
#     body: 30
# 27. Sum_{i=a}^{b - 1} v(i)
#     core type: Operation
#     operator: 31
#     operand: 35
# 28. v(b)
#     core type: Operation
#     operator: 42
#     operand: 54
# 29. Integer
#     core type: Literal
#     sub-expressions:
# 30. {v(i) if i in {a .. b}.
#     core type: Conditional
#     value: 39
#     condition: 34
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (i -> {v(i) if i in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. (b)
#     core type: ExprTuple
#     sub-expressions: 54
# 34. i in {a .. b}
#     core type: Operation
#     operator: 44
#     operands: 36
# 35. i -> {v(i) if i in {a .. b - 1}.
#     core type: Lambda
#     parameter: 46
#     body: 37
# 36. (i, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 46, 38
# 37. {v(i) if i in {a .. b - 1}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 38. {a .. b}
#     core type: Operation
#     operator: 48
#     operands: 41
# 39. v(i)
#     core type: Operation
#     operator: 42
#     operand: 46
# 40. i in {a .. b - 1}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (a, b)
#     core type: ExprTuple
#     sub-expressions: 50, 54
# 42. v
#     core type: Variable
#     sub-expressions:
# 43. (i)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (i, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. {a .. b - 1}
#     core type: Operation
#     operator: 48
#     operands: 49
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. b - 1
#     core type: Operation
#     operator: 52
#     operands: 53
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. -1
#     core type: Operation
#     operator: 56
#     operand: 58
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. 1
#     core type: Literal
#     sub-expressions:
