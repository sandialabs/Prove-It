# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, i, j, k, v
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([j, k], Conditional(Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(VecSum(index_or_indices = [i], summand = v, domain = Interval(j, k)), ScalarMult(Add(subtract(k, j), one), v)), domain = V), domain = VecSpaces(K)), And(InSet(j, Integer), InSet(k, Integer), LessEq(j, k)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(j, k\right) \mapsto \left\{\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{v \in V}~\left(\left(\sum_{i=j}^{k} v\right) = \left(\left(\left(k - j\right) + 1\right) \cdot v\right)\right)\right] \textrm{ if } j \in \mathbb{Z} ,  k \in \mathbb{Z} ,  j \leq k\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 60\n   body: 2
# 2. {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]
#    core type: Operation
#    operator: 20
#    operand: 8
# 4. (j in Integer) and (k in Integer) and (j <= k)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (j in Integer, k in Integer, j <= k)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 38
#    body: 13
# 9. j in Integer
#    core type: Operation
#    operator: 52
#    operands: 14
# 10. k in Integer
#     core type: Operation
#     operator: 52
#     operands: 15
# 11. j <= k
#     core type: Operation
#     operator: 16
#     operands: 60
# 12. (V)
#     core type: ExprTuple
#     sub-expressions: 38
# 13. {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 19
# 15. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 19
# 16. <=
#     core type: Literal
#     sub-expressions:
# 17. forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. (v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. in_c
#     core type: Literal
#     sub-expressions:
# 23. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 38, 25
# 24. v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Lambda
#     parameter: 48
#     body: 27
# 25. VecSpaces(K)
#     core type: Operation
#     operator: 28
#     operand: 32
# 26. (v)
#     core type: ExprTuple
#     sub-expressions: 48
# 27. {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Conditional
#     value: 30
#     condition: 31
# 28. VecSpaces
#     core type: Literal
#     sub-expressions:
# 29. (K)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. (Sum_{i=j}^{k} v) = (((k - j) + 1) * v)
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. v in V
#     core type: Operation
#     operator: 52
#     operands: 35
# 32. K
#     core type: Variable
#     sub-expressions:
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (Sum_{i=j}^{k} v, ((k - j) + 1) * v)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. (v, V)
#     core type: ExprTuple
#     sub-expressions: 48, 38
# 36. Sum_{i=j}^{k} v
#     core type: Operation
#     operator: 39
#     operand: 43
# 37. ((k - j) + 1) * v
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. V
#     core type: Variable
#     sub-expressions:
# 39. Sum
#     core type: Literal
#     sub-expressions:
# 40. (i -> {v if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. ((k - j) + 1, v)
#     core type: ExprTuple
#     sub-expressions: 44, 48
# 43. i -> {v if i in {j .. k}.
#     core type: Lambda
#     parameter: 56
#     body: 46
# 44. (k - j) + 1
#     core type: Operation
#     operator: 54
#     operands: 47
# 45. (i)
#     core type: ExprTuple
#     sub-expressions: 56
# 46. {v if i in {j .. k}.
#     core type: Conditional
#     value: 48
#     condition: 49
# 47. (k - j, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. v
#     core type: Variable
#     sub-expressions:
# 49. i in {j .. k}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. k - j
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 63, 58
# 56. i
#     core type: Variable
#     sub-expressions:
# 57. {j .. k}
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. -j
#     core type: Operation
#     operator: 61
#     operand: 64
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (j, k)
#     core type: ExprTuple
#     sub-expressions: 64, 63
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (j)
#     core type: ExprTuple
#     sub-expressions: 64
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. j
#     core type: Variable
#     sub-expressions:
