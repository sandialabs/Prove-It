# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, V, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.linear_algebra import VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b, c_1_to_j, d_1_to_k), VecAdd(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d_{1}, d_{2}, \ldots, d_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j} + b+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]]]
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]]
#    core type: Operation
#    operator: 20
#    operand: 3
# 2. (V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 72
#    body: 5
# 4. (V)
#    core type: ExprTuple
#    sub-expressions: 72
# 5. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 20
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 72, 12
# 11. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 59, 61, 64
# 14. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 36
#     operands: 22
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 23. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Lambda
#     parameters: 44\n    body: 27
# 24. i in Natural
#     core type: Operation
#     operator: 67
#     operands: 28
# 25. j in Natural
#     core type: Operation
#     operator: 67
#     operands: 29
# 26. k in Natural
#     core type: Operation
#     operator: 67
#     operands: 30
# 27. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Conditional
#     value: 31
#     condition: 32
# 28. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 33
# 29. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 61, 33
# 30. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 64, 33
# 31. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V) and (b in V)and (c_{1} in V) and  (c_{2} in V) and  ... and  (c_{j} in V)and (d_{1} in V) and  (d_{2} in V) and  ... and  (d_{k} in V)
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. Natural
#     core type: Literal
#     sub-expressions:
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V), b in V,(c_{1} in V), (c_{2} in V), ..., (c_{j} in V),(d_{1} in V), (d_{2} in V), ..., (d_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42, 43
# 38. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 45
#     operands: 44
# 39. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 63
#     end_index: 59
# 41. b in V
#     core type: Operation
#     operator: 67
#     operands: 48
# 42. (c_{1} in V), (c_{2} in V), ..., (c_{j} in V)
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 63
#     end_index: 61
# 43. (d_{1} in V), (d_{2} in V), ..., (d_{k} in V)
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 63
#     end_index: 64
# 44. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 55, 52, 53
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j}, b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 52, 55, 53
# 47. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 77
#     body: 54
# 48. (b, V)
#     core type: ExprTuple
#     sub-expressions: 55, 72
# 49. _a -> (c_{_a} in V)
#     core type: Lambda
#     parameter: 77
#     body: 56
# 50. _a -> (d_{_a} in V)
#     core type: Lambda
#     parameter: 77
#     body: 57
# 51. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 63
#     end_index: 59
# 52. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 63
#     end_index: 61
# 53. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 63
#     end_index: 64
# 54. a_{_a} in V
#     core type: Operation
#     operator: 67
#     operands: 65
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. c_{_a} in V
#     core type: Operation
#     operator: 67
#     operands: 66
# 57. d_{_a} in V
#     core type: Operation
#     operator: 67
#     operands: 68
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 69
# 59. i
#     core type: Variable
#     sub-expressions:
# 60. _a -> c_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 70
# 61. j
#     core type: Variable
#     sub-expressions:
# 62. _a -> d_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 71
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. k
#     core type: Variable
#     sub-expressions:
# 65. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 69, 72
# 66. (c_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 70, 72
# 67. in
#     core type: Literal
#     sub-expressions:
# 68. (d_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 69. a_{_a}
#     core type: IndexedVar
# variable: 73
# index: 77
# 70. c_{_a}
#     core type: IndexedVar
# variable: 74
# index: 77
# 71. d_{_a}
#     core type: IndexedVar
# variable: 75
# index: 77
# 72. V
#     core type: Variable
#     sub-expressions:
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. c
#     core type: Variable
#     sub-expressions:
# 75. d
#     core type: Variable
#     sub-expressions:
# 76. (_a)
#     core type: ExprTuple
#     sub-expressions: 77
# 77. _a
#     core type: Variable
#     sub-expressions:
