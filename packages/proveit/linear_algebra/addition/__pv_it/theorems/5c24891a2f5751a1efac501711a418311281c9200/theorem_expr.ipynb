# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#vec_sum_split_first">vec_sum_split_first</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.addition import vec_sum_split_first

# %%
# check that the built expression is the same as the stored expression
assert vec_sum_split_first.expr == stored_expr
assert vec_sum_split_first.expr._style_id == stored_expr._style_id
print("Passed sanity check: vec_sum_split_first matches stored_expr")
# Out:
# Passed sanity check: vec_sum_split_first matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{v}~\left[\forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{i=a}^{b} v\left(i\right)\right) = \left(v\left(a\right) + \left(\sum_{i=a + 1}^{b} v\left(i\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v} [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = (v(a) + (Sum_{i=a + 1}^{b} v(i))))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (v -> [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = (v(a) + (Sum_{i=a + 1}^{b} v(i))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. v -> [forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = (v(a) + (Sum_{i=a + 1}^{b} v(i))))]
#    core type: Lambda
#    parameter: 42
#    body: 4
# 3. (v)
#    core type: ExprTuple
#    sub-expressions: 42
# 4. forall_{a, b in Integer | a < b} ((Sum_{i=a}^{b} v(i)) = (v(a) + (Sum_{i=a + 1}^{b} v(i))))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {(Sum_{i=a}^{b} v(i)) = (v(a) + (Sum_{i=a + 1}^{b} v(i))) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 7
# ...
