# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, c, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, d_1_to_k
from proveit.linear_algebra import VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c, d_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b_1_to_j, c, d_1_to_k), VecAdd(a_1_to_i, c, b_1_to_j, d_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c, d_{1}, d_{2}, \ldots, d_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j} + c+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i} + c+ b_{1} +  b_{2} +  \ldots +  b_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 69
#    body: 2
# 1. (V)
#    core type: ExprTuple
#    sub-expressions: 69
# 2. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 17
#    operand: 8
# 4. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 69, 9
# 8. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. VecSpaces(K)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 56, 58, 61
# 11. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. VecSpaces
#     core type: Literal
#     sub-expressions:
# 13. (K)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 33
#     operands: 19
# 16. K
#     core type: Variable
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 20. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Lambda
#     parameters: 41\n    body: 24
# 21. i in Natural
#     core type: Operation
#     operator: 64
#     operands: 25
# 22. j in Natural
#     core type: Operation
#     operator: 64
#     operands: 26
# 23. k in Natural
#     core type: Operation
#     operator: 64
#     operands: 27
# 24. {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 30
# 26. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 58, 30
# 27. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 61, 30
# 28. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)and (b_{1} in V) and  (b_{2} in V) and  ... and  (b_{j} in V) and (c in V)and (d_{1} in V) and  (d_{2} in V) and  ... and  (d_{k} in V)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. Natural
#     core type: Literal
#     sub-expressions:
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V),(b_{1} in V), (b_{2} in V), ..., (b_{j} in V), c in V,(d_{1} in V), (d_{2} in V), ..., (d_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39, 40
# 35. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 42
#     operands: 41
# 36. a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 60
#     end_index: 56
# 38. (b_{1} in V), (b_{2} in V), ..., (b_{j} in V)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 60
#     end_index: 58
# 39. c in V
#     core type: Operation
#     operator: 64
#     operands: 46
# 40. (d_{1} in V), (d_{2} in V), ..., (d_{k} in V)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 60
#     end_index: 61
# 41. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 48, 49, 53, 50
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (a_{1}, a_{2}, ..., a_{i}, c,b_{1}, b_{2}, ..., b_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 48, 53, 49, 50
# 44. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 74
#     body: 51
# 45. _a -> (b_{_a} in V)
#     core type: Lambda
#     parameter: 74
#     body: 52
# 46. (c, V)
#     core type: ExprTuple
#     sub-expressions: 53, 69
# 47. _a -> (d_{_a} in V)
#     core type: Lambda
#     parameter: 74
#     body: 54
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 60
#     end_index: 56
# 49. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 60
#     end_index: 58
# 50. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 60
#     end_index: 61
# 51. a_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 62
# 52. b_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 63
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. d_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 65
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 66
# 56. i
#     core type: Variable
#     sub-expressions:
# 57. _a -> b_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 67
# 58. j
#     core type: Variable
#     sub-expressions:
# 59. _a -> d_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 68
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 66, 69
# 63. (b_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (d_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. a_{_a}
#     core type: IndexedVar
# variable: 70
# index: 74
# 67. b_{_a}
#     core type: IndexedVar
# variable: 71
# index: 74
# 68. d_{_a}
#     core type: IndexedVar
# variable: 72
# index: 74
# 69. V
#     core type: Variable
#     sub-expressions:
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. b
#     core type: Variable
#     sub-expressions:
# 72. d
#     core type: Variable
#     sub-expressions:
# 73. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. _a
#     core type: Variable
#     sub-expressions:
