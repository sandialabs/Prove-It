# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, c, i, vi
from proveit.linear_algebra import VecAdd, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Less, LessEq, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Lambda([a, b, c], Conditional(Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, c)), VecAdd(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, b)), VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(Add(b, one), c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), LessEq(a, b), Less(b, c))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(\sum_{i=a}^{c} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b} v\left(i\right)\right) + \left(\sum_{i=b + 1}^{c} v\left(i\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b ,  b < c\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a, b, c) -> {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 55, 60, 57
# 2. {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i)))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b) and (b < c)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{i=a}^{c} v(i), (Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i)))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integer, b in Integer, c in Integer, a <= b, b < c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# 9. Sum_{i=a}^{c} v(i)
#    core type: Operation
#    operator: 31
#    operand: 25
# 10. (Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. a in Integer
#     core type: Operation
#     operator: 47
#     operands: 19
# 12. b in Integer
#     core type: Operation
#     operator: 47
#     operands: 20
# 13. c in Integer
#     core type: Operation
#     operator: 47
#     operands: 21
# 14. a <= b
#     core type: Operation
#     operator: 22
#     operands: 52
# 15. b < c
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. (i -> {v(i) if i in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (Sum_{i=a}^{b} v(i), Sum_{i=b + 1}^{c} v(i))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 19. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 28
# 20. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 28
# 21. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 28
# 22. <=
#     core type: Literal
#     sub-expressions:
# 23. <
#     core type: Literal
#     sub-expressions:
# 24. (b, c)
#     core type: ExprTuple
#     sub-expressions: 60, 57
# 25. i -> {v(i) if i in {a .. c}.
#     core type: Lambda
#     parameter: 50
#     body: 29
# 26. Sum_{i=a}^{b} v(i)
#     core type: Operation
#     operator: 31
#     operand: 34
# 27. Sum_{i=b + 1}^{c} v(i)
#     core type: Operation
#     operator: 31
#     operand: 35
# 28. Integer
#     core type: Literal
#     sub-expressions:
# 29. {v(i) if i in {a .. c}.
#     core type: Conditional
#     value: 41
#     condition: 33
# 30. (i -> {v(i) if i in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (i -> {v(i) if i in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. i in {a .. c}
#     core type: Operation
#     operator: 47
#     operands: 36
# 34. i -> {v(i) if i in {a .. b}.
#     core type: Lambda
#     parameter: 50
#     body: 37
# 35. i -> {v(i) if i in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 50
#     body: 38
# 36. (i, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 50, 39
# 37. {v(i) if i in {a .. b}.
#     core type: Conditional
#     value: 41
#     condition: 40
# 38. {v(i) if i in {b + 1 .. c}.
#     core type: Conditional
#     value: 41
#     condition: 42
# 39. {a .. c}
#     core type: Operation
#     operator: 53
#     operands: 43
# 40. i in {a .. b}
#     core type: Operation
#     operator: 47
#     operands: 44
# 41. v(i)
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. i in {b + 1 .. c}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. (a, c)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 44. (i, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 45. v
#     core type: Variable
#     sub-expressions:
# 46. (i)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (i, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 49. {a .. b}
#     core type: Operation
#     operator: 53
#     operands: 52
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. {b + 1 .. c}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. (a, b)
#     core type: ExprTuple
#     sub-expressions: 55, 60
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. b + 1
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. b
#     core type: Variable
#     sub-expressions:
# 61. 1
#     core type: Literal
#     sub-expressions:
