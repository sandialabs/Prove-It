# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#disassociation">disassociation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.addition import disassociation

# %%
# check that the built expression is the same as the stored expression
assert disassociation.expr == stored_expr
assert disassociation.expr._style_id == stored_expr._style_id
print("Passed sanity check: disassociation matches stored_expr")
# Out:
# Passed sanity check: disassociation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c_{1}, c_{2}, \ldots, c_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i} + \left(b_{1} +  b_{2} +  \ldots +  b_{j}\right)+ c_{1} +  c_{2} +  \ldots +  c_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j}+ c_{1} +  c_{2} +  \ldots +  c_{k}\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]]]
#    core type: Operation
#    operator: 22
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]]]
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]]
#    core type: Operation
#    operator: 22
#    operand: 5
# 4. (V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 69
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 69
# 7. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
#    core type: Operation
#    operator: 22
#    operand: 13
# 9. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 69, 14
# 13. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Lambda
#     parameters: 15\n    body: 16
# 14. VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 59, 72, 61
# 16. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. VecSpaces
#     core type: Literal
#     sub-expressions:
# 18. (K)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))
#     core type: Operation
#     operator: 22
#     operand: 25
# 20. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 38
#     operands: 24
# 21. K
#     core type: Variable
#     sub-expressions:
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 25. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).
#     core type: Lambda
#     parameters: 46\n    body: 29
# 26. i in Natural
#     core type: Operation
#     operator: 64
#     operands: 30
# 27. j in Natural
#     core type: Operation
#     operator: 64
#     operands: 31
# 28. k in Natural
#     core type: Operation
#     operator: 64
#     operands: 32
# 29. {(a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).
#     core type: Conditional
#     value: 33
#     condition: 34
# 30. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 35
# 31. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 72, 35
# 32. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 61, 35
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k})
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)and (b_{1} in V) and  (b_{2} in V) and  ... and  (b_{j} in V)and (c_{1} in V) and  (c_{2} in V) and  ... and  (c_{k} in V)
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. Natural
#     core type: Literal
#     sub-expressions:
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V),(b_{1} in V), (b_{2} in V), ..., (b_{j} in V),(c_{1} in V), (c_{2} in V), ..., (c_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 42, 43, 44
# 40. a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}
#     core type: Operation
#     operator: 56
#     operands: 45
# 41. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}
#     core type: Operation
#     operator: 56
#     operands: 46
# 42. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 71
#     end_index: 59
# 43. (b_{1} in V), (b_{2} in V), ..., (b_{j} in V)
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 71
#     end_index: 72
# 44. (c_{1} in V), (c_{2} in V), ..., (c_{k} in V)
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 71
#     end_index: 61
# 45. (a_{1}, a_{2}, ..., a_{i}, b_{1} +  b_{2} +  ... +  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 50, 52
# 46. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 66, 52
# 47. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 78
#     body: 53
# 48. _a -> (b_{_a} in V)
#     core type: Lambda
#     parameter: 78
#     body: 54
# 49. _a -> (c_{_a} in V)
#     core type: Lambda
#     parameter: 78
#     body: 55
# 50. b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 71
#     end_index: 59
# 52. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 71
#     end_index: 61
# 53. a_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 62
# 54. b_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 63
# 55. c_{_a} in V
#     core type: Operation
#     operator: 64
#     operands: 65
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 66
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 67
# 59. i
#     core type: Variable
#     sub-expressions:
# 60. _a -> c_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 68
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 63. (b_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 75, 69
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (c_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 71
#     end_index: 72
# 67. a_{_a}
#     core type: IndexedVar
# variable: 73
# index: 78
# 68. c_{_a}
#     core type: IndexedVar
# variable: 74
# index: 78
# 69. V
#     core type: Variable
#     sub-expressions:
# 70. _a -> b_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 75
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. j
#     core type: Variable
#     sub-expressions:
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. c
#     core type: Variable
#     sub-expressions:
# 75. b_{_a}
#     core type: IndexedVar
# variable: 76
# index: 78
# 76. b
#     core type: Variable
#     sub-expressions:
# 77. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 78. _a
#     core type: Variable
#     sub-expressions:
