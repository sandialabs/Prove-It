# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Q, f, j, n
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra.addition import vec_summation_b1toj_fQ
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, NaturalPos
from proveit.numbers.summation import summation_b1toj_fQ

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([f, Q], Forall(instance_param_or_params = [n, j], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(vec_summation_b1toj_fQ, summation_b1toj_fQ), domain = Complex), domain = NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(f, Q\right) \mapsto \left[\forall_{n, j \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in \mathbb{C}}~\left(\left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right] = \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right]\right)\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((f, Q) -> [forall_{n, j in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})])]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, Q) -> [forall_{n, j in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})])]]
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, Q)
#    core type: ExprTuple
#    sub-expressions: 46, 47
# 3. forall_{n, j in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})])]
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. ((n, j) -> {forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]) if n in NaturalPos ,  j in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (n, j) -> {forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]) if n in NaturalPos ,  j in NaturalPos.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (n, j)
#    core type: ExprTuple
#    sub-expressions: 36, 53
# 7. {forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]) if n in NaturalPos ,  j in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{x_{1}, x_{2}, ..., x_{n} in Complex} ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})])
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (n in NaturalPos) and (j in NaturalPos)
#    core type: Operation
#    operator: 27
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((x_{1}, x_{2}, ..., x_{n}) -> {[Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] if (x_{1} in Complex) and  (x_{2} in Complex) and  ... and  (x_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (n in NaturalPos, j in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (x_{1}, x_{2}, ..., x_{n}) -> {[Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] if (x_{1} in Complex) and  (x_{2} in Complex) and  ... and  (x_{n} in Complex).
#     core type: Lambda
#     parameters: 16\n    body: 17
# 14. n in NaturalPos
#     core type: Operation
#     operator: 40
#     operands: 18
# 15. j in NaturalPos
#     core type: Operation
#     operator: 40
#     operands: 19
# 16. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 17. {[Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] if (x_{1} in Complex) and  (x_{2} in Complex) and  ... and  (x_{n} in Complex).
#     core type: Conditional
#     value: 21
#     condition: 22
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 36, 23
# 19. (j, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 53, 23
# 20. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 52
#     end_index: 36
# 21. [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (x_{1} in Complex) and  (x_{2} in Complex) and  ... and  (x_{n} in Complex)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. NaturalPos
#     core type: Literal
#     sub-expressions:
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 44
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}), Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((x_{1} in Complex), (x_{2} in Complex), ..., (x_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 31
# 29. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 32
#     operand: 37
# 30. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 33
#     operand: 37
# 31. (x_{1} in Complex), (x_{2} in Complex), ..., (x_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 52
#     end_index: 36
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. _a -> (x_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 38
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 48\n    body: 39
# 38. x_{_a} in Complex
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 42
#     condition: 43
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (x_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 46
#     operands: 48
# 43. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. x_{_a}
#     core type: IndexedVar
# variable: 49
# index: 57
# 45. Complex
#     core type: Literal
#     sub-expressions:
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. Q
#     core type: Variable
#     sub-expressions:
# 48. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 50
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 51. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. j
#     core type: Variable
#     sub-expressions:
# 54. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
