# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, c, i, v, vi
from proveit.linear_algebra import VecAdd, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Less, LessEq, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Lambda(v, Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, c)), VecAdd(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, b)), VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(Add(b, one), c)))), domain = Integer, conditions = [LessEq(a, b), Less(b, c)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# v \mapsto \left[\forall_{a, b, c \in \mathbb{Z}~|~a \leq b, b < c}~\left(\left(\sum_{i=a}^{c} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b} v\left(i\right)\right) + \left(\sum_{i=b + 1}^{c} v\left(i\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. v -> [forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))))]
#    core type: Lambda
#    parameter: 50
#    body: 2
# 1. (v)
#    core type: ExprTuple
#    sub-expressions: 50
# 2. forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 60, 65, 62
# 7. {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i)))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b) and (b < c)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (Sum_{i=a}^{c} v(i), (Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a in Integer, b in Integer, c in Integer, a <= b, b < c)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20
# 14. Sum_{i=a}^{c} v(i)
#     core type: Operation
#     operator: 36
#     operand: 30
# 15. (Sum_{i=a}^{b} v(i)) + (Sum_{i=b + 1}^{c} v(i))
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. a in Integer
#     core type: Operation
#     operator: 52
#     operands: 24
# 17. b in Integer
#     core type: Operation
#     operator: 52
#     operands: 25
# 18. c in Integer
#     core type: Operation
#     operator: 52
#     operands: 26
# 19. a <= b
#     core type: Operation
#     operator: 27
#     operands: 57
# 20. b < c
#     core type: Operation
#     operator: 28
#     operands: 29
# 21. (i -> {v(i) if i in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 30
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (Sum_{i=a}^{b} v(i), Sum_{i=b + 1}^{c} v(i))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 24. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 33
# 25. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 33
# 26. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 33
# 27. <=
#     core type: Literal
#     sub-expressions:
# 28. <
#     core type: Literal
#     sub-expressions:
# 29. (b, c)
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 30. i -> {v(i) if i in {a .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 34
# 31. Sum_{i=a}^{b} v(i)
#     core type: Operation
#     operator: 36
#     operand: 39
# 32. Sum_{i=b + 1}^{c} v(i)
#     core type: Operation
#     operator: 36
#     operand: 40
# 33. Integer
#     core type: Literal
#     sub-expressions:
# 34. {v(i) if i in {a .. c}.
#     core type: Conditional
#     value: 46
#     condition: 38
# 35. (i -> {v(i) if i in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. Sum
#     core type: Literal
#     sub-expressions:
# 37. (i -> {v(i) if i in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. i in {a .. c}
#     core type: Operation
#     operator: 52
#     operands: 41
# 39. i -> {v(i) if i in {a .. b}.
#     core type: Lambda
#     parameter: 55
#     body: 42
# 40. i -> {v(i) if i in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 43
# 41. (i, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 44
# 42. {v(i) if i in {a .. b}.
#     core type: Conditional
#     value: 46
#     condition: 45
# 43. {v(i) if i in {b + 1 .. c}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 44. {a .. c}
#     core type: Operation
#     operator: 58
#     operands: 48
# 45. i in {a .. b}
#     core type: Operation
#     operator: 52
#     operands: 49
# 46. v(i)
#     core type: Operation
#     operator: 50
#     operand: 55
# 47. i in {b + 1 .. c}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. (a, c)
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 49. (i, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 50. v
#     core type: Variable
#     sub-expressions:
# 51. (i)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (i, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. {a .. b}
#     core type: Operation
#     operator: 58
#     operands: 57
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. {b + 1 .. c}
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. (a, b)
#     core type: ExprTuple
#     sub-expressions: 60, 65
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. b + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. c
#     core type: Variable
#     sub-expressions:
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
