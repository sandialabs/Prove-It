# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.linear_algebra import VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b, c_1_to_j, d_1_to_k), VecAdd(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d_{1}, d_{2}, \ldots, d_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j} + b+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 70
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 70
# 3. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 18
#    operand: 9
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 70, 10
# 9. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 17
# 11. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 57, 59, 62
# 12. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 34
#     operands: 20
# 17. K
#     core type: Variable
#     sub-expressions:
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 21. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Lambda
#     parameters: 42\n    body: 25
# 22. i in Natural
#     core type: Operation
#     operator: 65
#     operands: 26
# 23. j in Natural
#     core type: Operation
#     operator: 65
#     operands: 27
# 24. k in Natural
#     core type: Operation
#     operator: 65
#     operands: 28
# 25. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 57, 31
# 27. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 31
# 28. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 62, 31
# 29. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V) and (b in V)and (c_{1} in V) and  (c_{2} in V) and  ... and  (c_{j} in V)and (d_{1} in V) and  (d_{2} in V) and  ... and  (d_{k} in V)
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. Natural
#     core type: Literal
#     sub-expressions:
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V), b in V,(c_{1} in V), (c_{2} in V), ..., (c_{j} in V),(d_{1} in V), (d_{2} in V), ..., (d_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 38, 39, 40, 41
# 36. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 43
#     operands: 42
# 37. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 61
#     end_index: 57
# 39. b in V
#     core type: Operation
#     operator: 65
#     operands: 46
# 40. (c_{1} in V), (c_{2} in V), ..., (c_{j} in V)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 61
#     end_index: 59
# 41. (d_{1} in V), (d_{2} in V), ..., (d_{k} in V)
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 61
#     end_index: 62
# 42. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 49, 53, 50, 51
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j}, b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 49, 50, 53, 51
# 45. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 75
#     body: 52
# 46. (b, V)
#     core type: ExprTuple
#     sub-expressions: 53, 70
# 47. _a -> (c_{_a} in V)
#     core type: Lambda
#     parameter: 75
#     body: 54
# 48. _a -> (d_{_a} in V)
#     core type: Lambda
#     parameter: 75
#     body: 55
# 49. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 61
#     end_index: 57
# 50. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 61
#     end_index: 59
# 51. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 61
#     end_index: 62
# 52. a_{_a} in V
#     core type: Operation
#     operator: 65
#     operands: 63
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. c_{_a} in V
#     core type: Operation
#     operator: 65
#     operands: 64
# 55. d_{_a} in V
#     core type: Operation
#     operator: 65
#     operands: 66
# 56. _a -> a_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 67
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. _a -> c_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 68
# 59. j
#     core type: Variable
#     sub-expressions:
# 60. _a -> d_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 69
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 67, 70
# 64. (c_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 68, 70
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (d_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 67. a_{_a}
#     core type: IndexedVar
# variable: 71
# index: 75
# 68. c_{_a}
#     core type: IndexedVar
# variable: 72
# index: 75
# 69. d_{_a}
#     core type: IndexedVar
# variable: 73
# index: 75
# 70. V
#     core type: Variable
#     sub-expressions:
# 71. a
#     core type: Variable
#     sub-expressions:
# 72. c
#     core type: Variable
#     sub-expressions:
# 73. d
#     core type: Variable
#     sub-expressions:
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. _a
#     core type: Variable
#     sub-expressions:
