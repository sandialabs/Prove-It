# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, i, vi
from proveit.linear_algebra import VecAdd, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Integer, Interval, Less, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, c)), VecAdd(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, subtract(b, one))), VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(b, c)))), domain = Integer, conditions = [Less(a, b), LessEq(b, c)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}~|~a < b, b \leq c}~\left(\left(\sum_{i=a}^{c} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b - 1} v\left(i\right)\right) + \left(\sum_{i=b}^{c} v\left(i\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 58, 63, 60
# 5. {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i)))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (c in Integer) and (a < b) and (b <= c)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (Sum_{i=a}^{c} v(i), (Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in Integer, b in Integer, c in Integer, a < b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17, 18
# 12. Sum_{i=a}^{c} v(i)
#     core type: Operation
#     operator: 34
#     operand: 28
# 13. (Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. a in Integer
#     core type: Operation
#     operator: 50
#     operands: 22
# 15. b in Integer
#     core type: Operation
#     operator: 50
#     operands: 23
# 16. c in Integer
#     core type: Operation
#     operator: 50
#     operands: 24
# 17. a < b
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. b <= c
#     core type: Operation
#     operator: 27
#     operands: 57
# 19. (i -> {v(i) if i in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (Sum_{i=a}^{b - 1} v(i), Sum_{i=b}^{c} v(i))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 22. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 31
# 23. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 31
# 24. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 31
# 25. <
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 58, 63
# 27. <=
#     core type: Literal
#     sub-expressions:
# 28. i -> {v(i) if i in {a .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 32
# 29. Sum_{i=a}^{b - 1} v(i)
#     core type: Operation
#     operator: 34
#     operand: 37
# 30. Sum_{i=b}^{c} v(i)
#     core type: Operation
#     operator: 34
#     operand: 38
# 31. Integer
#     core type: Literal
#     sub-expressions:
# 32. {v(i) if i in {a .. c}.
#     core type: Conditional
#     value: 44
#     condition: 36
# 33. (i -> {v(i) if i in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (i -> {v(i) if i in {b .. c}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. i in {a .. c}
#     core type: Operation
#     operator: 50
#     operands: 39
# 37. i -> {v(i) if i in {a .. b - 1}.
#     core type: Lambda
#     parameter: 53
#     body: 40
# 38. i -> {v(i) if i in {b .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 41
# 39. (i, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 42
# 40. {v(i) if i in {a .. b - 1}.
#     core type: Conditional
#     value: 44
#     condition: 43
# 41. {v(i) if i in {b .. c}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. {a .. c}
#     core type: Operation
#     operator: 56
#     operands: 46
# 43. i in {a .. b - 1}
#     core type: Operation
#     operator: 50
#     operands: 47
# 44. v(i)
#     core type: Operation
#     operator: 48
#     operand: 53
# 45. i in {b .. c}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (a, c)
#     core type: ExprTuple
#     sub-expressions: 58, 60
# 47. (i, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 48. v
#     core type: Variable
#     sub-expressions:
# 49. (i)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (i, {b .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. {a .. b - 1}
#     core type: Operation
#     operator: 56
#     operands: 55
# 53. i
#     core type: Variable
#     sub-expressions:
# 54. {b .. c}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (b, c)
#     core type: ExprTuple
#     sub-expressions: 63, 60
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. b - 1
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. -1
#     core type: Operation
#     operator: 65
#     operand: 67
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (1)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. 1
#     core type: Literal
#     sub-expressions:
