# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, i, j, k, v
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [j, k], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(VecSum(index_or_indices = [i], summand = v, domain = Interval(j, k)), ScalarMult(Add(subtract(k, j), one), v)), domain = V), domain = VecSpaces(K)), domain = Integer, condition = LessEq(j, k))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{v \in V}~\left(\left(\sum_{i=j}^{k} v\right) = \left(\left(\left(k - j\right) + 1\right) \cdot v\right)\right)\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]]
#    core type: Lambda
#    parameter: 35
#    body: 2
# 2. forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]
#    core type: Operation
#    operator: 23
#    operand: 4
# 3. ((j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 63\n   body: 5
# 5. {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]
#    core type: Operation
#    operator: 23
#    operand: 11
# 7. (j in Integer) and (k in Integer) and (j <= k)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (j in Integer, k in Integer, j <= k)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 41
#     body: 16
# 12. j in Integer
#     core type: Operation
#     operator: 55
#     operands: 17
# 13. k in Integer
#     core type: Operation
#     operator: 55
#     operands: 18
# 14. j <= k
#     core type: Operation
#     operator: 19
#     operands: 63
# 15. (V)
#     core type: ExprTuple
#     sub-expressions: 41
# 16. {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 67, 22
# 18. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 66, 22
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))
#     core type: Operation
#     operator: 23
#     operand: 27
# 21. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 41, 28
# 27. v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Lambda
#     parameter: 51
#     body: 30
# 28. VecSpaces(K)
#     core type: Operation
#     operator: 31
#     operand: 35
# 29. (v)
#     core type: ExprTuple
#     sub-expressions: 51
# 30. {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Conditional
#     value: 33
#     condition: 34
# 31. VecSpaces
#     core type: Literal
#     sub-expressions:
# 32. (K)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. (Sum_{i=j}^{k} v) = (((k - j) + 1) * v)
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. v in V
#     core type: Operation
#     operator: 55
#     operands: 38
# 35. K
#     core type: Variable
#     sub-expressions:
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (Sum_{i=j}^{k} v, ((k - j) + 1) * v)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. (v, V)
#     core type: ExprTuple
#     sub-expressions: 51, 41
# 39. Sum_{i=j}^{k} v
#     core type: Operation
#     operator: 42
#     operand: 46
# 40. ((k - j) + 1) * v
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. V
#     core type: Variable
#     sub-expressions:
# 42. Sum
#     core type: Literal
#     sub-expressions:
# 43. (i -> {v if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. ((k - j) + 1, v)
#     core type: ExprTuple
#     sub-expressions: 47, 51
# 46. i -> {v if i in {j .. k}.
#     core type: Lambda
#     parameter: 59
#     body: 49
# 47. (k - j) + 1
#     core type: Operation
#     operator: 57
#     operands: 50
# 48. (i)
#     core type: ExprTuple
#     sub-expressions: 59
# 49. {v if i in {j .. k}.
#     core type: Conditional
#     value: 51
#     condition: 52
# 50. (k - j, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. v
#     core type: Variable
#     sub-expressions:
# 52. i in {j .. k}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. k - j
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 66, 61
# 59. i
#     core type: Variable
#     sub-expressions:
# 60. {j .. k}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. -j
#     core type: Operation
#     operator: 64
#     operand: 67
# 62. Interval
#     core type: Literal
#     sub-expressions:
# 63. (j, k)
#     core type: ExprTuple
#     sub-expressions: 67, 66
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (j)
#     core type: ExprTuple
#     sub-expressions: 67
# 66. k
#     core type: Variable
#     sub-expressions:
# 67. j
#     core type: Variable
#     sub-expressions:
