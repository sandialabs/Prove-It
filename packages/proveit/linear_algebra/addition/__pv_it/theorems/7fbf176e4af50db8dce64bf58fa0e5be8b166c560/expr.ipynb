# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, V, i, j, k, v
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda(K, Forall(instance_param_or_params = [j, k], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(VecSum(index_or_indices = [i], summand = v, domain = Interval(j, k)), ScalarMult(Add(subtract(k, j), one), v)), domain = V), domain = VecSpaces(K)), domain = Integer, condition = LessEq(j, k)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{v \in V}~\left(\left(\sum_{i=j}^{k} v\right) = \left(\left(\left(k - j\right) + 1\right) \cdot v\right)\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]]
#    core type: Lambda
#    parameter: 34
#    body: 1
# 1. forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]
#    core type: Operation
#    operator: 22
#    operand: 3
# 2. ((j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 62\n   body: 4
# 4. {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]
#    core type: Operation
#    operator: 22
#    operand: 10
# 6. (j in Integer) and (k in Integer) and (j <= k)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (j in Integer, k in Integer, j <= k)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 40
#     body: 15
# 11. j in Integer
#     core type: Operation
#     operator: 54
#     operands: 16
# 12. k in Integer
#     core type: Operation
#     operator: 54
#     operands: 17
# 13. j <= k
#     core type: Operation
#     operator: 18
#     operands: 62
# 14. (V)
#     core type: ExprTuple
#     sub-expressions: 40
# 15. {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 66, 21
# 17. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 21
# 18. <=
#     core type: Literal
#     sub-expressions:
# 19. forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Integer
#     core type: Literal
#     sub-expressions:
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. in_c
#     core type: Literal
#     sub-expressions:
# 25. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 40, 27
# 26. v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Lambda
#     parameter: 50
#     body: 29
# 27. VecSpaces(K)
#     core type: Operation
#     operator: 30
#     operand: 34
# 28. (v)
#     core type: ExprTuple
#     sub-expressions: 50
# 29. {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. VecSpaces
#     core type: Literal
#     sub-expressions:
# 31. (K)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. (Sum_{i=j}^{k} v) = (((k - j) + 1) * v)
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. v in V
#     core type: Operation
#     operator: 54
#     operands: 37
# 34. K
#     core type: Variable
#     sub-expressions:
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (Sum_{i=j}^{k} v, ((k - j) + 1) * v)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. (v, V)
#     core type: ExprTuple
#     sub-expressions: 50, 40
# 38. Sum_{i=j}^{k} v
#     core type: Operation
#     operator: 41
#     operand: 45
# 39. ((k - j) + 1) * v
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. V
#     core type: Variable
#     sub-expressions:
# 41. Sum
#     core type: Literal
#     sub-expressions:
# 42. (i -> {v if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. ((k - j) + 1, v)
#     core type: ExprTuple
#     sub-expressions: 46, 50
# 45. i -> {v if i in {j .. k}.
#     core type: Lambda
#     parameter: 58
#     body: 48
# 46. (k - j) + 1
#     core type: Operation
#     operator: 56
#     operands: 49
# 47. (i)
#     core type: ExprTuple
#     sub-expressions: 58
# 48. {v if i in {j .. k}.
#     core type: Conditional
#     value: 50
#     condition: 51
# 49. (k - j, 1)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. v
#     core type: Variable
#     sub-expressions:
# 51. i in {j .. k}
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. k - j
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 65, 60
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. {j .. k}
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. -j
#     core type: Operation
#     operator: 63
#     operand: 66
# 61. Interval
#     core type: Literal
#     sub-expressions:
# 62. (j, k)
#     core type: ExprTuple
#     sub-expressions: 66, 65
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. (j)
#     core type: ExprTuple
#     sub-expressions: 66
# 65. k
#     core type: Variable
#     sub-expressions:
# 66. j
#     core type: Variable
#     sub-expressions:
