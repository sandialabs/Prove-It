# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, a, b
from proveit.linear_algebra import InnerProd, Norm, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, sqrt, two, zero

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = Equals(Norm(VecAdd(a, b)), sqrt(Add(Exp(Norm(a), two), Exp(Norm(b), two)))), domain = V, condition = Equals(InnerProd(a, b), zero)), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a, b \in V~|~\left \langle a, b\right \rangle = 0}~\left(\left \|a + b\right \| = \sqrt{\left(\left \|a\right \|^{2} + \left \|b\right \|^{2}\right)}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]]
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. (V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 40
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 40
# 7. {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. in_c
#     core type: Literal
#     sub-expressions:
# 13. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 40, 15
# 14. (a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Lambda
#     parameters: 49\n    body: 16
# 15. VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operand: 21
# 16. {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. VecSpaces
#     core type: Literal
#     sub-expressions:
# 18. (K)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. ||a + b|| = sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 35
#     operands: 22
# 20. (a in V) and (b in V) and (<a, b> = 0)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. K
#     core type: Variable
#     sub-expressions:
# 22. (||a + b||, sqrt((||a||^{2} + ||b||^{2})))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (a in V, b in V, <a, b> = 0)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 25. ||a + b||
#     core type: Operation
#     operator: 60
#     operand: 37
# 26. sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 54
#     operands: 31
# 27. a in V
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. b in V
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. <a, b> = 0
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. (a + b)
#     core type: ExprTuple
#     sub-expressions: 37
# 31. (||a||^{2} + ||b||^{2}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. (a, V)
#     core type: ExprTuple
#     sub-expressions: 62, 40
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (b, V)
#     core type: ExprTuple
#     sub-expressions: 63, 40
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (<a, b>, 0)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. a + b
#     core type: Operation
#     operator: 43
#     operands: 49
# 38. ||a||^{2} + ||b||^{2}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. 1 / 2
#     core type: Operation
#     operator: 46
#     operands: 47
# 40. V
#     core type: Variable
#     sub-expressions:
# 41. <a, b>
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (||a||^{2}, ||b||^{2})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 46. /
#     core type: Literal
#     sub-expressions:
# 47. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 52, 58
# 48. InnerProd
#     core type: Literal
#     sub-expressions:
# 49. (a, b)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 50. ||a||^{2}
#     core type: Operation
#     operator: 54
#     operands: 53
# 51. ||b||^{2}
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. (||a||, 2)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (||b||, 2)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. ||a||
#     core type: Operation
#     operator: 60
#     operand: 62
# 57. ||b||
#     core type: Operation
#     operator: 60
#     operand: 63
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. (a)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. Abs
#     core type: Literal
#     sub-expressions:
# 61. (b)
#     core type: ExprTuple
#     sub-expressions: 63
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. b
#     core type: Variable
#     sub-expressions:
