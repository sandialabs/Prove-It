# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#closure">closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.addition import closure

# %%
# check that the built expression is the same as the stored expression
assert closure.expr == stored_expr
assert closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: closure matches stored_expr")
# Out:
# Passed sanity check: closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(x_{1} +  x_{2} +  \ldots +  x_{n}\right) \in V\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]]]
#    core type: Operation
#    operator: 18
#    operand: 2
# 1. (n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 42
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 42
# 4. {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]] if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]]
#    core type: Operation
#    operator: 18
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 43
#    operands: 8
# 7. (K -> [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]])
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 42, 10
# 9. K -> [forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]]
#    core type: Lambda
#    parameter: 29
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. forall_{V in_c VecSpaces(K)} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)]
#     core type: Operation
#     operator: 18
#     operand: 13
# 12. (V -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V) if V in_c VecSpaces(K).)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. V -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V) if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 46
#     body: 15
# 14. (V)
#     core type: ExprTuple
#     sub-expressions: 46
# 15. {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. forall_{x_{1}, x_{2}, ..., x_{n} in V} ((x_{1} +  x_{2} +  ... +  x_{n}) in V)
#     core type: Operation
#     operator: 18
#     operand: 22
# 17. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((x_{1}, x_{2}, ..., x_{n}) -> {(x_{1} +  x_{2} +  ... +  x_{n}) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. in_c
#     core type: Literal
#     sub-expressions:
# 21. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 46, 23
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {(x_{1} +  x_{2} +  ... +  x_{n}) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 36\n    body: 24
# 23. VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operand: 29
# 24. {(x_{1} +  x_{2} +  ... +  x_{n}) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. VecSpaces
#     core type: Literal
#     sub-expressions:
# 26. (K)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. (x_{1} +  x_{2} +  ... +  x_{n}) in V
#     core type: Operation
#     operator: 43
#     operands: 30
# 28. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. K
#     core type: Variable
#     sub-expressions:
# 30. (x_{1} +  x_{2} +  ... +  x_{n}, V)
#     core type: ExprTuple
#     sub-expressions: 33, 46
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 34
# 33. x_{1} +  x_{2} +  ... +  x_{n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 41
#     end_index: 42
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 37. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 49
#     body: 39
# 38. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 39. x_{_a} in V
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. _a -> x_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 45
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. x_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 46. V
#     core type: Variable
#     sub-expressions:
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 49. _a
#     core type: Variable
#     sub-expressions:
