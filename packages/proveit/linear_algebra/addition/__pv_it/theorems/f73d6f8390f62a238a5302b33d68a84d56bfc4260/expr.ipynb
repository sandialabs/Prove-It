# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, V, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.linear_algebra import VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b_1_to_j, c_1_to_k), VecAdd(a_1_to_i, VecAdd(b_1_to_j), c_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c_{1}, c_{2}, \ldots, c_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j}+ c_{1} +  c_{2} +  \ldots +  c_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i} + \left(b_{1} +  b_{2} +  \ldots +  b_{j}\right)+ c_{1} +  c_{2} +  \ldots +  c_{k}\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]]]
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]]
#    core type: Operation
#    operator: 20
#    operand: 3
# 2. (V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 67
#    body: 5
# 4. (V)
#    core type: ExprTuple
#    sub-expressions: 67
# 5. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
#    core type: Operation
#    operator: 20
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 67, 12
# 11. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 55, 70, 59
# 14. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 36
#     operands: 22
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 23. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).
#     core type: Lambda
#     parameters: 43\n    body: 27
# 24. i in Natural
#     core type: Operation
#     operator: 62
#     operands: 28
# 25. j in Natural
#     core type: Operation
#     operator: 62
#     operands: 29
# 26. k in Natural
#     core type: Operation
#     operator: 62
#     operands: 30
# 27. {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V), (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{k} in V).
#     core type: Conditional
#     value: 31
#     condition: 32
# 28. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 33
# 29. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 70, 33
# 30. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 33
# 31. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k})
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)and (b_{1} in V) and  (b_{2} in V) and  ... and  (b_{j} in V)and (c_{1} in V) and  (c_{2} in V) and  ... and  (c_{k} in V)
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. Natural
#     core type: Literal
#     sub-expressions:
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}, a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V),(b_{1} in V), (b_{2} in V), ..., (b_{j} in V),(c_{1} in V), (c_{2} in V), ..., (c_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 38. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}
#     core type: Operation
#     operator: 56
#     operands: 43
# 39. a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}
#     core type: Operation
#     operator: 56
#     operands: 44
# 40. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 69
#     end_index: 55
# 41. (b_{1} in V), (b_{2} in V), ..., (b_{j} in V)
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 69
#     end_index: 70
# 42. (c_{1} in V), (c_{2} in V), ..., (c_{k} in V)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 69
#     end_index: 59
# 43. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 48, 64, 50
# 44. (a_{1}, a_{2}, ..., a_{i}, b_{1} +  b_{2} +  ... +  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 45. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 51
# 46. _a -> (b_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 52
# 47. _a -> (c_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 53
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 69
#     end_index: 55
# 49. b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 56
#     operands: 57
# 50. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 69
#     end_index: 59
# 51. a_{_a} in V
#     core type: Operation
#     operator: 62
#     operands: 60
# 52. b_{_a} in V
#     core type: Operation
#     operator: 62
#     operands: 61
# 53. c_{_a} in V
#     core type: Operation
#     operator: 62
#     operands: 63
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 65
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 64
# 58. _a -> c_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 66
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 65, 67
# 61. (b_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 73, 67
# 62. in
#     core type: Literal
#     sub-expressions:
# 63. (c_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 69
#     end_index: 70
# 65. a_{_a}
#     core type: IndexedVar
# variable: 71
# index: 76
# 66. c_{_a}
#     core type: IndexedVar
# variable: 72
# index: 76
# 67. V
#     core type: Variable
#     sub-expressions:
# 68. _a -> b_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 73
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. j
#     core type: Variable
#     sub-expressions:
# 71. a
#     core type: Variable
#     sub-expressions:
# 72. c
#     core type: Variable
#     sub-expressions:
# 73. b_{_a}
#     core type: IndexedVar
# variable: 74
# index: 76
# 74. b
#     core type: Variable
#     sub-expressions:
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 76. _a
#     core type: Variable
#     sub-expressions:
