# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, i, vi
from proveit.linear_algebra import VecAdd, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Integer, Interval, Less, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Conditional(Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, c)), VecAdd(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, subtract(b, one))), VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), Less(a, b), LessEq(b, c)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left(\sum_{i=a}^{c} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b - 1} v\left(i\right)\right) + \left(\sum_{i=b}^{c} v\left(i\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a < b ,  b \leq c\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (c in Integer) and (a < b) and (b <= c)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{i=a}^{c} v(i), (Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, c in Integer, a < b, b <= c)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13
# 7. Sum_{i=a}^{c} v(i)
#    core type: Operation
#    operator: 29
#    operand: 23
# 8. (Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))
#    core type: Operation
#    operator: 15
#    operands: 16
# 9. a in Integer
#    core type: Operation
#    operator: 45
#    operands: 17
# 10. b in Integer
#     core type: Operation
#     operator: 45
#     operands: 18
# 11. c in Integer
#     core type: Operation
#     operator: 45
#     operands: 19
# 12. a < b
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. b <= c
#     core type: Operation
#     operator: 22
#     operands: 52
# 14. (i -> {v(i) if i in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 23
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (Sum_{i=a}^{b - 1} v(i), Sum_{i=b}^{c} v(i))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 53, 26
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 26
# 19. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 26
# 20. <
#     core type: Literal
#     sub-expressions:
# 21. (a, b)
#     core type: ExprTuple
#     sub-expressions: 53, 58
# 22. <=
#     core type: Literal
#     sub-expressions:
# 23. i -> {v(i) if i in {a .. c}.
#     core type: Lambda
#     parameter: 48
#     body: 27
# 24. Sum_{i=a}^{b - 1} v(i)
#     core type: Operation
#     operator: 29
#     operand: 32
# 25. Sum_{i=b}^{c} v(i)
#     core type: Operation
#     operator: 29
#     operand: 33
# 26. Integer
#     core type: Literal
#     sub-expressions:
# 27. {v(i) if i in {a .. c}.
#     core type: Conditional
#     value: 39
#     condition: 31
# 28. (i -> {v(i) if i in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (i -> {v(i) if i in {b .. c}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. i in {a .. c}
#     core type: Operation
#     operator: 45
#     operands: 34
# 32. i -> {v(i) if i in {a .. b - 1}.
#     core type: Lambda
#     parameter: 48
#     body: 35
# 33. i -> {v(i) if i in {b .. c}.
#     core type: Lambda
#     parameter: 48
#     body: 36
# 34. (i, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 48, 37
# 35. {v(i) if i in {a .. b - 1}.
#     core type: Conditional
#     value: 39
#     condition: 38
# 36. {v(i) if i in {b .. c}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 37. {a .. c}
#     core type: Operation
#     operator: 51
#     operands: 41
# 38. i in {a .. b - 1}
#     core type: Operation
#     operator: 45
#     operands: 42
# 39. v(i)
#     core type: Operation
#     operator: 43
#     operand: 48
# 40. i in {b .. c}
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. (a, c)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 42. (i, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 43. v
#     core type: Variable
#     sub-expressions:
# 44. (i)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (i, {b .. c})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. {a .. b - 1}
#     core type: Operation
#     operator: 51
#     operands: 50
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. {b .. c}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (b, c)
#     core type: ExprTuple
#     sub-expressions: 58, 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. b - 1
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. c
#     core type: Variable
#     sub-expressions:
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. b
#     core type: Variable
#     sub-expressions:
# 59. -1
#     core type: Operation
#     operator: 60
#     operand: 62
# 60. -
#     core type: Literal
#     sub-expressions:
# 61. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. 1
#     core type: Literal
#     sub-expressions:
