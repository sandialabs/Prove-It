# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, i, j, k, v
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [j, k], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(VecSum(index_or_indices = [i], summand = v, domain = Interval(j, k)), ScalarMult(Add(subtract(k, j), one), v)), domain = V), domain = VecSpaces(K)), domain = Integer, condition = LessEq(j, k))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{v \in V}~\left(\left(\sum_{i=j}^{k} v\right) = \left(\left(\left(k - j\right) + 1\right) \cdot v\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{j, k in Integer | j <= k} [forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]]
#    core type: Operation
#    operator: 21
#    operand: 2
# 1. ((j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 61\n   body: 3
# 3. {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]
#    core type: Operation
#    operator: 21
#    operand: 9
# 5. (j in Integer) and (k in Integer) and (j <= k)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (j in Integer, k in Integer, j <= k)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 39
#    body: 14
# 10. j in Integer
#     core type: Operation
#     operator: 53
#     operands: 15
# 11. k in Integer
#     core type: Operation
#     operator: 53
#     operands: 16
# 12. j <= k
#     core type: Operation
#     operator: 17
#     operands: 61
# 13. (V)
#     core type: ExprTuple
#     sub-expressions: 39
# 14. {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 20
# 16. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 20
# 17. <=
#     core type: Literal
#     sub-expressions:
# 18. forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. (v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. in_c
#     core type: Literal
#     sub-expressions:
# 24. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 39, 26
# 25. v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Lambda
#     parameter: 49
#     body: 28
# 26. VecSpaces(K)
#     core type: Operation
#     operator: 29
#     operand: 33
# 27. (v)
#     core type: ExprTuple
#     sub-expressions: 49
# 28. {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Conditional
#     value: 31
#     condition: 32
# 29. VecSpaces
#     core type: Literal
#     sub-expressions:
# 30. (K)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. (Sum_{i=j}^{k} v) = (((k - j) + 1) * v)
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. v in V
#     core type: Operation
#     operator: 53
#     operands: 36
# 33. K
#     core type: Variable
#     sub-expressions:
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (Sum_{i=j}^{k} v, ((k - j) + 1) * v)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. (v, V)
#     core type: ExprTuple
#     sub-expressions: 49, 39
# 37. Sum_{i=j}^{k} v
#     core type: Operation
#     operator: 40
#     operand: 44
# 38. ((k - j) + 1) * v
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. V
#     core type: Variable
#     sub-expressions:
# 40. Sum
#     core type: Literal
#     sub-expressions:
# 41. (i -> {v if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. ((k - j) + 1, v)
#     core type: ExprTuple
#     sub-expressions: 45, 49
# 44. i -> {v if i in {j .. k}.
#     core type: Lambda
#     parameter: 57
#     body: 47
# 45. (k - j) + 1
#     core type: Operation
#     operator: 55
#     operands: 48
# 46. (i)
#     core type: ExprTuple
#     sub-expressions: 57
# 47. {v if i in {j .. k}.
#     core type: Conditional
#     value: 49
#     condition: 50
# 48. (k - j, 1)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. v
#     core type: Variable
#     sub-expressions:
# 50. i in {j .. k}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. k - j
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 64, 59
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. {j .. k}
#     core type: Operation
#     operator: 60
#     operands: 61
# 59. -j
#     core type: Operation
#     operator: 62
#     operand: 65
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (j, k)
#     core type: ExprTuple
#     sub-expressions: 65, 64
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (j)
#     core type: ExprTuple
#     sub-expressions: 65
# 64. k
#     core type: Variable
#     sub-expressions:
# 65. j
#     core type: Variable
#     sub-expressions:
