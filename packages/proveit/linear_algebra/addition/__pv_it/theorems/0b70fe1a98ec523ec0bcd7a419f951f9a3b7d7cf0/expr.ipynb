# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, a, b
from proveit.linear_algebra import InnerProd, Norm, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, sqrt, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = Equals(Norm(VecAdd(a, b)), sqrt(Add(Exp(Norm(a), two), Exp(Norm(b), two)))), domain = V, condition = Equals(InnerProd(a, b), zero)), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a, b \in V~|~\left \langle a, b\right \rangle = 0}~\left(\left \|a + b\right \| = \sqrt{\left(\left \|a\right \|^{2} + \left \|b\right \|^{2}\right)}\right)\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 39
#    body: 6
# 5. (V)
#    core type: ExprTuple
#    sub-expressions: 39
# 6. {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))
#    core type: Operation
#    operator: 9
#    operand: 13
# 8. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 39, 14
# 13. (a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Lambda
#     parameters: 48\n    body: 15
# 14. VecSpaces(K)
#     core type: Operation
#     operator: 16
#     operand: 20
# 15. {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. VecSpaces
#     core type: Literal
#     sub-expressions:
# 17. (K)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. ||a + b|| = sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 34
#     operands: 21
# 19. (a in V) and (b in V) and (<a, b> = 0)
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. K
#     core type: Variable
#     sub-expressions:
# 21. (||a + b||, sqrt((||a||^{2} + ||b||^{2})))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (a in V, b in V, <a, b> = 0)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 24. ||a + b||
#     core type: Operation
#     operator: 59
#     operand: 36
# 25. sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 53
#     operands: 30
# 26. a in V
#     core type: Operation
#     operator: 32
#     operands: 31
# 27. b in V
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. <a, b> = 0
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. (a + b)
#     core type: ExprTuple
#     sub-expressions: 36
# 30. (||a||^{2} + ||b||^{2}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. (a, V)
#     core type: ExprTuple
#     sub-expressions: 61, 39
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (b, V)
#     core type: ExprTuple
#     sub-expressions: 62, 39
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (<a, b>, 0)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. a + b
#     core type: Operation
#     operator: 42
#     operands: 48
# 37. ||a||^{2} + ||b||^{2}
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. 1 / 2
#     core type: Operation
#     operator: 45
#     operands: 46
# 39. V
#     core type: Variable
#     sub-expressions:
# 40. <a, b>
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (||a||^{2}, ||b||^{2})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. /
#     core type: Literal
#     sub-expressions:
# 46. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 51, 57
# 47. InnerProd
#     core type: Literal
#     sub-expressions:
# 48. (a, b)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 49. ||a||^{2}
#     core type: Operation
#     operator: 53
#     operands: 52
# 50. ||b||^{2}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. (||a||, 2)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (||b||, 2)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. ||a||
#     core type: Operation
#     operator: 59
#     operand: 61
# 56. ||b||
#     core type: Operation
#     operator: 59
#     operand: 62
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. (a)
#     core type: ExprTuple
#     sub-expressions: 61
# 59. Abs
#     core type: Literal
#     sub-expressions:
# 60. (b)
#     core type: ExprTuple
#     sub-expressions: 62
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. b
#     core type: Variable
#     sub-expressions:
