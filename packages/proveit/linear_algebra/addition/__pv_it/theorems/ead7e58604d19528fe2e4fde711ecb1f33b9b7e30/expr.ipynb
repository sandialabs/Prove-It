# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, Lambda, a, b, c, i, v, vi
from proveit.linear_algebra import VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Lambda(v, Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(VecSum(index_or_indices = sub_expr1, summand = vi, domain = Interval(a, b)), VecSum(index_or_indices = sub_expr1, summand = Function(v, [subtract(i, c)]), domain = Interval(Add(a, c), Add(b, c)))), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# v \mapsto \left[\forall_{a, b, c \in \mathbb{Z}}~\left(\left(\sum_{i=a}^{b} v\left(i\right)\right) = \left(\sum_{i=a + c}^{b + c} v\left(i - c\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. v -> [forall_{a, b, c in Integer} ((Sum_{i=a}^{b} v(i)) = (Sum_{i=a + c}^{b + c} v(i - c)))]
#    core type: Lambda
#    parameter: 36
#    body: 2
# 1. (v)
#    core type: ExprTuple
#    sub-expressions: 36
# 2. forall_{a, b, c in Integer} ((Sum_{i=a}^{b} v(i)) = (Sum_{i=a + c}^{b + c} v(i - c)))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{i=a}^{b} v(i)) = (Sum_{i=a + c}^{b + c} v(i - c)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{i=a}^{b} v(i)) = (Sum_{i=a + c}^{b + c} v(i - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 56, 57, 58
# 7. {(Sum_{i=a}^{b} v(i)) = (Sum_{i=a + c}^{b + c} v(i - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
# ...
