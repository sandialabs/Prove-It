# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, a, b
from proveit.linear_algebra import InnerProd, Norm, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Add, Exp, sqrt, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [a, b], instance_expr = Equals(Norm(VecAdd(a, b)), sqrt(Add(Exp(Norm(a), two), Exp(Norm(b), two)))), domain = V, condition = Equals(InnerProd(a, b), zero)), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{a, b \in V~|~\left \langle a, b\right \rangle = 0}~\left(\left \|a + b\right \| = \sqrt{\left(\left \|a\right \|^{2} + \left \|b\right \|^{2}\right)}\right) \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 36
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 36
# 3. {forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2}))) if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 36, 11
# 10. (a, b) -> {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Lambda
#     parameters: 45\n    body: 12
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 17
# 12. {||a + b|| = sqrt((||a||^{2} + ||b||^{2})) if a in V ,  b in V ,  <a, b> = 0.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. ||a + b|| = sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 31
#     operands: 18
# 16. (a in V) and (b in V) and (<a, b> = 0)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. K
#     core type: Variable
#     sub-expressions:
# 18. (||a + b||, sqrt((||a||^{2} + ||b||^{2})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a in V, b in V, <a, b> = 0)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. ||a + b||
#     core type: Operation
#     operator: 56
#     operand: 33
# 22. sqrt((||a||^{2} + ||b||^{2}))
#     core type: Operation
#     operator: 50
#     operands: 27
# 23. a in V
#     core type: Operation
#     operator: 29
#     operands: 28
# 24. b in V
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. <a, b> = 0
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. (a + b)
#     core type: ExprTuple
#     sub-expressions: 33
# 27. (||a||^{2} + ||b||^{2}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. (a, V)
#     core type: ExprTuple
#     sub-expressions: 58, 36
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (b, V)
#     core type: ExprTuple
#     sub-expressions: 59, 36
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (<a, b>, 0)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. a + b
#     core type: Operation
#     operator: 39
#     operands: 45
# 34. ||a||^{2} + ||b||^{2}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. 1 / 2
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. V
#     core type: Variable
#     sub-expressions:
# 37. <a, b>
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (||a||^{2}, ||b||^{2})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 42. /
#     core type: Literal
#     sub-expressions:
# 43. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 48, 54
# 44. InnerProd
#     core type: Literal
#     sub-expressions:
# 45. (a, b)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 46. ||a||^{2}
#     core type: Operation
#     operator: 50
#     operands: 49
# 47. ||b||^{2}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. (||a||, 2)
#     core type: ExprTuple
#     sub-expressions: 52, 54
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (||b||, 2)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. ||a||
#     core type: Operation
#     operator: 56
#     operand: 58
# 53. ||b||
#     core type: Operation
#     operator: 56
#     operand: 59
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. (a)
#     core type: ExprTuple
#     sub-expressions: 58
# 56. Abs
#     core type: Literal
#     sub-expressions:
# 57. (b)
#     core type: ExprTuple
#     sub-expressions: 59
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. b
#     core type: Variable
#     sub-expressions:
