# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import V, c, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, d_1_to_k
from proveit.linear_algebra import VecAdd
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c, d_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b_1_to_j, c, d_1_to_k), VecAdd(a_1_to_i, c, b_1_to_j, d_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c, d_{1}, d_{2}, \ldots, d_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j} + c+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i} + c+ b_{1} +  b_{2} +  \ldots +  b_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 46, 48, 51
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Lambda
#     parameters: 31\n    body: 14
# 11. i in Natural
#     core type: Operation
#     operator: 54
#     operands: 15
# 12. j in Natural
#     core type: Operation
#     operator: 54
#     operands: 16
# 13. k in Natural
#     core type: Operation
#     operator: 54
#     operands: 17
# 14. {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V), (b_{1} in V) ,  (b_{2} in V) ,  ... ,  (b_{j} in V) ,  c in V, (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 20
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 18. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)and (b_{1} in V) and  (b_{2} in V) and  ... and  (b_{j} in V) and (c in V)and (d_{1} in V) and  (d_{2} in V) and  ... and  (d_{k} in V)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V),(b_{1} in V), (b_{2} in V), ..., (b_{j} in V), c in V,(d_{1} in V), (d_{2} in V), ..., (d_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30
# 25. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 32
#     operands: 31
# 26. a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 50
#     end_index: 46
# 28. (b_{1} in V), (b_{2} in V), ..., (b_{j} in V)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 50
#     end_index: 48
# 29. c in V
#     core type: Operation
#     operator: 54
#     operands: 36
# 30. (d_{1} in V), (d_{2} in V), ..., (d_{k} in V)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 50
#     end_index: 51
# 31. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39, 43, 40
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (a_{1}, a_{2}, ..., a_{i}, c,b_{1}, b_{2}, ..., b_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 43, 39, 40
# 34. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 64
#     body: 41
# 35. _a -> (b_{_a} in V)
#     core type: Lambda
#     parameter: 64
#     body: 42
# 36. (c, V)
#     core type: ExprTuple
#     sub-expressions: 43, 59
# 37. _a -> (d_{_a} in V)
#     core type: Lambda
#     parameter: 64
#     body: 44
# 38. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 46
# 39. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 40. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 41. a_{_a} in V
#     core type: Operation
#     operator: 54
#     operands: 52
# 42. b_{_a} in V
#     core type: Operation
#     operator: 54
#     operands: 53
# 43. c
#     core type: Variable
#     sub-expressions:
# 44. d_{_a} in V
#     core type: Operation
#     operator: 54
#     operands: 55
# 45. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 56
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. _a -> b_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 57
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. _a -> d_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 58
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 56, 59
# 53. (b_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (d_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. b_{_a}
#     core type: IndexedVar
# variable: 61
# index: 64
# 58. d_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 59. V
#     core type: Variable
#     sub-expressions:
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. b
#     core type: Variable
#     sub-expressions:
# 62. d
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
