# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.linear_algebra import VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d_1_to_k], instance_expr = Equals(VecAdd(a_1_to_i, b, c_1_to_j, d_1_to_k), VecAdd(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), domain = V), domain = Natural), domain = VecSpaces(K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d_{1}, d_{2}, \ldots, d_{k} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j} + b+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V in_c VecSpaces(K)} [forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]]
#    core type: Operation
#    operator: 19
#    operand: 2
# 1. (V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. V -> {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 71
#    body: 4
# 3. (V)
#    core type: ExprTuple
#    sub-expressions: 71
# 4. {forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 19
#    operand: 10
# 6. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 71, 11
# 10. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 58, 60, 63
# 13. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. VecSpaces
#     core type: Literal
#     sub-expressions:
# 15. (K)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in V} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}))
#     core type: Operation
#     operator: 19
#     operand: 22
# 17. (i in Natural) and (j in Natural) and (k in Natural)
#     core type: Operation
#     operator: 35
#     operands: 21
# 18. K
#     core type: Variable
#     sub-expressions:
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 22. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Lambda
#     parameters: 43\n    body: 26
# 23. i in Natural
#     core type: Operation
#     operator: 66
#     operands: 27
# 24. j in Natural
#     core type: Operation
#     operator: 66
#     operands: 28
# 25. k in Natural
#     core type: Operation
#     operator: 66
#     operands: 29
# 26. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V) ,  b in V, (c_{1} in V) ,  (c_{2} in V) ,  ... ,  (c_{j} in V), (d_{1} in V) ,  (d_{2} in V) ,  ... ,  (d_{k} in V).
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 58, 32
# 28. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 60, 32
# 29. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 63, 32
# 30. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V) and (b in V)and (c_{1} in V) and  (c_{2} in V) and  ... and  (c_{j} in V)and (d_{1} in V) and  (d_{2} in V) and  ... and  (d_{k} in V)
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. Natural
#     core type: Literal
#     sub-expressions:
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. ((a_{1} in V), (a_{2} in V), ..., (a_{i} in V), b in V,(c_{1} in V), (c_{2} in V), ..., (c_{j} in V),(d_{1} in V), (d_{2} in V), ..., (d_{k} in V))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 37. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 44
#     operands: 43
# 38. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j} + b+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 62
#     end_index: 58
# 40. b in V
#     core type: Operation
#     operator: 66
#     operands: 47
# 41. (c_{1} in V), (c_{2} in V), ..., (c_{j} in V)
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 62
#     end_index: 60
# 42. (d_{1} in V), (d_{2} in V), ..., (d_{k} in V)
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 62
#     end_index: 63
# 43. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 50, 54, 51, 52
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j}, b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 50, 51, 54, 52
# 46. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 53
# 47. (b, V)
#     core type: ExprTuple
#     sub-expressions: 54, 71
# 48. _a -> (c_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 55
# 49. _a -> (d_{_a} in V)
#     core type: Lambda
#     parameter: 76
#     body: 56
# 50. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 62
#     end_index: 58
# 51. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 62
#     end_index: 60
# 52. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 53. a_{_a} in V
#     core type: Operation
#     operator: 66
#     operands: 64
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. c_{_a} in V
#     core type: Operation
#     operator: 66
#     operands: 65
# 56. d_{_a} in V
#     core type: Operation
#     operator: 66
#     operands: 67
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 68
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. _a -> c_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 69
# 60. j
#     core type: Variable
#     sub-expressions:
# 61. _a -> d_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 70
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 68, 71
# 65. (c_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 69, 71
# 66. in
#     core type: Literal
#     sub-expressions:
# 67. (d_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. a_{_a}
#     core type: IndexedVar
# variable: 72
# index: 76
# 69. c_{_a}
#     core type: IndexedVar
# variable: 73
# index: 76
# 70. d_{_a}
#     core type: IndexedVar
# variable: 74
# index: 76
# 71. V
#     core type: Variable
#     sub-expressions:
# 72. a
#     core type: Variable
#     sub-expressions:
# 73. c
#     core type: Variable
#     sub-expressions:
# 74. d
#     core type: Variable
#     sub-expressions:
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 76. _a
#     core type: Variable
#     sub-expressions:
