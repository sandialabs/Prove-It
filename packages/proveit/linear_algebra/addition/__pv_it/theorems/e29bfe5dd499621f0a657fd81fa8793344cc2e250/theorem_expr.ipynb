# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#vec_sum_split_before">vec_sum_split_before</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.addition import vec_sum_split_before

# %%
# check that the built expression is the same as the stored expression
assert vec_sum_split_before.expr == stored_expr
assert vec_sum_split_before.expr._style_id == stored_expr._style_id
print("Passed sanity check: vec_sum_split_before matches stored_expr")
# Out:
# Passed sanity check: vec_sum_split_before matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{v}~\left[\forall_{a, b, c \in \mathbb{Z}~|~a < b, b \leq c}~\left(\left(\sum_{i=a}^{c} v\left(i\right)\right) = \left(\left(\sum_{i=a}^{b - 1} v\left(i\right)\right) + \left(\sum_{i=b}^{c} v\left(i\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v} [forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (v -> [forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. v -> [forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))))]
#    core type: Lambda
#    parameter: 52
#    body: 4
# 3. (v)
#    core type: ExprTuple
#    sub-expressions: 52
# 4. forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{i=a}^{c} v(i)) = ((Sum_{i=a}^{b - 1} v(i)) + (Sum_{i=b}^{c} v(i))))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
