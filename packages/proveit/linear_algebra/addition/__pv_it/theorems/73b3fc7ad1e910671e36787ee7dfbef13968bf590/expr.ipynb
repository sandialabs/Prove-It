# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, i, j, k, v
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, one, subtract

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(VecSum(index_or_indices = [i], summand = v, domain = Interval(j, k)), ScalarMult(Add(subtract(k, j), one), v)), domain = V), domain = VecSpaces(K)), And(InSet(j, Integer), InSet(k, Integer), LessEq(j, k)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{v \in V}~\left(\left(\sum_{i=j}^{k} v\right) = \left(\left(\left(k - j\right) + 1\right) \cdot v\right)\right)\right] \textrm{ if } j \in \mathbb{Z} ,  k \in \mathbb{Z} ,  j \leq k\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))] if j in Integer ,  k in Integer ,  j <= k.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{V in_c VecSpaces(K)} [forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))]
#    core type: Operation
#    operator: 18
#    operand: 6
# 2. (j in Integer) and (k in Integer) and (j <= k)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (j in Integer, k in Integer, j <= k)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. V -> {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 36
#    body: 11
# 7. j in Integer
#    core type: Operation
#    operator: 50
#    operands: 12
# 8. k in Integer
#    core type: Operation
#    operator: 50
#    operands: 13
# 9. j <= k
#    core type: Operation
#    operator: 14
#    operands: 58
# 10. (V)
#     core type: ExprTuple
#     sub-expressions: 36
# 11. {forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v)) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 17
# 13. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 17
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. forall_{v in V} ((Sum_{i=j}^{k} v) = (((k - j) + 1) * v))
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Integer
#     core type: Literal
#     sub-expressions:
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. (v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. in_c
#     core type: Literal
#     sub-expressions:
# 21. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 36, 23
# 22. v -> {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Lambda
#     parameter: 46
#     body: 25
# 23. VecSpaces(K)
#     core type: Operation
#     operator: 26
#     operand: 30
# 24. (v)
#     core type: ExprTuple
#     sub-expressions: 46
# 25. {(Sum_{i=j}^{k} v) = (((k - j) + 1) * v) if v in V.
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. VecSpaces
#     core type: Literal
#     sub-expressions:
# 27. (K)
#     core type: ExprTuple
#     sub-expressions: 30
# 28. (Sum_{i=j}^{k} v) = (((k - j) + 1) * v)
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. v in V
#     core type: Operation
#     operator: 50
#     operands: 33
# 30. K
#     core type: Variable
#     sub-expressions:
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (Sum_{i=j}^{k} v, ((k - j) + 1) * v)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. (v, V)
#     core type: ExprTuple
#     sub-expressions: 46, 36
# 34. Sum_{i=j}^{k} v
#     core type: Operation
#     operator: 37
#     operand: 41
# 35. ((k - j) + 1) * v
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. V
#     core type: Variable
#     sub-expressions:
# 37. Sum
#     core type: Literal
#     sub-expressions:
# 38. (i -> {v if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. ((k - j) + 1, v)
#     core type: ExprTuple
#     sub-expressions: 42, 46
# 41. i -> {v if i in {j .. k}.
#     core type: Lambda
#     parameter: 54
#     body: 44
# 42. (k - j) + 1
#     core type: Operation
#     operator: 52
#     operands: 45
# 43. (i)
#     core type: ExprTuple
#     sub-expressions: 54
# 44. {v if i in {j .. k}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 45. (k - j, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. v
#     core type: Variable
#     sub-expressions:
# 47. i in {j .. k}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. k - j
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 61, 56
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. {j .. k}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. -j
#     core type: Operation
#     operator: 59
#     operand: 62
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (j, k)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (j)
#     core type: ExprTuple
#     sub-expressions: 62
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. j
#     core type: Variable
#     sub-expressions:
