# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import fi, gamma, i, x, y, z
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Forall, Implies, InSet
from proveit.numbers import Interval, Real, four, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = CartExp(Real, three)
sub_expr3 = Interval(two, four)
sub_expr4 = ScalarMult(gamma, fi)
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(x, y, sub_expr4, z), TensorProd(sub_expr2, sub_expr2, sub_expr2, sub_expr2)), domain = sub_expr3), Equals(TensorProd(x, y, VecSum(index_or_indices = sub_expr1, summand = sub_expr4, domain = sub_expr3), z), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(gamma, TensorProd(x, y, fi, z)), domain = sub_expr3)).with_wrapping_at(1)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{i \in \{2~\ldotp \ldotp~4\}}~\left(\left(x {\otimes} y {\otimes} \left(\gamma \cdot f\left(i\right)\right) {\otimes} z\right) \in \left(\mathbb{R}^{3} {\otimes} \mathbb{R}^{3} {\otimes} \mathbb{R}^{3} {\otimes} \mathbb{R}^{3}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(x {\otimes} y {\otimes} \left(\sum_{i=2}^{4} \left(\gamma \cdot f\left(i\right)\right)\right) {\otimes} z\right) \\  = \left(\sum_{i=2}^{4} \left(\gamma \cdot \left(x {\otimes} y {\otimes} f\left(i\right) {\otimes} z\right)\right)\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{i in {2 .. 4}} ((x otimes y otimes (gamma * f(i)) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}))] =>  \\ ((x otimes y otimes (Sum_{i=2}^{4} (gamma * f(i))) otimes z) \\  = (Sum_{i=2}^{4} (gamma * (x otimes y otimes f(i) otimes z))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{i in {2 .. 4}} ((x otimes y otimes (gamma * f(i)) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3})), (x otimes y otimes (Sum_{i=2}^{4} (gamma * f(i))) otimes z) \\  = (Sum_{i=2}^{4} (gamma * (x otimes y otimes f(i) otimes z))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{i in {2 .. 4}} ((x otimes y otimes (gamma * f(i)) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}))
#    core type: Operation
#    operator: 5
#    operand: 9
# ...
