# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, beta, fi, gamma, i, x, y
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Forall, InSet
from proveit.numbers import Interval, Real, four, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = ScalarMult(gamma, beta)
sub_expr3 = CartExp(Real, three)
sub_expr4 = Interval(two, four)
sub_expr5 = ScalarMult(sub_expr2, fi)
expr = ExprTuple(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(x, sub_expr5, y), TensorProd(sub_expr3, sub_expr3, sub_expr3)), domain = sub_expr4), Equals(TensorProd(x, VecSum(index_or_indices = sub_expr1, summand = sub_expr5, domain = sub_expr4), y), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, TensorProd(x, fi, y)), domain = sub_expr4)).with_wrapping_at(1))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{i \in \{2~\ldotp \ldotp~4\}}~\left(\left(x {\otimes} \left(\left(\gamma \cdot \beta\right) \cdot f\left(i\right)\right) {\otimes} y\right) \in \left(\mathbb{R}^{3} {\otimes} \mathbb{R}^{3} {\otimes} \mathbb{R}^{3}\right)\right), \begin{array}{c} \begin{array}{l} \left(x {\otimes} \left(\sum_{i=2}^{4} \left(\left(\gamma \cdot \beta\right) \cdot f\left(i\right)\right)\right) {\otimes} y\right) \\  = \left(\sum_{i=2}^{4} \left(\left(\gamma \cdot \beta\right) \cdot \left(x {\otimes} f\left(i\right) {\otimes} y\right)\right)\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{i in {2 .. 4}} ((x otimes ((gamma * beta) * f(i)) otimes y) in (Real^{3} otimes Real^{3} otimes Real^{3})), (x otimes (Sum_{i=2}^{4} ((gamma * beta) * f(i))) otimes y) \\  = (Sum_{i=2}^{4} ((gamma * beta) * (x otimes f(i) otimes y))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{i in {2 .. 4}} ((x otimes ((gamma * beta) * f(i)) otimes y) in (Real^{3} otimes Real^{3} otimes Real^{3}))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (x otimes (Sum_{i=2}^{4} ((gamma * beta) * f(i))) otimes y) \\  = (Sum_{i=2}^{4} ((gamma * beta) * (x otimes f(i) otimes y)))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (i -> {(x otimes ((gamma * beta) * f(i)) otimes y) in (Real^{3} otimes Real^{3} otimes Real^{3}) if i in {2 .. 4}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# ...
