# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, beta, gamma, i, x, y
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, InSet
from proveit.numbers import Add, Interval, Mult, Real, four, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = TensorProd(x, y)
sub_expr3 = Interval(two, four)
sub_expr4 = CartExp(Real, three)
sub_expr5 = Mult(gamma, beta)
sub_expr6 = Mult(i, Add(i, one))
sub_expr7 = VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr6, sub_expr2), domain = sub_expr3)
expr = ExprTuple(InSet(sub_expr7, TensorProd(sub_expr4, sub_expr4)), Equals(ScalarMult(sub_expr5, sub_expr7), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Mult(sub_expr5, sub_expr6), sub_expr2), domain = sub_expr3)).with_wrapping_at(1))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\sum_{i=2}^{4} \left(\left(i \cdot \left(i + 1\right)\right) \cdot \left(x {\otimes} y\right)\right)\right) \in \left(\mathbb{R}^{3} {\otimes} \mathbb{R}^{3}\right), \begin{array}{c} \begin{array}{l} \left(\left(\gamma \cdot \beta\right) \cdot \left(\sum_{i=2}^{4} \left(\left(i \cdot \left(i + 1\right)\right) \cdot \left(x {\otimes} y\right)\right)\right)\right) \\  = \left(\sum_{i=2}^{4} \left(\left(\left(\gamma \cdot \beta\right) \cdot \left(i \cdot \left(i + 1\right)\right)\right) \cdot \left(x {\otimes} y\right)\right)\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y))) in (Real^{3} otimes Real^{3}), ((gamma * beta) * (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y)))) \\  = (Sum_{i=2}^{4} (((gamma * beta) * (i * (i + 1))) * (x otimes y))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y))) in (Real^{3} otimes Real^{3})
#    core type: Operation
#    operator: 32
#    operands: 3
# 2. ((gamma * beta) * (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y)))) \\  = (Sum_{i=2}^{4} (((gamma * beta) * (i * (i + 1))) * (x otimes y)))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y)), Real^{3} otimes Real^{3})
#    core type: ExprTuple
#    sub-expressions: 13, 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((gamma * beta) * (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y))), Sum_{i=2}^{4} (((gamma * beta) * (i * (i + 1))) * (x otimes y)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Real^{3} otimes Real^{3}
#    core type: Operation
#    operator: 39
#    operands: 9
# 7. (gamma * beta) * (Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y)))
#    core type: Operation
#    operator: 30
#    operands: 10
# 8. Sum_{i=2}^{4} (((gamma * beta) * (i * (i + 1))) * (x otimes y))
#    core type: Operation
#    operator: 17
#    operand: 14
# 9. (Real^{3}, Real^{3})
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 10. (gamma * beta, Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y)))
#     core type: ExprTuple
#     sub-expressions: 37, 13
# 11. (i -> {((gamma * beta) * (i * (i + 1))) * (x otimes y) if i in {2 .. 4}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. Real^{3}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. Sum_{i=2}^{4} ((i * (i + 1)) * (x otimes y))
#     core type: Operation
#     operator: 17
#     operand: 22
# 14. i -> {((gamma * beta) * (i * (i + 1))) * (x otimes y) if i in {2 .. 4}.
#     core type: Lambda
#     parameter: 55
#     body: 19
# 15. CartExp
#     core type: Literal
#     sub-expressions:
# 16. (Real, 3)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (i -> {(i * (i + 1)) * (x otimes y) if i in {2 .. 4}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 19. {((gamma * beta) * (i * (i + 1))) * (x otimes y) if i in {2 .. 4}.
#     core type: Conditional
#     value: 23
#     condition: 28
# 20. Real
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
# 22. i -> {(i * (i + 1)) * (x otimes y) if i in {2 .. 4}.
#     core type: Lambda
#     parameter: 55
#     body: 25
# 23. ((gamma * beta) * (i * (i + 1))) * (x otimes y)
#     core type: Operation
#     operator: 30
#     operands: 26
# 24. (i)
#     core type: ExprTuple
#     sub-expressions: 55
# 25. {(i * (i + 1)) * (x otimes y) if i in {2 .. 4}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. ((gamma * beta) * (i * (i + 1)), x otimes y)
#     core type: ExprTuple
#     sub-expressions: 29, 35
# 27. (i * (i + 1)) * (x otimes y)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. i in {2 .. 4}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (gamma * beta) * (i * (i + 1))
#     core type: Operation
#     operator: 44
#     operands: 34
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (i * (i + 1), x otimes y)
#     core type: ExprTuple
#     sub-expressions: 38, 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (i, {2 .. 4})
#     core type: ExprTuple
#     sub-expressions: 55, 36
# 34. (gamma * beta, i * (i + 1))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. x otimes y
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. {2 .. 4}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. gamma * beta
#     core type: Operation
#     operator: 44
#     operands: 43
# 38. i * (i + 1)
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. otimes
#     core type: Literal
#     sub-expressions:
# 40. (x, y)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (2, 4)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. (gamma, beta)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (i, i + 1)
#     core type: ExprTuple
#     sub-expressions: 55, 52
# 46. x
#     core type: Variable
#     sub-expressions:
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. 2
#     core type: Literal
#     sub-expressions:
# 49. 4
#     core type: Literal
#     sub-expressions:
# 50. gamma
#     core type: Variable
#     sub-expressions:
# 51. beta
#     core type: Variable
#     sub-expressions:
# 52. i + 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
