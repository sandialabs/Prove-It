# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import fi, gamma, i, x, y, z
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Forall, Implies, InSet
from proveit.numbers import Interval, Real, four, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = CartExp(Real, three)
sub_expr3 = Interval(two, four)
sub_expr4 = TensorProd(y, fi)
sub_expr5 = ScalarMult(gamma, sub_expr4)
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(x, sub_expr5, z), TensorProd(sub_expr2, sub_expr2, sub_expr2, sub_expr2)), domain = sub_expr3), Equals(TensorProd(x, VecSum(index_or_indices = sub_expr1, summand = sub_expr5, domain = sub_expr3), z), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(gamma, TensorProd(x, sub_expr4, z)), domain = sub_expr3)).with_wrapping_at(1)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{i \in \{2~\ldotp \ldotp~4\}}~\left(\left(x {\otimes} \left(\gamma \cdot \left(y {\otimes} f\left(i\right)\right)\right) {\otimes} z\right) \in \left(\mathbb{R}^{3} {\otimes} \mathbb{R}^{3} {\otimes} \mathbb{R}^{3} {\otimes} \mathbb{R}^{3}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(x {\otimes} \left(\sum_{i=2}^{4} \left(\gamma \cdot \left(y {\otimes} f\left(i\right)\right)\right)\right) {\otimes} z\right) \\  = \left(\sum_{i=2}^{4} \left(\gamma \cdot \left(x {\otimes} \left(y {\otimes} f\left(i\right)\right) {\otimes} z\right)\right)\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{i in {2 .. 4}} ((x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}))] =>  \\ ((x otimes (Sum_{i=2}^{4} (gamma * (y otimes f(i)))) otimes z) \\  = (Sum_{i=2}^{4} (gamma * (x otimes (y otimes f(i)) otimes z))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{i in {2 .. 4}} ((x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3})), (x otimes (Sum_{i=2}^{4} (gamma * (y otimes f(i)))) otimes z) \\  = (Sum_{i=2}^{4} (gamma * (x otimes (y otimes f(i)) otimes z))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{i in {2 .. 4}} ((x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (x otimes (Sum_{i=2}^{4} (gamma * (y otimes f(i)))) otimes z) \\  = (Sum_{i=2}^{4} (gamma * (x otimes (y otimes f(i)) otimes z)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (i -> {(x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}) if i in {2 .. 4}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x otimes (Sum_{i=2}^{4} (gamma * (y otimes f(i)))) otimes z, Sum_{i=2}^{4} (gamma * (x otimes (y otimes f(i)) otimes z)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. i -> {(x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}) if i in {2 .. 4}.
#    core type: Lambda
#    parameter: 58
#    body: 12
# 10. x otimes (Sum_{i=2}^{4} (gamma * (y otimes f(i)))) otimes z
#     core type: Operation
#     operator: 50
#     operands: 13
# 11. Sum_{i=2}^{4} (gamma * (x otimes (y otimes f(i)) otimes z))
#     core type: Operation
#     operator: 19
#     operand: 17
# 12. {(x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}) if i in {2 .. 4}.
#     core type: Conditional
#     value: 15
#     condition: 32
# 13. (x, Sum_{i=2}^{4} (gamma * (y otimes f(i))), z)
#     core type: ExprTuple
#     sub-expressions: 45, 16, 47
# 14. (i -> {gamma * (x otimes (y otimes f(i)) otimes z) if i in {2 .. 4}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (x otimes (gamma * (y otimes f(i))) otimes z) in (Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3})
#     core type: Operation
#     operator: 38
#     operands: 18
# 16. Sum_{i=2}^{4} (gamma * (y otimes f(i)))
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. i -> {gamma * (x otimes (y otimes f(i)) otimes z) if i in {2 .. 4}.
#     core type: Lambda
#     parameter: 58
#     body: 21
# 18. (x otimes (gamma * (y otimes f(i))) otimes z, Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. Sum
#     core type: Literal
#     sub-expressions:
# 20. (i -> {gamma * (y otimes f(i)) if i in {2 .. 4}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. {gamma * (x otimes (y otimes f(i)) otimes z) if i in {2 .. 4}.
#     core type: Conditional
#     value: 25
#     condition: 32
# 22. x otimes (gamma * (y otimes f(i))) otimes z
#     core type: Operation
#     operator: 50
#     operands: 26
# 23. Real^{3} otimes Real^{3} otimes Real^{3} otimes Real^{3}
#     core type: Operation
#     operator: 50
#     operands: 27
# 24. i -> {gamma * (y otimes f(i)) if i in {2 .. 4}.
#     core type: Lambda
#     parameter: 58
#     body: 28
# 25. gamma * (x otimes (y otimes f(i)) otimes z)
#     core type: Operation
#     operator: 36
#     operands: 29
# 26. (x, gamma * (y otimes f(i)), z)
#     core type: ExprTuple
#     sub-expressions: 45, 31, 47
# 27. (Real^{3}, Real^{3}, Real^{3}, Real^{3})
#     core type: ExprTuple
#     sub-expressions: 30, 30, 30, 30
# 28. {gamma * (y otimes f(i)) if i in {2 .. 4}.
#     core type: Conditional
#     value: 31
#     condition: 32
# 29. (gamma, x otimes (y otimes f(i)) otimes z)
#     core type: ExprTuple
#     sub-expressions: 43, 33
# 30. Real^{3}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. gamma * (y otimes f(i))
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. i in {2 .. 4}
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. x otimes (y otimes f(i)) otimes z
#     core type: Operation
#     operator: 50
#     operands: 40
# 34. CartExp
#     core type: Literal
#     sub-expressions:
# 35. (Real, 3)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 36. *
#     core type: Literal
#     sub-expressions:
# 37. (gamma, y otimes f(i))
#     core type: ExprTuple
#     sub-expressions: 43, 46
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (i, {2 .. 4})
#     core type: ExprTuple
#     sub-expressions: 58, 44
# 40. (x, y otimes f(i), z)
#     core type: ExprTuple
#     sub-expressions: 45, 46, 47
# 41. Real
#     core type: Literal
#     sub-expressions:
# 42. 3
#     core type: Literal
#     sub-expressions:
# 43. gamma
#     core type: Variable
#     sub-expressions:
# 44. {2 .. 4}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. y otimes f(i)
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. z
#     core type: Variable
#     sub-expressions:
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (2, 4)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. otimes
#     core type: Literal
#     sub-expressions:
# 51. (y, f(i))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. 2
#     core type: Literal
#     sub-expressions:
# 53. 4
#     core type: Literal
#     sub-expressions:
# 54. y
#     core type: Variable
#     sub-expressions:
# 55. f(i)
#     core type: Operation
#     operator: 56
#     operand: 58
# 56. f
#     core type: Variable
#     sub-expressions:
# 57. (i)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. i
#     core type: Variable
#     sub-expressions:
