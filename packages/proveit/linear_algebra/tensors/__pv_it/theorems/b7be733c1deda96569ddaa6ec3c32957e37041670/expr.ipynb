# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = ExprTuple(Lambda(sub_expr2, Conditional(Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), Mult(ExprRange(sub_expr1, Norm(IndexedVar(a, sub_expr1)), one, i))), domains = sub_expr2).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(V, sub_expr1), InnerProdSpaces(K)), one, i)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(V_{1}, V_{2}, \ldots, V_{i}\right) \mapsto \left\{\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = \left(\left \|a_{1}\right \| \cdot  \left \|a_{2}\right \| \cdot  \ldots \cdot  \left \|a_{i}\right \|\right)\right)\end{array} \textrm{ if } \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right) \land  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right) \land  \ldots \land  \left(V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (V_{1}, V_{2}, ..., V_{i})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. V_{1}, V_{2}, ..., V_{i}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 47
#    end_index: 48
# 5. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))
#    core type: Operation
#    operator: 8
#    operand: 11
# 6. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#    core type: Operation
#    operator: 20
#    operands: 10
# 7. _a -> V_{_a}
#    core type: Lambda
#    parameter: 55
#    body: 45
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 39\n    body: 13
# 12. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 47
#     end_index: 48
# 13. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 55
#     body: 17
# 15. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. in_c
#     core type: Literal
#     sub-expressions:
# 23. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 45, 27
# 24. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 49
#     operand: 34
# 25. ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 47
#     end_index: 48
# 27. InnerProdSpaces(K)
#     core type: Operation
#     operator: 32
#     operand: 37
# 28. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 34
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (||a_{1}||, ||a_{2}||, ..., ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 36
# 32. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 33. (K)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. ||a_{1}||, ||a_{2}||, ..., ||a_{i}||
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 47
#     end_index: 48
# 36. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. K
#     core type: Variable
#     sub-expressions:
# 38. otimes
#     core type: Literal
#     sub-expressions:
# 39. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 43
# 40. _a -> ||a_{_a}||
#     core type: Lambda
#     parameter: 55
#     body: 44
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 43. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. ||a_{_a}||
#     core type: Operation
#     operator: 49
#     operand: 52
# 45. V_{_a}
#     core type: IndexedVar
# variable: 51
# index: 55
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. Abs
#     core type: Literal
#     sub-expressions:
# 50. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 52
# 51. V
#     core type: Variable
#     sub-expressions:
# 52. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
