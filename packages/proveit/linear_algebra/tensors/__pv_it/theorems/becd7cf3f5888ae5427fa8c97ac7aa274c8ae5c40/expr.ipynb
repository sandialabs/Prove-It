# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, Function, IndexedVar, K, Lambda, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, W_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(V, sub_expr1)
sub_expr3 = IndexedVar(W, sub_expr1)
sub_expr4 = VecSpaces(K)
expr = Lambda([V_1_to_n, W_1_to_n], Conditional(Forall(instance_param_or_params = [A_1_to_n], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(IndexedVar(A, sub_expr1), [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), domains = [ExprRange(sub_expr1, LinMap(sub_expr2, sub_expr3), one, n)]).with_wrapping(), And(ExprRange(sub_expr1, InClass(sub_expr2, sub_expr4), one, n), ExprRange(sub_expr1, InClass(sub_expr3, sub_expr4), one, n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V_{1}, V_{2}, \ldots, V_{n}, W_{1}, W_{2}, \ldots, W_{n}\right) \mapsto \left\{\begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(V_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (V_{1}, V_{2}, ..., V_{n},W_{1}, W_{2}, ..., W_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 5
#    condition: 6
# 3. V_{1}, V_{2}, ..., V_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 70
#    end_index: 71
# 4. W_{1}, W_{2}, ..., W_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 70
#    end_index: 71
# 5. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#    core type: Operation
#    operator: 21
#    operand: 11
# 6. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{n} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{n} in_c VecSpaces(K))
#    core type: Operation
#    operator: 40
#    operands: 10
# 7. _a -> V_{_a}
#    core type: Lambda
#    parameter: 79
#    body: 68
# 8. _a -> W_{_a}
#    core type: Lambda
#    parameter: 79
#    body: 57
# 9. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Lambda
#     parameters: 53\n    body: 14
# 12. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 70
#     end_index: 71
# 13. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 70
#     end_index: 71
# 14. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 79
#     body: 19
# 16. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 79
#     body: 20
# 17. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#     core type: Operation
#     operator: 21
#     operand: 27
# 18. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: Operation
#     operator: 40
#     operands: 23
# 19. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 24
# 20. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 68, 29
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 57, 29
# 27. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Lambda
#     parameters: 60\n    body: 30
# 28. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 70
#     end_index: 71
# 29. VecSpaces(K)
#     core type: Operation
#     operator: 32
#     operand: 37
# 30. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 34
#     condition: 35
# 31. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 79
#     body: 36
# 32. VecSpaces
#     core type: Literal
#     sub-expressions:
# 33. (K)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 62
#     operands: 42
# 37. K
#     core type: Variable
#     sub-expressions:
# 38. =
#     core type: Literal
#     sub-expressions:
# 39. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 45
# 42. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 72, 46
# 43. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 47
#     operand: 54
# 44. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 59
#     operands: 49
# 45. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 70
#     end_index: 71
# 46. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 59
#     operands: 53
# 48. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 55
# 50. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 79
#     body: 56
# 51. LINMAP
#     core type: Literal
#     sub-expressions:
# 52. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 68, 57
# 53. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 58
# 54. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 70
#     end_index: 71
# 56. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. W_{_a}
#     core type: IndexedVar
# variable: 64
# index: 79
# 58. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 70
#     end_index: 71
# 59. otimes
#     core type: Literal
#     sub-expressions:
# 60. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 66
# 61. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 79
#     body: 67
# 62. in
#     core type: Literal
#     sub-expressions:
# 63. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 76, 68
# 64. W
#     core type: Variable
#     sub-expressions:
# 65. _a -> A_{_a}
#     core type: Lambda
#     parameter: 79
#     body: 72
# 66. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 70
#     end_index: 71
# 67. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 72
#     operand: 76
# 68. V_{_a}
#     core type: IndexedVar
# variable: 74
# index: 79
# 69. _a -> v_{_a}
#     core type: Lambda
#     parameter: 79
#     body: 76
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. A_{_a}
#     core type: IndexedVar
# variable: 75
# index: 79
# 73. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 76
# 74. V
#     core type: Variable
#     sub-expressions:
# 75. A
#     core type: Variable
#     sub-expressions:
# 76. v_{_a}
#     core type: IndexedVar
# variable: 77
# index: 79
# 77. v
#     core type: Variable
#     sub-expressions:
# 78. (_a)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. _a
#     core type: Variable
#     sub-expressions:
