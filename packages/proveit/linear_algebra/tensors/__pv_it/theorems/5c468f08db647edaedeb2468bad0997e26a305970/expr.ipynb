# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, Function, IndexedVar, K, Lambda, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, W_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd, VecSpaces
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [V_1_to_n, W_1_to_n], instance_expr = Forall(instance_param_or_params = [A_1_to_n], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(IndexedVar(A, sub_expr1), [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), domains = [ExprRange(sub_expr1, LinMap(IndexedVar(V, sub_expr1), IndexedVar(W, sub_expr1)), one, n)]).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{n}, W_{1}, W_{2}, \ldots, W_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array}\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 79
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 79
# 2. {forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]
#    core type: Operation
#    operator: 29
#    operand: 7
# 4. n in NaturalPos
#    core type: Operation
#    operator: 70
#    operands: 6
# 5. ((V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 79, 8
# 7. (V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (V_{1}, V_{2}, ..., V_{n},W_{1}, W_{2}, ..., W_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. V_{1}, V_{2}, ..., V_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 78
#     end_index: 79
# 12. W_{1}, W_{2}, ..., W_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 78
#     end_index: 79
# 13. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#     core type: Operation
#     operator: 29
#     operand: 19
# 14. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{n} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{n} in_c VecSpaces(K))
#     core type: Operation
#     operator: 48
#     operands: 18
# 15. _a -> V_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 76
# 16. _a -> W_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 65
# 17. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Lambda
#     parameters: 61\n    body: 22
# 20. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 78
#     end_index: 79
# 21. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 78
#     end_index: 79
# 22. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 87
#     body: 27
# 24. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 87
#     body: 28
# 25. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#     core type: Operation
#     operator: 29
#     operand: 35
# 26. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: Operation
#     operator: 48
#     operands: 31
# 27. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#     core type: ExprTuple
#     sub-expressions: 36
# 32. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 76, 37
# 33. in_c
#     core type: Literal
#     sub-expressions:
# 34. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 65, 37
# 35. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Lambda
#     parameters: 68\n    body: 38
# 36. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 78
#     end_index: 79
# 37. VecSpaces(K)
#     core type: Operation
#     operator: 40
#     operand: 45
# 38. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 42
#     condition: 43
# 39. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 87
#     body: 44
# 40. VecSpaces
#     core type: Literal
#     sub-expressions:
# 41. (K)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 70
#     operands: 50
# 45. K
#     core type: Variable
#     sub-expressions:
# 46. =
#     core type: Literal
#     sub-expressions:
# 47. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 53
# 50. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 80, 54
# 51. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 55
#     operand: 62
# 52. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 67
#     operands: 57
# 53. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 78
#     end_index: 79
# 54. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 67
#     operands: 61
# 56. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 57. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 63
# 58. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 87
#     body: 64
# 59. LINMAP
#     core type: Literal
#     sub-expressions:
# 60. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 76, 65
# 61. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 66
# 62. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 78
#     end_index: 79
# 64. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 70
#     operands: 71
# 65. W_{_a}
#     core type: IndexedVar
# variable: 72
# index: 87
# 66. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 78
#     end_index: 79
# 67. otimes
#     core type: Literal
#     sub-expressions:
# 68. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 74
# 69. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 87
#     body: 75
# 70. in
#     core type: Literal
#     sub-expressions:
# 71. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 84, 76
# 72. W
#     core type: Variable
#     sub-expressions:
# 73. _a -> A_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 80
# 74. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 78
#     end_index: 79
# 75. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 80
#     operand: 84
# 76. V_{_a}
#     core type: IndexedVar
# variable: 82
# index: 87
# 77. _a -> v_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 84
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. n
#     core type: Variable
#     sub-expressions:
# 80. A_{_a}
#     core type: IndexedVar
# variable: 83
# index: 87
# 81. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 84
# 82. V
#     core type: Variable
#     sub-expressions:
# 83. A
#     core type: Variable
#     sub-expressions:
# 84. v_{_a}
#     core type: IndexedVar
# variable: 85
# index: 87
# 85. v
#     core type: Variable
#     sub-expressions:
# 86. (_a)
#     core type: ExprTuple
#     sub-expressions: 87
# 87. _a
#     core type: Variable
#     sub-expressions:
