# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [V_1_to_i]
expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = InSet(TensorProd(a_1_to_i), TensorProd(V_1_to_i)), domains = sub_expr1), domain = VecSpaces(K)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i \in \mathbb{N}^+}~\left[\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right) \in \left(V_{1} {\otimes}  V_{2} {\otimes}  \ldots {\otimes}  V_{i}\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 46
#    body: 4
# 3. (i)
#    core type: ExprTuple
#    sub-expressions: 46
# 4. {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. i in NaturalPos
#    core type: Operation
#    operator: 47
#    operands: 8
# 7. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 46, 10
# 9. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 35\n   body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K))
#     core type: Operation
#     operator: 25
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 33\n    body: 19
# 18. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 45
#     end_index: 46
# 19. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 54
#     body: 23
# 21. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: Operation
#     operator: 47
#     operands: 24
# 22. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}, V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 31
# 27. in_c
#     core type: Literal
#     sub-expressions:
# 28. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 50, 32
# 29. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 34
#     operands: 33
# 30. V_{1} otimes  V_{2} otimes  ... otimes  V_{i}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 45
#     end_index: 46
# 32. VecSpaces(K)
#     core type: Operation
#     operator: 37
#     operand: 42
# 33. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. otimes
#     core type: Literal
#     sub-expressions:
# 35. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 54
#     body: 41
# 37. VecSpaces
#     core type: Literal
#     sub-expressions:
# 38. (K)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 45
#     end_index: 46
# 40. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 41. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. K
#     core type: Variable
#     sub-expressions:
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 49
# 44. _a -> V_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 50
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 49. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 54
# 50. V_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. V
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
