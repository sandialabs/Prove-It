# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, V, s
from proveit.core_expr_types import Q__b_1_to_j, a_1_to_i, b_1_to_j, c_1_to_k, f__b_1_to_j
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import Equals, Forall, Implies, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(s, sub_expr1)
sub_expr3 = ScalarMult(sub_expr2, f__b_1_to_j)
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(a_1_to_i, sub_expr3, c_1_to_k), V), condition = Q__b_1_to_j), Equals(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, TensorProd(a_1_to_i, f__b_1_to_j, c_1_to_k)), condition = Q__b_1_to_j), TensorProd(a_1_to_i, VecSum(index_or_indices = sub_expr1, summand = sub_expr3, condition = Q__b_1_to_j), c_1_to_k)).with_wrapping_at(1)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \in V\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} f\left(b_{1}, b_{2}, \ldots, b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right)\right)\right] \\  = \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right)\right]{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V), [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})), a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).
#    core type: Lambda
#    parameters: 48\n   body: 12
# 10. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 21
#     operand: 16
# 11. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 33
#     operands: 14
# 12. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 15
#     condition: 32
# 13. ((b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. (a_{1}, a_{2}, ..., a_{i}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j})),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 17, 39
# 15. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 48\n    body: 20
# 17. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))
#     core type: Operation
#     operator: 21
#     operand: 26
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, V)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 25
#     condition: 32
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. ((b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 33
#     operands: 27
# 24. V
#     core type: Variable
#     sub-expressions:
# 25. s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 35
#     operands: 28
# 26. (b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 48\n    body: 29
# 27. (a_{1}, a_{2}, ..., a_{i}, s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 31, 39
# 28. (s(b_{1}, b_{2}, ..., b_{j}), a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 30
# 29. {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 37
#     operands: 48
# 33. otimes
#     core type: Literal
#     sub-expressions:
# 34. (a_{1}, a_{2}, ..., a_{i}, f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 41, 39
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (s(b_{1}, b_{2}, ..., b_{j}), f(b_{1}, b_{2}, ..., b_{j}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 55
#     end_index: 43
# 39. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 45
# 40. s(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 46
#     operands: 48
# 41. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 49
# 43. i
#     core type: Variable
#     sub-expressions:
# 44. _a -> c_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 50
# 45. k
#     core type: Variable
#     sub-expressions:
# 46. s
#     core type: Variable
#     sub-expressions:
# 47. f
#     core type: Variable
#     sub-expressions:
# 48. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 51
# 49. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 60
# 50. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 60
# 51. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. _a -> b_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 57
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. j
#     core type: Variable
#     sub-expressions:
# 57. b_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 58. b
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
