# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, U, V, Variable, W, i, j, k
from proveit.core_expr_types import U_1_to_i, V_1_to_j, W_1_to_k, a_1_to_i, b_1_to_j, c_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = VecSpaces(K)
expr = Conditional(Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, TensorProd(b_1_to_j), c_1_to_k), TensorProd(a_1_to_i, b_1_to_j, c_1_to_k)).with_wrapping_at(1), domains = [U_1_to_i, V_1_to_j, W_1_to_k]).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(U, sub_expr1), sub_expr2), one, i), ExprRange(sub_expr1, InClass(IndexedVar(V, sub_expr1), sub_expr2), one, j), ExprRange(sub_expr1, InClass(IndexedVar(W, sub_expr1), sub_expr2), one, k)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(b_{1} \in V_{1}\right), \left(b_{2} \in V_{2}\right), \ldots, \left(b_{j} \in V_{j}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right)\end{array} \textrm{ if } \left(U_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(U_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(U_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(V_{j} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K))and (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{j} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 21
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)),(V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#    core type: Lambda
#    parameters: 34\n   body: 10
# 7. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 64
#    end_index: 50
# 8. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 64
#    end_index: 65
# 9. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 64
#    end_index: 52
# 10. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 74
#     body: 16
# 12. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 74
#     body: 17
# 13. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 74
#     body: 18
# 14. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (b_{1} in V_{1}) and  (b_{2} in V_{2}) and  ... and  (b_{j} in V_{j})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 23
# 17. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 24
# 18. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31
# 23. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 59, 32
# 24. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 60, 32
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 62, 32
# 27. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 47
#     operands: 33
# 28. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 47
#     operands: 34
# 29. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 64
#     end_index: 50
# 30. (b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 64
#     end_index: 65
# 31. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 64
#     end_index: 52
# 32. VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operand: 46
# 33. (a_{1}, a_{2}, ..., a_{i}, b_{1} otimes  b_{2} otimes  ... otimes  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 40, 42
# 34. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 57, 42
# 35. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 74
#     body: 43
# 36. _a -> (b_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 74
#     body: 44
# 37. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 74
#     body: 45
# 38. VecSpaces
#     core type: Literal
#     sub-expressions:
# 39. (K)
#     core type: ExprTuple
#     sub-expressions: 46
# 40. b_{1} otimes  b_{2} otimes  ... otimes  b_{j}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 64
#     end_index: 50
# 42. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 64
#     end_index: 52
# 43. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 55
#     operands: 53
# 44. b_{_a} in V_{_a}
#     core type: Operation
#     operator: 55
#     operands: 54
# 45. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 46. K
#     core type: Variable
#     sub-expressions:
# 47. otimes
#     core type: Literal
#     sub-expressions:
# 48. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 57
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 58
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. _a -> c_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 61
# 52. k
#     core type: Variable
#     sub-expressions:
# 53. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. (b_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 71, 60
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 64
#     end_index: 65
# 58. a_{_a}
#     core type: IndexedVar
# variable: 66
# index: 74
# 59. U_{_a}
#     core type: IndexedVar
# variable: 67
# index: 74
# 60. V_{_a}
#     core type: IndexedVar
# variable: 68
# index: 74
# 61. c_{_a}
#     core type: IndexedVar
# variable: 69
# index: 74
# 62. W_{_a}
#     core type: IndexedVar
# variable: 70
# index: 74
# 63. _a -> b_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 71
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. j
#     core type: Variable
#     sub-expressions:
# 66. a
#     core type: Variable
#     sub-expressions:
# 67. U
#     core type: Variable
#     sub-expressions:
# 68. V
#     core type: Variable
#     sub-expressions:
# 69. c
#     core type: Variable
#     sub-expressions:
# 70. W
#     core type: Variable
#     sub-expressions:
# 71. b_{_a}
#     core type: IndexedVar
# variable: 72
# index: 74
# 72. b
#     core type: Variable
#     sub-expressions:
# 73. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. _a
#     core type: Variable
#     sub-expressions:
