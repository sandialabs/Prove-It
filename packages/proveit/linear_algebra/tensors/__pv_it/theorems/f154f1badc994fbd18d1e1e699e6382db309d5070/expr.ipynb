# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, b
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [U_1_to_i, V, W_1_to_k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k], instance_expr = Forall(instance_param_or_params = [b], instance_expr = Implies(Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, e_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, b, e_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping(), domain = VecSpaces(K)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(e_{1} \in W_{1}\right), \left(e_{2} \in W_{2}\right), \ldots, \left(e_{k} \in W_{k}\right)}~\\
# \left[\forall_{b \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} b{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]
#    core type: Operation
#    operator: 26
#    operand: 2
# 1. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 5, 64, 6
# 4. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 7
#    condition: 8
# 5. U_{1}, U_{2}, ..., U_{i}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 91
#    end_index: 89
# 6. W_{1}, W_{2}, ..., W_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 91
#    end_index: 92
# 7. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]
#    core type: Operation
#    operator: 26
#    operand: 13
# 8. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 28
#    operands: 12
# 9. _a -> U_{_a}
#    core type: Lambda
#    parameter: 102
#    body: 65
# 10. _a -> W_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 66
# 11. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 13. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 14. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 91
#     end_index: 89
# 15. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 31
#     operands: 20
# 16. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 91
#     end_index: 92
# 17. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 81, 82, 83, 85
# 18. {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 19. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 102
#     body: 24
# 20. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 64, 38
# 21. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 102
#     body: 25
# 22. forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))
#     core type: Operation
#     operator: 26
#     operand: 33
# 23. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (e_{1} in W_{1}) and  (e_{2} in W_{2}) and  ... and  (e_{k} in W_{k})
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. forall
#     core type: Literal
#     sub-expressions:
# 27. (b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.)
#     core type: ExprTuple
#     sub-expressions: 33
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36, 37
# 30. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 65, 38
# 31. in_c
#     core type: Literal
#     sub-expressions:
# 32. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 66, 38
# 33. b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Lambda
#     parameter: 84
#     body: 40
# 34. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 91
#     end_index: 89
# 35. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 91
#     end_index: 92
# 36. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 91
#     end_index: 89
# 37. (e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 91
#     end_index: 92
# 38. VecSpaces(K)
#     core type: Operation
#     operator: 45
#     operand: 53
# 39. (b)
#     core type: ExprTuple
#     sub-expressions: 84
# 40. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Conditional
#     value: 47
#     condition: 48
# 41. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 102
#     body: 49
# 42. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 102
#     body: 50
# 43. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 102
#     body: 51
# 44. _a -> (e_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 102
#     body: 52
# 45. VecSpaces
#     core type: Literal
#     sub-expressions:
# 46. (K)
#     core type: ExprTuple
#     sub-expressions: 53
# 47. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. b in V
#     core type: Operation
#     operator: 60
#     operands: 56
# 49. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 60
#     operands: 57
# 50. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 60
#     operands: 58
# 51. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 60
#     operands: 59
# 52. e_{_a} in W_{_a}
#     core type: Operation
#     operator: 60
#     operands: 61
# 53. K
#     core type: Variable
#     sub-expressions:
# 54. =>
#     core type: Literal
#     sub-expressions:
# 55. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 56. (b, V)
#     core type: ExprTuple
#     sub-expressions: 84, 64
# 57. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 93, 65
# 58. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 94, 66
# 59. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 95, 65
# 60. in
#     core type: Literal
#     sub-expressions:
# 61. (e_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 96, 66
# 62. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 68
#     operands: 67
# 63. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. V
#     core type: Variable
#     sub-expressions:
# 65. U_{_a}
#     core type: IndexedVar
# variable: 70
# index: 102
# 66. W_{_a}
#     core type: IndexedVar
# variable: 71
# index: 102
# 67. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. =
#     core type: Literal
#     sub-expressions:
# 69. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 70. U
#     core type: Variable
#     sub-expressions:
# 71. W
#     core type: Variable
#     sub-expressions:
# 72. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 79
#     operands: 76
# 73. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 79
#     operands: 77
# 74. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 79
#     operands: 78
# 75. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 79
#     operands: 80
# 76. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 77. (d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 83, 85
# 78. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 81, 84, 82
# 79. otimes
#     core type: Literal
#     sub-expressions:
# 80. (d_{1}, d_{2}, ..., d_{i}, b,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 83, 84, 85
# 81. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 86
#     start_index: 91
#     end_index: 89
# 82. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 87
#     start_index: 91
#     end_index: 92
# 83. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 88
#     start_index: 91
#     end_index: 89
# 84. b
#     core type: Variable
#     sub-expressions:
# 85. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 91
#     end_index: 92
# 86. _a -> a_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 93
# 87. _a -> c_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 94
# 88. _a -> d_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 95
# 89. i
#     core type: Variable
#     sub-expressions:
# 90. _a -> e_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 96
# 91. 1
#     core type: Literal
#     sub-expressions:
# 92. k
#     core type: Variable
#     sub-expressions:
# 93. a_{_a}
#     core type: IndexedVar
# variable: 97
# index: 102
# 94. c_{_a}
#     core type: IndexedVar
# variable: 98
# index: 102
# 95. d_{_a}
#     core type: IndexedVar
# variable: 99
# index: 102
# 96. e_{_a}
#     core type: IndexedVar
# variable: 100
# index: 102
# 97. a
#     core type: Variable
#     sub-expressions:
# 98. c
#     core type: Variable
#     sub-expressions:
# 99. d
#     core type: Variable
#     sub-expressions:
# 100. e
#      core type: Variable
#      sub-expressions:
# 101. (_a)
#      core type: ExprTuple
#      sub-expressions: 102
# 102. _a
#      core type: Variable
#      sub-expressions:
