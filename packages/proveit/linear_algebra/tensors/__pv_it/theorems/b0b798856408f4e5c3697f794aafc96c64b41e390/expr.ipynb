# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Lambda, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall
from proveit.numbers import NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Lambda(K, Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), one), domains = sub_expr2, condition = And(ExprRange(sub_expr1, Equals(Norm(IndexedVar(a, sub_expr1)), one), one, i))).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{i \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)~|~\left(\left \|a_{1}\right \| = 1\right) \land  \left(\left \|a_{2}\right \| = 1\right) \land  \ldots \land  \left(\left \|a_{i}\right \| = 1\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = 1\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]]
#    core type: Lambda
#    parameter: 45
#    body: 1
# 1. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]
#    core type: Operation
#    operator: 18
#    operand: 3
# 2. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.
#    core type: Lambda
#    parameter: 55
#    body: 5
# 4. (i)
#    core type: ExprTuple
#    sub-expressions: 55
# 5. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]
#    core type: Operation
#    operator: 18
#    operand: 10
# 7. i in NaturalPos
#    core type: Operation
#    operator: 48
#    operands: 9
# 8. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 55, 11
# 10. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 60
#     end_index: 55
# 15. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 38
#     operands: 20
# 17. _a -> V_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 52
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Lambda
#     parameters: 47\n    body: 23
# 22. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 60
#     end_index: 55
# 23. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 66
#     body: 27
# 25. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1
#     core type: Operation
#     operator: 57
#     operands: 28
# 26. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}) and ((||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: Operation
#     operator: 38
#     operands: 29
# 27. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 60
# 29. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}), (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. in_c
#     core type: Literal
#     sub-expressions:
# 31. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 52, 35
# 32. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 61
#     operand: 42
# 33. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 60
#     end_index: 55
# 34. (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. InnerProdSpaces(K)
#     core type: Operation
#     operator: 40
#     operand: 45
# 36. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 66
#     body: 43
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. ((||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 44
# 40. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 41. (K)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. (||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1)
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 60
#     end_index: 55
# 45. K
#     core type: Variable
#     sub-expressions:
# 46. otimes
#     core type: Literal
#     sub-expressions:
# 47. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 51
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 63, 52
# 50. _a -> (||a_{_a}|| = 1)
#     core type: Lambda
#     parameter: 66
#     body: 53
# 51. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 60
#     end_index: 55
# 52. V_{_a}
#     core type: IndexedVar
# variable: 56
# index: 66
# 53. ||a_{_a}|| = 1
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 63
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. V
#     core type: Variable
#     sub-expressions:
# 57. =
#     core type: Literal
#     sub-expressions:
# 58. (||a_{_a}||, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. ||a_{_a}||
#     core type: Operation
#     operator: 61
#     operand: 63
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. Abs
#     core type: Literal
#     sub-expressions:
# 62. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 63
# 63. a_{_a}
#     core type: IndexedVar
# variable: 64
# index: 66
# 64. a
#     core type: Variable
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
