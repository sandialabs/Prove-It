# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, V, b, e
from proveit.core_expr_types import a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecZero
from proveit.logic import And, Equals, Implies, InSet, NotEquals

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), And(InSet(b, V), InSet(e, V), Equals(b, e), NotEquals(b, VecZero(V))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array} \textrm{ if } b \in V ,  e \in V ,  b = e ,  b \neq \vec{0}\left(V\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (b in V) and (e in V) and (b = e) and (b != 0(V))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (b in V, e in V, b = e, b != 0(V))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#    core type: Operation
#    operator: 18
#    operands: 13
# 8. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#    core type: Operation
#    operator: 18
#    operands: 14
# 9. b in V
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. e in V
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. b = e
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. b != 0(V)
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 14. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 15. (b, V)
#     core type: ExprTuple
#     sub-expressions: 34, 40
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (e, V)
#     core type: ExprTuple
#     sub-expressions: 35, 40
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (b, e)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 20. !=
#     core type: Literal
#     sub-expressions:
# 21. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 34, 26
# 22. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 30
#     operands: 27
# 23. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 30
#     operands: 28
# 24. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 30
#     operands: 29
# 25. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. 0(V)
#     core type: Operation
#     operator: 32
#     operand: 40
# 27. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 34, 37
# 28. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 35, 39
# 29. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. otimes
#     core type: Literal
#     sub-expressions:
# 31. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. (V)
#     core type: ExprTuple
#     sub-expressions: 40
# 34. b
#     core type: Variable
#     sub-expressions:
# 35. e
#     core type: Variable
#     sub-expressions:
# 36. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 46
#     end_index: 44
# 37. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 46
#     end_index: 47
# 38. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 44
# 39. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 40. V
#     core type: Variable
#     sub-expressions:
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 48
# 42. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 49
# 43. _a -> d_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. _a -> f_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 51
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. k
#     core type: Variable
#     sub-expressions:
# 48. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 57
# 49. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 50. d_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 51. f_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. d
#     core type: Variable
#     sub-expressions:
# 55. f
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
