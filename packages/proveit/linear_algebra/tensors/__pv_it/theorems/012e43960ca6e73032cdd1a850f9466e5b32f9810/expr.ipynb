# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Lambda, V, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Lambda(sub_expr2, Conditional(Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), one), domains = sub_expr2, condition = And(ExprRange(sub_expr1, Equals(Norm(IndexedVar(a, sub_expr1)), one), one, i))).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(V, sub_expr1), InnerProdSpaces(K)), one, i))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V_{1}, V_{2}, \ldots, V_{i}\right) \mapsto \left\{\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)~|~\left(\left \|a_{1}\right \| = 1\right) \land  \left(\left \|a_{2}\right \| = 1\right) \land  \ldots \land  \left(\left \|a_{i}\right \| = 1\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = 1\right)\end{array} \textrm{ if } \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right) \land  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right) \land  \ldots \land  \left(V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (V_{1}, V_{2}, ..., V_{i})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. V_{1}, V_{2}, ..., V_{i}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 49
#    end_index: 44
# 4. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)
#    core type: Operation
#    operator: 7
#    operand: 10
# 5. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#    core type: Operation
#    operator: 27
#    operands: 9
# 6. _a -> V_{_a}
#    core type: Lambda
#    parameter: 55
#    body: 41
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Lambda
#     parameters: 36\n    body: 12
# 11. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 49
#     end_index: 44
# 12. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 55
#     body: 16
# 14. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1
#     core type: Operation
#     operator: 46
#     operands: 17
# 15. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}) and ((||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: Operation
#     operator: 27
#     operands: 18
# 16. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 49
# 18. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}), (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. in_c
#     core type: Literal
#     sub-expressions:
# 20. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 41, 24
# 21. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 50
#     operand: 31
# 22. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 49
#     end_index: 44
# 23. (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. InnerProdSpaces(K)
#     core type: Operation
#     operator: 29
#     operand: 34
# 25. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 31
# 26. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 32
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 33
# 29. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 30. (K)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. (||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 49
#     end_index: 44
# 34. K
#     core type: Variable
#     sub-expressions:
# 35. otimes
#     core type: Literal
#     sub-expressions:
# 36. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 41
# 39. _a -> (||a_{_a}|| = 1)
#     core type: Lambda
#     parameter: 55
#     body: 42
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 49
#     end_index: 44
# 41. V_{_a}
#     core type: IndexedVar
# variable: 45
# index: 55
# 42. ||a_{_a}|| = 1
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. V
#     core type: Variable
#     sub-expressions:
# 46. =
#     core type: Literal
#     sub-expressions:
# 47. (||a_{_a}||, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. ||a_{_a}||
#     core type: Operation
#     operator: 50
#     operand: 52
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. Abs
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 52
# 52. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
