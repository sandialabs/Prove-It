# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, K, Q, V, f, i, j, k, s
from proveit.core_expr_types import Q__b_1_to_j, a_1_to_i, b_1_to_j, c_1_to_k, f__b_1_to_j
from proveit.linear_algebra import ScalarMult, TensorProd, VecSpaces, VecSum
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Natural, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(s, sub_expr1)
sub_expr3 = ScalarMult(sub_expr2, f__b_1_to_j)
expr = Forall(instance_param_or_params = [K, f, Q, s], instance_expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(a_1_to_i, sub_expr3, c_1_to_k), V), condition = Q__b_1_to_j), Equals(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, TensorProd(a_1_to_i, f__b_1_to_j, c_1_to_k)), condition = Q__b_1_to_j), TensorProd(a_1_to_i, VecSum(index_or_indices = sub_expr1, summand = sub_expr3, condition = Q__b_1_to_j), c_1_to_k)).with_wrapping_at(1)).with_wrapping_at(2)).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), domains = [Natural, NaturalPos, Natural]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K, f, Q, s}~\left[\forall_{i \in \mathbb{N}, j \in \mathbb{N}^+, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left[\forall_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \in V\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} f\left(b_{1}, b_{2}, \ldots, b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right)\right)\right] \\  = \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(s\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right)\right]{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K, f, Q, s} [forall_{i in Natural, j in NaturalPos, k in Natural} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]]
#    core type: Operation
#    operator: 41
#    operand: 2
# 1. ((K, f, Q, s) -> [forall_{i in Natural, j in NaturalPos, k in Natural} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (K, f, Q, s) -> [forall_{i in Natural, j in NaturalPos, k in Natural} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (K, f, Q, s)
#    core type: ExprTuple
#    sub-expressions: 38, 83, 73, 82
# 4. forall_{i in Natural, j in NaturalPos, k in Natural} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]
#    core type: Operation
#    operator: 41
#    operand: 6
# 5. ((i, j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  j in NaturalPos ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (i, j, k) -> {forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  j in NaturalPos ,  k in Natural.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 7. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 79, 92, 81
# 8. {forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  j in NaturalPos ,  k in Natural.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]
#    core type: Operation
#    operator: 41
#    operand: 14
# 10. (i in Natural) and (j in NaturalPos) and (k in Natural)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (V -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if V in_c VecSpaces(K).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (i in Natural, j in NaturalPos, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 14. V -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 60
#     body: 19
# 15. i in Natural
#     core type: Operation
#     operator: 54
#     operands: 20
# 16. j in NaturalPos
#     core type: Operation
#     operator: 54
#     operands: 21
# 17. k in Natural
#     core type: Operation
#     operator: 54
#     operands: 22
# 18. (V)
#     core type: ExprTuple
#     sub-expressions: 60
# 19. {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 79, 26
# 21. (j, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 92, 25
# 22. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 81, 26
# 23. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))
#     core type: Operation
#     operator: 41
#     operand: 30
# 24. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. NaturalPos
#     core type: Literal
#     sub-expressions:
# 26. Natural
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))))
#     core type: ExprTuple
#     sub-expressions: 30
# 28. in_c
#     core type: Literal
#     sub-expressions:
# 29. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 60, 31
# 30. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))
#     core type: Lambda
#     parameters: 32\n    body: 33
# 31. VecSpaces(K)
#     core type: Operation
#     operator: 34
#     operand: 38
# 32. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 33. [forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. VecSpaces
#     core type: Literal
#     sub-expressions:
# 35. (K)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. =>
#     core type: Literal
#     sub-expressions:
# 37. (forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V), [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. K
#     core type: Variable
#     sub-expressions:
# 39. forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V)
#     core type: Operation
#     operator: 41
#     operand: 45
# 40. [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. forall
#     core type: Literal
#     sub-expressions:
# 42. ((b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})), a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. (b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 84\n    body: 48
# 46. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 57
#     operand: 52
# 47. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))]otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 69
#     operands: 50
# 48. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 51
#     condition: 68
# 49. ((b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. (a_{1}, a_{2}, ..., a_{i}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j})),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 53, 75
# 51. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) in V
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. (b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 84\n    body: 56
# 53. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))
#     core type: Operation
#     operator: 57
#     operand: 62
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, V)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 56. {s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 61
#     condition: 68
# 57. Sum
#     core type: Literal
#     sub-expressions:
# 58. ((b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 62
# 59. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}))otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 69
#     operands: 63
# 60. V
#     core type: Variable
#     sub-expressions:
# 61. s(b_{1}, b_{2}, ..., b_{j}) * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 71
#     operands: 64
# 62. (b_{1}, b_{2}, ..., b_{j}) -> {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 84\n    body: 65
# 63. (a_{1}, a_{2}, ..., a_{i}, s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 67, 75
# 64. (s(b_{1}, b_{2}, ..., b_{j}), a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 76, 66
# 65. {s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 67
#     condition: 68
# 66. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes f(b_{1}, b_{2}, ..., b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. s(b_{1}, b_{2}, ..., b_{j}) * f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 73
#     operands: 84
# 69. otimes
#     core type: Literal
#     sub-expressions:
# 70. (a_{1}, a_{2}, ..., a_{i}, f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 77, 75
# 71. *
#     core type: Literal
#     sub-expressions:
# 72. (s(b_{1}, b_{2}, ..., b_{j}), f(b_{1}, b_{2}, ..., b_{j}))
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 73. Q
#     core type: Variable
#     sub-expressions:
# 74. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 91
#     end_index: 79
# 75. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 80
#     start_index: 91
#     end_index: 81
# 76. s(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 82
#     operands: 84
# 77. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 83
#     operands: 84
# 78. _a -> a_{_a}
#     core type: Lambda
#     parameter: 96
#     body: 85
# 79. i
#     core type: Variable
#     sub-expressions:
# 80. _a -> c_{_a}
#     core type: Lambda
#     parameter: 96
#     body: 86
# 81. k
#     core type: Variable
#     sub-expressions:
# 82. s
#     core type: Variable
#     sub-expressions:
# 83. f
#     core type: Variable
#     sub-expressions:
# 84. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 87
# 85. a_{_a}
#     core type: IndexedVar
# variable: 88
# index: 96
# 86. c_{_a}
#     core type: IndexedVar
# variable: 89
# index: 96
# 87. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 91
#     end_index: 92
# 88. a
#     core type: Variable
#     sub-expressions:
# 89. c
#     core type: Variable
#     sub-expressions:
# 90. _a -> b_{_a}
#     core type: Lambda
#     parameter: 96
#     body: 93
# 91. 1
#     core type: Literal
#     sub-expressions:
# 92. j
#     core type: Variable
#     sub-expressions:
# 93. b_{_a}
#     core type: IndexedVar
# variable: 94
# index: 96
# 94. b
#     core type: Variable
#     sub-expressions:
# 95. (_a)
#     core type: ExprTuple
#     sub-expressions: 96
# 96. _a
#     core type: Variable
#     sub-expressions:
