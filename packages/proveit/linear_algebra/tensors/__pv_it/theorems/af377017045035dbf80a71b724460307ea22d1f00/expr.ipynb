# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import V, b, e
from proveit.core_expr_types import a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecZero
from proveit.logic import Equals, Forall, Implies, NotEquals

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [b, e], instance_expr = Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V, conditions = [Equals(b, e), NotEquals(b, VecZero(V))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{b, e \in V~|~b = e, b \neq \vec{0}\left(V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Lambda
#    parameters: 23\n   body: 4
# 4. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (b in V) and (e in V) and (b = e) and (b != 0(V))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (b in V, e in V, b = e, b != 0(V))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 22
#     operands: 17
# 12. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 22
#     operands: 18
# 13. b in V
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. e in V
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. b = e
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. b != 0(V)
#     core type: Operation
#     operator: 24
#     operands: 25
# 17. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 18. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 19. (b, V)
#     core type: ExprTuple
#     sub-expressions: 38, 44
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (e, V)
#     core type: ExprTuple
#     sub-expressions: 39, 44
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (b, e)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 24. !=
#     core type: Literal
#     sub-expressions:
# 25. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 38, 30
# 26. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 34
#     operands: 31
# 27. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 34
#     operands: 32
# 28. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. 0(V)
#     core type: Operation
#     operator: 36
#     operand: 44
# 31. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 38, 41
# 32. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 42, 39, 43
# 33. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 34. otimes
#     core type: Literal
#     sub-expressions:
# 35. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. (V)
#     core type: ExprTuple
#     sub-expressions: 44
# 38. b
#     core type: Variable
#     sub-expressions:
# 39. e
#     core type: Variable
#     sub-expressions:
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 48
# 41. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 50
#     end_index: 51
# 42. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 43. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 52
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 53
# 47. _a -> d_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. _a -> f_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 55
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. a_{_a}
#     core type: IndexedVar
# variable: 56
# index: 61
# 53. c_{_a}
#     core type: IndexedVar
# variable: 57
# index: 61
# 54. d_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 55. f_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. d
#     core type: Variable
#     sub-expressions:
# 59. f
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
