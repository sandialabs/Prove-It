# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, Function, IndexedVar, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(A, sub_expr1)
expr = Conditional(Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(sub_expr2, [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), And(ExprRange(sub_expr1, InSet(sub_expr2, LinMap(IndexedVar(V, sub_expr1), IndexedVar(W, sub_expr1))), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array} \textrm{ if } \left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right) \land  \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right) \land  \ldots \land  \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#    core type: Lambda
#    parameters: 35\n   body: 8
# 7. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 45
#    end_index: 46
# 8. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#    core type: Lambda
#    parameter: 54
#    body: 12
# 10. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 37
#     operands: 17
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 20
# 17. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 47, 21
# 18. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 22
#     operand: 29
# 19. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 34
#     operands: 24
# 20. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 45
#     end_index: 46
# 21. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 34
#     operands: 28
# 23. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 24. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 30
# 25. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 54
#     body: 31
# 26. LINMAP
#     core type: Literal
#     sub-expressions:
# 27. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 43, 32
# 28. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 29. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 45
#     end_index: 46
# 31. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. W_{_a}
#     core type: IndexedVar
# variable: 39
# index: 54
# 33. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 45
#     end_index: 46
# 34. otimes
#     core type: Literal
#     sub-expressions:
# 35. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 54
#     body: 42
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 51, 43
# 39. W
#     core type: Variable
#     sub-expressions:
# 40. _a -> A_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 47
# 41. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 42. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 47
#     operand: 51
# 43. V_{_a}
#     core type: IndexedVar
# variable: 49
# index: 54
# 44. _a -> v_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 51
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. A_{_a}
#     core type: IndexedVar
# variable: 50
# index: 54
# 48. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 51
# 49. V
#     core type: Variable
#     sub-expressions:
# 50. A
#     core type: Variable
#     sub-expressions:
# 51. v_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 52. v
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
