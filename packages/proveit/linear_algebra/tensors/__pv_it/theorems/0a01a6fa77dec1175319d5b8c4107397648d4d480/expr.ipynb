# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, Function, IndexedVar, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [A_1_to_n], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(IndexedVar(A, sub_expr1), [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), domains = [ExprRange(sub_expr1, LinMap(IndexedVar(V, sub_expr1), IndexedVar(W, sub_expr1)), one, n)]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#    core type: Lambda
#    parameters: 31\n   body: 3
# 3. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#    core type: Operation
#    operator: 18
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#    core type: Lambda
#    parameters: 38\n   body: 11
# 10. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 48
#     end_index: 49
# 11. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 57
#     body: 15
# 13. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 40
#     operands: 20
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 50, 24
# 21. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 25
#     operand: 32
# 22. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 37
#     operands: 27
# 23. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 48
#     end_index: 49
# 24. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 37
#     operands: 31
# 26. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 27. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 33
# 28. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 34
# 29. LINMAP
#     core type: Literal
#     sub-expressions:
# 30. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 46, 35
# 31. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 48
#     end_index: 49
# 34. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. W_{_a}
#     core type: IndexedVar
# variable: 42
# index: 57
# 36. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 48
#     end_index: 49
# 37. otimes
#     core type: Literal
#     sub-expressions:
# 38. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 39. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 45
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 54, 46
# 42. W
#     core type: Variable
#     sub-expressions:
# 43. _a -> A_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 44. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 45. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 50
#     operand: 54
# 46. V_{_a}
#     core type: IndexedVar
# variable: 52
# index: 57
# 47. _a -> v_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. A_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 51. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 52. V
#     core type: Variable
#     sub-expressions:
# 53. A
#     core type: Variable
#     sub-expressions:
# 54. v_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. v
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
