# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#tensor_prod_is_in_tensor_prod_space">tensor_prod_is_in_tensor_prod_space</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.tensors import tensor_prod_is_in_tensor_prod_space

# %%
# check that the built expression is the same as the stored expression
assert tensor_prod_is_in_tensor_prod_space.expr == stored_expr
assert tensor_prod_is_in_tensor_prod_space.expr._style_id == stored_expr._style_id
print("Passed sanity check: tensor_prod_is_in_tensor_prod_space matches stored_expr")
# Out:
# Passed sanity check: tensor_prod_is_in_tensor_prod_space matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{i \in \mathbb{N}^+}~\left[\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right) \in \left(V_{1} {\otimes}  V_{2} {\otimes}  \ldots {\otimes}  V_{i}\right)\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]]
#    core type: Lambda
#    parameter: 45
#    body: 3
# 3. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]
#    core type: Operation
#    operator: 17
#    operand: 5
# 4. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 49
#    body: 7
# 6. (i)
#    core type: ExprTuple
#    sub-expressions: 49
# 7. {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]
#    core type: Operation
#    operator: 17
#    operand: 12
# 9. i in NaturalPos
#    core type: Operation
#    operator: 50
#    operands: 11
# 10. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 49, 13
# 12. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 38\n    body: 14
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K))
#     core type: Operation
#     operator: 28
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 36\n    body: 22
# 21. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 48
#     end_index: 49
# 22. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 24
#     condition: 25
# 23. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 57
#     body: 26
# 24. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: Operation
#     operator: 50
#     operands: 27
# 25. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}, V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 34
# 30. in_c
#     core type: Literal
#     sub-expressions:
# 31. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 53, 35
# 32. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. V_{1} otimes  V_{2} otimes  ... otimes  V_{i}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 48
#     end_index: 49
# 35. VecSpaces(K)
#     core type: Operation
#     operator: 40
#     operand: 45
# 36. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. otimes
#     core type: Literal
#     sub-expressions:
# 38. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 43
# 39. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 44
# 40. VecSpaces
#     core type: Literal
#     sub-expressions:
# 41. (K)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 48
#     end_index: 49
# 43. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 44. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 45. K
#     core type: Variable
#     sub-expressions:
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 47. _a -> V_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. i
#     core type: Variable
#     sub-expressions:
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 53. V_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. V
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
