# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, alpha, b, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k
from proveit.linear_algebra import ScalarMult, TensorProd, VecSpaces
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [U_1_to_i, V, W_1_to_k]
expr = ExprTuple(Lambda(alpha, Conditional(Forall(instance_param_or_params = [i, k], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, ScalarMult(alpha, b), c_1_to_k), ScalarMult(alpha, TensorProd(a_1_to_i, b, c_1_to_k))).with_wrapping_at(1), domains = sub_expr1).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), domain = Natural), InSet(alpha, K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\alpha \mapsto \left\{\forall_{i, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right), b \in V,\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(\alpha \cdot b\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(\alpha \cdot \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right)\right) \end{array} \end{array}\right)\end{array}\right]\end{array}\right] \textrm{ if } \alpha \in K\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (alpha -> {forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]] if alpha in K.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. alpha -> {forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]] if alpha in K.
#    core type: Lambda
#    parameter: 77
#    body: 3
# 2. (alpha)
#    core type: ExprTuple
#    sub-expressions: 77
# 3. {forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]] if alpha in K.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]
#    core type: Operation
#    operator: 29
#    operand: 8
# 5. alpha in K
#    core type: Operation
#    operator: 75
#    operands: 7
# 6. ((i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (alpha, K)
#    core type: ExprTuple
#    sub-expressions: 77, 69
# 8. (i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 9. (i, k)
#    core type: ExprTuple
#    sub-expressions: 84, 87
# 10. {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]
#     core type: Operation
#     operator: 29
#     operand: 15
# 12. (i in Natural) and (k in Natural)
#     core type: Operation
#     operator: 46
#     operands: 14
# 13. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (i in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 18\n    body: 19
# 16. i in Natural
#     core type: Operation
#     operator: 75
#     operands: 20
# 17. k in Natural
#     core type: Operation
#     operator: 75
#     operands: 21
# 18. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 67, 23
# 19. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 24
#     condition: 25
# 20. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 84, 26
# 21. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 87, 26
# 22. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 86
#     end_index: 84
# 23. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 86
#     end_index: 87
# 24. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))
#     core type: Operation
#     operator: 29
#     operand: 32
# 25. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 46
#     operands: 31
# 26. Natural
#     core type: Literal
#     sub-expressions:
# 27. _a -> U_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 81
# 28. _a -> W_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 82
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 33, 34, 35
# 32. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 73\n    body: 36
# 33. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 86
#     end_index: 84
# 34. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 49
#     operands: 38
# 35. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 86
#     end_index: 87
# 36. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 40
#     condition: 41
# 37. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 95
#     body: 42
# 38. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 67, 56
# 39. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 95
#     body: 43
# 40. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i}) and (b in V)and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 49
#     operands: 48
# 43. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55
# 48. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 81, 56
# 49. in_c
#     core type: Literal
#     sub-expressions:
# 50. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 82, 56
# 51. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 72
#     operands: 57
# 52. alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 70
#     operands: 58
# 53. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 86
#     end_index: 84
# 54. b in V
#     core type: Operation
#     operator: 75
#     operands: 60
# 55. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 86
#     end_index: 87
# 56. VecSpaces(K)
#     core type: Operation
#     operator: 62
#     operand: 69
# 57. (a_{1}, a_{2}, ..., a_{i}, alpha * b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 78, 64, 80
# 58. (alpha, a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 77, 65
# 59. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 95
#     body: 66
# 60. (b, V)
#     core type: ExprTuple
#     sub-expressions: 79, 67
# 61. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 95
#     body: 68
# 62. VecSpaces
#     core type: Literal
#     sub-expressions:
# 63. (K)
#     core type: ExprTuple
#     sub-expressions: 69
# 64. alpha * b
#     core type: Operation
#     operator: 70
#     operands: 71
# 65. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 72
#     operands: 73
# 66. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 75
#     operands: 74
# 67. V
#     core type: Variable
#     sub-expressions:
# 68. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 75
#     operands: 76
# 69. K
#     core type: Variable
#     sub-expressions:
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (alpha, b)
#     core type: ExprTuple
#     sub-expressions: 77, 79
# 72. otimes
#     core type: Literal
#     sub-expressions:
# 73. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 78, 79, 80
# 74. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 90, 81
# 75. in
#     core type: Literal
#     sub-expressions:
# 76. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 91, 82
# 77. alpha
#     core type: Variable
#     sub-expressions:
# 78. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 86
#     end_index: 84
# 79. b
#     core type: Variable
#     sub-expressions:
# 80. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 85
#     start_index: 86
#     end_index: 87
# 81. U_{_a}
#     core type: IndexedVar
# variable: 88
# index: 95
# 82. W_{_a}
#     core type: IndexedVar
# variable: 89
# index: 95
# 83. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 90
# 84. i
#     core type: Variable
#     sub-expressions:
# 85. _a -> c_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 91
# 86. 1
#     core type: Literal
#     sub-expressions:
# 87. k
#     core type: Variable
#     sub-expressions:
# 88. U
#     core type: Variable
#     sub-expressions:
# 89. W
#     core type: Variable
#     sub-expressions:
# 90. a_{_a}
#     core type: IndexedVar
# variable: 92
# index: 95
# 91. c_{_a}
#     core type: IndexedVar
# variable: 93
# index: 95
# 92. a
#     core type: Variable
#     sub-expressions:
# 93. c
#     core type: Variable
#     sub-expressions:
# 94. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 95. _a
#     core type: Variable
#     sub-expressions:
