# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), one), domains = sub_expr2, condition = And(ExprRange(sub_expr1, Equals(Norm(IndexedVar(a, sub_expr1)), one), one, i))).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)~|~\left(\left \|a_{1}\right \| = 1\right) \land  \left(\left \|a_{2}\right \| = 1\right) \land  \ldots \land  \left(\left \|a_{i}\right \| = 1\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = 1\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (V_{1}, V_{2}, ..., V_{i})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. V_{1}, V_{2}, ..., V_{i}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 51
#    end_index: 46
# 6. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#    core type: Operation
#    operator: 29
#    operands: 11
# 8. _a -> V_{_a}
#    core type: Lambda
#    parameter: 57
#    body: 43
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Lambda
#     parameters: 38\n    body: 14
# 13. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 51
#     end_index: 46
# 14. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 57
#     body: 18
# 16. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1
#     core type: Operation
#     operator: 48
#     operands: 19
# 17. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}) and ((||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: Operation
#     operator: 29
#     operands: 20
# 18. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 51
# 20. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}), (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. in_c
#     core type: Literal
#     sub-expressions:
# 22. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 43, 26
# 23. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 52
#     operand: 33
# 24. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 51
#     end_index: 46
# 25. (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. InnerProdSpaces(K)
#     core type: Operation
#     operator: 31
#     operand: 36
# 27. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 34
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. ((||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 35
# 31. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 32. (K)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. (||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1)
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 51
#     end_index: 46
# 36. K
#     core type: Variable
#     sub-expressions:
# 37. otimes
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 42
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 54, 43
# 41. _a -> (||a_{_a}|| = 1)
#     core type: Lambda
#     parameter: 57
#     body: 44
# 42. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 51
#     end_index: 46
# 43. V_{_a}
#     core type: IndexedVar
# variable: 47
# index: 57
# 44. ||a_{_a}|| = 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. V
#     core type: Variable
#     sub-expressions:
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (||a_{_a}||, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. ||a_{_a}||
#     core type: Operation
#     operator: 52
#     operand: 54
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. Abs
#     core type: Literal
#     sub-expressions:
# 53. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 54. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
