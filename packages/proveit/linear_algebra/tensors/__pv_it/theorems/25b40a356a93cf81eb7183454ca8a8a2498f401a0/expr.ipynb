# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [V_1_to_i]
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = InSet(TensorProd(a_1_to_i), TensorProd(V_1_to_i)), domains = sub_expr1), domain = VecSpaces(K)), domain = NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{i \in \mathbb{N}^+}~\left[\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right) \in \left(V_{1} {\otimes}  V_{2} {\otimes}  \ldots {\otimes}  V_{i}\right)\right)\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]]
#    core type: Lambda
#    parameter: 44
#    body: 2
# 2. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]
#    core type: Operation
#    operator: 16
#    operand: 4
# 3. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 48
#    body: 6
# 5. (i)
#    core type: ExprTuple
#    sub-expressions: 48
# 6. {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]
#    core type: Operation
#    operator: 16
#    operand: 11
# 8. i in NaturalPos
#    core type: Operation
#    operator: 49
#    operands: 10
# 9. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (i, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 48, 12
# 11. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 37\n    body: 13
# 12. NaturalPos
#     core type: Literal
#     sub-expressions:
# 13. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K))
#     core type: Operation
#     operator: 27
#     operands: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 35\n    body: 21
# 20. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 47
#     end_index: 48
# 21. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 56
#     body: 25
# 23. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: Operation
#     operator: 49
#     operands: 26
# 24. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}, V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 33
# 29. in_c
#     core type: Literal
#     sub-expressions:
# 30. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 52, 34
# 31. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 36
#     operands: 35
# 32. V_{1} otimes  V_{2} otimes  ... otimes  V_{i}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 47
#     end_index: 48
# 34. VecSpaces(K)
#     core type: Operation
#     operator: 39
#     operand: 44
# 35. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. otimes
#     core type: Literal
#     sub-expressions:
# 37. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 56
#     body: 43
# 39. VecSpaces
#     core type: Literal
#     sub-expressions:
# 40. (K)
#     core type: ExprTuple
#     sub-expressions: 44
# 41. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 47
#     end_index: 48
# 42. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 43. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. K
#     core type: Variable
#     sub-expressions:
# 45. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 51
# 46. _a -> V_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 52. V_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. V
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
