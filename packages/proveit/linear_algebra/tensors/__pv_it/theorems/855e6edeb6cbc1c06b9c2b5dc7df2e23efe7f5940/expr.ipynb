# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K
from proveit.core_expr_types import U_1_to_i, V_1_to_j, W_1_to_k, a_1_to_i, b_1_to_j, c_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
sub_expr1 = [U_1_to_i, V_1_to_j, W_1_to_k]
expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, b_1_to_j, c_1_to_k), TensorProd(a_1_to_i, TensorProd(b_1_to_j), c_1_to_k)).with_wrapping_at(2), domains = sub_expr1).with_wrapping(), domain = VecSpaces(K)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(b_{1} \in V_{1}\right), \left(b_{2} \in V_{2}\right), \ldots, \left(b_{j} \in V_{j}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]
#    core type: Operation
#    operator: 13
#    operand: 2
# 1. ((U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j},W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 8
#    condition: 9
# 5. U_{1}, U_{2}, ..., U_{i}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 74
#    end_index: 58
# 6. V_{1}, V_{2}, ..., V_{j}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 74
#    end_index: 75
# 7. W_{1}, W_{2}, ..., W_{k}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 74
#    end_index: 62
# 8. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#    core type: Operation
#    operator: 13
#    operand: 16
# 9. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K))and (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{j} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 31
#    operands: 15
# 10. _a -> U_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 69
# 11. _a -> V_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 70
# 12. _a -> W_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 72
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)),(V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 16. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 43\n    body: 20
# 17. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 74
#     end_index: 58
# 18. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 74
#     end_index: 75
# 19. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 74
#     end_index: 62
# 20. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 84
#     body: 26
# 22. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 84
#     body: 27
# 23. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 84
#     body: 28
# 24. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (b_{1} in V_{1}) and  (b_{2} in V_{2}) and  ... and  (b_{j} in V_{j})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 35
#     operands: 33
# 27. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 35
#     operands: 34
# 28. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41
# 33. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 69, 42
# 34. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 70, 42
# 35. in_c
#     core type: Literal
#     sub-expressions:
# 36. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 72, 42
# 37. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 59
#     operands: 43
# 38. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 59
#     operands: 44
# 39. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 74
#     end_index: 58
# 40. (b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j})
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 74
#     end_index: 75
# 41. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 74
#     end_index: 62
# 42. VecSpaces(K)
#     core type: Operation
#     operator: 48
#     operand: 56
# 43. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 50, 67, 52
# 44. (a_{1}, a_{2}, ..., a_{i}, b_{1} otimes  b_{2} otimes  ... otimes  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52
# 45. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 53
# 46. _a -> (b_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 54
# 47. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 55
# 48. VecSpaces
#     core type: Literal
#     sub-expressions:
# 49. (K)
#     core type: ExprTuple
#     sub-expressions: 56
# 50. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 74
#     end_index: 58
# 51. b_{1} otimes  b_{2} otimes  ... otimes  b_{j}
#     core type: Operation
#     operator: 59
#     operands: 60
# 52. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 74
#     end_index: 62
# 53. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 65
#     operands: 63
# 54. b_{_a} in V_{_a}
#     core type: Operation
#     operator: 65
#     operands: 64
# 55. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 65
#     operands: 66
# 56. K
#     core type: Variable
#     sub-expressions:
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 68
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. otimes
#     core type: Literal
#     sub-expressions:
# 60. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 67
# 61. _a -> c_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 71
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. (b_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 81, 70
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 74
#     end_index: 75
# 68. a_{_a}
#     core type: IndexedVar
# variable: 76
# index: 84
# 69. U_{_a}
#     core type: IndexedVar
# variable: 77
# index: 84
# 70. V_{_a}
#     core type: IndexedVar
# variable: 78
# index: 84
# 71. c_{_a}
#     core type: IndexedVar
# variable: 79
# index: 84
# 72. W_{_a}
#     core type: IndexedVar
# variable: 80
# index: 84
# 73. _a -> b_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 81
# 74. 1
#     core type: Literal
#     sub-expressions:
# 75. j
#     core type: Variable
#     sub-expressions:
# 76. a
#     core type: Variable
#     sub-expressions:
# 77. U
#     core type: Variable
#     sub-expressions:
# 78. V
#     core type: Variable
#     sub-expressions:
# 79. c
#     core type: Variable
#     sub-expressions:
# 80. W
#     core type: Variable
#     sub-expressions:
# 81. b_{_a}
#     core type: IndexedVar
# variable: 82
# index: 84
# 82. b
#     core type: Variable
#     sub-expressions:
# 83. (_a)
#     core type: ExprTuple
#     sub-expressions: 84
# 84. _a
#     core type: Variable
#     sub-expressions:
