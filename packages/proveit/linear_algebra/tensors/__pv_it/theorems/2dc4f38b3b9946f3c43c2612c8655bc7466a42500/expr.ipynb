# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import V, b, e
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecZero
from proveit.logic import Equals, Forall, Implies, NotEquals

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k], instance_expr = Forall(instance_param_or_params = [b, e], instance_expr = Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V, conditions = [Equals(b, e), NotEquals(b, VecZero(V))]), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(f_{1} \in W_{1}\right), \left(f_{2} \in W_{2}\right), \ldots, \left(f_{k} \in W_{k}\right)}~\\
# \left[\forall_{b, e \in V~|~b = e, b \neq \vec{0}\left(V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#    core type: ExprTuple
#    sub-expressions: 67, 68, 69, 70
# 4. {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (f_{1} in W_{1}) and  (f_{2} in W_{2}) and  ... and  (f_{k} in W_{k})
#    core type: Operation
#    operator: 28
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k}))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 10. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Lambda
#     parameters: 48\n    body: 15
# 11. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 77
#     end_index: 75
# 12. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 77
#     end_index: 78
# 13. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 77
#     end_index: 75
# 14. (f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 77
#     end_index: 78
# 15. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Conditional
#     value: 20
#     condition: 21
# 16. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 88
#     body: 22
# 17. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 88
#     body: 23
# 18. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 88
#     body: 24
# 19. _a -> (f_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 88
#     body: 25
# 20. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. (b in V) and (e in V) and (b = e) and (b != 0(V))
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 45
#     operands: 30
# 23. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 45
#     operands: 31
# 24. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 45
#     operands: 32
# 25. f_{_a} in W_{_a}
#     core type: Operation
#     operator: 45
#     operands: 33
# 26. =>
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (b in V, e in V, b = e, b != 0(V))
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38, 39
# 30. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 79, 40
# 31. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 80, 41
# 32. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 81, 40
# 33. (f_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 82, 41
# 34. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 47
#     operands: 42
# 35. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 47
#     operands: 43
# 36. b in V
#     core type: Operation
#     operator: 45
#     operands: 44
# 37. e in V
#     core type: Operation
#     operator: 45
#     operands: 46
# 38. b = e
#     core type: Operation
#     operator: 47
#     operands: 48
# 39. b != 0(V)
#     core type: Operation
#     operator: 49
#     operands: 50
# 40. U_{_a}
#     core type: IndexedVar
# variable: 51
# index: 88
# 41. W_{_a}
#     core type: IndexedVar
# variable: 52
# index: 88
# 42. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 43. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 44. (b, V)
#     core type: ExprTuple
#     sub-expressions: 65, 71
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (e, V)
#     core type: ExprTuple
#     sub-expressions: 66, 71
# 47. =
#     core type: Literal
#     sub-expressions:
# 48. (b, e)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 49. !=
#     core type: Literal
#     sub-expressions:
# 50. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 65, 57
# 51. U
#     core type: Variable
#     sub-expressions:
# 52. W
#     core type: Variable
#     sub-expressions:
# 53. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 61
#     operands: 58
# 54. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 61
#     operands: 59
# 55. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 61
#     operands: 60
# 56. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. 0(V)
#     core type: Operation
#     operator: 63
#     operand: 71
# 58. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 65, 68
# 59. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 69, 66, 70
# 60. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 61. otimes
#     core type: Literal
#     sub-expressions:
# 62. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 63. 0
#     core type: Literal
#     sub-expressions:
# 64. (V)
#     core type: ExprTuple
#     sub-expressions: 71
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. e
#     core type: Variable
#     sub-expressions:
# 67. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 77
#     end_index: 75
# 68. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 77
#     end_index: 78
# 69. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 77
#     end_index: 75
# 70. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 77
#     end_index: 78
# 71. V
#     core type: Variable
#     sub-expressions:
# 72. _a -> a_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 79
# 73. _a -> c_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 80
# 74. _a -> d_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 81
# 75. i
#     core type: Variable
#     sub-expressions:
# 76. _a -> f_{_a}
#     core type: Lambda
#     parameter: 88
#     body: 82
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. k
#     core type: Variable
#     sub-expressions:
# 79. a_{_a}
#     core type: IndexedVar
# variable: 83
# index: 88
# 80. c_{_a}
#     core type: IndexedVar
# variable: 84
# index: 88
# 81. d_{_a}
#     core type: IndexedVar
# variable: 85
# index: 88
# 82. f_{_a}
#     core type: IndexedVar
# variable: 86
# index: 88
# 83. a
#     core type: Variable
#     sub-expressions:
# 84. c
#     core type: Variable
#     sub-expressions:
# 85. d
#     core type: Variable
#     sub-expressions:
# 86. f
#     core type: Variable
#     sub-expressions:
# 87. (_a)
#     core type: ExprTuple
#     sub-expressions: 88
# 88. _a
#     core type: Variable
#     sub-expressions:
