# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#tensor_prod_of_linear_maps">tensor_prod_of_linear_maps</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.tensors import tensor_prod_of_linear_maps

# %%
# check that the built expression is the same as the stored expression
assert tensor_prod_of_linear_maps.expr == stored_expr
assert tensor_prod_of_linear_maps.expr._style_id == stored_expr._style_id
print("Passed sanity check: tensor_prod_of_linear_maps matches stored_expr")
# Out:
# Passed sanity check: tensor_prod_of_linear_maps matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{n}, W_{1}, W_{2}, \ldots, W_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{n in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]]]
#    core type: Operation
#    operator: 34
#    operand: 2
# 1. (K -> [forall_{n in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{n in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]]]
#    core type: Lambda
#    parameter: 50
#    body: 3
# 3. forall_{n in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]]
#    core type: Operation
#    operator: 34
#    operand: 5
# 4. (n -> {forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. n -> {forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 84
#    body: 7
# 6. (n)
#    core type: ExprTuple
#    sub-expressions: 84
# 7. {forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]] if n in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]
#    core type: Operation
#    operator: 34
#    operand: 12
# 9. n in NaturalPos
#    core type: Operation
#    operator: 75
#    operands: 11
# 10. ((V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 84, 13
# 12. (V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. (V_{1}, V_{2}, ..., V_{n},W_{1}, W_{2}, ..., W_{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. V_{1}, V_{2}, ..., V_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 83
#     end_index: 84
# 17. W_{1}, W_{2}, ..., W_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 83
#     end_index: 84
# 18. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#     core type: Operation
#     operator: 34
#     operand: 24
# 19. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{n} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{n} in_c VecSpaces(K))
#     core type: Operation
#     operator: 53
#     operands: 23
# 20. _a -> V_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 81
# 21. _a -> W_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 70
# 22. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Lambda
#     parameters: 66\n    body: 27
# 25. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 83
#     end_index: 84
# 26. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 83
#     end_index: 84
# 27. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Conditional
#     value: 30
#     condition: 31
# 28. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 92
#     body: 32
# 29. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 92
#     body: 33
# 30. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#     core type: Operation
#     operator: 34
#     operand: 40
# 31. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: Operation
#     operator: 53
#     operands: 36
# 32. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operands: 37
# 33. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. forall
#     core type: Literal
#     sub-expressions:
# 35. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 81, 42
# 38. in_c
#     core type: Literal
#     sub-expressions:
# 39. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 70, 42
# 40. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Lambda
#     parameters: 73\n    body: 43
# 41. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 83
#     end_index: 84
# 42. VecSpaces(K)
#     core type: Operation
#     operator: 45
#     operand: 50
# 43. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 47
#     condition: 48
# 44. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 92
#     body: 49
# 45. VecSpaces
#     core type: Literal
#     sub-expressions:
# 46. (K)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 75
#     operands: 55
# 50. K
#     core type: Variable
#     sub-expressions:
# 51. =
#     core type: Literal
#     sub-expressions:
# 52. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 53. and
#     core type: Literal
#     sub-expressions:
# 54. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 58
# 55. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 85, 59
# 56. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 60
#     operand: 67
# 57. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 72
#     operands: 62
# 58. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 83
#     end_index: 84
# 59. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 72
#     operands: 66
# 61. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 67
# 62. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 68
# 63. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 92
#     body: 69
# 64. LINMAP
#     core type: Literal
#     sub-expressions:
# 65. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 81, 70
# 66. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 71
# 67. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 72
#     operands: 73
# 68. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 83
#     end_index: 84
# 69. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 75
#     operands: 76
# 70. W_{_a}
#     core type: IndexedVar
# variable: 77
# index: 92
# 71. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 83
#     end_index: 84
# 72. otimes
#     core type: Literal
#     sub-expressions:
# 73. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 79
# 74. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 92
#     body: 80
# 75. in
#     core type: Literal
#     sub-expressions:
# 76. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 89, 81
# 77. W
#     core type: Variable
#     sub-expressions:
# 78. _a -> A_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 85
# 79. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 83
#     end_index: 84
# 80. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 85
#     operand: 89
# 81. V_{_a}
#     core type: IndexedVar
# variable: 87
# index: 92
# 82. _a -> v_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 89
# 83. 1
#     core type: Literal
#     sub-expressions:
# 84. n
#     core type: Variable
#     sub-expressions:
# 85. A_{_a}
#     core type: IndexedVar
# variable: 88
# index: 92
# 86. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 89
# 87. V
#     core type: Variable
#     sub-expressions:
# 88. A
#     core type: Variable
#     sub-expressions:
# 89. v_{_a}
#     core type: IndexedVar
# variable: 90
# index: 92
# 90. v
#     core type: Variable
#     sub-expressions:
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 92
# 92. _a
#     core type: Variable
#     sub-expressions:
