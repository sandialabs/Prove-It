# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [V_1_to_i]
expr = Lambda(K, Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = InSet(TensorProd(a_1_to_i), TensorProd(V_1_to_i)), domains = sub_expr1), domain = VecSpaces(K)), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{i \in \mathbb{N}^+}~\left[\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\left(\left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right) \in \left(V_{1} {\otimes}  V_{2} {\otimes}  \ldots {\otimes}  V_{i}\right)\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]]
#    core type: Lambda
#    parameter: 43
#    body: 1
# 1. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 47
#    body: 5
# 4. (i)
#    core type: ExprTuple
#    sub-expressions: 47
# 5. {forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))] if i in NaturalPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]
#    core type: Operation
#    operator: 15
#    operand: 10
# 7. i in NaturalPos
#    core type: Operation
#    operator: 48
#    operands: 9
# 8. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 47, 11
# 10. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 36\n    body: 12
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})) if (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{i} in_c VecSpaces(K))
#     core type: Operation
#     operator: 26
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (a_{1}, a_{2}, ..., a_{i}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 34\n    body: 20
# 19. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 46
#     end_index: 47
# 20. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 21. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 55
#     body: 24
# 22. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: Operation
#     operator: 48
#     operands: 25
# 23. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}, V_{1} otimes  V_{2} otimes  ... otimes  V_{i})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. in_c
#     core type: Literal
#     sub-expressions:
# 29. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 51, 33
# 30. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. V_{1} otimes  V_{2} otimes  ... otimes  V_{i}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 46
#     end_index: 47
# 33. VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operand: 43
# 34. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 35. otimes
#     core type: Literal
#     sub-expressions:
# 36. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 42
# 38. VecSpaces
#     core type: Literal
#     sub-expressions:
# 39. (K)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 47
# 41. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 42. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 48
#     operands: 49
# 43. K
#     core type: Variable
#     sub-expressions:
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 50
# 45. _a -> V_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 51
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. i
#     core type: Variable
#     sub-expressions:
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 55
# 51. V_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. V
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
