# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, Function, IndexedVar, K, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, W_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [V_1_to_n, W_1_to_n], instance_expr = Forall(instance_param_or_params = [A_1_to_n], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(IndexedVar(A, sub_expr1), [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), domains = [ExprRange(sub_expr1, LinMap(IndexedVar(V, sub_expr1), IndexedVar(W, sub_expr1)), one, n)]).with_wrapping(), domain = VecSpaces(K)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{n}, W_{1}, W_{2}, \ldots, W_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n} in_c VecSpaces(K)} [forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. ((V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (V_{1}, V_{2}, ..., V_{n}, W_{1}, W_{2}, ..., W_{n}) -> {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (V_{1}, V_{2}, ..., V_{n},W_{1}, W_{2}, ..., W_{n})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 7
#    condition: 8
# 5. V_{1}, V_{2}, ..., V_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 72
#    end_index: 73
# 6. W_{1}, W_{2}, ..., W_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 72
#    end_index: 73
# 7. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#    core type: Operation
#    operator: 23
#    operand: 13
# 8. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{n} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{n} in_c VecSpaces(K))
#    core type: Operation
#    operator: 42
#    operands: 12
# 9. _a -> V_{_a}
#    core type: Lambda
#    parameter: 81
#    body: 70
# 10. _a -> W_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 59
# 11. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Lambda
#     parameters: 55\n    body: 16
# 14. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 72
#     end_index: 73
# 15. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 72
#     end_index: 73
# 16. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 81
#     body: 21
# 18. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 81
#     body: 22
# 19. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#     core type: Operation
#     operator: 23
#     operand: 29
# 20. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: Operation
#     operator: 42
#     operands: 25
# 21. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 70, 31
# 27. in_c
#     core type: Literal
#     sub-expressions:
# 28. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 59, 31
# 29. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Lambda
#     parameters: 62\n    body: 32
# 30. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 72
#     end_index: 73
# 31. VecSpaces(K)
#     core type: Operation
#     operator: 34
#     operand: 39
# 32. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 36
#     condition: 37
# 33. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 81
#     body: 38
# 34. VecSpaces
#     core type: Literal
#     sub-expressions:
# 35. (K)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 64
#     operands: 44
# 39. K
#     core type: Variable
#     sub-expressions:
# 40. =
#     core type: Literal
#     sub-expressions:
# 41. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 47
# 44. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 74, 48
# 45. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 49
#     operand: 56
# 46. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 61
#     operands: 51
# 47. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 72
#     end_index: 73
# 48. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 61
#     operands: 55
# 50. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 51. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 57
# 52. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 81
#     body: 58
# 53. LINMAP
#     core type: Literal
#     sub-expressions:
# 54. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 70, 59
# 55. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 60
# 56. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 72
#     end_index: 73
# 58. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 64
#     operands: 65
# 59. W_{_a}
#     core type: IndexedVar
# variable: 66
# index: 81
# 60. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 72
#     end_index: 73
# 61. otimes
#     core type: Literal
#     sub-expressions:
# 62. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 68
# 63. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 81
#     body: 69
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 78, 70
# 66. W
#     core type: Variable
#     sub-expressions:
# 67. _a -> A_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 74
# 68. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 72
#     end_index: 73
# 69. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 74
#     operand: 78
# 70. V_{_a}
#     core type: IndexedVar
# variable: 76
# index: 81
# 71. _a -> v_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 78
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. n
#     core type: Variable
#     sub-expressions:
# 74. A_{_a}
#     core type: IndexedVar
# variable: 77
# index: 81
# 75. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 78
# 76. V
#     core type: Variable
#     sub-expressions:
# 77. A
#     core type: Variable
#     sub-expressions:
# 78. v_{_a}
#     core type: IndexedVar
# variable: 79
# index: 81
# 79. v
#     core type: Variable
#     sub-expressions:
# 80. (_a)
#     core type: ExprTuple
#     sub-expressions: 81
# 81. _a
#     core type: Variable
#     sub-expressions:
