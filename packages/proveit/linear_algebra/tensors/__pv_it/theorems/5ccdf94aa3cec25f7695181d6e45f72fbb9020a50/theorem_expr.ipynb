# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#tensor_prod_association">tensor_prod_association</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.tensors import tensor_prod_association

# %%
# check that the built expression is the same as the stored expression
assert tensor_prod_association.expr == stored_expr
assert tensor_prod_association.expr._style_id == stored_expr._style_id
print("Passed sanity check: tensor_prod_association matches stored_expr")
# Out:
# Passed sanity check: tensor_prod_association matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{i, j, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(b_{1} \in V_{1}\right), \left(b_{2} \in V_{2}\right), \ldots, \left(b_{j} \in V_{j}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]]
#    core type: Operation
#    operator: 30
#    operand: 2
# 1. (K -> [forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]]
#    core type: Lambda
#    parameter: 73
#    body: 3
# 3. forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]
#    core type: Operation
#    operator: 30
#    operand: 5
# 4. ((i, j, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (i, j, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 75, 92, 79
# 7. {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]
#    core type: Operation
#    operator: 30
#    operand: 12
# 9. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 48
#    operands: 11
# 10. ((U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 12. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 16\n    body: 17
# 13. i in Natural
#     core type: Operation
#     operator: 82
#     operands: 18
# 14. j in Natural
#     core type: Operation
#     operator: 82
#     operands: 19
# 15. k in Natural
#     core type: Operation
#     operator: 82
#     operands: 20
# 16. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j},W_{1}, W_{2}, ..., W_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 17. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 24
#     condition: 25
# 18. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 75, 26
# 19. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 92, 26
# 20. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 79, 26
# 21. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 91
#     end_index: 75
# 22. V_{1}, V_{2}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 91
#     end_index: 92
# 23. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 91
#     end_index: 79
# 24. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 30
#     operand: 33
# 25. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K))and (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{j} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 48
#     operands: 32
# 26. Natural
#     core type: Literal
#     sub-expressions:
# 27. _a -> U_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 86
# 28. _a -> V_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 87
# 29. _a -> W_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 89
# 30. forall
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 33
# 32. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)),(V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36
# 33. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 60\n    body: 37
# 34. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 91
#     end_index: 75
# 35. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 91
#     end_index: 92
# 36. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 91
#     end_index: 79
# 37. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 41
#     condition: 42
# 38. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 101
#     body: 43
# 39. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 101
#     body: 44
# 40. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 101
#     body: 45
# 41. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (b_{1} in V_{1}) and  (b_{2} in V_{2}) and  ... and  (b_{j} in V_{j})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 48
#     operands: 49
# 43. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 50
# 44. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 51
# 45. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. =
#     core type: Literal
#     sub-expressions:
# 47. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58
# 50. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 86, 59
# 51. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 87, 59
# 52. in_c
#     core type: Literal
#     sub-expressions:
# 53. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 89, 59
# 54. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 76
#     operands: 60
# 55. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 76
#     operands: 61
# 56. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 91
#     end_index: 75
# 57. (b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j})
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 91
#     end_index: 92
# 58. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 91
#     end_index: 79
# 59. VecSpaces(K)
#     core type: Operation
#     operator: 65
#     operand: 73
# 60. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 84, 69
# 61. (a_{1}, a_{2}, ..., a_{i}, b_{1} otimes  b_{2} otimes  ... otimes  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 68, 69
# 62. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 101
#     body: 70
# 63. _a -> (b_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 101
#     body: 71
# 64. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 101
#     body: 72
# 65. VecSpaces
#     core type: Literal
#     sub-expressions:
# 66. (K)
#     core type: ExprTuple
#     sub-expressions: 73
# 67. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 91
#     end_index: 75
# 68. b_{1} otimes  b_{2} otimes  ... otimes  b_{j}
#     core type: Operation
#     operator: 76
#     operands: 77
# 69. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 91
#     end_index: 79
# 70. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 82
#     operands: 80
# 71. b_{_a} in V_{_a}
#     core type: Operation
#     operator: 82
#     operands: 81
# 72. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 82
#     operands: 83
# 73. K
#     core type: Variable
#     sub-expressions:
# 74. _a -> a_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 85
# 75. i
#     core type: Variable
#     sub-expressions:
# 76. otimes
#     core type: Literal
#     sub-expressions:
# 77. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 84
# 78. _a -> c_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 88
# 79. k
#     core type: Variable
#     sub-expressions:
# 80. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 81. (b_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 98, 87
# 82. in
#     core type: Literal
#     sub-expressions:
# 83. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 84. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 91
#     end_index: 92
# 85. a_{_a}
#     core type: IndexedVar
# variable: 93
# index: 101
# 86. U_{_a}
#     core type: IndexedVar
# variable: 94
# index: 101
# 87. V_{_a}
#     core type: IndexedVar
# variable: 95
# index: 101
# 88. c_{_a}
#     core type: IndexedVar
# variable: 96
# index: 101
# 89. W_{_a}
#     core type: IndexedVar
# variable: 97
# index: 101
# 90. _a -> b_{_a}
#     core type: Lambda
#     parameter: 101
#     body: 98
# 91. 1
#     core type: Literal
#     sub-expressions:
# 92. j
#     core type: Variable
#     sub-expressions:
# 93. a
#     core type: Variable
#     sub-expressions:
# 94. U
#     core type: Variable
#     sub-expressions:
# 95. V
#     core type: Variable
#     sub-expressions:
# 96. c
#     core type: Variable
#     sub-expressions:
# 97. W
#     core type: Variable
#     sub-expressions:
# 98. b_{_a}
#     core type: IndexedVar
# variable: 99
# index: 101
# 99. b
#     core type: Variable
#     sub-expressions:
# 100. (_a)
#      core type: ExprTuple
#      sub-expressions: 101
# 101. _a
#      core type: Variable
#      sub-expressions:
