# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, i, j, k
from proveit.core_expr_types import A_1_to_i, B_1_to_j, C_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [A_1_to_i, B_1_to_j, C_1_to_k], instance_expr = Equals(TensorProd(A_1_to_i, B_1_to_j, C_1_to_k), TensorProd(A_1_to_i, TensorProd(B_1_to_j), C_1_to_k)).with_wrapping_at(1), domain = VecSpaces(K)).with_wrapping(), domain = Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{i, j, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{A_{1}, A_{2}, \ldots, A_{i}, B_{1}, B_{2}, \ldots, B_{j}, C_{1}, C_{2}, \ldots, C_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{i}{\otimes} B_{1} {\otimes}  B_{2} {\otimes}  \ldots {\otimes}  B_{j}{\otimes} C_{1} {\otimes}  C_{2} {\otimes}  \ldots {\otimes}  C_{k}\right) \\  = \left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{i} {\otimes} \left(B_{1} {\otimes}  B_{2} {\otimes}  \ldots {\otimes}  B_{j}\right){\otimes} C_{1} {\otimes}  C_{2} {\otimes}  \ldots {\otimes}  C_{k}\right) \end{array} \end{array}\right)\end{array}\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{i, j, k in Natural} [forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}))]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{i, j, k in Natural} [forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}))]]
#    core type: Lambda
#    parameter: 66
#    body: 2
# 2. forall_{i, j, k in Natural} [forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}))]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. ((i, j, k) -> {forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (i, j, k) -> {forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 45, 60, 49
# 6. {forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k} in_c VecSpaces(K)} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 26
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) if (A_{1} in_c VecSpaces(K)) ,  (A_{2} in_c VecSpaces(K)) ,  ... ,  (A_{i} in_c VecSpaces(K)), (B_{1} in_c VecSpaces(K)) ,  (B_{2} in_c VecSpaces(K)) ,  ... ,  (B_{j} in_c VecSpaces(K)), (C_{1} in_c VecSpaces(K)) ,  (C_{2} in_c VecSpaces(K)) ,  ... ,  (C_{k} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 12. (A_{1}, A_{2}, ..., A_{i}, B_{1}, B_{2}, ..., B_{j}, C_{1}, C_{2}, ..., C_{k}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) if (A_{1} in_c VecSpaces(K)) ,  (A_{2} in_c VecSpaces(K)) ,  ... ,  (A_{i} in_c VecSpaces(K)), (B_{1} in_c VecSpaces(K)) ,  (B_{2} in_c VecSpaces(K)) ,  ... ,  (B_{j} in_c VecSpaces(K)), (C_{1} in_c VecSpaces(K)) ,  (C_{2} in_c VecSpaces(K)) ,  ... ,  (C_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 33\n    body: 16
# 13. i in Natural
#     core type: Operation
#     operator: 19
#     operands: 17
# 14. j in Natural
#     core type: Operation
#     operator: 19
#     operands: 18
# 15. k in Natural
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) if (A_{1} in_c VecSpaces(K)) ,  (A_{2} in_c VecSpaces(K)) ,  ... ,  (A_{i} in_c VecSpaces(K)), (B_{1} in_c VecSpaces(K)) ,  (B_{2} in_c VecSpaces(K)) ,  ... ,  (B_{j} in_c VecSpaces(K)), (C_{1} in_c VecSpaces(K)) ,  (C_{2} in_c VecSpaces(K)) ,  ... ,  (C_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 23
# 18. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 60, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 23
# 21. (A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}) \\  = (A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k})
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (A_{1} in_c VecSpaces(K)) and  (A_{2} in_c VecSpaces(K)) and  ... and  (A_{i} in_c VecSpaces(K))and (B_{1} in_c VecSpaces(K)) and  (B_{2} in_c VecSpaces(K)) and  ... and  (B_{j} in_c VecSpaces(K))and (C_{1} in_c VecSpaces(K)) and  (C_{2} in_c VecSpaces(K)) and  ... and  (C_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}, A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((A_{1} in_c VecSpaces(K)), (A_{2} in_c VecSpaces(K)), ..., (A_{i} in_c VecSpaces(K)),(B_{1} in_c VecSpaces(K)), (B_{2} in_c VecSpaces(K)), ..., (B_{j} in_c VecSpaces(K)),(C_{1} in_c VecSpaces(K)), (C_{2} in_c VecSpaces(K)), ..., (C_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 30, 31, 32
# 28. A_{1} otimes  A_{2} otimes  ... otimes  A_{i}otimes B_{1} otimes  B_{2} otimes  ... otimes  B_{j}otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}
#     core type: Operation
#     operator: 46
#     operands: 33
# 29. A_{1} otimes  A_{2} otimes  ... otimes  A_{i} otimes (B_{1} otimes  B_{2} otimes  ... otimes  B_{j})otimes C_{1} otimes  C_{2} otimes  ... otimes  C_{k}
#     core type: Operation
#     operator: 46
#     operands: 34
# 30. (A_{1} in_c VecSpaces(K)), (A_{2} in_c VecSpaces(K)), ..., (A_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 59
#     end_index: 45
# 31. (B_{1} in_c VecSpaces(K)), (B_{2} in_c VecSpaces(K)), ..., (B_{j} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 59
#     end_index: 60
# 32. (C_{1} in_c VecSpaces(K)), (C_{2} in_c VecSpaces(K)), ..., (C_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 59
#     end_index: 49
# 33. (A_{1}, A_{2}, ..., A_{i},B_{1}, B_{2}, ..., B_{j},C_{1}, C_{2}, ..., C_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 54, 40
# 34. (A_{1}, A_{2}, ..., A_{i}, B_{1} otimes  B_{2} otimes  ... otimes  B_{j},C_{1}, C_{2}, ..., C_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39, 40
# 35. _a -> (A_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 69
#     body: 41
# 36. _a -> (B_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 69
#     body: 42
# 37. _a -> (C_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 69
#     body: 43
# 38. A_{1}, A_{2}, ..., A_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 59
#     end_index: 45
# 39. B_{1} otimes  B_{2} otimes  ... otimes  B_{j}
#     core type: Operation
#     operator: 46
#     operands: 47
# 40. C_{1}, C_{2}, ..., C_{k}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 59
#     end_index: 49
# 41. A_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 50
# 42. B_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 51
# 43. C_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 52
#     operands: 53
# 44. _a -> A_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 55
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. otimes
#     core type: Literal
#     sub-expressions:
# 47. (B_{1}, B_{2}, ..., B_{j})
#     core type: ExprTuple
#     sub-expressions: 54
# 48. _a -> C_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 56
# 49. k
#     core type: Variable
#     sub-expressions:
# 50. (A_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 51. (B_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 65, 57
# 52. in_c
#     core type: Literal
#     sub-expressions:
# 53. (C_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. B_{1}, B_{2}, ..., B_{j}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 55. A_{_a}
#     core type: IndexedVar
# variable: 61
# index: 69
# 56. C_{_a}
#     core type: IndexedVar
# variable: 62
# index: 69
# 57. VecSpaces(K)
#     core type: Operation
#     operator: 63
#     operand: 66
# 58. _a -> B_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 65
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. j
#     core type: Variable
#     sub-expressions:
# 61. A
#     core type: Variable
#     sub-expressions:
# 62. C
#     core type: Variable
#     sub-expressions:
# 63. VecSpaces
#     core type: Literal
#     sub-expressions:
# 64. (K)
#     core type: ExprTuple
#     sub-expressions: 66
# 65. B_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 66. K
#     core type: Variable
#     sub-expressions:
# 67. B
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
