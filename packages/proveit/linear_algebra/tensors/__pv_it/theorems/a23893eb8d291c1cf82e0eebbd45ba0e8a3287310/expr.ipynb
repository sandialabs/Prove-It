# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, U, V, Variable, W, a, b, c, d, e, f, i, k
from proveit.core_expr_types import a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecZero
from proveit.logic import And, Equals, Forall, Implies, InSet, NotEquals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(U, sub_expr1)
sub_expr3 = IndexedVar(W, sub_expr1)
expr = Conditional(Forall(instance_param_or_params = [b, e], instance_expr = Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V, conditions = [Equals(b, e), NotEquals(b, VecZero(V))]), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), sub_expr2), one, i), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), sub_expr3), one, k), ExprRange(sub_expr1, InSet(IndexedVar(d, sub_expr1), sub_expr2), one, i), ExprRange(sub_expr1, InSet(IndexedVar(f, sub_expr1), sub_expr3), one, k)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{b, e \in V~|~b = e, b \neq \vec{0}\left(V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } \left(a_{1} \in U_{1}\right) ,  \left(a_{2} \in U_{2}\right) ,  \ldots ,  \left(a_{i} \in U_{i}\right), \left(c_{1} \in W_{1}\right) ,  \left(c_{2} \in W_{2}\right) ,  \ldots ,  \left(c_{k} \in W_{k}\right), \left(d_{1} \in U_{1}\right) ,  \left(d_{2} \in U_{2}\right) ,  \ldots ,  \left(d_{i} \in U_{i}\right), \left(f_{1} \in W_{1}\right) ,  \left(f_{2} \in W_{2}\right) ,  \ldots ,  \left(f_{k} \in W_{k}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (f_{1} in W_{1}) and  (f_{2} in W_{2}) and  ... and  (f_{k} in W_{k})
#    core type: Operation
#    operator: 24
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k}))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 6. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Lambda
#    parameters: 44\n   body: 11
# 7. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 73
#    end_index: 71
# 8. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 73
#    end_index: 74
# 9. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 73
#    end_index: 71
# 10. (f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 73
#     end_index: 74
# 11. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Conditional
#     value: 16
#     condition: 17
# 12. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 18
# 13. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 19
# 14. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 20
# 15. _a -> (f_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 84
#     body: 21
# 16. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. (b in V) and (e in V) and (b = e) and (b != 0(V))
#     core type: Operation
#     operator: 24
#     operands: 25
# 18. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 41
#     operands: 26
# 19. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 41
#     operands: 27
# 20. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 41
#     operands: 28
# 21. f_{_a} in W_{_a}
#     core type: Operation
#     operator: 41
#     operands: 29
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (b in V, e in V, b = e, b != 0(V))
#     core type: ExprTuple
#     sub-expressions: 32, 33, 34, 35
# 26. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 75, 36
# 27. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 76, 37
# 28. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 77, 36
# 29. (f_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 78, 37
# 30. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 43
#     operands: 38
# 31. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 43
#     operands: 39
# 32. b in V
#     core type: Operation
#     operator: 41
#     operands: 40
# 33. e in V
#     core type: Operation
#     operator: 41
#     operands: 42
# 34. b = e
#     core type: Operation
#     operator: 43
#     operands: 44
# 35. b != 0(V)
#     core type: Operation
#     operator: 45
#     operands: 46
# 36. U_{_a}
#     core type: IndexedVar
# variable: 47
# index: 84
# 37. W_{_a}
#     core type: IndexedVar
# variable: 48
# index: 84
# 38. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 39. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 40. (b, V)
#     core type: ExprTuple
#     sub-expressions: 61, 67
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (e, V)
#     core type: ExprTuple
#     sub-expressions: 62, 67
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (b, e)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 45. !=
#     core type: Literal
#     sub-expressions:
# 46. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 61, 53
# 47. U
#     core type: Variable
#     sub-expressions:
# 48. W
#     core type: Variable
#     sub-expressions:
# 49. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 57
#     operands: 54
# 50. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 57
#     operands: 55
# 51. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 57
#     operands: 56
# 52. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. 0(V)
#     core type: Operation
#     operator: 59
#     operand: 67
# 54. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 61, 64
# 55. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 65, 62, 66
# 56. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 57. otimes
#     core type: Literal
#     sub-expressions:
# 58. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 59. 0
#     core type: Literal
#     sub-expressions:
# 60. (V)
#     core type: ExprTuple
#     sub-expressions: 67
# 61. b
#     core type: Variable
#     sub-expressions:
# 62. e
#     core type: Variable
#     sub-expressions:
# 63. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 73
#     end_index: 71
# 64. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 73
#     end_index: 74
# 65. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 73
#     end_index: 71
# 66. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 73
#     end_index: 74
# 67. V
#     core type: Variable
#     sub-expressions:
# 68. _a -> a_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 75
# 69. _a -> c_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 76
# 70. _a -> d_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 77
# 71. i
#     core type: Variable
#     sub-expressions:
# 72. _a -> f_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 78
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. k
#     core type: Variable
#     sub-expressions:
# 75. a_{_a}
#     core type: IndexedVar
# variable: 79
# index: 84
# 76. c_{_a}
#     core type: IndexedVar
# variable: 80
# index: 84
# 77. d_{_a}
#     core type: IndexedVar
# variable: 81
# index: 84
# 78. f_{_a}
#     core type: IndexedVar
# variable: 82
# index: 84
# 79. a
#     core type: Variable
#     sub-expressions:
# 80. c
#     core type: Variable
#     sub-expressions:
# 81. d
#     core type: Variable
#     sub-expressions:
# 82. f
#     core type: Variable
#     sub-expressions:
# 83. (_a)
#     core type: ExprTuple
#     sub-expressions: 84
# 84. _a
#     core type: Variable
#     sub-expressions:
