# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, Function, IndexedVar, K, V, Variable, W, n, v
from proveit.core_expr_types import A_1_to_n, V_1_to_n, v_1_to_n
from proveit.linear_algebra import LinMap, TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(V, sub_expr1)
sub_expr3 = IndexedVar(W, sub_expr1)
sub_expr4 = VecSpaces(K)
expr = Conditional(Forall(instance_param_or_params = [A_1_to_n], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Equals(Function(TensorProd(A_1_to_n), [TensorProd(v_1_to_n)]), TensorProd(ExprRange(sub_expr1, Function(IndexedVar(A, sub_expr1), [IndexedVar(v, sub_expr1)]), one, n))), domains = [V_1_to_n]).with_wrapping(), domains = [ExprRange(sub_expr1, LinMap(sub_expr2, sub_expr3), one, n)]).with_wrapping(), And(ExprRange(sub_expr1, InClass(sub_expr2, sub_expr4), one, n), ExprRange(sub_expr1, InClass(sub_expr3, sub_expr4), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\left(A_{1} \in \mathcal{L}\left(V_{1}, W_{1}\right)\right), \left(A_{2} \in \mathcal{L}\left(V_{2}, W_{2}\right)\right), \ldots, \left(A_{n} \in \mathcal{L}\left(V_{n}, W_{n}\right)\right)}~\\
# \left[\begin{array}{l}\forall_{\left(v_{1} \in V_{1}\right), \left(v_{2} \in V_{2}\right), \ldots, \left(v_{n} \in V_{n}\right)}~\\
# \left(\left(A_{1} {\otimes}  A_{2} {\otimes}  \ldots {\otimes}  A_{n}\right)\left(v_{1} {\otimes}  v_{2} {\otimes}  \ldots {\otimes}  v_{n}\right) = \left(A_{1}\left(v_{1}\right) {\otimes}  A_{2}\left(v_{2}\right) {\otimes}  \ldots {\otimes}  A_{n}\left(v_{n}\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(V_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{n} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))] if (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{n} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{n} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{(A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))} [forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))]
#    core type: Operation
#    operator: 15
#    operand: 5
# 2. (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{n} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{n} in_c VecSpaces(K))
#    core type: Operation
#    operator: 34
#    operands: 4
# 3. ((A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ((V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A_{1}, A_{2}, ..., A_{n}) -> {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#    core type: Lambda
#    parameters: 47\n   body: 8
# 6. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{n} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 64
#    end_index: 65
# 7. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{n} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 64
#    end_index: 65
# 8. {forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))) if (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n})).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. _a -> (V_{_a} in_c VecSpaces(K))
#    core type: Lambda
#    parameter: 73
#    body: 13
# 10. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 73
#     body: 14
# 11. forall_{(v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})} ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})))
#     core type: Operation
#     operator: 15
#     operand: 21
# 12. (A_{1} in LINMAP(V_{1}, W_{1})) and  (A_{2} in LINMAP(V_{2}, W_{2})) and  ... and  (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: Operation
#     operator: 34
#     operands: 17
# 13. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 17. ((A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n})))
#     core type: ExprTuple
#     sub-expressions: 22
# 18. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 62, 23
# 19. in_c
#     core type: Literal
#     sub-expressions:
# 20. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 51, 23
# 21. (v_{1}, v_{2}, ..., v_{n}) -> {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Lambda
#     parameters: 54\n    body: 24
# 22. (A_{1} in LINMAP(V_{1}, W_{1})), (A_{2} in LINMAP(V_{2}, W_{2})), ..., (A_{n} in LINMAP(V_{n}, W_{n}))
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 64
#     end_index: 65
# 23. VecSpaces(K)
#     core type: Operation
#     operator: 26
#     operand: 31
# 24. {(A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})) if (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. _a -> (A_{_a} in LINMAP(V_{_a}, W_{_a}))
#     core type: Lambda
#     parameter: 73
#     body: 30
# 26. VecSpaces
#     core type: Literal
#     sub-expressions:
# 27. (K)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}) = (A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (v_{1} in V_{1}) and  (v_{2} in V_{2}) and  ... and  (v_{n} in V_{n})
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. A_{_a} in LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 56
#     operands: 36
# 31. K
#     core type: Variable
#     sub-expressions:
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. ((A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n}), A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ((v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n}))
#     core type: ExprTuple
#     sub-expressions: 39
# 36. (A_{_a}, LINMAP(V_{_a}, W_{_a}))
#     core type: ExprTuple
#     sub-expressions: 66, 40
# 37. (A_{1} otimes  A_{2} otimes  ... otimes  A_{n})(v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: Operation
#     operator: 41
#     operand: 48
# 38. A_{1}(v_{1}) otimes  A_{2}(v_{2}) otimes  ... otimes  A_{n}(v_{n})
#     core type: Operation
#     operator: 53
#     operands: 43
# 39. (v_{1} in V_{1}), (v_{2} in V_{2}), ..., (v_{n} in V_{n})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 64
#     end_index: 65
# 40. LINMAP(V_{_a}, W_{_a})
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. A_{1} otimes  A_{2} otimes  ... otimes  A_{n}
#     core type: Operation
#     operator: 53
#     operands: 47
# 42. (v_{1} otimes  v_{2} otimes  ... otimes  v_{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 43. (A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n}))
#     core type: ExprTuple
#     sub-expressions: 49
# 44. _a -> (v_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 73
#     body: 50
# 45. LINMAP
#     core type: Literal
#     sub-expressions:
# 46. (V_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 62, 51
# 47. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 48. v_{1} otimes  v_{2} otimes  ... otimes  v_{n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. A_{1}(v_{1}), A_{2}(v_{2}), ..., A_{n}(v_{n})
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 64
#     end_index: 65
# 50. v_{_a} in V_{_a}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. W_{_a}
#     core type: IndexedVar
# variable: 58
# index: 73
# 52. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 64
#     end_index: 65
# 53. otimes
#     core type: Literal
#     sub-expressions:
# 54. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 60
# 55. _a -> A_{_a}(v_{_a})
#     core type: Lambda
#     parameter: 73
#     body: 61
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (v_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 70, 62
# 58. W
#     core type: Variable
#     sub-expressions:
# 59. _a -> A_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 66
# 60. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 64
#     end_index: 65
# 61. A_{_a}(v_{_a})
#     core type: Operation
#     operator: 66
#     operand: 70
# 62. V_{_a}
#     core type: IndexedVar
# variable: 68
# index: 73
# 63. _a -> v_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 70
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. A_{_a}
#     core type: IndexedVar
# variable: 69
# index: 73
# 67. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 70
# 68. V
#     core type: Variable
#     sub-expressions:
# 69. A
#     core type: Variable
#     sub-expressions:
# 70. v_{_a}
#     core type: IndexedVar
# variable: 71
# index: 73
# 71. v
#     core type: Variable
#     sub-expressions:
# 72. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 73. _a
#     core type: Variable
#     sub-expressions:
