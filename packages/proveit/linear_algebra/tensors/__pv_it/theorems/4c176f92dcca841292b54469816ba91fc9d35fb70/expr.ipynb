# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Lambda, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Mult, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Lambda(K, Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), Mult(ExprRange(sub_expr1, Norm(IndexedVar(a, sub_expr1)), one, i))), domains = sub_expr2).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{i \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = \left(\left \|a_{1}\right \| \cdot  \left \|a_{2}\right \| \cdot  \ldots \cdot  \left \|a_{i}\right \|\right)\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]]
#    core type: Lambda
#    parameter: 47
#    body: 1
# 1. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]
#    core type: Operation
#    operator: 18
#    operand: 3
# 2. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 58
#    body: 5
# 4. (i)
#    core type: ExprTuple
#    sub-expressions: 58
# 5. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]
#    core type: Operation
#    operator: 18
#    operand: 10
# 7. i in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 9
# 8. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 58, 11
# 10. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 57
#     end_index: 58
# 15. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 30
#     operands: 20
# 17. _a -> V_{_a}
#     core type: Lambda
#     parameter: 65
#     body: 55
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 49\n    body: 23
# 22. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 57
#     end_index: 58
# 23. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 65
#     body: 27
# 25. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 36
# 32. in_c
#     core type: Literal
#     sub-expressions:
# 33. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 55, 37
# 34. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 59
#     operand: 44
# 35. ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 57
#     end_index: 58
# 37. InnerProdSpaces(K)
#     core type: Operation
#     operator: 42
#     operand: 47
# 38. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 44
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (||a_{1}||, ||a_{2}||, ..., ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 45
# 41. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 65
#     body: 46
# 42. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 43. (K)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. ||a_{1}||, ||a_{2}||, ..., ||a_{i}||
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 57
#     end_index: 58
# 46. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. K
#     core type: Variable
#     sub-expressions:
# 48. otimes
#     core type: Literal
#     sub-expressions:
# 49. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. _a -> ||a_{_a}||
#     core type: Lambda
#     parameter: 65
#     body: 54
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 62, 55
# 53. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 57
#     end_index: 58
# 54. ||a_{_a}||
#     core type: Operation
#     operator: 59
#     operand: 62
# 55. V_{_a}
#     core type: IndexedVar
# variable: 61
# index: 65
# 56. _a -> a_{_a}
#     core type: Lambda
#     parameter: 65
#     body: 62
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. Abs
#     core type: Literal
#     sub-expressions:
# 60. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 62
# 61. V
#     core type: Variable
#     sub-expressions:
# 62. a_{_a}
#     core type: IndexedVar
# variable: 63
# index: 65
# 63. a
#     core type: Variable
#     sub-expressions:
# 64. (_a)
#     core type: ExprTuple
#     sub-expressions: 65
# 65. _a
#     core type: Variable
#     sub-expressions:
