# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Lambda, U, V, Variable, W, i, j, k
from proveit.core_expr_types import U_1_to_i, V_1_to_j, W_1_to_k, a_1_to_i, b_1_to_j, c_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = VecSpaces(K)
sub_expr3 = [U_1_to_i, V_1_to_j, W_1_to_k]
expr = Lambda(sub_expr3, Conditional(Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, TensorProd(b_1_to_j), c_1_to_k), TensorProd(a_1_to_i, b_1_to_j, c_1_to_k)).with_wrapping_at(1), domains = sub_expr3).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(U, sub_expr1), sub_expr2), one, i), ExprRange(sub_expr1, InClass(IndexedVar(V, sub_expr1), sub_expr2), one, j), ExprRange(sub_expr1, InClass(IndexedVar(W, sub_expr1), sub_expr2), one, k))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}, W_{1}, W_{2}, \ldots, W_{k}\right) \mapsto \left\{\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(b_{1} \in V_{1}\right), \left(b_{2} \in V_{2}\right), \ldots, \left(b_{j} \in V_{j}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right)\end{array} \textrm{ if } \left(U_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(U_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(U_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(V_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(V_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(V_{j} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j},W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 2. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 6
#    condition: 7
# 3. U_{1}, U_{2}, ..., U_{i}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 72
#    end_index: 58
# 4. V_{1}, V_{2}, ..., V_{j}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 72
#    end_index: 73
# 5. W_{1}, W_{2}, ..., W_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 72
#    end_index: 60
# 6. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#    core type: Operation
#    operator: 11
#    operand: 14
# 7. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K))and (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{j} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 29
#    operands: 13
# 8. _a -> U_{_a}
#    core type: Lambda
#    parameter: 82
#    body: 67
# 9. _a -> V_{_a}
#    core type: Lambda
#    parameter: 82
#    body: 68
# 10. _a -> W_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 70
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)),(V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 14. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 42\n    body: 18
# 15. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 72
#     end_index: 58
# 16. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 72
#     end_index: 73
# 17. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 72
#     end_index: 60
# 18. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 19. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 82
#     body: 24
# 20. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 82
#     body: 25
# 21. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 82
#     body: 26
# 22. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (b_{1} in V_{1}) and  (b_{2} in V_{2}) and  ... and  (b_{j} in V_{j})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 33
#     operands: 31
# 25. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 33
#     operands: 32
# 26. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 33
#     operands: 34
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 31. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 67, 40
# 32. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 68, 40
# 33. in_c
#     core type: Literal
#     sub-expressions:
# 34. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 70, 40
# 35. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 55
#     operands: 41
# 36. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 55
#     operands: 42
# 37. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 72
#     end_index: 58
# 38. (b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 72
#     end_index: 73
# 39. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 72
#     end_index: 60
# 40. VecSpaces(K)
#     core type: Operation
#     operator: 46
#     operand: 54
# 41. (a_{1}, a_{2}, ..., a_{i}, b_{1} otimes  b_{2} otimes  ... otimes  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 49, 48, 50
# 42. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 49, 65, 50
# 43. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 82
#     body: 51
# 44. _a -> (b_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 82
#     body: 52
# 45. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 82
#     body: 53
# 46. VecSpaces
#     core type: Literal
#     sub-expressions:
# 47. (K)
#     core type: ExprTuple
#     sub-expressions: 54
# 48. b_{1} otimes  b_{2} otimes  ... otimes  b_{j}
#     core type: Operation
#     operator: 55
#     operands: 56
# 49. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 72
#     end_index: 58
# 50. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 72
#     end_index: 60
# 51. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 63
#     operands: 61
# 52. b_{_a} in V_{_a}
#     core type: Operation
#     operator: 63
#     operands: 62
# 53. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 54. K
#     core type: Variable
#     sub-expressions:
# 55. otimes
#     core type: Literal
#     sub-expressions:
# 56. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 65
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 66
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. _a -> c_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 69
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 62. (b_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 79, 68
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 65. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 72
#     end_index: 73
# 66. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 82
# 67. U_{_a}
#     core type: IndexedVar
# variable: 75
# index: 82
# 68. V_{_a}
#     core type: IndexedVar
# variable: 76
# index: 82
# 69. c_{_a}
#     core type: IndexedVar
# variable: 77
# index: 82
# 70. W_{_a}
#     core type: IndexedVar
# variable: 78
# index: 82
# 71. _a -> b_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 79
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. j
#     core type: Variable
#     sub-expressions:
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. U
#     core type: Variable
#     sub-expressions:
# 76. V
#     core type: Variable
#     sub-expressions:
# 77. c
#     core type: Variable
#     sub-expressions:
# 78. W
#     core type: Variable
#     sub-expressions:
# 79. b_{_a}
#     core type: IndexedVar
# variable: 80
# index: 82
# 80. b
#     core type: Variable
#     sub-expressions:
# 81. (_a)
#     core type: ExprTuple
#     sub-expressions: 82
# 82. _a
#     core type: Variable
#     sub-expressions:
