# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#norm_of_tensor_prod">norm_of_tensor_prod</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.tensors import norm_of_tensor_prod

# %%
# check that the built expression is the same as the stored expression
assert norm_of_tensor_prod.expr == stored_expr
assert norm_of_tensor_prod.expr._style_id == stored_expr._style_id
print("Passed sanity check: norm_of_tensor_prod matches stored_expr")
# Out:
# Passed sanity check: norm_of_tensor_prod matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{i \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = \left(\left \|a_{1}\right \| \cdot  \left \|a_{2}\right \| \cdot  \ldots \cdot  \left \|a_{i}\right \|\right)\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. (K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]]
#    core type: Lambda
#    parameter: 49
#    body: 3
# 3. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]
#    core type: Operation
#    operator: 20
#    operand: 5
# 4. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 60
#    body: 7
# 6. (i)
#    core type: ExprTuple
#    sub-expressions: 60
# 7. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]
#    core type: Operation
#    operator: 20
#    operand: 12
# 9. i in NaturalPos
#    core type: Operation
#    operator: 53
#    operands: 11
# 10. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 60, 13
# 12. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 59
#     end_index: 60
# 17. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 32
#     operands: 22
# 19. _a -> V_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 57
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 51\n    body: 25
# 24. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 59
#     end_index: 60
# 25. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 67
#     body: 29
# 27. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 38
# 34. in_c
#     core type: Literal
#     sub-expressions:
# 35. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 57, 39
# 36. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 61
#     operand: 46
# 37. ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 59
#     end_index: 60
# 39. InnerProdSpaces(K)
#     core type: Operation
#     operator: 44
#     operand: 49
# 40. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 46
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (||a_{1}||, ||a_{2}||, ..., ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 67
#     body: 48
# 44. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 45. (K)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. ||a_{1}||, ||a_{2}||, ..., ||a_{i}||
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 59
#     end_index: 60
# 48. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. K
#     core type: Variable
#     sub-expressions:
# 50. otimes
#     core type: Literal
#     sub-expressions:
# 51. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. _a -> ||a_{_a}||
#     core type: Lambda
#     parameter: 67
#     body: 56
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 64, 57
# 55. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 56. ||a_{_a}||
#     core type: Operation
#     operator: 61
#     operand: 64
# 57. V_{_a}
#     core type: IndexedVar
# variable: 63
# index: 67
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 64
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. Abs
#     core type: Literal
#     sub-expressions:
# 62. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 64
# 63. V
#     core type: Variable
#     sub-expressions:
# 64. a_{_a}
#     core type: IndexedVar
# variable: 65
# index: 67
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. _a
#     core type: Variable
#     sub-expressions:
