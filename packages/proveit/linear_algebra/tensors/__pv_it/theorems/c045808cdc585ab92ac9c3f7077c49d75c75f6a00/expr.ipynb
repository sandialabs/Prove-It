# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Conditional(Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), one), domains = sub_expr2, condition = And(ExprRange(sub_expr1, Equals(Norm(IndexedVar(a, sub_expr1)), one), one, i))).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), InSet(i, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)~|~\left(\left \|a_{1}\right \| = 1\right) \land  \left(\left \|a_{2}\right \| = 1\right) \land  \ldots \land  \left(\left \|a_{i}\right \| = 1\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = 1\right)\end{array}\right]\end{array} \textrm{ if } i \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]
#    core type: Operation
#    operator: 13
#    operand: 5
# 2. i in NaturalPos
#    core type: Operation
#    operator: 43
#    operands: 4
# 3. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 50, 6
# 5. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. (V_{1}, V_{2}, ..., V_{i})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. V_{1}, V_{2}, ..., V_{i}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 55
#    end_index: 50
# 10. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)
#     core type: Operation
#     operator: 13
#     operand: 16
# 11. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 33
#     operands: 15
# 12. _a -> V_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 47
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Lambda
#     parameters: 42\n    body: 18
# 17. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 55
#     end_index: 50
# 18. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 61
#     body: 22
# 20. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1
#     core type: Operation
#     operator: 52
#     operands: 23
# 21. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}) and ((||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: Operation
#     operator: 33
#     operands: 24
# 22. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 55
# 24. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}), (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. in_c
#     core type: Literal
#     sub-expressions:
# 26. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 47, 30
# 27. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 56
#     operand: 37
# 28. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 55
#     end_index: 50
# 29. (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. InnerProdSpaces(K)
#     core type: Operation
#     operator: 35
#     operand: 40
# 31. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 61
#     body: 38
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ((||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 39
# 35. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 36. (K)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. (||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 55
#     end_index: 50
# 40. K
#     core type: Variable
#     sub-expressions:
# 41. otimes
#     core type: Literal
#     sub-expressions:
# 42. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 58, 47
# 45. _a -> (||a_{_a}|| = 1)
#     core type: Lambda
#     parameter: 61
#     body: 48
# 46. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 55
#     end_index: 50
# 47. V_{_a}
#     core type: IndexedVar
# variable: 51
# index: 61
# 48. ||a_{_a}|| = 1
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 58
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. V
#     core type: Variable
#     sub-expressions:
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (||a_{_a}||, 1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. ||a_{_a}||
#     core type: Operation
#     operator: 56
#     operand: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. Abs
#     core type: Literal
#     sub-expressions:
# 57. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 58
# 58. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
