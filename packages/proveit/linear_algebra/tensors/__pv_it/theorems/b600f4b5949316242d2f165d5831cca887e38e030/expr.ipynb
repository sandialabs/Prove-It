# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, Lambda, i, j, k
from proveit.core_expr_types import U_1_to_i, V_1_to_j, W_1_to_k, a_1_to_i, b_1_to_j, c_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [U_1_to_i, V_1_to_j, W_1_to_k]
expr = Lambda(K, Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, TensorProd(b_1_to_j), c_1_to_k), TensorProd(a_1_to_i, b_1_to_j, c_1_to_k)).with_wrapping_at(1), domains = sub_expr1).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), domain = Natural))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{i, j, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(b_{1} \in V_{1}\right), \left(b_{2} \in V_{2}\right), \ldots, \left(b_{j} \in V_{j}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} b_{1} {\otimes}  b_{2} {\otimes}  \ldots {\otimes}  b_{j}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \end{array} \end{array}\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]]
#    core type: Lambda
#    parameter: 71
#    body: 1
# 1. forall_{i, j, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]]
#    core type: Operation
#    operator: 28
#    operand: 3
# 2. ((i, j, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (i, j, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 75, 90, 77
# 5. {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))]
#    core type: Operation
#    operator: 28
#    operand: 10
# 7. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 46
#    operands: 9
# 8. ((U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 11. i in Natural
#     core type: Operation
#     operator: 80
#     operands: 16
# 12. j in Natural
#     core type: Operation
#     operator: 80
#     operands: 17
# 13. k in Natural
#     core type: Operation
#     operator: 80
#     operands: 18
# 14. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j},W_{1}, W_{2}, ..., W_{k})
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 15. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)), (V_{1} in_c VecSpaces(K)) ,  (V_{2} in_c VecSpaces(K)) ,  ... ,  (V_{j} in_c VecSpaces(K)), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 22
#     condition: 23
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 75, 24
# 17. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 90, 24
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 77, 24
# 19. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 89
#     end_index: 75
# 20. V_{1}, V_{2}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 89
#     end_index: 90
# 21. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 89
#     end_index: 77
# 22. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 28
#     operand: 31
# 23. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K))and (V_{1} in_c VecSpaces(K)) and  (V_{2} in_c VecSpaces(K)) and  ... and  (V_{j} in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 46
#     operands: 30
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. _a -> U_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 84
# 26. _a -> V_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 85
# 27. _a -> W_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 87
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)),(V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K)),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 32, 33, 34
# 31. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 59\n    body: 35
# 32. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 89
#     end_index: 75
# 33. (V_{1} in_c VecSpaces(K)), (V_{2} in_c VecSpaces(K)), ..., (V_{j} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 89
#     end_index: 90
# 34. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 89
#     end_index: 77
# 35. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (b_{1} in V_{1}) ,  (b_{2} in V_{2}) ,  ... ,  (b_{j} in V_{j}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 39
#     condition: 40
# 36. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 99
#     body: 41
# 37. _a -> (V_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 99
#     body: 42
# 38. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 99
#     body: 43
# 39. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (b_{1} in V_{1}) and  (b_{2} in V_{2}) and  ... and  (b_{j} in V_{j})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 50
#     operands: 48
# 42. V_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 50
#     operands: 49
# 43. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 50
#     operands: 51
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 54, 55, 56
# 48. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 84, 57
# 49. (V_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 85, 57
# 50. in_c
#     core type: Literal
#     sub-expressions:
# 51. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 87, 57
# 52. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (b_{1} otimes  b_{2} otimes  ... otimes  b_{j})otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 72
#     operands: 58
# 53. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes b_{1} otimes  b_{2} otimes  ... otimes  b_{j}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 72
#     operands: 59
# 54. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 89
#     end_index: 75
# 55. (b_{1} in V_{1}), (b_{2} in V_{2}), ..., (b_{j} in V_{j})
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 89
#     end_index: 90
# 56. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 89
#     end_index: 77
# 57. VecSpaces(K)
#     core type: Operation
#     operator: 63
#     operand: 71
# 58. (a_{1}, a_{2}, ..., a_{i}, b_{1} otimes  b_{2} otimes  ... otimes  b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 66, 65, 67
# 59. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 66, 82, 67
# 60. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 99
#     body: 68
# 61. _a -> (b_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 99
#     body: 69
# 62. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 99
#     body: 70
# 63. VecSpaces
#     core type: Literal
#     sub-expressions:
# 64. (K)
#     core type: ExprTuple
#     sub-expressions: 71
# 65. b_{1} otimes  b_{2} otimes  ... otimes  b_{j}
#     core type: Operation
#     operator: 72
#     operands: 73
# 66. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 89
#     end_index: 75
# 67. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 89
#     end_index: 77
# 68. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 80
#     operands: 78
# 69. b_{_a} in V_{_a}
#     core type: Operation
#     operator: 80
#     operands: 79
# 70. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 80
#     operands: 81
# 71. K
#     core type: Variable
#     sub-expressions:
# 72. otimes
#     core type: Literal
#     sub-expressions:
# 73. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 82
# 74. _a -> a_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 83
# 75. i
#     core type: Variable
#     sub-expressions:
# 76. _a -> c_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 86
# 77. k
#     core type: Variable
#     sub-expressions:
# 78. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 79. (b_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 96, 85
# 80. in
#     core type: Literal
#     sub-expressions:
# 81. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 82. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 88
#     start_index: 89
#     end_index: 90
# 83. a_{_a}
#     core type: IndexedVar
# variable: 91
# index: 99
# 84. U_{_a}
#     core type: IndexedVar
# variable: 92
# index: 99
# 85. V_{_a}
#     core type: IndexedVar
# variable: 93
# index: 99
# 86. c_{_a}
#     core type: IndexedVar
# variable: 94
# index: 99
# 87. W_{_a}
#     core type: IndexedVar
# variable: 95
# index: 99
# 88. _a -> b_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 96
# 89. 1
#     core type: Literal
#     sub-expressions:
# 90. j
#     core type: Variable
#     sub-expressions:
# 91. a
#     core type: Variable
#     sub-expressions:
# 92. U
#     core type: Variable
#     sub-expressions:
# 93. V
#     core type: Variable
#     sub-expressions:
# 94. c
#     core type: Variable
#     sub-expressions:
# 95. W
#     core type: Variable
#     sub-expressions:
# 96. b_{_a}
#     core type: IndexedVar
# variable: 97
# index: 99
# 97. b
#     core type: Variable
#     sub-expressions:
# 98. (_a)
#     core type: ExprTuple
#     sub-expressions: 99
# 99. _a
#     core type: Variable
#     sub-expressions:
