# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, K, Lambda, V, b, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [i, k], instance_expr = Forall(instance_param_or_params = [U_1_to_i, V, W_1_to_k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k], instance_expr = Forall(instance_param_or_params = [b], instance_expr = Implies(Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, e_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, b, e_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), domain = Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{i, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(e_{1} \in W_{1}\right), \left(e_{2} \in W_{2}\right), \ldots, \left(e_{k} \in W_{k}\right)}~\\
# \left[\forall_{b \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} b{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right]\end{array}\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]]]
#    core type: Lambda
#    parameter: 67
#    body: 2
# 2. forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]]
#    core type: Operation
#    operator: 40
#    operand: 4
# 3. ((i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]] if i in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]] if i in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i, k)
#    core type: ExprTuple
#    sub-expressions: 103, 106
# 6. {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]] if i in Natural ,  k in Natural.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]
#    core type: Operation
#    operator: 40
#    operand: 11
# 8. (i in Natural) and (k in Natural)
#    core type: Operation
#    operator: 42
#    operands: 10
# 9. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (i in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 12. i in Natural
#     core type: Operation
#     operator: 74
#     operands: 16
# 13. k in Natural
#     core type: Operation
#     operator: 74
#     operands: 17
# 14. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#     core type: ExprTuple
#     sub-expressions: 18, 78, 19
# 15. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 20
#     condition: 21
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 103, 22
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 106, 22
# 18. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 105
#     end_index: 103
# 19. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 105
#     end_index: 106
# 20. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]
#     core type: Operation
#     operator: 40
#     operand: 27
# 21. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 42
#     operands: 26
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. _a -> U_{_a}
#     core type: Lambda
#     parameter: 116
#     body: 79
# 24. _a -> W_{_a}
#     core type: Lambda
#     parameter: 116
#     body: 80
# 25. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 27. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Lambda
#     parameters: 31\n    body: 32
# 28. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 105
#     end_index: 103
# 29. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 45
#     operands: 34
# 30. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 105
#     end_index: 106
# 31. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 95, 96, 97, 99
# 32. {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Conditional
#     value: 36
#     condition: 37
# 33. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 116
#     body: 38
# 34. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 78, 52
# 35. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 116
#     body: 39
# 36. forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))
#     core type: Operation
#     operator: 40
#     operand: 47
# 37. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (e_{1} in W_{1}) and  (e_{2} in W_{2}) and  ... and  (e_{k} in W_{k})
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 45
#     operands: 44
# 39. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. forall
#     core type: Literal
#     sub-expressions:
# 41. (b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.)
#     core type: ExprTuple
#     sub-expressions: 47
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50, 51
# 44. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 79, 52
# 45. in_c
#     core type: Literal
#     sub-expressions:
# 46. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 80, 52
# 47. b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Lambda
#     parameter: 98
#     body: 54
# 48. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 105
#     end_index: 103
# 49. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 105
#     end_index: 106
# 50. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 105
#     end_index: 103
# 51. (e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 105
#     end_index: 106
# 52. VecSpaces(K)
#     core type: Operation
#     operator: 59
#     operand: 67
# 53. (b)
#     core type: ExprTuple
#     sub-expressions: 98
# 54. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Conditional
#     value: 61
#     condition: 62
# 55. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 116
#     body: 63
# 56. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 116
#     body: 64
# 57. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 116
#     body: 65
# 58. _a -> (e_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 116
#     body: 66
# 59. VecSpaces
#     core type: Literal
#     sub-expressions:
# 60. (K)
#     core type: ExprTuple
#     sub-expressions: 67
# 61. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: Operation
#     operator: 68
#     operands: 69
# 62. b in V
#     core type: Operation
#     operator: 74
#     operands: 70
# 63. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 74
#     operands: 71
# 64. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 74
#     operands: 72
# 65. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 74
#     operands: 73
# 66. e_{_a} in W_{_a}
#     core type: Operation
#     operator: 74
#     operands: 75
# 67. K
#     core type: Variable
#     sub-expressions:
# 68. =>
#     core type: Literal
#     sub-expressions:
# 69. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 70. (b, V)
#     core type: ExprTuple
#     sub-expressions: 98, 78
# 71. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 107, 79
# 72. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 108, 80
# 73. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 109, 79
# 74. in
#     core type: Literal
#     sub-expressions:
# 75. (e_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 110, 80
# 76. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 82
#     operands: 81
# 77. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 82
#     operands: 83
# 78. V
#     core type: Variable
#     sub-expressions:
# 79. U_{_a}
#     core type: IndexedVar
# variable: 84
# index: 116
# 80. W_{_a}
#     core type: IndexedVar
# variable: 85
# index: 116
# 81. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 82. =
#     core type: Literal
#     sub-expressions:
# 83. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 84. U
#     core type: Variable
#     sub-expressions:
# 85. W
#     core type: Variable
#     sub-expressions:
# 86. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 93
#     operands: 90
# 87. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 93
#     operands: 91
# 88. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 93
#     operands: 92
# 89. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 93
#     operands: 94
# 90. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 91. (d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 97, 99
# 92. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 95, 98, 96
# 93. otimes
#     core type: Literal
#     sub-expressions:
# 94. (d_{1}, d_{2}, ..., d_{i}, b,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 97, 98, 99
# 95. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 100
#     start_index: 105
#     end_index: 103
# 96. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 101
#     start_index: 105
#     end_index: 106
# 97. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 102
#     start_index: 105
#     end_index: 103
# 98. b
#     core type: Variable
#     sub-expressions:
# 99. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 104
#     start_index: 105
#     end_index: 106
# 100. _a -> a_{_a}
#      core type: Lambda
#      parameter: 116
#      body: 107
# 101. _a -> c_{_a}
#      core type: Lambda
#      parameter: 116
#      body: 108
# 102. _a -> d_{_a}
#      core type: Lambda
#      parameter: 116
#      body: 109
# 103. i
#      core type: Variable
#      sub-expressions:
# 104. _a -> e_{_a}
#      core type: Lambda
#      parameter: 116
#      body: 110
# 105. 1
#      core type: Literal
#      sub-expressions:
# 106. k
#      core type: Variable
#      sub-expressions:
# 107. a_{_a}
#      core type: IndexedVar
# variable: 111
# index: 116
# 108. c_{_a}
#      core type: IndexedVar
# variable: 112
# index: 116
# 109. d_{_a}
#      core type: IndexedVar
# variable: 113
# index: 116
# 110. e_{_a}
#      core type: IndexedVar
# variable: 114
# index: 116
# 111. a
#      core type: Variable
#      sub-expressions:
# 112. c
#      core type: Variable
#      sub-expressions:
# 113. d
#      core type: Variable
#      sub-expressions:
# 114. e
#      core type: Variable
#      sub-expressions:
# 115. (_a)
#      core type: ExprTuple
#      sub-expressions: 116
# 116. _a
#      core type: Variable
#      sub-expressions:
