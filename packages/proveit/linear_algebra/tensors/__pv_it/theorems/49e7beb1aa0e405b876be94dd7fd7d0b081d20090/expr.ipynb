# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Mult, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), Mult(ExprRange(sub_expr1, Norm(IndexedVar(a, sub_expr1)), one, i))), domains = sub_expr2).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = \left(\left \|a_{1}\right \| \cdot  \left \|a_{2}\right \| \cdot  \ldots \cdot  \left \|a_{i}\right \|\right)\right)\end{array}\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Lambda
#    parameter: 57
#    body: 4
# 3. (i)
#    core type: ExprTuple
#    sub-expressions: 57
# 4. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]
#    core type: Operation
#    operator: 17
#    operand: 9
# 6. i in NaturalPos
#    core type: Operation
#    operator: 50
#    operands: 8
# 7. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 57, 10
# 9. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 56
#     end_index: 57
# 14. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 29
#     operands: 19
# 16. _a -> V_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 54
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 48\n    body: 22
# 21. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 56
#     end_index: 57
# 22. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 24
#     condition: 25
# 23. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 64
#     body: 26
# 24. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 35
# 31. in_c
#     core type: Literal
#     sub-expressions:
# 32. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 54, 36
# 33. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 58
#     operand: 43
# 34. ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 56
#     end_index: 57
# 36. InnerProdSpaces(K)
#     core type: Operation
#     operator: 41
#     operand: 46
# 37. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 43
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (||a_{1}||, ||a_{2}||, ..., ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 44
# 40. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 64
#     body: 45
# 41. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 42. (K)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. ||a_{1}||, ||a_{2}||, ..., ||a_{i}||
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 56
#     end_index: 57
# 45. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. K
#     core type: Variable
#     sub-expressions:
# 47. otimes
#     core type: Literal
#     sub-expressions:
# 48. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 52
# 49. _a -> ||a_{_a}||
#     core type: Lambda
#     parameter: 64
#     body: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 61, 54
# 52. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 53. ||a_{_a}||
#     core type: Operation
#     operator: 58
#     operand: 61
# 54. V_{_a}
#     core type: IndexedVar
# variable: 60
# index: 64
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 61
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. Abs
#     core type: Literal
#     sub-expressions:
# 59. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 61
# 60. V
#     core type: Variable
#     sub-expressions:
# 61. a_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
