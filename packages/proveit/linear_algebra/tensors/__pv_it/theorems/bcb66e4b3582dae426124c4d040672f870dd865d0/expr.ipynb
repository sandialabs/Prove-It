# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, b, e, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces, VecZero
from proveit.logic import And, Equals, Forall, Implies, InSet, NotEquals
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [U_1_to_i, V, W_1_to_k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k], instance_expr = Forall(instance_param_or_params = [b, e], instance_expr = Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V, conditions = [Equals(b, e), NotEquals(b, VecZero(V))]), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), And(InSet(i, Natural), InSet(k, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(f_{1} \in W_{1}\right), \left(f_{2} \in W_{2}\right), \ldots, \left(f_{k} \in W_{k}\right)}~\\
# \left[\forall_{b, e \in V~|~b = e, b \neq \vec{0}\left(V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right]\end{array} \textrm{ if } i \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))]] if i in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))]]
#    core type: Operation
#    operator: 34
#    operand: 5
# 2. (i in Natural) and (k in Natural)
#    core type: Operation
#    operator: 62
#    operands: 4
# 3. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. i in Natural
#    core type: Operation
#    operator: 79
#    operands: 10
# 7. k in Natural
#    core type: Operation
#    operator: 79
#    operands: 11
# 8. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 12, 105, 13
# 9. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 14
#    condition: 15
# 10. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 109, 16
# 11. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 112, 16
# 12. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 111
#     end_index: 109
# 13. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 111
#     end_index: 112
# 14. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))]
#     core type: Operation
#     operator: 34
#     operand: 21
# 15. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 62
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. _a -> U_{_a}
#     core type: Lambda
#     parameter: 122
#     body: 74
# 18. _a -> W_{_a}
#     core type: Lambda
#     parameter: 122
#     body: 75
# 19. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 21. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#     core type: Lambda
#     parameters: 25\n    body: 26
# 22. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 111
#     end_index: 109
# 23. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operands: 28
# 24. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 111
#     end_index: 112
# 25. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 101, 102, 103, 104
# 26. {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 122
#     body: 32
# 28. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 105, 45
# 29. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 122
#     body: 33
# 30. forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))
#     core type: Operation
#     operator: 34
#     operand: 40
# 31. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (f_{1} in W_{1}) and  (f_{2} in W_{2}) and  ... and  (f_{k} in W_{k})
#     core type: Operation
#     operator: 62
#     operands: 36
# 32. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operands: 37
# 33. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. forall
#     core type: Literal
#     sub-expressions:
# 35. ((b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43, 44
# 37. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 74, 45
# 38. in_c
#     core type: Literal
#     sub-expressions:
# 39. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 75, 45
# 40. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Lambda
#     parameters: 82\n    body: 46
# 41. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 111
#     end_index: 109
# 42. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 111
#     end_index: 112
# 43. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 111
#     end_index: 109
# 44. (f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 111
#     end_index: 112
# 45. VecSpaces(K)
#     core type: Operation
#     operator: 51
#     operand: 59
# 46. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Conditional
#     value: 53
#     condition: 54
# 47. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 122
#     body: 55
# 48. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 122
#     body: 56
# 49. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 122
#     body: 57
# 50. _a -> (f_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 122
#     body: 58
# 51. VecSpaces
#     core type: Literal
#     sub-expressions:
# 52. (K)
#     core type: ExprTuple
#     sub-expressions: 59
# 53. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: Operation
#     operator: 60
#     operands: 61
# 54. (b in V) and (e in V) and (b = e) and (b != 0(V))
#     core type: Operation
#     operator: 62
#     operands: 63
# 55. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 79
#     operands: 64
# 56. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 79
#     operands: 65
# 57. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 79
#     operands: 66
# 58. f_{_a} in W_{_a}
#     core type: Operation
#     operator: 79
#     operands: 67
# 59. K
#     core type: Variable
#     sub-expressions:
# 60. =>
#     core type: Literal
#     sub-expressions:
# 61. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 62. and
#     core type: Literal
#     sub-expressions:
# 63. (b in V, e in V, b = e, b != 0(V))
#     core type: ExprTuple
#     sub-expressions: 70, 71, 72, 73
# 64. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 113, 74
# 65. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 114, 75
# 66. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 115, 74
# 67. (f_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 116, 75
# 68. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 81
#     operands: 76
# 69. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 81
#     operands: 77
# 70. b in V
#     core type: Operation
#     operator: 79
#     operands: 78
# 71. e in V
#     core type: Operation
#     operator: 79
#     operands: 80
# 72. b = e
#     core type: Operation
#     operator: 81
#     operands: 82
# 73. b != 0(V)
#     core type: Operation
#     operator: 83
#     operands: 84
# 74. U_{_a}
#     core type: IndexedVar
# variable: 85
# index: 122
# 75. W_{_a}
#     core type: IndexedVar
# variable: 86
# index: 122
# 76. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 77. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 78. (b, V)
#     core type: ExprTuple
#     sub-expressions: 99, 105
# 79. in
#     core type: Literal
#     sub-expressions:
# 80. (e, V)
#     core type: ExprTuple
#     sub-expressions: 100, 105
# 81. =
#     core type: Literal
#     sub-expressions:
# 82. (b, e)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 83. !=
#     core type: Literal
#     sub-expressions:
# 84. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 99, 91
# 85. U
#     core type: Variable
#     sub-expressions:
# 86. W
#     core type: Variable
#     sub-expressions:
# 87. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 95
#     operands: 92
# 88. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 95
#     operands: 93
# 89. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 95
#     operands: 94
# 90. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 95
#     operands: 96
# 91. 0(V)
#     core type: Operation
#     operator: 97
#     operand: 105
# 92. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 101, 99, 102
# 93. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 103, 100, 104
# 94. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 95. otimes
#     core type: Literal
#     sub-expressions:
# 96. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 103, 104
# 97. 0
#     core type: Literal
#     sub-expressions:
# 98. (V)
#     core type: ExprTuple
#     sub-expressions: 105
# 99. b
#     core type: Variable
#     sub-expressions:
# 100. e
#      core type: Variable
#      sub-expressions:
# 101. a_{1}, a_{2}, ..., a_{i}
#      core type: ExprRange
#      lambda_map: 106
#      start_index: 111
#      end_index: 109
# 102. c_{1}, c_{2}, ..., c_{k}
#      core type: ExprRange
#      lambda_map: 107
#      start_index: 111
#      end_index: 112
# 103. d_{1}, d_{2}, ..., d_{i}
#      core type: ExprRange
#      lambda_map: 108
#      start_index: 111
#      end_index: 109
# 104. f_{1}, f_{2}, ..., f_{k}
#      core type: ExprRange
#      lambda_map: 110
#      start_index: 111
#      end_index: 112
# 105. V
#      core type: Variable
#      sub-expressions:
# 106. _a -> a_{_a}
#      core type: Lambda
#      parameter: 122
#      body: 113
# 107. _a -> c_{_a}
#      core type: Lambda
#      parameter: 122
#      body: 114
# 108. _a -> d_{_a}
#      core type: Lambda
#      parameter: 122
#      body: 115
# 109. i
#      core type: Variable
#      sub-expressions:
# 110. _a -> f_{_a}
#      core type: Lambda
#      parameter: 122
#      body: 116
# 111. 1
#      core type: Literal
#      sub-expressions:
# 112. k
#      core type: Variable
#      sub-expressions:
# 113. a_{_a}
#      core type: IndexedVar
# variable: 117
# index: 122
# 114. c_{_a}
#      core type: IndexedVar
# variable: 118
# index: 122
# 115. d_{_a}
#      core type: IndexedVar
# variable: 119
# index: 122
# 116. f_{_a}
#      core type: IndexedVar
# variable: 120
# index: 122
# 117. a
#      core type: Variable
#      sub-expressions:
# 118. c
#      core type: Variable
#      sub-expressions:
# 119. d
#      core type: Variable
#      sub-expressions:
# 120. f
#      core type: Variable
#      sub-expressions:
# 121. (_a)
#      core type: ExprTuple
#      sub-expressions: 122
# 122. _a
#      core type: Variable
#      sub-expressions:
