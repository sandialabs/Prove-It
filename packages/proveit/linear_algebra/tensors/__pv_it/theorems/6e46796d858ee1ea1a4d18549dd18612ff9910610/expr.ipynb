# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, b, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [U_1_to_i, V, W_1_to_k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, e_1_to_k], instance_expr = Forall(instance_param_or_params = [b], instance_expr = Implies(Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, e_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, b, e_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), And(InSet(i, Natural), InSet(k, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(e_{1} \in W_{1}\right), \left(e_{2} \in W_{2}\right), \ldots, \left(e_{k} \in W_{k}\right)}~\\
# \left[\forall_{b \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} b{\otimes} e_{1} {\otimes}  e_{2} {\otimes}  \ldots {\otimes}  e_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array}\right]\end{array} \textrm{ if } i \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]] if i in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]]
#    core type: Operation
#    operator: 34
#    operand: 5
# 2. (i in Natural) and (k in Natural)
#    core type: Operation
#    operator: 36
#    operands: 4
# 3. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. i in Natural
#    core type: Operation
#    operator: 68
#    operands: 10
# 7. k in Natural
#    core type: Operation
#    operator: 68
#    operands: 11
# 8. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 12, 72, 13
# 9. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 14
#    condition: 15
# 10. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 97, 16
# 11. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 100, 16
# 12. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 99
#     end_index: 97
# 13. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 99
#     end_index: 100
# 14. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})} [forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))]
#     core type: Operation
#     operator: 34
#     operand: 21
# 15. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 36
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. _a -> U_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 73
# 18. _a -> W_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 74
# 19. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 21. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, e_{1}, e_{2}, ..., e_{k}) -> {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Lambda
#     parameters: 25\n    body: 26
# 22. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 99
#     end_index: 97
# 23. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 39
#     operands: 28
# 24. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 99
#     end_index: 100
# 25. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 89, 90, 91, 93
# 26. {forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (e_{1} in W_{1}) ,  (e_{2} in W_{2}) ,  ... ,  (e_{k} in W_{k}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 110
#     body: 32
# 28. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 72, 46
# 29. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 110
#     body: 33
# 30. forall_{b in V} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})))
#     core type: Operation
#     operator: 34
#     operand: 41
# 31. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (e_{1} in W_{1}) and  (e_{2} in W_{2}) and  ... and  (e_{k} in W_{k})
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 39
#     operands: 38
# 33. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. forall
#     core type: Literal
#     sub-expressions:
# 35. (b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.)
#     core type: ExprTuple
#     sub-expressions: 41
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 42, 43, 44, 45
# 38. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 73, 46
# 39. in_c
#     core type: Literal
#     sub-expressions:
# 40. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 74, 46
# 41. b -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Lambda
#     parameter: 92
#     body: 48
# 42. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 99
#     end_index: 97
# 43. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 99
#     end_index: 100
# 44. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 99
#     end_index: 97
# 45. (e_{1} in W_{1}), (e_{2} in W_{2}), ..., (e_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 99
#     end_index: 100
# 46. VecSpaces(K)
#     core type: Operation
#     operator: 53
#     operand: 61
# 47. (b)
#     core type: ExprTuple
#     sub-expressions: 92
# 48. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) if b in V.
#     core type: Conditional
#     value: 55
#     condition: 56
# 49. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 110
#     body: 57
# 50. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 110
#     body: 58
# 51. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 110
#     body: 59
# 52. _a -> (e_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 110
#     body: 60
# 53. VecSpaces
#     core type: Literal
#     sub-expressions:
# 54. (K)
#     core type: ExprTuple
#     sub-expressions: 61
# 55. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: Operation
#     operator: 62
#     operands: 63
# 56. b in V
#     core type: Operation
#     operator: 68
#     operands: 64
# 57. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 68
#     operands: 65
# 58. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 68
#     operands: 66
# 59. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 68
#     operands: 67
# 60. e_{_a} in W_{_a}
#     core type: Operation
#     operator: 68
#     operands: 69
# 61. K
#     core type: Variable
#     sub-expressions:
# 62. =>
#     core type: Literal
#     sub-expressions:
# 63. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 64. (b, V)
#     core type: ExprTuple
#     sub-expressions: 92, 72
# 65. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 101, 73
# 66. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 102, 74
# 67. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 103, 73
# 68. in
#     core type: Literal
#     sub-expressions:
# 69. (e_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 104, 74
# 70. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 76
#     operands: 75
# 71. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. V
#     core type: Variable
#     sub-expressions:
# 73. U_{_a}
#     core type: IndexedVar
# variable: 78
# index: 110
# 74. W_{_a}
#     core type: IndexedVar
# variable: 79
# index: 110
# 75. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 76. =
#     core type: Literal
#     sub-expressions:
# 77. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k})
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 78. U
#     core type: Variable
#     sub-expressions:
# 79. W
#     core type: Variable
#     sub-expressions:
# 80. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 87
#     operands: 84
# 81. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 87
#     operands: 85
# 82. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 87
#     operands: 86
# 83. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes botimes e_{1} otimes  e_{2} otimes  ... otimes  e_{k}
#     core type: Operation
#     operator: 87
#     operands: 88
# 84. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 85. (d_{1}, d_{2}, ..., d_{i},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 91, 93
# 86. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 89, 92, 90
# 87. otimes
#     core type: Literal
#     sub-expressions:
# 88. (d_{1}, d_{2}, ..., d_{i}, b,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 91, 92, 93
# 89. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 94
#     start_index: 99
#     end_index: 97
# 90. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 95
#     start_index: 99
#     end_index: 100
# 91. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 96
#     start_index: 99
#     end_index: 97
# 92. b
#     core type: Variable
#     sub-expressions:
# 93. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 98
#     start_index: 99
#     end_index: 100
# 94. _a -> a_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 101
# 95. _a -> c_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 102
# 96. _a -> d_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 103
# 97. i
#     core type: Variable
#     sub-expressions:
# 98. _a -> e_{_a}
#     core type: Lambda
#     parameter: 110
#     body: 104
# 99. 1
#     core type: Literal
#     sub-expressions:
# 100. k
#      core type: Variable
#      sub-expressions:
# 101. a_{_a}
#      core type: IndexedVar
# variable: 105
# index: 110
# 102. c_{_a}
#      core type: IndexedVar
# variable: 106
# index: 110
# 103. d_{_a}
#      core type: IndexedVar
# variable: 107
# index: 110
# 104. e_{_a}
#      core type: IndexedVar
# variable: 108
# index: 110
# 105. a
#      core type: Variable
#      sub-expressions:
# 106. c
#      core type: Variable
#      sub-expressions:
# 107. d
#      core type: Variable
#      sub-expressions:
# 108. e
#      core type: Variable
#      sub-expressions:
# 109. (_a)
#      core type: ExprTuple
#      sub-expressions: 110
# 110. _a
#      core type: Variable
#      sub-expressions:
