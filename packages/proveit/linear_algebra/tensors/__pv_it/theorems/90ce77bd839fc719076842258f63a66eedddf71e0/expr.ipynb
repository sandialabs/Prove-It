# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import And, Equals, Forall
from proveit.numbers import NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), one), domains = sub_expr2, condition = And(ExprRange(sub_expr1, Equals(Norm(IndexedVar(a, sub_expr1)), one), one, i))).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{i \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)~|~\left(\left \|a_{1}\right \| = 1\right) \land  \left(\left \|a_{2}\right \| = 1\right) \land  \ldots \land  \left(\left \|a_{i}\right \| = 1\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = 1\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. (K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]]
#    core type: Lambda
#    parameter: 47
#    body: 3
# 3. forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]
#    core type: Operation
#    operator: 20
#    operand: 5
# 4. (i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. i -> {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.
#    core type: Lambda
#    parameter: 57
#    body: 7
# 6. (i)
#    core type: ExprTuple
#    sub-expressions: 57
# 7. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)] if i in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]
#    core type: Operation
#    operator: 20
#    operand: 12
# 9. i in NaturalPos
#    core type: Operation
#    operator: 50
#    operands: 11
# 10. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 57, 13
# 12. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. (V_{1}, V_{2}, ..., V_{i})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. V_{1}, V_{2}, ..., V_{i}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 62
#     end_index: 57
# 17. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 40
#     operands: 22
# 19. _a -> V_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 54
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Lambda
#     parameters: 49\n    body: 25
# 24. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 62
#     end_index: 57
# 25. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1 if (a_{1} in V_{1}) ,  (a_{2} in V_{2}) ,  ... ,  (a_{i} in V_{i}) ,  (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1).
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 68
#     body: 29
# 27. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1
#     core type: Operation
#     operator: 59
#     operands: 30
# 28. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}) and ((||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: Operation
#     operator: 40
#     operands: 31
# 29. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, 1)
#     core type: ExprTuple
#     sub-expressions: 34, 62
# 31. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}), (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. in_c
#     core type: Literal
#     sub-expressions:
# 33. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 54, 37
# 34. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 63
#     operand: 44
# 35. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 62
#     end_index: 57
# 36. (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. InnerProdSpaces(K)
#     core type: Operation
#     operator: 42
#     operand: 47
# 38. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 44
# 39. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 68
#     body: 45
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. ((||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1))
#     core type: ExprTuple
#     sub-expressions: 46
# 42. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 43. (K)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (||a_{1}|| = 1), (||a_{2}|| = 1), ..., (||a_{i}|| = 1)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 62
#     end_index: 57
# 47. K
#     core type: Variable
#     sub-expressions:
# 48. otimes
#     core type: Literal
#     sub-expressions:
# 49. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 65, 54
# 52. _a -> (||a_{_a}|| = 1)
#     core type: Lambda
#     parameter: 68
#     body: 55
# 53. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 62
#     end_index: 57
# 54. V_{_a}
#     core type: IndexedVar
# variable: 58
# index: 68
# 55. ||a_{_a}|| = 1
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. _a -> a_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 65
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. V
#     core type: Variable
#     sub-expressions:
# 59. =
#     core type: Literal
#     sub-expressions:
# 60. (||a_{_a}||, 1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. ||a_{_a}||
#     core type: Operation
#     operator: 63
#     operand: 65
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. Abs
#     core type: Literal
#     sub-expressions:
# 64. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 65
# 65. a_{_a}
#     core type: IndexedVar
# variable: 66
# index: 68
# 66. a
#     core type: Variable
#     sub-expressions:
# 67. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. _a
#     core type: Variable
#     sub-expressions:
