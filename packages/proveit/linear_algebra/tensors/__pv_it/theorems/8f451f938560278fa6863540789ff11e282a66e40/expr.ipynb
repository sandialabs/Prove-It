# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, U, V, Variable, W, b, e, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecSpaces, VecZero
from proveit.logic import And, Equals, Forall, Implies, InClass, NotEquals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = VecSpaces(K)
expr = Conditional(Forall(instance_param_or_params = [a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k], instance_expr = Forall(instance_param_or_params = [b, e], instance_expr = Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), domain = V, conditions = [Equals(b, e), NotEquals(b, VecZero(V))]), domains = [U_1_to_i, W_1_to_k, U_1_to_i, W_1_to_k]).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(U, sub_expr1), sub_expr2), one, i), InClass(V, sub_expr2), ExprRange(sub_expr1, InClass(IndexedVar(W, sub_expr1), sub_expr2), one, k)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right),\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right),\left(d_{1} \in U_{1}\right), \left(d_{2} \in U_{2}\right), \ldots, \left(d_{i} \in U_{i}\right),\left(f_{1} \in W_{1}\right), \left(f_{2} \in W_{2}\right), \ldots, \left(f_{k} \in W_{k}\right)}~\\
# \left[\forall_{b, e \in V~|~b = e, b \neq \vec{0}\left(V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\right]\end{array} \textrm{ if } \left(U_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(U_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(U_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))] if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})} [forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))]
#    core type: Operation
#    operator: 18
#    operand: 5
# 2. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 46
#    operands: 4
# 3. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{i}, f_{1}, f_{2}, ..., f_{k}) -> {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 6. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 95
#    end_index: 93
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 22
#    operands: 12
# 8. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 95
#    end_index: 96
# 9. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#    core type: ExprTuple
#    sub-expressions: 85, 86, 87, 88
# 10. {forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}), (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}), (d_{1} in U_{1}) ,  (d_{2} in U_{2}) ,  ... ,  (d_{i} in U_{i}), (f_{1} in W_{1}) ,  (f_{2} in W_{2}) ,  ... ,  (f_{k} in W_{k}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 106
#     body: 16
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 89, 29
# 13. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 106
#     body: 17
# 14. forall_{b, e in V | b = e, b != 0(V)} (((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})))
#     core type: Operation
#     operator: 18
#     operand: 24
# 15. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i})and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})and (d_{1} in U_{1}) and  (d_{2} in U_{2}) and  ... and  (d_{i} in U_{i})and (f_{1} in W_{1}) and  (f_{2} in W_{2}) and  ... and  (f_{k} in W_{k})
#     core type: Operation
#     operator: 46
#     operands: 20
# 16. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 22
#     operands: 21
# 17. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}),(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}),(d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i}),(f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 21. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 58, 29
# 22. in_c
#     core type: Literal
#     sub-expressions:
# 23. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 59, 29
# 24. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Lambda
#     parameters: 66\n    body: 30
# 25. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 95
#     end_index: 93
# 26. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 95
#     end_index: 96
# 27. (d_{1} in U_{1}), (d_{2} in U_{2}), ..., (d_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 95
#     end_index: 93
# 28. (f_{1} in W_{1}), (f_{2} in W_{2}), ..., (f_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 95
#     end_index: 96
# 29. VecSpaces(K)
#     core type: Operation
#     operator: 35
#     operand: 43
# 30. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#     core type: Conditional
#     value: 37
#     condition: 38
# 31. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 106
#     body: 39
# 32. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 106
#     body: 40
# 33. _a -> (d_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 106
#     body: 41
# 34. _a -> (f_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 106
#     body: 42
# 35. VecSpaces
#     core type: Literal
#     sub-expressions:
# 36. (K)
#     core type: ExprTuple
#     sub-expressions: 43
# 37. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. (b in V) and (e in V) and (b = e) and (b != 0(V))
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 63
#     operands: 48
# 40. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 63
#     operands: 49
# 41. d_{_a} in U_{_a}
#     core type: Operation
#     operator: 63
#     operands: 50
# 42. f_{_a} in W_{_a}
#     core type: Operation
#     operator: 63
#     operands: 51
# 43. K
#     core type: Variable
#     sub-expressions:
# 44. =>
#     core type: Literal
#     sub-expressions:
# 45. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. (b in V, e in V, b = e, b != 0(V))
#     core type: ExprTuple
#     sub-expressions: 54, 55, 56, 57
# 48. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 97, 58
# 49. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 98, 59
# 50. (d_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 99, 58
# 51. (f_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 100, 59
# 52. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 65
#     operands: 60
# 53. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: Operation
#     operator: 65
#     operands: 61
# 54. b in V
#     core type: Operation
#     operator: 63
#     operands: 62
# 55. e in V
#     core type: Operation
#     operator: 63
#     operands: 64
# 56. b = e
#     core type: Operation
#     operator: 65
#     operands: 66
# 57. b != 0(V)
#     core type: Operation
#     operator: 67
#     operands: 68
# 58. U_{_a}
#     core type: IndexedVar
# variable: 69
# index: 106
# 59. W_{_a}
#     core type: IndexedVar
# variable: 70
# index: 106
# 60. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 61. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 62. (b, V)
#     core type: ExprTuple
#     sub-expressions: 83, 89
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (e, V)
#     core type: ExprTuple
#     sub-expressions: 84, 89
# 65. =
#     core type: Literal
#     sub-expressions:
# 66. (b, e)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 67. !=
#     core type: Literal
#     sub-expressions:
# 68. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 83, 75
# 69. U
#     core type: Variable
#     sub-expressions:
# 70. W
#     core type: Variable
#     sub-expressions:
# 71. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 79
#     operands: 76
# 72. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 79
#     operands: 77
# 73. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 79
#     operands: 78
# 74. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 79
#     operands: 80
# 75. 0(V)
#     core type: Operation
#     operator: 81
#     operand: 89
# 76. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 85, 83, 86
# 77. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 87, 84, 88
# 78. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 79. otimes
#     core type: Literal
#     sub-expressions:
# 80. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 81. 0
#     core type: Literal
#     sub-expressions:
# 82. (V)
#     core type: ExprTuple
#     sub-expressions: 89
# 83. b
#     core type: Variable
#     sub-expressions:
# 84. e
#     core type: Variable
#     sub-expressions:
# 85. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 95
#     end_index: 93
# 86. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 91
#     start_index: 95
#     end_index: 96
# 87. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 92
#     start_index: 95
#     end_index: 93
# 88. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 94
#     start_index: 95
#     end_index: 96
# 89. V
#     core type: Variable
#     sub-expressions:
# 90. _a -> a_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 97
# 91. _a -> c_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 98
# 92. _a -> d_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 99
# 93. i
#     core type: Variable
#     sub-expressions:
# 94. _a -> f_{_a}
#     core type: Lambda
#     parameter: 106
#     body: 100
# 95. 1
#     core type: Literal
#     sub-expressions:
# 96. k
#     core type: Variable
#     sub-expressions:
# 97. a_{_a}
#     core type: IndexedVar
# variable: 101
# index: 106
# 98. c_{_a}
#     core type: IndexedVar
# variable: 102
# index: 106
# 99. d_{_a}
#     core type: IndexedVar
# variable: 103
# index: 106
# 100. f_{_a}
#      core type: IndexedVar
# variable: 104
# index: 106
# 101. a
#      core type: Variable
#      sub-expressions:
# 102. c
#      core type: Variable
#      sub-expressions:
# 103. d
#      core type: Variable
#      sub-expressions:
# 104. f
#      core type: Variable
#      sub-expressions:
# 105. (_a)
#      core type: ExprTuple
#      sub-expressions: 106
# 106. _a
#      core type: Variable
#      sub-expressions:
