# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Lambda, U, V, Variable, W, alpha, b, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k
from proveit.linear_algebra import ScalarMult, TensorProd, VecSpaces
from proveit.logic import And, Equals, Forall, InClass
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = VecSpaces(K)
sub_expr3 = [U_1_to_i, V, W_1_to_k]
expr = Lambda(sub_expr3, Conditional(Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, ScalarMult(alpha, b), c_1_to_k), ScalarMult(alpha, TensorProd(a_1_to_i, b, c_1_to_k))).with_wrapping_at(1), domains = sub_expr3).with_wrapping(), And(ExprRange(sub_expr1, InClass(IndexedVar(U, sub_expr1), sub_expr2), one, i), InClass(V, sub_expr2), ExprRange(sub_expr1, InClass(IndexedVar(W, sub_expr1), sub_expr2), one, k))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k}\right) \mapsto \left\{\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right), b \in V,\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(\alpha \cdot b\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(\alpha \cdot \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right)\right) \end{array} \end{array}\right)\end{array} \textrm{ if } \left(U_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(U_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(U_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right), \left(W_{1} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \left(W_{2} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right) ,  \ldots ,  \left(W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 47, 4
# 2. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#    core type: Conditional
#    value: 5
#    condition: 6
# 3. U_{1}, U_{2}, ..., U_{i}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 66
#    end_index: 64
# 4. W_{1}, W_{2}, ..., W_{k}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 66
#    end_index: 67
# 5. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))
#    core type: Operation
#    operator: 9
#    operand: 12
# 6. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#    core type: Operation
#    operator: 26
#    operands: 11
# 7. _a -> U_{_a}
#    core type: Lambda
#    parameter: 75
#    body: 61
# 8. _a -> W_{_a}
#    core type: Lambda
#    parameter: 75
#    body: 62
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 12. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 53\n    body: 16
# 13. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 66
#     end_index: 64
# 14. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 29
#     operands: 18
# 15. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 66
#     end_index: 67
# 16. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 75
#     body: 22
# 18. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 47, 36
# 19. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 75
#     body: 23
# 20. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i}) and (b in V)and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 33, 34, 35
# 28. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 61, 36
# 29. in_c
#     core type: Literal
#     sub-expressions:
# 30. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 62, 36
# 31. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 52
#     operands: 37
# 32. alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 50
#     operands: 38
# 33. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 66
#     end_index: 64
# 34. b in V
#     core type: Operation
#     operator: 55
#     operands: 40
# 35. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 66
#     end_index: 67
# 36. VecSpaces(K)
#     core type: Operation
#     operator: 42
#     operand: 49
# 37. (a_{1}, a_{2}, ..., a_{i}, alpha * b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 58, 44, 60
# 38. (alpha, a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 57, 45
# 39. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 75
#     body: 46
# 40. (b, V)
#     core type: ExprTuple
#     sub-expressions: 59, 47
# 41. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 75
#     body: 48
# 42. VecSpaces
#     core type: Literal
#     sub-expressions:
# 43. (K)
#     core type: ExprTuple
#     sub-expressions: 49
# 44. alpha * b
#     core type: Operation
#     operator: 50
#     operands: 51
# 45. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 55
#     operands: 54
# 47. V
#     core type: Variable
#     sub-expressions:
# 48. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 49. K
#     core type: Variable
#     sub-expressions:
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (alpha, b)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 52. otimes
#     core type: Literal
#     sub-expressions:
# 53. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 58, 59, 60
# 54. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 70, 61
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 71, 62
# 57. alpha
#     core type: Variable
#     sub-expressions:
# 58. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 66
#     end_index: 64
# 59. b
#     core type: Variable
#     sub-expressions:
# 60. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 66
#     end_index: 67
# 61. U_{_a}
#     core type: IndexedVar
# variable: 68
# index: 75
# 62. W_{_a}
#     core type: IndexedVar
# variable: 69
# index: 75
# 63. _a -> a_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 70
# 64. i
#     core type: Variable
#     sub-expressions:
# 65. _a -> c_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 71
# 66. 1
#     core type: Literal
#     sub-expressions:
# 67. k
#     core type: Variable
#     sub-expressions:
# 68. U
#     core type: Variable
#     sub-expressions:
# 69. W
#     core type: Variable
#     sub-expressions:
# 70. a_{_a}
#     core type: IndexedVar
# variable: 72
# index: 75
# 71. c_{_a}
#     core type: IndexedVar
# variable: 73
# index: 75
# 72. a
#     core type: Variable
#     sub-expressions:
# 73. c
#     core type: Variable
#     sub-expressions:
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. _a
#     core type: Variable
#     sub-expressions:
