# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Variable, a, i
from proveit.core_expr_types import V_1_to_i, a_1_to_i
from proveit.linear_algebra import InnerProdSpaces, Norm, TensorProd
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Mult, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [V_1_to_i]
expr = Conditional(Forall(instance_param_or_params = sub_expr2, instance_expr = Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(Norm(TensorProd(a_1_to_i)), Mult(ExprRange(sub_expr1, Norm(IndexedVar(a, sub_expr1)), one, i))), domains = sub_expr2).with_wrapping(), domain = InnerProdSpaces(K)).with_wrapping(), InSet(i, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{V_{1}, V_{2}, \ldots, V_{i} \underset{{\scriptscriptstyle c}}{\in} \textrm{InnerProdSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in V_{1}\right), \left(a_{2} \in V_{2}\right), \ldots, \left(a_{i} \in V_{i}\right)}~\\
# \left(\left \|a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}\right \| = \left(\left \|a_{1}\right \| \cdot  \left \|a_{2}\right \| \cdot  \ldots \cdot  \left \|a_{i}\right \|\right)\right)\end{array}\right]\end{array} \textrm{ if } i \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))] if i in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))]
#    core type: Operation
#    operator: 13
#    operand: 5
# 2. i in NaturalPos
#    core type: Operation
#    operator: 46
#    operands: 4
# 3. ((V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 53, 6
# 5. (V_{1}, V_{2}, ..., V_{i}) -> {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. (V_{1}, V_{2}, ..., V_{i})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. {forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)) if (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K)).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. V_{1}, V_{2}, ..., V_{i}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 52
#    end_index: 53
# 10. forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||))
#     core type: Operation
#     operator: 13
#     operand: 16
# 11. (V_{1} in_c InnerProdSpaces(K)) and  (V_{2} in_c InnerProdSpaces(K)) and  ... and  (V_{i} in_c InnerProdSpaces(K))
#     core type: Operation
#     operator: 25
#     operands: 15
# 12. _a -> V_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 50
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. ((V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (a_{1}, a_{2}, ..., a_{i}) -> {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Lambda
#     parameters: 44\n    body: 18
# 17. (V_{1} in_c InnerProdSpaces(K)), (V_{2} in_c InnerProdSpaces(K)), ..., (V_{i} in_c InnerProdSpaces(K))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 52
#     end_index: 53
# 18. {||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||) if (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i}).
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. _a -> (V_{_a} in_c InnerProdSpaces(K))
#     core type: Lambda
#     parameter: 60
#     body: 22
# 20. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = (||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (a_{1} in V_{1}) and  (a_{2} in V_{2}) and  ... and  (a_{i} in V_{i})
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. V_{_a} in_c InnerProdSpaces(K)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||, ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. ((a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}))
#     core type: ExprTuple
#     sub-expressions: 31
# 27. in_c
#     core type: Literal
#     sub-expressions:
# 28. (V_{_a}, InnerProdSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 50, 32
# 29. ||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}||
#     core type: Operation
#     operator: 54
#     operand: 39
# 30. ||a_{1}|| *  ||a_{2}|| *  ... *  ||a_{i}||
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 52
#     end_index: 53
# 32. InnerProdSpaces(K)
#     core type: Operation
#     operator: 37
#     operand: 42
# 33. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (||a_{1}||, ||a_{2}||, ..., ||a_{i}||)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. _a -> (a_{_a} in V_{_a})
#     core type: Lambda
#     parameter: 60
#     body: 41
# 37. InnerProdSpaces
#     core type: Literal
#     sub-expressions:
# 38. (K)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. ||a_{1}||, ||a_{2}||, ..., ||a_{i}||
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 52
#     end_index: 53
# 41. a_{_a} in V_{_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. K
#     core type: Variable
#     sub-expressions:
# 43. otimes
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. _a -> ||a_{_a}||
#     core type: Lambda
#     parameter: 60
#     body: 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (a_{_a}, V_{_a})
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 49. ||a_{_a}||
#     core type: Operation
#     operator: 54
#     operand: 57
# 50. V_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 51. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 57
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. i
#     core type: Variable
#     sub-expressions:
# 54. Abs
#     core type: Literal
#     sub-expressions:
# 55. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 57
# 56. V
#     core type: Variable
#     sub-expressions:
# 57. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
