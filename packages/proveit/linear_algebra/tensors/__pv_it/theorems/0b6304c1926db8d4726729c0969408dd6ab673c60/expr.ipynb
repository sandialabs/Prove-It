# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, V, alpha, b, i, k
from proveit.core_expr_types import U_1_to_i, W_1_to_k, a_1_to_i, c_1_to_k
from proveit.linear_algebra import ScalarMult, TensorProd, VecSpaces
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = [U_1_to_i, V, W_1_to_k]
expr = Conditional(Forall(instance_param_or_params = [i, k], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_k], instance_expr = Equals(TensorProd(a_1_to_i, ScalarMult(alpha, b), c_1_to_k), ScalarMult(alpha, TensorProd(a_1_to_i, b, c_1_to_k))).with_wrapping_at(1), domains = sub_expr1).with_wrapping(), domain = VecSpaces(K)).with_wrapping(), domain = Natural), InSet(alpha, K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{i, k \in \mathbb{N}}~\left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V, W_{1}, W_{2}, \ldots, W_{k} \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\\
# \left[\begin{array}{l}\forall_{\left(a_{1} \in U_{1}\right), \left(a_{2} \in U_{2}\right), \ldots, \left(a_{i} \in U_{i}\right), b \in V,\left(c_{1} \in W_{1}\right), \left(c_{2} \in W_{2}\right), \ldots, \left(c_{k} \in W_{k}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} \left(\alpha \cdot b\right){\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) \\  = \left(\alpha \cdot \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right)\right) \end{array} \end{array}\right)\end{array}\right]\end{array}\right] \textrm{ if } \alpha \in K\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]] if alpha in K.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{i, k in Natural} [forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]]
#    core type: Operation
#    operator: 26
#    operand: 5
# 2. alpha in K
#    core type: Operation
#    operator: 72
#    operands: 4
# 3. ((i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (alpha, K)
#    core type: ExprTuple
#    sub-expressions: 74, 66
# 5. (i, k) -> {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (i, k)
#    core type: ExprTuple
#    sub-expressions: 81, 84
# 7. {forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))] if i in Natural ,  k in Natural.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k} in_c VecSpaces(K)} [forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))]
#    core type: Operation
#    operator: 26
#    operand: 12
# 9. (i in Natural) and (k in Natural)
#    core type: Operation
#    operator: 43
#    operands: 11
# 10. ((U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (i in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (U_{1}, U_{2}, ..., U_{i}, V, W_{1}, W_{2}, ..., W_{k}) -> {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 13. i in Natural
#     core type: Operation
#     operator: 72
#     operands: 17
# 14. k in Natural
#     core type: Operation
#     operator: 72
#     operands: 18
# 15. (U_{1}, U_{2}, ..., U_{i}, V,W_{1}, W_{2}, ..., W_{k})
#     core type: ExprTuple
#     sub-expressions: 19, 64, 20
# 16. {forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))) if (U_{1} in_c VecSpaces(K)) ,  (U_{2} in_c VecSpaces(K)) ,  ... ,  (U_{i} in_c VecSpaces(K)) ,  V in_c VecSpaces(K), (W_{1} in_c VecSpaces(K)) ,  (W_{2} in_c VecSpaces(K)) ,  ... ,  (W_{k} in_c VecSpaces(K)).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 81, 23
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 84, 23
# 19. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 83
#     end_index: 81
# 20. W_{1}, W_{2}, ..., W_{k}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 83
#     end_index: 84
# 21. forall_{(a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})))
#     core type: Operation
#     operator: 26
#     operand: 29
# 22. (U_{1} in_c VecSpaces(K)) and  (U_{2} in_c VecSpaces(K)) and  ... and  (U_{i} in_c VecSpaces(K)) and (V in_c VecSpaces(K))and (W_{1} in_c VecSpaces(K)) and  (W_{2} in_c VecSpaces(K)) and  ... and  (W_{k} in_c VecSpaces(K))
#     core type: Operation
#     operator: 43
#     operands: 28
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. _a -> U_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 78
# 25. _a -> W_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 79
# 26. forall
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. ((U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K)), V in_c VecSpaces(K),(W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K)))
#     core type: ExprTuple
#     sub-expressions: 30, 31, 32
# 29. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Lambda
#     parameters: 70\n    body: 33
# 30. (U_{1} in_c VecSpaces(K)), (U_{2} in_c VecSpaces(K)), ..., (U_{i} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 83
#     end_index: 81
# 31. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 46
#     operands: 35
# 32. (W_{1} in_c VecSpaces(K)), (W_{2} in_c VecSpaces(K)), ..., (W_{k} in_c VecSpaces(K))
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 83
#     end_index: 84
# 33. {(a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})) if (a_{1} in U_{1}) ,  (a_{2} in U_{2}) ,  ... ,  (a_{i} in U_{i}) ,  b in V, (c_{1} in W_{1}) ,  (c_{2} in W_{2}) ,  ... ,  (c_{k} in W_{k}).
#     core type: Conditional
#     value: 37
#     condition: 38
# 34. _a -> (U_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 92
#     body: 39
# 35. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 64, 53
# 36. _a -> (W_{_a} in_c VecSpaces(K))
#     core type: Lambda
#     parameter: 92
#     body: 40
# 37. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) \\  = (alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (a_{1} in U_{1}) and  (a_{2} in U_{2}) and  ... and  (a_{i} in U_{i}) and (b in V)and (c_{1} in W_{1}) and  (c_{2} in W_{2}) and  ... and  (c_{k} in W_{k})
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. U_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 46
#     operands: 45
# 40. W_{_a} in_c VecSpaces(K)
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. and
#     core type: Literal
#     sub-expressions:
# 44. ((a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i}), b in V,(c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k}))
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52
# 45. (U_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 78, 53
# 46. in_c
#     core type: Literal
#     sub-expressions:
# 47. (W_{_a}, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 79, 53
# 48. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes (alpha * b)otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 69
#     operands: 54
# 49. alpha * (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: Operation
#     operator: 67
#     operands: 55
# 50. (a_{1} in U_{1}), (a_{2} in U_{2}), ..., (a_{i} in U_{i})
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 83
#     end_index: 81
# 51. b in V
#     core type: Operation
#     operator: 72
#     operands: 57
# 52. (c_{1} in W_{1}), (c_{2} in W_{2}), ..., (c_{k} in W_{k})
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 83
#     end_index: 84
# 53. VecSpaces(K)
#     core type: Operation
#     operator: 59
#     operand: 66
# 54. (a_{1}, a_{2}, ..., a_{i}, alpha * b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 75, 61, 77
# 55. (alpha, a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k})
#     core type: ExprTuple
#     sub-expressions: 74, 62
# 56. _a -> (a_{_a} in U_{_a})
#     core type: Lambda
#     parameter: 92
#     body: 63
# 57. (b, V)
#     core type: ExprTuple
#     sub-expressions: 76, 64
# 58. _a -> (c_{_a} in W_{_a})
#     core type: Lambda
#     parameter: 92
#     body: 65
# 59. VecSpaces
#     core type: Literal
#     sub-expressions:
# 60. (K)
#     core type: ExprTuple
#     sub-expressions: 66
# 61. alpha * b
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 69
#     operands: 70
# 63. a_{_a} in U_{_a}
#     core type: Operation
#     operator: 72
#     operands: 71
# 64. V
#     core type: Variable
#     sub-expressions:
# 65. c_{_a} in W_{_a}
#     core type: Operation
#     operator: 72
#     operands: 73
# 66. K
#     core type: Variable
#     sub-expressions:
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (alpha, b)
#     core type: ExprTuple
#     sub-expressions: 74, 76
# 69. otimes
#     core type: Literal
#     sub-expressions:
# 70. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 75, 76, 77
# 71. (a_{_a}, U_{_a})
#     core type: ExprTuple
#     sub-expressions: 87, 78
# 72. in
#     core type: Literal
#     sub-expressions:
# 73. (c_{_a}, W_{_a})
#     core type: ExprTuple
#     sub-expressions: 88, 79
# 74. alpha
#     core type: Variable
#     sub-expressions:
# 75. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 80
#     start_index: 83
#     end_index: 81
# 76. b
#     core type: Variable
#     sub-expressions:
# 77. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 83
#     end_index: 84
# 78. U_{_a}
#     core type: IndexedVar
# variable: 85
# index: 92
# 79. W_{_a}
#     core type: IndexedVar
# variable: 86
# index: 92
# 80. _a -> a_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 87
# 81. i
#     core type: Variable
#     sub-expressions:
# 82. _a -> c_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 88
# 83. 1
#     core type: Literal
#     sub-expressions:
# 84. k
#     core type: Variable
#     sub-expressions:
# 85. U
#     core type: Variable
#     sub-expressions:
# 86. W
#     core type: Variable
#     sub-expressions:
# 87. a_{_a}
#     core type: IndexedVar
# variable: 89
# index: 92
# 88. c_{_a}
#     core type: IndexedVar
# variable: 90
# index: 92
# 89. a
#     core type: Variable
#     sub-expressions:
# 90. c
#     core type: Variable
#     sub-expressions:
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 92
# 92. _a
#     core type: Variable
#     sub-expressions:
