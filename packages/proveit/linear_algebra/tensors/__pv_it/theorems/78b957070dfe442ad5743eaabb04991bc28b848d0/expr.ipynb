# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.tensors</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, V, b, e
from proveit.core_expr_types import a_1_to_i, c_1_to_k, d_1_to_i, f_1_to_k
from proveit.linear_algebra import TensorProd, VecZero
from proveit.logic import And, Equals, Implies, InSet, NotEquals

# %%
# build up the expression from sub-expressions
expr = Lambda([b, e], Conditional(Implies(Equals(TensorProd(a_1_to_i, b, c_1_to_k), TensorProd(d_1_to_i, e, f_1_to_k)).with_wrapping_at(2), Equals(TensorProd(a_1_to_i, c_1_to_k), TensorProd(d_1_to_i, f_1_to_k)).with_wrapping_at(2)).with_wrapping_at(2), And(InSet(b, V), InSet(e, V), Equals(b, e), NotEquals(b, VecZero(V)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(b, e\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i} {\otimes} b{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i} {\otimes} e{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(a_{1} {\otimes}  a_{2} {\otimes}  \ldots {\otimes}  a_{i}{\otimes} c_{1} {\otimes}  c_{2} {\otimes}  \ldots {\otimes}  c_{k}\right) =  \\ \left(d_{1} {\otimes}  d_{2} {\otimes}  \ldots {\otimes}  d_{i}{\otimes} f_{1} {\otimes}  f_{2} {\otimes}  \ldots {\otimes}  f_{k}\right) \end{array} \end{array}\right) \end{array} \end{array} \textrm{ if } b \in V ,  e \in V ,  b = e ,  b \neq \vec{0}\left(V\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (b, e) -> {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Lambda
#    parameters: 20\n   body: 1
# 1. {((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) if b in V ,  e in V ,  b = e ,  b != 0(V).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})) =>  \\ ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (b in V) and (e in V) and (b = e) and (b != 0(V))
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}), (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (b in V, e in V, b = e, b != 0(V))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#    core type: Operation
#    operator: 19
#    operands: 14
# 9. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}) =  \\ (d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#    core type: Operation
#    operator: 19
#    operands: 15
# 10. b in V
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. e in V
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. b = e
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. b != 0(V)
#     core type: Operation
#     operator: 21
#     operands: 22
# 14. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 15. (a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}, d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 16. (b, V)
#     core type: ExprTuple
#     sub-expressions: 35, 41
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (e, V)
#     core type: ExprTuple
#     sub-expressions: 36, 41
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (b, e)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 21. !=
#     core type: Literal
#     sub-expressions:
# 22. (b, 0(V))
#     core type: ExprTuple
#     sub-expressions: 35, 27
# 23. a_{1} otimes  a_{2} otimes  ... otimes  a_{i} otimes botimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 31
#     operands: 28
# 24. d_{1} otimes  d_{2} otimes  ... otimes  d_{i} otimes eotimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 31
#     operands: 29
# 25. a_{1} otimes  a_{2} otimes  ... otimes  a_{i}otimes c_{1} otimes  c_{2} otimes  ... otimes  c_{k}
#     core type: Operation
#     operator: 31
#     operands: 30
# 26. d_{1} otimes  d_{2} otimes  ... otimes  d_{i}otimes f_{1} otimes  f_{2} otimes  ... otimes  f_{k}
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. 0(V)
#     core type: Operation
#     operator: 33
#     operand: 41
# 28. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 35, 38
# 29. (d_{1}, d_{2}, ..., d_{i}, e,f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 39, 36, 40
# 30. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. otimes
#     core type: Literal
#     sub-expressions:
# 32. (d_{1}, d_{2}, ..., d_{i},f_{1}, f_{2}, ..., f_{k})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. (V)
#     core type: ExprTuple
#     sub-expressions: 41
# 35. b
#     core type: Variable
#     sub-expressions:
# 36. e
#     core type: Variable
#     sub-expressions:
# 37. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 45
# 38. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 47
#     end_index: 48
# 39. d_{1}, d_{2}, ..., d_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 40. f_{1}, f_{2}, ..., f_{k}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 41. V
#     core type: Variable
#     sub-expressions:
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 49
# 43. _a -> c_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 50
# 44. _a -> d_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 51
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> f_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. k
#     core type: Variable
#     sub-expressions:
# 49. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 58
# 50. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 58
# 51. d_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 52. f_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. d
#     core type: Variable
#     sub-expressions:
# 56. f
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
