# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">tensors</a>.<a class="ProveItLink" href="../../theorems.ipynb#insert_vec_on_both_sides_of_equality">insert_vec_on_both_sides_of_equality</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving insert_vec_on_both_sides_of_equality
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="insert_vec_on_both_sides_of_equality">insert_vec_on_both_sides_of_equality:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/271c9dd08ead9708fbd8597dfc503ac544ce8ecc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/bd248d7aeef141911080e52370f261e6d8ebe1d60/dependencies.ipynb">dependencies</a>)<br>
