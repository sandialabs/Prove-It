# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">tensors</a>.<a class="ProveItLink" href="../../theorems.ipynb#tensor_prod_distribution_over_summation_with_scalar_mult">tensor_prod_distribution_over_summation_with_scalar_mult</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tensor_prod_distribution_over_summation_with_scalar_mult
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="tensor_prod_distribution_over_summation_with_scalar_mult">tensor_prod_distribution_over_summation_with_scalar_mult:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9cd4971dee37570dc7a596e112e7ea19f5b839580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e5281f53b23e1dc9e1dd6601a4862110eadcea220/dependencies.ipynb">dependencies</a>)<br>
