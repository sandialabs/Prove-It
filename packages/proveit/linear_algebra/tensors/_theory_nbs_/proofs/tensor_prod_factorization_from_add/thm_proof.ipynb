# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">tensors</a>.<a class="ProveItLink" href="../../theorems.ipynb#tensor_prod_factorization_from_add">tensor_prod_factorization_from_add</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tensor_prod_factorization_from_add
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="tensor_prod_factorization_from_add">tensor_prod_factorization_from_add:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f6080e34107f0c2a79c58826bb007f56893864cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/b484696e0b2c4ec3de2860956f7b9df88842f1700/dependencies.ipynb">dependencies</a>)<br>
