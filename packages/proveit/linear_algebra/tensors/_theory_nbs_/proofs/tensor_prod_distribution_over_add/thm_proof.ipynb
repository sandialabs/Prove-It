# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">tensors</a>.<a class="ProveItLink" href="../../theorems.ipynb#tensor_prod_distribution_over_add">tensor_prod_distribution_over_add</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tensor_prod_distribution_over_add
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="tensor_prod_distribution_over_add">tensor_prod_distribution_over_add:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b2fdf0f003394df4743768be1ea0e965d3f6af080/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9b2e66c14e993fbc2db896c8594e55b33cd927f70/dependencies.ipynb">dependencies</a>)<br>
