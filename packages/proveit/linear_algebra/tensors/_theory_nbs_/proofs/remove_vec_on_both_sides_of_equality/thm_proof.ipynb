# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">tensors</a>.<a class="ProveItLink" href="../../theorems.ipynb#remove_vec_on_both_sides_of_equality">remove_vec_on_both_sides_of_equality</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving remove_vec_on_both_sides_of_equality
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="remove_vec_on_both_sides_of_equality">remove_vec_on_both_sides_of_equality:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e67da857e9b2cdf4a31a8b29fc321876a59c5d940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e25928f4432568b7385f77f4eb494b35c88e636a0/dependencies.ipynb">dependencies</a>)<br>
