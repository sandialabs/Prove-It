# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.linear_algebra.negation</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

from proveit import K, V,x
from proveit.linear_algebra import VecNeg
from proveit.logic import Forall, InSet
from proveit.numbers import Add, subtract, Mult, Exp, sqrd, sqrt
from proveit.linear_algebra import VecSpaces

# %%
# %begin theorems

# %%
neg_closure = Forall(
    K, Forall(
        V, Forall(x, InSet(VecNeg(x), V),
                  domain=V),
        domain=VecSpaces(K)))

# %%
# %end theorems
