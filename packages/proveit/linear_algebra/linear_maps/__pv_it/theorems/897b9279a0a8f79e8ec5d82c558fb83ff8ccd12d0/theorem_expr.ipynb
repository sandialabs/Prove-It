# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#lin_map_linearity">lin_map_linearity</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.linear_maps import lin_map_linearity

# %%
# check that the built expression is the same as the stored expression
assert lin_map_linearity.expr == stored_expr
assert lin_map_linearity.expr._style_id == stored_expr._style_id
print("Passed sanity check: lin_map_linearity matches stored_expr")
# Out:
# Passed sanity check: lin_map_linearity matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V, W}~\left[\forall_{P \in \mathcal{L}\left(V, W\right)}~\left[\forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V, W} [forall_{P in LINMAP(V, W)} [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. ((V, W) -> [forall_{P in LINMAP(V, W)} [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (V, W) -> [forall_{P in LINMAP(V, W)} [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))]]
#    core type: Lambda
#    parameters: 17\n   body: 3
# 3. forall_{P in LINMAP(V, W)} [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))]
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. (P -> {forall_{x, y in V} (P(x + y) = (P(x) + P(y))) if P in LINMAP(V, W).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. P -> {forall_{x, y in V} (P(x + y) = (P(x) + P(y))) if P in LINMAP(V, W).
#    core type: Lambda
#    parameter: 41
#    body: 7
# 6. (P)
#    core type: ExprTuple
#    sub-expressions: 41
# 7. {forall_{x, y in V} (P(x + y) = (P(x) + P(y))) if P in LINMAP(V, W).
# ...
