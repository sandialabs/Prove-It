# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, K, P, Px, Py, V, W, c, x, y
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import And, Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = And(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, W), domain = V), Forall(instance_param_or_params = [x, y], instance_expr = Equals(Function(P, [VecAdd(x, y)]), VecAdd(Px, Py)), domain = V), Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Function(P, [ScalarMult(c, x)]), ScalarMult(c, Px)), domain = V), domain = K)).with_wrapping_at(2,4)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \left[\forall_{x \in V}~\left(P\left(x\right) \in W\right)\right] \land  \\ \left[\forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right)\right] \land  \\ \left[\forall_{c \in K}~\left[\forall_{x \in V}~\left(P\left(c \cdot x\right) = \left(c \cdot P\left(x\right)\right)\right)\right]\right] \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2 4)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]]
#    core type: Operation
#    operator: 22
#    operands: 1
# 1. (forall_{x in V} (P(x) in W), forall_{x, y in V} (P(x + y) = (P(x) + P(y))), forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))])
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. forall_{x in V} (P(x) in W)
#    core type: Operation
#    operator: 24
#    operand: 8
# 3. forall_{x, y in V} (P(x + y) = (P(x) + P(y)))
#    core type: Operation
#    operator: 24
#    operand: 9
# 4. forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]
#    core type: Operation
#    operator: 24
#    operand: 10
# 5. (x -> {P(x) in W if x in V.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. ((x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. x -> {P(x) in W if x in V.
#    core type: Lambda
#    parameter: 61
#    body: 11
# 9. (x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#    core type: Lambda
#    parameters: 42\n   body: 12
# 10. c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Lambda
#     parameter: 60
#     body: 14
# 11. {P(x) in W if x in V.
#     core type: Conditional
#     value: 15
#     condition: 40
# 12. {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (c)
#     core type: ExprTuple
#     sub-expressions: 60
# 14. {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. P(x) in W
#     core type: Operation
#     operator: 46
#     operands: 20
# 16. P(x + y) = (P(x) + P(y))
#     core type: Operation
#     operator: 44
#     operands: 21
# 17. (x in V) and (y in V)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. forall_{x in V} (P(c * x) = (c * P(x)))
#     core type: Operation
#     operator: 24
#     operand: 31
# 19. c in K
#     core type: Operation
#     operator: 46
#     operands: 26
# 20. (P(x), W)
#     core type: ExprTuple
#     sub-expressions: 55, 27
# 21. (P(x + y), P(x) + P(y))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (x in V, y in V)
#     core type: ExprTuple
#     sub-expressions: 40, 30
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. (x -> {P(c * x) = (c * P(x)) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 31
# 26. (c, K)
#     core type: ExprTuple
#     sub-expressions: 60, 32
# 27. W
#     core type: Variable
#     sub-expressions:
# 28. P(x + y)
#     core type: Operation
#     operator: 58
#     operand: 37
# 29. P(x) + P(y)
#     core type: Operation
#     operator: 41
#     operands: 34
# 30. y in V
#     core type: Operation
#     operator: 46
#     operands: 35
# 31. x -> {P(c * x) = (c * P(x)) if x in V.
#     core type: Lambda
#     parameter: 61
#     body: 36
# 32. K
#     core type: Variable
#     sub-expressions:
# 33. (x + y)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. (P(x), P(y))
#     core type: ExprTuple
#     sub-expressions: 55, 38
# 35. (y, V)
#     core type: ExprTuple
#     sub-expressions: 48, 51
# 36. {P(c * x) = (c * P(x)) if x in V.
#     core type: Conditional
#     value: 39
#     condition: 40
# 37. x + y
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. P(y)
#     core type: Operation
#     operator: 58
#     operand: 48
# 39. P(c * x) = (c * P(x))
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. x in V
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (x, y)
#     core type: ExprTuple
#     sub-expressions: 61, 48
# 43. (y)
#     core type: ExprTuple
#     sub-expressions: 48
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (P(c * x), c * P(x))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x, V)
#     core type: ExprTuple
#     sub-expressions: 61, 51
# 48. y
#     core type: Variable
#     sub-expressions:
# 49. P(c * x)
#     core type: Operation
#     operator: 58
#     operand: 54
# 50. c * P(x)
#     core type: Operation
#     operator: 56
#     operands: 53
# 51. V
#     core type: Variable
#     sub-expressions:
# 52. (c * x)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 60, 55
# 54. c * x
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. P(x)
#     core type: Operation
#     operator: 58
#     operand: 61
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (c, x)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. P
#     core type: Variable
#     sub-expressions:
# 59. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
