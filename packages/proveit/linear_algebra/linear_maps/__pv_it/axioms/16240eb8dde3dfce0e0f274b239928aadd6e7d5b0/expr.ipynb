# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, K, P, Px, Py, V, W, c, x, y
from proveit.linear_algebra import LinMap, ScalarMult, VecAdd
from proveit.logic import And, Equals, Forall, Iff, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Iff(InSet(P, LinMap(V, W)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, W), domain = V), Forall(instance_param_or_params = [x, y], instance_expr = Equals(Function(P, [VecAdd(x, y)]), VecAdd(Px, Py)), domain = V), Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Function(P, [ScalarMult(c, x)]), ScalarMult(c, Px)), domain = V), domain = K)).with_wrapping_at(2,4)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(P \in \mathcal{L}\left(V, W\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in V}~\left(P\left(x\right) \in W\right)\right] \land  \\ \left[\forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right)\right] \land  \\ \left[\forall_{c \in K}~\left[\forall_{x \in V}~\left(P\left(c \cdot x\right) = \left(c \cdot P\left(x\right)\right)\right)\right]\right] \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (P in LINMAP(V, W)) <=>  \\ ([forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. (P in LINMAP(V, W), [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. P in LINMAP(V, W)
#    core type: Operation
#    operator: 54
#    operands: 5
# 4. [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]]
#    core type: Operation
#    operator: 30
#    operands: 6
# 5. (P, LINMAP(V, W))
#    core type: ExprTuple
#    sub-expressions: 66, 7
# 6. (forall_{x in V} (P(x) in W), forall_{x, y in V} (P(x + y) = (P(x) + P(y))), forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))])
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. LINMAP(V, W)
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. forall_{x in V} (P(x) in W)
#    core type: Operation
#    operator: 32
#    operand: 16
# 9. forall_{x, y in V} (P(x + y) = (P(x) + P(y)))
#    core type: Operation
#    operator: 32
#    operand: 17
# 10. forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]
#     core type: Operation
#     operator: 32
#     operand: 18
# 11. LINMAP
#     core type: Literal
#     sub-expressions:
# 12. (V, W)
#     core type: ExprTuple
#     sub-expressions: 59, 35
# 13. (x -> {P(x) in W if x in V.)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. ((x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. x -> {P(x) in W if x in V.
#     core type: Lambda
#     parameter: 69
#     body: 19
# 17. (x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Lambda
#     parameters: 50\n    body: 20
# 18. c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Lambda
#     parameter: 68
#     body: 22
# 19. {P(x) in W if x in V.
#     core type: Conditional
#     value: 23
#     condition: 48
# 20. {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. (c)
#     core type: ExprTuple
#     sub-expressions: 68
# 22. {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. P(x) in W
#     core type: Operation
#     operator: 54
#     operands: 28
# 24. P(x + y) = (P(x) + P(y))
#     core type: Operation
#     operator: 52
#     operands: 29
# 25. (x in V) and (y in V)
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. forall_{x in V} (P(c * x) = (c * P(x)))
#     core type: Operation
#     operator: 32
#     operand: 39
# 27. c in K
#     core type: Operation
#     operator: 54
#     operands: 34
# 28. (P(x), W)
#     core type: ExprTuple
#     sub-expressions: 63, 35
# 29. (P(x + y), P(x) + P(y))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (x in V, y in V)
#     core type: ExprTuple
#     sub-expressions: 48, 38
# 32. forall
#     core type: Literal
#     sub-expressions:
# 33. (x -> {P(c * x) = (c * P(x)) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. (c, K)
#     core type: ExprTuple
#     sub-expressions: 68, 40
# 35. W
#     core type: Variable
#     sub-expressions:
# 36. P(x + y)
#     core type: Operation
#     operator: 66
#     operand: 45
# 37. P(x) + P(y)
#     core type: Operation
#     operator: 49
#     operands: 42
# 38. y in V
#     core type: Operation
#     operator: 54
#     operands: 43
# 39. x -> {P(c * x) = (c * P(x)) if x in V.
#     core type: Lambda
#     parameter: 69
#     body: 44
# 40. K
#     core type: Variable
#     sub-expressions:
# 41. (x + y)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. (P(x), P(y))
#     core type: ExprTuple
#     sub-expressions: 63, 46
# 43. (y, V)
#     core type: ExprTuple
#     sub-expressions: 56, 59
# 44. {P(c * x) = (c * P(x)) if x in V.
#     core type: Conditional
#     value: 47
#     condition: 48
# 45. x + y
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. P(y)
#     core type: Operation
#     operator: 66
#     operand: 56
# 47. P(c * x) = (c * P(x))
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. x in V
#     core type: Operation
#     operator: 54
#     operands: 55
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (x, y)
#     core type: ExprTuple
#     sub-expressions: 69, 56
# 51. (y)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (P(c * x), c * P(x))
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (x, V)
#     core type: ExprTuple
#     sub-expressions: 69, 59
# 56. y
#     core type: Variable
#     sub-expressions:
# 57. P(c * x)
#     core type: Operation
#     operator: 66
#     operand: 62
# 58. c * P(x)
#     core type: Operation
#     operator: 64
#     operands: 61
# 59. V
#     core type: Variable
#     sub-expressions:
# 60. (c * x)
#     core type: ExprTuple
#     sub-expressions: 62
# 61. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 68, 63
# 62. c * x
#     core type: Operation
#     operator: 64
#     operands: 65
# 63. P(x)
#     core type: Operation
#     operator: 66
#     operand: 69
# 64. *
#     core type: Literal
#     sub-expressions:
# 65. (c, x)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. P
#     core type: Variable
#     sub-expressions:
# 67. (x)
#     core type: ExprTuple
#     sub-expressions: 69
# 68. c
#     core type: Variable
#     sub-expressions:
# 69. x
#     core type: Variable
#     sub-expressions:
