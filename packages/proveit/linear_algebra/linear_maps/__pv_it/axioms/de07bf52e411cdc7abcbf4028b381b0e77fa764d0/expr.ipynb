# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, P, Px, V, W, c, x
from proveit.linear_algebra import LinMap, ScalarMult, VecSpaces
from proveit.logic import Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V, W], instance_expr = Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = [P], instance_expr = Equals(ScalarMult(c, P), Lambda(x, Conditional(ScalarMult(c, Px), InSet(x, V)))), domain = LinMap(V, W)), domain = K), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V, W \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{c \in K}~\left[\forall_{P \in \mathcal{L}\left(V, W\right)}~\left(\left(c \cdot P\right) = \left[x \mapsto \left\{c \cdot P\left(x\right) \textrm{ if } x \in V\right..\right]\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V, W in_c VecSpaces(K)} [forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (K -> [forall_{V, W in_c VecSpaces(K)} [forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V, W in_c VecSpaces(K)} [forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]]]
#    core type: Lambda
#    parameter: 29
#    body: 3
# 3. forall_{V, W in_c VecSpaces(K)} [forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]]
#    core type: Operation
#    operator: 23
#    operand: 5
# 4. ((V, W) -> {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (V, W) -> {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).
#    core type: Lambda
#    parameters: 43\n   body: 6
# 6. {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]
#    core type: Operation
#    operator: 23
#    operand: 12
# 8. (V in_c VecSpaces(K)) and (W in_c VecSpaces(K))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (c -> {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (V in_c VecSpaces(K), W in_c VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. c -> {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.
#     core type: Lambda
#     parameter: 51
#     body: 16
# 13. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. W in_c VecSpaces(K)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (c)
#     core type: ExprTuple
#     sub-expressions: 51
# 16. {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 53, 22
# 18. in_c
#     core type: Literal
#     sub-expressions:
# 19. (W, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 46, 22
# 20. forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])
#     core type: Operation
#     operator: 23
#     operand: 28
# 21. c in K
#     core type: Operation
#     operator: 49
#     operands: 25
# 22. VecSpaces(K)
#     core type: Operation
#     operator: 26
#     operand: 29
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (P -> {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (c, K)
#     core type: ExprTuple
#     sub-expressions: 51, 29
# 26. VecSpaces
#     core type: Literal
#     sub-expressions:
# 27. (K)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. P -> {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).
#     core type: Lambda
#     parameter: 54
#     body: 31
# 29. K
#     core type: Variable
#     sub-expressions:
# 30. (P)
#     core type: ExprTuple
#     sub-expressions: 54
# 31. {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).
#     core type: Conditional
#     value: 32
#     condition: 33
# 32. (c * P) = [x -> {c * P(x) if x in V.]
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. P in LINMAP(V, W)
#     core type: Operation
#     operator: 49
#     operands: 36
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (c * P, x -> {c * P(x) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. (P, LINMAP(V, W))
#     core type: ExprTuple
#     sub-expressions: 54, 39
# 37. c * P
#     core type: Operation
#     operator: 47
#     operands: 40
# 38. x -> {c * P(x) if x in V.
#     core type: Lambda
#     parameter: 56
#     body: 41
# 39. LINMAP(V, W)
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. (c, P)
#     core type: ExprTuple
#     sub-expressions: 51, 54
# 41. {c * P(x) if x in V.
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. LINMAP
#     core type: Literal
#     sub-expressions:
# 43. (V, W)
#     core type: ExprTuple
#     sub-expressions: 53, 46
# 44. c * P(x)
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. x in V
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. W
#     core type: Variable
#     sub-expressions:
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (x, V)
#     core type: ExprTuple
#     sub-expressions: 56, 53
# 51. c
#     core type: Variable
#     sub-expressions:
# 52. P(x)
#     core type: Operation
#     operator: 54
#     operand: 56
# 53. V
#     core type: Variable
#     sub-expressions:
# 54. P
#     core type: Variable
#     sub-expressions:
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. x
#     core type: Variable
#     sub-expressions:
