# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, P, Px, V, W, c, x
from proveit.linear_algebra import LinMap, ScalarMult, VecSpaces
from proveit.logic import Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [V, W], instance_expr = Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = [P], instance_expr = Equals(ScalarMult(c, P), Lambda(x, Conditional(ScalarMult(c, Px), InSet(x, V)))), domain = LinMap(V, W)), domain = K), domain = VecSpaces(K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V, W \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{c \in K}~\left[\forall_{P \in \mathcal{L}\left(V, W\right)}~\left(\left(c \cdot P\right) = \left[x \mapsto \left\{c \cdot P\left(x\right) \textrm{ if } x \in V\right..\right]\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V, W in_c VecSpaces(K)} [forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. ((V, W) -> {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (V, W) -> {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).
#    core type: Lambda
#    parameters: 40\n   body: 3
# 3. {forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])] if V in_c VecSpaces(K) ,  W in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{c in K} [forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])]
#    core type: Operation
#    operator: 20
#    operand: 9
# 5. (V in_c VecSpaces(K)) and (W in_c VecSpaces(K))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (c -> {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (V in_c VecSpaces(K), W in_c VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. c -> {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.
#    core type: Lambda
#    parameter: 48
#    body: 13
# 10. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. W in_c VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (c)
#     core type: ExprTuple
#     sub-expressions: 48
# 13. {forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.]) if c in K.
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 50, 19
# 15. in_c
#     core type: Literal
#     sub-expressions:
# 16. (W, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 43, 19
# 17. forall_{P in LINMAP(V, W)} ((c * P) = [x -> {c * P(x) if x in V.])
#     core type: Operation
#     operator: 20
#     operand: 25
# 18. c in K
#     core type: Operation
#     operator: 46
#     operands: 22
# 19. VecSpaces(K)
#     core type: Operation
#     operator: 23
#     operand: 26
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. (P -> {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (c, K)
#     core type: ExprTuple
#     sub-expressions: 48, 26
# 23. VecSpaces
#     core type: Literal
#     sub-expressions:
# 24. (K)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. P -> {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).
#     core type: Lambda
#     parameter: 51
#     body: 28
# 26. K
#     core type: Variable
#     sub-expressions:
# 27. (P)
#     core type: ExprTuple
#     sub-expressions: 51
# 28. {(c * P) = [x -> {c * P(x) if x in V.] if P in LINMAP(V, W).
#     core type: Conditional
#     value: 29
#     condition: 30
# 29. (c * P) = [x -> {c * P(x) if x in V.]
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. P in LINMAP(V, W)
#     core type: Operation
#     operator: 46
#     operands: 33
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (c * P, x -> {c * P(x) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. (P, LINMAP(V, W))
#     core type: ExprTuple
#     sub-expressions: 51, 36
# 34. c * P
#     core type: Operation
#     operator: 44
#     operands: 37
# 35. x -> {c * P(x) if x in V.
#     core type: Lambda
#     parameter: 53
#     body: 38
# 36. LINMAP(V, W)
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. (c, P)
#     core type: ExprTuple
#     sub-expressions: 48, 51
# 38. {c * P(x) if x in V.
#     core type: Conditional
#     value: 41
#     condition: 42
# 39. LINMAP
#     core type: Literal
#     sub-expressions:
# 40. (V, W)
#     core type: ExprTuple
#     sub-expressions: 50, 43
# 41. c * P(x)
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. x in V
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. W
#     core type: Variable
#     sub-expressions:
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x, V)
#     core type: ExprTuple
#     sub-expressions: 53, 50
# 48. c
#     core type: Variable
#     sub-expressions:
# 49. P(x)
#     core type: Operation
#     operator: 51
#     operand: 53
# 50. V
#     core type: Variable
#     sub-expressions:
# 51. P
#     core type: Variable
#     sub-expressions:
# 52. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. x
#     core type: Variable
#     sub-expressions:
