# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, K, P, Px, Py, V, W, c, x, y
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, W), domain = V), Forall(instance_param_or_params = [x, y], instance_expr = Equals(Function(P, [VecAdd(x, y)]), VecAdd(Px, Py)), domain = V), Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Function(P, [ScalarMult(c, x)]), ScalarMult(c, Px)), domain = V), domain = K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{x \in V}~\left(P\left(x\right) \in W\right), \forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right), \forall_{c \in K}~\left[\forall_{x \in V}~\left(P\left(c \cdot x\right) = \left(c \cdot P\left(x\right)\right)\right)\right]\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{x in V} (P(x) in W), forall_{x, y in V} (P(x + y) = (P(x) + P(y))), forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))])
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. forall_{x in V} (P(x) in W)
#    core type: Operation
#    operator: 23
#    operand: 7
# 2. forall_{x, y in V} (P(x + y) = (P(x) + P(y)))
#    core type: Operation
#    operator: 23
#    operand: 8
# 3. forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]
#    core type: Operation
#    operator: 23
#    operand: 9
# 4. (x -> {P(x) in W if x in V.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. ((x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. (c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. x -> {P(x) in W if x in V.
#    core type: Lambda
#    parameter: 60
#    body: 10
# 8. (x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#    core type: Lambda
#    parameters: 41\n   body: 11
# 9. c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#    core type: Lambda
#    parameter: 59
#    body: 13
# 10. {P(x) in W if x in V.
#     core type: Conditional
#     value: 14
#     condition: 39
# 11. {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (c)
#     core type: ExprTuple
#     sub-expressions: 59
# 13. {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. P(x) in W
#     core type: Operation
#     operator: 45
#     operands: 19
# 15. P(x + y) = (P(x) + P(y))
#     core type: Operation
#     operator: 43
#     operands: 20
# 16. (x in V) and (y in V)
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. forall_{x in V} (P(c * x) = (c * P(x)))
#     core type: Operation
#     operator: 23
#     operand: 30
# 18. c in K
#     core type: Operation
#     operator: 45
#     operands: 25
# 19. (P(x), W)
#     core type: ExprTuple
#     sub-expressions: 54, 26
# 20. (P(x + y), P(x) + P(y))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (x in V, y in V)
#     core type: ExprTuple
#     sub-expressions: 39, 29
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (x -> {P(c * x) = (c * P(x)) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 30
# 25. (c, K)
#     core type: ExprTuple
#     sub-expressions: 59, 31
# 26. W
#     core type: Variable
#     sub-expressions:
# 27. P(x + y)
#     core type: Operation
#     operator: 57
#     operand: 36
# 28. P(x) + P(y)
#     core type: Operation
#     operator: 40
#     operands: 33
# 29. y in V
#     core type: Operation
#     operator: 45
#     operands: 34
# 30. x -> {P(c * x) = (c * P(x)) if x in V.
#     core type: Lambda
#     parameter: 60
#     body: 35
# 31. K
#     core type: Variable
#     sub-expressions:
# 32. (x + y)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (P(x), P(y))
#     core type: ExprTuple
#     sub-expressions: 54, 37
# 34. (y, V)
#     core type: ExprTuple
#     sub-expressions: 47, 50
# 35. {P(c * x) = (c * P(x)) if x in V.
#     core type: Conditional
#     value: 38
#     condition: 39
# 36. x + y
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. P(y)
#     core type: Operation
#     operator: 57
#     operand: 47
# 38. P(c * x) = (c * P(x))
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. x in V
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (x, y)
#     core type: ExprTuple
#     sub-expressions: 60, 47
# 42. (y)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (P(c * x), c * P(x))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x, V)
#     core type: ExprTuple
#     sub-expressions: 60, 50
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. P(c * x)
#     core type: Operation
#     operator: 57
#     operand: 53
# 49. c * P(x)
#     core type: Operation
#     operator: 55
#     operands: 52
# 50. V
#     core type: Variable
#     sub-expressions:
# 51. (c * x)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 59, 54
# 53. c * x
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. P(x)
#     core type: Operation
#     operator: 57
#     operand: 60
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (c, x)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. P
#     core type: Variable
#     sub-expressions:
# 58. (x)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. c
#     core type: Variable
#     sub-expressions:
# 60. x
#     core type: Variable
#     sub-expressions:
