# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#anti_commutator_def">anti_commutator_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.linear_maps import anti_commutator_def

# %%
# check that the built expression is the same as the stored expression
assert anti_commutator_def.expr == stored_expr
assert anti_commutator_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: anti_commutator_def matches stored_expr")
# Out:
# Passed sanity check: anti_commutator_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{A, B \in V}~\left(\left\{A, B\right\} = \left(\left(A \circ B\right) + \left(B \circ A\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{A, B in V} ({A, B'} = ((A o B) + (B o A)))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{A, B in V} ({A, B'} = ((A o B) + (B o A)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{A, B in V} ({A, B'} = ((A o B) + (B o A)))]]
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{A, B in V} ({A, B'} = ((A o B) + (B o A)))]
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. (V -> {forall_{A, B in V} ({A, B'} = ((A o B) + (B o A))) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{A, B in V} ({A, B'} = ((A o B) + (B o A))) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 38
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 38
# ...
