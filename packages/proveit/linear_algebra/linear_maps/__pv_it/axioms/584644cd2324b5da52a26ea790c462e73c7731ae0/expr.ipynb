# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, K, Lambda, P, Px, Py, V, W, c, x, y
from proveit.linear_algebra import LinMap, ScalarMult, VecAdd
from proveit.logic import And, Equals, Forall, Iff, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(P, Iff(InSet(P, LinMap(V, W)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, W), domain = V), Forall(instance_param_or_params = [x, y], instance_expr = Equals(Function(P, [VecAdd(x, y)]), VecAdd(Px, Py)), domain = V), Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Function(P, [ScalarMult(c, x)]), ScalarMult(c, Px)), domain = V), domain = K)).with_wrapping_at(2,4)).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# P \mapsto \left(\begin{array}{c} \begin{array}{l} \left(P \in \mathcal{L}\left(V, W\right)\right) \Leftrightarrow  \\ \left(\begin{array}{c} \left[\forall_{x \in V}~\left(P\left(x\right) \in W\right)\right] \land  \\ \left[\forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right)\right] \land  \\ \left[\forall_{c \in K}~\left[\forall_{x \in V}~\left(P\left(c \cdot x\right) = \left(c \cdot P\left(x\right)\right)\right)\right]\right] \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. P -> ((P in LINMAP(V, W)) <=>  \\ ([forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]]))
#    core type: Lambda
#    parameter: 68
#    body: 2
# 1. (P)
#    core type: ExprTuple
#    sub-expressions: 68
# 2. (P in LINMAP(V, W)) <=>  \\ ([forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]])
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. (P in LINMAP(V, W), [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. P in LINMAP(V, W)
#    core type: Operation
#    operator: 56
#    operands: 7
# 6. [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]]
#    core type: Operation
#    operator: 32
#    operands: 8
# 7. (P, LINMAP(V, W))
#    core type: ExprTuple
#    sub-expressions: 68, 9
# 8. (forall_{x in V} (P(x) in W), forall_{x, y in V} (P(x + y) = (P(x) + P(y))), forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))])
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. LINMAP(V, W)
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. forall_{x in V} (P(x) in W)
#     core type: Operation
#     operator: 34
#     operand: 18
# 11. forall_{x, y in V} (P(x + y) = (P(x) + P(y)))
#     core type: Operation
#     operator: 34
#     operand: 19
# 12. forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]
#     core type: Operation
#     operator: 34
#     operand: 20
# 13. LINMAP
#     core type: Literal
#     sub-expressions:
# 14. (V, W)
#     core type: ExprTuple
#     sub-expressions: 61, 37
# 15. (x -> {P(x) in W if x in V.)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. ((x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. x -> {P(x) in W if x in V.
#     core type: Lambda
#     parameter: 71
#     body: 21
# 19. (x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Lambda
#     parameters: 52\n    body: 22
# 20. c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Lambda
#     parameter: 70
#     body: 24
# 21. {P(x) in W if x in V.
#     core type: Conditional
#     value: 25
#     condition: 50
# 22. {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. (c)
#     core type: ExprTuple
#     sub-expressions: 70
# 24. {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. P(x) in W
#     core type: Operation
#     operator: 56
#     operands: 30
# 26. P(x + y) = (P(x) + P(y))
#     core type: Operation
#     operator: 54
#     operands: 31
# 27. (x in V) and (y in V)
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. forall_{x in V} (P(c * x) = (c * P(x)))
#     core type: Operation
#     operator: 34
#     operand: 41
# 29. c in K
#     core type: Operation
#     operator: 56
#     operands: 36
# 30. (P(x), W)
#     core type: ExprTuple
#     sub-expressions: 65, 37
# 31. (P(x + y), P(x) + P(y))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. (x in V, y in V)
#     core type: ExprTuple
#     sub-expressions: 50, 40
# 34. forall
#     core type: Literal
#     sub-expressions:
# 35. (x -> {P(c * x) = (c * P(x)) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 41
# 36. (c, K)
#     core type: ExprTuple
#     sub-expressions: 70, 42
# 37. W
#     core type: Variable
#     sub-expressions:
# 38. P(x + y)
#     core type: Operation
#     operator: 68
#     operand: 47
# 39. P(x) + P(y)
#     core type: Operation
#     operator: 51
#     operands: 44
# 40. y in V
#     core type: Operation
#     operator: 56
#     operands: 45
# 41. x -> {P(c * x) = (c * P(x)) if x in V.
#     core type: Lambda
#     parameter: 71
#     body: 46
# 42. K
#     core type: Variable
#     sub-expressions:
# 43. (x + y)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. (P(x), P(y))
#     core type: ExprTuple
#     sub-expressions: 65, 48
# 45. (y, V)
#     core type: ExprTuple
#     sub-expressions: 58, 61
# 46. {P(c * x) = (c * P(x)) if x in V.
#     core type: Conditional
#     value: 49
#     condition: 50
# 47. x + y
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. P(y)
#     core type: Operation
#     operator: 68
#     operand: 58
# 49. P(c * x) = (c * P(x))
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. x in V
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (x, y)
#     core type: ExprTuple
#     sub-expressions: 71, 58
# 53. (y)
#     core type: ExprTuple
#     sub-expressions: 58
# 54. =
#     core type: Literal
#     sub-expressions:
# 55. (P(c * x), c * P(x))
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (x, V)
#     core type: ExprTuple
#     sub-expressions: 71, 61
# 58. y
#     core type: Variable
#     sub-expressions:
# 59. P(c * x)
#     core type: Operation
#     operator: 68
#     operand: 64
# 60. c * P(x)
#     core type: Operation
#     operator: 66
#     operands: 63
# 61. V
#     core type: Variable
#     sub-expressions:
# 62. (c * x)
#     core type: ExprTuple
#     sub-expressions: 64
# 63. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 70, 65
# 64. c * x
#     core type: Operation
#     operator: 66
#     operands: 67
# 65. P(x)
#     core type: Operation
#     operator: 68
#     operand: 71
# 66. *
#     core type: Literal
#     sub-expressions:
# 67. (c, x)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. P
#     core type: Variable
#     sub-expressions:
# 69. (x)
#     core type: ExprTuple
#     sub-expressions: 71
# 70. c
#     core type: Variable
#     sub-expressions:
# 71. x
#     core type: Variable
#     sub-expressions:
