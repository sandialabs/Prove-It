# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.linear_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, K, P, Px, Py, V, W, c, x, y
from proveit.linear_algebra import LinMap, ScalarMult, VecAdd
from proveit.logic import And, Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(InSet(P, LinMap(V, W)), And(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, W), domain = V), Forall(instance_param_or_params = [x, y], instance_expr = Equals(Function(P, [VecAdd(x, y)]), VecAdd(Px, Py)), domain = V), Forall(instance_param_or_params = [c], instance_expr = Forall(instance_param_or_params = sub_expr1, instance_expr = Equals(Function(P, [ScalarMult(c, x)]), ScalarMult(c, Px)), domain = V), domain = K)).with_wrapping_at(2,4))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(P \in \mathcal{L}\left(V, W\right), \begin{array}{c} \left[\forall_{x \in V}~\left(P\left(x\right) \in W\right)\right] \land  \\ \left[\forall_{x, y \in V}~\left(P\left(x + y\right) = \left(P\left(x\right) + P\left(y\right)\right)\right)\right] \land  \\ \left[\forall_{c \in K}~\left[\forall_{x \in V}~\left(P\left(c \cdot x\right) = \left(c \cdot P\left(x\right)\right)\right)\right]\right] \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (P in LINMAP(V, W), [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P in LINMAP(V, W)
#    core type: Operation
#    operator: 52
#    operands: 3
# 2. [forall_{x in V} (P(x) in W)] and  \\ [forall_{x, y in V} (P(x + y) = (P(x) + P(y)))] and  \\ [forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]]
#    core type: Operation
#    operator: 28
#    operands: 4
# 3. (P, LINMAP(V, W))
#    core type: ExprTuple
#    sub-expressions: 64, 5
# 4. (forall_{x in V} (P(x) in W), forall_{x, y in V} (P(x + y) = (P(x) + P(y))), forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))])
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. LINMAP(V, W)
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. forall_{x in V} (P(x) in W)
#    core type: Operation
#    operator: 30
#    operand: 14
# 7. forall_{x, y in V} (P(x + y) = (P(x) + P(y)))
#    core type: Operation
#    operator: 30
#    operand: 15
# 8. forall_{c in K} [forall_{x in V} (P(c * x) = (c * P(x)))]
#    core type: Operation
#    operator: 30
#    operand: 16
# 9. LINMAP
#    core type: Literal
#    sub-expressions:
# 10. (V, W)
#     core type: ExprTuple
#     sub-expressions: 57, 33
# 11. (x -> {P(x) in W if x in V.)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. ((x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. x -> {P(x) in W if x in V.
#     core type: Lambda
#     parameter: 67
#     body: 17
# 15. (x, y) -> {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Lambda
#     parameters: 48\n    body: 18
# 16. c -> {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Lambda
#     parameter: 66
#     body: 20
# 17. {P(x) in W if x in V.
#     core type: Conditional
#     value: 21
#     condition: 46
# 18. {P(x + y) = (P(x) + P(y)) if x in V ,  y in V.
#     core type: Conditional
#     value: 22
#     condition: 23
# 19. (c)
#     core type: ExprTuple
#     sub-expressions: 66
# 20. {forall_{x in V} (P(c * x) = (c * P(x))) if c in K.
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. P(x) in W
#     core type: Operation
#     operator: 52
#     operands: 26
# 22. P(x + y) = (P(x) + P(y))
#     core type: Operation
#     operator: 50
#     operands: 27
# 23. (x in V) and (y in V)
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. forall_{x in V} (P(c * x) = (c * P(x)))
#     core type: Operation
#     operator: 30
#     operand: 37
# 25. c in K
#     core type: Operation
#     operator: 52
#     operands: 32
# 26. (P(x), W)
#     core type: ExprTuple
#     sub-expressions: 61, 33
# 27. (P(x + y), P(x) + P(y))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (x in V, y in V)
#     core type: ExprTuple
#     sub-expressions: 46, 36
# 30. forall
#     core type: Literal
#     sub-expressions:
# 31. (x -> {P(c * x) = (c * P(x)) if x in V.)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. (c, K)
#     core type: ExprTuple
#     sub-expressions: 66, 38
# 33. W
#     core type: Variable
#     sub-expressions:
# 34. P(x + y)
#     core type: Operation
#     operator: 64
#     operand: 43
# 35. P(x) + P(y)
#     core type: Operation
#     operator: 47
#     operands: 40
# 36. y in V
#     core type: Operation
#     operator: 52
#     operands: 41
# 37. x -> {P(c * x) = (c * P(x)) if x in V.
#     core type: Lambda
#     parameter: 67
#     body: 42
# 38. K
#     core type: Variable
#     sub-expressions:
# 39. (x + y)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. (P(x), P(y))
#     core type: ExprTuple
#     sub-expressions: 61, 44
# 41. (y, V)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 42. {P(c * x) = (c * P(x)) if x in V.
#     core type: Conditional
#     value: 45
#     condition: 46
# 43. x + y
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. P(y)
#     core type: Operation
#     operator: 64
#     operand: 54
# 45. P(c * x) = (c * P(x))
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. x in V
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. +
#     core type: Literal
#     sub-expressions:
# 48. (x, y)
#     core type: ExprTuple
#     sub-expressions: 67, 54
# 49. (y)
#     core type: ExprTuple
#     sub-expressions: 54
# 50. =
#     core type: Literal
#     sub-expressions:
# 51. (P(c * x), c * P(x))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (x, V)
#     core type: ExprTuple
#     sub-expressions: 67, 57
# 54. y
#     core type: Variable
#     sub-expressions:
# 55. P(c * x)
#     core type: Operation
#     operator: 64
#     operand: 60
# 56. c * P(x)
#     core type: Operation
#     operator: 62
#     operands: 59
# 57. V
#     core type: Variable
#     sub-expressions:
# 58. (c * x)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. (c, P(x))
#     core type: ExprTuple
#     sub-expressions: 66, 61
# 60. c * x
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. P(x)
#     core type: Operation
#     operator: 64
#     operand: 67
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (c, x)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. P
#     core type: Variable
#     sub-expressions:
# 65. (x)
#     core type: ExprTuple
#     sub-expressions: 67
# 66. c
#     core type: Variable
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
