# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Lambda, V, Variable, a, i, v
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Complex, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [a_1_to_i, v], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, i)), ScalarMult(VecAdd(a_1_to_i), v)).with_wrapping_at(2), domains = [Complex, V]), domain = Natural), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 41
#    body: 2
# 1. (V)
#    core type: ExprTuple
#    sub-expressions: 41
# 2. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 17
#    operand: 8
# 4. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 41, 9
# 8. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#    core type: Lambda
#    parameter: 54
#    body: 11
# 9. VecSpaces(K)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. (i)
#     core type: ExprTuple
#     sub-expressions: 54
# 11. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. VecSpaces
#     core type: Literal
#     sub-expressions:
# 13. (K)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. i in Natural
#     core type: Operation
#     operator: 45
#     operands: 19
# 16. K
#     core type: Variable
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 54, 21
# 20. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 22\n    body: 23
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 48, 55
# 23. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 24
#     condition: 25
# 24. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 43
#     operands: 34
# 31. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 50
#     operands: 35
# 32. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 53
#     end_index: 54
# 33. v in V
#     core type: Operation
#     operator: 45
#     operands: 37
# 34. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 38
# 35. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 39, 55
# 36. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 40
# 37. (v, V)
#     core type: ExprTuple
#     sub-expressions: 55, 41
# 38. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 53
#     end_index: 54
# 39. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. a_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. V
#     core type: Variable
#     sub-expressions:
# 42. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 59
#     body: 47
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 49
# 47. a_{_a} * v
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 52. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 56
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. v
#     core type: Variable
#     sub-expressions:
# 56. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
