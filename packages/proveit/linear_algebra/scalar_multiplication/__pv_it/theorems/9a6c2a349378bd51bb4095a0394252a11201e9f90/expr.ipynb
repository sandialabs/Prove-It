# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import VecSpaces, lin_comb_axn
from proveit.logic import Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = InSet(lin_comb_axn, V), domain = V), domain = K), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) \in V\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Lambda
#    parameter: 42
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]
#    core type: Operation
#    operator: 23
#    operand: 5
# 4. (V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 54
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 54
# 7. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]
#    core type: Operation
#    operator: 23
#    operand: 13
# 9. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 54, 14
# 13. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 14. VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operand: 42
# 15. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. VecSpaces
#     core type: Literal
#     sub-expressions:
# 18. (K)
#     core type: ExprTuple
#     sub-expressions: 42
# 19. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 49
#     end_index: 50
# 20. forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)
#     core type: Operation
#     operator: 23
#     operand: 26
# 21. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 37
#     operands: 25
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 57
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 27
# 26. (x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 28\n    body: 29
# 27. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 49
#     end_index: 50
# 28. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 29. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 62
#     body: 34
# 31. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 49
#     end_index: 50
# 32. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V
#     core type: Operation
#     operator: 51
#     operands: 36
# 33. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. a_{_a} in K
#     core type: Operation
#     operator: 51
#     operands: 39
# 35. _a -> x_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 36. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), V)
#     core type: ExprTuple
#     sub-expressions: 40, 54
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 41
# 39. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 57, 42
# 40. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 49
#     end_index: 50
# 42. K
#     core type: Variable
#     sub-expressions:
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 46
# 45. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 62
#     body: 47
# 46. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 47. x_{_a} in V
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 62
#     body: 53
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 58, 54
# 53. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. V
#     core type: Variable
#     sub-expressions:
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 58. x_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. x
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
