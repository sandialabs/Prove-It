# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import VecSpaces, lin_comb_axn
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = InSet(lin_comb_axn, V), domain = V), domain = K), domain = VecSpaces(K))), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) \in V\right)\right]\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 57
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 57
# 3. {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Operation
#    operator: 30
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 58
#    operands: 7
# 6. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]])
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 57, 9
# 8. K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Lambda
#    parameter: 49
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]
#     core type: Operation
#     operator: 30
#     operand: 12
# 11. (V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 61
#     body: 14
# 13. (V)
#     core type: ExprTuple
#     sub-expressions: 61
# 14. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]
#     core type: Operation
#     operator: 30
#     operand: 20
# 16. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. in_c
#     core type: Literal
#     sub-expressions:
# 19. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 61, 21
# 20. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 22\n    body: 23
# 21. VecSpaces(K)
#     core type: Operation
#     operator: 24
#     operand: 49
# 22. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 27
#     condition: 28
# 24. VecSpaces
#     core type: Literal
#     sub-expressions:
# 25. (K)
#     core type: ExprTuple
#     sub-expressions: 49
# 26. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 56
#     end_index: 57
# 27. forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)
#     core type: Operation
#     operator: 30
#     operand: 33
# 28. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 44
#     operands: 32
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 64
# 30. forall
#     core type: Literal
#     sub-expressions:
# 31. ((x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 33
# 32. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 34
# 33. (x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 35\n    body: 36
# 34. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 56
#     end_index: 57
# 35. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 36. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 39
#     condition: 40
# 37. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 69
#     body: 41
# 38. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 56
#     end_index: 57
# 39. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V
#     core type: Operation
#     operator: 58
#     operands: 43
# 40. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. a_{_a} in K
#     core type: Operation
#     operator: 58
#     operands: 46
# 42. _a -> x_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 65
# 43. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), V)
#     core type: ExprTuple
#     sub-expressions: 47, 61
# 44. and
#     core type: Literal
#     sub-expressions:
# 45. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 48
# 46. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 64, 49
# 47. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 56
#     end_index: 57
# 49. K
#     core type: Variable
#     sub-expressions:
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 53
# 52. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 69
#     body: 54
# 53. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 54. x_{_a} in V
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 69
#     body: 60
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 65, 61
# 60. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. V
#     core type: Variable
#     sub-expressions:
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 64. a_{_a}
#     core type: IndexedVar
# variable: 66
# index: 69
# 65. x_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 66. a
#     core type: Variable
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
