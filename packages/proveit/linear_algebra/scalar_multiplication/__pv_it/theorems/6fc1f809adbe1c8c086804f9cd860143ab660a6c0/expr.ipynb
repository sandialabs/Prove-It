# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, i, k
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [k, a_1_to_i], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(k, IndexedVar(a, sub_expr1)), one, i)), ScalarMult(k, VecAdd(a_1_to_i))).with_wrapping_at(2), domains = [K, V]), domain = Natural), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{i \in \mathbb{N}}~\left[\forall_{k \in K,\left(a_{1} \in V\right), \left(a_{2} \in V\right), \ldots, \left(a_{i} \in V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(k \cdot a_{1}\right) +  \left(k \cdot a_{2}\right) +  \ldots +  \left(k \cdot a_{i}\right)\right) =  \\ \left(k \cdot \left(a_{1} +  a_{2} +  \ldots +  a_{i}\right)\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 49
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 49
# 3. {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]
#    core type: Operation
#    operator: 17
#    operand: 9
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 49, 10
# 9. i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#    core type: Lambda
#    parameter: 54
#    body: 12
# 10. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 40
# 11. (i)
#     core type: ExprTuple
#     sub-expressions: 54
# 12. {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 40
# 15. forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. i in Natural
#     core type: Operation
#     operator: 45
#     operands: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 54, 21
# 20. (k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Lambda
#     parameters: 22\n    body: 23
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (k,a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 55, 48
# 23. {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Conditional
#     value: 24
#     condition: 25
# 24. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (k in K)and (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i}), k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})
#     core type: Operation
#     operator: 43
#     operands: 34
# 31. k * (a_{1} +  a_{2} +  ... +  a_{i})
#     core type: Operation
#     operator: 50
#     operands: 35
# 32. k in K
#     core type: Operation
#     operator: 45
#     operands: 36
# 33. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 53
#     end_index: 54
# 34. ((k * a_{1}), (k * a_{2}), ..., (k * a_{i}))
#     core type: ExprTuple
#     sub-expressions: 38
# 35. (k, a_{1} +  a_{2} +  ... +  a_{i})
#     core type: ExprTuple
#     sub-expressions: 55, 39
# 36. (k, K)
#     core type: ExprTuple
#     sub-expressions: 55, 40
# 37. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 59
#     body: 41
# 38. (k * a_{1}), (k * a_{2}), ..., (k * a_{i})
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 53
#     end_index: 54
# 39. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. K
#     core type: Variable
#     sub-expressions:
# 41. a_{_a} in V
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. _a -> (k * a_{_a})
#     core type: Lambda
#     parameter: 59
#     body: 47
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 56, 49
# 47. k * a_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 49. V
#     core type: Variable
#     sub-expressions:
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (k, a_{_a})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 52. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 56
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. k
#     core type: Variable
#     sub-expressions:
# 56. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
