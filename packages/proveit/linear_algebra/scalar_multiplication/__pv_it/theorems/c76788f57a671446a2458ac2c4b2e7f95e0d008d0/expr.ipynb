# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, V, Variable, a, n, v
from proveit.core_expr_types import a_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(ScalarMult(VecAdd(a_1_to_n), v), VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), domain = VecSpaces(K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} +  a_{2} +  \ldots +  a_{n}\right) \cdot v\right) =  \\ \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{n} \cdot v\right)\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V in_c VecSpaces(K)} [forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]]]
#    core type: Operation
#    operator: 25
#    operand: 2
# 1. (V -> {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. V -> {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 44
#    body: 4
# 3. (V)
#    core type: ExprTuple
#    sub-expressions: 44
# 4. {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]]
#    core type: Operation
#    operator: 25
#    operand: 10
# 6. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 44, 11
# 10. n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#     core type: Lambda
#     parameter: 57
#     body: 13
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 14
#     operand: 45
# 12. (n)
#     core type: ExprTuple
#     sub-expressions: 57
# 13. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. VecSpaces
#     core type: Literal
#     sub-expressions:
# 15. (K)
#     core type: ExprTuple
#     sub-expressions: 45
# 16. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]
#     core type: Operation
#     operator: 25
#     operand: 20
# 17. n in Natural
#     core type: Operation
#     operator: 40
#     operands: 19
# 18. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 57, 21
# 20. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 51\n    body: 22
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 23
#     condition: 24
# 23. forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))
#     core type: Operation
#     operator: 25
#     operand: 29
# 24. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. (v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 30
# 29. v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Lambda
#     parameter: 61
#     body: 32
# 30. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 56
#     end_index: 57
# 31. (v)
#     core type: ExprTuple
#     sub-expressions: 61
# 32. {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Conditional
#     value: 34
#     condition: 35
# 33. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 64
#     body: 36
# 34. ((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. v in V
#     core type: Operation
#     operator: 40
#     operands: 39
# 36. a_{_a} in K
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. ((a_{1} +  a_{2} +  ... +  a_{n}) * v, (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. (v, V)
#     core type: ExprTuple
#     sub-expressions: 61, 44
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 42. (a_{1} +  a_{2} +  ... +  a_{n}) * v
#     core type: Operation
#     operator: 58
#     operands: 46
# 43. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)
#     core type: Operation
#     operator: 50
#     operands: 47
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. K
#     core type: Variable
#     sub-expressions:
# 46. (a_{1} +  a_{2} +  ... +  a_{n}, v)
#     core type: ExprTuple
#     sub-expressions: 48, 61
# 47. ((a_{1} * v), (a_{2} * v), ..., (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 49
# 48. a_{1} +  a_{2} +  ... +  a_{n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. (a_{1} * v), (a_{2} * v), ..., (a_{n} * v)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 56
#     end_index: 57
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 52. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 64
#     body: 54
# 53. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 54. a_{_a} * v
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 60
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. *
#     core type: Literal
#     sub-expressions:
# 59. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. a_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 61. v
#     core type: Variable
#     sub-expressions:
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
