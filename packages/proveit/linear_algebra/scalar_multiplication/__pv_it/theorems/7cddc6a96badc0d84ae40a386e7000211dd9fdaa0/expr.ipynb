# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, K, Lambda, V, v
from proveit.core_expr_types import Q__b_1_to_j, b_1_to_j, f__b_1_to_j
from proveit.linear_algebra import ScalarMult, VecSpaces, VecSum
from proveit.linear_algebra.addition import vec_summation_b1toj_fQ
from proveit.logic import Equals, Forall, Implies, InClass, InSet
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [v], instance_expr = Implies(InSet(vec_summation_b1toj_fQ, K), Equals(ScalarMult(Sum(index_or_indices = sub_expr1, summand = f__b_1_to_j, condition = Q__b_1_to_j), v), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(f__b_1_to_j, v), condition = Q__b_1_to_j)).with_wrapping_at(1)).with_wrapping_at(2), domain = V), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right] \in K\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(\left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right] \cdot v\right) \\  = \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(f\left(b_{1}, b_{2}, \ldots, b_{j}\right) \cdot v\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{v in V} (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)])) if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{v in V} (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)])) if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 23
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 23
# 3. {forall_{v in V} (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)])) if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{v in V} (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)]))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (v -> {([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)]) if v in V.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 23, 11
# 10. v -> {([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)]) if v in V.
#     core type: Lambda
#     parameter: 47
#     body: 13
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 14
#     operand: 29
# 12. (v)
#     core type: ExprTuple
#     sub-expressions: 47
# 13. {([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)]) if v in V.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. VecSpaces
#     core type: Literal
#     sub-expressions:
# 15. (K)
#     core type: ExprTuple
#     sub-expressions: 29
# 16. ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K) =>  \\ (([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)])
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. v in V
#     core type: Operation
#     operator: 24
#     operands: 20
# 18. =>
#     core type: Literal
#     sub-expressions:
# 19. ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K, ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)])
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. (v, V)
#     core type: ExprTuple
#     sub-expressions: 47, 23
# 21. [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] in K
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)]
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. V
#     core type: Variable
#     sub-expressions:
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}), K)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 33
#     operand: 40
# 29. K
#     core type: Variable
#     sub-expressions:
# 30. [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] * v
#     core type: Operation
#     operator: 43
#     operands: 32
# 31. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) * v)
#     core type: Operation
#     operator: 33
#     operand: 36
# 32. (Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}), v)
#     core type: ExprTuple
#     sub-expressions: 35, 47
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) * v if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 36
# 35. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 37
#     operand: 40
# 36. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) * v if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 50\n    body: 39
# 37. Sum
#     core type: Literal
#     sub-expressions:
# 38. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 40
# 39. {f(b_{1}, b_{2}, ..., b_{j}) * v if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 41
#     condition: 45
# 40. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 50\n    body: 42
# 41. f(b_{1}, b_{2}, ..., b_{j}) * v
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 46
#     condition: 45
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (f(b_{1}, b_{2}, ..., b_{j}), v)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 48
#     operands: 50
# 46. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. v
#     core type: Variable
#     sub-expressions:
# 48. Q
#     core type: Variable
#     sub-expressions:
# 49. f
#     core type: Variable
#     sub-expressions:
# 50. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 51
# 51. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 52. _a -> b_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 55
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. b_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 56. b
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
