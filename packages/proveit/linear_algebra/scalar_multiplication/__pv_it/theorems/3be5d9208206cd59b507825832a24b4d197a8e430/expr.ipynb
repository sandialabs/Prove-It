# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, V, Variable, a, i, v
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [a_1_to_i, v], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, i)), ScalarMult(VecAdd(a_1_to_i), v)).with_wrapping_at(2), domains = [Complex, V]), domain = Natural), domain = VecSpaces(K))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]
#    core type: Operation
#    operator: 19
#    operand: 2
# 1. (V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 43
#    body: 4
# 3. (V)
#    core type: ExprTuple
#    sub-expressions: 43
# 4. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 19
#    operand: 10
# 6. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in_c
#    core type: Literal
#    sub-expressions:
# 9. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 43, 11
# 10. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Lambda
#     parameter: 56
#     body: 13
# 11. VecSpaces(K)
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. (i)
#     core type: ExprTuple
#     sub-expressions: 56
# 13. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. VecSpaces
#     core type: Literal
#     sub-expressions:
# 15. (K)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 19
#     operand: 22
# 17. i in Natural
#     core type: Operation
#     operator: 47
#     operands: 21
# 18. K
#     core type: Variable
#     sub-expressions:
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 23
# 22. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 24\n    body: 25
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 50, 57
# 25. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 45
#     operands: 36
# 33. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 52
#     operands: 37
# 34. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 55
#     end_index: 56
# 35. v in V
#     core type: Operation
#     operator: 47
#     operands: 39
# 36. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 40
# 37. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 41, 57
# 38. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 42
# 39. (v, V)
#     core type: ExprTuple
#     sub-expressions: 57, 43
# 40. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 56
# 41. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. a_{_a} in Complex
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. V
#     core type: Variable
#     sub-expressions:
# 44. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 61
#     body: 49
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 50
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 49. a_{_a} * v
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. Complex
#     core type: Literal
#     sub-expressions:
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. i
#     core type: Variable
#     sub-expressions:
# 57. v
#     core type: Variable
#     sub-expressions:
# 58. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
