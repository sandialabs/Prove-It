# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import VecSpaces, lin_comb_axn
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = InSet(lin_comb_axn, V), domain = V), domain = K), domain = VecSpaces(K))), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) \in V\right)\right]\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 56
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 56
# 2. {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Operation
#    operator: 29
#    operand: 7
# 4. n in NaturalPos
#    core type: Operation
#    operator: 57
#    operands: 6
# 5. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]])
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 56, 8
# 7. K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Lambda
#    parameter: 48
#    body: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]
#    core type: Operation
#    operator: 29
#    operand: 11
# 10. (V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 60
#     body: 13
# 12. (V)
#     core type: ExprTuple
#     sub-expressions: 60
# 13. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]
#     core type: Operation
#     operator: 29
#     operand: 19
# 15. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. in_c
#     core type: Literal
#     sub-expressions:
# 18. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 60, 20
# 19. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 21\n    body: 22
# 20. VecSpaces(K)
#     core type: Operation
#     operator: 23
#     operand: 48
# 21. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. VecSpaces
#     core type: Literal
#     sub-expressions:
# 24. (K)
#     core type: ExprTuple
#     sub-expressions: 48
# 25. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 55
#     end_index: 56
# 26. forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)
#     core type: Operation
#     operator: 29
#     operand: 32
# 27. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 43
#     operands: 31
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 63
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. ((x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 33
# 32. (x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 34\n    body: 35
# 33. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 55
#     end_index: 56
# 34. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 35. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 38
#     condition: 39
# 36. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 68
#     body: 40
# 37. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 55
#     end_index: 56
# 38. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V
#     core type: Operation
#     operator: 57
#     operands: 42
# 39. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. a_{_a} in K
#     core type: Operation
#     operator: 57
#     operands: 45
# 41. _a -> x_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 64
# 42. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), V)
#     core type: ExprTuple
#     sub-expressions: 46, 60
# 43. and
#     core type: Literal
#     sub-expressions:
# 44. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 47
# 45. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 63, 48
# 46. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 55
#     end_index: 56
# 48. K
#     core type: Variable
#     sub-expressions:
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 52
# 51. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 68
#     body: 53
# 52. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 53. x_{_a} in V
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 68
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 64, 60
# 59. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. V
#     core type: Variable
#     sub-expressions:
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. a_{_a}
#     core type: IndexedVar
# variable: 65
# index: 68
# 64. x_{_a}
#     core type: IndexedVar
# variable: 66
# index: 68
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. x
#     core type: Variable
#     sub-expressions:
# 67. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. _a
#     core type: Variable
#     sub-expressions:
