# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(ScalarMult(a, VecAdd(x_1_to_n)), VecAdd(ExprRange(sub_expr1, ScalarMult(a, IndexedVar(x, sub_expr1)), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{n \in \mathbb{N}}~\left[\forall_{a \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a \cdot \left(x_{1} +  x_{2} +  \ldots +  x_{n}\right)\right) =  \\ \left(\left(a \cdot x_{1}\right) +  \left(a \cdot x_{2}\right) +  \ldots +  \left(a \cdot x_{n}\right)\right) \end{array} \end{array}\right)\right]\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]]]
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]]
#    core type: Operation
#    operator: 28
#    operand: 4
# 3. (V -> {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 56
#    body: 6
# 5. (V)
#    core type: ExprTuple
#    sub-expressions: 56
# 6. {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]
#    core type: Operation
#    operator: 28
#    operand: 12
# 8. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (n -> {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 56, 13
# 12. n -> {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.
#     core type: Lambda
#     parameter: 59
#     body: 15
# 13. VecSpaces(K)
#     core type: Operation
#     operator: 16
#     operand: 32
# 14. (n)
#     core type: ExprTuple
#     sub-expressions: 59
# 15. {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. VecSpaces
#     core type: Literal
#     sub-expressions:
# 17. (K)
#     core type: ExprTuple
#     sub-expressions: 32
# 18. forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]
#     core type: Operation
#     operator: 28
#     operand: 22
# 19. n in Natural
#     core type: Operation
#     operator: 52
#     operands: 21
# 20. (a -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 23
# 22. a -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.
#     core type: Lambda
#     parameter: 62
#     body: 25
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. (a)
#     core type: ExprTuple
#     sub-expressions: 62
# 25. {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))
#     core type: Operation
#     operator: 28
#     operand: 31
# 27. a in K
#     core type: Operation
#     operator: 52
#     operands: 30
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. ((x_{1}, x_{2}, ..., x_{n}) -> {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. (a, K)
#     core type: ExprTuple
#     sub-expressions: 62, 32
# 31. (x_{1}, x_{2}, ..., x_{n}) -> {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 50\n    body: 33
# 32. K
#     core type: Variable
#     sub-expressions:
# 33. {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 34
#     condition: 35
# 34. (a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (a * (x_{1} +  x_{2} +  ... +  x_{n}), (a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 42
# 40. a * (x_{1} +  x_{2} +  ... +  x_{n})
#     core type: Operation
#     operator: 60
#     operands: 43
# 41. (a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})
#     core type: Operation
#     operator: 49
#     operands: 44
# 42. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 58
#     end_index: 59
# 43. (a, x_{1} +  x_{2} +  ... +  x_{n})
#     core type: ExprTuple
#     sub-expressions: 62, 46
# 44. ((a * x_{1}), (a * x_{2}), ..., (a * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 47
# 45. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 66
#     body: 48
# 46. x_{1} +  x_{2} +  ... +  x_{n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. (a * x_{1}), (a * x_{2}), ..., (a * x_{n})
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 58
#     end_index: 59
# 48. x_{_a} in V
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. _a -> (a * x_{_a})
#     core type: Lambda
#     parameter: 66
#     body: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 63, 56
# 54. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 55. a * x_{_a}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. V
#     core type: Variable
#     sub-expressions:
# 57. _a -> x_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 63
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. *
#     core type: Literal
#     sub-expressions:
# 61. (a, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. x_{_a}
#     core type: IndexedVar
# variable: 64
# index: 66
# 64. x
#     core type: Variable
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
