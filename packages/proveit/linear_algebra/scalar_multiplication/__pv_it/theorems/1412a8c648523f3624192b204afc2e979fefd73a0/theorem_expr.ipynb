# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#factorization_from_scalars">factorization_from_scalars</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra.scalar_multiplication import factorization_from_scalars

# %%
# check that the built expression is the same as the stored expression
assert factorization_from_scalars.expr == stored_expr
assert factorization_from_scalars.expr._style_id == stored_expr._style_id
print("Passed sanity check: factorization_from_scalars matches stored_expr")
# Out:
# Passed sanity check: factorization_from_scalars matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]]
#    core type: Operation
#    operator: 22
#    operand: 2
# 1. (K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]]
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]
#    core type: Operation
#    operator: 22
#    operand: 5
# 4. (V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 46
#    body: 7
# 6. (V)
#    core type: ExprTuple
#    sub-expressions: 46
# 7. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 22
#    operand: 13
# 9. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. in_c
#     core type: Literal
#     sub-expressions:
# 12. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 46, 14
# 13. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Lambda
#     parameter: 59
#     body: 16
# 14. VecSpaces(K)
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (i)
#     core type: ExprTuple
#     sub-expressions: 59
# 16. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. VecSpaces
#     core type: Literal
#     sub-expressions:
# 18. (K)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 22
#     operand: 25
# 20. i in Natural
#     core type: Operation
#     operator: 50
#     operands: 24
# 21. K
#     core type: Variable
#     sub-expressions:
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 26
# 25. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 27\n    body: 28
# 26. Natural
#     core type: Literal
#     sub-expressions:
# 27. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 53, 60
# 28. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 29
#     condition: 30
# 29. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 48
#     operands: 39
# 36. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 55
#     operands: 40
# 37. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 58
#     end_index: 59
# 38. v in V
#     core type: Operation
#     operator: 50
#     operands: 42
# 39. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 43
# 40. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 44, 60
# 41. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 45
# 42. (v, V)
#     core type: ExprTuple
#     sub-expressions: 60, 46
# 43. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 58
#     end_index: 59
# 44. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. a_{_a} in Complex
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. V
#     core type: Variable
#     sub-expressions:
# 47. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 64
#     body: 52
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 54
# 52. a_{_a} * v
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 54. Complex
#     core type: Literal
#     sub-expressions:
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 61, 60
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 61
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. i
#     core type: Variable
#     sub-expressions:
# 60. v
#     core type: Variable
#     sub-expressions:
# 61. a_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
