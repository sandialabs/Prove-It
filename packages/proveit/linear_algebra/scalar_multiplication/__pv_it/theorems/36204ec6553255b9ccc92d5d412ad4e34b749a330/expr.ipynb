# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Lambda, V, Variable, a, i, k
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [k, a_1_to_i], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(k, IndexedVar(a, sub_expr1)), one, i)), ScalarMult(k, VecAdd(a_1_to_i))).with_wrapping_at(2), domains = [K, V]), domain = Natural), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i \in \mathbb{N}}~\left[\forall_{k \in K,\left(a_{1} \in V\right), \left(a_{2} \in V\right), \ldots, \left(a_{i} \in V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(k \cdot a_{1}\right) +  \left(k \cdot a_{2}\right) +  \ldots +  \left(k \cdot a_{i}\right)\right) =  \\ \left(k \cdot \left(a_{1} +  a_{2} +  \ldots +  a_{i}\right)\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]]
#    core type: Lambda
#    parameter: 42
#    body: 1
# 1. forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]
#    core type: Operation
#    operator: 19
#    operand: 3
# 2. (V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 51
#    body: 5
# 4. (V)
#    core type: ExprTuple
#    sub-expressions: 51
# 5. {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]
#    core type: Operation
#    operator: 19
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 51, 12
# 11. i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#     core type: Lambda
#     parameter: 56
#     body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 42
# 13. (i)
#     core type: ExprTuple
#     sub-expressions: 56
# 14. {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 42
# 17. forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))
#     core type: Operation
#     operator: 19
#     operand: 22
# 18. i in Natural
#     core type: Operation
#     operator: 47
#     operands: 21
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 23
# 22. (k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Lambda
#     parameters: 24\n    body: 25
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. (k,a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 25. {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (k in K)and (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i}), k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. (k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})
#     core type: Operation
#     operator: 45
#     operands: 36
# 33. k * (a_{1} +  a_{2} +  ... +  a_{i})
#     core type: Operation
#     operator: 52
#     operands: 37
# 34. k in K
#     core type: Operation
#     operator: 47
#     operands: 38
# 35. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 55
#     end_index: 56
# 36. ((k * a_{1}), (k * a_{2}), ..., (k * a_{i}))
#     core type: ExprTuple
#     sub-expressions: 40
# 37. (k, a_{1} +  a_{2} +  ... +  a_{i})
#     core type: ExprTuple
#     sub-expressions: 57, 41
# 38. (k, K)
#     core type: ExprTuple
#     sub-expressions: 57, 42
# 39. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 61
#     body: 43
# 40. (k * a_{1}), (k * a_{2}), ..., (k * a_{i})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 56
# 41. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. K
#     core type: Variable
#     sub-expressions:
# 43. a_{_a} in V
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. _a -> (k * a_{_a})
#     core type: Lambda
#     parameter: 61
#     body: 49
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 50
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 49. k * a_{_a}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. V
#     core type: Variable
#     sub-expressions:
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (k, a_{_a})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. i
#     core type: Variable
#     sub-expressions:
# 57. k
#     core type: Variable
#     sub-expressions:
# 58. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
