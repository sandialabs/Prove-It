# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, n, v
from proveit.core_expr_types import a_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(ScalarMult(VecAdd(a_1_to_n), v), VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} +  a_{2} +  \ldots +  a_{n}\right) \cdot v\right) =  \\ \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{n} \cdot v\right)\right) \end{array} \end{array}\right)\right]\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 43
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 43
# 3. {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]]
#    core type: Operation
#    operator: 24
#    operand: 9
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 43, 10
# 9. n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#    core type: Lambda
#    parameter: 56
#    body: 12
# 10. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 44
# 11. (n)
#     core type: ExprTuple
#     sub-expressions: 56
# 12. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 44
# 15. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]
#     core type: Operation
#     operator: 24
#     operand: 19
# 16. n in Natural
#     core type: Operation
#     operator: 39
#     operands: 18
# 17. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 19. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 50\n    body: 21
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))
#     core type: Operation
#     operator: 24
#     operand: 28
# 23. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. (v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 29
# 28. v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Lambda
#     parameter: 60
#     body: 31
# 29. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 55
#     end_index: 56
# 30. (v)
#     core type: ExprTuple
#     sub-expressions: 60
# 31. {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Conditional
#     value: 33
#     condition: 34
# 32. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 63
#     body: 35
# 33. ((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. v in V
#     core type: Operation
#     operator: 39
#     operands: 38
# 35. a_{_a} in K
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} +  a_{2} +  ... +  a_{n}) * v, (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. (v, V)
#     core type: ExprTuple
#     sub-expressions: 60, 43
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 59, 44
# 41. (a_{1} +  a_{2} +  ... +  a_{n}) * v
#     core type: Operation
#     operator: 57
#     operands: 45
# 42. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)
#     core type: Operation
#     operator: 49
#     operands: 46
# 43. V
#     core type: Variable
#     sub-expressions:
# 44. K
#     core type: Variable
#     sub-expressions:
# 45. (a_{1} +  a_{2} +  ... +  a_{n}, v)
#     core type: ExprTuple
#     sub-expressions: 47, 60
# 46. ((a_{1} * v), (a_{2} * v), ..., (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 48
# 47. a_{1} +  a_{2} +  ... +  a_{n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. (a_{1} * v), (a_{2} * v), ..., (a_{n} * v)
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 55
#     end_index: 56
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 51. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 63
#     body: 53
# 52. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 53. a_{_a} * v
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. a_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 60. v
#     core type: Variable
#     sub-expressions:
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
