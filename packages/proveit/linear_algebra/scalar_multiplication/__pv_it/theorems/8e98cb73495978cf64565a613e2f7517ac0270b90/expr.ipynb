# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import K, V, n
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import VecSpaces, lin_comb_axn
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [K], instance_expr = Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = InSet(lin_comb_axn, V), domain = V), domain = K), domain = VecSpaces(K))), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{K}~\left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) \in V\right)\right]\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]]
#    core type: Operation
#    operator: 31
#    operand: 2
# 1. (n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 58
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 58
# 4. {forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]] if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Operation
#    operator: 31
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 59
#    operands: 8
# 7. (K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]])
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 58, 10
# 9. K -> [forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]]
#    core type: Lambda
#    parameter: 50
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. forall_{V in_c VecSpaces(K)} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]]
#     core type: Operation
#     operator: 31
#     operand: 13
# 12. (V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Lambda
#     parameter: 62
#     body: 15
# 14. (V)
#     core type: ExprTuple
#     sub-expressions: 62
# 15. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]
#     core type: Operation
#     operator: 31
#     operand: 21
# 17. V in_c VecSpaces(K)
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. in_c
#     core type: Literal
#     sub-expressions:
# 20. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 62, 22
# 21. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 22. VecSpaces(K)
#     core type: Operation
#     operator: 25
#     operand: 50
# 23. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. VecSpaces
#     core type: Literal
#     sub-expressions:
# 26. (K)
#     core type: ExprTuple
#     sub-expressions: 50
# 27. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 57
#     end_index: 58
# 28. forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)
#     core type: Operation
#     operator: 31
#     operand: 34
# 29. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 45
#     operands: 33
# 30. _a -> a_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 65
# 31. forall
#     core type: Literal
#     sub-expressions:
# 32. ((x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 34
# 33. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 35
# 34. (x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 36\n    body: 37
# 35. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 57
#     end_index: 58
# 36. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 37. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 40
#     condition: 41
# 38. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 70
#     body: 42
# 39. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 57
#     end_index: 58
# 40. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V
#     core type: Operation
#     operator: 59
#     operands: 44
# 41. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. a_{_a} in K
#     core type: Operation
#     operator: 59
#     operands: 47
# 43. _a -> x_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 66
# 44. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), V)
#     core type: ExprTuple
#     sub-expressions: 48, 62
# 45. and
#     core type: Literal
#     sub-expressions:
# 46. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 49
# 47. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 65, 50
# 48. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 57
#     end_index: 58
# 50. K
#     core type: Variable
#     sub-expressions:
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 54
# 53. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 70
#     body: 55
# 54. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 57
#     end_index: 58
# 55. x_{_a} in V
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 70
#     body: 61
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. n
#     core type: Variable
#     sub-expressions:
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 66, 62
# 61. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. V
#     core type: Variable
#     sub-expressions:
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. a_{_a}
#     core type: IndexedVar
# variable: 67
# index: 70
# 66. x_{_a}
#     core type: IndexedVar
# variable: 68
# index: 70
# 67. a
#     core type: Variable
#     sub-expressions:
# 68. x
#     core type: Variable
#     sub-expressions:
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. _a
#     core type: Variable
#     sub-expressions:
