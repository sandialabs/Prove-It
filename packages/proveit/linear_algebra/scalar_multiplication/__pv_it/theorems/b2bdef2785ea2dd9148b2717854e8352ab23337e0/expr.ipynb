# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, Lambda, V, Variable, a, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(ScalarMult(a, VecAdd(x_1_to_n)), VecAdd(ExprRange(sub_expr1, ScalarMult(a, IndexedVar(x, sub_expr1)), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{n \in \mathbb{N}}~\left[\forall_{a \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a \cdot \left(x_{1} +  x_{2} +  \ldots +  x_{n}\right)\right) =  \\ \left(\left(a \cdot x_{1}\right) +  \left(a \cdot x_{2}\right) +  \ldots +  \left(a \cdot x_{n}\right)\right) \end{array} \end{array}\right)\right]\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 52
#    body: 2
# 1. (V)
#    core type: ExprTuple
#    sub-expressions: 52
# 2. {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]
#    core type: Operation
#    operator: 24
#    operand: 8
# 4. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# ...
