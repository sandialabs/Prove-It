# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, V, Variable, a, i, k
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [k, a_1_to_i], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(k, IndexedVar(a, sub_expr1)), one, i)), ScalarMult(k, VecAdd(a_1_to_i))).with_wrapping_at(2), domains = [K, V]), domain = Natural), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{i \in \mathbb{N}}~\left[\forall_{k \in K,\left(a_{1} \in V\right), \left(a_{2} \in V\right), \ldots, \left(a_{i} \in V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(k \cdot a_{1}\right) +  \left(k \cdot a_{2}\right) +  \ldots +  \left(k \cdot a_{i}\right)\right) =  \\ \left(k \cdot \left(a_{1} +  a_{2} +  \ldots +  a_{i}\right)\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]
#    core type: Operation
#    operator: 14
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 46, 7
# 6. i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#    core type: Lambda
#    parameter: 51
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 37
# 8. (i)
#    core type: ExprTuple
#    sub-expressions: 51
# 9. {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 37
# 12. forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. i in Natural
#     core type: Operation
#     operator: 42
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 18
# 17. (k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. (k,a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 20. {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (k in K)and (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i}), k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. (k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. (k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})
#     core type: Operation
#     operator: 40
#     operands: 31
# 28. k * (a_{1} +  a_{2} +  ... +  a_{i})
#     core type: Operation
#     operator: 47
#     operands: 32
# 29. k in K
#     core type: Operation
#     operator: 42
#     operands: 33
# 30. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 50
#     end_index: 51
# 31. ((k * a_{1}), (k * a_{2}), ..., (k * a_{i}))
#     core type: ExprTuple
#     sub-expressions: 35
# 32. (k, a_{1} +  a_{2} +  ... +  a_{i})
#     core type: ExprTuple
#     sub-expressions: 52, 36
# 33. (k, K)
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 34. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 56
#     body: 38
# 35. (k * a_{1}), (k * a_{2}), ..., (k * a_{i})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 50
#     end_index: 51
# 36. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. K
#     core type: Variable
#     sub-expressions:
# 38. a_{_a} in V
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. _a -> (k * a_{_a})
#     core type: Lambda
#     parameter: 56
#     body: 44
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 53, 46
# 44. k * a_{_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 46. V
#     core type: Variable
#     sub-expressions:
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (k, a_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 53
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. k
#     core type: Variable
#     sub-expressions:
# 53. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
