# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, i, k
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [k, a_1_to_i], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(k, IndexedVar(a, sub_expr1)), one, i)), ScalarMult(k, VecAdd(a_1_to_i))).with_wrapping_at(2), domains = [K, V]), domain = Natural), domain = VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i \in \mathbb{N}}~\left[\forall_{k \in K,\left(a_{1} \in V\right), \left(a_{2} \in V\right), \ldots, \left(a_{i} \in V\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(k \cdot a_{1}\right) +  \left(k \cdot a_{2}\right) +  \ldots +  \left(k \cdot a_{i}\right)\right) =  \\ \left(k \cdot \left(a_{1} +  a_{2} +  \ldots +  a_{i}\right)\right) \end{array} \end{array}\right)\right]\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]]
#    core type: Lambda
#    parameter: 43
#    body: 2
# 2. forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. V -> {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 52
#    body: 6
# 5. (V)
#    core type: ExprTuple
#    sub-expressions: 52
# 6. {forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]
#    core type: Operation
#    operator: 20
#    operand: 12
# 8. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 52, 13
# 12. i -> {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#     core type: Lambda
#     parameter: 57
#     body: 15
# 13. VecSpaces(K)
#     core type: Operation
#     operator: 16
#     operand: 43
# 14. (i)
#     core type: ExprTuple
#     sub-expressions: 57
# 15. {forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))) if i in Natural.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. VecSpaces
#     core type: Literal
#     sub-expressions:
# 17. (K)
#     core type: ExprTuple
#     sub-expressions: 43
# 18. forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))
#     core type: Operation
#     operator: 20
#     operand: 23
# 19. i in Natural
#     core type: Operation
#     operator: 48
#     operands: 22
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 57, 24
# 23. (k, a_{1}, a_{2}, ..., a_{i}) -> {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Lambda
#     parameters: 25\n    body: 26
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. (k,a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 26. {((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})) if k in K, (a_{1} in V) ,  (a_{2} in V) ,  ... ,  (a_{i} in V).
#     core type: Conditional
#     value: 27
#     condition: 28
# 27. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (k in K)and (a_{1} in V) and  (a_{2} in V) and  ... and  (a_{i} in V)
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. ((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i}), k * (a_{1} +  a_{2} +  ... +  a_{i}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. (k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. (k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})
#     core type: Operation
#     operator: 46
#     operands: 37
# 34. k * (a_{1} +  a_{2} +  ... +  a_{i})
#     core type: Operation
#     operator: 53
#     operands: 38
# 35. k in K
#     core type: Operation
#     operator: 48
#     operands: 39
# 36. (a_{1} in V), (a_{2} in V), ..., (a_{i} in V)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 56
#     end_index: 57
# 37. ((k * a_{1}), (k * a_{2}), ..., (k * a_{i}))
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (k, a_{1} +  a_{2} +  ... +  a_{i})
#     core type: ExprTuple
#     sub-expressions: 58, 42
# 39. (k, K)
#     core type: ExprTuple
#     sub-expressions: 58, 43
# 40. _a -> (a_{_a} in V)
#     core type: Lambda
#     parameter: 62
#     body: 44
# 41. (k * a_{1}), (k * a_{2}), ..., (k * a_{i})
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 56
#     end_index: 57
# 42. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. K
#     core type: Variable
#     sub-expressions:
# 44. a_{_a} in V
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. _a -> (k * a_{_a})
#     core type: Lambda
#     parameter: 62
#     body: 50
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 51
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 59, 52
# 50. k * a_{_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 52. V
#     core type: Variable
#     sub-expressions:
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (k, a_{_a})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 59
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. k
#     core type: Variable
#     sub-expressions:
# 59. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
