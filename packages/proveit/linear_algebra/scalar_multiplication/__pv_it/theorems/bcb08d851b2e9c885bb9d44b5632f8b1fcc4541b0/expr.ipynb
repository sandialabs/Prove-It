# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, K, Lambda, V
from proveit.core_expr_types import a_1_to_n, x_1_to_n
from proveit.linear_algebra import VecSpaces, lin_comb_axn
from proveit.logic import Forall, InClass, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(V, Conditional(Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = InSet(lin_comb_axn, V), domain = V), domain = K), InClass(V, VecSpaces(K))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# V \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\left(\left(a_{1} \cdot x_{1}\right) +  \left(a_{2} \cdot x_{2}\right) +  \ldots +  \left(a_{n} \cdot x_{n}\right)\right) \in V\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. V -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 49
#    body: 2
# 1. (V)
#    core type: ExprTuple
#    sub-expressions: 49
# 2. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)]
#    core type: Operation
#    operator: 18
#    operand: 8
# 4. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 49, 9
# 8. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. VecSpaces(K)
#    core type: Operation
#    operator: 12
#    operand: 37
# 10. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. {forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. VecSpaces
#     core type: Literal
#     sub-expressions:
# 13. (K)
#     core type: ExprTuple
#     sub-expressions: 37
# 14. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 44
#     end_index: 45
# 15. forall_{x_{1}, x_{2}, ..., x_{n} in V} (((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V)
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 32
#     operands: 20
# 17. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (x_{1}, x_{2}, ..., x_{n}) -> {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 22. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 44
#     end_index: 45
# 23. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. {((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 57
#     body: 29
# 26. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 44
#     end_index: 45
# 27. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})) in V
#     core type: Operation
#     operator: 46
#     operands: 31
# 28. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. a_{_a} in K
#     core type: Operation
#     operator: 46
#     operands: 34
# 30. _a -> x_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 31. ((a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n}), V)
#     core type: ExprTuple
#     sub-expressions: 35, 49
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 36
# 34. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 35. (a_{1} * x_{1}) +  (a_{2} * x_{2}) +  ... +  (a_{n} * x_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 44
#     end_index: 45
# 37. K
#     core type: Variable
#     sub-expressions:
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. ((a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 41
# 40. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 57
#     body: 42
# 41. (a_{1} * x_{1}), (a_{2} * x_{2}), ..., (a_{n} * x_{n})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 42. x_{_a} in V
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. _a -> (a_{_a} * x_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 53, 49
# 48. a_{_a} * x_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. V
#     core type: Variable
#     sub-expressions:
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (a_{_a}, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 53. x_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. x
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
