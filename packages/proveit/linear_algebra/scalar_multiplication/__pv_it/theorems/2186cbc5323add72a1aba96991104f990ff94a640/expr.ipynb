# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, K, Lambda, V, Variable, a, i, v
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Complex, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(V, Conditional(Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [a_1_to_i, v], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, i)), ScalarMult(VecAdd(a_1_to_i), v)).with_wrapping_at(2), domains = [Complex, V]), domain = Natural), InClass(V, VecSpaces(K)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V \mapsto \left\{\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 42
#    body: 3
# 2. (V)
#    core type: ExprTuple
#    sub-expressions: 42
# 3. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 18
#    operand: 9
# 5. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 42, 10
# 9. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#    core type: Lambda
#    parameter: 55
#    body: 12
# 10. VecSpaces(K)
#     core type: Operation
#     operator: 13
#     operand: 17
# 11. (i)
#     core type: ExprTuple
#     sub-expressions: 55
# 12. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. VecSpaces
#     core type: Literal
#     sub-expressions:
# 14. (K)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 18
#     operand: 21
# 16. i in Natural
#     core type: Operation
#     operator: 46
#     operands: 20
# 17. K
#     core type: Variable
#     sub-expressions:
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 22
# 21. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 23\n    body: 24
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 49, 56
# 24. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 25
#     condition: 26
# 25. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 44
#     operands: 35
# 32. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 51
#     operands: 36
# 33. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 54
#     end_index: 55
# 34. v in V
#     core type: Operation
#     operator: 46
#     operands: 38
# 35. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 39
# 36. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 40, 56
# 37. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 41
# 38. (v, V)
#     core type: ExprTuple
#     sub-expressions: 56, 42
# 39. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 54
#     end_index: 55
# 40. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. a_{_a} in Complex
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. V
#     core type: Variable
#     sub-expressions:
# 43. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 60
#     body: 48
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 48. a_{_a} * v
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 53. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 57
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. v
#     core type: Variable
#     sub-expressions:
# 57. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
