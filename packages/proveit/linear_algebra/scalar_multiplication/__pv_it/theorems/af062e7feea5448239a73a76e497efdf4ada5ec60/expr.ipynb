# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, V, Variable, a, n, v
from proveit.core_expr_types import a_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [v], instance_expr = Equals(ScalarMult(VecAdd(a_1_to_n), v), VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in K}~\left[\forall_{v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} +  a_{2} +  \ldots +  a_{n}\right) \cdot v\right) =  \\ \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{n} \cdot v\right)\right) \end{array} \end{array}\right)\right]\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]]
#    core type: Operation
#    operator: 21
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 40, 7
# 6. n -> {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#    core type: Lambda
#    parameter: 53
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 41
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 53
# 9. {forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))] if n in Natural.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 41
# 12. forall_{a_{1}, a_{2}, ..., a_{n} in K} [forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))]
#     core type: Operation
#     operator: 21
#     operand: 16
# 13. n in Natural
#     core type: Operation
#     operator: 36
#     operands: 15
# 14. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 53, 17
# 16. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Lambda
#     parameters: 47\n    body: 18
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. {forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))) if (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K).
#     core type: Conditional
#     value: 19
#     condition: 20
# 19. forall_{v in V} (((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)))
#     core type: Operation
#     operator: 21
#     operand: 25
# 20. (a_{1} in K) and  (a_{2} in K) and  ... and  (a_{n} in K)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. (v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in K), (a_{2} in K), ..., (a_{n} in K))
#     core type: ExprTuple
#     sub-expressions: 26
# 25. v -> {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Lambda
#     parameter: 57
#     body: 28
# 26. (a_{1} in K), (a_{2} in K), ..., (a_{n} in K)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 52
#     end_index: 53
# 27. (v)
#     core type: ExprTuple
#     sub-expressions: 57
# 28. {((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)) if v in V.
#     core type: Conditional
#     value: 30
#     condition: 31
# 29. _a -> (a_{_a} in K)
#     core type: Lambda
#     parameter: 60
#     body: 32
# 30. ((a_{1} +  a_{2} +  ... +  a_{n}) * v) =  \\ ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. v in V
#     core type: Operation
#     operator: 36
#     operands: 35
# 32. a_{_a} in K
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. ((a_{1} +  a_{2} +  ... +  a_{n}) * v, (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. (v, V)
#     core type: ExprTuple
#     sub-expressions: 57, 40
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (a_{_a}, K)
#     core type: ExprTuple
#     sub-expressions: 56, 41
# 38. (a_{1} +  a_{2} +  ... +  a_{n}) * v
#     core type: Operation
#     operator: 54
#     operands: 42
# 39. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{n} * v)
#     core type: Operation
#     operator: 46
#     operands: 43
# 40. V
#     core type: Variable
#     sub-expressions:
# 41. K
#     core type: Variable
#     sub-expressions:
# 42. (a_{1} +  a_{2} +  ... +  a_{n}, v)
#     core type: ExprTuple
#     sub-expressions: 44, 57
# 43. ((a_{1} * v), (a_{2} * v), ..., (a_{n} * v))
#     core type: ExprTuple
#     sub-expressions: 45
# 44. a_{1} +  a_{2} +  ... +  a_{n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. (a_{1} * v), (a_{2} * v), ..., (a_{n} * v)
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 52
#     end_index: 53
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 49
# 48. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 60
#     body: 50
# 49. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 50. a_{_a} * v
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 56
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. n
#     core type: Variable
#     sub-expressions:
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 57. v
#     core type: Variable
#     sub-expressions:
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
