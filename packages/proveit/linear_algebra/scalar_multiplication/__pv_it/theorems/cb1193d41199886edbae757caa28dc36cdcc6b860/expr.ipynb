# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, V, Variable, a, i, v
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Complex, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [a_1_to_i, v], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, i)), ScalarMult(VecAdd(a_1_to_i), v)).with_wrapping_at(2), domains = [Complex, V]), domain = Natural), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 15
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 39, 7
# 6. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#    core type: Lambda
#    parameter: 52
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. (i)
#    core type: ExprTuple
#    sub-expressions: 52
# 9. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 15
#     operand: 18
# 13. i in Natural
#     core type: Operation
#     operator: 43
#     operands: 17
# 14. K
#     core type: Variable
#     sub-expressions:
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 52, 19
# 18. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 20\n    body: 21
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 46, 53
# 21. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 41
#     operands: 32
# 29. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 48
#     operands: 33
# 30. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 51
#     end_index: 52
# 31. v in V
#     core type: Operation
#     operator: 43
#     operands: 35
# 32. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 37, 53
# 34. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 38
# 35. (v, V)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 36. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 51
#     end_index: 52
# 37. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. a_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. V
#     core type: Variable
#     sub-expressions:
# 40. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 57
#     body: 45
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 47
# 45. a_{_a} * v
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 47. Complex
#     core type: Literal
#     sub-expressions:
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 50. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. v
#     core type: Variable
#     sub-expressions:
# 54. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
