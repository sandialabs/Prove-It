# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, K, Lambda, V, Variable, a, i, v
from proveit.core_expr_types import a_1_to_i
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(K, Forall(instance_param_or_params = [V], instance_expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [a_1_to_i, v], instance_expr = Equals(VecAdd(ExprRange(sub_expr1, ScalarMult(IndexedVar(a, sub_expr1), v), one, i)), ScalarMult(VecAdd(a_1_to_i), v)).with_wrapping_at(2), domains = [Complex, V]), domain = Natural), domain = VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# K \mapsto \left[\forall_{V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)}~\left[\forall_{i \in \mathbb{N}}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{i} \in \mathbb{C}\right), v \in V}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} \cdot v\right) +  \left(a_{2} \cdot v\right) +  \ldots +  \left(a_{i} \cdot v\right)\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i}\right) \cdot v\right) \end{array} \end{array}\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. K -> [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]]
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]]
#    core type: Operation
#    operator: 20
#    operand: 3
# 2. (V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. V -> {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Lambda
#    parameter: 44
#    body: 5
# 4. (V)
#    core type: ExprTuple
#    sub-expressions: 44
# 5. {forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i in Natural} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))]
#    core type: Operation
#    operator: 20
#    operand: 11
# 7. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in_c
#    core type: Literal
#    sub-expressions:
# 10. (V, VecSpaces(K))
#     core type: ExprTuple
#     sub-expressions: 44, 12
# 11. i -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Lambda
#     parameter: 57
#     body: 14
# 12. VecSpaces(K)
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (i)
#     core type: ExprTuple
#     sub-expressions: 57
# 14. {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)) if i in Natural.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. VecSpaces
#     core type: Literal
#     sub-expressions:
# 16. (K)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V} (((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v))
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. i in Natural
#     core type: Operation
#     operator: 48
#     operands: 22
# 19. K
#     core type: Variable
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 57, 24
# 23. (a_{1}, a_{2}, ..., a_{i}, v) -> {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Lambda
#     parameters: 25\n    body: 26
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. (a_{1}, a_{2}, ..., a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 51, 58
# 26. {((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  v in V.
#     core type: Conditional
#     value: 27
#     condition: 28
# 27. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (v in V)
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v), (a_{1} +  a_{2} +  ... +  a_{i}) * v)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), v in V)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. (a_{1} * v) +  (a_{2} * v) +  ... +  (a_{i} * v)
#     core type: Operation
#     operator: 46
#     operands: 37
# 34. (a_{1} +  a_{2} +  ... +  a_{i}) * v
#     core type: Operation
#     operator: 53
#     operands: 38
# 35. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 56
#     end_index: 57
# 36. v in V
#     core type: Operation
#     operator: 48
#     operands: 40
# 37. ((a_{1} * v), (a_{2} * v), ..., (a_{i} * v))
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (a_{1} +  a_{2} +  ... +  a_{i}, v)
#     core type: ExprTuple
#     sub-expressions: 42, 58
# 39. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 62
#     body: 43
# 40. (v, V)
#     core type: ExprTuple
#     sub-expressions: 58, 44
# 41. (a_{1} * v), (a_{2} * v), ..., (a_{i} * v)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 56
#     end_index: 57
# 42. a_{1} +  a_{2} +  ... +  a_{i}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. a_{_a} in Complex
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. _a -> (a_{_a} * v)
#     core type: Lambda
#     parameter: 62
#     body: 50
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 51
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 59, 52
# 50. a_{_a} * v
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 56
#     end_index: 57
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (a_{_a}, v)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 59
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. v
#     core type: Variable
#     sub-expressions:
# 59. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
