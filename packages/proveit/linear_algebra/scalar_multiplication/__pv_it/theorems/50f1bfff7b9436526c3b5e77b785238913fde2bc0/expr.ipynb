# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra.scalar_multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, K, V, Variable, a, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.linear_algebra import ScalarMult, VecAdd, VecSpaces
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(ScalarMult(a, VecAdd(x_1_to_n)), VecAdd(ExprRange(sub_expr1, ScalarMult(a, IndexedVar(x, sub_expr1)), one, n))).with_wrapping_at(2), domain = V), domain = K), domain = Natural), InClass(V, VecSpaces(K)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{n \in \mathbb{N}}~\left[\forall_{a \in K}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n} \in V}~\left(\begin{array}{c} \begin{array}{l} \left(a \cdot \left(x_{1} +  x_{2} +  \ldots +  x_{n}\right)\right) =  \\ \left(\left(a \cdot x_{1}\right) +  \left(a \cdot x_{2}\right) +  \ldots +  \left(a \cdot x_{n}\right)\right) \end{array} \end{array}\right)\right]\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{VecSpaces}\left(K\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]] if V in_c VecSpaces(K).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]
#    core type: Operation
#    operator: 22
#    operand: 6
# 2. V in_c VecSpaces(K)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n -> {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (V, VecSpaces(K))
#    core type: ExprTuple
#    sub-expressions: 50, 7
# 6. n -> {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.
#    core type: Lambda
#    parameter: 53
#    body: 9
# 7. VecSpaces(K)
#    core type: Operation
#    operator: 10
#    operand: 26
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 53
# 9. {forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))] if n in Natural.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. VecSpaces
#     core type: Literal
#     sub-expressions:
# 11. (K)
#     core type: ExprTuple
#     sub-expressions: 26
# 12. forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]
#     core type: Operation
#     operator: 22
#     operand: 16
# 13. n in Natural
#     core type: Operation
#     operator: 46
#     operands: 15
# 14. (a -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 53, 17
# 16. a -> {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.
#     core type: Lambda
#     parameter: 56
#     body: 19
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. (a)
#     core type: ExprTuple
#     sub-expressions: 56
# 19. {forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))) if a in K.
#     core type: Conditional
#     value: 20
#     condition: 21
# 20. forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. a in K
#     core type: Operation
#     operator: 46
#     operands: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((x_{1}, x_{2}, ..., x_{n}) -> {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (a, K)
#     core type: ExprTuple
#     sub-expressions: 56, 26
# 25. (x_{1}, x_{2}, ..., x_{n}) -> {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Lambda
#     parameters: 44\n    body: 27
# 26. K
#     core type: Variable
#     sub-expressions:
# 27. {(a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})) if (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V).
#     core type: Conditional
#     value: 28
#     condition: 29
# 28. (a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. (x_{1} in V) and  (x_{2} in V) and  ... and  (x_{n} in V)
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (a * (x_{1} +  x_{2} +  ... +  x_{n}), (a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. ((x_{1} in V), (x_{2} in V), ..., (x_{n} in V))
#     core type: ExprTuple
#     sub-expressions: 36
# 34. a * (x_{1} +  x_{2} +  ... +  x_{n})
#     core type: Operation
#     operator: 54
#     operands: 37
# 35. (a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})
#     core type: Operation
#     operator: 43
#     operands: 38
# 36. (x_{1} in V), (x_{2} in V), ..., (x_{n} in V)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 52
#     end_index: 53
# 37. (a, x_{1} +  x_{2} +  ... +  x_{n})
#     core type: ExprTuple
#     sub-expressions: 56, 40
# 38. ((a * x_{1}), (a * x_{2}), ..., (a * x_{n}))
#     core type: ExprTuple
#     sub-expressions: 41
# 39. _a -> (x_{_a} in V)
#     core type: Lambda
#     parameter: 60
#     body: 42
# 40. x_{1} +  x_{2} +  ... +  x_{n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (a * x_{1}), (a * x_{2}), ..., (a * x_{n})
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 52
#     end_index: 53
# 42. x_{_a} in V
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. _a -> (a * x_{_a})
#     core type: Lambda
#     parameter: 60
#     body: 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (x_{_a}, V)
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 48. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 49. a * x_{_a}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. V
#     core type: Variable
#     sub-expressions:
# 51. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 57
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. n
#     core type: Variable
#     sub-expressions:
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (a, x_{_a})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. x_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
