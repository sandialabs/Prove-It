# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">scalar_multiplication</a>.<a class="ProveItLink" href="../../theorems.ipynb#scalar_sum_factorization">scalar_sum_factorization</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving scalar_sum_factorization
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="scalar_sum_factorization">scalar_sum_factorization:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9c9fc57cf102e874f742856327ea135287bd05ba0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a3d8d84e428414a62a1471e46f5d5715c1fc4c200/dependencies.ipynb">dependencies</a>)<br>
