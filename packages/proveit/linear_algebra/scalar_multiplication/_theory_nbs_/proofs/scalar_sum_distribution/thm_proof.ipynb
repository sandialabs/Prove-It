# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">scalar_multiplication</a>.<a class="ProveItLink" href="../../theorems.ipynb#scalar_sum_distribution">scalar_sum_distribution</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving scalar_sum_distribution
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="scalar_sum_distribution">scalar_sum_distribution:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/544f05a635973c22e6f1e77bc7492ef703c7d10b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/667925f4803eddf14fd00df19c2c5cc9fc12a13f0/dependencies.ipynb">dependencies</a>)<br>
