# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">scalar_multiplication</a>.<a class="ProveItLink" href="../../theorems.ipynb#factorization_from_vectors">factorization_from_vectors</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import k
theory = proveit.Theory() # the theorem's theory
from proveit.linear_algebra.scalar_multiplication import distribution_over_vectors

# %%
# %proving factorization_from_vectors
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="factorization_from_vectors">factorization_from_vectors:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/357a51fbfb40b93eed33e9233b37c1c0130753d70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f3624eb7919ba5d761b1661b6f0a8641459dbb3d0/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.linear_algebra.scalar_multiplication.factorization_from_vectors has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{i in Natural} [forall_{k in K,(a_{1} in V), (a_{2} in V), ..., (a_{i} in V)} (((k * a_{1}) +  (k * a_{2}) +  ... +  (k * a_{i})) =  \\ (k * (a_{1} +  a_{2} +  ... +  a_{i})))]]]
# 1	instantiation	2, 3	{_e in_c VecSpaces(_f), _d in Natural, _c in _f,(_b_{1} in _e), (_b_{2} in _e), ..., (_b_{_d} in _e)} |- ((_c * _b_{1}) +  (_c * _b_{2}) +  ... +  (_c * _b_{_d})) = (_c * (_b_{1} +  _b_{2} +  ... +  _b_{_d}))
# 	x : _c * (_b_{1} +  _b_{2} +  ... +  _b_{_d}), y : (_c * _b_{1}) +  (_c * _b_{2}) +  ... +  (_c * _b_{_d})
# 2	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 3	instantiation	4, 5, 6, 7, 8	{_e in_c VecSpaces(_f), _d in Natural, _c in _f,(_b_{1} in _e), (_b_{2} in _e), ..., (_b_{_d} in _e)} |- (_c * (_b_{1} +  _b_{2} +  ... +  _b_{_d})) = ((_c * _b_{1}) +  (_c * _b_{2}) +  ... +  (_c * _b_{_d}))
# 	_f : _f
# 4	conjecture		|- forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{n in Natural} [forall_{a in K} [forall_{x_{1}, x_{2}, ..., x_{n} in V} ((a * (x_{1} +  x_{2} +  ... +  x_{n})) =  \\ ((a * x_{1}) +  (a * x_{2}) +  ... +  (a * x_{n})))]]]]
# 	proveit.linear_algebra.scalar_multiplication.distribution_over_vectors
# 5	assumption		{_e in_c VecSpaces(_f)} |- _e in_c VecSpaces(_f)
# 6	assumption		{_d in Natural} |- _d in Natural
# 7	assumption		{_c in _f} |- _c in _f
# 8	assumption		{(_b_{1} in _e), (_b_{2} in _e), ..., (_b_{_d} in _e)} |- (_b_{1} in _e) and  (_b_{2} in _e) and  ... and  (_b_{_d} in _e)
