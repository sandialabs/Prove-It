# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">scalar_multiplication</a>.<a class="ProveItLink" href="../../theorems.ipynb#factorization_from_vec_sum">factorization_from_vec_sum</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving factorization_from_vec_sum
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="factorization_from_vec_sum">factorization_from_vec_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/dc888333dbbb1cad1c0f57633f8bfd2752494b9e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/83274cefd4459262689fcec6ad09d9182972031c0/dependencies.ipynb">dependencies</a>)<br>
