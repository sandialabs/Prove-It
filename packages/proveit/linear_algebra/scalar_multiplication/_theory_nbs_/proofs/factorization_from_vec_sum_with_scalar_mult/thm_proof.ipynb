# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">scalar_multiplication</a>.<a class="ProveItLink" href="../../theorems.ipynb#factorization_from_vec_sum_with_scalar_mult">factorization_from_vec_sum_with_scalar_mult</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving factorization_from_vec_sum_with_scalar_mult
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="factorization_from_vec_sum_with_scalar_mult">factorization_from_vec_sum_with_scalar_mult:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8e070bde113496220e95170d54c0a3431182faa20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6a1a68367803849bae10eab616e394af4841e04f0/dependencies.ipynb">dependencies</a>)<br>
