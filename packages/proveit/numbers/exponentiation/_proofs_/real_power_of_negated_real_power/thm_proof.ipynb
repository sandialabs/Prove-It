# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">exponentiation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#real_power_of_negated_real_power">real_power_of_negated_real_power</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving real_power_of_negated_real_power
