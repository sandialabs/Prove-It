# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">exponentiation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#int_exp_of_neg_exp">int_exp_of_neg_exp</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving int_exp_of_neg_exp
