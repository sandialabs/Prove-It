# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sqrt_real_closure">sqrt_real_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import sqrt_real_closure

# %%
# check that the built expression is the same as the stored expression
assert sqrt_real_closure.expr == stored_expr
assert sqrt_real_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: sqrt_real_closure matches stored_expr")
# Out:
# Passed sanity check: sqrt_real_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sqrt_real_closure.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}~|~a \geq 0}~\left(\sqrt{a} \in \mathbb{R}\right)

# %%
# display the expression information
sqrt_real_closure.expr_info()
# Out:
# 0. forall_{a in Real | a >= 0} (sqrt(a) in Real)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {sqrt(a) in Real if a in Real ,  a >= 0.
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. {sqrt(a) in Real if a in Real ,  a >= 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. sqrt(a) in Real
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (a in Real) and (a >= 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (sqrt(a), Real)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. sqrt(a)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Real
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. a >= 0
#     core type: Operation
#     operator: 16
#     operands: 17
# ...
