# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, RealPos, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Complex), InSet(b, RealPos), InSet(c, RealPos), NotEquals(a, zero))
# Out:
# expr: (a in Complex) and (b in RealPos) and (c in RealPos) and (a != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(b \in \mathbb{R}^+\right) \land \left(c \in \mathbb{R}^+\right) \land \left(a \neq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex) and (b in RealPos) and (c in RealPos) and (a != 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complex, b in RealPos, c in RealPos, a != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Complex
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. b in RealPos
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. c in RealPos
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. a != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 17, 13
# 8. (b, RealPos)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (c, RealPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. RealPos
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
