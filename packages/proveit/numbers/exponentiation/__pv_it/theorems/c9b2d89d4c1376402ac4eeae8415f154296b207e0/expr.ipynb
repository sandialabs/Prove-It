# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos, RealPos
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_m, b], Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), domains = [RealPos, Complex]), InSet(m, NaturalPos))
# Out:
# expr: {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1} \in \mathbb{R}^+, \ldots, a_{m} \in \mathbb{R}^+, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 37, 8
# 6. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 32, 42
# 7. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{m} in RealPos ,  b in Complex.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{m} in RealPos) and (b in Complex)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#     core type: Operation
#     operator: 38
#     operands: 19
# 16. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#     core type: Operation
#     operator: 27
#     operands: 20
# 17. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{m} in RealPos)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 37
# 18. b in Complex
#     core type: Operation
#     operator: 30
#     operands: 22
# 19. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 23, 42
# 20. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 43
#     body: 25
# 22. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 26
# 23. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 36
#     end_index: 37
# 25. a_{_a} in RealPos
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 45
#     body: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 40, 34
# 32. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 33. (a_{i})^{b}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. RealPos
#     core type: Literal
#     sub-expressions:
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 40
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. a_{_a}
#     core type: IndexedVar
# variable: 44
# index: 43
# 41. a_{i}
#     core type: IndexedVar
# variable: 44
# index: 45
# 42. b
#     core type: Variable
#     sub-expressions:
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. i
#     core type: Variable
#     sub-expressions:
