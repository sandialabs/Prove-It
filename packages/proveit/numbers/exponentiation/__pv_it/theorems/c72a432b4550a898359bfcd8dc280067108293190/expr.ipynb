# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], Equals(Mult(Exp(a, b), a), Exp(a, Add(b, one))), domains = [Complex, Complex], condition = NotEquals(a, zero))
# Out:
# expr: forall_{a, b in Complex | a != 0} ((a^{b} * a) = a^{b + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{C}~|~a \neq 0}~\left(\left(a^{b} \cdot a\right) = a^{b + 1}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Complex | a != 0} ((a^{b} * a) = a^{b + 1})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a^{b} * a) = a^{b + 1} if a in Complex ,  b in Complex ,  a != 0.
#    core type: Lambda
#    parameters: 28\n   body: 3
# 3. {(a^{b} * a) = a^{b + 1} if a in Complex ,  b in Complex ,  a != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a^{b} * a) = a^{b + 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Complex) and (b in Complex) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a^{b} * a, a^{b + 1})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, b in Complex, a != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a^{b} * a
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. a^{b + 1}
#     core type: Operation
#     operator: 27
#     operands: 17
# 12. a in Complex
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. b in Complex
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. a != 0
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a^{b}, a)
#     core type: ExprTuple
#     sub-expressions: 23, 31
# 17. (a, b + 1)
#     core type: ExprTuple
#     sub-expressions: 31, 24
# 18. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 31, 25
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 32, 25
# 21. !=
#     core type: Literal
#     sub-expressions:
# 22. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 31, 26
# 23. a^{b}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. b + 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. Complex
#     core type: Literal
#     sub-expressions:
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. 1
#     core type: Literal
#     sub-expressions:
