# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, c
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Neg, Real, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c], Conditional(Equals(frac(Exp(a, b), Exp(a, c)), Exp(a, Add(b, Neg(c)))), And(InSet(a, Complex), InSet(b, Real), InSet(c, Real), NotEquals(a, zero))))
# Out:
# expr: (a, b, c) -> {(a^{b} / a^{c}) = a^{b - c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\frac{a^{b}}{a^{c}} = a^{b - c} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c) -> {(a^{b} / a^{c}) = a^{b - c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 35, 36, 39
# 2. {(a^{b} / a^{c}) = a^{b - c} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a^{b} / a^{c}) = a^{b - c}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (b in Real) and (c in Real) and (a != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a^{b} / a^{c}, a^{b - c})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, b in Real, c in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. a^{b} / a^{c}
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a^{b - c}
# ...
