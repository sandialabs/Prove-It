# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#negated_real_power_of_real_power">negated_real_power_of_real_power</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import negated_real_power_of_real_power

# %%
# check that the built expression is the same as the stored expression
assert negated_real_power_of_real_power.expr == stored_expr
assert negated_real_power_of_real_power.expr._style_id == stored_expr._style_id
print("Passed sanity check: negated_real_power_of_real_power matches stored_expr")
# Out:
# Passed sanity check: negated_real_power_of_real_power matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negated_real_power_of_real_power.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{R}, c \in \mathbb{R}~|~a \neq 0}~\left((a^{b})^{-c} = a^{-\left(b \cdot c\right)}\right)

# %%
# display the expression information
negated_real_power_of_real_power.expr_info()
# Out:
# 0. forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{-c} = a^{-(b * c)})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(a^{b})^{-c} = a^{-(b * c)} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 35, 38, 39
# 4. {(a^{b})^{-c} = a^{-(b * c)} if a in Complex ,  b in Real ,  c in Real ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{b})^{-c} = a^{-(b * c)}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (b in Real) and (c in Real) and (a != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((a^{b})^{-c}, a^{-(b * c)})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# ...
