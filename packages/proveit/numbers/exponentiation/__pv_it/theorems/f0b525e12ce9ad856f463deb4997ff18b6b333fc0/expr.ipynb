# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, m, n
from proveit.core_expr_types import a_1_to_m
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos
from proveit.numbers.exponentiation import prod_ai_raise_n__1_to_m

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Conditional(Forall([a_1_to_m], Equals(Exp(Mult(a_1_to_m), n), prod_ai_raise_n__1_to_m), domains = [Complex]), And(InSet(m, NaturalPos), InSet(n, NaturalPos))))
# Out:
# expr: (m, n) -> {forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{m} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{n} = \left(\left(a_{1}\right)^{n} \cdot \ldots \cdot \left(a_{m}\right)^{n}\right)\right) \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m, n) -> {forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 39, 44
# 2. {forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{m}) -> {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Lambda
#    parameters: 30\n   body: 8
# 7. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. m in NaturalPos
#    core type: Operation
#    operator: 32
#    operands: 13
# 10. n in NaturalPos
#     core type: Operation
#     operator: 32
#     operands: 14
# 11. (a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 39, 19
# 14. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 44, 19
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1} * ..a_{_a}.. * a_{m})^{n}, (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex)
#     core type: ExprTuple
#     sub-expressions: 22
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} * ..a_{_a}.. * a_{m})^{n}
#     core type: Operation
#     operator: 40
#     operands: 23
# 21. (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}
#     core type: Operation
#     operator: 29
#     operands: 24
# 22. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 38
#     end_index: 39
# 23. (a_{1} * ..a_{_a}.. * a_{m}, n)
#     core type: ExprTuple
#     sub-expressions: 26, 44
# 24. ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 25. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 45
#     body: 28
# 26. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 38
#     end_index: 39
# 28. a_{_a} in Complex
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 34
# 31. i -> (a_{i})^{n}
#     core type: Lambda
#     parameter: 47
#     body: 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 34. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 35. (a_{i})^{n}
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. _a -> a_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (a_{i}, n)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. a_{_a}
#     core type: IndexedVar
# variable: 46
# index: 45
# 43. a_{i}
#     core type: IndexedVar
# variable: 46
# index: 47
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. i
#     core type: Variable
#     sub-expressions:
