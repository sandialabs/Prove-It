# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_real_closure_base_pos">exp_real_closure_base_pos</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_real_closure_base_pos

# %%
# check that the built expression is the same as the stored expression
assert exp_real_closure_base_pos.expr == stored_expr
assert exp_real_closure_base_pos.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_real_closure_base_pos matches stored_expr")
# Out:
# Passed sanity check: exp_real_closure_base_pos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp_real_closure_base_pos.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{R}~|~a > 0}~\left(a^{b} \in \mathbb{R}\right)

# %%
# display the expression information
exp_real_closure_base_pos.expr_info()
# Out:
# 0. forall_{a, b in Real | a > 0} (a^{b} in Real)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {a^{b} in Real if a in Real ,  b in Real ,  a > 0.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {a^{b} in Real if a in Real ,  b in Real ,  a > 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a^{b} in Real
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (a in Real) and (b in Real) and (a > 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a^{b}, Real)
#    core type: ExprTuple
#    sub-expressions: 9, 21
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, b in Real, a > 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. a^{b}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a in Real
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. b in Real
# ...
