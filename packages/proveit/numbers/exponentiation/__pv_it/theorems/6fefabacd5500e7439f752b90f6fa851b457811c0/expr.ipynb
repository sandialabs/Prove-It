# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, m
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, Real, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = And(InSet(a, Complex), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Real), one, m), NotEquals(a, zero))
# Out:
# expr: (a in Complex) and (b_{1} in Real) and ..(b_{_a} in Real).. and (b_{m} in Real) and (a != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(b_{1} \in \mathbb{R}\right) \land \ldots \land \left(b_{m} \in \mathbb{R}\right) \land \left(a \neq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex) and (b_{1} in Real) and ..(b_{_a} in Real).. and (b_{m} in Real) and (a != 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a in Complex
#    core type: Operation
#    operator: 16
#    operands: 6
# 4. (b_{1} in Real), ..(b_{_a} in Real).., (b_{m} in Real)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 5. a != 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 7. _a -> (b_{_a} in Real)
#    core type: Lambda
#    parameter: 21
#    body: 13
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. b_{_a} in Real
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. b_{_a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 19. Real
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. _a
#     core type: Variable
#     sub-expressions:
