# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Exp, Mult, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([a, m, n], Equals(Mult(Exp(a, m), Exp(a, n)), Exp(a, Add(m, n))), domains = [Complex, NaturalPos, NaturalPos])
# Out:
# expr: forall_{a in Complex, m in NaturalPos, n in NaturalPos} ((a^{m} * a^{n}) = a^{m + n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}, m \in \mathbb{N}^+, n \in \mathbb{N}^+}~\left(\left(a^{m} \cdot a^{n}\right) = a^{m + n}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Complex, m in NaturalPos, n in NaturalPos} ((a^{m} * a^{n}) = a^{m + n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, m, n) -> {(a^{m} * a^{n}) = a^{m + n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, m, n)
#    core type: ExprTuple
#    sub-expressions: 33, 34, 35
# 4. {(a^{m} * a^{n}) = a^{m + n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{m} * a^{n}) = a^{m + n}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a^{m} * a^{n}, a^{m + n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complex, m in NaturalPos, n in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a^{m} * a^{n}
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. a^{m + n}
#     core type: Operation
#     operator: 29
#     operands: 18
# 13. a in Complex
#     core type: Operation
#     operator: 21
#     operands: 19
# 14. m in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. n in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (a^{m}, a^{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. (a, m + n)
#     core type: ExprTuple
#     sub-expressions: 33, 25
# 19. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 20. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 34, 27
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 35, 27
# 23. a^{m}
#     core type: Operation
#     operator: 29
#     operands: 28
# 24. a^{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. m + n
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. NaturalPos
#     core type: Literal
#     sub-expressions:
# 28. (a, m)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (a, n)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (m, n)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
