# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#quotient_of_complex_powers">quotient_of_complex_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import quotient_of_complex_powers

# %%
# check that the built expression is the same as the stored expression
assert quotient_of_complex_powers.expr == stored_expr
assert quotient_of_complex_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: quotient_of_complex_powers matches stored_expr")
# Out:
# Passed sanity check: quotient_of_complex_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(quotient_of_complex_powers.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^+, b \in \mathbb{C}, c \in \mathbb{C}}~\left(\frac{a^{b}}{a^{c}} = a^{b - c}\right)

# %%
# display the expression information
quotient_of_complex_powers.expr_info()
# Out:
# 0. forall_{a in RealPos, b in Complex, c in Complex} ((a^{b} / a^{c}) = a^{b - c})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(a^{b} / a^{c}) = a^{b - c} if a in RealPos ,  b in Complex ,  c in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 33, 34, 37
# 4. {(a^{b} / a^{c}) = a^{b - c} if a in RealPos ,  b in Complex ,  c in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{b} / a^{c}) = a^{b - c}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in RealPos) and (b in Complex) and (c in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a^{b} / a^{c}, a^{b - c})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in RealPos, b in Complex, c in Complex)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a^{b} / a^{c}
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. a^{b - c}
#     core type: Operation
#     operator: 29
#     operands: 18
# 13. a in RealPos
#     core type: Operation
#     operator: 21
#     operands: 19
# 14. b in Complex
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. c in Complex
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (a^{b}, a^{c})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. (a, b - c)
#     core type: ExprTuple
#     sub-expressions: 33, 25
# 19. (a, RealPos)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 20. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 34, 27
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 27
# 23. a^{b}
#     core type: Operation
#     operator: 29
#     operands: 28
# 24. a^{c}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. b - c
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. RealPos
#     core type: Literal
#     sub-expressions:
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (a, c)
#     core type: ExprTuple
#     sub-expressions: 33, 37
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (b, -c)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. b
#     core type: Variable
#     sub-expressions:
# 35. -c
#     core type: Operation
#     operator: 36
#     operand: 37
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. c
#     core type: Variable
#     sub-expressions:
