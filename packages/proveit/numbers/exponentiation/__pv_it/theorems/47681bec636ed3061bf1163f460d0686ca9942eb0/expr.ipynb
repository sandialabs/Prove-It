# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, m
from proveit.core_expr_types import k_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Complex, Exp, NaturalPos
from proveit.numbers.exponentiation import prod_a_raise_ki__1_to_m

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a, k_1_to_m], Equals(prod_a_raise_ki__1_to_m, Exp(a, Add(k_1_to_m))), domains = [Complex, NaturalPos]), InSet(m, NaturalPos))
# Out:
# expr: {forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a \in \mathbb{C}, k_{1} \in \mathbb{N}^+, \ldots, k_{m} \in \mathbb{N}^+}~\left(\left(a^{k_{1}} \cdot \ldots \cdot a^{k_{m}}\right) = a^{k_{1} + \ldots + k_{m}}\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos} ((a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a, k_{1}, ..k_{_a}.., k_{m}) -> {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 39, 34
# 6. (a, k_{1}, ..k_{_a}.., k_{m})
#    core type: ExprTuple
#    sub-expressions: 40, 33
# 7. {(a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}} if a in Complex ,  k_{1} in NaturalPos ,  ..k_{_a} in NaturalPos.. ,  k_{m} in NaturalPos.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}) = a^{k_{1} + ..k_{_a}.. + k_{m}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a in Complex) and (k_{1} in NaturalPos) and ..(k_{_a} in NaturalPos).. and (k_{m} in NaturalPos)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}, a^{k_{1} + ..k_{_a}.. + k_{m}})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a in Complex, k_{1} in NaturalPos, ..k_{_a} in NaturalPos.., k_{m} in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. a^{k_{1}} * ..a^{k_{i}}.. * a^{k_{m}}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. a^{k_{1} + ..k_{_a}.. + k_{m}}
#     core type: Operation
#     operator: 35
#     operands: 20
# 16. a in Complex
#     core type: Operation
#     operator: 30
#     operands: 21
# 17. (k_{1} in NaturalPos), ..(k_{_a} in NaturalPos).., (k_{m} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 38
#     end_index: 39
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (a, k_{1} + ..k_{_a}.. + k_{m})
#     core type: ExprTuple
#     sub-expressions: 40, 24
# 21. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 25
# 22. _a -> (k_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 45
#     body: 26
# 23. a^{k_{1}}, ..a^{k_{i}}.., a^{k_{m}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 38
#     end_index: 39
# 24. k_{1} + ..k_{_a}.. + k_{m}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. Complex
#     core type: Literal
#     sub-expressions:
# 26. k_{_a} in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. i -> a^{k_{i}}
#     core type: Lambda
#     parameter: 43
#     body: 32
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (k_{1}, ..k_{_a}.., k_{m})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (k_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 42, 34
# 32. a^{k_{i}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. k_{1}, ..k_{_a}.., k_{m}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 34. NaturalPos
#     core type: Literal
#     sub-expressions:
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (a, k_{i})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. _a -> k_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. k_{i}
#     core type: IndexedVar
# variable: 44
# index: 43
# 42. k_{_a}
#     core type: IndexedVar
# variable: 44
# index: 45
# 43. i
#     core type: Variable
#     sub-expressions:
# 44. k
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
