# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos, RealPos
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([a_1_to_m, b], Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), domains = [Complex, RealPos]), InSet(m, NaturalPos)))
# Out:
# expr: m -> {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{a_{1} \in \mathbb{C}, \ldots, a_{m} \in \mathbb{C}, b \in \mathbb{R}^+}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 38
#    body: 1
# 1. {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. m in NaturalPos
#    core type: Operation
#    operator: 31
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 38, 9
# 7. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 33, 43
# 8. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex) and (b in RealPos)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#     core type: Operation
#     operator: 39
#     operands: 20
# 17. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#     core type: Operation
#     operator: 28
#     operands: 21
# 18. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 37
#     end_index: 38
# 19. b in RealPos
#     core type: Operation
#     operator: 31
#     operands: 23
# 20. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 24, 43
# 21. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 44
#     body: 26
# 23. (b, RealPos)
#     core type: ExprTuple
#     sub-expressions: 43, 27
# 24. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 37
#     end_index: 38
# 26. a_{_a} in Complex
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. RealPos
#     core type: Literal
#     sub-expressions:
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 46
#     body: 34
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 35
# 33. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 34. (a_{i})^{b}
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. Complex
#     core type: Literal
#     sub-expressions:
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 41
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. Exp
#     core type: Literal
#     sub-expressions:
# 40. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. a_{_a}
#     core type: IndexedVar
# variable: 45
# index: 44
# 42. a_{i}
#     core type: IndexedVar
# variable: 45
# index: 46
# 43. b
#     core type: Variable
#     sub-expressions:
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. i
#     core type: Variable
#     sub-expressions:
