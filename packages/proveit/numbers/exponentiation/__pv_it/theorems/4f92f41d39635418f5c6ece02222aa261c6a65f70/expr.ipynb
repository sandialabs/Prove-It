# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.logic import InSet, NotEquals, Or
from proveit.numbers import Complex, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Complex), InSet(b, Complex), Or(NotEquals(a, zero), NotEquals(b, zero)))
# Out:
# expr: (a in Complex, b in Complex, (a != 0) or (b != 0))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}, b \in \mathbb{C}, \left(a \neq 0\right) \lor \left(b \neq 0\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex, b in Complex, (a != 0) or (b != 0))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. a in Complex
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. b in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. (a != 0) or (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 15, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (a != 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Complex
#    core type: Literal
#    sub-expressions:
# 10. a != 0
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. b != 0
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. !=
#     core type: Literal
#     sub-expressions:
# 14. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
