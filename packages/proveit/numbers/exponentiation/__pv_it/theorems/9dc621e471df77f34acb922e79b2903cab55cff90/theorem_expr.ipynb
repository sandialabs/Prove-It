# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#products_of_complex_powers">products_of_complex_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import products_of_complex_powers

# %%
# check that the built expression is the same as the stored expression
assert products_of_complex_powers.expr == stored_expr
assert products_of_complex_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: products_of_complex_powers matches stored_expr")
# Out:
# Passed sanity check: products_of_complex_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(products_of_complex_powers.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{R}^+, b_{1} \in \mathbb{C}, \ldots, b_{m} \in \mathbb{C}}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right)\right]

# %%
# display the expression information
products_of_complex_powers.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in RealPos ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{m} in Complex.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 42, 10
# 8. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 43, 36
# 9. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in RealPos ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{m} in Complex.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a in RealPos) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{m} in Complex)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 38
#     operands: 23
# 19. a in RealPos
#     core type: Operation
#     operator: 33
#     operands: 24
# 20. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 41
#     end_index: 42
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 43, 27
# 24. (a, RealPos)
#     core type: ExprTuple
#     sub-expressions: 43, 28
# 25. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 48
#     body: 29
# 26. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 41
#     end_index: 42
# 27. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. RealPos
#     core type: Literal
#     sub-expressions:
# 29. b_{_a} in Complex
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 46
#     body: 35
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 37
# 35. a^{b_{i}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 37. Complex
#     core type: Literal
#     sub-expressions:
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. _a -> b_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 45
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. m
#     core type: Variable
#     sub-expressions:
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. b_{i}
#     core type: IndexedVar
# variable: 47
# index: 46
# 45. b_{_a}
#     core type: IndexedVar
# variable: 47
# index: 48
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. b
#     core type: Variable
#     sub-expressions:
# 48. _a
#     core type: Variable
#     sub-expressions:
