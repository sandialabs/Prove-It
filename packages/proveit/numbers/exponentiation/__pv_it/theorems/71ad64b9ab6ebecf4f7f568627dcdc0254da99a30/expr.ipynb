# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import And, InSet
from proveit.numbers import Less, LessEq, LesserSequence, Real, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Real), InSet(x, Real), InSet(y, Real), LesserSequence([Less._operator_, LessEq._operator_], [zero, x, y]), Less(a, zero))
# Out:
# expr: (a in Real) and (x in Real) and (y in Real) and (0 < x <= y) and (a < 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(x \in \mathbb{R}\right) \land \left(y \in \mathbb{R}\right) \land \left(0 < x \leq y\right) \land \left(a < 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real) and (x in Real) and (y in Real) and (0 < x <= y) and (a < 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Real, x in Real, y in Real, 0 < x <= y, a < 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. a in Real
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. x in Real
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. y in Real
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. 0 < x <= y
#    core type: Operation
#    operators: 12
#    operands: 13
# 7. a < 0
#    core type: Operation
#    operator: 16
#    operands: 14
# 8. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 20, 15
# 9. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 18, 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y, Real)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 12. (<, <=)
# ...
