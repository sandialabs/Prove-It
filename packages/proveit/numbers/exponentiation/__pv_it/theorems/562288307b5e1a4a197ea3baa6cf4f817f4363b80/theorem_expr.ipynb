# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#posnat_power_of_products">posnat_power_of_products</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import posnat_power_of_products

# %%
# check that the built expression is the same as the stored expression
assert posnat_power_of_products.expr == stored_expr
assert posnat_power_of_products.expr._style_id == stored_expr._style_id
print("Passed sanity check: posnat_power_of_products matches stored_expr")
# Out:
# Passed sanity check: posnat_power_of_products matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}^+}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{m} \in \mathbb{C}}~\left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{m}\right)^{n} = \left(\left(a_{1}\right)^{n} \cdot  \left(a_{2}\right)^{n} \cdot  \ldots \cdot  \left(a_{m}\right)^{n}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{m} in Complex} ((a_{1} *  a_{2} *  ... *  a_{m})^{n} = ((a_{1})^{n} *  (a_{2})^{n} *  ... *  (a_{m})^{n}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{a_{1}, a_{2}, ..., a_{m} in Complex} ((a_{1} *  a_{2} *  ... *  a_{m})^{n} = ((a_{1})^{n} *  (a_{2})^{n} *  ... *  (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{a_{1}, a_{2}, ..., a_{m} in Complex} ((a_{1} *  a_{2} *  ... *  a_{m})^{n} = ((a_{1})^{n} *  (a_{2})^{n} *  ... *  (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 42, 46
# 4. {forall_{a_{1}, a_{2}, ..., a_{m} in Complex} ((a_{1} *  a_{2} *  ... *  a_{m})^{n} = ((a_{1})^{n} *  (a_{2})^{n} *  ... *  (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
# ...
