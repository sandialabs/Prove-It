# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#complex_x_to_first_power_is_x">complex_x_to_first_power_is_x</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/complex_x_to_first_power_is_x/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.exponentiation import complex_x_to_first_power_is_x

# %%
# %dependencies complex_x_to_first_power_is_x
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon complex_x_to_first_power_is_x</h3>
