# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#products_of_posnat_powers">products_of_posnat_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import products_of_posnat_powers

# %%
# check that the built expression is the same as the stored expression
assert products_of_posnat_powers.expr == stored_expr
assert products_of_posnat_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: products_of_posnat_powers matches stored_expr")
# Out:
# Passed sanity check: products_of_posnat_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{C},\left(k_{1} \in \mathbb{N}^+\right), \left(k_{2} \in \mathbb{N}^+\right), \ldots, \left(k_{m} \in \mathbb{N}^+\right)}~\left(\left(a^{k_{1}} \cdot  a^{k_{2}} \cdot  \ldots \cdot  a^{k_{m}}\right) = a^{k_{1} +  k_{2} +  \ldots +  k_{m}}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)} ((a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)} ((a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}}) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)} ((a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}}) if m in NaturalPos.
#    core type: Lambda
#    parameter: 44
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 44
# 4. {forall_{a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)} ((a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)} ((a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. m in NaturalPos
#    core type: Operation
#    operator: 35
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a, k_{1}, k_{2}, ..., k_{m}) -> {(a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}} if a in Complex, (k_{1} in NaturalPos) ,  (k_{2} in NaturalPos) ,  ... ,  (k_{m} in NaturalPos).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 44, 39
# 10. (a, k_{1}, k_{2}, ..., k_{m}) -> {(a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}} if a in Complex, (k_{1} in NaturalPos) ,  (k_{2} in NaturalPos) ,  ... ,  (k_{m} in NaturalPos).
#     core type: Lambda
#     parameters: 11\n    body: 12
# 11. (a,k_{1}, k_{2}, ..., k_{m})
#     core type: ExprTuple
#     sub-expressions: 45, 38
# 12. {(a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}} if a in Complex, (k_{1} in NaturalPos) ,  (k_{2} in NaturalPos) ,  ... ,  (k_{m} in NaturalPos).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. (a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}) = a^{k_{1} +  k_{2} +  ... +  k_{m}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a in Complex)and (k_{1} in NaturalPos) and  (k_{2} in NaturalPos) and  ... and  (k_{m} in NaturalPos)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}, a^{k_{1} +  k_{2} +  ... +  k_{m}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a in Complex,(k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a^{k_{1}} *  a^{k_{2}} *  ... *  a^{k_{m}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. a^{k_{1} +  k_{2} +  ... +  k_{m}}
#     core type: Operation
#     operator: 40
#     operands: 25
# 21. a in Complex
#     core type: Operation
#     operator: 35
#     operands: 26
# 22. (k_{1} in NaturalPos), (k_{2} in NaturalPos), ..., (k_{m} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 43
#     end_index: 44
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (a^{k_{1}}, a^{k_{2}}, ..., a^{k_{m}})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (a, k_{1} +  k_{2} +  ... +  k_{m})
#     core type: ExprTuple
#     sub-expressions: 45, 29
# 26. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 30
# 27. _a -> (k_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 49
#     body: 31
# 28. a^{k_{1}}, a^{k_{2}}, ..., a^{k_{m}}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 43
#     end_index: 44
# 29. k_{1} +  k_{2} +  ... +  k_{m}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. k_{_a} in NaturalPos
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. _a -> a^{k_{_a}}
#     core type: Lambda
#     parameter: 49
#     body: 37
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (k_{1}, k_{2}, ..., k_{m})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (k_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 46, 39
# 37. a^{k_{_a}}
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. k_{1}, k_{2}, ..., k_{m}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 39. NaturalPos
#     core type: Literal
#     sub-expressions:
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (a, k_{_a})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. _a -> k_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 46
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. k_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 47. k
#     core type: Variable
#     sub-expressions:
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 49. _a
#     core type: Variable
#     sub-expressions:
