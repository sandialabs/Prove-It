# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, Exp, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(Exp(one, x), one), InSet(x, Complex)))
# Out:
# expr: x -> {1^{x} = 1 if x in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{1^{x} = 1 \textrm{ if } x \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {1^{x} = 1 if x in Complex.
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. {1^{x} = 1 if x in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. 1^{x} = 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Complex
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (1^{x}, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 8. 1^{x}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Complex
#    core type: Literal
#    sub-expressions:
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (1, x)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
