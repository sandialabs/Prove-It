# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sqrt_of_prod">sqrt_of_prod</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import sqrt_of_prod

# %%
# check that the built expression is the same as the stored expression
assert sqrt_of_prod.expr == stored_expr
assert sqrt_of_prod.expr._style_id == stored_expr._style_id
print("Passed sanity check: sqrt_of_prod matches stored_expr")
# Out:
# Passed sanity check: sqrt_of_prod matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\left(\sqrt{\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{n}\right)} = \left(\sqrt{\left(a_{1}\right)} \cdot  \sqrt{\left(a_{2}\right)} \cdot  \ldots \cdot  \sqrt{\left(a_{n}\right)}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} (sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} (sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n})))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} (sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n})))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 37
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 37
# 4. {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} (sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n})))) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{n} in Complex} (sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 31
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{n}) -> {sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 37, 11
# 10. (a_{1}, a_{2}, ..., a_{n}) -> {sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 29\n    body: 12
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. {sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. sqrt((a_{1} *  a_{2} *  ... *  a_{n})) = (sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n})))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (sqrt((a_{1} *  a_{2} *  ... *  a_{n})), sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n})))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 21
# 19. sqrt((a_{1} *  a_{2} *  ... *  a_{n}))
#     core type: Operation
#     operator: 38
#     operands: 22
# 20. sqrt((a_{1})) *  sqrt((a_{2})) *  ... *  sqrt((a_{n}))
#     core type: Operation
#     operator: 28
#     operands: 23
# 21. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 47
#     end_index: 37
# 22. (a_{1} *  a_{2} *  ... *  a_{n}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 25, 41
# 23. (sqrt((a_{1})), sqrt((a_{2})), ..., sqrt((a_{n})))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 27
# 25. a_{1} *  a_{2} *  ... *  a_{n}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. sqrt((a_{1})), sqrt((a_{2})), ..., sqrt((a_{n}))
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 47
#     end_index: 37
# 27. a_{_a} in Complex
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. _a -> sqrt((a_{_a}))
#     core type: Lambda
#     parameter: 46
#     body: 34
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 35
# 33. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 47
#     end_index: 37
# 34. sqrt((a_{_a}))
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. Complex
#     core type: Literal
#     sub-expressions:
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (a_{_a}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. a_{_a}
#     core type: IndexedVar
# variable: 42
# index: 46
# 41. 1 / 2
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. a
#     core type: Variable
#     sub-expressions:
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. /
#     core type: Literal
#     sub-expressions:
# 45. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. _a
#     core type: Variable
#     sub-expressions:
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. 2
#     core type: Literal
#     sub-expressions:
