# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import Forall
from proveit.numbers import Exp, Less, LessEq, LesserSequence, Real, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, x, y], LessEq(Exp(y, a), Exp(x, a)), domains = [Real, Real, Real], conditions = [LesserSequence([Less._operator_, LessEq._operator_], [zero, x, y]), LessEq(a, zero)])
# Out:
# expr: forall_{a, x, y in Real | 0 < x <= y, a <= 0} (y^{a} <= x^{a})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, x, y \in \mathbb{R}~|~0 < x \leq y, a \leq 0}~\left(y^{a} \leq x^{a}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, x, y in Real | 0 < x <= y, a <= 0} (y^{a} <= x^{a})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, x, y) -> {y^{a} <= x^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x <= y ,  a <= 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 32, 30, 31
# 4. {y^{a} <= x^{a} if a in Real ,  x in Real ,  y in Real ,  0 < x <= y ,  a <= 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. y^{a} <= x^{a}
#    core type: Operation
#    operator: 29
#    operands: 7
# 6. (a in Real) and (x in Real) and (y in Real) and (0 < x <= y) and (a <= 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (y^{a}, x^{a})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, x in Real, y in Real, 0 < x <= y, a <= 0)
#    core type: ExprTuple
# ...
