# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, m
from proveit.logic import InSet
from proveit.numbers import Complex, RealPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, m), InSet(b, RealPos))
# Out:
# expr: (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{m} \in \mathbb{C}, b \in \mathbb{R}^+\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 4
#    end_index: 5
# 2. b in RealPos
#    core type: Operation
#    operator: 10
#    operands: 6
# 3. _a -> (a_{_a} in Complex)
#    core type: Lambda
#    parameter: 15
#    body: 7
# 4. 1
#    core type: Literal
#    sub-expressions:
# 5. m
#    core type: Variable
#    sub-expressions:
# 6. (b, RealPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a_{_a} in Complex
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. RealPos
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. a_{_a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
