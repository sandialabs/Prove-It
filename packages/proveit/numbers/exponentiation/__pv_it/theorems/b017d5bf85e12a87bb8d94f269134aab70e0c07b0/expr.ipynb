# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, NaturalPos, Real, zero
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [a, b_1_to_m], instance_expr = Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), domains = [Complex, Real], condition = NotEquals(a, zero)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{C},\left(b_{1} \in \mathbb{R}\right), \left(b_{2} \in \mathbb{R}\right), \ldots, \left(b_{m} \in \mathbb{R}\right)~|~a \neq 0}~\left(\left(a^{b_{1}} \cdot  a^{b_{2}} \cdot  \ldots \cdot  a^{b_{m}}\right) = a^{b_{1} +  b_{2} +  \ldots +  b_{m}}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real) | a != 0} ((a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real) | a != 0} ((a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}}) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real) | a != 0} ((a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}}) if m in NaturalPos.
#    core type: Lambda
#    parameter: 49
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 49
# 4. {forall_{a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real) | a != 0} ((a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real) | a != 0} ((a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. m in NaturalPos
#    core type: Operation
#    operator: 40
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a, b_{1}, b_{2}, ..., b_{m}) -> {(a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}} if a in Complex, (b_{1} in Real) ,  (b_{2} in Real) ,  ... ,  (b_{m} in Real) ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 49, 11
# 10. (a, b_{1}, b_{2}, ..., b_{m}) -> {(a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}} if a in Complex, (b_{1} in Real) ,  (b_{2} in Real) ,  ... ,  (b_{m} in Real) ,  a != 0.
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (a,b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 50, 43
# 13. {(a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}} if a in Complex, (b_{1} in Real) ,  (b_{2} in Real) ,  ... ,  (b_{m} in Real) ,  a != 0.
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. (a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}) = a^{b_{1} +  b_{2} +  ... +  b_{m}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (a in Complex)and (b_{1} in Real) and  (b_{2} in Real) and  ... and  (b_{m} in Real) and (a != 0)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}, a^{b_{1} +  b_{2} +  ... +  b_{m}})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (a in Complex,(b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real), a != 0)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 20. a^{b_{1}} *  a^{b_{2}} *  ... *  a^{b_{m}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. a^{b_{1} +  b_{2} +  ... +  b_{m}}
#     core type: Operation
#     operator: 45
#     operands: 27
# 22. a in Complex
#     core type: Operation
#     operator: 40
#     operands: 28
# 23. (b_{1} in Real), (b_{2} in Real), ..., (b_{m} in Real)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 48
#     end_index: 49
# 24. a != 0
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (a^{b_{1}}, a^{b_{2}}, ..., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 32
# 27. (a, b_{1} +  b_{2} +  ... +  b_{m})
#     core type: ExprTuple
#     sub-expressions: 50, 33
# 28. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 34
# 29. _a -> (b_{_a} in Real)
#     core type: Lambda
#     parameter: 54
#     body: 35
# 30. !=
#     core type: Literal
#     sub-expressions:
# 31. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 50, 36
# 32. a^{b_{1}}, a^{b_{2}}, ..., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 48
#     end_index: 49
# 33. b_{1} +  b_{2} +  ... +  b_{m}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. b_{_a} in Real
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. _a -> a^{b_{_a}}
#     core type: Lambda
#     parameter: 54
#     body: 42
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 43
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (b_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 51, 44
# 42. a^{b_{_a}}
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 44. Real
#     core type: Literal
#     sub-expressions:
# 45. Exp
#     core type: Literal
#     sub-expressions:
# 46. (a, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. _a -> b_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 51
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. m
#     core type: Variable
#     sub-expressions:
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. b_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 52. b
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
