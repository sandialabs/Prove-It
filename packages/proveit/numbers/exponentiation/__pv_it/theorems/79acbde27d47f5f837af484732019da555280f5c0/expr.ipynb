# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Real, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(Exp(x, one), x), InSet(x, Real)))
# Out:
# expr: x -> {x^{1} = x if x in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x^{1} = x \textrm{ if } x \in \mathbb{R}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x^{1} = x if x in Real.
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {x^{1} = x if x in Real.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x^{1} = x
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Real
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (x^{1}, x)
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 8. x^{1}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
