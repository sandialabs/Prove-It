# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#posnat_power_of_quotient">posnat_power_of_quotient</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import posnat_power_of_quotient

# %%
# check that the built expression is the same as the stored expression
assert posnat_power_of_quotient.expr == stored_expr
assert posnat_power_of_quotient.expr._style_id == stored_expr._style_id
print("Passed sanity check: posnat_power_of_quotient matches stored_expr")
# Out:
# Passed sanity check: posnat_power_of_quotient matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(posnat_power_of_quotient.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}, n \in \mathbb{N}^+~|~b \neq 0}~\left(\left(\frac{a}{b}\right)^{n} = \frac{a^{n}}{b^{n}}\right)

# %%
# display the expression information
posnat_power_of_quotient.expr_info()
# Out:
# 0. forall_{a in Complex, b in Complex, n in NaturalPos | b != 0} ((a / b)^{n} = (a^{n} / b^{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, n) -> {(a / b)^{n} = (a^{n} / b^{n}) if a in Complex ,  b in Complex ,  n in NaturalPos ,  b != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, n)
#    core type: ExprTuple
#    sub-expressions: 36, 37, 38
# 4. {(a / b)^{n} = (a^{n} / b^{n}) if a in Complex ,  b in Complex ,  n in NaturalPos ,  b != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a / b)^{n} = (a^{n} / b^{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (b in Complex) and (n in NaturalPos) and (b != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((a / b)^{n}, a^{n} / b^{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complex, b in Complex, n in NaturalPos, b != 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. (a / b)^{n}
#     core type: Operation
#     operator: 34
#     operands: 17
# 12. a^{n} / b^{n}
#     core type: Operation
#     operator: 31
#     operands: 18
# 13. a in Complex
#     core type: Operation
#     operator: 21
#     operands: 19
# 14. b in Complex
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. n in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. b != 0
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. (a / b, n)
#     core type: ExprTuple
#     sub-expressions: 25, 38
# 18. (a^{n}, b^{n})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 19. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 28
# 20. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 28
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 38, 29
# 23. !=
#     core type: Literal
#     sub-expressions:
# 24. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 37, 30
# 25. a / b
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. a^{n}
#     core type: Operation
#     operator: 34
#     operands: 33
# 27. b^{n}
#     core type: Operation
#     operator: 34
#     operands: 35
# 28. Complex
#     core type: Literal
#     sub-expressions:
# 29. NaturalPos
#     core type: Literal
#     sub-expressions:
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. /
#     core type: Literal
#     sub-expressions:
# 32. (a, b)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. (a, n)
#     core type: ExprTuple
#     sub-expressions: 36, 38
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (b, n)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. b
#     core type: Variable
#     sub-expressions:
# 38. n
#     core type: Variable
#     sub-expressions:
