# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Exp, Mult, RealPos, one
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, m), InSet(b, RealPos)))
# Out:
# expr: {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{m} \in \mathbb{C} ,  b \in \mathbb{R}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex) and (b in RealPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#    core type: Operation
#    operator: 30
#    operands: 11
# 8. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#    core type: Operation
#    operator: 19
#    operands: 12
# 9. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 28
#    end_index: 29
# 10. b in RealPos
#     core type: Operation
#     operator: 22
#     operands: 14
# 11. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 15, 34
# 12. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 35
#     body: 17
# 14. (b, RealPos)
#     core type: ExprTuple
#     sub-expressions: 34, 18
# 15. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 28
#     end_index: 29
# 17. a_{_a} in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. RealPos
#     core type: Literal
#     sub-expressions:
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 37
#     body: 25
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 24. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 25. (a_{i})^{b}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 32
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. a_{_a}
#     core type: IndexedVar
# variable: 36
# index: 35
# 33. a_{i}
#     core type: IndexedVar
# variable: 36
# index: 37
# 34. b
#     core type: Variable
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
