# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.core_expr_types import b_1_to_m
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, Real, zero
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
expr = Forall([a, b_1_to_m], Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), domains = [Complex, Real], condition = NotEquals(a, zero))
# Out:
# expr: forall_{a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real | a != 0} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}, b_{1} \in \mathbb{R}, \ldots, b_{m} \in \mathbb{R}~|~a \neq 0}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real | a != 0} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 41, 34
# 4. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 7
#    operands: 8
# ...
