# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complex_power_of_products">complex_power_of_products</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import complex_power_of_products

# %%
# check that the built expression is the same as the stored expression
assert complex_power_of_products.expr == stored_expr
assert complex_power_of_products.expr._style_id == stored_expr._style_id
print("Passed sanity check: complex_power_of_products matches stored_expr")
# Out:
# Passed sanity check: complex_power_of_products matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(complex_power_of_products.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{a_{1} \in \mathbb{R}^+, \ldots, a_{m} \in \mathbb{R}^+, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right)\right]

# %%
# display the expression information
complex_power_of_products.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 39
#    body: 2
# 2. {forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1} in RealPos, ..a_{_a} in RealPos.., a_{m} in RealPos, b in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))
#    core type: Operation
#    operator: 5
#    operand: 6
# ...
