# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Exp, Mult
from proveit.numbers.exponentiation import prod_ai_raise_n__1_to_m

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_m], Equals(Exp(Mult(a_1_to_m), n), prod_ai_raise_n__1_to_m), domains = [Complex])
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{m} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{n} = \left(\left(a_{1}\right)^{n} \cdot \ldots \cdot \left(a_{m}\right)^{n}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{m}) -> {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Lambda
#    parameters: 20\n   body: 3
# 3. {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1} * ..a_{_a}.. * a_{m})^{n}, (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (a_{1} * ..a_{_a}.. * a_{m})^{n}
#     core type: Operation
#     operator: 30
#     operands: 13
# 11. (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}
#     core type: Operation
#     operator: 19
#     operands: 14
# 12. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 28
#     end_index: 29
# 13. (a_{1} * ..a_{_a}.. * a_{m}, n)
#     core type: ExprTuple
#     sub-expressions: 16, 34
# 14. ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 35
#     body: 18
# 16. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 28
#     end_index: 29
# 18. a_{_a} in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. i -> (a_{i})^{n}
#     core type: Lambda
#     parameter: 37
#     body: 25
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 24. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 25. (a_{i})^{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 32
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (a_{i}, n)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. a_{_a}
#     core type: IndexedVar
# variable: 36
# index: 35
# 33. a_{i}
#     core type: IndexedVar
# variable: 36
# index: 37
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
