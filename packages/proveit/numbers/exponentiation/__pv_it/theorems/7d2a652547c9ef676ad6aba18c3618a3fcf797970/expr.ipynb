# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Complex, Exp, NaturalPos, RealPos
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a, b_1_to_m], Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), domains = [RealPos, Complex]), InSet(m, NaturalPos))
# Out:
# expr: {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a \in \mathbb{R}^+, b_{1} \in \mathbb{C}, \ldots, b_{m} \in \mathbb{C}}~\left(\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}}\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex} ((a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalPos
#    core type: Operation
#    operator: 31
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a, b_{1}, ..b_{_a}.., b_{m}) -> {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in RealPos ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{m} in Complex.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 40, 8
# 6. (a, b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 41, 34
# 7. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in RealPos ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{m} in Complex.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in RealPos) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{m} in Complex)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in RealPos, b_{1} in Complex, ..b_{_a} in Complex.., b_{m} in Complex)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. a^{b_{1} + ..b_{_a}.. + b_{m}}
#     core type: Operation
#     operator: 36
#     operands: 21
# 17. a in RealPos
#     core type: Operation
#     operator: 31
#     operands: 22
# 18. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 39
#     end_index: 40
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 41, 25
# 22. (a, RealPos)
#     core type: ExprTuple
#     sub-expressions: 41, 26
# 23. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 27
# 24. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 39
#     end_index: 40
# 25. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. RealPos
#     core type: Literal
#     sub-expressions:
# 27. b_{_a} in Complex
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 44
#     body: 33
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 34
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 35
# 33. a^{b_{i}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 35. Complex
#     core type: Literal
#     sub-expressions:
# 36. Exp
#     core type: Literal
#     sub-expressions:
# 37. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. _a -> b_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 43
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. a
#     core type: Variable
#     sub-expressions:
# 42. b_{i}
#     core type: IndexedVar
# variable: 45
# index: 44
# 43. b_{_a}
#     core type: IndexedVar
# variable: 45
# index: 46
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. b
#     core type: Variable
#     sub-expressions:
# 46. _a
#     core type: Variable
#     sub-expressions:
