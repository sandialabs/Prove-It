# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, m
from proveit.core_expr_types import b_1_to_m
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Real, one, zero
from proveit.numbers.exponentiation import prod_a_raise_bi__1_to_m

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(prod_a_raise_bi__1_to_m, Exp(a, Add(b_1_to_m))), And(InSet(a, Complex), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Real), one, m), NotEquals(a, zero)))
# Out:
# expr: {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a^{b_{1}} \cdot \ldots \cdot a^{b_{m}}\right) = a^{b_{1} + \ldots + b_{m}} \textrm{ if } a \in \mathbb{C} ,  b_{1} \in \mathbb{R} ,  \ldots ,  b_{m} \in \mathbb{R} ,  a \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}} if a in Complex ,  b_{1} in Real ,  ..b_{_a} in Real.. ,  b_{m} in Real ,  a != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}) = a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complex) and (b_{1} in Real) and ..(b_{_a} in Real).. and (b_{m} in Real) and (a != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}, a^{b_{1} + ..b_{_a}.. + b_{m}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Complex, b_{1} in Real, ..b_{_a} in Real.., b_{m} in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. a^{b_{1}} * ..a^{b_{i}}.. * a^{b_{m}}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a^{b_{1} + ..b_{_a}.. + b_{m}}
#    core type: Operation
#    operator: 32
#    operands: 14
# 9. a in Complex
#    core type: Operation
#    operator: 27
#    operands: 15
# 10. (b_{1} in Real), ..(b_{_a} in Real).., (b_{m} in Real)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 35
#     end_index: 36
# 11. a != 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}})
#     core type: ExprTuple
#     sub-expressions: 19
# 14. (a, b_{1} + ..b_{_a}.. + b_{m})
#     core type: ExprTuple
#     sub-expressions: 37, 20
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 21
# 16. _a -> (b_{_a} in Real)
#     core type: Lambda
#     parameter: 42
#     body: 22
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 37, 23
# 19. a^{b_{1}}, ..a^{b_{i}}.., a^{b_{m}}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 35
#     end_index: 36
# 20. b_{1} + ..b_{_a}.. + b_{m}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. b_{_a} in Real
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. i -> a^{b_{i}}
#     core type: Lambda
#     parameter: 40
#     body: 29
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 30
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (b_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 39, 31
# 29. a^{b_{i}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 31. Real
#     core type: Literal
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (a, b_{i})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. _a -> b_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 39
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. m
#     core type: Variable
#     sub-expressions:
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. b_{i}
#     core type: IndexedVar
# variable: 41
# index: 40
# 39. b_{_a}
#     core type: IndexedVar
# variable: 41
# index: 42
# 40. i
#     core type: Variable
#     sub-expressions:
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. _a
#     core type: Variable
#     sub-expressions:
