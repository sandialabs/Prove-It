# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n
from proveit.core_expr_types import a_1_to_m
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos
from proveit.numbers.exponentiation import prod_ai_raise_n__1_to_m

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_m], Equals(Exp(Mult(a_1_to_m), n), prod_ai_raise_n__1_to_m), domains = [Complex]), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{m} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{n} = \left(\left(a_{1}\right)^{n} \cdot \ldots \cdot \left(a_{m}\right)^{n}\right)\right) \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{m} in Complex} ((a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{m}) -> {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Lambda
#    parameters: 28\n   body: 6
# 5. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {(a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex).
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. m in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 11
# 8. n in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 12
# 9. (a_{1} * ..a_{_a}.. * a_{m})^{n} = ((a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex)
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 37, 17
# 12. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 42, 17
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1} * ..a_{_a}.. * a_{m})^{n}, (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. NaturalPos
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} * ..a_{_a}.. * a_{m})^{n}
#     core type: Operation
#     operator: 38
#     operands: 21
# 19. (a_{1})^{n} * ..(a_{i})^{n}.. * (a_{m})^{n}
#     core type: Operation
#     operator: 27
#     operands: 22
# 20. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 36
#     end_index: 37
# 21. (a_{1} * ..a_{_a}.. * a_{m}, n)
#     core type: ExprTuple
#     sub-expressions: 24, 42
# 22. ((a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 23. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 43
#     body: 26
# 24. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (a_{1})^{n}, ..(a_{i})^{n}.., (a_{m})^{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 36
#     end_index: 37
# 26. a_{_a} in Complex
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. i -> (a_{i})^{n}
#     core type: Lambda
#     parameter: 45
#     body: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 34
# 32. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 33. (a_{i})^{n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 40
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (a_{i}, n)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. a_{_a}
#     core type: IndexedVar
# variable: 44
# index: 43
# 41. a_{i}
#     core type: IndexedVar
# variable: 44
# index: 45
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. i
#     core type: Variable
#     sub-expressions:
