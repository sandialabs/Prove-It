# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, n
from proveit.logic import InSet, NotEquals
from proveit.numbers import Complex, NaturalPos, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Complex), InSet(b, Complex), InSet(n, NaturalPos), NotEquals(b, zero))
# Out:
# expr: (a in Complex, b in Complex, n in NaturalPos, b != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}, b \in \mathbb{C}, n \in \mathbb{N}^+, b \neq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex, b in Complex, n in NaturalPos, b != 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a in Complex
#    core type: Operation
#    operator: 7
#    operands: 5
# 2. b in Complex
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. b != 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 6. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. NaturalPos
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
