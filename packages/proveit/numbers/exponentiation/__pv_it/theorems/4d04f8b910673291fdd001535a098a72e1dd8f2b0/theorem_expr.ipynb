# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp_factored_int">exp_factored_int</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import exp_factored_int

# %%
# check that the built expression is the same as the stored expression
assert exp_factored_int.expr == stored_expr
assert exp_factored_int.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp_factored_int matches stored_expr")
# Out:
# Passed sanity check: exp_factored_int matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a \in \mathbb{R}, b \in \mathbb{Z}, c \in \mathbb{Z}, d \in \mathbb{Z}~|~a \neq 0, b = \left(c + d\right)}~\left(a^{b} = \left(a^{c} \cdot a^{d}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a in Real, b in Integer, c in Integer, d in Integer | a != 0, b = (c + d)} (a^{b} = (a^{c} * a^{d}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c, d) -> {a^{b} = (a^{c} * a^{d}) if a in Real ,  b in Integer ,  c in Integer ,  d in Integer ,  a != 0 ,  b = (c + d).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c, d) -> {a^{b} = (a^{c} * a^{d}) if a in Real ,  b in Integer ,  c in Integer ,  d in Integer ,  a != 0 ,  b = (c + d).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 43, 36, 44, 45
# 5. {a^{b} = (a^{c} * a^{d}) if a in Real ,  b in Integer ,  c in Integer ,  d in Integer ,  a != 0 ,  b = (c + d).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. a^{b} = (a^{c} * a^{d})
#    core type: Operation
#    operator: 29
#    operands: 8
# ...
