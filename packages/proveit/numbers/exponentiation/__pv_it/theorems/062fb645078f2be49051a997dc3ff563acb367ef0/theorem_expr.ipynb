# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#quotient_of_posnat_powers">quotient_of_posnat_powers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import quotient_of_posnat_powers

# %%
# check that the built expression is the same as the stored expression
assert quotient_of_posnat_powers.expr == stored_expr
assert quotient_of_posnat_powers.expr._style_id == stored_expr._style_id
print("Passed sanity check: quotient_of_posnat_powers matches stored_expr")
# Out:
# Passed sanity check: quotient_of_posnat_powers matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(quotient_of_posnat_powers.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, m \in \mathbb{N}^+, n \in \mathbb{N}^+~|~a \neq 0}~\left(\frac{a^{m}}{a^{n}} = a^{m - n}\right)

# %%
# display the expression information
quotient_of_posnat_powers.expr_info()
# Out:
# 0. forall_{a in Complex, m in NaturalPos, n in NaturalPos | a != 0} ((a^{m} / a^{n}) = a^{m - n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, m, n) -> {(a^{m} / a^{n}) = a^{m - n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos ,  a != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, m, n)
#    core type: ExprTuple
#    sub-expressions: 37, 38, 41
# 4. {(a^{m} / a^{n}) = a^{m - n} if a in Complex ,  m in NaturalPos ,  n in NaturalPos ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{m} / a^{n}) = a^{m - n}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (m in NaturalPos) and (n in NaturalPos) and (a != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a^{m} / a^{n}, a^{m - n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complex, m in NaturalPos, n in NaturalPos, a != 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. a^{m} / a^{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a^{m - n}
#     core type: Operation
#     operator: 33
#     operands: 19
# 13. a in Complex
#     core type: Operation
#     operator: 22
#     operands: 20
# 14. m in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 21
# 15. n in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. a != 0
#     core type: Operation
#     operator: 24
#     operands: 25
# 17. /
#     core type: Literal
#     sub-expressions:
# 18. (a^{m}, a^{n})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 19. (a, m - n)
#     core type: ExprTuple
#     sub-expressions: 37, 28
# 20. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 29
# 21. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 38, 30
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 41, 30
# 24. !=
#     core type: Literal
#     sub-expressions:
# 25. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 37, 31
# 26. a^{m}
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. a^{n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. m - n
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. NaturalPos
#     core type: Literal
#     sub-expressions:
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. (a, m)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (a, n)
#     core type: ExprTuple
#     sub-expressions: 37, 41
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (m, -n)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. -n
#     core type: Operation
#     operator: 40
#     operand: 41
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
