# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_power_of_products">real_power_of_products</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.exponentiation import real_power_of_products

# %%
# check that the built expression is the same as the stored expression
assert real_power_of_products.expr == stored_expr
assert real_power_of_products.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_power_of_products matches stored_expr")
# Out:
# Passed sanity check: real_power_of_products matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{\left(a_{1} \in \mathbb{C}\right), \left(a_{2} \in \mathbb{C}\right), \ldots, \left(a_{m} \in \mathbb{C}\right), b \in \mathbb{R}~|~\left(a_{1} \neq 0\right), \left(a_{2} \neq 0\right), \ldots, \left(a_{m} \neq 0\right)}~\left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot  \left(a_{2}\right)^{b} \cdot  \ldots \cdot  \left(a_{m}\right)^{b}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{m} in Complex), b in Real | (a_{1} != 0), (a_{2} != 0), ..., (a_{m} != 0)} ((a_{1} *  a_{2} *  ... *  a_{m})^{b} = ((a_{1})^{b} *  (a_{2})^{b} *  ... *  (a_{m})^{b}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{m} in Complex), b in Real | (a_{1} != 0), (a_{2} != 0), ..., (a_{m} != 0)} ((a_{1} *  a_{2} *  ... *  a_{m})^{b} = ((a_{1})^{b} *  (a_{2})^{b} *  ... *  (a_{m})^{b})) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{(a_{1} in Complex), (a_{2} in Complex), ..., (a_{m} in Complex), b in Real | (a_{1} != 0), (a_{2} != 0), ..., (a_{m} != 0)} ((a_{1} *  a_{2} *  ... *  a_{m})^{b} = ((a_{1})^{b} *  (a_{2})^{b} *  ... *  (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 48
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 48
# ...
