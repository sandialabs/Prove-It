# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, a, b, i, m
from proveit.core_expr_types import a_1_to_m
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Exp, Mult, NaturalPos, RealPos, one, zero
from proveit.numbers.exponentiation import prod_ai_raise_b__1_to_m

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([a_1_to_m, b], Equals(Exp(Mult(a_1_to_m), b), prod_ai_raise_b__1_to_m), domains = [Complex, RealPos], condition = ExprRange(i, NotEquals(IndexedVar(a, i), zero), one, m)), domains = [NaturalPos])
# Out:
# expr: forall_{m in NaturalPos} [forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos | a_{1} != 0, ..a_{i} != 0.., a_{m} != 0} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{a_{1} \in \mathbb{C}, \ldots, a_{m} \in \mathbb{C}, b \in \mathbb{R}^+~|~a_{1} \neq 0, \ldots, a_{m} \neq 0}~\left(\left(a_{1} \cdot \ldots \cdot a_{m}\right)^{b} = \left(\left(a_{1}\right)^{b} \cdot \ldots \cdot \left(a_{m}\right)^{b}\right)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos | a_{1} != 0, ..a_{i} != 0.., a_{m} != 0} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos | a_{1} != 0, ..a_{i} != 0.., a_{m} != 0} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 45
#    body: 2
# 2. {forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos | a_{1} != 0, ..a_{i} != 0.., a_{m} != 0} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos | a_{1} != 0, ..a_{i} != 0.., a_{m} != 0} ((a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalPos
#    core type: Operation
#    operator: 35
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos ,  a_{1} != 0 ,  ..a_{i} != 0.. ,  a_{m} != 0.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 10
# 8. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 39, 50
# 9. {(a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{m} in Complex ,  b in RealPos ,  a_{1} != 0 ,  ..a_{i} != 0.. ,  a_{m} != 0.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (a_{1} * ..a_{_a}.. * a_{m})^{b} = ((a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{m} in Complex) and (b in RealPos) and (a_{1} != 0) and ..(a_{i} != 0).. and (a_{m} != 0)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1} * ..a_{_a}.. * a_{m})^{b}, (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (a_{1} in Complex, ..a_{_a} in Complex.., a_{m} in Complex, b in RealPos, a_{1} != 0, ..a_{i} != 0.., a_{m} != 0)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 17. (a_{1} * ..a_{_a}.. * a_{m})^{b}
#     core type: Operation
#     operator: 46
#     operands: 22
# 18. (a_{1})^{b} * ..(a_{i})^{b}.. * (a_{m})^{b}
#     core type: Operation
#     operator: 32
#     operands: 23
# 19. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 44
#     end_index: 45
# 20. b in RealPos
#     core type: Operation
#     operator: 35
#     operands: 25
# 21. (a_{1} != 0), ..(a_{i} != 0).., (a_{m} != 0)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 44
#     end_index: 45
# 22. (a_{1} * ..a_{_a}.. * a_{m}, b)
#     core type: ExprTuple
#     sub-expressions: 27, 50
# 23. ((a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 51
#     body: 29
# 25. (b, RealPos)
#     core type: ExprTuple
#     sub-expressions: 50, 30
# 26. i -> (a_{i} != 0)
#     core type: Lambda
#     parameter: 53
#     body: 31
# 27. a_{1} * ..a_{_a}.. * a_{m}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. (a_{1})^{b}, ..(a_{i})^{b}.., (a_{m})^{b}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 44
#     end_index: 45
# 29. a_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. RealPos
#     core type: Literal
#     sub-expressions:
# 31. a_{i} != 0
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. i -> (a_{i})^{b}
#     core type: Lambda
#     parameter: 53
#     body: 40
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 41
# 37. !=
#     core type: Literal
#     sub-expressions:
# 38. (a_{i}, 0)
#     core type: ExprTuple
#     sub-expressions: 49, 42
# 39. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 40. (a_{i})^{b}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. Exp
#     core type: Literal
#     sub-expressions:
# 47. (a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 48. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 51
# 49. a_{i}
#     core type: IndexedVar
# variable: 52
# index: 53
# 50. b
#     core type: Variable
#     sub-expressions:
# 51. _a
#     core type: Variable
#     sub-expressions:
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. i
#     core type: Variable
#     sub-expressions:
