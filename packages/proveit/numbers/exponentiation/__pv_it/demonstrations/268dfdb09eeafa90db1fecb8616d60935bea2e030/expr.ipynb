# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import And, Boolean, InSet, NotEquals
from proveit.numbers import GreaterEq, zero

# %%
# build up the expression from sub-expressions
expr = InSet(And(GreaterEq(x, zero), NotEquals(y, zero)), Boolean)
# Out:
# expr: ((x >= 0) and (y != 0)) in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x \geq 0\right) \land \left(y \neq 0\right)\right) \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x >= 0) and (y != 0)) in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((x >= 0) and (y != 0), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (x >= 0) and (y != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x >= 0, y != 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x >= 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. y != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. >=
#    core type: Literal
#    sub-expressions:
# 10. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. y
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
