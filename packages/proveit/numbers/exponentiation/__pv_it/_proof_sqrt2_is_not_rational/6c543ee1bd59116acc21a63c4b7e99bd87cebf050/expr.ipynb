# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b_star
from proveit.logic import InSet
from proveit.numbers import Abs, Complex, Mult, sqrt, two

# %%
# build up the expression from sub-expressions
expr = InSet(Mult(Abs(sqrt(two)), b_star), Complex)
# Out:
# expr: (|sqrt(2)| * b_star) in Complex

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\sqrt{2}\right| \cdot b^*\right) \in \mathbb{C}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|sqrt(2)| * b_star) in Complex
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (|sqrt(2)| * b_star, Complex)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |sqrt(2)| * b_star
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Complex
#    core type: Literal
#    sub-expressions:
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (|sqrt(2)|, b_star)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |sqrt(2)|
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. b_star
#    core type: Variable
#    sub-expressions:
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. sqrt(2)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 13. 1 / 2
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
