# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a_star, b_star
from proveit.numbers import Abs, Mult, frac, sqrt, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(Abs(sqrt(two)), b_star), Mult(frac(a_star, b_star), b_star))
# Out:
# expr: (|sqrt(2)| * b_star, (a_star / b_star) * b_star)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\sqrt{2}\right| \cdot b^*, \frac{a^*}{b^*} \cdot b^*\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|sqrt(2)| * b_star, (a_star / b_star) * b_star)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |sqrt(2)| * b_star
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (a_star / b_star) * b_star
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|sqrt(2)|, b_star)
#    core type: ExprTuple
#    sub-expressions: 6, 14
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (a_star / b_star, b_star)
#    core type: ExprTuple
#    sub-expressions: 7, 14
# 6. |sqrt(2)|
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. a_star / b_star
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. Abs
#    core type: Literal
#    sub-expressions:
# 9. sqrt(2)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a_star, b_star)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 13. a_star
#     core type: Variable
#     sub-expressions:
# 14. b_star
#     core type: Variable
#     sub-expressions:
# 15. 1 / 2
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
