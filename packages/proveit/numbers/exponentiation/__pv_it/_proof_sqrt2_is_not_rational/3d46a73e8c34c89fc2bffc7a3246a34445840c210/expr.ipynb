# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a_star, b_star
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, two

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(two, Exp(b_star, two)), Exp(a_star, two))
# Out:
# expr: (2 * (b_star)^{2}) = (a_star)^{2}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot \left(b^*\right)^{2}\right) = \left(a^*\right)^{2}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * (b_star)^{2}) = (a_star)^{2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 * (b_star)^{2}, (a_star)^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 * (b_star)^{2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_star)^{2}
#    core type: Operation
#    operator: 10
#    operands: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (2, (b_star)^{2})
#    core type: ExprTuple
#    sub-expressions: 13, 8
# 7. (a_star, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 8. (b_star)^{2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. a_star
#    core type: Variable
#    sub-expressions:
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (b_star, 2)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. b_star
#     core type: Variable
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
