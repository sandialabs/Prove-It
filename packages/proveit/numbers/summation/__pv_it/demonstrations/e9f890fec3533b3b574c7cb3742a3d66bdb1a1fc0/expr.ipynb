# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, l
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(c, one)
sub_expr4 = Add(l, one)
sub_expr5 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, zero)
expr = Forall(instance_param_or_params = [sub_expr5, sub_expr3], instance_expr = Equals(Mult(sub_expr5, Sum(index_or_indices = sub_expr2, summand = sub_expr4, domain = Integer), sub_expr3), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr5, sub_expr4, sub_expr3), domain = Integer)).with_wrapping_at(2), domain = Complex).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{0}, c_{1} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{0} \cdot \left[\sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right] \cdot c_{1}\right) =  \\ \left[\sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{0} \cdot \left(l + 1\right) \cdot c_{1}\right)\right] \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{0}, c_{1} in Complex} ((a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{0}, c_{1}) -> {(a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{0} in Complex) ,  c_{1} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{0}, c_{1}) -> {(a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{0} in Complex) ,  c_{1} in Complex.
#    core type: Lambda
# ...
