# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = Add(l, one)
sub_expr4 = IndexedVar(c, one)
sub_expr5 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, zero)
expr = Implies(Forall(instance_param_or_params = sub_expr2, instance_expr = InSet(sub_expr3, Complex), domain = Integer), Forall(instance_param_or_params = [sub_expr5, sub_expr4], instance_expr = Equals(Mult(sub_expr5, Sum(index_or_indices = sub_expr2, summand = sub_expr3, domain = Integer), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr5, sub_expr3, sub_expr4), domain = Integer)).with_wrapping_at(2), domain = Complex).with_wrapping()).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \in \mathbb{C}\right)\right] \Rightarrow  \\ \left[\begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{0}, c_{1} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{0} \cdot \left[\sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right] \cdot c_{1}\right) =  \\ \left[\sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{0} \cdot \left(l + 1\right) \cdot c_{1}\right)\right] \end{array} \end{array}\right)\end{array}\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{l in Integer} ((l + 1) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{0}, c_{1} in Complex} ((a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})])]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in Integer} ((l + 1) in Complex), forall_{a_{1}, a_{2}, ..., a_{0}, c_{1} in Complex} ((a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})]))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in Integer} ((l + 1) in Complex)
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. forall_{a_{1}, a_{2}, ..., a_{0}, c_{1} in Complex} ((a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l -> {(l + 1) in Complex if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, a_{2}, ..., a_{0}, c_{1}) -> {(a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{0} in Complex) ,  c_{1} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. l -> {(l + 1) in Complex if l in Integer.
#    core type: Lambda
#    parameter: 57
#    body: 10
# 9. (a_{1}, a_{2}, ..., a_{0}, c_{1}) -> {(a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{0} in Complex) ,  c_{1} in Complex.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. {(l + 1) in Complex if l in Integer.
#     core type: Conditional
#     value: 13
#     condition: 43
# 11. (a_{1}, a_{2}, ..., a_{0}, c_{1})
#     core type: ExprTuple
#     sub-expressions: 44, 46
# 12. {(a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{0} in Complex) ,  c_{1} in Complex.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. (l + 1) in Complex
#     core type: Operation
#     operator: 47
#     operands: 16
# 14. (a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}) =  \\ [Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})]
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{0} in Complex) and (c_{1} in Complex)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (l + 1, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 38
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}, Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{0} in Complex), c_{1} in Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a_{1} *  a_{2} *  ... *  a_{0} * [Sum_{l in Integer} (l + 1)] * c_{1}
#     core type: Operation
#     operator: 41
#     operands: 25
# 22. Sum_{l in Integer} (a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1})
#     core type: Operation
#     operator: 32
#     operand: 30
# 23. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 58
#     end_index: 50
# 24. c_{1} in Complex
#     core type: Operation
#     operator: 47
#     operands: 28
# 25. (a_{1}, a_{2}, ..., a_{0}, Sum_{l in Integer} (l + 1), c_{1})
#     core type: ExprTuple
#     sub-expressions: 44, 29, 46
# 26. (l -> {a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1} if l in Integer.)
#     core type: ExprTuple
#     sub-expressions: 30
# 27. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 31
# 28. (c_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 38
# 29. Sum_{l in Integer} (l + 1)
#     core type: Operation
#     operator: 32
#     operand: 36
# 30. l -> {a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1} if l in Integer.
#     core type: Lambda
#     parameter: 57
#     body: 34
# 31. a_{_a} in Complex
#     core type: Operation
#     operator: 47
#     operands: 35
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (l -> {l + 1 if l in Integer.)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. {a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1} if l in Integer.
#     core type: Conditional
#     value: 37
#     condition: 43
# 35. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 38
# 36. l -> {l + 1 if l in Integer.
#     core type: Lambda
#     parameter: 57
#     body: 40
# 37. a_{1} *  a_{2} *  ... *  a_{0} * (l + 1) * c_{1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. (l)
#     core type: ExprTuple
#     sub-expressions: 57
# 40. {l + 1 if l in Integer.
#     core type: Conditional
#     value: 45
#     condition: 43
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (a_{1}, a_{2}, ..., a_{0}, l + 1, c_{1})
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 43. l in Integer
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. a_{1}, a_{2}, ..., a_{0}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 58
#     end_index: 50
# 45. l + 1
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. c_{1}
#     core type: IndexedVar
# variable: 53
# index: 58
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 55
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 55. Integer
#     core type: Literal
#     sub-expressions:
# 56. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 57. l
#     core type: Variable
#     sub-expressions:
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
