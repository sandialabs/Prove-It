# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, c, l
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = Add(l, one)
sub_expr4 = IndexedVar(a, one)
sub_expr5 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
expr = ExprTuple(Forall(instance_param_or_params = sub_expr2, instance_expr = InSet(sub_expr3, Complex), domain = Integer), Forall(instance_param_or_params = [sub_expr4, sub_expr5], instance_expr = Equals(Mult(sub_expr4, Sum(index_or_indices = sub_expr2, summand = sub_expr3, domain = Integer), sub_expr5), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr4, sub_expr3, sub_expr5), domain = Integer)).with_wrapping_at(2), domain = Complex).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \in \mathbb{C}\right), \begin{array}{l}\forall_{a_{1}, c_{1}, c_{2}, \ldots, c_{0} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left[\sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right]\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left[\sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \left(l + 1\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right] \end{array} \end{array}\right)\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{l in Integer} ((l + 1) in Complex), forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})]))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{l in Integer} ((l + 1) in Complex)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})])
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (l -> {(l + 1) in Complex if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})] if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. l -> {(l + 1) in Complex if l in Integer.
#    core type: Lambda
#    parameter: 54
#    body: 8
# 7. (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})] if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. {(l + 1) in Complex if l in Integer.
#    core type: Conditional
#    value: 11
#    condition: 41
# 9. (a_{1},c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 42, 44
# 10. {(a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})] if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. (l + 1) in Complex
#     core type: Operation
#     operator: 45
#     operands: 14
# 12. (a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ [Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})]
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (a_{1} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{0} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (l + 1, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 36
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a_{1} * [Sum_{l in Integer} (l + 1)]* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 39
#     operands: 23
# 20. Sum_{l in Integer} (a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0})
#     core type: Operation
#     operator: 30
#     operand: 28
# 21. a_{1} in Complex
#     core type: Operation
#     operator: 45
#     operands: 25
# 22. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 55
#     end_index: 52
# 23. (a_{1}, Sum_{l in Integer} (l + 1),c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 42, 27, 44
# 24. (l -> {a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0} if l in Integer.)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (a_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 26. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 29
# 27. Sum_{l in Integer} (l + 1)
#     core type: Operation
#     operator: 30
#     operand: 34
# 28. l -> {a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0} if l in Integer.
#     core type: Lambda
#     parameter: 54
#     body: 32
# 29. c_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 33
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (l -> {l + 1 if l in Integer.)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. {a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0} if l in Integer.
#     core type: Conditional
#     value: 35
#     condition: 41
# 33. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 36
# 34. l -> {l + 1 if l in Integer.
#     core type: Lambda
#     parameter: 54
#     body: 38
# 35. a_{1} * (l + 1)* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. (l)
#     core type: ExprTuple
#     sub-expressions: 54
# 38. {l + 1 if l in Integer.
#     core type: Conditional
#     value: 43
#     condition: 41
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (a_{1}, l + 1,c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 42, 43, 44
# 41. l in Integer
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. a_{1}
#     core type: IndexedVar
# variable: 47
# index: 55
# 43. l + 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 55
#     end_index: 52
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. (1)
#     core type: ExprTuple
#     sub-expressions: 55
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 51. _a -> c_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 56
# 52. 0
#     core type: Literal
#     sub-expressions:
# 53. Integer
#     core type: Literal
#     sub-expressions:
# 54. l
#     core type: Variable
#     sub-expressions:
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. c_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
