# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i, m, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = Conditional(Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), And(InSet(m, Natural), Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x} \textrm{ if } m \in \mathbb{N} ,  \left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (m in Natural) and ((Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Sum_{i = 0}^{m + 1} x^{i}, (1 - x^{m + 2}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. Sum_{i = 0}^{m + 1} x^{i}
#    core type: Operation
#    operator: 22
#    operand: 15
# 7. (1 - x^{m + 2}) / (1 - x)
#    core type: Operation
#    operator: 24
#    operands: 11
# 8. m in Natural
#    core type: Operation
#    operator: 46
#    operands: 12
# 9. (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (i -> {x^{i} if i in {0 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. (1 - x^{m + 2}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 16, 30
# 12. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 66, 17
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (Sum_{i = 0}^{m} x^{i}, (1 - x^{m + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. i -> {x^{i} if i in {0 .. m + 1}.
#     core type: Lambda
#     parameter: 52
#     body: 20
# 16. 1 - x^{m + 2}
#     core type: Operation
#     operator: 64
#     operands: 21
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. Sum_{i = 0}^{m} x^{i}
#     core type: Operation
#     operator: 22
#     operand: 28
# 19. (1 - x^{m + 1}) / (1 - x)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. {x^{i} if i in {0 .. m + 1}.
#     core type: Conditional
#     value: 39
#     condition: 26
# 21. (1, -x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 67, 27
# 22. Sum
#     core type: Literal
#     sub-expressions:
# 23. (i -> {x^{i} if i in {0 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 24. /
#     core type: Literal
#     sub-expressions:
# 25. (1 - x^{m + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. i in {0 .. m + 1}
#     core type: Operation
#     operator: 46
#     operands: 31
# 27. -x^{m + 2}
#     core type: Operation
#     operator: 49
#     operand: 38
# 28. i -> {x^{i} if i in {0 .. m}.
#     core type: Lambda
#     parameter: 52
#     body: 34
# 29. 1 - x^{m + 1}
#     core type: Operation
#     operator: 64
#     operands: 35
# 30. 1 - x
#     core type: Operation
#     operator: 64
#     operands: 36
# 31. (i, {0 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 32. (x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. (i)
#     core type: ExprTuple
#     sub-expressions: 52
# 34. {x^{i} if i in {0 .. m}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 35. (1, -x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 67, 41
# 36. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 67, 42
# 37. {0 .. m + 1}
#     core type: Operation
#     operator: 56
#     operands: 43
# 38. x^{m + 2}
#     core type: Operation
#     operator: 58
#     operands: 44
# 39. x^{i}
#     core type: Operation
#     operator: 58
#     operands: 45
# 40. i in {0 .. m}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. -x^{m + 1}
#     core type: Operation
#     operator: 49
#     operand: 54
# 42. -x
#     core type: Operation
#     operator: 49
#     operand: 62
# 43. (0, m + 1)
#     core type: ExprTuple
#     sub-expressions: 61, 63
# 44. (x, m + 2)
#     core type: ExprTuple
#     sub-expressions: 62, 51
# 45. (x, i)
#     core type: ExprTuple
#     sub-expressions: 62, 52
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (i, {0 .. m})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 48. (x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 51. m + 2
#     core type: Operation
#     operator: 64
#     operands: 55
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. {0 .. m}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. x^{m + 1}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 66, 60
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (0, m)
#     core type: ExprTuple
#     sub-expressions: 61, 66
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (x, m + 1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. 0
#     core type: Literal
#     sub-expressions:
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. m + 1
#     core type: Operation
#     operator: 64
#     operands: 65
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. m
#     core type: Variable
#     sub-expressions:
# 67. 1
#     core type: Literal
#     sub-expressions:
