# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, m, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = ExprTuple(Lambda(m, Conditional(Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), And(InSet(m, Natural), Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m \mapsto \left\{\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x} \textrm{ if } m \in \mathbb{N} ,  \left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Lambda
#    parameter: 69
#    body: 3
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 69
# 3. {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (m in Natural) and ((Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (Sum_{i = 0}^{m + 1} x^{i}, (1 - x^{m + 2}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. Sum_{i = 0}^{m + 1} x^{i}
#    core type: Operation
#    operator: 25
#    operand: 18
# 10. (1 - x^{m + 2}) / (1 - x)
#     core type: Operation
#     operator: 27
#     operands: 14
# 11. m in Natural
#     core type: Operation
#     operator: 49
#     operands: 15
# 12. (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (i -> {x^{i} if i in {0 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (1 - x^{m + 2}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 19, 33
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 69, 20
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (Sum_{i = 0}^{m} x^{i}, (1 - x^{m + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. i -> {x^{i} if i in {0 .. m + 1}.
#     core type: Lambda
#     parameter: 55
#     body: 23
# 19. 1 - x^{m + 2}
#     core type: Operation
#     operator: 67
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. Sum_{i = 0}^{m} x^{i}
#     core type: Operation
#     operator: 25
#     operand: 31
# 22. (1 - x^{m + 1}) / (1 - x)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. {x^{i} if i in {0 .. m + 1}.
#     core type: Conditional
#     value: 42
#     condition: 29
# 24. (1, -x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 70, 30
# 25. Sum
#     core type: Literal
#     sub-expressions:
# 26. (i -> {x^{i} if i in {0 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. /
#     core type: Literal
#     sub-expressions:
# 28. (1 - x^{m + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. i in {0 .. m + 1}
#     core type: Operation
#     operator: 49
#     operands: 34
# 30. -x^{m + 2}
#     core type: Operation
#     operator: 52
#     operand: 41
# 31. i -> {x^{i} if i in {0 .. m}.
#     core type: Lambda
#     parameter: 55
#     body: 37
# 32. 1 - x^{m + 1}
#     core type: Operation
#     operator: 67
#     operands: 38
# 33. 1 - x
#     core type: Operation
#     operator: 67
#     operands: 39
# 34. (i, {0 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 55, 40
# 35. (x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. (i)
#     core type: ExprTuple
#     sub-expressions: 55
# 37. {x^{i} if i in {0 .. m}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 38. (1, -x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 70, 44
# 39. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 70, 45
# 40. {0 .. m + 1}
#     core type: Operation
#     operator: 59
#     operands: 46
# 41. x^{m + 2}
#     core type: Operation
#     operator: 61
#     operands: 47
# 42. x^{i}
#     core type: Operation
#     operator: 61
#     operands: 48
# 43. i in {0 .. m}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. -x^{m + 1}
#     core type: Operation
#     operator: 52
#     operand: 57
# 45. -x
#     core type: Operation
#     operator: 52
#     operand: 65
# 46. (0, m + 1)
#     core type: ExprTuple
#     sub-expressions: 64, 66
# 47. (x, m + 2)
#     core type: ExprTuple
#     sub-expressions: 65, 54
# 48. (x, i)
#     core type: ExprTuple
#     sub-expressions: 65, 55
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (i, {0 .. m})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. (x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 57
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (x)
#     core type: ExprTuple
#     sub-expressions: 65
# 54. m + 2
#     core type: Operation
#     operator: 67
#     operands: 58
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. {0 .. m}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. x^{m + 1}
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 69, 63
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (0, m)
#     core type: ExprTuple
#     sub-expressions: 64, 69
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (x, m + 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. 2
#     core type: Literal
#     sub-expressions:
# 64. 0
#     core type: Literal
#     sub-expressions:
# 65. x
#     core type: Variable
#     sub-expressions:
# 66. m + 1
#     core type: Operation
#     operator: 67
#     operands: 68
# 67. +
#     core type: Literal
#     sub-expressions:
# 68. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 69. m
#     core type: Variable
#     sub-expressions:
# 70. 1
#     core type: Literal
#     sub-expressions:
