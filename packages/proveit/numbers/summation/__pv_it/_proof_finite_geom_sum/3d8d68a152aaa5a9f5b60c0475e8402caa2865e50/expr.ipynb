# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, m, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), domain = Natural, condition = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}~|~\left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}}~\left(\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Lambda
#    parameter: 71
#    body: 5
# 4. (m)
#    core type: ExprTuple
#    sub-expressions: 71
# 5. {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
#    core type: Operation
#    operator: 18
#    operands: 8
# 7. (m in Natural) and ((Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (Sum_{i = 0}^{m + 1} x^{i}, (1 - x^{m + 2}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Sum_{i = 0}^{m + 1} x^{i}
#     core type: Operation
#     operator: 27
#     operand: 20
# 12. (1 - x^{m + 2}) / (1 - x)
#     core type: Operation
#     operator: 29
#     operands: 16
# 13. m in Natural
#     core type: Operation
#     operator: 51
#     operands: 17
# 14. (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (i -> {x^{i} if i in {0 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. (1 - x^{m + 2}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 21, 35
# 17. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 71, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (Sum_{i = 0}^{m} x^{i}, (1 - x^{m + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. i -> {x^{i} if i in {0 .. m + 1}.
#     core type: Lambda
#     parameter: 57
#     body: 25
# 21. 1 - x^{m + 2}
#     core type: Operation
#     operator: 69
#     operands: 26
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. Sum_{i = 0}^{m} x^{i}
#     core type: Operation
#     operator: 27
#     operand: 33
# 24. (1 - x^{m + 1}) / (1 - x)
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. {x^{i} if i in {0 .. m + 1}.
#     core type: Conditional
#     value: 44
#     condition: 31
# 26. (1, -x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 72, 32
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (i -> {x^{i} if i in {0 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (1 - x^{m + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. i in {0 .. m + 1}
#     core type: Operation
#     operator: 51
#     operands: 36
# 32. -x^{m + 2}
#     core type: Operation
#     operator: 54
#     operand: 43
# 33. i -> {x^{i} if i in {0 .. m}.
#     core type: Lambda
#     parameter: 57
#     body: 39
# 34. 1 - x^{m + 1}
#     core type: Operation
#     operator: 69
#     operands: 40
# 35. 1 - x
#     core type: Operation
#     operator: 69
#     operands: 41
# 36. (i, {0 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 57, 42
# 37. (x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 43
# 38. (i)
#     core type: ExprTuple
#     sub-expressions: 57
# 39. {x^{i} if i in {0 .. m}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 40. (1, -x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 72, 46
# 41. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 72, 47
# 42. {0 .. m + 1}
#     core type: Operation
#     operator: 61
#     operands: 48
# 43. x^{m + 2}
#     core type: Operation
#     operator: 63
#     operands: 49
# 44. x^{i}
#     core type: Operation
#     operator: 63
#     operands: 50
# 45. i in {0 .. m}
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. -x^{m + 1}
#     core type: Operation
#     operator: 54
#     operand: 59
# 47. -x
#     core type: Operation
#     operator: 54
#     operand: 67
# 48. (0, m + 1)
#     core type: ExprTuple
#     sub-expressions: 66, 68
# 49. (x, m + 2)
#     core type: ExprTuple
#     sub-expressions: 67, 56
# 50. (x, i)
#     core type: ExprTuple
#     sub-expressions: 67, 57
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (i, {0 .. m})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 53. (x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 59
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 67
# 56. m + 2
#     core type: Operation
#     operator: 69
#     operands: 60
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. {0 .. m}
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. x^{m + 1}
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 71, 65
# 61. Interval
#     core type: Literal
#     sub-expressions:
# 62. (0, m)
#     core type: ExprTuple
#     sub-expressions: 66, 71
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (x, m + 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. 0
#     core type: Literal
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. m + 1
#     core type: Operation
#     operator: 69
#     operands: 70
# 69. +
#     core type: Literal
#     sub-expressions:
# 70. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 71. m
#     core type: Variable
#     sub-expressions:
# 72. 1
#     core type: Literal
#     sub-expressions:
