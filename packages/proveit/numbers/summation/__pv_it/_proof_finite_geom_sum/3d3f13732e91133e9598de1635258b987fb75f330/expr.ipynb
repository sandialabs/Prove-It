# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, m, x
from proveit.logic import And, Equals, Forall, TRUE
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), domain = Natural, condition = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \top \land \left[\forall_{m \in \mathbb{N}~|~\left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}}~\left(\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (TRUE, forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. TRUE
#    core type: Literal
#    sub-expressions:
# 3. forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Lambda
#    parameter: 74
#    body: 8
# 7. (m)
#    core type: ExprTuple
#    sub-expressions: 74
# 8. {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
#    core type: Operation
#    operator: 21
#    operands: 11
# 10. (m in Natural) and ((Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (Sum_{i = 0}^{m + 1} x^{i}, (1 - x^{m + 2}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Sum_{i = 0}^{m + 1} x^{i}
#     core type: Operation
#     operator: 30
#     operand: 23
# 15. (1 - x^{m + 2}) / (1 - x)
#     core type: Operation
#     operator: 32
#     operands: 19
# 16. m in Natural
#     core type: Operation
#     operator: 54
#     operands: 20
# 17. (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (i -> {x^{i} if i in {0 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. (1 - x^{m + 2}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 24, 38
# 20. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 74, 25
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (Sum_{i = 0}^{m} x^{i}, (1 - x^{m + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. i -> {x^{i} if i in {0 .. m + 1}.
#     core type: Lambda
#     parameter: 60
#     body: 28
# 24. 1 - x^{m + 2}
#     core type: Operation
#     operator: 72
#     operands: 29
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. Sum_{i = 0}^{m} x^{i}
#     core type: Operation
#     operator: 30
#     operand: 36
# 27. (1 - x^{m + 1}) / (1 - x)
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. {x^{i} if i in {0 .. m + 1}.
#     core type: Conditional
#     value: 47
#     condition: 34
# 29. (1, -x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 75, 35
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (i -> {x^{i} if i in {0 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (1 - x^{m + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. i in {0 .. m + 1}
#     core type: Operation
#     operator: 54
#     operands: 39
# 35. -x^{m + 2}
#     core type: Operation
#     operator: 57
#     operand: 46
# 36. i -> {x^{i} if i in {0 .. m}.
#     core type: Lambda
#     parameter: 60
#     body: 42
# 37. 1 - x^{m + 1}
#     core type: Operation
#     operator: 72
#     operands: 43
# 38. 1 - x
#     core type: Operation
#     operator: 72
#     operands: 44
# 39. (i, {0 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 40. (x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 46
# 41. (i)
#     core type: ExprTuple
#     sub-expressions: 60
# 42. {x^{i} if i in {0 .. m}.
#     core type: Conditional
#     value: 47
#     condition: 48
# 43. (1, -x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 75, 49
# 44. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 75, 50
# 45. {0 .. m + 1}
#     core type: Operation
#     operator: 64
#     operands: 51
# 46. x^{m + 2}
#     core type: Operation
#     operator: 66
#     operands: 52
# 47. x^{i}
#     core type: Operation
#     operator: 66
#     operands: 53
# 48. i in {0 .. m}
#     core type: Operation
#     operator: 54
#     operands: 55
# 49. -x^{m + 1}
#     core type: Operation
#     operator: 57
#     operand: 62
# 50. -x
#     core type: Operation
#     operator: 57
#     operand: 70
# 51. (0, m + 1)
#     core type: ExprTuple
#     sub-expressions: 69, 71
# 52. (x, m + 2)
#     core type: ExprTuple
#     sub-expressions: 70, 59
# 53. (x, i)
#     core type: ExprTuple
#     sub-expressions: 70, 60
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (i, {0 .. m})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 56. (x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 62
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (x)
#     core type: ExprTuple
#     sub-expressions: 70
# 59. m + 2
#     core type: Operation
#     operator: 72
#     operands: 63
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. {0 .. m}
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. x^{m + 1}
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 74, 68
# 64. Interval
#     core type: Literal
#     sub-expressions:
# 65. (0, m)
#     core type: ExprTuple
#     sub-expressions: 69, 74
# 66. Exp
#     core type: Literal
#     sub-expressions:
# 67. (x, m + 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. 0
#     core type: Literal
#     sub-expressions:
# 70. x
#     core type: Variable
#     sub-expressions:
# 71. m + 1
#     core type: Operation
#     operator: 72
#     operands: 73
# 72. +
#     core type: Literal
#     sub-expressions:
# 73. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 74. m
#     core type: Variable
#     sub-expressions:
# 75. 1
#     core type: Literal
#     sub-expressions:
