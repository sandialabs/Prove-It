# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, m, n, x
from proveit.logic import And, Equals, Forall, TRUE
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = ExprTuple(And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), domain = Natural, condition = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4)))), Forall(instance_param_or_params = [n], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, n)), frac(subtract(one, Exp(x, Add(n, one))), sub_expr4)), domain = Natural))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\top \land \left[\forall_{m \in \mathbb{N}~|~\left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}}~\left(\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x}\right)\right], \forall_{n \in \mathbb{N}}~\left(\left(\sum_{i = 0}^{n} x^{i}\right) = \frac{1 - x^{n + 1}}{1 - x}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))], forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]
#    core type: Operation
#    operator: 24
#    operands: 3
# 2. forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))
#    core type: Operation
#    operator: 8
#    operand: 7
# 3. (TRUE, forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (n -> {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. TRUE
# ...
