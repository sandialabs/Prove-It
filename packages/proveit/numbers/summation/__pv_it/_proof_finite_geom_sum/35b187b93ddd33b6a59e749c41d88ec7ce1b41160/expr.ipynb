# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, m, n, x
from proveit.logic import And, Equals, Forall, Implies, TRUE
from proveit.numbers import Add, Exp, Interval, Natural, Sum, frac, one, subtract, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(x, i)
sub_expr3 = Add(m, one)
sub_expr4 = subtract(one, x)
expr = Implies(And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, sub_expr3)), frac(subtract(one, Exp(x, Add(m, two))), sub_expr4)), domain = Natural, condition = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, m)), frac(subtract(one, Exp(x, sub_expr3)), sub_expr4)))), Forall(instance_param_or_params = [n], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(zero, n)), frac(subtract(one, Exp(x, Add(n, one))), sub_expr4)), domain = Natural))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\top \land \left[\forall_{m \in \mathbb{N}~|~\left(\sum_{i = 0}^{m} x^{i}\right) = \frac{1 - x^{m + 1}}{1 - x}}~\left(\left(\sum_{i = 0}^{m + 1} x^{i}\right) = \frac{1 - x^{m + 2}}{1 - x}\right)\right]\right) \Rightarrow \left[\forall_{n \in \mathbb{N}}~\left(\left(\sum_{i = 0}^{n} x^{i}\right) = \frac{1 - x^{n + 1}}{1 - x}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]) => [forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))], forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]
#    core type: Operation
#    operator: 26
#    operands: 5
# 4. forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))
#    core type: Operation
#    operator: 10
#    operand: 9
# 5. (TRUE, forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (n -> {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. TRUE
#    core type: Literal
#    sub-expressions:
# 8. forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. n -> {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if n in Natural.
#    core type: Lambda
#    parameter: 93
#    body: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. (m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (n)
#     core type: ExprTuple
#     sub-expressions: 93
# 13. {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if n in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. m -> {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#     core type: Lambda
#     parameter: 105
#     body: 18
# 15. (Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))
#     core type: Operation
#     operator: 39
#     operands: 19
# 16. n in Natural
#     core type: Operation
#     operator: 83
#     operands: 20
# 17. (m)
#     core type: ExprTuple
#     sub-expressions: 105
# 18. {(Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)) if m in Natural ,  (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. (Sum_{i = 0}^{n} x^{i}, (1 - x^{n + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 93, 45
# 21. (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
#     core type: Operation
#     operator: 39
#     operands: 25
# 22. (m in Natural) and ((Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Sum_{i = 0}^{n} x^{i}
#     core type: Operation
#     operator: 52
#     operand: 34
# 24. (1 - x^{n + 1}) / (1 - x)
#     core type: Operation
#     operator: 54
#     operands: 29
# 25. (Sum_{i = 0}^{m + 1} x^{i}, (1 - x^{m + 2}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. (i -> {x^{i} if i in {0 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. (1 - x^{n + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 35, 62
# 30. Sum_{i = 0}^{m + 1} x^{i}
#     core type: Operation
#     operator: 52
#     operand: 43
# 31. (1 - x^{m + 2}) / (1 - x)
#     core type: Operation
#     operator: 54
#     operands: 37
# 32. m in Natural
#     core type: Operation
#     operator: 83
#     operands: 38
# 33. (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. i -> {x^{i} if i in {0 .. n}.
#     core type: Lambda
#     parameter: 90
#     body: 41
# 35. 1 - x^{n + 1}
#     core type: Operation
#     operator: 103
#     operands: 42
# 36. (i -> {x^{i} if i in {0 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 43
# 37. (1 - x^{m + 2}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 44, 62
# 38. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 105, 45
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. (Sum_{i = 0}^{m} x^{i}, (1 - x^{m + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 41. {x^{i} if i in {0 .. n}.
#     core type: Conditional
#     value: 75
#     condition: 48
# 42. (1, -x^{n + 1})
#     core type: ExprTuple
#     sub-expressions: 106, 49
# 43. i -> {x^{i} if i in {0 .. m + 1}.
#     core type: Lambda
#     parameter: 90
#     body: 50
# 44. 1 - x^{m + 2}
#     core type: Operation
#     operator: 103
#     operands: 51
# 45. Natural
#     core type: Literal
#     sub-expressions:
# 46. Sum_{i = 0}^{m} x^{i}
#     core type: Operation
#     operator: 52
#     operand: 60
# 47. (1 - x^{m + 1}) / (1 - x)
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. i in {0 .. n}
#     core type: Operation
#     operator: 83
#     operands: 56
# 49. -x^{n + 1}
#     core type: Operation
#     operator: 86
#     operand: 64
# 50. {x^{i} if i in {0 .. m + 1}.
#     core type: Conditional
#     value: 75
#     condition: 58
# 51. (1, -x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 106, 59
# 52. Sum
#     core type: Literal
#     sub-expressions:
# 53. (i -> {x^{i} if i in {0 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. /
#     core type: Literal
#     sub-expressions:
# 55. (1 - x^{m + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 56. (i, {0 .. n})
#     core type: ExprTuple
#     sub-expressions: 90, 63
# 57. (x^{n + 1})
#     core type: ExprTuple
#     sub-expressions: 64
# 58. i in {0 .. m + 1}
#     core type: Operation
#     operator: 83
#     operands: 65
# 59. -x^{m + 2}
#     core type: Operation
#     operator: 86
#     operand: 74
# 60. i -> {x^{i} if i in {0 .. m}.
#     core type: Lambda
#     parameter: 90
#     body: 68
# 61. 1 - x^{m + 1}
#     core type: Operation
#     operator: 103
#     operands: 69
# 62. 1 - x
#     core type: Operation
#     operator: 103
#     operands: 70
# 63. {0 .. n}
#     core type: Operation
#     operator: 95
#     operands: 71
# 64. x^{n + 1}
#     core type: Operation
#     operator: 97
#     operands: 72
# 65. (i, {0 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 90, 73
# 66. (x^{m + 2})
#     core type: ExprTuple
#     sub-expressions: 74
# 67. (i)
#     core type: ExprTuple
#     sub-expressions: 90
# 68. {x^{i} if i in {0 .. m}.
#     core type: Conditional
#     value: 75
#     condition: 76
# 69. (1, -x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 106, 77
# 70. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 106, 78
# 71. (0, n)
#     core type: ExprTuple
#     sub-expressions: 100, 93
# 72. (x, n + 1)
#     core type: ExprTuple
#     sub-expressions: 101, 79
# 73. {0 .. m + 1}
#     core type: Operation
#     operator: 95
#     operands: 80
# 74. x^{m + 2}
#     core type: Operation
#     operator: 97
#     operands: 81
# 75. x^{i}
#     core type: Operation
#     operator: 97
#     operands: 82
# 76. i in {0 .. m}
#     core type: Operation
#     operator: 83
#     operands: 84
# 77. -x^{m + 1}
#     core type: Operation
#     operator: 86
#     operand: 92
# 78. -x
#     core type: Operation
#     operator: 86
#     operand: 101
# 79. n + 1
#     core type: Operation
#     operator: 103
#     operands: 88
# 80. (0, m + 1)
#     core type: ExprTuple
#     sub-expressions: 100, 102
# 81. (x, m + 2)
#     core type: ExprTuple
#     sub-expressions: 101, 89
# 82. (x, i)
#     core type: ExprTuple
#     sub-expressions: 101, 90
# 83. in
#     core type: Literal
#     sub-expressions:
# 84. (i, {0 .. m})
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 85. (x^{m + 1})
#     core type: ExprTuple
#     sub-expressions: 92
# 86. -
#     core type: Literal
#     sub-expressions:
# 87. (x)
#     core type: ExprTuple
#     sub-expressions: 101
# 88. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 93, 106
# 89. m + 2
#     core type: Operation
#     operator: 103
#     operands: 94
# 90. i
#     core type: Variable
#     sub-expressions:
# 91. {0 .. m}
#     core type: Operation
#     operator: 95
#     operands: 96
# 92. x^{m + 1}
#     core type: Operation
#     operator: 97
#     operands: 98
# 93. n
#     core type: Variable
#     sub-expressions:
# 94. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 105, 99
# 95. Interval
#     core type: Literal
#     sub-expressions:
# 96. (0, m)
#     core type: ExprTuple
#     sub-expressions: 100, 105
# 97. Exp
#     core type: Literal
#     sub-expressions:
# 98. (x, m + 1)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. 2
#     core type: Literal
#     sub-expressions:
# 100. 0
#      core type: Literal
#      sub-expressions:
# 101. x
#      core type: Variable
#      sub-expressions:
# 102. m + 1
#      core type: Operation
#      operator: 103
#      operands: 104
# 103. +
#      core type: Literal
#      sub-expressions:
# 104. (m, 1)
#      core type: ExprTuple
#      sub-expressions: 105, 106
# 105. m
#      core type: Variable
#      sub-expressions:
# 106. 1
#      core type: Literal
#      sub-expressions:
