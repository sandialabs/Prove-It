# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Forall(instance_param_or_params = [a, b, c], instance_expr = Forall(instance_param_or_params = [alpha], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(Add(b, one), c))))), domain = Integer, condition = And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left[\forall_{\alpha}~\left(\left(\sum_{k = a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k = a}^{b} \alpha_{k}\right) + \left(\sum_{k = b + 1}^{c} \alpha_{k}\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer | a <= b <= c} [forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a, b, c) -> {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b, c) -> {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 62, 67, 64
# 4. {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 20
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 10. alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#     core type: Lambda
#     parameter: 52
#     body: 16
# 11. a in Integer
#     core type: Operation
#     operator: 54
#     operands: 17
# 12. b in Integer
#     core type: Operation
#     operator: 54
#     operands: 18
# 13. c in Integer
#     core type: Operation
#     operator: 54
#     operands: 19
# 14. a <= b <= c
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (alpha)
#     core type: ExprTuple
#     sub-expressions: 52
# 16. (Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 24
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 67, 24
# 19. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (Sum_{k = a}^{c} alpha_{k}, (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. Integer
#     core type: Literal
#     sub-expressions:
# 25. a <= b
#     core type: Operation
#     operator: 29
#     operands: 59
# 26. b <= c
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. Sum_{k = a}^{c} alpha_{k}
#     core type: Operation
#     operator: 38
#     operand: 33
# 28. (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})
#     core type: Operation
#     operator: 65
#     operands: 32
# 29. <=
#     core type: Literal
#     sub-expressions:
# 30. (b, c)
#     core type: ExprTuple
#     sub-expressions: 67, 64
# 31. (k -> {alpha_{k} if k in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 32. (Sum_{k = a}^{b} alpha_{k}, Sum_{k = b + 1}^{c} alpha_{k})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. k -> {alpha_{k} if k in {a .. c}.
#     core type: Lambda
#     parameter: 57
#     body: 36
# 34. Sum_{k = a}^{b} alpha_{k}
#     core type: Operation
#     operator: 38
#     operand: 41
# 35. Sum_{k = b + 1}^{c} alpha_{k}
#     core type: Operation
#     operator: 38
#     operand: 42
# 36. {alpha_{k} if k in {a .. c}.
#     core type: Conditional
#     value: 48
#     condition: 40
# 37. (k -> {alpha_{k} if k in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. Sum
#     core type: Literal
#     sub-expressions:
# 39. (k -> {alpha_{k} if k in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. k in {a .. c}
#     core type: Operation
#     operator: 54
#     operands: 43
# 41. k -> {alpha_{k} if k in {a .. b}.
#     core type: Lambda
#     parameter: 57
#     body: 44
# 42. k -> {alpha_{k} if k in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 57
#     body: 45
# 43. (k, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 57, 46
# 44. {alpha_{k} if k in {a .. b}.
#     core type: Conditional
#     value: 48
#     condition: 47
# 45. {alpha_{k} if k in {b + 1 .. c}.
#     core type: Conditional
#     value: 48
#     condition: 49
# 46. {a .. c}
#     core type: Operation
#     operator: 60
#     operands: 50
# 47. k in {a .. b}
#     core type: Operation
#     operator: 54
#     operands: 51
# 48. alpha_{k}
#     core type: IndexedVar
# variable: 52
# index: 57
# 49. k in {b + 1 .. c}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. (a, c)
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 51. (k, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 52. alpha
#     core type: Variable
#     sub-expressions:
# 53. (k)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (k, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. {a .. b}
#     core type: Operation
#     operator: 60
#     operands: 59
# 57. k
#     core type: Variable
#     sub-expressions:
# 58. {b + 1 .. c}
#     core type: Operation
#     operator: 60
#     operands: 61
# 59. (a, b)
#     core type: ExprTuple
#     sub-expressions: 62, 67
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. b + 1
#     core type: Operation
#     operator: 65
#     operands: 66
# 64. c
#     core type: Variable
#     sub-expressions:
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. b
#     core type: Variable
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
