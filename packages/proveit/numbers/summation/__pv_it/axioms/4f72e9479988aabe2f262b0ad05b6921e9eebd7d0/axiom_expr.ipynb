# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#sum_split_last">sum_split_last</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import sum_split_last

# %%
# check that the built expression is the same as the stored expression
assert sum_split_last.expr == stored_expr
assert sum_split_last.expr._style_id == stored_expr._style_id
print("Passed sanity check: sum_split_last matches stored_expr")
# Out:
# Passed sanity check: sum_split_last matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) = \left(\left(\sum_{x = a}^{b - 1} f\left(x\right)\right) + f\left(b\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (f -> [forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)))]
#    core type: Lambda
#    parameter: 41
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 41
# 4. forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {(Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (a, b) -> {(Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Lambda
#    parameters: 40\n   body: 8
# 8. {(Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in Integer) and (b in Integer) and (a < b)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Sum_{x = a}^{b} f(x), (Sum_{x = a}^{b - 1} f(x)) + f(b))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in Integer, b in Integer, a < b)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 15. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 30
#     operand: 25
# 16. (Sum_{x = a}^{b - 1} f(x)) + f(b)
#     core type: Operation
#     operator: 51
#     operands: 21
# 17. a in Integer
#     core type: Operation
#     operator: 43
#     operands: 22
# 18. b in Integer
#     core type: Operation
#     operator: 43
#     operands: 23
# 19. a < b
#     core type: Operation
#     operator: 24
#     operands: 40
# 20. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. (Sum_{x = a}^{b - 1} f(x), f(b))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 49, 28
# 23. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 53, 28
# 24. <
#     core type: Literal
#     sub-expressions:
# 25. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 45
#     body: 29
# 26. Sum_{x = a}^{b - 1} f(x)
#     core type: Operation
#     operator: 30
#     operand: 34
# 27. f(b)
#     core type: Operation
#     operator: 41
#     operand: 53
# 28. Integer
#     core type: Literal
#     sub-expressions:
# 29. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 38
#     condition: 33
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (x -> {f(x) if x in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. (b)
#     core type: ExprTuple
#     sub-expressions: 53
# 33. x in {a .. b}
#     core type: Operation
#     operator: 43
#     operands: 35
# 34. x -> {f(x) if x in {a .. b - 1}.
#     core type: Lambda
#     parameter: 45
#     body: 36
# 35. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 45, 37
# 36. {f(x) if x in {a .. b - 1}.
#     core type: Conditional
#     value: 38
#     condition: 39
# 37. {a .. b}
#     core type: Operation
#     operator: 47
#     operands: 40
# 38. f(x)
#     core type: Operation
#     operator: 41
#     operand: 45
# 39. x in {a .. b - 1}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (a, b)
#     core type: ExprTuple
#     sub-expressions: 49, 53
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (x, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. {a .. b - 1}
#     core type: Operation
#     operator: 47
#     operands: 48
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 49. a
#     core type: Variable
#     sub-expressions:
# 50. b - 1
#     core type: Operation
#     operator: 51
#     operands: 52
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. -1
#     core type: Operation
#     operator: 55
#     operand: 57
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (1)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. 1
#     core type: Literal
#     sub-expressions:
