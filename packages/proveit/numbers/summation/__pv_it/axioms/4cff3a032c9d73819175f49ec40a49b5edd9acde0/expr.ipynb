# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = ExprTuple(Lambda([a, b, c], Conditional(Forall(instance_param_or_params = [alpha], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(Add(b, one), c))))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\forall_{\alpha}~\left(\left(\sum_{k = a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k = a}^{b} \alpha_{k}\right) + \left(\sum_{k = b + 1}^{c} \alpha_{k}\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a, b, c) -> {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 61, 66, 63
# 3. {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#    core type: Lambda
#    parameter: 51
#    body: 15
# 10. a in Integer
#     core type: Operation
#     operator: 53
#     operands: 16
# 11. b in Integer
#     core type: Operation
#     operator: 53
#     operands: 17
# 12. c in Integer
#     core type: Operation
#     operator: 53
#     operands: 18
# 13. a <= b <= c
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (alpha)
#     core type: ExprTuple
#     sub-expressions: 51
# 15. (Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 23
# 17. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 66, 23
# 18. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 23
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (Sum_{k = a}^{c} alpha_{k}, (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. Integer
#     core type: Literal
#     sub-expressions:
# 24. a <= b
#     core type: Operation
#     operator: 28
#     operands: 58
# 25. b <= c
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. Sum_{k = a}^{c} alpha_{k}
#     core type: Operation
#     operator: 37
#     operand: 32
# 27. (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})
#     core type: Operation
#     operator: 64
#     operands: 31
# 28. <=
#     core type: Literal
#     sub-expressions:
# 29. (b, c)
#     core type: ExprTuple
#     sub-expressions: 66, 63
# 30. (k -> {alpha_{k} if k in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. (Sum_{k = a}^{b} alpha_{k}, Sum_{k = b + 1}^{c} alpha_{k})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. k -> {alpha_{k} if k in {a .. c}.
#     core type: Lambda
#     parameter: 56
#     body: 35
# 33. Sum_{k = a}^{b} alpha_{k}
#     core type: Operation
#     operator: 37
#     operand: 40
# 34. Sum_{k = b + 1}^{c} alpha_{k}
#     core type: Operation
#     operator: 37
#     operand: 41
# 35. {alpha_{k} if k in {a .. c}.
#     core type: Conditional
#     value: 47
#     condition: 39
# 36. (k -> {alpha_{k} if k in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. Sum
#     core type: Literal
#     sub-expressions:
# 38. (k -> {alpha_{k} if k in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. k in {a .. c}
#     core type: Operation
#     operator: 53
#     operands: 42
# 40. k -> {alpha_{k} if k in {a .. b}.
#     core type: Lambda
#     parameter: 56
#     body: 43
# 41. k -> {alpha_{k} if k in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 56
#     body: 44
# 42. (k, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 56, 45
# 43. {alpha_{k} if k in {a .. b}.
#     core type: Conditional
#     value: 47
#     condition: 46
# 44. {alpha_{k} if k in {b + 1 .. c}.
#     core type: Conditional
#     value: 47
#     condition: 48
# 45. {a .. c}
#     core type: Operation
#     operator: 59
#     operands: 49
# 46. k in {a .. b}
#     core type: Operation
#     operator: 53
#     operands: 50
# 47. alpha_{k}
#     core type: IndexedVar
# variable: 51
# index: 56
# 48. k in {b + 1 .. c}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. (a, c)
#     core type: ExprTuple
#     sub-expressions: 61, 63
# 50. (k, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 51. alpha
#     core type: Variable
#     sub-expressions:
# 52. (k)
#     core type: ExprTuple
#     sub-expressions: 56
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (k, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. {a .. b}
#     core type: Operation
#     operator: 59
#     operands: 58
# 56. k
#     core type: Variable
#     sub-expressions:
# 57. {b + 1 .. c}
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. (a, b)
#     core type: ExprTuple
#     sub-expressions: 61, 66
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. b + 1
#     core type: Operation
#     operator: 64
#     operands: 65
# 63. c
#     core type: Variable
#     sub-expressions:
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. b
#     core type: Variable
#     sub-expressions:
# 67. 1
#     core type: Literal
#     sub-expressions:
