# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Conditional(Forall(instance_param_or_params = [alpha], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = alpha_k, domain = Interval(Add(b, one), c))))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{\alpha}~\left(\left(\sum_{k = a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k = a}^{b} \alpha_{k}\right) + \left(\sum_{k = b + 1}^{c} \alpha_{k}\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{alpha} ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 6. alpha -> ((Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})))
#    core type: Lambda
#    parameter: 48
#    body: 12
# 7. a in Integer
#    core type: Operation
#    operator: 50
#    operands: 13
# 8. b in Integer
#    core type: Operation
#    operator: 50
#    operands: 14
# 9. c in Integer
#    core type: Operation
#    operator: 50
#    operands: 15
# 10. a <= b <= c
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. (alpha)
#     core type: ExprTuple
#     sub-expressions: 48
# 12. (Sum_{k = a}^{c} alpha_{k}) = ((Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 20
# 14. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 20
# 15. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 20
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (Sum_{k = a}^{c} alpha_{k}, (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. a <= b
#     core type: Operation
#     operator: 25
#     operands: 55
# 22. b <= c
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. Sum_{k = a}^{c} alpha_{k}
#     core type: Operation
#     operator: 34
#     operand: 29
# 24. (Sum_{k = a}^{b} alpha_{k}) + (Sum_{k = b + 1}^{c} alpha_{k})
#     core type: Operation
#     operator: 61
#     operands: 28
# 25. <=
#     core type: Literal
#     sub-expressions:
# 26. (b, c)
#     core type: ExprTuple
#     sub-expressions: 63, 60
# 27. (k -> {alpha_{k} if k in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 29
# 28. (Sum_{k = a}^{b} alpha_{k}, Sum_{k = b + 1}^{c} alpha_{k})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. k -> {alpha_{k} if k in {a .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 32
# 30. Sum_{k = a}^{b} alpha_{k}
#     core type: Operation
#     operator: 34
#     operand: 37
# 31. Sum_{k = b + 1}^{c} alpha_{k}
#     core type: Operation
#     operator: 34
#     operand: 38
# 32. {alpha_{k} if k in {a .. c}.
#     core type: Conditional
#     value: 44
#     condition: 36
# 33. (k -> {alpha_{k} if k in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (k -> {alpha_{k} if k in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. k in {a .. c}
#     core type: Operation
#     operator: 50
#     operands: 39
# 37. k -> {alpha_{k} if k in {a .. b}.
#     core type: Lambda
#     parameter: 53
#     body: 40
# 38. k -> {alpha_{k} if k in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 41
# 39. (k, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 42
# 40. {alpha_{k} if k in {a .. b}.
#     core type: Conditional
#     value: 44
#     condition: 43
# 41. {alpha_{k} if k in {b + 1 .. c}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. {a .. c}
#     core type: Operation
#     operator: 56
#     operands: 46
# 43. k in {a .. b}
#     core type: Operation
#     operator: 50
#     operands: 47
# 44. alpha_{k}
#     core type: IndexedVar
# variable: 48
# index: 53
# 45. k in {b + 1 .. c}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (a, c)
#     core type: ExprTuple
#     sub-expressions: 58, 60
# 47. (k, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 48. alpha
#     core type: Variable
#     sub-expressions:
# 49. (k)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (k, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. {a .. b}
#     core type: Operation
#     operator: 56
#     operands: 55
# 53. k
#     core type: Variable
#     sub-expressions:
# 54. {b + 1 .. c}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. (a, b)
#     core type: ExprTuple
#     sub-expressions: 58, 63
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. b + 1
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
