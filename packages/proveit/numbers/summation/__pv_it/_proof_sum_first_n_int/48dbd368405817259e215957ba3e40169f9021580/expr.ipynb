# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m, n
from proveit.logic import And, Equals, Forall, Implies, TRUE
from proveit.numbers import Add, Interval, Mult, NaturalPos, Sum, frac, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(m, one)
expr = Implies(And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, sub_expr2)), frac(Mult(sub_expr2, Add(m, two)), two)), domain = NaturalPos, condition = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, m)), frac(Mult(m, sub_expr2), two)))), Forall(instance_param_or_params = [n], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, n)), frac(Mult(n, Add(n, one)), two)), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\top \land \left[\forall_{m \in \mathbb{N}^+~|~\left(\sum_{k = 1}^{m} k\right) = \frac{m \cdot \left(m + 1\right)}{2}}~\left(\left(\sum_{k = 1}^{m + 1} k\right) = \frac{\left(m + 1\right) \cdot \left(m + 2\right)}{2}\right)\right]\right) \Rightarrow \left[\forall_{n \in \mathbb{N}^+}~\left(\left(\sum_{k = 1}^{n} k\right) = \frac{n \cdot \left(n + 1\right)}{2}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))]) => [forall_{n in NaturalPos} ((Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))], forall_{n in NaturalPos} ((Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))]
#    core type: Operation
#    operator: 26
#    operands: 5
# 4. forall_{n in NaturalPos} ((Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2))
#    core type: Operation
#    operator: 10
#    operand: 9
# 5. (TRUE, forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (n -> {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. TRUE
#    core type: Literal
#    sub-expressions:
# 8. forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. n -> {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#    core type: Lambda
#    parameter: 73
#    body: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. (m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (n)
#     core type: ExprTuple
#     sub-expressions: 73
# 13. {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#     core type: Lambda
#     parameter: 85
#     body: 18
# 15. (Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2)
#     core type: Operation
#     operator: 39
#     operands: 19
# 16. n in NaturalPos
#     core type: Operation
#     operator: 75
#     operands: 20
# 17. (m)
#     core type: ExprTuple
#     sub-expressions: 85
# 18. {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. (Sum_{k = 1}^{n} k, (n * (n + 1)) / 2)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 73, 45
# 21. (Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)
#     core type: Operation
#     operator: 39
#     operands: 25
# 22. (m in NaturalPos) and ((Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Sum_{k = 1}^{n} k
#     core type: Operation
#     operator: 52
#     operand: 34
# 24. (n * (n + 1)) / 2
#     core type: Operation
#     operator: 54
#     operands: 29
# 25. (Sum_{k = 1}^{m + 1} k, ((m + 1) * (m + 2)) / 2)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (m in NaturalPos, (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. (k -> {k if k in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. (n * (n + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 35, 71
# 30. Sum_{k = 1}^{m + 1} k
#     core type: Operation
#     operator: 52
#     operand: 43
# 31. ((m + 1) * (m + 2)) / 2
#     core type: Operation
#     operator: 54
#     operands: 37
# 32. m in NaturalPos
#     core type: Operation
#     operator: 75
#     operands: 38
# 33. (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. k -> {k if k in {1 .. n}.
#     core type: Lambda
#     parameter: 78
#     body: 41
# 35. n * (n + 1)
#     core type: Operation
#     operator: 67
#     operands: 42
# 36. (k -> {k if k in {1 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 43
# 37. ((m + 1) * (m + 2), 2)
#     core type: ExprTuple
#     sub-expressions: 44, 71
# 38. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 85, 45
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. (Sum_{k = 1}^{m} k, (m * (m + 1)) / 2)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 41. {k if k in {1 .. n}.
#     core type: Conditional
#     value: 78
#     condition: 48
# 42. (n, n + 1)
#     core type: ExprTuple
#     sub-expressions: 73, 49
# 43. k -> {k if k in {1 .. m + 1}.
#     core type: Lambda
#     parameter: 78
#     body: 50
# 44. (m + 1) * (m + 2)
#     core type: Operation
#     operator: 67
#     operands: 51
# 45. NaturalPos
#     core type: Literal
#     sub-expressions:
# 46. Sum_{k = 1}^{m} k
#     core type: Operation
#     operator: 52
#     operand: 60
# 47. (m * (m + 1)) / 2
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. k in {1 .. n}
#     core type: Operation
#     operator: 75
#     operands: 56
# 49. n + 1
#     core type: Operation
#     operator: 80
#     operands: 57
# 50. {k if k in {1 .. m + 1}.
#     core type: Conditional
#     value: 78
#     condition: 58
# 51. (m + 1, m + 2)
#     core type: ExprTuple
#     sub-expressions: 77, 59
# 52. Sum
#     core type: Literal
#     sub-expressions:
# 53. (k -> {k if k in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. /
#     core type: Literal
#     sub-expressions:
# 55. (m * (m + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 61, 71
# 56. (k, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 78, 62
# 57. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 84
# 58. k in {1 .. m + 1}
#     core type: Operation
#     operator: 75
#     operands: 63
# 59. m + 2
#     core type: Operation
#     operator: 80
#     operands: 64
# 60. k -> {k if k in {1 .. m}.
#     core type: Lambda
#     parameter: 78
#     body: 66
# 61. m * (m + 1)
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. {1 .. n}
#     core type: Operation
#     operator: 82
#     operands: 69
# 63. (k, {1 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 78, 70
# 64. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 85, 71
# 65. (k)
#     core type: ExprTuple
#     sub-expressions: 78
# 66. {k if k in {1 .. m}.
#     core type: Conditional
#     value: 78
#     condition: 72
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (m, m + 1)
#     core type: ExprTuple
#     sub-expressions: 85, 77
# 69. (1, n)
#     core type: ExprTuple
#     sub-expressions: 84, 73
# 70. {1 .. m + 1}
#     core type: Operation
#     operator: 82
#     operands: 74
# 71. 2
#     core type: Literal
#     sub-expressions:
# 72. k in {1 .. m}
#     core type: Operation
#     operator: 75
#     operands: 76
# 73. n
#     core type: Variable
#     sub-expressions:
# 74. (1, m + 1)
#     core type: ExprTuple
#     sub-expressions: 84, 77
# 75. in
#     core type: Literal
#     sub-expressions:
# 76. (k, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 77. m + 1
#     core type: Operation
#     operator: 80
#     operands: 81
# 78. k
#     core type: Variable
#     sub-expressions:
# 79. {1 .. m}
#     core type: Operation
#     operator: 82
#     operands: 83
# 80. +
#     core type: Literal
#     sub-expressions:
# 81. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 85, 84
# 82. Interval
#     core type: Literal
#     sub-expressions:
# 83. (1, m)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 84. 1
#     core type: Literal
#     sub-expressions:
# 85. m
#     core type: Variable
#     sub-expressions:
