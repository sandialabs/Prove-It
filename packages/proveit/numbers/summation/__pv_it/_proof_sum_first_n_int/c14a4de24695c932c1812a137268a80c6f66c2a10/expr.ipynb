# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, m, n
from proveit.logic import And, Equals, Forall, TRUE
from proveit.numbers import Add, Interval, Mult, NaturalPos, Sum, frac, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(m, one)
expr = ExprTuple(And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, sub_expr2)), frac(Mult(sub_expr2, Add(m, two)), two)), domain = NaturalPos, condition = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, m)), frac(Mult(m, sub_expr2), two)))), Forall(instance_param_or_params = [n], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, n)), frac(Mult(n, Add(n, one)), two)), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\top \land \left[\forall_{m \in \mathbb{N}^+~|~\left(\sum_{k = 1}^{m} k\right) = \frac{m \cdot \left(m + 1\right)}{2}}~\left(\left(\sum_{k = 1}^{m + 1} k\right) = \frac{\left(m + 1\right) \cdot \left(m + 2\right)}{2}\right)\right], \forall_{n \in \mathbb{N}^+}~\left(\left(\sum_{k = 1}^{n} k\right) = \frac{n \cdot \left(n + 1\right)}{2}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))], forall_{n in NaturalPos} ((Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))]
#    core type: Operation
#    operator: 24
#    operands: 3
# 2. forall_{n in NaturalPos} ((Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2))
#    core type: Operation
#    operator: 8
#    operand: 7
# 3. (TRUE, forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (n -> {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. TRUE
#    core type: Literal
#    sub-expressions:
# 6. forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))
#    core type: Operation
#    operator: 8
#    operand: 12
# 7. n -> {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#    core type: Lambda
#    parameter: 71
#    body: 11
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 71
# 11. {(Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#     core type: Lambda
#     parameter: 83
#     body: 16
# 13. (Sum_{k = 1}^{n} k) = ((n * (n + 1)) / 2)
#     core type: Operation
#     operator: 37
#     operands: 17
# 14. n in NaturalPos
#     core type: Operation
#     operator: 73
#     operands: 18
# 15. (m)
#     core type: ExprTuple
#     sub-expressions: 83
# 16. {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. (Sum_{k = 1}^{n} k, (n * (n + 1)) / 2)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 71, 43
# 19. (Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)
#     core type: Operation
#     operator: 37
#     operands: 23
# 20. (m in NaturalPos) and ((Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Sum_{k = 1}^{n} k
#     core type: Operation
#     operator: 50
#     operand: 32
# 22. (n * (n + 1)) / 2
#     core type: Operation
#     operator: 52
#     operands: 27
# 23. (Sum_{k = 1}^{m + 1} k, ((m + 1) * (m + 2)) / 2)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (m in NaturalPos, (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. (k -> {k if k in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 27. (n * (n + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 33, 69
# 28. Sum_{k = 1}^{m + 1} k
#     core type: Operation
#     operator: 50
#     operand: 41
# 29. ((m + 1) * (m + 2)) / 2
#     core type: Operation
#     operator: 52
#     operands: 35
# 30. m in NaturalPos
#     core type: Operation
#     operator: 73
#     operands: 36
# 31. (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. k -> {k if k in {1 .. n}.
#     core type: Lambda
#     parameter: 76
#     body: 39
# 33. n * (n + 1)
#     core type: Operation
#     operator: 65
#     operands: 40
# 34. (k -> {k if k in {1 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 35. ((m + 1) * (m + 2), 2)
#     core type: ExprTuple
#     sub-expressions: 42, 69
# 36. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 83, 43
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (Sum_{k = 1}^{m} k, (m * (m + 1)) / 2)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 39. {k if k in {1 .. n}.
#     core type: Conditional
#     value: 76
#     condition: 46
# 40. (n, n + 1)
#     core type: ExprTuple
#     sub-expressions: 71, 47
# 41. k -> {k if k in {1 .. m + 1}.
#     core type: Lambda
#     parameter: 76
#     body: 48
# 42. (m + 1) * (m + 2)
#     core type: Operation
#     operator: 65
#     operands: 49
# 43. NaturalPos
#     core type: Literal
#     sub-expressions:
# 44. Sum_{k = 1}^{m} k
#     core type: Operation
#     operator: 50
#     operand: 58
# 45. (m * (m + 1)) / 2
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. k in {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 54
# 47. n + 1
#     core type: Operation
#     operator: 78
#     operands: 55
# 48. {k if k in {1 .. m + 1}.
#     core type: Conditional
#     value: 76
#     condition: 56
# 49. (m + 1, m + 2)
#     core type: ExprTuple
#     sub-expressions: 75, 57
# 50. Sum
#     core type: Literal
#     sub-expressions:
# 51. (k -> {k if k in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. /
#     core type: Literal
#     sub-expressions:
# 53. (m * (m + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 59, 69
# 54. (k, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 76, 60
# 55. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 71, 82
# 56. k in {1 .. m + 1}
#     core type: Operation
#     operator: 73
#     operands: 61
# 57. m + 2
#     core type: Operation
#     operator: 78
#     operands: 62
# 58. k -> {k if k in {1 .. m}.
#     core type: Lambda
#     parameter: 76
#     body: 64
# 59. m * (m + 1)
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. {1 .. n}
#     core type: Operation
#     operator: 80
#     operands: 67
# 61. (k, {1 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 76, 68
# 62. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 83, 69
# 63. (k)
#     core type: ExprTuple
#     sub-expressions: 76
# 64. {k if k in {1 .. m}.
#     core type: Conditional
#     value: 76
#     condition: 70
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (m, m + 1)
#     core type: ExprTuple
#     sub-expressions: 83, 75
# 67. (1, n)
#     core type: ExprTuple
#     sub-expressions: 82, 71
# 68. {1 .. m + 1}
#     core type: Operation
#     operator: 80
#     operands: 72
# 69. 2
#     core type: Literal
#     sub-expressions:
# 70. k in {1 .. m}
#     core type: Operation
#     operator: 73
#     operands: 74
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. (1, m + 1)
#     core type: ExprTuple
#     sub-expressions: 82, 75
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (k, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 75. m + 1
#     core type: Operation
#     operator: 78
#     operands: 79
# 76. k
#     core type: Variable
#     sub-expressions:
# 77. {1 .. m}
#     core type: Operation
#     operator: 80
#     operands: 81
# 78. +
#     core type: Literal
#     sub-expressions:
# 79. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 83, 82
# 80. Interval
#     core type: Literal
#     sub-expressions:
# 81. (1, m)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 82. 1
#     core type: Literal
#     sub-expressions:
# 83. m
#     core type: Variable
#     sub-expressions:
