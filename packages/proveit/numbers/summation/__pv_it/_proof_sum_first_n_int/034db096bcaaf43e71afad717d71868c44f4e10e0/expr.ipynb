# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import And, Equals, Forall, TRUE
from proveit.numbers import Add, Interval, Mult, NaturalPos, Sum, frac, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(m, one)
expr = And(TRUE, Forall(instance_param_or_params = [m], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, sub_expr2)), frac(Mult(sub_expr2, Add(m, two)), two)), domain = NaturalPos, condition = Equals(Sum(index_or_indices = sub_expr1, summand = k, domain = Interval(one, m)), frac(Mult(m, sub_expr2), two))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \top \land \left[\forall_{m \in \mathbb{N}^+~|~\left(\sum_{k = 1}^{m} k\right) = \frac{m \cdot \left(m + 1\right)}{2}}~\left(\left(\sum_{k = 1}^{m + 1} k\right) = \frac{\left(m + 1\right) \cdot \left(m + 2\right)}{2}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. TRUE and [forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))]
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (TRUE, forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. TRUE
#    core type: Literal
#    sub-expressions:
# 3. forall_{m in NaturalPos | (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)} ((Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. m -> {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#    core type: Lambda
#    parameter: 58
#    body: 8
# 7. (m)
#    core type: ExprTuple
#    sub-expressions: 58
# 8. {(Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2) if m in NaturalPos ,  (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (Sum_{k = 1}^{m + 1} k) = (((m + 1) * (m + 2)) / 2)
#    core type: Operation
#    operator: 21
#    operands: 11
# 10. (m in NaturalPos) and ((Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (Sum_{k = 1}^{m + 1} k, ((m + 1) * (m + 2)) / 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (m in NaturalPos, (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Sum_{k = 1}^{m + 1} k
#     core type: Operation
#     operator: 30
#     operand: 23
# 15. ((m + 1) * (m + 2)) / 2
#     core type: Operation
#     operator: 32
#     operands: 19
# 16. m in NaturalPos
#     core type: Operation
#     operator: 48
#     operands: 20
# 17. (Sum_{k = 1}^{m} k) = ((m * (m + 1)) / 2)
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (k -> {k if k in {1 .. m + 1}.)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. ((m + 1) * (m + 2), 2)
#     core type: ExprTuple
#     sub-expressions: 24, 45
# 20. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 58, 25
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (Sum_{k = 1}^{m} k, (m * (m + 1)) / 2)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. k -> {k if k in {1 .. m + 1}.
#     core type: Lambda
#     parameter: 51
#     body: 28
# 24. (m + 1) * (m + 2)
#     core type: Operation
#     operator: 42
#     operands: 29
# 25. NaturalPos
#     core type: Literal
#     sub-expressions:
# 26. Sum_{k = 1}^{m} k
#     core type: Operation
#     operator: 30
#     operand: 36
# 27. (m * (m + 1)) / 2
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. {k if k in {1 .. m + 1}.
#     core type: Conditional
#     value: 51
#     condition: 34
# 29. (m + 1, m + 2)
#     core type: ExprTuple
#     sub-expressions: 50, 35
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (k -> {k if k in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (m * (m + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 37, 45
# 34. k in {1 .. m + 1}
#     core type: Operation
#     operator: 48
#     operands: 38
# 35. m + 2
#     core type: Operation
#     operator: 53
#     operands: 39
# 36. k -> {k if k in {1 .. m}.
#     core type: Lambda
#     parameter: 51
#     body: 41
# 37. m * (m + 1)
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. (k, {1 .. m + 1})
#     core type: ExprTuple
#     sub-expressions: 51, 44
# 39. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 58, 45
# 40. (k)
#     core type: ExprTuple
#     sub-expressions: 51
# 41. {k if k in {1 .. m}.
#     core type: Conditional
#     value: 51
#     condition: 46
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (m, m + 1)
#     core type: ExprTuple
#     sub-expressions: 58, 50
# 44. {1 .. m + 1}
#     core type: Operation
#     operator: 55
#     operands: 47
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. k in {1 .. m}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. (1, m + 1)
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (k, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. m + 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. {1 .. m}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (1, m)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. m
#     core type: Variable
#     sub-expressions:
