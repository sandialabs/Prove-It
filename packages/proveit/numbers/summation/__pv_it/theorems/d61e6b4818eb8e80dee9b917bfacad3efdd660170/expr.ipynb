# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, j, k, x
from proveit.logic import And, Equals, Forall, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Integer, Interval, LessEq, Sum, frac, one, subtract

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Forall(instance_param_or_params = [j, k], instance_expr = Equals(Sum(index_or_indices = [i], summand = Exp(x, i), domain = Interval(j, k)), frac(subtract(Exp(x, j), Exp(x, Add(k, one))), subtract(one, x))), domain = Integer, condition = LessEq(j, k)), And(InSet(x, Complex), NotEquals(x, one)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(x \mapsto \left\{\forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left(\left(\sum_{i = j}^{k} x^{i}\right) = \frac{x^{j} - x^{k + 1}}{1 - x}\right) \textrm{ if } x \in \mathbb{C} ,  x \neq 1\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (x -> {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Lambda
#    parameter: 62
#    body: 2
# 2. {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (x in Complex) and (x != 1)
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x in Complex, x != 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 58\n   body: 11
# 9. x in Complex
#    core type: Operation
#    operator: 48
#    operands: 12
# 10. x != 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 17
# 13. !=
#     core type: Literal
#     sub-expressions:
# 14. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 62, 67
# 15. (Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (j in Integer) and (k in Integer) and (j <= k)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Complex
#     core type: Literal
#     sub-expressions:
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (Sum_{i = j}^{k} x^{i}, (x^{j} - x^{k + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (j in Integer, k in Integer, j <= k)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 22. Sum_{i = j}^{k} x^{i}
#     core type: Operation
#     operator: 27
#     operand: 34
# 23. (x^{j} - x^{k + 1}) / (1 - x)
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. j in Integer
#     core type: Operation
#     operator: 48
#     operands: 31
# 25. k in Integer
#     core type: Operation
#     operator: 48
#     operands: 32
# 26. j <= k
#     core type: Operation
#     operator: 33
#     operands: 58
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (i -> {x^{i} if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (x^{j} - x^{k + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 37
# 32. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 66, 37
# 33. <=
#     core type: Literal
#     sub-expressions:
# 34. i -> {x^{i} if i in {j .. k}.
#     core type: Lambda
#     parameter: 54
#     body: 39
# 35. x^{j} - x^{k + 1}
#     core type: Operation
#     operator: 64
#     operands: 40
# 36. 1 - x
#     core type: Operation
#     operator: 64
#     operands: 41
# 37. Integer
#     core type: Literal
#     sub-expressions:
# 38. (i)
#     core type: ExprTuple
#     sub-expressions: 54
# 39. {x^{i} if i in {j .. k}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 40. (x^{j}, -x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 67, 46
# 42. x^{i}
#     core type: Operation
#     operator: 59
#     operands: 47
# 43. i in {j .. k}
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. x^{j}
#     core type: Operation
#     operator: 59
#     operands: 50
# 45. -x^{k + 1}
#     core type: Operation
#     operator: 52
#     operand: 56
# 46. -x
#     core type: Operation
#     operator: 52
#     operand: 62
# 47. (x, i)
#     core type: ExprTuple
#     sub-expressions: 62, 54
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. (x, j)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 51. (x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. {j .. k}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. x^{k + 1}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (j, k)
#     core type: ExprTuple
#     sub-expressions: 61, 66
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (x, k + 1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 61. j
#     core type: Variable
#     sub-expressions:
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. k + 1
#     core type: Operation
#     operator: 64
#     operands: 65
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. k
#     core type: Variable
#     sub-expressions:
# 67. 1
#     core type: Literal
#     sub-expressions:
