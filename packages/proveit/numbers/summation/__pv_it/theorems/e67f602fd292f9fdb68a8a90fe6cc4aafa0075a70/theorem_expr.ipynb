# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#integral_upper_bound_of_sum">integral_upper_bound_of_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import integral_upper_bound_of_sum

# %%
# check that the built expression is the same as the stored expression
assert integral_upper_bound_of_sum.expr == stored_expr
assert integral_upper_bound_of_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: integral_upper_bound_of_sum matches stored_expr")
# Out:
# Passed sanity check: integral_upper_bound_of_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{S}~\left[\forall_{f \in \textrm{MonDecFuncs}\left(S\right)~|~S \subseteq \mathbb{R}}~\left[\forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a - 1,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(\int_{a - 1}^{b} f\left(x\right)\,dx\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{S} [forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. (S -> [forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. S -> [forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]]
#    core type: Lambda
#    parameter: 46
#    body: 3
# 3. forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]
#    core type: Operation
#    operator: 10
#    operand: 5
# ...
