# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import c, d, fj, gj, j, x
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Integer, Interval, Mult, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = Forall(instance_param_or_params = [x], instance_expr = Forall(instance_param_or_params = [c, d], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = Mult(Mult(x, gj), fj), domain = sub_expr2), Mult(x, Sum(index_or_indices = sub_expr1, summand = Mult(gj, fj), domain = sub_expr2))), domain = Integer), domain = Complex)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x \in \mathbb{C}}~\left[\forall_{c, d \in \mathbb{Z}}~\left(\left(\sum_{j = c}^{d} \left(\left(x \cdot g\left(j\right)\right) \cdot f\left(j\right)\right)\right) = \left(x \cdot \left(\sum_{j = c}^{d} \left(g\left(j\right) \cdot f\left(j\right)\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x in Complex} [forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (x -> {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. x -> {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.
#    core type: Lambda
#    parameter: 45
#    body: 4
# 3. (x)
#    core type: ExprTuple
#    sub-expressions: 45
# 4. {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. x in Complex
#    core type: Operation
#    operator: 43
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((c, d) -> {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 45, 11
# 10. (c, d) -> {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.
#     core type: Lambda
#     parameters: 53\n    body: 12
# 11. Complex
#     core type: Literal
#     sub-expressions:
# 12. {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. (Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (c in Integer) and (d in Integer)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (Sum_{j = c}^{d} ((x * g(j)) * f(j)), x * (Sum_{j = c}^{d} (g(j) * f(j))))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (c in Integer, d in Integer)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Sum_{j = c}^{d} ((x * g(j)) * f(j))
#     core type: Operation
#     operator: 31
#     operand: 27
# 20. x * (Sum_{j = c}^{d} (g(j) * f(j)))
#     core type: Operation
#     operator: 41
#     operands: 24
# 21. c in Integer
#     core type: Operation
#     operator: 43
#     operands: 25
# 22. d in Integer
#     core type: Operation
#     operator: 43
#     operands: 26
# 23. (j -> {(x * g(j)) * f(j) if j in {c .. d}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (x, Sum_{j = c}^{d} (g(j) * f(j)))
#     core type: ExprTuple
#     sub-expressions: 45, 28
# 25. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 29
# 26. (d, Integer)
#     core type: ExprTuple
#     sub-expressions: 56, 29
# 27. j -> {(x * g(j)) * f(j) if j in {c .. d}.
#     core type: Lambda
#     parameter: 54
#     body: 30
# 28. Sum_{j = c}^{d} (g(j) * f(j))
#     core type: Operation
#     operator: 31
#     operand: 34
# 29. Integer
#     core type: Literal
#     sub-expressions:
# 30. {(x * g(j)) * f(j) if j in {c .. d}.
#     core type: Conditional
#     value: 33
#     condition: 39
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (j -> {g(j) * f(j) if j in {c .. d}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 33. (x * g(j)) * f(j)
#     core type: Operation
#     operator: 41
#     operands: 35
# 34. j -> {g(j) * f(j) if j in {c .. d}.
#     core type: Lambda
#     parameter: 54
#     body: 36
# 35. (x * g(j), f(j))
#     core type: ExprTuple
#     sub-expressions: 37, 47
# 36. {g(j) * f(j) if j in {c .. d}.
#     core type: Conditional
#     value: 38
#     condition: 39
# 37. x * g(j)
#     core type: Operation
#     operator: 41
#     operands: 40
# 38. g(j) * f(j)
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. j in {c .. d}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (x, g(j))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (g(j), f(j))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (j, {c .. d})
#     core type: ExprTuple
#     sub-expressions: 54, 48
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. g(j)
#     core type: Operation
#     operator: 49
#     operand: 54
# 47. f(j)
#     core type: Operation
#     operator: 50
#     operand: 54
# 48. {c .. d}
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. g
#     core type: Variable
#     sub-expressions:
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (j)
#     core type: ExprTuple
#     sub-expressions: 54
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (c, d)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. c
#     core type: Variable
#     sub-expressions:
# 56. d
#     core type: Variable
#     sub-expressions:
