# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#inf_geom_sum">inf_geom_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import inf_geom_sum

# %%
# check that the built expression is the same as the stored expression
assert inf_geom_sum.expr == stored_expr
assert inf_geom_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: inf_geom_sum matches stored_expr")
# Out:
# Passed sanity check: inf_geom_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x \in \mathbb{C}~|~\left|x\right| < 1}~\left(\left(\sum_{m = 0}^{\infty} x^{m}\right) = \frac{1}{1 - x}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x in Complex | |x| < 1} ((Sum_{m = 0}^{infinity} x^{m}) = (1 / (1 - x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {(Sum_{m = 0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex ,  |x| < 1.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {(Sum_{m = 0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex ,  |x| < 1.
#    core type: Lambda
#    parameter: 43
#    body: 4
# 4. {(Sum_{m = 0}^{infinity} x^{m}) = (1 / (1 - x)) if x in Complex ,  |x| < 1.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{m = 0}^{infinity} x^{m}) = (1 / (1 - x))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in Complex) and (|x| < 1)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (Sum_{m = 0}^{infinity} x^{m}, 1 / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
# ...
