# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Lambda, R, S, a, f, fa, fx, g, gy, n, x, y
from proveit.logic import Card, Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Natural, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [f, g, R, S], instance_expr = Implies(Forall(instance_param_or_params = [a], instance_expr = InSet(fa, Complex), domain = R), Equals(Sum(index_or_indices = [x], summand = fx, domain = R), Sum(index_or_indices = sub_expr1, summand = Function(f, [gy]), domain = S))), conditions = [Equals(SetOfAll(instance_param_or_params = sub_expr1, instance_element = gy, domain = S), R), Equals(Card(S), n), Equals(Card(R), n)]), InSet(n, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{f, g, R, S~|~\left\{g\left(y\right)\right\}_{y \in S} = R, |S| = n, |R| = n}~\left(\left[\forall_{a \in R}~\left(f\left(a\right) \in \mathbb{C}\right)\right] \Rightarrow \left(\left[\sum_{x \in R}~f\left(x\right)\right] = \left[\sum_{y \in S}~f\left(g\left(y\right)\right)\right]\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])) if n in Natural.
#    core type: Lambda
#    parameter: 35
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 35
# 2. {forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]))
#    core type: Operation
#    operator: 22
#    operand: 7
# 4. n in Natural
#    core type: Operation
#    operator: 66
#    operands: 6
# 5. ((f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 35, 8
# 7. (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. (f, g, R, S)
#    core type: ExprTuple
#    sub-expressions: 64, 73, 70, 72
# 10. {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. [forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. ({g(y)}_{y in S} = R) and (|S| = n) and (|R| = n)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (forall_{a in R} (f(a) in Complex), [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. ({g(y)}_{y in S} = R, |S| = n, |R| = n)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 17. forall_{a in R} (f(a) in Complex)
#     core type: Operation
#     operator: 22
#     operand: 29
# 18. [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]
#     core type: Operation
#     operator: 27
#     operands: 24
# 19. {g(y)}_{y in S} = R
#     core type: Operation
#     operator: 27
#     operands: 25
# 20. |S| = n
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. |R| = n
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (a -> {f(a) in Complex if a in R.)
#     core type: ExprTuple
#     sub-expressions: 29
# 24. (Sum_{x in R} f(x), Sum_{y in S} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 25. ({g(y)}_{y in S}, R)
#     core type: ExprTuple
#     sub-expressions: 32, 70
# 26. (|S|, n)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (|R|, n)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. a -> {f(a) in Complex if a in R.
#     core type: Lambda
#     parameter: 68
#     body: 36
# 30. Sum_{x in R} f(x)
#     core type: Operation
#     operator: 38
#     operand: 47
# 31. Sum_{y in S} f(g(y))
#     core type: Operation
#     operator: 38
#     operand: 48
# 32. {g(y)}_{y in S}
#     core type: Operation
#     operator: 40
#     operand: 49
# 33. |S|
#     core type: Operation
#     operator: 43
#     operand: 72
# 34. |R|
#     core type: Operation
#     operator: 43
#     operand: 70
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. {f(a) in Complex if a in R.
#     core type: Conditional
#     value: 45
#     condition: 46
# 37. (x -> {f(x) if x in R.)
#     core type: ExprTuple
#     sub-expressions: 47
# 38. Sum
#     core type: Literal
#     sub-expressions:
# 39. (y -> {f(g(y)) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 48
# 40. SetOfAll
#     core type: Literal
#     sub-expressions:
# 41. (y -> {g(y) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 49
# 42. (S)
#     core type: ExprTuple
#     sub-expressions: 72
# 43. card
#     core type: Literal
#     sub-expressions:
# 44. (R)
#     core type: ExprTuple
#     sub-expressions: 70
# 45. f(a) in Complex
#     core type: Operation
#     operator: 66
#     operands: 50
# 46. a in R
#     core type: Operation
#     operator: 66
#     operands: 51
# 47. x -> {f(x) if x in R.
#     core type: Lambda
#     parameter: 69
#     body: 52
# 48. y -> {f(g(y)) if y in S.
#     core type: Lambda
#     parameter: 75
#     body: 53
# 49. y -> {g(y) if y in S.
#     core type: Lambda
#     parameter: 75
#     body: 54
# 50. (f(a), Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. (a, R)
#     core type: ExprTuple
#     sub-expressions: 68, 70
# 52. {f(x) if x in R.
#     core type: Conditional
#     value: 57
#     condition: 58
# 53. {f(g(y)) if y in S.
#     core type: Conditional
#     value: 59
#     condition: 60
# 54. {g(y) if y in S.
#     core type: Conditional
#     value: 71
#     condition: 60
# 55. f(a)
#     core type: Operation
#     operator: 64
#     operand: 68
# 56. Complex
#     core type: Literal
#     sub-expressions:
# 57. f(x)
#     core type: Operation
#     operator: 64
#     operand: 69
# 58. x in R
#     core type: Operation
#     operator: 66
#     operands: 63
# 59. f(g(y))
#     core type: Operation
#     operator: 64
#     operand: 71
# 60. y in S
#     core type: Operation
#     operator: 66
#     operands: 67
# 61. (a)
#     core type: ExprTuple
#     sub-expressions: 68
# 62. (x)
#     core type: ExprTuple
#     sub-expressions: 69
# 63. (x, R)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 64. f
#     core type: Variable
#     sub-expressions:
# 65. (g(y))
#     core type: ExprTuple
#     sub-expressions: 71
# 66. in
#     core type: Literal
#     sub-expressions:
# 67. (y, S)
#     core type: ExprTuple
#     sub-expressions: 75, 72
# 68. a
#     core type: Variable
#     sub-expressions:
# 69. x
#     core type: Variable
#     sub-expressions:
# 70. R
#     core type: Variable
#     sub-expressions:
# 71. g(y)
#     core type: Operation
#     operator: 73
#     operand: 75
# 72. S
#     core type: Variable
#     sub-expressions:
# 73. g
#     core type: Variable
#     sub-expressions:
# 74. (y)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. y
#     core type: Variable
#     sub-expressions:
