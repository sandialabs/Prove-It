# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, c, f, fx, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Less, LessEq, Sum, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(f, Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, subtract(b, one))), Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(b, c)))), domain = Integer, conditions = [Less(a, b), LessEq(b, c)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# f \mapsto \left[\forall_{a, b, c \in \mathbb{Z}~|~a < b, b \leq c}~\left(\left(\sum_{x = a}^{c} f\left(x\right)\right) = \left(\left(\sum_{x = a}^{b - 1} f\left(x\right)\right) + \left(\sum_{x = b}^{c} f\left(x\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. f -> [forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))))]
#    core type: Lambda
#    parameter: 49
#    body: 2
# 1. (f)
#    core type: ExprTuple
#    sub-expressions: 49
# 2. forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
# ...
