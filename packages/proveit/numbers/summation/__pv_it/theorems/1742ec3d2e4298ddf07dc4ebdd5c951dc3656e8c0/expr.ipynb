# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, c, d, f, fj, g, gj, j, x
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Integer, Interval, Mult, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = Lambda([f, g], Forall(instance_param_or_params = [x], instance_expr = Forall(instance_param_or_params = [c, d], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = Mult(Mult(x, gj), fj), domain = sub_expr2), Mult(x, Sum(index_or_indices = sub_expr1, summand = Mult(gj, fj), domain = sub_expr2))), domain = Integer), domain = Complex))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(f, g\right) \mapsto \left[\forall_{x \in \mathbb{C}}~\left[\forall_{c, d \in \mathbb{Z}}~\left(\left(\sum_{j = c}^{d} \left(\left(x \cdot g\left(j\right)\right) \cdot f\left(j\right)\right)\right) = \left(x \cdot \left(\sum_{j = c}^{d} \left(g\left(j\right) \cdot f\left(j\right)\right)\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (f, g) -> [forall_{x in Complex} [forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))))]]
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, g)
#    core type: ExprTuple
#    sub-expressions: 52, 51
# 2. forall_{x in Complex} [forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))))]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (x -> {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. x -> {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.
#    core type: Lambda
#    parameter: 47
#    body: 6
# 5. (x)
#    core type: ExprTuple
#    sub-expressions: 47
# 6. {forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))) if x in Complex.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{c, d in Integer} ((Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. x in Complex
#    core type: Operation
#    operator: 45
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((c, d) -> {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 13
# 12. (c, d) -> {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.
#     core type: Lambda
#     parameters: 55\n    body: 14
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. {(Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j)))) if c in Integer ,  d in Integer.
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. (Sum_{j = c}^{d} ((x * g(j)) * f(j))) = (x * (Sum_{j = c}^{d} (g(j) * f(j))))
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (c in Integer) and (d in Integer)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (Sum_{j = c}^{d} ((x * g(j)) * f(j)), x * (Sum_{j = c}^{d} (g(j) * f(j))))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (c in Integer, d in Integer)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Sum_{j = c}^{d} ((x * g(j)) * f(j))
#     core type: Operation
#     operator: 33
#     operand: 29
# 22. x * (Sum_{j = c}^{d} (g(j) * f(j)))
#     core type: Operation
#     operator: 43
#     operands: 26
# 23. c in Integer
#     core type: Operation
#     operator: 45
#     operands: 27
# 24. d in Integer
#     core type: Operation
#     operator: 45
#     operands: 28
# 25. (j -> {(x * g(j)) * f(j) if j in {c .. d}.)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (x, Sum_{j = c}^{d} (g(j) * f(j)))
#     core type: ExprTuple
#     sub-expressions: 47, 30
# 27. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 31
# 28. (d, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 31
# 29. j -> {(x * g(j)) * f(j) if j in {c .. d}.
#     core type: Lambda
#     parameter: 56
#     body: 32
# 30. Sum_{j = c}^{d} (g(j) * f(j))
#     core type: Operation
#     operator: 33
#     operand: 36
# 31. Integer
#     core type: Literal
#     sub-expressions:
# 32. {(x * g(j)) * f(j) if j in {c .. d}.
#     core type: Conditional
#     value: 35
#     condition: 41
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (j -> {g(j) * f(j) if j in {c .. d}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 35. (x * g(j)) * f(j)
#     core type: Operation
#     operator: 43
#     operands: 37
# 36. j -> {g(j) * f(j) if j in {c .. d}.
#     core type: Lambda
#     parameter: 56
#     body: 38
# 37. (x * g(j), f(j))
#     core type: ExprTuple
#     sub-expressions: 39, 49
# 38. {g(j) * f(j) if j in {c .. d}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 39. x * g(j)
#     core type: Operation
#     operator: 43
#     operands: 42
# 40. g(j) * f(j)
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. j in {c .. d}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. (x, g(j))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (g(j), f(j))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (j, {c .. d})
#     core type: ExprTuple
#     sub-expressions: 56, 50
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. g(j)
#     core type: Operation
#     operator: 51
#     operand: 56
# 49. f(j)
#     core type: Operation
#     operator: 52
#     operand: 56
# 50. {c .. d}
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. g
#     core type: Variable
#     sub-expressions:
# 52. f
#     core type: Variable
#     sub-expressions:
# 53. (j)
#     core type: ExprTuple
#     sub-expressions: 56
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (c, d)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. j
#     core type: Variable
#     sub-expressions:
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. d
#     core type: Variable
#     sub-expressions:
