# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Function, Lambda, R, S, a, f, fa, fx, g, gy, n, x, y
from proveit.logic import And, Card, Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = ExprTuple(Lambda([f, g, R, S], Conditional(Implies(Forall(instance_param_or_params = [a], instance_expr = InSet(fa, Complex), domain = R), Equals(Sum(index_or_indices = [x], summand = fx, domain = R), Sum(index_or_indices = sub_expr1, summand = Function(f, [gy]), domain = S))), And(Equals(SetOfAll(instance_param_or_params = sub_expr1, instance_element = gy, domain = S), R), Equals(Card(S), n), Equals(Card(R), n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(f, g, R, S\right) \mapsto \left\{\left[\forall_{a \in R}~\left(f\left(a\right) \in \mathbb{C}\right)\right] \Rightarrow \left(\left[\sum_{x \in R}~f\left(x\right)\right] = \left[\sum_{y \in S}~f\left(g\left(y\right)\right)\right]\right) \textrm{ if } \left\{g\left(y\right)\right\}_{y \in S} = R ,  |S| = n ,  |R| = n\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, g, R, S)
#    core type: ExprTuple
#    sub-expressions: 57, 66, 63, 65
# 3. {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ({g(y)}_{y in S} = R) and (|S| = n) and (|R| = n)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. (forall_{a in R} (f(a) in Complex), [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ({g(y)}_{y in S} = R, |S| = n, |R| = n)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. forall_{a in R} (f(a) in Complex)
#     core type: Operation
#     operator: 15
#     operand: 22
# 11. [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]
#     core type: Operation
#     operator: 20
#     operands: 17
# 12. {g(y)}_{y in S} = R
#     core type: Operation
#     operator: 20
#     operands: 18
# 13. |S| = n
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. |R| = n
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (a -> {f(a) in Complex if a in R.)
#     core type: ExprTuple
#     sub-expressions: 22
# 17. (Sum_{x in R} f(x), Sum_{y in S} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. ({g(y)}_{y in S}, R)
#     core type: ExprTuple
#     sub-expressions: 25, 63
# 19. (|S|, n)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (|R|, n)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. a -> {f(a) in Complex if a in R.
#     core type: Lambda
#     parameter: 61
#     body: 29
# 23. Sum_{x in R} f(x)
#     core type: Operation
#     operator: 31
#     operand: 40
# 24. Sum_{y in S} f(g(y))
#     core type: Operation
#     operator: 31
#     operand: 41
# 25. {g(y)}_{y in S}
#     core type: Operation
#     operator: 33
#     operand: 42
# 26. |S|
#     core type: Operation
#     operator: 36
#     operand: 65
# 27. |R|
#     core type: Operation
#     operator: 36
#     operand: 63
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. {f(a) in Complex if a in R.
#     core type: Conditional
#     value: 38
#     condition: 39
# 30. (x -> {f(x) if x in R.)
#     core type: ExprTuple
#     sub-expressions: 40
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (y -> {f(g(y)) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 41
# 33. SetOfAll
#     core type: Literal
#     sub-expressions:
# 34. (y -> {g(y) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 42
# 35. (S)
#     core type: ExprTuple
#     sub-expressions: 65
# 36. card
#     core type: Literal
#     sub-expressions:
# 37. (R)
#     core type: ExprTuple
#     sub-expressions: 63
# 38. f(a) in Complex
#     core type: Operation
#     operator: 59
#     operands: 43
# 39. a in R
#     core type: Operation
#     operator: 59
#     operands: 44
# 40. x -> {f(x) if x in R.
#     core type: Lambda
#     parameter: 62
#     body: 45
# 41. y -> {f(g(y)) if y in S.
#     core type: Lambda
#     parameter: 68
#     body: 46
# 42. y -> {g(y) if y in S.
#     core type: Lambda
#     parameter: 68
#     body: 47
# 43. (f(a), Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. (a, R)
#     core type: ExprTuple
#     sub-expressions: 61, 63
# 45. {f(x) if x in R.
#     core type: Conditional
#     value: 50
#     condition: 51
# 46. {f(g(y)) if y in S.
#     core type: Conditional
#     value: 52
#     condition: 53
# 47. {g(y) if y in S.
#     core type: Conditional
#     value: 64
#     condition: 53
# 48. f(a)
#     core type: Operation
#     operator: 57
#     operand: 61
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. f(x)
#     core type: Operation
#     operator: 57
#     operand: 62
# 51. x in R
#     core type: Operation
#     operator: 59
#     operands: 56
# 52. f(g(y))
#     core type: Operation
#     operator: 57
#     operand: 64
# 53. y in S
#     core type: Operation
#     operator: 59
#     operands: 60
# 54. (a)
#     core type: ExprTuple
#     sub-expressions: 61
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. (x, R)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 57. f
#     core type: Variable
#     sub-expressions:
# 58. (g(y))
#     core type: ExprTuple
#     sub-expressions: 64
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (y, S)
#     core type: ExprTuple
#     sub-expressions: 68, 65
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. R
#     core type: Variable
#     sub-expressions:
# 64. g(y)
#     core type: Operation
#     operator: 66
#     operand: 68
# 65. S
#     core type: Variable
#     sub-expressions:
# 66. g
#     core type: Variable
#     sub-expressions:
# 67. (y)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. y
#     core type: Variable
#     sub-expressions:
