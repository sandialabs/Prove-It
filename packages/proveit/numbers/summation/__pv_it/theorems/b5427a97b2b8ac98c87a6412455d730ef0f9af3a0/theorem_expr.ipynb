# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#distributive_summation">distributive_summation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import distributive_summation

# %%
# check that the built expression is the same as the stored expression
assert distributive_summation.expr == stored_expr
assert distributive_summation.expr._style_id == stored_expr._style_id
print("Passed sanity check: distributive_summation matches stored_expr")
# Out:
# Passed sanity check: distributive_summation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{x \in \mathbb{C}}~\left[\forall_{j, k \in \mathbb{Z}}~\left(\left(\sum_{i = j}^{k} \left(x \cdot f\left(i\right)\right)\right) = \left(x \cdot \left(\sum_{i = j}^{k} f\left(i\right)\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{x in Complex} [forall_{j, k in Integer} ((Sum_{i = j}^{k} (x * f(i))) = (x * (Sum_{i = j}^{k} f(i))))]]
#    core type: Operation
#    operator: 11
#    operand: 2
# 1. (f -> [forall_{x in Complex} [forall_{j, k in Integer} ((Sum_{i = j}^{k} (x * f(i))) = (x * (Sum_{i = j}^{k} f(i))))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{x in Complex} [forall_{j, k in Integer} ((Sum_{i = j}^{k} (x * f(i))) = (x * (Sum_{i = j}^{k} f(i))))]]
#    core type: Lambda
#    parameter: 45
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 45
# 4. forall_{x in Complex} [forall_{j, k in Integer} ((Sum_{i = j}^{k} (x * f(i))) = (x * (Sum_{i = j}^{k} f(i))))]
#    core type: Operation
#    operator: 11
#    operand: 6
# 5. (x -> {forall_{j, k in Integer} ((Sum_{i = j}^{k} (x * f(i))) = (x * (Sum_{i = j}^{k} f(i)))) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 6
# ...
