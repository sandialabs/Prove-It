# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, R, S, a, f, fa, fx, g, gy, n, x, y
from proveit.logic import Card, Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Forall(instance_param_or_params = [f, g, R, S], instance_expr = Implies(Forall(instance_param_or_params = [a], instance_expr = InSet(fa, Complex), domain = R), Equals(Sum(index_or_indices = [x], summand = fx, domain = R), Sum(index_or_indices = sub_expr1, summand = Function(f, [gy]), domain = S))), conditions = [Equals(SetOfAll(instance_param_or_params = sub_expr1, instance_element = gy, domain = S), R), Equals(Card(S), n), Equals(Card(R), n)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f, g, R, S~|~\left\{g\left(y\right)\right\}_{y \in S} = R, |S| = n, |R| = n}~\left(\left[\forall_{a \in R}~\left(f\left(a\right) \in \mathbb{C}\right)\right] \Rightarrow \left(\left[\sum_{x \in R}~f\left(x\right)\right] = \left[\sum_{y \in S}~f\left(g\left(y\right)\right)\right]\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]))
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. ((f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, g, R, S)
#    core type: ExprTuple
#    sub-expressions: 58, 67, 64, 66
# 4. {[forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]) if {g(y)}_{y in S} = R ,  |S| = n ,  |R| = n.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. [forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ({g(y)}_{y in S} = R) and (|S| = n) and (|R| = n)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. (forall_{a in R} (f(a) in Complex), [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ({g(y)}_{y in S} = R, |S| = n, |R| = n)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. forall_{a in R} (f(a) in Complex)
#     core type: Operation
#     operator: 16
#     operand: 23
# 12. [Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]
#     core type: Operation
#     operator: 21
#     operands: 18
# 13. {g(y)}_{y in S} = R
#     core type: Operation
#     operator: 21
#     operands: 19
# 14. |S| = n
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. |R| = n
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (a -> {f(a) in Complex if a in R.)
#     core type: ExprTuple
#     sub-expressions: 23
# 18. (Sum_{x in R} f(x), Sum_{y in S} f(g(y)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 19. ({g(y)}_{y in S}, R)
#     core type: ExprTuple
#     sub-expressions: 26, 64
# 20. (|S|, n)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (|R|, n)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 23. a -> {f(a) in Complex if a in R.
#     core type: Lambda
#     parameter: 62
#     body: 30
# 24. Sum_{x in R} f(x)
#     core type: Operation
#     operator: 32
#     operand: 41
# 25. Sum_{y in S} f(g(y))
#     core type: Operation
#     operator: 32
#     operand: 42
# 26. {g(y)}_{y in S}
#     core type: Operation
#     operator: 34
#     operand: 43
# 27. |S|
#     core type: Operation
#     operator: 37
#     operand: 66
# 28. |R|
#     core type: Operation
#     operator: 37
#     operand: 64
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. {f(a) in Complex if a in R.
#     core type: Conditional
#     value: 39
#     condition: 40
# 31. (x -> {f(x) if x in R.)
#     core type: ExprTuple
#     sub-expressions: 41
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (y -> {f(g(y)) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 42
# 34. SetOfAll
#     core type: Literal
#     sub-expressions:
# 35. (y -> {g(y) if y in S.)
#     core type: ExprTuple
#     sub-expressions: 43
# 36. (S)
#     core type: ExprTuple
#     sub-expressions: 66
# 37. card
#     core type: Literal
#     sub-expressions:
# 38. (R)
#     core type: ExprTuple
#     sub-expressions: 64
# 39. f(a) in Complex
#     core type: Operation
#     operator: 60
#     operands: 44
# 40. a in R
#     core type: Operation
#     operator: 60
#     operands: 45
# 41. x -> {f(x) if x in R.
#     core type: Lambda
#     parameter: 63
#     body: 46
# 42. y -> {f(g(y)) if y in S.
#     core type: Lambda
#     parameter: 69
#     body: 47
# 43. y -> {g(y) if y in S.
#     core type: Lambda
#     parameter: 69
#     body: 48
# 44. (f(a), Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. (a, R)
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 46. {f(x) if x in R.
#     core type: Conditional
#     value: 51
#     condition: 52
# 47. {f(g(y)) if y in S.
#     core type: Conditional
#     value: 53
#     condition: 54
# 48. {g(y) if y in S.
#     core type: Conditional
#     value: 65
#     condition: 54
# 49. f(a)
#     core type: Operation
#     operator: 58
#     operand: 62
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. f(x)
#     core type: Operation
#     operator: 58
#     operand: 63
# 52. x in R
#     core type: Operation
#     operator: 60
#     operands: 57
# 53. f(g(y))
#     core type: Operation
#     operator: 58
#     operand: 65
# 54. y in S
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. (a)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. (x)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. (x, R)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 58. f
#     core type: Variable
#     sub-expressions:
# 59. (g(y))
#     core type: ExprTuple
#     sub-expressions: 65
# 60. in
#     core type: Literal
#     sub-expressions:
# 61. (y, S)
#     core type: ExprTuple
#     sub-expressions: 69, 66
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. R
#     core type: Variable
#     sub-expressions:
# 65. g(y)
#     core type: Operation
#     operator: 67
#     operand: 69
# 66. S
#     core type: Variable
#     sub-expressions:
# 67. g
#     core type: Variable
#     sub-expressions:
# 68. (y)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. y
#     core type: Variable
#     sub-expressions:
