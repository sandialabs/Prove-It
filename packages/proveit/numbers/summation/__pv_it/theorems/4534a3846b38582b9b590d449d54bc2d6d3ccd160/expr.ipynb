# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, c, fx, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Less, LessEq, Sum, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda([a, b, c], Conditional(Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, subtract(b, one))), Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), Less(a, b), LessEq(b, c)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\left(\sum_{x = a}^{c} f\left(x\right)\right) = \left(\left(\sum_{x = a}^{b - 1} f\left(x\right)\right) + \left(\sum_{x = b}^{c} f\left(x\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a < b ,  b \leq c\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a, b, c) -> {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 55, 60, 57
# 3. {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x)))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integer) and (b in Integer) and (c in Integer) and (a < b) and (b <= c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (Sum_{x = a}^{c} f(x), (Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integer, b in Integer, c in Integer, a < b, b <= c)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. Sum_{x = a}^{c} f(x)
#     core type: Operation
#     operator: 31
#     operand: 25
# 11. (Sum_{x = a}^{b - 1} f(x)) + (Sum_{x = b}^{c} f(x))
#     core type: Operation
#     operator: 58
#     operands: 18
# 12. a in Integer
#     core type: Operation
#     operator: 47
#     operands: 19
# 13. b in Integer
#     core type: Operation
#     operator: 47
#     operands: 20
# 14. c in Integer
#     core type: Operation
#     operator: 47
#     operands: 21
# 15. a < b
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. b <= c
#     core type: Operation
#     operator: 24
#     operands: 54
# 17. (x -> {f(x) if x in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 18. (Sum_{x = a}^{b - 1} f(x), Sum_{x = b}^{c} f(x))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 19. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 28
# 20. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 28
# 21. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 28
# 22. <
#     core type: Literal
#     sub-expressions:
# 23. (a, b)
#     core type: ExprTuple
#     sub-expressions: 55, 60
# 24. <=
#     core type: Literal
#     sub-expressions:
# 25. x -> {f(x) if x in {a .. c}.
#     core type: Lambda
#     parameter: 50
#     body: 29
# 26. Sum_{x = a}^{b - 1} f(x)
#     core type: Operation
#     operator: 31
#     operand: 34
# 27. Sum_{x = b}^{c} f(x)
#     core type: Operation
#     operator: 31
#     operand: 35
# 28. Integer
#     core type: Literal
#     sub-expressions:
# 29. {f(x) if x in {a .. c}.
#     core type: Conditional
#     value: 41
#     condition: 33
# 30. (x -> {f(x) if x in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (x -> {f(x) if x in {b .. c}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. x in {a .. c}
#     core type: Operation
#     operator: 47
#     operands: 36
# 34. x -> {f(x) if x in {a .. b - 1}.
#     core type: Lambda
#     parameter: 50
#     body: 37
# 35. x -> {f(x) if x in {b .. c}.
#     core type: Lambda
#     parameter: 50
#     body: 38
# 36. (x, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 50, 39
# 37. {f(x) if x in {a .. b - 1}.
#     core type: Conditional
#     value: 41
#     condition: 40
# 38. {f(x) if x in {b .. c}.
#     core type: Conditional
#     value: 41
#     condition: 42
# 39. {a .. c}
#     core type: Operation
#     operator: 53
#     operands: 43
# 40. x in {a .. b - 1}
#     core type: Operation
#     operator: 47
#     operands: 44
# 41. f(x)
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. x in {b .. c}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. (a, c)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 44. (x, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 45. f
#     core type: Variable
#     sub-expressions:
# 46. (x)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (x, {b .. c})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 49. {a .. b - 1}
#     core type: Operation
#     operator: 53
#     operands: 52
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. {b .. c}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (b, c)
#     core type: ExprTuple
#     sub-expressions: 60, 57
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. b - 1
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. b
#     core type: Variable
#     sub-expressions:
# 61. -1
#     core type: Operation
#     operator: 62
#     operand: 64
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. 1
#     core type: Literal
#     sub-expressions:
