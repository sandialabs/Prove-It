# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, S, a, b, f, fa, fx, x
from proveit.logic import And, Forall, InSet, SubsetEq
from proveit.numbers import Add, Integer, Integrate, Interval, IntervalCC, LessEq, MonDecFuncs, Real, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = IntervalCC(a, b)
expr = Lambda(f, Conditional(Forall(instance_param_or_params = [a, b], instance_expr = LessEq(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Add(fa, Integrate(index_or_indices = sub_expr1, integrand = fx, domain = sub_expr2))), domain = Integer, conditions = [LessEq(a, b), SubsetEq(sub_expr2, S)]), And(InSet(f, MonDecFuncs(S)), SubsetEq(S, Real))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# f \mapsto \left\{\forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(f\left(a\right) + \left(\int_{a}^{b} f\left(x\right)\,dx\right)\right)\right) \textrm{ if } f \in \textrm{MonDecFuncs}\left(S\right) ,  S \subseteq \mathbb{R}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. f -> {forall_{a, b in Integer | a <= b, [a,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx))) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Lambda
#    parameter: 55
#    body: 2
# 1. (f)
#    core type: ExprTuple
#    sub-expressions: 55
# 2. {forall_{a, b in Integer | a <= b, [a,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx))) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, b in Integer | a <= b, [a,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (f in MonDecFuncs(S)) and (S subset_eq Real)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (f in MonDecFuncs(S), S subset_eq Real)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a, b) -> {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.
#    core type: Lambda
#    parameters: 62\n   body: 11
# 9. f in MonDecFuncs(S)
#    core type: Operation
#    operator: 57
#    operands: 12
# 10. S subset_eq Real
#     core type: Operation
#     operator: 36
#     operands: 13
# 11. {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (f, MonDecFuncs(S))
#     core type: ExprTuple
#     sub-expressions: 55, 16
# 13. (S, Real)
#     core type: ExprTuple
#     sub-expressions: 42, 17
# 14. (Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx))
#     core type: Operation
#     operator: 35
#     operands: 18
# 15. (a in Integer) and (b in Integer) and (a <= b) and ([a,b] subset_eq S)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. MonDecFuncs(S)
#     core type: Operation
#     operator: 21
#     operand: 42
# 17. Real
#     core type: Literal
#     sub-expressions:
# 18. (Sum_{x = a}^{b} f(x), f(a) + (Integrate_{a}^{b} f(x)\,dx))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a in Integer, b in Integer, a <= b, [a,b] subset_eq S)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 21. MonDecFuncs
#     core type: Literal
#     sub-expressions:
# 22. (S)
#     core type: ExprTuple
#     sub-expressions: 42
# 23. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 29
#     operand: 38
# 24. f(a) + (Integrate_{a}^{b} f(x)\,dx)
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. a in Integer
#     core type: Operation
#     operator: 57
#     operands: 33
# 26. b in Integer
#     core type: Operation
#     operator: 57
#     operands: 34
# 27. a <= b
#     core type: Operation
#     operator: 35
#     operands: 62
# 28. [a,b] subset_eq S
#     core type: Operation
#     operator: 36
#     operands: 37
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (f(a), Integrate_{a}^{b} f(x)\,dx)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 41
# 34. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 41
# 35. <=
#     core type: Literal
#     sub-expressions:
# 36. subset_eq
#     core type: Literal
#     sub-expressions:
# 37. ([a,b], S)
#     core type: ExprTuple
#     sub-expressions: 60, 42
# 38. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 59
#     body: 43
# 39. f(a)
#     core type: Operation
#     operator: 55
#     operand: 63
# 40. Integrate_{a}^{b} f(x)\,dx
#     core type: Operation
#     operator: 45
#     operand: 48
# 41. Integer
#     core type: Literal
#     sub-expressions:
# 42. S
#     core type: Variable
#     sub-expressions:
# 43. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 52
#     condition: 47
# 44. (a)
#     core type: ExprTuple
#     sub-expressions: 63
# 45. Integrate
#     core type: Literal
#     sub-expressions:
# 46. (x -> {f(x) if x in [a,b].)
#     core type: ExprTuple
#     sub-expressions: 48
# 47. x in {a .. b}
#     core type: Operation
#     operator: 57
#     operands: 49
# 48. x -> {f(x) if x in [a,b].
#     core type: Lambda
#     parameter: 59
#     body: 50
# 49. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 59, 51
# 50. {f(x) if x in [a,b].
#     core type: Conditional
#     value: 52
#     condition: 53
# 51. {a .. b}
#     core type: Operation
#     operator: 54
#     operands: 62
# 52. f(x)
#     core type: Operation
#     operator: 55
#     operand: 59
# 53. x in [a,b]
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. f
#     core type: Variable
#     sub-expressions:
# 56. (x)
#     core type: ExprTuple
#     sub-expressions: 59
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (x, [a,b])
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. [a,b]
#     core type: Operation
#     operator: 61
#     operands: 62
# 61. IntervalCC
#     core type: Literal
#     sub-expressions:
# 62. (a, b)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. a
#     core type: Variable
#     sub-expressions:
# 64. b
#     core type: Variable
#     sub-expressions:
