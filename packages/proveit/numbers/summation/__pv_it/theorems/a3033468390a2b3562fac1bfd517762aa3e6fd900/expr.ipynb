# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, Lambda, a, b, c, f, fx, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Sum, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(f, Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = Function(f, [subtract(x, c)]), domain = Interval(Add(a, c), Add(b, c)))), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# f \mapsto \left[\forall_{a, b, c \in \mathbb{Z}}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) = \left(\sum_{x = a + c}^{b + c} f\left(x - c\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. f -> [forall_{a, b, c in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)))]
#    core type: Lambda
#    parameter: 36
#    body: 2
# 1. (f)
#    core type: ExprTuple
#    sub-expressions: 36
# 2. forall_{a, b, c in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 56, 57, 58
# 7. {(Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a in Integer) and (b in Integer) and (c in Integer)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (Sum_{x = a}^{b} f(x), Sum_{x = a + c}^{b + c} f(x - c))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a in Integer, b in Integer, c in Integer)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 14. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 20
#     operand: 25
# 15. Sum_{x = a + c}^{b + c} f(x - c)
#     core type: Operation
#     operator: 20
#     operand: 26
# 16. a in Integer
#     core type: Operation
#     operator: 38
#     operands: 22
# 17. b in Integer
#     core type: Operation
#     operator: 38
#     operands: 23
# 18. c in Integer
#     core type: Operation
#     operator: 38
#     operands: 24
# 19. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. Sum
#     core type: Literal
#     sub-expressions:
# 21. (x -> {f(x - c) if x in {a + c .. b + c}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 56, 27
# 23. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 27
# 24. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 27
# 25. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 47
#     body: 28
# 26. x -> {f(x - c) if x in {a + c .. b + c}.
#     core type: Lambda
#     parameter: 47
#     body: 29
# 27. Integer
#     core type: Literal
#     sub-expressions:
# 28. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 30
#     condition: 31
# 29. {f(x - c) if x in {a + c .. b + c}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. f(x)
#     core type: Operation
#     operator: 36
#     operand: 47
# 31. x in {a .. b}
#     core type: Operation
#     operator: 38
#     operands: 35
# 32. f(x - c)
#     core type: Operation
#     operator: 36
#     operand: 41
# 33. x in {a + c .. b + c}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. (x)
#     core type: ExprTuple
#     sub-expressions: 47
# 35. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 47, 40
# 36. f
#     core type: Variable
#     sub-expressions:
# 37. (x - c)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (x, {a + c .. b + c})
#     core type: ExprTuple
#     sub-expressions: 47, 42
# 40. {a .. b}
#     core type: Operation
#     operator: 45
#     operands: 43
# 41. x - c
#     core type: Operation
#     operator: 54
#     operands: 44
# 42. {a + c .. b + c}
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. (a, b)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 44. (x, -c)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. Interval
#     core type: Literal
#     sub-expressions:
# 46. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. -c
#     core type: Operation
#     operator: 51
#     operand: 58
# 49. a + c
#     core type: Operation
#     operator: 54
#     operands: 53
# 50. b + c
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (c)
#     core type: ExprTuple
#     sub-expressions: 58
# 53. (a, c)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (b, c)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. b
#     core type: Variable
#     sub-expressions:
# 58. c
#     core type: Variable
#     sub-expressions:
