# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, a, b, fx, x
from proveit.logic import Forall, SubsetEq
from proveit.numbers import Integer, Integrate, Interval, IntervalCC, LessEq, Sum, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = IntervalCC(subtract(a, one), b)
expr = Forall(instance_param_or_params = [a, b], instance_expr = LessEq(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Integrate(index_or_indices = sub_expr1, integrand = fx, domain = sub_expr2)), domain = Integer, conditions = [LessEq(a, b), SubsetEq(sub_expr2, S)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a - 1,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(\int_{a - 1}^{b} f\left(x\right)\,dx\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#    core type: Lambda
#    parameters: 43\n   body: 4
# 4. {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. (a in Integer) and (b in Integer) and (a <= b) and ([a - 1,b] subset_eq S)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (Sum_{x = a}^{b} f(x), Integrate_{a - 1}^{b} f(x)\,dx)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integer, b in Integer, a <= b, [a - 1,b] subset_eq S)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 16
#     operand: 25
# 11. Integrate_{a - 1}^{b} f(x)\,dx
#     core type: Operation
#     operator: 18
#     operand: 26
# 12. a in Integer
#     core type: Operation
#     operator: 37
#     operands: 20
# 13. b in Integer
#     core type: Operation
#     operator: 37
#     operands: 21
# 14. a <= b
#     core type: Operation
#     operator: 22
#     operands: 43
# 15. [a - 1,b] subset_eq S
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. Sum
#     core type: Literal
#     sub-expressions:
# 17. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 18. Integrate
#     core type: Literal
#     sub-expressions:
# 19. (x -> {f(x) if x in [a - 1,b].)
#     core type: ExprTuple
#     sub-expressions: 26
# 20. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 50, 27
# 21. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 47, 27
# 22. <=
#     core type: Literal
#     sub-expressions:
# 23. subset_eq
#     core type: Literal
#     sub-expressions:
# 24. ([a - 1,b], S)
#     core type: ExprTuple
#     sub-expressions: 41, 28
# 25. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 40
#     body: 29
# 26. x -> {f(x) if x in [a - 1,b].
#     core type: Lambda
#     parameter: 40
#     body: 30
# 27. Integer
#     core type: Literal
#     sub-expressions:
# 28. S
#     core type: Variable
#     sub-expressions:
# 29. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 32
#     condition: 31
# 30. {f(x) if x in [a - 1,b].
#     core type: Conditional
#     value: 32
#     condition: 33
# 31. x in {a .. b}
#     core type: Operation
#     operator: 37
#     operands: 34
# 32. f(x)
#     core type: Operation
#     operator: 35
#     operand: 40
# 33. x in [a - 1,b]
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 40, 39
# 35. f
#     core type: Variable
#     sub-expressions:
# 36. (x)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (x, [a - 1,b])
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. {a .. b}
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. [a - 1,b]
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (a, b)
#     core type: ExprTuple
#     sub-expressions: 50, 47
# 44. IntervalCC
#     core type: Literal
#     sub-expressions:
# 45. (a - 1, b)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 46. a - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. b
#     core type: Variable
#     sub-expressions:
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (a, -1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. -1
#     core type: Operation
#     operator: 52
#     operand: 54
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. 1
#     core type: Literal
#     sub-expressions:
