# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#equiv_sums">equiv_sums</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import equiv_sums

# %%
# check that the built expression is the same as the stored expression
assert equiv_sums.expr == stored_expr
assert equiv_sums.expr._style_id == stored_expr._style_id
print("Passed sanity check: equiv_sums matches stored_expr")
# Out:
# Passed sanity check: equiv_sums matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{f, g, R, S~|~\left\{g\left(y\right)\right\}_{y \in S} = R, |S| = n, |R| = n}~\left(\left[\forall_{a \in R}~\left(f\left(a\right) \in \mathbb{C}\right)\right] \Rightarrow \left(\left[\sum_{x \in R}~f\left(x\right)\right] = \left[\sum_{y \in S}~f\left(g\left(y\right)\right)\right]\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))]))]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. (n -> {forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])) if n in Natural.
#    core type: Lambda
#    parameter: 37
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 37
# 4. {forall_{f, g, R, S | {g(y)}_{y in S} = R, |S| = n, |R| = n} ([forall_{a in R} (f(a) in Complex)] => ([Sum_{x in R} f(x)] = [Sum_{y in S} f(g(y))])) if n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
