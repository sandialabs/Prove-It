# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, S, a, b, f, fa, fx, x
from proveit.logic import And, Forall, InSet, SubsetEq
from proveit.numbers import Add, Integer, Integrate, Interval, IntervalCC, LessEq, MonDecFuncs, Real, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = IntervalCC(a, b)
expr = Conditional(Forall(instance_param_or_params = [a, b], instance_expr = LessEq(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Add(fa, Integrate(index_or_indices = sub_expr1, integrand = fx, domain = sub_expr2))), domain = Integer, conditions = [LessEq(a, b), SubsetEq(sub_expr2, S)]), And(InSet(f, MonDecFuncs(S)), SubsetEq(S, Real)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(f\left(a\right) + \left(\int_{a}^{b} f\left(x\right)\,dx\right)\right)\right) \textrm{ if } f \in \textrm{MonDecFuncs}\left(S\right) ,  S \subseteq \mathbb{R}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a, b in Integer | a <= b, [a,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx))) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, b in Integer | a <= b, [a,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (f in MonDecFuncs(S)) and (S subset_eq Real)
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b) -> {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (f in MonDecFuncs(S), S subset_eq Real)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a, b) -> {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.
#    core type: Lambda
#    parameters: 60\n   body: 9
# 7. f in MonDecFuncs(S)
#    core type: Operation
#    operator: 55
#    operands: 10
# 8. S subset_eq Real
#    core type: Operation
#    operator: 34
#    operands: 11
# 9. {(Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx)) if a in Integer ,  b in Integer ,  a <= b ,  [a,b] subset_eq S.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (f, MonDecFuncs(S))
#     core type: ExprTuple
#     sub-expressions: 53, 14
# 11. (S, Real)
#     core type: ExprTuple
#     sub-expressions: 40, 15
# 12. (Sum_{x = a}^{b} f(x)) <= (f(a) + (Integrate_{a}^{b} f(x)\,dx))
#     core type: Operation
#     operator: 33
#     operands: 16
# 13. (a in Integer) and (b in Integer) and (a <= b) and ([a,b] subset_eq S)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. MonDecFuncs(S)
#     core type: Operation
#     operator: 19
#     operand: 40
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. (Sum_{x = a}^{b} f(x), f(a) + (Integrate_{a}^{b} f(x)\,dx))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a in Integer, b in Integer, a <= b, [a,b] subset_eq S)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26
# 19. MonDecFuncs
#     core type: Literal
#     sub-expressions:
# 20. (S)
#     core type: ExprTuple
#     sub-expressions: 40
# 21. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 27
#     operand: 36
# 22. f(a) + (Integrate_{a}^{b} f(x)\,dx)
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. a in Integer
#     core type: Operation
#     operator: 55
#     operands: 31
# 24. b in Integer
#     core type: Operation
#     operator: 55
#     operands: 32
# 25. a <= b
#     core type: Operation
#     operator: 33
#     operands: 60
# 26. [a,b] subset_eq S
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (f(a), Integrate_{a}^{b} f(x)\,dx)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 39
# 32. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 39
# 33. <=
#     core type: Literal
#     sub-expressions:
# 34. subset_eq
#     core type: Literal
#     sub-expressions:
# 35. ([a,b], S)
#     core type: ExprTuple
#     sub-expressions: 58, 40
# 36. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 57
#     body: 41
# 37. f(a)
#     core type: Operation
#     operator: 53
#     operand: 61
# 38. Integrate_{a}^{b} f(x)\,dx
#     core type: Operation
#     operator: 43
#     operand: 46
# 39. Integer
#     core type: Literal
#     sub-expressions:
# 40. S
#     core type: Variable
#     sub-expressions:
# 41. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 50
#     condition: 45
# 42. (a)
#     core type: ExprTuple
#     sub-expressions: 61
# 43. Integrate
#     core type: Literal
#     sub-expressions:
# 44. (x -> {f(x) if x in [a,b].)
#     core type: ExprTuple
#     sub-expressions: 46
# 45. x in {a .. b}
#     core type: Operation
#     operator: 55
#     operands: 47
# 46. x -> {f(x) if x in [a,b].
#     core type: Lambda
#     parameter: 57
#     body: 48
# 47. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 57, 49
# 48. {f(x) if x in [a,b].
#     core type: Conditional
#     value: 50
#     condition: 51
# 49. {a .. b}
#     core type: Operation
#     operator: 52
#     operands: 60
# 50. f(x)
#     core type: Operation
#     operator: 53
#     operand: 57
# 51. x in [a,b]
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. f
#     core type: Variable
#     sub-expressions:
# 54. (x)
#     core type: ExprTuple
#     sub-expressions: 57
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (x, [a,b])
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. x
#     core type: Variable
#     sub-expressions:
# 58. [a,b]
#     core type: Operation
#     operator: 59
#     operands: 60
# 59. IntervalCC
#     core type: Literal
#     sub-expressions:
# 60. (a, b)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. b
#     core type: Variable
#     sub-expressions:
