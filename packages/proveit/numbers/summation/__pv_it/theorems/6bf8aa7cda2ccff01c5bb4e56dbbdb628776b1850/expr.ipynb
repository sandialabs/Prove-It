# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, j, k, x
from proveit.logic import And, Equals, Forall, InSet, NotEquals
from proveit.numbers import Add, Complex, Exp, Integer, Interval, LessEq, Sum, frac, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Forall(instance_param_or_params = [j, k], instance_expr = Equals(Sum(index_or_indices = [i], summand = Exp(x, i), domain = Interval(j, k)), frac(subtract(Exp(x, j), Exp(x, Add(k, one))), subtract(one, x))), domain = Integer, condition = LessEq(j, k)), And(InSet(x, Complex), NotEquals(x, one))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# x \mapsto \left\{\forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left(\left(\sum_{i = j}^{k} x^{i}\right) = \frac{x^{j} - x^{k + 1}}{1 - x}\right) \textrm{ if } x \in \mathbb{C} ,  x \neq 1\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. x -> {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Lambda
#    parameter: 61
#    body: 1
# 1. {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (x in Complex) and (x != 1)
#    core type: Operation
#    operator: 19
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x in Complex, x != 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 57\n   body: 10
# 8. x in Complex
#    core type: Operation
#    operator: 47
#    operands: 11
# 9. x != 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 16
# 12. !=
#     core type: Literal
#     sub-expressions:
# 13. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 61, 66
# 14. (Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (j in Integer) and (k in Integer) and (j <= k)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Complex
#     core type: Literal
#     sub-expressions:
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (Sum_{i = j}^{k} x^{i}, (x^{j} - x^{k + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (j in Integer, k in Integer, j <= k)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. Sum_{i = j}^{k} x^{i}
#     core type: Operation
#     operator: 26
#     operand: 33
# 22. (x^{j} - x^{k + 1}) / (1 - x)
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. j in Integer
#     core type: Operation
#     operator: 47
#     operands: 30
# 24. k in Integer
#     core type: Operation
#     operator: 47
#     operands: 31
# 25. j <= k
#     core type: Operation
#     operator: 32
#     operands: 57
# 26. Sum
#     core type: Literal
#     sub-expressions:
# 27. (i -> {x^{i} if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 28. /
#     core type: Literal
#     sub-expressions:
# 29. (x^{j} - x^{k + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 30. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 36
# 31. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 36
# 32. <=
#     core type: Literal
#     sub-expressions:
# 33. i -> {x^{i} if i in {j .. k}.
#     core type: Lambda
#     parameter: 53
#     body: 38
# 34. x^{j} - x^{k + 1}
#     core type: Operation
#     operator: 63
#     operands: 39
# 35. 1 - x
#     core type: Operation
#     operator: 63
#     operands: 40
# 36. Integer
#     core type: Literal
#     sub-expressions:
# 37. (i)
#     core type: ExprTuple
#     sub-expressions: 53
# 38. {x^{i} if i in {j .. k}.
#     core type: Conditional
#     value: 41
#     condition: 42
# 39. (x^{j}, -x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 66, 45
# 41. x^{i}
#     core type: Operation
#     operator: 58
#     operands: 46
# 42. i in {j .. k}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. x^{j}
#     core type: Operation
#     operator: 58
#     operands: 49
# 44. -x^{k + 1}
#     core type: Operation
#     operator: 51
#     operand: 55
# 45. -x
#     core type: Operation
#     operator: 51
#     operand: 61
# 46. (x, i)
#     core type: ExprTuple
#     sub-expressions: 61, 53
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. (x, j)
#     core type: ExprTuple
#     sub-expressions: 61, 60
# 50. (x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 55
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 53. i
#     core type: Variable
#     sub-expressions:
# 54. {j .. k}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. x^{k + 1}
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (j, k)
#     core type: ExprTuple
#     sub-expressions: 60, 65
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (x, k + 1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 60. j
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. k + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. k
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
