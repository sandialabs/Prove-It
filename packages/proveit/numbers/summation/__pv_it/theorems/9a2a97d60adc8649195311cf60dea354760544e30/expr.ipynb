# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, a, b, f, fx, x
from proveit.logic import Equals, Forall
from proveit.numbers import Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = Function(f, [Neg(x)]), domain = Interval(Neg(b), Neg(a)))), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) = \left(\sum_{x = -b}^{-a} f\left(-x\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (f -> [forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)))]
#    core type: Lambda
#    parameter: 34
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 34
# 4. forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {(Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (a, b) -> {(Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 41\n   body: 8
# 8. {(Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x)) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (Sum_{x = a}^{b} f(x)) = (Sum_{x = -b}^{-a} f(-x))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in Integer) and (b in Integer)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Sum_{x = a}^{b} f(x), Sum_{x = -b}^{-a} f(-x))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 20
#     operand: 24
# 16. Sum_{x = -b}^{-a} f(-x)
#     core type: Operation
#     operator: 20
#     operand: 25
# 17. a in Integer
#     core type: Operation
#     operator: 36
#     operands: 22
# 18. b in Integer
#     core type: Operation
#     operator: 36
#     operands: 23
# 19. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. Sum
#     core type: Literal
#     sub-expressions:
# 21. (x -> {f(-x) if x in {-b .. -a}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 52, 26
# 23. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 51, 26
# 24. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 45
#     body: 27
# 25. x -> {f(-x) if x in {-b .. -a}.
#     core type: Lambda
#     parameter: 45
#     body: 28
# 26. Integer
#     core type: Literal
#     sub-expressions:
# 27. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. {f(-x) if x in {-b .. -a}.
#     core type: Conditional
#     value: 31
#     condition: 32
# 29. f(x)
#     core type: Operation
#     operator: 34
#     operand: 45
# 30. x in {a .. b}
#     core type: Operation
#     operator: 36
#     operands: 33
# 31. f(-x)
#     core type: Operation
#     operator: 34
#     operand: 39
# 32. x in {-b .. -a}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 45, 38
# 34. f
#     core type: Variable
#     sub-expressions:
# 35. (-x)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (x, {-b .. -a})
#     core type: ExprTuple
#     sub-expressions: 45, 40
# 38. {a .. b}
#     core type: Operation
#     operator: 43
#     operands: 41
# 39. -x
#     core type: Operation
#     operator: 49
#     operand: 45
# 40. {-b .. -a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (a, b)
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 42. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (-b, -a)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. -b
#     core type: Operation
#     operator: 49
#     operand: 51
# 47. -a
#     core type: Operation
#     operator: 49
#     operand: 52
# 48. (b)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (a)
#     core type: ExprTuple
#     sub-expressions: 52
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. a
#     core type: Variable
#     sub-expressions:
