# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, fx, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(Add(b, one), c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left(\sum_{x = a}^{c} f\left(x\right)\right) = \left(\left(\sum_{x = a}^{b} f\left(x\right)\right) + \left(\sum_{x = b + 1}^{c} f\left(x\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{x = a}^{c} f(x), (Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 6. Sum_{x = a}^{c} f(x)
#    core type: Operation
#    operator: 27
#    operand: 19
# 7. (Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))
#    core type: Operation
#    operator: 56
#    operands: 13
# 8. a in Integer
#    core type: Operation
#    operator: 45
#    operands: 14
# 9. b in Integer
#    core type: Operation
#    operator: 45
#    operands: 15
# 10. c in Integer
#     core type: Operation
#     operator: 45
#     operands: 16
# 11. a <= b <= c
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (x -> {f(x) if x in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 13. (Sum_{x = a}^{b} f(x), Sum_{x = b + 1}^{c} f(x))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 14. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 53, 22
# 15. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 22
# 16. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 22
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 19. x -> {f(x) if x in {a .. c}.
#     core type: Lambda
#     parameter: 48
#     body: 25
# 20. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 27
#     operand: 32
# 21. Sum_{x = b + 1}^{c} f(x)
#     core type: Operation
#     operator: 27
#     operand: 33
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. a <= b
#     core type: Operation
#     operator: 29
#     operands: 50
# 24. b <= c
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. {f(x) if x in {a .. c}.
#     core type: Conditional
#     value: 39
#     condition: 31
# 26. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (x -> {f(x) if x in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. <=
#     core type: Literal
#     sub-expressions:
# 30. (b, c)
#     core type: ExprTuple
#     sub-expressions: 58, 55
# 31. x in {a .. c}
#     core type: Operation
#     operator: 45
#     operands: 34
# 32. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 48
#     body: 35
# 33. x -> {f(x) if x in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 48
#     body: 36
# 34. (x, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 48, 37
# 35. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 39
#     condition: 38
# 36. {f(x) if x in {b + 1 .. c}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 37. {a .. c}
#     core type: Operation
#     operator: 51
#     operands: 41
# 38. x in {a .. b}
#     core type: Operation
#     operator: 45
#     operands: 42
# 39. f(x)
#     core type: Operation
#     operator: 43
#     operand: 48
# 40. x in {b + 1 .. c}
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. (a, c)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 42. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 43. f
#     core type: Variable
#     sub-expressions:
# 44. (x)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. {a .. b}
#     core type: Operation
#     operator: 51
#     operands: 50
# 48. x
#     core type: Variable
#     sub-expressions:
# 49. {b + 1 .. c}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. (a, b)
#     core type: ExprTuple
#     sub-expressions: 53, 58
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. b + 1
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. c
#     core type: Variable
#     sub-expressions:
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. b
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
