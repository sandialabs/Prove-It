# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, n, x
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, Interval, Natural, Sum, frac, one, subtract, zero

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [x, n], instance_expr = Equals(Sum(index_or_indices = [i], summand = Exp(x, i), domain = Interval(zero, n)), frac(subtract(one, Exp(x, Add(n, one))), subtract(one, x))), domains = [Complex, Natural], condition = NotEquals(x, one))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x \in \mathbb{C}, n \in \mathbb{N}~|~x \neq 1}~\left(\left(\sum_{i = 0}^{n} x^{i}\right) = \frac{1 - x^{n + 1}}{1 - x}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x in Complex, n in Natural | x != 1} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, n) -> {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in Natural ,  x != 1.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, n) -> {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in Natural ,  x != 1.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, n)
#    core type: ExprTuple
#    sub-expressions: 52, 56
# 5. {(Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in Natural ,  x != 1.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Complex) and (n in Natural) and (x != 1)
#    core type: Operation
#    operator: 10
# ...
