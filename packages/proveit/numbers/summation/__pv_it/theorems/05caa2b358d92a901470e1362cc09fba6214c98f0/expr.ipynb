# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, f, fx, x
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, c)), Add(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(Add(b, one), c)))), domain = Integer, condition = And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left(\left(\sum_{x = a}^{c} f\left(x\right)\right) = \left(\left(\sum_{x = a}^{b} f\left(x\right)\right) + \left(\sum_{x = b + 1}^{c} f\left(x\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))))]
#    core type: Lambda
#    parameter: 52
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 52
# 4. forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x = a}^{c} f(x)) = ((Sum_{x = a}^{b} f(x)) + (Sum_{x = b + 1}^{c} f(x))))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
