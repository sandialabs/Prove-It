# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, S, a, b, f, fx, x
from proveit.logic import And, Forall, InSet, SubsetEq
from proveit.numbers import Integer, Integrate, Interval, IntervalCC, LessEq, MonDecFuncs, Real, Sum, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = IntervalCC(subtract(a, one), b)
expr = Conditional(Forall(instance_param_or_params = [a, b], instance_expr = LessEq(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Integrate(index_or_indices = sub_expr1, integrand = fx, domain = sub_expr2)), domain = Integer, conditions = [LessEq(a, b), SubsetEq(sub_expr2, S)]), And(InSet(f, MonDecFuncs(S)), SubsetEq(S, Real)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a - 1,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(\int_{a - 1}^{b} f\left(x\right)\,dx\right)\right) \textrm{ if } f \in \textrm{MonDecFuncs}\left(S\right) ,  S \subseteq \mathbb{R}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (f in MonDecFuncs(S)) and (S subset_eq Real)
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (f in MonDecFuncs(S), S subset_eq Real)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#    core type: Lambda
#    parameters: 54\n   body: 9
# 7. f in MonDecFuncs(S)
#    core type: Operation
#    operator: 48
#    operands: 10
# 8. S subset_eq Real
#    core type: Operation
#    operator: 34
#    operands: 11
# 9. {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (f, MonDecFuncs(S))
#     core type: ExprTuple
#     sub-expressions: 46, 14
# 11. (S, Real)
#     core type: ExprTuple
#     sub-expressions: 39, 15
# 12. (Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)
#     core type: Operation
#     operator: 33
#     operands: 16
# 13. (a in Integer) and (b in Integer) and (a <= b) and ([a - 1,b] subset_eq S)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. MonDecFuncs(S)
#     core type: Operation
#     operator: 19
#     operand: 39
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. (Sum_{x = a}^{b} f(x), Integrate_{a - 1}^{b} f(x)\,dx)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a in Integer, b in Integer, a <= b, [a - 1,b] subset_eq S)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26
# 19. MonDecFuncs
#     core type: Literal
#     sub-expressions:
# 20. (S)
#     core type: ExprTuple
#     sub-expressions: 39
# 21. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 27
#     operand: 36
# 22. Integrate_{a - 1}^{b} f(x)\,dx
#     core type: Operation
#     operator: 29
#     operand: 37
# 23. a in Integer
#     core type: Operation
#     operator: 48
#     operands: 31
# 24. b in Integer
#     core type: Operation
#     operator: 48
#     operands: 32
# 25. a <= b
#     core type: Operation
#     operator: 33
#     operands: 54
# 26. [a - 1,b] subset_eq S
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 29. Integrate
#     core type: Literal
#     sub-expressions:
# 30. (x -> {f(x) if x in [a - 1,b].)
#     core type: ExprTuple
#     sub-expressions: 37
# 31. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 38
# 32. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 38
# 33. <=
#     core type: Literal
#     sub-expressions:
# 34. subset_eq
#     core type: Literal
#     sub-expressions:
# 35. ([a - 1,b], S)
#     core type: ExprTuple
#     sub-expressions: 52, 39
# 36. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 51
#     body: 40
# 37. x -> {f(x) if x in [a - 1,b].
#     core type: Lambda
#     parameter: 51
#     body: 41
# 38. Integer
#     core type: Literal
#     sub-expressions:
# 39. S
#     core type: Variable
#     sub-expressions:
# 40. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 43
#     condition: 42
# 41. {f(x) if x in [a - 1,b].
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. x in {a .. b}
#     core type: Operation
#     operator: 48
#     operands: 45
# 43. f(x)
#     core type: Operation
#     operator: 46
#     operand: 51
# 44. x in [a - 1,b]
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 51, 50
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. (x)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (x, [a - 1,b])
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. {a .. b}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. [a - 1,b]
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (a, b)
#     core type: ExprTuple
#     sub-expressions: 61, 58
# 55. IntervalCC
#     core type: Literal
#     sub-expressions:
# 56. (a - 1, b)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. a - 1
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. b
#     core type: Variable
#     sub-expressions:
# 59. +
#     core type: Literal
#     sub-expressions:
# 60. (a, -1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. -1
#     core type: Operation
#     operator: 63
#     operand: 65
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. (1)
#     core type: ExprTuple
#     sub-expressions: 65
# 65. 1
#     core type: Literal
#     sub-expressions:
