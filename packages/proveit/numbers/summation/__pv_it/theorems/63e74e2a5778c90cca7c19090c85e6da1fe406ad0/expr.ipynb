# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j, k, x
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, Exp, Integer, Interval, LessEq, Sum, frac, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [x], instance_expr = Forall(instance_param_or_params = [j, k], instance_expr = Equals(Sum(index_or_indices = [i], summand = Exp(x, i), domain = Interval(j, k)), frac(subtract(Exp(x, j), Exp(x, Add(k, one))), subtract(one, x))), domain = Integer, condition = LessEq(j, k)), domain = Complex, condition = NotEquals(x, one))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x \in \mathbb{C}~|~x \neq 1}~\left[\forall_{j, k \in \mathbb{Z}~|~j \leq k}~\left(\left(\sum_{i = j}^{k} x^{i}\right) = \frac{x^{j} - x^{k + 1}}{1 - x}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x in Complex | x != 1} [forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (x -> {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. x -> {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Lambda
#    parameter: 63
#    body: 3
# 3. {forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))) if x in Complex ,  x != 1.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (x in Complex) and (x != 1)
#    core type: Operation
#    operator: 21
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x in Complex, x != 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (j, k) -> {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#    core type: Lambda
#    parameters: 59\n   body: 12
# 10. x in Complex
#     core type: Operation
#     operator: 49
#     operands: 13
# 11. x != 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {(Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j <= k.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 63, 18
# 14. !=
#     core type: Literal
#     sub-expressions:
# 15. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 63, 68
# 16. (Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (j in Integer) and (k in Integer) and (j <= k)
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (Sum_{i = j}^{k} x^{i}, (x^{j} - x^{k + 1}) / (1 - x))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (j in Integer, k in Integer, j <= k)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 23. Sum_{i = j}^{k} x^{i}
#     core type: Operation
#     operator: 28
#     operand: 35
# 24. (x^{j} - x^{k + 1}) / (1 - x)
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. j in Integer
#     core type: Operation
#     operator: 49
#     operands: 32
# 26. k in Integer
#     core type: Operation
#     operator: 49
#     operands: 33
# 27. j <= k
#     core type: Operation
#     operator: 34
#     operands: 59
# 28. Sum
#     core type: Literal
#     sub-expressions:
# 29. (i -> {x^{i} if i in {j .. k}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 30. /
#     core type: Literal
#     sub-expressions:
# 31. (x^{j} - x^{k + 1}, 1 - x)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. (j, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 38
# 33. (k, Integer)
#     core type: ExprTuple
#     sub-expressions: 67, 38
# 34. <=
#     core type: Literal
#     sub-expressions:
# 35. i -> {x^{i} if i in {j .. k}.
#     core type: Lambda
#     parameter: 55
#     body: 40
# 36. x^{j} - x^{k + 1}
#     core type: Operation
#     operator: 65
#     operands: 41
# 37. 1 - x
#     core type: Operation
#     operator: 65
#     operands: 42
# 38. Integer
#     core type: Literal
#     sub-expressions:
# 39. (i)
#     core type: ExprTuple
#     sub-expressions: 55
# 40. {x^{i} if i in {j .. k}.
#     core type: Conditional
#     value: 43
#     condition: 44
# 41. (x^{j}, -x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 68, 47
# 43. x^{i}
#     core type: Operation
#     operator: 60
#     operands: 48
# 44. i in {j .. k}
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. x^{j}
#     core type: Operation
#     operator: 60
#     operands: 51
# 46. -x^{k + 1}
#     core type: Operation
#     operator: 53
#     operand: 57
# 47. -x
#     core type: Operation
#     operator: 53
#     operand: 63
# 48. (x, i)
#     core type: ExprTuple
#     sub-expressions: 63, 55
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (i, {j .. k})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. (x, j)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 52. (x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (x)
#     core type: ExprTuple
#     sub-expressions: 63
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. {j .. k}
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. x^{k + 1}
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (j, k)
#     core type: ExprTuple
#     sub-expressions: 62, 67
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (x, k + 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 62. j
#     core type: Variable
#     sub-expressions:
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. k + 1
#     core type: Operation
#     operator: 65
#     operands: 66
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. k
#     core type: Variable
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
