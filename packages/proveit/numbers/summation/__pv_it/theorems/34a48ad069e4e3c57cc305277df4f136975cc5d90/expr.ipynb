# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, a, b, f, fx, x
from proveit.logic import Forall, SubsetEq
from proveit.numbers import Integer, Integrate, Interval, IntervalCC, LessEq, MonDecFuncs, Real, Sum, one, subtract

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = IntervalCC(subtract(a, one), b)
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = LessEq(Sum(index_or_indices = sub_expr1, summand = fx, domain = Interval(a, b)), Integrate(index_or_indices = sub_expr1, integrand = fx, domain = sub_expr2)), domain = Integer, conditions = [LessEq(a, b), SubsetEq(sub_expr2, S)]), domain = MonDecFuncs(S), condition = SubsetEq(S, Real))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f \in \textrm{MonDecFuncs}\left(S\right)~|~S \subseteq \mathbb{R}}~\left[\forall_{a, b \in \mathbb{Z}~|~a \leq b, \left[a - 1,b\right] \subseteq S}~\left(\left(\sum_{x = a}^{b} f\left(x\right)\right) \leq \left(\int_{a - 1}^{b} f\left(x\right)\,dx\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (f -> {forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)) if f in MonDecFuncs(S) ,  S subset_eq Real.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> {forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Lambda
#    parameter: 50
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 50
# 4. {forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)) if f in MonDecFuncs(S) ,  S subset_eq Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a, b in Integer | a <= b, [a - 1,b] subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (f in MonDecFuncs(S)) and (S subset_eq Real)
#    core type: Operation
#    operator: 21
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (f in MonDecFuncs(S), S subset_eq Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a, b) -> {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#     core type: Lambda
#     parameters: 58\n    body: 13
# 11. f in MonDecFuncs(S)
#     core type: Operation
#     operator: 52
#     operands: 14
# 12. S subset_eq Real
#     core type: Operation
#     operator: 38
#     operands: 15
# 13. {(Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx) if a in Integer ,  b in Integer ,  a <= b ,  [a - 1,b] subset_eq S.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. (f, MonDecFuncs(S))
#     core type: ExprTuple
#     sub-expressions: 50, 18
# 15. (S, Real)
#     core type: ExprTuple
#     sub-expressions: 43, 19
# 16. (Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx)
#     core type: Operation
#     operator: 37
#     operands: 20
# 17. (a in Integer) and (b in Integer) and (a <= b) and ([a - 1,b] subset_eq S)
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. MonDecFuncs(S)
#     core type: Operation
#     operator: 23
#     operand: 43
# 19. Real
#     core type: Literal
#     sub-expressions:
# 20. (Sum_{x = a}^{b} f(x), Integrate_{a - 1}^{b} f(x)\,dx)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (a in Integer, b in Integer, a <= b, [a - 1,b] subset_eq S)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30
# 23. MonDecFuncs
#     core type: Literal
#     sub-expressions:
# 24. (S)
#     core type: ExprTuple
#     sub-expressions: 43
# 25. Sum_{x = a}^{b} f(x)
#     core type: Operation
#     operator: 31
#     operand: 40
# 26. Integrate_{a - 1}^{b} f(x)\,dx
#     core type: Operation
#     operator: 33
#     operand: 41
# 27. a in Integer
#     core type: Operation
#     operator: 52
#     operands: 35
# 28. b in Integer
#     core type: Operation
#     operator: 52
#     operands: 36
# 29. a <= b
#     core type: Operation
#     operator: 37
#     operands: 58
# 30. [a - 1,b] subset_eq S
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 33. Integrate
#     core type: Literal
#     sub-expressions:
# 34. (x -> {f(x) if x in [a - 1,b].)
#     core type: ExprTuple
#     sub-expressions: 41
# 35. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 42
# 36. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 42
# 37. <=
#     core type: Literal
#     sub-expressions:
# 38. subset_eq
#     core type: Literal
#     sub-expressions:
# 39. ([a - 1,b], S)
#     core type: ExprTuple
#     sub-expressions: 56, 43
# 40. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 55
#     body: 44
# 41. x -> {f(x) if x in [a - 1,b].
#     core type: Lambda
#     parameter: 55
#     body: 45
# 42. Integer
#     core type: Literal
#     sub-expressions:
# 43. S
#     core type: Variable
#     sub-expressions:
# 44. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 47
#     condition: 46
# 45. {f(x) if x in [a - 1,b].
#     core type: Conditional
#     value: 47
#     condition: 48
# 46. x in {a .. b}
#     core type: Operation
#     operator: 52
#     operands: 49
# 47. f(x)
#     core type: Operation
#     operator: 50
#     operand: 55
# 48. x in [a - 1,b]
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (x)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (x, [a - 1,b])
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. {a .. b}
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. x
#     core type: Variable
#     sub-expressions:
# 56. [a - 1,b]
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (a, b)
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 59. IntervalCC
#     core type: Literal
#     sub-expressions:
# 60. (a - 1, b)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. a - 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. b
#     core type: Variable
#     sub-expressions:
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (a, -1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. -1
#     core type: Operation
#     operator: 67
#     operand: 69
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. 1
#     core type: Literal
#     sub-expressions:
