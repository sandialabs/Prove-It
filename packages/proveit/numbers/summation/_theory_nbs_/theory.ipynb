# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">numbers</a>.summation
# ========
#
# Provide description here.

# %%
import proveit
# %theory
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#sum_single">proveit.numbers.summation.sum_single</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/1ae8b6efa23aa0f7a8d8881b3266f995edd258520/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
