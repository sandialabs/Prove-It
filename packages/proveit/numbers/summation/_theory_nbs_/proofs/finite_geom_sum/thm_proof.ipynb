# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">summation</a>.<a class="ProveItLink" href="../../theorems.ipynb#finite_geom_sum">finite_geom_sum</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, defaults, Function, m, n, P, x
from proveit.logic import Equals, InSet, Not, NotEquals
from proveit.numbers import zero, one, Add, Div, frac, Less, LessEq, Mult, Neg, subtract
from proveit.numbers import Complex, Natural
from proveit.numbers.negation import neg_not_eq_zero
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural

# %%
# %proving finite_geom_sum
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="finite_geom_sum">finite_geom_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/5ec8e414dc010a6105e0fb7d15458d4343bd67d20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dc74ff74bbf98dcb038a9fc6b1d2fe7582e2850a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = finite_geom_sum.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3230b50235837dde65d24a8fb202b9739a6cbf940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Mult.change_simplification_directives(combine_all_exponents=True)

# %% [markdown]
# ### Instantiate the Induction Theorem for an induction proof

# %%
finite_geom_sum.instance_expr
# Out:
# (Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))

# %%
fold_forall_natural
# Out:
# |- forall_{P} ((P(0) and [forall_{m in Natural | P(m)} P(m + 1)]) => [forall_{n in Natural} P(n)])

# %%
induction_inst = fold_forall_natural.instantiate({Function(P,n):finite_geom_sum.instance_expr})
# Out:
# <strong id="induction_inst">induction_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/9d9c498d6dba96f4adbb163bd45091563d7c0b740/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/35b187b93ddd33b6a59e749c41d88ec7ce1b41160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# *Note that the base case was proven automatically via auto-simplification.*

# %% [markdown]
# ### Inductive Step

# %%
inductive_step = induction_inst.antecedent.operands[1]
# Out:
# <strong id="inductive_step">inductive_step:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/3d8d68a152aaa5a9f5b60c0475e8402caa2865e50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
inductive_step.conditions.entries
# Out:
# (m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)))

# %%
defaults.assumptions = defaults.assumptions + inductive_step.conditions.entries
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/b43954af3fe20485b24d8203d59c00435d6981f70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
sum_zero_to_m_plus_one = induction_inst.antecedent.operands[1].instance_expr.lhs
# Out:
# <strong id="sum_zero_to_m_plus_one">sum_zero_to_m_plus_one:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/0544b6739d17247f0d936bda30d3c1b87ca8cdc00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
zero_less_eq_m = LessEq(zero, m).prove()
# Out:
# <strong id="zero_less_eq_m">zero_less_eq_m:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/86a962667cf2d1b93ffcdae5470501c8c54edde70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/00ae78e9a966899d3dda7231c277fe5e88eb25630/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
zero_less_eq_m.right_add_both_sides(one)
# Out:
# {m in Natural} |- 1 <= (m + 1)

# %%
zero_less_than_m_plus_1 = Less(zero, Add(m, one)).prove()
# Out:
# <strong id="zero_less_than_m_plus_1">zero_less_than_m_plus_1:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/06f0aefb3015dc7171f87828df62c0711430c84e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/02f57d9fd0f9c3f3d401dd071fbc45c3a665a6ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# also need to have m+1 != -1 for later inductive step(s)
neg_one_less_than_m_plus_1 = zero_less_than_m_plus_1.add_left(Neg(one))
# Out:
# <strong id="neg_one_less_than_m_plus_1">neg_one_less_than_m_plus_1:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/4b59cb978e5c59eba1afe85a72c578acbbc69d860/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/fa6e96d7d9c41e14f1472af8685bf85a56f9c8cb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
NotEquals(Neg(one), Add(m, one)).prove()
# Out:
# {m in Natural} |- (-1) != (m + 1)

# %%
sum_zero_to_m_plus_one_split = sum_zero_to_m_plus_one.partition_last()
# Out:
# <strong id="sum_zero_to_m_plus_one_split">sum_zero_to_m_plus_one_split:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/934110f1cfa9dd8cfa0905f95e0da0dc0f827bf30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/ff2943dc4e1d108136e93962a8c80a82b24cae030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
for the_assumption in defaults.assumptions:
    if isinstance(the_assumption, Equals):
        print("{}".format(the_assumption))
        inductive_hypothesis = the_assumption
inductive_hypothesis
# Out:
# (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
# (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))

# %%
inductive_hypothesis_judgment = inductive_hypothesis.prove()
# Out:
# <strong id="inductive_hypothesis_judgment">inductive_hypothesis_judgment:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/7bfbfedc7167f6a9a037a0cdf3daf00ed0ad97000/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sum_zero_to_m_plus_one_simplified_01 = inductive_hypothesis_judgment.sub_right_side_into(sum_zero_to_m_plus_one_split)
# Out:
# <strong id="sum_zero_to_m_plus_one_simplified_01">sum_zero_to_m_plus_one_simplified_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/97f2426b9d8d49fffaca03b2b927c193ee45e6570/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/f2a7d132e13278abc8b7deffba7dc5b36fce415b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alg_expr_01 = sum_zero_to_m_plus_one_simplified_01.rhs.operands[1]
# Out:
# <strong id="alg_expr_01">alg_expr_01:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/fdaad199028fc16e0f515fd290cc65222637fd920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
alg_expr_02 = frac(Mult(subtract(one, x), alg_expr_01), subtract(one, x))
# Out:
# <strong id="alg_expr_02">alg_expr_02:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/2821acd27cf1b4e705e0268a8dbb7f6c8de0eb6e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
alg_manip_01 = alg_expr_02.cancelation(subtract(one, x))
# Out:
# <strong id="alg_manip_01">alg_manip_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/6b508e248e3711b0ac15741f789d60b2416c36dd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/73d78fa4b55e786a80c6eb5811b771867f6a80070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sum_zero_to_m_plus_one_simplified_02 = (
    alg_manip_01.sub_left_side_into(sum_zero_to_m_plus_one_simplified_01.
    inner_expr().rhs.operands[1]))
# Out:
# <strong id="sum_zero_to_m_plus_one_simplified_02">sum_zero_to_m_plus_one_simplified_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/bd893486fb6a577e669d80b412b117f836a504e40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/7597e864555f89c455b9c0cddc0688f6731f07b40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sum_zero_to_m_plus_one_simplified_03 = sum_zero_to_m_plus_one_simplified_02.inner_expr().rhs.operands[1].numerator.distribute(0)
# Out:
# <strong id="sum_zero_to_m_plus_one_simplified_03">sum_zero_to_m_plus_one_simplified_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e70ce164ab7d266ec90e10e2331348efebd3f98d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/bb881159e4d5f37c84f42c6ee9f2a074274917170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sum_zero_to_m_plus_one_simplified_04 = sum_zero_to_m_plus_one_simplified_03.inner_expr().rhs.factor(frac(one, subtract(one, x)))
# Out:
# <strong id="sum_zero_to_m_plus_one_simplified_04">sum_zero_to_m_plus_one_simplified_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e80bc806309fd6c62717ed4632e6eddd2cbbbfc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/0189a11a638a55155e652c70b70ec16ce98a822c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/6d73cee543af17e2c457047db25e2f4ed65203520/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Less(Neg(one), Add(m, one)).prove()
# Out:
# {m in Natural} |- (-1) < (m + 1)

# %%
sum_zero_to_m_plus_one_formula = inductive_step.instance_expr.rhs.factorization(frac(one, subtract(one, x)))
# Out:
# <strong id="sum_zero_to_m_plus_one_formula">sum_zero_to_m_plus_one_formula:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/47de90a2f33f8b52cbee7743781f250244e7f67b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/1fd7a37e2d10ef6ecfa25d60298556652ffcb0620/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/c817e556110dae887a02c9d15bc0fb7493b825890/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sum_zero_to_m_plus_one_formula.inner_expr().rhs.operands[1].operands[1].operand.exponent.commute()
# Out:
# {x in Complex, m in Natural, x != 1} |- ((1 - x^{m + 2}) / (1 - x)) = ((1 / (1 - x)) * (1 - x^{2 + m}))

# %%
inductive_step.instance_expr.conclude_via_transitivity()
# Out:
# {m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)), x in Complex, x != 1} |- (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))

# %%
inductive_step.prove()
# Out:
# {x in Complex, x != 1} |- forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))

# %% [markdown]
# ### Finishing Up
#
# The final steps are a little complicated because of the extra constraints in the theorem imposed on $x$ (_i.e._ $x \in \mathbb{C}, x \ne 1$), so we derive the consequent but then instantiate to get domains and conditions as assumptions, and then generalize over the $x$ and $n$ simultaneously.

# %%
induction_inst_consequent_intermediate = induction_inst.derive_consequent()
# Out:
# <strong id="induction_inst_consequent_intermediate">induction_inst_consequent_intermediate:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/730b8e80abd4daddf9e8b27dc005c131ae3969570/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/6e8965025ba160812539ea5d60534c634f345b4a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# finite_geom_sum may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
induction_inst_consequent_intermediate_inst = induction_inst_consequent_intermediate.instantiate({n:n})
# Out:
# <strong id="induction_inst_consequent_intermediate_inst">induction_inst_consequent_intermediate_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/6bf1a18c2e3498be826f1c5ef7caab578b7ee8c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/af76701477db06fad8882e67ea596653971f406b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_finite_geom_sum/e36af9b52820b5dc3788ef542e195c645fa450db0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/b44afc90e1fb1b06a67c4d47f93cd96e2ab829010/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
induction_inst_consequent_intermediate_inst.generalize([x,n], domain_lists=[[Complex, Natural]], conditions=[NotEquals(x, one)])
# Out:
# |- forall_{x in Complex, n in Natural | x != 1} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))

# %%
# %qed
# Out:
# proveit.numbers.summation.finite_geom_sum has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x in Complex, n in Natural | x != 1} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))
# 1	instantiation	2, 3	{x in Complex, x != 1, n in Natural} |- (Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))
# 	n : n
# 2	modus ponens	4, 5	{x in Complex, x != 1} |- forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))
# 3	assumption		{n in Natural} |- n in Natural
# 4	instantiation	6, 7*, 8*	{x in Complex, x != 1} |- (TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]) => [forall_{n in Natural} ((Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x)))]
# 	P(n) : (Sum_{i = 0}^{n} x^{i}) = ((1 - x^{n + 1}) / (1 - x))
# 5	instantiation	9, 10, 11	{x in Complex, x != 1} |- TRUE and [forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))]
# 	A : TRUE, B : forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))
# 6	conjecture		|- forall_{P} ((P(0) and [forall_{m in Natural | P(m)} P(m + 1)]) => [forall_{n in Natural} P(n)])
# 	proveit.numbers.number_sets.natural_numbers.fold_forall_natural
# 7	instantiation	108, 12, 13	{x in Complex, x != 1} |- ((Sum_{i = 0}^{0} x^{i}) = ((1 - x^{0 + 1}) / (1 - x))) = TRUE
# 	x : (Sum_{i = 0}^{0} x^{i}) = ((1 - x^{0 + 1}) / (1 - x)), y : 1 = 1, z : TRUE
# 8	instantiation	108, 14, 15	{m in Natural} |- ((m + 1) + 1) = (m + 2)
# 	x : (m + 1) + 1, y : m + 1 + 1, z : m + 2
# 9	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 10	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
# 11	generalization	16	{x in Complex, x != 1} |- forall_{m in Natural | (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} ((Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x)))
# 12	instantiation	17, 178, 18, 132, 19, 20	{x in Complex, x != 1} |- ((Sum_{i = 0}^{0} x^{i}) = ((1 - x^{0 + 1}) / (1 - x))) =  \\ (1 = 1)
# 	n : 2, f(_a, _b) : _a = _b, x : (Sum_{i = 0}^{0} x^{i}, (1 - x^{0 + 1}) / (1 - x)), y : (1, 1)
# 13	instantiation	21, 125	|- (1 = 1) = TRUE
# 	A : 1 = 1
# 14	instantiation	121, 130, 178, 175, 131, 122, 157, 139	{m in Natural} |- ((m + 1) + 1) =  \\ (m + 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (m, 1), c : (1)
# 15	instantiation	129, 175, 178, 130, 132, 131, 157, 139, 133*	{m in Natural} |- (m + 1 + 1) =  \\ (m + 2)
# 	i : 1, j : 2, k : 0, a : (m), b : (1, 1), c : ()
# 16	instantiation	108, 22, 23	{m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)), x in Complex, x != 1} |- (Sum_{i = 0}^{m + 1} x^{i}) = ((1 - x^{m + 2}) / (1 - x))
# 	x : Sum_{i = 0}^{m + 1} x^{i}, y : (1 / (1 - x)) * (1 - x^{2 + m}), z : (1 - x^{m + 2}) / (1 - x)
# 17	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 18	instantiation	143	|- |(Sum_{i = 0}^{0} x^{i}, (1 - x^{0 + 1}) / (1 - x))| = |(1, ..., 2)|
# 	a : Sum_{i = 0}^{0} x^{i}, b : (1 - x^{0 + 1}) / (1 - x)
# 19	instantiation	24, 82, 25*	{x in Complex} |- (Sum_{_a = 0}^{0} x^{_a}) = 1
# 	f(i) : x^{i}, a : 0
# 20	instantiation	108, 26, 27	{x in Complex, x != 1} |- ((1 - x^{0 + 1}) / (1 - x)) = 1
# 	x : (1 - x^{0 + 1}) / (1 - x), y : (1 - x) / (1 - x), z : 1
# 21	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 22	instantiation	59, 28, 29	{m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)), x in Complex, x != 1} |- (Sum_{i = 0}^{m + 1} x^{i}) = ((1 / (1 - x)) * (1 - x^{2 + m}))
# 	P(_a) : (Sum_{i = 0}^{m + 1} x^{i}) = _a, x : ((1 - x^{m + 1}) / (1 - x)) + ((x^{m + 1} - x^{2 + m}) / (1 - x)), y : (1 / (1 - x)) * (1 - x^{2 + m})
# 23	instantiation	70, 30	{x in Complex, m in Natural, x != 1} |- ((1 / (1 - x)) * (1 - x^{2 + m})) = ((1 - x^{m + 2}) / (1 - x))
# 	x : (1 - x^{m + 2}) / (1 - x), y : (1 / (1 - x)) * (1 - x^{2 + m})
# 24	axiom		|- forall_{f} [forall_{a in Integer} ((Sum_{x = a}^{a} f(x)) = f(a))]
# 	proveit.numbers.summation.sum_single
# 25	instantiation	31, 151	{x in Complex} |- x^{0} = 1
# 	a : x
# 26	instantiation	99, 32	{x in Complex} |- ((1 - x^{0 + 1}) / (1 - x)) = ((1 - x) / (1 - x))
# 	f(_a) : _a / (1 - x), x : 1 - x^{0 + 1}, y : 1 - x
# 27	instantiation	33, 96, 97	{x in Complex, x != 1} |- ((1 - x) / (1 - x)) = 1
# 	x : 1 - x
# 28	instantiation	59, 34, 35	{m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)), x in Complex, x != 1} |- (Sum_{i = 0}^{m + 1} x^{i}) = (((1 - x^{m + 1}) / (1 - x)) + ((x^{m + 1} - x^{2 + m}) / (1 - x)))
# 	P(_a) : (Sum_{i = 0}^{m + 1} x^{i}) = (((1 - x^{m + 1}) / (1 - x)) + (_a / (1 - x))), x : (1 - x) * x^{m + 1}, y : x^{m + 1} - x^{2 + m}
# 29	instantiation	52, 36, 37, 38, 39*	{x in Complex, m in Natural, x != 1} |- (((1 - x^{m + 1}) / (1 - x)) + ((x^{m + 1} - x^{2 + m}) / (1 - x))) = ((1 / (1 - x)) * (1 - x^{2 + m}))
# 	a : ((1 - x^{m + 1}) / (1 - x)) + ((x^{m + 1} - x^{2 + m}) / (1 - x)), b : ((1 / (1 - x)) * (1 - x^{m + 1})) + ((x^{m + 1} - x^{2 + m}) / (1 - x)), c : ((1 / (1 - x)) * (1 - x^{m + 1})) + ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m})), d : (1 / (1 - x)) * ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m}))
# 30	instantiation	59, 40, 41	{x in Complex, m in Natural, x != 1} |- ((1 - x^{m + 2}) / (1 - x)) = ((1 / (1 - x)) * (1 - x^{2 + m}))
# 	P(_a) : ((1 - x^{m + 2}) / (1 - x)) = ((1 / (1 - x)) * (1 - x^{_a})), x : m + 2, y : 2 + m
# 31	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 	proveit.numbers.exponentiation.exp_zero_eq_one
# 32	instantiation	99, 42	{x in Complex} |- (1 - x^{0 + 1}) = (1 - x)
# 	f(_a) : 1 + _a, x : -x^{0 + 1}, y : -x
# 33	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 34	instantiation	43, 44, 45	{m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x)), x in Complex, x != 1} |- (Sum_{i = 0}^{m + 1} x^{i}) = (((1 - x^{m + 1}) / (1 - x)) + (((1 - x) * x^{m + 1}) / (1 - x)))
# 	P(_a) : (Sum_{i = 0}^{m + 1} x^{i}) = (((1 - x^{m + 1}) / (1 - x)) + _a), x : ((1 - x) * x^{m + 1}) / (1 - x), y : x^{m + 1}
# 35	instantiation	46, 130, 175, 131, 139, 151, 144, 47*, 48*	{x in Complex, m in Natural} |- ((1 - x) * x^{m + 1}) =  \\ (x^{m + 1} - x^{2 + m})
# 	i : 0, j : 1, a : (), x : 1, y : x, b : (x^{m + 1})
# 36	instantiation	99, 49	{x in Complex, m in Natural, x != 1} |- (((1 - x^{m + 1}) / (1 - x)) + ((x^{m + 1} - x^{2 + m}) / (1 - x))) = (((1 / (1 - x)) * (1 - x^{m + 1})) + ((x^{m + 1} - x^{2 + m}) / (1 - x)))
# 	f(_a) : _a + ((x^{m + 1} - x^{2 + m}) / (1 - x)), x : (1 - x^{m + 1}) / (1 - x), y : (1 / (1 - x)) * (1 - x^{m + 1})
# 37	instantiation	99, 50	{x in Complex, m in Natural, x != 1} |- (((1 / (1 - x)) * (1 - x^{m + 1})) + ((x^{m + 1} - x^{2 + m}) / (1 - x))) = (((1 / (1 - x)) * (1 - x^{m + 1})) + ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m})))
# 	f(_a) : ((1 / (1 - x)) * (1 - x^{m + 1})) + _a, x : (x^{m + 1} - x^{2 + m}) / (1 - x), y : (1 / (1 - x)) * (x^{m + 1} - x^{2 + m})
# 38	instantiation	70, 51	{x in Complex, x != 1, m in Natural} |- (((1 / (1 - x)) * (1 - x^{m + 1})) + ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m}))) = ((1 / (1 - x)) * ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m})))
# 	x : (1 / (1 - x)) * ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m})), y : ((1 / (1 - x)) * (1 - x^{m + 1})) + ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m}))
# 39	instantiation	52, 53, 54, 55	{x in Complex, m in Natural} |- ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m})) = (1 - x^{2 + m})
# 	a : (1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m}), b : 1 - x^{m + 1} + (x^{m + 1} - x^{2 + m}), c : 1 - x^{m + 1} + x^{m + 1} - x^{2 + m}, d : 1 - x^{2 + m}
# 40	instantiation	70, 56	{x in Complex, m in Natural, x != 1} |- ((1 - x^{m + 2}) / (1 - x)) = ((1 / (1 - x)) * (1 - x^{m + 2}))
# 	x : (1 / (1 - x)) * (1 - x^{m + 2}), y : (1 - x^{m + 2}) / (1 - x)
# 41	instantiation	57, 157, 156	{m in Natural} |- (m + 2) = (2 + m)
# 	a : m, b : 2
# 42	instantiation	99, 58	{x in Complex} |- (-x^{0 + 1}) = (-x)
# 	f(_a) : -_a, x : x^{0 + 1}, y : x
# 43	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 44	instantiation	59, 60, 61	{m in Natural, (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} |- (Sum_{i = 0}^{m + 1} x^{i}) = (((1 - x^{m + 1}) / (1 - x)) + x^{m + 1})
# 	P(_a) : (Sum_{i = 0}^{m + 1} x^{i}) = (_a + x^{m + 1}), x : Sum_{i = 0}^{m} x^{i}, y : (1 - x^{m + 1}) / (1 - x)
# 45	instantiation	62, 63, 64, 144, 65*, 66*	{x in Complex, x != 1, m in Natural} |- (((1 - x) * x^{m + 1}) / (1 - x)) = x^{m + 1}
# 	x : 1 - x, z : 1, y : x^{m + 1}
# 46	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))]
# 	proveit.numbers.multiplication.distribute_through_subtract
# 47	instantiation	112, 144	{x in Complex, m in Natural} |- (1 * x^{m + 1}) = x^{m + 1}
# 	x : x^{m + 1}
# 48	instantiation	67, 151, 142, 103, 80*, 68*	{x in Complex, m in Natural} |- (x * x^{m + 1}) = x^{2 + m}
# 	a : x, m : 1, n : m + 1
# 49	instantiation	70, 69	{x in Complex, m in Natural, x != 1} |- ((1 - x^{m + 1}) / (1 - x)) = ((1 / (1 - x)) * (1 - x^{m + 1}))
# 	x : (1 / (1 - x)) * (1 - x^{m + 1}), y : (1 - x^{m + 1}) / (1 - x)
# 50	instantiation	70, 71	{x in Complex, m in Natural, x != 1} |- ((x^{m + 1} - x^{2 + m}) / (1 - x)) = ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m}))
# 	x : (1 / (1 - x)) * (x^{m + 1} - x^{2 + m}), y : (x^{m + 1} - x^{2 + m}) / (1 - x)
# 51	instantiation	72, 175, 178, 130, 73, 131, 74, 111, 113	{x in Complex, x != 1, m in Natural} |- ((1 / (1 - x)) * ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m}))) =  \\ (((1 / (1 - x)) * (1 - x^{m + 1})) + ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m})))
# 	i : 1, j : 2, k : 0, a : (1 / (1 - x)), b : (1 - x^{m + 1}, x^{m + 1} - x^{2 + m}), c : ()
# 52	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 53	instantiation	121, 130, 178, 175, 131, 75, 139, 134, 113	{x in Complex, m in Natural} |- ((1 - x^{m + 1}) + (x^{m + 1} - x^{2 + m})) =  \\ (1 - x^{m + 1} + (x^{m + 1} - x^{2 + m}))
# 	i : 0, j : 2, k : 1, a : (), b : (1, -x^{m + 1}), c : (x^{m + 1} - x^{2 + m})
# 54	instantiation	121, 178, 130, 75, 76, 131, 139, 134, 144, 135	{x in Complex, m in Natural} |- (1 - x^{m + 1} + (x^{m + 1} - x^{2 + m})) =  \\ (1 - x^{m + 1} + x^{m + 1} - x^{2 + m})
# 	i : 2, j : 2, k : 0, a : (1, -x^{m + 1}), b : (x^{m + 1}, -x^{2 + m}), c : ()
# 55	instantiation	77, 175, 130, 131, 139, 144, 135	{x in Complex, m in Natural} |- (1 - x^{m + 1} + x^{m + 1} - x^{2 + m}) = (1 - x^{2 + m})
# 	i : 1, j : 0, k : 1, a : (1), b : x^{m + 1}, c : (), d : x^{m + 1}, e : (-x^{2 + m})
# 56	instantiation	93, 139, 98, 96, 97, 78*	{x in Complex, m in Natural, x != 1} |- ((1 / (1 - x)) * (1 - x^{m + 2})) = ((1 - x^{m + 2}) / (1 - x))
# 	x : 1, y : 1 - x^{m + 2}, z : 1 - x
# 57	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 58	instantiation	108, 79, 80	{x in Complex} |- x^{0 + 1} = x
# 	x : x^{0 + 1}, y : x^{1}, z : x
# 59	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 60	instantiation	81, 82, 162, 83, 84*	{m in Natural} |- (Sum_{i = 0}^{m + 1} x^{i}) = ((Sum_{i = 0}^{m} x^{i}) + x^{m + 1})
# 	f(i) : x^{i}, a : 0, b : m + 1, x : i
# 61	assumption		{(Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))} |- (Sum_{i = 0}^{m} x^{i}) = ((1 - x^{m + 1}) / (1 - x))
# 62	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 63	instantiation	85, 96, 97	{x in Complex, x != 1} |- (1 - x) in ComplexNonZero
# 	x : 1 - x
# 64	instantiation	176, 86, 87	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 65	instantiation	88, 96	{x in Complex} |- ((1 - x) * 1) = (1 - x)
# 	x : 1 - x
# 66	instantiation	89, 144	{x in Complex, m in Natural} |- (x^{m + 1} / 1) = x^{m + 1}
# 	x : x^{m + 1}
# 67	conjecture		|- forall_{a in Complex, m in NaturalPos, n in NaturalPos} ((a^{m} * a^{n}) = a^{m + n})
# 	proveit.numbers.exponentiation.product_of_posnat_powers
# 68	instantiation	108, 90, 91	{m in Natural} |- (1 + (m + 1)) = (2 + m)
# 	x : 1 + (m + 1), y : 1 + m + 1, z : 2 + m
# 69	instantiation	93, 139, 111, 96, 97, 92*	{x in Complex, m in Natural, x != 1} |- ((1 / (1 - x)) * (1 - x^{m + 1})) = ((1 - x^{m + 1}) / (1 - x))
# 	x : 1, y : 1 - x^{m + 1}, z : 1 - x
# 70	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 71	instantiation	93, 139, 113, 96, 97, 94*	{x in Complex, m in Natural, x != 1} |- ((1 / (1 - x)) * (x^{m + 1} - x^{2 + m})) = ((x^{m + 1} - x^{2 + m}) / (1 - x))
# 	x : 1, y : x^{m + 1} - x^{2 + m}, z : 1 - x
# 72	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 73	instantiation	143	|- |(1 - x^{m + 1}, x^{m + 1} - x^{2 + m})| = |(1, ..., 2)|
# 	a : 1 - x^{m + 1}, b : x^{m + 1} - x^{2 + m}
# 74	instantiation	95, 139, 96, 97	{x in Complex, x != 1} |- (1 / (1 - x)) in Complex
# 	a : 1, b : 1 - x
# 75	instantiation	143	|- |(1, -x^{m + 1})| = |(1, ..., 2)|
# 	a : 1, b : -x^{m + 1}
# 76	instantiation	143	|- |(x^{m + 1}, -x^{2 + m})| = |(1, ..., 2)|
# 	a : x^{m + 1}, b : -x^{2 + m}
# 77	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general_rev
# 78	instantiation	112, 98	{x in Complex, m in Natural} |- (1 * (1 - x^{m + 2})) = (1 - x^{m + 2})
# 	x : 1 - x^{m + 2}
# 79	instantiation	99, 100	|- x^{0 + 1} = x^{1}
# 	f(_a) : x^{_a}, x : 0 + 1, y : 1
# 80	instantiation	101, 151	{x in Complex} |- x^{1} = x
# 	x : x
# 81	axiom		|- forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = ((Sum_{x = a}^{b - 1} f(x)) + f(b)))]
# 	proveit.numbers.summation.sum_split_last
# 82	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 83	instantiation	102, 103	{m in Natural} |- (m + 1) > 0
# 	n : m + 1
# 84	instantiation	108, 104, 105	{m in Natural} |- ((m + 1) - 1) = m
# 	x : (m + 1) - 1, y : m + 1 - 1, z : m
# 85	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 	proveit.numbers.number_sets.complex_numbers.nonzero_complex_is_complex_nonzero
# 86	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 87	instantiation	176, 106, 107	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 88	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 89	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 90	instantiation	121, 175, 178, 130, 122, 131, 139, 157	{m in Natural} |- (1 + (m + 1)) =  \\ (1 + m + 1)
# 	i : 1, j : 2, k : 0, a : (1), b : (m, 1), c : ()
# 91	instantiation	108, 109, 110	{m in Natural} |- (1 + m + 1) = (2 + m)
# 	x : 1 + m + 1, y : 1 + 1 + m, z : 2 + m
# 92	instantiation	112, 111	{x in Complex, m in Natural} |- (1 * (1 - x^{m + 1})) = (1 - x^{m + 1})
# 	x : 1 - x^{m + 1}
# 93	conjecture		|- forall_{x, y, z in Complex | z != 0} (((x / z) * y) = ((x * y) / z))
# 	proveit.numbers.division.mult_frac_left
# 94	instantiation	112, 113	{x in Complex, m in Natural} |- (1 * (x^{m + 1} - x^{2 + m})) = (x^{m + 1} - x^{2 + m})
# 	x : x^{m + 1} - x^{2 + m}
# 95	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 96	instantiation	155, 139, 114	{x in Complex} |- (1 - x) in Complex
# 	a : 1, b : -x
# 97	instantiation	115, 116	{x != 1} |- (1 - x) != 0
# 	a : 1, b : x
# 98	instantiation	155, 139, 117	{x in Complex, m in Natural} |- (1 - x^{m + 2}) in Complex
# 	a : 1, b : -x^{m + 2}
# 99	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 100	instantiation	118, 139	|- (0 + 1) = 1
# 	a : 1
# 101	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 102	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 103	instantiation	119, 175, 130, 131, 174, 120	{m in Natural} |- (m + 1) in NaturalPos
# 	i : 1, j : 0, a : (m), b : 1, c : ()
# 104	instantiation	121, 130, 178, 175, 131, 122, 157, 139, 123	{m in Natural} |- ((m + 1) - 1) =  \\ (m + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (m, 1), c : (-1)
# 105	instantiation	124, 139, 157, 125	{m in Natural} |- (m + 1 - 1) = m
# 	a : 1, b : 1, c : m
# 106	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 107	instantiation	176, 126, 127	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 108	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 109	instantiation	128, 175, 130, 131, 139, 157	{m in Natural} |- (1 + m + 1) =  \\ (1 + 1 + m)
# 	i : 1, j : 1, k : 0, a : (1), b : (m), c : 1, d : ()
# 110	instantiation	129, 130, 178, 175, 131, 132, 139, 157, 133*	{m in Natural} |- (1 + 1 + m) =  \\ (2 + m)
# 	i : 0, j : 2, k : 1, a : (), b : (1, 1), c : (m)
# 111	instantiation	155, 139, 134	{x in Complex, m in Natural} |- (1 - x^{m + 1}) in Complex
# 	a : 1, b : -x^{m + 1}
# 112	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 113	instantiation	155, 144, 135	{x in Complex, m in Natural} |- (x^{m + 1} - x^{2 + m}) in Complex
# 	a : x^{m + 1}, b : -x^{2 + m}
# 114	instantiation	145, 151	{x in Complex} |- (-x) in Complex
# 	a : x
# 115	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 116	instantiation	136, 137	{x != 1} |- 1 != x
# 	x : x, y : 1
# 117	instantiation	145, 138	{x in Complex, m in Natural} |- (-x^{m + 2}) in Complex
# 	a : x^{m + 2}
# 118	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 119	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Natural | b > 0} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) in NaturalPos)]
# 	proveit.numbers.addition.add_nat_pos_from_nonneg
# 120	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 121	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 122	instantiation	143	|- |(m, 1)| = |(1, ..., 2)|
# 	a : m, b : 1
# 123	instantiation	145, 139	|- (-1) in Complex
# 	a : 1
# 124	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 125	instantiation	140	|- 1 = 1
# 	x : 1
# 126	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 127	instantiation	176, 141, 142	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 128	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
# 	proveit.numbers.addition.leftward_commutation
# 129	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 130	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 131	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 132	instantiation	143	|- |(1, 1)| = |(1, ..., 2)|
# 	a : 1, b : 1
# 133	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 134	instantiation	145, 144	{x in Complex, m in Natural} |- (-x^{m + 1}) in Complex
# 	a : x^{m + 1}
# 135	instantiation	145, 146	{x in Complex, m in Natural} |- (-x^{2 + m}) in Complex
# 	a : x^{2 + m}
# 136	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 137	assumption		{x != 1} |- x != 1
# 138	instantiation	150, 151, 147	{x in Complex, m in Natural} |- x^{m + 2} in Complex
# 	a : x, b : m + 2
# 139	instantiation	176, 160, 148	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 140	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 141	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 142	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 143	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 144	instantiation	150, 151, 149	{x in Complex, m in Natural} |- x^{m + 1} in Complex
# 	a : x, b : m + 1
# 145	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 146	instantiation	150, 151, 152	{x in Complex, m in Natural} |- x^{2 + m} in Complex
# 	a : x, b : 2 + m
# 147	instantiation	155, 157, 156	{m in Natural} |- (m + 2) in Complex
# 	a : m, b : 2
# 148	instantiation	176, 163, 153	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 149	instantiation	176, 160, 154	{m in Natural} |- (m + 1) in Complex
# 	A : Real, B : Complex, x : m + 1
# 150	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 151	assumption		{x in Complex} |- x in Complex
# 152	instantiation	155, 156, 157	{m in Natural} |- (2 + m) in Complex
# 	a : 2, b : m
# 153	instantiation	176, 170, 169	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 154	instantiation	176, 163, 158	{m in Natural} |- (m + 1) in Real
# 	A : Rational, B : Real, x : m + 1
# 155	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 156	instantiation	176, 160, 159	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 157	instantiation	176, 160, 161	{m in Natural} |- m in Complex
# 	A : Real, B : Complex, x : m
# 158	instantiation	176, 170, 162	{m in Natural} |- (m + 1) in Rational
# 	A : Integer, B : Rational, x : m + 1
# 159	instantiation	176, 163, 164	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 160	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 161	instantiation	165, 166, 174	{m in Natural} |- m in Real
# 	A : Natural, B : Real, x : m
# 162	instantiation	167, 168, 169	{m in Natural} |- (m + 1) in Integer
# 	a : m, b : 1
# 163	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 164	instantiation	176, 170, 171	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 165	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 166	instantiation	172, 173	|- Natural subset_eq Real
# 	A : Natural, B : Real
# 167	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 168	instantiation	176, 177, 174	{m in Natural} |- m in Integer
# 	A : Natural, B : Integer, x : m
# 169	instantiation	176, 177, 175	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 170	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 171	instantiation	176, 177, 178	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 172	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 173	conjecture		|- Natural proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_within_real
# 174	assumption		{m in Natural} |- m in Natural
# 175	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 176	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 177	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 178	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
