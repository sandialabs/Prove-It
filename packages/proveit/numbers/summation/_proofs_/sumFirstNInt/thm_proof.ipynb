# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">summation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#sumFirstNInt">sumFirstNInt</a> theorem
# ========

# %%
import proveit
from proveit import Function
from proveit.logic import Implies, Forall, Equals, InSet
from proveit.numbers import Add, Exp, frac, Mult, subtract, Sum
from proveit.numbers import Natural, NaturalPos, Integer, Real
from proveit.numbers import Complex, Interval, zero, one, two, three, infinity
from proveit._common_ import a, f, i, m, n, x, fx, P, Px, S, Q
from proveit.numbers.summation._axioms_ import sumSingle
from proveit.numbers.sets.natural._theorems_ import fold_forall_natural_pos
# from proveit.numbers.numerals.decimals._theorems_ import posNat1
theory = proveit.Theory() # the theorem's theory

# %%
# %proving sumFirstNInt

# %%
sumSingle

# %%
sumSingleSpec = sumSingle.instantiate({fx:x})

# %%
sumSingleSpecSpec = sumSingleSpec.instantiate({a:one}, assumptions=[InSet(one, Integer)])

# %%
# posNat1

# %% [markdown]
# The following induction theorem seems the most relevant and easy-to-apply:

# %%
fold_forall_natural_pos

# %% [markdown]
# the following is not really a function but instead an expression that looks like a function

# %%
frac(Mult(n, Add(n, one)),two)

# %%
Qn = Function(Q, n)
Equals(Qn, Equals(Sum(i, i, domain=Interval(one, n)), frac(Mult(n, Add(n, one)),two)))

# %%
Q1 = Function(Q, one)
Equals(Q1, Equals(Sum(i, i, domain=Interval(one, one)), one))

# %%
# %qed
