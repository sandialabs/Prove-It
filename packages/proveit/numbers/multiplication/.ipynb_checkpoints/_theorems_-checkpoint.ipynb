# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.numbers.multiplication</a>
# ========

# %%
import proveit
## 72 spaces ===========================================================

# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
theory = proveit.Theory('.') # adds theory root to sys.path if necessary
from proveit import ExprRange, IndexedVar

from proveit._common_ import a, b, c, d, i, j, k, n, x, y, P, S
from proveit.core_expr_types._common_ import (
    a_1_to_i, a_1_to_n, b_1_to_j, c_1_to_j, c_1_to_k, d_1_to_k)

from proveit.logic import Forall, Set, InSet, Equals, NotEquals, Implies, Boolean
from proveit.numbers import (Natural, NaturalPos, Integer, Real, 
                            RealNonNeg, RealPos, Complex)
from proveit.numbers import (Mult, Neg, Add, subtract, Sum, num, zero, one, two, Exp,
                            Less, LessEq, Greater, GreaterEq)
from proveit.numbers._common_ import ComplexSansZero
from proveit._core_.expression.operation import Function

# %%
# %begin theorems
# Out:
# Defining theorems for theory 'proveit.numbers.multiplication'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
multDefRev = \
    Forall((n, x), Forall(a_1_to_n, 
                          Equals(Add(a_1_to_n), Mult(n, x)),
                          domain=Set(x)),
           domains=(Natural, Complex))
# Out:
# multDefRev: forall_{n in Natural, x in Complex} [forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((a_{1} + ..a_{_a}.. + a_{n}) = (n * x))]

# %%
repeated_addition_to_mult = Forall((n, x), Equals(Add(ExprRange(k, x, one, n)), 
                                                  Mult(n, x)),
                                   domains=(Natural, Complex))
# Out:
# repeated_addition_to_mult: forall_{n in Natural, x in Complex} ((x + ..n repeats.. + x) = (n * x))

# %%
multNatClosureBin = Forall((a, b), InSet(Mult(a, b), Natural), domain=Natural)
# Out:
# multNatClosureBin: forall_{a, b in Natural} ((a * b) in Natural)

# %%
multNatClosure = \
    Forall(n, Forall(a_1_to_n, InSet(Mult(a_1_to_n), Natural), 
                     domain=Natural), 
           domain=Natural)
# Out:
# multNatClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Natural} ((a_{1} * ..a_{_a}.. * a_{n}) in Natural)]

# %%
multNatPosClosureBin = Forall((a, b), InSet(Mult(a, b), NaturalPos), domain=NaturalPos)
# Out:
# multNatPosClosureBin: forall_{a, b in NaturalPos} ((a * b) in NaturalPos)

# %%
multNatPosClosure = \
    Forall(n, Forall(a_1_to_n, 
                     InSet(Mult(a_1_to_n), NaturalPos), 
                     domain=NaturalPos), 
           domain=Natural)
# Out:
# multNatPosClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalPos} ((a_{1} * ..a_{_a}.. * a_{n}) in NaturalPos)]

# %%
multIntClosureBin = Forall((a, b), InSet(Mult(a, b), Integer), domain=Integer)
# Out:
# multIntClosureBin: forall_{a, b in Integer} ((a * b) in Integer)

# %%
multIntClosure = \
    Forall(n, Forall(a_1_to_n, InSet(Mult(a_1_to_n), Integer), 
                     domain=Integer), 
           domain=Natural)
# Out:
# multIntClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer)]

# %%
multRealClosureBin = Forall((a, b), InSet(Mult(a, b), Real), domain=Real)
# Out:
# multRealClosureBin: forall_{a, b in Real} ((a * b) in Real)

# %%
multRealClosure = \
    Forall(n, Forall(a_1_to_n, 
                     InSet(Mult(a_1_to_n), Real), 
                     domain=Real), 
           domain=Natural)
# Out:
# multRealClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Real} ((a_{1} * ..a_{_a}.. * a_{n}) in Real)]

# %%
multRealPosClosureBin = Forall((a, b), InSet(Mult(a, b), RealPos), domain=RealPos)
# Out:
# multRealPosClosureBin: forall_{a, b in RealPos} ((a * b) in RealPos)

# %%
multRealPosClosure = \
    Forall(n, Forall(a_1_to_n, InSet(Mult(a_1_to_n), RealPos), 
                     domain=RealPos), 
           domain=Natural)
# Out:
# multRealPosClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos)]

# %%
multRealNonNegClosureBin = Forall((a, b), InSet(Mult(a, b), RealNonNeg), domain=RealNonNeg)
# Out:
# multRealNonNegClosureBin: forall_{a, b in RealNonNeg} ((a * b) in RealNonNeg)

# %%
multRealNonNegClosure = Forall(n, Forall(a_1_to_n, InSet(Mult(a_1_to_n), RealNonNeg), 
                                         domain=RealNonNeg), 
                               domain=Natural)
# Out:
# multRealNonNegClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in RealNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg)]

# %%
multComplexClosureBin = Forall((a, b), InSet(Mult(a, b), Complex), domain=Complex)
# Out:
# multComplexClosureBin: forall_{a, b in Complex} ((a * b) in Complex)

# %%
multComplexClosure = \
    Forall(n, Forall(a_1_to_n, InSet(Mult(a_1_to_n),Complex), 
                     domain=Complex), 
           domain=Natural)
# Out:
# multComplexClosure: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} ((a_{1} * ..a_{_a}.. * a_{n}) in Complex)]

# %%
multNotEqZero = \
    Forall(n, Forall(a_1_to_n, 
                     NotEquals(Mult(a_1_to_n), zero), 
                     domain=ComplexSansZero), 
           domain=Natural)
# Out:
# multNotEqZero: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complex - {0}} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)]

# %%
elimOneLeft = Forall(x, Equals(Mult(one, x), x), domain=Complex)
# Out:
# elimOneLeft: forall_{x in Complex} ((1 * x) = x)

# %%
elimOneRight = Forall(x, Equals(Mult(x, one), x), domain=Complex)
# Out:
# elimOneRight: forall_{x in Complex} ((x * 1) = x)

# %%
elimOneAny = \
    Forall((i, j), 
           Forall((a_1_to_i, b_1_to_j), 
                  Equals(Mult(a_1_to_i, one, b_1_to_j), 
                         Mult(a_1_to_i, b_1_to_j)), 
                  domain=Complex),
           domain=Natural)
# Out:
# elimOneAny: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}))]

# %%
multZeroLeft = Forall(x, Equals(Mult(zero, x), zero), domain=Complex)
# Out:
# multZeroLeft: forall_{x in Complex} ((0 * x) = 0)

# %%
multZeroRight = Forall(x, Equals(Mult(x, zero), zero), domain=Complex)
# Out:
# multZeroRight: forall_{x in Complex} ((x * 0) = 0)

# %%
multZeroAny = \
    Forall((i, j), 
           Forall((a_1_to_i, b_1_to_j), 
                  Equals(Mult(a_1_to_i, zero, b_1_to_j), zero), 
                  domain=Complex),
           domain=Natural)
# Out:
# multZeroAny: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0)]

# %%
multNegLeft = Forall((x, y), Equals(Mult(Neg(x), y), Neg(Mult(x, y))), domain=Complex)
# Out:
# multNegLeft: forall_{x, y in Complex} (((-x) * y) = (-(x * y)))

# %%
multNegRight = Forall((x, y), Equals(Mult(x, Neg(y)), Neg(Mult(x, y))), domain=Complex)
# Out:
# multNegRight: forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))

# %%
multNegLeftDouble = Forall((x, y), Equals(Neg(Mult(Neg(x), y)), Mult(x, y)), domain=Complex)
# Out:
# multNegLeftDouble: forall_{x, y in Complex} ((-((-x) * y)) = (x * y))

# %%
multNegRightDouble = Forall((x, y), Equals(Neg(Mult(x, Neg(y))), Mult(x, y)), domain=Complex)
# Out:
# multNegRightDouble: forall_{x, y in Complex} ((-(x * (-y))) = (x * y))

# %% [markdown]
# ### Theorems for the NumberRelation class

# %%
left_mult_eq = Forall((a, x, y), Equals(Mult(a, x), Mult(a, y)), condition=Equals(x, y), domain=Complex)
# Out:
# left_mult_eq: forall_{a, x, y in Complex | x = y} ((a * x) = (a * y))

# %%
right_mult_eq = Forall((a, x, y), Equals(Mult(x, a), Mult(y, a)), condition=Equals(x, y), domain=Complex)
# Out:
# right_mult_eq: forall_{a, x, y in Complex | x = y} ((x * a) = (y * a))

# %% [markdown]
# Note: proving left_mult_neq and right_mult_neq for the complex domain is a bit more challenging than just real numbers, but should still be applicable.  Using a polar coordinate representations, such as $r \textrm{exp}(i \theta)$, makes it more clear.  Suppose $x = x_r \textrm{exp}(x_{\theta})$ and $y = y_r \textrm{exp}(y_{\theta})$; if $x \neq y$, either $x_r \neq y_r$ or $x_{\theta} \neq y_{\theta}$ (or both), so either the length or angle (or both) will differ on either side.

# %%
left_mult_neq = Forall((a, x, y), NotEquals(Mult(a, x), Mult(a, y)),
                       conditions=[NotEquals(x, y), NotEquals(a, zero)], domain=Complex)
# Out:
# left_mult_neq: forall_{a, x, y in Complex | x != y, a != 0} ((a * x) != (a * y))

# %%
right_mult_neq = Forall((a, x, y), NotEquals(Mult(x, a), Mult(y, a)), 
                        conditions=[NotEquals(x, y), NotEquals(a, zero)], domain=Complex)
# Out:
# right_mult_neq: forall_{a, x, y in Complex | x != y, a != 0} ((x * a) != (y * a))

# %%
left_mult_pos_less = Forall((a, x, y), Less(Mult(a, x), Mult(a, y)), conditions=[Less(x, y), Greater(a, zero)], 
                        domain=Real)
# Out:
# left_mult_pos_less: forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))

# %%
left_mult_nonneg_less = Forall((a, x, y), LessEq(Mult(a, x), Mult(a, y)), 
                               conditions=[Less(x, y), GreaterEq(a, zero)], domain=Real)
# Out:
# left_mult_nonneg_less: forall_{a, x, y in Real | x < y, a >= 0} ((a * x) <= (a * y))

# %%
right_mult_pos_less = Forall((a, x, y), Less(Mult(x, a), Mult(y, a)), 
                             conditions=[Less(x, y), Greater(a, zero)], domain=Real)
# Out:
# right_mult_pos_less: forall_{a, x, y in Real | x < y, a > 0} ((x * a) < (y * a))

# %%
right_mult_nonneg_less = Forall((a, x, y), LessEq(Mult(x, a), Mult(y, a)), 
                                conditions=[Less(x, y), GreaterEq(a, zero)], domain=Real)
# Out:
# right_mult_nonneg_less: forall_{a, x, y in Real | x < y, a >= 0} ((x * a) <= (y * a))

# %%
left_mult_pos_lesseq = Forall((a, x, y), LessEq(Mult(a, x), Mult(a, y)), 
                              conditions=[LessEq(x, y), GreaterEq(a, zero)], domain=Real)
# Out:
# left_mult_pos_lesseq: forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))

# %%
right_mult_pos_lesseq = Forall((a, x, y), LessEq(Mult(x, a), Mult(y, a)), conditions=[LessEq(x, y), GreaterEq(a, zero)], 
                               domain=Real)
# Out:
# right_mult_pos_lesseq: forall_{a, x, y in Real | x <= y, a >= 0} ((x * a) <= (y * a))

# %%
left_mult_neg_less = Forall((a, x, y), Greater(Mult(a, x), Mult(a, y)), 
                            conditions=[Less(x, y), Less(a, zero)], domain=Real)
# Out:
# left_mult_neg_less: forall_{a, x, y in Real | x < y, a < 0} ((a * x) > (a * y))

# %%
left_mult_nonpos_less = Forall((a, x, y), GreaterEq(Mult(a, x), Mult(a, y)), 
                               conditions=[Less(x, y), LessEq(a, zero)], domain=Real)
# Out:
# left_mult_nonpos_less: forall_{a, x, y in Real | x < y, a <= 0} ((a * x) >= (a * y))

# %%
right_mult_neg_less = Forall((a, x, y), Greater(Mult(x, a), Mult(y, a)), 
                             conditions=[Less(x, y), Less(a, zero)], domain=Real)
# Out:
# right_mult_neg_less: forall_{a, x, y in Real | x < y, a < 0} ((x * a) > (y * a))

# %%
right_mult_nonpos_less = Forall((a, x, y), GreaterEq(Mult(x, a), Mult(y, a)), 
                                conditions=[Less(x, y), LessEq(a, zero)], domain=Real)
# Out:
# right_mult_nonpos_less: forall_{a, x, y in Real | x < y, a <= 0} ((x * a) >= (y * a))

# %%
left_mult_neg_lesseq = Forall((a, x, y), GreaterEq(Mult(a, x), Mult(a, y)), 
                              conditions=[LessEq(x, y), LessEq(a, zero)], domain=Real)
# Out:
# left_mult_neg_lesseq: forall_{a, x, y in Real | x <= y, a <= 0} ((a * x) >= (a * y))

# %%
right_mult_neg_lesseq = Forall((a, x, y), GreaterEq(Mult(x, a), Mult(y, a)), 
                               conditions=[LessEq(x, y), LessEq(a, zero)], domain=Real)
# Out:
# right_mult_neg_lesseq: forall_{a, x, y in Real | x <= y, a <= 0} ((x * a) >= (y * a))

# %%
multNegAny = \
    Forall((i, j), 
           Forall((a_1_to_i, b, c_1_to_j), 
                  Equals(Mult(a_1_to_i, Neg(b), c_1_to_j), 
                         Neg(Mult(a_1_to_i, b, c_1_to_j))), 
                  domain=Complex),
           domain=Natural)
# Out:
# multNegAny: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j}) = (-(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})))]

# %%
multNegAnyDouble = \
    Forall((i, j), 
           Forall((a_1_to_i, b, c_1_to_j), 
                  Equals(Neg(Mult(a_1_to_i, Neg(b), c_1_to_j)), 
                         Mult(a_1_to_i, b, c_1_to_j)), 
                  domain=Complex),
           domain=Natural)
# Out:
# multNegAnyDouble: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}))]

# %%
distributeThroughSum =  \
    Forall((i,j,k),
           Forall((a_1_to_i, b_1_to_j, c_1_to_k),
                  Equals(
                        Mult(a_1_to_i, Add(b_1_to_j), c_1_to_k),
                        Add(ExprRange(n,Mult(a_1_to_i, 
                                             IndexedVar(b, n), 
                                             c_1_to_k), 
                                 one, j))).withWrappingAt(2),
                  domain=Complex),
           domain=Natural)
# Out:
# distributeThroughSum: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} + ..b_{_a}.. + b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * c_{1} * ..c_{_a}.. * c_{k}) + ..(a_{1} * ..a_{_a}.. * a_{i} * b_{n} * c_{1} * ..c_{_a}.. * c_{k}).. + (a_{1} * ..a_{_a}.. * a_{i} * b_{j} * c_{1} * ..c_{_a}.. * c_{k})))]

# %%
distributeThroughSubtract =  \
    Forall((i,j),
           Forall((a_1_to_i, x, y, b_1_to_j),
                  Equals(
                        Mult(a_1_to_i, subtract(x, y), b_1_to_j),
                        subtract(Mult(a_1_to_i, x, b_1_to_j),
                                 Mult(a_1_to_i, y, b_1_to_j)))\
                  .withWrappingAt(2), 
                  domain=Complex),
           domain=Natural)
# Out:
# distributeThroughSubtract: forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, x, y, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})))]

# %%
distributeThroughSummation = \
    Forall((i,j,k), 
           Forall((P, S),
                  Implies(Forall(b_1_to_j, 
                                 InSet(Function(P, b_1_to_j), Complex), 
                                 domain=S),
                          Forall((a_1_to_i, c_1_to_k),
                                 Equals(Mult(a_1_to_i, 
                                             Sum(b_1_to_j, 
                                                 Function(P, b_1_to_j), 
                                                 domain=S), 
                                             c_1_to_k),
                                        Sum(b_1_to_j, 
                                            Mult(a_1_to_i,
                                                 Function(P, b_1_to_j), 
                                                 c_1_to_k), 
                                            domain=S))\
                                 .withWrappingAt(2),
                                 domain=Complex))), 
           domain=Natural)
# Out:
# distributeThroughSummation: forall_{i, j, k in Natural} [forall_{P, S} ([forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])]

# %%
commutation = Forall((a, b), Equals(Mult(a, b), Mult(b, a)), domain=Complex)
# Out:
# commutation: forall_{a, b in Complex} ((a * b) = (b * a))

# %%
rightwardCommutation = \
    Forall((i,j,k),
           Forall((a_1_to_i,b,c_1_to_j,d_1_to_k), 
                  Equals(Mult(a_1_to_i, b, c_1_to_j, d_1_to_k), 
                         Mult(a_1_to_i, c_1_to_j, b, d_1_to_k)) \
                  .withWrappingAt(2), 
                  domain=Complex),
           domain=Natural)
# Out:
# rightwardCommutation: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}))]

# %%
leftwardCommutation = \
    Forall((i,j,k),
           Forall((a_1_to_i,b_1_to_j,c,d_1_to_k), 
                  Equals(Mult(a_1_to_i, b_1_to_j, c, d_1_to_k), 
                         Mult(a_1_to_i, c, b_1_to_j, d_1_to_k)) \
                  .withWrappingAt(2), 
                  domain=Complex), 
           domain=Natural)
# Out:
# leftwardCommutation: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k}))]

# %%
association = \
    Forall((i,j,k), 
           Forall((a_1_to_i,b_1_to_j,c_1_to_k), 
                  Equals(Mult(a_1_to_i, b_1_to_j, c_1_to_k), 
                         Mult(a_1_to_i, Mult(b_1_to_j), c_1_to_k)) \
                  .withWrappingAt(2),
                  domain=Complex),
           domain=Natural)
# Out:
# association: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]

# %%
disassociation = \
    Forall((i,j,k), 
           Forall((a_1_to_i,b_1_to_j,c_1_to_k), 
                  Equals(Mult(a_1_to_i, Mult(b_1_to_j), c_1_to_k),
                         Mult(a_1_to_i, b_1_to_j, c_1_to_k)) \
                  .withWrappingAt(2),
                  domain=Complex),
           domain=Natural)
# Out:
# disassociation: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k}))]

# %%
# %end theorems
# Out:
# Removing theorem natSqrdInNatPosImpliesNatInNatPos from proveit.numbers.multiplication theory
# Theorems may be imported from autogenerated _theorems_.py
# Stashing _proofs_/natSqrdInNatPosImpliesNatInNatPos to _proofs_/natSqrdInNatPosImpliesNatInNatPos~stashed~1 in case it is needed.
