# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, c, d, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_i, b, c_1_to_j, d_1_to_k], Conditional(Equals(Mult(a_1_to_i, b, c_1_to_j, d_1_to_k), Mult(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j), ExprRange(sub_expr1, InSet(IndexedVar(d, sub_expr1), Complex), one, k))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k}\right) \mapsto \left\{\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b \cdot c_{1} \cdot \ldots \cdot c_{j} \cdot d_{1} \cdot \ldots \cdot d_{k}\right) =  \\ \left(a_{1} \cdot \ldots \cdot a_{i} \cdot c_{1} \cdot \ldots \cdot c_{j} \cdot b \cdot d_{1} \cdot \ldots \cdot d_{k}\right) \end{array} \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b \in \mathbb{C} ,  c_{1} \in \mathbb{C} ,  \ldots ,  c_{j} \in \mathbb{C} ,  d_{1} \in \mathbb{C} ,  \ldots ,  d_{k} \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Lambda
#    parameters: 14\n   body: 1
# 1. {(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex) and (d_{1} in Complex) and ..(d_{_a} in Complex).. and (d_{k} in Complex)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}, a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex, d_{1} in Complex, ..d_{_a} in Complex.., d_{k} in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 33
#     end_index: 29
# 11. b in Complex
#     core type: Operation
#     operator: 37
#     operands: 18
# 12. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 33
#     end_index: 31
# 13. (d_{1} in Complex), ..(d_{_a} in Complex).., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 33
#     end_index: 34
# 14. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 25, 22, 23
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 25, 23
# 17. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 24
# 18. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 25, 42
# 19. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 26
# 20. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 27
# 21. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 33
#     end_index: 29
# 22. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 33
#     end_index: 31
# 23. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 24. a_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 35
# 25. b
#     core type: Variable
#     sub-expressions:
# 26. c_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 36
# 27. d_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 38
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 39
# 29. i
#     core type: Variable
#     sub-expressions:
# 30. _a -> c_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 31. j
#     core type: Variable
#     sub-expressions:
# 32. _a -> d_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 41
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. k
#     core type: Variable
#     sub-expressions:
# 35. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 42
# 36. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 42
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. a_{_a}
#     core type: IndexedVar
# variable: 43
# index: 46
# 40. c_{_a}
#     core type: IndexedVar
# variable: 44
# index: 46
# 41. d_{_a}
#     core type: IndexedVar
# variable: 45
# index: 46
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. c
#     core type: Variable
#     sub-expressions:
# 45. d
#     core type: Variable
#     sub-expressions:
# 46. _a
#     core type: Variable
#     sub-expressions:
