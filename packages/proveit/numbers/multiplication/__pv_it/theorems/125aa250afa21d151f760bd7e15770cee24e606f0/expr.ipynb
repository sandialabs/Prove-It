# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, x, y, b_1_to_j], Equals(Mult(a_1_to_i, Add(x, Neg(y)), b_1_to_j), Add(Mult(a_1_to_i, x, b_1_to_j), Neg(Mult(a_1_to_i, y, b_1_to_j)))).with_wrapping_at(2), domains = [Complex, Complex, Complex, Complex])
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{i}, x, y, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{i}, x, y, b_{1}, \ldots, b_{j} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(x - y\right) \cdot b_{1} \cdot \ldots \cdot b_{j}\right) =  \\ \left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot x \cdot b_{1} \cdot \ldots \cdot b_{j}\right) - \left(a_{1} \cdot \ldots \cdot a_{i} \cdot y \cdot b_{1} \cdot \ldots \cdot b_{j}\right)\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{i}, x, y, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{i}, x, y, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  x in Complex ,  y in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, ..a_{_a}.., a_{i}, x, y, b_{1}, ..b_{_a}.., b_{j})
#    core type: ExprTuple
#    sub-expressions: 41, 36, 42, 43
# 4. {(a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  x in Complex ,  y in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (x in Complex) and (y in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}, (a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, x in Complex, y in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 37
#     operands: 17
# 12. (a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})
#     core type: Operation
#     operator: 28
#     operands: 18
# 13. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 47
#     end_index: 45
# 14. x in Complex
#     core type: Operation
#     operator: 33
#     operands: 20
# 15. y in Complex
#     core type: Operation
#     operator: 33
#     operands: 21
# 16. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 47
#     end_index: 48
# 17. (a_{1}, ..a_{_a}.., a_{i}, x - y, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 41, 23, 43
# 18. (a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}, -(a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 19. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 53
#     body: 26
# 20. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 39
# 21. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 39
# 22. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 53
#     body: 27
# 23. x - y
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 37
#     operands: 30
# 25. -(a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})
#     core type: Operation
#     operator: 40
#     operand: 31
# 26. a_{_a} in Complex
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. b_{_a} in Complex
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 30. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 41, 36, 43
# 31. a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 39
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 39
# 35. -y
#     core type: Operation
#     operator: 40
#     operand: 42
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. *
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, ..a_{_a}.., a_{i}, y, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 42. y
#     core type: Variable
#     sub-expressions:
# 43. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 49
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> b_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 50. b_{_a}
#     core type: IndexedVar
# variable: 52
# index: 53
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. b
#     core type: Variable
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
