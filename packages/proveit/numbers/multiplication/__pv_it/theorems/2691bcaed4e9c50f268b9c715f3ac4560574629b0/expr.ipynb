# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([a, x, y], Equals(Mult(x, a), Mult(y, a)), domains = [Complex, Complex, Complex], condition = Equals(x, y))
# Out:
# expr: forall_{a, x, y in Complex | x = y} ((x * a) = (y * a))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, x, y \in \mathbb{C}~|~x = y}~\left(\left(x \cdot a\right) = \left(y \cdot a\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, x, y in Complex | x = y} ((x * a) = (y * a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, x, y) -> {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 25, 27, 28
# 4. {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x * a) = (y * a)
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (a in Complex) and (x in Complex) and (y in Complex) and (x = y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, x in Complex, y in Complex, x = y)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. x * a
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. y * a
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a in Complex
#     core type: Operation
#     operator: 21
#     operands: 19
# 13. x in Complex
#     core type: Operation
#     operator: 21
#     operands: 20
# 14. y in Complex
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. x = y
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. (x, a)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (y, a)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 19. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (x, y)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. y
#     core type: Variable
#     sub-expressions:
