# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_neg_any_double">mult_neg_any_double</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_neg_any_double

# %%
# check that the built expression is the same as the stored expression
assert mult_neg_any_double.expr == stored_expr
assert mult_neg_any_double.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_neg_any_double matches stored_expr")
# Out:
# Passed sanity check: mult_neg_any_double matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_neg_any_double.latex())
# Out:
# \vdash \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j} \in \mathbb{C}}~\left(\left(-\left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(-b\right) \cdot c_{1} \cdot \ldots \cdot c_{j}\right)\right) = \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b \cdot c_{1} \cdot \ldots \cdot c_{j}\right)\right)\right]

# %%
# display the expression information
mult_neg_any_double.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 42, 47
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Complex} ((-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 18
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}) -> {(-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex.
#    core type: Lambda
#    parameters: 27\n   body: 9
# 8. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. {(-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. i in Natural
#     core type: Operation
#     operator: 39
#     operands: 14
# 11. j in Natural
#     core type: Operation
#     operator: 39
#     operands: 15
# 12. (-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})) = (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex)
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 20
# 15. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 20
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (-(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j}), a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. -(a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j})
#     core type: Operation
#     operator: 43
#     operand: 26
# 22. a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j}
#     core type: Operation
#     operator: 31
#     operands: 27
# 23. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 46
#     end_index: 42
# 24. b in Complex
#     core type: Operation
#     operator: 39
#     operands: 29
# 25. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 46
#     end_index: 47
# 26. a_{1} * ..a_{_a}.. * a_{i} * (-b) * c_{1} * ..c_{_a}.. * c_{j}
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 35, 44, 37
# 28. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 53
#     body: 33
# 29. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 48
# 30. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 53
#     body: 34
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (a_{1}, ..a_{_a}.., a_{i}, -b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 33. a_{_a} in Complex
#     core type: Operation
#     operator: 39
#     operands: 38
# 34. c_{_a} in Complex
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 46
#     end_index: 42
# 36. -b
#     core type: Operation
#     operator: 43
#     operand: 44
# 37. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 38. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 48
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 49
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. b
#     core type: Variable
#     sub-expressions:
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 50
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. Complex
#     core type: Literal
#     sub-expressions:
# 49. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 50. c_{_a}
#     core type: IndexedVar
# variable: 52
# index: 53
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. c
#     core type: Variable
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
