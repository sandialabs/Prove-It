# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#right_mult_neg_lesseq">right_mult_neg_lesseq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import right_mult_neg_lesseq

# %%
# check that the built expression is the same as the stored expression
assert right_mult_neg_lesseq.expr == stored_expr
assert right_mult_neg_lesseq.expr._style_id == stored_expr._style_id
print("Passed sanity check: right_mult_neg_lesseq matches stored_expr")
# Out:
# Passed sanity check: right_mult_neg_lesseq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(right_mult_neg_lesseq.latex())
# Out:
# \vdash \forall_{a, x, y \in \mathbb{R}~|~x \leq y, a \leq 0}~\left(\left(x \cdot a\right) \geq \left(y \cdot a\right)\right)

# %%
# display the expression information
right_mult_neg_lesseq.expr_info()
# Out:
# 0. forall_{a, x, y in Real | x <= y, a <= 0} ((x * a) >= (y * a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, x, y) -> {(x * a) >= (y * a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a <= 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 31, 29, 30
# 4. {(x * a) >= (y * a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a <= 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x * a) >= (y * a)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Real) and (x in Real) and (y in Real) and (x <= y) and (a <= 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. >=
#    core type: Literal
#    sub-expressions:
# 8. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# ...
