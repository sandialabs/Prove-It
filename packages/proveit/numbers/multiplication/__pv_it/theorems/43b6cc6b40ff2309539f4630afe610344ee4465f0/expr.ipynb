# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, j, x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.numbers import Less, Mult, Natural, RealPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([i, j], Conditional(Forall(instance_param_or_params = [x, y], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j], instance_expr = Less(Mult(a_1_to_i, x, b_1_to_j), Mult(a_1_to_i, y, b_1_to_j)), domain = RealPos, condition = Less(x, y))), And(InSet(i, Natural), InSet(j, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j\right) \mapsto \left\{\forall_{x, y}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{R}^+~|~x < y}~\left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot x\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) < \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot y\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j) -> {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j) -> {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 44, 47
# 3. {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]
#    core type: Operation
#    operator: 14
#    operand: 8
# 5. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. ((x, y) -> [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))])
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (x, y) -> [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]
#    core type: Lambda
#    parameters: 36\n   body: 11
# 9. i in Natural
#    core type: Operation
#    operator: 49
#    operands: 12
# 10. j in Natural
#     core type: Operation
#     operator: 49
#     operands: 13
# 11. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: Operation
#     operator: 14
#     operand: 17
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 16
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.
#     core type: Lambda
#     parameters: 18\n    body: 19
# 18. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 19. {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.
#     core type: Conditional
#     value: 20
#     condition: 21
# 20. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 35
#     operands: 22
# 21. (a_{1} in RealPos) and  (a_{2} in RealPos) and  ... and  (a_{i} in RealPos)and (b_{1} in RealPos) and  (b_{2} in RealPos) and  ... and  (b_{j} in RealPos) and (x < y)
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}, a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos),(b_{1} in RealPos), (b_{2} in RealPos), ..., (b_{j} in RealPos), x < y)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 25. a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 31
#     operands: 30
# 26. a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 46
#     end_index: 44
# 28. (b_{1} in RealPos), (b_{2} in RealPos), ..., (b_{j} in RealPos)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 46
#     end_index: 47
# 29. x < y
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 37, 41, 38
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (a_{1}, a_{2}, ..., a_{i}, y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 37, 42, 38
# 33. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 57
#     body: 39
# 34. _a -> (b_{_a} in RealPos)
#     core type: Lambda
#     parameter: 57
#     body: 40
# 35. <
#     core type: Literal
#     sub-expressions:
# 36. (x, y)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 44
# 38. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 39. a_{_a} in RealPos
#     core type: Operation
#     operator: 49
#     operands: 48
# 40. b_{_a} in RealPos
#     core type: Operation
#     operator: 49
#     operands: 50
# 41. x
#     core type: Variable
#     sub-expressions:
# 42. y
#     core type: Variable
#     sub-expressions:
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 51
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (b_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 51. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 52. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 53. RealPos
#     core type: Literal
#     sub-expressions:
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
