# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import GreaterEq, Less, LessEq, Mult, Real, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, x, y], Conditional(GreaterEq(Mult(a, x), Mult(a, y)), And(InSet(a, Real), InSet(x, Real), InSet(y, Real), Less(x, y), LessEq(a, zero))))
# Out:
# expr: (a, x, y) -> {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, x, y\right) \mapsto \left\{\left(a \cdot x\right) \geq \left(a \cdot y\right) \textrm{ if } a \in \mathbb{R} ,  x \in \mathbb{R} ,  y \in \mathbb{R} ,  x < y ,  a \leq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, x, y) -> {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 30, 28, 29
# 2. {(a * x) >= (a * y) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a <= 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a * x) >= (a * y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Real) and (x in Real) and (y in Real) and (x < y) and (a <= 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. >=
#    core type: Literal
#    sub-expressions:
# 6. (a * x, a * y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, x in Real, y in Real, x < y, a <= 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# 9. a * x
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. a * y
# ...
