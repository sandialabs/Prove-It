# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, IndexedVar, Lambda, Q, Variable, a, c, f, i, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, Sum, one
from proveit.numbers.summation import summation_b1toj_fQ

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [b_1_to_j]
expr = Lambda([a_1_to_i, c_1_to_k], Conditional(Equals(Mult(a_1_to_i, summation_b1toj_fQ, c_1_to_k), Sum(index_or_indices = sub_expr2, summand = Mult(a_1_to_i, Function(f, sub_expr2), c_1_to_k), condition = Function(Q, sub_expr2))).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, k))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k}\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right]\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) =  \\ \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right)\right] \end{array} \end{array} \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{i} \in \mathbb{C}\right), \left(c_{1} \in \mathbb{C}\right) ,  \left(c_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(c_{k} \in \mathbb{C}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#    core type: ExprTuple
#    sub-expressions: 34, 36
# 2. {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{k} in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}
#    core type: Operation
#    operator: 31
#    operands: 13
# 10. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Operation
#     operator: 21
#     operand: 18
# 11. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 49
#     end_index: 39
# 12. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 49
#     end_index: 43
# 13. (a_{1}, a_{2}, ..., a_{i}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 34, 17, 36
# 14. ((b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 19
# 16. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 20
# 17. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 21
#     operand: 27
# 18. (b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 41\n    body: 23
# 19. a_{_a} in Complex
#     core type: Operation
#     operator: 25
#     operands: 24
# 20. c_{_a} in Complex
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 28
#     condition: 33
# 24. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 29
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 29
# 27. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 41\n    body: 30
# 28. a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 35
#     condition: 33
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (a_{1}, a_{2}, ..., a_{i}, f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36
# 33. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 37
#     operands: 41
# 34. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 49
#     end_index: 39
# 35. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 49
#     end_index: 43
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 44
# 39. i
#     core type: Variable
#     sub-expressions:
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. _a -> c_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 46
# 43. k
#     core type: Variable
#     sub-expressions:
# 44. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 55
# 45. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 46. c_{_a}
#     core type: IndexedVar
# variable: 51
# index: 55
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. _a -> b_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. c
#     core type: Variable
#     sub-expressions:
# 52. b_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
