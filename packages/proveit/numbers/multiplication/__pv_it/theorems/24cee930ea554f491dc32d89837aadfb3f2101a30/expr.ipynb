# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, b, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Abs, Add, Complex, Mult, Natural, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
expr = ExprTuple(Lambda([i, j, k], Conditional(Forall(instance_param_or_params = [a_1_to_i, c_1_to_k], instance_expr = Forall(instance_param_or_params = [b_1_to_j], instance_expr = Equals(Mult(a_1_to_i, Abs(Add(b_1_to_j)), c_1_to_k), Abs(Add(ExprRange(sub_expr1, Mult(a_1_to_i, IndexedVar(b, sub_expr1), c_1_to_k), one, j)))).with_wrapping_at(2), domain = Complex).with_wrapping(), domain = RealNonNeg).with_wrapping(), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j, k\right) \mapsto \left\{\begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k} \in \mathbb{R}^{\ge 0}}~\\
# \left[\begin{array}{l}\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left|b_{1} +  b_{2} +  \ldots +  b_{j}\right|\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) =  \\ \left|\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{1}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) +  \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{2}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) +  \ldots +  \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{j}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right)\right| \end{array} \end{array}\right)\end{array}\right]\end{array} \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)] if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 71, 63, 76
# 3. {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)] if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)]
#    core type: Operation
#    operator: 20
#    operand: 8
# 5. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 35
#    operands: 7
# 6. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 9. i in Natural
#    core type: Operation
#    operator: 52
#    operands: 14
# 10. j in Natural
#     core type: Operation
#     operator: 52
#     operands: 15
# 11. k in Natural
#     core type: Operation
#     operator: 52
#     operands: 16
# 12. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 13. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 71, 19
# 15. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 63, 19
# 16. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 76, 19
# 17. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. (a_{1} in RealNonNeg) and  (a_{2} in RealNonNeg) and  ... and  (a_{i} in RealNonNeg)and (c_{1} in RealNonNeg) and  (c_{2} in RealNonNeg) and  ... and  (c_{k} in RealNonNeg)
#     core type: Operation
#     operator: 35
#     operands: 22
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. ((a_{1} in RealNonNeg), (a_{2} in RealNonNeg), ..., (a_{i} in RealNonNeg),(c_{1} in RealNonNeg), (c_{2} in RealNonNeg), ..., (c_{k} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. (b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Lambda
#     parameters: 58\n    body: 26
# 24. (a_{1} in RealNonNeg), (a_{2} in RealNonNeg), ..., (a_{i} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 75
#     end_index: 71
# 25. (c_{1} in RealNonNeg), (c_{2} in RealNonNeg), ..., (c_{k} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 75
#     end_index: 76
# 26. {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Conditional
#     value: 29
#     condition: 30
# 27. _a -> (a_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 83
#     body: 31
# 28. _a -> (c_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 83
#     body: 32
# 29. (a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. a_{_a} in RealNonNeg
#     core type: Operation
#     operator: 52
#     operands: 37
# 32. c_{_a} in RealNonNeg
#     core type: Operation
#     operator: 52
#     operands: 38
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}, |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (a_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 77, 42
# 38. (c_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 79, 42
# 39. a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 64
#     operands: 43
# 40. |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|
#     core type: Operation
#     operator: 49
#     operand: 47
# 41. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 75
#     end_index: 63
# 42. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 43. (a_{1}, a_{2}, ..., a_{i}, |b_{1} +  b_{2} +  ... +  b_{j}|,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 46, 69
# 44. ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 47
# 45. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 83
#     body: 48
# 46. |b_{1} +  b_{2} +  ... +  b_{j}|
#     core type: Operation
#     operator: 49
#     operand: 54
# 47. (a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Operation
#     operator: 57
#     operands: 51
# 48. b_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. Abs
#     core type: Literal
#     sub-expressions:
# 50. (b_{1} +  b_{2} +  ... +  b_{j})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}), (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}), ..., (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 66, 56
# 54. b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. (a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}), (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}), ..., (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 75
#     end_index: 63
# 56. Complex
#     core type: Literal
#     sub-expressions:
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 60
# 59. _b -> (a_{1} *  a_{2} *  ... *  a_{i} * b_{_b}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Lambda
#     parameter: 78
#     body: 61
# 60. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 75
#     end_index: 63
# 61. a_{1} *  a_{2} *  ... *  a_{i} * b_{_b}* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. _a -> b_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 66
# 63. j
#     core type: Variable
#     sub-expressions:
# 64. *
#     core type: Literal
#     sub-expressions:
# 65. (a_{1}, a_{2}, ..., a_{i}, b_{_b},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 67, 68, 69
# 66. b_{_a}
#     core type: IndexedVar
# variable: 72
# index: 83
# 67. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 75
#     end_index: 71
# 68. b_{_b}
#     core type: IndexedVar
# variable: 72
# index: 78
# 69. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 75
#     end_index: 76
# 70. _a -> a_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 77
# 71. i
#     core type: Variable
#     sub-expressions:
# 72. b
#     core type: Variable
#     sub-expressions:
# 73. (_b)
#     core type: ExprTuple
#     sub-expressions: 78
# 74. _a -> c_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 79
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. k
#     core type: Variable
#     sub-expressions:
# 77. a_{_a}
#     core type: IndexedVar
# variable: 80
# index: 83
# 78. _b
#     core type: Variable
#     sub-expressions:
# 79. c_{_a}
#     core type: IndexedVar
# variable: 81
# index: 83
# 80. a
#     core type: Variable
#     sub-expressions:
# 81. c
#     core type: Variable
#     sub-expressions:
# 82. (_a)
#     core type: ExprTuple
#     sub-expressions: 83
# 83. _a
#     core type: Variable
#     sub-expressions:
