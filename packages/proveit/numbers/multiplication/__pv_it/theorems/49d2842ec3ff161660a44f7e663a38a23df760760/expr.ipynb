# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import GreaterEq, LessEq, Mult, Real, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Mult(x, a), Mult(y, a)), And(InSet(a, Real), InSet(x, Real), InSet(y, Real), LessEq(x, y), GreaterEq(a, zero)))
# Out:
# expr: {(x * a) <= (y * a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a >= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x \cdot a\right) \leq \left(y \cdot a\right) \textrm{ if } a \in \mathbb{R} ,  x \in \mathbb{R} ,  y \in \mathbb{R} ,  x \leq y ,  a \geq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x * a) <= (y * a) if a in Real ,  x in Real ,  y in Real ,  x <= y ,  a >= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x * a) <= (y * a)
#    core type: Operation
#    operator: 20
#    operands: 3
# 2. (a in Real) and (x in Real) and (y in Real) and (x <= y) and (a >= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Real, x in Real, y in Real, x <= y, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 6. x * a
#    core type: Operation
#    operator: 14
#    operands: 13
# 7. y * a
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. a in Real
#    core type: Operation
#    operator: 18
#    operands: 16
# 9. x in Real
#    core type: Operation
#    operator: 18
#    operands: 17
# 10. y in Real
#     core type: Operation
#     operator: 18
#     operands: 19
# ...
