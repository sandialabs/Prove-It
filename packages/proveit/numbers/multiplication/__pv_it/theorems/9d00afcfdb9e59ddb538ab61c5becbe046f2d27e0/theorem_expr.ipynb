# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_zero_any">mult_zero_any</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_zero_any

# %%
# check that the built expression is the same as the stored expression
assert mult_zero_any.expr == stored_expr
assert mult_zero_any.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_zero_any matches stored_expr")
# Out:
# Passed sanity check: mult_zero_any matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot 0\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) = 0\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0) if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 37, 40
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 22
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0 if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0 if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. i in Natural
#     core type: Operation
#     operator: 42
#     operands: 15
# 12. j in Natural
#     core type: Operation
#     operator: 42
#     operands: 16
# 13. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 31, 33
# 14. {(a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0 if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 19
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 40, 19
# 17. (a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}, 0)
#     core type: ExprTuple
#     sub-expressions: 24, 32
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 39
#     end_index: 37
# 26. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 39
#     end_index: 40
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, a_{2}, ..., a_{i}, 0,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 31, 32, 33
# 29. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 50
#     body: 34
# 30. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 50
#     body: 35
# 31. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 39
#     end_index: 37
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 34. a_{_a} in Complex
#     core type: Operation
#     operator: 42
#     operands: 41
# 35. b_{_a} in Complex
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 44
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. _a -> b_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 45
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. j
#     core type: Variable
#     sub-expressions:
# 41. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 46
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 44. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 50
# 45. b_{_a}
#     core type: IndexedVar
# variable: 48
# index: 50
# 46. Complex
#     core type: Literal
#     sub-expressions:
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 50. _a
#     core type: Variable
#     sub-expressions:
