# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import Integer, Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([a_1_to_n], InSet(Mult(a_1_to_n), Integer), domains = [Integer]), domains = [Natural])
# Out:
# expr: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{Z}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{Z}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer) if n in Natural.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in Integer} ((a_{1} * ..a_{_a}.. * a_{n}) in Integer)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Natural
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Integer if (a_{1} in Integer) and ..(a_{_a} in Integer).. and (a_{n} in Integer).
#    core type: Lambda
#    parameters: 18\n   body: 8
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(a_{1} * ..a_{_a}.. * a_{n}) in Integer if (a_{1} in Integer) and ..(a_{_a} in Integer).. and (a_{n} in Integer).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} * ..a_{_a}.. * a_{n}) in Integer
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (a_{1} in Integer) and ..(a_{_a} in Integer).. and (a_{n} in Integer)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a_{1} * ..a_{_a}.. * a_{n}, Integer)
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a_{1} in Integer, ..a_{_a} in Integer.., a_{n} in Integer)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (a_{1} in Integer), ..(a_{_a} in Integer).., (a_{n} in Integer)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (a_{_a} in Integer)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. a_{_a} in Integer
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (a_{_a}, Integer)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. Integer
#     core type: Literal
#     sub-expressions:
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
