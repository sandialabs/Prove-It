# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, j, x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, x, y, b_1_to_j], instance_expr = Equals(Mult(a_1_to_i, subtract(x, y), b_1_to_j), subtract(Mult(a_1_to_i, x, b_1_to_j), Mult(a_1_to_i, y, b_1_to_j))).with_wrapping_at(2), domain = Complex), And(InSet(i, Natural), InSet(j, Natural))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, x, y, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left(x - y\right)\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) =  \\ \left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot x\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) - \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot y\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\right) \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j)
#    core type: ExprTuple
#    sub-expressions: 58, 61
# 2. {forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 9. i in Natural
#    core type: Operation
#    operator: 44
#    operands: 13
# 10. j in Natural
#     core type: Operation
#     operator: 44
#     operands: 14
# 11. (a_{1}, a_{2}, ..., a_{i}, x, y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 54, 47, 55, 56
# 12. {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 58, 17
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 61, 17
# 15. (a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (x in Complex) and (y in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}, (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), x in Complex, y in Complex,(b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 22. a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 52
#     operands: 28
# 23. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 39
#     operands: 29
# 24. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 60
#     end_index: 58
# 25. x in Complex
#     core type: Operation
#     operator: 44
#     operands: 31
# 26. y in Complex
#     core type: Operation
#     operator: 44
#     operands: 32
# 27. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 60
#     end_index: 61
# 28. (a_{1}, a_{2}, ..., a_{i}, x - y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 54, 34, 56
# 29. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}, -(a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 67
#     body: 37
# 31. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 49
# 32. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 49
# 33. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 67
#     body: 38
# 34. x - y
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 52
#     operands: 41
# 36. -(a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 50
#     operand: 48
# 37. a_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 43
# 38. b_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 41. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 54, 47, 56
# 42. (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: ExprTuple
#     sub-expressions: 48
# 43. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 49
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 63, 49
# 46. -y
#     core type: Operation
#     operator: 50
#     operand: 55
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. -
#     core type: Literal
#     sub-expressions:
# 51. (y)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (a_{1}, a_{2}, ..., a_{i}, y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 54, 55, 56
# 54. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 60
#     end_index: 58
# 55. y
#     core type: Variable
#     sub-expressions:
# 56. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 60
#     end_index: 61
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 62
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. _a -> b_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 63
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. j
#     core type: Variable
#     sub-expressions:
# 62. a_{_a}
#     core type: IndexedVar
# variable: 64
# index: 67
# 63. b_{_a}
#     core type: IndexedVar
# variable: 65
# index: 67
# 64. a
#     core type: Variable
#     sub-expressions:
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. _a
#     core type: Variable
#     sub-expressions:
