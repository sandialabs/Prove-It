# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Lambda, Q, f, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Mult, Natural, NaturalPos, Sum
from proveit.numbers.summation import summation_b1toj_fQ

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(f, sub_expr1)
sub_expr3 = Function(Q, sub_expr1)
expr = Lambda([i, j, k], Conditional(Forall(instance_param_or_params = [f, Q], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr2, Complex), condition = sub_expr3), Forall(instance_param_or_params = [a_1_to_i, c_1_to_k], instance_expr = Equals(Mult(a_1_to_i, summation_b1toj_fQ, c_1_to_k), Sum(index_or_indices = sub_expr1, summand = Mult(a_1_to_i, sub_expr2, c_1_to_k), condition = sub_expr3)).with_wrapping_at(2), domain = Complex).with_wrapping()).with_wrapping_at(2)), And(InSet(i, Natural), InSet(j, NaturalPos), InSet(k, Natural))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(i, j, k\right) \mapsto \left\{\forall_{f, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(f\left(b_{1}, b_{2}, \ldots, b_{j}\right) \in \mathbb{C}\right)\right] \Rightarrow  \\ \left[\begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right]\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) =  \\ \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right)\right] \end{array} \end{array}\right)\end{array}\right] \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}^+ ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (i, j, k) -> {forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]) if i in Natural ,  j in NaturalPos ,  k in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 68, 79, 72
# 2. {forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]) if i in Natural ,  j in NaturalPos ,  k in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])])
#    core type: Operation
#    operator: 23
#    operand: 7
# 4. (i in Natural) and (j in NaturalPos) and (k in Natural)
#    core type: Operation
#    operator: 36
#    operands: 6
# 5. ((f, Q) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (i in Natural, j in NaturalPos, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (f, Q) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])])
#    core type: Lambda
#    parameters: 11\n   body: 12
# 8. i in Natural
#    core type: Operation
#    operator: 54
#    operands: 13
# 9. j in NaturalPos
#    core type: Operation
#    operator: 54
#    operands: 14
# 10. k in Natural
#     core type: Operation
#     operator: 54
#     operands: 15
# 11. (f, Q)
#     core type: ExprTuple
#     sub-expressions: 69, 66
# 12. [forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 68, 19
# 14. (j, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 79, 18
# 15. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 72, 19
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex), forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})]))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)
#     core type: Operation
#     operator: 23
#     operand: 25
# 21. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])
#     core type: Operation
#     operator: 23
#     operand: 26
# 22. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 70\n    body: 27
# 26. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#     core type: Lambda
#     parameters: 28\n    body: 29
# 27. {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 30
#     condition: 62
# 28. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 65
# 29. {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. f(b_{1}, b_{2}, ..., b_{j}) in Complex
#     core type: Operation
#     operator: 54
#     operands: 33
# 31. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})]
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{k} in Complex)
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (f(b_{1}, b_{2}, ..., b_{j}), Complex)
#     core type: ExprTuple
#     sub-expressions: 64, 58
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 60
#     operands: 42
# 39. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Operation
#     operator: 50
#     operand: 47
# 40. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 78
#     end_index: 68
# 41. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 78
#     end_index: 72
# 42. (a_{1}, a_{2}, ..., a_{i}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 46, 65
# 43. ((b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 84
#     body: 48
# 45. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 84
#     body: 49
# 46. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 50
#     operand: 56
# 47. (b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 70\n    body: 52
# 48. a_{_a} in Complex
#     core type: Operation
#     operator: 54
#     operands: 53
# 49. c_{_a} in Complex
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. Sum
#     core type: Literal
#     sub-expressions:
# 51. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 57
#     condition: 62
# 53. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 73, 58
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 75, 58
# 56. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 70\n    body: 59
# 57. a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. Complex
#     core type: Literal
#     sub-expressions:
# 59. {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 64
#     condition: 62
# 60. *
#     core type: Literal
#     sub-expressions:
# 61. (a_{1}, a_{2}, ..., a_{i}, f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 64, 65
# 62. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 66
#     operands: 70
# 63. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 78
#     end_index: 68
# 64. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 78
#     end_index: 72
# 66. Q
#     core type: Variable
#     sub-expressions:
# 67. _a -> a_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 73
# 68. i
#     core type: Variable
#     sub-expressions:
# 69. f
#     core type: Variable
#     sub-expressions:
# 70. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 74
# 71. _a -> c_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 75
# 72. k
#     core type: Variable
#     sub-expressions:
# 73. a_{_a}
#     core type: IndexedVar
# variable: 76
# index: 84
# 74. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 78
#     end_index: 79
# 75. c_{_a}
#     core type: IndexedVar
# variable: 80
# index: 84
# 76. a
#     core type: Variable
#     sub-expressions:
# 77. _a -> b_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 81
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. j
#     core type: Variable
#     sub-expressions:
# 80. c
#     core type: Variable
#     sub-expressions:
# 81. b_{_a}
#     core type: IndexedVar
# variable: 82
# index: 84
# 82. b
#     core type: Variable
#     sub-expressions:
# 83. (_a)
#     core type: ExprTuple
#     sub-expressions: 84
# 84. _a
#     core type: Variable
#     sub-expressions:
