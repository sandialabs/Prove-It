# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import Mult, Real, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_n], Conditional(InSet(Mult(a_1_to_n), Real), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Real), one, n))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Real if (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{n} in Real).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R} \textrm{ if } \left(a_{1} \in \mathbb{R}\right) \land \ldots \land \left(a_{n} \in \mathbb{R}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Real if (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{n} in Real).
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {(a_{1} * ..a_{_a}.. * a_{n}) in Real if (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{n} in Real).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * ..a_{_a}.. * a_{n}) in Real
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{n} in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} * ..a_{_a}.. * a_{n}, Real)
#    core type: ExprTuple
#    sub-expressions: 7, 20
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Real, ..a_{_a} in Real.., a_{n} in Real)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a_{1} in Real), ..(a_{_a} in Real).., (a_{n} in Real)
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 15
#    end_index: 16
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. _a -> (a_{_a} in Real)
#     core type: Lambda
#     parameter: 22
#     body: 13
# 12. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 13. a_{_a} in Real
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. _a -> a_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (a_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. a_{_a}
#     core type: IndexedVar
# variable: 21
# index: 22
# 20. Real
#     core type: Literal
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. _a
#     core type: Variable
#     sub-expressions:
