# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import a_1_to_n
from proveit.logic import InSet
from proveit.numbers import Mult, Natural

# %%
# build up the expression from sub-expressions
expr = InSet(Mult(a_1_to_n), Natural)
# Out:
# expr: (a_{1} * ..a_{_a}.. * a_{n}) in Natural

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{N}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} * ..a_{_a}.. * a_{n}) in Natural
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} * ..a_{_a}.. * a_{n}, Natural)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Natural
#    core type: Literal
#    sub-expressions:
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. a_{1}, ..a_{_a}.., a_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. _a -> a_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. a_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
