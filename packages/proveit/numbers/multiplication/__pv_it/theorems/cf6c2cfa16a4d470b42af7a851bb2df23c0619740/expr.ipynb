# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(Equals(Mult(Neg(x), y), Neg(Mult(x, y))), And(InSet(x, Complex), InSet(y, Complex))))
# Out:
# expr: (x, y) -> {((-x) * y) = (-(x * y)) if x in Complex ,  y in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\left(\left(-x\right) \cdot y\right) = \left(-\left(x \cdot y\right)\right) \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y) -> {((-x) * y) = (-(x * y)) if x in Complex ,  y in Complex.
#    core type: Lambda
#    parameters: 19\n   body: 1
# 1. {((-x) * y) = (-(x * y)) if x in Complex ,  y in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ((-x) * y) = (-(x * y))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x in Complex) and (y in Complex)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((-x) * y, -(x * y))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in Complex, y in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (-x) * y
#    core type: Operation
#    operator: 18
#    operands: 12
# 9. -(x * y)
#    core type: Operation
#    operator: 21
#    operand: 13
# 10. x in Complex
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. y in Complex
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (-x, y)
#     core type: ExprTuple
#     sub-expressions: 17, 23
# 13. x * y
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 17. -x
#     core type: Operation
#     operator: 21
#     operand: 22
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (x, y)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. Complex
#     core type: Literal
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
