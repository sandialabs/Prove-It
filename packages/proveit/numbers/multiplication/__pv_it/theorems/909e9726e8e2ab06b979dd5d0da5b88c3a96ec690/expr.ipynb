# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, S, Variable, b, j
from proveit.logic import InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), S), one, j)
# Out:
# expr: (b_{1} in S), ..(b_{_a} in S).., (b_{j} in S)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b_{1} \in S\right), \ldots, \left(b_{j} \in S\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (b_{1} in S), ..(b_{_a} in S).., (b_{j} in S)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> (b_{_a} in S)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. b_{_a} in S
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b_{_a}, S)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 8. S
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
