# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_real_non_neg_closure">mult_real_non_neg_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_real_non_neg_closure

# %%
# check that the built expression is the same as the stored expression
assert mult_real_non_neg_closure.expr == stored_expr
assert mult_real_non_neg_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_real_non_neg_closure matches stored_expr")
# Out:
# Passed sanity check: mult_real_non_neg_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_real_non_neg_closure.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{R}^{\ge 0}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R}^{\ge 0}\right)\right]

# %%
# display the expression information
mult_real_non_neg_closure.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in RealNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg) if n in Natural.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in RealNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in RealNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Natural
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealNonNeg if (a_{1} in RealNonNeg) and ..(a_{_a} in RealNonNeg).. and (a_{n} in RealNonNeg).
# ...
