# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Q, f, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Mult, Natural, NaturalPos, Sum
from proveit.numbers.summation import summation_b1toj_fQ

# %%
# build up the expression from sub-expressions
sub_expr1 = [b_1_to_j]
sub_expr2 = Function(f, sub_expr1)
sub_expr3 = Function(Q, sub_expr1)
expr = Conditional(Forall(instance_param_or_params = [f, Q], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr2, Complex), condition = sub_expr3), Forall(instance_param_or_params = [a_1_to_i, c_1_to_k], instance_expr = Equals(Mult(a_1_to_i, summation_b1toj_fQ, c_1_to_k), Sum(index_or_indices = sub_expr1, summand = Mult(a_1_to_i, sub_expr2, c_1_to_k), condition = sub_expr3)).with_wrapping_at(2), domain = Complex).with_wrapping()).with_wrapping_at(2)), And(InSet(i, Natural), InSet(j, NaturalPos), InSet(k, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{f, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(f\left(b_{1}, b_{2}, \ldots, b_{j}\right) \in \mathbb{C}\right)\right] \Rightarrow  \\ \left[\begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\right]\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) =  \\ \left[\sum_{b_{1}, b_{2}, \ldots, b_{j}~|~Q\left(b_{1}, b_{2}, \ldots, b_{j}\right)}~\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot f\left(b_{1}, b_{2}, \ldots, b_{j}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right)\right] \end{array} \end{array}\right)\end{array}\right] \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}^+ ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]) if i in Natural ,  j in NaturalPos ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])])
#    core type: Operation
#    operator: 21
#    operand: 5
# 2. (i in Natural) and (j in NaturalPos) and (k in Natural)
#    core type: Operation
#    operator: 34
#    operands: 4
# 3. ((f, Q) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (i in Natural, j in NaturalPos, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (f, Q) -> ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])])
#    core type: Lambda
#    parameters: 9\n   body: 10
# 6. i in Natural
#    core type: Operation
#    operator: 52
#    operands: 11
# 7. j in NaturalPos
#    core type: Operation
#    operator: 52
#    operands: 12
# 8. k in Natural
#    core type: Operation
#    operator: 52
#    operands: 13
# 9. (f, Q)
#    core type: ExprTuple
#    sub-expressions: 67, 64
# 10. [forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])]
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 66, 17
# 12. (j, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 77, 16
# 13. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 70, 17
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex), forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})]))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)
#     core type: Operation
#     operator: 21
#     operand: 23
# 19. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 68\n    body: 25
# 24. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#     core type: Lambda
#     parameters: 26\n    body: 27
# 25. {f(b_{1}, b_{2}, ..., b_{j}) in Complex if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 28
#     condition: 60
# 26. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 61, 63
# 27. {(a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})] if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{k} in Complex).
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. f(b_{1}, b_{2}, ..., b_{j}) in Complex
#     core type: Operation
#     operator: 52
#     operands: 31
# 29. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})]
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{k} in Complex)
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (f(b_{1}, b_{2}, ..., b_{j}), Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 56
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 58
#     operands: 40
# 37. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Operation
#     operator: 48
#     operand: 45
# 38. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 76
#     end_index: 66
# 39. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 76
#     end_index: 70
# 40. (a_{1}, a_{2}, ..., a_{i}, Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 61, 44, 63
# 41. ((b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 82
#     body: 46
# 43. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 82
#     body: 47
# 44. Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 48
#     operand: 54
# 45. (b_{1}, b_{2}, ..., b_{j}) -> {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 68\n    body: 50
# 46. a_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 51
# 47. c_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. Sum
#     core type: Literal
#     sub-expressions:
# 49. ((b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).)
#     core type: ExprTuple
#     sub-expressions: 54
# 50. {a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k} if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 55
#     condition: 60
# 51. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 71, 56
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 73, 56
# 54. (b_{1}, b_{2}, ..., b_{j}) -> {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Lambda
#     parameters: 68\n    body: 57
# 55. a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. Complex
#     core type: Literal
#     sub-expressions:
# 57. {f(b_{1}, b_{2}, ..., b_{j}) if Q(b_{1}, b_{2}, ..., b_{j}).
#     core type: Conditional
#     value: 62
#     condition: 60
# 58. *
#     core type: Literal
#     sub-expressions:
# 59. (a_{1}, a_{2}, ..., a_{i}, f(b_{1}, b_{2}, ..., b_{j}),c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 61, 62, 63
# 60. Q(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 64
#     operands: 68
# 61. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 76
#     end_index: 66
# 62. f(b_{1}, b_{2}, ..., b_{j})
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 76
#     end_index: 70
# 64. Q
#     core type: Variable
#     sub-expressions:
# 65. _a -> a_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 71
# 66. i
#     core type: Variable
#     sub-expressions:
# 67. f
#     core type: Variable
#     sub-expressions:
# 68. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 72
# 69. _a -> c_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 73
# 70. k
#     core type: Variable
#     sub-expressions:
# 71. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 82
# 72. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 76
#     end_index: 77
# 73. c_{_a}
#     core type: IndexedVar
# variable: 78
# index: 82
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. _a -> b_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 79
# 76. 1
#     core type: Literal
#     sub-expressions:
# 77. j
#     core type: Variable
#     sub-expressions:
# 78. c
#     core type: Variable
#     sub-expressions:
# 79. b_{_a}
#     core type: IndexedVar
# variable: 80
# index: 82
# 80. b
#     core type: Variable
#     sub-expressions:
# 81. (_a)
#     core type: ExprTuple
#     sub-expressions: 82
# 82. _a
#     core type: Variable
#     sub-expressions:
