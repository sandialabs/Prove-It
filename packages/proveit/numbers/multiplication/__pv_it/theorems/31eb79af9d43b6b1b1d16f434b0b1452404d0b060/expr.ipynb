# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j], instance_expr = Equals(Neg(Mult(a_1_to_i, Neg(b), c_1_to_j)), Mult(a_1_to_i, b, c_1_to_j)), domain = Complex), And(InSet(i, Natural), InSet(j, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{C}}~\left(\left(-\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left(-b\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{j}\right)\right) = \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{j}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Complex} ((-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})) if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Complex} ((-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 45, 50
# 3. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Complex} ((-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Complex} ((-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {(-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {(-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex).
#    core type: Lambda
#    parameters: 28\n   body: 12
# 10. i in Natural
#     core type: Operation
#     operator: 38
#     operands: 13
# 11. j in Natural
#     core type: Operation
#     operator: 38
#     operands: 14
# 12. {(-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex).
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 17
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 17
# 15. (-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})) = (a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (-(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j}), a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 22. -(a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})
#     core type: Operation
#     operator: 46
#     operand: 32
# 23. a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}
#     core type: Operation
#     operator: 35
#     operands: 28
# 24. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 49
#     end_index: 45
# 25. b in Complex
#     core type: Operation
#     operator: 38
#     operands: 30
# 26. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 49
#     end_index: 50
# 27. (a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 40, 52, 42
# 29. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 33
# 30. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 43
# 31. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 34
# 32. a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. a_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 37
# 34. c_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (a_{1}, a_{2}, ..., a_{i}, -b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 37. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 43
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 43
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 49
#     end_index: 45
# 41. -b
#     core type: Operation
#     operator: 46
#     operand: 52
# 42. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 51
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. (b)
#     core type: ExprTuple
#     sub-expressions: 52
# 48. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 52. b
#     core type: Variable
#     sub-expressions:
# 53. c_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. c
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
