# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j, x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import Forall
from proveit.numbers import Less, Mult, Natural, RealPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j], instance_expr = Forall(instance_param_or_params = [x, y], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j], instance_expr = Less(Mult(a_1_to_i, x, b_1_to_j), Mult(a_1_to_i, y, b_1_to_j)), domain = RealPos, condition = Less(x, y))), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j \in \mathbb{N}}~\left[\forall_{x, y}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{R}^+~|~x < y}~\left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot x\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) < \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot y\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]]
#    core type: Operation
#    operator: 15
#    operand: 2
# 1. ((i, j) -> {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 45, 48
# 4. {forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))] if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]
#    core type: Operation
#    operator: 15
#    operand: 9
# 6. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 24
#    operands: 8
# 7. ((x, y) -> [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))])
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (x, y) -> [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]
#    core type: Lambda
#    parameters: 37\n   body: 12
# 10. i in Natural
#     core type: Operation
#     operator: 50
#     operands: 13
# 11. j in Natural
#     core type: Operation
#     operator: 50
#     operands: 14
# 12. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: Operation
#     operator: 15
#     operand: 18
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 17
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.
#     core type: Lambda
#     parameters: 19\n    body: 20
# 19. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 20. {(a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (b_{1} in RealPos) ,  (b_{2} in RealPos) ,  ... ,  (b_{j} in RealPos) ,  x < y.
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 36
#     operands: 23
# 22. (a_{1} in RealPos) and  (a_{2} in RealPos) and  ... and  (a_{i} in RealPos)and (b_{1} in RealPos) and  (b_{2} in RealPos) and  ... and  (b_{j} in RealPos) and (x < y)
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}, a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. ((a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos),(b_{1} in RealPos), (b_{2} in RealPos), ..., (b_{j} in RealPos), x < y)
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 26. a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 32
#     operands: 31
# 27. a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. (a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 47
#     end_index: 45
# 29. (b_{1} in RealPos), (b_{2} in RealPos), ..., (b_{j} in RealPos)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 47
#     end_index: 48
# 30. x < y
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 38, 42, 39
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (a_{1}, a_{2}, ..., a_{i}, y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 38, 43, 39
# 34. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 58
#     body: 40
# 35. _a -> (b_{_a} in RealPos)
#     core type: Lambda
#     parameter: 58
#     body: 41
# 36. <
#     core type: Literal
#     sub-expressions:
# 37. (x, y)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 39. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 40. a_{_a} in RealPos
#     core type: Operation
#     operator: 50
#     operands: 49
# 41. b_{_a} in RealPos
#     core type: Operation
#     operator: 50
#     operands: 51
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. y
#     core type: Variable
#     sub-expressions:
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 52
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> b_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 53
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 52, 54
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (b_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 53. b_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 54. RealPos
#     core type: Literal
#     sub-expressions:
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. b
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
