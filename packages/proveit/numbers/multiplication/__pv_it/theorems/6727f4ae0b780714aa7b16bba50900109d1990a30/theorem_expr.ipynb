# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_def_rev">mult_def_rev</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.multiplication import mult_def_rev

# %%
# check that the built expression is the same as the stored expression
assert mult_def_rev.expr == stored_expr
assert mult_def_rev.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_def_rev matches stored_expr")
# Out:
# Passed sanity check: mult_def_rev matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}, x \in \mathbb{C}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in \left\{x\right\}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{n}\right) = \left(x \cdot n\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in Natural, x in Complex} [forall_{a_{1}, a_{2}, ..., a_{n} in {x}} ((a_{1} +  a_{2} +  ... +  a_{n}) = (x * n))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((n, x) -> {forall_{a_{1}, a_{2}, ..., a_{n} in {x}} ((a_{1} +  a_{2} +  ... +  a_{n}) = (x * n)) if n in Natural ,  x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (n, x) -> {forall_{a_{1}, a_{2}, ..., a_{n} in {x}} ((a_{1} +  a_{2} +  ... +  a_{n}) = (x * n)) if n in Natural ,  x in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (n, x)
#    core type: ExprTuple
#    sub-expressions: 36, 46
# 4. {forall_{a_{1}, a_{2}, ..., a_{n} in {x}} ((a_{1} +  a_{2} +  ... +  a_{n}) = (x * n)) if n in Natural ,  x in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{n} in {x}} ((a_{1} +  a_{2} +  ... +  a_{n}) = (x * n))
#    core type: Operation
#    operator: 7
#    operand: 10
# ...
