# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, i, j
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Mult(a_1_to_i, one, b_1_to_j), Mult(a_1_to_i, b_1_to_j)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, j)))
# Out:
# expr: {(a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \ldots \cdot a_{i} \cdot 1 \cdot b_{1} \cdot \ldots \cdot b_{j}\right) = \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{1} \cdot \ldots \cdot b_{j}\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b_{1} \in \mathbb{C} ,  \ldots ,  b_{j} \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}) = (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}, a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. a_{1} * ..a_{_a}.. * a_{i} * 1 * b_{1} * ..b_{_a}.. * b_{j}
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 23
#    end_index: 21
# 10. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 23
#     end_index: 24
# 11. (a_{1}, ..a_{_a}.., a_{i}, 1, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 16, 23, 17
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 33
#     body: 18
# 15. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 33
#     body: 19
# 16. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 23
#     end_index: 21
# 17. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 18. a_{_a} in Complex
#     core type: Operation
#     operator: 26
#     operands: 25
# 19. b_{_a} in Complex
#     core type: Operation
#     operator: 26
#     operands: 27
# 20. _a -> a_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 28
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. _a -> b_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 29
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. j
#     core type: Variable
#     sub-expressions:
# 25. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. a_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 29. b_{_a}
#     core type: IndexedVar
# variable: 32
# index: 33
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. _a
#     core type: Variable
#     sub-expressions:
