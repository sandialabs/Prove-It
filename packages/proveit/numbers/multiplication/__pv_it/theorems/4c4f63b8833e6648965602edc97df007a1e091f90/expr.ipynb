# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import Greater, Less, Mult, Real, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Greater(Mult(x, a), Mult(y, a)), And(InSet(a, Real), InSet(x, Real), InSet(y, Real), Less(x, y), Less(a, zero)))
# Out:
# expr: {(x * a) > (y * a) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a < 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x \cdot a\right) > \left(y \cdot a\right) \textrm{ if } a \in \mathbb{R} ,  x \in \mathbb{R} ,  y \in \mathbb{R} ,  x < y ,  a < 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x * a) > (y * a) if a in Real ,  x in Real ,  y in Real ,  x < y ,  a < 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x * a) > (y * a)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Real) and (x in Real) and (y in Real) and (x < y) and (a < 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. >
#    core type: Literal
#    sub-expressions:
# 4. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, x in Real, y in Real, x < y, a < 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13
# 7. x * a
#    core type: Operation
#    operator: 15
#    operands: 14
# 8. y * a
#    core type: Operation
#    operator: 15
#    operands: 16
# 9. a in Real
#    core type: Operation
#    operator: 19
#    operands: 17
# 10. x in Real
#     core type: Operation
#     operator: 19
#     operands: 18
# 11. y in Real
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. x < y
#     core type: Operation
#     operator: 22
#     operands: 21
# 13. a < 0
#     core type: Operation
#     operator: 22
#     operands: 23
# 14. (x, a)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (y, a)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 17. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 18. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (y, Real)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 21. (x, y)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. <
#     core type: Literal
#     sub-expressions:
# 23. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. Real
#     core type: Literal
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. 0
#     core type: Literal
#     sub-expressions:
