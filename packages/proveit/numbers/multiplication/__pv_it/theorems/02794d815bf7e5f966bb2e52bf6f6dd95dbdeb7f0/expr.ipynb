# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j, k], Conditional(Forall([a_1_to_i, b, c_1_to_j, d_1_to_k], Equals(Mult(a_1_to_i, b, c_1_to_j, d_1_to_k), Mult(a_1_to_i, c_1_to_j, b, d_1_to_k)).with_wrapping_at(2), domains = [Complex, Complex, Complex, Complex]), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural))))
# Out:
# expr: (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j, k\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b \cdot c_{1} \cdot \ldots \cdot c_{j} \cdot d_{1} \cdot \ldots \cdot d_{k}\right) =  \\ \left(a_{1} \cdot \ldots \cdot a_{i} \cdot c_{1} \cdot \ldots \cdot c_{j} \cdot b \cdot d_{1} \cdot \ldots \cdot d_{k}\right) \end{array}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 43, 45, 48
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Lambda
#    parameters: 28\n   body: 8
# 7. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. {(a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{j} in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Conditional
#    value: 12
#    condition: 13
# 9. i in Natural
#    core type: Operation
#    operator: 51
#    operands: 14
# 10. j in Natural
#     core type: Operation
#     operator: 51
#     operands: 15
# 11. k in Natural
#     core type: Operation
#     operator: 51
#     operands: 16
# 12. (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{j} in Complex) and (d_{1} in Complex) and ..(d_{_a} in Complex).. and (d_{k} in Complex)
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 21
# 15. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 21
# 16. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}, a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{j} in Complex, d_{1} in Complex, ..d_{_a} in Complex.., d_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 47
#     end_index: 43
# 25. b in Complex
#     core type: Operation
#     operator: 51
#     operands: 32
# 26. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 47
#     end_index: 45
# 27. (d_{1} in Complex), ..(d_{_a} in Complex).., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 47
#     end_index: 48
# 28. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 39, 36, 37
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 39, 37
# 31. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 38
# 32. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 56
# 33. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 40
# 34. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 41
# 35. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 43
# 36. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 37. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 38. a_{_a} in Complex
#     core type: Operation
#     operator: 51
#     operands: 49
# 39. b
#     core type: Variable
#     sub-expressions:
# 40. c_{_a} in Complex
#     core type: Operation
#     operator: 51
#     operands: 50
# 41. d_{_a} in Complex
#     core type: Operation
#     operator: 51
#     operands: 52
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 43. i
#     core type: Variable
#     sub-expressions:
# 44. _a -> c_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 45. j
#     core type: Variable
#     sub-expressions:
# 46. _a -> d_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. k
#     core type: Variable
#     sub-expressions:
# 49. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 56
# 50. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 54. c_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 55. d_{_a}
#     core type: IndexedVar
# variable: 59
# index: 60
# 56. Complex
#     core type: Literal
#     sub-expressions:
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. c
#     core type: Variable
#     sub-expressions:
# 59. d
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
