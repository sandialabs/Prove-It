# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, Mult, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(one, x), x), InSet(x, Complex))
# Out:
# expr: {(1 * x) = x if x in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(1 \cdot x\right) = x \textrm{ if } x \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(1 * x) = x if x in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (1 * x) = x
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (1 * x, x)
#    core type: ExprTuple
#    sub-expressions: 7, 12
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 7. 1 * x
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (1, x)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
