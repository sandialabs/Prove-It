# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet
from proveit.numbers import Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Mult(a, b), Natural), And(InSet(a, Natural), InSet(b, Natural)))
# Out:
# expr: {(a * b) in Natural if a in Natural ,  b in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \cdot b\right) \in \mathbb{N} \textrm{ if } a \in \mathbb{N} ,  b \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a * b) in Natural if a in Natural ,  b in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a * b) in Natural
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in Natural) and (b in Natural)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a * b, Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Natural, b in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in Natural
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in Natural
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (a, Natural)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, Natural)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. Natural
#     core type: Literal
#     sub-expressions:
