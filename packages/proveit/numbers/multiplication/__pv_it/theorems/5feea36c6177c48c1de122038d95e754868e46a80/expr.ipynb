# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, b, j
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Forall
from proveit.numbers import Abs, Add, Complex, Mult, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
expr = Forall(instance_param_or_params = [a_1_to_i, c_1_to_k], instance_expr = Forall(instance_param_or_params = [b_1_to_j], instance_expr = Equals(Mult(a_1_to_i, Abs(Add(b_1_to_j)), c_1_to_k), Abs(Add(ExprRange(sub_expr1, Mult(a_1_to_i, IndexedVar(b, sub_expr1), c_1_to_k), one, j)))).with_wrapping_at(2), domain = Complex).with_wrapping(), domain = RealNonNeg).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{k} \in \mathbb{R}^{\ge 0}}~\\
# \left[\begin{array}{l}\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left|b_{1} +  b_{2} +  \ldots +  b_{j}\right|\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) =  \\ \left|\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{1}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) +  \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{2}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right) +  \ldots +  \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot b_{j}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{k}\right)\right| \end{array} \end{array}\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k}) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{k})
#    core type: ExprTuple
#    sub-expressions: 54, 56
# 4. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|) if (a_{1} in RealNonNeg) ,  (a_{2} in RealNonNeg) ,  ... ,  (a_{i} in RealNonNeg), (c_{1} in RealNonNeg) ,  (c_{2} in RealNonNeg) ,  ... ,  (c_{k} in RealNonNeg).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (a_{1} in RealNonNeg) and  (a_{2} in RealNonNeg) and  ... and  (a_{i} in RealNonNeg)and (c_{1} in RealNonNeg) and  (c_{2} in RealNonNeg) and  ... and  (c_{k} in RealNonNeg)
#    core type: Operation
#    operator: 22
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ((a_{1} in RealNonNeg), (a_{2} in RealNonNeg), ..., (a_{i} in RealNonNeg),(c_{1} in RealNonNeg), (c_{2} in RealNonNeg), ..., (c_{k} in RealNonNeg))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Lambda
#     parameters: 45\n    body: 13
# 11. (a_{1} in RealNonNeg), (a_{2} in RealNonNeg), ..., (a_{i} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 62
#     end_index: 58
# 12. (c_{1} in RealNonNeg), (c_{2} in RealNonNeg), ..., (c_{k} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 62
#     end_index: 63
# 13. {(a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})| if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. _a -> (a_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 70
#     body: 18
# 15. _a -> (c_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 70
#     body: 19
# 16. (a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. a_{_a} in RealNonNeg
#     core type: Operation
#     operator: 39
#     operands: 24
# 19. c_{_a} in RealNonNeg
#     core type: Operation
#     operator: 39
#     operands: 25
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}, |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (a_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 64, 29
# 25. (c_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 66, 29
# 26. a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 51
#     operands: 30
# 27. |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|
#     core type: Operation
#     operator: 36
#     operand: 34
# 28. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 62
#     end_index: 50
# 29. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, a_{2}, ..., a_{i}, |b_{1} +  b_{2} +  ... +  b_{j}|,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 54, 33, 56
# 31. ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 34
# 32. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 70
#     body: 35
# 33. |b_{1} +  b_{2} +  ... +  b_{j}|
#     core type: Operation
#     operator: 36
#     operand: 41
# 34. (a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Operation
#     operator: 44
#     operands: 38
# 35. b_{_a} in Complex
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. Abs
#     core type: Literal
#     sub-expressions:
# 37. (b_{1} +  b_{2} +  ... +  b_{j})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}), (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}), ..., (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))
#     core type: ExprTuple
#     sub-expressions: 42
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 43
# 41. b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. (a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}), (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}), ..., (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 62
#     end_index: 50
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 47
# 46. _b -> (a_{1} *  a_{2} *  ... *  a_{i} * b_{_b}* c_{1} *  c_{2} *  ... *  c_{k})
#     core type: Lambda
#     parameter: 65
#     body: 48
# 47. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 62
#     end_index: 50
# 48. a_{1} *  a_{2} *  ... *  a_{i} * b_{_b}* c_{1} *  c_{2} *  ... *  c_{k}
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 53
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (a_{1}, a_{2}, ..., a_{i}, b_{_b},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 54, 55, 56
# 53. b_{_a}
#     core type: IndexedVar
# variable: 59
# index: 70
# 54. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 62
#     end_index: 58
# 55. b_{_b}
#     core type: IndexedVar
# variable: 59
# index: 65
# 56. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 64
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. b
#     core type: Variable
#     sub-expressions:
# 60. (_b)
#     core type: ExprTuple
#     sub-expressions: 65
# 61. _a -> c_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 66
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. a_{_a}
#     core type: IndexedVar
# variable: 67
# index: 70
# 65. _b
#     core type: Variable
#     sub-expressions:
# 66. c_{_a}
#     core type: IndexedVar
# variable: 68
# index: 70
# 67. a
#     core type: Variable
#     sub-expressions:
# 68. c
#     core type: Variable
#     sub-expressions:
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. _a
#     core type: Variable
#     sub-expressions:
