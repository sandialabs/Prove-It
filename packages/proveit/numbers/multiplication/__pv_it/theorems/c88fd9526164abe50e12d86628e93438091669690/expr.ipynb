# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_n], InSet(Mult(a_1_to_n), Complex), domains = [Complex])
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} ((a_{1} * ..a_{_a}.. * a_{n}) in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{n} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{C}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} ((a_{1} * ..a_{_a}.. * a_{n}) in Complex)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in Complex if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex).
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {(a_{1} * ..a_{_a}.. * a_{n}) in Complex if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a_{1} * ..a_{_a}.. * a_{n}) in Complex
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1} * ..a_{_a}.. * a_{n}, Complex)
#    core type: ExprTuple
#    sub-expressions: 9, 22
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 18
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 24
#     body: 15
# 14. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. a_{_a} in Complex
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> a_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. a_{_a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 22. Complex
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
