# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals
from proveit.numbers import Mult

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(a_1_to_i, Mult(b_1_to_j), c_1_to_k), Mult(a_1_to_i, b_1_to_j, c_1_to_k)).with_wrapping_at(2)
# Out:
# expr: (a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(b_{1} \cdot \ldots \cdot b_{j}\right) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{1} \cdot \ldots \cdot b_{j} \cdot c_{1} \cdot \ldots \cdot c_{k}\right) \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}, a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k}
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (a_{1}, ..a_{_a}.., a_{i}, b_{1} * ..b_{_a}.. * b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 7, 9
# 6. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 16, 9
# 7. b_{1} * ..b_{_a}.. * b_{j}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 20
#    end_index: 13
# 9. c_{1}, ..c_{_a}.., c_{k}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 20
#    end_index: 15
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 16
# 12. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 17
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. _a -> c_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 18
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 17. a_{_a}
#     core type: IndexedVar
# variable: 22
# index: 26
# 18. c_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 19. _a -> b_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. j
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. c
#     core type: Variable
#     sub-expressions:
# 24. b_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 25. b
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
