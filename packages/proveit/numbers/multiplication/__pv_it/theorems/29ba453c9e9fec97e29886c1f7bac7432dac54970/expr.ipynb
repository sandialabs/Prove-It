# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = Lambda([a, x, y], Conditional(Equals(Mult(x, a), Mult(y, a)), And(InSet(a, Complex), InSet(x, Complex), InSet(y, Complex), Equals(x, y))))
# Out:
# expr: (a, x, y) -> {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, x, y\right) \mapsto \left\{\left(x \cdot a\right) = \left(y \cdot a\right) \textrm{ if } a \in \mathbb{C} ,  x \in \mathbb{C} ,  y \in \mathbb{C} ,  x = y\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, x, y) -> {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 23, 25, 26
# 2. {(x * a) = (y * a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x * a) = (y * a)
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (a in Complex) and (x in Complex) and (y in Complex) and (x = y)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x * a, y * a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Complex, x in Complex, y in Complex, x = y)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. x * a
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. y * a
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a in Complex
# ...
