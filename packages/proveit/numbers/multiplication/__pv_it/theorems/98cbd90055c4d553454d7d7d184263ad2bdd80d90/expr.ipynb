# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Mult, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a_1_to_i, x, y, b_1_to_j], instance_expr = Equals(Mult(a_1_to_i, subtract(x, y), b_1_to_j), subtract(Mult(a_1_to_i, x, b_1_to_j), Mult(a_1_to_i, y, b_1_to_j))).with_wrapping_at(2), domain = Complex)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a_{1}, a_{2}, \ldots, a_{i}, x, y, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot \left(x - y\right)\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) =  \\ \left(\left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot x\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right) - \left(a_{1} \cdot  a_{2} \cdot  \ldots \cdot  a_{i} \cdot y\cdot b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, a_{2}, ..., a_{i}, x, y,b_{1}, b_{2}, ..., b_{j})
#    core type: ExprTuple
#    sub-expressions: 44, 37, 45, 46
# 5. {(a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  x in Complex ,  y in Complex, (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (x in Complex) and (y in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}, (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), x in Complex, y in Complex,(b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 42
#     operands: 18
# 13. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 29
#     operands: 19
# 14. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 50
#     end_index: 48
# 15. x in Complex
#     core type: Operation
#     operator: 34
#     operands: 21
# 16. y in Complex
#     core type: Operation
#     operator: 34
#     operands: 22
# 17. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 50
#     end_index: 51
# 18. (a_{1}, a_{2}, ..., a_{i}, x - y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 44, 24, 46
# 19. (a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}, -(a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 27
# 21. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 22. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 39
# 23. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 28
# 24. x - y
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 42
#     operands: 31
# 26. -(a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: Operation
#     operator: 40
#     operand: 38
# 27. a_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 33
# 28. b_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 31. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 44, 37, 46
# 32. (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 39
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 36. -y
#     core type: Operation
#     operator: 40
#     operand: 45
# 37. x
#     core type: Variable
#     sub-expressions:
# 38. a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. (y)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (a_{1}, a_{2}, ..., a_{i}, y,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 44. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 47. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. j
#     core type: Variable
#     sub-expressions:
# 52. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 53. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
