# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#negative_rational_is_rational_neg">negative_rational_is_rational_neg</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import negative_rational_is_rational_neg

# %%
# check that the built expression is the same as the stored expression
assert negative_rational_is_rational_neg.expr == stored_expr
assert negative_rational_is_rational_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: negative_rational_is_rational_neg matches stored_expr")
# Out:
# Passed sanity check: negative_rational_is_rational_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negative_rational_is_rational_neg.latex())
# Out:
# \vdash \forall_{q \in \mathbb{Q}~|~q < 0}~\left(q \in \mathbb{Q}^-\right)

# %%
# display the expression information
negative_rational_is_rational_neg.expr_info()
# Out:
# 0. forall_{q in Rational | q < 0} (q in RationalNeg)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. q -> {q in RationalNeg if q in Rational ,  q < 0.
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. {q in RationalNeg if q in Rational ,  q < 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. q in RationalNeg
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (q in Rational) and (q < 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (q, RationalNeg)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (q in Rational, q < 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. RationalNeg
#    core type: Literal
#    sub-expressions:
# 10. q in Rational
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. q < 0
#     core type: Operation
#     operator: 14
# ...
