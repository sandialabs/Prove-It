# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, q
from proveit.logic import Equals, Exists, InSet
from proveit.numbers import Natural, NaturalPos, RationalNonNeg, frac

# %%
# build up the expression from sub-expressions
expr = Lambda(q, Conditional(Exists([a, b], Equals(q, frac(a, b)), domains = [Natural, NaturalPos]), InSet(q, RationalNonNeg)))
# Out:
# expr: q -> {exists_{a in Natural, b in NaturalPos} (q = (a / b)) if q in RationalNonNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# q \mapsto \left\{\exists_{a \in \mathbb{N}, b \in \mathbb{N}^+}~\left(q = \frac{a}{b}\right) \textrm{ if } q \in \mathbb{Q}^{\geq 0}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. q -> {exists_{a in Natural, b in NaturalPos} (q = (a / b)) if q in RationalNonNeg.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {exists_{a in Natural, b in NaturalPos} (q = (a / b)) if q in RationalNonNeg.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{a in Natural, b in NaturalPos} (q = (a / b))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. q in RationalNonNeg
#    core type: Operation
#    operator: 22
#    operands: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. (a, b) -> {q = (a / b) if a in Natural ,  b in NaturalPos.
#    core type: Lambda
#    parameters: 20\n   body: 7
# 6. (q, RationalNonNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 7. {q = (a / b) if a in Natural ,  b in NaturalPos.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. RationalNonNeg
#    core type: Literal
#    sub-expressions:
# 9. q = (a / b)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in Natural) and (b in NaturalPos)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (q, a / b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in Natural, b in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. q
#     core type: Variable
#     sub-expressions:
# 16. a / b
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. a in Natural
#     core type: Operation
#     operator: 22
#     operands: 21
# 18. b in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. /
#     core type: Literal
#     sub-expressions:
# 20. (a, b)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 21. (a, Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (b, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
# 27. NaturalPos
#     core type: Literal
#     sub-expressions:
