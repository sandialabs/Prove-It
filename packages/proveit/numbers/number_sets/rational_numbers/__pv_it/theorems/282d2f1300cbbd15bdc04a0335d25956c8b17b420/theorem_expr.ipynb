# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#rational_non_neg_within_rational">rational_non_neg_within_rational</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import rational_non_neg_within_rational

# %%
# check that the built expression is the same as the stored expression
assert rational_non_neg_within_rational.expr == stored_expr
assert rational_non_neg_within_rational.expr._style_id == stored_expr._style_id
print("Passed sanity check: rational_non_neg_within_rational matches stored_expr")
# Out:
# Passed sanity check: rational_non_neg_within_rational matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rational_non_neg_within_rational.latex())
# Out:
# \vdash \mathbb{Q}^{\geq 0} \subset \mathbb{Q}

# %%
# display the expression information
rational_non_neg_within_rational.expr_info()
# Out:
# 0. RationalNonNeg proper_subset Rational
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (RationalNonNeg, Rational)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalNonNeg
#    core type: Literal
#    sub-expressions:
# 4. Rational
#    core type: Literal
#    sub-expressions:
