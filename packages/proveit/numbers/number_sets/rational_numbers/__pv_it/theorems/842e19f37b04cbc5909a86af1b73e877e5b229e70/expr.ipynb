# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, q
from proveit.logic import And, Equals, Exists, InSet
from proveit.numbers import GCD, NaturalPos, RationalPos, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda(q, Conditional(Exists([a, b], And(Equals(q, frac(a, b)), Equals(GCD(a, b), one)), domains = [NaturalPos, NaturalPos]), InSet(q, RationalPos)))
# Out:
# expr: q -> {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# q \mapsto \left\{\exists_{a, b \in \mathbb{N}^+}~\left(\left(q = \frac{a}{b}\right) \land \left(gcd(a, b) = 1\right)\right) \textrm{ if } q \in \mathbb{Q}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. q -> {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. {exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1)) if q in RationalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. q in RationalPos
#    core type: Operation
#    operator: 22
#    operands: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. (a, b) -> {(q = (a / b)) and (gcd(a, b) = 1) if a in NaturalPos ,  b in NaturalPos.
#    core type: Lambda
#    parameters: 31\n   body: 7
# 6. (q, RationalPos)
#    core type: ExprTuple
#    sub-expressions: 24, 8
# 7. {(q = (a / b)) and (gcd(a, b) = 1) if a in NaturalPos ,  b in NaturalPos.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. RationalPos
#    core type: Literal
#    sub-expressions:
# 9. (q = (a / b)) and (gcd(a, b) = 1)
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. (a in NaturalPos) and (b in NaturalPos)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (q = (a / b), gcd(a, b) = 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a in NaturalPos, b in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. q = (a / b)
#     core type: Operation
#     operator: 19
#     operands: 18
# 15. gcd(a, b) = 1
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. a in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 21
# 17. b in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. (q, a / b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (gcd(a, b), 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 21. (a, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 32, 28
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (b, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 33, 28
# 24. q
#     core type: Variable
#     sub-expressions:
# 25. a / b
#     core type: Operation
#     operator: 29
#     operands: 31
# 26. gcd(a, b)
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. NaturalPos
#     core type: Literal
#     sub-expressions:
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. gcd
#     core type: Literal
#     sub-expressions:
# 31. (a, b)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. b
#     core type: Variable
#     sub-expressions:
