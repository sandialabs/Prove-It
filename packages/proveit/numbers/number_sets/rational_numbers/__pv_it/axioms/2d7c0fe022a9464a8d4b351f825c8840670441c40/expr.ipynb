# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import q
from proveit.logic import Equals, SetOfAll
from proveit.numbers import GreaterEq, Rational, RationalNonNeg, zero

# %%
# build up the expression from sub-expressions
expr = Equals(RationalNonNeg, SetOfAll([q], q, domains = [Rational], condition = GreaterEq(q, zero)))
# Out:
# expr: RationalNonNeg = {q s.t. q >= 0}_{q in Rational}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathbb{Q}^{\geq 0} = \left\{q~|~q \geq 0\right\}_{q \in \mathbb{Q}}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. RationalNonNeg = {q s.t. q >= 0}_{q in Rational}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (RationalNonNeg, {q s.t. q >= 0}_{q in Rational})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalNonNeg
#    core type: Literal
#    sub-expressions:
# 4. {q s.t. q >= 0}_{q in Rational}
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. SetOfAll
#    core type: Literal
#    sub-expressions:
# 6. q -> {q if q in Rational ,  q >= 0.
#    core type: Lambda
#    parameter: 18
#    body: 7
# 7. {q if q in Rational ,  q >= 0.
#    core type: Conditional
#    value: 18
#    condition: 8
# 8. (q in Rational) and (q >= 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (q in Rational, q >= 0)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. q in Rational
#     core type: Operation
#     operator: 13
# ...
