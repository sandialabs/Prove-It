# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#rationals_pos_def">rationals_pos_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import rationals_pos_def

# %%
# check that the built expression is the same as the stored expression
assert rationals_pos_def.expr == stored_expr
assert rationals_pos_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: rationals_pos_def matches stored_expr")
# Out:
# Passed sanity check: rationals_pos_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rationals_pos_def.latex())
# Out:
# \vdash \mathbb{Q}^+ = \left\{q~|~q > 0\right\}_{q \in \mathbb{Q}}

# %%
# display the expression information
rationals_pos_def.expr_info()
# Out:
# 0. RationalPos = {q s.t. q > 0}_{q in Rational}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (RationalPos, {q s.t. q > 0}_{q in Rational})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalPos
#    core type: Literal
#    sub-expressions:
# 4. {q s.t. q > 0}_{q in Rational}
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. SetOfAll
#    core type: Literal
#    sub-expressions:
# 6. q -> {q if q in Rational ,  q > 0.
#    core type: Lambda
#    parameter: 18
#    body: 7
# 7. {q if q in Rational ,  q > 0.
#    core type: Conditional
#    value: 18
#    condition: 8
# 8. (q in Rational) and (q > 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (q in Rational, q > 0)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. q in Rational
#     core type: Operation
#     operator: 13
#     operands: 14
# ...
