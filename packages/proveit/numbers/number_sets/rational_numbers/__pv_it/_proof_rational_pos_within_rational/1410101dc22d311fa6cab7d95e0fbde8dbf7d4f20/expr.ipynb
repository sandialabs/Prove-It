# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Equals, Forall, InSet, SubsetEq
from proveit.numbers import Rational, RationalPos

# %%
# build up the expression from sub-expressions
expr = Equals(SubsetEq(RationalPos, Rational), Forall([x], InSet(x, Rational), domains = [RationalPos]))
# Out:
# expr: (RationalPos subseteq Rational) = [forall_{x in RationalPos} (x in Rational)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathbb{Q}^+ \subseteq \mathbb{Q}\right) = \left[\forall_{x \in \mathbb{Q}^+}~\left(x \in \mathbb{Q}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (RationalPos subseteq Rational) = [forall_{x in RationalPos} (x in Rational)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (RationalPos subseteq Rational, forall_{x in RationalPos} (x in Rational))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalPos subseteq Rational
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{x in RationalPos} (x in Rational)
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (RationalPos, Rational)
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> {x in Rational if x in RationalPos.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 9. {x in Rational if x in RationalPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. x in Rational
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. x in RationalPos
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x, Rational)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, RationalPos)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. Rational
#     core type: Literal
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. RationalPos
#     core type: Literal
#     sub-expressions:
