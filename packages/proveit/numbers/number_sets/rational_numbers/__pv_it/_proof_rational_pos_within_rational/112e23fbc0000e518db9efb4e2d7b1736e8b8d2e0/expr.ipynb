# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import SubsetEq
from proveit.numbers import Rational, RationalPos

# %%
# build up the expression from sub-expressions
expr = SubsetEq(RationalPos, Rational)
# Out:
# expr: RationalPos subseteq Rational

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathbb{Q}^+ \subseteq \mathbb{Q}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. RationalPos subseteq Rational
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. (RationalPos, Rational)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalPos
#    core type: Literal
#    sub-expressions:
# 4. Rational
#    core type: Literal
#    sub-expressions:
