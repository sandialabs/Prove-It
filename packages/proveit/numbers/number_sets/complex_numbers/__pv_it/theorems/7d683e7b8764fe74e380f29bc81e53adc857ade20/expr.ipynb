# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Boolean, Forall, InSet
from proveit.numbers import Complex

# %%
# build up the expression from sub-expressions
expr = Forall([x], InSet(InSet(x, Complex), Boolean))
# Out:
# expr: forall_{x} ((x in Complex) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x}~\left(\left(x \in \mathbb{C}\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x} ((x in Complex) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x in Complex) in BOOLEAN)
#    core type: Lambda
#    parameter: 9
#    body: 3
# 3. (x in Complex) in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 4
# 4. (x in Complex, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x in Complex
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. Complex
#     core type: Literal
#     sub-expressions:
