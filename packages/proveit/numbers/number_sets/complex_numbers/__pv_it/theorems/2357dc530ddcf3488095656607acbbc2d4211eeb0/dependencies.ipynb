# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#int_within_complex">int_within_complex</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/int_within_complex/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.complex_numbers import int_within_complex

# %%
# %dependencies int_within_complex
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon int_within_complex</h3>
