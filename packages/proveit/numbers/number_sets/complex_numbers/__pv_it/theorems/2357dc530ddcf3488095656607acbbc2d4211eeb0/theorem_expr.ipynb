# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#int_within_complex">int_within_complex</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.complex_numbers import int_within_complex

# %%
# check that the built expression is the same as the stored expression
assert int_within_complex.expr == stored_expr
assert int_within_complex.expr._style_id == stored_expr._style_id
print("Passed sanity check: int_within_complex matches stored_expr")
# Out:
# Passed sanity check: int_within_complex matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(int_within_complex.latex())
# Out:
# \vdash \mathbb{Z} \subset \mathbb{C}

# %%
# display the expression information
int_within_complex.expr_info()
# Out:
# 0. Integer proper_subset Complex
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (Integer, Complex)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Integer
#    core type: Literal
#    sub-expressions:
# 4. Complex
#    core type: Literal
#    sub-expressions:
