# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Boolean, InSet
from proveit.numbers import Complex

# %%
# build up the expression from sub-expressions
expr = InSet(InSet(x, Complex), Boolean)
# Out:
# expr: (x in Complex) in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{C}\right) \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x in Complex) in BOOLEAN
#    core type: Operation
#    operator: 4
#    operands: 1
# 1. (x in Complex, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. x in Complex
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. Complex
#    core type: Literal
#    sub-expressions:
