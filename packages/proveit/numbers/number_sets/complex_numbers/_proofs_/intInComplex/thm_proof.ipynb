# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number_sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">complex_numbers</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#intInComplex">intInComplex</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving intInComplex
