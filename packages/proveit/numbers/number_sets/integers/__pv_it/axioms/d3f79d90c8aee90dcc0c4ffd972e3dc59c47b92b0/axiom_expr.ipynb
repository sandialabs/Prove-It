# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#integers_def">integers_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.integers import integers_def

# %%
# check that the built expression is the same as the stored expression
assert integers_def.expr == stored_expr
assert integers_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: integers_def matches stored_expr")
# Out:
# Passed sanity check: integers_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(integers_def.latex())
# Out:
# \vdash \mathbb{Z} = \left(\mathbb{N} \cup \left\{-n\right\}_{n \in \mathbb{N}^+}\right)

# %%
# display the expression information
integers_def.expr_info()
# Out:
# 0. Integer = (Natural union {-n}_{n in NaturalPos})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Integer, Natural union {-n}_{n in NaturalPos})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Integer
#    core type: Literal
#    sub-expressions:
# 4. Natural union {-n}_{n in NaturalPos}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. union
#    core type: Literal
#    sub-expressions:
# 6. (Natural, {-n}_{n in NaturalPos})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. Natural
#    core type: Literal
#    sub-expressions:
# 8. {-n}_{n in NaturalPos}
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. SetOfAll
#    core type: Literal
#    sub-expressions:
# 10. n -> {-n if n in NaturalPos.
#     core type: Lambda
#     parameter: 17
#     body: 11
# 11. {-n if n in NaturalPos.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. -n
# ...
