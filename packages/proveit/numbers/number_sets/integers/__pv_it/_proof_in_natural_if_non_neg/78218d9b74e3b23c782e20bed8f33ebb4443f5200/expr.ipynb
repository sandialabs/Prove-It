# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, n
from proveit.logic import Equals, SetOfAll, Union
from proveit.numbers import GreaterEq, Integer, Natural, NaturalPos, Neg, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(GreaterEq(a, zero), Equals(Integer, Union(Natural, SetOfAll([n], Neg(n), domains = [NaturalPos]))))
# Out:
# expr: (a >= 0, Integer = (Natural union {-n}_{n in NaturalPos}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \geq 0, \mathbb{Z} = \left(\mathbb{N} \cup \left\{-n\right\}_{n \in \mathbb{N}^+}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a >= 0, Integer = (Natural union {-n}_{n in NaturalPos}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a >= 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Integer = (Natural union {-n}_{n in NaturalPos})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. >=
#    core type: Literal
#    sub-expressions:
# 4. (a, 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Integer, Natural union {-n}_{n in NaturalPos})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. Natural union {-n}_{n in NaturalPos}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (Natural, {-n}_{n in NaturalPos})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. Natural
#     core type: Literal
#     sub-expressions:
# 14. {-n}_{n in NaturalPos}
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. SetOfAll
#     core type: Literal
#     sub-expressions:
# 16. n -> {-n if n in NaturalPos.
#     core type: Lambda
#     parameter: 23
#     body: 17
# 17. {-n if n in NaturalPos.
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. -n
#     core type: Operation
#     operator: 20
#     operand: 23
# 19. n in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. NaturalPos
#     core type: Literal
#     sub-expressions:
