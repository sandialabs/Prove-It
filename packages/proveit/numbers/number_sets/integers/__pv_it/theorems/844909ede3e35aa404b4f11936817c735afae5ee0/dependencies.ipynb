# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#interval_in_nat_pos">interval_in_nat_pos</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/interval_in_nat_pos/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.integers import interval_in_nat_pos

# %%
# %dependencies interval_in_nat_pos
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon interval_in_nat_pos</h3>
