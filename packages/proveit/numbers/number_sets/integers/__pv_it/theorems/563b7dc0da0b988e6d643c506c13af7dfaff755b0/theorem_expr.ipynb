# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nat_within_int">nat_within_int</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.integers import nat_within_int

# %%
# check that the built expression is the same as the stored expression
assert nat_within_int.expr == stored_expr
assert nat_within_int.expr._style_id == stored_expr._style_id
print("Passed sanity check: nat_within_int matches stored_expr")
# Out:
# Passed sanity check: nat_within_int matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nat_within_int.latex())
# Out:
# \vdash \mathbb{N} \subset \mathbb{Z}

# %%
# display the expression information
nat_within_int.expr_info()
# Out:
# 0. Natural proper_subset Integer
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (Natural, Integer)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Natural
#    core type: Literal
#    sub-expressions:
# 4. Integer
#    core type: Literal
#    sub-expressions:
