# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, n
from proveit.logic import Forall, InSet
from proveit.numbers import Interval, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], InSet(n, NaturalPos), domains = [Interval(a, b)])
# Out:
# expr: forall_{n in {a...b}} (n in NaturalPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \{a \dots b\}}~\left(n \in \mathbb{N}^+\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in {a...b}} (n in NaturalPos)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. n -> {n in NaturalPos if n in {a...b}.
#    core type: Lambda
#    parameter: 10
#    body: 3
# 3. {n in NaturalPos if n in {a...b}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. n in {a...b}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, {a...b})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. {a...b}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
