# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, n
from proveit.logic import Forall
from proveit.numbers import Greater, Integer, Interval, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], Forall([n], Greater(n, zero), domains = [Interval(a, b)]), domains = [Integer, Integer], condition = Greater(a, zero))
# Out:
# expr: forall_{a, b in Integer | a > 0} [forall_{n in {a...b}} (n > 0)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}~|~a > 0}~\left[\forall_{n \in \{a \dots b\}}~\left(n > 0\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Integer | a > 0} [forall_{n in {a...b}} (n > 0)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (a, b) -> {forall_{n in {a...b}} (n > 0) if a in Integer ,  b in Integer ,  a > 0.
#    core type: Lambda
#    parameters: 27\n   body: 2
# 2. {forall_{n in {a...b}} (n > 0) if a in Integer ,  b in Integer ,  a > 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in {a...b}} (n > 0)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (a in Integer) and (b in Integer) and (a > 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. n -> {n > 0 if n in {a...b}.
#    core type: Lambda
#    parameter: 24
#    body: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integer, b in Integer, a > 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {n > 0 if n in {a...b}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. a in Integer
#     core type: Operation
#     operator: 20
#     operands: 15
# 11. b in Integer
#     core type: Operation
#     operator: 20
#     operands: 16
# 12. a > 0
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. n > 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. n in {a...b}
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 28, 22
# 16. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 17. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 23
# 18. >
#     core type: Literal
#     sub-expressions:
# 19. (n, 0)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. {a...b}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (a, b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
