# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Integer, Interval

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([n], InSet(n, Integer), domains = [Interval(a, b)]), And(InSet(a, Integer), InSet(b, Integer))))
# Out:
# expr: (a, b) -> {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{n \in \{a \dots b\}}~\left(n \in \mathbb{Z}\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 22\n   body: 1
# 1. {forall_{n in {a...b}} (n in Integer) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in {a...b}} (n in Integer)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. n -> {n in Integer if n in {a...b}.
#    core type: Lambda
#    parameter: 19
#    body: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {n in Integer if n in {a...b}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. a in Integer
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. b in Integer
#     core type: Operation
#     operator: 16
#     operands: 14
# 11. n in Integer
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. n in {a...b}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 14. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 15. (n, Integer)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Integer
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. {a...b}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
