# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number_sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">integers</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#inNaturalIfNonNeg">inNaturalIfNonNeg</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import a, m, n, x, A, B
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.numbers import zero, num, Neg, NaturalPos, Integer, Greater, Natural, GreaterEq
from proveit.logic import NotInSet, SetOfAll, InSet, Implies, And
from proveit.logic.sets.unification._theorems_ import membershipUnfolding
from proveit.numbers.number_sets.natural_numbers._axioms_ import naturalsPosDef
from proveit.numbers.number_sets.integers._axioms_ import integersDef
theory = proveit.Theory() # the theorem's theory

# %%
# %proving inNaturalIfNonNeg

# %%
defaults.assumptions = inNaturalIfNonNeg.conditions

# %%
integersDef

# %%
intUnion = integersDef.expr.rhs

# %%
intUnion.operands

# %%
membershipUnfolding

# %%
spec1 = membershipUnfolding.instantiate({x:a, m:num(2), A:intUnion.operands}, assumptions = [InSet(m, NaturalPos), *defaults.assumptions])

# %%
aInInt = defaults.assumptions[0]

# %%
aElemUnion = Implies(And(aInInt, integersDef.expr),InSet(a,intUnion))

# %%
newAssumpt = [defaults.assumptions]+ [integersDef.expr]
