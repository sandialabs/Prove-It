# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number_sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">natural_numbers</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#non_zero_if_is_nat_pos">non_zero_if_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import a, b, n
from proveit.numbers import zero, one, Greater
from proveit.numbers.ordering._theorems_ import gtr_is_not_eq
from proveit.numbers.number_sets.natural_numbers._theorems_ import natural_pos_lower_bound
theory = proveit.Theory() # the theorem's theory

# %%
# %proving non_zero_if_is_nat_pos

# %%
defaults.assumptions = non_zero_if_is_nat_pos.conditions

# %%
natural_pos_lower_bound

# %%
natural_pos_lower_bound.instantiate({n:n})

# %%
Greater(one, zero).prove()

# %%
Greater(n, zero).prove()

# %%
gtr_is_not_eq

# %%
gtr_is_not_eq.instantiate({a:n, b:zero})

# %%
# %qed
