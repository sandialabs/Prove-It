# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.natural_numbers</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#boolean_natural_membership">boolean_natural_membership</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.natural_numbers import boolean_natural_membership

# %%
# %dependencies boolean_natural_membership
# Out:
# <h3>No theorems/conjectures depend upon boolean_natural_membership</h3>
