# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#zero_not_successor">zero_not_successor</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.natural_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.natural_numbers import zero_not_successor

# %%
# check that the built expression is the same as the stored expression
assert zero_not_successor.expr == stored_expr
assert zero_not_successor.expr._style_id == stored_expr._style_id
print("Passed sanity check: zero_not_successor matches stored_expr")
# Out:
# Passed sanity check: zero_not_successor matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(zero_not_successor.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left(\left(n + 1\right) \neq 0\right)

# %%
# display the expression information
zero_not_successor.expr_info()
# Out:
# 0. forall_{n in Natural} ((n + 1) != 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. n -> {(n + 1) != 0 if n in Natural.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {(n + 1) != 0 if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (n + 1) != 0
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. n in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. !=
#    core type: Literal
#    sub-expressions:
# 7. (n + 1, 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. n + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. Natural
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
# ...
