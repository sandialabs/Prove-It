# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.numbers.number_sets.real_numbers</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit import a, b, c, n, x
from proveit.logic import Forall, Iff, in_bool, InSet, NotEquals, NotInSet, ProperSubset
from proveit.numbers import (Add, Greater, GreaterEq, IntervalCC,
                            IntervalCO, IntervalOC, IntervalOO,
                            Less, LessEq, Mult, Neg, sqrt)
from proveit.numbers import (zero, one, two, e, pi, Integer, Natural,
                            NaturalPos, Rational, Real, RealPos,
                            RealNeg, RealNonNeg)

# %%
# %begin theorems
# Out:
# Defining theorems for theory 'proveit.numbers.number_sets.real_numbers'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
real_pos_is_real = ProperSubset(RealPos, Real)
# Out:
# real_pos_is_real: RealPos proper_subset Real

# %%
real_neg_is_real = ProperSubset(RealNeg, Real)
# Out:
# real_neg_is_real: RealNeg proper_subset Real

# %%
real_non_neg_is_real = ProperSubset(RealNonNeg, Real)
# Out:
# real_non_neg_is_real: RealNonNeg proper_subset Real

# %%
int_is_real = ProperSubset(Integer, Real)
# Out:
# int_is_real: Integer proper_subset Real

# %%
rational_is_real = ProperSubset(Rational, Real)
# Out:
# rational_is_real: Rational proper_subset Real

# %%
nat_is_real = ProperSubset(Natural, Real)
# Out:
# nat_is_real: Natural proper_subset Real

# %%
nat_pos_is_real = ProperSubset(NaturalPos, Real)
# Out:
# nat_pos_is_real: NaturalPos proper_subset Real

# %%
nat_pos_is_real_pos = ProperSubset(NaturalPos, RealPos)
# Out:
# nat_pos_is_real_pos: NaturalPos proper_subset RealPos

# %%
nat_is_real_non_neg = ProperSubset(Natural, RealNonNeg)
# Out:
# nat_is_real_non_neg: Natural proper_subset RealNonNeg

# %%
nat_pos_is_real_non_neg = ProperSubset(NaturalPos, RealNonNeg)
# Out:
# nat_pos_is_real_non_neg: NaturalPos proper_subset RealNonNeg

# %%
real_pos_is_real_non_neg = ProperSubset(RealPos, RealNonNeg)
# Out:
# real_pos_is_real_non_neg: RealPos proper_subset RealNonNeg

# %%
in_real_pos_iff_positive = Forall(a, Iff(InSet(a, RealPos), Greater(a, zero)), domain=Real)
# Out:
# in_real_pos_iff_positive: forall_{a in Real} ((a in RealPos) <=> (a > 0))

# %%
in_real_neg_iff_negative = Forall(a, Iff(InSet(a, RealNeg), Less(a, zero)), domain=Real)
# Out:
# in_real_neg_iff_negative: forall_{a in Real} ((a in RealNeg) <=> (a < 0))

# %%
neg_is_real_neg_if_pos_is_real_pos = Forall(
    a,
    InSet(Neg(a), RealNeg),
    domain=RealPos)
# Out:
# neg_is_real_neg_if_pos_is_real_pos: forall_{a in RealPos} ((-a) in RealNeg)

# %%
in_real_non_neg_iff_non_negative = Forall(
    a,
    Iff(InSet(a, RealNonNeg), GreaterEq(a, zero)),
    domain=Real)
# Out:
# in_real_non_neg_iff_non_negative: forall_{a in Real} ((a in RealNonNeg) <=> (a >= 0))

# %%
in_real_non_neg_if_greater_eq_zero = Forall(
    a,
    InSet(a, RealNonNeg),
    domain=Real,
    conditions=[GreaterEq(a, zero)])
# Out:
# in_real_non_neg_if_greater_eq_zero: forall_{a in Real | a >= 0} (a in RealNonNeg)

# %% [markdown]
# ***Non-Zero Theorems***

# %%
positive_implies_not_zero = Forall(
    a,
    NotEquals(a, zero),
    domain=Real,
    conditions=[Greater(a, zero)])
# Out:
# positive_implies_not_zero: forall_{a in Real | a > 0} (a != 0)

# %%
negative_implies_not_zero = Forall(
    a, NotEquals(a, zero),
    domain=Real,
    conditions=[Less(a, zero)])
# Out:
# negative_implies_not_zero: forall_{a in Real | a < 0} (a != 0)

# %% [markdown]
# ***Elements of Real Intervals are Real Numbers***

# %%
all_is__interval_oo_is__real = Forall(
    (a, b),
    Forall(x,
           InSet(x, Real),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# all_is__interval_oo_is__real: forall_{a, b in Real} [forall_{x in (a,b)} (x in Real)]

# %%
all_is__interval_co_is__real = Forall(
    (a, b),
    Forall(x,
           InSet(x, Real),
           domain=IntervalCO(a, b)),
    domain=Real)
# Out:
# all_is__interval_co_is__real: forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]

# %%
all_is__interval_oc_is__real = Forall(
    (a, b),
    Forall(x,
           InSet(x, Real),
           domain=IntervalOC(a, b)),
    domain=Real)
# Out:
# all_is__interval_oc_is__real: forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]

# %%
all_is__interval_cc_is__real = Forall(
    (a, b),
    Forall(x,
           InSet(x, Real),
           domain=IntervalCC(a, b)),
    domain=Real)
# Out:
# all_is__interval_cc_is__real: forall_{a, b in Real} [forall_{x in [a,b]} (x in Real)]

# %%
real_non_neg_membership_is_bool = Forall(x, in_bool(InSet(x, RealNonNeg)))
# Out:
# real_non_neg_membership_is_bool: forall_{x} ((x in RealNonNeg) in BOOLEAN)

# %% [markdown]
# ***Real Intervals are Subsets of the Real number set***

# %%
interval_o_o_is_subset_of__real = Forall(
    (a, b),
    ProperSubset(IntervalOO(a, b), Real),
    domain=Real)
# Out:
# interval_o_o_is_subset_of__real: forall_{a, b in Real} ((a,b) proper_subset Real)

# %%
interval_o_c_is_subset_of__real = Forall(
    (a, b),
    ProperSubset(IntervalOC(a, b), Real),
    domain=Real)
# Out:
# interval_o_c_is_subset_of__real: forall_{a, b in Real} ((a,b] proper_subset Real)

# %%
interval_c_o_is_subset_of__real = Forall(
    (a, b),
    ProperSubset(IntervalCO(a, b), Real),
    domain=Real)
# Out:
# interval_c_o_is_subset_of__real: forall_{a, b in Real} ([a,b) proper_subset Real)

# %%
interval_c_c_is_subset_of__real = Forall(
    (a, b),
    ProperSubset(IntervalCC(a, b), Real),
    domain=Real)
# Out:
# interval_c_c_is_subset_of__real: forall_{a, b in Real} ([a,b] proper_subset Real)

# %% [markdown]
# ***Positive Real Intervals are Subsets of the Positive Real number set***

# %%
real_pos_interval_o_o_is_subset_of__real_pos = Forall(
    (a, b),
    ProperSubset(IntervalOO(a, b), RealPos),
    domain=RealPos)
# Out:
# real_pos_interval_o_o_is_subset_of__real_pos: forall_{a, b in RealPos} ((a,b) proper_subset RealPos)

# %%
real_pos_interval_o_c_is_subset_of__real_pos = Forall(
    (a, b),
    ProperSubset(IntervalOC(a, b), RealPos),
    domain=RealPos)
# Out:
# real_pos_interval_o_c_is_subset_of__real_pos: forall_{a, b in RealPos} ((a,b] proper_subset RealPos)

# %%
real_pos_interval_c_o_is_subset_of__real_pos = Forall(
    (a, b),
    ProperSubset(IntervalCO(a, b), RealPos),
    domain=RealPos)
# Out:
# real_pos_interval_c_o_is_subset_of__real_pos: forall_{a, b in RealPos} ([a,b) proper_subset RealPos)

# %%
real_pos_interval_c_c_is_subset_of__real_pos = Forall(
    (a, b),
    ProperSubset(IntervalCC(a, b), RealPos),
    domain=RealPos)
# Out:
# real_pos_interval_c_c_is_subset_of__real_pos: forall_{a, b in RealPos} ([a,b] proper_subset RealPos)

# %% [markdown]
# ***Non-Negative Real Intervals are Subsets of the Non-Negative Real number set***

# %%
real_non_neg_interval_o_o_is_subset_of_real_non_neg = Forall(
    (a, b),
    ProperSubset(IntervalOO(a, b), RealNonNeg),
    domain=RealNonNeg)
# Out:
# real_non_neg_interval_o_o_is_subset_of_real_non_neg: forall_{a, b in RealNonNeg} ((a,b) proper_subset RealNonNeg)

# %%
real_non_neg_interval_o_c_is_subset_of_real_non_neg = Forall(
    (a, b),
    ProperSubset(IntervalOC(a, b), RealNonNeg),
    domain=RealNonNeg)
# Out:
# real_non_neg_interval_o_c_is_subset_of_real_non_neg: forall_{a, b in RealNonNeg} ((a,b] proper_subset RealNonNeg)

# %%
real_non_neg_interval_c_o_is_subset_of_real_non_neg = Forall(
    (a, b),
    ProperSubset(IntervalCO(a, b), RealNonNeg),
    domain=RealNonNeg)
# Out:
# real_non_neg_interval_c_o_is_subset_of_real_non_neg: forall_{a, b in RealNonNeg} ([a,b) proper_subset RealNonNeg)

# %%
real_non_neg_interval_c_c_is_subset_of_real_non_neg = Forall(
    (a, b),
    ProperSubset(IntervalCC(a, b), RealNonNeg),
    domain=RealNonNeg)
# Out:
# real_non_neg_interval_c_c_is_subset_of_real_non_neg: forall_{a, b in RealNonNeg} ([a,b] proper_subset RealNonNeg)

# %% [markdown]
# ***Upper and Lower Bounds on Real Intervals***

# %%
interval_o_o_lower_bound = Forall(
    (a, b),
    Forall(x,
           Less(a, x),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# interval_o_o_lower_bound: forall_{a, b in Real} [forall_{x in (a,b)} (a < x)]

# %%
interval_o_o_upper_bound = Forall(
    (a, b),
    Forall(x,
           Less(x, b),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# interval_o_o_upper_bound: forall_{a, b in Real} [forall_{x in (a,b)} (x < b)]

# %%
interval_c_o_lower_bound = Forall(
    (a, b),
    Forall(x,
           LessEq(a, x),
           domain=IntervalCO(a, b)),
    domain=Real)
# Out:
# interval_c_o_lower_bound: forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]

# %%
interval_c_o_upper_bound = Forall(
    (a, b),
    Forall(x,
           Less(x, b),
           domain=IntervalCO(a, b)),
    domain=Real)
# Out:
# interval_c_o_upper_bound: forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]

# %%
interval_o_c_lower_bound = Forall(
    (a, b),
    Forall(x,
           Less(a, x),
           domain=IntervalOC(a, b)),
    domain=Real)
# Out:
# interval_o_c_lower_bound: forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]

# %%
interval_o_c_upper_bound = Forall(
    (a, b),
    Forall(x,
           LessEq(x, b),
           domain=IntervalOC(a, b)),
    domain=Real)
# Out:
# interval_o_c_upper_bound: forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]

# %%
interval_c_c_lower_bound = Forall(
    (a, b),
    Forall(x,
           LessEq(a, x),
           domain=IntervalCC(a, b)),
    domain=Real)
# Out:
# interval_c_c_lower_bound: forall_{a, b in Real} [forall_{x in [a,b]} (a <= x)]

# %%
interval_c_c_upper_bound = Forall(
    (a, b),
    Forall(x,
           LessEq(x, b),
           domain=IntervalCC(a, b)),
    domain=Real)
# Out:
# interval_c_c_upper_bound: forall_{a, b in Real} [forall_{x in [a,b]} (x <= b)]

# %% [markdown]
# ***Translating Boundedness to Interval Membership***

# %%
in__interval_o_o = Forall(
    (a, b, x),
    InSet(x, IntervalOO(a, b)),
    domain=Real,
    conditions=[Less(a, x), Less(x, b)])
# Out:
# in__interval_o_o: forall_{a, b, x in Real | a < x, x < b} (x in (a,b))

# %%
in__interval_c_o = Forall(
    (a, b, x),
    InSet(x, IntervalCO(a, b)),
    domain=Real,
    conditions=[LessEq(a, x), Less(x, b)])
# Out:
# in__interval_c_o: forall_{a, b, x in Real | a <= x, x < b} (x in [a,b))

# %%
in__interval_o_c = Forall(
    (a, b, x),
    InSet(x, IntervalOC(a, b)),
    domain=Real,
    conditions=[Less(a, x), LessEq(x, b)])
# Out:
# in__interval_o_c: forall_{a, b, x in Real | a < x, x <= b} (x in (a,b])

# %%
in__interval_c_c = Forall(
    (a, b, x),
    InSet(x, IntervalCC(a, b)),
    domain=Real,
    conditions=[LessEq(a, x), LessEq(x, b)])
# Out:
# in__interval_c_c: forall_{a, b, x in Real | a <= x, x <= b} (x in [a,b])

# %% [markdown]
# ***Scaling Elements of Intervals To Scaled Intervals***

# %%
rescale_in__interval_o_o = Forall(
    (a, b, c),
    Forall(x,
           InSet(Mult(c, x), IntervalOO(Mult(c, a), Mult(c, b))),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# rescale_in__interval_o_o: forall_{a, b, c in Real} [forall_{x in (a,b)} ((c * x) in (c * a,c * b))]

# %%
rescale_in__interval_o_c = Forall(
    (a, b, c),
    Forall(x,
           InSet(Mult(c, x),
                 IntervalOC(Mult(c, a), Mult(c, b))),
           domain=IntervalOC(a, b)),
    domain=Real)
# Out:
# rescale_in__interval_o_c: forall_{a, b, c in Real} [forall_{x in (a,b]} ((c * x) in (c * a,c * b])]

# %%
rescale_in__interval_c_o = Forall(
    (a, b, c),
    Forall(x,
           InSet(Mult(c, x), IntervalCO(Mult(c, a), Mult(c, b))),
           domain=IntervalCO(a, b)),
    domain=Real)
# Out:
# rescale_in__interval_c_o: forall_{a, b, c in Real} [forall_{x in [a,b)} ((c * x) in [c * a,c * b))]

# %%
rescale_in__interval_c_c = Forall(
    (a, b, c),
    Forall(x,
           InSet(Mult(c, x), IntervalCC(Mult(c, a), Mult(c, b))),
           domain=IntervalCC(a, b)),
    domain=Real)
# Out:
# rescale_in__interval_c_c: forall_{a, b, c in Real} [forall_{x in [a,b]} ((c * x) in [c * a,c * b])]

# %% [markdown]
# ***Interval Relaxation Theorems***

# %%
relax__interval_c_o = Forall(
    (a, b),
    Forall(x,
           InSet(x, IntervalCC(a, b)),
           domain=IntervalCO(a, b)),
    domain=Real)
# Out:
# relax__interval_c_o: forall_{a, b in Real} [forall_{x in [a,b)} (x in [a,b])]

# %%
relax__interval_o_c = Forall(
    (a, b),
    Forall(x,
           InSet(x, IntervalCC(a, b)),
           domain=IntervalOC(a, b)),
    domain=Real)
# Out:
# relax__interval_o_c: forall_{a, b in Real} [forall_{x in (a,b]} (x in [a,b])]

# %%
relax__interval_o_o_left = Forall(
    (a, b),
    Forall(x,
           InSet(x, IntervalCO(a, b)),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# relax__interval_o_o_left: forall_{a, b in Real} [forall_{x in (a,b)} (x in [a,b))]

# %%
relax__interval_o_o_right = Forall(
    (a, b),
    Forall(x,
           InSet(x, IntervalOC(a, b)),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# relax__interval_o_o_right: forall_{a, b in Real} [forall_{x in (a,b)} (x in (a,b])]

# %%
relax__interval_o_o_left_right = Forall(
    (a, b),
    Forall(x,
           InSet(x, IntervalCC(a, b)),
           domain=IntervalOO(a, b)),
    domain=Real)
# Out:
# relax__interval_o_o_left_right: forall_{a, b in Real} [forall_{x in (a,b)} (x in [a,b])]

# %% [markdown]
# ***Misc Theorems About the Real number set***

# %%
not_int_if_between_successive_int = Forall(
    n,
    Forall(x,
           NotInSet(x, Integer),
           domain=IntervalOO(n, Add(n, one))),
    domain=Integer)
# Out:
# not_int_if_between_successive_int: forall_{n in Integer} [forall_{x in (n,n + 1)} (x not-in Integer)]

# %%
e_is__real_pos = InSet(e, RealPos)
# Out:
# e_is__real_pos: e in RealPos

# %%
e_not_zero = NotEquals(e, zero)
# Out:
# e_not_zero: e != 0

# %%
pi_is__real_pos = InSet(pi, RealPos)
# Out:
# pi_is__real_pos: pi in RealPos

# %%
pi_not_zero = NotEquals(pi, zero)
# Out:
# pi_not_zero: pi != 0

# %% [markdown]
# ***A set of in_bool theorems, which are accessed by the respective NumberSets to implement their ``deduce_membership_in_bool()`` methods, covering the ``RealSet``, ``RealPosSet``, and ``RealNegSet`` NumberSet classes (defined in proveit.numbers.number_sets.real_numbers/reals.py):***

# %%
real_membership_is_bool = Forall(x, in_bool(InSet(x, Real)))
# Out:
# real_membership_is_bool: forall_{x} ((x in Real) in BOOLEAN)

# %%
real_pos_membership_is_bool = Forall(x, in_bool(InSet(x, RealPos)))
# Out:
# real_pos_membership_is_bool: forall_{x} ((x in RealPos) in BOOLEAN)

# %%
real_neg_membership_is_bool = Forall(x, in_bool(InSet(x, RealNeg)))
# Out:
# real_neg_membership_is_bool: forall_{x} ((x in RealNeg) in BOOLEAN)

# %%
# %end theorems
# Out:
# Theorems may be imported from autogenerated _theorems_.py
