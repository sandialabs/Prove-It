# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number_sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">real_numbers</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#real_pos_interval_c_o_is_subset_of_RealPos">real_pos_interval_c_o_is_subset_of_RealPos</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving real_pos_interval_c_o_is_subset_of_RealPos
