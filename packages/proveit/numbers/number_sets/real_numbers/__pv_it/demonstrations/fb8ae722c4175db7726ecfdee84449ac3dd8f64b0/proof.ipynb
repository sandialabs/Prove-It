# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.numbers.number_sets.real_numbers.demonstrations.fb8ae722c4175db7726ecfdee84449ac3dd8f64b0_step0">0</a></td><td>assumption</td><td></td><td><span style="font-size:20px;"><a class="ProveItLink" href="../7dc775a68468efc89a11839e3271282f2e6e4d7c0/expr.ipynb"><img src="../7dc775a68468efc89a11839e3271282f2e6e4d7c0/expr.png" style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../7dc775a68468efc89a11839e3271282f2e6e4d7c0/expr.ipynb"><img src="../7dc775a68468efc89a11839e3271282f2e6e4d7c0/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# </table>
