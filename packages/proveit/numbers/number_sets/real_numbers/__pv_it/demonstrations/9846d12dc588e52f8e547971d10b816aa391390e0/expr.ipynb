# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Implies, InSet
from proveit.numbers import Less, Neg, RealNeg, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(two)
expr = Implies(InSet(sub_expr1, RealNeg), Less(sub_expr1, zero))
# Out:
# expr: ((-2) in RealNeg) => ((-2) < 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(-2\right) \in \mathbb{R}^-\right) \Rightarrow \left(\left(-2\right) < 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((-2) in RealNeg) => ((-2) < 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((-2) in RealNeg, (-2) < 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (-2) in RealNeg
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (-2) < 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (-2, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. (-2, 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. RealNeg
#    core type: Literal
#    sub-expressions:
# 10. -2
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
