# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.IntervalCO.html">IntervalCO</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.numbers import IntervalCO, Mult, one, three

# %%
# build up the expression from sub-expressions
expr = IntervalCO(Mult(three, one), Mult(three, three))
# Out:
# expr: [3 * 1,3 * 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[3 \cdot 1,3 \cdot 3\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [3 * 1,3 * 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. IntervalCO
#    core type: Literal
#    sub-expressions:
# 2. (3 * 1, 3 * 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 3 * 1
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. 3 * 3
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (3, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (3, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 9
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
