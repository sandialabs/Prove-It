# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, x
from proveit.logic import InSet
from proveit.numbers import Less, LesserSequence, Real

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Real), LesserSequence([Less._operator_, Less._operator_], [a, x, b]))
# Out:
# expr: (x in Real, a < x < b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{R}, a < x < b\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x in Real, a < x < b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in Real
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. a < x < b
#    core type: Operation
#    operators: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 5. (<, <)
#    core type: ExprTuple
#    sub-expressions: 8, 8
# 6. (a, x, b)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. Real
#    core type: Literal
#    sub-expressions:
# 8. <
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
