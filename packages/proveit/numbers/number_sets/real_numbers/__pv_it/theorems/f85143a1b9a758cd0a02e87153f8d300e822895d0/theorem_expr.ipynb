# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pi_not_zero">pi_not_zero</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.NotEquals.html">NotEquals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import pi_not_zero

# %%
# check that the built expression is the same as the stored expression
assert pi_not_zero.expr == stored_expr
assert pi_not_zero.expr._style_id == stored_expr._style_id
print("Passed sanity check: pi_not_zero matches stored_expr")
# Out:
# Passed sanity check: pi_not_zero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pi_not_zero.latex())
# Out:
# \vdash \pi \neq 0

# %%
# display the expression information
pi_not_zero.expr_info()
# Out:
# 0. pi != 0
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. !=
#    core type: Literal
#    sub-expressions:
# 2. (pi, 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. pi
#    core type: Literal
#    sub-expressions:
# 4. 0
#    core type: Literal
#    sub-expressions:
