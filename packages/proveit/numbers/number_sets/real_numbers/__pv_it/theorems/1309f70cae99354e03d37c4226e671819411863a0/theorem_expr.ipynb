# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unique_int_in_interval">unique_int_in_interval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import unique_int_in_interval

# %%
# check that the built expression is the same as the stored expression
assert unique_int_in_interval.expr == stored_expr
assert unique_int_in_interval.expr._style_id == stored_expr._style_id
print("Passed sanity check: unique_int_in_interval matches stored_expr")
# Out:
# Passed sanity check: unique_int_in_interval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a \in \mathbb{R}^+, b \in \mathbb{R}^+, x \in \mathbb{Z}, y \in \mathbb{Z}~|~a \leq 1, b \leq 1}~\left(\left(y \in \left(x - a,x + b\right)\right) \Rightarrow \left(y = x\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a in RealPos, b in RealPos, x in Integer, y in Integer | a <= 1, b <= 1} ((y in (x - a,x + b)) => (y = x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, x, y) -> {(y in (x - a,x + b)) => (y = x) if a in RealPos ,  b in RealPos ,  x in Integer ,  y in Integer ,  a <= 1 ,  b <= 1.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, x, y) -> {(y in (x - a,x + b)) => (y = x) if a in RealPos ,  b in RealPos ,  x in Integer ,  y in Integer ,  a <= 1 ,  b <= 1.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, x, y)
#    core type: ExprTuple
#    sub-expressions: 48, 45, 44, 33
# 5. {(y in (x - a,x + b)) => (y = x) if a in RealPos ,  b in RealPos ,  x in Integer ,  y in Integer ,  a <= 1 ,  b <= 1.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (y in (x - a,x + b)) => (y = x)
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
