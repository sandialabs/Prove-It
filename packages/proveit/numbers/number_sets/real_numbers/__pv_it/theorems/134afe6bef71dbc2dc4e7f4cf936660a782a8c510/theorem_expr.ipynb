# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#rescale_interval_cc_membership">rescale_interval_cc_membership</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import rescale_interval_cc_membership

# %%
# check that the built expression is the same as the stored expression
assert rescale_interval_cc_membership.expr == stored_expr
assert rescale_interval_cc_membership.expr._style_id == stored_expr._style_id
print("Passed sanity check: rescale_interval_cc_membership matches stored_expr")
# Out:
# Passed sanity check: rescale_interval_cc_membership matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rescale_interval_cc_membership.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{R}}~\left[\forall_{x \in \left[a,b\right]}~\left(\left(c \cdot x\right) \in \left[c \cdot a,c \cdot b\right]\right)\right]

# %%
# display the expression information
rescale_interval_cc_membership.expr_info()
# Out:
# 0. forall_{a, b, c in Real} [forall_{x in [a,b]} ((c * x) in [c * a,c * b])]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (a, b, c) -> {forall_{x in [a,b]} ((c * x) in [c * a,c * b]) if a in Real ,  b in Real ,  c in Real.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 36, 38, 37
# 3. {forall_{x in [a,b]} ((c * x) in [c * a,c * b]) if a in Real ,  b in Real ,  c in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in [a,b]} ((c * x) in [c * a,c * b])
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (a in Real) and (b in Real) and (c in Real)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. x -> {(c * x) in [c * a,c * b] if x in [a,b].
#    core type: Lambda
#    parameter: 30
#    body: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
