# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_non_neg_within_real">real_non_neg_within_real</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import real_non_neg_within_real

# %%
# check that the built expression is the same as the stored expression
assert real_non_neg_within_real.expr == stored_expr
assert real_non_neg_within_real.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_non_neg_within_real matches stored_expr")
# Out:
# Passed sanity check: real_non_neg_within_real matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(real_non_neg_within_real.latex())
# Out:
# \vdash \mathbb{R}^{\ge 0} \subset \mathbb{R}

# %%
# display the expression information
real_non_neg_within_real.expr_info()
# Out:
# 0. RealNonNeg proper_subset Real
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (RealNonNeg, Real)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RealNonNeg
#    core type: Literal
#    sub-expressions:
# 4. Real
#    core type: Literal
#    sub-expressions:
