# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#not_int_if_not_int_in_interval_gen">not_int_if_not_int_in_interval_gen</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import not_int_if_not_int_in_interval_gen

# %%
# check that the built expression is the same as the stored expression
assert not_int_if_not_int_in_interval_gen.expr == stored_expr
assert not_int_if_not_int_in_interval_gen.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_int_if_not_int_in_interval_gen matches stored_expr")
# Out:
# Passed sanity check: not_int_if_not_int_in_interval_gen matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}}~\left[\forall_{x \in \left(a,b\right)~|~x \notin \{a + 1~\ldotp \ldotp~b - 1\}}~\left(x \notin \mathbb{Z}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b in Integer} [forall_{x in (a,b) | x not-in {a + 1 .. b - 1}} (x not-in Integer)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((a, b) -> {forall_{x in (a,b) | x not-in {a + 1 .. b - 1}} (x not-in Integer) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> {forall_{x in (a,b) | x not-in {a + 1 .. b - 1}} (x not-in Integer) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 32\n   body: 3
# 3. {forall_{x in (a,b) | x not-in {a + 1 .. b - 1}} (x not-in Integer) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in (a,b) | x not-in {a + 1 .. b - 1}} (x not-in Integer)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# ...
