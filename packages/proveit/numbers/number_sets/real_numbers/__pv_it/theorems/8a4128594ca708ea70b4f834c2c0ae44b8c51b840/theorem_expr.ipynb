# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_non_neg_interval_o_c_is_subset_of_real_non_neg">real_non_neg_interval_o_c_is_subset_of_real_non_neg</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import real_non_neg_interval_o_c_is_subset_of_real_non_neg

# %%
# check that the built expression is the same as the stored expression
assert real_non_neg_interval_o_c_is_subset_of_real_non_neg.expr == stored_expr
assert real_non_neg_interval_o_c_is_subset_of_real_non_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_non_neg_interval_o_c_is_subset_of_real_non_neg matches stored_expr")
# Out:
# Passed sanity check: real_non_neg_interval_o_c_is_subset_of_real_non_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(real_non_neg_interval_o_c_is_subset_of_real_non_neg.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{R}^{\ge 0}}~\left(\left(a,b\right] \subset \mathbb{R}^{\ge 0}\right)

# %%
# display the expression information
real_non_neg_interval_o_c_is_subset_of_real_non_neg.expr_info()
# Out:
# 0. forall_{a, b in RealNonNeg} ((a,b] proper_subset RealNonNeg)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a,b] proper_subset RealNonNeg if a in RealNonNeg ,  b in RealNonNeg.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a,b] proper_subset RealNonNeg if a in RealNonNeg ,  b in RealNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a,b] proper_subset RealNonNeg
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in RealNonNeg) and (b in RealNonNeg)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. proper_subset
#    core type: Literal
#    sub-expressions:
# 7. ((a,b], RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in RealNonNeg, b in RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a,b]
#     core type: Operation
# ...
