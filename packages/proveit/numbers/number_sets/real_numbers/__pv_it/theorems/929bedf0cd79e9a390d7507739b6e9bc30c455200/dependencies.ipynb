# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#rational_within_real">rational_within_real</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/rational_within_real/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.real_numbers import rational_within_real

# %%
# %dependencies rational_within_real
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on rational_within_real</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../exponentiation/_theory_nbs_/proofs/sqrt2_is_not_rational/thm_proof.ipynb">proveit.numbers.exponentiation.sqrt2_is_not_rational</a></dt><dd><a class="ProveItLink" href="../../../../../exponentiation/__pv_it/theorems/7fae0196da015b8256d13b37a10b8319c493434a0/expr.ipynb"><img src="../../../../../exponentiation/__pv_it/theorems/7fae0196da015b8256d13b37a10b8319c493434a0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
