# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#real_pos_interval_o_o_is_subset_of_RealPos">real_pos_interval_o_o_is_subset_of_RealPos</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/real_pos_interval_o_o_is_subset_of_RealPos/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.real_numbers import real_pos_interval_o_o_is_subset_of_RealPos

# %%
# %dependencies real_pos_interval_o_o_is_subset_of_RealPos
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon real_pos_interval_o_o_is_subset_of_RealPos</h3>
