# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.numbers.number_sets.real_numbers.theorems.d5eecdc2e8b467573cc0145f18d9c9ee21ab0da10_step0">0</a></td><td>theorem</td><td></td><td><span style="font-size:20px;"> <a class="ProveItLink" href="../../../_theory_nbs_/proofs/in_real_non_neg_if_greater_eq_zero/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../72dc8379fd6fb029cc662b0da332d678fcdfb8cc0/expr.ipynb"><img src="../72dc8379fd6fb029cc662b0da332d678fcdfb8cc0/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# <tr><td>&nbsp;</td><td colspan=4 style-"text-align:left"><a class="ProveItLink" href="../../../_theory_nbs_/proofs/in_real_non_neg_if_greater_eq_zero/thm_proof.ipynb">proveit.numbers.number_sets.real_numbers.in_real_non_neg_if_greater_eq_zero</a></td></tr></table>
