# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, Forall, InSet
from proveit.numbers import IntervalCO, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], LessEq(a, x), domains = [IntervalCO(a, b)]), And(InSet(a, Real), InSet(b, Real)))
# Out:
# expr: {forall_{x in [a,b)} (a <= x) if a in Real ,  b in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \left[a,b\right)}~\left(a \leq x\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in [a,b)} (a <= x) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in [a,b)} (a <= x)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {a <= x if x in [a,b).
#    core type: Lambda
#    parameter: 19
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {a <= x if x in [a,b).
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. a in Real
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. b in Real
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. a <= x
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x in [a,b)
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 13. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. (a, x)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x, [a,b))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. [a,b)
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. IntervalCO
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
