# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#in_IntervalOO">in_IntervalOO</a> of type <a href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.logic import Forall, InSet
from proveit.numbers import IntervalOO, Less, Real

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, x], InSet(x, IntervalOO(a, b)), domains = [Real, Real, Real], conditions = [Less(a, x), Less(x, b)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: in_IntervalOO matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
# display the expression information
expr.expr_info()
