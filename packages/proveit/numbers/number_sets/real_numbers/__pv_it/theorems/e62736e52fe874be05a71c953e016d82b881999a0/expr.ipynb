# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import ProperSubset
from proveit.numbers import IntervalOO, RealNonNeg

# %%
# build up the expression from sub-expressions
expr = ProperSubset(IntervalOO(a, b), RealNonNeg)
# Out:
# expr: (a,b) proper_subset RealNonNeg

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a,b\right) \subset \mathbb{R}^{\ge 0}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a,b) proper_subset RealNonNeg
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. ((a,b), RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a,b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. RealNonNeg
#    core type: Literal
#    sub-expressions:
# 5. IntervalOO
#    core type: Literal
#    sub-expressions:
# 6. (a, b)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
