# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, x
from proveit.logic import And, Forall, InSet
from proveit.numbers import IntervalOO, Mult, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], InSet(Mult(c, x), IntervalOO(Mult(c, a), Mult(c, b))), domains = [IntervalOO(a, b)]), And(InSet(a, Real), InSet(b, Real), InSet(c, Real)))
# Out:
# expr: {forall_{x in (a,b)} ((c * x) in (c * a,c * b)) if a in Real ,  b in Real ,  c in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \left(a,b\right)}~\left(\left(c \cdot x\right) \in \left(c \cdot a,c \cdot b\right)\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in (a,b)} ((c * x) in (c * a,c * b)) if a in Real ,  b in Real ,  c in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in (a,b)} ((c * x) in (c * a,c * b))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Real) and (b in Real) and (c in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {(c * x) in (c * a,c * b) if x in (a,b).
#    core type: Lambda
#    parameter: 27
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real, c in Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. {(c * x) in (c * a,c * b) if x in (a,b).
#    core type: Conditional
#    value: 11
#    condition: 12
# 8. a in Real
#    core type: Operation
#    operator: 17
#    operands: 13
# 9. b in Real
#    core type: Operation
#    operator: 17
#    operands: 14
# 10. c in Real
#     core type: Operation
# ...
