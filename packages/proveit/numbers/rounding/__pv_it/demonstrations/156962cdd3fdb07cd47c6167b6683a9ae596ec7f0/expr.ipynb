# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x, y
from proveit.numbers import Add, Mult, Round, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(x, y)
expr = ExprTuple(Round(Add(one, sub_expr1, two)), Add(Round(sub_expr1), three))
# Out:
# expr: (round(1 + (x * y) + 2), round(x * y) + 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(round(1 + \left(x \cdot y\right) + 2), round(x \cdot y) + 3\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (round(1 + (x * y) + 2), round(x * y) + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. round(1 + (x * y) + 2)
#    core type: Operation
#    operator: 11
#    operand: 3
# 2. round(x * y) + 3
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. 1 + (x * y) + 2
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (round(x * y), 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (1, x * y, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 12, 10
# 7. round(x * y)
#    core type: Operation
#    operator: 11
#    operand: 12
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. round
#     core type: Literal
#     sub-expressions:
# 12. x * y
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (x, y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
