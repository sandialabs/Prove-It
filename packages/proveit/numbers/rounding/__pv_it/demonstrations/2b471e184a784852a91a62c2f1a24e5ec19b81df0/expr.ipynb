# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Equals
from proveit.numbers import Add, Ceil, Neg, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(y)
expr = Equals(Ceil(Add(x, sub_expr1, two).with_subtraction_at()), Add(Ceil(x), Add(sub_expr1, two).with_subtraction_at()))
# Out:
# expr: ceil(x + (-y) + 2) = (ceil(x) + ((-y) + 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lceil x + \left(-y\right) + 2\rceil = \left(\lceil x\rceil + \left(\left(-y\right) + 2\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ceil(x + (-y) + 2) = (ceil(x) + ((-y) + 2))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (ceil(x + (-y) + 2), ceil(x) + ((-y) + 2))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ceil(x + (-y) + 2)
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. ceil(x) + ((-y) + 2)
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. x + (-y) + 2
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (ceil(x), (-y) + 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x, -y, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 14, 15
# 8. ceil(x)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (-y) + 2
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. ceil
#     core type: Literal
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (-y, 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. -y
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. y
#     core type: Variable
#     sub-expressions:
