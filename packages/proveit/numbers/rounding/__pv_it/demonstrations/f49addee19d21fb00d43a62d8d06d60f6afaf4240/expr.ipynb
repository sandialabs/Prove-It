# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, y
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Neg, one, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([Neg(y), two]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: |(-y, 2)| = |(1, ..k.., 2)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(-y, 2\right)| = |\left(1, \ldots, 2\right)|

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(-y, 2)| = |(1, ..k.., 2)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(-y, 2)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(-y, 2)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((-y, 2))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (-y, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 16
# 9. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. -y
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. 1, ..k.., 2
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
