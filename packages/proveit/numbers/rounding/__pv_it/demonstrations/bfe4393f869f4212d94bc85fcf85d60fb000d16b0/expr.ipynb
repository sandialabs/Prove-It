# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Equals
from proveit.numbers import Add, Ceil, Neg, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(y)
expr = Equals(Ceil(Add(Add(x, sub_expr1), two)), Add(Ceil(x), Add(sub_expr1, two).with_subtraction_at()))
# Out:
# expr: ceil((x - y) + 2) = (ceil(x) + ((-y) + 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lceil \left(x - y\right) + 2\rceil = \left(\lceil x\rceil + \left(\left(-y\right) + 2\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ceil((x - y) + 2) = (ceil(x) + ((-y) + 2))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (ceil((x - y) + 2), ceil(x) + ((-y) + 2))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ceil((x - y) + 2)
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. ceil(x) + ((-y) + 2)
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. (x - y) + 2
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (ceil(x), (-y) + 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x - y, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 15
# 8. ceil(x)
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. (-y) + 2
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. x - y
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. ceil
#     core type: Literal
#     sub-expressions:
# 12. (-y, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. -y
#     core type: Operation
#     operator: 18
#     operand: 19
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
