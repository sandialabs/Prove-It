# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Equals
from proveit.numbers import Add, Round, one, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Round(Add(x, y, one, two)), Add(Round(Add(x, y)), three))
# Out:
# expr: round(x + y + 1 + 2) = (round(x + y) + 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# round(x + y + 1 + 2) = \left(round(x + y) + 3\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. round(x + y + 1 + 2) = (round(x + y) + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (round(x + y + 1 + 2), round(x + y) + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. round(x + y + 1 + 2)
#    core type: Operation
#    operator: 12
#    operand: 5
# 4. round(x + y) + 3
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. x + y + 1 + 2
#    core type: Operation
#    operator: 14
#    operands: 7
# 6. (round(x + y), 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x, y, 1, 2)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 10, 11
# 8. round(x + y)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. round
#     core type: Literal
#     sub-expressions:
# 13. x + y
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (x, y)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. y
#     core type: Variable
#     sub-expressions:
