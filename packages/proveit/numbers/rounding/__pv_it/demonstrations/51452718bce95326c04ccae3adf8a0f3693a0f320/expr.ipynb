# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Equals
from proveit.numbers import Add, Neg, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(y)
expr = Equals(Add(Add(x, sub_expr1).with_subtraction_at(), two), Add(x, sub_expr1, two).with_subtraction_at())
# Out:
# expr: ((x + (-y)) + 2) = (x + (-y) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x + \left(-y\right)\right) + 2\right) = \left(x + \left(-y\right) + 2\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x + (-y)) + 2) = (x + (-y) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((x + (-y)) + 2, x + (-y) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (x + (-y)) + 2
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. x + (-y) + 2
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (x + (-y), 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (x, -y, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 8
# 7. x + (-y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. -y
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. y
#     core type: Variable
#     sub-expressions:
