# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.numbers.rounding.demonstrations.e77b6c4d6c7a7447e4c5ac5a27a06c4a255af6910_step0">0</a></td><td>assumption</td><td></td><td><span style="font-size:20px;"><a class="ProveItLink" href="../df00502ed16a4992edbc267ef95beb725b0e4ff30/expr.ipynb"><img src="../df00502ed16a4992edbc267ef95beb725b0e4ff30/expr.png" style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../df00502ed16a4992edbc267ef95beb725b0e4ff30/expr.ipynb"><img src="../df00502ed16a4992edbc267ef95beb725b0e4ff30/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# </table>
