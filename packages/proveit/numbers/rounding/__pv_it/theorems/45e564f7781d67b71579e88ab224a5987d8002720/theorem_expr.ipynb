# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#floor_plus_ceil_of_neg">floor_plus_ceil_of_neg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import floor_plus_ceil_of_neg

# %%
# check that the built expression is the same as the stored expression
assert floor_plus_ceil_of_neg.expr == stored_expr
assert floor_plus_ceil_of_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: floor_plus_ceil_of_neg matches stored_expr")
# Out:
# Passed sanity check: floor_plus_ceil_of_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floor_plus_ceil_of_neg.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left(\left(\lfloor x\rfloor + \lceil -x\rceil\right) = 0\right)

# %%
# display the expression information
floor_plus_ceil_of_neg.expr_info()
# Out:
# 0. forall_{x in Real} ((floor(x) + ceil(-x)) = 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {(floor(x) + ceil(-x)) = 0 if x in Real.
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. {(floor(x) + ceil(-x)) = 0 if x in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (floor(x) + ceil(-x)) = 0
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Real
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (floor(x) + ceil(-x), 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 21, 12
# 10. floor(x) + ceil(-x)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. Real
#     core type: Literal
# ...
