# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#round_of_integer">round_of_integer</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import round_of_integer

# %%
# check that the built expression is the same as the stored expression
assert round_of_integer.expr == stored_expr
assert round_of_integer.expr._style_id == stored_expr._style_id
print("Passed sanity check: round_of_integer matches stored_expr")
# Out:
# Passed sanity check: round_of_integer matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(round_of_integer.latex())
# Out:
# \vdash \forall_{x \in \mathbb{Z}}~\left(round(x) = x\right)

# %%
# display the expression information
round_of_integer.expr_info()
# Out:
# 0. forall_{x in Integer} (round(x) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {round(x) = x if x in Integer.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {round(x) = x if x in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. round(x) = x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Integer
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (round(x), x)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Integer)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 10. round(x)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. Integer
#     core type: Literal
#     sub-expressions:
# 12. round
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
# ...
