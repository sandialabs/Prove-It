# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Ceil, Integer, Real

# %%
# build up the expression from sub-expressions
expr = Forall([x], Forall([n], Equals(Ceil(Add(x, n)), Add(Ceil(x), n)), domains = [Integer]), domains = [Real])
# Out:
# expr: forall_{x in Real} [forall_{n in Integer} (ceil(x + n) = (ceil(x) + n))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left[\forall_{n \in \mathbb{Z}}~\left(\lceil x + n\rceil = \left(\lceil x\rceil + n\right)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Real} [forall_{n in Integer} (ceil(x + n) = (ceil(x) + n))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> {forall_{n in Integer} (ceil(x + n) = (ceil(x) + n)) if x in Real.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{n in Integer} (ceil(x + n) = (ceil(x) + n)) if x in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in Integer} (ceil(x + n) = (ceil(x) + n))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. x in Real
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. n -> {ceil(x + n) = (ceil(x) + n) if n in Integer.
#    core type: Lambda
#    parameter: 24
#    body: 8
# 7. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 8. {ceil(x + n) = (ceil(x) + n) if n in Integer.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. ceil(x + n) = (ceil(x) + n)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. n in Integer
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (ceil(x + n), ceil(x) + n)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (n, Integer)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 16. ceil(x + n)
#     core type: Operation
#     operator: 25
#     operand: 19
# 17. ceil(x) + n
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. Integer
#     core type: Literal
#     sub-expressions:
# 19. x + n
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (ceil(x), n)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (x, n)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 23. ceil(x)
#     core type: Operation
#     operator: 25
#     operand: 26
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. ceil
#     core type: Literal
#     sub-expressions:
# 26. x
#     core type: Variable
#     sub-expressions:
