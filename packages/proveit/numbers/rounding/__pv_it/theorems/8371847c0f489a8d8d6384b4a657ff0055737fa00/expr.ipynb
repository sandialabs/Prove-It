# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.logic import Forall
from proveit.numbers import Add, Floor, LessEq, Real, one

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], LessEq(Floor(Add(x, y)), Add(Floor(x), Floor(y), one)), domains = [Real, Real])
# Out:
# expr: forall_{x, y in Real} (floor(x + y) <= (floor(x) + floor(y) + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, y \in \mathbb{R}}~\left(\lfloor x + y\rfloor \leq \left(\lfloor x\rfloor + \lfloor y\rfloor + 1\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, y in Real} (floor(x + y) <= (floor(x) + floor(y) + 1))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {floor(x + y) <= (floor(x) + floor(y) + 1) if x in Real ,  y in Real.
#    core type: Lambda
#    parameters: 20\n   body: 3
# 3. {floor(x + y) <= (floor(x) + floor(y) + 1) if x in Real ,  y in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. floor(x + y) <= (floor(x) + floor(y) + 1)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x in Real) and (y in Real)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (floor(x + y), floor(x) + floor(y) + 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Real, y in Real)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. floor(x + y)
#     core type: Operation
#     operator: 26
#     operand: 14
# 11. floor(x) + floor(y) + 1
#     core type: Operation
#     operator: 19
#     operands: 15
# 12. x in Real
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. y in Real
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. x + y
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (floor(x), floor(y), 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 16. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (x, y)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 21. floor(x)
#     core type: Operation
#     operator: 26
#     operand: 25
# 22. floor(y)
#     core type: Operation
#     operator: 26
#     operand: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. Real
#     core type: Literal
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. floor
#     core type: Literal
#     sub-expressions:
# 27. y
#     core type: Variable
#     sub-expressions:
