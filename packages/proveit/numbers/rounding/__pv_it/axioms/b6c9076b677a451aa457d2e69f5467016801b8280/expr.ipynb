# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import InSet
from proveit.numbers import Ceil, Integer, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Ceil(x), Integer), InSet(x, Real))
# Out:
# expr: {ceil(x) in Integer if x in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lceil x\rceil \in \mathbb{Z} \textrm{ if } x \in \mathbb{R}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {ceil(x) in Integer if x in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ceil(x) in Integer
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. x in Real
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (ceil(x), Integer)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 10, 8
# 6. ceil(x)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. Integer
#    core type: Literal
#    sub-expressions:
# 8. Real
#    core type: Literal
#    sub-expressions:
# 9. ceil
#    core type: Literal
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
