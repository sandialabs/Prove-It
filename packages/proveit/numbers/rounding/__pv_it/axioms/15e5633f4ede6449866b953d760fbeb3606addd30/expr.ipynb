# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Forall, InSet
from proveit.numbers import Floor, Integer, Real

# %%
# build up the expression from sub-expressions
expr = Forall([x], InSet(Floor(x), Integer), domains = [Real])
# Out:
# expr: forall_{x in Real} (floor(x) in Integer)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left(\lfloor x\rfloor \in \mathbb{Z}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Real} (floor(x) in Integer)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {floor(x) in Integer if x in Real.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {floor(x) in Integer if x in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. floor(x) in Integer
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. x in Real
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (floor(x), Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. floor(x)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. floor
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
