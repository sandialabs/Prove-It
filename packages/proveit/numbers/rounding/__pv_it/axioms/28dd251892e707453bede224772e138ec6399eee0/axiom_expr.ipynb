# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#floor_of_x_greater_eq">floor_of_x_greater_eq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.rounding import floor_of_x_greater_eq

# %%
# check that the built expression is the same as the stored expression
assert floor_of_x_greater_eq.expr == stored_expr
assert floor_of_x_greater_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: floor_of_x_greater_eq matches stored_expr")
# Out:
# Passed sanity check: floor_of_x_greater_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floor_of_x_greater_eq.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}, y \in \mathbb{Z}~|~y \leq x}~\left(\lfloor x\rfloor \geq y\right)

# %%
# display the expression information
floor_of_x_greater_eq.expr_info()
# Out:
# 0. forall_{x in Real, y in Integer | y <= x} (floor(x) >= y)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {floor(x) >= y if x in Real ,  y in Integer ,  y <= x.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, y)
#    core type: ExprTuple
#    sub-expressions: 24, 23
# 4. {floor(x) >= y if x in Real ,  y in Integer ,  y <= x.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. floor(x) >= y
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in Real) and (y in Integer) and (y <= x)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. >=
#    core type: Literal
#    sub-expressions:
# 8. (floor(x), y)
#    core type: ExprTuple
#    sub-expressions: 11, 23
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x in Real, y in Integer, y <= x)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. floor(x)
# ...
