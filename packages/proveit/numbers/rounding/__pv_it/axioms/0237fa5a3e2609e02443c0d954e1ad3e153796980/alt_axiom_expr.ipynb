# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_axioms_.ipynb#round_up">round_up</a> of type <a href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official axiom from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Ceil, Floor, Neg, Real, Round

# %%
# build up the expression from sub-expressions
sub_expr1 = Ceil(x)
expr = Forall([x], Equals(Round(x), sub_expr1), domains = [Real], condition = Equals(Add(x, Neg(Floor(x))), Add(sub_expr1, Neg(x))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: round_up matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
# display the expression information
expr.expr_info()
