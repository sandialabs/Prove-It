# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x, y
from proveit.logic import And, InSet
from proveit.numbers import Ceil, GreaterEq, Integer, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Ceil(x), y), And(InSet(x, Real), InSet(y, Integer), GreaterEq(y, x)))
# Out:
# expr: {ceil(x) <= y if x in Real ,  y in Integer ,  y >= x.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lceil x\rceil \leq y \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{Z} ,  y \geq x\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {ceil(x) <= y if x in Real ,  y in Integer ,  y >= x.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ceil(x) <= y
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Real) and (y in Integer) and (y >= x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (ceil(x), y)
#    core type: ExprTuple
#    sub-expressions: 7, 19
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Real, y in Integer, y >= x)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. ceil(x)
#    core type: Operation
#    operator: 11
#    operand: 20
# 8. x in Real
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. y in Integer
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. y >= x
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. ceil
#     core type: Literal
#     sub-expressions:
# 12. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (y, Integer)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 15. >=
#     core type: Literal
#     sub-expressions:
# 16. (y, x)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. Real
#     core type: Literal
#     sub-expressions:
# 18. Integer
#     core type: Literal
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
