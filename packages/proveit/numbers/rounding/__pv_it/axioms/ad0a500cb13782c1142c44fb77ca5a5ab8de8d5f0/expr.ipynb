# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Forall
from proveit.numbers import Ceil, GreaterEq, Real

# %%
# build up the expression from sub-expressions
expr = Forall([x], GreaterEq(Ceil(x), x), domains = [Real])
# Out:
# expr: forall_{x in Real} (ceil(x) >= x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left(\lceil x\rceil \geq x\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Real} (ceil(x) >= x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {ceil(x) >= x if x in Real.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {ceil(x) >= x if x in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ceil(x) >= x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Real
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. >=
#    core type: Literal
#    sub-expressions:
# 7. (ceil(x), x)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 10. ceil(x)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. ceil
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
