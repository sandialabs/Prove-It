# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">rounding</a>.<a class="ProveItLink" href="../../theorems.ipynb#real_minus_floor_interval">real_minus_floor_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, x
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.numbers import zero_in_nats
from proveit.numbers.number_sets.real_numbers import int_within_real
from proveit.numbers.rounding import Floor
from proveit.numbers.rounding import floor_is_an_int, real_minus_floor_lower_bound, real_minus_floor_upper_bound

# %%
# %proving real_minus_floor_interval
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="real_minus_floor_interval">real_minus_floor_interval:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2633fee9b070bfd190f7b7e8bfa53604aab5837f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2ae3bbc5d33f7204fe0c302f2b700c48e9946a0f0/dependencies.ipynb">dependencies</a>)<br>
# real_minus_floor_interval may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = real_minus_floor_interval.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_real_minus_floor_interval/721b375d5dd5d4da2811702f75c886ecc42288280/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
interval = real_minus_floor_interval.instance_expr.operands[1]
# Out:
# <strong id="interval">interval:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d6fef8131d9292183bfbdfc42dc66cd3842083190/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_minus_floor = real_minus_floor_interval.instance_expr.operands[0]
# Out:
# <strong id="x_minus_floor">x_minus_floor:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b20180cf2471e28c0192c36fc5c74d299c8c9eb00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
floor_is_an_int.instantiate({x:x})
# Out:
# {x in Real} |- floor(x) in Integer

# %%
real_minus_floor_lower_bound
# Out:
# |- forall_{x in Real} ((x - floor(x)) >= 0)

# %%
real_minus_floor_lower_bound.instantiate({x:x})
# Out:
# {x in Real} |- (x - floor(x)) >= 0

# %%
real_minus_floor_upper_bound
# Out:
# |- forall_{x in Real} ((x - floor(x)) < 1)

# %%
real_minus_floor_upper_bound.instantiate({x:x})
# Out:
# {x in Real} |- (x - floor(x)) < 1

# %%
# %qed
# Out:
# proveit.numbers.rounding.real_minus_floor_interval has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 1	instantiation	2, 3, 4, 5, 6	{x in Real} |- (x - floor(x)) in [0,1)
# 	a : 0, b : 1, x : x - floor(x)
# 2	conjecture		|- forall_{a, b, x in Real | a <= x < b} (x in [a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalCO
# 3	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 4	instantiation	22, 20, 7	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 5	instantiation	8, 26, 9	{x in Real} |- (x - floor(x)) in Real
# 	a : x, b : -floor(x)
# 6	instantiation	10, 11, 12	{x in Real} |- (0 <= (x - floor(x))) and ((x - floor(x)) < 1)
# 	A : 0 <= (x - floor(x)), B : (x - floor(x)) < 1
# 7	instantiation	22, 23, 13	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 8	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 9	instantiation	14, 15	{x in Real} |- (-floor(x)) in Real
# 	a : floor(x)
# 10	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 11	instantiation	16, 26	{x in Real} |- (x - floor(x)) >= 0
# 	x : x
# 12	instantiation	17, 26	{x in Real} |- (x - floor(x)) < 1
# 	x : x
# 13	instantiation	22, 18, 19	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 14	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 15	instantiation	22, 20, 21	{x in Real} |- floor(x) in Real
# 	A : Rational, B : Real, x : floor(x)
# 16	conjecture		|- forall_{x in Real} ((x - floor(x)) >= 0)
# 	proveit.numbers.rounding.real_minus_floor_lower_bound
# 17	conjecture		|- forall_{x in Real} ((x - floor(x)) < 1)
# 	proveit.numbers.rounding.real_minus_floor_upper_bound
# 18	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 19	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 20	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 21	instantiation	22, 23, 24	{x in Real} |- floor(x) in Rational
# 	A : Integer, B : Rational, x : floor(x)
# 22	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 23	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 24	instantiation	25, 26	{x in Real} |- floor(x) in Integer
# 	x : x
# 25	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 26	assumption		{x in Real} |- x in Real
