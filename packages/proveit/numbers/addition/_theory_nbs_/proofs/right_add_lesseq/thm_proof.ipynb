# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">addition</a>.<a class="ProveItLink" href="../../theorems.ipynb#right_add_lesseq">right_add_lesseq</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving right_add_lesseq
# Out:
# right_add_lesseq: forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
