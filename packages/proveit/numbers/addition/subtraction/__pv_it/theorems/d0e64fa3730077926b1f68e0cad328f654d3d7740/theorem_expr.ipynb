# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_cancel_general">add_cancel_general</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition.subtraction import add_cancel_general

# %%
# check that the built expression is the same as the stored expression
assert add_cancel_general.expr == stored_expr
assert add_cancel_general.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_cancel_general matches stored_expr")
# Out:
# Passed sanity check: add_cancel_general matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_cancel_general.latex())
# Out:
# \vdash \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k} \in \mathbb{C}}~\left(\left(a_{1} i \textrm{ repeats} \ldots + a_{i} + b + c_{1} j \textrm{ repeats} \ldots + c_{j} - b + d_{1} k \textrm{ repeats} \ldots + d_{k}\right) = \left(a_{1} + \ldots + a_{i} + c_{1} + \ldots + c_{j} + d_{1} + \ldots + d_{k}\right)\right)\right]

# %%
# display the expression information
add_cancel_general.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 47, 49, 52
# ...
