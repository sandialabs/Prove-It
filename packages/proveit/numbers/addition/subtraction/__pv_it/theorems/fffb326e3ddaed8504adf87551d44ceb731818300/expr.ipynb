# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, d, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d, e_1_to_k], instance_expr = Equals(Add(a_1_to_i, b, c_1_to_j, Neg(d), e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), domain = Complex, condition = Equals(b, d)), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k} \in \mathbb{C}~|~b = d}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j} - d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 54, 56, 59
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#     core type: Lambda
#     parameters: 14\n    body: 15
# 11. i in Natural
#     core type: Operation
#     operator: 62
#     operands: 16
# 12. j in Natural
#     core type: Operation
#     operator: 62
#     operands: 17
# 13. k in Natural
#     core type: Operation
#     operator: 62
#     operands: 18
# 14. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 44, 50, 45, 64, 46
# 15. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 54, 21
# 17. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 21
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 59, 21
# 19. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: Operation
#     operator: 41
#     operands: 22
# 20. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex) and (b = d)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex), b = d)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30, 31, 32
# 25. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 34
#     operands: 33
# 26. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 58
#     end_index: 54
# 28. b in Complex
#     core type: Operation
#     operator: 62
#     operands: 37
# 29. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 58
#     end_index: 56
# 30. d in Complex
#     core type: Operation
#     operator: 62
#     operands: 39
# 31. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 58
#     end_index: 59
# 32. b = d
#     core type: Operation
#     operator: 41
#     operands: 42
# 33. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, -d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 44, 50, 45, 43, 46
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 36. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 73
#     body: 47
# 37. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 68
# 38. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 73
#     body: 48
# 39. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 64, 68
# 40. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 73
#     body: 49
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (b, d)
#     core type: ExprTuple
#     sub-expressions: 50, 64
# 43. -d
#     core type: Operation
#     operator: 51
#     operand: 64
# 44. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 58
#     end_index: 54
# 45. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 58
#     end_index: 56
# 46. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 47. a_{_a} in Complex
#     core type: Operation
#     operator: 62
#     operands: 60
# 48. c_{_a} in Complex
#     core type: Operation
#     operator: 62
#     operands: 61
# 49. e_{_a} in Complex
#     core type: Operation
#     operator: 62
#     operands: 63
# 50. b
#     core type: Variable
#     sub-expressions:
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (d)
#     core type: ExprTuple
#     sub-expressions: 64
# 53. _a -> a_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 65
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. _a -> c_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 66
# 56. j
#     core type: Variable
#     sub-expressions:
# 57. _a -> e_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 67
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 65, 68
# 61. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 66, 68
# 62. in
#     core type: Literal
#     sub-expressions:
# 63. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 64. d
#     core type: Variable
#     sub-expressions:
# 65. a_{_a}
#     core type: IndexedVar
# variable: 69
# index: 73
# 66. c_{_a}
#     core type: IndexedVar
# variable: 70
# index: 73
# 67. e_{_a}
#     core type: IndexedVar
# variable: 71
# index: 73
# 68. Complex
#     core type: Literal
#     sub-expressions:
# 69. a
#     core type: Variable
#     sub-expressions:
# 70. c
#     core type: Variable
#     sub-expressions:
# 71. e
#     core type: Variable
#     sub-expressions:
# 72. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 73. _a
#     core type: Variable
#     sub-expressions:
