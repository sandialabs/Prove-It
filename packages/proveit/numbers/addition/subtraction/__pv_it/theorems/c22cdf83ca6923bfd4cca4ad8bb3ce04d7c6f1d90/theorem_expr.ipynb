# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#subtract_from_add">subtract_from_add</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition.subtraction import subtract_from_add

# %%
# check that the built expression is the same as the stored expression
assert subtract_from_add.expr == stored_expr
assert subtract_from_add.expr._style_id == stored_expr._style_id
print("Passed sanity check: subtract_from_add matches stored_expr")
# Out:
# Passed sanity check: subtract_from_add matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(subtract_from_add.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{C}~|~\left(a + b\right) = c}~\left(\left(c - b\right) = a\right)

# %%
# display the expression information
subtract_from_add.expr_info()
# Out:
# 0. forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(c - b) = a if a in Complex ,  b in Complex ,  c in Complex ,  (a + b) = c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 25
# 4. {(c - b) = a if a in Complex ,  b in Complex ,  c in Complex ,  (a + b) = c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (c - b) = a
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (a in Complex) and (b in Complex) and (c in Complex) and ((a + b) = c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (c - b, a)
#    core type: ExprTuple
#    sub-expressions: 10, 29
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, b in Complex, c in Complex, (a + b) = c)
#    core type: ExprTuple
# ...
