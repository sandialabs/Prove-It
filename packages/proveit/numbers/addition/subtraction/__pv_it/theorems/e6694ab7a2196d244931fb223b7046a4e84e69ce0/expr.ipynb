# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.numbers import Add, Neg

# %%
# build up the expression from sub-expressions
expr = Add(a_1_to_i, b, c_1_to_j, Neg(b), d_1_to_k)
# Out:
# expr: a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a_{1} i \textrm{ repeats} \ldots + a_{i} + b + c_{1} j \textrm{ repeats} \ldots + c_{j} - b + d_{1} k \textrm{ repeats} \ldots + d_{k}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, -b, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 12, 4, 5, 6
# 3. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 14
#    end_index: 8
# 4. c_{1}, ..c_{_a}.., c_{j}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 14
#    end_index: 10
# 5. -b
#    core type: Operation
#    operator: 11
#    operand: 12
# 6. d_{1}, ..d_{_a}.., d_{k}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 14
#    end_index: 15
# 7. _a -> a_{_a}
#    core type: Lambda
#    parameter: 22
#    body: 16
# 8. i
#    core type: Variable
#    sub-expressions:
# 9. _a -> c_{_a}
#    core type: Lambda
#    parameter: 22
#    body: 17
# 10. j
#     core type: Variable
#     sub-expressions:
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. _a -> d_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. a_{_a}
#     core type: IndexedVar
# variable: 19
# index: 22
# 17. c_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 18. d_{_a}
#     core type: IndexedVar
# variable: 21
# index: 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. d
#     core type: Variable
#     sub-expressions:
# 22. _a
#     core type: Variable
#     sub-expressions:
