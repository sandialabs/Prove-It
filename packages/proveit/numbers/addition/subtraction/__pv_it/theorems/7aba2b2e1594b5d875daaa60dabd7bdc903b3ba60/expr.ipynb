# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, b, d, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Complex, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d, e_1_to_k], instance_expr = Equals(Add(a_1_to_i, b, c_1_to_j, Neg(d), e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), domain = Complex, condition = Equals(b, d)), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k} \in \mathbb{C}~|~b = d}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j} - d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 19
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 7. i in Natural
#    core type: Operation
#    operator: 58
#    operands: 12
# 8. j in Natural
#    core type: Operation
#    operator: 58
#    operands: 13
# 9. k in Natural
#    core type: Operation
#    operator: 58
#    operands: 14
# 10. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 46, 41, 60, 42
# 11. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 17
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 52, 17
# 14. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 17
# 15. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: Operation
#     operator: 37
#     operands: 18
# 16. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex) and (b = d)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex), b = d)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26, 27, 28
# 21. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 30
#     operands: 29
# 22. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 30
#     operands: 31
# 23. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 50
# 24. b in Complex
#     core type: Operation
#     operator: 58
#     operands: 33
# 25. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 54
#     end_index: 52
# 26. d in Complex
#     core type: Operation
#     operator: 58
#     operands: 35
# 27. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 54
#     end_index: 55
# 28. b = d
#     core type: Operation
#     operator: 37
#     operands: 38
# 29. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, -d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 46, 41, 39, 42
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 32. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 43
# 33. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 64
# 34. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 44
# 35. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 60, 64
# 36. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 45
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (b, d)
#     core type: ExprTuple
#     sub-expressions: 46, 60
# 39. -d
#     core type: Operation
#     operator: 47
#     operand: 60
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 54
#     end_index: 50
# 41. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 54
#     end_index: 52
# 42. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 43. a_{_a} in Complex
#     core type: Operation
#     operator: 58
#     operands: 56
# 44. c_{_a} in Complex
#     core type: Operation
#     operator: 58
#     operands: 57
# 45. e_{_a} in Complex
#     core type: Operation
#     operator: 58
#     operands: 59
# 46. b
#     core type: Variable
#     sub-expressions:
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (d)
#     core type: ExprTuple
#     sub-expressions: 60
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 61
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. _a -> c_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 62
# 52. j
#     core type: Variable
#     sub-expressions:
# 53. _a -> e_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 63
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. k
#     core type: Variable
#     sub-expressions:
# 56. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 64
# 57. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. d
#     core type: Variable
#     sub-expressions:
# 61. a_{_a}
#     core type: IndexedVar
# variable: 65
# index: 69
# 62. c_{_a}
#     core type: IndexedVar
# variable: 66
# index: 69
# 63. e_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 64. Complex
#     core type: Literal
#     sub-expressions:
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. c
#     core type: Variable
#     sub-expressions:
# 67. e
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
