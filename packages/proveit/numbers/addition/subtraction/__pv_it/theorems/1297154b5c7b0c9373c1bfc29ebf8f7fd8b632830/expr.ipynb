# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, c, d, e, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_i, b, c_1_to_j, d, e_1_to_k], Conditional(Equals(Add(a_1_to_i, Neg(b), c_1_to_j, d, e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j), InSet(d, Complex), ExprRange(sub_expr1, InSet(IndexedVar(e, sub_expr1), Complex), one, k)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k}\right) \mapsto \left\{\left(a_{1} +  a_{2} +  \ldots +  a_{i} - b+ c_{1} +  c_{2} +  \ldots +  c_{j} + d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{i} \in \mathbb{C}\right) ,  b \in \mathbb{C}, \left(c_{1} \in \mathbb{C}\right) ,  \left(c_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(c_{j} \in \mathbb{C}\right) ,  d \in \mathbb{C}, \left(e_{1} \in \mathbb{C}\right) ,  \left(e_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(e_{k} \in \mathbb{C}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#    core type: ExprTuple
#    sub-expressions: 26, 46, 27, 31, 28
# 3. {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 40
#     end_index: 36
# 13. b in Complex
#     core type: Operation
#     operator: 44
#     operands: 21
# 14. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 40
#     end_index: 38
# 15. d in Complex
#     core type: Operation
#     operator: 44
#     operands: 23
# 16. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 40
#     end_index: 41
# 17. (a_{1}, a_{2}, ..., a_{i}, -b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 25, 27, 31, 28
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 20. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 29
# 21. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 50
# 22. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 30
# 23. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 31, 50
# 24. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 32
# 25. -b
#     core type: Operation
#     operator: 33
#     operand: 46
# 26. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 40
#     end_index: 36
# 27. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 40
#     end_index: 38
# 28. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 29. a_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 42
# 30. c_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 43
# 31. d
#     core type: Variable
#     sub-expressions:
# 32. e_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 45
# 33. -
#     core type: Literal
#     sub-expressions:
# 34. (b)
#     core type: ExprTuple
#     sub-expressions: 46
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 47
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. _a -> c_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 48
# 38. j
#     core type: Variable
#     sub-expressions:
# 39. _a -> e_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 49
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. k
#     core type: Variable
#     sub-expressions:
# 42. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 50
# 43. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 50
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. b
#     core type: Variable
#     sub-expressions:
# 47. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 55
# 48. c_{_a}
#     core type: IndexedVar
# variable: 52
# index: 55
# 49. e_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. c
#     core type: Variable
#     sub-expressions:
# 53. e
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
