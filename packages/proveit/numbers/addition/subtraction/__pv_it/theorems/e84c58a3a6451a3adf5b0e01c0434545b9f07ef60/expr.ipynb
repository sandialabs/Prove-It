# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, c, d, e, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Add(a_1_to_i, b, c_1_to_j, Neg(d), e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j), InSet(d, Complex), ExprRange(sub_expr1, InSet(IndexedVar(e, sub_expr1), Complex), one, k), Equals(b, d)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j} - d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{i} \in \mathbb{C}\right) ,  b \in \mathbb{C}, \left(c_{1} \in \mathbb{C}\right) ,  \left(c_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(c_{j} \in \mathbb{C}\right) ,  d \in \mathbb{C}, \left(e_{1} \in \mathbb{C}\right) ,  \left(e_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(e_{k} \in \mathbb{C}\right) ,  b = d\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: Operation
#    operator: 22
#    operands: 3
# 2. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex) and (b = d)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex), b = d)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 6. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}
#    core type: Operation
#    operator: 15
#    operands: 14
# 7. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#    core type: Operation
#    operator: 15
#    operands: 16
# 8. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#    core type: ExprRange
#    lambda_map: 17
#    start_index: 39
#    end_index: 35
# 9. b in Complex
#    core type: Operation
#    operator: 43
#    operands: 18
# 10. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 39
#     end_index: 37
# 11. d in Complex
#     core type: Operation
#     operator: 43
#     operands: 20
# 12. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 39
#     end_index: 40
# 13. b = d
#     core type: Operation
#     operator: 22
#     operands: 23
# 14. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, -d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 31, 26, 24, 27
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 17. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 54
#     body: 28
# 18. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 31, 49
# 19. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 54
#     body: 29
# 20. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 49
# 21. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 54
#     body: 30
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (b, d)
#     core type: ExprTuple
#     sub-expressions: 31, 45
# 24. -d
#     core type: Operation
#     operator: 32
#     operand: 45
# 25. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 39
#     end_index: 35
# 26. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 39
#     end_index: 37
# 27. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 28. a_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 41
# 29. c_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 42
# 30. e_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 44
# 31. b
#     core type: Variable
#     sub-expressions:
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. (d)
#     core type: ExprTuple
#     sub-expressions: 45
# 34. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 46
# 35. i
#     core type: Variable
#     sub-expressions:
# 36. _a -> c_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 47
# 37. j
#     core type: Variable
#     sub-expressions:
# 38. _a -> e_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 48
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. k
#     core type: Variable
#     sub-expressions:
# 41. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 49
# 42. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 49
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. d
#     core type: Variable
#     sub-expressions:
# 46. a_{_a}
#     core type: IndexedVar
# variable: 50
# index: 54
# 47. c_{_a}
#     core type: IndexedVar
# variable: 51
# index: 54
# 48. e_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. c
#     core type: Variable
#     sub-expressions:
# 52. e
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
