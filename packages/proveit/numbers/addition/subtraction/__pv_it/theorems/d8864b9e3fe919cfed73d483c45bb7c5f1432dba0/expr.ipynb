# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, d
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Neg

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d, e_1_to_k], instance_expr = Equals(Add(a_1_to_i, Neg(b), c_1_to_j, d, e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), domain = Complex)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k} \in \mathbb{C}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} - b+ c_{1} +  c_{2} +  \ldots +  c_{j} + d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#    core type: ExprTuple
#    sub-expressions: 28, 48, 29, 33, 30
# 5. {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex))
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17, 18
# 12. a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 20
#     operands: 19
# 13. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 42
#     end_index: 38
# 15. b in Complex
#     core type: Operation
#     operator: 46
#     operands: 23
# 16. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 42
#     end_index: 40
# 17. d in Complex
#     core type: Operation
#     operator: 46
#     operands: 25
# 18. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 42
#     end_index: 43
# 19. (a_{1}, a_{2}, ..., a_{i}, -b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 27, 29, 33, 30
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 22. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 31
# 23. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 52
# 24. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 32
# 25. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 33, 52
# 26. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 34
# 27. -b
#     core type: Operation
#     operator: 35
#     operand: 48
# 28. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 42
#     end_index: 38
# 29. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 42
#     end_index: 40
# 30. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 31. a_{_a} in Complex
#     core type: Operation
#     operator: 46
#     operands: 44
# 32. c_{_a} in Complex
#     core type: Operation
#     operator: 46
#     operands: 45
# 33. d
#     core type: Variable
#     sub-expressions:
# 34. e_{_a} in Complex
#     core type: Operation
#     operator: 46
#     operands: 47
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (b)
#     core type: ExprTuple
#     sub-expressions: 48
# 37. _a -> a_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 49
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 40. j
#     core type: Variable
#     sub-expressions:
# 41. _a -> e_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 51
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. k
#     core type: Variable
#     sub-expressions:
# 44. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 52
# 45. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 50. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 51. e_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. e
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
