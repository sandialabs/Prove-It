# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, a, b, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Natural, Neg, one

# %%
# build up the expression from sub-expressions
expr = Forall([i, j, k], Forall([a_1_to_i, b_1_to_j, c_1_to_k], Equals(Add(a_1_to_i, Neg(Add(b_1_to_j)), c_1_to_k), Add(a_1_to_i, ExprRange(a, Neg(IndexedVar(b, a)), one, j), c_1_to_k)).with_wrapping_at(2), domains = [Complex, Complex, Complex]), domains = [Natural, Natural, Natural])
# Out:
# expr: forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - \left(b_{1} + \ldots + b_{j}\right) + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) =  \\ \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - b_{1} j \textrm{ repeats} \ldots - b_{j} + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) \end{array}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 43, 63, 46
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 21
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 35, 57, 37
# 10. {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. i in Natural
#     core type: Operation
#     operator: 49
#     operands: 16
# 12. j in Natural
#     core type: Operation
#     operator: 49
#     operands: 17
# 13. k in Natural
#     core type: Operation
#     operator: 49
#     operands: 18
# 14. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 23
# 17. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 63, 23
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 23
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}, a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 51
#     operands: 29
# 25. a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 51
#     operands: 30
# 26. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 62
#     end_index: 43
# 27. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 62
#     end_index: 63
# 28. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 62
#     end_index: 46
# 29. (a_{1}, ..a_{_a}.., a_{i}, -(b_{1} + ..b_{_a}.. + b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 34, 37
# 30. (a_{1}, ..a_{_a}.., a_{i}, -b_{1}, ..-b_{a}.., -b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 31. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 67
#     body: 38
# 32. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 67
#     body: 39
# 33. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 67
#     body: 40
# 34. -(b_{1} + ..b_{_a}.. + b_{j})
#     core type: Operation
#     operator: 58
#     operand: 41
# 35. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 62
#     end_index: 43
# 36. (-b_{1}), ..(-b_{a}).., (-b_{j})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 62
#     end_index: 63
# 37. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 62
#     end_index: 46
# 38. a_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 47
# 39. b_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 48
# 40. c_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 50
# 41. b_{1} + ..b_{_a}.. + b_{j}
#     core type: Operation
#     operator: 51
#     operands: 52
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 54
# 43. i
#     core type: Variable
#     sub-expressions:
# 44. a -> (-b_{a})
#     core type: Lambda
#     parameter: 64
#     body: 53
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 55
# 46. k
#     core type: Variable
#     sub-expressions:
# 47. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 48. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 65, 56
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. -b_{a}
#     core type: Operation
#     operator: 58
#     operand: 59
# 54. a_{_a}
#     core type: IndexedVar
# variable: 64
# index: 67
# 55. c_{_a}
#     core type: IndexedVar
# variable: 60
# index: 67
# 56. Complex
#     core type: Literal
#     sub-expressions:
# 57. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 58. -
#     core type: Literal
#     sub-expressions:
# 59. b_{a}
#     core type: IndexedVar
# variable: 66
# index: 64
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. _a -> b_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 65
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. j
#     core type: Variable
#     sub-expressions:
# 64. a
#     core type: Variable
#     sub-expressions:
# 65. b_{_a}
#     core type: IndexedVar
# variable: 66
# index: 67
# 66. b
#     core type: Variable
#     sub-expressions:
# 67. _a
#     core type: Variable
#     sub-expressions:
