# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Add(Neg(a), b, a), b), And(InSet(a, Complex), InSet(b, Complex))))
# Out:
# expr: (a, b) -> {(-a + b + a) = b if a in Complex ,  b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(-a + b + a\right) = b \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(-a + b + a) = b if a in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 21, 18
# 2. {(-a + b + a) = b if a in Complex ,  b in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (-a + b + a) = b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complex) and (b in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (-a + b + a, b)
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. -a + b + a
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Complex
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. b in Complex
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (-a, b, a)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 21
# 14. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. -a
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. Complex
#     core type: Literal
#     sub-expressions:
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
