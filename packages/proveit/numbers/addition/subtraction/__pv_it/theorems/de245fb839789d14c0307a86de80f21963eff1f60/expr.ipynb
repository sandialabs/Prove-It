# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, c, d, e, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_i, b, c_1_to_j, d, e_1_to_k], Conditional(Equals(Add(a_1_to_i, b, c_1_to_j, Neg(d), e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), InSet(b, Complex), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, j), InSet(d, Complex), ExprRange(sub_expr1, InSet(IndexedVar(e, sub_expr1), Complex), one, k), Equals(b, d))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k}\right) \mapsto \left\{\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j} - d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{i} \in \mathbb{C}\right) ,  b \in \mathbb{C}, \left(c_{1} \in \mathbb{C}\right) ,  \left(c_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(c_{j} \in \mathbb{C}\right) ,  d \in \mathbb{C}, \left(e_{1} \in \mathbb{C}\right) ,  \left(e_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(e_{k} \in \mathbb{C}\right) ,  b = d\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#    core type: ExprTuple
#    sub-expressions: 27, 33, 28, 47, 29
# 2. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex) ,  b = d.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: Operation
#    operator: 24
#    operands: 5
# 4. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex) and (b = d)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex), b = d)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 14, 15
# 8. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}
#    core type: Operation
#    operator: 17
#    operands: 16
# 9. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#    core type: Operation
#    operator: 17
#    operands: 18
# 10. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 41
#     end_index: 37
# 11. b in Complex
#     core type: Operation
#     operator: 45
#     operands: 20
# 12. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 41
#     end_index: 39
# 13. d in Complex
#     core type: Operation
#     operator: 45
#     operands: 22
# 14. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 41
#     end_index: 42
# 15. b = d
#     core type: Operation
#     operator: 24
#     operands: 25
# 16. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, -d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 27, 33, 28, 26, 29
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 19. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 30
# 20. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 33, 51
# 21. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 31
# 22. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 51
# 23. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 32
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (b, d)
#     core type: ExprTuple
#     sub-expressions: 33, 47
# 26. -d
#     core type: Operation
#     operator: 34
#     operand: 47
# 27. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 41
#     end_index: 37
# 28. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 41
#     end_index: 39
# 29. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 30. a_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 43
# 31. c_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 44
# 32. e_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 46
# 33. b
#     core type: Variable
#     sub-expressions:
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (d)
#     core type: ExprTuple
#     sub-expressions: 47
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 48
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 49
# 39. j
#     core type: Variable
#     sub-expressions:
# 40. _a -> e_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 50
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. k
#     core type: Variable
#     sub-expressions:
# 43. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 51
# 44. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 51
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. d
#     core type: Variable
#     sub-expressions:
# 48. a_{_a}
#     core type: IndexedVar
# variable: 52
# index: 56
# 49. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 50. e_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 51. Complex
#     core type: Literal
#     sub-expressions:
# 52. a
#     core type: Variable
#     sub-expressions:
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. e
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
