# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, c, i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_i, b_1_to_j, c_1_to_k], Conditional(Equals(Add(a_1_to_i, Neg(Add(b_1_to_j)), c_1_to_k), Add(a_1_to_i, ExprRange(a, Neg(IndexedVar(b, a)), one, j), c_1_to_k)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, j), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Complex), one, k))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right) \mapsto \left\{\begin{array}{c} \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - \left(b_{1} + \ldots + b_{j}\right) + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) =  \\ \left(a_{1} i \textrm{ repeats} \ldots + a_{i} - b_{1} j \textrm{ repeats} \ldots - b_{j} + c_{1} k \textrm{ repeats} \ldots + c_{k}\right) \end{array} \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b_{1} \in \mathbb{C} ,  \ldots ,  b_{j} \in \mathbb{C} ,  c_{1} \in \mathbb{C} ,  \ldots ,  c_{k} \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 20, 42, 22
# 2. {(a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c_{1} in Complex ,  ..c_{_a} in Complex.. ,  c_{k} in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}) =  \\ (a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex) and (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{k} in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}, a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c_{1} in Complex, ..c_{_a} in Complex.., c_{k} in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. a_{1} i repeats ..a_{_a}.. + a_{i} - (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} k repeats ..c_{_a}.. + c_{k}
#    core type: Operation
#    operator: 36
#    operands: 14
# 10. a_{1} i repeats ..a_{_a}.. + a_{i} - b_{1} j repeats ..b_{a}.. - b_{j} + c_{1} k repeats ..c_{_a}.. + c_{k}
#     core type: Operation
#     operator: 36
#     operands: 15
# 11. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 47
#     end_index: 28
# 12. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 47
#     end_index: 48
# 13. (c_{1} in Complex), ..(c_{_a} in Complex).., (c_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 47
#     end_index: 31
# 14. (a_{1}, ..a_{_a}.., a_{i}, -(b_{1} + ..b_{_a}.. + b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 20, 19, 22
# 15. (a_{1}, ..a_{_a}.., a_{i}, -b_{1}, ..-b_{a}.., -b_{j}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 16. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 52
#     body: 23
# 17. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 52
#     body: 24
# 18. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 52
#     body: 25
# 19. -(b_{1} + ..b_{_a}.. + b_{j})
#     core type: Operation
#     operator: 43
#     operand: 26
# 20. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 47
#     end_index: 28
# 21. (-b_{1}), ..(-b_{a}).., (-b_{j})
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 47
#     end_index: 48
# 22. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 47
#     end_index: 31
# 23. a_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 32
# 24. b_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 33
# 25. c_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 35
# 26. b_{1} + ..b_{_a}.. + b_{j}
#     core type: Operation
#     operator: 36
#     operands: 37
# 27. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 39
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. a -> (-b_{a})
#     core type: Lambda
#     parameter: 49
#     body: 38
# 30. _a -> c_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 40
# 31. k
#     core type: Variable
#     sub-expressions:
# 32. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 33. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 41
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. -b_{a}
#     core type: Operation
#     operator: 43
#     operand: 44
# 39. a_{_a}
#     core type: IndexedVar
# variable: 49
# index: 52
# 40. c_{_a}
#     core type: IndexedVar
# variable: 45
# index: 52
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. b_{a}
#     core type: IndexedVar
# variable: 51
# index: 49
# 45. c
#     core type: Variable
#     sub-expressions:
# 46. _a -> b_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. a
#     core type: Variable
#     sub-expressions:
# 50. b_{_a}
#     core type: IndexedVar
# variable: 51
# index: 52
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. _a
#     core type: Variable
#     sub-expressions:
