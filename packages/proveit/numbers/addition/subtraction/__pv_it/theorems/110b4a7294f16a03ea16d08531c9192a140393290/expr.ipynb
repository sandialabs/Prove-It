# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, b, d, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, e_1_to_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Complex, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([i, j, k], Conditional(Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j, d, e_1_to_k], instance_expr = Equals(Add(a_1_to_i, Neg(b), c_1_to_j, d, e_1_to_k), Add(a_1_to_i, c_1_to_j, e_1_to_k)), domain = Complex), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j, k\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}, d, e_{1}, e_{2}, \ldots, e_{k} \in \mathbb{C}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} - b+ c_{1} +  c_{2} +  \ldots +  c_{j} + d+ e_{1} +  e_{2} +  \ldots +  e_{k}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ c_{1} +  c_{2} +  \ldots +  c_{j}+ e_{1} +  e_{2} +  \ldots +  e_{k}\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 51, 53, 56
# 3. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#    core type: Lambda
#    parameters: 13\n   body: 14
# 10. i in Natural
#     core type: Operation
#     operator: 59
#     operands: 15
# 11. j in Natural
#     core type: Operation
#     operator: 59
#     operands: 16
# 12. k in Natural
#     core type: Operation
#     operator: 59
#     operands: 17
# 13. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 61, 42, 46, 43
# 14. {(a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex) ,  b in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{j} in Complex) ,  d in Complex, (e_{1} in Complex) ,  (e_{2} in Complex) ,  ... ,  (e_{k} in Complex).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 53, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 18. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex) and (b in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{j} in Complex) and (d in Complex)and (e_{1} in Complex) and  (e_{2} in Complex) and  ... and  (e_{k} in Complex)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}, a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex), b in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex), d in Complex,(e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex))
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30, 31
# 25. a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 33
#     operands: 32
# 26. a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}
#     core type: Operation
#     operator: 33
#     operands: 34
# 27. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 55
#     end_index: 51
# 28. b in Complex
#     core type: Operation
#     operator: 59
#     operands: 36
# 29. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 55
#     end_index: 53
# 30. d in Complex
#     core type: Operation
#     operator: 59
#     operands: 38
# 31. (e_{1} in Complex), (e_{2} in Complex), ..., (e_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 55
#     end_index: 56
# 32. (a_{1}, a_{2}, ..., a_{i}, -b,c_{1}, c_{2}, ..., c_{j}, d,e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 40, 42, 46, 43
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j},e_{1}, e_{2}, ..., e_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 35. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 70
#     body: 44
# 36. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 65
# 37. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 70
#     body: 45
# 38. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 65
# 39. _a -> (e_{_a} in Complex)
#     core type: Lambda
#     parameter: 70
#     body: 47
# 40. -b
#     core type: Operation
#     operator: 48
#     operand: 61
# 41. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 55
#     end_index: 51
# 42. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 55
#     end_index: 53
# 43. e_{1}, e_{2}, ..., e_{k}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 44. a_{_a} in Complex
#     core type: Operation
#     operator: 59
#     operands: 57
# 45. c_{_a} in Complex
#     core type: Operation
#     operator: 59
#     operands: 58
# 46. d
#     core type: Variable
#     sub-expressions:
# 47. e_{_a} in Complex
#     core type: Operation
#     operator: 59
#     operands: 60
# 48. -
#     core type: Literal
#     sub-expressions:
# 49. (b)
#     core type: ExprTuple
#     sub-expressions: 61
# 50. _a -> a_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 62
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. _a -> c_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 63
# 53. j
#     core type: Variable
#     sub-expressions:
# 54. _a -> e_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 64
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. k
#     core type: Variable
#     sub-expressions:
# 57. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 58. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 63, 65
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (e_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. b
#     core type: Variable
#     sub-expressions:
# 62. a_{_a}
#     core type: IndexedVar
# variable: 66
# index: 70
# 63. c_{_a}
#     core type: IndexedVar
# variable: 67
# index: 70
# 64. e_{_a}
#     core type: IndexedVar
# variable: 68
# index: 70
# 65. Complex
#     core type: Literal
#     sub-expressions:
# 66. a
#     core type: Variable
#     sub-expressions:
# 67. c
#     core type: Variable
#     sub-expressions:
# 68. e
#     core type: Variable
#     sub-expressions:
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. _a
#     core type: Variable
#     sub-expressions:
