# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, b
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Variable("_a", latex_format = r"{_{-}a}"), Add(Mult(three, b), Mult(two, b)), two)
# Out:
# expr: _a + ((3 * b) + (2 * b)) + 2

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} + \left(\left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + 2

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 4
#    operands: 1
# 1. (_a, (3 * b) + (2 * b), 2)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 12
# 2. _a
#    core type: Variable
#    sub-expressions:
# 3. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 3 * b
#    core type: Operation
#    operator: 9
#    operands: 8
# 7. 2 * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (3, b)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2, b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
