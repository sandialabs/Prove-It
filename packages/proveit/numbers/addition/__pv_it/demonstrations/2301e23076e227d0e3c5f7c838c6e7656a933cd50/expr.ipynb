# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(a, a, c, one, two, b, b, c, c, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + a + c + 1 + 2 + b + b + c + c + 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3\right) = \left(a + a + c + 1 + 2 + b + b + c + c + 3\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + a + c + 1 + 2 + b + b + c + c + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, a + a + c + 1 + 2 + b + b + c + c + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + a + c + 1 + 2 + b + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 13, 12, 9, 8, 12, 13, 13, 14
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a, a, c, 1, 2, b, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 9, 13, 10, 11, 12, 12, 13, 13, 14
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
