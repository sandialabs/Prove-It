# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.logic import Equals
from proveit.numbers import Add, Mult, one, three

# %%
# build up the expression from sub-expressions
expr = Equals(Add(Mult(one, b), Mult(three, b)), Mult(Add(one, three), b))
# Out:
# expr: ((1 * b) + (3 * b)) = ((1 + 3) * b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 \cdot b\right) + \left(3 \cdot b\right)\right) = \left(\left(1 + 3\right) \cdot b\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((1 * b) + (3 * b)) = ((1 + 3) * b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 * b) + (3 * b), (1 + 3) * b)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 * b) + (3 * b)
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (1 + 3) * b
#    core type: Operation
#    operator: 11
#    operands: 6
# 5. (1 * b, 3 * b)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (1 + 3, b)
#    core type: ExprTuple
#    sub-expressions: 9, 15
# 7. 1 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. 1 + 3
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (1, b)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (3, b)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 3
#     core type: Literal
#     sub-expressions:
