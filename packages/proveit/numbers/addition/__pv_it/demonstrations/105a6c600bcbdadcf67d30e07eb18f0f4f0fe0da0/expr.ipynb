# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(b)
sub_expr2 = Mult(three, b)
expr = ExprTuple(Add(Mult(two, b), sub_expr2, b, sub_expr1), Add(Mult(b, two), sub_expr2, b, sub_expr1))
# Out:
# expr: ((2 * b) + (3 * b) + b - b, (b * 2) + (3 * b) + b - b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b, \left(b \cdot 2\right) + \left(3 \cdot b\right) + b - b\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + (3 * b) + b - b, (b * 2) + (3 * b) + b - b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (b * 2) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 6, 8, 17, 9
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b * 2, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 17, 9
# 6. 2 * b
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. b * 2
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. -b
#    core type: Operation
#    operator: 14
#    operand: 17
# 10. (2, b)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 11. (b, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
