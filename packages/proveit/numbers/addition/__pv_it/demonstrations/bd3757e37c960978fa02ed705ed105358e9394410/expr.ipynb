# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(three, b)
sub_expr2 = Mult(two, b)
expr = ExprTuple(Add(two, b, c, sub_expr1, sub_expr2, c), Add(b, sub_expr1, two, c, sub_expr2, c))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) + c, b + (3 * b) + 2 + c + (2 * b) + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + c, b + \left(3 \cdot b\right) + 2 + c + \left(2 \cdot b\right) + c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) + c, b + (3 * b) + 2 + c + (2 * b) + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. b + (3 * b) + 2 + c + (2 * b) + c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2, b, c, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 13, 14, 8, 6, 7, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b, 3 * b, 2, c, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 14, 6, 13, 8, 7, 8
# 6. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. (3, b)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
