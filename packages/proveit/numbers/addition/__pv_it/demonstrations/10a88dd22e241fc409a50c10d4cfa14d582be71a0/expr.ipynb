# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Mult(two, a), Mult(three, c), Mult(two, b), Add(one, two, three)))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, (2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3, \left(2 \cdot a\right) + \left(3 \cdot c\right) + \left(2 \cdot b\right) + \left(1 + 2 + 3\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, (2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 16, 19, 20, 17, 18, 16, 5, 18, 17, 17, 21
# 4. (2 * a, 3 * c, 2 * b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. 2 * a
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. 3 * c
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. 2 * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. 1 + 2 + 3
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. (2, a)
#     core type: ExprTuple
#     sub-expressions: 20, 16
# 11. (3, c)
#     core type: ExprTuple
#     sub-expressions: 21, 17
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
