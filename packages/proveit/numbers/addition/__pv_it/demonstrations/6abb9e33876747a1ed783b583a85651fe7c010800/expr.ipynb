# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, b, c, a, b, a, c), Add(Mult(three, a), Mult(two, b), Mult(two, c)))
# Out:
# expr: (a + b + c + a + b + a + c, (3 * a) + (2 * b) + (2 * c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + c + a + b + a + c, \left(3 \cdot a\right) + \left(2 \cdot b\right) + \left(2 \cdot c\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + b + c + a + b + a + c, (3 * a) + (2 * b) + (2 * c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + b + c + a + b + a + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (3 * a) + (2 * b) + (2 * c)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b, c, a, b, a, c)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 17, 14, 15, 14, 17
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (3 * a, 2 * b, 2 * c)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. 3 * a
#    core type: Operation
#    operator: 11
#    operands: 9
# 7. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. 2 * c
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (3, a)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (2, b)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
