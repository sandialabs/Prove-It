# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, b, c, k
from proveit.core_expr_types import Len
from proveit.numbers import Mult, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([b, Mult(three, b), Mult(two, b), c]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(b, 3 * b, 2 * b, c)|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b, 3 \cdot b, 2 \cdot b, c\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(b, 3 * b, 2 * b, c)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b, 3 * b, 2 * b, c)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((b, 3 * b, 2 * b, c))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 20, 8, 9, 10
# 7. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. 3 * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 1, ..k.., 4
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 12. (3, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. k -> k
#     core type: Lambda
#     parameter: 21
#     body: 21
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 4
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. k
#     core type: Variable
#     sub-expressions:
