# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(two, b)
sub_expr2 = Mult(three, b)
expr = ExprTuple(Add(sub_expr1, sub_expr2, b, Neg(b)), Add(sub_expr1, sub_expr2, Mult(one, b), Mult(Neg(one), b)).with_subtraction_at(3))
# Out:
# expr: ((2 * b) + (3 * b) + b - b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b, \left(2 \cdot b\right) + \left(3 \cdot b\right) + \left(1 \cdot b\right) + \left(\left(-1\right) \cdot b\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + (3 * b) + b - b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2 * b) + (3 * b) + (1 * b) + ((-1) * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 19, 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2 * b, 3 * b, 1 * b, (-1) * b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 6. -b
#    core type: Operation
#    operator: 20
#    operand: 19
# 7. 2 * b
#    core type: Operation
#    operator: 14
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. 1 * b
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. (-1) * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (2, b)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# ...
