# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(two, three, four, a, a, c, zero, c, b, b), Add(Add(a, a), Add(c, c), b, b, two, three, four))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b, (a + a) + (c + c) + b + b + 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + 3 + 4 + a + a + c + 0 + c + b + b, \left(a + a\right) + \left(c + c\right) + b + b + 2 + 3 + 4\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b, (a + a) + (c + c) + b + b + 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (a + a) + (c + c) + b + b + 2 + 3 + 4
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (2, 3, 4, a, a, c, 0, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 15, 15, 16, 5, 16, 8, 8
# 4. (a + a, c + c, b, b, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 8, 9, 10, 11
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. a + a
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. c + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
# 12. (a, a)
#     core type: ExprTuple
#     sub-expressions: 15, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (c, c)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
