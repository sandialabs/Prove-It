# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, three

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(b, b)
sub_expr2 = Add(c, c)
expr = ExprTuple(Add(Add(a, a, a), sub_expr1, sub_expr2), Add(Mult(three, a), sub_expr1, sub_expr2))
# Out:
# expr: ((a + a + a) + (b + b) + (c + c), (3 * a) + (b + b) + (c + c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a + a + a\right) + \left(b + b\right) + \left(c + c\right), \left(3 \cdot a\right) + \left(b + b\right) + \left(c + c\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a + a + a) + (b + b) + (c + c), (3 * a) + (b + b) + (c + c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a + a + a) + (b + b) + (c + c)
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (3 * a) + (b + b) + (c + c)
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a + a + a, b + b, c + c)
#    core type: ExprTuple
#    sub-expressions: 5, 7, 8
# 4. (3 * a, b + b, c + c)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. a + a + a
#    core type: Operation
#    operator: 13
#    operands: 9
# 6. 3 * a
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. b + b
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. c + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (a, a, a)
#    core type: ExprTuple
#    sub-expressions: 16, 16, 16
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (3, a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (b, b)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (c, c)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
