# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, b, c, a, b, a, c, b, a, c, a), Add(Add(a, a, a, a, a), b, b, b, c, c, c))
# Out:
# expr: (a + b + c + a + b + a + c + b + a + c + a) = ((a + a + a + a + a) + b + b + b + c + c + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + c + a + b + a + c + b + a + c + a\right) = \left(\left(a + a + a + a + a\right) + b + b + b + c + c + c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + b + c + a + b + a + c + b + a + c + a) = ((a + a + a + a + a) + b + b + b + c + c + c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + b + c + a + b + a + c + b + a + c + a, (a + a + a + a + a) + b + b + b + c + c + c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + b + c + a + b + a + c + b + a + c + a
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (a + a + a + a + a) + b + b + b + c + c + c
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (a, b, c, a, b, a, c, b, a, c, a)
#    core type: ExprTuple
#    sub-expressions: 12, 8, 9, 12, 8, 12, 9, 8, 12, 9, 12
# 6. (a + a + a + a + a, b, b, b, c, c, c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 8, 8, 9, 9, 9
# 7. a + a + a + a + a
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (a, a, a, a, a)
#     core type: ExprTuple
#     sub-expressions: 12, 12, 12, 12, 12
# 12. a
#     core type: Variable
#     sub-expressions:
