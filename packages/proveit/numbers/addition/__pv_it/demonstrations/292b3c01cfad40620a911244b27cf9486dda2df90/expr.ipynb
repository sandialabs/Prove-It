# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, one, three, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(one, a, A, zero, b, B, C, c, one, three, A), Add(a, one, A, b, B, C, c, one, three, A))
# Out:
# expr: (1 + a + A + 0 + b + B + C + c + 1 + 3 + A) = (a + 1 + A + b + B + C + c + 1 + 3 + A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 + a + A + 0 + b + B + C + c + 1 + 3 + A\right) = \left(a + 1 + A + b + B + C + c + 1 + 3 + A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 + a + A + 0 + b + B + C + c + 1 + 3 + A) = (a + 1 + A + b + B + C + c + 1 + 3 + A)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1 + a + A + 0 + b + B + C + c + 1 + 3 + A, a + 1 + A + b + B + C + c + 1 + 3 + A)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1 + a + A + 0 + b + B + C + c + 1 + 3 + A
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + 1 + A + b + B + C + c + 1 + 3 + A
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1, a, A, 0, b, B, C, c, 1, 3, A)
#    core type: ExprTuple
#    sub-expressions: 14, 9, 16, 8, 10, 11, 12, 13, 14, 15, 16
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a, 1, A, b, B, C, c, 1, 3, A)
#    core type: ExprTuple
#    sub-expressions: 9, 14, 16, 10, 11, 12, 13, 14, 15, 16
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
