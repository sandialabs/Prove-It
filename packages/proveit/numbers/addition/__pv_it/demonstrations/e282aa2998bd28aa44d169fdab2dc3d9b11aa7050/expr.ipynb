# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(Mult(two, b), Mult(three, b), b, Neg(b)), Add(Mult(b, two), Mult(b, three), Mult(b, one), Mult(b, Neg(one))).with_subtraction_at(3))
# Out:
# expr: ((2 * b) + (3 * b) + b - b, (b * 2) + (b * 3) + (b * 1) + (b * (-1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b, \left(b \cdot 2\right) + \left(b \cdot 3\right) + \left(b \cdot 1\right) + \left(b \cdot \left(-1\right)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + (3 * b) + b - b, (b * 2) + (b * 3) + (b * 1) + (b * (-1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (b * 2) + (b * 3) + (b * 1) + (b * (-1))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 22, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b * 2, b * 3, b * 1, b * (-1))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 6. 2 * b
#    core type: Operation
#    operator: 18
#    operands: 13
# 7. 3 * b
#    core type: Operation
#    operator: 18
#    operands: 14
# 8. -b
#    core type: Operation
#    operator: 24
#    operand: 22
# 9. b * 2
#    core type: Operation
#    operator: 18
#    operands: 15
# 10. b * 3
#     core type: Operation
#     operator: 18
#     operands: 16
# 11. b * 1
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. b * (-1)
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 14. (3, b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 15. (b, 2)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 16. (b, 3)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 17. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 25
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
# 23. -1
#     core type: Operation
#     operator: 24
#     operand: 25
# 24. -
#     core type: Literal
#     sub-expressions:
# 25. 1
#     core type: Literal
#     sub-expressions:
