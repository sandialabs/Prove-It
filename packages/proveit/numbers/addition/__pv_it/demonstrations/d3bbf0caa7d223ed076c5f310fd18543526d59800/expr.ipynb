# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprTuple, a, b, c
from proveit.numbers import Add, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, A, A, b, B, C, c, one, one, three), Add(a, Add(A, A), b, B, C, c, one, one, three))
# Out:
# expr: (a + A + A + b + B + C + c + 1 + 1 + 3, a + (A + A) + b + B + C + c + 1 + 1 + 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + A + A + b + B + C + c + 1 + 1 + 3, a + \left(A + A\right) + b + B + C + c + 1 + 1 + 3\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + A + A + b + B + C + c + 1 + 1 + 3, a + (A + A) + b + B + C + c + 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + A + A + b + B + C + c + 1 + 1 + 3
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. a + (A + A) + b + B + C + c + 1 + 1 + 3
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a, A, A, b, B, C, c, 1, 1, 3)
#    core type: ExprTuple
#    sub-expressions: 5, 15, 15, 7, 8, 9, 10, 11, 11, 12
# 4. (a, A + A, b, B, C, c, 1, 1, 3)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8, 9, 10, 11, 11, 12
# 5. a
#    core type: Variable
#    sub-expressions:
# 6. A + A
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. b
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (A, A)
#     core type: ExprTuple
#     sub-expressions: 15, 15
# 15. A
#     core type: Variable
#     sub-expressions:
