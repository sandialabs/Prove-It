# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, b, k
from proveit.core_expr_types import Len
from proveit.numbers import one, six

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a, a, a, a, a, b]), Len([ExprRange(k, k, one, six)]))
# Out:
# expr: (|(a, a, a, a, a, b)|, |(1, ..k.., 6)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a, a, a, a, a, b\right)|, |\left(1, \ldots, 6\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a, a, a, a, a, b)|, |(1, ..k.., 6)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a, a, a, a, a, b)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 6)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a, a, a, a, a, b))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 6))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, a, a, a, a, b)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 8, 8, 8, 9
# 7. (1, ..k.., 6)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. 1, ..k.., 6
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. k -> k
#     core type: Lambda
#     parameter: 14
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 6
#     core type: Literal
#     sub-expressions:
# 14. k
#     core type: Variable
#     sub-expressions:
