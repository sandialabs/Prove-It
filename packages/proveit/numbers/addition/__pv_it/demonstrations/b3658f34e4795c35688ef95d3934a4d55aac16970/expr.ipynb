# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, five, three

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, b, c, a, b, a, c, b, a, c, a), Add(Mult(five, a), Mult(three, b), Mult(three, c)))
# Out:
# expr: (a + b + c + a + b + a + c + b + a + c + a) = ((5 * a) + (3 * b) + (3 * c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + c + a + b + a + c + b + a + c + a\right) = \left(\left(5 \cdot a\right) + \left(3 \cdot b\right) + \left(3 \cdot c\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + b + c + a + b + a + c + b + a + c + a) = ((5 * a) + (3 * b) + (3 * c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + b + c + a + b + a + c + b + a + c + a, (5 * a) + (3 * b) + (3 * c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + b + c + a + b + a + c + b + a + c + a
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (5 * a) + (3 * b) + (3 * c)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, b, c, a, b, a, c, b, a, c, a)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 19, 16, 17, 16, 19, 17, 16, 19, 16
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (5 * a, 3 * b, 3 * c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 8. 5 * a
#    core type: Operation
#    operator: 13
#    operands: 11
# 9. 3 * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. 3 * c
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (5, a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (3, b)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (3, c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
