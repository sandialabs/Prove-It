# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d
from proveit.logic import Equals
from proveit.numbers import Add, Mult, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(Mult(two, b), b, a, c, Mult(zero, d)), Add(Mult(three, b), a, c))
# Out:
# expr: ((2 * b) + b + a + c + (0 * d)) = ((3 * b) + a + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + b + a + c + \left(0 \cdot d\right)\right) = \left(\left(3 \cdot b\right) + a + c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * b) + b + a + c + (0 * d)) = ((3 * b) + a + c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * b) + b + a + c + (0 * d), (3 * b) + a + c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * b) + b + a + c + (0 * d)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (3 * b) + a + c
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 * b, b, a, c, 0 * d)
#    core type: ExprTuple
#    sub-expressions: 8, 21, 11, 12, 9
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (3 * b, a, c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 9. 0 * d
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. 3 * b
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 14. (0, d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (3, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
