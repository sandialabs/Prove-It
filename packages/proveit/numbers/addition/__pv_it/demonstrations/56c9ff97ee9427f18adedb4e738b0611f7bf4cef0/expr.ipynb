# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(three, b)
sub_expr2 = Mult(two, b)
expr = ExprTuple(Add(b, sub_expr1, sub_expr2), Add(Mult(one, b), sub_expr1, sub_expr2))
# Out:
# expr: (b + (3 * b) + (2 * b), (1 * b) + (3 * b) + (2 * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b + \left(3 \cdot b\right) + \left(2 \cdot b\right), \left(1 \cdot b\right) + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (b + (3 * b) + (2 * b), (1 * b) + (3 * b) + (2 * b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (1 * b) + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 16, 7, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (1 * b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. 1 * b
#    core type: Operation
#    operator: 11
#    operands: 9
# 7. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (1, b)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 10. (3, b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
