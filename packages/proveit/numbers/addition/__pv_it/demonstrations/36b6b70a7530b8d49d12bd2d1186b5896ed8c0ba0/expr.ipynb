# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Mult(three, b), Mult(two, b))
expr = Equals(Add(Add(c, c), sub_expr1, two), Add(Mult(two, c), sub_expr1, two))
# Out:
# expr: ((c + c) + ((3 * b) + (2 * b)) + 2) = ((2 * c) + ((3 * b) + (2 * b)) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(c + c\right) + \left(\left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + 2\right) = \left(\left(2 \cdot c\right) + \left(\left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + 2\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((c + c) + ((3 * b) + (2 * b)) + 2) = ((2 * c) + ((3 * b) + (2 * b)) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((c + c) + ((3 * b) + (2 * b)) + 2, (2 * c) + ((3 * b) + (2 * b)) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (c + c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (2 * c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (c + c, (3 * b) + (2 * b), 2)
#    core type: ExprTuple
#    sub-expressions: 7, 9, 21
# 6. (2 * c, (3 * b) + (2 * b), 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 21
# 7. c + c
#    core type: Operation
#    operator: 12
#    operands: 10
# 8. 2 * c
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (c, c)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 11. (2, c)
#     core type: ExprTuple
#     sub-expressions: 21, 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (3 * b, 2 * b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. 3 * b
#     core type: Operation
#     operator: 18
#     operands: 17
# 16. 2 * b
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (3, b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (2, b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
