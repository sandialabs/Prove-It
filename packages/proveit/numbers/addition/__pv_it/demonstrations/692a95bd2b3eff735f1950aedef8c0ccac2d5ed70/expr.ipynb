# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, one, six, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Mult(two, a), Mult(three, c), Mult(two, b), six))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((2 * a) + (3 * c) + (2 * b) + 6)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3\right) = \left(\left(2 \cdot a\right) + \left(3 \cdot c\right) + \left(2 \cdot b\right) + 6\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((2 * a) + (3 * c) + (2 * b) + 6)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, (2 * a) + (3 * c) + (2 * b) + 6)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * a) + (3 * c) + (2 * b) + 6
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 18, 8, 21, 20, 22, 18, 9, 22, 20, 20, 19
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2 * a, 3 * c, 2 * b, 6)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. 2 * a
#     core type: Operation
#     operator: 16
#     operands: 14
# 11. 3 * c
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. 6
#     core type: Literal
#     sub-expressions:
# 14. (2, a)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 15. (3, c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2, b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
