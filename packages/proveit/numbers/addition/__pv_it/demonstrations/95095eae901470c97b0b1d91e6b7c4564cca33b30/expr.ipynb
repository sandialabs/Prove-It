# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = ExprTuple(Mult(b, Add(two, three, one, sub_expr1).with_subtraction_at()), Add(Mult(b, two), Mult(b, three), Mult(b, one), Mult(b, sub_expr1)).with_subtraction_at(3))
# Out:
# expr: (b * (2 + 3 + 1 + (-1)), (b * 2) + (b * 3) + (b * 1) + (b * (-1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b \cdot \left(2 + 3 + 1 + \left(-1\right)\right), \left(b \cdot 2\right) + \left(b \cdot 3\right) + \left(b \cdot 1\right) + \left(b \cdot \left(-1\right)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (b * (2 + 3 + 1 + (-1)), (b * 2) + (b * 3) + (b * 1) + (b * (-1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. b * (2 + 3 + 1 + (-1))
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (b * 2) + (b * 3) + (b * 1) + (b * (-1))
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (b, 2 + 3 + 1 + (-1))
#    core type: ExprTuple
#    sub-expressions: 19, 5
# 4. (b * 2, b * 3, b * 1, b * (-1))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 2 + 3 + 1 + (-1)
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. b * 2
#    core type: Operation
#    operator: 15
#    operands: 12
# 7. b * 3
#    core type: Operation
#    operator: 15
#    operands: 13
# 8. b * 1
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. b * (-1)
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (2, 3, 1, -1)
#     core type: ExprTuple
# ...
