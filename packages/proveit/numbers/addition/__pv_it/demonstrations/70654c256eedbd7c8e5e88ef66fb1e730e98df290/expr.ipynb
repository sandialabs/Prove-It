# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, a, b
from proveit.numbers import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Mult(two, a), Variable("_a", latex_format = r"{_{-}a}"), Add(b, b), Add(two, three, four))
# Out:
# expr: (2 * a) + _a + (b + b) + (2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot a\right) + {_{-}a} + \left(b + b\right) + \left(2 + 3 + 4\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * a) + _a + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. (2 * a, _a, b + b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. 2 * a
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. _a
#    core type: Variable
#    sub-expressions:
# 4. b + b
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. 2 + 3 + 4
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (2, a)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 8. (b, b)
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
