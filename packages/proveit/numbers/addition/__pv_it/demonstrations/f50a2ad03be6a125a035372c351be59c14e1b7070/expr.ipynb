# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(two, three, four, a, a, c, zero, c, b, b), Add(Mult(two, a), Add(c, c), Add(b, b), Add(two, three, four)))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b, (2 * a) + (c + c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + 3 + 4 + a + a + c + 0 + c + b + b, \left(2 \cdot a\right) + \left(c + c\right) + \left(b + b\right) + \left(2 + 3 + 4\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b, (2 * a) + (c + c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (2 * a) + (c + c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (2, 3, 4, a, a, c, 0, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 19, 20, 21, 16, 16, 17, 5, 17, 18, 18
# 4. (2 * a, c + c, b + b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. 2 * a
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. c + c
#    core type: Operation
#    operator: 14
#    operands: 12
# 8. b + b
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. 2 + 3 + 4
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2, a)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 12. (c, c)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. (b, b)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
