# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(three, b)
sub_expr2 = Mult(two, b)
expr = Equals(Add(c, c, two, sub_expr1, sub_expr2), Add(c, c, sub_expr1, two, sub_expr2))
# Out:
# expr: (c + c + 2 + (3 * b) + (2 * b)) = (c + c + (3 * b) + 2 + (2 * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c + c + 2 + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right) = \left(c + c + \left(3 \cdot b\right) + 2 + \left(2 \cdot b\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c + c + 2 + (3 * b) + (2 * b)) = (c + c + (3 * b) + 2 + (2 * b))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (c + c + 2 + (3 * b) + (2 * b), c + c + (3 * b) + 2 + (2 * b))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. c + c + 2 + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. c + c + (3 * b) + 2 + (2 * b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (c, c, 2, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 15, 9, 10
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (c, c, 3 * b, 2, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 9, 15, 10
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. 2 * b
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (3, b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
