# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, d
from proveit.logic import InSet
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
expr = InSet(Add(a, b, one, d), NaturalPos)
# Out:
# expr: (a + b + 1 + d) in NaturalPos

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + 1 + d\right) \in \mathbb{N}^+

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + b + 1 + d) in NaturalPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (a + b + 1 + d, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + b + 1 + d
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. NaturalPos
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (a, b, 1, d)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. d
#     core type: Variable
#     sub-expressions:
