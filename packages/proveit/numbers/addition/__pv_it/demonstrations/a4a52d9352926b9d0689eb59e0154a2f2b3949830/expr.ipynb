# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, five, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, b, c, a, b, a, c, b, a, c, a), Add(Mult(five, a), Mult(three, b), Add(c, c, c)))
# Out:
# expr: (a + b + c + a + b + a + c + b + a + c + a, (5 * a) + (3 * b) + (c + c + c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + c + a + b + a + c + b + a + c + a, \left(5 \cdot a\right) + \left(3 \cdot b\right) + \left(c + c + c\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + b + c + a + b + a + c + b + a + c + a, (5 * a) + (3 * b) + (c + c + c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + b + c + a + b + a + c + b + a + c + a
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (5 * a) + (3 * b) + (c + c + c)
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (a, b, c, a, b, a, c, b, a, c, a)
#    core type: ExprTuple
#    sub-expressions: 14, 16, 17, 14, 16, 14, 17, 16, 14, 17, 14
# 4. (5 * a, 3 * b, c + c + c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. 5 * a
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. 3 * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. c + c + c
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (5, a)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (3, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (c, c, c)
#     core type: ExprTuple
#     sub-expressions: 17, 17, 17
# 13. 5
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
