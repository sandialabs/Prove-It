# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c
from proveit.numbers import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(b)
sub_expr2 = Mult(three, b)
sub_expr3 = Mult(two, b)
expr = ExprTuple(Add(Mult(one, two), b, c, sub_expr2, sub_expr3, sub_expr1, Mult(one, c)), Add(two, b, c, sub_expr2, sub_expr3, sub_expr1, c))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c), 2 + b + c + (3 * b) + (2 * b) - b + c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 \cdot 2\right) + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) - b + \left(1 \cdot c\right), 2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) - b + c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c), 2 + b + c + (3 * b) + (2 * b) - b + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. 2 + b + c + (3 * b) + (2 * b) - b + c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 * 2, b, c, 3 * b, 2 * b, -b, 1 * c)
#    core type: ExprTuple
#    sub-expressions: 6, 21, 18, 8, 9, 10, 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2, b, c, 3 * b, 2 * b, -b, c)
#    core type: ExprTuple
#    sub-expressions: 20, 21, 18, 8, 9, 10, 18
# 6. 1 * 2
#    core type: Operation
#    operator: 14
#    operands: 11
# 7. 1 * c
#    core type: Operation
#    operator: 14
#    operands: 12
# 8. 3 * b
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. 2 * b
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. -b
#     core type: Operation
#     operator: 16
#     operand: 21
# 11. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 12. (1, c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
