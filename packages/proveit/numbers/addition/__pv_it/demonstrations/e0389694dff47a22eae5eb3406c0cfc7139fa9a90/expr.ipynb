# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Equals
from proveit.numbers import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(two, a)
sub_expr2 = Add(b, b)
sub_expr3 = Add(one, two, three)
expr = Equals(Add(sub_expr1, Add(c, c, c), sub_expr2, sub_expr3), Add(sub_expr1, Mult(three, c), sub_expr2, sub_expr3))
# Out:
# expr: ((2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3)) = ((2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot a\right) + \left(c + c + c\right) + \left(b + b\right) + \left(1 + 2 + 3\right)\right) = \left(\left(2 \cdot a\right) + \left(3 \cdot c\right) + \left(b + b\right) + \left(1 + 2 + 3\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3)) = ((2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3), (2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * a) + (c + c + c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. (2 * a) + (3 * c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (2 * a, c + c + c, b + b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10, 11
# 6. (2 * a, 3 * c, b + b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. c + c + c
#    core type: Operation
#    operator: 17
#    operands: 12
# 8. 2 * a
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. 3 * c
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. b + b
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. 1 + 2 + 3
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (c, c, c)
#     core type: ExprTuple
#     sub-expressions: 20, 20, 20
# 13. (2, a)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (3, c)
#     core type: ExprTuple
#     sub-expressions: 24, 20
# 16. (b, b)
#     core type: ExprTuple
#     sub-expressions: 21, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. 2
#     core type: Literal
#     sub-expressions:
# 24. 3
#     core type: Literal
#     sub-expressions:
