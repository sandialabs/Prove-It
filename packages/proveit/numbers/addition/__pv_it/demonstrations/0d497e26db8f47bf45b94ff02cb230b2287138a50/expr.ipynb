# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.numbers import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(two, a), Mult(two, c), Mult(two, b), Add(two, three, four))
# Out:
# expr: (2 * a, 2 * c, 2 * b, 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot a, 2 \cdot c, 2 \cdot b, 2 + 3 + 4\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * a, 2 * c, 2 * b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. 2 * a
#    core type: Operation
#    operator: 7
#    operands: 5
# 2. 2 * c
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. 2 * b
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. 2 + 3 + 4
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. (2, a)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 6. (2, c)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (2, b)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. 4
#     core type: Literal
#     sub-expressions:
