# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i
from proveit.core_expr_types import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Natural, RealPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i], InSet(Add(a_1_to_i), RealPos), domains = [RealPos]), InSet(i, Natural))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos) if i in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{i} \in \mathbb{R}^+}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}^+\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos) if i in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{i} in RealPos} ((a_{1} + ..a_{_a}.. + a_{i}) in RealPos)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. i in Natural
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in RealPos if (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{i} in RealPos).
#    core type: Lambda
#    parameters: 16\n   body: 6
# 5. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. {(a_{1} + ..a_{_a}.. + a_{i}) in RealPos if (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{i} in RealPos).
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. Natural
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} + ..a_{_a}.. + a_{i}) in RealPos
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{i} in RealPos)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a_{1} + ..a_{_a}.. + a_{i}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 13, 26
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{i} in RealPos)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. a_{1} + ..a_{_a}.. + a_{i}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{i} in RealPos)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 28
#     body: 19
# 18. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. a_{_a} in RealPos
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> a_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. a_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. RealPos
#     core type: Literal
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
