# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#leftward_commutation">leftward_commutation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import leftward_commutation

# %%
# check that the built expression is the same as the stored expression
assert leftward_commutation.expr == stored_expr
assert leftward_commutation.expr._style_id == stored_expr._style_id
print("Passed sanity check: leftward_commutation matches stored_expr")
# Out:
# Passed sanity check: leftward_commutation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftward_commutation.latex())
# Out:
# \vdash \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}, c, d_{1}, \ldots, d_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} + \ldots + a_{i} + b_{1} + \ldots + b_{j} + c + d_{1} + \ldots + d_{k}\right) =  \\ \left(a_{1} + \ldots + a_{i} + c + b_{1} + \ldots + b_{j} + d_{1} + \ldots + d_{k}\right) \end{array}\right)\right]

# %%
# display the expression information
leftward_commutation.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 44, 46, 49
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k}) -> {(a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Lambda
#    parameters: 29\n   body: 9
# 8. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{i} in Complex ,  b_{1} in Complex ,  ..b_{_a} in Complex.. ,  b_{j} in Complex ,  c in Complex ,  d_{1} in Complex ,  ..d_{_a} in Complex.. ,  d_{k} in Complex.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. i in Natural
#     core type: Operation
#     operator: 52
#     operands: 15
# 11. j in Natural
#     core type: Operation
#     operator: 52
#     operands: 16
# 12. k in Natural
#     core type: Operation
#     operator: 52
#     operands: 17
# 13. (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{i} in Complex) and (b_{1} in Complex) and ..(b_{_a} in Complex).. and (b_{j} in Complex) and (c in Complex) and (d_{1} in Complex) and ..(d_{_a} in Complex).. and (d_{k} in Complex)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 22
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 22
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}, a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (a_{1} in Complex, ..a_{_a} in Complex.., a_{i} in Complex, b_{1} in Complex, ..b_{_a} in Complex.., b_{j} in Complex, c in Complex, d_{1} in Complex, ..d_{_a} in Complex.., d_{k} in Complex)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c + d_{1} + ..d_{_a}.. + d_{k}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. a_{1} + ..a_{_a}.. + a_{i} + c + b_{1} + ..b_{_a}.. + b_{j} + d_{1} + ..d_{_a}.. + d_{k}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 48
#     end_index: 44
# 26. (b_{1} in Complex), ..(b_{_a} in Complex).., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 48
#     end_index: 46
# 27. c in Complex
#     core type: Operation
#     operator: 52
#     operands: 34
# 28. (d_{1} in Complex), ..(d_{_a} in Complex).., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 48
#     end_index: 49
# 29. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 41, 38
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 36, 41, 37, 38
# 32. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 39
# 33. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 40
# 34. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 57
# 35. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 42
# 36. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 48
#     end_index: 44
# 37. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 48
#     end_index: 46
# 38. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 39. a_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 50
# 40. b_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 51
# 41. c
#     core type: Variable
#     sub-expressions:
# 42. d_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. _a -> b_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 55
# 46. j
#     core type: Variable
#     sub-expressions:
# 47. _a -> d_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. k
#     core type: Variable
#     sub-expressions:
# 50. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 51. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 55. b_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. d_{_a}
#     core type: IndexedVar
# variable: 60
# index: 61
# 57. Complex
#     core type: Literal
#     sub-expressions:
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. b
#     core type: Variable
#     sub-expressions:
# 60. d
#     core type: Variable
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
