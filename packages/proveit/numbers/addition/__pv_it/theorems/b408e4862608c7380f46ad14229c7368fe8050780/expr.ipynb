# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, i
from proveit.core_expr_types import a_1_to_i
from proveit.logic import And, InSet
from proveit.numbers import Add, Real, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(InSet(Add(a_1_to_i), Real), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Real), one, i)))
# Out:
# expr: {(a_{1} + ..a_{_a}.. + a_{i}) in Real if (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{i} in Real).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R} \textrm{ if } \left(a_{1} \in \mathbb{R}\right) \land \ldots \land \left(a_{i} \in \mathbb{R}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} + ..a_{_a}.. + a_{i}) in Real if (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{i} in Real).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} + ..a_{_a}.. + a_{i}) in Real
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (a_{1} in Real) and ..(a_{_a} in Real).. and (a_{i} in Real)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} + ..a_{_a}.. + a_{i}, Real)
#    core type: ExprTuple
#    sub-expressions: 6, 19
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} in Real, ..a_{_a} in Real.., a_{i} in Real)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. a_{1} + ..a_{_a}.. + a_{i}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in Real), ..(a_{_a} in Real).., (a_{i} in Real)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (a_{1}, ..a_{_a}.., a_{i})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. _a -> (a_{_a} in Real)
#     core type: Lambda
#     parameter: 21
#     body: 12
# 11. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. a_{_a} in Real
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. _a -> a_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. i
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (a_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. a_{_a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 19. Real
#     core type: Literal
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. _a
#     core type: Variable
#     sub-expressions:
