# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Complex), InSet(x, Complex), InSet(y, Complex), Equals(x, y))
# Out:
# expr: (a in Complex) and (x in Complex) and (y in Complex) and (x = y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(x \in \mathbb{C}\right) \land \left(y \in \mathbb{C}\right) \land \left(x = y\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex) and (x in Complex) and (y in Complex) and (x = y)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complex, x in Complex, y in Complex, x = y)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Complex
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. x in Complex
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. y in Complex
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. x = y
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x, y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. Complex
#     core type: Literal
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
