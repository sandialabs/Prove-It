# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.numbers import Add, LessEq, Natural, Real, RealNonPos

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, c_1_to_j], instance_expr = Forall(instance_param_or_params = [b], instance_expr = LessEq(Add(a_1_to_i, b, c_1_to_j), b), domain = Real), domain = RealNonPos), And(InSet(i, Natural), InSet(j, Natural))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{R}^{\le 0}}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right) \leq b\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNonPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b)] if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j)
#    core type: ExprTuple
#    sub-expressions: 47, 50
# 2. {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNonPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b)] if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNonPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b)]
#    core type: Operation
#    operator: 17
#    operand: 7
# 4. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b) if (a_{1} in RealNonPos) ,  (a_{2} in RealNonPos) ,  ... ,  (a_{i} in RealNonPos), (c_{1} in RealNonPos) ,  (c_{2} in RealNonPos) ,  ... ,  (c_{j} in RealNonPos).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b) if (a_{1} in RealNonPos) ,  (a_{2} in RealNonPos) ,  ... ,  (a_{i} in RealNonPos), (c_{1} in RealNonPos) ,  (c_{2} in RealNonPos) ,  ... ,  (c_{j} in RealNonPos).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. i in Natural
#    core type: Operation
#    operator: 36
#    operands: 12
# 9. j in Natural
#    core type: Operation
#    operator: 36
#    operands: 13
# 10. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 11. {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b) if (a_{1} in RealNonPos) ,  (a_{2} in RealNonPos) ,  ... ,  (a_{i} in RealNonPos), (c_{1} in RealNonPos) ,  (c_{2} in RealNonPos) ,  ... ,  (c_{j} in RealNonPos).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 16
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 16
# 14. forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b)
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (a_{1} in RealNonPos) and  (a_{2} in RealNonPos) and  ... and  (a_{i} in RealNonPos)and (c_{1} in RealNonPos) and  (c_{2} in RealNonPos) and  ... and  (c_{j} in RealNonPos)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b if b in Real.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1} in RealNonPos), (a_{2} in RealNonPos), ..., (a_{i} in RealNonPos),(c_{1} in RealNonPos), (c_{2} in RealNonPos), ..., (c_{j} in RealNonPos))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b if b in Real.
#     core type: Lambda
#     parameter: 44
#     body: 25
# 22. (a_{1} in RealNonPos), (a_{2} in RealNonPos), ..., (a_{i} in RealNonPos)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 49
#     end_index: 47
# 23. (c_{1} in RealNonPos), (c_{2} in RealNonPos), ..., (c_{j} in RealNonPos)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 49
#     end_index: 50
# 24. (b)
#     core type: ExprTuple
#     sub-expressions: 44
# 25. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b if b in Real.
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. _a -> (a_{_a} in RealNonPos)
#     core type: Lambda
#     parameter: 56
#     body: 30
# 27. _a -> (c_{_a} in RealNonPos)
#     core type: Lambda
#     parameter: 56
#     body: 31
# 28. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) <= b
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. b in Real
#     core type: Operation
#     operator: 36
#     operands: 34
# 30. a_{_a} in RealNonPos
#     core type: Operation
#     operator: 36
#     operands: 35
# 31. c_{_a} in RealNonPos
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. <=
#     core type: Literal
#     sub-expressions:
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}, b)
#     core type: ExprTuple
#     sub-expressions: 38, 44
# 34. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 44, 39
# 35. (a_{_a}, RealNonPos)
#     core type: ExprTuple
#     sub-expressions: 51, 40
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (c_{_a}, RealNonPos)
#     core type: ExprTuple
#     sub-expressions: 52, 40
# 38. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. Real
#     core type: Literal
#     sub-expressions:
# 40. RealNonPos
#     core type: Literal
#     sub-expressions:
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 43. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 49
#     end_index: 47
# 44. b
#     core type: Variable
#     sub-expressions:
# 45. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 51
# 47. i
#     core type: Variable
#     sub-expressions:
# 48. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 52. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
