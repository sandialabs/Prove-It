# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.core_expr_types import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([i], Forall([a_1_to_i], InSet(Add(a_1_to_i), NaturalPos), domains = [NaturalPos]), domains = [Natural])
# Out:
# expr: forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i} \in \mathbb{N}^+}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{N}^+\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos) if i in Natural.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos) if i in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Natural
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{i} in NaturalPos).
#    core type: Lambda
#    parameters: 18\n   body: 8
# 7. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{i} in NaturalPos).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} + ..a_{_a}.. + a_{i}) in NaturalPos
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{i} in NaturalPos)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a_{1} + ..a_{_a}.. + a_{i}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a_{1} in NaturalPos, ..a_{_a} in NaturalPos.., a_{i} in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. a_{1} + ..a_{_a}.. + a_{i}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (a_{1} in NaturalPos), ..(a_{_a} in NaturalPos).., (a_{i} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (a_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. a_{_a} in NaturalPos
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (a_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. NaturalPos
#     core type: Literal
#     sub-expressions:
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
