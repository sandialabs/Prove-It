# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Real

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Real), InSet(x, Real), InSet(y, Real), LessEq(x, y))
# Out:
# expr: (a in Real) and (x in Real) and (y in Real) and (x <= y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(x \in \mathbb{R}\right) \land \left(y \in \mathbb{R}\right) \land \left(x \leq y\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real) and (x in Real) and (y in Real) and (x <= y)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Real, x in Real, y in Real, x <= y)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Real
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. x in Real
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. y in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. x <= y
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. (x, Real)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (y, Real)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. (x, y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. Real
#     core type: Literal
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
