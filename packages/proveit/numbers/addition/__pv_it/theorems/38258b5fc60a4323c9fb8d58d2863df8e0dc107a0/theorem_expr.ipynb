# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#left_add_lesseq">left_add_lesseq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import left_add_lesseq

# %%
# check that the built expression is the same as the stored expression
assert left_add_lesseq.expr == stored_expr
assert left_add_lesseq.expr._style_id == stored_expr._style_id
print("Passed sanity check: left_add_lesseq matches stored_expr")
# Out:
# Passed sanity check: left_add_lesseq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(left_add_lesseq.latex())
# Out:
# \vdash \forall_{a, x, y \in \mathbb{R}~|~x \leq y}~\left(\left(a + x\right) \leq \left(a + y\right)\right)

# %%
# display the expression information
left_add_lesseq.expr_info()
# Out:
# 0. forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, x, y) -> {(a + x) <= (a + y) if a in Real ,  x in Real ,  y in Real ,  x <= y.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 25, 27, 28
# 4. {(a + x) <= (a + y) if a in Real ,  x in Real ,  y in Real ,  x <= y.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a + x) <= (a + y)
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (a in Real) and (x in Real) and (y in Real) and (x <= y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a + x, a + y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, x in Real, y in Real, x <= y)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. a + x
# ...
