# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Add, Complex

# %%
# build up the expression from sub-expressions
expr = Conditional(NotEquals(Add(a, x), Add(a, y)), And(InSet(a, Complex), InSet(x, Complex), InSet(y, Complex), NotEquals(x, y)))
# Out:
# expr: {(a + x) != (a + y) if a in Complex ,  x in Complex ,  y in Complex ,  x != y.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a + x\right) \neq \left(a + y\right) \textrm{ if } a \in \mathbb{C} ,  x \in \mathbb{C} ,  y \in \mathbb{C} ,  x \neq y\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a + x) != (a + y) if a in Complex ,  x in Complex ,  y in Complex ,  x != y.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a + x) != (a + y)
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a in Complex) and (x in Complex) and (y in Complex) and (x != y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a + x, a + y)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Complex, x in Complex, y in Complex, x != y)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 6. a + x
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. a + y
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a in Complex
#    core type: Operation
#    operator: 17
#    operands: 15
# 9. x in Complex
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. y in Complex
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. x != y
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. (a, x)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (a, y)
#     core type: ExprTuple
#     sub-expressions: 21, 24
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (x, y)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. Complex
#     core type: Literal
#     sub-expressions:
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
