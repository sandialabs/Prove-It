# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.numbers import Add, Natural, Real, RealPos, greater, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, c_1_to_j], instance_expr = Forall(instance_param_or_params = [b], instance_expr = greater(Add(a_1_to_i, b, c_1_to_j), b), domain = Real), domain = RealPos), And(InSet(i, Natural), InSet(j, Natural), greater(Add(i, j), zero))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{R}^+}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right) > b\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  \left(i + j\right) > 0\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b)] if i in Natural ,  j in Natural ,  (i + j) > 0.
#    core type: Lambda
#    parameters: 24\n   body: 1
# 1. {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b)] if i in Natural ,  j in Natural ,  (i + j) > 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealPos} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b)]
#    core type: Operation
#    operator: 20
#    operand: 6
# 3. (i in Natural) and (j in Natural) and ((i + j) > 0)
#    core type: Operation
#    operator: 22
#    operands: 5
# 4. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (c_{1} in RealPos) ,  (c_{2} in RealPos) ,  ... ,  (c_{j} in RealPos).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (i in Natural, j in Natural, (i + j) > 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (c_{1} in RealPos) ,  (c_{2} in RealPos) ,  ... ,  (c_{j} in RealPos).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 7. i in Natural
#    core type: Operation
#    operator: 40
#    operands: 12
# 8. j in Natural
#    core type: Operation
#    operator: 40
#    operands: 13
# 9. (i + j) > 0
#    core type: Operation
#    operator: 36
#    operands: 14
# 10. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 47, 49
# 11. {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b) if (a_{1} in RealPos) ,  (a_{2} in RealPos) ,  ... ,  (a_{i} in RealPos), (c_{1} in RealPos) ,  (c_{2} in RealPos) ,  ... ,  (c_{j} in RealPos).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 17
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 54, 17
# 14. (0, i + j)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b)
#     core type: Operation
#     operator: 20
#     operand: 25
# 16. (a_{1} in RealPos) and  (a_{2} in RealPos) and  ... and  (a_{i} in RealPos)and (c_{1} in RealPos) and  (c_{2} in RealPos) and  ... and  (c_{j} in RealPos)
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. i + j
#     core type: Operation
#     operator: 45
#     operands: 24
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. (b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b if b in Real.)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos),(c_{1} in RealPos), (c_{2} in RealPos), ..., (c_{j} in RealPos))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (i, j)
#     core type: ExprTuple
#     sub-expressions: 51, 54
# 25. b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b if b in Real.
#     core type: Lambda
#     parameter: 48
#     body: 29
# 26. (a_{1} in RealPos), (a_{2} in RealPos), ..., (a_{i} in RealPos)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 53
#     end_index: 51
# 27. (c_{1} in RealPos), (c_{2} in RealPos), ..., (c_{j} in RealPos)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 53
#     end_index: 54
# 28. (b)
#     core type: ExprTuple
#     sub-expressions: 48
# 29. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b if b in Real.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 60
#     body: 34
# 31. _a -> (c_{_a} in RealPos)
#     core type: Lambda
#     parameter: 60
#     body: 35
# 32. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) > b
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. b in Real
#     core type: Operation
#     operator: 40
#     operands: 38
# 34. a_{_a} in RealPos
#     core type: Operation
#     operator: 40
#     operands: 39
# 35. c_{_a} in RealPos
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. <
#     core type: Literal
#     sub-expressions:
# 37. (b, a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j})
#     core type: ExprTuple
#     sub-expressions: 48, 42
# 38. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 48, 43
# 39. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 55, 44
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (c_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 56, 44
# 42. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. Real
#     core type: Literal
#     sub-expressions:
# 44. RealPos
#     core type: Literal
#     sub-expressions:
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 47, 48, 49
# 47. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 53
#     end_index: 51
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 50. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. _a -> c_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 56
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 56. c_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. c
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
