# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Natural, zero

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j], instance_expr = Equals(Add(a_1_to_i, zero, b_1_to_j), Add(a_1_to_i, b_1_to_j)), domain = Complex), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + 0+ b_{1} +  b_{2} +  \ldots +  b_{j}\right) = \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j})) if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j})) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 38, 41
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j})) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 21
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}) -> {(a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#     core type: Lambda
#     parameters: 29\n    body: 13
# 11. i in Natural
#     core type: Operation
#     operator: 43
#     operands: 14
# 12. j in Natural
#     core type: Operation
#     operator: 43
#     operands: 15
# 13. {(a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 38, 18
# 15. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 41, 18
# 16. (a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}, a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 28
#     operands: 27
# 24. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 40
#     end_index: 38
# 26. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 40
#     end_index: 41
# 27. (a_{1}, a_{2}, ..., a_{i}, 0,b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 33, 32, 34
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 51
#     body: 35
# 31. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 51
#     body: 36
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 40
#     end_index: 38
# 34. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 35. a_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 42
# 36. b_{_a} in Complex
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. _a -> a_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 45
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. _a -> b_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 46
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. j
#     core type: Variable
#     sub-expressions:
# 42. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. a_{_a}
#     core type: IndexedVar
# variable: 48
# index: 51
# 46. b_{_a}
#     core type: IndexedVar
# variable: 49
# index: 51
# 47. Complex
#     core type: Literal
#     sub-expressions:
# 48. a
#     core type: Variable
#     sub-expressions:
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. (_a)
#     core type: ExprTuple
#     sub-expressions: 51
# 51. _a
#     core type: Variable
#     sub-expressions:
