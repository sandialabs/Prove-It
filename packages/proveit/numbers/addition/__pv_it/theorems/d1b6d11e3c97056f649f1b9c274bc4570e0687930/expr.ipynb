# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, c, j
from proveit.logic import InSet
from proveit.numbers import RealNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), RealNeg), one, j)
# Out:
# expr: (c_{1} in RealNeg), ..(c_{_a} in RealNeg).., (c_{j} in RealNeg)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c_{1} \in \mathbb{R}^-\right), \ldots, \left(c_{j} \in \mathbb{R}^-\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c_{1} in RealNeg), ..(c_{_a} in RealNeg).., (c_{j} in RealNeg)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> (c_{_a} in RealNeg)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. c_{_a} in RealNeg
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (c_{_a}, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. c_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 8. RealNeg
#    core type: Literal
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
