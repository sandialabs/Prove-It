# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#elim_zero_right">elim_zero_right</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/elim_zero_right/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.addition import elim_zero_right

# %%
# %dependencies elim_zero_right
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon elim_zero_right</h3>
