# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#leftward_commutation">leftward_commutation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import leftward_commutation

# %%
# check that the built expression is the same as the stored expression
assert leftward_commutation.expr == stored_expr
assert leftward_commutation.expr._style_id == stored_expr._style_id
print("Passed sanity check: leftward_commutation matches stored_expr")
# Out:
# Passed sanity check: leftward_commutation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{C}}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1} +  a_{2} +  \ldots +  a_{i}+ b_{1} +  b_{2} +  \ldots +  b_{j} + c+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) =  \\ \left(a_{1} +  a_{2} +  \ldots +  a_{i} + c+ b_{1} +  b_{2} +  \ldots +  b_{j}+ d_{1} +  d_{2} +  \ldots +  d_{k}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 46, 48, 51
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex) ,  c in Complex, (d_{1} in Complex) ,  (d_{2} in Complex) ,  ... ,  (d_{k} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k}) -> {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex) ,  c in Complex, (d_{1} in Complex) ,  (d_{2} in Complex) ,  ... ,  (d_{k} in Complex).
#     core type: Lambda
#     parameters: 31\n    body: 14
# 11. i in Natural
#     core type: Operation
#     operator: 54
#     operands: 15
# 12. j in Natural
#     core type: Operation
#     operator: 54
#     operands: 16
# 13. k in Natural
#     core type: Operation
#     operator: 54
#     operands: 17
# 14. {(a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{i} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{j} in Complex) ,  c in Complex, (d_{1} in Complex) ,  (d_{2} in Complex) ,  ... ,  (d_{k} in Complex).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 20
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 18. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{i} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex) and (c in Complex)and (d_{1} in Complex) and  (d_{2} in Complex) and  ... and  (d_{k} in Complex)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}, a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex), c in Complex,(d_{1} in Complex), (d_{2} in Complex), ..., (d_{k} in Complex))
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30
# 25. a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 32
#     operands: 31
# 26. a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{i} in Complex)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 50
#     end_index: 46
# 28. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 50
#     end_index: 48
# 29. c in Complex
#     core type: Operation
#     operator: 54
#     operands: 36
# 30. (d_{1} in Complex), (d_{2} in Complex), ..., (d_{k} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 50
#     end_index: 51
# 31. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 39, 43, 40
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (a_{1}, a_{2}, ..., a_{i}, c,b_{1}, b_{2}, ..., b_{j},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 38, 43, 39, 40
# 34. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 41
# 35. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 42
# 36. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 59
# 37. _a -> (d_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 44
# 38. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 46
# 39. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 40. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 41. a_{_a} in Complex
#     core type: Operation
#     operator: 54
#     operands: 52
# 42. b_{_a} in Complex
#     core type: Operation
#     operator: 54
#     operands: 53
# 43. c
#     core type: Variable
#     sub-expressions:
# 44. d_{_a} in Complex
#     core type: Operation
#     operator: 54
#     operands: 55
# 45. _a -> a_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 56
# 46. i
#     core type: Variable
#     sub-expressions:
# 47. _a -> b_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 57
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. _a -> d_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 58
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 59
# 53. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (d_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. b_{_a}
#     core type: IndexedVar
# variable: 61
# index: 64
# 58. d_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. b
#     core type: Variable
#     sub-expressions:
# 62. d
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
