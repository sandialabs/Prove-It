# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet
from proveit.numbers import Add, Complex

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Add(a, b), Complex), And(InSet(a, Complex), InSet(b, Complex)))
# Out:
# expr: {(a + b) in Complex if a in Complex ,  b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a + b\right) \in \mathbb{C} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a + b) in Complex if a in Complex ,  b in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a + b) in Complex
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in Complex) and (b in Complex)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a + b, Complex)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Complex, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a + b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in Complex
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in Complex
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. Complex
#     core type: Literal
#     sub-expressions:
