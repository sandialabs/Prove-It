# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_nat_pos_from_non_neg">add_nat_pos_from_non_neg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition import add_nat_pos_from_non_neg

# %%
# check that the built expression is the same as the stored expression
assert add_nat_pos_from_non_neg.expr == stored_expr
assert add_nat_pos_from_non_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_nat_pos_from_non_neg matches stored_expr")
# Out:
# Passed sanity check: add_nat_pos_from_non_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_nat_pos_from_non_neg.latex())
# Out:
# \vdash \forall_{i, j \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j} \in \mathbb{N}~|~b > 0}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) \in \mathbb{N}^+\right)\right]

# %%
# display the expression information
add_nat_pos_from_non_neg.expr_info()
# Out:
# 0. forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos) if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 39, 42
# 3. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j} in Natural | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalPos) if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
