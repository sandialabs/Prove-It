# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.numbers import Add, Greater, Natural, Real, RealPos

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall([a_1_to_i, c_1_to_j], Forall([b], Greater(Add(a_1_to_i, b, c_1_to_j), b), domains = [Real]), domains = [RealPos, RealPos]), And(InSet(i, Natural), InSet(j, Natural))))
# Out:
# expr: (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j} in RealPos} [forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)] if i in Natural ,  j in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{i}, c_{1}, \ldots, c_{j} \in \mathbb{R}^+}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) > b\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i, j) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j} in RealPos} [forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)] if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j)
#    core type: ExprTuple
#    sub-expressions: 44, 47
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j} in RealPos} [forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)] if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j} in RealPos} [forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)]
#    core type: Operation
#    operator: 15
#    operand: 5
# 4. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}) -> {forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{i} in RealPos ,  c_{1} in RealPos ,  ..c_{_a} in RealPos.. ,  c_{j} in RealPos.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j})
#    core type: ExprTuple
#    sub-expressions: 40, 42
# 8. {forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b) if a_{1} in RealPos ,  ..a_{_a} in RealPos.. ,  a_{i} in RealPos ,  c_{1} in RealPos ,  ..c_{_a} in RealPos.. ,  c_{j} in RealPos.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. i in Natural
#    core type: Operation
#    operator: 35
#    operands: 13
# 10. j in Natural
#     core type: Operation
#     operator: 35
#     operands: 14
# 11. forall_{b in Real} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (a_{1} in RealPos) and ..(a_{_a} in RealPos).. and (a_{i} in RealPos) and (c_{1} in RealPos) and ..(c_{_a} in RealPos).. and (c_{j} in RealPos)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 19
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 19
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. b -> {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b if b in Real.
#     core type: Lambda
#     parameter: 41
#     body: 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{i} in RealPos, c_{1} in RealPos, ..c_{_a} in RealPos.., c_{j} in RealPos)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b if b in Real.
#     core type: Conditional
#     value: 23
#     condition: 24
# 21. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{i} in RealPos)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 46
#     end_index: 44
# 22. (c_{1} in RealPos), ..(c_{_a} in RealPos).., (c_{j} in RealPos)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 46
#     end_index: 47
# 23. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. b in Real
#     core type: Operation
#     operator: 35
#     operands: 29
# 25. _a -> (a_{_a} in RealPos)
#     core type: Lambda
#     parameter: 52
#     body: 30
# 26. _a -> (c_{_a} in RealPos)
#     core type: Lambda
#     parameter: 52
#     body: 31
# 27. >
#     core type: Literal
#     sub-expressions:
# 28. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}, b)
#     core type: ExprTuple
#     sub-expressions: 32, 41
# 29. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 41, 33
# 30. a_{_a} in RealPos
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. c_{_a} in RealPos
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. Real
#     core type: Literal
#     sub-expressions:
# 34. (a_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 48, 39
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (c_{_a}, RealPos)
#     core type: ExprTuple
#     sub-expressions: 49, 39
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 39. RealPos
#     core type: Literal
#     sub-expressions:
# 40. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 44
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 48
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 49
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. a_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 49. c_{_a}
#     core type: IndexedVar
# variable: 51
# index: 52
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. c
#     core type: Variable
#     sub-expressions:
# 52. _a
#     core type: Variable
#     sub-expressions:
