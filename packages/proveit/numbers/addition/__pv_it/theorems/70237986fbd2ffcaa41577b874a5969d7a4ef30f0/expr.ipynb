# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.numbers import Add, Less, Natural, Real, RealNeg, greater, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, c_1_to_j], instance_expr = Forall(instance_param_or_params = [b], instance_expr = Less(Add(a_1_to_i, b, c_1_to_j), b), domain = Real), domain = RealNeg), And(InSet(i, Natural), InSet(j, Natural), greater(Add(i, j), zero)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{R}^-}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right) < b\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  \left(i + j\right) > 0\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNeg} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)] if i in Natural ,  j in Natural ,  (i + j) > 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNeg} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)] if i in Natural ,  j in Natural ,  (i + j) > 0.
#    core type: Lambda
#    parameters: 25\n   body: 2
# 2. {forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNeg} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)] if i in Natural ,  j in Natural ,  (i + j) > 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNeg} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)]
#    core type: Operation
#    operator: 21
#    operand: 7
# 4. (i in Natural) and (j in Natural) and ((i + j) > 0)
#    core type: Operation
#    operator: 23
#    operands: 6
# 5. ((a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b) if (a_{1} in RealNeg) ,  (a_{2} in RealNeg) ,  ... ,  (a_{i} in RealNeg), (c_{1} in RealNeg) ,  (c_{2} in RealNeg) ,  ... ,  (c_{j} in RealNeg).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (i in Natural, j in Natural, (i + j) > 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j}) -> {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b) if (a_{1} in RealNeg) ,  (a_{2} in RealNeg) ,  ... ,  (a_{i} in RealNeg), (c_{1} in RealNeg) ,  (c_{2} in RealNeg) ,  ... ,  (c_{j} in RealNeg).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 8. i in Natural
#    core type: Operation
#    operator: 41
#    operands: 13
# 9. j in Natural
#    core type: Operation
#    operator: 41
#    operands: 14
# 10. (i + j) > 0
#     core type: Operation
#     operator: 37
#     operands: 15
# 11. (a_{1}, a_{2}, ..., a_{i},c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 48, 50
# 12. {forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b) if (a_{1} in RealNeg) ,  (a_{2} in RealNeg) ,  ... ,  (a_{i} in RealNeg), (c_{1} in RealNeg) ,  (c_{2} in RealNeg) ,  ... ,  (c_{j} in RealNeg).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 52, 18
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 18
# 15. (0, i + j)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)
#     core type: Operation
#     operator: 21
#     operand: 26
# 17. (a_{1} in RealNeg) and  (a_{2} in RealNeg) and  ... and  (a_{i} in RealNeg)and (c_{1} in RealNeg) and  (c_{2} in RealNeg) and  ... and  (c_{j} in RealNeg)
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. 0
#     core type: Literal
#     sub-expressions:
# 20. i + j
#     core type: Operation
#     operator: 46
#     operands: 25
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. (b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b if b in Real.)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in RealNeg), (a_{2} in RealNeg), ..., (a_{i} in RealNeg),(c_{1} in RealNeg), (c_{2} in RealNeg), ..., (c_{j} in RealNeg))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. (i, j)
#     core type: ExprTuple
#     sub-expressions: 52, 55
# 26. b -> {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b if b in Real.
#     core type: Lambda
#     parameter: 49
#     body: 30
# 27. (a_{1} in RealNeg), (a_{2} in RealNeg), ..., (a_{i} in RealNeg)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 54
#     end_index: 52
# 28. (c_{1} in RealNeg), (c_{2} in RealNeg), ..., (c_{j} in RealNeg)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 55
# 29. (b)
#     core type: ExprTuple
#     sub-expressions: 49
# 30. {(a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b if b in Real.
#     core type: Conditional
#     value: 33
#     condition: 34
# 31. _a -> (a_{_a} in RealNeg)
#     core type: Lambda
#     parameter: 61
#     body: 35
# 32. _a -> (c_{_a} in RealNeg)
#     core type: Lambda
#     parameter: 61
#     body: 36
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. b in Real
#     core type: Operation
#     operator: 41
#     operands: 39
# 35. a_{_a} in RealNeg
#     core type: Operation
#     operator: 41
#     operands: 40
# 36. c_{_a} in RealNeg
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. <
#     core type: Literal
#     sub-expressions:
# 38. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}, b)
#     core type: ExprTuple
#     sub-expressions: 43, 49
# 39. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 49, 44
# 40. (a_{_a}, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 56, 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (c_{_a}, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 57, 45
# 43. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. Real
#     core type: Literal
#     sub-expressions:
# 45. RealNeg
#     core type: Literal
#     sub-expressions:
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 48. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 54
#     end_index: 52
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 51. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. _a -> c_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 57
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. j
#     core type: Variable
#     sub-expressions:
# 56. a_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 57. c_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. c
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
