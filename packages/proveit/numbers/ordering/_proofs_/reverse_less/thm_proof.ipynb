# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">ordering</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#reverse_less">reverse_less</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, y
from proveit.numbers.ordering  import reverse_relation
theory = proveit.Theory() # the theorem's theory

# %%
# %proving reverse_less

# %%
defaults.assumptions = reverse_less.all_conditions()

# %%
reverse_relation

# %%
spec_rev_rel = reverse_relation.instantiate({x:x, y:y}, assumptions = defaults.assumptions)

# %%
spec_rev_rel.derive_left_via_equality()

# %%
# %qed
