# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">ordering</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#reverse_less_eq">reverse_less_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, y
from proveit.logic.equality._axioms_ import equals_symmetry
from proveit.numbers import GreaterEq
from proveit.numbers.ordering._axioms_ import reverse_relation, less_eq_def, greater_eq_def
from proveit.logic.equality._theorems_ import sub_right_side_into

theory = proveit.Theory() # the theorem's theory

# %%
# %proving reverse_less_eq

# %%
defaults.assumptions = reverse_less_eq.all_conditions()

# %%
less_eq_def

# %%
spec_less_eq_def = less_eq_def.instantiate({x:x, y:y})

# %%
expanded = spec_less_eq_def.derive_right_via_equality()

# %%
reverse_relation

# %%
subleft = reverse_relation.instantiate({x:x, y:y}).sub_left_side_into(expanded, )

# %%
equals_symmetry

# %%
subboth = equals_symmetry.instantiate({x:x, y:y}).sub_left_side_into(subleft)

# %%
spec_greater_eq_def = greater_eq_def.instantiate({x:y, y:x}, assumptions = [GreaterEq(y,x)])

# %%
spec_greater_eq_def.sub_left_side_into(subboth,)

# %%
# %qed
