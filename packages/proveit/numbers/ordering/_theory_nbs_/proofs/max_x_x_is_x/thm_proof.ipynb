# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#max_x_x_is_x">max_x_x_is_x</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import x, y, defaults
from proveit.numbers.ordering import max_def_bin

# %%
# %proving max_x_x_is_x
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="max_x_x_is_x">max_x_x_is_x:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/91369821e1f1c5ee80cf40ceb0e9a2e1ed8899360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e1955b0e8c6ac05ca6334b93e4d477024f8451360/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = max_x_x_is_x.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_max_x_x_is_x/a9035fc3044be597753d318e1720d849ea14753c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
max_def_bin
# Out:
# |- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)

# %%
max_def_bin_inst = max_def_bin.instantiate({x: x, y: x})
# Out:
# <strong id="max_def_bin_inst">max_def_bin_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_x_x_is_x/f564e519ca0882ece33cbd4c0b00a4431ae530f10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_max_x_x_is_x/59d687f62610d1a4478faea17c7ec60b03a8edcd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# The rhs of the max_def_bin_inst above cannot be simplified until we explicitly establish that the second condition is False.

# %%
from proveit.numbers.ordering import not_less_from_less_eq
not_less_from_less_eq
# Out:
# |- forall_{x, y in Real | x <= y} [not](y < x)

# %%
not_less_from_less_eq.instantiate({x: x, y: x})
# Out:
# {x in Real} |- [not](x < x)

# %% [markdown]
# Now we can simplify the Max(x, x) definition in max_def_bin_inst:

# %%
max_def_bin_inst.inner_expr().rhs.simplify()
# Out:
# {x in Real} |- Max(x, x) = x
# max_x_x_is_x may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.ordering.max_x_x_is_x has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x in Real} (Max(x, x) = x)
# 1	instantiation	2, 3, 4	{x in Real} |- Max(x, x) = x
# 	P(_a) : Max(x, x) = _a, x : {x if x >= x; x if x > x., y : x
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	instantiation	5, 24	{x in Real} |- Max(x, x) = {x if x >= x; x if x > x.
# 	x : x, y : x
# 4	instantiation	8, 6, 7	{x in Real} |- {x if x >= x; x if x > x. = x
# 	x : {x if x >= x; x if x > x., y : {x; x if FALSE., z : x
# 5	axiom		|- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)
# 	proveit.numbers.ordering.max_def_bin
# 6	instantiation	8, 9, 10	{x in Real} |- {x if x >= x; x if x > x. = {x; x if FALSE.
# 	x : {x if x >= x; x if x > x., y : {x; x if x > x., z : {x; x if FALSE.
# 7	instantiation	11, 12, 13, 14	|- {x; x if FALSE. = x
# 	m : 0, n : 1, a : (), b : x, c : (x)
# 8	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 9	instantiation	16, 15	{x in Real} |- {x if x >= x; x if x > x. = {x; x if x > x.
# 	f(_a) : {_a; x if x > x., x : {x if x >= x., y : x
# 10	instantiation	16, 17	{x in Real} |- {x; x if x > x. = {x; x if FALSE.
# 	f(_a) : {x; _a., x : {x if x > x., y : {x if FALSE.
# 11	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 12	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 13	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 14	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 15	instantiation	18, 22	{x in Real} |- {x if x >= x. = x
# 	a : x, Q : x >= x
# 16	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 17	instantiation	19, 20	{x in Real} |- {x if x > x. = {x if FALSE.
# 	a : x, Q : x > x
# 18	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 19	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 20	instantiation	21, 24, 22	{x in Real} |- [not](x < x)
# 	x : x, y : x
# 21	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 22	instantiation	23, 24, 25	{x in Real} |- x <= x
# 	x : x, y : x
# 23	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 24	assumption		{x in Real} |- x in Real
# 25	instantiation	26	|- x = x
# 	x : x
# 26	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
