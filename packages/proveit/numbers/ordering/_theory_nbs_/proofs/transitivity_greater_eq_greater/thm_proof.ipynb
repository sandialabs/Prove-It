# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_greater_eq_greater">transitivity_greater_eq_greater</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, y, z
from proveit.logic import Equals
from proveit.numbers import Greater
from proveit.numbers.ordering  import greater_eq_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivity_greater_eq_greater
# Out:
# transitivity_greater_eq_greater: forall_{x, y, z | x >= y, y > z} (x > z)

# %%
defaults.assumptions = transitivity_greater_eq_greater.all_conditions()
# Out:
# defaults.assumptions: (x >= y, y > z)

# %%
greater_eq_def
# Out:
# |- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))

# %%
spec_g_e_d = greater_eq_def.instantiate({x:x, y:y, z:y})
# Out:
# spec_g_e_d: |- (x >= y) = ((x > y) or (x = y))

# %%
spec_g_e_d.derive_right_via_equality()
# Out:
# {x >= y} |- (x > y) or (x = y)

# %%
Greater(x,z).prove(assumptions = (Equals(x,y), Greater(y,z)))
# Out:
# {y > z, x = y} |- x > z

# %%
Greater(x,z).prove(assumptions = (Greater(x,y), Greater(y,z)))
# Out:
# {x > y, y > z} |- x > z

# %%
spec_g_e_d.rhs.derive_via_dilemma(Greater(x,z))
# Out:
# {x >= y, y > z} |- x > z

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x, y, z | x >= y, y > z} (x > z)
# 1	instantiation	2, 3, 4, 14, 5, 6	{x >= y, y > z} |- x > z
# 	A : x > y, B : x = y, C : x > z
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{x >= y} |- (x > y) in BOOLEAN
# 	A : x > y, B : x = y
# 4	instantiation	8, 9	{x >= y} |- (x = y) in BOOLEAN
# 	A : x > y, B : x = y
# 5	deduction	10	{y > z} |- (x > y) => (x > z)
# 6	deduction	11	{y > z} |- (x = y) => (x > z)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13, 14	{x >= y} |- ((x > y) or (x = y)) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : (x > y) or (x = y)
# 10	instantiation	15, 16, 18	{x > y, y > z} |- x > z
# 	x : x, y : y, z : z
# 11	instantiation	17, 18, 19	{y > z, x = y} |- x > z
# 	P(_a) : _a > z, x : x, y : y
# 12	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 13	conjecture		|- TRUE in BOOLEAN
# 14	instantiation	20, 21, 22	{x >= y} |- (x > y) or (x = y)
# 	P : x >= y, Q : (x > y) or (x = y)
# 15	theorem		|- forall_{x, y, z | x > y, y > z} (x > z)
# 	proveit.numbers.ordering.transitivity_greater_greater
# 16	assumption		{x > y} |- x > y
# 17	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 18	assumption		{y > z} |- y > z
# 19	assumption		{x = y} |- x = y
# 20	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 21	assumption		{x >= y} |- x >= y
# 22	instantiation	23	|- (x >= y) = ((x > y) or (x = y))
# 	x : x, y : y
# 23	axiom		|- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))
# 	proveit.numbers.ordering.greater_eq_def
