# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#reverse_less_eq">reverse_less_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, y
from proveit.logic.equality  import equals_symmetry
from proveit.numbers import GreaterEq
from proveit.numbers.ordering  import reverse_relation, less_eq_def, greater_eq_def
from proveit.logic.equality import sub_right_side_into

theory = proveit.Theory() # the theorem's theory

# %%
# %proving reverse_less_eq
# Out:
# reverse_less_eq: forall_{x, y | x <= y} (y >= x)

# %%
defaults.assumptions = reverse_less_eq.all_conditions()
# Out:
# defaults.assumptions: (x <= y)

# %%
less_eq_def
# Out:
# |- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))

# %%
spec_less_eq_def = less_eq_def.instantiate({x:x, y:y})
# Out:
# spec_less_eq_def: |- (x <= y) = ((x < y) or (x = y))

# %%
expanded = spec_less_eq_def.derive_right_via_equality()
# Out:
# expanded: {x <= y} |- (x < y) or (x = y)

# %%
reverse_relation
# Out:
# |- forall_{x, y} ((y > x) = (x < y))

# %%
subleft = reverse_relation.instantiate({x:x, y:y}).sub_left_side_into(expanded, )
# Out:
# subleft: {x <= y} |- (y > x) or (x = y)

# %%
equals_symmetry
# Out:
# |- forall_{x, y} ((y = x) = (x = y))

# %%
subboth = equals_symmetry.instantiate({x:x, y:y}).sub_left_side_into(subleft)
# Out:
# subboth: {x <= y} |- (y > x) or (y = x)

# %%
spec_greater_eq_def = greater_eq_def.instantiate({x:y, y:x}, assumptions = [GreaterEq(y,x)])
# Out:
# spec_greater_eq_def: |- (y >= x) = ((y > x) or (y = x))

# %%
spec_greater_eq_def.sub_left_side_into(subboth,)
# Out:
# {x <= y} |- y >= x

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x, y | x <= y} (y >= x)
# 1	instantiation	7, 2, 3	{x <= y} |- y >= x
# 	P(_a) : _a, x : y >= x, y : (y > x) or (y = x)
# 2	instantiation	7, 4, 5	{x <= y} |- (y > x) or (y = x)
# 	P(_a) : (y > x) or _a, x : y = x, y : x = y
# 3	instantiation	6	|- (y >= x) = ((y > x) or (y = x))
# 	x : y, y : x
# 4	instantiation	7, 8, 9	{x <= y} |- (y > x) or (x = y)
# 	P(_a) : _a or (x = y), x : y > x, y : x < y
# 5	instantiation	10	|- (y = x) = (x = y)
# 	x : x, y : y
# 6	axiom		|- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))
# 	proveit.numbers.ordering.greater_eq_def
# 7	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 8	instantiation	11, 12, 13	{x <= y} |- (x < y) or (x = y)
# 	P : x <= y, Q : (x < y) or (x = y)
# 9	instantiation	14	|- (y > x) = (x < y)
# 	x : x, y : y
# 10	axiom		|- forall_{x, y} ((y = x) = (x = y))
# 	proveit.logic.equality.equals_symmetry
# 11	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 12	assumption		{x <= y} |- x <= y
# 13	instantiation	15	|- (x <= y) = ((x < y) or (x = y))
# 	x : x, y : y
# 14	axiom		|- forall_{x, y} ((y > x) = (x < y))
# 	proveit.numbers.ordering.reverse_relation
# 15	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
