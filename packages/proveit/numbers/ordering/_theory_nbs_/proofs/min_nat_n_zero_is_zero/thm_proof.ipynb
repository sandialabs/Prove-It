# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#min_nat_n_zero_is_zero">min_nat_n_zero_is_zero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import n, x, y, defaults
from proveit.logic import Equals
from proveit.numbers import zero, greater_eq, Less, LessEq
from proveit.numbers.ordering import min_def_bin

# %%
# %proving min_nat_n_zero_is_zero
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="min_nat_n_zero_is_zero">min_nat_n_zero_is_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/feb316f151e2b66ea0a3ac1d6a23e334f77e59780/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/249f64f3f3dbbe90e773d416a532a182576790410/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = min_nat_n_zero_is_zero.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/35f3a9e86686d0426394ec24c7b002b9cbad74f60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
min_def_bin
# Out:
# |- forall_{x, y in Real} (Min(x, y) = {x if x <= y; y if y < x.)

# %%
min_def_bin_inst = min_def_bin.instantiate({x: n, y: zero}, auto_simplify=False)
# Out:
# <strong id="min_def_bin_inst">min_def_bin_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/5c956367a979dfc6c8ddbe8e874f152d21bb815c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/14125b6f96864d15da9ad508ebbca1bc40e362bb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# For $n \in \mathbb{N}$, we know that $0 < n \lor 0 = n$. We show that the rhs of the instantiated definition is reducible to 0 for both of those cases.

# %%
greater_eq(n, zero).prove()
# Out:
# {n in Natural} |- n >= 0

# %%
from proveit.numbers.ordering import less_eq_def
less_eq_def
# Out:
# |- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))

# %%
less_eq_def_inst = less_eq_def.instantiate({x: zero, y: n})
# Out:
# <strong id="less_eq_def_inst">less_eq_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/9000cf9a60ea8f04e290b5b5e7b575f46cba8cf30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/f6bbb37ed37f7271db930f6a3d9fa33e71222dd40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
less_eq_def_inst.derive_right_via_equality()
# Out:
# {n in Natural} |- (0 < n) or (0 = n)

# %% [markdown]
# ### Case 1: $0 = n$

# %%
# First we relax the equality to a LessEq
LessEq(n, zero).prove(assumptions=[Equals(zero, n)])
# Out:
# {0 = n} |- n <= 0

# %%
# That then allows the axiomatic definition to be evaluated
min_def_bin_inst_simpl_zero_eq_n = min_def_bin_inst.inner_expr().rhs.simplify(
    assumptions=[Equals(zero, n)])
# Out:
# <strong id="min_def_bin_inst_simpl_zero_eq_n">min_def_bin_inst_simpl_zero_eq_n:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/584161dfdfb31c264bbc2da3d0778094435d5bdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/8280496970dbf2435e32d7288e3efe834be602200/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_nat_n_zero_is_zero/96490010cca990ead55bb2d8a48f5f2b9257d4110/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# But then we need to use the fact that 0 = n
min_def_bin_inst_simpl_zero_eq_n.inner_expr().rhs.substitute(
        zero, assumptions=[Equals(zero, n)], auto_simplify=False)
# Out:
# {n in Natural, 0 = n} |- Min(n, 0) = 0

# %% [markdown]
# ### Case 2: $0 < n$

# %%
# This one simplifies immediately
min_def_bin_inst.inner_expr().rhs.simplify(assumptions=[Less(zero, n)])
# Out:
# {n in Natural, 0 < n} |- Min(n, 0) = 0

# %% [markdown]
# ### Now combine the cases

# %%
less_eq_def_inst.rhs.derive_via_singular_dilemma(min_nat_n_zero_is_zero.instance_expr)
# Out:
# {n in Natural} |- Min(n, 0) = 0
# min_nat_n_zero_is_zero may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.ordering.min_nat_n_zero_is_zero has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in Natural} (Min(n, 0) = 0)
# 1	instantiation	2, 3, 4, 13, 5, 6	{n in Natural} |- Min(n, 0) = 0
# 	A : 0 < n, B : 0 = n, C : Min(n, 0) = 0
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{n in Natural} |- (0 < n) in BOOLEAN
# 	A : 0 < n, B : 0 = n
# 4	instantiation	8, 9	{n in Natural} |- (0 = n) in BOOLEAN
# 	A : 0 < n, B : 0 = n
# 5	deduction	10	{n in Natural} |- (0 < n) => (Min(n, 0) = 0)
# 6	deduction	11	{n in Natural} |- (0 = n) => (Min(n, 0) = 0)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13	{n in Natural} |- ((0 < n) or (0 = n)) in BOOLEAN
# 	A : (0 < n) or (0 = n)
# 10	instantiation	60, 22, 14	{n in Natural, 0 < n} |- Min(n, 0) = 0
# 	P(_a) : Min(n, 0) = _a, x : {n if n <= 0; 0 if 0 < n., y : 0
# 11	instantiation	15, 16, 63	{n in Natural, 0 = n} |- Min(n, 0) = 0
# 	P(_a) : Min(n, 0) = _a, x : 0, y : n
# 12	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 13	instantiation	17, 18, 19	{n in Natural} |- (0 < n) or (0 = n)
# 	P : 0 <= n, Q : (0 < n) or (0 = n)
# 14	instantiation	33, 20, 21	{n in Natural, 0 < n} |- {n if n <= 0; 0 if 0 < n. = 0
# 	x : {n if n <= 0; 0 if 0 < n., y : {n if FALSE; 0., z : 0
# 15	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 16	instantiation	60, 22, 23	{n in Natural, 0 = n} |- Min(n, 0) = n
# 	P(_a) : Min(n, 0) = _a, x : {n if n <= 0; 0 if 0 < n., y : n
# 17	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 18	instantiation	24, 52	{n in Natural} |- n >= 0
# 	n : n
# 19	instantiation	25	|- (0 <= n) = ((0 < n) or (0 = n))
# 	x : 0, y : n
# 20	instantiation	33, 26, 27	{n in Natural, 0 < n} |- {n if n <= 0; 0 if 0 < n. = {n if FALSE; 0.
# 	x : {n if n <= 0; 0 if 0 < n., y : {n if FALSE; 0 if 0 < n., z : {n if FALSE; 0.
# 21	instantiation	36, 38, 37, 39	|- {n if FALSE; 0. = 0
# 	m : 1, n : 0, a : (n), b : 0, c : ()
# 22	instantiation	28, 45, 61	{n in Natural} |- Min(n, 0) = {n if n <= 0; 0 if 0 < n.
# 	x : n, y : 0
# 23	instantiation	33, 29, 30	{0 = n} |- {n if n <= 0; 0 if 0 < n. = n
# 	x : {n if n <= 0; 0 if 0 < n., y : {n; 0 if FALSE., z : n
# 24	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 25	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
# 26	instantiation	42, 31	{n in Natural, 0 < n} |- {n if n <= 0; 0 if 0 < n. = {n if FALSE; 0 if 0 < n.
# 	f(_a) : {_a; 0 if 0 < n., x : {n if n <= 0., y : {n if FALSE.
# 27	instantiation	42, 32	{0 < n} |- {n if FALSE; 0 if 0 < n. = {n if FALSE; 0.
# 	f(_a) : {n if FALSE; _a., x : {0 if 0 < n., y : 0
# 28	axiom		|- forall_{x, y in Real} (Min(x, y) = {x if x <= y; y if y < x.)
# 	proveit.numbers.ordering.min_def_bin
# 29	instantiation	33, 34, 35	{0 = n} |- {n if n <= 0; 0 if 0 < n. = {n; 0 if FALSE.
# 	x : {n if n <= 0; 0 if 0 < n., y : {n; 0 if 0 < n., z : {n; 0 if FALSE.
# 30	instantiation	36, 37, 38, 39	|- {n; 0 if FALSE. = n
# 	m : 0, n : 1, a : (), b : n, c : (0)
# 31	instantiation	48, 40	{n in Natural, 0 < n} |- {n if n <= 0. = {n if FALSE.
# 	a : n, Q : n <= 0
# 32	instantiation	47, 46	{0 < n} |- {0 if 0 < n. = 0
# 	a : 0, Q : 0 < n
# 33	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 34	instantiation	42, 41	{0 = n} |- {n if n <= 0; 0 if 0 < n. = {n; 0 if 0 < n.
# 	f(_a) : {_a; 0 if 0 < n., x : {n if n <= 0., y : n
# 35	instantiation	42, 43	{0 = n} |- {n; 0 if 0 < n. = {n; 0 if FALSE.
# 	f(_a) : {n; _a., x : {0 if 0 < n., y : {0 if FALSE.
# 36	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 37	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 38	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 39	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 40	instantiation	44, 61, 45, 46	{n in Natural, 0 < n} |- [not](n <= 0)
# 	x : 0, y : n
# 41	instantiation	47, 54	{0 = n} |- {n if n <= 0. = n
# 	a : n, Q : n <= 0
# 42	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 43	instantiation	48, 49	{0 = n} |- {0 if 0 < n. = {0 if FALSE.
# 	a : 0, Q : 0 < n
# 44	conjecture		|- forall_{x, y in Real | x < y} [not](y <= x)
# 	proveit.numbers.ordering.not_less_eq_from_less
# 45	instantiation	50, 51, 52	{n in Natural} |- n in Real
# 	A : Natural, B : Real, x : n
# 46	assumption		{0 < n} |- 0 < n
# 47	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 48	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 49	instantiation	53, 58, 61, 54	{0 = n} |- [not](0 < n)
# 	x : n, y : 0
# 50	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 51	instantiation	55, 56	|- Natural subset_eq Real
# 	A : Natural, B : Real
# 52	assumption		{n in Natural} |- n in Natural
# 53	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 54	instantiation	57, 58, 61, 59	{0 = n} |- n <= 0
# 	x : n, y : 0
# 55	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 56	conjecture		|- Natural proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_within_real
# 57	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 58	instantiation	60, 61, 63	{0 = n} |- n in Real
# 	P(_a) : _a in Real, x : 0, y : n
# 59	instantiation	62, 63	{0 = n} |- n = 0
# 	x : 0, y : n
# 60	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 61	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 62	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 63	assumption		{0 = n} |- 0 = n
