# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#max_nat_n_zero_is_n">max_nat_n_zero_is_n</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import n, x, y, defaults
from proveit.numbers import zero
from proveit.numbers.ordering import max_def_bin

# %%
# %proving max_nat_n_zero_is_n
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="max_nat_n_zero_is_n">max_nat_n_zero_is_n:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ecd6389de8a3528e7ca9d7b9e89662b2696997360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d9e9c380fe5aa21fc669f8ef414d43f85894edb10/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = max_nat_n_zero_is_n.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_max_nat_n_zero_is_n/35f3a9e86686d0426394ec24c7b002b9cbad74f60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
max_def_bin
# Out:
# |- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)

# %% [markdown]
# In the following instantiation, we need to set auto_simplify=False, else we over-simplify and end up with the unhelpful $n = n$:

# %%
max_def_bin_inst = max_def_bin.instantiate({x: n, y: zero}, auto_simplify=False)
# Out:
# <strong id="max_def_bin_inst">max_def_bin_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_nat_n_zero_is_n/c76ae209d16d735451832bf15dc44ddcab4ab0df0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_max_nat_n_zero_is_n/4ee778953bc4c13a489f51fbd2553cd70c8ba9b50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Prove-It can then complete the formal proof on its own, but it's nice to explicitly show the final step before handing it off to Prove-It:

# %%
max_def_bin_inst.inner_expr().rhs.simplify()
# Out:
# {n in Natural} |- Max(n, 0) = n
# max_nat_n_zero_is_n may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.ordering.max_nat_n_zero_is_n has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in Natural} (Max(n, 0) = n)
# 1	instantiation	2, 3, 4	{n in Natural} |- Max(n, 0) = n
# 	P(_a) : Max(n, 0) = _a, x : {n if n >= 0; 0 if 0 > n., y : n
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	instantiation	5, 23, 22	{n in Natural} |- Max(n, 0) = {n if n >= 0; 0 if 0 > n.
# 	x : n, y : 0
# 4	instantiation	8, 6, 7	{n in Natural} |- {n if n >= 0; 0 if 0 > n. = n
# 	x : {n if n >= 0; 0 if 0 > n., y : {n; 0 if FALSE., z : n
# 5	axiom		|- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)
# 	proveit.numbers.ordering.max_def_bin
# 6	instantiation	8, 9, 10	{n in Natural} |- {n if n >= 0; 0 if 0 > n. = {n; 0 if FALSE.
# 	x : {n if n >= 0; 0 if 0 > n., y : {n; 0 if 0 > n., z : {n; 0 if FALSE.
# 7	instantiation	11, 12, 13, 14	|- {n; 0 if FALSE. = n
# 	m : 0, n : 1, a : (), b : n, c : (0)
# 8	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 9	instantiation	16, 15	{n in Natural} |- {n if n >= 0; 0 if 0 > n. = {n; 0 if 0 > n.
# 	f(_a) : {_a; 0 if 0 > n., x : {n if n >= 0., y : n
# 10	instantiation	16, 17	{n in Natural} |- {n; 0 if 0 > n. = {n; 0 if FALSE.
# 	f(_a) : {n; _a., x : {0 if 0 > n., y : {0 if FALSE.
# 11	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 12	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 13	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 14	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 15	instantiation	18, 24	{n in Natural} |- {n if n >= 0. = n
# 	a : n, Q : n >= 0
# 16	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 17	instantiation	19, 20	{n in Natural} |- {0 if 0 > n. = {0 if FALSE.
# 	a : 0, Q : 0 > n
# 18	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 19	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 20	instantiation	21, 22, 23, 24	{n in Natural} |- [not](n < 0)
# 	x : 0, y : n
# 21	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 22	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 23	instantiation	25, 26, 28	{n in Natural} |- n in Real
# 	A : Natural, B : Real, x : n
# 24	instantiation	27, 28	{n in Natural} |- n >= 0
# 	n : n
# 25	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 26	instantiation	29, 30	|- Natural subset_eq Real
# 	A : Natural, B : Real
# 27	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 28	assumption		{n in Natural} |- n in Natural
# 29	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 30	conjecture		|- Natural proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_within_real
