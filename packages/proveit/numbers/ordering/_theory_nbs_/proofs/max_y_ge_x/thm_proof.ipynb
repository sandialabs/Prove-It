# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#max_y_ge_x">max_y_ge_x</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import x, y, defaults
from proveit.logic import Equals, InSet
from proveit.numbers import greater_eq, Less, Real
from proveit.numbers.ordering import less_eq_def, max_def_bin

# %%
# %proving max_y_ge_x
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="max_y_ge_x">max_y_ge_x:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9f8d0c05f21642d704f9ad81e216b493f42084f90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/1575f47b67f608b97a730595946b10aaf29977760/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = max_y_ge_x.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/cdd9df064e363371fc97d5051e21e30d4798b8580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
max_def_bin
# Out:
# |- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)

# %%
max_x_y = max_def_bin.instantiate({x: x, y: y}, auto_simplify=False)
# Out:
# <strong id="max_x_y">max_x_y:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/8528652a62922cad2d57afd8250537e40f0c31df0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/3f9dc6d3a6195eb84e81aba6f913fa363792d4c90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### We proceed by breaking the assumption $y \ge x$ into 2 cases

# %%
less_eq_def
# Out:
# |- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))

# %%
y_ge_x_def = less_eq_def.instantiate({x: x, y: y})
# Out:
# <strong id="y_ge_x_def">y_ge_x_def:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/697a7287818434e649776a43566bc313eb2e875d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/1af4f8c9abfd3cd7db1c0455020e61577b1cf48a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
y_ge_x_def.derive_right_via_equality()
# Out:
# {y >= x} |- (x < y) or (x = y)

# %% [markdown]
# ### Case 1: $x < y$

# %%
max_x_y_is_y_if_x_less_y = max_x_y.inner_expr().rhs.simplify(assumptions=[InSet(x, Real), InSet(y, Real), Less(x, y)])
# Out:
# <strong id="max_x_y_is_y_if_x_less_y">max_x_y_is_y_if_x_less_y:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/44d10bba886cb9c03d8c1d01224b9827d41c27660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/f3419a396cb497566e03814a89eb03e045647a7c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/cd04a61999b9108ab229a80023effc54c25e77b10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Case 2: $x = y$

# %%
greater_eq(x, y).prove(assumptions=[InSet(x, Real), InSet(y, Real), Equals(x, y)])
# Out:
# {y in Real, x in Real, x = y} |- x >= y

# %%
max_x_y_when_x_eq_y = max_x_y.inner_expr().rhs.simplify(assumptions=[InSet(x, Real), InSet(y, Real), Equals(x, y)])
# Out:
# <strong id="max_x_y_when_x_eq_y">max_x_y_when_x_eq_y:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../logic/equality/__pv_it/theorems/8dc625ee9fbf5f96228c059ed58b16ec83d4e40d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/9a6b6262ccd5ad79c4c6bc96093f9eb5208ec2700/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/790542c8b24a3276bbfaf15cf0de613896ff9dd10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Use the fact that x = y to substitute
max_x_y_when_x_eq_y.inner_expr().rhs.substitute(y, assumptions=[Equals(x, y)], auto_simplify=False)
# Out:
# {x in Real, y in Real, x = y} |- Max(x, y) = y

# %% [markdown]
# ### Combine the 2 cases

# %%
or_version_of_thm = y_ge_x_def.rhs.derive_via_singular_dilemma(
    max_x_y_is_y_if_x_less_y.expr)
# Out:
# <strong id="or_version_of_thm">or_version_of_thm:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/210b2731e2a7107a98c0f842aebde725bb7ab12b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_max_y_ge_x/ffbbbe6d2fd7fa3a4d550b2adc6c7dce597083a80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/cd04a61999b9108ab229a80023effc54c25e77b10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# max_y_ge_x may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.ordering.max_y_ge_x has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y in Real | y >= x} (Max(x, y) = y)
# 1	instantiation	2, 3, 4, 13, 5, 6	{y >= x, x in Real, y in Real} |- Max(x, y) = y
# 	A : x < y, B : x = y, C : Max(x, y) = y
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{y >= x} |- (x < y) in BOOLEAN
# 	A : x < y, B : x = y
# 4	instantiation	8, 9	{y >= x} |- (x = y) in BOOLEAN
# 	A : x < y, B : x = y
# 5	deduction	10	{x in Real, y in Real} |- (x < y) => (Max(x, y) = y)
# 6	deduction	11	{x in Real, y in Real} |- (x = y) => (Max(x, y) = y)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13	{y >= x} |- ((x < y) or (x = y)) in BOOLEAN
# 	A : (x < y) or (x = y)
# 10	instantiation	21, 22, 14	{x in Real, y in Real, x < y} |- Max(x, y) = y
# 	P(_a) : Max(x, y) = _a, x : {x if x >= y; y if y > x., y : y
# 11	instantiation	21, 15, 55	{x in Real, y in Real, x = y} |- Max(x, y) = y
# 	P(_a) : Max(x, y) = _a, x : x, y : y
# 12	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 13	instantiation	16, 17, 18	{y >= x} |- (x < y) or (x = y)
# 	P : x <= y, Q : (x < y) or (x = y)
# 14	instantiation	32, 19, 20	{x in Real, y in Real, x < y} |- {x if x >= y; y if y > x. = y
# 	x : {x if x >= y; y if y > x., y : {x if FALSE; y., z : y
# 15	instantiation	21, 22, 23	{x in Real, y in Real, x = y} |- Max(x, y) = x
# 	P(_a) : Max(x, y) = _a, x : {x if x >= y; y if y > x., y : x
# 16	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 17	assumption		{x <= y} |- x <= y
# 18	instantiation	24	|- (x <= y) = ((x < y) or (x = y))
# 	x : x, y : y
# 19	instantiation	32, 25, 26	{x in Real, y in Real, x < y} |- {x if x >= y; y if y > x. = {x if FALSE; y.
# 	x : {x if x >= y; y if y > x., y : {x if FALSE; y if y > x., z : {x if FALSE; y.
# 20	instantiation	35, 37, 36, 38	|- {x if FALSE; y. = y
# 	m : 1, n : 0, a : (x), b : y, c : ()
# 21	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 22	instantiation	27, 52, 51	{x in Real, y in Real} |- Max(x, y) = {x if x >= y; y if y > x.
# 	x : x, y : y
# 23	instantiation	32, 28, 29	{y in Real, x in Real, x = y} |- {x if x >= y; y if y > x. = x
# 	x : {x if x >= y; y if y > x., y : {x; y if FALSE., z : x
# 24	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
# 25	instantiation	41, 30	{x in Real, y in Real, x < y} |- {x if x >= y; y if y > x. = {x if FALSE; y if y > x.
# 	f(_a) : {_a; y if y > x., x : {x if x >= y., y : {x if FALSE.
# 26	instantiation	41, 31	{x < y} |- {x if FALSE; y if y > x. = {x if FALSE; y.
# 	f(_a) : {x if FALSE; _a., x : {y if y > x., y : y
# 27	axiom		|- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)
# 	proveit.numbers.ordering.max_def_bin
# 28	instantiation	32, 33, 34	{y in Real, x in Real, x = y} |- {x if x >= y; y if y > x. = {x; y if FALSE.
# 	x : {x if x >= y; y if y > x., y : {x; y if y > x., z : {x; y if FALSE.
# 29	instantiation	35, 36, 37, 38	|- {x; y if FALSE. = x
# 	m : 0, n : 1, a : (), b : x, c : (y)
# 30	instantiation	46, 39	{x in Real, y in Real, x < y} |- {x if x >= y. = {x if FALSE.
# 	a : x, Q : x >= y
# 31	instantiation	45, 44	{x < y} |- {y if y > x. = y
# 	a : y, Q : y > x
# 32	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 33	instantiation	41, 40	{y in Real, x in Real, x = y} |- {x if x >= y; y if y > x. = {x; y if y > x.
# 	f(_a) : {_a; y if y > x., x : {x if x >= y., y : x
# 34	instantiation	41, 42	{y in Real, x in Real, x = y} |- {x; y if y > x. = {x; y if FALSE.
# 	f(_a) : {x; _a., x : {y if y > x., y : {y if FALSE.
# 35	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 36	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 37	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 38	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 39	instantiation	43, 52, 51, 44	{x in Real, y in Real, x < y} |- [not](y <= x)
# 	x : x, y : y
# 40	instantiation	45, 49	{y in Real, x in Real, x = y} |- {x if x >= y. = x
# 	a : x, Q : x >= y
# 41	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 42	instantiation	46, 47	{y in Real, x in Real, x = y} |- {y if y > x. = {y if FALSE.
# 	a : y, Q : y > x
# 43	conjecture		|- forall_{x, y in Real | x < y} [not](y <= x)
# 	proveit.numbers.ordering.not_less_eq_from_less
# 44	assumption		{x < y} |- x < y
# 45	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 46	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 47	instantiation	48, 51, 52, 49	{y in Real, x in Real, x = y} |- [not](x < y)
# 	x : y, y : x
# 48	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 49	instantiation	50, 51, 52, 53	{y in Real, x in Real, x = y} |- y <= x
# 	x : y, y : x
# 50	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 51	assumption		{y in Real} |- y in Real
# 52	assumption		{x in Real} |- x in Real
# 53	instantiation	54, 55	{x = y} |- y = x
# 	x : x, y : y
# 54	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 55	assumption		{x = y} |- x = y
