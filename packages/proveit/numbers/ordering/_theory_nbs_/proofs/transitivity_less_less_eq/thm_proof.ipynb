# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_less_less_eq">transitivity_less_less_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, y, z
from proveit.logic import Equals
from proveit.numbers import Less
from proveit.numbers.ordering  import less_eq_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivity_less_less_eq
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="transitivity_less_less_eq">transitivity_less_less_eq:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b92cdd66584b50f04a21e5076b35d033cbdb6e110/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a9d9e1badf965d9eaed1582bdd5dda60a395e68d0/dependencies.ipynb">dependencies</a>)<br>
# transitivity_less_less_eq may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = transitivity_less_less_eq.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8191badb620f06a7d76f98cb0bfa0123227ee95c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
spec_l_e_d = less_eq_def.instantiate({x:y, y:z})
# Out:
# <strong id="spec_l_e_d">spec_l_e_d:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/292df812ebe3721d576f2413a918f4f2f98c90830/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/c657e5036469c108c97e682ea3e326625c09f3ff0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
spec_l_e_d.derive_right_via_equality()
# Out:
# {y <= z} |- (y < z) or (y = z)

# %%
yeq_z = Less(x,z).prove(assumptions = (Equals(y,z), Less(x,y)))
# Out:
# <strong id="yeq_z">yeq_z:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/44d10bba886cb9c03d8c1d01224b9827d41c27660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/9f5c265b251465f0150ee63561a9a2ed1fa47fd70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/5433c8a7e181761373f02818a7983544ace154610/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/379a915db37b0a2702f9d2f28f9d6723c69946af0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
yless_z = Less(x,z).prove(assumptions = (Less(y,z), Less(x,y)))
# Out:
# <strong id="yless_z">yless_z:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/44d10bba886cb9c03d8c1d01224b9827d41c27660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/43e11eadbb774a9099226361c78bdd793b6204940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_less_less_eq/e47b9b86c84a2890358c29e1812f14bc77ef3d7d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/379a915db37b0a2702f9d2f28f9d6723c69946af0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
spec_l_e_d.rhs.derive_via_dilemma(Less(x,z))
# Out:
# {y <= z, x < y} |- x < z

# %%
# %qed
# Out:
# proveit.numbers.ordering.transitivity_less_less_eq has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y, z | x < y, y <= z} (x < z)
# 1	instantiation	2, 3, 4, 13, 5, 6	{y <= z, x < y} |- x < z
# 	A : y < z, B : y = z, C : x < z
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{y <= z} |- (y < z) in BOOLEAN
# 	A : y < z, B : y = z
# 4	instantiation	8, 9	{y <= z} |- (y = z) in BOOLEAN
# 	A : y < z, B : y = z
# 5	deduction	10	{x < y} |- (y < z) => (x < z)
# 6	deduction	11	{x < y} |- (y = z) => (x < z)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13	{y <= z} |- ((y < z) or (y = z)) in BOOLEAN
# 	A : (y < z) or (y = z)
# 10	instantiation	14, 17, 15	{x < y, y < z} |- x < z
# 	x : x, y : y, z : z
# 11	instantiation	16, 17, 18	{x < y, y = z} |- x < z
# 	P(_a) : x < _a, x : y, y : z
# 12	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 13	instantiation	19, 20, 21	{y <= z} |- (y < z) or (y = z)
# 	P : y <= z, Q : (y < z) or (y = z)
# 14	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 15	assumption		{y < z} |- y < z
# 16	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 17	assumption		{x < y} |- x < y
# 18	assumption		{y = z} |- y = z
# 19	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 20	assumption		{y <= z} |- y <= z
# 21	instantiation	22	|- (y <= z) = ((y < z) or (y = z))
# 	x : y, y : z
# 22	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
