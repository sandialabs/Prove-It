# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_greater_eq_greater_eq">transitivity_greater_eq_greater_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, y, z
from proveit.logic import Equals
from proveit.numbers import GreaterEq, Greater
from proveit.numbers.ordering  import greater_eq_def
from proveit.numbers.ordering import transitivity_greater_greater_eq
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivity_greater_eq_greater_eq
# Out:
# transitivity_greater_eq_greater_eq: forall_{x, y, z | x >= y, y >= z} (x >= z)

# %%
defaults.assumptions = transitivity_greater_eq_greater_eq.all_conditions()
# Out:
# defaults.assumptions: (x >= y, y >= z)

# %%
greater_eq_def
# Out:
# |- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))

# %%
x_geq_y__expanded = greater_eq_def.instantiate({x:x, y:y}).derive_right_via_equality()
# Out:
# x_geq_y__expanded: {x >= y} |- (x > y) or (x = y)

# %%
x_greater_y, x_eq_y = x_geq_y__expanded.operands
# Out:
# x_greater_y: x > y
# x_eq_y: x = y

# %%
transitivity_greater_greater_eq
# Out:
# |- forall_{x, y, z | x > y, y >= z} (x > z)

# %%
transitivity_greater_greater_eq.instantiate({x:x, y:y, z:z}, assumptions = defaults.assumptions+(x_greater_y,))
# Out:
# {x > y, y >= z} |- x > z

# %%
x_eq_y.sub_left_side_into(GreaterEq(y, z), assumptions = defaults.assumptions+(x_eq_y,))
# Out:
# {y >= z, x = y} |- x >= z

# %%
x_geq_y__expanded.derive_via_dilemma(GreaterEq(x, z))
# Out:
# {x >= y, y >= z} |- x >= z

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x, y, z | x >= y, y >= z} (x >= z)
# 1	instantiation	2, 3, 4, 14, 5, 6	{x >= y, y >= z} |- x >= z
# 	A : x > y, B : x = y, C : x >= z
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{x >= y} |- (x > y) in BOOLEAN
# 	A : x > y, B : x = y
# 4	instantiation	8, 9	{x >= y} |- (x = y) in BOOLEAN
# 	A : x > y, B : x = y
# 5	deduction	10	{y >= z} |- (x > y) => (x >= z)
# 6	deduction	11	{y >= z} |- (x = y) => (x >= z)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13, 14	{x >= y} |- ((x > y) or (x = y)) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : (x > y) or (x = y)
# 10	instantiation	15, 16	{x > y, y >= z} |- x >= z
# 	x : x, y : z
# 11	instantiation	17, 24, 18	{y >= z, x = y} |- x >= z
# 	P(_a) : _a >= z, x : x, y : y
# 12	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 13	conjecture		|- TRUE in BOOLEAN
# 14	instantiation	19, 20, 21	{x >= y} |- (x > y) or (x = y)
# 	P : x >= y, Q : (x > y) or (x = y)
# 15	conjecture		|- forall_{x, y | x > y} (x >= y)
# 16	instantiation	22, 23, 24	{x > y, y >= z} |- x > z
# 	x : x, y : y, z : z
# 17	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 18	assumption		{x = y} |- x = y
# 19	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 20	assumption		{x >= y} |- x >= y
# 21	instantiation	25	|- (x >= y) = ((x > y) or (x = y))
# 	x : x, y : y
# 22	conjecture		|- forall_{x, y, z | x > y, y >= z} (x > z)
# 23	assumption		{x > y} |- x > y
# 24	assumption		{y >= z} |- y >= z
# 25	axiom		|- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))
# 	proveit.numbers.ordering.greater_eq_def
