# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_axioms_.ipynb#less_sequence_def">less_sequence_def</a> of type <a href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official axiom from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import x_1_to_np1
from proveit.logic import Equals, Forall
from proveit.numbers import NaturalPos, Real
from proveit.numbers.ordering import less_eq_relations, rho_1_to_n, sequential_x_relations, x_relation_sequence

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([x_1_to_np1], Forall([rho_1_to_n], Equals(x_relation_sequence, sequential_x_relations), domains = [less_eq_relations]), domains = [Real]), domains = [NaturalPos])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: less_sequence_def matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
# display the expression information
expr.expr_info()
