# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#transitivity_less_less">transitivity_less_less</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.ordering import transitivity_less_less

# %%
# %dependencies transitivity_less_less
# Out:
# <h3>Theorems/conjectures that depend directly on transitivity_less_less</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/transitivity_greater_greater/thm_proof.ipynb">proveit.numbers.ordering.transitivity_greater_greater</a></dt><dd><a class="ProveItLink" href="../../theorems/5cf1d820eb1e6145fd316e58246d30f0bc90f1570/expr.ipynb"><img src="../../theorems/5cf1d820eb1e6145fd316e58246d30f0bc90f1570/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/transitivity_less_eq_less/thm_proof.ipynb">proveit.numbers.ordering.transitivity_less_eq_less</a></dt><dd><a class="ProveItLink" href="../../theorems/7fc80fd0eaf1ee875074c1b5925ff9bb287042be0/expr.ipynb"><img src="../../theorems/7fc80fd0eaf1ee875074c1b5925ff9bb287042be0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/transitivity_less_less_eq/thm_proof.ipynb">proveit.numbers.ordering.transitivity_less_less_eq</a></dt><dd><a class="ProveItLink" href="../../theorems/7b8d58341b5906ecd4ee00de1e57de439743b9390/expr.ipynb"><img src="../../theorems/7b8d58341b5906ecd4ee00de1e57de439743b9390/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
