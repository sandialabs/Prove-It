# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, Lambda, Variable, rho
from proveit.logic import InSet
from proveit.numbers.ordering import less_eq_relations

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(sub_expr1, InSet(IndexedVar(rho, sub_expr1), less_eq_relations))
# Out:
# expr: _a -> (rho_{_a} in {<, <=, =})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \mapsto \left(\rho_{{_{-}a}} \in \left\{<, \leq, =\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a -> (rho_{_a} in {<, <=, =})
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. rho_{_a} in {<, <=, =}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. in
#    core type: Literal
#    sub-expressions:
# 3. (rho_{_a}, {<, <=, =})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. rho_{_a}
#    core type: IndexedVar
# variable: 6
# index: 7
# 5. {<, <=, =}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. rho
#    core type: Variable
#    sub-expressions:
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. (<, <=, =)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 10. <
#     core type: Literal
#     sub-expressions:
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
