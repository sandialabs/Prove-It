# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#greater_eq_def">greater_eq_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import greater_eq_def

# %%
# check that the built expression is the same as the stored expression
assert greater_eq_def.expr == stored_expr
assert greater_eq_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: greater_eq_def matches stored_expr")
# Out:
# Passed sanity check: greater_eq_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greater_eq_def.latex())
# Out:
# \vdash \forall_{x, y}~\left(\left(x \geq y\right) = \left(\left(x > y\right) \lor \left(x = y\right)\right)\right)

# %%
# display the expression information
greater_eq_def.expr_info()
# Out:
# 0. forall_{x, y} ((x >= y) = ((x > y) or (x = y)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> ((x >= y) = ((x > y) or (x = y)))
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. (x >= y) = ((x > y) or (x = y))
#    core type: Operation
#    operator: 13
#    operands: 4
# 4. (x >= y, (x > y) or (x = y))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x >= y
#    core type: Operation
#    operator: 7
#    operands: 14
# 6. (x > y) or (x = y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. >=
#    core type: Literal
#    sub-expressions:
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (x > y, x = y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x > y
#     core type: Operation
#     operator: 12
#     operands: 14
# 11. x = y
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. >
#     core type: Literal
# ...
