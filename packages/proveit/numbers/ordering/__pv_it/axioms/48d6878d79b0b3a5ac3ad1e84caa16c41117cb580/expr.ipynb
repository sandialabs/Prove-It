# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, n, rho
from proveit.logic import And, Equals, InSet
from proveit.numbers import one
from proveit.numbers.ordering import greater_eq_relations, rho_1_to_n, sequential_x_relations, x_relation_sequence

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([rho_1_to_n], Conditional(Equals(x_relation_sequence, sequential_x_relations), And(ExprRange(sub_expr1, InSet(IndexedVar(rho, sub_expr1), greater_eq_relations), one, n))))
# Out:
# expr: (rho_{1}, ..rho_{_a}.., rho_{n}) -> {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\rho_{1}, \ldots, \rho_{n}\right) \mapsto \left\{\left(x_{1} \rho_{1} \ldots  x_{n} \rho_{n} x_{n + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{n} \rho_{n} x_{n + 1}\right)\right) \textrm{ if } \left(\rho_{1} \in \left\{>, \geq, =\right\}\right) \land \ldots \land \left(\rho_{n} \in \left\{>, \geq, =\right\}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (rho_{1}, ..rho_{_a}.., rho_{n}) -> {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).
#    core type: Lambda
#    parameters: 9\n   body: 1
# 1. {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))
#    core type: Operation
#    operator: 40
#    operands: 4
# 3. (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =})
#    core type: Operation
#    operator: 11
# ...
