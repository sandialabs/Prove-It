# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n
from proveit.core_expr_types import x_1_to_np1
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import NaturalPos, Real
from proveit.numbers.ordering import greater_eq_relations, rho_1_to_n, sequential_x_relations, x_relation_sequence

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([x_1_to_np1], Forall([rho_1_to_n], Equals(x_relation_sequence, sequential_x_relations), domains = [greater_eq_relations]), domains = [Real]), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x_{1}, \ldots, x_{n + 1} \in \mathbb{R}}~\left[\forall_{\rho_{1}, \ldots, \rho_{n} \in \left\{>, \geq, =\right\}}~\left(\left(x_{1} \rho_{1} \ldots  x_{n} \rho_{n} x_{n + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{n} \rho_{n} x_{n + 1}\right)\right)\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 49
#    body: 1
# 1. {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))]
#    core type: Operation
#    operator: 12
#    operand: 4
# 3. n in NaturalPos
#    core type: Operation
#    operator: 43
#    operands: 5
# 4. (x_{1}, ..x_{_a}.., x_{n + 1}) -> {forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))) if (x_{1} in Real) and ..(x_{_a} in Real).. and (x_{n + 1} in Real).
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 49, 8
# 6. (x_{1}, ..x_{_a}.., x_{n + 1})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. {forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))) if (x_{1} in Real) and ..(x_{_a} in Real).. and (x_{n + 1} in Real).
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. x_{1}, ..x_{_a}.., x_{n + 1}
#    core type: ExprRange
#    lambda_map: 40
#    start_index: 66
#    end_index: 41
# 10. forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. (x_{1} in Real) and ..(x_{_a} in Real).. and (x_{n + 1} in Real)
#     core type: Operation
#     operator: 29
#     operands: 14
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. (rho_{1}, ..rho_{_a}.., rho_{n}) -> {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).
#     core type: Lambda
#     parameters: 27\n    body: 15
# 14. (x_{1} in Real, ..x_{_a} in Real.., x_{n + 1} in Real)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. (x_{1} in Real), ..(x_{_a} in Real).., (x_{n + 1} in Real)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 66
#     end_index: 41
# 17. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))
#     core type: Operation
#     operator: 60
#     operands: 20
# 18. (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =})
#     core type: Operation
#     operator: 29
#     operands: 21
# 19. _a -> (x_{_a} in Real)
#     core type: Lambda
#     parameter: 52
#     body: 22
# 20. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}, (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (rho_{1} in {>, >=, =}, ..rho_{_a} in {>, >=, =}.., rho_{n} in {>, >=, =})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. x_{_a} in Real
#     core type: Operation
#     operator: 43
#     operands: 26
# 23. x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}
#     core type: Operation
#     operators: 27
#     operands: 28
# 24. (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (rho_{1} in {>, >=, =}), ..(rho_{_a} in {>, >=, =}).., (rho_{n} in {>, >=, =})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 66
#     end_index: 49
# 26. (x_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. (rho_{1}, ..rho_{i}.., rho_{n})
#     core type: ExprTuple
#     sub-expressions: 34
# 28. (x_{1}, ..x_{i}.., x_{n}, x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. (x_{1} rho_{1} x_{1 + 1}, ..x_{i} rho_{i} x_{i + 1}.., x_{n} rho_{n} x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 37
# 31. _a -> (rho_{_a} in {>, >=, =})
#     core type: Lambda
#     parameter: 52
#     body: 38
# 32. x_{_a}
#     core type: IndexedVar
# variable: 61
# index: 52
# 33. Real
#     core type: Literal
#     sub-expressions:
# 34. rho_{1}, ..rho_{i}.., rho_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 66
#     end_index: 49
# 35. x_{1}, ..x_{i}.., x_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 66
#     end_index: 49
# 36. x_{n + 1}
#     core type: IndexedVar
# variable: 61
# index: 41
# 37. (x_{1} rho_{1} x_{1 + 1}), ..(x_{i} rho_{i} x_{i + 1}).., (x_{n} rho_{n} x_{n + 1})
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 66
#     end_index: 49
# 38. rho_{_a} in {>, >=, =}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. i -> rho_{i}
#     core type: Lambda
#     parameter: 65
#     body: 50
# 40. i -> x_{i}
#     core type: Lambda
#     parameter: 65
#     body: 56
# 41. n + 1
#     core type: Operation
#     operator: 63
#     operands: 45
# 42. i -> (x_{i} rho_{i} x_{i + 1})
#     core type: Lambda
#     parameter: 65
#     body: 46
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (rho_{_a}, {>, >=, =})
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 66
# 46. x_{i} rho_{i} x_{i + 1}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. rho_{_a}
#     core type: IndexedVar
# variable: 55
# index: 52
# 48. {>, >=, =}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. rho_{i}
#     core type: IndexedVar
# variable: 55
# index: 65
# 51. (x_{i}, x_{i + 1})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 52. _a
#     core type: Variable
#     sub-expressions:
# 53. Set
#     core type: Literal
#     sub-expressions:
# 54. (>, >=, =)
#     core type: ExprTuple
#     sub-expressions: 58, 59, 60
# 55. rho
#     core type: Variable
#     sub-expressions:
# 56. x_{i}
#     core type: IndexedVar
# variable: 61
# index: 65
# 57. x_{i + 1}
#     core type: IndexedVar
# variable: 61
# index: 62
# 58. >
#     core type: Literal
#     sub-expressions:
# 59. >=
#     core type: Literal
#     sub-expressions:
# 60. =
#     core type: Literal
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. i + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. i
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
