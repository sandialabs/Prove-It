# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#greater_sequence_def">greater_sequence_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import greater_sequence_def

# %%
# check that the built expression is the same as the stored expression
assert greater_sequence_def.expr == stored_expr
assert greater_sequence_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: greater_sequence_def matches stored_expr")
# Out:
# Passed sanity check: greater_sequence_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greater_sequence_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n + 1} \in \mathbb{R}}~\left[\forall_{\rho_{1}, \ldots, \rho_{n} \in \left\{>, \geq, =\right\}}~\left(\left(x_{1} \rho_{1} \ldots  x_{n} \rho_{n} x_{n + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{n} \rho_{n} x_{n + 1}\right)\right)\right)\right]\right]

# %%
# display the expression information
greater_sequence_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))]]
#    core type: Operation
#    operator: 13
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 50
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalPos.
#    core type: Conditional
# ...
