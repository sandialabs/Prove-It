# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#reverse_relation">reverse_relation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import reverse_relation

# %%
# check that the built expression is the same as the stored expression
assert reverse_relation.expr == stored_expr
assert reverse_relation.expr._style_id == stored_expr._style_id
print("Passed sanity check: reverse_relation matches stored_expr")
# Out:
# Passed sanity check: reverse_relation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reverse_relation.latex())
# Out:
# \vdash \forall_{x, y}~\left(\left(y > x\right) = \left(x < y\right)\right)

# %%
# display the expression information
reverse_relation.expr_info()
# Out:
# 0. forall_{x, y} ((y > x) = (x < y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> ((y > x) = (x < y))
#    core type: Lambda
#    parameters: 11\n   body: 3
# 3. (y > x) = (x < y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (y > x, x < y)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. y > x
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. x < y
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. >
#    core type: Literal
#    sub-expressions:
# 9. (y, x)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. <
#     core type: Literal
#     sub-expressions:
# 11. (x, y)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
