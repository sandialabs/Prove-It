# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#min_def_multi">min_def_multi</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import min_def_multi

# %%
# check that the built expression is the same as the stored expression
assert min_def_multi.expr == stored_expr
assert min_def_multi.expr._style_id == stored_expr._style_id
print("Passed sanity check: min_def_multi matches stored_expr")
# Out:
# Passed sanity check: min_def_multi matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{m}, b \in \mathbb{R}}~\left({\rm Min}\left(a_{1}, a_{2}, \ldots, a_{m}, b\right) = {\rm Min}\left({\rm Min}\left(a_{1}, a_{2}, \ldots, a_{m}\right), b\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{m}, b in Real} (Min(a_{1}, a_{2}, ..., a_{m}, b) = Min(Min(a_{1}, a_{2}, ..., a_{m}), b))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{a_{1}, a_{2}, ..., a_{m}, b in Real} (Min(a_{1}, a_{2}, ..., a_{m}, b) = Min(Min(a_{1}, a_{2}, ..., a_{m}), b)) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{a_{1}, a_{2}, ..., a_{m}, b in Real} (Min(a_{1}, a_{2}, ..., a_{m}, b) = Min(Min(a_{1}, a_{2}, ..., a_{m}), b)) if m in NaturalPos.
#    core type: Lambda
#    parameter: 38
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 38
# 4. {forall_{a_{1}, a_{2}, ..., a_{m}, b in Real} (Min(a_{1}, a_{2}, ..., a_{m}, b) = Min(Min(a_{1}, a_{2}, ..., a_{m}), b)) if m in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
