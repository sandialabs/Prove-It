# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Add, Neg, four, one, three

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(Add(one, one))
expr = ExprTuple(Add(Add(three, one), sub_expr1, one), Add(four, sub_expr1, one))
# Out:
# expr: ((3 + 1) - (1 + 1) + 1, 4 - (1 + 1) + 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(3 + 1\right) - \left(1 + 1\right) + 1, 4 - \left(1 + 1\right) + 1\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((3 + 1) - (1 + 1) + 1, 4 - (1 + 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (3 + 1) - (1 + 1) + 1
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. 4 - (1 + 1) + 1
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. (3 + 1, -(1 + 1), 1)
#    core type: ExprTuple
#    sub-expressions: 5, 7, 14
# 4. (4, -(1 + 1), 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 14
# 5. 3 + 1
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. 4
#    core type: Literal
#    sub-expressions:
# 7. -(1 + 1)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. (3, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. 1 + 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (1, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 14. 1
#     core type: Literal
#     sub-expressions:
