# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i
from proveit.logic import And
from proveit.numbers import one, three
from proveit.numbers.ordering import sequential_x_relation

# %%
# build up the expression from sub-expressions
expr = And(ExprRange(i, sequential_x_relation, one, three))
# Out:
# expr: (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{3} \rho_{3} x_{3 + 1}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x_{1} rho_{1} x_{1 + 1}, ..x_{i} rho_{i} x_{i + 1}.., x_{3} rho_{3} x_{3 + 1})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1} rho_{1} x_{1 + 1}), ..(x_{i} rho_{i} x_{i + 1}).., (x_{3} rho_{3} x_{3 + 1})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 17
#    end_index: 5
# 4. i -> (x_{i} rho_{i} x_{i + 1})
#    core type: Lambda
#    parameter: 16
#    body: 6
# 5. 3
#    core type: Literal
#    sub-expressions:
# 6. x_{i} rho_{i} x_{i + 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. rho_{i}
#    core type: IndexedVar
# variable: 9
# index: 16
# 8. (x_{i}, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. rho
#    core type: Variable
#    sub-expressions:
# 10. x_{i}
#     core type: IndexedVar
# variable: 12
# index: 16
# 11. x_{i + 1}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. i + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
