# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, OperationSequence, Variable, i, rho, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, one, three
from proveit.numbers.ordering import less_eq_relations, sequential_x_relation

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(OperationSequence([ExprRange(i, IndexedVar(rho, i), one, three)], [ExprRange(i, IndexedVar(x, i), one, three), IndexedVar(x, Add(three, one))]), And(ExprRange(i, sequential_x_relation, one, three))), And(ExprRange(sub_expr1, InSet(IndexedVar(rho, sub_expr1), less_eq_relations), one, three)))
# Out:
# expr: {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})) if (rho_{1} in {<, <=, =}) and ..(rho_{_a} in {<, <=, =}).. and (rho_{3} in {<, <=, =}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x_{1} \rho_{1} \ldots  x_{3} \rho_{3} x_{3 + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{3} \rho_{3} x_{3 + 1}\right)\right) \textrm{ if } \left(\rho_{1} \in \left\{<, \leq, =\right\}\right) \land \ldots \land \left(\rho_{3} \in \left\{<, \leq, =\right\}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})) if (rho_{1} in {<, <=, =}) and ..(rho_{_a} in {<, <=, =}).. and (rho_{3} in {<, <=, =}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1}))
#    core type: Operation
#    operator: 39
#    operands: 3
# 2. (rho_{1} in {<, <=, =}) and ..(rho_{_a} in {<, <=, =}).. and (rho_{3} in {<, <=, =})
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}, (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (rho_{1} in {<, <=, =}, ..rho_{_a} in {<, <=, =}.., rho_{3} in {<, <=, =})
#    core type: ExprTuple
# ...
