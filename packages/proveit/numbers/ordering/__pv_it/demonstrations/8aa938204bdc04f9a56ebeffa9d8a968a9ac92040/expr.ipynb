# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, OperationSequence, Variable, i, rho, x
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Real, one, three
from proveit.numbers.ordering import less_eq_relations, sequential_x_relation

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(three, one)
expr = Forall([ExprRange(sub_expr1, IndexedVar(x, sub_expr1), one, sub_expr2)], Forall([ExprRange(sub_expr1, IndexedVar(rho, sub_expr1), one, three)], Equals(OperationSequence([ExprRange(i, IndexedVar(rho, i), one, three)], [ExprRange(i, IndexedVar(x, i), one, three), IndexedVar(x, sub_expr2)]), And(ExprRange(i, sequential_x_relation, one, three))), domains = [less_eq_relations]), domains = [Real])
# Out:
# expr: forall_{x_{1}, ..x_{_a}.., x_{3 + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x_{1}, \ldots, x_{3 + 1} \in \mathbb{R}}~\left[\forall_{\rho_{1}, \ldots, \rho_{3} \in \left\{<, \leq, =\right\}}~\left(\left(x_{1} \rho_{1} \ldots  x_{3} \rho_{3} x_{3 + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{3} \rho_{3} x_{3 + 1}\right)\right)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x_{1}, ..x_{_a}.., x_{3 + 1} in Real} [forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})))]
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. (x_{1}, ..x_{_a}.., x_{3 + 1}) -> {forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1}))) if (x_{1} in Real) and ..(x_{_a} in Real).. and (x_{3 + 1} in Real).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x_{1}, ..x_{_a}.., x_{3 + 1})
#    core type: ExprTuple
#    sub-expressions: 4
# ...
