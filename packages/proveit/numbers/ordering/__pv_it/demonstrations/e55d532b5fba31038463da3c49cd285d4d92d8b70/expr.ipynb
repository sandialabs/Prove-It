# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a
from proveit.core_expr_types import Len
from proveit.numbers import Add, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(three, Len([ExprRange(a, a, Add(one, one), Add(three, one))]))
# Out:
# expr: (3, |(1 + 1, ..a.., 3 + 1)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(3, |\left(1 + 1, \ldots, 3 + 1\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (3, |(1 + 1, ..a.., 3 + 1)|)
#    core type: ExprTuple
#    sub-expressions: 13, 1
# 1. |(1 + 1, ..a.., 3 + 1)|
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. length
#    core type: Literal
#    sub-expressions:
# 3. ((1 + 1, ..a.., 3 + 1))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (1 + 1, ..a.., 3 + 1)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (1 + 1), ..a.., (3 + 1)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. a -> a
#    core type: Lambda
#    parameter: 9
#    body: 9
# 7. 1 + 1
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. 3 + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. (1, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (3, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
