# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, x
from proveit.numbers import Add, one, three

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, IndexedVar(x, sub_expr1), one, three), IndexedVar(x, Add(three, one)))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{3}, x_{3 + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{3}, x_{3 + 1}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{3}, x_{3 + 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x_{1}, ..x_{_a}.., x_{3}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 11
#    end_index: 10
# 2. x_{3 + 1}
#    core type: IndexedVar
# variable: 8
# index: 4
# 3. _a -> x_{_a}
#    core type: Lambda
#    parameter: 9
#    body: 5
# 4. 3 + 1
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x_{_a}
#    core type: IndexedVar
# variable: 8
# index: 9
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (3, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
