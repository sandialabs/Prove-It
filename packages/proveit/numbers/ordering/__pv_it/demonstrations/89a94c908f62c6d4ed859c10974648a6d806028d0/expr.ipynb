# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, x, y, z
from proveit.logic import Equals
from proveit.numbers import Less, LessEq
from proveit.numbers.ordering import i_plus_1

# %%
# build up the expression from sub-expressions
sub_expr1 = IndexedVar(x, i_plus_1)
expr = ExprTuple(Less(x, sub_expr1), LessEq(y, sub_expr1), Equals(z, sub_expr1))
# Out:
# expr: (x < x_{i + 1}, y <= x_{i + 1}, z = x_{i + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x < x_{i + 1}, y \leq x_{i + 1}, z = x_{i + 1}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x < x_{i + 1}, y <= x_{i + 1}, z = x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. x < x_{i + 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 2. y <= x_{i + 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. z = x_{i + 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. <
#    core type: Literal
#    sub-expressions:
# 5. (x, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (y, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (z, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. z
#     core type: Variable
#     sub-expressions:
# 12. x_{i + 1}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. i + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
