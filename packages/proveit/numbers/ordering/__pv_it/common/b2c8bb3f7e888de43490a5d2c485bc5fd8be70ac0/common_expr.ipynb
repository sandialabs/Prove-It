# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#n_plus_1">n_plus_1</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import n_plus_1

# %%
# check that the built expression is the same as the stored expression
assert n_plus_1 == stored_expr
assert n_plus_1._style_id == stored_expr._style_id
print("Passed sanity check: n_plus_1 matches stored_expr")
# Out:
# Passed sanity check: n_plus_1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(n_plus_1.latex())
# Out:
# n + 1

# %%
# display the expression information
n_plus_1.expr_info()
# Out:
# 0. n + 1
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (n, 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. 1
#    core type: Literal
#    sub-expressions:
