# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Operation.html">Operation</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, Operation, i, rho, x
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = Operation(IndexedVar(rho, i), [IndexedVar(x, i), IndexedVar(x, Add(i, one))])
# Out:
# expr: x_{i} rho_{i} x_{i + 1}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x_{i} \rho_{i} x_{i + 1}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x_{i} rho_{i} x_{i + 1}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. rho_{i}
#    core type: IndexedVar
# variable: 3
# index: 10
# 2. (x_{i}, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. rho
#    core type: Variable
#    sub-expressions:
# 4. x_{i}
#    core type: IndexedVar
# variable: 6
# index: 10
# 5. x_{i + 1}
#    core type: IndexedVar
# variable: 6
# index: 7
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. i + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (i, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
