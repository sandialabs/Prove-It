# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#reverse_greater_eq">reverse_greater_eq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import reverse_greater_eq

# %%
# check that the built expression is the same as the stored expression
assert reverse_greater_eq.expr == stored_expr
assert reverse_greater_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: reverse_greater_eq matches stored_expr")
# Out:
# Passed sanity check: reverse_greater_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reverse_greater_eq.latex())
# Out:
# \vdash \forall_{x, y~|~x \geq y}~\left(y \leq x\right)

# %%
# display the expression information
reverse_greater_eq.expr_info()
# Out:
# 0. forall_{x, y | x >= y} (y <= x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {y <= x if x >= y.
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. {y <= x if x >= y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. y <= x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x >= y
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (y, x)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. >=
#    core type: Literal
#    sub-expressions:
# 9. (x, y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. y
#     core type: Variable
#     sub-expressions:
