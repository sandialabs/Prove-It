# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.logic import Forall
from proveit.numbers import GreaterEq, RealNonNeg, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a], GreaterEq(a, zero), domains = [RealNonNeg])
# Out:
# expr: forall_{a in RealNonNeg} (a >= 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}^{\ge 0}}~\left(a \geq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in RealNonNeg} (a >= 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {a >= 0 if a in RealNonNeg.
#    core type: Lambda
#    parameter: 11
#    body: 3
# 3. {a >= 0 if a in RealNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a >= 0
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. a in RealNonNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. >=
#    core type: Literal
#    sub-expressions:
# 7. (a, 0)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. RealNonNeg
#     core type: Literal
#     sub-expressions:
