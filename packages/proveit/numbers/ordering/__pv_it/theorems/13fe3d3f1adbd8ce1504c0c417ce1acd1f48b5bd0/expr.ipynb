# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.logic import InSet
from proveit.numbers import GreaterEq, Real

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Real), InSet(b, Real), InSet(c, Real), GreaterEq(a, b))
# Out:
# expr: (a in Real, b in Real, c in Real, a >= b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}, a \geq b\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real, b in Real, c in Real, a >= b)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a in Real
#    core type: Operation
#    operator: 7
#    operands: 5
# 2. b in Real
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. c in Real
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. a >= b
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 6. (b, Real)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (c, Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. >=
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. Real
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
