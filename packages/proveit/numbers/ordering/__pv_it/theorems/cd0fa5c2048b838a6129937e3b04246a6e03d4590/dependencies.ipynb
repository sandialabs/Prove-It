# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#eq__in__greater_eq_relations">eq__in__greater_eq_relations</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/eq__in__greater_eq_relations/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.ordering import eq__in__greater_eq_relations

# %%
# %dependencies eq__in__greater_eq_relations
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon eq__in__greater_eq_relations</h3>
