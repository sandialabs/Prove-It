# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#less_add_both">less_add_both</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import less_add_both

# %%
# check that the built expression is the same as the stored expression
assert less_add_both.expr == stored_expr
assert less_add_both.expr._style_id == stored_expr._style_id
print("Passed sanity check: less_add_both matches stored_expr")
# Out:
# Passed sanity check: less_add_both matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(less_add_both.latex())
# Out:
# \vdash \forall_{a, b, c, d \in \mathbb{R}~|~a < b, c \leq d}~\left(\left(a + c\right) < \left(b + d\right)\right)

# %%
# display the expression information
less_add_both.expr_info()
# Out:
# 0. forall_{a, b, c, d in Real | a < b, c <= d} ((a + c) < (b + d))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d) -> {(a + c) < (b + d) if a in Real ,  b in Real ,  c in Real ,  d in Real ,  a < b ,  c <= d.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 31, 32, 33, 34
# 4. {(a + c) < (b + d) if a in Real ,  b in Real ,  c in Real ,  d in Real ,  a < b ,  c <= d.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a + c) < (b + d)
#    core type: Operation
#    operator: 26
#    operands: 7
# 6. (a in Real) and (b in Real) and (c in Real) and (d in Real) and (a < b) and (c <= d)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a + c, b + d)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real, c in Real, d in Real, a < b, c <= d)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16, 17
# 10. a + c
#     core type: Operation
#     operator: 19
#     operands: 18
# 11. b + d
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. a in Real
#     core type: Operation
#     operator: 24
#     operands: 21
# 13. b in Real
#     core type: Operation
#     operator: 24
#     operands: 22
# 14. c in Real
#     core type: Operation
#     operator: 24
#     operands: 23
# 15. d in Real
#     core type: Operation
#     operator: 24
#     operands: 25
# 16. a < b
#     core type: Operation
#     operator: 26
#     operands: 27
# 17. c <= d
#     core type: Operation
#     operator: 28
#     operands: 29
# 18. (a, c)
#     core type: ExprTuple
#     sub-expressions: 31, 33
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (b, d)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 21. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 31, 30
# 22. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 32, 30
# 23. (c, Real)
#     core type: ExprTuple
#     sub-expressions: 33, 30
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (d, Real)
#     core type: ExprTuple
#     sub-expressions: 34, 30
# 26. <
#     core type: Literal
#     sub-expressions:
# 27. (a, b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. <=
#     core type: Literal
#     sub-expressions:
# 29. (c, d)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. Real
#     core type: Literal
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. c
#     core type: Variable
#     sub-expressions:
# 34. d
#     core type: Variable
#     sub-expressions:
