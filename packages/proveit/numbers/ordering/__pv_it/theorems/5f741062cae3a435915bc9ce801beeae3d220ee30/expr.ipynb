# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.logic import InSet
from proveit.numbers import GreaterEq, Real, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Real), InSet(b, Real), InSet(c, Real), GreaterEq(a, b), GreaterEq(c, zero))
# Out:
# expr: (a in Real, b in Real, c in Real, a >= b, c >= 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}, a \geq b, c \geq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Real, b in Real, c in Real, a >= b, c >= 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. a in Real
#    core type: Operation
#    operator: 8
#    operands: 6
# 2. b in Real
#    core type: Operation
#    operator: 8
#    operands: 7
# 3. c in Real
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. a >= b
#    core type: Operation
#    operator: 11
#    operands: 10
# 5. c >= 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 7. (b, Real)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (c, Real)
#    core type: ExprTuple
#    sub-expressions: 16, 13
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. >=
#     core type: Literal
#     sub-expressions:
# 12. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Real
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
