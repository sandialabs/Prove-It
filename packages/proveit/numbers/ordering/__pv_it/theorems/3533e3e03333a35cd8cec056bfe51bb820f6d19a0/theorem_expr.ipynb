# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#greater_eq_add_left">greater_eq_add_left</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import greater_eq_add_left

# %%
# check that the built expression is the same as the stored expression
assert greater_eq_add_left.expr == stored_expr
assert greater_eq_add_left.expr._style_id == stored_expr._style_id
print("Passed sanity check: greater_eq_add_left matches stored_expr")
# Out:
# Passed sanity check: greater_eq_add_left matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greater_eq_add_left.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{R}~|~a \geq b, c \geq 0}~\left(\left(a + c\right) \geq b\right)

# %%
# display the expression information
greater_eq_add_left.expr_info()
# Out:
# 0. forall_{a, b, c in Real | a >= b, c >= 0} ((a + c) >= b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(a + c) >= b if a in Real ,  b in Real ,  c in Real ,  a >= b ,  c >= 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 26, 27, 28
# 4. {(a + c) >= b if a in Real ,  b in Real ,  c in Real ,  a >= b ,  c >= 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a + c) >= b
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (a in Real) and (b in Real) and (c in Real) and (a >= b) and (c >= 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a + c, b)
#    core type: ExprTuple
#    sub-expressions: 10, 27
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real, c in Real, a >= b, c >= 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# ...
