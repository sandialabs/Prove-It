# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#greater_add_right">greater_add_right</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.ordering import greater_add_right

# %%
# check that the built expression is the same as the stored expression
assert greater_add_right.expr == stored_expr
assert greater_add_right.expr._style_id == stored_expr._style_id
print("Passed sanity check: greater_add_right matches stored_expr")
# Out:
# Passed sanity check: greater_add_right matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greater_add_right.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{R}~|~a > b, 0 \geq c}~\left(a > \left(b + c\right)\right)

# %%
# display the expression information
greater_add_right.expr_info()
# Out:
# 0. forall_{a, b, c in Real | a > b, 0 >= c} (a > (b + c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {a > (b + c) if a in Real ,  b in Real ,  c in Real ,  a > b ,  0 >= c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 27, 28, 30
# 4. {a > (b + c) if a in Real ,  b in Real ,  c in Real ,  a > b ,  0 >= c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a > (b + c)
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. (a in Real) and (b in Real) and (c in Real) and (a > b) and (0 >= c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a, b + c)
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real, c in Real, a > b, 0 >= c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# ...
