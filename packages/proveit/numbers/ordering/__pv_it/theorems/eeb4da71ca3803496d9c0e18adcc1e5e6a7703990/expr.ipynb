# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c
from proveit.logic import And, InSet
from proveit.numbers import Add, LessEq, Real, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Add(a, c), b), And(InSet(a, Real), InSet(b, Real), InSet(c, Real), LessEq(a, b), LessEq(c, zero)))
# Out:
# expr: {(a + c) <= b if a in Real ,  b in Real ,  c in Real ,  a <= b ,  c <= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a + c\right) \leq b \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a \leq b ,  c \leq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a + c) <= b if a in Real ,  b in Real ,  c in Real ,  a <= b ,  c <= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a + c) <= b
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a in Real) and (b in Real) and (c in Real) and (a <= b) and (c <= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a + c, b)
#    core type: ExprTuple
#    sub-expressions: 6, 23
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Real, b in Real, c in Real, a <= b, c <= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 6. a + c
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. a in Real
#    core type: Operation
#    operator: 16
#    operands: 14
# 8. b in Real
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. c in Real
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. a <= b
#     core type: Operation
#     operator: 19
#     operands: 18
# 11. c <= 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (a, c)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 14. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 15. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c, Real)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 18. (a, b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. Real
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. 0
#     core type: Literal
#     sub-expressions:
