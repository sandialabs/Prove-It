# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c
from proveit.logic import And, InSet
from proveit.numbers import Add, Greater, GreaterEq, Real, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Greater(a, Add(b, c)), And(InSet(a, Real), InSet(b, Real), InSet(c, Real), Greater(a, b), GreaterEq(zero, c)))
# Out:
# expr: {a > (b + c) if a in Real ,  b in Real ,  c in Real ,  a > b ,  0 >= c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a > \left(b + c\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a > b ,  0 \geq c\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a > (b + c) if a in Real ,  b in Real ,  c in Real ,  a > b ,  0 >= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a > (b + c)
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. (a in Real) and (b in Real) and (c in Real) and (a > b) and (0 >= c)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b + c)
#    core type: ExprTuple
#    sub-expressions: 23, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Real, b in Real, c in Real, a > b, 0 >= c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 6. b + c
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. a in Real
#    core type: Operation
#    operator: 16
#    operands: 14
# 8. b in Real
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. c in Real
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. a > b
#     core type: Operation
#     operator: 18
#     operands: 19
# 11. 0 >= c
# ...
