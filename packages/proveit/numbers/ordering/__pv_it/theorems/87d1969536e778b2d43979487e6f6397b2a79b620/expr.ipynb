# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.logic import Forall
from proveit.numbers import Add, Greater, Real, one

# %%
# build up the expression from sub-expressions
expr = Forall([a], Greater(Add(a, one), a), domains = [Real])
# Out:
# expr: forall_{a in Real} ((a + 1) > a)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}}~\left(\left(a + 1\right) > a\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Real} ((a + 1) > a)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {(a + 1) > a if a in Real.
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {(a + 1) > a if a in Real.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a + 1) > a
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. a in Real
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. >
#    core type: Literal
#    sub-expressions:
# 7. (a + 1, a)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a, Real)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. a + 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (a, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
