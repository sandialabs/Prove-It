# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../_theory_.ipynb">sets</a>.rational
# ========
#
# Provide description here.

# %%
import proveit
# %theory # toggles between interactive and static modes
