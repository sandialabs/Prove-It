# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">division</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#prod_of_fracs">prod_of_fracs</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving prod_of_fracs
