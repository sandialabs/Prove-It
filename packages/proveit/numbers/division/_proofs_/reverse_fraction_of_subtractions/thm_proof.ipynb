# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">division</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#reverse_fraction_of_subtractions">reverse_fraction_of_subtractions</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving reverse_fraction_of_subtractions
