# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Px, d, x, y, z
from proveit.logic import Equals, Forall, Implies, InSet, NotEquals
from proveit.numbers import Complex, Interval, Sum, frac, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = Interval(y, z)
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(Px, Complex), domain = sub_expr2), Forall(instance_param_or_params = [d], instance_expr = Equals(frac(Sum(index_or_indices = sub_expr1, summand = Px, domain = sub_expr2), d), Sum(index_or_indices = sub_expr1, summand = frac(Px, d), domain = sub_expr2)), domain = Complex, condition = NotEquals(d, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{x \in \{y~\ldotp \ldotp~z\}}~\left(P\left(x\right) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{d \in \mathbb{C}~|~d \neq 0}~\left(\frac{\sum_{x = y}^{z} P\left(x\right)}{d} = \left(\sum_{x = y}^{z} \frac{P\left(x\right)}{d}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{x in {y .. z}} (P(x) in Complex)] => [forall_{d in Complex | d != 0} (((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d)))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in {y .. z}} (P(x) in Complex), forall_{d in Complex | d != 0} (((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x in {y .. z}} (P(x) in Complex)
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. forall_{d in Complex | d != 0} (((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (x -> {P(x) in Complex if x in {y .. z}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (d -> {((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d)) if d in Complex ,  d != 0.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. x -> {P(x) in Complex if x in {y .. z}.
#    core type: Lambda
#    parameter: 50
#    body: 10
# 9. d -> {((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d)) if d in Complex ,  d != 0.
#    core type: Lambda
#    parameter: 44
#    body: 12
# 10. {P(x) in Complex if x in {y .. z}.
#     core type: Conditional
#     value: 13
#     condition: 42
# 11. (d)
#     core type: ExprTuple
#     sub-expressions: 44
# 12. {((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d)) if d in Complex ,  d != 0.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. P(x) in Complex
#     core type: Operation
#     operator: 45
#     operands: 16
# 14. ((Sum_{x = y}^{z} P(x)) / d) = (Sum_{x = y}^{z} (P(x) / d))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (d in Complex) and (d != 0)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (P(x), Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 32
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. ((Sum_{x = y}^{z} P(x)) / d, Sum_{x = y}^{z} (P(x) / d))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (d in Complex, d != 0)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (Sum_{x = y}^{z} P(x)) / d
#     core type: Operation
#     operator: 40
#     operands: 25
# 22. Sum_{x = y}^{z} (P(x) / d)
#     core type: Operation
#     operator: 34
#     operand: 31
# 23. d in Complex
#     core type: Operation
#     operator: 45
#     operands: 27
# 24. d != 0
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (Sum_{x = y}^{z} P(x), d)
#     core type: ExprTuple
#     sub-expressions: 30, 44
# 26. (x -> {P(x) / d if x in {y .. z}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 32
# 28. !=
#     core type: Literal
#     sub-expressions:
# 29. (d, 0)
#     core type: ExprTuple
#     sub-expressions: 44, 33
# 30. Sum_{x = y}^{z} P(x)
#     core type: Operation
#     operator: 34
#     operand: 37
# 31. x -> {P(x) / d if x in {y .. z}.
#     core type: Lambda
#     parameter: 50
#     body: 36
# 32. Complex
#     core type: Literal
#     sub-expressions:
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (x -> {P(x) if x in {y .. z}.)
#     core type: ExprTuple
#     sub-expressions: 37
# 36. {P(x) / d if x in {y .. z}.
#     core type: Conditional
#     value: 38
#     condition: 42
# 37. x -> {P(x) if x in {y .. z}.
#     core type: Lambda
#     parameter: 50
#     body: 39
# 38. P(x) / d
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. {P(x) if x in {y .. z}.
#     core type: Conditional
#     value: 43
#     condition: 42
# 40. /
#     core type: Literal
#     sub-expressions:
# 41. (P(x), d)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. x in {y .. z}
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. P(x)
#     core type: Operation
#     operator: 47
#     operand: 50
# 44. d
#     core type: Variable
#     sub-expressions:
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x, {y .. z})
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 47. P
#     core type: Variable
#     sub-expressions:
# 48. (x)
#     core type: ExprTuple
#     sub-expressions: 50
# 49. {y .. z}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (y, z)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. z
#     core type: Variable
#     sub-expressions:
