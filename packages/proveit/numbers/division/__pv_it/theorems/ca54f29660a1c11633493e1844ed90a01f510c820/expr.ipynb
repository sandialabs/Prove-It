# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n, x, y
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, NaturalPos, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(Mult(w_1_to_m, frac(x, y), z_1_to_n), frac(Mult(w_1_to_m, x, z_1_to_n), y)), domain = Complex, condition = NotEquals(y, zero)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}^+}~\left[\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0}~\left(\left(w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \frac{x}{y}\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}\right) = \frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n in NaturalPos} [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 57, 60
# 4. {forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 22
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. m in NaturalPos
#     core type: Operation
#     operator: 49
#     operands: 15
# 12. n in NaturalPos
#     core type: Operation
#     operator: 49
#     operands: 16
# 13. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 52, 53, 51, 54
# 14. {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 57, 19
# 16. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 60, 19
# 17. (w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}, (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29, 30
# 24. w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 46
#     operands: 31
# 25. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 44
#     operands: 32
# 26. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 59
#     end_index: 57
# 27. x in Complex
#     core type: Operation
#     operator: 49
#     operands: 34
# 28. y in Complex
#     core type: Operation
#     operator: 49
#     operands: 35
# 29. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 59
#     end_index: 60
# 30. y != 0
#     core type: Operation
#     operator: 37
#     operands: 38
# 31. (w_{1}, w_{2}, ..., w_{m}, x / y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 52, 39, 54
# 32. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 40, 51
# 33. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 66
#     body: 41
# 34. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 35. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 55
# 36. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 66
#     body: 42
# 37. !=
#     core type: Literal
#     sub-expressions:
# 38. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 51, 43
# 39. x / y
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. w_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 48
# 42. z_{_a} in Complex
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. 0
#     core type: Literal
#     sub-expressions:
# 44. /
#     core type: Literal
#     sub-expressions:
# 45. (x, y)
#     core type: ExprTuple
#     sub-expressions: 53, 51
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (w_{1}, w_{2}, ..., w_{m}, x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 52, 53, 54
# 48. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 61, 55
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 55
# 51. y
#     core type: Variable
#     sub-expressions:
# 52. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 59
#     end_index: 57
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 55. Complex
#     core type: Literal
#     sub-expressions:
# 56. _a -> w_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 61
# 57. m
#     core type: Variable
#     sub-expressions:
# 58. _a -> z_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 62
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. n
#     core type: Variable
#     sub-expressions:
# 61. w_{_a}
#     core type: IndexedVar
# variable: 63
# index: 66
# 62. z_{_a}
#     core type: IndexedVar
# variable: 64
# index: 66
# 63. w
#     core type: Variable
#     sub-expressions:
# 64. z
#     core type: Variable
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
