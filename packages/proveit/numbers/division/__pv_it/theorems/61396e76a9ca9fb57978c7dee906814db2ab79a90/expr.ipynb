# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, n, x, y
from proveit.core_expr_types import x_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Add, Complex, NaturalPos, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n, y], instance_expr = Equals(frac(Add(x_1_to_n), y), Add(ExprRange(sub_expr1, frac(IndexedVar(x, sub_expr1), y), one, n))), domain = Complex, condition = NotEquals(y, zero)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n}, y \in \mathbb{C}~|~y \neq 0}~\left(\frac{x_{1} +  x_{2} +  \ldots +  x_{n}}{y} = \left(\frac{x_{1}}{y} +  \frac{x_{2}}{y} +  \ldots +  \frac{x_{n}}{y}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 45
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 45
# 4. {forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y))) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 38
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, x_{2}, ..., x_{n}, y) -> {((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)) if (x_{1} in Complex) ,  (x_{2} in Complex) ,  ... ,  (x_{n} in Complex) ,  y in Complex ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 11
# 10. (x_{1}, x_{2}, ..., x_{n}, y) -> {((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)) if (x_{1} in Complex) ,  (x_{2} in Complex) ,  ... ,  (x_{n} in Complex) ,  y in Complex ,  y != 0.
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, x_{2}, ..., x_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 40, 49
# 13. {((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)) if (x_{1} in Complex) ,  (x_{2} in Complex) ,  ... ,  (x_{n} in Complex) ,  y in Complex ,  y != 0.
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. ((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y))
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (x_{1} in Complex) and  (x_{2} in Complex) and  ... and  (x_{n} in Complex) and (y in Complex) and (y != 0)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. ((x_{1} +  x_{2} +  ... +  x_{n}) / y, (x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ((x_{1} in Complex), (x_{2} in Complex), ..., (x_{n} in Complex), y in Complex, y != 0)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 20. (x_{1} +  x_{2} +  ... +  x_{n}) / y
#     core type: Operation
#     operator: 46
#     operands: 25
# 21. (x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)
#     core type: Operation
#     operator: 35
#     operands: 26
# 22. (x_{1} in Complex), (x_{2} in Complex), ..., (x_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 44
#     end_index: 45
# 23. y in Complex
#     core type: Operation
#     operator: 38
#     operands: 28
# 24. y != 0
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (x_{1} +  x_{2} +  ... +  x_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 31, 49
# 26. ((x_{1} / y), (x_{2} / y), ..., (x_{n} / y))
#     core type: ExprTuple
#     sub-expressions: 32
# 27. _a -> (x_{_a} in Complex)
#     core type: Lambda
#     parameter: 52
#     body: 33
# 28. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 42
# 29. !=
#     core type: Literal
#     sub-expressions:
# 30. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 49, 34
# 31. x_{1} +  x_{2} +  ... +  x_{n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (x_{1} / y), (x_{2} / y), ..., (x_{n} / y)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 44
#     end_index: 45
# 33. x_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. 0
#     core type: Literal
#     sub-expressions:
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. _a -> (x_{_a} / y)
#     core type: Lambda
#     parameter: 52
#     body: 41
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (x_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 42
# 40. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 41. x_{_a} / y
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. _a -> x_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. /
#     core type: Literal
#     sub-expressions:
# 47. (x_{_a}, y)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. x_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 49. y
#     core type: Variable
#     sub-expressions:
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. _a
#     core type: Variable
#     sub-expressions:
