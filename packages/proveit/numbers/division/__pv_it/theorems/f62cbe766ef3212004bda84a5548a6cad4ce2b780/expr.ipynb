# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Complex), InSet(b, Complex), NotEquals(b, zero))
# Out:
# expr: (a in Complex) and (b in Complex) and (b != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(b \in \mathbb{C}\right) \land \left(b \neq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex) and (b in Complex) and (b != 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complex, b in Complex, b != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a in Complex
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. b in Complex
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. b != 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. 0
#     core type: Literal
#     sub-expressions:
