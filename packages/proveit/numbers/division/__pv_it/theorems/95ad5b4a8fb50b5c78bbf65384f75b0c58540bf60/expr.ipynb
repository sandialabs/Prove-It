# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(frac(Mult(w_1_to_m, Neg(x), z_1_to_n), y), Neg(frac(Mult(w_1_to_m, x, z_1_to_n), y))), domain = Complex, condition = NotEquals(y, zero))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0}~\left(\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-x\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y} = \left(-\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 46, 47, 40, 48
# 5. {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y, -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17, 18
# 12. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 33
#     operands: 19
# 13. -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: Operation
#     operator: 42
#     operand: 28
# 14. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 52
#     end_index: 50
# 15. x in Complex
#     core type: Operation
#     operator: 36
#     operands: 22
# 16. y in Complex
#     core type: Operation
#     operator: 36
#     operands: 23
# 17. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 52
#     end_index: 53
# 18. y != 0
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 27, 40
# 20. ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: ExprTuple
#     sub-expressions: 28
# 21. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 29
# 22. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 41
# 23. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 24. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 30
# 25. !=
#     core type: Literal
#     sub-expressions:
# 26. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 40, 31
# 27. w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 44
#     operands: 32
# 28. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. w_{_a} in Complex
#     core type: Operation
#     operator: 36
#     operands: 35
# 30. z_{_a} in Complex
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. (w_{1}, w_{2}, ..., w_{m}, -x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 46, 38, 48
# 33. /
#     core type: Literal
#     sub-expressions:
# 34. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 41
# 38. -x
#     core type: Operation
#     operator: 42
#     operand: 47
# 39. w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. y
#     core type: Variable
#     sub-expressions:
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. (x)
#     core type: ExprTuple
#     sub-expressions: 47
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (w_{1}, w_{2}, ..., w_{m}, x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 46, 47, 48
# 46. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 52
#     end_index: 50
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 49. _a -> w_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 54
# 50. m
#     core type: Variable
#     sub-expressions:
# 51. _a -> z_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 55
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. n
#     core type: Variable
#     sub-expressions:
# 54. w_{_a}
#     core type: IndexedVar
# variable: 56
# index: 59
# 55. z_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 56. w
#     core type: Variable
#     sub-expressions:
# 57. z
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
