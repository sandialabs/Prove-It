# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_frac_cancel_numer_left">mult_frac_cancel_numer_left</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import mult_frac_cancel_numer_left

# %%
# check that the built expression is the same as the stored expression
assert mult_frac_cancel_numer_left.expr == stored_expr
assert mult_frac_cancel_numer_left.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_frac_cancel_numer_left matches stored_expr")
# Out:
# Passed sanity check: mult_frac_cancel_numer_left matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_frac_cancel_numer_left.latex())
# Out:
# \vdash \forall_{a, b, c, d, e \in \mathbb{C}~|~b \neq 0}~\left(\left(\frac{a \cdot b}{c} \cdot \frac{d}{b \cdot e}\right) = \left(\frac{a}{c} \cdot \frac{d}{e}\right)\right)

# %%
# display the expression information
mult_frac_cancel_numer_left.expr_info()
# Out:
# 0. forall_{a, b, c, d, e in Complex | b != 0} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  b != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 47, 48, 42, 43, 49
# 4. {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  b != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (b in Complex) and (c in Complex) and (d in Complex) and (e in Complex) and (b != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (((a * b) / c) * (d / (b * e)), (a / c) * (d / e))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complex, b in Complex, c in Complex, d in Complex, e in Complex, b != 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16, 17, 18
# 11. ((a * b) / c) * (d / (b * e))
#     core type: Operation
#     operator: 45
#     operands: 19
# 12. (a / c) * (d / e)
#     core type: Operation
#     operator: 45
#     operands: 20
# 13. a in Complex
#     core type: Operation
#     operator: 25
#     operands: 21
# 14. b in Complex
#     core type: Operation
#     operator: 25
#     operands: 22
# 15. c in Complex
#     core type: Operation
#     operator: 25
#     operands: 23
# 16. d in Complex
#     core type: Operation
#     operator: 25
#     operands: 24
# 17. e in Complex
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. b != 0
#     core type: Operation
#     operator: 27
#     operands: 28
# 19. ((a * b) / c, d / (b * e))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 20. (a / c, d / e)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 21. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 33
# 22. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 33
# 23. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 33
# 24. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 33
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (e, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 33
# 27. !=
#     core type: Literal
#     sub-expressions:
# 28. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 48, 34
# 29. (a * b) / c
#     core type: Operation
#     operator: 38
#     operands: 35
# 30. d / (b * e)
#     core type: Operation
#     operator: 38
#     operands: 36
# 31. a / c
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. d / e
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. Complex
#     core type: Literal
#     sub-expressions:
# 34. 0
#     core type: Literal
#     sub-expressions:
# 35. (a * b, c)
#     core type: ExprTuple
#     sub-expressions: 40, 42
# 36. (d, b * e)
#     core type: ExprTuple
#     sub-expressions: 43, 41
# 37. (a, c)
#     core type: ExprTuple
#     sub-expressions: 47, 42
# 38. /
#     core type: Literal
#     sub-expressions:
# 39. (d, e)
#     core type: ExprTuple
#     sub-expressions: 43, 49
# 40. a * b
#     core type: Operation
#     operator: 45
#     operands: 44
# 41. b * e
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. c
#     core type: Variable
#     sub-expressions:
# 43. d
#     core type: Variable
#     sub-expressions:
# 44. (a, b)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (b, e)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. e
#     core type: Variable
#     sub-expressions:
