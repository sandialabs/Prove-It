# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, m, n, w, x, y, z
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(w, sub_expr1)
sub_expr3 = IndexedVar(z, sub_expr1)
expr = Conditional(Equals(frac(x, Mult(w_1_to_m, Neg(y), z_1_to_n)), Neg(frac(x, Mult(w_1_to_m, y, z_1_to_n)))), And(ExprRange(sub_expr1, InSet(sub_expr2, Complex), one, m), InSet(x, Complex), InSet(y, Complex), ExprRange(sub_expr1, InSet(sub_expr3, Complex), one, n), NotEquals(y, zero), ExprRange(sub_expr1, NotEquals(sub_expr2, zero), one, m), ExprRange(sub_expr1, NotEquals(sub_expr3, zero), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-y\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}} = \left(-\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot y\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}\right) \textrm{ if } \left(w_{1} \in \mathbb{C}\right) ,  \left(w_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(w_{m} \in \mathbb{C}\right) ,  x \in \mathbb{C} ,  y \in \mathbb{C}, \left(z_{1} \in \mathbb{C}\right) ,  \left(z_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(z_{n} \in \mathbb{C}\right) ,  y \neq 0, \left(w_{1} \neq 0\right) ,  \left(w_{2} \neq 0\right) ,  \ldots ,  \left(w_{m} \neq 0\right), \left(z_{1} \neq 0\right) ,  \left(z_{2} \neq 0\right) ,  \ldots ,  \left(z_{n} \neq 0\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)and (w_{1} != 0) and  (w_{2} != 0) and  ... and  (w_{m} != 0)and (z_{1} != 0) and  (z_{2} != 0) and  ... and  (z_{n} != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}), -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13, 14, 15
# 7. x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#    core type: Operation
#    operator: 32
#    operands: 16
# 8. -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#    core type: Operation
#    operator: 45
#    operand: 26
# 9. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#    core type: ExprRange
#    lambda_map: 18
#    start_index: 55
#    end_index: 53
# 10. x in Complex
#     core type: Operation
#     operator: 35
#     operands: 19
# 11. y in Complex
#     core type: Operation
#     operator: 35
#     operands: 20
# 12. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 55
#     end_index: 56
# 13. y != 0
#     core type: Operation
#     operator: 38
#     operands: 22
# 14. (w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 55
#     end_index: 53
# 15. (z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 55
#     end_index: 56
# 16. (x, w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 41, 25
# 17. (x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: ExprTuple
#     sub-expressions: 26
# 18. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 62
#     body: 27
# 19. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 20. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 43
# 21. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 62
#     body: 28
# 22. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 50, 44
# 23. _a -> (w_{_a} != 0)
#     core type: Lambda
#     parameter: 62
#     body: 29
# 24. _a -> (z_{_a} != 0)
#     core type: Lambda
#     parameter: 62
#     body: 30
# 25. w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 47
#     operands: 31
# 26. x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. w_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 34
# 28. z_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. w_{_a} != 0
#     core type: Operation
#     operator: 38
#     operands: 37
# 30. z_{_a} != 0
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. (w_{1}, w_{2}, ..., w_{m}, -y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 49, 40, 51
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (x, w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 34. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 43
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 43
# 37. (w_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 57, 44
# 38. !=
#     core type: Literal
#     sub-expressions:
# 39. (z_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 58, 44
# 40. -y
#     core type: Operation
#     operator: 45
#     operand: 50
# 41. x
#     core type: Variable
#     sub-expressions:
# 42. w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. 0
#     core type: Literal
#     sub-expressions:
# 45. -
#     core type: Literal
#     sub-expressions:
# 46. (y)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (w_{1}, w_{2}, ..., w_{m}, y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 49, 50, 51
# 49. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 55
#     end_index: 53
# 50. y
#     core type: Variable
#     sub-expressions:
# 51. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 52. _a -> w_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 57
# 53. m
#     core type: Variable
#     sub-expressions:
# 54. _a -> z_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. w_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 58. z_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 59. w
#     core type: Variable
#     sub-expressions:
# 60. z
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
