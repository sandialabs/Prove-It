# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, m, n, w, x, y, z
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(frac(x, Mult(w_1_to_m, Neg(y), z_1_to_n)), Neg(frac(x, Mult(w_1_to_m, y, z_1_to_n)))), domain = Complex, conditions = [NotEquals(y, zero), ExprRange(sub_expr1, NotEquals(IndexedVar(w, sub_expr1), zero), one, m), ExprRange(sub_expr1, NotEquals(IndexedVar(z, sub_expr1), zero), one, n)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n}~\left[\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0,\left(w_{1} \neq 0\right), \left(w_{2} \neq 0\right), \ldots, \left(w_{m} \neq 0\right),\left(z_{1} \neq 0\right), \left(z_{2} \neq 0\right), \ldots, \left(z_{n} \neq 0\right)}~\left(\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-y\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}} = \left(-\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot y\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n} [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. ((m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 62, 65
# 4. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 8. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 58, 50, 59, 60
# 9. {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)and (w_{1} != 0) and  (w_{2} != 0) and  ... and  (w_{m} != 0)and (z_{1} != 0) and  (z_{2} != 0) and  ... and  (z_{n} != 0)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}), -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20, 21, 22, 23, 24
# 16. x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 41
#     operands: 25
# 17. -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: Operation
#     operator: 54
#     operand: 35
# 18. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 64
#     end_index: 62
# 19. x in Complex
#     core type: Operation
#     operator: 44
#     operands: 28
# 20. y in Complex
#     core type: Operation
#     operator: 44
#     operands: 29
# 21. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 64
#     end_index: 65
# 22. y != 0
#     core type: Operation
#     operator: 47
#     operands: 31
# 23. (w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 64
#     end_index: 62
# 24. (z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 64
#     end_index: 65
# 25. (x, w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 50, 34
# 26. (x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: ExprTuple
#     sub-expressions: 35
# 27. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 71
#     body: 36
# 28. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 29. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 59, 52
# 30. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 71
#     body: 37
# 31. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 59, 53
# 32. _a -> (w_{_a} != 0)
#     core type: Lambda
#     parameter: 71
#     body: 38
# 33. _a -> (z_{_a} != 0)
#     core type: Lambda
#     parameter: 71
#     body: 39
# 34. w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 56
#     operands: 40
# 35. x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. w_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 43
# 37. z_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. w_{_a} != 0
#     core type: Operation
#     operator: 47
#     operands: 46
# 39. z_{_a} != 0
#     core type: Operation
#     operator: 47
#     operands: 48
# 40. (w_{1}, w_{2}, ..., w_{m}, -y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 58, 49, 60
# 41. /
#     core type: Literal
#     sub-expressions:
# 42. (x, w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 43. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 66, 52
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 67, 52
# 46. (w_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 66, 53
# 47. !=
#     core type: Literal
#     sub-expressions:
# 48. (z_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 67, 53
# 49. -y
#     core type: Operation
#     operator: 54
#     operand: 59
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. 0
#     core type: Literal
#     sub-expressions:
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (y)
#     core type: ExprTuple
#     sub-expressions: 59
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (w_{1}, w_{2}, ..., w_{m}, y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 58, 59, 60
# 58. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 64
#     end_index: 62
# 59. y
#     core type: Variable
#     sub-expressions:
# 60. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 64
#     end_index: 65
# 61. _a -> w_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 66
# 62. m
#     core type: Variable
#     sub-expressions:
# 63. _a -> z_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 67
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. w_{_a}
#     core type: IndexedVar
# variable: 68
# index: 71
# 67. z_{_a}
#     core type: IndexedVar
# variable: 69
# index: 71
# 68. w
#     core type: Variable
#     sub-expressions:
# 69. z
#     core type: Variable
#     sub-expressions:
# 70. (_a)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. _a
#     core type: Variable
#     sub-expressions:
