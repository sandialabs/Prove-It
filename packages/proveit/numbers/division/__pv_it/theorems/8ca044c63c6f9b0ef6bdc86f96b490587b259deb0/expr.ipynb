# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, x, y], Equals(frac(x, a), frac(y, a)), domains = [Complex, Complex, Complex], conditions = [Equals(x, y), NotEquals(a, zero)])
# Out:
# expr: forall_{a, x, y in Complex | x = y, a != 0} ((x / a) = (y / a))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, x, y \in \mathbb{C}~|~x = y, a \neq 0}~\left(\frac{x}{a} = \frac{y}{a}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, x, y in Complex | x = y, a != 0} ((x / a) = (y / a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, x, y) -> {(x / a) = (y / a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y ,  a != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, x, y)
#    core type: ExprTuple
#    sub-expressions: 31, 29, 30
# 4. {(x / a) = (y / a) if a in Complex ,  x in Complex ,  y in Complex ,  x = y ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x / a) = (y / a)
#    core type: Operation
#    operator: 24
#    operands: 7
# 6. (a in Complex) and (x in Complex) and (y in Complex) and (x = y) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x / a, y / a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complex, x in Complex, y in Complex, x = y, a != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. x / a
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. y / a
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. a in Complex
#     core type: Operation
#     operator: 22
#     operands: 20
# 13. x in Complex
#     core type: Operation
#     operator: 22
#     operands: 21
# 14. y in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 15. x = y
#     core type: Operation
#     operator: 24
#     operands: 25
# 16. a != 0
#     core type: Operation
#     operator: 26
#     operands: 27
# 17. (x, a)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 18. /
#     core type: Literal
#     sub-expressions:
# 19. (y, a)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 20. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 31, 28
# 21. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (x, y)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. !=
#     core type: Literal
#     sub-expressions:
# 27. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. Complex
#     core type: Literal
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. y
#     core type: Variable
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. 0
#     core type: Literal
#     sub-expressions:
