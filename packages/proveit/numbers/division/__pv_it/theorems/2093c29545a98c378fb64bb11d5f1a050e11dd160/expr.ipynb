# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, m, n, x, y
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(frac(Mult(w_1_to_m, Neg(x), z_1_to_n), y), Neg(frac(Mult(w_1_to_m, x, z_1_to_n), y))), domain = Complex, condition = NotEquals(y, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m, n\right) \mapsto \left[\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0}~\left(\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-x\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y} = \left(-\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))]
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 52, 55
# 2. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 48, 49, 42, 50
# 7. {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y, -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20
# 14. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 35
#     operands: 21
# 15. -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: Operation
#     operator: 44
#     operand: 30
# 16. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 54
#     end_index: 52
# 17. x in Complex
#     core type: Operation
#     operator: 38
#     operands: 24
# 18. y in Complex
#     core type: Operation
#     operator: 38
#     operands: 25
# 19. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 54
#     end_index: 55
# 20. y != 0
#     core type: Operation
#     operator: 27
#     operands: 28
# 21. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 29, 42
# 22. ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: ExprTuple
#     sub-expressions: 30
# 23. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 31
# 24. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 43
# 25. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 26. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 32
# 27. !=
#     core type: Literal
#     sub-expressions:
# 28. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 42, 33
# 29. w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 46
#     operands: 34
# 30. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. w_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. z_{_a} in Complex
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. (w_{1}, w_{2}, ..., w_{m}, -x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 40, 50
# 35. /
#     core type: Literal
#     sub-expressions:
# 36. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 43
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 43
# 40. -x
#     core type: Operation
#     operator: 44
#     operand: 49
# 41. w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. y
#     core type: Variable
#     sub-expressions:
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. (x)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (w_{1}, w_{2}, ..., w_{m}, x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 48. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 54
#     end_index: 52
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 51. _a -> w_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 52. m
#     core type: Variable
#     sub-expressions:
# 53. _a -> z_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 57
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. w_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 57. z_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 58. w
#     core type: Variable
#     sub-expressions:
# 59. z
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
