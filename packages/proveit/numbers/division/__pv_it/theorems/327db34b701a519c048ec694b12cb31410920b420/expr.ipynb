# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x, y, z
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y, z], Conditional(Equals(Mult(frac(one, y), frac(x, z)), frac(x, Mult(y, z))), And(InSet(x, Complex), InSet(y, Complex), InSet(z, Complex))))
# Out:
# expr: (x, y, z) -> {((1 / y) * (x / z)) = (x / (y * z)) if x in Complex ,  y in Complex ,  z in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y, z\right) \mapsto \left\{\left(\frac{1}{y} \cdot \frac{x}{z}\right) = \frac{x}{y \cdot z} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  z \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y, z) -> {((1 / y) * (x / z)) = (x / (y * z)) if x in Complex ,  y in Complex ,  z in Complex.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 30, 31, 32
# 2. {((1 / y) * (x / z)) = (x / (y * z)) if x in Complex ,  y in Complex ,  z in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((1 / y) * (x / z)) = (x / (y * z))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complex) and (y in Complex) and (z in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((1 / y) * (x / z), x / (y * z))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Complex, y in Complex, z in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (1 / y) * (x / z)
#    core type: Operation
#    operator: 27
#    operands: 14
# ...
