# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, m, n, w, x, y, z
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(w, sub_expr1)
sub_expr3 = IndexedVar(z, sub_expr1)
expr = Lambda([w_1_to_m, x, y, z_1_to_n], Conditional(Equals(frac(x, Mult(w_1_to_m, Neg(y), z_1_to_n)), Neg(frac(x, Mult(w_1_to_m, y, z_1_to_n)))), And(ExprRange(sub_expr1, InSet(sub_expr2, Complex), one, m), InSet(x, Complex), InSet(y, Complex), ExprRange(sub_expr1, InSet(sub_expr3, Complex), one, n), NotEquals(y, zero), ExprRange(sub_expr1, NotEquals(sub_expr2, zero), one, m), ExprRange(sub_expr1, NotEquals(sub_expr3, zero), one, n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n}\right) \mapsto \left\{\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-y\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}} = \left(-\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot y\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}\right) \textrm{ if } \left(w_{1} \in \mathbb{C}\right) ,  \left(w_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(w_{m} \in \mathbb{C}\right) ,  x \in \mathbb{C} ,  y \in \mathbb{C}, \left(z_{1} \in \mathbb{C}\right) ,  \left(z_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(z_{n} \in \mathbb{C}\right) ,  y \neq 0, \left(w_{1} \neq 0\right) ,  \left(w_{2} \neq 0\right) ,  \ldots ,  \left(w_{m} \neq 0\right), \left(z_{1} \neq 0\right) ,  \left(z_{2} \neq 0\right) ,  \ldots ,  \left(z_{n} \neq 0\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 51, 43, 52, 53
# 2. {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)and (w_{1} != 0) and  (w_{2} != 0) and  ... and  (w_{m} != 0)and (z_{1} != 0) and  (z_{2} != 0) and  ... and  (z_{n} != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}), -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15, 16, 17
# 9. x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#    core type: Operation
#    operator: 34
#    operands: 18
# 10. -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: Operation
#     operator: 47
#     operand: 28
# 11. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 57
#     end_index: 55
# 12. x in Complex
#     core type: Operation
#     operator: 37
#     operands: 21
# 13. y in Complex
#     core type: Operation
#     operator: 37
#     operands: 22
# 14. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 57
#     end_index: 58
# 15. y != 0
#     core type: Operation
#     operator: 40
#     operands: 24
# 16. (w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 57
#     end_index: 55
# 17. (z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 57
#     end_index: 58
# 18. (x, w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 43, 27
# 19. (x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: ExprTuple
#     sub-expressions: 28
# 20. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 29
# 21. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 22. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 23. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 30
# 24. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 25. _a -> (w_{_a} != 0)
#     core type: Lambda
#     parameter: 64
#     body: 31
# 26. _a -> (z_{_a} != 0)
#     core type: Lambda
#     parameter: 64
#     body: 32
# 27. w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 49
#     operands: 33
# 28. x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. w_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 36
# 30. z_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 38
# 31. w_{_a} != 0
#     core type: Operation
#     operator: 40
#     operands: 39
# 32. z_{_a} != 0
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. (w_{1}, w_{2}, ..., w_{m}, -y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 51, 42, 53
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (x, w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 36. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 59, 45
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 39. (w_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 59, 46
# 40. !=
#     core type: Literal
#     sub-expressions:
# 41. (z_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 60, 46
# 42. -y
#     core type: Operation
#     operator: 47
#     operand: 52
# 43. x
#     core type: Variable
#     sub-expressions:
# 44. w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. Complex
#     core type: Literal
#     sub-expressions:
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (y)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (w_{1}, w_{2}, ..., w_{m}, y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 51, 52, 53
# 51. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 57
#     end_index: 55
# 52. y
#     core type: Variable
#     sub-expressions:
# 53. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 57
#     end_index: 58
# 54. _a -> w_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 59
# 55. m
#     core type: Variable
#     sub-expressions:
# 56. _a -> z_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 60
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. n
#     core type: Variable
#     sub-expressions:
# 59. w_{_a}
#     core type: IndexedVar
# variable: 61
# index: 64
# 60. z_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 61. w
#     core type: Variable
#     sub-expressions:
# 62. z
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
