# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(frac(zero, x), zero), And(InSet(x, Complex), NotEquals(x, zero))))
# Out:
# expr: x -> {(0 / x) = 0 if x in Complex ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{\frac{0}{x} = 0 \textrm{ if } x \in \mathbb{C} ,  x \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {(0 / x) = 0 if x in Complex ,  x != 0.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {(0 / x) = 0 if x in Complex ,  x != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (0 / x) = 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x in Complex) and (x != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (0 / x, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 19
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in Complex, x != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 0 / x
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. x in Complex
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. x != 0
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (0, x)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. !=
#     core type: Literal
#     sub-expressions:
# 16. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Complex
#     core type: Literal
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. 0
#     core type: Literal
#     sub-expressions:
