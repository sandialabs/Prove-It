# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a, d], instance_expr = Forall(instance_param_or_params = [b, c, e], instance_expr = Equals(Mult(frac(Mult(a, b), c), frac(d, Mult(b, e))), Mult(frac(a, c), frac(d, e))), domain = ComplexNonZero), domain = Complex)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, d \in \mathbb{C}}~\left[\forall_{b, c, e \in \mathbb{C}^{\neq 0}}~\left(\left(\frac{a \cdot b}{c} \cdot \frac{d}{b \cdot e}\right) = \left(\frac{a}{c} \cdot \frac{d}{e}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a, d) -> {forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))) if a in Complex ,  d in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, d) -> {forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))) if a in Complex ,  d in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, d)
#    core type: ExprTuple
#    sub-expressions: 52, 48
# 4. {forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))) if a in Complex ,  d in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
#    core type: Operation
#    operator: 7
#    operand: 10
# ...
