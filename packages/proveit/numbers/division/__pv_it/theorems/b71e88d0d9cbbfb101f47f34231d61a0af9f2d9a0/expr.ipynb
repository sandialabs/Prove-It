# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x, y, z
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y, z], Conditional(Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), And(InSet(x, Complex), InSet(y, Complex), InSet(z, Complex), NotEquals(x, zero))))
# Out:
# expr: (x, y, z) -> {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y, z\right) \mapsto \left\{\frac{x \cdot y}{x \cdot z} = \frac{y}{z} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  z \in \mathbb{C} ,  x \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y, z) -> {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 32, 31, 33
# 2. {((x * y) / (x * z)) = (y / z) if x in Complex ,  y in Complex ,  z in Complex ,  x != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((x * y) / (x * z)) = (y / z)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complex) and (y in Complex) and (z in Complex) and (x != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((x * y) / (x * z), y / z)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Complex, y in Complex, z in Complex, x != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. (x * y) / (x * z)
#    core type: Operation
#    operator: 16
# ...
