# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_frac_neg_numerator_gen">neg_frac_neg_numerator_gen</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import neg_frac_neg_numerator_gen

# %%
# check that the built expression is the same as the stored expression
assert neg_frac_neg_numerator_gen.expr == stored_expr
assert neg_frac_neg_numerator_gen.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_frac_neg_numerator_gen matches stored_expr")
# Out:
# Passed sanity check: neg_frac_neg_numerator_gen matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n}~\left[\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0}~\left(\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-x\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y} = \left(-\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n} [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. ((m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} (((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)))]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
# ...
