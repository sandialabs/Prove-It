# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_frac_through_subtract">distribute_frac_through_subtract</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import distribute_frac_through_subtract

# %%
# check that the built expression is the same as the stored expression
assert distribute_frac_through_subtract.expr == stored_expr
assert distribute_frac_through_subtract.expr._style_id == stored_expr._style_id
print("Passed sanity check: distribute_frac_through_subtract matches stored_expr")
# Out:
# Passed sanity check: distribute_frac_through_subtract matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{x, y, z \in \mathbb{C}~|~z \neq 0}~\left(\frac{x - y}{z} = \left(\frac{x}{z} - \frac{y}{z}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{x, y, z in Complex | z != 0} (((x - y) / z) = ((x / z) - (y / z)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y, z) -> {((x - y) / z) = ((x / z) - (y / z)) if x in Complex ,  y in Complex ,  z in Complex ,  z != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y, z) -> {((x - y) / z) = ((x / z) - (y / z)) if x in Complex ,  y in Complex ,  z in Complex ,  z != 0.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 36, 42, 43
# 5. {((x - y) / z) = ((x / z) - (y / z)) if x in Complex ,  y in Complex ,  z in Complex ,  z != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((x - y) / z) = ((x / z) - (y / z))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Complex) and (y in Complex) and (z in Complex) and (z != 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# ...
