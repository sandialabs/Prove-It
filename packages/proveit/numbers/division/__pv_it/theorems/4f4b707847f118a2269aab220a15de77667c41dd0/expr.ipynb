# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(frac(a, b), Complex), And(InSet(a, Complex), InSet(b, Complex), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {(a / b) in Complex if a in Complex ,  b in Complex ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\frac{a}{b} \in \mathbb{C} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  b \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(a / b) in Complex if a in Complex ,  b in Complex ,  b != 0.
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {(a / b) in Complex if a in Complex ,  b in Complex ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a / b) in Complex
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (a in Complex) and (b in Complex) and (b != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a / b, Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 19
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Complex, b in Complex, b != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. a / b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. a in Complex
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. b in Complex
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. b != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 13. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. Complex
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. 0
#     core type: Literal
#     sub-expressions:
