# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable, m, n, w, x, y, z
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([m, n], Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(frac(x, Mult(w_1_to_m, Neg(y), z_1_to_n)), Neg(frac(x, Mult(w_1_to_m, y, z_1_to_n)))), domain = Complex, conditions = [NotEquals(y, zero), ExprRange(sub_expr1, NotEquals(IndexedVar(w, sub_expr1), zero), one, m), ExprRange(sub_expr1, NotEquals(IndexedVar(z, sub_expr1), zero), one, n)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m, n\right) \mapsto \left[\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0,\left(w_{1} \neq 0\right), \left(w_{2} \neq 0\right), \ldots, \left(w_{m} \neq 0\right),\left(z_{1} \neq 0\right), \left(z_{2} \neq 0\right), \ldots, \left(z_{n} \neq 0\right)}~\left(\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-y\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}} = \left(-\frac{x}{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot y\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m, n) -> [forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))]
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 60, 63
# 2. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)} ((x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 56, 48, 57, 58
# 7. {(x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0, (w_{1} != 0) ,  (w_{2} != 0) ,  ... ,  (w_{m} != 0), (z_{1} != 0) ,  (z_{2} != 0) ,  ... ,  (z_{n} != 0).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})) = (-(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)and (w_{1} != 0) and  (w_{2} != 0) and  ... and  (w_{m} != 0)and (z_{1} != 0) and  (z_{2} != 0) and  ... and  (z_{n} != 0)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}), -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0,(w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0),(z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0))
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20, 21, 22
# 14. x / (w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 39
#     operands: 23
# 15. -(x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: Operation
#     operator: 52
#     operand: 33
# 16. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 62
#     end_index: 60
# 17. x in Complex
#     core type: Operation
#     operator: 42
#     operands: 26
# 18. y in Complex
#     core type: Operation
#     operator: 42
#     operands: 27
# 19. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 62
#     end_index: 63
# 20. y != 0
#     core type: Operation
#     operator: 45
#     operands: 29
# 21. (w_{1} != 0), (w_{2} != 0), ..., (w_{m} != 0)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 62
#     end_index: 60
# 22. (z_{1} != 0), (z_{2} != 0), ..., (z_{n} != 0)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 62
#     end_index: 63
# 23. (x, w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 32
# 24. (x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}))
#     core type: ExprTuple
#     sub-expressions: 33
# 25. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 34
# 26. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 50
# 27. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 28. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 69
#     body: 35
# 29. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 57, 51
# 30. _a -> (w_{_a} != 0)
#     core type: Lambda
#     parameter: 69
#     body: 36
# 31. _a -> (z_{_a} != 0)
#     core type: Lambda
#     parameter: 69
#     body: 37
# 32. w_{1} *  w_{2} *  ... *  w_{m} * (-y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 54
#     operands: 38
# 33. x / (w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. w_{_a} in Complex
#     core type: Operation
#     operator: 42
#     operands: 41
# 35. z_{_a} in Complex
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. w_{_a} != 0
#     core type: Operation
#     operator: 45
#     operands: 44
# 37. z_{_a} != 0
#     core type: Operation
#     operator: 45
#     operands: 46
# 38. (w_{1}, w_{2}, ..., w_{m}, -y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 56, 47, 58
# 39. /
#     core type: Literal
#     sub-expressions:
# 40. (x, w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 41. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 64, 50
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 65, 50
# 44. (w_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 64, 51
# 45. !=
#     core type: Literal
#     sub-expressions:
# 46. (z_{_a}, 0)
#     core type: ExprTuple
#     sub-expressions: 65, 51
# 47. -y
#     core type: Operation
#     operator: 52
#     operand: 57
# 48. x
#     core type: Variable
#     sub-expressions:
# 49. w_{1} *  w_{2} *  ... *  w_{m} * y* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. 0
#     core type: Literal
#     sub-expressions:
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (y)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (w_{1}, w_{2}, ..., w_{m}, y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58
# 56. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 62
#     end_index: 60
# 57. y
#     core type: Variable
#     sub-expressions:
# 58. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 59. _a -> w_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 64
# 60. m
#     core type: Variable
#     sub-expressions:
# 61. _a -> z_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 65
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. w_{_a}
#     core type: IndexedVar
# variable: 66
# index: 69
# 65. z_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 66. w
#     core type: Variable
#     sub-expressions:
# 67. z
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
