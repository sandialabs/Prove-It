# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import And, InSet
from proveit.numbers import ComplexSansZero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, ComplexSansZero), InSet(b, ComplexSansZero))
# Out:
# expr: (a in (Complex - {0})) and (b in (Complex - {0}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \left(\mathbb{C} - \left\{0\right\}\right)\right) \land \left(b \in \left(\mathbb{C} - \left\{0\right\}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in (Complex - {0})) and (b in (Complex - {0}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in (Complex - {0}), b in (Complex - {0}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a in (Complex - {0})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. b in (Complex - {0})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, Complex - {0})
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (b, Complex - {0})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. Complex - {0}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. (Complex, {0})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. {0}
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. Set
#     core type: Literal
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
