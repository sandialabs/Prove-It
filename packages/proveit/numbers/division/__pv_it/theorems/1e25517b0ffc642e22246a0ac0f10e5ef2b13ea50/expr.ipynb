# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n, x, y
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import And, Equals, Forall, InSet, NotEquals
from proveit.numbers import Complex, Mult, NaturalPos, frac, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [w_1_to_m, x, y, z_1_to_n], instance_expr = Equals(Mult(w_1_to_m, frac(x, y), z_1_to_n), frac(Mult(w_1_to_m, x, z_1_to_n), y)), domain = Complex, condition = NotEquals(y, zero)), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n} \in \mathbb{C}~|~y \neq 0}~\left(\left(w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \frac{x}{y}\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}\right) = \frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right) \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n} in Complex | y != 0} ((w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. m in NaturalPos
#    core type: Operation
#    operator: 45
#    operands: 11
# 8. n in NaturalPos
#    core type: Operation
#    operator: 45
#    operands: 12
# 9. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 48, 49, 47, 50
# 10. {(w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 53, 15
# 12. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 56, 15
# 13. (w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}) = ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. NaturalPos
#     core type: Literal
#     sub-expressions:
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}, (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24, 25, 26
# 20. w_{1} *  w_{2} *  ... *  w_{m} * (x / y)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 42
#     operands: 27
# 21. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 40
#     operands: 28
# 22. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 55
#     end_index: 53
# 23. x in Complex
#     core type: Operation
#     operator: 45
#     operands: 30
# 24. y in Complex
#     core type: Operation
#     operator: 45
#     operands: 31
# 25. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 55
#     end_index: 56
# 26. y != 0
#     core type: Operation
#     operator: 33
#     operands: 34
# 27. (w_{1}, w_{2}, ..., w_{m}, x / y,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 35, 50
# 28. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 36, 47
# 29. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 62
#     body: 37
# 30. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 51
# 31. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 51
# 32. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 62
#     body: 38
# 33. !=
#     core type: Literal
#     sub-expressions:
# 34. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 47, 39
# 35. x / y
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. w_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 44
# 38. z_{_a} in Complex
#     core type: Operation
#     operator: 45
#     operands: 46
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. /
#     core type: Literal
#     sub-expressions:
# 41. (x, y)
#     core type: ExprTuple
#     sub-expressions: 49, 47
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (w_{1}, w_{2}, ..., w_{m}, x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 44. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 51
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 55
#     end_index: 53
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. Complex
#     core type: Literal
#     sub-expressions:
# 52. _a -> w_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 57
# 53. m
#     core type: Variable
#     sub-expressions:
# 54. _a -> z_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. w_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 58. z_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 59. w
#     core type: Variable
#     sub-expressions:
# 60. z
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
