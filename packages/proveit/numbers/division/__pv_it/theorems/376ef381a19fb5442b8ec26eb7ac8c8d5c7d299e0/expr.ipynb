# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a, d], instance_expr = Forall(instance_param_or_params = [b, c, e], instance_expr = Equals(Mult(frac(a, Mult(b, c)), frac(Mult(c, d), e)), Mult(frac(a, b), frac(d, e))), domain = ComplexNonZero), domain = Complex)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, d \in \mathbb{C}}~\left[\forall_{b, c, e \in \mathbb{C}^{\neq 0}}~\left(\left(\frac{a}{b \cdot c} \cdot \frac{c \cdot d}{e}\right) = \left(\frac{a}{b} \cdot \frac{d}{e}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a, d) -> {forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))) if a in Complex ,  d in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, d) -> {forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))) if a in Complex ,  d in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, d)
#    core type: ExprTuple
#    sub-expressions: 47, 54
# 4. {forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))) if a in Complex ,  d in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (a in Complex) and (d in Complex)
#    core type: Operation
#    operator: 22
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((b, c, e) -> {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (a in Complex, d in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (b, c, e) -> {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. a in Complex
#     core type: Operation
#     operator: 33
#     operands: 15
# 12. d in Complex
#     core type: Operation
#     operator: 33
#     operands: 16
# 13. (b, c, e)
#     core type: ExprTuple
#     sub-expressions: 52, 53, 48
# 14. {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 19
# 16. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 19
# 17. ((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (b in ComplexNonZero) and (c in ComplexNonZero) and (e in ComplexNonZero)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Complex
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. ((a / (b * c)) * ((c * d) / e), (a / b) * (d / e))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (b in ComplexNonZero, c in ComplexNonZero, e in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 24. (a / (b * c)) * ((c * d) / e)
#     core type: Operation
#     operator: 50
#     operands: 29
# 25. (a / b) * (d / e)
#     core type: Operation
#     operator: 50
#     operands: 30
# 26. b in ComplexNonZero
#     core type: Operation
#     operator: 33
#     operands: 31
# 27. c in ComplexNonZero
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. e in ComplexNonZero
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. (a / (b * c), (c * d) / e)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (a / b, d / e)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. (b, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 52, 39
# 32. (c, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (e, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 48, 39
# 35. a / (b * c)
#     core type: Operation
#     operator: 43
#     operands: 40
# 36. (c * d) / e
#     core type: Operation
#     operator: 43
#     operands: 41
# 37. a / b
#     core type: Operation
#     operator: 43
#     operands: 42
# 38. d / e
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 40. (a, b * c)
#     core type: ExprTuple
#     sub-expressions: 47, 45
# 41. (c * d, e)
#     core type: ExprTuple
#     sub-expressions: 46, 48
# 42. (a, b)
#     core type: ExprTuple
#     sub-expressions: 47, 52
# 43. /
#     core type: Literal
#     sub-expressions:
# 44. (d, e)
#     core type: ExprTuple
#     sub-expressions: 54, 48
# 45. b * c
#     core type: Operation
#     operator: 50
#     operands: 49
# 46. c * d
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. e
#     core type: Variable
#     sub-expressions:
# 49. (b, c)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (c, d)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. b
#     core type: Variable
#     sub-expressions:
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. d
#     core type: Variable
#     sub-expressions:
