# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, m, n, w, x, y, z
from proveit.core_expr_types import w_1_to_m, z_1_to_n
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, Neg, frac, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([w_1_to_m, x, y, z_1_to_n], Conditional(Equals(frac(Mult(w_1_to_m, Neg(x), z_1_to_n), y), Neg(frac(Mult(w_1_to_m, x, z_1_to_n), y))), And(ExprRange(sub_expr1, InSet(IndexedVar(w, sub_expr1), Complex), one, m), InSet(x, Complex), InSet(y, Complex), ExprRange(sub_expr1, InSet(IndexedVar(z, sub_expr1), Complex), one, n), NotEquals(y, zero)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(w_{1}, w_{2}, \ldots, w_{m}, x, y, z_{1}, z_{2}, \ldots, z_{n}\right) \mapsto \left\{\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot \left(-x\right)\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y} = \left(-\frac{w_{1} \cdot  w_{2} \cdot  \ldots \cdot  w_{m} \cdot x\cdot z_{1} \cdot  z_{2} \cdot  \ldots \cdot  z_{n}}{y}\right) \textrm{ if } \left(w_{1} \in \mathbb{C}\right) ,  \left(w_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(w_{m} \in \mathbb{C}\right) ,  x \in \mathbb{C} ,  y \in \mathbb{C}, \left(z_{1} \in \mathbb{C}\right) ,  \left(z_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(z_{n} \in \mathbb{C}\right) ,  y \neq 0\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (w_{1}, w_{2}, ..., w_{m}, x, y, z_{1}, z_{2}, ..., z_{n}) -> {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (w_{1}, w_{2}, ..., w_{m}, x, y,z_{1}, z_{2}, ..., z_{n})
#    core type: ExprTuple
#    sub-expressions: 44, 45, 38, 46
# 3. {((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)) if (w_{1} in Complex) ,  (w_{2} in Complex) ,  ... ,  (w_{m} in Complex) ,  x in Complex ,  y in Complex, (z_{1} in Complex) ,  (z_{2} in Complex) ,  ... ,  (z_{n} in Complex) ,  y != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y) = (-((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (w_{1} in Complex) and  (w_{2} in Complex) and  ... and  (w_{m} in Complex) and (x in Complex) and (y in Complex)and (z_{1} in Complex) and  (z_{2} in Complex) and  ... and  (z_{n} in Complex) and (y != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ((w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y, -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ((w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex), x in Complex, y in Complex,(z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex), y != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 31
#     operands: 17
# 11. -((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: Operation
#     operator: 40
#     operand: 26
# 12. (w_{1} in Complex), (w_{2} in Complex), ..., (w_{m} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 50
#     end_index: 48
# 13. x in Complex
#     core type: Operation
#     operator: 34
#     operands: 20
# 14. y in Complex
#     core type: Operation
#     operator: 34
#     operands: 21
# 15. (z_{1} in Complex), (z_{2} in Complex), ..., (z_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 50
#     end_index: 51
# 16. y != 0
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. (w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 25, 38
# 18. ((w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y)
#     core type: ExprTuple
#     sub-expressions: 26
# 19. _a -> (w_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 27
# 20. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 39
# 21. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 22. _a -> (z_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 28
# 23. !=
#     core type: Literal
#     sub-expressions:
# 24. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 38, 29
# 25. w_{1} *  w_{2} *  ... *  w_{m} * (-x)* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 42
#     operands: 30
# 26. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}) / y
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. w_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 33
# 28. z_{_a} in Complex
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. (w_{1}, w_{2}, ..., w_{m}, -x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 36, 46
# 31. /
#     core type: Literal
#     sub-expressions:
# 32. (w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}, y)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. (w_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 39
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (z_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 36. -x
#     core type: Operation
#     operator: 40
#     operand: 45
# 37. w_{1} *  w_{2} *  ... *  w_{m} * x* z_{1} *  z_{2} *  ... *  z_{n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. y
#     core type: Variable
#     sub-expressions:
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. (x)
#     core type: ExprTuple
#     sub-expressions: 45
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (w_{1}, w_{2}, ..., w_{m}, x,z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 44. w_{1}, w_{2}, ..., w_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 47. _a -> w_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 48. m
#     core type: Variable
#     sub-expressions:
# 49. _a -> z_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 53
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
# 52. w_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 53. z_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 54. w
#     core type: Variable
#     sub-expressions:
# 55. z
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
