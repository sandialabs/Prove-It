# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import Equals, Forall, NotEquals
from proveit.numbers import Complex, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c, d, e], Equals(Mult(frac(a, Mult(b, c)), frac(Mult(c, d), e)), Mult(frac(a, b), frac(d, e))), domains = [Complex, Complex, Complex, Complex, Complex], condition = NotEquals(c, zero))
# Out:
# expr: forall_{a, b, c, d, e in Complex | c != 0} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c, d, e \in \mathbb{C}~|~c \neq 0}~\left(\left(\frac{a}{b \cdot c} \cdot \frac{c \cdot d}{e}\right) = \left(\frac{a}{b} \cdot \frac{d}{e}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c, d, e in Complex | c != 0} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d, e) -> {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  c != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 42, 47, 48, 49, 43
# 4. {((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)) if a in Complex ,  b in Complex ,  c in Complex ,  d in Complex ,  e in Complex ,  c != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complex) and (b in Complex) and (c in Complex) and (d in Complex) and (e in Complex) and (c != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((a / (b * c)) * ((c * d) / e), (a / b) * (d / e))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complex, b in Complex, c in Complex, d in Complex, e in Complex, c != 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16, 17, 18
# 11. (a / (b * c)) * ((c * d) / e)
#     core type: Operation
#     operator: 45
#     operands: 19
# 12. (a / b) * (d / e)
#     core type: Operation
#     operator: 45
#     operands: 20
# 13. a in Complex
#     core type: Operation
#     operator: 25
#     operands: 21
# 14. b in Complex
#     core type: Operation
#     operator: 25
#     operands: 22
# 15. c in Complex
#     core type: Operation
#     operator: 25
#     operands: 23
# 16. d in Complex
#     core type: Operation
#     operator: 25
#     operands: 24
# 17. e in Complex
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. c != 0
#     core type: Operation
#     operator: 27
#     operands: 28
# 19. (a / (b * c), (c * d) / e)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 20. (a / b, d / e)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 21. (a, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 33
# 22. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 33
# 23. (c, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 33
# 24. (d, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 33
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (e, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 33
# 27. !=
#     core type: Literal
#     sub-expressions:
# 28. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 48, 34
# 29. a / (b * c)
#     core type: Operation
#     operator: 38
#     operands: 35
# 30. (c * d) / e
#     core type: Operation
#     operator: 38
#     operands: 36
# 31. a / b
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. d / e
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. Complex
#     core type: Literal
#     sub-expressions:
# 34. 0
#     core type: Literal
#     sub-expressions:
# 35. (a, b * c)
#     core type: ExprTuple
#     sub-expressions: 42, 40
# 36. (c * d, e)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 37. (a, b)
#     core type: ExprTuple
#     sub-expressions: 42, 47
# 38. /
#     core type: Literal
#     sub-expressions:
# 39. (d, e)
#     core type: ExprTuple
#     sub-expressions: 49, 43
# 40. b * c
#     core type: Operation
#     operator: 45
#     operands: 44
# 41. c * d
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. a
#     core type: Variable
#     sub-expressions:
# 43. e
#     core type: Variable
#     sub-expressions:
# 44. (b, c)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (c, d)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. b
#     core type: Variable
#     sub-expressions:
# 48. c
#     core type: Variable
#     sub-expressions:
# 49. d
#     core type: Variable
#     sub-expressions:
