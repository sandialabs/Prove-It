# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#prod_of_fracs">prod_of_fracs</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import prod_of_fracs

# %%
# check that the built expression is the same as the stored expression
assert prod_of_fracs.expr == stored_expr
assert prod_of_fracs.expr._style_id == stored_expr._style_id
print("Passed sanity check: prod_of_fracs matches stored_expr")
# Out:
# Passed sanity check: prod_of_fracs matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(prod_of_fracs.latex())
# Out:
# \vdash \forall_{x, y, z, w \in \mathbb{C}}~\left(\left(\frac{x}{z} \cdot \frac{y}{w}\right) = \frac{x \cdot y}{z \cdot w}\right)

# %%
# display the expression information
prod_of_fracs.expr_info()
# Out:
# 0. forall_{x, y, z, w in Complex} (((x / z) * (y / w)) = ((x * y) / (z * w)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y, z, w) -> {((x / z) * (y / w)) = ((x * y) / (z * w)) if x in Complex ,  y in Complex ,  z in Complex ,  w in Complex.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, y, z, w)
#    core type: ExprTuple
#    sub-expressions: 35, 36, 37, 38
# 4. {((x / z) * (y / w)) = ((x * y) / (z * w)) if x in Complex ,  y in Complex ,  z in Complex ,  w in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ((x / z) * (y / w)) = ((x * y) / (z * w))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in Complex) and (y in Complex) and (z in Complex) and (w in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((x / z) * (y / w), (x * y) / (z * w))
# ...
