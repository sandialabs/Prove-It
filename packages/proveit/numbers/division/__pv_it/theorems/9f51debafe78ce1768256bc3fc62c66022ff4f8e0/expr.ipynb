# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.logic import InSet, NotEquals
from proveit.numbers import Rational, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Rational), InSet(b, Rational), NotEquals(b, zero))
# Out:
# expr: (a in Rational, b in Rational, b != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{Q}, b \in \mathbb{Q}, b \neq 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Rational, b in Rational, b != 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. a in Rational
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. b in Rational
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. b != 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (a, Rational)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, Rational)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 7. !=
#    core type: Literal
#    sub-expressions:
# 8. (b, 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. Rational
#     core type: Literal
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. 0
#     core type: Literal
#     sub-expressions:
