# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#divide_complex_closure">divide_complex_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import divide_complex_closure

# %%
# check that the built expression is the same as the stored expression
assert divide_complex_closure.expr == stored_expr
assert divide_complex_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: divide_complex_closure matches stored_expr")
# Out:
# Passed sanity check: divide_complex_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(divide_complex_closure.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{C}~|~b \neq 0}~\left(\frac{a}{b} \in \mathbb{C}\right)

# %%
# display the expression information
divide_complex_closure.expr_info()
# Out:
# 0. forall_{a, b in Complex | b != 0} ((a / b) in Complex)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a / b) in Complex if a in Complex ,  b in Complex ,  b != 0.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a / b) in Complex if a in Complex ,  b in Complex ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a / b) in Complex
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (a in Complex) and (b in Complex) and (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a / b, Complex)
#    core type: ExprTuple
#    sub-expressions: 9, 21
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complex, b in Complex, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. a / b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a in Complex
#     core type: Operation
# ...
