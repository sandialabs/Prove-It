# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#posnat3">posnat3</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import posnat3

# %%
# check that the built expression is the same as the stored expression
assert posnat3.expr == stored_expr
assert posnat3.expr._style_id == stored_expr._style_id
print("Passed sanity check: posnat3 matches stored_expr")
# Out:
# Passed sanity check: posnat3 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(posnat3.latex())
# Out:
# \vdash 3 \in \mathbb{N}^+

# %%
# display the expression information
posnat3.expr_info()
# Out:
# 0. 3 in NaturalPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (3, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 3
#    core type: Literal
#    sub-expressions:
# 4. NaturalPos
#    core type: Literal
#    sub-expressions:
