# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import DecimalSequence, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_n], InSet(DecimalSequence(a_1_to_n), NaturalPos), domains = [NaturalPos]), InSet(n, NaturalPos))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalPos} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{n} \in \mathbb{N}^+}~\left(\# (a_{1} ~ \ldots ~ a_{n}) \in \mathbb{N}^+\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalPos} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalPos} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in NaturalPos
#    core type: Operation
#    operator: 22
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{n}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).
#    core type: Lambda
#    parameters: 15\n   body: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 21, 25
# 6. {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos if (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. \# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in NaturalPos
#    core type: Operation
#    operator: 22
#    operands: 9
# 8. (a_{1} in NaturalPos) and ..(a_{_a} in NaturalPos).. and (a_{n} in NaturalPos)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}), NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 12, 25
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a_{1} in NaturalPos, ..a_{_a} in NaturalPos.., a_{n} in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. \# (a_{1} ~ ..a_{_a}.. ~ a_{n})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{1} in NaturalPos), ..(a_{_a} in NaturalPos).., (a_{n} in NaturalPos)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 20
#     end_index: 21
# 14. Decimal
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. _a -> (a_{_a} in NaturalPos)
#     core type: Lambda
#     parameter: 27
#     body: 18
# 17. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. a_{_a} in NaturalPos
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (a_{_a}, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a_{_a}
#     core type: IndexedVar
# variable: 26
# index: 27
# 25. NaturalPos
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. _a
#     core type: Variable
#     sub-expressions:
