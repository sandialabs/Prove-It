# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, a, b, c, d, e, f, g, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import one, seven

# %%
# build up the expression from sub-expressions
sub_expr1 = [a, b, c, d, e, f, g]
expr = Lambda(sub_expr1, Equals(Len(sub_expr1), Len([ExprRange(k, k, one, seven)])))
# Out:
# expr: (a, b, c, d, e, f, g) -> (|(a, b, c, d, e, f, g)| = |(1, ..k.., 7)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c, d, e, f, g\right) \mapsto \left(|\left(a, b, c, d, e, f, g\right)| = |\left(1, \ldots, 7\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c, d, e, f, g) -> (|(a, b, c, d, e, f, g)| = |(1, ..k.., 7)|)
#    core type: Lambda
#    parameters: 9\n   body: 1
# 1. |(a, b, c, d, e, f, g)| = |(1, ..k.., 7)|
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (|(a, b, c, d, e, f, g)|, |(1, ..k.., 7)|)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. |(a, b, c, d, e, f, g)|
#    core type: Operation
#    operator: 7
#    operand: 9
# 5. |(1, ..k.., 7)|
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. ((a, b, c, d, e, f, g))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. length
#    core type: Literal
#    sub-expressions:
# 8. ((1, ..k.., 7))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (a, b, c, d, e, f, g)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15, 16, 17
# 10. (1, ..k.., 7)
#     core type: ExprTuple
#     sub-expressions: 18
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. g
#     core type: Variable
#     sub-expressions:
# 18. 1, ..k.., 7
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 19. k -> k
#     core type: Lambda
#     parameter: 22
#     body: 22
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. 7
#     core type: Literal
#     sub-expressions:
# 22. k
#     core type: Variable
#     sub-expressions:
