# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_4_8">mult_4_8</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import mult_4_8

# %%
# check that the built expression is the same as the stored expression
assert mult_4_8.expr == stored_expr
assert mult_4_8.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_4_8 matches stored_expr")
# Out:
# Passed sanity check: mult_4_8 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_4_8.latex())
# Out:
# \vdash \left(4 \cdot 8\right) = 32

# %%
# display the expression information
mult_4_8.expr_info()
# Out:
# 0. (4 * 8) = 32
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (4 * 8, 32)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 4 * 8
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 32
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (4, 8)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (3, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. 4
#    core type: Literal
#    sub-expressions:
# 10. 8
#     core type: Literal
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
