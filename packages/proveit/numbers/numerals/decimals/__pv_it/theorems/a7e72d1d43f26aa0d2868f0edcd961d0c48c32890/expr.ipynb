# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, c, d, i, k, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = IndexedVar(c, sub_expr1)
sub_expr4 = IndexedVar(d, sub_expr1)
sub_expr5 = ExprRange(i, b, one, n)
sub_expr6 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr7 = ExprRange(sub_expr1, sub_expr3, one, n)
sub_expr8 = ExprRange(sub_expr1, sub_expr4, one, k)
expr = Lambda([sub_expr6, b, sub_expr7, sub_expr8], Conditional(Equals(DecimalSequence(sub_expr6, sub_expr5, sub_expr8), DecimalSequence(sub_expr6, sub_expr7, sub_expr8)), And(ExprRange(sub_expr1, InSet(sub_expr2, Digits), one, m), InSet(b, Digits), ExprRange(sub_expr1, InSet(sub_expr3, Digits), one, n), ExprRange(sub_expr1, InSet(sub_expr4, Digits), one, k), Equals([sub_expr5], [sub_expr7]))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}, d_{1}, \ldots, d_{k}\right) \mapsto \left\{\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ ..n \textrm{ repeats}.. ~ b ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c_{1} ~ \ldots ~ c_{n} ~ d_{1} ~ \ldots ~ d_{k}) \textrm{ if } a_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  a_{m} \in \mathbb{N}^{\leq 9} ,  b \in \mathbb{N}^{\leq 9} ,  c_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  c_{n} \in \mathbb{N}^{\leq 9} ,  d_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  d_{k} \in \mathbb{N}^{\leq 9} ,  \left(b, ..n \textrm{ repeats}.., b\right) = \left(c_{1}, \ldots, c_{n}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 24, 51, 40, 25
# 2. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 22
#    operands: 5
# 4. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b in Digits) and (c_{1} in Digits) and ..(c_{_a} in Digits).. and (c_{n} in Digits) and (d_{1} in Digits) and ..(d_{_a} in Digits).. and (d_{k} in Digits) and ((b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}), \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b in Digits, c_{1} in Digits, ..c_{_a} in Digits.., c_{n} in Digits, d_{1} in Digits, ..d_{_a} in Digits.., d_{k} in Digits, (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 14
# 8. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 46
#     end_index: 32
# 11. b in Digits
#     core type: Operation
#     operator: 37
#     operands: 19
# 12. (c_{1} in Digits), ..(c_{_a} in Digits).., (c_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 46
#     end_index: 47
# 13. (d_{1} in Digits), ..(d_{_a} in Digits).., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 46
#     end_index: 34
# 14. (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n})
#     core type: Operation
#     operator: 22
#     operands: 23
# 15. (a_{1}, ..a_{_a}.., a_{m}, b, ..n repeats.., b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 39, 25
# 16. Decimal
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, ..a_{_a}.., a_{m}, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 40, 25
# 18. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 26
# 19. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 51, 43
# 20. _a -> (c_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 27
# 21. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 28
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. ((b, ..n repeats.., b), (c_{1}, ..c_{_a}.., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 46
#     end_index: 32
# 25. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 46
#     end_index: 34
# 26. a_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 35
# 27. c_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 36
# 28. d_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 38
# 29. (b, ..n repeats.., b)
#     core type: ExprTuple
#     sub-expressions: 39
# 30. (c_{1}, ..c_{_a}.., c_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 41
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. _a -> d_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 42
# 34. k
#     core type: Variable
#     sub-expressions:
# 35. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 36. (c_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 52, 43
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. b, ..n repeats.., b
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 47
# 40. c_{1}, ..c_{_a}.., c_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 41. a_{_a}
#     core type: IndexedVar
# variable: 48
# index: 54
# 42. d_{_a}
#     core type: IndexedVar
# variable: 49
# index: 54
# 43. Digits
#     core type: Literal
#     sub-expressions:
# 44. i -> b
#     core type: Lambda
#     parameter: 50
#     body: 51
# 45. _a -> c_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 52
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. a
#     core type: Variable
#     sub-expressions:
# 49. d
#     core type: Variable
#     sub-expressions:
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 54
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. _a
#     core type: Variable
#     sub-expressions:
