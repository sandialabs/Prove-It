# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, c, d, k, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = IndexedVar(d, sub_expr1)
sub_expr4 = IndexedVar(c, sub_expr1)
sub_expr5 = ExprRange(sub_expr1, b, one, n)
sub_expr6 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr7 = ExprRange(sub_expr1, sub_expr3, one, k)
sub_expr8 = ExprRange(sub_expr1, sub_expr4, one, n)
expr = Conditional(Equals(DecimalSequence(sub_expr6, sub_expr5, sub_expr7), DecimalSequence(sub_expr6, sub_expr8, sub_expr7)), And(ExprRange(sub_expr1, InSet(sub_expr2, Digits), one, m), InSet(b, Digits), ExprRange(sub_expr1, InSet(sub_expr4, Digits), one, n), ExprRange(sub_expr1, InSet(sub_expr3, Digits), one, k), Equals([sub_expr5], [sub_expr8])))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ b, b, ..\left(n - 3\right) \times.., b ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c_{1}, c_{2}, \ldots, c_{n} ~ d_{1}, d_{2}, \ldots, d_{k}) \textrm{ if } \left(a_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(a_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(a_{m} \in \mathbb{N}^{\leq 9}\right) ,  b \in \mathbb{N}^{\leq 9}, \left(c_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(c_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(c_{n} \in \mathbb{N}^{\leq 9}\right), \left(d_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(d_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(d_{k} \in \mathbb{N}^{\leq 9}\right) ,  \left(b, b, ..\left(n - 3\right) \times.., b\right) = \left(c_{1}, c_{2}, \ldots, c_{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 20
#    operands: 3
# 2. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits) and (b in Digits)and (c_{1} in Digits) and  (c_{2} in Digits) and  ... and  (c_{n} in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits), b in Digits,(c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits),(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 6. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 14
#    operands: 13
# 7. #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 44
#    end_index: 30
# 9. b in Digits
#    core type: Operation
#    operator: 35
#    operands: 17
# 10. (c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 44
#     end_index: 45
# 11. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 44
#     end_index: 32
# 12. (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. (a_{1}, a_{2}, ..., a_{m},b, b, ..(n - 3) ×.., b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 37, 23
# 14. Decimal
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, a_{2}, ..., a_{m},c_{1}, c_{2}, ..., c_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 22, 38, 23
# 16. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 24
# 17. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 48, 41
# 18. _a -> (c_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 25
# 19. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 26
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. ((b, b, ..(n - 3) ×.., b), (c_{1}, c_{2}, ..., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 44
#     end_index: 30
# 23. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 44
#     end_index: 32
# 24. a_{_a} in Digits
#     core type: Operation
#     operator: 35
#     operands: 33
# 25. c_{_a} in Digits
#     core type: Operation
#     operator: 35
#     operands: 34
# 26. d_{_a} in Digits
#     core type: Operation
#     operator: 35
#     operands: 36
# 27. (b, b, ..(n - 3) ×.., b)
#     core type: ExprTuple
#     sub-expressions: 37
# 28. (c_{1}, c_{2}, ..., c_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 39
# 30. m
#     core type: Variable
#     sub-expressions:
# 31. _a -> d_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 40
# 32. k
#     core type: Variable
#     sub-expressions:
# 33. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 34. (c_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 49, 41
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. b, b, ..(n - 3) ×.., b
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 44
#     end_index: 45
# 38. c_{1}, c_{2}, ..., c_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 39. a_{_a}
#     core type: IndexedVar
# variable: 46
# index: 52
# 40. d_{_a}
#     core type: IndexedVar
# variable: 47
# index: 52
# 41. Digits
#     core type: Literal
#     sub-expressions:
# 42. _a -> b
#     core type: Lambda
#     parameter: 52
#     body: 48
# 43. _a -> c_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 49
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. d
#     core type: Variable
#     sub-expressions:
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. c_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. _a
#     core type: Variable
#     sub-expressions:
