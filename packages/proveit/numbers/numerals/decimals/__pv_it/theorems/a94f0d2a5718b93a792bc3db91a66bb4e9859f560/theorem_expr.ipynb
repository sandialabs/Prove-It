# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#deci_sequence_is_nat_pos">deci_sequence_is_nat_pos</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import deci_sequence_is_nat_pos

# %%
# check that the built expression is the same as the stored expression
assert deci_sequence_is_nat_pos.expr == stored_expr
assert deci_sequence_is_nat_pos.expr._style_id == stored_expr._style_id
print("Passed sanity check: deci_sequence_is_nat_pos matches stored_expr")
# Out:
# Passed sanity check: deci_sequence_is_nat_pos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{N}^{\leq 9}~|~a > 0}~\left(\texttt{\#}(a ~ b_{1}, b_{2}, \ldots, b_{n}) \in \mathbb{N}^+\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a, b_{1}, b_{2}, ..., b_{n} in Digits | a > 0} (#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{a, b_{1}, b_{2}, ..., b_{n} in Digits | a > 0} (#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a, b_{1}, b_{2}, ..., b_{n} in Digits | a > 0} (#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos) if n in Natural.
#    core type: Lambda
#    parameter: 35
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 35
# 4. {forall_{a, b_{1}, b_{2}, ..., b_{n} in Digits | a > 0} (#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos) if n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a, b_{1}, b_{2}, ..., b_{n} in Digits | a > 0} (#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in Natural
#    core type: Operation
#    operator: 36
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a, b_{1}, b_{2}, ..., b_{n}) -> {#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos if a in Digits, (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  a > 0.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 35, 11
# 10. (a, b_{1}, b_{2}, ..., b_{n}) -> {#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos if a in Digits, (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  a > 0.
#     core type: Lambda
#     parameters: 24\n    body: 12
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. {#(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos if a in Digits, (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  a > 0.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. #(a ~ b_{1}, b_{2}, ..., b_{n}) in NaturalPos
#     core type: Operation
#     operator: 36
#     operands: 15
# 14. (a in Digits)and (b_{1} in Digits) and  (b_{2} in Digits) and  ... and  (b_{n} in Digits) and (a > 0)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (#(a ~ b_{1}, b_{2}, ..., b_{n}), NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a in Digits,(b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits), a > 0)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 18. #(a ~ b_{1}, b_{2}, ..., b_{n})
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. a in Digits
#     core type: Operation
#     operator: 36
#     operands: 25
# 21. (b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 34
#     end_index: 35
# 22. a > 0
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. Decimal
#     core type: Literal
#     sub-expressions:
# 24. (a,b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 29
# 25. (a, Digits)
#     core type: ExprTuple
#     sub-expressions: 32, 39
# 26. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 42
#     body: 30
# 27. <
#     core type: Literal
#     sub-expressions:
# 28. (0, a)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 30. b_{_a} in Digits
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. _a -> b_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. b_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 39. Digits
#     core type: Literal
#     sub-expressions:
# 40. b
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. _a
#     core type: Variable
#     sub-expressions:
