# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n
from proveit.logic import InSet
from proveit.numbers import Digits, LessEq, nine

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(LessEq(n, nine), InSet(n, Digits)))
# Out:
# expr: n -> {n <= 9 if n in Digits.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{n \leq 9 \textrm{ if } n \in \mathbb{N}^{\leq 9}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {n <= 9 if n in Digits.
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. {n <= 9 if n in Digits.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. n <= 9
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. n in Digits
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <=
#    core type: Literal
#    sub-expressions:
# 5. (n, 9)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Digits)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 9
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. Digits
#     core type: Literal
#     sub-expressions:
