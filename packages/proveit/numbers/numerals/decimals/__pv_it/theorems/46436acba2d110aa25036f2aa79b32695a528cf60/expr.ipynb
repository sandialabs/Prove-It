# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, c, d, k, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(b, sub_expr1), one, n)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr5 = Add(sub_expr3)
expr = Forall([sub_expr2, sub_expr3, c, sub_expr4], Equals(DecimalSequence(sub_expr2, sub_expr5, sub_expr4), DecimalSequence(sub_expr2, c, sub_expr4)), domains = [Digits, Digits, Digits, Digits], condition = Equals(sub_expr5, c))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}, c, d_{1}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} + \ldots + b_{n}\right) = c}~\left(\# (a_{1} ~ \ldots ~ a_{m} ~ \left(b_{1} + \ldots + b_{n}\right) ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c ~ d_{1} ~ \ldots ~ d_{k})\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 26, 46, 32, 27
# 4. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 24
#    operands: 7
# 6. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b_{1} in Digits) and ..(b_{_a} in Digits).. and (b_{n} in Digits) and (c in Digits) and (d_{1} in Digits) and ..(d_{_a} in Digits).. and (d_{k} in Digits) and ((b_{1} + ..b_{_a}.. + b_{n}) = c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}), \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b_{1} in Digits, ..b_{_a} in Digits.., b_{n} in Digits, c in Digits, d_{1} in Digits, ..d_{_a} in Digits.., d_{k} in Digits, (b_{1} + ..b_{_a}.. + b_{n}) = c)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 50
#     end_index: 34
# 13. (b_{1} in Digits), ..(b_{_a} in Digits).., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 50
#     end_index: 51
# 14. c in Digits
#     core type: Operation
#     operator: 39
#     operands: 22
# 15. (d_{1} in Digits), ..(d_{_a} in Digits).., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 50
#     end_index: 36
# 16. (b_{1} + ..b_{_a}.. + b_{n}) = c
#     core type: Operation
#     operator: 24
#     operands: 25
# 17. (a_{1}, ..a_{_a}.., a_{m}, b_{1} + ..b_{_a}.. + b_{n}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 31, 27
# 18. Decimal
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, ..a_{_a}.., a_{m}, c, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 32, 27
# 20. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 28
# 21. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 29
# 22. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 32, 45
# 23. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 54
#     body: 30
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (b_{1} + ..b_{_a}.. + b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 50
#     end_index: 34
# 27. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 50
#     end_index: 36
# 28. a_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 37
# 29. b_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 38
# 30. d_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 40
# 31. b_{1} + ..b_{_a}.. + b_{n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 32. c
#     core type: Variable
#     sub-expressions:
# 33. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 43
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. _a -> d_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 44
# 36. k
#     core type: Variable
#     sub-expressions:
# 37. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 38. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 54
# 44. d_{_a}
#     core type: IndexedVar
# variable: 48
# index: 54
# 45. Digits
#     core type: Literal
#     sub-expressions:
# 46. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. d
#     core type: Variable
#     sub-expressions:
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 52
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
# 52. b_{_a}
#     core type: IndexedVar
# variable: 53
# index: 54
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. _a
#     core type: Variable
#     sub-expressions:
