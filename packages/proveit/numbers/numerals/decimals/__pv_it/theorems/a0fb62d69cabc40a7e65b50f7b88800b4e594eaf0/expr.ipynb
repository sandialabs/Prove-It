# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, i, k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, Less, nine, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
expr = Forall([sub_expr2, b], Equals(Add(DecimalSequence(sub_expr2, b, ExprRange(i, nine, one, k)), one), DecimalSequence(sub_expr2, Add(b, one), ExprRange(i, zero, one, k))), domains = [Digits, Digits], condition = Less(b, nine))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{m}, b \in \mathbb{N}^{\leq 9}~|~b < 9}~\left(\left(\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ 9 ~ ..k \textrm{ repeats}.. ~ 9) + 1\right) = \# (a_{1} ~ \ldots ~ a_{m} ~ \left(b + 1\right) ~ 0 ~ ..k \textrm{ repeats}.. ~ 0)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  b < 9.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 33, 35
# 4. {(\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  b < 9.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b in Digits) and (b < 9)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1, \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b in Digits, b < 9)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1
#     core type: Operation
#     operator: 28
#     operands: 16
# 12. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)
#     core type: Operation
#     operator: 26
#     operands: 17
# 13. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 41
#     end_index: 39
# 14. b in Digits
#     core type: Operation
#     operator: 31
#     operands: 19
# 15. b < 9
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9), 1)
#     core type: ExprTuple
#     sub-expressions: 22, 41
# 17. (a_{1}, ..a_{_a}.., a_{m}, b + 1, 0, ..k repeats.., 0)
#     core type: ExprTuple
#     sub-expressions: 33, 23, 24
# 18. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 47
#     body: 25
# 19. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 20. <
#     core type: Literal
#     sub-expressions:
# 21. (b, 9)
#     core type: ExprTuple
#     sub-expressions: 35, 45
# 22. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9)
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. b + 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 0, ..k repeats.., 0
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 41
#     end_index: 42
# 25. a_{_a} in Digits
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. Decimal
#     core type: Literal
#     sub-expressions:
# 27. (a_{1}, ..a_{_a}.., a_{m}, b, 9, ..k repeats.., 9)
#     core type: ExprTuple
#     sub-expressions: 33, 35, 34
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 41
# 30. i -> 0
#     core type: Lambda
#     parameter: 44
#     body: 36
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 43, 37
# 33. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 41
#     end_index: 39
# 34. 9, ..k repeats.., 9
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 35. b
#     core type: Variable
#     sub-expressions:
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. Digits
#     core type: Literal
#     sub-expressions:
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 43
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. i -> 9
#     core type: Lambda
#     parameter: 44
#     body: 45
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. k
#     core type: Variable
#     sub-expressions:
# 43. a_{_a}
#     core type: IndexedVar
# variable: 46
# index: 47
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. 9
#     core type: Literal
#     sub-expressions:
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. _a
#     core type: Variable
#     sub-expressions:
