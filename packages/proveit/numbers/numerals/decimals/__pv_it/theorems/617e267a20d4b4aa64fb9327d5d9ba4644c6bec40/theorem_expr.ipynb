# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#deci_sequence_reduction_ER">deci_sequence_reduction_ER</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import deci_sequence_reduction_ER

# %%
# check that the built expression is the same as the stored expression
assert deci_sequence_reduction_ER.expr == stored_expr
assert deci_sequence_reduction_ER.expr._style_id == stored_expr._style_id
print("Passed sanity check: deci_sequence_reduction_ER matches stored_expr")
# Out:
# Passed sanity check: deci_sequence_reduction_ER matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{m}, b, c_{1}, c_{2}, \ldots, c_{n}, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b, b, ..\left(n - 3\right) \times.., b\right) = \left(c_{1}, c_{2}, \ldots, c_{n}\right)}~\left(\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ b, b, ..\left(n - 3\right) \times.., b ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c_{1}, c_{2}, \ldots, c_{n} ~ d_{1}, d_{2}, \ldots, d_{k})\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k} in Digits | (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})} (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n, k) -> {forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k} in Digits | (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})} (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# ...
