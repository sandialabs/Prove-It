# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#tuple_len_5_typical_eq">tuple_len_5_typical_eq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import tuple_len_5_typical_eq

# %%
# check that the built expression is the same as the stored expression
assert tuple_len_5_typical_eq.expr == stored_expr
assert tuple_len_5_typical_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: tuple_len_5_typical_eq matches stored_expr")
# Out:
# Passed sanity check: tuple_len_5_typical_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_5_typical_eq.latex())
# Out:
# \vdash \forall_{a, b, c, d, e}~\left(|\left(a, b, c, d, e\right)| = |\left(1, \ldots, 5\right)|\right)

# %%
# display the expression information
tuple_len_5_typical_eq.expr_info()
# Out:
# 0. forall_{a, b, c, d, e} (|(a, b, c, d, e)| = |(1, ..k.., 5)|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d, e) -> (|(a, b, c, d, e)| = |(1, ..k.., 5)|)
#    core type: Lambda
#    parameters: 11\n   body: 3
# 3. |(a, b, c, d, e)| = |(1, ..k.., 5)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|(a, b, c, d, e)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. |(a, b, c, d, e)|
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. ((a, b, c, d, e))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. ((1, ..k.., 5))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a, b, c, d, e)
#     core type: ExprTuple
# ...
