# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_7_0">add_7_0</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import add_7_0

# %%
# check that the built expression is the same as the stored expression
assert add_7_0.expr == stored_expr
assert add_7_0.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_7_0 matches stored_expr")
# Out:
# Passed sanity check: add_7_0 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_7_0.latex())
# Out:
# \vdash \left(7 + 0\right) = 7

# %%
# display the expression information
add_7_0.expr_info()
# Out:
# 0. (7 + 0) = 7
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (7 + 0, 7)
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. 7 + 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (7, 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 7
#    core type: Literal
#    sub-expressions:
# 7. 0
#    core type: Literal
#    sub-expressions:
