# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, d, k, m, n
from proveit.core_expr_types import b_1_to_n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr4 = Add(b_1_to_n)
expr = Forall(instance_param_or_params = [m, n, k], instance_expr = Forall(instance_param_or_params = [sub_expr2, b_1_to_n, c, sub_expr3], instance_expr = Equals(DecimalSequence(sub_expr2, sub_expr4, sub_expr3), DecimalSequence(sub_expr2, c, sub_expr3)), domain = Digits, condition = Equals(sub_expr4, c)), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{n}, c, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) = c}~\left(\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ \left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c ~ d_{1}, d_{2}, \ldots, d_{k})\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n, k) -> {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n, k) -> {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n, k)
#    core type: ExprTuple
#    sub-expressions: 49, 66, 51
# 4. {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (m in Natural) and (n in Natural) and (k in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m in Natural, n in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#     core type: Lambda
#     parameters: 14\n    body: 15
# 11. m in Natural
#     core type: Operation
#     operator: 54
#     operands: 16
# 12. n in Natural
#     core type: Operation
#     operator: 54
#     operands: 17
# 13. k in Natural
#     core type: Operation
#     operator: 54
#     operands: 18
# 14. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{n}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 61, 47, 42
# 15. {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 21
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 66, 21
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 21
# 19. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 39
#     operands: 22
# 20. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits)and (b_{1} in Digits) and  (b_{2} in Digits) and  ... and  (b_{n} in Digits) and (c in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b_{1} +  b_{2} +  ... +  b_{n}) = c)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits),(b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits), c in Digits,(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b_{1} +  b_{2} +  ... +  b_{n}) = c)
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30, 31
# 25. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 33
#     operands: 32
# 26. #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 33
#     operands: 34
# 27. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 65
#     end_index: 49
# 28. (b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 65
#     end_index: 66
# 29. c in Digits
#     core type: Operation
#     operator: 54
#     operands: 37
# 30. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 65
#     end_index: 51
# 31. (b_{1} +  b_{2} +  ... +  b_{n}) = c
#     core type: Operation
#     operator: 39
#     operands: 40
# 32. (a_{1}, a_{2}, ..., a_{m}, b_{1} +  b_{2} +  ... +  b_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 46, 42
# 33. Decimal
#     core type: Literal
#     sub-expressions:
# 34. (a_{1}, a_{2}, ..., a_{m}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 41, 47, 42
# 35. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 70
#     body: 43
# 36. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 70
#     body: 44
# 37. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 47, 60
# 38. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 70
#     body: 45
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. (b_{1} +  b_{2} +  ... +  b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 41. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 65
#     end_index: 49
# 42. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 65
#     end_index: 51
# 43. a_{_a} in Digits
#     core type: Operation
#     operator: 54
#     operands: 52
# 44. b_{_a} in Digits
#     core type: Operation
#     operator: 54
#     operands: 53
# 45. d_{_a} in Digits
#     core type: Operation
#     operator: 54
#     operands: 55
# 46. b_{1} +  b_{2} +  ... +  b_{n}
#     core type: Operation
#     operator: 56
#     operands: 57
# 47. c
#     core type: Variable
#     sub-expressions:
# 48. _a -> a_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 58
# 49. m
#     core type: Variable
#     sub-expressions:
# 50. _a -> d_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 59
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 58, 60
# 53. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 67, 60
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 58. a_{_a}
#     core type: IndexedVar
# variable: 62
# index: 70
# 59. d_{_a}
#     core type: IndexedVar
# variable: 63
# index: 70
# 60. Digits
#     core type: Literal
#     sub-expressions:
# 61. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 65
#     end_index: 66
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. d
#     core type: Variable
#     sub-expressions:
# 64. _a -> b_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 67
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. n
#     core type: Variable
#     sub-expressions:
# 67. b_{_a}
#     core type: IndexedVar
# variable: 68
# index: 70
# 68. b
#     core type: Variable
#     sub-expressions:
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. _a
#     core type: Variable
#     sub-expressions:
