# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k
from proveit.logic import Equals
from proveit.numbers import eight, five, four, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
expr = Equals([one, two, three, four, five, six, seven, eight], [ExprRange(k, k, one, eight)])
# Out:
# expr: (1, 2, 3, 4, 5, 6, 7, 8) = (1, ..k.., 8)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1, 2, 3, 4, 5, 6, 7, 8\right) = \left(1, \ldots, 8\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1, 2, 3, 4, 5, 6, 7, 8) = (1, ..k.., 8)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1, 2, 3, 4, 5, 6, 7, 8), (1, ..k.., 8))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1, 2, 3, 4, 5, 6, 7, 8)
#    core type: ExprTuple
#    sub-expressions: 13, 5, 6, 7, 8, 9, 10, 14
# 4. (1, ..k.., 8)
#    core type: ExprTuple
#    sub-expressions: 11
# 5. 2
#    core type: Literal
#    sub-expressions:
# 6. 3
#    core type: Literal
#    sub-expressions:
# 7. 4
#    core type: Literal
#    sub-expressions:
# 8. 5
#    core type: Literal
#    sub-expressions:
# 9. 6
#    core type: Literal
#    sub-expressions:
# 10. 7
#     core type: Literal
#     sub-expressions:
# 11. 1, ..k.., 8
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 8
#     core type: Literal
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
