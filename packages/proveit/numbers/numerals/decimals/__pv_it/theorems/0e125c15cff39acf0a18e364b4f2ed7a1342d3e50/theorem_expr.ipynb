# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#count_to_3_range">count_to_3_range</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import count_to_3_range

# %%
# check that the built expression is the same as the stored expression
assert count_to_3_range.expr == stored_expr
assert count_to_3_range.expr._style_id == stored_expr._style_id
print("Passed sanity check: count_to_3_range matches stored_expr")
# Out:
# Passed sanity check: count_to_3_range matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(count_to_3_range.latex())
# Out:
# \vdash \left(1, 2, 3\right) = \left(1, \ldots, 3\right)

# %%
# display the expression information
count_to_3_range.expr_info()
# Out:
# 0. (1, 2, 3) = (1, ..k.., 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1, 2, 3), (1, ..k.., 3))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1, 2, 3)
#    core type: ExprTuple
#    sub-expressions: 8, 5, 9
# 4. (1, ..k.., 3)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. 2
#    core type: Literal
#    sub-expressions:
# 6. 1, ..k.., 3
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. k -> k
#    core type: Lambda
#    parameter: 10
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. k
#     core type: Variable
#     sub-expressions:
