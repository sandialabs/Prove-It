# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Function, Lambda, f, i, j
from proveit.core_expr_types import f_i_to_j
from proveit.logic import Equals
from proveit.numbers import Add, eight, five, four, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(i, eight)
expr = ExprTuple(Lambda([f, i, j], Conditional(Equals([f_i_to_j], [Function(f, [i]), Function(f, [Add(i, one)]), Function(f, [Add(i, two)]), Function(f, [Add(i, three)]), Function(f, [Add(i, four)]), Function(f, [Add(i, five)]), Function(f, [Add(i, six)]), Function(f, [Add(i, seven)]), Function(f, [sub_expr1])]), Equals(j, sub_expr1))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(f, i, j\right) \mapsto \left\{\left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right)\right) = \left(f\left(i\right), f\left(i + 1\right), f\left(i + 2\right), f\left(i + 3\right), f\left(i + 4\right), f\left(i + 5\right), f\left(i + 6\right), f\left(i + 7\right), f\left(i + 8\right)\right) \textrm{ if } j = \left(i + 8\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((f, i, j) -> {(f(i), f(i + 1), ..., f(j)) = (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8)) if j = (i + 8).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, i, j) -> {(f(i), f(i + 1), ..., f(j)) = (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8)) if j = (i + 8).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 41, 60, 22
# 3. {(f(i), f(i + 1), ..., f(j)) = (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8)) if j = (i + 8).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (f(i), f(i + 1), ..., f(j)) = (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8))
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. j = (i + 8)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((f(i), f(i + 1), ..., f(j)), (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8)))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (j, i + 8)
#    core type: ExprTuple
#    sub-expressions: 22, 40
# 9. (f(i), f(i + 1), ..., f(j))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (f(i), f(i + 1), f(i + 2), f(i + 3), f(i + 4), f(i + 5), f(i + 6), f(i + 7), f(i + 8))
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15, 16, 17, 18, 19, 20
# 11. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 60
#     end_index: 22
# 12. f(i)
#     core type: Operation
#     operator: 41
#     operand: 60
# 13. f(i + 1)
#     core type: Operation
#     operator: 41
#     operand: 33
# 14. f(i + 2)
#     core type: Operation
#     operator: 41
#     operand: 34
# 15. f(i + 3)
#     core type: Operation
#     operator: 41
#     operand: 35
# 16. f(i + 4)
#     core type: Operation
#     operator: 41
#     operand: 36
# 17. f(i + 5)
#     core type: Operation
#     operator: 41
#     operand: 37
# 18. f(i + 6)
#     core type: Operation
#     operator: 41
#     operand: 38
# 19. f(i + 7)
#     core type: Operation
#     operator: 41
#     operand: 39
# 20. f(i + 8)
#     core type: Operation
#     operator: 41
#     operand: 40
# 21. _a -> f(_a)
#     core type: Lambda
#     parameter: 52
#     body: 32
# 22. j
#     core type: Variable
#     sub-expressions:
# 23. (i)
#     core type: ExprTuple
#     sub-expressions: 60
# 24. (i + 1)
#     core type: ExprTuple
#     sub-expressions: 33
# 25. (i + 2)
#     core type: ExprTuple
#     sub-expressions: 34
# 26. (i + 3)
#     core type: ExprTuple
#     sub-expressions: 35
# 27. (i + 4)
#     core type: ExprTuple
#     sub-expressions: 36
# 28. (i + 5)
#     core type: ExprTuple
#     sub-expressions: 37
# 29. (i + 6)
#     core type: ExprTuple
#     sub-expressions: 38
# 30. (i + 7)
#     core type: ExprTuple
#     sub-expressions: 39
# 31. (i + 8)
#     core type: ExprTuple
#     sub-expressions: 40
# 32. f(_a)
#     core type: Operation
#     operator: 41
#     operand: 52
# 33. i + 1
#     core type: Operation
#     operator: 50
#     operands: 43
# 34. i + 2
#     core type: Operation
#     operator: 50
#     operands: 44
# 35. i + 3
#     core type: Operation
#     operator: 50
#     operands: 45
# 36. i + 4
#     core type: Operation
#     operator: 50
#     operands: 46
# 37. i + 5
#     core type: Operation
#     operator: 50
#     operands: 47
# 38. i + 6
#     core type: Operation
#     operator: 50
#     operands: 48
# 39. i + 7
#     core type: Operation
#     operator: 50
#     operands: 49
# 40. i + 8
#     core type: Operation
#     operator: 50
#     operands: 51
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 43. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 60, 53
# 44. (i, 2)
#     core type: ExprTuple
#     sub-expressions: 60, 54
# 45. (i, 3)
#     core type: ExprTuple
#     sub-expressions: 60, 55
# 46. (i, 4)
#     core type: ExprTuple
#     sub-expressions: 60, 56
# 47. (i, 5)
#     core type: ExprTuple
#     sub-expressions: 60, 57
# 48. (i, 6)
#     core type: ExprTuple
#     sub-expressions: 60, 58
# 49. (i, 7)
#     core type: ExprTuple
#     sub-expressions: 60, 59
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (i, 8)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 52. _a
#     core type: Variable
#     sub-expressions:
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. 3
#     core type: Literal
#     sub-expressions:
# 56. 4
#     core type: Literal
#     sub-expressions:
# 57. 5
#     core type: Literal
#     sub-expressions:
# 58. 6
#     core type: Literal
#     sub-expressions:
# 59. 7
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. 8
#     core type: Literal
#     sub-expressions:
