# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, i, x
from proveit.logic import Equals
from proveit.numbers import eight, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Equals([ExprRange(i, x, one, eight)], [x, x, x, x, x, x, x, x]))
# Out:
# expr: x -> ((x, ..8 repeats.., x) = (x, x, x, x, x, x, x, x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left(\left(x, ..8 \textrm{ repeats}.., x\right) = \left(x, x, x, x, x, x, x, x\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> ((x, ..8 repeats.., x) = (x, x, x, x, x, x, x, x))
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. (x, ..8 repeats.., x) = (x, x, x, x, x, x, x, x)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. ((x, ..8 repeats.., x), (x, x, x, x, x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (x, ..8 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x, x, x, x, x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 11, 11, 11, 11, 11, 11, 11, 11
# 6. x, ..8 repeats.., x
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. i -> x
#    core type: Lambda
#    parameter: 10
#    body: 11
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 8
#    core type: Literal
#    sub-expressions:
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
