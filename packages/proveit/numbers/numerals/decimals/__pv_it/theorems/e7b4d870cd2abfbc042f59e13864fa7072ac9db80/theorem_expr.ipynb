# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_1_7">mult_1_7</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import mult_1_7

# %%
# check that the built expression is the same as the stored expression
assert mult_1_7.expr == stored_expr
assert mult_1_7.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_1_7 matches stored_expr")
# Out:
# Passed sanity check: mult_1_7 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_1_7.latex())
# Out:
# \vdash \left(1 \cdot 7\right) = 7

# %%
# display the expression information
mult_1_7.expr_info()
# Out:
# 0. (1 * 7) = 7
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1 * 7, 7)
#    core type: ExprTuple
#    sub-expressions: 3, 7
# 3. 1 * 7
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (1, 7)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. 7
#    core type: Literal
#    sub-expressions:
