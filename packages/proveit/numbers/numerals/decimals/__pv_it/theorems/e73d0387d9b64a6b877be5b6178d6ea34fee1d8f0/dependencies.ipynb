# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#count_to_6_range">count_to_6_range</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/count_to_6_range/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.numerals.decimals import count_to_6_range

# %%
# %dependencies count_to_6_range
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon count_to_6_range</h3>
