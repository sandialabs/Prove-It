# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, c, d, k, m, n
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import DecimalSequence, Digits, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, b, one, n)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, n)
sub_expr5 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
expr = Conditional(Forall(instance_param_or_params = [sub_expr3, b, sub_expr4, sub_expr5], instance_expr = Equals(DecimalSequence(sub_expr3, sub_expr2, sub_expr5), DecimalSequence(sub_expr3, sub_expr4, sub_expr5)), domain = Digits, condition = Equals([sub_expr2], [sub_expr4])), And(InSet(m, Natural), InSet(n, Natural), InSet(k, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a_{1}, a_{2}, \ldots, a_{m}, b, c_{1}, c_{2}, \ldots, c_{n}, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b, b, ..\left(n - 3\right) \times.., b\right) = \left(c_{1}, c_{2}, \ldots, c_{n}\right)}~\left(\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ b, b, ..\left(n - 3\right) \times.., b ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c_{1}, c_{2}, \ldots, c_{n} ~ d_{1}, d_{2}, \ldots, d_{k})\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k} in Digits | (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})} (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k} in Digits | (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})} (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (m in Natural) and (n in Natural) and (k in Natural)
#    core type: Operation
#    operator: 19
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (m in Natural, n in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 7. m in Natural
#    core type: Operation
#    operator: 50
#    operands: 12
# 8. n in Natural
#    core type: Operation
#    operator: 50
#    operands: 13
# 9. k in Natural
#    core type: Operation
#    operator: 50
#    operands: 14
# 10. (a_{1}, a_{2}, ..., a_{m}, b,c_{1}, c_{2}, ..., c_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 63, 53, 38
# 11. {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 17
# 13. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 60, 17
# 14. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 17
# 15. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 35
#     operands: 18
# 16. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits) and (b in Digits)and (c_{1} in Digits) and  (c_{2} in Digits) and  ... and  (c_{n} in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits), b in Digits,(c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits),(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26, 27
# 21. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 29
#     operands: 28
# 22. #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 59
#     end_index: 45
# 24. b in Digits
#     core type: Operation
#     operator: 50
#     operands: 32
# 25. (c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 59
#     end_index: 60
# 26. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 59
#     end_index: 47
# 27. (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 28. (a_{1}, a_{2}, ..., a_{m},b, b, ..(n - 3) ×.., b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 52, 38
# 29. Decimal
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, a_{2}, ..., a_{m},c_{1}, c_{2}, ..., c_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 37, 53, 38
# 31. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 39
# 32. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 63, 56
# 33. _a -> (c_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 40
# 34. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 41
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. ((b, b, ..(n - 3) ×.., b), (c_{1}, c_{2}, ..., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 37. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 59
#     end_index: 45
# 38. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 59
#     end_index: 47
# 39. a_{_a} in Digits
#     core type: Operation
#     operator: 50
#     operands: 48
# 40. c_{_a} in Digits
#     core type: Operation
#     operator: 50
#     operands: 49
# 41. d_{_a} in Digits
#     core type: Operation
#     operator: 50
#     operands: 51
# 42. (b, b, ..(n - 3) ×.., b)
#     core type: ExprTuple
#     sub-expressions: 52
# 43. (c_{1}, c_{2}, ..., c_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 54
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. _a -> d_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 55
# 47. k
#     core type: Variable
#     sub-expressions:
# 48. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 49. (c_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 64, 56
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 52. b, b, ..(n - 3) ×.., b
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 59
#     end_index: 60
# 53. c_{1}, c_{2}, ..., c_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 59
#     end_index: 60
# 54. a_{_a}
#     core type: IndexedVar
# variable: 61
# index: 67
# 55. d_{_a}
#     core type: IndexedVar
# variable: 62
# index: 67
# 56. Digits
#     core type: Literal
#     sub-expressions:
# 57. _a -> b
#     core type: Lambda
#     parameter: 67
#     body: 63
# 58. _a -> c_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 64
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. n
#     core type: Variable
#     sub-expressions:
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. d
#     core type: Variable
#     sub-expressions:
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. c_{_a}
#     core type: IndexedVar
# variable: 65
# index: 67
# 65. c
#     core type: Variable
#     sub-expressions:
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. _a
#     core type: Variable
#     sub-expressions:
