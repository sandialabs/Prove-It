# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, c, d, i, k, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(i, b, one, n)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, n)
sub_expr5 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
expr = Forall([sub_expr3, b, sub_expr4, sub_expr5], Equals(DecimalSequence(sub_expr3, sub_expr2, sub_expr5), DecimalSequence(sub_expr3, sub_expr4, sub_expr5)), domains = [Digits, Digits, Digits, Digits], condition = Equals([sub_expr2], [sub_expr4]))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k} in Digits | (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n})} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}, d_{1}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b, ..n \textrm{ repeats}.., b\right) = \left(c_{1}, \ldots, c_{n}\right)}~\left(\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ ..n \textrm{ repeats}.. ~ b ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c_{1} ~ \ldots ~ c_{n} ~ d_{1} ~ \ldots ~ d_{k})\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k} in Digits | (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n})} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 26, 53, 42, 27
# 4. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  c_{1} in Digits ,  ..c_{_a} in Digits.. ,  c_{n} in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 24
#    operands: 7
# 6. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b in Digits) and (c_{1} in Digits) and ..(c_{_a} in Digits).. and (c_{n} in Digits) and (d_{1} in Digits) and ..(d_{_a} in Digits).. and (d_{k} in Digits) and ((b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k}), \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b in Digits, c_{1} in Digits, ..c_{_a} in Digits.., c_{n} in Digits, d_{1} in Digits, ..d_{_a} in Digits.., d_{k} in Digits, (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n}))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16
# 10. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ ..n repeats.. ~ b ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c_{1} ~ ..c_{_a}.. ~ c_{n} ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 48
#     end_index: 34
# 13. b in Digits
#     core type: Operation
#     operator: 39
#     operands: 21
# 14. (c_{1} in Digits), ..(c_{_a} in Digits).., (c_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 48
#     end_index: 49
# 15. (d_{1} in Digits), ..(d_{_a} in Digits).., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 48
#     end_index: 36
# 16. (b, ..n repeats.., b) = (c_{1}, ..c_{_a}.., c_{n})
#     core type: Operation
#     operator: 24
#     operands: 25
# 17. (a_{1}, ..a_{_a}.., a_{m}, b, ..n repeats.., b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 41, 27
# 18. Decimal
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, ..a_{_a}.., a_{m}, c_{1}, ..c_{_a}.., c_{n}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 26, 42, 27
# 20. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 28
# 21. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 53, 45
# 22. _a -> (c_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 29
# 23. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 30
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. ((b, ..n repeats.., b), (c_{1}, ..c_{_a}.., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 48
#     end_index: 34
# 27. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 48
#     end_index: 36
# 28. a_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 37
# 29. c_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 38
# 30. d_{_a} in Digits
#     core type: Operation
#     operator: 39
#     operands: 40
# 31. (b, ..n repeats.., b)
#     core type: ExprTuple
#     sub-expressions: 41
# 32. (c_{1}, ..c_{_a}.., c_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 33. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 43
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. _a -> d_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 44
# 36. k
#     core type: Variable
#     sub-expressions:
# 37. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 38. (c_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 54, 45
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. b, ..n repeats.., b
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 48
#     end_index: 49
# 42. c_{1}, ..c_{_a}.., c_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 43. a_{_a}
#     core type: IndexedVar
# variable: 50
# index: 56
# 44. d_{_a}
#     core type: IndexedVar
# variable: 51
# index: 56
# 45. Digits
#     core type: Literal
#     sub-expressions:
# 46. i -> b
#     core type: Lambda
#     parameter: 52
#     body: 53
# 47. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 54
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. d
#     core type: Variable
#     sub-expressions:
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. c_{_a}
#     core type: IndexedVar
# variable: 55
# index: 56
# 55. c
#     core type: Variable
#     sub-expressions:
# 56. _a
#     core type: Variable
#     sub-expressions:
