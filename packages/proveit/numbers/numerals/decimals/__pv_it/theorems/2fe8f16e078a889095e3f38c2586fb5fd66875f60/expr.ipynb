# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, i, k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, Less, Natural, nine, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
expr = Forall([m, k], Forall([sub_expr2, b], Equals(Add(DecimalSequence(sub_expr2, b, ExprRange(i, nine, one, k)), one), DecimalSequence(sub_expr2, Add(b, one), ExprRange(i, zero, one, k))), domains = [Digits, Digits], condition = Less(b, nine)), domains = [Natural, Natural])
# Out:
# expr: forall_{m, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{m}, b \in \mathbb{N}^{\leq 9}~|~b < 9}~\left(\left(\# (a_{1} ~ \ldots ~ a_{m} ~ b ~ 9 ~ ..k \textrm{ repeats}.. ~ 9) + 1\right) = \# (a_{1} ~ \ldots ~ a_{m} ~ \left(b + 1\right) ~ 0 ~ ..k \textrm{ repeats}.. ~ 0)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)) if m in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, k)
#    core type: ExprTuple
#    sub-expressions: 50, 53
# 3. {forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)) if m in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{m}, b in Digits | b < 9} ((\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (m in Natural) and (k in Natural)
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{m}, b) -> {(\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  b < 9.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. (m in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (a_{1}, ..a_{_a}.., a_{m}, b)
#    core type: ExprTuple
#    sub-expressions: 44, 46
# 10. {(\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b in Digits ,  b < 9.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. m in Natural
#     core type: Operation
#     operator: 42
#     operands: 15
# 12. k in Natural
#     core type: Operation
#     operator: 42
#     operands: 16
# 13. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b in Digits) and (b < 9)
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 21
# 16. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 53, 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1, \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b in Digits, b < 9)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9) + 1
#     core type: Operation
#     operator: 39
#     operands: 27
# 23. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b + 1) ~ 0 ~ ..k repeats.. ~ 0)
#     core type: Operation
#     operator: 37
#     operands: 28
# 24. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 52
#     end_index: 50
# 25. b in Digits
#     core type: Operation
#     operator: 42
#     operands: 30
# 26. b < 9
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9), 1)
#     core type: ExprTuple
#     sub-expressions: 33, 52
# 28. (a_{1}, ..a_{_a}.., a_{m}, b + 1, 0, ..k repeats.., 0)
#     core type: ExprTuple
#     sub-expressions: 44, 34, 35
# 29. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 58
#     body: 36
# 30. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 46, 48
# 31. <
#     core type: Literal
#     sub-expressions:
# 32. (b, 9)
#     core type: ExprTuple
#     sub-expressions: 46, 56
# 33. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9)
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. b + 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. 0, ..k repeats.., 0
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 52
#     end_index: 53
# 36. a_{_a} in Digits
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. Decimal
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, ..a_{_a}.., a_{m}, b, 9, ..k repeats.., 9)
#     core type: ExprTuple
#     sub-expressions: 44, 46, 45
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 46, 52
# 41. i -> 0
#     core type: Lambda
#     parameter: 55
#     body: 47
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 54, 48
# 44. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 52
#     end_index: 50
# 45. 9, ..k repeats.., 9
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 46. b
#     core type: Variable
#     sub-expressions:
# 47. 0
#     core type: Literal
#     sub-expressions:
# 48. Digits
#     core type: Literal
#     sub-expressions:
# 49. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 54
# 50. m
#     core type: Variable
#     sub-expressions:
# 51. i -> 9
#     core type: Lambda
#     parameter: 55
#     body: 56
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. k
#     core type: Variable
#     sub-expressions:
# 54. a_{_a}
#     core type: IndexedVar
# variable: 57
# index: 58
# 55. i
#     core type: Variable
#     sub-expressions:
# 56. 9
#     core type: Literal
#     sub-expressions:
# 57. a
#     core type: Variable
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
