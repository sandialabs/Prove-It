# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_5_3">mult_5_3</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import mult_5_3

# %%
# check that the built expression is the same as the stored expression
assert mult_5_3.expr == stored_expr
assert mult_5_3.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_5_3 matches stored_expr")
# Out:
# Passed sanity check: mult_5_3 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_5_3.latex())
# Out:
# \vdash \left(5 \cdot 3\right) = 15

# %%
# display the expression information
mult_5_3.expr_info()
# Out:
# 0. (5 * 3) = 15
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (5 * 3, 15)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 5 * 3
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 15
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (5, 3)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (1, 5)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 5
#     core type: Literal
#     sub-expressions:
