# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, c, d, k, m, n
from proveit.core_expr_types import b_1_to_n
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, DecimalSequence, Digits, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr4 = Add(b_1_to_n)
expr = ExprTuple(Lambda([m, n, k], Conditional(Forall(instance_param_or_params = [sub_expr2, b_1_to_n, c, sub_expr3], instance_expr = Equals(DecimalSequence(sub_expr2, sub_expr4, sub_expr3), DecimalSequence(sub_expr2, c, sub_expr3)), domain = Digits, condition = Equals(sub_expr4, c)), And(InSet(m, Natural), InSet(n, Natural), InSet(k, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(m, n, k\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{n}, c, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) = c}~\left(\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ \left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c ~ d_{1}, d_{2}, \ldots, d_{k})\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N} ,  k \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((m, n, k) -> {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (m, n, k) -> {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n, k)
#    core type: ExprTuple
#    sub-expressions: 48, 65, 50
# 3. {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (m in Natural) and (n in Natural) and (k in Natural)
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m in Natural, n in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#    core type: Lambda
#    parameters: 13\n   body: 14
# 10. m in Natural
#     core type: Operation
#     operator: 53
#     operands: 15
# 11. n in Natural
#     core type: Operation
#     operator: 53
#     operands: 16
# 12. k in Natural
#     core type: Operation
#     operator: 53
#     operands: 17
# 13. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{n}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 60, 46, 41
# 14. {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 65, 20
# 17. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 20
# 18. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 38
#     operands: 21
# 19. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits)and (b_{1} in Digits) and  (b_{2} in Digits) and  ... and  (b_{n} in Digits) and (c in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b_{1} +  b_{2} +  ... +  b_{n}) = c)
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits),(b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits), c in Digits,(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b_{1} +  b_{2} +  ... +  b_{n}) = c)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29, 30
# 24. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 32
#     operands: 31
# 25. #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 64
#     end_index: 48
# 27. (b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 64
#     end_index: 65
# 28. c in Digits
#     core type: Operation
#     operator: 53
#     operands: 36
# 29. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 64
#     end_index: 50
# 30. (b_{1} +  b_{2} +  ... +  b_{n}) = c
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. (a_{1}, a_{2}, ..., a_{m}, b_{1} +  b_{2} +  ... +  b_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 45, 41
# 32. Decimal
#     core type: Literal
#     sub-expressions:
# 33. (a_{1}, a_{2}, ..., a_{m}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 40, 46, 41
# 34. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 69
#     body: 42
# 35. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 69
#     body: 43
# 36. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 46, 59
# 37. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 69
#     body: 44
# 38. =
#     core type: Literal
#     sub-expressions:
# 39. (b_{1} +  b_{2} +  ... +  b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 40. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 64
#     end_index: 48
# 41. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 64
#     end_index: 50
# 42. a_{_a} in Digits
#     core type: Operation
#     operator: 53
#     operands: 51
# 43. b_{_a} in Digits
#     core type: Operation
#     operator: 53
#     operands: 52
# 44. d_{_a} in Digits
#     core type: Operation
#     operator: 53
#     operands: 54
# 45. b_{1} +  b_{2} +  ... +  b_{n}
#     core type: Operation
#     operator: 55
#     operands: 56
# 46. c
#     core type: Variable
#     sub-expressions:
# 47. _a -> a_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 57
# 48. m
#     core type: Variable
#     sub-expressions:
# 49. _a -> d_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 58
# 50. k
#     core type: Variable
#     sub-expressions:
# 51. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 52. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 66, 59
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 60
# 57. a_{_a}
#     core type: IndexedVar
# variable: 61
# index: 69
# 58. d_{_a}
#     core type: IndexedVar
# variable: 62
# index: 69
# 59. Digits
#     core type: Literal
#     sub-expressions:
# 60. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 64
#     end_index: 65
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. d
#     core type: Variable
#     sub-expressions:
# 63. _a -> b_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 66
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. b_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 67. b
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
