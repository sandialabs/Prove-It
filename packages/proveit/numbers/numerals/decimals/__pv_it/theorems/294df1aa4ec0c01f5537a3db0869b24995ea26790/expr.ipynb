# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, i, k
from proveit.logic import Equals, InSet
from proveit.numbers import Add, DecimalSequence, NaturalPos, nine, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Add(DecimalSequence(ExprRange(i, nine, one, k)), one), DecimalSequence(one, ExprRange(i, zero, one, k))), InSet(k, NaturalPos))
# Out:
# expr: {(\# (9 ~ ..k repeats.. ~ 9) + 1) = \# (1 ~ 0 ~ ..k repeats.. ~ 0) if k in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\# (9 ~ ..k \textrm{ repeats}.. ~ 9) + 1\right) = \# (1 ~ 0 ~ ..k \textrm{ repeats}.. ~ 0) \textrm{ if } k \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(\# (9 ~ ..k repeats.. ~ 9) + 1) = \# (1 ~ 0 ~ ..k repeats.. ~ 0) if k in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (\# (9 ~ ..k repeats.. ~ 9) + 1) = \# (1 ~ 0 ~ ..k repeats.. ~ 0)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. k in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (\# (9 ~ ..k repeats.. ~ 9) + 1, \# (1 ~ 0 ~ ..k repeats.. ~ 0))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. \# (9 ~ ..k repeats.. ~ 9) + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. \# (1 ~ 0 ~ ..k repeats.. ~ 0)
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# ...
