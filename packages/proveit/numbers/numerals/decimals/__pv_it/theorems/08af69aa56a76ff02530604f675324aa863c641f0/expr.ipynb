# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, d, k, m
from proveit.core_expr_types import b_1_to_n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr4 = Add(b_1_to_n)
expr = Forall(instance_param_or_params = [sub_expr2, b_1_to_n, c, sub_expr3], instance_expr = Equals(DecimalSequence(sub_expr2, sub_expr4, sub_expr3), DecimalSequence(sub_expr2, c, sub_expr3)), domain = Digits, condition = Equals(sub_expr4, c))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{n}, c, d_{1}, d_{2}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) = c}~\left(\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ \left(b_{1} +  b_{2} +  \ldots +  b_{n}\right) ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c ~ d_{1}, d_{2}, \ldots, d_{k})\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k} in Digits | (b_{1} +  b_{2} +  ... +  b_{n}) = c} (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{n}, c, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{n}, c,d_{1}, d_{2}, ..., d_{k})
#    core type: ExprTuple
#    sub-expressions: 27, 47, 33, 28
# 5. {#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits), (b_{1} in Digits) ,  (b_{2} in Digits) ,  ... ,  (b_{n} in Digits) ,  c in Digits, (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b_{1} +  b_{2} +  ... +  b_{n}) = c.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 25
#    operands: 8
# 7. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits)and (b_{1} in Digits) and  (b_{2} in Digits) and  ... and  (b_{n} in Digits) and (c in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b_{1} +  b_{2} +  ... +  b_{n}) = c)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (#(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits),(b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits), c in Digits,(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b_{1} +  b_{2} +  ... +  b_{n}) = c)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16, 17
# 11. #(a_{1}, a_{2}, ..., a_{m} ~ (b_{1} +  b_{2} +  ... +  b_{n}) ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 19
#     operands: 18
# 12. #(a_{1}, a_{2}, ..., a_{m} ~ c ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 51
#     end_index: 35
# 14. (b_{1} in Digits), (b_{2} in Digits), ..., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 51
#     end_index: 52
# 15. c in Digits
#     core type: Operation
#     operator: 40
#     operands: 23
# 16. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 51
#     end_index: 37
# 17. (b_{1} +  b_{2} +  ... +  b_{n}) = c
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. (a_{1}, a_{2}, ..., a_{m}, b_{1} +  b_{2} +  ... +  b_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 27, 32, 28
# 19. Decimal
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, a_{2}, ..., a_{m}, c,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 27, 33, 28
# 21. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 29
# 22. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 30
# 23. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 33, 46
# 24. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 56
#     body: 31
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (b_{1} +  b_{2} +  ... +  b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 51
#     end_index: 35
# 28. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 51
#     end_index: 37
# 29. a_{_a} in Digits
#     core type: Operation
#     operator: 40
#     operands: 38
# 30. b_{_a} in Digits
#     core type: Operation
#     operator: 40
#     operands: 39
# 31. d_{_a} in Digits
#     core type: Operation
#     operator: 40
#     operands: 41
# 32. b_{1} +  b_{2} +  ... +  b_{n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 33. c
#     core type: Variable
#     sub-expressions:
# 34. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 44
# 35. m
#     core type: Variable
#     sub-expressions:
# 36. _a -> d_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 45
# 37. k
#     core type: Variable
#     sub-expressions:
# 38. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 44, 46
# 39. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 53, 46
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. a_{_a}
#     core type: IndexedVar
# variable: 48
# index: 56
# 45. d_{_a}
#     core type: IndexedVar
# variable: 49
# index: 56
# 46. Digits
#     core type: Literal
#     sub-expressions:
# 47. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 48. a
#     core type: Variable
#     sub-expressions:
# 49. d
#     core type: Variable
#     sub-expressions:
# 50. _a -> b_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 53
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. b_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
