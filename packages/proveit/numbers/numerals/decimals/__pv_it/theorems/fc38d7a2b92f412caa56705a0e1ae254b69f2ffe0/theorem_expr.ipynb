# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#posnat7">posnat7</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import posnat7

# %%
# check that the built expression is the same as the stored expression
assert posnat7.expr == stored_expr
assert posnat7.expr._style_id == stored_expr._style_id
print("Passed sanity check: posnat7 matches stored_expr")
# Out:
# Passed sanity check: posnat7 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(posnat7.latex())
# Out:
# \vdash 7 \in \mathbb{N}^+

# %%
# display the expression information
posnat7.expr_info()
# Out:
# 0. 7 in NaturalPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (7, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 7
#    core type: Literal
#    sub-expressions:
# 4. NaturalPos
#    core type: Literal
#    sub-expressions:
