# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, c, d, k, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = IndexedVar(c, sub_expr1)
sub_expr4 = IndexedVar(d, sub_expr1)
sub_expr5 = ExprRange(sub_expr1, b, one, n)
sub_expr6 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr7 = ExprRange(sub_expr1, sub_expr3, one, n)
sub_expr8 = ExprRange(sub_expr1, sub_expr4, one, k)
expr = ExprTuple(Lambda([sub_expr6, b, sub_expr7, sub_expr8], Conditional(Equals(DecimalSequence(sub_expr6, sub_expr5, sub_expr8), DecimalSequence(sub_expr6, sub_expr7, sub_expr8)), And(ExprRange(sub_expr1, InSet(sub_expr2, Digits), one, m), InSet(b, Digits), ExprRange(sub_expr1, InSet(sub_expr3, Digits), one, n), ExprRange(sub_expr1, InSet(sub_expr4, Digits), one, k), Equals([sub_expr5], [sub_expr7])))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a_{1}, a_{2}, \ldots, a_{m}, b, c_{1}, c_{2}, \ldots, c_{n}, d_{1}, d_{2}, \ldots, d_{k}\right) \mapsto \left\{\texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ b, b, ..\left(n - 3\right) \times.., b ~ d_{1}, d_{2}, \ldots, d_{k}) = \texttt{\#}(a_{1}, a_{2}, \ldots, a_{m} ~ c_{1}, c_{2}, \ldots, c_{n} ~ d_{1}, d_{2}, \ldots, d_{k}) \textrm{ if } \left(a_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(a_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(a_{m} \in \mathbb{N}^{\leq 9}\right) ,  b \in \mathbb{N}^{\leq 9}, \left(c_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(c_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(c_{n} \in \mathbb{N}^{\leq 9}\right), \left(d_{1} \in \mathbb{N}^{\leq 9}\right) ,  \left(d_{2} \in \mathbb{N}^{\leq 9}\right) ,  \ldots ,  \left(d_{k} \in \mathbb{N}^{\leq 9}\right) ,  \left(b, b, ..\left(n - 3\right) \times.., b\right) = \left(c_{1}, c_{2}, \ldots, c_{n}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}, d_{1}, d_{2}, ..., d_{k}) -> {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a_{1}, a_{2}, ..., a_{m}, b,c_{1}, c_{2}, ..., c_{n},d_{1}, d_{2}, ..., d_{k})
#    core type: ExprTuple
#    sub-expressions: 25, 51, 41, 26
# 3. {#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}) if (a_{1} in Digits) ,  (a_{2} in Digits) ,  ... ,  (a_{m} in Digits) ,  b in Digits, (c_{1} in Digits) ,  (c_{2} in Digits) ,  ... ,  (c_{n} in Digits), (d_{1} in Digits) ,  (d_{2} in Digits) ,  ... ,  (d_{k} in Digits) ,  (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}) = #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 23
#    operands: 6
# 5. (a_{1} in Digits) and  (a_{2} in Digits) and  ... and  (a_{m} in Digits) and (b in Digits)and (c_{1} in Digits) and  (c_{2} in Digits) and  ... and  (c_{n} in Digits)and (d_{1} in Digits) and  (d_{2} in Digits) and  ... and  (d_{k} in Digits) and ((b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (#(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k}), #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits), b in Digits,(c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits),(d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits), (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n}))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# 9. #(a_{1}, a_{2}, ..., a_{m} ~ b, b, ..(n - 3) ×.., b ~ d_{1}, d_{2}, ..., d_{k})
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. #(a_{1}, a_{2}, ..., a_{m} ~ c_{1}, c_{2}, ..., c_{n} ~ d_{1}, d_{2}, ..., d_{k})
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. (a_{1} in Digits), (a_{2} in Digits), ..., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 47
#     end_index: 33
# 12. b in Digits
#     core type: Operation
#     operator: 38
#     operands: 20
# 13. (c_{1} in Digits), (c_{2} in Digits), ..., (c_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 47
#     end_index: 48
# 14. (d_{1} in Digits), (d_{2} in Digits), ..., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 47
#     end_index: 35
# 15. (b, b, ..(n - 3) ×.., b) = (c_{1}, c_{2}, ..., c_{n})
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. (a_{1}, a_{2}, ..., a_{m},b, b, ..(n - 3) ×.., b,d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 40, 26
# 17. Decimal
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, a_{2}, ..., a_{m},c_{1}, c_{2}, ..., c_{n},d_{1}, d_{2}, ..., d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 41, 26
# 19. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 55
#     body: 27
# 20. (b, Digits)
#     core type: ExprTuple
#     sub-expressions: 51, 44
# 21. _a -> (c_{_a} in Digits)
#     core type: Lambda
#     parameter: 55
#     body: 28
# 22. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 55
#     body: 29
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. ((b, b, ..(n - 3) ×.., b), (c_{1}, c_{2}, ..., c_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 25. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 47
#     end_index: 33
# 26. d_{1}, d_{2}, ..., d_{k}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 47
#     end_index: 35
# 27. a_{_a} in Digits
#     core type: Operation
#     operator: 38
#     operands: 36
# 28. c_{_a} in Digits
#     core type: Operation
#     operator: 38
#     operands: 37
# 29. d_{_a} in Digits
#     core type: Operation
#     operator: 38
#     operands: 39
# 30. (b, b, ..(n - 3) ×.., b)
#     core type: ExprTuple
#     sub-expressions: 40
# 31. (c_{1}, c_{2}, ..., c_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 32. _a -> a_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 42
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. _a -> d_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 43
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 37. (c_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 52, 44
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. b, b, ..(n - 3) ×.., b
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 47
#     end_index: 48
# 41. c_{1}, c_{2}, ..., c_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 42. a_{_a}
#     core type: IndexedVar
# variable: 49
# index: 55
# 43. d_{_a}
#     core type: IndexedVar
# variable: 50
# index: 55
# 44. Digits
#     core type: Literal
#     sub-expressions:
# 45. _a -> b
#     core type: Lambda
#     parameter: 55
#     body: 51
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. a
#     core type: Variable
#     sub-expressions:
# 50. d
#     core type: Variable
#     sub-expressions:
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. c_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
