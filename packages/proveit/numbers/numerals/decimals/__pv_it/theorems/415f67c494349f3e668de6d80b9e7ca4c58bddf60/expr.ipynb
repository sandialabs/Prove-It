# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, c, d, k, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, DecimalSequence, Digits, Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m)
sub_expr3 = ExprRange(sub_expr1, IndexedVar(b, sub_expr1), one, n)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(d, sub_expr1), one, k)
sub_expr5 = Add(sub_expr3)
expr = Forall([m, n, k], Forall([sub_expr2, sub_expr3, c, sub_expr4], Equals(DecimalSequence(sub_expr2, sub_expr5, sub_expr4), DecimalSequence(sub_expr2, c, sub_expr4)), domains = [Digits, Digits, Digits, Digits], condition = Equals(sub_expr5, c)), domains = [Natural, Natural, Natural])
# Out:
# expr: forall_{m, n, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m, n, k \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}, c, d_{1}, \ldots, d_{k} \in \mathbb{N}^{\leq 9}~|~\left(b_{1} + \ldots + b_{n}\right) = c}~\left(\# (a_{1} ~ \ldots ~ a_{m} ~ \left(b_{1} + \ldots + b_{n}\right) ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c ~ d_{1} ~ \ldots ~ d_{k})\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m, n, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, n, k) -> {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n, k)
#    core type: ExprTuple
#    sub-expressions: 47, 64, 49
# 3. {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})) if m in Natural ,  n in Natural ,  k in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k} in Digits | (b_{1} + ..b_{_a}.. + b_{n}) = c} (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (m in Natural) and (n in Natural) and (k in Natural)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. (m in Natural, n in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 39, 59, 45, 40
# 10. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. m in Natural
#     core type: Operation
#     operator: 52
#     operands: 16
# 12. n in Natural
#     core type: Operation
#     operator: 52
#     operands: 17
# 13. k in Natural
#     core type: Operation
#     operator: 52
#     operands: 18
# 14. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 37
#     operands: 19
# 15. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b_{1} in Digits) and ..(b_{_a} in Digits).. and (b_{n} in Digits) and (c in Digits) and (d_{1} in Digits) and ..(d_{_a} in Digits).. and (d_{k} in Digits) and ((b_{1} + ..b_{_a}.. + b_{n}) = c)
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 22
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 64, 22
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 22
# 19. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}), \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b_{1} in Digits, ..b_{_a} in Digits.., b_{n} in Digits, c in Digits, d_{1} in Digits, ..d_{_a} in Digits.., d_{k} in Digits, (b_{1} + ..b_{_a}.. + b_{n}) = c)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28, 29
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 31
#     operands: 30
# 24. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 63
#     end_index: 47
# 26. (b_{1} in Digits), ..(b_{_a} in Digits).., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 63
#     end_index: 64
# 27. c in Digits
#     core type: Operation
#     operator: 52
#     operands: 35
# 28. (d_{1} in Digits), ..(d_{_a} in Digits).., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 63
#     end_index: 49
# 29. (b_{1} + ..b_{_a}.. + b_{n}) = c
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. (a_{1}, ..a_{_a}.., a_{m}, b_{1} + ..b_{_a}.. + b_{n}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 39, 44, 40
# 31. Decimal
#     core type: Literal
#     sub-expressions:
# 32. (a_{1}, ..a_{_a}.., a_{m}, c, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 39, 45, 40
# 33. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 41
# 34. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 42
# 35. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 45, 58
# 36. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 67
#     body: 43
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (b_{1} + ..b_{_a}.. + b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 39. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 63
#     end_index: 47
# 40. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 63
#     end_index: 49
# 41. a_{_a} in Digits
#     core type: Operation
#     operator: 52
#     operands: 50
# 42. b_{_a} in Digits
#     core type: Operation
#     operator: 52
#     operands: 51
# 43. d_{_a} in Digits
#     core type: Operation
#     operator: 52
#     operands: 53
# 44. b_{1} + ..b_{_a}.. + b_{n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 45. c
#     core type: Variable
#     sub-expressions:
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 56
# 47. m
#     core type: Variable
#     sub-expressions:
# 48. _a -> d_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 57
# 49. k
#     core type: Variable
#     sub-expressions:
# 50. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 51. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 65, 58
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 59
# 56. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 67
# 57. d_{_a}
#     core type: IndexedVar
# variable: 61
# index: 67
# 58. Digits
#     core type: Literal
#     sub-expressions:
# 59. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 63
#     end_index: 64
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. d
#     core type: Variable
#     sub-expressions:
# 62. _a -> b_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 65
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. b_{_a}
#     core type: IndexedVar
# variable: 66
# index: 67
# 66. b
#     core type: Variable
#     sub-expressions:
# 67. _a
#     core type: Variable
#     sub-expressions:
