# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#reduce_9_repeats">reduce_9_repeats</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import reduce_9_repeats

# %%
# check that the built expression is the same as the stored expression
assert reduce_9_repeats.expr == stored_expr
assert reduce_9_repeats.expr._style_id == stored_expr._style_id
print("Passed sanity check: reduce_9_repeats matches stored_expr")
# Out:
# Passed sanity check: reduce_9_repeats matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reduce_9_repeats.latex())
# Out:
# \vdash \forall_{x}~\left(\left(x, ..9 \textrm{ repeats}.., x\right) = \left(x, x, x, x, x, x, x, x, x\right)\right)

# %%
# display the expression information
reduce_9_repeats.expr_info()
# Out:
# 0. forall_{x} ((x, ..9 repeats.., x) = (x, x, x, x, x, x, x, x, x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x, ..9 repeats.., x) = (x, x, x, x, x, x, x, x, x))
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. (x, ..9 repeats.., x) = (x, x, x, x, x, x, x, x, x)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((x, ..9 repeats.., x), (x, x, x, x, x, x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. (x, ..9 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x, x, x, x, x, x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 13, 13, 13, 13, 13, 13, 13, 13, 13
# 8. x, ..9 repeats.., x
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. i -> x
#    core type: Lambda
#    parameter: 12
#    body: 13
# 10. 1
#     core type: Literal
# ...
