# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i, x
from proveit.logic import Equals
from proveit.numbers import four, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(i, x, one, four)], [x, x, x, x])
# Out:
# expr: (x, ..4 repeats.., x) = (x, x, x, x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, ..4 \textrm{ repeats}.., x\right) = \left(x, x, x, x\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, ..4 repeats.., x) = (x, x, x, x)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((x, ..4 repeats.., x), (x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (x, ..4 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 10, 10, 10, 10
# 5. x, ..4 repeats.., x
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. i -> x
#    core type: Lambda
#    parameter: 9
#    body: 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 4
#    core type: Literal
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
