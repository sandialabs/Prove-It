# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i, x
from proveit.logic import Equals, Forall
from proveit.numbers import one, seven

# %%
# build up the expression from sub-expressions
expr = Forall([x], Equals([ExprRange(i, x, one, seven)], [x, x, x, x, x, x, x]))
# Out:
# expr: forall_{x} ((x, ..7 repeats.., x) = (x, x, x, x, x, x, x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x}~\left(\left(x, ..7 \textrm{ repeats}.., x\right) = \left(x, x, x, x, x, x, x\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x} ((x, ..7 repeats.., x) = (x, x, x, x, x, x, x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x, ..7 repeats.., x) = (x, x, x, x, x, x, x))
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. (x, ..7 repeats.., x) = (x, x, x, x, x, x, x)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((x, ..7 repeats.., x), (x, x, x, x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. (x, ..7 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x, x, x, x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 13, 13, 13, 13, 13, 13, 13
# 8. x, ..7 repeats.., x
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. i -> x
#    core type: Lambda
#    parameter: 12
#    body: 13
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 7
#     core type: Literal
#     sub-expressions:
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
