# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import DecimalSequence, Digits, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([a_1_to_n], InSet(DecimalSequence(a_1_to_n), Natural), domains = [Digits]), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n} in Digits} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{N}^{\leq 9}}~\left(\# (a_{1} ~ \ldots ~ a_{n}) \in \mathbb{N}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n} in Digits} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Digits} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural) if n in NaturalPos.
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in Digits} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in Digits} (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{n}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural if (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{n} in Digits).
#    core type: Lambda
#    parameters: 19\n   body: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 25, 9
# 8. {\# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural if (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{n} in Digits).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. \# (a_{1} ~ ..a_{_a}.. ~ a_{n}) in Natural
#     core type: Operation
#     operator: 26
#     operands: 12
# 11. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{n} in Digits)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (\# (a_{1} ~ ..a_{_a}.. ~ a_{n}), Natural)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a_{1} in Digits, ..a_{_a} in Digits.., a_{n} in Digits)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. \# (a_{1} ~ ..a_{_a}.. ~ a_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 24
#     end_index: 25
# 18. Decimal
#     core type: Literal
#     sub-expressions:
# 19. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 31
#     body: 22
# 21. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 22. a_{_a} in Digits
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. _a -> a_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. a_{_a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 29. Digits
#     core type: Literal
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
