# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, i, x
from proveit.numbers import five, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([ExprRange(i, x, one, five)], [x, x, x, x, x])
# Out:
# expr: ((x, ..5 repeats.., x), (x, x, x, x, x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, ..5 \textrm{ repeats}.., x\right), \left(x, x, x, x, x\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, ..5 repeats.., x), (x, x, x, x, x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (x, ..5 repeats.., x)
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (x, x, x, x, x)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 8, 8, 8
# 3. x, ..5 repeats.., x
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. i -> x
#    core type: Lambda
#    parameter: 7
#    body: 8
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. 5
#    core type: Literal
#    sub-expressions:
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. x
#    core type: Variable
#    sub-expressions:
