# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, c, d, k, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, DecimalSequence, Digits, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = IndexedVar(b, sub_expr1)
sub_expr4 = IndexedVar(d, sub_expr1)
sub_expr5 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr6 = ExprRange(sub_expr1, sub_expr3, one, n)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, k)
sub_expr8 = Add(sub_expr6)
expr = Lambda([sub_expr5, sub_expr6, c, sub_expr7], Conditional(Equals(DecimalSequence(sub_expr5, sub_expr8, sub_expr7), DecimalSequence(sub_expr5, c, sub_expr7)), And(ExprRange(sub_expr1, InSet(sub_expr2, Digits), one, m), ExprRange(sub_expr1, InSet(sub_expr3, Digits), one, n), InSet(c, Digits), ExprRange(sub_expr1, InSet(sub_expr4, Digits), one, k), Equals(sub_expr8, c))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{n}, c, d_{1}, \ldots, d_{k}\right) \mapsto \left\{\# (a_{1} ~ \ldots ~ a_{m} ~ \left(b_{1} + \ldots + b_{n}\right) ~ d_{1} ~ \ldots ~ d_{k}) = \# (a_{1} ~ \ldots ~ a_{m} ~ c ~ d_{1} ~ \ldots ~ d_{k}) \textrm{ if } a_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  a_{m} \in \mathbb{N}^{\leq 9} ,  b_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  b_{n} \in \mathbb{N}^{\leq 9} ,  c \in \mathbb{N}^{\leq 9} ,  d_{1} \in \mathbb{N}^{\leq 9} ,  \ldots ,  d_{k} \in \mathbb{N}^{\leq 9} ,  \left(b_{1} + \ldots + b_{n}\right) = c\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k}) -> {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{n}, c, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 24, 44, 30, 25
# 2. {\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) if a_{1} in Digits ,  ..a_{_a} in Digits.. ,  a_{m} in Digits ,  b_{1} in Digits ,  ..b_{_a} in Digits.. ,  b_{n} in Digits ,  c in Digits ,  d_{1} in Digits ,  ..d_{_a} in Digits.. ,  d_{k} in Digits ,  (b_{1} + ..b_{_a}.. + b_{n}) = c.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}) = \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 22
#    operands: 5
# 4. (a_{1} in Digits) and ..(a_{_a} in Digits).. and (a_{m} in Digits) and (b_{1} in Digits) and ..(b_{_a} in Digits).. and (b_{n} in Digits) and (c in Digits) and (d_{1} in Digits) and ..(d_{_a} in Digits).. and (d_{k} in Digits) and ((b_{1} + ..b_{_a}.. + b_{n}) = c)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (\# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k}), \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in Digits, ..a_{_a} in Digits.., a_{m} in Digits, b_{1} in Digits, ..b_{_a} in Digits.., b_{n} in Digits, c in Digits, d_{1} in Digits, ..d_{_a} in Digits.., d_{k} in Digits, (b_{1} + ..b_{_a}.. + b_{n}) = c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 14
# 8. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ (b_{1} + ..b_{_a}.. + b_{n}) ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ c ~ d_{1} ~ ..d_{_a}.. ~ d_{k})
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. (a_{1} in Digits), ..(a_{_a} in Digits).., (a_{m} in Digits)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 48
#     end_index: 32
# 11. (b_{1} in Digits), ..(b_{_a} in Digits).., (b_{n} in Digits)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 48
#     end_index: 49
# 12. c in Digits
#     core type: Operation
#     operator: 37
#     operands: 20
# 13. (d_{1} in Digits), ..(d_{_a} in Digits).., (d_{k} in Digits)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 48
#     end_index: 34
# 14. (b_{1} + ..b_{_a}.. + b_{n}) = c
#     core type: Operation
#     operator: 22
#     operands: 23
# 15. (a_{1}, ..a_{_a}.., a_{m}, b_{1} + ..b_{_a}.. + b_{n}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 29, 25
# 16. Decimal
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, ..a_{_a}.., a_{m}, c, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 24, 30, 25
# 18. _a -> (a_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 26
# 19. _a -> (b_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 27
# 20. (c, Digits)
#     core type: ExprTuple
#     sub-expressions: 30, 43
# 21. _a -> (d_{_a} in Digits)
#     core type: Lambda
#     parameter: 52
#     body: 28
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (b_{1} + ..b_{_a}.. + b_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 48
#     end_index: 32
# 25. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 48
#     end_index: 34
# 26. a_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 35
# 27. b_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 36
# 28. d_{_a} in Digits
#     core type: Operation
#     operator: 37
#     operands: 38
# 29. b_{1} + ..b_{_a}.. + b_{n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 30. c
#     core type: Variable
#     sub-expressions:
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 41
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. _a -> d_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 42
# 34. k
#     core type: Variable
#     sub-expressions:
# 35. (a_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 36. (b_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 50, 43
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (d_{_a}, Digits)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 41. a_{_a}
#     core type: IndexedVar
# variable: 45
# index: 52
# 42. d_{_a}
#     core type: IndexedVar
# variable: 46
# index: 52
# 43. Digits
#     core type: Literal
#     sub-expressions:
# 44. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. d
#     core type: Variable
#     sub-expressions:
# 47. _a -> b_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 50
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. b_{_a}
#     core type: IndexedVar
# variable: 51
# index: 52
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. _a
#     core type: Variable
#     sub-expressions:
