# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.DecimalSequence.html">DecimalSequence</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, i, k, m
from proveit.numbers import DecimalSequence, nine, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = DecimalSequence(ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, m), b, ExprRange(i, nine, one, k))
# Out:
# expr: \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \# (a_{1} ~ \ldots ~ a_{m} ~ b ~ 9 ~ ..k \textrm{ repeats}.. ~ 9)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. \# (a_{1} ~ ..a_{_a}.. ~ a_{m} ~ b ~ 9 ~ ..k repeats.. ~ 9)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Decimal
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{m}, b, 9, ..k repeats.., 9)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a_{1}, ..a_{_a}.., a_{m}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 7
# 4. b
#    core type: Variable
#    sub-expressions:
# 5. 9, ..k repeats.., 9
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 15
#    body: 11
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. i -> 9
#    core type: Lambda
#    parameter: 12
#    body: 13
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. a_{_a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. 9
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
