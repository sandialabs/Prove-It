# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_3_1">mult_3_1</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import mult_3_1

# %%
# check that the built expression is the same as the stored expression
assert mult_3_1.expr == stored_expr
assert mult_3_1.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_3_1 matches stored_expr")
# Out:
# Passed sanity check: mult_3_1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_3_1.latex())
# Out:
# \vdash \left(3 \cdot 1\right) = 3

# %%
# display the expression information
mult_3_1.expr_info()
# Out:
# 0. (3 * 1) = 3
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (3 * 1, 3)
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. 3 * 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (3, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 3
#    core type: Literal
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
