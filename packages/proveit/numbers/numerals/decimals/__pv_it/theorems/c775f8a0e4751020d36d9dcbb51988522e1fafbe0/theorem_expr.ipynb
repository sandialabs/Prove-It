# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_6_2">add_6_2</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import add_6_2

# %%
# check that the built expression is the same as the stored expression
assert add_6_2.expr == stored_expr
assert add_6_2.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_6_2 matches stored_expr")
# Out:
# Passed sanity check: add_6_2 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_6_2.latex())
# Out:
# \vdash \left(6 + 2\right) = 8

# %%
# display the expression information
add_6_2.expr_info()
# Out:
# 0. (6 + 2) = 8
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (6 + 2, 8)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 6 + 2
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 8
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (6, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 6
#    core type: Literal
#    sub-expressions:
# 8. 2
#    core type: Literal
#    sub-expressions:
