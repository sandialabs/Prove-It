# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#digit1">digit1</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import digit1

# %%
# check that the built expression is the same as the stored expression
assert digit1.expr == stored_expr
assert digit1.expr._style_id == stored_expr._style_id
print("Passed sanity check: digit1 matches stored_expr")
# Out:
# Passed sanity check: digit1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(digit1.latex())
# Out:
# \vdash 1 \in \mathbb{N}^{\leq 9}

# %%
# display the expression information
digit1.expr_info()
# Out:
# 0. 1 in Digits
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (1, Digits)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. Digits
#    core type: Literal
#    sub-expressions:
