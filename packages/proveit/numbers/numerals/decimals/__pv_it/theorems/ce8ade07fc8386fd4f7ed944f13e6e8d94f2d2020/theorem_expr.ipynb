# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#add_4_5">add_4_5</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import add_4_5

# %%
# check that the built expression is the same as the stored expression
assert add_4_5.expr == stored_expr
assert add_4_5.expr._style_id == stored_expr._style_id
print("Passed sanity check: add_4_5 matches stored_expr")
# Out:
# Passed sanity check: add_4_5 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_4_5.latex())
# Out:
# \vdash \left(4 + 5\right) = 9

# %%
# display the expression information
add_4_5.expr_info()
# Out:
# 0. (4 + 5) = 9
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (4 + 5, 9)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 4 + 5
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 9
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (4, 5)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 4
#    core type: Literal
#    sub-expressions:
# 8. 5
#    core type: Literal
#    sub-expressions:
