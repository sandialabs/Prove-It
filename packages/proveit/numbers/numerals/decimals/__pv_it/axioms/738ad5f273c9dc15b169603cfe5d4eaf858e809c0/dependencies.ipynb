# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#N_leq_9_def">N_leq_9_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.numerals.decimals import N_leq_9_def

# %%
# %dependencies N_leq_9_def
# Out:
# <h3>No theorems/conjectures depend upon N_leq_9_def</h3>
