# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#two_def">two_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.numerals.decimals import two_def

# %%
# %dependencies two_def
# Out:
# <h3>Theorems/conjectures that depend directly on two_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/nat2/thm_proof.ipynb">proveit.numbers.numerals.decimals.nat2</a></dt><dd><a class="ProveItLink" href="../../theorems/f05a14f3b1e025929c966a4ccb020e28f34812b20/expr.ipynb"><img src="../../theorems/f05a14f3b1e025929c966a4ccb020e28f34812b20/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
