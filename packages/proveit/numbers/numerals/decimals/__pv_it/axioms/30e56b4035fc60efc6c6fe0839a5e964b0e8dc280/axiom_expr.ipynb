# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#seven_def">seven_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import seven_def

# %%
# check that the built expression is the same as the stored expression
assert seven_def.expr == stored_expr
assert seven_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: seven_def matches stored_expr")
# Out:
# Passed sanity check: seven_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(seven_def.latex())
# Out:
# \vdash 7 = \left(6 + 1\right)

# %%
# display the expression information
seven_def.expr_info()
# Out:
# 0. 7 = (6 + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (7, 6 + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 7
#    core type: Literal
#    sub-expressions:
# 4. 6 + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (6, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 6
#    core type: Literal
#    sub-expressions:
# 8. 1
#    core type: Literal
#    sub-expressions:
