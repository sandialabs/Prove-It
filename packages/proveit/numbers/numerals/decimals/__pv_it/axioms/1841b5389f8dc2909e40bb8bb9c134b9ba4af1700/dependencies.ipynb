# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#one_def">one_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.numerals.decimals import one_def

# %%
# %dependencies one_def
# Out:
# <h3>Theorems/conjectures that depend directly on one_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/nat1/thm_proof.ipynb">proveit.numbers.numerals.decimals.nat1</a></dt><dd><a class="ProveItLink" href="../../theorems/7fb9a05424b991456a1d535347793e2786ff41910/expr.ipynb"><img src="../../theorems/7fb9a05424b991456a1d535347793e2786ff41910/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
