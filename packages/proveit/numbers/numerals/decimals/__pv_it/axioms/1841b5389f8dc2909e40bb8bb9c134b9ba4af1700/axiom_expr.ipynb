# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#one_def">one_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.numerals.decimals import one_def

# %%
# check that the built expression is the same as the stored expression
assert one_def.expr == stored_expr
assert one_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: one_def matches stored_expr")
# Out:
# Passed sanity check: one_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(one_def.latex())
# Out:
# \vdash 1 = \left(0 + 1\right)

# %%
# display the expression information
one_def.expr_info()
# Out:
# 0. 1 = (0 + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1, 0 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 3
# 3. 0 + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (0, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
