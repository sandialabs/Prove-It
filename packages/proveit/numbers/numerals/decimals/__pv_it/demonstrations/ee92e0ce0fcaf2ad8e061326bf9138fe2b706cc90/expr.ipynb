# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Add, DecimalSequence, four, nine, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(DecimalSequence(nine, nine, nine, nine, nine, nine, three), one), DecimalSequence(nine, nine, nine, nine, nine, nine, four))
# Out:
# expr: (9999993 + 1, 9999994)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(9999993 + 1, 9999994\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (9999993 + 1, 9999994)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 9999993 + 1
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. 9999994
#    core type: Operation
#    operator: 9
#    operands: 5
# 3. +
#    core type: Literal
#    sub-expressions:
# 4. (9999993, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (9, 9, 9, 9, 9, 9, 4)
#    core type: ExprTuple
#    sub-expressions: 11, 11, 11, 11, 11, 11, 8
# 6. 9999993
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 4
#    core type: Literal
#    sub-expressions:
# 9. Decimal
#    core type: Literal
#    sub-expressions:
# 10. (9, 9, 9, 9, 9, 9, 3)
#     core type: ExprTuple
#     sub-expressions: 11, 11, 11, 11, 11, 11, 12
# 11. 9
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
