# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i
from proveit.logic import Equals
from proveit.numbers import four, nine, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(i, nine, one, four)], [nine, nine, nine, nine])
# Out:
# expr: (9, ..4 repeats.., 9) = (9, 9, 9, 9)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(9, ..4 \textrm{ repeats}.., 9\right) = \left(9, 9, 9, 9\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (9, ..4 repeats.., 9) = (9, 9, 9, 9)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((9, ..4 repeats.., 9), (9, 9, 9, 9))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (9, ..4 repeats.., 9)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (9, 9, 9, 9)
#    core type: ExprTuple
#    sub-expressions: 10, 10, 10, 10
# 5. 9, ..4 repeats.., 9
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. i -> 9
#    core type: Lambda
#    parameter: 9
#    body: 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 4
#    core type: Literal
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. 9
#     core type: Literal
#     sub-expressions:
