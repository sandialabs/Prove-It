# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k
from proveit.core_expr_types import Len
from proveit.numbers import four, nine, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([nine, nine, nine, nine]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(9, 9, 9, 9)|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(9, 9, 9, 9\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(9, 9, 9, 9)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(9, 9, 9, 9)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((9, 9, 9, 9))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (9, 9, 9, 9)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 8, 8
# 7. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. 9
#    core type: Literal
#    sub-expressions:
# 9. 1, ..k.., 4
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 10. k -> k
#     core type: Lambda
#     parameter: 13
#     body: 13
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
