# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.divisibility</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, p
from proveit.logic import And, Forall, Not
from proveit.numbers import Divides, Greater, NaturalPos, one

# %%
# build up the expression from sub-expressions
expr = Forall([p], Not(And(Divides(p, a), Divides(p, b))), domains = [NaturalPos], condition = Greater(p, one))
# Out:
# expr: forall_{p in NaturalPos | p > 1} [not]((p | a) and (p | b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{p \in \mathbb{N}^+~|~p > 1}~(\lnot \left(\left(p \rvert a\right) \land \left(p \rvert b\right)\right))

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{p in NaturalPos | p > 1} [not]((p | a) and (p | b))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. p -> {[not]((p | a) and (p | b)) if p in NaturalPos ,  p > 1.
#    core type: Lambda
#    parameter: 25
#    body: 3
# 3. {[not]((p | a) and (p | b)) if p in NaturalPos ,  p > 1.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [not]((p | a) and (p | b))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (p in NaturalPos) and (p > 1)
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. not
#    core type: Literal
#    sub-expressions:
# 7. (p | a) and (p | b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (p in NaturalPos, p > 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (p | a, p | b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. p in NaturalPos
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. p > 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. p | a
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. p | b
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (p, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 17. >
#     core type: Literal
#     sub-expressions:
# 18. (p, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 23
# 19. (p, a)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 20. |
#     core type: Literal
#     sub-expressions:
# 21. (p, b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. NaturalPos
#     core type: Literal
#     sub-expressions:
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. p
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
