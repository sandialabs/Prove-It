# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.divisibility</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x, y
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, Divides, Integer, Mult, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Divides(x, Mult(x, y)), And(InSet(x, Complex), InSet(y, Integer), NotEquals(x, zero)))
# Out:
# expr: {x | (x * y) if x in Complex ,  y in Integer ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \rvert \left(x \cdot y\right) \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{Z} ,  x \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x | (x * y) if x in Complex ,  y in Integer ,  x != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x | (x * y)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complex) and (y in Integer) and (x != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. |
#    core type: Literal
#    sub-expressions:
# 4. (x, x * y)
#    core type: ExprTuple
#    sub-expressions: 21, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex, y in Integer, x != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. x * y
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. x in Complex
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. y in Integer
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. x != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (x, y)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 13. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y, Integer)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. 0
#     core type: Literal
#     sub-expressions:
