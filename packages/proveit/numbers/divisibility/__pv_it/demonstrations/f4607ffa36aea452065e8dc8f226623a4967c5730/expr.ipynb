# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Divides.html">Divides</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.divisibility</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.numbers import Divides, Mult, five, three, two

# %%
# build up the expression from sub-expressions
expr = Divides(Mult(two, three), Mult(two, five))
# Out:
# expr: (2 * 3) | (2 * 5)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot 3\right) \rvert \left(2 \cdot 5\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * 3) | (2 * 5)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. |
#    core type: Literal
#    sub-expressions:
# 2. (2 * 3, 2 * 5)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 * 3
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. 2 * 5
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (2, 5)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. 5
#     core type: Literal
#     sub-expressions:
