# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">divisibility</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#nonZeroDividesZero">nonZeroDividesZero</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, y
from proveit.numbers import zero
from proveit.numbers.divisibility._axioms_ import dividesDef
from proveit.numbers.division._theorems_ import fracZeroNumer
from proveit.numbers.number_sets.integers._theorems_ import zeroInInteger
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nonZeroDividesZero

# %%
defaults.assumptions = nonZeroDividesZero.conditions

# %%
dividesDef

# %%
dividesDef_inst = dividesDef.instantiate({x:x, y:zero})

# %%
fracZeroNumer

# %%
fracZeroNumer_inst = fracZeroNumer.instantiate({x:x})

# %%
zeroInInteger

# %%
zeroOverXInZ = fracZeroNumer_inst.subLeftSideInto(zeroInInteger)

# %%
dividesDef_inst.subLeftSideInto(zeroOverXInZ)

# %%
# %qed
