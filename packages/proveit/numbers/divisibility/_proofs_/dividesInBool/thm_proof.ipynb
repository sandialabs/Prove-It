# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">divisibility</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#dividesInBool">dividesInBool</a> theorem
# ========

# %%
import proveit
from proveit import defaults
# from proveit.core_expr_types import
from proveit._common_ import a, b, x, y
from proveit.numbers import frac
from proveit.numbers.divisibility._axioms_ import dividesDef
from proveit.numbers.number_sets.integers._theorems_ import xInIntInBool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving dividesInBool

# %%
defaults.assumptions = dividesInBool.conditions

# %%
dividesDef

# %%
dividesDef_inst = dividesDef.instantiate(
    {x:x, y:y})

# %%
xInIntInBool

# %%
xInIntInBool_inst = xInIntInBool.instantiate({x:frac(y, x)})

# %%
dividesDef_inst.subLeftSideInto(xInIntInBool_inst)

# %%
# %qed
