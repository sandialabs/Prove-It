# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a
from proveit.logic import InSet
from proveit.numbers import Complex, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(InSet(Neg(a), Complex), InSet(a, Complex)))
# Out:
# expr: a -> {(-a) in Complex if a in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{\left(-a\right) \in \mathbb{C} \textrm{ if } a \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a -> {(-a) in Complex if a in Complex.
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. {(-a) in Complex if a in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (-a) in Complex
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. a in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (-a, Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (a, Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 8
# 7. -a
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
