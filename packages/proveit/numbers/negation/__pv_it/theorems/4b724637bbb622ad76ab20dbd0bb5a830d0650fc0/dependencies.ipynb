# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_neg_through_binary_sum">distribute_neg_through_binary_sum</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/distribute_neg_through_binary_sum/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.negation import distribute_neg_through_binary_sum

# %%
# %dependencies distribute_neg_through_binary_sum
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon distribute_neg_through_binary_sum</h3>
