# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_times_neg">neg_times_neg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.negation import neg_times_neg

# %%
# check that the built expression is the same as the stored expression
assert neg_times_neg.expr == stored_expr
assert neg_times_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_times_neg matches stored_expr")
# Out:
# Passed sanity check: neg_times_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_times_neg.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{C}}~\left(\left(\left(-x\right) \cdot \left(-y\right)\right) = \left(x \cdot y\right)\right)

# %%
# display the expression information
neg_times_neg.expr_info()
# Out:
# 0. forall_{x, y in Complex} (((-x) * (-y)) = (x * y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {((-x) * (-y)) = (x * y) if x in Complex ,  y in Complex.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ((-x) * (-y)) = (x * y)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x in Complex) and (y in Complex)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ((-x) * (-y), x * y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Complex, y in Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. (-x) * (-y)
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. x * y
# ...
