# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, Mult, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(x, Neg(one)), Neg(x)), InSet(x, Complex))
# Out:
# expr: {(x * (-1)) = (-x) if x in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x \cdot \left(-1\right)\right) = \left(-x\right) \textrm{ if } x \in \mathbb{C}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x * (-1)) = (-x) if x in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x * (-1)) = (-x)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x * (-1), -x)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Complex)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 7. x * (-1)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. -x
#    core type: Operation
#    operator: 14
#    operand: 12
# 9. Complex
#    core type: Literal
#    sub-expressions:
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (x, -1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
