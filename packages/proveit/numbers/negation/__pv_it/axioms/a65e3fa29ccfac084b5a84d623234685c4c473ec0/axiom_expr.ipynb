# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#neg_def_add_inv">neg_def_add_inv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.negation import neg_def_add_inv

# %%
# check that the built expression is the same as the stored expression
assert neg_def_add_inv.expr == stored_expr
assert neg_def_add_inv.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_def_add_inv matches stored_expr")
# Out:
# Passed sanity check: neg_def_add_inv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_def_add_inv.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{N}~|~\left(a + b\right) = c}~\left(\left(c + \left(-a\right)\right) = b\right)

# %%
# display the expression information
neg_def_add_inv.expr_info()
# Out:
# 0. forall_{a, b, c in Natural | (a + b) = c} ((c + (-a)) = b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(c + (-a)) = b if a in Natural ,  b in Natural ,  c in Natural ,  (a + b) = c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 25
# 4. {(c + (-a)) = b if a in Natural ,  b in Natural ,  c in Natural ,  (a + b) = c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (c + (-a)) = b
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (a in Natural) and (b in Natural) and (c in Natural) and ((a + b) = c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (c + (-a), b)
#    core type: ExprTuple
#    sub-expressions: 10, 30
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Natural, b in Natural, c in Natural, (a + b) = c)
#    core type: ExprTuple
# ...
