# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, y
from proveit.logic import Equals
from proveit.numbers import Add, Mult

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(y, b)
expr = Equals(Mult(Mult(a, sub_expr1), c), Mult(a, sub_expr1, c))
# Out:
# expr: ((a * (y + b)) * c) = (a * (y + b) * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a \cdot \left(y + b\right)\right) \cdot c\right) = \left(a \cdot \left(y + b\right) \cdot c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a * (y + b)) * c) = (a * (y + b) * c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a * (y + b)) * c, a * (y + b) * c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a * (y + b)) * c
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. a * (y + b) * c
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (a * (y + b), c)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (a, y + b, c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 8
# 7. a * (y + b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, y + b)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. y + b
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (y, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
