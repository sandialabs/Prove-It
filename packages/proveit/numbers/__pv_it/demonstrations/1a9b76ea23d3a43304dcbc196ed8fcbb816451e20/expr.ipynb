# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Less.html">Less</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, a, b, x
from proveit.numbers import Add, Less

# %%
# build up the expression from sub-expressions
expr = Less(Add(a, x, b), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: (a + x + b) < _a

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + x + b\right) < {_{-}a}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a + x + b) < _a
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <
#    core type: Literal
#    sub-expressions:
# 2. (a + x + b, _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + x + b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (a, x, b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
