# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, x, y
from proveit.logic import Equals
from proveit.numbers import Add, Mult

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(Mult(a, Add(x, b)), c), Mult(Mult(a, Add(y, b)), c))
# Out:
# expr: ((a * (x + b)) * c) = ((a * (y + b)) * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a \cdot \left(x + b\right)\right) \cdot c\right) = \left(\left(a \cdot \left(y + b\right)\right) \cdot c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a * (x + b)) * c) = ((a * (y + b)) * c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a * (x + b)) * c, (a * (y + b)) * c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a * (x + b)) * c
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. (a * (y + b)) * c
#    core type: Operation
#    operator: 11
#    operands: 6
# 5. (a * (x + b), c)
#    core type: ExprTuple
#    sub-expressions: 7, 9
# 6. (a * (y + b), c)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a * (x + b)
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. a * (y + b)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. (a, x + b)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (a, y + b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. x + b
#     core type: Operation
#     operator: 17
#     operands: 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. y + b
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x, b)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (y, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. y
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
