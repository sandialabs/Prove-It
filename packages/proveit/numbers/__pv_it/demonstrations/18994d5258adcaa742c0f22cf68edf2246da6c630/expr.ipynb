# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, x, y
from proveit.numbers import Add, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(Mult(a, Add(x, b)), c), Mult(Mult(a, Add(y, b)), c))
# Out:
# expr: ((a * (x + b)) * c, (a * (y + b)) * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a \cdot \left(x + b\right)\right) \cdot c, \left(a \cdot \left(y + b\right)\right) \cdot c\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a * (x + b)) * c, (a * (y + b)) * c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a * (x + b)) * c
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (a * (y + b)) * c
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. (a * (x + b), c)
#    core type: ExprTuple
#    sub-expressions: 5, 7
# 4. (a * (y + b), c)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. a * (x + b)
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. a * (y + b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. (a, x + b)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, y + b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. x + b
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. y + b
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (y, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
