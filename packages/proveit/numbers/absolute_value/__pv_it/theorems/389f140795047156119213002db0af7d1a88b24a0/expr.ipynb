# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.logic import Equals, Forall
from proveit.numbers import Abs, Neg, RealNeg

# %%
# build up the expression from sub-expressions
expr = Forall([x], Equals(Abs(x), Neg(x)), domains = [RealNeg])
# Out:
# expr: forall_{x in RealNeg} (|x| = (-x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}^-}~\left(\left|x\right| = \left(-x\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in RealNeg} (|x| = (-x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {|x| = (-x) if x in RealNeg.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {|x| = (-x) if x in RealNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |x| = (-x)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in RealNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|x|, -x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. |x|
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. -x
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. RealNeg
#     core type: Literal
#     sub-expressions:
# 13. Abs
#     core type: Literal
#     sub-expressions:
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
