# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x, y
from proveit.logic import And
from proveit.numbers import Abs, LessEq, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(LessEq(Abs(x), y), And(LessEq(Neg(y), x), LessEq(x, y)))
# Out:
# expr: (|x| <= y, ((-y) <= x) and (x <= y))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|x\right| \leq y, \left(\left(-y\right) \leq x\right) \land \left(x \leq y\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|x| <= y, ((-y) <= x) and (x <= y))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |x| <= y
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. ((-y) <= x) and (x <= y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|x|, y)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((-y) <= x, x <= y)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. |x|
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. (-y) <= x
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. x <= y
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. (-y, x)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. (x, y)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 13. -y
#     core type: Operation
#     operator: 15
#     operand: 16
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
