# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#abs_elim">abs_elim</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.absolute_value import abs_elim

# %%
# check that the built expression is the same as the stored expression
assert abs_elim.expr == stored_expr
assert abs_elim.expr._style_id == stored_expr._style_id
print("Passed sanity check: abs_elim matches stored_expr")
# Out:
# Passed sanity check: abs_elim matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(abs_elim.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}^{\ge 0}}~\left(\left|x\right| = x\right)

# %%
# display the expression information
abs_elim.expr_info()
# Out:
# 0. forall_{x in RealNonNeg} (|x| = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {|x| = x if x in RealNonNeg.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {|x| = x if x in RealNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |x| = x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in RealNonNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|x|, x)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 10. |x|
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
# ...
