# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_.ipynb">modular</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#full_modular_range_equiv">full_modular_range_equiv</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving full_modular_range_equiv
