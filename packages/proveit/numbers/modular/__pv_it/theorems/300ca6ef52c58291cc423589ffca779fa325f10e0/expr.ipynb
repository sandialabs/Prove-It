# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Forall, NotEquals
from proveit.numbers import Abs, Add, LessEq, Mod, ModAbs, Neg, Real, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c], LessEq(ModAbs(Add(Mod(Add(b, a), c), Neg(b)), c), Abs(a)), domains = [Real, Real, Real], condition = NotEquals(c, zero))
# Out:
# expr: forall_{a, b, c in Real | c != 0} (|((b + a) mod  c) - b|_{mod c} <= |a|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{R}~|~c \neq 0}~\left(\left|\left(\left(b + a\right) ~\textup{mod}~ c\right) - b\right|_{\textup{mod}\thinspace c} \leq \left|a\right|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c in Real | c != 0} (|((b + a) mod  c) - b|_{mod c} <= |a|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {|((b + a) mod  c) - b|_{mod c} <= |a| if a in Real ,  b in Real ,  c in Real ,  c != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 40, 39, 36
# 4. {|((b + a) mod  c) - b|_{mod c} <= |a| if a in Real ,  b in Real ,  c in Real ,  c != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |((b + a) mod  c) - b|_{mod c} <= |a|
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Real) and (b in Real) and (c in Real) and (c != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (|((b + a) mod  c) - b|_{mod c}, |a|)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
# ...
