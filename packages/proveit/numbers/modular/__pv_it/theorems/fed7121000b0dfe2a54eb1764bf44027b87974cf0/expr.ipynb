# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, N, a, b, c, x
from proveit.logic import Card, Equals, Forall, InSet, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, NaturalPos, greater_eq, one, subtract, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(a, b)
expr = Lambda(N, Conditional(Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(SetOfAll(instance_param_or_params = [x], instance_element = Mod(Add(x, c), N), domain = sub_expr1), Interval(zero, subtract(N, one))), domain = Integer, condition = greater_eq(Card(sub_expr1), N)), InSet(N, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# N \mapsto \left\{\forall_{a, b, c \in \mathbb{Z}~|~|\{a~\ldotp \ldotp~b\}| \geq N}~\left(\left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a~\ldotp \ldotp~b\}} = \{0~\ldotp \ldotp~N - 1\}\right) \textrm{ if } N \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. N -> {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.
#    core type: Lambda
#    parameter: 52
#    body: 2
# 1. (N)
#    core type: ExprTuple
#    sub-expressions: 52
# 2. {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, b, c in Integer | |{a .. b}| >= N} ({(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. N in NaturalPos
#    core type: Operation
#    operator: 47
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b, c) -> {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (N, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 52, 9
# 8. (a, b, c) -> {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 61, 62, 60
# 11. {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. {(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a in Integer) and (b in Integer) and (c in Integer) and (|{a .. b}| >= N)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. ({(x + c) mod N}_{x in {a .. b}}, {0 .. N - 1})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a in Integer, b in Integer, c in Integer, |{a .. b}| >= N)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22, 23
# 18. {(x + c) mod N}_{x in {a .. b}}
#     core type: Operation
#     operator: 24
#     operand: 32
# 19. {0 .. N - 1}
#     core type: Operation
#     operator: 57
#     operands: 26
# 20. a in Integer
#     core type: Operation
#     operator: 47
#     operands: 27
# 21. b in Integer
#     core type: Operation
#     operator: 47
#     operands: 28
# 22. c in Integer
#     core type: Operation
#     operator: 47
#     operands: 29
# 23. |{a .. b}| >= N
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. SetOfAll
#     core type: Literal
#     sub-expressions:
# 25. (x -> {(x + c) mod N if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 26. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 27. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 35
# 28. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 35
# 29. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 35
# 30. <=
#     core type: Literal
#     sub-expressions:
# 31. (N, |{a .. b}|)
#     core type: ExprTuple
#     sub-expressions: 52, 36
# 32. x -> {(x + c) mod N if x in {a .. b}.
#     core type: Lambda
#     parameter: 59
#     body: 38
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. N - 1
#     core type: Operation
#     operator: 55
#     operands: 39
# 35. Integer
#     core type: Literal
#     sub-expressions:
# 36. |{a .. b}|
#     core type: Operation
#     operator: 40
#     operand: 53
# 37. (x)
#     core type: ExprTuple
#     sub-expressions: 59
# 38. {(x + c) mod N if x in {a .. b}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 39. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 44
# 40. card
#     core type: Literal
#     sub-expressions:
# 41. ({a .. b})
#     core type: ExprTuple
#     sub-expressions: 53
# 42. (x + c) mod N
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. x in {a .. b}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. -1
#     core type: Operation
#     operator: 49
#     operand: 54
# 45. mod
#     core type: Literal
#     sub-expressions:
# 46. (x + c, N)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 59, 53
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. x + c
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. N
#     core type: Variable
#     sub-expressions:
# 53. {a .. b}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (x, c)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (a, b)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. b
#     core type: Variable
#     sub-expressions:
