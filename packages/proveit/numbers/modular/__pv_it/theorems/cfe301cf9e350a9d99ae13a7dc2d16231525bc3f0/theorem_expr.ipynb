# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#full_modular_range_equiv">full_modular_range_equiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.modular import full_modular_range_equiv

# %%
# check that the built expression is the same as the stored expression
assert full_modular_range_equiv.expr == stored_expr
assert full_modular_range_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: full_modular_range_equiv matches stored_expr")
# Out:
# Passed sanity check: full_modular_range_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(full_modular_range_equiv.latex())
# Out:
# \vdash \forall_{N, a, b \in \mathbb{Z}~|~\left(b - a\right) = \left(N - 1\right), N \neq 0}~\left(\left\{x ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\}\right)

# %%
# display the expression information
full_modular_range_equiv.expr_info()
# Out:
# 0. forall_{N, a, b in Integer | (b - a) = (N - 1), N != 0} ({x mod  N}_{x in {a...b}} = {0...N - 1})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (N, a, b) -> {{x mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (N, a, b)
#    core type: ExprTuple
#    sub-expressions: 43, 50, 51
# 4. {{x mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {x mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (N in Integer) and (a in Integer) and (b in Integer) and ((b - a) = (N - 1)) and (N != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ({x mod  N}_{x in {a...b}}, {0...N - 1})
# ...
