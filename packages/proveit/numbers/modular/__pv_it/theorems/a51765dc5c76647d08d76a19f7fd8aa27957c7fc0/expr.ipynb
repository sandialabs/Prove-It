# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import L, b
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Mod, ModAbs, Real, RealPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j], instance_expr = Forall(instance_param_or_params = [L], instance_expr = Equals(ModAbs(Add(a_1_to_i, Mod(b, L), c_1_to_j), L), ModAbs(Add(a_1_to_i, b, c_1_to_j), L)).with_wrapping_at(2), domain = RealPos), domain = Real)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{R}}~\left[\forall_{L \in \mathbb{R}^+}~\left(\begin{array}{c} \begin{array}{l} \left|a_{1} +  a_{2} +  \ldots +  a_{i} + \left(b ~\textup{mod}~ L\right)+ c_{1} +  c_{2} +  \ldots +  c_{j}\right|_{\textup{mod}\thinspace L} =  \\ \left|a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right|_{\textup{mod}\thinspace L} \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Real} [forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#    core type: Lambda
#    parameters: 40\n   body: 3
# 3. {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (a_{1} in Real) and  (a_{2} in Real) and  ... and  (a_{i} in Real) and (b in Real)and (c_{1} in Real) and  (c_{2} in Real) and  ... and  (c_{j} in Real)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (L -> {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real), b in Real,(c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. L -> {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.
#     core type: Lambda
#     parameter: 52
#     body: 15
# 11. (a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 49
#     end_index: 47
# 12. b in Real
#     core type: Operation
#     operator: 27
#     operands: 17
# 13. (c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 49
#     end_index: 50
# 14. (L)
#     core type: ExprTuple
#     sub-expressions: 52
# 15. {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. _a -> (a_{_a} in Real)
#     core type: Lambda
#     parameter: 58
#     body: 21
# 17. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 51, 32
# 18. _a -> (c_{_a} in Real)
#     core type: Lambda
#     parameter: 58
#     body: 22
# 19. |a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. L in RealPos
#     core type: Operation
#     operator: 27
#     operands: 25
# 21. a_{_a} in Real
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. c_{_a} in Real
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}, |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. (L, RealPos)
#     core type: ExprTuple
#     sub-expressions: 52, 31
# 26. (a_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 53, 32
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (c_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 54, 32
# 29. |a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 34
#     operands: 33
# 30. |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. RealPos
#     core type: Literal
#     sub-expressions:
# 32. Real
#     core type: Literal
#     sub-expressions:
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 36, 52
# 34. ModAbs
#     core type: Literal
#     sub-expressions:
# 35. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 37, 52
# 36. a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 39
#     operands: 38
# 37. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. (a_{1}, a_{2}, ..., a_{i}, b mod L,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 42, 41, 43
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 42, 51, 43
# 41. b mod L
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 49
#     end_index: 47
# 43. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 44. mod
#     core type: Literal
#     sub-expressions:
# 45. (b, L)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 46. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 53
# 47. i
#     core type: Variable
#     sub-expressions:
# 48. _a -> c_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 54
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. L
#     core type: Variable
#     sub-expressions:
# 53. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 54. c_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. c
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
