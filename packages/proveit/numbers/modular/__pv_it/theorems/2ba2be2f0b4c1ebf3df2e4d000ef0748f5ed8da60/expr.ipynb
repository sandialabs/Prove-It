# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Abs, Add, Integer, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Mod(a, b), Interval(zero, Add(Abs(b), Neg(one)))), And(InSet(a, Integer), InSet(b, Integer), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a ~\textup{mod}~ b\right) \in \{0 \dots \left|b\right| - 1\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {(a mod  b) in {0...|b| - 1} if a in Integer ,  b in Integer ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a mod  b) in {0...|b| - 1}
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. (a in Integer) and (b in Integer) and (b != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a mod  b, {0...|b| - 1})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, b != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. a mod  b
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. {0...|b| - 1}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. a in Integer
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. b in Integer
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. b != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. mod
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (0, |b| - 1)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 16. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 30, 24
# 21. |b| - 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. Integer
#     core type: Literal
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (|b|, -1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. |b|
#     core type: Operation
#     operator: 29
#     operand: 30
# 28. -1
#     core type: Operation
#     operator: 31
#     operand: 32
# 29. Abs
#     core type: Literal
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. 1
#     core type: Literal
#     sub-expressions:
