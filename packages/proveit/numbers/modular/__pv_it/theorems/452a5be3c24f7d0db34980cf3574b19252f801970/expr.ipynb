# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Mod, Real, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Mod(a, b), Real), And(InSet(a, Real), InSet(b, Real), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {(a mod  b) in Real if a in Real ,  b in Real ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a ~\textup{mod}~ b\right) \in \mathbb{R} \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  b \neq 0\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(a mod  b) in Real if a in Real ,  b in Real ,  b != 0.
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {(a mod  b) in Real if a in Real ,  b in Real ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a mod  b) in Real
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (a in Real) and (b in Real) and (b != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a mod  b, Real)
#    core type: ExprTuple
#    sub-expressions: 7, 19
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real, b != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. a mod  b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. a in Real
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. b in Real
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. b != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. mod
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 13. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. Real
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. 0
#     core type: Literal
#     sub-expressions:
