# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Forall, InSet, NotEquals
from proveit.numbers import Integer, Mod, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], InSet(Mod(a, b), Integer), domains = [Integer, Integer], condition = NotEquals(b, zero))
# Out:
# expr: forall_{a, b in Integer | b != 0} ((a mod  b) in Integer)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}~|~b \neq 0}~\left(\left(a ~\textup{mod}~ b\right) \in \mathbb{Z}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Integer | b != 0} ((a mod  b) in Integer)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a mod  b) in Integer if a in Integer ,  b in Integer ,  b != 0.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a mod  b) in Integer if a in Integer ,  b in Integer ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a mod  b) in Integer
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (a in Integer) and (b in Integer) and (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a mod  b, Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 21
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integer, b in Integer, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. a mod  b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a in Integer
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. b in Integer
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. b != 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. mod
#     core type: Literal
#     sub-expressions:
# 14. (a, b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 15. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. Integer
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
