# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complete_interval_left_shift_image_size">complete_interval_left_shift_image_size</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.modular import complete_interval_left_shift_image_size

# %%
# check that the built expression is the same as the stored expression
assert complete_interval_left_shift_image_size.expr == stored_expr
assert complete_interval_left_shift_image_size.expr._style_id == stored_expr._style_id
print("Passed sanity check: complete_interval_left_shift_image_size matches stored_expr")
# Out:
# Passed sanity check: complete_interval_left_shift_image_size matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{N \in \mathbb{N}^+}~\left[\forall_{a, b, c \in \mathbb{Z}~|~|\{a~\ldotp \ldotp~b\}| \geq N}~\left(|\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a~\ldotp \ldotp~b\}}| = N\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{N in NaturalPos} [forall_{a, b, c in Integer | |{a .. b}| >= N} (|{(c + x) mod N}_{x in {a .. b}}| = N)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (N -> {forall_{a, b, c in Integer | |{a .. b}| >= N} (|{(c + x) mod N}_{x in {a .. b}}| = N) if N in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. N -> {forall_{a, b, c in Integer | |{a .. b}| >= N} (|{(c + x) mod N}_{x in {a .. b}}| = N) if N in NaturalPos.
#    core type: Lambda
#    parameter: 48
#    body: 4
# 3. (N)
#    core type: ExprTuple
#    sub-expressions: 48
# 4. {forall_{a, b, c in Integer | |{a .. b}| >= N} (|{(c + x) mod N}_{x in {a .. b}}| = N) if N in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a, b, c in Integer | |{a .. b}| >= N} (|{(c + x) mod N}_{x in {a .. b}}| = N)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. N in NaturalPos
#    core type: Operation
#    operator: 45
#    operands: 9
# 7. forall
# ...
