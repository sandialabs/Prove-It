# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#image_size_indep_of_right_shift">image_size_indep_of_right_shift</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.modular import image_size_indep_of_right_shift

# %%
# check that the built expression is the same as the stored expression
assert image_size_indep_of_right_shift.expr == stored_expr
assert image_size_indep_of_right_shift.expr._style_id == stored_expr._style_id
print("Passed sanity check: image_size_indep_of_right_shift matches stored_expr")
# Out:
# Passed sanity check: image_size_indep_of_right_shift matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{L \in \mathbb{R}}~\left[\forall_{S~|~S \subseteq \mathbb{R}}~\left[\forall_{c \in \mathbb{R}}~\left(|\left\{\left(x + c\right) ~\textup{mod}~ L\right\}_{x \in S}| = |\left\{x ~\textup{mod}~ L\right\}_{x \in S}|\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{L in Real} [forall_{S | S subset_eq Real} [forall_{c in Real} (|{(x + c) mod L}_{x in S}| = |{x mod L}_{x in S}|)]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (L -> {forall_{S | S subset_eq Real} [forall_{c in Real} (|{(x + c) mod L}_{x in S}| = |{x mod L}_{x in S}|)] if L in Real.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. L -> {forall_{S | S subset_eq Real} [forall_{c in Real} (|{(x + c) mod L}_{x in S}| = |{x mod L}_{x in S}|)] if L in Real.
#    core type: Lambda
#    parameter: 51
#    body: 4
# 3. (L)
#    core type: ExprTuple
#    sub-expressions: 51
# 4. {forall_{S | S subset_eq Real} [forall_{c in Real} (|{(x + c) mod L}_{x in S}| = |{x mod L}_{x in S}|)] if L in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{S | S subset_eq Real} [forall_{c in Real} (|{(x + c) mod L}_{x in S}| = |{x mod L}_{x in S}|)]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. L in Real
# ...
