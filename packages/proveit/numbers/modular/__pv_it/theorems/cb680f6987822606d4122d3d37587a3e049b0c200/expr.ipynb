# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, N, a, b, c, x
from proveit.logic import Card, Equals, Forall, InSet, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, NaturalPos, greater_eq, one, subtract, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(a, b)
expr = Conditional(Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(SetOfAll(instance_param_or_params = [x], instance_element = Mod(Add(c, x), N), domain = sub_expr1), Interval(zero, subtract(N, one))), domain = Integer, condition = greater_eq(Card(sub_expr1), N)), InSet(N, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a, b, c \in \mathbb{Z}~|~|\{a~\ldotp \ldotp~b\}| \geq N}~\left(\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a~\ldotp \ldotp~b\}} = \{0~\ldotp \ldotp~N - 1\}\right) \textrm{ if } N \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. N in NaturalPos
#    core type: Operation
#    operator: 45
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (N, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 50, 7
# 6. (a, b, c) -> {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 59, 60, 57
# 9. {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. {(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a in Integer) and (b in Integer) and (c in Integer) and (|{a .. b}| >= N)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. ({(c + x) mod N}_{x in {a .. b}}, {0 .. N - 1})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a in Integer, b in Integer, c in Integer, |{a .. b}| >= N)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20, 21
# 16. {(c + x) mod N}_{x in {a .. b}}
#     core type: Operation
#     operator: 22
#     operand: 30
# 17. {0 .. N - 1}
#     core type: Operation
#     operator: 55
#     operands: 24
# 18. a in Integer
#     core type: Operation
#     operator: 45
#     operands: 25
# 19. b in Integer
#     core type: Operation
#     operator: 45
#     operands: 26
# 20. c in Integer
#     core type: Operation
#     operator: 45
#     operands: 27
# 21. |{a .. b}| >= N
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. SetOfAll
#     core type: Literal
#     sub-expressions:
# 23. (x -> {(c + x) mod N if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 30
# 24. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 25. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 59, 33
# 26. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 33
# 27. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 57, 33
# 28. <=
#     core type: Literal
#     sub-expressions:
# 29. (N, |{a .. b}|)
#     core type: ExprTuple
#     sub-expressions: 50, 34
# 30. x -> {(c + x) mod N if x in {a .. b}.
#     core type: Lambda
#     parameter: 58
#     body: 36
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. N - 1
#     core type: Operation
#     operator: 53
#     operands: 37
# 33. Integer
#     core type: Literal
#     sub-expressions:
# 34. |{a .. b}|
#     core type: Operation
#     operator: 38
#     operand: 51
# 35. (x)
#     core type: ExprTuple
#     sub-expressions: 58
# 36. {(c + x) mod N if x in {a .. b}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 37. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 50, 42
# 38. card
#     core type: Literal
#     sub-expressions:
# 39. ({a .. b})
#     core type: ExprTuple
#     sub-expressions: 51
# 40. (c + x) mod N
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. x in {a .. b}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. -1
#     core type: Operation
#     operator: 47
#     operand: 52
# 43. mod
#     core type: Literal
#     sub-expressions:
# 44. (c + x, N)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (1)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. c + x
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. N
#     core type: Variable
#     sub-expressions:
# 51. {a .. b}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (c, x)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (a, b)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. b
#     core type: Variable
#     sub-expressions:
