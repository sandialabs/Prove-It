# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, L, Lambda, Variable, a, b, c, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Mod, Real, RealPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_i, b, c_1_to_j], Conditional(Forall(instance_param_or_params = [L], instance_expr = Equals(Mod(Add(a_1_to_i, Mod(b, L), c_1_to_j), L), Mod(Add(a_1_to_i, b, c_1_to_j), L)).with_wrapping_at(2), domain = RealPos), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Real), one, i), InSet(b, Real), ExprRange(sub_expr1, InSet(IndexedVar(c, sub_expr1), Real), one, j)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j}\right) \mapsto \left\{\forall_{L \in \mathbb{R}^+}~\left(\begin{array}{c} \begin{array}{l} \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + \left(b ~\textup{mod}~ L\right)+ c_{1} +  c_{2} +  \ldots +  c_{j}\right) ~\textup{mod}~ L\right) =  \\ \left(\left(a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right) ~\textup{mod}~ L\right) \end{array} \end{array}\right) \textrm{ if } \left(a_{1} \in \mathbb{R}\right) ,  \left(a_{2} \in \mathbb{R}\right) ,  \ldots ,  \left(a_{i} \in \mathbb{R}\right) ,  b \in \mathbb{R}, \left(c_{1} \in \mathbb{R}\right) ,  \left(c_{2} \in \mathbb{R}\right) ,  \ldots ,  \left(c_{j} \in \mathbb{R}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L)) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L)) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#    core type: Lambda
#    parameters: 38\n   body: 2
# 2. {forall_{L in RealPos} (((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L)) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{L in RealPos} (((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (a_{1} in Real) and  (a_{2} in Real) and  ... and  (a_{i} in Real) and (b in Real)and (c_{1} in Real) and  (c_{2} in Real) and  ... and  (c_{j} in Real)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (L -> {((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) if L in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real), b in Real,(c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. L -> {((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) if L in RealPos.
#    core type: Lambda
#    parameter: 50
#    body: 14
# 10. (a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 47
#     end_index: 45
# 11. b in Real
#     core type: Operation
#     operator: 26
#     operands: 16
# 12. (c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 47
#     end_index: 48
# 13. (L)
#     core type: ExprTuple
#     sub-expressions: 50
# 14. {((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) if L in RealPos.
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. _a -> (a_{_a} in Real)
#     core type: Lambda
#     parameter: 56
#     body: 20
# 16. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 49, 31
# 17. _a -> (c_{_a} in Real)
#     core type: Lambda
#     parameter: 56
#     body: 21
# 18. ((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L) =  \\ ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. L in RealPos
#     core type: Operation
#     operator: 26
#     operands: 24
# 20. a_{_a} in Real
#     core type: Operation
#     operator: 26
#     operands: 25
# 21. c_{_a} in Real
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. ((a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L, (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. (L, RealPos)
#     core type: ExprTuple
#     sub-expressions: 50, 30
# 25. (a_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 51, 31
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (c_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 52, 31
# 28. (a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}) mod L
#     core type: Operation
#     operator: 42
#     operands: 32
# 29. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) mod L
#     core type: Operation
#     operator: 42
#     operands: 33
# 30. RealPos
#     core type: Literal
#     sub-expressions:
# 31. Real
#     core type: Literal
#     sub-expressions:
# 32. (a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 34, 50
# 33. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 35, 50
# 34. a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 37
#     operands: 36
# 35. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. (a_{1}, a_{2}, ..., a_{i}, b mod L,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 40, 39, 41
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 40, 49, 41
# 39. b mod L
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 41. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 42. mod
#     core type: Literal
#     sub-expressions:
# 43. (b, L)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 51
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. L
#     core type: Variable
#     sub-expressions:
# 51. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 52. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
