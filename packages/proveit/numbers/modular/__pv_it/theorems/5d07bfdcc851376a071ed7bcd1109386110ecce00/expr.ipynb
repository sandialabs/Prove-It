# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, N, a, b, c, x
from proveit.logic import Card, Equals, Forall, InSet, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, NaturalPos, greater_eq, one, subtract, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(a, b)
expr = ExprTuple(Lambda(N, Conditional(Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(SetOfAll(instance_param_or_params = [x], instance_element = Mod(Add(c, x), N), domain = sub_expr1), Interval(zero, subtract(N, one))), domain = Integer, condition = greater_eq(Card(sub_expr1), N)), InSet(N, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(N \mapsto \left\{\forall_{a, b, c \in \mathbb{Z}~|~|\{a~\ldotp \ldotp~b\}| \geq N}~\left(\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a~\ldotp \ldotp~b\}} = \{0~\ldotp \ldotp~N - 1\}\right) \textrm{ if } N \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (N -> {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. N -> {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.
#    core type: Lambda
#    parameter: 53
#    body: 3
# 2. (N)
#    core type: ExprTuple
#    sub-expressions: 53
# 3. {forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}) if N in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a, b, c in Integer | |{a .. b}| >= N} ({(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. N in NaturalPos
#    core type: Operation
#    operator: 48
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a, b, c) -> {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (N, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 53, 10
# 9. (a, b, c) -> {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 62, 63, 60
# 12. {{(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. {(c + x) mod N}_{x in {a .. b}} = {0 .. N - 1}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a in Integer) and (b in Integer) and (c in Integer) and (|{a .. b}| >= N)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ({(c + x) mod N}_{x in {a .. b}}, {0 .. N - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a in Integer, b in Integer, c in Integer, |{a .. b}| >= N)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23, 24
# 19. {(c + x) mod N}_{x in {a .. b}}
#     core type: Operation
#     operator: 25
#     operand: 33
# 20. {0 .. N - 1}
#     core type: Operation
#     operator: 58
#     operands: 27
# 21. a in Integer
#     core type: Operation
#     operator: 48
#     operands: 28
# 22. b in Integer
#     core type: Operation
#     operator: 48
#     operands: 29
# 23. c in Integer
#     core type: Operation
#     operator: 48
#     operands: 30
# 24. |{a .. b}| >= N
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. SetOfAll
#     core type: Literal
#     sub-expressions:
# 26. (x -> {(c + x) mod N if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 27. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 36
# 29. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 36
# 30. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 36
# 31. <=
#     core type: Literal
#     sub-expressions:
# 32. (N, |{a .. b}|)
#     core type: ExprTuple
#     sub-expressions: 53, 37
# 33. x -> {(c + x) mod N if x in {a .. b}.
#     core type: Lambda
#     parameter: 61
#     body: 39
# 34. 0
#     core type: Literal
#     sub-expressions:
# 35. N - 1
#     core type: Operation
#     operator: 56
#     operands: 40
# 36. Integer
#     core type: Literal
#     sub-expressions:
# 37. |{a .. b}|
#     core type: Operation
#     operator: 41
#     operand: 54
# 38. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 39. {(c + x) mod N if x in {a .. b}.
#     core type: Conditional
#     value: 43
#     condition: 44
# 40. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 45
# 41. card
#     core type: Literal
#     sub-expressions:
# 42. ({a .. b})
#     core type: ExprTuple
#     sub-expressions: 54
# 43. (c + x) mod N
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. x in {a .. b}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. -1
#     core type: Operation
#     operator: 50
#     operand: 55
# 46. mod
#     core type: Literal
#     sub-expressions:
# 47. (c + x, N)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 61, 54
# 50. -
#     core type: Literal
#     sub-expressions:
# 51. (1)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. c + x
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. N
#     core type: Variable
#     sub-expressions:
# 54. {a .. b}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (c, x)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (a, b)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. b
#     core type: Variable
#     sub-expressions:
