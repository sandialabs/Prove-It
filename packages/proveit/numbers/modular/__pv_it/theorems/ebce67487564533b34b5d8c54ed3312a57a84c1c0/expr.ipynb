# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import N, a, b, c, x
from proveit.logic import Card, Equals, Forall, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, greater_eq, one, subtract, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(a, b)
expr = Forall(instance_param_or_params = [a, b, c], instance_expr = Equals(SetOfAll(instance_param_or_params = [x], instance_element = Mod(Add(x, c), N), domain = sub_expr1), Interval(zero, subtract(N, one))), domain = Integer, condition = greater_eq(Card(sub_expr1), N))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}~|~|\{a~\ldotp \ldotp~b\}| \geq N}~\left(\left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a~\ldotp \ldotp~b\}} = \{0~\ldotp \ldotp~N - 1\}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer | |{a .. b}| >= N} ({(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 55, 56, 54
# 5. {{(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1} if a in Integer ,  b in Integer ,  c in Integer ,  |{a .. b}| >= N.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. {(x + c) mod N}_{x in {a .. b}} = {0 .. N - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (c in Integer) and (|{a .. b}| >= N)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ({(x + c) mod N}_{x in {a .. b}}, {0 .. N - 1})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in Integer, b in Integer, c in Integer, |{a .. b}| >= N)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. {(x + c) mod N}_{x in {a .. b}}
#     core type: Operation
#     operator: 18
#     operand: 26
# 13. {0 .. N - 1}
#     core type: Operation
#     operator: 51
#     operands: 20
# 14. a in Integer
#     core type: Operation
#     operator: 41
#     operands: 21
# 15. b in Integer
#     core type: Operation
#     operator: 41
#     operands: 22
# 16. c in Integer
#     core type: Operation
#     operator: 41
#     operands: 23
# 17. |{a .. b}| >= N
#     core type: Operation
#     operator: 24
#     operands: 25
# 18. SetOfAll
#     core type: Literal
#     sub-expressions:
# 19. (x -> {(x + c) mod N if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 20. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 21. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 29
# 22. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 56, 29
# 23. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 54, 29
# 24. <=
#     core type: Literal
#     sub-expressions:
# 25. (N, |{a .. b}|)
#     core type: ExprTuple
#     sub-expressions: 46, 30
# 26. x -> {(x + c) mod N if x in {a .. b}.
#     core type: Lambda
#     parameter: 53
#     body: 32
# 27. 0
#     core type: Literal
#     sub-expressions:
# 28. N - 1
#     core type: Operation
#     operator: 49
#     operands: 33
# 29. Integer
#     core type: Literal
#     sub-expressions:
# 30. |{a .. b}|
#     core type: Operation
#     operator: 34
#     operand: 47
# 31. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 32. {(x + c) mod N if x in {a .. b}.
#     core type: Conditional
#     value: 36
#     condition: 37
# 33. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 46, 38
# 34. card
#     core type: Literal
#     sub-expressions:
# 35. ({a .. b})
#     core type: ExprTuple
#     sub-expressions: 47
# 36. (x + c) mod N
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. x in {a .. b}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. -1
#     core type: Operation
#     operator: 43
#     operand: 48
# 39. mod
#     core type: Literal
#     sub-expressions:
# 40. (x + c, N)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 53, 47
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. x + c
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. N
#     core type: Variable
#     sub-expressions:
# 47. {a .. b}
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (x, c)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (a, b)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. b
#     core type: Variable
#     sub-expressions:
