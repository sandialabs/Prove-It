# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.SetOfAll.html">SetOfAll</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import N, a, b, c, x
from proveit.logic import SetOfAll
from proveit.numbers import Add, Interval, Mod

# %%
# build up the expression from sub-expressions
expr = SetOfAll([x], Mod(Add(x, c), N), domains = [Interval(a, b)])
# Out:
# expr: {(x + c) mod  N}_{x in {a...b}}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x + c) mod  N}_{x in {a...b}}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. SetOfAll
#    core type: Literal
#    sub-expressions:
# 2. x -> {(x + c) mod  N if x in {a...b}.
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. {(x + c) mod  N if x in {a...b}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x + c) mod  N
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in {a...b}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. mod
#    core type: Literal
#    sub-expressions:
# 7. (x + c, N)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, {a...b})
#    core type: ExprTuple
#    sub-expressions: 17, 12
# 10. x + c
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. N
#     core type: Variable
#     sub-expressions:
# 12. {a...b}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (x, c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (a, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
