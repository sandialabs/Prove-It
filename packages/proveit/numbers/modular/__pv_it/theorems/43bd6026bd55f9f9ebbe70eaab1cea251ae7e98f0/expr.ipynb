# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, L, Lambda, b, i, j
from proveit.core_expr_types import a_1_to_i, c_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Mod, ModAbs, Natural, Real, RealPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([i, j], Conditional(Forall(instance_param_or_params = [a_1_to_i, b, c_1_to_j], instance_expr = Forall(instance_param_or_params = [L], instance_expr = Equals(ModAbs(Add(a_1_to_i, Mod(b, L), c_1_to_j), L), ModAbs(Add(a_1_to_i, b, c_1_to_j), L)).with_wrapping_at(2), domain = RealPos), domain = Real), And(InSet(i, Natural), InSet(j, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(i, j\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{j} \in \mathbb{R}}~\left[\forall_{L \in \mathbb{R}^+}~\left(\begin{array}{c} \begin{array}{l} \left|a_{1} +  a_{2} +  \ldots +  a_{i} + \left(b ~\textup{mod}~ L\right)+ c_{1} +  c_{2} +  \ldots +  c_{j}\right|_{\textup{mod}\thinspace L} =  \\ \left|a_{1} +  a_{2} +  \ldots +  a_{i} + b+ c_{1} +  c_{2} +  \ldots +  c_{j}\right|_{\textup{mod}\thinspace L} \end{array} \end{array}\right)\right] \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Real} [forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})] if i in Natural ,  j in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (i, j) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Real} [forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})] if i in Natural ,  j in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 58, 61
# 3. {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Real} [forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})] if i in Natural ,  j in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Real} [forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})]
#    core type: Operation
#    operator: 17
#    operand: 8
# 5. (i in Natural) and (j in Natural)
#    core type: Operation
#    operator: 19
#    operands: 7
# 6. ((a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i in Natural, j in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}) -> {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#    core type: Lambda
#    parameters: 51\n   body: 11
# 9. i in Natural
#    core type: Operation
#    operator: 38
#    operands: 12
# 10. j in Natural
#     core type: Operation
#     operator: 38
#     operands: 13
# 11. {forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}) if (a_{1} in Real) ,  (a_{2} in Real) ,  ... ,  (a_{i} in Real) ,  b in Real, (c_{1} in Real) ,  (c_{2} in Real) ,  ... ,  (c_{j} in Real).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 58, 16
# 13. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 61, 16
# 14. forall_{L in RealPos} (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (a_{1} in Real) and  (a_{2} in Real) and  ... and  (a_{i} in Real) and (b in Real)and (c_{1} in Real) and  (c_{2} in Real) and  ... and  (c_{j} in Real)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (L -> {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real), b in Real,(c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real))
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 21. L -> {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.
#     core type: Lambda
#     parameter: 63
#     body: 26
# 22. (a_{1} in Real), (a_{2} in Real), ..., (a_{i} in Real)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 60
#     end_index: 58
# 23. b in Real
#     core type: Operation
#     operator: 38
#     operands: 28
# 24. (c_{1} in Real), (c_{2} in Real), ..., (c_{j} in Real)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 60
#     end_index: 61
# 25. (L)
#     core type: ExprTuple
#     sub-expressions: 63
# 26. {|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} if L in RealPos.
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. _a -> (a_{_a} in Real)
#     core type: Lambda
#     parameter: 69
#     body: 32
# 28. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 62, 43
# 29. _a -> (c_{_a} in Real)
#     core type: Lambda
#     parameter: 69
#     body: 33
# 30. |a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L} =  \\ |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. L in RealPos
#     core type: Operation
#     operator: 38
#     operands: 36
# 32. a_{_a} in Real
#     core type: Operation
#     operator: 38
#     operands: 37
# 33. c_{_a} in Real
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (|a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}, |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. (L, RealPos)
#     core type: ExprTuple
#     sub-expressions: 63, 42
# 37. (a_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 64, 43
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (c_{_a}, Real)
#     core type: ExprTuple
#     sub-expressions: 65, 43
# 40. |a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 45
#     operands: 44
# 41. |a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}|_{mod L}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. RealPos
#     core type: Literal
#     sub-expressions:
# 43. Real
#     core type: Literal
#     sub-expressions:
# 44. (a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 47, 63
# 45. ModAbs
#     core type: Literal
#     sub-expressions:
# 46. (a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}, L)
#     core type: ExprTuple
#     sub-expressions: 48, 63
# 47. a_{1} +  a_{2} +  ... +  a_{i} + (b mod L)+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 50
#     operands: 49
# 48. a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. (a_{1}, a_{2}, ..., a_{i}, b mod L,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 53, 52, 54
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (a_{1}, a_{2}, ..., a_{i}, b,c_{1}, c_{2}, ..., c_{j})
#     core type: ExprTuple
#     sub-expressions: 53, 62, 54
# 52. b mod L
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 60
#     end_index: 58
# 54. c_{1}, c_{2}, ..., c_{j}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 60
#     end_index: 61
# 55. mod
#     core type: Literal
#     sub-expressions:
# 56. (b, L)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 57. _a -> a_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 64
# 58. i
#     core type: Variable
#     sub-expressions:
# 59. _a -> c_{_a}
#     core type: Lambda
#     parameter: 69
#     body: 65
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. j
#     core type: Variable
#     sub-expressions:
# 62. b
#     core type: Variable
#     sub-expressions:
# 63. L
#     core type: Variable
#     sub-expressions:
# 64. a_{_a}
#     core type: IndexedVar
# variable: 66
# index: 69
# 65. c_{_a}
#     core type: IndexedVar
# variable: 67
# index: 69
# 66. a
#     core type: Variable
#     sub-expressions:
# 67. c
#     core type: Variable
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
