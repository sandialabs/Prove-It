# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#interval_left_shift_bijection">interval_left_shift_bijection</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.modular import interval_left_shift_bijection

# %%
# check that the built expression is the same as the stored expression
assert interval_left_shift_bijection.expr == stored_expr
assert interval_left_shift_bijection.expr._style_id == stored_expr._style_id
print("Passed sanity check: interval_left_shift_bijection matches stored_expr")
# Out:
# Passed sanity check: interval_left_shift_bijection matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{N \in \mathbb{N}^+}~\left[\forall_{a, b, c \in \mathbb{Z}}~\left(\left[x \mapsto \left(\left(c + x\right) ~\textup{mod}~ N\right)\right] \in \left[\{a~\ldotp \ldotp~b\} \xrightarrow[\text{onto}]{\text{1-to-1}} \{0~\ldotp \ldotp~N - 1\}\right]\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{N in NaturalPos} [forall_{a, b, c in Integer} ([x -> ((c + x) mod N)] in Bijections({a .. b}, {0 .. N - 1}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (N -> {forall_{a, b, c in Integer} ([x -> ((c + x) mod N)] in Bijections({a .. b}, {0 .. N - 1})) if N in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. N -> {forall_{a, b, c in Integer} ([x -> ((c + x) mod N)] in Bijections({a .. b}, {0 .. N - 1})) if N in NaturalPos.
#    core type: Lambda
#    parameter: 50
#    body: 4
# 3. (N)
#    core type: ExprTuple
#    sub-expressions: 50
# 4. {forall_{a, b, c in Integer} ([x -> ((c + x) mod N)] in Bijections({a .. b}, {0 .. N - 1})) if N in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a, b, c in Integer} ([x -> ((c + x) mod N)] in Bijections({a .. b}, {0 .. N - 1}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. N in NaturalPos
#    core type: Operation
#    operator: 30
# ...
