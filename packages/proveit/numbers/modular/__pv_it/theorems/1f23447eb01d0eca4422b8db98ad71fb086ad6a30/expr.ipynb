# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import N, a, b, c, x
from proveit.logic import Equals, Forall, NotEquals, SetOfAll
from proveit.numbers import Add, Integer, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(N, Neg(one))
expr = Forall([N, a, b, c], Equals(SetOfAll([x], Mod(Add(c, x), N), domains = [Interval(a, b)]), Interval(zero, sub_expr1)), domains = [Integer, Integer, Integer, Integer], conditions = [Equals(Add(b, Neg(a)), sub_expr1), NotEquals(N, zero)])
# Out:
# expr: forall_{N, a, b, c in Integer | (b - a) = (N - 1), N != 0} ({(c + x) mod  N}_{x in {a...b}} = {0...N - 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{N, a, b, c \in \mathbb{Z}~|~\left(b - a\right) = \left(N - 1\right), N \neq 0}~\left(\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{N, a, b, c in Integer | (b - a) = (N - 1), N != 0} ({(c + x) mod  N}_{x in {a...b}} = {0...N - 1})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (N, a, b, c) -> {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (N, a, b, c)
#    core type: ExprTuple
#    sub-expressions: 45, 55, 56, 53
# 4. {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integer ,  a in Integer ,  b in Integer ,  c in Integer ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {(c + x) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 25
#    operands: 7
# 6. (N in Integer) and (a in Integer) and (b in Integer) and (c in Integer) and ((b - a) = (N - 1)) and (N != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ({(c + x) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (N in Integer, a in Integer, b in Integer, c in Integer, (b - a) = (N - 1), N != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16, 17
# 10. {(c + x) mod  N}_{x in {a...b}}
#     core type: Operation
#     operator: 18
#     operand: 19
# 11. {0...N - 1}
#     core type: Operation
#     operator: 51
#     operands: 20
# 12. N in Integer
#     core type: Operation
#     operator: 40
#     operands: 21
# 13. a in Integer
#     core type: Operation
#     operator: 40
#     operands: 22
# 14. b in Integer
#     core type: Operation
#     operator: 40
#     operands: 23
# 15. c in Integer
#     core type: Operation
#     operator: 40
#     operands: 24
# 16. (b - a) = (N - 1)
#     core type: Operation
#     operator: 25
#     operands: 26
# 17. N != 0
#     core type: Operation
#     operator: 27
#     operands: 28
# 18. SetOfAll
#     core type: Literal
#     sub-expressions:
# 19. x -> {(c + x) mod  N if x in {a...b}.
#     core type: Lambda
#     parameter: 54
#     body: 29
# 20. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 32
# 21. (N, Integer)
#     core type: ExprTuple
#     sub-expressions: 45, 30
# 22. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 55, 30
# 23. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 56, 30
# 24. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 53, 30
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (b - a, N - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. !=
#     core type: Literal
#     sub-expressions:
# 28. (N, 0)
#     core type: ExprTuple
#     sub-expressions: 45, 33
# 29. {(c + x) mod  N if x in {a...b}.
#     core type: Conditional
#     value: 34
#     condition: 35
# 30. Integer
#     core type: Literal
#     sub-expressions:
# 31. b - a
#     core type: Operation
#     operator: 49
#     operands: 36
# 32. N - 1
#     core type: Operation
#     operator: 49
#     operands: 37
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. (c + x) mod  N
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. x in {a...b}
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. (b, -a)
#     core type: ExprTuple
#     sub-expressions: 56, 42
# 37. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 45, 43
# 38. mod
#     core type: Literal
#     sub-expressions:
# 39. (c + x, N)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (x, {a...b})
#     core type: ExprTuple
#     sub-expressions: 54, 46
# 42. -a
#     core type: Operation
#     operator: 47
#     operand: 55
# 43. -1
#     core type: Operation
#     operator: 47
#     operand: 48
# 44. c + x
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. N
#     core type: Variable
#     sub-expressions:
# 46. {a...b}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (c, x)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (a, b)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. c
#     core type: Variable
#     sub-expressions:
# 54. x
#     core type: Variable
#     sub-expressions:
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. b
#     core type: Variable
#     sub-expressions:
