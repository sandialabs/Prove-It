# %%
import proveit
from proveit import defaults, free_vars
from proveit.numbers.differentiation import (Differentiate, Differentiables, diff_add, diff_exponent, diff_prod, diff_x, diff_const)
from proveit.numbers import Complex, zero, one, two, three, Add, Mult, Integer, Rational, Exp, subtract, Real, Natural, sqrt, Neg, frac, RealPos, readily_provable_number_set
from proveit import c, Lambda, x,y, f,g, n, Composition, fx, gx , Function, U, m, z, k
from proveit.logic.sets import InSet
from proveit.logic import Equals
from proveit.physics.quantum import ket0, ket1

# %%
# %begin demonstrations

# %%
# defaults.assumptions = [InSet(x, Real),InSet(y, Real), InSet(Lambda(x,Exp(x, three)), Differentiables(Real)), InSet(Lambda(x,x), Differentiables(Real)), 
#                         InSet(Lambda(x,two), Differentiables(Real)), InSet(Lambda(x,one), Differentiables(Real)),
#                         InSet(Lambda(x,Exp(x, two)), Differentiables(Real)),InSet(Lambda(x,Add(x, two)), Differentiables(Real)),
#                         InSet(z,Real),InSet(k,Real),InSet(Lambda(x,Mult(x,ket0)),Differentiables(Real)),InSet(Lambda(x,Mult(Exp(x,two),ket1)),Differentiables(Real)),
#                          InSet(Lambda(x,ket0),Differentiables(Real)),InSet(Lambda(x,ket1),Differentiables(Real)),
#                          InSet(Lambda(x,Exp(x,frac(one,two))),Differentiables(Real)),
#                          InSet(Lambda(x,Add(one, Neg(Exp(Mult(Mult(two, k),x),Neg(two))))),Differentiables(Real)),
#                          InSet(Lambda(x, Add(one, x)), Differentiables(Real)),InSet(Lambda(x, Add(one, Exp(x,two))), Differentiables(Real)), 
#                          InSet(Lambda(x,Add(one, Exp(Mult(two,x), two))),Differentiables(Real)),
#                           InSet(Lambda(x, Exp(Mult(two,x),two)),Differentiables(Real)), InSet(Lambda(x, Mult(two, x)), Differentiables(Real)),
#                         InSet(Lambda(x, Neg(Exp(Mult(Mult(two, k),x),Neg(two)))), Differentiables(Real)), InSet(k,Real)]

# %%
defaults.assumptions = [InSet(y, RealPos), InSet(k, RealPos)]

# %%
readily_provable_number_set(y)

# %%
ex1 = Function(Differentiate(Lambda(x,Exp(Add(one, Neg(Exp(Mult(Mult(two, k),x), Neg(two)))),frac(one,two)))),y).simplification()

# %%
ex1 = Function(Differentiate(Lambda(x,Exp(Add(one, Neg(Exp(Mult(Mult(two, k),x), Neg(three)))),frac(one,two)))),y).simplification()

# %%
Function(Differentiate(Lambda(x,Add(x,two))),y).simplification()

# %%
Function(Differentiate(Lambda(x,z)),y).simplification()

# %%
Function(Differentiate(Lambda(x,Mult(two,x))),y).simplification()

# %% [markdown]
# quantum states

# %%
# Function(Differentiate(Lambda(x,Add(Mult(x, ket0),Mult(Exp(x,two),ket1)))),y).simplification()

# %%
ex2 = ex1.shallow_simplification()

# %% [markdown]
# # Exponent rule

# %%
diff_exponent

# %%
Function(Differentiate(Lambda(x,Exp(x,three))),y).simplification()

# %%
Function(Differentiate(Lambda(x,Exp(x,frac(one,two)))),y).simplification()

# %%
Function(Differentiate(Lambda(x,Exp(x,Neg(one)))),y).simplification()

# %% [markdown]
# # Addition rule

# %%
diff_add

# %%
Function(Differentiate(Lambda(x,Add(Exp(x,three),Exp(x,two)))),y).simplification()

# %% [markdown]
# # Product rule

# %%
diff_prod

# %%
Function(Differentiate(Lambda(x,Mult(Exp(x,three),Add(x,two)))),y).simplification()

# %%
Function(Differentiate(Lambda(x,x)),y)

# %% [markdown]
# # Chain rule

# %%
defaults.assumptions += [InSet(Lambda(x, Add(one, x)), Differentiables(Real)),
                         InSet(Lambda(x, Add(one, Exp(x,two))), Differentiables(Real)), InSet(Lambda(x,Add(one, Exp(Mult(two,x), two))),Differentiables(Real)),
                          InSet(Lambda(x, Exp(Mult(two,x),two)),Differentiables(Real)), InSet(Lambda(x, Mult(two, x)), Differentiables(Real)) ]

### InSet(Lambda(x, one), Differentiables(Real)),

# %%
Function(Differentiate(Composition(Lambda(x, Exp(x, two)), Lambda(x, Add(one, x)))) , y).simplification()

# %%
Function(Differentiate(Lambda(x, Exp(Add(one,x), two))),y).simplification()

# Differentiate(Lambda(x, Exp(Add(one,x), two))).application_simplification([y])

# %%
Function(Differentiate(Lambda(x, Exp(Add(one,Exp(Mult(two,x),two)), two))),y).simplification()

# %% [markdown]
# why does it not substitute y
