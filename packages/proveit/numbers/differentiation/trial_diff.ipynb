# %%
import proveit
from proveit import defaults
from proveit.numbers.differentiation import (Differentiate, Differentiables, diff_add, diff_exponent, diff_prod, diff_x, diff_const)
from proveit.numbers import Complex, zero, one, two, three, Add, Mult, Integer, Rational, Exp, subtract, Real, Natural, sqrt, Neg
from proveit import c, Lambda, x,y, f,g, n, Composition, fx, gx , Function, U, m, z
from proveit.logic.sets import InSet
from proveit.logic import Equals

# %%
# %begin demonstrations
