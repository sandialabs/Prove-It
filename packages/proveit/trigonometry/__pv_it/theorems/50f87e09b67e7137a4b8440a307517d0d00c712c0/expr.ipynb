# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, r
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Abs, Exp, Mult, Real, RealNonNeg, e, frac, i, subtract, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda(r, Conditional(Forall(instance_param_or_params = [a, b], instance_expr = Equals(Abs(subtract(Mult(r, Exp(e, Mult(i, a))), Mult(r, Exp(e, Mult(i, b))))), Mult(two, r, Sin(frac(Abs(subtract(a, b)), two)))), domain = Real), InSet(r, RealNonNeg)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# r \mapsto \left\{\forall_{a, b \in \mathbb{R}}~\left(\left|\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right) - \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right| = \left(2 \cdot r \cdot \sin{\frac{\left|a - b\right|}{2}}\right)\right) \textrm{ if } r \in \mathbb{R}^{\ge 0}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. r -> {forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))) if r in RealNonNeg.
#    core type: Lambda
#    parameter: 49
#    body: 2
# 1. (r)
#    core type: ExprTuple
#    sub-expressions: 49
# 2. {forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))) if r in RealNonNeg.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. r in RealNonNeg
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (r, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 49, 9
# 8. (a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. RealNonNeg
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 59, 66
# 11. {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. |(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a in Real) and (b in Real)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (|(r * e^{i * a}) - (r * e^{i * b})|, 2 * r * sin(|a - b| / 2))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a in Real, b in Real)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. |(r * e^{i * a}) - (r * e^{i * b})|
#     core type: Operation
#     operator: 46
#     operand: 27
# 19. 2 * r * sin(|a - b| / 2)
#     core type: Operation
#     operator: 61
#     operands: 23
# 20. a in Real
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. b in Real
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. ((r * e^{i * a}) - (r * e^{i * b}))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (2, r, sin(|a - b| / 2))
#     core type: ExprTuple
#     sub-expressions: 43, 49, 28
# 24. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 59, 29
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 66, 29
# 27. (r * e^{i * a}) - (r * e^{i * b})
#     core type: Operation
#     operator: 55
#     operands: 30
# 28. sin(|a - b| / 2)
#     core type: Operation
#     operator: 31
#     operand: 35
# 29. Real
#     core type: Literal
#     sub-expressions:
# 30. (r * e^{i * a}, -(r * e^{i * b}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. sin
#     core type: Literal
#     sub-expressions:
# 32. (|a - b| / 2)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. r * e^{i * a}
#     core type: Operation
#     operator: 61
#     operands: 36
# 34. -(r * e^{i * b})
#     core type: Operation
#     operator: 63
#     operand: 41
# 35. |a - b| / 2
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. (r, e^{i * a})
#     core type: ExprTuple
#     sub-expressions: 49, 40
# 37. (r * e^{i * b})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. /
#     core type: Literal
#     sub-expressions:
# 39. (|a - b|, 2)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. e^{i * a}
#     core type: Operation
#     operator: 53
#     operands: 44
# 41. r * e^{i * b}
#     core type: Operation
#     operator: 61
#     operands: 45
# 42. |a - b|
#     core type: Operation
#     operator: 46
#     operand: 51
# 43. 2
#     core type: Literal
#     sub-expressions:
# 44. (e, i * a)
#     core type: ExprTuple
#     sub-expressions: 57, 48
# 45. (r, e^{i * b})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. Abs
#     core type: Literal
#     sub-expressions:
# 47. (a - b)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. i * a
#     core type: Operation
#     operator: 61
#     operands: 52
# 49. r
#     core type: Variable
#     sub-expressions:
# 50. e^{i * b}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. a - b
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. (i, a)
#     core type: ExprTuple
#     sub-expressions: 65, 59
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (e, i * b)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (a, -b)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. e
#     core type: Literal
#     sub-expressions:
# 58. i * b
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. -b
#     core type: Operation
#     operator: 63
#     operand: 66
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (i, b)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. (b)
#     core type: ExprTuple
#     sub-expressions: 66
# 65. i
#     core type: Literal
#     sub-expressions:
# 66. b
#     core type: Variable
#     sub-expressions:
