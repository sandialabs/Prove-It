# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">trigonometry</a>.<a class="ProveItLink" href="../../theorems.ipynb#complex_polar_negation">complex_polar_negation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving complex_polar_negation
