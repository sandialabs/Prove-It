# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, f, g, i
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i], instance_expr = Forall(instance_param_or_params = [f, g, Q], instance_expr = Implies(Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i \in \mathbb{N}^+}~\left[\forall_{f, g, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, a_{2}, \ldots, a_{i}~|~Q\left(a_{1}, a_{2}, \ldots, a_{i}\right)}~\left(f\left(a_{1}, a_{2}, \ldots, a_{i}\right) = g\left(a_{1}, a_{2}, \ldots, a_{i}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, b_{2}, \ldots, b_{i}\right) \mapsto \left\{f\left(b_{1}, b_{2}, \ldots, b_{i}\right) \textrm{ if } Q\left(b_{1}, b_{2}, \ldots, b_{i}\right)\right..\right] =  \\ \left[\left(c_{1}, c_{2}, \ldots, c_{i}\right) \mapsto \left\{g\left(c_{1}, c_{2}, \ldots, c_{i}\right) \textrm{ if } Q\left(c_{1}, c_{2}, \ldots, c_{i}\right)\right..\right] \end{array} \end{array}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))]
#    core type: Operation
#    operator: 18
#    operand: 2
# 1. (i -> {forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])) if i in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])) if i in NaturalPos.
#    core type: Lambda
#    parameter: 52
#    body: 4
# 3. (i)
#    core type: ExprTuple
#    sub-expressions: 52
# 4. {forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])) if i in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))
#    core type: Operation
#    operator: 18
#    operand: 10
# 6. i in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((f, g, Q) -> ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 52, 11
# 10. (f, g, Q) -> ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (f, g, Q)
#     core type: ExprTuple
#     sub-expressions: 42, 43, 36
# 13. [forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i})), [(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))
#     core type: Operation
#     operator: 18
#     operand: 21
# 17. [(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]
#     core type: Operation
#     operator: 33
#     operands: 20
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{i}) -> {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ((b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i})., (c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. (a_{1}, a_{2}, ..., a_{i}) -> {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).
#     core type: Lambda
#     parameters: 44\n    body: 24
# 22. (b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).
#     core type: Lambda
#     parameters: 35\n    body: 25
# 23. (c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).
#     core type: Lambda
#     parameters: 37\n    body: 26
# 24. {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 27. f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. Q(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 36
#     operands: 44
# 29. f(b_{1}, b_{2}, ..., b_{i})
#     core type: Operation
#     operator: 42
#     operands: 35
# 30. Q(b_{1}, b_{2}, ..., b_{i})
#     core type: Operation
#     operator: 36
#     operands: 35
# 31. g(c_{1}, c_{2}, ..., c_{i})
#     core type: Operation
#     operator: 43
#     operands: 37
# 32. Q(c_{1}, c_{2}, ..., c_{i})
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (f(a_{1}, a_{2}, ..., a_{i}), g(a_{1}, a_{2}, ..., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. (b_{1}, b_{2}, ..., b_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. (c_{1}, c_{2}, ..., c_{i})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. f(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 42
#     operands: 44
# 39. g(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. b_{1}, b_{2}, ..., b_{i}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 51
#     end_index: 52
# 41. c_{1}, c_{2}, ..., c_{i}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 51
#     end_index: 52
# 42. f
#     core type: Variable
#     sub-expressions:
# 43. g
#     core type: Variable
#     sub-expressions:
# 44. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. _a -> b_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 48
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 49
# 47. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 48. b_{_a}
#     core type: IndexedVar
# variable: 53
# index: 58
# 49. c_{_a}
#     core type: IndexedVar
# variable: 54
# index: 58
# 50. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 55
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. b
#     core type: Variable
#     sub-expressions:
# 54. c
#     core type: Variable
#     sub-expressions:
# 55. a_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
