# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, f, g, i
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Forall(instance_param_or_params = [f, g, Q], instance_expr = Implies(Forall(instance_param_or_params = [a_1_to_i], instance_expr = Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)), InSet(i, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# i \mapsto \left\{\forall_{f, g, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{a_{1}, a_{2}, \ldots, a_{i}~|~Q\left(a_{1}, a_{2}, \ldots, a_{i}\right)}~\left(f\left(a_{1}, a_{2}, \ldots, a_{i}\right) = g\left(a_{1}, a_{2}, \ldots, a_{i}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\left(b_{1}, b_{2}, \ldots, b_{i}\right) \mapsto \left\{f\left(b_{1}, b_{2}, \ldots, b_{i}\right) \textrm{ if } Q\left(b_{1}, b_{2}, \ldots, b_{i}\right)\right..\right] =  \\ \left[\left(c_{1}, c_{2}, \ldots, c_{i}\right) \mapsto \left\{g\left(c_{1}, c_{2}, \ldots, c_{i}\right) \textrm{ if } Q\left(c_{1}, c_{2}, \ldots, c_{i}\right)\right..\right] \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. i -> {forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])) if i in NaturalPos.
#    core type: Lambda
#    parameter: 50
#    body: 2
# 1. (i)
#    core type: ExprTuple
#    sub-expressions: 50
# 2. {forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])) if i in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))
#    core type: Operation
#    operator: 16
#    operand: 8
# 4. i in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f, g, Q) -> ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 50, 9
# 8. (f, g, Q) -> ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (f, g, Q)
#     core type: ExprTuple
#     sub-expressions: 40, 41, 34
# 11. [forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i})), [(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).])
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. [(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]
#     core type: Operation
#     operator: 31
#     operands: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((a_{1}, a_{2}, ..., a_{i}) -> {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. ((b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i})., (c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. (a_{1}, a_{2}, ..., a_{i}) -> {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).
#     core type: Lambda
#     parameters: 42\n    body: 22
# 20. (b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).
#     core type: Lambda
#     parameters: 33\n    body: 23
# 21. (c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).
#     core type: Lambda
#     parameters: 35\n    body: 24
# 22. {f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}) if Q(a_{1}, a_{2}, ..., a_{i}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 24. {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. Q(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 34
#     operands: 42
# 27. f(b_{1}, b_{2}, ..., b_{i})
#     core type: Operation
#     operator: 40
#     operands: 33
# 28. Q(b_{1}, b_{2}, ..., b_{i})
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. g(c_{1}, c_{2}, ..., c_{i})
#     core type: Operation
#     operator: 41
#     operands: 35
# 30. Q(c_{1}, c_{2}, ..., c_{i})
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (f(a_{1}, a_{2}, ..., a_{i}), g(a_{1}, a_{2}, ..., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. (b_{1}, b_{2}, ..., b_{i})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. Q
#     core type: Variable
#     sub-expressions:
# 35. (c_{1}, c_{2}, ..., c_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. f(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 40
#     operands: 42
# 37. g(a_{1}, a_{2}, ..., a_{i})
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. b_{1}, b_{2}, ..., b_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 49
#     end_index: 50
# 39. c_{1}, c_{2}, ..., c_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 49
#     end_index: 50
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. g
#     core type: Variable
#     sub-expressions:
# 42. (a_{1}, a_{2}, ..., a_{i})
#     core type: ExprTuple
#     sub-expressions: 45
# 43. _a -> b_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 46
# 44. _a -> c_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 47
# 45. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 46. b_{_a}
#     core type: IndexedVar
# variable: 51
# index: 56
# 47. c_{_a}
#     core type: IndexedVar
# variable: 52
# index: 56
# 48. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 53
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. c
#     core type: Variable
#     sub-expressions:
# 53. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
