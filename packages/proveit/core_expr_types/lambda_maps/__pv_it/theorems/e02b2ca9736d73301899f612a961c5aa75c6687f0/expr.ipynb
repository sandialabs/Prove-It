# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, f, g, i
from proveit.core_expr_types import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Forall([f, g, Q], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda([b_1_to_i], Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda([c_1_to_i], Conditional(g__c_1_to_i, Q__c_1_to_i))).with_wrapping_at(2)).with_wrapping_at(2)), InSet(i, NaturalPos)))
# Out:
# expr: i -> {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\forall_{f, g, Q}~\left(\begin{array}{c} \left[\forall_{a_{1}, \ldots, a_{i}~|~Q(a_{1}, \ldots, a_{i})}~\left(f(a_{1}, \ldots, a_{i}) = g(a_{1}, \ldots, a_{i})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\left(b_{1}, \ldots, b_{i}\right) \mapsto \left\{f(b_{1}, \ldots, b_{i}) \textrm{ if } Q(b_{1}, \ldots, b_{i})\right..\right] =  \\ \left[\left(c_{1}, \ldots, c_{i}\right) \mapsto \left\{g(c_{1}, \ldots, c_{i}) \textrm{ if } Q(c_{1}, \ldots, c_{i})\right..\right] \end{array}\right) \end{array}\right) \textrm{ if } i \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.
#    core type: Lambda
#    parameter: 45
#    body: 1
# 1. {forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])) if i in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. i in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (f, g, Q) -> ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 9
# 7. (f, g, Q)
#    core type: ExprTuple
#    sub-expressions: 35, 36, 33
# 8. [forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})), [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).])
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. [(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]
#     core type: Operation
#     operator: 24
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, ..a_{_a}.., a_{i}) -> {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Lambda
#     parameters: 37\n    body: 17
# 16. ((b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i})., (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}) if Q(a_{1}, ..a_{_a}.., a_{i}).
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. (b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Lambda
#     parameters: 32\n    body: 22
# 19. (c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Lambda
#     parameters: 34\n    body: 23
# 20. f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Q(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 33
#     operands: 37
# 22. {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (f(a_{1}, ..a_{_a}.., a_{i}), g(a_{1}, ..a_{_a}.., a_{i}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. f(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 35
#     operands: 32
# 27. Q(b_{1}, ..b_{_a}.., b_{i})
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. g(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 36
#     operands: 34
# 29. Q(c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. f(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 35
#     operands: 37
# 31. g(a_{1}, ..a_{_a}.., a_{i})
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (b_{1}, ..b_{_a}.., b_{i})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. f
#     core type: Variable
#     sub-expressions:
# 36. g
#     core type: Variable
#     sub-expressions:
# 37. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 40
# 38. b_{1}, ..b_{_a}.., b_{i}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 44
#     end_index: 45
# 39. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 44
#     end_index: 45
# 40. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 41. _a -> b_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 46
# 42. _a -> c_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 47
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. b_{_a}
#     core type: IndexedVar
# variable: 49
# index: 52
# 47. c_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 48. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 52
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. _a
#     core type: Variable
#     sub-expressions:
