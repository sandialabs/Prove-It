# %% [markdown]
# Theory of <a class="ProveItLink" href="../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../_theory_.ipynb">core_expr_types</a>.lambda_maps
# ========
#
# Theory related to **Lambda** types of Prove-It expressions.  A **Lambda** has *parameter(s)* and a *body* and represents a mapping of the *parameter(s)* to the *body*.  For example, $(x, y) \mapsto x + y$ represents a mapping of $x$ and $y$ into $x + y$; the application of this mapping to the arguments $5$ and $2$ yields $5+2$.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="_common_.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="_axioms_.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="_theorems_.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="_demonstrations_.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>Axioms contained (directly or indirectly) within this theory</h3>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#lambda_substitution">proveit.core_expr_types.lambda_maps.lambda_substitution</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/58f2a0876d12b8ae7ae1bea4193d2cf4abf24fba0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <h3>Theorems (or conjectures) contained (directly or indirectly) within this theory</h3>
# Also see list of all contained <a href="contain_theorems.ipynb">theorems (or conjectures)</a>.
