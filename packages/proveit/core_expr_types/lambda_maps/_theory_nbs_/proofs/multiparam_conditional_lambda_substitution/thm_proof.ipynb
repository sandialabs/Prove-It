# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../../theory.ipynb">lambda_maps</a>.<a class="ProveItLink" href="../../theorems.ipynb#multiparam_conditional_lambda_substitution">multiparam_conditional_lambda_substitution</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
defaults.assumptions = [] # often useful to set
defaults.auto_simplify = False # can be convenient to enable

# %%
# %proving multiparam_conditional_lambda_substitution
