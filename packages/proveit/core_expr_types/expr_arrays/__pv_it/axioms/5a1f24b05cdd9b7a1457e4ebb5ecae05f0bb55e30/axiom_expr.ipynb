# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#varray_eq_def">varray_eq_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.expr_arrays import varray_eq_def

# %%
# check that the built expression is the same as the stored expression
assert varray_eq_def.expr == stored_expr
assert varray_eq_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: varray_eq_def matches stored_expr")
# Out:
# Passed sanity check: varray_eq_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b, c_{1}, c_{2}, \ldots, c_{i}, d}~\left(\begin{array}{c} \begin{array}{l} \left(\left(\begin{array}{ccccc}
#  \multirow{1}{*}{$\begin{array}{c} \uparrow \\ a_{1} \\ \downarrow \end{array}$} & \multirow{1}{*}{$\begin{array}{c} \uparrow \\ a_{2} \\ \downarrow \end{array}$} & \multirow{1}{*}{$\begin{array}{c} \uparrow \\ \cdots \\ \downarrow \end{array}$} & \multirow{1}{*}{$\begin{array}{c} \uparrow \\ a_{i} \\ \downarrow \end{array}$} & \multirow{1}{*}{$\begin{array}{c} \uparrow \\ b \\ \downarrow \end{array}$} \\
# \end{array}
# \right) = \left(\begin{array}{ccccc}
# ...

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} ((VertExprArray(a_{1},  \\ a_{2}, ..., a_{i}, b) = VertExprArray(c_{1},  \\ c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (i -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} ((VertExprArray(a_{1},  \\ a_{2}, ..., a_{i}, b) = VertExprArray(c_{1},  \\ c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d))) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. i -> {forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} ((VertExprArray(a_{1},  \\ a_{2}, ..., a_{i}, b) = VertExprArray(c_{1},  \\ c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d))) if i in Natural.
#    core type: Lambda
#    parameter: 37
#    body: 4
# 3. (i)
# ...
