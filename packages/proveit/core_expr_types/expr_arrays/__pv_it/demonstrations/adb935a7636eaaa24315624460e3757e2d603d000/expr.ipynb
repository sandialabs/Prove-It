# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprArray, ExprRange, IndexedVar, i, j, m, n
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprArray(ExprRange(i, [ExprRange(j, IndexedVar(A, [i, j]), one, n)], one, m)).with_orientation("vertical").with_explicit_parameterization()
# Out:
# expr: A_{1, 1} & ..A_{i, 1}.. & A_{m, 1}  \\
#   \colon & \colon & \colon  \\
#   A_{1, j} & ..A_{i, j}.. & A_{m, j}  \\
#   \colon & \colon & \colon  \\
#   A_{1, n} & ..A_{i, n}.. & A_{m, n}  \\

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  A_{1, 1} & ..A_{i, 1}.. & A_{m, 1}  \\
#   \colon & \colon & \colon  \\
#   A_{1, j} & ..A_{i, j}.. & A_{m, j}  \\
#   \colon & \colon & \colon  \\
#   A_{1, n} & ..A_{i, n}.. & A_{m, n}  \\
#   \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A_{1, 1} & ..A_{i, 1}.. & A_{m, 1}  \\
#   \colon & \colon & \colon  \\
#   A_{1, j} & ..A_{i, j}.. & A_{m, j}  \\
#   \colon & \colon & \colon  \\
#   A_{1, n} & ..A_{i, n}.. & A_{m, n}  \\
#
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1, 1}, ..A_{1, j}.., A_{1, n}), ..(A_{i, 1}, ..A_{i, j}.., A_{i, n}).., (A_{m, 1}, ..A_{m, j}.., A_{m, n})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 7
#    end_index: 3
# 2. i -> (A_{i, 1}, ..A_{i, j}.., A_{i, n})
#    core type: Lambda
#    parameter: 12
#    body: 4
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. (A_{i, 1}, ..A_{i, j}.., A_{i, n})
#    core type: ExprTuple
#    sub-expressions: 5
# 5. A_{i, 1}, ..A_{i, j}.., A_{i, n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. j -> A_{i, j}
#    core type: Lambda
#    parameter: 13
#    body: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. A_{i, j}
#    core type: IndexedVar
# variable: 10
# indices: 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. (i, j)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. j
#     core type: Variable
#     sub-expressions:
