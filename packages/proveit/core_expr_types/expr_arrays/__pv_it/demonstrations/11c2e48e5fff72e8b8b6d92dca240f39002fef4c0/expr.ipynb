# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, ExprTuple, IndexedVar, Variable, i, j

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, IndexedVar(A, sub_expr1), i, j), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), i, j))
# Out:
# expr: (A_{i}, ..A_{_a}.., A_{j}, B_{i}, ..B_{_a}.., B_{j})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{i}, \ldots, A_{j}, B_{i}, \ldots, B_{j}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{i}, ..A_{_a}.., A_{j}, B_{i}, ..B_{_a}.., B_{j})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{i}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 5
#    end_index: 6
# 2. B_{i}, ..B_{_a}.., B_{j}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 3. _a -> A_{_a}
#    core type: Lambda
#    parameter: 11
#    body: 7
# 4. _a -> B_{_a}
#    core type: Lambda
#    parameter: 11
#    body: 8
# 5. i
#    core type: Variable
#    sub-expressions:
# 6. j
#    core type: Variable
#    sub-expressions:
# 7. A_{_a}
#    core type: IndexedVar
# variable: 9
# index: 11
# 8. B_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
