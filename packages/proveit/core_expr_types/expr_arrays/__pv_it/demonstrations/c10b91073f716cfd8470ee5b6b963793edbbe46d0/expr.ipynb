# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, E, ExprArray, ExprRange, F, IndexedVar, Variable, i, j

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprArray([ExprRange(sub_expr1, IndexedVar(A, sub_expr1), i, j), A, B, C], [ExprRange(sub_expr1, IndexedVar(C, sub_expr1), i, j), D, E, F]).with_implicit_parameterization()
# Out:
# expr: A_{i} & \cdots & A_{j} & A & B & C  \\
#   C_{i} & \cdots & C_{j} & D & E & F

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccccc}
#  A_{i} & \cdots & A_{j} & A & B & C  \\
#   C_{i} & \cdots & C_{j} & D & E & F \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A_{i} & \cdots & A_{j} & A & B & C  \\
#   C_{i} & \cdots & C_{j} & D & E & F
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A_{i}, ..A_{_a}.., A_{j}, A, B, C)
#    core type: ExprTuple
#    sub-expressions: 3, 15, 4, 16
# 2. (C_{i}, ..C_{_a}.., C_{j}, D, E, F)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 3. A_{i}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 11
#    end_index: 12
# 4. B
#    core type: Variable
#    sub-expressions:
# 5. C_{i}, ..C_{_a}.., C_{j}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 6. D
#    core type: Variable
#    sub-expressions:
# 7. E
#    core type: Variable
#    sub-expressions:
# 8. F
#    core type: Variable
#    sub-expressions:
# 9. _a -> A_{_a}
#    core type: Lambda
#    parameter: 17
#    body: 13
# 10. _a -> C_{_a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. i
#     core type: Variable
#     sub-expressions:
# ...
