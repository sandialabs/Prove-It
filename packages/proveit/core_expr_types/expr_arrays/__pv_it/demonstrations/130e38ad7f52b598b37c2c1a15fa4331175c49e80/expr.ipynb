# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, ExprTuple, IndexedVar, i, j, k, m, n
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, j]
expr = ExprTuple(ExprRange(i, [ExprRange(j, IndexedVar(A, sub_expr1), one, n), ExprRange(j, IndexedVar(B, sub_expr1), one, k)], one, m))
# Out:
# expr: ((A_{1, 1}, ..A_{1, j}.., A_{1, n}, B_{1, 1}, ..B_{1, j}.., B_{1, k}), ..(A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k}).., (A_{m, 1}, ..A_{m, j}.., A_{m, n}, B_{m, 1}, ..B_{m, j}.., B_{m, k}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1, 1}, \ldots, A_{1, n}, B_{1, 1}, \ldots, B_{1, k}\right), \ldots, \left(A_{m, 1}, \ldots, A_{m, n}, B_{m, 1}, \ldots, B_{m, k}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1, 1}, ..A_{1, j}.., A_{1, n}, B_{1, 1}, ..B_{1, j}.., B_{1, k}), ..(A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k}).., (A_{m, 1}, ..A_{m, j}.., A_{m, n}, B_{m, 1}, ..B_{m, j}.., B_{m, k}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1, 1}, ..A_{1, j}.., A_{1, n}, B_{1, 1}, ..B_{1, j}.., B_{1, k}), ..(A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k}).., (A_{m, 1}, ..A_{m, j}.., A_{m, n}, B_{m, 1}, ..B_{m, j}.., B_{m, k})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 10
#    end_index: 3
# 2. i -> (A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k})
#    core type: Lambda
#    parameter: 17
#    body: 4
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. (A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A_{i, 1}, ..A_{i, j}.., A_{i, n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 10
#    end_index: 8
# 6. B_{i, 1}, ..B_{i, j}.., B_{i, k}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 7. j -> A_{i, j}
#    core type: Lambda
#    parameter: 18
#    body: 12
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. j -> B_{i, j}
#    core type: Lambda
#    parameter: 18
#    body: 13
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. A_{i, j}
#     core type: IndexedVar
# variable: 14
# indices: 16
# 13. B_{i, j}
#     core type: IndexedVar
# variable: 15
# indices: 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. (i, j)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. j
#     core type: Variable
#     sub-expressions:
