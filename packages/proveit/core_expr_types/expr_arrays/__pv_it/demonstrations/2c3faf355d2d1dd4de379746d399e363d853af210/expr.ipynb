# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, ExprTuple, IndexedVar, i, j, k, n
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, j]
expr = ExprTuple(ExprRange(j, IndexedVar(A, sub_expr1), one, n), ExprRange(j, IndexedVar(B, sub_expr1), one, k))
# Out:
# expr: (A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{i, 1}, \ldots, A_{i, n}, B_{i, 1}, \ldots, B_{i, k}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{i, 1}, ..A_{i, j}.., A_{i, n}, B_{i, 1}, ..B_{i, j}.., B_{i, k})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{i, 1}, ..A_{i, j}.., A_{i, n}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 4
# 2. B_{i, 1}, ..B_{i, j}.., B_{i, k}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 3. j -> A_{i, j}
#    core type: Lambda
#    parameter: 14
#    body: 8
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. j -> B_{i, j}
#    core type: Lambda
#    parameter: 14
#    body: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. A_{i, j}
#    core type: IndexedVar
# variable: 10
# indices: 12
# 9. B_{i, j}
#    core type: IndexedVar
# variable: 11
# indices: 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. (i, j)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
