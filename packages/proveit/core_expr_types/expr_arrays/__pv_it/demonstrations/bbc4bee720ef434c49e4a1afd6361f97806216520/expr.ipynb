# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.expr_arrays</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, ExprArray, ExprRange, IndexedVar, Variable, i, j

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprArray([ExprRange(sub_expr1, IndexedVar(A, sub_expr1), i, j), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), i, j)], [ExprRange(sub_expr1, IndexedVar(C, sub_expr1), i, j), ExprRange(sub_expr1, IndexedVar(D, sub_expr1), i, j)]).with_implicit_parameterization()
# Out:
# expr: A_{i} & \cdots & A_{j} & B_{i} & \cdots & B_{j}  \\
#   C_{i} & \cdots & C_{j} & D_{i} & \cdots & D_{j}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccccc}
#  A_{i} & \cdots & A_{j} & B_{i} & \cdots & B_{j}  \\
#   C_{i} & \cdots & C_{j} & D_{i} & \cdots & D_{j} \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A_{i} & \cdots & A_{j} & B_{i} & \cdots & B_{j}  \\
#   C_{i} & \cdots & C_{j} & D_{i} & \cdots & D_{j}
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A_{i}, ..A_{_a}.., A_{j}, B_{i}, ..B_{_a}.., B_{j})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (C_{i}, ..C_{_a}.., C_{j}, D_{i}, ..D_{_a}.., D_{j})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. A_{i}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 11
#    end_index: 12
# 4. B_{i}, ..B_{_a}.., B_{j}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 12
# 5. C_{i}, ..C_{_a}.., C_{j}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 11
#    end_index: 12
# 6. D_{i}, ..D_{_a}.., D_{j}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 7. _a -> A_{_a}
#    core type: Lambda
#    parameter: 21
#    body: 13
# 8. _a -> B_{_a}
#    core type: Lambda
#    parameter: 21
#    body: 14
# ...
