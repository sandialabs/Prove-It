# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">core_expr_types</a>.expr_arrays
# ========
#
# Theory related to **ExprArray** types of Prove-It expressions.  An **ExprArray** is a tuple of tuples representing a two-dimensional grid of expressions.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#array_eq_def">proveit.core_expr_types.expr_arrays.array_eq_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/c903e5650c08768a9af4af964efcf8d2cc5526440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# ...
