# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.expr_array</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprRange, IndexedVar
from proveit._common_ import A, B, i, j, k, m, n
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprArray(ExprRange(i, [ExprRange(j, IndexedVar(IndexedVar(A, i), j), one, n), ExprRange(j, IndexedVar(IndexedVar(B, i), j), one, k)], one, m)).withExplicitParameterization()
# Out:
# expr: A_{1,1} & ..A_{1,j}.. & A_{1,n} & B_{1,1} & ..B_{1,j}.. & B_{1,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{i,1} & ..A_{i,j}.. & A_{i,n} & B_{i,1} & ..B_{i,j}.. & B_{i,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{m,1} & ..A_{m,j}.. & A_{m,n} & B_{m,1} & ..B_{m,j}.. & B_{m,k}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccccc}
#  A_{1,1} & ..A_{1,j}.. & A_{1,n} & B_{1,1} & ..B_{1,j}.. & B_{1,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{i,1} & ..A_{i,j}.. & A_{i,n} & B_{i,1} & ..B_{i,j}.. & B_{i,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{m,1} & ..A_{m,j}.. & A_{m,n} & B_{m,1} & ..B_{m,j}.. & B_{m,k} \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_{1,1} & ..A_{1,j}.. & A_{1,n} & B_{1,1} & ..B_{1,j}.. & B_{1,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{i,1} & ..A_{i,j}.. & A_{i,n} & B_{i,1} & ..B_{i,j}.. & B_{i,k}  \\
#  \colon & \colon & \colon & \colon &\colon & \colon \\
#   A_{m,1} & ..A_{m,j}.. & A_{m,n} & B_{m,1} & ..B_{m,j}.. & B_{m,k}
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1,1}, ..A_{1,j}.., A_{1,n}, B_{1,1}, ..B_{1,j}.., B_{1,k}), ..(A_{i,1}, ..A_{i,j}.., A_{i,n}, B_{i,1}, ..B_{i,j}.., B_{i,k}).., (A_{m,1}, ..A_{m,j}.., A_{m,n}, B_{m,1}, ..B_{m,j}.., B_{m,k})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 10
#    end_index: 3
# 2. i -> (A_{i,1}, ..A_{i,j}.., A_{i,n}, B_{i,1}, ..B_{i,j}.., B_{i,k})
#    core type: Lambda
#    parameter: 19
#    body: 4
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. (A_{i,1}, ..A_{i,j}.., A_{i,n}, B_{i,1}, ..B_{i,j}.., B_{i,k})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# ...
