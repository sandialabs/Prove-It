# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.expr_array</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import A, B, i, j, n
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprRange(j, [IndexedVar(IndexedVar(A, i), j), IndexedVar(IndexedVar(B, i), j)], one, n)
# Out:
# expr: (A_{i,1}, B_{i,1}), ..(A_{i,j}, B_{i,j}).., (A_{i,n}, B_{i,n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{i,1}, B_{i,1}\right), \ldots, \left(A_{i,n}, B_{i,n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{i,1}, B_{i,1}), ..(A_{i,j}, B_{i,j}).., (A_{i,n}, B_{i,n})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. j -> (A_{i,j}, B_{i,j})
#    core type: Lambda
#    parameter: 9
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. (A_{i,j}, B_{i,j})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A_{i,j}
#    core type: IndexedVar
# variable: 7
# index: 9
# 6. B_{i,j}
#    core type: IndexedVar
# variable: 8
# index: 9
# 7. A_{i}
#    core type: IndexedVar
# variable: 10
# index: 12
# 8. B_{i}
#    core type: IndexedVar
# variable: 11
# index: 12
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. i
#     core type: Variable
#     sub-expressions:
