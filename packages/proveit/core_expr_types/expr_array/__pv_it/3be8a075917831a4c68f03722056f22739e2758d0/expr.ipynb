# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.expr_array</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import B, i, j, k
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprRange(j, IndexedVar(IndexedVar(B, i), j), one, k)
# Out:
# expr: B_{i,1}, ..B_{i,j}.., B_{i,k}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B_{i,1}, \ldots, B_{i,k}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B_{i,1}, ..B_{i,j}.., B_{i,k}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. j -> B_{i,j}
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. k
#    core type: Variable
#    sub-expressions:
# 4. B_{i,j}
#    core type: IndexedVar
# variable: 5
# index: 6
# 5. B_{i}
#    core type: IndexedVar
# variable: 7
# index: 8
# 6. j
#    core type: Variable
#    sub-expressions:
# 7. B
#    core type: Variable
#    sub-expressions:
# 8. i
#    core type: Variable
#    sub-expressions:
