# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, f
from proveit.core_expr_types import f__x_1_to_n, f__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Lambda([f, x_1_to_n, y_1_to_n], Conditional(Equals(f__x_1_to_n, f__y_1_to_n).with_wrapping_at(2), Equals([x_1_to_n], [y_1_to_n])))
# Out:
# expr: (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}\right) \mapsto \left\{\begin{array}{c} f(x_{1}, \ldots, x_{n}) =  \\ f(y_{1}, \ldots, y_{n}) \end{array} \textrm{ if } \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 13, 14
# 2. {f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}) if (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (f(x_{1}, ..x_{_a}.., x_{n}), f(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. f(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. f(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 17
#     end_index: 18
# 14. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. _a -> x_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 16. _a -> y_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 20
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. x_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. y_{_a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. y
#     core type: Variable
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
