# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#R__x_1_to_n">R__x_1_to_n</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types._common_ import R__x_1_to_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr R__x_1_to_n
# Out:
# Passed sanity check: built 'R__x_1_to_n' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(R__x_1_to_n.latex())
# Out:
# R(x_{1}, \ldots, x_{n})

# %%
# display the expression information
R__x_1_to_n.exprInfo()
# Out:
# 0. R(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. R
#    core type: Variable
#    sub-expressions:
# 2. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> x_{_a}
#    core type: Lambda
#    parameter: 9
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. x_{_a}
#    core type: IndexedVar
# variable: 8
# index: 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. _a
#    core type: Variable
#    sub-expressions:
