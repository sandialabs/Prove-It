# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, IndexedVar, P, Q, a, k, n
from proveit.logic import Implies
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = IndexedVar(a, k)
expr = ExprRange(k, Implies(Function(Q, sub_expr1), Function(P, sub_expr1)), one, n)
# Out:
# expr: (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(Q(a_{1}) \Rightarrow P(a_{1})\right), \ldots, \left(Q(a_{n}) \Rightarrow P(a_{n})\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> (Q(a_{k}) => P(a_{k}))
#    core type: Lambda
#    parameter: 13
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. Q(a_{k}) => P(a_{k})
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (Q(a_{k}), P(a_{k}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. Q(a_{k})
#    core type: Operation
#    operator: 9
#    operand: 11
# 8. P(a_{k})
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. Q
#    core type: Variable
#    sub-expressions:
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. a_{k}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
