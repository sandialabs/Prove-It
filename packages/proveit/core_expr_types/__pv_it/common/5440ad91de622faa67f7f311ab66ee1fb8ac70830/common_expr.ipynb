# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#R__y_1_to_n">R__y_1_to_n</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import R__y_1_to_n

# %%
# check that the built expression is the same as the stored expression
assert R__y_1_to_n == stored_expr
assert R__y_1_to_n._style_id == stored_expr._style_id
print("Passed sanity check: R__y_1_to_n matches stored_expr")
# Out:
# Passed sanity check: R__y_1_to_n matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(R__y_1_to_n.latex())
# Out:
# R(y_{1}, \ldots, y_{n})

# %%
# display the expression information
R__y_1_to_n.expr_info()
# Out:
# 0. R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. R
#    core type: Variable
#    sub-expressions:
# 2. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> y_{_a}
#    core type: Lambda
#    parameter: 9
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. y_{_a}
#    core type: IndexedVar
# variable: 8
# index: 9
# 8. y
#    core type: Variable
#    sub-expressions:
# 9. _a
#    core type: Variable
#    sub-expressions:
