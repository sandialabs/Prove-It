# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_ip1_to_j">f_ip1_to_j</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import f_ip1_to_j

# %%
# check that the built expression is the same as the stored expression
assert f_ip1_to_j == stored_expr
assert f_ip1_to_j._style_id == stored_expr._style_id
print("Passed sanity check: f_ip1_to_j matches stored_expr")
# Out:
# Passed sanity check: f_ip1_to_j matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_ip1_to_j.latex())
# Out:
# f(i + 1), \ldots, f(j)

# %%
# display the expression information
f_ip1_to_j.expr_info()
# Out:
# 0. f(i + 1), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> f(a)
#    core type: Lambda
#    parameter: 8
#    body: 4
# 2. i + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. f(a)
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (i, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. f
#    core type: Variable
#    sub-expressions:
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
