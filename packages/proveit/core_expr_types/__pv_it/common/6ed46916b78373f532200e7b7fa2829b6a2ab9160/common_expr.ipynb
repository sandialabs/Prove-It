# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#partition_front_equiv">partition_front_equiv</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import partition_front_equiv

# %%
# check that the built expression is the same as the stored expression
assert partition_front_equiv == stored_expr
assert partition_front_equiv._style_id == stored_expr._style_id
print("Passed sanity check: partition_front_equiv matches stored_expr")
# Out:
# Passed sanity check: partition_front_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(partition_front_equiv.latex())
# Out:
# \begin{array}{c} \left(f(i), \ldots, f(j)\right) =  \\ \left(f(i), f(i + 1), \ldots, f(j)\right) \end{array}

# %%
# display the expression information
partition_front_equiv.expr_info()
# Out:
# 0. (f(i), ..f(a).., f(j)) =  \\ (f(i), f(i + 1), ..f(a).., f(j))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i), ..f(a).., f(j)), (f(i), f(i + 1), ..f(a).., f(j)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i), ..f(a).., f(j))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(i), f(i + 1), ..f(a).., f(j))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 16
#    end_index: 10
# 6. f(i)
#    core type: Operation
#    operator: 14
#    operand: 16
# 7. f(i + 1), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. a -> f(a)
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. i + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. j
#     core type: Variable
#     sub-expressions:
# 11. f(a)
# ...
