# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, fa, i, j, k
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(a, fa, i, j), ExprRange(a, fa, Add(j, one), k))
# Out:
# expr: (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f(i), \ldots, f(j), f(j + 1), \ldots, f(k)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 3
#    end_index: 12
# 2. f(j + 1), ..f(a).., f(k)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 3. i
#    core type: Variable
#    sub-expressions:
# 4. a -> f(a)
#    core type: Lambda
#    parameter: 11
#    body: 7
# 5. j + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. k
#    core type: Variable
#    sub-expressions:
# 7. f(a)
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (j, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. f
#     core type: Variable
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
