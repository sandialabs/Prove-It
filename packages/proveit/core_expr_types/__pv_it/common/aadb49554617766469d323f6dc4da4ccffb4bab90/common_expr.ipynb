# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#f_k_to_l">f_k_to_l</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types import f_k_to_l

# %%
# check that the built expression is the same as the stored expression
assert f_k_to_l == stored_expr
assert f_k_to_l._style_id == stored_expr._style_id
print("Passed sanity check: f_k_to_l matches stored_expr")
# Out:
# Passed sanity check: f_k_to_l matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_k_to_l.latex())
# Out:
# f(k), \ldots, f(l)

# %%
# display the expression information
f_k_to_l.expr_info()
# Out:
# 0. f(k), ..f(a).., f(l)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> f(a)
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. k
#    core type: Variable
#    sub-expressions:
# 3. l
#    core type: Variable
#    sub-expressions:
# 4. f(a)
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. a
#    core type: Variable
#    sub-expressions:
