# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, fa, i, j
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, IndexedVar(a, subExpr1), one, i), ExprRange(a, fa, one, j))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, f(1), ..f(a).., f(j))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, f(1), \ldots, f(j)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, f(1), ..f(a).., f(j))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 4
# 2. f(1), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 3. _a -> a_{_a}
#    core type: Lambda
#    parameter: 10
#    body: 8
# 4. i
#    core type: Variable
#    sub-expressions:
# 5. a -> f(a)
#    core type: Lambda
#    parameter: 12
#    body: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. j
#    core type: Variable
#    sub-expressions:
# 8. a_{_a}
#    core type: IndexedVar
# variable: 12
# index: 10
# 9. f(a)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. _a
#     core type: Variable
#     sub-expressions:
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
