# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#f_1_to_n">f_1_to_n</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types._common_ import f_1_to_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr f_1_to_n
# Out:
# Passed sanity check: built 'f_1_to_n' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(f_1_to_n.latex())
# Out:
# f_{1}, \ldots, f_{n}

# %%
# display the expression information
f_1_to_n.exprInfo()
# Out:
# 0. f_{1}, ..f_{_a}.., f_{n}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> f_{_a}
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. f_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
