# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.core_expr_types</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

from proveit import x, y, f, n, P, Q, Qx, Function, ExprTuple
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Equals, Implies, Iff, Forall, Exists, UniqueExists
from proveit.numbers import Natural

# %%
# %begin theorems

# %%
unary_partial_function_existence = Forall(
    (P, Q), Implies(Forall(x, UniqueExists(y, Function(P, ExprTuple(x, y))),
                          condition=Qx),
                    Exists(f, Forall((x, y),
                                     Iff(Equals(Function(f, ExprTuple(x)), y),
                                         Function(P, ExprTuple(x, y))),
                                    condition=Qx))).with_wrap_after_operator())

# %%
# %end theorems
