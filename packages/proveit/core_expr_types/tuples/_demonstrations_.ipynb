# %% [markdown]
# Demonstrations for context <a href="_context_.ipynb" class="ProveItLink">proveit.core_expr_types.tuples</a>
# ========

# %%
import proveit
from proveit import Lambda, ExprTuple, ExprRange, indexed_var
from proveit._common_ import A, a, b, f, i, j, k, l, m, n, x, y, xx, yy
from proveit.logic import InSet
#from proveit.logic.equality._theorems_ import multiVarSubstitution
from proveit.number import Add, Mult, Neg, subtract, Naturals, NaturalsPos, Integers, zero, one, two
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import (
    a_i_to_j, x_1_to_n, y_1_to_n, f_i_to_j, f_i_to_jp1)
from proveit.core_expr_types.tuples._theorems_ import (singular_nested_range_reduction, 
len_of_ranges_with_repeated_indices_from_1, range_from1_len, len_of_ranges_with_repeated_indices_from_1, len_of_ranges_with_repeated_indices)
# %begin demonstrations

# %%
Len(one).computation()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\composite.py in compositeExpression(expressions)
#      65             # See if we can build an ExprTuple.
# ---> 66             return ExprTuple(*expressions)
#      67         except:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\expr_tuple.py in __init__(self, styles, *expressions)
#      46
# ---> 47         Expression.__init__(self, ['ExprTuple'], self.entries, styles=styles)
#      48
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in __init__(self, coreInfo, subExpressions, styles)
#     113             self._meaningData = meaningData(self._generate_unique_rep(object_rep_fn,
# --> 114                                                                       coreInfo))
#     115             if not hasattr(self._meaningData, '_coreInfo'):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generate_unique_rep(self, objectRepFn, coreInfo, styles)
#     246         # references to stored information.
# --> 247         return '%s;%s;%s;%s;%s'%(generic_ref, sub_expr_info, self._class_path(),
#     248                                  ','.join(coreInfo), style_str)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _class_path(self)
#     254         if hasattr(class_module, '__file__'):
# --> 255             context = Context(class_module.__file__)
#     256         else:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\context.py in __init__(self, path)
#      77
# ---> 78         path = os.path.abspath(path)
#      79         # if in a __pv_it_ directory, go to the containing context directory
#
# ~\Anaconda3\lib\ntpath.py in abspath(path)
#     525         try:
# --> 526             return normpath(_getfullpathname(path))
#     527         except (OSError, ValueError):
#
# ~\Anaconda3\lib\ntpath.py in normpath(path)
#     451     """Normalize path, eliminating double slashes, etc."""
# --> 452     path = os.fspath(path)
#     453     if isinstance(path, bytes):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6d140ec6806f> in <module>
# ----> 1 Len(one).computation()
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# ...
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in inner_equiv(*args, **kwargs)
#     227                 else:
#     228                     assumptions = USE_DEFAULTS
# --> 229                 equivalence = equiv_method(*args, **kwargs)
#     230                 # We need to disable the auto-reduction as we
#     231                 # are making this substitution to ensure we do not
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in simplification(self, assumptions, automation)
#     384         if not automation:
#     385             return Expression.simplification(self, assumptions, automation=False)
# --> 386         from proveit.relation import TransRelUpdater
#     387         eq = TransRelUpdater(self, assumptions)
#     388         expr = eq.update(self.computation(assumptions))
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     324             # Restore 'defaults'.
#     325             if disable_range_reduction and not was_range_reduction_disabled:
# --> 326                 defaults.disabled_auto_reduction_types.remove(ExprRange)
#     327         if simplify:
#     328             equiv = equiv.innerExpr().rhs.simplify(assumptions=assumptions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in __getattr__(self, attr)
#     270             # and may be a sub-sub-Expression (or a member of sub-sub-Expression composite);
#     271             # if so, return the SubExprRepl extended to the sub-sub-Expression.
# --> 272             inner_expr = self._getAttrAsInnerExpr(len(self.innerExprPath), attr, inner_attr_val)
#     273             if inner_expr is not None:
#     274                 return inner_expr
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in _getAttrAsInnerExpr(self, cur_depth, attr, attr_expr)
#     185                                    assumptions=self.assumptions)
#     186             inner_expr = inner_expr._getAttrAsInnerExpr(cur_depth,  attr,
# --> 187                                                         attr_expr)
#     188             if inner_expr is not None:
#     189                 return inner_expr
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in _getAttrAsInnerExpr(self, cur_depth, attr, attr_expr)
#     170                                               self.innerExprPath + (i,),
#     171                                               assumptions=self.assumptions)
# --> 172                 repl_lambda = deeper_inner_expr.repl_lambda()
#     173                 sub_expr = repl_lambda .body
#     174                 for j in self.innerExprPath[:cur_depth]:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in repl_lambda(self)
#     388         # Build the expression with replacement parameters from
#     389         # the inside out.
# --> 390         lambda_body = self._rebuild(lambda_body)
#     391         return Lambda(lambda_params, lambda_body)
#     392
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\inner_expr.py in _rebuild(self, inner_expr_replacement)
#     412             inner_expr = expr.__class__._make(
#     413                     expr.coreInfo(), expr.getStyles(),
# --> 414                     expr_subs[:idx] + (inner_expr,) + expr_subs[idx+1:])
#     415         revised_expr = inner_expr
#     416         if (isinstance(self.exprHierarchy[0], KnownTruth) and
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in _make(operationClass, coreInfo, styles, subExpressions)
#     294                 kw, val = arg
#     295                 kw_args[kw] = val
# --> 296         made_operation = operationClass(*args, **kw_args)
#     297         if styles is not None:
#     298             made_operation.withStyles(**styles)
#
# c:\users\joaqu\prove-it\packages\proveit\logic\equality\equals.py in __init__(self, a, b)
#      37
#      38     def __init__(self, a, b):
# ---> 39         TransitiveRelation.__init__(self, Equals._operator_, a, b)
#      40         '''
#      41         # May be better not to be proactive but we need to see if this
#
# c:\users\joaqu\prove-it\packages\proveit\relation\transitivity.py in __init__(self, operator, lhs, rhs)
#      35
#      36     def __init__(self, operator, lhs, rhs):
# ---> 37         Operation.__init__(self,operator, (lhs, rhs))
#      38         assert(len(self.operands)==2)
#      39         self.lhs = self.operands[0]
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in __init__(self, operator_or_operators, operand_or_operands, styles)
#      49         # one non-ExprRange and non-ExprTuple element.
#      50         self.operand_or_operands = singleOrCompositeExpression(
# ---> 51                 operand_or_operands, do_singular_reduction=True)
#      52
#      53         def raiseBadOperatorType(operator):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\composite.py in singleOrCompositeExpression(expr_or_exprs, wrap_expr_range_in_tuple, do_singular_reduction)
#      90         return ExprTuple(expr_or_exprs)
#      91     if not isinstance(expr_or_exprs, Expression):
# ---> 92         expr_or_exprs = compositeExpression(expr_or_exprs)
#      93     if (do_singular_reduction and isinstance(expr_or_exprs, ExprTuple)
#      94             and len(expr_or_exprs)==1):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\composite.py in compositeExpression(expressions)
#      67         except:
#      68             # try to see if we can use expressions to generate a NamedExpressions object
# ---> 69             return NamedExprs(expressions)
#      70
#      71 def singleOrCompositeExpression(expr_or_exprs,
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\named_exprs.py in __init__(self, items, styles)
#      15         keywords = []
#      16         elems = dict()
# ---> 17         for key, val in items:
#      18             keywords.append(key)
#      19             if ':' in key:
#
# TypeError: cannot unpack non-iterable Variable object

# %%
ExprRange(i, i, one, one)._possibly_reduced_range_entries(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), two, one), 
                                                                    two, one), assumptions=[], requirements=[])
# Out:
# <generator object ExprRange._possibly_reduced_range_entries at 0x000001D79555F570>

# %%
expr_range = ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, n), one, zero)
# Out:
# expr_range: a_{1,1}, ..a_{1,j}.., a_{1,n}, ....a_{i,1}, ..a_{i,j}.., a_{i,n}...., a_{0,1}, ..a_{0,j}.., a_{0,n}

# %%
expr_range.lambda_map
# Out:
# i -> a_{i,1}, ..a_{i,j}.., a_{i,n}

# %%
lambdaMap = Lambda((expr_range.parameter, expr_range.body.parameter), expr_range.body.body)
# Out:
# lambdaMap: (i, j) -> a_{i,j}

# %%
def entry_map(entry):
    if isinstance(entry, ExprRange):
        if isinstance(entry.body, ExprRange):
            # Return an ExprRange of lambda maps.
            return ExprRange(entry.parameter, 
                             entry.body.lambda_map,
                             entry.start_index,
                             entry.end_index)
        else:
            # Use the ExprRange entry's map.
            return entry.lambda_map
    # For individual elements, just map to the 
    # elemental entry.
    return Lambda(_x, entry)

# %%
entries = expr_range
# Out:
# entries: a_{1,1}, ..a_{1,j}.., a_{1,n}, ....a_{i,1}, ..a_{i,j}.., a_{i,n}...., a_{0,1}, ..a_{0,j}.., a_{0,n}

# %%
Map = [entry_map(entry) for entry in [entries]]
# Out:
# Map: (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j})

# %%
Map[0].lambda_map
# Out:
# i -> [j -> a_{i,j}]

# %%
Len(Map).computation()
# Out:
# reducing: [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}]
# else!
# range reduction
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{0,j}]
# single range!!
# i -> [j -> a_{i,j}]
# 0
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{0,j}]
# returning: |- |(j -> a_{1,j}, ..j -> a_{_a,j}.., j -> a_{0,j})| = 0
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{0,j}]
# reducing: [_a -> a_{1,_a}], ..[_a -> a_{_c,_a}].., [_a -> a_{0,_a}]
# reducing: [_a -> a_{1,_a}], ..[_a -> a_{_c,_a}].., [_a -> a_{0,_a}]
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{0,j}]
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{0,j}]
# |- |(j -> a_{1,j}, ..j -> a_{_a,j}.., j -> a_{0,j})| = 0

# %%
Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, zero), one, n)).computation(assumptions=[InSet(n, Naturals)])
# Out:
# reducing: a_{1,1}, ..a_{1,j}.., a_{1,0}, ....a_{i,1}, ..a_{i,j}.., a_{i,0}...., a_{n,1}, ..a_{n,j}.., a_{n,0}
# else!
# reducing: 1, ..n repeats.., 1
# else!
# single range!!
# i -> 1
# n
# reducing: 1, ..n repeats.., 1
# else!
# returning: {n in Naturals} |- |(1, ..n repeats.., 1)| = n
# reducing: 1, ..n repeats.., 1
# else!
# reducing: 1, .._a.., n
# else!
# single range!!
# _a -> _a
# n
# reducing: 1, ..a.., n
# else!
# returning: {n in Naturals} |- |(1, ..a.., n)| = n
# reducing: 1, ..a.., n
# else!
# reducing: 1, .._a.., n
# reducing: 1, .._a.., n
# reducing: 1, ..a.., n
# reducing: 1, ..a.., n
# reducing: [j -> a_{1,j}], ..[j -> a_{_a,j}].., [j -> a_{n,j}]
# reducing: 1, ..k.., n
# reducing: 1, .._a.., n
# else!
# single range!!
# _a -> _a
# n
# reducing: 1, ..a.., n
# else!
# returning: {n in Naturals} |- |(1, ..a.., n)| = n
# reducing: 1, ..a.., n
# else!
# reducing: 1, .._a.., n
# reducing: 1, .._a.., n
# reducing: 1, ..a.., n
# reducing: 1, ..a.., n
# reducing: a_{1,1}, ..a_{1,x}.., a_{1,0}, ....a_{k,1}, ..a_{k,x}.., a_{k,0}...., a_{n,1}, ..a_{n,x}.., a_{n,0}
# else!
# reducing: a_{1,1}, ..a_{1,_d}.., a_{1,0}, ....a_{_c,1}, ..a_{_c,_d}.., a_{_c,0}...., a_{n,1}, ..a_{n,_d}.., a_{n,0}
# reducing: a_{1,1}, ..a_{1,_d}.., a_{1,0}, ....a_{_c,1}, ..a_{_c,_d}.., a_{_c,0}...., a_{n,1}, ..a_{n,_d}.., a_{n,0}
# reducing: a_{1,1}, ..a_{1,x}.., a_{1,0}, ....a_{k,1}, ..a_{k,x}.., a_{k,0}...., a_{n,1}, ..a_{n,x}.., a_{n,0}
# reducing: a_{1,1}, ..a_{1,x}.., a_{1,0}, ....a_{k,1}, ..a_{k,x}.., a_{k,0}...., a_{n,1}, ..a_{n,x}.., a_{n,0}
# {n in Naturals} |- |(a_{1,1}, ..a_{1,x}.., a_{1,0}, ....a_{k,1}, ..a_{k,x}.., a_{k,0}...., a_{n,1}, ..a_{n,x}.., a_{n,0})| = 0

# %%
Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, n), one, zero)).computation(assumptions=[InSet(n, Naturals)])
# Out:
# reducing: a_{1,1}, ..a_{1,j}.., a_{1,n}, ....a_{i,1}, ..a_{i,j}.., a_{i,n}...., a_{0,1}, ..a_{0,j}.., a_{0,n}
# else!
# range reduction
# nested range
# reducing: 1, ..0 repeats.., 1
# else!
# range reduction
# reducing: 1, ..0 repeats.., 1
# single range!!
# i -> 1
# 0
# reducing: 1, ..0 repeats.., 1
# returning: |- |(1, ..0 repeats.., 1)| = 0
# reducing: 1, ..0 repeats.., 1
# doReducedEvaluation for |n|
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1030                                    operands_iter, assumptions, requirements,
# -> 1031                                    repl_map, is_complete=True)
#    1032     except ValueError as e:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_param_replacements(parameters, parameter_vars, body, operands_iter, assumptions, requirements, repl_map, is_complete)
#    1179                                 Len(operand).evaluation(
# -> 1180                                         assumptions=assumptions)
#    1181                             requirements.append(operand_len_evaluation)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in evaluation(self, assumptions, automation, **kwargs)
#     904                    %(method_called, evaluation, self, assumptions))
# --> 905             raise ValueError(msg)
#     906         # Note: No need to store in Equals.known_evaluation_sets or
#
# ValueError: <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming (n in Naturals,)
#
# During handling of the above exception, another exception occurred:
#
# LambdaApplicationError                    Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#     940                         assumptions, requirements,
# --> 941                         equality_repl_requirements)
#     942
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in _instantiated_expr(original_known_truth, num_forall_eliminations, instantiation_params, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1211                 # Instantiate the condition.
# -> 1212                 subbed_cond = instantiate(condition)
#    1213                 if isinstance(subbed_cond, And):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in instantiate(expr, exclusion)
#    1159                     assumptions=assumptions, requirements=requirements,
# -> 1160                     equality_repl_requirements=equality_repl_requirements)
#    1161
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in _apply(parameters, body, equiv_alt_expansions, allow_relabeling, assumptions, requirements, equality_repl_requirements, parameter_vars, *operands)
#     515                 parameters, parameter_vars, body, operands,
# --> 516                 assumptions, requirements, repl_map)
#     517
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1033         raise LambdaApplicationError(
# -> 1034                 parameters, body, operands, assumptions, [], str(e))
#    1035
#
# LambdaApplicationError: Failure to apply (n, f_{1}, ..f_{_a}.., f_{0}, i) -> (i in Naturals) to (0, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], n) assuming (n in Naturals,):
# <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming (n in Naturals,)
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# <ipython-input-12-6cd175149506> in <module>
# ----> 1 Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, n), one, zero)).computation(assumptions=[InSet(n, Naturals)])
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in computation(self, assumptions, simplify)
#      59                 self._computation, assumptions,
#      60                 disable_range_reduction=disable_range_reduction,
# ---> 61                 simplify=simplify)
#      62
#      63     def _computation(self, assumptions=USE_DEFAULTS):
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _tested_equivalence(self, equivalence_fn, assumptions, simplify, disable_range_reduction)
#     318                 # is not reduced).
#     319                 defaults.disabled_auto_reduction_types.add(ExprRange)
# --> 320             equiv = equivalence_fn(assumptions)
#     321         finally:
#     322             # Restore 'defaults'.
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _computation(self, assumptions)
#     204                         return thm.instantiate(
#     205                                 {n:_n, f:_f, i:_j[0]},
# --> 206                                 assumptions=assumptions)
#     207                     else:
#     208                         thm = len_of_ranges_with_repeated_indices
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     893                               repl_map=processed_repl_map,
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#     897     def generalize(self, forall_var_or_vars_or_var_lists,
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1021         except LambdaApplicationError as e:
#    1022             raise InstantiationFailure(orig_known_truth, repl_map,
# -> 1023                                        assumptions, str(e))
#    1024         finally:
#    1025             # restore the original default assumptions
#
# InstantiationFailure: Proof step failed assuming {n in Naturals}:
# Attempting to instantiate |- forall_{n in Naturals} [forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Naturals} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))] with {n: 0, f: (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j}), i: n, (f_{1}, ..f_{_a}.., f_{0}): (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j})}:
# Failure to apply (n, f_{1}, ..f_{_a}.., f_{0}, i) -> (i in Naturals) to (0, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], n) assuming (n in Naturals,):
# <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming (n in Naturals,)

# %%
Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, n), one, zero))._computation()
# line 88 ("returning: range_from1_len")
# Out:
# reducing: 1, ..0 repeats.., 1
# else!
# range reduction
# reducing: 1, ..0 repeats.., 1
# single range!!
# i -> 1
# 0
# reducing: 1, ..0 repeats.., 1
# returning: |- |(1, ..0 repeats.., 1)| = 0
# reducing: 1, ..0 repeats.., 1
# doReducedEvaluation for |n|
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1030                                    operands_iter, assumptions, requirements,
# -> 1031                                    repl_map, is_complete=True)
#    1032     except ValueError as e:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_param_replacements(parameters, parameter_vars, body, operands_iter, assumptions, requirements, repl_map, is_complete)
#    1179                                 Len(operand).evaluation(
# -> 1180                                         assumptions=assumptions)
#    1181                             requirements.append(operand_len_evaluation)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in evaluation(self, assumptions, automation, **kwargs)
#     904                    %(method_called, evaluation, self, assumptions))
# --> 905             raise ValueError(msg)
#     906         # Note: No need to store in Equals.known_evaluation_sets or
#
# ValueError: <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming ()
#
# During handling of the above exception, another exception occurred:
#
# LambdaApplicationError                    Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#     940                         assumptions, requirements,
# --> 941                         equality_repl_requirements)
#     942
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in _instantiated_expr(original_known_truth, num_forall_eliminations, instantiation_params, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1211                 # Instantiate the condition.
# -> 1212                 subbed_cond = instantiate(condition)
#    1213                 if isinstance(subbed_cond, And):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in instantiate(expr, exclusion)
#    1159                     assumptions=assumptions, requirements=requirements,
# -> 1160                     equality_repl_requirements=equality_repl_requirements)
#    1161
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in _apply(parameters, body, equiv_alt_expansions, allow_relabeling, assumptions, requirements, equality_repl_requirements, parameter_vars, *operands)
#     515                 parameters, parameter_vars, body, operands,
# --> 516                 assumptions, requirements, repl_map)
#     517
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1033         raise LambdaApplicationError(
# -> 1034                 parameters, body, operands, assumptions, [], str(e))
#    1035
#
# LambdaApplicationError: Failure to apply (n, f_{1}, ..f_{_a}.., f_{0}, i) -> (i in Naturals) to (0, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], n):
# <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming ()
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# <ipython-input-13-69749cac09ac> in <module>
# ----> 1 Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, n), one, zero))._computation()
#       2 # line 88 ("returning: range_from1_len")
#
# c:\users\joaqu\prove-it\packages\proveit\core_expr_types\tuples\length.py in _computation(self, assumptions)
#     204                         return thm.instantiate(
#     205                                 {n:_n, f:_f, i:_j[0]},
# --> 206                                 assumptions=assumptions)
#     207                     else:
#     208                         thm = len_of_ranges_with_repeated_indices
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     893                               repl_map=processed_repl_map,
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#     897     def generalize(self, forall_var_or_vars_or_var_lists,
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1021         except LambdaApplicationError as e:
#    1022             raise InstantiationFailure(orig_known_truth, repl_map,
# -> 1023                                        assumptions, str(e))
#    1024         finally:
#    1025             # restore the original default assumptions
#
# InstantiationFailure: Proof step failed:
# Attempting to instantiate |- forall_{n in Naturals} [forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Naturals} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))] with {n: 0, f: (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j}), i: n, (f_{1}, ..f_{_a}.., f_{0}): (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j})}:
# Failure to apply (n, f_{1}, ..f_{_a}.., f_{0}, i) -> (i in Naturals) to (0, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], n):
# <bound method Len.doReducedEvaluation of |n|> must return an KnownTruth equality with an irreducible value on the right side, not |- |n| = |n| for |n| assuming ()

# %%
len_of_ranges_with_repeated_indices.instantiate({i:n, f:Map, n: zero}, assumptions=[InSet(n, Naturals)])
# Out:
# doReducedEvaluation for |0|
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1030                                    operands_iter, assumptions, requirements,
# -> 1031                                    repl_map, is_complete=True)
#    1032     except ValueError as e:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_param_replacements(parameters, parameter_vars, body, operands_iter, assumptions, requirements, repl_map, is_complete)
#    1179                                 Len(operand).evaluation(
# -> 1180                                         assumptions=assumptions)
#    1181                             requirements.append(operand_len_evaluation)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in evaluation(self, assumptions, automation, **kwargs)
#     904                    %(method_called, evaluation, self, assumptions))
# --> 905             raise ValueError(msg)
#     906         # Note: No need to store in Equals.known_evaluation_sets or
#
# ValueError: <bound method Len.doReducedEvaluation of |0|> must return an KnownTruth equality with an irreducible value on the right side, not |- |0| = |0| for |0| assuming (n in Naturals,)
#
# During handling of the above exception, another exception occurred:
#
# LambdaApplicationError                    Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#     940                         assumptions, requirements,
# --> 941                         equality_repl_requirements)
#     942
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in _instantiated_expr(original_known_truth, num_forall_eliminations, instantiation_params, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1211                 # Instantiate the condition.
# -> 1212                 subbed_cond = instantiate(condition)
#    1213                 if isinstance(subbed_cond, And):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in instantiate(expr, exclusion)
#    1159                     assumptions=assumptions, requirements=requirements,
# -> 1160                     equality_repl_requirements=equality_repl_requirements)
#    1161
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in _apply(parameters, body, equiv_alt_expansions, allow_relabeling, assumptions, requirements, equality_repl_requirements, parameter_vars, *operands)
#     515                 parameters, parameter_vars, body, operands,
# --> 516                 assumptions, requirements, repl_map)
#     517
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in extract_complete_param_replacements(parameters, parameter_vars, body, operands, assumptions, requirements, repl_map)
#    1033         raise LambdaApplicationError(
# -> 1034                 parameters, body, operands, assumptions, [], str(e))
#    1035
#
# LambdaApplicationError: Failure to apply (i, f_{1}, ..f_{_a}.., f_{0}, n, j) -> ((j - i + 1) in Naturals) to (n, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], 0, j) assuming (n in Naturals,):
# <bound method Len.doReducedEvaluation of |0|> must return an KnownTruth equality with an irreducible value on the right side, not |- |0| = |0| for |0| assuming (n in Naturals,)
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# <ipython-input-14-d744e3eb6d0e> in <module>
# ----> 1 len_of_ranges_with_repeated_indices.instantiate({i:n, f:Map, n: zero}, assumptions=[InSet(n, Naturals)])
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     893                               repl_map=processed_repl_map,
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#     897     def generalize(self, forall_var_or_vars_or_var_lists,
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1021         except LambdaApplicationError as e:
#    1022             raise InstantiationFailure(orig_known_truth, repl_map,
# -> 1023                                        assumptions, str(e))
#    1024         finally:
#    1025             # restore the original default assumptions
#
# InstantiationFailure: Proof step failed assuming {n in Naturals}:
# Attempting to instantiate |- forall_{n in Naturals} [forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Naturals} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))] with {i: n, f: (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j}), n: 0, j: j, (f_{1}, ..f_{_a}.., f_{0}): (j -> a_{1,j}, ..j -> a_{i,j}.., j -> a_{0,j})}:
# Failure to apply (i, f_{1}, ..f_{_a}.., f_{0}, n, j) -> ((j - i + 1) in Naturals) to (n, [j -> a_{1,j}], ..[j -> a_{i,j}].., [j -> a_{0,j}], 0, j) assuming (n in Naturals,):
# <bound method Len.doReducedEvaluation of |0|> must return an KnownTruth equality with an irreducible value on the right side, not |- |0| = |0| for |0| assuming (n in Naturals,)

# %%
len_of_ranges_with_repeated_indices_from_1.instantiate({n: zero, f:[entry_map(entry) for entry in [entries]], i: n}, assumptions=[InSet(n, Naturals)])

# %%
expr_range = ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, one), one, one)

# %%
lambda_map = Lambda((expr_range.parameter, expr_range.body.parameter), expr_range.body.body)

# %%
singular_nested_range_reduction.instantiate({f:lambda_map, i:one, j:one, m:one})

# %%
Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, one), one, one)).computation()

# %%
Len(ExprRange(i, ExprRange(j, indexed_var(a, [i, j]), one, two), one, one)).computation()

# %%
assumptions = [InSet(Add(j, Neg(i), one), Naturals), 
               InSet(i, Naturals), InSet(j, Naturals)]

# %%
f_i_to_jp1

# %%
eq = f_i_to_jp1.partition(j, assumptions)

# %%
eq.rhs.merger(assumptions)

# %%
f_i_to_j__shift__eq = \
    f_i_to_j.shift_equivalence(new_shift=one, assumptions=[InSet(subtract(Add(j, one), i),
                                                                 Naturals)])

# %%
f_i_to_j__shift__eq.rhs

# %%
Add(subtract(i, one), one).simplification([InSet(i, Integers)])

# %%
Add(Add(i, Neg(two)), two).simplification([InSet(i, Integers)])

# %%
Add(subtract(j, one), one).simplification([InSet(j, Integers)])

# %%
Add(subtract(j, two), two).simplification([InSet(j, Integers)])

# %%
f_i_to_j__shift__eq.rhs.entries[0].shift_equivalence(
    old_shift=one, new_shift=two, 
    assumptions=[InSet(j, Integers), InSet(i, Integers),
                 InSet(subtract(j, subtract(i, one)), Naturals)])

# %%
tup=ExprTuple(a, b)

# %%
Len(a_i_to_j).computation([InSet(Add(j, Neg(i), one), Naturals)],
                          simplify=False)

# %%
tup.prove([tup]).instantiate({a:a_i_to_j},
                            assumptions=[InSet(Add(j, Neg(i), one), Naturals)])

# %%
eq = f_i_to_jp1.partition(k, [InSet(subtract(Add(k, one), i), Naturals),
                              InSet(subtract(Add(j, one), k), Naturals)])

# %%
eq.rhs.merger([InSet(subtract(Add(k, one), i), Naturals),
                              InSet(subtract(Add(j, one), k), Naturals)])

# %%
eq = f_i_to_jp1.partition(i, [InSet(subtract(Add(j, one), i), Naturals)])

# %%
eq.rhs.merger([InSet(subtract(Add(j, one), i), Naturals)])

# %%
eq = f_i_to_j.partition(subtract(j, one), [InSet(subtract(j, i), Naturals)])

# %%
Add(subtract(j, one), one).simplification([InSet(j, Naturals)])

# %%
eq.rhs.merger([InSet(subtract(j, i), Naturals), InSet(j, Naturals)])

# %%
# %end demonstrations
