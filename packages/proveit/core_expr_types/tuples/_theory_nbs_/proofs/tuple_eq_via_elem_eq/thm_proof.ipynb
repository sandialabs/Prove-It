# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../../theory.ipynb">tuples</a>.<a class="ProveItLink" href="../../theorems.ipynb#tuple_eq_via_elem_eq">tuple_eq_via_elem_eq</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import a, b, c, d, m
from proveit.core_expr_types.tuples  import tuple_eq_def
from proveit.logic import And
from proveit.numbers import Add, zero, one
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural_pos

# %%
# %proving tuple_eq_via_elem_eq
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="tuple_eq_via_elem_eq">tuple_eq_via_elem_eq:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b032b2cdc2eda215cf3bb0e638ef73c96c50ab690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f597eed95753311ebd4f279a41f64a54a8efde810/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# ### Instantiate the induction theorem for an inductive proof.

# %%
tuple_eq_via_elem_eq.instance_expr
# Out:
# forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{i} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{i} = b_{i})} ((a_{1}, a_{2}, ..., a_{i}) = (b_{1}, b_{2}, ..., b_{i}))

# %%
fold_forall_natural_pos
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])

# %%
from proveit import Function
from proveit import P, i
induction_inst = \
    fold_forall_natural_pos.instantiate({Function(P, i):tuple_eq_via_elem_eq.instance_expr}) \
        .inner_expr().with_wrapping_at(1).inner_expr().antecedent.with_wrapping_at(1) \
        .inner_expr().antecedent.operands[1].with_wrapping()
# Out:
# <strong id="induction_inst">induction_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/a9061ec5ea6bb4eabfbd74cd56573a2525a2b4940/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/cf11078f92ffbe8831606293cdcb0a635c250d8d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# <strong id="induction_base">induction_base:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/40c367c48fec87eb152445ded5e31adcbe45a0560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
a1, b1 = induction_base.instance_params
# Out:
# <strong id="a1">a1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/3eb479a88d1b946b5388809929c87dbef86577a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="b1">b1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e34709e0b4eff584811d487a3c503cb2524c7d200/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
tuple_eq_def
# Out:
# |- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} (((a_{1}, a_{2}, ..., a_{i}, b) = (c_{1}, c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d)))]

# %%
tuple_eq_base = tuple_eq_def.instantiate({i:zero})
# Out:
# <strong id="tuple_eq_base">tuple_eq_base:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/420768d4a35bc0e22b00e303663d1fbca40f8de90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/80f8ebd830e77ec1c3b27c5f52187bc14824c1db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
tuple_eq_base_inst = tuple_eq_base.instantiate({b:a1, d:b1})
# Out:
# <strong id="tuple_eq_base_inst">tuple_eq_base_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/f49046f1bc13c994a99123bdd43b60690daf08820/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/3cbf39f1b5ff5699fed5cfc600a47c54b6a633210/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
tuple_eq_base_inst.rhs.prove(assumptions=induction_base.conditions)
# Out:
# {a_{1} = b_{1}} |- TRUE and (a_{1} = b_{1})

# %%
tuple_eq_base_inst.derive_left_via_equality(assumptions=induction_base.conditions)
# Out:
# {a_{1} = b_{1}} |- (a_{1}) = (b_{1})

# %%
induction_base.prove()
# Out:
# |- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1].with_wrapping()
# Out:
# <strong id="induction_step">induction_step:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/06f83c4f9c2f90780c4496a6c84badbdabb31bd10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
eq_conds = induction_step.instance_expr.explicit_conditions()[0]
# Out:
# <strong id="eq_conds">eq_conds:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = (induction_step.conditions + [eq_conds])
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/ef24b3681ac330f8b30d540bb6526d09f01637f10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# <strong id="induction_hyp">induction_hyp:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e69ae6f8d6cefc57f09a9c919aa48aef65a02b8f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ***Splitting apart the conjunction of equality conditions is an important step***

# %%
eq_cond_partition = eq_conds.partition(m)
# Out:
# <strong id="eq_cond_partition">eq_cond_partition:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/be5531e59e0b64eb34b2e1692a4d01178b8633bb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/ef44a70204d3caecb8b3ff4412e3129e93f13d2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_conds_conjunction = And(eq_conds).prove()
# Out:
# <strong id="eq_conds_conjunction">eq_conds_conjunction:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/31a584a70450de90d7b55070267bf8a7bf07c12a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/1877b42461214579e6111125f626197536a4c9e60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_conds_conjunction_partition = eq_cond_partition.sub_right_side_into(eq_conds_conjunction)
# Out:
# <strong id="eq_conds_conjunction_partition">eq_conds_conjunction_partition:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/5a6d4e3e17275ed681820fb77fd0441c1a9d15f60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e25eb2201f5c3bf5305e67478ba73671a6d552df0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_conds_conjunction_partition.derive_some(0)
# Out:
# {m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})

# %% [markdown]
# ***And now we will be able to prove the induction step by invoking the `tuple_eq_def` axiom***

# %%
last_eq = eq_conds_conjunction_partition.derive_any(1)
# Out:
# <strong id="last_eq">last_eq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e4f77c4c5eb59851a38ef0df785f366ea896b7bf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/c8bd885db02a8c4a981cf7403c81c0a2903d954c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
a_mp1, b_mp1 = last_eq.operands
# Out:
# <strong id="a_mp1">a_mp1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2b5a28624994429edf509f4c13e184f339fe32fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="b_mp1">b_mp1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2e9e170a14c7b9e8f46fd2a0675729b550abe2b00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
tuple_eq_def
# Out:
# |- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} (((a_{1}, a_{2}, ..., a_{i}, b) = (c_{1}, c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d)))]

# %%
tuple_eq_def_inst = tuple_eq_def.instantiate({i:m, c:b, b:a_mp1, d:b_mp1})
# Out:
# <strong id="tuple_eq_def_inst">tuple_eq_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/4b37382bb33972516f90ec44f8e172fd5056c46d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/bf2c9f92e26454beca8b61f9da3d336f614df1ed0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
tuple_eq_def_inst.rhs.prove()
# Out:
# {forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})) and (a_{m + 1} = b_{m + 1})

# %%
tuple_eq_split_both = tuple_eq_def_inst.derive_left_via_equality()
# Out:
# <strong id="tuple_eq_split_both">tuple_eq_split_both:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e69ae6f8d6cefc57f09a9c919aa48aef65a02b8f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/09f1bb9fb90e7e6a8e4ddbff0f77b1840557c6bc0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/9595037881ddff0b9e9c427edefbed9acabd5a570/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
tuple_eq_split_right = tuple_eq_split_both.inner_expr().lhs.merge()
# Out:
# <strong id="tuple_eq_split_right">tuple_eq_split_right:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e69ae6f8d6cefc57f09a9c919aa48aef65a02b8f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/264313abf0f1d6d5e17f4b8d587e900d816297f90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/df7f9d0822e0a080f2208c99ddf39c22abf548440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
tuple_eq = tuple_eq_split_right.inner_expr().rhs.merge()
# Out:
# <strong id="tuple_eq">tuple_eq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/e69ae6f8d6cefc57f09a9c919aa48aef65a02b8f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/2fa67578b2af9f310f3c641ab402a90dc9ab796e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/a18f9194766498db10419de183fafb82b8d84dcf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_tuple_eq_via_elem_eq/13422a744e77bf166d934cbb40a473ef6800ff7a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.derive_consequent()
# Out:
# |- forall_{n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}))]
# tuple_eq_via_elem_eq has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.core_expr_types.tuples.tuple_eq_via_elem_eq has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{i in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{i} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{i} = b_{i})} ((a_{1}, a_{2}, ..., a_{i}) = (b_{1}, b_{2}, ..., b_{i}))]
# 1	instantiation	3	|- ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]]) => [forall_{n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}))]]
# 	P(i) : forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{i} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{i} = b_{i})} ((a_{1}, a_{2}, ..., a_{i}) = (b_{1}, b_{2}, ..., b_{i}))
# 2	instantiation	33, 4, 5	|- [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]]
# 	A : forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), B : forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]
# 3	conjecture		|- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])
# 	proveit.numbers.number_sets.natural_numbers.fold_forall_natural_pos
# 4	generalization	6	|- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
# 5	generalization	7	|- forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]
# 6	instantiation	22, 8, 9	{a_{1} = b_{1}} |- (a_{1}) = (b_{1})
# 	P : (a_{1}) = (b_{1}), Q : TRUE and (a_{1} = b_{1})
# 7	instantiation	15, 10, 11	{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
# 	P(_b) : (a_{1}, a_{2}, ..., a_{m + 1}) = _b, x : (b_{1}, b_{2}, ..., b_{m}, b_{m + 1}), y : (b_{1}, b_{2}, ..., b_{m + 1})
# 8	instantiation	33, 12, 13	{a_{1} = b_{1}} |- TRUE and (a_{1} = b_{1})
# 	A : TRUE, B : a_{1} = b_{1}
# 9	instantiation	14	|- ((a_{1}) = (b_{1})) =  \\ (TRUE and (a_{1} = b_{1}))
# 	a : a, b : a_{1}, c : c, d : b_{1}
# 10	instantiation	15, 16, 17	{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m}, b_{m + 1})
# 	P(_b) : _b = (b_{1}, b_{2}, ..., b_{m}, b_{m + 1}), x : (a_{1}, a_{2}, ..., a_{m}, a_{m + 1}), y : (a_{1}, a_{2}, ..., a_{m + 1})
# 11	instantiation	25, 18	{m in NaturalPos} |- (b_{1}, b_{2}, ..., b_{m}, b_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
# 	f(_a) : b_{_a}, i : 1, j : m
# 12	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
# 13	assumption		{a_{1} = b_{1}} |- a_{1} = b_{1}
# 14	instantiation	36, 53, 19*, 20*, 21*	|- forall_{a_{1}, a_{2}, ..., a_{0}, b, c_{1}, c_{2}, ..., c_{0}, d} (((b) = (d)) =  \\ (TRUE and (b = d)))
# 	i : 0
# 15	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 16	instantiation	22, 23, 24	{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1}, a_{2}, ..., a_{m}, a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m}, b_{m + 1})
# 	P : (a_{1}, a_{2}, ..., a_{m}, a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m}, b_{m + 1}), Q : ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})) and (a_{m + 1} = b_{m + 1})
# 17	instantiation	25, 26	{m in NaturalPos} |- (a_{1}, a_{2}, ..., a_{m}, a_{m + 1}) = (a_{1}, a_{2}, ..., a_{m + 1})
# 	f(_a) : a_{_a}, i : 1, j : m
# 18	instantiation	74, 75	{m in NaturalPos} |- |(b_{1}, b_{2}, ..., b_{m})| in Natural
# 	i : m, f(_a) : b_{_a}
# 19	instantiation	28, 53, 82, 54, 27, 41	|- (a_{1}, a_{2}, ..., a_{0}, b) =  \\ (b)
# 	i : 0, j : 0, k : 1, a : (), b : (a_{1}, a_{2}, ..., a_{0}), c : (b), d : ()
# 20	instantiation	28, 53, 82, 54, 29, 42	|- (c_{1}, c_{2}, ..., c_{0}, d) =  \\ (d)
# 	i : 0, j : 0, k : 1, a : (), b : (c_{1}, c_{2}, ..., c_{0}), c : (d), d : ()
# 21	instantiation	30, 31, 32	|- ((a_{1}, a_{2}, ..., a_{0}) = (c_{1}, c_{2}, ..., c_{0})) = TRUE
# 	x : (a_{1}, a_{2}, ..., a_{0}) = (c_{1}, c_{2}, ..., c_{0}), y : () = (), z : TRUE
# 22	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 23	instantiation	33, 34, 35	{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})) and (a_{m + 1} = b_{m + 1})
# 	A : (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}), B : a_{m + 1} = b_{m + 1}
# 24	instantiation	36, 75	{m in NaturalPos} |- ((a_{1}, a_{2}, ..., a_{m}, a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m}, b_{m + 1})) =  \\ (((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})) and (a_{m + 1} = b_{m + 1}))
# 	i : m, a : a, b : a_{m + 1}, c : b, d : b_{m + 1}
# 25	conjecture		|- forall_{f, i, j | |(f(i), f(i + 1), ..., f(j))| in Natural} ((f(i), f(i + 1), ..., f(j), f(j + 1)) = (f(i), f(i + 1), ..., f(j + 1)))
# 	proveit.core_expr_types.tuples.merge_extension
# 26	instantiation	74, 75	{m in NaturalPos} |- |(a_{1}, a_{2}, ..., a_{m})| in Natural
# 	i : m, f(_a) : a_{_a}
# 27	instantiation	66, 53	|- |(a_{1}, a_{2}, ..., a_{0})| = |(1, 2, ..., 0)|
# 	i : 0, f(_a) : a_{_a}
# 28	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}))]
# 	proveit.core_expr_types.tuples.tuple_portion_substitution
# 29	instantiation	66, 53	|- |(c_{1}, c_{2}, ..., c_{0})| = |(1, 2, ..., 0)|
# 	i : 0, f(_a) : c_{_a}
# 30	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 31	instantiation	37, 38, 39, 40, 41, 42	|- ((a_{1}, a_{2}, ..., a_{0}) = (c_{1}, c_{2}, ..., c_{0})) =  \\ (() = ())
# 	n : 2, f(_b, _c) : _b = _c, x : ((a_{1}, a_{2}, ..., a_{0}), (c_{1}, c_{2}, ..., c_{0})), y : ((), ())
# 32	instantiation	43, 44	|- (() = ()) = TRUE
# 	A : () = ()
# 33	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 34	instantiation	45, 46	{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})), m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
# 	a : a, b : b
# 35	instantiation	47, 75, 53, 55, 54, 56	{m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- a_{m + 1} = b_{m + 1}
# 	m : m, n : 0, A : ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})), B : a_{m + 1} = b_{m + 1}, C : ()
# 36	axiom		|- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{i}, d} (((a_{1}, a_{2}, ..., a_{i}, b) = (c_{1}, c_{2}, ..., c_{i}, d)) =  \\ (((a_{1}, a_{2}, ..., a_{i}) = (c_{1}, c_{2}, ..., c_{i})) and (b = d)))]
# 	proveit.core_expr_types.tuples.tuple_eq_def
# 37	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 38	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 39	instantiation	48	|- |((a_{1}, a_{2}, ..., a_{0}), (c_{1}, c_{2}, ..., c_{0}))| = |(1, ..., 2)|
# 	a : (a_{1}, a_{2}, ..., a_{0}), b : (c_{1}, c_{2}, ..., c_{0})
# 40	instantiation	48	|- |((), ())| = |(1, ..., 2)|
# 	a : (), b : ()
# 41	instantiation	49, 50	|- (a_{1}, a_{2}, ..., a_{0}) = ()
# 	f(_a) : a_{_a}, i : 1, j : 0
# 42	instantiation	49, 50	|- (c_{1}, c_{2}, ..., c_{0}) = ()
# 	f(_a) : c_{_a}, i : 1, j : 0
# 43	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 44	instantiation	51	|- () = ()
# 	x : ()
# 45	assumption		{forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} |- forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
# 46	instantiation	52, 53, 75, 82, 54, 55, 56	{m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
# 	l : 0, m : m, n : 1, A : (), B : ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})), C : (a_{m + 1} = b_{m + 1})
# 47	conjecture		|- forall_{m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, B, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{m}, B,C_{1}, C_{2}, ..., C_{n}} B]
# 	proveit.logic.booleans.conjunction.any_from_and
# 48	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 49	axiom		|- forall_{f, i, j | (j + 1) = i} ((f(i), f(i + 1), ..., f(j)) = ())
# 	proveit.core_expr_types.tuples.empty_range_def
# 50	instantiation	57, 58	|- (0 + 1) = 1
# 	a : 1
# 51	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 52	conjecture		|- forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m})]
# 	proveit.logic.booleans.conjunction.some_from_and
# 53	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 54	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 55	instantiation	66, 75	{m in NaturalPos} |- |((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))| = |(1, 2, ..., m)|
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 56	instantiation	59, 67, 60, 61, 62, 63	{m in NaturalPos,(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})
# 	n : m + 1, P(_b_{1}, _b_{2}, ..., _b_{m + 1}) : _b_{1} and  _b_{2} and  ... and  _b_{m + 1}, x : ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})), y : ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1})
# 57	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 58	instantiation	80, 64, 65	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 59	conjecture		|- forall_{n in Natural} [forall_{P, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | P(x_{1}, x_{2}, ..., x_{n}), (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands_via_tuple
# 60	instantiation	66, 67	{m in NaturalPos} |- |((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))| = |(1, 2, ..., (m + 1))|
# 	i : m + 1, f(_a) : a_{_a} = b_{_a}
# 61	instantiation	68, 75	{m in NaturalPos} |- |((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1})| = |(1, 2, ..., (m + 1))|
# 	f(_a) : a_{_a} = b_{_a}, x : a_{m + 1} = b_{m + 1}, i : m
# 62	assumption		{(a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} |- (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
# 63	instantiation	69, 70	{m in NaturalPos} |- ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})) =  \\ ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}), a_{m + 1} = b_{m + 1})
# 	f(_a) : a_{_a} = b_{_a}, i : 1, j : m
# 64	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 65	instantiation	80, 71, 72	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 66	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 67	instantiation	73, 75, 82	{m in NaturalPos} |- (m + 1) in Natural
# 	a : m, b : 1
# 68	conjecture		|- forall_{f, x} [forall_{i in Natural} (|(f(1), f(2), ..., f(i), x)| = |(1, 2, ..., (i + 1))|)]
# 	proveit.core_expr_types.tuples.extended_range_from1_len_typical_eq
# 69	axiom		|- forall_{f, i, j | |(f(i), f(i + 1), ..., f(j))| in Natural} ((f(i), f(i + 1), ..., f(j + 1)) =  \\ (f(i), f(i + 1), ..., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 70	instantiation	74, 75	{m in NaturalPos} |- |((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))| in Natural
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 71	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 72	instantiation	80, 76, 77	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 73	conjecture		|- forall_{a, b in Natural} ((a + b) in Natural)
# 	proveit.numbers.addition.add_nat_closure_bin
# 74	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| in Natural)]
# 	proveit.core_expr_types.tuples.range_from1_len_is_nat
# 75	instantiation	80, 78, 79	{m in NaturalPos} |- m in Natural
# 	A : NaturalPos, B : Natural, x : m
# 76	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 77	instantiation	80, 81, 82	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 78	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 79	assumption		{m in NaturalPos} |- m in NaturalPos
# 80	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 81	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 82	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
