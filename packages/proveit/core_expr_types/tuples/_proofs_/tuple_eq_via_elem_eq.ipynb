# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_context_.ipynb">tuples</a>.<a class="ProveItLink" href="../_theorems_.ipynb#tuple_eq_via_elem_eq">tuple_eq_via_elem_eq</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory
from proveit import defaults
from proveit._common_ import a, b, c, d, m
from proveit.core_expr_types.tuples._axioms_ import tuple_eq_def
from proveit.logic import And
from proveit.number import Add, zero, one
from proveit.number.sets.integer._theorems_ import natPosInduction

# %%
# %proving tuple_eq_via_elem_eq presuming [natPosInduction, proveit.logic.boolean.conjunction.unary_and_reduction, proveit.number.numeral.deci.add_0_1, proveit.logic.equality.subRightSideInto, proveit.logic.equality.sub_in_right_operands, proveit.number.sets.integer.natsPosInNats, proveit.logic.set_theory.containment.unfoldSubsetEq, proveit.logic.set_theory.containment.relaxSubset, proveit.number.addition.addNatClosureBin, proveit.number.numeral.deci.nat1, proveit.logic.boolean.conjunction.someFromAnd, proveit.core_expr_types.conditionals.singular_conjunction_condition_reduction]
# Out:
# Beginning proof of tuple_eq_via_elem_eq
# Recorded 'presuming' information
# Presuming proveit.core_expr_types.conditionals.singular_conjunction_condition_reduction, proveit.logic.boolean.conjunction.someFromAnd, proveit.logic.boolean.conjunction.unary_and_reduction, proveit.logic.equality.subRightSideInto, proveit.logic.equality.sub_in_right_operands, proveit.logic.set_theory.containment.relaxSubset, proveit.logic.set_theory.containment.unfoldSubsetEq, proveit.number.addition.addNatClosureBin, proveit.number.numeral.deci.add_0_1, proveit.number.numeral.deci.nat1, proveit.number.sets.integer.natPosInduction, proveit.number.sets.integer.natsPosInNats theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# tuple_eq_via_elem_eq: forall_{i in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]

# %% [markdown]
# ### Instantiate the induction theorem for an inductive proof.

# %%
tuple_eq_via_elem_eq.instanceExpr
# Out:
# forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))

# %%
natPosInduction
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])

# %%
from proveit import Function
from proveit._common_ import P, i
induction_inst = \
    natPosInduction.instantiate({Function(P, i):tuple_eq_via_elem_eq.instanceExpr}) \
        .innerExpr().withWrappingAt(1).innerExpr().antecedent.withWrappingAt(1)
# Out:
# induction_inst: |- ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# induction_base: forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))

# %%
a1, b1 = induction_base.instanceParams
# Out:
# a1: a_{1}
# b1: b_{1}

# %%
tuple_eq_def
# Out:
# |- forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]

# %%
tuple_eq_base = tuple_eq_def.instantiate({i:zero})
# Out:
# tuple_eq_base: |- forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))

# %%
tuple_eq_base_inst = tuple_eq_base.instantiate({b:a1, d:b1})
# Out:
# tuple_eq_base_inst: |- ((a_{1}) = (b_{1})) = ((() = ()) and (a_{1} = b_{1}))

# %%
tuple_eq_base_inst.rhs.prove(assumptions=induction_base.conditions)
# Out:
# {a_{1} = b_{1}} |- (() = ()) and (a_{1} = b_{1})

# %%
tuple_eq_base_inst.deriveLeftViaEquivalence(assumptions=induction_base.conditions)
# Out:
# {a_{1} = b_{1}} |- (a_{1}) = (b_{1})

# %%
induction_base.prove()
# Out:
# |- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1]
# Out:
# induction_step: forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]

# %%
eq_conds = induction_step.instanceExpr.explicitConditions()[0]
# Out:
# eq_conds: (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})

# %%
defaults.assumptions = (induction_step.conditions + [eq_conds])
# Out:
# defaults.assumptions: (m in NaturalsPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# induction_hyp: forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))

# %% [markdown]
# ***Splitting apart the conjunction of equality conditions is an important step***

# %%
eq_cond_partition = eq_conds.partition(m)
# Out:
# eq_cond_partition: {m in NaturalsPos} |- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction = And(eq_conds).prove()
# Out:
# eq_conds_conjunction: {a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction_partition = eq_cond_partition.subRightSideInto(eq_conds_conjunction)
# Out:
# eq_conds_conjunction_partition: {m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})

# %%
eq_conds_conjunction_partition.deriveSome(0)
# Out:
# {m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})

# %% [markdown]
# ***And now we will be able to prove the induction step by invoking the `tuple_eq_def` axiom***

# %%
last_eq = eq_conds_conjunction_partition.deriveAny(1)
# Out:
# last_eq: {m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- a_{m + 1} = b_{m + 1}

# %%
a_mp1, b_mp1 = last_eq.operands
# Out:
# a_mp1: a_{m + 1}
# b_mp1: b_{m + 1}

# %%
tuple_eq_def
# Out:
# |- forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]

# %%
tuple_eq_def_inst = tuple_eq_def.instantiate({i:m, c:b, b:a_mp1, d:b_mp1})
# Out:
# tuple_eq_def_inst: {m in NaturalsPos} |- ((a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})) = (((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}))

# %%
tuple_eq_def_inst.rhs.prove()
# Out:
# {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})

# %%
tuple_eq_split_both = tuple_eq_def_inst.deriveLeftViaEquivalence()
# Out:
# tuple_eq_split_both: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})

# %%
tuple_eq_split_right = tuple_eq_split_both.innerExpr().lhs.merge()
# Out:
# tuple_eq_split_right: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})

# %%
tuple_eq = tuple_eq_split_right.innerExpr().rhs.merge()
# Out:
# tuple_eq: {forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.deriveConsequent()
# Out:
# tuple_eq_via_elem_eq has been proven.  Now simply execute "%qed".
# |- forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]
# 1	instantiation	3, 4, 5, 6, 7*	|- ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]
# 	P(i) : forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))
# 2	instantiation	38, 8, 9	|- [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
# 	A : forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), B : forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
# 3	theorem		|- forall_{P} ((P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])
# 	proveit.number.sets.integer.natPosInduction
# 4	instantiation	10	|- (a_{1}, ..a_{_a}.., a_{1}) = (a_{1})
# 	f(_a) : a_{_a}, i : 1
# 5	instantiation	10	|- (b_{1}, ..b_{a}.., b_{1}) = (b_{1})
# 	f(_a) : b_{_a}, i : 1
# 6	instantiation	10	|- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}) = (a_{1} = b_{1})
# 	f(k) : a_{k} = b_{k}, i : 1
# 7	instantiation	11, 12	|- [and](a_{1} = b_{1}) = (a_{1} = b_{1})
# 	A : a_{1} = b_{1}
# 8	generalizaton	13	|- forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
# 9	generalizaton	14	|- forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]
# 10	theorem		|- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))
# 	proveit.core_expr_types.tuples.singular_range_reduction
# 11	theorem		|- forall_{A in BOOLEANS} ([and](A) = A)
# 	proveit.logic.boolean.conjunction.unary_and_reduction
# 12	instantiation	15	|- (a_{1} = b_{1}) in BOOLEANS
# 	x : a_{1}, y : b_{1}
# 13	instantiation	30, 16, 17	{a_{1} = b_{1}} |- (a_{1}) = (b_{1})
# 	P : (a_{1}) = (b_{1}), Q : (() = ()) and (a_{1} = b_{1})
# 14	instantiation	23, 18, 19	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
# 	P(_b) : (a_{1}, ..a_{_a}.., a_{m + 1}) = _b, x : (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), y : (b_{1}, ..b_{a}.., b_{m + 1})
# 15	axiom		|- forall_{x, y} ((x = y) in BOOLEANS)
# 	proveit.logic.equality.equalityInBool
# 16	instantiation	38, 20, 21	{a_{1} = b_{1}} |- (() = ()) and (a_{1} = b_{1})
# 	A : () = (), B : a_{1} = b_{1}
# 17	instantiation	22	|- ((a_{1}) = (b_{1})) = ((() = ()) and (a_{1} = b_{1}))
# 	b : a_{1}, d : b_{1}
# 18	instantiation	23, 24, 25	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
# 	P(_b) : _b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), x : (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), y : (a_{1}, ..a_{_a}.., a_{m + 1})
# 19	instantiation	33, 26	{m in NaturalsPos} |- (b_{1}, ..b_{a}.., b_{m}, b_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
# 	f(_a) : b_{_a}, i : 1, j : m
# 20	instantiation	27	|- () = ()
# 	x : ()
# 21	assumption		{a_{1} = b_{1}} |- a_{1} = b_{1}
# 22	instantiation	41, 47, 28, 29	|- forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))
# 	i : 0
# 23	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.subRightSideInto
# 24	instantiation	30, 31, 32	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
# 	P : (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}), Q : ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})
# 25	instantiation	33, 34	{m in NaturalsPos} |- (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (a_{1}, ..a_{_a}.., a_{m + 1})
# 	f(_a) : a_{_a}, i : 1, j : m
# 26	instantiation	65, 68, 35	{m in NaturalsPos} |- |(b_{1}, ..b_{a}.., b_{m})| in Naturals
# 	P(_a) : _a in Naturals, x : |(b_{1}, ..b_{a}.., b_{m})|, y : m
# 27	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equalsReflexivity
# 28	instantiation	36, 37	|- (a_{1}, ..a_{_a}.., a_{0}) = ()
# 	f(_a) : a_{_a}, i : 1, j : 0
# 29	instantiation	36, 37	|- (c_{1}, ..c_{a}.., c_{0}) = ()
# 	f(_a) : c_{_a}, i : 1, j : 0
# 30	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhsViaEquivalence
# 31	instantiation	38, 39, 40	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1})
# 	A : (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}), B : a_{m + 1} = b_{m + 1}
# 32	instantiation	41, 68	{m in NaturalsPos} |- ((a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})) = (((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})) and (a_{m + 1} = b_{m + 1}))
# 	i : m, a : a, b : a_{m + 1}, c : b, d : b_{m + 1}
# 33	theorem		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j), f(j + 1)) = (f(i), ..f(a).., f(j + 1)))
# 	proveit.core_expr_types.tuples.merge_extension
# 34	instantiation	65, 68, 42	{m in NaturalsPos} |- |(a_{1}, ..a_{_a}.., a_{m})| in Naturals
# 	P(_a) : _a in Naturals, x : |(a_{1}, ..a_{_a}.., a_{m})|, y : m
# 35	instantiation	67, 68	{m in NaturalsPos} |- |(b_{1}, ..b_{a}.., b_{m})| = m
# 	i : m, f(a) : b_{a}
# 36	axiom		|- forall_{f, i, j | (j + 1) = i} ((f(i), ..f(a).., f(j)) = ())
# 	proveit.core_expr_types.tuples.empty_range_def
# 37	theorem		|- (0 + 1) = 1
# 	proveit.number.numeral.deci.add_0_1
# 38	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.boolean.conjunction.andIfBoth
# 39	instantiation	43, 44	{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})), m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
# 	a : a, b : b
# 40	instantiation	45, 68, 47, 49, 48, 51	{m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- a_{m + 1} = b_{m + 1}
# 	m : m, n : 0, A : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}), B : a_{m + 1} = b_{m + 1}, C : ()
# 41	axiom		|- forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]
# 	proveit.core_expr_types.tuples.tuple_eq_def
# 42	instantiation	67, 68	{m in NaturalsPos} |- |(a_{1}, ..a_{_a}.., a_{m})| = m
# 	i : m, f(_a) : a_{_a}
# 43	assumption		{forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} |- forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
# 44	instantiation	46, 47, 68, 64, 48, 49, 50, 51	{m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m})
# 	l : 0, m : m, n : 1, A : (), B : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}), C : (a_{m + 1} = b_{m + 1})
# 45	theorem		|- forall_{m in Naturals, n in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B]
# 	proveit.logic.boolean.conjunction.anyFromAnd
# 46	theorem		|- forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}} (B_{1} and ..B_{_a}.. and B_{m})]
# 	proveit.logic.boolean.conjunction.someFromAnd
# 47	theorem		|- 0 in Naturals
# 	proveit.number.sets.integer.zeroInNats
# 48	theorem		|- |()| = |(1, ..a.., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_equiv
# 49	instantiation	58, 68	{m in NaturalsPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = |(1, ..k.., m)|
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 50	instantiation	52	|- |(a_{m + 1} = b_{m + 1})| = |(1, ..k.., 1)|
# 	a : a_{m + 1} = b_{m + 1}
# 51	instantiation	53, 59, 54, 55, 56, 57	{m in NaturalsPos, a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{_a} = b_{_a}).. and (a_{m} = b_{m}) and (a_{m + 1} = b_{m + 1})
# 	n : m + 1, P(_a_{1}, .._a_{_b}.., _a_{m + 1}) : _a_{1} and .._a_{_b}.. and _a_{m + 1}, x : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}), y : (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})
# 52	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 53	theorem		|- forall_{n in Naturals} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands
# 54	instantiation	58, 59	{m in NaturalsPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1})| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(_a) : a_{_a} = b_{_a}
# 55	instantiation	60, 68	{m in NaturalsPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})| = |(1, ..k.., m + 1)|
# 	f(_a) : a_{_a} = b_{_a}, b : a_{m + 1} = b_{m + 1}, i : m
# 56	assumption		{a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} |- (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
# 57	instantiation	61, 62	{m in NaturalsPos} |- (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m}, a_{m + 1} = b_{m + 1})
# 	f(k) : a_{k} = b_{k}, i : 1, j : m
# 58	theorem		|- forall_{i in Naturals} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_equiv
# 59	instantiation	63, 68, 64	{m in NaturalsPos} |- (m + 1) in Naturals
# 	a : m, b : 1
# 60	theorem		|- forall_{f, b} [forall_{i in Naturals} (|(f(1), ..f(a).., f(i), b)| = |(1, ..k.., i + 1)|)]
# 	proveit.core_expr_types.tuples.extended_range_from1_len_typical_equiv
# 61	axiom		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 62	instantiation	65, 68, 66	{m in NaturalsPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| in Naturals
# 	P(_a) : _a in Naturals, x : |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})|, y : m
# 63	theorem		|- forall_{a in Naturals, b in Naturals} ((a + b) in Naturals)
# 	proveit.number.addition.addNatClosureBin
# 64	theorem		|- 1 in Naturals
# 	proveit.number.numeral.deci.nat1
# 65	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.subLeftSideInto
# 66	instantiation	67, 68	{m in NaturalsPos} |- |(a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{m} = b_{m})| = m
# 	i : m, f(_a) : a_{_a} = b_{_a}
# 67	theorem		|- forall_{i in Naturals} [forall_{f} (|(f(1), ..f(a).., f(i))| = i)]
# 	proveit.core_expr_types.tuples.range_from1_len
# 68	instantiation	69, 70, 71	{m in NaturalsPos} |- m in Naturals
# 	A : NaturalsPos, B : Naturals, x : m
# 69	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 70	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 71	assumption		{m in NaturalsPos} |- m in NaturalsPos
