# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_context_.ipynb">tuples</a>.<a class="ProveItLink" href="../_theorems_.ipynb#extended_range_len_typical_equiv">extended_range_len_typical_equiv</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving extended_range_len_typical_equiv presuming []
# Out:
# Beginning proof of extended_range_len_typical_equiv
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# extended_range_len_typical_equiv: forall_{f} [forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)]
