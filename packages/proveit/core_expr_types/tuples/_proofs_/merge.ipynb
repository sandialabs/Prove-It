# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_context_.ipynb">tuples</a>.<a class="ProveItLink" href="../_theorems_.ipynb#merge">merge</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving merge presuming []
# Out:
# Beginning proof of merge
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# merge: forall_{f, i, j, k, l | (k - i) in Naturals, (l - j) in Naturals, k = (j + 1)} ((f(i), ..f(a).., f(j), f(k), ..f(a).., f(l)) =  \\ (f(i), ..f(a).., f(l)))
