# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_context_.ipynb">tuples</a>.<a class="ProveItLink" href="../_theorems_.ipynb#partition_back">partition_back</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving partition_back presuming []
# Out:
# Beginning proof of partition_back
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# partition_back: forall_{f, i, j | (j - i) in Naturals} ((f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)))
