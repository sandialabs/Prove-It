# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import f, i, j
from proveit.core_expr_types._common_ import merge_series_conditions, merge_series_equiv, x_0_to_jmi
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j], Conditional(Forall([x_0_to_jmi], merge_series_equiv, condition = merge_series_conditions), InSet(Add(j, Neg(i)), Naturals)))
# Out:
# expr: (f, i, j) -> {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j\right) \mapsto \left\{\forall_{x_{0}, \ldots, x_{j - i}~|~x_{0} = f(i + 0), \ldots, x_{j - i} = f(i + \left(j - i\right))}~\left(\begin{array}{c} \left(x_{0}, \ldots, x_{j - i}\right) =  \\ \left(f(i), \ldots, f(j)\right) \end{array}\right) \textrm{ if } \left(j - i\right) \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j) -> {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 39, 43, 32
# 2. {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (j - i) in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
