# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, a, f, fa, i, j
from proveit.core_expr_types import f_i_to_jp1
from proveit.logic import Equals
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals([f_i_to_jp1], [Function(f, i), ExprRange(a, fa, Add(i, one), Add(j, one))])
# Out:
# expr: (f(i), ..f(a).., f(j + 1)) = (f(i), f(i + 1), ..f(a).., f(j + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f(i), \ldots, f(j + 1)\right) = \left(f(i), f(i + 1), \ldots, f(j + 1)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f(i), ..f(a).., f(j + 1)) = (f(i), f(i + 1), ..f(a).., f(j + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i), ..f(a).., f(j + 1)), (f(i), f(i + 1), ..f(a).., f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i), ..f(a).., f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(i), f(i + 1), ..f(a).., f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. f(i), ..f(a).., f(j + 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 17
#    end_index: 10
# 6. f(i)
#    core type: Operation
#    operator: 15
#    operand: 17
# 7. f(i + 1), ..f(a).., f(j + 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. a -> f(a)
#    core type: Lambda
#    parameter: 16
#    body: 11
# 9. i + 1
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. j + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. f(a)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. f
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. j
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
