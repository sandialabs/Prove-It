# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, k, x
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([ExprRange(k, ExprRange(x, IndexedVar(a, [k, x]), one, one), one, one)])
# Out:
# expr: ((a_{1, 1}, ..a_{1, x}.., a_{1, 1}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 1}...., a_{1, 1}, ..a_{1, x}.., a_{1, 1}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1, 1}, \ldots, a_{1, 1}, \ldots\ldots, a_{1, 1}, \ldots, a_{1, 1}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1, 1}, ..a_{1, x}.., a_{1, 1}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 1}...., a_{1, 1}, ..a_{1, x}.., a_{1, 1}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1, 1}, ..a_{1, x}.., a_{1, 1}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 1}...., a_{1, 1}, ..a_{1, x}.., a_{1, 1})
#    core type: ExprTuple
#    sub-expressions: 2
# 2. a_{1, 1}, ..a_{1, x}.., a_{1, 1}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 1}...., a_{1, 1}, ..a_{1, x}.., a_{1, 1}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 6
# 3. k -> a_{k, 1}, ..a_{k, x}.., a_{k, 1}
#    core type: Lambda
#    parameter: 10
#    body: 4
# 4. a_{k, 1}, ..a_{k, x}.., a_{k, 1}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 6
# 5. x -> a_{k, x}
#    core type: Lambda
#    parameter: 11
#    body: 7
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. a_{k, x}
#    core type: IndexedVar
# variable: 8
# indices: 9
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. (k, x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
