# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import j
from proveit.logic import Equals
from proveit.numbers import Add, Neg, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(two)
expr = Equals(Add(Add(j, sub_expr1), two), Add(j, sub_expr1, two).with_subtraction_at())
# Out:
# expr: ((j - 2) + 2) = (j + (-2) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j - 2\right) + 2\right) = \left(j + \left(-2\right) + 2\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((j - 2) + 2) = (j + (-2) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((j - 2) + 2, j + (-2) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (j - 2) + 2
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. j + (-2) + 2
#    core type: Operation
#    operator: 8
#    operands: 6
# 5. (j - 2, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 13
# 6. (j, -2, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 13
# 7. j - 2
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (j, -2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. j
#     core type: Variable
#     sub-expressions:
# 11. -2
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
