# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable, a, j
from proveit.core_expr_types import Len
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Len([ExprRange(sub_expr1, Lambda(j, IndexedVar(a, [sub_expr1, j])), one, one)])
# Out:
# expr: |(j -> a_{1, j}, ..j -> a_{_a, j}.., j -> a_{1, j})|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(j \mapsto a_{1, j}, \ldots, j \mapsto a_{1, j}\right)|

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(j -> a_{1, j}, ..j -> a_{_a, j}.., j -> a_{1, j})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((j -> a_{1, j}, ..j -> a_{_a, j}.., j -> a_{1, j}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (j -> a_{1, j}, ..j -> a_{_a, j}.., j -> a_{1, j})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. [j -> a_{1, j}], ..[j -> a_{_a, j}].., [j -> a_{1, j}]
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 6
# 5. _a -> [j -> a_{_a, j}]
#    core type: Lambda
#    parameter: 11
#    body: 7
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. j -> a_{_a, j}
#    core type: Lambda
#    parameter: 12
#    body: 8
# 8. a_{_a, j}
#    core type: IndexedVar
# variable: 9
# indices: 10
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. (_a, j)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. j
#     core type: Variable
#     sub-expressions:
