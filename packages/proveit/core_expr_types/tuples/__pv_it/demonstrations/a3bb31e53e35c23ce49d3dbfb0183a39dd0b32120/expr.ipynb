# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, k, n, x
from proveit.core_expr_types import Len
from proveit.numbers import one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(k, ExprRange(x, IndexedVar(a, [k, x]), one, zero), one, n)]), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: (|(a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})|, _a)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{1, 1}, \ldots, a_{1, 0}, \ldots\ldots, a_{n, 1}, \ldots, a_{n, 0}\right)|, {_{-}a}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})|, _a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})|
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. _a
#    core type: Variable
#    sub-expressions:
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0}))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0})
#    core type: ExprTuple
#    sub-expressions: 6
# 6. a_{1, 1}, ..a_{1, x}.., a_{1, 0}, ....a_{k, 1}, ..a_{k, x}.., a_{k, 0}...., a_{n, 1}, ..a_{n, x}.., a_{n, 0}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 11
#    end_index: 8
# ...
