# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, k, l
from proveit.core_expr_types import Len
from proveit.numbers import one, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(k, ExprRange(l, IndexedVar(a, [k, l]), one, zero), two, one)]), zero)
# Out:
# expr: (|(a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0})|, 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{2, 1}, \ldots, a_{2, 0}, \ldots\ldots, a_{1, 1}, \ldots, a_{1, 0}\right)|, 0\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0})|, 0)
#    core type: ExprTuple
#    sub-expressions: 1, 11
# 1. |(a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0})|
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. length
#    core type: Literal
#    sub-expressions:
# 3. ((a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0}))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0})
#    core type: ExprTuple
#    sub-expressions: 5
# 5. a_{2, 1}, ..a_{2, l}.., a_{2, 0}, ....a_{k, 1}, ..a_{k, l}.., a_{k, 0}...., a_{1, 1}, ..a_{1, l}.., a_{1, 0}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 10
# 6. k -> a_{k, 1}, ..a_{k, l}.., a_{k, 0}
#    core type: Lambda
#    parameter: 15
#    body: 8
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. a_{k, 1}, ..a_{k, l}.., a_{k, 0}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. l -> a_{k, l}
#    core type: Lambda
#    parameter: 16
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. a_{k, l}
#     core type: IndexedVar
# variable: 13
# indices: 14
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. (k, l)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. l
#     core type: Variable
#     sub-expressions:
