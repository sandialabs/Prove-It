# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(Add(i, Neg(one)), one), Add(Add(i, Neg(two)).with_subtraction_at(), two))
# Out:
# expr: ((i - 1) + 1) = ((i + (-2)) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(i - 1\right) + 1\right) = \left(\left(i + \left(-2\right)\right) + 2\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((i - 1) + 1) = ((i + (-2)) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((i - 1) + 1, (i + (-2)) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (i - 1) + 1
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (i + (-2)) + 2
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (i - 1, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 6. (i + (-2), 2)
#    core type: ExprTuple
#    sub-expressions: 8, 17
# 7. i - 1
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. i + (-2)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (i, -1)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (i, -2)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. -1
#     core type: Operation
#     operator: 16
#     operand: 15
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. -2
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
