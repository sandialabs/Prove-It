# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, Variable, f, i, j, k
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Neg(one)
sub_expr3 = Neg(two)
expr = Equals([ExprRange(k, Function(f, Add(k, one)), Add(i, sub_expr2), Add(j, sub_expr2))], [ExprRange(sub_expr1, Function(f, Add(sub_expr1, two)), Add(i, sub_expr3).with_subtraction_at(), Add(j, sub_expr3).with_subtraction_at())])
# Out:
# expr: (f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)) = (f((i + (-2)) + 2), ..f(_a + 2).., f((j + (-2)) + 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f(\left(i - 1\right) + 1), \ldots, f(\left(j - 1\right) + 1)\right) = \left(f(\left(i + \left(-2\right)\right) + 2), \ldots, f(\left(j + \left(-2\right)\right) + 2)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)) = (f((i + (-2)) + 2), ..f(_a + 2).., f((j + (-2)) + 2))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)), (f((i + (-2)) + 2), ..f(_a + 2).., f((j + (-2)) + 2)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f((i + (-2)) + 2), ..f(_a + 2).., f((j + (-2)) + 2))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 6. f((i + (-2)) + 2), ..f(_a + 2).., f((j + (-2)) + 2)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 7. k -> f(k + 1)
#    core type: Lambda
#    parameter: 30
#    body: 13
# 8. i - 1
#    core type: Operation
#    operator: 27
# ...
