# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit._common_ import a, b, k, m
from proveit.logic import And, Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Conditional(Equals([ExprRange(subExpr1, IndexedVar(a, subExpr1), one, m)], [ExprRange(subExpr1, IndexedVar(b, subExpr1), one, m)]), And(ExprRange(k, Equals(IndexedVar(a, k), IndexedVar(b, k)), one, m)))
# Out:
# expr: {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right) \textrm{ if } \left(a_{1} = b_{1}\right) \land \ldots \land \left(a_{m} = b_{m}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. (a_{1}, ..a_{_a}.., a_{m})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (b_{1}, ..b_{_a}.., b_{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 14
# ...
