# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar, Lambda, Variable
from proveit._common_ import a
from proveit.logic import InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Lambda(subExpr1, InSet(IndexedVar(a, subExpr1), Complexes))
# Out:
# expr: _a -> (a_{_a} in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \mapsto \left(a_{{_{-}a}} \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _a -> (a_{_a} in Complexes)
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. a_{_a} in Complexes
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. in
#    core type: Literal
#    sub-expressions:
# 3. (a_{_a}, Complexes)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. a_{_a}
#    core type: IndexedVar
# variable: 6
# index: 7
# 5. Complexes
#    core type: Literal
#    sub-expressions:
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. _a
#    core type: Variable
#    sub-expressions:
