# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda
from proveit._common_ import a, b, f, i, j, k, l
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j, k, l], Conditional(Equals([ExprRange(k, Function(f, Add(k, a)), i, j)], [ExprRange(i, Function(f, Add(i, b)), k, l)]), And(InSet(Add(Add(j, one), Neg(i)), Naturals), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b)))))
# Out:
# expr: (i, j, k, l) -> {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Naturals ,  (i + a) = (k + b) ,  (j + a) = (l + b).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j, k, l\right) \mapsto \left\{\left(f(i + a), \ldots, f(j + a)\right) = \left(f(k + b), \ldots, f(l + b)\right) \textrm{ if } \left(\left(j + 1\right) - i\right) \in \mathbb{N} ,  \left(i + a\right) = \left(k + b\right) ,  \left(j + a\right) = \left(l + b\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (i, j, k, l) -> {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Naturals ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 48, 50, 46, 40
# 2. {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Naturals ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (((j + 1) - i) in Naturals) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i + a), ..f(k + a).., f(j + a)), (f(k + b), ..f(i + b).., f(l + b)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# ...
