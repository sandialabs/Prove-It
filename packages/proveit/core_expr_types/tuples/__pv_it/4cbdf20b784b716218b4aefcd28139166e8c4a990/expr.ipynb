# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda
from proveit._common_ import a, f, i, j, k, l
from proveit.core_expr_types._common_ import f_i_to_j
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Integers, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(a)
expr = Lambda(a, Conditional(Forall([i, j, k, l], Equals([f_i_to_j], [ExprRange(i, Function(f, Add(i, a)), k, l)]), conditions = [InSet(Add(Add(j, one), Neg(i)), Naturals), Equals(k, Add(i, subExpr1)), Equals(l, Add(j, subExpr1))]), InSet(a, Integers)))
# Out:
# expr: a -> {forall_{i, j, k, l | ((j + 1) - i) in Naturals, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f(i), \ldots, f(j)\right) = \left(f(k + a), \ldots, f(l + a)\right)\right) \textrm{ if } a \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> {forall_{i, j, k, l | ((j + 1) - i) in Naturals, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integers.
#    core type: Lambda
#    parameter: 50
#    body: 1
# 1. {forall_{i, j, k, l | ((j + 1) - i) in Naturals, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))) if a in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{i, j, k, l | ((j + 1) - i) in Naturals, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. a in Integers
#    core type: Operation
#    operator: 22
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Naturals ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (a, Integers)
# ...
