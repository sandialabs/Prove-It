# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, fa, j, k
from proveit.core_expr_types._common_ import f_i_to_jp1, f_i_to_k
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([f_i_to_jp1], [f_i_to_k, ExprRange(a, fa, Add(k, one), Add(j, one))])
# Out:
# expr: ((f(i), ..f(a).., f(j + 1)), (f(i), ..f(a).., f(k), f(k + 1), ..f(a).., f(j + 1)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f(i), \ldots, f(j + 1)\right), \left(f(i), \ldots, f(k), f(k + 1), \ldots, f(j + 1)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((f(i), ..f(a).., f(j + 1)), (f(i), ..f(a).., f(k), f(k + 1), ..f(a).., f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (f(i), ..f(a).., f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (f(i), ..f(a).., f(k), f(k + 1), ..f(a).., f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. f(i), ..f(a).., f(j + 1)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 6
#    end_index: 9
# 4. f(i), ..f(a).., f(k)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 6
#    end_index: 16
# 5. f(k + 1), ..f(a).., f(j + 1)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. a -> f(a)
#    core type: Lambda
#    parameter: 15
#    body: 10
# 8. k + 1
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. j + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. f(a)
#     core type: Operation
#     operator: 14
#     operand: 15
# 11. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. j
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
