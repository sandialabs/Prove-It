# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#partition">partition</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import partition

# %%
# check that the built expression is the same as the stored expression
# %check_expr partition
# Out:
# Passed sanity check: built 'partition' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(partition.latex())
# Out:
# \vdash \forall_{f, i, j, k~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(k - j\right) \in \mathbb{N}}~\left(\begin{array}{c} \left(f(i), \ldots, f(k)\right) =  \\ \left(f(i), \ldots, f(j), f(j + 1), \ldots, f(k)\right) \end{array}\right)

# %%
# display the expression information
partition.exprInfo()
# Out:
# 0. forall_{f, i, j, k | ((j + 1) - i) in Naturals, (k - j) in Naturals} ((f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j, k) -> {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Naturals ,  (k - j) in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 28, 36, 38, 32
# 4. {(f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)) if ((j + 1) - i) in Naturals ,  (k - j) in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i), ..f(a).., f(k)) =  \\ (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (((j + 1) - i) in Naturals) and ((k - j) in Naturals)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((f(i), ..f(a).., f(k)), (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (((j + 1) - i) in Naturals, (k - j) in Naturals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i), ..f(a).., f(k))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (f(i), ..f(a).., f(j), f(j + 1), ..f(a).., f(k))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. ((j + 1) - i) in Naturals
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. (k - j) in Naturals
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 32
# 16. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 38
# 17. f(j + 1), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 30
#     end_index: 32
# 18. ((j + 1) - i, Naturals)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k - j, Naturals)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a -> f(a)
#     core type: Lambda
#     parameter: 29
#     body: 25
# 22. (j + 1) - i
#     core type: Operation
#     operator: 34
#     operands: 26
# 23. k - j
#     core type: Operation
#     operator: 34
#     operands: 27
# 24. Naturals
#     core type: Literal
#     sub-expressions:
# 25. f(a)
#     core type: Operation
#     operator: 28
#     operand: 29
# 26. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. j + 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. -i
#     core type: Operation
#     operator: 37
#     operand: 36
# 32. k
#     core type: Variable
#     sub-expressions:
# 33. -j
#     core type: Operation
#     operator: 37
#     operand: 38
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. -
#     core type: Literal
#     sub-expressions:
# 38. j
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
