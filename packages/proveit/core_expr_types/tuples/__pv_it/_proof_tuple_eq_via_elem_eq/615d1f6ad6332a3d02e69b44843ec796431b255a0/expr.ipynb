# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, m
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = Add(m, one)
sub_expr4 = IndexedVar(b, sub_expr1)
sub_expr5 = ExprRange(sub_expr1, sub_expr2, one, sub_expr3)
sub_expr6 = ExprRange(sub_expr1, sub_expr4, one, sub_expr3)
sub_expr7 = Equals(sub_expr2, sub_expr4)
sub_expr8 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr9 = ExprRange(sub_expr1, sub_expr4, one, m)
expr = ExprTuple(Lambda(m, Conditional(Forall(instance_param_or_params = [sub_expr5, sub_expr6], instance_expr = Equals([sub_expr5], [sub_expr6]), condition = ExprRange(sub_expr1, sub_expr7, one, sub_expr3)), And(InSet(m, NaturalPos), Forall(instance_param_or_params = [sub_expr8, sub_expr9], instance_expr = Equals([sub_expr8], [sub_expr9]), condition = ExprRange(sub_expr1, sub_expr7, one, m))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{m + 1}, b_{1}, b_{2}, \ldots, b_{m + 1}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m + 1} = b_{m + 1}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m + 1}\right) = \left(b_{1}, b_{2}, \ldots, b_{m + 1}\right)\right) \textrm{ if } m \in \mathbb{N}^+ ,  \forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{m}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m} = b_{m}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m}\right) = \left(b_{1}, b_{2}, \ldots, b_{m}\right)\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Lambda
#    parameter: 47
#    body: 3
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 47
# 3. {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))
#    core type: Operation
#    operator: 15
#    operand: 8
# 5. (m in NaturalPos) and [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))]
#    core type: Operation
#    operator: 33
#    operands: 7
# 6. ((a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m in NaturalPos, forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 9. m in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
#     core type: Operation
#     operator: 15
#     operand: 20
# 11. (a_{1}, a_{2}, ..., a_{m + 1},b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 12. {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 47, 19
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: Operation
#     operator: 49
#     operands: 21
# 18. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 33
#     operands: 22
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 21. ((a_{1}, a_{2}, ..., a_{m + 1}), (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 24. {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (a_{1}, a_{2}, ..., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 31
# 27. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 35
# 28. (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
#     core type: Operation
#     operator: 49
#     operands: 32
# 29. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. a_{1}, a_{2}, ..., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 35
# 31. b_{1}, b_{2}, ..., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 35
# 32. ((a_{1}, a_{2}, ..., a_{m}), (b_{1}, b_{2}, ..., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))
#     core type: ExprTuple
#     sub-expressions: 38
# 35. m + 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 47
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 41. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 47
# 42. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 43. _a -> (a_{_a} = b_{_a})
#     core type: Lambda
#     parameter: 56
#     body: 48
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 51
# 45. _a -> b_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. m
#     core type: Variable
#     sub-expressions:
# 48. a_{_a} = b_{_a}
#     core type: Operation
#     operator: 49
#     operands: 50
# 49. =
#     core type: Literal
#     sub-expressions:
# 50. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 52. b_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
