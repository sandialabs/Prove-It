# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = IndexedVar(b, sub_expr1)
sub_expr4 = Add(m, one)
sub_expr5 = ExprRange(sub_expr1, sub_expr2, one, sub_expr4)
sub_expr6 = ExprRange(sub_expr1, sub_expr3, one, sub_expr4)
sub_expr7 = Equals(IndexedVar(a, k), IndexedVar(b, k))
sub_expr8 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr9 = ExprRange(sub_expr1, sub_expr3, one, m)
expr = Forall([m], Forall([sub_expr5, sub_expr6], Equals([sub_expr5], [sub_expr6]), condition = ExprRange(k, sub_expr7, one, sub_expr4)), domains = [NaturalPos], condition = Forall([sub_expr8, sub_expr9], Equals([sub_expr8], [sub_expr9]), condition = ExprRange(k, sub_expr7, one, m)))
# Out:
# expr: forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Lambda
#    parameter: 44
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))
#    core type: Operation
#    operator: 15
#    operand: 5
# 4. (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
#    core type: Operation
#    operator: 30
#    operands: 6
# 5. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 27, 28
# 8. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. m in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#     core type: Operation
#     operator: 15
#     operand: 16
# 11. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: Operation
#     operator: 48
#     operands: 17
# 12. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 30
#     operands: 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 44, 19
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 17. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 21. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. (a_{1}, ..a_{_a}.., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 43
#     end_index: 32
# 25. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 48
#     operands: 29
# 26. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. a_{1}, ..a_{_a}.., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 43
#     end_index: 32
# 28. b_{1}, ..b_{_a}.., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 32
# 29. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. m + 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 43
#     end_index: 44
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 43
# 38. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 43
#     end_index: 44
# 39. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 40. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 55
#     body: 45
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 46
# 42. _a -> b_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 47
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. a_{k} = b_{k}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. a_{_a}
#     core type: IndexedVar
# variable: 53
# index: 50
# 47. b_{_a}
#     core type: IndexedVar
# variable: 54
# index: 50
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. _a
#     core type: Variable
#     sub-expressions:
# 51. a_{k}
#     core type: IndexedVar
# variable: 53
# index: 55
# 52. b_{k}
#     core type: IndexedVar
# variable: 54
# index: 55
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. k
#     core type: Variable
#     sub-expressions:
