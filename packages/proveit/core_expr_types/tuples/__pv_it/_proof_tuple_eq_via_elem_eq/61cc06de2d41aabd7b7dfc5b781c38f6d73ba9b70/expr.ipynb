# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, m
from proveit.logic import Equals
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = Add(m, one)
expr = Equals([ExprRange(sub_expr1, sub_expr2, one, m), IndexedVar(a, sub_expr3)], [ExprRange(sub_expr1, sub_expr2, one, sub_expr3)])
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (a_{1}, ..a_{_a}.., a_{m + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, a_{m + 1}\right) = \left(a_{1}, \ldots, a_{m + 1}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}) = (a_{1}, ..a_{_a}.., a_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{m}, a_{m + 1}), (a_{1}, ..a_{_a}.., a_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1}, ..a_{_a}.., a_{m}, a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (a_{1}, ..a_{_a}.., a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. a_{1}, ..a_{_a}.., a_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 16
#    end_index: 15
# 6. a_{m + 1}
#    core type: IndexedVar
# variable: 13
# index: 9
# 7. a_{1}, ..a_{_a}.., a_{m + 1}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 16
#    end_index: 9
# 8. _a -> a_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 10
# 9. m + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. a_{_a}
#     core type: IndexedVar
# variable: 13
# index: 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. _a
#     core type: Variable
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
