# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, m
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = Add(m, one)
sub_expr6 = IndexedVar(b, sub_expr1)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, sub_expr5)
sub_expr8 = ExprRange(sub_expr1, sub_expr6, one, sub_expr5)
sub_expr9 = Equals(sub_expr4, sub_expr6)
sub_expr10 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr11 = ExprRange(sub_expr1, sub_expr6, one, m)
expr = And(Forall(instance_param_or_params = [sub_expr2, sub_expr3], instance_expr = Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [sub_expr7, sub_expr8], instance_expr = Equals([sub_expr7], [sub_expr8]), condition = ExprRange(sub_expr1, sub_expr9, one, sub_expr5)), domain = NaturalPos, condition = Forall(instance_param_or_params = [sub_expr10, sub_expr11], instance_expr = Equals([sub_expr10], [sub_expr11]), condition = ExprRange(sub_expr1, sub_expr9, one, m))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right)\right] \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{m}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m} = b_{m}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m}\right) = \left(b_{1}, b_{2}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{m + 1}, b_{1}, b_{2}, \ldots, b_{m + 1}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m + 1} = b_{m + 1}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m + 1}\right) = \left(b_{1}, b_{2}, \ldots, b_{m + 1}\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] and [forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]]
#    core type: Operation
#    operator: 49
#    operands: 1
# 1. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 30
#    operand: 6
# 3. forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]
#    core type: Operation
#    operator: 30
#    operand: 7
# 4. ((a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Lambda
#    parameters: 16\n   body: 8
# 7. m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Lambda
#    parameter: 63
#    body: 10
# 8. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. (m)
#    core type: ExprTuple
#    sub-expressions: 63
# 10. {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a_{1}) = (b_{1})
#     core type: Operation
#     operator: 65
#     operands: 15
# 12. a_{1} = b_{1}
#     core type: Operation
#     operator: 65
#     operands: 16
# 13. forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: Operation
#     operator: 30
#     operand: 21
# 14. (m in NaturalPos) and [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))]
#     core type: Operation
#     operator: 49
#     operands: 18
# 15. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 17. ((a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (m in NaturalPos, forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 24
# 20. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 25
# 21. (a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 26\n    body: 27
# 22. m in NaturalPos
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
#     core type: Operation
#     operator: 30
#     operand: 36
# 24. a_{1}
#     core type: IndexedVar
# variable: 69
# index: 62
# 25. b_{1}
#     core type: IndexedVar
# variable: 70
# index: 62
# 26. (a_{1}, a_{2}, ..., a_{m + 1},b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 27. {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 63, 35
# 30. forall
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 36
# 32. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 33. (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: Operation
#     operator: 65
#     operands: 37
# 34. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 49
#     operands: 38
# 35. NaturalPos
#     core type: Literal
#     sub-expressions:
# 36. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 39\n    body: 40
# 37. ((a_{1}, a_{2}, ..., a_{m + 1}), (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 43
# 39. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 40. {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Conditional
#     value: 44
#     condition: 45
# 41. (a_{1}, a_{2}, ..., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 47
# 43. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 62
#     end_index: 51
# 44. (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
#     core type: Operation
#     operator: 65
#     operands: 48
# 45. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. a_{1}, a_{2}, ..., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 62
#     end_index: 51
# 47. b_{1}, b_{2}, ..., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 51
# 48. ((a_{1}, a_{2}, ..., a_{m}), (b_{1}, b_{2}, ..., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. and
#     core type: Literal
#     sub-expressions:
# 50. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))
#     core type: ExprTuple
#     sub-expressions: 54
# 51. m + 1
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 58
# 54. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 62
#     end_index: 63
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 57. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 62
#     end_index: 63
# 58. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 62
#     end_index: 63
# 59. _a -> (a_{_a} = b_{_a})
#     core type: Lambda
#     parameter: 72
#     body: 64
# 60. _a -> a_{_a}
#     core type: Lambda
#     parameter: 72
#     body: 67
# 61. _a -> b_{_a}
#     core type: Lambda
#     parameter: 72
#     body: 68
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. m
#     core type: Variable
#     sub-expressions:
# 64. a_{_a} = b_{_a}
#     core type: Operation
#     operator: 65
#     operands: 66
# 65. =
#     core type: Literal
#     sub-expressions:
# 66. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. a_{_a}
#     core type: IndexedVar
# variable: 69
# index: 72
# 68. b_{_a}
#     core type: IndexedVar
# variable: 70
# index: 72
# 69. a
#     core type: Variable
#     sub-expressions:
# 70. b
#     core type: Variable
#     sub-expressions:
# 71. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 72. _a
#     core type: Variable
#     sub-expressions:
