# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, k, m, n
from proveit.logic import And, Equals, Forall, Implies
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = IndexedVar(b, sub_expr1)
sub_expr6 = [NaturalPos]
sub_expr7 = Add(m, one)
sub_expr8 = ExprRange(sub_expr1, sub_expr4, one, sub_expr7)
sub_expr9 = ExprRange(sub_expr1, sub_expr5, one, sub_expr7)
sub_expr10 = Equals(IndexedVar(a, k), IndexedVar(b, k))
sub_expr11 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr12 = ExprRange(sub_expr1, sub_expr5, one, m)
sub_expr13 = ExprRange(sub_expr1, sub_expr4, one, n)
sub_expr14 = ExprRange(sub_expr1, sub_expr5, one, n)
expr = Implies(And(Forall([sub_expr2, sub_expr3], Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall([m], Forall([sub_expr8, sub_expr9], Equals([sub_expr8], [sub_expr9]), condition = ExprRange(k, sub_expr10, one, sub_expr7)), domains = sub_expr6, condition = Forall([sub_expr11, sub_expr12], Equals([sub_expr11], [sub_expr12]), condition = ExprRange(k, sub_expr10, one, m)))).with_wrapping_at(1), Forall([n], Forall([sub_expr13, sub_expr14], Equals([sub_expr13], [sub_expr14]), condition = ExprRange(k, sub_expr10, one, n)), domains = sub_expr6)).with_wrapping_at(1)
# Out:
# expr: ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(\begin{array}{c} \left[\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right)\right] \\  \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]\right] \end{array}\right) \\  \Rightarrow \left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n}, b_{1}, \ldots, b_{n}~|~a_{1} = b_{1}, \ldots, a_{n} = b_{n}}~\left(\left(a_{1}, \ldots, a_{n}\right) = \left(b_{1}, \ldots, b_{n}\right)\right)\right]\right] \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]) \\  => [forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# ...
