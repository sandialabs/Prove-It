# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = IndexedVar(b, sub_expr1)
sub_expr6 = Add(m, one)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, sub_expr6)
sub_expr8 = ExprRange(sub_expr1, sub_expr5, one, sub_expr6)
sub_expr9 = Equals(IndexedVar(a, k), IndexedVar(b, k))
sub_expr10 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr11 = ExprRange(sub_expr1, sub_expr5, one, m)
expr = ExprTuple(Forall([sub_expr2, sub_expr3], Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall([m], Forall([sub_expr7, sub_expr8], Equals([sub_expr7], [sub_expr8]), condition = ExprRange(k, sub_expr9, one, sub_expr6)), domains = [NaturalPos], condition = Forall([sub_expr10, sub_expr11], Equals([sub_expr10], [sub_expr11]), condition = ExprRange(k, sub_expr9, one, m))))
# Out:
# expr: (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right), \forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 27
#    operand: 3
# 2. forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
#    core type: Operation
#    operator: 27
#    operand: 4
# 3. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Lambda
#    parameters: 12\n   body: 5
# 4. m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Lambda
#    parameter: 56
#    body: 6
# 5. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Conditional
#    value: 7
#    condition: 8
# 6. {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. (a_{1}) = (b_{1})
#    core type: Operation
#    operator: 60
#    operands: 11
# 8. a_{1} = b_{1}
#    core type: Operation
#    operator: 60
#    operands: 12
# 9. forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))
#    core type: Operation
#    operator: 27
#    operand: 13
# 10. (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
#     core type: Operation
#     operator: 42
#     operands: 14
# 11. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 13. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 14. (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 18. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 19. m in NaturalPos
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#     core type: Operation
#     operator: 27
#     operand: 28
# 21. a_{1}
#     core type: IndexedVar
# variable: 65
# index: 55
# 22. b_{1}
#     core type: IndexedVar
# variable: 66
# index: 55
# 23. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: Operation
#     operator: 60
#     operands: 29
# 24. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 42
#     operands: 30
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 56, 31
# 27. forall
#     core type: Literal
#     sub-expressions:
# 28. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 32\n    body: 33
# 29. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 30. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 36
# 31. NaturalPos
#     core type: Literal
#     sub-expressions:
# 32. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 33. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 37
#     condition: 38
# 34. (a_{1}, ..a_{_a}.., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 55
#     end_index: 44
# 37. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 60
#     operands: 41
# 38. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. a_{1}, ..a_{_a}.., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 55
#     end_index: 44
# 40. b_{1}, ..b_{_a}.., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 44
# 41. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. m + 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 50
# 46. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 51
# 47. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 55
#     end_index: 56
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 50. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 55
#     end_index: 56
# 51. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 52. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 67
#     body: 57
# 53. _a -> a_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 54. _a -> b_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. m
#     core type: Variable
#     sub-expressions:
# 57. a_{k} = b_{k}
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. a_{_a}
#     core type: IndexedVar
# variable: 65
# index: 62
# 59. b_{_a}
#     core type: IndexedVar
# variable: 66
# index: 62
# 60. =
#     core type: Literal
#     sub-expressions:
# 61. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 62. _a
#     core type: Variable
#     sub-expressions:
# 63. a_{k}
#     core type: IndexedVar
# variable: 65
# index: 67
# 64. b_{k}
#     core type: IndexedVar
# variable: 66
# index: 67
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. b
#     core type: Variable
#     sub-expressions:
# 67. k
#     core type: Variable
#     sub-expressions:
