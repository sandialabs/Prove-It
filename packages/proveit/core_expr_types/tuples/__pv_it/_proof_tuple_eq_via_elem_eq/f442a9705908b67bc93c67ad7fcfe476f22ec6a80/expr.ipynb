# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, k, m, n
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = IndexedVar(b, sub_expr1)
sub_expr6 = [NaturalPos]
sub_expr7 = Add(m, one)
sub_expr8 = ExprRange(sub_expr1, sub_expr4, one, sub_expr7)
sub_expr9 = ExprRange(sub_expr1, sub_expr5, one, sub_expr7)
sub_expr10 = Equals(IndexedVar(a, k), IndexedVar(b, k))
sub_expr11 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr12 = ExprRange(sub_expr1, sub_expr5, one, m)
sub_expr13 = ExprRange(sub_expr1, sub_expr4, one, n)
sub_expr14 = ExprRange(sub_expr1, sub_expr5, one, n)
expr = ExprTuple(And(Forall([sub_expr2, sub_expr3], Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall([m], Forall([sub_expr8, sub_expr9], Equals([sub_expr8], [sub_expr9]), condition = ExprRange(k, sub_expr10, one, sub_expr7)), domains = sub_expr6, condition = Forall([sub_expr11, sub_expr12], Equals([sub_expr11], [sub_expr12]), condition = ExprRange(k, sub_expr10, one, m)))).with_wrapping_at(1), Forall([n], Forall([sub_expr13, sub_expr14], Equals([sub_expr13], [sub_expr14]), condition = ExprRange(k, sub_expr10, one, n)), domains = sub_expr6))
# Out:
# expr: ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\begin{array}{c} \left[\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right)\right] \\  \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]\right] \end{array}, \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n}, b_{1}, \ldots, b_{n}~|~a_{1} = b_{1}, \ldots, a_{n} = b_{n}}~\left(\left(a_{1}, \ldots, a_{n}\right) = \left(b_{1}, \ldots, b_{n}\right)\right)\right]\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]], forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]]
#    core type: Operation
#    operator: 63
#    operands: 3
# 2. forall_{n in NaturalPos} [forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))]
#    core type: Operation
#    operator: 42
#    operand: 4
# 3. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 59
#    body: 7
# 5. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 42
#    operand: 8
# 6. forall_{m in NaturalPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))]
#    core type: Operation
#    operator: 42
#    operand: 9
# 7. {forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})) if n in NaturalPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Lambda
#    parameters: 23\n   body: 12
# 9. m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Lambda
#    parameter: 77
#    body: 13
# 10. forall_{a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n}} ((a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}))
#     core type: Operation
#     operator: 42
#     operand: 14
# 11. n in NaturalPos
#     core type: Operation
#     operator: 40
#     operands: 15
# 12. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#     core type: Conditional
#     value: 18
#     condition: 19
# 14. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n}) -> {(a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 15. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 59, 49
# 16. (a_{1}) = (b_{1})
#     core type: Operation
#     operator: 81
#     operands: 22
# 17. a_{1} = b_{1}
#     core type: Operation
#     operator: 81
#     operands: 23
# 18. forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: Operation
#     operator: 42
#     operand: 24
# 19. (m in NaturalPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
#     core type: Operation
#     operator: 63
#     operands: 25
# 20. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 21. {(a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 22. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 23. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 24. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 30\n    body: 31
# 25. (m in NaturalPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 26. (a_{1}, ..a_{_a}.., a_{n}) = (b_{1}, ..b_{_a}.., b_{n})
#     core type: Operation
#     operator: 81
#     operands: 34
# 27. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{n} = b_{n})
#     core type: Operation
#     operator: 63
#     operands: 35
# 28. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 36
# 29. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 37
# 30. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 31. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 38
#     condition: 39
# 32. m in NaturalPos
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#     core type: Operation
#     operator: 42
#     operand: 43
# 34. ((a_{1}, ..a_{_a}.., a_{n}), (b_{1}, ..b_{_a}.., b_{n}))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 35. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{n} = b_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 36. a_{1}
#     core type: IndexedVar
# variable: 86
# index: 76
# 37. b_{1}
#     core type: IndexedVar
# variable: 87
# index: 76
# 38. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: Operation
#     operator: 81
#     operands: 47
# 39. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 63
#     operands: 48
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 77, 49
# 42. forall
#     core type: Literal
#     sub-expressions:
# 43. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 50\n    body: 51
# 44. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 45. (b_{1}, ..b_{_a}.., b_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 46. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{n} = b_{n})
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 76
#     end_index: 59
# 47. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 56
# 49. NaturalPos
#     core type: Literal
#     sub-expressions:
# 50. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 51. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 57
#     condition: 58
# 52. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 76
#     end_index: 59
# 53. b_{1}, ..b_{_a}.., b_{n}
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 76
#     end_index: 59
# 54. (a_{1}, ..a_{_a}.., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 60
# 55. (b_{1}, ..b_{_a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 76
#     end_index: 65
# 57. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 81
#     operands: 62
# 58. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. a_{1}, ..a_{_a}.., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 76
#     end_index: 65
# 61. b_{1}, ..b_{_a}.., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 76
#     end_index: 65
# 62. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. and
#     core type: Literal
#     sub-expressions:
# 64. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 68
# 65. m + 1
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 71
# 67. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 72
# 68. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 76
#     end_index: 77
# 69. +
#     core type: Literal
#     sub-expressions:
# 70. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 77, 76
# 71. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 76
#     end_index: 77
# 72. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 76
#     end_index: 77
# 73. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 88
#     body: 78
# 74. _a -> a_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 79
# 75. _a -> b_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 80
# 76. 1
#     core type: Literal
#     sub-expressions:
# 77. m
#     core type: Variable
#     sub-expressions:
# 78. a_{k} = b_{k}
#     core type: Operation
#     operator: 81
#     operands: 82
# 79. a_{_a}
#     core type: IndexedVar
# variable: 86
# index: 83
# 80. b_{_a}
#     core type: IndexedVar
# variable: 87
# index: 83
# 81. =
#     core type: Literal
#     sub-expressions:
# 82. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 83. _a
#     core type: Variable
#     sub-expressions:
# 84. a_{k}
#     core type: IndexedVar
# variable: 86
# index: 88
# 85. b_{k}
#     core type: IndexedVar
# variable: 87
# index: 88
# 86. a
#     core type: Variable
#     sub-expressions:
# 87. b
#     core type: Variable
#     sub-expressions:
# 88. k
#     core type: Variable
#     sub-expressions:
