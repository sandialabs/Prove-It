# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, m, n
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = Add(m, one)
sub_expr6 = IndexedVar(b, sub_expr1)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, sub_expr5)
sub_expr8 = ExprRange(sub_expr1, sub_expr6, one, sub_expr5)
sub_expr9 = Equals(sub_expr4, sub_expr6)
sub_expr10 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr11 = ExprRange(sub_expr1, sub_expr6, one, m)
sub_expr12 = ExprRange(sub_expr1, sub_expr4, one, n)
sub_expr13 = ExprRange(sub_expr1, sub_expr6, one, n)
expr = ExprTuple(And(Forall(instance_param_or_params = [sub_expr2, sub_expr3], instance_expr = Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [sub_expr7, sub_expr8], instance_expr = Equals([sub_expr7], [sub_expr8]), condition = ExprRange(sub_expr1, sub_expr9, one, sub_expr5)), domain = NaturalPos, condition = Forall(instance_param_or_params = [sub_expr10, sub_expr11], instance_expr = Equals([sub_expr10], [sub_expr11]), condition = ExprRange(sub_expr1, sub_expr9, one, m))).with_wrapping()).with_wrapping_at(1), Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [sub_expr12, sub_expr13], instance_expr = Equals([sub_expr12], [sub_expr13]), condition = ExprRange(sub_expr1, sub_expr9, one, n)), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \left[\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right)\right] \\  \land \left[\begin{array}{l}\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{m}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m} = b_{m}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m}\right) = \left(b_{1}, b_{2}, \ldots, b_{m}\right)\right)}~\\
# \left[\forall_{a_{1}, a_{2}, \ldots, a_{m + 1}, b_{1}, b_{2}, \ldots, b_{m + 1}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m + 1} = b_{m + 1}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m + 1}\right) = \left(b_{1}, b_{2}, \ldots, b_{m + 1}\right)\right)\right]\end{array}\right] \end{array}, \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{n} = b_{n}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{n}\right) = \left(b_{1}, b_{2}, \ldots, b_{n}\right)\right)\right]\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]], forall_{n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))] \\  and [forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]]
#    core type: Operation
#    operator: 72
#    operands: 3
# 2. forall_{n in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}))]
#    core type: Operation
#    operator: 45
#    operand: 7
# 3. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (n -> {forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 45
#    operand: 12
# 6. forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]
#    core type: Operation
#    operator: 45
#    operand: 13
# 7. n -> {forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 68
#    body: 11
# 8. ((a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 68
# 11. {forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n})) if n in NaturalPos.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#     core type: Lambda
#     parameters: 27\n    body: 16
# 13. m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#     core type: Lambda
#     parameter: 86
#     body: 18
# 14. forall_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})} ((a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}))
#     core type: Operation
#     operator: 45
#     operand: 25
# 15. n in NaturalPos
#     core type: Operation
#     operator: 43
#     operands: 20
# 16. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. (m)
#     core type: ExprTuple
#     sub-expressions: 86
# 18. {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#     core type: Conditional
#     value: 23
#     condition: 24
# 19. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{n} = b_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 68, 52
# 21. (a_{1}) = (b_{1})
#     core type: Operation
#     operator: 88
#     operands: 26
# 22. a_{1} = b_{1}
#     core type: Operation
#     operator: 88
#     operands: 27
# 23. forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: Operation
#     operator: 45
#     operand: 34
# 24. (m in NaturalPos) and [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))]
#     core type: Operation
#     operator: 72
#     operands: 29
# 25. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{n} = b_{n}).
#     core type: Lambda
#     parameters: 30\n    body: 31
# 26. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 28. ((a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. (m in NaturalPos, forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 31. {(a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{n} = b_{n}).
#     core type: Conditional
#     value: 37
#     condition: 38
# 32. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 39
# 33. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 40
# 34. (a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 41\n    body: 42
# 35. m in NaturalPos
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
#     core type: Operation
#     operator: 45
#     operand: 53
# 37. (a_{1}, a_{2}, ..., a_{n}) = (b_{1}, b_{2}, ..., b_{n})
#     core type: Operation
#     operator: 88
#     operands: 47
# 38. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{n} = b_{n})
#     core type: Operation
#     operator: 72
#     operands: 48
# 39. a_{1}
#     core type: IndexedVar
# variable: 92
# index: 85
# 40. b_{1}
#     core type: IndexedVar
# variable: 93
# index: 85
# 41. (a_{1}, a_{2}, ..., a_{m + 1},b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 42. {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 50
#     condition: 51
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 86, 52
# 45. forall
#     core type: Literal
#     sub-expressions:
# 46. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 53
# 47. ((a_{1}, a_{2}, ..., a_{n}), (b_{1}, b_{2}, ..., b_{n}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n}))
#     core type: ExprTuple
#     sub-expressions: 56
# 49. (1)
#     core type: ExprTuple
#     sub-expressions: 85
# 50. (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: Operation
#     operator: 88
#     operands: 57
# 51. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 72
#     operands: 58
# 52. NaturalPos
#     core type: Literal
#     sub-expressions:
# 53. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 59\n    body: 60
# 54. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 55. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 56. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{n} = b_{n})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 68
# 57. ((a_{1}, a_{2}, ..., a_{m + 1}), (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 58. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 65
# 59. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 60. {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Conditional
#     value: 66
#     condition: 67
# 61. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 68
# 62. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 68
# 63. (a_{1}, a_{2}, ..., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 69
# 64. (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 70
# 65. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 74
# 66. (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
#     core type: Operation
#     operator: 88
#     operands: 71
# 67. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
#     core type: Operation
#     operator: 72
#     operands: 73
# 68. n
#     core type: Variable
#     sub-expressions:
# 69. a_{1}, a_{2}, ..., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 74
# 70. b_{1}, b_{2}, ..., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 74
# 71. ((a_{1}, a_{2}, ..., a_{m}), (b_{1}, b_{2}, ..., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. and
#     core type: Literal
#     sub-expressions:
# 73. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))
#     core type: ExprTuple
#     sub-expressions: 77
# 74. m + 1
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 80
# 76. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 81
# 77. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 85
#     end_index: 86
# 78. +
#     core type: Literal
#     sub-expressions:
# 79. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 86, 85
# 80. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 85
#     end_index: 86
# 81. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 85
#     end_index: 86
# 82. _a -> (a_{_a} = b_{_a})
#     core type: Lambda
#     parameter: 95
#     body: 87
# 83. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 90
# 84. _a -> b_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 91
# 85. 1
#     core type: Literal
#     sub-expressions:
# 86. m
#     core type: Variable
#     sub-expressions:
# 87. a_{_a} = b_{_a}
#     core type: Operation
#     operator: 88
#     operands: 89
# 88. =
#     core type: Literal
#     sub-expressions:
# 89. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 90. a_{_a}
#     core type: IndexedVar
# variable: 92
# index: 95
# 91. b_{_a}
#     core type: IndexedVar
# variable: 93
# index: 95
# 92. a
#     core type: Variable
#     sub-expressions:
# 93. b
#     core type: Variable
#     sub-expressions:
# 94. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 95. _a
#     core type: Variable
#     sub-expressions:
