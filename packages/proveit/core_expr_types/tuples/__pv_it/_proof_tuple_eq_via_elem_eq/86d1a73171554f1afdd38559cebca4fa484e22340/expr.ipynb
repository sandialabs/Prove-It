# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, b, m
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, sub_expr1)
sub_expr3 = Add(m, one)
sub_expr4 = IndexedVar(b, sub_expr1)
sub_expr5 = ExprRange(sub_expr1, sub_expr2, one, sub_expr3)
sub_expr6 = ExprRange(sub_expr1, sub_expr4, one, sub_expr3)
sub_expr7 = Equals(sub_expr2, sub_expr4)
sub_expr8 = ExprRange(sub_expr1, sub_expr2, one, m)
sub_expr9 = ExprRange(sub_expr1, sub_expr4, one, m)
expr = Conditional(Forall(instance_param_or_params = [sub_expr5, sub_expr6], instance_expr = Equals([sub_expr5], [sub_expr6]), condition = ExprRange(sub_expr1, sub_expr7, one, sub_expr3)), And(InSet(m, NaturalPos), Forall(instance_param_or_params = [sub_expr8, sub_expr9], instance_expr = Equals([sub_expr8], [sub_expr9]), condition = ExprRange(sub_expr1, sub_expr7, one, m))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a_{1}, a_{2}, \ldots, a_{m + 1}, b_{1}, b_{2}, \ldots, b_{m + 1}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m + 1} = b_{m + 1}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m + 1}\right) = \left(b_{1}, b_{2}, \ldots, b_{m + 1}\right)\right) \textrm{ if } m \in \mathbb{N}^+ ,  \forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{m}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m} = b_{m}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m}\right) = \left(b_{1}, b_{2}, \ldots, b_{m}\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))
#    core type: Operation
#    operator: 12
#    operand: 5
# 2. (m in NaturalPos) and [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))]
#    core type: Operation
#    operator: 30
#    operands: 4
# 3. ((a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (m in NaturalPos, forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. m in NaturalPos
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
#    core type: Operation
#    operator: 12
#    operand: 17
# 8. (a_{1}, a_{2}, ..., a_{m + 1},b_{1}, b_{2}, ..., b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 27, 28
# 9. {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#    core type: Conditional
#    value: 14
#    condition: 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 44, 16
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: Operation
#     operator: 46
#     operands: 18
# 15. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 30
#     operands: 19
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 18. ((a_{1}, a_{2}, ..., a_{m + 1}), (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 24
# 20. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 21. {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. (a_{1}, a_{2}, ..., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 43
#     end_index: 32
# 25. (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
#     core type: Operation
#     operator: 46
#     operands: 29
# 26. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. a_{1}, a_{2}, ..., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 43
#     end_index: 32
# 28. b_{1}, b_{2}, ..., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 32
# 29. ((a_{1}, a_{2}, ..., a_{m}), (b_{1}, b_{2}, ..., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))
#     core type: ExprTuple
#     sub-expressions: 35
# 32. m + 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 43
#     end_index: 44
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 43
# 38. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 43
#     end_index: 44
# 39. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 40. _a -> (a_{_a} = b_{_a})
#     core type: Lambda
#     parameter: 53
#     body: 45
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 48
# 42. _a -> b_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 49
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. a_{_a} = b_{_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 46. =
#     core type: Literal
#     sub-expressions:
# 47. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. a_{_a}
#     core type: IndexedVar
# variable: 50
# index: 53
# 49. b_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 50. a
#     core type: Variable
#     sub-expressions:
# 51. b
#     core type: Variable
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. _a
#     core type: Variable
#     sub-expressions:
