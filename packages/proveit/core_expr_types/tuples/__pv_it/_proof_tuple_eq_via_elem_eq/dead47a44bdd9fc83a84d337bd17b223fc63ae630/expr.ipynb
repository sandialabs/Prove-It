# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, m
from proveit.logic import Equals, Forall
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(a, one)
sub_expr3 = IndexedVar(b, one)
sub_expr4 = IndexedVar(a, sub_expr1)
sub_expr5 = Add(m, one)
sub_expr6 = IndexedVar(b, sub_expr1)
sub_expr7 = ExprRange(sub_expr1, sub_expr4, one, sub_expr5)
sub_expr8 = ExprRange(sub_expr1, sub_expr6, one, sub_expr5)
sub_expr9 = Equals(sub_expr4, sub_expr6)
sub_expr10 = ExprRange(sub_expr1, sub_expr4, one, m)
sub_expr11 = ExprRange(sub_expr1, sub_expr6, one, m)
expr = ExprTuple(Forall(instance_param_or_params = [sub_expr2, sub_expr3], instance_expr = Equals([sub_expr2], [sub_expr3]), condition = Equals(sub_expr2, sub_expr3)), Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [sub_expr7, sub_expr8], instance_expr = Equals([sub_expr7], [sub_expr8]), condition = ExprRange(sub_expr1, sub_expr9, one, sub_expr5)), domain = NaturalPos, condition = Forall(instance_param_or_params = [sub_expr10, sub_expr11], instance_expr = Equals([sub_expr10], [sub_expr11]), condition = ExprRange(sub_expr1, sub_expr9, one, m))).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right), \begin{array}{l}\forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, a_{2}, \ldots, a_{m}, b_{1}, b_{2}, \ldots, b_{m}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m} = b_{m}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m}\right) = \left(b_{1}, b_{2}, \ldots, b_{m}\right)\right)}~\\
# \left[\forall_{a_{1}, a_{2}, \ldots, a_{m + 1}, b_{1}, b_{2}, \ldots, b_{m + 1}~|~\left(a_{1} = b_{1}\right), \left(a_{2} = b_{2}\right), \ldots, \left(a_{m + 1} = b_{m + 1}\right)}~\left(\left(a_{1}, a_{2}, \ldots, a_{m + 1}\right) = \left(b_{1}, b_{2}, \ldots, b_{m + 1}\right)\right)\right]\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})), forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 29
#    operand: 5
# 2. forall_{m in NaturalPos | forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))} [forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))]
#    core type: Operation
#    operator: 29
#    operand: 6
# 3. ((a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a_{1}, b_{1}) -> {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Lambda
#    parameters: 15\n   body: 7
# 6. m -> {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Lambda
#    parameter: 62
#    body: 9
# 7. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. (m)
#    core type: ExprTuple
#    sub-expressions: 62
# 9. {forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})) if m in NaturalPos ,  forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (a_{1}) = (b_{1})
#     core type: Operation
#     operator: 64
#     operands: 14
# 11. a_{1} = b_{1}
#     core type: Operation
#     operator: 64
#     operands: 15
# 12. forall_{a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})} ((a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: Operation
#     operator: 29
#     operand: 20
# 13. (m in NaturalPos) and [forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))]
#     core type: Operation
#     operator: 48
#     operands: 17
# 14. ((a_{1}), (b_{1}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (a_{1}, b_{1})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 16. ((a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. (m in NaturalPos, forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. (a_{1})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. (b_{1})
#     core type: ExprTuple
#     sub-expressions: 24
# 20. (a_{1}, a_{2}, ..., a_{m + 1}, b_{1}, b_{2}, ..., b_{m + 1}) -> {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Lambda
#     parameters: 25\n    body: 26
# 21. m in NaturalPos
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. forall_{a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})} ((a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}))
#     core type: Operation
#     operator: 29
#     operand: 35
# 23. a_{1}
#     core type: IndexedVar
# variable: 68
# index: 61
# 24. b_{1}
#     core type: IndexedVar
# variable: 69
# index: 61
# 25. (a_{1}, a_{2}, ..., a_{m + 1},b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 26. {(a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1}).
#     core type: Conditional
#     value: 32
#     condition: 33
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 62, 34
# 29. forall
#     core type: Literal
#     sub-expressions:
# 30. ((a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. (1)
#     core type: ExprTuple
#     sub-expressions: 61
# 32. (a_{1}, a_{2}, ..., a_{m + 1}) = (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: Operation
#     operator: 64
#     operands: 36
# 33. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 48
#     operands: 37
# 34. NaturalPos
#     core type: Literal
#     sub-expressions:
# 35. (a_{1}, a_{2}, ..., a_{m}, b_{1}, b_{2}, ..., b_{m}) -> {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 38\n    body: 39
# 36. ((a_{1}, a_{2}, ..., a_{m + 1}), (b_{1}, b_{2}, ..., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 42
# 38. (a_{1}, a_{2}, ..., a_{m},b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 39. {(a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m}) if (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m}).
#     core type: Conditional
#     value: 43
#     condition: 44
# 40. (a_{1}, a_{2}, ..., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 45
# 41. (b_{1}, b_{2}, ..., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 61
#     end_index: 50
# 43. (a_{1}, a_{2}, ..., a_{m}) = (b_{1}, b_{2}, ..., b_{m})
#     core type: Operation
#     operator: 64
#     operands: 47
# 44. (a_{1} = b_{1}) and  (a_{2} = b_{2}) and  ... and  (a_{m} = b_{m})
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. a_{1}, a_{2}, ..., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 61
#     end_index: 50
# 46. b_{1}, b_{2}, ..., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 61
#     end_index: 50
# 47. ((a_{1}, a_{2}, ..., a_{m}), (b_{1}, b_{2}, ..., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. ((a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m}))
#     core type: ExprTuple
#     sub-expressions: 53
# 50. m + 1
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. (b_{1}, b_{2}, ..., b_{m})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 61
#     end_index: 62
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 56. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 61
#     end_index: 62
# 57. b_{1}, b_{2}, ..., b_{m}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 61
#     end_index: 62
# 58. _a -> (a_{_a} = b_{_a})
#     core type: Lambda
#     parameter: 71
#     body: 63
# 59. _a -> a_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 66
# 60. _a -> b_{_a}
#     core type: Lambda
#     parameter: 71
#     body: 67
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. m
#     core type: Variable
#     sub-expressions:
# 63. a_{_a} = b_{_a}
#     core type: Operation
#     operator: 64
#     operands: 65
# 64. =
#     core type: Literal
#     sub-expressions:
# 65. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. a_{_a}
#     core type: IndexedVar
# variable: 68
# index: 71
# 67. b_{_a}
#     core type: IndexedVar
# variable: 69
# index: 71
# 68. a
#     core type: Variable
#     sub-expressions:
# 69. b
#     core type: Variable
#     sub-expressions:
# 70. (_a)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. _a
#     core type: Variable
#     sub-expressions:
