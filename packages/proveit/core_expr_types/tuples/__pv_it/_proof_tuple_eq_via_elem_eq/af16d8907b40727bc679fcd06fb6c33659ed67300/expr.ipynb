# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b
from proveit.logic import Equals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple([ExprRange(sub_expr1, Equals(IndexedVar(a, sub_expr1), IndexedVar(b, sub_expr1)), one, one)], [Equals(IndexedVar(a, one), IndexedVar(b, one))])
# Out:
# expr: ((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}), (a_{1} = b_{1}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} = b_{1}, \ldots, a_{1} = b_{1}\right), \left(a_{1} = b_{1}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1}), (a_{1} = b_{1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} = b_{1}, ..a_{_a} = b_{_a}.., a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (a_{1} = b_{1}), ..(a_{_a} = b_{_a}).., (a_{1} = b_{1})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 12
#    end_index: 12
# 4. a_{1} = b_{1}
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. _a -> (a_{_a} = b_{_a})
#    core type: Lambda
#    parameter: 17
#    body: 7
# 6. (a_{1}, b_{1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a_{_a} = b_{_a}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a_{1}
#    core type: IndexedVar
# variable: 15
# index: 12
# 9. b_{1}
#    core type: IndexedVar
# variable: 16
# index: 12
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a_{_a}, b_{_a})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. a_{_a}
#     core type: IndexedVar
# variable: 15
# index: 17
# 14. b_{_a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
