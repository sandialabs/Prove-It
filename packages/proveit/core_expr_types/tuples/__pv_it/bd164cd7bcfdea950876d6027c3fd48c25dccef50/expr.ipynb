# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i, j
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_i_to_j, f_jp1, range_i_to_jp1
from proveit.logic import Equals, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([i, j], Equals(Len([f_i_to_j, f_jp1]), Len([range_i_to_jp1])), condition = InSet(Len([f_i_to_j]), Naturals))
# Out:
# expr: forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j), f(j + 1)\right)| = |\left(i, \ldots, j + 1\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (i, j) -> {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j)
#    core type: ExprTuple
#    sub-expressions: 28, 33
# 4. {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. |(f(i), ..f(a).., f(j))| in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|(f(i), ..f(a).., f(j), f(j + 1))|, |(i, ..k.., j + 1)|)
#    core type: ExprTuple
# ...
