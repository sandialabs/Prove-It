# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import f, i, j
from proveit.core_expr_types._common_ import partition_back_equiv
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([f, i, j], partition_back_equiv, condition = InSet(Add(j, Neg(i)), Naturals))
# Out:
# expr: forall_{f, i, j | (j - i) in Naturals} ((f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, i, j~|~\left(j - i\right) \in \mathbb{N}}~\left(\begin{array}{c} \left(f(i), \ldots, f(j)\right) =  \\ \left(f(i), \ldots, f(j - 1), f(j)\right) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, i, j | (j - i) in Naturals} ((f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {(f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)) if (j - i) in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 26, 25, 28
# 4. {(f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j)) if (j - i) in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i), ..f(a).., f(j)) =  \\ (f(i), ..f(a).., f(j - 1), f(j))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (j - i) in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((f(i), ..f(a).., f(j)), (f(i), ..f(a).., f(j - 1), f(j)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (j - i, Naturals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (f(i), ..f(a).., f(j - 1), f(j))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. j - i
#     core type: Operation
#     operator: 23
#     operands: 18
# 14. Naturals
#     core type: Literal
#     sub-expressions:
# 15. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 25
#     end_index: 28
# 16. f(i), ..f(a).., f(j - 1)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 25
#     end_index: 20
# 17. f(j)
#     core type: Operation
#     operator: 26
#     operand: 28
# 18. (j, -i)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 19. a -> f(a)
#     core type: Lambda
#     parameter: 27
#     body: 22
# 20. j - 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. -i
#     core type: Operation
#     operator: 30
#     operand: 25
# 22. f(a)
#     core type: Operation
#     operator: 26
#     operand: 27
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. i
#     core type: Variable
#     sub-expressions:
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. j
#     core type: Variable
#     sub-expressions:
# 29. -1
#     core type: Operation
#     operator: 30
#     operand: 31
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. 1
#     core type: Literal
#     sub-expressions:
