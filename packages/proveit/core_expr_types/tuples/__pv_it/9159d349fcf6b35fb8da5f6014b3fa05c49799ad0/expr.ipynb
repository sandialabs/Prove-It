# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#len_of_ranges_with_repeated_indices">len_of_ranges_with_repeated_indices</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import len_of_ranges_with_repeated_indices

# %%
# check that the built expression is the same as the stored expression
# %check_expr len_of_ranges_with_repeated_indices
# Out:
# Passed sanity check: built 'len_of_ranges_with_repeated_indices' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(len_of_ranges_with_repeated_indices.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{f_{1}, \ldots, f_{n}, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} |\left(f_{1}(i), \ldots, f_{1}(j), \ldots\ldots, f_{n}(i), \ldots, f_{n}(j)\right)| \\  = \left(n \cdot \left(j - i + 1\right)\right) \end{array}\right)\right]

# %%
# display the expression information
len_of_ranges_with_repeated_indices.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Naturals} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Naturals} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Naturals} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Naturals} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (f_{1}, ..f_{_a}.., f_{n}, i, j) -> {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Naturals.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 34, 10
# 8. (f_{1}, ..f_{_a}.., f_{n}, i, j)
#    core type: ExprTuple
#    sub-expressions: 11, 40, 41
# 9. {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. f_{1}, ..f_{_a}.., f_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 36
#     end_index: 34
# 12. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (j - i + 1) in Naturals
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. _a -> f_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|, n * (j - i + 1))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (j - i + 1, Naturals)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 19. f_{_a}
#     core type: IndexedVar
# variable: 45
# index: 23
# 20. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|
#     core type: Operation
#     operator: 24
#     operand: 28
# 21. n * (j - i + 1)
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. Naturals
#     core type: Literal
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
# 24. length
#     core type: Literal
#     sub-expressions:
# 25. ((f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)))
#     core type: ExprTuple
#     sub-expressions: 28
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (n, j - i + 1)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 28. (f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))
#     core type: ExprTuple
#     sub-expressions: 30
# 29. j - i + 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 36
#     end_index: 34
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 35, 36
# 33. k -> f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: Lambda
#     parameter: 46
#     body: 37
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. -i
#     core type: Operation
#     operator: 38
#     operand: 40
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 38. -
#     core type: Literal
#     sub-expressions:
# 39. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 44
#     body: 42
# 40. i
#     core type: Variable
#     sub-expressions:
# 41. j
#     core type: Variable
#     sub-expressions:
# 42. f_{k}(x)
#     core type: Operation
#     operator: 43
#     operand: 44
# 43. f_{k}
#     core type: IndexedVar
# variable: 45
# index: 46
# 44. x
#     core type: Variable
#     sub-expressions:
# 45. f
#     core type: Variable
#     sub-expressions:
# 46. k
#     core type: Variable
#     sub-expressions:
