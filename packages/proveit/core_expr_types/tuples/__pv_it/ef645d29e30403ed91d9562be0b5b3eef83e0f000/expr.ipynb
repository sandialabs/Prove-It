# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import P
from proveit.core_expr_types._common_ import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([P, x_1_to_n, y_1_to_n], P__y_1_to_n, conditions = [P__x_1_to_n, Equals([x_1_to_n], [y_1_to_n])])
# Out:
# expr: forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(x_{1}, \ldots, x_{n}), \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)}~P(y_{1}, \ldots, y_{n})

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 16, 17
# 4. {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 11
#    operands: 15
# 6. P(x_{1}, ..x_{_a}.., x_{n}) and ((x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 11
#    operands: 14
# 10. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 20
#     end_index: 21
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 19. _a -> y_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 23
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. x_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. y_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
