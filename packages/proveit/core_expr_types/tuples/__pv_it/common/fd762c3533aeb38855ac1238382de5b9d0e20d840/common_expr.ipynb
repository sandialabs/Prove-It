# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#fk_i_to_j">fk_i_to_j</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import fk_i_to_j

# %%
# check that the built expression is the same as the stored expression
assert fk_i_to_j == stored_expr
assert fk_i_to_j._style_id == stored_expr._style_id
print("Passed sanity check: fk_i_to_j matches stored_expr")
# Out:
# Passed sanity check: fk_i_to_j matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fk_i_to_j.latex())
# Out:
# f_{k}(i), \ldots, f_{k}(j)

# %%
# display the expression information
fk_i_to_j.expr_info()
# Out:
# 0. f_{k}(i), ..f_{k}(x).., f_{k}(j)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. x -> f_{k}(x)
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. i
#    core type: Variable
#    sub-expressions:
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. f_{k}(x)
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. f_{k}
#    core type: IndexedVar
# variable: 7
# index: 8
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. f
#    core type: Variable
#    sub-expressions:
# 8. k
#    core type: Variable
#    sub-expressions:
