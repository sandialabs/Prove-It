# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#range_len_sum">range_len_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import range_len_sum

# %%
# check that the built expression is the same as the stored expression
assert range_len_sum == stored_expr
assert range_len_sum._style_id == stored_expr._style_id
print("Passed sanity check: range_len_sum matches stored_expr")
# Out:
# Passed sanity check: range_len_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(range_len_sum.latex())
# Out:
# \left(j_{1} - i_{1} + 1\right) + \ldots + \left(j_{n} - i_{n} + 1\right)

# %%
# display the expression information
range_len_sum.expr_info()
# Out:
# 0. (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)
#    core type: Operation
#    operator: 6
#    operands: 1
# 1. (j_{1} - i_{1} + 1, ..j_{k} - i_{k} + 1.., j_{n} - i_{n} + 1)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (j_{1} - i_{1} + 1), ..(j_{k} - i_{k} + 1).., (j_{n} - i_{n} + 1)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 10
#    end_index: 4
# 3. k -> (j_{k} - i_{k} + 1)
#    core type: Lambda
#    parameter: 15
#    body: 5
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. j_{k} - i_{k} + 1
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (j_{k}, -i_{k}, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 8. j_{k}
#    core type: IndexedVar
# variable: 11
# index: 15
# 9. -i_{k}
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. j
#     core type: Variable
# ...
