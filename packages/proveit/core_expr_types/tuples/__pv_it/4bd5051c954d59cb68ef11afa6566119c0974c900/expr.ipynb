# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import SubsetEq
from proveit.number import Integers, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = SubsetEq(NaturalsPos, Integers)
# Out:
# expr: NaturalsPos subseteq Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathbb{N}^+ \subseteq \mathbb{Z}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. NaturalsPos subseteq Integers
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. (NaturalsPos, Integers)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 4. Integers
#    core type: Literal
#    sub-expressions:
