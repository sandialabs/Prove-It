# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#merge_series">merge_series</a>
# ***see <a class="ProveItLink" href="../../_proofs_/merge_series.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.core_expr_types.tuples._theorems_ import merge_series

# %%
# %dependencies merge_series
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems depend upon merge_series</h3>
