# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#merge_series">merge_series</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import merge_series

# %%
# check that the built expression is the same as the stored expression
# %check_expr merge_series
# Out:
# Passed sanity check: built 'merge_series' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_series.latex())
# Out:
# \vdash \forall_{f, i, j~|~\left(j - i\right) \in \mathbb{N}}~\left[\forall_{x_{0}, \ldots, x_{j - i}~|~x_{0} = f(i + 0), \ldots, x_{j - i} = f(i + \left(j - i\right))}~\left(\begin{array}{c} \left(x_{0}, \ldots, x_{j - i}\right) =  \\ \left(f(i), \ldots, f(j)\right) \end{array}\right)\right]

# %%
# display the expression information
merge_series.exprInfo()
# Out:
# 0. forall_{f, i, j | (j - i) in Naturals} [forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (f, i, j) -> {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 40, 44, 33
# 3. {forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))) if (j - i) in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x_{0}, ..x_{i}.., x_{j - i} | x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i))} ((x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (j - i) in Naturals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (x_{0}, ..x_{i}.., x_{j - i}) -> {(x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)) if (x_{0} = f(i + 0)) and ..(x_{k} = f(i + k)).. and (x_{j - i} = f(i + (j - i))).
#    core type: Lambda
#    parameter: 20
#    body: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (j - i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 25, 11
# 10. {(x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j)) if (x_{0} = f(i + 0)) and ..(x_{k} = f(i + k)).. and (x_{j - i} = f(i + (j - i))).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. (x_{0}, ..x_{i}.., x_{j - i}) =  \\ (f(i), ..f(a).., f(j))
#     core type: Operation
#     operator: 31
#     operands: 14
# 13. (x_{0} = f(i + 0)) and ..(x_{k} = f(i + k)).. and (x_{j - i} = f(i + (j - i)))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. ((x_{0}, ..x_{i}.., x_{j - i}), (f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x_{0} = f(i + 0), ..x_{k} = f(i + k).., x_{j - i} = f(i + (j - i)))
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (x_{0}, ..x_{i}.., x_{j - i})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (x_{0} = f(i + 0)), ..(x_{k} = f(i + k)).., (x_{j - i} = f(i + (j - i)))
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 24
#     end_index: 25
# 20. x_{0}, ..x_{i}.., x_{j - i}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 21. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 44
#     end_index: 33
# 22. k -> (x_{k} = f(i + k))
#     core type: Lambda
#     parameter: 45
#     body: 27
# 23. i -> x_{i}
#     core type: Lambda
#     parameter: 44
#     body: 28
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. j - i
#     core type: Operation
#     operator: 42
#     operands: 29
# 26. a -> f(a)
#     core type: Lambda
#     parameter: 35
#     body: 30
# 27. x_{k} = f(i + k)
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. x_{i}
#     core type: IndexedVar
# variable: 39
# index: 44
# 29. (j, -i)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. f(a)
#     core type: Operation
#     operator: 40
#     operand: 35
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (x_{k}, f(i + k))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. -i
#     core type: Operation
#     operator: 38
#     operand: 44
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. x_{k}
#     core type: IndexedVar
# variable: 39
# index: 45
# 37. f(i + k)
#     core type: Operation
#     operator: 40
#     operand: 41
# 38. -
#     core type: Literal
#     sub-expressions:
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. i + k
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (i, k)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. k
#     core type: Variable
#     sub-expressions:
