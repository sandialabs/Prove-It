# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import b, m
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(Variable("_b", latexFormat = r"{_{-}b}"), [ExprRange(subExpr1, IndexedVar(b, subExpr1), one, m), IndexedVar(b, Add(m, one))])
# Out:
# expr: (_b, (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left({_{-}b}, \left(b_{1}, \ldots, b_{m}, b_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (_b, (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. _b
#    core type: Variable
#    sub-expressions:
# 2. (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b_{1}, ..b_{_a}.., b_{m}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 13
#    end_index: 12
# 4. b_{m + 1}
#    core type: IndexedVar
# variable: 10
# index: 6
# 5. _a -> b_{_a}
#    core type: Lambda
#    parameter: 11
#    body: 7
# 6. m + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. b_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
