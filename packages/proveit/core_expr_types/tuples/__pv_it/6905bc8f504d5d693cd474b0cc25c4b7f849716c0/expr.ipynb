# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import f, i
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_1_to_i
from proveit.logic import Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Forall([f], InSet(Len([f_1_to_i]), Naturals)), InSet(i, Naturals)))
# Out:
# expr: i -> {forall_{f} (|(f(1), ..f(a).., f(i))| in Naturals) if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\forall_{f}~\left(|\left(f(1), \ldots, f(i)\right)| \in \mathbb{N}\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> {forall_{f} (|(f(1), ..f(a).., f(i))| in Naturals) if i in Naturals.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {forall_{f} (|(f(1), ..f(a).., f(i))| in Naturals) if i in Naturals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{f} (|(f(1), ..f(a).., f(i))| in Naturals)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. i in Naturals
#    core type: Operation
#    operator: 8
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. f -> (|(f(1), ..f(a).., f(i))| in Naturals)
#    core type: Lambda
#    parameter: 20
#    body: 7
# 6. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 18, 11
# 7. |(f(1), ..f(a).., f(i))| in Naturals
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (|(f(1), ..f(a).., f(i))|, Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. |(f(1), ..f(a).., f(i))|
#     core type: Operation
#     operator: 12
#     operand: 14
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. length
#     core type: Literal
#     sub-expressions:
# 13. ((f(1), ..f(a).., f(i)))
#     core type: ExprTuple
#     sub-expressions: 14
# 14. (f(1), ..f(a).., f(i))
#     core type: ExprTuple
#     sub-expressions: 15
# 15. f(1), ..f(a).., f(i)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 16. a -> f(a)
#     core type: Lambda
#     parameter: 21
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. f(a)
#     core type: Operation
#     operator: 20
#     operand: 21
# 20. f
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
