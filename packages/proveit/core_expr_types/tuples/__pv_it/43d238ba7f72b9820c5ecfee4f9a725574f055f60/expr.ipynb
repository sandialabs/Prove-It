# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import B
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = Lambda([A_1_to_m, B, C_1_to_n], Conditional(B, And(A_1_to_m, B, C_1_to_n)))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}\right) \mapsto \left\{B \textrm{ if } A_{1} ,  \ldots ,  A_{m} ,  B ,  C_{1} ,  \ldots ,  C_{n}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Lambda
#    parameters: 4\n   body: 1
# 1. {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Conditional
#    value: 6
#    condition: 2
# 2. A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 9
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. C_{1}, ..C_{_a}.., C_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 8. _a -> A_{_a}
#    core type: Lambda
#    parameter: 17
#    body: 13
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. _a -> C_{_a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. A_{_a}
#     core type: IndexedVar
# variable: 15
# index: 17
# 14. C_{_a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
