# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#empty_range_def">empty_range_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.core_expr_types.tuples import empty_range_def

# %%
# %dependencies empty_range_def
# Out:
# <h3>Theorems/conjectures that depend directly on empty_range_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/tuple_eq_via_elem_eq/thm_proof.ipynb">proveit.core_expr_types.tuples.tuple_eq_via_elem_eq</a></dt><dd><a class="ProveItLink" href="../../theorems/b236f0e28657e92c0fd2f0f7de81efb42f320fc60/expr.ipynb"><img src="../../theorems/b236f0e28657e92c0fd2f0f7de81efb42f320fc60/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
