# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#tuple_len_0">tuple_len_0</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import tuple_len_0

# %%
# check that the built expression is the same as the stored expression
assert tuple_len_0.expr == stored_expr
assert tuple_len_0.expr._style_id == stored_expr._style_id
print("Passed sanity check: tuple_len_0 matches stored_expr")
# Out:
# Passed sanity check: tuple_len_0 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_0.latex())
# Out:
# \vdash |()| = 0

# %%
# display the expression information
tuple_len_0.expr_info()
# Out:
# 0. |()| = 0
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|()|, 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |()|
#    core type: Operation
#    operator: 5
#    operand: 7
# 4. 0
#    core type: Literal
#    sub-expressions:
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. (())
#    core type: ExprTuple
#    sub-expressions: 7
# 7. ()
#    core type: ExprTuple
#    sub-expressions:
