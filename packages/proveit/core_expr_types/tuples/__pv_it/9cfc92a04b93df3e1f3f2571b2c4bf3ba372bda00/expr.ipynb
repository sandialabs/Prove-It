# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n
from proveit.logic import InSet
from proveit.number import NaturalsPos
from proveit.number._common_ import Pn

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Pn, InSet(n, NaturalsPos)))
# Out:
# expr: n -> {P(n) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{P(n) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {P(n) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. {P(n) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. P(n)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. P
#    core type: Variable
#    sub-expressions:
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. n
#    core type: Variable
#    sub-expressions:
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
