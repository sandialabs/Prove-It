# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i, j
from proveit.logic import InSet, Set
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Set(InSet(Add(j, Neg(Add(i, Neg(one)))), Naturals))
# Out:
# expr: {(j - (i - 1)) in Naturals}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(j - \left(i - 1\right)\right) \in \mathbb{N}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(j - (i - 1)) in Naturals}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (j - (i - 1)) in Naturals
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (j - (i - 1), Naturals)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. j - (i - 1)
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. Naturals
#    core type: Literal
#    sub-expressions:
# 7. (j, -(i - 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. -(i - 1)
#    core type: Operation
#    operator: 15
#    operand: 10
# 10. i - 1
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. -1
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
