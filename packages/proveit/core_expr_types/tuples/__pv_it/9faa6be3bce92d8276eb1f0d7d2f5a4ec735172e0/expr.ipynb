# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function
from proveit._common_ import a, b, f, i, j, k, l
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Integers, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], Forall([i, j, k, l], Equals([ExprRange(k, Function(f, Add(k, a)), i, j)], [ExprRange(i, Function(f, Add(i, b)), k, l)]), conditions = [InSet(Add(Add(j, one), Neg(i)), Naturals), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), domains = [Integers, Integers])
# Out:
# expr: forall_{a in Integers, b in Integers} [forall_{i, j, k, l | ((j + 1) - i) in Naturals, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{Z}, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f(i + a), \ldots, f(j + a)\right) = \left(f(k + b), \ldots, f(l + b)\right)\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in Integers, b in Integers} [forall_{i, j, k, l | ((j + 1) - i) in Naturals, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Naturals, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integers ,  b in Integers.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b)
#    core type: ExprTuple
#    sub-expressions: 60, 62
# 3. {forall_{i, j, k, l | ((j + 1) - i) in Naturals, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
