# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import a, b, k, m
from proveit.logic import Equals, Forall
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(a, subExpr1)
subExpr3 = IndexedVar(b, subExpr1)
subExpr4 = Add(m, one)
subExpr5 = ExprRange(subExpr1, subExpr2, one, subExpr4)
subExpr6 = Equals(IndexedVar(a, k), IndexedVar(b, k))
subExpr7 = ExprRange(subExpr1, subExpr2, one, m)
subExpr8 = ExprRange(subExpr1, subExpr3, one, m)
expr = Forall([m], Forall([subExpr5, ExprRange(subExpr1, subExpr3, one, subExpr4)], Equals([subExpr5], [ExprRange(a, IndexedVar(b, a), one, subExpr4)]), condition = ExprRange(k, subExpr6, one, subExpr4)), domain = NaturalsPos, condition = Forall([subExpr7, subExpr8], Equals([subExpr7], [subExpr8]), condition = ExprRange(k, subExpr6, one, m)))
# Out:
# expr: forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+~|~\forall_{a_{1}, \ldots, a_{m}, b_{1}, \ldots, b_{m}~|~a_{1} = b_{1}, \ldots, a_{m} = b_{m}}~\left(\left(a_{1}, \ldots, a_{m}\right) = \left(b_{1}, \ldots, b_{m}\right)\right)}~\left[\forall_{a_{1}, \ldots, a_{m + 1}, b_{1}, \ldots, b_{m + 1}~|~a_{1} = b_{1}, \ldots, a_{m + 1} = b_{m + 1}}~\left(\left(a_{1}, \ldots, a_{m + 1}\right) = \left(b_{1}, \ldots, b_{m + 1}\right)\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos | forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))} [forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))]
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. m -> {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})) if m in NaturalsPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Lambda
#    parameter: 45
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})) if m in NaturalsPos ,  forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1}} ((a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}))
#    core type: Operation
#    operator: 15
#    operand: 5
# 4. (m in NaturalsPos) and [forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))]
#    core type: Operation
#    operator: 30
#    operands: 6
# 5. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1}) -> {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m in NaturalsPos, forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1}, ..a_{_a}.., a_{m + 1}, b_{1}, ..b_{_a}.., b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 27, 28
# 8. {(a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. m in NaturalsPos
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. forall_{a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m}} ((a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}))
#     core type: Operation
#     operator: 15
#     operand: 16
# 11. (a_{1}, ..a_{_a}.., a_{m + 1}) = (b_{1}, ..b_{a}.., b_{m + 1})
#     core type: Operation
#     operator: 49
#     operands: 17
# 12. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m + 1} = b_{m + 1})
#     core type: Operation
#     operator: 30
#     operands: 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (m, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 45, 19
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m}) -> {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 17. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{a}.., b_{m + 1}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m + 1} = b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{m}, b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 21. {(a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m}) if (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. (a_{1}, ..a_{_a}.., a_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (b_{1}, ..b_{a}.., b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m + 1} = b_{m + 1})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 44
#     end_index: 32
# 25. (a_{1}, ..a_{_a}.., a_{m}) = (b_{1}, ..b_{_a}.., b_{m})
#     core type: Operation
#     operator: 49
#     operands: 29
# 26. (a_{1} = b_{1}) and ..(a_{k} = b_{k}).. and (a_{m} = b_{m})
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. a_{1}, ..a_{_a}.., a_{m + 1}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 44
#     end_index: 32
# 28. b_{1}, ..b_{a}.., b_{m + 1}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 32
# 29. ((a_{1}, ..a_{_a}.., a_{m}), (b_{1}, ..b_{_a}.., b_{m}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{m} = b_{m})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. m + 1
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. (a_{1}, ..a_{_a}.., a_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. (b_{1}, ..b_{_a}.., b_{m})
#     core type: ExprTuple
#     sub-expressions: 40
# 35. (a_{1} = b_{1}), ..(a_{k} = b_{k}).., (a_{m} = b_{m})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 44
#     end_index: 45
# 36. b_{a}
#     core type: IndexedVar
# variable: 55
# index: 54
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 39. a_{1}, ..a_{_a}.., a_{m}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 44
#     end_index: 45
# 40. b_{1}, ..b_{_a}.., b_{m}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 41. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 56
#     body: 46
# 42. _a -> a_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 47
# 43. _a -> b_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. a_{k} = b_{k}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 51
# 48. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 51
# 49. =
#     core type: Literal
#     sub-expressions:
# 50. (a_{k}, b_{k})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 51. _a
#     core type: Variable
#     sub-expressions:
# 52. a_{k}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. b_{k}
#     core type: IndexedVar
# variable: 55
# index: 56
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. k
#     core type: Variable
#     sub-expressions:
