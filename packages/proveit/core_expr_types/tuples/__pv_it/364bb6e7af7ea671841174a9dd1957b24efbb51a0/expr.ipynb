# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import b, m
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals(Variable("_b", latexFormat = r"{_{-}b}"), [ExprRange(Variable("_a", latexFormat = r"{_{-}a}"), IndexedVar(b, Variable("_a", latexFormat = r"{_{-}a}")), one, m), IndexedVar(b, Add(m, one))])
# Out:
# expr: _b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}b} = \left(b_{1}, \ldots, b_{m}, b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _b = (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (_b, (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. _b
#    core type: Variable
#    sub-expressions:
# 4. (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. b_{1}, ..b_{_a}.., b_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 15
#    end_index: 14
# 6. b_{m + 1}
#    core type: IndexedVar
# variable: 12
# index: 8
# 7. _a -> b_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 9
# 8. m + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. b_{_a}
#    core type: IndexedVar
# variable: 12
# index: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
# 14. m
#     core type: Variable
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
