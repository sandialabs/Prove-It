# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, b, m
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = Add(m, one)
expr = ExprTuple([ExprRange(subExpr1, IndexedVar(a, subExpr1), one, subExpr2)], [ExprRange(subExpr1, IndexedVar(b, subExpr1), one, m), IndexedVar(b, subExpr2)])
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{m + 1}\right), \left(b_{1}, \ldots, b_{m}, b_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{m + 1}), (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1}, ..a_{_a}.., a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (b_{1}, ..b_{_a}.., b_{m}, b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. a_{1}, ..a_{_a}.., a_{m + 1}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 17
#    end_index: 8
# 4. b_{1}, ..b_{_a}.., b_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 17
#    end_index: 16
# 5. b_{m + 1}
#    core type: IndexedVar
# variable: 14
# index: 8
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 15
#    body: 9
# 7. _a -> b_{_a}
#    core type: Lambda
#    parameter: 15
#    body: 10
# 8. m + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a_{_a}
#    core type: IndexedVar
# variable: 13
# index: 15
# 10. b_{_a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
