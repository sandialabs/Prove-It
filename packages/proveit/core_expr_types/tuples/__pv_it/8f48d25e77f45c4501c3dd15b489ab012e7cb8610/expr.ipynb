# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#tuple_eq_def">tuple_eq_def</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.tuples._axioms_ import tuple_eq_def

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_eq_def
# Out:
# Passed sanity check: built 'tuple_eq_def' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_eq_def.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{i}, d}~\left(\begin{array}{c} \left(\left(a_{1}, \ldots, a_{i}, b\right) = \left(c_{1}, \ldots, c_{i}, d\right)\right) =  \\ \left(\left(\left(a_{1}, \ldots, a_{i}\right) = \left(c_{1}, \ldots, c_{i}\right)\right) \land \left(b = d\right)\right) \end{array}\right)\right]

# %%
# display the expression information
tuple_eq_def.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))) if i in Naturals.
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d} (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d) -> (((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)))
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 34, 11
# 9. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{i}, d)
#    core type: ExprTuple
#    sub-expressions: 29, 27, 30, 28
# 10. ((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)) =  \\ (((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))
#     core type: Operation
#     operator: 23
#     operands: 12
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. ((a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d), ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. (a_{1}, ..a_{_a}.., a_{i}, b) = (c_{1}, ..c_{_a}.., c_{i}, d)
#     core type: Operation
#     operator: 23
#     operands: 15
# 14. ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})) and (b = d)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. ((a_{1}, ..a_{_a}.., a_{i}, b), (c_{1}, ..c_{_a}.., c_{i}, d))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. ((a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i}), b = d)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (a_{1}, ..a_{_a}.., a_{i}, b)
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 19. (c_{1}, ..c_{_a}.., c_{i}, d)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 20. (a_{1}, ..a_{_a}.., a_{i}) = (c_{1}, ..c_{_a}.., c_{i})
#     core type: Operation
#     operator: 23
#     operands: 22
# 21. b = d
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. ((a_{1}, ..a_{_a}.., a_{i}), (c_{1}, ..c_{_a}.., c_{i}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (b, d)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (c_{1}, ..c_{_a}.., c_{i})
#     core type: ExprTuple
#     sub-expressions: 30
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. d
#     core type: Variable
#     sub-expressions:
# 29. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 33
#     end_index: 34
# 30. c_{1}, ..c_{_a}.., c_{i}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 39
#     body: 35
# 32. _a -> c_{_a}
#     core type: Lambda
#     parameter: 39
#     body: 36
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. i
#     core type: Variable
#     sub-expressions:
# 35. a_{_a}
#     core type: IndexedVar
# variable: 37
# index: 39
# 36. c_{_a}
#     core type: IndexedVar
# variable: 38
# index: 39
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. c
#     core type: Variable
#     sub-expressions:
# 39. _a
#     core type: Variable
#     sub-expressions:
