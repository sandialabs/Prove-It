# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#extended_range_len_typical_equiv">extended_range_len_typical_equiv</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import extended_range_len_typical_equiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr extended_range_len_typical_equiv
# Out:
# Passed sanity check: built 'extended_range_len_typical_equiv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(extended_range_len_typical_equiv.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j), f(j + 1)\right)| = |\left(i, \ldots, j + 1\right)|\right)\right]

# %%
# display the expression information
extended_range_len_typical_equiv.exprInfo()
# Out:
# 0. forall_{f} [forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. f -> [forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)]
#    core type: Lambda
#    parameter: 37
#    body: 2
# 2. forall_{i, j | |(f(i), ..f(a).., f(j))| in Naturals} (|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (i, j) -> {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i, j)
#    core type: ExprTuple
#    sub-expressions: 30, 35
# 6. {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Conditional
#    value: 7
# ...
