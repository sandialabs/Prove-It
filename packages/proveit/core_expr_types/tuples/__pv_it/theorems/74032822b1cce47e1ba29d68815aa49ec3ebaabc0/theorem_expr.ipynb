# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#merge_back">merge_back</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import merge_back

# %%
# check that the built expression is the same as the stored expression
assert merge_back.expr == stored_expr
assert merge_back.expr._style_id == stored_expr._style_id
print("Passed sanity check: merge_back matches stored_expr")
# Out:
# Passed sanity check: merge_back matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_back.latex())
# Out:
# \vdash \forall_{f, i, j, k~|~\left(k - i\right) \in \mathbb{N}, k = \left(j + 1\right)}~\left(\begin{array}{c} \left(f(i), \ldots, f(j), f(k)\right) =  \\ \left(f(i), \ldots, f(k)\right) \end{array}\right)

# %%
# display the expression information
merge_back.expr_info()
# Out:
# 0. forall_{f, i, j, k | (k - i) in Natural, k = (j + 1)} ((f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j, k) -> {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 29, 36, 33, 31
# 4. {(f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k)) if (k - i) in Natural ,  k = (j + 1).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i), ..f(a).., f(j), f(k)) =  \\ (f(i), ..f(a).., f(k))
#    core type: Operation
#    operator: 19
#    operands: 7
# 6. ((k - i) in Natural) and (k = (j + 1))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((f(i), ..f(a).., f(j), f(k)), (f(i), ..f(a).., f(k)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ((k - i) in Natural, k = (j + 1))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. (f(i), ..f(a).., f(j), f(k))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (f(i), ..f(a).., f(k))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (k - i) in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. k = (j + 1)
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 33
# 15. f(k)
#     core type: Operation
#     operator: 29
#     operand: 31
# 16. f(i), ..f(a).., f(k)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 31
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (k, j + 1)
#     core type: ExprTuple
#     sub-expressions: 31, 24
# 21. a -> f(a)
#     core type: Lambda
#     parameter: 30
#     body: 25
# 22. k - i
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. j + 1
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. f(a)
#     core type: Operation
#     operator: 29
#     operand: 30
# 26. (k, -i)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. k
#     core type: Variable
#     sub-expressions:
# 32. -i
#     core type: Operation
#     operator: 35
#     operand: 36
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
