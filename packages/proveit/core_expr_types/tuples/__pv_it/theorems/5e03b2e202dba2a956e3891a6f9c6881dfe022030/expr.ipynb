# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv_both
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda(f, Forall(instance_param_or_params = [a, b], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# f \mapsto \left[\forall_{a, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i + 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k + 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]]
#    core type: Lambda
#    parameter: 54
#    body: 2
# 1. (f)
#    core type: ExprTuple
#    sub-expressions: 54
# 2. forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. ((a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (a, b)
#    core type: ExprTuple
#    sub-expressions: 71, 73
# 6. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 13. a in Integer
#     core type: Operation
#     operator: 32
#     operands: 17
# 14. b in Integer
#     core type: Operation
#     operator: 32
#     operands: 18
# 15. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 70, 68, 58, 59
# 16. {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 71, 21
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 73, 21
# 19. (f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: Operation
#     operator: 35
#     operands: 22
# 20. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Integer
#     core type: Literal
#     sub-expressions:
# 22. ((f(i + a), f((i + 1) + a), ..., f(j + a)), (f(k + b), f((k + 1) + b), ..., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 25. (f(i + a), f((i + 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 31
# 27. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. (i + a) = (k + b)
#     core type: Operation
#     operator: 35
#     operands: 34
# 29. (j + a) = (l + b)
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. f(i + a), f((i + 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 70
#     end_index: 68
# 31. f(k + b), f((k + 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 58
#     end_index: 59
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 37. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 72
#     body: 45
# 38. _a -> f(_a + b)
#     core type: Lambda
#     parameter: 72
#     body: 47
# 39. (j + 1) - i
#     core type: Operation
#     operator: 66
#     operands: 48
# 40. Natural
#     core type: Literal
#     sub-expressions:
# 41. i + a
#     core type: Operation
#     operator: 66
#     operands: 49
# 42. k + b
#     core type: Operation
#     operator: 66
#     operands: 50
# 43. j + a
#     core type: Operation
#     operator: 66
#     operands: 51
# 44. l + b
#     core type: Operation
#     operator: 66
#     operands: 52
# 45. f(_a + a)
#     core type: Operation
#     operator: 54
#     operand: 60
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 47. f(_a + b)
#     core type: Operation
#     operator: 54
#     operand: 61
# 48. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 49. (i, a)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 50. (k, b)
#     core type: ExprTuple
#     sub-expressions: 58, 73
# 51. (j, a)
#     core type: ExprTuple
#     sub-expressions: 68, 71
# 52. (l, b)
#     core type: ExprTuple
#     sub-expressions: 59, 73
# 53. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. f
#     core type: Variable
#     sub-expressions:
# 55. (_a + b)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. j + 1
#     core type: Operation
#     operator: 66
#     operands: 62
# 57. -i
#     core type: Operation
#     operator: 63
#     operand: 70
# 58. k
#     core type: Variable
#     sub-expressions:
# 59. l
#     core type: Variable
#     sub-expressions:
# 60. _a + a
#     core type: Operation
#     operator: 66
#     operands: 65
# 61. _a + b
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. (i)
#     core type: ExprTuple
#     sub-expressions: 70
# 65. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 72, 71
# 66. +
#     core type: Literal
#     sub-expressions:
# 67. (_a, b)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. j
#     core type: Variable
#     sub-expressions:
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. i
#     core type: Variable
#     sub-expressions:
# 71. a
#     core type: Variable
#     sub-expressions:
# 72. _a
#     core type: Variable
#     sub-expressions:
# 73. b
#     core type: Variable
#     sub-expressions:
