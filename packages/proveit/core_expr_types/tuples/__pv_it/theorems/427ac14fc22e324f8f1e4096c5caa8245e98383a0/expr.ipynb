# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv_both
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [a, b], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i + 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k + 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]]
#    core type: Operation
#    operator: 11
#    operand: 2
# 1. (f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]]
#    core type: Lambda
#    parameter: 56
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 56
# 4. forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))]
#    core type: Operation
#    operator: 11
#    operand: 6
# 5. ((a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 7. (a, b)
#    core type: ExprTuple
#    sub-expressions: 73, 75
# 8. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. (a in Integer) and (b in Integer)
#     core type: Operation
#     operator: 25
#     operands: 13
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. ((i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. (i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 15. a in Integer
#     core type: Operation
#     operator: 34
#     operands: 19
# 16. b in Integer
#     core type: Operation
#     operator: 34
#     operands: 20
# 17. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 72, 70, 60, 61
# 18. {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 73, 23
# 20. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 75, 23
# 21. (f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: Operation
#     operator: 37
#     operands: 24
# 22. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. Integer
#     core type: Literal
#     sub-expressions:
# 24. ((f(i + a), f((i + 1) + a), ..., f(j + a)), (f(k + b), f((k + 1) + b), ..., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31
# 27. (f(i + a), f((i + 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 33
# 29. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. (i + a) = (k + b)
#     core type: Operation
#     operator: 37
#     operands: 36
# 31. (j + a) = (l + b)
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. f(i + a), f((i + 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 72
#     end_index: 70
# 33. f(k + b), f((k + 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 60
#     end_index: 61
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 36. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 39. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 74
#     body: 47
# 40. _a -> f(_a + b)
#     core type: Lambda
#     parameter: 74
#     body: 49
# 41. (j + 1) - i
#     core type: Operation
#     operator: 68
#     operands: 50
# 42. Natural
#     core type: Literal
#     sub-expressions:
# 43. i + a
#     core type: Operation
#     operator: 68
#     operands: 51
# 44. k + b
#     core type: Operation
#     operator: 68
#     operands: 52
# 45. j + a
#     core type: Operation
#     operator: 68
#     operands: 53
# 46. l + b
#     core type: Operation
#     operator: 68
#     operands: 54
# 47. f(_a + a)
#     core type: Operation
#     operator: 56
#     operand: 62
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 49. f(_a + b)
#     core type: Operation
#     operator: 56
#     operand: 63
# 50. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 51. (i, a)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 52. (k, b)
#     core type: ExprTuple
#     sub-expressions: 60, 75
# 53. (j, a)
#     core type: ExprTuple
#     sub-expressions: 70, 73
# 54. (l, b)
#     core type: ExprTuple
#     sub-expressions: 61, 75
# 55. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. f
#     core type: Variable
#     sub-expressions:
# 57. (_a + b)
#     core type: ExprTuple
#     sub-expressions: 63
# 58. j + 1
#     core type: Operation
#     operator: 68
#     operands: 64
# 59. -i
#     core type: Operation
#     operator: 65
#     operand: 72
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. l
#     core type: Variable
#     sub-expressions:
# 62. _a + a
#     core type: Operation
#     operator: 68
#     operands: 67
# 63. _a + b
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (i)
#     core type: ExprTuple
#     sub-expressions: 72
# 67. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 74, 73
# 68. +
#     core type: Literal
#     sub-expressions:
# 69. (_a, b)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 70. j
#     core type: Variable
#     sub-expressions:
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Variable
#     sub-expressions:
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. _a
#     core type: Variable
#     sub-expressions:
# 75. b
#     core type: Variable
#     sub-expressions:
