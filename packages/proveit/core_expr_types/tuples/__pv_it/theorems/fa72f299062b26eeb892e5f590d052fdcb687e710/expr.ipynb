# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), InSet(a, Integer))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a \mapsto \left\{\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k + 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right) \textrm{ if } a \in \mathbb{Z}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 59
#    body: 2
# 2. {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. a in Integer
#    core type: Operation
#    operator: 24
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (a, Integer)
#    core type: ExprTuple
#    sub-expressions: 59, 9
# 8. (i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 57, 55, 33, 35
# 11. {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 27
#     operands: 14
# 13. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. ((f(i), f(i + 1), ..., f(j)), (f(k + a), f((k + 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 17. (f(i), f(i + 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 22
# 18. (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 23
# 19. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. k = (i - a)
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. l = (j - a)
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 57
#     end_index: 55
# 23. f(k + a), f((k + 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 33
#     end_index: 35
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 29. _a -> f(_a)
#     core type: Lambda
#     parameter: 58
#     body: 37
# 30. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 58
#     body: 38
# 31. (j + 1) - i
#     core type: Operation
#     operator: 53
#     operands: 39
# 32. Natural
#     core type: Literal
#     sub-expressions:
# 33. k
#     core type: Variable
#     sub-expressions:
# 34. i - a
#     core type: Operation
#     operator: 53
#     operands: 40
# 35. l
#     core type: Variable
#     sub-expressions:
# 36. j - a
#     core type: Operation
#     operator: 53
#     operands: 41
# 37. f(_a)
#     core type: Operation
#     operator: 43
#     operand: 58
# 38. f(_a + a)
#     core type: Operation
#     operator: 43
#     operand: 48
# 39. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 40. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 57, 47
# 41. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 55, 47
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 43. f
#     core type: Variable
#     sub-expressions:
# 44. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. j + 1
#     core type: Operation
#     operator: 53
#     operands: 49
# 46. -i
#     core type: Operation
#     operator: 51
#     operand: 57
# 47. -a
#     core type: Operation
#     operator: 51
#     operand: 59
# 48. _a + a
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 50. (i)
#     core type: ExprTuple
#     sub-expressions: 57
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (a)
#     core type: ExprTuple
#     sub-expressions: 59
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. j
#     core type: Variable
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. a
#     core type: Variable
#     sub-expressions:
