# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, f, i
from proveit.core_expr_types import Len, f_1_to_i, range_1_to_i
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([f], Equals(Len([f_1_to_i]), Len([range_1_to_i]))), InSet(i, Natural))
# Out:
# expr: {forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|) if i in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{f}~\left(|\left(f(1), \ldots, f(i)\right)| = |\left(1, \ldots, i\right)|\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|) if i in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. i in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. f -> (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)
#    core type: Lambda
#    parameter: 26
#    body: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 23, 8
# 7. |(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (|(f(1), ..f(a).., f(i))|, |(1, ..k.., i)|)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. |(f(1), ..f(a).., f(i))|
#     core type: Operation
#     operator: 14
#     operand: 16
# 12. |(1, ..k.., i)|
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. ((f(1), ..f(a).., f(i)))
#     core type: ExprTuple
#     sub-expressions: 16
# 14. length
#     core type: Literal
#     sub-expressions:
# 15. ((1, ..k.., i))
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (f(1), ..f(a).., f(i))
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (1, ..k.., i)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. f(1), ..f(a).., f(i)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 22
#     end_index: 23
# 19. 1, ..k.., i
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. a -> f(a)
#     core type: Lambda
#     parameter: 27
#     body: 24
# 21. k -> k
#     core type: Lambda
#     parameter: 25
#     body: 25
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. i
#     core type: Variable
#     sub-expressions:
# 24. f(a)
#     core type: Operation
#     operator: 26
#     operand: 27
# 25. k
#     core type: Variable
#     sub-expressions:
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
