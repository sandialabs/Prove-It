# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [f], instance_expr = Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k + 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]]
#    core type: Operation
#    operator: 10
#    operand: 2
# 1. (f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]]
#    core type: Lambda
#    parameter: 48
#    body: 4
# 3. (f)
#    core type: ExprTuple
#    sub-expressions: 48
# 4. forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]
#    core type: Operation
#    operator: 10
#    operand: 6
# 5. (a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 64
#    body: 7
# 7. {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. a in Integer
#    core type: Operation
#    operator: 29
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 14
# 13. (i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 14. Integer
#     core type: Literal
#     sub-expressions:
# 15. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 62, 60, 38, 40
# 16. {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 17
#     condition: 18
# 17. (f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 32
#     operands: 19
# 18. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. ((f(i), f(i + 1), ..., f(j)), (f(k + a), f((k + 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 22. (f(i), f(i + 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. k = (i - a)
#     core type: Operation
#     operator: 32
#     operands: 31
# 26. l = (j - a)
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 62
#     end_index: 60
# 28. f(k + a), f((k + 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 38
#     end_index: 40
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 31. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 34. _a -> f(_a)
#     core type: Lambda
#     parameter: 63
#     body: 42
# 35. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 63
#     body: 43
# 36. (j + 1) - i
#     core type: Operation
#     operator: 58
#     operands: 44
# 37. Natural
#     core type: Literal
#     sub-expressions:
# 38. k
#     core type: Variable
#     sub-expressions:
# 39. i - a
#     core type: Operation
#     operator: 58
#     operands: 45
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. j - a
#     core type: Operation
#     operator: 58
#     operands: 46
# 42. f(_a)
#     core type: Operation
#     operator: 48
#     operand: 63
# 43. f(_a + a)
#     core type: Operation
#     operator: 48
#     operand: 53
# 44. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 45. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 62, 52
# 46. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 60, 52
# 47. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. j + 1
#     core type: Operation
#     operator: 58
#     operands: 54
# 51. -i
#     core type: Operation
#     operator: 56
#     operand: 62
# 52. -a
#     core type: Operation
#     operator: 56
#     operand: 64
# 53. _a + a
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 55. (i)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (a)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. j
#     core type: Variable
#     sub-expressions:
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. i
#     core type: Variable
#     sub-expressions:
# 63. _a
#     core type: Variable
#     sub-expressions:
# 64. a
#     core type: Variable
#     sub-expressions:
