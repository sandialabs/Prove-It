# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, i, j, k, l
from proveit.core_expr_types.tuples import neg_shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = neg_shift_equiv, conditions = [InSet(subtract(subtract(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k, l~|~\left(\left(j - 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i - 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k - 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 56, 54, 43, 44
# 5. {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. (((j - 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((f(i), f(i - 1), ..., f(j)), (f(k + a), f((k - 1) + a), ..., f(l + a)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (((j - 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. (f(i), f(i - 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (f(k + a), f((k - 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 17
# 13. ((j - 1) - i) in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. k = (i - a)
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. l = (j - a)
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. f(i), f(i - 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 46
#     end_index: 24
# 17. f(k + a), f((k - 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. ((j - 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 20. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 43, 30
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 44, 31
# 23. _a -> f(-_a)
#     core type: Lambda
#     parameter: 63
#     body: 32
# 24. -j
#     core type: Operation
#     operator: 60
#     operand: 54
# 25. _a -> f(-_a + a)
#     core type: Lambda
#     parameter: 63
#     body: 34
# 26. -k
#     core type: Operation
#     operator: 60
#     operand: 43
# 27. -l
#     core type: Operation
#     operator: 60
#     operand: 44
# 28. (j - 1) - i
#     core type: Operation
#     operator: 52
#     operands: 37
# 29. Natural
#     core type: Literal
#     sub-expressions:
# 30. i - a
#     core type: Operation
#     operator: 52
#     operands: 38
# 31. j - a
#     core type: Operation
#     operator: 52
#     operands: 39
# 32. f(-_a)
#     core type: Operation
#     operator: 41
#     operand: 57
# 33. (j)
#     core type: ExprTuple
#     sub-expressions: 54
# 34. f(-_a + a)
#     core type: Operation
#     operator: 41
#     operand: 48
# 35. (k)
#     core type: ExprTuple
#     sub-expressions: 43
# 36. (l)
#     core type: ExprTuple
#     sub-expressions: 44
# 37. (j - 1, -i)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 38. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 56, 47
# 39. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 54, 47
# 40. (-_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. (-_a + a)
#     core type: ExprTuple
#     sub-expressions: 48
# 43. k
#     core type: Variable
#     sub-expressions:
# 44. l
#     core type: Variable
#     sub-expressions:
# 45. j - 1
#     core type: Operation
#     operator: 52
#     operands: 49
# 46. -i
#     core type: Operation
#     operator: 60
#     operand: 56
# 47. -a
#     core type: Operation
#     operator: 60
#     operand: 58
# 48. -_a + a
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. (i)
#     core type: ExprTuple
#     sub-expressions: 56
# 51. (a)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (-_a, a)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. -1
#     core type: Operation
#     operator: 60
#     operand: 62
# 56. i
#     core type: Variable
#     sub-expressions:
# 57. -_a
#     core type: Operation
#     operator: 60
#     operand: 63
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. -
#     core type: Literal
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. _a
#     core type: Variable
#     sub-expressions:
