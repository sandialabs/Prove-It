# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Len, f_1_to_n, i_1_to_n, j_1_to_n
from proveit.core_expr_types.tuples import f_ik_to_jk__1_to_n, range_len_conditions, range_len_sum
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([f_1_to_n, i_1_to_n, j_1_to_n], Equals(Len([f_ik_to_jk__1_to_n]), range_len_sum).with_wrapping_at(1), condition = range_len_conditions)
# Out:
# expr: forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f_{1}, \ldots, f_{n}, i_{1}, \ldots, i_{n}, j_{1}, \ldots, j_{n}~|~\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}, \ldots, \left(j_{n} - i_{n} + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} |\left(f_{1}(i_{1}), \ldots, f_{1}(j_{1}), \ldots\ldots, f_{n}(i_{n}), \ldots, f_{n}(j_{n})\right)| \\  = \left(\left(j_{1} - i_{1} + 1\right) + \ldots + \left(j_{n} - i_{n} + 1\right)\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n} | (j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural} (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n}) -> {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural).
#    core type: Conditional
#    value: 8
#    condition: 9
# 5. f_{1}, ..f_{_a}.., f_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 45
#    end_index: 36
# 6. i_{1}, ..i_{_a}.., i_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 45
#    end_index: 36
# 7. j_{1}, ..j_{_a}.., j_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 45
#    end_index: 36
# 8. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. ((j_{1} - i_{1} + 1) in Natural) and ..((j_{k} - i_{k} + 1) in Natural).. and ((j_{n} - i_{n} + 1) in Natural)
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. _a -> f_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 17
# 11. _a -> i_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 18
# 12. _a -> j_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|, (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. ((j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural)
#     core type: ExprTuple
#     sub-expressions: 22
# 17. f_{_a}
#     core type: IndexedVar
# variable: 53
# index: 23
# 18. i_{_a}
#     core type: IndexedVar
# variable: 52
# index: 23
# 19. j_{_a}
#     core type: IndexedVar
# variable: 47
# index: 23
# 20. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|
#     core type: Operation
#     operator: 24
#     operand: 28
# 21. (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)
#     core type: Operation
#     operator: 40
#     operands: 26
# 22. ((j_{1} - i_{1} + 1) in Natural), ..((j_{k} - i_{k} + 1) in Natural).., ((j_{n} - i_{n} + 1) in Natural)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 45
#     end_index: 36
# 23. _a
#     core type: Variable
#     sub-expressions:
# 24. length
#     core type: Literal
#     sub-expressions:
# 25. ((f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})))
#     core type: ExprTuple
#     sub-expressions: 28
# 26. (j_{1} - i_{1} + 1, ..j_{k} - i_{k} + 1.., j_{n} - i_{n} + 1)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. k -> ((j_{k} - i_{k} + 1) in Natural)
#     core type: Lambda
#     parameter: 54
#     body: 30
# 28. (f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))
#     core type: ExprTuple
#     sub-expressions: 31
# 29. (j_{1} - i_{1} + 1), ..(j_{k} - i_{k} + 1).., (j_{n} - i_{n} + 1)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 45
#     end_index: 36
# 30. (j_{k} - i_{k} + 1) in Natural
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 45
#     end_index: 36
# 32. k -> (j_{k} - i_{k} + 1)
#     core type: Lambda
#     parameter: 54
#     body: 37
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (j_{k} - i_{k} + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. k -> f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: Lambda
#     parameter: 54
#     body: 39
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. j_{k} - i_{k} + 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. Natural
#     core type: Literal
#     sub-expressions:
# 39. f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 49
#     end_index: 43
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (j_{k}, -i_{k}, 1)
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 42. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 51
#     body: 46
# 43. j_{k}
#     core type: IndexedVar
# variable: 47
# index: 54
# 44. -i_{k}
#     core type: Operation
#     operator: 48
#     operand: 49
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. f_{k}(x)
#     core type: Operation
#     operator: 50
#     operand: 51
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. -
#     core type: Literal
#     sub-expressions:
# 49. i_{k}
#     core type: IndexedVar
# variable: 52
# index: 54
# 50. f_{k}
#     core type: IndexedVar
# variable: 53
# index: 54
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. i
#     core type: Variable
#     sub-expressions:
# 53. f
#     core type: Variable
#     sub-expressions:
# 54. k
#     core type: Variable
#     sub-expressions:
