# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#shift_equivalence_both">shift_equivalence_both</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import shift_equivalence_both

# %%
# check that the built expression is the same as the stored expression
assert shift_equivalence_both.expr == stored_expr
assert shift_equivalence_both.expr._style_id == stored_expr._style_id
print("Passed sanity check: shift_equivalence_both matches stored_expr")
# Out:
# Passed sanity check: shift_equivalence_both matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(shift_equivalence_both.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f(i + a), \ldots, f(j + a)\right) = \left(f(k + b), \ldots, f(l + b)\right)\right)\right]\right]

# %%
# display the expression information
shift_equivalence_both.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. f -> [forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]]
#    core type: Lambda
#    parameter: 51
#    body: 2
# 2. forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))]
#    core type: Operation
#    operator: 8
#    operand: 3
# 3. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b)
#    core type: ExprTuple
#    sub-expressions: 62, 64
# 5. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 20
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (i, j, k, l) -> {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. (a in Integer, b in Integer)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 63, 65, 61, 55
# 12. {(f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. a in Integer
#     core type: Operation
#     operator: 30
#     operands: 17
# 14. b in Integer
#     core type: Operation
#     operator: 30
#     operands: 18
# 15. (f(i + a), ..f(k + a).., f(j + a)) = (f(k + b), ..f(i + b).., f(l + b))
#     core type: Operation
#     operator: 33
#     operands: 19
# 16. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 22
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 22
# 19. ((f(i + a), ..f(k + a).., f(j + a)), (f(k + b), ..f(i + b).., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. (f(i + a), ..f(k + a).., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (f(k + b), ..f(i + b).., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 29
# 25. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. (i + a) = (k + b)
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. (j + a) = (l + b)
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. f(i + a), ..f(k + a).., f(j + a)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 63
#     end_index: 65
# 29. f(k + b), ..f(i + b).., f(l + b)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 61
#     end_index: 55
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 32. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 35. k -> f(k + a)
#     core type: Lambda
#     parameter: 61
#     body: 43
# 36. i -> f(i + b)
#     core type: Lambda
#     parameter: 63
#     body: 44
# 37. (j + 1) - i
#     core type: Operation
#     operator: 58
#     operands: 45
# 38. Natural
#     core type: Literal
#     sub-expressions:
# 39. i + a
#     core type: Operation
#     operator: 58
#     operands: 46
# 40. k + b
#     core type: Operation
#     operator: 58
#     operands: 47
# 41. j + a
#     core type: Operation
#     operator: 58
#     operands: 48
# 42. l + b
#     core type: Operation
#     operator: 58
#     operands: 49
# 43. f(k + a)
#     core type: Operation
#     operator: 51
#     operand: 50
# 44. f(i + b)
#     core type: Operation
#     operator: 51
#     operand: 52
# 45. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 46. (i, a)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 47. (k, b)
#     core type: ExprTuple
#     sub-expressions: 61, 64
# 48. (j, a)
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 49. (l, b)
#     core type: ExprTuple
#     sub-expressions: 55, 64
# 50. k + a
#     core type: Operation
#     operator: 58
#     operands: 56
# 51. f
#     core type: Variable
#     sub-expressions:
# 52. i + b
#     core type: Operation
#     operator: 58
#     operands: 57
# 53. j + 1
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. -i
#     core type: Operation
#     operator: 60
#     operand: 63
# 55. l
#     core type: Variable
#     sub-expressions:
# 56. (k, a)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. (i, b)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 60. -
#     core type: Literal
#     sub-expressions:
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. a
#     core type: Variable
#     sub-expressions:
# 63. i
#     core type: Variable
#     sub-expressions:
# 64. b
#     core type: Variable
#     sub-expressions:
# 65. j
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
