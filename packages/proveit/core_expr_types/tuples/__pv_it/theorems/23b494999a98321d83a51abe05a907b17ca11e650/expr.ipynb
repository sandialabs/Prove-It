# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv_both
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), And(InSet(a, Integer), InSet(b, Integer))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i + 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k + 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 67, 69
# 2. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 9. a in Integer
#    core type: Operation
#    operator: 28
#    operands: 13
# 10. b in Integer
#     core type: Operation
#     operator: 28
#     operands: 14
# 11. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 66, 64, 54, 55
# 12. {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 67, 17
# 14. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 69, 17
# 15. (f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: Operation
#     operator: 31
#     operands: 18
# 16. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. Integer
#     core type: Literal
#     sub-expressions:
# 18. ((f(i + a), f((i + 1) + a), ..., f(j + a)), (f(k + b), f((k + 1) + b), ..., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. (f(i + a), f((i + 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. (i + a) = (k + b)
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. (j + a) = (l + b)
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. f(i + a), f((i + 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 66
#     end_index: 64
# 27. f(k + b), f((k + 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 54
#     end_index: 55
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 68
#     body: 41
# 34. _a -> f(_a + b)
#     core type: Lambda
#     parameter: 68
#     body: 43
# 35. (j + 1) - i
#     core type: Operation
#     operator: 62
#     operands: 44
# 36. Natural
#     core type: Literal
#     sub-expressions:
# 37. i + a
#     core type: Operation
#     operator: 62
#     operands: 45
# 38. k + b
#     core type: Operation
#     operator: 62
#     operands: 46
# 39. j + a
#     core type: Operation
#     operator: 62
#     operands: 47
# 40. l + b
#     core type: Operation
#     operator: 62
#     operands: 48
# 41. f(_a + a)
#     core type: Operation
#     operator: 50
#     operand: 56
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 43. f(_a + b)
#     core type: Operation
#     operator: 50
#     operand: 57
# 44. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 45. (i, a)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 46. (k, b)
#     core type: ExprTuple
#     sub-expressions: 54, 69
# 47. (j, a)
#     core type: ExprTuple
#     sub-expressions: 64, 67
# 48. (l, b)
#     core type: ExprTuple
#     sub-expressions: 55, 69
# 49. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 56
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (_a + b)
#     core type: ExprTuple
#     sub-expressions: 57
# 52. j + 1
#     core type: Operation
#     operator: 62
#     operands: 58
# 53. -i
#     core type: Operation
#     operator: 59
#     operand: 66
# 54. k
#     core type: Variable
#     sub-expressions:
# 55. l
#     core type: Variable
#     sub-expressions:
# 56. _a + a
#     core type: Operation
#     operator: 62
#     operands: 61
# 57. _a + b
#     core type: Operation
#     operator: 62
#     operands: 63
# 58. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (i)
#     core type: ExprTuple
#     sub-expressions: 66
# 61. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 68, 67
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (_a, b)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. j
#     core type: Variable
#     sub-expressions:
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. i
#     core type: Variable
#     sub-expressions:
# 67. a
#     core type: Variable
#     sub-expressions:
# 68. _a
#     core type: Variable
#     sub-expressions:
# 69. b
#     core type: Variable
#     sub-expressions:
