# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, i, j, k, l
from proveit.core_expr_types.tuples import neg_shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = neg_shift_equiv, conditions = [InSet(subtract(subtract(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), domain = Integer)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j - 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i - 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k - 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a in Integer} [forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (a -> {forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. a -> {forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 65
#    body: 3
# 3. {forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. a in Integer
#    core type: Operation
#    operator: 25
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a, Integer)
#    core type: ExprTuple
#    sub-expressions: 65, 10
# 9. (i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 63, 61, 50, 51
# 12. {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. (f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 28
#     operands: 15
# 14. (((j - 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. ((f(i), f(i - 1), ..., f(j)), (f(k + a), f((k - 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (((j - 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 18. (f(i), f(i - 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 23
# 19. (f(k + a), f((k - 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 24
# 20. ((j - 1) - i) in Natural
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. k = (i - a)
#     core type: Operation
#     operator: 28
#     operands: 27
# 22. l = (j - a)
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. f(i), f(i - 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 53
#     end_index: 31
# 24. f(k + a), f((k - 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. ((j - 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 27. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 50, 37
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 51, 38
# 30. _a -> f(-_a)
#     core type: Lambda
#     parameter: 70
#     body: 39
# 31. -j
#     core type: Operation
#     operator: 67
#     operand: 61
# 32. _a -> f(-_a + a)
#     core type: Lambda
#     parameter: 70
#     body: 41
# 33. -k
#     core type: Operation
#     operator: 67
#     operand: 50
# 34. -l
#     core type: Operation
#     operator: 67
#     operand: 51
# 35. (j - 1) - i
#     core type: Operation
#     operator: 59
#     operands: 44
# 36. Natural
#     core type: Literal
#     sub-expressions:
# 37. i - a
#     core type: Operation
#     operator: 59
#     operands: 45
# 38. j - a
#     core type: Operation
#     operator: 59
#     operands: 46
# 39. f(-_a)
#     core type: Operation
#     operator: 48
#     operand: 64
# 40. (j)
#     core type: ExprTuple
#     sub-expressions: 61
# 41. f(-_a + a)
#     core type: Operation
#     operator: 48
#     operand: 55
# 42. (k)
#     core type: ExprTuple
#     sub-expressions: 50
# 43. (l)
#     core type: ExprTuple
#     sub-expressions: 51
# 44. (j - 1, -i)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 45. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 63, 54
# 46. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 61, 54
# 47. (-_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. (-_a + a)
#     core type: ExprTuple
#     sub-expressions: 55
# 50. k
#     core type: Variable
#     sub-expressions:
# 51. l
#     core type: Variable
#     sub-expressions:
# 52. j - 1
#     core type: Operation
#     operator: 59
#     operands: 56
# 53. -i
#     core type: Operation
#     operator: 67
#     operand: 63
# 54. -a
#     core type: Operation
#     operator: 67
#     operand: 65
# 55. -_a + a
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. (i)
#     core type: ExprTuple
#     sub-expressions: 63
# 58. (a)
#     core type: ExprTuple
#     sub-expressions: 65
# 59. +
#     core type: Literal
#     sub-expressions:
# 60. (-_a, a)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. j
#     core type: Variable
#     sub-expressions:
# 62. -1
#     core type: Operation
#     operator: 67
#     operand: 69
# 63. i
#     core type: Variable
#     sub-expressions:
# 64. -_a
#     core type: Operation
#     operator: 67
#     operand: 70
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 70
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. _a
#     core type: Variable
#     sub-expressions:
