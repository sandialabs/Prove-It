# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, a, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(f, Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), domain = Integer)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(f \mapsto \left[\forall_{a \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k + 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right)\right]\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]]
#    core type: Lambda
#    parameter: 47
#    body: 3
# 2. (f)
#    core type: ExprTuple
#    sub-expressions: 47
# 3. forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]
#    core type: Operation
#    operator: 9
#    operand: 5
# 4. (a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 63
#    body: 6
# 6. {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. a in Integer
#    core type: Operation
#    operator: 28
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 13
# 12. (i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 13. Integer
#     core type: Literal
#     sub-expressions:
# 14. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 61, 59, 37, 39
# 15. {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. (f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 31
#     operands: 18
# 17. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. ((f(i), f(i + 1), ..., f(j)), (f(k + a), f((k + 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. (f(i), f(i + 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 27
# 23. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. k = (i - a)
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. l = (j - a)
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 61
#     end_index: 59
# 27. f(k + a), f((k + 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 37
#     end_index: 39
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. _a -> f(_a)
#     core type: Lambda
#     parameter: 62
#     body: 41
# 34. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 62
#     body: 42
# 35. (j + 1) - i
#     core type: Operation
#     operator: 57
#     operands: 43
# 36. Natural
#     core type: Literal
#     sub-expressions:
# 37. k
#     core type: Variable
#     sub-expressions:
# 38. i - a
#     core type: Operation
#     operator: 57
#     operands: 44
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. j - a
#     core type: Operation
#     operator: 57
#     operands: 45
# 41. f(_a)
#     core type: Operation
#     operator: 47
#     operand: 62
# 42. f(_a + a)
#     core type: Operation
#     operator: 47
#     operand: 52
# 43. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 61, 51
# 45. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 59, 51
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 47. f
#     core type: Variable
#     sub-expressions:
# 48. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. j + 1
#     core type: Operation
#     operator: 57
#     operands: 53
# 50. -i
#     core type: Operation
#     operator: 55
#     operand: 61
# 51. -a
#     core type: Operation
#     operator: 55
#     operand: 63
# 52. _a + a
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 54. (i)
#     core type: ExprTuple
#     sub-expressions: 61
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (a)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. j
#     core type: Variable
#     sub-expressions:
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. i
#     core type: Variable
#     sub-expressions:
# 62. _a
#     core type: Variable
#     sub-expressions:
# 63. a
#     core type: Variable
#     sub-expressions:
