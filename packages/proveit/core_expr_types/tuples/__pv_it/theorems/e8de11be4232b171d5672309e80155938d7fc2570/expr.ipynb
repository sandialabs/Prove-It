# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Len, f_1_to_n, i_1_to_n, j_1_to_n
from proveit.core_expr_types.tuples import f_ik_to_jk__1_to_n, range_len_conditions, range_len_sum
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [f_1_to_n, i_1_to_n, j_1_to_n], instance_expr = Equals(Len(operands = [f_ik_to_jk__1_to_n]), range_len_sum).with_wrapping_at(1), condition = range_len_conditions).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{f_{1}, f_{2}, \ldots, f_{n}, i_{1}, i_{2}, \ldots, i_{n}, j_{1}, j_{2}, \ldots, j_{n}~|~\left(\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}\right), \left(\left(j_{2} - i_{2} + 1\right) \in \mathbb{N}\right), \ldots, \left(\left(j_{n} - i_{n} + 1\right) \in \mathbb{N}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} |\left(f_{1}\left(i_{1}\right), f_{1}\left(i_{1} + 1\right), \ldots, f_{1}\left(j_{1}\right), f_{2}\left(i_{2}\right), f_{2}\left(i_{2} + 1\right), \ldots, f_{2}\left(j_{2}\right), \ldots\ldots, f_{n}\left(i_{n}\right), f_{n}\left(i_{n} + 1\right), \ldots, f_{n}\left(j_{n}\right)\right)| \\  = \left(\left(j_{1} - i_{1} + 1\right) +  \left(j_{2} - i_{2} + 1\right) +  \ldots +  \left(j_{n} - i_{n} + 1\right)\right) \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n} | ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)} (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n}) -> {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n}) -> {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f_{1}, f_{2}, ..., f_{n},i_{1}, i_{2}, ..., i_{n},j_{1}, j_{2}, ..., j_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).
#    core type: Conditional
#    value: 9
#    condition: 10
# 6. f_{1}, f_{2}, ..., f_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 45
#    end_index: 31
# 7. i_{1}, i_{2}, ..., i_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 45
#    end_index: 31
# 8. j_{1}, j_{2}, ..., j_{n}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 45
#    end_index: 31
# 9. |(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural)
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. _a -> f_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 18
# 12. _a -> i_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 13. _a -> j_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 43
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))|, (j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural))
#     core type: ExprTuple
#     sub-expressions: 21
# 18. f_{_a}
#     core type: IndexedVar
# variable: 50
# index: 56
# 19. |(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))|
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)
#     core type: Operation
#     operator: 40
#     operands: 24
# 21. ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 45
#     end_index: 31
# 22. length
#     core type: Literal
#     sub-expressions:
# 23. (f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. ((j_{1} - i_{1} + 1), (j_{2} - i_{2} + 1), ..., (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 27
# 25. _a -> ((j_{_a} - i_{_a} + 1) in Natural)
#     core type: Lambda
#     parameter: 56
#     body: 28
# 26. f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n})
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 45
#     end_index: 31
# 27. (j_{1} - i_{1} + 1), (j_{2} - i_{2} + 1), ..., (j_{n} - i_{n} + 1)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 45
#     end_index: 31
# 28. (j_{_a} - i_{_a} + 1) in Natural
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. _b -> f_{_b}(i_{_b}), f_{_b}(i_{_b} + 1), ..., f_{_b}(j_{_b})
#     core type: Lambda
#     parameter: 53
#     body: 34
# 30. _a -> (j_{_a} - i_{_a} + 1)
#     core type: Lambda
#     parameter: 56
#     body: 35
# 31. n
#     core type: Variable
#     sub-expressions:
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (j_{_a} - i_{_a} + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. f_{_b}(i_{_b}), f_{_b}(i_{_b} + 1), ..., f_{_b}(j_{_b})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 35. j_{_a} - i_{_a} + 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. Natural
#     core type: Literal
#     sub-expressions:
# 37. _a -> f_{_b}(_a)
#     core type: Lambda
#     parameter: 56
#     body: 42
# 38. i_{_b}
#     core type: IndexedVar
# variable: 54
# index: 53
# 39. j_{_b}
#     core type: IndexedVar
# variable: 47
# index: 53
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (j_{_a}, -i_{_a}, 1)
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 42. f_{_b}(_a)
#     core type: Operation
#     operator: 46
#     operand: 56
# 43. j_{_a}
#     core type: IndexedVar
# variable: 47
# index: 56
# 44. -i_{_a}
#     core type: Operation
#     operator: 48
#     operand: 52
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. f_{_b}
#     core type: IndexedVar
# variable: 50
# index: 53
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. -
#     core type: Literal
#     sub-expressions:
# 49. (i_{_a})
#     core type: ExprTuple
#     sub-expressions: 52
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (_b)
#     core type: ExprTuple
#     sub-expressions: 53
# 52. i_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. _b
#     core type: Variable
#     sub-expressions:
# 54. i
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
