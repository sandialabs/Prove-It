# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, i, j, k, l
from proveit.core_expr_types.tuples import neg_shift_equiv_both
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = neg_shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i - 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k - 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((i, j, k, l) -> {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (i, j, k, l) -> {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 60, 58, 49, 50
# 5. {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b))
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((f(i + a), f((i - 1) + a), ..., f(j + a)), (f(k + b), f((k - 1) + b), ..., f(l + b)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. (f(i + a), f((i - 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (f(k + b), f((k - 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 17
# 13. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (i + a) = (k + b)
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. (j + a) = (l + b)
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. f(i + a), f((i - 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 48
#     end_index: 24
# 17. f(k + b), f((k - 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 20. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 23. _a -> f(-_a + a)
#     core type: Lambda
#     parameter: 66
#     body: 34
# 24. -j
#     core type: Operation
#     operator: 64
#     operand: 58
# 25. _a -> f(-_a + b)
#     core type: Lambda
#     parameter: 66
#     body: 36
# 26. -k
#     core type: Operation
#     operator: 64
#     operand: 49
# 27. -l
#     core type: Operation
#     operator: 64
#     operand: 50
# 28. (j + 1) - i
#     core type: Operation
#     operator: 56
#     operands: 39
# 29. Natural
#     core type: Literal
#     sub-expressions:
# 30. i + a
#     core type: Operation
#     operator: 56
#     operands: 40
# 31. k + b
#     core type: Operation
#     operator: 56
#     operands: 41
# 32. j + a
#     core type: Operation
#     operator: 56
#     operands: 42
# 33. l + b
#     core type: Operation
#     operator: 56
#     operands: 43
# 34. f(-_a + a)
#     core type: Operation
#     operator: 45
#     operand: 51
# 35. (j)
#     core type: ExprTuple
#     sub-expressions: 58
# 36. f(-_a + b)
#     core type: Operation
#     operator: 45
#     operand: 52
# 37. (k)
#     core type: ExprTuple
#     sub-expressions: 49
# 38. (l)
#     core type: ExprTuple
#     sub-expressions: 50
# 39. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 40. (i, a)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 41. (k, b)
#     core type: ExprTuple
#     sub-expressions: 49, 63
# 42. (j, a)
#     core type: ExprTuple
#     sub-expressions: 58, 61
# 43. (l, b)
#     core type: ExprTuple
#     sub-expressions: 50, 63
# 44. (-_a + a)
#     core type: ExprTuple
#     sub-expressions: 51
# 45. f
#     core type: Variable
#     sub-expressions:
# 46. (-_a + b)
#     core type: ExprTuple
#     sub-expressions: 52
# 47. j + 1
#     core type: Operation
#     operator: 56
#     operands: 53
# 48. -i
#     core type: Operation
#     operator: 64
#     operand: 60
# 49. k
#     core type: Variable
#     sub-expressions:
# 50. l
#     core type: Variable
#     sub-expressions:
# 51. -_a + a
#     core type: Operation
#     operator: 56
#     operands: 55
# 52. -_a + b
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. (i)
#     core type: ExprTuple
#     sub-expressions: 60
# 55. (-_a, a)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (-_a, b)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. j
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. a
#     core type: Variable
#     sub-expressions:
# 62. -_a
#     core type: Operation
#     operator: 64
#     operand: 66
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
