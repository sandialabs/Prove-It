# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv_both
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), And(InSet(a, Integer), InSet(b, Integer)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i + 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k + 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (i, j, k, l) -> {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. a in Integer
#    core type: Operation
#    operator: 26
#    operands: 11
# 8. b in Integer
#    core type: Operation
#    operator: 26
#    operands: 12
# 9. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 64, 62, 52, 53
# 10. {(f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 15
# 12. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 67, 15
# 13. (f(i + a), f((i + 1) + a), ..., f(j + a)) = (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: Operation
#     operator: 29
#     operands: 16
# 14. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Integer
#     core type: Literal
#     sub-expressions:
# 16. ((f(i + a), f((i + 1) + a), ..., f(j + a)), (f(k + b), f((k + 1) + b), ..., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 19. (f(i + a), f((i + 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 24
# 20. (f(k + b), f((k + 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 25
# 21. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. (i + a) = (k + b)
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. (j + a) = (l + b)
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. f(i + a), f((i + 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 64
#     end_index: 62
# 25. f(k + b), f((k + 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 52
#     end_index: 53
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 66
#     body: 39
# 32. _a -> f(_a + b)
#     core type: Lambda
#     parameter: 66
#     body: 41
# 33. (j + 1) - i
#     core type: Operation
#     operator: 60
#     operands: 42
# 34. Natural
#     core type: Literal
#     sub-expressions:
# 35. i + a
#     core type: Operation
#     operator: 60
#     operands: 43
# 36. k + b
#     core type: Operation
#     operator: 60
#     operands: 44
# 37. j + a
#     core type: Operation
#     operator: 60
#     operands: 45
# 38. l + b
#     core type: Operation
#     operator: 60
#     operands: 46
# 39. f(_a + a)
#     core type: Operation
#     operator: 48
#     operand: 54
# 40. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 41. f(_a + b)
#     core type: Operation
#     operator: 48
#     operand: 55
# 42. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 43. (i, a)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 44. (k, b)
#     core type: ExprTuple
#     sub-expressions: 52, 67
# 45. (j, a)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 46. (l, b)
#     core type: ExprTuple
#     sub-expressions: 53, 67
# 47. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 54
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. (_a + b)
#     core type: ExprTuple
#     sub-expressions: 55
# 50. j + 1
#     core type: Operation
#     operator: 60
#     operands: 56
# 51. -i
#     core type: Operation
#     operator: 57
#     operand: 64
# 52. k
#     core type: Variable
#     sub-expressions:
# 53. l
#     core type: Variable
#     sub-expressions:
# 54. _a + a
#     core type: Operation
#     operator: 60
#     operands: 59
# 55. _a + b
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (i)
#     core type: ExprTuple
#     sub-expressions: 64
# 59. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 66, 65
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (_a, b)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 62. j
#     core type: Variable
#     sub-expressions:
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. i
#     core type: Variable
#     sub-expressions:
# 65. a
#     core type: Variable
#     sub-expressions:
# 66. _a
#     core type: Variable
#     sub-expressions:
# 67. b
#     core type: Variable
#     sub-expressions:
