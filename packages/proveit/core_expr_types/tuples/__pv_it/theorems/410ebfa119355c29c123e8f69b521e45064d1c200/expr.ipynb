# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j, k
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k, d_1_to_j
from proveit.logic import Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [i, j, k], instance_expr = Forall(instance_param_or_params = [a_1_to_i, b_1_to_j, c_1_to_k, d_1_to_j], instance_expr = Equals([a_1_to_i, b_1_to_j, c_1_to_k], [a_1_to_i, d_1_to_j, c_1_to_k]).with_wrapping_at(2), condition = Equals([b_1_to_j], [d_1_to_j])), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, b_{1}, b_{2}, \ldots, b_{j}, c_{1}, c_{2}, \ldots, c_{k}, d_{1}, d_{2}, \ldots, d_{j}~|~\left(b_{1}, b_{2}, \ldots, b_{j}\right) = \left(d_{1}, d_{2}, \ldots, d_{j}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(a_{1}, a_{2}, \ldots, a_{i},b_{1}, b_{2}, \ldots, b_{j},c_{1}, c_{2}, \ldots, c_{k}\right) =  \\ \left(a_{1}, a_{2}, \ldots, a_{i},d_{1}, d_{2}, \ldots, d_{j},c_{1}, c_{2}, \ldots, c_{k}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k})) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 36, 42, 38
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k})) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j} | (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})} ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j}) -> {(a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}) if (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}, d_{1}, d_{2}, ..., d_{j}) -> {(a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}) if (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j}).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 12. i in Natural
#     core type: Operation
#     operator: 19
#     operands: 17
# 13. j in Natural
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. k in Natural
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k},d_{1}, d_{2}, ..., d_{j})
#     core type: ExprTuple
#     sub-expressions: 31, 33, 32, 34
# 16. {(a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}) if (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 23
# 18. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 38, 23
# 21. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}) =  \\ (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. (b_{1}, b_{2}, ..., b_{j}) = (d_{1}, d_{2}, ..., d_{j})
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. ((a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}), (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. ((b_{1}, b_{2}, ..., b_{j}), (d_{1}, d_{2}, ..., d_{j}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. (a_{1}, a_{2}, ..., a_{i},b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 31, 33, 32
# 28. (a_{1}, a_{2}, ..., a_{i},d_{1}, d_{2}, ..., d_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 31, 34, 32
# 29. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 33
# 30. (d_{1}, d_{2}, ..., d_{j})
#     core type: ExprTuple
#     sub-expressions: 34
# 31. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 41
#     end_index: 36
# 32. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 41
#     end_index: 38
# 33. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 41
#     end_index: 42
# 34. d_{1}, d_{2}, ..., d_{j}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 43
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. _a -> c_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 44
# 38. k
#     core type: Variable
#     sub-expressions:
# 39. _a -> b_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 45
# 40. _a -> d_{_a}
#     core type: Lambda
#     parameter: 52
#     body: 46
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. j
#     core type: Variable
#     sub-expressions:
# 43. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 52
# 44. c_{_a}
#     core type: IndexedVar
# variable: 48
# index: 52
# 45. b_{_a}
#     core type: IndexedVar
# variable: 49
# index: 52
# 46. d_{_a}
#     core type: IndexedVar
# variable: 50
# index: 52
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. c
#     core type: Variable
#     sub-expressions:
# 49. b
#     core type: Variable
#     sub-expressions:
# 50. d
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. _a
#     core type: Variable
#     sub-expressions:
