# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#len_of_ranges_with_repeated_indices_from_1">len_of_ranges_with_repeated_indices_from_1</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import len_of_ranges_with_repeated_indices_from_1

# %%
# check that the built expression is the same as the stored expression
assert len_of_ranges_with_repeated_indices_from_1.expr == stored_expr
assert len_of_ranges_with_repeated_indices_from_1.expr._style_id == stored_expr._style_id
print("Passed sanity check: len_of_ranges_with_repeated_indices_from_1 matches stored_expr")
# Out:
# Passed sanity check: len_of_ranges_with_repeated_indices_from_1 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{f_{1}, f_{2}, \ldots, f_{n}, i~|~i \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} |\left(f_{1}\left(1\right), f_{1}\left(2\right), \ldots, f_{1}\left(i\right), f_{2}\left(1\right), f_{2}\left(2\right), \ldots, f_{2}\left(i\right), \ldots\ldots, f_{n}\left(1\right), f_{n}\left(2\right), \ldots, f_{n}\left(i\right)\right)| \\  = \left(n \cdot i\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{f_{1}, f_{2}, ..., f_{n}, i | i in Natural} (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{f_{1}, f_{2}, ..., f_{n}, i | i in Natural} (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{f_{1}, f_{2}, ..., f_{n}, i | i in Natural} (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.
#    core type: Lambda
#    parameter: 32
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 32
# 4. {forall_{f_{1}, f_{2}, ..., f_{n}, i | i in Natural} (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i)) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{f_{1}, f_{2}, ..., f_{n}, i | i in Natural} (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 20
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((f_{1}, f_{2}, ..., f_{n}, i) -> {|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i) if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 32, 11
# 10. (f_{1}, f_{2}, ..., f_{n}, i) -> {|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i) if i in Natural.
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (f_{1}, f_{2}, ..., f_{n}, i)
#     core type: ExprTuple
#     sub-expressions: 14, 36
# 13. {|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i) if i in Natural.
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. f_{1}, f_{2}, ..., f_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 35
#     end_index: 32
# 15. |(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))| \\  = (n * i)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. i in Natural
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. _a -> f_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (|(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))|, n * i)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 25
# 22. f_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 23. |(f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))|
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. n * i
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. length
#     core type: Literal
#     sub-expressions:
# 27. (f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i))
#     core type: ExprTuple
#     sub-expressions: 30
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (n, i)
#     core type: ExprTuple
#     sub-expressions: 32, 36
# 30. f_{1}(1), f_{1}(2), ..., f_{1}(i), f_{2}(1), f_{2}(2), ..., f_{2}(i), ......, f_{n}(1), f_{n}(2), ..., f_{n}(i)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 35
#     end_index: 32
# 31. _b -> f_{_b}(1), f_{_b}(2), ..., f_{_b}(i)
#     core type: Lambda
#     parameter: 43
#     body: 33
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. f_{_b}(1), f_{_b}(2), ..., f_{_b}(i)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 34. _a -> f_{_b}(_a)
#     core type: Lambda
#     parameter: 42
#     body: 37
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. f_{_b}(_a)
#     core type: Operation
#     operator: 38
#     operand: 42
# 38. f_{_b}
#     core type: IndexedVar
# variable: 40
# index: 43
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. (_b)
#     core type: ExprTuple
#     sub-expressions: 43
# 42. _a
#     core type: Variable
#     sub-expressions:
# 43. _b
#     core type: Variable
#     sub-expressions:
