# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, f, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda(f, Forall(instance_param_or_params = [a], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = shift_equiv, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), domain = Integer))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# f \mapsto \left[\forall_{a \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k + 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. f -> [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]]
#    core type: Lambda
#    parameter: 46
#    body: 2
# 1. (f)
#    core type: ExprTuple
#    sub-expressions: 46
# 2. forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. a -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 62
#    body: 5
# 5. {forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. a in Integer
#    core type: Operation
#    operator: 27
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. ((i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 12
# 11. (i, j, k, l) -> {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. Integer
#     core type: Literal
#     sub-expressions:
# 13. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 60, 58, 36, 38
# 14. {(f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. (f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 30
#     operands: 17
# 16. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. ((f(i), f(i + 1), ..., f(j)), (f(k + a), f((k + 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 20. (f(i), f(i + 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 25
# 21. (f(k + a), f((k + 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. k = (i - a)
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. l = (j - a)
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 60
#     end_index: 58
# 26. f(k + a), f((k + 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 36
#     end_index: 38
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. _a -> f(_a)
#     core type: Lambda
#     parameter: 61
#     body: 40
# 33. _a -> f(_a + a)
#     core type: Lambda
#     parameter: 61
#     body: 41
# 34. (j + 1) - i
#     core type: Operation
#     operator: 56
#     operands: 42
# 35. Natural
#     core type: Literal
#     sub-expressions:
# 36. k
#     core type: Variable
#     sub-expressions:
# 37. i - a
#     core type: Operation
#     operator: 56
#     operands: 43
# 38. l
#     core type: Variable
#     sub-expressions:
# 39. j - a
#     core type: Operation
#     operator: 56
#     operands: 44
# 40. f(_a)
#     core type: Operation
#     operator: 46
#     operand: 61
# 41. f(_a + a)
#     core type: Operation
#     operator: 46
#     operand: 51
# 42. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 60, 50
# 44. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 58, 50
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. (_a + a)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. j + 1
#     core type: Operation
#     operator: 56
#     operands: 52
# 49. -i
#     core type: Operation
#     operator: 54
#     operand: 60
# 50. -a
#     core type: Operation
#     operator: 54
#     operand: 62
# 51. _a + a
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 53. (i)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (a)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (_a, a)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 58. j
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. a
#     core type: Variable
#     sub-expressions:
