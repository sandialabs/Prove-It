# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types.tuples import range_len_conditions

# %%
# build up the expression from sub-expressions
expr = ExprTuple(range_len_conditions)
# Out:
# expr: ((j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}, \ldots, \left(j_{n} - i_{n} + 1\right) \in \mathbb{N}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((j_{1} - i_{1} + 1) in Natural, ..(j_{k} - i_{k} + 1) in Natural.., (j_{n} - i_{n} + 1) in Natural)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. ((j_{1} - i_{1} + 1) in Natural), ..((j_{k} - i_{k} + 1) in Natural).., ((j_{n} - i_{n} + 1) in Natural)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 13
#    end_index: 3
# 2. k -> ((j_{k} - i_{k} + 1) in Natural)
#    core type: Lambda
#    parameter: 18
#    body: 4
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. (j_{k} - i_{k} + 1) in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j_{k} - i_{k} + 1, Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. j_{k} - i_{k} + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (j_{k}, -i_{k}, 1)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. j_{k}
#     core type: IndexedVar
# variable: 14
# index: 18
# 12. -i_{k}
#     core type: Operation
#     operator: 15
#     operand: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. i_{k}
#     core type: IndexedVar
# variable: 17
# index: 18
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
