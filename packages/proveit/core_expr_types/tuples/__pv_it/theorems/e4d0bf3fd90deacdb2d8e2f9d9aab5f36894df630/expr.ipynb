# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, j, n
from proveit.core_expr_types import Len, f_1_to_n, i_to_j_len
from proveit.core_expr_types.tuples import f_i_to_j__1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Mult, Natural, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([f_1_to_n, i, j], Equals(Len([f_i_to_j__1_to_n]), Mult(n, i_to_j_len)).with_wrapping_at(1), condition = InSet(i_to_j_len, Natural)), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{f_{1}, \ldots, f_{n}, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} |\left(f_{1}(i), \ldots, f_{1}(j), \ldots\ldots, f_{n}(i), \ldots, f_{n}(j)\right)| \\  = \left(n \cdot \left(j - i + 1\right)\right) \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 33
#    body: 1
# 1. {forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))) if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{f_{1}, ..f_{_a}.., f_{n}, i, j | (j - i + 1) in Natural} (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalPos
#    core type: Operation
#    operator: 16
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (f_{1}, ..f_{_a}.., f_{n}, i, j) -> {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Natural.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 33, 9
# 7. (f_{1}, ..f_{_a}.., f_{n}, i, j)
#    core type: ExprTuple
#    sub-expressions: 10, 39, 40
# 8. {|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1)) if (j - i + 1) in Natural.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. f_{1}, ..f_{_a}.., f_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 35
#     end_index: 33
# 11. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))| \\  = (n * (j - i + 1))
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (j - i + 1) in Natural
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. _a -> f_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 18
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (|(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|, n * (j - i + 1))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (j - i + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 18. f_{_a}
#     core type: IndexedVar
# variable: 44
# index: 22
# 19. |(f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))|
#     core type: Operation
#     operator: 23
#     operand: 27
# 20. n * (j - i + 1)
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. _a
#     core type: Variable
#     sub-expressions:
# 23. length
#     core type: Literal
#     sub-expressions:
# 24. ((f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)))
#     core type: ExprTuple
#     sub-expressions: 27
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (n, j - i + 1)
#     core type: ExprTuple
#     sub-expressions: 33, 28
# 27. (f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j))
#     core type: ExprTuple
#     sub-expressions: 29
# 28. j - i + 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. f_{1}(i), ..f_{1}(x).., f_{1}(j), ....f_{k}(i), ..f_{k}(x).., f_{k}(j)...., f_{n}(i), ..f_{n}(x).., f_{n}(j)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 35
#     end_index: 33
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 40, 34, 35
# 32. k -> f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: Lambda
#     parameter: 45
#     body: 36
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. -i
#     core type: Operation
#     operator: 37
#     operand: 39
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. f_{k}(i), ..f_{k}(x).., f_{k}(j)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 37. -
#     core type: Literal
#     sub-expressions:
# 38. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 43
#     body: 41
# 39. i
#     core type: Variable
#     sub-expressions:
# 40. j
#     core type: Variable
#     sub-expressions:
# 41. f_{k}(x)
#     core type: Operation
#     operator: 42
#     operand: 43
# 42. f_{k}
#     core type: IndexedVar
# variable: 44
# index: 45
# 43. x
#     core type: Variable
#     sub-expressions:
# 44. f
#     core type: Variable
#     sub-expressions:
# 45. k
#     core type: Variable
#     sub-expressions:
