# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n
from proveit.core_expr_types import Len, f_1_to_n, i_1_to_n, j_1_to_n
from proveit.core_expr_types.tuples import f_ik_to_jk__1_to_n, range_len_conditions, range_len_sum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [f_1_to_n, i_1_to_n, j_1_to_n], instance_expr = Equals(Len(operands = [f_ik_to_jk__1_to_n]), range_len_sum).with_wrapping_at(1), condition = range_len_conditions).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{f_{1}, f_{2}, \ldots, f_{n}, i_{1}, i_{2}, \ldots, i_{n}, j_{1}, j_{2}, \ldots, j_{n}~|~\left(\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}\right), \left(\left(j_{2} - i_{2} + 1\right) \in \mathbb{N}\right), \ldots, \left(\left(j_{n} - i_{n} + 1\right) \in \mathbb{N}\right)}~\\
# \left(\begin{array}{c} \begin{array}{l} |\left(f_{1}\left(i_{1}\right), f_{1}\left(i_{1} + 1\right), \ldots, f_{1}\left(j_{1}\right), f_{2}\left(i_{2}\right), f_{2}\left(i_{2} + 1\right), \ldots, f_{2}\left(j_{2}\right), \ldots\ldots, f_{n}\left(i_{n}\right), f_{n}\left(i_{n} + 1\right), \ldots, f_{n}\left(j_{n}\right)\right)| \\  = \left(\left(j_{1} - i_{1} + 1\right) +  \left(j_{2} - i_{2} + 1\right) +  \ldots +  \left(j_{n} - i_{n} + 1\right)\right) \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n} | ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)} (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n} | ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)} (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 38
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 38
# 3. {forall_{f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n} | ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)} (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n} | ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)} (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 39
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n}) -> {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 38, 10
# 9. (f_{1}, f_{2}, ..., f_{n}, i_{1}, i_{2}, ..., i_{n}, j_{1}, j_{2}, ..., j_{n}) -> {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (f_{1}, f_{2}, ..., f_{n},i_{1}, i_{2}, ..., i_{n},j_{1}, j_{2}, ..., j_{n})
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 12. {|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. f_{1}, f_{2}, ..., f_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 52
#     end_index: 38
# 14. i_{1}, i_{2}, ..., i_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 52
#     end_index: 38
# 15. j_{1}, j_{2}, ..., j_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 52
#     end_index: 38
# 16. |(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))| \\  = ((j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. ((j_{1} - i_{1} + 1) in Natural) and  ((j_{2} - i_{2} + 1) in Natural) and  ... and  ((j_{n} - i_{n} + 1) in Natural)
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. _a -> f_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 25
# 19. _a -> i_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 59
# 20. _a -> j_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 50
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (|(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))|, (j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural))
#     core type: ExprTuple
#     sub-expressions: 28
# 25. f_{_a}
#     core type: IndexedVar
# variable: 57
# index: 63
# 26. |(f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))|
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (j_{1} - i_{1} + 1) +  (j_{2} - i_{2} + 1) +  ... +  (j_{n} - i_{n} + 1)
#     core type: Operation
#     operator: 47
#     operands: 31
# 28. ((j_{1} - i_{1} + 1) in Natural), ((j_{2} - i_{2} + 1) in Natural), ..., ((j_{n} - i_{n} + 1) in Natural)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 52
#     end_index: 38
# 29. length
#     core type: Literal
#     sub-expressions:
# 30. (f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n}))
#     core type: ExprTuple
#     sub-expressions: 33
# 31. ((j_{1} - i_{1} + 1), (j_{2} - i_{2} + 1), ..., (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 34
# 32. _a -> ((j_{_a} - i_{_a} + 1) in Natural)
#     core type: Lambda
#     parameter: 63
#     body: 35
# 33. f_{1}(i_{1}), f_{1}(i_{1} + 1), ..., f_{1}(j_{1}), f_{2}(i_{2}), f_{2}(i_{2} + 1), ..., f_{2}(j_{2}), ......, f_{n}(i_{n}), f_{n}(i_{n} + 1), ..., f_{n}(j_{n})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 52
#     end_index: 38
# 34. (j_{1} - i_{1} + 1), (j_{2} - i_{2} + 1), ..., (j_{n} - i_{n} + 1)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 52
#     end_index: 38
# 35. (j_{_a} - i_{_a} + 1) in Natural
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. _b -> f_{_b}(i_{_b}), f_{_b}(i_{_b} + 1), ..., f_{_b}(j_{_b})
#     core type: Lambda
#     parameter: 60
#     body: 41
# 37. _a -> (j_{_a} - i_{_a} + 1)
#     core type: Lambda
#     parameter: 63
#     body: 42
# 38. n
#     core type: Variable
#     sub-expressions:
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (j_{_a} - i_{_a} + 1, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. f_{_b}(i_{_b}), f_{_b}(i_{_b} + 1), ..., f_{_b}(j_{_b})
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 42. j_{_a} - i_{_a} + 1
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. Natural
#     core type: Literal
#     sub-expressions:
# 44. _a -> f_{_b}(_a)
#     core type: Lambda
#     parameter: 63
#     body: 49
# 45. i_{_b}
#     core type: IndexedVar
# variable: 61
# index: 60
# 46. j_{_b}
#     core type: IndexedVar
# variable: 54
# index: 60
# 47. +
#     core type: Literal
#     sub-expressions:
# 48. (j_{_a}, -i_{_a}, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52
# 49. f_{_b}(_a)
#     core type: Operation
#     operator: 53
#     operand: 63
# 50. j_{_a}
#     core type: IndexedVar
# variable: 54
# index: 63
# 51. -i_{_a}
#     core type: Operation
#     operator: 55
#     operand: 59
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. f_{_b}
#     core type: IndexedVar
# variable: 57
# index: 60
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (i_{_a})
#     core type: ExprTuple
#     sub-expressions: 59
# 57. f
#     core type: Variable
#     sub-expressions:
# 58. (_b)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. i_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 60. _b
#     core type: Variable
#     sub-expressions:
# 61. i
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
