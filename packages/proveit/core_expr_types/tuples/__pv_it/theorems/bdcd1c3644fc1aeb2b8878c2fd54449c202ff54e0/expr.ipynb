# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, i, j, k, l
from proveit.core_expr_types.tuples import shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(a)
expr = Forall([i, j, k, l], shift_equiv, conditions = [InSet(Add(Add(j, one), Neg(i)), Natural), Equals(k, Add(i, sub_expr1)), Equals(l, Add(j, sub_expr1))])
# Out:
# expr: forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f(i), \ldots, f(j)\right) = \left(f(k + a), \ldots, f(l + a)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (i, j, k, l) -> {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 44, 46, 26, 28
# 4. {(f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a)) if ((j + 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i), ..f(a).., f(j)) = (f(k + a), ..f(i + a).., f(l + a))
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (((j + 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((f(i), ..f(a).., f(j)), (f(k + a), ..f(i + a).., f(l + a)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (((j + 1) - i) in Natural, k = (i - a), l = (j - a))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 15
# 11. (f(k + a), ..f(i + a).., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. k = (i - a)
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. l = (j - a)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 44
#     end_index: 46
# 16. f(k + a), ..f(i + a).., f(l + a)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 26
#     end_index: 28
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 19. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 22. a -> f(a)
#     core type: Lambda
#     parameter: 45
#     body: 30
# 23. i -> f(i + a)
#     core type: Lambda
#     parameter: 44
#     body: 31
# 24. (j + 1) - i
#     core type: Operation
#     operator: 41
#     operands: 32
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. i - a
#     core type: Operation
#     operator: 41
#     operands: 33
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. j - a
#     core type: Operation
#     operator: 41
#     operands: 34
# 30. f(a)
#     core type: Operation
#     operator: 35
#     operand: 45
# 31. f(i + a)
#     core type: Operation
#     operator: 35
#     operand: 36
# 32. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 44, 39
# 34. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 46, 39
# 35. f
#     core type: Variable
#     sub-expressions:
# 36. i + a
#     core type: Operation
#     operator: 41
#     operands: 40
# 37. j + 1
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. -i
#     core type: Operation
#     operator: 43
#     operand: 44
# 39. -a
#     core type: Operation
#     operator: 43
#     operand: 45
# 40. (i, a)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. j
#     core type: Variable
#     sub-expressions:
# 47. 1
#     core type: Literal
#     sub-expressions:
