# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, i, j, k, l
from proveit.core_expr_types.tuples import neg_shift_equiv
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(Forall(instance_param_or_params = [i, j, k, l], instance_expr = neg_shift_equiv, conditions = [InSet(subtract(subtract(j, one), i), Natural), Equals(k, subtract(i, a)), Equals(l, subtract(j, a))]), InSet(a, Integer)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# a \mapsto \left\{\forall_{i, j, k, l~|~\left(\left(j - 1\right) - i\right) \in \mathbb{N}, k = \left(i - a\right), l = \left(j - a\right)}~\left(\left(f\left(i\right), f\left(i - 1\right), \ldots, f\left(j\right)\right) = \left(f\left(k + a\right), f\left(\left(k - 1\right) + a\right), \ldots, f\left(l + a\right)\right)\right) \textrm{ if } a \in \mathbb{Z}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. a -> {forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Lambda
#    parameter: 63
#    body: 1
# 1. {forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))) if a in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{i, j, k, l | ((j - 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. a in Integer
#    core type: Operation
#    operator: 23
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, Integer)
#    core type: ExprTuple
#    sub-expressions: 63, 8
# 7. (i, j, k, l) -> {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. (i, j, k, l)
#    core type: ExprTuple
#    sub-expressions: 61, 59, 48, 49
# 10. {(f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a)) if ((j - 1) - i) in Natural ,  k = (i - a) ,  l = (j - a).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. (f(i), f(i - 1), ..., f(j)) = (f(k + a), f((k - 1) + a), ..., f(l + a))
#     core type: Operation
#     operator: 26
#     operands: 13
# 12. (((j - 1) - i) in Natural) and (k = (i - a)) and (l = (j - a))
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. ((f(i), f(i - 1), ..., f(j)), (f(k + a), f((k - 1) + a), ..., f(l + a)))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (((j - 1) - i) in Natural, k = (i - a), l = (j - a))
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 16. (f(i), f(i - 1), ..., f(j))
#     core type: ExprTuple
#     sub-expressions: 21
# 17. (f(k + a), f((k - 1) + a), ..., f(l + a))
#     core type: ExprTuple
#     sub-expressions: 22
# 18. ((j - 1) - i) in Natural
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. k = (i - a)
#     core type: Operation
#     operator: 26
#     operands: 25
# 20. l = (j - a)
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. f(i), f(i - 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 51
#     end_index: 29
# 22. f(k + a), f((k - 1) + a), ..., f(l + a)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. ((j - 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 25. (k, i - a)
#     core type: ExprTuple
#     sub-expressions: 48, 35
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (l, j - a)
#     core type: ExprTuple
#     sub-expressions: 49, 36
# 28. _a -> f(-_a)
#     core type: Lambda
#     parameter: 68
#     body: 37
# 29. -j
#     core type: Operation
#     operator: 65
#     operand: 59
# 30. _a -> f(-_a + a)
#     core type: Lambda
#     parameter: 68
#     body: 39
# 31. -k
#     core type: Operation
#     operator: 65
#     operand: 48
# 32. -l
#     core type: Operation
#     operator: 65
#     operand: 49
# 33. (j - 1) - i
#     core type: Operation
#     operator: 57
#     operands: 42
# 34. Natural
#     core type: Literal
#     sub-expressions:
# 35. i - a
#     core type: Operation
#     operator: 57
#     operands: 43
# 36. j - a
#     core type: Operation
#     operator: 57
#     operands: 44
# 37. f(-_a)
#     core type: Operation
#     operator: 46
#     operand: 62
# 38. (j)
#     core type: ExprTuple
#     sub-expressions: 59
# 39. f(-_a + a)
#     core type: Operation
#     operator: 46
#     operand: 53
# 40. (k)
#     core type: ExprTuple
#     sub-expressions: 48
# 41. (l)
#     core type: ExprTuple
#     sub-expressions: 49
# 42. (j - 1, -i)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 43. (i, -a)
#     core type: ExprTuple
#     sub-expressions: 61, 52
# 44. (j, -a)
#     core type: ExprTuple
#     sub-expressions: 59, 52
# 45. (-_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. (-_a + a)
#     core type: ExprTuple
#     sub-expressions: 53
# 48. k
#     core type: Variable
#     sub-expressions:
# 49. l
#     core type: Variable
#     sub-expressions:
# 50. j - 1
#     core type: Operation
#     operator: 57
#     operands: 54
# 51. -i
#     core type: Operation
#     operator: 65
#     operand: 61
# 52. -a
#     core type: Operation
#     operator: 65
#     operand: 63
# 53. -_a + a
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. (i)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. (a)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (-_a, a)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. j
#     core type: Variable
#     sub-expressions:
# 60. -1
#     core type: Operation
#     operator: 65
#     operand: 67
# 61. i
#     core type: Variable
#     sub-expressions:
# 62. -_a
#     core type: Operation
#     operator: 65
#     operand: 68
# 63. a
#     core type: Variable
#     sub-expressions:
# 64. (1)
#     core type: ExprTuple
#     sub-expressions: 67
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 67. 1
#     core type: Literal
#     sub-expressions:
# 68. _a
#     core type: Variable
#     sub-expressions:
