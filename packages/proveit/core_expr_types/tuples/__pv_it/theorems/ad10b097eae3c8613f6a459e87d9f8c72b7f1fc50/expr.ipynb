# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, j, k
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Natural, Neg, one

# %%
# build up the expression from sub-expressions
expr = And(InSet(Add(k, Neg(i)), Natural), Equals(k, Add(j, one)))
# Out:
# expr: ((k - i) in Natural) and (k = (j + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(k - i\right) \in \mathbb{N}\right) \land \left(k = \left(j + 1\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((k - i) in Natural) and (k = (j + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ((k - i) in Natural, k = (j + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (k - i) in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. k = (j + 1)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k - i, Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (k, j + 1)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 9. k - i
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. j + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (k, -i)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. -i
#     core type: Operation
#     operator: 19
#     operand: 20
# 17. j
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. i
#     core type: Variable
#     sub-expressions:
