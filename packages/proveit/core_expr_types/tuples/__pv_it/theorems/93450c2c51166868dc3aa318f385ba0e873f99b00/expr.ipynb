# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import f, i, j
from proveit.core_expr_types import Len, f_i_to_j, f_jp1
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Natural, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([f], Forall([i, j], Equals(Len([f_i_to_j, f_jp1]), Add(j, Neg(i))), condition = InSet(Len([f_i_to_j]), Natural)))
# Out:
# expr: forall_{f} [forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f}~\left[\forall_{i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j), f(j + 1)\right)| = \left(j - i\right)\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f} [forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i))]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. f -> [forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i))]
#    core type: Lambda
#    parameter: 35
#    body: 2
# 2. forall_{i, j | |(f(i), ..f(a).., f(j))| in Natural} (|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (i, j) -> {|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i) if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i, j)
#    core type: ExprTuple
#    sub-expressions: 29, 33
# 6. {|(f(i), ..f(a).., f(j), f(j + 1))| = (j - i) if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. |(f(i), ..f(a).., f(j), f(j + 1))| = (j - i)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. |(f(i), ..f(a).., f(j))| in Natural
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (|(f(i), ..f(a).., f(j), f(j + 1))|, j - i)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (|(f(i), ..f(a).., f(j))|, Natural)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. |(f(i), ..f(a).., f(j), f(j + 1))|
#     core type: Operation
#     operator: 19
#     operand: 21
# 14. j - i
#     core type: Operation
#     operator: 30
#     operands: 18
# 15. |(f(i), ..f(a).., f(j))|
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. ((f(i), ..f(a).., f(j), f(j + 1)))
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (j, -i)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 19. length
#     core type: Literal
#     sub-expressions:
# 20. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (f(i), ..f(a).., f(j), f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 22. -i
#     core type: Operation
#     operator: 25
#     operand: 29
# 23. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. f(j + 1)
#     core type: Operation
#     operator: 35
#     operand: 27
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 29
#     end_index: 33
# 27. j + 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. a -> f(a)
#     core type: Lambda
#     parameter: 36
#     body: 32
# 29. i
#     core type: Variable
#     sub-expressions:
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. f(a)
#     core type: Operation
#     operator: 35
#     operand: 36
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. f
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
