# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, a, b, f, fab, i, j, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = Forall([f, i, j, m, n], Equals([ExprRange(a, ExprRange(b, fab, i, j), m, n)], []), condition = Equals(Add(j, one), i))
# Out:
# expr: forall_{f, i, j, m, n | (j + 1) = i} ((f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = ())

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, i, j, m, n~|~\left(j + 1\right) = i}~\left(\left(f(m, i), \ldots, f(m, j), \ldots\ldots, f(n, i), \ldots, f(n, j)\right) = ()\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f, i, j, m, n | (j + 1) = i} ((f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = ())
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j, m, n) -> {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (j + 1) = i.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j, m, n)
#    core type: ExprTuple
#    sub-expressions: 25, 22, 23, 17, 18
# 4. {(f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = () if (j + 1) = i.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)) = ()
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. (j + 1) = i
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)), ())
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (j + 1, i)
#    core type: ExprTuple
#    sub-expressions: 12, 22
# 10. (f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j))
#     core type: ExprTuple
#     sub-expressions: 13
# 11. ()
#     core type: ExprTuple
#     sub-expressions:
# 12. j + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. f(m, i), ..f(m, b).., f(m, j), ....f(a, i), ..f(a, b).., f(a, j)...., f(n, i), ..f(n, b).., f(n, j)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 16. a -> f(a, i), ..f(a, b).., f(a, j)
#     core type: Lambda
#     parameter: 27
#     body: 20
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. f(a, i), ..f(a, b).., f(a, j)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 21. b -> f(a, b)
#     core type: Lambda
#     parameter: 28
#     body: 24
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. j
#     core type: Variable
#     sub-expressions:
# 24. f(a, b)
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. f
#     core type: Variable
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
