# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import Len, f_i_to_j, f_jp1, range_i_to_jp1
from proveit.logic import Equals, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Len([f_i_to_j, f_jp1]), Len([range_i_to_jp1])), InSet(Len([f_i_to_j]), Natural))
# Out:
# expr: {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{|\left(f(i), \ldots, f(j), f(j + 1)\right)| = |\left(i, \ldots, j + 1\right)| \textrm{ if } |\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)| if |(f(i), ..f(a).., f(j))| in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |(f(i), ..f(a).., f(j), f(j + 1))| = |(i, ..k.., j + 1)|
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. |(f(i), ..f(a).., f(j))| in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(f(i), ..f(a).., f(j), f(j + 1))|, |(i, ..k.., j + 1)|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (|(f(i), ..f(a).., f(j))|, Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |(f(i), ..f(a).., f(j), f(j + 1))|
#    core type: Operation
#    operator: 13
#    operand: 15
# 8. |(i, ..k.., j + 1)|
#    core type: Operation
#    operator: 13
#    operand: 16
# 9. |(f(i), ..f(a).., f(j))|
#    core type: Operation
#    operator: 13
#    operand: 17
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. ((f(i), ..f(a).., f(j), f(j + 1)))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. ((i, ..k.., j + 1))
#     core type: ExprTuple
#     sub-expressions: 16
# 13. length
#     core type: Literal
#     sub-expressions:
# 14. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (f(i), ..f(a).., f(j), f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 16. (i, ..k.., j + 1)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 20
# 18. f(j + 1)
#     core type: Operation
#     operator: 31
#     operand: 22
# 19. i, ..k.., (j + 1)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 24
#     end_index: 22
# 20. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 29
# 21. k -> k
#     core type: Lambda
#     parameter: 25
#     body: 25
# 22. j + 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. a -> f(a)
#     core type: Lambda
#     parameter: 32
#     body: 28
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. k
#     core type: Variable
#     sub-expressions:
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. f(a)
#     core type: Operation
#     operator: 31
#     operand: 32
# 29. j
#     core type: Variable
#     sub-expressions:
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. f
#     core type: Variable
#     sub-expressions:
# 32. a
#     core type: Variable
#     sub-expressions:
