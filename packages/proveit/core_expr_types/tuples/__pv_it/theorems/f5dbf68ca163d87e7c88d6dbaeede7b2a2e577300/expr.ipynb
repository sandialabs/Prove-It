# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, f, i, j, m, n
from proveit.core_expr_types import Len
from proveit.core_expr_types.tuples import general_range_of_ranges
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Natural, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Conditional(Forall([f, i, j], Equals(Len(general_range_of_ranges), zero).with_wrapping_at(1)), And(InSet(m, Natural), InSet(n, Natural), Equals(Add(n, one), m))))
# Out:
# expr: (m, n) -> {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{f, i, j}~\left(\begin{array}{c} |\left(f(m, i(m)), \ldots, f(m, j(m)), \ldots\ldots, f(n, i(n)), \ldots, f(n, j(n))\right)| \\  = 0 \end{array}\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N} ,  \left(n + 1\right) = m\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m, n) -> {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 32, 33
# 2. {forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0) if m in Natural ,  n in Natural ,  (n + 1) = m.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, i, j} (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (m in Natural) and (n in Natural) and ((n + 1) = m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (f, i, j) -> (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0)
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m in Natural, n in Natural, (n + 1) = m)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 41, 39, 40
# 10. |(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))| \\  = 0
#     core type: Operation
#     operator: 18
#     operands: 14
# 11. m in Natural
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (n + 1) = m
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (|(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))|, 0)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (n + 1, m)
#     core type: ExprTuple
#     sub-expressions: 23, 32
# 20. |(f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))|
#     core type: Operation
#     operator: 24
#     operand: 28
# 21. 0
#     core type: Literal
#     sub-expressions:
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. n + 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. length
#     core type: Literal
#     sub-expressions:
# 25. ((f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n))))
#     core type: ExprTuple
#     sub-expressions: 28
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 29
# 28. (f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n)))
#     core type: ExprTuple
#     sub-expressions: 30
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. f(m, i(m)), ..f(m, l).., f(m, j(m)), ....f(k, i(k)), ..f(k, l).., f(k, j(k))...., f(n, i(n)), ..f(n, l).., f(n, j(n))
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 31. k -> f(k, i(k)), ..f(k, l).., f(k, j(k))
#     core type: Lambda
#     parameter: 43
#     body: 34
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. f(k, i(k)), ..f(k, l).., f(k, j(k))
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 35. l -> f(k, l)
#     core type: Lambda
#     parameter: 44
#     body: 38
# 36. i(k)
#     core type: Operation
#     operator: 39
#     operand: 43
# 37. j(k)
#     core type: Operation
#     operator: 40
#     operand: 43
# 38. f(k, l)
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. i
#     core type: Variable
#     sub-expressions:
# 40. j
#     core type: Variable
#     sub-expressions:
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. (k, l)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. k
#     core type: Variable
#     sub-expressions:
# 44. l
#     core type: Variable
#     sub-expressions:
