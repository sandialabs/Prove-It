# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, i, j, k, l
from proveit.core_expr_types.tuples import neg_shift_equiv_both
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Natural, one, subtract

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [a, b], instance_expr = Forall(instance_param_or_params = [i, j, k, l], instance_expr = neg_shift_equiv_both, conditions = [InSet(subtract(Add(j, one), i), Natural), Equals(Add(i, a), Add(k, b)), Equals(Add(j, a), Add(l, b))]), domain = Integer)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}}~\left[\forall_{i, j, k, l~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(i + a\right) = \left(k + b\right), \left(j + a\right) = \left(l + b\right)}~\left(\left(f\left(i + a\right), f\left(\left(i - 1\right) + a\right), \ldots, f\left(j + a\right)\right) = \left(f\left(k + b\right), f\left(\left(k - 1\right) + b\right), \ldots, f\left(l + b\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a, b in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b)
#    core type: ExprTuple
#    sub-expressions: 73, 75
# 4. {forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b))) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{i, j, k, l | ((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b)} ((f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 21
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((i, j, k, l) -> {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (i, j, k, l) -> {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. a in Integer
#     core type: Operation
#     operator: 30
#     operands: 15
# 12. b in Integer
#     core type: Operation
#     operator: 30
#     operands: 16
# 13. (i, j, k, l)
#     core type: ExprTuple
#     sub-expressions: 72, 70, 61, 62
# 14. {(f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b)) if ((j + 1) - i) in Natural ,  (i + a) = (k + b) ,  (j + a) = (l + b).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 73, 19
# 16. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 75, 19
# 17. (f(i + a), f((i - 1) + a), ..., f(j + a)) = (f(k + b), f((k - 1) + b), ..., f(l + b))
#     core type: Operation
#     operator: 33
#     operands: 20
# 18. (((j + 1) - i) in Natural) and ((i + a) = (k + b)) and ((j + a) = (l + b))
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. ((f(i + a), f((i - 1) + a), ..., f(j + a)), (f(k + b), f((k - 1) + b), ..., f(l + b)))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (((j + 1) - i) in Natural, (i + a) = (k + b), (j + a) = (l + b))
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 23. (f(i + a), f((i - 1) + a), ..., f(j + a))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (f(k + b), f((k - 1) + b), ..., f(l + b))
#     core type: ExprTuple
#     sub-expressions: 29
# 25. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. (i + a) = (k + b)
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. (j + a) = (l + b)
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. f(i + a), f((i - 1) + a), ..., f(j + a)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 60
#     end_index: 36
# 29. f(k + b), f((k - 1) + b), ..., f(l + b)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 32. (i + a, k + b)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (j + a, l + b)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 35. _a -> f(-_a + a)
#     core type: Lambda
#     parameter: 78
#     body: 46
# 36. -j
#     core type: Operation
#     operator: 76
#     operand: 70
# 37. _a -> f(-_a + b)
#     core type: Lambda
#     parameter: 78
#     body: 48
# 38. -k
#     core type: Operation
#     operator: 76
#     operand: 61
# 39. -l
#     core type: Operation
#     operator: 76
#     operand: 62
# 40. (j + 1) - i
#     core type: Operation
#     operator: 68
#     operands: 51
# 41. Natural
#     core type: Literal
#     sub-expressions:
# 42. i + a
#     core type: Operation
#     operator: 68
#     operands: 52
# 43. k + b
#     core type: Operation
#     operator: 68
#     operands: 53
# 44. j + a
#     core type: Operation
#     operator: 68
#     operands: 54
# 45. l + b
#     core type: Operation
#     operator: 68
#     operands: 55
# 46. f(-_a + a)
#     core type: Operation
#     operator: 57
#     operand: 63
# 47. (j)
#     core type: ExprTuple
#     sub-expressions: 70
# 48. f(-_a + b)
#     core type: Operation
#     operator: 57
#     operand: 64
# 49. (k)
#     core type: ExprTuple
#     sub-expressions: 61
# 50. (l)
#     core type: ExprTuple
#     sub-expressions: 62
# 51. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 52. (i, a)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 53. (k, b)
#     core type: ExprTuple
#     sub-expressions: 61, 75
# 54. (j, a)
#     core type: ExprTuple
#     sub-expressions: 70, 73
# 55. (l, b)
#     core type: ExprTuple
#     sub-expressions: 62, 75
# 56. (-_a + a)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. f
#     core type: Variable
#     sub-expressions:
# 58. (-_a + b)
#     core type: ExprTuple
#     sub-expressions: 64
# 59. j + 1
#     core type: Operation
#     operator: 68
#     operands: 65
# 60. -i
#     core type: Operation
#     operator: 76
#     operand: 72
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. l
#     core type: Variable
#     sub-expressions:
# 63. -_a + a
#     core type: Operation
#     operator: 68
#     operands: 67
# 64. -_a + b
#     core type: Operation
#     operator: 68
#     operands: 69
# 65. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 66. (i)
#     core type: ExprTuple
#     sub-expressions: 72
# 67. (-_a, a)
#     core type: ExprTuple
#     sub-expressions: 74, 73
# 68. +
#     core type: Literal
#     sub-expressions:
# 69. (-_a, b)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 70. j
#     core type: Variable
#     sub-expressions:
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Variable
#     sub-expressions:
# 73. a
#     core type: Variable
#     sub-expressions:
# 74. -_a
#     core type: Operation
#     operator: 76
#     operand: 78
# 75. b
#     core type: Variable
#     sub-expressions:
# 76. -
#     core type: Literal
#     sub-expressions:
# 77. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 78. _a
#     core type: Variable
#     sub-expressions:
