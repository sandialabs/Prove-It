# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#partition">partition</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.tuples import partition

# %%
# check that the built expression is the same as the stored expression
assert partition.expr == stored_expr
assert partition.expr._style_id == stored_expr._style_id
print("Passed sanity check: partition matches stored_expr")
# Out:
# Passed sanity check: partition matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{f, i, j, k~|~\left(\left(j + 1\right) - i\right) \in \mathbb{N}, \left(k - j\right) \in \mathbb{N}}~\left(\begin{array}{c} \begin{array}{l} \left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(k\right)\right) =  \\ \left(f\left(i\right), f\left(i + 1\right), \ldots, f\left(j\right),f\left(j + 1\right), f\left(j + 2\right), \ldots, f\left(k\right)\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{f, i, j, k | ((j + 1) - i) in Natural, (k - j) in Natural} ((f(i), f(i + 1), ..., f(k)) =  \\ (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, i, j, k) -> {(f(i), f(i + 1), ..., f(k)) =  \\ (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (f, i, j, k) -> {(f(i), f(i + 1), ..., f(k)) =  \\ (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (f, i, j, k)
#    core type: ExprTuple
#    sub-expressions: 29, 42, 43, 33
# 5. {(f(i), f(i + 1), ..., f(k)) =  \\ (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k)) if ((j + 1) - i) in Natural ,  (k - j) in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (f(i), f(i + 1), ..., f(k)) =  \\ (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (((j + 1) - i) in Natural) and ((k - j) in Natural)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((f(i), f(i + 1), ..., f(k)), (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (((j + 1) - i) in Natural, (k - j) in Natural)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. (f(i), f(i + 1), ..., f(k))
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (f(i), f(i + 1), ..., f(j),f(j + 1), f(j + 2), ..., f(k))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. ((j + 1) - i) in Natural
#     core type: Operation
#     operator: 20
#     operands: 19
# 15. (k - j) in Natural
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. f(i), f(i + 1), ..., f(k)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 42
#     end_index: 33
# 17. f(i), f(i + 1), ..., f(j)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 42
#     end_index: 43
# 18. f(j + 1), f(j + 2), ..., f(k)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 31
#     end_index: 33
# 19. ((j + 1) - i, Natural)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (k - j, Natural)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. _a -> f(_a)
#     core type: Lambda
#     parameter: 35
#     body: 26
# 23. (j + 1) - i
#     core type: Operation
#     operator: 36
#     operands: 27
# 24. k - j
#     core type: Operation
#     operator: 36
#     operands: 28
# 25. Natural
#     core type: Literal
#     sub-expressions:
# 26. f(_a)
#     core type: Operation
#     operator: 29
#     operand: 35
# 27. (j + 1, -i)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. (k, -j)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. (_a)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. j + 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. -i
#     core type: Operation
#     operator: 39
#     operand: 42
# 33. k
#     core type: Variable
#     sub-expressions:
# 34. -j
#     core type: Operation
#     operator: 39
#     operand: 43
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 43, 41
# 38. (i)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. -
#     core type: Literal
#     sub-expressions:
# 40. (j)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. j
#     core type: Variable
#     sub-expressions:
