# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Natural, one

# %%
# build up the expression from sub-expressions
expr = And(InSet(m, Natural), InSet(n, Natural), Equals(Add(n, one), m))
# Out:
# expr: (m in Natural) and (n in Natural) and ((n + 1) = m)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m \in \mathbb{N}\right) \land \left(n \in \mathbb{N}\right) \land \left(\left(n + 1\right) = m\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m in Natural) and (n in Natural) and ((n + 1) = m)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (m in Natural, n in Natural, (n + 1) = m)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. m in Natural
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. n in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (n + 1) = m
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 16, 11
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (n + 1, m)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. n + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
