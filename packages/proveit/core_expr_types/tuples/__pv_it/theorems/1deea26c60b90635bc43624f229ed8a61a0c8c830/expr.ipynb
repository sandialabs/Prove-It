# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import f, i, j
from proveit.core_expr_types import Len, f_i_to_j, i_to_j_len
from proveit.logic import Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([f, i, j], InSet(Len([f_i_to_j]), Natural), condition = InSet(i_to_j_len, Natural))
# Out:
# expr: forall_{f, i, j | (j - i + 1) in Natural} (|(f(i), ..f(a).., f(j))| in Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f, i, j | (j - i + 1) in Natural} (|(f(i), ..f(a).., f(j))| in Natural)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {|(f(i), ..f(a).., f(j))| in Natural if (j - i + 1) in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 26, 23, 24
# 4. {|(f(i), ..f(a).., f(j))| in Natural if (j - i + 1) in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |(f(i), ..f(a).., f(j))| in Natural
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. (j - i + 1) in Natural
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (|(f(i), ..f(a).., f(j))|, Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (j - i + 1, Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. |(f(i), ..f(a).., f(j))|
#     core type: Operation
#     operator: 13
#     operand: 17
# 11. j - i + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. Natural
#     core type: Literal
#     sub-expressions:
# 13. length
#     core type: Literal
#     sub-expressions:
# 14. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 18, 19
# 17. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 20
# 18. -i
#     core type: Operation
#     operator: 21
#     operand: 23
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. a -> f(a)
#     core type: Lambda
#     parameter: 27
#     body: 25
# 23. i
#     core type: Variable
#     sub-expressions:
# 24. j
#     core type: Variable
#     sub-expressions:
# 25. f(a)
#     core type: Operation
#     operator: 26
#     operand: 27
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
