# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, i
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_1_to_i
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([f_1_to_i, b]), Add(i, one))
# Out:
# expr: (|(f(1), ..f(a).., f(i), b)|, i + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(f(1), \ldots, f(i), b\right)|, i + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(f(1), ..f(a).., f(i), b)|, i + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(f(1), ..f(a).., f(i), b)|
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. i + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((f(1), ..f(a).., f(i), b))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (i, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 7. (f(1), ..f(a).., f(i), b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. f(1), ..f(a).., f(i)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. a -> f(a)
#     core type: Lambda
#     parameter: 15
#     body: 13
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. f(a)
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
