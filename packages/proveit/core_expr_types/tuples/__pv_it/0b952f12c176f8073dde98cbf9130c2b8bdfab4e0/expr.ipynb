# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function
from proveit._common_ import i, k, n, x
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_1_to_n, f_k
from proveit.logic import Equals, Forall, InSet
from proveit.number import Mult, Naturals, one

# %%
# build up the expression from sub-expressions
expr = Forall([f_1_to_n, i], Equals(Len([ExprRange(k, ExprRange(x, Function(f_k, x), one, i), one, n)]), Mult(n, i)).withWrappingAt(1), condition = InSet(i, Naturals))
# Out:
# expr: forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Naturals} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f_{1}, \ldots, f_{n}, i~|~i \in \mathbb{N}}~\left(\begin{array}{c} |\left(f_{1}(1), \ldots, f_{1}(i), \ldots\ldots, f_{n}(1), \ldots, f_{n}(i)\right)| \\  = \left(n \cdot i\right) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f_{1}, ..f_{_a}.., f_{n}, i | i in Naturals} (|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f_{1}, ..f_{_a}.., f_{n}, i) -> {|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i) if i in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f_{1}, ..f_{_a}.., f_{n}, i)
#    core type: ExprTuple
#    sub-expressions: 5, 29
# 4. {|(f_{1}(1), ..f_{1}(x).., f_{1}(i), ....f_{k}(1), ..f_{k}(x).., f_{k}(i)...., f_{n}(1), ..f_{n}(x).., f_{n}(i))| \\  = (n * i) if i in Naturals.
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. f_{1}, ..f_{_a}.., f_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 28
#    end_index: 25
# ...
