# %% [markdown]
# Theory of <a class="ProveItLink" href="../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../_theory_.ipynb">core_expr_types</a>.tuples
# ========
#
# Theory related to **ExprTuple** types of Prove-It expressions.  An **ExprTuple** is an ordered sequence of expressions.  It may contain an **ExprRange** that represents an indeterminant number of *elements* within the sequence.  For example, $(a, b_1, \ldots, b_n, c)$ is a tuple of $n+2$ elements with $b_1, \ldots, b_n$ as an **ExprRange** that is a single entry of this tuple.  Each *entry* of the **ExprTuple** is a single **Expression** which may represent zero or more elements of the tuple sequence.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="_common_.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="_axioms_.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="_theorems_.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="_demonstrations_.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>Axioms contained (directly or indirectly) within this theory</h3>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#tuple_len_0">proveit.core_expr_types.tuples.tuple_len_0</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/bde05b1d4a41b82350f7aa6841d153d3b5cbcc080/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#tuple_len_incr">proveit.core_expr_types.tuples.tuple_len_incr</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/346546f7a8ae361456baec30361c5f8867498c540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#tuple_eq_def">proveit.core_expr_types.tuples.tuple_eq_def</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/c0565a7fd26d5fbd1785bf2ae2860416d88875060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#empty_range_def">proveit.core_expr_types.tuples.empty_range_def</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/76bdce3eab1184ed9ad2d35a921cfe00d0610de20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#range_extension_def">proveit.core_expr_types.tuples.range_extension_def</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/a617b0b760e08e6576d4a0c8542d23eadf54bcf60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <h3>Theorems (or conjectures) contained (directly or indirectly) within this theory</h3>
# Also see list of all contained <a href="contain_theorems.ipynb">theorems (or conjectures)</a>.
