# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_theory_.ipynb">conditionals</a>.<a class="ProveItLink" href="../_theorems_.ipynb#condition_merger_reduction">condition_merger_reduction</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving condition_merger_reduction
