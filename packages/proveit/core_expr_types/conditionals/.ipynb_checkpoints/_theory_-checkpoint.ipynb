# %% [markdown]
# Theory of <a class="ProveItLink" href="../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../_theory_.ipynb">core_expr_types</a>.conditionals
# ========
#
# Theory related to **Conditional** types of Prove-It expressions.  A **Conditional** has a *condition* and a *value*.  The expression evaluates to the *value* when the *condition* is satisfied (evaluates to true) but cannot be reduced if it is not satisfied.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="_common_.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="_axioms_.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="_theorems_.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="_demonstrations_.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>Axioms contained (directly or indirectly) within this theory</h3>
# <dt><a class="ProveItLink" href="_axioms_.ipynb#true_condition_reduction">proveit.core_expr_types.conditionals.true_condition_reduction</a></dt><dd><a class="ProveItLink" href="__pv_it/axioms/a2b80d992904e51d5aa91b165e15872c37700d590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# ...
