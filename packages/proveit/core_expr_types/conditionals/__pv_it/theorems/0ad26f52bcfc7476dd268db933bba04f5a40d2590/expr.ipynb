# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, m
from proveit.core_expr_types import Q_1_to_m
from proveit.logic import And, Equals, Forall, InSet, TRUE
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
sub_expr1 = And(Q_1_to_m)
expr = Conditional(Forall([a, Q_1_to_m], Equals(Conditional(a, And(TRUE, sub_expr1)), Conditional(a, sub_expr1)).with_wrapping_at(1)), InSet(m, Natural))
# Out:
# expr: {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a, Q_{1}, \ldots, Q_{m}}~\left(\begin{array}{c} \left\{a \textrm{ if } \top ,  Q_{1} \land \ldots \land Q_{m}\right.. \\  = \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m}\right.. \end{array}\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.) if m in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}} ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a, Q_{1}, ..Q_{_a}.., Q_{m}) -> ({a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.)
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 7. (a, Q_{1}, ..Q_{_a}.., Q_{m})
#    core type: ExprTuple
#    sub-expressions: 15, 21
# 8. {a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}. \\  = {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}, a if Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. {a if TRUE ,  Q_{1} and ..Q_{_a}.. and Q_{m}.
#     core type: Conditional
#     value: 15
#     condition: 14
# 13. {a if Q_{1} and ..Q_{_a}.. and Q_{m}.
#     core type: Conditional
#     value: 15
#     condition: 18
# 14. TRUE and (Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: Operation
#     operator: 19
#     operands: 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. (TRUE, Q_{1} and ..Q_{_a}.. and Q_{m})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. TRUE
#     core type: Literal
#     sub-expressions:
# 18. Q_{1} and ..Q_{_a}.. and Q_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (Q_{1}, ..Q_{_a}.., Q_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. Q_{1}, ..Q_{_a}.., Q_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 22. _a -> Q_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 25
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. Q_{_a}
#     core type: IndexedVar
# variable: 26
# index: 27
# 26. Q
#     core type: Variable
#     sub-expressions:
# 27. _a
#     core type: Variable
#     sub-expressions:
