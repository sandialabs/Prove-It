# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#condition_merger_reduction">condition_merger_reduction</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.core_expr_types.conditionals import condition_merger_reduction

# %%
# check that the built expression is the same as the stored expression
assert condition_merger_reduction.expr == stored_expr
assert condition_merger_reduction.expr._style_id == stored_expr._style_id
print("Passed sanity check: condition_merger_reduction matches stored_expr")
# Out:
# Passed sanity check: condition_merger_reduction matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(condition_merger_reduction.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}}~\left[\forall_{a, Q_{1}, \ldots, Q_{m}, R_{1}, \ldots, R_{n}}~\left(\begin{array}{c} \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m} ,  R_{1} \land \ldots \land R_{n}\right.. \\  = \left\{a \textrm{ if } Q_{1} ,  \ldots ,  Q_{m} ,  R_{1} ,  \ldots ,  R_{n}\right.. \end{array}\right)\right]

# %%
# display the expression information
condition_merger_reduction.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, n) -> {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n)
#    core type: ExprTuple
#    sub-expressions: 34, 37
# 3. {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
