# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#condition_append_reduction">condition_append_reduction</a>
# ***see <a class="ProveItLink" href="../../_proofs_/condition_append_reduction.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.core_expr_types.conditionals._theorems_ import condition_append_reduction

# %%
# %dependencies condition_append_reduction
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems depend upon condition_append_reduction</h3>
