# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a
from proveit.core_expr_types._common_ import Q_1_to_m
from proveit.logic import And, TRUE

# %%
# build up the expression from sub-expressions
expr = Conditional(a, And(And(Q_1_to_m), TRUE))
# Out:
# expr: {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m} ,  \top\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  TRUE.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a
#    core type: Variable
#    sub-expressions:
# 2. (Q_{1} and ..Q_{_a}.. and Q_{m}) and TRUE
#    core type: Operation
#    operator: 6
#    operands: 3
# 3. (Q_{1} and ..Q_{_a}.. and Q_{m}, TRUE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. Q_{1} and ..Q_{_a}.. and Q_{m}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. TRUE
#    core type: Literal
#    sub-expressions:
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (Q_{1}, ..Q_{_a}.., Q_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. Q_{1}, ..Q_{_a}.., Q_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. _a -> Q_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. Q_{_a}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. Q
#     core type: Variable
#     sub-expressions:
# 14. _a
#     core type: Variable
#     sub-expressions:
