# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types._common_ import A_1_to_m, B_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(A_1_to_m), And(B_1_to_n))
# Out:
# expr: (A_{1} and ..A_{_a}.. and A_{m}, B_{1} and ..B_{_a}.. and B_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \land \ldots \land A_{m}, B_{1} \land \ldots \land B_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} and ..A_{_a}.. and A_{m}, B_{1} and ..B_{_a}.. and B_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. B_{1} and ..B_{_a}.. and B_{n}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (B_{1}, ..B_{_a}.., B_{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 9
# 7. B_{1}, ..B_{_a}.., B_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 8. _a -> A_{_a}
#    core type: Lambda
#    parameter: 17
#    body: 13
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. _a -> B_{_a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. A_{_a}
#     core type: IndexedVar
# variable: 15
# index: 17
# 14. B_{_a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
