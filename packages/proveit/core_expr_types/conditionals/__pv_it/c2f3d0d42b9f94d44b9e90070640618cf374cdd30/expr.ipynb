# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#condition_merger_reduction">condition_merger_reduction</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.conditionals._theorems_ import condition_merger_reduction

# %%
# check that the built expression is the same as the stored expression
# %check_expr condition_merger_reduction
# Out:
# Passed sanity check: built 'condition_merger_reduction' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(condition_merger_reduction.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{a, Q_{1}, \ldots, Q_{m}, R_{1}, \ldots, R_{n}}~\left(\begin{array}{c} \left\{a \textrm{ if } Q_{1} \land \ldots \land Q_{m} ,  R_{1} \land \ldots \land R_{n}\right.. \\  = \left\{a \textrm{ if } Q_{1} ,  \ldots ,  Q_{m} ,  R_{1} ,  \ldots ,  R_{n}\right.. \end{array}\right)\right]

# %%
# display the expression information
condition_merger_reduction.exprInfo()
# Out:
# 0. forall_{m in Naturals, n in Naturals} [forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, n) -> {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n)
#    core type: ExprTuple
#    sub-expressions: 34, 37
# 3. {forall_{a, Q_{1}, ..Q_{_a}.., Q_{m}, R_{1}, ..R_{_a}.., R_{n}} ({a if Q_{1} and ..Q_{_a}.. and Q_{m} ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q_{1} ,  ..Q_{_a}.. ,  Q_{m} ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
# ...
