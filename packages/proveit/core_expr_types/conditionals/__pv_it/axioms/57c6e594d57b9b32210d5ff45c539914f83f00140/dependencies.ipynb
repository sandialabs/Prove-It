# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#true_condition_reduction">true_condition_reduction</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.core_expr_types.conditionals import true_condition_reduction

# %%
# %dependencies true_condition_reduction
# Out:
# <h3>Theorems/conjectures that depend directly on true_condition_reduction</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/implication_from_conditional/thm_proof.ipynb">proveit.core_expr_types.conditionals.implication_from_conditional</a></dt><dd><a class="ProveItLink" href="../../theorems/407c0d5d2c6155094109c1ede3f329cb5d9c033b0/expr.ipynb"><img src="../../theorems/407c0d5d2c6155094109c1ede3f329cb5d9c033b0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
