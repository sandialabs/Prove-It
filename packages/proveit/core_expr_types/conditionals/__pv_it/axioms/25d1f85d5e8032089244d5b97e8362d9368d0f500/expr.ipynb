# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Q, a
from proveit.logic import Equals, TRUE

# %%
# build up the expression from sub-expressions
expr = Equals(Conditional(a, Q), Conditional(a, Equals(Q, TRUE))).with_wrapping_at(1)
# Out:
# expr: {a if Q. \\  = {a if Q = TRUE.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left\{a \textrm{ if } Q\right.. \\  = \left\{a \textrm{ if } Q = \top\right.. \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a if Q. \\  = {a if Q = TRUE.
#    core type: Operation
#    operator: 6
#    operands: 1
# 1. (a if Q, a if Q = TRUE)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. {a if Q.
#    core type: Conditional
#    value: 4
#    condition: 8
# 3. {a if Q = TRUE.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a
#    core type: Variable
#    sub-expressions:
# 5. Q = TRUE
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (Q, TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Q
#    core type: Variable
#    sub-expressions:
# 9. TRUE
#    core type: Literal
#    sub-expressions:
