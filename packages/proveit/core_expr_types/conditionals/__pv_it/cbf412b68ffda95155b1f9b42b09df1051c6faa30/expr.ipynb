# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#condition_prepend_reduction">condition_prepend_reduction</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.core_expr_types.conditionals._theorems_ import condition_prepend_reduction

# %%
# check that the built expression is the same as the stored expression
# %check_expr condition_prepend_reduction
# Out:
# Passed sanity check: built 'condition_prepend_reduction' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(condition_prepend_reduction.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a, Q, R_{1}, \ldots, R_{n}}~\left(\begin{array}{c} \left\{a \textrm{ if } Q ,  R_{1} \land \ldots \land R_{n}\right.. \\  = \left\{a \textrm{ if } Q ,  R_{1} ,  \ldots ,  R_{n}\right.. \end{array}\right)\right]

# %%
# display the expression information
condition_prepend_reduction.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if n in Naturals.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.) if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a, Q, R_{1}, ..R_{_a}.., R_{n}) -> ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 9. (a, Q, R_{1}, ..R_{_a}.., R_{n})
#    core type: ExprTuple
#    sub-expressions: 17, 22, 25
# 10. {a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (a if Q ,  R_{1} and ..R_{_a}.. and R_{n}, a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. {a if Q ,  R_{1} and ..R_{_a}.. and R_{n}.
#     core type: Conditional
#     value: 17
#     condition: 16
# 15. {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. Q and (R_{1} and ..R_{_a}.. and R_{n})
#     core type: Operation
#     operator: 23
#     operands: 19
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. Q and R_{1} and ..R_{_a}.. and R_{n}
#     core type: Operation
#     operator: 23
#     operands: 20
# 19. (Q, R_{1} and ..R_{_a}.. and R_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 20. (Q, R_{1}, ..R_{_a}.., R_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 25
# 21. R_{1} and ..R_{_a}.. and R_{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. Q
#     core type: Variable
#     sub-expressions:
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (R_{1}, ..R_{_a}.., R_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 25. R_{1}, ..R_{_a}.., R_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 26. _a -> R_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. R_{_a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 30. R
#     core type: Variable
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
