# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, x
from proveit.core_expr_types import B_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = Conditional(x, And(A, And(B_1_to_n)))
# Out:
# expr: {x if A ,  B_{1} and ..B_{_a}.. and B_{n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \textrm{ if } A ,  B_{1} \land \ldots \land B_{n}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x if A ,  B_{1} and ..B_{_a}.. and B_{n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x
#    core type: Variable
#    sub-expressions:
# 2. A and (B_{1} and ..B_{_a}.. and B_{n})
#    core type: Operation
#    operator: 6
#    operands: 3
# 3. (A, B_{1} and ..B_{_a}.. and B_{n})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A
#    core type: Variable
#    sub-expressions:
# 5. B_{1} and ..B_{_a}.. and B_{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (B_{1}, ..B_{_a}.., B_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. B_{1}, ..B_{_a}.., B_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. _a -> B_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. B_{_a}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. _a
#     core type: Variable
#     sub-expressions:
