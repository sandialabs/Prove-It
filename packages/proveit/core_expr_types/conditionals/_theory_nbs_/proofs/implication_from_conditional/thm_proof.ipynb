# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../../theory.ipynb">conditionals</a>.<a class="ProveItLink" href="../../theorems.ipynb#implication_from_conditional">implication_from_conditional</a> theorem
# ========

# %%
import proveit
from proveit import Conditional
from proveit import A, Q
from proveit.logic import TRUE, Equals
theory = proveit.Theory() # the theorem's theory

# %%
# %proving implication_from_conditional
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="implication_from_conditional">implication_from_conditional:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d35cfde53d9649de6f12958ab7729f48b4592a270/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/aa98bdea9b7af342767a4f3f696745564500c11a0/dependencies.ipynb">dependencies</a>)<br>

# %%
Q_eq_T = Equals(Q, TRUE).prove(assumptions=[Q])
# Out:
# <strong id="Q_eq_T">Q_eq_T:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../__pv_it/common/d72bb8b07403efe79afab564c36a28e21330e5f90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_implication_from_conditional/1104b4e886d61d8cb08736d97bc56591da200f8e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_implication_from_conditional/542034044d7f1bb57d5b0be8056a851675045e5d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Q_eq_T.sub_right_side_into(Conditional(A, Q), 
                           assumptions=[Conditional(A, Q)]).simplify()
# Out:
# {A if Q, Q} |- A
# implication_from_conditional may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.core_expr_types.conditionals.implication_from_conditional has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, Q | A if Q} (Q => A)
# 1	deduction	2	{A if Q} |- Q => A
# 2	instantiation	3, 4, 5	{A if Q, Q} |- A
# 	P : {A if TRUE., Q : A
# 3	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 4	instantiation	6, 7, 8	{A if Q, Q} |- {A if TRUE.
# 	P(_a) : {A if _a., x : Q
# 5	instantiation	9	|- {A if TRUE. = A
# 	a : A
# 6	theorem		|- forall_{P, x | P(x), x} P(TRUE)
# 	proveit.logic.equality.substitute_in_true
# 7	assumption		{A if Q} |- {A if Q.
# 8	assumption		{Q} |- Q
# 9	axiom		|- forall_{a} ({a if TRUE. = a)
# 	proveit.core_expr_types.conditionals.true_condition_reduction
