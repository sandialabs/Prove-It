# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.core_expr_types.indexed_vars</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

# %%
# %begin theorems
# Out:
# Defining theorems for theory 'proveit.core_expr_types.indexed_vars'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
# %end theorems
# Out:
# Theory proveit.core_expr_types.indexed_vars has no theorems
