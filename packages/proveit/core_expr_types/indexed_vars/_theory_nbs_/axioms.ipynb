# %% [markdown]
# Axioms for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.core_expr_types.indexed_vars</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the axioms of a theory:
# %axioms_notebook # Keep this at the top following 'import proveit'.

# %%
# %begin axioms
# Out:
# Defining axioms for theory 'proveit.core_expr_types.indexed_vars'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %%
# %end axioms
# Out:
# Theory proveit.core_expr_types.indexed_vars has no axioms
