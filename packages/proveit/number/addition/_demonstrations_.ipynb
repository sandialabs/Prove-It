# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.addition</a>
# ========

# %%
import proveit
from proveit import ExprList
from proveit.logic import Forall, Equals, InSet
from proveit.number import Less, Greater, LessEq, GreaterEq, Neg
from proveit._common_ import a, b,c,d,e,f,g,m,x,y
from proveit.number import zero, one,two, three,four, five, six, seven, eight,Add, Complexes, Neg, Subtract, Integers, Naturals, NaturalsPos,Reals, RealsPos, RealsNeg
# %begin demonstrations

# %%
#Add(a, one, two , c, b, a, zero, b, c, c, three).groupLikeTerms([InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(one, Reals), InSet(two, Reals)])

# %%
Add(one, two).simplification()
# Out:
# {'Lit': [[0, 1], [1, 2]]}
# before loop [[0, 1], [1, 2]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 2]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 2]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 2] 1
# (1 + 2) = (1 + 2)

# %%
Add(a, one, a).simplification([InSet(a, Reals), InSet(one, Reals)])
# Out:
# {'Lit': [[1, 1]], a: [[0, 1], [2, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# before loop [[0, 1], [2, 1]] a
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key a
# hold[key] [[0, 1], [2, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index a [[0, 1], [2, 1]] 0 [0, 1] 0
# len of expr 2
# before if 0 1
# m 0
# one, two a 1
# == False literal: False
# idx before -1 1
# idx after loop 1
# m+idx 1
# == a 1 literal: False True
# m 1
# m 2
# expr after group like terms a + 1 + a
# {'Lit': [[1, 1]], a: [[0, 1], [2, 1]]}
# new dict {'Lit': [[1, 1]], a: [[0, 1], [2, 1]]}
# in if 0 2
# swap values 1 2
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': []}
# before loop [] Lit
# values per key 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': []}
# before loop [] Lit
# values per key 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# {a in Reals , 1 in Reals} |= (a + 1 + a) = (a + a + 1)
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': []}
# before loop [] Lit
# values per key 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': []}
# before loop [] Lit
# values per key 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# n, length 0 2
# n, length 1 3
# n, length 2 3
# {'Lit': [[2, 1]], a: [[0, 1], [1, 1]]}
# new dict after swap {'Lit': [[2, 1]], a: [[0, 1], [1, 1]]}
# in loop, place, item, size (place < size) 1 [2, 1] 1
# (a + 1 + a) = (a + a + 1)

# %%
Add(a, one, two , c, b, a, zero, b, c, c, three).simplification([InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(one, Reals), InSet(two, Reals)])
# Out:
# {'Lit': [[1, 1], [2, 2], [6, 0], [10, 3]], a: [[0, 1], [5, 1]], c: [[3, 1], [8, 1], [9, 1]], b: [[4, 1], [7, 1]]}
# before loop [[1, 1], [2, 2], [6, 0], [10, 3]] Lit
# values per key 4
# in loop, place, item, size (place < size) 0 [1, 1] 3
# key Lit
# hold[key] [[1, 1], [2, 2], [6, 0], [10, 3]]
# place 0
# hold[key][place] [1, 1]
# index 1
# key, hold[key], place, hold[key][place], index Lit [[1, 1], [2, 2], [6, 0], [10, 3]] 0 [1, 1] 1
# len of expr 10
# before if 1 1
# in loop, place, item, size (place < size) 1 [2, 2] 3
# key Lit
# hold[key] [[1, 1], [2, 2], [6, 0], [10, 3]]
# place 1
# hold[key][place] [2, 2]
# index 2
# key, hold[key], place, hold[key][place], index Lit [[1, 1], [2, 2], [6, 0], [10, 3]] 1 [2, 2] 2
# len of expr 10
# before if 2 5
# m 0
# one, two a 1
# == False literal: False
# idx before -1 1
# idx after loop 1
# m+idx 1
# == a 1 literal: False True
# m 1
# one, two 1 2
# == False literal: True
# in loop idx 1
# new two c
# idx before -1 2
# idx after loop 1
# m+idx 2
# == 1 2 literal: True True
# going to group 1 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': []}
# before loop [] Lit
# values per key 0
# other [(1 + 1 , 1)]
# length of other is greater than 0: 1 1 + 1
# {'Lit': [[1, 1]]}
# before loop [[1, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [1, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# {'Lit': [[0, 1]]}
# before loop [[0, 1]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, 1] 0
# {'Lit': [[0, 1], [1, 1]]}
# before loop [[0, 1], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, 1] 1
# key Lit
# hold[key] [[0, 1], [1, 1]]
# place 0
# hold[key][place] [0, 1]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, 1], [1, 1]] 0 [0, 1] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]]]}
# before loop [[0, [(1 , 1)]]] Lit
# values per key 1
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 0
# other [(1 , 1)]
# length of other is greater than 0: 1 1
# {'Lit': [[0, [(1 , 1)]], [1, 1]]}
# before loop [[0, [(1 , 1)]], [1, 1]] Lit
# values per key 2
# in loop, place, item, size (place < size) 0 [0, [(1 , 1)]] 1
# key Lit
# hold[key] [[0, [(1 , 1)]], [1, 1]]
# place 0
# hold[key][place] [0, [(1 , 1)]]
# index 0
# key, hold[key], place, hold[key][place], index Lit [[0, [(1 , 1)]], [1, 1]] 0 [0, [(1 , 1)]] 0
# len of expr 1
# before if 0 0
# in loop, place, item, size (place < size) 1 [1, 1] 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-d63f07af2a4c> in <module>
# ----> 1 Add(a, one, two , c, b, a, zero, b, c, c, three).simplification([InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(one, Reals), InSet(two, Reals)])
#
# /home/jmadri/Prove-It/packages/proveit/number/addition/add.py in simplification(self, assumptions)
#     359                             # then they are not next to each other in the expression.
#     360                             # We must group values that are similar in order to avoid undoing previous swapping.
# --> 361                             expr = expr.groupLikeTerms(assumptions)
#     362                             print("expr after group like terms", expr)
#     363                             # create new dictionary to reflect these changes.
#
# /home/jmadri/Prove-It/packages/proveit/number/addition/add.py in groupLikeTerms(self, assumptions)
#     310                 if One == expr.operands[m + idx] or (isinstance(One, Literal) and isinstance(expr.operands[m+idx], Literal)):
#     311                     print("going to group", m , idx)
# --> 312                     expr = expr.deriveGroup(m, m + idx, assumptions).rhs
#     313                     print("after group", expr)
#     314                     length -= idx
#
# /home/jmadri/Prove-It/packages/proveit/number/addition/add.py in deriveGroup(self, beg, end, assumptions)
#     204             raise IndexError("End value must be less than length of expression.")
#     205         #print(group.specialize({l :num(beg), m:num(end - beg), n: num(len(self.terms) - end), AA:self.terms[:beg], BB:self.terms[beg : end], CC: self.terms[end :]}, assumptions=assumptions))
# --> 206         return group.specialize({l :num(beg), m:num(end - beg + 1), n: num(len(self.terms) - end - 1), AA:self.terms[:beg], BB:self.terms[beg : end + 1], CC: self.terms[end+1:]}, assumptions=assumptions)
#     207
#     208     def deriveUnGroup(self, beg, assumptions=USE_DEFAULTS):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     760                     processedSubMap[iVar] = iVar
#     761
# --> 762         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     763
#     764     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     724             generalExpr = generalTruth.expr
#     725             # perform the appropriate substitution/relabeling
# --> 726             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     727             # obtain the KnownTruths for the substituted conditions
#     728             requirementTruths = []
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     871         mappings.update(relabelMap) # mapping everything
#     872
# --> 873         subbed_expr = expr.substituted(specializeMap, relabelMap, assumptions=assumptions, requirements=requirements)
#     874
#     875         # Return the expression and conditions with substitutions and the information to reconstruct the specialization
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         subbed_exprs = []
#     334         for expr in self:
# --> 335             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     336             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     337                 # The iterated expression is being expanded
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         subbed_exprs = []
#     334         for expr in self:
# --> 335             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     336             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     337                 # The iterated expression is being expanded
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/iteration.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     279             # If there is not expansion, we will break out of the try block.
#     280
# --> 281             for iter_range in self.lambda_map.body._expandingIterRanges(iter_params, subbed_start, subbed_end, inner_expr_map, relabelMap, inner_reservations, inner_assumptions, new_requirements):
#     282                 iter_ranges.add(iter_range)
#     283                 for axis, (start, end) in enumerate(zip(*iter_range)):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/indexed.py in _expandingIterRanges(self, iterParams, startArgs, endArgs, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     147                 entryRangeGenerator = subbed_var.entryRanges(self.base, start_indices, end_indices, assumptions, requirements)
#     148
# --> 149             for (intersection_start, intersection_end) in entryRangeGenerator:
#     150                 # We must put it terms of iter parameter values (arguments) via inverting the index_expr.
#     151                 def coord2param(axis, coord):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in entryRanges(self, base, start_index, end_index, assumptions, requirements)
#     319
#     320         if not arrived_at_end:
# --> 321             raise IndexError("ExprList index out of range")
#     322
#     323     def substituted(self, exprMap, relabelMap=None, reservedVars=None, assumptions=USE_DEFAULTS, requirements=None):
#
# IndexError: ExprList index out of range

# %%
Add(a,b).deduceInNumberSet(Integers, assumptions=[InSet(a, Integers), InSet(b,Integers)]).proof()

# %%
Add(a,b,c,d).deduceInNumberSet(Integers,[InSet(a,Integers),InSet(b, Integers), InSet(c, Integers), InSet(d,Integers)]).proof()

# %%
Add(a,b).deduceInNumberSet(Naturals, assumptions=[InSet(a, Naturals), InSet(b, Naturals)]).proof()

# %%
Add(a,b,c,d).deduceInNumberSet(Naturals, assumptions=[InSet(a,Naturals), InSet(b, Naturals), InSet(c,Naturals), InSet(d, Naturals)]).proof()

# %%
Add(a,b).deduceInNumberSet(Reals, assumptions=[InSet(a, Reals), InSet(b,Reals)]).proof()

# %%
Add(a,b,c,d).deduceInNumberSet(Reals, assumptions=[InSet(a,Reals), InSet(b,Reals), InSet(c, Reals), InSet(d, Reals)]).proof()

# %%
Add(a,b).deduceInNumberSet(Complexes, assumptions=[InSet(a, Complexes), InSet(b, Complexes)]).proof()

# %%
Add(a,b,c,d).deduceInNumberSet(Complexes, assumptions=[InSet(a, Complexes), InSet(b, Complexes), InSet(c, Complexes), InSet(d,Complexes)]).proof()

# %%
Add(a,b,one,d).deduceInNumberSet(NaturalsPos, assumptions=[InSet(a, Naturals), InSet(b, Naturals), InSet(c, Naturals), InSet(d, Naturals)]).proof()

# %%
Add(zero, b).deduceAddZero([InSet(b,Complexes)]).proof()

# %%
Add(a,b,c,d).deriveSwap(1,3, assumptions=[InSet(a,Reals), InSet(b,Reals), InSet(c, Reals), InSet(d,Reals)]).proof()

# %%
Add(one, two, three, four, five, six, one).deriveGroup(3,5, assumptions = []).proof()
#Equals(Subtract(two, one),one), Equals(Subtract(one, one), zero), Equals(Subtract(three, one), two), Less(zero,Less(one, Less(two, three)))

# %%
InSet((one,two), RealsPos).substituted({})

# %%
Greater(Add(one, two, three, one), three).deduceIncAdd([InSet(two, RealsPos), InSet(three, Reals), InSet(one, RealsPos)]).proof()

# %%
Less(Add(Neg(one), Neg(two), three, Neg(one)), three).deduceDecAdd([InSet(two, RealsNeg), InSet(three, Reals), InSet(one, RealsNeg), InSet(Neg(one), RealsNeg), InSet(Neg(two), RealsNeg)]).string()

# %%
zero.prove([Subtract(x,x)]).proof()

# %%
zero.prove([Subtract(one, one)]).proof()

# %%
m.prove([Add(m, Subtract(one, one))])

# %%
# %end demonstrations
