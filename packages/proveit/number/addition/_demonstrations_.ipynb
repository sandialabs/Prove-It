# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.addition</a>
# ========

# %%
import proveit
from proveit.logic import Forall, Equals, InSet
from proveit.number import Less, Greater, LessEq, GreaterEq
from proveit._common_ import a, b,c,d,e,f,g,m,x
from proveit.number import zero, one,two, three,four, five, six, seven, eight,Add, Complexes, Neg, Subtract, Integers, Naturals, Reals, RealsPos
# %begin demonstrations

# %%
Add(a,b,c,d)._closureTheorem(Integers).proof()
# Out:
# proveit.number.addition.addIntClosure

# %%
Add(a,b,c,d)._closureTheorem(Naturals).proof()
# Out:
# proveit.number.addition.addNatClosure

# %%
Add(a,b,c,d)._closureTheorem(Reals).proof()
# Out:
# proveit.number.addition.addRealClosure

# %%
Add(a,b,c,d)._closureTheorem(Complexes).proof()
# Out:
# proveit.number.addition.addComplexClosure

# %%
Add(one,b,one,d).deduceInNaturalsPosDirectly(assumptions=[InSet(a, Naturals), InSet(b, Naturals), InSet(c, Naturals), InSet(d, Naturals)]).proof()
# Out:
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# Naturals
# Naturals
# Naturals
# Naturals
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# [a in Naturals, b in Naturals, c in Naturals, d in Naturals]
# Naturals
# Naturals
# Naturals
# Naturals
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-015ca8edf53f> in <module>
# ----> 1 Add(one,b,one,d).deduceInNaturalsPosDirectly(assumptions=[InSet(a, Naturals), InSet(b, Naturals), InSet(c, Naturals), InSet(d, Naturals)]).proof()
#
# c:\users\joaqu\prove-it\packages\proveit\number\addition\add.py in deduceInNaturalsPosDirectly(self, assumptions, ruledOutSets, dontTryPos, dontTryNeg)
#     206                 # found one positive term to make the sum positive
#     207             deducePositive(term, assumptions)
# --> 208             return addNatPosClosure.specialize({m:num(k), n:num(len(self.operands)-k-1), AA:self.operands[:k], B:term, CC:self.operands[k+1:]}, assumptions=assumptions)
#     209             #except:
#     210                # pass
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     760                     processedSubMap[iVar] = iVar
#     761
# --> 762         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     763
#     764     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     724             generalExpr = generalTruth.expr
#     725             # perform the appropriate substitution/relabeling
# --> 726             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     727             # obtain the KnownTruths for the substituted conditions
#     728             requirementTruths = []
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     871         mappings.update(relabelMap) # mapping everything
#     872
# --> 873         subbed_expr = expr.substituted(specializeMap, relabelMap, assumptions=assumptions, requirements=requirements)
#     874
#     875         # Return the expression and conditions with substitutions and the information to reconstruct the specialization
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     348         if (exprMap is not None) and (self in exprMap):
#     349             return exprMap[self]._restrictionChecked(reservedVars)
# --> 350         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     351         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     352         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         subbed_exprs = []
#     334         for expr in self:
# --> 335             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     336             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     337                 # The iterated expression is being expanded
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     348         if (exprMap is not None) and (self in exprMap):
#     349             return exprMap[self]._restrictionChecked(reservedVars)
# --> 350         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     351         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     352         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         subbed_exprs = []
#     334         for expr in self:
# --> 335             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     336             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     337                 # The iterated expression is being expanded
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\iteration.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     289                     # Add the coordinate simplification to argument sorting assumptions -
#     290                     # after all, this sorting does not go directly into the requirements.
# --> 291                     start_minus_one = _simplifiedCoord(Subtract(start, one), assumptions=assumptions, requirements=arg_sorting_assumptions)
#     292                     end_plus_one = _simplifiedCoord(Add(end, one), assumptions=assumptions, requirements=arg_sorting_assumptions)
#     293                     special_points[axis].update({start_minus_one, end_plus_one})
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\composite\composite.py in _simplifiedCoord(coord, assumptions, requirements)
#      77     from proveit.logic import Equals
#      78     #from proveit.number import Add
# ---> 79     simplified_coord = coord.simplification(assumptions=assumptions).rhs
#      80     if simplified_coord != coord and requirements is not None:
#      81         requirements.append(Equals(coord, simplified_coord))
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in simplification(self, assumptions, automation)
#     595                 raise ProofFailure(self, assumptions, "No existing simplification; cannot perform 'simplification' without automation")
#     596             return list(simplifications)[0]
# --> 597         return defaultSimplification(self.innerExpr(), inPlace=False, assumptions=assumptions)
#     598
#     599     def orderOfAppearance(self, subExpressions):
#
# c:\users\joaqu\prove-it\packages\proveit\logic\equality\equals.py in defaultSimplification(innerExpr, inPlace, mustEvaluate, operandsOnly, assumptions, automation)
#     610             # don't know how to simplify, so keep it the same
#     611             return innerSimplification(Equals(inner, inner).prove())
# --> 612     reducedInnerExpr = reduceOperands(innerExpr, inPlace, mustEvaluate, assumptions) # OR DO WE WANT TO REDUCE AT THE INNER LEVEL??
#     613     if reducedInnerExpr == innerExpr:
#     614         if mustEvaluate:
#
# c:\users\joaqu\prove-it\packages\proveit\logic\equality\equals.py in reduceOperands(innerExpr, inPlace, mustEvaluate, assumptions)
#     475             if not mustEvaluate or not isIrreducibleValue(operand):
#     476                 # the operand is not an irreducible value so it must be evaluated
# --> 477                 operandEval = operand.evaluation(assumptions=assumptions) if mustEvaluate else operand.simplification(assumptions=assumptions)
#     478                 if mustEvaluate and not isIrreducibleValue(operandEval.rhs):
#     479                     raise EvaluationError('Evaluations expected to be irreducible values')
#
# c:\users\joaqu\prove-it\packages\proveit\number\negation\neg.py in simplification(self, assumptions)
#      44         Assumptions may be necessary to deduce necessary conditions for the simplification.
#      45         '''
# ---> 46         from ._theorems_ import negNeg, negZero
#      47         from proveit.number import zero
#      48         from proveit.logic import Equals
#
# ImportError: cannot import name 'negNeg' from 'proveit.number.negation._theorems_' (c:\users\joaqu\prove-it\packages\proveit\number\negation\_theorems_.py)

# %%
Add(zero, b).deduceAddZero([InSet(b,Complexes)]).proof()

# %%
Add(a,b,c,d).deriveSwap(1,3, assumptions=[InSet(a,Reals), InSet(b,Reals), InSet(c, Reals), InSet(d,Reals)]).proof()

# %%
Add(one, two, three, four, five, six, one).deriveGroup(3,5, assumptions = []).proof()
#Equals(Subtract(two, one),one), Equals(Subtract(one, one), zero), Equals(Subtract(three, one), two), Less(zero,Less(one, Less(two, three)))
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# /home/jmadri/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove (1 + (-1)) = 4 assuming {(1 + 1) = 2, (1 + (-1)) < 1, 1 < 2, 1 = (2 + (-1)), 1 <= 1, (2 + 1) = 3, (2 + (-1)) < 2, 2 < 3, 2 = (3 + (-1)), 2 <= 2, (3 + 1) = 4, (3 + (-1)) < 3, 3 < 4, 3 = (4 + (-1)), 3 <= 3, forall_{P, x, y | P(y) , x = y} P(x), forall_{P, x, y | P(x) , x = y} P(y), forall_{x, y | x = y} (y = x), forall_{x, y, z | x < y , y < z} (x < z), forall_{x, y, z | x <= y , y < z} (x < z), forall_{x, y, z | x < y , y <= z} (x < z), forall_{x, y, z | x <= y , y <= z} (x <= z), forall_{a, b, c | (a + b) = c} ((c + b) = a)}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# EvaluationError                           Traceback (most recent call last)
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in conclude(self, assumptions)
#     102             try:
# --> 103                 evaluation = self.lhs.evaluation()
#     104                 if evaluation.rhs != self.rhs:
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in evaluation(self, assumptions, automation)
#     604             return list(evaluations)[0]
# --> 605         return defaultSimplification(self.innerExpr(), inPlace=False, mustEvaluate=True, assumptions=assumptions)
#     606
#
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in defaultSimplification(innerExpr, inPlace, mustEvaluate, operandsOnly, assumptions, automation)
#     611             return innerSimplification(Equals(inner, inner).prove())
# --> 612     reducedInnerExpr = reduceOperands(innerExpr, inPlace, mustEvaluate, assumptions) # OR DO WE WANT TO REDUCE AT THE INNER LEVEL??
#     613     if reducedInnerExpr == innerExpr:
#
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in reduceOperands(innerExpr, inPlace, mustEvaluate, assumptions)
#     476                 # the operand is not an irreducible value so it must be evaluated
# --> 477                 operandEval = operand.evaluation(assumptions=assumptions) if mustEvaluate else operand.simplification(assumptions=assumptions)
#     478                 if mustEvaluate and not isIrreducibleValue(operandEval.rhs):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in evaluation(self, assumptions, automation)
#     604             return list(evaluations)[0]
# --> 605         return defaultSimplification(self.innerExpr(), inPlace=False, mustEvaluate=True, assumptions=assumptions)
#     606
#
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in defaultSimplification(innerExpr, inPlace, mustEvaluate, operandsOnly, assumptions, automation)
#     615             # since it wasn't irreducible to begin with, it must change in order to evaluate
# --> 616             raise EvaluationError('Unable to evaluate: ' + str(inner))
#     617         elif inPlace:
#
# EvaluationError: Unable to evaluate: -1
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-9-4207bdd6d7b4> in <module>
# ----> 1 Add(one, two, three, four, five, six, one).deriveGroup(3,5, assumptions = []).proof()
#       2 #Equals(Subtract(two, one),one), Equals(Subtract(one, one), zero), Equals(Subtract(three, one), two), Less(zero,Less(one, Less(two, three)))
#
# /home/jmadri/Prove-It/packages/proveit/number/addition/add.py in deriveGroup(self, beg, end, assumptions)
#     190         if end > len(self.operands) -1:
#     191             raise IndexError("End value must be less than length of expression.")
# --> 192         print(group.specialize({l :num(beg), m:num(end - beg), n: num(len(self.terms) - end), AA:self.terms[:beg], BB:self.terms[beg : end], CC: self.terms[end :]}, assumptions=assumptions))
#     193         return group.specialize({l :num(beg), m:num(end - beg), n: num(len(self.terms) - end), AA:self.terms[:beg], BB:self.terms[beg : end], CC: self.terms[end :]}, assumptions=assumptions)
#     194
#
# /home/jmadri/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     760                     processedSubMap[iVar] = iVar
#     761
# --> 762         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     763
#     764     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     724             generalExpr = generalTruth.expr
#     725             # perform the appropriate substitution/relabeling
# --> 726             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     727             # obtain the KnownTruths for the substituted conditions
#     728             requirementTruths = []
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     871         mappings.update(relabelMap) # mapping everything
#     872
# --> 873         subbed_expr = expr.substituted(specializeMap, relabelMap, assumptions=assumptions, requirements=requirements)
#     874
#     875         # Return the expression and conditions with substitutions and the information to reconstruct the specialization
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     334         subbed_exprs = []
#     335         for expr in self:
# --> 336             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     337             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     338                 # The iterated expression is being expanded
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     334         subbed_exprs = []
#     335         for expr in self:
# --> 336             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     337             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     338                 # The iterated expression is being expanded
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/iteration.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     328                     arg_sorting_relation = None
#     329                 else:
# --> 330                     arg_sorting_relation = Less.sort(special_points[axis], assumptions=arg_sorting_assumptions)
#     331                 arg_sorting_relations.append(arg_sorting_relation)
#     332
#
# /home/jmadri/Prove-It/packages/proveit/relation/transitivity.py in sort(RelationClass, items, reorder, assumptions)
#     118         assumptions = defaults.checkedAssumptions(assumptions)
#     119         if reorder:
# --> 120             return RelationClass._transitivitySort(items, assumptions=assumptions)
#     121         else:
#     122             return RelationClass._fixedTransitivitySort(items, assumptions=assumptions)
#
# /home/jmadri/Prove-It/packages/proveit/relation/transitivity.py in _transitivitySort(RelationClass, items, assumptions)
#     537                         prepend = [Equals(item1, eq_item1).prove(assumptions)] if item1 != eq_item1 else []
#     538                         # if item2 and eq_item2 are not identical expressions, prove that they are logically equal.
# --> 539                         append = [Equals(eq_item2, item2).prove(assumptions)] if item2 != eq_item2 else []
#     540                         # make the (item1, item2) chain by prepending/appending necessary equalities to the (eq_item1, eq_item2) chain
#     541                         item_pair_chains[(item1, item2)] = prepend + item_pair_chains[(eq_item1, eq_item2)] + append
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     434                 except ProofFailure:
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#     438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in conclude(self, assumptions)
#     106                 return evaluation
#     107             except EvaluationError as e:
# --> 108                 raise ProofFailure(self, assumptions, "Evaluation error: %s"%e.message)
#     109         elif isIrreducibleValue(self.lhs):
#     110             try:
#
# ProofFailure: Unable to prove (1 + (-1)) = 4 assuming {(1 + 1) = 2, (1 + (-1)) < 1, 1 < 2, 1 = (2 + (-1)), 1 <= 1, (2 + 1) = 3, (2 + (-1)) < 2, 2 < 3, 2 = (3 + (-1)), 2 <= 2, (3 + 1) = 4, (3 + (-1)) < 3, 3 < 4, 3 = (4 + (-1)), 3 <= 3, forall_{P, x, y | P(y) , x = y} P(x), forall_{P, x, y | P(x) , x = y} P(y), forall_{x, y | x = y} (y = x), forall_{x, y, z | x < y , y < z} (x < z), forall_{x, y, z | x <= y , y < z} (x < z), forall_{x, y, z | x < y , y <= z} (x < z), forall_{x, y, z | x <= y , y <= z} (x <= z), forall_{a, b, c | (a + b) = c} ((c + b) = a)}: Evaluation error: Unable to evaluate: -1

# %%
Greater(Add(one, two, three, one), three).deduceIncAdd([InSet((one,two), RealsPos), InSet(three, Reals), InSet((one), RealsPos)]).proof()
# Out:
# 3
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# /home/jmadri/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove 3 = 1 assuming {(1 , 2) in RealsPos, 3 in Reals, 1 in RealsPos, (1 + 1) = 2, (1 + (-1)) < 1, 1 < 2, 1 = (2 + (-1)), 1 <= 1, (2 + 1) = 3, (2 + (-1)) < 2, 2 < 3, 2 = (3 + (-1)), 2 <= 2, forall_{P, x, y | P(y) , x = y} P(x), forall_{P, x, y | P(x) , x = y} P(y), forall_{x, y | x = y} (y = x), forall_{x, y, z | x < y , y < z} (x < z), forall_{x, y, z | x <= y , y < z} (x < z), forall_{x, y, z | x < y , y <= z} (x < z), forall_{x, y, z | x <= y , y <= z} (x <= z), forall_{a, b, c | (a + b) = c} ((c + b) = a)}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-8-6eecd5035421> in <module>
# ----> 1 Greater(Add(one, two, three, one), three).deduceIncAdd([InSet((one,two), RealsPos), InSet(three, Reals), InSet((one), RealsPos)]).proof()
#
# /home/jmadri/Prove-It/packages/proveit/number/ordering/greater_than.py in deduceIncAdd(self, assumptions)
#      99
#     100         if isinstance(self.lhs,Add):
# --> 101             self.lhs.concludeStrictIncAdd(self.rhs, assumptions)
#     102         else:
#     103             raise ValueError("expected self.lhs to be addition")
#
# /home/jmadri/Prove-It/packages/proveit/number/addition/add.py in concludeStrictIncAdd(self, b, assumptions)
#     129                 idx = i
#     130         nVal = len(self.terms) -1 - idx
# --> 131         print(strictlyIncreasingAdditions.specialize({m:num(idx),n:num(nVal),AA:self.terms[:idx],B:self.terms[idx],CC:self.terms[idx+1:]}, assumptions=assumptions))
#     132         return strictlyIncreasingAdditions.specialize({m:num(idx),n:num(nVal),AA:self.terms[:idx],B:self.terms[idx],CC:self.terms[idx +1:]}, assumptions=assumptions)
#     133
#
# /home/jmadri/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     760                     processedSubMap[iVar] = iVar
#     761
# --> 762         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     763
#     764     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     724             generalExpr = generalTruth.expr
#     725             # perform the appropriate substitution/relabeling
# --> 726             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     727             # obtain the KnownTruths for the substituted conditions
#     728             requirementTruths = []
#
# /home/jmadri/Prove-It/packages/proveit/_core_/proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     847                 elif parameterVar in relabelMap: subbedParam = relabelMap[parameterVar]
#     848                 if isinstance(parameter, Iter) and subbedParam is not None:
# --> 849                     expandedParameter = parameter.substituted(specializeMap, relabelMap, assumptions=assumptions, requirements=requirements)
#     850                     if len(expandedParameter) != len(subbedParam):
#     851                         raise SpecializationFailure(None, assumptions, "Substitution of iterated instance variables incomplete: %d length expansion versus %d length substitution"%(len(expandedParameter), len(subbedParam)))
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/composite/iteration.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     328                     arg_sorting_relation = None
#     329                 else:
# --> 330                     arg_sorting_relation = Less.sort(special_points[axis], assumptions=arg_sorting_assumptions)
#     331                 arg_sorting_relations.append(arg_sorting_relation)
#     332
#
# /home/jmadri/Prove-It/packages/proveit/relation/transitivity.py in sort(RelationClass, items, reorder, assumptions)
#     118         assumptions = defaults.checkedAssumptions(assumptions)
#     119         if reorder:
# --> 120             return RelationClass._transitivitySort(items, assumptions=assumptions)
#     121         else:
#     122             return RelationClass._fixedTransitivitySort(items, assumptions=assumptions)
#
# /home/jmadri/Prove-It/packages/proveit/relation/transitivity.py in _transitivitySort(RelationClass, items, assumptions)
#     535                     if (eq_item1, eq_item2) in item_pair_chains:
#     536                         # if item1 and eq_item1 are not identical expressions, prove that they are logically equal.
# --> 537                         prepend = [Equals(item1, eq_item1).prove(assumptions)] if item1 != eq_item1 else []
#     538                         # if item2 and eq_item2 are not identical expressions, prove that they are logically equal.
#     539                         append = [Equals(eq_item2, item2).prove(assumptions)] if item2 != eq_item2 else []
#
# /home/jmadri/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     434                 except ProofFailure:
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#     438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#
# /home/jmadri/Prove-It/packages/proveit/logic/equality/equals.py in conclude(self, assumptions)
#     103                 evaluation = self.lhs.evaluation()
#     104                 if evaluation.rhs != self.rhs:
# --> 105                     raise ProofFailure(self, assumptions, "Does not match with evaluation: %s"%str(evaluation))
#     106                 return evaluation
#     107             except EvaluationError as e:
#
# ProofFailure: Unable to prove 3 = 1 assuming {(1 , 2) in RealsPos, 3 in Reals, 1 in RealsPos, (1 + 1) = 2, (1 + (-1)) < 1, 1 < 2, 1 = (2 + (-1)), 1 <= 1, (2 + 1) = 3, (2 + (-1)) < 2, 2 < 3, 2 = (3 + (-1)), 2 <= 2, forall_{P, x, y | P(y) , x = y} P(x), forall_{P, x, y | P(x) , x = y} P(y), forall_{x, y | x = y} (y = x), forall_{x, y, z | x < y , y < z} (x < z), forall_{x, y, z | x <= y , y < z} (x < z), forall_{x, y, z | x < y , y <= z} (x < z), forall_{x, y, z | x <= y , y <= z} (x <= z), forall_{a, b, c | (a + b) = c} ((c + b) = a)}: Does not match with evaluation: |= 3 = 3

# %%
zero.prove([Subtract(x,x)]).proof()

# %%
zero.prove([Subtract(one, one)]).proof()

# %%
m.prove([Add(m, Subtract(one, one))])

# %%
# %end demonstrations
