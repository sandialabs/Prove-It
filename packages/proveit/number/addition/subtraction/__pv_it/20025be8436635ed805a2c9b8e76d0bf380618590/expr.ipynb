# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar, Variable
from proveit._common_ import d
from proveit.logic import InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = InSet(IndexedVar(d, Variable("_a", latexFormat = r"{_{-}a}")), Complexes)
# Out:
# expr: d_{_a} in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# d_{{_{-}a}} \in \mathbb{C}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. d_{_a} in Complexes
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (d_{_a}, Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. d_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 4. Complexes
#    core type: Literal
#    sub-expressions:
# 5. d
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
