# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#addCancelTriple_12">addCancelTriple_12</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition.subtraction._theorems_ import addCancelTriple_12

# %%
# check that the built expression is the same as the stored expression
# %check_expr addCancelTriple_12
# Out:
# Passed sanity check: built 'addCancelTriple_12' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(addCancelTriple_12.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}}~\left(\left(a - a + b\right) = b\right)

# %%
# display the expression information
addCancelTriple_12.exprInfo()
# Out:
# 0. forall_{a in Complexes, b in Complexes} ((a - a + b) = b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a - a + b) = b if a in Complexes ,  b in Complexes.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b)
#    core type: ExprTuple
#    sub-expressions: 23, 20
# 4. {(a - a + b) = b if a in Complexes ,  b in Complexes.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a - a + b) = b
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complexes) and (b in Complexes)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a - a + b, b)
#    core type: ExprTuple
#    sub-expressions: 11, 20
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Complexes, b in Complexes)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. a - a + b
#     core type: Operation
# ...
