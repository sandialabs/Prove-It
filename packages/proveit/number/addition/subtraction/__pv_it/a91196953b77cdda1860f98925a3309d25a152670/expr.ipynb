# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#negatedAdd">negatedAdd</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition.subtraction._theorems_ import negatedAdd

# %%
# check that the built expression is the same as the stored expression
# %check_expr negatedAdd
# Out:
# Passed sanity check: built 'negatedAdd' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negatedAdd.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}, c \in \mathbb{C}~|~\left(a + b\right) = c}~\left(\left(-a - b\right) = \left(-c\right)\right)

# %%
# display the expression information
negatedAdd.exprInfo()
# Out:
# 0. forall_{a in Complexes, b in Complexes, c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(-a - b) = (-c) if a in Complexes ,  b in Complexes ,  c in Complexes ,  (a + b) = c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 31, 32, 27
# 4. {(-a - b) = (-c) if a in Complexes ,  b in Complexes ,  c in Complexes ,  (a + b) = c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (-a - b) = (-c)
#    core type: Operation
#    operator: 21
#    operands: 7
# 6. (a in Complexes) and (b in Complexes) and (c in Complexes) and ((a + b) = c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (-a - b, -c)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
