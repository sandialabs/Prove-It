# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Add(b, Neg(a), a), b), And(InSet(a, Complexes), InSet(b, Complexes))))
# Out:
# expr: (a, b) -> {(b - a + a) = b if a in Complexes ,  b in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(b - a + a\right) = b \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(b - a + a) = b if a in Complexes ,  b in Complexes.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 21, 18
# 2. {(b - a + a) = b if a in Complexes ,  b in Complexes.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (b - a + a) = b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complexes) and (b in Complexes)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (b - a + a, b)
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complexes, b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. b - a + a
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Complexes
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. b in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (b, -a, a)
#     core type: ExprTuple
#     sub-expressions: 18, 17, 21
# 14. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. -a
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. Complexes
#     core type: Literal
#     sub-expressions:
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
