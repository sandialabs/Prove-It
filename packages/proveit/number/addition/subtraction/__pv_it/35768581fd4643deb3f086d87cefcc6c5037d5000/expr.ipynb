# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b
from proveit.logic import InSet
from proveit.number import LessEq, Naturals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Naturals), InSet(b, Naturals), LessEq(b, a))
# Out:
# expr: (a in Naturals, b in Naturals, b <= a)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{N}, b \in \mathbb{N}, b \leq a\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Naturals, b in Naturals, b <= a)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. a in Naturals
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. b in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. b <= a
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (a, Naturals)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (b, a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
