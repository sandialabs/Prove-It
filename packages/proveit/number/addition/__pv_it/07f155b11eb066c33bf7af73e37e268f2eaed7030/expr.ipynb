# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b
from proveit.number import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = ExprTuple(Mult(Add(two, three, one, subExpr1).withSubtractionAt(), b), Add(Mult(two, b), Mult(three, b), Mult(one, b), Mult(subExpr1, b)).withSubtractionAt(3))
# Out:
# expr: ((2 + 3 + 1 + (-1)) * b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 + 3 + 1 + \left(-1\right)\right) \cdot b, \left(2 \cdot b\right) + \left(3 \cdot b\right) + \left(1 \cdot b\right) + \left(\left(-1\right) \cdot b\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 + 3 + 1 + (-1)) * b, (2 * b) + (3 * b) + (1 * b) + ((-1) * b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 + 3 + 1 + (-1)) * b
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (2 * b) + (3 * b) + (1 * b) + ((-1) * b)
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 + 3 + 1 + (-1), b)
#    core type: ExprTuple
#    sub-expressions: 5, 20
# 4. (2 * b, 3 * b, 1 * b, (-1) * b)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 2 + 3 + 1 + (-1)
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 12
# 7. 3 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 8. 1 * b
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. (-1) * b
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (2, 3, 1, -1)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 22, 19
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 14. (1, b)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (-1, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. -1
#     core type: Operation
#     operator: 21
#     operand: 22
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
