# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable
from proveit._common_ import a, c
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(two, a), Mult(two, c), Variable("_a", latexFormat = r"{_{-}a}"), Add(two, three, four))
# Out:
# expr: (2 * a, 2 * c, _a, 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot a, 2 \cdot c, {_{-}a}, 2 + 3 + 4\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 * a, 2 * c, _a, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. 2 * a
#    core type: Operation
#    operator: 6
#    operands: 5
# 2. 2 * c
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. _a
#    core type: Variable
#    sub-expressions:
# 4. 2 + 3 + 4
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. (2, a)
#    core type: ExprTuple
#    sub-expressions: 12, 10
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (2, c)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 4
#     core type: Literal
#     sub-expressions:
