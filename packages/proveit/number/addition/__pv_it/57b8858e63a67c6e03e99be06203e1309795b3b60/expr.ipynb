# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, b, c, i, j
from proveit.logic import InSet
from proveit.number import Greater, RealsNonNeg, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), RealsNonNeg), one, i), InSet(b, RealsNonNeg), ExprRange(subExpr1, InSet(IndexedVar(c, subExpr1), RealsNonNeg), one, j), Greater(b, zero))
# Out:
# expr: (a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg, b in RealsNonNeg, c_{1} in RealsNonNeg, ..c_{_a} in RealsNonNeg.., c_{j} in RealsNonNeg, b > 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{R}^{\ge 0}, \ldots, a_{i} \in \mathbb{R}^{\ge 0}, b \in \mathbb{R}^{\ge 0}, c_{1} \in \mathbb{R}^{\ge 0}, \ldots, c_{j} \in \mathbb{R}^{\ge 0}, b > 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg, b in RealsNonNeg, c_{1} in RealsNonNeg, ..c_{_a} in RealsNonNeg.., c_{j} in RealsNonNeg, b > 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. (a_{1} in RealsNonNeg), ..(a_{_a} in RealsNonNeg).., (a_{i} in RealsNonNeg)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 9
#    end_index: 6
# 2. b in RealsNonNeg
#    core type: Operation
#    operator: 18
#    operands: 7
# 3. (c_{1} in RealsNonNeg), ..(c_{_a} in RealsNonNeg).., (c_{j} in RealsNonNeg)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 4. b > 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 5. _a -> (a_{_a} in RealsNonNeg)
#    core type: Lambda
#    parameter: 25
#    body: 13
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. (b, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 22
# 8. _a -> (c_{_a} in RealsNonNeg)
#    core type: Lambda
# ...
