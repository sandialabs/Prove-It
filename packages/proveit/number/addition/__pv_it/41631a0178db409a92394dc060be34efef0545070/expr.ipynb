# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(a, a, c, c, c, b, b, one, two, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + a + c + c + c + b + b + 1 + 2 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3\right) = \left(a + a + c + c + c + b + b + 1 + 2 + 3\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + a + c + c + c + b + b + 1 + 2 + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, a + a + c + c + c + b + b + 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + a + c + c + c + b + b + 1 + 2 + 3
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 12, 13, 10, 11, 9, 8, 11, 10, 10, 14
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a, a, c, c, c, b, b, 1, 2, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 9, 10, 10, 10, 11, 11, 12, 13, 14
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
