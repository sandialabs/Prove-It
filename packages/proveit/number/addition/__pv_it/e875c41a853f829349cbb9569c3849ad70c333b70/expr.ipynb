# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import B, C, c, k
from proveit.core_expr_types import Len
from proveit.number import five, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([B, C, c, one, three]), Len([ExprRange(k, k, one, five)]))
# Out:
# expr: (|(B, C, c, 1, 3)|, |(1, ..k.., 5)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(B, C, c, 1, 3\right)|, |\left(1, \ldots, 5\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(B, C, c, 1, 3)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(B, C, c, 1, 3)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((B, C, c, 1, 3))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (B, C, c, 1, 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 14, 11
# 7. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 1, ..k.., 5
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
