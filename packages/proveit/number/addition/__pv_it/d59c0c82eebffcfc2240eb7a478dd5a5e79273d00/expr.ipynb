# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import InSet, Set
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = Set(InSet(d, Complexes), InSet(b, Complexes), InSet(a, Complexes), InSet(c, Complexes))
# Out:
# expr: {d in Complexes, b in Complexes, a in Complexes, c in Complexes}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{d \in \mathbb{C}, b \in \mathbb{C}, a \in \mathbb{C}, c \in \mathbb{C}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {d in Complexes, b in Complexes, a in Complexes, c in Complexes}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (d in Complexes, b in Complexes, a in Complexes, c in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. d in Complexes
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. b in Complexes
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. a in Complexes
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. c in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (d, Complexes)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (b, Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (a, Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (c, Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. d
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. Complexes
#     core type: Literal
#     sub-expressions:
