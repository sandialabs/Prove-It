# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import InSet
from proveit.number import Add, Reals

# %%
# build up the expression from sub-expressions
expr = InSet(Add(a_1_to_i), Reals)
# Out:
# expr: (a_{1} + ..a_{_a}.. + a_{i}) in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} + ..a_{_a}.. + a_{i}) in Reals
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} + ..a_{_a}.. + a_{i}, Reals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{1} + ..a_{_a}.. + a_{i}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Reals
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. _a -> a_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. a_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
