# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import b, c, k
from proveit.core_expr_types import Len
from proveit.number import four, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([b, c, c, three]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(b, c, c, 3)|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b, c, c, 3\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(b, c, c, 3)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b, c, c, 3)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((b, c, c, 3))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 9, 10
# 7. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 1, ..k.., 4
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 4
#     core type: Literal
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
