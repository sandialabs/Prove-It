# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = Equals(Add(Mult(one, two), b, c, subExpr1, subExpr2, Mult(one, c)), Add(two, b, c, subExpr1, subExpr2, c))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)) = (2 + b + c + (3 * b) + (2 * b) + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 \cdot 2\right) + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + \left(1 \cdot c\right)\right) = \left(2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + c\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)) = (2 + b + c + (3 * b) + (2 * b) + c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c), 2 + b + c + (3 * b) + (2 * b) + c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1 * 2, b, c, 3 * b, 2 * b, 1 * c)
#    core type: ExprTuple
#    sub-expressions: 8, 21, 18, 10, 11, 9
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2, b, c, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 20, 21, 18, 10, 11, 18
# 8. 1 * 2
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. 1 * c
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. 3 * b
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. 2 * b
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 13. (1, c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (3, b)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
