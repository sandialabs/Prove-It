# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, i
from proveit.logic import InSet
from proveit.number import RealsNonNeg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), RealsNonNeg), one, i))
# Out:
# expr: (a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{R}^{\ge 0}, \ldots, a_{i} \in \mathbb{R}^{\ge 0}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1} in RealsNonNeg), ..(a_{_a} in RealsNonNeg).., (a_{i} in RealsNonNeg)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _a -> (a_{_a} in RealsNonNeg)
#    core type: Lambda
#    parameter: 11
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. i
#    core type: Variable
#    sub-expressions:
# 5. a_{_a} in RealsNonNeg
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (a_{_a}, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. a_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. RealsNonNeg
#    core type: Literal
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
