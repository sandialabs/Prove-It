# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b
from proveit.number import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(Mult(one, b), Mult(three, b), Mult(two, b)), Mult(Add(one, three, two), b))
# Out:
# expr: ((1 * b) + (3 * b) + (2 * b), (1 + 3 + 2) * b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 \cdot b\right) + \left(3 \cdot b\right) + \left(2 \cdot b\right), \left(1 + 3 + 2\right) \cdot b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 * b) + (3 * b) + (2 * b), (1 + 3 + 2) * b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 * b) + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (1 + 3 + 2) * b
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (1 * b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. (1 + 3 + 2, b)
#    core type: ExprTuple
#    sub-expressions: 8, 15
# 5. 1 * b
#    core type: Operation
#    operator: 11
#    operands: 9
# 6. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. 1 + 3 + 2
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (1, b)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 10. (3, b)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (1, 3, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
