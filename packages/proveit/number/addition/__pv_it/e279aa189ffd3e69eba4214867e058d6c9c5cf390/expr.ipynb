# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#addIntClosure">addIntClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition._theorems_ import addIntClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr addIntClosure
# Out:
# Passed sanity check: built 'addIntClosure' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(addIntClosure.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i} \in \mathbb{Z}}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{Z}\right)\right]

# %%
# display the expression information
addIntClosure.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers) if i in Naturals.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in Integers if (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{i} in Integers).
#    core type: Lambda
# ...
