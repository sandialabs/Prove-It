# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import a, c
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Mult(two, a), Mult(two, c), Variable("_a", latexFormat = r"{_{-}a}"), Add(two, three, four))
# Out:
# expr: (2 * a) + (2 * c) + _a + (2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot a\right) + \left(2 \cdot c\right) + {_{-}a} + \left(2 + 3 + 4\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 * a) + (2 * c) + _a + (2 + 3 + 4)
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. (2 * a, 2 * c, _a, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. 2 * a
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. 2 * c
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. 2 + 3 + 4
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (2, a)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (2, c)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
