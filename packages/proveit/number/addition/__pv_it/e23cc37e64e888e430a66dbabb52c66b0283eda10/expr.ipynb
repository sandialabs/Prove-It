# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, b)
expr = ExprTuple(Add(subExpr1, b, a, c), Add(Add(subExpr1, b), a, c))
# Out:
# expr: ((2 * b) + b + a + c, ((2 * b) + b) + a + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + b + a + c, \left(\left(2 \cdot b\right) + b\right) + a + c\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + b + a + c, ((2 * b) + b) + a + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + b + a + c
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. ((2 * b) + b) + a + c
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (2 * b, b, a, c)
#    core type: ExprTuple
#    sub-expressions: 10, 14, 6, 7
# 4. ((2 * b) + b, a, c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. (2 * b) + b
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (2 * b, b)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 10. 2 * b
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
