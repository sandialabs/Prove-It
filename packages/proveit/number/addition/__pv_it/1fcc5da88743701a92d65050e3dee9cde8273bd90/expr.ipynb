# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit._common_ import a, i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import And, InSet
from proveit.number import Add, RealsNonNeg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Conditional(InSet(Add(a_1_to_i), RealsNonNeg), And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), RealsNonNeg), one, i)))
# Out:
# expr: {(a_{1} + ..a_{_a}.. + a_{i}) in RealsNonNeg if (a_{1} in RealsNonNeg) and ..(a_{_a} in RealsNonNeg).. and (a_{i} in RealsNonNeg).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}^{\ge 0} \textrm{ if } \left(a_{1} \in \mathbb{R}^{\ge 0}\right) \land \ldots \land \left(a_{i} \in \mathbb{R}^{\ge 0}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1} + ..a_{_a}.. + a_{i}) in RealsNonNeg if (a_{1} in RealsNonNeg) and ..(a_{_a} in RealsNonNeg).. and (a_{i} in RealsNonNeg).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} + ..a_{_a}.. + a_{i}) in RealsNonNeg
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (a_{1} in RealsNonNeg) and ..(a_{_a} in RealsNonNeg).. and (a_{i} in RealsNonNeg)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} + ..a_{_a}.. + a_{i}, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 6, 19
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. a_{1} + ..a_{_a}.. + a_{i}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in RealsNonNeg), ..(a_{_a} in RealsNonNeg).., (a_{i} in RealsNonNeg)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# ...
