# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, three, four, a, a, c, zero, c, b, b), Add(Mult(two, a), Mult(two, c), Add(b, b), Add(two, three, four)))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + 3 + 4 + a + a + c + 0 + c + b + b\right) = \left(\left(2 \cdot a\right) + \left(2 \cdot c\right) + \left(b + b\right) + \left(2 + 3 + 4\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + 3 + 4 + a + a + c + 0 + c + b + b, (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (2, 3, 4, a, a, c, 0, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 21, 22, 23, 18, 18, 19, 7, 19, 20, 20
# 6. (2 * a, 2 * c, b + b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. 2 * a
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * c
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. b + b
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. 2 + 3 + 4
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (2, a)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, c)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 15. (b, b)
#     core type: ExprTuple
#     sub-expressions: 20, 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. 3
#     core type: Literal
#     sub-expressions:
# 23. 4
#     core type: Literal
#     sub-expressions:
