# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, k
from proveit.core_expr_types import Len
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([Add(a, a, a, a, a)]), Len([ExprRange(k, k, one, one)]))
# Out:
# expr: (|(a + a + a + a + a)|, |(1, ..k.., 1)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a + a + a + a + a\right)|, |\left(1, \ldots, 1\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a + a + a + a + a)|, |(1, ..k.., 1)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a + a + a + a + a)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 1)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a + a + a + a + a))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a + a + a + a + a)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., 1)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. a + a + a + a + a
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. 1, ..k.., 1
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (a, a, a, a, a)
#     core type: ExprTuple
#     sub-expressions: 14, 14, 14, 14, 14
# 12. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
