# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, three

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, b, c, a, b, a, c), Add(Mult(three, a), Add(b, b), Add(c, c)))
# Out:
# expr: (a + b + c + a + b + a + c) = ((3 * a) + (b + b) + (c + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + b + c + a + b + a + c\right) = \left(\left(3 \cdot a\right) + \left(b + b\right) + \left(c + c\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + b + c + a + b + a + c) = ((3 * a) + (b + b) + (c + c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + b + c + a + b + a + c, (3 * a) + (b + b) + (c + c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + b + c + a + b + a + c
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (3 * a) + (b + b) + (c + c)
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. (a, b, c, a, b, a, c)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18, 16, 17, 16, 18
# 6. (3 * a, b + b, c + c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. 3 * a
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. b + b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. c + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (3, a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (b, b)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (c, c)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
