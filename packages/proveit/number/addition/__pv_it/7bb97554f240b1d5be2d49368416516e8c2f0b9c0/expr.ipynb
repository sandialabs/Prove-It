# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(two, b, c, subExpr1, subExpr2, c), Add(Add(b, subExpr1, subExpr2), Add(c, c), two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) + c, (b + (3 * b) + (2 * b)) + (c + c) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) + c, \left(b + \left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + \left(c + c\right) + 2\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) + c, (b + (3 * b) + (2 * b)) + (c + c) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (b + (3 * b) + (2 * b)) + (c + c) + 2
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (2, b, c, 3 * b, 2 * b, c)
#    core type: ExprTuple
#    sub-expressions: 17, 18, 12, 10, 11, 12
# 4. (b + (3 * b) + (2 * b), c + c, 2)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 17
# 5. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. c + c
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (b, 3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 18, 10, 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (c, c)
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 10. 3 * b
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. 2 * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
