# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = Equals(Add(two, b, c, subExpr1, subExpr2, Neg(b), c), Add(c, c, subExpr1, two, subExpr2))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) - b + c) = (c + c + (3 * b) + 2 + (2 * b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + b + c + \left(3 \cdot b\right) + \left(2 \cdot b\right) - b + c\right) = \left(c + c + \left(3 \cdot b\right) + 2 + \left(2 \cdot b\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) - b + c) = (c + c + (3 * b) + 2 + (2 * b))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + b + c + (3 * b) + (2 * b) - b + c, c + c + (3 * b) + 2 + (2 * b))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + b + c + (3 * b) + (2 * b) - b + c
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. c + c + (3 * b) + 2 + (2 * b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2, b, c, 3 * b, 2 * b, -b, c)
#    core type: ExprTuple
#    sub-expressions: 17, 18, 9, 10, 11, 8, 9
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (c, c, 3 * b, 2, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 9, 9, 10, 17, 11
# 8. -b
#    core type: Operation
#    operator: 12
#    operand: 18
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. 3 * b
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. 2 * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
