# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#elimZeroAny">elimZeroAny</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition._theorems_ import elimZeroAny

# %%
# check that the built expression is the same as the stored expression
# %check_expr elimZeroAny
# Out:
# Passed sanity check: built 'elimZeroAny' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(elimZeroAny.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}, j \in \mathbb{N}}~\left[\forall_{a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, b_{1} \in \mathbb{C}, \ldots, b_{j} \in \mathbb{C}}~\left(\left(a_{1} + \ldots + a_{i} + 0 + b_{1} + \ldots + b_{j}\right) = \left(a_{1} + \ldots + a_{i} + b_{1} + \ldots + b_{j}\right)\right)\right]

# %%
# display the expression information
elimZeroAny.exprInfo()
# Out:
# 0. forall_{i in Naturals, j in Naturals} [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes} ((a_{1} + ..a_{_a}.. + a_{i} + 0 + b_{1} + ..b_{_a}.. + b_{j}) = (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j) -> {forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes} ((a_{1} + ..a_{_a}.. + a_{i} + 0 + b_{1} + ..b_{_a}.. + b_{j}) = (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j})) if i in Naturals ,  j in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 36, 39
# ...
