# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(two, b, c, Mult(three, b), Mult(two, b), Neg(b), Mult(one, c))
# Out:
# expr: (2, b, c, 3 * b, 2 * b, -b, 1 * c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2, b, c, 3 \cdot b, 2 \cdot b, -b, 1 \cdot c\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2, b, c, 3 * b, 2 * b, -b, 1 * c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 14, 1, 2, 3, 4
# 1. 3 * b
#    core type: Operation
#    operator: 8
#    operands: 5
# 2. 2 * b
#    core type: Operation
#    operator: 8
#    operands: 6
# 3. -b
#    core type: Operation
#    operator: 7
#    operand: 12
# 4. 1 * c
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. (3, b)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 6. (2, b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. -
#    core type: Literal
#    sub-expressions:
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. (1, c)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
