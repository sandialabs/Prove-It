# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b, c
from proveit.number import Add, one, three, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(one, a, A, zero, b, B, C, c, one, three, A), Add(a, A, A, b, B, C, one, c, one, three))
# Out:
# expr: (1 + a + A + 0 + b + B + C + c + 1 + 3 + A, a + A + A + b + B + C + 1 + c + 1 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 + a + A + 0 + b + B + C + c + 1 + 3 + A, a + A + A + b + B + C + 1 + c + 1 + 3\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 + a + A + 0 + b + B + C + c + 1 + 3 + A, a + A + A + b + B + C + 1 + c + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 + a + A + 0 + b + B + C + c + 1 + 3 + A
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a + A + A + b + B + C + 1 + c + 1 + 3
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1, a, A, 0, b, B, C, c, 1, 3, A)
#    core type: ExprTuple
#    sub-expressions: 13, 7, 8, 6, 9, 10, 11, 12, 13, 14, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (a, A, A, b, B, C, 1, c, 1, 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 8, 9, 10, 11, 13, 12, 13, 14
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
