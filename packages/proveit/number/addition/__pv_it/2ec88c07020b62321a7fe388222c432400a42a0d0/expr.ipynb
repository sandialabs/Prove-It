# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i], InSet(Add(a_1_to_i), Reals), domain = Reals), InSet(i, Naturals))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals) if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{i} \in \mathbb{R}}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals) if i in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. i in Naturals
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in Reals if (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals).
#    core type: Lambda
#    parameter: 18
#    body: 6
# 5. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. {(a_{1} + ..a_{_a}.. + a_{i}) in Reals if (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals).
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} + ..a_{_a}.. + a_{i}) in Reals
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a_{1} + ..a_{_a}.. + a_{i}, Reals)
#     core type: ExprTuple
#     sub-expressions: 13, 26
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (a_{1} in Reals, ..a_{_a} in Reals.., a_{i} in Reals)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. a_{1} + ..a_{_a}.. + a_{i}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a_{1} in Reals), ..(a_{_a} in Reals).., (a_{i} in Reals)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (a_{_a} in Reals)
#     core type: Lambda
#     parameter: 28
#     body: 19
# 18. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. a_{_a} in Reals
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> a_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (a_{_a}, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. a_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. Reals
#     core type: Literal
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
