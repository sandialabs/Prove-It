# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#strictlyIncreasingAdditions">strictlyIncreasingAdditions</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition._theorems_ import strictlyIncreasingAdditions

# %%
# check that the built expression is the same as the stored expression
# %check_expr strictlyIncreasingAdditions
# Out:
# Passed sanity check: built 'strictlyIncreasingAdditions' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(strictlyIncreasingAdditions.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}, j \in \mathbb{N}}~\left[\forall_{a_{1} \in \mathbb{R}^+, \ldots, a_{i} \in \mathbb{R}^+, c_{1} \in \mathbb{R}^+, \ldots, c_{j} \in \mathbb{R}^+}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) > b\right)\right]\right]

# %%
# display the expression information
strictlyIncreasingAdditions.exprInfo()
# Out:
# 0. forall_{i in Naturals, j in Naturals} [forall_{a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{i} in RealsPos, c_{1} in RealsPos, ..c_{_a} in RealsPos.., c_{j} in RealsPos} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)]]
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. (i, j) -> {forall_{a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{i} in RealsPos, c_{1} in RealsPos, ..c_{_a} in RealsPos.., c_{j} in RealsPos} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)] if i in Naturals ,  j in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 45, 48
# 3. {forall_{a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{i} in RealsPos, c_{1} in RealsPos, ..c_{_a} in RealsPos.., c_{j} in RealsPos} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)] if i in Naturals ,  j in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{i} in RealsPos, c_{1} in RealsPos, ..c_{_a} in RealsPos.., c_{j} in RealsPos} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)]
#    core type: Operation
#    operator: 16
#    operand: 6
# 5. (i in Naturals) and (j in Naturals)
#    core type: Operation
#    operator: 18
#    operands: 7
# 6. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}) -> {forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b) if a_{1} in RealsPos ,  ..a_{_a} in RealsPos.. ,  a_{i} in RealsPos ,  c_{1} in RealsPos ,  ..c_{_a} in RealsPos.. ,  c_{j} in RealsPos.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (i in Naturals, j in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j})
#    core type: ExprTuple
#    sub-expressions: 41, 43
# 9. {forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b) if a_{1} in RealsPos ,  ..a_{_a} in RealsPos.. ,  a_{i} in RealsPos ,  c_{1} in RealsPos ,  ..c_{_a} in RealsPos.. ,  c_{j} in RealsPos.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. i in Naturals
#     core type: Operation
#     operator: 36
#     operands: 14
# 11. j in Naturals
#     core type: Operation
#     operator: 36
#     operands: 15
# 12. forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b)
#     core type: Operation
#     operator: 16
#     operand: 17
# 13. (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{i} in RealsPos) and (c_{1} in RealsPos) and ..(c_{_a} in RealsPos).. and (c_{j} in RealsPos)
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (i, Naturals)
#     core type: ExprTuple
#     sub-expressions: 45, 20
# 15. (j, Naturals)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. b -> {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b if b in Reals.
#     core type: Lambda
#     parameter: 42
#     body: 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{i} in RealsPos, c_{1} in RealsPos, ..c_{_a} in RealsPos.., c_{j} in RealsPos)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. Naturals
#     core type: Literal
#     sub-expressions:
# 21. {(a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b if b in Reals.
#     core type: Conditional
#     value: 24
#     condition: 25
# 22. (a_{1} in RealsPos), ..(a_{_a} in RealsPos).., (a_{i} in RealsPos)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 47
#     end_index: 45
# 23. (c_{1} in RealsPos), ..(c_{_a} in RealsPos).., (c_{j} in RealsPos)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 47
#     end_index: 48
# 24. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) > b
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. b in Reals
#     core type: Operation
#     operator: 36
#     operands: 30
# 26. _a -> (a_{_a} in RealsPos)
#     core type: Lambda
#     parameter: 53
#     body: 31
# 27. _a -> (c_{_a} in RealsPos)
#     core type: Lambda
#     parameter: 53
#     body: 32
# 28. >
#     core type: Literal
#     sub-expressions:
# 29. (a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}, b)
#     core type: ExprTuple
#     sub-expressions: 33, 42
# 30. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 42, 34
# 31. a_{_a} in RealsPos
#     core type: Operation
#     operator: 36
#     operands: 35
# 32. c_{_a} in RealsPos
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. Reals
#     core type: Literal
#     sub-expressions:
# 35. (a_{_a}, RealsPos)
#     core type: ExprTuple
#     sub-expressions: 49, 40
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (c_{_a}, RealsPos)
#     core type: ExprTuple
#     sub-expressions: 50, 40
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j})
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 40. RealsPos
#     core type: Literal
#     sub-expressions:
# 41. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 42. b
#     core type: Variable
#     sub-expressions:
# 43. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 49
# 45. i
#     core type: Variable
#     sub-expressions:
# 46. _a -> c_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. j
#     core type: Variable
#     sub-expressions:
# 49. a_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 50. c_{_a}
#     core type: IndexedVar
# variable: 52
# index: 53
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. c
#     core type: Variable
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
