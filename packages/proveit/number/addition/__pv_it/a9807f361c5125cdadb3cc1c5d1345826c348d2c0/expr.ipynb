# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_j
from proveit.logic import Forall
from proveit.number import Add, Less, Reals, RealsNeg

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, c_1_to_j], Forall([b], Less(Add(a_1_to_i, b, c_1_to_j), b), domain = Reals), domains = [RealsNeg, RealsNeg])
# Out:
# expr: forall_{a_{1} in RealsNeg, ..a_{_a} in RealsNeg.., a_{i} in RealsNeg, c_{1} in RealsNeg, ..c_{_a} in RealsNeg.., c_{j} in RealsNeg} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) < b)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1} \in \mathbb{R}^-, \ldots, a_{i} \in \mathbb{R}^-, c_{1} \in \mathbb{R}^-, \ldots, c_{j} \in \mathbb{R}^-}~\left[\forall_{b \in \mathbb{R}}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) < b\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1} in RealsNeg, ..a_{_a} in RealsNeg.., a_{i} in RealsNeg, c_{1} in RealsNeg, ..c_{_a} in RealsNeg.., c_{j} in RealsNeg} [forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) < b)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}) -> {forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) < b) if a_{1} in RealsNeg ,  ..a_{_a} in RealsNeg.. ,  a_{i} in RealsNeg ,  c_{1} in RealsNeg ,  ..c_{_a} in RealsNeg.. ,  c_{j} in RealsNeg.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j})
#    core type: ExprTuple
#    sub-expressions: 30, 32
# 3. {forall_{b in Reals} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) < b) if a_{1} in RealsNeg ,  ..a_{_a} in RealsNeg.. ,  a_{i} in RealsNeg ,  c_{1} in RealsNeg ,  ..c_{_a} in RealsNeg.. ,  c_{j} in RealsNeg.
#    core type: Conditional
# ...
