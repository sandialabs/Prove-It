# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import b, i, j
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_j
from proveit.logic import And, Forall, InSet
from proveit.number import Add, Greater, Naturals, NaturalsPos, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j], Conditional(Forall([a_1_to_i, b, c_1_to_j], InSet(Add(a_1_to_i, b, c_1_to_j), NaturalsPos), domains = [Naturals, Naturals, Naturals], condition = Greater(b, zero)), And(InSet(i, Naturals), InSet(j, Naturals))))
# Out:
# expr: (i, j) -> {forall_{a_{1} in Naturals, ..a_{_a} in Naturals.., a_{i} in Naturals, b in Naturals, c_{1} in Naturals, ..c_{_a} in Naturals.., c_{j} in Naturals | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalsPos) if i in Naturals ,  j in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j\right) \mapsto \left\{\forall_{a_{1} \in \mathbb{N}, \ldots, a_{i} \in \mathbb{N}, b \in \mathbb{N}, c_{1} \in \mathbb{N}, \ldots, c_{j} \in \mathbb{N}~|~b > 0}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) \in \mathbb{N}^+\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (i, j) -> {forall_{a_{1} in Naturals, ..a_{_a} in Naturals.., a_{i} in Naturals, b in Naturals, c_{1} in Naturals, ..c_{_a} in Naturals.., c_{j} in Naturals | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalsPos) if i in Naturals ,  j in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j)
#    core type: ExprTuple
#    sub-expressions: 38, 41
# 2. {forall_{a_{1} in Naturals, ..a_{_a} in Naturals.., a_{i} in Naturals, b in Naturals, c_{1} in Naturals, ..c_{_a} in Naturals.., c_{j} in Naturals | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalsPos) if i in Naturals ,  j in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1} in Naturals, ..a_{_a} in Naturals.., a_{i} in Naturals, b in Naturals, c_{1} in Naturals, ..c_{_a} in Naturals.., c_{j} in Naturals | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in NaturalsPos)
# ...
