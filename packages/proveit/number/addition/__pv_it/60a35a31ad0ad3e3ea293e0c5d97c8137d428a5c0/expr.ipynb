# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import c
from proveit.logic import Equals
from proveit.number import Add, Mult, one, seven, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(one, c, two, three, c, one, c), Add(Mult(three, c), seven))
# Out:
# expr: (1 + c + 2 + 3 + c + 1 + c) = ((3 * c) + 7)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 + c + 2 + 3 + c + 1 + c\right) = \left(\left(3 \cdot c\right) + 7\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 + c + 2 + 3 + c + 1 + c) = ((3 * c) + 7)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1 + c + 2 + 3 + c + 1 + c, (3 * c) + 7)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1 + c + 2 + 3 + c + 1 + c
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (3 * c) + 7
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1, c, 2, 3, c, 1, c)
#    core type: ExprTuple
#    sub-expressions: 9, 15, 8, 14, 15, 9, 15
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (3 * c, 7)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 3 * c
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. 7
#     core type: Literal
#     sub-expressions:
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (3, c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
