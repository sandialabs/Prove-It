# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, three, four, a, a, c, zero, c, b, b), Add(Add(a, a), Add(c, c), b, b, two, three, four))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((a + a) + (c + c) + b + b + 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + 3 + 4 + a + a + c + 0 + c + b + b\right) = \left(\left(a + a\right) + \left(c + c\right) + b + b + 2 + 3 + 4\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((a + a) + (c + c) + b + b + 2 + 3 + 4)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + 3 + 4 + a + a + c + 0 + c + b + b, (a + a) + (c + c) + b + b + 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. (a + a) + (c + c) + b + b + 2 + 3 + 4
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (2, 3, 4, a, a, c, 0, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 17, 17, 18, 7, 18, 10, 10
# 6. (a + a, c + c, b, b, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 10, 11, 12, 13
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. a + a
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. c + c
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
# 14. (a, a)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (c, c)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
