# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Add(a, a), Add(c, c, c), b, b, one, two, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, (a + a) + (c + c + c) + b + b + 1 + 2 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3, \left(a + a\right) + \left(c + c + c\right) + b + b + 1 + 2 + 3\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, (a + a) + (c + c + c) + b + b + 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (a + a) + (c + c + c) + b + b + 1 + 2 + 3
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 15, 9, 10, 16, 8, 15, 5, 8, 16, 16, 11
# 4. (a + a, c + c + c, b, b, 1, 2, 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 8, 9, 10, 11
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. a + a
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. c + c + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. (a, a)
#     core type: ExprTuple
#     sub-expressions: 15, 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (c, c, c)
#     core type: ExprTuple
#     sub-expressions: 16, 16, 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
