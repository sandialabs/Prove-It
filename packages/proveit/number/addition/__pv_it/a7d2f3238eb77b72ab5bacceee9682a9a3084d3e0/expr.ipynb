# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i], InSet(Add(a_1_to_i), NaturalsPos), domain = NaturalsPos), InSet(i, Naturals))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalsPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalsPos) if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{i} \in \mathbb{N}^+}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{N}^+\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalsPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalsPos) if i in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{i} in NaturalsPos} ((a_{1} + ..a_{_a}.. + a_{i}) in NaturalsPos)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. i in Naturals
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in NaturalsPos if (a_{1} in NaturalsPos) and ..(a_{_a} in NaturalsPos).. and (a_{i} in NaturalsPos).
#    core type: Lambda
#    parameter: 18
#    body: 6
# 5. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. {(a_{1} + ..a_{_a}.. + a_{i}) in NaturalsPos if (a_{1} in NaturalsPos) and ..(a_{_a} in NaturalsPos).. and (a_{i} in NaturalsPos).
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. Naturals
# ...
