# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, a)
subExpr2 = Mult(two, c)
subExpr3 = Add(two, three, four)
expr = ExprTuple(Add(subExpr1, subExpr2, Add(b, b), subExpr3), Add(subExpr1, subExpr2, Mult(two, b), subExpr3))
# Out:
# expr: ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4), (2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot a\right) + \left(2 \cdot c\right) + \left(b + b\right) + \left(2 + 3 + 4\right), \left(2 \cdot a\right) + \left(2 \cdot c\right) + \left(2 \cdot b\right) + \left(2 + 3 + 4\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4), (2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 15
#    operands: 4
# 3. (2 * a, 2 * c, b + b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 5, 9
# 4. (2 * a, 2 * c, 2 * b, 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. b + b
#    core type: Operation
#    operator: 15
#    operands: 10
# 6. 2 * a
#    core type: Operation
#    operator: 13
#    operands: 11
# 7. 2 * c
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. 2 + 3 + 4
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (b, b)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 11. (2, a)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 12. (2, c)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (2, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
# 22. 4
#     core type: Literal
#     sub-expressions:
