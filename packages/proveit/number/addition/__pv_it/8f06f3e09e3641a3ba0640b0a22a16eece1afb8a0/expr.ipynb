# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(b)
subExpr2 = Mult(two, b)
subExpr3 = Mult(three, b)
expr = Equals(Add(subExpr2, subExpr3, b, subExpr1), Add(subExpr2, subExpr3, Mult(one, b), subExpr1))
# Out:
# expr: ((2 * b) + (3 * b) + b - b) = ((2 * b) + (3 * b) + (1 * b) - b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + b - b\right) = \left(\left(2 \cdot b\right) + \left(3 \cdot b\right) + \left(1 \cdot b\right) - b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + (3 * b) + b - b) = ((2 * b) + (3 * b) + (1 * b) - b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * b) + (3 * b) + b - b, (2 * b) + (3 * b) + (1 * b) - b)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * b) + (3 * b) + (1 * b) - b
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 * b, 3 * b, b, -b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 20, 11
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2 * b, 3 * b, 1 * b, -b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. 2 * b
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. 3 * b
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. 1 * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. -b
#     core type: Operation
#     operator: 16
#     operand: 20
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 13. (3, b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (1, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
