# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import c
from proveit.logic import Equals
from proveit.number import Add, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(c, c, c)
expr = Equals(Add(subExpr1, one, two, three, one), Add(subExpr1, Add(one, two, three, one)))
# Out:
# expr: ((c + c + c) + 1 + 2 + 3 + 1) = ((c + c + c) + (1 + 2 + 3 + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(c + c + c\right) + 1 + 2 + 3 + 1\right) = \left(\left(c + c + c\right) + \left(1 + 2 + 3 + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((c + c + c) + 1 + 2 + 3 + 1) = ((c + c + c) + (1 + 2 + 3 + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((c + c + c) + 1 + 2 + 3 + 1, (c + c + c) + (1 + 2 + 3 + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (c + c + c) + 1 + 2 + 3 + 1
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (c + c + c) + (1 + 2 + 3 + 1)
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (c + c + c, 1, 2, 3, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 15, 13, 14, 15
# 6. (c + c + c, 1 + 2 + 3 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. c + c + c
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. 1 + 2 + 3 + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (c, c, c)
#    core type: ExprTuple
#    sub-expressions: 12, 12, 12
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (1, 2, 3, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 13, 14, 15
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
