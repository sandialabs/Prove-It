# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import a, i
from proveit.logic import InSet
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Naturals), one, i)
# Out:
# expr: (a_{1} in Naturals), ..(a_{_a} in Naturals).., (a_{i} in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{N}\right), \ldots, \left(a_{i} \in \mathbb{N}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in Naturals), ..(a_{_a} in Naturals).., (a_{i} in Naturals)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> (a_{_a} in Naturals)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. i
#    core type: Variable
#    sub-expressions:
# 4. a_{_a} in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (a_{_a}, Naturals)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. a_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
