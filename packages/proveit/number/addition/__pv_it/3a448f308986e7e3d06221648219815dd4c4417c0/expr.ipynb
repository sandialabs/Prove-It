# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, four, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, three, four, a, a, c, c, b, b), Add(a, two, three, four, a, c, c, b, b))
# Out:
# expr: (2 + 3 + 4 + a + a + c + c + b + b) = (a + 2 + 3 + 4 + a + c + c + b + b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 + 3 + 4 + a + a + c + c + b + b\right) = \left(a + 2 + 3 + 4 + a + c + c + b + b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + c + b + b) = (a + 2 + 3 + 4 + a + c + c + b + b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + 3 + 4 + a + a + c + c + b + b, a + 2 + 3 + 4 + a + c + c + b + b)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + 3 + 4 + a + a + c + c + b + b
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + 2 + 3 + 4 + a + c + c + b + b
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2, 3, 4, a, a, c, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 11, 12, 12, 13, 13
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a, 2, 3, 4, a, c, c, b, b)
#    core type: ExprTuple
#    sub-expressions: 11, 8, 9, 10, 11, 12, 12, 13, 13
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 4
#     core type: Literal
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
