# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, four, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, a, c, c, b, b, two, three, four), Add(Add(a, a), c, c, b, b, two, three, four))
# Out:
# expr: (a + a + c + c + b + b + 2 + 3 + 4, (a + a) + c + c + b + b + 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + a + c + c + b + b + 2 + 3 + 4, \left(a + a\right) + c + c + b + b + 2 + 3 + 4\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + a + c + c + b + b + 2 + 3 + 4, (a + a) + c + c + b + b + 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + a + c + c + b + b + 2 + 3 + 4
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (a + a) + c + c + b + b + 2 + 3 + 4
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (a, a, c, c, b, b, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 13, 13, 6, 6, 7, 7, 8, 9, 10
# 4. (a + a, c, c, b, b, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 6, 7, 7, 8, 9, 10
# 5. a + a
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. c
#    core type: Variable
#    sub-expressions:
# 7. b
#    core type: Variable
#    sub-expressions:
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 4
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (a, a)
#     core type: ExprTuple
#     sub-expressions: 13, 13
# 13. a
#     core type: Variable
#     sub-expressions:
