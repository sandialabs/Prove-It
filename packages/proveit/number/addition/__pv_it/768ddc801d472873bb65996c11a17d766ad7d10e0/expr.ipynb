# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, one, six, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, a)
subExpr2 = Mult(three, c)
subExpr3 = Mult(two, b)
expr = ExprTuple(Add(subExpr1, subExpr2, subExpr3, Add(one, two, three)), Add(subExpr1, subExpr2, subExpr3, six))
# Out:
# expr: ((2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3), (2 * a) + (3 * c) + (2 * b) + 6)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot a\right) + \left(3 \cdot c\right) + \left(2 \cdot b\right) + \left(1 + 2 + 3\right), \left(2 \cdot a\right) + \left(3 \cdot c\right) + \left(2 \cdot b\right) + 6\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3), (2 * a) + (3 * c) + (2 * b) + 6)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (2 * a) + (3 * c) + (2 * b) + 6
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 * a, 3 * c, 2 * b, 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 5
# 4. (2 * a, 3 * c, 2 * b, 6)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 1 + 2 + 3
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. 2 * a
#    core type: Operation
#    operator: 14
#    operands: 12
# 7. 3 * c
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. 2 * b
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. 6
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 16, 20, 18
# 12. (2, a)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 13. (3, c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
