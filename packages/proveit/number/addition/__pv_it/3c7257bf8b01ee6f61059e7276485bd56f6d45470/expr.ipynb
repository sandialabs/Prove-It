# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.number import Add, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(zero, two, three, zero), Add(Add(zero, two), three, zero))
# Out:
# expr: (0 + 2 + 3 + 0, (0 + 2) + 3 + 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(0 + 2 + 3 + 0, \left(0 + 2\right) + 3 + 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (0 + 2 + 3 + 0, (0 + 2) + 3 + 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 0 + 2 + 3 + 0
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (0 + 2) + 3 + 0
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. (0, 2, 3, 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 6, 9
# 4. (0 + 2, 3, 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 9
# 5. 0 + 2
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. 3
#    core type: Literal
#    sub-expressions:
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (0, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
