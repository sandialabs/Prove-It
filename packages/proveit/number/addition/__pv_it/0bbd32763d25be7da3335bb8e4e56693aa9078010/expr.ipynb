# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, c, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.number import four, one, six, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([two, three, four, a, a, c]), Len([ExprRange(k, k, one, six)]))
# Out:
# expr: |(2, 3, 4, a, a, c)| = |(1, ..k.., 6)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(2, 3, 4, a, a, c\right)| = |\left(1, \ldots, 6\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(2, 3, 4, a, a, c)| = |(1, ..k.., 6)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(2, 3, 4, a, a, c)|, |(1, ..k.., 6)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(2, 3, 4, a, a, c)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 6)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((2, 3, 4, a, a, c))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 6))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (2, 3, 4, a, a, c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13, 13, 14
# 9. (1, ..k.., 6)
#    core type: ExprTuple
#    sub-expressions: 15
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. 1, ..k.., 6
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 16. k -> k
#     core type: Lambda
#     parameter: 19
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 6
#     core type: Literal
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
