# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#addIntClosureBin">addIntClosureBin</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.addition._theorems_ import addIntClosureBin

# %%
# check that the built expression is the same as the stored expression
# %check_expr addIntClosureBin
# Out:
# Passed sanity check: built 'addIntClosureBin' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(addIntClosureBin.latex())
# Out:
# \vdash \forall_{a \in \mathbb{Z}, b \in \mathbb{Z}}~\left(\left(a + b\right) \in \mathbb{Z}\right)

# %%
# display the expression information
addIntClosureBin.exprInfo()
# Out:
# 0. forall_{a in Integers, b in Integers} ((a + b) in Integers)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a + b) in Integers if a in Integers ,  b in Integers.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(a + b) in Integers if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a + b) in Integers
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a in Integers) and (b in Integers)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a + b, Integers)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a + b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Integers
#     core type: Operation
#     operator: 15
#     operands: 14
# ...
