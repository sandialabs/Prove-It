# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import b, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.number import five, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([b, b, two, three, four]), Len([ExprRange(k, k, one, five)]))
# Out:
# expr: |(b, b, 2, 3, 4)| = |(1, ..k.., 5)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(b, b, 2, 3, 4\right)| = |\left(1, \ldots, 5\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(b, b, 2, 3, 4)| = |(1, ..k.., 5)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(b, b, 2, 3, 4)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(b, b, 2, 3, 4)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((b, b, 2, 3, 4))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (b, b, 2, 3, 4)
#    core type: ExprTuple
#    sub-expressions: 10, 10, 11, 12, 13
# 9. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
# 14. 1, ..k.., 5
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 15. k -> k
#     core type: Lambda
#     parameter: 18
#     body: 18
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 5
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
