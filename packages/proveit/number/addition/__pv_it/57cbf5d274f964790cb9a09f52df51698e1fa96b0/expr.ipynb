# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Add(c, c), Add(Mult(three, b), Mult(two, b)), two)
# Out:
# expr: (c + c) + ((3 * b) + (2 * b)) + 2

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c + c\right) + \left(\left(3 \cdot b\right) + \left(2 \cdot b\right)\right) + 2

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (c + c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 5
#    operands: 1
# 1. (c + c, (3 * b) + (2 * b), 2)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 14
# 2. c + c
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (c, c)
#    core type: ExprTuple
#    sub-expressions: 7, 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (3 * b, 2 * b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (3, b)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
