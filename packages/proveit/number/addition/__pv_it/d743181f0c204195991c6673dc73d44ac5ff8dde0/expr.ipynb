# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(a, a, c, one, two, b, b, c, c, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, a + a + c + 1 + 2 + b + b + c + c + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a + 1 + 2 + c + b + a + 0 + b + c + c + 3, a + a + c + 1 + 2 + b + b + c + c + 3\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3, a + a + c + 1 + 2 + b + b + c + c + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a + a + c + 1 + 2 + b + b + c + c + 3
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, 1, 2, c, b, a, 0, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 11, 10, 7, 6, 10, 11, 11, 12
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (a, a, c, 1, 2, b, b, c, c, 3)
#    core type: ExprTuple
#    sub-expressions: 7, 7, 11, 8, 9, 10, 10, 11, 11, 12
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
