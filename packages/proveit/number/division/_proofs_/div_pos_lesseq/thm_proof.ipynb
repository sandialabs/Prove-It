# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../_context_.ipynb">division</a>.<a class="ProveItLink" href="../_theorems_.ipynb#div_pos_lesseq">div_pos_lesseq</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving div_pos_lesseq presuming []
