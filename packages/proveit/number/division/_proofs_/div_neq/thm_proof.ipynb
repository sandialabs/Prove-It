# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../_context_.ipynb">division</a>.<a class="ProveItLink" href="../_theorems_.ipynb#div_neq">div_neq</a> theorem
# ========

# %%
import proveit
context = proveit.Context() # the theorem's context

# %%
# %proving div_neq
