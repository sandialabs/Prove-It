# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#prodOfFracs">prodOfFracs</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.division._theorems_ import prodOfFracs

# %%
# check that the built expression is the same as the stored expression
# %check_expr prodOfFracs
# Out:
# Passed sanity check: built 'prodOfFracs' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(prodOfFracs.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}, y \in \mathbb{C}, z \in \mathbb{C}, w \in \mathbb{C}}~\left(\left(\frac{x}{z} \cdot \frac{y}{w}\right) = \frac{x \cdot y}{z \cdot w}\right)

# %%
# display the expression information
prodOfFracs.exprInfo()
# Out:
# 0. forall_{x in Complexes, y in Complexes, z in Complexes, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y, z, w) -> {((x / z) * (y / w)) = ((x * y) / (z * w)) if x in Complexes ,  y in Complexes ,  z in Complexes ,  w in Complexes.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, y, z, w)
#    core type: ExprTuple
#    sub-expressions: 35, 36, 37, 38
# 4. {((x / z) * (y / w)) = ((x * y) / (z * w)) if x in Complexes ,  y in Complexes ,  z in Complexes ,  w in Complexes.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ((x / z) * (y / w)) = ((x * y) / (z * w))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in Complexes) and (y in Complexes) and (z in Complexes) and (w in Complexes)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# ...
