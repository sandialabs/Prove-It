# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import x, y, z
from proveit.logic import InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Complexes), InSet(y, Complexes), InSet(z, Complexes))
# Out:
# expr: (x in Complexes, y in Complexes, z in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{C}, y \in \mathbb{C}, z \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in Complexes, y in Complexes, z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. x in Complexes
#    core type: Operation
#    operator: 6
#    operands: 4
# 2. y in Complexes
#    core type: Operation
#    operator: 6
#    operands: 5
# 3. z in Complexes
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 8, 11
# 5. (y, Complexes)
#    core type: ExprTuple
#    sub-expressions: 9, 11
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (z, Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. y
#    core type: Variable
#    sub-expressions:
# 10. z
#     core type: Variable
#     sub-expressions:
# 11. Complexes
#     core type: Literal
#     sub-expressions:
