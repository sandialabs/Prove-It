# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#reverseFractionOfSubtractions">reverseFractionOfSubtractions</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.division._theorems_ import reverseFractionOfSubtractions

# %%
# check that the built expression is the same as the stored expression
# %check_expr reverseFractionOfSubtractions
# Out:
# Passed sanity check: built 'reverseFractionOfSubtractions' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reverseFractionOfSubtractions.latex())
# Out:
# \vdash \forall_{w \in \mathbb{C}, x \in \mathbb{C}, y \in \mathbb{C}, z \in \mathbb{C}}~\left(\frac{w - x}{y - z} = \frac{x - w}{z - y}\right)

# %%
# display the expression information
reverseFractionOfSubtractions.exprInfo()
# Out:
# 0. forall_{w in Complexes, x in Complexes, y in Complexes, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (w, x, y, z) -> {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complexes ,  x in Complexes ,  y in Complexes ,  z in Complexes.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (w, x, y, z)
#    core type: ExprTuple
#    sub-expressions: 41, 39, 43, 40
# 4. {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complexes ,  x in Complexes ,  y in Complexes ,  z in Complexes.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ((w - x) / (y - z)) = ((x - w) / (z - y))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (w in Complexes) and (x in Complexes) and (y in Complexes) and (z in Complexes)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# ...
