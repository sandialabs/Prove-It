# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fracZeroNumer">fracZeroNumer</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.division._theorems_ import fracZeroNumer

# %%
# check that the built expression is the same as the stored expression
# %check_expr fracZeroNumer
# Out:
# Passed sanity check: built 'fracZeroNumer' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fracZeroNumer.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}}~\left(\frac{0}{x} = 0\right)

# %%
# display the expression information
fracZeroNumer.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((0 / x) = 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {(0 / x) = 0 if x in Complexes.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {(0 / x) = 0 if x in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (0 / x) = 0
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (0 / x, 0)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 10. 0 / x
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (0, x)
# ...
