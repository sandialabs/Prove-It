# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.number import frac, zero
from proveit.number._common_ import ComplexesSansZero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(NotEquals(frac(a, b), zero), And(InSet(a, ComplexesSansZero), InSet(b, ComplexesSansZero))))
# Out:
# expr: (a, b) -> {(a / b) != 0 if a in (Complexes - {0}) ,  b in (Complexes - {0}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\frac{a}{b} \neq 0 \textrm{ if } a \in \left(\mathbb{C} - \left\{0\right\}\right) ,  b \in \left(\mathbb{C} - \left\{0\right\}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a / b) != 0 if a in (Complexes - {0}) ,  b in (Complexes - {0}).
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {(a / b) != 0 if a in (Complexes - {0}) ,  b in (Complexes - {0}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a / b) != 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in (Complexes - {0})) and (b in (Complexes - {0}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. !=
#    core type: Literal
#    sub-expressions:
# 5. (a / b, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 24
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in (Complexes - {0}), b in (Complexes - {0}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a / b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a in (Complexes - {0})
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in (Complexes - {0})
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (a, Complexes - {0})
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Complexes - {0})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. Complexes - {0}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (Complexes, {0})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. Complexes
#     core type: Literal
#     sub-expressions:
# 22. {0}
#     core type: Operation
#     operator: 23
#     operand: 24
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
