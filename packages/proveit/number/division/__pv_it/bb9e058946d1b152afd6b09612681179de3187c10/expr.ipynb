# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x, y
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Complexes, Mult, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(frac(x, Mult(x, y)), frac(one, y)), And(InSet(x, Complexes), InSet(y, Complexes), NotEquals(x, zero)))
# Out:
# expr: {(x / (x * y)) = (1 / y) if x in Complexes ,  y in Complexes ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\frac{x}{x \cdot y} = \frac{1}{y} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  x \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(x / (x * y)) = (1 / y) if x in Complexes ,  y in Complexes ,  x != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x / (x * y)) = (1 / y)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complexes) and (y in Complexes) and (x != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x / (x * y), 1 / y)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complexes, y in Complexes, x != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. x / (x * y)
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. 1 / y
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. x in Complexes
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. y in Complexes
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. x != 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. (x, x * y)
#     core type: ExprTuple
#     sub-expressions: 26, 20
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (1, y)
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 15. (x, Complexes)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (y, Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 26, 23
# 20. x * y
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. Complexes
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (x, y)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. y
#     core type: Variable
#     sub-expressions:
