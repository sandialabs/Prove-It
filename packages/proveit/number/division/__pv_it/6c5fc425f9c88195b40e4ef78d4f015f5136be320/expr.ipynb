# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Exp, Integers, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a, b], Equals(frac(Exp(a, n), Exp(b, n)), Exp(frac(a, b), n)), conditions = [NotEquals(a, zero), NotEquals(b, zero)]), InSet(n, Integers)))
# Out:
# expr: n -> {forall_{a, b | a != 0, b != 0} ((a^{n} / b^{n}) = (a / b)^{n}) if n in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a, b~|~a \neq 0, b \neq 0}~\left(\frac{a^{n}}{b^{n}} = \left(\frac{a}{b}\right)^{n}\right) \textrm{ if } n \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{a, b | a != 0, b != 0} ((a^{n} / b^{n}) = (a / b)^{n}) if n in Integers.
#    core type: Lambda
#    parameter: 34
#    body: 1
# 1. {forall_{a, b | a != 0, b != 0} ((a^{n} / b^{n}) = (a / b)^{n}) if n in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a, b | a != 0, b != 0} ((a^{n} / b^{n}) = (a / b)^{n})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Integers
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a, b) -> {(a^{n} / b^{n}) = (a / b)^{n} if a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 33\n   body: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Integers)
#    core type: ExprTuple
#    sub-expressions: 34, 9
# 8. {(a^{n} / b^{n}) = (a / b)^{n} if a != 0 ,  b != 0.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Integers
#    core type: Literal
#    sub-expressions:
# ...
