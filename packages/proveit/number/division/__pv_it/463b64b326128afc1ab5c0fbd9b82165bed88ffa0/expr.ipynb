# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import And, Equals, NotEquals
from proveit.number import Exp, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(frac(Exp(a, n), Exp(b, n)), Exp(frac(a, b), n)), And(NotEquals(a, zero), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {(a^{n} / b^{n}) = (a / b)^{n} if a != 0 ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\frac{a^{n}}{b^{n}} = \left(\frac{a}{b}\right)^{n} \textrm{ if } a \neq 0 ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a^{n} / b^{n}) = (a / b)^{n} if a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 25\n   body: 1
# 1. {(a^{n} / b^{n}) = (a / b)^{n} if a != 0 ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a^{n} / b^{n}) = (a / b)^{n}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a != 0) and (b != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a^{n} / b^{n}, (a / b)^{n})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a != 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. a^{n} / b^{n}
#    core type: Operation
#    operator: 24
#    operands: 12
# 9. (a / b)^{n}
#    core type: Operation
#    operator: 22
#    operands: 13
# 10. a != 0
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. b != 0
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (a^{n}, b^{n})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. (a / b, n)
#     core type: ExprTuple
#     sub-expressions: 19, 26
# 14. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 15. !=
#     core type: Literal
#     sub-expressions:
# 16. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 20
# 17. a^{n}
#     core type: Operation
#     operator: 22
#     operands: 21
# 18. b^{n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. a / b
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. 0
#     core type: Literal
#     sub-expressions:
# 21. (a, n)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (b, n)
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 24. /
#     core type: Literal
#     sub-expressions:
# 25. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. n
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
