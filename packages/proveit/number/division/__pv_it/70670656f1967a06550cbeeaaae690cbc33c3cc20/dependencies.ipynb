# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#fracCancelLeft">fracCancelLeft</a>
# ***see <a class="ProveItLink" href="../../_proofs_/fracCancelLeft.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.division._theorems_ import fracCancelLeft

# %%
# %dependencies fracCancelLeft
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems depend upon fracCancelLeft</h3>
