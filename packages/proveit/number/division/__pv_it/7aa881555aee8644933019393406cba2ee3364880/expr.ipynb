# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x, y, z
from proveit.logic import And, Equals, InSet
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(frac(x, y), frac(one, z)), frac(x, Mult(y, z))), And(InSet(x, Complexes), InSet(y, Complexes), InSet(z, Complexes)))
# Out:
# expr: {((x / y) * (1 / z)) = (x / (y * z)) if x in Complexes ,  y in Complexes ,  z in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\frac{x}{y} \cdot \frac{1}{z}\right) = \frac{x}{y \cdot z} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  z \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {((x / y) * (1 / z)) = (x / (y * z)) if x in Complexes ,  y in Complexes ,  z in Complexes.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((x / y) * (1 / z)) = (x / (y * z))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complexes) and (y in Complexes) and (z in Complexes)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x / y) * (1 / z), x / (y * z))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complexes, y in Complexes, z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. (x / y) * (1 / z)
#    core type: Operation
#    operator: 25
#    operands: 12
# 8. x / (y * z)
#    core type: Operation
#    operator: 23
#    operands: 13
# 9. x in Complexes
#    core type: Operation
#    operator: 16
#    operands: 14
# 10. y in Complexes
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. z in Complexes
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (x / y, 1 / z)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. (x, y * z)
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 14. (x, Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 15. (y, Complexes)
#     core type: ExprTuple
#     sub-expressions: 29, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (z, Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 21
# 18. x / y
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. 1 / z
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. y * z
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Complexes
#     core type: Literal
#     sub-expressions:
# 22. (x, y)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (1, z)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (y, z)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. y
#     core type: Variable
#     sub-expressions:
# 30. z
#     core type: Variable
#     sub-expressions:
