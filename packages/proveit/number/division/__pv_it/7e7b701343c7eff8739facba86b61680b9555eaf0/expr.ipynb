# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x, y, z
from proveit.logic import And, Equals, InSet
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y, z], Conditional(Equals(Mult(frac(one, y), frac(x, z)), frac(x, Mult(y, z))), And(InSet(x, Complexes), InSet(y, Complexes), InSet(z, Complexes))))
# Out:
# expr: (x, y, z) -> {((1 / y) * (x / z)) = (x / (y * z)) if x in Complexes ,  y in Complexes ,  z in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y, z\right) \mapsto \left\{\left(\frac{1}{y} \cdot \frac{x}{z}\right) = \frac{x}{y \cdot z} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  z \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, y, z) -> {((1 / y) * (x / z)) = (x / (y * z)) if x in Complexes ,  y in Complexes ,  z in Complexes.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 30, 31, 32
# 2. {((1 / y) * (x / z)) = (x / (y * z)) if x in Complexes ,  y in Complexes ,  z in Complexes.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((1 / y) * (x / z)) = (x / (y * z))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes) and (y in Complexes) and (z in Complexes)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((1 / y) * (x / z), x / (y * z))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Complexes, y in Complexes, z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (1 / y) * (x / z)
#    core type: Operation
#    operator: 27
#    operands: 14
# 10. x / (y * z)
#     core type: Operation
#     operator: 25
#     operands: 15
# 11. x in Complexes
#     core type: Operation
#     operator: 18
#     operands: 16
# 12. y in Complexes
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. z in Complexes
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (1 / y, x / z)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 15. (x, y * z)
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 16. (x, Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 17. (y, Complexes)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (z, Complexes)
#     core type: ExprTuple
#     sub-expressions: 32, 23
# 20. 1 / y
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. x / z
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. y * z
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. Complexes
#     core type: Literal
#     sub-expressions:
# 24. (1, y)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 25. /
#     core type: Literal
#     sub-expressions:
# 26. (x, z)
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (y, z)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. y
#     core type: Variable
#     sub-expressions:
# 32. z
#     core type: Variable
#     sub-expressions:
