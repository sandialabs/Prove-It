# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">sets</a>.<a class="ProveItLink" href="../_context_.ipynb">rational</a>.<a class="ProveItLink" href="../_theorems_.ipynb#zeroInRationals">zeroInRationals</a> theorem
# ========

# %%
import proveit
from proveit._common_ import k, x, S
from proveit.number import one, zero, Rationals
from proveit.number.sets.rational._axioms_ import rationalsDef
from proveit.logic.set_theory.comprehension._axioms_ import comprehensionDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving zeroInRationals presuming [proveit.logic, proveit.number.numeral.deci.nat1]

# %%
rationalsDef

# %%
rationalsDefRHS = rationalsDef.rhs

# %%
rationalsDefRHS

# %%
comprehensionDef

# %%
comprehensionDefSpec = comprehensionDef.specialize({k:one, S:Rationals})

# %%
# %qed
