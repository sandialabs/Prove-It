# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#xInRationalsNonNegInBool">xInRationalsNonNegInBool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.rational</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.rational._theorems_ import xInRationalsNonNegInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr xInRationalsNonNegInBool
# Out:
# Passed sanity check: built 'xInRationalsNonNegInBool' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(xInRationalsNonNegInBool.latex())
# Out:
# \vdash \forall_{x}~\left(\left(x \in \mathbb{Q}^{\ge 0}\right) \in \mathbb{B}\right)

# %%
# display the expression information
xInRationalsNonNegInBool.exprInfo()
# Out:
# 0. forall_{x} ((x in RationalsNonNeg) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x in RationalsNonNeg) in BOOLEANS)
#    core type: Lambda
#    parameter: 9
#    body: 3
# 3. (x in RationalsNonNeg) in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 4
# 4. (x in RationalsNonNeg, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x in RationalsNonNeg
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, RationalsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. RationalsNonNeg
#     core type: Literal
#     sub-expressions:
