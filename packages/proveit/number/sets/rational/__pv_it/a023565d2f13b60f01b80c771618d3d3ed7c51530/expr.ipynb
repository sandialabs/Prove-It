# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.rational</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, x
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Integers, frac, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(x, frac(a, b)), And(InSet(a, Integers), InSet(b, Integers), NotEquals(b, zero)))
# Out:
# expr: {x = (a / b) if a in Integers ,  b in Integers ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x = \frac{a}{b} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {x = (a / b) if a in Integers ,  b in Integers ,  b != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x = (a / b)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integers) and (b in Integers) and (b != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x, a / b)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integers, b in Integers, b != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. a / b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. a in Integers
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. b in Integers
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. b != 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 14. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. Integers
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 0
#     core type: Literal
#     sub-expressions:
