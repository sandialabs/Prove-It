# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.rational</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, x
from proveit.logic import Equals, Exists, NotEquals
from proveit.number import Integers, frac, zero

# %%
# build up the expression from sub-expressions
expr = Exists([a, b], Equals(x, frac(a, b)), domains = [Integers, Integers], condition = NotEquals(b, zero))
# Out:
# expr: exists_{a in Integers, b in Integers | b != 0} (x = (a / b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \exists_{a \in \mathbb{Z}, b \in \mathbb{Z}~|~b \neq 0}~\left(x = \frac{a}{b}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. exists_{a in Integers, b in Integers | b != 0} (x = (a / b))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {x = (a / b) if a in Integers ,  b in Integers ,  b != 0.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {x = (a / b) if a in Integers ,  b in Integers ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x = (a / b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integers) and (b in Integers) and (b != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x, a / b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integers, b in Integers, b != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. a / b
# ...
