# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.rational</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, x
from proveit.logic import Equals, Exists, Iff, InSet
from proveit.number import NaturalsPos, RationalsPos, frac

# %%
# build up the expression from sub-expressions
expr = Iff(InSet(x, RationalsPos), Exists([a, b], Equals(x, frac(a, b)), domains = [NaturalsPos, NaturalsPos]))
# Out:
# expr: (x in RationalsPos) <=> [exists_{a in NaturalsPos, b in NaturalsPos} (x = (a / b))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{Q}^+\right) \Leftrightarrow \left[\exists_{a \in \mathbb{N}^+, b \in \mathbb{N}^+}~\left(x = \frac{a}{b}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in RationalsPos) <=> [exists_{a in NaturalsPos, b in NaturalsPos} (x = (a / b))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. (x in RationalsPos, exists_{a in NaturalsPos, b in NaturalsPos} (x = (a / b)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in RationalsPos
#    core type: Operation
#    operator: 23
#    operands: 5
# 4. exists_{a in NaturalsPos, b in NaturalsPos} (x = (a / b))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (x, RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 16, 8
# 6. exists
#    core type: Literal
#    sub-expressions:
# 7. (a, b) -> {x = (a / b) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 21\n   body: 9
# 8. RationalsPos
#    core type: Literal
#    sub-expressions:
# 9. {x = (a / b) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# ...
