# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rationalsNonNegInRationals">rationalsNonNegInRationals</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Subset.html">Subset</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.rational</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.rational._theorems_ import rationalsNonNegInRationals

# %%
# check that the built expression is the same as the stored expression
# %check_expr rationalsNonNegInRationals
# Out:
# Passed sanity check: built 'rationalsNonNegInRationals' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rationalsNonNegInRationals.latex())
# Out:
# \vdash \mathbb{Q}^{\ge 0} \subset \mathbb{Q}

# %%
# display the expression information
rationalsNonNegInRationals.exprInfo()
# Out:
# 0. RationalsNonNeg subset Rationals
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subset
#    core type: Literal
#    sub-expressions:
# 2. (RationalsNonNeg, Rationals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. RationalsNonNeg
#    core type: Literal
#    sub-expressions:
# 4. Rationals
#    core type: Literal
#    sub-expressions:
