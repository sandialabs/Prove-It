# %% [markdown]
# Axioms for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.sets.natural</a>
# ========

# %%
import proveit
# Automation is not needed when building axiom expressions:
proveit.defaults.automation = False # This will speed things up.
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
from proveit._common_ import m, n, x, S
from proveit.logic import Implies, And, Forall, Equals, NotEquals, InSet, SubsetEq
from proveit.number import zero, one, Add, Naturals

# %%
# %begin axioms

# %% [markdown]
# ### Peano's axioms define the natural numbers

# %%
zero_in_nats = InSet(zero, Naturals)

# %%
successor_in_nats = Forall(n, InSet(Add(n, one), Naturals), domain=Naturals)

# %% [markdown]
# The following two axioms will ensure that successors are never repeated.

# %%
successor_is_injective = Forall((m, n), Equals(n, m), domain=Naturals, 
                                condition=Equals(Add(m, one), Add(n, one)))

# %%
zero_not_successor = Forall(n, NotEquals(Add(n, one), zero), domain=Naturals)

# %% [markdown]
# The induction axioms defines the naturals as only zero and its successors and nothing else.

# %%
induction = Forall(S, Implies(And(InSet(zero, S), Forall(x, InSet(Add(x, one), S), domain=Naturals)),
                             Equals(S, Naturals)),
                  conditions=[SubsetEq(S, Naturals)])

# %%
# %end axioms
