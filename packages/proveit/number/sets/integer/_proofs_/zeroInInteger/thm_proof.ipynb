# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">integer</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#zeroInInteger">zeroInInteger</a> theorem
# ========

# %%
import proveit
from proveit._common_ import x, A, B
from proveit.number import zero, Integer, Natural
from proveit.number.sets.natural._axioms_ import zero_in_nats
from proveit.number.sets.integer._theorems_ import natInInt
theory = proveit.Theory() # the theorem's theory

# %%
# %proving zeroInInteger

# %%
zero_in_nats

# %%
natInInt

# %%
# %qed
