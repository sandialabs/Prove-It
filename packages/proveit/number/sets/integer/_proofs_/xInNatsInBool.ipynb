# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">sets</a>.<a class="ProveItLink" href="../_context_.ipynb">integer</a>.<a class="ProveItLink" href="../_theorems_.ipynb#xInNatsInBool">xInNatsInBool</a> theorem
# ========

# %%
import proveit
from proveit._common_ import k, l, n, x
from proveit.number import Naturals, NaturalsPos
from proveit.number import zero, one
from proveit.logic import InSet
from proveit.number.sets.integer._axioms_ import naturalsDef
from proveit.number.numeral.deci._theorems_ import posnat1
from proveit.logic.boolean.quantification.universal._axioms_ import forall_in_bool
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving xInNatsInBool presuming [proveit.logic, proveit.number.numeral.deci, proveit.core_expr_types.tuples.singular_range_reduction]
# Out:
# Beginning proof of xInNatsInBool
# Recorded 'presuming' information
# Presuming theorems in proveit.logic, proveit.number.numeral.deci (except any that presume this theorem).
# Presuming proveit.core_expr_types.tuples.singular_range_reduction theorem (applied transitively).
# Presuming previous theorems (applied transitively).
# xInNatsInBool: forall_{x} ((x in Naturals) in BOOLEANS)

# %%
naturalsDef
# Out:
# |- forall_{n} ((n in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))])

# %%
naturalsDefInst = naturalsDef.instantiate({n:x, x:k})
# Out:
# naturalsDefInst: |- (x in Naturals) = [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))]

# %%
naturalsDefInst_rhs = naturalsDefInst.rhs
# Out:
# naturalsDefInst_rhs: forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))

# %%
naturalsDefInst_rhs__inbool = naturalsDefInst_rhs.deduceInBool()
# Out:
# naturalsDefInst_rhs__inbool: |- [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))] in BOOLEANS

# %%
naturalsDefInst.subLeftSideInto(naturalsDefInst_rhs__inbool)
# Out:
# |- (x in Naturals) in BOOLEANS

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x} ((x in Naturals) in BOOLEANS)
# 1	instantiation	2, 3, 4	|- (x in Naturals) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : x in Naturals, y : forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.subLeftSideInto
# 3	instantiation	5, 6, 7	|- [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))] in BOOLEANS
# 	n : 1, P(S) : ((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S), (x_{1}, ..x_{k}.., x_{1}) : (S)
# 4	instantiation	8	|- (x in Naturals) = [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))]
# 	n : x, x : k
# 5	axiom		|- forall_{n in NaturalsPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)]
# 	proveit.logic.boolean.quantification.universal.forall_in_bool
# 6	instantiation	9	|- |(S)| = |(1, ..k.., 1)|
# 	a : S
# 7	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 8	axiom		|- forall_{n} ((n in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))])
# 	proveit.number.sets.integer.naturalsDef
# 9	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
