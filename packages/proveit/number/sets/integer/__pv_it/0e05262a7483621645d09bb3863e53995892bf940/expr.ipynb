# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, k, x
from proveit.logic import And, Booleans, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = InSet(Forall([S], Implies(And(InSet(zero, S), Forall([k], InSet(Add(k, one), S), domain = S)), InSet(x, S))), Booleans)
# Out:
# expr: [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))] in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{k \in S}~\left(\left(k + 1\right) \in S\right)\right]\right) \Rightarrow \left(x \in S\right)\right)\right] \in \mathbb{B}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))] in BOOLEANS
#    core type: Operation
#    operator: 24
#    operands: 1
# 1. (forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)), BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Operation
#    operator: 17
#    operand: 4
# 3. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 4. S -> (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Lambda
#    parameter: 27
#    body: 5
# 5. ((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. ((0 in S) and [forall_{k in S} ((k + 1) in S)], x in S)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. (0 in S) and [forall_{k in S} ((k + 1) in S)]
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. x in S
#    core type: Operation
#    operator: 24
#    operands: 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (0 in S, forall_{k in S} ((k + 1) in S))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (x, S)
#     core type: ExprTuple
#     sub-expressions: 15, 27
# 13. 0 in S
#     core type: Operation
#     operator: 24
#     operands: 16
# 14. forall_{k in S} ((k + 1) in S)
#     core type: Operation
#     operator: 17
#     operand: 18
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. (0, S)
#     core type: ExprTuple
#     sub-expressions: 19, 27
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. k -> {(k + 1) in S if k in S.
#     core type: Lambda
#     parameter: 30
#     body: 20
# 19. 0
#     core type: Literal
#     sub-expressions:
# 20. {(k + 1) in S if k in S.
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. (k + 1) in S
#     core type: Operation
#     operator: 24
#     operands: 23
# 22. k in S
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (k + 1, S)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (k, S)
#     core type: ExprTuple
#     sub-expressions: 30, 27
# 26. k + 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. S
#     core type: Variable
#     sub-expressions:
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. 1
#     core type: Literal
#     sub-expressions:
