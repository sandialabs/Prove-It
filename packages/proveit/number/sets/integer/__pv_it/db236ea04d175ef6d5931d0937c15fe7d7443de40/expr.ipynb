# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, k, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = Forall([S], Implies(And(InSet(zero, S), Forall([k], InSet(Add(k, one), S), domain = S)), InSet(x, S)))
# Out:
# expr: forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{k \in S}~\left(\left(k + 1\right) \in S\right)\right]\right) \Rightarrow \left(x \in S\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. S -> (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. ((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. ((0 in S) and [forall_{k in S} ((k + 1) in S)], x in S)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (0 in S) and [forall_{k in S} ((k + 1) in S)]
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in S
#    core type: Operation
#    operator: 21
#    operands: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (0 in S, forall_{k in S} ((k + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (x, S)
#    core type: ExprTuple
#    sub-expressions: 12, 24
# 10. 0 in S
# ...
