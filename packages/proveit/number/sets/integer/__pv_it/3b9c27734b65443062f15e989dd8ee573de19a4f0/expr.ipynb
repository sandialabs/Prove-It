# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, n
from proveit.logic import And, Forall, InSet
from proveit.number import Greater, Integers, Interval, NaturalsPos, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([n], InSet(n, NaturalsPos), domain = Interval(a, b)), And(InSet(a, Integers), InSet(b, Integers), Greater(a, zero)))
# Out:
# expr: {forall_{n in {a...b}} (n in NaturalsPos) if a in Integers ,  b in Integers ,  a > 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{n \in \{a \dots b\}}~\left(n \in \mathbb{N}^+\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a > 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{n in {a...b}} (n in NaturalsPos) if a in Integers ,  b in Integers ,  a > 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in {a...b}} (n in NaturalsPos)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Integers) and (b in Integers) and (a > 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. n -> {n in NaturalsPos if n in {a...b}.
#    core type: Lambda
#    parameter: 23
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integers, b in Integers, a > 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. {n in NaturalsPos if n in {a...b}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 8. a in Integers
#    core type: Operation
#    operator: 18
#    operands: 13
# 9. b in Integers
#    core type: Operation
#    operator: 18
#    operands: 14
# 10. a > 0
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. n in NaturalsPos
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. n in {a...b}
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 14. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 28, 20
# 15. >
#     core type: Literal
#     sub-expressions:
# 16. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 17. (n, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. Integers
#     core type: Literal
#     sub-expressions:
# 21. 0
#     core type: Literal
#     sub-expressions:
# 22. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. {a...b}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
