# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import n
from proveit.logic import SetOfAll
from proveit.number import Naturals, NaturalsPos, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Naturals, SetOfAll([n], Neg(n), domain = NaturalsPos))
# Out:
# expr: (Naturals, {-n}_{n in NaturalsPos})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathbb{N}, \left\{-n\right\}_{n \in \mathbb{N}^+}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Naturals, {-n}_{n in NaturalsPos})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Naturals
#    core type: Literal
#    sub-expressions:
# 2. {-n}_{n in NaturalsPos}
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. SetOfAll
#    core type: Literal
#    sub-expressions:
# 4. n -> {-n if n in NaturalsPos.
#    core type: Lambda
#    parameter: 11
#    body: 5
# 5. {-n if n in NaturalsPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. -n
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. n in NaturalsPos
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. -
#    core type: Literal
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (n, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. NaturalsPos
#     core type: Literal
#     sub-expressions:
