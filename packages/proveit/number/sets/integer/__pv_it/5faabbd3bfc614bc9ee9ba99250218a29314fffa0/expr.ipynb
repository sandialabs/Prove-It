# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, n, x
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.number import Add, Naturals, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Add(n, one)
expr = Equals(InSet(subExpr1, Naturals), Forall([S], Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S)), InSet(subExpr1, S))))
# Out:
# expr: ((n + 1) in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(n + 1\right) \in \mathbb{N}\right) = \left[\forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right) \Rightarrow \left(\left(n + 1\right) \in S\right)\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((n + 1) in Naturals) = [forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((n + 1) in Naturals, forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (n + 1) in Naturals
#    core type: Operation
#    operator: 29
#    operands: 5
# 4. forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))
#    core type: Operation
#    operator: 20
#    operand: 6
# 5. (n + 1, Naturals)
#    core type: ExprTuple
#    sub-expressions: 18, 7
# 6. S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))
#    core type: Lambda
#    parameter: 32
#    body: 8
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. ((0 in S) and [forall_{x in S} ((x + 1) in S)], (n + 1) in S)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (n + 1) in S
#     core type: Operation
#     operator: 29
#     operands: 15
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (0 in S, forall_{x in S} ((x + 1) in S))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. (n + 1, S)
#     core type: ExprTuple
#     sub-expressions: 18, 32
# 16. 0 in S
#     core type: Operation
#     operator: 29
#     operands: 19
# 17. forall_{x in S} ((x + 1) in S)
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. n + 1
#     core type: Operation
#     operator: 33
#     operands: 22
# 19. (0, S)
#     core type: ExprTuple
#     sub-expressions: 23, 32
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 35
#     body: 24
# 22. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 36
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. (x + 1) in S
#     core type: Operation
#     operator: 29
#     operands: 28
# 27. x in S
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (x, S)
#     core type: ExprTuple
#     sub-expressions: 35, 32
# 31. x + 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. S
#     core type: Variable
#     sub-expressions:
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. x
#     core type: Variable
#     sub-expressions:
# 36. 1
#     core type: Literal
#     sub-expressions:
