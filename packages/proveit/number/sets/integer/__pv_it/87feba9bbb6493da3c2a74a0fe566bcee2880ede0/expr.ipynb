# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import And, Forall, InSet
from proveit.number import Greater, Integers, Interval, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([n], Greater(n, zero), domain = Interval(a, b)), And(InSet(a, Integers), InSet(b, Integers), Greater(a, zero))))
# Out:
# expr: (a, b) -> {forall_{n in {a...b}} (n > 0) if a in Integers ,  b in Integers ,  a > 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{n \in \{a \dots b\}}~\left(n > 0\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a > 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {forall_{n in {a...b}} (n > 0) if a in Integers ,  b in Integers ,  a > 0.
#    core type: Lambda
#    parameters: 26\n   body: 1
# 1. {forall_{n in {a...b}} (n > 0) if a in Integers ,  b in Integers ,  a > 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in {a...b}} (n > 0)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Integers) and (b in Integers) and (a > 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. n -> {n > 0 if n in {a...b}.
#    core type: Lambda
#    parameter: 23
#    body: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integers, b in Integers, a > 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. {n > 0 if n in {a...b}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 9. a in Integers
#    core type: Operation
#    operator: 19
#    operands: 14
# 10. b in Integers
#     core type: Operation
#     operator: 19
#     operands: 15
# 11. a > 0
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. n > 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. n in {a...b}
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 15. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 16. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 17. >
#     core type: Literal
#     sub-expressions:
# 18. (n, 0)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Integers
#     core type: Literal
#     sub-expressions:
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. {a...b}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
