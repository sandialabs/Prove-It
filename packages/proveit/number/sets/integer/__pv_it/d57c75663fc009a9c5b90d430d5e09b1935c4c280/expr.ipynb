# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, n, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = Forall([S], Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S)), InSet(Add(n, one), S)))
# Out:
# expr: forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right) \Rightarrow \left(\left(n + 1\right) \in S\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S))
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => ((n + 1) in S)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. ((0 in S) and [forall_{x in S} ((x + 1) in S)], (n + 1) in S)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n + 1) in S
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (0 in S, forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (n + 1, S)
#    core type: ExprTuple
#    sub-expressions: 12, 26
# 10. 0 in S
#     core type: Operation
#     operator: 23
#     operands: 13
# 11. forall_{x in S} ((x + 1) in S)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. n + 1
#     core type: Operation
#     operator: 27
#     operands: 16
# 13. (0, S)
#     core type: ExprTuple
#     sub-expressions: 17, 26
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 29
#     body: 18
# 16. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 30
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. (x + 1) in S
#     core type: Operation
#     operator: 23
#     operands: 22
# 21. x in S
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (x, S)
#     core type: ExprTuple
#     sub-expressions: 29, 26
# 25. x + 1
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. S
#     core type: Variable
#     sub-expressions:
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. 1
#     core type: Literal
#     sub-expressions:
