# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import S, n, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, Naturals, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(n, Naturals), Forall([S], Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S)), InSet(n, S))))
# Out:
# expr: (n in Naturals, forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{N}, \forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right) \Rightarrow \left(n \in S\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n in Naturals, forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. n in Naturals
#    core type: Operation
#    operator: 25
#    operands: 3
# 2. forall_{S} (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))
#    core type: Operation
#    operator: 18
#    operand: 4
# 3. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 16, 5
# 4. S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))
#    core type: Lambda
#    parameter: 28
#    body: 6
# 5. Naturals
#    core type: Literal
#    sub-expressions:
# 6. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. ((0 in S) and [forall_{x in S} ((x + 1) in S)], n in S)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. n in S
#     core type: Operation
#     operator: 25
#     operands: 13
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (0 in S, forall_{x in S} ((x + 1) in S))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (n, S)
#     core type: ExprTuple
#     sub-expressions: 16, 28
# 14. 0 in S
#     core type: Operation
#     operator: 25
#     operands: 17
# 15. forall_{x in S} ((x + 1) in S)
#     core type: Operation
#     operator: 18
#     operand: 19
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. (0, S)
#     core type: ExprTuple
#     sub-expressions: 20, 28
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 31
#     body: 21
# 20. 0
#     core type: Literal
#     sub-expressions:
# 21. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. (x + 1) in S
#     core type: Operation
#     operator: 25
#     operands: 24
# 23. x in S
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (x, S)
#     core type: ExprTuple
#     sub-expressions: 31, 28
# 27. x + 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. S
#     core type: Variable
#     sub-expressions:
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. 1
#     core type: Literal
#     sub-expressions:
