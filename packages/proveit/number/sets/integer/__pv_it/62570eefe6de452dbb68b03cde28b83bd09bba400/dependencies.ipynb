# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#naturalsPosLowerBound">naturalsPosLowerBound</a>
# ***see <a class="ProveItLink" href="../../_proofs_/naturalsPosLowerBound.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.sets.integer._theorems_ import naturalsPosLowerBound

# %%
# %dependencies naturalsPosLowerBound
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems that depend directly on naturalsPosLowerBound</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../physics/quantum/QPE/_proofs_/two_pow_tMinusOne_in_posnats.ipynb">proveit.physics.quantum.QPE.two_pow_tMinusOne_in_posnats</a></dt><dd><a class="ProveItLink" href="../../../../../physics/quantum/QPE/__pv_it/8e5f4e7f0d4f68ee6ee6f9d8e1bcf91f4e77cf960/expr.ipynb"><img src="../../../../../physics/quantum/QPE/__pv_it/8e5f4e7f0d4f68ee6ee6f9d8e1bcf91f4e77cf960/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
