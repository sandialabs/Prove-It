# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Add, Integers, LessEq, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Add(a, Neg(b)), Naturals), And(InSet(a, Integers), InSet(b, Integers), LessEq(b, a))))
# Out:
# expr: (a, b) -> {(a - b) in Naturals if a in Integers ,  b in Integers ,  b <= a.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a - b\right) \in \mathbb{N} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b \leq a\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a - b) in Naturals if a in Integers ,  b in Integers ,  b <= a.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 22, 24
# 2. {(a - b) in Naturals if a in Integers ,  b in Integers ,  b <= a.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a - b) in Naturals
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. (a in Integers) and (b in Integers) and (b <= a)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a - b, Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integers, b in Integers, b <= a)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. a - b
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. a in Integers
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. b in Integers
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. b <= a
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (a, -b)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 18. <=
#     core type: Literal
#     sub-expressions:
# 19. (b, a)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 20. -b
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. Integers
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
