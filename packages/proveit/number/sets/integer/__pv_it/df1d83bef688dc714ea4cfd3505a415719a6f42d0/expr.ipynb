# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, k
from proveit.logic import And, Forall, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(zero, S), Forall([k], InSet(Add(k, one), S), domain = S))
# Out:
# expr: (0 in S) and [forall_{k in S} ((k + 1) in S)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(0 \in S\right) \land \left[\forall_{k \in S}~\left(\left(k + 1\right) \in S\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (0 in S) and [forall_{k in S} ((k + 1) in S)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (0 in S, forall_{k in S} ((k + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 0 in S
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. forall_{k in S} ((k + 1) in S)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (0, S)
#    core type: ExprTuple
#    sub-expressions: 8, 16
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. k -> {(k + 1) in S if k in S.
#    core type: Lambda
#    parameter: 19
#    body: 9
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. {(k + 1) in S if k in S.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. (k + 1) in S
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. k in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (k + 1, S)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (k, S)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 15. k + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. S
#     core type: Variable
#     sub-expressions:
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
