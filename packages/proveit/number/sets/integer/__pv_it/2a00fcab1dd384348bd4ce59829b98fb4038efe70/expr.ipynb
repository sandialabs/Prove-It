# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a
from proveit.logic import And, InSet
from proveit.number import GreaterEq, Integers, Naturals, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(a, Naturals), And(InSet(a, Integers), GreaterEq(a, zero)))
# Out:
# expr: {a in Naturals if a in Integers ,  a >= 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a \in \mathbb{N} \textrm{ if } a \in \mathbb{Z} ,  a \geq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a in Naturals if a in Integers ,  a >= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a in Naturals
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (a in Integers) and (a >= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, Naturals)
#    core type: ExprTuple
#    sub-expressions: 14, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Integers, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Naturals
#    core type: Literal
#    sub-expressions:
# 7. a in Integers
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. a >= 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. >=
#     core type: Literal
#     sub-expressions:
# 12. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Integers
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
