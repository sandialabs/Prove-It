# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = InSet(zero, S)
expr = Lambda(S, Implies(And(subExpr1, Forall([x], InSet(Add(x, one), S), domain = S)), subExpr1))
# Out:
# expr: S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (0 in S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# S \mapsto \left(\left(\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right) \Rightarrow \left(0 \in S\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (0 in S))
#    core type: Lambda
#    parameter: 20
#    body: 1
# 1. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (0 in S)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((0 in S) and [forall_{x in S} ((x + 1) in S)], 0 in S)
#    core type: ExprTuple
#    sub-expressions: 4, 7
# 4. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (0 in S, forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 0 in S
#    core type: Operation
#    operator: 17
#    operands: 9
# 8. forall_{x in S} ((x + 1) in S)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (0, S)
#    core type: ExprTuple
#    sub-expressions: 12, 20
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 23
#     body: 13
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. (x + 1) in S
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. x in S
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x, S)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 19. x + 1
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. S
#     core type: Variable
#     sub-expressions:
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. 1
#     core type: Literal
#     sub-expressions:
