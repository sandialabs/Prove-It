# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, n
from proveit.logic import And, InSet
from proveit.number import Integers, Interval, LessEq, LesserSequence

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(n, Interval(a, b)), And(InSet(a, Integers), InSet(b, Integers), InSet(n, Integers), LesserSequence([LessEq._operator_, LessEq._operator_], [a, n, b])))
# Out:
# expr: {n in {a...b} if a in Integers ,  b in Integers ,  n in Integers ,  a <= n <= b.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{n \in \{a \dots b\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  n \in \mathbb{Z} ,  a \leq n \leq b\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {n in {a...b} if a in Integers ,  b in Integers ,  n in Integers ,  a <= n <= b.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. n in {a...b}
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (a in Integers) and (b in Integers) and (n in Integers) and (a <= n <= b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n, {a...b})
#    core type: ExprTuple
#    sub-expressions: 22, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Integers, b in Integers, n in Integers, a <= n <= b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 6. {a...b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. a in Integers
#    core type: Operation
#    operator: 15
#    operands: 13
# 8. b in Integers
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. n in Integers
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a <= n <= b
#     core type: Operation
#     operators: 17
# ...
