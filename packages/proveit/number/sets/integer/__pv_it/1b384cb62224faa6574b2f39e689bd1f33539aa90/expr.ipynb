# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, n, x
from proveit.logic import And, Forall, InSet, Set
from proveit.number import Add, Naturals, one, zero

# %%
# build up the expression from sub-expressions
expr = Set(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S)), InSet(n, Naturals))
# Out:
# expr: {(0 in S) and [forall_{x in S} ((x + 1) in S)], n in Naturals}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right], n \in \mathbb{N}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(0 in S) and [forall_{x in S} ((x + 1) in S)], n in Naturals}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ((0 in S) and [forall_{x in S} ((x + 1) in S)], n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (0 in S, forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. 0 in S
#    core type: Operation
#    operator: 20
#    operands: 12
# 9. forall_{x in S} ((x + 1) in S)
#    core type: Operation
#    operator: 13
#    operand: 14
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. (0, S)
#     core type: ExprTuple
#     sub-expressions: 15, 23
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. x -> {(x + 1) in S if x in S.
#     core type: Lambda
#     parameter: 26
#     body: 16
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 17
#     condition: 18
# 17. (x + 1) in S
#     core type: Operation
#     operator: 20
#     operands: 19
# 18. x in S
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (x, S)
#     core type: ExprTuple
#     sub-expressions: 26, 23
# 22. x + 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. S
#     core type: Variable
#     sub-expressions:
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
