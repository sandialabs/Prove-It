# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#allInPositiveIntervalArePositive">allInPositiveIntervalArePositive</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.integer._theorems_ import allInPositiveIntervalArePositive

# %%
# check that the built expression is the same as the stored expression
# %check_expr allInPositiveIntervalArePositive
# Out:
# Passed sanity check: built 'allInPositiveIntervalArePositive' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(allInPositiveIntervalArePositive.latex())
# Out:
# \vdash \forall_{a \in \mathbb{Z}, b \in \mathbb{Z}~|~a > 0}~\left[\forall_{n \in \{a \dots b\}}~\left(n > 0\right)\right]

# %%
# display the expression information
allInPositiveIntervalArePositive.exprInfo()
# Out:
# 0. forall_{a in Integers, b in Integers | a > 0} [forall_{n in {a...b}} (n > 0)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (a, b) -> {forall_{n in {a...b}} (n > 0) if a in Integers ,  b in Integers ,  a > 0.
#    core type: Lambda
#    parameters: 27\n   body: 2
# 2. {forall_{n in {a...b}} (n > 0) if a in Integers ,  b in Integers ,  a > 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in {a...b}} (n > 0)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (a in Integers) and (b in Integers) and (a > 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. n -> {n > 0 if n in {a...b}.
#    core type: Lambda
#    parameter: 24
#    body: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integers, b in Integers, a > 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {n > 0 if n in {a...b}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. a in Integers
#     core type: Operation
#     operator: 20
#     operands: 15
# 11. b in Integers
#     core type: Operation
#     operator: 20
#     operands: 16
# 12. a > 0
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. n > 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. n in {a...b}
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 28, 22
# 16. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 17. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 23
# 18. >
#     core type: Literal
#     sub-expressions:
# 19. (n, 0)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Integers
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. {a...b}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (a, b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
