# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import S, k, x
from proveit.logic import And, Booleans, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([S], Implies(And(InSet(zero, S), Forall([k], InSet(Add(k, one), S), domain = S)), InSet(x, S))), Booleans)
# Out:
# expr: (forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)), BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{S}~\left(\left(\left(0 \in S\right) \land \left[\forall_{k \in S}~\left(\left(k + 1\right) \in S\right)\right]\right) \Rightarrow \left(x \in S\right)\right), \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)), BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{S} (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Operation
#    operator: 16
#    operand: 3
# 2. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 3. S -> (((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S))
#    core type: Lambda
#    parameter: 26
#    body: 4
# 4. ((0 in S) and [forall_{k in S} ((k + 1) in S)]) => (x in S)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. ((0 in S) and [forall_{k in S} ((k + 1) in S)], x in S)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. (0 in S) and [forall_{k in S} ((k + 1) in S)]
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x in S
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. and
#    core type: Literal
# ...
