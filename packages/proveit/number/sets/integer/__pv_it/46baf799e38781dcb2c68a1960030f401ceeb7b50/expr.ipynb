# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Greater, Integers, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Integers), InSet(b, Integers), Greater(a, zero))
# Out:
# expr: (a in Integers) and (b in Integers) and (a > 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{Z}\right) \land \left(b \in \mathbb{Z}\right) \land \left(a > 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Integers) and (b in Integers) and (a > 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Integers, b in Integers, a > 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a in Integers
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. b in Integers
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. a > 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (a, Integers)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b, Integers)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. >
#    core type: Literal
#    sub-expressions:
# 10. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. Integers
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. 0
#     core type: Literal
#     sub-expressions:
