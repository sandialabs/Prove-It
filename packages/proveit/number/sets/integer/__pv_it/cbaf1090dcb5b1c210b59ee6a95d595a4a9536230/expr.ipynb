# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n
from proveit.logic import And, InSet
from proveit.number import Greater, Naturals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(n, And(InSet(n, Naturals), Greater(n, zero))))
# Out:
# expr: n -> {n if n in Naturals ,  n > 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{n \textrm{ if } n \in \mathbb{N} ,  n > 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {n if n in Naturals ,  n > 0.
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {n if n in Naturals ,  n > 0.
#    core type: Conditional
#    value: 12
#    condition: 2
# 2. (n in Naturals) and (n > 0)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (n in Naturals, n > 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. n in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. n > 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. >
#    core type: Literal
#    sub-expressions:
# 10. (n, 0)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. 0
#     core type: Literal
#     sub-expressions:
