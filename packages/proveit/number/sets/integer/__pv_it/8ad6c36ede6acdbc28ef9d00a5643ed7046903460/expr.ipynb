# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import S, x
from proveit.logic import And, Forall, InSet, Set
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = Set(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S)))
# Out:
# expr: {(0 in S) and [forall_{x in S} ((x + 1) in S)]}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(0 \in S\right) \land \left[\forall_{x \in S}~\left(\left(x + 1\right) \in S\right)\right]\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(0 in S) and [forall_{x in S} ((x + 1) in S)]}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (0 in S, forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. 0 in S
#    core type: Operation
#    operator: 15
#    operands: 7
# 6. forall_{x in S} ((x + 1) in S)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (0, S)
#    core type: ExprTuple
#    sub-expressions: 10, 18
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. x -> {(x + 1) in S if x in S.
#    core type: Lambda
#    parameter: 21
#    body: 11
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. {(x + 1) in S if x in S.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (x + 1) in S
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. x in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x + 1, S)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, S)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 17. x + 1
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. S
#     core type: Variable
#     sub-expressions:
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (x, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
