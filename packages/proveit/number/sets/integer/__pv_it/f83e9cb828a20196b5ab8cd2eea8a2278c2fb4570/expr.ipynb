# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#addByZero">addByZero</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.integer._axioms_ import addByZero

# %%
# check that the built expression is the same as the stored expression
# %check_expr addByZero
# Out:
# Passed sanity check: built 'addByZero' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(addByZero.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}}~\left(\left(x + 0\right) = x\right)

# %%
# display the expression information
addByZero.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((x + 0) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {(x + 0) = x if x in Complexes.
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {(x + 0) = x if x in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x + 0) = x
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x + 0, x)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. x + 0
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
