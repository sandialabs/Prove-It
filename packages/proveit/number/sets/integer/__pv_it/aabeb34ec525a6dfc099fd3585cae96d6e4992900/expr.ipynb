# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, n
from proveit.logic import And, Forall, InSet
from proveit.number import Integers, Interval, LessEq

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([n], LessEq(n, b), domain = Interval(a, b)), And(InSet(a, Integers), InSet(b, Integers)))
# Out:
# expr: {forall_{n in {a...b}} (n <= b) if a in Integers ,  b in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{n \in \{a \dots b\}}~\left(n \leq b\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{n in {a...b}} (n <= b) if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in {a...b}} (n <= b)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Integers) and (b in Integers)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. n -> {n <= b if n in {a...b}.
#    core type: Lambda
#    parameter: 19
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {n <= b if n in {a...b}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. a in Integers
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. b in Integers
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. n <= b
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. n in {a...b}
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 13. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. (n, b)
#     core type: ExprTuple
#     sub-expressions: 19, 24
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, {a...b})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Integers
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. {a...b}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
