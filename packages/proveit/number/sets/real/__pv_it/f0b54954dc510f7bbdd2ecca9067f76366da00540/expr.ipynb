# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, x
from proveit.logic import And, Forall, InSet
from proveit.number import IntervalCO, Less, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([x], Less(x, b), domain = IntervalCO(a, b)), And(InSet(a, Reals), InSet(b, Reals))))
# Out:
# expr: (a, b) -> {forall_{x in [a,b)} (x < b) if a in Reals ,  b in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{x \in \left[a,b\right)}~\left(x < b\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {forall_{x in [a,b)} (x < b) if a in Reals ,  b in Reals.
#    core type: Lambda
#    parameters: 23\n   body: 1
# 1. {forall_{x in [a,b)} (x < b) if a in Reals ,  b in Reals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x in [a,b)} (x < b)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Reals) and (b in Reals)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> {x < b if x in [a,b).
#    core type: Lambda
#    parameter: 20
#    body: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Reals, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {x < b if x in [a,b).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. a in Reals
#    core type: Operation
#    operator: 17
#    operands: 13
# 10. b in Reals
#     core type: Operation
#     operator: 17
#     operands: 14
# 11. x < b
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. x in [a,b)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 24, 19
# 14. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 19
# 15. <
#     core type: Literal
#     sub-expressions:
# 16. (x, b)
#     core type: ExprTuple
#     sub-expressions: 20, 25
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x, [a,b))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. Reals
#     core type: Literal
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. [a,b)
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. IntervalCO
#     core type: Literal
#     sub-expressions:
# 23. (a, b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
