# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, x
from proveit.logic import And, Equals, Forall, InSet
from proveit.number import IntervalOC, Less, LessEq, LesserSequence, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([x], Equals(InSet(x, IntervalOC(a, b)), And(InSet(x, Reals), LesserSequence([Less._operator_, LessEq._operator_], [a, x, b])))), And(InSet(a, Reals), InSet(b, Reals))))
# Out:
# expr: (a, b) -> {forall_{x} ((x in (a,b]) = ((x in Reals) and (a < x <= b))) if a in Reals ,  b in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{x}~\left(\left(x \in \left(a,b\right]\right) = \left(\left(x \in \mathbb{R}\right) \land \left(a < x \leq b\right)\right)\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {forall_{x} ((x in (a,b]) = ((x in Reals) and (a < x <= b))) if a in Reals ,  b in Reals.
#    core type: Lambda
#    parameters: 23\n   body: 1
# 1. {forall_{x} ((x in (a,b]) = ((x in Reals) and (a < x <= b))) if a in Reals ,  b in Reals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x} ((x in (a,b]) = ((x in Reals) and (a < x <= b)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Reals) and (b in Reals)
#    core type: Operation
#    operator: 17
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> ((x in (a,b]) = ((x in Reals) and (a < x <= b)))
#    core type: Lambda
#    parameter: 32
#    body: 7
# 6. (a in Reals, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x in (a,b]) = ((x in Reals) and (a < x <= b))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in Reals
#    core type: Operation
#    operator: 24
#    operands: 12
# 9. b in Reals
# ...
