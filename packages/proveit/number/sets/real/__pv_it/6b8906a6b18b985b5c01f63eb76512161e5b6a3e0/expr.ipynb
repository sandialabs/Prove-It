# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, x
from proveit.logic import And, InSet
from proveit.number import LessEq, LesserSequence, Reals

# %%
# build up the expression from sub-expressions
expr = And(InSet(x, Reals), LesserSequence([LessEq._operator_, LessEq._operator_], [a, x, b]))
# Out:
# expr: (x in Reals) and (a <= x <= b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{R}\right) \land \left(a \leq x \leq b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in Reals) and (a <= x <= b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x in Reals, a <= x <= b)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in Reals
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a <= x <= b
#    core type: Operation
#    operators: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 7. (<=, <=)
#    core type: ExprTuple
#    sub-expressions: 10, 10
# 8. (a, x, b)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. Reals
#    core type: Literal
#    sub-expressions:
# 10. <=
#     core type: Literal
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
