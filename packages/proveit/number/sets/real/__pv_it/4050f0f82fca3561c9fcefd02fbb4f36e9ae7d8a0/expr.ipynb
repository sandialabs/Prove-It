# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intervalOO_lower_bound">intervalOO_lower_bound</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real._theorems_ import intervalOO_lower_bound

# %%
# check that the built expression is the same as the stored expression
# %check_expr intervalOO_lower_bound
# Out:
# Passed sanity check: built 'intervalOO_lower_bound' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intervalOO_lower_bound.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}}~\left[\forall_{x \in \left(a,b\right)}~\left(a < x\right)\right]

# %%
# display the expression information
intervalOO_lower_bound.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals} [forall_{x in (a,b)} (a < x)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (a, b) -> {forall_{x in (a,b)} (a < x) if a in Reals ,  b in Reals.
#    core type: Lambda
#    parameters: 24\n   body: 2
# 2. {forall_{x in (a,b)} (a < x) if a in Reals ,  b in Reals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in (a,b)} (a < x)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (a in Reals) and (b in Reals)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> {a < x if x in (a,b).
#    core type: Lambda
#    parameter: 21
#    body: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Reals, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. {a < x if x in (a,b).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. a in Reals
#     core type: Operation
# ...
