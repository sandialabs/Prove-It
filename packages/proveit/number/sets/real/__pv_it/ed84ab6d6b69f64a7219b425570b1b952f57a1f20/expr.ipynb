# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#realsNonNeg_intervalOC_is_subset_of_realsNonNeg">realsNonNeg_intervalOC_is_subset_of_realsNonNeg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real._theorems_ import realsNonNeg_intervalOC_is_subset_of_realsNonNeg

# %%
# check that the built expression is the same as the stored expression
# %check_expr realsNonNeg_intervalOC_is_subset_of_realsNonNeg
# Out:
# Passed sanity check: built 'realsNonNeg_intervalOC_is_subset_of_realsNonNeg' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(realsNonNeg_intervalOC_is_subset_of_realsNonNeg.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^{\ge 0}, b \in \mathbb{R}^{\ge 0}}~\left(\left(a,b\right] \subset \mathbb{R}^{\ge 0}\right)

# %%
# display the expression information
realsNonNeg_intervalOC_is_subset_of_realsNonNeg.exprInfo()
# Out:
# 0. forall_{a in RealsNonNeg, b in RealsNonNeg} ((a,b] subset RealsNonNeg)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a,b] subset RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a,b] subset RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a,b] subset RealsNonNeg
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in RealsNonNeg) and (b in RealsNonNeg)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. subset
#    core type: Literal
#    sub-expressions:
# 7. ((a,b], RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in RealsNonNeg, b in RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a,b]
#     core type: Operation
# ...
