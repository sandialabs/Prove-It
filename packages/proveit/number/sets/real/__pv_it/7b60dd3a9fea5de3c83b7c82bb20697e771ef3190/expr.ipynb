# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, x
from proveit.logic import And, InSet
from proveit.number import Less, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Reals), InSet(b, Reals), InSet(x, Reals), LessEq(a, x), Less(x, b))
# Out:
# expr: (a in Reals) and (b in Reals) and (x in Reals) and (a <= x) and (x < b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(b \in \mathbb{R}\right) \land \left(x \in \mathbb{R}\right) \land \left(a \leq x\right) \land \left(x < b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals) and (b in Reals) and (x in Reals) and (a <= x) and (x < b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Reals, b in Reals, x in Reals, a <= x, x < b)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. a in Reals
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. b in Reals
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. x in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. a <= x
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. x < b
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 9. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 19, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 12. <=
#     core type: Literal
#     sub-expressions:
# 13. (a, x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. <
#     core type: Literal
#     sub-expressions:
# 15. (x, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. Reals
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
