# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, c, x
from proveit.logic import And, Forall, InSet
from proveit.number import IntervalCC, Mult, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c], Conditional(Forall([x], InSet(Mult(c, x), IntervalCC(Mult(c, a), Mult(c, b))), domain = IntervalCC(a, b)), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals))))
# Out:
# expr: (a, b, c) -> {forall_{x in [a,b]} ((c * x) in [c * a,c * b]) if a in Reals ,  b in Reals ,  c in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\forall_{x \in \left[a,b\right]}~\left(\left(c \cdot x\right) \in \left[c \cdot a,c \cdot b\right]\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b, c) -> {forall_{x in [a,b]} ((c * x) in [c * a,c * b]) if a in Reals ,  b in Reals ,  c in Reals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 35, 37, 36
# 2. {forall_{x in [a,b]} ((c * x) in [c * a,c * b]) if a in Reals ,  b in Reals ,  c in Reals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in [a,b]} ((c * x) in [c * a,c * b])
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (a in Reals) and (b in Reals) and (c in Reals)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> {(c * x) in [c * a,c * b] if x in [a,b].
#    core type: Lambda
#    parameter: 29
#    body: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Reals, b in Reals, c in Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(c * x) in [c * a,c * b] if x in [a,b].
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. a in Reals
#     core type: Operation
#     operator: 19
#     operands: 15
# 11. b in Reals
#     core type: Operation
#     operator: 19
#     operands: 16
# 12. c in Reals
#     core type: Operation
#     operator: 19
#     operands: 17
# 13. (c * x) in [c * a,c * b]
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. x in [a,b]
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 35, 21
# 16. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 37, 21
# 17. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 36, 21
# 18. (c * x, [c * a,c * b])
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (x, [a,b])
#     core type: ExprTuple
#     sub-expressions: 29, 24
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. c * x
#     core type: Operation
#     operator: 33
#     operands: 25
# 23. [c * a,c * b]
#     core type: Operation
#     operator: 27
#     operands: 26
# 24. [a,b]
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (c, x)
#     core type: ExprTuple
#     sub-expressions: 36, 29
# 26. (c * a, c * b)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. IntervalCC
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. c * a
#     core type: Operation
#     operator: 33
#     operands: 32
# 31. c * b
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. (c, a)
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 33. *
#     core type: Literal
#     sub-expressions:
# 34. (c, b)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. c
#     core type: Variable
#     sub-expressions:
# 37. b
#     core type: Variable
#     sub-expressions:
