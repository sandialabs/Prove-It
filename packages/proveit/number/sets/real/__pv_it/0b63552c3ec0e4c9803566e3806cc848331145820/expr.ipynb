# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Subset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(SubsetEq(A, B), Subset(A, B)))
# Out:
# expr: (A, B) -> {A subseteq B if A subset B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \subseteq B \textrm{ if } A \subset B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A subseteq B if A subset B.
#    core type: Lambda
#    parameters: 6\n   body: 1
# 1. {A subseteq B if A subset B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A subseteq B
#    core type: Operation
#    operator: 4
#    operands: 6
# 3. A subset B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. subseteq
#    core type: Literal
#    sub-expressions:
# 5. subset
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
