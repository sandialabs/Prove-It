# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intervalOO_is_subset_of_Reals">intervalOO_is_subset_of_Reals</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real._theorems_ import intervalOO_is_subset_of_Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr intervalOO_is_subset_of_Reals
# Out:
# Passed sanity check: built 'intervalOO_is_subset_of_Reals' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intervalOO_is_subset_of_Reals.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}}~\left(\left(a,b\right) \subset \mathbb{R}\right)

# %%
# display the expression information
intervalOO_is_subset_of_Reals.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals} ((a,b) subset Reals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a,b) subset Reals if a in Reals ,  b in Reals.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a,b) subset Reals if a in Reals ,  b in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a,b) subset Reals
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Reals) and (b in Reals)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. subset
#    core type: Literal
#    sub-expressions:
# 7. ((a,b), Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Reals, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a,b)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. a in Reals
#     core type: Operation
#     operator: 16
# ...
