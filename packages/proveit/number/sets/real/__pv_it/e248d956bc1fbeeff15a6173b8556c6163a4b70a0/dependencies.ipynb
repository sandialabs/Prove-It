# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>.<a class="ProveItLink" href="../../_axioms_.ipynb#in_IntervalCO_def">in_IntervalCO_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.sets.real._axioms_ import in_IntervalCO_def

# %%
# %dependencies in_IntervalCO_def
# Out:
# <h3>No theorems depend upon in_IntervalCO_def</h3>
