# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rescale_in_IntervalOO">rescale_in_IntervalOO</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real._theorems_ import rescale_in_IntervalOO

# %%
# check that the built expression is the same as the stored expression
# %check_expr rescale_in_IntervalOO
# Out:
# Passed sanity check: built 'rescale_in_IntervalOO' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rescale_in_IntervalOO.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}}~\left[\forall_{x \in \left(a,b\right)}~\left(\left(c \cdot x\right) \in \left(c \cdot a,c \cdot b\right)\right)\right]

# %%
# display the expression information
rescale_in_IntervalOO.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals, c in Reals} [forall_{x in (a,b)} ((c * x) in (c * a,c * b))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (a, b, c) -> {forall_{x in (a,b)} ((c * x) in (c * a,c * b)) if a in Reals ,  b in Reals ,  c in Reals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 36, 38, 37
# 3. {forall_{x in (a,b)} ((c * x) in (c * a,c * b)) if a in Reals ,  b in Reals ,  c in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in (a,b)} ((c * x) in (c * a,c * b))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (a in Reals) and (b in Reals) and (c in Reals)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. x -> {(c * x) in (c * a,c * b) if x in (a,b).
#    core type: Lambda
#    parameter: 30
#    body: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
