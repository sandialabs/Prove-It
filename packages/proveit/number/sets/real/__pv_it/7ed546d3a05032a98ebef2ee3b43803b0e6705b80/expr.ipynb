# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, x
from proveit.logic import And, Equals, Forall, InSet
from proveit.number import IntervalOO, Less, LesserSequence, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], Equals(InSet(x, IntervalOO(a, b)), And(InSet(x, Reals), LesserSequence([Less._operator_, Less._operator_], [a, x, b])))), And(InSet(a, Reals), InSet(b, Reals)))
# Out:
# expr: {forall_{x} ((x in (a,b)) = ((x in Reals) and (a < x < b))) if a in Reals ,  b in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x}~\left(\left(x \in \left(a,b\right)\right) = \left(\left(x \in \mathbb{R}\right) \land \left(a < x < b\right)\right)\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x} ((x in (a,b)) = ((x in Reals) and (a < x < b))) if a in Reals ,  b in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x} ((x in (a,b)) = ((x in Reals) and (a < x < b)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Reals) and (b in Reals)
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> ((x in (a,b)) = ((x in Reals) and (a < x < b)))
#    core type: Lambda
#    parameter: 30
#    body: 6
# 5. (a in Reals, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (x in (a,b)) = ((x in Reals) and (a < x < b))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in Reals
#    core type: Operation
#    operator: 23
#    operands: 11
# 8. b in Reals
#    core type: Operation
#    operator: 23
#    operands: 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (x in (a,b), (x in Reals) and (a < x < b))
# ...
