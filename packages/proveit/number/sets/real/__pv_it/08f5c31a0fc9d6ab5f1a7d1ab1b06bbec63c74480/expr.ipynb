# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, x
from proveit.logic import And, Equals, InSet
from proveit.number import IntervalOO, Less, LesserSequence, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Equals(InSet(x, IntervalOO(a, b)), And(InSet(x, Reals), LesserSequence([Less._operator_, Less._operator_], [a, x, b]))))
# Out:
# expr: x -> ((x in (a,b)) = ((x in Reals) and (a < x < b)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left(\left(x \in \left(a,b\right)\right) = \left(\left(x \in \mathbb{R}\right) \land \left(a < x < b\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> ((x in (a,b)) = ((x in Reals) and (a < x < b)))
#    core type: Lambda
#    parameter: 21
#    body: 1
# 1. (x in (a,b)) = ((x in Reals) and (a < x < b))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x in (a,b), (x in Reals) and (a < x < b))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in (a,b)
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (x in Reals) and (a < x < b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x, (a,b))
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Reals, a < x < b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (a,b)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x in Reals
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. a < x < b
#     core type: Operation
#     operators: 16
#     operands: 17
# 12. IntervalOO
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 16. (<, <)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 17. (a, x, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 18. Reals
#     core type: Literal
#     sub-expressions:
# 19. <
#     core type: Literal
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
