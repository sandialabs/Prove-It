# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#in_IntervalOO">in_IntervalOO</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real._theorems_ import in_IntervalOO

# %%
# check that the built expression is the same as the stored expression
# %check_expr in_IntervalOO
# Out:
# Passed sanity check: built 'in_IntervalOO' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(in_IntervalOO.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}, x \in \mathbb{R}~|~a < x, x < b}~\left(x \in \left(a,b\right)\right)

# %%
# display the expression information
in_IntervalOO.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals, x in Reals | a < x, x < b} (x in (a,b))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, x) -> {x in (a,b) if a in Reals ,  b in Reals ,  x in Reals ,  a < x ,  x < b.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 26, 28, 27
# 4. {x in (a,b) if a in Reals ,  b in Reals ,  x in Reals ,  a < x ,  x < b.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x in (a,b)
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (a in Reals) and (b in Reals) and (x in Reals) and (a < x) and (x < b)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x, (a,b))
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Reals, b in Reals, x in Reals, a < x, x < b)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# 10. (a,b)
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. a in Reals
#     core type: Operation
#     operator: 20
#     operands: 18
# 12. b in Reals
#     core type: Operation
#     operator: 20
#     operands: 19
# 13. x in Reals
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. a < x
#     core type: Operation
#     operator: 23
#     operands: 22
# 15. x < b
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. IntervalOO
#     core type: Literal
#     sub-expressions:
# 17. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 18. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 19. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 22. (a, x)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. <
#     core type: Literal
#     sub-expressions:
# 24. (x, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. Reals
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
