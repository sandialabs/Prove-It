# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Variable
from proveit.logic import InSet
from proveit.number import IntervalCC, RealsPos, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Conditional(InSet(subExpr1, RealsPos), InSet(subExpr1, IntervalCC(one, two)))
# Out:
# expr: {_a in RealsPos if _a in [1,2].

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{{_{-}a} \in \mathbb{R}^+ \textrm{ if } {_{-}a} \in \left[1,2\right]\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {_a in RealsPos if _a in [1,2].
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. _a in RealsPos
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. _a in [1,2]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (_a, [1,2])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. RealsPos
#    core type: Literal
#    sub-expressions:
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. [1,2]
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. IntervalCC
#    core type: Literal
#    sub-expressions:
# 10. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
