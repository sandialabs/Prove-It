# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, x
from proveit.logic import And, Equals, InSet
from proveit.number import IntervalCO, Less, LessEq, LesserSequence, Reals

# %%
# build up the expression from sub-expressions
expr = Equals(InSet(x, IntervalCO(a, b)), And(InSet(x, Reals), LesserSequence([LessEq._operator_, Less._operator_], [a, x, b])))
# Out:
# expr: (x in [a,b)) = ((x in Reals) and (a <= x < b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \left[a,b\right)\right) = \left(\left(x \in \mathbb{R}\right) \land \left(a \leq x < b\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in [a,b)) = ((x in Reals) and (a <= x < b))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (x in [a,b), (x in Reals) and (a <= x < b))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in [a,b)
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (x in Reals) and (a <= x < b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, [a,b))
#    core type: ExprTuple
#    sub-expressions: 21, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in Reals, a <= x < b)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. [a,b)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. x in Reals
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a <= x < b
#     core type: Operation
#     operators: 15
#     operands: 16
# 11. IntervalCO
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 21, 17
# 15. (<=, <)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. (a, x, b)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 17. Reals
#     core type: Literal
#     sub-expressions:
# 18. <=
#     core type: Literal
#     sub-expressions:
# 19. <
#     core type: Literal
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
