# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, c, x
from proveit.logic import And, Forall, InSet
from proveit.number import IntervalOC, Mult, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], InSet(Mult(c, x), IntervalOC(Mult(c, a), Mult(c, b))), domain = IntervalOC(a, b)), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals)))
# Out:
# expr: {forall_{x in (a,b]} ((c * x) in (c * a,c * b]) if a in Reals ,  b in Reals ,  c in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \left(a,b\right]}~\left(\left(c \cdot x\right) \in \left(c \cdot a,c \cdot b\right]\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x in (a,b]} ((c * x) in (c * a,c * b]) if a in Reals ,  b in Reals ,  c in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in (a,b]} ((c * x) in (c * a,c * b])
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Reals) and (b in Reals) and (c in Reals)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {(c * x) in (c * a,c * b] if x in (a,b].
#    core type: Lambda
#    parameter: 27
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Reals, b in Reals, c in Reals)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. {(c * x) in (c * a,c * b] if x in (a,b].
#    core type: Conditional
#    value: 11
#    condition: 12
# 8. a in Reals
#    core type: Operation
#    operator: 17
#    operands: 13
# 9. b in Reals
#    core type: Operation
#    operator: 17
#    operands: 14
# 10. c in Reals
#     core type: Operation
#     operator: 17
#     operands: 15
# 11. (c * x) in (c * a,c * b]
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. x in (a,b]
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 33, 19
# 14. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 35, 19
# 15. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 34, 19
# 16. (c * x, (c * a,c * b])
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x, (a,b])
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 19. Reals
#     core type: Literal
#     sub-expressions:
# 20. c * x
#     core type: Operation
#     operator: 31
#     operands: 23
# 21. (c * a,c * b]
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. (a,b]
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (c, x)
#     core type: ExprTuple
#     sub-expressions: 34, 27
# 24. (c * a, c * b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. IntervalOC
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. c * a
#     core type: Operation
#     operator: 31
#     operands: 30
# 29. c * b
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (c, a)
#     core type: ExprTuple
#     sub-expressions: 34, 33
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (c, b)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. c
#     core type: Variable
#     sub-expressions:
# 35. b
#     core type: Variable
#     sub-expressions:
