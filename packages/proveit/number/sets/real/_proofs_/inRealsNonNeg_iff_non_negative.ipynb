# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">sets</a>.<a class="ProveItLink" href="../_context_.ipynb">real</a>.<a class="ProveItLink" href="../_theorems_.ipynb#inRealsNonNeg_iff_non_negative">inRealsNonNeg_iff_non_negative</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving inRealsNonNeg_iff_non_negative presuming []
# Out:
# Beginning proof of inRealsNonNeg_iff_non_negative
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# inRealsNonNeg_iff_non_negative: forall_{a in Reals} ((a in RealsNonNeg) <=> (a >= 0))
