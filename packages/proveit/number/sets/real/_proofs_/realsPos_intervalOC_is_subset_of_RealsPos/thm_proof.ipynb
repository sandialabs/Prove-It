# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../_theory_.ipynb">real</a>.<a class="ProveItLink" href="../_theorems_.ipynb#realsPos_intervalOC_is_subset_of_RealsPos">realsPos_intervalOC_is_subset_of_RealsPos</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving realsPos_intervalOC_is_subset_of_RealsPos
