# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">sets</a>.<a class="ProveItLink" href="../_context_.ipynb">real</a>.<a class="ProveItLink" href="../_theorems_.ipynb#positive_implies_not_zero">positive_implies_not_zero</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving positive_implies_not_zero presuming []
# Out:
# Beginning proof of positive_implies_not_zero
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# positive_implies_not_zero: forall_{a in Reals | a > 0} (a != 0)
