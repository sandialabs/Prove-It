# %% [markdown]
# Common expressions for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>
# ========

# %%
import proveit
# Automation is not needed when only building common expressions:
proveit.defaults.automation = False # This will speed things up.
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin common
# Out:
# Defining common sub-expressions for context 'proveit.number.sets.real.root2_proof_temporary_context'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
# %end common
# Out:
# Context proveit.number.sets.real.root2_proof_temporary_context has no common expressions
