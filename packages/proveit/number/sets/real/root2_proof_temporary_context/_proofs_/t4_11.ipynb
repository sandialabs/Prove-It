# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../../_context_.ipynb">sets</a>.<a class="ProveItLink" href="../../_context_.ipynb">real</a>.<a class="ProveItLink" href="../_context_.ipynb">root2_proof_temporary_context</a>.<a class="ProveItLink" href="../_theorems_.ipynb#t4_11">t4_11</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving t4_11 presuming []
