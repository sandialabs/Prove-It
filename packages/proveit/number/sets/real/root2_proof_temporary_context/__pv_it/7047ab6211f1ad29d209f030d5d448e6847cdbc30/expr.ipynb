# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Lambda, Variable
from proveit._common_ import P, alpha
from proveit.logic import And

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("x1")
subExpr2 = Variable("x2")
subExpr3 = [subExpr1, subExpr2]
expr = Lambda(subExpr3, Conditional(alpha, And(Function(P, subExpr3), Function(Variable("Q1"), subExpr1), Function(Variable("Q2"), subExpr2))))
# Out:
# expr: (x1, x2) -> {alpha if P(x1, x2) ,  Q1(x1) ,  Q2(x2).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x1, x2\right) \mapsto \left\{\alpha \textrm{ if } P(x1, x2) ,  Q1(x1) ,  Q2(x2)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x1, x2) -> {alpha if P(x1, x2) ,  Q1(x1) ,  Q2(x2).
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {alpha if P(x1, x2) ,  Q1(x1) ,  Q2(x2).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. alpha
#    core type: Variable
#    sub-expressions:
# 3. P(x1, x2) and Q1(x1) and Q2(x2)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (P(x1, x2), Q1(x1), Q2(x2))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. P(x1, x2)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. Q1(x1)
#    core type: Operation
#    operator: 11
#    operand: 13
# 8. Q2(x2)
#    core type: Operation
#    operator: 12
#    operand: 14
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. (x1, x2)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Q1
#     core type: Variable
#     sub-expressions:
# 12. Q2
#     core type: Variable
#     sub-expressions:
# 13. x1
# ...
