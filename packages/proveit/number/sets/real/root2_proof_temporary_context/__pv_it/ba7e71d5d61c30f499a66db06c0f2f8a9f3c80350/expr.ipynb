# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n
from proveit.logic import Implies, InSet
from proveit.number import NaturalsPos, Rationals, RationalsPos, sqrt

# %%
# build up the expression from sub-expressions
subExpr1 = sqrt(n)
expr = Lambda(n, Conditional(Implies(InSet(subExpr1, Rationals), InSet(subExpr1, RationalsPos)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {(sqrt(n) in Rationals) => (sqrt(n) in RationalsPos) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\left(\sqrt{n} \in \mathbb{Q}\right) \Rightarrow \left(\sqrt{n} \in \mathbb{Q}^+\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {(sqrt(n) in Rationals) => (sqrt(n) in RationalsPos) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {(sqrt(n) in Rationals) => (sqrt(n) in RationalsPos) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (sqrt(n) in Rationals) => (sqrt(n) in RationalsPos)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 11
#    operands: 6
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (sqrt(n) in Rationals, sqrt(n) in RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 18, 9
# 7. sqrt(n) in Rationals
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. sqrt(n) in RationalsPos
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. (sqrt(n), Rationals)
# ...
