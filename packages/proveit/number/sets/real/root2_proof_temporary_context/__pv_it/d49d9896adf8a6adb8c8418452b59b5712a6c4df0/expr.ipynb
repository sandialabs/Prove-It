# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rationalsPosDefExtensionReduced">rationalsPosDefExtensionReduced</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real.root2_proof_temporary_context._theorems_ import rationalsPosDefExtensionReduced

# %%
# check that the built expression is the same as the stored expression
# %check_expr rationalsPosDefExtensionReduced
# Out:
# Passed sanity check: built 'rationalsPosDefExtensionReduced' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rationalsPosDefExtensionReduced.latex())
# Out:
# \vdash \forall_{x \in \mathbb{Q}^+, y \in \mathbb{Q}^+}~\left[\exists_{u \in \mathbb{N}^+, v \in \mathbb{N}^+}~\left(\left(\left(gcd(x, y) \cdot u\right) = x\right) \land \left(\left(gcd(x, y) \cdot v\right) = y\right) \land \left(gcd(u, v) = 1\right)\right)\right]

# %%
# display the expression information
rationalsPosDefExtensionReduced.exprInfo()
# Out:
# 0. forall_{x in RationalsPos, y in RationalsPos} [exists_{u in NaturalsPos, v in NaturalsPos} (((gcd(x, y) * u) = x) and ((gcd(x, y) * v) = y) and (gcd(u, v) = 1))]
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {exists_{u in NaturalsPos, v in NaturalsPos} (((gcd(x, y) * u) = x) and ((gcd(x, y) * v) = y) and (gcd(u, v) = 1)) if x in RationalsPos ,  y in RationalsPos.
#    core type: Lambda
#    parameters: 45\n   body: 3
# 3. {exists_{u in NaturalsPos, v in NaturalsPos} (((gcd(x, y) * u) = x) and ((gcd(x, y) * v) = y) and (gcd(u, v) = 1)) if x in RationalsPos ,  y in RationalsPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. exists_{u in NaturalsPos, v in NaturalsPos} (((gcd(x, y) * u) = x) and ((gcd(x, y) * v) = y) and (gcd(u, v) = 1))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (x in RationalsPos) and (y in RationalsPos)
#    core type: Operation
# ...
