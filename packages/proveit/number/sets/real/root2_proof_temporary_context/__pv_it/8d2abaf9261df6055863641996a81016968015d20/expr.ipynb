# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, aPrime, b, bPrime
from proveit.logic import And, Equals, Exists, InSet
from proveit.number import GCD, NaturalsPos, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Exists([aPrime, bPrime], And(Equals(frac(a, b), frac(aPrime, bPrime)), Equals(GCD(aPrime, bPrime), one)), domains = [NaturalsPos, NaturalsPos]), And(InSet(a, NaturalsPos), InSet(b, NaturalsPos))))
# Out:
# expr: (a, b) -> {exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1)) if a in NaturalsPos ,  b in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\exists_{a' \in \mathbb{N}^+, b' \in \mathbb{N}^+}~\left(\left(\frac{a}{b} = \frac{a'}{b'}\right) \land \left(gcd(a', b') = 1\right)\right) \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1)) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 32\n   body: 1
# 1. {exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1)) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 15
#    operands: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. (a', b') -> {((a / b) = (a' / b')) and (gcd(a', b') = 1) if a' in NaturalsPos ,  b' in NaturalsPos.
#    core type: Lambda
#    parameters: 35\n   body: 7
# 6. (a in NaturalsPos, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# ...
