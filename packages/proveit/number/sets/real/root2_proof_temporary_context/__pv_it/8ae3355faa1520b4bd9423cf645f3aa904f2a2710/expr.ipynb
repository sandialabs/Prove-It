# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import n
from proveit.logic import InSet
from proveit.number import Divides, Mult, NaturalsPos, two

# %%
# build up the expression from sub-expressions
expr = Conditional(Divides(two, Mult(two, n)), InSet(n, NaturalsPos))
# Out:
# expr: {2 | (2 * n) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{2 \rvert \left(2 \cdot n\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {2 | (2 * n) if n in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. 2 | (2 * n)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. n in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. |
#    core type: Literal
#    sub-expressions:
# 4. (2, 2 * n)
#    core type: ExprTuple
#    sub-expressions: 11, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 7. 2 * n
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2, n)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
