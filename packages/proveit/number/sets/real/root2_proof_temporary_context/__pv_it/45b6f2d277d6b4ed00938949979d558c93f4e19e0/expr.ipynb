# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import n
from proveit.logic import InSet
from proveit.number import Rationals, RationalsPos, sqrt

# %%
# build up the expression from sub-expressions
subExpr1 = sqrt(n)
expr = ExprTuple(InSet(subExpr1, Rationals), InSet(subExpr1, RationalsPos))
# Out:
# expr: (sqrt(n) in Rationals, sqrt(n) in RationalsPos)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sqrt{n} \in \mathbb{Q}, \sqrt{n} \in \mathbb{Q}^+\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (sqrt(n) in Rationals, sqrt(n) in RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. sqrt(n) in Rationals
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. sqrt(n) in RationalsPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (sqrt(n), Rationals)
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (sqrt(n), RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Rationals
#    core type: Literal
#    sub-expressions:
# 7. sqrt(n)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. RationalsPos
#    core type: Literal
#    sub-expressions:
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (n, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. 1 / 2
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
