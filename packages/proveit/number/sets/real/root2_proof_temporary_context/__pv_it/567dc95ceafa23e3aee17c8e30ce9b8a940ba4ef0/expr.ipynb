# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Variable
from proveit._common_ import P
from proveit.logic import And

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("y1")
subExpr2 = Variable("y2")
expr = Conditional(Function(P, [subExpr1, subExpr2]), And(Function(Variable("Q1"), subExpr1), Function(Variable("Q2"), subExpr2)))
# Out:
# expr: {P(y1, y2) if Q1(y1) ,  Q2(y2).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P(y1, y2) \textrm{ if } Q1(y1) ,  Q2(y2)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {P(y1, y2) if Q1(y1) ,  Q2(y2).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. P(y1, y2)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Q1(y1) and Q2(y2)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. (y1, y2)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (Q1(y1), Q2(y2))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. Q1(y1)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. Q2(y2)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. Q1
#    core type: Variable
#    sub-expressions:
# 10. y1
#     core type: Variable
#     sub-expressions:
# 11. Q2
#     core type: Variable
#     sub-expressions:
# 12. y2
#     core type: Variable
#     sub-expressions:
