# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#t8">t8</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real.root2_proof_temporary_context._theorems_ import t8

# %%
# check that the built expression is the same as the stored expression
# %check_expr t8
# Out:
# Passed sanity check: built 't8' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(t8.latex())
# Out:
# \vdash \forall_{a \in \mathbb{N}^+, b \in \mathbb{N}^+}~\left(\left(\sqrt{2} = \frac{a}{b}\right) \Rightarrow \left(\left(2 \cdot b^{2}\right) = a^{2}\right)\right)

# %%
# display the expression information
t8.exprInfo()
# Out:
# 0. forall_{a in NaturalsPos, b in NaturalsPos} ((sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2}) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 26\n   body: 3
# 3. {(sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2}) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. (sqrt(2) = (a / b), (2 * b^{2}) = a^{2})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in NaturalsPos, b in NaturalsPos)
# ...
