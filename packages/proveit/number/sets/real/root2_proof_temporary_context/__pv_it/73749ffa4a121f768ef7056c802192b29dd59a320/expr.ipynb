# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import u, v, x
from proveit.logic import Equals, Exists
from proveit.number import Mult, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Exists([u, v], Equals(Mult(x, u), v), domains = [NaturalsPos, NaturalsPos])
# Out:
# expr: exists_{u in NaturalsPos, v in NaturalsPos} ((x * u) = v)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \exists_{u \in \mathbb{N}^+, v \in \mathbb{N}^+}~\left(\left(x \cdot u\right) = v\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. exists_{u in NaturalsPos, v in NaturalsPos} ((x * u) = v)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (u, v) -> {(x * u) = v if u in NaturalsPos ,  v in NaturalsPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (u, v)
#    core type: ExprTuple
#    sub-expressions: 20, 21
# 4. {(x * u) = v if u in NaturalsPos ,  v in NaturalsPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x * u) = v
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (u in NaturalsPos) and (v in NaturalsPos)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x * u, v)
#    core type: ExprTuple
#    sub-expressions: 11, 21
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (u in NaturalsPos, v in NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. x * u
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. u in NaturalsPos
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. v in NaturalsPos
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (x, u)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. (u, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (v, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. u
#     core type: Variable
#     sub-expressions:
# 21. v
#     core type: Variable
#     sub-expressions:
# 22. NaturalsPos
#     core type: Literal
#     sub-expressions:
