# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import Px, Py, Qx, Qy, alpha, x, y
from proveit.logic import And, Exists, Forall

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(Exists([y], Py, condition = Qy), Forall([x], alpha, conditions = [Px, Qx])), alpha)
# Out:
# expr: ([exists_{y | Q(y)} P(y)] and [forall_{x | P(x), Q(x)} alpha], alpha)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[\exists_{y~|~Q(y)}~P(y)\right] \land \left[\forall_{x~|~P(x), Q(x)}~\alpha\right], \alpha\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ([exists_{y | Q(y)} P(y)] and [forall_{x | P(x), Q(x)} alpha], alpha)
#    core type: ExprTuple
#    sub-expressions: 1, 13
# 1. [exists_{y | Q(y)} P(y)] and [forall_{x | P(x), Q(x)} alpha]
#    core type: Operation
#    operator: 16
#    operands: 2
# 2. (exists_{y | Q(y)} P(y), forall_{x | P(x), Q(x)} alpha)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. exists_{y | Q(y)} P(y)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. forall_{x | P(x), Q(x)} alpha
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. y -> {P(y) if Q(y).
#    core type: Lambda
#    parameter: 15
#    body: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> {alpha if P(x) ,  Q(x).
#    core type: Lambda
#    parameter: 22
#    body: 10
# 9. {P(y) if Q(y).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. {alpha if P(x) ,  Q(x).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. P(y)
#     core type: Operation
#     operator: 20
#     operand: 15
# 12. Q(y)
#     core type: Operation
#     operator: 21
#     operand: 15
# 13. alpha
#     core type: Variable
#     sub-expressions:
# 14. P(x) and Q(x)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (P(x), Q(x))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. P(x)
#     core type: Operation
#     operator: 20
#     operand: 22
# 19. Q(x)
#     core type: Operation
#     operator: 21
#     operand: 22
# 20. P
#     core type: Variable
#     sub-expressions:
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
