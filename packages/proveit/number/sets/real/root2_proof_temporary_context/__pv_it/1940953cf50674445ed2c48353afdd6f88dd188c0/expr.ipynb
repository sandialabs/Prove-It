# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a
from proveit.logic import Implies, InSet
from proveit.number import Divides, Exp, NaturalsPos, four, two

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(Implies(Divides(two, a), Divides(four, Exp(a, two))), InSet(a, NaturalsPos)))
# Out:
# expr: a -> {(2 | a) => (4 | a^{2}) if a in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{\left(2 \rvert a\right) \Rightarrow \left(4 \rvert a^{2}\right) \textrm{ if } a \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> {(2 | a) => (4 | a^{2}) if a in NaturalsPos.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {(2 | a) => (4 | a^{2}) if a in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (2 | a) => (4 | a^{2})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. a in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (2 | a, 4 | a^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (a, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. 2 | a
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. 4 | a^{2}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. (2, a)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 12. |
#     core type: Literal
#     sub-expressions:
# 13. (4, a^{2})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 4
#     core type: Literal
#     sub-expressions:
# 15. a^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (a, 2)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
