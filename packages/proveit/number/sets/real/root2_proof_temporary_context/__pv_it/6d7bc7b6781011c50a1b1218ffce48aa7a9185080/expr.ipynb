# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, Equals, Implies, InSet
from proveit.number import Exp, Mult, NaturalsPos, frac, sqrt, two

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(Equals(sqrt(two), frac(a, b)), Equals(Mult(two, Exp(b, two)), Exp(a, two))), And(InSet(a, NaturalsPos), InSet(b, NaturalsPos)))
# Out:
# expr: {(sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2}) if a in NaturalsPos ,  b in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sqrt{2} = \frac{a}{b}\right) \Rightarrow \left(\left(2 \cdot b^{2}\right) = a^{2}\right) \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2}) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (sqrt(2) = (a / b)) => ((2 * b^{2}) = a^{2})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (sqrt(2) = (a / b), (2 * b^{2}) = a^{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in NaturalsPos, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. sqrt(2) = (a / b)
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. (2 * b^{2}) = a^{2}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. a in NaturalsPos
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. b in NaturalsPos
#     core type: Operation
#     operator: 15
# ...
