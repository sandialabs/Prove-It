# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, p
from proveit.logic import And, Equals, Forall, Implies, InSet, Not
from proveit.number import Divides, GCD, Greater, NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Implies(Equals(GCD(a, b), one), Forall([p], Implies(Greater(p, one), Not(And(Divides(p, a), Divides(p, b)))), domain = NaturalsPos)), And(InSet(a, NaturalsPos), InSet(b, NaturalsPos))))
# Out:
# expr: (a, b) -> {(gcd(a, b) = 1) => [forall_{p in NaturalsPos} ((p > 1) => [not]((p | a) and (p | b)))] if a in NaturalsPos ,  b in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(gcd(a, b) = 1\right) \Rightarrow \left[\forall_{p \in \mathbb{N}^+}~\left(\left(p > 1\right) \Rightarrow (\lnot \left(\left(p \rvert a\right) \land \left(p \rvert b\right)\right))\right)\right] \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(gcd(a, b) = 1) => [forall_{p in NaturalsPos} ((p > 1) => [not]((p | a) and (p | b)))] if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 19\n   body: 1
# 1. {(gcd(a, b) = 1) => [forall_{p in NaturalsPos} ((p > 1) => [not]((p | a) and (p | b)))] if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (gcd(a, b) = 1) => [forall_{p in NaturalsPos} ((p > 1) => [not]((p | a) and (p | b)))]
#    core type: Operation
#    operator: 22
#    operands: 4
# 3. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 34
#    operands: 5
# 4. (gcd(a, b) = 1, forall_{p in NaturalsPos} ((p > 1) => [not]((p | a) and (p | b))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a in NaturalsPos, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. gcd(a, b) = 1
#    core type: Operation
#    operator: 10
#    operands: 11
# ...
