# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Function, Variable
from proveit._common_ import P
from proveit.logic import Exists

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("y1")
subExpr2 = Variable("y2")
subExpr3 = [subExpr1, subExpr2]
expr = Exists(subExpr3, Function(P, subExpr3), conditions = [Function(Variable("Q1"), subExpr1), Function(Variable("Q2"), subExpr2)])
# Out:
# expr: exists_{y1, y2 | Q1(y1), Q2(y2)} P(y1, y2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \exists_{y1, y2~|~Q1(y1), Q2(y2)}~P(y1, y2)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. exists_{y1, y2 | Q1(y1), Q2(y2)} P(y1, y2)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (y1, y2) -> {P(y1, y2) if Q1(y1) ,  Q2(y2).
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {P(y1, y2) if Q1(y1) ,  Q2(y2).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. P(y1, y2)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. Q1(y1) and Q2(y2)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. (y1, y2)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (Q1(y1), Q2(y2))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. Q1(y1)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. Q2(y2)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. Q1
#     core type: Variable
#     sub-expressions:
# 13. y1
# ...
