# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#t6">t6</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.sets.real.root2_proof_temporary_context._theorems_ import t6

# %%
# check that the built expression is the same as the stored expression
# %check_expr t6
# Out:
# Passed sanity check: built 't6' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(t6.latex())
# Out:
# \vdash \forall_{a \in \mathbb{N}^+, b \in \mathbb{N}^+}~\left[\exists_{a' \in \mathbb{N}^+, b' \in \mathbb{N}^+}~\left(\left(\frac{a}{b} = \frac{a'}{b'}\right) \land \left(gcd(a', b') = 1\right)\right)\right]

# %%
# display the expression information
t6.exprInfo()
# Out:
# 0. forall_{a in NaturalsPos, b in NaturalsPos} [exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1))]
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1)) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 34\n   body: 3
# 3. {exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1)) if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. exists_{a' in NaturalsPos, b' in NaturalsPos} (((a / b) = (a' / b')) and (gcd(a', b') = 1))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 17
#    operands: 8
# 6. exists
#    core type: Literal
#    sub-expressions:
# ...
