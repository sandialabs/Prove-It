# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.real.root2_proof_temporary_context</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import u, v
from proveit.logic import And, InSet
from proveit.number import RationalsPos

# %%
# build up the expression from sub-expressions
expr = And(InSet(u, RationalsPos), InSet(v, RationalsPos))
# Out:
# expr: (u in RationalsPos) and (v in RationalsPos)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(u \in \mathbb{Q}^+\right) \land \left(v \in \mathbb{Q}^+\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (u in RationalsPos) and (v in RationalsPos)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (u in RationalsPos, v in RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. u in RationalsPos
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. v in RationalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (u, RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (v, RationalsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. u
#    core type: Variable
#    sub-expressions:
# 9. v
#    core type: Variable
#    sub-expressions:
# 10. RationalsPos
#     core type: Literal
#     sub-expressions:
