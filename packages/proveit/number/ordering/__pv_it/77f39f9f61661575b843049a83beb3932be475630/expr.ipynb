# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#greaterShiftAddRight">greaterShiftAddRight</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.ordering._theorems_ import greaterShiftAddRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr greaterShiftAddRight
# Out:
# Passed sanity check: built 'greaterShiftAddRight' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greaterShiftAddRight.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}~|~a > b}~\left(\left(a + c\right) > \left(b + c\right)\right)

# %%
# display the expression information
greaterShiftAddRight.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals, c in Reals | a > b} ((a + c) > (b + c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(a + c) > (b + c) if a in Reals ,  b in Reals ,  c in Reals ,  a > b.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 27, 28, 25
# 4. {(a + c) > (b + c) if a in Reals ,  b in Reals ,  c in Reals ,  a > b.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a + c) > (b + c)
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (a in Reals) and (b in Reals) and (c in Reals) and (a > b)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a + c, b + c)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Reals, b in Reals, c in Reals, a > b)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. a + c
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. b + c
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a in Reals
#     core type: Operation
#     operator: 21
#     operands: 19
# 13. b in Reals
#     core type: Operation
#     operator: 21
#     operands: 20
# 14. c in Reals
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. a > b
#     core type: Operation
#     operator: 23
#     operands: 24
# 16. (a, c)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (b, c)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 19. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 20. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. >
#     core type: Literal
#     sub-expressions:
# 24. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. Reals
#     core type: Literal
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
