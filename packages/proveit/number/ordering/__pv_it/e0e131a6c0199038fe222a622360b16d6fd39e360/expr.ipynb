# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, Variable
from proveit._common_ import rho
from proveit.logic import Equals, Set
from proveit.number import Less, LessEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(IndexedVar(rho, Variable("_a", latexFormat = r"{_{-}a}")), Set(Less._operator_, LessEq._operator_, Equals._operator_))
# Out:
# expr: (rho_{_a}, {<, <=, =})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\rho_{{_{-}a}}, \left\{<, \leq, =\right\}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (rho_{_a}, {<, <=, =})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. rho_{_a}
#    core type: IndexedVar
# variable: 3
# index: 4
# 2. {<, <=, =}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. rho
#    core type: Variable
#    sub-expressions:
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (<, <=, =)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
