# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import And, InSet
from proveit.number import Less, Reals

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), Less(a, b))
# Out:
# expr: (a in Reals) and (b in Reals) and (c in Reals) and (a < b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(b \in \mathbb{R}\right) \land \left(c \in \mathbb{R}\right) \land \left(a < b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals) and (b in Reals) and (c in Reals) and (a < b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Reals, b in Reals, c in Reals, a < b)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Reals
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. b in Reals
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. c in Reals
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. a < b
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 8. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 16, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. <
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. Reals
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
