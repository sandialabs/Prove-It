# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a
from proveit.number import Add, one, three

# %%
# build up the expression from sub-expressions
subExpr1 = Add(three, one)
expr = ExprTuple([ExprRange(a, a, one, subExpr1)], [ExprRange(a, a, one, three), subExpr1])
# Out:
# expr: ((1, ..a.., 3 + 1), (1, ..a.., 3, 3 + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1, \ldots, 3 + 1\right), \left(1, \ldots, 3, 3 + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1, ..a.., 3 + 1), (1, ..a.., 3, 3 + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1, ..a.., 3 + 1)
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (1, ..a.., 3, 3 + 1)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. 1, ..a.., (3 + 1)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 11
#    end_index: 5
# 4. 1, ..a.., 3
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 11
#    end_index: 10
# 5. 3 + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. a -> a
#    core type: Lambda
#    parameter: 9
#    body: 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (3, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
