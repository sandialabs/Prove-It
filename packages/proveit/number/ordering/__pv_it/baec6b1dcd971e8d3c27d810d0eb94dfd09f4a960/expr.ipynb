# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, c, d
from proveit.logic import And, InSet
from proveit.number import Add, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(GreaterEq(Add(a, c), Add(b, d)), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(d, Reals), GreaterEq(a, b), GreaterEq(c, d)))
# Out:
# expr: {(a + c) >= (b + d) if a in Reals ,  b in Reals ,  c in Reals ,  d in Reals ,  a >= b ,  c >= d.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a + c\right) \geq \left(b + d\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  d \in \mathbb{R} ,  a \geq b ,  c \geq d\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a + c) >= (b + d) if a in Reals ,  b in Reals ,  c in Reals ,  d in Reals ,  a >= b ,  c >= d.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a + c) >= (b + d)
#    core type: Operation
#    operator: 23
#    operands: 3
# 2. (a in Reals) and (b in Reals) and (c in Reals) and (d in Reals) and (a >= b) and (c >= d)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a + c, b + d)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Reals, b in Reals, c in Reals, d in Reals, a >= b, c >= d)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 6. a + c
#    core type: Operation
#    operator: 15
#    operands: 14
# 7. b + d
#    core type: Operation
#    operator: 15
#    operands: 16
# 8. a in Reals
#    core type: Operation
#    operator: 20
#    operands: 17
# 9. b in Reals
#    core type: Operation
#    operator: 20
#    operands: 18
# 10. c in Reals
#     core type: Operation
#     operator: 20
#     operands: 19
# 11. d in Reals
#     core type: Operation
#     operator: 20
#     operands: 21
# 12. a >= b
#     core type: Operation
#     operator: 23
#     operands: 22
# 13. c >= d
#     core type: Operation
#     operator: 23
#     operands: 24
# 14. (a, c)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (b, d)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 17. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 18. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 19. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (d, Reals)
#     core type: ExprTuple
#     sub-expressions: 29, 25
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. >=
#     core type: Literal
#     sub-expressions:
# 24. (c, d)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Reals
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. d
#     core type: Variable
#     sub-expressions:
