# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, c
from proveit.logic import And, InSet
from proveit.number import Add, Less, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c], Conditional(Less(Add(c, a), Add(c, b)), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), Less(a, b))))
# Out:
# expr: (a, b, c) -> {(c + a) < (c + b) if a in Reals ,  b in Reals ,  c in Reals ,  a < b.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(c + a\right) < \left(c + b\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a < b\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b, c) -> {(c + a) < (c + b) if a in Reals ,  b in Reals ,  c in Reals ,  a < b.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 25, 26, 23
# 2. {(c + a) < (c + b) if a in Reals ,  b in Reals ,  c in Reals ,  a < b.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (c + a) < (c + b)
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (a in Reals) and (b in Reals) and (c in Reals) and (a < b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (c + a, c + b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Reals, b in Reals, c in Reals, a < b)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. c + a
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. c + b
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a in Reals
#     core type: Operation
#     operator: 19
#     operands: 17
# 11. b in Reals
#     core type: Operation
#     operator: 19
#     operands: 18
# 12. c in Reals
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. a < b
#     core type: Operation
#     operator: 21
#     operands: 22
# 14. (c, a)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (c, b)
#     core type: ExprTuple
#     sub-expressions: 23, 26
# 17. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 18. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. <
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. c
#     core type: Variable
#     sub-expressions:
# 24. Reals
#     core type: Literal
#     sub-expressions:
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
