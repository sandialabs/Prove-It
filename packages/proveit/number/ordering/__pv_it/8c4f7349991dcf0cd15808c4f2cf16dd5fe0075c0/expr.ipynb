# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#greaterSequenceDef">greaterSequenceDef</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.ordering._axioms_ import greaterSequenceDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr greaterSequenceDef
# Out:
# Passed sanity check: built 'greaterSequenceDef' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(greaterSequenceDef.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n + 1} \in \mathbb{R}}~\left[\forall_{\rho_{1}, \ldots, \rho_{n} \in \left\{>, \geq, =\right\}}~\left(\left(x_{1} \rho_{1} \ldots  x_{n} \rho_{n} x_{n + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{n} \rho_{n} x_{n + 1}\right)\right)\right)\right]\right]

# %%
# display the expression information
greaterSequenceDef.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Reals} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))]]
#    core type: Operation
#    operator: 12
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Reals} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 49
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n + 1} in Reals} [forall_{rho_{1}, ..rho_{_a}.., rho_{n} in {>, >=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})))] if n in NaturalsPos.
# ...
