# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#transitivityGreaterGreaterEq">transitivityGreaterGreaterEq</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.ordering._theorems_ import transitivityGreaterGreaterEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr transitivityGreaterGreaterEq
# Out:
# Passed sanity check: built 'transitivityGreaterGreaterEq' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivityGreaterGreaterEq.latex())
# Out:
# \vdash \forall_{x, y, z~|~x > y, y \geq z}~\left(x > z\right)

# %%
# display the expression information
transitivityGreaterGreaterEq.exprInfo()
# Out:
# 0. forall_{x, y, z | x > y, y >= z} (x > z)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y, z) -> {x > z if x > y ,  y >= z.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 4. {x > z if x > y ,  y >= z.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x > z
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (x > y) and (y >= z)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x, z)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x > y, y >= z)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x > y
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. y >= z
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. >
#     core type: Literal
#     sub-expressions:
# ...
