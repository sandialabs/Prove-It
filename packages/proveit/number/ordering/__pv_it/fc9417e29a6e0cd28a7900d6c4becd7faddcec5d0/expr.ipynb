# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar, Variable
from proveit._common_ import rho
from proveit.logic import Equals, InSet, Set
from proveit.number import Greater, GreaterEq

# %%
# build up the expression from sub-expressions
expr = InSet(IndexedVar(rho, Variable("_a", latexFormat = r"{_{-}a}")), Set(Greater._operator_, GreaterEq._operator_, Equals._operator_))
# Out:
# expr: rho_{_a} in {>, >=, =}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \rho_{{_{-}a}} \in \left\{>, \geq, =\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. rho_{_a} in {>, >=, =}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (rho_{_a}, {>, >=, =})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. rho_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 4. {>, >=, =}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. rho
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
# 7. Set
#    core type: Literal
#    sub-expressions:
# 8. (>, >=, =)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 9. >
#    core type: Literal
#    sub-expressions:
# 10. >=
#     core type: Literal
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
