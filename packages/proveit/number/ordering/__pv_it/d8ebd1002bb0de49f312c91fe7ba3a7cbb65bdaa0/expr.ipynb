# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n, x
from proveit.core_expr_types._common_ import y_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.logic.set_theory._common_ import x_equals_any_y
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([x, y_1_to_n], InSet(x, Set(y_1_to_n)), condition = x_equals_any_y), domain = Naturals)
# Out:
# expr: forall_{n in Naturals} [forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{x, y_{1}, \ldots, y_{n}~|~\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right)}~\left(x \in \left\{y_{1}, \ldots, y_{n}\right\}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}}) if n in Naturals.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}}) if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, y_{1}, ..y_{_a}.., y_{n} | (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})} (x in {y_{1}, ..y_{_a}.., y_{n}})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x, y_{1}, ..y_{_a}.., y_{n}) -> {x in {y_{1}, ..y_{_a}.., y_{n}} if (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 26, 10
# 8. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 30, 22
# 9. {x in {y_{1}, ..y_{_a}.., y_{n}} if (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. x in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 30, 17
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 34
#     body: 23
# 22. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. x = y_{i}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> y_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. n
#     core type: Variable
#     sub-expressions:
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. y_{_a}
#     core type: IndexedVar
# variable: 33
# index: 32
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. y_{i}
#     core type: IndexedVar
# variable: 33
# index: 34
# 32. _a
#     core type: Variable
#     sub-expressions:
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. i
#     core type: Variable
#     sub-expressions:
