# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.number import LessEq, one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([Equals(LessEq._operator_, Equals._operator_)]), Len([ExprRange(k, k, one, one)]))
# Out:
# expr: |(<= = =)| = |(1, ..k.., 1)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\leq = =\right)| = |\left(1, \ldots, 1\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(<= = =)| = |(1, ..k.., 1)|
#    core type: Operation
#    operator: 15
#    operands: 1
# 1. (|(<= = =)|, |(1, ..k.., 1)|)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. |(<= = =)|
#    core type: Operation
#    operator: 5
#    operand: 7
# 3. |(1, ..k.., 1)|
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. ((<= = =))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((1, ..k.., 1))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (<= = =)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (1, ..k.., 1)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. <= = =
#    core type: Operation
#    operator: 15
#    operands: 11
# 10. 1, ..k.., 1
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 13
# 11. (<=, =)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
