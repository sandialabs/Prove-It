# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, c
from proveit.logic import And, InSet
from proveit.number import Add, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(GreaterEq(a, Add(b, c)), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), GreaterEq(a, b), GreaterEq(zero, c)))
# Out:
# expr: {a >= (b + c) if a in Reals ,  b in Reals ,  c in Reals ,  a >= b ,  0 >= c.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a \geq \left(b + c\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a \geq b ,  0 \geq c\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a >= (b + c) if a in Reals ,  b in Reals ,  c in Reals ,  a >= b ,  0 >= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a >= (b + c)
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a in Reals) and (b in Reals) and (c in Reals) and (a >= b) and (0 >= c)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b + c)
#    core type: ExprTuple
#    sub-expressions: 22, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Reals, b in Reals, c in Reals, a >= b, 0 >= c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 6. b + c
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. a in Reals
#    core type: Operation
#    operator: 16
#    operands: 14
# 8. b in Reals
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. c in Reals
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. a >= b
#     core type: Operation
#     operator: 19
#     operands: 18
# 11. 0 >= c
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (b, c)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 14. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 15. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 18. (a, b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. >=
#     core type: Literal
#     sub-expressions:
# 20. (0, c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
