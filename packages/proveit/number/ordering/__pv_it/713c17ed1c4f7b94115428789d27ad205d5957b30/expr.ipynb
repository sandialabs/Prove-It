# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.logic import InSet
from proveit.number import LessEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), LessEq(a, b), LessEq(c, zero))
# Out:
# expr: (a in Reals, b in Reals, c in Reals, a <= b, c <= 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}, a \leq b, c \leq 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals, b in Reals, c in Reals, a <= b, c <= 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. a in Reals
#    core type: Operation
#    operator: 8
#    operands: 6
# 2. b in Reals
#    core type: Operation
#    operator: 8
#    operands: 7
# 3. c in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. a <= b
#    core type: Operation
#    operator: 11
#    operands: 10
# 5. c <= 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 7. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (c, Reals)
#    core type: ExprTuple
#    sub-expressions: 16, 13
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Reals
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
