# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c, d
from proveit.logic import InSet
from proveit.number import GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(d, Reals), GreaterEq(a, b), GreaterEq(c, d))
# Out:
# expr: (a in Reals, b in Reals, c in Reals, d in Reals, a >= b, c >= d)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}, d \in \mathbb{R}, a \geq b, c \geq d\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals, b in Reals, c in Reals, d in Reals, a >= b, c >= d)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. a in Reals
#    core type: Operation
#    operator: 10
#    operands: 7
# 2. b in Reals
#    core type: Operation
#    operator: 10
#    operands: 8
# 3. c in Reals
#    core type: Operation
#    operator: 10
#    operands: 9
# 4. d in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 5. a >= b
#    core type: Operation
#    operator: 13
#    operands: 12
# 6. c >= d
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 8. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 9. (c, Reals)
#    core type: ExprTuple
#    sub-expressions: 18, 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (d, Reals)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. >=
#     core type: Literal
#     sub-expressions:
# 14. (c, d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Reals
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
