# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Operation
from proveit._common_ import i, rho, x
from proveit.number import Add, one, three

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, Operation(IndexedVar(rho, i), [IndexedVar(x, i), IndexedVar(x, Add(i, one))]), one, three)
# Out:
# expr: (x_{1} rho_{1} x_{1 + 1}), ..(x_{i} rho_{i} x_{i + 1}).., (x_{3} rho_{3} x_{3 + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} \rho_{1} x_{1 + 1}\right), \ldots, \left(x_{3} \rho_{3} x_{3 + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{1} rho_{1} x_{1 + 1}), ..(x_{i} rho_{i} x_{i + 1}).., (x_{3} rho_{3} x_{3 + 1})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 14
#    end_index: 2
# 1. i -> (x_{i} rho_{i} x_{i + 1})
#    core type: Lambda
#    parameter: 13
#    body: 3
# 2. 3
#    core type: Literal
#    sub-expressions:
# 3. x_{i} rho_{i} x_{i + 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. rho_{i}
#    core type: IndexedVar
# variable: 6
# index: 13
# 5. (x_{i}, x_{i + 1})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. rho
#    core type: Variable
#    sub-expressions:
# 7. x_{i}
#    core type: IndexedVar
# variable: 9
# index: 13
# 8. x_{i + 1}
#    core type: IndexedVar
# variable: 9
# index: 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. i + 1
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# ...
