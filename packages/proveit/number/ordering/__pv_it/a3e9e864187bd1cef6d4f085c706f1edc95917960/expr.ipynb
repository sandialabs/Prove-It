# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#relaxEqualToLessEq">relaxEqualToLessEq</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.ordering._theorems_ import relaxEqualToLessEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr relaxEqualToLessEq
# Out:
# Passed sanity check: built 'relaxEqualToLessEq' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(relaxEqualToLessEq.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}, y \in \mathbb{R}~|~x = y}~\left(x \leq y\right)

# %%
# display the expression information
relaxEqualToLessEq.exprInfo()
# Out:
# 0. forall_{x in Reals, y in Reals | x = y} (x <= y)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {x <= y if x in Reals ,  y in Reals ,  x = y.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {x <= y if x in Reals ,  y in Reals ,  x = y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x <= y
#    core type: Operation
#    operator: 6
#    operands: 16
# 5. (x in Reals) and (y in Reals) and (x = y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Reals, y in Reals, x = y)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 9. x in Reals
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. y in Reals
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. x = y
#     core type: Operation
#     operator: 15
# ...
