# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Operation, OperationSequence, Variable
from proveit._common_ import i, rho, x
from proveit.logic import And, Equals, Forall, Set
from proveit.number import Add, Less, LessEq, Reals, one, three

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(rho, i)
subExpr2 = IndexedVar(x, i)
subExpr3 = Add(three, one)
expr = Forall([ExprRange(Variable("_a", latexFormat = r"{_{-}a}"), IndexedVar(x, Variable("_a", latexFormat = r"{_{-}a}")), one, subExpr3)], Forall([ExprRange(Variable("_a", latexFormat = r"{_{-}a}"), IndexedVar(rho, Variable("_a", latexFormat = r"{_{-}a}")), one, three)], Equals(OperationSequence([ExprRange(i, subExpr1, one, three)], [ExprRange(i, subExpr2, one, three), IndexedVar(x, subExpr3)]), And(ExprRange(i, Operation(subExpr1, [subExpr2, IndexedVar(x, Add(i, one))]), one, three))), domain = Set(Less._operator_, LessEq._operator_, Equals._operator_)), domain = Reals)
# Out:
# expr: forall_{x_{1}, ..x_{_a}.., x_{3 + 1} in Reals} [forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x_{1}, \ldots, x_{3 + 1} \in \mathbb{R}}~\left[\forall_{\rho_{1}, \ldots, \rho_{3} \in \left\{<, \leq, =\right\}}~\left(\left(x_{1} \rho_{1} \ldots  x_{3} \rho_{3} x_{3 + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{3} \rho_{3} x_{3 + 1}\right)\right)\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x_{1}, ..x_{_a}.., x_{3 + 1} in Reals} [forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1})))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (x_{1}, ..x_{_a}.., x_{3 + 1}) -> {forall_{rho_{1}, ..rho_{_a}.., rho_{3} in {<, <=, =}} ((x_{1} rho_{1} ..x_{i}.. rho_{i} x_{3} rho_{3} x_{3 + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{3} rho_{3} x_{3 + 1}))) if (x_{1} in Reals) and ..(x_{_a} in Reals).. and (x_{3 + 1} in Reals).
#    core type: Lambda
#    parameter: 2
#    body: 3
# 2. x_{1}, ..x_{_a}.., x_{3 + 1}
#    core type: ExprRange
#    lambda_map: 34
#    start_index: 60
#    end_index: 35
# ...
