# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, c
from proveit.logic import And, InSet
from proveit.number import Add, Greater, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c], Conditional(Greater(Add(a, c), b), And(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), Greater(a, b), GreaterEq(c, zero))))
# Out:
# expr: (a, b, c) -> {(a + c) > b if a in Reals ,  b in Reals ,  c in Reals ,  a > b ,  c >= 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(a + c\right) > b \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  c \in \mathbb{R} ,  a > b ,  c \geq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b, c) -> {(a + c) > b if a in Reals ,  b in Reals ,  c in Reals ,  a > b ,  c >= 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 25, 26, 27
# 2. {(a + c) > b if a in Reals ,  b in Reals ,  c in Reals ,  a > b ,  c >= 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a + c) > b
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. (a in Reals) and (b in Reals) and (c in Reals) and (a > b) and (c >= 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a + c, b)
#    core type: ExprTuple
#    sub-expressions: 8, 26
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Reals, b in Reals, c in Reals, a > b, c >= 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13
# 8. a + c
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. a in Reals
#    core type: Operation
#    operator: 18
#    operands: 16
# 10. b in Reals
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. c in Reals
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. a > b
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. c >= 0
#     core type: Operation
#     operator: 22
#     operands: 23
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (a, c)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 16. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 17. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (c, Reals)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 20. >
#     core type: Literal
#     sub-expressions:
# 21. (a, b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. >=
#     core type: Literal
#     sub-expressions:
# 23. (c, 0)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. Reals
#     core type: Literal
#     sub-expressions:
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. 0
#     core type: Literal
#     sub-expressions:
