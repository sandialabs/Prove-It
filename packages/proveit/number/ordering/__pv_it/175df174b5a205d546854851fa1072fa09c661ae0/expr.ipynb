# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Booleans, Equals, InSet, Or
from proveit.number import Less

# %%
# build up the expression from sub-expressions
expr = InSet(Or(Less(x, y), Equals(x, y)), Booleans)
# Out:
# expr: ((x < y) or (x = y)) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x < y\right) \lor \left(x = y\right)\right) \in \mathbb{B}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((x < y) or (x = y)) in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((x < y) or (x = y), BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (x < y) or (x = y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x < y, x = y)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x < y
#    core type: Operation
#    operator: 9
#    operands: 11
# 8. x = y
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. <
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x, y)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
