# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Operation, OperationSequence, Variable
from proveit._common_ import i, n, rho, x
from proveit.logic import And, Equals, InSet, Set
from proveit.number import Add, Greater, GreaterEq, one
from proveit.number.ordering._common_ import n_plus_1

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(rho, i)
subExpr3 = IndexedVar(x, i)
expr = Conditional(Equals(OperationSequence([ExprRange(i, subExpr2, one, n)], [ExprRange(i, subExpr3, one, n), IndexedVar(x, n_plus_1)]), And(ExprRange(i, Operation(subExpr2, [subExpr3, IndexedVar(x, Add(i, one))]), one, n))), And(ExprRange(subExpr1, InSet(IndexedVar(rho, subExpr1), Set(Greater._operator_, GreaterEq._operator_, Equals._operator_)), one, n)))
# Out:
# expr: {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x_{1} \rho_{1} \ldots  x_{n} \rho_{n} x_{n + 1}\right) = \left(\left(x_{1} \rho_{1} x_{1 + 1}\right) \land \ldots \land \left(x_{n} \rho_{n} x_{n + 1}\right)\right) \textrm{ if } \left(\rho_{1} \in \left\{>, \geq, =\right\}\right) \land \ldots \land \left(\rho_{n} \in \left\{>, \geq, =\right\}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})) if (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}) = ((x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))
#    core type: Operation
#    operator: 39
#    operands: 3
# 2. (rho_{1} in {>, >=, =}) and ..(rho_{_a} in {>, >=, =}).. and (rho_{n} in {>, >=, =})
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}, (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (rho_{1} in {>, >=, =}, ..rho_{_a} in {>, >=, =}.., rho_{n} in {>, >=, =})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. x_{1} rho_{1} ..x_{i}.. rho_{i} x_{n} rho_{n} x_{n + 1}
#    core type: Operation
#    operators: 8
#    operands: 9
# 6. (x_{1} rho_{1} x_{1 + 1}) and ..(x_{i} rho_{i} x_{i + 1}).. and (x_{n} rho_{n} x_{n + 1})
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (rho_{1} in {>, >=, =}), ..(rho_{_a} in {>, >=, =}).., (rho_{n} in {>, >=, =})
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 45
#    end_index: 28
# 8. (rho_{1}, ..rho_{i}.., rho_{n})
#    core type: ExprTuple
#    sub-expressions: 13
# 9. (x_{1}, ..x_{i}.., x_{n}, x_{n + 1})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x_{1} rho_{1} x_{1 + 1}, ..x_{i} rho_{i} x_{i + 1}.., x_{n} rho_{n} x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 16
# 12. _a -> (rho_{_a} in {>, >=, =})
#     core type: Lambda
#     parameter: 31
#     body: 17
# 13. rho_{1}, ..rho_{i}.., rho_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 45
#     end_index: 28
# 14. x_{1}, ..x_{i}.., x_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 45
#     end_index: 28
# 15. x_{n + 1}
#     core type: IndexedVar
# variable: 40
# index: 20
# 16. (x_{1} rho_{1} x_{1 + 1}), ..(x_{i} rho_{i} x_{i + 1}).., (x_{n} rho_{n} x_{n + 1})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 45
#     end_index: 28
# 17. rho_{_a} in {>, >=, =}
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. i -> rho_{i}
#     core type: Lambda
#     parameter: 44
#     body: 29
# 19. i -> x_{i}
#     core type: Lambda
#     parameter: 44
#     body: 35
# 20. n + 1
#     core type: Operation
#     operator: 42
#     operands: 24
# 21. i -> (x_{i} rho_{i} x_{i + 1})
#     core type: Lambda
#     parameter: 44
#     body: 25
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (rho_{_a}, {>, >=, =})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 45
# 25. x_{i} rho_{i} x_{i + 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. rho_{_a}
#     core type: IndexedVar
# variable: 34
# index: 31
# 27. {>, >=, =}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. rho_{i}
#     core type: IndexedVar
# variable: 34
# index: 44
# 30. (x_{i}, x_{i + 1})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. Set
#     core type: Literal
#     sub-expressions:
# 33. (>, >=, =)
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 34. rho
#     core type: Variable
#     sub-expressions:
# 35. x_{i}
#     core type: IndexedVar
# variable: 40
# index: 44
# 36. x_{i + 1}
#     core type: IndexedVar
# variable: 40
# index: 41
# 37. >
#     core type: Literal
#     sub-expressions:
# 38. >=
#     core type: Literal
#     sub-expressions:
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. i + 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. 1
#     core type: Literal
#     sub-expressions:
