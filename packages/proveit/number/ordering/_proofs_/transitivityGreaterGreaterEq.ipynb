# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../_context_.ipynb">ordering</a>.<a class="ProveItLink" href="../_theorems_.ipynb#transitivityGreaterGreaterEq">transitivityGreaterGreaterEq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, y, z
from proveit.logic import Equals
from proveit.number import Greater
from proveit.number.ordering._axioms_ import greaterEqDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving transitivityGreaterGreaterEq presuming [proveit.logic]
# Out:
# Beginning proof of transitivityGreaterGreaterEq
# Recorded 'presuming' information
# Presuming theorems in proveit.logic (except any that presume this theorem).
# Presuming previous theorems (applied transitively).
# transitivityGreaterGreaterEq: forall_{x, y, z | x > y, y >= z} (x > z)

# %%
defaults.assumptions = transitivityGreaterGreaterEq.allConditions()
# Out:
# defaults.assumptions: (x > y, y >= z)

# %%
specGED = greaterEqDef.specialize({x:y, y:z})
# Out:
# specGED: |- (y >= z) = ((y > z) or (y = z))

# %%
specGED.deriveRightViaEquivalence()
# Out:
# {y >= z} |- (y > z) or (y = z)

# %%
yeqZ = Greater(x,z).prove(assumptions = [Equals(y,z), Greater(x,y)])
# Out:
# yeqZ: {x > y, y = z} |- x > z

# %%
ylessZ = Greater(x,z).prove(assumptions = [Greater(y,z), Greater(x,y)])
# Out:
# ylessZ: {x > y, y > z} |- x > z

# %%
specGED.rhs.deriveViaDilemma(Greater(x,z))
# Out:
# {y >= z, x > y} |- x > z

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x, y, z | x > y, y >= z} (x > z)
# 1	instantiation	2, 3, 4, 14, 5, 6	{y >= z, x > y} |- x > z
# 	A : y > z, B : y = z, C : x > z
# 2	theorem		|- forall_{A in BOOLEANS, B in BOOLEANS | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.boolean.disjunction.singularConstructiveDilemma
# 3	instantiation	7, 9	{y >= z} |- (y > z) in BOOLEANS
# 	A : y > z, B : y = z
# 4	instantiation	8, 9	{y >= z} |- (y = z) in BOOLEANS
# 	A : y > z, B : y = z
# 5	hypothetical reasoning	10	{x > y} |- (y > z) => (x > z)
# 6	hypothetical reasoning	11	{x > y} |- (y = z) => (x > z)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)
# 	proveit.logic.boolean.disjunction.leftInBool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEANS} (B in BOOLEANS)
# 	proveit.logic.boolean.disjunction.rightInBool
# 9	instantiation	12, 13, 14	{y >= z} |- ((y > z) or (y = z)) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : (y > z) or (y = z)
# 10	instantiation	15, 18, 16	{x > y, y > z} |- x > z
# 	x : x, y : y, z : z
# 11	instantiation	17, 18, 19	{x > y, y = z} |- x > z
# 	P(_a) : x > _a, x : y, y : z
# 12	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substituteTruth
# 13	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 14	instantiation	20, 21, 22	{y >= z} |- (y > z) or (y = z)
# 	P : y >= z, Q : (y > z) or (y = z)
# 15	theorem		|- forall_{x, y, z | x > y, y > z} (x > z)
# 	proveit.number.ordering.transitivityGreaterGreater
# 16	assumption		{y > z} |- y > z
# 17	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.subRightSideInto
# 18	assumption		{x > y} |- x > y
# 19	assumption		{y = z} |- y = z
# 20	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhsViaEquivalence
# 21	assumption		{y >= z} |- y >= z
# 22	instantiation	23	|- (y >= z) = ((y > z) or (y = z))
# 	x : y, y : z
# 23	axiom		|- forall_{x, y} ((x >= y) = ((x > y) or (x = y)))
# 	proveit.number.ordering.greaterEqDef
