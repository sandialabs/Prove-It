# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">ordering</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#transitivityGreaterEqGreaterEq">transitivityGreaterEqGreaterEq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, y, z
from proveit.logic import Equals
from proveit.number import GreaterEq, Greater
from proveit.number.ordering._axioms_ import greaterEqDef
from proveit.number.ordering._theorems_ import transitivityGreaterGreaterEq
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivityGreaterEqGreaterEq

# %%
defaults.assumptions = transitivityGreaterEqGreaterEq.allConditions()

# %%
greaterEqDef

# %%
x_geq_y__expanded = greaterEqDef.instantiate({x:x, y:y}).deriveRightViaEquality()

# %%
x_greater_y, x_eq_y = x_geq_y__expanded.operands

# %%
transitivityGreaterGreaterEq

# %%
transitivityGreaterGreaterEq.instantiate({x:x, y:y, z:z}, assumptions = defaults.assumptions+(x_greater_y,))

# %%
x_eq_y.subLeftSideInto(GreaterEq(y, z), assumptions = defaults.assumptions+(x_eq_y,))

# %%
x_geq_y__expanded.deriveViaDilemma(GreaterEq(x, z))

# %%
# %qed
