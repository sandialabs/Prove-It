# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../_theory_.ipynb">decimal</a>.<a class="ProveItLink" href="../_theorems_.ipynb#nat2">nat2</a> theorem
# ========

# %%
import proveit
from proveit._common_ import n
from proveit.number import zero, one, two, Add
from proveit.number.numeral.deci._axioms_ import twoDef
from proveit.number.sets.natural._axioms_ import zero_in_nats, successor_in_nats
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nat2

# %%
twoDef

# %%
successor_in_nats

# %%
one_plus_one__in__nats = successor_in_nats.instantiate({n:one})

# %%
twoDef.subLeftSideInto(one_plus_one__in__nats)

# %%
# %qed
