# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">numeral</a>.<a class="ProveItLink" href="../_context_.ipynb">deci</a>.<a class="ProveItLink" href="../_theorems_.ipynb#tuple_len_6_typical_equiv">tuple_len_6_typical_equiv</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving tuple_len_6_typical_equiv presuming []
# Out:
# Beginning proof of tuple_len_6_typical_equiv
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# tuple_len_6_typical_equiv: forall_{a, b, c, d, e, f} (|(a, b, c, d, e, f)| = |(1, ..k.., 6)|)
