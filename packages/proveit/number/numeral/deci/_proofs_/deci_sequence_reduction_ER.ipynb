# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">numeral</a>.<a class="ProveItLink" href="../_context_.ipynb">deci</a>.<a class="ProveItLink" href="../_theorems_.ipynb#deci_sequence_reduction_ER">deci_sequence_reduction_ER</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.number.numeral import DecimalSequence
defaults.disabled_auto_reduction_types.add(DecimalSequence)
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving deci_sequence_reduction_ER presuming [proveit.logic, proveit.number, proveit.core_expr_types]

# %%
defaults.assumptions = deci_sequence_reduction_ER.allConditions()

# %%
equality = defaults.assumptions[-1]

# %%
lhs = deci_sequence_reduction_ER.instanceExpr.instanceExpr.lhs

# %%
rhs = deci_sequence_reduction_ER.instanceExpr.instanceExpr.rhs

# %%
equality.substitution(lhs.innerExpr().operands[1:2])

# %%
# %qed
