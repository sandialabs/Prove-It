# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../../_context_.ipynb">numeral</a>.<a class="ProveItLink" href="../_context_.ipynb">deci</a>.<a class="ProveItLink" href="../_theorems_.ipynb#count_to_8_range">count_to_8_range</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving count_to_8_range presuming []
# Out:
# Beginning proof of count_to_8_range
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# count_to_8_range: (1, 2, 3, 4, 5, 6, 7, 8) = (1, ..k.., 8)
