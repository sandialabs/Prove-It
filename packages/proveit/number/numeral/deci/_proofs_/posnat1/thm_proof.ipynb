# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../_theory_.ipynb">decimal</a>.<a class="ProveItLink" href="../_theorems_.ipynb#posnat1">posnat1</a> theorem
# ========

# %%
import proveit
from proveit._common_ import n
from proveit.number import zero, one, Greater
from proveit.number import Naturals, NaturalsPos
from proveit.number.sets.natural._axioms_ import naturalsPosDef
from proveit.logic import InSet
theory = proveit.Theory() # the theorem's theory

# %%
# %proving posnat1

# %%
naturalsPosDef

# %%
oneInNaturals = InSet(one, Naturals).prove()

# %%
oneInNaturals.proof()

# %%
Greater(one, zero)

# %%
# natPosInduction

# %%
# natPosInduction_spec = natPosInduction.instantiate()
