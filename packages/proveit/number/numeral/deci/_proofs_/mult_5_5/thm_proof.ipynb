# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../../_theory_.ipynb">deci</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#mult_5_5">mult_5_5</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving mult_5_5
