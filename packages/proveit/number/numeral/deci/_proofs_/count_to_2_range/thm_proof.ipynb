# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../_theory_.ipynb">deci</a>.<a class="ProveItLink" href="../_theorems_.ipynb#count_to_2_range">count_to_2_range</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving count_to_2_range
