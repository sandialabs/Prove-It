# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../../_theory_.ipynb">deci</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len_1">tuple_len_1</a> theorem
# ========

# %%
import proveit
from proveit import varRange, ExprTuple
from proveit._common_ import a, b, i
from proveit.core_expr_types.tuples._axioms_ import tuple_len_incr, tuple_len_0
from proveit.logic import InSet
from proveit.number import Natural, zero, one
from proveit.number. numeral.deci._theorems_ import md_nine_add_one
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tuple_len_1

# %%
tuple_len_incr

# %%
tuple_len_0

# %%
tuple_len_0.rhs

# %%
# tuple_len_incr.instantiate({i: tuple_len_0.rhs, ExprTuple(varRange(a, one, zero)):tuple_len_0.lhs.operands[0], b:a}, 
#                           assumptions=[InSet(zero, Natural)])

# %%
# %qed
