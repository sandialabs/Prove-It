# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../_theory_.ipynb">decimal</a>.<a class="ProveItLink" href="../_theorems_.ipynb#add_8_9">add_8_9</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving add_8_9
