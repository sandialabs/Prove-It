# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">number</a>.<a class="ProveItLink" href="../../_theory_.ipynb">numeral</a>.<a class="ProveItLink" href="../_theory_.ipynb">deci</a>.<a class="ProveItLink" href="../_theorems_.ipynb#tuple_len_3">tuple_len_3</a> theorem
# ========

# %%
import proveit
from proveit._common_ import a, b, c, i
from proveit.core_expr_types.tuples._axioms_ import tuple_len_incr
from proveit.number. numeral.deci._theorems_ import tuple_len_2, add_2_1
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tuple_len_3

# %%
one_spec = tuple_len_2.instantiate({a:a})

# %%
tuple_spec = tuple_len_incr.instantiate({i: one_spec.rhs, a: one_spec.lhs.operands[0], b: c})

# %%
spec = tuple_spec.applyTransitivity(add_2_1)

# %%
# %qed
