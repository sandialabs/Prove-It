# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>.<a class="ProveItLink" href="../../_axioms_.ipynb#sevenDef">sevenDef</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.numeral.deci._axioms_ import sevenDef

# %%
# %dependencies sevenDef
# Out:
# <h3>No theorems depend upon sevenDef</h3>
