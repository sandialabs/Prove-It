# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, b, c, d, e, k
from proveit.core_expr_types import Len
from proveit.number import five, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a, b, c, d, e]), Len([ExprRange(k, k, one, five)]))
# Out:
# expr: (|(a, b, c, d, e)|, |(1, ..k.., 5)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a, b, c, d, e\right)|, |\left(1, \ldots, 5\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a, b, c, d, e)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a, b, c, d, e)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a, b, c, d, e))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 7. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 13
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. d
#     core type: Variable
#     sub-expressions:
# 12. e
#     core type: Variable
#     sub-expressions:
# 13. 1, ..k.., 5
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 5
#     core type: Literal
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
