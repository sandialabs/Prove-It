# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#add_5_0">add_5_0</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import add_5_0

# %%
# check that the built expression is the same as the stored expression
# %check_expr add_5_0
# Out:
# Passed sanity check: built 'add_5_0' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_5_0.latex())
# Out:
# \vdash \left(5 + 0\right) = 5

# %%
# display the expression information
add_5_0.exprInfo()
# Out:
# 0. (5 + 0) = 5
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (5 + 0, 5)
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. 5 + 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (5, 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 5
#    core type: Literal
#    sub-expressions:
# 7. 0
#    core type: Literal
#    sub-expressions:
