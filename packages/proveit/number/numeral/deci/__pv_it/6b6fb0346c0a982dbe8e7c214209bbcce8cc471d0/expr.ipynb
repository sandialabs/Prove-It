# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#add_5_7">add_5_7</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import add_5_7

# %%
# check that the built expression is the same as the stored expression
# %check_expr add_5_7
# Out:
# Passed sanity check: built 'add_5_7' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(add_5_7.latex())
# Out:
# \vdash \left(5 + 7\right) = 12

# %%
# display the expression information
add_5_7.exprInfo()
# Out:
# 0. (5 + 7) = 12
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (5 + 7, 12)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 5 + 7
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 12
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (5, 7)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. 5
#    core type: Literal
#    sub-expressions:
# 10. 7
#     core type: Literal
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
