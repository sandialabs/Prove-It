# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#mult_7_6">mult_7_6</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import mult_7_6

# %%
# check that the built expression is the same as the stored expression
# %check_expr mult_7_6
# Out:
# Passed sanity check: built 'mult_7_6' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_7_6.latex())
# Out:
# \vdash \left(7 \cdot 6\right) = 42

# %%
# display the expression information
mult_7_6.exprInfo()
# Out:
# 0. (7 * 6) = 42
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (7 * 6, 42)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 7 * 6
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 42
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (7, 6)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (4, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. 7
#    core type: Literal
#    sub-expressions:
# 10. 6
#     core type: Literal
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
