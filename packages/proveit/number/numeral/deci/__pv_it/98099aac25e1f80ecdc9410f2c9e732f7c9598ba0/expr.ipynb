# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len_8">tuple_len_8</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import tuple_len_8

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_len_8
# Out:
# Passed sanity check: built 'tuple_len_8' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_8.latex())
# Out:
# \vdash \forall_{a, b, c, d, e, f, g, h}~\left(|\left(a, b, c, d, e, f, g, h\right)| = 8\right)

# %%
# display the expression information
tuple_len_8.exprInfo()
# Out:
# 0. forall_{a, b, c, d, e, f, g, h} (|(a, b, c, d, e, f, g, h)| = 8)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d, e, f, g, h) -> (|(a, b, c, d, e, f, g, h)| = 8)
#    core type: Lambda
#    parameters: 10\n   body: 3
# 3. |(a, b, c, d, e, f, g, h)| = 8
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|(a, b, c, d, e, f, g, h)|, 8)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. |(a, b, c, d, e, f, g, h)|
#    core type: Operation
#    operator: 8
#    operand: 10
# 7. 8
#    core type: Literal
#    sub-expressions:
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((a, b, c, d, e, f, g, h))
#    core type: ExprTuple
#    sub-expressions: 10
# 10. (a, b, c, d, e, f, g, h)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13, 14, 15, 16, 17, 18
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. g
#     core type: Variable
#     sub-expressions:
# 18. h
#     core type: Variable
#     sub-expressions:
