# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#mult_6_6">mult_6_6</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import mult_6_6

# %%
# check that the built expression is the same as the stored expression
# %check_expr mult_6_6
# Out:
# Passed sanity check: built 'mult_6_6' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_6_6.latex())
# Out:
# \vdash \left(6 \cdot 6\right) = 36

# %%
# display the expression information
mult_6_6.exprInfo()
# Out:
# 0. (6 * 6) = 36
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (6 * 6, 36)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 6 * 6
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 36
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (6, 6)
#    core type: ExprTuple
#    sub-expressions: 10, 10
# 7. Decimal
#    core type: Literal
#    sub-expressions:
# 8. (3, 6)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 6
#     core type: Literal
#     sub-expressions:
