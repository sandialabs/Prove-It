# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#count_to_5_range">count_to_5_range</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import count_to_5_range

# %%
# check that the built expression is the same as the stored expression
# %check_expr count_to_5_range
# Out:
# Passed sanity check: built 'count_to_5_range' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(count_to_5_range.latex())
# Out:
# \vdash \left(1, 2, 3, 4, 5\right) = \left(1, \ldots, 5\right)

# %%
# display the expression information
count_to_5_range.exprInfo()
# Out:
# 0. (1, 2, 3, 4, 5) = (1, ..k.., 5)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1, 2, 3, 4, 5), (1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1, 2, 3, 4, 5)
#    core type: ExprTuple
#    sub-expressions: 10, 5, 6, 7, 11
# 4. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 8
# 5. 2
#    core type: Literal
#    sub-expressions:
# 6. 3
#    core type: Literal
#    sub-expressions:
# 7. 4
#    core type: Literal
#    sub-expressions:
# 8. 1, ..k.., 5
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. k -> k
#    core type: Lambda
#    parameter: 12
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. 5
#     core type: Literal
#     sub-expressions:
# 12. k
#     core type: Variable
#     sub-expressions:
