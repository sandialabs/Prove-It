# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#less_2_3">less_2_3</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Less.html">Less</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import less_2_3

# %%
# check that the built expression is the same as the stored expression
# %check_expr less_2_3
# Out:
# Passed sanity check: built 'less_2_3' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(less_2_3.latex())
# Out:
# \vdash 2 < 3

# %%
# display the expression information
less_2_3.exprInfo()
# Out:
# 0. 2 < 3
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <
#    core type: Literal
#    sub-expressions:
# 2. (2, 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2
#    core type: Literal
#    sub-expressions:
# 4. 3
#    core type: Literal
#    sub-expressions:
