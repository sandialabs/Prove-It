# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len_5_typical_equiv">tuple_len_5_typical_equiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.numeral.deci._theorems_ import tuple_len_5_typical_equiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_len_5_typical_equiv
# Out:
# Passed sanity check: built 'tuple_len_5_typical_equiv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_5_typical_equiv.latex())
# Out:
# \vdash \forall_{a, b, c, d, e}~\left(|\left(a, b, c, d, e\right)| = |\left(1, \ldots, 5\right)|\right)

# %%
# display the expression information
tuple_len_5_typical_equiv.exprInfo()
# Out:
# 0. forall_{a, b, c, d, e} (|(a, b, c, d, e)| = |(1, ..k.., 5)|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d, e) -> (|(a, b, c, d, e)| = |(1, ..k.., 5)|)
#    core type: Lambda
#    parameters: 11\n   body: 3
# 3. |(a, b, c, d, e)| = |(1, ..k.., 5)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|(a, b, c, d, e)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. |(a, b, c, d, e)|
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. ((a, b, c, d, e))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. ((1, ..k.., 5))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (a, b, c, d, e)
#     core type: ExprTuple
# ...
