# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len_7_typical_equiv">tuple_len_7_typical_equiv</a>
# ***see <a class="ProveItLink" href="../../_proofs_/tuple_len_7_typical_equiv.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.numeral.deci._theorems_ import tuple_len_7_typical_equiv

# %%
# %dependencies tuple_len_7_typical_equiv
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems depend upon tuple_len_7_typical_equiv</h3>
