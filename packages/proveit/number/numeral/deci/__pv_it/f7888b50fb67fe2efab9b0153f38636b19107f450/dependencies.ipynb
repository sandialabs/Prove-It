# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len_2_typical_equiv">tuple_len_2_typical_equiv</a>
# ***see <a class="ProveItLink" href="../../_proofs_/tuple_len_2_typical_equiv.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.number.numeral.deci._theorems_ import tuple_len_2_typical_equiv

# %%
# %dependencies tuple_len_2_typical_equiv
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems that depend directly on tuple_len_2_typical_equiv</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../logic/boolean/conjunction/_proofs_/nandIfNotRight.ipynb">proveit.logic.boolean.conjunction.nandIfNotRight</a></dt><dd><a class="ProveItLink" href="../../../../../logic/boolean/conjunction/__pv_it/58940e15458f3da6ff43c8e15e3de78f3e24b2a80/expr.ipynb"><img src="../../../../../logic/boolean/conjunction/__pv_it/58940e15458f3da6ff43c8e15e3de78f3e24b2a80/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
