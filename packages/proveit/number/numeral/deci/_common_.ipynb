# %% [markdown]
# Common expressions for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.numeral.decimal</a>
# ========

# %%
import proveit
# Automation is not needed when only building common expressions:
proveit.defaults.automation = False # This will speed things up.
# the context is in the current directory:
from deci import DecimalSet
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin common
# Out:
# Defining common sub-expressions for context 'proveit.number.numeral.deci'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
Digits = DecimalSet()
# Out:
# Digits: Digits

# %%
# %end common
# Out:
# Common expressions may be imported from autogenerated _common_.py
