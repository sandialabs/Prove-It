# %% [markdown]
# Common expressions for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.numeral.hexidecimal</a>
# ========

# %%
import proveit
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin common

# %%
# %end common
