# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Exp, Greater, Reals, RealsPos, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Exp(a, b), RealsPos), And(InSet(a, Reals), InSet(b, Reals), Greater(a, zero)))
# Out:
# expr: {a^{b} in RealsPos if a in Reals ,  b in Reals ,  a > 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a^{b} \in \mathbb{R}^+ \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  a > 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a^{b} in RealsPos if a in Reals ,  b in Reals ,  a > 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a^{b} in RealsPos
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (a in Reals) and (b in Reals) and (a > 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a^{b}, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Reals, b in Reals, a > 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. a^{b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. RealsPos
#    core type: Literal
#    sub-expressions:
# 8. a in Reals
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. b in Reals
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. a > 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 13. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. >
#     core type: Literal
#     sub-expressions:
# 17. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. Reals
#     core type: Literal
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. 0
#     core type: Literal
#     sub-expressions:
