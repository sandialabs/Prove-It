# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Complexes, Exp, Integers, Mult, Neg, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a, b], Equals(Exp(Exp(a, Neg(b)), Neg(n)), Exp(a, Mult(b, n))), domains = [Complexes, Complexes], condition = NotEquals(a, zero)), InSet(n, Integers)))
# Out:
# expr: n -> {forall_{a in Complexes, b in Complexes | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a \in \mathbb{C}, b \in \mathbb{C}~|~a \neq 0}~\left((a^{-b})^{-n} = a^{b \cdot n}\right) \textrm{ if } n \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{a in Complexes, b in Complexes | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integers.
#    core type: Lambda
#    parameter: 39
#    body: 1
# 1. {forall_{a in Complexes, b in Complexes | a != 0} ((a^{-b})^{-n} = a^{b * n}) if n in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a in Complexes, b in Complexes | a != 0} ((a^{-b})^{-n} = a^{b * n})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Integers
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a, b) -> {(a^{-b})^{-n} = a^{b * n} if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, Integers)
#    core type: ExprTuple
#    sub-expressions: 39, 9
# 7. (a, b)
#    core type: ExprTuple
#    sub-expressions: 37, 41
# 8. {(a^{-b})^{-n} = a^{b * n} if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Integers
#    core type: Literal
#    sub-expressions:
# 10. (a^{-b})^{-n} = a^{b * n}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a in Complexes) and (b in Complexes) and (a != 0)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. ((a^{-b})^{-n}, a^{b * n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a in Complexes, b in Complexes, a != 0)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 16. (a^{-b})^{-n}
#     core type: Operation
#     operator: 33
#     operands: 21
# 17. a^{b * n}
#     core type: Operation
#     operator: 33
#     operands: 22
# 18. a in Complexes
#     core type: Operation
#     operator: 24
#     operands: 23
# 19. b in Complexes
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. a != 0
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. (a^{-b}, -n)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 22. (a, b * n)
#     core type: ExprTuple
#     sub-expressions: 37, 30
# 23. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 37, 31
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 41, 31
# 26. !=
#     core type: Literal
#     sub-expressions:
# 27. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 37, 32
# 28. a^{-b}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. -n
#     core type: Operation
#     operator: 40
#     operand: 39
# 30. b * n
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. Complexes
#     core type: Literal
#     sub-expressions:
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (a, -b)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (b, n)
#     core type: ExprTuple
#     sub-expressions: 41, 39
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. -b
#     core type: Operation
#     operator: 40
#     operand: 41
# 39. n
#     core type: Variable
#     sub-expressions:
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. b
#     core type: Variable
#     sub-expressions:
