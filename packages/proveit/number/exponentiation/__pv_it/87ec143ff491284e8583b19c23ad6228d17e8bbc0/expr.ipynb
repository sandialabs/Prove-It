# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Add, Complexes, Exp, Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(a, Exp(a, b)), Exp(a, Add(one, b))), And(InSet(a, Complexes), InSet(b, Complexes), NotEquals(a, zero)))
# Out:
# expr: {(a * a^{b}) = a^{1 + b} if a in Complexes ,  b in Complexes ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \cdot a^{b}\right) = a^{1 + b} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  a \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a * a^{b}) = a^{1 + b} if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a * a^{b}) = a^{1 + b}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complexes) and (b in Complexes) and (a != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a * a^{b}, a^{1 + b})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Complexes, b in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. a * a^{b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a^{1 + b}
#    core type: Operation
#    operator: 24
#    operands: 14
# 9. a in Complexes
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. b in Complexes
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. a != 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a, a^{b})
#     core type: ExprTuple
#     sub-expressions: 28, 20
# 14. (a, 1 + b)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 15. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 28, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 23
# 20. a^{b}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. 1 + b
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. Complexes
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (a, b)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (1, b)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
