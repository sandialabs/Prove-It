# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Abs, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Reals), InSet(b, Reals), LessEq(Abs(a), b))
# Out:
# expr: (a in Reals) and (b in Reals) and (|a| <= b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}\right) \land \left(b \in \mathbb{R}\right) \land \left(\left|a\right| \leq b\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals) and (b in Reals) and (|a| <= b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Reals, b in Reals, |a| <= b)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a in Reals
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. b in Reals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. |a| <= b
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. <=
#    core type: Literal
#    sub-expressions:
# 10. (|a|, b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Reals
#     core type: Literal
#     sub-expressions:
# 12. |a|
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. Abs
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
