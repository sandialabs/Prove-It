# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#expOfPositivesProdRev">expOfPositivesProdRev</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import expOfPositivesProdRev

# %%
# check that the built expression is the same as the stored expression
# %check_expr expOfPositivesProdRev
# Out:
# Passed sanity check: built 'expOfPositivesProdRev' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expOfPositivesProdRev.latex())
# Out:
# \vdash \forall_{c \in \mathbb{C}}~\left[\forall_{a \in \mathbb{R}^+, b \in \mathbb{R}^+}~\left(\left(a^{c} \cdot b^{c}\right) = \left(a \cdot b\right)^{c}\right)\right]

# %%
# display the expression information
expOfPositivesProdRev.exprInfo()
# Out:
# 0. forall_{c in Complexes} [forall_{a in RealsPos, b in RealsPos} ((a^{c} * b^{c}) = (a * b)^{c})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. c -> {forall_{a in RealsPos, b in RealsPos} ((a^{c} * b^{c}) = (a * b)^{c}) if c in Complexes.
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. {forall_{a in RealsPos, b in RealsPos} ((a^{c} * b^{c}) = (a * b)^{c}) if c in Complexes.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a in RealsPos, b in RealsPos} ((a^{c} * b^{c}) = (a * b)^{c})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. c in Complexes
#    core type: Operation
#    operator: 23
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a, b) -> {(a^{c} * b^{c}) = (a * b)^{c} if a in RealsPos ,  b in RealsPos.
#    core type: Lambda
#    parameters: 33\n   body: 8
# 7. (c, Complexes)
#    core type: ExprTuple
#    sub-expressions: 34, 9
# ...
