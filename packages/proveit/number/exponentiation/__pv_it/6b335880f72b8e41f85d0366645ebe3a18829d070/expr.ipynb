# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, c
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Add, Complexes, Exp, Mult, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, c], Conditional(Equals(Mult(Exp(a, b), Exp(a, c)), Exp(a, Add(b, c))), And(InSet(a, Complexes), InSet(b, Complexes), InSet(c, Complexes), NotEquals(a, zero))))
# Out:
# expr: (a, b, c) -> {(a^{b} * a^{c}) = a^{b + c} if a in Complexes ,  b in Complexes ,  c in Complexes ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(a^{b} \cdot a^{c}\right) = a^{b + c} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  c \in \mathbb{C} ,  a \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b, c) -> {(a^{b} * a^{c}) = a^{b + c} if a in Complexes ,  b in Complexes ,  c in Complexes ,  a != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 34, 35, 36
# 2. {(a^{b} * a^{c}) = a^{b + c} if a in Complexes ,  b in Complexes ,  c in Complexes ,  a != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a^{b} * a^{c}) = a^{b + c}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complexes) and (b in Complexes) and (c in Complexes) and (a != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a^{b} * a^{c}, a^{b + c})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complexes, b in Complexes, c in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. a^{b} * a^{c}
#    core type: Operation
# ...
