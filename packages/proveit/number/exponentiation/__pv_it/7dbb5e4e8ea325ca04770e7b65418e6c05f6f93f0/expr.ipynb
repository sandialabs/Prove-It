# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Booleans, InSet, NotEquals, Set
from proveit.number import Greater, GreaterEq, zero

# %%
# build up the expression from sub-expressions
expr = Set(InSet(Greater(x, zero), Booleans), GreaterEq(x, zero), NotEquals(y, zero))
# Out:
# expr: {(x > 0) in BOOLEANS, x >= 0, y != 0}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x > 0\right) \in \mathbb{B}, x \geq 0, y \neq 0\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(x > 0) in BOOLEANS, x >= 0, y != 0}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ((x > 0) in BOOLEANS, x >= 0, y != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. (x > 0) in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. x >= 0
#    core type: Operation
#    operator: 8
#    operands: 15
# 5. y != 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x > 0, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. >=
#    core type: Literal
#    sub-expressions:
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. (y, 0)
#     core type: ExprTuple
#     sub-expressions: 13, 17
# 11. x > 0
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. >
#     core type: Literal
#     sub-expressions:
# 15. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
