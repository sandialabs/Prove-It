# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Add, Complexes, Exp, Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Mult(a, Exp(a, b)), Exp(a, Add(one, b))), And(InSet(a, Complexes), InSet(b, Complexes), NotEquals(a, zero))))
# Out:
# expr: (a, b) -> {(a * a^{b}) = a^{1 + b} if a in Complexes ,  b in Complexes ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a \cdot a^{b}\right) = a^{1 + b} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  a \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a * a^{b}) = a^{1 + b} if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Lambda
#    parameters: 26\n   body: 1
# 1. {(a * a^{b}) = a^{1 + b} if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a * a^{b}) = a^{1 + b}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Complexes) and (b in Complexes) and (a != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a * a^{b}, a^{1 + b})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Complexes, b in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. a * a^{b}
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. a^{1 + b}
#    core type: Operation
#    operator: 25
#    operands: 15
# 10. a in Complexes
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. b in Complexes
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (a, a^{b})
#     core type: ExprTuple
#     sub-expressions: 29, 21
# 15. (a, 1 + b)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 16. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 29, 23
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 29, 24
# 21. a^{b}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. 1 + b
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. Complexes
#     core type: Literal
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (1, b)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
