# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b
from proveit.logic import InSet, NotEquals
from proveit.number import GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Reals), InSet(b, Reals), GreaterEq(a, zero), NotEquals(b, zero))
# Out:
# expr: (a in Reals, b in Reals, a >= 0, b != 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{R}, b \in \mathbb{R}, a \geq 0, b \neq 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Reals, b in Reals, a >= 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a in Reals
#    core type: Operation
#    operator: 6
#    operands: 5
# 2. b in Reals
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. a >= 0
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. b != 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 5. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 8. >=
#    core type: Literal
#    sub-expressions:
# 9. (a, 0)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Reals
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
