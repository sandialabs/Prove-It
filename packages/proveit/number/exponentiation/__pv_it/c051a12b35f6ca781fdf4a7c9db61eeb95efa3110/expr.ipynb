# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import Equals
from proveit.number import Add, Exp, Mult, Neg, frac

# %%
# build up the expression from sub-expressions
expr = Equals(Exp(a, Add(b, Neg(frac(c, d)))), Mult(Exp(a, b), Exp(a, frac(Neg(c), d))))
# Out:
# expr: a^{b - (c / d)} = (a^{b} * a^{(-c) / d})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a^{b - \frac{c}{d}} = \left(a^{b} \cdot a^{\frac{-c}{d}}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a^{b - (c / d)} = (a^{b} * a^{(-c) / d})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a^{b - (c / d)}, a^{b} * a^{(-c) / d})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a^{b - (c / d)}
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. a^{b} * a^{(-c) / d}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, b - (c / d))
#    core type: ExprTuple
#    sub-expressions: 18, 8
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (a^{b}, a^{(-c) / d})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. b - (c / d)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a^{b}
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. a^{(-c) / d}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (b, -(c / d))
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (a, (-c) / d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. -(c / d)
#     core type: Operation
#     operator: 26
#     operand: 20
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. (-c) / d
#     core type: Operation
#     operator: 22
#     operands: 21
# 20. c / d
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. (-c, d)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (c, d)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 24. -c
#     core type: Operation
#     operator: 26
#     operand: 27
# 25. d
#     core type: Variable
#     sub-expressions:
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. c
#     core type: Variable
#     sub-expressions:
