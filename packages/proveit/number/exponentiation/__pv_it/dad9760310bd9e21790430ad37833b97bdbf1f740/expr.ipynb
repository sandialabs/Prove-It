# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import Equals
from proveit.number import Add, Exp, Mult, frac, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = frac(one, two)
subExpr2 = Exp(two, subExpr1)
expr = Equals(Mult(subExpr2, subExpr2), Exp(two, Add(subExpr1, subExpr1)))
# Out:
# expr: (2^{1 / 2} * 2^{1 / 2}) = 2^{(1 / 2) + (1 / 2)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2^{\frac{1}{2}} \cdot 2^{\frac{1}{2}}\right) = 2^{\frac{1}{2} + \frac{1}{2}}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2^{1 / 2} * 2^{1 / 2}) = 2^{(1 / 2) + (1 / 2)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2^{1 / 2} * 2^{1 / 2}, 2^{(1 / 2) + (1 / 2)})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2^{1 / 2} * 2^{1 / 2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 2^{(1 / 2) + (1 / 2)}
#    core type: Operation
#    operator: 10
#    operands: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (2^{1 / 2}, 2^{1 / 2})
#    core type: ExprTuple
#    sub-expressions: 8, 8
# 7. (2, (1 / 2) + (1 / 2))
#    core type: ExprTuple
#    sub-expressions: 18, 9
# 8. 2^{1 / 2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1 / 2) + (1 / 2)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (1 / 2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 14. 1 / 2
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. /
#     core type: Literal
#     sub-expressions:
# 16. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
