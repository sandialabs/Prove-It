# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#sqrtOfProd">sqrtOfProd</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import sqrtOfProd

# %%
# check that the built expression is the same as the stored expression
# %check_expr sqrtOfProd
# Out:
# Passed sanity check: built 'sqrtOfProd' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sqrtOfProd.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{C}}~\left(\sqrt{\left(a_{1} \cdot \ldots \cdot a_{n}\right)} = \left(\sqrt{\left(a_{1}\right)} \cdot \ldots \cdot \sqrt{\left(a_{n}\right)}\right)\right)\right]

# %%
# display the expression information
sqrtOfProd.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complexes} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in Complexes} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in Complexes} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n})))) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in Complexes} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 28
#    operands: 7
# 5. forall
# ...
