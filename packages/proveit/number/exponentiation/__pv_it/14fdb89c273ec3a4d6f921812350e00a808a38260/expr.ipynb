# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, c, d
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Add, Complexes, Exp, Mult, Neg, frac, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(Exp(a, b), Exp(a, frac(Neg(c), d))), Exp(a, Add(b, Neg(frac(c, d))))), And(InSet(a, Complexes), InSet(b, Complexes), InSet(c, Complexes), InSet(d, Complexes), NotEquals(a, zero), NotEquals(d, zero)))
# Out:
# expr: {(a^{b} * a^{(-c) / d}) = a^{b - (c / d)} if a in Complexes ,  b in Complexes ,  c in Complexes ,  d in Complexes ,  a != 0 ,  d != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a^{b} \cdot a^{\frac{-c}{d}}\right) = a^{b - \frac{c}{d}} \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  c \in \mathbb{C} ,  d \in \mathbb{C} ,  a \neq 0 ,  d \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a^{b} * a^{(-c) / d}) = a^{b - (c / d)} if a in Complexes ,  b in Complexes ,  c in Complexes ,  d in Complexes ,  a != 0 ,  d != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a^{b} * a^{(-c) / d}) = a^{b - (c / d)}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complexes) and (b in Complexes) and (c in Complexes) and (d in Complexes) and (a != 0) and (d != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a^{b} * a^{(-c) / d}, a^{b - (c / d)})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Complexes, b in Complexes, c in Complexes, d in Complexes, a != 0, d != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13, 14
# 7. a^{b} * a^{(-c) / d}
#    core type: Operation
#    operator: 15
#    operands: 16
# 8. a^{b - (c / d)}
#    core type: Operation
#    operator: 32
# ...
