# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Complexes, Exp, Integers, Mult, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a, b], Equals(Exp(Mult(a, b), n), Mult(Exp(a, n), Exp(b, n))), domains = [Complexes, Complexes], conditions = [NotEquals(a, zero), NotEquals(b, zero)]), InSet(n, Integers))
# Out:
# expr: {forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n})) if n in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a \in \mathbb{C}, b \in \mathbb{C}~|~a \neq 0, b \neq 0}~\left(\left(a \cdot b\right)^{n} = \left(a^{n} \cdot b^{n}\right)\right) \textrm{ if } n \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n})) if n in Integers.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in Integers
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a, b) -> {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 34\n   body: 6
# 5. (n, Integers)
#    core type: ExprTuple
#    sub-expressions: 40, 7
# 6. {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. Integers
#    core type: Literal
#    sub-expressions:
# 8. (a * b)^{n} = (a^{n} * b^{n})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a in Complexes) and (b in Complexes) and (a != 0) and (b != 0)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. ((a * b)^{n}, a^{n} * b^{n})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a in Complexes, b in Complexes, a != 0, b != 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19
# 14. (a * b)^{n}
#     core type: Operation
#     operator: 36
#     operands: 20
# 15. a^{n} * b^{n}
#     core type: Operation
#     operator: 33
#     operands: 21
# 16. a in Complexes
#     core type: Operation
#     operator: 23
#     operands: 22
# 17. b in Complexes
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. a != 0
#     core type: Operation
#     operator: 26
#     operands: 25
# 19. b != 0
#     core type: Operation
#     operator: 26
#     operands: 27
# 20. (a * b, n)
#     core type: ExprTuple
#     sub-expressions: 28, 40
# 21. (a^{n}, b^{n})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 22. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 38, 31
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 39, 31
# 25. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 38, 32
# 26. !=
#     core type: Literal
#     sub-expressions:
# 27. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 39, 32
# 28. a * b
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. a^{n}
#     core type: Operation
#     operator: 36
#     operands: 35
# 30. b^{n}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. Complexes
#     core type: Literal
#     sub-expressions:
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. *
#     core type: Literal
#     sub-expressions:
# 34. (a, b)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. (a, n)
#     core type: ExprTuple
#     sub-expressions: 38, 40
# 36. Exp
#     core type: Literal
#     sub-expressions:
# 37. (b, n)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. a
#     core type: Variable
#     sub-expressions:
# 39. b
#     core type: Variable
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
