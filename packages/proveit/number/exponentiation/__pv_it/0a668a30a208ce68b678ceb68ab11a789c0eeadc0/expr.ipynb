# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#expRealClosureExpNonZero">expRealClosureExpNonZero</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import expRealClosureExpNonZero

# %%
# check that the built expression is the same as the stored expression
# %check_expr expRealClosureExpNonZero
# Out:
# Passed sanity check: built 'expRealClosureExpNonZero' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expRealClosureExpNonZero.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}~|~a \geq 0, b \neq 0}~\left(a^{b} \in \mathbb{R}\right)

# %%
# display the expression information
expRealClosureExpNonZero.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals | a >= 0, b != 0} (a^{b} in Reals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {a^{b} in Reals if a in Reals ,  b in Reals ,  a >= 0 ,  b != 0.
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {a^{b} in Reals if a in Reals ,  b in Reals ,  a >= 0 ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a^{b} in Reals
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (a in Reals) and (b in Reals) and (a >= 0) and (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a^{b}, Reals)
#    core type: ExprTuple
#    sub-expressions: 9, 23
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Reals, b in Reals, a >= 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. a^{b}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. a in Reals
# ...
