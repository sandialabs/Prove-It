# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#addOneRightInExp">addOneRightInExp</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import addOneRightInExp

# %%
# check that the built expression is the same as the stored expression
# %check_expr addOneRightInExp
# Out:
# Passed sanity check: built 'addOneRightInExp' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(addOneRightInExp.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}~|~a \neq 0}~\left(a^{b + 1} = \left(a^{b} \cdot a\right)\right)

# %%
# display the expression information
addOneRightInExp.exprInfo()
# Out:
# 0. forall_{a in Complexes, b in Complexes | a != 0} (a^{b + 1} = (a^{b} * a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {a^{b + 1} = (a^{b} * a) if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Lambda
#    parameters: 30\n   body: 3
# 3. {a^{b + 1} = (a^{b} * a) if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a^{b + 1} = (a^{b} * a)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Complexes) and (b in Complexes) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a^{b + 1}, a^{b} * a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Complexes, b in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a^{b + 1}
# ...
