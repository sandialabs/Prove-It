# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Abs, Exp, LessEq, Reals, two

# %%
# build up the expression from sub-expressions
subExpr1 = Abs(a)
expr = Lambda([a, b], Conditional(LessEq(Exp(subExpr1, two), Exp(b, two)), And(InSet(a, Reals), InSet(b, Reals), LessEq(subExpr1, b))))
# Out:
# expr: (a, b) -> {|a|^{2} <= b^{2} if a in Reals ,  b in Reals ,  |a| <= b.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left|a\right|^{2} \leq b^{2} \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  \left|a\right| \leq b\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {|a|^{2} <= b^{2} if a in Reals ,  b in Reals ,  |a| <= b.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 26, 24
# 2. {|a|^{2} <= b^{2} if a in Reals ,  b in Reals ,  |a| <= b.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |a|^{2} <= b^{2}
#    core type: Operation
#    operator: 19
#    operands: 5
# 4. (a in Reals) and (b in Reals) and (|a| <= b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|a|^{2}, b^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Reals, b in Reals, |a| <= b)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. |a|^{2}
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. b^{2}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. a in Reals
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. b in Reals
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. |a| <= b
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. (|a|, 2)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (b, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 16. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (|a|, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. Reals
#     core type: Literal
#     sub-expressions:
# 23. |a|
#     core type: Operation
#     operator: 25
#     operand: 26
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
