# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intExpOfProd">intExpOfProd</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import intExpOfProd

# %%
# check that the built expression is the same as the stored expression
# %check_expr intExpOfProd
# Out:
# Passed sanity check: built 'intExpOfProd' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intExpOfProd.latex())
# Out:
# \vdash \forall_{n \in \mathbb{Z}}~\left[\forall_{a \in \mathbb{C}, b \in \mathbb{C}~|~a \neq 0, b \neq 0}~\left(\left(a \cdot b\right)^{n} = \left(a^{n} \cdot b^{n}\right)\right)\right]

# %%
# display the expression information
intExpOfProd.exprInfo()
# Out:
# 0. forall_{n in Integers} [forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n})) if n in Integers.
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. {forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n})) if n in Integers.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a in Complexes, b in Complexes | a != 0, b != 0} ((a * b)^{n} = (a^{n} * b^{n}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Integers
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a, b) -> {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 36\n   body: 8
# 7. (n, Integers)
# ...
