# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y, z
from proveit.logic import And, InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = And(InSet(x, Complexes), InSet(y, Complexes), InSet(z, Complexes))
# Out:
# expr: (x in Complexes) and (y in Complexes) and (z in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{C}\right) \land \left(y \in \mathbb{C}\right) \land \left(z \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in Complexes) and (y in Complexes) and (z in Complexes)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x in Complexes, y in Complexes, z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. x in Complexes
#    core type: Operation
#    operator: 8
#    operands: 6
# 4. y in Complexes
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. z in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 7. (y, Complexes)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (z, Complexes)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. y
#     core type: Variable
#     sub-expressions:
# 12. z
#     core type: Variable
#     sub-expressions:
# 13. Complexes
#     core type: Literal
#     sub-expressions:
