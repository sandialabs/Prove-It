# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Exp, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exp(a, Add(b, c)), Mult(Exp(a, b), Exp(a, c)))
# Out:
# expr: (a^{b + c}, a^{b} * a^{c})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a^{b + c}, a^{b} \cdot a^{c}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a^{b + c}, a^{b} * a^{c})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a^{b + c}
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. a^{b} * a^{c}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b + c)
#    core type: ExprTuple
#    sub-expressions: 15, 6
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (a^{b}, a^{c})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. b + c
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a^{b}
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. a^{c}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (b, c)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (a, c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
