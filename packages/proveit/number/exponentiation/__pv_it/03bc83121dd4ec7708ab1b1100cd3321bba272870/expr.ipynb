# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Exp, Mult, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a, b], Equals(Exp(Mult(a, b), n), Mult(Exp(a, n), Exp(b, n))), domains = [Complexes, Complexes]), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{a in Complexes, b in Complexes} ((a * b)^{n} = (a^{n} * b^{n})) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a \in \mathbb{C}, b \in \mathbb{C}}~\left(\left(a \cdot b\right)^{n} = \left(a^{n} \cdot b^{n}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{a in Complexes, b in Complexes} ((a * b)^{n} = (a^{n} * b^{n})) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 35
#    body: 1
# 1. {forall_{a in Complexes, b in Complexes} ((a * b)^{n} = (a^{n} * b^{n})) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a in Complexes, b in Complexes} ((a * b)^{n} = (a^{n} * b^{n}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 22
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a, b) -> {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes.
#    core type: Lambda
#    parameters: 29\n   body: 7
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 35, 8
# 7. {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. (a * b)^{n} = (a^{n} * b^{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a in Complexes) and (b in Complexes)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. ((a * b)^{n}, a^{n} * b^{n})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a in Complexes, b in Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (a * b)^{n}
#     core type: Operation
#     operator: 31
#     operands: 19
# 16. a^{n} * b^{n}
#     core type: Operation
#     operator: 28
#     operands: 20
# 17. a in Complexes
#     core type: Operation
#     operator: 22
#     operands: 21
# 18. b in Complexes
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (a * b, n)
#     core type: ExprTuple
#     sub-expressions: 24, 35
# 20. (a^{n}, b^{n})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 21. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 33, 27
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 34, 27
# 24. a * b
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. a^{n}
#     core type: Operation
#     operator: 31
#     operands: 30
# 26. b^{n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. Complexes
#     core type: Literal
#     sub-expressions:
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (a, b)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. (a, n)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (b, n)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. b
#     core type: Variable
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
