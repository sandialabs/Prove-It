# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Add, Complexes, Exp, Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Exp(a, Add(b, one)), Mult(Exp(a, b), a)), And(InSet(a, Complexes), InSet(b, Complexes), NotEquals(a, zero))))
# Out:
# expr: (a, b) -> {a^{b + 1} = (a^{b} * a) if a in Complexes ,  b in Complexes ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a^{b + 1} = \left(a^{b} \cdot a\right) \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  a \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {a^{b + 1} = (a^{b} * a) if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Lambda
#    parameters: 28\n   body: 1
# 1. {a^{b + 1} = (a^{b} * a) if a in Complexes ,  b in Complexes ,  a != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a^{b + 1} = (a^{b} * a)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Complexes) and (b in Complexes) and (a != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a^{b + 1}, a^{b} * a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Complexes, b in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. a^{b + 1}
#    core type: Operation
#    operator: 27
#    operands: 13
# 9. a^{b} * a
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. a in Complexes
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. b in Complexes
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. (a, b + 1)
#     core type: ExprTuple
#     sub-expressions: 30, 21
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (a^{b}, a)
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 16. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 30, 24
# 21. b + 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. a^{b}
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. Complexes
#     core type: Literal
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
