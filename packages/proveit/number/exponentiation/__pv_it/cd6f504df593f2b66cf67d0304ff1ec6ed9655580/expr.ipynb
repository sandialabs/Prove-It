# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#diffFracInExpRev">diffFracInExpRev</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.exponentiation._theorems_ import diffFracInExpRev

# %%
# check that the built expression is the same as the stored expression
# %check_expr diffFracInExpRev
# Out:
# Passed sanity check: built 'diffFracInExpRev' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(diffFracInExpRev.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}, b \in \mathbb{C}, c \in \mathbb{C}, d \in \mathbb{C}~|~a \neq 0, d \neq 0}~\left(\left(a^{b} \cdot a^{\frac{-c}{d}}\right) = a^{b - \frac{c}{d}}\right)

# %%
# display the expression information
diffFracInExpRev.exprInfo()
# Out:
# 0. forall_{a in Complexes, b in Complexes, c in Complexes, d in Complexes | a != 0, d != 0} ((a^{b} * a^{(-c) / d}) = a^{b - (c / d)})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c, d) -> {(a^{b} * a^{(-c) / d}) = a^{b - (c / d)} if a in Complexes ,  b in Complexes ,  c in Complexes ,  d in Complexes ,  a != 0 ,  d != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 40, 42, 50, 51
# 4. {(a^{b} * a^{(-c) / d}) = a^{b - (c / d)} if a in Complexes ,  b in Complexes ,  c in Complexes ,  d in Complexes ,  a != 0 ,  d != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a^{b} * a^{(-c) / d}) = a^{b - (c / d)}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Complexes) and (b in Complexes) and (c in Complexes) and (d in Complexes) and (a != 0) and (d != 0)
#    core type: Operation
# ...
