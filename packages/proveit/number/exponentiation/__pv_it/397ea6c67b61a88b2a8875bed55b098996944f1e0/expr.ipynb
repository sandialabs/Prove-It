# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Or(A, B), domains = [Booleans, Booleans], condition = B)
# Out:
# expr: forall_{A in BOOLEANS, B in BOOLEANS | B} (A or B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A \in \mathbb{B}, B \in \mathbb{B}~|~B}~\left(A \lor B\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS, B in BOOLEANS | B} (A or B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A or B if A in BOOLEANS ,  B in BOOLEANS ,  B.
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {A or B if A in BOOLEANS ,  B in BOOLEANS ,  B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A or B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A in BOOLEANS) and (B in BOOLEANS) and B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 15, 16
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A in BOOLEANS, B in BOOLEANS, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 16
# 10. A in BOOLEANS
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. B in BOOLEANS
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
