# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.number import Complexes, zero

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Complexes), InSet(b, Complexes), NotEquals(a, zero), NotEquals(b, zero))
# Out:
# expr: (a in Complexes) and (b in Complexes) and (a != 0) and (b != 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}\right) \land \left(b \in \mathbb{C}\right) \land \left(a \neq 0\right) \land \left(b \neq 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Complexes) and (b in Complexes) and (a != 0) and (b != 0)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Complexes, b in Complexes, a != 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Complexes
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. b in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. a != 0
#    core type: Operation
#    operator: 11
#    operands: 10
# 6. b != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (b, Complexes)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
