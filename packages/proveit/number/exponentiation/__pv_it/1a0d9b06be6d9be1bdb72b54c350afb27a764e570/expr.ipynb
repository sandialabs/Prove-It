# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b
from proveit.number import Add, Exp, Mult, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exp(a, Add(b, one)), Mult(Exp(a, b), a))
# Out:
# expr: (a^{b + 1}, a^{b} * a)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a^{b + 1}, a^{b} \cdot a\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a^{b + 1}, a^{b} * a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a^{b + 1}
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. a^{b} * a
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b + 1)
#    core type: ExprTuple
#    sub-expressions: 13, 6
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (a^{b}, a)
#    core type: ExprTuple
#    sub-expressions: 7, 13
# 6. b + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. a^{b}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (b, 1)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
