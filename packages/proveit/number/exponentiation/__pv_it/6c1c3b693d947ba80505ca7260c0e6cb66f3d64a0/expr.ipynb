# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b, n
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.number import Complexes, Exp, Mult, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Exp(Mult(a, b), n), Mult(Exp(a, n), Exp(b, n))), And(InSet(a, Complexes), InSet(b, Complexes), NotEquals(a, zero), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a \cdot b\right)^{n} = \left(a^{n} \cdot b^{n}\right) \textrm{ if } a \in \mathbb{C} ,  b \in \mathbb{C} ,  a \neq 0 ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.
#    core type: Lambda
#    parameters: 28\n   body: 1
# 1. {(a * b)^{n} = (a^{n} * b^{n}) if a in Complexes ,  b in Complexes ,  a != 0 ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a * b)^{n} = (a^{n} * b^{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Complexes) and (b in Complexes) and (a != 0) and (b != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((a * b)^{n}, a^{n} * b^{n})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Complexes, b in Complexes, a != 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 8. (a * b)^{n}
#    core type: Operation
#    operator: 30
#    operands: 14
# 9. a^{n} * b^{n}
#    core type: Operation
#    operator: 27
#    operands: 15
# 10. a in Complexes
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. b in Complexes
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. a != 0
#     core type: Operation
#     operator: 20
#     operands: 19
# 13. b != 0
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. (a * b, n)
#     core type: ExprTuple
#     sub-expressions: 22, 34
# 15. (a^{n}, b^{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 16. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 32, 25
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 33, 25
# 19. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 20. !=
#     core type: Literal
#     sub-expressions:
# 21. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 22. a * b
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. a^{n}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. b^{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. Complexes
#     core type: Literal
#     sub-expressions:
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (a, b)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. (a, n)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (b, n)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. b
#     core type: Variable
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
