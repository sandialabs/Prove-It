# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Exp, GreaterEq, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(GreaterEq(Exp(a, b), a), And(InSet(a, NaturalsPos), InSet(b, NaturalsPos)))
# Out:
# expr: {a^{b} >= a if a in NaturalsPos ,  b in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a^{b} \geq a \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a^{b} >= a if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a^{b} >= a
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. >=
#    core type: Literal
#    sub-expressions:
# 4. (a^{b}, a)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in NaturalsPos, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a^{b}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in NaturalsPos
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b in NaturalsPos
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (a, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. NaturalsPos
#     core type: Literal
#     sub-expressions:
