# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.number import Exp, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Exp(a, b), Reals), And(InSet(a, Reals), InSet(b, Reals), GreaterEq(a, zero), NotEquals(b, zero))))
# Out:
# expr: (a, b) -> {a^{b} in Reals if a in Reals ,  b in Reals ,  a >= 0 ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a^{b} \in \mathbb{R} \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  a \geq 0 ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {a^{b} in Reals if a in Reals ,  b in Reals ,  a >= 0 ,  b != 0.
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {a^{b} in Reals if a in Reals ,  b in Reals ,  a >= 0 ,  b != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a^{b} in Reals
#    core type: Operation
#    operator: 15
#    operands: 4
# 3. (a in Reals) and (b in Reals) and (a >= 0) and (b != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a^{b}, Reals)
#    core type: ExprTuple
#    sub-expressions: 7, 21
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Reals, b in Reals, a >= 0, b != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. a^{b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a in Reals
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. b in Reals
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. a >= 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. b != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 14. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 17. >=
#     core type: Literal
#     sub-expressions:
# 18. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
