# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">number</a>.<a class="ProveItLink" href="../_context_.ipynb">exponentiation</a>.<a class="ProveItLink" href="../_theorems_.ipynb#sqrtOfProd">sqrtOfProd</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving sqrtOfProd presuming []
# Out:
# Beginning proof of sqrtOfProd
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# sqrtOfProd: forall_{n in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complexes} (sqrt((a_{1} * ..a_{_a}.. * a_{n})) = (sqrt((a_{1})) * ..sqrt((a_{i})).. * sqrt((a_{n}))))]
