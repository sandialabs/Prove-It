# %% [markdown]
# Theory of <a href="../../_theory_.ipynb" class="ProveItLink">proveit</a>.<a href="../_theory_.ipynb" class="ProveItLink">number</a>.differentiation
# ========
#
# Provide description here.

# %%
import proveit
# %theory
