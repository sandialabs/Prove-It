# %% [markdown]
# Axioms for context <a class="ProveItLink" href="_context_.ipynb">proveit.number.absolute_value</a>
# ========

# %%
import proveit
# Automation is not needed when building axiom expressions:
proveit.defaults.automation = False # This will speed things up.
from proveit._common_ import x
from proveit.logic import Equals, Forall
from proveit.number import two, Abs, Exp, Reals, sqrt
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin axioms
# Out:
# Defining axioms for context 'proveit.number.absolute_value'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %%
# this axiom might be shifted to theorems once we have
# the Conditional class to use for a piece-wise definition
abs_val_def_sqrt = Forall(
    x,
    Equals(Abs(x), sqrt(Exp(x, two))),
    domain = Reals)
# Out:
# abs_val_def_sqrt: forall_{x in Reals} (|x| = sqrt((x^{2})))

# %%
# %end axioms
# Out:
# Axioms may be imported from autogenerated _axioms_.py
