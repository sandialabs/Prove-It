# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda
from proveit._common_ import i, n, x
from proveit.core_expr_types._common_ import x_1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Abs, Complexes, Mult, NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([x_1_to_n], Equals(Abs(Mult(x_1_to_n)), Mult(ExprRange(i, Abs(IndexedVar(x, i)), one, n))), domain = Complexes), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|)) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}}~\left(\left|x_{1} \cdot \ldots \cdot x_{n}\right| = \left(\left|x_{1}\right| \cdot \ldots \cdot \left|x_{n}\right|\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|)) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 31
#    body: 1
# 1. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|)) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 27
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x_{1}, ..x_{_a}.., x_{n}) -> {|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|) if (x_{1} in Complexes) and ..(x_{_a} in Complexes).. and (x_{n} in Complexes).
#    core type: Lambda
#    parameter: 25
#    body: 7
# 6. (n, NaturalsPos)
# ...
