# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import InSet
from proveit.number import Abs, Add, RealsNonNeg, three, two

# %%
# build up the expression from sub-expressions
expr = InSet(Abs(Add(a, b, two, three)), RealsNonNeg)
# Out:
# expr: |a + b + 2 + 3| in RealsNonNeg

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|a + b + 2 + 3\right| \in \mathbb{R}^{\ge 0}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |a + b + 2 + 3| in RealsNonNeg
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (|a + b + 2 + 3|, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |a + b + 2 + 3|
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. RealsNonNeg
#    core type: Literal
#    sub-expressions:
# 5. Abs
#    core type: Literal
#    sub-expressions:
# 6. a + b + 2 + 3
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (a, b, 2, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
