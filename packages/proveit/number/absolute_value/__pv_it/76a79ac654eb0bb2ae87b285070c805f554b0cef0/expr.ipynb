# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x, y
from proveit.logic import And, Iff, InSet
from proveit.number import Abs, GreaterEq, LessEq, Neg, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(Iff(LessEq(Abs(x), y), And(LessEq(Neg(y), x), LessEq(x, y))), And(InSet(x, Reals), InSet(y, Reals), GreaterEq(y, zero))))
# Out:
# expr: (x, y) -> {(|x| <= y) <=> (((-y) <= x) and (x <= y)) if x in Reals ,  y in Reals ,  y >= 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\left(\left|x\right| \leq y\right) \Leftrightarrow \left(\left(\left(-y\right) \leq x\right) \land \left(x \leq y\right)\right) \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{R} ,  y \geq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, y) -> {(|x| <= y) <=> (((-y) <= x) and (x <= y)) if x in Reals ,  y in Reals ,  y >= 0.
#    core type: Lambda
#    parameters: 28\n   body: 1
# 1. {(|x| <= y) <=> (((-y) <= x) and (x <= y)) if x in Reals ,  y in Reals ,  y >= 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (|x| <= y) <=> (((-y) <= x) and (x <= y))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x in Reals) and (y in Reals) and (y >= 0)
#    core type: Operation
#    operator: 13
#    operands: 6
# 4. <=>
#    core type: Literal
#    sub-expressions:
# 5. (|x| <= y, ((-y) <= x) and (x <= y))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (x in Reals, y in Reals, y >= 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. |x| <= y
#    core type: Operation
#    operator: 27
#    operands: 12
# 8. ((-y) <= x) and (x <= y)
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. x in Reals
#    core type: Operation
#    operator: 16
# ...
