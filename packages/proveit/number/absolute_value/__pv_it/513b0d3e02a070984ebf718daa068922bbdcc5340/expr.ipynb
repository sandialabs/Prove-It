# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import b, i, j
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_j
from proveit.logic import Forall, InSet
from proveit.number import Add, Greater, Naturals, RealsNonNeg, RealsPos, zero

# %%
# build up the expression from sub-expressions
expr = Forall([i, j], Forall([a_1_to_i, b, c_1_to_j], InSet(Add(a_1_to_i, b, c_1_to_j), RealsPos), domains = [RealsNonNeg, RealsNonNeg, RealsNonNeg], condition = Greater(b, zero)), domains = [Naturals, Naturals])
# Out:
# expr: forall_{i in Naturals, j in Naturals} [forall_{a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg, b in RealsNonNeg, c_{1} in RealsNonNeg, ..c_{_a} in RealsNonNeg.., c_{j} in RealsNonNeg | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in RealsPos)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}, j \in \mathbb{N}}~\left[\forall_{a_{1} \in \mathbb{R}^{\ge 0}, \ldots, a_{i} \in \mathbb{R}^{\ge 0}, b \in \mathbb{R}^{\ge 0}, c_{1} \in \mathbb{R}^{\ge 0}, \ldots, c_{j} \in \mathbb{R}^{\ge 0}~|~b > 0}~\left(\left(a_{1} + \ldots + a_{i} + b + c_{1} + \ldots + c_{j}\right) \in \mathbb{R}^+\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{i in Naturals, j in Naturals} [forall_{a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg, b in RealsNonNeg, c_{1} in RealsNonNeg, ..c_{_a} in RealsNonNeg.., c_{j} in RealsNonNeg | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in RealsPos)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (i, j) -> {forall_{a_{1} in RealsNonNeg, ..a_{_a} in RealsNonNeg.., a_{i} in RealsNonNeg, b in RealsNonNeg, c_{1} in RealsNonNeg, ..c_{_a} in RealsNonNeg.., c_{j} in RealsNonNeg | b > 0} ((a_{1} + ..a_{_a}.. + a_{i} + b + c_{1} + ..c_{_a}.. + c_{j}) in RealsPos) if i in Naturals ,  j in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (i, j)
#    core type: ExprTuple
#    sub-expressions: 40, 43
# ...
