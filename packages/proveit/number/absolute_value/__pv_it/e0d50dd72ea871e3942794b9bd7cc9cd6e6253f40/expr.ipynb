# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a
from proveit.logic import Forall, InSet
from proveit.number import GreaterEq, Reals, RealsNonNeg, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a], InSet(a, RealsNonNeg), domain = Reals, condition = GreaterEq(a, zero))
# Out:
# expr: forall_{a in Reals | a >= 0} (a in RealsNonNeg)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}~|~a \geq 0}~\left(a \in \mathbb{R}^{\ge 0}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in Reals | a >= 0} (a in RealsNonNeg)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {a in RealsNonNeg if a in Reals ,  a >= 0.
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. {a in RealsNonNeg if a in Reals ,  a >= 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a in RealsNonNeg
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (a in Reals) and (a >= 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Reals, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. RealsNonNeg
#    core type: Literal
#    sub-expressions:
# 10. a in Reals
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. a >= 0
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. >=
#     core type: Literal
#     sub-expressions:
# 15. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Reals
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
