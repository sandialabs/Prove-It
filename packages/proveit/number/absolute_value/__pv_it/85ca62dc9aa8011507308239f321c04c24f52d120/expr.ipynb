# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#absProd">absProd</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.absolute_value._theorems_ import absProd

# %%
# check that the built expression is the same as the stored expression
# %check_expr absProd
# Out:
# Passed sanity check: built 'absProd' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(absProd.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}}~\left(\left|x_{1} \cdot \ldots \cdot x_{n}\right| = \left(\left|x_{1}\right| \cdot \ldots \cdot \left|x_{n}\right|\right)\right)\right]

# %%
# display the expression information
absProd.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|)) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|)) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{i}|.. * |x_{n}|))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 28
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
