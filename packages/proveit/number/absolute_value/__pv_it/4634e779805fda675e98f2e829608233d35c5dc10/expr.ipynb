# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#absComplexClosure">absComplexClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.absolute_value._theorems_ import absComplexClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr absComplexClosure
# Out:
# Passed sanity check: built 'absComplexClosure' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(absComplexClosure.latex())
# Out:
# \vdash \forall_{a \in \mathbb{C}}~\left(\left|a\right| \in \mathbb{R}\right)

# %%
# display the expression information
absComplexClosure.exprInfo()
# Out:
# 0. forall_{a in Complexes} (|a| in Reals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {|a| in Reals if a in Complexes.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {|a| in Reals if a in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |a| in Reals
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. a in Complexes
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|a|, Reals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (a, Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. |a|
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. Reals
#     core type: Literal
#     sub-expressions:
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. a
# ...
