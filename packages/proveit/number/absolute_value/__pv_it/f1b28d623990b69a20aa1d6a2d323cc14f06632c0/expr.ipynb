# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Add, RealsNonNeg

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(Add(a, b), RealsNonNeg), And(InSet(a, RealsNonNeg), InSet(b, RealsNonNeg))))
# Out:
# expr: (a, b) -> {(a + b) in RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a + b\right) \in \mathbb{R}^{\ge 0} \textrm{ if } a \in \mathbb{R}^{\ge 0} ,  b \in \mathbb{R}^{\ge 0}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a + b) in RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {(a + b) in RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a + b) in RealsNonNeg
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a in RealsNonNeg) and (b in RealsNonNeg)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a + b, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 7, 17
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in RealsNonNeg, b in RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a + b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in RealsNonNeg
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b in RealsNonNeg
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (a, RealsNonNeg)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b, RealsNonNeg)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. RealsNonNeg
#     core type: Literal
#     sub-expressions:
