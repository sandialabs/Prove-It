# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import InSet, Set
from proveit.number import NaturalsPos, Reals

# %%
# build up the expression from sub-expressions
expr = Set(InSet(a, Reals), InSet(b, NaturalsPos))
# Out:
# expr: {a in Reals, b in NaturalsPos}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a \in \mathbb{R}, b \in \mathbb{N}^+\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a in Reals, b in NaturalsPos}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (a in Reals, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a in Reals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. b in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, Reals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (b, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. Reals
#    core type: Literal
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
