# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, b, c, i, j, k
from proveit.logic import InSet
from proveit.number import Complexes, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Complexes), one, i), ExprRange(subExpr1, InSet(IndexedVar(b, subExpr1), Complexes), one, j), ExprRange(subExpr1, InSet(IndexedVar(c, subExpr1), Complexes), one, k))
# Out:
# expr: (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, b_{1} \in \mathbb{C}, \ldots, b_{j} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (a_{1} in Complexes), ..(a_{_a} in Complexes).., (a_{i} in Complexes)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 5
# 2. (b_{1} in Complexes), ..(b_{_a} in Complexes).., (b_{j} in Complexes)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 7
# 3. (c_{1} in Complexes), ..(c_{_a} in Complexes).., (c_{k} in Complexes)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 4. _a -> (a_{_a} in Complexes)
#    core type: Lambda
#    parameter: 25
#    body: 11
# 5. i
#    core type: Variable
#    sub-expressions:
# 6. _a -> (b_{_a} in Complexes)
#    core type: Lambda
#    parameter: 25
#    body: 12
# 7. j
#    core type: Variable
#    sub-expressions:
# 8. _a -> (c_{_a} in Complexes)
#    core type: Lambda
#    parameter: 25
#    body: 13
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. a_{_a} in Complexes
#     core type: Operation
#     operator: 16
#     operands: 14
# 12. b_{_a} in Complexes
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. c_{_a} in Complexes
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. (a_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 15. (b_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a_{_a}
#     core type: IndexedVar
# variable: 22
# index: 25
# 19. b_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 20. c_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 21. Complexes
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
