# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a
from proveit.logic import Forall, InSet, NotEquals
from proveit.number import Abs, Complexes, RealsPos, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a], InSet(Abs(a), RealsPos), domain = Complexes, condition = NotEquals(a, zero))
# Out:
# expr: forall_{a in Complexes | a != 0} (|a| in RealsPos)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}~|~a \neq 0}~\left(\left|a\right| \in \mathbb{R}^+\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in Complexes | a != 0} (|a| in RealsPos)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> {|a| in RealsPos if a in Complexes ,  a != 0.
#    core type: Lambda
#    parameter: 19
#    body: 3
# 3. {|a| in RealsPos if a in Complexes ,  a != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |a| in RealsPos
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (a in Complexes) and (a != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|a|, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complexes, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. |a|
#    core type: Operation
#    operator: 13
#    operand: 19
# 10. RealsPos
#     core type: Literal
#     sub-expressions:
# 11. a in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. a != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. Abs
#     core type: Literal
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Complexes
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. 0
#     core type: Literal
#     sub-expressions:
