# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a
from proveit.logic import InSet
from proveit.number import Abs, Complexes, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(InSet(Abs(a), Reals), InSet(a, Complexes)))
# Out:
# expr: a -> {|a| in Reals if a in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{\left|a\right| \in \mathbb{R} \textrm{ if } a \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> {|a| in Reals if a in Complexes.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {|a| in Reals if a in Complexes.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |a| in Reals
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. a in Complexes
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|a|, Reals)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (a, Complexes)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. |a|
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. Reals
#    core type: Literal
#    sub-expressions:
# 9. Complexes
#    core type: Literal
#    sub-expressions:
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
