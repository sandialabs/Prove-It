# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c, d, x, y
from proveit.logic import InSet
from proveit.number import Complexes, Integers

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Integers), InSet(b, Integers), InSet(x, Complexes), InSet(y, Complexes), InSet(c, Complexes), InSet(d, Complexes))
# Out:
# expr: (a in Integers, b in Integers, x in Complexes, y in Complexes, c in Complexes, d in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{Z}, b \in \mathbb{Z}, x \in \mathbb{C}, y \in \mathbb{C}, c \in \mathbb{C}, d \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Integers, b in Integers, x in Complexes, y in Complexes, c in Complexes, d in Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. a in Integers
#    core type: Operation
#    operator: 12
#    operands: 7
# 2. b in Integers
#    core type: Operation
#    operator: 12
#    operands: 8
# 3. x in Complexes
#    core type: Operation
#    operator: 12
#    operands: 9
# 4. y in Complexes
#    core type: Operation
#    operator: 12
#    operands: 10
# 5. c in Complexes
#    core type: Operation
#    operator: 12
#    operands: 11
# 6. d in Complexes
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. (a, Integers)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 8. (b, Integers)
#    core type: ExprTuple
#    sub-expressions: 15, 16
# 9. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 17, 21
# 10. (y, Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 11. (c, Complexes)
# ...
