# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, c, i, k
from proveit.logic import InSet
from proveit.number import Complexes, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Complexes), one, i), ExprRange(subExpr1, InSet(IndexedVar(c, subExpr1), Complexes), one, k))
# Out:
# expr: (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} in Complexes), ..(a_{_a} in Complexes).., (a_{i} in Complexes)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 4
# 2. (c_{1} in Complexes), ..(c_{_a} in Complexes).., (c_{k} in Complexes)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 3. _a -> (a_{_a} in Complexes)
#    core type: Lambda
#    parameter: 18
#    body: 8
# 4. i
#    core type: Variable
#    sub-expressions:
# 5. _a -> (c_{_a} in Complexes)
#    core type: Lambda
#    parameter: 18
#    body: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. a_{_a} in Complexes
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. c_{_a} in Complexes
#    core type: Operation
#    operator: 11
# ...
