# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, S
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.number import Mult, Sum

# %%
# build up the expression from sub-expressions
subExpr1 = [b_1_to_j]
expr = Mult(a_1_to_i, Sum(subExpr1, Function(P, subExpr1), domain = S), c_1_to_k)
# Out:
# expr: a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a_{1} \cdot \ldots \cdot a_{i} \cdot \left[\sum_{b_{1}, \ldots, b_{j} \in S}~P(b_{1}, \ldots, b_{j})\right] \cdot c_{1} \cdot \ldots \cdot c_{k}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 27
#    end_index: 7
# 4. Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})
#    core type: Operation
#    operator: 8
#    operand: 9
# 5. c_{1}, ..c_{_a}.., c_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 27
#    end_index: 11
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 35
#    body: 12
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. Sum
#    core type: Literal
#    sub-expressions:
# 9. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#    core type: Lambda
#    parameter: 23
#    body: 13
# 10. _a -> c_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 14
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. a_{_a}
#     core type: IndexedVar
# variable: 15
# index: 35
# 13. {P(b_{1}, ..b_{_a}.., b_{j}) if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. c_{_a}
#     core type: IndexedVar
# variable: 18
# index: 35
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S)
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (b_{1} in S, ..b_{_a} in S.., b_{j} in S)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 27
#     end_index: 28
# 24. (b_{1} in S), ..(b_{_a} in S).., (b_{j} in S)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. _a -> b_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 32
# 26. _a -> (b_{_a} in S)
#     core type: Lambda
#     parameter: 35
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. j
#     core type: Variable
#     sub-expressions:
# 29. b_{_a} in S
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (b_{_a}, S)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. b_{_a}
#     core type: IndexedVar
# variable: 34
# index: 35
# 33. S
#     core type: Variable
#     sub-expressions:
# 34. b
#     core type: Variable
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
