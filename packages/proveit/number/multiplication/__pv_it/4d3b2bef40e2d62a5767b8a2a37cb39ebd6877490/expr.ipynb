# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import a, n
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.logic import And, InSet
from proveit.number import Mult, RealsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Lambda(a_1_to_n, Conditional(InSet(Mult(a_1_to_n), RealsPos), And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), RealsPos), one, n))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealsPos if (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{n} in RealsPos).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R}^+ \textrm{ if } \left(a_{1} \in \mathbb{R}^+\right) \land \ldots \land \left(a_{n} \in \mathbb{R}^+\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealsPos if (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{n} in RealsPos).
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {(a_{1} * ..a_{_a}.. * a_{n}) in RealsPos if (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{n} in RealsPos).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * ..a_{_a}.. * a_{n}) in RealsPos
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{n} in RealsPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} * ..a_{_a}.. * a_{n}, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 20
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in RealsPos, ..a_{_a} in RealsPos.., a_{n} in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 9
# ...
