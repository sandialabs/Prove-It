# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.number import Integers, Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(a_1_to_n), Integers)
# Out:
# expr: (a_{1} * ..a_{_a}.. * a_{n}, Integers)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \cdot \ldots \cdot a_{n}, \mathbb{Z}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} * ..a_{_a}.. * a_{n}, Integers)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Integers
#    core type: Literal
#    sub-expressions:
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (a_{1}, ..a_{_a}.., a_{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 5. a_{1}, ..a_{_a}.., a_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 11
#    body: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. a_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
