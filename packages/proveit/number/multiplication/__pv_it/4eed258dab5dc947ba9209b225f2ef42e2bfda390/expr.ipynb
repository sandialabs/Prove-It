# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multNegRight">multNegRight</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._theorems_ import multNegRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr multNegRight
# Out:
# Passed sanity check: built 'multNegRight' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multNegRight.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}, y \in \mathbb{C}}~\left(\left(x \cdot \left(-y\right)\right) = \left(-\left(x \cdot y\right)\right)\right)

# %%
# display the expression information
multNegRight.exprInfo()
# Out:
# 0. forall_{x in Complexes, y in Complexes} ((x * (-y)) = (-(x * y)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {(x * (-y)) = (-(x * y)) if x in Complexes ,  y in Complexes.
#    core type: Lambda
#    parameters: 21\n   body: 3
# 3. {(x * (-y)) = (-(x * y)) if x in Complexes ,  y in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x * (-y)) = (-(x * y))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x in Complexes) and (y in Complexes)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x * (-y), -(x * y))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Complexes, y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. x * (-y)
#     core type: Operation
#     operator: 20
# ...
