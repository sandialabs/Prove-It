# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multRealPosClosure">multRealPosClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._theorems_ import multRealPosClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr multRealPosClosure
# Out:
# Passed sanity check: built 'multRealPosClosure' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multRealPosClosure.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{R}^+}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R}^+\right)\right]

# %%
# display the expression information
multRealPosClosure.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{n} in RealsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsPos)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsPos) if n in Naturals.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in RealsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsPos) if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in RealsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsPos)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealsPos if (a_{1} in RealsPos) and ..(a_{_a} in RealsPos).. and (a_{n} in RealsPos).
#    core type: Lambda
# ...
