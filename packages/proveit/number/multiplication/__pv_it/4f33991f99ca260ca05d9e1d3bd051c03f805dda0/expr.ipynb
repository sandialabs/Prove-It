# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, S
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Mult, Sum

# %%
# build up the expression from sub-expressions
subExpr1 = [b_1_to_j]
subExpr2 = Function(P, subExpr1)
expr = Forall([a_1_to_i, c_1_to_k], Equals(Mult(a_1_to_i, Sum(subExpr1, subExpr2, domain = S), c_1_to_k), Sum(subExpr1, Mult(a_1_to_i, subExpr2, c_1_to_k), domain = S)).withWrappingAt(2), domains = [Complexes, Complexes])
# Out:
# expr: forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left[\sum_{b_{1}, \ldots, b_{j} \in S}~P(b_{1}, \ldots, b_{j})\right] \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \left[\sum_{b_{1}, \ldots, b_{j} \in S}~\left(a_{1} \cdot \ldots \cdot a_{i} \cdot P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right)\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})] if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  c_{1} in Complexes ,  ..c_{_a} in Complexes.. ,  c_{k} in Complexes.
# ...
