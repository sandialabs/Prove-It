# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import And, InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = And(InSet(x, Complexes), InSet(y, Complexes))
# Out:
# expr: (x in Complexes) and (y in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{C}\right) \land \left(y \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in Complexes) and (y in Complexes)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x in Complexes, y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in Complexes
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. y in Complexes
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (y, Complexes)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. y
#    core type: Variable
#    sub-expressions:
# 10. Complexes
#     core type: Literal
#     sub-expressions:
