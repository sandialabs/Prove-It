# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x
from proveit.logic import Equals, InSet
from proveit.number import Complexes, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(Mult(one, x), x), InSet(x, Complexes)))
# Out:
# expr: x -> {(1 * x) = x if x in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{\left(1 \cdot x\right) = x \textrm{ if } x \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> {(1 * x) = x if x in Complexes.
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. {(1 * x) = x if x in Complexes.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (1 * x) = x
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Complexes
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (1 * x, x)
#    core type: ExprTuple
#    sub-expressions: 8, 13
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 8. 1 * x
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Complexes
#    core type: Literal
#    sub-expressions:
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (1, x)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
