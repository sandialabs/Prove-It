# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, e
from proveit.logic import InSet
from proveit.number import Mult, RealsPos

# %%
# build up the expression from sub-expressions
expr = InSet(Mult(a, b, c, d, e), RealsPos)
# Out:
# expr: (a * b * c * d * e) in RealsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \cdot b \cdot c \cdot d \cdot e\right) \in \mathbb{R}^+

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a * b * c * d * e) in RealsPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (a * b * c * d * e, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a * b * c * d * e
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. RealsPos
#    core type: Literal
#    sub-expressions:
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. d
#     core type: Variable
#     sub-expressions:
# 11. e
#     core type: Variable
#     sub-expressions:
