# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c, d, w, x, y, z
from proveit.logic import InSet
from proveit.number import Complexes, Integers

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(c, Complexes), InSet(d, Complexes), InSet(w, Complexes), InSet(x, Complexes), InSet(y, Complexes), InSet(z, Complexes), InSet(a, Integers), InSet(b, Integers))
# Out:
# expr: (c in Complexes, d in Complexes, w in Complexes, x in Complexes, y in Complexes, z in Complexes, a in Integers, b in Integers)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c \in \mathbb{C}, d \in \mathbb{C}, w \in \mathbb{C}, x \in \mathbb{C}, y \in \mathbb{C}, z \in \mathbb{C}, a \in \mathbb{Z}, b \in \mathbb{Z}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (c in Complexes, d in Complexes, w in Complexes, x in Complexes, y in Complexes, z in Complexes, a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7, 8
# 1. c in Complexes
#    core type: Operation
#    operator: 16
#    operands: 9
# 2. d in Complexes
#    core type: Operation
#    operator: 16
#    operands: 10
# 3. w in Complexes
#    core type: Operation
#    operator: 16
#    operands: 11
# 4. x in Complexes
#    core type: Operation
#    operator: 16
#    operands: 12
# 5. y in Complexes
#    core type: Operation
#    operator: 16
#    operands: 13
# 6. z in Complexes
#    core type: Operation
#    operator: 16
#    operands: 14
# 7. a in Integers
#    core type: Operation
#    operator: 16
#    operands: 15
# 8. b in Integers
#    core type: Operation
#    operator: 16
#    operands: 17
# 9. (c, Complexes)
#    core type: ExprTuple
#    sub-expressions: 18, 24
# 10. (d, Complexes)
#     core type: ExprTuple
# ...
