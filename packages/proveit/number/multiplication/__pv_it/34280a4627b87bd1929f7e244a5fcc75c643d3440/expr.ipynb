# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import a, b, i, j
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j
from proveit.logic import And, Equals, InSet
from proveit.number import Complexes, Mult, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Lambda([a_1_to_i, b_1_to_j], Conditional(Equals(Mult(a_1_to_i, zero, b_1_to_j), zero), And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Complexes), one, i), ExprRange(subExpr1, InSet(IndexedVar(b, subExpr1), Complexes), one, j))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0 if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  b_{1} in Complexes ,  ..b_{_a} in Complexes.. ,  b_{j} in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j}\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{i} \cdot 0 \cdot b_{1} \cdot \ldots \cdot b_{j}\right) = 0 \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b_{1} \in \mathbb{C} ,  \ldots ,  b_{j} \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0 if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  b_{1} in Complexes ,  ..b_{_a} in Complexes.. ,  b_{j} in Complexes.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j})
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 2. {(a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0 if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  b_{1} in Complexes ,  ..b_{_a} in Complexes.. ,  b_{j} in Complexes.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in Complexes) and ..(a_{_a} in Complexes).. and (a_{i} in Complexes) and (b_{1} in Complexes) and ..(b_{_a} in Complexes).. and (b_{j} in Complexes)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}, 0)
#    core type: ExprTuple
#    sub-expressions: 9, 17
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (a_{1} in Complexes), ..(a_{_a} in Complexes).., (a_{i} in Complexes)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 24
#     end_index: 22
# 11. (b_{1} in Complexes), ..(b_{_a} in Complexes).., (b_{j} in Complexes)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 24
#     end_index: 25
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a_{1}, ..a_{_a}.., a_{i}, 0, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 14. _a -> (a_{_a} in Complexes)
#     core type: Lambda
#     parameter: 34
#     body: 19
# 15. _a -> (b_{_a} in Complexes)
#     core type: Lambda
#     parameter: 34
#     body: 20
# 16. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 24
#     end_index: 22
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 19. a_{_a} in Complexes
#     core type: Operation
#     operator: 27
#     operands: 26
# 20. b_{_a} in Complexes
#     core type: Operation
#     operator: 27
#     operands: 28
# 21. _a -> a_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 29
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. _a -> b_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 30
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. j
#     core type: Variable
#     sub-expressions:
# 26. (a_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (b_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. a_{_a}
#     core type: IndexedVar
# variable: 32
# index: 34
# 30. b_{_a}
#     core type: IndexedVar
# variable: 33
# index: 34
# 31. Complexes
#     core type: Literal
#     sub-expressions:
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. b
#     core type: Variable
#     sub-expressions:
# 34. _a
#     core type: Variable
#     sub-expressions:
