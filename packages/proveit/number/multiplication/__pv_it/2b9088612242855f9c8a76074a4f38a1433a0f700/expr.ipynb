# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multRealNonNegClosureBin">multRealNonNegClosureBin</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._theorems_ import multRealNonNegClosureBin

# %%
# check that the built expression is the same as the stored expression
# %check_expr multRealNonNegClosureBin
# Out:
# Passed sanity check: built 'multRealNonNegClosureBin' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multRealNonNegClosureBin.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^{\ge 0}, b \in \mathbb{R}^{\ge 0}}~\left(\left(a \cdot b\right) \in \mathbb{R}^{\ge 0}\right)

# %%
# display the expression information
multRealNonNegClosureBin.exprInfo()
# Out:
# 0. forall_{a in RealsNonNeg, b in RealsNonNeg} ((a * b) in RealsNonNeg)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a * b) in RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(a * b) in RealsNonNeg if a in RealsNonNeg ,  b in RealsNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a * b) in RealsNonNeg
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a in RealsNonNeg) and (b in RealsNonNeg)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a * b, RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in RealsNonNeg, b in RealsNonNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in RealsNonNeg
# ...
