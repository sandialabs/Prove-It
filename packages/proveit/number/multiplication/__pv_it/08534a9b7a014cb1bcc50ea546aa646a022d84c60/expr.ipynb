# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.logic import Forall, InSet
from proveit.number import Mult, Naturals, RealsNonNeg

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a_1_to_n], InSet(Mult(a_1_to_n), RealsNonNeg), domain = RealsNonNeg), InSet(n, Naturals)))
# Out:
# expr: n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealsNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsNonNeg) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n} \in \mathbb{R}^{\ge 0}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{R}^{\ge 0}\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in RealsNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsNonNeg) if n in Naturals.
#    core type: Lambda
#    parameter: 23
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{n} in RealsNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsNonNeg) if n in Naturals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{n} in RealsNonNeg} ((a_{1} * ..a_{_a}.. * a_{n}) in RealsNonNeg)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Naturals
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) in RealsNonNeg if (a_{1} in RealsNonNeg) and ..(a_{_a} in RealsNonNeg).. and (a_{n} in RealsNonNeg).
#    core type: Lambda
#    parameter: 19
#    body: 7
# 6. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 23, 8
# ...
