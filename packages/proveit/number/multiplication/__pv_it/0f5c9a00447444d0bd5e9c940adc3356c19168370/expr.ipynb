# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multNatPosClosure">multNatPosClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._theorems_ import multNatPosClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr multNatPosClosure
# Out:
# Passed sanity check: built 'multNatPosClosure' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multNatPosClosure.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \mathbb{N}^+}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{N}^+\right)\right]

# %%
# display the expression information
multNatPosClosure.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos) if n in Naturals.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos) if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in NaturalsPos} ((a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
