# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#multDef">multDef</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._axioms_ import multDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr multDef
# Out:
# Passed sanity check: built 'multDef' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multDef.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}, x \in \mathbb{C}}~\left[\forall_{a_{1}, \ldots, a_{n} \in \left\{x\right\}}~\left(\left(n \cdot x\right) = \left(a_{1} + \ldots + a_{n}\right)\right)\right]

# %%
# display the expression information
multDef.exprInfo()
# Out:
# 0. forall_{n in Naturals, x in Complexes} [forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (n, x) -> {forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n})) if n in Naturals ,  x in Complexes.
#    core type: Lambda
#    parameters: 25\n   body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n})) if n in Naturals ,  x in Complexes.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (n in Naturals) and (x in Complexes)
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
