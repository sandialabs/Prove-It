# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import i, j, x, y
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j
from proveit.logic import And, Equals, Forall, InSet
from proveit.number import Add, Complexes, Mult, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i, x, y, b_1_to_j], Equals(Mult(a_1_to_i, Add(x, Neg(y)), b_1_to_j), Add(Mult(a_1_to_i, x, b_1_to_j), Neg(Mult(a_1_to_i, y, b_1_to_j)))).withWrappingAt(2), domains = [Complexes, Complexes, Complexes, Complexes]), And(InSet(i, Naturals), InSet(j, Naturals)))
# Out:
# expr: {forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, x in Complexes, y in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))) if i in Naturals ,  j in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, x \in \mathbb{C}, y \in \mathbb{C}, b_{1} \in \mathbb{C}, \ldots, b_{j} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(x - y\right) \cdot b_{1} \cdot \ldots \cdot b_{j}\right) =  \\ \left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot x \cdot b_{1} \cdot \ldots \cdot b_{j}\right) - \left(a_{1} \cdot \ldots \cdot a_{i} \cdot y \cdot b_{1} \cdot \ldots \cdot b_{j}\right)\right) \end{array}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, x in Complexes, y in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))) if i in Naturals ,  j in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, x in Complexes, y in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * (x - y) * b_{1} * ..b_{_a}.. * b_{j}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) - (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (i in Naturals) and (j in Naturals)
#    core type: Operation
#    operator: 16
# ...
