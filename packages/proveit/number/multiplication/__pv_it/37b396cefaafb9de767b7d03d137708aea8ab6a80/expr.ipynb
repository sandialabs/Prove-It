# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n, x
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.logic import Equals, Forall, Set
from proveit.number import Add, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_n], Equals(Mult(n, x), Add(a_1_to_n)), domain = Set(x))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{n} \in \left\{x\right\}}~\left(\left(n \cdot x\right) = \left(a_{1} + \ldots + a_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{n} in {x}} ((n * x) = (a_{1} + ..a_{_a}.. + a_{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1}, ..a_{_a}.., a_{n}) -> {(n * x) = (a_{1} + ..a_{_a}.. + a_{n}) if (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x}).
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. {(n * x) = (a_{1} + ..a_{_a}.. + a_{n}) if (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (n * x) = (a_{1} + ..a_{_a}.. + a_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1} in {x}) and ..(a_{_a} in {x}).. and (a_{n} in {x})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (n * x, a_{1} + ..a_{_a}.. + a_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} in {x}, ..a_{_a} in {x}.., a_{n} in {x})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. n * x
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. a_{1} + ..a_{_a}.. + a_{n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (a_{1} in {x}), ..(a_{_a} in {x}).., (a_{n} in {x})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (n, x)
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (a_{_a} in {x})
#     core type: Lambda
#     parameter: 28
#     body: 19
# 18. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. a_{_a} in {x}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> a_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (a_{_a}, {x})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. a_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. {x}
#     core type: Operation
#     operator: 29
#     operand: 30
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
# 29. Set
#     core type: Literal
#     sub-expressions:
# 30. x
#     core type: Variable
#     sub-expressions:
