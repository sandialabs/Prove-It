# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Function
from proveit._common_ import P, S, i, j, k
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.number import Complexes, Mult, Naturals, Sum

# %%
# build up the expression from sub-expressions
subExpr1 = [b_1_to_j]
subExpr2 = Function(P, subExpr1)
expr = Conditional(Forall([P, S], Implies(Forall(subExpr1, InSet(subExpr2, Complexes), domain = S), Forall([a_1_to_i, c_1_to_k], Equals(Mult(a_1_to_i, Sum(subExpr1, subExpr2, domain = S), c_1_to_k), Sum(subExpr1, Mult(a_1_to_i, subExpr2, c_1_to_k), domain = S)).withWrappingAt(2), domains = [Complexes, Complexes]))), And(InSet(i, Naturals), InSet(j, Naturals), InSet(k, Naturals)))
# Out:
# expr: {forall_{P, S} ([forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)] => [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])]) if i in Naturals ,  j in Naturals ,  k in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P, S}~\left(\left[\forall_{b_{1}, \ldots, b_{j} \in S}~\left(P(b_{1}, \ldots, b_{j}) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left[\sum_{b_{1}, \ldots, b_{j} \in S}~P(b_{1}, \ldots, b_{j})\right] \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \left[\sum_{b_{1}, \ldots, b_{j} \in S}~\left(a_{1} \cdot \ldots \cdot a_{i} \cdot P(b_{1}, \ldots, b_{j}) \cdot c_{1} \cdot \ldots \cdot c_{k}\right)\right] \end{array}\right)\right]\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{P, S} ([forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)] => [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])]) if i in Naturals ,  j in Naturals ,  k in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, S} ([forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)] => [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])])
#    core type: Operation
#    operator: 19
#    operand: 3
# 2. (i in Naturals) and (j in Naturals) and (k in Naturals)
#    core type: Operation
#    operator: 56
#    operands: 4
# 3. (P, S) -> ([forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)] => [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])])
#    core type: Lambda
#    parameters: 5\n   body: 6
# 4. (i in Naturals, j in Naturals, k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 5. (P, S)
#    core type: ExprTuple
#    sub-expressions: 60, 78
# 6. [forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)] => [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])]
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. i in Naturals
#    core type: Operation
#    operator: 75
#    operands: 12
# 8. j in Naturals
#    core type: Operation
#    operator: 75
#    operands: 13
# 9. k in Naturals
#    core type: Operation
#    operator: 75
#    operands: 14
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes), forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})]))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (i, Naturals)
#     core type: ExprTuple
#     sub-expressions: 59, 17
# 13. (j, Naturals)
#     core type: ExprTuple
#     sub-expressions: 72, 17
# 14. (k, Naturals)
#     core type: ExprTuple
#     sub-expressions: 63, 17
# 15. forall_{b_{1}, ..b_{_a}.., b_{j} in S} (P(b_{1}, ..b_{_a}.., b_{j}) in Complexes)
#     core type: Operation
#     operator: 19
#     operand: 18
# 16. forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})])
#     core type: Operation
#     operator: 19
#     operand: 20
# 17. Naturals
#     core type: Literal
#     sub-expressions:
# 18. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) in Complexes if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Lambda
#     parameter: 66
#     body: 21
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k}) -> {(a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})] if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  c_{1} in Complexes ,  ..c_{_a} in Complexes.. ,  c_{k} in Complexes.
#     core type: Lambda
#     parameters: 22\n    body: 23
# 21. {P(b_{1}, ..b_{_a}.., b_{j}) in Complexes if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Conditional
#     value: 24
#     condition: 52
# 22. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 23. {(a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})] if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  c_{1} in Complexes ,  ..c_{_a} in Complexes.. ,  c_{k} in Complexes.
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. P(b_{1}, ..b_{_a}.., b_{j}) in Complexes
#     core type: Operation
#     operator: 75
#     operands: 27
# 25. (a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}) =  \\ [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})]
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (a_{1} in Complexes) and ..(a_{_a} in Complexes).. and (a_{i} in Complexes) and (c_{1} in Complexes) and ..(c_{_a} in Complexes).. and (c_{k} in Complexes)
#     core type: Operation
#     operator: 56
#     operands: 30
# 27. (P(b_{1}, ..b_{_a}.., b_{j}), Complexes)
#     core type: ExprTuple
#     sub-expressions: 54, 51
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}, Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. a_{1} * ..a_{_a}.. * a_{i} * [Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})] * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 49
#     operands: 35
# 32. Sum_{b_{1}, ..b_{_a}.., b_{j} in S} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k})
#     core type: Operation
#     operator: 43
#     operand: 36
# 33. (a_{1} in Complexes), ..(a_{_a} in Complexes).., (a_{i} in Complexes)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 71
#     end_index: 59
# 34. (c_{1} in Complexes), ..(c_{_a} in Complexes).., (c_{k} in Complexes)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 71
#     end_index: 63
# 35. (a_{1}, ..a_{_a}.., a_{i}, Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 53, 39, 55
# 36. (b_{1}, ..b_{_a}.., b_{j}) -> {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Lambda
#     parameter: 66
#     body: 40
# 37. _a -> (a_{_a} in Complexes)
#     core type: Lambda
#     parameter: 80
#     body: 41
# 38. _a -> (c_{_a} in Complexes)
#     core type: Lambda
#     parameter: 80
#     body: 42
# 39. Sum_{b_{1}, ..b_{_a}.., b_{j} in S} P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 43
#     operand: 44
# 40. {a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k} if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Conditional
#     value: 45
#     condition: 52
# 41. a_{_a} in Complexes
#     core type: Operation
#     operator: 75
#     operands: 46
# 42. c_{_a} in Complexes
#     core type: Operation
#     operator: 75
#     operands: 47
# 43. Sum
#     core type: Literal
#     sub-expressions:
# 44. (b_{1}, ..b_{_a}.., b_{j}) -> {P(b_{1}, ..b_{_a}.., b_{j}) if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Lambda
#     parameter: 66
#     body: 48
# 45. a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. (a_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 65, 51
# 47. (c_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 67, 51
# 48. {P(b_{1}, ..b_{_a}.., b_{j}) if (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S).
#     core type: Conditional
#     value: 54
#     condition: 52
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (a_{1}, ..a_{_a}.., a_{i}, P(b_{1}, ..b_{_a}.., b_{j}), c_{1}, ..c_{_a}.., c_{k})
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55
# 51. Complexes
#     core type: Literal
#     sub-expressions:
# 52. (b_{1} in S) and ..(b_{_a} in S).. and (b_{j} in S)
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 71
#     end_index: 59
# 54. P(b_{1}, ..b_{_a}.., b_{j})
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 71
#     end_index: 63
# 56. and
#     core type: Literal
#     sub-expressions:
# 57. (b_{1} in S, ..b_{_a} in S.., b_{j} in S)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 65
# 59. i
#     core type: Variable
#     sub-expressions:
# 60. P
#     core type: Variable
#     sub-expressions:
# 61. (b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 66
# 62. _a -> c_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 67
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. (b_{1} in S), ..(b_{_a} in S).., (b_{j} in S)
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 71
#     end_index: 72
# 65. a_{_a}
#     core type: IndexedVar
# variable: 69
# index: 80
# 66. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 71
#     end_index: 72
# 67. c_{_a}
#     core type: IndexedVar
# variable: 73
# index: 80
# 68. _a -> (b_{_a} in S)
#     core type: Lambda
#     parameter: 80
#     body: 74
# 69. a
#     core type: Variable
#     sub-expressions:
# 70. _a -> b_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 77
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. j
#     core type: Variable
#     sub-expressions:
# 73. c
#     core type: Variable
#     sub-expressions:
# 74. b_{_a} in S
#     core type: Operation
#     operator: 75
#     operands: 76
# 75. in
#     core type: Literal
#     sub-expressions:
# 76. (b_{_a}, S)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 77. b_{_a}
#     core type: IndexedVar
# variable: 79
# index: 80
# 78. S
#     core type: Variable
#     sub-expressions:
# 79. b
#     core type: Variable
#     sub-expressions:
# 80. _a
#     core type: Variable
#     sub-expressions:
