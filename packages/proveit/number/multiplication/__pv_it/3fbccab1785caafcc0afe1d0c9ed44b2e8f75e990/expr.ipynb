# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Mult, RealsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Mult(a, b), RealsPos), And(InSet(a, RealsPos), InSet(b, RealsPos)))
# Out:
# expr: {(a * b) in RealsPos if a in RealsPos ,  b in RealsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \cdot b\right) \in \mathbb{R}^+ \textrm{ if } a \in \mathbb{R}^+ ,  b \in \mathbb{R}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a * b) in RealsPos if a in RealsPos ,  b in RealsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a * b) in RealsPos
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in RealsPos) and (b in RealsPos)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a * b, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in RealsPos, b in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in RealsPos
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in RealsPos
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (a, RealsPos)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, RealsPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. RealsPos
#     core type: Literal
#     sub-expressions:
