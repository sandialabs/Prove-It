# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B, x
from proveit.logic import Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], InSet(x, B), domain = A), SubsetEq(A, B))
# Out:
# expr: {forall_{x in A} (x in B) if A subseteq B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in A}~\left(x \in B\right) \textrm{ if } A \subseteq B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x in A} (x in B) if A subseteq B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. A subseteq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {x in B if x in A.
#    core type: Lambda
#    parameter: 14
#    body: 7
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 7. {x in B if x in A.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. x in B
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. x in A
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, B)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x, A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
