# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Forall, InSet
from proveit.number import Complexes, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], InSet(Mult(a, b), Complexes), domains = [Complexes, Complexes])
# Out:
# expr: forall_{a in Complexes, b in Complexes} ((a * b) in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{C}, b \in \mathbb{C}}~\left(\left(a \cdot b\right) \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in Complexes, b in Complexes} ((a * b) in Complexes)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a * b) in Complexes if a in Complexes ,  b in Complexes.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(a * b) in Complexes if a in Complexes ,  b in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a * b) in Complexes
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a in Complexes) and (b in Complexes)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a * b, Complexes)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Complexes, b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Complexes
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. b in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (a, Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. Complexes
#     core type: Literal
#     sub-expressions:
