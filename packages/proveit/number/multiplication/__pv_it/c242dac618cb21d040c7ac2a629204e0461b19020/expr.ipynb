# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#distributeThroughSum">distributeThroughSum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.multiplication._theorems_ import distributeThroughSum

# %%
# check that the built expression is the same as the stored expression
# %check_expr distributeThroughSum
# Out:
# Passed sanity check: built 'distributeThroughSum' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distributeThroughSum.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}, j \in \mathbb{N}, k \in \mathbb{N}}~\left[\forall_{a_{1} \in \mathbb{C}, \ldots, a_{i} \in \mathbb{C}, b_{1} \in \mathbb{C}, \ldots, b_{j} \in \mathbb{C}, c_{1} \in \mathbb{C}, \ldots, c_{k} \in \mathbb{C}}~\left(\begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot \left(b_{1} + \ldots + b_{j}\right) \cdot c_{1} \cdot \ldots \cdot c_{k}\right) =  \\ \left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{1} \cdot c_{1} \cdot \ldots \cdot c_{k}\right) + \ldots + \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{j} \cdot c_{1} \cdot \ldots \cdot c_{k}\right)\right) \end{array}\right)\right]

# %%
# display the expression information
distributeThroughSum.exprInfo()
# Out:
# 0. forall_{i in Naturals, j in Naturals, k in Naturals} [forall_{a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b_{1} in Complexes, ..b_{_a} in Complexes.., b_{j} in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{k} in Complexes} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} + ..b_{_a}.. + b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * c_{1} * ..c_{_a}.. * c_{k}) + ..(a_{1} * ..a_{_a}.. * a_{i} * b_{n} * c_{1} * ..c_{_a}.. * c_{k}).. + (a_{1} * ..a_{_a}.. * a_{i} * b_{j} * c_{1} * ..c_{_a}.. * c_{k})))]
#    core type: Operation
#    operator: 6
#    operand: 1
# ...
