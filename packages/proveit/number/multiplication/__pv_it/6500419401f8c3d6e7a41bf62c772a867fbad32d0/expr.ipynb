# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import a, n
from proveit.logic import And, InSet
from proveit.number import Integers, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Integers), one, n))
# Out:
# expr: (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{n} in Integers)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{Z}\right) \land \ldots \land \left(a_{n} \in \mathbb{Z}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{n} in Integers)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} in Integers, ..a_{_a} in Integers.., a_{n} in Integers)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1} in Integers), ..(a_{_a} in Integers).., (a_{n} in Integers)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> (a_{_a} in Integers)
#    core type: Lambda
#    parameter: 13
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. a_{_a} in Integers
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a_{_a}, Integers)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 11. Integers
#     core type: Literal
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
