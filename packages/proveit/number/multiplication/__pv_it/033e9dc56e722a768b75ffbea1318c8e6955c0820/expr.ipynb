# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit._common_ import a, n
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.logic import And, InSet
from proveit.number import Mult, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Conditional(InSet(Mult(a_1_to_n), NaturalsPos), And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), NaturalsPos), one, n)))
# Out:
# expr: {(a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos if (a_{1} in NaturalsPos) and ..(a_{_a} in NaturalsPos).. and (a_{n} in NaturalsPos).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \in \mathbb{N}^+ \textrm{ if } \left(a_{1} \in \mathbb{N}^+\right) \land \ldots \land \left(a_{n} \in \mathbb{N}^+\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos if (a_{1} in NaturalsPos) and ..(a_{_a} in NaturalsPos).. and (a_{n} in NaturalsPos).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * ..a_{_a}.. * a_{n}) in NaturalsPos
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (a_{1} in NaturalsPos) and ..(a_{_a} in NaturalsPos).. and (a_{n} in NaturalsPos)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} * ..a_{_a}.. * a_{n}, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6, 19
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} in NaturalsPos, ..a_{_a} in NaturalsPos.., a_{n} in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in NaturalsPos), ..(a_{_a} in NaturalsPos).., (a_{n} in NaturalsPos)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# ...
