# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar, Variable
from proveit._common_ import a
from proveit.logic import InSet
from proveit.number._common_ import ComplexesSansZero

# %%
# build up the expression from sub-expressions
expr = InSet(IndexedVar(a, Variable("_a", latexFormat = r"{_{-}a}")), ComplexesSansZero)
# Out:
# expr: a_{_a} in (Complexes - {0})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a_{{_{-}a}} \in \left(\mathbb{C} - \left\{0\right\}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_{_a} in (Complexes - {0})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (a_{_a}, Complexes - {0})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 4. Complexes - {0}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. a
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
# 7. -
#    core type: Literal
#    sub-expressions:
# 8. (Complexes, {0})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. Complexes
#    core type: Literal
#    sub-expressions:
# 10. {0}
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. 0
#     core type: Literal
#     sub-expressions:
