# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import c
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_j, d_1_to_k
from proveit.logic import Equals
from proveit.number import Mult

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(a_1_to_i, b_1_to_j, c, d_1_to_k), Mult(a_1_to_i, c, b_1_to_j, d_1_to_k)).withWrappingAt(2)
# Out:
# expr: (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(a_{1} \cdot \ldots \cdot a_{i} \cdot b_{1} \cdot \ldots \cdot b_{j} \cdot c \cdot d_{1} \cdot \ldots \cdot d_{k}\right) =  \\ \left(a_{1} \cdot \ldots \cdot a_{i} \cdot c \cdot b_{1} \cdot \ldots \cdot b_{j} \cdot d_{1} \cdot \ldots \cdot d_{k}\right) \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}, a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 10, 9, 11
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (a_{1}, ..a_{_a}.., a_{i}, c, b_{1}, ..b_{_a}.., b_{j}, d_{1}, ..d_{_a}.., d_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 17
#    end_index: 13
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 17
#     end_index: 15
# 11. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 12. _a -> a_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 19
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. _a -> b_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 20
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. _a -> d_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. a_{_a}
#     core type: IndexedVar
# variable: 22
# index: 25
# 20. b_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 21. d_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. d
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
