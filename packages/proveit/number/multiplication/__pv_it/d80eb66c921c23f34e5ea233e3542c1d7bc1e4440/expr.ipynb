# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x, y
from proveit.logic import And, Equals, InSet
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(Equals(Neg(Mult(x, Neg(y))), Mult(x, y)), And(InSet(x, Complexes), InSet(y, Complexes))))
# Out:
# expr: (x, y) -> {(-(x * (-y))) = (x * y) if x in Complexes ,  y in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\left(-\left(x \cdot \left(-y\right)\right)\right) = \left(x \cdot y\right) \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, y) -> {(-(x * (-y))) = (x * y) if x in Complexes ,  y in Complexes.
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {(-(x * (-y))) = (x * y) if x in Complexes ,  y in Complexes.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (-(x * (-y))) = (x * y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x in Complexes) and (y in Complexes)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (-(x * (-y)), x * y)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in Complexes, y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. -(x * (-y))
#    core type: Operation
#    operator: 22
#    operand: 12
# 9. x * y
#    core type: Operation
#    operator: 17
#    operands: 13
# 10. x in Complexes
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. y in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. x * (-y)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (x, y)
#     core type: ExprTuple
#     sub-expressions: 20, 23
# 14. (x, Complexes)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (y, Complexes)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (x, -y)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. Complexes
#     core type: Literal
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. -y
#     core type: Operation
#     operator: 22
#     operand: 23
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
