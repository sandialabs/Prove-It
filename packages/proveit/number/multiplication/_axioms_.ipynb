# %% [markdown]
# Axioms for context <a href="_context_.ipynb" class="ProveItLink">proveit.number.multiplication</a>
# ========

# %%
import proveit
from proveit import varIter, Iter, Indexed
from proveit.logic import Forall, Equals
from proveit._common_ import A, i, m,x
from proveit.number import one, two, Mult, Add, Complexes, Naturals
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin axioms
# Out:
# Defining axioms for context 'proveit.number.multiplication'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %%
multDef = Forall(m, Forall((A,x), Equals(Add(varIter(A, one,m)),Mult(m, x)), conditions=[Iter(i, Equals(Indexed(A,i), x), one, m)], domain = Complexes), domain = Naturals)
# Out:
# multDef: forall_{m in Naturals} [forall_{A, x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))]

# %%
# %end axioms
# Out:
# Modifying axiom multDef in proveit.number.multiplication context
# multDef expression notebook is being updated
# Axioms may be imported from autogenerated _axioms_.py
