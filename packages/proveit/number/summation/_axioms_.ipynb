# %% [markdown]
# Axioms for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.number.summation</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the axioms of a theory:
# %axioms_notebook # Keep this at the top following 'import proveit'.
from proveit.logic import Implies, Forall, Equals, InSet
from proveit.number import Add, Exp, Mult, Sum
# removed Frac, Substract from the line above
from proveit.number import Natural, NaturalPos, Integer, Real
from proveit.number import Complex, Interval, zero, one, two, three, infinity
from proveit._common_ import a, f, i, m, n, x, fa, fx, P, Px, S, Q

# %%
# %begin axioms

# %%
sumSingle = Forall(f,
                   Forall(a,
                          Equals(Sum(x, fx, domain=Interval(a,a)), fa),
                          domain=Integer)
                  )

# %%
# %end axioms
