# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.number.summation</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit.logic import Implies, Forall, Equals, InSet
from proveit.number import Add, Div, Exp, frac, Mult, subtract, Sum
# removed Frac, Substract from line above; added Div, frac, substract
from proveit.number import Natural, NaturalPos, Integer, Real
from proveit.number import Complex, Interval, zero, one, two, infinity
from proveit._common_ import i, m, n, x, P, Px, S, Q

# %%
# %begin theorems

# %%
"""
summationNatsClosure = Forall([P, S, Qmulti], Implies(Forall(xMulti, InSet(PxEtc, Natural), domain=S, conditions=etc_QxEtc), 
                                              InSet(Sum(xMulti, PxEtc, domain=S, conditions=etc_QxEtc), domain=Natural)))

"""

# %%
"""
summationIntsClosure = Forall([P, S, Qmulti], Implies(Forall(xMulti, InSet(PxEtc, Integer), domain=S, conditions=etc_QxEtc), 
                                              InSet(Sum(xMulti, PxEtc, domain=S, conditions=etc_QxEtc), domain=Integer)))
"""

# %%
"""
summationRealClosure = Forall([P, S, Qmulti], Implies(Forall(xMulti, InSet(PxEtc, Real), domain=S, conditions=etc_QxEtc), 
                                              InSet(Sum(xMulti, PxEtc, domain=S, conditions=etc_QxEtc), domain=Real)))
"""

# %%
"""
summationComplexClosure = Forall([P, S, Qmulti], Implies(Forall(xMulti, InSet(PxEtc, Complex), domain=S, conditions=etc_QxEtc), 
                                              InSet(Sum(xMulti, PxEtc, domain=S, conditions=etc_QxEtc), Complex)))
"""

# %%
infGeomSum = Forall(x, Equals(Sum(m,Exp(x,m),
                                  domain=Interval(zero,infinity)), 
                              frac(one,subtract(one,x))),
                    domain=Complex)

# %%
sumFirstNInt = Forall(n,
                       Equals( Sum(i, i, domain=Interval(one, n)),
                               frac(Mult(n, Add(n, one)), two) ),
                       domain=NaturalPos)

# %%
# %end theorems
