# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#floorOfRealPlusInt">floorOfRealPlusInt</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.rounding._theorems_ import floorOfRealPlusInt

# %%
# check that the built expression is the same as the stored expression
# %check_expr floorOfRealPlusInt
# Out:
# Passed sanity check: built 'floorOfRealPlusInt' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floorOfRealPlusInt.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left[\forall_{n \in \mathbb{Z}}~\left(\lfloor x + n\rfloor = \left(\lfloor x\rfloor + n\right)\right)\right]

# %%
# display the expression information
floorOfRealPlusInt.exprInfo()
# Out:
# 0. forall_{x in Reals} [forall_{n in Integers} (floor(x + n) = (floor(x) + n))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> {forall_{n in Integers} (floor(x + n) = (floor(x) + n)) if x in Reals.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{n in Integers} (floor(x + n) = (floor(x) + n)) if x in Reals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in Integers} (floor(x + n) = (floor(x) + n))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. x in Reals
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. n -> {floor(x + n) = (floor(x) + n) if n in Integers.
#    core type: Lambda
#    parameter: 24
#    body: 8
# 7. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 8. {floor(x + n) = (floor(x) + n) if n in Integers.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Reals
# ...
