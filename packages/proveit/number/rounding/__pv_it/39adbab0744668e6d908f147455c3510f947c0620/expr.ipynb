# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals
from proveit.number import Add, Floor, one

# %%
# build up the expression from sub-expressions
expr = Equals(Floor(Add(x, one, y)), Add(Floor(Add(x, y)), one))
# Out:
# expr: floor(x + 1 + y) = (floor(x + y) + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lfloor x + 1 + y\rfloor = \left(\lfloor x + y\rfloor + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. floor(x + 1 + y) = (floor(x + y) + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (floor(x + 1 + y), floor(x + y) + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. floor(x + 1 + y)
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. floor(x + y) + 1
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. x + 1 + y
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (floor(x + y), 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x, 1, y)
#    core type: ExprTuple
#    sub-expressions: 14, 9, 15
# 8. floor(x + y)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. floor
#     core type: Literal
#     sub-expressions:
# 11. x + y
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (x, y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
