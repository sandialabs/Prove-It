# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals
from proveit.number import Add, Ceil, Neg

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(y)
expr = Equals(Ceil(Add(x, subExpr1).withSubtractionAt()), Add(Ceil(x), subExpr1).withSubtractionAt())
# Out:
# expr: ceil(x + (-y)) = (ceil(x) + (-y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lceil x + \left(-y\right)\rceil = \left(\lceil x\rceil + \left(-y\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ceil(x + (-y)) = (ceil(x) + (-y))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (ceil(x + (-y)), ceil(x) + (-y))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ceil(x + (-y))
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. ceil(x) + (-y)
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. x + (-y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (ceil(x), -y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (x, -y)
#    core type: ExprTuple
#    sub-expressions: 12, 10
# 9. ceil(x)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. -y
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. ceil
#     core type: Literal
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. y
#     core type: Variable
#     sub-expressions:
