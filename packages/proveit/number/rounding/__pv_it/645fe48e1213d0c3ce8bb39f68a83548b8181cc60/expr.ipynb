# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x, y
from proveit.logic import And, InSet
from proveit.number import Add, Ceil, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(LessEq(Ceil(Add(x, y)), Add(Ceil(x), Ceil(y))), And(InSet(x, Reals), InSet(y, Reals))))
# Out:
# expr: (x, y) -> {ceil(x + y) <= (ceil(x) + ceil(y)) if x in Reals ,  y in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\lceil x + y\rceil \leq \left(\lceil x\rceil + \lceil y\rceil\right) \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, y) -> {ceil(x + y) <= (ceil(x) + ceil(y)) if x in Reals ,  y in Reals.
#    core type: Lambda
#    parameters: 18\n   body: 1
# 1. {ceil(x + y) <= (ceil(x) + ceil(y)) if x in Reals ,  y in Reals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ceil(x + y) <= (ceil(x) + ceil(y))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x in Reals) and (y in Reals)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <=
#    core type: Literal
#    sub-expressions:
# 5. (ceil(x + y), ceil(x) + ceil(y))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in Reals, y in Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. ceil(x + y)
#    core type: Operation
#    operator: 23
#    operand: 12
# 9. ceil(x) + ceil(y)
#    core type: Operation
#    operator: 17
#    operands: 13
# 10. x in Reals
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. y in Reals
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. x + y
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (ceil(x), ceil(y))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (y, Reals)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (x, y)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 19. ceil(x)
#     core type: Operation
#     operator: 23
#     operand: 22
# 20. ceil(y)
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. ceil
#     core type: Literal
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
