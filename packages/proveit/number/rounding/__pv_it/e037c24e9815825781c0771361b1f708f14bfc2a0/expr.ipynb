# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#floorLessEqCeil">floorLessEqCeil</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.rounding._theorems_ import floorLessEqCeil

# %%
# check that the built expression is the same as the stored expression
# %check_expr floorLessEqCeil
# Out:
# Passed sanity check: built 'floorLessEqCeil' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floorLessEqCeil.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left(\lfloor x\rfloor \leq \lceil x\rceil\right)

# %%
# display the expression information
floorLessEqCeil.exprInfo()
# Out:
# 0. forall_{x in Reals} (floor(x) <= ceil(x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {floor(x) <= ceil(x) if x in Reals.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {floor(x) <= ceil(x) if x in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. floor(x) <= ceil(x)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (floor(x), ceil(x))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. floor(x)
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. ceil(x)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. Reals
#     core type: Literal
# ...
