# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#floorOfCeil">floorOfCeil</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.rounding._theorems_ import floorOfCeil

# %%
# check that the built expression is the same as the stored expression
# %check_expr floorOfCeil
# Out:
# Passed sanity check: built 'floorOfCeil' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(floorOfCeil.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}}~\left(\lfloor \lceil x\rceil\rfloor = \lceil x\rceil\right)

# %%
# display the expression information
floorOfCeil.exprInfo()
# Out:
# 0. forall_{x in Reals} (floor(ceil(x)) = ceil(x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {floor(ceil(x)) = ceil(x) if x in Reals.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {floor(ceil(x)) = ceil(x) if x in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. floor(ceil(x)) = ceil(x)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (floor(ceil(x)), ceil(x))
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 10. floor(ceil(x))
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. Reals
#     core type: Literal
#     sub-expressions:
# 12. floor
#     core type: Literal
# ...
