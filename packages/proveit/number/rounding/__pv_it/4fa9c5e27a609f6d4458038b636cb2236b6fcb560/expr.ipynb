# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n, x
from proveit.logic import Equals, InSet
from proveit.number import Add, Integers, Round

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Equals(Round(Add(x, n)), Add(Round(x), n)), InSet(n, Integers)))
# Out:
# expr: n -> {round(x + n) = (round(x) + n) if n in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{round(x + n) = \left(round(x) + n\right) \textrm{ if } n \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {round(x + n) = (round(x) + n) if n in Integers.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {round(x + n) = (round(x) + n) if n in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. round(x + n) = (round(x) + n)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. n in Integers
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (round(x + n), round(x) + n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Integers)
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 8. round(x + n)
#    core type: Operation
#    operator: 17
#    operand: 11
# 9. round(x) + n
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. Integers
#     core type: Literal
#     sub-expressions:
# 11. x + n
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (round(x), n)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (x, n)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 15. round(x)
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. round
#     core type: Literal
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
