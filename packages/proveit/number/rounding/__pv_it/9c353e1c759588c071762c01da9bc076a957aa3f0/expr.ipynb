# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import x, y
from proveit.number import Add, Mult, Round, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(x, y)
expr = ExprTuple(Round(Add(subExpr1, Add(one, two))), Round(Add(subExpr1, three)))
# Out:
# expr: (round((x * y) + (1 + 2)), round((x * y) + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(round(\left(x \cdot y\right) + \left(1 + 2\right)), round(\left(x \cdot y\right) + 3)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (round((x * y) + (1 + 2)), round((x * y) + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. round((x * y) + (1 + 2))
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. round((x * y) + 3)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x * y) + (1 + 2)
#    core type: Operation
#    operator: 11
#    operands: 6
# 4. round
#    core type: Literal
#    sub-expressions:
# 5. (x * y) + 3
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. (x * y, 1 + 2)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 7. (x * y, 3)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 1 + 2
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. x * y
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (x, y)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
