# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import alpha, beta
from proveit.number import Add, Floor, Integers

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Floor(Add(alpha, beta)), Integers)
# Out:
# expr: (floor(alpha + beta), Integers)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\lfloor \alpha + \beta\rfloor, \mathbb{Z}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (floor(alpha + beta), Integers)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. floor(alpha + beta)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. Integers
#    core type: Literal
#    sub-expressions:
# 3. floor
#    core type: Literal
#    sub-expressions:
# 4. alpha + beta
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (alpha, beta)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. alpha
#    core type: Variable
#    sub-expressions:
# 8. beta
#    core type: Variable
#    sub-expressions:
