# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x
from proveit.logic import Equals, InSet
from proveit.number import Integers, Round

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Equals(Round(x), x), InSet(x, Integers)))
# Out:
# expr: x -> {round(x) = x if x in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{round(x) = x \textrm{ if } x \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> {round(x) = x if x in Integers.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {round(x) = x if x in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. round(x) = x
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in Integers
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (round(x), x)
#    core type: ExprTuple
#    sub-expressions: 8, 11
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Integers)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 8. round(x)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. Integers
#    core type: Literal
#    sub-expressions:
# 10. round
#     core type: Literal
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
