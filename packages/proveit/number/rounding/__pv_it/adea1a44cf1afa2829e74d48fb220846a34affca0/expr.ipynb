# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Forall([a_1_to_i], InSet(Add(a_1_to_i), Reals), domain = Reals), InSet(i, Naturals)))
# Out:
# expr: i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals) if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\forall_{a_{1}, \ldots, a_{i} \in \mathbb{R}}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{R}\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals) if i in Naturals.
#    core type: Lambda
#    parameter: 23
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals) if i in Naturals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{i} in Reals} ((a_{1} + ..a_{_a}.. + a_{i}) in Reals)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. i in Naturals
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in Reals if (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals).
#    core type: Lambda
#    parameter: 19
#    body: 7
# 6. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 23, 8
# 7. {(a_{1} + ..a_{_a}.. + a_{i}) in Reals if (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals).
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} + ..a_{_a}.. + a_{i}) in Reals
#    core type: Operation
#    operator: 24
#    operands: 11
# 10. (a_{1} in Reals) and ..(a_{_a} in Reals).. and (a_{i} in Reals)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a_{1} + ..a_{_a}.. + a_{i}, Reals)
#     core type: ExprTuple
#     sub-expressions: 14, 27
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (a_{1} in Reals, ..a_{_a} in Reals.., a_{i} in Reals)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. a_{1} + ..a_{_a}.. + a_{i}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (a_{1} in Reals), ..(a_{_a} in Reals).., (a_{i} in Reals)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 22
#     end_index: 23
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. _a -> (a_{_a} in Reals)
#     core type: Lambda
#     parameter: 29
#     body: 20
# 19. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. a_{_a} in Reals
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. _a -> a_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. i
#     core type: Variable
#     sub-expressions:
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (a_{_a}, Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. a_{_a}
#     core type: IndexedVar
# variable: 28
# index: 29
# 27. Reals
#     core type: Literal
#     sub-expressions:
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. _a
#     core type: Variable
#     sub-expressions:
