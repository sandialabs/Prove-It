# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x, y
from proveit.logic import And, InSet
from proveit.number import Add, Floor, LessEq, Reals, one

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Floor(Add(x, y)), Add(Floor(x), Floor(y), one)), And(InSet(x, Reals), InSet(y, Reals)))
# Out:
# expr: {floor(x + y) <= (floor(x) + floor(y) + 1) if x in Reals ,  y in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lfloor x + y\rfloor \leq \left(\lfloor x\rfloor + \lfloor y\rfloor + 1\right) \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {floor(x + y) <= (floor(x) + floor(y) + 1) if x in Reals ,  y in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. floor(x + y) <= (floor(x) + floor(y) + 1)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Reals) and (y in Reals)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (floor(x + y), floor(x) + floor(y) + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Reals, y in Reals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. floor(x + y)
#    core type: Operation
#    operator: 23
#    operand: 11
# 8. floor(x) + floor(y) + 1
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. x in Reals
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. y in Reals
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x + y
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (floor(x), floor(y), 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 13. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y, Reals)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (x, y)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 18. floor(x)
#     core type: Operation
#     operator: 23
#     operand: 22
# 19. floor(y)
#     core type: Operation
#     operator: 23
#     operand: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. floor
#     core type: Literal
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
