# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals
from proveit.number import Add, Round, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(x, y, two)
expr = Equals(Round(Add(subExpr1, one)), Add(Round(subExpr1), one))
# Out:
# expr: round((x + y + 2) + 1) = (round(x + y + 2) + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# round(\left(x + y + 2\right) + 1) = \left(round(x + y + 2) + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. round((x + y + 2) + 1) = (round(x + y + 2) + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (round((x + y + 2) + 1), round(x + y + 2) + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. round((x + y + 2) + 1)
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. round(x + y + 2) + 1
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (x + y + 2) + 1
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (round(x + y + 2), 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x + y + 2, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 8. round(x + y + 2)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. round
#     core type: Literal
#     sub-expressions:
# 11. x + y + 2
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (x, y, 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
