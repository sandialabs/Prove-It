# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Forall, InSet
from proveit.number import Add, Integers, Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([i], Forall([a_1_to_i], InSet(Add(a_1_to_i), Integers), domain = Integers), domain = Naturals)
# Out:
# expr: forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{i} \in \mathbb{Z}}~\left(\left(a_{1} + \ldots + a_{i}\right) \in \mathbb{Z}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers) if i in Naturals.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i} in Integers} ((a_{1} + ..a_{_a}.. + a_{i}) in Integers)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}) -> {(a_{1} + ..a_{_a}.. + a_{i}) in Integers if (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{i} in Integers).
#    core type: Lambda
#    parameter: 20
#    body: 8
# 7. (i, Naturals)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(a_{1} + ..a_{_a}.. + a_{i}) in Integers if (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{i} in Integers).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} + ..a_{_a}.. + a_{i}) in Integers
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (a_{1} in Integers) and ..(a_{_a} in Integers).. and (a_{i} in Integers)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (a_{1} + ..a_{_a}.. + a_{i}, Integers)
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (a_{1} in Integers, ..a_{_a} in Integers.., a_{i} in Integers)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. a_{1} + ..a_{_a}.. + a_{i}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (a_{1} in Integers), ..(a_{_a} in Integers).., (a_{i} in Integers)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, ..a_{_a}.., a_{i})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (a_{_a} in Integers)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. a_{_a} in Integers
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (a_{_a}, Integers)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. Integers
#     core type: Literal
#     sub-expressions:
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
