# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x
from proveit.logic import InSet
from proveit.number import Floor, Naturals, RealsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Floor(x), Naturals), InSet(x, RealsPos))
# Out:
# expr: {floor(x) in Naturals if x in RealsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lfloor x\rfloor \in \mathbb{N} \textrm{ if } x \in \mathbb{R}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {floor(x) in Naturals if x in RealsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. floor(x) in Naturals
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. x in RealsPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (floor(x), Naturals)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 8
# 6. floor(x)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. RealsPos
#    core type: Literal
#    sub-expressions:
# 9. floor
#    core type: Literal
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
