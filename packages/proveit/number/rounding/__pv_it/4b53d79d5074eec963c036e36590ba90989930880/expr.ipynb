# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x
from proveit.logic import Equals, InSet
from proveit.number import Ceil, Reals

# %%
# build up the expression from sub-expressions
subExpr1 = Ceil(x)
expr = Conditional(Equals(Ceil(subExpr1), subExpr1), InSet(x, Reals))
# Out:
# expr: {ceil(ceil(x)) = ceil(x) if x in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lceil \lceil x\rceil\rceil = \lceil x\rceil \textrm{ if } x \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {ceil(ceil(x)) = ceil(x) if x in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ceil(ceil(x)) = ceil(x)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in Reals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (ceil(ceil(x)), ceil(x))
#    core type: ExprTuple
#    sub-expressions: 7, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 7. ceil(ceil(x))
#    core type: Operation
#    operator: 10
#    operand: 9
# 8. Reals
#    core type: Literal
#    sub-expressions:
# 9. ceil(x)
#    core type: Operation
#    operator: 10
#    operand: 11
# 10. ceil
#     core type: Literal
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
