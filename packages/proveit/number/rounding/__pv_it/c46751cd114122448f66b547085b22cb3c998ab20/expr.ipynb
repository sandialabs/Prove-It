# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import k, x, y
from proveit.core_expr_types import Len
from proveit.number import Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([x, Neg(y), two]), Len([ExprRange(k, k, one, three)]))
# Out:
# expr: (|(x, -y, 2)|, |(1, ..k.., 3)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(x, -y, 2\right)|, |\left(1, \ldots, 3\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(x, -y, 2)|, |(1, ..k.., 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(x, -y, 2)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 3)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((x, -y, 2))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 3))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x, -y, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (1, ..k.., 3)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. -y
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. 1, ..k.., 3
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
