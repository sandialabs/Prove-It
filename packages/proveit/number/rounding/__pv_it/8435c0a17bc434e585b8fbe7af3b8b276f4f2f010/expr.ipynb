# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import n, x
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Ceil, Integers, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([n], Equals(Ceil(Add(x, n)), Add(Ceil(x), n)), domain = Integers), InSet(x, Reals))
# Out:
# expr: {forall_{n in Integers} (ceil(x + n) = (ceil(x) + n)) if x in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{n \in \mathbb{Z}}~\left(\lceil x + n\rceil = \left(\lceil x\rceil + n\right)\right) \textrm{ if } x \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{n in Integers} (ceil(x + n) = (ceil(x) + n)) if x in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in Integers} (ceil(x + n) = (ceil(x) + n))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. x in Reals
#    core type: Operation
#    operator: 12
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. n -> {ceil(x + n) = (ceil(x) + n) if n in Integers.
#    core type: Lambda
#    parameter: 22
#    body: 6
# 5. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 24, 7
# 6. {ceil(x + n) = (ceil(x) + n) if n in Integers.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. Reals
#    core type: Literal
#    sub-expressions:
# 8. ceil(x + n) = (ceil(x) + n)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. n in Integers
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (ceil(x + n), ceil(x) + n)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (n, Integers)
#     core type: ExprTuple
#     sub-expressions: 22, 16
# 14. ceil(x + n)
#     core type: Operation
#     operator: 23
#     operand: 17
# 15. ceil(x) + n
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. Integers
#     core type: Literal
#     sub-expressions:
# 17. x + n
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (ceil(x), n)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (x, n)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 21. ceil(x)
#     core type: Operation
#     operator: 23
#     operand: 24
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. ceil
#     core type: Literal
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
