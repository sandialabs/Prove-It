# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n, x
from proveit.logic import Equals, Forall
from proveit.number import Add, Floor, Integers

# %%
# build up the expression from sub-expressions
expr = Forall([n], Equals(Floor(Add(x, n)), Add(Floor(x), n)), domain = Integers)
# Out:
# expr: forall_{n in Integers} (floor(x + n) = (floor(x) + n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{Z}}~\left(\lfloor x + n\rfloor = \left(\lfloor x\rfloor + n\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Integers} (floor(x + n) = (floor(x) + n))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. n -> {floor(x + n) = (floor(x) + n) if n in Integers.
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. {floor(x + n) = (floor(x) + n) if n in Integers.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. floor(x + n) = (floor(x) + n)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. n in Integers
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (floor(x + n), floor(x) + n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, Integers)
#    core type: ExprTuple
#    sub-expressions: 18, 12
# 10. floor(x + n)
#     core type: Operation
#     operator: 19
#     operand: 13
# 11. floor(x) + n
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. Integers
#     core type: Literal
#     sub-expressions:
# 13. x + n
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (floor(x), n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (x, n)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 17. floor(x)
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. floor
#     core type: Literal
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
