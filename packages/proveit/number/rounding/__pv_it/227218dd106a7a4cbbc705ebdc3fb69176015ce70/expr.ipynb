# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x
from proveit.logic import Forall, InSet
from proveit.number import Ceil, Integers, Reals

# %%
# build up the expression from sub-expressions
expr = Forall([x], InSet(Ceil(x), Integers), domain = Reals)
# Out:
# expr: forall_{x in Reals} (ceil(x) in Integers)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left(\lceil x\rceil \in \mathbb{Z}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x in Reals} (ceil(x) in Integers)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {ceil(x) in Integers if x in Reals.
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. {ceil(x) in Integers if x in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ceil(x) in Integers
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. x in Reals
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (ceil(x), Integers)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. ceil(x)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. Integers
#     core type: Literal
#     sub-expressions:
# 11. Reals
#     core type: Literal
#     sub-expressions:
# 12. ceil
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
