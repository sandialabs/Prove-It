# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import x, y
from proveit.logic import And, InSet
from proveit.number import Add, Ceil, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Ceil(Add(x, y)), Add(Ceil(x), Ceil(y))), And(InSet(x, Reals), InSet(y, Reals)))
# Out:
# expr: {ceil(x + y) <= (ceil(x) + ceil(y)) if x in Reals ,  y in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lceil x + y\rceil \leq \left(\lceil x\rceil + \lceil y\rceil\right) \textrm{ if } x \in \mathbb{R} ,  y \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {ceil(x + y) <= (ceil(x) + ceil(y)) if x in Reals ,  y in Reals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ceil(x + y) <= (ceil(x) + ceil(y))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Reals) and (y in Reals)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (ceil(x + y), ceil(x) + ceil(y))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Reals, y in Reals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. ceil(x + y)
#    core type: Operation
#    operator: 22
#    operand: 11
# 8. ceil(x) + ceil(y)
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. x in Reals
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. y in Reals
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x + y
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (ceil(x), ceil(y))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. (x, Reals)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y, Reals)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (x, y)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 18. ceil(x)
#     core type: Operation
#     operator: 22
#     operand: 21
# 19. ceil(y)
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. Reals
#     core type: Literal
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. ceil
#     core type: Literal
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
