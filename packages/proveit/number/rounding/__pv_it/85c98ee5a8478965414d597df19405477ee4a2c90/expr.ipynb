# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import x
from proveit.logic import Equals, Forall
from proveit.number import Add, Ceil, Floor, Neg, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Forall([x], Equals(Add(Ceil(x), Floor(Neg(x))), zero), domain = Reals)
# Out:
# expr: forall_{x in Reals} ((ceil(x) + floor(-x)) = 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{R}}~\left(\left(\lceil x\rceil + \lfloor -x\rfloor\right) = 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x in Reals} ((ceil(x) + floor(-x)) = 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> {(ceil(x) + floor(-x)) = 0 if x in Reals.
#    core type: Lambda
#    parameter: 21
#    body: 3
# 3. {(ceil(x) + floor(-x)) = 0 if x in Reals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (ceil(x) + floor(-x)) = 0
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (ceil(x) + floor(-x), 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, Reals)
#    core type: ExprTuple
#    sub-expressions: 21, 12
# 10. ceil(x) + floor(-x)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. Reals
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (ceil(x), floor(-x))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. ceil(x)
#     core type: Operation
#     operator: 17
#     operand: 21
# 16. floor(-x)
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. ceil
#     core type: Literal
#     sub-expressions:
# 18. floor
#     core type: Literal
#     sub-expressions:
# 19. -x
#     core type: Operation
#     operator: 20
#     operand: 21
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
