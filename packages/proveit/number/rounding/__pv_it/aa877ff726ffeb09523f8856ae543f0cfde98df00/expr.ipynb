# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x
from proveit.logic import InSet
from proveit.number import Ceil, NaturalsPos, RealsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(InSet(Ceil(x), NaturalsPos), InSet(x, RealsPos)))
# Out:
# expr: x -> {ceil(x) in NaturalsPos if x in RealsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{\lceil x\rceil \in \mathbb{N}^+ \textrm{ if } x \in \mathbb{R}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> {ceil(x) in NaturalsPos if x in RealsPos.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {ceil(x) in NaturalsPos if x in RealsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ceil(x) in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. x in RealsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (ceil(x), NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, RealsPos)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. ceil(x)
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. RealsPos
#    core type: Literal
#    sub-expressions:
# 10. ceil
#     core type: Literal
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
