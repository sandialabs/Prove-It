# %%
from arithmeticOps import *
from inequality import Inequality

# %%
from arithmeticOps import *
from inequality import Inequality

X = LessThan(a,b)
Y = LessThan(b,c)

X.applyTransitivity(Y)
# Out:
# a < b (a < b) => ((b < c) => (a < c))
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-2-cb91c9b5cc78> in <module>()
#       5 Y = LessThan(b,c)
#       6
# ----> 7 X.applyTransitivity(Y)
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.py in applyTransitivity(self, other)
#     153 #                else:
#     154 #                    return other.rhsSubstitute(X,
# --> 155         return self.transitivityImpl(other).deriveConclusion().checked({self, other})
#     156
#     157 class LessThan(OrderingRelation):
#
# /Users/kmrudin/proveit/proveit/expression.pyc in checked(self, assumptions)
#     135             return "{" + ", ".join([str(assumption) for assumption in assumptions]) + "}"
#     136         if self.isProven(assumptions, markProof=False)==False:
# --> 137             raise ProofFailure("Proof failed: " + str(self) + " assuming " + makeAssumptionsStr(assumptions))
#     138         return self
#     139
#
# ProofFailure: Proof failed: (b < c) => (a < c) assuming {a < b, b < c}

# %%
X = LessThan(a,b)
Y = LessThan(b,c)

# %%
X.transitivityImpl(Y)
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-2-ae41eb7eda85> in <module>()
# ----> 1 X.transitivityImpl(Y)
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.pyc in transitivityImpl(self, other)
#     180             if isinstance(other,LessThan):
#     181                 result = lessThanTransLessThanRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
# --> 182                 return result.checked({self})
#     183             elif isinstance(other,LessThanEquals):
#     184                 result = lessThanTransLessThanEqualsRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
#
# /Users/kmrudin/proveit/proveit/expression.pyc in checked(self, assumptions)
#     135             return "{" + ", ".join([str(assumption) for assumption in assumptions]) + "}"
#     136         if self.isProven(assumptions, markProof=False)==False:
# --> 137             raise ProofFailure("Proof failed: " + str(self) + " assuming " + makeAssumptionsStr(assumptions))
#     138         return self
#     139
#
# ProofFailure: Proof failed: (b < c) => (a < c) assuming {a < b}

# %%
X.applyTransitivity(Y)
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-3-633c6da0f88c> in <module>()
# ----> 1 X.applyTransitivity(Y)
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.py in applyTransitivity(self, other)
#     153 #                else:
#     154 #                    return other.rhsSubstitute(X,
# --> 155         return self.transitivityImpl(other).deriveConclusion().checked({self, other})
#     156
#     157 class LessThan(OrderingRelation):
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.py in transitivityImpl(self, other)
#     180             if isinstance(other,LessThan):
#     181                 result = lessThanTransLessThanRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
# --> 182                 return result.checked({self})
#     183             elif isinstance(other,LessThanEquals):
#     184                 result = lessThanTransLessThanEqualsRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
#
# /Users/kmrudin/proveit/proveit/expression.pyc in checked(self, assumptions)
#     135             return "{" + ", ".join([str(assumption) for assumption in assumptions]) + "}"
#     136         if self.isProven(assumptions, markProof=False)==False:
# --> 137             raise ProofFailure("Proof failed: " + str(self) + " assuming " + makeAssumptionsStr(assumptions))
#     138         return self
#     139
#
# ProofFailure: Proof failed: (b < c) => (a < c) assuming {a < b}

# %%
Inequality(X).update(Y)
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-5-d0bebb97a9b9> in <module>()
# ----> 1 Inequality(X).update(Y)
#
# /Users/kmrudin/proveit/proveit/number/inequality.py in update(self, nextIneqExpr)
#      28         if not isinstance(nextIneqExpr, OrderingRelation) and not isinstance(nextIneqExpr, Equals):
#      29             raise ValueError('Inequality may updated only with an OrderingRelation or Equals expression')
# ---> 30         self.ineqExpr = self.ineqExpr.applyTransitivity(nextIneqExpr).checked({self.ineqExpr, nextIneqExpr})
#      31         return self.eqExpr
#      32
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.pyc in applyTransitivity(self, other)
#     153 #                else:
#     154 #                    return other.rhsSubstitute(X,
# --> 155         return self.transitivityImpl(other).deriveConclusion().checked({self, other})
#     156
#     157 class LessThan(OrderingRelation):
#
# /Users/kmrudin/proveit/proveit/number/arithmeticOps.pyc in transitivityImpl(self, other)
#     180             if isinstance(other,LessThan):
#     181                 result = lessThanTransLessThanRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
# --> 182                 return result.checked({self})
#     183             elif isinstance(other,LessThanEquals):
#     184                 result = lessThanTransLessThanEqualsRight.specialize({x:self.lhs, y:self.rhs, z:other.rhs}).deriveConclusion()
#
# /Users/kmrudin/proveit/proveit/expression.pyc in checked(self, assumptions)
#     135             return "{" + ", ".join([str(assumption) for assumption in assumptions]) + "}"
#     136         if self.isProven(assumptions, markProof=False)==False:
# --> 137             raise ProofFailure("Proof failed: " + str(self) + " assuming " + makeAssumptionsStr(assumptions))
#     138         return self
#     139
#
# ProofFailure: Proof failed: (b < c) => (a < c) assuming {a < b}
