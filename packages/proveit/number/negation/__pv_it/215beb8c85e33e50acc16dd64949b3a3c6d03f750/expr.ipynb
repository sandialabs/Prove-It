# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#distributeNegThroughSum">distributeNegThroughSum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.negation._theorems_ import distributeNegThroughSum

# %%
# check that the built expression is the same as the stored expression
# %check_expr distributeNegThroughSum
# Out:
# Passed sanity check: built 'distributeNegThroughSum' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distributeNegThroughSum.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}}~\left(\left(-\left(x_{1} + \ldots + x_{n}\right)\right) = \left(\left(-x_{1}\right) + \ldots + \left(-x_{n}\right)\right)\right)\right]

# %%
# display the expression information
distributeNegThroughSum.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes} ((-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 28
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> {(-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})) if (x_{1} in Complexes) and ..(x_{_a} in Complexes).. and (x_{n} in Complexes).
#    core type: Lambda
#    parameter: 26
#    body: 8
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 32, 9
# 8. {(-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n})) if (x_{1} in Complexes) and ..(x_{_a} in Complexes).. and (x_{n} in Complexes).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. (-(x_{1} + ..x_{_a}.. + x_{n})) = ((-x_{1}) + ..(-x_{k}).. + (-x_{n}))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x_{1} in Complexes) and ..(x_{_a} in Complexes).. and (x_{n} in Complexes)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (-(x_{1} + ..x_{_a}.. + x_{n}), (-x_{1}) + ..(-x_{k}).. + (-x_{n}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (x_{1} in Complexes, ..x_{_a} in Complexes.., x_{n} in Complexes)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. -(x_{1} + ..x_{_a}.. + x_{n})
#     core type: Operation
#     operator: 36
#     operand: 19
# 17. (-x_{1}) + ..(-x_{k}).. + (-x_{n})
#     core type: Operation
#     operator: 22
#     operands: 20
# 18. (x_{1} in Complexes), ..(x_{_a} in Complexes).., (x_{n} in Complexes)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 31
#     end_index: 32
# 19. x_{1} + ..x_{_a}.. + x_{n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (-x_{1}, ..-x_{k}.., -x_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. _a -> (x_{_a} in Complexes)
#     core type: Lambda
#     parameter: 38
#     body: 25
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. (-x_{1}), ..(-x_{k}).., (-x_{n})
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 31
#     end_index: 32
# 25. x_{_a} in Complexes
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 27. k -> (-x_{k})
#     core type: Lambda
#     parameter: 40
#     body: 33
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (x_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 30. _a -> x_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 35
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. -x_{k}
#     core type: Operation
#     operator: 36
#     operand: 37
# 34. Complexes
#     core type: Literal
#     sub-expressions:
# 35. x_{_a}
#     core type: IndexedVar
# variable: 39
# index: 38
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. x_{k}
#     core type: IndexedVar
# variable: 39
# index: 40
# 38. _a
#     core type: Variable
#     sub-expressions:
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. k
#     core type: Variable
#     sub-expressions:
