# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#negDefAddInv">negDefAddInv</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.negation._axioms_ import negDefAddInv

# %%
# check that the built expression is the same as the stored expression
# %check_expr negDefAddInv
# Out:
# Passed sanity check: built 'negDefAddInv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negDefAddInv.latex())
# Out:
# \vdash \forall_{a \in \mathbb{N}, b \in \mathbb{N}, c \in \mathbb{N}~|~\left(a + b\right) = c}~\left(\left(c + \left(-a\right)\right) = b\right)

# %%
# display the expression information
negDefAddInv.exprInfo()
# Out:
# 0. forall_{a in Naturals, b in Naturals, c in Naturals | (a + b) = c} ((c + (-a)) = b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {(c + (-a)) = b if a in Naturals ,  b in Naturals ,  c in Naturals ,  (a + b) = c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 25
# 4. {(c + (-a)) = b if a in Naturals ,  b in Naturals ,  c in Naturals ,  (a + b) = c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (c + (-a)) = b
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (a in Naturals) and (b in Naturals) and (c in Naturals) and ((a + b) = c)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (c + (-a), b)
#    core type: ExprTuple
#    sub-expressions: 10, 30
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Naturals, b in Naturals, c in Naturals, (a + b) = c)
# ...
