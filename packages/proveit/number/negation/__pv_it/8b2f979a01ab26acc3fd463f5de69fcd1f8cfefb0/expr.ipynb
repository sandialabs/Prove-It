# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals

# %%
# build up the expression from sub-expressions
expr = And(InSet(a, Naturals), InSet(b, Naturals), InSet(c, Naturals), Equals(Add(a, b), c))
# Out:
# expr: (a in Naturals) and (b in Naturals) and (c in Naturals) and ((a + b) = c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{N}\right) \land \left(b \in \mathbb{N}\right) \land \left(c \in \mathbb{N}\right) \land \left(\left(a + b\right) = c\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Naturals) and (b in Naturals) and (c in Naturals) and ((a + b) = c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a in Naturals, b in Naturals, c in Naturals, (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Naturals
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. b in Naturals
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. c in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (a + b) = c
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (a, Naturals)
#    core type: ExprTuple
#    sub-expressions: 18, 13
# 8. (b, Naturals)
#    core type: ExprTuple
#    sub-expressions: 19, 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (c, Naturals)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (a + b, c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Naturals
#     core type: Literal
#     sub-expressions:
# 14. a + b
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a, b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
