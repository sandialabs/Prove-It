# %% [markdown]
# Axioms for context <a href="_context_.ipynb" class="ProveItLink">proveit.number.negation</a>
# ========

# %%
import proveit
from proveit.logic import Forall, Equals
from proveit._common_ import x
from proveit.number import Neg, Mult, Reals, one
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin axioms
# Out:
# Defining axioms for context 'proveit.number.negation'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %%
negMultOneDef = Forall(x,Equals(Neg(x), Mult(Neg(one), x)) , domain=Reals)
# Out:
# negMultOneDef: forall_{x in Reals} ((-x) = ((-1) * x))

# %%
# %end axioms
# Out:
# Axioms may be imported from autogenerated _axioms_.py
