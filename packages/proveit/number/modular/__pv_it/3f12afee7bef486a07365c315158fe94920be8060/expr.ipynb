# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import N, a, b, c, x
from proveit.logic import And, Equals, InSet, NotEquals, SetOfAll
from proveit.number import Add, Integers, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Add(N, Neg(one))
expr = Conditional(Equals(SetOfAll([x], Mod(Add(x, c), N), domain = Interval(a, b)), Interval(zero, subExpr1)), And(InSet(N, Integers), InSet(a, Integers), InSet(b, Integers), InSet(c, Integers), Equals(Add(b, Neg(a)), subExpr1), NotEquals(N, zero)))
# Out:
# expr: {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\} \textrm{ if } N \in \mathbb{Z} ,  a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  \left(b - a\right) = \left(N - 1\right) ,  N \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {{(x + c) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {(x + c) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 21
#    operands: 3
# 2. (N in Integers) and (a in Integers) and (b in Integers) and (c in Integers) and ((b - a) = (N - 1)) and (N != 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ({(x + c) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (N in Integers, a in Integers, b in Integers, c in Integers, (b - a) = (N - 1), N != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 6. {(x + c) mod  N}_{x in {a...b}}
#    core type: Operation
#    operator: 14
#    operand: 15
# 7. {0...N - 1}
#    core type: Operation
#    operator: 47
#    operands: 16
# 8. N in Integers
#    core type: Operation
#    operator: 36
#    operands: 17
# 9. a in Integers
#    core type: Operation
#    operator: 36
#    operands: 18
# 10. b in Integers
#     core type: Operation
#     operator: 36
#     operands: 19
# 11. c in Integers
#     core type: Operation
#     operator: 36
#     operands: 20
# 12. (b - a) = (N - 1)
#     core type: Operation
#     operator: 21
#     operands: 22
# 13. N != 0
#     core type: Operation
#     operator: 23
#     operands: 24
# 14. SetOfAll
#     core type: Literal
#     sub-expressions:
# 15. x -> {(x + c) mod  N if x in {a...b}.
#     core type: Lambda
#     parameter: 49
#     body: 25
# 16. (0, N - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 17. (N, Integers)
#     core type: ExprTuple
#     sub-expressions: 41, 26
# 18. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 51, 26
# 19. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 52, 26
# 20. (c, Integers)
#     core type: ExprTuple
#     sub-expressions: 50, 26
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (b - a, N - 1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. !=
#     core type: Literal
#     sub-expressions:
# 24. (N, 0)
#     core type: ExprTuple
#     sub-expressions: 41, 29
# 25. {(x + c) mod  N if x in {a...b}.
#     core type: Conditional
#     value: 30
#     condition: 31
# 26. Integers
#     core type: Literal
#     sub-expressions:
# 27. b - a
#     core type: Operation
#     operator: 45
#     operands: 32
# 28. N - 1
#     core type: Operation
#     operator: 45
#     operands: 33
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. (x + c) mod  N
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. x in {a...b}
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (b, -a)
#     core type: ExprTuple
#     sub-expressions: 52, 38
# 33. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 39
# 34. mod
#     core type: Literal
#     sub-expressions:
# 35. (x + c, N)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (x, {a...b})
#     core type: ExprTuple
#     sub-expressions: 49, 42
# 38. -a
#     core type: Operation
#     operator: 43
#     operand: 51
# 39. -1
#     core type: Operation
#     operator: 43
#     operand: 44
# 40. x + c
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. N
#     core type: Variable
#     sub-expressions:
# 42. {a...b}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (x, c)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (a, b)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. a
#     core type: Variable
#     sub-expressions:
# 52. b
#     core type: Variable
#     sub-expressions:
