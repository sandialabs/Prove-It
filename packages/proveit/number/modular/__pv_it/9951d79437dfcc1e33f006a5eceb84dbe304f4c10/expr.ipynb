# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#modAbsSubtractCancel">modAbsSubtractCancel</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.modular._theorems_ import modAbsSubtractCancel

# %%
# check that the built expression is the same as the stored expression
# %check_expr modAbsSubtractCancel
# Out:
# Passed sanity check: built 'modAbsSubtractCancel' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(modAbsSubtractCancel.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}, c \in \mathbb{R}~|~c \neq 0}~\left(\left|\left(\left(b + a\right) ~\textup{mod}~ c\right) - b\right|_{\textup{mod}\thinspace c} \leq \left|a\right|\right)

# %%
# display the expression information
modAbsSubtractCancel.exprInfo()
# Out:
# 0. forall_{a in Reals, b in Reals, c in Reals | c != 0} (|((b + a) mod  c) - b|_{mod c} <= |a|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b, c) -> {|((b + a) mod  c) - b|_{mod c} <= |a| if a in Reals ,  b in Reals ,  c in Reals ,  c != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 40, 39, 36
# 4. {|((b + a) mod  c) - b|_{mod c} <= |a| if a in Reals ,  b in Reals ,  c in Reals ,  c != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |((b + a) mod  c) - b|_{mod c} <= |a|
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Reals) and (b in Reals) and (c in Reals) and (c != 0)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (|((b + a) mod  c) - b|_{mod c}, |a|)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
# ...
