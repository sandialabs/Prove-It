# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import N, a, b, c, x
from proveit.logic import SetOfAll
from proveit.number import Add, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(SetOfAll([x], Mod(Add(c, x), N), domain = Interval(a, b)), Interval(zero, Add(N, Neg(one))))
# Out:
# expr: ({(c + x) mod  N}_{x in {a...b}}, {0...N - 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}}, \{0 \dots N - 1\}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ({(c + x) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {(c + x) mod  N}_{x in {a...b}}
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. {0...N - 1}
#    core type: Operation
#    operator: 24
#    operands: 5
# 3. SetOfAll
#    core type: Literal
#    sub-expressions:
# 4. x -> {(c + x) mod  N if x in {a...b}.
#    core type: Lambda
#    parameter: 27
#    body: 6
# 5. (0, N - 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {(c + x) mod  N if x in {a...b}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. N - 1
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. (c + x) mod  N
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x in {a...b}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 12. mod
#     core type: Literal
#     sub-expressions:
# 13. (c + x, N)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x, {a...b})
#     core type: ExprTuple
#     sub-expressions: 27, 19
# 16. -1
#     core type: Operation
#     operator: 20
#     operand: 21
# 17. c + x
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. N
#     core type: Variable
#     sub-expressions:
# 19. {a...b}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (c, x)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (a, b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. c
#     core type: Variable
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
