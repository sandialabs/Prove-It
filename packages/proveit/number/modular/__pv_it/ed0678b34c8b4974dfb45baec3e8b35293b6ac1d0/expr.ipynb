# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import N, a, b, c, x
from proveit.logic import And, Equals, InSet, NotEquals, SetOfAll
from proveit.number import Add, Integers, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Add(N, Neg(one))
expr = Lambda([N, a, b, c], Conditional(Equals(SetOfAll([x], Mod(Add(c, x), N), domain = Interval(a, b)), Interval(zero, subExpr1)), And(InSet(N, Integers), InSet(a, Integers), InSet(b, Integers), InSet(c, Integers), Equals(Add(b, Neg(a)), subExpr1), NotEquals(N, zero))))
# Out:
# expr: (N, a, b, c) -> {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(N, a, b, c\right) \mapsto \left\{\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\} \textrm{ if } N \in \mathbb{Z} ,  a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  \left(b - a\right) = \left(N - 1\right) ,  N \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (N, a, b, c) -> {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (N, a, b, c)
#    core type: ExprTuple
#    sub-expressions: 43, 53, 54, 51
# 2. {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. {(c + x) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 23
#    operands: 5
# 4. (N in Integers) and (a in Integers) and (b in Integers) and (c in Integers) and ((b - a) = (N - 1)) and (N != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ({(c + x) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# ...
