# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#modAbsIntClosure">modAbsIntClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.modular._theorems_ import modAbsIntClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr modAbsIntClosure
# Out:
# Passed sanity check: built 'modAbsIntClosure' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(modAbsIntClosure.latex())
# Out:
# \vdash \forall_{a \in \mathbb{Z}, b \in \mathbb{Z}~|~b \neq 0}~\left(\left|a\right|_{\textup{mod}\thinspace b} \in \mathbb{Z}\right)

# %%
# display the expression information
modAbsIntClosure.exprInfo()
# Out:
# 0. forall_{a in Integers, b in Integers | b != 0} (|a|_{mod b} in Integers)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {|a|_{mod b} in Integers if a in Integers ,  b in Integers ,  b != 0.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {|a|_{mod b} in Integers if a in Integers ,  b in Integers ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |a|_{mod b} in Integers
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (a in Integers) and (b in Integers) and (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|a|_{mod b}, Integers)
#    core type: ExprTuple
#    sub-expressions: 9, 21
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integers, b in Integers, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. |a|_{mod b}
#    core type: Operation
#    operator: 13
#    operands: 14
# ...
