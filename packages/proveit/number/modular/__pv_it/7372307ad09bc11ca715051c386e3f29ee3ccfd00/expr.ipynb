# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.number import Mod, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Mod(a, b), Reals), And(InSet(a, Reals), InSet(b, Reals), NotEquals(b, zero)))
# Out:
# expr: {(a mod  b) in Reals if a in Reals ,  b in Reals ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a ~\textup{mod}~ b\right) \in \mathbb{R} \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a mod  b) in Reals if a in Reals ,  b in Reals ,  b != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a mod  b) in Reals
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (a in Reals) and (b in Reals) and (b != 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a mod  b, Reals)
#    core type: ExprTuple
#    sub-expressions: 6, 18
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Reals, b in Reals, b != 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. a mod  b
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. a in Reals
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. b in Reals
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. b != 0
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. mod
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 12. (a, Reals)
# ...
