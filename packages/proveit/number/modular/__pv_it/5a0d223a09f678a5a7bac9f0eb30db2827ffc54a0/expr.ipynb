# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import GreaterEq, Mod, Reals, RealsPos, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(GreaterEq(Mod(a, b), zero), And(InSet(a, Reals), InSet(b, RealsPos)))
# Out:
# expr: {(a mod  b) >= 0 if a in Reals ,  b in RealsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a ~\textup{mod}~ b\right) \geq 0 \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a mod  b) >= 0 if a in Reals ,  b in RealsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a mod  b) >= 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Reals) and (b in RealsPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. >=
#    core type: Literal
#    sub-expressions:
# 4. (a mod  b, 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Reals, b in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. a mod  b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a in Reals
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in RealsPos
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. mod
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. (a, Reals)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, RealsPos)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. Reals
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. RealsPos
#     core type: Literal
#     sub-expressions:
