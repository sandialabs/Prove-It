# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import N, a, b, c, x
from proveit.logic import Equals, SetOfAll
from proveit.number import Add, Interval, Mod, Neg, one, zero

# %%
# build up the expression from sub-expressions
expr = Equals(SetOfAll([x], Mod(Add(x, c), N), domain = Interval(a, b)), Interval(zero, Add(N, Neg(one))))
# Out:
# expr: {(x + c) mod  N}_{x in {a...b}} = {0...N - 1}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x + c\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(x + c) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ({(x + c) mod  N}_{x in {a...b}}, {0...N - 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {(x + c) mod  N}_{x in {a...b}}
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. {0...N - 1}
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. SetOfAll
#    core type: Literal
#    sub-expressions:
# 6. x -> {(x + c) mod  N if x in {a...b}.
#    core type: Lambda
#    parameter: 28
#    body: 8
# 7. (0, N - 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {(x + c) mod  N if x in {a...b}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. N - 1
#     core type: Operation
#     operator: 24
#     operands: 13
# 11. (x + c) mod  N
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. x in {a...b}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (N, -1)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 14. mod
#     core type: Literal
#     sub-expressions:
# 15. (x + c, N)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x, {a...b})
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 18. -1
#     core type: Operation
#     operator: 22
#     operand: 23
# 19. x + c
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. N
#     core type: Variable
#     sub-expressions:
# 21. {a...b}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (x, c)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (a, b)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. c
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
