# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet, NotEquals
from proveit.number import Abs, Add, Integers, Interval, ModAbs, Neg, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(ModAbs(a, b), Interval(zero, Add(Abs(b), Neg(one)))), And(InSet(a, Integers), InSet(b, Integers), NotEquals(b, zero)))
# Out:
# expr: {|a|_{mod b} in {0...|b| - 1} if a in Integers ,  b in Integers ,  b != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|a\right|_{\textup{mod}\thinspace b} \in \{0 \dots \left|b\right| - 1\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {|a|_{mod b} in {0...|b| - 1} if a in Integers ,  b in Integers ,  b != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |a|_{mod b} in {0...|b| - 1}
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (a in Integers) and (b in Integers) and (b != 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|a|_{mod b}, {0...|b| - 1})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Integers, b in Integers, b != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. |a|_{mod b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. {0...|b| - 1}
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. a in Integers
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. b in Integers
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. b != 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 11. ModAbs
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 21, 29
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (0, |b| - 1)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 15. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 29, 23
# 20. |b| - 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. Integers
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (|b|, -1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. |b|
#     core type: Operation
#     operator: 28
#     operand: 29
# 27. -1
#     core type: Operation
#     operator: 30
#     operand: 31
# 28. Abs
#     core type: Literal
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. 1
#     core type: Literal
#     sub-expressions:
