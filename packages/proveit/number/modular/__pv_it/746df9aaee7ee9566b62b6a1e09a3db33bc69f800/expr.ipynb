# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#modInInterval">modInInterval</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.modular._theorems_ import modInInterval

# %%
# check that the built expression is the same as the stored expression
# %check_expr modInInterval
# Out:
# Passed sanity check: built 'modInInterval' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(modInInterval.latex())
# Out:
# \vdash \forall_{a \in \mathbb{Z}, b \in \mathbb{Z}~|~b \neq 0}~\left(\left|a\right|_{\textup{mod}\thinspace b} \in \{0 \dots \left|b\right| - 1\}\right)

# %%
# display the expression information
modInInterval.exprInfo()
# Out:
# 0. forall_{a in Integers, b in Integers | b != 0} (|a|_{mod b} in {0...|b| - 1})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {|a|_{mod b} in {0...|b| - 1} if a in Integers ,  b in Integers ,  b != 0.
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {|a|_{mod b} in {0...|b| - 1} if a in Integers ,  b in Integers ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |a|_{mod b} in {0...|b| - 1}
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (a in Integers) and (b in Integers) and (b != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|a|_{mod b}, {0...|b| - 1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integers, b in Integers, b != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. |a|_{mod b}
#    core type: Operation
# ...
