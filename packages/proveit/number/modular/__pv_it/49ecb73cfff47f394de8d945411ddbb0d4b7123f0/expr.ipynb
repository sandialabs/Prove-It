# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fullModularRangeEquivLeftShift">fullModularRangeEquivLeftShift</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.modular._theorems_ import fullModularRangeEquivLeftShift

# %%
# check that the built expression is the same as the stored expression
# %check_expr fullModularRangeEquivLeftShift
# Out:
# Passed sanity check: built 'fullModularRangeEquivLeftShift' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fullModularRangeEquivLeftShift.latex())
# Out:
# \vdash \forall_{N \in \mathbb{Z}, a \in \mathbb{Z}, b \in \mathbb{Z}, c \in \mathbb{Z}~|~\left(b - a\right) = \left(N - 1\right), N \neq 0}~\left(\left\{\left(c + x\right) ~\textup{mod}~ N\right\}_{x \in \{a \dots b\}} = \{0 \dots N - 1\}\right)

# %%
# display the expression information
fullModularRangeEquivLeftShift.exprInfo()
# Out:
# 0. forall_{N in Integers, a in Integers, b in Integers, c in Integers | (b - a) = (N - 1), N != 0} ({(c + x) mod  N}_{x in {a...b}} = {0...N - 1})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (N, a, b, c) -> {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (N, a, b, c)
#    core type: ExprTuple
#    sub-expressions: 45, 55, 56, 53
# 4. {{(c + x) mod  N}_{x in {a...b}} = {0...N - 1} if N in Integers ,  a in Integers ,  b in Integers ,  c in Integers ,  (b - a) = (N - 1) ,  N != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. {(c + x) mod  N}_{x in {a...b}} = {0...N - 1}
#    core type: Operation
#    operator: 25
#    operands: 7
# ...
