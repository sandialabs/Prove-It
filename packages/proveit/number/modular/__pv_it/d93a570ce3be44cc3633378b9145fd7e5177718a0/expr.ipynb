# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#modLessModulus">modLessModulus</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.modular</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.number.modular._axioms_ import modLessModulus

# %%
# check that the built expression is the same as the stored expression
# %check_expr modLessModulus
# Out:
# Passed sanity check: built 'modLessModulus' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(modLessModulus.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}, b \in \mathbb{R}^+}~\left(\left(a ~\textup{mod}~ b\right) < b\right)

# %%
# display the expression information
modLessModulus.exprInfo()
# Out:
# 0. forall_{a in Reals, b in RealsPos} ((a mod  b) < b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a mod  b) < b if a in Reals ,  b in RealsPos.
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. {(a mod  b) < b if a in Reals ,  b in RealsPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a mod  b) < b
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Reals) and (b in RealsPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <
#    core type: Literal
#    sub-expressions:
# 7. (a mod  b, b)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Reals, b in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. a mod  b
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. a in Reals
#     core type: Operation
#     operator: 16
# ...
