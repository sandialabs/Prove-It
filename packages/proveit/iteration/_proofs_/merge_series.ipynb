# %% [markdown]
# Proof of <a class="ProveItLink" href="../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../_context_.ipynb">iteration</a>.<a class="ProveItLink" href="../_theorems_.ipynb#merge_series">merge_series</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving merge_series presuming []
