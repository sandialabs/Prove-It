# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_theorems_.ipynb#foldForallOverBool">foldForallOverBool</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import PofA
from proveit.logic._common_ import PofTrue, PofFalse
from proveit.logic.boolean.disjunction._theorems_ import singularConstructiveDilemma
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving foldForallOverBool presuming [singularConstructiveDilemma]
# Out:
# Beginning proof of foldForallOverBool
# Recorded 'presuming' information
# Presuming proveit.logic.boolean.disjunction.singularConstructiveDilemma theorem (applied transitively).
# Presuming previous theorems (applied transitively).
# foldForallOverBool: forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]

# %%
defaults.assumptions=foldForallOverBool.allConditions()
# Out:
# defaults.assumptions: (P(TRUE), P(FALSE), A in BOOLEANS)

# %%
AinBool=defaults.assumptions[2]
# Out:
# AinBool: A in BOOLEANS

# %%
ATRUEorFALSE=AinBool.unfold()
# Out:
# ATRUEorFALSE: {A in BOOLEANS} |- (A = TRUE) or (A = FALSE)

# %%
AequalTRUE, AequalFALSE=ATRUEorFALSE.operands
# Out:
# AequalTRUE: A = TRUE
# AequalFALSE: A = FALSE

# %%
AequalTRUE.subLeftSideInto(PofTrue, assumptions=defaults.assumptions + (AequalTRUE,))
# Out:
# {P(TRUE), A = TRUE} |- P(A)

# %%
AequalFALSE.subLeftSideInto(PofFalse, assumptions=defaults.assumptions + (AequalFALSE,))
# Out:
# {P(FALSE), A = FALSE} |- P(A)

# %%
ATRUEorFALSE.deriveViaDilemma(PofA)
# Out:
# {A in BOOLEANS, P(TRUE), P(FALSE)} |- P(A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 1	instantiation	2, 3, 4, 14, 5, 6	{A in BOOLEANS, P(TRUE), P(FALSE)} |- P(A)
# 	A : A = TRUE, B : A = FALSE, C : P(A)
# 2	theorem		|- forall_{A in BOOLEANS, B in BOOLEANS | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.boolean.disjunction.singularConstructiveDilemma
# 3	instantiation	7, 9	{A in BOOLEANS} |- (A = TRUE) in BOOLEANS
# 	A : A = TRUE, B : A = FALSE
# 4	instantiation	8, 9	{A in BOOLEANS} |- (A = FALSE) in BOOLEANS
# 	A : A = TRUE, B : A = FALSE
# 5	hypothetical reasoning	10	{P(TRUE)} |- (A = TRUE) => P(A)
# 6	hypothetical reasoning	11	{P(FALSE)} |- (A = FALSE) => P(A)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)
# 	proveit.logic.boolean.disjunction.leftInBool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEANS} (B in BOOLEANS)
# 	proveit.logic.boolean.disjunction.rightInBool
# 9	instantiation	12, 13, 14	{A in BOOLEANS} |- ((A = TRUE) or (A = FALSE)) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : (A = TRUE) or (A = FALSE)
# 10	instantiation	17, 15, 16	{P(TRUE), A = TRUE} |- P(A)
# 	P(_a) : P(_a), x : A, y : TRUE
# 11	instantiation	17, 18, 19	{P(FALSE), A = FALSE} |- P(A)
# 	P(_a) : P(_a), x : A, y : FALSE
# 12	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substituteTruth
# 13	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 14	instantiation	20, 21	{A in BOOLEANS} |- (A = TRUE) or (A = FALSE)
# 	A : A
# 15	assumption		{P(TRUE)} |- P(TRUE)
# 16	assumption		{A = TRUE} |- A = TRUE
# 17	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.subLeftSideInto
# 18	assumption		{P(FALSE)} |- P(FALSE)
# 19	assumption		{A = FALSE} |- A = FALSE
# 20	theorem		|- forall_{A in BOOLEANS} ((A = TRUE) or (A = FALSE))
# 	proveit.logic.boolean.unfoldInBoolExplicit
# 21	assumption		{A in BOOLEANS} |- A in BOOLEANS
