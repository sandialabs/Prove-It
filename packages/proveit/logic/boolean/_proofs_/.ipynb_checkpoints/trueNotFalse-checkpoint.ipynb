# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_theorems_.ipynb#trueNotFalse">trueNotFalse</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean._axioms_ import falseNotTrue
context = proveit.Context('..') # the theorem's context is in the parent directory
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     608                     # first attempt to prove via implication
# --> 609                     concludedTruth = self.concludeViaImplication(assumptions)
#     610                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     685         from proveit.logic import concludeViaImplication
# --> 686         return concludeViaImplication(self, assumptions)
#     687
#
# /home/wwitzel/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     312                         queue.append(local_antecedent)
# --> 313     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     314
#
# ProofFailure: Unable to prove [not](TRUE = FALSE) in BOOLEANS:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     197                         # assumptions utilized in the last derivation step.
# --> 198                         sideEffect(assumptions=assumptions)
#     199                     except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/boolean/negation/not_op.py in deriveInBool(self, assumptions)
#      48         '''
# ---> 49         return inBool(self).prove(assumptions=assumptions)
#      50
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     611                     # try the 'conclude' method of the specific Expression class
# --> 612                     concludedTruth = self.conclude(assumptions)
#     613             if concludedTruth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/set_theory/membership/in_set.py in conclude(self, assumptions)
#     132             inner_expr = simple_membership.innerExpr().element
# --> 133             return elem_simplification.subLeftSideInto(inner_expr, assumptions)
#     134         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in call_method_with_known_truth_assumptions(*args, **kwargs)
#     636                             defaults.checkedAssumptions(assumptions)
# --> 637                     return attr.__call__(*args, **kwargs)
#     638                 return call_method_with_known_truth_assumptions
#
# /home/wwitzel/Prove-It/packages/proveit/logic/equality/equals.py in subLeftSideInto(self, lambda_map, assumptions)
#     418         from ._theorems_ import subLeftSideInto
# --> 419         from ._theorems_ import substituteTruth, substituteInTrue, substituteFalsehood, substituteInFalse
#     420         from proveit.logic import TRUE, FALSE
#
# ImportError: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     197                         # assumptions utilized in the last derivation step.
# --> 198                         sideEffect(assumptions=assumptions)
#     199                     except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/equality/not_equals.py in unfold(self, assumptions)
#      98         from ._theorems_ import unfoldNotEquals
# ---> 99         return unfoldNotEquals.specialize({x:self.lhs, y:self.rhs}, assumptions=assumptions)
#     100
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, repl_map, relabel_map, assumptions)
#     736             repl_map.update(relabel_map)
# --> 737         return self.instantiate(repl_map, assumptions=assumptions)
#     738
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1019             Proof.__init__(self, instantiated_truth, requirements,
# -> 1020                            marked_req_indices)
#    1021         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths, markedRequiredTruthIndices)
#     136             # (if it has not already been processed):
# --> 137             provenTruth.deriveSideEffects(defaults.assumptions)
#     138
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     201                     except Exception as e:
# --> 202                         raise Exception("Side effect failure for %s, while running %s: "%(str(self.expr), str(sideEffect)) + str(e))
#     203             finally:
#
# Exception: Side effect failure for [not](TRUE = FALSE), while running <bound method Not.deriveInBool of [not](TRUE = FALSE)>: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     197                         # assumptions utilized in the last derivation step.
# --> 198                         sideEffect(assumptions=assumptions)
#     199                     except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/equality/not_equals.py in deriveReversed(self, assumptions)
#      52         from ._theorems_ import notEqualsSymmetry
# ---> 53         return notEqualsSymmetry.specialize({x:self.lhs, y:self.rhs}, assumptions=assumptions)
#      54
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, repl_map, relabel_map, assumptions)
#     736             repl_map.update(relabel_map)
# --> 737         return self.instantiate(repl_map, assumptions=assumptions)
#     738
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1019             Proof.__init__(self, instantiated_truth, requirements,
# -> 1020                            marked_req_indices)
#    1021         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths, markedRequiredTruthIndices)
#     136             # (if it has not already been processed):
# --> 137             provenTruth.deriveSideEffects(defaults.assumptions)
#     138
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     201                     except Exception as e:
# --> 202                         raise Exception("Side effect failure for %s, while running %s: "%(str(self.expr), str(sideEffect)) + str(e))
#     203             finally:
#
# Exception: Side effect failure for TRUE != FALSE, while running <bound method NotEquals.unfold of TRUE != FALSE>: Side effect failure for [not](TRUE = FALSE), while running <bound method Not.deriveInBool of [not](TRUE = FALSE)>: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-d976c8cd46dd> in <module>
#       1 import proveit
# ----> 2 from proveit.logic.boolean._axioms_ import falseNotTrue
#       3 context = proveit.Context('..') # the theorem's context is in the parent directory
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/context.py in __getattr__(self, name)
#     485             raise AttributeError # don't handle internal Python attributes
#     486         try:
# --> 487             axiom_truth = self._context.getAxiom(name).provenTruth
#     488         except KeyError:
#     489             raise AttributeError("'" + name + "' axiom not found in '" + self._context.name + "'\n(make sure to execute the appropriate '_axioms_.ipynb' notebook after any changes)")
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/context.py in getAxiom(self, name)
#     284         Return the Axiom of the given name in this context.
#     285         '''
# --> 286         return self._storage.getAxiom(name)
#     287
#     288     def getTheorem(self, name):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_context_storage.py in getAxiom(self, name)
#     487             return self._loadedAxioms[name]
#     488         expr = self._getSpecialStatementExpr('axiom', name)
# --> 489         axiom = self._loadedAxioms[name] = Axiom(expr, self.context, name)
#     490         return axiom
#     491
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, expr, context, name)
#     523         self.context = context
#     524         self.name = name
# --> 525         Proof.__init__(self, KnownTruth(expr, frozenset()), [])
#     526
#     527     def _generate_step_info(self, objectRepFn):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths, markedRequiredTruthIndices)
#     135             # May derive any side-effects that are obvious consequences arising from this truth
#     136             # (if it has not already been processed):
# --> 137             provenTruth.deriveSideEffects(defaults.assumptions)
#     138
#     139     def _updateDependencies(self, newproof):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     200                         pass
#     201                     except Exception as e:
# --> 202                         raise Exception("Side effect failure for %s, while running %s: "%(str(self.expr), str(sideEffect)) + str(e))
#     203             finally:
#     204                 KnownTruth.in_progress_to_derive_sideeffects.remove(self)
#
# Exception: Side effect failure for FALSE != TRUE, while running <bound method NotEquals.deriveReversed of FALSE != TRUE>: Side effect failure for TRUE != FALSE, while running <bound method NotEquals.unfold of TRUE != FALSE>: Side effect failure for [not](TRUE = FALSE), while running <bound method Not.deriveInBool of [not](TRUE = FALSE)>: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)

# %%
# %proving trueNotFalse presuming [proveit.logic.equality.notEqualsSymmetry]
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     608                     # first attempt to prove via implication
# --> 609                     concludedTruth = self.concludeViaImplication(assumptions)
#     610                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     685         from proveit.logic import concludeViaImplication
# --> 686         return concludeViaImplication(self, assumptions)
#     687
#
# /home/wwitzel/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     312                         queue.append(local_antecedent)
# --> 313     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     314
#
# ProofFailure: Unable to prove [not](TRUE = FALSE) in BOOLEANS:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     197                         # assumptions utilized in the last derivation step.
# --> 198                         sideEffect(assumptions=assumptions)
#     199                     except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/boolean/negation/not_op.py in deriveInBool(self, assumptions)
#      48         '''
# ---> 49         return inBool(self).prove(assumptions=assumptions)
#      50
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     611                     # try the 'conclude' method of the specific Expression class
# --> 612                     concludedTruth = self.conclude(assumptions)
#     613             if concludedTruth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/set_theory/membership/in_set.py in conclude(self, assumptions)
#     132             inner_expr = simple_membership.innerExpr().element
# --> 133             return elem_simplification.subLeftSideInto(inner_expr, assumptions)
#     134         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in call_method_with_known_truth_assumptions(*args, **kwargs)
#     636                             defaults.checkedAssumptions(assumptions)
# --> 637                     return attr.__call__(*args, **kwargs)
#     638                 return call_method_with_known_truth_assumptions
#
# /home/wwitzel/Prove-It/packages/proveit/logic/equality/equals.py in subLeftSideInto(self, lambda_map, assumptions)
#     418         from ._theorems_ import subLeftSideInto
# --> 419         from ._theorems_ import substituteTruth, substituteInTrue, substituteFalsehood, substituteInFalse
#     420         from proveit.logic import TRUE, FALSE
#
# ImportError: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     197                         # assumptions utilized in the last derivation step.
# --> 198                         sideEffect(assumptions=assumptions)
#     199                     except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/equality/not_equals.py in unfold(self, assumptions)
#      98         from ._theorems_ import unfoldNotEquals
# ---> 99         return unfoldNotEquals.specialize({x:self.lhs, y:self.rhs}, assumptions=assumptions)
#     100
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, repl_map, relabel_map, assumptions)
#     736             repl_map.update(relabel_map)
# --> 737         return self.instantiate(repl_map, assumptions=assumptions)
#     738
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in instantiate(self, repl_map, num_forall_eliminations, assumptions)
#     894                               equiv_alt_expansions=equiv_alt_expansions,
# --> 895                               assumptions=assumptions))
#     896
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_known_truth, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1019             Proof.__init__(self, instantiated_truth, requirements,
# -> 1020                            marked_req_indices)
#    1021         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths, markedRequiredTruthIndices)
#     136             # (if it has not already been processed):
# --> 137             provenTruth.deriveSideEffects(defaults.assumptions)
#     138
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     201                     except Exception as e:
# --> 202                         raise Exception("Side effect failure for %s, while running %s: "%(str(self.expr), str(sideEffect)) + str(e))
#     203             finally:
#
# Exception: Side effect failure for [not](TRUE = FALSE), while running <bound method Not.deriveInBool of [not](TRUE = FALSE)>: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-66c6c3088e07> in <module>
# ----> 1 get_ipython().run_line_magic('proving', 'trueNotFalse presuming [proveit.logic.equality.notEqualsSymmetry]')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <decorator-gen-135> in proving(self, line)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in proving(self, line)
#     637                 thm = knownTruth.proof()
#     638                 presumptions[k] = str(thm) # full path of theorem
# --> 639         begin_proof_result = ProveItMagicCommands.proving(self, theorem_name, presumptions)
#     640         assert isinstance(begin_proof_result, Expression), "Expecting result of 'proving' to be an expression"
#     641         # assign the theorem name to the theorem expression
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in proving(self, theorem_name, presumptions, justRecordPresumingInfo)
#     420         self.context = Context('..') # the context should be up a directory from the _proofs_ directory
#     421         sys.path.append('..')
# --> 422         proving_theorem = self.context.getTheorem(theorem_name)
#     423         proving_theorem_truth = proving_theorem.provenTruth
#     424         print("Beginning proof of", theorem_name)
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/context.py in getTheorem(self, name)
#     290         Return the Theorem of the given name in this context.
#     291         '''
# --> 292         return self._storage.getTheorem(name)
#     293
#     294     @staticmethod
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_context_storage.py in getTheorem(self, name)
#     498             return self._loadedTheorems[name]
#     499         expr = self._getSpecialStatementExpr('theorem', name)
# --> 500         thm = self._loadedTheorems[name] = Theorem(expr, self.context, name)
#     501         return thm
#     502
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, expr, context, name)
#     570         self._possibleProofs = []
#     571         # Note that _setUsability will be called within Proof.__init__
# --> 572         Proof.__init__(self, KnownTruth(expr, frozenset()), [])
#     573         Theorem.allTheorems.append(self)
#     574
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths, markedRequiredTruthIndices)
#     135             # May derive any side-effects that are obvious consequences arising from this truth
#     136             # (if it has not already been processed):
# --> 137             provenTruth.deriveSideEffects(defaults.assumptions)
#     138
#     139     def _updateDependencies(self, newproof):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self, assumptions)
#     200                         pass
#     201                     except Exception as e:
# --> 202                         raise Exception("Side effect failure for %s, while running %s: "%(str(self.expr), str(sideEffect)) + str(e))
#     203             finally:
#     204                 KnownTruth.in_progress_to_derive_sideeffects.remove(self)
#
# Exception: Side effect failure for TRUE != FALSE, while running <bound method NotEquals.unfold of TRUE != FALSE>: Side effect failure for [not](TRUE = FALSE), while running <bound method Not.deriveInBool of [not](TRUE = FALSE)>: cannot import name 'substituteTruth' from 'proveit.logic.equality._theorems_' (/home/wwitzel/Prove-It/packages/proveit/logic/equality/_theorems_.py)

# %%
# %qed
