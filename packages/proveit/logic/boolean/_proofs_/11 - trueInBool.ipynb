# %%
from proveit.logic.boolean._theorems_ import trueInBool, inBoolEquiv, trueEqTrueEval, trueEqFalseEval
from proveit.logic.boolean.disjunction._theorems_ import trueOrFalse

# %%
trueInBool.beginProof([inBoolEquiv, trueEqTrueEval, trueEqFalseEval, trueOrFalse])
# Out:
# Beginning proof of
# TRUE in BOOLEANS

# %%
trueInBoolEquiv = trueInBool.equivalence()
trueInBoolEquiv
# Out:
# |= (TRUE in BOOLEANS) = ((TRUE = TRUE) or (TRUE = FALSE))

# %%
trueInBoolEquiv.rhs.prove()
# Out:
# |= (TRUE = TRUE) or (TRUE = FALSE)

# %%
trueInBoolEquiv.deriveLeftViaEquivalence().qed()
# Out:
# proveit.logic.boolean.trueInBool has a proof
# proveit.logic.boolean.trueInBool has been completely proven
# proveit.logic.boolean.inBoolIfTrue has been completely proven
# <proveit._core_.proof.Specialization instance at 0x0000000004331388>

# %%
trueInBool.printRequirements()
# Out:
# proveit.logic.boolean.boolsDef
# proveit.logic.boolean.disjunction.orTF
# proveit.logic.boolean.eqTrueElim
# proveit.logic.boolean.eqTrueIntro
# proveit.logic.boolean.falseNotTrue
# proveit.logic.boolean.negation.negationElim
# proveit.logic.equality.equalsReflexivity
# proveit.logic.equality.equalsSymmetry
# proveit.logic.equality.equalsTransitivity
# proveit.logic.equality.notEqualsDef
# proveit.logic.equality.substitution
# proveit.logic.set_theory.singletonDef
# proveit.logic.set_theory.unification.unionDef
# Theorem is fully proven!
