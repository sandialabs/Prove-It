# %%
from proveit.logic.boolean._theorems_ import falseInBool, inBoolEquiv, falseEqFalseEval, falseEqTrueEval
from proveit.logic.equality._theorems_ import lhsViaEquivalence
from proveit.logic.boolean.disjunction._theorems_ import falseOrTrue

# %%
falseInBool.beginProof([inBoolEquiv, falseEqFalseEval, falseEqTrueEval, falseOrTrue, lhsViaEquivalence])
# Out:
# Beginning proof of
# FALSE in BOOLEANS

# %%
falseInBoolEquiv = falseInBool.equivalence()
falseInBoolEquiv
# Out:
# |= (FALSE in BOOLEANS) = ((FALSE = TRUE) or (FALSE = FALSE))

# %%
falseInBoolEquiv.rhs.prove()
# Out:
# |= (FALSE = TRUE) or (FALSE = FALSE)

# %%
falseInBoolEquiv.deriveLeftViaEquivalence().qed()
# Out:
# proveit.logic.boolean.falseInBool has a proof
# proveit.logic.boolean.falseInBool has been completely proven
# <proveit._core_.proof.Specialization instance at 0x0000000004263488>

# %%
falseInBool.printRequirements()
# Out:
# proveit.logic.boolean.boolsDef
# proveit.logic.boolean.disjunction.orFT
# proveit.logic.boolean.eqTrueElim
# proveit.logic.boolean.eqTrueIntro
# proveit.logic.boolean.falseNotTrue
# proveit.logic.boolean.negation.negationElim
# proveit.logic.equality.equalsReflexivity
# proveit.logic.equality.equalsSymmetry
# proveit.logic.equality.equalsTransitivity
# proveit.logic.equality.notEqualsDef
# proveit.logic.equality.substitution
# proveit.logic.set_theory.singletonDef
# proveit.logic.set_theory.unification.unionDef
# Theorem is fully proven!
