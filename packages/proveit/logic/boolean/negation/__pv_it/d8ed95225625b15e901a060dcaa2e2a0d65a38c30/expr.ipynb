# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, C
from proveit.logic import Booleans, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), Implies(A, C), Implies(Not(A), C))
# Out:
# expr: (A in BOOLEANS, A => C, [not](A) => C)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}, A \Rightarrow C, (\lnot A) \Rightarrow C\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS, A => C, [not](A) => C)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 5
# 2. A => C
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. [not](A) => C
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 6. (A, C)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. ([not](A), C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. [not](A)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
