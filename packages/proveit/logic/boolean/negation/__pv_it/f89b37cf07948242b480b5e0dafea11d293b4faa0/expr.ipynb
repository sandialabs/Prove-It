# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Not, TRUE
from proveit.logic.boolean.negation._theorems_ import notFalse

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Not(notFalse.expr), Not(TRUE))
# Out:
# expr: ([not]([not](FALSE)), [not](TRUE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\lnot (\lnot \bot), \lnot \top\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ([not]([not](FALSE)), [not](TRUE))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [not]([not](FALSE))
#    core type: Operation
#    operator: 5
#    operand: 3
# 2. [not](TRUE)
#    core type: Operation
#    operator: 5
#    operand: 4
# 3. [not](FALSE)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. TRUE
#    core type: Literal
#    sub-expressions:
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. FALSE
#    core type: Literal
#    sub-expressions:
