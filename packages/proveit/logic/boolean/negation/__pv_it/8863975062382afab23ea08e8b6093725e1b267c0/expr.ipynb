# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A
from proveit.logic import Booleans, Equals, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Not(Not(A)), A), InSet(A, Booleans))
# Out:
# expr: {[not]([not](A)) = A if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{(\lnot (\lnot A)) = A \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not]([not](A)) = A if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [not]([not](A)) = A
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ([not]([not](A)), A)
#    core type: ExprTuple
#    sub-expressions: 7, 11
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 7. [not]([not](A))
#    core type: Operation
#    operator: 10
#    operand: 9
# 8. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 9. [not](A)
#    core type: Operation
#    operator: 10
#    operand: 11
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
