# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../_theory_.ipynb">negation</a>.<a href="../_theorems_.ipynb#negationContradiction" class="ProveItLink">negationContradiction</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import A
from proveit.logic import Not
from proveit.logic.boolean.negation._axioms_ import notT
theory = proveit.Theory() # the theorem's theory

# %%
# %proving negationContradiction

# %%
defaults.assumptions = negationContradiction.conditions

# %%
AeqT = A.evaluation([A])

# %%
notTrue = AeqT.subRightSideInto(Not(A))

# %%
notT

# %%
notT.deriveRightViaEquality()

# %%
# %qed
