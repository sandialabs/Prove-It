# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">negation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#doubleNegationElim">doubleNegationElim</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit._common_ import A
from proveit.logic import inBool, Not
from proveit.logic.boolean.negation._axioms_ import notT, notF
from proveit.logic.boolean.negation._theorems_ import doubleNegationElimLemma

# %%
# %proving doubleNegationElim

# %%
defaults.assumptions = doubleNegationElim.conditions

# %%
doubleNegationElimLemma

# %%
doubleNegationElimLemma.instantiate({A:A})

# %%
# %qed
