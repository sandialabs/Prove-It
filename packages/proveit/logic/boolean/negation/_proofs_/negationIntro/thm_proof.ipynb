# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">negation</a>.<a class="ProveItLink" href="../_theorems_.ipynb#negationIntro">negationIntro</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean.negation._theorems_ import notFalse
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving negationIntro presuming [proveit.logic.equality.subLeftSideInto]

# %%
AeqF = negationIntro.condition

# %%
notFalse

# %%
AeqF.subLeftSideInto(notFalse, assumptions=[AeqF])

# %%
# %qed
