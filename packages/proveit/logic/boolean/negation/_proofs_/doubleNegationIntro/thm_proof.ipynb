# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">negation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#doubleNegationIntro">doubleNegationIntro</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A
from proveit.logic import Not
theory = proveit.Theory() # the theorem's theory

# %%
# %proving doubleNegationIntro

# %%
notA_eq_F = Not(A).evaluation([A])

# %%
notA_eq_F.deriveViaBooleanEquality()

# %%
# %qed # proven via automation
