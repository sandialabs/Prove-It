# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Forall, Not, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Not(Or(A, B)), conditions = [Not(A), Not(B)])
# Out:
# expr: forall_{A, B | [not](A), [not](B)} [not](A or B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~\lnot A, \lnot B}~(\lnot \left(A \lor B\right))

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | [not](A), [not](B)} [not](A or B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {[not](A or B) if [not](A) ,  [not](B).
#    core type: Lambda
#    parameters: 10\n   body: 3
# 3. {[not](A or B) if [not](A) ,  [not](B).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [not](A or B)
#    core type: Operation
#    operator: 14
#    operand: 6
# 5. [not](A) and [not](B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A or B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ([not](A), [not](B))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. [not](A)
#     core type: Operation
#     operator: 14
#     operand: 13
# 12. [not](B)
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. not
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
