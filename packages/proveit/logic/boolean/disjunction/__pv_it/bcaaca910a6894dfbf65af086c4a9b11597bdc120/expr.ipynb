# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Or(A, B), Or(B, A)), And(InSet(A, Booleans), InSet(B, Booleans)))
# Out:
# expr: {(A or B) = (B or A) if A in BOOLEANS ,  B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \lor B\right) = \left(B \lor A\right) \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A or B) = (B or A) if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A or B) = (B or A)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in BOOLEANS) and (B in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A or B, B or A)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEANS, B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. A or B
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B or A
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. A in BOOLEANS
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. B in BOOLEANS
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. (B, A)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 14. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
