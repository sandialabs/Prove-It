# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(A, And(InSet(A, Booleans), InSet(B, Booleans), Or(A, B), Not(B))))
# Out:
# expr: (A, B) -> {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  A \lor B ,  \lnot B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).
#    core type: Conditional
#    value: 16
#    condition: 2
# 2. (A in BOOLEANS) and (B in BOOLEANS) and (A or B) and [not](B)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A in BOOLEANS, B in BOOLEANS, A or B, [not](B))
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. A or B
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. [not](B)
#    core type: Operation
#    operator: 14
#    operand: 17
# 9. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. not
#     core type: Literal
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
