# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#multiDisjunctionDef">multiDisjunctionDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._axioms_ import multiDisjunctionDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr multiDisjunctionDef
# Out:
# Passed sanity check: built 'multiDisjunctionDef' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multiDisjunctionDef.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B}~\left(\left(A_{1} \lor \ldots \lor A_{m} \lor B\right) = \left(\left(A_{1} \lor \ldots \lor A_{m}\right) \lor B\right)\right)\right]

# %%
# display the expression information
multiDisjunctionDef.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) = ((A_{1} or ..A_{_a}.. or A_{m}) or B))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) = ((A_{1} or ..A_{_a}.. or A_{m}) or B)) if m in Naturals.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) = ((A_{1} or ..A_{_a}.. or A_{m}) or B)) if m in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) = ((A_{1} or ..A_{_a}.. or A_{m}) or B))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
