# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.core_expr_types._common_ import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_l, B, C_1_to_m, D_1_to_n], Or(A_1_to_l, C_1_to_m, B, D_1_to_n), condition = Or(A_1_to_l, B, C_1_to_m, D_1_to_n))
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{l}, B, C_{1}, \ldots, C_{m}, D_{1}, \ldots, D_{n}~|~A_{1} \lor \ldots \lor A_{l} \lor B \lor C_{1} \lor \ldots \lor C_{m} \lor D_{1} \lor \ldots \lor D_{n}}~\left(A_{1} \lor \ldots \lor A_{l} \lor C_{1} \lor \ldots \lor C_{m} \lor B \lor D_{1} \lor \ldots \lor D_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}.
#    core type: Lambda
#    parameters: 8\n   body: 3
# 3. {A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 11, 10, 12
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 18
#    end_index: 14
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 18
#     end_index: 16
# 12. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 20
# 14. l
#     core type: Variable
#     sub-expressions:
# 15. _a -> C_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 21
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. _a -> D_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. A_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 21. C_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 22. D_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. C
#     core type: Variable
#     sub-expressions:
# 25. D
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
