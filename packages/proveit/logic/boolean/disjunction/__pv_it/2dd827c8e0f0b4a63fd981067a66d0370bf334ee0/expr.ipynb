# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, InSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(Or(A, B, C, D), Booleans))
# Out:
# expr: {(A or B or C or D) in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \lor B \lor C \lor D\right) \in \mathbb{B}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A or B or C or D) in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D) in BOOLEANS
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (A or B or C or D, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A or B or C or D
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A, B, C, D)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. D
#     core type: Variable
#     sub-expressions:
