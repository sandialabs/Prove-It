# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Not, Or

# %%
# build up the expression from sub-expressions
subExpr1 = Or(A, B)
subExpr2 = InSet(A, Booleans)
subExpr3 = InSet(B, Booleans)
subExpr4 = Not(And(Not(A), Not(B)))
expr = ExprTuple(Conditional(subExpr1, And(subExpr2, And(subExpr3, subExpr4))), Conditional(subExpr1, And(subExpr2, subExpr3, subExpr4)))
# Out:
# expr: (A or B if A in BOOLEANS ,  (B in BOOLEANS) and [not]([not](A) and [not](B)), A or B if A in BOOLEANS ,  B in BOOLEANS ,  [not]([not](A) and [not](B)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \lor B \textrm{ if } A \in \mathbb{B} ,  \left(B \in \mathbb{B}\right) \land (\lnot \left((\lnot A) \land (\lnot B)\right)), A \lor B \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  \lnot \left((\lnot A) \land (\lnot B)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A or B if A in BOOLEANS ,  (B in BOOLEANS) and [not]([not](A) and [not](B)), A or B if A in BOOLEANS ,  B in BOOLEANS ,  [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {A or B if A in BOOLEANS ,  (B in BOOLEANS) and [not]([not](A) and [not](B)).
#    core type: Conditional
#    value: 4
#    condition: 3
# 2. {A or B if A in BOOLEANS ,  B in BOOLEANS ,  [not]([not](A) and [not](B)).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. (A in BOOLEANS) and ((B in BOOLEANS) and [not]([not](A) and [not](B)))
#    core type: Operation
#    operator: 20
#    operands: 6
# 4. A or B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (A in BOOLEANS) and (B in BOOLEANS) and [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 20
#    operands: 9
# 6. (A in BOOLEANS, (B in BOOLEANS) and [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 24, 26
# 9. (A in BOOLEANS, B in BOOLEANS, [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 11, 14, 15
# 10. (B in BOOLEANS) and [not]([not](A) and [not](B))
#     core type: Operation
#     operator: 20
#     operands: 12
# 11. A in BOOLEANS
#     core type: Operation
#     operator: 16
#     operands: 13
# 12. (B in BOOLEANS, [not]([not](A) and [not](B)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 19
# 14. B in BOOLEANS
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. [not]([not](A) and [not](B))
#     core type: Operation
#     operator: 25
#     operand: 18
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 26, 19
# 18. [not](A) and [not](B)
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. ([not](A), [not](B))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. [not](A)
#     core type: Operation
#     operator: 25
#     operand: 24
# 23. [not](B)
#     core type: Operation
#     operator: 25
#     operand: 26
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. not
#     core type: Literal
#     sub-expressions:
# 26. B
#     core type: Variable
#     sub-expressions:
