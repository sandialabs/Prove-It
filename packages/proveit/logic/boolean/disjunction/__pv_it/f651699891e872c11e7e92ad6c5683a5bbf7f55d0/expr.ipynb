# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import And, Not, Set

# %%
# build up the expression from sub-expressions
expr = Set(Not(And(Not(A), Not(B), Not(C))))
# Out:
# expr: {[not]([not](A) and [not](B) and [not](C))}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lnot \left((\lnot A) \land (\lnot B) \land (\lnot C)\right)\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not]([not](A) and [not](B) and [not](C))}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. [not]([not](A) and [not](B) and [not](C))
#    core type: Operation
#    operator: 11
#    operand: 3
# 3. [not](A) and [not](B) and [not](C)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ([not](A), [not](B), [not](C))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 9
# 7. [not](B)
#    core type: Operation
#    operator: 11
#    operand: 10
# 8. [not](C)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
