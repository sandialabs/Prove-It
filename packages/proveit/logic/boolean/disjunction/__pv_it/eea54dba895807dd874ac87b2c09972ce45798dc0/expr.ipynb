# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([B], InSet(Or(A, B), Booleans), domain = Booleans), InSet(A, Booleans))
# Out:
# expr: {forall_{B in BOOLEANS} ((A or B) in BOOLEANS) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{B \in \mathbb{B}}~\left(\left(A \lor B\right) \in \mathbb{B}\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{B in BOOLEANS} ((A or B) in BOOLEANS) if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{B in BOOLEANS} ((A or B) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> {(A or B) in BOOLEANS if B in BOOLEANS.
#    core type: Lambda
#    parameter: 17
#    body: 6
# 5. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 13
# 6. {(A or B) in BOOLEANS if B in BOOLEANS.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (A or B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 12. A or B
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
