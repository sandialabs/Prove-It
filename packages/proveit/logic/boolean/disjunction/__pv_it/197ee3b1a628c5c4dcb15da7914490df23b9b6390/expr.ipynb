# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import H, I, k
from proveit.core_expr_types import Len
from proveit.number import one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([H, I]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: (|(H, I)|, |(1, ..k.., 2)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(H, I\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(H, I)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(H, I)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((H, I))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (H, I)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. H
#    core type: Variable
#    sub-expressions:
# 9. I
#    core type: Variable
#    sub-expressions:
# 10. 1, ..k.., 2
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. k -> k
#     core type: Lambda
#     parameter: 14
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. k
#     core type: Variable
#     sub-expressions:
