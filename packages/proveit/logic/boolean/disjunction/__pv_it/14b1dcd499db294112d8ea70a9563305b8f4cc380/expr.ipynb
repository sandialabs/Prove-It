# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#singularConstructiveMultiDilemma">singularConstructiveMultiDilemma</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import singularConstructiveMultiDilemma

# %%
# check that the built expression is the same as the stored expression
# %check_expr singularConstructiveMultiDilemma
# Out:
# Passed sanity check: built 'singularConstructiveMultiDilemma' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(singularConstructiveMultiDilemma.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}~|~A_{1} \lor \ldots \lor A_{m}}~\left[\forall_{C~|~A_{1} \Rightarrow C, \ldots, A_{m} \Rightarrow C}~C\right]\right]

# %%
# display the expression information
singularConstructiveMultiDilemma.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C]]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C] if m in Naturals.
#    core type: Lambda
#    parameter: 31
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C] if m in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C]
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. m in Naturals
#    core type: Operation
#    operator: 26
#    operands: 6
# ...
