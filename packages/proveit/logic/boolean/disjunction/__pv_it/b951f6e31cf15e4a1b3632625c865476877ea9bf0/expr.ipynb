# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(A, Booleans), InSet(Or(A, B), Booleans))
# Out:
# expr: {A in BOOLEANS if (A or B) in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \in \mathbb{B} \textrm{ if } \left(A \lor B\right) \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in BOOLEANS if (A or B) in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (A or B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A or B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
