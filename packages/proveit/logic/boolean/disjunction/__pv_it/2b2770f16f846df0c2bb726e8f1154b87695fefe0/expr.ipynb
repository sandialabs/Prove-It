# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Booleans, Forall, InSet, Or
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_m], InSet(Or(A_1_to_m), Booleans), domain = Booleans), InSet(m, NaturalsPos))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS) if m in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS) if m in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalsPos
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS).
#    core type: Lambda
#    parameter: 18
#    body: 6
# 5. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS).
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 26
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 28
#     body: 19
# 18. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> A_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. m
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. A_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
