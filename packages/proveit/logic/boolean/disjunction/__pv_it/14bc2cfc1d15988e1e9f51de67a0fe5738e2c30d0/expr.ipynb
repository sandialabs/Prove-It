# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import A, a, m
from proveit.core_expr_types import Len
from proveit.logic import Booleans, InSet
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Len([ExprRange(a, InSet(IndexedVar(A, a), Booleans), one, m), InSet(IndexedVar(A, Add(m, one)), Booleans)])
# Out:
# expr: |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}, A_{m + 1} \in \mathbb{B}\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (A_{1} in BOOLEANS), ..(A_{a} in BOOLEANS).., (A_{m} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 20
#    end_index: 19
# 5. A_{m + 1} in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 7
# 6. a -> (A_{a} in BOOLEANS)
#    core type: Lambda
#    parameter: 18
#    body: 8
# 7. (A_{m + 1}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 14
# 8. A_{a} in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. A_{m + 1}
#    core type: IndexedVar
# variable: 17
# index: 12
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (A_{a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. m + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. A_{a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
