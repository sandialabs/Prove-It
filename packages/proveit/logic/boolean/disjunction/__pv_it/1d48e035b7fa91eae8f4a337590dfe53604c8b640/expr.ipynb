# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, m, n
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, Booleans, Forall, Implies, InSet, Or
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(A, one)
subExpr3 = IndexedVar(A, subExpr1)
subExpr4 = ExprRange(subExpr1, subExpr3, one, Add(m, one))
subExpr5 = ExprRange(subExpr1, subExpr3, one, n)
expr = Implies(And(Forall([subExpr2], InSet(subExpr2, Booleans), domain = Booleans), Forall([m], Forall([subExpr4], InSet(Or(subExpr4), Booleans), domain = Booleans), domain = NaturalsPos, condition = Forall([A_1_to_m], InSet(Or(A_1_to_m), Booleans), domain = Booleans))), Forall([n], Forall([subExpr5], InSet(Or(subExpr5), Booleans), domain = Booleans), domain = NaturalsPos))
# Out:
# expr: ([forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]) => [forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[\forall_{A_{1} \in \mathbb{B}}~\left(A_{1} \in \mathbb{B}\right)\right] \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)}~\left[\forall_{A_{1}, \ldots, A_{m + 1} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B}\right)\right]\right]\right) \Rightarrow \left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{A_{1}, \ldots, A_{n} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{n}\right) \in \mathbb{B}\right)\right]\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ([forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]) => [forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ([forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]], forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]
#    core type: Operation
#    operator: 52
#    operands: 5
# 4. forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]
#    core type: Operation
#    operator: 36
#    operand: 6
# 5. (forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS), forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. n -> {forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 54
#    body: 9
# 7. forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)
#    core type: Operation
#    operator: 36
#    operand: 10
# 8. forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]
#    core type: Operation
#    operator: 36
#    operand: 11
# 9. {forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS) if n in NaturalsPos.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. A_{1} -> {A_{1} in BOOLEANS if A_{1} in BOOLEANS.
#     core type: Lambda
#     parameter: 27
#     body: 14
# 11. m -> {forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS) if m in NaturalsPos ,  forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS).
#     core type: Lambda
#     parameter: 68
#     body: 15
# 12. forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)
#     core type: Operation
#     operator: 36
#     operand: 16
# 13. n in NaturalsPos
#     core type: Operation
#     operator: 69
#     operands: 17
# 14. {A_{1} in BOOLEANS if A_{1} in BOOLEANS.
#     core type: Conditional
#     value: 18
#     condition: 18
# 15. {forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS) if m in NaturalsPos ,  forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS).
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. (A_{1}, ..A_{_a}.., A_{n}) -> {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).
#     core type: Lambda
#     parameter: 49
#     body: 21
# 17. (n, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 54, 42
# 18. A_{1} in BOOLEANS
#     core type: Operation
#     operator: 69
#     operands: 22
# 19. forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)
#     core type: Operation
#     operator: 36
#     operand: 23
# 20. (m in NaturalsPos) and [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)]
#     core type: Operation
#     operator: 52
#     operands: 24
# 21. {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. (A_{1}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 27, 72
# 23. (A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS).
#     core type: Lambda
#     parameter: 55
#     body: 28
# 24. (m in NaturalsPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. (A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS
#     core type: Operation
#     operator: 69
#     operands: 31
# 26. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS)
#     core type: Operation
#     operator: 52
#     operands: 32
# 27. A_{1}
#     core type: IndexedVar
# variable: 73
# index: 67
# 28. {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS).
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. m in NaturalsPos
#     core type: Operation
#     operator: 69
#     operands: 35
# 30. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)
#     core type: Operation
#     operator: 36
#     operand: 37
# 31. (A_{1} or ..A_{_a}.. or A_{n}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 38, 72
# 32. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{n} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 39
# 33. (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS
#     core type: Operation
#     operator: 69
#     operands: 40
# 34. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)
#     core type: Operation
#     operator: 52
#     operands: 41
# 35. (m, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 68, 42
# 36. forall
#     core type: Literal
#     sub-expressions:
# 37. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS).
#     core type: Lambda
#     parameter: 64
#     body: 43
# 38. A_{1} or ..A_{_a}.. or A_{n}
#     core type: Operation
#     operator: 59
#     operands: 44
# 39. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 67
#     end_index: 54
# 40. (A_{1} or ..A_{_a}.. or A_{m + 1}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 45, 72
# 41. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 43. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS).
#     core type: Conditional
#     value: 47
#     condition: 48
# 44. (A_{1}, ..A_{_a}.., A_{n})
#     core type: ExprTuple
#     sub-expressions: 49
# 45. A_{1} or ..A_{_a}.. or A_{m + 1}
#     core type: Operation
#     operator: 59
#     operands: 50
# 46. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 67
#     end_index: 58
# 47. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS
#     core type: Operation
#     operator: 69
#     operands: 51
# 48. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS)
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. A_{1}, ..A_{_a}.., A_{n}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 67
#     end_index: 54
# 50. (A_{1}, ..A_{_a}.., A_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 55
# 51. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 56, 72
# 52. and
#     core type: Literal
#     sub-expressions:
# 53. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. A_{1}, ..A_{_a}.., A_{m + 1}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 67
#     end_index: 58
# 56. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 67
#     end_index: 68
# 58. m + 1
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. or
#     core type: Literal
#     sub-expressions:
# 60. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 64
# 61. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 74
#     body: 65
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 68, 67
# 64. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 67
#     end_index: 68
# 65. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. _a -> A_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 71
# 67. 1
#     core type: Literal
#     sub-expressions:
# 68. m
#     core type: Variable
#     sub-expressions:
# 69. in
#     core type: Literal
#     sub-expressions:
# 70. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 71. A_{_a}
#     core type: IndexedVar
# variable: 73
# index: 74
# 72. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 73. A
#     core type: Variable
#     sub-expressions:
# 74. _a
#     core type: Variable
#     sub-expressions:
