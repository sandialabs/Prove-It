# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rightwardCommutation">rightwardCommutation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import rightwardCommutation

# %%
# check that the built expression is the same as the stored expression
# %check_expr rightwardCommutation
# Out:
# Passed sanity check: built 'rightwardCommutation' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rightwardCommutation.latex())
# Out:
# \vdash \forall_{l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{A_{1} \in \mathbb{B}, \ldots, A_{l} \in \mathbb{B}, B \in \mathbb{B}, C_{1} \in \mathbb{B}, \ldots, C_{m} \in \mathbb{B}, D_{1} \in \mathbb{B}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor B \lor C_{1} \lor \ldots \lor C_{m} \lor D_{1} \lor \ldots \lor D_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor C_{1} \lor \ldots \lor C_{m} \lor B \lor D_{1} \lor \ldots \lor D_{n}\right) \end{array}\right)\right]

# %%
# display the expression information
rightwardCommutation.exprInfo()
# Out:
# 0. forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (l, m, n) -> {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 44, 46, 49
# 3. {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (l in Naturals) and (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{m} in BOOLEANS ,  D_{1} in BOOLEANS ,  ..D_{_a} in BOOLEANS.. ,  D_{n} in BOOLEANS.
#    core type: Lambda
#    parameters: 29\n   body: 9
# 8. (l in Naturals, m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{m} in BOOLEANS ,  D_{1} in BOOLEANS ,  ..D_{_a} in BOOLEANS.. ,  D_{n} in BOOLEANS.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. l in Naturals
#     core type: Operation
#     operator: 52
#     operands: 15
# 11. m in Naturals
#     core type: Operation
#     operator: 52
#     operands: 16
# 12. n in Naturals
#     core type: Operation
#     operator: 52
#     operands: 17
# 13. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{l} in BOOLEANS) and (B in BOOLEANS) and (C_{1} in BOOLEANS) and ..(C_{_a} in BOOLEANS).. and (C_{m} in BOOLEANS) and (D_{1} in BOOLEANS) and ..(D_{_a} in BOOLEANS).. and (D_{n} in BOOLEANS)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (l, Naturals)
#     core type: ExprTuple
#     sub-expressions: 44, 22
# 16. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 46, 22
# 17. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 49, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}, A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 22. Naturals
#     core type: Literal
#     sub-expressions:
# 23. A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{l} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 48
#     end_index: 44
# 26. B in BOOLEANS
#     core type: Operation
#     operator: 52
#     operands: 33
# 27. (C_{1} in BOOLEANS), ..(C_{_a} in BOOLEANS).., (C_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 48
#     end_index: 46
# 28. (D_{1} in BOOLEANS), ..(D_{_a} in BOOLEANS).., (D_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 48
#     end_index: 49
# 29. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 40, 37, 38
# 30. or
#     core type: Literal
#     sub-expressions:
# 31. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 40, 38
# 32. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 61
#     body: 39
# 33. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 40, 57
# 34. _a -> (C_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 61
#     body: 41
# 35. _a -> (D_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 61
#     body: 42
# 36. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 48
#     end_index: 44
# 37. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 48
#     end_index: 46
# 38. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 39. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 52
#     operands: 50
# 40. B
#     core type: Variable
#     sub-expressions:
# 41. C_{_a} in BOOLEANS
#     core type: Operation
#     operator: 52
#     operands: 51
# 42. D_{_a} in BOOLEANS
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. _a -> A_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 44. l
#     core type: Variable
#     sub-expressions:
# 45. _a -> C_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 55
# 46. m
#     core type: Variable
#     sub-expressions:
# 47. _a -> D_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 56
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 51. (C_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (D_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. A_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 55. C_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. D_{_a}
#     core type: IndexedVar
# variable: 60
# index: 61
# 57. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 58. A
#     core type: Variable
#     sub-expressions:
# 59. C
#     core type: Variable
#     sub-expressions:
# 60. D
#     core type: Variable
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
