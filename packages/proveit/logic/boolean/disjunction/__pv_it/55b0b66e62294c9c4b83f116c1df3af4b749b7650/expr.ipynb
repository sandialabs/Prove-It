# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import C
from proveit.core_expr_types._common_ import A_1_to_l, B_1_to_m, D_1_to_n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(A_1_to_l, C, B_1_to_m, D_1_to_n)
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{l}, C, B_{1}, \ldots, B_{m}, D_{1}, \ldots, D_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 10
#    end_index: 6
# 2. C
#    core type: Variable
#    sub-expressions:
# 3. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 10
#    end_index: 8
# 4. D_{1}, ..D_{_a}.., D_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 5. _a -> A_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 12
# 6. l
#    core type: Variable
#    sub-expressions:
# 7. _a -> B_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 13
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. _a -> D_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 14
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. A_{_a}
#     core type: IndexedVar
# variable: 15
# index: 18
# 13. B_{_a}
#     core type: IndexedVar
# variable: 16
# index: 18
# 14. D_{_a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. D
#     core type: Variable
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
