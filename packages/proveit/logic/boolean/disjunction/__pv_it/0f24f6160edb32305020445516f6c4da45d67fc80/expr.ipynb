# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import Equals, FALSE, Or

# %%
# build up the expression from sub-expressions
expr = Equals(Or(FALSE), Or(FALSE, FALSE))
# Out:
# expr: [or](FALSE) = (FALSE or FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\lor\right]\left(\bot\right) = \left(\bot \lor \bot\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [or](FALSE) = (FALSE or FALSE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ([or](FALSE), FALSE or FALSE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [or](FALSE)
#    core type: Operation
#    operator: 5
#    operand: 7
# 4. FALSE or FALSE
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (FALSE, FALSE)
#    core type: ExprTuple
#    sub-expressions: 7, 7
# 7. FALSE
#    core type: Literal
#    sub-expressions:
