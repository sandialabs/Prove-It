# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Not

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), And(InSet(B, Booleans), Not(And(Not(A), Not(B)))))
# Out:
# expr: (A in BOOLEANS, (B in BOOLEANS) and [not]([not](A) and [not](B)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}, \left(B \in \mathbb{B}\right) \land (\lnot \left((\lnot A) \land (\lnot B)\right))\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS, (B in BOOLEANS) and [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (B in BOOLEANS) and [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 10
# 4. (B in BOOLEANS, [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 16
#    operand: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 9. [not](A) and [not](B)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. ([not](A), [not](B))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. [not](A)
#     core type: Operation
#     operator: 16
#     operand: 15
# 14. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
