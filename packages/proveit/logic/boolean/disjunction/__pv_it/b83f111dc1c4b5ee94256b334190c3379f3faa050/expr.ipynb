# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A
from proveit.logic import Booleans, Equals, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Conditional(Equals(Or(A), A), InSet(A, Booleans)))
# Out:
# expr: A -> {[or](A) = A if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A \mapsto \left\{\left[\lor\right]\left(A\right) = A \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> {[or](A) = A if A in BOOLEANS.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {[or](A) = A if A in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [or](A) = A
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ([or](A), A)
#    core type: ExprTuple
#    sub-expressions: 8, 11
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 8. [or](A)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
