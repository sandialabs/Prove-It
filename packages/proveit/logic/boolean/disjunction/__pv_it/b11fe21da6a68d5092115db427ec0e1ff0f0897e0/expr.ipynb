# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Or(A, B), Not(And(Not(A), Not(B)))))
# Out:
# expr: (A, B) -> {A or B if [not]([not](A) and [not](B)).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \lor B \textrm{ if } \lnot \left((\lnot A) \land (\lnot B)\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A or B if [not]([not](A) and [not](B)).
#    core type: Lambda
#    parameters: 5\n   body: 1
# 1. {A or B if [not]([not](A) and [not](B)).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A or B
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 12
#    operand: 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A, B)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 6. [not](A) and [not](B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ([not](A), [not](B))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. [not](A)
#    core type: Operation
#    operator: 12
#    operand: 11
# 10. [not](B)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
