# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Implies, InSet, Not, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(A, B), InSet(A, Booleans), Implies(A, C), Not(C), InSet(B, Booleans), Implies(B, C))
# Out:
# expr: {A or B, A in BOOLEANS, A => C, [not](C), B in BOOLEANS, B => C}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \lor B, A \in \mathbb{B}, A \Rightarrow C, \lnot C, B \in \mathbb{B}, B \Rightarrow C\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or B, A in BOOLEANS, A => C, [not](C), B in BOOLEANS, B => C}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B, A in BOOLEANS, A => C, [not](C), B in BOOLEANS, B => C)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8
# 3. A or B
#    core type: Operation
#    operator: 9
#    operands: 10
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 11
# 5. A => C
#    core type: Operation
#    operator: 16
#    operands: 12
# 6. [not](C)
#    core type: Operation
#    operator: 13
#    operand: 21
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. B => C
#    core type: Operation
#    operator: 16
#    operands: 17
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 11. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 12. (A, C)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (B, C)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. C
#     core type: Variable
#     sub-expressions:
