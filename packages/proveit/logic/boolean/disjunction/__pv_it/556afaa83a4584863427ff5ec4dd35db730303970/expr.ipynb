# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import And, Equals, Not, TRUE
from proveit.logic.boolean.negation._theorems_ import notFalse

# %%
# build up the expression from sub-expressions
expr = Equals(Not(And(notFalse.expr, notFalse.expr)), Not(TRUE))
# Out:
# expr: [not]([not](FALSE) and [not](FALSE)) = [not](TRUE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# (\lnot \left((\lnot \bot) \land (\lnot \bot)\right)) = (\lnot \top)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not]([not](FALSE) and [not](FALSE)) = [not](TRUE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ([not]([not](FALSE) and [not](FALSE)), [not](TRUE))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [not]([not](FALSE) and [not](FALSE))
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. [not](TRUE)
#    core type: Operation
#    operator: 10
#    operand: 6
# 5. [not](FALSE) and [not](FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. TRUE
#    core type: Literal
#    sub-expressions:
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ([not](FALSE), [not](FALSE))
#    core type: ExprTuple
#    sub-expressions: 9, 9
# 9. [not](FALSE)
#    core type: Operation
#    operator: 10
#    operand: 11
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. FALSE
#     core type: Literal
#     sub-expressions:
