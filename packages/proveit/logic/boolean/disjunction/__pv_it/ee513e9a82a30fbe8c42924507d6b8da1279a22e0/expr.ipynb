# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, n
from proveit.logic import Booleans, Forall, InSet, Or
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = ExprRange(subExpr1, IndexedVar(A, subExpr1), one, n)
expr = Forall([n], Forall([subExpr2], InSet(Or(subExpr2), Booleans), domain = Booleans), domain = NaturalsPos)
# Out:
# expr: forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{A_{1}, \ldots, A_{n} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{n}\right) \in \mathbb{B}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{n}) -> {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).
#    core type: Lambda
#    parameter: 20
#    body: 8
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A_{1} or ..A_{_a}.. or A_{n}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{n} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. A_{1} or ..A_{_a}.. or A_{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. or
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. A_{1}, ..A_{_a}.., A_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> A_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. A_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 29. A
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
