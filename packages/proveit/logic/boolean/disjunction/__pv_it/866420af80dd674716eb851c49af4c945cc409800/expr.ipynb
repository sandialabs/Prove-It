# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#constructiveMultiDilemma">constructiveMultiDilemma</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import constructiveMultiDilemma

# %%
# check that the built expression is the same as the stored expression
# %check_expr constructiveMultiDilemma
# Out:
# Passed sanity check: built 'constructiveMultiDilemma' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(constructiveMultiDilemma.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}, B_{1} \in \mathbb{B}, \ldots, B_{m} \in \mathbb{B}~|~A_{1} \lor \ldots \lor A_{m}, A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left(B_{1} \lor \ldots \lor B_{m}\right)\right]

# %%
# display the expression information
constructiveMultiDilemma.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m}) if m in Naturals.
#    core type: Lambda
#    parameter: 36
#    body: 2
# 2. {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m}) if m in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# ...
