# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import P__x_1_to_m_y_1_to_n, R__x_1_to_m_y_1_to_n, y_1_to_n
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Forall([y_1_to_n], P__x_1_to_m_y_1_to_n, condition = R__x_1_to_m_y_1_to_n)
# Out:
# expr: forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{y_{1}, \ldots, y_{n}~|~R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameter: 10
#    body: 3
# 3. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 8
# 5. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. R
#    core type: Variable
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x_{1}, ..x_{_a}.., x_{m}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 14
#    end_index: 12
# 10. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 11. _a -> x_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 16
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. _a -> y_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. x_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 17. y_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
