# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import A, m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Booleans, Forall, InSet, Or
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(A, one)
subExpr3 = ExprRange(subExpr1, IndexedVar(A, subExpr1), one, Add(m, one))
expr = ExprTuple(Forall([subExpr2], InSet(subExpr2, Booleans), domain = Booleans), Forall([m], Forall([subExpr3], InSet(Or(subExpr3), Booleans), domain = Booleans), domain = NaturalsPos, condition = Forall([A_1_to_m], InSet(Or(A_1_to_m), Booleans), domain = Booleans)))
# Out:
# expr: (forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS), forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{A_{1} \in \mathbb{B}}~\left(A_{1} \in \mathbb{B}\right), \forall_{m \in \mathbb{N}^+~|~\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)}~\left[\forall_{A_{1}, \ldots, A_{m + 1} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B}\right)\right]\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS), forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)
#    core type: Operation
#    operator: 20
#    operand: 3
# 2. forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. A_{1} -> {A_{1} in BOOLEANS if A_{1} in BOOLEANS.
#    core type: Lambda
#    parameter: 13
#    body: 5
# ...
