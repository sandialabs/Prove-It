# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import Booleans, Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m, B, C_1_to_n], Or(A_1_to_m, B, C_1_to_n), domains = [Booleans, Booleans, Booleans], condition = B)
# Out:
# expr: forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS | B} (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}, B \in \mathbb{B}, C_{1} \in \mathbb{B}, \ldots, C_{n} \in \mathbb{B}~|~B}~\left(A_{1} \lor \ldots \lor A_{m} \lor B \lor C_{1} \lor \ldots \lor C_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS | B} (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n} if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{m} in BOOLEANS ,  B in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{n} in BOOLEANS ,  B.
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n} if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{m} in BOOLEANS ,  B in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{n} in BOOLEANS ,  B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS) and (B in BOOLEANS) and (C_{1} in BOOLEANS) and ..(C_{_a} in BOOLEANS).. and (C_{n} in BOOLEANS) and B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 24, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS, B)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 24
# 10. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 21
#     end_index: 18
# 11. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 21
#     end_index: 22
# 12. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 18
# 13. B in BOOLEANS
#     core type: Operation
#     operator: 27
#     operands: 19
# 14. (C_{1} in BOOLEANS), ..(C_{_a} in BOOLEANS).., (C_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 15. _a -> A_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 29
# 16. _a -> C_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 30
# 17. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 34
#     body: 23
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 31
# 20. _a -> (C_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 34
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 27
#     operands: 26
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. C_{_a} in BOOLEANS
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (C_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. A_{_a}
#     core type: IndexedVar
# variable: 32
# index: 34
# 30. C_{_a}
#     core type: IndexedVar
# variable: 33
# index: 34
# 31. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 32. A
#     core type: Variable
#     sub-expressions:
# 33. C
#     core type: Variable
#     sub-expressions:
# 34. _a
#     core type: Variable
#     sub-expressions:
