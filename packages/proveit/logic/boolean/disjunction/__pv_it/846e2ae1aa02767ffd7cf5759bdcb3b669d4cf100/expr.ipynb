# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(C, Booleans), InSet(A, Booleans), InSet(B, Booleans), InSet(D, Booleans))
# Out:
# expr: {C in BOOLEANS, A in BOOLEANS, B in BOOLEANS, D in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{C \in \mathbb{B}, A \in \mathbb{B}, B \in \mathbb{B}, D \in \mathbb{B}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {C in BOOLEANS, A in BOOLEANS, B in BOOLEANS, D in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (C in BOOLEANS, A in BOOLEANS, B in BOOLEANS, D in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. C in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. D in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (C, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (D, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. D
#     core type: Variable
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
