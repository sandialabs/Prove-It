# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types._common_ import P__x_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(P__x_1_to_n, Equals([x_1_to_n], [y_1_to_n]))
# Out:
# expr: (P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P(x_{1}, \ldots, x_{n}), \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 3
#    operands: 6
# 2. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. _a -> x_{_a}
#     core type: Lambda
#     parameter: 18
#     body: 14
# 11. _a -> y_{_a}
#     core type: Lambda
#     parameter: 18
#     body: 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. x_{_a}
#     core type: IndexedVar
# variable: 16
# index: 18
# 15. y_{_a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. y
#     core type: Variable
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
