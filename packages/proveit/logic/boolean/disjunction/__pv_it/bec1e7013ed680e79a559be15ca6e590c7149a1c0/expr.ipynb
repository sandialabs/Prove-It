# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Or(A, B), And(InSet(A, Booleans), InSet(B, Booleans), A)))
# Out:
# expr: (A, B) -> {A or B if A in BOOLEANS ,  B in BOOLEANS ,  A.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \lor B \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  A\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A or B if A in BOOLEANS ,  B in BOOLEANS ,  A.
#    core type: Lambda
#    parameters: 5\n   body: 1
# 1. {A or B if A in BOOLEANS ,  B in BOOLEANS ,  A.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A or B
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A in BOOLEANS) and (B in BOOLEANS) and A
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A, B)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A in BOOLEANS, B in BOOLEANS, A)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 13
# 8. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
