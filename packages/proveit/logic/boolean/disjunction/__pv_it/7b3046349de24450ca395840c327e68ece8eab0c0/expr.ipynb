# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import A, m
from proveit.logic import And, Booleans, InSet, Or
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(A, subExpr1)
subExpr3 = Add(m, one)
subExpr4 = ExprRange(subExpr1, subExpr2, one, subExpr3)
expr = Lambda(subExpr4, Conditional(InSet(Or(subExpr4), Booleans), And(ExprRange(subExpr1, InSet(subExpr2, Booleans), one, subExpr3))))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{m + 1}\right) \mapsto \left\{\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B} \textrm{ if } \left(A_{1} \in \mathbb{B}\right) \land \ldots \land \left(A_{m + 1} \in \mathbb{B}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS).
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS
#    core type: Operation
#    operator: 16
#    operands: 4
# 3. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A_{1} or ..A_{_a}.. or A_{m + 1}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 21
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. A_{1} or ..A_{_a}.. or A_{m + 1}
# ...
