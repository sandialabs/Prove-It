# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import C
from proveit.logic import And, Booleans, InSet
from proveit.number import four, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, InSet(IndexedVar(C, subExpr1), Booleans), one, four))
# Out:
# expr: (C_{1} in BOOLEANS) and ..(C_{_a} in BOOLEANS).. and (C_{4} in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(C_{1} \in \mathbb{B}\right) \land \ldots \land \left(C_{4} \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (C_{1} in BOOLEANS) and ..(C_{_a} in BOOLEANS).. and (C_{4} in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{4} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (C_{1} in BOOLEANS), ..(C_{_a} in BOOLEANS).., (C_{4} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> (C_{_a} in BOOLEANS)
#    core type: Lambda
#    parameter: 13
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. 4
#    core type: Literal
#    sub-expressions:
# 7. C_{_a} in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (C_{_a}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. C_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
