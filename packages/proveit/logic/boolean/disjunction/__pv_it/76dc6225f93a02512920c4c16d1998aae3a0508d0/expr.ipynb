# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import A, m
from proveit.logic import Booleans, InSet
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(A, subExpr1), Booleans), one, m), InSet(IndexedVar(A, Add(m, one)), Booleans))
# Out:
# expr: (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}, A_{m + 1} \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 17
#    end_index: 16
# 2. A_{m + 1} in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. _a -> (A_{_a} in BOOLEANS)
#    core type: Lambda
#    parameter: 15
#    body: 5
# 4. (A_{m + 1}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 11
# 5. A_{_a} in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A_{m + 1}
#    core type: IndexedVar
# variable: 14
# index: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A_{_a}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. m + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. A_{_a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
