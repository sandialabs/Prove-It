# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import A, n
from proveit.logic import Booleans, InSet
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, InSet(IndexedVar(A, subExpr1), Booleans), one, n))
# Out:
# expr: (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{n} in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \in \mathbb{B}, \ldots, A_{n} \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{n} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{n} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _a -> (A_{_a} in BOOLEANS)
#    core type: Lambda
#    parameter: 11
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. A_{_a} in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A_{_a}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
