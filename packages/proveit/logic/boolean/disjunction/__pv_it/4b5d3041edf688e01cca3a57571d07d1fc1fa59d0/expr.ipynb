# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, m
from proveit.logic import Booleans, InSet
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprRange(subExpr1, InSet(IndexedVar(A, subExpr1), Booleans), one, Add(m, one))
# Out:
# expr: (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \in \mathbb{B}\right), \ldots, \left(A_{m + 1} \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 9
#    end_index: 2
# 1. _a -> (A_{_a} in BOOLEANS)
#    core type: Lambda
#    parameter: 13
#    body: 3
# 2. m + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. A_{_a} in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A_{_a}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. A_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
