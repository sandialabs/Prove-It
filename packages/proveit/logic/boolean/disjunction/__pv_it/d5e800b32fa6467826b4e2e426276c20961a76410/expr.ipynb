# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import f, i, j
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_i_to_j, iter_ext_equiv
from proveit.logic import Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([f, i, j], iter_ext_equiv, condition = InSet(Len([f_i_to_j]), Naturals))
# Out:
# expr: forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, i, j~|~|\left(f(i), \ldots, f(j)\right)| \in \mathbb{N}}~\left(\begin{array}{c} \left(f(i), \ldots, f(j + 1)\right) =  \\ \left(f(i), \ldots, f(j), f(j + 1)\right) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {(f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)) if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 29, 26, 27
# 4. {(f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)) if |(f(i), ..f(a).., f(j))| in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. |(f(i), ..f(a).., f(j))| in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((f(i), ..f(a).., f(j + 1)), (f(i), ..f(a).., f(j), f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (|(f(i), ..f(a).., f(j))|, Naturals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i), ..f(a).., f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (f(i), ..f(a).., f(j), f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 23, 16
# 13. |(f(i), ..f(a).., f(j))|
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Naturals
#     core type: Literal
#     sub-expressions:
# 15. f(i), ..f(a).., f(j + 1)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 19
# 16. f(j + 1)
#     core type: Operation
#     operator: 29
#     operand: 19
# 17. length
#     core type: Literal
#     sub-expressions:
# 18. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. j + 1
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 23. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. a -> f(a)
#     core type: Lambda
#     parameter: 30
#     body: 28
# 26. i
#     core type: Variable
#     sub-expressions:
# 27. j
#     core type: Variable
#     sub-expressions:
# 28. f(a)
#     core type: Operation
#     operator: 29
#     operand: 30
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
