# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar
from proveit._common_ import A, C, i, m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Booleans, Forall, Implies, InSet, Or
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_m], Forall([C], C, condition = ExprRange(i, Implies(IndexedVar(A, i), C), one, m)), domain = Booleans, condition = Or(A_1_to_m)), InSet(m, Naturals))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C] if m in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}~|~A_{1} \lor \ldots \lor A_{m}}~\left[\forall_{C~|~A_{1} \Rightarrow C, \ldots, A_{m} \Rightarrow C}~C\right] \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C] if m in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS | A_{1} or ..A_{_a}.. or A_{m}} [forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C]
#    core type: Operation
#    operator: 9
#    operand: 3
# 2. m in Naturals
#    core type: Operation
#    operator: 24
#    operands: 4
# 3. (A_{1}, ..A_{_a}.., A_{m}) -> {forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{m} in BOOLEANS ,  A_{1} or ..A_{_a}.. or A_{m}.
#    core type: Lambda
#    parameter: 22
#    body: 5
# 4. (m, Naturals)
#    core type: ExprTuple
#    sub-expressions: 29, 6
# 5. {forall_{C | A_{1} => C, ..A_{i} => C.., A_{m} => C} C if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{m} in BOOLEANS ,  A_{1} or ..A_{_a}.. or A_{m}.
# ...
