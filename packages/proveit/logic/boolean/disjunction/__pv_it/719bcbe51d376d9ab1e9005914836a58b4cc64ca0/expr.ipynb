# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftwardCommute">leftwardCommute</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import leftwardCommute

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftwardCommute
# Out:
# Passed sanity check: built 'leftwardCommute' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftwardCommute.latex())
# Out:
# \vdash \forall_{l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C, D_{1}, \ldots, D_{n}~|~A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C \lor D_{1} \lor \ldots \lor D_{n}}~\left(A_{1} \lor \ldots \lor A_{l} \lor C \lor B_{1} \lor \ldots \lor B_{m} \lor D_{1} \lor \ldots \lor D_{n}\right)\right]

# %%
# display the expression information
leftwardCommute.exprInfo()
# Out:
# 0. forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n})]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n}) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 29, 31, 34
# 3. {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n}) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} | A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}} (A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n})
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (l in Naturals) and (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}.
#    core type: Lambda
#    parameters: 22\n   body: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (l in Naturals, m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. {A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. l in Naturals
#     core type: Operation
#     operator: 18
#     operands: 16
# 12. m in Naturals
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. n in Naturals
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (l, Naturals)
#     core type: ExprTuple
#     sub-expressions: 29, 23
# 17. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 34, 23
# 20. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 26, 25, 27
# 21. or
#     core type: Literal
#     sub-expressions:
# 22. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 23. Naturals
#     core type: Literal
#     sub-expressions:
# 24. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 33
#     end_index: 29
# 25. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 33
#     end_index: 31
# 26. C
#     core type: Variable
#     sub-expressions:
# 27. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 28. _a -> A_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 35
# 29. l
#     core type: Variable
#     sub-expressions:
# 30. _a -> B_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 36
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. _a -> D_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 37
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. A_{_a}
#     core type: IndexedVar
# variable: 38
# index: 41
# 36. B_{_a}
#     core type: IndexedVar
# variable: 39
# index: 41
# 37. D_{_a}
#     core type: IndexedVar
# variable: 40
# index: 41
# 38. A
#     core type: Variable
#     sub-expressions:
# 39. B
#     core type: Variable
#     sub-expressions:
# 40. D
#     core type: Variable
#     sub-expressions:
# 41. _a
#     core type: Variable
#     sub-expressions:
