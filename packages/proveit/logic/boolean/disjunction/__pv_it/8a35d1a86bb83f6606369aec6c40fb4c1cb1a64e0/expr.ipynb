# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import A, a, m
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(A, a)
subExpr2 = Add(m, one)
expr = ExprTuple([ExprRange(a, subExpr1, one, m), IndexedVar(A, subExpr2)], [ExprRange(a, subExpr1, one, subExpr2)])
# Out:
# expr: ((A_{1}, ..A_{a}.., A_{m}, A_{m + 1}), (A_{1}, ..A_{a}.., A_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1}, \ldots, A_{m}, A_{m + 1}\right), \left(A_{1}, \ldots, A_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((A_{1}, ..A_{a}.., A_{m}, A_{m + 1}), (A_{1}, ..A_{a}.., A_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A_{1}, ..A_{a}.., A_{m}, A_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (A_{1}, ..A_{a}.., A_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. A_{1}, ..A_{a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 14
#    end_index: 13
# 4. A_{m + 1}
#    core type: IndexedVar
# variable: 11
# index: 7
# 5. A_{1}, ..A_{a}.., A_{m + 1}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 14
#    end_index: 7
# 6. a -> A_{a}
#    core type: Lambda
#    parameter: 12
#    body: 8
# 7. m + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. A_{a}
#    core type: IndexedVar
# variable: 11
# index: 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
