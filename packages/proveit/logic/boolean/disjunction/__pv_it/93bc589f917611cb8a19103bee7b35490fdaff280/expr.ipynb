# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(A, And(InSet(A, Booleans), InSet(B, Booleans), Or(A, B), Not(B)))
# Out:
# expr: {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  A \lor B ,  \lnot B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).
#    core type: Conditional
#    value: 15
#    condition: 1
# 1. (A in BOOLEANS) and (B in BOOLEANS) and (A or B) and [not](B)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (A in BOOLEANS, B in BOOLEANS, A or B, [not](B))
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6, 7
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. A or B
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. [not](B)
#    core type: Operation
#    operator: 13
#    operand: 16
# 8. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
