# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftIfNotRight">leftIfNotRight</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import leftIfNotRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftIfNotRight
# Out:
# Passed sanity check: built 'leftIfNotRight' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftIfNotRight.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}, B \in \mathbb{B}~|~A \lor B, \lnot B}~A

# %%
# display the expression information
leftIfNotRight.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS, B in BOOLEANS | A or B, [not](B)} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {A if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  [not](B).
#    core type: Conditional
#    value: 18
#    condition: 4
# 4. (A in BOOLEANS) and (B in BOOLEANS) and (A or B) and [not](B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEANS, B in BOOLEANS, A or B, [not](B))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. A or B
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. [not](B)
# ...
