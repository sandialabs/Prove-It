# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, m
from proveit.logic import And, Booleans, InSet
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, InSet(IndexedVar(A, subExpr1), Booleans), one, Add(m, one)))
# Out:
# expr: (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \in \mathbb{B}\right) \land \ldots \land \left(A_{m + 1} \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 12
#    end_index: 5
# 4. _a -> (A_{_a} in BOOLEANS)
#    core type: Lambda
#    parameter: 16
#    body: 6
# 5. m + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A_{_a} in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. A_{_a}
#     core type: IndexedVar
# variable: 15
# index: 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. _a
#     core type: Variable
#     sub-expressions:
