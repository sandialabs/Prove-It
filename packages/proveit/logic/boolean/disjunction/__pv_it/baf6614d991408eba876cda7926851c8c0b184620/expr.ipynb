# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#constrainedSingularConstructiveDilemma">constrainedSingularConstructiveDilemma</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import constrainedSingularConstructiveDilemma

# %%
# check that the built expression is the same as the stored expression
# %check_expr constrainedSingularConstructiveDilemma
# Out:
# Passed sanity check: built 'constrainedSingularConstructiveDilemma' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(constrainedSingularConstructiveDilemma.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}, B \in \mathbb{B}, C \in \mathbb{B}~|~A \lor B, A \Rightarrow C, B \Rightarrow C}~C

# %%
# display the expression information
constrainedSingularConstructiveDilemma.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS, B in BOOLEANS, C in BOOLEANS | A or B, A => C, B => C} C
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {C if A in BOOLEANS ,  B in BOOLEANS ,  C in BOOLEANS ,  A or B ,  A => C ,  B => C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 24, 25, 26
# 4. {C if A in BOOLEANS ,  B in BOOLEANS ,  C in BOOLEANS ,  A or B ,  A => C ,  B => C.
#    core type: Conditional
#    value: 26
#    condition: 5
# 5. (A in BOOLEANS) and (B in BOOLEANS) and (C in BOOLEANS) and (A or B) and (A => C) and (B => C)
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A in BOOLEANS, B in BOOLEANS, C in BOOLEANS, A or B, A => C, B => C)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 8. A in BOOLEANS
#    core type: Operation
# ...
