# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import A, a, k, m
from proveit.core_expr_types import Len
from proveit.logic import Booleans, InSet
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(m, one)
expr = ExprTuple(Len([ExprRange(a, InSet(IndexedVar(A, a), Booleans), one, subExpr1)]), Len([ExprRange(k, k, one, subExpr1)]))
# Out:
# expr: (|(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS)|, |(1, ..k.., m + 1)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(A_{1} \in \mathbb{B}, \ldots, A_{m + 1} \in \mathbb{B}\right)|, |\left(1, \ldots, m + 1\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS)|, |(1, ..k.., m + 1)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., m + 1)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., m + 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., m + 1)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (A_{1} in BOOLEANS), ..(A_{a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 20
#    end_index: 12
# 9. 1, ..k.., (m + 1)
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 20
#    end_index: 12
# 10. a -> (A_{a} in BOOLEANS)
#     core type: Lambda
#     parameter: 24
#     body: 13
# 11. k -> k
#     core type: Lambda
#     parameter: 14
#     body: 14
# 12. m + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. A_{a} in BOOLEANS
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. k
#     core type: Variable
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (A_{a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. A_{a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 22. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
