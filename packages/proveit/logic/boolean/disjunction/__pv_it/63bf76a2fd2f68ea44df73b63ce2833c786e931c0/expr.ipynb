# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, C, D
from proveit.logic import Booleans, Implies, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(C, Booleans), InSet(D, Booleans), Implies(A, C))
# Out:
# expr: {C in BOOLEANS, D in BOOLEANS, A => C}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{C \in \mathbb{B}, D \in \mathbb{B}, A \Rightarrow C\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {C in BOOLEANS, D in BOOLEANS, A => C}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (C in BOOLEANS, D in BOOLEANS, A => C)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. C in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. D in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. A => C
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (C, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (D, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (A, C)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. D
#     core type: Variable
#     sub-expressions:
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
