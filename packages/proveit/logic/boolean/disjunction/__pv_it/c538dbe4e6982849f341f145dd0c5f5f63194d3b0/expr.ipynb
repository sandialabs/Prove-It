# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#disassociation">disassociation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import disassociation

# %%
# check that the built expression is the same as the stored expression
# %check_expr disassociation
# Out:
# Passed sanity check: built 'disassociation' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(disassociation.latex())
# Out:
# \vdash \forall_{l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{A_{1} \in \mathbb{B}, \ldots, A_{l} \in \mathbb{B}, B_{1} \in \mathbb{B}, \ldots, B_{m} \in \mathbb{B}, C_{1} \in \mathbb{B}, \ldots, C_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor \left(B_{1} \lor \ldots \lor B_{m}\right) \lor C_{1} \lor \ldots \lor C_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C_{1} \lor \ldots \lor C_{n}\right) \end{array}\right)\right]

# %%
# display the expression information
disassociation.exprInfo()
# Out:
# 0. forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (l, m, n) -> {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 42, 55, 44
# 3. {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (l in Naturals) and (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {(A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B_{1} in BOOLEANS ,  ..B_{_a} in BOOLEANS.. ,  B_{m} in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{n} in BOOLEANS.
#    core type: Lambda
#    parameters: 29\n   body: 9
# 8. (l in Naturals, m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B_{1} in BOOLEANS ,  ..B_{_a} in BOOLEANS.. ,  B_{m} in BOOLEANS ,  C_{1} in BOOLEANS ,  ..C_{_a} in BOOLEANS.. ,  C_{n} in BOOLEANS.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. l in Naturals
#     core type: Operation
#     operator: 47
#     operands: 15
# 11. m in Naturals
#     core type: Operation
#     operator: 47
#     operands: 16
# 12. n in Naturals
#     core type: Operation
#     operator: 47
#     operands: 17
# 13. (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{l} in BOOLEANS) and (B_{1} in BOOLEANS) and ..(B_{_a} in BOOLEANS).. and (B_{m} in BOOLEANS) and (C_{1} in BOOLEANS) and ..(C_{_a} in BOOLEANS).. and (C_{n} in BOOLEANS)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (l, Naturals)
#     core type: ExprTuple
#     sub-expressions: 42, 22
# 16. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 55, 22
# 17. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 44, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}, A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{n} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 22. Naturals
#     core type: Literal
#     sub-expressions:
# 23. A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}
#     core type: Operation
#     operator: 39
#     operands: 28
# 24. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}
#     core type: Operation
#     operator: 39
#     operands: 29
# 25. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{l} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 54
#     end_index: 42
# 26. (B_{1} in BOOLEANS), ..(B_{_a} in BOOLEANS).., (B_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 54
#     end_index: 55
# 27. (C_{1} in BOOLEANS), ..(C_{_a} in BOOLEANS).., (C_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 44
# 28. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 33, 35
# 29. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 49, 35
# 30. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 36
# 31. _a -> (B_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 37
# 32. _a -> (C_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 38
# 33. B_{1} or ..B_{_a}.. or B_{m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 54
#     end_index: 42
# 35. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 54
#     end_index: 44
# 36. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 47
#     operands: 45
# 37. B_{_a} in BOOLEANS
#     core type: Operation
#     operator: 47
#     operands: 46
# 38. C_{_a} in BOOLEANS
#     core type: Operation
#     operator: 47
#     operands: 48
# 39. or
#     core type: Literal
#     sub-expressions:
# 40. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 49
# 41. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 50
# 42. l
#     core type: Variable
#     sub-expressions:
# 43. _a -> C_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 51
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 46. (B_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 58, 52
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (C_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 50. A_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 51. C_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 52. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 53. _a -> B_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 58
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. m
#     core type: Variable
#     sub-expressions:
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. C
#     core type: Variable
#     sub-expressions:
# 58. B_{_a}
#     core type: IndexedVar
# variable: 59
# index: 60
# 59. B
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
