# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import A, i, m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Forall, Not, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m], Not(Or(A_1_to_m)), condition = ExprRange(i, Not(IndexedVar(A, i)), one, m))
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m} | [not](A_{1}), ..[not](A_{i}).., [not](A_{m})} [not](A_{1} or ..A_{_a}.. or A_{m})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m}~|~\lnot A_{1}, \ldots, \lnot A_{m}}~(\lnot \left(A_{1} \lor \ldots \lor A_{m}\right))

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m} | [not](A_{1}), ..[not](A_{i}).., [not](A_{m})} [not](A_{1} or ..A_{_a}.. or A_{m})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{m}) -> {[not](A_{1} or ..A_{_a}.. or A_{m}) if [not](A_{1}) and ..[not](A_{i}).. and [not](A_{m}).
#    core type: Lambda
#    parameter: 12
#    body: 3
# 3. {[not](A_{1} or ..A_{_a}.. or A_{m}) if [not](A_{1}) and ..[not](A_{i}).. and [not](A_{m}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [not](A_{1} or ..A_{_a}.. or A_{m})
#    core type: Operation
#    operator: 19
#    operand: 6
# 5. [not](A_{1}) and ..[not](A_{i}).. and [not](A_{m})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A_{1} or ..A_{_a}.. or A_{m}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 15
#     end_index: 16
# 12. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 13. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 23
#     body: 17
# 14. _a -> A_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. [not](A_{i})
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 21
# 19. not
#     core type: Literal
#     sub-expressions:
# 20. A_{i}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. _a
#     core type: Variable
#     sub-expressions:
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. i
#     core type: Variable
#     sub-expressions:
