# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Equals, Or

# %%
# build up the expression from sub-expressions
expr = Equals(Or(A, B, C, D), Or(C, Or(A, B), D))
# Out:
# expr: (A or B or C or D) = (C or (A or B) or D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \lor B \lor C \lor D\right) = \left(C \lor \left(A \lor B\right) \lor D\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A or B or C or D) = (C or (A or B) or D)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D, C or (A or B) or D)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A or B or C or D
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. C or (A or B) or D
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (A, B, C, D)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 7, 9
# 6. (C, A or B, D)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. C
#    core type: Variable
#    sub-expressions:
# 8. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. D
#    core type: Variable
#    sub-expressions:
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
