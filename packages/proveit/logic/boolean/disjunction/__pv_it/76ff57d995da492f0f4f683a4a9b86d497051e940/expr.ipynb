# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit._common_ import A, n
from proveit.logic import And, Booleans, InSet, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(A, subExpr1)
expr = Conditional(InSet(Or(ExprRange(subExpr1, subExpr2, one, n)), Booleans), And(ExprRange(subExpr1, InSet(subExpr2, Booleans), one, n)))
# Out:
# expr: {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A_{1} \lor \ldots \lor A_{n}\right) \in \mathbb{B} \textrm{ if } \left(A_{1} \in \mathbb{B}\right) \land \ldots \land \left(A_{n} \in \mathbb{B}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS if (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{n} in BOOLEANS)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A_{1} or ..A_{_a}.. or A_{n}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 19
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{n} in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_{1} or ..A_{_a}.. or A_{n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{n} in BOOLEANS)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# 8. or
#    core type: Literal
# ...
