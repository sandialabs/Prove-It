# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../_theory_.ipynb">disjunction</a>.<a href="../_theorems_.ipynb#trueOrFalse" class="ProveItLink">trueOrFalse</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean.disjunction._axioms_ import orTF
theory = proveit.Theory() # the theorem's theory

# %%
# %proving trueOrFalse

# %%
# %qed
