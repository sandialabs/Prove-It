# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">disjunction</a>.<a href="../_theorems_.ipynb#closure" class="ProveItLink">closure</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import KnownTruth
from proveit.logic.set_theory._common_ import EmptySet
from proveit.logic.set_theory.cardinality._axioms_ import emptyCard
from proveit import Operation, IndexedVar
from proveit.logic import Forall, InSet, Or, Booleans, inBool, And
from proveit._common_ import A, B, Q, x, i, l, m, n, P,S
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.number import num, Exp, Add, one, Naturals, Less, zero, Greater
from proveit.number.sets.integer._theorems_ import natPosInduction
#from proveit.number.sets.integer._axioms_ import emptyNatDef
from proveit.logic.boolean.disjunction._axioms_ import multiDisjunctionDef, emptyDisjunction
from proveit.logic.boolean.disjunction._theorems_ import binaryClosure
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving closure presuming [proveit.number, proveit.logic.equality.sub_in_right_operands, proveit.logic.boolean.conjunction.someFromAnd, proveit.logic.set_theory.containment.supersetMembershipFromSubset, proveit.number.addition.addNatClosureBin, proveit.number.sets.integer.natPosInduction, proveit.core_expr_types.tuples.singular_range_reduction, proveit.core_expr_types.tuples.merge_extension]
# Out:
# Beginning proof of closure
# Recorded 'presuming' information
# Presuming theorems in proveit.number (except any that presume this theorem).
# Presuming proveit.core_expr_types.tuples.merge_extension, proveit.core_expr_types.tuples.singular_range_reduction, proveit.logic.boolean.conjunction.someFromAnd, proveit.logic.equality.sub_in_right_operands, proveit.logic.set_theory.containment.supersetMembershipFromSubset, proveit.number.addition.addNatClosureBin, proveit.number.sets.integer.natPosInduction theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# closure: forall_{m in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)]

# %%
closure.instanceExpr
# Out:
# forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)

# %%
natPosInduction
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])

# %%
from proveit import Function
from proveit._common_ import P, m
induction_inst = \
    natPosInduction.instantiate({Function(P, m):closure.instanceExpr})
# Out:
# induction_inst: |- ([forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]) => [forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]]

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# induction_base: forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)

# %%
induction_base.prove()
# Out:
# |- forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1]
# Out:
# induction_step: forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]

# %%
inBool_conds = induction_step.instanceExpr.conditions[0]
# Out:
# inBool_conds: (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{m + 1} in BOOLEANS)

# %%
defaults.assumptions = (induction_step.conditions + [inBool_conds])
# Out:
# defaults.assumptions: (m in NaturalsPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS)

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# induction_hyp: forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)

# %% [markdown]
# ***Splitting apart the conjunction of "in Bool" conditions is an important step***

# %%
inBool_cond_partition = inBool_conds.partition(m)
# Out:
# inBool_cond_partition: {m in NaturalsPos} |- (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS) = (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)

# %%
inBool_conds_conjunction = And(inBool_conds).prove()
# Out:
# inBool_conds_conjunction: {A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)

# %%
inBool_conds_conjunction_partition = \
    inBool_cond_partition.subRightSideInto(inBool_conds_conjunction)
# Out:
# inBool_conds_conjunction_partition: {m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS) and (A_{m + 1} in BOOLEANS)

# %%
inBool_conds_conjunction_partition.deriveSome(0)
# Out:
# {m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS)

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS

# %% [markdown]
# ***And now we will be able to prove the induction step via binaryClosure and multiDisjunctionDef***

# %%
last_inBool_cond = inBool_conds_conjunction_partition.deriveAny(1)
# Out:
# last_inBool_cond: {m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- A_{m + 1} in BOOLEANS

# %%
A_mp1 = last_inBool_cond.element
# Out:
# A_mp1: A_{m + 1}

# %%
binaryClosure
# Out:
# |- forall_{A in BOOLEANS, B in BOOLEANS} ((A or B) in BOOLEANS)

# %%
binary_conclusion = binaryClosure.instantiate({A:Or(A_1_to_m), B:A_mp1})
# Out:
# binary_conclusion: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}) in BOOLEANS

# %%
multi_disjunction_eq = multiDisjunctionDef.instantiate({B:A_mp1})
# Out:
# multi_disjunction_eq: {m in NaturalsPos} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) = ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1})

# %%
pre_merge_conclusion = multi_disjunction_eq.subLeftSideInto(binary_conclusion)
# Out:
# pre_merge_conclusion: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) in BOOLEANS

# %%
pre_merge_conclusion.innerExpr().element.operands.merge()
# Out:
# {m in NaturalsPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS

# %%
induction_step
# Out:
# forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.deriveConsequent()
# Out:
# closure has been proven.  Now simply execute "%qed".
# |- forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]
# 1	instantiation	3, 4, 5, 6*, 7*	|- ([forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]) => [forall_{n in NaturalsPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEANS)]]
# 	P(m) : forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)
# 2	instantiation	8, 9, 10	|- [forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)] and [forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]]
# 	A : forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS), B : forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]
# 3	theorem		|- forall_{P} ((P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])
# 	proveit.number.sets.integer.natPosInduction
# 4	instantiation	11	|- (A_{1}, ..A_{a}.., A_{1}) = (A_{1})
# 	f(_a) : A_{_a}, i : 1
# 5	instantiation	11	|- (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{1} in BOOLEANS) = (A_{1} in BOOLEANS)
# 	f(_a) : A_{_a} in BOOLEANS, i : 1
# 6	instantiation	12, 13	{[and](A_{1} in BOOLEANS)} |- [or](A_{1}) = A_{1}
# 	A : A_{1}
# 7	instantiation	14	|- {A_{1} in BOOLEANS if [and](A_{1} in BOOLEANS). = {A_{1} in BOOLEANS if A_{1} in BOOLEANS.
# 	a : A_{1} in BOOLEANS, Q : A_{1} in BOOLEANS
# 8	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.boolean.conjunction.andIfBoth
# 9	generalizaton	15	|- forall_{A_{1} in BOOLEANS} (A_{1} in BOOLEANS)
# 10	generalizaton	16	|- forall_{m in NaturalsPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS)]
# 11	theorem		|- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))
# 	proveit.core_expr_types.tuples.singular_range_reduction
# 12	theorem		|- forall_{A in BOOLEANS} ([or](A) = A)
# 	proveit.logic.boolean.disjunction.unaryOrReduction
# 13	instantiation	17, 18	{[and](A_{1} in BOOLEANS)} |- A_{1} in BOOLEANS
# 	A : A_{1} in BOOLEANS
# 14	theorem		|- forall_{a, Q} ({a if [and](Q). \\  = {a if Q.)
# 	proveit.core_expr_types.conditionals.singular_conjunction_condition_reduction
# 15	assumption		{A_{1} in BOOLEANS} |- A_{1} in BOOLEANS
# 16	instantiation	42, 48, 19, 20, 21, 22	{m in NaturalsPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEANS
# 	n : m + 1, P(_b_{1}, .._b_{_a}.., _b_{m + 1}) : (_b_{1} or .._b_{_a}.. or _b_{m + 1}) in BOOLEANS, x : (A_{1}, ..A_{_a}.., A_{m}, A_{m + 1}), y : (A_{1}, ..A_{a}.., A_{m + 1})
# 17	theorem		|- forall_{A | [and](A)} A
# 	proveit.logic.boolean.conjunction.from_unary_and
# 18	assumption		{[and](A_{1} in BOOLEANS)} |- [and](A_{1} in BOOLEANS)
# 19	instantiation	49, 57	{m in NaturalsPos} |- |(A_{1}, ..A_{a}.., A_{m}, A_{m + 1})| = |(1, ..k.., m + 1)|
# 	f(_a) : A_{_a}, b : A_{m + 1}, i : m
# 20	instantiation	47, 48	{m in NaturalsPos} |- |(A_{1}, ..A_{a}.., A_{m + 1})| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(a) : A_{a}
# 21	instantiation	54, 23, 24	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) in BOOLEANS
# 	P(_b) : _b in BOOLEANS, x : A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}, y : (A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}
# 22	instantiation	25, 26	{m in NaturalsPos} |- (A_{1}, ..A_{a}.., A_{m}, A_{m + 1}) = (A_{1}, ..A_{a}.., A_{m + 1})
# 	f(_a) : A_{_a}, i : 1, j : m
# 23	instantiation	27, 28, 29	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}) in BOOLEANS
# 	A : A_{1} or ..A_{_a}.. or A_{m}, B : A_{m + 1}
# 24	instantiation	30, 57	{m in NaturalsPos} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) = ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1})
# 	m : m, A : A, B : A_{m + 1}
# 25	theorem		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j), f(j + 1)) = (f(i), ..f(a).., f(j + 1)))
# 	proveit.core_expr_types.tuples.merge_extension
# 26	instantiation	54, 57, 31	{m in NaturalsPos} |- |(A_{1}, ..A_{a}.., A_{m})| in Naturals
# 	P(_a) : _a in Naturals, x : |(A_{1}, ..A_{a}.., A_{m})|, y : m
# 27	theorem		|- forall_{A in BOOLEANS, B in BOOLEANS} ((A or B) in BOOLEANS)
# 	proveit.logic.boolean.disjunction.binaryClosure
# 28	instantiation	32, 33	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS), m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS
# 	A : A
# 29	instantiation	34, 57, 36, 38, 37, 40	{m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- A_{m + 1} in BOOLEANS
# 	m : m, n : 0, A : (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS), B : A_{m + 1} in BOOLEANS, C : ()
# 30	axiom		|- forall_{m in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) = ((A_{1} or ..A_{_a}.. or A_{m}) or B))]
# 	proveit.logic.boolean.disjunction.multiDisjunctionDef
# 31	instantiation	56, 57	{m in NaturalsPos} |- |(A_{1}, ..A_{a}.., A_{m})| = m
# 	i : m, f(a) : A_{a}
# 32	assumption		{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)} |- forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEANS} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEANS)
# 33	instantiation	35, 36, 57, 53, 37, 38, 39, 40	{m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS)
# 	l : 0, m : m, n : 1, A : (), B : (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m} in BOOLEANS), C : (A_{m + 1} in BOOLEANS)
# 34	theorem		|- forall_{m in Naturals, n in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B]
# 	proveit.logic.boolean.conjunction.anyFromAnd
# 35	theorem		|- forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}} (B_{1} and ..B_{_a}.. and B_{m})]
# 	proveit.logic.boolean.conjunction.someFromAnd
# 36	theorem		|- 0 in Naturals
# 	proveit.number.sets.integer.zeroInNats
# 37	theorem		|- |()| = |(1, ..a.., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_equiv
# 38	instantiation	47, 57	{m in NaturalsPos} |- |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS)| = |(1, ..k.., m)|
# 	i : m, f(_a) : A_{_a} in BOOLEANS
# 39	instantiation	41	|- |(A_{m + 1} in BOOLEANS)| = |(1, ..k.., 1)|
# 	a : A_{m + 1} in BOOLEANS
# 40	instantiation	42, 48, 43, 44, 45, 46	{m in NaturalsPos, A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m} in BOOLEANS) and (A_{m + 1} in BOOLEANS)
# 	n : m + 1, P(_b_{1}, .._b_{_a}.., _b_{m + 1}) : _b_{1} and .._b_{_a}.. and _b_{m + 1}, x : (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS), y : (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)
# 41	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 42	theorem		|- forall_{n in Naturals} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands
# 43	instantiation	47, 48	{m in NaturalsPos} |- |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS)| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(a) : A_{a} in BOOLEANS
# 44	instantiation	49, 57	{m in NaturalsPos} |- |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)| = |(1, ..k.., m + 1)|
# 	f(a) : A_{a} in BOOLEANS, b : A_{m + 1} in BOOLEANS, i : m
# 45	assumption		{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{m + 1} in BOOLEANS} |- (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{m + 1} in BOOLEANS)
# 46	instantiation	50, 51	{m in NaturalsPos} |- (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m + 1} in BOOLEANS) = (A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS, A_{m + 1} in BOOLEANS)
# 	f(_a) : A_{_a} in BOOLEANS, i : 1, j : m
# 47	theorem		|- forall_{i in Naturals} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_equiv
# 48	instantiation	52, 57, 53	{m in NaturalsPos} |- (m + 1) in Naturals
# 	a : m, b : 1
# 49	theorem		|- forall_{f, b} [forall_{i in Naturals} (|(f(1), ..f(a).., f(i), b)| = |(1, ..k.., i + 1)|)]
# 	proveit.core_expr_types.tuples.extended_range_from1_len_typical_equiv
# 50	axiom		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Naturals} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 51	instantiation	54, 57, 55	{m in NaturalsPos} |- |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS)| in Naturals
# 	P(_a) : _a in Naturals, x : |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS)|, y : m
# 52	theorem		|- forall_{a in Naturals, b in Naturals} ((a + b) in Naturals)
# 	proveit.number.addition.addNatClosureBin
# 53	theorem		|- 1 in Naturals
# 	proveit.number.numeral.deci.nat1
# 54	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.subLeftSideInto
# 55	instantiation	56, 57	{m in NaturalsPos} |- |(A_{1} in BOOLEANS, ..A_{a} in BOOLEANS.., A_{m} in BOOLEANS)| = m
# 	i : m, f(a) : A_{a} in BOOLEANS
# 56	theorem		|- forall_{i in Naturals} [forall_{f} (|(f(1), ..f(a).., f(i))| = i)]
# 	proveit.core_expr_types.tuples.range_from1_len
# 57	instantiation	58, 59, 60	{m in NaturalsPos} |- m in Naturals
# 	A : NaturalsPos, B : Naturals, x : m
# 58	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 59	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 60	assumption		{m in NaturalsPos} |- m in NaturalsPos
