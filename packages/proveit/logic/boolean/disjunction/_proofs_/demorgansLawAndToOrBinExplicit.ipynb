# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">disjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#demorgansLawAndToOrBinExplicit">demorgansLawAndToOrBinExplicit</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean._theorems_ import foldForallOverBool, foldConditionedForallOverBool
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving demorgansLawAndToOrBinExplicit presuming [foldForallOverBool, foldConditionedForallOverBool]
# Out:
# Beginning proof of demorgansLawAndToOrBinExplicit
# Recorded 'presuming' information
# Presuming proveit.logic.boolean.foldConditionedForallOverBool, proveit.logic.boolean.foldForallOverBool theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# demorgansLawAndToOrBinExplicit: forall_{A in BOOLEANS, B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)]
# 	m : 1, n : 1, P(A, B) : A or B, Q(A) : A in BOOLEANS, R(A, B) : (B in BOOLEANS) and [not]([not](A) and [not](B)), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)]
# 	P(A) : forall_{B in BOOLEANS | [not]([not](A) and [not](B))} (A or B), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 13, 14	|- {A or B if A in BOOLEANS ,  (B in BOOLEANS) and [not]([not](A) and [not](B)). = {A or B if A in BOOLEANS ,  B in BOOLEANS ,  [not]([not](A) and [not](B)).
# 	n : 2, a : A or B, Q : A in BOOLEANS, R : (B in BOOLEANS, [not]([not](A) and [not](B)))
# 8	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 9	instantiation	17, 15, 16	|- forall_{B in BOOLEANS | [not]([not](TRUE) and [not](B))} (TRUE or B)
# 	P(B) : TRUE or B, Q(B) : [not]([not](TRUE) and [not](B)), A : B
# 10	instantiation	17, 18, 19	|- forall_{B in BOOLEANS | [not]([not](FALSE) and [not](B))} (FALSE or B)
# 	P(B) : FALSE or B, Q(B) : [not]([not](FALSE) and [not](B)), A : B
# 11	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 12	theorem		|- forall_{n in Naturals} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 13	theorem		|- 2 in Naturals
# 	proveit.number.numeral.deci.nat2
# 14	instantiation	20	|- |(B in BOOLEANS, [not]([not](A) and [not](B)))| = |(1, ..k.., 2)|
# 	a : B in BOOLEANS, b : [not]([not](A) and [not](B))
# 15	hypothetical reasoning	21	|- [not]([not](TRUE) and [not](TRUE)) => (TRUE or TRUE)
# 16	hypothetical reasoning	22	|- [not]([not](TRUE) and [not](FALSE)) => (TRUE or FALSE)
# 17	theorem		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEANS | Q(A)} P(A)]
# 	proveit.logic.boolean.foldConditionedForallOverBool
# 18	hypothetical reasoning	23	|- [not]([not](FALSE) and [not](TRUE)) => (FALSE or TRUE)
# 19	instantiation	24, 25	|- [not]([not](FALSE) and [not](FALSE)) => (FALSE or FALSE)
# 	A : [not]([not](FALSE) and [not](FALSE)), B : FALSE or FALSE
# 20	theorem		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 	proveit.number.numeral.deci.tuple_len_2_typical_equiv
# 21	instantiation	28, 26	|- TRUE or TRUE
# 	A : TRUE or TRUE
# 22	instantiation	28, 27	|- TRUE or FALSE
# 	A : TRUE or FALSE
# 23	instantiation	28, 29	|- FALSE or TRUE
# 	A : FALSE or TRUE
# 24	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.boolean.implication.falseAntecedentImplication
# 25	instantiation	30, 31	|- [not]([not]([not](FALSE) and [not](FALSE)))
# 	A : [not]([not](FALSE) and [not](FALSE))
# 26	axiom		|- (TRUE or TRUE) = TRUE
# 	proveit.logic.boolean.disjunction.orTT
# 27	axiom		|- (TRUE or FALSE) = TRUE
# 	proveit.logic.boolean.disjunction.orTF
# 28	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.boolean.eqTrueElim
# 29	axiom		|- (FALSE or TRUE) = TRUE
# 	proveit.logic.boolean.disjunction.orFT
# 30	axiom		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.boolean.negation.negationIntro
# 31	instantiation	32, 33, 34	|- [not]([not](FALSE) and [not](FALSE)) = FALSE
# 	x : [not]([not](FALSE) and [not](FALSE)), y : [not](TRUE), z : FALSE
# 32	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equalsTransitivity
# 33	instantiation	35, 36	|- [not]([not](FALSE) and [not](FALSE)) = [not](TRUE)
# 	f(_a) : [not](_a), x : [not](FALSE) and [not](FALSE), y : TRUE
# 34	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.boolean.negation.notT
# 35	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 36	instantiation	37, 38	|- ([not](FALSE) and [not](FALSE)) = TRUE
# 	A : [not](FALSE) and [not](FALSE)
# 37	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.boolean.eqTrueIntro
# 38	instantiation	39, 40	|- [not](FALSE) and [not](FALSE)
# 	A : [not](FALSE), B : [not](FALSE)
# 39	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.boolean.conjunction.andIfBoth
# 40	theorem		|- [not](FALSE)
# 	proveit.logic.boolean.negation.notFalse
