# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">disjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unaryOrReduction">unaryOrReduction</a> theorem
# ========

# %%
import proveit
from proveit.logic import TRUE, FALSE
from proveit._common_ import A
from proveit.logic.boolean.disjunction._theorems_ import unaryOrLemma
from proveit.logic.boolean.disjunction._axioms_ import orFT, orFF
theory = proveit.Theory() # the theorem's theory

# %%
# %proving unaryOrReduction

# %%
baseCaseTRUE = unaryOrLemma.instantiate({A:TRUE})

# %%
baseCaseFALSE = unaryOrLemma.instantiate({A:FALSE})

# %%
baseCaseTRUE.subLeftSideInto(orFT)

# %%
baseCaseFALSE.subLeftSideInto(orFF)

# %%
# %qed
