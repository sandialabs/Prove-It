# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">disjunction</a>.<a href="../_theorems_.ipynb#binaryClosure" class="ProveItLink">binaryClosure</a> theorem
# ========

# %%
import proveit
# we need to import falseOrFalseNegated to derive it's side-effects:
from proveit.logic.boolean.disjunction._theorems_ import \
    (trueOrTrue, falseOrTrue, trueOrFalse, falseOrFalseNegated)
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving binaryClosure presuming [proveit.logic.boolean.quantification.universal.bundle, proveit.number.numeral.deci.posnat1]
# Out:
# Beginning proof of binaryClosure
# Recorded 'presuming' information
# Presuming proveit.logic.boolean.quantification.universal.bundle, proveit.number.numeral.deci.posnat1 theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# binaryClosure: forall_{A in BOOLEANS, B in BOOLEANS} ((A or B) in BOOLEANS)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS} ((A or B) in BOOLEANS)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A or B) in BOOLEANS)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A or B) in BOOLEANS)]
# 	m : 1, n : 1, P(A, B) : (A or B) in BOOLEANS, Q(A) : A in BOOLEANS, R(A, B) : B in BOOLEANS, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A or B) in BOOLEANS)]
# 	P(A) : forall_{B in BOOLEANS} ((A or B) in BOOLEANS), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 10, 11	|- forall_{B in BOOLEANS} ((TRUE or B) in BOOLEANS)
# 	P(B) : (TRUE or B) in BOOLEANS, A : B
# 8	instantiation	12, 13, 14	|- forall_{B in BOOLEANS} ((FALSE or B) in BOOLEANS)
# 	P(B) : (FALSE or B) in BOOLEANS, A : B
# 9	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 10	instantiation	20, 21, 15	|- (TRUE or TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE or TRUE
# 11	instantiation	20, 21, 16	|- (TRUE or FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE or FALSE
# 12	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 13	instantiation	20, 21, 17	|- (FALSE or TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : FALSE or TRUE
# 14	instantiation	18, 19	|- (FALSE or FALSE) in BOOLEANS
# 	A : FALSE or FALSE
# 15	theorem		|- TRUE or TRUE
# 	proveit.logic.boolean.disjunction.trueOrTrue
# 16	theorem		|- TRUE or FALSE
# 	proveit.logic.boolean.disjunction.trueOrFalse
# 17	theorem		|- FALSE or TRUE
# 	proveit.logic.boolean.disjunction.falseOrTrue
# 18	theorem		|- forall_{A | [not](A) in BOOLEANS} (A in BOOLEANS)
# 	proveit.logic.boolean.negation.operandInBool
# 19	instantiation	20, 21, 22	|- [not](FALSE or FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : [not](FALSE or FALSE)
# 20	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substituteTruth
# 21	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 22	theorem		|- [not](FALSE or FALSE)
# 	proveit.logic.boolean.disjunction.falseOrFalseNegated
