# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.logic.boolean.disjunction</a>
# ========

# %%
import proveit
from proveit._common_ import A, B, C, D, AA, m
from proveit.number import num
from proveit.logic import Booleans, inBool
from proveit.logic.boolean.disjunction._theorems_ import closure
# %begin demonstrations

# %%
demo1 = closure.specialize({m:num(4), AA:[A, B, C, D]}, assumptions = [inBool(A), inBool(B), inBool(C), inBool(D)])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~/ProveIt/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self)
#     186                         # assumptions utilized in the last derivation step.
# --> 187                         sideEffect(assumptions=defaults.assumptions)
#     188                     except ProofFailure:
#
# ~/ProveIt/Prove-It/packages/proveit/logic/boolean/disjunction/or_op.py in deducePartsInBool(self, assumptions)
#     216         for i in range(len(self.operands)):
# --> 217             self.deducePartInBool(i, assumptions)
#     218
#
# ~/ProveIt/Prove-It/packages/proveit/logic/boolean/disjunction/or_op.py in deducePartInBool(self, indexOrExpr, assumptions)
#     231         #attempt to replace with AA and CC over Amulti and Cmulti
# --> 232         return eachInBool.specialize({AA:self.operands[:idx], B:self.operands[idx], CC:self.operands[idx+1:]}, assumptions=assumptions)
#     233
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     754
# --> 755         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     756
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     726             # perform the appropriate substitution/relabeling
# --> 727             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     728             # obtain the KnownTruths for the substituted conditions
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     867             # make substitutions in the condition
# --> 868             subbedConditions += conditions.substituted(partialMap, relabelMap)
#     869
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         for expr in self:
# --> 334             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     335             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349             return exprMap[self]._restrictionChecked(reservedVars)
# --> 350         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     351         subbed_operands = compositeExpression(subbed_operand_or_operands)
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         for expr in self:
# --> 334             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     335             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349             return exprMap[self]._restrictionChecked(reservedVars)
# --> 350         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     351         subbed_operands = compositeExpression(subbed_operand_or_operands)
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         for expr in self:
# --> 334             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     335             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/iteration.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     280
# --> 281             for iter_range in self.lambda_map.body._expandingIterRanges(iter_params, subbed_start, subbed_end, inner_expr_map, relabelMap, inner_reservations, inner_assumptions, new_requirements):
#     282                 iter_ranges.add(iter_range)
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/indexed.py in _expandingIterRanges(self, iterParams, startArgs, endArgs, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     150
# --> 151             for (intersection_start, intersection_end) in entryRangeGenerator:
#     152                 # We must put it terms of iter parameter values (arguments) via inverting the index_expr.
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in entryRanges(self, base, start_index, end_index, assumptions, requirements)
#     318
# --> 319         if not arrived_at_end:
#     320             raise IndexError("ExprList index out of range")
#
# UnboundLocalError: local variable 'arrived_at_end' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-71703e8e305f> in <module>
# ----> 1 demo1 = closure.specialize({m:num(4), AA:[A, B, C, D]}, assumptions = [inBool(A), inBool(B), inBool(C), inBool(D)])
#       2 proveit.magics.Assignments(['demo1'], [demo1])
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     753                     processedSubMap[iVar] = iVar
#     754
# --> 755         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     756
#     757     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     751             self.mappings = mappings
#     752             specializedTruth = KnownTruth(specializedExpr, assumptions)
# --> 753             Proof.__init__(self, specializedTruth, [generalTruth] + requirementTruths)
#     754         finally:
#     755             # restore the original default assumptions
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/proof.py in __init__(self, provenTruth, requiredTruths)
#     124             if (provenTruth, defaults.assumptions) not in KnownTruth.sideeffect_processed:
#     125                 # may derive any side-effects that are obvious consequences arising from this truth:
# --> 126                 provenTruth.deriveSideEffects()
#     127
#     128     def _updateDependencies(self, newproof):
#
# ~/ProveIt/Prove-It/packages/proveit/_core_/known_truth.py in deriveSideEffects(self)
#     189                         pass
#     190                     except Exception as e:
# --> 191                         raise Exception("Side effect failure for %s: "%str(self.expr) + str(e))
#     192             finally:
#     193                 KnownTruth.in_progress_to_derive_sideeffects.remove(self)
#
# Exception: Side effect failure for (A or B or C or D) in BOOLEANS: local variable 'arrived_at_end' referenced before assignment

# %%
demo1.proof()

# %%
# %end demonstrations
