# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Conditional(Forall([B], InSet(Implies(A, B), Booleans), domain = Booleans), InSet(A, Booleans)))
# Out:
# expr: A -> {forall_{B in BOOLEANS} ((A => B) in BOOLEANS) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A \mapsto \left\{\forall_{B \in \mathbb{B}}~\left(\left(A \Rightarrow B\right) \in \mathbb{B}\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> {forall_{B in BOOLEANS} ((A => B) in BOOLEANS) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 17
#    body: 1
# 1. {forall_{B in BOOLEANS} ((A => B) in BOOLEANS) if A in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{B in BOOLEANS} ((A => B) in BOOLEANS)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> {(A => B) in BOOLEANS if B in BOOLEANS.
#    core type: Lambda
#    parameter: 18
#    body: 7
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 14
# 7. {(A => B) in BOOLEANS if B in BOOLEANS.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (A => B) in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A => B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 13. A => B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
