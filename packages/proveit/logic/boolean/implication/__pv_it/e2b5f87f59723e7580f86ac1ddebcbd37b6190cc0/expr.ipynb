# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Equals(A, B), And(InSet(A, Booleans), InSet(B, Booleans), Implies(A, B), Implies(B, A))))
# Out:
# expr: (A, B) -> {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A => B ,  B => A.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A = B \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  A \Rightarrow B ,  B \Rightarrow A\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A => B ,  B => A.
#    core type: Lambda
#    parameters: 14\n   body: 1
# 1. {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A => B ,  B => A.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A = B
#    core type: Operation
#    operator: 4
#    operands: 14
# 3. (A in BOOLEANS) and (B in BOOLEANS) and (A => B) and (B => A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEANS, B in BOOLEANS, A => B, B => A)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. A => B
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. B => A
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (B, A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
