# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import B
from proveit.logic import Booleans, FALSE, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Conditional(InSet(Iff(FALSE, B), Booleans), InSet(B, Booleans)))
# Out:
# expr: B -> {(FALSE <=> B) in BOOLEANS if B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B \mapsto \left\{\left(\bot \Leftrightarrow B\right) \in \mathbb{B} \textrm{ if } B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> {(FALSE <=> B) in BOOLEANS if B in BOOLEANS.
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {(FALSE <=> B) in BOOLEANS if B in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (FALSE <=> B) in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. B in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (FALSE <=> B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 7. FALSE <=> B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 9. <=>
#    core type: Literal
#    sub-expressions:
# 10. (FALSE, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. FALSE
#     core type: Literal
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
