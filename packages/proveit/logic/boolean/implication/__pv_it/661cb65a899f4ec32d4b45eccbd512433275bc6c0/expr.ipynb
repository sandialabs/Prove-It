# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Implies(Not(B), A), And(Implies(Not(A), B), InSet(A, Booleans))))
# Out:
# expr: (A, B) -> {[not](B) => A if [not](A) => B ,  A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{(\lnot B) \Rightarrow A \textrm{ if } (\lnot A) \Rightarrow B ,  A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {[not](B) => A if [not](A) => B ,  A in BOOLEANS.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (A, B)
#    core type: ExprTuple
#    sub-expressions: 19, 16
# 2. {[not](B) => A if [not](A) => B ,  A in BOOLEANS.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. [not](B) => A
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. ([not](A) => B) and (A in BOOLEANS)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ([not](B), A)
#    core type: ExprTuple
#    sub-expressions: 8, 19
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. ([not](A) => B, A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. [not](B)
#    core type: Operation
#    operator: 18
#    operand: 16
# 9. [not](A) => B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A in BOOLEANS
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. ([not](A), B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. [not](A)
#     core type: Operation
#     operator: 18
#     operand: 19
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
