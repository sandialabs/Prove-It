# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Equals, Forall, Iff

# %%
# build up the expression from sub-expressions
expr = Forall([B], Equals(A, B), domain = Booleans, condition = Iff(A, B))
# Out:
# expr: forall_{B in BOOLEANS | A <=> B} (A = B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{B \in \mathbb{B}~|~A \Leftrightarrow B}~\left(A = B\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS | A <=> B} (A = B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> {A = B if B in BOOLEANS ,  A <=> B.
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. {A = B if B in BOOLEANS ,  A <=> B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A = B
#    core type: Operation
#    operator: 6
#    operands: 14
# 5. (B in BOOLEANS) and (A <=> B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (B in BOOLEANS, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A <=> B
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 13. <=>
#     core type: Literal
#     sub-expressions:
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
