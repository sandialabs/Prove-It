# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(InSet(Implies(A, B), Booleans), And(InSet(A, Booleans), InSet(B, Booleans))))
# Out:
# expr: (A, B) -> {(A => B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\left(A \Rightarrow B\right) \in \mathbb{B} \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {(A => B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {(A => B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (A => B) in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (A in BOOLEANS) and (B in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A => B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 17
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEANS, B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. A => B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. A in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
