# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#impliesFalseDef">impliesFalseDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.implication._axioms_ import impliesFalseDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr impliesFalseDef
# Out:
# Passed sanity check: built 'impliesFalseDef' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(impliesFalseDef.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}}~\left(\left((\lnot A) \Rightarrow \bot\right) = A\right)

# %%
# display the expression information
impliesFalseDef.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} (([not](A) => FALSE) = A)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> {([not](A) => FALSE) = A if A in BOOLEANS.
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. {([not](A) => FALSE) = A if A in BOOLEANS.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ([not](A) => FALSE) = A
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ([not](A) => FALSE, A)
#    core type: ExprTuple
#    sub-expressions: 10, 17
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 10. [not](A) => FALSE
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. =>
# ...
