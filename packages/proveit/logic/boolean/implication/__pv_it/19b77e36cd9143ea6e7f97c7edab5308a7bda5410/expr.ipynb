# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Conditional(Forall([B], A, conditions = [Implies(Not(A), B), Not(B)]), InSet(A, Booleans)))
# Out:
# expr: A -> {forall_{B | [not](A) => B, [not](B)} A if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A \mapsto \left\{\forall_{B~|~(\lnot A) \Rightarrow B, \lnot B}~A \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> {forall_{B | [not](A) => B, [not](B)} A if A in BOOLEANS.
#    core type: Lambda
#    parameter: 20
#    body: 1
# 1. {forall_{B | [not](A) => B, [not](B)} A if A in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{B | [not](A) => B, [not](B)} A
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> {A if [not](A) => B ,  [not](B).
#    core type: Lambda
#    parameter: 18
#    body: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 20, 9
# 8. {A if [not](A) => B ,  [not](B).
#    core type: Conditional
#    value: 20
#    condition: 10
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. ([not](A) => B) and [not](B)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. ([not](A) => B, [not](B))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. [not](A) => B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. [not](B)
#     core type: Operation
#     operator: 19
#     operand: 18
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. ([not](A), B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. [not](A)
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. not
#     core type: Literal
#     sub-expressions:
# 20. A
#     core type: Variable
#     sub-expressions:
