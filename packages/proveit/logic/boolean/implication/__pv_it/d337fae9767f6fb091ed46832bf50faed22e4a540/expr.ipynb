# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, PofA
from proveit.logic import And, Booleans, Forall
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A], PofA, domain = Booleans), And(PofTrue, PofFalse))
# Out:
# expr: {forall_{A in BOOLEANS} P(A) if P(TRUE) ,  P(FALSE).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A \in \mathbb{B}}~P(A) \textrm{ if } P(\top) ,  P(\bot)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A in BOOLEANS} P(A) if P(TRUE) ,  P(FALSE).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. P(TRUE) and P(FALSE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> {P(A) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 17
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (P(TRUE), P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {P(A) if A in BOOLEANS.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. P(TRUE)
#    core type: Operation
#    operator: 14
#    operand: 12
# 9. P(FALSE)
#    core type: Operation
#    operator: 14
#    operand: 13
# 10. P(A)
#     core type: Operation
#     operator: 14
#     operand: 17
# 11. A in BOOLEANS
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. FALSE
#     core type: Literal
#     sub-expressions:
# 14. P
#     core type: Variable
#     sub-expressions:
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. BOOLEANS
#     core type: Literal
#     sub-expressions:
