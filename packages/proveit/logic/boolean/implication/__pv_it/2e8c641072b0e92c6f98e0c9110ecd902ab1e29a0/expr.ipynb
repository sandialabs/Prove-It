# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Iff(A, B), Booleans), And(InSet(A, Booleans), InSet(B, Booleans)))
# Out:
# expr: {(A <=> B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \Leftrightarrow B\right) \in \mathbb{B} \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A <=> B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A <=> B) in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (A in BOOLEANS) and (B in BOOLEANS)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A <=> B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A in BOOLEANS, B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. A <=> B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. <=>
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
