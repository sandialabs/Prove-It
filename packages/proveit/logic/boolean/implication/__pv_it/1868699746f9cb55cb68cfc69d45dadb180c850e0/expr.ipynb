# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = Forall([A], Forall([B], InSet(Iff(A, B), Booleans), domain = Booleans), domain = Booleans)
# Out:
# expr: forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A \in \mathbb{B}}~\left[\forall_{B \in \mathbb{B}}~\left(\left(A \Leftrightarrow B\right) \in \mathbb{B}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. A -> {forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 18
#    body: 2
# 2. {forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS) if A in BOOLEANS.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. B -> {(A <=> B) in BOOLEANS if B in BOOLEANS.
#    core type: Lambda
#    parameter: 19
#    body: 8
# 7. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 15
# 8. {(A <=> B) in BOOLEANS if B in BOOLEANS.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (A <=> B) in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. B in BOOLEANS
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (A <=> B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 14. A <=> B
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 16. <=>
#     core type: Literal
#     sub-expressions:
# 17. (A, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
