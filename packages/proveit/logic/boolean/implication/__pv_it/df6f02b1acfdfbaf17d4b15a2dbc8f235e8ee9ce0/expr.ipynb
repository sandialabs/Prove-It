# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Conditional(Equals(A, B), And(InSet(B, Booleans), Iff(A, B))))
# Out:
# expr: B -> {A = B if B in BOOLEANS ,  A <=> B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B \mapsto \left\{A = B \textrm{ if } B \in \mathbb{B} ,  A \Leftrightarrow B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> {A = B if B in BOOLEANS ,  A <=> B.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {A = B if B in BOOLEANS ,  A <=> B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A = B
#    core type: Operation
#    operator: 4
#    operands: 12
# 3. (B in BOOLEANS) and (A <=> B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (B in BOOLEANS, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. A <=> B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. <=>
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
