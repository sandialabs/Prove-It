# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Implies(A, B), Booleans), InSet(B, Booleans))
# Out:
# expr: {(A => B) in BOOLEANS if B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \Rightarrow B\right) \in \mathbb{B} \textrm{ if } B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A => B) in BOOLEANS if B in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A => B) in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. B in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A => B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 7
# 6. A => B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
