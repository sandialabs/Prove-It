# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#modusTollensDenial">modusTollensDenial</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.implication._theorems_ import modusTollensDenial

# %%
# check that the built expression is the same as the stored expression
# %check_expr modusTollensDenial
# Out:
# Passed sanity check: built 'modusTollensDenial' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(modusTollensDenial.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}}~\left[\forall_{B~|~A \Rightarrow B, \lnot B}~(\lnot A)\right]

# %%
# display the expression information
modusTollensDenial.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} [forall_{B | A => B, [not](B)} [not](A)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. A -> {forall_{B | A => B, [not](B)} [not](A) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. {forall_{B | A => B, [not](B)} [not](A) if A in BOOLEANS.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{B | A => B, [not](B)} [not](A)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. B -> {[not](A) if A => B ,  [not](B).
#    core type: Lambda
#    parameter: 21
#    body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 20, 10
# 9. {[not](A) if A => B ,  [not](B).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. BOOLEANS
#     core type: Literal
# ...
