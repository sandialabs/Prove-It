# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#iffImpliesRight">iffImpliesRight</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.implication._theorems_ import iffImpliesRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr iffImpliesRight
# Out:
# Passed sanity check: built 'iffImpliesRight' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(iffImpliesRight.latex())
# Out:
# \vdash \forall_{A, B~|~A \Leftrightarrow B}~\left(A \Rightarrow B\right)

# %%
# display the expression information
iffImpliesRight.exprInfo()
# Out:
# 0. forall_{A, B | A <=> B} (A => B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A => B if A <=> B.
#    core type: Lambda
#    parameters: 8\n   body: 3
# 3. {A => B if A <=> B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A => B
#    core type: Operation
#    operator: 6
#    operands: 8
# 5. A <=> B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
