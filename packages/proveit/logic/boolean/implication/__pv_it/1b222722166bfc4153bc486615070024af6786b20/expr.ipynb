# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import B
from proveit.logic import And, Booleans, Equals, Implies, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(TRUE, B), And(InSet(B, Booleans), Implies(TRUE, B), Implies(B, TRUE)))
# Out:
# expr: {TRUE = B if B in BOOLEANS ,  TRUE => B ,  B => TRUE.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\top = B \textrm{ if } B \in \mathbb{B} ,  \top \Rightarrow B ,  B \Rightarrow \top\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {TRUE = B if B in BOOLEANS ,  TRUE => B ,  B => TRUE.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. TRUE = B
#    core type: Operation
#    operator: 3
#    operands: 11
# 2. (B in BOOLEANS) and (TRUE => B) and (B => TRUE)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (B in BOOLEANS, TRUE => B, B => TRUE)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. TRUE => B
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B => TRUE
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B, TRUE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. TRUE
#     core type: Literal
#     sub-expressions:
