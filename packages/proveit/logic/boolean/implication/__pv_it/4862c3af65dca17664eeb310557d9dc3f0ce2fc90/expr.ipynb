# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet

# %%
# build up the expression from sub-expressions
expr = And(InSet(A, Booleans), InSet(B, Booleans))
# Out:
# expr: (A in BOOLEANS) and (B in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}\right) \land \left(B \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS) and (B in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEANS, B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
