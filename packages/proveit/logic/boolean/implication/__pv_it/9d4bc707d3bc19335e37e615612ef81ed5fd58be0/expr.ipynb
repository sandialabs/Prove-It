# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import And
from proveit.logic.boolean.implication._theorems_ import trueImpliesTrue

# %%
# build up the expression from sub-expressions
expr = And(trueImpliesTrue.expr, trueImpliesTrue.expr)
# Out:
# expr: (TRUE => TRUE) and (TRUE => TRUE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\top \Rightarrow \top\right) \land \left(\top \Rightarrow \top\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (TRUE => TRUE) and (TRUE => TRUE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (TRUE => TRUE, TRUE => TRUE)
#    core type: ExprTuple
#    sub-expressions: 3, 3
# 3. TRUE => TRUE
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (TRUE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 6, 6
# 6. TRUE
#    core type: Literal
#    sub-expressions:
