# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(A, B), And(InSet(A, Booleans), InSet(B, Booleans), Iff(A, B)))
# Out:
# expr: {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A <=> B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A = B \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B} ,  A \Leftrightarrow B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A <=> B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A = B
#    core type: Operation
#    operator: 3
#    operands: 13
# 2. (A in BOOLEANS) and (B in BOOLEANS) and (A <=> B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A in BOOLEANS, B in BOOLEANS, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. A <=> B
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 12. <=>
#     core type: Literal
#     sub-expressions:
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
