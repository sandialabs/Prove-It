# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import B
from proveit.logic import And, Booleans, Implies, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(B, Booleans), And(Implies(TRUE, B), Implies(B, TRUE)))
# Out:
# expr: (B in BOOLEANS, (TRUE => B) and (B => TRUE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \in \mathbb{B}, \left(\top \Rightarrow B\right) \land \left(B \Rightarrow \top\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (B in BOOLEANS, (TRUE => B) and (B => TRUE))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. B in BOOLEANS
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (TRUE => B) and (B => TRUE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (TRUE => B, B => TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 8. TRUE => B
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. B => TRUE
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (B, TRUE)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. TRUE
#     core type: Literal
#     sub-expressions:
