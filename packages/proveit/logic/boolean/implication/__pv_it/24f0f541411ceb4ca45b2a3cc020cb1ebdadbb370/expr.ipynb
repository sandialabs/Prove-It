# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import B
from proveit.logic import And, Booleans, Equals, FALSE, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(FALSE, B), And(InSet(B, Booleans), Implies(FALSE, B), Implies(B, FALSE)))
# Out:
# expr: {FALSE = B if B in BOOLEANS ,  FALSE => B ,  B => FALSE.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\bot = B \textrm{ if } B \in \mathbb{B} ,  \bot \Rightarrow B ,  B \Rightarrow \bot\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {FALSE = B if B in BOOLEANS ,  FALSE => B ,  B => FALSE.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. FALSE = B
#    core type: Operation
#    operator: 3
#    operands: 11
# 2. (B in BOOLEANS) and (FALSE => B) and (B => FALSE)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (B in BOOLEANS, FALSE => B, B => FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. FALSE => B
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B => FALSE
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. (FALSE, B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B, FALSE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. FALSE
#     core type: Literal
#     sub-expressions:
