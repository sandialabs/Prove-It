# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">implication</a>.<a class="ProveItLink" href="../_theorems_.ipynb#falsifiedAntecedentImplication">falsifiedAntecedentImplication</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory
from proveit._common_ import A, B
from proveit.logic import TRUE, inBool, Not, Equals

# %%
# %proving falsifiedAntecedentImplication presuming [proveit.logic.boolean.negation.negationContradiction]

# %%
contradiction = Not(A).deriveContradiction([A, Not(A)])

# %%
notB_contradiction = contradiction.asImplication(Not(Equals(B, TRUE)))

# %%
BeqT_via_contradiction = notB_contradiction.deriveViaContradiction()

# %%
B_via_contradiction = B.prove([A, Not(A)])

# %%
B_via_contradiction.asImplication(A)

# %%
# %qed
