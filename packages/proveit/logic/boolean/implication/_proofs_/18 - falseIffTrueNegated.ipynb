# %%
from proveit.logic.boolean.implication._axioms_ import iffDef
from proveit.logic.boolean.implication._theorems_ import falseIffTrueNegated, falseImpliesTrue, trueImpliesFalseNegated
from proveit.logic.boolean.conjunction._theorems_ import trueAndFalseNegated
from proveit.logic.equality._theorems_ import substituteInTrue, substituteInFalse
from proveit.logic import TRUE, FALSE
from proveit.common import A, B

# %%
falseIffTrueNegated.beginProof([falseImpliesTrue, trueImpliesFalseNegated, trueAndFalseNegated, substituteInTrue, substituteInFalse])
# Out:
# Beginning proof of
# not(FALSE <=> TRUE)

# %%
iffDef
# Out:
# |= forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))

# %%
iffDefFT = iffDef.specialize({A:FALSE, B:TRUE})
iffDefFT
# Out:
# |= (FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))

# %%
falseImpliesTrue
# Out:
# |= FALSE => TRUE

# %%
partiallySubbed = falseImpliesTrue.evaluate().rhsSubstitute(iffDefFT)
partiallySubbed
# Out:
# |= (FALSE <=> TRUE) = (TRUE and (TRUE => FALSE))

# %%
trueImpliesFalseNegated
# Out:
# |= not(TRUE => FALSE)

# %%
iffDefFTsubbed = trueImpliesFalseNegated.substituteInFalse(partiallySubbed)
iffDefFTsubbed
# Out:
# |= (FALSE <=> TRUE) = (TRUE and FALSE)

# %%
iffDefFTsubbed.lhsSubstitute(trueAndFalseNegated).qed()
# Out:
# proveit.logic.boolean.implication.falseIffTrueNegated has a proof
# <proveit._core_.proof.Specialization instance at 0x000000000432DFC8>

# %%
falseIffTrueNegated.printRequirements()
# Out:
# proveit.logic.boolean.boolsDef
# proveit.logic.boolean.disjunction.orFT
# proveit.logic.boolean.eqTrueElim
# proveit.logic.boolean.eqTrueIntro
# proveit.logic.boolean.falseNotTrue
# proveit.logic.boolean.implication.iffDef
# proveit.logic.boolean.implication.impliesFalseDef
# proveit.logic.boolean.negation.negationElim
# proveit.logic.boolean.negation.negationIntro
# proveit.logic.boolean.trueAxiom
# proveit.logic.equality.equalsReflexivity
# proveit.logic.equality.equalsSymmetry
# proveit.logic.equality.equalsTransitivity
# proveit.logic.equality.notEqualsDef
# proveit.logic.equality.substitution
# proveit.logic.set_theory.singletonDef
# proveit.logic.set_theory.unification.unionDef
#
# Unproven theorems:
# proveit.logic.boolean.conjunction.trueAndFalseNegated
