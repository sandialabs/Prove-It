# %%
from proveit.logic.boolean.implication._axioms_ import iffDef
from proveit.logic.boolean.implication._theorems_ import trueIffFalseNegated, falseImpliesTrue, trueImpliesFalseNegated
from proveit.logic.boolean.conjunction._theorems_ import falseAndTrueNegated
from proveit.logic.equality._theorems_ import substituteInTrue, substituteInFalse
from proveit.logic import TRUE, FALSE
from proveit.common import A, B

# %%
trueIffFalseNegated.beginProof([falseImpliesTrue, trueImpliesFalseNegated, falseAndTrueNegated, substituteInTrue, substituteInFalse])
# Out:
# Beginning proof of
# not(TRUE <=> FALSE)

# %%
iffDef
# Out:
# |= forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))

# %%
iffDefTF = iffDef.specialize({A:TRUE, B:FALSE})
iffDefTF
# Out:
# |= (TRUE <=> FALSE) = ((TRUE => FALSE) and (FALSE => TRUE))

# %%
falseImpliesTrue
# Out:
# |= FALSE => TRUE

# %%
partiallySubbed = falseImpliesTrue.evaluate().rhsSubstitute(iffDefTF)
partiallySubbed
# Out:
# |= (TRUE <=> FALSE) = ((TRUE => FALSE) and TRUE)

# %%
trueImpliesFalseNegated
# Out:
# |= not(TRUE => FALSE)

# %%
iffDefTFsubbed = trueImpliesFalseNegated.substituteInFalse(partiallySubbed)
iffDefTFsubbed
# Out:
# |= (TRUE <=> FALSE) = (FALSE and TRUE)

# %%
iffDefTFsubbed.lhsSubstitute(falseAndTrueNegated).qed()
# Out:
# proveit.logic.boolean.implication.trueIffFalseNegated has a proof
# <proveit._core_.proof.Specialization instance at 0x0000000004442FC8>

# %%
trueIffFalseNegated.printRequirements()
# Out:
# proveit.logic.boolean.boolsDef
# proveit.logic.boolean.disjunction.orFT
# proveit.logic.boolean.eqTrueElim
# proveit.logic.boolean.eqTrueIntro
# proveit.logic.boolean.falseNotTrue
# proveit.logic.boolean.implication.iffDef
# proveit.logic.boolean.implication.impliesFalseDef
# proveit.logic.boolean.negation.negationElim
# proveit.logic.boolean.negation.negationIntro
# proveit.logic.boolean.trueAxiom
# proveit.logic.equality.equalsReflexivity
# proveit.logic.equality.equalsSymmetry
# proveit.logic.equality.equalsTransitivity
# proveit.logic.equality.notEqualsDef
# proveit.logic.equality.substitution
# proveit.logic.set_theory.singletonDef
# proveit.logic.set_theory.unification.unionDef
#
# Unproven theorems:
# proveit.logic.boolean.conjunction.falseAndTrueNegated
