# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">implication</a>.<a class="ProveItLink" href="../_theorems_.ipynb#iffClosure">iffClosure</a> theorem
# ========

# %%
import proveit
# we need to import trueIffFalseNegated and falseIffTrueNegated
# to derive their side-effects:
from proveit.logic.boolean.implication._theorems_ import trueIffTrue, trueIffFalseNegated
from proveit.logic.boolean.implication._theorems_ import falseIffFalse, falseIffTrueNegated
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving iffClosure presuming []
# Out:
# Beginning proof of iffClosure
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# iffClosure: forall_{A in BOOLEANS, B in BOOLEANS} ((A <=> B) in BOOLEANS)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS} ((A <=> B) in BOOLEANS)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A <=> B) in BOOLEANS)]
# 	m : 1, n : 1, P(A, B) : (A <=> B) in BOOLEANS, Q(A) : A in BOOLEANS, R(A, B) : B in BOOLEANS, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)]
# 	P(A) : forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 10, 11	|- forall_{B in BOOLEANS} ((TRUE <=> B) in BOOLEANS)
# 	P(B) : (TRUE <=> B) in BOOLEANS, A : B
# 8	instantiation	12, 13, 14	|- forall_{B in BOOLEANS} ((FALSE <=> B) in BOOLEANS)
# 	P(B) : (FALSE <=> B) in BOOLEANS, A : B
# 9	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 10	instantiation	20, 21, 15	|- (TRUE <=> TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE <=> TRUE
# 11	instantiation	17, 18, 16	|- (TRUE <=> FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE <=> FALSE
# 12	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 13	instantiation	17, 18, 19	|- (FALSE <=> TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : FALSE <=> TRUE
# 14	instantiation	20, 21, 22	|- (FALSE <=> FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : FALSE <=> FALSE
# 15	theorem		|- TRUE <=> TRUE
# 	proveit.logic.boolean.implication.trueIffTrue
# 16	theorem		|- [not](TRUE <=> FALSE)
# 	proveit.logic.boolean.implication.trueIffFalseNegated
# 17	theorem		|- forall_{P, x | P(FALSE), [not](x)} P(x)
# 	proveit.logic.equality.substituteFalsehood
# 18	theorem		|- FALSE in BOOLEANS
# 	proveit.logic.boolean.falseInBool
# 19	theorem		|- [not](FALSE <=> TRUE)
# 	proveit.logic.boolean.implication.falseIffTrueNegated
# 20	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substituteTruth
# 21	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 22	theorem		|- FALSE <=> FALSE
# 	proveit.logic.boolean.implication.falseIffFalse
