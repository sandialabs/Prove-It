# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">implication</a>.<a class="ProveItLink" href="../_theorems_.ipynb#eqFromIff">eqFromIff</a> theorem
# ========

# %%
import proveit
# we need to import these to derive their side-effects:
from proveit.logic.boolean.implication._theorems_ import trueIffFalseNegated, falseIffTrueNegated
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving eqFromIff presuming [proveit.logic.boolean.foldConditionedForallOverBool, proveit.logic.boolean.quantification.universal.bundling, proveit.core_expr_types.tuples.singular_range_reduction, proveit.core_expr_types.conditionals.singular_conjunction_condition_reduction, proveit.core_expr_types.conditionals.condition_prepend_reduction, proveit.number.numeral.deci.posnat1, proveit.logic.boolean.quantification.universal.bundle]
# Out:
# Beginning proof of eqFromIff
# Recorded 'presuming' information
# Presuming proveit.core_expr_types.conditionals.condition_prepend_reduction, proveit.core_expr_types.conditionals.singular_conjunction_condition_reduction, proveit.core_expr_types.tuples.singular_range_reduction, proveit.logic.boolean.foldConditionedForallOverBool, proveit.logic.boolean.quantification.universal.bundle, proveit.logic.boolean.quantification.universal.bundling, proveit.number.numeral.deci.posnat1 theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# eqFromIff: forall_{A in BOOLEANS, B in BOOLEANS | A <=> B} (A = B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS | A <=> B} (A = B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS | A <=> B} (A = B)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS | A <=> B} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEANS, R(A, B) : (B in BOOLEANS) and (A <=> B), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS | A <=> B} (A = B)]
# 	P(A) : forall_{B in BOOLEANS | A <=> B} (A = B), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 13, 14	|- {A = B if A in BOOLEANS ,  (B in BOOLEANS) and (A <=> B). = {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A <=> B.
# 	n : 2, a : A = B, Q : A in BOOLEANS, R : (B in BOOLEANS, A <=> B)
# 8	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 9	instantiation	15, 16, 17	|- forall_{B in BOOLEANS | TRUE <=> B} (TRUE = B)
# 	P(B) : TRUE = B, Q(B) : TRUE <=> B, A : B
# 10	generalizaton	18	|- forall_{B in BOOLEANS | FALSE <=> B} (FALSE = B)
# 11	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 12	theorem		|- forall_{n in Naturals} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 13	theorem		|- 2 in Naturals
# 	proveit.number.numeral.deci.nat2
# 14	instantiation	19	|- |(B in BOOLEANS, A <=> B)| = |(1, ..k.., 2)|
# 	a : B in BOOLEANS, b : A <=> B
# 15	theorem		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEANS | Q(A)} P(A)]
# 	proveit.logic.boolean.foldConditionedForallOverBool
# 16	hypothetical reasoning	20	|- (TRUE <=> TRUE) => (TRUE = TRUE)
# 17	hypothetical reasoning	21	|- (TRUE <=> FALSE) => (TRUE = FALSE)
# 18	instantiation	22, 23	{B in BOOLEANS, FALSE <=> B} |- FALSE = B
# 	x : B, y : FALSE
# 19	theorem		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 	proveit.number.numeral.deci.tuple_len_2_typical_equiv
# 20	theorem		|- TRUE = TRUE
# 	proveit.logic.boolean.trueEqTrue
# 21	instantiation	25, 24	{TRUE <=> FALSE} |- TRUE = FALSE
# 	A : TRUE
# 22	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equalsReversal
# 23	instantiation	25, 26	{B in BOOLEANS, FALSE <=> B} |- B = FALSE
# 	A : B
# 24	instantiation	29, 27, 28	{TRUE <=> FALSE} |- [not](TRUE)
# 	A : TRUE
# 25	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.boolean.negation.negationElim
# 26	instantiation	29, 30, 31	{B in BOOLEANS, FALSE <=> B} |- [not](B)
# 	A : B
# 27	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 28	instantiation	32, 33	{TRUE <=> FALSE} |- TRUE => FALSE
# 	A : TRUE, B : FALSE
# 29	theorem		|- forall_{A in BOOLEANS | A => FALSE} [not](A)
# 	proveit.logic.boolean.implication.denyViaContradiction
# 30	assumption		{B in BOOLEANS} |- B in BOOLEANS
# 31	instantiation	34, 35	{FALSE <=> B} |- B => FALSE
# 	A : FALSE, B : B
# 32	theorem		|- forall_{A, B | A <=> B} (A => B)
# 	proveit.logic.boolean.implication.iffImpliesRight
# 33	assumption		{TRUE <=> FALSE} |- TRUE <=> FALSE
# 34	theorem		|- forall_{A, B | A <=> B} (B => A)
# 	proveit.logic.boolean.implication.iffImpliesLeft
# 35	assumption		{FALSE <=> B} |- FALSE <=> B
