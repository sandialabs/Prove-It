# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">implication</a>.<a class="ProveItLink" href="../_theorems_.ipynb#eqFromMutualImpl">eqFromMutualImpl</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean._theorems_ import foldForallOverBool
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving eqFromMutualImpl presuming []
# Out:
# Beginning proof of eqFromMutualImpl
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# eqFromMutualImpl: forall_{A in BOOLEANS, B in BOOLEANS | A => B, B => A} (A = B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS | A => B, B => A} (A = B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS | A => B, B => A} (A = B)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS | A => B, B => A} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEANS, R(A, B) : (B in BOOLEANS) and (A => B) and (B => A), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS | A => B, B => A} (A = B)]
# 	P(A) : forall_{B in BOOLEANS | A => B, B => A} (A = B), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	22, 12, 13	|- {A = B if A in BOOLEANS ,  (B in BOOLEANS) and (A => B) and (B => A). = {A = B if A in BOOLEANS ,  B in BOOLEANS ,  A => B ,  B => A.
# 	n : 3, a : A = B, Q : A in BOOLEANS, R : (B in BOOLEANS, A => B, B => A)
# 8	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 9	instantiation	14, 15, 16, 17*	|- forall_{B in BOOLEANS | TRUE => B, B => TRUE} (TRUE = B)
# 	P(B) : TRUE = B, Q(B) : (TRUE => B) and (B => TRUE), A : B
# 10	generalizaton	18	|- forall_{B in BOOLEANS | FALSE => B, B => FALSE} (FALSE = B)
# 11	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 12	theorem		|- 3 in Naturals
# 	proveit.number.numeral.deci.nat3
# 13	instantiation	19	|- |(B in BOOLEANS, A => B, B => A)| = |(1, ..k.., 3)|
# 	a : B in BOOLEANS, b : A => B, c : B => A
# 14	theorem		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEANS | Q(A)} P(A)]
# 	proveit.logic.boolean.foldConditionedForallOverBool
# 15	hypothetical reasoning	20	|- ((TRUE => TRUE) and (TRUE => TRUE)) => (TRUE = TRUE)
# 16	hypothetical reasoning	21	|- ((TRUE => FALSE) and (FALSE => TRUE)) => (TRUE = FALSE)
# 17	instantiation	22, 23, 24	|- {TRUE = B if B in BOOLEANS ,  (TRUE => B) and (B => TRUE). = {TRUE = B if B in BOOLEANS ,  TRUE => B ,  B => TRUE.
# 	n : 2, a : TRUE = B, Q : B in BOOLEANS, R : (TRUE => B, B => TRUE)
# 18	instantiation	25, 26	{B in BOOLEANS, B => FALSE} |- FALSE = B
# 	x : B, y : FALSE
# 19	theorem		|- forall_{a, b, c} (|(a, b, c)| = |(1, ..k.., 3)|)
# 	proveit.number.numeral.deci.tuple_len_3_typical_equiv
# 20	theorem		|- TRUE = TRUE
# 	proveit.logic.boolean.trueEqTrue
# 21	instantiation	29, 27	{(TRUE => FALSE) and (FALSE => TRUE)} |- TRUE = FALSE
# 	A : TRUE
# 22	theorem		|- forall_{n in Naturals} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 23	theorem		|- 2 in Naturals
# 	proveit.number.numeral.deci.nat2
# 24	instantiation	28	|- |(TRUE => B, B => TRUE)| = |(1, ..k.., 2)|
# 	a : TRUE => B, b : B => TRUE
# 25	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equalsReversal
# 26	instantiation	29, 30	{B in BOOLEANS, B => FALSE} |- B = FALSE
# 	A : B
# 27	instantiation	33, 31, 32	{(TRUE => FALSE) and (FALSE => TRUE)} |- [not](TRUE)
# 	A : TRUE
# 28	theorem		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 	proveit.number.numeral.deci.tuple_len_2_typical_equiv
# 29	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.boolean.negation.negationElim
# 30	instantiation	33, 34, 35	{B in BOOLEANS, B => FALSE} |- [not](B)
# 	A : B
# 31	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 32	instantiation	36, 37	{(TRUE => FALSE) and (FALSE => TRUE)} |- TRUE => FALSE
# 	A : TRUE => FALSE, B : FALSE => TRUE
# 33	theorem		|- forall_{A in BOOLEANS | A => FALSE} [not](A)
# 	proveit.logic.boolean.implication.denyViaContradiction
# 34	assumption		{B in BOOLEANS} |- B in BOOLEANS
# 35	assumption		{B => FALSE} |- B => FALSE
# 36	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.boolean.conjunction.leftFromAnd
# 37	assumption		{(TRUE => FALSE) and (FALSE => TRUE)} |- (TRUE => FALSE) and (FALSE => TRUE)
