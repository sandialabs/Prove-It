# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#iffClosure">iffClosure</a> theorem
# ========

# %%
import proveit
# we need to import trueIffFalseNegated and falseIffTrueNegated
# to derive their side-effects:
from proveit.logic.boolean.implication._theorems_ import trueIffTrue, trueIffFalseNegated
from proveit.logic.boolean.implication._theorems_ import falseIffFalse, falseIffTrueNegated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iffClosure

# %%
# %qed
