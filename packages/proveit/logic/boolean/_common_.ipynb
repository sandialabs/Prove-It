# %% [markdown]
# Common expressions for context <a href="_context_.ipynb" class="ProveItLink">proveit.logic.boolean</a>
# ========

# %%
import proveit
from booleans import BooleanSet, TrueLiteral, FalseLiteral
# %begin common
# Out:
# Defining common sub-expressions for context 'proveit.logic.boolean'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
Booleans = BooleanSet()
# Out:
# Booleans: BOOLEANS

# %%
TRUE, FALSE = TrueLiteral(), FalseLiteral()
# Out:
# TRUE: TRUE
# FALSE: FALSE

# %%
# %end common
# Out:
# FALSE expression notebook is being updated
# TRUE expression notebook is being updated
# Booleans expression notebook is being updated
# Common expressions may be imported from autogenerated _common_.py
