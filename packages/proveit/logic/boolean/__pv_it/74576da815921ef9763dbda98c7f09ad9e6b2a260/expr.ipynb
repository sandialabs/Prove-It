# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Booleans
from proveit.logic.boolean.disjunction._theorems_ import falseOrTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(falseOrTrue.expr, Booleans)
# Out:
# expr: (FALSE or TRUE, BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\bot \lor \top, \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (FALSE or TRUE, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. FALSE or TRUE
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (FALSE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. FALSE
#    core type: Literal
#    sub-expressions:
# 6. TRUE
#    core type: Literal
#    sub-expressions:
