# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inBoolInBool">inBoolInBool</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean._theorems_ import inBoolInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr inBoolInBool
# Out:
# Passed sanity check: built 'inBoolInBool' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(inBoolInBool.latex())
# Out:
# \vdash \forall_{A}~\left(\left(A \in \mathbb{B}\right) \in \mathbb{B}\right)

# %%
# display the expression information
inBoolInBool.exprInfo()
# Out:
# 0. forall_{A} ((A in BOOLEANS) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ((A in BOOLEANS) in BOOLEANS)
#    core type: Lambda
#    parameter: 8
#    body: 3
# 3. (A in BOOLEANS) in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 4
# 4. (A in BOOLEANS, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5, 9
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
