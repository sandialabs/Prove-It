# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, P, PofA
from proveit.logic import And, Booleans, Equals, FALSE, Forall, Implies
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Implies(And(Equals(PofTrue, FALSE), Equals(PofFalse, FALSE)), Equals(Forall([A], PofA, domain = Booleans), FALSE)))
# Out:
# expr: P -> (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P \mapsto \left(\left(\left(P(\top) = \bot\right) \land \left(P(\bot) = \bot\right)\right) \Rightarrow \left(\left[\forall_{A \in \mathbb{B}}~P(A)\right] = \bot\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE), [forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (P(TRUE) = FALSE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. [forall_{A in BOOLEANS} P(A)] = FALSE
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(TRUE) = FALSE, P(FALSE) = FALSE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (forall_{A in BOOLEANS} P(A), FALSE)
#    core type: ExprTuple
#    sub-expressions: 11, 21
# 9. P(TRUE) = FALSE
# ...
