# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(InSet(A, Booleans), InSet(Or(A, B), Booleans)))
# Out:
# expr: (A, B) -> {A in BOOLEANS if (A or B) in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \in \mathbb{B} \textrm{ if } \left(A \lor B\right) \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {A in BOOLEANS if (A or B) in BOOLEANS.
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {A in BOOLEANS if (A or B) in BOOLEANS.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A or B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A or B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
