# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, PofA, QofA
from proveit.logic import And, Booleans, Forall, Implies
from proveit.logic._common_ import QimplPofFalse, QimplPofTrue

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A], Implies(QofA, PofA), domain = Booleans), And(QimplPofTrue, QimplPofFalse))
# Out:
# expr: {forall_{A in BOOLEANS} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A \in \mathbb{B}}~\left(Q(A) \Rightarrow P(A)\right) \textrm{ if } Q(\top) \Rightarrow P(\top) ,  Q(\bot) \Rightarrow P(\bot)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A in BOOLEANS} (Q(A) => P(A)) if Q(TRUE) => P(TRUE) ,  Q(FALSE) => P(FALSE).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A in BOOLEANS} (Q(A) => P(A))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (Q(TRUE) => P(TRUE)) and (Q(FALSE) => P(FALSE))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> {Q(A) => P(A) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 29
#    body: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {Q(A) => P(A) if A in BOOLEANS.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. Q(TRUE) => P(TRUE)
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. Q(FALSE) => P(FALSE)
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. Q(A) => P(A)
#     core type: Operation
# ...
