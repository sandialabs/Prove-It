# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n, x
from proveit.core_expr_types._common_ import y_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.logic.set_theory._common_ import x_equals_any_y
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([x, y_1_to_n], x_equals_any_y, condition = InSet(x, Set(y_1_to_n))), InSet(n, Naturals)))
# Out:
# expr: n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x, y_{1}, \ldots, y_{n}~|~x \in \left\{y_{1}, \ldots, y_{n}\right\}}~\left(\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})) if n in Naturals.
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})) if n in Naturals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Naturals
#    core type: Operation
#    operator: 14
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 7. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 28, 22
# 8. {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. x in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#     core type: ExprTuple
#     sub-expressions: 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 28, 17
# 16. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 26
#     end_index: 27
# 17. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 31
#     body: 21
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. x = y_{i}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. _a -> y_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 30
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. y_{i}
#     core type: IndexedVar
# variable: 32
# index: 31
# 30. y_{_a}
#     core type: IndexedVar
# variable: 32
# index: 33
# 31. i
#     core type: Variable
#     sub-expressions:
# 32. y
#     core type: Variable
#     sub-expressions:
# 33. _a
#     core type: Variable
#     sub-expressions:
