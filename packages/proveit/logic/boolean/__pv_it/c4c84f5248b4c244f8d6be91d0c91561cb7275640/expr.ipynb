# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fromExcludedMiddle">fromExcludedMiddle</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean._theorems_ import fromExcludedMiddle

# %%
# check that the built expression is the same as the stored expression
# %check_expr fromExcludedMiddle
# Out:
# Passed sanity check: built 'fromExcludedMiddle' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fromExcludedMiddle.latex())
# Out:
# \vdash \forall_{C}~\left[\forall_{A \in \mathbb{B}~|~A \Rightarrow C, (\lnot A) \Rightarrow C}~C\right]

# %%
# display the expression information
fromExcludedMiddle.exprInfo()
# Out:
# 0. forall_{C} [forall_{A in BOOLEANS | A => C, [not](A) => C} C]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. C -> [forall_{A in BOOLEANS | A => C, [not](A) => C} C]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{A in BOOLEANS | A => C, [not](A) => C} C
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> {C if A in BOOLEANS ,  A => C ,  [not](A) => C.
#    core type: Lambda
#    parameter: 21
#    body: 5
# 5. {C if A in BOOLEANS ,  A => C ,  [not](A) => C.
#    core type: Conditional
#    value: 19
#    condition: 6
# 6. (A in BOOLEANS) and (A => C) and ([not](A) => C)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A in BOOLEANS, A => C, [not](A) => C)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 9. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 13
# ...
