# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A
from proveit.logic import And, Booleans, FALSE, InSet, NotEquals

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Conditional(A, And(InSet(A, Booleans), NotEquals(A, FALSE))))
# Out:
# expr: A -> {A if A in BOOLEANS ,  A != FALSE.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A \mapsto \left\{A \textrm{ if } A \in \mathbb{B} ,  A \neq \bot\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> {A if A in BOOLEANS ,  A != FALSE.
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. {A if A in BOOLEANS ,  A != FALSE.
#    core type: Conditional
#    value: 12
#    condition: 2
# 2. (A in BOOLEANS) and (A != FALSE)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A in BOOLEANS, A != FALSE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. A != FALSE
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. (A, FALSE)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. FALSE
#     core type: Literal
#     sub-expressions:
