# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], InSet(A, Booleans), condition = InSet(Or(A, B), Booleans))
# Out:
# expr: forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~\left(A \lor B\right) \in \mathbb{B}}~\left(A \in \mathbb{B}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A in BOOLEANS if (A or B) in BOOLEANS.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {A in BOOLEANS if (A or B) in BOOLEANS.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A or B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A or B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
