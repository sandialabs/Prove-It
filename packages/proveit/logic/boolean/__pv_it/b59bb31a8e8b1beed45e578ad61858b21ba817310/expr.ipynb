# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, P, PofA
from proveit.logic import And, Booleans, Forall
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Conditional(Forall([A], PofA, domain = Booleans), And(PofTrue, PofFalse)))
# Out:
# expr: P -> {forall_{A in BOOLEANS} P(A) if P(TRUE) ,  P(FALSE).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P \mapsto \left\{\forall_{A \in \mathbb{B}}~P(A) \textrm{ if } P(\top) ,  P(\bot)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> {forall_{A in BOOLEANS} P(A) if P(TRUE) ,  P(FALSE).
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {forall_{A in BOOLEANS} P(A) if P(TRUE) ,  P(FALSE).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. P(TRUE) and P(FALSE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. A -> {P(A) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 18
#    body: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(TRUE), P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {P(A) if A in BOOLEANS.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. P(TRUE)
#    core type: Operation
#    operator: 15
#    operand: 13
# 10. P(FALSE)
#     core type: Operation
#     operator: 15
#     operand: 14
# 11. P(A)
#     core type: Operation
#     operator: 15
#     operand: 18
# 12. A in BOOLEANS
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. TRUE
#     core type: Literal
#     sub-expressions:
# 14. FALSE
#     core type: Literal
#     sub-expressions:
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
