# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#forallBoolEvalFalseViaTF">forallBoolEvalFalseViaTF</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean._theorems_ import forallBoolEvalFalseViaTF

# %%
# check that the built expression is the same as the stored expression
# %check_expr forallBoolEvalFalseViaTF
# Out:
# Passed sanity check: built 'forallBoolEvalFalseViaTF' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(forallBoolEvalFalseViaTF.latex())
# Out:
# \vdash \forall_{P}~\left(\left(\left(P(\top) = \top\right) \land \left(P(\bot) = \bot\right)\right) \Rightarrow \left(\left[\forall_{A \in \mathbb{B}}~P(A)\right] = \bot\right)\right)

# %%
# display the expression information
forallBoolEvalFalseViaTF.exprInfo()
# Out:
# 0. forall_{P} (((P(TRUE) = TRUE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. P -> (((P(TRUE) = TRUE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. ((P(TRUE) = TRUE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. ((P(TRUE) = TRUE) and (P(FALSE) = FALSE), [forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (P(TRUE) = TRUE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. [forall_{A in BOOLEANS} P(A)] = FALSE
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(TRUE) = TRUE, P(FALSE) = FALSE)
#    core type: ExprTuple
# ...
