# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">conjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#binaryClosure">binaryClosure</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean._theorems_ import foldForallOverBool
# we need to import these to derive their side-effects:
from proveit.logic.boolean.conjunction._theorems_ import \
    (trueAndTrue, falseAndTrueNegated, trueAndFalseNegated, falseAndFalseNegated)
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving binaryClosure presuming [foldForallOverBool]
# Out:
# Beginning proof of binaryClosure
# Recorded 'presuming' information
# Presuming proveit.logic.boolean.foldForallOverBool theorem (applied transitively).
# Presuming previous theorems (applied transitively).
# binaryClosure: forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) in BOOLEANS)

# %%
# %qed # concludeAsFolded automatically
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) in BOOLEANS)
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) in BOOLEANS)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) in BOOLEANS)]
# 	m : 1, n : 1, P(A, B) : (A and B) in BOOLEANS, Q(A) : A in BOOLEANS, R(A, B) : B in BOOLEANS, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	12, 7, 8	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) in BOOLEANS)]
# 	P(A) : forall_{B in BOOLEANS} ((A and B) in BOOLEANS), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 10, 11	|- forall_{B in BOOLEANS} ((TRUE and B) in BOOLEANS)
# 	P(B) : (TRUE and B) in BOOLEANS, A : B
# 8	instantiation	12, 13, 14	|- forall_{B in BOOLEANS} ((FALSE and B) in BOOLEANS)
# 	P(B) : (FALSE and B) in BOOLEANS, A : B
# 9	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 10	instantiation	15, 16, 17	|- (TRUE and TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE and TRUE
# 11	instantiation	20, 21, 18	|- (TRUE and FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : TRUE and FALSE
# 12	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 13	instantiation	20, 21, 19	|- (FALSE and TRUE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : FALSE and TRUE
# 14	instantiation	20, 21, 22	|- (FALSE and FALSE) in BOOLEANS
# 	P(_a) : _a in BOOLEANS, x : FALSE and FALSE
# 15	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substituteTruth
# 16	theorem		|- TRUE in BOOLEANS
# 	proveit.logic.boolean.trueInBool
# 17	theorem		|- TRUE and TRUE
# 	proveit.logic.boolean.conjunction.trueAndTrue
# 18	theorem		|- [not](TRUE and FALSE)
# 	proveit.logic.boolean.conjunction.trueAndFalseNegated
# 19	theorem		|- [not](FALSE and TRUE)
# 	proveit.logic.boolean.conjunction.falseAndTrueNegated
# 20	theorem		|- forall_{P, x | P(FALSE), [not](x)} P(x)
# 	proveit.logic.equality.substituteFalsehood
# 21	theorem		|- FALSE in BOOLEANS
# 	proveit.logic.boolean.falseInBool
# 22	theorem		|- [not](FALSE and FALSE)
# 	proveit.logic.boolean.conjunction.falseAndFalseNegated
