# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">conjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#redundant_conjunction">redundant_conjunction</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving redundant_conjunction presuming []
# Out:
# Beginning proof of redundant_conjunction
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# redundant_conjunction: forall_{n in Naturals} [forall_{A | A} (A and ..n repeats.. and A)]
