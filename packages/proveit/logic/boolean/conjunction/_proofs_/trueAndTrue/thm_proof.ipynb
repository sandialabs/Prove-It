# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">conjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#trueAndTrue">trueAndTrue</a> theorem
# ========

# %%
import proveit
from proveit.logic.boolean.conjunction._axioms_ import andTT
theory = proveit.Theory() # the theorem's theory

# %%
# %proving trueAndTrue

# %%
# %qed
