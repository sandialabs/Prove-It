# %% [markdown]
# Proof of <a class="ProveItLink" href="..\..\..\..\_context_.ipynb">proveit</a>.<a class="ProveItLink" href="..\..\..\_context_.ipynb">logic</a>.<a class="ProveItLink" href="..\..\_context_.ipynb">boolean</a>.<a class="ProveItLink" href="..\_context_.ipynb">conjunction</a>.<a href="../_theorems_.ipynb#falsifiedAndIfNotLeft" class="ProveItLink">falsifiedAndIfNotLeft</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %begin_proof falsifiedAndIfNotLeft presuming []
# Out:
# Recorded 'presuming' information
# Presuming previous theorems in this context (and any of their dependencies).
# Beginning proof of
# falsifiedAndIfNotLeft: forall_{A, B | not(A),B} ((A and B) = FALSE)
