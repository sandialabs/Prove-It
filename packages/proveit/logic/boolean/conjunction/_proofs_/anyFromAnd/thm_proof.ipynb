# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../_theory_.ipynb">conjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#anyFromAnd">anyFromAnd</a> theorem
# ========

# %%
import proveit
from proveit.logic import And
from proveit._common_ import A, B, C
from proveit.logic.boolean._theorems_ import inBoolIfTrue, foldForallOverBool
from proveit.logic.boolean.conjunction._axioms_ import leftInBool, rightInBool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving anyFromAnd
