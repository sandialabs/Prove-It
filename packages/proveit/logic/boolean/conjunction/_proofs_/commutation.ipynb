# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">conjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#commutation">commutation</a> theorem
# ========

# %%
import proveit
from proveit.logic import TRUE, And, Equals
from proveit._common_ import A, B
from proveit.logic.boolean.conjunction._axioms_ import andTT, andTF, andFT, andFF
from proveit.logic.boolean.conjunction._theorems_ import rightFromAnd, leftFromAnd 
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving commutation presuming []
# Out:
# Beginning proof of commutation
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# commutation: forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))]
# 	m : 1, n : 1, P(A, B) : (A and B) = (B and A), Q(A) : A in BOOLEANS, R(A, B) : B in BOOLEANS, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	11, 7, 8	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))]
# 	P(A) : forall_{B in BOOLEANS} ((A and B) = (B and A)), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	11, 10, 14	|- forall_{B in BOOLEANS} ((TRUE and B) = (B and TRUE))
# 	P(B) : (TRUE and B) = (B and TRUE), A : B
# 8	instantiation	11, 12, 13	|- forall_{B in BOOLEANS} ((FALSE and B) = (B and FALSE))
# 	P(B) : (FALSE and B) = (B and FALSE), A : B
# 9	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 10	instantiation	15	|- (TRUE and TRUE) = (TRUE and TRUE)
# 	x : TRUE and TRUE
# 11	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 12	instantiation	19, 14	|- (FALSE and TRUE) = (TRUE and FALSE)
# 	x : TRUE and FALSE, y : FALSE and TRUE
# 13	instantiation	15	|- (FALSE and FALSE) = (FALSE and FALSE)
# 	x : FALSE and FALSE
# 14	instantiation	16, 17, 18	|- (TRUE and FALSE) = (FALSE and TRUE)
# 	x : TRUE and FALSE, y : FALSE, z : FALSE and TRUE
# 15	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equalsReflexivity
# 16	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equalsTransitivity
# 17	axiom		|- (TRUE and FALSE) = FALSE
# 	proveit.logic.boolean.conjunction.andTF
# 18	instantiation	19, 20	|- FALSE = (FALSE and TRUE)
# 	x : FALSE and TRUE, y : FALSE
# 19	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equalsReversal
# 20	axiom		|- (FALSE and TRUE) = FALSE
# 	proveit.logic.boolean.conjunction.andFT
