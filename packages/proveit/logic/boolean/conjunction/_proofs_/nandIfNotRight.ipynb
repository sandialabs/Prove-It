# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../_context_.ipynb">conjunction</a>.<a class="ProveItLink" href="../_theorems_.ipynb#nandIfNotRight">nandIfNotRight</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import A, B
from proveit.logic.boolean.conjunction._theorems_ import nandIfLeftButNotRight, nandIfNeither
from proveit.logic.boolean._theorems_ import foldForallOverBool
from proveit.logic import Not, TRUE, FALSE
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving nandIfNotRight presuming [foldForallOverBool, proveit.logic.boolean.quantification.universal.bundle, proveit.core_expr_types.conditionals.condition_prepend_reduction, proveit.number.numeral.deci.posnat1]
# Out:
# Beginning proof of nandIfNotRight
# Recorded 'presuming' information
# Presuming proveit.core_expr_types.conditionals.condition_prepend_reduction, proveit.logic.boolean.foldForallOverBool, proveit.logic.boolean.quantification.universal.bundle, proveit.number.numeral.deci.posnat1 theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# nandIfNotRight: forall_{A in BOOLEANS, B in BOOLEANS | [not](B)} [not](A and B)

# %%
defaults.assumptions = nandIfNotRight.conditions
# Out:
# defaults.assumptions: (A in BOOLEANS, B in BOOLEANS, [not](B))

# %%
nandIfLeftButNotRight.instantiate({A:TRUE})
# Out:
# {[not](B)} |- [not](TRUE and B)

# %%
nandIfNeither.instantiate({A:FALSE})
# Out:
# {[not](B)} |- [not](FALSE and B)

# %%
nandIfLeftButNotRight.instantiate({A:TRUE, B:B})
# Out:
# {[not](B)} |- [not](TRUE and B)

# %%
nandIfNeither.instantiate({A:FALSE, B:B})
# Out:
# {[not](B)} |- [not](FALSE and B)

# %%
nandIfNotRight.concludeAsFolded(nandIfNotRight.conditions)
# Out:
# nandIfNotRight has been proven.  Now simply execute "%qed".
# |- forall_{A in BOOLEANS, B in BOOLEANS | [not](B)} [not](A and B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A in BOOLEANS, B in BOOLEANS | [not](B)} [not](A and B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEANS} [forall_{B in BOOLEANS | [not](B)} [not](A and B)]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS | [not](B)} [not](A and B)]
# 	m : 1, n : 1, P(A, B) : [not](A and B), Q(A) : A in BOOLEANS, R(A, B) : (B in BOOLEANS) and [not](B), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEANS} [forall_{B in BOOLEANS | [not](B)} [not](A and B)]
# 	P(A) : forall_{B in BOOLEANS | [not](B)} [not](A and B), A : A
# 3	theorem		|- forall_{m in NaturalsPos, n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 	proveit.logic.boolean.quantification.universal.bundle
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 7	instantiation	12, 13, 14	|- {[not](A and B) if A in BOOLEANS ,  (B in BOOLEANS) and [not](B). = {[not](A and B) if A in BOOLEANS ,  B in BOOLEANS ,  [not](B).
# 	n : 2, a : [not](A and B), Q : A in BOOLEANS, R : (B in BOOLEANS, [not](B))
# 8	theorem		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEANS} P(A)]
# 	proveit.logic.boolean.foldForallOverBool
# 9	generalizaton	15	|- forall_{B in BOOLEANS | [not](B)} [not](TRUE and B)
# 10	generalizaton	16	|- forall_{B in BOOLEANS | [not](B)} [not](FALSE and B)
# 11	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 12	theorem		|- forall_{n in Naturals} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 13	theorem		|- 2 in Naturals
# 	proveit.number.numeral.deci.nat2
# 14	instantiation	17	|- |(B in BOOLEANS, [not](B))| = |(1, ..k.., 2)|
# 	a : B in BOOLEANS, b : [not](B)
# 15	instantiation	18, 19, 22	{[not](B)} |- [not](TRUE and B)
# 	A : TRUE, B : B
# 16	instantiation	20, 21, 22	{[not](B)} |- [not](FALSE and B)
# 	A : FALSE, B : B
# 17	theorem		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 	proveit.number.numeral.deci.tuple_len_2_typical_equiv
# 18	theorem		|- forall_{A, B | A, [not](B)} [not](A and B)
# 	proveit.logic.boolean.conjunction.nandIfLeftButNotRight
# 19	axiom		|- TRUE
# 	proveit.logic.boolean.trueAxiom
# 20	theorem		|- forall_{A, B | [not](A), [not](B)} [not](A and B)
# 	proveit.logic.boolean.conjunction.nandIfNeither
# 21	theorem		|- [not](FALSE)
# 	proveit.logic.boolean.negation.notFalse
# 22	assumption		{[not](B)} |- [not](B)
