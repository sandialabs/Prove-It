# %%
from proveit.logic import And, Or, TRUE, FALSE

# %%
And(TRUE, TRUE).evaluate().proof()
# Out:
# <proveit._core_.proof.Axiom instance at 0x0000000003FBE808>

# %%
And(TRUE, TRUE, TRUE).evaluate().proof()
# Out:
# <proveit._core_.proof.Specialization instance at 0x00000000041A9048>

# %%
And(TRUE, Or(TRUE, FALSE)).evaluate().proof()
# Out:
# <proveit._core_.proof.Specialization instance at 0x00000000041DD1C8>

# %%
And(TRUE, Or(TRUE, FALSE), FALSE).evaluate()
# Out:
# |= ( TRUE and ( TRUE or FALSE ) and FALSE ) = FALSE

# %%
And(TRUE, Or(TRUE, FALSE), FALSE).evaluate().proof()
# Out:
# <proveit._core_.proof.Specialization instance at 0x0000000004268688>

# %%
from proveit.logic.boolean.conjunction.theorems import conjunctionIntro, conjunctionClosure
from proveit.common import A, B, C, Aetc

# %%
conjunctionIntro
# Out:
# |= forall_{ .., A_{*} ,..  |  .., A_{*} ,.. } ( ..and A_{*} and.. )

# %%
conjunctionClosure
# Out:
# |= forall_{ .., A_{*} ,..  in BOOLEANS} (( ..and A_{*} and.. ) in BOOLEANS)

# %%
from proveit.logic import compose

# %%
compose([A, B, C], assumptions=[A, B, C])
# Out:
# {A,B,C} |=  A and B and C

# %%
conjunctionIntro.specialize({Aetc:[A, B]}, assumptions=[A, B])
# Out:
# {A,B} |=  A and B

# %%
from proveit.logic import inBool, And

# %%
inBool(And(A, B, C)).prove(assumptions=[inBool(A), inBool(B), inBool(C)])
# Out:
# {A in BOOLEANS,B in BOOLEANS,C in BOOLEANS} |= ( A and B and C ) in BOOLEANS

# %%
conjunctionIntro.specialize({Aetc:[A,B]}, [A, B])
# Out:
# {A,B} |=  A and B

# %%
conjunctionIntro.exprInfo()
# Out:
# <proveit._core_.expression.expr_info.ExpressionInfo instance at 0x0000000004292488>
