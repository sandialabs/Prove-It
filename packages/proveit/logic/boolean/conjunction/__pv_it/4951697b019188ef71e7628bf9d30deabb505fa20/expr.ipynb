# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And, FALSE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(A_1_to_m, FALSE, C_1_to_n), FALSE)
# Out:
# expr: (A_{1} and ..A_{_a}.. and A_{m} and FALSE and C_{1} and ..C_{_a}.. and C_{n}, FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \land \ldots \land A_{m} \land \bot \land C_{1} \land \ldots \land C_{n}, \bot\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} and ..A_{_a}.. and A_{m} and FALSE and C_{1} and ..C_{_a}.. and C_{n}, FALSE)
#    core type: ExprTuple
#    sub-expressions: 1, 5
# 1. A_{1} and ..A_{_a}.. and A_{m} and FALSE and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (A_{1}, ..A_{_a}.., A_{m}, FALSE, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 10
#    end_index: 8
# 5. FALSE
#    core type: Literal
#    sub-expressions:
# 6. C_{1}, ..C_{_a}.., C_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 7. _a -> A_{_a}
#    core type: Lambda
#    parameter: 16
#    body: 12
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. _a -> C_{_a}
#    core type: Lambda
#    parameter: 16
#    body: 13
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. A_{_a}
#     core type: IndexedVar
# variable: 14
# index: 16
# 13. C_{_a}
#     core type: IndexedVar
# variable: 15
# index: 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. C
#     core type: Variable
#     sub-expressions:
# 16. _a
#     core type: Variable
#     sub-expressions:
