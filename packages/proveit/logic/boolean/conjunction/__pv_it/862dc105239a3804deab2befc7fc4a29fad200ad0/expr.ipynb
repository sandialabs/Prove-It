# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import And, Booleans, Equals, Forall, TRUE

# %%
# build up the expression from sub-expressions
expr = Forall([B], Equals(And(TRUE, B), And(B, TRUE)), domain = Booleans)
# Out:
# expr: forall_{B in BOOLEANS} ((TRUE and B) = (B and TRUE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{B \in \mathbb{B}}~\left(\left(\top \land B\right) = \left(B \land \top\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS} ((TRUE and B) = (B and TRUE))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> {(TRUE and B) = (B and TRUE) if B in BOOLEANS.
#    core type: Lambda
#    parameter: 16
#    body: 3
# 3. {(TRUE and B) = (B and TRUE) if B in BOOLEANS.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (TRUE and B) = (B and TRUE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (TRUE and B, B and TRUE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 12
# 10. TRUE and B
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. B and TRUE
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (B, TRUE)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. TRUE
#     core type: Literal
#     sub-expressions:
