# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(And(A, B), Booleans), And(InSet(A, Booleans), InSet(B, Booleans)))
# Out:
# expr: {(A and B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \land B\right) \in \mathbb{B} \textrm{ if } A \in \mathbb{B} ,  B \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A and B) in BOOLEANS if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A and B) in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (A in BOOLEANS) and (B in BOOLEANS)
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (A and B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5, 15
# 4. (A in BOOLEANS, B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. A and B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
