# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(one, subExpr1, one), Add(n, subExpr1, one)), Add(one, n))
# Out:
# expr: ((1 - 1 + 1) + (n - 1 + 1)) = (1 + n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 - 1 + 1\right) + \left(n - 1 + 1\right)\right) = \left(1 + n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 - 1 + 1) + (n - 1 + 1)) = (1 + n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 - 1 + 1) + (n - 1 + 1), 1 + n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 - 1 + 1) + (n - 1 + 1)
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. 1 + n
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (1 - 1 + 1, n - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (1, n)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 7. 1 - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. n - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 15, 13, 15
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (n, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 15
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
