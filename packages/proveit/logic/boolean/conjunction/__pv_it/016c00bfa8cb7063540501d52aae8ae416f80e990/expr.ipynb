# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange
from proveit._common_ import A, k, n
from proveit.logic import And, Forall, InSet
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A], And(ExprRange(k, A, one, n)), condition = A), InSet(n, Naturals))
# Out:
# expr: {forall_{A | A} (A and ..n repeats.. and A) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A~|~A}~\left(A \land ..n \textrm{ repeats}.. \land A\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A | A} (A and ..n repeats.. and A) if n in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A | A} (A and ..n repeats.. and A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> {A and ..n repeats.. and A if A.
#    core type: Lambda
#    parameter: 17
#    body: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 7. {A and ..n repeats.. and A if A.
#    core type: Conditional
#    value: 9
#    condition: 17
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. A and ..n repeats.. and A
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A, ..n repeats.., A)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. A, ..n repeats.., A
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. k -> A
#     core type: Lambda
#     parameter: 16
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
