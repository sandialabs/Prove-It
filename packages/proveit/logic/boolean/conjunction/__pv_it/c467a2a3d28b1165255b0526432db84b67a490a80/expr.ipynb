# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import B, m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, Equals, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_m, B], Equals(And(A_1_to_m, B), And(And(A_1_to_m), B))), InSet(m, Naturals))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m}, B}~\left(\left(A_{1} \land \ldots \land A_{m} \land B\right) = \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right)\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Lambda
#    parameters: 13\n   body: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, Naturals)
#    core type: ExprTuple
#    sub-expressions: 22, 8
# 7. (A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} and ..A_{_a}.. and A_{m} and B, (A_{1} and ..A_{_a}.. and A_{m}) and B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A_{1} and ..A_{_a}.. and A_{m} and B
#     core type: Operation
#     operator: 17
#     operands: 13
# 12. (A_{1} and ..A_{_a}.. and A_{m}) and B
#     core type: Operation
#     operator: 17
#     operands: 14
# 13. (A_{1}, ..A_{_a}.., A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 14. (A_{1} and ..A_{_a}.. and A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 19
# 19. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 20. _a -> A_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 23
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. m
#     core type: Variable
#     sub-expressions:
# 23. A_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
