# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, Equals, TRUE

# %%
# build up the expression from sub-expressions
expr = Equals(And(A_1_to_m), TRUE)
# Out:
# expr: (A_{1} and ..A_{_a}.. and A_{m}) = TRUE

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \land \ldots \land A_{m}\right) = \top

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} and ..A_{_a}.. and A_{m}) = TRUE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A_{1} and ..A_{_a}.. and A_{m}, TRUE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. TRUE
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. _a -> A_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. A_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
