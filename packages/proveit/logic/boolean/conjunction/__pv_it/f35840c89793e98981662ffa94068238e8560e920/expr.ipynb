# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Forall, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([B], Not(And(A, B)), domain = Booleans, condition = Not(B)), InSet(A, Booleans))
# Out:
# expr: {forall_{B in BOOLEANS | [not](B)} [not](A and B) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{B \in \mathbb{B}~|~\lnot B}~(\lnot \left(A \land B\right)) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{B in BOOLEANS | [not](B)} [not](A and B) if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{B in BOOLEANS | [not](B)} [not](A and B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> {[not](A and B) if B in BOOLEANS ,  [not](B).
#    core type: Lambda
#    parameter: 19
#    body: 6
# 5. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 20
# 6. {[not](A and B) if B in BOOLEANS ,  [not](B).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. [not](A and B)
#    core type: Operation
#    operator: 18
#    operand: 9
# 8. (B in BOOLEANS) and [not](B)
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. A and B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (B in BOOLEANS, [not](B))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 19
# 13. B in BOOLEANS
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. [not](B)
#     core type: Operation
#     operator: 18
#     operand: 19
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. BOOLEANS
#     core type: Literal
#     sub-expressions:
