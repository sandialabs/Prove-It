# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import C
from proveit.core_expr_types._common_ import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = And(A_1_to_l, B_1_to_m, C, D_1_to_n)
# Out:
# expr: A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C \land D_{1} \land \ldots \land D_{n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 12
#    end_index: 8
# 4. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 12
#    end_index: 10
# 5. C
#    core type: Variable
#    sub-expressions:
# 6. D_{1}, ..D_{_a}.., D_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 7. _a -> A_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 14
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. _a -> B_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 15
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. _a -> D_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 16
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. A_{_a}
#     core type: IndexedVar
# variable: 17
# index: 20
# 15. B_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 16. D_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. D
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
