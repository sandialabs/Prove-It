# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A
from proveit.logic import And, Booleans, Equals, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(And(A), And(TRUE, A)), InSet(A, Booleans))
# Out:
# expr: {[and](A) = (TRUE and A) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left[\land\right]\left(A\right) = \left(\top \land A\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[and](A) = (TRUE and A) if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [and](A) = (TRUE and A)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ([and](A), TRUE and A)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 7. [and](A)
#    core type: Operation
#    operator: 10
#    operand: 13
# 8. TRUE and A
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (TRUE, A)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
