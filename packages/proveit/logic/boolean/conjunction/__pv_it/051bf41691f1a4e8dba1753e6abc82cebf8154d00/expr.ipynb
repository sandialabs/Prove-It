# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftFromAnd">leftFromAnd</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import leftFromAnd

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftFromAnd
# Out:
# Passed sanity check: built 'leftFromAnd' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftFromAnd.latex())
# Out:
# \vdash \forall_{A, B~|~A, B}~A

# %%
# display the expression information
leftFromAnd.exprInfo()
# Out:
# 0. forall_{A, B | A, B} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A if A ,  B.
#    core type: Lambda
#    parameters: 6\n   body: 3
# 3. {A if A ,  B.
#    core type: Conditional
#    value: 7
#    condition: 4
# 4. A and B
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
