# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#falseAndTrueNegated">falseAndTrueNegated</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import falseAndTrueNegated

# %%
# check that the built expression is the same as the stored expression
# %check_expr falseAndTrueNegated
# Out:
# Passed sanity check: built 'falseAndTrueNegated' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(falseAndTrueNegated.latex())
# Out:
# \vdash \lnot \left(\bot \land \top\right)

# %%
# display the expression information
falseAndTrueNegated.exprInfo()
# Out:
# 0. [not](FALSE and TRUE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. not
#    core type: Literal
#    sub-expressions:
# 2. FALSE and TRUE
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (FALSE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. FALSE
#    core type: Literal
#    sub-expressions:
# 6. TRUE
#    core type: Literal
#    sub-expressions:
