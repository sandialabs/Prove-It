# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#leftInBool">leftInBool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.conjunction._axioms_ import leftInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftInBool
# Out:
# Passed sanity check: built 'leftInBool' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftInBool.latex())
# Out:
# \vdash \forall_{A, B~|~\left(A \land B\right) \in \mathbb{B}}~\left(A \in \mathbb{B}\right)

# %%
# display the expression information
leftInBool.exprInfo()
# Out:
# 0. forall_{A, B | (A and B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A in BOOLEANS if (A and B) in BOOLEANS.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {A in BOOLEANS if (A and B) in BOOLEANS.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (A and B) in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A and B, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A and B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
