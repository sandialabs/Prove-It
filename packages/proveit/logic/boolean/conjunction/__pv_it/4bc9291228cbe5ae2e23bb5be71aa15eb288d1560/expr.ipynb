# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftwardCommutation">leftwardCommutation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import leftwardCommutation

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftwardCommutation
# Out:
# Passed sanity check: built 'leftwardCommutation' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(leftwardCommutation.latex())
# Out:
# \vdash \forall_{l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{A_{1} \in \mathbb{B}, \ldots, A_{l} \in \mathbb{B}, B_{1} \in \mathbb{B}, \ldots, B_{m} \in \mathbb{B}, C \in \mathbb{B}, D_{1} \in \mathbb{B}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C \land D_{1} \land \ldots \land D_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land C \land B_{1} \land \ldots \land B_{m} \land D_{1} \land \ldots \land D_{n}\right) \end{array}\right)\right]

# %%
# display the expression information
leftwardCommutation.exprInfo()
# Out:
# 0. forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (l, m, n) -> {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 43, 45, 48
# 3. {forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (l in Naturals) and (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 29
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B_{1} in BOOLEANS ,  ..B_{_a} in BOOLEANS.. ,  B_{m} in BOOLEANS ,  C in BOOLEANS ,  D_{1} in BOOLEANS ,  ..D_{_a} in BOOLEANS.. ,  D_{n} in BOOLEANS.
#    core type: Lambda
#    parameters: 28\n   body: 9
# 8. (l in Naturals, m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEANS ,  ..A_{_a} in BOOLEANS.. ,  A_{l} in BOOLEANS ,  B_{1} in BOOLEANS ,  ..B_{_a} in BOOLEANS.. ,  B_{m} in BOOLEANS ,  C in BOOLEANS ,  D_{1} in BOOLEANS ,  ..D_{_a} in BOOLEANS.. ,  D_{n} in BOOLEANS.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. l in Naturals
#     core type: Operation
#     operator: 51
#     operands: 15
# 11. m in Naturals
#     core type: Operation
#     operator: 51
#     operands: 16
# 12. n in Naturals
#     core type: Operation
#     operator: 51
#     operands: 17
# 13. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (A_{1} in BOOLEANS) and ..(A_{_a} in BOOLEANS).. and (A_{l} in BOOLEANS) and (B_{1} in BOOLEANS) and ..(B_{_a} in BOOLEANS).. and (B_{m} in BOOLEANS) and (C in BOOLEANS) and (D_{1} in BOOLEANS) and ..(D_{_a} in BOOLEANS).. and (D_{n} in BOOLEANS)
#     core type: Operation
#     operator: 29
#     operands: 20
# 15. (l, Naturals)
#     core type: ExprTuple
#     sub-expressions: 43, 21
# 16. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 45, 21
# 17. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 48, 21
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}, A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B_{1} in BOOLEANS, ..B_{_a} in BOOLEANS.., B_{m} in BOOLEANS, C in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 21. Naturals
#     core type: Literal
#     sub-expressions:
# 22. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (A_{1} in BOOLEANS), ..(A_{_a} in BOOLEANS).., (A_{l} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 47
#     end_index: 43
# 25. (B_{1} in BOOLEANS), ..(B_{_a} in BOOLEANS).., (B_{m} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 47
#     end_index: 45
# 26. C in BOOLEANS
#     core type: Operation
#     operator: 51
#     operands: 33
# 27. (D_{1} in BOOLEANS), ..(D_{_a} in BOOLEANS).., (D_{n} in BOOLEANS)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 47
#     end_index: 48
# 28. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 40, 37
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 40, 36, 37
# 31. _a -> (A_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 38
# 32. _a -> (B_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 39
# 33. (C, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 40, 56
# 34. _a -> (D_{_a} in BOOLEANS)
#     core type: Lambda
#     parameter: 60
#     body: 41
# 35. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 43
# 36. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 37. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 38. A_{_a} in BOOLEANS
#     core type: Operation
#     operator: 51
#     operands: 49
# 39. B_{_a} in BOOLEANS
#     core type: Operation
#     operator: 51
#     operands: 50
# 40. C
#     core type: Variable
#     sub-expressions:
# 41. D_{_a} in BOOLEANS
#     core type: Operation
#     operator: 51
#     operands: 52
# 42. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. _a -> B_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. _a -> D_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. (A_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 53, 56
# 50. (B_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (D_{_a}, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 54. B_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 55. D_{_a}
#     core type: IndexedVar
# variable: 59
# index: 60
# 56. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. B
#     core type: Variable
#     sub-expressions:
# 59. D
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
