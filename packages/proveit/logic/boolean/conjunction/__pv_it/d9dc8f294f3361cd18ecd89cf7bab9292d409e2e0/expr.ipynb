# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([B], Equals(And(A, B), And(B, A)), domain = Booleans), InSet(A, Booleans))
# Out:
# expr: {forall_{B in BOOLEANS} ((A and B) = (B and A)) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{B \in \mathbb{B}}~\left(\left(A \land B\right) = \left(B \land A\right)\right) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{B in BOOLEANS} ((A and B) = (B and A)) if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{B in BOOLEANS} ((A and B) = (B and A))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> {(A and B) = (B and A) if B in BOOLEANS.
#    core type: Lambda
#    parameter: 19
#    body: 6
# 5. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 20, 15
# 6. {(A and B) = (B and A) if B in BOOLEANS.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. (A and B) = (B and A)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A and B, B and A)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 13. A and B
#     core type: Operation
#     operator: 17
#     operands: 16
# 14. B and A
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (B, A)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. A
#     core type: Variable
#     sub-expressions:
