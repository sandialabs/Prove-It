# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = Lambda([A_1_to_m, B], Equals(And(A_1_to_m, B), And(And(A_1_to_m), B)))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{m}, B\right) \mapsto \left(\left(A_{1} \land \ldots \land A_{m} \land B\right) = \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Lambda
#    parameters: 6\n   body: 1
# 1. (A_{1} and ..A_{_a}.. and A_{m} and B) = ((A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (A_{1} and ..A_{_a}.. and A_{m} and B, (A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A_{1} and ..A_{_a}.. and A_{m} and B
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (A_{1} and ..A_{_a}.. and A_{m}) and B
#    core type: Operation
#    operator: 10
#    operands: 7
# 6. (A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 7. (A_{1} and ..A_{_a}.. and A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 12
# 12. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 18
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. A_{_a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
