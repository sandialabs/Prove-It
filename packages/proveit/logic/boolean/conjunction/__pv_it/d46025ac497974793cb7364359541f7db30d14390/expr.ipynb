# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import B, m, n
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And, Booleans, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Conditional(Forall([A_1_to_m, B, C_1_to_n], InSet(B, Booleans), condition = InSet(And(A_1_to_m, B, C_1_to_n), Booleans)), And(InSet(m, Naturals), InSet(n, Naturals))))
# Out:
# expr: (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS} (B in BOOLEANS) if m in Naturals ,  n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~\left(A_{1} \land \ldots \land A_{m} \land B \land C_{1} \land \ldots \land C_{n}\right) \in \mathbb{B}}~\left(B \in \mathbb{B}\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS} (B in BOOLEANS) if m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 27, 30
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS} (B in BOOLEANS) if m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS} (B in BOOLEANS)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 21
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
