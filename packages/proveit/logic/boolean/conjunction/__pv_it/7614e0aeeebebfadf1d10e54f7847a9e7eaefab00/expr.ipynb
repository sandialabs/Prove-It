# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import B, m, n
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = [A_1_to_m, B, C_1_to_n]
expr = Lambda([m, n], Conditional(Forall(subExpr1, B, conditions = subExpr1), And(InSet(m, Naturals), InSet(n, Naturals))))
# Out:
# expr: (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B if m in Naturals ,  n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}}~B \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B if m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 22, 25
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B if m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Lambda
#    parameters: 16\n   body: 8
# 7. (m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Conditional
#    value: 19
#    condition: 11
# 9. m in Naturals
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. n in Naturals
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 22, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 25, 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 17. Naturals
#     core type: Literal
#     sub-expressions:
# 18. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 24
#     end_index: 22
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 21. _a -> A_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 26
# 22. m
#     core type: Variable
#     sub-expressions:
# 23. _a -> C_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. A_{_a}
#     core type: IndexedVar
# variable: 28
# index: 30
# 27. C_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. A
#     core type: Variable
#     sub-expressions:
# 29. C
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
