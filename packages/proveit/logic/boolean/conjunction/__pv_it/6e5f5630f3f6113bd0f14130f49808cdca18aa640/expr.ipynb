# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rightwardCommutation">rightwardCommutation</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import rightwardCommutation

# %%
# check that the built expression is the same as the stored expression
# %check_expr rightwardCommutation
# Out:
# Passed sanity check: built 'rightwardCommutation' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rightwardCommutation.latex())
# Out:
# \vdash \forall_{l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}}~\left[\forall_{A_{1} \in \mathbb{B}, \ldots, A_{l} \in \mathbb{B}, B \in \mathbb{B}, C_{1} \in \mathbb{B}, \ldots, C_{m} \in \mathbb{B}, D_{1} \in \mathbb{B}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \land \ldots \land A_{l} \land B \land C_{1} \land \ldots \land C_{m} \land D_{1} \land \ldots \land D_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land C_{1} \land \ldots \land C_{m} \land B \land D_{1} \land \ldots \land D_{n}\right) \end{array}\right)\right]

# %%
# display the expression information
rightwardCommutation.exprInfo()
# Out:
# 0. forall_{l in Naturals, m in Naturals, n in Naturals} [forall_{A_{1} in BOOLEANS, ..A_{_a} in BOOLEANS.., A_{l} in BOOLEANS, B in BOOLEANS, C_{1} in BOOLEANS, ..C_{_a} in BOOLEANS.., C_{m} in BOOLEANS, D_{1} in BOOLEANS, ..D_{_a} in BOOLEANS.., D_{n} in BOOLEANS} ((A_{1} and ..A_{_a}.. and A_{l} and B and C_{1} and ..C_{_a}.. and C_{m} and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C_{1} and ..C_{_a}.. and C_{m} and B and D_{1} and ..D_{_a}.. and D_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# ...
