# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import B, m, n
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = [A_1_to_m, B, C_1_to_n]
expr = Conditional(Forall(subExpr1, B, conditions = subExpr1), And(InSet(m, Naturals), InSet(n, Naturals)))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B if m in Naturals ,  n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}}~B \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B if m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Lambda
#    parameters: 14\n   body: 6
# 5. (m in Naturals, n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {B if A_{1} ,  ..A_{_a}.. ,  A_{m} ,  B ,  C_{1} ,  ..C_{_a}.. ,  C_{n}.
#    core type: Conditional
#    value: 17
#    condition: 9
# 7. m in Naturals
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. n in Naturals
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (m, Naturals)
#     core type: ExprTuple
#     sub-expressions: 20, 15
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 15. Naturals
#     core type: Literal
#     sub-expressions:
# 16. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 22
#     end_index: 20
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 19. _a -> A_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. _a -> C_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. A_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 25. C_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. A
#     core type: Variable
#     sub-expressions:
# 27. C
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
