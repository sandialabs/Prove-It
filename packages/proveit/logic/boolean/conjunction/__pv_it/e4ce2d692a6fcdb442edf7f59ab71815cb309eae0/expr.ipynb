# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Forall, Implies
from proveit.logic.boolean.conjunction._theorems_ import commutation

# %%
# build up the expression from sub-expressions
expr = Implies(Forall([A], Forall([B], Equals(And(A, B), And(B, A)), domain = Booleans), domain = Booleans), commutation.expr).withWrappingAt(1)
# Out:
# expr: [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left[\forall_{A \in \mathbb{B}}~\left[\forall_{B \in \mathbb{B}}~\left(\left(A \land B\right) = \left(B \land A\right)\right)\right]\right] \\  \Rightarrow \left[\forall_{A \in \mathbb{B}, B \in \mathbb{B}}~\left(\left(A \land B\right) = \left(B \land A\right)\right)\right] \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))]] \\  => [forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))], forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{A in BOOLEANS} [forall_{B in BOOLEANS} ((A and B) = (B and A))]
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. forall_{A in BOOLEANS, B in BOOLEANS} ((A and B) = (B and A))
#    core type: Operation
#    operator: 11
#    operand: 6
# 5. A -> {forall_{B in BOOLEANS} ((A and B) = (B and A)) if A in BOOLEANS.
#    core type: Lambda
#    parameter: 30
#    body: 7
# 6. (A, B) -> {(A and B) = (B and A) if A in BOOLEANS ,  B in BOOLEANS.
#    core type: Lambda
#    parameters: 26\n   body: 8
# ...
