# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#general_exists_Py">general_exists_Py</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.quantification._common_ import general_exists_Py

# %%
# check that the built expression is the same as the stored expression
# %check_expr general_exists_Py
# Out:
# Passed sanity check: built 'general_exists_Py' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(general_exists_Py.latex())
# Out:
# \exists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})

# %%
# display the expression information
general_exists_Py.exprInfo()
# Out:
# 0. exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (y_{1}, ..y_{_a}.., y_{n}) -> P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Lambda
#    parameter: 6
#    body: 3
# 3. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. P
#    core type: Variable
#    sub-expressions:
# 5. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 6
# 6. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. _a -> y_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. y_{_a}
#     core type: IndexedVar
# variable: 11
# index: 12
# 11. y
#     core type: Variable
#     sub-expressions:
# 12. _a
#     core type: Variable
# ...
