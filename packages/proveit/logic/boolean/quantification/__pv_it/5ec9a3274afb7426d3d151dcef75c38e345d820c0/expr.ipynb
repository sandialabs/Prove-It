# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit.core_expr_types._common_ import P__x_1_to_n, Q__x_1_to_n, x_1_to_n

# %%
# build up the expression from sub-expressions
expr = Lambda(x_1_to_n, Conditional(P__x_1_to_n, Q__x_1_to_n))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{n}\right) \mapsto \left\{P(x_{1}, \ldots, x_{n}) \textrm{ if } Q(x_{1}, \ldots, x_{n})\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 4
#    operands: 6
# 3. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. P
#    core type: Variable
#    sub-expressions:
# 5. Q
#    core type: Variable
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 7. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. _a -> x_{_a}
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. x_{_a}
#     core type: IndexedVar
# ...
