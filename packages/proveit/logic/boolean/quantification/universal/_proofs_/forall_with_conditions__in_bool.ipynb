# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_context_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_context_.ipynb">quantification</a>.<a class="ProveItLink" href="../_context_.ipynb">universal</a>.<a class="ProveItLink" href="../_theorems_.ipynb#forall_with_conditions__in_bool">forall_with_conditions__in_bool</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory
from proveit import defaults
from proveit import Conditional
from proveit.core_expr_types._common_ import P__x_1_to_n, Q__x_1_to_n
from proveit.logic.boolean.quantification.universal._axioms_ import forall_in_bool

# %%
# %proving forall_with_conditions__in_bool presuming [proveit.core_expr_types.tuples, proveit.logic.set_theory.containment.supersetMembershipFromSubset, proveit.logic.equality.subRightSideInto, proveit.number.sets.integer.natsPosInNats]
# Out:
# Beginning proof of forall_with_conditions__in_bool
# Recorded 'presuming' information
# Presuming theorems in proveit.core_expr_types.tuples (except any that presume this theorem).
# Presuming proveit.logic.equality.subRightSideInto, proveit.logic.set_theory.containment.supersetMembershipFromSubset, proveit.number.sets.integer.natsPosInNats theorems (applied transitively).
# forall_with_conditions__in_bool: forall_{n in NaturalsPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)]

# %%
defaults.assumptions = forall_with_conditions__in_bool.conditions
# Out:
# defaults.assumptions: (n in NaturalsPos)

# %%
forall_in_bool
# Out:
# |- forall_{n in NaturalsPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)]

# %%
forall_in_bool.instantiate({P__x_1_to_n: Conditional(P__x_1_to_n, Q__x_1_to_n)})
# Out:
# {n in NaturalsPos} |- [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalsPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)]
# 1	instantiation	2, 8, 3	{n in NaturalsPos} |- [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS
# 	n : n, P(x_{1}, ..x_{_a}.., x_{n}) : {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
# 2	axiom		|- forall_{n in NaturalsPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)]
# 	proveit.logic.boolean.quantification.universal.forall_in_bool
# 3	instantiation	4, 5	{n in NaturalsPos} |- |(x_{1}, ..x_{a}.., x_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : x_{_a}
# 4	theorem		|- forall_{i in Naturals} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_equiv
# 5	instantiation	6, 7, 8	{n in NaturalsPos} |- n in Naturals
# 	A : NaturalsPos, B : Naturals, x : n
# 6	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 7	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 8	assumption		{n in NaturalsPos} |- n in NaturalsPos
