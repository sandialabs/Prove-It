# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.logic.boolean.quantification.universal</a>
# ========

# %%
import proveit
# %begin demonstrations

# %%
# %end demonstrations
