# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#bundling">bundling</a>
# ***see <a class="ProveItLink" href="../../_proofs_/bundling.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.boolean.quantification.universal._theorems_ import bundling

# %%
# %dependencies bundling
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems depend upon bundling</h3>
