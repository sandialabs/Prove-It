# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function
from proveit._common_ import P, n
from proveit.core_expr_types._common_ import P__x_1_to_n, P__x_1_to_np1, x_1_to_n, x_1_to_np1
from proveit.logic import And, Forall, Implies
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = [n]
subExpr2 = Forall([x_1_to_n], P__x_1_to_n)
expr = ExprTuple(And(Function(P, []), Forall(subExpr1, Implies(subExpr2, Forall([x_1_to_np1], P__x_1_to_np1)).withWrappingAt(2), domain = Naturals)), Forall(subExpr1, subExpr2, domain = Naturals))
# Out:
# expr: (P() and [forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])], forall_{n in Naturals} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P() \land \left[\forall_{n \in \mathbb{N}}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\forall_{x_{1}, \ldots, x_{n + 1}}~P(x_{1}, \ldots, x_{n + 1})\right] \end{array}\right)\right], \forall_{n \in \mathbb{N}}~\left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P() and [forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])], forall_{n in Naturals} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P() and [forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. forall_{n in Naturals} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 22
#    operand: 5
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(), forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. n -> {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Naturals.
#    core type: Lambda
#    parameter: 38
#    body: 8
# 6. P()
#    core type: Operation
#    operator: 27
#    operands: 9
# 7. forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])
#    core type: Operation
#    operator: 22
#    operand: 10
# 8. {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Naturals.
#    core type: Conditional
#    value: 18
#    condition: 13
# 9. ()
#    core type: ExprTuple
#    sub-expressions:
# 10. n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Naturals.
#     core type: Lambda
#     parameter: 38
#     body: 11
# 11. {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Naturals.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. n in Naturals
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, Naturals)
#     core type: ExprTuple
#     sub-expressions: 38, 20
# 18. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 22
#     operand: 21
# 19. forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. Naturals
#     core type: Literal
#     sub-expressions:
# 21. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameter: 29
#     body: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Lambda
#     parameter: 30
#     body: 25
# 24. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 27
#     operands: 26
# 25. P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 27. P
#     core type: Variable
#     sub-expressions:
# 28. (x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 39
#     end_index: 38
# 30. x_{1}, ..x_{_a}.., x_{n + 1}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 39
#     end_index: 32
# 31. _a -> x_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 33
# 32. n + 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. x_{_a}
#     core type: IndexedVar
# variable: 36
# index: 37
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. _a
#     core type: Variable
#     sub-expressions:
# 38. n
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
