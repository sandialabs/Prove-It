# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import P, Q, n
from proveit.logic import Booleans, Forall, InSet
from proveit.logic.boolean.quantification._common_ import general_forall_Px_if_Qx
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P, Q], InSet(general_forall_Px_if_Qx, Booleans)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, Q}~\left(\left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. {forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)
#    core type: Operation
#    operator: 13
#    operand: 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (P, Q) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS)
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 24, 8
# 6. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 18, 19
# 7. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameter: 21
#     body: 15
# 15. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 18
#     operands: 20
# 17. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. Q
#     core type: Variable
#     sub-expressions:
# 20. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 22. _a -> x_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 25
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. x_{_a}
#     core type: IndexedVar
# variable: 26
# index: 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. _a
#     core type: Variable
#     sub-expressions:
