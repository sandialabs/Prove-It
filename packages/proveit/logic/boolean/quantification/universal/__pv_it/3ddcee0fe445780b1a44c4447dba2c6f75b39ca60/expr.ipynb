# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n
from proveit.core_expr_types._common_ import P__x_1_to_n, P__x_1_to_np1, x_1_to_n, x_1_to_np1
from proveit.logic import Forall, Implies
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([n], Implies(Forall([x_1_to_n], P__x_1_to_n), Forall([x_1_to_np1], P__x_1_to_np1)).withWrappingAt(2), domain = Naturals)
# Out:
# expr: forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\forall_{x_{1}, \ldots, x_{n + 1}}~P(x_{1}, \ldots, x_{n + 1})\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])
#    core type: Operation
#    operator: 13
#    operand: 1
# 1. n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Naturals.
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 29, 11
# 9. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 13
#    operand: 12
# 10. forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameter: 20
#     body: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. (x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Lambda
#     parameter: 21
#     body: 16
# 15. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 18
#     operands: 17
# 16. P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. (x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 30
#     end_index: 29
# 21. x_{1}, ..x_{_a}.., x_{n + 1}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 30
#     end_index: 23
# 22. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 23. n + 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. x_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. 1
#     core type: Literal
#     sub-expressions:
