# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import P, Q, R, m, n
from proveit.logic import And, Equals, Forall, InSet
from proveit.logic.boolean.quantification._common_ import general_bundled_forall_Pxy_if_Qx, general_nested_forall_Pxy_if_Qx
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda([m, n], Conditional(Forall([P, Q, R], Equals(general_nested_forall_Pxy_if_Qx, general_bundled_forall_Pxy_if_Qx).withWrappingAt(1)), And(InSet(m, NaturalsPos), InSet(n, NaturalsPos))))
# Out:
# expr: (m, n) -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]) if m in NaturalsPos ,  n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{m}~|~Q(x_{1}, \ldots, x_{m})}~\left[\forall_{y_{1}, \ldots, y_{n}~|~R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right]\right] \\  = \left[\forall_{x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}~|~Q(x_{1}, \ldots, x_{m}), R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right] \end{array}\right) \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (m, n) -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]) if m in NaturalsPos ,  n in NaturalsPos.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (m, n)
#    core type: ExprTuple
#    sub-expressions: 41, 44
# 2. {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]) if m in NaturalsPos ,  n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 25
#    operand: 5
# 4. (m in NaturalsPos) and (n in NaturalsPos)
#    core type: Operation
#    operator: 27
#    operands: 6
# 5. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m in NaturalsPos, n in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 35, 33, 36
# 8. [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  = [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. m in NaturalsPos
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. n in NaturalsPos
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})], forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (m, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 41, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (n, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 44, 18
# 16. forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 25
#     operand: 19
# 17. forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 25
#     operand: 20
# 18. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 19. (x_{1}, ..x_{_a}.., x_{m}) -> {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Lambda
#     parameter: 38
#     body: 21
# 20. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 22
# 21. {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Conditional
#     value: 23
#     condition: 30
# 22. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 31
#     condition: 24
# 23. forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 25
#     operand: 26
# 24. Q(x_{1}, ..x_{_a}.., x_{m}) and R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. (y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameter: 39
#     body: 29
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 29. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. Q(x_{1}, ..x_{_a}.., x_{m})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 37
# 32. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. (x_{1}, ..x_{_a}.., x_{m})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. R
#     core type: Variable
#     sub-expressions:
# 37. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 43
#     end_index: 41
# 39. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 40. _a -> x_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 45
# 41. m
#     core type: Variable
#     sub-expressions:
# 42. _a -> y_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 46
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. x_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 46. y_{_a}
#     core type: IndexedVar
# variable: 48
# index: 49
# 47. x
#     core type: Variable
#     sub-expressions:
# 48. y
#     core type: Variable
#     sub-expressions:
# 49. _a
#     core type: Variable
#     sub-expressions:
