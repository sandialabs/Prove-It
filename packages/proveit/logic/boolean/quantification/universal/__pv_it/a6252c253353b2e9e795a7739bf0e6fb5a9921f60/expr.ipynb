# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import Booleans, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = InSet(Forall([x_1_to_n], P__x_1_to_n, condition = Q__x_1_to_n), Booleans)
# Out:
# expr: [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameter: 13
#    body: 7
# 7. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 10
#    operands: 12
# 9. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. _a -> x_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. x_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
