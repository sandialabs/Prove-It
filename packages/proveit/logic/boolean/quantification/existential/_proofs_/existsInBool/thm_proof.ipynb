# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">boolean</a>.<a class="ProveItLink" href="../../_theory_.ipynb">quantification</a>.<a class="ProveItLink" href="../_theory_.ipynb">existential</a>.<a href="../_theorems_.ipynb#existsInBool" class="ProveItLink">existsInBool</a> theorem
# ========
# *** see <a href="../__pv_it/84700d9fefa54ea1d425e5f5147806a4ff4396650/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving existsInBool
