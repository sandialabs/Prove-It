# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import Implies, SubsetEq
from proveit.logic.boolean.quantification._common_ import general_exists_in_A_Px, general_exists_in_B_Py

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(general_exists_in_A_Px, general_exists_in_B_Py).withWrappingAt(2), SubsetEq(A, B))
# Out:
# expr: {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subseteq B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array} \textrm{ if } A \subseteq B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subseteq B.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A subseteq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n}), exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 40, 42
# 7. exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 10
#    operand: 9
# 8. exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#    core type: Lambda
#    parameter: 24
#    body: 12
# 10. exists
#     core type: Literal
#     sub-expressions:
# 11. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Lambda
#     parameter: 26
#     body: 13
# 12. {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 20
#     operands: 18
# 15. (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A)
#     core type: Operation
#     operator: 22
#     operands: 19
# 16. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. (x_{1} in A, ..x_{_a} in A.., x_{n} in A)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. P
#     core type: Variable
#     sub-expressions:
# 21. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (y_{1} in B, ..y_{_a} in B.., y_{n} in B)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 32
#     end_index: 33
# 25. (x_{1} in A), ..(x_{_a} in A).., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 33
# 26. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 32
#     end_index: 33
# 27. (y_{1} in B), ..(y_{_a} in B).., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 28. _a -> x_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 39
# 29. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 45
#     body: 34
# 30. _a -> y_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 41
# 31. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 45
#     body: 35
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. x_{_a} in A
#     core type: Operation
#     operator: 37
#     operands: 36
# 35. y_{_a} in B
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. x_{_a}
#     core type: IndexedVar
# variable: 43
# index: 45
# 40. A
#     core type: Variable
#     sub-expressions:
# 41. y_{_a}
#     core type: IndexedVar
# variable: 44
# index: 45
# 42. B
#     core type: Variable
#     sub-expressions:
# 43. x
#     core type: Variable
#     sub-expressions:
# 44. y
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
