# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import P, Q, R
from proveit.logic import Forall, Implies
from proveit.logic.boolean.quantification._common_ import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx

# %%
# build up the expression from sub-expressions
expr = Forall([P, Q, R], Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).withWrappingAt(2)).withWrappingAt(2))
# Out:
# expr: forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow R(x_{1}, \ldots, x_{n})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \Rightarrow  \\ \left[\exists_{z_{1}, \ldots, z_{n}~|~Q(z_{1}, \ldots, z_{n})}~R(z_{1}, \ldots, z_{n})\right] \end{array}\right) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 29, 32, 31
# 3. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: Operation
#    operator: 18
#    operands: 4
# 4. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})), [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]
#    core type: Operation
#    operator: 18
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameter: 34
#    body: 10
# 9. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 16
#     operand: 15
# 12. exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 16
#     operand: 17
# 13. P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 32
#     operands: 28
# 15. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameter: 35
#     body: 20
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. (z_{1}, ..z_{_a}.., z_{n}) -> {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Lambda
#     parameter: 36
#     body: 21
# 18. =>
#     core type: Literal
#     sub-expressions:
# 19. (P(x_{1}, ..x_{_a}.., x_{n}), R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 22. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 31
#     operands: 28
# 24. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 32
#     operands: 30
# 26. R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 31
#     operands: 33
# 27. Q(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 34
# 29. P
#     core type: Variable
#     sub-expressions:
# 30. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. R
#     core type: Variable
#     sub-expressions:
# 32. Q
#     core type: Variable
#     sub-expressions:
# 33. (z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 34. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 40
#     end_index: 41
# 35. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 40
#     end_index: 41
# 36. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 37. _a -> x_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 42
# 38. _a -> y_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 43
# 39. _a -> z_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 44
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
# 42. x_{_a}
#     core type: IndexedVar
# variable: 45
# index: 48
# 43. y_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 44. z_{_a}
#     core type: IndexedVar
# variable: 47
# index: 48
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. y
#     core type: Variable
#     sub-expressions:
# 47. z
#     core type: Variable
#     sub-expressions:
# 48. _a
#     core type: Variable
#     sub-expressions:
