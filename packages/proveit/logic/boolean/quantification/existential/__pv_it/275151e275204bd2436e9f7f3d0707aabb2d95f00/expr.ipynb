# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.logic import Equals, Not
from proveit.logic.boolean.quantification._common_ import general_exists_Py, general_notexists_Px

# %%
# build up the expression from sub-expressions
expr = Equals(general_notexists_Px, Not(general_exists_Py)).withWrappingAt(2)
# Out:
# expr: [notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left[\nexists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\exists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right]) \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 10
# 4. [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. notexists
#    core type: Literal
#    sub-expressions:
# 6. not
#    core type: Literal
#    sub-expressions:
# 7. exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 14
#    operands: 11
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. (y_{1}, ..y_{_a}.., y_{n}) -> P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Lambda
#     parameter: 17
#     body: 12
# 11. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 20
#     end_index: 21
# 14. P
#     core type: Variable
#     sub-expressions:
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 18
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. x_{_a}
#     core type: IndexedVar
# variable: 22
# index: 25
# 19. _a -> y_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 23
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 24. y
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
