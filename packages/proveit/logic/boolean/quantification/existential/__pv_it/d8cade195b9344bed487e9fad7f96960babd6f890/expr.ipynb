# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B, P, n
from proveit.logic import Forall, Implies, InSet, SubsetEq
from proveit.logic.boolean.quantification._common_ import general_exists_in_A_Px, general_exists_in_B_Py
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P, A, B], Implies(general_exists_in_A_Px, general_exists_in_B_Py).withWrappingAt(2), condition = SubsetEq(A, B)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, A, B~|~A \subseteq B}~\left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 42
#    body: 1
# 1. {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 46
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (P, A, B) -> {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subseteq B.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. (P, A, B)
#    core type: ExprTuple
#    sub-expressions: 29, 49, 51
# 8. {[exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})] if A subseteq B.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. [exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. A subseteq B
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n}), exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. subseteq
#     core type: Literal
#     sub-expressions:
# 15. (A, B)
#     core type: ExprTuple
#     sub-expressions: 49, 51
# 16. exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 19
#     operand: 18
# 17. exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Lambda
#     parameter: 33
#     body: 21
# 19. exists
#     core type: Literal
#     sub-expressions:
# 20. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Lambda
#     parameter: 35
#     body: 22
# 21. {P(x_{1}, ..x_{_a}.., x_{n}) if (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A).
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. {P(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B).
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 29
#     operands: 27
# 24. (x_{1} in A) and ..(x_{_a} in A).. and (x_{n} in A)
#     core type: Operation
#     operator: 31
#     operands: 28
# 25. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (y_{1} in B) and ..(y_{_a} in B).. and (y_{n} in B)
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. (x_{1} in A, ..x_{_a} in A.., x_{n} in A)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. P
#     core type: Variable
#     sub-expressions:
# 30. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. (y_{1} in B, ..y_{_a} in B.., y_{n} in B)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 41
#     end_index: 42
# 34. (x_{1} in A), ..(x_{_a} in A).., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 41
#     end_index: 42
# 35. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 41
#     end_index: 42
# 36. (y_{1} in B), ..(y_{_a} in B).., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 37. _a -> x_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 48
# 38. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 54
#     body: 43
# 39. _a -> y_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 50
# 40. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 54
#     body: 44
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. x_{_a} in A
#     core type: Operation
#     operator: 46
#     operands: 45
# 44. y_{_a} in B
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. x_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 49. A
#     core type: Variable
#     sub-expressions:
# 50. y_{_a}
#     core type: IndexedVar
# variable: 53
# index: 54
# 51. B
#     core type: Variable
#     sub-expressions:
# 52. x
#     core type: Variable
#     sub-expressions:
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. _a
#     core type: Variable
#     sub-expressions:
