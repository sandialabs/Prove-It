# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#existentialImplication">existentialImplication</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.quantification.existential._theorems_ import existentialImplication

# %%
# check that the built expression is the same as the stored expression
# %check_expr existentialImplication
# Out:
# Passed sanity check: built 'existentialImplication' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(existentialImplication.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow R(x_{1}, \ldots, x_{n})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \Rightarrow  \\ \left[\exists_{z_{1}, \ldots, z_{n}~|~Q(z_{1}, \ldots, z_{n})}~R(z_{1}, \ldots, z_{n})\right] \end{array}\right) \end{array}\right)\right]

# %%
# display the expression information
existentialImplication.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))]
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. n -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 48
#    body: 2
# 2. {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Operation
#    operator: 14
#    operand: 5
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 48, 10
# 8. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 36, 39, 38
# 9. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: Operation
#    operator: 25
#    operands: 11
# 10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})), [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]
#     core type: Operation
#     operator: 25
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameter: 41
#     body: 17
# 16. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operand: 22
# 19. exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 23
#     operand: 24
# 20. P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 39
#     operands: 35
# 22. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameter: 42
#     body: 27
# 23. exists
#     core type: Literal
#     sub-expressions:
# 24. (z_{1}, ..z_{_a}.., z_{n}) -> {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Lambda
#     parameter: 43
#     body: 28
# 25. =>
#     core type: Literal
#     sub-expressions:
# 26. (P(x_{1}, ..x_{_a}.., x_{n}), R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 28. {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 35
# 30. R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 38
#     operands: 35
# 31. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 39
#     operands: 37
# 33. R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 38
#     operands: 40
# 34. Q(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. P
#     core type: Variable
#     sub-expressions:
# 37. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. R
#     core type: Variable
#     sub-expressions:
# 39. Q
#     core type: Variable
#     sub-expressions:
# 40. (z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 48
# 42. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 47
#     end_index: 48
# 43. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. _a -> x_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 49
# 45. _a -> y_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 50
# 46. _a -> z_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 51
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. x_{_a}
#     core type: IndexedVar
# variable: 52
# index: 55
# 50. y_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 51. z_{_a}
#     core type: IndexedVar
# variable: 54
# index: 55
# 52. x
#     core type: Variable
#     sub-expressions:
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. z
#     core type: Variable
#     sub-expressions:
# 55. _a
#     core type: Variable
#     sub-expressions:
