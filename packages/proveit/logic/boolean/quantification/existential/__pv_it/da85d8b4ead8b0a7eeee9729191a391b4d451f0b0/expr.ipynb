# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import P, Q, R, n
from proveit.logic import Forall, Implies, InSet
from proveit.logic.boolean.quantification._common_ import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P, Q, R], Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).withWrappingAt(2)).withWrappingAt(2)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow R(x_{1}, \ldots, x_{n})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \Rightarrow  \\ \left[\exists_{z_{1}, \ldots, z_{n}~|~Q(z_{1}, \ldots, z_{n})}~R(z_{1}, \ldots, z_{n})\right] \end{array}\right) \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 47
#    body: 1
# 1. {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Operation
#    operator: 13
#    operand: 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 47, 9
# 7. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 35, 38, 37
# 8. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: Operation
#    operator: 24
#    operands: 10
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})), [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]
#     core type: Operation
#     operator: 24
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameter: 40
#     body: 16
# 15. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 22
#     operand: 21
# 18. exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 22
#     operand: 23
# 19. P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 38
#     operands: 34
# 21. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameter: 41
#     body: 26
# 22. exists
#     core type: Literal
#     sub-expressions:
# 23. (z_{1}, ..z_{_a}.., z_{n}) -> {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Lambda
#     parameter: 42
#     body: 27
# 24. =>
#     core type: Literal
#     sub-expressions:
# 25. (P(x_{1}, ..x_{_a}.., x_{n}), R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Conditional
#     value: 32
#     condition: 33
# 28. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 35
#     operands: 34
# 29. R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 37
#     operands: 34
# 30. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 36
# 32. R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 37
#     operands: 39
# 33. Q(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. R
#     core type: Variable
#     sub-expressions:
# 38. Q
#     core type: Variable
#     sub-expressions:
# 39. (z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 40. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 47
# 41. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 46
#     end_index: 47
# 42. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 43. _a -> x_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 48
# 44. _a -> y_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 49
# 45. _a -> z_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 50
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. x_{_a}
#     core type: IndexedVar
# variable: 51
# index: 54
# 49. y_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 50. z_{_a}
#     core type: IndexedVar
# variable: 53
# index: 54
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. y
#     core type: Variable
#     sub-expressions:
# 53. z
#     core type: Variable
#     sub-expressions:
# 54. _a
#     core type: Variable
#     sub-expressions:
