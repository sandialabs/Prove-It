# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#existsInSuperset">existsInSuperset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.quantification.existential._theorems_ import existsInSuperset

# %%
# check that the built expression is the same as the stored expression
# %check_expr existsInSuperset
# Out:
# Passed sanity check: built 'existsInSuperset' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(existsInSuperset.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, A, B~|~A \subseteq B}~\left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right)\right]

# %%
# display the expression information
existsInSuperset.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 43
#    body: 2
# 2. {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])
# ...
