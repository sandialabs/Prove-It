# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import P, n
from proveit.logic import Equals, Forall, InSet, Not
from proveit.logic.boolean.quantification._common_ import general_exists_Py, general_notexists_Px
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P], Equals(general_notexists_Px, Not(general_exists_Py)).withWrappingAt(2)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{P} ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P}~\left(\begin{array}{c} \left[\nexists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\exists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right]) \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{P} ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 30
#    body: 1
# 1. {forall_{P} ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P} ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. P -> ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})))
#    core type: Lambda
#    parameter: 23
#    body: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 30, 9
# 8. [notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 14
#     operand: 19
# 13. [not](exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 15
#     operand: 16
# 14. notexists
#     core type: Literal
#     sub-expressions:
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. exists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 23
#     operands: 20
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. (y_{1}, ..y_{_a}.., y_{n}) -> P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Lambda
#     parameter: 26
#     body: 21
# 20. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 29
#     end_index: 30
# 23. P
#     core type: Variable
#     sub-expressions:
# 24. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 25. _a -> x_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 27
# 26. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 29
#     end_index: 30
# 27. x_{_a}
#     core type: IndexedVar
# variable: 31
# index: 34
# 28. _a -> y_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 32
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. n
#     core type: Variable
#     sub-expressions:
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. y_{_a}
#     core type: IndexedVar
# variable: 33
# index: 34
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. _a
#     core type: Variable
#     sub-expressions:
