# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import P
from proveit.logic import Equals, Forall, Not
from proveit.logic.boolean.quantification._common_ import general_exists_Px, general_forall__Py_not_T

# %%
# build up the expression from sub-expressions
expr = Forall([P], Equals(general_exists_Px, Not(general_forall__Py_not_T)).withWrappingAt(2))
# Out:
# expr: forall_{P} ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P}~\left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\forall_{x_{1}, \ldots, x_{n}}~\left(P(x_{1}, \ldots, x_{n}) \neq \top\right)\right]) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{P} ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)))
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. P -> ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)))
#    core type: Lambda
#    parameter: 18
#    body: 2
# 2. [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. [not](forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. exists
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameter: 20
#    body: 16
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n}) -> (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
#     core type: Lambda
#     parameter: 20
#     body: 13
# 13. P(x_{1}, ..x_{_a}.., x_{n}) != TRUE
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. !=
#     core type: Literal
#     sub-expressions:
# 15. (P(x_{1}, ..x_{_a}.., x_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. TRUE
#     core type: Literal
#     sub-expressions:
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 20. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 21. _a -> x_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 24
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. x_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
