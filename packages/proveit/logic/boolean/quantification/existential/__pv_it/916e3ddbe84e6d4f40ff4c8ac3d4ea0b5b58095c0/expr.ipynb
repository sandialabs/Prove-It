# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import P, n
from proveit.core_expr_types._common_ import P__y_1_to_n, y_1_to_n
from proveit.logic import Forall, Implies, InSet
from proveit.logic.boolean.quantification._common_ import general_exists_Px
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P], Forall([y_1_to_n], Implies(P__y_1_to_n, general_exists_Px).withWrappingAt(2))), InSet(n, NaturalsPos))
# Out:
# expr: {forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])] if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P}~\left[\forall_{y_{1}, \ldots, y_{n}}~\left(\begin{array}{c} P(y_{1}, \ldots, y_{n}) \Rightarrow  \\ \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \end{array}\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])] if n in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. n in NaturalsPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. P -> [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])]
#    core type: Lambda
#    parameter: 21
#    body: 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 28, 7
# 6. forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (y_{1}, ..y_{_a}.., y_{n}) -> (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: Lambda
#    parameter: 18
#    body: 10
# 10. P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (P(y_{1}, ..y_{_a}.., y_{n}), exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operands: 15
# 14. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameter: 24
#     body: 19
# 18. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 27
#     end_index: 28
# 19. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. _a -> y_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 23
# 21. P
#     core type: Variable
#     sub-expressions:
# 22. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. y_{_a}
#     core type: IndexedVar
# variable: 25
# index: 31
# 24. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. _a -> x_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. x_{_a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
