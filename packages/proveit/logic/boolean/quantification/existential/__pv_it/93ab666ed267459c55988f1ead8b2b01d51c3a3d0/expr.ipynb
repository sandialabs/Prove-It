# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#notExistsFolding">notExistsFolding</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.boolean.quantification.existential._theorems_ import notExistsFolding

# %%
# check that the built expression is the same as the stored expression
# %check_expr notExistsFolding
# Out:
# Passed sanity check: built 'notExistsFolding' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(notExistsFolding.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P}~\left(\begin{array}{c} (\lnot \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]) \Rightarrow  \\ \left[\nexists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right)\right]

# %%
# display the expression information
notExistsFolding.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 30
#    body: 2
# 2. {forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
# ...
