# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import P
from proveit.logic import Forall, Implies, Not
from proveit.logic.boolean.quantification._common_ import general_exists_Px, general_notexists_Py

# %%
# build up the expression from sub-expressions
expr = Forall([P], Implies(Not(general_exists_Px), general_notexists_Py).withWrappingAt(2))
# Out:
# expr: forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P}~\left(\begin{array}{c} (\lnot \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]) \Rightarrow  \\ \left[\nexists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. P -> ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Lambda
#    parameter: 16
#    body: 3
# 3. [not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})), notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. [not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operand: 12
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. notexists
#     core type: Literal
#     sub-expressions:
# 11. exists
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameter: 19
#     body: 14
# 13. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 16
#     operands: 15
# 14. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. P
#     core type: Variable
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 22
#     end_index: 23
# 19. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. _a -> y_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 21. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. y_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 25. x_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
