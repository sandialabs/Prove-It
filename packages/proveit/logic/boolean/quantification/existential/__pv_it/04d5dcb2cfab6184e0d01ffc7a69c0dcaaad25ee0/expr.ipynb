# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.core_expr_types._common_ import P__y_1_to_n, y_1_to_n
from proveit.logic import Implies
from proveit.logic.boolean.quantification._common_ import general_exists_Px

# %%
# build up the expression from sub-expressions
expr = Lambda(y_1_to_n, Implies(P__y_1_to_n, general_exists_Px).withWrappingAt(2))
# Out:
# expr: (y_{1}, ..y_{_a}.., y_{n}) -> (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(y_{1}, \ldots, y_{n}\right) \mapsto \left(\begin{array}{c} P(y_{1}, \ldots, y_{n}) \Rightarrow  \\ \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y_{1}, ..y_{_a}.., y_{n}) -> (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. (P(y_{1}, ..y_{_a}.., y_{n}), exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. exists
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameter: 15
#    body: 10
# 9. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 18
#    end_index: 19
# 10. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. _a -> y_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 14
# 12. P
#     core type: Variable
#     sub-expressions:
# 13. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. y_{_a}
#     core type: IndexedVar
# variable: 16
# index: 22
# 15. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. _a -> x_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 20
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. x_{_a}
#     core type: IndexedVar
# variable: 21
# index: 22
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. _a
#     core type: Variable
#     sub-expressions:
