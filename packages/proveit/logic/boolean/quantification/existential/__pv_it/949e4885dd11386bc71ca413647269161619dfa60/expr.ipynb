# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P
from proveit.logic import Equals
from proveit.logic.boolean.quantification._common_ import general_forall__Py_not_T, general_notexists_Px

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Equals(general_notexists_Px, general_forall__Py_not_T).withWrappingAt(2))
# Out:
# expr: P -> ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P \mapsto \left(\begin{array}{c} \left[\nexists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] =  \\ \left[\forall_{x_{1}, \ldots, x_{n}}~\left(P(x_{1}, \ldots, x_{n}) \neq \top\right)\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> ([notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)])
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. [notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)]
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. notexists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. forall_{x_{1}, ..x_{_a}.., x_{n}} (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. notexists
#    core type: Literal
#    sub-expressions:
# 7. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameter: 17
#    body: 13
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (x_{1}, ..x_{_a}.., x_{n}) -> (P(x_{1}, ..x_{_a}.., x_{n}) != TRUE)
#    core type: Lambda
#    parameter: 17
#    body: 10
# 10. P(x_{1}, ..x_{_a}.., x_{n}) != TRUE
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (P(x_{1}, ..x_{_a}.., x_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. x_{_a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
