# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#false_antecedent_implication">false_antecedent_implication</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit._common_ import A, B
from proveit.logic import Not, in_bool, FALSE

# %%
# %proving false_antecedent_implication

# %% [markdown]
# Prove $A$ assuming $\bot$ via deriving a contradiction.

# %%
F_assuming_F = FALSE.prove([FALSE])

# %%
not_a_impl_F = F_assuming_F.as_implication(Not(A))

# %%
A_via_contradiction = not_a_impl_F.derive_via_contradiction([in_bool(A)])

# %% [markdown]
# Now we can derive $\bot \Rightarrow A$ via Deduction.

# %%
A_via_contradiction.as_implication(FALSE)

# %%
# %qed
