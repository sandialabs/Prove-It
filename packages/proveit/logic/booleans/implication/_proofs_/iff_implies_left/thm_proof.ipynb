# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#iff_implies_left">iff_implies_left</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans.implication._axioms_ import iff_def
from proveit._common_ import A, B
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iff_implies_left

# %%
iff_def

# %%
iff_def_spec = iff_def.instantiate({A:A, B:B})

# %%
iff_unfolded = iff_def_spec.derive_right_via_equality(iff_implies_left.conditions)

# %%
iff_unfolded.derive_right()

# %%
# %qed
