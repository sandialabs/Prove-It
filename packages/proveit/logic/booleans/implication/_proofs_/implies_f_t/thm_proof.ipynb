# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#implies_f_t">implies_f_t</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans.implication._theorems_ import false_implies_true
theory = proveit.Theory() # the theorem's theory

# %%
# %proving implies_f_t

# %%
# %qed
