# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#from_contraposition">from_contraposition</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A
theory = proveit.Theory() # the theorem's theory

# %%
# %proving from_contraposition

# %%
defaults.assumptions = list(from_contraposition.all_conditions()) + [A]

# %%
not_b_implies_not_a = defaults.assumptions[0]

# %%
not_b_implies_not_a.deny_antecedent().as_implication(A)

# %%
# %qed # automation can take it from here
