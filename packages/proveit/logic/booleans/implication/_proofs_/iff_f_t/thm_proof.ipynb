# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#iff_f_t">iff_f_t</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A, B
from proveit.logic import TRUE, FALSE
from proveit.logic.booleans.implication._axioms_ import iff_def
from proveit.logic.equality._theorems_ import sub_right_side_into, substitute_in_true, substitute_in_false
substitute_in_true.proof().disable(); substitute_in_false.proof().disable() # disable these to avoid longer proof
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iff_f_t

# %%
iff_def

# %%
iff_def_f_t = iff_def.instantiate({A:FALSE, B:TRUE})

# %%
iff_def_f_t.inner_expr().rhs.evaluate()

# %%
# %qed
