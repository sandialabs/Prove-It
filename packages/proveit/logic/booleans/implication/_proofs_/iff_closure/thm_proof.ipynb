# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">implication</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#iff_closure">iff_closure</a> theorem
# ========

# %%
import proveit
# we need to import true_iff_false_negated and false_iff_true_negated
# to derive their side-effects:
from proveit.logic.booleans.implication import true_iff_true, true_iff_false_negated
from proveit.logic.booleans.implication import false_iff_false, false_iff_true_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iff_closure

# %%
# %qed
