# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#iff_closure">iff_closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.implication import iff_closure

# %%
# check that the built expression is the same as the stored expression
assert iff_closure.expr == stored_expr
assert iff_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: iff_closure matches stored_expr")
# Out:
# Passed sanity check: iff_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(iff_closure.latex())
# Out:
# \vdash \forall_{A, B \in \mathbb{B}}~\left(\left(A \Leftrightarrow B\right) \in \mathbb{B}\right)

# %%
# display the expression information
iff_closure.expr_info()
# Out:
# 0. forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {(A <=> B) in BOOLEAN if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(A <=> B) in BOOLEAN if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A <=> B) in BOOLEAN
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (A in BOOLEAN) and (B in BOOLEAN)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A <=> B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A in BOOLEAN, B in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. A <=> B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. A in BOOLEAN
#     core type: Operation
#     operator: 15
#     operands: 14
# ...
