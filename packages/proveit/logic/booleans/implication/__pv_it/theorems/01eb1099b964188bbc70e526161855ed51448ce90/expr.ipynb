# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Boolean, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Implies(B, Not(A)), conditions = [Implies(A, Not(B)), InSet(A, Boolean)])
# Out:
# expr: forall_{A, B | A => [not](B), A in BOOLEAN} (B => [not](A))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~A \Rightarrow (\lnot B), A \in \mathbb{B}}~\left(B \Rightarrow (\lnot A)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | A => [not](B), A in BOOLEAN} (B => [not](A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {B => [not](A) if A => [not](B) ,  A in BOOLEAN.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B)
#    core type: ExprTuple
#    sub-expressions: 18, 21
# 4. {B => [not](A) if A => [not](B) ,  A in BOOLEAN.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. B => [not](A)
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (A => [not](B)) and (A in BOOLEAN)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (B, [not](A))
#    core type: ExprTuple
#    sub-expressions: 21, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A => [not](B), A in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. [not](A)
#     core type: Operation
#     operator: 20
#     operand: 18
# 11. A => [not](B)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A in BOOLEAN
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (A, [not](B))
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. [not](B)
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 20. not
#     core type: Literal
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
