# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import Iff, Implies, Not

# %%
# build up the expression from sub-expressions
expr = Conditional(Not(Iff(A, B)), Not(Implies(B, A)))
# Out:
# expr: {[not](A <=> B) if [not](B => A).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lnot \left(A \Leftrightarrow B\right) \textrm{ if } \lnot \left(B \Rightarrow A\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[not](A <=> B) if [not](B => A).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [not](A <=> B)
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. [not](B => A)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. A <=> B
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. B => A
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=>
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (B, A)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
