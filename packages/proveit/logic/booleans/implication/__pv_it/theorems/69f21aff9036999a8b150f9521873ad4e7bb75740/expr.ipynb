# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Boolean, Equals, Forall, Iff

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Equals(A, B), domains = [Boolean, Boolean], condition = Iff(A, B))
# Out:
# expr: forall_{A, B in BOOLEAN | A <=> B} (A = B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B \in \mathbb{B}~|~A \Leftrightarrow B}~\left(A = B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B in BOOLEAN | A <=> B} (A = B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A <=> B.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A <=> B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A = B
#    core type: Operation
#    operator: 6
#    operands: 16
# 5. (A in BOOLEAN) and (B in BOOLEAN) and (A <=> B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A in BOOLEAN, B in BOOLEAN, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 9. A in BOOLEAN
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. B in BOOLEAN
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. A <=> B
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. <=>
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
