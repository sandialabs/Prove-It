# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_iff_true">true_iff_true</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.implication import true_iff_true

# %%
# check that the built expression is the same as the stored expression
assert true_iff_true.expr == stored_expr
assert true_iff_true.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_iff_true matches stored_expr")
# Out:
# Passed sanity check: true_iff_true matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(true_iff_true.latex())
# Out:
# \vdash \top \Leftrightarrow \top

# %%
# display the expression information
true_iff_true.expr_info()
# Out:
# 0. TRUE <=> TRUE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. (TRUE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 3, 3
# 3. TRUE
#    core type: Literal
#    sub-expressions:
