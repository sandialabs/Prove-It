# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple
from proveit.logic import Boolean, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Boolean), InSet(B, Boolean), Iff(A, B))
# Out:
# expr: (A in BOOLEAN, B in BOOLEAN, A <=> B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}, B \in \mathbb{B}, A \Leftrightarrow B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A in BOOLEAN, B in BOOLEAN, A <=> B)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. A in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. B in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. A <=> B
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
