# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Boolean, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = And(InSet(B, Boolean), Implies(A, B), Implies(B, A))
# Out:
# expr: (B in BOOLEAN) and (A => B) and (B => A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \in \mathbb{B}\right) \land \left(A \Rightarrow B\right) \land \left(B \Rightarrow A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B in BOOLEAN) and (A => B) and (B => A)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (B in BOOLEAN, A => B, B => A)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. B in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. A => B
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. B => A
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (B, A)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
