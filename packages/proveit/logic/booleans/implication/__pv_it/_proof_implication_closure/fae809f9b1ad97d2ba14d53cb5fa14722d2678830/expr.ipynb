# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Boolean, FALSE, Implies, Not, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Not(Implies(TRUE, FALSE)), Boolean)
# Out:
# expr: ([not](TRUE => FALSE), BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\lnot \left(\top \Rightarrow \bot\right), \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ([not](TRUE => FALSE), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [not](TRUE => FALSE)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 3. not
#    core type: Literal
#    sub-expressions:
# 4. TRUE => FALSE
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (TRUE, FALSE)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. TRUE
#    core type: Literal
#    sub-expressions:
# 8. FALSE
#    core type: Literal
#    sub-expressions:
