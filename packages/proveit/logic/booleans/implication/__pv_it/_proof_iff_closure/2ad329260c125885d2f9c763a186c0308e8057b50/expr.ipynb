# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.logic import Boolean, Forall, Iff, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = Forall([B], InSet(Iff(TRUE, B), Boolean), domains = [Boolean])
# Out:
# expr: forall_{B in BOOLEAN} ((TRUE <=> B) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{B \in \mathbb{B}}~\left(\left(\top \Leftrightarrow B\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{B in BOOLEAN} ((TRUE <=> B) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> {(TRUE <=> B) in BOOLEAN if B in BOOLEAN.
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {(TRUE <=> B) in BOOLEAN if B in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (TRUE <=> B) in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. B in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (TRUE <=> B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 9. TRUE <=> B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. <=>
#     core type: Literal
#     sub-expressions:
# 12. (TRUE, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. TRUE
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
