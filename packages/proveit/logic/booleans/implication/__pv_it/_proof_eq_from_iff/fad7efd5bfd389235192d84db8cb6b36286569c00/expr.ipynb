# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.implication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.logic import And, Boolean, FALSE, Iff, InSet

# %%
# build up the expression from sub-expressions
expr = And(InSet(B, Boolean), Iff(FALSE, B))
# Out:
# expr: (B in BOOLEAN) and (FALSE <=> B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \in \mathbb{B}\right) \land \left(\bot \Leftrightarrow B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B in BOOLEAN) and (FALSE <=> B)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (B in BOOLEAN, FALSE <=> B)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. B in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. FALSE <=> B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (FALSE, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 10. FALSE
#     core type: Literal
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
