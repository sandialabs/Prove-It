# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_def_quantified">iff_def_quantified</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.implication import iff_def

# %%
# %proving iff_def_quantified
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_def_quantified">iff_def_quantified:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/58a59ea31f5a83ad01737244ae60b8d4dd112afb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3e25781e2d1dd02b81b25690e1f1bec9c29621e00/dependencies.ipynb">dependencies</a>)<br>

# %%
iff_def
# Out:
# |- [<=>] = [(A, B) -> ((A => B) and (B => A))]

# %%
iff_def.substitution(iff_def_quantified.instance_expr.lhs)
# Out:
# |- (A <=> B) = ((A => B) and (B => A))
# iff_def_quantified may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_def_quantified is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 1	instantiation	2, 3	|- (A <=> B) = ((A => B) and (B => A))
# 	f(_a) : _a(A, B), x : <=>, y(A, B) : (A => B) and (B => A)
# 2	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 3	basic_definition		|- [<=>] = [(A, B) -> ((A => B) and (B => A))]
# 	proveit.logic.booleans.implication.iff_def
