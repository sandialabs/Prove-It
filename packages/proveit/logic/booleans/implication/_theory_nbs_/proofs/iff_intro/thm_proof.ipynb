# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_intro">iff_intro</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving iff_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_intro">iff_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/38afe9062a5b783763816ff4f830f23686d1b3160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dee648f52bae8ad11773d90e9a4bfb8f0139775c0/dependencies.ipynb">dependencies</a>)<br>
# iff_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_intro is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A => B, B => A} (A <=> B)
# 1	instantiation	2, 3	{(A => B) and (B => A)} |- A <=> B
# 	P : A <=> B, Q : (A => B) and (B => A)
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	modus_ponens	4, 5	{(A => B) and (B => A)} |- ((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))
# 4	modus_ponens	6, 7	{(A => B) and (B => A)} |- ((A <=> B) = ((A => B) and (B => A))) => (((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A))))
# 5	instantiation	8	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 6	instantiation	9	|- ((A => B) and (B => A)) => (((A <=> B) = ((A => B) and (B => A))) => (((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))))
# 	A : (A => B) and (B => A), B : (A <=> B) = ((A => B) and (B => A))
# 7	assumption		{(A => B) and (B => A)} |- (A => B) and (B => A)
# 8	theorem		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def_quantified
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
