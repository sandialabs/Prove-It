# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#falsified_antecedent_implication">falsified_antecedent_implication</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Implies, Not, FALSE

# %%
# %proving falsified_antecedent_implication
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="falsified_antecedent_implication">falsified_antecedent_implication:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/28929e1faa0d6cd913a00023d42a5ba1e5cedce10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e05cf9287d165031f563cc4e713007097804fc0b0/dependencies.ipynb">dependencies</a>)<br>
# falsified_antecedent_implication may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = (falsified_antecedent_implication.condition, )
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../../negation/__pv_it/theorems/d6cb9e4509552d53ba07d8d7903246aa9677ce4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
F_impl_B = Implies(FALSE, B).prove()
# Out:
# <strong id="F_impl_B">F_impl_B:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_falsified_antecedent_implication/b53ca97dbff23369b3ad122ef9cd31f8a23b2fc10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_falsified_antecedent_implication/418de185beb89dae07508a8292728d7996f5d1d00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_F = Not(A).unfold()
# Out:
# <strong id="A_impl_F">A_impl_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_falsified_antecedent_implication/5d51e97fdb755ba78bf0e7925d2ee7ee3fc24ac80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2e91c09acf833f9a9fa60791fc63a618fb0cb6b40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction = A_impl_F.derive_consequent(assumptions=(A,))
# Out:
# <strong id="contradiction">contradiction:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_falsified_antecedent_implication/00c127289e503a0c346076041da9cfe4d0b262710/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_via_contradiction = F_impl_B.derive_consequent(assumptions=(A, Not(A)))
# Out:
# <strong id="B_via_contradiction">B_via_contradiction:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_falsified_antecedent_implication/96f7490135d34ae1c7c2771f38610041572ee3ab0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_via_contradiction.as_implication(A)
# Out:
# {[not](A)} |- A => B

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.falsified_antecedent_implication is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A)} (A => B)
# 1	deduction	2	{[not](A)} |- A => B
# 2	modus_ponens	3, 4	{A, [not](A)} |- B
# 3	instantiation	5	|- FALSE => B
# 	A : B
# 4	modus_ponens	6, 7	{A, [not](A)} |- FALSE
# 5	theorem		|- forall_{A} (FALSE => A)
# 	proveit.logic.booleans.implication.false_antecedent_implication
# 6	instantiation	8, 9	{[not](A)} |- A => FALSE
# 	A : A
# 7	assumption		{A} |- A
# 8	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 9	assumption		{[not](A)} |- [not](A)
