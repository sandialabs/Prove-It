# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#false_iff_false">false_iff_false</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving false_iff_false
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="false_iff_false">false_iff_false:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3c8d2e6d203b8fdc322a1cd6633c5de822b6112c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9b6c1cf61d6bee98608e338a2e73f8c40ad2a7de0/dependencies.ipynb">dependencies</a>)<br>
# false_iff_false may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.false_iff_false is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- FALSE <=> FALSE
# 	A : FALSE, B : FALSE
# 1	theorem		|- forall_{A, B | A => B, B => A} (A <=> B)
# 	proveit.logic.booleans.implication.iff_intro
# 2	modus_ponens	3, 5	|- (FALSE => FALSE) and (FALSE => FALSE)
# 3	modus_ponens	4, 5	|- (FALSE => FALSE) => ((FALSE => FALSE) and (FALSE => FALSE))
# 4	instantiation	6	|- (FALSE => FALSE) => ((FALSE => FALSE) => ((FALSE => FALSE) and (FALSE => FALSE)))
# 	A : FALSE => FALSE, B : FALSE => FALSE
# 5	theorem		|- FALSE => FALSE
# 	proveit.logic.booleans.implication.false_implies_false
# 6	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
