# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_closure">iff_closure</a> theorem
# ========

# %%
import proveit
# we need to import true_iff_false_negated and false_iff_true_negated
# to derive their side-effects:
from proveit.logic.booleans.implication import true_iff_true, true_iff_false_negated
from proveit.logic.booleans.implication import false_iff_false, false_iff_true_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving iff_closure
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_closure">iff_closure:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a4ffa6d29c1157c0c94e50a5f6d2897f5e9acc390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/71ac7a846feb950fb5708cd86d98373c1443af7d0/dependencies.ipynb">dependencies</a>)<br>
# iff_closure may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_closure has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)
# 1	instantiation	3, 4	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN)]] \\  => [forall_{A, B in BOOLEAN} ((A <=> B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A <=> B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, x_{1} : A, y_{1} : B
# 2	instantiation	9, 5, 6	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A <=> B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 7, 8	|- forall_{B in BOOLEAN} ((TRUE <=> B) in BOOLEAN)
# 	P(B) : (TRUE <=> B) in BOOLEAN, A : B
# 6	instantiation	9, 10, 11	|- forall_{B in BOOLEAN} ((FALSE <=> B) in BOOLEAN)
# 	P(B) : (FALSE <=> B) in BOOLEAN, A : B
# 7	instantiation	18, 12	|- (TRUE <=> TRUE) in BOOLEAN
# 	A : TRUE <=> TRUE
# 8	instantiation	14, 13	|- (TRUE <=> FALSE) in BOOLEAN
# 	A : TRUE <=> FALSE
# 9	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 10	instantiation	14, 15	|- (FALSE <=> TRUE) in BOOLEAN
# 	A : FALSE <=> TRUE
# 11	instantiation	18, 16	|- (FALSE <=> FALSE) in BOOLEAN
# 	A : FALSE <=> FALSE
# 12	conjecture		|- TRUE <=> TRUE
# 	proveit.logic.booleans.implication.true_iff_true
# 13	instantiation	18, 17	|- [not](TRUE <=> FALSE) in BOOLEAN
# 	A : [not](TRUE <=> FALSE)
# 14	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 15	instantiation	18, 19	|- [not](FALSE <=> TRUE) in BOOLEAN
# 	A : [not](FALSE <=> TRUE)
# 16	conjecture		|- FALSE <=> FALSE
# 	proveit.logic.booleans.implication.false_iff_false
# 17	conjecture		|- [not](TRUE <=> FALSE)
# 	proveit.logic.booleans.implication.true_iff_false_negated
# 18	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 19	theorem		|- [not](FALSE <=> TRUE)
# 	proveit.logic.booleans.implication.false_iff_true_negated
