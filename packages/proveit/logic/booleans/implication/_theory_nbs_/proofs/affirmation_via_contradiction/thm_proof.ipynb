# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#affirmation_via_contradiction">affirmation_via_contradiction</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving affirmation_via_contradiction
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="affirmation_via_contradiction">affirmation_via_contradiction:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0e4c32c7bdfdd36632fe6535a35dea27a98079f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e1e9a824ed031a32830438cc5646e367f032b4770/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# Attempting to use proveit.logic.booleans.negation.unfold_negation
# which has neither been allowed nor disallowed for use in this proof.
# Hint: %s is fully proven and based upon current proofs,
# it is safe to ALLOW.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel or raise an (e)xception?  d
# Attempting to use proveit.logic.booleans.in_bool_if_true
# which has neither been allowed nor disallowed for use in this proof.
# Hint: based upon current proofs, this must be DISALLOWED to prevent circular logic.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel or raise an (e)xception?  d
# proveit.logic.booleans.implication.affirmation_via_contradiction is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | [not](A) => FALSE} A
# 1	instantiation	2, 3	{[not](A) => FALSE} |- A
# 	A : A
# 2	theorem		|- forall_{A | [not]([not](A))} A
# 	proveit.logic.booleans.negation.double_negation_elim
# 3	instantiation	4, 5	{[not](A) => FALSE} |- [not]([not](A))
# 	A : [not](A)
# 4	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 5	assumption		{[not](A) => FALSE} |- [not](A) => FALSE
