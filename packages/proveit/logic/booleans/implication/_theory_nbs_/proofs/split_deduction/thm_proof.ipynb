# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#split_deduction">split_deduction</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C
from proveit.logic import Implies

# %%
# %proving split_deduction
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="split_deduction">split_deduction:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a5c3fef1d9d9107149b49f8093cf270d93714cf50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ae08b08748b8a85d22ef0f8647ab245aa50d09210/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# ### Doing steps manually rather than using automation, for pedogogical purposes
#
# It's possible to prove this using 2 @prover calls.  Can you?

# %%
antecedent = Implies(A, Implies(B, C))
# Out:
# <strong id="antecedent">antecedent:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/17750919c613dfb5794dc80af882e29e829118e80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
B_impl_C = antecedent.derive_consequent(assumptions=[antecedent, A])
# Out:
# <strong id="B_impl_C">B_impl_C:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/17750919c613dfb5794dc80af882e29e829118e80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_split_deduction/fa5d074baada5c0be103929bb322e8c2febb2f7a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a86ca283eb9d9c83c0349442b18fd6f3c40be44b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_B = Implies(A, B)
# Out:
# <strong id="A_impl_B">A_impl_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d78c7a0a66f0f0f40e69d505fb93268ea9af46dc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_impl_B.derive_consequent(assumptions=[A, A_impl_B])
# Out:
# {A, A => B} |- B

# %%
conclusion = B_impl_C.derive_consequent(assumptions=[A_impl_B])
# Out:
# <strong id="conclusion">conclusion:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d78c7a0a66f0f0f40e69d505fb93268ea9af46dc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/17750919c613dfb5794dc80af882e29e829118e80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_split_deduction/e0a027d4b9fb9e7e2d11effd47d0764df731c8b90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../__pv_it/common/9fba9f29e823606ff4fdf2f1c6d5d08d906e850a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# split_deduction may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A_impl_C = conclusion.as_implication(A)
# Out:
# <strong id="A_impl_C">A_impl_C:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d78c7a0a66f0f0f40e69d505fb93268ea9af46dc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/17750919c613dfb5794dc80af882e29e829118e80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_split_deduction/df8500619c2cf65daa739a908fad7c48269116140/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/b0b3d3c382931039ce0ca448f5ff75a920e621340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_B__impl__A_impl_C = A_impl_C.as_implication(A_impl_B)
# Out:
# <strong id="A_impl_B__impl__A_impl_C">A_impl_B__impl__A_impl_C:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/17750919c613dfb5794dc80af882e29e829118e80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_split_deduction/e49118be1cfb600f1d08cbeae129a90e5658e5fe0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/34008e52f82a159dde925710a35f60a3abbddc5d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
final_conclusion = A_impl_B__impl__A_impl_C.as_implication(antecedent)
# Out:
# <strong id="final_conclusion">final_conclusion:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_split_deduction/d2f2e4705b1b8f2c8b005e81b243e12d32bcb3f30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/7925e8de5675bd9e10b74c518753668d98a8b3e20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
final_conclusion.generalize((A, B, C))
# Out:
# |- forall_{A, B, C} ((A => (B => C)) => ((A => B) => (A => C)))
# split_deduction has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.split_deduction is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C} ((A => (B => C)) => ((A => B) => (A => C)))
# 1	deduction	2	|- (A => (B => C)) => ((A => B) => (A => C))
# 2	deduction	3	{A => (B => C)} |- (A => B) => (A => C)
# 3	deduction	4	{A => B, A => (B => C)} |- A => C
# 4	modus_ponens	5, 6	{A => B, A => (B => C), A} |- C
# 5	modus_ponens	7, 9	{A => (B => C), A} |- B => C
# 6	modus_ponens	8, 9	{A => B, A} |- B
# 7	assumption		{A => (B => C)} |- A => (B => C)
# 8	assumption		{A => B} |- A => B
# 9	assumption		{A} |- A
