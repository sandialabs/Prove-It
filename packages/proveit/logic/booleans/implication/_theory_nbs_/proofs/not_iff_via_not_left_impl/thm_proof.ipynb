# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_iff_via_not_left_impl">not_iff_via_not_left_impl</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Iff

# %%
# %proving not_iff_via_not_left_impl
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_iff_via_not_left_impl">not_iff_via_not_left_impl:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/78c20d68a20023122281f4e4912623bc975072db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e24d9391c16b8ff7ce9202891d9caae24a9281900/dependencies.ipynb">dependencies</a>)<br>
# not_iff_via_not_left_impl may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = not_iff_via_not_left_impl.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/76cc3ff46057ae2996b33dda55d8e2e2af73ffe40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_iff_B = Iff(A, B)
# Out:
# <strong id="A_iff_B">A_iff_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/354ec164e0e28f03ef1fb1858764e0da4a36a45b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
iff_A_B_def = A_iff_B.definition()
# Out:
# <strong id="iff_A_B_def">iff_A_B_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/36edc3f916453e19bb37b2ea1e9c38b75ed9d2260/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/6a1fb7a4625d5d14b9fb08d72f3e6598f52293a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_disproven = iff_A_B_def.rhs.disprove()
# Out:
# <strong id="rhs_disproven">rhs_disproven:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/79066e488045f28a7b4bd83c42526d2d065ae2c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/7564fbc2df91bd2d595e8c38630be1fa2484d3400/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/1530c9bc9e7419681a4e77d36e034d191f62b62f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
iff_A_B_def.sub_left_side_into(rhs_disproven)
# Out:
# {[not](B => A)} |- [not](A <=> B)

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.not_iff_via_not_left_impl is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](B => A)} [not](A <=> B)
# 1	instantiation	2, 3	{[not](B => A)} |- [not](A <=> B)
# 	P(_a) : [not](_a), x : A <=> B, y : (A => B) and (B => A)
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{[not](B => A)} |- [not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))
# 4	modus_ponens	6, 7	{[not](B => A)} |- ((A <=> B) = ((A => B) and (B => A))) => ([not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A))))
# 5	instantiation	8	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 6	instantiation	9	|- [not]((A => B) and (B => A)) => (((A <=> B) = ((A => B) and (B => A))) => ([not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))))
# 	A : [not]((A => B) and (B => A)), B : (A <=> B) = ((A => B) and (B => A))
# 7	instantiation	10, 11	{[not](B => A)} |- [not]((A => B) and (B => A))
# 	A : A => B, B : B => A
# 8	theorem		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def_quantified
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	theorem		|- forall_{A, B | [not](B)} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_not_right
# 11	assumption		{[not](B => A)} |- [not](B => A)
