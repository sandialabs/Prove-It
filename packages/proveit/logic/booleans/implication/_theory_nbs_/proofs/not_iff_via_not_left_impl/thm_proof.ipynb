# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_iff_via_not_left_impl">not_iff_via_not_left_impl</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import And, Implies, Iff, Not
from proveit.logic.booleans.conjunction import true_and_false_negated
from proveit.logic.booleans.implication import negated_reflex
theory = proveit.Theory() # the theorem's theory

# %%
# %proving not_iff_via_not_left_impl
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_iff_via_not_left_impl">not_iff_via_not_left_impl:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/78c20d68a20023122281f4e4912623bc975072db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ed73e1a58285c7e35835db5e2f56c81943774e9f0/dependencies.ipynb">dependencies</a>)<br>
# not_iff_via_not_left_impl may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = not_iff_via_not_left_impl.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/76cc3ff46057ae2996b33dda55d8e2e2af73ffe40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
true_and_false_negated
# Out:
# |- [not](TRUE and FALSE)

# %%
not__AimplB_and_T = true_and_false_negated.inner_expr().operand.operands[0].substitute(Implies(A, B))
# Out:
# <strong id="not__AimplB_and_T">not__AimplB_and_T:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/79066e488045f28a7b4bd83c42526d2d065ae2c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/263196030fd06bedbb5f6222a988aaa2460326790/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/416c5bef0af04292ab249b38cfbba5eadb59077d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not__AimplB_and_BimplA = not__AimplB_and_T.inner_expr().operand.operands[1].substitute(Implies(B, A))
# Out:
# <strong id="not__AimplB_and_BimplA">not__AimplB_and_BimplA:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/79066e488045f28a7b4bd83c42526d2d065ae2c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/50f1ef5a566a1bddfec3ce7fc4513c6d8f2d50cb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/f7f183ad4bcd4e28799d9125a8933b526a62f6990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_iff_B__def = Iff(A, B).definition(assumptions=[])
# Out:
# <strong id="A_iff_B__def">A_iff_B__def:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_left_impl/b7aba8a005f5ba408b795ab73886a80c28ee71c20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/6a1fb7a4625d5d14b9fb08d72f3e6598f52293a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_iff_B__def.sub_left_side_into(not__AimplB_and_BimplA)
# Out:
# {[not](B => A)} |- [not](A <=> B)

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.not_iff_via_not_left_impl has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](B => A)} [not](A <=> B)
# 1	instantiation	2, 3, 4	{[not](B => A)} |- [not](A <=> B)
# 	P(_a) : [not](_a), x : A <=> B, y : (A => B) and (B => A)
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 12	{[not](B => A)} |- [not]((A => B) and (B => A))
# 	P(_a) : [not]((A => B) and _a), x : B => A
# 4	instantiation	7	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 5	theorem		|- forall_{P, x | P(FALSE), [not](x)} P(x)
# 	proveit.logic.equality.substitute_falsehood
# 6	instantiation	8, 9, 10	{[not](B => A)} |- [not]((A => B) and FALSE)
# 	P(_a) : [not](_a and FALSE), x : A => B
# 7	axiom		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def
# 8	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 9	theorem		|- [not](TRUE and FALSE)
# 	proveit.logic.booleans.conjunction.true_and_false_negated
# 10	instantiation	11, 12	{[not](B => A)} |- A => B
# 	A : B, B : A
# 11	theorem		|- forall_{A, B | [not](A => B)} (B => A)
# 	proveit.logic.booleans.implication.negated_reflex
# 12	assumption		{[not](B => A)} |- [not](B => A)
