# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_symmetry">iff_symmetry</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving iff_symmetry
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_symmetry">iff_symmetry:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f79984b537d4b8ec3119d627d9b72c99d1a346a90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/11fc9602fec145b29b19503e4363d085639ba56f0/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_symmetry is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A <=> B} (B <=> A)
# 1	instantiation	2, 3	{A <=> B} |- B <=> A
# 	A : B, B : A
# 2	theorem		|- forall_{A, B | A => B, B => A} (A <=> B)
# 	proveit.logic.booleans.implication.iff_intro
# 3	modus_ponens	4, 5	{A <=> B} |- (B => A) and (A => B)
# 4	modus_ponens	6, 7	{A <=> B} |- (A => B) => ((B => A) and (A => B))
# 5	instantiation	8, 11	{A <=> B} |- A => B
# 	A : A, B : B
# 6	instantiation	9	|- (B => A) => ((A => B) => ((B => A) and (A => B)))
# 	A : B => A, B : A => B
# 7	instantiation	10, 11	{A <=> B} |- B => A
# 	A : A, B : B
# 8	theorem		|- forall_{A, B | A <=> B} (A => B)
# 	proveit.logic.booleans.implication.iff_implies_right
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	theorem		|- forall_{A, B | A <=> B} (B => A)
# 	proveit.logic.booleans.implication.iff_implies_left
# ...
