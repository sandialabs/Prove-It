# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_f_t">iff_f_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import TRUE, FALSE, Iff

# %%
# %proving iff_f_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_f_t">iff_f_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d299dcf582f22b8136620d62e52412141024c17c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3c691cc94d80b086617e94bfb947f8de098868ad0/dependencies.ipynb">dependencies</a>)<br>

# %%
iff_f_t__def = iff_f_t.lhs.definition(auto_simplify=False)
# Out:
# <strong id="iff_f_t__def">iff_f_t__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_iff_f_t/bb0c4957d2c6ae2d0ed328e262bb971b2250fab70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_iff_f_t/aebc778ed4232ed464eb855938f7a26e236a24d40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_eval = iff_f_t__def.rhs.evaluation()
# Out:
# <strong id="rhs_eval">rhs_eval:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_iff_f_t/ee7c9195417b5c024e7db6350dcef6d1fdf616fe0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_iff_f_t/2698767b0dc91b51db2c5fd128d948372ff0af4d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# iff_f_t may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
iff_f_t__def.apply_transitivity(rhs_eval)
# Out:
# |- (FALSE <=> TRUE) = FALSE
# iff_f_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_f_t is now proven.
# 	step type	requirements	statement
# 0	instantiation	12, 1	|- (FALSE <=> TRUE) = FALSE
# 	x : FALSE <=> TRUE, y : (FALSE => TRUE) and (TRUE => FALSE), z : FALSE
# 1	modus_ponens	2, 3	|- ((FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))) and (((FALSE => TRUE) and (TRUE => FALSE)) = FALSE)
# 2	modus_ponens	4, 5	|- (((FALSE => TRUE) and (TRUE => FALSE)) = FALSE) => (((FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))) and (((FALSE => TRUE) and (TRUE => FALSE)) = FALSE))
# 3	instantiation	12, 6	|- ((FALSE => TRUE) and (TRUE => FALSE)) = FALSE
# 	x : (FALSE => TRUE) and (TRUE => FALSE), y : TRUE and FALSE, z : FALSE
# 4	instantiation	19	|- ((FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))) => ((((FALSE => TRUE) and (TRUE => FALSE)) = FALSE) => (((FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))) and (((FALSE => TRUE) and (TRUE => FALSE)) = FALSE)))
# 	A : (FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE)), B : ((FALSE => TRUE) and (TRUE => FALSE)) = FALSE
# 5	instantiation	7	|- (FALSE <=> TRUE) = ((FALSE => TRUE) and (TRUE => FALSE))
# 	A : FALSE, B : TRUE
# 6	modus_ponens	8, 9	|- (((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE)) and ((TRUE and FALSE) = FALSE)
# 7	theorem		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def_quantified
# 8	modus_ponens	10, 11	|- ((TRUE and FALSE) = FALSE) => ((((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE)) and ((TRUE and FALSE) = FALSE))
# 9	theorem		|- (TRUE and FALSE) = FALSE
# 	proveit.logic.booleans.conjunction.and_t_f
# 10	instantiation	19	|- (((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE)) => (((TRUE and FALSE) = FALSE) => ((((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE)) and ((TRUE and FALSE) = FALSE)))
# 	A : ((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE), B : (TRUE and FALSE) = FALSE
# 11	instantiation	12, 13	|- ((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and FALSE)
# 	x : (FALSE => TRUE) and (TRUE => FALSE), y : TRUE and (TRUE => FALSE), z : TRUE and FALSE
# 12	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 13	modus_ponens	14, 15	|- (((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE))) and ((TRUE and (TRUE => FALSE)) = (TRUE and FALSE))
# 14	modus_ponens	16, 17	|- ((TRUE and (TRUE => FALSE)) = (TRUE and FALSE)) => ((((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE))) and ((TRUE and (TRUE => FALSE)) = (TRUE and FALSE)))
# 15	instantiation	20, 18	|- (TRUE and (TRUE => FALSE)) = (TRUE and FALSE)
# 	f(_a) : TRUE and _a, x : TRUE => FALSE, y : FALSE
# 16	instantiation	19	|- (((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE))) => (((TRUE and (TRUE => FALSE)) = (TRUE and FALSE)) => ((((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE))) and ((TRUE and (TRUE => FALSE)) = (TRUE and FALSE))))
# 	A : ((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE)), B : (TRUE and (TRUE => FALSE)) = (TRUE and FALSE)
# 17	instantiation	20, 21	|- ((FALSE => TRUE) and (TRUE => FALSE)) = (TRUE and (TRUE => FALSE))
# 	f(_a) : _a and (TRUE => FALSE), x : FALSE => TRUE, y : TRUE
# 18	theorem		|- (TRUE => FALSE) = FALSE
# 	proveit.logic.booleans.implication.implies_t_f
# 19	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 20	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 21	theorem		|- (FALSE => TRUE) = TRUE
# 	proveit.logic.booleans.implication.implies_f_t
