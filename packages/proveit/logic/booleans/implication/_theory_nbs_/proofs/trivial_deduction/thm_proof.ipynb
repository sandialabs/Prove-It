# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#trivial_deduction">trivial_deduction</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B

# %%
# %proving trivial_deduction
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="trivial_deduction">trivial_deduction:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6587582e5428dc85a87135f0f89dfac2b2a58c8d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/784f04256a2ecc5f0e75a60b9e30ed3ceb8bbc400/dependencies.ipynb">dependencies</a>)<br>
# trivial_deduction may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A.prove(assumptions=[A]).as_implication(B)
# Out:
# {A} |- B => A

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.trivial_deduction is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B} (A => (B => A))
# 1	deduction	2	|- A => (B => A)
# 2	deduction	3	{A} |- B => A
# 3	assumption		{A} |- A
