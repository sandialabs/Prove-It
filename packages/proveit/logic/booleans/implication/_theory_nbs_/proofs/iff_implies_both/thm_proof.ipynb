# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_implies_both">iff_implies_both</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving iff_implies_both
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_implies_both">iff_implies_both:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3c6e0b4787742310cecf69dbfd1aff085063ff4f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e44ad3c2b3ec1dfe39690a5b149c2668600bfa300/dependencies.ipynb">dependencies</a>)<br>

# %%
A_iff_B = iff_implies_both.condition
# Out:
# <strong id="A_iff_B">A_iff_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/354ec164e0e28f03ef1fb1858764e0da4a36a45b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_iff_B__def = A_iff_B.definition()
# Out:
# <strong id="A_iff_B__def">A_iff_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_iff_implies_both/45fb3ef551a5f7c3434c79709be6ecfbbf3761960/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/6a1fb7a4625d5d14b9fb08d72f3e6598f52293a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_iff_B__def.derive_right_via_equality(assumptions=[A_iff_B])
# Out:
# {A <=> B} |- (A => B) and (B => A)
# iff_implies_both may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_implies_both is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A <=> B} ((A => B) and (B => A))
# 1	instantiation	2, 3	{A <=> B} |- (A => B) and (B => A)
# 	P : A <=> B, Q : (A => B) and (B => A)
# 2	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 3	modus_ponens	4, 5	{A <=> B} |- (A <=> B) and ((A <=> B) = ((A => B) and (B => A)))
# 4	modus_ponens	6, 7	{A <=> B} |- ((A <=> B) = ((A => B) and (B => A))) => ((A <=> B) and ((A <=> B) = ((A => B) and (B => A))))
# 5	instantiation	8	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 6	instantiation	9	|- (A <=> B) => (((A <=> B) = ((A => B) and (B => A))) => ((A <=> B) and ((A <=> B) = ((A => B) and (B => A)))))
# 	A : A <=> B, B : (A <=> B) = ((A => B) and (B => A))
# 7	assumption		{A <=> B} |- A <=> B
# 8	theorem		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def_quantified
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
