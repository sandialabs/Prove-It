# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#eq_from_iff">eq_from_iff</a> theorem
# ========

# %%
import proveit
# we need to import these to derive their side-effects:
from proveit.logic.booleans.implication import true_iff_false_negated, false_iff_true_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving eq_from_iff
# Out:
# eq_from_iff: forall_{A, B in BOOLEAN | A <=> B} (A = B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | A <=> B} (A = B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A <=> B} (A = B)]] \\  => [forall_{A, B in BOOLEAN | A <=> B} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and (A <=> B), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A <=> B} (A = B)]
# 	P(A) : forall_{B in BOOLEAN | A <=> B} (A = B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	12, 13, 14	|- {A = B if A in BOOLEAN ,  (B in BOOLEAN) and (A <=> B). = {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A <=> B.
# 	n : 2, a : A = B, Q : A in BOOLEAN, R : (B in BOOLEAN, A <=> B)
# 8	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 9	instantiation	15, 16, 17	|- forall_{B in BOOLEAN | TRUE <=> B} (TRUE = B)
# 	P(B) : TRUE = B, Q(B) : TRUE <=> B, A : B
# 10	generalizaton	18	|- forall_{B in BOOLEAN | FALSE <=> B} (FALSE = B)
# 11	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 12	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 13	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 14	instantiation	19	|- |(B in BOOLEAN, A <=> B)| = |(1, ..k.., 2)|
# 	a : B in BOOLEAN, b : A <=> B
# 15	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 16	deduction	20	|- (TRUE <=> TRUE) => (TRUE = TRUE)
# 17	instantiation	21, 22	|- (TRUE <=> FALSE) => (TRUE = FALSE)
# 	A : TRUE <=> FALSE, B : TRUE = FALSE
# 18	instantiation	23, 24	{B in BOOLEAN, FALSE <=> B} |- FALSE = B
# 	x : B, y : FALSE
# 19	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 20	theorem		|- TRUE = TRUE
# 	proveit.logic.booleans.true_eq_true
# 21	theorem		|- forall_{A, B | A != TRUE} (A => B)
# 	proveit.logic.booleans.implication.untrue_antecedent_implication
# 22	instantiation	25, 26	|- (TRUE <=> FALSE) != TRUE
# 	A : TRUE <=> FALSE
# 23	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 24	instantiation	27, 28	{B in BOOLEAN, FALSE <=> B} |- B = FALSE
# 	A : B
# 25	theorem		|- forall_{A | [not](A)} (A != TRUE)
# 	proveit.logic.booleans.negation.untrue_from_negation
# 26	theorem		|- [not](TRUE <=> FALSE)
# 	proveit.logic.booleans.implication.true_iff_false_negated
# 27	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.booleans.negation.negation_elim
# 28	instantiation	29, 30, 31	{B in BOOLEAN, FALSE <=> B} |- [not](B)
# 	A : B
# 29	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 30	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 31	instantiation	32, 33	{FALSE <=> B} |- B => FALSE
# 	A : FALSE, B : B
# 32	theorem		|- forall_{A, B | A <=> B} (B => A)
# 	proveit.logic.booleans.implication.iff_implies_left
# 33	assumption		{FALSE <=> B} |- FALSE <=> B
