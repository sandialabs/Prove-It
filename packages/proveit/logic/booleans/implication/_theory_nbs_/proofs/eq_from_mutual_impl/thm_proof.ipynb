# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#eq_from_mutual_impl">eq_from_mutual_impl</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving eq_from_mutual_impl
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="eq_from_mutual_impl">eq_from_mutual_impl:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f10a52b8e7a4007b2382936a509145bd26bf96f00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/07a08a70dfd2838dc22520d3e64efd00ac4a6e300/dependencies.ipynb">dependencies</a>)<br>
# eq_from_mutual_impl may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.eq_from_mutual_impl has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | A => B, B => A} (A = B)
# 1	instantiation	3, 4, 5*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A => B, B => A} (A = B)]] \\  => [forall_{A, B in BOOLEAN | A => B, B => A} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and (A => B) and (B => A), x_{1} : A, y_{1} : B
# 2	instantiation	6, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A => B, B => A} (A = B)]
# 	P(A) : forall_{B in BOOLEAN | A => B, B => A} (A = B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 10, 11	|- {A = B if A in BOOLEAN ,  (B in BOOLEAN) and (A => B) and (B => A). \\  = {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A => B ,  B => A.
# 	n : 3, a : A = B, Q : A in BOOLEAN, R : (B in BOOLEAN, A => B, B => A)
# 6	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 7	generalization	12	|- forall_{B in BOOLEAN | TRUE => B, B => TRUE} (TRUE = B)
# 8	generalization	13	|- forall_{B in BOOLEAN | FALSE => B, B => FALSE} (FALSE = B)
# 9	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, R_{2}, ..., R_{n}} ({a if Q ,  R_{1} and  R_{2} and  ... and  R_{n}. \\  = {a if Q, R_{1} ,  R_{2} ,  ... ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 10	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 11	instantiation	14	|- |(B in BOOLEAN, A => B, B => A)| = |(1, 2, ..., 3)|
# 	a : B in BOOLEAN, b : A => B, c : B => A
# 12	instantiation	16, 15	{TRUE => B} |- TRUE = B
# 	x : B, y : TRUE
# 13	instantiation	16, 17	{B in BOOLEAN, B => FALSE} |- FALSE = B
# 	x : B, y : FALSE
# 14	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 15	instantiation	18, 19	{TRUE => B} |- B = TRUE
# 	A : B
# 16	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 17	instantiation	20, 21	{B in BOOLEAN, B => FALSE} |- B = FALSE
# 	A : B
# 18	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 19	modus ponens	22, 23	{TRUE => B} |- B
# 20	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.booleans.negation.negation_elim
# 21	instantiation	24, 25, 26	{B in BOOLEAN, B => FALSE} |- [not](B)
# 	A : B
# 22	assumption		{TRUE => B} |- TRUE => B
# 23	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
# 24	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 25	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 26	assumption		{B => FALSE} |- B => FALSE
