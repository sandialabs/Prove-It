# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#eq_from_mutual_impl">eq_from_mutual_impl</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans import fold_forall_over_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving eq_from_mutual_impl
# Out:
# eq_from_mutual_impl: forall_{A, B in BOOLEAN | A => B, B => A} (A = B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | A => B, B => A} (A = B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A => B, B => A} (A = B)]] \\  => [forall_{A, B in BOOLEAN | A => B, B => A} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and (A => B) and (B => A), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A => B, B => A} (A = B)]
# 	P(A) : forall_{B in BOOLEAN | A => B, B => A} (A = B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	24, 12, 13	|- {A = B if A in BOOLEAN ,  (B in BOOLEAN) and (A => B) and (B => A). = {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A => B ,  B => A.
# 	n : 3, a : A = B, Q : A in BOOLEAN, R : (B in BOOLEAN, A => B, B => A)
# 8	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 9	instantiation	14, 15, 16, 17*	|- forall_{B in BOOLEAN | TRUE => B, B => TRUE} (TRUE = B)
# 	P(B) : TRUE = B, Q(B) : (TRUE => B) and (B => TRUE), A : B
# 10	generalizaton	18	|- forall_{B in BOOLEAN | FALSE => B, B => FALSE} (FALSE = B)
# 11	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 12	instantiation	32, 33, 19	|- 3 in Natural
# 	A : NaturalPos, B : Natural, x : 3
# 13	instantiation	20	|- |(B in BOOLEAN, A => B, B => A)| = |(1, ..k.., 3)|
# 	a : B in BOOLEAN, b : A => B, c : B => A
# 14	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 15	deduction	21	|- ((TRUE => TRUE) and (TRUE => TRUE)) => (TRUE = TRUE)
# 16	instantiation	22, 23	|- ((TRUE => FALSE) and (FALSE => TRUE)) => (TRUE = FALSE)
# 	A : (TRUE => FALSE) and (FALSE => TRUE), B : TRUE = FALSE
# 17	instantiation	24, 25, 26	|- {TRUE = B if B in BOOLEAN ,  (TRUE => B) and (B => TRUE). = {TRUE = B if B in BOOLEAN ,  TRUE => B ,  B => TRUE.
# 	n : 2, a : TRUE = B, Q : B in BOOLEAN, R : (TRUE => B, B => TRUE)
# 18	instantiation	27, 28	{B in BOOLEAN, B => FALSE} |- FALSE = B
# 	x : B, y : FALSE
# 19	conjecture		|- 3 in NaturalPos
# 20	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, ..k.., 3)|)
# 21	theorem		|- TRUE = TRUE
# 	proveit.logic.booleans.true_eq_true
# 22	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 23	instantiation	29, 30, 31	|- [not]((TRUE => FALSE) and (FALSE => TRUE))
# 	A : TRUE => FALSE, B : FALSE => TRUE
# 24	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 25	instantiation	32, 33, 34	|- 2 in Natural
# 	A : NaturalPos, B : Natural, x : 2
# 26	instantiation	35	|- |(TRUE => B, B => TRUE)| = |(1, ..k.., 2)|
# 	a : TRUE => B, b : B => TRUE
# 27	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 28	instantiation	36, 37	{B in BOOLEAN, B => FALSE} |- B = FALSE
# 	A : B
# 29	theorem		|- forall_{A, B | [not](A), B} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_right_but_not_left
# 30	theorem		|- [not](TRUE => FALSE)
# 	proveit.logic.booleans.implication.true_implies_false_negated
# 31	theorem		|- FALSE => TRUE
# 	proveit.logic.booleans.implication.false_implies_true
# 32	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 33	conjecture		|- NaturalPos proper_subset Natural
# 34	conjecture		|- 2 in NaturalPos
# 35	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 36	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.booleans.negation.negation_elim
# 37	instantiation	38, 39, 40	{B in BOOLEAN, B => FALSE} |- [not](B)
# 	A : B
# 38	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 39	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 40	assumption		{B => FALSE} |- B => FALSE
