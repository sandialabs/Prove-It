# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#implication_closure">implication_closure</a> theorem
# ========

# %%
import proveit
# we need to import true_implies_false_negated to derive it's side-effects:
from proveit.logic.booleans.implication import true_implies_false_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving implication_closure
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="implication_closure">implication_closure:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/cd9335192baff757d9f342ccaf7413444c1474cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/51b769d88aeae04ad7b371773fa6f8dd8627cd0c0/dependencies.ipynb">dependencies</a>)<br>
# implication_closure may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.implication_closure has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A => B) in BOOLEAN)
# 1	instantiation	3, 4	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A => B) in BOOLEAN)]] \\  => [forall_{A, B in BOOLEAN} ((A => B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A => B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, x_{1} : A, y_{1} : B
# 2	instantiation	9, 5, 6	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A => B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A => B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 7, 8	|- forall_{B in BOOLEAN} ((TRUE => B) in BOOLEAN)
# 	P(B) : (TRUE => B) in BOOLEAN, A : B
# 6	instantiation	9, 10, 11	|- forall_{B in BOOLEAN} ((FALSE => B) in BOOLEAN)
# 	P(B) : (FALSE => B) in BOOLEAN, A : B
# 7	instantiation	17, 12	|- (TRUE => TRUE) in BOOLEAN
# 	A : TRUE => TRUE
# 8	instantiation	13, 14	|- (TRUE => FALSE) in BOOLEAN
# 	A : TRUE => FALSE
# 9	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 10	instantiation	17, 15	|- (FALSE => TRUE) in BOOLEAN
# 	A : FALSE => TRUE
# 11	instantiation	17, 16	|- (FALSE => FALSE) in BOOLEAN
# 	A : FALSE => FALSE
# 12	theorem		|- TRUE => TRUE
# 	proveit.logic.booleans.implication.true_implies_true
# 13	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 14	instantiation	17, 18	|- [not](TRUE => FALSE) in BOOLEAN
# 	A : [not](TRUE => FALSE)
# 15	theorem		|- FALSE => TRUE
# 	proveit.logic.booleans.implication.false_implies_true
# 16	theorem		|- FALSE => FALSE
# 	proveit.logic.booleans.implication.false_implies_false
# 17	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 18	theorem		|- [not](TRUE => FALSE)
# 	proveit.logic.booleans.implication.true_implies_false_negated
