# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#iff_transitivity">iff_transitivity</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving iff_transitivity
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="iff_transitivity">iff_transitivity:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/63714da37dea0d689fc9a4630b19edab3b2f9ec90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ddb7dce25b20b8e99745ca88e8e3f24c5b00bfae0/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.iff_transitivity is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C | A <=> B, B <=> C} (A <=> C)
# 1	instantiation	2, 3	{(A <=> B) and (B <=> C)} |- A <=> C
# 	A : A, B : C
# 2	theorem		|- forall_{A, B | A => B, B => A} (A <=> B)
# 	proveit.logic.booleans.implication.iff_intro
# 3	modus_ponens	4, 5	{(A <=> B) and (B <=> C)} |- (A => C) and (C => A)
# 4	modus_ponens	6, 7	{(A <=> B) and (B <=> C)} |- (C => A) => ((A => C) and (C => A))
# 5	deduction	8	{(A <=> B) and (B <=> C)} |- C => A
# 6	instantiation	9	|- (A => C) => ((C => A) => ((A => C) and (C => A)))
# 	A : A => C, B : C => A
# 7	deduction	10	{(A <=> B) and (B <=> C)} |- A => C
# 8	modus_ponens	11, 12	{(A <=> B) and (B <=> C), C} |- A
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	modus_ponens	13, 14	{(A <=> B) and (B <=> C), A} |- C
# 11	instantiation	19, 22	{(A <=> B) and (B <=> C)} |- B => A
# 	A : A, B : B
# 12	modus_ponens	15, 16	{(A <=> B) and (B <=> C), C} |- B
# 13	instantiation	21, 20	{(A <=> B) and (B <=> C)} |- B => C
# 	A : B, B : C
# 14	modus_ponens	17, 18	{(A <=> B) and (B <=> C), A} |- B
# 15	instantiation	19, 20	{(A <=> B) and (B <=> C)} |- C => B
# 	A : B, B : C
# 16	assumption		{C} |- C
# 17	instantiation	21, 22	{(A <=> B) and (B <=> C)} |- A => B
# 	A : A, B : B
# 18	assumption		{A} |- A
# 19	theorem		|- forall_{A, B | A <=> B} (B => A)
# 	proveit.logic.booleans.implication.iff_implies_left
# 20	instantiation	23, 25	{(A <=> B) and (B <=> C)} |- B <=> C
# 	A : A <=> B, B : B <=> C
# 21	theorem		|- forall_{A, B | A <=> B} (A => B)
# 	proveit.logic.booleans.implication.iff_implies_right
# 22	instantiation	24, 25	{(A <=> B) and (B <=> C)} |- A <=> B
# 	A : A <=> B, B : B <=> C
# 23	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 24	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 25	assumption		{(A <=> B) and (B <=> C)} |- (A <=> B) and (B <=> C)
