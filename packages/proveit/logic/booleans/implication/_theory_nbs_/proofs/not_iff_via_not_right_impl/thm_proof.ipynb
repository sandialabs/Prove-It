# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_iff_via_not_right_impl">not_iff_via_not_right_impl</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Iff

# %%
# %proving not_iff_via_not_right_impl
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_iff_via_not_right_impl">not_iff_via_not_right_impl:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e7cd6046acecae1b333ff18e425fc675ea4341d80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/92cd58d2a7d244e8f8251ebc313064ba07de6a3c0/dependencies.ipynb">dependencies</a>)<br>
# not_iff_via_not_right_impl may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = not_iff_via_not_right_impl.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/4517770f2e92eff37f0ade8147ac32e5dffa674b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_iff_B = Iff(A, B)
# Out:
# <strong id="A_iff_B">A_iff_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/354ec164e0e28f03ef1fb1858764e0da4a36a45b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
iff_A_B_def = A_iff_B.definition()
# Out:
# <strong id="iff_A_B_def">iff_A_B_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/adf2e0d88a8843cb274514f767d387d8595a7a630/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/6a1fb7a4625d5d14b9fb08d72f3e6598f52293a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_disproven = iff_A_B_def.rhs.disprove()
# Out:
# <strong id="rhs_disproven">rhs_disproven:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/772185474b8a5bfd5acbd869d8a83b52f0a4f2b80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/a3f2a9562f69c67708224cb49d4dd68e9b3e497f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/1530c9bc9e7419681a4e77d36e034d191f62b62f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
iff_A_B_def.sub_left_side_into(rhs_disproven)
# Out:
# {[not](A => B)} |- [not](A <=> B)

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.not_iff_via_not_right_impl is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A => B)} [not](A <=> B)
# 1	instantiation	2, 3	{[not](A => B)} |- [not](A <=> B)
# 	P(_a) : [not](_a), x : A <=> B, y : (A => B) and (B => A)
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{[not](A => B)} |- [not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))
# 4	modus_ponens	6, 7	{[not](A => B)} |- ((A <=> B) = ((A => B) and (B => A))) => ([not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A))))
# 5	instantiation	8	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 6	instantiation	9	|- [not]((A => B) and (B => A)) => (((A <=> B) = ((A => B) and (B => A))) => ([not]((A => B) and (B => A)) and ((A <=> B) = ((A => B) and (B => A)))))
# 	A : [not]((A => B) and (B => A)), B : (A <=> B) = ((A => B) and (B => A))
# 7	instantiation	10, 11	{[not](A => B)} |- [not]((A => B) and (B => A))
# 	A : A => B, B : B => A
# 8	theorem		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def_quantified
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	theorem		|- forall_{A, B | [not](A)} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_not_left
# 11	assumption		{[not](A => B)} |- [not](A => B)
