# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_iff_via_not_right_impl">not_iff_via_not_right_impl</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import And, Implies, Iff, Not
from proveit.logic.booleans.conjunction import false_and_true_negated
from proveit.logic.booleans.implication import negated_reflex
theory = proveit.Theory() # the theorem's theory

# %%
# %proving not_iff_via_not_right_impl
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_iff_via_not_right_impl">not_iff_via_not_right_impl:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e7cd6046acecae1b333ff18e425fc675ea4341d80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2f87b81f53c9fd549dbe360575d3ecbb9b25b6fc0/dependencies.ipynb">dependencies</a>)<br>
# not_iff_via_not_right_impl may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = not_iff_via_not_right_impl.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/4517770f2e92eff37f0ade8147ac32e5dffa674b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
false_and_true_negated
# Out:
# |- [not](FALSE and TRUE)

# %%
not__AimplB_and_T = false_and_true_negated.inner_expr().operand.operands[0].substitute(
    Implies(A, B))
# Out:
# <strong id="not__AimplB_and_T">not__AimplB_and_T:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/772185474b8a5bfd5acbd869d8a83b52f0a4f2b80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/6d4d6e641662a594915d594ea44c15b1dd0f9f800/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/47f20e8f2f69cb631adbcedeba18928cc95f9df80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not__AimplB_and_BimplA = not__AimplB_and_T.inner_expr().operand.operands[1].substitute(
    Implies(B, A))
# Out:
# <strong id="not__AimplB_and_BimplA">not__AimplB_and_BimplA:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/772185474b8a5bfd5acbd869d8a83b52f0a4f2b80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/35069fe751242e334ca7e9d38810d045a2c09e470/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/f7f183ad4bcd4e28799d9125a8933b526a62f6990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_iff_B__def = Iff(A, B).definition(assumptions=[])
# Out:
# <strong id="A_iff_B__def">A_iff_B__def:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_iff_via_not_right_impl/b7aba8a005f5ba408b795ab73886a80c28ee71c20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/6a1fb7a4625d5d14b9fb08d72f3e6598f52293a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_iff_B__def.sub_left_side_into(not__AimplB_and_BimplA)
# Out:
# {[not](A => B)} |- [not](A <=> B)

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.not_iff_via_not_right_impl has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A => B)} [not](A <=> B)
# 1	instantiation	2, 3, 4	{[not](A => B)} |- [not](A <=> B)
# 	P(_a) : [not](_a), x : A <=> B, y : (A => B) and (B => A)
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7	{[not](A => B)} |- [not]((A => B) and (B => A))
# 	P(_a) : [not]((A => B) and _a), x : B => A
# 4	instantiation	8	|- (A <=> B) = ((A => B) and (B => A))
# 	A : A, B : B
# 5	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 6	instantiation	9, 10, 12	{[not](A => B)} |- [not]((A => B) and TRUE)
# 	P(_a) : [not](_a and TRUE), x : A => B
# 7	instantiation	11, 12	{[not](A => B)} |- B => A
# 	A : A, B : B
# 8	axiom		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def
# 9	theorem		|- forall_{P, x | P(FALSE), [not](x)} P(x)
# 	proveit.logic.equality.substitute_falsehood
# 10	theorem		|- [not](FALSE and TRUE)
# 	proveit.logic.booleans.conjunction.false_and_true_negated
# 11	theorem		|- forall_{A, B | [not](A => B)} (B => A)
# 	proveit.logic.booleans.implication.negated_reflex
# 12	assumption		{[not](A => B)} |- [not](A => B)
