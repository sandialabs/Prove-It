# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#modus_tollens_affirmation">modus_tollens_affirmation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not

# %%
# %proving modus_tollens_affirmation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="modus_tollens_affirmation">modus_tollens_affirmation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1ce6b5a9cfeaa7e592ee9d926bcb96b4451904f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2110f148f1324e91e187a084dd3861f2464ff2980/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = modus_tollens_affirmation.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_modus_tollens_affirmation/5a0d9e45c3e3813a1ff908e140fe7cb8831fe1040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# Prove A via the contradition, under the assumptions, 
# of B and Not(B) simultaneously being true when A is false.
Not(B).affirm_via_contradiction(A)
# Out:
# {([not](A) => B) and [not](B)} |- A

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.modus_tollens_affirmation is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A} [forall_{B | [not](A) => B, [not](B)} A]
# 1	instantiation	2, 3	{([not](A) => B) and [not](B)} |- A
# 	A : A
# 2	theorem		|- forall_{A | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	deduction	4	{([not](A) => B) and [not](B)} |- [not](A) => FALSE
# 4	modus_ponens	5, 6	{([not](A) => B) and [not](B), [not](A)} |- FALSE
# 5	instantiation	7, 8	{([not](A) => B) and [not](B)} |- B => FALSE
# 	A : B
# 6	modus_ponens	9, 10	{([not](A) => B) and [not](B), [not](A)} |- B
# 7	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 8	instantiation	11, 13	{([not](A) => B) and [not](B)} |- [not](B)
# 	A : [not](A) => B, B : [not](B)
# 9	instantiation	12, 13	{([not](A) => B) and [not](B)} |- [not](A) => B
# 	A : [not](A) => B, B : [not](B)
# 10	assumption		{[not](A)} |- [not](A)
# 11	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 12	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 13	assumption		{([not](A) => B) and [not](B)} |- ([not](A) => B) and [not](B)
