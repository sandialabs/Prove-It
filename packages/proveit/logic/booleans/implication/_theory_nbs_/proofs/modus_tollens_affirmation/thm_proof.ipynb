# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#modus_tollens_affirmation">modus_tollens_affirmation</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic.booleans.negation import negation_contradiction
from proveit.logic import Not
theory = proveit.Theory() # the theorem's theory

# %%
# %proving modus_tollens_affirmation
# Out:
# modus_tollens_affirmation: forall_{A in BOOLEAN} [forall_{B | [not](A) => B, [not](B)} A]

# %%
defaults.assumptions = modus_tollens_affirmation.all_conditions()
# Out:
# defaults.assumptions: (A in BOOLEAN, [not](A) => B, [not](B))

# %%
# Prove A via the contradition, under the assumptions, 
# of B and Not(B) simultaneously being true when A is false.
Not(B).affirm_via_contradiction(A)
# Out:
# {A in BOOLEAN, [not](A) => B, [not](B)} |- A

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A in BOOLEAN} [forall_{B | [not](A) => B, [not](B)} A]
# 1	instantiation	2, 3, 4	{A in BOOLEAN, [not](A) => B, [not](B)} |- A
# 	A : A
# 2	axiom		|- forall_{A in BOOLEAN | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 4	deduction	5	{[not](A) => B, [not](B)} |- [not](A) => FALSE
# 5	instantiation	6, 7, 8	{[not](A) => B, [not](A), [not](B)} |- FALSE
# 	A : B
# 6	theorem		|- forall_{A | A, [not](A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 7	modus ponens	9, 10	{[not](A) => B, [not](A)} |- B
# 8	assumption		{[not](B)} |- [not](B)
# 9	assumption		{[not](A) => B} |- [not](A) => B
# 10	assumption		{[not](A)} |- [not](A)
