# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#implies_t_f">implies_t_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.negation import not_t

# %%
# %proving implies_t_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="implies_t_f">implies_t_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/aac2148bd08007417c156444654d2678db44244f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9276d6ec2a25c105e0f3bf5f6316bb9273c791210/dependencies.ipynb">dependencies</a>)<br>

# %%
not_t
# Out:
# |- [not](TRUE) = FALSE

# %%
not_t.inner_expr().lhs.define()
# Out:
# |- (TRUE => FALSE) = FALSE
# implies_t_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.implies_t_f is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- (TRUE => FALSE) = FALSE
# 1	modus_ponens	3, 4	|- ([not](TRUE) = (TRUE => FALSE)) => ((TRUE => FALSE) = FALSE)
# 2	instantiation	5	|- [not](TRUE) = (TRUE => FALSE)
# 	A : TRUE
# 3	instantiation	6	|- ([not](TRUE) = FALSE) => (([not](TRUE) = (TRUE => FALSE)) => ((TRUE => FALSE) = FALSE))
# 	P(_a) : _a = FALSE, x : [not](TRUE), y : TRUE => FALSE
# 4	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 5	theorem		|- forall_{A} ([not](A) = (A => FALSE))
# 	proveit.logic.booleans.negation.not_def_quantified
# 6	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
