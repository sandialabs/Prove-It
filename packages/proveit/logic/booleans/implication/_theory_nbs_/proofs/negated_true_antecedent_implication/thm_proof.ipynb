# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#negated_true_antecedent_implication">negated_true_antecedent_implication</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not
from proveit.logic.booleans.implication import falsified_antecedent_implication

# %%
# %proving negated_true_antecedent_implication
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="negated_true_antecedent_implication">negated_true_antecedent_implication:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/275edaac48a38e1d57d0f035c226176cb99d5ab30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/50785657089bf0c08207853c7f1b88afca982cc80/dependencies.ipynb">dependencies</a>)<br>
# negated_true_antecedent_implication may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.negated_true_antecedent_implication is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A} ([not](A) => B)
# 1	instantiation	2, 3	{A} |- [not](A) => B
# 	A : [not](A), B : B
# 2	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 3	instantiation	4, 5	{A} |- [not]([not](A))
# 	A : A
# 4	theorem		|- forall_{A | A} [not]([not](A))
# 	proveit.logic.booleans.negation.double_negation_intro
# 5	assumption		{A} |- A
