# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#modus_tollens_denial">modus_tollens_denial</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic.booleans.negation import negation_contradiction
from proveit.logic import FALSE, Not, Equals
#from proveit.logic.booleans import from_not_false
#from proveit.logic.booleans.implication import modus_tollens_affirmation
theory = proveit.Theory() # the theorem's theory

# %%
# %proving modus_tollens_denial
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="modus_tollens_denial">modus_tollens_denial:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6e585db1db364b78f6e359174ec389300c03caad0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d389baab15ba021c1a3765cb6fdf0f512717a5700/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = modus_tollens_denial.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_modus_tollens_denial/14be8931602b6f919a51a2e6ab22eeb80bf23a970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# Prove Not(A) via the contradition, under the assumptions, 
# of B and Not(B) simultaneously being true when A is true.
Not(B).deny_via_contradiction(A)
# Out:
# {A in BOOLEAN, A => B, [not](B)} |- [not](A)
# modus_tollens_denial may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.modus_tollens_denial has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 1	instantiation	2, 3, 4	{A in BOOLEAN, A => B, [not](B)} |- [not](A)
# 	A : A
# 2	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 3	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 4	deduction	5	{A => B, [not](B)} |- A => FALSE
# 5	instantiation	6, 7, 8	{A => B, A, [not](B)} |- FALSE
# 	A : B
# 6	theorem		|- forall_{A | A, [not](A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 7	modus ponens	9, 10	{A => B, A} |- B
# 8	assumption		{[not](B)} |- [not](B)
# 9	assumption		{A => B} |- A => B
# 10	assumption		{A} |- A
