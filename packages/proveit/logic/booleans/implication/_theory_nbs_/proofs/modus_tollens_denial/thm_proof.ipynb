# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#modus_tollens_denial">modus_tollens_denial</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not

# %%
# %proving modus_tollens_denial
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="modus_tollens_denial">modus_tollens_denial:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/4ac90d9bf3df329aa6a4a0e5bc6f49153a3132a10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a23e3c8b8b631a31229b2b23652272437e1c03630/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = modus_tollens_denial.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_modus_tollens_denial/8618d35ed49759dbd4e1bf23b8d4a446bb376fc60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# Prove Not(A) via the contradition, under the assumptions, 
# of B and Not(B) simultaneously being true when A is true.
Not(B).deny_via_contradiction(A)
# Out:
# {(A => B) and [not](B)} |- [not](A)

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.modus_tollens_denial is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A} [forall_{B | A => B, [not](B)} [not](A)]
# 1	instantiation	2, 3	{(A => B) and [not](B)} |- [not](A)
# 	A : A
# 2	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 3	deduction	4	{(A => B) and [not](B)} |- A => FALSE
# 4	modus_ponens	5, 6	{(A => B) and [not](B), A} |- FALSE
# 5	instantiation	7, 8	{(A => B) and [not](B)} |- B => FALSE
# 	A : B
# 6	modus_ponens	9, 10	{(A => B) and [not](B), A} |- B
# 7	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 8	instantiation	11, 13	{(A => B) and [not](B)} |- [not](B)
# 	A : A => B, B : [not](B)
# 9	instantiation	12, 13	{(A => B) and [not](B)} |- A => B
# 	A : A => B, B : [not](B)
# 10	assumption		{A} |- A
# 11	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 12	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 13	assumption		{(A => B) and [not](B)} |- (A => B) and [not](B)
