# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#false_antecedent_implication">false_antecedent_implication</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import FALSE
from proveit.logic import Implies
from proveit.logic.booleans import double_negation_elim_via_implication
from proveit.logic.booleans.implication import trivial_deduction
from proveit.logic.booleans.negation import not_def

# %%
# %proving false_antecedent_implication
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="false_antecedent_implication">false_antecedent_implication:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/63e5aff070e61d36fd7aeaf4ffbef8a63dd87bee0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2feb8d57f18a1fd8e86182b7a9fcb6402e81a7870/dependencies.ipynb">dependencies</a>)<br>
# false_antecedent_implication may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
double_negation_elim_via_implication
# Out:
# |- forall_{A} ([not]([not](A)) => A)

# %%
double_neg_impl_inst = double_negation_elim_via_implication.instantiate()
# Out:
# <strong id="double_neg_impl_inst">double_neg_impl_inst:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/3562bbf0edcf52998972b4e807200c3e702cf7a50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/axioms/d76a73728b60f39ae7f18a5932345f34adbb33010/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_def
# Out:
# |- [not] = [A -> (A => FALSE)]

# %%
double_neg_expanded = not_def.sub_right_side_into(double_neg_impl_inst)
# Out:
# <strong id="double_neg_expanded">double_neg_expanded:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/550251680aa1dbf820bd2da2397bbdb39eb098a80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/779e5fed97e96119f25f925c6793902b07b3f1310/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
trivial_deduction
# Out:
# |- forall_{A, B} (A => (B => A))

# %%
trivial_deduction_inst = trivial_deduction.instantiate({A:FALSE, B:Implies(A, FALSE)})
# Out:
# <strong id="trivial_deduction_inst">trivial_deduction_inst:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/822d216f6a39d097d4dde1f2b1e65a010aff119c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/4edc02feae24187da31ccc83d962aeddde8f656c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_F__impl_F = trivial_deduction_inst.derive_consequent(assumptions=[FALSE])
# Out:
# <strong id="A_impl_F__impl_F">A_impl_F__impl_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/a1ab8aacb66bf1c7ef59091640cafda964e9cb2d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/d437cd8bdb421b5f6f3586a589c4c27200604a7a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_assuming_F = double_neg_expanded.derive_consequent(assumptions=[FALSE])
# Out:
# <strong id="A_assuming_F">A_assuming_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_false_antecedent_implication/868d91e4bd5cd3427f05d83e078d9c901c70eabb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_assuming_F.as_implication(FALSE)
# Out:
# |- FALSE => A

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.false_antecedent_implication is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A} (FALSE => A)
# 1	deduction	2	|- FALSE => A
# 2	modus_ponens	3, 4	{FALSE} |- A
# 3	modus_ponens	5, 6	|- ((A => FALSE) => FALSE) => A
# 4	modus_ponens	7, 8	{FALSE} |- (A => FALSE) => FALSE
# 5	modus_ponens	9, 10	|- ([not] = [A -> (A => FALSE)]) => (((A => FALSE) => FALSE) => A)
# 6	basic_definition		|- [not] = [A -> (A => FALSE)]
# 	proveit.logic.booleans.negation.not_def
# 7	instantiation	11	|- FALSE => ((A => FALSE) => FALSE)
# 	A : FALSE, B : A => FALSE
# 8	assumption		{FALSE} |- FALSE
# 9	instantiation	12	|- ([not]([not](A)) => A) => (([not] = [A -> (A => FALSE)]) => (((A => FALSE) => FALSE) => A))
# 	P(_a) : _a(_a(A)) => A, x : not, y(A) : A => FALSE
# 10	instantiation	13	|- [not]([not](A)) => A
# 	A : A
# 11	theorem		|- forall_{A, B} (A => (B => A))
# 	proveit.logic.booleans.implication.trivial_deduction
# 12	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 13	axiom		|- forall_{A} ([not]([not](A)) => A)
# 	proveit.logic.booleans.double_negation_elim_via_implication
