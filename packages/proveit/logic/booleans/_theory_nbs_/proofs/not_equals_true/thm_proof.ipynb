# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_equals_true">not_equals_true</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic import Equals, TRUE

# %%
# %proving not_equals_true
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_equals_true">not_equals_true:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b81279305ef5bf92e6ddf38d9965bf29373d3b1c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/cfb9a5891d6b3ee11f957cb97ed3e5c7edfbfefa0/dependencies.ipynb">dependencies</a>)<br>
# not_equals_true may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_A = not_equals_true.condition
# Out:
# <strong id="not_A">not_A:</strong> <a class="ProveItLink" href="../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_A.deny_via_contradiction(Equals(A, TRUE), assumptions=[not_A])
# Out:
# {[not](A)} |- [not](A = TRUE)

# %%
# %qed
# Out:
# proveit.logic.booleans.not_equals_true is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | [not](A)} (A != TRUE)
# 1	instantiation	2, 3	{[not](A)} |- A != TRUE
# 	x : A, y : TRUE
# 2	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 3	instantiation	4, 5	{[not](A)} |- [not](A = TRUE)
# 	A : A = TRUE
# 4	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 5	deduction	6	{[not](A)} |- (A = TRUE) => FALSE
# 6	modus_ponens	7, 8	{[not](A), A = TRUE} |- FALSE
# 7	instantiation	9, 10	{[not](A)} |- A => FALSE
# 	A : A
# 8	instantiation	11, 12	{A = TRUE} |- A
# 	A : A
# 9	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 10	assumption		{[not](A)} |- [not](A)
# 11	theorem		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 12	assumption		{A = TRUE} |- A = TRUE
