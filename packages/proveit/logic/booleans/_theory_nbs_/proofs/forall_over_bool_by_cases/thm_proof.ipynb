# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#forall_over_bool_by_cases">forall_over_bool_by_cases</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import PofA
from proveit.logic import PofTrue, PofFalse
from proveit.logic.booleans.disjunction import singular_constructive_dilemma
theory = proveit.Theory() # the theorem's theory

# %%
# %proving forall_over_bool_by_cases
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="forall_over_bool_by_cases">forall_over_bool_by_cases:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6d327d2140f1f0c2a937cb448134f4763a4374070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d2018f319547b6ba80dc07fa7bab3517da687ca40/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions=forall_over_bool_by_cases.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_forall_over_bool_by_cases/4937796961a2a32ecf91ca99be4dfc121445cd8f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Ain_bool=defaults.assumptions[2]
# Out:
# <strong id="Ain_bool">Ain_bool:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a10dbfd9a4efbb6f30af430036ab01697a9460f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
ATRUEorFALSE=Ain_bool.unfold()
# Out:
# <strong id="ATRUEorFALSE">ATRUEorFALSE:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a10dbfd9a4efbb6f30af430036ab01697a9460f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_forall_over_bool_by_cases/07661004d672b1d41fc8dc254b76ec63fc7366c50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a80dd87b84d6ebecfbeb8f329cbbb1f9711c031a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
AequalTRUE, AequalFALSE=ATRUEorFALSE.operands
# Out:
# <strong id="AequalTRUE">AequalTRUE:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/bd0a6a631c1aea42bd4e95c9e4e7fa7c531d32e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="AequalFALSE">AequalFALSE:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/df6506bd32d9f7c53b00f834a4c61833f27224860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AequalTRUE.sub_left_side_into(PofTrue, assumptions=defaults.assumptions + (AequalTRUE,))
# Out:
# {P(TRUE), A = TRUE} |- P(A)

# %%
AequalFALSE.sub_left_side_into(PofFalse, assumptions=defaults.assumptions + (AequalFALSE,))
# Out:
# {P(FALSE), A = FALSE} |- P(A)

# %%
ATRUEorFALSE.derive_via_dilemma(PofA)
# Out:
# {A in BOOLEAN, P(TRUE), P(FALSE)} |- P(A)
# forall_over_bool_by_cases may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.forall_over_bool_by_cases has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 1	instantiation	2, 3, 4, 13, 5, 6	{A in BOOLEAN, P(TRUE), P(FALSE)} |- P(A)
# 	A : A = TRUE, B : A = FALSE, C : P(A)
# 2	conjecture		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	{A in BOOLEAN} |- (A = TRUE) in BOOLEAN
# 	A : A = TRUE, B : A = FALSE
# 4	instantiation	8, 9	{A in BOOLEAN} |- (A = FALSE) in BOOLEAN
# 	A : A = TRUE, B : A = FALSE
# 5	deduction	10	{P(TRUE)} |- (A = TRUE) => P(A)
# 6	deduction	11	{P(FALSE)} |- (A = FALSE) => P(A)
# 7	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 9	instantiation	12, 13	{A in BOOLEAN} |- ((A = TRUE) or (A = FALSE)) in BOOLEAN
# 	A : (A = TRUE) or (A = FALSE)
# 10	instantiation	16, 14, 15	{P(TRUE), A = TRUE} |- P(A)
# 	P(_a) : P(_a), x : A, y : TRUE
# 11	instantiation	16, 17, 18	{P(FALSE), A = FALSE} |- P(A)
# 	P(_a) : P(_a), x : A, y : FALSE
# 12	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 13	instantiation	19, 20	{A in BOOLEAN} |- (A = TRUE) or (A = FALSE)
# 	A : A
# 14	assumption		{P(TRUE)} |- P(TRUE)
# 15	assumption		{A = TRUE} |- A = TRUE
# 16	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 17	assumption		{P(FALSE)} |- P(FALSE)
# 18	assumption		{A = FALSE} |- A = FALSE
# 19	conjecture		|- forall_{A in BOOLEAN} ((A = TRUE) or (A = FALSE))
# 	proveit.logic.booleans.unfold_is_bool_explicit
# 20	assumption		{A in BOOLEAN} |- A in BOOLEAN
