# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#unfold_is_bool">unfold_is_bool</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A
from proveit.logic.booleans import unfold_is_bool_explicit
from proveit.logic.booleans.negation import closure
neg_closure = closure
from proveit.logic.booleans.disjunction import constructive_dilemma
theory = proveit.Theory() # the theorem's theory

# %%
# %proving unfold_is_bool
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="unfold_is_bool">unfold_is_bool:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/779edfd0fb4a47bf77bced3a4fd2941adbb64ed70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/22746b6ca3d14ebb05bedc8ca0ef430f4beef3350/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = unfold_is_bool.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_is_bool/81d270e9c5cc07d6f2e45f97085e5bea1368be7e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
unfold_is_bool_explicit
# Out:
# |- forall_{A in BOOLEAN} ((A = TRUE) or (A = FALSE))

# %%
explicit_form = unfold_is_bool_explicit.instantiate({A:A})
# Out:
# <strong id="explicit_form">explicit_form:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a10dbfd9a4efbb6f30af430036ab01697a9460f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_is_bool/07661004d672b1d41fc8dc254b76ec63fc7366c50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a80dd87b84d6ebecfbeb8f329cbbb1f9711c031a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
explicit_form.derive_via_multi_dilemma(unfold_is_bool.instance_expr)
# Out:
# {A in BOOLEAN} |- A or [not](A)
# unfold_is_bool may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.unfold_is_bool has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A in BOOLEAN} (A or [not](A))
# 1	instantiation	2, 3, 4, 21, 5, 15, 6, 7	{A in BOOLEAN} |- A or [not](A)
# 	A : A = TRUE, B : A = FALSE, C : A, D : [not](A)
# 2	conjecture		|- forall_{A, B, C, D in BOOLEAN | A or B, A => C, B => D} (C or D)
# 	proveit.logic.booleans.disjunction.constructive_dilemma
# 3	instantiation	8, 10	{A in BOOLEAN} |- (A = TRUE) in BOOLEAN
# 	A : A = TRUE, B : A = FALSE
# 4	instantiation	9, 10	{A in BOOLEAN} |- (A = FALSE) in BOOLEAN
# 	A : A = TRUE, B : A = FALSE
# 5	instantiation	11, 21	{A in BOOLEAN} |- [not](A) in BOOLEAN
# 	A : A
# 6	deduction	12	|- (A = TRUE) => A
# 7	deduction	13	|- (A = FALSE) => [not](A)
# 8	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 9	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 10	instantiation	14, 15	{A in BOOLEAN} |- ((A = TRUE) or (A = FALSE)) in BOOLEAN
# 	A : (A = TRUE) or (A = FALSE)
# 11	conjecture		|- forall_{A in BOOLEAN} ([not](A) in BOOLEAN)
# 	proveit.logic.booleans.negation.closure
# 12	instantiation	16, 17	{A = TRUE} |- A
# 	A : A
# 13	instantiation	18, 19	{A = FALSE} |- [not](A)
# 	A : A
# 14	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 15	instantiation	20, 21	{A in BOOLEAN} |- (A = TRUE) or (A = FALSE)
# 	A : A
# 16	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 17	assumption		{A = TRUE} |- A = TRUE
# 18	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 19	assumption		{A = FALSE} |- A = FALSE
# 20	conjecture		|- forall_{A in BOOLEAN} ((A = TRUE) or (A = FALSE))
# 	proveit.logic.booleans.unfold_is_bool_explicit
# 21	assumption		{A in BOOLEAN} |- A in BOOLEAN
