# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#true_truth">true_truth</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Not, FALSE
from proveit.logic.booleans import true_def

# %%
# %proving true_truth
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="true_truth">true_truth:</strong> <a class="ProveItLink" href="../../../__pv_it/common/95025295868b9266d37330b4427adf122f6061770/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/64bc9adbfc772c829f06a77a4e513c5d49368e060/dependencies.ipynb">dependencies</a>)<br>

# %%
true_def
# Out:
# |- TRUE = [not](FALSE)

# %%
true_def_rev = true_def.derive_reversed()
# Out:
# <strong id="true_def_rev">true_def_rev:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_true_truth/dc73e3ede11d0f6384683da1f0c6ef6194d3d0010/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../negation/__pv_it/theorems/b9bd74a578c6b2e794e4ce82c543ff5c79f215890/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_false = Not(FALSE).prove()
# Out:
# <strong id="not_false">not_false:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../negation/_theory_nbs_/proofs/not_false/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../negation/__pv_it/theorems/446a01d9a7ebef169028057d3b157d31652390170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
true_def_rev.sub_right_side_into(not_false)
# Out:
# |- TRUE
# true_truth has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.true_truth is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- TRUE
# 1	modus_ponens	3, 4	|- ([not](FALSE) = TRUE) => TRUE
# 2	instantiation	5, 6	|- [not](FALSE) = TRUE
# 	x : TRUE, y : [not](FALSE)
# 3	instantiation	7	|- [not](FALSE) => (([not](FALSE) = TRUE) => TRUE)
# 	P(_a) : _a, x : [not](FALSE), y : TRUE
# 4	theorem		|- [not](FALSE)
# 	proveit.logic.booleans.negation.not_false
# 5	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 6	basic_definition		|- TRUE = [not](FALSE)
# 	proveit.logic.booleans.true_def
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
