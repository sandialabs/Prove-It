# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#true_not_false">true_not_false</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic import TRUE, FALSE, Equals
from proveit.logic.booleans import true_def

# %%
# %proving true_not_false
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="true_not_false">true_not_false:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/870a060ad7dcb1bd4612ad00133aadda1058053b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/39673a3773482e1591adf8e56db6c594061d50b10/dependencies.ipynb">dependencies</a>)<br>
# true_not_false may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %% [markdown]
# We will derive this via contradiction.

# %%
true_eq_false = Equals(TRUE, FALSE)
# Out:
# <strong id="true_eq_false">true_eq_false:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/bc50cbab1e7f410153451fcd3e4652ef1fce43590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [true_eq_false]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/00d36f1e4a4150aed66fc8c701d4b0fbdb1b50510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
true_def
# Out:
# |- TRUE = [not](FALSE)

# %%
contradictory_eq = true_def.sub_right_side_into(true_eq_false)
# Out:
# <strong id="contradictory_eq">contradictory_eq:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/bc50cbab1e7f410153451fcd3e4652ef1fce43590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/1ab3ba5ee19ffe2e971d53ed5805d4783acdd88b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/e90e4cda6c38bf803ee7515475077b933e6a02f40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction_stmt = contradictory_eq.derive_right_via_equality()
# Out:
# <strong id="contradiction_stmt">contradiction_stmt:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/bc50cbab1e7f410153451fcd3e4652ef1fce43590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_true_not_false/b5c2315f1448d03b7a1c8b4a6b918d2f5855c8580/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction_stmt.as_implication(true_eq_false)
# Out:
# |- (TRUE = FALSE) => FALSE
# true_not_false has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.true_not_false is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- TRUE != FALSE
# 	x : TRUE, y : FALSE
# 1	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 2	instantiation	3, 4	|- [not](TRUE = FALSE)
# 	A : TRUE = FALSE
# 3	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 4	deduction	5	|- (TRUE = FALSE) => FALSE
# 5	instantiation	6, 7	{TRUE = FALSE} |- FALSE
# 	A : FALSE
# 6	theorem		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 7	instantiation	8, 9	{TRUE = FALSE} |- FALSE = TRUE
# 	x : TRUE, y : FALSE
# 8	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 9	assumption		{TRUE = FALSE} |- TRUE = FALSE
