# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#eq_true_elim">eq_true_elim</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving eq_true_elim
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="eq_true_elim">eq_true_elim:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d7e58871e1086f5eec17cfd7ebff753b9f9969a40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/26c36d9eb99a39bdbbd90203cd49b8e195c051db0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = eq_true_elim.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_eq_true_elim/5b41e26d10ad5fe18369c0af1d43bc0f2b6bada50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_eq_T = defaults.assumptions[0]
# Out:
# <strong id="A_eq_T">A_eq_T:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/bd0a6a631c1aea42bd4e95c9e4e7fa7c531d32e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_eq_T.derive_left_via_equality()
# Out:
# {A = TRUE} |- A
# eq_true_elim may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.eq_true_elim is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A = TRUE} A
# 1	instantiation	2, 3	{A = TRUE} |- A
# 	P : A, Q : TRUE
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	modus_ponens	4, 5	{A = TRUE} |- TRUE and (A = TRUE)
# 4	modus_ponens	6, 7	|- (A = TRUE) => (TRUE and (A = TRUE))
# 5	assumption		{A = TRUE} |- A = TRUE
# 6	instantiation	8	|- TRUE => ((A = TRUE) => (TRUE and (A = TRUE)))
# 	A : TRUE, B : A = TRUE
# 7	theorem		|- TRUE
# 	proveit.logic.booleans.true_truth
# 8	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
