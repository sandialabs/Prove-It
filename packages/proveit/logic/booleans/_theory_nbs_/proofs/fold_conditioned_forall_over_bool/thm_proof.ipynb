# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#fold_conditioned_forall_over_bool">fold_conditioned_forall_over_bool</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic import Implies, Forall, Boolean
from proveit import PofA, QofA, P, A, Q
from proveit.logic import QimplPofTrue, QimplPofFalse, PofTrue, PofFalse
from proveit.logic.booleans import fold_forall_over_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving fold_conditioned_forall_over_bool
# Out:
# fold_conditioned_forall_over_bool: forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]

# %%
defaults.assumptions = fold_conditioned_forall_over_bool.conditions + fold_conditioned_forall_over_bool.instance_expr.conditions
# Out:
# defaults.assumptions: (Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE), A in BOOLEAN, Q(A))

# %%
fold_forall_over_bool
# Out:
# |- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]

# %%
fold_forall_over_bool_spec = fold_forall_over_bool.instantiate({PofA:Implies(QofA,PofA)})
# Out:
# fold_forall_over_bool_spec: {Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} |- forall_{A in BOOLEAN} (Q(A) => P(A))

# %%
QAimplPA = fold_forall_over_bool_spec.generalize((P, Q), conditions=fold_forall_over_bool_spec.assumptions)
# Out:
# QAimplPA: |- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN} (Q(A) => P(A))]

# %%
QAimplPA.instantiate({P:P, Q:Q, A:A})
# Out:
# {Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE), A in BOOLEAN} |- Q(A) => P(A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 1	modus ponens	2, 3	{Q(FALSE) => P(FALSE), Q(TRUE) => P(TRUE), A in BOOLEAN, Q(A)} |- P(A)
# 2	instantiation	4, 8, 9, 5	{Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE), A in BOOLEAN} |- Q(A) => P(A)
# 	P : P, Q : Q, A : A
# 3	assumption		{Q(A)} |- Q(A)
# 4	generalizaton	6	|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN} (Q(A) => P(A))]
# 5	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 6	instantiation	7, 8, 9	{Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} |- forall_{A in BOOLEAN} (Q(A) => P(A))
# 	P(A) : Q(A) => P(A)
# 7	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 8	assumption		{Q(TRUE) => P(TRUE)} |- Q(TRUE) => P(TRUE)
# 9	assumption		{Q(FALSE) => P(FALSE)} |- Q(FALSE) => P(FALSE)
