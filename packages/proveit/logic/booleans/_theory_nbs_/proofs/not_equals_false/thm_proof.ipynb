# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_equals_false">not_equals_false</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic import NotEquals, TRUE, FALSE

# %%
# %proving not_equals_false
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_equals_false">not_equals_false:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fc482c8639c85f39a0bf05f5580dfa0ef7830dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/74173c7689829f18800ce97edf4bdb4c84b2b7550/dependencies.ipynb">dependencies</a>)<br>
# not_equals_false may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
true_not_false = NotEquals(TRUE, FALSE).prove()
# Out:
# <strong id="true_not_false">true_not_false:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../true_not_false/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/870a060ad7dcb1bd4612ad00133aadda1058053b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
AeqT = A.evaluation(assumptions=[A])
# Out:
# <strong id="AeqT">AeqT:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_equals_false/8d8de252ecd397742cb823dab43fa75ce5f5e6490/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/bd0a6a631c1aea42bd4e95c9e4e7fa7c531d32e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
AeqT.sub_left_side_into(true_not_false)
# Out:
# {A} |- A != FALSE

# %%
# %qed
# Out:
# proveit.logic.booleans.not_equals_false is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A} (A != FALSE)
# 1	instantiation	2, 3	{A} |- A != FALSE
# 	P(_a) : _a != FALSE, x : A
# 2	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 3	modus_ponens	4, 5	{A} |- (TRUE != FALSE) and A
# 4	modus_ponens	6, 7	|- A => ((TRUE != FALSE) and A)
# 5	assumption		{A} |- A
# 6	instantiation	8	|- (TRUE != FALSE) => (A => ((TRUE != FALSE) and A))
# 	A : TRUE != FALSE, B : A
# 7	theorem		|- TRUE != FALSE
# 	proveit.logic.booleans.true_not_false
# 8	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
