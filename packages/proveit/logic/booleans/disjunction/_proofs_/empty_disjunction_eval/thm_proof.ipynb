# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">disjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#empty_disjunction_eval">empty_disjunction_eval</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans.disjunction  import empty_disjunction
theory = proveit.Theory() # the theorem's theory

# %%
# %proving empty_disjunction_eval

# %%
empty_disjunction

# %%
empty_disjunction.equate_negated_to_false()

# %%
# %qed
