# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">disjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#demorgans_law_and_to_or_bin_explicit">demorgans_law_and_to_or_bin_explicit</a> theorem
# ========

# %%
import proveit
from proveit.logic.booleans import fold_forall_over_bool, fold_conditioned_forall_over_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving demorgans_law_and_to_or_bin_explicit

# %%
# %qed
