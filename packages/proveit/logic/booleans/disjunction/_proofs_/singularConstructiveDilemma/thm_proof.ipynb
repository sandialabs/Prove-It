# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">disjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#singularConstructiveDilemma">singularConstructiveDilemma</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import C
from proveit.logic import TRUE, Equals
from proveit.logic.booleans.disjunction._theorems_ import singularConstructiveDilemmaLemma
theory = proveit.Theory() # the theorem's theory

# %%
# %proving singularConstructiveDilemma

# %%
defaults.assumptions = singularConstructiveDilemma.allConditions()

# %% [markdown]
# We will use the constrained singular constructive dilemma as a convenient Lemma to prove some $C=\top$ and deriving $C$ from there.

# %%
singularConstructiveDilemmaLemma

# %%
singularConstructiveDilemmaLemma.instantiate({C:Equals(C, TRUE)})

# %%
# %qed
