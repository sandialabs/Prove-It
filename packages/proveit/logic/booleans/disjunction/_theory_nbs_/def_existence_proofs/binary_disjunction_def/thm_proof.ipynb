# %% [markdown]
# Existence proof for <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../definitions.ipynb#binary_disjunction_def">binary_disjunction_def</a>
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, P, x, y
from proveit import Lambda, Function
from proveit.logic import Implies, Not, Forall, Equals, Or
from proveit.logic.booleans.quantification.existence import existence_by_basic_example

# %%
# %existence_proving binary_disjunction_def
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of existence for<br><strong id="binary_disjunction_def">binary_disjunction_def:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/ca70b956223a1636627b35b2c058e41bf62abf7c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/definitions/795dfa97d24bf82b0442a57d5e33c4b236807ba00/dependencies.ipynb">dependencies</a>)<br>
# binary_disjunction_def may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
existence_by_basic_example
# Out:
# |- forall_{P} [forall_{x | P(x)} [exists_{y} P(y)]]

# %%
dij_def_rhs = binary_disjunction_def.instance_expr.instance_expr.rhs
# Out:
# <strong id="dij_def_rhs">dij_def_rhs:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/821ba9051d7e1d8be825aa9b50fcbef4c2fb4f2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
or_op = Or._operator_.as_variable()
# Out:
# <strong id="or_op">or_op:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/1d32327eea726c83d7d9fde89b4a168e38c481a90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
existence_by_basic_example.instantiate({P:Lambda(or_op, Forall((A, B), Equals(Function(or_op, [A, B]), dij_def_rhs))), 
                                        x:Lambda((A, B), dij_def_rhs), y:or_op})
# Out:
# |- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# binary_disjunction_def has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.binary_disjunction_def is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# 	P(or) : forall_{A, B} (or(A, B) = ([not](A) => B)), x(A, B) : [not](A) => B, y : or
# 1	theorem		|- forall_{P} [forall_{x | P(x)} [exists_{y} P(y)]]
# 	proveit.logic.booleans.quantification.existence.existence_by_basic_example
# 2	generalization	3	|- forall_{A, B} (([not](A) => B) = ([not](A) => B))
# 3	instantiation	4	|- ([not](A) => B) = ([not](A) => B)
# 	x : [not](A) => B
# 4	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
