# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_right_if_neither">not_right_if_neither</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import in_bool, Not, Or
from proveit.logic.booleans.disjunction import not_left_if_neither
theory = proveit.Theory() # the theorem's theory

# %%
import proveit.logic

# %%
# %proving not_right_if_neither
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_right_if_neither">not_right_if_neither:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0db750d8f6f1f1f2212dadc96a5752f814303a800/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/4c15a8ddaee9910378eb70671c603589a0dfc3a80/dependencies.ipynb">dependencies</a>)<br>

# %%
# If we do not disable "not_left_if_neither" then a sub-optimal derivation may be generated through the automration.
# (a locally optimal choice in minimizing proof steps is not always globally optimal)
not_left_if_neither.proof().disable()

# %%
defaults.assumptions = not_right_if_neither.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/f47f80766aefd26227e9fa4908b147150401588c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AorB_given_B = Or(A, B).conclude_via_example(
    B, assumptions = defaults.assumptions + (B,))
# Out:
# <strong id="AorB_given_B">AorB_given_B:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/88b090a35cddd0f3ea45e2fff303d7d3770a7d390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/40278cd2ae6285f1dd64f3ddfae473a92537b5d00/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_impl_AorB = AorB_given_B.as_implication(B)
# Out:
# <strong id="B_impl_AorB">B_impl_AorB:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/88b090a35cddd0f3ea45e2fff303d7d3770a7d390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/db5d55e5fc786366d16bfaaaf93432a94c6352700/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/cf6031696e81bc3704fadec0ba6f458bfe6c1e060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_impl_AorB.deny_antecedent()
# Out:
# {[not](A or B)} |- [not](B)
# not_right_if_neither may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.not_right_if_neither has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A or B)} [not](B)
# 1	instantiation	2, 7, 3, 15	{[not](A or B)} |- [not](B)
# 	A : B, B : A or B
# 2	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 3	deduction	4	{[not](A or B)} |- B => (A or B)
# 4	instantiation	5, 6, 7, 8	{[not](A or B), B} |- A or B
# 	A : A, B : B
# 5	conjecture		|- forall_{A, B in BOOLEAN | B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_right
# 6	instantiation	9, 11	{[not](A or B)} |- A in BOOLEAN
# 	A : A, B : B
# 7	instantiation	10, 11	{[not](A or B)} |- B in BOOLEAN
# 	A : A, B : B
# 8	assumption		{B} |- B
# 9	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 10	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 11	instantiation	12, 13	{[not](A or B)} |- (A or B) in BOOLEAN
# 	A : A or B
# 12	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 13	instantiation	14, 15	{[not](A or B)} |- [not](A or B) in BOOLEAN
# 	A : [not](A or B)
# 14	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 15	assumption		{[not](A or B)} |- [not](A or B)
