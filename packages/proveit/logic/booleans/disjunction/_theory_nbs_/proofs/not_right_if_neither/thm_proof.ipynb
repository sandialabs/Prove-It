# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_right_if_neither">not_right_if_neither</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not, Or

# %%
# %proving not_right_if_neither
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_right_if_neither">not_right_if_neither:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0db750d8f6f1f1f2212dadc96a5752f814303a800/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ff1c1c68d954b6b1301a126b80066b352c0406ef0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = not_right_if_neither.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/f47f80766aefd26227e9fa4908b147150401588c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AorB_given_B = Or(A, B).conclude_via_example(
    B, assumptions = defaults.assumptions + (B,))
# Out:
# <strong id="AorB_given_B">AorB_given_B:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/98fbc67546efd42a34b5288e72c6217cd6aca8890/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# not_right_if_neither may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
B_impl_AorB = AorB_given_B.as_implication(B)
# Out:
# <strong id="B_impl_AorB">B_impl_AorB:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/ed8ba25e5dd7853d6c0272c9d2702292423592320/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_right_if_neither/cf6031696e81bc3704fadec0ba6f458bfe6c1e060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_impl_AorB.deny_antecedent()
# Out:
# {[not](A or B)} |- [not](B)

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.not_right_if_neither is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A or B)} [not](B)
# 1	instantiation	2, 3	{[not](A or B)} |- [not](B)
# 	A : B, B : A or B
# 2	theorem		|- forall_{A} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 3	modus_ponens	4, 5	{[not](A or B)} |- (B => (A or B)) and [not](A or B)
# 4	modus_ponens	6, 7	|- [not](A or B) => ((B => (A or B)) and [not](A or B))
# 5	assumption		{[not](A or B)} |- [not](A or B)
# 6	instantiation	8	|- (B => (A or B)) => ([not](A or B) => ((B => (A or B)) and [not](A or B)))
# 	A : B => (A or B), B : [not](A or B)
# 7	deduction	9	|- B => (A or B)
# 8	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 9	instantiation	10, 11	{B} |- A or B
# 	A : A, B : B
# 10	theorem		|- forall_{A, B | B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_right
# 11	assumption		{B} |- B
