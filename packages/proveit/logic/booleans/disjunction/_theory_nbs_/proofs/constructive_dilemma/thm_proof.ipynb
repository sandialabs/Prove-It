# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#constructive_dilemma">constructive_dilemma</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C, D
from proveit.logic import Or

# %%
# %proving constructive_dilemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="constructive_dilemma">constructive_dilemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/72ebcf37d8dceb9a8c5a8210a40ce457a98c89be0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2b09a0ba79bce9f287981eed4ed8012bf7e374d00/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# Prove by applying the **singular_constructive_dilemma** on $(C \lor D)$ as a unit, using **or_if_left** to prove $A \Rightarrow (C \lor D)$ and **or_if_right** to prove $B \Rightarrow (C \lor D)$ under the **constructive_dilemma** conditions.

# %%
defaults.assumptions = constructive_dilemma.all_conditions() + [constructive_dilemma.instance_expr.antecedent]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_constructive_dilemma/3ea1e5e1f77e64e46727c3f56e8a8782060bf91d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Or(C, D).conclude_via_example(C, assumptions = defaults.assumptions + (A,))
# Out:
# {(A => C) and (B => D), A} |- C or D

# %%
Or(C, D).conclude_via_example(D, assumptions = defaults.assumptions + (B,))
# Out:
# {(A => C) and (B => D), B} |- C or D

# %%
Or(A, B).derive_via_dilemma(Or(C, D))
# Out:
# {(A => C) and (B => D), A or B} |- C or D

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.constructive_dilemma is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C, D | A => C, B => D} ((A or B) => (C or D))
# 1	deduction	2	{(A => C) and (B => D)} |- (A or B) => (C or D)
# 2	instantiation	3, 4, 5	{(A => C) and (B => D), A or B} |- C or D
# 	A : A, B : B, C : C or D
# 3	theorem		|- forall_{A, B | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 4	assumption		{A or B} |- A or B
# 5	modus_ponens	6, 7	{(A => C) and (B => D)} |- (A => (C or D)) and (B => (C or D))
# 6	modus_ponens	8, 9	{(A => C) and (B => D)} |- (B => (C or D)) => ((A => (C or D)) and (B => (C or D)))
# 7	deduction	10	{(A => C) and (B => D)} |- B => (C or D)
# 8	instantiation	11	|- (A => (C or D)) => ((B => (C or D)) => ((A => (C or D)) and (B => (C or D))))
# 	A : A => (C or D), B : B => (C or D)
# 9	deduction	12	{(A => C) and (B => D)} |- A => (C or D)
# 10	instantiation	13, 14	{(A => C) and (B => D), B} |- C or D
# 	A : C, B : D
# 11	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 12	instantiation	15, 16	{(A => C) and (B => D), A} |- C or D
# 	A : C, B : D
# 13	theorem		|- forall_{A, B | B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_right
# 14	modus_ponens	17, 18	{(A => C) and (B => D), B} |- D
# 15	theorem		|- forall_{A, B | A} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_left
# 16	modus_ponens	19, 20	{(A => C) and (B => D), A} |- C
# 17	instantiation	21, 23	{(A => C) and (B => D)} |- B => D
# 	A : A => C, B : B => D
# 18	assumption		{B} |- B
# 19	instantiation	22, 23	{(A => C) and (B => D)} |- A => C
# 	A : A => C, B : B => D
# 20	assumption		{A} |- A
# 21	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 22	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 23	assumption		{(A => C) and (B => D)} |- (A => C) and (B => D)
