# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#constructive_dilemma">constructive_dilemma</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B, C, D
from proveit.logic import Or
theory = proveit.Theory() # the theorem's theory

# %%
# %proving constructive_dilemma
# Out:
# constructive_dilemma: forall_{A, B, C, D in BOOLEAN | A or B, A => C, B => D} (C or D)

# %% [markdown]
# Prove by applying the **singular_constructive_dilemma** on $(C \lor D)$ as a unit, using **or_if_left** to prove $A \Rightarrow (C \lor D)$ and **or_if_right** to prove $B \Rightarrow (C \lor D)$ under the **constructive_dilemma** conditions.

# %%
defaults.assumptions = constructive_dilemma.all_conditions()
# Out:
# defaults.assumptions: (A in BOOLEAN, B in BOOLEAN, C in BOOLEAN, D in BOOLEAN, A or B, A => C, B => D)

# %%
Or(C, D).conclude_via_example(C, defaults.assumptions + (A,))
# Out:
# {C in BOOLEAN, D in BOOLEAN, A => C, A} |- C or D

# %%
Or(C, D).conclude_via_example(D, defaults.assumptions + (B,))
# Out:
# {C in BOOLEAN, D in BOOLEAN, B => D, B} |- C or D

# %%
Or(A, B).derive_via_singular_dilemma(Or(C, D))
# Out:
# {A in BOOLEAN, B in BOOLEAN, A or B, C in BOOLEAN, D in BOOLEAN, A => C, B => D} |- C or D

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B, C, D in BOOLEAN | A or B, A => C, B => D} (C or D)
# 1	instantiation	2, 3, 4, 5, 6, 7	{A in BOOLEAN, B in BOOLEAN, A or B, C in BOOLEAN, D in BOOLEAN, A => C, B => D} |- C or D
# 	A : A, B : B, C : C or D
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 4	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 5	assumption		{A or B} |- A or B
# 6	deduction	8	{C in BOOLEAN, D in BOOLEAN, A => C} |- A => (C or D)
# 7	deduction	9	{C in BOOLEAN, D in BOOLEAN, B => D} |- B => (C or D)
# 8	instantiation	10, 13, 14, 11	{C in BOOLEAN, D in BOOLEAN, A => C, A} |- C or D
# 	A : C, B : D
# 9	instantiation	12, 13, 14, 15	{C in BOOLEAN, D in BOOLEAN, B => D, B} |- C or D
# 	A : C, B : D
# 10	conjecture		|- forall_{A, B in BOOLEAN | A} (A or B)
# 11	modus ponens	16, 17	{A => C, A} |- C
# 12	conjecture		|- forall_{A, B in BOOLEAN | B} (A or B)
# 13	assumption		{C in BOOLEAN} |- C in BOOLEAN
# 14	assumption		{D in BOOLEAN} |- D in BOOLEAN
# 15	modus ponens	18, 19	{B => D, B} |- D
# 16	assumption		{A => C} |- A => C
# 17	assumption		{A} |- A
# 18	assumption		{B => D} |- B => D
# 19	assumption		{B} |- B
