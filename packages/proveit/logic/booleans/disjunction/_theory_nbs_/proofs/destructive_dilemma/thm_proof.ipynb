# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#destructive_dilemma">destructive_dilemma</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C, D
from proveit.logic import Implies, Not, Or

# %%
# %proving destructive_dilemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="destructive_dilemma">destructive_dilemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/5164decbb4ae63e83f0d192262794300d1c149170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/bf49eb513d11dc1047f330345d5d83c087c20eb20/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# Prove by applying the **constructive_dilemma** after taking contraposing $A \Rightarrow C$ to $\lnot C \Rightarrow \lnot A$ and $B \Rightarrow D$ to $\lnot D \Rightarrow \lnot B$.

# %%
defaults.assumptions = destructive_dilemma.conditions + (destructive_dilemma.instance_expr.antecedent,)
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_destructive_dilemma/114651719c125caa48af94c531948120b33f49210/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Implies(A, C).contrapose()
# Out:
# {A => C} |- [not](C) => [not](A)

# %%
Implies(B, D).contrapose()
# Out:
# {B => D} |- [not](D) => [not](B)

# %%
Or(Not(C), Not(D)).derive_via_multi_dilemma(Or(Not(A), Not(B)))
# Out:
# {A => C, B => D, [not](C) or [not](D)} |- [not](A) or [not](B)
# destructive_dilemma may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.destructive_dilemma is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C, D | A => C, B => D} (([not](C) or [not](D)) => ([not](A) or [not](B)))
# 1	instantiation	2, 3	{(A => C) and (B => D)} |- ([not](C) or [not](D)) => ([not](A) or [not](B))
# 	A : [not](C), B : [not](D), C : [not](A), D : [not](B)
# 2	theorem		|- forall_{A, B, C, D | A => C, B => D} ((A or B) => (C or D))
# 	proveit.logic.booleans.disjunction.constructive_dilemma
# 3	modus_ponens	4, 5	{(A => C) and (B => D)} |- ([not](C) => [not](A)) and ([not](D) => [not](B))
# 4	modus_ponens	6, 7	{(A => C) and (B => D)} |- ([not](D) => [not](B)) => (([not](C) => [not](A)) and ([not](D) => [not](B)))
# 5	instantiation	10, 8	{(A => C) and (B => D)} |- [not](D) => [not](B)
# 	A : B, B : D
# 6	instantiation	9	|- ([not](C) => [not](A)) => (([not](D) => [not](B)) => (([not](C) => [not](A)) and ([not](D) => [not](B))))
# 	A : [not](C) => [not](A), B : [not](D) => [not](B)
# 7	instantiation	10, 11	{(A => C) and (B => D)} |- [not](C) => [not](A)
# 	A : A, B : C
# 8	instantiation	12, 14	{(A => C) and (B => D)} |- B => D
# 	A : A => C, B : B => D
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	theorem		|- forall_{A, B | A => B} ([not](B) => [not](A))
# 	proveit.logic.booleans.implication.to_contraposition
# 11	instantiation	13, 14	{(A => C) and (B => D)} |- A => C
# 	A : A => C, B : B => D
# 12	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 13	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 14	assumption		{(A => C) and (B => D)} |- (A => C) and (B => D)
