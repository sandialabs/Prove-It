# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#destructive_dilemma">destructive_dilemma</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B, C, D
from proveit.logic import Implies, Not, Or
from proveit.logic.booleans.disjunction  import left_in_bool, right_in_bool
left_in_bool.proof().disable(); right_in_bool.proof().disable() # disable these to avoid a longer proof
theory = proveit.Theory() # the theorem's theory

# %%
# %proving destructive_dilemma
# Out:
# destructive_dilemma: forall_{A, B, C, D in BOOLEAN | [not](C) or [not](D), A => C, B => D} ([not](A) or [not](B))

# %%
from proveit.logic.booleans.disjunction import destructive_multi_dilemma
destructive_multi_dilemma.is_usable()
# Out:
# False

# %% [markdown]
# Prove by applying the **constructive_dilemma** after taking contraposing $A \Rightarrow C$ to $\lnot C \Rightarrow \lnot A$ and $B \Rightarrow D$ to $\lnot D \Rightarrow \lnot B$.

# %%
defaults.assumptions = destructive_dilemma.all_conditions()
# Out:
# defaults.assumptions: (A in BOOLEAN, B in BOOLEAN, C in BOOLEAN, D in BOOLEAN, [not](C) or [not](D), A => C, B => D)

# %%
Implies(A, C).contrapose()
# Out:
# {A => C, A in BOOLEAN} |- [not](C) => [not](A)

# %%
Implies(B, D).contrapose()
# Out:
# {B => D, B in BOOLEAN} |- [not](D) => [not](B)

# %%
Or(Not(C), Not(D)).derive_via_multi_dilemma(Or(Not(A), Not(B)))
# Out:
# {C in BOOLEAN, D in BOOLEAN, A in BOOLEAN, B in BOOLEAN, [not](C) or [not](D), A => C, B => D} |- [not](A) or [not](B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B, C, D in BOOLEAN | [not](C) or [not](D), A => C, B => D} ([not](A) or [not](B))
# 1	instantiation	2, 3, 4, 5, 6, 7, 8, 9	{C in BOOLEAN, D in BOOLEAN, A in BOOLEAN, B in BOOLEAN, [not](C) or [not](D), A => C, B => D} |- [not](A) or [not](B)
# 	A : [not](C), B : [not](D), C : [not](A), D : [not](B)
# 2	conjecture		|- forall_{A, B, C, D in BOOLEAN | A or B, A => C, B => D} (C or D)
# 3	instantiation	12, 10	{C in BOOLEAN} |- [not](C) in BOOLEAN
# 	A : C
# 4	instantiation	12, 11	{D in BOOLEAN} |- [not](D) in BOOLEAN
# 	A : D
# 5	instantiation	12, 14	{A in BOOLEAN} |- [not](A) in BOOLEAN
# 	A : A
# 6	instantiation	12, 17	{B in BOOLEAN} |- [not](B) in BOOLEAN
# 	A : B
# 7	assumption		{[not](C) or [not](D)} |- [not](C) or [not](D)
# 8	instantiation	15, 13, 14	{A => C, A in BOOLEAN} |- [not](C) => [not](A)
# 	A : A, B : C
# 9	instantiation	15, 16, 17	{B => D, B in BOOLEAN} |- [not](D) => [not](B)
# 	A : B, B : D
# 10	assumption		{C in BOOLEAN} |- C in BOOLEAN
# 11	assumption		{D in BOOLEAN} |- D in BOOLEAN
# 12	conjecture		|- forall_{A in BOOLEAN} ([not](A) in BOOLEAN)
# 13	assumption		{A => C} |- A => C
# 14	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 15	theorem		|- forall_{A, B | A => B, A in BOOLEAN} ([not](B) => [not](A))
# 	proveit.logic.booleans.implication.to_contraposition
# 16	assumption		{B => D} |- B => D
# 17	assumption		{B in BOOLEAN} |- B in BOOLEAN
