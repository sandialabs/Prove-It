# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_t_t">or_t_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving or_t_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_t_t">or_t_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/51ce2bda98b4bba5508f7e5f97f3c050ced5ef980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e283f7d26f7ad7350e96f4866df8952cee487de90/dependencies.ipynb">dependencies</a>)<br>
# or_t_t may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
or_t_t.lhs.definition(auto_simplify=True) # using auto-simplification
# Out:
# |- (TRUE or TRUE) = TRUE
# or_t_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_t_t is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2*	|- (TRUE or TRUE) = TRUE
# 	A : TRUE, B : TRUE
# 1	defining_property	3	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 2	instantiation	4, 5	|- ([not](TRUE) => TRUE) = TRUE
# 	x : [not](TRUE) => TRUE, y : FALSE => TRUE, z : TRUE
# 3	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# 4	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	modus_ponens	6, 7	|- (([not](TRUE) => TRUE) = (FALSE => TRUE)) and ((FALSE => TRUE) = TRUE)
# 6	modus_ponens	8, 9	|- ((FALSE => TRUE) = TRUE) => ((([not](TRUE) => TRUE) = (FALSE => TRUE)) and ((FALSE => TRUE) = TRUE))
# 7	theorem		|- (FALSE => TRUE) = TRUE
# 	proveit.logic.booleans.implication.implies_f_t
# 8	instantiation	10	|- (([not](TRUE) => TRUE) = (FALSE => TRUE)) => (((FALSE => TRUE) = TRUE) => ((([not](TRUE) => TRUE) = (FALSE => TRUE)) and ((FALSE => TRUE) = TRUE)))
# 	A : ([not](TRUE) => TRUE) = (FALSE => TRUE), B : (FALSE => TRUE) = TRUE
# 9	instantiation	11, 12	|- ([not](TRUE) => TRUE) = (FALSE => TRUE)
# 	f(_a) : _a => TRUE, x : [not](TRUE), y : FALSE
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 12	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
