# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#demorgans_law_and_to_or_bin">demorgans_law_and_to_or_bin</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import in_bool
from proveit.logic.booleans import fold_forall_over_bool
from proveit.logic.booleans.disjunction import demorgans_law_and_to_or_bin_explicit 
theory = proveit.Theory() # the theorem's theory

# %%
# %proving demorgans_law_and_to_or_bin
# Out:
# demorgans_law_and_to_or_bin: forall_{A, B | [not]([not](A) and [not](B))} (A or B)

# %%
defaults.assumptions = demorgans_law_and_to_or_bin.all_conditions()
# Out:
# defaults.assumptions: ([not]([not](A) and [not](B)))

# %%
in_bool(defaults.assumptions[0].operands[0].operands[0].operand).prove()
# Out:
# {[not]([not](A) and [not](B))} |- A in BOOLEAN

# %%
in_bool(defaults.assumptions[0].operands[0].operands[1].operand).prove()
# Out:
# {[not]([not](A) and [not](B))} |- B in BOOLEAN

# %%
demorgans_law_and_to_or_bin_explicit
# Out:
# |- forall_{A, B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)

# %%
demorgans_law_and_to_or_bin_explicit.instantiate({A:A, B:B}, assumptions = demorgans_law_and_to_or_bin.all_conditions())
# Out:
# {[not]([not](A) and [not](B))} |- A or B

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | [not]([not](A) and [not](B))} (A or B)
# 1	instantiation	2, 3, 4, 14	{[not]([not](A) and [not](B))} |- A or B
# 	A : A, B : B
# 2	conjecture		|- forall_{A, B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)
# 3	instantiation	10, 5	{[not]([not](A) and [not](B))} |- A in BOOLEAN
# 	A : A
# 4	instantiation	10, 6	{[not]([not](A) and [not](B))} |- B in BOOLEAN
# 	A : B
# 5	instantiation	7, 9	{[not]([not](A) and [not](B))} |- [not](A) in BOOLEAN
# 	A : [not](A), B : [not](B)
# 6	instantiation	8, 9	{[not]([not](A) and [not](B))} |- [not](B) in BOOLEAN
# 	A : [not](A), B : [not](B)
# 7	axiom		|- forall_{A, B | (A and B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.conjunction.left_in_bool
# 8	axiom		|- forall_{A, B | (A and B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.conjunction.right_in_bool
# 9	instantiation	10, 11	{[not]([not](A) and [not](B))} |- ([not](A) and [not](B)) in BOOLEAN
# 	A : [not](A) and [not](B)
# 10	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 11	instantiation	12, 13, 14	{[not]([not](A) and [not](B))} |- [not]([not](A) and [not](B)) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : [not]([not](A) and [not](B))
# 12	conjecture		|- forall_{P, x | P(TRUE), x} P(x)
# 13	conjecture		|- TRUE in BOOLEAN
# 14	assumption		{[not]([not](A) and [not](B))} |- [not]([not](A) and [not](B))
