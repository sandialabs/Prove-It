# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#excluded_middle">excluded_middle</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic.booleans.disjunction import binary_disjunction_def
from proveit.logic.booleans.negation import Not

# %%
# %proving excluded_middle
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="excluded_middle">excluded_middle:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6056980e8eca2030112902c630f7df5eea625dc50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f2e21615e86b752bf2a44d512a5a4f7789f73ccb0/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# Attempting to use proveit.logic.booleans.disjunction.fold_or
# which has neither been allowed nor disallowed for use in this proof.
# Hint: proveit.logic.booleans.disjunction.fold_or is fully proven and based upon current proofs,
# it is safe to ALLOW.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel or raise an (e)xception?  a
# proveit.logic.booleans.disjunction.excluded_middle is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A} (A or [not](A))
# 1	instantiation	2, 3	|- A or [not](A)
# 	A : A, B : [not](A)
# 2	theorem		|- forall_{A, B | [not](A) => B} (A or B)
# 	proveit.logic.booleans.disjunction.fold_or
# 3	instantiation	4	|- [not](A) => [not](A)
# 	A : [not](A)
# 4	theorem		|- forall_{A} (A => A)
# 	proveit.logic.booleans.implication.self_implication
