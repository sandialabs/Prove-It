# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_f_t">or_f_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving or_f_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_f_t">or_f_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9e9f256c794c8500531ff9573d3ae5b5b63b68f90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/c699f7932435caa390fb7937a4cc44ae83811b220/dependencies.ipynb">dependencies</a>)<br>
# or_f_t may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
or_f_t.lhs.definition(auto_simplify=True) # using auto-simplification
# Out:
# |- (FALSE or TRUE) = TRUE
# or_f_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_f_t is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2*	|- (FALSE or TRUE) = TRUE
# 	A : FALSE, B : TRUE
# 1	defining_property	3	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 2	instantiation	4, 5	|- ([not](FALSE) => TRUE) = TRUE
# 	x : [not](FALSE) => TRUE, y : TRUE => TRUE, z : TRUE
# 3	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# 4	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	modus_ponens	6, 7	|- (([not](FALSE) => TRUE) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE)
# 6	modus_ponens	8, 9	|- ((TRUE => TRUE) = TRUE) => ((([not](FALSE) => TRUE) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE))
# 7	theorem		|- (TRUE => TRUE) = TRUE
# 	proveit.logic.booleans.implication.implies_t_t
# 8	instantiation	10	|- (([not](FALSE) => TRUE) = (TRUE => TRUE)) => (((TRUE => TRUE) = TRUE) => ((([not](FALSE) => TRUE) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE)))
# 	A : ([not](FALSE) => TRUE) = (TRUE => TRUE), B : (TRUE => TRUE) = TRUE
# 9	instantiation	11, 12	|- ([not](FALSE) => TRUE) = (TRUE => TRUE)
# 	f(_a) : _a => TRUE, x : [not](FALSE), y : TRUE
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 12	theorem		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
