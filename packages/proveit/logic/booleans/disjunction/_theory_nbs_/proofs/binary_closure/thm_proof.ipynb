# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#binary_closure">binary_closure</a> theorem
# ========

# %%
import proveit
# we need to import false_or_false_negated to derive it's side-effects:
from proveit.logic.booleans.disjunction import \
    (true_or_true, false_or_true, true_or_false, false_or_false_negated)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving binary_closure
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="binary_closure">binary_closure:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1cbf1dd6702357f58be729613e6504284ff9936a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/77b13fc0156b765e348c13e9a1b0c73e8cb109380/dependencies.ipynb">dependencies</a>)<br>
# binary_closure may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.binary_closure has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)
# 1	instantiation	3, 4	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A or B) in BOOLEAN)]] \\  => [forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A or B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, x_{1} : A, y_{1} : B
# 2	instantiation	8, 5, 6	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A or B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A or B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	generalization	7	|- forall_{B in BOOLEAN} ((TRUE or B) in BOOLEAN)
# 6	instantiation	8, 9, 10	|- forall_{B in BOOLEAN} ((FALSE or B) in BOOLEAN)
# 	P(B) : (FALSE or B) in BOOLEAN, A : B
# 7	instantiation	19, 11	{B in BOOLEAN} |- (TRUE or B) in BOOLEAN
# 	A : TRUE or B
# 8	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 9	instantiation	19, 12	|- (FALSE or TRUE) in BOOLEAN
# 	A : FALSE or TRUE
# 10	instantiation	13, 14	|- (FALSE or FALSE) in BOOLEAN
# 	A : FALSE or FALSE
# 11	instantiation	15, 16, 17, 20	{B in BOOLEAN} |- TRUE or B
# 	A : TRUE, B : B
# 12	theorem		|- FALSE or TRUE
# 	proveit.logic.booleans.disjunction.false_or_true
# 13	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 14	instantiation	19, 18	|- [not](FALSE or FALSE) in BOOLEAN
# 	A : [not](FALSE or FALSE)
# 15	conjecture		|- forall_{A, B in BOOLEAN | A} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_left
# 16	instantiation	19, 20	|- TRUE in BOOLEAN
# 	A : TRUE
# 17	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 18	theorem		|- [not](FALSE or FALSE)
# 	proveit.logic.booleans.disjunction.false_or_false_negated
# 19	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 20	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
