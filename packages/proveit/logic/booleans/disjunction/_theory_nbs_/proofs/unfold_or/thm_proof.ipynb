# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#unfold_or">unfold_or</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.disjunction import binary_disjunction_def

# %%
# %proving unfold_or
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="unfold_or">unfold_or:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ac36b184493e713c534f924b4b4811d7c24fe72a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a98095123484891ac4e28bdc582bc664aab1b1380/dependencies.ipynb">dependencies</a>)<br>

# %%
binary_disjunction_def
# Out:
# |- forall_{A, B} ((A or B) = ([not](A) => B))

# %%
A_or_B__def = binary_disjunction_def.instantiate()
# Out:
# <strong id="A_or_B__def">A_or_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_or/b4cf94f623687f54d21955d427fc932c6dfc81830/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/22b93d8b52b075a015f35084bdc694a1ac56cccd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_or_B__def.derive_right_via_equality(assumptions=[unfold_or.condition])
# Out:
# {A or B} |- [not](A) => B
# unfold_or may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.unfold_or is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A or B} ([not](A) => B)
# 1	instantiation	2, 3	{A or B} |- [not](A) => B
# 	P : A or B, Q : [not](A) => B
# 2	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 3	modus_ponens	4, 5	{A or B} |- (A or B) and ((A or B) = ([not](A) => B))
# 4	modus_ponens	6, 7	{A or B} |- ((A or B) = ([not](A) => B)) => ((A or B) and ((A or B) = ([not](A) => B)))
# 5	instantiation	8	|- (A or B) = ([not](A) => B)
# 	A : A, B : B
# 6	instantiation	9	|- (A or B) => (((A or B) = ([not](A) => B)) => ((A or B) and ((A or B) = ([not](A) => B))))
# 	A : A or B, B : (A or B) = ([not](A) => B)
# 7	assumption		{A or B} |- A or B
# 8	defining_property	10	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# ...
