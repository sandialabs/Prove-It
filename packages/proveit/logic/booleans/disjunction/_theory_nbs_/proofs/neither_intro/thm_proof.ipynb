# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#neither_intro">neither_intro</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic.booleans.disjunction import binary_disjunction_def

# %%
# %proving neither_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="neither_intro">neither_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/aa437e25342693eaa9c76896665fa5c65b317cb80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/7359e8193d9aae38bd3cc140e4a5a07fb198e0020/dependencies.ipynb">dependencies</a>)<br>
# neither_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = neither_intro.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e08a4ac88f1815e5594cfa40e1aca1f0ee499af30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B = neither_intro.instance_expr.operand
# Out:
# <strong id="A_or_B">A_or_B:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B__def = A_or_B.definition()
# Out:
# <strong id="A_or_B__def">A_or_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_neither_intro/b4cf94f623687f54d21955d427fc932c6dfc81830/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/22b93d8b52b075a015f35084bdc694a1ac56cccd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_disproven = A_or_B__def.rhs.disprove()
# Out:
# <strong id="rhs_disproven">rhs_disproven:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8552c6321b312c5e15a5015adce4a756ce05da420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_neither_intro/ef2325533c06fc3c736265ec5305a85119faa2800/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_neither_intro/462bc6d07133e45a19bb708d046682393336722d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_or_B__def.sub_left_side_into(rhs_disproven)
# Out:
# {[not](A), [not](B)} |- [not](A or B)

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.neither_intro is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A), [not](B)} [not](A or B)
# 1	instantiation	2, 3	{[not](A) and [not](B)} |- [not](A or B)
# 	P(_a) : [not](_a), x : A or B, y : [not](A) => B
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{[not](A) and [not](B)} |- [not]([not](A) => B) and ((A or B) = ([not](A) => B))
# 4	modus_ponens	6, 7	{[not](A) and [not](B)} |- ((A or B) = ([not](A) => B)) => ([not]([not](A) => B) and ((A or B) = ([not](A) => B)))
# 5	instantiation	8	|- (A or B) = ([not](A) => B)
# 	A : A, B : B
# 6	instantiation	9	|- [not]([not](A) => B) => (((A or B) = ([not](A) => B)) => ([not]([not](A) => B) and ((A or B) = ([not](A) => B))))
# 	A : [not]([not](A) => B), B : (A or B) = ([not](A) => B)
# 7	instantiation	10, 11	{[not](A) and [not](B)} |- [not]([not](A) => B)
# 	A : [not](A), B : B
# 8	defining_property	12	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	theorem		|- forall_{A, B | A, [not](B)} [not](A => B)
# 	proveit.logic.booleans.implication.invalid_implication
# 11	assumption		{[not](A) and [not](B)} |- [not](A) and [not](B)
# 12	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
