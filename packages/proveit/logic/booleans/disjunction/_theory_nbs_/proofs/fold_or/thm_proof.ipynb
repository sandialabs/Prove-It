# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#fold_or">fold_or</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.disjunction import binary_disjunction_def

# %%
# %proving fold_or
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="fold_or">fold_or:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b913394c21cb2d68df283290f3d3b5d4116c4a760/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/514c87ff5f02eaf4c8468c420b3eca266d3571290/dependencies.ipynb">dependencies</a>)<br>

# %%
binary_disjunction_def
# Out:
# |- forall_{A, B} ((A or B) = ([not](A) => B))

# %%
A_or_B__def = binary_disjunction_def.instantiate()
# Out:
# <strong id="A_or_B__def">A_or_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_or/b4cf94f623687f54d21955d427fc932c6dfc81830/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/22b93d8b52b075a015f35084bdc694a1ac56cccd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_or_B__def.derive_left_via_equality(assumptions=[fold_or.condition])
# Out:
# {[not](A) => B} |- A or B
# fold_or may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.fold_or is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A) => B} (A or B)
# 1	instantiation	2, 3	{[not](A) => B} |- A or B
# 	P : A or B, Q : [not](A) => B
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	modus_ponens	4, 5	{[not](A) => B} |- ([not](A) => B) and ((A or B) = ([not](A) => B))
# 4	modus_ponens	6, 7	{[not](A) => B} |- ((A or B) = ([not](A) => B)) => (([not](A) => B) and ((A or B) = ([not](A) => B)))
# 5	instantiation	8	|- (A or B) = ([not](A) => B)
# 	A : A, B : B
# 6	instantiation	9	|- ([not](A) => B) => (((A or B) = ([not](A) => B)) => (([not](A) => B) and ((A or B) = ([not](A) => B))))
# 	A : [not](A) => B, B : (A or B) = ([not](A) => B)
# 7	assumption		{[not](A) => B} |- [not](A) => B
# 8	defining_property	10	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 10	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
