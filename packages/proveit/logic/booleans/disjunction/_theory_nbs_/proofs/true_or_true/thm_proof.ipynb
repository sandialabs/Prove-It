# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#true_or_true">true_or_true</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving true_or_true
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="true_or_true">true_or_true:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/644ef198683ba1122dae29a93144c0bb33daed710/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d4abeb1ec4b9b666539dbf51239e137b3139e5660/dependencies.ipynb">dependencies</a>)<br>
# true_or_true may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.true_or_true is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- TRUE or TRUE
# 	A : TRUE, B : TRUE
# 1	theorem		|- forall_{A, B | A} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_left
# 2	theorem		|- TRUE
# 	proveit.logic.booleans.true_truth
