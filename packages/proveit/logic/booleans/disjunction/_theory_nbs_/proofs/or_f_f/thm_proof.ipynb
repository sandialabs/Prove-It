# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_f_f">or_f_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving or_f_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_f_f">or_f_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/4e6ae09189e7fdfa4842751d2c37d9938b19ca550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/5414b2682f03117bede9652cc82320a24ed031bf0/dependencies.ipynb">dependencies</a>)<br>

# %%
or_f_f.lhs.definition(auto_simplify=True) # using auto-simplification
# Out:
# |- (FALSE or FALSE) = FALSE
# or_f_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_f_f is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2*	|- (FALSE or FALSE) = FALSE
# 	A : FALSE, B : FALSE
# 1	defining_property	3	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 2	instantiation	4, 5	|- ([not](FALSE) => FALSE) = FALSE
# 	x : [not](FALSE) => FALSE, y : TRUE => FALSE, z : FALSE
# 3	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# 4	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	modus_ponens	6, 7	|- (([not](FALSE) => FALSE) = (TRUE => FALSE)) and ((TRUE => FALSE) = FALSE)
# 6	modus_ponens	8, 9	|- ((TRUE => FALSE) = FALSE) => ((([not](FALSE) => FALSE) = (TRUE => FALSE)) and ((TRUE => FALSE) = FALSE))
# 7	theorem		|- (TRUE => FALSE) = FALSE
# 	proveit.logic.booleans.implication.implies_t_f
# 8	instantiation	10	|- (([not](FALSE) => FALSE) = (TRUE => FALSE)) => (((TRUE => FALSE) = FALSE) => ((([not](FALSE) => FALSE) = (TRUE => FALSE)) and ((TRUE => FALSE) = FALSE)))
# 	A : ([not](FALSE) => FALSE) = (TRUE => FALSE), B : (TRUE => FALSE) = FALSE
# 9	instantiation	11, 12	|- ([not](FALSE) => FALSE) = (TRUE => FALSE)
# 	f(_a) : _a => FALSE, x : [not](FALSE), y : TRUE
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 12	theorem		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
