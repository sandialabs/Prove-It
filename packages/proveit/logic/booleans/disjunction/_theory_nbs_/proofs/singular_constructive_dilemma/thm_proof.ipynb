# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#singular_constructive_dilemma">singular_constructive_dilemma</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import C
from proveit.logic import TRUE, Equals
from proveit.logic.booleans.disjunction import singular_constructive_dilemma_lemma
theory = proveit.Theory() # the theorem's theory

# %%
# %proving singular_constructive_dilemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="singular_constructive_dilemma">singular_constructive_dilemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f809f331dab9bb767cdac3d0ee485f302aa77c2c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ce54cf91536af8521128da7c955cb8dd248760a10/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = singular_constructive_dilemma.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_singular_constructive_dilemma/7bc91243e3e4f4ba3d900cc6765c5b722b3bd1cf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# We will use the constrained singular constructive dilemma as a convenient Lemma to prove some $C=\top$ and deriving $C$ from there.

# %%
singular_constructive_dilemma_lemma
# Out:
# |- forall_{A, B, C in BOOLEAN | A or B, A => C, B => C} C

# %%
singular_constructive_dilemma_lemma.instantiate({C:Equals(C, TRUE)})
# Out:
# {A in BOOLEAN, B in BOOLEAN, A or B, A => C, B => C} |- C = TRUE
# singular_constructive_dilemma may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.singular_constructive_dilemma has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 1	instantiation	2, 3	{A in BOOLEAN, B in BOOLEAN, A or B, A => C, B => C} |- C
# 	A : C
# 2	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 3	instantiation	4, 5, 6, 7, 8, 9, 10	{A in BOOLEAN, B in BOOLEAN, A or B, A => C, B => C} |- C = TRUE
# 	A : A, B : B, C : C = TRUE
# 4	conjecture		|- forall_{A, B, C in BOOLEAN | A or B, A => C, B => C} C
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma_lemma
# 5	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 6	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 7	instantiation	11	|- (C = TRUE) in BOOLEAN
# 	x : C, y : TRUE
# 8	assumption		{A or B} |- A or B
# 9	deduction	12	{A => C} |- A => (C = TRUE)
# 10	deduction	13	{B => C} |- B => (C = TRUE)
# 11	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 12	instantiation	15, 14	{A => C, A} |- C = TRUE
# 	A : C
# 13	instantiation	15, 16	{B => C, B} |- C = TRUE
# 	A : C
# 14	modus ponens	17, 18	{A => C, A} |- C
# 15	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 16	modus ponens	19, 20	{B => C, B} |- C
# 17	assumption		{A => C} |- A => C
# 18	assumption		{A} |- A
# 19	assumption		{B => C} |- B => C
# 20	assumption		{B} |- B
