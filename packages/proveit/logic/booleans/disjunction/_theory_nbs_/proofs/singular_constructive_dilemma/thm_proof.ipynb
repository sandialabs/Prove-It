# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#singular_constructive_dilemma">singular_constructive_dilemma</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C
from proveit.logic import Implies, Not, Or

# %%
# %proving singular_constructive_dilemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="singular_constructive_dilemma">singular_constructive_dilemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/11983ab1c21d8b8920155338e2ebf31305c567450/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/1887b0fab47c62ad57ca46fccfacc349224446a10/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = singular_constructive_dilemma.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_singular_constructive_dilemma/305868b7c071c622f9e92cc832b4873dd193089e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Implies(A, C).deny_antecedent(assumptions=defaults.assumptions + (Not(C),))
# Out:
# {(A => C) and (B => C), [not](C)} |- [not](A)

# %%
Implies(B, C).deny_antecedent(assumptions=defaults.assumptions + (Not(C),))
# Out:
# {(A => C) and (B => C), [not](C)} |- [not](B)

# %%
Or(A, B).affirm_via_contradiction(C)
# Out:
# {A or B, (A => C) and (B => C)} |- C

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.singular_constructive_dilemma is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A or B} [forall_{C | A => C, B => C} C]
# 1	instantiation	2, 3	{A or B, (A => C) and (B => C)} |- C
# 	A : C
# 2	theorem		|- forall_{A | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	deduction	4	{A or B, (A => C) and (B => C)} |- [not](C) => FALSE
# 4	modus_ponens	5, 6	{A or B, (A => C) and (B => C), [not](C)} |- FALSE
# 5	instantiation	7, 8	{(A => C) and (B => C), [not](C)} |- (A or B) => FALSE
# 	A : A, B : B
# 6	assumption		{A or B} |- A or B
# 7	theorem		|- forall_{A, B | [not](A), [not](B)} ((A or B) => FALSE)
# 	proveit.logic.booleans.disjunction.binary_or_contradiction
# 8	modus_ponens	9, 10	{(A => C) and (B => C), [not](C)} |- [not](A) and [not](B)
# 9	modus_ponens	11, 12	{(A => C) and (B => C), [not](C)} |- [not](B) => ([not](A) and [not](B))
# 10	instantiation	14, 13	{(A => C) and (B => C), [not](C)} |- [not](B)
# 	A : B, B : C
# 11	instantiation	24	|- [not](A) => ([not](B) => ([not](A) and [not](B)))
# 	A : [not](A), B : [not](B)
# 12	instantiation	14, 15	{(A => C) and (B => C), [not](C)} |- [not](A)
# 	A : A, B : C
# 13	modus_ponens	16, 18	{(A => C) and (B => C), [not](C)} |- (B => C) and [not](C)
# 14	theorem		|- forall_{A} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 15	modus_ponens	17, 18	{(A => C) and (B => C), [not](C)} |- (A => C) and [not](C)
# 16	modus_ponens	19, 20	{(A => C) and (B => C)} |- [not](C) => ((B => C) and [not](C))
# 17	modus_ponens	21, 22	{(A => C) and (B => C)} |- [not](C) => ((A => C) and [not](C))
# 18	assumption		{[not](C)} |- [not](C)
# 19	instantiation	24	|- (B => C) => ([not](C) => ((B => C) and [not](C)))
# 	A : B => C, B : [not](C)
# 20	instantiation	23, 26	{(A => C) and (B => C)} |- B => C
# 	A : A => C, B : B => C
# 21	instantiation	24	|- (A => C) => ([not](C) => ((A => C) and [not](C)))
# 	A : A => C, B : [not](C)
# 22	instantiation	25, 26	{(A => C) and (B => C)} |- A => C
# 	A : A => C, B : B => C
# 23	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 24	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 25	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 26	assumption		{(A => C) and (B => C)} |- (A => C) and (B => C)
