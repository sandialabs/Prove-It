# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#singular_constructive_dilemma_lemma">singular_constructive_dilemma_lemma</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B, C
from proveit.logic import Implies, Not, Or
theory = proveit.Theory() # the theorem's theory

# %%
# %proving singular_constructive_dilemma_lemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="singular_constructive_dilemma_lemma">singular_constructive_dilemma_lemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e991ae62702c27a35ba07eab7f3f3ba9214a1a560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f3f3ad9131886904745d318db9ce47ed835066860/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = singular_constructive_dilemma_lemma.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a8c722cf43bae5013189e12568bf597082072ec70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Implies(A, C).deny_antecedent(assumptions=defaults.assumptions + (Not(C),))
# Out:
# {A in BOOLEAN, A => C, [not](C)} |- [not](A)

# %%
Implies(B, C).deny_antecedent(assumptions=defaults.assumptions + (Not(C),))
# Out:
# {B in BOOLEAN, B => C, [not](C)} |- [not](B)

# %%
Or(A, B).affirm_via_contradiction(C)
# Out:
# {C in BOOLEAN, A or B, A in BOOLEAN, A => C, B in BOOLEAN, B => C} |- C
# singular_constructive_dilemma_lemma may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.singular_constructive_dilemma_lemma has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C in BOOLEAN | A or B, A => C, B => C} C
# 1	instantiation	2, 3, 4	{C in BOOLEAN, A or B, A in BOOLEAN, A => C, B in BOOLEAN, B => C} |- C
# 	A : C
# 2	axiom		|- forall_{A in BOOLEAN | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	assumption		{C in BOOLEAN} |- C in BOOLEAN
# 4	deduction	5	{A or B, A in BOOLEAN, A => C, B in BOOLEAN, B => C} |- [not](C) => FALSE
# 5	instantiation	6, 7, 8, 9	{A or B, A in BOOLEAN, A => C, [not](C), B in BOOLEAN, B => C} |- FALSE
# 	A : A, B : B
# 6	theorem		|- forall_{A, B | A or B, [not](A), [not](B)} FALSE
# 	proveit.logic.booleans.disjunction.binary_or_contradiction
# 7	assumption		{A or B} |- A or B
# 8	instantiation	12, 10, 11, 15	{A in BOOLEAN, A => C, [not](C)} |- [not](A)
# 	A : A, B : C
# 9	instantiation	12, 13, 14, 15	{B in BOOLEAN, B => C, [not](C)} |- [not](B)
# 	A : B, B : C
# 10	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 11	assumption		{A => C} |- A => C
# 12	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 13	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 14	assumption		{B => C} |- B => C
# 15	assumption		{[not](C)} |- [not](C)
