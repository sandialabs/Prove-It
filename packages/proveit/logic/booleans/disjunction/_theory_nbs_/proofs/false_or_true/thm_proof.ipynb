# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#false_or_true">false_or_true</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving false_or_true
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="false_or_true">false_or_true:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/439378edc5303e14cd663a2903f838515479ff050/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/48f42b48bb3bd3164a931f632eeacc366dfc25840/dependencies.ipynb">dependencies</a>)<br>
# false_or_true may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# Attempting to use proveit.logic.booleans.disjunction.or_if_any
# which has neither been allowed nor disallowed for use in this proof.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel or raise an (e)xception?  d
# Attempting to use proveit.logic.booleans.true_truth
# which has neither been allowed nor disallowed for use in this proof.
# Hint: proveit.logic.booleans.true_truth is fully proven and based upon current proofs,
# it is safe to ALLOW.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel or raise an (e)xception?  a
# proveit.logic.booleans.disjunction.false_or_true is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- FALSE or TRUE
# 	A : FALSE, B : TRUE
# 1	theorem		|- forall_{A, B | B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_right
# 2	theorem		|- TRUE
# 	proveit.logic.booleans.true_truth
