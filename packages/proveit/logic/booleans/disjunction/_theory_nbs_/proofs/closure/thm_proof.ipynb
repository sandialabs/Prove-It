# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#closure">closure</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import Judgment
from proveit.logic.sets import EmptySet
from proveit.logic.sets.cardinality  import empty_card
from proveit import Operation, IndexedVar
from proveit.logic import Forall, InSet, Or, Boolean, in_bool, And
from proveit import A, B, Q, x, i, l, m, n, P,S
from proveit.core_expr_types import A_1_to_m
from proveit.numbers import num, Exp, Add, one, Natural, Less, zero, Greater
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural_pos
#from proveit.numbers.number_sets.integers  import empty_nat_def
from proveit.logic.booleans.disjunction  import multi_disjunction_def, empty_disjunction
from proveit.logic.booleans.disjunction import binary_closure
theory = proveit.Theory() # the theorem's theory

# %%
# %proving closure
# Out:
# closure: forall_{m in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)]

# %%
closure.instance_expr
# Out:
# forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)

# %%
fold_forall_natural_pos
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])

# %%
from proveit import Function
from proveit import P, m
induction_inst = \
    fold_forall_natural_pos.instantiate({Function(P, m):closure.instance_expr})
# Out:
# induction_inst: |- ([forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]]) => [forall_{n in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEAN)]]

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# induction_base: forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)

# %%
induction_base.prove()
# Out:
# |- forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1]
# Out:
# induction_step: forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]

# %%
in_bool_conds = induction_step.instance_expr.conditions[0]
# Out:
# in_bool_conds: (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m + 1} in BOOLEAN)

# %%
defaults.assumptions = (induction_step.conditions + [in_bool_conds])
# Out:
# defaults.assumptions: (m in NaturalPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN)

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# induction_hyp: forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)

# %% [markdown]
# ***Splitting apart the conjunction of "in Bool" conditions is an important step***

# %%
in_bool_cond_partition = in_bool_conds.partition(m)
# Out:
# in_bool_cond_partition: {m in NaturalPos} |- (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m + 1} in BOOLEAN) = (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN, A_{m + 1} in BOOLEAN)

# %%
in_bool_conds_conjunction = And(in_bool_conds).prove()
# Out:
# in_bool_conds_conjunction: {A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN)

# %%
in_bool_conds_conjunction_partition = \
    in_bool_cond_partition.sub_right_side_into(in_bool_conds_conjunction)
# Out:
# in_bool_conds_conjunction_partition: {m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (A_{m + 1} in BOOLEAN)

# %%
in_bool_conds_conjunction_partition.derive_some(0)
# Out:
# {m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN

# %% [markdown]
# ***And now we will be able to prove the induction step via binary_closure and multi_disjunction_def***

# %%
last_in_bool_cond = in_bool_conds_conjunction_partition.derive_any(1)
# Out:
# last_in_bool_cond: {m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- A_{m + 1} in BOOLEAN

# %%
A_mp1 = last_in_bool_cond.element
# Out:
# A_mp1: A_{m + 1}

# %%
binary_closure
# Out:
# |- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)

# %%
binary_conclusion = binary_closure.instantiate({A:Or(A_1_to_m), B:A_mp1})
# Out:
# binary_conclusion: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}) in BOOLEAN

# %%
multi_disjunction_eq = multi_disjunction_def.instantiate({B:A_mp1})
# Out:
# multi_disjunction_eq: {m in NaturalPos} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) = ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1})

# %%
pre_merge_conclusion = multi_disjunction_eq.sub_left_side_into(binary_conclusion)
# Out:
# pre_merge_conclusion: {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) in BOOLEAN

# %%
pre_merge_conclusion.inner_expr().element.operands.merge()
# Out:
# {m in NaturalPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN

# %%
induction_step
# Out:
# forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.derive_consequent()
# Out:
# closure has been proven.  Now simply execute "%qed".
# |- forall_{n in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEAN)]

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{n in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEAN)]
# 1	instantiation	3, 4, 5, 6*, 7*	|- ([forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]]) => [forall_{n in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{n}) in BOOLEAN)]]
# 	P(m) : forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
# 2	instantiation	8, 9, 10	|- [forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]]
# 	A : forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN), B : forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]
# 3	conjecture		|- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])
# 4	instantiation	11	|- (A_{1}, ..A_{a}.., A_{1}) = (A_{1})
# 	f(_a) : A_{_a}, i : 1
# 5	instantiation	11	|- (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{1} in BOOLEAN) = (A_{1} in BOOLEAN)
# 	f(_a) : A_{_a} in BOOLEAN, i : 1
# 6	instantiation	12, 13	{[and](A_{1} in BOOLEAN)} |- [or](A_{1}) = A_{1}
# 	A : A_{1}
# 7	instantiation	14	|- {A_{1} in BOOLEAN if [and](A_{1} in BOOLEAN). = {A_{1} in BOOLEAN if A_{1} in BOOLEAN.
# 	a : A_{1} in BOOLEAN, Q : A_{1} in BOOLEAN
# 8	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 9	generalizaton	15	|- forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)
# 10	generalizaton	16	|- forall_{m in NaturalPos | forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} [forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)]
# 11	conjecture		|- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))
# 12	conjecture		|- forall_{A in BOOLEAN} ([or](A) = A)
# 13	instantiation	17, 18	{[and](A_{1} in BOOLEAN)} |- A_{1} in BOOLEAN
# 	A : A_{1} in BOOLEAN
# 14	conjecture		|- forall_{a, Q} ({a if [and](Q). \\  = {a if Q.)
# 15	assumption		{A_{1} in BOOLEAN} |- A_{1} in BOOLEAN
# 16	instantiation	42, 48, 19, 20, 21, 22	{m in NaturalPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN
# 	n : m + 1, P(_b_{1}, .._b_{_a}.., _b_{m + 1}) : (_b_{1} or .._b_{_a}.. or _b_{m + 1}) in BOOLEAN, x : (A_{1}, ..A_{_a}.., A_{m}, A_{m + 1}), y : (A_{1}, ..A_{a}.., A_{m + 1})
# 17	conjecture		|- forall_{A | [and](A)} A
# 18	assumption		{[and](A_{1} in BOOLEAN)} |- [and](A_{1} in BOOLEAN)
# 19	instantiation	49, 57	{m in NaturalPos} |- |(A_{1}, ..A_{a}.., A_{m}, A_{m + 1})| = |(1, ..k.., m + 1)|
# 	f(_a) : A_{_a}, b : A_{m + 1}, i : m
# 20	instantiation	47, 48	{m in NaturalPos} |- |(A_{1}, ..A_{a}.., A_{m + 1})| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(a) : A_{a}
# 21	instantiation	54, 23, 24	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) in BOOLEAN
# 	P(_b) : _b in BOOLEAN, x : A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}, y : (A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}
# 22	instantiation	25, 26	{m in NaturalPos} |- (A_{1}, ..A_{a}.., A_{m}, A_{m + 1}) = (A_{1}, ..A_{a}.., A_{m + 1})
# 	f(_a) : A_{_a}, i : 1, j : m
# 23	instantiation	27, 28, 29	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1}) in BOOLEAN
# 	A : A_{1} or ..A_{_a}.. or A_{m}, B : A_{m + 1}
# 24	instantiation	30, 57	{m in NaturalPos} |- (A_{1} or ..A_{_a}.. or A_{m} or A_{m + 1}) = ((A_{1} or ..A_{_a}.. or A_{m}) or A_{m + 1})
# 	m : m, A : A, B : A_{m + 1}
# 25	conjecture		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Natural} ((f(i), ..f(a).., f(j), f(j + 1)) = (f(i), ..f(a).., f(j + 1)))
# 26	instantiation	54, 57, 31	{m in NaturalPos} |- |(A_{1}, ..A_{a}.., A_{m})| in Natural
# 	P(_a) : _a in Natural, x : |(A_{1}, ..A_{a}.., A_{m})|, y : m
# 27	conjecture		|- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)
# 28	instantiation	32, 33	{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN), m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN
# 	A : A
# 29	instantiation	34, 57, 36, 38, 37, 40	{m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- A_{m + 1} in BOOLEAN
# 	m : m, n : 0, A : (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN), B : A_{m + 1} in BOOLEAN, C : ()
# 30	axiom		|- forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} or ..A_{_a}.. or A_{m} or B) =  \\ ((A_{1} or ..A_{_a}.. or A_{m}) or B))]
# 	proveit.logic.booleans.disjunction.multi_disjunction_def
# 31	instantiation	56, 57	{m in NaturalPos} |- |(A_{1}, ..A_{a}.., A_{m})| = m
# 	i : m, f(a) : A_{a}
# 32	assumption		{forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)} |- forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
# 33	instantiation	35, 36, 57, 53, 37, 38, 39, 40	{m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
# 	l : 0, m : m, n : 1, A : (), B : (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN), C : (A_{m + 1} in BOOLEAN)
# 34	conjecture		|- forall_{m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}} B]
# 35	conjecture		|- forall_{l, m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} | A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}} (B_{1} and ..B_{_a}.. and B_{m})]
# 36	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 37	conjecture		|- |()| = |(1, ..a.., 0)|
# 38	instantiation	47, 57	{m in NaturalPos} |- |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)| = |(1, ..k.., m)|
# 	i : m, f(_a) : A_{_a} in BOOLEAN
# 39	instantiation	41	|- |(A_{m + 1} in BOOLEAN)| = |(1, ..k.., 1)|
# 	a : A_{m + 1} in BOOLEAN
# 40	instantiation	42, 48, 43, 44, 45, 46	{m in NaturalPos, A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (A_{m + 1} in BOOLEAN)
# 	n : m + 1, P(_b_{1}, .._b_{_a}.., _b_{m + 1}) : _b_{1} and .._b_{_a}.. and _b_{m + 1}, x : (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m + 1} in BOOLEAN), y : (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN, A_{m + 1} in BOOLEAN)
# 41	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 42	theorem		|- forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands
# 43	instantiation	47, 48	{m in NaturalPos} |- |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m + 1} in BOOLEAN)| = |(1, ..k.., m + 1)|
# 	i : m + 1, f(a) : A_{a} in BOOLEAN
# 44	instantiation	49, 57	{m in NaturalPos} |- |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN, A_{m + 1} in BOOLEAN)| = |(1, ..k.., m + 1)|
# 	f(a) : A_{a} in BOOLEAN, b : A_{m + 1} in BOOLEAN, i : m
# 45	assumption		{A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN} |- (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN)
# 46	instantiation	50, 51	{m in NaturalPos} |- (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m + 1} in BOOLEAN) = (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN, A_{m + 1} in BOOLEAN)
# 	f(_a) : A_{_a} in BOOLEAN, i : 1, j : m
# 47	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 48	instantiation	52, 57, 53	{m in NaturalPos} |- (m + 1) in Natural
# 	a : m, b : 1
# 49	conjecture		|- forall_{f, b} [forall_{i in Natural} (|(f(1), ..f(a).., f(i), b)| = |(1, ..k.., i + 1)|)]
# 50	axiom		|- forall_{f, i, j | |(f(i), ..f(a).., f(j))| in Natural} ((f(i), ..f(a).., f(j + 1)) =  \\ (f(i), ..f(a).., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 51	instantiation	54, 57, 55	{m in NaturalPos} |- |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)| in Natural
# 	P(_a) : _a in Natural, x : |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)|, y : m
# 52	conjecture		|- forall_{a, b in Natural} ((a + b) in Natural)
# 53	conjecture		|- 1 in Natural
# 54	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 55	instantiation	56, 57	{m in NaturalPos} |- |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)| = m
# 	i : m, f(a) : A_{a} in BOOLEAN
# 56	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = i)]
# 57	instantiation	58, 59, 60	{m in NaturalPos} |- m in Natural
# 	A : NaturalPos, B : Natural, x : m
# 58	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 59	conjecture		|- NaturalPos proper_subset Natural
# 60	assumption		{m in NaturalPos} |- m in NaturalPos
