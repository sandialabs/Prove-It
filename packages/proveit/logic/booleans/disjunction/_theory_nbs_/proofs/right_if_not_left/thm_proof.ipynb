# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#right_if_not_left">right_if_not_left</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not, Or

# %%
# %proving right_if_not_left
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="right_if_not_left">right_if_not_left:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/60bb36d75ade5ad7578aa0cbf75c0bf313cbaedd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ff9c96d7176dd89af6f178fd5ba5b814bb96f0a50/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [Or(A, B), Not(A), Not(B)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_right_if_not_left/9e9c72bfd1b143d147f0045d8457706ac66fa0100/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B = Or(A, B)
# Out:
# <strong id="A_or_B">A_or_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B.affirm_via_contradiction(B) # prove B via contradiction
# Out:
# {A or B, [not](A)} |- B
# right_if_not_left may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.right_if_not_left is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A or B, [not](A)} B
# 1	instantiation	2, 3	{(A or B) and [not](A)} |- B
# 	A : B
# 2	theorem		|- forall_{A | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	deduction	4	{(A or B) and [not](A)} |- [not](B) => FALSE
# 4	modus_ponens	5, 6	{(A or B) and [not](A), [not](B)} |- FALSE
# 5	instantiation	7, 8	{(A or B) and [not](A), [not](B)} |- (A or B) => FALSE
# 	A : A, B : B
# 6	instantiation	9, 16	{(A or B) and [not](A)} |- A or B
# 	A : A or B, B : [not](A)
# 7	theorem		|- forall_{A, B | [not](A), [not](B)} ((A or B) => FALSE)
# 	proveit.logic.booleans.disjunction.binary_or_contradiction
# 8	modus_ponens	10, 11	{(A or B) and [not](A), [not](B)} |- [not](A) and [not](B)
# 9	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 10	modus_ponens	12, 13	{(A or B) and [not](A)} |- [not](B) => ([not](A) and [not](B))
# 11	assumption		{[not](B)} |- [not](B)
# 12	instantiation	14	|- [not](A) => ([not](B) => ([not](A) and [not](B)))
# 	A : [not](A), B : [not](B)
# 13	instantiation	15, 16	{(A or B) and [not](A)} |- [not](A)
# 	A : A or B, B : [not](A)
# 14	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 15	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 16	assumption		{(A or B) and [not](A)} |- (A or B) and [not](A)
