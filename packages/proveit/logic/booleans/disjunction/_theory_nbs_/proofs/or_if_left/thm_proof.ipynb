# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_if_left">or_if_left</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import in_bool, Or
theory = proveit.Theory() # the theorem's theory

# %%
# %proving or_if_left
# Out:
# or_if_left: forall_{A, B in BOOLEAN | A} (A or B)

# %% [markdown]
# We will prove this using `unfold_is_bool_explicit`, proving $(B = \top) \lor (B = \bot)$, rather than `unfold_is_bool` to prove $B \lor (\lnot B)$.  The latter would make this proof shorter, but requires `constructive_dilemma` which will use this theorem for convenience.

# %%
defaults.assumptions = or_if_left.all_conditions()
# Out:
# defaults.assumptions: (A in BOOLEAN, B in BOOLEAN, A)

# %%
BeqT_or_BeqF = in_bool(B).unfold([in_bool(B)])
# Out:
# BeqT_or_BeqF: {B in BOOLEAN} |- (B = TRUE) or (B = FALSE)

# %%
BeqT = BeqT_or_BeqF.operands[0]
# Out:
# BeqT: B = TRUE

# %%
BeqF = BeqT_or_BeqF.operands[1]
# Out:
# BeqF: B = FALSE

# %% [markdown]
# By proving $\vdash (B = \top) \in \mathbb{B}$ and  $\vdash (B = \bot) \in \mathbb{B}$ (under no assumptions) we can force the proof to be shorter than otherwise (since it automatically deduces these assuming $B \in \mathbb{B}$ in a convoluted manner).

# %%
in_bool(BeqT).prove([])
# Out:
# |- (B = TRUE) in BOOLEAN

# %%
in_bool(BeqF).prove([])
# Out:
# |- (B = FALSE) in BOOLEAN

# %%
Or(A, B).prove([A, BeqT])
# Out:
# {A, B = TRUE} |- A or B

# %%
Or(A, B).prove([A, BeqF])
# Out:
# {A, B = FALSE} |- A or B

# %%
BeqT_or_BeqF.derive_via_singular_dilemma(Or(A, B), assumptions=[in_bool(B), A])
# Out:
# {B in BOOLEAN, A} |- A or B

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B in BOOLEAN | A} (A or B)
# 1	instantiation	2, 3, 4, 5, 6, 7	{B in BOOLEAN, A} |- A or B
# 	A : B = TRUE, B : B = FALSE, C : A or B
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	8	|- (B = TRUE) in BOOLEAN
# 	x : B, y : TRUE
# 4	instantiation	8	|- (B = FALSE) in BOOLEAN
# 	x : B, y : FALSE
# 5	instantiation	9, 10	{B in BOOLEAN} |- (B = TRUE) or (B = FALSE)
# 	A : B
# 6	deduction	11	{A} |- (B = TRUE) => (A or B)
# 7	deduction	12	{A} |- (B = FALSE) => (A or B)
# 8	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 9	conjecture		|- forall_{A in BOOLEAN} ((A = TRUE) or (A = FALSE))
# 10	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 11	instantiation	13, 16, 14	{A, B = TRUE} |- A or B
# 	A : A, B : B
# 12	instantiation	15, 16, 17	{A, B = FALSE} |- A or B
# 	A : A, B : B
# 13	theorem		|- forall_{A, B | A, B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_both
# 14	instantiation	18, 19	{B = TRUE} |- B
# 	A : B
# 15	theorem		|- forall_{A, B | A, [not](B)} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_left
# 16	assumption		{A} |- A
# 17	instantiation	20, 21	{B = FALSE} |- [not](B)
# 	A : B
# 18	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 19	assumption		{B = TRUE} |- B = TRUE
# 20	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 21	assumption		{B = FALSE} |- B = FALSE
