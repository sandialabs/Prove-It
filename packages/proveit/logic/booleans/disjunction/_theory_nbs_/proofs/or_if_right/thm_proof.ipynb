# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_if_right">or_if_right</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import B
from proveit.logic.booleans.disjunction import fold_or

# %%
# %proving or_if_right
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_if_right">or_if_right:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3628bf97964bf199a69d39eaa8914e9fe4f366d70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d6691181130f6f50f58ffd188724207727456c890/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_if_right is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | B} (A or B)
# 1	instantiation	2, 3	{B} |- A or B
# 	A : A, B : B
# 2	theorem		|- forall_{A, B | [not](A) => B} (A or B)
# 	proveit.logic.booleans.disjunction.fold_or
# 3	deduction	4	{B} |- [not](A) => B
# 4	assumption		{B} |- B
