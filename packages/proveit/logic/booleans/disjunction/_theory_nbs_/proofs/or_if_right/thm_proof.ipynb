# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_if_right">or_if_right</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import in_bool, Or
theory = proveit.Theory() # the theorem's theory

# %%
# %proving or_if_right
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_if_right">or_if_right:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e261296d68d73dde13ddb92fc09190a5d25c15470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e3724abf685745045f6437ce8d6a198b5e7dfc010/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = or_if_right.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9e842e10e693fc12be1f2ab521a071756d0fa5420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AeqT_or_AeqF = in_bool(A).unfold(assumptions=[in_bool(A)])
# Out:
# <strong id="AeqT_or_AeqF">AeqT_or_AeqF:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../__pv_it/theorems/a10dbfd9a4efbb6f30af430036ab01697a9460f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_or_if_right/7e01d8373d4d0235fe32b832897c2378738a3fd10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/theorems/a80dd87b84d6ebecfbeb8f329cbbb1f9711c031a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
AeqT = AeqT_or_AeqF.operands[0]
# Out:
# <strong id="AeqT">AeqT:</strong> <a class="ProveItLink" href="../../../../__pv_it/axioms/bd0a6a631c1aea42bd4e95c9e4e7fa7c531d32e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AeqF = AeqT_or_AeqF.operands[1]
# Out:
# <strong id="AeqF">AeqF:</strong> <a class="ProveItLink" href="../../../../__pv_it/theorems/df6506bd32d9f7c53b00f834a4c61833f27224860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# By proving $\vdash (B = \top) \in \mathbb{B}$ and  $\vdash (B = \bot) \in \mathbb{B}$ (under no assumptions) we can force the proof to be shorter than otherwise (since it automatically deduces these assuming $B \in \mathbb{B}$ in a convoluted manner).

# %%
in_bool(AeqT).prove(assumptions=[])
# Out:
# |- (A = TRUE) in BOOLEAN

# %%
in_bool(AeqF).prove(assumptions=[])
# Out:
# |- (A = FALSE) in BOOLEAN

# %%
Or(A, B).prove(assumptions=[AeqT, B])
# Out:
# {A = TRUE, B} |- A or B

# %%
Or(A, B).prove(assumptions=[AeqF, B])
# Out:
# {A = FALSE, B} |- A or B

# %%
AeqT_or_AeqF.derive_via_singular_dilemma(Or(A, B), assumptions=[in_bool(A), B])
# Out:
# {A in BOOLEAN, B} |- A or B
# or_if_right may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_if_right has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B in BOOLEAN | B} (A or B)
# 1	instantiation	2, 3, 4, 5, 6, 7	{A in BOOLEAN, B} |- A or B
# 	A : A = TRUE, B : A = FALSE, C : A or B
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	8	|- (A = TRUE) in BOOLEAN
# 	x : A, y : TRUE
# 4	instantiation	8	|- (A = FALSE) in BOOLEAN
# 	x : A, y : FALSE
# 5	instantiation	9, 10	{A in BOOLEAN} |- (A = TRUE) or (A = FALSE)
# 	A : A
# 6	deduction	11	{B} |- (A = TRUE) => (A or B)
# 7	deduction	12	{B} |- (A = FALSE) => (A or B)
# 8	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 9	conjecture		|- forall_{A in BOOLEAN} ((A = TRUE) or (A = FALSE))
# 	proveit.logic.booleans.unfold_is_bool_explicit
# 10	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 11	instantiation	13, 14, 17	{A = TRUE, B} |- A or B
# 	A : A, B : B
# 12	instantiation	15, 16, 17	{A = FALSE, B} |- A or B
# 	A : A, B : B
# 13	theorem		|- forall_{A, B | A, B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_both
# 14	instantiation	18, 19	{A = TRUE} |- A
# 	A : A
# 15	theorem		|- forall_{A, B | [not](A), B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_right
# 16	instantiation	20, 21	{A = FALSE} |- [not](A)
# 	A : A
# 17	assumption		{B} |- B
# 18	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 19	assumption		{A = TRUE} |- A = TRUE
# 20	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 21	assumption		{A = FALSE} |- A = FALSE
