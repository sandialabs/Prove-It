# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_left_if_neither">not_left_if_neither</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Or

# %%
# %proving not_left_if_neither
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_left_if_neither">not_left_if_neither:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a3b9fc0294764745ee98c59c2bed4028a10501f10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9159d684204e8e016d12a4fa47c26c09fac56a0b0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = not_left_if_neither.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_not_left_if_neither/f47f80766aefd26227e9fa4908b147150401588c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
AorB_given_A = Or(A, B).conclude_via_example(
    A, assumptions = defaults.assumptions + (A,))
# Out:
# <strong id="AorB_given_A">AorB_given_A:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_not_left_if_neither/59378f88020ca3c13eccb891a5af6ebd21afd0470/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# not_left_if_neither may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A_impl_AorB = AorB_given_A.as_implication(A)
# Out:
# <strong id="A_impl_AorB">A_impl_AorB:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_left_if_neither/d9b429f61907e5e06f8dad568068e3d2a75147350/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_left_if_neither/5f421b0d34fff1748e89ba2c386a2e28acafe3190/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_AorB.deny_antecedent()
# Out:
# {[not](A or B)} |- [not](A)

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.not_left_if_neither is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A or B)} [not](A)
# 1	instantiation	2, 3	{[not](A or B)} |- [not](A)
# 	A : A, B : A or B
# 2	theorem		|- forall_{A} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 3	modus_ponens	4, 5	{[not](A or B)} |- (A => (A or B)) and [not](A or B)
# 4	modus_ponens	6, 7	|- [not](A or B) => ((A => (A or B)) and [not](A or B))
# 5	assumption		{[not](A or B)} |- [not](A or B)
# 6	instantiation	8	|- (A => (A or B)) => ([not](A or B) => ((A => (A or B)) and [not](A or B)))
# 	A : A => (A or B), B : [not](A or B)
# 7	deduction	9	|- A => (A or B)
# 8	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 9	instantiation	10, 11	{A} |- A or B
# 	A : A, B : B
# 10	theorem		|- forall_{A, B | A} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_left
# 11	assumption		{A} |- A
