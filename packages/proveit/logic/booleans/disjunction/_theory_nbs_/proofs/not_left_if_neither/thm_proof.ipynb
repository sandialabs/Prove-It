# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_left_if_neither">not_left_if_neither</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import in_bool, Not, Or
theory = proveit.Theory() # the theorem's theory

# %%
# %proving not_left_if_neither
# Out:
# not_left_if_neither: forall_{A, B | [not](A or B)} [not](A)

# %%
defaults.assumptions = not_left_if_neither.all_conditions()
# Out:
# defaults.assumptions: ([not](A or B))

# %%
AorB_given_A = Or(A, B).conclude_via_example(A, defaults.assumptions + (A,))
# Out:
# AorB_given_A: {[not](A or B), A} |- A or B

# %%
A_impl_AorB = AorB_given_A.as_implication(A)
# Out:
# A_impl_AorB: {[not](A or B)} |- A => (A or B)

# %%
A_impl_AorB.deny_antecedent()
# Out:
# {[not](A or B)} |- [not](A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | [not](A or B)} [not](A)
# 1	instantiation	2, 6, 3, 16	{[not](A or B)} |- [not](A)
# 	A : A, B : A or B
# 2	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 3	deduction	4	{[not](A or B)} |- A => (A or B)
# 4	instantiation	5, 6, 7, 8	{[not](A or B), A} |- A or B
# 	A : A, B : B
# 5	conjecture		|- forall_{A, B in BOOLEAN | A} (A or B)
# 6	instantiation	9, 11	{[not](A or B)} |- A in BOOLEAN
# 	A : A, B : B
# 7	instantiation	10, 11	{[not](A or B)} |- B in BOOLEAN
# 	A : A, B : B
# 8	assumption		{A} |- A
# 9	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 10	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 11	instantiation	12, 13	{[not](A or B)} |- (A or B) in BOOLEAN
# 	A : A or B
# 12	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 13	instantiation	14, 15, 16	{[not](A or B)} |- [not](A or B) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : [not](A or B)
# 14	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 15	conjecture		|- TRUE in BOOLEAN
# 16	assumption		{[not](A or B)} |- [not](A or B)
