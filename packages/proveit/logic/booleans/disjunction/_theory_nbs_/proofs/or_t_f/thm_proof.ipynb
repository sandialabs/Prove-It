# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#or_t_f">or_t_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving or_t_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="or_t_f">or_t_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/60330ee6db5efb06d1adf8b0bcef3a1d453390260/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a0bb643c41f8d72ee611d66317859595aaa2c80a0/dependencies.ipynb">dependencies</a>)<br>
# or_t_f may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
or_t_f.lhs.definition(auto_simplify=True) # using auto-simplification
# Out:
# |- (TRUE or FALSE) = TRUE
# or_t_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.or_t_f is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2*	|- (TRUE or FALSE) = TRUE
# 	A : TRUE, B : FALSE
# 1	defining_property	3	|- forall_{A, B} ((A or B) = ([not](A) => B))
# 	proveit.logic.booleans.disjunction.binary_disjunction_def
# 2	instantiation	4, 5	|- ([not](TRUE) => FALSE) = TRUE
# 	x : [not](TRUE) => FALSE, y : FALSE => FALSE, z : TRUE
# 3	definition_existence		|- exists_{or} [forall_{A, B} (or(A, B) = ([not](A) => B))]
# 4	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	modus_ponens	6, 7	|- (([not](TRUE) => FALSE) = (FALSE => FALSE)) and ((FALSE => FALSE) = TRUE)
# 6	modus_ponens	8, 9	|- ((FALSE => FALSE) = TRUE) => ((([not](TRUE) => FALSE) = (FALSE => FALSE)) and ((FALSE => FALSE) = TRUE))
# 7	theorem		|- (FALSE => FALSE) = TRUE
# 	proveit.logic.booleans.implication.implies_f_f
# ...
