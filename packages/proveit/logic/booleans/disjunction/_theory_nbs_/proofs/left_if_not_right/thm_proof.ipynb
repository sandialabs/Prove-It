# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#left_if_not_right">left_if_not_right</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Not, Or

# %%
# %proving left_if_not_right
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="left_if_not_right">left_if_not_right:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1dade7d1c452b09a7649eb1f9293bda907cd24410/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d8eb7c161a2d5614f02b023443769fade8e69bef0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [Or(A, B), Not(A), Not(B)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_left_if_not_right/0177ad9070f6f9e7de4eb2d879f0f49563d68ca90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B = Or(A, B)
# Out:
# <strong id="A_or_B">A_or_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/93740805d9480eb9ad930b4e4e09b06b85ab14c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_or_B.affirm_via_contradiction(A) # prove A via contradiction
# Out:
# {A or B, [not](B)} |- A
# left_if_not_right may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.left_if_not_right is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A or B, [not](B)} A
# 1	instantiation	2, 3	{(A or B) and [not](B)} |- A
# 	A : A
# 2	theorem		|- forall_{A | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 3	deduction	4	{(A or B) and [not](B)} |- [not](A) => FALSE
# 4	modus_ponens	5, 6	{(A or B) and [not](B), [not](A)} |- FALSE
# 5	instantiation	7, 8	{(A or B) and [not](B), [not](A)} |- (A or B) => FALSE
# 	A : A, B : B
# 6	instantiation	9, 15	{(A or B) and [not](B)} |- A or B
# 	A : A or B, B : [not](B)
# 7	theorem		|- forall_{A, B | [not](A), [not](B)} ((A or B) => FALSE)
# 	proveit.logic.booleans.disjunction.binary_or_contradiction
# 8	modus_ponens	10, 11	{(A or B) and [not](B), [not](A)} |- [not](A) and [not](B)
# 9	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 10	modus_ponens	12, 13	{[not](A)} |- [not](B) => ([not](A) and [not](B))
# 11	instantiation	14, 15	{(A or B) and [not](B)} |- [not](B)
# 	A : A or B, B : [not](B)
# 12	instantiation	16	|- [not](A) => ([not](B) => ([not](A) and [not](B)))
# 	A : [not](A), B : [not](B)
# 13	assumption		{[not](A)} |- [not](A)
# 14	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 15	assumption		{(A or B) and [not](B)} |- (A or B) and [not](B)
# 16	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
