# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import Boolean, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(InSet(B, Boolean), InSet(Or(A, B), Boolean)))
# Out:
# expr: (A, B) -> {B in BOOLEAN if (A or B) in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{B \in \mathbb{B} \textrm{ if } \left(A \lor B\right) \in \mathbb{B}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {B in BOOLEAN if (A or B) in BOOLEAN.
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {B in BOOLEAN if (A or B) in BOOLEAN.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. B in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. (A or B) in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A or B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A or B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
