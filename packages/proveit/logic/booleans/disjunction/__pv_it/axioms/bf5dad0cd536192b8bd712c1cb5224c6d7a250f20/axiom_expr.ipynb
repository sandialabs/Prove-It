# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#or_t_t">or_t_t</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import or_t_t

# %%
# check that the built expression is the same as the stored expression
assert or_t_t.expr == stored_expr
assert or_t_t.expr._style_id == stored_expr._style_id
print("Passed sanity check: or_t_t matches stored_expr")
# Out:
# Passed sanity check: or_t_t matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(or_t_t.latex())
# Out:
# \vdash \left(\top \lor \top\right) = \top

# %%
# display the expression information
or_t_t.expr_info()
# Out:
# 0. (TRUE or TRUE) = TRUE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (TRUE or TRUE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. TRUE or TRUE
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (TRUE, TRUE)
#    core type: ExprTuple
#    sub-expressions: 6, 6
# 6. TRUE
#    core type: Literal
#    sub-expressions:
