# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#empty_disjunction">empty_disjunction</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans.disjunction import empty_disjunction

# %%
# %dependencies empty_disjunction
# Out:
# <h3>Theorems/conjectures that depend directly on empty_disjunction</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/empty_disjunction_eval/thm_proof.ipynb">proveit.logic.booleans.disjunction.empty_disjunction_eval</a></dt><dd><a class="ProveItLink" href="../../theorems/fb4547487f73d73e98a0ad108e025261a51f9c470/expr.ipynb"><img src="../../theorems/fb4547487f73d73e98a0ad108e025261a51f9c470/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
