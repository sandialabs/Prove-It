# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprTuple
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Or(A_1_to_m, B), Or(Or(A_1_to_m), B))
# Out:
# expr: (A_{1} or ..A_{_a}.. or A_{m} or B, (A_{1} or ..A_{_a}.. or A_{m}) or B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \lor \ldots \lor A_{m} \lor B, \left(A_{1} \lor \ldots \lor A_{m}\right) \lor B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1} or ..A_{_a}.. or A_{m} or B, (A_{1} or ..A_{_a}.. or A_{m}) or B)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{1} or ..A_{_a}.. or A_{m} or B
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (A_{1} or ..A_{_a}.. or A_{m}) or B
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. (A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 9, 6
# 4. (A_{1} or ..A_{_a}.. or A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A_{1} or ..A_{_a}.. or A_{m}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 9
# 9. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 15
#     body: 13
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. A_{_a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
