# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, ExprTuple, IndexedVar, a, m
from proveit.logic import Boolean, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([ExprRange(a, InSet(IndexedVar(A, a), Boolean), one, m)])
# Out:
# expr: ((A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A_{1} in BOOLEAN), ..(A_{a} in BOOLEAN).., (A_{m} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 4
#    end_index: 5
# 3. a -> (A_{a} in BOOLEAN)
#    core type: Lambda
#    parameter: 12
#    body: 6
# 4. 1
#    core type: Literal
#    sub-expressions:
# 5. m
#    core type: Variable
#    sub-expressions:
# 6. A_{a} in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A_{a}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A_{a}
#    core type: IndexedVar
# variable: 11
# index: 12
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
