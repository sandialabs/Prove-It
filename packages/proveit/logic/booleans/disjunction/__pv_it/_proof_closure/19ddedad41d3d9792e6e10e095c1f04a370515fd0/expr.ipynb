# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, Variable, m, n
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean, Forall, Implies, InSet, Or
from proveit.numbers import Add, NaturalPos, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(A, one)
sub_expr3 = IndexedVar(A, sub_expr1)
sub_expr4 = Add(m, one)
sub_expr5 = ExprRange(sub_expr1, sub_expr3, one, n)
expr = Implies(And(Forall(instance_param_or_params = [sub_expr2], instance_expr = InSet(sub_expr2, Boolean), domain = Boolean), Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [ExprRange(sub_expr1, sub_expr3, one, Add(m, two))], instance_expr = InSet(Or(ExprRange(sub_expr1, sub_expr3, one, sub_expr4)), Boolean), condition = ExprRange(sub_expr1, InSet(sub_expr3, Boolean), one, sub_expr4)), domain = NaturalPos, condition = Forall(instance_param_or_params = [A_1_to_m], instance_expr = InSet(Or(A_1_to_m), Boolean), domain = Boolean))), Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [sub_expr5], instance_expr = InSet(Or(sub_expr5), Boolean), domain = Boolean), domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left[\forall_{A_{1} \in \mathbb{B}}~\left(A_{1} \in \mathbb{B}\right)\right] \land \left[\forall_{m \in \mathbb{N}^+~|~\forall_{A_{1}, A_{2}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{m}\right) \in \mathbb{B}\right)}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{m + 2}~|~\left(A_{1} \in \mathbb{B}\right), \left(A_{2} \in \mathbb{B}\right), \ldots, \left(A_{m + 1} \in \mathbb{B}\right)}~\left(\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{m + 1}\right) \in \mathbb{B}\right)\right]\right]\right) \Rightarrow \left[\forall_{n \in \mathbb{N}^+}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{n} \in \mathbb{B}}~\left(\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{n}\right) \in \mathbb{B}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]]) => [forall_{n in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ([forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]], forall_{n in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]]
#    core type: Operation
#    operator: 67
#    operands: 5
# 4. forall_{n in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)]
#    core type: Operation
#    operator: 42
#    operand: 9
# 5. (forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN), forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (n -> {forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)
#    core type: Operation
#    operator: 42
#    operand: 14
# 8. forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]
#    core type: Operation
#    operator: 42
#    operand: 15
# 9. n -> {forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN) if n in NaturalPos.
#    core type: Lambda
#    parameter: 69
#    body: 13
# 10. (A_{1} -> {A_{1} in BOOLEAN if A_{1} in BOOLEAN.)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. (m -> {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (n)
#     core type: ExprTuple
#     sub-expressions: 69
# 13. {forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN) if n in NaturalPos.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. A_{1} -> {A_{1} in BOOLEAN if A_{1} in BOOLEAN.
#     core type: Lambda
#     parameter: 32
#     body: 19
# 15. m -> {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).
#     core type: Lambda
#     parameter: 83
#     body: 21
# 16. forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)
#     core type: Operation
#     operator: 42
#     operand: 27
# 17. n in NaturalPos
#     core type: Operation
#     operator: 84
#     operands: 23
# 18. (A_{1})
#     core type: ExprTuple
#     sub-expressions: 32
# 19. {A_{1} in BOOLEAN if A_{1} in BOOLEAN.
#     core type: Conditional
#     value: 24
#     condition: 24
# 20. (m)
#     core type: ExprTuple
#     sub-expressions: 83
# 21. {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. ((A_{1}, A_{2}, ..., A_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{n} in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 69, 49
# 24. A_{1} in BOOLEAN
#     core type: Operation
#     operator: 84
#     operands: 28
# 25. forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)
#     core type: Operation
#     operator: 42
#     operand: 33
# 26. (m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]
#     core type: Operation
#     operator: 67
#     operands: 30
# 27. (A_{1}, A_{2}, ..., A_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{n} in BOOLEAN).
#     core type: Lambda
#     parameters: 57\n    body: 31
# 28. (A_{1}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 32, 87
# 29. ((A_{1}, A_{2}, ..., A_{m + 2}) -> {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. (m in NaturalPos, forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. {(A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{n} in BOOLEAN).
#     core type: Conditional
#     value: 36
#     condition: 37
# 32. A_{1}
#     core type: IndexedVar
# variable: 88
# index: 82
# 33. (A_{1}, A_{2}, ..., A_{m + 2}) -> {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).
#     core type: Lambda
#     parameters: 39\n    body: 40
# 34. m in NaturalPos
#     core type: Operation
#     operator: 84
#     operands: 41
# 35. forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)
#     core type: Operation
#     operator: 42
#     operand: 50
# 36. (A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN
#     core type: Operation
#     operator: 84
#     operands: 44
# 37. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{n} in BOOLEAN)
#     core type: Operation
#     operator: 67
#     operands: 45
# 38. (1)
#     core type: ExprTuple
#     sub-expressions: 82
# 39. (A_{1}, A_{2}, ..., A_{m + 2})
#     core type: ExprTuple
#     sub-expressions: 46
# 40. {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).
#     core type: Conditional
#     value: 47
#     condition: 48
# 41. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 83, 49
# 42. forall
#     core type: Literal
#     sub-expressions:
# 43. ((A_{1}, A_{2}, ..., A_{m}) -> {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 50
# 44. (A_{1} or  A_{2} or  ... or  A_{n}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 51, 87
# 45. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 52
# 46. A_{1}, A_{2}, ..., A_{m + 2}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 82
#     end_index: 53
# 47. (A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN
#     core type: Operation
#     operator: 84
#     operands: 54
# 48. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN)
#     core type: Operation
#     operator: 67
#     operands: 55
# 49. NaturalPos
#     core type: Literal
#     sub-expressions:
# 50. (A_{1}, A_{2}, ..., A_{m}) -> {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).
#     core type: Lambda
#     parameters: 75\n    body: 56
# 51. A_{1} or  A_{2} or  ... or  A_{n}
#     core type: Operation
#     operator: 74
#     operands: 57
# 52. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 82
#     end_index: 69
# 53. m + 2
#     core type: Operation
#     operator: 77
#     operands: 58
# 54. (A_{1} or  A_{2} or  ... or  A_{m + 1}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 59, 87
# 55. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 60
# 56. {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).
#     core type: Conditional
#     value: 61
#     condition: 62
# 57. (A_{1}, A_{2}, ..., A_{n})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 83, 64
# 59. A_{1} or  A_{2} or  ... or  A_{m + 1}
#     core type: Operation
#     operator: 74
#     operands: 65
# 60. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 82
#     end_index: 73
# 61. (A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 84
#     operands: 66
# 62. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. A_{1}, A_{2}, ..., A_{n}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 82
#     end_index: 69
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. (A_{1}, A_{2}, ..., A_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 70
# 66. (A_{1} or  A_{2} or  ... or  A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 71, 87
# 67. and
#     core type: Literal
#     sub-expressions:
# 68. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 72
# 69. n
#     core type: Variable
#     sub-expressions:
# 70. A_{1}, A_{2}, ..., A_{m + 1}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 82
#     end_index: 73
# 71. A_{1} or  A_{2} or  ... or  A_{m}
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 82
#     end_index: 83
# 73. m + 1
#     core type: Operation
#     operator: 77
#     operands: 78
# 74. or
#     core type: Literal
#     sub-expressions:
# 75. (A_{1}, A_{2}, ..., A_{m})
#     core type: ExprTuple
#     sub-expressions: 79
# 76. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 90
#     body: 80
# 77. +
#     core type: Literal
#     sub-expressions:
# 78. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 83, 82
# 79. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 82
#     end_index: 83
# 80. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 84
#     operands: 85
# 81. _a -> A_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 86
# 82. 1
#     core type: Literal
#     sub-expressions:
# 83. m
#     core type: Variable
#     sub-expressions:
# 84. in
#     core type: Literal
#     sub-expressions:
# 85. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 86. A_{_a}
#     core type: IndexedVar
# variable: 88
# index: 90
# 87. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 88. A
#     core type: Variable
#     sub-expressions:
# 89. (_a)
#     core type: ExprTuple
#     sub-expressions: 90
# 90. _a
#     core type: Variable
#     sub-expressions:
