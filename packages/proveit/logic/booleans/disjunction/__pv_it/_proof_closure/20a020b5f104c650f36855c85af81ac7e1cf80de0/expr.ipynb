# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, ExprTuple, IndexedVar, Variable, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Boolean, Forall, InSet, Or
from proveit.numbers import Add, NaturalPos, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(A, one)
sub_expr3 = IndexedVar(A, sub_expr1)
sub_expr4 = Add(m, one)
expr = ExprTuple(Forall(instance_param_or_params = [sub_expr2], instance_expr = InSet(sub_expr2, Boolean), domain = Boolean), Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [ExprRange(sub_expr1, sub_expr3, one, Add(m, two))], instance_expr = InSet(Or(ExprRange(sub_expr1, sub_expr3, one, sub_expr4)), Boolean), condition = ExprRange(sub_expr1, InSet(sub_expr3, Boolean), one, sub_expr4)), domain = NaturalPos, condition = Forall(instance_param_or_params = [A_1_to_m], instance_expr = InSet(Or(A_1_to_m), Boolean), domain = Boolean)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{A_{1} \in \mathbb{B}}~\left(A_{1} \in \mathbb{B}\right), \forall_{m \in \mathbb{N}^+~|~\forall_{A_{1}, A_{2}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{m}\right) \in \mathbb{B}\right)}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{m + 2}~|~\left(A_{1} \in \mathbb{B}\right), \left(A_{2} \in \mathbb{B}\right), \ldots, \left(A_{m + 1} \in \mathbb{B}\right)}~\left(\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{m + 1}\right) \in \mathbb{B}\right)\right]\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN), forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)
#    core type: Operation
#    operator: 25
#    operand: 5
# 2. forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]
#    core type: Operation
#    operator: 25
#    operand: 6
# 3. (A_{1} -> {A_{1} in BOOLEAN if A_{1} in BOOLEAN.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (m -> {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. A_{1} -> {A_{1} in BOOLEAN if A_{1} in BOOLEAN.
#    core type: Lambda
#    parameter: 17
#    body: 8
# 6. m -> {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).
#    core type: Lambda
#    parameter: 59
#    body: 10
# 7. (A_{1})
#    core type: ExprTuple
#    sub-expressions: 17
# 8. {A_{1} in BOOLEAN if A_{1} in BOOLEAN.
#    core type: Conditional
#    value: 11
#    condition: 11
# 9. (m)
#    core type: ExprTuple
#    sub-expressions: 59
# 10. {forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. A_{1} in BOOLEAN
#     core type: Operation
#     operator: 60
#     operands: 14
# 12. forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)
#     core type: Operation
#     operator: 25
#     operand: 18
# 13. (m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]
#     core type: Operation
#     operator: 44
#     operands: 16
# 14. (A_{1}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17, 63
# 15. ((A_{1}, A_{2}, ..., A_{m + 2}) -> {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. (m in NaturalPos, forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. A_{1}
#     core type: IndexedVar
# variable: 64
# index: 58
# 18. (A_{1}, A_{2}, ..., A_{m + 2}) -> {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).
#     core type: Lambda
#     parameters: 22\n    body: 23
# 19. m in NaturalPos
#     core type: Operation
#     operator: 60
#     operands: 24
# 20. forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)
#     core type: Operation
#     operator: 25
#     operand: 31
# 21. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 22. (A_{1}, A_{2}, ..., A_{m + 2})
#     core type: ExprTuple
#     sub-expressions: 27
# 23. {(A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN).
#     core type: Conditional
#     value: 28
#     condition: 29
# 24. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 59, 30
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. ((A_{1}, A_{2}, ..., A_{m}) -> {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. A_{1}, A_{2}, ..., A_{m + 2}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 32
# 28. (A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN
#     core type: Operation
#     operator: 60
#     operands: 33
# 29. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN)
#     core type: Operation
#     operator: 44
#     operands: 34
# 30. NaturalPos
#     core type: Literal
#     sub-expressions:
# 31. (A_{1}, A_{2}, ..., A_{m}) -> {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).
#     core type: Lambda
#     parameters: 51\n    body: 35
# 32. m + 2
#     core type: Operation
#     operator: 53
#     operands: 36
# 33. (A_{1} or  A_{2} or  ... or  A_{m + 1}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 37, 63
# 34. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 38
# 35. {(A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN).
#     core type: Conditional
#     value: 39
#     condition: 40
# 36. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 59, 41
# 37. A_{1} or  A_{2} or  ... or  A_{m + 1}
#     core type: Operation
#     operator: 50
#     operands: 42
# 38. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 58
#     end_index: 49
# 39. (A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 60
#     operands: 43
# 40. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. 2
#     core type: Literal
#     sub-expressions:
# 42. (A_{1}, A_{2}, ..., A_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. (A_{1} or  A_{2} or  ... or  A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 47, 63
# 44. and
#     core type: Literal
#     sub-expressions:
# 45. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 48
# 46. A_{1}, A_{2}, ..., A_{m + 1}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 49
# 47. A_{1} or  A_{2} or  ... or  A_{m}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 58
#     end_index: 59
# 49. m + 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. or
#     core type: Literal
#     sub-expressions:
# 51. (A_{1}, A_{2}, ..., A_{m})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 66
#     body: 56
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 55. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 56. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. _a -> A_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 62
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. m
#     core type: Variable
#     sub-expressions:
# 60. in
#     core type: Literal
#     sub-expressions:
# 61. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. A_{_a}
#     core type: IndexedVar
# variable: 64
# index: 66
# 63. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 64. A
#     core type: Variable
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
