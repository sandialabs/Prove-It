# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, IndexedVar, Lambda, Variable, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean, Forall, InSet, Or
from proveit.numbers import Add, NaturalPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [Boolean]
sub_expr3 = ExprRange(sub_expr1, IndexedVar(A, sub_expr1), one, Add(m, one))
expr = Lambda(m, Conditional(Forall([sub_expr3], InSet(Or(sub_expr3), Boolean), domains = sub_expr2), And(InSet(m, NaturalPos), Forall([A_1_to_m], InSet(Or(A_1_to_m), Boolean), domains = sub_expr2))))
# Out:
# expr: m -> {forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{A_{1}, \ldots, A_{m + 1} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m + 1}\right) \in \mathbb{B}\right) \textrm{ if } m \in \mathbb{N}^+ ,  \forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN).
#    core type: Lambda
#    parameter: 39
#    body: 1
# 1. {forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN) if m in NaturalPos ,  forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A_{1}, ..A_{_a}.., A_{m + 1} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN)
#    core type: Operation
#    operator: 12
#    operand: 4
# 3. (m in NaturalPos) and [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)]
#    core type: Operation
#    operator: 24
#    operands: 5
# 4. (A_{1}, ..A_{_a}.., A_{m + 1}) -> {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).
#    core type: Lambda
#    parameters: 22\n   body: 6
# 5. (m in NaturalPos, forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {(A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN).
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. m in NaturalPos
#    core type: Operation
#    operator: 40
#    operands: 11
# 8. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. (A_{1} or ..A_{_a}.. or A_{m + 1}) in BOOLEAN
#    core type: Operation
#    operator: 40
#    operands: 14
# 10. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m + 1} in BOOLEAN)
#     core type: Operation
#     operator: 24
#     operands: 15
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 39, 16
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#     core type: Lambda
#     parameters: 31\n    body: 17
# 14. (A_{1} or ..A_{_a}.. or A_{m + 1}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 43
# 15. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m + 1} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. A_{1} or ..A_{_a}.. or A_{m + 1}
#     core type: Operation
#     operator: 30
#     operands: 22
# 19. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m + 1} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 38
#     end_index: 29
# 20. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 23
# 21. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (A_{1}, ..A_{_a}.., A_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 27, 43
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. A_{1}, ..A_{_a}.., A_{m + 1}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 29
# 27. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 38
#     end_index: 39
# 29. m + 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. or
#     core type: Literal
#     sub-expressions:
# 31. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 45
#     body: 36
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 36. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. _a -> A_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. A_{_a}
#     core type: IndexedVar
# variable: 44
# index: 45
# 43. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
