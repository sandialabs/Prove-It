# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, ExprTuple, IndexedVar, a, m
from proveit.core_expr_types import Len
from proveit.logic import Boolean, InSet
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(a, InSet(IndexedVar(A, a), Boolean), one, m)]), Natural)
# Out:
# expr: (|(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)|, Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}\right)|, \mathbb{N}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)|, Natural)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)|
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. Natural
#    core type: Literal
#    sub-expressions:
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (A_{1} in BOOLEAN, ..A_{a} in BOOLEAN.., A_{m} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (A_{1} in BOOLEAN), ..(A_{a} in BOOLEAN).., (A_{m} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. a -> (A_{a} in BOOLEAN)
#    core type: Lambda
#    parameter: 16
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. A_{a} in BOOLEAN
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (A_{a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A_{a}
#     core type: IndexedVar
# variable: 15
# index: 16
# 14. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
