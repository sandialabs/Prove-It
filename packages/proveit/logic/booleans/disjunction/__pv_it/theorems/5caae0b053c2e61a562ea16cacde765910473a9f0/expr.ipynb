# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(A_1_to_l, Or(B_1_to_m), C_1_to_n)
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{l}, B_{1} \lor \ldots \lor B_{m}, C_{1}, \ldots, C_{n}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 15
#    end_index: 5
# 2. B_{1} or ..B_{_a}.. or B_{m}
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. C_{1}, ..C_{_a}.., C_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 15
#    end_index: 9
# 4. _a -> A_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 10
# 5. l
#    core type: Variable
#    sub-expressions:
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. _a -> C_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 12
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. A_{_a}
#     core type: IndexedVar
# variable: 13
# index: 20
# 11. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. C_{_a}
#     core type: IndexedVar
# variable: 17
# index: 20
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. _a -> B_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
# 18. B_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
