# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, IndexedVar, Variable, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, Not, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(B, sub_expr1)
sub_expr3 = IndexedVar(A, sub_expr1)
expr = Forall(instance_param_or_params = [A_1_to_m, B_1_to_m], instance_expr = Or(ExprRange(sub_expr1, Not(sub_expr2), one, m)), domain = Boolean, conditions = [Or(ExprRange(sub_expr1, Not(sub_expr3), one, m)), ExprRange(sub_expr1, Implies(sub_expr3, sub_expr2), one, m)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A_{1}, A_{2}, \ldots, A_{m}, B_{1}, B_{2}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor  (\lnot A_{2}) \lor  \ldots \lor  (\lnot A_{m}),\left(A_{1} \Rightarrow B_{1}\right), \left(A_{2} \Rightarrow B_{2}\right), \ldots, \left(A_{m} \Rightarrow B_{m}\right)}~\left((\lnot B_{1}) \lor  (\lnot B_{2}) \lor  \ldots \lor  (\lnot B_{m})\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (A_{1}, A_{2}, ..., A_{m},B_{1}, B_{2}, ..., B_{m})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 6. A_{1}, A_{2}, ..., A_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 36
#    end_index: 37
# 7. B_{1}, B_{2}, ..., B_{m}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 36
#    end_index: 37
# 8. [not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})
#    core type: Operation
#    operator: 23
#    operands: 12
# 9. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and ([not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}))and (A_{1} => B_{1}) and  (A_{2} => B_{2}) and  ... and  (A_{m} => B_{m})
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 46
# 11. _a -> B_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 42
# 12. ([not](B_{1}), [not](B_{2}), ..., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m}))
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19
# 15. [not](B_{1}), [not](B_{2}), ..., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 36
#     end_index: 37
# 16. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 37
# 17. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 36
#     end_index: 37
# 18. [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m})
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 36
#     end_index: 37
# 20. _a -> [not](B_{_a})
#     core type: Lambda
#     parameter: 49
#     body: 26
# 21. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 27
# 22. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 28
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. ([not](A_{1}), [not](A_{2}), ..., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 29
# 25. _a -> (A_{_a} => B_{_a})
#     core type: Lambda
#     parameter: 49
#     body: 30
# 26. [not](B_{_a})
#     core type: Operation
#     operator: 43
#     operand: 42
# 27. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 33
#     operands: 32
# 28. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. [not](A_{1}), [not](A_{2}), ..., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 30. A_{_a} => B_{_a}
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. (B_{_a})
#     core type: ExprTuple
#     sub-expressions: 42
# 32. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 46, 40
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 40
# 35. _a -> [not](A_{_a})
#     core type: Lambda
#     parameter: 49
#     body: 41
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. =>
#     core type: Literal
#     sub-expressions:
# 39. (A_{_a}, B_{_a})
#     core type: ExprTuple
#     sub-expressions: 46, 42
# 40. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 41. [not](A_{_a})
#     core type: Operation
#     operator: 43
#     operand: 46
# 42. B_{_a}
#     core type: IndexedVar
# variable: 45
# index: 49
# 43. not
#     core type: Literal
#     sub-expressions:
# 44. (A_{_a})
#     core type: ExprTuple
#     sub-expressions: 46
# 45. B
#     core type: Variable
#     sub-expressions:
# 46. A_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 47. A
#     core type: Variable
#     sub-expressions:
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 49. _a
#     core type: Variable
#     sub-expressions:
