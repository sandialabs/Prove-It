# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Boolean, Forall, Not, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], A, domains = [Boolean, Boolean], conditions = [Or(A, B), Not(B)])
# Out:
# expr: forall_{A, B in BOOLEAN | A or B, [not](B)} A

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B \in \mathbb{B}~|~A \lor B, \lnot B}~A

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B in BOOLEAN | A or B, [not](B)} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A if A in BOOLEAN ,  B in BOOLEAN ,  A or B ,  [not](B).
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {A if A in BOOLEAN ,  B in BOOLEAN ,  A or B ,  [not](B).
#    core type: Conditional
#    value: 18
#    condition: 4
# 4. (A in BOOLEAN) and (B in BOOLEAN) and (A or B) and [not](B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEAN, B in BOOLEAN, A or B, [not](B))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. A in BOOLEAN
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B in BOOLEAN
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. A or B
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 19
# 11. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (A, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
