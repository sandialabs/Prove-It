# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Or(A_1_to_l, Or(B_1_to_m), C_1_to_n), Or(A_1_to_l, B_1_to_m, C_1_to_n))
# Out:
# expr: {A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A_{1} \lor \ldots \lor A_{l} \lor \left(B_{1} \lor \ldots \lor B_{m}\right) \lor C_{1} \lor \ldots \lor C_{n} \textrm{ if } A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C_{1} \lor \ldots \lor C_{n}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n} if A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 5, 7
# 4. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 14, 7
# 5. B_{1} or ..B_{_a}.. or B_{m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 18
#    end_index: 11
# 7. C_{1}, ..C_{_a}.., C_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 18
#    end_index: 13
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 14
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 15
# 11. l
#     core type: Variable
#     sub-expressions:
# 12. _a -> C_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 16
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 15. A_{_a}
#     core type: IndexedVar
# variable: 20
# index: 24
# 16. C_{_a}
#     core type: IndexedVar
# variable: 21
# index: 24
# 17. _a -> B_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. C
#     core type: Variable
#     sub-expressions:
# 22. B_{_a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 23. B
#     core type: Variable
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
