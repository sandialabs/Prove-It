# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import Boolean, Equals, Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [A_1_to_l, B_1_to_m, C, D_1_to_n], instance_expr = Equals(Or(A_1_to_l, B_1_to_m, C, D_1_to_n), Or(A_1_to_l, C, B_1_to_m, D_1_to_n)).with_wrapping_at(2), domain = Boolean)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m} \lor C\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor C\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 17\n   body: 4
# 4. {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and (C in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}, A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), C in BOOLEAN,(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 36
#     end_index: 32
# 14. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 36
#     end_index: 34
# 15. C in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 22
# 16. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 36
#     end_index: 37
# 17. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m}, C,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25, 29, 26
# 18. or
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, A_{2}, ..., A_{l}, C,B_{1}, B_{2}, ..., B_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 29, 25, 26
# 20. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 27
# 21. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 28
# 22. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 29, 45
# 23. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 30
# 24. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 36
#     end_index: 32
# 25. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 36
#     end_index: 34
# 26. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 27. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 38
# 28. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 39
# 29. C
#     core type: Variable
#     sub-expressions:
# 30. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 41
# 31. _a -> A_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 42
# 32. l
#     core type: Variable
#     sub-expressions:
# 33. _a -> B_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 43
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. _a -> D_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 44
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 45
# 39. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. A_{_a}
#     core type: IndexedVar
# variable: 46
# index: 50
# 43. B_{_a}
#     core type: IndexedVar
# variable: 47
# index: 50
# 44. D_{_a}
#     core type: IndexedVar
# variable: 48
# index: 50
# 45. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. B
#     core type: Variable
#     sub-expressions:
# 48. D
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 50. _a
#     core type: Variable
#     sub-expressions:
