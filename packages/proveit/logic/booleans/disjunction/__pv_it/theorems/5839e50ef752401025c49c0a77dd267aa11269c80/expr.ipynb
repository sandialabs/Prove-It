# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import Or

# %%
# build up the expression from sub-expressions
expr = Or(A_1_to_l, C, B_1_to_m, D_1_to_n)
# Out:
# expr: A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A_{1} \lor \ldots \lor A_{l} \lor C \lor B_{1} \lor \ldots \lor B_{m} \lor D_{1} \lor \ldots \lor D_{n}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. A_{1} or ..A_{_a}.. or A_{l} or C or B_{1} or ..B_{_a}.. or B_{m} or D_{1} or ..D_{_a}.. or D_{n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. A_{1}, ..A_{_a}.., A_{l}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 12
#    end_index: 8
# 4. C
#    core type: Variable
#    sub-expressions:
# 5. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 12
#    end_index: 10
# 6. D_{1}, ..D_{_a}.., D_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 7. _a -> A_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 14
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. _a -> B_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 15
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. _a -> D_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 16
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. A_{_a}
#     core type: IndexedVar
# variable: 17
# index: 20
# 15. B_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 16. D_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. D
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
