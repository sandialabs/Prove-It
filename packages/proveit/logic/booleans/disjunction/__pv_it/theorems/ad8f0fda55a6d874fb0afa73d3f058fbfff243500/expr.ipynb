# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C
from proveit.logic import And, Boolean, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = And(InSet(A, Boolean), InSet(B, Boolean), InSet(C, Boolean), Or(A, B), Implies(A, C), Implies(B, C))
# Out:
# expr: (A in BOOLEAN) and (B in BOOLEAN) and (C in BOOLEAN) and (A or B) and (A => C) and (B => C)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}\right) \land \left(B \in \mathbb{B}\right) \land \left(C \in \mathbb{B}\right) \land \left(A \lor B\right) \land \left(A \Rightarrow C\right) \land \left(B \Rightarrow C\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A in BOOLEAN) and (B in BOOLEAN) and (C in BOOLEAN) and (A or B) and (A => C) and (B => C)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEAN, B in BOOLEAN, C in BOOLEAN, A or B, A => C, B => C)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8
# 3. A in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 9
# 4. B in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 10
# 5. C in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. A or B
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. A => C
#    core type: Operation
#    operator: 16
#    operands: 15
# 8. B => C
#    core type: Operation
#    operator: 16
#    operands: 17
# 9. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 19, 18
# 10. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (A, C)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (B, C)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. C
#     core type: Variable
#     sub-expressions:
