# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#association">association</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import association

# %%
# check that the built expression is the same as the stored expression
assert association.expr == stored_expr
assert association.expr._style_id == stored_expr._style_id
print("Passed sanity check: association matches stored_expr")
# Out:
# Passed sanity check: association matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(association.latex())
# Out:
# \vdash \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C_{1}, \ldots, C_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C_{1} \lor \ldots \lor C_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor \left(B_{1} \lor \ldots \lor B_{m}\right) \lor C_{1} \lor \ldots \lor C_{n}\right) \end{array}\right)\right]

# %%
# display the expression information
association.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (l, m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 40, 55, 44
# 3. {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n}) -> {(A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.
#    core type: Lambda
#    parameters: 28\n   body: 9
# 8. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {(A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. l in Natural
#     core type: Operation
#     operator: 47
#     operands: 15
# 11. m in Natural
#     core type: Operation
#     operator: 47
#     operands: 16
# 12. n in Natural
#     core type: Operation
#     operator: 47
#     operands: 17
# 13. (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{n} in BOOLEAN)
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 40, 22
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 22
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 22
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}, A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{n} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}
#     core type: Operation
#     operator: 41
#     operands: 28
# 24. A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}
#     core type: Operation
#     operator: 41
#     operands: 29
# 25. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 54
#     end_index: 40
# 26. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 54
#     end_index: 55
# 27. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 44
# 28. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 33, 49, 35
# 29. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 33, 34, 35
# 30. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 36
# 31. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 37
# 32. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 38
# 33. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 54
#     end_index: 40
# 34. B_{1} or ..B_{_a}.. or B_{m}
#     core type: Operation
#     operator: 41
#     operands: 42
# 35. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 54
#     end_index: 44
# 36. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 47
#     operands: 45
# 37. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 47
#     operands: 46
# 38. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 47
#     operands: 48
# 39. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 50
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. or
#     core type: Literal
#     sub-expressions:
# 42. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 49
# 43. _a -> C_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 51
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 46. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 58, 52
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 50. A_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 51. C_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 52. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 53. _a -> B_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 58
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. m
#     core type: Variable
#     sub-expressions:
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. C
#     core type: Variable
#     sub-expressions:
# 58. B_{_a}
#     core type: IndexedVar
# variable: 59
# index: 60
# 59. B
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
