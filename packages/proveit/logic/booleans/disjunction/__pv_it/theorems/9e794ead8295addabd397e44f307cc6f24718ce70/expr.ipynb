# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, ExprRange, IndexedVar, Variable, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And, Boolean, Equals, InSet, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Or(A_1_to_l, B_1_to_m, C_1_to_n), Or(A_1_to_l, Or(B_1_to_m), C_1_to_n)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, l), ExprRange(sub_expr1, InSet(IndexedVar(B, sub_expr1), Boolean), one, m), ExprRange(sub_expr1, InSet(IndexedVar(C, sub_expr1), Boolean), one, n)))
# Out:
# expr: {(A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor B_{1} \lor \ldots \lor B_{m} \lor C_{1} \lor \ldots \lor C_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor \left(B_{1} \lor \ldots \lor B_{m}\right) \lor C_{1} \lor \ldots \lor C_{n}\right) \end{array} \textrm{ if } A_{1} \in \mathbb{B} ,  \ldots ,  A_{l} \in \mathbb{B} ,  B_{1} \in \mathbb{B} ,  \ldots ,  B_{m} \in \mathbb{B} ,  C_{1} \in \mathbb{B} ,  \ldots ,  C_{n} \in \mathbb{B}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{n} in BOOLEAN)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}, A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. A_{1} or ..A_{_a}.. or A_{l} or B_{1} or ..B_{_a}.. or B_{m} or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 25
#    operands: 12
# 8. A_{1} or ..A_{_a}.. or A_{l} or (B_{1} or ..B_{_a}.. or B_{m}) or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 25
#    operands: 13
# 9. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 38
#    end_index: 24
# 10. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 38
#     end_index: 39
# 11. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 38
#     end_index: 28
# 12. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 33, 19
# 13. (A_{1}, ..A_{_a}.., A_{l}, B_{1} or ..B_{_a}.. or B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 14. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 44
#     body: 20
# 15. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 44
#     body: 21
# 16. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 44
#     body: 22
# 17. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 38
#     end_index: 24
# 18. B_{1} or ..B_{_a}.. or B_{m}
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 38
#     end_index: 28
# 20. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 29
# 21. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 30
# 22. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 32
# 23. _a -> A_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 34
# 24. l
#     core type: Variable
#     sub-expressions:
# 25. or
#     core type: Literal
#     sub-expressions:
# 26. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 33
# 27. _a -> C_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 35
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 30. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 34. A_{_a}
#     core type: IndexedVar
# variable: 40
# index: 44
# 35. C_{_a}
#     core type: IndexedVar
# variable: 41
# index: 44
# 36. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 37. _a -> B_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 42
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. A
#     core type: Variable
#     sub-expressions:
# 41. C
#     core type: Variable
#     sub-expressions:
# 42. B_{_a}
#     core type: IndexedVar
# variable: 43
# index: 44
# 43. B
#     core type: Variable
#     sub-expressions:
# 44. _a
#     core type: Variable
#     sub-expressions:
