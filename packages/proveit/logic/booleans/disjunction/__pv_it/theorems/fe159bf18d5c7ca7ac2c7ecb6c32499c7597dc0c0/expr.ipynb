# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, D, ExprRange, IndexedVar, Variable, l, m, n
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, InSet, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(Or(A_1_to_l, B, C_1_to_m, D_1_to_n), Or(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, l), InSet(B, Boolean), ExprRange(sub_expr1, InSet(IndexedVar(C, sub_expr1), Boolean), one, m), ExprRange(sub_expr1, InSet(IndexedVar(D, sub_expr1), Boolean), one, n)))
# Out:
# expr: {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{m} in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor B \lor C_{1} \lor \ldots \lor C_{m} \lor D_{1} \lor \ldots \lor D_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor C_{1} \lor \ldots \lor C_{m} \lor B \lor D_{1} \lor \ldots \lor D_{n}\right) \end{array} \textrm{ if } A_{1} \in \mathbb{B} ,  \ldots ,  A_{l} \in \mathbb{B} ,  B \in \mathbb{B} ,  C_{1} \in \mathbb{B} ,  \ldots ,  C_{m} \in \mathbb{B} ,  D_{1} \in \mathbb{B} ,  \ldots ,  D_{n} \in \mathbb{B}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{m} in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B in BOOLEAN) and (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{m} in BOOLEAN) and (D_{1} in BOOLEAN) and ..(D_{_a} in BOOLEAN).. and (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}, A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{m} in BOOLEAN, D_{1} in BOOLEAN, ..D_{_a} in BOOLEAN.., D_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 32
#    end_index: 28
# 10. B in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 17
# 11. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 32
#     end_index: 30
# 12. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 32
#     end_index: 33
# 13. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 24, 21, 22
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 24, 22
# 16. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 45
#     body: 23
# 17. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 24, 41
# 18. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 45
#     body: 25
# 19. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 45
#     body: 26
# 20. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 32
#     end_index: 28
# 21. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 22. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 23. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 34
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 35
# 26. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 36
#     operands: 37
# 27. _a -> A_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 38
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. _a -> C_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 39
# 30. m
#     core type: Variable
#     sub-expressions:
# 31. _a -> D_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 40
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 38, 41
# 35. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 39, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. A_{_a}
#     core type: IndexedVar
# variable: 42
# index: 45
# 39. C_{_a}
#     core type: IndexedVar
# variable: 43
# index: 45
# 40. D_{_a}
#     core type: IndexedVar
# variable: 44
# index: 45
# 41. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 42. A
#     core type: Variable
#     sub-expressions:
# 43. C
#     core type: Variable
#     sub-expressions:
# 44. D
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
