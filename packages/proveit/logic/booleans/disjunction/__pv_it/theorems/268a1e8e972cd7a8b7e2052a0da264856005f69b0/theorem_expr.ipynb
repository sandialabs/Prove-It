# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#constructive_dilemma">constructive_dilemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import constructive_dilemma

# %%
# check that the built expression is the same as the stored expression
assert constructive_dilemma.expr == stored_expr
assert constructive_dilemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: constructive_dilemma matches stored_expr")
# Out:
# Passed sanity check: constructive_dilemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(constructive_dilemma.latex())
# Out:
# \vdash \forall_{A, B, C, D \in \mathbb{B}~|~A \lor B, A \Rightarrow C, B \Rightarrow D}~\left(C \lor D\right)

# %%
# display the expression information
constructive_dilemma.expr_info()
# Out:
# 0. forall_{A, B, C, D in BOOLEAN | A or B, A => C, B => D} (C or D)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C, D) -> {C or D if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  D in BOOLEAN ,  A or B ,  A => C ,  B => D.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C, D)
#    core type: ExprTuple
#    sub-expressions: 28, 30, 29, 31
# 4. {C or D if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  D in BOOLEAN ,  A or B ,  A => C ,  B => D.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. C or D
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. (A in BOOLEAN) and (B in BOOLEAN) and (C in BOOLEAN) and (D in BOOLEAN) and (A or B) and (A => C) and (B => D)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (C, D)
#    core type: ExprTuple
#    sub-expressions: 29, 31
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
