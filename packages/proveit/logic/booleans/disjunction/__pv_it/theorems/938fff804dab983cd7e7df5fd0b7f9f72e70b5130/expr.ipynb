# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet, Or
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([l, m, n], Conditional(Forall(instance_param_or_params = [A_1_to_l, B_1_to_m, C_1_to_n], instance_expr = Equals(Or(A_1_to_l, Or(B_1_to_m), C_1_to_n), Or(A_1_to_l, B_1_to_m, C_1_to_n)).with_wrapping_at(2), domain = Boolean), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(l, m, n\right) \mapsto \left\{\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C_{1}, C_{2}, \ldots, C_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor \left(B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m}\right)\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m}\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{n}\right) \end{array} \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 43, 56, 45
# 3. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 30\n   body: 13
# 10. l in Natural
#     core type: Operation
#     operator: 48
#     operands: 14
# 11. m in Natural
#     core type: Operation
#     operator: 48
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 48
#     operands: 16
# 13. {(A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 19
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 19
# 17. (A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{n} in BOOLEAN)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}, A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN),(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 24. A_{1} or  A_{2} or  ... or  A_{l} or (B_{1} or  B_{2} or  ... or  B_{m})or C_{1} or  C_{2} or  ... or  C_{n}
#     core type: Operation
#     operator: 40
#     operands: 29
# 25. A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m}or C_{1} or  C_{2} or  ... or  C_{n}
#     core type: Operation
#     operator: 40
#     operands: 30
# 26. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 55
#     end_index: 43
# 27. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 55
#     end_index: 56
# 28. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 55
#     end_index: 45
# 29. (A_{1}, A_{2}, ..., A_{l}, B_{1} or  B_{2} or  ... or  B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 34, 36
# 30. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 50, 36
# 31. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 37
# 32. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 38
# 33. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 39
# 34. B_{1} or  B_{2} or  ... or  B_{m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 55
#     end_index: 43
# 36. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 45
# 37. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 46
# 38. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 47
# 39. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 49
# 40. or
#     core type: Literal
#     sub-expressions:
# 41. (B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 50
# 42. _a -> A_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 51
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. _a -> C_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 52
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 47. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 59, 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 62
# 52. C_{_a}
#     core type: IndexedVar
# variable: 58
# index: 62
# 53. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 54. _a -> B_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. m
#     core type: Variable
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. C
#     core type: Variable
#     sub-expressions:
# 59. B_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 60. B
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
