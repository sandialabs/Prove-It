# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprRange, ExprTuple, IndexedVar, Variable, m, n
from proveit.logic import Boolean, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, m), InSet(B, Boolean), ExprRange(sub_expr1, InSet(IndexedVar(C, sub_expr1), Boolean), one, n), B)
# Out:
# expr: (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{n} in BOOLEAN, B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \in \mathbb{B}, \ldots, A_{m} \in \mathbb{B}, B \in \mathbb{B}, C_{1} \in \mathbb{B}, \ldots, C_{n} \in \mathbb{B}, B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{n} in BOOLEAN, B)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 11
# 1. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 8
#    end_index: 5
# 2. B in BOOLEAN
#    core type: Operation
#    operator: 14
#    operands: 6
# 3. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{n} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 4. _a -> (A_{_a} in BOOLEAN)
#    core type: Lambda
#    parameter: 21
#    body: 10
# 5. m
#    core type: Variable
#    sub-expressions:
# 6. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 18
# 7. _a -> (C_{_a} in BOOLEAN)
#    core type: Lambda
#    parameter: 21
#    body: 12
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. A_{_a}
#     core type: IndexedVar
# variable: 19
# index: 21
# 17. C_{_a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. C
#     core type: Variable
#     sub-expressions:
# 21. _a
#     core type: Variable
#     sub-expressions:
