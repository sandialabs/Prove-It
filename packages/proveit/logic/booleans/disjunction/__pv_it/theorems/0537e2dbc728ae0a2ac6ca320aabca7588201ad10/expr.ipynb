# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprRange, IndexedVar, i, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, Not, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = IndexedVar(B, i)
sub_expr2 = IndexedVar(A, i)
expr = Forall([A_1_to_m, B_1_to_m], Or(ExprRange(i, Not(sub_expr1), one, m)), domains = [Boolean, Boolean], conditions = [Or(ExprRange(i, Not(sub_expr2), one, m)), ExprRange(i, Implies(sub_expr2, sub_expr1), one, m)])
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m}, B_{1}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor \ldots \lor (\lnot A_{m}), A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left((\lnot B_{1}) \lor \ldots \lor (\lnot B_{m})\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Conditional
#    value: 7
#    condition: 8
# 5. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 34
#    end_index: 35
# 6. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 34
#    end_index: 35
# 7. [not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})
#    core type: Operation
#    operator: 22
#    operands: 11
# 8. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and ([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})) and (A_{1} => B_{1}) and ..(A_{i} => B_{i}).. and (A_{m} => B_{m})
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. _a -> A_{_a}
#    core type: Lambda
#    parameter: 43
#    body: 38
# 10. _a -> B_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 39
# 11. ([not](B_{1}), ..[not](B_{i}).., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m})
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 14. [not](B_{1}), ..[not](B_{i}).., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 34
#     end_index: 35
# 15. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 34
#     end_index: 35
# 16. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 34
#     end_index: 35
# 17. [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. (A_{1} => B_{1}), ..(A_{i} => B_{i}).., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 34
#     end_index: 35
# 19. i -> [not](B_{i})
#     core type: Lambda
#     parameter: 48
#     body: 25
# 20. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 26
# 21. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 27
# 22. or
#     core type: Literal
#     sub-expressions:
# 23. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. i -> (A_{i} => B_{i})
#     core type: Lambda
#     parameter: 48
#     body: 29
# 25. [not](B_{i})
#     core type: Operation
#     operator: 44
#     operand: 42
# 26. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 30
# 27. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 29. A_{i} => B_{i}
#     core type: Operation
#     operator: 36
#     operands: 37
# 30. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 38, 40
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 48
#     body: 41
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. m
#     core type: Variable
#     sub-expressions:
# 36. =>
#     core type: Literal
#     sub-expressions:
# 37. (A_{i}, B_{i})
#     core type: ExprTuple
#     sub-expressions: 45, 42
# 38. A_{_a}
#     core type: IndexedVar
# variable: 47
# index: 43
# 39. B_{_a}
#     core type: IndexedVar
# variable: 46
# index: 43
# 40. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 41. [not](A_{i})
#     core type: Operation
#     operator: 44
#     operand: 45
# 42. B_{i}
#     core type: IndexedVar
# variable: 46
# index: 48
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. not
#     core type: Literal
#     sub-expressions:
# 45. A_{i}
#     core type: IndexedVar
# variable: 47
# index: 48
# 46. B
#     core type: Variable
#     sub-expressions:
# 47. A
#     core type: Variable
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
