# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#leftward_commutation">leftward_commutation</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import leftward_commutation

# %%
# check that the built expression is the same as the stored expression
assert leftward_commutation.expr == stored_expr
assert leftward_commutation.expr._style_id == stored_expr._style_id
print("Passed sanity check: leftward_commutation matches stored_expr")
# Out:
# Passed sanity check: leftward_commutation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m} \lor C\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor C\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 46, 48, 51
# 4. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Lambda
#     parameters: 31\n    body: 14
# 11. l in Natural
#     core type: Operation
#     operator: 54
#     operands: 15
# 12. m in Natural
#     core type: Operation
#     operator: 54
#     operands: 16
# 13. n in Natural
#     core type: Operation
#     operator: 54
#     operands: 17
# 14. {(A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 20
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 18. (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and (C in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}, A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), C in BOOLEAN,(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29, 30
# 25. A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 32
#     operands: 31
# 26. A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 50
#     end_index: 46
# 28. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 50
#     end_index: 48
# 29. C in BOOLEAN
#     core type: Operation
#     operator: 54
#     operands: 36
# 30. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 50
#     end_index: 51
# 31. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m}, C,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 38, 39, 43, 40
# 32. or
#     core type: Literal
#     sub-expressions:
# 33. (A_{1}, A_{2}, ..., A_{l}, C,B_{1}, B_{2}, ..., B_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 38, 43, 39, 40
# 34. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 64
#     body: 41
# 35. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 64
#     body: 42
# 36. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 59
# 37. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 64
#     body: 44
# 38. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 46
# 39. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 40. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 41. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 54
#     operands: 52
# 42. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 54
#     operands: 53
# 43. C
#     core type: Variable
#     sub-expressions:
# 44. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 54
#     operands: 55
# 45. _a -> A_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 56
# 46. l
#     core type: Variable
#     sub-expressions:
# 47. _a -> B_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 57
# 48. m
#     core type: Variable
#     sub-expressions:
# 49. _a -> D_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 58
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
# 52. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 56, 59
# 53. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 57, 59
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. A_{_a}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. B_{_a}
#     core type: IndexedVar
# variable: 61
# index: 64
# 58. D_{_a}
#     core type: IndexedVar
# variable: 62
# index: 64
# 59. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 60. A
#     core type: Variable
#     sub-expressions:
# 61. B
#     core type: Variable
#     sub-expressions:
# 62. D
#     core type: Variable
#     sub-expressions:
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. _a
#     core type: Variable
#     sub-expressions:
