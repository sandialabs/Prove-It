# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#destructive_multi_dilemma">destructive_multi_dilemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import destructive_multi_dilemma

# %%
# check that the built expression is the same as the stored expression
assert destructive_multi_dilemma.expr == stored_expr
assert destructive_multi_dilemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: destructive_multi_dilemma matches stored_expr")
# Out:
# Passed sanity check: destructive_multi_dilemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(destructive_multi_dilemma.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B_{1}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor \ldots \lor (\lnot A_{m}), A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left((\lnot B_{1}) \lor \ldots \lor (\lnot B_{m})\right)\right]

# %%
# display the expression information
destructive_multi_dilemma.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})) if m in Natural.
#    core type: Lambda
#    parameter: 41
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})) if m in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in Natural
#    core type: Operation
#    operator: 37
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 41, 10
# 8. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 40
#     end_index: 41
# 12. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 40
#     end_index: 41
# 13. [not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})
#     core type: Operation
#     operator: 28
#     operands: 17
# 14. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and ([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})) and (A_{1} => B_{1}) and ..(A_{i} => B_{i}).. and (A_{m} => B_{m})
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. _a -> A_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 44
# 16. _a -> B_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 45
# 17. ([not](B_{1}), ..[not](B_{i}).., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 20
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23, 24
# 20. [not](B_{1}), ..[not](B_{i}).., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 40
#     end_index: 41
# 21. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 40
#     end_index: 41
# 22. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 40
#     end_index: 41
# 23. [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. (A_{1} => B_{1}), ..(A_{i} => B_{i}).., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 40
#     end_index: 41
# 25. i -> [not](B_{i})
#     core type: Lambda
#     parameter: 54
#     body: 31
# 26. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 32
# 27. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 33
# 28. or
#     core type: Literal
#     sub-expressions:
# 29. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 34
# 30. i -> (A_{i} => B_{i})
#     core type: Lambda
#     parameter: 54
#     body: 35
# 31. [not](B_{i})
#     core type: Operation
#     operator: 50
#     operand: 48
# 32. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 35. A_{i} => B_{i}
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 44, 46
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 39. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 54
#     body: 47
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. m
#     core type: Variable
#     sub-expressions:
# 42. =>
#     core type: Literal
#     sub-expressions:
# 43. (A_{i}, B_{i})
#     core type: ExprTuple
#     sub-expressions: 51, 48
# 44. A_{_a}
#     core type: IndexedVar
# variable: 53
# index: 49
# 45. B_{_a}
#     core type: IndexedVar
# variable: 52
# index: 49
# 46. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 47. [not](A_{i})
#     core type: Operation
#     operator: 50
#     operand: 51
# 48. B_{i}
#     core type: IndexedVar
# variable: 52
# index: 54
# 49. _a
#     core type: Variable
#     sub-expressions:
# 50. not
#     core type: Literal
#     sub-expressions:
# 51. A_{i}
#     core type: IndexedVar
# variable: 53
# index: 54
# 52. B
#     core type: Variable
#     sub-expressions:
# 53. A
#     core type: Variable
#     sub-expressions:
# 54. i
#     core type: Variable
#     sub-expressions:
