# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#destructive_multi_dilemma">destructive_multi_dilemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import destructive_multi_dilemma

# %%
# check that the built expression is the same as the stored expression
assert destructive_multi_dilemma.expr == stored_expr
assert destructive_multi_dilemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: destructive_multi_dilemma matches stored_expr")
# Out:
# Passed sanity check: destructive_multi_dilemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{m}, B_{1}, B_{2}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor  (\lnot A_{2}) \lor  \ldots \lor  (\lnot A_{m}),\left(A_{1} \Rightarrow B_{1}\right), \left(A_{2} \Rightarrow B_{2}\right), \ldots, \left(A_{m} \Rightarrow B_{m}\right)}~\left((\lnot B_{1}) \lor  (\lnot B_{2}) \lor  \ldots \lor  (\lnot B_{m})\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})) if m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})) if m in Natural.
#    core type: Lambda
#    parameter: 45
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 45
# 4. {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})) if m in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. m in Natural
#    core type: Operation
#    operator: 41
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 45, 11
# 10. (A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, A_{2}, ..., A_{m},B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 44
#     end_index: 45
# 15. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 44
#     end_index: 45
# 16. [not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})
#     core type: Operation
#     operator: 31
#     operands: 20
# 17. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and ([not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}))and (A_{1} => B_{1}) and  (A_{2} => B_{2}) and  ... and  (A_{m} => B_{m})
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. _a -> A_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 54
# 19. _a -> B_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 20. ([not](B_{1}), [not](B_{2}), ..., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m}))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 23. [not](B_{1}), [not](B_{2}), ..., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 44
#     end_index: 45
# 24. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 44
#     end_index: 45
# 25. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 44
#     end_index: 45
# 26. [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m})
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 44
#     end_index: 45
# 28. _a -> [not](B_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 34
# 29. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 57
#     body: 35
# 30. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 57
#     body: 36
# 31. or
#     core type: Literal
#     sub-expressions:
# 32. ([not](A_{1}), [not](A_{2}), ..., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 37
# 33. _a -> (A_{_a} => B_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 38
# 34. [not](B_{_a})
#     core type: Operation
#     operator: 51
#     operand: 50
# 35. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 41
#     operands: 40
# 36. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. [not](A_{1}), [not](A_{2}), ..., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 38. A_{_a} => B_{_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. (B_{_a})
#     core type: ExprTuple
#     sub-expressions: 50
# 40. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 54, 48
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 50, 48
# 43. _a -> [not](A_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 49
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. =>
#     core type: Literal
#     sub-expressions:
# 47. (A_{_a}, B_{_a})
#     core type: ExprTuple
#     sub-expressions: 54, 50
# 48. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 49. [not](A_{_a})
#     core type: Operation
#     operator: 51
#     operand: 54
# 50. B_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 51. not
#     core type: Literal
#     sub-expressions:
# 52. (A_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 53. B
#     core type: Variable
#     sub-expressions:
# 54. A_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 55. A
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
