# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#leftward_commute">leftward_commute</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import leftward_commute

# %%
# check that the built expression is the same as the stored expression
assert leftward_commute.expr == stored_expr
assert leftward_commute.expr._style_id == stored_expr._style_id
print("Passed sanity check: leftward_commute matches stored_expr")
# Out:
# Passed sanity check: leftward_commute matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C, D_{1}, D_{2}, \ldots, D_{n}~|~A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m} \lor C\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}}~\left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor C\lor B_{1} \lor  B_{2} \lor  \ldots \lor  B_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} | A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}} (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} | A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}} (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} | A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}} (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 31, 33, 36
# 4. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} | A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}} (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} | A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}} (A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n})
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n} if A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (l in Natural, m in Natural, n in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n} if A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}.
#     core type: Lambda
#     parameters: 25\n    body: 15
# 12. l in Natural
#     core type: Operation
#     operator: 18
#     operands: 16
# 13. m in Natural
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. n in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. {A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n} if A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 16. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 31, 22
# 17. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 22
# 20. A_{1} or  A_{2} or  ... or  A_{l} or Cor B_{1} or  B_{2} or  ... or  B_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 24
#     operands: 23
# 21. A_{1} or  A_{2} or  ... or  A_{l}or B_{1} or  B_{2} or  ... or  B_{m} or Cor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. (A_{1}, A_{2}, ..., A_{l}, C,B_{1}, B_{2}, ..., B_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 26, 28, 27, 29
# 24. or
#     core type: Literal
#     sub-expressions:
# 25. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m}, C,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29
# 26. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 35
#     end_index: 31
# 27. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 35
#     end_index: 33
# 28. C
#     core type: Variable
#     sub-expressions:
# 29. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 30. _a -> A_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 37
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. _a -> B_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 38
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. _a -> D_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 39
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. A_{_a}
#     core type: IndexedVar
# variable: 40
# index: 44
# 38. B_{_a}
#     core type: IndexedVar
# variable: 41
# index: 44
# 39. D_{_a}
#     core type: IndexedVar
# variable: 42
# index: 44
# 40. A
#     core type: Variable
#     sub-expressions:
# 41. B
#     core type: Variable
#     sub-expressions:
# 42. D
#     core type: Variable
#     sub-expressions:
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 44. _a
#     core type: Variable
#     sub-expressions:
