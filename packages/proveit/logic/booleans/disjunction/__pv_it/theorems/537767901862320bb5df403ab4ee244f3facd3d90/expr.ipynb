# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprTuple, Lambda, l, m, n
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet, Or
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([l, m, n], Conditional(Forall(instance_param_or_params = [A_1_to_l, B, C_1_to_m, D_1_to_n], instance_expr = Equals(Or(A_1_to_l, B, C_1_to_m, D_1_to_n), Or(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), domain = Boolean), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(l, m, n\right) \mapsto \left\{\forall_{A_{1}, A_{2}, \ldots, A_{l}, B, C_{1}, C_{2}, \ldots, C_{m}, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor B\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m} \lor B\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) \end{array} \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 45, 47, 50
# 3. {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 30\n   body: 13
# 10. l in Natural
#     core type: Operation
#     operator: 53
#     operands: 14
# 11. m in Natural
#     core type: Operation
#     operator: 53
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 53
#     operands: 16
# 13. {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 19
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 19
# 17. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN) and (B in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{m} in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}, A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN), B in BOOLEAN,(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN),(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29
# 24. A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 49
#     end_index: 45
# 27. B in BOOLEAN
#     core type: Operation
#     operator: 53
#     operands: 34
# 28. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 49
#     end_index: 47
# 29. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 49
#     end_index: 50
# 30. (A_{1}, A_{2}, ..., A_{l}, B,C_{1}, C_{2}, ..., C_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 41, 38, 39
# 31. or
#     core type: Literal
#     sub-expressions:
# 32. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{m}, B,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 41, 39
# 33. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 63
#     body: 40
# 34. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 41, 58
# 35. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 63
#     body: 42
# 36. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 63
#     body: 43
# 37. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 49
#     end_index: 45
# 38. C_{1}, C_{2}, ..., C_{m}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 49
#     end_index: 47
# 39. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 40. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 53
#     operands: 51
# 41. B
#     core type: Variable
#     sub-expressions:
# 42. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 53
#     operands: 52
# 43. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 53
#     operands: 54
# 44. _a -> A_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 55
# 45. l
#     core type: Variable
#     sub-expressions:
# 46. _a -> C_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 56
# 47. m
#     core type: Variable
#     sub-expressions:
# 48. _a -> D_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 57
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 55, 58
# 52. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. A_{_a}
#     core type: IndexedVar
# variable: 59
# index: 63
# 56. C_{_a}
#     core type: IndexedVar
# variable: 60
# index: 63
# 57. D_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 58. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 59. A
#     core type: Variable
#     sub-expressions:
# 60. C
#     core type: Variable
#     sub-expressions:
# 61. D
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
