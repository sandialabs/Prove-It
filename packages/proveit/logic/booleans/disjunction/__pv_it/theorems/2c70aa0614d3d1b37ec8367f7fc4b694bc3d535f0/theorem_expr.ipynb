# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#disjunction_eq_quantification">disjunction_eq_quantification</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import disjunction_eq_quantification

# %%
# check that the built expression is the same as the stored expression
assert disjunction_eq_quantification.expr == stored_expr
assert disjunction_eq_quantification.expr._style_id == stored_expr._style_id
print("Passed sanity check: disjunction_eq_quantification matches stored_expr")
# Out:
# Passed sanity check: disjunction_eq_quantification matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j \in \mathbb{Z}}~\left[\forall_{P~|~i \leq \left(j + 1\right)}~\left(\left(P\left(i\right) \lor  P\left(i + 1\right) \lor  \ldots \lor  P\left(j\right)\right) = \left[\exists_{k \in \{i~\ldotp \ldotp~j\}}~P\left(k\right)\right]\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j in Integer} [forall_{P | i <= (j + 1)} ((P(i) or  P(i + 1) or  ... or  P(j)) = [exists_{k in {i .. j}} P(k)])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((i, j) -> {forall_{P | i <= (j + 1)} ((P(i) or  P(i + 1) or  ... or  P(j)) = [exists_{k in {i .. j}} P(k)]) if i in Integer ,  j in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j) -> {forall_{P | i <= (j + 1)} ((P(i) or  P(i + 1) or  ... or  P(j)) = [exists_{k in {i .. j}} P(k)]) if i in Integer ,  j in Integer.
#    core type: Lambda
#    parameters: 50\n   body: 3
# 3. {forall_{P | i <= (j + 1)} ((P(i) or  P(i + 1) or  ... or  P(j)) = [exists_{k in {i .. j}} P(k)]) if i in Integer ,  j in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P | i <= (j + 1)} ((P(i) or  P(i + 1) or  ... or  P(j)) = [exists_{k in {i .. j}} P(k)])
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (i in Integer) and (j in Integer)
# ...
