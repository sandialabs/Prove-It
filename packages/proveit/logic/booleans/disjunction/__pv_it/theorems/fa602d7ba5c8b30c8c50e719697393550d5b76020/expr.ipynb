# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple
from proveit.logic import Boolean, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Boolean), InSet(B, Boolean), Or(A, B), Not(A))
# Out:
# expr: (A in BOOLEAN, B in BOOLEAN, A or B, [not](A))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}, B \in \mathbb{B}, A \lor B, \lnot A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A in BOOLEAN, B in BOOLEAN, A or B, [not](A))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. A in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 5
# 2. B in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. A or B
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. [not](A)
#    core type: Operation
#    operator: 10
#    operand: 12
# 5. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
