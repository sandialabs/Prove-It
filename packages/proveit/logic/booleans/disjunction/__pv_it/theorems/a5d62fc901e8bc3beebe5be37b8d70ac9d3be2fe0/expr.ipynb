# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Lambda, Variable, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, InSet, Not, Or
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(B, sub_expr1)
sub_expr3 = IndexedVar(A, sub_expr1)
expr = Lambda(m, Conditional(Forall(instance_param_or_params = [A_1_to_m, B_1_to_m], instance_expr = Or(ExprRange(sub_expr1, Not(sub_expr2), one, m)), domain = Boolean, conditions = [Or(ExprRange(sub_expr1, Not(sub_expr3), one, m)), ExprRange(sub_expr1, Implies(sub_expr3, sub_expr2), one, m)]), InSet(m, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# m \mapsto \left\{\forall_{A_{1}, A_{2}, \ldots, A_{m}, B_{1}, B_{2}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor  (\lnot A_{2}) \lor  \ldots \lor  (\lnot A_{m}),\left(A_{1} \Rightarrow B_{1}\right), \left(A_{2} \Rightarrow B_{2}\right), \ldots, \left(A_{m} \Rightarrow B_{m}\right)}~\left((\lnot B_{1}) \lor  (\lnot B_{2}) \lor  \ldots \lor  (\lnot B_{m})\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. m -> {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})) if m in Natural.
#    core type: Lambda
#    parameter: 43
#    body: 2
# 1. (m)
#    core type: ExprTuple
#    sub-expressions: 43
# 2. {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})) if m in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m} in BOOLEAN | [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})} ([not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. m in Natural
#    core type: Operation
#    operator: 39
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 43, 9
# 8. (A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{m}) -> {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (A_{1}, A_{2}, ..., A_{m},B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. {[not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}), (A_{1} => B_{1}) ,  (A_{2} => B_{2}) ,  ... ,  (A_{m} => B_{m}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 42
#     end_index: 43
# 13. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 42
#     end_index: 43
# 14. [not](B_{1}) or  [not](B_{2}) or  ... or  [not](B_{m})
#     core type: Operation
#     operator: 29
#     operands: 18
# 15. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and ([not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}))and (A_{1} => B_{1}) and  (A_{2} => B_{2}) and  ... and  (A_{m} => B_{m})
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> A_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 17. _a -> B_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 48
# 18. ([not](B_{1}), [not](B_{2}), ..., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 21
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m}),(A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m}))
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24, 25
# 21. [not](B_{1}), [not](B_{2}), ..., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 42
#     end_index: 43
# 22. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 42
#     end_index: 43
# 23. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 42
#     end_index: 43
# 24. [not](A_{1}) or  [not](A_{2}) or  ... or  [not](A_{m})
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (A_{1} => B_{1}), (A_{2} => B_{2}), ..., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 42
#     end_index: 43
# 26. _a -> [not](B_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 32
# 27. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 55
#     body: 33
# 28. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 55
#     body: 34
# 29. or
#     core type: Literal
#     sub-expressions:
# 30. ([not](A_{1}), [not](A_{2}), ..., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 35
# 31. _a -> (A_{_a} => B_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 36
# 32. [not](B_{_a})
#     core type: Operation
#     operator: 49
#     operand: 48
# 33. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 38
# 34. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. [not](A_{1}), [not](A_{2}), ..., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 36. A_{_a} => B_{_a}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. (B_{_a})
#     core type: ExprTuple
#     sub-expressions: 48
# 38. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 48, 46
# 41. _a -> [not](A_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 47
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. m
#     core type: Variable
#     sub-expressions:
# 44. =>
#     core type: Literal
#     sub-expressions:
# 45. (A_{_a}, B_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 48
# 46. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 47. [not](A_{_a})
#     core type: Operation
#     operator: 49
#     operand: 52
# 48. B_{_a}
#     core type: IndexedVar
# variable: 51
# index: 55
# 49. not
#     core type: Literal
#     sub-expressions:
# 50. (A_{_a})
#     core type: ExprTuple
#     sub-expressions: 52
# 51. B
#     core type: Variable
#     sub-expressions:
# 52. A_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 53. A
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
