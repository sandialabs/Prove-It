# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, i, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, InSet, Not, Or
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
sub_expr1 = IndexedVar(B, i)
sub_expr2 = IndexedVar(A, i)
expr = Conditional(Forall([A_1_to_m, B_1_to_m], Or(ExprRange(i, Not(sub_expr1), one, m)), domains = [Boolean, Boolean], conditions = [Or(ExprRange(i, Not(sub_expr2), one, m)), ExprRange(i, Implies(sub_expr2, sub_expr1), one, m)]), InSet(m, Natural))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m}, B_{1}, \ldots, B_{m} \in \mathbb{B}~|~(\lnot A_{1}) \lor \ldots \lor (\lnot A_{m}), A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left((\lnot B_{1}) \lor \ldots \lor (\lnot B_{m})\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})) if m in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} ([not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in Natural
#    core type: Operation
#    operator: 35
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 39, 8
# 6. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. {[not](B_{1}) or ..[not](B_{i}).. or [not](B_{m}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}) ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 38
#    end_index: 39
# 10. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 38
#     end_index: 39
# 11. [not](B_{1}) or ..[not](B_{i}).. or [not](B_{m})
#     core type: Operation
#     operator: 26
#     operands: 15
# 12. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and ([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})) and (A_{1} => B_{1}) and ..(A_{i} => B_{i}).. and (A_{m} => B_{m})
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 14. _a -> B_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 43
# 15. ([not](B_{1}), ..[not](B_{i}).., [not](B_{m}))
#     core type: ExprTuple
#     sub-expressions: 18
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}), A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m})
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21, 22
# 18. [not](B_{1}), ..[not](B_{i}).., [not](B_{m})
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 38
#     end_index: 39
# 19. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 38
#     end_index: 39
# 20. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 38
#     end_index: 39
# 21. [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. (A_{1} => B_{1}), ..(A_{i} => B_{i}).., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 38
#     end_index: 39
# 23. i -> [not](B_{i})
#     core type: Lambda
#     parameter: 52
#     body: 29
# 24. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 47
#     body: 30
# 25. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 47
#     body: 31
# 26. or
#     core type: Literal
#     sub-expressions:
# 27. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. i -> (A_{i} => B_{i})
#     core type: Lambda
#     parameter: 52
#     body: 33
# 29. [not](B_{i})
#     core type: Operation
#     operator: 48
#     operand: 46
# 30. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 33. A_{i} => B_{i}
#     core type: Operation
#     operator: 40
#     operands: 41
# 34. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 37. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 52
#     body: 45
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. =>
#     core type: Literal
#     sub-expressions:
# 41. (A_{i}, B_{i})
#     core type: ExprTuple
#     sub-expressions: 49, 46
# 42. A_{_a}
#     core type: IndexedVar
# variable: 51
# index: 47
# 43. B_{_a}
#     core type: IndexedVar
# variable: 50
# index: 47
# 44. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 45. [not](A_{i})
#     core type: Operation
#     operator: 48
#     operand: 49
# 46. B_{i}
#     core type: IndexedVar
# variable: 50
# index: 52
# 47. _a
#     core type: Variable
#     sub-expressions:
# 48. not
#     core type: Literal
#     sub-expressions:
# 49. A_{i}
#     core type: IndexedVar
# variable: 51
# index: 52
# 50. B
#     core type: Variable
#     sub-expressions:
# 51. A
#     core type: Variable
#     sub-expressions:
# 52. i
#     core type: Variable
#     sub-expressions:
