# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.core_expr_types import A_1_to_m, C_1_to_n
from proveit.logic import Boolean, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m, B, C_1_to_n], InSet(B, Boolean), condition = InSet(Or(A_1_to_m, B, C_1_to_n), Boolean))
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~\left(A_{1} \lor \ldots \lor A_{m} \lor B \lor C_{1} \lor \ldots \lor C_{n}\right) \in \mathbb{B}}~\left(B \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B in BOOLEAN if (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {B in BOOLEAN if (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. B in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 13. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 19
#     end_index: 17
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 16. _a -> A_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 21
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. _a -> C_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. A_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 22. C_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. C
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
