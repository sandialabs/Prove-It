# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import Boolean, Equals, Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [A_1_to_l, B, C_1_to_m, D_1_to_n], instance_expr = Equals(Or(A_1_to_l, B, C_1_to_m, D_1_to_n), Or(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), domain = Boolean)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A_{1}, A_{2}, \ldots, A_{l}, B, C_{1}, C_{2}, \ldots, C_{m}, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor B\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m} \lor B\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 17\n   body: 4
# 4. {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN) and (B in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{m} in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}, A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN), B in BOOLEAN,(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN),(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 36
#     end_index: 32
# 14. B in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 21
# 15. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 36
#     end_index: 34
# 16. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 36
#     end_index: 37
# 17. (A_{1}, A_{2}, ..., A_{l}, B,C_{1}, C_{2}, ..., C_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 28, 25, 26
# 18. or
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{m}, B,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25, 28, 26
# 20. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 27
# 21. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 28, 45
# 22. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 29
# 23. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 50
#     body: 30
# 24. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 36
#     end_index: 32
# 25. C_{1}, C_{2}, ..., C_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 36
#     end_index: 34
# 26. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 27. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 38
# 28. B
#     core type: Variable
#     sub-expressions:
# 29. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 39
# 30. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 40
#     operands: 41
# 31. _a -> A_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 42
# 32. l
#     core type: Variable
#     sub-expressions:
# 33. _a -> C_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 43
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. _a -> D_{_a}
#     core type: Lambda
#     parameter: 50
#     body: 44
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 45
# 39. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. A_{_a}
#     core type: IndexedVar
# variable: 46
# index: 50
# 43. C_{_a}
#     core type: IndexedVar
# variable: 47
# index: 50
# 44. D_{_a}
#     core type: IndexedVar
# variable: 48
# index: 50
# 45. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. C
#     core type: Variable
#     sub-expressions:
# 48. D
#     core type: Variable
#     sub-expressions:
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 50. _a
#     core type: Variable
#     sub-expressions:
