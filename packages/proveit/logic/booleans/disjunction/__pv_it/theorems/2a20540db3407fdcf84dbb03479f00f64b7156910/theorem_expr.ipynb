# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#destructive_dilemma">destructive_dilemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import destructive_dilemma

# %%
# check that the built expression is the same as the stored expression
assert destructive_dilemma.expr == stored_expr
assert destructive_dilemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: destructive_dilemma matches stored_expr")
# Out:
# Passed sanity check: destructive_dilemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(destructive_dilemma.latex())
# Out:
# \vdash \forall_{A, B, C, D \in \mathbb{B}~|~(\lnot C) \lor (\lnot D), A \Rightarrow C, B \Rightarrow D}~\left((\lnot A) \lor (\lnot B)\right)

# %%
# display the expression information
destructive_dilemma.expr_info()
# Out:
# 0. forall_{A, B, C, D in BOOLEAN | [not](C) or [not](D), A => C, B => D} ([not](A) or [not](B))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C, D) -> {[not](A) or [not](B) if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  D in BOOLEAN ,  [not](C) or [not](D) ,  A => C ,  B => D.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C, D)
#    core type: ExprTuple
#    sub-expressions: 32, 33, 34, 36
# 4. {[not](A) or [not](B) if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  D in BOOLEAN ,  [not](C) or [not](D) ,  A => C ,  B => D.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. [not](A) or [not](B)
#    core type: Operation
#    operator: 24
#    operands: 7
# 6. (A in BOOLEAN) and (B in BOOLEAN) and (C in BOOLEAN) and (D in BOOLEAN) and ([not](C) or [not](D)) and (A => C) and (B => D)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ([not](A), [not](B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A in BOOLEAN, B in BOOLEAN, C in BOOLEAN, D in BOOLEAN, [not](C) or [not](D), A => C, B => D)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16, 17, 18
# 10. [not](A)
#     core type: Operation
#     operator: 35
#     operand: 32
# 11. [not](B)
#     core type: Operation
#     operator: 35
#     operand: 33
# 12. A in BOOLEAN
#     core type: Operation
#     operator: 22
#     operands: 19
# 13. B in BOOLEAN
#     core type: Operation
#     operator: 22
#     operands: 20
# 14. C in BOOLEAN
#     core type: Operation
#     operator: 22
#     operands: 21
# 15. D in BOOLEAN
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. [not](C) or [not](D)
#     core type: Operation
#     operator: 24
#     operands: 25
# 17. A => C
#     core type: Operation
#     operator: 27
#     operands: 26
# 18. B => D
#     core type: Operation
#     operator: 27
#     operands: 28
# 19. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 32, 29
# 20. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 33, 29
# 21. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (D, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 36, 29
# 24. or
#     core type: Literal
#     sub-expressions:
# 25. ([not](C), [not](D))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. (A, C)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 27. =>
#     core type: Literal
#     sub-expressions:
# 28. (B, D)
#     core type: ExprTuple
#     sub-expressions: 33, 36
# 29. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 30. [not](C)
#     core type: Operation
#     operator: 35
#     operand: 34
# 31. [not](D)
#     core type: Operation
#     operator: 35
#     operand: 36
# 32. A
#     core type: Variable
#     sub-expressions:
# 33. B
#     core type: Variable
#     sub-expressions:
# 34. C
#     core type: Variable
#     sub-expressions:
# 35. not
#     core type: Literal
#     sub-expressions:
# 36. D
#     core type: Variable
#     sub-expressions:
