# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#singular_constructive_dilemma_lemma">singular_constructive_dilemma_lemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import singular_constructive_dilemma_lemma

# %%
# check that the built expression is the same as the stored expression
assert singular_constructive_dilemma_lemma.expr == stored_expr
assert singular_constructive_dilemma_lemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: singular_constructive_dilemma_lemma matches stored_expr")
# Out:
# Passed sanity check: singular_constructive_dilemma_lemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(singular_constructive_dilemma_lemma.latex())
# Out:
# \vdash \forall_{A, B, C \in \mathbb{B}~|~A \lor B, A \Rightarrow C, B \Rightarrow C}~C

# %%
# display the expression information
singular_constructive_dilemma_lemma.expr_info()
# Out:
# 0. forall_{A, B, C in BOOLEAN | A or B, A => C, B => C} C
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {C if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  A or B ,  A => C ,  B => C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 24, 25, 26
# 4. {C if A in BOOLEAN ,  B in BOOLEAN ,  C in BOOLEAN ,  A or B ,  A => C ,  B => C.
#    core type: Conditional
#    value: 26
#    condition: 5
# 5. (A in BOOLEAN) and (B in BOOLEAN) and (C in BOOLEAN) and (A or B) and (A => C) and (B => C)
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A in BOOLEAN, B in BOOLEAN, C in BOOLEAN, A or B, A => C, B => C)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 8. A in BOOLEAN
#    core type: Operation
#    operator: 16
#    operands: 14
# ...
