# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Boolean, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_m], InSet(Or(A_1_to_m), Boolean), domains = [Boolean])
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 22
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A_{1} or ..A_{_a}.. or A_{m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 18
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 24
#     body: 15
# 14. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> A_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. A_{_a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 22. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
