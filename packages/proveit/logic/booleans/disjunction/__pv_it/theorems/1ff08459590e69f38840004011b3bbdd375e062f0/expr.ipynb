# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import Boolean, Equals, Forall, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_l, B, C_1_to_m, D_1_to_n], Equals(Or(A_1_to_l, B, C_1_to_m, D_1_to_n), Or(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), domains = [Boolean, Boolean, Boolean, Boolean])
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{l}, B, C_{1}, \ldots, C_{m}, D_{1}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \lor \ldots \lor A_{l} \lor B \lor C_{1} \lor \ldots \lor C_{m} \lor D_{1} \lor \ldots \lor D_{n}\right) =  \\ \left(A_{1} \lor \ldots \lor A_{l} \lor C_{1} \lor \ldots \lor C_{m} \lor B \lor D_{1} \lor \ldots \lor D_{n}\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{m} in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {(A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{m} in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}) =  \\ (A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B in BOOLEAN) and (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{m} in BOOLEAN) and (D_{1} in BOOLEAN) and ..(D_{_a} in BOOLEAN).. and (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}, A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{m} in BOOLEAN, D_{1} in BOOLEAN, ..D_{_a} in BOOLEAN.., D_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15
# 10. A_{1} or ..A_{_a}.. or A_{l} or B or C_{1} or ..C_{_a}.. or C_{m} or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. A_{1} or ..A_{_a}.. or A_{l} or C_{1} or ..C_{_a}.. or C_{m} or B or D_{1} or ..D_{_a}.. or D_{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 35
#     end_index: 31
# 13. B in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 20
# 14. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 35
#     end_index: 33
# 15. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 35
#     end_index: 36
# 16. (A_{1}, ..A_{_a}.., A_{l}, B, C_{1}, ..C_{_a}.., C_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 27, 24, 25
# 17. or
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{l}, C_{1}, ..C_{_a}.., C_{m}, B, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24, 27, 25
# 19. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 48
#     body: 26
# 20. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 27, 44
# 21. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 48
#     body: 28
# 22. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 48
#     body: 29
# 23. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 35
#     end_index: 31
# 24. C_{1}, ..C_{_a}.., C_{m}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 35
#     end_index: 33
# 25. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 35
#     end_index: 36
# 26. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 37
# 27. B
#     core type: Variable
#     sub-expressions:
# 28. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 38
# 29. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 39
#     operands: 40
# 30. _a -> A_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 41
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. _a -> C_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 42
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. _a -> D_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 43
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. n
#     core type: Variable
#     sub-expressions:
# 37. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 41, 44
# 38. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. A_{_a}
#     core type: IndexedVar
# variable: 45
# index: 48
# 42. C_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 43. D_{_a}
#     core type: IndexedVar
# variable: 47
# index: 48
# 44. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 45. A
#     core type: Variable
#     sub-expressions:
# 46. C
#     core type: Variable
#     sub-expressions:
# 47. D
#     core type: Variable
#     sub-expressions:
# 48. _a
#     core type: Variable
#     sub-expressions:
