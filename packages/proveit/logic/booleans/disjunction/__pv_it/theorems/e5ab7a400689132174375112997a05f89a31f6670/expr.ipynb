# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Lambda, i, m
from proveit.core_expr_types import A_1_to_m, B_1_to_m
from proveit.logic import Boolean, Forall, Implies, InSet, Or
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([A_1_to_m, B_1_to_m], Or(B_1_to_m), domains = [Boolean, Boolean], conditions = [Or(A_1_to_m), ExprRange(i, Implies(IndexedVar(A, i), IndexedVar(B, i)), one, m)]), InSet(m, Natural)))
# Out:
# expr: m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m}) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{A_{1}, \ldots, A_{m}, B_{1}, \ldots, B_{m} \in \mathbb{B}~|~A_{1} \lor \ldots \lor A_{m}, A_{1} \Rightarrow B_{1}, \ldots, A_{m} \Rightarrow B_{m}}~\left(B_{1} \lor \ldots \lor B_{m}\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m}) if m in Natural.
#    core type: Lambda
#    parameter: 35
#    body: 1
# 1. {forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m}) if m in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m} in BOOLEAN | A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m}} (B_{1} or ..B_{_a}.. or B_{m})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. m in Natural
#    core type: Operation
#    operator: 31
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m}) -> {B_{1} or ..B_{_a}.. or B_{m} if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m} ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 35, 9
# 7. (A_{1}, ..A_{_a}.., A_{m}, B_{1}, ..B_{_a}.., B_{m})
#    core type: ExprTuple
#    sub-expressions: 28, 15
# 8. {B_{1} or ..B_{_a}.. or B_{m} if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{m} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  A_{1} or ..A_{_a}.. or A_{m} ,  A_{1} => B_{1} ,  ..A_{i} => B_{i}.. ,  A_{m} => B_{m}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. B_{1} or ..B_{_a}.. or B_{m}
#     core type: Operation
#     operator: 23
#     operands: 12
# 11. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (A_{1} or ..A_{_a}.. or A_{m}) and (A_{1} => B_{1}) and ..(A_{i} => B_{i}).. and (A_{m} => B_{m})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, A_{1} or ..A_{_a}.. or A_{m}, A_{1} => B_{1}, ..A_{i} => B_{i}.., A_{m} => B_{m})
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19
# 15. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 34
#     end_index: 35
# 16. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 34
#     end_index: 35
# 17. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 34
#     end_index: 35
# 18. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (A_{1} => B_{1}), ..(A_{i} => B_{i}).., (A_{m} => B_{m})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 34
#     end_index: 35
# 20. _a -> B_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 38
# 21. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 26
# 22. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 27
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. i -> (A_{i} => B_{i})
#     core type: Lambda
#     parameter: 46
#     body: 29
# 26. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 30
# 27. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 29. A_{i} => B_{i}
#     core type: Operation
#     operator: 36
#     operands: 37
# 30. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 39
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 33. _a -> A_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 40
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. m
#     core type: Variable
#     sub-expressions:
# 36. =>
#     core type: Literal
#     sub-expressions:
# 37. (A_{i}, B_{i})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. B_{_a}
#     core type: IndexedVar
# variable: 45
# index: 43
# 39. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 40. A_{_a}
#     core type: IndexedVar
# variable: 44
# index: 43
# 41. A_{i}
#     core type: IndexedVar
# variable: 44
# index: 46
# 42. B_{i}
#     core type: IndexedVar
# variable: 45
# index: 46
# 43. _a
#     core type: Variable
#     sub-expressions:
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. B
#     core type: Variable
#     sub-expressions:
# 46. i
#     core type: Variable
#     sub-expressions:
