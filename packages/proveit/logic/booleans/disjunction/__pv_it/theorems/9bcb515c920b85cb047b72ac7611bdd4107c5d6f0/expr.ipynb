# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, l, m, n
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet, Or
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [A_1_to_l, B, C_1_to_m, D_1_to_n], instance_expr = Equals(Or(A_1_to_l, B, C_1_to_m, D_1_to_n), Or(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), domain = Boolean), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{A_{1}, A_{2}, \ldots, A_{l}, B, C_{1}, C_{2}, \ldots, C_{m}, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l} \lor B\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m}\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) =  \\ \left(A_{1} \lor  A_{2} \lor  \ldots \lor  A_{l}\lor C_{1} \lor  C_{2} \lor  \ldots \lor  C_{m} \lor B\lor D_{1} \lor  D_{2} \lor  \ldots \lor  D_{n}\right) \end{array} \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 19
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 27\n   body: 10
# 7. l in Natural
#    core type: Operation
#    operator: 50
#    operands: 11
# 8. m in Natural
#    core type: Operation
#    operator: 50
#    operands: 12
# 9. n in Natural
#    core type: Operation
#    operator: 50
#    operands: 13
# 10. {(A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 16
# 12. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 16
# 13. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 16
# 14. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}) =  \\ (A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN) and (B in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{m} in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}, A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN), B in BOOLEAN,(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN),(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26
# 21. A_{1} or  A_{2} or  ... or  A_{l} or Bor C_{1} or  C_{2} or  ... or  C_{m}or D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 28
#     operands: 27
# 22. A_{1} or  A_{2} or  ... or  A_{l}or C_{1} or  C_{2} or  ... or  C_{m} or Bor D_{1} or  D_{2} or  ... or  D_{n}
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 46
#     end_index: 42
# 24. B in BOOLEAN
#     core type: Operation
#     operator: 50
#     operands: 31
# 25. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 46
#     end_index: 44
# 26. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 46
#     end_index: 47
# 27. (A_{1}, A_{2}, ..., A_{l}, B,C_{1}, C_{2}, ..., C_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 38, 35, 36
# 28. or
#     core type: Literal
#     sub-expressions:
# 29. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{m}, B,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 35, 38, 36
# 30. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 37
# 31. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 38, 55
# 32. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 39
# 33. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 60
#     body: 40
# 34. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 46
#     end_index: 42
# 35. C_{1}, C_{2}, ..., C_{m}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 46
#     end_index: 44
# 36. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 37. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 50
#     operands: 48
# 38. B
#     core type: Variable
#     sub-expressions:
# 39. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 50
#     operands: 49
# 40. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 50
#     operands: 51
# 41. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 52
# 42. l
#     core type: Variable
#     sub-expressions:
# 43. _a -> C_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. _a -> D_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 52, 55
# 49. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. A_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 53. C_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 54. D_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 55. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. C
#     core type: Variable
#     sub-expressions:
# 58. D
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
