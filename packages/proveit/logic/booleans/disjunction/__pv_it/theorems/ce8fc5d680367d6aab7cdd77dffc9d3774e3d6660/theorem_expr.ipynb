# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#each_is_bool">each_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import each_is_bool

# %%
# check that the built expression is the same as the stored expression
assert each_is_bool.expr == stored_expr
assert each_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: each_is_bool matches stored_expr")
# Out:
# Passed sanity check: each_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(each_is_bool.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B, C_{1}, \ldots, C_{n}~|~\left(A_{1} \lor \ldots \lor A_{m} \lor B \lor C_{1} \lor \ldots \lor C_{n}\right) \in \mathbb{B}}~\left(B \in \mathbb{B}\right)\right]

# %%
# display the expression information
each_is_bool.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN)]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, n) -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n)
#    core type: ExprTuple
#    sub-expressions: 29, 32
# 3. {forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n} | (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN} (B in BOOLEAN)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n}) -> {B in BOOLEAN if (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN.
#    core type: Lambda
#    parameters: 24\n   body: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {B in BOOLEAN if (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. m in Natural
#     core type: Operation
#     operator: 18
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 18
#     operands: 16
# 13. B in BOOLEAN
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}) in BOOLEAN
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 29, 20
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 20
# 17. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. A_{1} or ..A_{_a}.. or A_{m} or B or C_{1} or ..C_{_a}.. or C_{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 25. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 31
#     end_index: 29
# 26. B
#     core type: Variable
#     sub-expressions:
# 27. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 28. _a -> A_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 33
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. _a -> C_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 34
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. A_{_a}
#     core type: IndexedVar
# variable: 35
# index: 37
# 34. C_{_a}
#     core type: IndexedVar
# variable: 36
# index: 37
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. C
#     core type: Variable
#     sub-expressions:
# 37. _a
#     core type: Variable
#     sub-expressions:
