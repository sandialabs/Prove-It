# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Boolean, Forall, InSet, Or
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m], InSet(Or(A_1_to_m), Boolean), domains = [Boolean]), domains = [NaturalPos])
# Out:
# expr: forall_{m in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \lor \ldots \lor A_{m}\right) \in \mathbb{B}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN) if m in NaturalPos.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalPos
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Lambda
#    parameters: 18\n   body: 8
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} or ..A_{_a}.. or A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A_{1} or ..A_{_a}.. or A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. A_{1} or ..A_{_a}.. or A_{m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. or
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> A_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. A_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 29. A
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
