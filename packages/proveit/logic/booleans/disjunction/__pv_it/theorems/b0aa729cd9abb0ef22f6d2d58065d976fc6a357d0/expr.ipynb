# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Boolean, InSet

# %%
# build up the expression from sub-expressions
expr = And(InSet(A, Boolean), InSet(B, Boolean), A)
# Out:
# expr: (A in BOOLEAN) and (B in BOOLEAN) and A

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \in \mathbb{B}\right) \land \left(B \in \mathbb{B}\right) \land A

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A in BOOLEAN) and (B in BOOLEAN) and A
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEAN, B in BOOLEAN, A)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 8
# 3. A in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. B in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
