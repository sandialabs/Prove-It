# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#empty_disjunction_eval">empty_disjunction_eval</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/empty_disjunction_eval/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans.disjunction import empty_disjunction_eval

# %%
# %dependencies empty_disjunction_eval
# Out:
# <h3>Axioms required (directly or indirectly) to prove empty_disjunction_eval</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/axioms.ipynb#empty_disjunction">proveit.logic.booleans.disjunction.empty_disjunction</a></dt><dd><a class="ProveItLink" href="../../axioms/25457ba768b8e083d3aef1fb189b90f421febeae0/expr.ipynb"><img src="../../axioms/25457ba768b8e083d3aef1fb189b90f421febeae0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../negation/_theory_nbs_/axioms.ipynb#negation_elim">proveit.logic.booleans.negation.negation_elim</a></dt><dd><a class="ProveItLink" href="../../../../negation/__pv_it/axioms/9495abbd5f513bded61d958ff7a4f236116799110/expr.ipynb"><img src="../../../../negation/__pv_it/axioms/9495abbd5f513bded61d958ff7a4f236116799110/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
# <h3>Theorems/conjectures that depend directly on empty_disjunction_eval</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/unary_or_lemma/thm_proof.ipynb">proveit.logic.booleans.disjunction.unary_or_lemma</a></dt><dd><a class="ProveItLink" href="../2b4cae56333fccecf9262d93f7d7ac8577ab94190/expr.ipynb"><img src="../2b4cae56333fccecf9262d93f7d7ac8577ab94190/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
