# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#demorgans_law_and_to_or_bin">demorgans_law_and_to_or_bin</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.disjunction import demorgans_law_and_to_or_bin

# %%
# check that the built expression is the same as the stored expression
assert demorgans_law_and_to_or_bin.expr == stored_expr
assert demorgans_law_and_to_or_bin.expr._style_id == stored_expr._style_id
print("Passed sanity check: demorgans_law_and_to_or_bin matches stored_expr")
# Out:
# Passed sanity check: demorgans_law_and_to_or_bin matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(demorgans_law_and_to_or_bin.latex())
# Out:
# \vdash \forall_{A, B~|~\lnot \left((\lnot A) \land (\lnot B)\right)}~\left(A \lor B\right)

# %%
# display the expression information
demorgans_law_and_to_or_bin.expr_info()
# Out:
# 0. forall_{A, B | [not]([not](A) and [not](B))} (A or B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A or B if [not]([not](A) and [not](B)).
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {A or B if [not]([not](A) and [not](B)).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A or B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 14
#    operand: 8
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 8. [not](A) and [not](B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ([not](A), [not](B))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. [not](A)
#     core type: Operation
#     operator: 14
#     operand: 13
# 12. [not](B)
# ...
