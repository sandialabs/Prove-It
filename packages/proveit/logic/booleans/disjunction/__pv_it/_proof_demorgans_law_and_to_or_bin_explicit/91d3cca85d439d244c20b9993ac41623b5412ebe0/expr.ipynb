# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.logic import And, Boolean, InSet, Not, TRUE

# %%
# build up the expression from sub-expressions
expr = And(InSet(B, Boolean), Not(And(Not(TRUE), Not(B))))
# Out:
# expr: (B in BOOLEAN) and [not]([not](TRUE) and [not](B))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \in \mathbb{B}\right) \land (\lnot \left((\lnot \top) \land (\lnot B)\right))

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B in BOOLEAN) and [not]([not](TRUE) and [not](B))
#    core type: Operation
#    operator: 8
#    operands: 1
# 1. (B in BOOLEAN, [not]([not](TRUE) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. B in BOOLEAN
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. [not]([not](TRUE) and [not](B))
#    core type: Operation
#    operator: 13
#    operand: 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 6. [not](TRUE) and [not](B)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ([not](TRUE), [not](B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. [not](TRUE)
#     core type: Operation
#     operator: 13
#     operand: 12
# 11. [not](B)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
