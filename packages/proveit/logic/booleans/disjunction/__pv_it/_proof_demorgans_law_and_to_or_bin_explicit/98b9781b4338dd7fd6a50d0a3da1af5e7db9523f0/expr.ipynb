# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional
from proveit.logic import And, Boolean, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Or(A, B), And(InSet(A, Boolean), And(InSet(B, Boolean), Not(And(Not(A), Not(B))))))
# Out:
# expr: {A or B if A in BOOLEAN ,  (B in BOOLEAN) and [not]([not](A) and [not](B)).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \lor B \textrm{ if } A \in \mathbb{B} ,  \left(B \in \mathbb{B}\right) \land (\lnot \left((\lnot A) \land (\lnot B)\right))\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A or B if A in BOOLEAN ,  (B in BOOLEAN) and [not]([not](A) and [not](B)).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A or B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in BOOLEAN) and ((B in BOOLEAN) and [not]([not](A) and [not](B)))
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (A, B)
#    core type: ExprTuple
#    sub-expressions: 20, 22
# 5. (A in BOOLEAN, (B in BOOLEAN) and [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A in BOOLEAN
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. (B in BOOLEAN) and [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 16
#    operands: 9
# 8. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 20, 15
# 9. (B in BOOLEAN, [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. B in BOOLEAN
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. [not]([not](A) and [not](B))
#     core type: Operation
#     operator: 21
#     operand: 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 22, 15
# 14. [not](A) and [not](B)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. ([not](A), [not](B))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. [not](A)
#     core type: Operation
#     operator: 21
#     operand: 20
# 19. [not](B)
#     core type: Operation
#     operator: 21
#     operand: 22
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. not
#     core type: Literal
#     sub-expressions:
# 22. B
#     core type: Variable
#     sub-expressions:
