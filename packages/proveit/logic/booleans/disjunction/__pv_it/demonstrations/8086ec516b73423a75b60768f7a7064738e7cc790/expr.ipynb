# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C, ExprRange, IndexedVar, Variable
from proveit.logic import And, Boolean, InSet
from proveit.numbers import four, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = And(ExprRange(sub_expr1, InSet(IndexedVar(C, sub_expr1), Boolean), one, four))
# Out:
# expr: (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{4} in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(C_{1} \in \mathbb{B}\right) \land \ldots \land \left(C_{4} \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{4} in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{4} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{4} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> (C_{_a} in BOOLEAN)
#    core type: Lambda
#    parameter: 13
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. 4
#    core type: Literal
#    sub-expressions:
# 7. C_{_a} in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (C_{_a}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. C_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
