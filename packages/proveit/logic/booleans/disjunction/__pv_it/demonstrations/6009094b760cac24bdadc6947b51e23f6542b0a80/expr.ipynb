# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.disjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, E, F, G, H
from proveit.logic import Boolean, InSet, Or

# %%
# build up the expression from sub-expressions
expr = InSet(Or(A, B, C, D, E, F, G, H), Boolean)
# Out:
# expr: (A or B or C or D or E or F or G or H) in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \lor B \lor C \lor D \lor E \lor F \lor G \lor H\right) \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A or B or C or D or E or F or G or H) in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D or E or F or G or H, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A or B or C or D or E or F or G or H
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A, B, C, D, E, F, G, H)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11, 12, 13, 14
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. D
#     core type: Variable
#     sub-expressions:
# 11. E
#     core type: Variable
#     sub-expressions:
# 12. F
#     core type: Variable
#     sub-expressions:
# 13. G
#     core type: Variable
#     sub-expressions:
# 14. H
#     core type: Variable
#     sub-expressions:
