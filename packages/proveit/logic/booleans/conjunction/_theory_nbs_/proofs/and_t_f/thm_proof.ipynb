# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#and_t_f">and_t_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Equals, TRUE, FALSE
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving and_t_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="and_t_f">and_t_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/12e5b601afe5116e2b09be2b7482d4d0c350a2490/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/b0fcb1313f4951add4a9f561835e7241d9dcbcd90/dependencies.ipynb">dependencies</a>)<br>

# %%
binary_conjunction_def
# Out:
# |- forall_{A, B} ((A and B) = [not](A => [not](B)))

# %%
and_t_f__def = binary_conjunction_def.instantiate({A:TRUE, B:FALSE}, auto_simplify=False)
# Out:
# <strong id="and_t_f__def">and_t_f__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_and_t_f/933456427938cad37f990c7c7f65d6496f94f85c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_and_t_f/ed665e00034f61da3272f550a9e9690c5438e9040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
and_t_f__def.inner_expr().rhs.evaluate()
# Out:
# |- (TRUE and FALSE) = FALSE
# and_t_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.and_t_f is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- (TRUE and FALSE) = FALSE
# 	P(_a) : (TRUE and FALSE) = _a, x : [not](TRUE => [not](FALSE)), y : FALSE
# 1	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 2	modus_ponens	3, 4	|- ((TRUE and FALSE) = [not](TRUE => [not](FALSE))) and ([not](TRUE => [not](FALSE)) = FALSE)
# 3	modus_ponens	5, 6	|- ([not](TRUE => [not](FALSE)) = FALSE) => (((TRUE and FALSE) = [not](TRUE => [not](FALSE))) and ([not](TRUE => [not](FALSE)) = FALSE))
# 4	instantiation	15, 7	|- [not](TRUE => [not](FALSE)) = FALSE
# 	x : [not](TRUE => [not](FALSE)), y : [not](TRUE), z : FALSE
# 5	instantiation	21	|- ((TRUE and FALSE) = [not](TRUE => [not](FALSE))) => (([not](TRUE => [not](FALSE)) = FALSE) => (((TRUE and FALSE) = [not](TRUE => [not](FALSE))) and ([not](TRUE => [not](FALSE)) = FALSE)))
# 	A : (TRUE and FALSE) = [not](TRUE => [not](FALSE)), B : [not](TRUE => [not](FALSE)) = FALSE
# 6	instantiation	8	|- (TRUE and FALSE) = [not](TRUE => [not](FALSE))
# 	A : TRUE, B : FALSE
# 7	modus_ponens	9, 10	|- ([not](TRUE => [not](FALSE)) = [not](TRUE)) and ([not](TRUE) = FALSE)
# 8	defining_property	11	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# 	proveit.logic.booleans.conjunction.binary_conjunction_def
# 9	modus_ponens	12, 13	|- ([not](TRUE) = FALSE) => (([not](TRUE => [not](FALSE)) = [not](TRUE)) and ([not](TRUE) = FALSE))
# 10	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 11	definition_existence		|- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
# 12	instantiation	21	|- ([not](TRUE => [not](FALSE)) = [not](TRUE)) => (([not](TRUE) = FALSE) => (([not](TRUE => [not](FALSE)) = [not](TRUE)) and ([not](TRUE) = FALSE)))
# 	A : [not](TRUE => [not](FALSE)) = [not](TRUE), B : [not](TRUE) = FALSE
# 13	instantiation	22, 14	|- [not](TRUE => [not](FALSE)) = [not](TRUE)
# 	f(_a) : [not](_a), x : TRUE => [not](FALSE), y : TRUE
# 14	instantiation	15, 16	|- (TRUE => [not](FALSE)) = TRUE
# 	x : TRUE => [not](FALSE), y : TRUE => TRUE, z : TRUE
# 15	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 16	modus_ponens	17, 18	|- ((TRUE => [not](FALSE)) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE)
# 17	modus_ponens	19, 20	|- ((TRUE => TRUE) = TRUE) => (((TRUE => [not](FALSE)) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE))
# 18	theorem		|- (TRUE => TRUE) = TRUE
# 	proveit.logic.booleans.implication.implies_t_t
# 19	instantiation	21	|- ((TRUE => [not](FALSE)) = (TRUE => TRUE)) => (((TRUE => TRUE) = TRUE) => (((TRUE => [not](FALSE)) = (TRUE => TRUE)) and ((TRUE => TRUE) = TRUE)))
# 	A : (TRUE => [not](FALSE)) = (TRUE => TRUE), B : (TRUE => TRUE) = TRUE
# 20	instantiation	22, 23	|- (TRUE => [not](FALSE)) = (TRUE => TRUE)
# 	f(_a) : TRUE => _a, x : [not](FALSE), y : TRUE
# 21	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 22	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 23	theorem		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
