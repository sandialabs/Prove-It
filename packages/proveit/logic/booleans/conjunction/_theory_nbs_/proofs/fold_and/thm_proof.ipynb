# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#fold_and">fold_and</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving fold_and
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="fold_and">fold_and:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1169da9f3605a592ef9a4cbdce5755877129fd9d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dbaef3685f1b2be0101c2571d6b7456f167f0a110/dependencies.ipynb">dependencies</a>)<br>

# %%
A_and_B = fold_and.instance_expr
# Out:
# <strong id="A_and_B">A_and_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_and_B__def = A_and_B.definition(auto_simplify=False)
# Out:
# <strong id="A_and_B__def">A_and_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_and/e587fee2e282cd0b2d6129ec512f8d13dec2f9480/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/ef529c58a44b4872743bfc852dabd8b1b61744370/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_and_B__def_rev = A_and_B__def.derive_reversed()
# Out:
# <strong id="A_and_B__def_rev">A_and_B__def_rev:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_and/d15fb81bc6323cebf538e5bf239fbb908dcdfdd50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_fold_and/2812e64bb9fd3e367e4698ef012041d1026dcd580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_and_B__def_rev.sub_right_side_into(fold_and.condition, assumptions=[fold_and.condition])
# Out:
# {[not](A => [not](B))} |- A and B
# fold_and may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.fold_and is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A => [not](B))} (A and B)
# 1	modus_ponens	2, 3	{[not](A => [not](B))} |- A and B
# 2	modus_ponens	4, 5	{[not](A => [not](B))} |- ([not](A => [not](B)) = (A and B)) => (A and B)
# 3	instantiation	6, 7	|- [not](A => [not](B)) = (A and B)
# 	x : A and B, y : [not](A => [not](B))
# 4	instantiation	8	|- [not](A => [not](B)) => (([not](A => [not](B)) = (A and B)) => (A and B))
# 	P(_a) : _a, x : [not](A => [not](B)), y : A and B
# 5	assumption		{[not](A => [not](B))} |- [not](A => [not](B))
# 6	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 7	instantiation	9	|- (A and B) = [not](A => [not](B))
# 	A : A, B : B
# 8	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 9	defining_property	10	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# 	proveit.logic.booleans.conjunction.binary_conjunction_def
# 10	definition_existence		|- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
