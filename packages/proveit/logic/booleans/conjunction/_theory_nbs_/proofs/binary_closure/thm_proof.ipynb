# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#binary_closure">binary_closure</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving binary_closure
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="binary_closure">binary_closure:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/21a8b7f98abec2158517baa30c940bdb021de8790/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e3518bf61423a7fb6c0f66d60d387426a1a385350/dependencies.ipynb">dependencies</a>)<br>
# binary_closure may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed # conclude_as_folded automatically
# Out:
# proveit.logic.booleans.conjunction.binary_closure has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)
# 1	instantiation	3, 4	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) in BOOLEAN)]] \\  => [forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)]
# 	m : 1, n : 1, P(A, B) : (A and B) in BOOLEAN, Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, x_{1} : A, y_{1} : B
# 2	instantiation	9, 5, 6	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) in BOOLEAN)]
# 	P(A) : forall_{B in BOOLEAN} ((A and B) in BOOLEAN), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 7, 8	|- forall_{B in BOOLEAN} ((TRUE and B) in BOOLEAN)
# 	P(B) : (TRUE and B) in BOOLEAN, A : B
# 6	instantiation	9, 10, 11	|- forall_{B in BOOLEAN} ((FALSE and B) in BOOLEAN)
# 	P(B) : (FALSE and B) in BOOLEAN, A : B
# 7	instantiation	21, 12	|- (TRUE and TRUE) in BOOLEAN
# 	A : TRUE and TRUE
# 8	instantiation	15, 13	|- (TRUE and FALSE) in BOOLEAN
# 	A : TRUE and FALSE
# 9	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 10	instantiation	15, 14	|- (FALSE and TRUE) in BOOLEAN
# 	A : FALSE and TRUE
# 11	instantiation	15, 16	|- (FALSE and FALSE) in BOOLEAN
# 	A : FALSE and FALSE
# 12	instantiation	17, 18	|- TRUE and TRUE
# 	A : TRUE and TRUE
# 13	instantiation	21, 19	|- [not](TRUE and FALSE) in BOOLEAN
# 	A : [not](TRUE and FALSE)
# 14	instantiation	21, 20	|- [not](FALSE and TRUE) in BOOLEAN
# 	A : [not](FALSE and TRUE)
# 15	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 16	instantiation	21, 22	|- [not](FALSE and FALSE) in BOOLEAN
# 	A : [not](FALSE and FALSE)
# 17	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 18	axiom		|- (TRUE and TRUE) = TRUE
# 	proveit.logic.booleans.conjunction.and_t_t
# 19	instantiation	25, 23	|- [not](TRUE and FALSE)
# 	A : TRUE and FALSE
# 20	instantiation	25, 24	|- [not](FALSE and TRUE)
# 	A : FALSE and TRUE
# 21	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 22	instantiation	25, 26	|- [not](FALSE and FALSE)
# 	A : FALSE and FALSE
# 23	axiom		|- (TRUE and FALSE) = FALSE
# 	proveit.logic.booleans.conjunction.and_t_f
# 24	axiom		|- (FALSE and TRUE) = FALSE
# 	proveit.logic.booleans.conjunction.and_f_t
# 25	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 26	axiom		|- (FALSE and FALSE) = FALSE
# 	proveit.logic.booleans.conjunction.and_f_f
