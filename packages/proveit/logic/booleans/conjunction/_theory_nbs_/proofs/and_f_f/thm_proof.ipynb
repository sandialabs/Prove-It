# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#and_f_f">and_f_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Equals, TRUE, FALSE
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving and_f_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="and_f_f">and_f_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b5ff076bc01af38ecec321425420cbf9d4b90b460/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/5ed037a1a76eebefa9c68bc33a57cf4e6a3dc84b0/dependencies.ipynb">dependencies</a>)<br>

# %%
binary_conjunction_def
# Out:
# |- forall_{A, B} ((A and B) = [not](A => [not](B)))

# %%
and_f_f__def = binary_conjunction_def.instantiate({A:FALSE, B:FALSE}, auto_simplify=False)
# Out:
# <strong id="and_f_f__def">and_f_f__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_and_f_f/6ede375c9257a519024db33ae16501e2345d902c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_and_f_f/bd9b55ebbfd21a5048823cc340d3f980a94dcee70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
and_f_f__def.inner_expr().rhs.evaluate()
# Out:
# |- (FALSE and FALSE) = FALSE
# and_f_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.and_f_f is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- (FALSE and FALSE) = FALSE
# 1	modus_ponens	3, 4	|- ([not](FALSE => [not](FALSE)) = FALSE) => ((FALSE and FALSE) = FALSE)
# 2	modus_ponens	5, 6	|- [not](FALSE => [not](FALSE)) = FALSE
# 3	instantiation	7	|- ((FALSE and FALSE) = [not](FALSE => [not](FALSE))) => (([not](FALSE => [not](FALSE)) = FALSE) => ((FALSE and FALSE) = FALSE))
# 	P(_a) : (FALSE and FALSE) = _a, x : [not](FALSE => [not](FALSE)), y : FALSE
# 4	instantiation	8	|- (FALSE and FALSE) = [not](FALSE => [not](FALSE))
# 	A : FALSE, B : FALSE
# 5	modus_ponens	9, 10	|- ([not](TRUE) = FALSE) => ([not](FALSE => [not](FALSE)) = FALSE)
# 6	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 8	defining_property	11	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# ...
