# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#and_t_t">and_t_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Equals, TRUE
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving and_t_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="and_t_t">and_t_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2e06e480834dffc99779e341f5b63756ff25f98e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a8a11c287bd0e085d7e9b3f4e9e3cc1508658b3f0/dependencies.ipynb">dependencies</a>)<br>
# and_t_t may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
binary_conjunction_def
# Out:
# |- forall_{A, B} ((A and B) = [not](A => [not](B)))

# %%
and_t_t__def = binary_conjunction_def.instantiate({A:TRUE, B:TRUE}, auto_simplify=False)
# Out:
# <strong id="and_t_t__def">and_t_t__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_and_t_t/754409cf7a61a4cfdddb16ca915988eacde880100/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_and_t_t/b420097acd8a4ca31f8d4f3c9b577db0ee62a13b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
and_t_t__def.inner_expr().rhs.evaluate()
# Out:
# |- (TRUE and TRUE) = TRUE
# and_t_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.and_t_t is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- (TRUE and TRUE) = TRUE
# 1	modus_ponens	3, 4	|- ([not](TRUE => [not](TRUE)) = TRUE) => ((TRUE and TRUE) = TRUE)
# 2	modus_ponens	5, 6	|- [not](TRUE => [not](TRUE)) = TRUE
# 3	instantiation	7	|- ((TRUE and TRUE) = [not](TRUE => [not](TRUE))) => (([not](TRUE => [not](TRUE)) = TRUE) => ((TRUE and TRUE) = TRUE))
# 	P(_a) : (TRUE and TRUE) = _a, x : [not](TRUE => [not](TRUE)), y : TRUE
# 4	instantiation	8	|- (TRUE and TRUE) = [not](TRUE => [not](TRUE))
# 	A : TRUE, B : TRUE
# 5	modus_ponens	9, 10	|- ([not](FALSE) = TRUE) => ([not](TRUE => [not](TRUE)) = TRUE)
# 6	theorem		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 8	defining_property	11	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# ...
