# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#nand_if_not_right">nand_if_not_right</a> theorem
# ========

# %%
import proveit
from proveit import defaults, A
from proveit.logic import TRUE, FALSE
from proveit.logic.booleans.conjunction import (
        nand_if_left_but_not_right, nand_if_neither)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nand_if_not_right
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="nand_if_not_right">nand_if_not_right:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7e3be7b2b3ee1271a36b4fa69d315f0a421702b30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a20d5d78f2221bd06b7fefe2949505997c8a12380/dependencies.ipynb">dependencies</a>)<br>
# nand_if_not_right may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = nand_if_not_right.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3ccb2e9dd7b1640bf7995d7f692f23d898369fa80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
nand_if_left_but_not_right.instantiate({A:TRUE}, auto_simplify=False)
# Out:
# {[not](B)} |- [not](TRUE and B)

# %%
nand_if_neither.instantiate({A:FALSE}, auto_simplify=False)
# Out:
# {[not](B)} |- [not](FALSE and B)

# %%
nand_if_not_right.conclude_by_cases()
# Out:
# |- forall_{A, B in BOOLEAN | [not](B)} [not](A and B)

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.nand_if_not_right has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | [not](B)} [not](A and B)
# 1	instantiation	3, 4, 5*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](B)} [not](A and B)]] \\  => [forall_{A, B in BOOLEAN | [not](B)} [not](A and B)]
# 	m : 1, n : 1, P(A, B) : [not](A and B), Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and [not](B), x_{1} : A, y_{1} : B
# 2	instantiation	6, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](B)} [not](A and B)]
# 	P(A) : forall_{B in BOOLEAN | [not](B)} [not](A and B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 10, 11	|- {[not](A and B) if A in BOOLEAN ,  (B in BOOLEAN) and [not](B). \\  = {[not](A and B) if A in BOOLEAN ,  B in BOOLEAN ,  [not](B).
# 	n : 2, a : [not](A and B), Q : A in BOOLEAN, R : (B in BOOLEAN, [not](B))
# 6	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 7	generalization	12	|- forall_{B in BOOLEAN | [not](B)} [not](TRUE and B)
# 8	generalization	13	|- forall_{B in BOOLEAN | [not](B)} [not](FALSE and B)
# 9	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, R_{2}, ..., R_{n}} ({a if Q ,  R_{1} and  R_{2} and  ... and  R_{n}. \\  = {a if Q, R_{1} ,  R_{2} ,  ... ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 10	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 11	instantiation	14	|- |(B in BOOLEAN, [not](B))| = |(1, ..., 2)|
# 	a : B in BOOLEAN, b : [not](B)
# 12	instantiation	15, 16, 19	{[not](B)} |- [not](TRUE and B)
# 	A : TRUE, B : B
# 13	instantiation	17, 18, 19	{[not](B)} |- [not](FALSE and B)
# 	A : FALSE, B : B
# 14	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 15	theorem		|- forall_{A, B | A, [not](B)} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_left_but_not_right
# 16	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
# 17	theorem		|- forall_{A, B | [not](A), [not](B)} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_neither
# 18	theorem		|- [not](FALSE)
# 	proveit.logic.booleans.negation.not_false
# 19	assumption		{[not](B)} |- [not](B)
