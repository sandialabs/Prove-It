# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#and_f_t">and_f_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B
from proveit.logic import Equals, TRUE, FALSE
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving and_f_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="and_f_t">and_f_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a65bf4fde9913e34cd5a85bbb0b1d1d29d885ac50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/cba017f42c93ad5502cb6f2bd66650c64470f5630/dependencies.ipynb">dependencies</a>)<br>

# %%
binary_conjunction_def
# Out:
# |- forall_{A, B} ((A and B) = [not](A => [not](B)))

# %%
and_f_t__def = binary_conjunction_def.instantiate({A:FALSE, B:TRUE}, auto_simplify=False)
# Out:
# <strong id="and_f_t__def">and_f_t__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_and_f_t/3db87145b81ab9bd7e1108a29af599c696fa73bc0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_and_f_t/c6353ac3c43971f3da8d5db04ee6adba202a868d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
and_f_t__def.inner_expr().rhs.evaluate()
# Out:
# |- (FALSE and TRUE) = FALSE
# and_f_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.and_f_t is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- (FALSE and TRUE) = FALSE
# 1	modus_ponens	3, 4	|- ([not](FALSE => [not](TRUE)) = FALSE) => ((FALSE and TRUE) = FALSE)
# 2	modus_ponens	5, 18	|- [not](FALSE => [not](TRUE)) = FALSE
# 3	instantiation	6	|- ((FALSE and TRUE) = [not](FALSE => [not](TRUE))) => (([not](FALSE => [not](TRUE)) = FALSE) => ((FALSE and TRUE) = FALSE))
# 	P(_a) : (FALSE and TRUE) = _a, x : [not](FALSE => [not](TRUE)), y : FALSE
# 4	instantiation	7	|- (FALSE and TRUE) = [not](FALSE => [not](TRUE))
# 	A : FALSE, B : TRUE
# 5	modus_ponens	8, 9	|- ([not](TRUE) = FALSE) => ([not](FALSE => [not](TRUE)) = FALSE)
# 6	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 7	defining_property	10	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# 	proveit.logic.booleans.conjunction.binary_conjunction_def
# 8	instantiation	16	|- ([not](FALSE => [not](TRUE)) = [not](TRUE)) => (([not](TRUE) = FALSE) => ([not](FALSE => [not](TRUE)) = FALSE))
# 	x : [not](FALSE => [not](TRUE)), y : [not](TRUE), z : FALSE
# 9	instantiation	17, 11	|- [not](FALSE => [not](TRUE)) = [not](TRUE)
# 	f(_a) : [not](_a), x : FALSE => [not](TRUE), y : TRUE
# 10	definition_existence		|- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
# 11	modus_ponens	12, 13	|- (FALSE => [not](TRUE)) = TRUE
# 12	modus_ponens	14, 15	|- ((FALSE => FALSE) = TRUE) => ((FALSE => [not](TRUE)) = TRUE)
# 13	theorem		|- (FALSE => FALSE) = TRUE
# 	proveit.logic.booleans.implication.implies_f_f
# 14	instantiation	16	|- ((FALSE => [not](TRUE)) = (FALSE => FALSE)) => (((FALSE => FALSE) = TRUE) => ((FALSE => [not](TRUE)) = TRUE))
# 	x : FALSE => [not](TRUE), y : FALSE => FALSE, z : TRUE
# 15	instantiation	17, 18	|- (FALSE => [not](TRUE)) = (FALSE => FALSE)
# 	f(_a) : FALSE => _a, x : [not](TRUE), y : FALSE
# 16	theorem		|- forall_{x, y, z} ((x = y) => ((y = z) => (x = z)))
# 	proveit.logic.equality.equals_transitivity_via_implications
# 17	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 18	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
