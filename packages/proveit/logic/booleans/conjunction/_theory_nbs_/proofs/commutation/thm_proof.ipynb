# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#commutation">commutation</a> theorem
# ========

# %%
import proveit
from proveit.logic import TRUE, And, Equals
from proveit import A, B
from proveit.logic.booleans.conjunction  import and_t_t, and_t_f, and_f_t, and_f_f
from proveit.logic.booleans.conjunction import right_from_and, left_from_and 
theory = proveit.Theory() # the theorem's theory

# %%
# %proving commutation
# Out:
# commutation: forall_{A, B in BOOLEAN} ((A and B) = (B and A))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN} ((A and B) = (B and A))
# 1	instantiation	3, 4, 5, 6	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))]] \\  => [forall_{A, B in BOOLEAN} ((A and B) = (B and A))]
# 	m : 1, n : 1, P(A, B) : (A and B) = (B and A), Q(A) : A in BOOLEAN, R(A, B) : B in BOOLEAN, (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	11, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))]
# 	P(A) : forall_{B in BOOLEAN} ((A and B) = (B and A)), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	9	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	9	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	11, 10, 14	|- forall_{B in BOOLEAN} ((TRUE and B) = (B and TRUE))
# 	P(B) : (TRUE and B) = (B and TRUE), A : B
# 8	instantiation	11, 12, 13	|- forall_{B in BOOLEAN} ((FALSE and B) = (B and FALSE))
# 	P(B) : (FALSE and B) = (B and FALSE), A : B
# 9	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 10	instantiation	15	|- (TRUE and TRUE) = (TRUE and TRUE)
# 	x : TRUE and TRUE
# 11	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 12	instantiation	19, 14	|- (FALSE and TRUE) = (TRUE and FALSE)
# 	x : TRUE and FALSE, y : FALSE and TRUE
# 13	instantiation	15	|- (FALSE and FALSE) = (FALSE and FALSE)
# 	x : FALSE and FALSE
# 14	instantiation	16, 17, 18	|- (TRUE and FALSE) = (FALSE and TRUE)
# 	x : TRUE and FALSE, y : FALSE, z : FALSE and TRUE
# 15	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 16	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 17	axiom		|- (TRUE and FALSE) = FALSE
# 	proveit.logic.booleans.conjunction.and_t_f
# 18	instantiation	19, 20	|- FALSE = (FALSE and TRUE)
# 	x : FALSE and TRUE, y : FALSE
# 19	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 20	axiom		|- (FALSE and TRUE) = FALSE
# 	proveit.logic.booleans.conjunction.and_f_t
