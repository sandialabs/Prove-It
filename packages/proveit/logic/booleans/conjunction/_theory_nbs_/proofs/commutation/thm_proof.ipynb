# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#commutation">commutation</a> theorem
# ========

# %%
import proveit
from proveit import defaults
theory = proveit.Theory() # the theorem's theory

# %%
# %proving commutation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="commutation">commutation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ee3c8b0f4d53bfef5140fc769dd5f5fcbef842d00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ff109cee4fced40026e8088dbf51ae6b29c0a12d0/dependencies.ipynb">dependencies</a>)<br>
# commutation may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %% [markdown]
# Not quite readily provable because of unusable proofs to avoid circular logic.

# %%
defaults.assumptions = commutation.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c8774faa9ebba7bcce7317dd44385a510c5bc46a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
commutation.instance_expr.conclude_via_mutual_implication()
# Out:
# {A in BOOLEAN, B in BOOLEAN} |- (A and B) = (B and A)

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.commutation has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B in BOOLEAN} ((A and B) = (B and A))
# 1	instantiation	2, 3, 4, 5, 6	{A in BOOLEAN, B in BOOLEAN} |- (A and B) = (B and A)
# 	A : A and B, B : B and A
# 2	conjecture		|- forall_{A, B in BOOLEAN | A => B, B => A} (A = B)
# 	proveit.logic.booleans.implication.eq_from_mutual_impl
# 3	instantiation	7, 9, 8	{A in BOOLEAN, B in BOOLEAN} |- (A and B) in BOOLEAN
# 	A : A, B : B
# 4	instantiation	7, 8, 9	{B in BOOLEAN, A in BOOLEAN} |- (B and A) in BOOLEAN
# 	A : B, B : A
# 5	deduction	10	|- (A and B) => (B and A)
# 6	deduction	11	|- (B and A) => (A and B)
# 7	conjecture		|- forall_{A, B in BOOLEAN} ((A and B) in BOOLEAN)
# 	proveit.logic.booleans.conjunction.binary_closure
# 8	assumption		{B in BOOLEAN} |- B in BOOLEAN
# 9	assumption		{A in BOOLEAN} |- A in BOOLEAN
# 10	instantiation	14, 12, 13	{A and B} |- B and A
# 	A : B, B : A
# 11	instantiation	14, 15, 16	{B and A} |- A and B
# 	A : A, B : B
# 12	instantiation	18, 17	{A and B} |- B
# 	A : A, B : B
# 13	instantiation	19, 17	{A and B} |- A
# 	A : A, B : B
# 14	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 15	instantiation	18, 20	{B and A} |- A
# 	A : B, B : A
# 16	instantiation	19, 20	{B and A} |- B
# 	A : B, B : A
# 17	assumption		{A and B} |- A and B
# 18	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 19	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 20	assumption		{B and A} |- B and A
