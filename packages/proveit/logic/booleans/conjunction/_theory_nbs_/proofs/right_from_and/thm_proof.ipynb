# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#right_from_and">right_from_and</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C
from proveit.logic import Not, FALSE, And
from proveit.logic.booleans.negation import not_def

# %%
# %proving right_from_and
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="right_from_and">right_from_and:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/53f934d959ef00a2d007db63433e676c9774b52c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/c7b01605c5678f91ff8d5f7100e015b9d4c41c120/dependencies.ipynb">dependencies</a>)<br>
# right_from_and may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A_and_B = right_from_and.condition
# Out:
# <strong id="A_and_B">A_and_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_and_B__as_defined = A_and_B.unfold(assumptions=[A_and_B])
# Out:
# <strong id="A_and_B__as_defined">A_and_B__as_defined:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_right_from_and/0385d375c357507a4d1152fa6f74dbd05c9934340/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/20236bec9ca725ad2bac2efefe8fa2ea5c104b080/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_notB = Not(B).prove(assumptions=(Not(B),)).as_implication(A)
# Out:
# <strong id="A_impl_notB">A_impl_notB:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8552c6321b312c5e15a5015adce4a756ce05da420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_right_from_and/c50825f1ea2e506f273df4164a3aaff44eb6a44d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/4848464b321f8ab262f0c4edd1eb2a26f58250ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction = A_and_B__as_defined.unfold().derive_consequent(assumptions=(And(A, B), Not(B)))
# Out:
# <strong id="contradiction">contradiction:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8552c6321b312c5e15a5015adce4a756ce05da420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_right_from_and/0a6e57af19b8a2f1177bc13a790984c87134fe410/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
notB_impl_F = contradiction.as_implication(Not(B))
# Out:
# <strong id="notB_impl_F">notB_impl_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_right_from_and/bffe0e7c1143a4b0d7416d8bd21eb0ef9219fc1b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_right_from_and/b2265cdeafb73dfc4eca4bf220954ffd79ddb26a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.right_from_and is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A, B} B
# 1	instantiation	2, 3	{A and B} |- B
# 	A : B
# 2	theorem		|- forall_{A | [not]([not](A))} A
# 	proveit.logic.booleans.negation.double_negation_elim
# 3	instantiation	4, 5	{A and B} |- [not]([not](B))
# 	A : [not](B)
# 4	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 5	deduction	6	{A and B} |- [not](B) => FALSE
# 6	modus_ponens	7, 8	{A and B, [not](B)} |- FALSE
# 7	instantiation	9, 10	{A and B} |- (A => [not](B)) => FALSE
# 	A : A => [not](B)
# 8	deduction	11	{[not](B)} |- A => [not](B)
# 9	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 10	instantiation	12, 13	{A and B} |- [not](A => [not](B))
# 	A : A, B : B
# 11	assumption		{[not](B)} |- [not](B)
# 12	theorem		|- forall_{A, B | A, B} [not](A => [not](B))
# 	proveit.logic.booleans.conjunction.unfold_and
# 13	assumption		{A and B} |- A and B
