# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#conjunction_intro">conjunction_intro</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, C
from proveit.logic import Implies, Not, FALSE, And
from proveit.logic.booleans.implication import split_deduction

# %%
# %proving conjunction_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="conjunction_intro">conjunction_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c3037e647f6133f964d4e44f3915b20087614e810/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/694e809f94eaf73445db926a8ef939910a8a5f990/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = (A, B)
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../../implication/__pv_it/theorems/e791ee87807ed43d7ac6262f8f70c4ffc8f24c940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
split_deduction
# Out:
# |- forall_{A, B, C} ((A => (B => C)) => ((A => B) => (A => C)))

# %%
split_deduction_with_CasF = split_deduction.instantiate({C:FALSE})
# Out:
# <strong id="split_deduction_with_CasF">split_deduction_with_CasF:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/acd7de2fb00e9bb6ce90f2713dd1ceaef8fadb0a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/f0ddf8da48812b6371dcd1a9593497f7f358a98a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_notB = Implies(A, Not(B))
# Out:
# <strong id="A_impl_notB">A_impl_notB:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/4848464b321f8ab262f0c4edd1eb2a26f58250ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_impl_B__impl__A_impl_F = split_deduction_with_CasF.derive_consequent(assumptions=(A_impl_notB,))
# Out:
# <strong id="A_impl_B__impl__A_impl_F">A_impl_B__impl__A_impl_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/4848464b321f8ab262f0c4edd1eb2a26f58250ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/abe455fdaca75f672c1eaf273f992cfedf7129fb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/bd2555aa6083a680a5751c44dc2213116cfa4efd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_B__given__B = B.prove(assumptions=(B,)).as_implication(A)
# Out:
# <strong id="A_impl_B__given__B">A_impl_B__given__B:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/663d02e01213055daffef94dc11cab3e0ecbd3bc0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../implication/__pv_it/theorems/d78c7a0a66f0f0f40e69d505fb93268ea9af46dc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_impl_F__conclusion = A_impl_B__impl__A_impl_F.derive_consequent()
# Out:
# <strong id="A_impl_F__conclusion">A_impl_F__conclusion:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/4848464b321f8ab262f0c4edd1eb2a26f58250ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/c10c540396731e2b86e6f234bfa98d9e8232e3b50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2e91c09acf833f9a9fa60791fc63a618fb0cb6b40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
F_conclusion = A_impl_F__conclusion.derive_consequent()
# Out:
# <strong id="F_conclusion">F_conclusion:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/4848464b321f8ab262f0c4edd1eb2a26f58250ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/7955e4765dd3098c98a18b1ce1b523eef8038e090/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction = F_conclusion.as_implication(A_impl_notB)
# Out:
# <strong id="contradiction">contradiction:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../__pv_it/common/a9162d1c3cc0470c02e5daf414500903a7a419230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/242dc0db34853d4d69bf0ce11c91862f68764b9f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_conjunction_intro/9f6f5c42b0366d61e96fde7a0e2eeba98b3616540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
And(A, B).conclude_as_folded()
# Out:
# {A, B} |- A and B
# conjunction_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.conjunction_intro is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B} (A => (B => (A and B)))
# 1	deduction	2	|- A => (B => (A and B))
# 2	deduction	3	{A} |- B => (A and B)
# 3	instantiation	4, 5	{A, B} |- A and B
# 	A : A, B : B
# 4	theorem		|- forall_{A, B | [not](A => [not](B))} (A and B)
# 	proveit.logic.booleans.conjunction.fold_and
# 5	instantiation	6, 7	{A, B} |- [not](A => [not](B))
# 	A : A => [not](B)
# 6	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 7	deduction	8	{A, B} |- (A => [not](B)) => FALSE
# 8	modus_ponens	9, 10	{A, B, A => [not](B)} |- FALSE
# 9	instantiation	11, 12	{A, A => [not](B)} |- B => FALSE
# 	A : B
# 10	assumption		{B} |- B
# 11	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 12	modus_ponens	13, 14	{A, A => [not](B)} |- [not](B)
# 13	assumption		{A => [not](B)} |- A => [not](B)
# 14	assumption		{A} |- A
