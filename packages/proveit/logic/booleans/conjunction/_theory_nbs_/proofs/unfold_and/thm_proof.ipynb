# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#unfold_and">unfold_and</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving unfold_and
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="unfold_and">unfold_and:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7fbdf9b256c8528f0c8abab87f793f5f43782c720/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/908da99d2618bc8f4ba5ad7689511ccdc53a1f5f0/dependencies.ipynb">dependencies</a>)<br>
# unfold_and may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A_and_B = unfold_and.condition
# Out:
# <strong id="A_and_B">A_and_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ebe322aacd1b571c58879de875163df360acd3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_and_B__def = A_and_B.definition()
# Out:
# <strong id="A_and_B__def">A_and_B__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_and/e587fee2e282cd0b2d6129ec512f8d13dec2f9480/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/ef529c58a44b4872743bfc852dabd8b1b61744370/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_and_B__def.sub_right_side_into(unfold_and.condition, assumptions=[unfold_and.condition])
# Out:
# {A and B} |- [not](A => [not](B))

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.unfold_and is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A, B} [not](A => [not](B))
# 1	modus_ponens	2, 3	{A and B} |- [not](A => [not](B))
# 2	modus_ponens	4, 5	{A and B} |- ((A and B) = [not](A => [not](B))) => [not](A => [not](B))
# 3	instantiation	6	|- (A and B) = [not](A => [not](B))
# 	A : A, B : B
# 4	instantiation	7	|- (A and B) => (((A and B) = [not](A => [not](B))) => [not](A => [not](B)))
# 	P(_a) : _a, x : A and B, y : [not](A => [not](B))
# 5	assumption		{A and B} |- A and B
# 6	defining_property	8	|- forall_{A, B} ((A and B) = [not](A => [not](B)))
# 	proveit.logic.booleans.conjunction.binary_conjunction_def
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 8	definition_existence		|- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
