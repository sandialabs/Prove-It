# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#falsified_and_if_not_right">falsified_and_if_not_right</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic.booleans.conjunction import nand_if_not_right
theory = proveit.Theory() # the theorem's theory

# %%
# %proving falsified_and_if_not_right
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="falsified_and_if_not_right">falsified_and_if_not_right:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e16aae2f975d931d3e2eb4a9a0c78b7c6b7ade480/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/eff0a6e00c7ba4cfe35e0f16e55c1de254b2634f0/dependencies.ipynb">dependencies</a>)<br>
# falsified_and_if_not_right may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = falsified_and_if_not_right.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2aa411f4d996e43998d5dbfe6b6926842657cede0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
nand_if_not_right
# Out:
# |- forall_{A, B in BOOLEAN | [not](B)} [not](A and B)

# %%
nand = nand_if_not_right.instantiate({A:A, B:B})
# Out:
# <strong id="nand">nand:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8552c6321b312c5e15a5015adce4a756ce05da420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_falsified_and_if_not_right/d883a7b99a053c0b0ebc0c056b4a6060982e1a6f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0567bf29b3602a47df1cf08da8d3e179ba950a980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# To do this manually, execute nand.equate_negated_to_false(assumptions=conditions)
# and then generalize.  But it can figure this out via automation.
# %qed
# Out:
# proveit.logic.booleans.conjunction.falsified_and_if_not_right has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A, [not](B)} ((A and B) = FALSE)
# 1	instantiation	2, 3	{A, [not](B)} |- (A and B) = FALSE
# 	A : A and B
# 2	axiom		|- forall_{A | [not](A)} (A = FALSE)
# 	proveit.logic.booleans.negation.negation_elim
# 3	instantiation	4, 5, 6, 11	{A, [not](B)} |- [not](A and B)
# 	A : A, B : B
# 4	conjecture		|- forall_{A, B in BOOLEAN | [not](B)} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_not_right
# 5	instantiation	10, 7	{A} |- A in BOOLEAN
# 	A : A
# 6	instantiation	8, 9	{[not](B)} |- B in BOOLEAN
# 	A : B
# 7	assumption		{A} |- A
# 8	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 9	instantiation	10, 11	{[not](B)} |- [not](B) in BOOLEAN
# 	A : [not](B)
# 10	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 11	assumption		{[not](B)} |- [not](B)
