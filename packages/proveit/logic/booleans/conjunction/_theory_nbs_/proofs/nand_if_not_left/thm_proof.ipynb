# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#nand_if_not_left">nand_if_not_left</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B
from proveit.logic import Not, TRUE, FALSE
from proveit.logic.booleans import fold_conditioned_forall_over_bool
from proveit.logic.booleans.conjunction import nand_if_right_but_not_left, nand_if_neither
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nand_if_not_left
# Out:
# nand_if_not_left: forall_{A, B in BOOLEAN | [not](A)} [not](A and B)

# %%
defaults.assumptions = nand_if_not_left.all_conditions()
# Out:
# defaults.assumptions: (A in BOOLEAN, B in BOOLEAN, [not](A))

# %%
nand_if_right_but_not_left
# Out:
# |- forall_{A, B | [not](A), B} [not](A and B)

# %%
nand_if_neither
# Out:
# |- forall_{A, B | [not](A), [not](B)} [not](A and B)

# %%
nand_if_right_but_not_left.instantiate({B:TRUE})
# Out:
# {[not](A)} |- [not](A and TRUE)

# %%
nand_if_neither.instantiate({B:FALSE})
# Out:
# {[not](A)} |- [not](A and FALSE)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | [not](A)} [not](A and B)
# 1	instantiation	3, 4, 5, 6, 7*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](A)} [not](A and B)]] \\  => [forall_{A, B in BOOLEAN | [not](A)} [not](A and B)]
# 	m : 1, n : 1, P(A, B) : [not](A and B), Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and [not](A), (x_{1}, ..x_{_a}.., x_{1}) : (A), (y_{1}, ..y_{_a}.., y_{1}) : (B)
# 2	instantiation	8, 9, 10	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](A)} [not](A and B)]
# 	P(A) : forall_{B in BOOLEAN | [not](A)} [not](A and B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])]
# 4	instantiation	11	|- |(A)| = |(1, ..k.., 1)|
# 	a : A
# 5	instantiation	11	|- |(B)| = |(1, ..k.., 1)|
# 	a : B
# 6	conjecture		|- 1 in NaturalPos
# 7	instantiation	12, 13, 14	|- {[not](A and B) if A in BOOLEAN ,  (B in BOOLEAN) and [not](A). = {[not](A and B) if A in BOOLEAN ,  B in BOOLEAN ,  [not](A).
# 	n : 2, a : [not](A and B), Q : A in BOOLEAN, R : (B in BOOLEAN, [not](A))
# 8	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 9	instantiation	17, 15, 16	|- forall_{B in BOOLEAN | [not](TRUE)} [not](TRUE and B)
# 	P(B) : [not](TRUE and B), Q(B) : [not](TRUE), A : B
# 10	instantiation	17, 18, 19	|- forall_{B in BOOLEAN | [not](FALSE)} [not](FALSE and B)
# 	P(B) : [not](FALSE and B), Q(B) : [not](FALSE), A : B
# 11	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 12	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, ..R_{_a}.., R_{n}} ({a if Q ,  R_{1} and ..R_{_a}.. and R_{n}. \\  = {a if Q ,  R_{1} ,  ..R_{_a}.. ,  R_{n}.)]
# 13	instantiation	20, 21, 22	|- 2 in Natural
# 	A : NaturalPos, B : Natural, x : 2
# 14	instantiation	23	|- |(B in BOOLEAN, [not](A))| = |(1, ..k.., 2)|
# 	a : B in BOOLEAN, b : [not](A)
# 15	instantiation	24, 25	|- [not](TRUE) => [not](TRUE and TRUE)
# 	A : [not](TRUE), B : [not](TRUE and TRUE)
# 16	instantiation	24, 25	|- [not](TRUE) => [not](TRUE and FALSE)
# 	A : [not](TRUE), B : [not](TRUE and FALSE)
# 17	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 18	deduction	26	|- [not](FALSE) => [not](FALSE and TRUE)
# 19	deduction	27	|- [not](FALSE) => [not](FALSE and FALSE)
# 20	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 21	conjecture		|- NaturalPos proper_subset Natural
# 22	conjecture		|- 2 in NaturalPos
# 23	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 24	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 25	instantiation	30, 28	|- [not]([not](TRUE))
# 	A : [not](TRUE)
# 26	instantiation	30, 29	|- [not](FALSE and TRUE)
# 	A : FALSE and TRUE
# 27	instantiation	30, 31	|- [not](FALSE and FALSE)
# 	A : FALSE and FALSE
# 28	axiom		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 29	axiom		|- (FALSE and TRUE) = FALSE
# 	proveit.logic.booleans.conjunction.and_f_t
# 30	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 31	axiom		|- (FALSE and FALSE) = FALSE
# 	proveit.logic.booleans.conjunction.and_f_f
