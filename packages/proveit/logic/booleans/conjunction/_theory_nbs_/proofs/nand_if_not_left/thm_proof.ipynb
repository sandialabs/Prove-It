# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#nand_if_not_left">nand_if_not_left</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic.booleans.conjunction import binary_conjunction_def

# %%
# %proving nand_if_not_left
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="nand_if_not_left">nand_if_not_left:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c4b138aa7062b127c0f990f12f31d72077fab3360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/90facc27d8deb29f83ad64383a8a4189074bea7e0/dependencies.ipynb">dependencies</a>)<br>
# nand_if_not_left may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = nand_if_not_left.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../../negation/__pv_it/theorems/d6cb9e4509552d53ba07d8d7903246aa9677ce4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
binary_conjunction_def
# Out:
# |- forall_{A, B} ((A and B) = [not](A => [not](B)))

# %%
and_A_B_def = binary_conjunction_def.instantiate()
# Out:
# <strong id="and_A_B_def">and_A_B_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_nand_if_not_left/e587fee2e282cd0b2d6129ec512f8d13dec2f9480/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/definitions/ef529c58a44b4872743bfc852dabd8b1b61744370/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_disproven = and_A_B_def.rhs.disprove()
# Out:
# <strong id="rhs_disproven">rhs_disproven:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../negation/__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_nand_if_not_left/8442cf1072b2815ebf784f7b0e9b8fe02daee54a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_nand_if_not_left/64507b1cbec97e6887faf14d31f7bdbf7dc10f360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
and_A_B_def.sub_left_side_into(rhs_disproven)
# Out:
# {[not](A)} |- [not](A and B)

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.nand_if_not_left is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | [not](A)} [not](A and B)
# 1	instantiation	2, 3	{[not](A)} |- [not](A and B)
# 	P(_a) : [not](_a), x : A and B, y : [not](A => [not](B))
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{[not](A)} |- [not]([not](A => [not](B))) and ((A and B) = [not](A => [not](B)))
# 4	modus_ponens	6, 7	{[not](A)} |- ((A and B) = [not](A => [not](B))) => ([not]([not](A => [not](B))) and ((A and B) = [not](A => [not](B))))
# 5	instantiation	8	|- (A and B) = [not](A => [not](B))
# 	A : A, B : B
# 6	instantiation	9	|- [not]([not](A => [not](B))) => (((A and B) = [not](A => [not](B))) => ([not]([not](A => [not](B))) and ((A and B) = [not](A => [not](B)))))
# 	A : [not]([not](A => [not](B))), B : (A and B) = [not](A => [not](B))
# 7	instantiation	10, 11	{[not](A)} |- [not]([not](A => [not](B)))
# ...
