# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#nand_if_not_left">nand_if_not_left</a> theorem
# ========

# %%
import proveit
from proveit import defaults, B
from proveit.logic import TRUE, FALSE
from proveit.logic.booleans.conjunction import (
        nand_if_right_but_not_left, nand_if_neither)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nand_if_not_left
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="nand_if_not_left">nand_if_not_left:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d1a8d850df39db46e655bd55dea2076f61270d090/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3a73e8e102494c1b88cf5ffe3d063d4f76e96acc0/dependencies.ipynb">dependencies</a>)<br>
# nand_if_not_left may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = nand_if_not_left.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/64791b8bb4078e8f87fcb2deafeff4bfa9f4d2550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
nand_if_right_but_not_left
# Out:
# |- forall_{A, B | [not](A), B} [not](A and B)

# %%
nand_if_neither
# Out:
# |- forall_{A, B | [not](A), [not](B)} [not](A and B)

# %%
nand_if_right_but_not_left.instantiate({B:TRUE})
# Out:
# {[not](A)} |- [not](A and TRUE)

# %%
nand_if_neither.instantiate({B:FALSE})
# Out:
# {[not](A)} |- [not](A and FALSE)

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.nand_if_not_left has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | [not](A)} [not](A and B)
# 1	instantiation	3, 4, 5*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](A)} [not](A and B)]] \\  => [forall_{A, B in BOOLEAN | [not](A)} [not](A and B)]
# 	m : 1, n : 1, P(A, B) : [not](A and B), Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and [not](A), x_{1} : A, y_{1} : B
# 2	instantiation	6, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not](A)} [not](A and B)]
# 	P(A) : forall_{B in BOOLEAN | [not](A)} [not](A and B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 10, 11	|- {[not](A and B) if A in BOOLEAN ,  (B in BOOLEAN) and [not](A). \\  = {[not](A and B) if A in BOOLEAN ,  B in BOOLEAN ,  [not](A).
# 	n : 2, a : [not](A and B), Q : A in BOOLEAN, R : (B in BOOLEAN, [not](A))
# 6	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 7	instantiation	14, 12, 13	|- forall_{B in BOOLEAN | [not](TRUE)} [not](TRUE and B)
# 	P(B) : [not](TRUE and B), Q(B) : [not](TRUE), A : B
# 8	instantiation	14, 15, 16	|- forall_{B in BOOLEAN | [not](FALSE)} [not](FALSE and B)
# 	P(B) : [not](FALSE and B), Q(B) : [not](FALSE), A : B
# 9	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, R_{2}, ..., R_{n}} ({a if Q ,  R_{1} and  R_{2} and  ... and  R_{n}. \\  = {a if Q, R_{1} ,  R_{2} ,  ... ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 10	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 11	instantiation	17	|- |(B in BOOLEAN, [not](A))| = |(1, ..., 2)|
# 	a : B in BOOLEAN, b : [not](A)
# 12	instantiation	18, 19	|- [not](TRUE) => [not](TRUE and TRUE)
# 	A : [not](TRUE), B : [not](TRUE and TRUE)
# 13	instantiation	18, 19	|- [not](TRUE) => [not](TRUE and FALSE)
# 	A : [not](TRUE), B : [not](TRUE and FALSE)
# 14	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 	proveit.logic.booleans.conditioned_forall_over_bool_by_cases
# 15	deduction	20	|- [not](FALSE) => [not](FALSE and TRUE)
# 16	deduction	21	|- [not](FALSE) => [not](FALSE and FALSE)
# 17	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 18	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 19	instantiation	22, 23	|- [not]([not](TRUE))
# 	A : [not](TRUE)
# 20	theorem		|- [not](FALSE and TRUE)
# 	proveit.logic.booleans.conjunction.false_and_true_negated
# 21	theorem		|- [not](FALSE and FALSE)
# 	proveit.logic.booleans.conjunction.false_and_false_negated
# 22	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 23	axiom		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
