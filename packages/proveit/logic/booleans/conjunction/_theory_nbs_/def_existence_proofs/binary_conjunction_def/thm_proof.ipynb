# %% [markdown]
# Existence proof for <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">conjunction</a>.<a class="ProveItLink" href="../../definitions.ipynb#binary_conjunction_def">binary_conjunction_def</a>
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A, B, P, x, y
from proveit import Lambda, Function
from proveit.logic import Implies, Not, Forall, Equals, And
from proveit.logic.booleans.quantification.existence import existence_by_basic_example

# %%
# %existence_proving binary_conjunction_def
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of existence for<br><strong id="binary_conjunction_def">binary_conjunction_def:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/6cf23bdde9847f68922be1f431b6b2dafa650cfc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/definitions/ca28e0406887b9cb309b7c6be0e7832d6348c2b10/dependencies.ipynb">dependencies</a>)<br>
# binary_conjunction_def may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
existence_by_basic_example
# Out:
# |- forall_{P} [forall_{x | P(x)} [exists_{y} P(y)]]

# %%
conj_def_rhs = binary_conjunction_def.instance_expr.instance_expr.rhs
# Out:
# <strong id="conj_def_rhs">conj_def_rhs:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/20236bec9ca725ad2bac2efefe8fa2ea5c104b080/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
and_op = And._operator_.as_variable()
# Out:
# <strong id="and_op">and_op:</strong> <a class="ProveItLink" href="../../../__pv_it/definitions/36aabccb37642190cd7d796b600e159cbf4019360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
existence_by_basic_example.instantiate({P:Lambda(and_op, Forall((A, B), Equals(Function(and_op, [A, B]), conj_def_rhs))), 
                                        x:Lambda((A, B), conj_def_rhs), y:and_op})
# Out:
# |- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
# binary_conjunction_def has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.conjunction.binary_conjunction_def is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- exists_{and} [forall_{A, B} (and(A, B) = [not](A => [not](B)))]
# 	P(and) : forall_{A, B} (and(A, B) = [not](A => [not](B))), x(A, B) : [not](A => [not](B)), y : and
# 1	theorem		|- forall_{P} [forall_{x | P(x)} [exists_{y} P(y)]]
# 	proveit.logic.booleans.quantification.existence.existence_by_basic_example
# 2	generalization	3	|- forall_{A, B} ([not](A => [not](B)) = [not](A => [not](B)))
# 3	instantiation	4	|- [not](A => [not](B)) = [not](A => [not](B))
# 	x : [not](A => [not](B))
# 4	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
