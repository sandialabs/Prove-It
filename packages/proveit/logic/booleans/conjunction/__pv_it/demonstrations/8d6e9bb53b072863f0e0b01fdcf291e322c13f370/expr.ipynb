# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, C, ExprRange, IndexedVar, n, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([B, ExprRange(x, IndexedVar(C, x), one, n)]), Add(n, one))
# Out:
# expr: |(B, C_{1}, ..C_{x}.., C_{n})| = (n + 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(B, C_{1}, \ldots, C_{n}\right)| = \left(n + 1\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(B, C_{1}, ..C_{x}.., C_{n})| = (n + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(B, C_{1}, ..C_{x}.., C_{n})|, n + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(B, C_{1}, ..C_{x}.., C_{n})|
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. n + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((B, C_{1}, ..C_{x}.., C_{n}))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (n, 1)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 9. (B, C_{1}, ..C_{x}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C_{1}, ..C_{x}.., C_{n}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. x -> C_{x}
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. C_{x}
#     core type: IndexedVar
# variable: 16
# index: 17
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
