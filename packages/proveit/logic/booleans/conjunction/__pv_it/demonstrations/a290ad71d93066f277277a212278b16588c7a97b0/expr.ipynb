# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(n, sub_expr1, one)
expr = Equals(Add(Add(one, sub_expr1, one), sub_expr2), Add(one, sub_expr2))
# Out:
# expr: ((1 - 1 + 1) + (n - 1 + 1)) = (1 + (n - 1 + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 - 1 + 1\right) + \left(n - 1 + 1\right)\right) = \left(1 + \left(n - 1 + 1\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((1 - 1 + 1) + (n - 1 + 1)) = (1 + (n - 1 + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 - 1 + 1) + (n - 1 + 1), 1 + (n - 1 + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 - 1 + 1) + (n - 1 + 1)
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. 1 + (n - 1 + 1)
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (1 - 1 + 1, n - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (1, n - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 7. 1 - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. n - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 15, 13, 15
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (n, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 15
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
