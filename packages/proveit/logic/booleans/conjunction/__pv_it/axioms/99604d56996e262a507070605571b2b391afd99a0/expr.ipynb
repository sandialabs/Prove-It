# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Equals, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m, B], Equals(And(A_1_to_m, B), And(And(A_1_to_m), B)).with_wrapping_at(2)), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}, B}~\left(\begin{array}{c} \left(A_{1} \land \ldots \land A_{m} \land B\right) =  \\ \left(\left(A_{1} \land \ldots \land A_{m}\right) \land B\right) \end{array}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Natural.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)) if m in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m}, B} ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}, B) -> ((A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B))
#    core type: Lambda
#    parameters: 15\n   body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 24, 10
# 9. (A_{1} and ..A_{_a}.. and A_{m} and B) =  \\ ((A_{1} and ..A_{_a}.. and A_{m}) and B)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A_{1} and ..A_{_a}.. and A_{m} and B, (A_{1} and ..A_{_a}.. and A_{m}) and B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A_{1} and ..A_{_a}.. and A_{m} and B
#     core type: Operation
#     operator: 19
#     operands: 15
# 14. (A_{1} and ..A_{_a}.. and A_{m}) and B
#     core type: Operation
#     operator: 19
#     operands: 16
# 15. (A_{1}, ..A_{_a}.., A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 16. (A_{1} and ..A_{_a}.. and A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 22. _a -> A_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 25
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. A_{_a}
#     core type: IndexedVar
# variable: 26
# index: 27
# 26. A
#     core type: Variable
#     sub-expressions:
# 27. _a
#     core type: Variable
#     sub-expressions:
