# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#multi_conjunction_def">multi_conjunction_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans.conjunction import multi_conjunction_def

# %%
# %dependencies multi_conjunction_def
# Out:
# <h3>Theorems/conjectures that depend directly on multi_conjunction_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/unary_and_reduction_lemma/thm_proof.ipynb">proveit.logic.booleans.conjunction.unary_and_reduction_lemma</a></dt><dd><a class="ProveItLink" href="../../theorems/caa4fa85f429badd63ed4a0e8aecb9c844bff2a80/expr.ipynb"><img src="../../theorems/caa4fa85f429badd63ed4a0e8aecb9c844bff2a80/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
