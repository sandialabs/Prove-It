# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#left_in_bool">left_in_bool</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import left_in_bool

# %%
# check that the built expression is the same as the stored expression
assert left_in_bool.expr == stored_expr
assert left_in_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: left_in_bool matches stored_expr")
# Out:
# Passed sanity check: left_in_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(left_in_bool.latex())
# Out:
# \vdash \forall_{A, B~|~\left(A \land B\right) \in \mathbb{B}}~\left(A \in \mathbb{B}\right)

# %%
# display the expression information
left_in_bool.expr_info()
# Out:
# 0. forall_{A, B | (A and B) in BOOLEAN} (A in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A in BOOLEAN if (A and B) in BOOLEAN.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {A in BOOLEAN if (A and B) in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (A and B) in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A and B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A and B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
