# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Boolean, Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
sub_expr1 = [Boolean]
sub_expr2 = Equals(And(A, B), And(B, A))
expr = Implies(Forall([A], Forall([B], sub_expr2, domains = sub_expr1), domains = sub_expr1), Forall([A, B], sub_expr2, domains = [Boolean, Boolean])).with_wrapping_at(1)
# Out:
# expr: [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))]] \\  => [forall_{A, B in BOOLEAN} ((A and B) = (B and A))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left[\forall_{A \in \mathbb{B}}~\left[\forall_{B \in \mathbb{B}}~\left(\left(A \land B\right) = \left(B \land A\right)\right)\right]\right] \\  \Rightarrow \left[\forall_{A, B \in \mathbb{B}}~\left(\left(A \land B\right) = \left(B \land A\right)\right)\right] \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))]] \\  => [forall_{A, B in BOOLEAN} ((A and B) = (B and A))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))], forall_{A, B in BOOLEAN} ((A and B) = (B and A)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{A in BOOLEAN} [forall_{B in BOOLEAN} ((A and B) = (B and A))]
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. forall_{A, B in BOOLEAN} ((A and B) = (B and A))
#    core type: Operation
#    operator: 11
#    operand: 6
# 5. A -> {forall_{B in BOOLEAN} ((A and B) = (B and A)) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 30
#    body: 7
# 6. (A, B) -> {(A and B) = (B and A) if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Lambda
#    parameters: 26\n   body: 8
# 7. {forall_{B in BOOLEAN} ((A and B) = (B and A)) if A in BOOLEAN.
#    core type: Conditional
#    value: 9
#    condition: 15
# 8. {(A and B) = (B and A) if A in BOOLEAN ,  B in BOOLEAN.
#    core type: Conditional
#    value: 16
#    condition: 10
# 9. forall_{B in BOOLEAN} ((A and B) = (B and A))
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. (A in BOOLEAN) and (B in BOOLEAN)
#     core type: Operation
#     operator: 27
#     operands: 13
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. B -> {(A and B) = (B and A) if B in BOOLEAN.
#     core type: Lambda
#     parameter: 29
#     body: 14
# 13. (A in BOOLEAN, B in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 14. {(A and B) = (B and A) if B in BOOLEAN.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. A in BOOLEAN
#     core type: Operation
#     operator: 21
#     operands: 18
# 16. (A and B) = (B and A)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. B in BOOLEAN
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 30, 25
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (A and B, B and A)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 29, 25
# 23. A and B
#     core type: Operation
#     operator: 27
#     operands: 26
# 24. B and A
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 26. (A, B)
#     core type: ExprTuple
#     sub-expressions: 30, 29
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (B, A)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. B
#     core type: Variable
#     sub-expressions:
# 30. A
#     core type: Variable
#     sub-expressions:
