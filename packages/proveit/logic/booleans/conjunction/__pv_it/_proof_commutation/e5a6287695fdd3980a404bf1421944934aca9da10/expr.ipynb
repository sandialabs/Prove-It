# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B
from proveit.logic import And, Boolean, Equals, FALSE, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([B], Equals(And(FALSE, B), And(B, FALSE)), domains = [Boolean])
# Out:
# expr: forall_{B in BOOLEAN} ((FALSE and B) = (B and FALSE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{B \in \mathbb{B}}~\left(\left(\bot \land B\right) = \left(B \land \bot\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{B in BOOLEAN} ((FALSE and B) = (B and FALSE))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> {(FALSE and B) = (B and FALSE) if B in BOOLEAN.
#    core type: Lambda
#    parameter: 16
#    body: 3
# 3. {(FALSE and B) = (B and FALSE) if B in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (FALSE and B) = (B and FALSE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. B in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (FALSE and B, B and FALSE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 16, 12
# 10. FALSE and B
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. B and FALSE
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 13. (FALSE, B)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (B, FALSE)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. FALSE
#     core type: Literal
#     sub-expressions:
