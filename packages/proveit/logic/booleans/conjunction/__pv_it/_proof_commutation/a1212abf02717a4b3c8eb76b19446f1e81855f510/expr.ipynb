# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import And, Boolean, Equals, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Conditional(Equals(And(A, B), And(B, A)), InSet(B, Boolean)))
# Out:
# expr: B -> {(A and B) = (B and A) if B in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B \mapsto \left\{\left(A \land B\right) = \left(B \land A\right) \textrm{ if } B \in \mathbb{B}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. B -> {(A and B) = (B and A) if B in BOOLEAN.
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. {(A and B) = (B and A) if B in BOOLEAN.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (A and B) = (B and A)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. B in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A and B, B and A)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 8. A and B
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. B and A
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (B, A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
