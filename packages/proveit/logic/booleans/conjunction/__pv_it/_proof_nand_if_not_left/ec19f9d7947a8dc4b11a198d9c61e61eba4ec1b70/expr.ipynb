# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional
from proveit.logic import And, Boolean, InSet, Not, TRUE

# %%
# build up the expression from sub-expressions
expr = Conditional(Not(And(TRUE, B)), And(InSet(B, Boolean), Not(TRUE)))
# Out:
# expr: {[not](TRUE and B) if B in BOOLEAN ,  [not](TRUE).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lnot \left(\top \land B\right) \textrm{ if } B \in \mathbb{B} ,  \lnot \top\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[not](TRUE and B) if B in BOOLEAN ,  [not](TRUE).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [not](TRUE and B)
#    core type: Operation
#    operator: 11
#    operand: 3
# 2. (B in BOOLEAN) and [not](TRUE)
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. TRUE and B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B in BOOLEAN, [not](TRUE))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (TRUE, B)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 7. B in BOOLEAN
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not](TRUE)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. BOOLEAN
#     core type: Literal
#     sub-expressions:
