# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import And, Boolean, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Conditional(Not(And(A, B)), And(InSet(B, Boolean), Not(A))))
# Out:
# expr: B -> {[not](A and B) if B in BOOLEAN ,  [not](A).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B \mapsto \left\{\lnot \left(A \land B\right) \textrm{ if } B \in \mathbb{B} ,  \lnot A\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. B -> {[not](A and B) if B in BOOLEAN ,  [not](A).
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. {[not](A and B) if B in BOOLEAN ,  [not](A).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [not](A and B)
#    core type: Operation
#    operator: 12
#    operand: 4
# 3. (B in BOOLEAN) and [not](A)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. A and B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (B in BOOLEAN, [not](A))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. B in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. [not](A)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. BOOLEAN
#     core type: Literal
#     sub-expressions:
