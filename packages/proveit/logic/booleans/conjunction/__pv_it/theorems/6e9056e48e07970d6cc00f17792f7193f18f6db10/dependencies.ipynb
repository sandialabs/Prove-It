# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#empty_conjunction_eval">empty_conjunction_eval</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/empty_conjunction_eval/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.booleans.conjunction import empty_conjunction_eval

# %%
# %dependencies empty_conjunction_eval
# Out:
# <h3>Axioms required (directly or indirectly) to prove empty_conjunction_eval</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/axioms.ipynb#empty_conjunction">proveit.logic.booleans.conjunction.empty_conjunction</a></dt><dd><a class="ProveItLink" href="../c16d53f7a5fe53295bdcbfd1cadfd0f0f61454f00/expr.ipynb"><img src="../c16d53f7a5fe53295bdcbfd1cadfd0f0f61454f00/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../_theory_nbs_/axioms.ipynb#eq_true_intro">proveit.logic.booleans.eq_true_intro</a></dt><dd><a class="ProveItLink" href="../../../../__pv_it/axioms/654339f5fb5a65119fa860e26cec5f77107afe860/expr.ipynb"><img src="../../../../__pv_it/axioms/654339f5fb5a65119fa860e26cec5f77107afe860/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
# <h3>Theorems/conjectures that depend directly on empty_conjunction_eval</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/unary_and_reduction_lemma/thm_proof.ipynb">proveit.logic.booleans.conjunction.unary_and_reduction_lemma</a></dt><dd><a class="ProveItLink" href="../caa4fa85f429badd63ed4a0e8aecb9c844bff2a80/expr.ipynb"><img src="../caa4fa85f429badd63ed4a0e8aecb9c844bff2a80/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
