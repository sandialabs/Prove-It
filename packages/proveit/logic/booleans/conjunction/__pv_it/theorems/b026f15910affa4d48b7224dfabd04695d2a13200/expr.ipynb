# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import D, ExprRange, IndexedVar, Variable, n
from proveit.logic import Boolean, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprRange(sub_expr1, InSet(IndexedVar(D, sub_expr1), Boolean), one, n)
# Out:
# expr: (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(D_{1} \in \mathbb{B}\right), \ldots, \left(D_{n} \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> (D_{_a} in BOOLEAN)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. D_{_a} in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (D_{_a}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. D_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 8. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 9. D
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
