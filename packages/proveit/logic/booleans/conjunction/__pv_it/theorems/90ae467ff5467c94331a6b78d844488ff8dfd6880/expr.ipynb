# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C, Conditional, Lambda, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda([l, m, n], Conditional(Forall(instance_param_or_params = [A_1_to_l, B_1_to_m, C, D_1_to_n], instance_expr = Equals(And(A_1_to_l, B_1_to_m, C, D_1_to_n), And(A_1_to_l, C, B_1_to_m, D_1_to_n)).with_wrapping_at(2), domain = Boolean), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(l, m, n\right) \mapsto \left\{\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l}\land B_{1} \land  B_{2} \land  \ldots \land  B_{m} \land C\land D_{1} \land  D_{2} \land  \ldots \land  D_{n}\right) =  \\ \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l} \land C\land B_{1} \land  B_{2} \land  \ldots \land  B_{m}\land D_{1} \land  D_{2} \land  \ldots \land  D_{n}\right) \end{array} \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 43, 45, 48
# 2. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 29
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 28\n   body: 12
# 9. l in Natural
#    core type: Operation
#    operator: 51
#    operands: 13
# 10. m in Natural
#     core type: Operation
#     operator: 51
#     operands: 14
# 11. n in Natural
#     core type: Operation
#     operator: 51
#     operands: 15
# 12. {(A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN) ,  C in BOOLEAN, (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 18
# 14. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 18
# 15. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 18
# 16. (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN) and (C in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 29
#     operands: 21
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}, A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN), C in BOOLEAN,(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 22. A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m} and Cand D_{1} and  D_{2} and  ... and  D_{n}
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. A_{1} and  A_{2} and  ... and  A_{l} and Cand B_{1} and  B_{2} and  ... and  B_{m}and D_{1} and  D_{2} and  ... and  D_{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 47
#     end_index: 43
# 25. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 47
#     end_index: 45
# 26. C in BOOLEAN
#     core type: Operation
#     operator: 51
#     operands: 33
# 27. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 47
#     end_index: 48
# 28. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m}, C,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 40, 37
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. (A_{1}, A_{2}, ..., A_{l}, C,B_{1}, B_{2}, ..., B_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 40, 36, 37
# 31. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 61
#     body: 38
# 32. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 61
#     body: 39
# 33. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 56
# 34. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 61
#     body: 41
# 35. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 43
# 36. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 37. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 38. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 51
#     operands: 49
# 39. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 51
#     operands: 50
# 40. C
#     core type: Variable
#     sub-expressions:
# 41. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 51
#     operands: 52
# 42. _a -> A_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 53
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. _a -> B_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. _a -> D_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 55
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 53, 56
# 50. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 61
# 54. B_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 55. D_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. B
#     core type: Variable
#     sub-expressions:
# 59. D
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
