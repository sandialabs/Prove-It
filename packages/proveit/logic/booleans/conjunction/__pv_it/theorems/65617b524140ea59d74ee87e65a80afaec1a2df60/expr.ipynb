# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, ExprRange, IndexedVar, Variable, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And, Boolean, Equals, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Equals(And(A_1_to_l, And(B_1_to_m), C_1_to_n), And(A_1_to_l, B_1_to_m, C_1_to_n)).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(A, sub_expr1), Boolean), one, l), ExprRange(sub_expr1, InSet(IndexedVar(B, sub_expr1), Boolean), one, m), ExprRange(sub_expr1, InSet(IndexedVar(C, sub_expr1), Boolean), one, n)))
# Out:
# expr: {(A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(A_{1} \land \ldots \land A_{l} \land \left(B_{1} \land \ldots \land B_{m}\right) \land C_{1} \land \ldots \land C_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C_{1} \land \ldots \land C_{n}\right) \end{array} \textrm{ if } A_{1} \in \mathbb{B} ,  \ldots ,  A_{l} \in \mathbb{B} ,  B_{1} \in \mathbb{B} ,  \ldots ,  B_{m} \in \mathbb{B} ,  C_{1} \in \mathbb{B} ,  \ldots ,  C_{n} \in \mathbb{B}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C_{1} in BOOLEAN ,  ..C_{_a} in BOOLEAN.. ,  C_{n} in BOOLEAN.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C_{1} in BOOLEAN) and ..(C_{_a} in BOOLEAN).. and (C_{n} in BOOLEAN)
#    core type: Operation
#    operator: 22
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}, A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C_{1} in BOOLEAN, ..C_{_a} in BOOLEAN.., C_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. A_{1} and ..A_{_a}.. and A_{l} and (B_{1} and ..B_{_a}.. and B_{m}) and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 22
#    operands: 11
# 7. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 22
#    operands: 12
# 8. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 37
#    end_index: 25
# 9. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 37
#    end_index: 38
# 10. (C_{1} in BOOLEAN), ..(C_{_a} in BOOLEAN).., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 37
#     end_index: 27
# 11. (A_{1}, ..A_{_a}.., A_{l}, B_{1} and ..B_{_a}.. and B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 16, 18
# 12. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C_{1}, ..C_{_a}.., C_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 32, 18
# 13. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 19
# 14. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 20
# 15. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 43
#     body: 21
# 16. B_{1} and ..B_{_a}.. and B_{m}
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 37
#     end_index: 25
# 18. C_{1}, ..C_{_a}.., C_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 37
#     end_index: 27
# 19. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 30
#     operands: 28
# 20. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 30
#     operands: 29
# 21. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 30
#     operands: 31
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (B_{1}, ..B_{_a}.., B_{m})
#     core type: ExprTuple
#     sub-expressions: 32
# 24. _a -> A_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 33
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. _a -> C_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 34
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 29. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 41, 35
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 33. A_{_a}
#     core type: IndexedVar
# variable: 39
# index: 43
# 34. C_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 35. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 36. _a -> B_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 41
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. A
#     core type: Variable
#     sub-expressions:
# 40. C
#     core type: Variable
#     sub-expressions:
# 41. B_{_a}
#     core type: IndexedVar
# variable: 42
# index: 43
# 42. B
#     core type: Variable
#     sub-expressions:
# 43. _a
#     core type: Variable
#     sub-expressions:
