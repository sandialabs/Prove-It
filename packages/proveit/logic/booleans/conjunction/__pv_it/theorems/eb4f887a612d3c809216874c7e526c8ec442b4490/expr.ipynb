# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Equals, TRUE

# %%
# build up the expression from sub-expressions
sub_expr1 = And(A_1_to_m)
expr = Conditional(Equals(sub_expr1, TRUE), sub_expr1)
# Out:
# expr: {(A_{1} and ..A_{_a}.. and A_{m}) = TRUE if A_{1} and ..A_{_a}.. and A_{m}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A_{1} \land \ldots \land A_{m}\right) = \top \textrm{ if } A_{1} \land \ldots \land A_{m}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(A_{1} and ..A_{_a}.. and A_{m}) = TRUE if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Conditional
#    value: 1
#    condition: 4
# 1. (A_{1} and ..A_{_a}.. and A_{m}) = TRUE
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (A_{1} and ..A_{_a}.. and A_{m}, TRUE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. TRUE
#    core type: Literal
#    sub-expressions:
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. _a -> A_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. A_{_a}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. _a
#     core type: Variable
#     sub-expressions:
