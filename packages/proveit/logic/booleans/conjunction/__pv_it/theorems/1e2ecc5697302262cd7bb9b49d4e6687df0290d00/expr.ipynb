# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import And, Not

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Not(And(A, B)), And(Not(A), Not(B))))
# Out:
# expr: (A, B) -> {[not](A and B) if [not](A) ,  [not](B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\lnot \left(A \land B\right) \textrm{ if } \lnot A ,  \lnot B\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {[not](A and B) if [not](A) ,  [not](B).
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. {[not](A and B) if [not](A) ,  [not](B).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [not](A and B)
#    core type: Operation
#    operator: 11
#    operand: 4
# 3. [not](A) and [not](B)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. A and B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ([not](A), [not](B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 10
# 9. [not](B)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
