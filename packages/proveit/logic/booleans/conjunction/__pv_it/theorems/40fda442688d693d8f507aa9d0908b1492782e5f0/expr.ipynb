# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Boolean, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m], InSet(And(A_1_to_m), Boolean), domains = [Boolean]), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m} \in \mathbb{B}}~\left(\left(A_{1} \land \ldots \land A_{m}\right) \in \mathbb{B}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN) if m in Natural.
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN) if m in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in Natural
#    core type: Operation
#    operator: 24
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Lambda
#    parameters: 17\n   body: 8
# 7. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 23, 9
# 8. {(A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN if (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} and ..A_{_a}.. and A_{m}) in BOOLEAN
#     core type: Operation
#     operator: 24
#     operands: 12
# 11. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{m} in BOOLEAN)
#     core type: Operation
#     operator: 16
#     operands: 13
# 12. (A_{1} and ..A_{_a}.. and A_{m}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 14, 27
# 13. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{m} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 22
#     end_index: 23
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 29
#     body: 20
# 19. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. m
#     core type: Variable
#     sub-expressions:
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. A_{_a}
#     core type: IndexedVar
# variable: 28
# index: 29
# 27. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 28. A
#     core type: Variable
#     sub-expressions:
# 29. _a
#     core type: Variable
#     sub-expressions:
