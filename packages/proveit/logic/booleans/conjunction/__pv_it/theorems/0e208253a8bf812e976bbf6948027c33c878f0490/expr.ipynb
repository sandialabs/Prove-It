# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([A_1_to_l, B_1_to_m, C, D_1_to_n], Equals(And(A_1_to_l, B_1_to_m, C, D_1_to_n), And(A_1_to_l, C, B_1_to_m, D_1_to_n)).with_wrapping_at(2), domains = [Boolean, Boolean, Boolean, Boolean])
# Out:
# expr: forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C, D_{1}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C \land D_{1} \land \ldots \land D_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land C \land B_{1} \land \ldots \land B_{m} \land D_{1} \land \ldots \land D_{n}\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Lambda
#    parameters: 15\n   body: 3
# 3. {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C in BOOLEAN) and (D_{1} in BOOLEAN) and ..(D_{_a} in BOOLEAN).. and (D_{n} in BOOLEAN)
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}, A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C in BOOLEAN, D_{1} in BOOLEAN, ..D_{_a} in BOOLEAN.., D_{n} in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 34
#     end_index: 30
# 12. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 34
#     end_index: 32
# 13. C in BOOLEAN
#     core type: Operation
#     operator: 38
#     operands: 20
# 14. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 34
#     end_index: 35
# 15. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 27, 24
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 27, 23, 24
# 18. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 47
#     body: 25
# 19. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 47
#     body: 26
# 20. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 27, 43
# 21. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 47
#     body: 28
# 22. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 34
#     end_index: 30
# 23. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 34
#     end_index: 32
# 24. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 25. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 38
#     operands: 36
# 26. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 38
#     operands: 37
# 27. C
#     core type: Variable
#     sub-expressions:
# 28. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 38
#     operands: 39
# 29. _a -> A_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 40
# 30. l
#     core type: Variable
#     sub-expressions:
# 31. _a -> B_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 41
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. _a -> D_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 43
# 37. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. A_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 41. B_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 42. D_{_a}
#     core type: IndexedVar
# variable: 46
# index: 47
# 43. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. B
#     core type: Variable
#     sub-expressions:
# 46. D
#     core type: Variable
#     sub-expressions:
# 47. _a
#     core type: Variable
#     sub-expressions:
