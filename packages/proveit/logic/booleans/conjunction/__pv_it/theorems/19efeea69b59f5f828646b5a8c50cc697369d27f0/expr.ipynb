# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprRange, IndexedVar, Lambda, i, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Not, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Lambda([A_1_to_m], Conditional(And(A_1_to_m), Not(Or(ExprRange(i, Not(IndexedVar(A, i)), one, m)))))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if [not]([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{m}\right) \mapsto \left\{A_{1} \land \ldots \land A_{m} \textrm{ if } \lnot \left((\lnot A_{1}) \lor \ldots \lor (\lnot A_{m})\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if [not]([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})).
#    core type: Lambda
#    parameters: 5\n   body: 1
# 1. {A_{1} and ..A_{_a}.. and A_{m} if [not]([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A_{1} and ..A_{_a}.. and A_{m}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. [not]([not](A_{1}) or ..[not](A_{i}).. or [not](A_{m}))
#    core type: Operation
#    operator: 18
#    operand: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. [not](A_{1}) or ..[not](A_{i}).. or [not](A_{m})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 16
#     body: 12
# 11. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. A_{_a}
#     core type: IndexedVar
# variable: 20
# index: 16
# 13. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 21
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. _a
#     core type: Variable
#     sub-expressions:
# 17. [not](A_{i})
#     core type: Operation
#     operator: 18
#     operand: 19
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. A_{i}
#     core type: IndexedVar
# variable: 20
# index: 21
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. i
#     core type: Variable
#     sub-expressions:
