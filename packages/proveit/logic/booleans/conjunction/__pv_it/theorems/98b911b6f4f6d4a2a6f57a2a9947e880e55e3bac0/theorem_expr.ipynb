# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#disassociation">disassociation</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import disassociation

# %%
# check that the built expression is the same as the stored expression
assert disassociation.expr == stored_expr
assert disassociation.expr._style_id == stored_expr._style_id
print("Passed sanity check: disassociation matches stored_expr")
# Out:
# Passed sanity check: disassociation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C_{1}, C_{2}, \ldots, C_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l} \land \left(B_{1} \land  B_{2} \land  \ldots \land  B_{m}\right)\land C_{1} \land  C_{2} \land  \ldots \land  C_{n}\right) =  \\ \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l}\land B_{1} \land  B_{2} \land  \ldots \land  B_{m}\land C_{1} \land  C_{2} \land  \ldots \land  C_{n}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 43, 56, 45
# 4. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 40
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#     core type: Lambda
#     parameters: 30\n    body: 14
# 11. l in Natural
#     core type: Operation
#     operator: 48
#     operands: 15
# 12. m in Natural
#     core type: Operation
#     operator: 48
#     operands: 16
# 13. n in Natural
#     core type: Operation
#     operator: 48
#     operands: 17
# 14. {(A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN), (B_{1} in BOOLEAN) ,  (B_{2} in BOOLEAN) ,  ... ,  (B_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 20
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 17. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 20
# 18. (A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN)and (B_{1} in BOOLEAN) and  (B_{2} in BOOLEAN) and  ... and  (B_{m} in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{n} in BOOLEAN)
#     core type: Operation
#     operator: 40
#     operands: 23
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}, A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN),(B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN),(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 24. A_{1} and  A_{2} and  ... and  A_{l} and (B_{1} and  B_{2} and  ... and  B_{m})and C_{1} and  C_{2} and  ... and  C_{n}
#     core type: Operation
#     operator: 40
#     operands: 29
# 25. A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}
#     core type: Operation
#     operator: 40
#     operands: 30
# 26. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 55
#     end_index: 43
# 27. (B_{1} in BOOLEAN), (B_{2} in BOOLEAN), ..., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 55
#     end_index: 56
# 28. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 55
#     end_index: 45
# 29. (A_{1}, A_{2}, ..., A_{l}, B_{1} and  B_{2} and  ... and  B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 34, 36
# 30. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 50, 36
# 31. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 37
# 32. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 38
# 33. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 39
# 34. B_{1} and  B_{2} and  ... and  B_{m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 55
#     end_index: 43
# 36. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 55
#     end_index: 45
# 37. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 46
# 38. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 47
# 39. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 49
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. (B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 50
# 42. _a -> A_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 51
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. _a -> C_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 52
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 47. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 59, 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 51. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 62
# 52. C_{_a}
#     core type: IndexedVar
# variable: 58
# index: 62
# 53. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 54. _a -> B_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. m
#     core type: Variable
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. C
#     core type: Variable
#     sub-expressions:
# 59. B_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 60. B
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
