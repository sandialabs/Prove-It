# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import C, Conditional, l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_l, B_1_to_m, C, D_1_to_n], Equals(And(A_1_to_l, B_1_to_m, C, D_1_to_n), And(A_1_to_l, C, B_1_to_m, D_1_to_n)).with_wrapping_at(2), domains = [Boolean, Boolean, Boolean, Boolean]), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})) if l in Natural ,  m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{l}, B_{1}, \ldots, B_{m}, C, D_{1}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \left(A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C \land D_{1} \land \ldots \land D_{n}\right) =  \\ \left(A_{1} \land \ldots \land A_{l} \land C \land B_{1} \land \ldots \land B_{m} \land D_{1} \land \ldots \land D_{n}\right) \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n} in BOOLEAN} ((A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 26
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n}) -> {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Lambda
#    parameters: 25\n   body: 6
# 5. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. {(A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}) if A_{1} in BOOLEAN ,  ..A_{_a} in BOOLEAN.. ,  A_{l} in BOOLEAN ,  B_{1} in BOOLEAN ,  ..B_{_a} in BOOLEAN.. ,  B_{m} in BOOLEAN ,  C in BOOLEAN ,  D_{1} in BOOLEAN ,  ..D_{_a} in BOOLEAN.. ,  D_{n} in BOOLEAN.
#    core type: Conditional
#    value: 10
#    condition: 11
# 7. l in Natural
#    core type: Operation
#    operator: 48
#    operands: 12
# 8. m in Natural
#    core type: Operation
#    operator: 48
#    operands: 13
# 9. n in Natural
#    core type: Operation
#    operator: 48
#    operands: 14
# 10. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}) =  \\ (A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (A_{1} in BOOLEAN) and ..(A_{_a} in BOOLEAN).. and (A_{l} in BOOLEAN) and (B_{1} in BOOLEAN) and ..(B_{_a} in BOOLEAN).. and (B_{m} in BOOLEAN) and (C in BOOLEAN) and (D_{1} in BOOLEAN) and ..(D_{_a} in BOOLEAN).. and (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 26
#     operands: 17
# 12. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 40, 18
# 13. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 18
# 14. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}, A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (A_{1} in BOOLEAN, ..A_{_a} in BOOLEAN.., A_{l} in BOOLEAN, B_{1} in BOOLEAN, ..B_{_a} in BOOLEAN.., B_{m} in BOOLEAN, C in BOOLEAN, D_{1} in BOOLEAN, ..D_{_a} in BOOLEAN.., D_{n} in BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23, 24
# 18. Natural
#     core type: Literal
#     sub-expressions:
# 19. A_{1} and ..A_{_a}.. and A_{l} and B_{1} and ..B_{_a}.. and B_{m} and C and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 26
#     operands: 25
# 20. A_{1} and ..A_{_a}.. and A_{l} and C and B_{1} and ..B_{_a}.. and B_{m} and D_{1} and ..D_{_a}.. and D_{n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. (A_{1} in BOOLEAN), ..(A_{_a} in BOOLEAN).., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 44
#     end_index: 40
# 22. (B_{1} in BOOLEAN), ..(B_{_a} in BOOLEAN).., (B_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 44
#     end_index: 42
# 23. C in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 30
# 24. (D_{1} in BOOLEAN), ..(D_{_a} in BOOLEAN).., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 44
#     end_index: 45
# 25. (A_{1}, ..A_{_a}.., A_{l}, B_{1}, ..B_{_a}.., B_{m}, C, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 33, 37, 34
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (A_{1}, ..A_{_a}.., A_{l}, C, B_{1}, ..B_{_a}.., B_{m}, D_{1}, ..D_{_a}.., D_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 37, 33, 34
# 28. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 57
#     body: 35
# 29. _a -> (B_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 57
#     body: 36
# 30. (C, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 37, 53
# 31. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 57
#     body: 38
# 32. A_{1}, ..A_{_a}.., A_{l}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 44
#     end_index: 40
# 33. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 44
#     end_index: 42
# 34. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 35. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 46
# 36. B_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 47
# 37. C
#     core type: Variable
#     sub-expressions:
# 38. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 48
#     operands: 49
# 39. _a -> A_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. _a -> B_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 51
# 42. m
#     core type: Variable
#     sub-expressions:
# 43. _a -> D_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 50, 53
# 47. (B_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. A_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 51. B_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 52. D_{_a}
#     core type: IndexedVar
# variable: 56
# index: 57
# 53. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 54. A
#     core type: Variable
#     sub-expressions:
# 55. B
#     core type: Variable
#     sub-expressions:
# 56. D
#     core type: Variable
#     sub-expressions:
# 57. _a
#     core type: Variable
#     sub-expressions:
