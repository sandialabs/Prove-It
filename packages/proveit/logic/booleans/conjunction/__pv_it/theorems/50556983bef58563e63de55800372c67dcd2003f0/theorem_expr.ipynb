# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#left_from_and">left_from_and</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import left_from_and

# %%
# check that the built expression is the same as the stored expression
assert left_from_and.expr == stored_expr
assert left_from_and.expr._style_id == stored_expr._style_id
print("Passed sanity check: left_from_and matches stored_expr")
# Out:
# Passed sanity check: left_from_and matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(left_from_and.latex())
# Out:
# \vdash \forall_{A, B~|~A, B}~A

# %%
# display the expression information
left_from_and.expr_info()
# Out:
# 0. forall_{A, B | A, B} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A if A ,  B.
#    core type: Lambda
#    parameters: 6\n   body: 3
# 3. {A if A ,  B.
#    core type: Conditional
#    value: 7
#    condition: 4
# 4. A and B
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
