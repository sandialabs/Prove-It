# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([m], Forall([A_1_to_m], And(A_1_to_m), condition = A_1_to_m), domains = [Natural])
# Out:
# expr: forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}}~\left[\forall_{A_{1}, \ldots, A_{m}~|~A_{1}, \ldots, A_{m}}~\left(A_{1} \land \ldots \land A_{m}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m in Natural} [forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m}) if m in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} (A_{1} and ..A_{_a}.. and A_{m})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}) -> {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Lambda
#    parameters: 13\n   body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 9. {A_{1} and ..A_{_a}.. and A_{m} if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Conditional
#    value: 11
#    condition: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 14. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 15. _a -> A_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 18
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. A_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
