# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unary_and_is_true_reduction">unary_and_is_true_reduction</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import unary_and_is_true_reduction

# %%
# check that the built expression is the same as the stored expression
assert unary_and_is_true_reduction.expr == stored_expr
assert unary_and_is_true_reduction.expr._style_id == stored_expr._style_id
print("Passed sanity check: unary_and_is_true_reduction matches stored_expr")
# Out:
# Passed sanity check: unary_and_is_true_reduction matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(unary_and_is_true_reduction.latex())
# Out:
# \vdash \forall_{A}~\left(\left(\left[\land\right]\left(A\right) = \top\right) = \left(A = \top\right)\right)

# %%
# display the expression information
unary_and_is_true_reduction.expr_info()
# Out:
# 0. forall_{A} (([and](A) = TRUE) = (A = TRUE))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> (([and](A) = TRUE) = (A = TRUE))
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. ([and](A) = TRUE) = (A = TRUE)
#    core type: Operation
#    operator: 8
#    operands: 4
# 4. ([and](A) = TRUE, A = TRUE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. [and](A) = TRUE
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. A = TRUE
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ([and](A), TRUE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (A, TRUE)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 10. [and](A)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. TRUE
#     core type: Literal
#     sub-expressions:
# 12. and
#     core type: Literal
#     sub-expressions:
# ...
