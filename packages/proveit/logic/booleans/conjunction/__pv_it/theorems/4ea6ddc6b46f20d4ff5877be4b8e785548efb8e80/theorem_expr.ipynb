# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#false_eval">false_eval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import false_eval

# %%
# check that the built expression is the same as the stored expression
assert false_eval.expr == stored_expr
assert false_eval.expr._style_id == stored_expr._style_id
print("Passed sanity check: false_eval matches stored_expr")
# Out:
# Passed sanity check: false_eval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{m}, C_{1}, C_{2}, \ldots, C_{n} \in \mathbb{B}}~\left(\left(A_{1} \land  A_{2} \land  \ldots \land  A_{m} \land \bot\land C_{1} \land  C_{2} \land  \ldots \land  C_{n}\right) = \bot\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE) if m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 36, 39
# 4. {forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 26
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. m in Natural
#     core type: Operation
#     operator: 41
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 41
#     operands: 16
# 13. (A_{1}, A_{2}, ..., A_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 14. {(A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{m} in BOOLEAN), (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{n} in BOOLEAN).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 36, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 39, 19
# 17. (A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}) = FALSE
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{n} in BOOLEAN)
#     core type: Operation
#     operator: 26
#     operands: 22
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}, FALSE)
#     core type: ExprTuple
#     sub-expressions: 23, 31
# 22. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN),(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. A_{1} and  A_{2} and  ... and  A_{m} and FALSEand C_{1} and  C_{2} and  ... and  C_{n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 38
#     end_index: 36
# 25. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 38
#     end_index: 39
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (A_{1}, A_{2}, ..., A_{m}, FALSE,C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 30, 31, 32
# 28. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 33
# 29. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 49
#     body: 34
# 30. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 38
#     end_index: 36
# 31. FALSE
#     core type: Literal
#     sub-expressions:
# 32. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 38
#     end_index: 39
# 33. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 41
#     operands: 40
# 34. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 41
#     operands: 42
# 35. _a -> A_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 43
# 36. m
#     core type: Variable
#     sub-expressions:
# 37. _a -> C_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 44
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. n
#     core type: Variable
#     sub-expressions:
# 40. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 43. A_{_a}
#     core type: IndexedVar
# variable: 46
# index: 49
# 44. C_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 45. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. C
#     core type: Variable
#     sub-expressions:
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 49. _a
#     core type: Variable
#     sub-expressions:
