# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#falsified_and_if_not_left">falsified_and_if_not_left</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import falsified_and_if_not_left

# %%
# check that the built expression is the same as the stored expression
assert falsified_and_if_not_left.expr == stored_expr
assert falsified_and_if_not_left.expr._style_id == stored_expr._style_id
print("Passed sanity check: falsified_and_if_not_left matches stored_expr")
# Out:
# Passed sanity check: falsified_and_if_not_left matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(falsified_and_if_not_left.latex())
# Out:
# \vdash \forall_{A, B~|~\lnot A, B}~\left(\left(A \land B\right) = \bot\right)

# %%
# display the expression information
falsified_and_if_not_left.expr_info()
# Out:
# 0. forall_{A, B | [not](A), B} ((A and B) = FALSE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {(A and B) = FALSE if [not](A) ,  B.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(A and B) = FALSE if [not](A) ,  B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A and B) = FALSE
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. [not](A) and B
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A and B, FALSE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. ([not](A), B)
#    core type: ExprTuple
#    sub-expressions: 11, 16
# 9. A and B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. FALSE
#     core type: Literal
#     sub-expressions:
# 11. [not](A)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. and
#     core type: Literal
# ...
