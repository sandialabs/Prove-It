# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l, m, n
from proveit.logic import InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural))
# Out:
# expr: (l in Natural, m in Natural, n in Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \in \mathbb{N}, m \in \mathbb{N}, n \in \mathbb{N}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. l in Natural
#    core type: Operation
#    operator: 6
#    operands: 4
# 2. m in Natural
#    core type: Operation
#    operator: 6
#    operands: 5
# 3. n in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. (l, Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 11
# 5. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 11
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. Natural
#     core type: Literal
#     sub-expressions:
