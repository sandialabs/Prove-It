# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#some_from_and">some_from_and</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.conjunction import some_from_and

# %%
# check that the built expression is the same as the stored expression
assert some_from_and.expr == stored_expr
assert some_from_and.expr._style_id == stored_expr._style_id
print("Passed sanity check: some_from_and matches stored_expr")
# Out:
# Passed sanity check: some_from_and matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l, m, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C_{1}, C_{2}, \ldots, C_{n}~|~A_{1}, A_{2}, \ldots, A_{l},B_{1}, B_{2}, \ldots, B_{m},C_{1}, C_{2}, \ldots, C_{n}}~\left(B_{1} \land  B_{2} \land  \ldots \land  B_{m}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m}) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 29, 31, 34
# 4. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m}) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 23
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {B_{1} and  B_{2} and  ... and  B_{m} if A_{1} ,  A_{2} ,  ... ,  A_{l}, B_{1} ,  B_{2} ,  ... ,  B_{m}, C_{1} ,  C_{2} ,  ... ,  C_{n}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 10. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {B_{1} and  B_{2} and  ... and  B_{m} if A_{1} ,  A_{2} ,  ... ,  A_{l}, B_{1} ,  B_{2} ,  ... ,  B_{m}, C_{1} ,  C_{2} ,  ... ,  C_{n}.
#     core type: Lambda
#     parameters: 24\n    body: 14
# 11. l in Natural
#     core type: Operation
#     operator: 17
#     operands: 15
# 12. m in Natural
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. n in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. {B_{1} and  B_{2} and  ... and  B_{m} if A_{1} ,  A_{2} ,  ... ,  A_{l}, B_{1} ,  B_{2} ,  ... ,  B_{m}, C_{1} ,  C_{2} ,  ... ,  C_{n}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 29, 21
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 31, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 34, 21
# 19. B_{1} and  B_{2} and  ... and  B_{m}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. A_{1} and  A_{2} and  ... and  A_{l}and B_{1} and  B_{2} and  ... and  B_{m}and C_{1} and  C_{2} and  ... and  C_{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 25. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 33
#     end_index: 29
# 26. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 33
#     end_index: 31
# 27. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 28. _a -> A_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 35
# 29. l
#     core type: Variable
#     sub-expressions:
# 30. _a -> B_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 36
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. _a -> C_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 37
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. A_{_a}
#     core type: IndexedVar
# variable: 38
# index: 42
# 36. B_{_a}
#     core type: IndexedVar
# variable: 39
# index: 42
# 37. C_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 38. A
#     core type: Variable
#     sub-expressions:
# 39. B
#     core type: Variable
#     sub-expressions:
# 40. C
#     core type: Variable
#     sub-expressions:
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. _a
#     core type: Variable
#     sub-expressions:
