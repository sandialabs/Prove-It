# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprTuple, Lambda, l, m, n
from proveit.core_expr_types import A_1_to_l, C_1_to_m, D_1_to_n
from proveit.logic import And, Boolean, Equals, Forall, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([l, m, n], Conditional(Forall(instance_param_or_params = [A_1_to_l, B, C_1_to_m, D_1_to_n], instance_expr = Equals(And(A_1_to_l, B, C_1_to_m, D_1_to_n), And(A_1_to_l, C_1_to_m, B, D_1_to_n)).with_wrapping_at(2), domain = Boolean), And(InSet(l, Natural), InSet(m, Natural), InSet(n, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(l, m, n\right) \mapsto \left\{\forall_{A_{1}, A_{2}, \ldots, A_{l}, B, C_{1}, C_{2}, \ldots, C_{m}, D_{1}, D_{2}, \ldots, D_{n} \in \mathbb{B}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l} \land B\land C_{1} \land  C_{2} \land  \ldots \land  C_{m}\land D_{1} \land  D_{2} \land  \ldots \land  D_{n}\right) =  \\ \left(A_{1} \land  A_{2} \land  \ldots \land  A_{l}\land C_{1} \land  C_{2} \land  \ldots \land  C_{m} \land B\land D_{1} \land  D_{2} \land  \ldots \land  D_{n}\right) \end{array} \end{array}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 44, 46, 49
# 3. {forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n})) if l in Natural ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n} in BOOLEAN} ((A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l in Natural) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (l in Natural, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{m}, D_{1}, D_{2}, ..., D_{n}) -> {(A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#    core type: Lambda
#    parameters: 29\n   body: 13
# 10. l in Natural
#     core type: Operation
#     operator: 52
#     operands: 14
# 11. m in Natural
#     core type: Operation
#     operator: 52
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 52
#     operands: 16
# 13. {(A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n}) if (A_{1} in BOOLEAN) ,  (A_{2} in BOOLEAN) ,  ... ,  (A_{l} in BOOLEAN) ,  B in BOOLEAN, (C_{1} in BOOLEAN) ,  (C_{2} in BOOLEAN) ,  ... ,  (C_{m} in BOOLEAN), (D_{1} in BOOLEAN) ,  (D_{2} in BOOLEAN) ,  ... ,  (D_{n} in BOOLEAN).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 19
# 15. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 19
# 17. (A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}) =  \\ (A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{l} in BOOLEAN) and (B in BOOLEAN)and (C_{1} in BOOLEAN) and  (C_{2} in BOOLEAN) and  ... and  (C_{m} in BOOLEAN)and (D_{1} in BOOLEAN) and  (D_{2} in BOOLEAN) and  ... and  (D_{n} in BOOLEAN)
#     core type: Operation
#     operator: 30
#     operands: 22
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}, A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN), B in BOOLEAN,(C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN),(D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN))
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 23. A_{1} and  A_{2} and  ... and  A_{l} and Band C_{1} and  C_{2} and  ... and  C_{m}and D_{1} and  D_{2} and  ... and  D_{n}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. A_{1} and  A_{2} and  ... and  A_{l}and C_{1} and  C_{2} and  ... and  C_{m} and Band D_{1} and  D_{2} and  ... and  D_{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{l} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 48
#     end_index: 44
# 26. B in BOOLEAN
#     core type: Operation
#     operator: 52
#     operands: 33
# 27. (C_{1} in BOOLEAN), (C_{2} in BOOLEAN), ..., (C_{m} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 48
#     end_index: 46
# 28. (D_{1} in BOOLEAN), (D_{2} in BOOLEAN), ..., (D_{n} in BOOLEAN)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 48
#     end_index: 49
# 29. (A_{1}, A_{2}, ..., A_{l}, B,C_{1}, C_{2}, ..., C_{m},D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 40, 37, 38
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{m}, B,D_{1}, D_{2}, ..., D_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 40, 38
# 32. _a -> (A_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 39
# 33. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 40, 57
# 34. _a -> (C_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 41
# 35. _a -> (D_{_a} in BOOLEAN)
#     core type: Lambda
#     parameter: 62
#     body: 42
# 36. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 48
#     end_index: 44
# 37. C_{1}, C_{2}, ..., C_{m}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 48
#     end_index: 46
# 38. D_{1}, D_{2}, ..., D_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 39. A_{_a} in BOOLEAN
#     core type: Operation
#     operator: 52
#     operands: 50
# 40. B
#     core type: Variable
#     sub-expressions:
# 41. C_{_a} in BOOLEAN
#     core type: Operation
#     operator: 52
#     operands: 51
# 42. D_{_a} in BOOLEAN
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. _a -> A_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 54
# 44. l
#     core type: Variable
#     sub-expressions:
# 45. _a -> C_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 55
# 46. m
#     core type: Variable
#     sub-expressions:
# 47. _a -> D_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 56
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. (A_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 51. (C_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (D_{_a}, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. A_{_a}
#     core type: IndexedVar
# variable: 58
# index: 62
# 55. C_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 56. D_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 57. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 58. A
#     core type: Variable
#     sub-expressions:
# 59. C
#     core type: Variable
#     sub-expressions:
# 60. D
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
