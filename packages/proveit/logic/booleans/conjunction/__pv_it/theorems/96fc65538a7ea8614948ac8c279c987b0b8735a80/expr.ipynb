# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, m
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Equals, Forall, InSet, TRUE
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([A_1_to_m], Equals(And(A_1_to_m), TRUE), condition = A_1_to_m), InSet(m, Natural)))
# Out:
# expr: m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} ((A_{1} and ..A_{_a}.. and A_{m}) = TRUE) if m in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{A_{1}, \ldots, A_{m}~|~A_{1}, \ldots, A_{m}}~\left(\left(A_{1} \land \ldots \land A_{m}\right) = \top\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} ((A_{1} and ..A_{_a}.. and A_{m}) = TRUE) if m in Natural.
#    core type: Lambda
#    parameter: 20
#    body: 1
# 1. {forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} ((A_{1} and ..A_{_a}.. and A_{m}) = TRUE) if m in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A_{1}, ..A_{_a}.., A_{m} | A_{1}, ..A_{_a}.., A_{m}} ((A_{1} and ..A_{_a}.. and A_{m}) = TRUE)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. m in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (A_{1}, ..A_{_a}.., A_{m}) -> {(A_{1} and ..A_{_a}.. and A_{m}) = TRUE if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Lambda
#    parameters: 16\n   body: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 20, 9
# 8. {(A_{1} and ..A_{_a}.. and A_{m}) = TRUE if A_{1} and ..A_{_a}.. and A_{m}.
#    core type: Conditional
#    value: 10
#    condition: 13
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. (A_{1} and ..A_{_a}.. and A_{m}) = TRUE
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A_{1} and ..A_{_a}.. and A_{m}, TRUE)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A_{1} and ..A_{_a}.. and A_{m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. _a -> A_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
