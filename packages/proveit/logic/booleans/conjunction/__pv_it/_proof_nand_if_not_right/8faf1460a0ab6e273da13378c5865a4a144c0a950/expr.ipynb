# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.conjunction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, Lambda
from proveit.logic import And, Boolean, InSet, Not, TRUE

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Conditional(Not(And(TRUE, B)), And(InSet(B, Boolean), Not(B))))
# Out:
# expr: B -> {[not](TRUE and B) if B in BOOLEAN ,  [not](B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# B \mapsto \left\{\lnot \left(\top \land B\right) \textrm{ if } B \in \mathbb{B} ,  \lnot B\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. B -> {[not](TRUE and B) if B in BOOLEAN ,  [not](B).
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. {[not](TRUE and B) if B in BOOLEAN ,  [not](B).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [not](TRUE and B)
#    core type: Operation
#    operator: 13
#    operand: 4
# 3. (B in BOOLEAN) and [not](B)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. TRUE and B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (B in BOOLEAN, [not](B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (TRUE, B)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 8. B in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. [not](B)
#    core type: Operation
#    operator: 13
#    operand: 14
# 10. TRUE
#     core type: Literal
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. BOOLEAN
#     core type: Literal
#     sub-expressions:
