# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">conjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#commutation">commutation</a> theorem
# ========

# %%
import proveit
from proveit.logic import TRUE, And, Equals
from proveit._common_ import A, B
from proveit.logic.booleans.conjunction._axioms_ import and_t_t, and_t_f, and_f_t, and_f_f
from proveit.logic.booleans.conjunction._theorems_ import right_from_and, left_from_and 
theory = proveit.Theory() # the theorem's theory

# %%
# %proving commutation

# %%
# %qed
