# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">conjunction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#nandIfLeftButNotRight">nandIfLeftButNotRight</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A, B
from proveit import defaults
from proveit.logic.booleans.conjunction._theorems_ import trueAndFalseNegated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nandIfLeftButNotRight

# %%
defaults.assumptions = nandIfLeftButNotRight.allConditions()

# %%
AeqT = A.evaluation([A])

# %%
BeqF = B.evaluation()

# %%
trueAndFalseNegated

# %%
AnandF = AeqT.subLeftSideInto(trueAndFalseNegated)

# %%
BeqF.subLeftSideInto(AnandF)

# %%
# %qed
