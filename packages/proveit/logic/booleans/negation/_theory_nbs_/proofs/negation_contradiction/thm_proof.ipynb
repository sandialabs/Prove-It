# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#negation_contradiction">negation_contradiction</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic import Not
from proveit.logic.booleans.negation import not_t, not_false

# %%
# %proving negation_contradiction
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="negation_contradiction">negation_contradiction:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/27dc228341cf78472ea9e06dffca1323233a47f10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/4663d747c867f9591938f21c7445598b859b9dc00/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.negation_contradiction is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A, [not](A)} FALSE
# 1	modus_ponens	2, 3	{A and [not](A)} |- FALSE
# 2	instantiation	4, 5	{A and [not](A)} |- A => FALSE
# 	A : A
# 3	instantiation	6, 8	{A and [not](A)} |- A
# 	A : A, B : [not](A)
# 4	theorem		|- forall_{A | [not](A)} (A => FALSE)
# 	proveit.logic.booleans.negation.unfold_negation
# 5	instantiation	7, 8	{A and [not](A)} |- [not](A)
# 	A : A, B : [not](A)
# 6	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 7	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 8	assumption		{A and [not](A)} |- A and [not](A)
