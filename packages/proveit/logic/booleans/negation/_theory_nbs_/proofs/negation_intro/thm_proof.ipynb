# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#negation_intro">negation_intro</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Not, FALSE

# %%
# %proving negation_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="negation_intro">negation_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6d52edb7489198a819b30fa49358832bc6fbae820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/5cff412dd93dad9d7927a07e0930b1eb4afd787a0/dependencies.ipynb">dependencies</a>)<br>

# %%
AeqF = negation_intro.condition
# Out:
# <strong id="AeqF">AeqF:</strong> <a class="ProveItLink" href="../../../../__pv_it/theorems/df6506bd32d9f7c53b00f834a4c61833f27224860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_false = Not(FALSE).prove()
# Out:
# <strong id="not_false">not_false:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../not_false/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/446a01d9a7ebef169028057d3b157d31652390170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
AeqF.sub_left_side_into(not_false, assumptions=[AeqF])
# Out:
# {A = FALSE} |- [not](A)
# negation_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.negation_intro is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A = FALSE} [not](A)
# 1	instantiation	2, 3	{A = FALSE} |- [not](A)
# 	P(_a) : [not](_a), x : A, y : FALSE
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{A = FALSE} |- [not](FALSE) and (A = FALSE)
# 4	modus_ponens	6, 7	|- (A = FALSE) => ([not](FALSE) and (A = FALSE))
# 5	assumption		{A = FALSE} |- A = FALSE
# 6	instantiation	8	|- [not](FALSE) => ((A = FALSE) => ([not](FALSE) and (A = FALSE)))
# 	A : [not](FALSE), B : A = FALSE
# 7	theorem		|- [not](FALSE)
# 	proveit.logic.booleans.negation.not_false
# 8	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
