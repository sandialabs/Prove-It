# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_f">not_f</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Not, FALSE

# %%
# %proving not_f
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_f">not_f:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b9bd74a578c6b2e794e4ce82c543ff5c79f215890/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/97242ff90190c28bc15131a8c5c8266bc6f0d2db0/dependencies.ipynb">dependencies</a>)<br>
# not_f may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_false = Not(FALSE).prove()
# Out:
# <strong id="not_false">not_false:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../not_false/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/446a01d9a7ebef169028057d3b157d31652390170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_false.evaluation()
# Out:
# |- [not](FALSE) = TRUE
# not_f has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.not_f is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- [not](FALSE) = TRUE
# 	A : [not](FALSE)
# 1	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 2	theorem		|- [not](FALSE)
# 	proveit.logic.booleans.negation.not_false
