# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#fold_negation">fold_negation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving fold_negation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="fold_negation">fold_negation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/96d76ae654d924d04063f8576fc5655f9618a4480/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/aceae425932f5c69fdbc7eed8ab4b779229b210f0/dependencies.ipynb">dependencies</a>)<br>
# fold_negation may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = fold_negation.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_negation/ac1b8913abefe0dcb0684707d3ea05499b42621f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_A = fold_negation.instance_expr
# Out:
# <strong id="not_A">not_A:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_A_def = not_A.definition()
# Out:
# <strong id="not_A_def">not_A_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_negation/9297731e62f686e4eab0ecc1c1a45e31f480d9eb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/01622bb85bcc551946b23d36eddf1b6b39cd82ac0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_A_def_rev = not_A_def.derive_reversed()
# Out:
# <strong id="not_A_def_rev">not_A_def_rev:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_fold_negation/d3fc7e969253ac03315524946d4f5ff580adc4ad0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_fold_negation/be5c2098df25871d2ff59526095d0a81fdba95220/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_A_def_rev.sub_right_side_into(not_A_def.rhs)
# Out:
# {A => FALSE} |- [not](A)

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.fold_negation is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A => FALSE} [not](A)
# 1	modus_ponens	2, 3	{A => FALSE} |- [not](A)
# 2	modus_ponens	4, 5	{A => FALSE} |- ((A => FALSE) = [not](A)) => [not](A)
# 3	instantiation	6, 7	|- (A => FALSE) = [not](A)
# 	x : [not](A), y : A => FALSE
# 4	instantiation	8	|- (A => FALSE) => (((A => FALSE) = [not](A)) => [not](A))
# 	P(_a) : _a, x : A => FALSE, y : [not](A)
# 5	assumption		{A => FALSE} |- A => FALSE
# 6	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 7	instantiation	9	|- [not](A) = (A => FALSE)
# 	A : A
# 8	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 9	theorem		|- forall_{A} ([not](A) = (A => FALSE))
# 	proveit.logic.booleans.negation.not_def_quantified
