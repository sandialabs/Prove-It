# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_t">not_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Not, TRUE

# %%
# %proving not_t
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_t">not_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fa3556271013b3b54b7b75b637f6a18a1772897d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/a3adac7ef26689d6f5d66bbc3e23a610285c113d0/dependencies.ipynb">dependencies</a>)<br>

# %%
Not(TRUE).evaluation()
# Out:
# |- [not](TRUE) = FALSE
# not_t has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.not_t is now proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- [not](TRUE) = FALSE
# 	A : TRUE
# 1	axiom		|- forall_{A | A} ([not](A) = FALSE)
# 	proveit.logic.booleans.eq_false_intro
# 2	theorem		|- TRUE
# 	proveit.logic.booleans.true_truth
