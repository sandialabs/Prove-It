# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#double_negation_equiv">double_negation_equiv</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving double_negation_equiv
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="double_negation_equiv">double_negation_equiv:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9cc2495953c167a4972aea446b8f8744b9387cc10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/bce9b9843b683e862f71580bd81275031ab806200/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# ***Automated proof, folding the forall over the Boolean set.
# This is a shorter proof than via $\lnot (\lnot A) \Leftrightarrow A$.***

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.double_negation_equiv has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- forall_{A in BOOLEAN} ([not]([not](A)) = A)
# 	P(A) : [not]([not](A)) = A, A : A
# 1	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 2	instantiation	4, 5	|- [not]([not](TRUE)) = TRUE
# 	A : [not]([not](TRUE))
# 3	instantiation	6, 7, 8	|- [not]([not](FALSE)) = FALSE
# 	x : [not]([not](FALSE)), y : [not](TRUE), z : FALSE
# 4	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 5	instantiation	9, 10	|- [not]([not](TRUE))
# 	A : TRUE
# 6	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 7	instantiation	11, 12	|- [not]([not](FALSE)) = [not](TRUE)
# 	f(_a) : [not](_a), x : [not](FALSE), y : TRUE
# 8	axiom		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 9	theorem		|- forall_{A | A} [not]([not](A))
# 	proveit.logic.booleans.negation.double_negation_intro
# 10	axiom		|- TRUE
# 	proveit.logic.booleans.true_axiom
# 11	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 12	axiom		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
