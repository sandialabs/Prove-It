# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#double_negation_intro">double_negation_intro</a> theorem
# ========

# %%
import proveit
from proveit import A
from proveit.logic import Not
theory = proveit.Theory() # the theorem's theory

# %%
# %proving double_negation_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="double_negation_intro">double_negation_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0b22d68afd7bfc707f054cfbe8b4e2370c2f148f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2a673c5806b436fc7c11c310aa3ce35e5d96fe2e0/dependencies.ipynb">dependencies</a>)<br>
# double_negation_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_a_eq_F = Not(A).evaluation(assumptions=[A])
# Out:
# <strong id="not_a_eq_F">not_a_eq_F:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_double_negation_intro/97d04f87c35a8b2a4efb69c0dc9cd230719b07920/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0538e70e2732802d141dcc88dd503157a23879040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_a_eq_F.derive_via_boolean_equality()
# Out:
# {A} |- [not]([not](A))

# %%
# %qed # proven via automation
# Out:
# proveit.logic.booleans.negation.double_negation_intro has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A} [not]([not](A))
# 1	instantiation	2, 3	{A} |- [not]([not](A))
# 	A : [not](A)
# 2	conjecture		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 3	instantiation	4, 5, 6	{A} |- [not](A) = FALSE
# 	x : [not](A), y : [not](TRUE), z : FALSE
# 4	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	instantiation	7, 8	{A} |- [not](A) = [not](TRUE)
# 	f(_a) : [not](_a), x : A, y : TRUE
# 6	axiom		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 7	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 8	instantiation	9, 10	{A} |- A = TRUE
# 	A : A
# 9	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 10	assumption		{A} |- A
