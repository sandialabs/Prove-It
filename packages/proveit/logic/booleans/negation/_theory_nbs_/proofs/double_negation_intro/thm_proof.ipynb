# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#double_negation_intro">double_negation_intro</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic import Not

# %%
# %proving double_negation_intro
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="double_negation_intro">double_negation_intro:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0b22d68afd7bfc707f054cfbe8b4e2370c2f148f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/b800b915b96c7aee8ddcfe938b579c046486ef250/dependencies.ipynb">dependencies</a>)<br>
# double_negation_intro may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_a_eq_F = Not(A).evaluation(assumptions=[A])
# Out:
# <strong id="not_a_eq_F">not_a_eq_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../__pv_it/common/09585084922504426caf1db2ff588a23a0932a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_double_negation_intro/d9d20e4e241503e3eafef5bbe5dbd363fda4879b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_double_negation_intro/025926f83dbd5c2f04b35084d899ac1514a39d270/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_a_eq_F.derive_via_boolean_equality()
# Out:
# {A} |- [not]([not](A))

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.double_negation_intro is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | A} [not]([not](A))
# 1	instantiation	2, 3	{A} |- [not]([not](A))
# 	A : [not](A)
# 2	theorem		|- forall_{A | A = FALSE} [not](A)
# 	proveit.logic.booleans.negation.negation_intro
# 3	instantiation	4, 5	{A} |- [not](A) = FALSE
# 	x : [not](A), y : [not](TRUE), z : FALSE
# 4	theorem		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 5	modus_ponens	6, 7	{A} |- ([not](A) = [not](TRUE)) and ([not](TRUE) = FALSE)
# 6	modus_ponens	8, 9	{A} |- ([not](TRUE) = FALSE) => (([not](A) = [not](TRUE)) and ([not](TRUE) = FALSE))
# 7	theorem		|- [not](TRUE) = FALSE
# 	proveit.logic.booleans.negation.not_t
# 8	instantiation	10	|- ([not](A) = [not](TRUE)) => (([not](TRUE) = FALSE) => (([not](A) = [not](TRUE)) and ([not](TRUE) = FALSE)))
# 	A : [not](A) = [not](TRUE), B : [not](TRUE) = FALSE
# 9	instantiation	11, 12	{A} |- [not](A) = [not](TRUE)
# 	f(_a) : [not](_a), x : A, y : TRUE
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 12	instantiation	13, 14	{A} |- A = TRUE
# 	A : A
# 13	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 14	assumption		{A} |- A
