# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#unfold_negation">unfold_negation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving unfold_negation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="unfold_negation">unfold_negation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1db0d0b3f340704773fcca4c5ded52617ff934440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/8a0792504b75cdc05ca484eeb5d518e9f25c89970/dependencies.ipynb">dependencies</a>)<br>
# unfold_negation may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_A = unfold_negation.condition
# Out:
# <strong id="not_A">not_A:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2d607b2877f5542a9baeaa9f0a7ccbda21f95e660/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [not_A]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_negation/0ed77e7fb87a65a73bcffed95231e285451fd5070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_A_def = not_A.definition()
# Out:
# <strong id="not_A_def">not_A_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_negation/e09d8e8a273b25ac1ad2cbad90cac354017295e50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/01622bb85bcc551946b23d36eddf1b6b39cd82ac0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_A_def.sub_right_side_into(not_A_def.lhs)
# Out:
# {[not](A)} |- A => FALSE

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.unfold_negation is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A | [not](A)} (A => FALSE)
# 1	modus_ponens	2, 3	{[not](A)} |- A => FALSE
# 2	modus_ponens	4, 5	{[not](A)} |- ([not](A) = (A => FALSE)) => (A => FALSE)
# 3	instantiation	6	|- [not](A) = (A => FALSE)
# 	A : A
# 4	instantiation	7	|- [not](A) => (([not](A) = (A => FALSE)) => (A => FALSE))
# 	P(_a) : _a, x : [not](A), y : A => FALSE
# 5	assumption		{[not](A)} |- [not](A)
# 6	theorem		|- forall_{A} ([not](A) = (A => FALSE))
# 	proveit.logic.booleans.negation.not_def_quantified
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
