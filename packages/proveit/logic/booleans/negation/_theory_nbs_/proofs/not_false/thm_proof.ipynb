# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_false">not_false</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Implies, Not, FALSE
from proveit.logic.booleans.negation import not_def

# %%
# %proving not_false
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_false">not_false:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/446a01d9a7ebef169028057d3b157d31652390170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3a2711492151a14d480dd1a75263ce0c433fa3570/dependencies.ipynb">dependencies</a>)<br>
# not_false may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_def
# Out:
# |- [not] = [A -> (A => FALSE)]

# %%
not_false_def = not_def.substitution(Not(FALSE), auto_simplify=False)
# Out:
# <strong id="not_false_def">not_false_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_false/c2e4743c7aadee6e91e71a7f938e6e79242437050/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_false/681050b1e9f6ca220603d2d783757a9e3d95be5f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_false_def_rev = not_false_def.derive_reversed()
# Out:
# <strong id="not_false_def_rev">not_false_def_rev:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_not_false/b326e5797f5311c60097c0b585fb82e885209e030/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_not_false/7289fd60b75b719d9266057131e36ccae7f7e3160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
false_implies_false = Implies(FALSE, FALSE).prove()
# Out:
# <strong id="false_implies_false">false_implies_false:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../../implication/_theory_nbs_/proofs/false_implies_false/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../implication/__pv_it/theorems/cfa5600f601c2810e3b5108de4803cae722878400/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_false_def_rev.sub_right_side_into(false_implies_false)
# Out:
# |- [not](FALSE)
# not_false has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.not_false is now proven.
# 	step type	requirements	statement
# 0	modus_ponens	1, 2	|- [not](FALSE)
# 1	modus_ponens	3, 4	|- ((FALSE => FALSE) = [not](FALSE)) => [not](FALSE)
# 2	instantiation	5, 6	|- (FALSE => FALSE) = [not](FALSE)
# 	x : [not](FALSE), y : FALSE => FALSE
# 3	instantiation	7	|- (FALSE => FALSE) => (((FALSE => FALSE) = [not](FALSE)) => [not](FALSE))
# 	P(_a) : _a, x : FALSE => FALSE, y : [not](FALSE)
# 4	theorem		|- FALSE => FALSE
# 	proveit.logic.booleans.implication.false_implies_false
# 5	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 6	instantiation	8, 9	|- [not](FALSE) = (FALSE => FALSE)
# 	f(_a) : _a(FALSE), x : not, y(A) : A => FALSE
# 7	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 8	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 9	basic_definition		|- [not] = [A -> (A => FALSE)]
# 	proveit.logic.booleans.negation.not_def
