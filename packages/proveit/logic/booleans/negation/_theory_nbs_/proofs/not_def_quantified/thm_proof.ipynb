# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">negation</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_def_quantified">not_def_quantified</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import A
from proveit.logic.booleans.negation import Not, not_def

# %%
# %proving not_def_quantified
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_def_quantified">not_def_quantified:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d63eded85be8c50028f487b714d6b50c1b20fe4e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/245a69456365c10dc9f8d38f9f382cefe58588c90/dependencies.ipynb">dependencies</a>)<br>

# %%
not_def
# Out:
# |- [not] = [A -> (A => FALSE)]

# %%
not_def.substitution(Not(A), auto_simplify=False)
# Out:
# |- [not](A) = (A => FALSE)
# not_def_quantified may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.negation.not_def_quantified is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A} ([not](A) = (A => FALSE))
# 1	instantiation	2, 3	|- [not](A) = (A => FALSE)
# 	f(_a) : _a(A), x : not, y(A) : A => FALSE
# 2	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 3	basic_definition		|- [not] = [A -> (A => FALSE)]
# 	proveit.logic.booleans.negation.not_def
