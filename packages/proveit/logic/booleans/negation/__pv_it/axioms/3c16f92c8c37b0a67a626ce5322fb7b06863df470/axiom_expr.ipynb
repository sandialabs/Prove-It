# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#not_t">not_t</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.negation import not_t

# %%
# check that the built expression is the same as the stored expression
assert not_t.expr == stored_expr
assert not_t.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_t matches stored_expr")
# Out:
# Passed sanity check: not_t matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_t.latex())
# Out:
# \vdash (\lnot \top) = \bot

# %%
# display the expression information
not_t.expr_info()
# Out:
# 0. [not](TRUE) = FALSE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ([not](TRUE), FALSE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [not](TRUE)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. FALSE
#    core type: Literal
#    sub-expressions:
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. TRUE
#    core type: Literal
#    sub-expressions:
