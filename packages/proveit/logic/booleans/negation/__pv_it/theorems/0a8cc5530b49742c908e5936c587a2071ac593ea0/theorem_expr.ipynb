# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#double_negation_equiv">double_negation_equiv</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.negation import double_negation_equiv

# %%
# check that the built expression is the same as the stored expression
assert double_negation_equiv.expr == stored_expr
assert double_negation_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: double_negation_equiv matches stored_expr")
# Out:
# Passed sanity check: double_negation_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(double_negation_equiv.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}}~\left((\lnot (\lnot A)) = A\right)

# %%
# display the expression information
double_negation_equiv.expr_info()
# Out:
# 0. forall_{A in BOOLEAN} ([not]([not](A)) = A)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> {[not]([not](A)) = A if A in BOOLEAN.
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {[not]([not](A)) = A if A in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [not]([not](A)) = A
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ([not]([not](A)), A)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. [not]([not](A))
#     core type: Operation
#     operator: 13
#     operand: 12
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 12. [not](A)
#     core type: Operation
# ...
