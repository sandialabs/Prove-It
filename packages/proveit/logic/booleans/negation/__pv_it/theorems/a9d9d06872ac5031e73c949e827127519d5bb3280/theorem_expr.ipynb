# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#double_negation_elim_lemma">double_negation_elim_lemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.negation import double_negation_elim_lemma

# %%
# check that the built expression is the same as the stored expression
assert double_negation_elim_lemma.expr == stored_expr
assert double_negation_elim_lemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: double_negation_elim_lemma matches stored_expr")
# Out:
# Passed sanity check: double_negation_elim_lemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(double_negation_elim_lemma.latex())
# Out:
# \vdash \forall_{A \in \mathbb{B}~|~\lnot (\lnot A)}~A

# %%
# display the expression information
double_negation_elim_lemma.expr_info()
# Out:
# 0. forall_{A in BOOLEAN | [not]([not](A))} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> {A if A in BOOLEAN ,  [not]([not](A)).
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {A if A in BOOLEAN ,  [not]([not](A)).
#    core type: Conditional
#    value: 14
#    condition: 4
# 4. (A in BOOLEAN) and [not]([not](A))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEAN, [not]([not](A)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A in BOOLEAN
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not]([not](A))
#    core type: Operation
#    operator: 13
#    operand: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 14, 12
# 11. [not](A)
#     core type: Operation
#     operator: 13
#     operand: 14
# ...
