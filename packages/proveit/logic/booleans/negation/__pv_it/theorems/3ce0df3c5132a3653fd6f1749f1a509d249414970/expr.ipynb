# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A
from proveit.logic import Boolean, Forall, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Forall([A], InSet(Not(A), Boolean), domains = [Boolean])
# Out:
# expr: forall_{A in BOOLEAN} ([not](A) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A \in \mathbb{B}}~\left((\lnot A) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A in BOOLEAN} ([not](A) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> {[not](A) in BOOLEAN if A in BOOLEAN.
#    core type: Lambda
#    parameter: 12
#    body: 3
# 3. {[not](A) in BOOLEAN if A in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [not](A) in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. A in BOOLEAN
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ([not](A), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 12, 10
# 9. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
