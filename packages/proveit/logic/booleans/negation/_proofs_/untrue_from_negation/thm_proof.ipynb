# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theory_.ipynb">negation</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#untrue_from_negation">untrue_from_negation</a> theorem
# ========

# %%
import proveit
from proveit import A
from proveit.logic import Not
from proveit.logic.booleans  import false_not_true
theory = proveit.Theory() # the theorem's theory

# %%
# %proving untrue_from_negation

# %%
false_not_true

# %%
A_eq_F = Not(A).prove([Not(A)]).equate_negated_to_false()

# %%
A_untrue = A_eq_F.sub_left_side_into(false_not_true)

# %%
# %qed
