# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#not_equals_false">not_equals_false</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans import not_equals_false

# %%
# check that the built expression is the same as the stored expression
assert not_equals_false.expr == stored_expr
assert not_equals_false.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_equals_false matches stored_expr")
# Out:
# Passed sanity check: not_equals_false matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_equals_false.latex())
# Out:
# \vdash \forall_{A~|~A}~\left(A \neq \bot\right)

# %%
# display the expression information
not_equals_false.expr_info()
# Out:
# 0. forall_{A | A} (A != FALSE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> {A != FALSE if A.
#    core type: Lambda
#    parameter: 7
#    body: 3
# 3. {A != FALSE if A.
#    core type: Conditional
#    value: 4
#    condition: 7
# 4. A != FALSE
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (A, FALSE)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. FALSE
#    core type: Literal
#    sub-expressions:
