# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprTuple, PofA
from proveit.logic import And, Boolean, Equals, FALSE, Forall, PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(Equals(PofTrue, FALSE), Equals(PofFalse, FALSE)), Equals(Forall([A], PofA, domains = [Boolean]), FALSE))
# Out:
# expr: ((P(TRUE) = FALSE) and (P(FALSE) = FALSE), [forall_{A in BOOLEAN} P(A)] = FALSE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P(\top) = \bot\right) \land \left(P(\bot) = \bot\right), \left[\forall_{A \in \mathbb{B}}~P(A)\right] = \bot\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE), [forall_{A in BOOLEAN} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (P(TRUE) = FALSE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. [forall_{A in BOOLEAN} P(A)] = FALSE
#    core type: Operation
#    operator: 10
#    operands: 5
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(TRUE) = FALSE, P(FALSE) = FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (forall_{A in BOOLEAN} P(A), FALSE)
#    core type: ExprTuple
#    sub-expressions: 8, 18
# 6. P(TRUE) = FALSE
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. P(FALSE) = FALSE
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. forall_{A in BOOLEAN} P(A)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. (P(TRUE), FALSE)
#    core type: ExprTuple
#    sub-expressions: 14, 18
# 10. =
#     core type: Literal
#     sub-expressions:
# ...
