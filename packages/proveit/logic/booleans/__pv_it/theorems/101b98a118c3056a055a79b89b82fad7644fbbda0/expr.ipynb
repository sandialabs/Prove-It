# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, P, PofA
from proveit.logic import And, Boolean, Equals, FALSE, Forall, Implies, PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Forall([P], Implies(And(Equals(PofTrue, FALSE), Equals(PofFalse, FALSE)), Equals(Forall([A], PofA, domains = [Boolean]), FALSE)))
# Out:
# expr: forall_{P} (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEAN} P(A)] = FALSE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P}~\left(\left(\left(P(\top) = \bot\right) \land \left(P(\bot) = \bot\right)\right) \Rightarrow \left(\left[\forall_{A \in \mathbb{B}}~P(A)\right] = \bot\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P} (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEAN} P(A)] = FALSE))
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. P -> (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEAN} P(A)] = FALSE))
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEAN} P(A)] = FALSE)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE), [forall_{A in BOOLEAN} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (P(TRUE) = FALSE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. [forall_{A in BOOLEAN} P(A)] = FALSE
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(TRUE) = FALSE, P(FALSE) = FALSE)
#    core type: ExprTuple
# ...
