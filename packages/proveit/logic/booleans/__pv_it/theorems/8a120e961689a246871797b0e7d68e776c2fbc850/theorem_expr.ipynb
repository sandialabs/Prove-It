# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_not_false">true_not_false</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.NotEquals.html">NotEquals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans import true_not_false

# %%
# check that the built expression is the same as the stored expression
assert true_not_false.expr == stored_expr
assert true_not_false.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_not_false matches stored_expr")
# Out:
# Passed sanity check: true_not_false matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(true_not_false.latex())
# Out:
# \vdash \top \neq \bot

# %%
# display the expression information
true_not_false.expr_info()
# Out:
# 0. TRUE != FALSE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. !=
#    core type: Literal
#    sub-expressions:
# 2. (TRUE, FALSE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. TRUE
#    core type: Literal
#    sub-expressions:
# 4. FALSE
#    core type: Literal
#    sub-expressions:
