# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, P, PofA
from proveit.logic import And, Boolean, Forall, Implies, PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Forall([P], Implies(Forall([A], PofA, domains = [Boolean]), And(PofTrue, PofFalse)))
# Out:
# expr: forall_{P} ([forall_{A in BOOLEAN} P(A)] => (P(TRUE) and P(FALSE)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P}~\left(\left[\forall_{A \in \mathbb{B}}~P(A)\right] \Rightarrow \left(P(\top) \land P(\bot)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P} ([forall_{A in BOOLEAN} P(A)] => (P(TRUE) and P(FALSE)))
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. P -> ([forall_{A in BOOLEAN} P(A)] => (P(TRUE) and P(FALSE)))
#    core type: Lambda
#    parameter: 18
#    body: 2
# 2. [forall_{A in BOOLEAN} P(A)] => (P(TRUE) and P(FALSE))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{A in BOOLEAN} P(A), P(TRUE) and P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{A in BOOLEAN} P(A)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. P(TRUE) and P(FALSE)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. A -> {P(A) if A in BOOLEAN.
#    core type: Lambda
#    parameter: 21
#    body: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (P(TRUE), P(FALSE))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. {P(A) if A in BOOLEAN.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. P(TRUE)
#     core type: Operation
#     operator: 18
#     operand: 16
# 13. P(FALSE)
#     core type: Operation
#     operator: 18
#     operand: 17
# 14. P(A)
#     core type: Operation
#     operator: 18
#     operand: 21
# 15. A in BOOLEAN
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. TRUE
#     core type: Literal
#     sub-expressions:
# 17. FALSE
#     core type: Literal
#     sub-expressions:
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (A, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. BOOLEAN
#     core type: Literal
#     sub-expressions:
