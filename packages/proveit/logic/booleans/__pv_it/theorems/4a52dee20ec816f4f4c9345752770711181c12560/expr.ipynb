# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional
from proveit.logic import Boolean, Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(A, Boolean), Or(Equals(A, TRUE), Equals(A, FALSE)))
# Out:
# expr: {A in BOOLEAN if (A = TRUE) or (A = FALSE).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \in \mathbb{B} \textrm{ if } \left(A = \top\right) \lor \left(A = \bot\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A in BOOLEAN if (A = TRUE) or (A = FALSE).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (A, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A = TRUE, A = FALSE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. A = TRUE
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. A = FALSE
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A, TRUE)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A, FALSE)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. TRUE
#     core type: Literal
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. FALSE
#     core type: Literal
#     sub-expressions:
