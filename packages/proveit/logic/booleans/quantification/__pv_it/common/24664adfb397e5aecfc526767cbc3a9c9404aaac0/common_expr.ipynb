# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#general_exists_notPx">general_exists_notPx</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification import general_exists_notPx

# %%
# check that the built expression is the same as the stored expression
assert general_exists_notPx == stored_expr
assert general_exists_notPx._style_id == stored_expr._style_id
print("Passed sanity check: general_exists_notPx matches stored_expr")
# Out:
# Passed sanity check: general_exists_notPx matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(general_exists_notPx.latex())
# Out:
# \exists_{x_{1}, \ldots, x_{n}}~(\lnot P(x_{1}, \ldots, x_{n}))

# %%
# display the expression information
general_exists_notPx.expr_info()
# Out:
# 0. exists_{x_{1}, ..x_{_a}.., x_{n}} [not](P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (x_{1}, ..x_{_a}.., x_{n}) -> [not](P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. [not](P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. _a -> x_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. n
#     core type: Variable
#     sub-expressions:
# ...
