# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.core_expr_types import P__x_1_to_n, x_1_to_n
from proveit.logic import Not

# %%
# build up the expression from sub-expressions
expr = Lambda([x_1_to_n], Not(P__x_1_to_n))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{n}) -> [not](P(x_{1}, ..x_{_a}.., x_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{n}\right) \mapsto (\lnot P(x_{1}, \ldots, x_{n}))

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{n}) -> [not](P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Lambda
#    parameters: 5\n   body: 1
# 1. [not](P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. not
#    core type: Literal
#    sub-expressions:
# 3. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. P
#    core type: Variable
#    sub-expressions:
# 5. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 6
# 6. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 7. _a -> x_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. x_{_a}
#     core type: IndexedVar
# variable: 11
# index: 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. _a
#     core type: Variable
#     sub-expressions:
