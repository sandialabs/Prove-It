# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprRange, ExprTuple, IndexedVar, Variable, n, y
from proveit.logic import InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(y, sub_expr1), B), one, n))
# Out:
# expr: (y_{1} in B, ..y_{_a} in B.., y_{n} in B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(y_{1} \in B, \ldots, y_{n} \in B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (y_{1} in B, ..y_{_a} in B.., y_{n} in B)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (y_{1} in B), ..(y_{_a} in B).., (y_{n} in B)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _a -> (y_{_a} in B)
#    core type: Lambda
#    parameter: 11
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. y_{_a} in B
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (y_{_a}, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. y_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
