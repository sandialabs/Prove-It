# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, ExprTuple, IndexedVar, Variable, n, x
from proveit.logic import InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(x, sub_expr1), A), one, n))
# Out:
# expr: (x_{1} in A, ..x_{_a} in A.., x_{n} in A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} \in A, \ldots, x_{n} \in A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} in A, ..x_{_a} in A.., x_{n} in A)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1} in A), ..(x_{_a} in A).., (x_{n} in A)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _a -> (x_{_a} in A)
#    core type: Lambda
#    parameter: 11
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. x_{_a} in A
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x_{_a}, A)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
