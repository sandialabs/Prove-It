# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import P__x_1_to_m_y_1_to_n, R__x_1_to_m_y_1_to_n

# %%
# build up the expression from sub-expressions
expr = Conditional(P__x_1_to_m_y_1_to_n, R__x_1_to_m_y_1_to_n)
# Out:
# expr: {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}) \textrm{ if } R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 3
#    operands: 5
# 2. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. R
#    core type: Variable
#    sub-expressions:
# 5. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x_{1}, ..x_{_a}.., x_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 9
# 7. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 8. _a -> x_{_a}
#    core type: Lambda
#    parameter: 17
#    body: 13
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. _a -> y_{_a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. x_{_a}
#     core type: IndexedVar
# variable: 15
# index: 17
# 14. y_{_a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
