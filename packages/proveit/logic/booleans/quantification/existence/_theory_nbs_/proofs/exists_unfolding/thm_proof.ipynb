# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">existence</a>.<a class="ProveItLink" href="../../theorems.ipynb#exists_unfolding">exists_unfolding</a> theorem
# ========

# %%
import proveit
from proveit import defaults
theory = proveit.Theory() # the theorem's theory

# %%
# %proving exists_unfolding
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="exists_unfolding">exists_unfolding:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3057a321b6f6907ed14aa4b65641e8d6883b5ece0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/de0182ee537f7b0e8d0a937d8a60db55daa35a650/dependencies.ipynb">dependencies</a>)<br>

# %%
antecedent = exists_unfolding.instance_expr.instance_expr.antecedent
# Out:
# <strong id="antecedent">antecedent:</strong> <a class="ProveItLink" href="../../../../__pv_it/common/b1921585ebb165238ef2d3470ef01b6c7f2cb8190/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [exists_unfolding.condition, antecedent]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_exists_unfolding/c016d09cac4ea8ef220b94bd0480778a438ec31d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
definition = antecedent.definition()
# Out:
# <strong id="definition">definition:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/c3c0a0522590e024022c8052cabac138164190560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_exists_unfolding/a78583b240a7de2557dff10e9aafc8ae6b77adea0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_exists_unfolding/28ad71d670a40f1b1b1224a63414190b199272cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
definition.derive_right_via_equality().as_implication(antecedent)
# Out:
# {n in NaturalPos} |- [exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] => [not](forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE))
# exists_unfolding may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.quantification.existence.exists_unfolding has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)))]
# 1	deduction	2	{n in NaturalPos} |- [exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] => [not](forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE))
# 2	instantiation	3, 4, 5	{exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), n in NaturalPos} |- [not](forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE))
# 	P : exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), Q : [not](forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE))
# 3	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 4	assumption		{exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})} |- exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
# 5	instantiation	6, 7	{n in NaturalPos} |- [exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE))
# 	n : n
# 6	axiom		|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)))]
# 	proveit.logic.booleans.quantification.existence.exists_def
# 7	assumption		{n in NaturalPos} |- n in NaturalPos
