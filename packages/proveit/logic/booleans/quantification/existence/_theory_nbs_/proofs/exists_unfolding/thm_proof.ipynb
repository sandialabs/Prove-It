# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">existence</a>.<a class="ProveItLink" href="../../theorems.ipynb#exists_unfolding">exists_unfolding</a> theorem
# ========

# %%
import proveit
from proveit import defaults
theory = proveit.Theory() # the theorem's theory

# %%
# %proving exists_unfolding
# Out:
# exists_unfolding: forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))]

# %%
antecedent = exists_unfolding.instance_expr.instance_expr.antecedent
# Out:
# antecedent: exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})

# %%
defaults.assumptions = [exists_unfolding.condition, antecedent]
# Out:
# defaults.assumptions: (n in NaturalPos, exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}))

# %%
definition = antecedent.definition()
# Out:
# definition: {n in NaturalPos} |- [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] = [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))

# %%
definition.derive_right_via_equality().as_implication(antecedent)
# Out:
# {n in NaturalPos} |- [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] => [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))]
# 1	deduction	2	{n in NaturalPos} |- [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 2	instantiation	3, 4, 5	{exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), n in NaturalPos} |- [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 	P : exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), Q : [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 3	conjecture		|- forall_{P, Q | P, P = Q} Q
# 4	assumption		{exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})} |- exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
# 5	instantiation	6, 13, 7, 8	{n in NaturalPos} |- [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] = [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
# 	n : n, P(x_{1}, ..x_{_a}.., x_{n}) : P(x_{1}, ..x_{_a}.., x_{n}), Q(x_{1}, ..x_{_a}.., x_{n}) : Q(x_{1}, ..x_{_a}.., x_{n})
# 6	axiom		|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))]
# 	proveit.logic.booleans.quantification.existence.exists_def
# 7	instantiation	9, 10	{n in NaturalPos} |- |(x_{1}, ..x_{a}.., x_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : x_{_a}
# 8	instantiation	9, 10	{n in NaturalPos} |- |(y_{1}, ..y_{a}.., y_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : y_{_a}
# 9	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 10	instantiation	11, 12, 13	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 11	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 12	conjecture		|- NaturalPos proper_subset Natural
# 13	assumption		{n in NaturalPos} |- n in NaturalPos
