# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">existence</a>.<a class="ProveItLink" href="../../theorems.ipynb#skolem_elim_lemma">skolem_elim_lemma</a> theorem
# ========

# %%
import proveit
from proveit import alpha
from proveit.core_expr_types import x_1_to_n, Q__x_1_to_n, P__x_1_to_n
from proveit.logic import Not, Equals, TRUE, NotEquals
from proveit import defaults
theory = proveit.Theory() # the theorem's theory

# %%
# %proving skolem_elim_lemma
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="skolem_elim_lemma">skolem_elim_lemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ddee0e527ffaa944d5a3e6546d2ca6a3da31ec620/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3cab4cb7f5a3b941b257cbb30da0b40b106c9e7b0/dependencies.ipynb">dependencies</a>)<br>

# %%
antecedent = skolem_elim_lemma.instance_expr.instance_expr.antecedent
# Out:
# <strong id="antecedent">antecedent:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
main_assumptions = (*skolem_elim_lemma.conditions.entries, antecedent)
# Out:
# <strong id="main_assumptions">main_assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/1fa2a24bbb6e696b92c59560cf6e3b3f60b90d0c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ### This is be a proof by contradiction

# %%
defaults.assumptions = (*main_assumptions, Not(alpha))
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/182ede2be98414a47705153358937d06d128b2560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
existential, universal = antecedent.derive_left(), antecedent.derive_right()
# Out:
# <strong id="existential">existential:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/dcc41f1e05e2de7c7555c7428fb38a76bf56efbf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../__pv_it/common/98af65715eb6c41dec97828dea8ccb9a7b951d070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# <strong id="universal">universal:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/4ef9c531d1dbc86f3704bad0e5f0ef676e1b77ab0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/b258f815bda0f7297efc89634de81c1e83416c8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
unfolded_existential = existential.unfold()
# Out:
# <strong id="unfolded_existential">unfolded_existential:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/132c57ec1224a4beaf274a23bd799047020206590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/3f72646a24c184e40daf400fabbdec8e7bc01d3b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/9da4e14dd203a7df17d36f76382461ddc1e97fe70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
universal
# Out:
# {[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]} |- forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)

# %%
alpha_under_assumptions = universal.instantiate(assumptions=[Q__x_1_to_n]).derive_consequent(
    assumptions=[Equals(P__x_1_to_n, TRUE)])
# Out:
# <strong id="alpha_under_assumptions">alpha_under_assumptions:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/9831c3274fdbb7bc58d371eeea2ac8f0b00cc9670/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../../core_expr_types/__pv_it/common/bf2f905b72ae7caedef50b78edeba9c03ac6d7cd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/ca7276f7a14b3ca7a8f4dfaec46f9505630adb430/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../../__pv_it/common/9705ebf23debd1198c43ec3d0c30ebe152d069440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction = Not(alpha).derive_contradiction(
    assumptions=[*defaults.assumptions, Q__x_1_to_n, Equals(P__x_1_to_n, TRUE)])
# Out:
# <strong id="contradiction">contradiction:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/9831c3274fdbb7bc58d371eeea2ac8f0b00cc9670/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../../core_expr_types/__pv_it/common/bf2f905b72ae7caedef50b78edeba9c03ac6d7cd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/51cf343ec2606ba8eadf6f296a9aee90e0fe4a820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/aeb29b8efe21eb289916631e2d13f88a618993850/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction.deny_assumption(Equals(P__x_1_to_n, TRUE))
# Out:
# {[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n}), [not](alpha)} |- [not](P(x_{1}, x_{2}, ..., x_{n}) = TRUE)

# %%
P_neq_T = NotEquals(P__x_1_to_n, TRUE).prove(assumptions=[*defaults.assumptions, Q__x_1_to_n])
# Out:
# <strong id="P_neq_T">P_neq_T:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/3bbfcaf0362277b94ee8d029389dec567eab27030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../../core_expr_types/__pv_it/common/bf2f905b72ae7caedef50b78edeba9c03ac6d7cd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/51cf343ec2606ba8eadf6f296a9aee90e0fe4a820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/dac3ee7ede31f7f81b4da2257f1c9dd48e1389b90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_skolem_elim_lemma/4dd0bddd8f01a44ddcdabe9923556aa9dcd3592a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
P_neq_T.generalize(x_1_to_n, conditions=[Q__x_1_to_n])
# Out:
# {[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], [not](alpha)} |- forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE)

# %%
unfolded_existential.affirm_via_contradiction(alpha, assumptions=main_assumptions)
# Out:
# {alpha in BOOLEAN, [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], n in NaturalPos} |- alpha
# skolem_elim_lemma may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.quantification.existence.skolem_elim_lemma has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in NaturalPos, alpha in BOOLEAN} [forall_{P, Q} (([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]) => alpha)]
# 1	deduction	2	{alpha in BOOLEAN, n in NaturalPos} |- ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]) => alpha
# 2	instantiation	3, 4, 5	{alpha in BOOLEAN, [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], n in NaturalPos} |- alpha
# 	A : alpha
# 3	axiom		|- forall_{A in BOOLEAN | [not](A) => FALSE} A
# 	proveit.logic.booleans.implication.affirmation_via_contradiction
# 4	assumption		{alpha in BOOLEAN} |- alpha in BOOLEAN
# 5	deduction	6	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], n in NaturalPos} |- [not](alpha) => FALSE
# 6	instantiation	22, 7, 8	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], [not](alpha), n in NaturalPos} |- FALSE
# 	A : forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)
# 7	generalization	9	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], [not](alpha)} |- forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) != TRUE)
# 8	modus ponens	10, 11	{n in NaturalPos, [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]} |- [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE))
# 9	instantiation	12, 13	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n}), [not](alpha)} |- P(x_{1}, x_{2}, ..., x_{n}) != TRUE
# 	x : P(x_{1}, x_{2}, ..., x_{n}), y : TRUE
# 10	instantiation	14, 15	{n in NaturalPos} |- [exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE))
# 	n : n
# 11	instantiation	16, 32	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]} |- exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
# 	A : exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}), B : forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)
# 12	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 13	instantiation	17, 18, 19	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n}), [not](alpha)} |- [not](P(x_{1}, x_{2}, ..., x_{n}) = TRUE)
# 	A : P(x_{1}, x_{2}, ..., x_{n}) = TRUE
# 14	conjecture		|- forall_{n in NaturalPos} [forall_{P, Q} ([exists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)))]
# 	proveit.logic.booleans.quantification.existence.exists_unfolding
# 15	assumption		{n in NaturalPos} |- n in NaturalPos
# 16	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 17	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 18	instantiation	20	|- (P(x_{1}, x_{2}, ..., x_{n}) = TRUE) in BOOLEAN
# 	x : P(x_{1}, x_{2}, ..., x_{n}), y : TRUE
# 19	deduction	21	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n}), [not](alpha)} |- (P(x_{1}, x_{2}, ..., x_{n}) = TRUE) => FALSE
# 20	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 21	instantiation	22, 23, 24	{P(x_{1}, x_{2}, ..., x_{n}) = TRUE, [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n}), [not](alpha)} |- FALSE
# 	A : alpha
# 22	conjecture		|- forall_{A | A, [not](A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 23	modus ponens	25, 26	{P(x_{1}, x_{2}, ..., x_{n}) = TRUE, [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n})} |- alpha
# 24	assumption		{[not](alpha)} |- [not](alpha)
# 25	instantiation	27, 28	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)], Q(x_{1}, x_{2}, ..., x_{n})} |- P(x_{1}, x_{2}, ..., x_{n}) => alpha
# 	x : x
# 26	instantiation	29, 30	{P(x_{1}, x_{2}, ..., x_{n}) = TRUE} |- P(x_{1}, x_{2}, ..., x_{n})
# 	A : P(x_{1}, x_{2}, ..., x_{n})
# 27	instantiation	31, 32	{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]} |- forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)
# 	A : exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}), B : forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)
# 28	assumption		{Q(x_{1}, x_{2}, ..., x_{n})} |- Q(x_{1}, x_{2}, ..., x_{n})
# 29	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 30	assumption		{P(x_{1}, x_{2}, ..., x_{n}) = TRUE} |- P(x_{1}, x_{2}, ..., x_{n}) = TRUE
# 31	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 32	assumption		{[exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]} |- [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]
