# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">existence</a>.<a class="ProveItLink" href="../../theorems.ipynb#existence_by_basic_example">existence_by_basic_example</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, y, P, Px
from proveit.logic import FALSE, Implies, Not, Exists

# %%
# %proving existence_by_basic_example
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="existence_by_basic_example">existence_by_basic_example:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/20261e3471524e36cb2aece3d881dc37dc438f960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/cde458d7e3a29c1c2d7fad7d1ae5246bdf8726800/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = existence_by_basic_example.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/fac16180a501d67223fd321d714c742127a74a860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
exists_Py = existence_by_basic_example.instance_expr.instance_expr
# Out:
# <strong id="exists_Py">exists_Py:</strong> <a class="ProveItLink" href="../../../../__pv_it/common/936b5bf791acf74ac7471f3cc5ef478e215e0c2b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
exists_Py_def = exists_Py.definition()
# Out:
# <strong id="exists_Py_def">exists_Py_def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/22695f5d7e13c425fc2f286173b26fdc6c02b6ff0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/0bdebfa5d828201d3d76ac977a053d9c0c90a2f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_Py_forall_y = exists_Py_def.rhs.operand
# Out:
# <strong id="not_Py_forall_y">not_Py_forall_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1b65fa47663faee348e35dcb612d530dedce054a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
not_Px = not_Py_forall_y.instantiate({y:x}, assumptions=[not_Py_forall_y])
# Out:
# <strong id="not_Px">not_Px:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/1b65fa47663faee348e35dcb612d530dedce054a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/b690c0f8d8bb28256dfbc72ad8898d76ff30d77b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/6ec59fff905688003998ee9dfa812012add2f2f70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Px_impl_F = not_Px.unfold()
# Out:
# <strong id="Px_impl_F">Px_impl_F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/1b65fa47663faee348e35dcb612d530dedce054a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/c2e6d893e972e43aba3aed60f648bf24d7f1a7420/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/535531982c8a59fc8fd0a9f427116623cfa96cb30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction = Px_impl_F.derive_consequent()
# Out:
# <strong id="contradiction">contradiction:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../../__pv_it/common/32fc7f13c9e7e89074583aa5bfc208d125f839970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/1b65fa47663faee348e35dcb612d530dedce054a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/6a91800910290655402d5a405c9063081087038b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_Py_forall_y__impl__F = contradiction.as_implication(not_Py_forall_y)
# Out:
# <strong id="not_Py_forall_y__impl__F">not_Py_forall_y__impl__F:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../../__pv_it/common/32fc7f13c9e7e89074583aa5bfc208d125f839970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/7793e93dc77b670ec521e408f36676d7e1ecde150/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/dacd9c95ff1012cae74f2352cebdcad919e1c43d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
exists_Py_def_rhs = Not(not_Py_forall_y).prove()
# Out:
# <strong id="exists_Py_def_rhs">exists_Py_def_rhs:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../../__pv_it/common/32fc7f13c9e7e89074583aa5bfc208d125f839970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/9062b6419fe0745da57ead835bb8c3e0ec90645f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/8d68b5f4aa271479533dc5c0741d6f9a19dc25b10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
exists_Py_def_rev = exists_Py_def.derive_reversed()
# Out:
# <strong id="exists_Py_def_rev">exists_Py_def_rev:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/4feaf5251f6689f689b9879f01dad8be623420f90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_existence_by_basic_example/5369680c474f702791bf6468492c0c8cbe77c2ac0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
exists_Py_def_rev.sub_right_side_into(exists_Py_def_rhs)
# Out:
# {P(x)} |- exists_{y} P(y)
# existence_by_basic_example may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.quantification.existence.existence_by_basic_example is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{P} [forall_{x | P(x)} [exists_{y} P(y)]]
# 1	modus_ponens	2, 3	{P(x)} |- exists_{y} P(y)
# 2	modus_ponens	4, 5	{P(x)} |- ([not](forall_{y} [not](P(y))) = [exists_{y} P(y)]) => [exists_{y} P(y)]
# 3	instantiation	6, 7	|- [not](forall_{y} [not](P(y))) = [exists_{x} P(x)]
# 	x : exists_{x} P(x), y : [not](forall_{y} [not](P(y)))
# 4	instantiation	8	|- [not](forall_{y} [not](P(y))) => (([not](forall_{y} [not](P(y))) = [exists_{y} P(y)]) => [exists_{y} P(y)])
# 	P(_a) : _a, x : [not](forall_{y} [not](P(y))), y : exists_{y} P(y)
# 5	instantiation	9, 10	{P(x)} |- [not](forall_{y} [not](P(y)))
# 	A : forall_{y} [not](P(y))
# 6	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 7	instantiation	11	|- [exists_{x} P(x)] = [not](forall_{y} [not](P(y)))
# 	P : P
# ...
