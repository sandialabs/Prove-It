# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import alpha
from proveit.logic import Boolean, Equals, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = InSet(Equals(alpha, TRUE), Boolean)
# Out:
# expr: (alpha = TRUE) in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha = \top\right) \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (alpha = TRUE) in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (alpha = TRUE, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha = TRUE
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (alpha, TRUE)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. alpha
#    core type: Variable
#    sub-expressions:
# 8. TRUE
#    core type: Literal
#    sub-expressions:
