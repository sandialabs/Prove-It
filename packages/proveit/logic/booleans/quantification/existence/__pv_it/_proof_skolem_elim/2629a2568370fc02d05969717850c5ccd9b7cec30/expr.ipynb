# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, alpha
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import Equals, Implies, TRUE

# %%
# build up the expression from sub-expressions
expr = Lambda([x_1_to_n], Conditional(Implies(P__x_1_to_n, Equals(alpha, TRUE)), Q__x_1_to_n))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => (alpha = TRUE) if Q(x_{1}, ..x_{_a}.., x_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{n}\right) \mapsto \left\{P(x_{1}, \ldots, x_{n}) \Rightarrow \left(\alpha = \top\right) \textrm{ if } Q(x_{1}, \ldots, x_{n})\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => (alpha = TRUE) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {P(x_{1}, ..x_{_a}.., x_{n}) => (alpha = TRUE) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. P(x_{1}, ..x_{_a}.., x_{n}) => (alpha = TRUE)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. Q(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 6
#    operands: 10
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (P(x_{1}, ..x_{_a}.., x_{n}), alpha = TRUE)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Q
#    core type: Variable
#    sub-expressions:
# 7. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. alpha = TRUE
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (alpha, TRUE)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 14. alpha
#     core type: Variable
#     sub-expressions:
# 15. TRUE
#     core type: Literal
#     sub-expressions:
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. x_{_a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. _a
#     core type: Variable
#     sub-expressions:
