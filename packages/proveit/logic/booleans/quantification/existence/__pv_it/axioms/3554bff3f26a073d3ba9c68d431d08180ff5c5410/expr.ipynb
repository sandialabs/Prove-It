# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Q, n
from proveit.logic import Equals, Forall, Not
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy, general_notexists_Px_st_Qx
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([P, Q], Equals(general_notexists_Px_st_Qx, Not(general_exists_Py_st_Qy)).with_wrapping_at(2)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\begin{array}{c} \left[\nexists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right]) \end{array}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 37
#    body: 2
# 2. {forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q} ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (P, Q) -> ([notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 37, 11
# 9. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 29, 30
# 10. [notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. notexists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operand: 21
# 15. [not](exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. notexists
#     core type: Literal
#     sub-expressions:
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 20
#     operand: 21
# 19. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 20. exists
#     core type: Literal
#     sub-expressions:
# 21. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 31\n    body: 24
# 22. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 29
#     operands: 25
# 23. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 30
#     operands: 25
# 24. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 26. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 31
# 27. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 36
#     end_index: 37
# 29. P
#     core type: Variable
#     sub-expressions:
# 30. Q
#     core type: Variable
#     sub-expressions:
# 31. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 32. _a -> x_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 34
# 33. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 34. x_{_a}
#     core type: IndexedVar
# variable: 38
# index: 41
# 35. _a -> y_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 39
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. x
#     core type: Variable
#     sub-expressions:
# 39. y_{_a}
#     core type: IndexedVar
# variable: 40
# index: 41
# 40. y
#     core type: Variable
#     sub-expressions:
# 41. _a
#     core type: Variable
#     sub-expressions:
