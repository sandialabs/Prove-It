# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Q, n
from proveit.logic import Equals, Forall, InSet, Not
from proveit.logic.booleans.quantification import general_exists_Px_st_Qx, general_forall__Py_not_T__st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P, Q], Equals(general_exists_Px_st_Qx, Not(general_forall__Py_not_T__st_Qy)).with_wrapping_at(2)), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, Q}~\left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] =  \\ (\lnot \left[\forall_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(P(y_{1}, \ldots, y_{n}) \neq \top\right)\right]) \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 41
#    body: 1
# 1. {forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))) if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P, Q} ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#    core type: Operation
#    operator: 19
#    operand: 4
# 3. n in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (P, Q) -> ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 41, 9
# 7. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 35, 30
# 8. [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. exists
#     core type: Literal
#     sub-expressions:
# 15. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 24\n    body: 18
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 23
# 21. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 35
#     operands: 24
# 22. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 30
#     operands: 24
# 23. {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 27
# 25. P(y_{1}, ..y_{_a}.., y_{n}) != TRUE
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 36
# 27. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 40
#     end_index: 41
# 28. !=
#     core type: Literal
#     sub-expressions:
# 29. (P(y_{1}, ..y_{_a}.., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. Q
#     core type: Variable
#     sub-expressions:
# 31. _a -> x_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 34
# 32. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. TRUE
#     core type: Literal
#     sub-expressions:
# 34. x_{_a}
#     core type: IndexedVar
# variable: 37
# index: 44
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 37. x
#     core type: Variable
#     sub-expressions:
# 38. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 40
#     end_index: 41
# 39. _a -> y_{_a}
#     core type: Lambda
#     parameter: 44
#     body: 42
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
# 42. y_{_a}
#     core type: IndexedVar
# variable: 43
# index: 44
# 43. y
#     core type: Variable
#     sub-expressions:
# 44. _a
#     core type: Variable
#     sub-expressions:
