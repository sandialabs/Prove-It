# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, P, Q, R
from proveit.logic import Implies
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx

# %%
# build up the expression from sub-expressions
expr = Lambda([P, Q, R], Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).with_wrapping_at(2)).with_wrapping_at(2))
# Out:
# expr: (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P, Q, R\right) \mapsto \left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow R(x_{1}, \ldots, x_{n})\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \Rightarrow  \\ \left[\exists_{z_{1}, \ldots, z_{n}~|~Q(z_{1}, \ldots, z_{n})}~R(z_{1}, \ldots, z_{n})\right] \end{array}\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 28, 31, 30
# 2. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))] =>  \\ ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: Operation
#    operator: 17
#    operands: 3
# 3. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})), [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})])
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] =>  \\ [exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})]
#    core type: Operation
#    operator: 17
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 27\n   body: 9
# 8. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. {P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 15
#     operand: 14
# 11. exists_{z_{1}, ..z_{_a}.., z_{n} | Q(z_{1}, ..z_{_a}.., z_{n})} R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. P(x_{1}, ..x_{_a}.., x_{n}) => R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 31
#     operands: 27
# 14. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 29\n    body: 19
# 15. exists
#     core type: Literal
#     sub-expressions:
# 16. (z_{1}, ..z_{_a}.., z_{n}) -> {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Lambda
#     parameters: 32\n    body: 20
# 17. =>
#     core type: Literal
#     sub-expressions:
# 18. (P(x_{1}, ..x_{_a}.., x_{n}), R(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. {R(z_{1}, ..z_{_a}.., z_{n}) if Q(z_{1}, ..z_{_a}.., z_{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 21. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 28
#     operands: 27
# 22. R(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 30
#     operands: 27
# 23. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 31
#     operands: 29
# 25. R(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 30
#     operands: 32
# 26. Q(z_{1}, ..z_{_a}.., z_{n})
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. P
#     core type: Variable
#     sub-expressions:
# 29. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 34
# 30. R
#     core type: Variable
#     sub-expressions:
# 31. Q
#     core type: Variable
#     sub-expressions:
# 32. (z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 33. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 39
#     end_index: 40
# 34. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 39
#     end_index: 40
# 35. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 36. _a -> x_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 41
# 37. _a -> y_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 38. _a -> z_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 43
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
# 41. x_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 42. y_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 43. z_{_a}
#     core type: IndexedVar
# variable: 46
# index: 47
# 44. x
#     core type: Variable
#     sub-expressions:
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. z
#     core type: Variable
#     sub-expressions:
# 47. _a
#     core type: Variable
#     sub-expressions:
