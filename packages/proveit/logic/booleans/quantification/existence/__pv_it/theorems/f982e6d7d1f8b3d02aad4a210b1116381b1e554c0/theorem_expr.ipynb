# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exists_with_conditions_is_bool">exists_with_conditions_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import exists_with_conditions_is_bool

# %%
# check that the built expression is the same as the stored expression
assert exists_with_conditions_is_bool.expr == stored_expr
assert exists_with_conditions_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: exists_with_conditions_is_bool matches stored_expr")
# Out:
# Passed sanity check: exists_with_conditions_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exists_with_conditions_is_bool.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \in \mathbb{B}\right)\right]

# %%
# display the expression information
exists_with_conditions_is_bool.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, Q} ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN) if n in NaturalPos.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{P, Q} ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q} ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 11
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (P, Q) -> ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN)
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 26, 10
# 8. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 20, 21
# 9. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 15
#     operand: 16
# 14. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 15. exists
#     core type: Literal
#     sub-expressions:
# 16. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 22\n    body: 17
# 17. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 20
#     operands: 22
# 19. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. P
#     core type: Variable
#     sub-expressions:
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 23. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 24. _a -> y_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 27
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. n
#     core type: Variable
#     sub-expressions:
# 27. y_{_a}
#     core type: IndexedVar
# variable: 28
# index: 29
# 28. y
#     core type: Variable
#     sub-expressions:
# 29. _a
#     core type: Variable
#     sub-expressions:
