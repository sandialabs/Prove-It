# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#skolem_elim_lemma">skolem_elim_lemma</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import skolem_elim_lemma

# %%
# check that the built expression is the same as the stored expression
assert skolem_elim_lemma.expr == stored_expr
assert skolem_elim_lemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: skolem_elim_lemma matches stored_expr")
# Out:
# Passed sanity check: skolem_elim_lemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(skolem_elim_lemma.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+, \alpha \in \mathbb{B}}~\left[\forall_{P, Q}~\left(\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \land \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow \alpha\right)\right]\right) \Rightarrow \alpha\right)\right]

# %%
# display the expression information
skolem_elim_lemma.expr_info()
# Out:
# 0. forall_{n in NaturalPos, alpha in BOOLEAN} [forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)]
#    core type: Operation
#    operator: 25
#    operand: 1
# 1. (n, alpha) -> {forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos ,  alpha in BOOLEAN.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (n, alpha)
#    core type: ExprTuple
#    sub-expressions: 48, 39
# 3. {forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos ,  alpha in BOOLEAN.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P, Q} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Operation
#    operator: 25
#    operand: 6
# 5. (n in NaturalPos) and (alpha in BOOLEAN)
#    core type: Operation
#    operator: 19
#    operands: 7
# 6. (P, Q) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (n in NaturalPos, alpha in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 41, 36
# 9. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
#    core type: Operation
#    operator: 34
#    operands: 12
# 10. n in NaturalPos
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. alpha in BOOLEAN
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], alpha)
#     core type: ExprTuple
#     sub-expressions: 16, 39
# 13. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 48, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (alpha, BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 39, 18
# 16. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. NaturalPos
#     core type: Literal
#     sub-expressions:
# 18. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operand: 24
# 22. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
#     core type: Operation
#     operator: 25
#     operand: 26
# 23. exists
#     core type: Literal
#     sub-expressions:
# 24. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 33\n    body: 27
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 42\n    body: 28
# 27. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 29. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 41
#     operands: 33
# 30. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 33
# 31. P(x_{1}, ..x_{_a}.., x_{n}) => alpha
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 42
# 33. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. =>
#     core type: Literal
#     sub-expressions:
# 35. (P(x_{1}, ..x_{_a}.., x_{n}), alpha)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 47
#     end_index: 48
# 38. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. alpha
#     core type: Variable
#     sub-expressions:
# 40. _a -> y_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 43
# 41. P
#     core type: Variable
#     sub-expressions:
# 42. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 43. y_{_a}
#     core type: IndexedVar
# variable: 45
# index: 51
# 44. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. _a -> x_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 49
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. x_{_a}
#     core type: IndexedVar
# variable: 50
# index: 51
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. _a
#     core type: Variable
#     sub-expressions:
