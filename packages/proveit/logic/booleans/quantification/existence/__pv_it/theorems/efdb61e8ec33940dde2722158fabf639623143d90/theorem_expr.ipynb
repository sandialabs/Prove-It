# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exists_def_negation">exists_def_negation</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import exists_def_negation

# %%
# check that the built expression is the same as the stored expression
assert exists_def_negation.expr == stored_expr
assert exists_def_negation.expr._style_id == stored_expr._style_id
print("Passed sanity check: exists_def_negation matches stored_expr")
# Out:
# Passed sanity check: exists_def_negation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\nexists_{x_{1}, x_{2}, \ldots, x_{n}~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] =  \\ \left[\forall_{y_{1}, y_{2}, \ldots, y_{n}~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~\left(P\left(y_{1}, y_{2}, \ldots, y_{n}\right) \neq \top\right)\right] \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)])]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. (n -> {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 45
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 45
# 4. {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)]) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)])
#    core type: Operation
#    operator: 20
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((P, Q) -> ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)]))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 45, 11
# 10. (P, Q) -> ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)])
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 38, 33
# 13. [notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =  \\ [forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)]
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 18
#     operand: 22
# 17. forall_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} (P(y_{1}, y_{2}, ..., y_{n}) != TRUE)
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. notexists
#     core type: Literal
#     sub-expressions:
# 19. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) != TRUE if Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 30\n    body: 24
# 23. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) != TRUE if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 25
# 24. {P(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. {P(y_{1}, y_{2}, ..., y_{n}) != TRUE if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 38
#     operands: 30
# 27. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 33
#     operands: 30
# 28. P(y_{1}, y_{2}, ..., y_{n}) != TRUE
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 39
# 30. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 34
# 31. !=
#     core type: Literal
#     sub-expressions:
# 32. (P(y_{1}, y_{2}, ..., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 44
#     end_index: 45
# 35. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. TRUE
#     core type: Literal
#     sub-expressions:
# 37. _a -> x_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 40
# 38. P
#     core type: Variable
#     sub-expressions:
# 39. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 40. x_{_a}
#     core type: IndexedVar
# variable: 42
# index: 49
# 41. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. _a -> y_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 46
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. y_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. (_a)
#     core type: ExprTuple
#     sub-expressions: 49
# 49. _a
#     core type: Variable
#     sub-expressions:
