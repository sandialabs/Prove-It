# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import alpha, n
from proveit.logic import And, Boolean, InSet
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = And(InSet(n, NaturalPos), InSet(alpha, Boolean))
# Out:
# expr: (n in NaturalPos) and (alpha in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{N}^+\right) \land \left(\alpha \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n in NaturalPos) and (alpha in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (n in NaturalPos, alpha in BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. alpha in BOOLEAN
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (alpha, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. alpha
#     core type: Variable
#     sub-expressions:
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
