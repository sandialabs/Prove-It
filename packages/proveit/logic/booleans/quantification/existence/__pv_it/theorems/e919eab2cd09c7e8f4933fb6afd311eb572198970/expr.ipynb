# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Q, R, n
from proveit.logic import Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [P, Q, R], instance_expr = Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).with_wrapping_at(2)).with_wrapping_at(2)), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~\left(P\left(x_{1}, x_{2}, \ldots, x_{n}\right) \Rightarrow R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\exists_{y_{1}, y_{2}, \ldots, y_{n}~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \Rightarrow  \\ \left[\exists_{z_{1}, z_{2}, \ldots, z_{n}~|~Q\left(z_{1}, z_{2}, \ldots, z_{n}\right)}~R\left(z_{1}, z_{2}, \ldots, z_{n}\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])) if n in NaturalPos.
#    core type: Lambda
#    parameter: 52
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 52
# 2. {forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Operation
#    operator: 15
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 52, 9
# 8. (P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (P, Q, R)
#     core type: ExprTuple
#     sub-expressions: 40, 43, 42
# 11. [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#     core type: Operation
#     operator: 29
#     operands: 12
# 12. (forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})), [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]
#     core type: Operation
#     operator: 29
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}), exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 21
# 19. exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 23
#     operand: 27
# 20. exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 23
#     operand: 28
# 21. {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. exists
#     core type: Literal
#     sub-expressions:
# 24. ((z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 43
#     operands: 39
# 27. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 41\n    body: 31
# 28. (z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Lambda
#     parameters: 44\n    body: 32
# 29. =>
#     core type: Literal
#     sub-expressions:
# 30. (P(x_{1}, x_{2}, ..., x_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 35
#     condition: 36
# 32. {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Conditional
#     value: 37
#     condition: 38
# 33. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 40
#     operands: 39
# 34. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 42
#     operands: 39
# 35. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 43
#     operands: 41
# 37. R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 42
#     operands: 44
# 38. Q(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 40. P
#     core type: Variable
#     sub-expressions:
# 41. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. R
#     core type: Variable
#     sub-expressions:
# 43. Q
#     core type: Variable
#     sub-expressions:
# 44. (z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 51
#     end_index: 52
# 46. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 51
#     end_index: 52
# 47. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 48. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 49. _a -> y_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 50. _a -> z_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. x_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 54. y_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 55. z_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 56. x
#     core type: Variable
#     sub-expressions:
# 57. y
#     core type: Variable
#     sub-expressions:
# 58. z
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
