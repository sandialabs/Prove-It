# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#not_exists_folding">not_exists_folding</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import not_exists_folding

# %%
# check that the built expression is the same as the stored expression
assert not_exists_folding.expr == stored_expr
assert not_exists_folding.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_exists_folding matches stored_expr")
# Out:
# Passed sanity check: not_exists_folding matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_exists_folding.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P}~\left(\begin{array}{c} (\lnot \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]) \Rightarrow  \\ \left[\nexists_{y_{1}, \ldots, y_{n}}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right)\right]

# %%
# display the expression information
not_exists_folding.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 30
#    body: 2
# 2. {forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P} ([not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})) =>  \\ [notexists_{y_{1}, ..y_{_a}.., y_{n}} P(y_{1}, ..y_{_a}.., y_{n})])
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
# ...
