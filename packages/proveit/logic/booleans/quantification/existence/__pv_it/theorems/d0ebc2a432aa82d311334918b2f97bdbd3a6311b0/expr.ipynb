# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, P, Q
from proveit.logic import Forall, Implies, SubsetEq
from proveit.logic.booleans.quantification import general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [P, Q, A, B], instance_expr = Implies(general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy).with_wrapping_at(2), condition = SubsetEq(A, B))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{P, Q, A, B~|~A \subseteq B}~\left(\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, x_{2}, \ldots, x_{n} \in A~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left[\exists_{y_{1}, y_{2}, \ldots, y_{n} \in B~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (P, Q, A, B)
#    core type: ExprTuple
#    sub-expressions: 26, 36, 49, 51
# 5. {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. [exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. A subset_eq B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. subset_eq
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 49, 51
# 12. exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 15
#     operand: 17
# 13. exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. exists
#     core type: Literal
#     sub-expressions:
# 16. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 34\n    body: 19
# 18. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 20
# 19. {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 21. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 26
#     operands: 34
# 22. (x_{1} in A) and  (x_{2} in A) and  ... and  (x_{n} in A) and Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 27
#     operands: 25
# 23. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 26
#     operands: 37
# 24. (y_{1} in B) and  (y_{2} in B) and  ... and  (y_{n} in B) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. ((x_{1} in A), (x_{2} in A), ..., (x_{n} in A), Q(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. P
#     core type: Variable
#     sub-expressions:
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((y_{1} in B), (y_{2} in B), ..., (y_{n} in B), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. (x_{1} in A), (x_{2} in A), ..., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 47
#     end_index: 48
# 30. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 34
# 31. (y_{1} in B), (y_{2} in B), ..., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 47
#     end_index: 48
# 32. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 56
#     body: 38
# 34. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 56
#     body: 40
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. x_{_a} in A
#     core type: Operation
#     operator: 44
#     operands: 42
# 39. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 47
#     end_index: 48
# 40. y_{_a} in B
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 42. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 43. _a -> x_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 50
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 46. _a -> y_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. A
#     core type: Variable
#     sub-expressions:
# 50. x_{_a}
#     core type: IndexedVar
# variable: 53
# index: 56
# 51. B
#     core type: Variable
#     sub-expressions:
# 52. y_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. y
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
