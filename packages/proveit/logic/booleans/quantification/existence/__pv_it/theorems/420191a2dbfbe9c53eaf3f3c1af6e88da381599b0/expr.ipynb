# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Q, R, n
from proveit.logic import Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [P, Q, R], instance_expr = Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).with_wrapping_at(2)).with_wrapping_at(2)), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{P, Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~\left(P\left(x_{1}, x_{2}, \ldots, x_{n}\right) \Rightarrow R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\exists_{y_{1}, y_{2}, \ldots, y_{n}~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \Rightarrow  \\ \left[\exists_{z_{1}, z_{2}, \ldots, z_{n}~|~Q\left(z_{1}, z_{2}, \ldots, z_{n}\right)}~R\left(z_{1}, z_{2}, \ldots, z_{n}\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Operation
#    operator: 13
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 50, 7
# 6. (P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 38, 41, 40
# 9. [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#    core type: Operation
#    operator: 27
#    operands: 10
# 10. (forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})), [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]
#     core type: Operation
#     operator: 27
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}), exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 19
# 17. exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 21
#     operand: 25
# 18. exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 21
#     operand: 26
# 19. {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. exists
#     core type: Literal
#     sub-expressions:
# 22. ((z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 41
#     operands: 37
# 25. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 29
# 26. (z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Lambda
#     parameters: 42\n    body: 30
# 27. =>
#     core type: Literal
#     sub-expressions:
# 28. (P(x_{1}, x_{2}, ..., x_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 30. {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Conditional
#     value: 35
#     condition: 36
# 31. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 40
#     operands: 37
# 33. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 41
#     operands: 39
# 35. R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 40
#     operands: 42
# 36. Q(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 38. P
#     core type: Variable
#     sub-expressions:
# 39. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 40. R
#     core type: Variable
#     sub-expressions:
# 41. Q
#     core type: Variable
#     sub-expressions:
# 42. (z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 43. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 49
#     end_index: 50
# 44. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 49
#     end_index: 50
# 45. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 46. _a -> x_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 51
# 47. _a -> y_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 52
# 48. _a -> z_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 53
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. x_{_a}
#     core type: IndexedVar
# variable: 54
# index: 58
# 52. y_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 53. z_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 54. x
#     core type: Variable
#     sub-expressions:
# 55. y
#     core type: Variable
#     sub-expressions:
# 56. z
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
