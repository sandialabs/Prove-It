# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Boolean, InSet
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy

# %%
# build up the expression from sub-expressions
expr = InSet(general_exists_Py_st_Qy, Boolean)
# Out:
# expr: [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 12\n   body: 7
# 7. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 10
#    operands: 12
# 9. Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 13. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. _a -> y_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. y_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
