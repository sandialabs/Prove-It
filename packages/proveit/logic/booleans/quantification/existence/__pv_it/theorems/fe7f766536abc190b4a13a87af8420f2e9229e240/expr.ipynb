# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, P, Q, n
from proveit.logic import Forall, Implies, InSet, SubsetEq
from proveit.logic.booleans.quantification import general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [P, Q, A, B], instance_expr = Implies(general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy).with_wrapping_at(2), condition = SubsetEq(A, B)), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, Q, A, B~|~A \subseteq B}~\left(\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, x_{2}, \ldots, x_{n} \in A~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left[\exists_{y_{1}, y_{2}, \ldots, y_{n} \in B~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 54
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 54
# 2. {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})])
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 50
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 54, 9
# 8. (P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (P, Q, A, B)
#     core type: ExprTuple
#     sub-expressions: 32, 42, 55, 57
# 11. {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. [exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. A subset_eq B
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. subset_eq
#     core type: Literal
#     sub-expressions:
# 17. (A, B)
#     core type: ExprTuple
#     sub-expressions: 55, 57
# 18. exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 21
#     operand: 23
# 19. exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. exists
#     core type: Literal
#     sub-expressions:
# 22. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 25
# 24. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 43\n    body: 26
# 25. {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 29
#     condition: 30
# 27. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 32
#     operands: 40
# 28. (x_{1} in A) and  (x_{2} in A) and  ... and  (x_{n} in A) and Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 33
#     operands: 31
# 29. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 32
#     operands: 43
# 30. (y_{1} in B) and  (y_{2} in B) and  ... and  (y_{n} in B) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. ((x_{1} in A), (x_{2} in A), ..., (x_{n} in A), Q(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. P
#     core type: Variable
#     sub-expressions:
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ((y_{1} in B), (y_{2} in B), ..., (y_{n} in B), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. (x_{1} in A), (x_{2} in A), ..., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 53
#     end_index: 54
# 36. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 42
#     operands: 40
# 37. (y_{1} in B), (y_{2} in B), ..., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 53
#     end_index: 54
# 38. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 62
#     body: 44
# 40. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 41. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 62
#     body: 46
# 42. Q
#     core type: Variable
#     sub-expressions:
# 43. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. x_{_a} in A
#     core type: Operation
#     operator: 50
#     operands: 48
# 45. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 53
#     end_index: 54
# 46. y_{_a} in B
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 48. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 49. _a -> x_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 56
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 52. _a -> y_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. A
#     core type: Variable
#     sub-expressions:
# 56. x_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 57. B
#     core type: Variable
#     sub-expressions:
# 58. y_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. y
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
