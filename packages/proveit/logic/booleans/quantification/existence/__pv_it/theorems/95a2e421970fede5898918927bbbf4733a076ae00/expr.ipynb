# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Q, R
from proveit.logic import Forall, Implies
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy, general_exists_Rz_st_Qz, general_forall_st_Qx__Px_implies_Rx

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [P, Q, R], instance_expr = Implies(general_forall_st_Qx__Px_implies_Rx, Implies(general_exists_Py_st_Qy, general_exists_Rz_st_Qz).with_wrapping_at(2)).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{P, Q, R}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~\left(P\left(x_{1}, x_{2}, \ldots, x_{n}\right) \Rightarrow R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[\exists_{y_{1}, y_{2}, \ldots, y_{n}~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \Rightarrow  \\ \left[\exists_{z_{1}, z_{2}, \ldots, z_{n}~|~Q\left(z_{1}, z_{2}, \ldots, z_{n}\right)}~R\left(z_{1}, z_{2}, \ldots, z_{n}\right)\right] \end{array} \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Operation
#    operator: 8
#    operand: 2
# 1. ((P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (P, Q, R) -> ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 33, 36, 35
# 4. [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))] =>  \\ ([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#    core type: Operation
#    operator: 22
#    operands: 5
# 5. (forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})), [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. [exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] =>  \\ [exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})]
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}), exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n}))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 32\n    body: 14
# 12. exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 16
#     operand: 20
# 13. exists_{z_{1}, z_{2}, ..., z_{n} | Q(z_{1}, z_{2}, ..., z_{n})} R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 16
#     operand: 21
# 14. {P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. ((z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. P(x_{1}, x_{2}, ..., x_{n}) => R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 32
# 20. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 34\n    body: 24
# 21. (z_{1}, z_{2}, ..., z_{n}) -> {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 25
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. (P(x_{1}, x_{2}, ..., x_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. {R(z_{1}, z_{2}, ..., z_{n}) if Q(z_{1}, z_{2}, ..., z_{n}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 26. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 35
#     operands: 32
# 28. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 34
# 30. R(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 35
#     operands: 37
# 31. Q(z_{1}, z_{2}, ..., z_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. P
#     core type: Variable
#     sub-expressions:
# 34. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. R
#     core type: Variable
#     sub-expressions:
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. (z_{1}, z_{2}, ..., z_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 38. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 44
#     end_index: 45
# 39. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 44
#     end_index: 45
# 40. z_{1}, z_{2}, ..., z_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 44
#     end_index: 45
# 41. _a -> x_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 46
# 42. _a -> y_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 47
# 43. _a -> z_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. x_{_a}
#     core type: IndexedVar
# variable: 49
# index: 53
# 47. y_{_a}
#     core type: IndexedVar
# variable: 50
# index: 53
# 48. z_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. y
#     core type: Variable
#     sub-expressions:
# 51. z
#     core type: Variable
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. _a
#     core type: Variable
#     sub-expressions:
