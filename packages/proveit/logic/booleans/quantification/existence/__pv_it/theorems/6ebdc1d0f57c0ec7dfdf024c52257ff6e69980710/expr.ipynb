# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, P, Q, n
from proveit.logic import Forall, Implies, InSet, SubsetEq
from proveit.logic.booleans.quantification import general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [P, Q, A, B], instance_expr = Implies(general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy).with_wrapping_at(2), condition = SubsetEq(A, B)), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{P, Q, A, B~|~A \subseteq B}~\left(\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, x_{2}, \ldots, x_{n} \in A~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left[\exists_{y_{1}, y_{2}, \ldots, y_{n} \in B~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 55
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 55
# 3. {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 55, 10
# 9. (P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (P, Q, A, B)
#     core type: ExprTuple
#     sub-expressions: 33, 43, 56, 58
# 12. {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. [exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A subset_eq B
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. subset_eq
#     core type: Literal
#     sub-expressions:
# 18. (A, B)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 19. exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 22
#     operand: 24
# 20. exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. exists
#     core type: Literal
#     sub-expressions:
# 23. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 41\n    body: 26
# 25. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 44\n    body: 27
# 26. {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 28. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 33
#     operands: 41
# 29. (x_{1} in A) and  (x_{2} in A) and  ... and  (x_{n} in A) and Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 34
#     operands: 32
# 30. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 44
# 31. (y_{1} in B) and  (y_{2} in B) and  ... and  (y_{n} in B) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. ((x_{1} in A), (x_{2} in A), ..., (x_{n} in A), Q(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. P
#     core type: Variable
#     sub-expressions:
# 34. and
#     core type: Literal
#     sub-expressions:
# 35. ((y_{1} in B), (y_{2} in B), ..., (y_{n} in B), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. (x_{1} in A), (x_{2} in A), ..., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 54
#     end_index: 55
# 37. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 43
#     operands: 41
# 38. (y_{1} in B), (y_{2} in B), ..., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 54
#     end_index: 55
# 39. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 63
#     body: 45
# 41. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 63
#     body: 47
# 43. Q
#     core type: Variable
#     sub-expressions:
# 44. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. x_{_a} in A
#     core type: Operation
#     operator: 51
#     operands: 49
# 46. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 54
#     end_index: 55
# 47. y_{_a} in B
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 49. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 50. _a -> x_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 57
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 53. _a -> y_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 59
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. x_{_a}
#     core type: IndexedVar
# variable: 60
# index: 63
# 58. B
#     core type: Variable
#     sub-expressions:
# 59. y_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 60. x
#     core type: Variable
#     sub-expressions:
# 61. y
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
