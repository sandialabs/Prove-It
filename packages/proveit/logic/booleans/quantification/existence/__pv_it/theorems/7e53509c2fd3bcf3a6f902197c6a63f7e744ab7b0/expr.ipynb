# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, P, Q, n
from proveit.logic import Forall, Implies, InSet, SubsetEq
from proveit.logic.booleans.quantification import general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [P, Q, A, B], instance_expr = Implies(general_exists_in_A_Px_st_Qx, general_exists_in_B_Py_st_Qy).with_wrapping_at(2), condition = SubsetEq(A, B)), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{P, Q, A, B~|~A \subseteq B}~\left(\begin{array}{c} \begin{array}{l} \left[\exists_{x_{1}, x_{2}, \ldots, x_{n} \in A~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left[\exists_{y_{1}, y_{2}, \ldots, y_{n} \in B~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, Q, A, B | A subset_eq B} ([exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})])
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 48
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 52, 7
# 6. (P, Q, A, B) -> {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (P, Q, A, B)
#    core type: ExprTuple
#    sub-expressions: 30, 40, 53, 55
# 9. {[exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] if A subset_eq B.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. [exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. A subset_eq B
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. subset_eq
#     core type: Literal
#     sub-expressions:
# 15. (A, B)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 16. exists_{x_{1}, x_{2}, ..., x_{n} in A | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 19
#     operand: 21
# 17. exists_{y_{1}, y_{2}, ..., y_{n} in B | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 19
#     operand: 22
# 18. ((x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. exists
#     core type: Literal
#     sub-expressions:
# 20. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (x_{1}, x_{2}, ..., x_{n}) -> {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 38\n    body: 23
# 22. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 41\n    body: 24
# 23. {P(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in A) ,  (x_{2} in A) ,  ... ,  (x_{n} in A) ,  Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. {P(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in B) ,  (y_{2} in B) ,  ... ,  (y_{n} in B) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 30
#     operands: 38
# 26. (x_{1} in A) and  (x_{2} in A) and  ... and  (x_{n} in A) and Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 31
#     operands: 29
# 27. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 41
# 28. (y_{1} in B) and  (y_{2} in B) and  ... and  (y_{n} in B) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. ((x_{1} in A), (x_{2} in A), ..., (x_{n} in A), Q(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. P
#     core type: Variable
#     sub-expressions:
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ((y_{1} in B), (y_{2} in B), ..., (y_{n} in B), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. (x_{1} in A), (x_{2} in A), ..., (x_{n} in A)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 51
#     end_index: 52
# 34. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 40
#     operands: 38
# 35. (y_{1} in B), (y_{2} in B), ..., (y_{n} in B)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 51
#     end_index: 52
# 36. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. _a -> (x_{_a} in A)
#     core type: Lambda
#     parameter: 60
#     body: 42
# 38. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 39. _a -> (y_{_a} in B)
#     core type: Lambda
#     parameter: 60
#     body: 44
# 40. Q
#     core type: Variable
#     sub-expressions:
# 41. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. x_{_a} in A
#     core type: Operation
#     operator: 48
#     operands: 46
# 43. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 51
#     end_index: 52
# 44. y_{_a} in B
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 46. (x_{_a}, A)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 47. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (y_{_a}, B)
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 50. _a -> y_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 56
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. A
#     core type: Variable
#     sub-expressions:
# 54. x_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 55. B
#     core type: Variable
#     sub-expressions:
# 56. y_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 57. x
#     core type: Variable
#     sub-expressions:
# 58. y
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
