# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, P, Q
from proveit.logic import Implies, Not
from proveit.logic.booleans.quantification import general_exists_Px_st_Qx, general_forall__Py_not_T__st_Qy

# %%
# build up the expression from sub-expressions
expr = Lambda([P, Q], Implies(general_exists_Px_st_Qx, Not(general_forall__Py_not_T__st_Qy)).with_wrapping_at(2))
# Out:
# expr: (P, Q) -> ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P, Q\right) \mapsto \left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ (\lnot \left[\forall_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(P(y_{1}, \ldots, y_{n}) \neq \top\right)\right]) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P, Q) -> ([exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 28, 23
# 2. [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. exists
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 17\n   body: 11
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 29\n    body: 16
# 14. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 28
#     operands: 17
# 15. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 23
#     operands: 17
# 16. {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. P(y_{1}, ..y_{_a}.., y_{n}) != TRUE
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operands: 29
# 20. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 33
#     end_index: 34
# 21. !=
#     core type: Literal
#     sub-expressions:
# 22. (P(y_{1}, ..y_{_a}.., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Q
#     core type: Variable
#     sub-expressions:
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 27
# 25. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. TRUE
#     core type: Literal
#     sub-expressions:
# 27. x_{_a}
#     core type: IndexedVar
# variable: 30
# index: 37
# 28. P
#     core type: Variable
#     sub-expressions:
# 29. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 32. _a -> y_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 35
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. y_{_a}
#     core type: IndexedVar
# variable: 36
# index: 37
# 36. y
#     core type: Variable
#     sub-expressions:
# 37. _a
#     core type: Variable
#     sub-expressions:
