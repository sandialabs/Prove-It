# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, n
from proveit.logic import Boolean, Forall, InSet
from proveit.logic.booleans.quantification import general_exists_Px
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P], InSet(general_exists_Px, Boolean)), InSet(n, NaturalPos))
# Out:
# expr: {forall_{P} ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P}~\left(\left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P} ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P} ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in NaturalPos
#    core type: Operation
#    operator: 8
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. P -> ([exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Lambda
#    parameter: 15
#    body: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 20, 7
# 6. [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 12. exists
#     core type: Literal
#     sub-expressions:
# 13. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 16\n    body: 14
# 14. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. P
#     core type: Variable
#     sub-expressions:
# 16. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. x_{_a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
