# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Not
from proveit.logic.booleans.quantification import general_exists_Px

# %%
# build up the expression from sub-expressions
expr = Not(general_exists_Px)
# Out:
# expr: [not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lnot \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [not](exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. not
#    core type: Literal
#    sub-expressions:
# 2. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameters: 7\n   body: 5
# 5. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 9. _a -> x_{_a}
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. x_{_a}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. _a
#     core type: Variable
#     sub-expressions:
