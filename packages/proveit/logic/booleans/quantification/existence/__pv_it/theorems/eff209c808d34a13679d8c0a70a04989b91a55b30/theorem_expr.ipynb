# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#not_exists_unfolding">not_exists_unfolding</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import not_exists_unfolding

# %%
# check that the built expression is the same as the stored expression
assert not_exists_unfolding.expr == stored_expr
assert not_exists_unfolding.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_exists_unfolding matches stored_expr")
# Out:
# Passed sanity check: not_exists_unfolding matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\begin{array}{c} \begin{array}{l} \left[\nexists_{x_{1}, x_{2}, \ldots, x_{n}~|~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~P\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ (\lnot \left[\exists_{y_{1}, y_{2}, \ldots, y_{n}~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~P\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right]) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 43
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 43
# 4. {forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{P, Q} ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. n in NaturalPos
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((P, Q) -> ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 43, 12
# 11. (P, Q) -> ([notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})))
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. NaturalPos
#     core type: Literal
#     sub-expressions:
# 13. (P, Q)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 14. [notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] =>  \\ [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n}), [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. notexists_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 19
#     operand: 28
# 18. [not](exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: Operation
#     operator: 20
#     operand: 22
# 19. notexists
#     core type: Literal
#     sub-expressions:
# 20. not
#     core type: Literal
#     sub-expressions:
# 21. (exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 22
# 22. exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 24
#     operand: 28
# 23. {P(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 24. exists
#     core type: Literal
#     sub-expressions:
# 25. ((y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. P(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 35
#     operands: 29
# 27. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 29
# 28. (y_{1}, y_{2}, ..., y_{n}) -> {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 30
# 29. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. {P(y_{1}, y_{2}, ..., y_{n}) if Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 32
#     condition: 33
# 31. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 42
#     end_index: 43
# 32. P(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 37
# 33. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. _a -> x_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 38
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 38. x_{_a}
#     core type: IndexedVar
# variable: 40
# index: 47
# 39. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. _a -> y_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 44
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. y_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 47. _a
#     core type: Variable
#     sub-expressions:
