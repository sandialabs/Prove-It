# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exists_in_superset">exists_in_superset</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.existence import exists_in_superset

# %%
# check that the built expression is the same as the stored expression
assert exists_in_superset.expr == stored_expr
assert exists_in_superset.expr._style_id == stored_expr._style_id
print("Passed sanity check: exists_in_superset matches stored_expr")
# Out:
# Passed sanity check: exists_in_superset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exists_in_superset.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, A, B~|~A \subseteq B}~\left(\begin{array}{c} \left[\exists_{x_{1}, \ldots, x_{n} \in A}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\exists_{y_{1}, \ldots, y_{n} \in B}~P(y_{1}, \ldots, y_{n})\right] \end{array}\right)\right]

# %%
# display the expression information
exists_in_superset.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 43
#    body: 2
# 2. {forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, A, B | A subseteq B} ([exists_{x_{1}, ..x_{_a}.., x_{n} in A} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [exists_{y_{1}, ..y_{_a}.., y_{n} in B} P(y_{1}, ..y_{_a}.., y_{n})])
# ...
