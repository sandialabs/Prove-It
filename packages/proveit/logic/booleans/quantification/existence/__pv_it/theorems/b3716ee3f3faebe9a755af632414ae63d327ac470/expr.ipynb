# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, n
from proveit.core_expr_types import P__y_1_to_n, y_1_to_n
from proveit.logic import Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_exists_Px
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P], Forall([y_1_to_n], Implies(P__y_1_to_n, general_exists_Px).with_wrapping_at(2))), InSet(n, NaturalPos))
# Out:
# expr: {forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P}~\left[\forall_{y_{1}, \ldots, y_{n}}~\left(\begin{array}{c} P(y_{1}, \ldots, y_{n}) \Rightarrow  \\ \left[\exists_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \end{array}\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])] if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P} [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. n in NaturalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. P -> [forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])]
#    core type: Lambda
#    parameter: 21
#    body: 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 28, 7
# 6. forall_{y_{1}, ..y_{_a}.., y_{n}} (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (y_{1}, ..y_{_a}.., y_{n}) -> (P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})])
#    core type: Lambda
#    parameters: 15\n   body: 10
# 10. P(y_{1}, ..y_{_a}.., y_{n}) =>  \\ [exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (P(y_{1}, ..y_{_a}.., y_{n}), exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operands: 15
# 14. exists_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 22\n    body: 19
# 18. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 27
#     end_index: 28
# 19. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. _a -> y_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 23
# 21. P
#     core type: Variable
#     sub-expressions:
# 22. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. y_{_a}
#     core type: IndexedVar
# variable: 25
# index: 31
# 24. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. _a -> x_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. x_{_a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
