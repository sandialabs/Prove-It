# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Q, alpha, n
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n, x_1_to_n
from proveit.logic import And, Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_exists_Py_st_Qy
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P, Q, alpha], Implies(And(general_exists_Py_st_Qy, Forall([x_1_to_n], Implies(P__x_1_to_n, alpha), condition = Q__x_1_to_n)), alpha)), InSet(n, NaturalPos))
# Out:
# expr: {forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P, Q, \alpha}~\left(\left(\left[\exists_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~P(y_{1}, \ldots, y_{n})\right] \land \left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~\left(P(x_{1}, \ldots, x_{n}) \Rightarrow \alpha\right)\right]\right) \Rightarrow \alpha\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, Q, alpha} (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Operation
#    operator: 17
#    operand: 3
# 2. n in NaturalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (P, Q, alpha) -> (([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha)
#    core type: Lambda
#    parameters: 6\n   body: 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 40, 8
# 6. (P, Q, alpha)
#    core type: ExprTuple
#    sub-expressions: 33, 28, 31
# 7. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]) => alpha
#    core type: Operation
#    operator: 26
#    operands: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. ([exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)], alpha)
#    core type: ExprTuple
#    sub-expressions: 10, 31
# 10. [exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})] and [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)]
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. exists_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 15
#     operand: 16
# 14. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} (P(x_{1}, ..x_{_a}.., x_{n}) => alpha)
#     core type: Operation
#     operator: 17
#     operand: 18
# 15. exists
#     core type: Literal
#     sub-expressions:
# 16. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 25\n    body: 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 34\n    body: 20
# 19. {P(y_{1}, ..y_{_a}.., y_{n}) if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. {P(x_{1}, ..x_{_a}.., x_{n}) => alpha if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 21. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 33
#     operands: 25
# 22. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operands: 25
# 23. P(x_{1}, ..x_{_a}.., x_{n}) => alpha
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 28
#     operands: 34
# 25. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. =>
#     core type: Literal
#     sub-expressions:
# 27. (P(x_{1}, ..x_{_a}.., x_{n}), alpha)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. Q
#     core type: Variable
#     sub-expressions:
# 29. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 39
#     end_index: 40
# 30. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. alpha
#     core type: Variable
#     sub-expressions:
# 32. _a -> y_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 35
# 33. P
#     core type: Variable
#     sub-expressions:
# 34. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 35. y_{_a}
#     core type: IndexedVar
# variable: 37
# index: 43
# 36. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 39
#     end_index: 40
# 37. y
#     core type: Variable
#     sub-expressions:
# 38. _a -> x_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 41
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
# 41. x_{_a}
#     core type: IndexedVar
# variable: 42
# index: 43
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. _a
#     core type: Variable
#     sub-expressions:
