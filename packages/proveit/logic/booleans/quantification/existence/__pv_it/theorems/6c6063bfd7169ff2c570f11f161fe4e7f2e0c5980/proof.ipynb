# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.logic.booleans.quantification.existence.theorems.6c6063bfd7169ff2c570f11f161fe4e7f2e0c5980_step0">0</a></td><td>theorem</td><td></td><td><span style="font-size:20px;"> <a class="ProveItLink" href="../../../_theory_nbs_/proofs/exists_not_implies_not_forall/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../ab32103985cc6fecd0b50d8583fa53948752b08a0/expr.ipynb"><img src="../ab32103985cc6fecd0b50d8583fa53948752b08a0/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# <tr><td>&nbsp;</td><td colspan=4 style-"text-align:left"><a class="ProveItLink" href="../../../_theory_nbs_/proofs/exists_not_implies_not_forall/thm_proof.ipynb">proveit.logic.booleans.quantification.existence.exists_not_implies_not_forall</a></td></tr></table>
