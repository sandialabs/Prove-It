# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.existence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Implies, Not
from proveit.logic.booleans.quantification import general_exists_Px_st_Qx, general_forall__Py_not_T__st_Qy

# %%
# build up the expression from sub-expressions
expr = Implies(general_exists_Px_st_Qx, Not(general_forall__Py_not_T__st_Qy))
# Out:
# expr: [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] => [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\exists_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow (\lnot \left[\forall_{y_{1}, \ldots, y_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(P(y_{1}, \ldots, y_{n}) \neq \top\right)\right])

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] => [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. exists_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. [not](forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE))
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 15\n   body: 9
# 7. not
#    core type: Literal
#    sub-expressions:
# 8. forall_{y_{1}, ..y_{_a}.., y_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (P(y_{1}, ..y_{_a}.., y_{n}) != TRUE)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. (y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 27\n    body: 14
# 12. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 26
#     operands: 15
# 13. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operands: 15
# 14. {P(y_{1}, ..y_{_a}.., y_{n}) != TRUE if Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. P(y_{1}, ..y_{_a}.., y_{n}) != TRUE
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operands: 27
# 18. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 31
#     end_index: 32
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (P(y_{1}, ..y_{_a}.., y_{n}), TRUE)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. _a -> x_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 25
# 23. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. TRUE
#     core type: Literal
#     sub-expressions:
# 25. x_{_a}
#     core type: IndexedVar
# variable: 28
# index: 35
# 26. P
#     core type: Variable
#     sub-expressions:
# 27. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 30. _a -> y_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 33
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. y_{_a}
#     core type: IndexedVar
# variable: 34
# index: 35
# 34. y
#     core type: Variable
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
