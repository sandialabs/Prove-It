# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">universality</a>.<a class="ProveItLink" href="../../theorems.ipynb#forall_with_conditions__is_bool">forall_with_conditions__is_bool</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import Conditional
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n
from proveit.logic.booleans.quantification.universality  import forall_in_bool

# %%
# %proving forall_with_conditions__is_bool
# Out:
# forall_with_conditions__is_bool: forall_{n in NaturalPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]

# %%
defaults.assumptions = forall_with_conditions__is_bool.conditions
# Out:
# defaults.assumptions: (n in NaturalPos)

# %%
forall_in_bool
# Out:
# |- forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]

# %%
forall_in_bool.instantiate({P__x_1_to_n: Conditional(P__x_1_to_n, Q__x_1_to_n)})
# Out:
# {n in NaturalPos} |- [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]
# 1	instantiation	2, 8, 3	{n in NaturalPos} |- [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
# 	n : n, P(x_{1}, ..x_{_a}.., x_{n}) : {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
# 2	axiom		|- forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]
# 	proveit.logic.booleans.quantification.universality.forall_in_bool
# 3	instantiation	4, 5	{n in NaturalPos} |- |(x_{1}, ..x_{a}.., x_{n})| = |(1, ..k.., n)|
# 	i : n, f(_a) : x_{_a}
# 4	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 5	instantiation	6, 7, 8	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 6	conjecture		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 7	conjecture		|- NaturalPos proper_subset Natural
# 8	assumption		{n in NaturalPos} |- n in NaturalPos
