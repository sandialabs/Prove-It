# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantification</a>.<a class="ProveItLink" href="../../theory.ipynb">universality</a>.<a class="ProveItLink" href="../../theorems.ipynb#forall_with_conditions__is_bool">forall_with_conditions__is_bool</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import Conditional
from proveit.core_expr_types import P__x_1_to_n, Q__x_1_to_n
from proveit.logic.booleans.quantification.universality  import forall_in_bool

# %%
# %proving forall_with_conditions__is_bool
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="forall_with_conditions__is_bool">forall_with_conditions__is_bool:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d42b753fcefcfd265695a2128485c3198523abda0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ac94b83bb6bc492fb94e5821826f4d934a11c9c10/dependencies.ipynb">dependencies</a>)<br>
# forall_with_conditions__is_bool may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = forall_with_conditions__is_bool.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_forall_with_conditions__is_bool/aeeb89774b5bbb442a5379552cb8d33d88ef64410/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
forall_in_bool
# Out:
# |- forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, x_{2}, ..., x_{n}} P(x_{1}, x_{2}, ..., x_{n})] in BOOLEAN)]

# %%
forall_in_bool.instantiate({P__x_1_to_n: Conditional(P__x_1_to_n, Q__x_1_to_n)})
# Out:
# {n in NaturalPos} |- [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] in BOOLEAN

# %%
# %qed
# Out:
# proveit.logic.booleans.quantification.universality.forall_with_conditions__is_bool has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in NaturalPos} [forall_{P, Q} ([forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] in BOOLEAN)]
# 1	instantiation	2, 8, 3	{n in NaturalPos} |- [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} P(x_{1}, x_{2}, ..., x_{n})] in BOOLEAN
# 	n : n, P(x_{1}, x_{2}, ..., x_{n}) : {P(x_{1}, x_{2}, ..., x_{n}) if Q(x_{1}, x_{2}, ..., x_{n}).
# 2	axiom		|- forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, x_{2}, ..., x_{n}} P(x_{1}, x_{2}, ..., x_{n})] in BOOLEAN)]
# 	proveit.logic.booleans.quantification.universality.forall_in_bool
# 3	instantiation	4, 5	{n in NaturalPos} |- |(x_{1}, x_{2}, ..., x_{n})| = |(1, 2, ..., n)|
# 	i : n, f(_a) : x_{_a}
# 4	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 5	instantiation	6, 7, 8	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 6	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 7	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 8	assumption		{n in NaturalPos} |- n in NaturalPos
