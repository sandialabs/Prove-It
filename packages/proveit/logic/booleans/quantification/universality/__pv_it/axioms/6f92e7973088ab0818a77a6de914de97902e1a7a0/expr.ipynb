# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Boolean, InSet
from proveit.logic.booleans.quantification import general_forall_Px

# %%
# build up the expression from sub-expressions
expr = InSet(general_forall_Px, Boolean)
# Out:
# expr: [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameters: 9\n   body: 7
# 7. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 10. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. _a -> x_{_a}
#     core type: Lambda
#     parameter: 16
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. x_{_a}
#     core type: IndexedVar
# variable: 15
# index: 16
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. _a
#     core type: Variable
#     sub-expressions:
