# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, k, n, x
from proveit.core_expr_types import Len
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(a, IndexedVar(x, a), one, n)]), Len([ExprRange(k, k, one, n)]))
# Out:
# expr: (|(x_{1}, ..x_{a}.., x_{n})|, |(1, ..k.., n)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(x_{1}, \ldots, x_{n}\right)|, |\left(1, \ldots, n\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(x_{1}, ..x_{a}.., x_{n})|, |(1, ..k.., n)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(x_{1}, ..x_{a}.., x_{n})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., n)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((x_{1}, ..x_{a}.., x_{n}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., n))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x_{1}, ..x_{a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., n)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. x_{1}, ..x_{a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. 1, ..k.., n
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. a -> x_{a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. x_{a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
