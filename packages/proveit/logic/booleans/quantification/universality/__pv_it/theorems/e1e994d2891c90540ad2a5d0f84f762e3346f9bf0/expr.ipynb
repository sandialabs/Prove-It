# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Q, R, m, n
from proveit.logic import And, Forall, Implies, InSet
from proveit.logic.booleans.quantification import general_bundled_forall_Pxy_if_Qx, general_nested_forall_Pxy_if_Qx
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P, Q, R], Implies(general_bundled_forall_Pxy_if_Qx, general_nested_forall_Pxy_if_Qx).with_wrapping_at(1)), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))
# Out:
# expr: {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]) if m in NaturalPos ,  n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}~|~Q(x_{1}, \ldots, x_{m}), R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right] \\  \Rightarrow \left[\forall_{x_{1}, \ldots, x_{m}~|~Q(x_{1}, \ldots, x_{m})}~\left[\forall_{y_{1}, \ldots, y_{n}~|~R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right]\right] \end{array}\right) \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]])
#    core type: Operation
#    operator: 25
#    operand: 3
# 2. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 23
#    operands: 4
# 3. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]])
#    core type: Lambda
#    parameters: 5\n   body: 6
# 4. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 34, 30, 35
# 6. [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. m in NaturalPos
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. n in NaturalPos
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 40, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 43, 16
# 14. forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 25
#     operand: 17
# 15. forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 25
#     operand: 18
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 19
# 18. (x_{1}, ..x_{_a}.., x_{m}) -> {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Lambda
#     parameters: 31\n    body: 20
# 19. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 32
#     condition: 21
# 20. {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Conditional
#     value: 22
#     condition: 27
# 21. Q(x_{1}, ..x_{_a}.., x_{m}) and R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 25
#     operand: 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 33
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. (y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 28\n    body: 29
# 27. Q(x_{1}, ..x_{_a}.., x_{m})
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 29. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. Q
#     core type: Variable
#     sub-expressions:
# 31. (x_{1}, ..x_{_a}.., x_{m})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 34
#     operands: 36
# 33. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. P
#     core type: Variable
#     sub-expressions:
# 35. R
#     core type: Variable
#     sub-expressions:
# 36. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 42
#     end_index: 40
# 38. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 39. _a -> x_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 44
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. _a -> y_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 45
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. x_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 45. y_{_a}
#     core type: IndexedVar
# variable: 47
# index: 48
# 46. x
#     core type: Variable
#     sub-expressions:
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. _a
#     core type: Variable
#     sub-expressions:
