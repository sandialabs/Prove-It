# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, P, n
from proveit.core_expr_types import P__x_1_to_n, P__x_1_to_np1, x_1_to_n, x_1_to_np1
from proveit.logic import Forall, Implies
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Function(P, []), Forall([n], Implies(Forall([x_1_to_n], P__x_1_to_n), Forall([x_1_to_np1], P__x_1_to_np1)).with_wrapping_at(2), domains = [Natural]))
# Out:
# expr: (P(), forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P(), \forall_{n \in \mathbb{N}}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right] \Rightarrow  \\ \left[\forall_{x_{1}, \ldots, x_{n + 1}}~P(x_{1}, \ldots, x_{n + 1})\right] \end{array}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P(), forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P()
#    core type: Operation
#    operator: 21
#    operands: 3
# 2. forall_{n in Natural} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})])
#    core type: Operation
#    operator: 16
#    operand: 4
# 3. ()
#    core type: ExprTuple
#    sub-expressions:
# 4. n -> {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#    core type: Lambda
#    parameter: 32
#    body: 5
# 5. {[forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})] if n in Natural.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] =>  \\ [forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. n in Natural
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}), forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 14
# 12. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 16
#     operand: 15
# 13. forall_{x_{1}, ..x_{_a}.., x_{n + 1}} P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. Natural
#     core type: Literal
#     sub-expressions:
# 15. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Lambda
#     parameters: 20\n    body: 18
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, ..x_{_a}.., x_{n + 1}) -> P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Lambda
#     parameters: 22\n    body: 19
# 18. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operands: 20
# 19. P(x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. P
#     core type: Variable
#     sub-expressions:
# 22. (x_{1}, ..x_{_a}.., x_{n + 1})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 33
#     end_index: 32
# 24. x_{1}, ..x_{_a}.., x_{n + 1}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 33
#     end_index: 26
# 25. _a -> x_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 27
# 26. n + 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. x_{_a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
# 33. 1
#     core type: Literal
#     sub-expressions:
