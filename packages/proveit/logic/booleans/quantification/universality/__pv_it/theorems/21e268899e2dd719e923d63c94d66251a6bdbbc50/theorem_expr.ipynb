# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unbundle">unbundle</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.booleans.quantification.universality import unbundle

# %%
# check that the built expression is the same as the stored expression
assert unbundle.expr == stored_expr
assert unbundle.expr._style_id == stored_expr._style_id
print("Passed sanity check: unbundle matches stored_expr")
# Out:
# Passed sanity check: unbundle matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(unbundle.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}^+}~\left[\forall_{P, Q, R}~\left(\begin{array}{c} \left[\forall_{x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n}~|~Q(x_{1}, \ldots, x_{m}), R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right] \\  \Rightarrow \left[\forall_{x_{1}, \ldots, x_{m}~|~Q(x_{1}, \ldots, x_{m})}~\left[\forall_{y_{1}, \ldots, y_{n}~|~R(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})}~P(x_{1}, \ldots, x_{m}, y_{1}, \ldots, y_{n})\right]\right] \end{array}\right)\right]

# %%
# display the expression information
unbundle.expr_info()
# Out:
# 0. forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]])]
#    core type: Operation
#    operator: 28
#    operand: 1
# 1. (m, n) -> {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]) if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n)
#    core type: ExprTuple
#    sub-expressions: 43, 46
# 3. {forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{P, Q, R} ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]])
#    core type: Operation
#    operator: 28
#    operand: 6
# 5. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 26
#    operands: 7
# 6. (P, Q, R) -> ([forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]])
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (P, Q, R)
#    core type: ExprTuple
#    sub-expressions: 37, 33, 38
# 9. [forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})] \\  => [forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]]
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. m in NaturalPos
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. n in NaturalPos
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}), forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})])
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 43, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 46, 19
# 17. forall_{x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n} | Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operand: 20
# 18. forall_{x_{1}, ..x_{_a}.., x_{m} | Q(x_{1}, ..x_{_a}.., x_{m})} [forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 28
#     operand: 21
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 39\n    body: 22
# 21. (x_{1}, ..x_{_a}.., x_{m}) -> {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Lambda
#     parameters: 34\n    body: 23
# 22. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}) ,  R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 35
#     condition: 24
# 23. {forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if Q(x_{1}, ..x_{_a}.., x_{m}).
#     core type: Conditional
#     value: 25
#     condition: 30
# 24. Q(x_{1}, ..x_{_a}.., x_{m}) and R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. forall_{y_{1}, ..y_{_a}.., y_{n} | R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operand: 29
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (Q(x_{1}, ..x_{_a}.., x_{m}), R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 36
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. (y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 31\n    body: 32
# 30. Q(x_{1}, ..x_{_a}.., x_{m})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 32. {P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}) if R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 35
#     condition: 36
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. (x_{1}, ..x_{_a}.., x_{m})
#     core type: ExprTuple
#     sub-expressions: 40
# 35. P(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 39
# 36. R(x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. P
#     core type: Variable
#     sub-expressions:
# 38. R
#     core type: Variable
#     sub-expressions:
# 39. (x_{1}, ..x_{_a}.., x_{m}, y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 45
#     end_index: 43
# 41. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 45
#     end_index: 46
# 42. _a -> x_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 47
# 43. m
#     core type: Variable
#     sub-expressions:
# 44. _a -> y_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 48
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. x_{_a}
#     core type: IndexedVar
# variable: 49
# index: 51
# 48. y_{_a}
#     core type: IndexedVar
# variable: 50
# index: 51
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. y
#     core type: Variable
#     sub-expressions:
# 51. _a
#     core type: Variable
#     sub-expressions:
