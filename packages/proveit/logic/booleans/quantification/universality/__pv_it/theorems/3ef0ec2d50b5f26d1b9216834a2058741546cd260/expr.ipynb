# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Q, n
from proveit.logic import Boolean, Forall, InSet
from proveit.logic.booleans.quantification import general_forall_Px_if_Qx
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([P, Q], InSet(general_forall_Px_if_Qx, Boolean)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{P, Q}~\left(\left[\forall_{x_{1}, \ldots, x_{n}~|~Q(x_{1}, \ldots, x_{n})}~P(x_{1}, \ldots, x_{n})\right] \in \mathbb{B}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. n -> {forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN) if n in NaturalPos.
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. {forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, Q} ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Operation
#    operator: 14
#    operand: 5
# 4. n in NaturalPos
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (P, Q) -> ([forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 25, 9
# 7. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 19, 20
# 8. [forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n}), BOOLEAN)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. forall_{x_{1}, ..x_{_a}.., x_{n} | Q(x_{1}, ..x_{_a}.., x_{n})} P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. BOOLEAN
#     core type: Literal
#     sub-expressions:
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (x_{1}, ..x_{_a}.., x_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Lambda
#     parameters: 21\n    body: 16
# 16. {P(x_{1}, ..x_{_a}.., x_{n}) if Q(x_{1}, ..x_{_a}.., x_{n}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 17. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 19
#     operands: 21
# 18. Q(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. Q
#     core type: Variable
#     sub-expressions:
# 21. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 22. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 23. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 26
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. x_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
