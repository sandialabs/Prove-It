# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.booleans.quantification.universality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import P__x_1_to_n, x_1_to_n
from proveit.logic import Forall
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([x_1_to_n], P__x_1_to_n), domains = [Natural])
# Out:
# expr: forall_{n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{x_{1}, \ldots, x_{n}}~P(x_{1}, \ldots, x_{n})\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Lambda
#    parameters: 12\n   body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 9. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. _a -> x_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. x_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
