# %% [markdown]
# Theorems for the theory of <a href="_theory_.ipynb" class="ProveItLink">proveit.logic.booleanss.quantification</a>
# ========

# %%
import proveit
# Automation is not needed when building theorem expressions:
proveit.defaults.automation = False # This will speed things up.
# %begin theorems
# Out:
# Defining theorems for theory 'proveit.logic.booleanss.quantification'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
# %end theorems
# Out:
# Theory proveit.logic.booleanss.quantification has no theorems
