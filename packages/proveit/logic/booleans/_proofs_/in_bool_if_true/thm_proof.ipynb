# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#in_bool_if_true">in_bool_if_true</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A
from proveit.logic.booleans._theorems_ import true_is_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving in_bool_if_true

# %%
true_is_bool

# %%
AeqT = A.evaluation([A])

# %%
AeqT.sub_left_side_into(true_is_bool)

# %%
# %qed
