# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">booleans</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#in_bool_if_false">in_bool_if_false</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A
from proveit.logic import Not
from proveit.logic.booleans._theorems_ import false_is_bool
theory = proveit.Theory() # the theorem's theory

# %%
# %proving in_bool_if_false

# %%
# %qed # proven via automation
