# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonmembership_equiv">nonmembership_equiv</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.unification import nonmembership_equiv

# %%
# check that the built expression is the same as the stored expression
assert nonmembership_equiv.expr == stored_expr
assert nonmembership_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonmembership_equiv matches stored_expr")
# Out:
# Passed sanity check: nonmembership_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonmembership_equiv.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{x, A_{1}, \ldots, A_{m}}~\left(\left(x \notin \left(A_{1} \cup \ldots \cup A_{m}\right)\right) = \left(\left(x \notin A_{1}\right) \land \ldots \land \left(x \notin A_{m}\right)\right)\right)\right]

# %%
# display the expression information
nonmembership_equiv.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))) if m in NaturalPos.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})))
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 9. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 32, 24
# 10. (x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x not-in (A_{1} union ..A_{_a}.. union A_{m}), (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#     core type: Operation
#     operator: 29
#     operands: 16
# 15. (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 32, 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 27
#     end_index: 28
# 21. union
#     core type: Literal
#     sub-expressions:
# 22. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 36
#     body: 25
# 24. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. x not-in A_{i}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. _a -> A_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 31
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. m
#     core type: Variable
#     sub-expressions:
# 29. not-in
#     core type: Literal
#     sub-expressions:
# 30. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. A_{_a}
#     core type: IndexedVar
# variable: 35
# index: 34
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. A_{i}
#     core type: IndexedVar
# variable: 35
# index: 36
# 34. _a
#     core type: Variable
#     sub-expressions:
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
