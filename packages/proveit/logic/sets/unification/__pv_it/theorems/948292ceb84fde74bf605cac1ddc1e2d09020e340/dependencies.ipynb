# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#membership_unfolding">membership_unfolding</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/membership_unfolding/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.unification import membership_unfolding

# %%
# %dependencies membership_unfolding
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon membership_unfolding</h3>
