# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Forall, InSet, Union
from proveit.logic.sets import x_in_any_A
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, A_1_to_m], InSet(x, Union(A_1_to_m)), condition = x_in_any_A), InSet(m, NaturalPos))
# Out:
# expr: {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)}~\left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalPos
#    core type: Operation
#    operator: 24
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 23, 8
# 6. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 27, 19
# 7. {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. x in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 24
#    operands: 11
# 10. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 27, 14
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 22
#     end_index: 23
# 16. union
#     core type: Literal
#     sub-expressions:
# 17. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 31
#     body: 20
# 19. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. x in A_{i}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. _a -> A_{_a}
#     core type: Lambda
#     parameter: 29
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. m
#     core type: Variable
#     sub-expressions:
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. A_{_a}
#     core type: IndexedVar
# variable: 30
# index: 29
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. A_{i}
#     core type: IndexedVar
# variable: 30
# index: 31
# 29. _a
#     core type: Variable
#     sub-expressions:
# 30. A
#     core type: Variable
#     sub-expressions:
# 31. i
#     core type: Variable
#     sub-expressions:
