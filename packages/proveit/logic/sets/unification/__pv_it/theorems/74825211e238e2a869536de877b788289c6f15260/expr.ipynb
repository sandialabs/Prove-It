# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, m, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Forall, InSet, Union
from proveit.logic.sets import x_in_any_A
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Forall([x, A_1_to_m], InSet(x, Union(A_1_to_m)), condition = x_in_any_A), InSet(m, NaturalPos)))
# Out:
# expr: m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{\forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)}~\left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})} (x in (A_{1} union ..A_{_a}.. union A_{m}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. m in NaturalPos
#    core type: Operation
#    operator: 25
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 7. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 28, 20
# 8. {x in (A_{1} union ..A_{_a}.. union A_{m}) if (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. x in (A_{1} union ..A_{_a}.. union A_{m})
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 28, 15
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. union
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 32
#     body: 21
# 20. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. x in A_{i}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> A_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. A_{_a}
#     core type: IndexedVar
# variable: 31
# index: 30
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. A_{i}
#     core type: IndexedVar
# variable: 31
# index: 32
# 30. _a
#     core type: Variable
#     sub-expressions:
# 31. A
#     core type: Variable
#     sub-expressions:
# 32. i
#     core type: Variable
#     sub-expressions:
