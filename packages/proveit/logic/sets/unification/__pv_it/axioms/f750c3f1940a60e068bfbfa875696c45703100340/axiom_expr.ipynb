# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#union_all_def">union_all_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.unification import union_all_def

# %%
# check that the built expression is the same as the stored expression
assert union_all_def.expr == stored_expr
assert union_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: union_all_def matches stored_expr")
# Out:
# Passed sanity check: union_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, S_{2}, \ldots, S_{n}, Q, R, x}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcup_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~R\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right]\right) \\  = \left[\exists_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~\left(x \in R\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right)\right] \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x} ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))])]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x} ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x} ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 49
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 49
# 4. {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x} ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x} ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))])
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 45
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((S_{1}, S_{2}, ..., S_{n}, Q, R, x) -> ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 49, 11
# 10. (S_{1}, S_{2}, ..., S_{n}, Q, R, x) -> ((x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))])
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (S_{1}, S_{2}, ..., S_{n}, Q, R, x)
#     core type: ExprTuple
#     sub-expressions: 14, 41, 37, 33
# 13. (x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. S_{1}, S_{2}, ..., S_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 48
#     end_index: 49
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})], exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. _a -> S_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 50
# 18. x in [union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]
#     core type: Operation
#     operator: 45
#     operands: 20
# 19. exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. (x, union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 23
# 21. exists
#     core type: Literal
#     sub-expressions:
# 22. ((y_{1}, y_{2}, ..., y_{n}) -> {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. union_of_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 25
#     operand: 28
# 24. (y_{1}, y_{2}, ..., y_{n}) -> {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 42\n    body: 27
# 25. union_of_all
#     core type: Literal
#     sub-expressions:
# 26. ((y_{1}, y_{2}, ..., y_{n}) -> {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 29
#     condition: 32
# 28. (y_{1}, y_{2}, ..., y_{n}) -> {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 42\n    body: 30
# 29. x in R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 45
#     operands: 31
# 30. {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 34
#     condition: 32
# 31. (x, R(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 42
# 35. and
#     core type: Literal
#     sub-expressions:
# 36. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. R
#     core type: Variable
#     sub-expressions:
# 38. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 48
#     end_index: 49
# 39. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 41
#     operands: 42
# 40. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 43
# 41. Q
#     core type: Variable
#     sub-expressions:
# 42. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 43. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 44. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 51, 50
# 47. _a -> y_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 51
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. S_{_a}
#     core type: IndexedVar
# variable: 52
# index: 55
# 51. y_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 52. S
#     core type: Variable
#     sub-expressions:
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
