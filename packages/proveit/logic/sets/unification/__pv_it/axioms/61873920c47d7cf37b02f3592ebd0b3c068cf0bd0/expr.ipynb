# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Equals, InSet, Union
from proveit.logic.sets import x_in_any_A

# %%
# build up the expression from sub-expressions
expr = Lambda([x, A_1_to_m], Equals(InSet(x, Union(A_1_to_m)), x_in_any_A).with_wrapping_at(2))
# Out:
# expr: (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, A_{1}, \ldots, A_{m}\right) \mapsto \left(\begin{array}{c} \left(x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right) =  \\ \left(\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right)\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 23, 15
# 2. (x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x in (A_{1} union ..A_{_a}.. union A_{m}), (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x, A_{1} union ..A_{_a}.. union A_{m})
#    core type: ExprTuple
#    sub-expressions: 23, 10
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 18
#     end_index: 19
# 12. union
#     core type: Literal
#     sub-expressions:
# 13. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 27
#     body: 16
# 15. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. x in A_{i}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. _a -> A_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. A_{_a}
#     core type: IndexedVar
# variable: 26
# index: 25
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. A_{i}
#     core type: IndexedVar
# variable: 26
# index: 27
# 25. _a
#     core type: Variable
#     sub-expressions:
# 26. A
#     core type: Variable
#     sub-expressions:
# 27. i
#     core type: Variable
#     sub-expressions:
