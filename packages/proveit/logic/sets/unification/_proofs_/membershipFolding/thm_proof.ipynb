# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">unification</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#membershipFolding">membershipFolding</a> theorem
# ========
# *** see <a href="../__pv_it/709fc20852943228921ca5b87c9e3d9f188037870/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving membershipFolding
