# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SetOfAll.html">SetOfAll</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import NotEquals, SetOfAll
from proveit.numbers import Integer, Real, frac, zero

# %%
# build up the expression from sub-expressions
expr = SetOfAll([a, b], frac(a, b), domains = [Integer, Real], condition = NotEquals(b, zero))
# Out:
# expr: {(a / b) s.t. b != 0}_{a in Integer, b in Real}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\frac{a}{b}~|~b \neq 0\right\}_{a \in \mathbb{Z}, b \in \mathbb{R}}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a / b) s.t. b != 0}_{a in Integer, b in Real}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. SetOfAll
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {a / b if a in Integer ,  b in Real ,  b != 0.
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {a / b if a in Integer ,  b in Real ,  b != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. a / b
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integer) and (b in Real) and (b != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (a, b)
#    core type: ExprTuple
#    sub-expressions: 18, 21
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integer, b in Real, b != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 10. a in Integer
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. b in Real
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. b != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (b, 0)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. Real
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 0
#     core type: Literal
#     sub-expressions:
