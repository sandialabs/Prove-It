# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Q__x_1_to_n, R__x_1_to_n, S_1_to_n, f__x_1_to_n, x_1_to_n
from proveit.logic import Forall, Implies, SetOfAll, SubsetEq
from proveit.logic.sets import general_comprehension_fyn

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
sub_expr2 = [S_1_to_n]
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Q__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), SubsetEq(SetOfAll(instance_param_or_params = sub_expr1, instance_element = f__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), general_comprehension_fyn).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left\{f\left(x_{1}, x_{2}, \ldots, x_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right\}_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)} \subseteq  \\ \left\{f\left(y_{1}, y_{2}, \ldots, y_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right\}_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)} \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n}), {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. subset_eq
#    core type: Literal
#    sub-expressions:
# 8. ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}, {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#    core type: Lambda
#    parameters: 35\n   body: 12
# 10. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}
#     core type: Operation
#     operator: 14
#     operand: 17
# 11. {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 16
#     condition: 22
# 13. ((x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. SetOfAll
#     core type: Literal
#     sub-expressions:
# 15. ((y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 37
#     operands: 35
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 35\n    body: 19
# 18. (y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 38\n    body: 20
# 19. {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 24
# 21. f(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 26
#     operands: 35
# 22. (x_{1} in S_{1}) and  (x_{2} in S_{2}) and  ... and  (x_{n} in S_{n}) and R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 27
#     operands: 25
# 23. f(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 26
#     operands: 38
# 24. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. ((x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. (x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 48
#     end_index: 49
# 30. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 48
#     end_index: 49
# 32. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. _a -> (x_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 39
# 34. R
#     core type: Variable
#     sub-expressions:
# 35. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 57
#     body: 41
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 39. x_{_a} in S_{_a}
#     core type: Operation
#     operator: 45
#     operands: 43
# 40. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 48
#     end_index: 49
# 41. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 48
#     end_index: 49
# 43. (x_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 44. _a -> x_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 50
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 47. _a -> y_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 52
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
# 50. x_{_a}
#     core type: IndexedVar
# variable: 53
# index: 57
# 51. S_{_a}
#     core type: IndexedVar
# variable: 54
# index: 57
# 52. y_{_a}
#     core type: IndexedVar
# variable: 55
# index: 57
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. S
#     core type: Variable
#     sub-expressions:
# 55. y
#     core type: Variable
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
