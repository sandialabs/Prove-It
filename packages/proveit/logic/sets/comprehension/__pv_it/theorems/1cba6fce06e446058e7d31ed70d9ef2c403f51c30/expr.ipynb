# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types import Q__x_1_to_n, R__x_1_to_n, S_1_to_n, f__x_1_to_n, x_1_to_n
from proveit.logic import Forall, SetOfAll, SubsetEq
from proveit.logic.sets import general_comprehension_fyn

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
sub_expr2 = [S_1_to_n]
expr = ExprTuple(Forall(instance_param_or_params = sub_expr1, instance_expr = Q__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), SubsetEq(SetOfAll(instance_param_or_params = sub_expr1, instance_element = f__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), general_comprehension_fyn).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right), \begin{array}{c} \begin{array}{l} \left\{f\left(x_{1}, x_{2}, \ldots, x_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right\}_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)} \subseteq  \\ \left\{f\left(y_{1}, y_{2}, \ldots, y_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right\}_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)} \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n}), {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}, {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#    core type: Lambda
#    parameters: 33\n   body: 10
# 8. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 14
#     condition: 20
# 11. ((x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. SetOfAll
#     core type: Literal
#     sub-expressions:
# 13. ((y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 35
#     operands: 33
# 15. (x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 33\n    body: 17
# 16. (y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 18
# 17. {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. f(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 24
#     operands: 33
# 20. (x_{1} in S_{1}) and  (x_{2} in S_{2}) and  ... and  (x_{n} in S_{n}) and R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 25
#     operands: 23
# 21. f(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 24
#     operands: 36
# 22. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. ((x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. (x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 46
#     end_index: 47
# 28. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 46
#     end_index: 47
# 30. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. _a -> (x_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 37
# 32. R
#     core type: Variable
#     sub-expressions:
# 33. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 39
# 35. Q
#     core type: Variable
#     sub-expressions:
# 36. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. x_{_a} in S_{_a}
#     core type: Operation
#     operator: 43
#     operands: 41
# 38. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 46
#     end_index: 47
# 39. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 41. (x_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 42. _a -> x_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 48
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 50, 49
# 45. _a -> y_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 50
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. n
#     core type: Variable
#     sub-expressions:
# 48. x_{_a}
#     core type: IndexedVar
# variable: 51
# index: 55
# 49. S_{_a}
#     core type: IndexedVar
# variable: 52
# index: 55
# 50. y_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. S
#     core type: Variable
#     sub-expressions:
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
