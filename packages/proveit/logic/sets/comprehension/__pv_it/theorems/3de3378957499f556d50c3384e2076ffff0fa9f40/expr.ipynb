# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Q, R, f, n
from proveit.core_expr_types import Q__x_1_to_n, R__x_1_to_n, S_1_to_n, f__x_1_to_n, x_1_to_n
from proveit.logic import Forall, Implies, InSet, SetOfAll, SubsetEq
from proveit.logic.sets import general_comprehension_fyn
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
sub_expr2 = [S_1_to_n]
expr = Conditional(Forall(instance_param_or_params = [f, Q, R, S_1_to_n], instance_expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Q__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), SubsetEq(SetOfAll(instance_param_or_params = sub_expr1, instance_element = f__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), general_comprehension_fyn).with_wrapping_at(2)).with_wrapping_at(2)), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{f, Q, R, S_{1}, S_{2}, \ldots, S_{n}}~\left(\begin{array}{c} \begin{array}{l} \left[\forall_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left\{f\left(x_{1}, x_{2}, \ldots, x_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right\}_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)} \subseteq  \\ \left\{f\left(y_{1}, y_{2}, \ldots, y_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right\}_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)} \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{f, Q, R, S_{1}, S_{2}, ..., S_{n}} ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f, Q, R, S_{1}, S_{2}, ..., S_{n}} ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}))
#    core type: Operation
#    operator: 15
#    operand: 5
# 2. n in NaturalPos
#    core type: Operation
#    operator: 55
#    operands: 4
# 3. ((f, Q, R, S_{1}, S_{2}, ..., S_{n}) -> ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 59, 6
# 5. (f, Q, R, S_{1}, S_{2}, ..., S_{n}) -> ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. (f, Q, R,S_{1}, S_{2}, ..., S_{n})
#    core type: ExprTuple
#    sub-expressions: 36, 47, 44, 9
# 8. [forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. S_{1}, S_{2}, ..., S_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 58
#    end_index: 59
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n}), {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. _a -> S_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 61
# 13. forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 15
#     operand: 19
# 14. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. subset_eq
#     core type: Literal
#     sub-expressions:
# 18. ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}, {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. (x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 45\n    body: 22
# 20. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}
#     core type: Operation
#     operator: 24
#     operand: 27
# 21. {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#     core type: Operation
#     operator: 24
#     operand: 28
# 22. {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 26
#     condition: 32
# 23. ((x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. SetOfAll
#     core type: Literal
#     sub-expressions:
# 25. ((y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 47
#     operands: 45
# 27. (x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 45\n    body: 29
# 28. (y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 48\n    body: 30
# 29. {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 31. f(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 36
#     operands: 45
# 32. (x_{1} in S_{1}) and  (x_{2} in S_{2}) and  ... and  (x_{n} in S_{n}) and R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 37
#     operands: 35
# 33. f(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 48
# 34. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. ((x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. f
#     core type: Variable
#     sub-expressions:
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. (x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 58
#     end_index: 59
# 40. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 58
#     end_index: 59
# 42. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. _a -> (x_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 67
#     body: 49
# 44. R
#     core type: Variable
#     sub-expressions:
# 45. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 50
# 46. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 67
#     body: 51
# 47. Q
#     core type: Variable
#     sub-expressions:
# 48. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 49. x_{_a} in S_{_a}
#     core type: Operation
#     operator: 55
#     operands: 53
# 50. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 58
#     end_index: 59
# 51. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 58
#     end_index: 59
# 53. (x_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 54. _a -> x_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 60
# 55. in
#     core type: Literal
#     sub-expressions:
# 56. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 57. _a -> y_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 62
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. x_{_a}
#     core type: IndexedVar
# variable: 63
# index: 67
# 61. S_{_a}
#     core type: IndexedVar
# variable: 64
# index: 67
# 62. y_{_a}
#     core type: IndexedVar
# variable: 65
# index: 67
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. S
#     core type: Variable
#     sub-expressions:
# 65. y
#     core type: Variable
#     sub-expressions:
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. _a
#     core type: Variable
#     sub-expressions:
