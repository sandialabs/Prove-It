# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Q, R, f
from proveit.core_expr_types import Q__x_1_to_n, R__x_1_to_n, S_1_to_n, f__x_1_to_n, x_1_to_n
from proveit.logic import Forall, Implies, SetOfAll, SubsetEq
from proveit.logic.sets import general_comprehension_fyn

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
sub_expr2 = [S_1_to_n]
expr = ExprTuple(Lambda([f, Q, R, S_1_to_n], Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = Q__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), SubsetEq(SetOfAll(instance_param_or_params = sub_expr1, instance_element = f__x_1_to_n, domains = sub_expr2, condition = R__x_1_to_n), general_comprehension_fyn).with_wrapping_at(2)).with_wrapping_at(2)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(f, Q, R, S_{1}, S_{2}, \ldots, S_{n}\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left[\forall_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)}~Q\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left\{f\left(x_{1}, x_{2}, \ldots, x_{n}\right)~|~R\left(x_{1}, x_{2}, \ldots, x_{n}\right)\right\}_{\left(x_{1} \in S_{1}\right), \left(x_{2} \in S_{2}\right), \ldots, \left(x_{n} \in S_{n}\right)} \subseteq  \\ \left\{f\left(y_{1}, y_{2}, \ldots, y_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right\}_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)} \end{array} \end{array}\right) \end{array} \end{array}\right)\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((f, Q, R, S_{1}, S_{2}, ..., S_{n}) -> ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, Q, R, S_{1}, S_{2}, ..., S_{n}) -> ([forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, Q, R,S_{1}, S_{2}, ..., S_{n})
#    core type: ExprTuple
#    sub-expressions: 31, 42, 39, 4
# 3. [forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})] =>  \\ ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. S_{1}, S_{2}, ..., S_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 53
#    end_index: 54
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n}), {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. _a -> S_{_a}
#    core type: Lambda
#    parameter: 62
#    body: 56
# 8. forall_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}) | R(x_{1}, x_{2}, ..., x_{n})} Q(x_{1}, x_{2}, ..., x_{n})
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})} subset_eq  \\ {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. subset_eq
#     core type: Literal
#     sub-expressions:
# 13. ({f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}, {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. (x_{1}, x_{2}, ..., x_{n}) -> {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 17
# 15. {f(x_{1}, x_{2}, ..., x_{n}) s.t. R(x_{1}, x_{2}, ..., x_{n})}_{(x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})}
#     core type: Operation
#     operator: 19
#     operand: 22
# 16. {f(y_{1}, y_{2}, ..., y_{n}) s.t. Q(y_{1}, y_{2}, ..., y_{n})}_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})}
#     core type: Operation
#     operator: 19
#     operand: 23
# 17. {Q(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 21
#     condition: 27
# 18. ((x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 19. SetOfAll
#     core type: Literal
#     sub-expressions:
# 20. ((y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. Q(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 42
#     operands: 40
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Lambda
#     parameters: 40\n    body: 24
# 23. (y_{1}, y_{2}, ..., y_{n}) -> {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 43\n    body: 25
# 24. {f(x_{1}, x_{2}, ..., x_{n}) if (x_{1} in S_{1}) ,  (x_{2} in S_{2}) ,  ... ,  (x_{n} in S_{n}) ,  R(x_{1}, x_{2}, ..., x_{n}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. {f(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. f(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 31
#     operands: 40
# 27. (x_{1} in S_{1}) and  (x_{2} in S_{2}) and  ... and  (x_{n} in S_{n}) and R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 32
#     operands: 30
# 28. f(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 31
#     operands: 43
# 29. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. ((x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n}), R(x_{1}, x_{2}, ..., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. f
#     core type: Variable
#     sub-expressions:
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. (x_{1} in S_{1}), (x_{2} in S_{2}), ..., (x_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 53
#     end_index: 54
# 35. R(x_{1}, x_{2}, ..., x_{n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 53
#     end_index: 54
# 37. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. _a -> (x_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 62
#     body: 44
# 39. R
#     core type: Variable
#     sub-expressions:
# 40. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 41. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 62
#     body: 46
# 42. Q
#     core type: Variable
#     sub-expressions:
# 43. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. x_{_a} in S_{_a}
#     core type: Operation
#     operator: 50
#     operands: 48
# 45. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 53
#     end_index: 54
# 46. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 48. (x_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 49. _a -> x_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 55
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 52. _a -> y_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 57
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. x_{_a}
#     core type: IndexedVar
# variable: 58
# index: 62
# 56. S_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 57. y_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. S
#     core type: Variable
#     sub-expressions:
# 60. y
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
