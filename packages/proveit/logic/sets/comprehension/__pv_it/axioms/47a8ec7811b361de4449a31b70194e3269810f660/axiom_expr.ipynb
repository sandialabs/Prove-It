# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#comprehension_def">comprehension_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.comprehension</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.comprehension import comprehension_def

# %%
# check that the built expression is the same as the stored expression
assert comprehension_def.expr == stored_expr
assert comprehension_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: comprehension_def matches stored_expr")
# Out:
# Passed sanity check: comprehension_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(comprehension_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, \ldots, S_{n}, Q, f, x}~\left(\begin{array}{c} \left(x \in \left\{f(y_{1}, \ldots, y_{n})~|~Q(y_{1}, \ldots, y_{n})\right\}_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}\right) \\  = \left[\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x = f(y_{1}, \ldots, y_{n})\right)\right] \end{array}\right)\right]

# %%
# display the expression information
comprehension_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 44
#    body: 2
# 2. {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, f, x} ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 40
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x) -> ((x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 44, 10
# 8. (S_{1}, ..S_{_a}.., S_{n}, Q, f, x)
#    core type: ExprTuple
#    sub-expressions: 11, 36, 32, 28
# 9. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}) \\  = [exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 25
#    operands: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. S_{1}, ..S_{_a}.., S_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 43
#     end_index: 44
# 12. (x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}, exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. _a -> S_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 45
# 14. x in {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#     core type: Operation
#     operator: 40
#     operands: 16
# 15. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x = f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. (x, {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}})
#     core type: ExprTuple
#     sub-expressions: 28, 19
# 17. exists
#     core type: Literal
#     sub-expressions:
# 18. (y_{1}, ..y_{_a}.., y_{n}) -> {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 20
# 19. {f(y_{1}, ..y_{_a}.., y_{n}) s.t. Q(y_{1}, ..y_{_a}.., y_{n})}_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}}
#     core type: Operation
#     operator: 21
#     operand: 22
# 20. {x = f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 27
# 21. SetOfAll
#     core type: Literal
#     sub-expressions:
# 22. (y_{1}, ..y_{_a}.., y_{n}) -> {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 37\n    body: 24
# 23. x = f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. {f(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 29
#     condition: 27
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (x, f(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. f(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 32
#     operands: 37
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. f
#     core type: Variable
#     sub-expressions:
# 33. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 43
#     end_index: 44
# 34. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 49
#     body: 38
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 38. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 46, 45
# 42. _a -> y_{_a}
#     core type: Lambda
#     parameter: 49
#     body: 46
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. n
#     core type: Variable
#     sub-expressions:
# 45. S_{_a}
#     core type: IndexedVar
# variable: 47
# index: 49
# 46. y_{_a}
#     core type: IndexedVar
# variable: 48
# index: 49
# 47. S
#     core type: Variable
#     sub-expressions:
# 48. y
#     core type: Variable
#     sub-expressions:
# 49. _a
#     core type: Variable
#     sub-expressions:
