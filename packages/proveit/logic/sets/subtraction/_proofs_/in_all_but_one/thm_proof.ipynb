# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">subtraction</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#in_all_but_one">in_all_but_one</a> theorem
# ========
# *** see <a href="../__pv_it/b1b4ffd6baaa57210b30d83dcaa354021ee7fd9a0/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving in_all_but_one
