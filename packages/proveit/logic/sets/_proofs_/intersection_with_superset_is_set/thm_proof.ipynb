# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#intersection_with_superset_is_set">intersection_with_superset_is_set</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving intersection_with_superset_is_set
