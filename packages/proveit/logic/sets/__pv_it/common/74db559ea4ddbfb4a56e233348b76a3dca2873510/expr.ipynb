# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, S, Variable, n, y
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(R__y_1_to_n, And(ExprRange(sub_expr1, InSet(IndexedVar(y, sub_expr1), IndexedVar(S, sub_expr1)), one, n), Q__y_1_to_n))
# Out:
# expr: {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{R(y_{1}, \ldots, y_{n}) \textrm{ if } y_{1} \in S_{1} ,  \ldots ,  y_{n} \in S_{n} ,  Q(y_{1}, \ldots, y_{n})\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. R(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 3
#    operands: 10
# 2. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. R
#    core type: Variable
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 16
#    end_index: 17
# 7. Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. _a -> (y_{_a} in S_{_a})
#    core type: Lambda
# ...
