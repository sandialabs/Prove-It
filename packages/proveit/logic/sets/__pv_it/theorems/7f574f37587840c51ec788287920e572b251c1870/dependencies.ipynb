# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#set_subset_eq_of_union_with_set">set_subset_eq_of_union_with_set</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/set_subset_eq_of_union_with_set/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets import set_subset_eq_of_union_with_set

# %%
# %dependencies set_subset_eq_of_union_with_set
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove set_subset_eq_of_union_with_set</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../enumeration/_theory_nbs_/proofs/fold/thm_proof.ipynb">proveit.logic.sets.enumeration.fold</a></dt><dd><a class="ProveItLink" href="../../../enumeration/__pv_it/theorems/4b71bfe5d22b9547d17c7ff100fd316b5dbe9cd80/expr.ipynb"><img src="../../../enumeration/__pv_it/theorems/4b71bfe5d22b9547d17c7ff100fd316b5dbe9cd80/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../enumeration/_theory_nbs_/proofs/unfold/thm_proof.ipynb">proveit.logic.sets.enumeration.unfold</a></dt><dd><a class="ProveItLink" href="../../../enumeration/__pv_it/theorems/c0683eda477f9342e88a14bea04d9fca30cabeb60/expr.ipynb"><img src="../../../enumeration/__pv_it/theorems/c0683eda477f9342e88a14bea04d9fca30cabeb60/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
