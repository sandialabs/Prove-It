# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#intersection_is_subset_eq">intersection_is_subset_eq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets import intersection_is_subset_eq

# %%
# check that the built expression is the same as the stored expression
assert intersection_is_subset_eq.expr == stored_expr
assert intersection_is_subset_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: intersection_is_subset_eq matches stored_expr")
# Out:
# Passed sanity check: intersection_is_subset_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intersection_is_subset_eq.latex())
# Out:
# \vdash \forall_{A, B~|~\forall_{x}~\left(\left(x \in B\right) \in \mathbb{B}\right)}~\left(\left(A \cap B\right) \subseteq A\right)

# %%
# display the expression information
intersection_is_subset_eq.expr_info()
# Out:
# 0. forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} ((A intersect B) subseteq A)
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. (A, B) -> {(A intersect B) subseteq A if forall_{x} ((x in B) in BOOLEAN).
#    core type: Lambda
#    parameters: 12\n   body: 2
# 2. {(A intersect B) subseteq A if forall_{x} ((x in B) in BOOLEAN).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (A intersect B) subseteq A
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{x} ((x in B) in BOOLEAN)
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (A intersect B, A)
#    core type: ExprTuple
#    sub-expressions: 9, 14
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> ((x in B) in BOOLEAN)
#    core type: Lambda
#    parameter: 19
#    body: 10
# 9. A intersect B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x in B) in BOOLEAN
# ...
