# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, S
from proveit.logic import SetEquiv, SubsetEq, Union

# %%
# build up the expression from sub-expressions
expr = Conditional(SetEquiv(Union(A, S), S), SubsetEq(A, S))
# Out:
# expr: {(A union S) equiv S if A subseteq S.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(A \cup S\right) \cong S \textrm{ if } A \subseteq S\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(A union S) equiv S if A subseteq S.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A union S) equiv S
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A subseteq S
#    core type: Operation
#    operator: 5
#    operands: 8
# 3. equiv
#    core type: Literal
#    sub-expressions:
# 4. (A union S, S)
#    core type: ExprTuple
#    sub-expressions: 6, 10
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. A union S
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. union
#    core type: Literal
#    sub-expressions:
# 8. (A, S)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. S
#     core type: Variable
#     sub-expressions:
