# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.disjointness</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Disjoint, EmptySet, Equals, Forall, Iff, Intersect

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Iff(Disjoint(A, B), Equals(Intersect(A, B), EmptySet)))
# Out:
# expr: forall_{A, B} (disjoint(A, B) <=> ((A intersect B) = emptyset))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B}~\left(\textrm{disjoint}(A, B) \Leftrightarrow \left(\left(A \cap B\right) = \emptyset\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B} (disjoint(A, B) <=> ((A intersect B) = emptyset))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> (disjoint(A, B) <=> ((A intersect B) = emptyset))
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. disjoint(A, B) <=> ((A intersect B) = emptyset)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. <=>
#    core type: Literal
#    sub-expressions:
# 5. (disjoint(A, B), (A intersect B) = emptyset)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. disjoint(A, B)
#    core type: Operation
#    operator: 8
#    operands: 14
# 7. (A intersect B) = emptyset
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. disjoint
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A intersect B, emptyset)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A intersect B
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. emptyset
#     core type: Literal
#     sub-expressions:
# 13. intersect
#     core type: Literal
#     sub-expressions:
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
