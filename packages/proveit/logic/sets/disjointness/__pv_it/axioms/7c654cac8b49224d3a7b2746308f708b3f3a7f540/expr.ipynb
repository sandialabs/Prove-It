# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.disjointness</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, X
from proveit.core_expr_types import A_1_to_m
from proveit.logic import And, Disjoint, Forall, Iff, Set

# %%
# build up the expression from sub-expressions
expr = Iff(Disjoint(A_1_to_m, B), And(Disjoint(A_1_to_m), Forall([X], Disjoint(X, B), domains = [Set(A_1_to_m)]))).with_wrapping_at(2)
# Out:
# expr: disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \textrm{disjoint}(A_{1}, \ldots, A_{m}, B) \Leftrightarrow  \\ \left(\textrm{disjoint}(A_{1}, \ldots, A_{m}) \land \left[\forall_{X \in \left\{A_{1}, \ldots, A_{m}\right\}}~\textrm{disjoint}(X, B)\right]\right) \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. (disjoint(A_{1}, ..A_{_a}.., A_{m}, B), disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. disjoint(A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: ExprTuple
#    sub-expressions: 24, 19
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (disjoint(A_{1}, ..A_{_a}.., A_{m}), forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B))
#    core type: ExprTuple
# ...
