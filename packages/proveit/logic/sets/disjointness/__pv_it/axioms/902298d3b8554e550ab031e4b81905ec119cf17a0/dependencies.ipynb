# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.disjointness</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#disjoint_pair_def">disjoint_pair_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.disjointness import disjoint_pair_def

# %%
# %dependencies disjoint_pair_def
# Out:
# <h3>No theorems/conjectures depend upon disjoint_pair_def</h3>
