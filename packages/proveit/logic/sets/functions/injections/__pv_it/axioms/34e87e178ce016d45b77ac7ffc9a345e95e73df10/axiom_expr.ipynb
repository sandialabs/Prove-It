# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#injective_def">injective_def</a> of type <a class="ProveItLink" href="../../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.functions.injections</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.functions.injections import injective_def

# %%
# check that the built expression is the same as the stored expression
assert injective_def.expr == stored_expr
assert injective_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: injective_def matches stored_expr")
# Out:
# Passed sanity check: injective_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A, B}~\left[\forall_{f}~\left(\begin{array}{c} \begin{array}{l} \left(f \in \left[A \xrightarrow[]{\text{1-to-1}} B\right]\right) =  \\ \left(\left(f \in \left[A \rightarrow B\right]\right) \land \left[\forall_{a, b \in A~|~a \neq b}~\left(f\left(a\right) \neq f\left(b\right)\right)\right]\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A, B} [forall_{f} ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))]))]
#    core type: Operation
#    operator: 19
#    operand: 2
# 1. ((A, B) -> [forall_{f} ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))]))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (A, B) -> [forall_{f} ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))]))]
#    core type: Lambda
#    parameters: 24\n   body: 3
# 3. forall_{f} ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))]))
#    core type: Operation
#    operator: 19
#    operand: 5
# 4. (f -> ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))])))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. f -> ((f in Injections(A, B)) =  \\ ((f in [A -> B]) and [forall_{a, b in A | a != b} (f(a) != f(b))]))
# ...
