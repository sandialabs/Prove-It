# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#intersection_subset_eq_union">intersection_subset_eq_union</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, A, B
from proveit.numbers import two
from proveit.logic import Union, Intersect
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.unification  import union_def
from proveit.logic.sets.intersection  import intersection_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving intersection_subset_eq_union
# Out:
# intersection_subset_eq_union: forall_{A, B} ((A intersect B) subseteq (A union B))

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:Intersect(A, B), B:Union(A, B)})
# Out:
# subset_eq_def_inst: |- ((A intersect B) subseteq (A union B)) = [forall_{x in A intersect B} (x in (A union B))]

# %%
defaults.assumptions = [subset_eq_def_inst.rhs.condition]
# Out:
# defaults.assumptions: (x in (A intersect B))

# %%
intersection_def_inst = intersection_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# intersection_def_inst: |- (x in (A intersect B)) = ((x in A) and (x in B))

# %%
intersection_def_inst.derive_right_via_equality()
# Out:
# {x in (A intersect B)} |- (x in A) and (x in B)

# %%
union_def_inst = union_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# union_def_inst: |- (x in (A union B)) = ((x in A) or (x in B))

# %%
union_def_inst.rhs.prove()
# Out:
# {x in (A intersect B)} |- (x in A) or (x in B)

# %%
union_def_inst.derive_left_via_equality()
# Out:
# {x in (A intersect B)} |- x in (A union B)

# %%
subset_eq_def_inst.rhs.prove()
# Out:
# |- forall_{x in A intersect B} (x in (A union B))

# %%
subset_eq_def_inst.derive_left_via_equality()
# Out:
# |- (A intersect B) subseteq (A union B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B} ((A intersect B) subseteq (A union B))
# 1	instantiation	6, 2, 3	|- (A intersect B) subseteq (A union B)
# 	P : (A intersect B) subseteq (A union B), Q : forall_{x in A intersect B} (x in (A union B))
# 2	generalizaton	4	|- forall_{x in A intersect B} (x in (A union B))
# 3	instantiation	5	|- ((A intersect B) subseteq (A union B)) = [forall_{x in A intersect B} (x in (A union B))]
# 	A : A intersect B, B : A union B
# 4	instantiation	6, 7, 8	{x in (A intersect B)} |- x in (A union B)
# 	P : x in (A union B), Q : (x in A) or (x in B)
# 5	axiom		|- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 6	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 7	instantiation	9, 10	{x in (A intersect B)} |- (x in A) or (x in B)
# 	A : x in A, B : x in B
# 8	instantiation	11, 16, 17	|- (x in (A union B)) = ((x in A) or (x in B))
# 	m : 2, x : x, A : (A, B)
# 9	theorem		|- forall_{A, B | A, B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_both
# 10	instantiation	12, 13, 14	{x in (A intersect B)} |- (x in A) and (x in B)
# 	P : x in (A intersect B), Q : (x in A) and (x in B)
# 11	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))]
# 	proveit.logic.sets.unification.union_def
# 12	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 13	assumption		{x in (A intersect B)} |- x in (A intersect B)
# 14	instantiation	15, 16, 17	|- (x in (A intersect B)) = ((x in A) and (x in B))
# 	m : 2, x : x, A : (A, B)
# 15	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))]
# 	proveit.logic.sets.intersection.intersection_def
# 16	conjecture		|- 2 in NaturalPos
# 17	instantiation	18	|- |(A, B)| = |(1, ..k.., 2)|
# 	a : A, b : B
# 18	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
