# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#intersection_subset_eq_union">intersection_subset_eq_union</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, A, B
from proveit.numbers import two
from proveit.logic import Union, Intersect
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.unification  import union_def
from proveit.logic.sets.intersection  import intersection_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving intersection_subset_eq_union
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="intersection_subset_eq_union">intersection_subset_eq_union:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0d87b9ef2d9558dea01d39da248cc5118d77b7b60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/33097b974abf7754dbe319fc36772dd57d9ff5000/dependencies.ipynb">dependencies</a>)<br>

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:Intersect(A, B), B:Union(A, B)})
# Out:
# <strong id="subset_eq_def_inst">subset_eq_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/c5758bdf2f35a4e3721fd18e72ed756039a8e79b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/e112f23bbced7dd0ede1ff0c1fe6eb44f6abfaec0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
defaults.assumptions = [subset_eq_def_inst.rhs.condition]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/b45c9a2e2a62084247825e00b3628b534f34baa20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
intersection_def_inst = intersection_def.instantiate({m:two, x:x, A:[A, B]}, auto_simplify=False)
# Out:
# <strong id="intersection_def_inst">intersection_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/0ad4b2dba17e563b8530cfa9989b77737049db0a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/6275fcb2cf76fec7d407b03d0315dee12a1b82500/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
intersection_def_inst.derive_right_via_equality()
# Out:
# {x in (A intersect B)} |- (x in A) and (x in B)

# %%
union_def_inst = union_def.instantiate({m:two, x:x, A:[A, B]}, auto_simplify=False)
# Out:
# <strong id="union_def_inst">union_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/2751a82142c6a1687c9dcae38d1b2eb270d34b800/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_intersection_subset_eq_union/2be5560e861c28910db861e3194d5255ea1372b00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
union_def_inst.rhs.prove()
# Out:
# {x in (A intersect B)} |- (x in A) or (x in B)

# %%
union_def_inst.derive_left_via_equality()
# Out:
# {x in (A intersect B)} |- x in (A union B)

# %%
subset_eq_def_inst.rhs.prove()
# Out:
# |- forall_{x in A intersect B} (x in (A union B))
# intersection_subset_eq_union may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
subset_eq_def_inst.derive_left_via_equality()
# Out:
# |- (A intersect B) subset_eq (A union B)

# %%
# %qed
# Out:
# proveit.logic.sets.intersection_subset_eq_union has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B} ((A intersect B) subset_eq (A union B))
# 1	instantiation	6, 2, 3	|- (A intersect B) subset_eq (A union B)
# 	P : (A intersect B) subset_eq (A union B), Q : forall_{x in A intersect B} (x in (A union B))
# 2	generalization	4	|- forall_{x in A intersect B} (x in (A union B))
# 3	instantiation	5	|- ((A intersect B) subset_eq (A union B)) = [forall_{x in A intersect B} (x in (A union B))]
# 	A : A intersect B, B : A union B
# 4	instantiation	6, 7, 8	{x in (A intersect B)} |- x in (A union B)
# 	P : x in (A union B), Q : (x in A) or (x in B)
# 5	axiom		|- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 6	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 7	instantiation	9, 10	{x in (A intersect B)} |- (x in A) or (x in B)
# 	A : x in A, B : x in B
# 8	instantiation	11, 13, 14	|- (x in (A union B)) =  \\ ((x in A) or (x in B))
# 	m : 2, x : x, A : (A, B)
# 9	theorem		|- forall_{A, B | A, B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_both
# 10	instantiation	12, 13, 14, 15	{x in (A intersect B)} |- (x in A) and (x in B)
# 	m : 2, x : x, A : (A, B)
# 11	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m}} ((x in (A_{1} union  A_{2} union  ... union  A_{m})) =  \\ ((x in A_{1}) or  (x in A_{2}) or  ... or  (x in A_{m})))]
# 	proveit.logic.sets.unification.union_def
# 12	conjecture		|- forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m} | x in (A_{1} intersect  A_{2} intersect  ... intersect  A_{m})} ((x in A_{1}) and  (x in A_{2}) and  ... and  (x in A_{m}))]
# 	proveit.logic.sets.intersection.membership_unfolding
# 13	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 14	instantiation	16	|- |(A, B)| = |(1, ..., 2)|
# 	a : A, b : B
# 15	assumption		{x in (A intersect B)} |- x in (A intersect B)
# 16	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
