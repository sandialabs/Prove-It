# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#intersection_is_subset_eq">intersection_is_subset_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, y, A, B, S
from proveit.numbers import one, two
from proveit.logic import InSet, Intersect
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.intersection  import intersection_def

theory = proveit.Theory() # the theorem's theory

# %%
# %proving intersection_is_subset_eq
# Out:
# intersection_is_subset_eq: forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} ((A intersect B) subseteq A)

# %%
defaults.assumptions = [intersection_is_subset_eq.condition]
# Out:
# defaults.assumptions: (forall_{x} ((x in B) in BOOLEAN))

# %%
intersection_is_subset_eq.condition.instantiate()
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:Intersect(A, B), B:A})
# Out:
# subset_eq_def_inst: |- ((A intersect B) subseteq A) = [forall_{x in A intersect B} (x in A)]

# %%
defaults.assumptions = [*defaults.assumptions, subset_eq_def_inst.rhs.condition]
# Out:
# defaults.assumptions: (forall_{x} ((x in B) in BOOLEAN), x in (A intersect B))

# %%
intersection_def_inst = intersection_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# intersection_def_inst: |- (x in (A intersect B)) = ((x in A) and (x in B))

# %%
intersection_def_inst.derive_right_via_equality()
# Out:
# {x in (A intersect B)} |- (x in A) and (x in B)

# %%
subset_eq_def_inst.rhs.prove()
# Out:
# |- forall_{x in A intersect B} (x in A)

# %%
subset_eq_def_inst.derive_left_via_equality()
# Out:
# |- (A intersect B) subseteq A

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} ((A intersect B) subseteq A)
# 1	instantiation	2, 3, 4	|- (A intersect B) subseteq A
# 	P : (A intersect B) subseteq A, Q : forall_{x in A intersect B} (x in A)
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	generalizaton	5	|- forall_{x in A intersect B} (x in A)
# 4	instantiation	6	|- ((A intersect B) subseteq A) = [forall_{x in A intersect B} (x in A)]
# 	A : A intersect B, B : A
# 5	instantiation	7, 8	{x in (A intersect B)} |- x in A
# 	A : x in A, B : x in B
# 6	axiom		|- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 7	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 8	instantiation	9, 10, 11	{x in (A intersect B)} |- (x in A) and (x in B)
# 	P : x in (A intersect B), Q : (x in A) and (x in B)
# 9	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 10	assumption		{x in (A intersect B)} |- x in (A intersect B)
# 11	instantiation	12, 13, 14	|- (x in (A intersect B)) = ((x in A) and (x in B))
# 	m : 2, x : x, A : (A, B)
# 12	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))]
# 	proveit.logic.sets.intersection.intersection_def
# 13	conjecture		|- 2 in NaturalPos
# 14	instantiation	15	|- |(A, B)| = |(1, ..k.., 2)|
# 	a : A, b : B
# 15	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
