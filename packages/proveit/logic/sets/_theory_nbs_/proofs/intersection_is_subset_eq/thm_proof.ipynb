# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#intersection_is_subset_eq">intersection_is_subset_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, y, A, B, S
from proveit.numbers import one, two
from proveit.logic import InSet, Intersect
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.intersection  import intersection_def

theory = proveit.Theory() # the theorem's theory

# %%
# %proving intersection_is_subset_eq
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="intersection_is_subset_eq">intersection_is_subset_eq:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/569f8a87824f185c1a259e647282952dc0b09b400/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d128656b1184d8f64303405e0e790e8da6f0892c0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [intersection_is_subset_eq.condition]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/06a2b2ba75229c4a16d2e9fe0738274033005adf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
intersection_is_subset_eq.condition.instantiate()
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:Intersect(A, B), B:A})
# Out:
# <strong id="subset_eq_def_inst">subset_eq_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/c3784157cef1fe848733794f3cba8e70a27111780/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/aa25872a9f6b509506c509a80a04f230aa7cc4ca0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
defaults.assumptions = [*defaults.assumptions, subset_eq_def_inst.rhs.condition]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/11524e9c9d303a868a332d59072d4642a96dd1f40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
intersection_def_inst = intersection_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# <strong id="intersection_def_inst">intersection_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/0ad4b2dba17e563b8530cfa9989b77737049db0a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_intersection_is_subset_eq/6275fcb2cf76fec7d407b03d0315dee12a1b82500/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
intersection_def_inst.derive_right_via_equality()
# Out:
# {x in (A intersect B)} |- (x in A) and (x in B)

# %%
subset_eq_def_inst.rhs.prove()
# Out:
# |- forall_{x in A intersect B} (x in A)
# intersection_is_subset_eq may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
subset_eq_def_inst.derive_left_via_equality()
# Out:
# |- (A intersect B) subset_eq A

# %%
# %qed
# Out:
# proveit.logic.sets.intersection_is_subset_eq has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} ((A intersect B) subset_eq A)
# 1	instantiation	2, 3, 4	|- (A intersect B) subset_eq A
# 	P : (A intersect B) subset_eq A, Q : forall_{x in A intersect B} (x in A)
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	generalization	5	|- forall_{x in A intersect B} (x in A)
# 4	instantiation	6	|- ((A intersect B) subset_eq A) = [forall_{x in A intersect B} (x in A)]
# 	A : A intersect B, B : A
# 5	instantiation	7, 8	{x in (A intersect B)} |- x in A
# 	A : x in A, B : x in B
# 6	axiom		|- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 7	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 8	instantiation	9, 10, 11, 12	{x in (A intersect B)} |- (x in A) and (x in B)
# 	m : 2, x : x, A : (A, B)
# 9	conjecture		|- forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m} | x in (A_{1} intersect  A_{2} intersect  ... intersect  A_{m})} ((x in A_{1}) and  (x in A_{2}) and  ... and  (x in A_{m}))]
# 	proveit.logic.sets.intersection.membership_unfolding
# 10	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 11	instantiation	13	|- |(A, B)| = |(1, ..., 2)|
# 	a : A, b : B
# 12	assumption		{x in (A intersect B)} |- x in (A intersect B)
# 13	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
