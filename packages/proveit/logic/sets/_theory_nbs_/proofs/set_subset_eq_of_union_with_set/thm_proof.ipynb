# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#set_subset_eq_of_union_with_set">set_subset_eq_of_union_with_set</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, y, A, B, S
from proveit.numbers import one, two
from proveit.logic import InSet, Union
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.unification  import union_def

theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_subset_eq_of_union_with_set
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="set_subset_eq_of_union_with_set">set_subset_eq_of_union_with_set:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/91252e0299cd4cea6fb015ee5d68f3c41361cf980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f64a213357b2d18caf0cc9a424c7f3eea439ed3a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [set_subset_eq_of_union_with_set.condition]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/06a2b2ba75229c4a16d2e9fe0738274033005adf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
set_subset_eq_of_union_with_set.condition.instantiate()
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:A, B:Union(A, B)})
# Out:
# <strong id="subset_eq_def_inst">subset_eq_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/fc2c20337bc07c5624e6cc7700641d90cf0717d30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/7a465324628d302699a3f8791102bd7b9ee1fa870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
union_def_inst = union_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# <strong id="union_def_inst">union_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/2751a82142c6a1687c9dcae38d1b2eb270d34b800/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/2be5560e861c28910db861e3194d5255ea1372b00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
defaults.assumptions = [*defaults.assumptions, InSet(x, A)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_set_subset_eq_of_union_with_set/932e819e424d13dd50d0c4734fbd66efcb9d61ab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
union_def_inst.rhs.prove()
# Out:
# {x in A, forall_{x} ((x in B) in BOOLEAN)} |- (x in A) or (x in B)

# %%
union_def_inst.derive_left_via_equality()
# Out:
# {x in A, forall_{x} ((x in B) in BOOLEAN)} |- x in (A union B)

# %%
subset_eq_def_inst.derive_left_via_equality(assumptions=[set_subset_eq_of_union_with_set.condition])
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- A subset_eq (A union B)
# set_subset_eq_of_union_with_set may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.sets.set_subset_eq_of_union_with_set has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} (A subset_eq (A union B))
# 1	instantiation	6, 2, 3	{forall_{x} ((x in B) in BOOLEAN)} |- A subset_eq (A union B)
# 	P : A subset_eq (A union B), Q : forall_{x in A} (x in (A union B))
# 2	generalization	4	{forall_{x} ((x in B) in BOOLEAN)} |- forall_{x in A} (x in (A union B))
# 3	instantiation	5	|- (A subset_eq (A union B)) = [forall_{x in A} (x in (A union B))]
# 	A : A, B : A union B
# 4	instantiation	6, 7, 8	{x in A, forall_{x} ((x in B) in BOOLEAN)} |- x in (A union B)
# 	P : x in (A union B), Q : (x in A) or (x in B)
# 5	axiom		|- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 6	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 7	instantiation	9, 10, 11, 16	{x in A, forall_{x} ((x in B) in BOOLEAN)} |- (x in A) or (x in B)
# 	A : x in A, B : x in B
# 8	instantiation	12, 13, 14	|- (x in (A union B)) =  \\ ((x in A) or (x in B))
# 	m : 2, x : x, A : (A, B)
# 9	conjecture		|- forall_{A, B in BOOLEAN | A} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_left
# 10	instantiation	15, 16	{x in A} |- (x in A) in BOOLEAN
# 	A : x in A
# 11	instantiation	17	{forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN
# 	x : x
# 12	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m}} ((x in (A_{1} union  A_{2} union  ... union  A_{m})) =  \\ ((x in A_{1}) or  (x in A_{2}) or  ... or  (x in A_{m})))]
# 	proveit.logic.sets.unification.union_def
# 13	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 14	instantiation	18	|- |(A, B)| = |(1, ..., 2)|
# 	a : A, b : B
# 15	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 16	assumption		{x in A} |- x in A
# 17	assumption		{forall_{x} ((x in B) in BOOLEAN)} |- forall_{x} ((x in B) in BOOLEAN)
# 18	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
