# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theorems.ipynb#set_subset_eq_of_union_with_set">set_subset_eq_of_union_with_set</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import m, x, y, A, B, S
from proveit.numbers import one, two
from proveit.logic import InSet, Union
from proveit.logic.sets.inclusion  import subset_eq_def
from proveit.logic.sets.unification  import union_def

theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_subset_eq_of_union_with_set
# Out:
# set_subset_eq_of_union_with_set: forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} (A subseteq (A union B))

# %%
defaults.assumptions = [set_subset_eq_of_union_with_set.condition]
# Out:
# defaults.assumptions: (forall_{x} ((x in B) in BOOLEAN))

# %%
set_subset_eq_of_union_with_set.condition.instantiate()
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst = subset_eq_def.instantiate({A:A, B:Union(A, B)})
# Out:
# subset_eq_def_inst: |- (A subseteq (A union B)) = [forall_{x in A} (x in (A union B))]

# %%
union_def_inst = union_def.instantiate({m:two, x:x, A:[A, B]})
# Out:
# union_def_inst: |- (x in (A union B)) = ((x in A) or (x in B))

# %%
defaults.assumptions = [*defaults.assumptions, InSet(x, A)]
# Out:
# defaults.assumptions: (forall_{x} ((x in B) in BOOLEAN), x in A)

# %%
union_def_inst.rhs.prove()
# Out:
# {x in A, forall_{x} ((x in B) in BOOLEAN)} |- (x in A) or (x in B)

# %%
union_def_inst.derive_left_via_equality()
# Out:
# {x in A, forall_{x} ((x in B) in BOOLEAN)} |- x in (A union B)

# %%
subset_eq_def_inst.derive_left_via_equality(assumptions=[set_subset_eq_of_union_with_set.condition])
# Out:
# {forall_{x} ((x in B) in BOOLEAN)} |- A subseteq (A union B)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | forall_{x} ((x in B) in BOOLEAN)} (A subseteq (A union B))
# 1	instantiation	6, 2, 3	{forall_{x} ((x in B) in BOOLEAN)} |- A subseteq (A union B)
# 	P : A subseteq (A union B), Q : forall_{x in A} (x in (A union B))
# 2	generalizaton	4	{forall_{x} ((x in B) in BOOLEAN)} |- forall_{x in A} (x in (A union B))
# 3	instantiation	5	|- (A subseteq (A union B)) = [forall_{x in A} (x in (A union B))]
# 	A : A, B : A union B
# 4	instantiation	6, 7, 8	{x in A, forall_{x} ((x in B) in BOOLEAN)} |- x in (A union B)
# 	P : x in (A union B), Q : (x in A) or (x in B)
# 5	axiom		|- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
# 6	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 7	instantiation	9, 10, 11, 17	{x in A, forall_{x} ((x in B) in BOOLEAN)} |- (x in A) or (x in B)
# 	A : x in A, B : x in B
# 8	instantiation	12, 13, 14	|- (x in (A union B)) = ((x in A) or (x in B))
# 	m : 2, x : x, A : (A, B)
# 9	conjecture		|- forall_{A, B in BOOLEAN | A} (A or B)
# 10	instantiation	15, 16, 17	{x in A} |- (x in A) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : x in A
# 11	instantiation	18	{forall_{x} ((x in B) in BOOLEAN)} |- (x in B) in BOOLEAN
# 	x : x
# 12	axiom		|- forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} union ..A_{_a}.. union A_{m})) =  \\ ((x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})))]
# 	proveit.logic.sets.unification.union_def
# 13	conjecture		|- 2 in NaturalPos
# 14	instantiation	19	|- |(A, B)| = |(1, ..k.., 2)|
# 	a : A, b : B
# 15	conjecture		|- forall_{P, x | P(TRUE), x} P(x)
# 16	conjecture		|- TRUE in BOOLEAN
# 17	assumption		{x in A} |- x in A
# 18	assumption		{forall_{x} ((x in B) in BOOLEAN)} |- forall_{x} ((x in B) in BOOLEAN)
# 19	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
