# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.power_set</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, S, x
from proveit.logic import Equals, InSet, PowerSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([x, S], Equals(InSet(x, PowerSet(S)), SubsetEq(x, S)))
# Out:
# expr: (x, S) -> ((x in power_set(S)) = (x subseteq S))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, S\right) \mapsto \left(\left(x \in \mathbb{P}(S)\right) = \left(x \subseteq S\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, S) -> ((x in power_set(S)) = (x subseteq S))
#    core type: Lambda
#    parameters: 9\n   body: 1
# 1. (x in power_set(S)) = (x subseteq S)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x in power_set(S), x subseteq S)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in power_set(S)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x subseteq S
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, power_set(S))
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. subseteq
#    core type: Literal
#    sub-expressions:
# 9. (x, S)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 10. power_set(S)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. power_set
#     core type: Literal
#     sub-expressions:
# 13. S
#     core type: Variable
#     sub-expressions:
