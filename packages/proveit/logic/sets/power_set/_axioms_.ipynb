# %% [markdown]
# Axioms for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.logic.sets.power_set</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the axioms of a theory:
# %axioms_notebook # Keep this at the top following 'import proveit'.
from proveit._common_ import x, S
from proveit.logic import Equals, Forall, InSet, PowerSet, SubsetEq

# %%
# %begin axioms

# %%
power_set_def = Forall((x, S), Equals(InSet(x, PowerSet(S)),
                                      SubsetEq(x, S)))

# %%
# %end axioms
