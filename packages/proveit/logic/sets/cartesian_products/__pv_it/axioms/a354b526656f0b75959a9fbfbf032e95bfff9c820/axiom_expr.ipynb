# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#cart_prod_def">cart_prod_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.cartesian_products</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.cartesian_products import cart_prod_def

# %%
# check that the built expression is the same as the stored expression
assert cart_prod_def.expr == stored_expr
assert cart_prod_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: cart_prod_def matches stored_expr")
# Out:
# Passed sanity check: cart_prod_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{x, A_{1}, A_{2}, \ldots, A_{m}, a_{1}, a_{2}, \ldots, a_{m}}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left(A_{1} \times  A_{2} \times  \ldots \times  A_{m}\right)\right) =  \\ \left(\left(x = \left(a_{1}, a_{2}, \ldots, a_{m}\right)\right)\land \left(a_{1} \in A_{1}\right) \land  \left(a_{2} \in A_{2}\right) \land  \ldots \land  \left(a_{m} \in A_{m}\right)\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m}, a_{1}, a_{2}, ..., a_{m}} ((x in (A_{1} X  A_{2} X  ... X  A_{m})) =  \\ ((x = (a_{1}, a_{2}, ..., a_{m}))and (a_{1} in A_{1}) and  (a_{2} in A_{2}) and  ... and  (a_{m} in A_{m})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (m -> {forall_{x, A_{1}, A_{2}, ..., A_{m}, a_{1}, a_{2}, ..., a_{m}} ((x in (A_{1} X  A_{2} X  ... X  A_{m})) =  \\ ((x = (a_{1}, a_{2}, ..., a_{m}))and (a_{1} in A_{1}) and  (a_{2} in A_{2}) and  ... and  (a_{m} in A_{m}))) if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{x, A_{1}, A_{2}, ..., A_{m}, a_{1}, a_{2}, ..., a_{m}} ((x in (A_{1} X  A_{2} X  ... X  A_{m})) =  \\ ((x = (a_{1}, a_{2}, ..., a_{m}))and (a_{1} in A_{1}) and  (a_{2} in A_{2}) and  ... and  (a_{m} in A_{m}))) if m in NaturalPos.
#    core type: Lambda
#    parameter: 38
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 38
# ...
