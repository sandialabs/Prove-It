# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#membership_folding">membership_folding</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.intersection import membership_folding

# %%
# check that the built expression is the same as the stored expression
assert membership_folding.expr == stored_expr
assert membership_folding.expr._style_id == stored_expr._style_id
print("Passed sanity check: membership_folding matches stored_expr")
# Out:
# Passed sanity check: membership_folding matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(membership_folding.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{x, A_{1}, \ldots, A_{m}~|~x \in A_{1}, \ldots, x \in A_{m}}~\left(x \in \left(A_{1} \cap \ldots \cap A_{m}\right)\right)\right]

# %%
# display the expression information
membership_folding.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m} | x in A_{1}, ..x in A_{i}.., x in A_{m}} (x in (A_{1} intersect ..A_{_a}.. intersect A_{m}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | x in A_{1}, ..x in A_{i}.., x in A_{m}} (x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalPos.
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | x in A_{1}, ..x in A_{i}.., x in A_{m}} (x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, A_{1}, ..A_{_a}.., A_{m} | x in A_{1}, ..x in A_{i}.., x in A_{m}} (x in (A_{1} intersect ..A_{_a}.. intersect A_{m}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalPos
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 25, 10
# 8. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 29, 21
# 9. {x in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. x in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: Operation
#     operator: 26
#     operands: 13
# 12. (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: ExprTuple
#     sub-expressions: 29, 16
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. A_{1} intersect ..A_{_a}.. intersect A_{m}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 24
#     end_index: 25
# 18. intersect
#     core type: Literal
#     sub-expressions:
# 19. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 33
#     body: 22
# 21. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 22. x in A_{i}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. _a -> A_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. m
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. A_{_a}
#     core type: IndexedVar
# variable: 32
# index: 31
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. A_{i}
#     core type: IndexedVar
# variable: 32
# index: 33
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. A
#     core type: Variable
#     sub-expressions:
# 33. i
#     core type: Variable
#     sub-expressions:
