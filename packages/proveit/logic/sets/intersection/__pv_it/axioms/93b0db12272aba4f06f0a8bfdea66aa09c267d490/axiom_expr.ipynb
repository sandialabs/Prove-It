# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#intersect_all_def">intersect_all_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.intersection import intersect_all_def

# %%
# check that the built expression is the same as the stored expression
assert intersect_all_def.expr == stored_expr
assert intersect_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: intersect_all_def matches stored_expr")
# Out:
# Passed sanity check: intersect_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(intersect_all_def.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, \ldots, S_{n}, Q, R, x~|~\exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}~Q(y_{1}, \ldots, y_{n})}~\left(\begin{array}{c} \left(x \in \left[\bigcap_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\forall_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array}\right)\right]

# %%
# display the expression information
intersect_all_def.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])]
#    core type: Operation
#    operator: 22
#    operand: 1
# 1. n -> {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 50
#    body: 2
# 2. {forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{S_{1}, ..S_{_a}.., S_{n}, Q, R, x | exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})} ((x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))])
#    core type: Operation
#    operator: 22
#    operand: 5
# 4. n in NaturalPos
#    core type: Operation
#    operator: 46
#    operands: 6
# 5. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 50, 9
# 7. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#    core type: ExprTuple
#    sub-expressions: 10, 42, 38, 34
# 8. {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. S_{1}, ..S_{_a}.., S_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 49
#     end_index: 50
# 11. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 16
#     operand: 17
# 13. _a -> S_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 51
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. exists
#     core type: Literal
#     sub-expressions:
# 17. (y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Lambda
#     parameters: 43\n    body: 20
# 18. x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 46
#     operands: 21
# 19. forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Conditional
#     value: 40
#     condition: 24
# 21. (x, intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 25
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 43\n    body: 26
# 24. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n})
#     core type: Operation
#     operator: 36
#     operands: 27
# 25. intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 28
#     operand: 29
# 26. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 30
#     condition: 33
# 27. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 28. intersect_all
#     core type: Literal
#     sub-expressions:
# 29. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 43\n    body: 31
# 30. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 46
#     operands: 32
# 31. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 35
#     condition: 33
# 32. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 38
#     operands: 43
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. R
#     core type: Variable
#     sub-expressions:
# 39. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 49
#     end_index: 50
# 40. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 55
#     body: 44
# 42. Q
#     core type: Variable
#     sub-expressions:
# 43. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 45
# 44. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 49
#     end_index: 50
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 48. _a -> y_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 52
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. n
#     core type: Variable
#     sub-expressions:
# 51. S_{_a}
#     core type: IndexedVar
# variable: 53
# index: 55
# 52. y_{_a}
#     core type: IndexedVar
# variable: 54
# index: 55
# 53. S
#     core type: Variable
#     sub-expressions:
# 54. y
#     core type: Variable
#     sub-expressions:
# 55. _a
#     core type: Variable
#     sub-expressions:
