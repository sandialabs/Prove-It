# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#intersect_all_def">intersect_all_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.intersection import intersect_all_def

# %%
# check that the built expression is the same as the stored expression
assert intersect_all_def.expr == stored_expr
assert intersect_all_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: intersect_all_def matches stored_expr")
# Out:
# Passed sanity check: intersect_all_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{S_{1}, S_{2}, \ldots, S_{n}, Q, R, x~|~\exists_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)}~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(x \in \left[\bigcap_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~R\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right]\right) \\  = \left[\forall_{\left(y_{1} \in S_{1}\right), \left(y_{2} \in S_{2}\right), \ldots, \left(y_{n} \in S_{n}\right)~|~Q\left(y_{1}, y_{2}, \ldots, y_{n}\right)}~\left(x \in R\left(y_{1}, y_{2}, \ldots, y_{n}\right)\right)\right] \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x | exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})} ((x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))])]
#    core type: Operation
#    operator: 25
#    operand: 2
# 1. (n -> {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x | exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})} ((x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x | exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})} ((x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 56
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 56
# 4. {forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x | exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})} ((x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{S_{1}, S_{2}, ..., S_{n}, Q, R, x | exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})} ((x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))])
#    core type: Operation
#    operator: 25
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 52
#    operands: 8
# 7. ((S_{1}, S_{2}, ..., S_{n}, Q, R, x) -> {(x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))] if exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 56, 10
# 9. (S_{1}, S_{2}, ..., S_{n}, Q, R, x) -> {(x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))] if exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n}).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (S_{1}, S_{2}, ..., S_{n}, Q, R, x)
#     core type: ExprTuple
#     sub-expressions: 13, 48, 44, 40
# 12. {(x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))] if exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. S_{1}, S_{2}, ..., S_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 55
#     end_index: 56
# 14. (x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]) \\  = [forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))]
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. exists_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})} Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 19
#     operand: 23
# 16. _a -> S_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 57
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})], forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. exists
#     core type: Literal
#     sub-expressions:
# 20. ((y_{1}, y_{2}, ..., y_{n}) -> {Q(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}).)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. x in [intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})]
#     core type: Operation
#     operator: 52
#     operands: 24
# 22. forall_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} (x in R(y_{1}, y_{2}, ..., y_{n}))
#     core type: Operation
#     operator: 25
#     operand: 29
# 23. (y_{1}, y_{2}, ..., y_{n}) -> {Q(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}).
#     core type: Lambda
#     parameters: 49\n    body: 27
# 24. (x, intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 40, 28
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. ((y_{1}, y_{2}, ..., y_{n}) -> {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. {Q(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}).
#     core type: Conditional
#     value: 46
#     condition: 30
# 28. intersect_all_{(y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}) | Q(y_{1}, y_{2}, ..., y_{n})} R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 31
#     operand: 35
# 29. (y_{1}, y_{2}, ..., y_{n}) -> {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 49\n    body: 33
# 30. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n})
#     core type: Operation
#     operator: 42
#     operands: 34
# 31. intersect_all
#     core type: Literal
#     sub-expressions:
# 32. ((y_{1}, y_{2}, ..., y_{n}) -> {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. {x in R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 36
#     condition: 39
# 34. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}))
#     core type: ExprTuple
#     sub-expressions: 45
# 35. (y_{1}, y_{2}, ..., y_{n}) -> {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Lambda
#     parameters: 49\n    body: 37
# 36. x in R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 52
#     operands: 38
# 37. {R(y_{1}, y_{2}, ..., y_{n}) if (y_{1} in S_{1}) ,  (y_{2} in S_{2}) ,  ... ,  (y_{n} in S_{n}) ,  Q(y_{1}, y_{2}, ..., y_{n}).
#     core type: Conditional
#     value: 41
#     condition: 39
# 38. (x, R(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. (y_{1} in S_{1}) and  (y_{2} in S_{2}) and  ... and  (y_{n} in S_{n}) and Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. x
#     core type: Variable
#     sub-expressions:
# 41. R(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 44
#     operands: 49
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. ((y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n}), Q(y_{1}, y_{2}, ..., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 44. R
#     core type: Variable
#     sub-expressions:
# 45. (y_{1} in S_{1}), (y_{2} in S_{2}), ..., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 55
#     end_index: 56
# 46. Q(y_{1}, y_{2}, ..., y_{n})
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 62
#     body: 50
# 48. Q
#     core type: Variable
#     sub-expressions:
# 49. (y_{1}, y_{2}, ..., y_{n})
#     core type: ExprTuple
#     sub-expressions: 51
# 50. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. y_{1}, y_{2}, ..., y_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 55
#     end_index: 56
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 54. _a -> y_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 58
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. S_{_a}
#     core type: IndexedVar
# variable: 59
# index: 62
# 58. y_{_a}
#     core type: IndexedVar
# variable: 60
# index: 62
# 59. S
#     core type: Variable
#     sub-expressions:
# 60. y
#     core type: Variable
#     sub-expressions:
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. _a
#     core type: Variable
#     sub-expressions:
