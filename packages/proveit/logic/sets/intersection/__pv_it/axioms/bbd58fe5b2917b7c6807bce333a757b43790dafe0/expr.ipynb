# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Q__y_1_to_n, S_1_to_n, y_1_to_n
from proveit.logic import Exists

# %%
# build up the expression from sub-expressions
expr = Exists([y_1_to_n], Q__y_1_to_n, domains = [S_1_to_n])
# Out:
# expr: exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}~Q(y_{1}, \ldots, y_{n})

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. Q
#    core type: Variable
#    sub-expressions:
# 7. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 14
#     end_index: 15
# 11. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. _a -> y_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 13. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 23
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. y_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. S_{_a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. y
#     core type: Variable
#     sub-expressions:
# 22. S
#     core type: Variable
#     sub-expressions:
# 23. _a
#     core type: Variable
#     sub-expressions:
