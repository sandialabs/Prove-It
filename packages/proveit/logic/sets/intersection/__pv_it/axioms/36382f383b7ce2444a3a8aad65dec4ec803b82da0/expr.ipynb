# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Q, R, x
from proveit.core_expr_types import Q__y_1_to_n, R__y_1_to_n, S_1_to_n, y_1_to_n
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic.sets import general_intersectall_Ryn

# %%
# build up the expression from sub-expressions
sub_expr1 = [y_1_to_n]
sub_expr2 = [S_1_to_n]
expr = Lambda([S_1_to_n, Q, R, x], Conditional(Equals(InSet(x, general_intersectall_Ryn), Forall(sub_expr1, InSet(x, R__y_1_to_n), domains = sub_expr2, condition = Q__y_1_to_n)).with_wrapping_at(1), Exists(sub_expr1, Q__y_1_to_n, domains = sub_expr2)))
# Out:
# expr: (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S_{1}, \ldots, S_{n}, Q, R, x\right) \mapsto \left\{\begin{array}{c} \left(x \in \left[\bigcap_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~R(y_{1}, \ldots, y_{n})\right]\right) \\  = \left[\forall_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}~|~Q(y_{1}, \ldots, y_{n})}~\left(x \in R(y_{1}, \ldots, y_{n})\right)\right] \end{array} \textrm{ if } \exists_{y_{1} \in S_{1}, \ldots, y_{n} \in S_{n}}~Q(y_{1}, \ldots, y_{n})\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x) -> {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S_{1}, ..S_{_a}.., S_{n}, Q, R, x)
#    core type: ExprTuple
#    sub-expressions: 3, 35, 31, 27
# 2. {(x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))] if exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. S_{1}, ..S_{_a}.., S_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 42
#    end_index: 43
# 4. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]) \\  = [forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. exists_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}} Q(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operand: 10
# 6. _a -> S_{_a}
#    core type: Lambda
#    parameter: 48
#    body: 44
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})], forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n})))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. (y_{1}, ..y_{_a}.., y_{n}) -> {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 13
# 11. x in [intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})]
#     core type: Operation
#     operator: 39
#     operands: 14
# 12. forall_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} (x in R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: Operation
#     operator: 15
#     operand: 16
# 13. {Q(y_{1}, ..y_{_a}.., y_{n}) if (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}).
#     core type: Conditional
#     value: 33
#     condition: 17
# 14. (x, intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 18
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (y_{1}, ..y_{_a}.., y_{n}) -> {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 19
# 17. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n})
#     core type: Operation
#     operator: 29
#     operands: 20
# 18. intersect_all_{y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n} | Q(y_{1}, ..y_{_a}.., y_{n})} R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operand: 22
# 19. {x in R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 23
#     condition: 26
# 20. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 21. intersect_all
#     core type: Literal
#     sub-expressions:
# 22. (y_{1}, ..y_{_a}.., y_{n}) -> {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Lambda
#     parameters: 36\n    body: 24
# 23. x in R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 39
#     operands: 25
# 24. {R(y_{1}, ..y_{_a}.., y_{n}) if y_{1} in S_{1} ,  ..y_{_a} in S_{_a}.. ,  y_{n} in S_{n} ,  Q(y_{1}, ..y_{_a}.., y_{n}).
#     core type: Conditional
#     value: 28
#     condition: 26
# 25. (x, R(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. (y_{1} in S_{1}) and ..(y_{_a} in S_{_a}).. and (y_{n} in S_{n}) and Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. R(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 31
#     operands: 36
# 29. and
#     core type: Literal
#     sub-expressions:
# 30. (y_{1} in S_{1}, ..y_{_a} in S_{_a}.., y_{n} in S_{n}, Q(y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. R
#     core type: Variable
#     sub-expressions:
# 32. (y_{1} in S_{1}), ..(y_{_a} in S_{_a}).., (y_{n} in S_{n})
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 42
#     end_index: 43
# 33. Q(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. _a -> (y_{_a} in S_{_a})
#     core type: Lambda
#     parameter: 48
#     body: 37
# 35. Q
#     core type: Variable
#     sub-expressions:
# 36. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 37. y_{_a} in S_{_a}
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (y_{_a}, S_{_a})
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 41. _a -> y_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 45
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. S_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 45. y_{_a}
#     core type: IndexedVar
# variable: 47
# index: 48
# 46. S
#     core type: Variable
#     sub-expressions:
# 47. y
#     core type: Variable
#     sub-expressions:
# 48. _a
#     core type: Variable
#     sub-expressions:
