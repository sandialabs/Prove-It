# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x
from proveit.core_expr_types import A_1_to_m
from proveit.logic import Equals, Forall, InSet, Intersect
from proveit.logic.sets import x_in_every_A

# %%
# build up the expression from sub-expressions
expr = Forall([x, A_1_to_m], Equals(InSet(x, Intersect(A_1_to_m)), x_in_every_A).with_wrapping_at(2))
# Out:
# expr: forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, A_{1}, \ldots, A_{m}}~\left(\begin{array}{c} \left(x \in \left(A_{1} \cap \ldots \cap A_{m}\right)\right) =  \\ \left(\left(x \in A_{1}\right) \land \ldots \land \left(x \in A_{m}\right)\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 25, 17
# 4. (x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) =  \\ ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x in (A_{1} intersect ..A_{_a}.. intersect A_{m}), (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 22
#    operands: 9
# 8. (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 25, 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. A_{1} intersect ..A_{_a}.. intersect A_{m}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 20
#     end_index: 21
# 14. intersect
#     core type: Literal
#     sub-expressions:
# 15. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 29
#     body: 18
# 17. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. x in A_{i}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. _a -> A_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. m
#     core type: Variable
#     sub-expressions:
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. A_{_a}
#     core type: IndexedVar
# variable: 28
# index: 27
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. A_{i}
#     core type: IndexedVar
# variable: 28
# index: 29
# 27. _a
#     core type: Variable
#     sub-expressions:
# 28. A
#     core type: Variable
#     sub-expressions:
# 29. i
#     core type: Variable
#     sub-expressions:
