# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple, x
from proveit.logic import Boolean, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], InSet(x, B), domains = [A]), Boolean)
# Out:
# expr: (forall_{x in A} (x in B), BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x \in A}~\left(x \in B\right), \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x in A} (x in B), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {x in B if x in A.
#    core type: Lambda
#    parameter: 12
#    body: 5
# 5. {x in B if x in A.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x in B
#    core type: Operation
#    operator: 9
#    operands: 8
# 7. x in A
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x, B)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, A)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
