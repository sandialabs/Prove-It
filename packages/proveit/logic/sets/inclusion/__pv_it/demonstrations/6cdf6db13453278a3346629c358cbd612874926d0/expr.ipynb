# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x
from proveit.logic import InSet, Set
from proveit.numbers import four, one, six, three

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(x, Set(one, three, four, six)), InSet(x, Set(one, three, four)))
# Out:
# expr: {x in {1, 3, 4, 6} if x in {1, 3, 4}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \in \left\{1, 3, 4, 6\right\} \textrm{ if } x \in \left\{1, 3, 4\right\}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x in {1, 3, 4, 6} if x in {1, 3, 4}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x in {1, 3, 4, 6}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. x in {1, 3, 4}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, {1, 3, 4, 6})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, {1, 3, 4})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {1, 3, 4, 6}
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. {1, 3, 4}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, 3, 4, 6)
#    core type: ExprTuple
#    sub-expressions: 13, 14, 15, 12
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (1, 3, 4)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 12. 6
#     core type: Literal
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
