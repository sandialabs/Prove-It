# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.logic import Boolean, Equals, Or
from proveit.numbers import five, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Or(Equals(x, one), Equals(x, three), Equals(x, five)), Boolean)
# Out:
# expr: ((x = 1) or (x = 3) or (x = 5), BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x = 1\right) \lor \left(x = 3\right) \lor \left(x = 5\right), \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x = 1) or (x = 3) or (x = 5), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (x = 1) or (x = 3) or (x = 5)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (x = 1, x = 3, x = 5)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. x = 1
#    core type: Operation
#    operator: 10
#    operands: 8
# 6. x = 3
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. x = 5
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (x, 1)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 9. (x, 3)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x, 5)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. 5
#     core type: Literal
#     sub-expressions:
