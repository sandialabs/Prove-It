# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c, d, f, g
from proveit.logic import Set, SubsetEq

# %%
# build up the expression from sub-expressions
expr = SubsetEq(Set(b, c, f), Set(b, c, d, f, g))
# Out:
# expr: {b, c, f} subseteq {b, c, d, f, g}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{b, c, f\right\} \subseteq \left\{b, c, d, f, g\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {b, c, f} subseteq {b, c, d, f, g}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. ({b, c, f}, {b, c, d, f, g})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {b, c, f}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {b, c, d, f, g}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (b, c, f)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 11
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (b, c, d, f, g)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. d
#     core type: Variable
#     sub-expressions:
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. g
#     core type: Variable
#     sub-expressions:
