# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.logic import InSet, Set
from proveit.numbers import five, four, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Set(one, three, five)), InSet(x, Set(one, two, three, four, five)))
# Out:
# expr: (x in {1, 3, 5}, x in {1, 2, 3, 4, 5})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \left\{1, 3, 5\right\}, x \in \left\{1, 2, 3, 4, 5\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x in {1, 3, 5}, x in {1, 2, 3, 4, 5})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in {1, 3, 5}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. x in {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, {1, 3, 5})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x, {1, 2, 3, 4, 5})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {1, 3, 5}
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. {1, 2, 3, 4, 5}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, 3, 5)
#    core type: ExprTuple
#    sub-expressions: 12, 14, 16
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (1, 2, 3, 4, 5)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15, 16
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
# 16. 5
#     core type: Literal
#     sub-expressions:
