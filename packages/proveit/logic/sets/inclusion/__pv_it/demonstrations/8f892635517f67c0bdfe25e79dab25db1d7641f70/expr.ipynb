# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SupersetEq.html">SupersetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c, f
from proveit.logic import Set, SupersetEq

# %%
# build up the expression from sub-expressions
expr = SupersetEq(Set(b, c, f), Set(b, c))
# Out:
# expr: {b, c, f} supseteq {b, c}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{b, c, f\right\} \supseteq \left\{b, c\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {b, c, f} supseteq {b, c}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. supseteq
#    core type: Literal
#    sub-expressions:
# 2. ({b, c, f}, {b, c})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {b, c, f}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {b, c}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (b, c, f)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 8
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (b, c)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. f
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
