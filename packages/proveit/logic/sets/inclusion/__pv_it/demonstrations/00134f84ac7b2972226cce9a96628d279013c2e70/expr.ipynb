# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple, x
from proveit.logic import InSet, ProperSuperset

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ProperSuperset(A, B), InSet(x, A))
# Out:
# expr: (A proper_superset B, x in A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \supset B, x \in A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A proper_superset B, x in A)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A proper_superset B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. x in A
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. proper_superset
#    core type: Literal
#    sub-expressions:
# 4. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x, A)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. B
#    core type: Variable
#    sub-expressions:
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. A
#    core type: Variable
#    sub-expressions:
