# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import Boolean, InSet, Set, SupersetEq

# %%
# build up the expression from sub-expressions
expr = InSet(SupersetEq(Set(a, b, c, d, e), Set(a, b, c)), Boolean)
# Out:
# expr: ({a, b, c, d, e} supseteq {a, b, c}) in BOOLEAN

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{a, b, c, d, e\right\} \supseteq \left\{a, b, c\right\}\right) \in \mathbb{B}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({a, b, c, d, e} supseteq {a, b, c}) in BOOLEAN
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ({a, b, c, d, e} supseteq {a, b, c}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {a, b, c, d, e} supseteq {a, b, c}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 5. supseteq
#    core type: Literal
#    sub-expressions:
# 6. ({a, b, c, d, e}, {a, b, c})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. {a, b, c, d, e}
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. {a, b, c}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 16, 12, 13
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 12. d
#     core type: Variable
#     sub-expressions:
# 13. e
#     core type: Variable
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
