# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SupersetEq.html">SupersetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, d, g
from proveit.logic import Set, SupersetEq

# %%
# build up the expression from sub-expressions
expr = SupersetEq(Set(b, d, g), Set(b, g))
# Out:
# expr: {b, d, g} supseteq {b, g}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{b, d, g\right\} \supseteq \left\{b, g\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {b, d, g} supseteq {b, g}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. supseteq
#    core type: Literal
#    sub-expressions:
# 2. ({b, d, g}, {b, g})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {b, d, g}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {b, g}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (b, d, g)
#    core type: ExprTuple
#    sub-expressions: 9, 8, 10
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (b, g)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. d
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. g
#     core type: Variable
#     sub-expressions:
