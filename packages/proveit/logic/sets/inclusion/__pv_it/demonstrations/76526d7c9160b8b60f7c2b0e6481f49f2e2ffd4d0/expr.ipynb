# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Set, SubsetEq
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
expr = SubsetEq(Set(one, three), Set(one, three, two, four))
# Out:
# expr: {1, 3} subseteq {1, 3, 2, 4}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{1, 3\right\} \subseteq \left\{1, 3, 2, 4\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {1, 3} subseteq {1, 3, 2, 4}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. ({1, 3}, {1, 3, 2, 4})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {1, 3}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {1, 3, 2, 4}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1, 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (1, 3, 2, 4)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
