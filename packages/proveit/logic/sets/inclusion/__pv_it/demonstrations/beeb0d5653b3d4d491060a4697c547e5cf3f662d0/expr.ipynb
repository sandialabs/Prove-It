# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.logic import Boolean, Equals, Or
from proveit.numbers import four, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Or(Equals(x, two), Equals(x, four)), Boolean)
# Out:
# expr: ((x = 2) or (x = 4), BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x = 2\right) \lor \left(x = 4\right), \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x = 2) or (x = 4), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (x = 2) or (x = 4)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (x = 2, x = 4)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x = 2
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. x = 4
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (x, 4)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. 4
#     core type: Literal
#     sub-expressions:
