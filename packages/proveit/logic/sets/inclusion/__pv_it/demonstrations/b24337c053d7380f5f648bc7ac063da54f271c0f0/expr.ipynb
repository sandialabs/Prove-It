# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Set, SubsetEq
from proveit.numbers import four, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two, four)
expr = SubsetEq(sub_expr1, sub_expr1)
# Out:
# expr: {1, 2, 4} subseteq {1, 2, 4}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{1, 2, 4\right\} \subseteq \left\{1, 2, 4\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {1, 2, 4} subseteq {1, 2, 4}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. ({1, 2, 4}, {1, 2, 4})
#    core type: ExprTuple
#    sub-expressions: 3, 3
# 3. {1, 2, 4}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (1, 2, 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. 4
#    core type: Literal
#    sub-expressions:
