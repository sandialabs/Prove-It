# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple
from proveit.logic import Not, NotProperSubset, ProperSubset

# %%
# build up the expression from sub-expressions
expr = ExprTuple(NotProperSubset(A, B), Not(ProperSubset(A, B)))
# Out:
# expr: (A not_proper_subset B, [not](A proper_subset B))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \not\subset B, \lnot \left(A \subset B\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A not_proper_subset B, [not](A proper_subset B))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A not_proper_subset B
#    core type: Operation
#    operator: 3
#    operands: 7
# 2. [not](A proper_subset B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. not_proper_subset
#    core type: Literal
#    sub-expressions:
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. A proper_subset B
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. proper_subset
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
