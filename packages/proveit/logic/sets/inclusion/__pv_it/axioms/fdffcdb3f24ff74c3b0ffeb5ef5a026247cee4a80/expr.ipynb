# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, x
from proveit.logic import Equals, Forall, InSet, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Equals(SupersetEq(A, B), Forall([x], InSet(x, A), domains = [B])))
# Out:
# expr: forall_{A, B} ((A supseteq B) = [forall_{x in B} (x in A)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B}~\left(\left(A \supseteq B\right) = \left[\forall_{x \in B}~\left(x \in A\right)\right]\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B} ((A supseteq B) = [forall_{x in B} (x in A)])
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. (A, B) -> ((A supseteq B) = [forall_{x in B} (x in A)])
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. (A supseteq B) = [forall_{x in B} (x in A)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A supseteq B, forall_{x in B} (x in A))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A supseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. supseteq
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 17, 19
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. x -> {x in A if x in B.
#     core type: Lambda
#     parameter: 18
#     body: 11
# 11. {x in A if x in B.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. x in A
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. x in B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, A)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
