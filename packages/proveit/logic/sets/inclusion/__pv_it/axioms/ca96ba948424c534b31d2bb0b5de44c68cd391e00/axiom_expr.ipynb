# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#proper_superset_def">proper_superset_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import proper_superset_def

# %%
# check that the built expression is the same as the stored expression
assert proper_superset_def.expr == stored_expr
assert proper_superset_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: proper_superset_def matches stored_expr")
# Out:
# Passed sanity check: proper_superset_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(proper_superset_def.latex())
# Out:
# \vdash \forall_{A, B}~\left(\left(A \supset B\right) = \left(\left(A \supseteq B\right) \land \left(B \ncong A\right)\right)\right)

# %%
# display the expression information
proper_superset_def.expr_info()
# Out:
# 0. forall_{A, B} ((A proper_superset B) = ((A supseteq B) and (B not_equiv A)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> ((A proper_superset B) = ((A supseteq B) and (B not_equiv A)))
#    core type: Lambda
#    parameters: 14\n   body: 3
# 3. (A proper_superset B) = ((A supseteq B) and (B not_equiv A))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A proper_superset B, (A supseteq B) and (B not_equiv A))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A proper_superset B
#    core type: Operation
#    operator: 8
#    operands: 14
# 7. (A supseteq B) and (B not_equiv A)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. proper_superset
#    core type: Literal
#    sub-expressions:
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A supseteq B, B not_equiv A)
#     core type: ExprTuple
# ...
