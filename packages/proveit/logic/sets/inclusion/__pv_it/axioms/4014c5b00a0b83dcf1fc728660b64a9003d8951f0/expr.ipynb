# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Equals, ProperSubset, SetNotEquiv, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Equals(ProperSubset(A, B), And(SubsetEq(A, B), SetNotEquiv(B, A)))
# Out:
# expr: (A proper_subset B) = ((A subseteq B) and (B not_equiv A))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \subset B\right) = \left(\left(A \subseteq B\right) \land \left(B \ncong A\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A proper_subset B) = ((A subseteq B) and (B not_equiv A))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A proper_subset B, (A subseteq B) and (B not_equiv A))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A proper_subset B
#    core type: Operation
#    operator: 5
#    operands: 11
# 4. (A subseteq B) and (B not_equiv A)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. proper_subset
#    core type: Literal
#    sub-expressions:
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A subseteq B, B not_equiv A)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A subseteq B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. B not_equiv A
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. subseteq
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. not_equiv
#     core type: Literal
#     sub-expressions:
# 13. (B, A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
