# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#not_proper_subset_def">not_proper_subset_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import not_proper_subset_def

# %%
# check that the built expression is the same as the stored expression
assert not_proper_subset_def.expr == stored_expr
assert not_proper_subset_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_proper_subset_def matches stored_expr")
# Out:
# Passed sanity check: not_proper_subset_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_proper_subset_def.latex())
# Out:
# \vdash \forall_{A, B}~\left(\left(A \not\subset B\right) = (\lnot \left(A \subset B\right))\right)

# %%
# display the expression information
not_proper_subset_def.expr_info()
# Out:
# 0. forall_{A, B} ((A not_proper_subset B) = [not](A proper_subset B))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> ((A not_proper_subset B) = [not](A proper_subset B))
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. (A not_proper_subset B) = [not](A proper_subset B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A not_proper_subset B, [not](A proper_subset B))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A not_proper_subset B
#    core type: Operation
#    operator: 8
#    operands: 12
# 7. [not](A proper_subset B)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. not_proper_subset
#    core type: Literal
#    sub-expressions:
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. A proper_subset B
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. proper_subset
# ...
