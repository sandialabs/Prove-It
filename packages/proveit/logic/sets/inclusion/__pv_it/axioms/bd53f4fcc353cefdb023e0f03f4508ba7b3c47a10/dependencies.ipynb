# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#not_proper_subset_def">not_proper_subset_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.inclusion import not_proper_subset_def

# %%
# %dependencies not_proper_subset_def
# Out:
# <h3>Theorems/conjectures that depend directly on not_proper_subset_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/fold_not_proper_subset/thm_proof.ipynb">proveit.logic.sets.inclusion.fold_not_proper_subset</a></dt><dd><a class="ProveItLink" href="../../theorems/6caa68c9c6a94aa13838140a821e9edccb061bc50/expr.ipynb"><img src="../../theorems/6caa68c9c6a94aa13838140a821e9edccb061bc50/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/unfold_not_proper_subset/thm_proof.ipynb">proveit.logic.sets.inclusion.unfold_not_proper_subset</a></dt><dd><a class="ProveItLink" href="../../theorems/e34e0a148e64ab046be81cc706ea8dfb8fb1aaec0/expr.ipynb"><img src="../../theorems/e34e0a148e64ab046be81cc706ea8dfb8fb1aaec0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
