# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Equals, Forall, Not, NotProperSuperset, ProperSuperset

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], Equals(Not(ProperSuperset(A, B)), NotProperSuperset(A, B)))
# Out:
# expr: forall_{A, B} ([not](A proper_superset B) = (A nsupset B))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B}~\left((\lnot \left(A \supset B\right)) = \left(A \not\supset B\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B} ([not](A proper_superset B) = (A nsupset B))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> ([not](A proper_superset B) = (A nsupset B))
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. [not](A proper_superset B) = (A nsupset B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ([not](A proper_superset B), A nsupset B)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. [not](A proper_superset B)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. A nsupset B
#    core type: Operation
#    operator: 10
#    operands: 12
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. A proper_superset B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. nsupset
#     core type: Literal
#     sub-expressions:
# 11. proper_superset
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
