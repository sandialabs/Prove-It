# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C
from proveit.logic import Equals, Forall, ProperSubset

# %%
# build up the expression from sub-expressions
expr = Forall([A, B, C], ProperSubset(A, C), conditions = [ProperSubset(A, B), Equals(B, C)])
# Out:
# expr: forall_{A, B, C | A proper_subset B, B = C} (A proper_subset C)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B, C~|~A \subset B, B = C}~\left(A \subset C\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B, C | A proper_subset B, B = C} (A proper_subset C)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {A proper_subset C if A proper_subset B ,  B = C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 4. {A proper_subset C if A proper_subset B ,  B = C.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A proper_subset C
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (A proper_subset B) and (B = C)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A, C)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A proper_subset B, B = C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A proper_subset B
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. B = C
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. proper_subset
#     core type: Literal
#     sub-expressions:
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (B, C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
