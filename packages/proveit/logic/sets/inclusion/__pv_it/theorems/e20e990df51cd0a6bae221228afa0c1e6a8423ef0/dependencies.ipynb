# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#fold_not_proper_supset">fold_not_proper_supset</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/fold_not_proper_supset/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.inclusion import fold_not_proper_supset

# %%
# %dependencies fold_not_proper_supset
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon fold_not_proper_supset</h3>
