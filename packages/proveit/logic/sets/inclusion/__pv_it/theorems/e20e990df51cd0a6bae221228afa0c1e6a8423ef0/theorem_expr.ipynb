# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#fold_not_proper_supset">fold_not_proper_supset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import fold_not_proper_supset

# %%
# check that the built expression is the same as the stored expression
assert fold_not_proper_supset.expr == stored_expr
assert fold_not_proper_supset.expr._style_id == stored_expr._style_id
print("Passed sanity check: fold_not_proper_supset matches stored_expr")
# Out:
# Passed sanity check: fold_not_proper_supset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fold_not_proper_supset.latex())
# Out:
# \vdash \forall_{A, B~|~\lnot \left(A \supset B\right)}~\left(A \not\supset B\right)

# %%
# display the expression information
fold_not_proper_supset.expr_info()
# Out:
# 0. forall_{A, B | [not](A proper_superset B)} (A nsupset B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A nsupset B if [not](A proper_superset B).
#    core type: Lambda
#    parameters: 10\n   body: 3
# 3. {A nsupset B if [not](A proper_superset B).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A nsupset B
#    core type: Operation
#    operator: 6
#    operands: 10
# 5. [not](A proper_superset B)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. nsupset
#    core type: Literal
#    sub-expressions:
# 7. not
#    core type: Literal
#    sub-expressions:
# 8. A proper_superset B
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. proper_superset
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
# ...
