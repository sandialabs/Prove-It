# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Forall, ProperSubset, ProperSuperset

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], ProperSuperset(B, A), condition = ProperSubset(A, B))
# Out:
# expr: forall_{A, B | A proper_subset B} (B proper_superset A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~A \subset B}~\left(B \supset A\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | A proper_subset B} (B proper_superset A)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {B proper_superset A if A proper_subset B.
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. {B proper_superset A if A proper_subset B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. B proper_superset A
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A proper_subset B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. proper_superset
#    core type: Literal
#    sub-expressions:
# 7. (B, A)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. proper_subset
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
