# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#transitivity_subset_eq_subset">transitivity_subset_eq_subset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import transitivity_subset_eq_subset

# %%
# check that the built expression is the same as the stored expression
assert transitivity_subset_eq_subset.expr == stored_expr
assert transitivity_subset_eq_subset.expr._style_id == stored_expr._style_id
print("Passed sanity check: transitivity_subset_eq_subset matches stored_expr")
# Out:
# Passed sanity check: transitivity_subset_eq_subset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivity_subset_eq_subset.latex())
# Out:
# \vdash \forall_{A, B, C~|~A \subseteq B, B \subset C}~\left(A \subset C\right)

# %%
# display the expression information
transitivity_subset_eq_subset.expr_info()
# Out:
# 0. forall_{A, B, C | A subseteq B, B proper_subset C} (A proper_subset C)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {A proper_subset C if A subseteq B ,  B proper_subset C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 4. {A proper_subset C if A subseteq B ,  B proper_subset C.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A proper_subset C
#    core type: Operation
#    operator: 14
#    operands: 7
# 6. (A subseteq B) and (B proper_subset C)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A, C)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A subseteq B, B proper_subset C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A subseteq B
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. B proper_subset C
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. subseteq
#     core type: Literal
#     sub-expressions:
# 13. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. proper_subset
#     core type: Literal
#     sub-expressions:
# 15. (B, C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
