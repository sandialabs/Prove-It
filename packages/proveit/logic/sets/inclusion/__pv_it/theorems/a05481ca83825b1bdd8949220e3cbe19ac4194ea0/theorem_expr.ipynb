# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unfold_proper_subset">unfold_proper_subset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import unfold_proper_subset

# %%
# check that the built expression is the same as the stored expression
assert unfold_proper_subset.expr == stored_expr
assert unfold_proper_subset.expr._style_id == stored_expr._style_id
print("Passed sanity check: unfold_proper_subset matches stored_expr")
# Out:
# Passed sanity check: unfold_proper_subset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(unfold_proper_subset.latex())
# Out:
# \vdash \forall_{A, B~|~A \subset B}~\left(\left(A \subseteq B\right) \land \left(B \ncong A\right)\right)

# %%
# display the expression information
unfold_proper_subset.expr_info()
# Out:
# 0. forall_{A, B | A proper_subset B} ((A subseteq B) and (B not_equiv A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {(A subseteq B) and (B not_equiv A) if A proper_subset B.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {(A subseteq B) and (B not_equiv A) if A proper_subset B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A subseteq B) and (B not_equiv A)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A proper_subset B
#    core type: Operation
#    operator: 8
#    operands: 12
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A subseteq B, B not_equiv A)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. proper_subset
#    core type: Literal
#    sub-expressions:
# 9. A subseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. B not_equiv A
#     core type: Operation
#     operator: 13
# ...
