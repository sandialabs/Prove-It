# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, x
from proveit.logic import Forall, InSet, ProperSuperset

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Forall([x], InSet(x, A), domains = [B]), ProperSuperset(A, B)))
# Out:
# expr: (A, B) -> {forall_{x in B} (x in A) if A proper_superset B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\forall_{x \in B}~\left(x \in A\right) \textrm{ if } A \supset B\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {forall_{x in B} (x in A) if A proper_superset B.
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. {forall_{x in B} (x in A) if A proper_superset B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. A proper_superset B
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> {x in A if x in B.
#    core type: Lambda
#    parameter: 15
#    body: 8
# 6. proper_superset
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 8. {x in A if x in B.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. x in A
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. x in B
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x, A)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
