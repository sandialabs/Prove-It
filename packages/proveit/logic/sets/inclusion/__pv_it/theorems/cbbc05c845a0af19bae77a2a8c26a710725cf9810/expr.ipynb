# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Forall, ProperSubset, SetNotEquiv, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], ProperSubset(A, B), condition = And(SubsetEq(A, B), SetNotEquiv(B, A)))
# Out:
# expr: forall_{A, B | (A subseteq B) and (B not_equiv A)} (A proper_subset B)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~\left(A \subseteq B\right) \land \left(B \ncong A\right)}~\left(A \subset B\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | (A subseteq B) and (B not_equiv A)} (A proper_subset B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A proper_subset B if A subseteq B ,  B not_equiv A.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {A proper_subset B if A subseteq B ,  B not_equiv A.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A proper_subset B
#    core type: Operation
#    operator: 6
#    operands: 12
# 5. (A subseteq B) and (B not_equiv A)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. proper_subset
#    core type: Literal
#    sub-expressions:
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A subseteq B, B not_equiv A)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A subseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. B not_equiv A
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. subseteq
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. not_equiv
#     core type: Literal
#     sub-expressions:
# 14. (B, A)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
