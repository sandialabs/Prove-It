# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#reverse_not_subset_eq">reverse_not_subset_eq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import reverse_not_subset_eq

# %%
# check that the built expression is the same as the stored expression
assert reverse_not_subset_eq.expr == stored_expr
assert reverse_not_subset_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: reverse_not_subset_eq matches stored_expr")
# Out:
# Passed sanity check: reverse_not_subset_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reverse_not_subset_eq.latex())
# Out:
# \vdash \forall_{A, B~|~A \nsubseteq B}~\left(B \nsupseteq A\right)

# %%
# display the expression information
reverse_not_subset_eq.expr_info()
# Out:
# 0. forall_{A, B | A nsubseteq B} (B nsupseteq A)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {B nsupseteq A if A nsubseteq B.
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. {B nsupseteq A if A nsubseteq B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. B nsupseteq A
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A nsubseteq B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. nsupseteq
#    core type: Literal
#    sub-expressions:
# 7. (B, A)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. nsubseteq
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
