# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#reverse_not_subset_eq">reverse_not_subset_eq</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/reverse_not_subset_eq/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.inclusion import reverse_not_subset_eq

# %%
# %dependencies reverse_not_subset_eq
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove reverse_not_subset_eq</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../core_expr_types/conditionals/_theory_nbs_/proofs/condition_prepend_reduction/thm_proof.ipynb">proveit.core_expr_types.conditionals.condition_prepend_reduction</a></dt><dd><a class="ProveItLink" href="../../../../../../core_expr_types/conditionals/__pv_it/theorems/b44d87e5fff10cc477917426a275929cc623b19b0/expr.ipynb"><img src="../../../../../../core_expr_types/conditionals/__pv_it/theorems/b44d87e5fff10cc477917426a275929cc623b19b0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
