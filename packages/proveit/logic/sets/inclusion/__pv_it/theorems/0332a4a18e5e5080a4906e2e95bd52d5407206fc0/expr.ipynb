# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional
from proveit.logic import And, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(SupersetEq(A, C), And(SupersetEq(A, B), SupersetEq(B, C)))
# Out:
# expr: {A supseteq C if A supseteq B ,  B supseteq C.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \supseteq C \textrm{ if } A \supseteq B ,  B \supseteq C\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A supseteq C if A supseteq B ,  B supseteq C.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A supseteq C
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (A supseteq B) and (B supseteq C)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A, C)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A supseteq B, B supseteq C)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A supseteq B
#    core type: Operation
#    operator: 9
#    operands: 8
# 7. B supseteq C
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. supseteq
#    core type: Literal
#    sub-expressions:
# 10. (B, C)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. C
#     core type: Variable
#     sub-expressions:
