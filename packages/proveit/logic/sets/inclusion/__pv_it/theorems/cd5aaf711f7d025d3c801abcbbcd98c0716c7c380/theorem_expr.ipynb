# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#relax_proper_superset">relax_proper_superset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import relax_proper_superset

# %%
# check that the built expression is the same as the stored expression
assert relax_proper_superset.expr == stored_expr
assert relax_proper_superset.expr._style_id == stored_expr._style_id
print("Passed sanity check: relax_proper_superset matches stored_expr")
# Out:
# Passed sanity check: relax_proper_superset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(relax_proper_superset.latex())
# Out:
# \vdash \forall_{A, B~|~A \supset B}~\left(A \supseteq B\right)

# %%
# display the expression information
relax_proper_superset.expr_info()
# Out:
# 0. forall_{A, B | A proper_superset B} (A supseteq B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {A supseteq B if A proper_superset B.
#    core type: Lambda
#    parameters: 8\n   body: 3
# 3. {A supseteq B if A proper_superset B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. A supseteq B
#    core type: Operation
#    operator: 6
#    operands: 8
# 5. A proper_superset B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. supseteq
#    core type: Literal
#    sub-expressions:
# 7. proper_superset
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
