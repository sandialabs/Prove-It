# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, Lambda
from proveit.logic import And, ProperSuperset, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B, C], Conditional(ProperSuperset(A, C), And(SupersetEq(A, B), ProperSuperset(B, C))))
# Out:
# expr: (A, B, C) -> {A proper_superset C if A supseteq B ,  B proper_superset C.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B, C\right) \mapsto \left\{A \supset C \textrm{ if } A \supseteq B ,  B \supset C\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B, C) -> {A proper_superset C if A supseteq B ,  B proper_superset C.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 16
# 2. {A proper_superset C if A supseteq B ,  B proper_superset C.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. A proper_superset C
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (A supseteq B) and (B proper_superset C)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A, C)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A supseteq B, B proper_superset C)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A supseteq B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. B proper_superset C
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. supseteq
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. proper_superset
#     core type: Literal
#     sub-expressions:
# 13. (B, C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
