# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#superset_membership_from_proper_superset">superset_membership_from_proper_superset</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import superset_membership_from_proper_superset

# %%
# check that the built expression is the same as the stored expression
assert superset_membership_from_proper_superset.expr == stored_expr
assert superset_membership_from_proper_superset.expr._style_id == stored_expr._style_id
print("Passed sanity check: superset_membership_from_proper_superset matches stored_expr")
# Out:
# Passed sanity check: superset_membership_from_proper_superset matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(superset_membership_from_proper_superset.latex())
# Out:
# \vdash \forall_{A, B~|~A \supset B}~\left[\forall_{x \in B}~\left(x \in A\right)\right]

# %%
# display the expression information
superset_membership_from_proper_superset.expr_info()
# Out:
# 0. forall_{A, B | A proper_superset B} [forall_{x in B} (x in A)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (A, B) -> {forall_{x in B} (x in A) if A proper_superset B.
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. {forall_{x in B} (x in A) if A proper_superset B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A proper_superset B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> {x in A if x in B.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 7. proper_superset
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 9. {x in A if x in B.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. x in A
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. x in B
# ...
