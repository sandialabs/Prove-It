# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Lambda
from proveit.logic import Boolean, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], InSet(SubsetEq(A, B), Boolean))
# Out:
# expr: (A, B) -> ((A subseteq B) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left(\left(A \subseteq B\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> ((A subseteq B) in BOOLEAN)
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. (A subseteq B) in BOOLEAN
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. in
#    core type: Literal
#    sub-expressions:
# 3. (A subseteq B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A subseteq B
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 6. subseteq
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
