# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import Not, NotSupersetEq, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(NotSupersetEq(A, B), Not(SupersetEq(A, B))))
# Out:
# expr: (A, B) -> {A nsupseteq B if [not](A supseteq B).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{A \nsupseteq B \textrm{ if } \lnot \left(A \supseteq B\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {A nsupseteq B if [not](A supseteq B).
#    core type: Lambda
#    parameters: 8\n   body: 1
# 1. {A nsupseteq B if [not](A supseteq B).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A nsupseteq B
#    core type: Operation
#    operator: 4
#    operands: 8
# 3. [not](A supseteq B)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. nsupseteq
#    core type: Literal
#    sub-expressions:
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. A supseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. supseteq
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
