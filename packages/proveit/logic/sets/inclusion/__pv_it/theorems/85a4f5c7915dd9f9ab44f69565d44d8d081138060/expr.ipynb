# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprTuple
from proveit.logic import ProperSuperset

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ProperSuperset(A, B), ProperSuperset(B, C))
# Out:
# expr: (A proper_superset B, B proper_superset C)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \supset B, B \supset C\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A proper_superset B, B proper_superset C)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A proper_superset B
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. B proper_superset C
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A, B)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. proper_superset
#    core type: Literal
#    sub-expressions:
# 5. (B, C)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. B
#    core type: Variable
#    sub-expressions:
# 8. C
#    core type: Variable
#    sub-expressions:
