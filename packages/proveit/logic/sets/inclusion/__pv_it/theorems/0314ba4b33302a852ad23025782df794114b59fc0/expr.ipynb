# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import And, Forall, ProperSuperset, SetNotEquiv, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], And(SupersetEq(A, B), SetNotEquiv(B, A)), condition = ProperSuperset(A, B))
# Out:
# expr: forall_{A, B | A proper_superset B} ((A supseteq B) and (B not_equiv A))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~A \supset B}~\left(\left(A \supseteq B\right) \land \left(B \ncong A\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, B | A proper_superset B} ((A supseteq B) and (B not_equiv A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {(A supseteq B) and (B not_equiv A) if A proper_superset B.
#    core type: Lambda
#    parameters: 12\n   body: 3
# 3. {(A supseteq B) and (B not_equiv A) if A proper_superset B.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (A supseteq B) and (B not_equiv A)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A proper_superset B
#    core type: Operation
#    operator: 8
#    operands: 12
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (A supseteq B, B not_equiv A)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. proper_superset
#    core type: Literal
#    sub-expressions:
# 9. A supseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. B not_equiv A
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. supseteq
#     core type: Literal
#     sub-expressions:
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. not_equiv
#     core type: Literal
#     sub-expressions:
# 14. (B, A)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
