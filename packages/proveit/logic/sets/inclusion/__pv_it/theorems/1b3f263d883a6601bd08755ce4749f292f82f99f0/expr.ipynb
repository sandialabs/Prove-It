# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda
from proveit.logic import ProperSubset, ProperSuperset

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(ProperSuperset(B, A), ProperSubset(A, B)))
# Out:
# expr: (A, B) -> {B proper_superset A if A proper_subset B.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{B \supset A \textrm{ if } A \subset B\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, B) -> {B proper_superset A if A proper_subset B.
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. {B proper_superset A if A proper_subset B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. B proper_superset A
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. A proper_subset B
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. proper_superset
#    core type: Literal
#    sub-expressions:
# 5. (B, A)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. proper_subset
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
