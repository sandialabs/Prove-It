# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C
from proveit.logic import And, ProperSuperset, SupersetEq

# %%
# build up the expression from sub-expressions
expr = And(ProperSuperset(A, B), SupersetEq(B, C))
# Out:
# expr: (A proper_superset B) and (B supseteq C)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \supset B\right) \land \left(B \supseteq C\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A proper_superset B) and (B supseteq C)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A proper_superset B, B supseteq C)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A proper_superset B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. B supseteq C
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. proper_superset
#    core type: Literal
#    sub-expressions:
# 6. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. supseteq
#    core type: Literal
#    sub-expressions:
# 8. (B, C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C
#     core type: Variable
#     sub-expressions:
