# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#proper_supset_is_bool">proper_supset_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import proper_supset_is_bool

# %%
# check that the built expression is the same as the stored expression
assert proper_supset_is_bool.expr == stored_expr
assert proper_supset_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: proper_supset_is_bool matches stored_expr")
# Out:
# Passed sanity check: proper_supset_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(proper_supset_is_bool.latex())
# Out:
# \vdash \forall_{A, B}~\left(\left(A \supset B\right) \in \mathbb{B}\right)

# %%
# display the expression information
proper_supset_is_bool.expr_info()
# Out:
# 0. forall_{A, B} ((A proper_superset B) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> ((A proper_superset B) in BOOLEAN)
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. (A proper_superset B) in BOOLEAN
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (A proper_superset B, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A proper_superset B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. proper_superset
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
