# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional
from proveit.logic import And, Equals, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(SubsetEq(A, C), And(SubsetEq(A, B), Equals(B, C)))
# Out:
# expr: {A subseteq C if A subseteq B ,  B = C.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \subseteq C \textrm{ if } A \subseteq B ,  B = C\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {A subseteq C if A subseteq B ,  B = C.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A subseteq C
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (A subseteq B) and (B = C)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A, C)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A subseteq B, B = C)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A subseteq B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. B = C
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. subseteq
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (B, C)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
