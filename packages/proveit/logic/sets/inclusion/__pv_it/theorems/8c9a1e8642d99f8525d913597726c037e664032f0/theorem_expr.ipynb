# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#transitivity_subset_eq_subset_eq">transitivity_subset_eq_subset_eq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.inclusion</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.inclusion import transitivity_subset_eq_subset_eq

# %%
# check that the built expression is the same as the stored expression
assert transitivity_subset_eq_subset_eq.expr == stored_expr
assert transitivity_subset_eq_subset_eq.expr._style_id == stored_expr._style_id
print("Passed sanity check: transitivity_subset_eq_subset_eq matches stored_expr")
# Out:
# Passed sanity check: transitivity_subset_eq_subset_eq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivity_subset_eq_subset_eq.latex())
# Out:
# \vdash \forall_{A, B, C~|~A \subseteq B, B \subseteq C}~\left(A \subseteq C\right)

# %%
# display the expression information
transitivity_subset_eq_subset_eq.expr_info()
# Out:
# 0. forall_{A, B, C | A subseteq B, B subseteq C} (A subseteq C)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {A subseteq C if A subseteq B ,  B subseteq C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 15, 16, 17
# 4. {A subseteq C if A subseteq B ,  B subseteq C.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A subseteq C
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (A subseteq B) and (B subseteq C)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A, C)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A subseteq B, B subseteq C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A subseteq B
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. B subseteq C
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A, B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. subseteq
#     core type: Literal
#     sub-expressions:
# 14. (B, C)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
