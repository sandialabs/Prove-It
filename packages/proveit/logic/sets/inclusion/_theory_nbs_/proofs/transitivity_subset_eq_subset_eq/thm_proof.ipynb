# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_subset_eq_subset_eq">transitivity_subset_eq_subset_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, A, B, C
from proveit.logic import InSet, SubsetEq
from proveit.logic.sets.inclusion  import subset_eq_def

# %%
# %proving transitivity_subset_eq_subset_eq
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="transitivity_subset_eq_subset_eq">transitivity_subset_eq_subset_eq:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e70e46ebdd31dc39d657197e3671c8ad1a4d81170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/29ae097d3d5fe900e9a6c007f7ce9c946c79b1cf0/dependencies.ipynb">dependencies</a>)<br>

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst_AB = subset_eq_def.instantiate({A:A, B:B})
# Out:
# <strong id="subset_eq_def_inst_AB">subset_eq_def_inst_AB:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_subset_eq_subset_eq/99a1fa96a19e693c150cd2e8738c201103c773500/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/369d595e9ce73ec272a603a3113a2b2655115f130/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
subset_eq_def_inst_BC = subset_eq_def.instantiate({A:B, B:C})
# Out:
# <strong id="subset_eq_def_inst_BC">subset_eq_def_inst_BC:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_subset_eq_subset_eq/8f3924a436e62723cb9e92a0eb8e72f497c6b8fd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_subset_eq_subset_eq/76459757f8178dc48cc9e123ffd4eb69677916c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
subset_eq_def_inst_AB.derive_right_via_equality(assumptions=[subset_eq_def_inst_AB.lhs])
# Out:
# {A subset_eq B} |- forall_{x in A} (x in B)

# %%
subset_eq_def_inst_AB.derive_right_via_equality(assumptions=[subset_eq_def_inst_AB.lhs]).instantiate(
        {x:x}, assumptions=[InSet(x, A), subset_eq_def_inst_AB.lhs])
# Out:
# {A subset_eq B, x in A} |- x in B

# %%
subset_eq_def_inst_BC.derive_right_via_equality(assumptions=[subset_eq_def_inst_BC.lhs]).instantiate(
        assumptions=[InSet(x, A), SubsetEq(A, B), subset_eq_def_inst_BC.lhs])
# Out:
# {B subset_eq C, A subset_eq B, x in A} |- x in C

# %%
subset_eq_def_inst_AC = subset_eq_def.instantiate({A:A, B:C})
# Out:
# <strong id="subset_eq_def_inst_AC">subset_eq_def_inst_AC:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_subset_eq_subset_eq/9789f0a13c9c8ff5e2da6fc80bb0540b5a1559520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_transitivity_subset_eq_subset_eq/37e6821bd0b8f670d04b87adf349f8c4ad3a608b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
subset_eq_def_inst_AC.derive_left_via_equality(assumptions=[SubsetEq(A, B), SubsetEq(B, C)])
# Out:
# {B subset_eq C, A subset_eq B} |- A subset_eq C
# transitivity_subset_eq_subset_eq may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.sets.inclusion.transitivity_subset_eq_subset_eq has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B, C | A subset_eq B, B subset_eq C} (A subset_eq C)
# 1	instantiation	2, 3, 4	{B subset_eq C, A subset_eq B} |- A subset_eq C
# 	P : A subset_eq C, Q : forall_{x in A} (x in C)
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	generalization	5	{B subset_eq C, A subset_eq B} |- forall_{x in A} (x in C)
# 4	instantiation	14	|- (A subset_eq C) = [forall_{x in A} (x in C)]
# 	A : A, B : C
# 5	instantiation	6, 7	{B subset_eq C, A subset_eq B, x in A} |- x in C
# 	x : x
# 6	instantiation	8, 9, 10	{B subset_eq C} |- forall_{x in B} (x in C)
# 	P : B subset_eq C, Q : forall_{x in B} (x in C)
# 7	instantiation	11, 12, 13	{A subset_eq B, x in A} |- x in B
# 	A : A, B : B
# 8	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 9	assumption		{B subset_eq C} |- B subset_eq C
# 10	instantiation	14	|- (B subset_eq C) = [forall_{x in B} (x in C)]
# 	A : B, B : C
# 11	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 12	assumption		{A subset_eq B} |- A subset_eq B
# 13	assumption		{x in A} |- x in A
# 14	axiom		|- forall_{A, B} ((A subset_eq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
