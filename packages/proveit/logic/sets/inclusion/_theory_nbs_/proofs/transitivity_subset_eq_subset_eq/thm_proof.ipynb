# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_subset_eq_subset_eq">transitivity_subset_eq_subset_eq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import x, A, B, C
from proveit.logic import InSet, SubsetEq
from proveit.logic.sets.inclusion  import subset_eq_def

# %%
# %proving transitivity_subset_eq_subset_eq
# Out:
# transitivity_subset_eq_subset_eq: forall_{A, B, C | A subseteq B, B subseteq C} (A subseteq C)

# %%
subset_eq_def
# Out:
# |- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
subset_eq_def_inst_AB = subset_eq_def.instantiate({A:A, B:B})
# Out:
# subset_eq_def_inst_AB: |- (A subseteq B) = [forall_{x in A} (x in B)]

# %%
subset_eq_def_inst_BC = subset_eq_def.instantiate({A:B, B:C})
# Out:
# subset_eq_def_inst_BC: |- (B subseteq C) = [forall_{x in B} (x in C)]

# %%
subset_eq_def_inst_AB.derive_right_via_equality([subset_eq_def_inst_AB.lhs]).instantiate(assumptions=[InSet(x, A)])
# Out:
# {A subseteq B, x in A} |- x in B

# %%
subset_eq_def_inst_BC.derive_right_via_equality([subset_eq_def_inst_BC.lhs]).instantiate(assumptions=[InSet(x, A), SubsetEq(A, B)])
# Out:
# {B subseteq C, A subseteq B, x in A} |- x in C

# %%
subset_eq_def_inst_AC = subset_eq_def.instantiate({A:A, B:C})
# Out:
# subset_eq_def_inst_AC: |- (A subseteq C) = [forall_{x in A} (x in C)]

# %%
subset_eq_def_inst_AC.derive_left_via_equality([SubsetEq(A, B), SubsetEq(B, C)])
# Out:
# {B subseteq C, A subseteq B} |- A subseteq C

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B, C | A subseteq B, B subseteq C} (A subseteq C)
# 1	instantiation	2, 3, 4	{B subseteq C, A subseteq B} |- A subseteq C
# 	P : A subseteq C, Q : forall_{x in A} (x in C)
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	generalizaton	5	{B subseteq C, A subseteq B} |- forall_{x in A} (x in C)
# 4	instantiation	15	|- (A subseteq C) = [forall_{x in A} (x in C)]
# 	A : A, B : C
# 5	instantiation	6, 7	{B subseteq C, A subseteq B, x in A} |- x in C
# 	x : x
# 6	instantiation	12, 8, 9	{B subseteq C} |- forall_{x in B} (x in C)
# 	P : B subseteq C, Q : forall_{x in B} (x in C)
# 7	instantiation	10, 11	{A subseteq B, x in A} |- x in B
# 	x : x
# 8	assumption		{B subseteq C} |- B subseteq C
# 9	instantiation	15	|- (B subseteq C) = [forall_{x in B} (x in C)]
# 	A : B, B : C
# 10	instantiation	12, 13, 14	{A subseteq B} |- forall_{x in A} (x in B)
# 	P : A subseteq B, Q : forall_{x in A} (x in B)
# 11	assumption		{x in A} |- x in A
# 12	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 13	assumption		{A subseteq B} |- A subseteq B
# 14	instantiation	15	|- (A subseteq B) = [forall_{x in A} (x in B)]
# 	A : A, B : B
# 15	axiom		|- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])
# 	proveit.logic.sets.inclusion.subset_eq_def
