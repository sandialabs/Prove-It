# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_supset_eq_supset">transitivity_supset_eq_supset</a> theorem
# ========

# %%
import sys
sys.path.append('..') # allows access to modules in parent theory
import proveit

# %%
# %proving transitivity_supset_eq_supset
# Out:
# transitivity_supset_eq_supset: forall_{A, B, C | A supseteq B, B proper_superset C} (A proper_superset C)
