# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#transitivity_supset_eq_supset_eq">transitivity_supset_eq_supset_eq</a> theorem
# ========

# %%
import proveit
from proveit import x, A, B, C
from proveit.logic import InSet, SupersetEq
from proveit.logic.sets.inclusion  import superset_eq_def

# %%
# %proving transitivity_supset_eq_supset_eq
# Out:
# transitivity_supset_eq_supset_eq: forall_{A, B, C | A supseteq B, B supseteq C} (A supseteq C)

# %%
superset_eq_def
# Out:
# |- forall_{A, B} ((A supseteq B) = [forall_{x in B} (x in A)])

# %%
superset_eq_def_inst_AB = superset_eq_def.instantiate({A:A, B:B})
# Out:
# superset_eq_def_inst_AB: |- (A supseteq B) = [forall_{x in B} (x in A)]

# %%
superset_eq_def_inst_BC = superset_eq_def.instantiate({A:B, B:C})
# Out:
# superset_eq_def_inst_BC: |- (B supseteq C) = [forall_{x in C} (x in B)]

# %%
superset_eq_def_inst_AC = superset_eq_def.instantiate({A:A, B:C})
# Out:
# superset_eq_def_inst_AC: |- (A supseteq C) = [forall_{x in C} (x in A)]

# %%
# We work the opposite direction we worked for the Subset case
superset_eq_def_inst_BC.derive_right_via_equality([superset_eq_def_inst_BC.lhs]).instantiate(assumptions=[InSet(x, C)])
# Out:
# {B supseteq C, x in C} |- x in B

# %%
superset_eq_def_inst_AB.derive_right_via_equality([superset_eq_def_inst_AB.lhs]).instantiate(assumptions=[InSet(x, C), SupersetEq(B, C)])
# Out:
# {A supseteq B, B supseteq C, x in C} |- x in A

# %%
superset_eq_def_inst_AC.rhs.prove(assumptions=[SupersetEq(A,B), SupersetEq(B,C)])
# Out:
# {B supseteq C, A supseteq B} |- forall_{x in C} (x in A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B, C | A supseteq B, B supseteq C} (A supseteq C)
# 1	instantiation	2, 3	{B supseteq C, A supseteq B} |- A supseteq C
# 	A : A, B : C, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in B} (x in A)} (A supseteq B)
# 	proveit.logic.sets.inclusion.fold_supset_eq
# 3	generalizaton	4	{B supseteq C, A supseteq B} |- forall_{x in C} (x in A)
# 4	instantiation	5, 6	{A supseteq B, B supseteq C, x in C} |- x in A
# 	x : x
# 5	instantiation	11, 7, 8	{A supseteq B} |- forall_{x in B} (x in A)
# 	P : A supseteq B, Q : forall_{x in B} (x in A)
# 6	instantiation	9, 10	{B supseteq C, x in C} |- x in B
# 	x : x
# 7	assumption		{A supseteq B} |- A supseteq B
# 8	instantiation	14	|- (A supseteq B) = [forall_{x in B} (x in A)]
# 	A : A, B : B
# 9	instantiation	11, 12, 13	{B supseteq C} |- forall_{x in C} (x in B)
# 	P : B supseteq C, Q : forall_{x in C} (x in B)
# 10	assumption		{x in C} |- x in C
# 11	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 12	assumption		{B supseteq C} |- B supseteq C
# 13	instantiation	14	|- (B supseteq C) = [forall_{x in C} (x in B)]
# 	A : B, B : C
# 14	axiom		|- forall_{A, B} ((A supseteq B) = [forall_{x in B} (x in A)])
# 	proveit.logic.sets.inclusion.superset_eq_def
