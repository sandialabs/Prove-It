# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#subset_eq_equals_superset_eq">subset_eq_equals_superset_eq</a> theorem
# ========

# %%
import proveit
from proveit import A, B
from proveit.logic import And, SubsetEq, SupersetEq
from proveit.logic.booleans.implication  import iff_def
from proveit.logic.booleans.implication import eq_from_iff
from proveit.logic.sets.inclusion import (
        reverse_subset_eq, reverse_supset_eq)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving subset_eq_equals_superset_eq
# Out:
# subset_eq_equals_superset_eq: forall_{A, B} ((A subseteq B) = (B supseteq A))

# %%
reverse_subset_eq
# Out:
# |- forall_{A, B | A subseteq B} (B supseteq A)

# %%
reverse_subset_eq_inst_AB = reverse_subset_eq.instantiate(
        {A:A, B:B}, assumptions=[*reverse_subset_eq.conditions.entries])
# Out:
# reverse_subset_eq_inst_AB: {A subseteq B} |- B supseteq A

# %%
reverse_subset_eq_inst_AB_impl = reverse_subset_eq_inst_AB.as_implication(
        hypothesis=reverse_subset_eq_inst_AB.assumptions[0])
# Out:
# reverse_subset_eq_inst_AB_impl: |- (A subseteq B) => (B supseteq A)

# %%
reverse_supset_eq
# Out:
# |- forall_{A, B | A supseteq B} (B subseteq A)

# %%
reverse_supset_eq_inst_BA = reverse_supset_eq.instantiate(
        {A:B, B:A}, assumptions=[SupersetEq(B, A)])
# Out:
# reverse_supset_eq_inst_BA: {B supseteq A} |- A subseteq B

# %%
reverse_supset_eq_inst_BA_impl = reverse_supset_eq_inst_BA.as_implication(
        hypothesis=reverse_supset_eq_inst_BA.assumptions[0])
# Out:
# reverse_supset_eq_inst_BA_impl: |- (B supseteq A) => (A subseteq B)

# %% [markdown]
# ### From the Implications, Derive the Biconditional

# %%
iff_def
# Out:
# |- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))

# %%
iff_def_inst = iff_def.instantiate({A:SubsetEq(A, B), B:SupersetEq(B, A)})
# Out:
# iff_def_inst: |- ((A subseteq B) <=> (B supseteq A)) = (((A subseteq B) => (B supseteq A)) and ((B supseteq A) => (A subseteq B)))

# %%
# this step isn't explicitly needed, but it's nice to see here
two_implications = And(reverse_subset_eq_inst_AB_impl.expr, reverse_supset_eq_inst_BA_impl.expr).prove()
# Out:
# two_implications: |- ((A subseteq B) => (B supseteq A)) and ((B supseteq A) => (A subseteq B))

# %%
# this step isn't explicitly needed, but it's nice to see here
iff_def_inst.sub_left_side_into(two_implications)
# Out:
# |- (A subseteq B) <=> (B supseteq A)

# %% [markdown]
# ### Now deduce equality (system already knows each piece is Boolean)

# %%
eq_from_iff
# Out:
# |- forall_{A, B in BOOLEAN | A <=> B} (A = B)

# %%
eq_from_iff.instantiate({A:SubsetEq(A, B), B:SupersetEq(B, A)})
# Out:
# |- (A subseteq B) = (B supseteq A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B} ((A subseteq B) = (B supseteq A))
# 1	instantiation	2, 3, 4, 5	|- (A subseteq B) = (B supseteq A)
# 	A : A subseteq B, B : B supseteq A
# 2	conjecture		|- forall_{A, B in BOOLEAN | A <=> B} (A = B)
# 3	instantiation	6	|- (A subseteq B) in BOOLEAN
# 	A : A, B : B
# 4	instantiation	7	|- (B supseteq A) in BOOLEAN
# 	A : B, B : A
# 5	instantiation	8, 9, 10	|- (A subseteq B) <=> (B supseteq A)
# 	P(_a) : _a, x : (A subseteq B) <=> (B supseteq A), y : ((A subseteq B) => (B supseteq A)) and ((B supseteq A) => (A subseteq B))
# 6	conjecture		|- forall_{A, B} ((A subseteq B) in BOOLEAN)
# 7	conjecture		|- forall_{A, B} ((A supseteq B) in BOOLEAN)
# 8	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 9	instantiation	11, 12, 13	|- ((A subseteq B) => (B supseteq A)) and ((B supseteq A) => (A subseteq B))
# 	A : (A subseteq B) => (B supseteq A), B : (B supseteq A) => (A subseteq B)
# 10	instantiation	14	|- ((A subseteq B) <=> (B supseteq A)) = (((A subseteq B) => (B supseteq A)) and ((B supseteq A) => (A subseteq B)))
# 	A : A subseteq B, B : B supseteq A
# 11	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 12	deduction	15	|- (A subseteq B) => (B supseteq A)
# 13	deduction	16	|- (B supseteq A) => (A subseteq B)
# 14	axiom		|- forall_{A, B} ((A <=> B) = ((A => B) and (B => A)))
# 	proveit.logic.booleans.implication.iff_def
# 15	instantiation	17, 18	{A subseteq B} |- B supseteq A
# 	A : A, B : B
# 16	instantiation	19, 20	{B supseteq A} |- A subseteq B
# 	A : B, B : A
# 17	theorem		|- forall_{A, B | A subseteq B} (B supseteq A)
# 	proveit.logic.sets.inclusion.reverse_subset_eq
# 18	assumption		{A subseteq B} |- A subseteq B
# 19	theorem		|- forall_{A, B | A supseteq B} (B subseteq A)
# 	proveit.logic.sets.inclusion.reverse_supset_eq
# 20	assumption		{B supseteq A} |- B supseteq A
