# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#reverse_subset_eq">reverse_subset_eq</a> theorem
# ========

# %%
import proveit

# %%
# %proving reverse_subset_eq
# Out:
# reverse_subset_eq: forall_{A, B | A subseteq B} (B supseteq A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | A subseteq B} (B supseteq A)
# 1	instantiation	2, 3	{A subseteq B} |- B supseteq A
# 	A : B, B : A, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in B} (x in A)} (A supseteq B)
# 	proveit.logic.sets.inclusion.fold_supset_eq
# 3	generalizaton	4	{A subseteq B} |- forall_{_a in A} (_a in B)
# 4	instantiation	5, 6, 7	{A subseteq B, _a in A} |- _a in B
# 	A : A, B : B, x : _a
# 5	theorem		|- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 6	assumption		{A subseteq B} |- A subseteq B
# 7	assumption		{_a in A} |- _a in A
