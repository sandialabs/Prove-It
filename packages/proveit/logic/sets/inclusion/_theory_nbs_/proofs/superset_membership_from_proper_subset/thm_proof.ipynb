# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#superset_membership_from_proper_subset">superset_membership_from_proper_subset</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving superset_membership_from_proper_subset
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="superset_membership_from_proper_subset">superset_membership_from_proper_subset:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8c2c4c3c91efdbf0b7e86e4a2d99545aea54db000/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2235dee58a3fecd7484ea00ab222055c7e10c0220/dependencies.ipynb">dependencies</a>)<br>

# %%
A_propersub_B = superset_membership_from_proper_subset.condition
# Out:
# <strong id="A_propersub_B">A_propersub_B:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/4fcb3ae92330d8963f99abe44b7ac51675d7edc40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_propersub_B__unfolded = A_propersub_B.unfold(assumptions=[A_propersub_B])
# Out:
# <strong id="A_propersub_B__unfolded">A_propersub_B__unfolded:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/4fcb3ae92330d8963f99abe44b7ac51675d7edc40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_superset_membership_from_proper_subset/89a95855eabdd377231a3de4dd1ac1e7eb7df5b60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/645ab94911b55be4e820c4430a5b89d3b6f479bc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# superset_membership_from_proper_subset may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
A_sub_B = A_propersub_B__unfolded.derive_left()
# Out:
# <strong id="A_sub_B">A_sub_B:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/4fcb3ae92330d8963f99abe44b7ac51675d7edc40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_superset_membership_from_proper_subset/94a883ff0bb181f4e36b5d341268f1fdad812b050/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/db7a164f644801bfd111812bb9a6a278f180c2b50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# %qed
# Out:
# proveit.logic.sets.inclusion.superset_membership_from_proper_subset has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 1	instantiation	2, 3, 4	{A proper_subset B, x in A} |- x in B
# 	A : A, B : B, x : x
# 2	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 3	instantiation	5, 6	{A proper_subset B} |- A subset_eq B
# 	A : A subset_eq B, B : B not_equiv A
# 4	assumption		{x in A} |- x in A
# 5	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 6	instantiation	7, 8	{A proper_subset B} |- (A subset_eq B) and (B not_equiv A)
# 	A : A, B : B
# 7	conjecture		|- forall_{A, B | A proper_subset B} ((A subset_eq B) and (B not_equiv A))
# 	proveit.logic.sets.inclusion.unfold_proper_subset
# 8	assumption		{A proper_subset B} |- A proper_subset B
