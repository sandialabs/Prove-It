# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">inclusion</a>.<a class="ProveItLink" href="../../theorems.ipynb#superset_membership_from_proper_subset">superset_membership_from_proper_subset</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving superset_membership_from_proper_subset
# Out:
# superset_membership_from_proper_subset: forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]

# %%
A_propersub_B = superset_membership_from_proper_subset.condition
# Out:
# A_propersub_B: A proper_subset B

# %%
A_propersub_B__unfolded = A_propersub_B.unfold([A_propersub_B])
# Out:
# A_propersub_B__unfolded: {A proper_subset B} |- (A subseteq B) and (B not_equiv A)

# %%
A_sub_B = A_propersub_B__unfolded.derive_left()
# Out:
# A_sub_B: {A proper_subset B} |- A subseteq B

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 1	instantiation	2, 3, 4	{A proper_subset B, x in A} |- x in B
# 	A : A, B : B, x : x
# 2	theorem		|- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 3	instantiation	5, 6	{A proper_subset B} |- A subseteq B
# 	A : A subseteq B, B : B not_equiv A
# 4	assumption		{x in A} |- x in A
# 5	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 6	instantiation	7, 8	{A proper_subset B} |- (A subseteq B) and (B not_equiv A)
# 	A : A, B : B
# 7	theorem		|- forall_{A, B | A proper_subset B} ((A subseteq B) and (B not_equiv A))
# 	proveit.logic.sets.inclusion.unfold_proper_subset
# 8	assumption		{A proper_subset B} |- A proper_subset B
