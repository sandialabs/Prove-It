# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#reverse_subset_eq">reverse_subset_eq</a> theorem
# ========

# %%
import proveit

# %%
# %proving reverse_subset_eq

# %%
# %qed
