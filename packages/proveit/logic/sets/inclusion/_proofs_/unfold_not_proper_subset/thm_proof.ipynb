# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfold_not_proper_subset">unfold_not_proper_subset</a> theorem
# ========

# %%
import proveit
from proveit.logic.sets.inclusion._axioms_ import not_proper_subset_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving unfold_not_proper_subset

# %%
# pull in the definition of not proper subset
not_proper_subset_def

# %%
not_proper_subset_def_inst = not_proper_subset_def.instantiate()

# %%
not_proper_subset_def_inst.derive_right_via_equality([not_proper_subset_def_inst.lhs])

# %%
# %qed
