# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfoldSupsetEq">unfoldSupsetEq</a> theorem
# ========

# %%
import proveit
from proveit.logic.sets.inclusion._axioms_ import supersetEqDef

# %%
# %proving unfoldSupsetEq

# %%
# Pull in the definition of non-proper superset (SupersetEq)
supersetEqDef

# %%
SupersetEqDef_inst = supersetEqDef.instantiate()

# %%
SupersetEqDef_inst.deriveRightViaEquality([SupersetEqDef_inst.lhs])

# %%
# %qed
