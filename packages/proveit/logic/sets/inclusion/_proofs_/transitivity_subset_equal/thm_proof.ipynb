# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#transitivity_subset_equal">transitivity_subset_equal</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import A, B, C
from proveit.logic import Equals, ProperSubset
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivity_subset_equal

# %%
defaults.assumptions = transitivity_subset_equal.all_conditions()

# %%
A_properSubset_B = ProperSubset(A, B).prove()

# %%
B_equals_C = Equals(B, C).prove()

# %%
B_equals_C.sub_right_side_into(A_properSubset_B)

# %%
# %qed
