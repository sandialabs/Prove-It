# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#reverseNotSubsetEq">reverseNotSubsetEq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import A, B
from proveit.logic.sets.inclusion._axioms_ import notSubsetEqDef, notSupersetEqDef 
from proveit.logic.sets.inclusion._theorems_ import subsetEqEqualsSupersetEq
theory = proveit.Theory() # the theorem's theory

# %%
# %proving reverseNotSubsetEq

# %%
defaults.assumptions = reverseNotSubsetEq.allConditions()

# %%
notSubsetEqDef

# %%
notSubsetEqDef_inst = notSubsetEqDef.instantiate()

# %%
notSubsetEqDef_inst_deriveRight = notSubsetEqDef_inst.deriveRightViaEquality([notSubsetEqDef_inst.lhs])

# %%
subsetEqEqualsSupersetEq

# %%
subsetEqEqualsSupersetEq_inst = subsetEqEqualsSupersetEq.instantiate()

# %%
c1 = subsetEqEqualsSupersetEq_inst.subRightSideInto(notSubsetEqDef_inst_deriveRight)

# %%
notSupersetEqDef

# %%
notSupersetEqDef_inst_BA = notSupersetEqDef.instantiate({A:B, B:A})

# %%
notSupersetEqDef_inst_BA.subLeftSideInto(c1)

# %%
# %qed
