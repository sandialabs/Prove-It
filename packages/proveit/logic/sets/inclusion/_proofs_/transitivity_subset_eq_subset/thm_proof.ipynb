# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#transitivity_subset_eq_subset">transitivity_subset_eq_subset</a> theorem
# ========

# %%
import sys
sys.path.append('..') # allows access to modules in parent theory
import proveit

# %%
# %proving transitivity_subset_eq_subset
