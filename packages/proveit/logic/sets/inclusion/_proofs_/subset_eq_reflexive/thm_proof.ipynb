# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">inclusion</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#subset_eq_reflexive">subset_eq_reflexive</a> theorem
# ========

# %%
import proveit
from proveit import A, B, x
from proveit.logic.sets.inclusion import fold_subset_eq
theory = proveit.Theory() # the theorem's theory

# %%
# %proving subset_eq_reflexive

# %%
# %qed
