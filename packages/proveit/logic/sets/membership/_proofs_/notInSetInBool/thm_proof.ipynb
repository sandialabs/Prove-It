# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">membership</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#notInSetInBool">notInSetInBool</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, A, S
from proveit.logic import InSet
from proveit.logic.booleans.negation._theorems_ import closure
from proveit.logic.sets.membership._axioms_ import notInSetDef
theory = proveit.Theory() # the theorem's theory

# %%
# %proving notInSetInBool

# %%
defaults.assumptions = notInSetInBool.allConditions()

# %%
closure

# %%
closureSpec = closure.instantiate({A:InSet(x, S)})

# %%
notInSetDef

# %%
notInSetDefSpec = notInSetDef.instantiate({x:x, S:S})

# %%
notInSetDefSpec.subLeftSideInto(closureSpec)

# %%
# %qed
