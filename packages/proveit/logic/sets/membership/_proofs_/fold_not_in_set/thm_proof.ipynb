# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">membership</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#fold_not_in_set">fold_not_in_set</a> theorem
# ========
# *** see <a href="../__pv_it/37a0e0955551f7186966242f3c5b5edd6b57745c0/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit._common_ import x, S
from proveit.logic.sets.membership._axioms_ import not_in_set_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving fold_not_in_set

# %%
not_in_set_def

# %%
not_in_set_def_spec = not_in_set_def.instantiate({x:x, S:S})

# %%
not_in_set_def_spec.derive_left_via_equality([not_in_set_def_spec.rhs])

# %%
# %qed
