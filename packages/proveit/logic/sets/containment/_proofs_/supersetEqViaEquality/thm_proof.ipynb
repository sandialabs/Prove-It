# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">containment</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#supersetEqViaEquality">supersetEqViaEquality</a> theorem
# ========
# *** see <a href="../__pv_it/47693a3681f83c1d3a81ca1cb74bc485125038e40/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit._common_ import x, y, A, B, Px
from proveit.logic import Equals, SupersetEq
from proveit.logic.equality._theorems_ import subRightSideInto
from proveit.logic.sets.containment._theorems_ import supsetEqReflexive
# %proving supersetEqViaEquality

# %% [markdown]
# This proceeded automatically but with a 7-step proof using the subsetEqViaEquality.
# By introducing the subRightSideInto thm, and the reflexiveness of supersets, we nudge the proof to be a bit shorter.

# %%
supsetEqReflexive

# %%
supsetEqReflexive.instantiate()

# %%
subRightSideInto

# %%
subRightSideInto.instantiate({Px:SupersetEq(A, x), x:A, y:B }, assumptions=[Equals(A, B)])

# %%
# %qed
