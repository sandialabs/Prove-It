# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">containment</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#transitivitySubsetEqual">transitivitySubsetEqual</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import A, B, C
from proveit.logic import Equals, ProperSubset
theory = proveit.Theory() # the theorem's theory

# %%
# %proving transitivitySubsetEqual

# %%
defaults.assumptions = transitivitySubsetEqual.allConditions()

# %%
A_properSubset_B = ProperSubset(A, B).prove()

# %%
B_equals_C = Equals(B, C).prove()

# %%
B_equals_C.subRightSideInto(A_properSubset_B)

# %%
# %qed
