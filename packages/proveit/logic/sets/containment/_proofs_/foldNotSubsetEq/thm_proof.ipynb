# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">containment</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#foldNotSubsetEq">foldNotSubsetEq</a> theorem
# ========

# %%
# import sys
# sys.path.append('..') # allows access to modules in parent theory
import proveit
from proveit.logic.sets.containment._axioms_ import notSubsetEqDef

# %%
# %proving foldNotSubsetEq

# %%
# Pull in the definition of NotSubsetEq
notSubsetEqDef

# %%
notSubsetEqDef_inst = notSubsetEqDef.instantiate()

# %%
notSubsetEqDef_inst.deriveLeftViaEquality([notSubsetEqDef_inst.rhs])

# %%
# %qed
