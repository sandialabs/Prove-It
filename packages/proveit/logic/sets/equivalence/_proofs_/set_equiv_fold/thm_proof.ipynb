# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">equivalence</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#set_equiv_fold">set_equiv_fold</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic.sets.equivalence  import set_equiv_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_equiv_fold

# %%
defaults.assumptions = set_equiv_fold.conditions

# %%
set_equiv_def

# %%
set_equiv_def.instantiate().derive_left_via_equality()

# %%
# %qed
