# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">equivalence</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfold_set_not_equiv">unfold_set_not_equiv</a> theorem
# ========

# %%
import proveit
from proveit.logic.sets.equivalence._axioms_ import set_not_equiv_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving unfold_set_not_equiv

# %%
set_not_equiv_def

# %%
set_not_equiv_def_inst = set_not_equiv_def.instantiate()

# %%
set_not_equiv_def_inst.derive_right_via_equality(assumptions=[set_not_equiv_def_inst.lhs])

# %%
# %qed
