# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">equivalence</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#set_equiv_is_bool">set_equiv_is_bool</a> theorem
# ========

# %%
import proveit
from proveit import A, B
from proveit.logic import Boolean, InSet
from proveit.logic.sets.equivalence  import set_equiv_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_equiv_is_bool

# %%
set_equiv_def

# %%
set_equiv_def_inst = set_equiv_def.instantiate()

# %%
conjunction_of_subsets_in_bool = set_equiv_def_inst.rhs.deduce_in_bool()

# %%
set_equiv_def_inst.sub_left_side_into(conjunction_of_subsets_in_bool)

# %%
# %qed
