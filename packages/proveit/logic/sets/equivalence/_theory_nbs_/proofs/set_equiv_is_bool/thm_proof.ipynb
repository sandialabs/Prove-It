# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">equivalence</a>.<a class="ProveItLink" href="../../theorems.ipynb#set_equiv_is_bool">set_equiv_is_bool</a> theorem
# ========

# %%
import proveit
from proveit import A, B
from proveit.logic import Boolean, InSet
from proveit.logic.sets.equivalence  import set_equiv_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_equiv_is_bool
# Out:
# set_equiv_is_bool: forall_{A, B} ((A equiv B) in BOOLEAN)

# %%
set_equiv_def
# Out:
# |- forall_{A, B} ((A equiv B) = [forall_{x} ((x in A) = (x in B))])

# %%
set_equiv_def_inst = set_equiv_def.instantiate()
# Out:
# set_equiv_def_inst: |- (A equiv B) = [forall_{x} ((x in A) = (x in B))]

# %%
conjunction_of_subsets_in_bool = set_equiv_def_inst.rhs.deduce_in_bool()
# Out:
# conjunction_of_subsets_in_bool: |- [forall_{x} ((x in A) = (x in B))] in BOOLEAN

# %%
set_equiv_def_inst.sub_left_side_into(conjunction_of_subsets_in_bool)
# Out:
# |- (A equiv B) in BOOLEAN

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B} ((A equiv B) in BOOLEAN)
# 1	instantiation	2, 3, 4	|- (A equiv B) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : A equiv B, y : forall_{x} ((x in A) = (x in B))
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7	|- [forall_{x} ((x in A) = (x in B))] in BOOLEAN
# 	n : 1, P(x) : (x in A) = (x in B), (x_{1}, ..x_{k}.., x_{1}) : (x)
# 4	instantiation	8	|- (A equiv B) = [forall_{x} ((x in A) = (x in B))]
# 	A : A, B : B
# 5	axiom		|- forall_{n in NaturalPos} [forall_{P} ([forall_{x_{1}, ..x_{_a}.., x_{n}} P(x_{1}, ..x_{_a}.., x_{n})] in BOOLEAN)]
# 	proveit.logic.booleans.quantification.universality.forall_in_bool
# 6	instantiation	9	|- |(x)| = |(1, ..k.., 1)|
# 	a : x
# 7	conjecture		|- 1 in NaturalPos
# 8	axiom		|- forall_{A, B} ((A equiv B) = [forall_{x} ((x in A) = (x in B))])
# 	proveit.logic.sets.equivalence.set_equiv_def
# 9	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
