# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">equivalence</a>.<a class="ProveItLink" href="../../theorems.ipynb#set_not_equiv_reversal">set_not_equiv_reversal</a> theorem
# ========

# %%
import proveit
from proveit import A, B
from proveit.logic import Not, SetNotEquiv
from proveit.logic.sets import SetEquiv
from proveit.logic.sets.equivalence  import set_equiv_def, set_not_equiv_def
from proveit.logic.sets.equivalence import set_equiv_reversal
theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_not_equiv_reversal
# Out:
# set_not_equiv_reversal: forall_{A, B | A not_equiv B} (B not_equiv A)

# %%
set_not_equiv_def
# Out:
# |- forall_{A, B} ((A not_equiv B) = [not](A equiv B))

# %%
set_not_equiv_def_inst_AB = set_not_equiv_def.instantiate()
# Out:
# set_not_equiv_def_inst_AB: |- (A not_equiv B) = [not](A equiv B)

# %%
set_not_equiv_def_inst_BA = set_not_equiv_def.instantiate({A:B, B:A})
# Out:
# set_not_equiv_def_inst_BA: |- (B not_equiv A) = [not](B equiv A)

# %%
set_equiv_reversal
# Out:
# |- forall_{A, B | A equiv B} (B equiv A)

# %%
set_equiv_reversal_inst_BA = set_equiv_reversal.instantiate({A:B, B:A}, assumptions=[SetEquiv(B, A)])
# Out:
# set_equiv_reversal_inst_BA: {B equiv A} |- A equiv B

# %%
set_equiv_reversal_inst_BA_as_implication = set_equiv_reversal_inst_BA.as_implication(hypothesis=SetEquiv(B, A))
# Out:
# set_equiv_reversal_inst_BA_as_implication: |- (B equiv A) => (A equiv B)

# %%
not_AEquivB_gives_not_BEquivA = set_equiv_reversal_inst_BA_as_implication.deny_antecedent(assumptions=[Not(SetEquiv(A, B))])
# Out:
# not_AEquivB_gives_not_BEquivA: {[not](A equiv B)} |- [not](B equiv A)

# %%
not_AEquivB_gives_not_BEquivA_as_implication = not_AEquivB_gives_not_BEquivA.as_implication(hypothesis=Not(SetEquiv(A, B)))
# Out:
# not_AEquivB_gives_not_BEquivA_as_implication: |- [not](A equiv B) => [not](B equiv A)

# %%
c_1 = set_not_equiv_def_inst_AB.sub_left_side_into(not_AEquivB_gives_not_BEquivA_as_implication)
# Out:
# c_1: |- (A not_equiv B) => [not](B equiv A)

# %%
c_2 = set_not_equiv_def_inst_BA.sub_left_side_into(c_1)
# Out:
# c_2: |- (A not_equiv B) => (B not_equiv A)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{A, B | A not_equiv B} (B not_equiv A)
# 1	modus ponens	2, 3	{A not_equiv B} |- B not_equiv A
# 2	instantiation	6, 4, 5	|- (A not_equiv B) => (B not_equiv A)
# 	P(_a) : (A not_equiv B) => _a, x : B not_equiv A, y : [not](B equiv A)
# 3	assumption		{A not_equiv B} |- A not_equiv B
# 4	instantiation	6, 7, 8	|- (A not_equiv B) => [not](B equiv A)
# 	P(_a) : _a => [not](B equiv A), x : A not_equiv B, y : [not](A equiv B)
# 5	instantiation	10	|- (B not_equiv A) = [not](B equiv A)
# 	A : B, B : A
# 6	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 7	deduction	9	|- [not](A equiv B) => [not](B equiv A)
# 8	instantiation	10	|- (A not_equiv B) = [not](A equiv B)
# 	A : A, B : B
# 9	instantiation	11, 12, 13, 14	{[not](A equiv B)} |- [not](B equiv A)
# 	A : B equiv A, B : A equiv B
# 10	axiom		|- forall_{A, B} ((A not_equiv B) = [not](A equiv B))
# 	proveit.logic.sets.equivalence.set_not_equiv_def
# 11	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 12	instantiation	15	|- (B equiv A) in BOOLEAN
# 	A : B, B : A
# 13	deduction	16	|- (B equiv A) => (A equiv B)
# 14	assumption		{[not](A equiv B)} |- [not](A equiv B)
# 15	conjecture		|- forall_{A, B} ((A equiv B) in BOOLEAN)
# 16	instantiation	17, 18	{B equiv A} |- A equiv B
# 	A : B, B : A
# 17	theorem		|- forall_{A, B | A equiv B} (B equiv A)
# 	proveit.logic.sets.equivalence.set_equiv_reversal
# 18	assumption		{B equiv A} |- B equiv A
