# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.equivalence</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B
from proveit.logic import Equals, Not, SetEquiv, SetNotEquiv

# %%
# build up the expression from sub-expressions
expr = Equals(SetNotEquiv(B, A), Not(SetEquiv(B, A)))
# Out:
# expr: (B not_equiv A) = [not](B equiv A)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B \ncong A\right) = (\lnot \left(B \cong A\right))

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (B not_equiv A) = [not](B equiv A)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (B not_equiv A, [not](B equiv A))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. B not_equiv A
#    core type: Operation
#    operator: 5
#    operands: 9
# 4. [not](B equiv A)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. not_equiv
#    core type: Literal
#    sub-expressions:
# 6. not
#    core type: Literal
#    sub-expressions:
# 7. B equiv A
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. equiv
#    core type: Literal
#    sub-expressions:
# 9. (B, A)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
