# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#distinct_subset_existence">distinct_subset_existence</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.cardinality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.cardinality import distinct_subset_existence

# %%
# check that the built expression is the same as the stored expression
assert distinct_subset_existence.expr == stored_expr
assert distinct_subset_existence.expr._style_id == stored_expr._style_id
print("Passed sanity check: distinct_subset_existence matches stored_expr")
# Out:
# Passed sanity check: distinct_subset_existence matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distinct_subset_existence.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S, N~|~|S| \geq N}~\left[\exists_{x_{1}, \ldots, x_{n} \in S~|~|\left(x_{1}, \ldots, x_{n}\right)| = N}~\textrm{distinct}(x_{1}, \ldots, x_{n})\right]\right]

# %%
# display the expression information
distinct_subset_existence.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})]]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})] if n in NaturalPos.
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. {forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. forall
#    core type: Literal
# ...
