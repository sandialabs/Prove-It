# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.cardinality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import Len, x_1_to_n
from proveit.logic import Card, Distinct, Equals, Forall, Set
from proveit.numbers import NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = [x_1_to_n]
expr = Forall([n], Forall(sub_expr1, Equals(Card(Set(x_1_to_n)), Len(sub_expr1)), condition = Distinct(x_1_to_n)), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} | distinct(x_{1}, ..x_{_a}.., x_{n})} (|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n}~|~\textrm{distinct}(x_{1}, \ldots, x_{n})}~\left(|\left\{x_{1}, \ldots, x_{n}\right\}| = |\left(x_{1}, \ldots, x_{n}\right)|\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} | distinct(x_{1}, ..x_{_a}.., x_{n})} (|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} | distinct(x_{1}, ..x_{_a}.., x_{n})} (|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|) if n in NaturalPos.
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n} | distinct(x_{1}, ..x_{_a}.., x_{n})} (|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n} | distinct(x_{1}, ..x_{_a}.., x_{n})} (|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> {|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})| if distinct(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Lambda
#    parameters: 23\n   body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 9. {|{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})| if distinct(x_{1}, ..x_{_a}.., x_{n}).
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. |{x_{1}, ..x_{_a}.., x_{n}}| = |(x_{1}, ..x_{_a}.., x_{n})|
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. distinct(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 15
#     operands: 23
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (|{x_{1}, ..x_{_a}.., x_{n}}|, |(x_{1}, ..x_{_a}.., x_{n})|)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. distinct
#     core type: Literal
#     sub-expressions:
# 16. |{x_{1}, ..x_{_a}.., x_{n}}|
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. |(x_{1}, ..x_{_a}.., x_{n})|
#     core type: Operation
#     operator: 20
#     operand: 23
# 18. card
#     core type: Literal
#     sub-expressions:
# 19. {x_{1}, ..x_{_a}.., x_{n}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. length
#     core type: Literal
#     sub-expressions:
# 21. ((x_{1}, ..x_{_a}.., x_{n}))
#     core type: ExprTuple
#     sub-expressions: 23
# 22. Set
#     core type: Literal
#     sub-expressions:
# 23. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 24. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 25. _a -> x_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 28
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. x_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
