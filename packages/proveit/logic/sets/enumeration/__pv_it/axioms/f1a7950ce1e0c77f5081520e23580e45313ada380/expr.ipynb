# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x
from proveit.core_expr_types import y_1_to_n
from proveit.logic import Equals, InSet, Set
from proveit.logic.sets import x_equals_any_y

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y_1_to_n], Equals(InSet(x, Set(y_1_to_n)), x_equals_any_y).with_wrapping_at(2))
# Out:
# expr: (x, y_{1}, ..y_{_a}.., y_{n}) -> ((x in {y_{1}, ..y_{_a}.., y_{n}}) =  \\ ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y_{1}, \ldots, y_{n}\right) \mapsto \left(\begin{array}{c} \left(x \in \left\{y_{1}, \ldots, y_{n}\right\}\right) =  \\ \left(\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right)\right) \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y_{1}, ..y_{_a}.., y_{n}) -> ((x in {y_{1}, ..y_{_a}.., y_{n}}) =  \\ ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 23, 15
# 2. (x in {y_{1}, ..y_{_a}.., y_{n}}) =  \\ ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}))
#    core type: Operation
#    operator: 20
#    operands: 3
# 3. (x in {y_{1}, ..y_{_a}.., y_{n}}, (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in {y_{1}, ..y_{_a}.., y_{n}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {y_{1}, ..y_{_a}.., y_{n}})
#    core type: ExprTuple
#    sub-expressions: 23, 10
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 18
#     end_index: 19
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 27
#     body: 16
# 15. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. x = y_{i}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. _a -> y_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. y_{_a}
#     core type: IndexedVar
# variable: 26
# index: 25
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y_{i}
#     core type: IndexedVar
# variable: 26
# index: 27
# 25. _a
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. i
#     core type: Variable
#     sub-expressions:
