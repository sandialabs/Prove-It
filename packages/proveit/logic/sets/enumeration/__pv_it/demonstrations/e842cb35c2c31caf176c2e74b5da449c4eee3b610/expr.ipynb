# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, a, b, c
from proveit.logic import ProperSubset, Set

# %%
# build up the expression from sub-expressions
expr = ProperSubset(Set(c, b, a), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: {c, b, a} proper_subset _a

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{c, b, a\right\} \subset {_{-}a}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {c, b, a} proper_subset _a
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. ({c, b, a}, _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {c, b, a}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (c, b, a)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
