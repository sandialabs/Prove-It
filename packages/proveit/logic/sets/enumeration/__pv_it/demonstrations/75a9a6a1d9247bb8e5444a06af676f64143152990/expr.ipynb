# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k
from proveit.core_expr_types import Len
from proveit.numbers import five, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([one, three, five, one, five]), Len([ExprRange(k, k, one, five)]))
# Out:
# expr: (|(1, 3, 5, 1, 5)|, |(1, ..k.., 5)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(1, 3, 5, 1, 5\right)|, |\left(1, \ldots, 5\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(1, 3, 5, 1, 5)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(1, 3, 5, 1, 5)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((1, 3, 5, 1, 5))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (1, 3, 5, 1, 5)
#    core type: ExprTuple
#    sub-expressions: 11, 8, 12, 11, 12
# 7. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. 1, ..k.., 5
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 10. k -> k
#     core type: Lambda
#     parameter: 13
#     body: 13
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 5
#     core type: Literal
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
