# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c
from proveit.logic import Set, SubsetEq
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
expr = SubsetEq(Set(a, two, c), Set(a, two, c, one, b, three))
# Out:
# expr: {a, 2, c} subseteq {a, 2, c, 1, b, 3}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a, 2, c\right\} \subseteq \left\{a, 2, c, 1, b, 3\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a, 2, c} subseteq {a, 2, c, 1, b, 3}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. ({a, 2, c}, {a, 2, c, 1, b, 3})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {a, 2, c}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {a, 2, c, 1, b, 3}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, 2, c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (a, 2, c, 1, b, 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
