# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import ProperSubset, Set

# %%
# build up the expression from sub-expressions
expr = ProperSubset(Set(c, b, a), Set(c, b, a, d, e))
# Out:
# expr: {c, b, a} proper_subset {c, b, a, d, e}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{c, b, a\right\} \subset \left\{c, b, a, d, e\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {c, b, a} proper_subset {c, b, a, d, e}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. ({c, b, a}, {c, b, a, d, e})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {c, b, a}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. {c, b, a, d, e}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (c, b, a)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. Set
#    core type: Literal
#    sub-expressions:
# 7. (c, b, a, d, e)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. d
#     core type: Variable
#     sub-expressions:
# 12. e
#     core type: Variable
#     sub-expressions:
