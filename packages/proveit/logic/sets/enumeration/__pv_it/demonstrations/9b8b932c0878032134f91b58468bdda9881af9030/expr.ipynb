# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, d, e
from proveit.logic import Set
from proveit.numbers import four

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Set(a, b, c, d, e), Set(a, b, c, d, four))
# Out:
# expr: ({a, b, c, d, e}, {a, b, c, d, 4})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{a, b, c, d, e\right\}, \left\{a, b, c, d, 4\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({a, b, c, d, e}, {a, b, c, d, 4})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {a, b, c, d, e}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. {a, b, c, d, 4}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, b, c, d, e)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 6
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (a, b, c, d, 4)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 6. e
#    core type: Variable
#    sub-expressions:
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. d
#     core type: Variable
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
