# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, d, e
from proveit.logic import Set
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Set(one, two, three, d, e), Set(two, three, d, one, e))
# Out:
# expr: ({1, 2, 3, d, e}, {2, 3, d, 1, e})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{1, 2, 3, d, e\right\}, \left\{2, 3, d, 1, e\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({1, 2, 3, d, e}, {2, 3, d, 1, e})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {1, 2, 3, d, e}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. {2, 3, d, 1, e}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1, 2, 3, d, e)
#    core type: ExprTuple
#    sub-expressions: 9, 6, 7, 8, 10
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (2, 3, d, 1, e)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10
# 6. 2
#    core type: Literal
#    sub-expressions:
# 7. 3
#    core type: Literal
#    sub-expressions:
# 8. d
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. e
#     core type: Variable
#     sub-expressions:
