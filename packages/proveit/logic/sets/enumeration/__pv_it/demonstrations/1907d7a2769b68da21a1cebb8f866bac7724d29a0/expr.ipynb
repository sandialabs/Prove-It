# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Equals, Set

# %%
# build up the expression from sub-expressions
sub_expr1 = Set()
sub_expr2 = Set(a)
sub_expr3 = Set(b)
sub_expr4 = Set(a, b)
expr = Equals(Set(sub_expr1, sub_expr2, sub_expr3, sub_expr4), Set(sub_expr3, sub_expr1, sub_expr2, sub_expr4))
# Out:
# expr: {{}, {a}, {b}, {a, b}} = {{b}, {}, {a}, {a, b}}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left\{\right\}, \left\{a\right\}, \left\{b\right\}, \left\{a, b\right\}\right\} = \left\{\left\{b\right\}, \left\{\right\}, \left\{a\right\}, \left\{a, b\right\}\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {{}, {a}, {b}, {a, b}} = {{b}, {}, {a}, {a, b}}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ({{}, {a}, {b}, {a, b}}, {{b}, {}, {a}, {a, b}})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {{}, {a}, {b}, {a, b}}
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. {{b}, {}, {a}, {a, b}}
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. ({}, {a}, {b}, {a, b})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 7, 10
# 6. ({b}, {}, {a}, {a, b})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. {b}
#    core type: Operation
#    operator: 12
#    operand: 15
# 8. {}
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. {a}
#    core type: Operation
#    operator: 12
#    operand: 14
# 10. {a, b}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. ()
#     core type: ExprTuple
#     sub-expressions:
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
