# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, b, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import five, one, two

# %%
# build up the expression from sub-expressions
expr = Equals(Len([one, two, one, b, two]), Len([ExprRange(k, k, one, five)]))
# Out:
# expr: |(1, 2, 1, b, 2)| = |(1, ..k.., 5)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(1, 2, 1, b, 2\right)| = |\left(1, \ldots, 5\right)|

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(1, 2, 1, b, 2)| = |(1, ..k.., 5)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(1, 2, 1, b, 2)|, |(1, ..k.., 5)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(1, 2, 1, b, 2)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 5)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((1, 2, 1, b, 2))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 5))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (1, 2, 1, b, 2)
#    core type: ExprTuple
#    sub-expressions: 14, 11, 14, 10, 11
# 9. (1, ..k.., 5)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. 1, ..k.., 5
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
