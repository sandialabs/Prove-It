# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import InSet, Set
from proveit.numbers import five, four, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
expr = InSet(six, Set(one, two, three, four, five, six, seven))
# Out:
# expr: 6 in {1, 2, 3, 4, 5, 6, 7}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# 6 \in \left\{1, 2, 3, 4, 5, 6, 7\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. 6 in {1, 2, 3, 4, 5, 6, 7}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (6, {1, 2, 3, 4, 5, 6, 7})
#    core type: ExprTuple
#    sub-expressions: 11, 3
# 3. {1, 2, 3, 4, 5, 6, 7}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (1, 2, 3, 4, 5, 6, 7)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11, 12
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. 4
#    core type: Literal
#    sub-expressions:
# 10. 5
#     core type: Literal
#     sub-expressions:
# 11. 6
#     core type: Literal
#     sub-expressions:
# 12. 7
#     core type: Literal
#     sub-expressions:
