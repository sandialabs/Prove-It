# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.ProperSubset.html">ProperSubset</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, a, b
from proveit.logic import ProperSubset, Set
from proveit.numbers import one, two

# %%
# build up the expression from sub-expressions
expr = ProperSubset(Variable("_a", latex_format = r"{_{-}a}"), Set(one, a, one, b, two, a))
# Out:
# expr: _a proper_subset {1, a, 1, b, 2, a}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \subset \left\{1, a, 1, b, 2, a\right\}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a proper_subset {1, a, 1, b, 2, a}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. proper_subset
#    core type: Literal
#    sub-expressions:
# 2. (_a, {1, a, 1, b, 2, a})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. _a
#    core type: Variable
#    sub-expressions:
# 4. {1, a, 1, b, 2, a}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (1, a, 1, b, 2, a)
#    core type: ExprTuple
#    sub-expressions: 7, 10, 7, 8, 9, 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
