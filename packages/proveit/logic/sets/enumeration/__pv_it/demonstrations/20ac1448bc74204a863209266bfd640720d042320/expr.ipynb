# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.SubsetEq.html">SubsetEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, d, e
from proveit.logic import Set, SubsetEq
from proveit.numbers import three, two

# %%
# build up the expression from sub-expressions
expr = SubsetEq(Set(two, three, d, e), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: {2, 3, d, e} subseteq _a

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{2, 3, d, e\right\} \subseteq {_{-}a}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {2, 3, d, e} subseteq _a
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. subseteq
#    core type: Literal
#    sub-expressions:
# 2. ({2, 3, d, e}, _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {2, 3, d, e}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (2, 3, d, e)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. d
#    core type: Variable
#    sub-expressions:
# 10. e
#     core type: Variable
#     sub-expressions:
