# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.logic import Boolean, Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Boolean), Or(Equals(x, TRUE), Equals(x, FALSE)))
# Out:
# expr: (x in BOOLEAN, (x = TRUE) or (x = FALSE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \mathbb{B}, \left(x = \top\right) \lor \left(x = \bot\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x in BOOLEAN, (x = TRUE) or (x = FALSE))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x = TRUE) or (x = FALSE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (x, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x = TRUE, x = FALSE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. x = TRUE
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. x = FALSE
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, TRUE)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x, FALSE)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. TRUE
#     core type: Literal
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. FALSE
#     core type: Literal
#     sub-expressions:
