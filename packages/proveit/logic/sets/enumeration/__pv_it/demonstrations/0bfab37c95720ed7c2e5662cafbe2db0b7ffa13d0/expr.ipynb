# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c
from proveit.logic import Set
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Set(one, a, two, b, three, c), Set(a, two, c, one, b, three))
# Out:
# expr: ({1, a, 2, b, 3, c}, {a, 2, c, 1, b, 3})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left\{1, a, 2, b, 3, c\right\}, \left\{a, 2, c, 1, b, 3\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ({1, a, 2, b, 3, c}, {a, 2, c, 1, b, 3})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {1, a, 2, b, 3, c}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. {a, 2, c, 1, b, 3}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1, a, 2, b, 3, c)
#    core type: ExprTuple
#    sub-expressions: 9, 6, 7, 10, 11, 8
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (a, 2, c, 1, b, 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
