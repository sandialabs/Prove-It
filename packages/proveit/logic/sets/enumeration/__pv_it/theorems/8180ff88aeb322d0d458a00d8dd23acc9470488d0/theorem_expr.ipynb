# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonmembership_unfold_singleton">nonmembership_unfold_singleton</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import nonmembership_unfold_singleton

# %%
# check that the built expression is the same as the stored expression
assert nonmembership_unfold_singleton.expr == stored_expr
assert nonmembership_unfold_singleton.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonmembership_unfold_singleton matches stored_expr")
# Out:
# Passed sanity check: nonmembership_unfold_singleton matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonmembership_unfold_singleton.latex())
# Out:
# \vdash \forall_{x, y~|~x \notin \left\{y\right\}}~\left(x \neq y\right)

# %%
# display the expression information
nonmembership_unfold_singleton.expr_info()
# Out:
# 0. forall_{x, y | x not-in {y}} (x != y)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {x != y if x not-in {y}.
#    core type: Lambda
#    parameters: 7\n   body: 3
# 3. {x != y if x not-in {y}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x != y
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x not-in {y}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. !=
#    core type: Literal
#    sub-expressions:
# 7. (x, y)
#    core type: ExprTuple
#    sub-expressions: 10, 13
# 8. not-in
#    core type: Literal
#    sub-expressions:
# 9. (x, {y})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. {y}
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
