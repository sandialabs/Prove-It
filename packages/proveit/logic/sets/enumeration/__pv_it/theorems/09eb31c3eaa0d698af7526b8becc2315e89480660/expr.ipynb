# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n, x
from proveit.core_expr_types import y_1_to_n
from proveit.logic import Forall, InSet, NotInSet, Set
from proveit.logic.sets import x_notequals_all_y
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([x, y_1_to_n], x_notequals_all_y, condition = NotInSet(x, Set(y_1_to_n))), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x not-in {y_{1}, ..y_{_a}.., y_{n}}} ((x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})) if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x, y_{1}, \ldots, y_{n}~|~x \notin \left\{y_{1}, \ldots, y_{n}\right\}}~\left(\left(x \neq y_{1}\right) \land \ldots \land \left(x \neq y_{n}\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x not-in {y_{1}, ..y_{_a}.., y_{n}}} ((x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})) if n in Natural.
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x not-in {y_{1}, ..y_{_a}.., y_{n}}} ((x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})) if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x, y_{1}, ..y_{_a}.., y_{n} | x not-in {y_{1}, ..y_{_a}.., y_{n}}} ((x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 28, 10
# 8. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 29, 23
# 9. {(x != y_{1}) and ..(x != y_{i}).. and (x != y_{n}) if x not-in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. (x != y_{1}) and ..(x != y_{i}).. and (x != y_{n})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. x not-in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (x != y_{1}, ..x != y_{i}.., x != y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. not-in
#     core type: Literal
#     sub-expressions:
# 16. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 29, 18
# 17. (x != y_{1}), ..(x != y_{i}).., (x != y_{n})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 27
#     end_index: 28
# 18. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. i -> (x != y_{i})
#     core type: Lambda
#     parameter: 32
#     body: 22
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 22. x != y_{i}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 24. !=
#     core type: Literal
#     sub-expressions:
# 25. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. _a -> y_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 31
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. y_{i}
#     core type: IndexedVar
# variable: 33
# index: 32
# 31. y_{_a}
#     core type: IndexedVar
# variable: 33
# index: 34
# 32. i
#     core type: Variable
#     sub-expressions:
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. _a
#     core type: Variable
#     sub-expressions:
