# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k
from proveit.logic import Equals, Set

# %%
# build up the expression from sub-expressions
expr = Lambda([a_1_to_i, x, b_1_to_j, c_1_to_k], Equals(Set(a_1_to_i, x, b_1_to_j, x, c_1_to_k), Set(a_1_to_i, x, b_1_to_j, c_1_to_k)))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right) \mapsto \left(\left\{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, x, c_{1}, \ldots, c_{k}\right\} = \left\{a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right\}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}})
#    core type: Lambda
#    parameters: 8\n   body: 1
# 1. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}} = {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. ({a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}, {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k}}
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. {a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, x, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 10, 12
# 7. Set
#    core type: Literal
#    sub-expressions:
# 8. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 18
#    end_index: 14
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 18
#     end_index: 16
# 12. c_{1}, ..c_{_a}.., c_{k}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 13. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 20
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. _a -> b_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 21
# 16. j
#     core type: Variable
#     sub-expressions:
# 17. _a -> c_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. a_{_a}
#     core type: IndexedVar
# variable: 23
# index: 26
# 21. b_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 22. c_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
