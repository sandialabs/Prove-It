# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P, Px, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import And, Forall, Set

# %%
# build up the expression from sub-expressions
expr = Forall([P], And(Pk_a1_to_an), condition = Forall([x], Px, domains = [Set(a_1_to_n)]))
# Out:
# expr: forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P~|~\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)}~\left(P(a_{1}) \land \ldots \land P(a_{n})\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#    core type: Lambda
#    parameter: 19
#    body: 10
# 9. P(a_{1}), ..P(a_{k}).., P(a_{n})
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 26
#    end_index: 27
# 10. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. k -> P(a_{k})
#     core type: Lambda
#     parameter: 21
#     body: 14
# 12. P(x)
#     core type: Operation
#     operator: 17
#     operand: 19
# 13. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. P(a_{k})
#     core type: Operation
#     operator: 17
#     operand: 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. P
#     core type: Variable
#     sub-expressions:
# 18. a_{k}
#     core type: IndexedVar
# variable: 29
# index: 21
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. k
#     core type: Variable
#     sub-expressions:
# 22. Set
#     core type: Literal
#     sub-expressions:
# 23. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 24. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 25. _a -> a_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 28
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. a_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
