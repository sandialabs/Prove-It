# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.core_expr_types import a_1_to_i, b_1_to_j, c_1_to_k

# %%
# build up the expression from sub-expressions
expr = ExprTuple(a_1_to_i, x, b_1_to_j, c_1_to_k)
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{i}, x, b_{1}, \ldots, b_{j}, c_{1}, \ldots, c_{k}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a_{1}, ..a_{_a}.., a_{i}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 10
#    end_index: 6
# 2. x
#    core type: Variable
#    sub-expressions:
# 3. b_{1}, ..b_{_a}.., b_{j}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 10
#    end_index: 8
# 4. c_{1}, ..c_{_a}.., c_{k}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 5. _a -> a_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 12
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. _a -> b_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 13
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. _a -> c_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 14
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. a_{_a}
#     core type: IndexedVar
# variable: 15
# index: 18
# 13. b_{_a}
#     core type: IndexedVar
# variable: 16
# index: 18
# 14. c_{_a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
