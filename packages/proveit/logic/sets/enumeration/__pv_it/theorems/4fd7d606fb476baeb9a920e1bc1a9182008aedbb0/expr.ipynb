# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, P, Px, Q, Qx, n, x
from proveit.core_expr_types import Qk_implies_Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a_1_to_n], Forall([P, Q], Forall([x], Px, domains = [Set(a_1_to_n)], condition = Qx), condition = Qk_implies_Pk_a1_to_an)), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P, Q~|~Q(a_{1}) \Rightarrow P(a_{1}), \ldots, Q(a_{n}) \Rightarrow P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}~|~Q(x)}~P(x)\right]\right] \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Lambda
#    parameter: 43
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Operation
#    operator: 13
#    operand: 4
# 3. n in Natural
#    core type: Operation
#    operator: 28
#    operands: 5
# 4. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Lambda
#    parameters: 38\n   body: 6
# 5. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 43, 7
# 6. forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]
#    core type: Operation
#    operator: 13
#    operand: 8
# 7. Natural
#    core type: Literal
#    sub-expressions:
# 8. (P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 9. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 35, 34
# 10. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n}))
#     core type: Operation
#     operator: 21
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Lambda
#     parameter: 32
#     body: 16
# 15. (Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 17
# 16. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 42
#     end_index: 43
# 18. P(x)
#     core type: Operation
#     operator: 35
#     operand: 32
# 19. (x in {a_{1}, ..a_{_a}.., a_{n}}) and Q(x)
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. k -> (Q(a_{k}) => P(a_{k}))
#     core type: Lambda
#     parameter: 39
#     body: 23
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. (x in {a_{1}, ..a_{_a}.., a_{n}}, Q(x))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. Q(a_{k}) => P(a_{k})
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. Q(x)
#     core type: Operation
#     operator: 34
#     operand: 32
# 26. =>
#     core type: Literal
#     sub-expressions:
# 27. (Q(a_{k}), P(a_{k}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. Q(a_{k})
#     core type: Operation
#     operator: 34
#     operand: 36
# 31. P(a_{k})
#     core type: Operation
#     operator: 35
#     operand: 36
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. Q
#     core type: Variable
#     sub-expressions:
# 35. P
#     core type: Variable
#     sub-expressions:
# 36. a_{k}
#     core type: IndexedVar
# variable: 45
# index: 39
# 37. Set
#     core type: Literal
#     sub-expressions:
# 38. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 39. k
#     core type: Variable
#     sub-expressions:
# 40. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 44
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. a_{_a}
#     core type: IndexedVar
# variable: 45
# index: 46
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. _a
#     core type: Variable
#     sub-expressions:
