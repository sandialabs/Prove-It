# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x
from proveit.core_expr_types import y_1_to_n
from proveit.logic import Boolean, InSet, NotInSet, Set

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y_1_to_n], InSet(NotInSet(x, Set(y_1_to_n)), Boolean))
# Out:
# expr: (x, y_{1}, ..y_{_a}.., y_{n}) -> ((x not-in {y_{1}, ..y_{_a}.., y_{n}}) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y_{1}, \ldots, y_{n}\right) \mapsto \left(\left(x \notin \left\{y_{1}, \ldots, y_{n}\right\}\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y_{1}, ..y_{_a}.., y_{n}) -> ((x not-in {y_{1}, ..y_{_a}.., y_{n}}) in BOOLEAN)
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 2. (x not-in {y_{1}, ..y_{_a}.., y_{n}}) in BOOLEAN
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (x not-in {y_{1}, ..y_{_a}.., y_{n}}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. x not-in {y_{1}, ..y_{_a}.., y_{n}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 7. not-in
#    core type: Literal
#    sub-expressions:
# 8. (x, {y_{1}, ..y_{_a}.., y_{n}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 13. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 14. _a -> y_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. y_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
