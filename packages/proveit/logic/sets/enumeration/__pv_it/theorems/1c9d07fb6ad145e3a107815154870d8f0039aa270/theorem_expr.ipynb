# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#reduction_right">reduction_right</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import reduction_right

# %%
# check that the built expression is the same as the stored expression
assert reduction_right.expr == stored_expr
assert reduction_right.expr._style_id == stored_expr._style_id
print("Passed sanity check: reduction_right matches stored_expr")
# Out:
# Passed sanity check: reduction_right matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{i}, x, b_{1}, b_{2}, \ldots, b_{j}, c_{1}, c_{2}, \ldots, c_{k}}~\left(\begin{array}{c} \begin{array}{l} \left\{a_{1}, a_{2}, \ldots, a_{i}, x,b_{1}, b_{2}, \ldots, b_{j}, x,c_{1}, c_{2}, \ldots, c_{k}\right\} =  \\ \left\{a_{1}, a_{2}, \ldots, a_{i}, x,b_{1}, b_{2}, \ldots, b_{j},c_{1}, c_{2}, \ldots, c_{k}\right\} \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}} ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}} ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (i, j, k) -> {forall_{a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}} ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 33, 35, 38
# 4. {forall_{a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}} ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}} ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}})
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (i in Natural, j in Natural, k in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (a_{1}, a_{2}, ..., a_{i}, x, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k}) -> ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}})
#     core type: Lambda
#     parameters: 27\n    body: 15
# 12. i in Natural
#     core type: Operation
#     operator: 18
#     operands: 16
# 13. j in Natural
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. k in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}} =  \\ {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 17. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 38, 22
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. ({a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}}, {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k}}
#     core type: Operation
#     operator: 26
#     operands: 25
# 24. {a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j}, x,c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 29, 31
# 26. Set
#     core type: Literal
#     sub-expressions:
# 27. (a_{1}, a_{2}, ..., a_{i}, x,b_{1}, b_{2}, ..., b_{j},c_{1}, c_{2}, ..., c_{k})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 31
# 28. a_{1}, a_{2}, ..., a_{i}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 37
#     end_index: 33
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 37
#     end_index: 35
# 31. c_{1}, c_{2}, ..., c_{k}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 32. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 39
# 33. i
#     core type: Variable
#     sub-expressions:
# 34. _a -> b_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 40
# 35. j
#     core type: Variable
#     sub-expressions:
# 36. _a -> c_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 41
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. k
#     core type: Variable
#     sub-expressions:
# 39. a_{_a}
#     core type: IndexedVar
# variable: 42
# index: 46
# 40. b_{_a}
#     core type: IndexedVar
# variable: 43
# index: 46
# 41. c_{_a}
#     core type: IndexedVar
# variable: 44
# index: 46
# 42. a
#     core type: Variable
#     sub-expressions:
# 43. b
#     core type: Variable
#     sub-expressions:
# 44. c
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 46. _a
#     core type: Variable
#     sub-expressions:
