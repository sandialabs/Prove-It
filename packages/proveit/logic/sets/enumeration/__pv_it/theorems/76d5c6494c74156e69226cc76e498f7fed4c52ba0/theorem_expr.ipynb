# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_for_each_is_true_for_all">true_for_each_is_true_for_all</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import true_for_each_is_true_for_all

# %%
# check that the built expression is the same as the stored expression
assert true_for_each_is_true_for_all.expr == stored_expr
assert true_for_each_is_true_for_all.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_for_each_is_true_for_all matches stored_expr")
# Out:
# Passed sanity check: true_for_each_is_true_for_all matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, a_{2}, \ldots, a_{n}}~\left[\forall_{P}~\left(\left(P\left(a_{1}\right) \land  P\left(a_{2}\right) \land  \ldots \land  P\left(a_{n}\right)\right) = \left[\forall_{x \in \left\{a_{1}, a_{2}, \ldots, a_{n}\right\}}~P\left(x\right)\right]\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])]]
#    core type: Operation
#    operator: 22
#    operand: 2
# 1. (n -> {forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])] if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])] if n in Natural.
#    core type: Lambda
#    parameter: 43
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 43
# 4. {forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])] if n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])]
#    core type: Operation
#    operator: 22
#    operand: 9
# 6. n in Natural
#    core type: Operation
#    operator: 34
#    operands: 8
# 7. ((a_{1}, a_{2}, ..., a_{n}) -> [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])])
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 43, 10
# 9. (a_{1}, a_{2}, ..., a_{n}) -> [forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])]
#    core type: Lambda
#    parameters: 39\n   body: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. forall_{P} ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])
#     core type: Operation
#     operator: 22
#     operand: 13
# 12. (P -> ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]))
#     core type: ExprTuple
#     sub-expressions: 13
# 13. P -> ((P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)])
#     core type: Lambda
#     parameter: 32
#     body: 15
# 14. (P)
#     core type: ExprTuple
#     sub-expressions: 32
# 15. (P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})) = [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n}), forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. P(a_{1}) and  P(a_{2}) and  ... and  P(a_{n})
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)
#     core type: Operation
#     operator: 22
#     operand: 25
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (P(a_{1}), P(a_{2}), ..., P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. (x -> {P(x) if x in {a_{1}, a_{2}, ..., a_{n}}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. P(a_{1}), P(a_{2}), ..., P(a_{n})
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 42
#     end_index: 43
# 25. x -> {P(x) if x in {a_{1}, a_{2}, ..., a_{n}}.
#     core type: Lambda
#     parameter: 36
#     body: 27
# 26. _a -> P(a_{_a})
#     core type: Lambda
#     parameter: 47
#     body: 28
# 27. {P(x) if x in {a_{1}, a_{2}, ..., a_{n}}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. P(a_{_a})
#     core type: Operation
#     operator: 32
#     operand: 44
# 29. P(x)
#     core type: Operation
#     operator: 32
#     operand: 36
# 30. x in {a_{1}, a_{2}, ..., a_{n}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 44
# 32. P
#     core type: Variable
#     sub-expressions:
# 33. (x)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (x, {a_{1}, a_{2}, ..., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. {a_{1}, a_{2}, ..., a_{n}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Set
#     core type: Literal
#     sub-expressions:
# 39. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 40
# 40. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 41. _a -> a_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 44
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. a_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 45. a
#     core type: Variable
#     sub-expressions:
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 47
# 47. _a
#     core type: Variable
#     sub-expressions:
