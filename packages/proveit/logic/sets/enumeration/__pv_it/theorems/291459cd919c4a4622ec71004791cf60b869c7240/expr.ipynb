# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Px, n, x
from proveit.core_expr_types import Pk_a1_to_an, a_1_to_n
from proveit.logic import And, Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_n], Forall([P], And(Pk_a1_to_an), condition = Forall([x], Px, domains = [Set(a_1_to_n)]))), InSet(n, Natural))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P~|~\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)}~\left(P(a_{1}) \land \ldots \land P(a_{n})\right)\right] \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))] if n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]
#    core type: Operation
#    operator: 13
#    operand: 3
# 2. n in Natural
#    core type: Operation
#    operator: 21
#    operands: 4
# 3. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))]
#    core type: Lambda
#    parameters: 29\n   body: 5
# 4. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 33, 6
# 5. forall_{P | forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)} (P(a_{1}) and ..P(a_{k}).. and P(a_{n}))
#    core type: Operation
#    operator: 13
#    operand: 7
# 6. Natural
#    core type: Literal
#    sub-expressions:
# 7. P -> {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Lambda
#    parameter: 23
#    body: 8
# 8. {P(a_{1}) and ..P(a_{k}).. and P(a_{n}) if forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Lambda
#     parameter: 25
#     body: 16
# 15. P(a_{1}), ..P(a_{k}).., P(a_{n})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 32
#     end_index: 33
# 16. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. k -> P(a_{k})
#     core type: Lambda
#     parameter: 27
#     body: 20
# 18. P(x)
#     core type: Operation
#     operator: 23
#     operand: 25
# 19. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. P(a_{k})
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. P
#     core type: Variable
#     sub-expressions:
# 24. a_{k}
#     core type: IndexedVar
# variable: 35
# index: 27
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. k
#     core type: Variable
#     sub-expressions:
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 30. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 31. _a -> a_{_a}
#     core type: Lambda
#     parameter: 36
#     body: 34
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
# 34. a_{_a}
#     core type: IndexedVar
# variable: 35
# index: 36
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. _a
#     core type: Variable
#     sub-expressions:
