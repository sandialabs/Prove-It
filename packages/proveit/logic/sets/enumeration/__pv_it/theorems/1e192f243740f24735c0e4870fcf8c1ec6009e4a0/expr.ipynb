# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Pk_a1_to_an
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = And(Pk_a1_to_an)
# Out:
# expr: P(a_{1}) and ..P(a_{k}).. and P(a_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# P(a_{1}) \land \ldots \land P(a_{n})

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. P(a_{1}) and ..P(a_{k}).. and P(a_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (P(a_{1}), ..P(a_{k}).., P(a_{n}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. P(a_{1}), ..P(a_{k}).., P(a_{n})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. k -> P(a_{k})
#    core type: Lambda
#    parameter: 11
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. P(a_{k})
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. a_{k}
#    core type: IndexedVar
# variable: 10
# index: 11
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. k
#     core type: Variable
#     sub-expressions:
