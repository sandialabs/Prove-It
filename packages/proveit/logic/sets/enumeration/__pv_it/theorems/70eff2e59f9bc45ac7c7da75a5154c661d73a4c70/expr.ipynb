# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Px, x
from proveit.core_expr_types import a_1_to_n
from proveit.logic import FALSE, Forall, Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], Px, domains = [Set(a_1_to_n)]), FALSE)
# Out:
# expr: (forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x), FALSE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x), \bot\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x), FALSE)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. FALSE
#    core type: Literal
#    sub-expressions:
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#    core type: Lambda
#    parameter: 11
#    body: 5
# 5. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. P(x)
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. x in {a_{1}, ..a_{_a}.., a_{n}}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 15. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 16. _a -> a_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. a_{_a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. _a
#     core type: Variable
#     sub-expressions:
