# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# Automation is not needed when only showing a stored proof:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td><a name="proveit.logic.sets.enumeration.theorems.1c9b39053242eb1eb56a84f2ee5a5a97bdc038f10_step0">0</a></td><td>theorem</td><td></td><td><span style="font-size:20px;"> <a class="ProveItLink" href="../../../_theory_nbs_/proofs/true_for_each_then_true_for_all_conditioned/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../ae433f6af9f48bd7ab354afeb28e5b88223998220/expr.ipynb"><img src="../ae433f6af9f48bd7ab354afeb28e5b88223998220/expr.png" style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# <tr><td>&nbsp;</td><td colspan=4 style-"text-align:left"><a class="ProveItLink" href="../../../_theory_nbs_/proofs/true_for_each_then_true_for_all_conditioned/thm_proof.ipynb">proveit.logic.sets.enumeration.true_for_each_then_true_for_all_conditioned</a></td></tr></table>
