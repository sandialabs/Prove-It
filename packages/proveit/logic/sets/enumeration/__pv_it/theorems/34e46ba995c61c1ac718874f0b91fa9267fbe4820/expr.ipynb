# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, Px, Q, Qx, n, x
from proveit.core_expr_types import Qk_implies_Pk_a1_to_an, a_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_n], Forall([P, Q], Forall([x], Px, domains = [Set(a_1_to_n)], condition = Qx), condition = Qk_implies_Pk_a1_to_an)), InSet(n, Natural))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P, Q~|~Q(a_{1}) \Rightarrow P(a_{1}), \ldots, Q(a_{n}) \Rightarrow P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}~|~Q(x)}~P(x)\right]\right] \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]] if n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Operation
#    operator: 12
#    operand: 3
# 2. n in Natural
#    core type: Operation
#    operator: 27
#    operands: 4
# 3. (a_{1}, ..a_{_a}.., a_{n}) -> [forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]]
#    core type: Lambda
#    parameters: 37\n   body: 5
# 4. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 42, 6
# 5. forall_{P, Q | Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)]
#    core type: Operation
#    operator: 12
#    operand: 7
# 6. Natural
#    core type: Literal
#    sub-expressions:
# 7. (P, Q) -> {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 8. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 34, 33
# 9. {forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x) if (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n})).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. forall_{x in {a_{1}, ..a_{_a}.., a_{n}} | Q(x)} P(x)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. (Q(a_{1}) => P(a_{1})) and ..(Q(a_{k}) => P(a_{k})).. and (Q(a_{n}) => P(a_{n}))
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. x -> {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Lambda
#     parameter: 31
#     body: 15
# 14. (Q(a_{1}) => P(a_{1}), ..Q(a_{k}) => P(a_{k}).., Q(a_{n}) => P(a_{n}))
#     core type: ExprTuple
#     sub-expressions: 16
# 15. {P(x) if x in {a_{1}, ..a_{_a}.., a_{n}} ,  Q(x).
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. (Q(a_{1}) => P(a_{1})), ..(Q(a_{k}) => P(a_{k})).., (Q(a_{n}) => P(a_{n}))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 41
#     end_index: 42
# 17. P(x)
#     core type: Operation
#     operator: 34
#     operand: 31
# 18. (x in {a_{1}, ..a_{_a}.., a_{n}}) and Q(x)
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. k -> (Q(a_{k}) => P(a_{k}))
#     core type: Lambda
#     parameter: 38
#     body: 22
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (x in {a_{1}, ..a_{_a}.., a_{n}}, Q(x))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. Q(a_{k}) => P(a_{k})
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. x in {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. Q(x)
#     core type: Operation
#     operator: 33
#     operand: 31
# 25. =>
#     core type: Literal
#     sub-expressions:
# 26. (Q(a_{k}), P(a_{k}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (x, {a_{1}, ..a_{_a}.., a_{n}})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. Q(a_{k})
#     core type: Operation
#     operator: 33
#     operand: 35
# 30. P(a_{k})
#     core type: Operation
#     operator: 34
#     operand: 35
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. {a_{1}, ..a_{_a}.., a_{n}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. Q
#     core type: Variable
#     sub-expressions:
# 34. P
#     core type: Variable
#     sub-expressions:
# 35. a_{k}
#     core type: IndexedVar
# variable: 44
# index: 38
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 38. k
#     core type: Variable
#     sub-expressions:
# 39. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 40. _a -> a_{_a}
#     core type: Lambda
#     parameter: 45
#     body: 43
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. a_{_a}
#     core type: IndexedVar
# variable: 44
# index: 45
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
