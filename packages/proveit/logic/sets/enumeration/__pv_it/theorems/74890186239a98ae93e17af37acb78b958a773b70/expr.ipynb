# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, i, j, k
from proveit.core_expr_types import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, Forall, InSet, Set
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Lambda([i, j, k], Conditional(Forall([a_1_to_i, b, c_1_to_j, d_1_to_k], Equals(Set(a_1_to_i, b, c_1_to_j, d_1_to_k), Set(a_1_to_i, c_1_to_j, b, d_1_to_k))), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural))))
# Out:
# expr: (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}}) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i, j, k\right) \mapsto \left\{\forall_{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k}}~\left(\left\{a_{1}, \ldots, a_{i}, b, c_{1}, \ldots, c_{j}, d_{1}, \ldots, d_{k}\right\} = \left\{a_{1}, \ldots, a_{i}, c_{1}, \ldots, c_{j}, b, d_{1}, \ldots, d_{k}\right\}\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i, j, k) -> {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (i, j, k)
#    core type: ExprTuple
#    sub-expressions: 30, 32, 35
# 2. {forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}}) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (i in Natural) and (j in Natural) and (k in Natural)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}) -> ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}})
#    core type: Lambda
#    parameters: 22\n   body: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (i in Natural, j in Natural, k in Natural)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. {a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}} = {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. i in Natural
#     core type: Operation
#     operator: 17
#     operands: 15
# 11. j in Natural
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. k in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ({a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}}, {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (i, Natural)
#     core type: ExprTuple
#     sub-expressions: 30, 21
# 16. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 35, 21
# 19. {a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k}}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. {a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 27, 26, 28
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 25. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 34
#     end_index: 30
# 26. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 34
#     end_index: 32
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 36
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. _a -> c_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 37
# 32. j
#     core type: Variable
#     sub-expressions:
# 33. _a -> d_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 38
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. a_{_a}
#     core type: IndexedVar
# variable: 39
# index: 42
# 37. c_{_a}
#     core type: IndexedVar
# variable: 40
# index: 42
# 38. d_{_a}
#     core type: IndexedVar
# variable: 41
# index: 42
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. c
#     core type: Variable
#     sub-expressions:
# 41. d
#     core type: Variable
#     sub-expressions:
# 42. _a
#     core type: Variable
#     sub-expressions:
