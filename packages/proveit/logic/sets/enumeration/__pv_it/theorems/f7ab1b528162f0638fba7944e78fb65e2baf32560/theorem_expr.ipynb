# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#true_for_each_then_true_for_all">true_for_each_then_true_for_all</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.sets.enumeration import true_for_each_then_true_for_all

# %%
# check that the built expression is the same as the stored expression
assert true_for_each_then_true_for_all.expr == stored_expr
assert true_for_each_then_true_for_all.expr._style_id == stored_expr._style_id
print("Passed sanity check: true_for_each_then_true_for_all matches stored_expr")
# Out:
# Passed sanity check: true_for_each_then_true_for_all matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(true_for_each_then_true_for_all.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n}}~\left[\forall_{P~|~P(a_{1}), \ldots, P(a_{n})}~\left[\forall_{x \in \left\{a_{1}, \ldots, a_{n}\right\}}~P(x)\right]\right]\right]

# %%
# display the expression information
true_for_each_then_true_for_all.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]]]
#    core type: Operation
#    operator: 13
#    operand: 1
# 1. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]] if n in Natural.
#    core type: Lambda
#    parameter: 35
#    body: 2
# 2. {forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]] if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1}, ..a_{_a}.., a_{n}} [forall_{P | P(a_{1}), ..P(a_{k}).., P(a_{n})} [forall_{x in {a_{1}, ..a_{_a}.., a_{n}}} P(x)]]
#    core type: Operation
#    operator: 13
#    operand: 5
# 4. n in Natural
#    core type: Operation
#    operator: 22
#    operands: 6
# ...
