# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n
from proveit.logic import And, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = And(InSet(m, Natural), InSet(n, Natural))
# Out:
# expr: (m in Natural) and (n in Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m \in \mathbb{N}\right) \land \left(n \in \mathbb{N}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. m in Natural
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. n in Natural
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (m, Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. Natural
#     core type: Literal
#     sub-expressions:
