# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b
from proveit.core_expr_types import a_1_to_m, c_1_to_n
from proveit.logic import NotInSet, ProperSubset, Set

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(a_1_to_m)
expr = Lambda([a_1_to_m, b, c_1_to_n], Conditional(ProperSubset(sub_expr1, Set(a_1_to_m, b, c_1_to_n)), NotInSet(b, sub_expr1)))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}) -> {{a_{1}, ..a_{_a}.., a_{m}} proper_subset {a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} if b not-in {a_{1}, ..a_{_a}.., a_{m}}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}\right) \mapsto \left\{\left\{a_{1}, \ldots, a_{m}\right\} \subset \left\{a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}\right\} \textrm{ if } b \notin \left\{a_{1}, \ldots, a_{m}\right\}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}) -> {{a_{1}, ..a_{_a}.., a_{m}} proper_subset {a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} if b not-in {a_{1}, ..a_{_a}.., a_{m}}.
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. {{a_{1}, ..a_{_a}.., a_{m}} proper_subset {a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}} if b not-in {a_{1}, ..a_{_a}.., a_{m}}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. {a_{1}, ..a_{_a}.., a_{m}} proper_subset {a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. b not-in {a_{1}, ..a_{_a}.., a_{m}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. proper_subset
#    core type: Literal
#    sub-expressions:
# 5. ({a_{1}, ..a_{_a}.., a_{m}}, {a_{1}, ..a_{_a}.., a_{m}, b, c_{1}, ..c_{_a}.., c_{n}})
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. not-in
#    core type: Literal
#    sub-expressions:
# ...
