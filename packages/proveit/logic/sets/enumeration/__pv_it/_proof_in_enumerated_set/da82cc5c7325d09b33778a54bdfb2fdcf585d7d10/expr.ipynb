# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, b, c, k, n
from proveit.logic import Boolean, Equals, InSet
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprRange(k, InSet(Equals(b, IndexedVar(c, k)), Boolean), one, n)
# Out:
# expr: ((b = c_{1}) in BOOLEAN), ..((b = c_{k}) in BOOLEAN).., ((b = c_{n}) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(b = c_{1}\right) \in \mathbb{B}\right), \ldots, \left(\left(b = c_{n}\right) \in \mathbb{B}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((b = c_{1}) in BOOLEAN), ..((b = c_{k}) in BOOLEAN).., ((b = c_{n}) in BOOLEAN)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> ((b = c_{k}) in BOOLEAN)
#    core type: Lambda
#    parameter: 14
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. (b = c_{k}) in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b = c_{k}, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b = c_{k}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (b, c_{k})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. c_{k}
#     core type: IndexedVar
# variable: 13
# index: 14
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. k
#     core type: Variable
#     sub-expressions:
