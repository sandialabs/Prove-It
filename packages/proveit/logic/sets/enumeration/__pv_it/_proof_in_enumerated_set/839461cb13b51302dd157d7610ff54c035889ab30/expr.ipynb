# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, b, c, k, m, n, x
from proveit.core_expr_types import Len
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(x, IndexedVar(a, x), one, m), b, ExprRange(x, IndexedVar(c, x), one, n)]), Len([ExprRange(a, a, one, k)]))
# Out:
# expr: (|(a_{1}, ..a_{x}.., a_{m}, b, c_{1}, ..c_{x}.., c_{n})|, |(1, ..a.., k)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{1}, \ldots, a_{m}, b, c_{1}, \ldots, c_{n}\right)|, |\left(1, \ldots, k\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a_{1}, ..a_{x}.., a_{m}, b, c_{1}, ..c_{x}.., c_{n})|, |(1, ..a.., k)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a_{1}, ..a_{x}.., a_{m}, b, c_{1}, ..c_{x}.., c_{n})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..a.., k)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a_{1}, ..a_{x}.., a_{m}, b, c_{1}, ..c_{x}.., c_{n}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..a.., k))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a_{1}, ..a_{x}.., a_{m}, b, c_{1}, ..c_{x}.., c_{n})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (1, ..a.., k)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. a_{1}, ..a_{x}.., a_{m}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 17
#    end_index: 13
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c_{1}, ..c_{x}.., c_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 17
#     end_index: 15
# 11. 1, ..a.., k
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 12. x -> a_{x}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. x -> c_{x}
#     core type: Lambda
#     parameter: 23
#     body: 20
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. a -> a
#     core type: Lambda
#     parameter: 21
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. a_{x}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. c_{x}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. x
#     core type: Variable
#     sub-expressions:
