# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, i, k, x, y
from proveit.logic import Equals, Or
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Or(ExprRange(i, Equals(x, IndexedVar(y, i)), one, k))
# Out:
# expr: (x = y_{1}) or ..(x = y_{i}).. or (x = y_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{k}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{k})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. (x = y_{1}, ..x = y_{i}.., x = y_{k})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x = y_{1}), ..(x = y_{i}).., (x = y_{k})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. i -> (x = y_{i})
#    core type: Lambda
#    parameter: 13
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. k
#    core type: Variable
#    sub-expressions:
# 7. x = y_{i}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (x, y_{i})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. y_{i}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. y
#     core type: Variable
#     sub-expressions:
# 13. i
#     core type: Variable
#     sub-expressions:
