# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = Equals(Add(m, one, Add(n, Neg(one), one)), Add(m, one, n))
# Out:
# expr: (m + 1 + (n - 1 + 1)) = (m + 1 + n)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m + 1 + \left(n - 1 + 1\right)\right) = \left(m + 1 + n\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m + 1 + (n - 1 + 1)) = (m + 1 + n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (m + 1 + (n - 1 + 1), m + 1 + n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. m + 1 + (n - 1 + 1)
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. m + 1 + n
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (m, 1, n - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 8, 14, 7
# 6. (m, 1, n)
#    core type: ExprTuple
#    sub-expressions: 8, 14, 11
# 7. n - 1 + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (n, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 14
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
