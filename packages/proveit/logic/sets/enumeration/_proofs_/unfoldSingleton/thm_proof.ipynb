# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">enumeration</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfoldSingleton">unfoldSingleton</a> theorem
# ========
# *** see <a href="../__pv_it/388ccdf8814b17c34471b9f6668be0ca49d21e5f0/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving unfoldSingleton
