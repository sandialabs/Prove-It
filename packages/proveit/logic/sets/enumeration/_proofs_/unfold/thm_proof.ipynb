# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">enumeration</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfold">unfold</a> theorem
# ========
# *** see <a href="../__pv_it/b4e0e013be878a4c77f8dbfff5095973b7bbdd180/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit import defaults
from proveit._common_ import x
from proveit.logic.sets.enumeration._axioms_ import enumSetDef

# %%
# %proving unfold

# %%
defaults.assumptions = unfold.allConditions()

# %%
enumSetDef

# %%
#enumSetDef.instantiate({x:x, yy:yy})

# %%
#%qed
