# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">sets</a>.<a class="ProveItLink" href="../../_theory_.ipynb">enumeration</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#fold_singleton">fold_singleton</a> theorem
# ========
# *** see <a href="../__pv_it/d7a9db2d1feeaa5118756db70085b31517897b790/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving fold_singleton
