# %% [markdown]
# Context: <a href="../../../_context_.ipynb" class="ProveItLink">proveit</a>.<a href="../../_context_.ipynb" class="ProveItLink">logic</a>.<a href="../_context_.ipynb" class="ProveItLink">set_theory</a>.unification
# ========
#
# Unification is an operation for building a set that includes all elements of some number of sets.  For example, $A \cup B \cup C$ is the set that includes all members of $A$, $B$, $C$, and no other members.

# %%
import proveit
# %context
