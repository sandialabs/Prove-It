# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import InSet, Union
from proveit.logic.set_theory._common_ import x_in_any_A

# %%
# build up the expression from sub-expressions
expr = Lambda([x, A_1_to_m], Conditional(x_in_any_A, InSet(x, Union(A_1_to_m))))
# Out:
# expr: (x, A_{1}, ..A_{_a}.., A_{m}) -> {(x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}) if x in (A_{1} union ..A_{_a}.. union A_{m}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, A_{1}, \ldots, A_{m}\right) \mapsto \left\{\left(x \in A_{1}\right) \lor \ldots \lor \left(x \in A_{m}\right) \textrm{ if } x \in \left(A_{1} \cup \ldots \cup A_{m}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, A_{1}, ..A_{_a}.., A_{m}) -> {(x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}) if x in (A_{1} union ..A_{_a}.. union A_{m}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 20, 14
# 2. {(x in A_{1}) or ..(x in A_{i}).. or (x in A_{m}) if x in (A_{1} union ..A_{_a}.. union A_{m}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x in A_{1}) or ..(x in A_{i}).. or (x in A_{m})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x, A_{1} union ..A_{_a}.. union A_{m})
#    core type: ExprTuple
#    sub-expressions: 20, 9
# 8. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 18
#    end_index: 19
# 9. A_{1} union ..A_{_a}.. union A_{m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 23
#     body: 13
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. x in A_{i}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. _a -> A_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. A_{i}
#     core type: IndexedVar
# variable: 24
# index: 23
# 22. A_{_a}
#     core type: IndexedVar
# variable: 24
# index: 25
# 23. i
#     core type: Variable
#     sub-expressions:
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. _a
#     core type: Variable
#     sub-expressions:
