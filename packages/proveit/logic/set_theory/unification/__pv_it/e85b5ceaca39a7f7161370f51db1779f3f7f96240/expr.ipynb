# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import m, x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Equals, Forall, InSet, NotInSet, Union
from proveit.logic.set_theory._common_ import x_notin_all_A
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, A_1_to_m], Equals(NotInSet(x, Union(A_1_to_m)), x_notin_all_A)), InSet(m, NaturalsPos))
# Out:
# expr: {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))) if m in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, A_{1}, \ldots, A_{m}}~\left(\left(x \notin \left(A_{1} \cup \ldots \cup A_{m}\right)\right) = \left(\left(x \notin A_{1}\right) \land \ldots \land \left(x \notin A_{m}\right)\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))) if m in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 7. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 30, 22
# 8. (x not-in (A_{1} union ..A_{_a}.. union A_{m})) = ((x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x not-in (A_{1} union ..A_{_a}.. union A_{m}), (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#     core type: Operation
#     operator: 27
#     operands: 14
# 13. (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 30, 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. union
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 34
#     body: 23
# 22. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. x not-in A_{i}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> A_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. not-in
#     core type: Literal
#     sub-expressions:
# 28. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. A_{_a}
#     core type: IndexedVar
# variable: 33
# index: 32
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. A_{i}
#     core type: IndexedVar
# variable: 33
# index: 34
# 32. _a
#     core type: Variable
#     sub-expressions:
# 33. A
#     core type: Variable
#     sub-expressions:
# 34. i
#     core type: Variable
#     sub-expressions:
