# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda
from proveit._common_ import A, i, m, x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, NotInSet, Union
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda([x, A_1_to_m], Conditional(NotInSet(x, Union(A_1_to_m)), And(ExprRange(i, NotInSet(x, IndexedVar(A, i)), one, m))))
# Out:
# expr: (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, A_{1}, \ldots, A_{m}\right) \mapsto \left\{x \notin \left(A_{1} \cup \ldots \cup A_{m}\right) \textrm{ if } \left(x \notin A_{1}\right) \land \ldots \land \left(x \notin A_{m}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 21, 13
# 2. {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x, A_{1} union ..A_{_a}.. union A_{m})
#    core type: ExprTuple
#    sub-expressions: 21, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. A_{1} union ..A_{_a}.. union A_{m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 16
#    end_index: 17
# 10. union
#     core type: Literal
#     sub-expressions:
# 11. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 25
#     body: 14
# 13. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 14. x not-in A_{i}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. _a -> A_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 20
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. not-in
#     core type: Literal
#     sub-expressions:
# 19. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. A_{_a}
#     core type: IndexedVar
# variable: 24
# index: 23
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. A_{i}
#     core type: IndexedVar
# variable: 24
# index: 25
# 23. _a
#     core type: Variable
#     sub-expressions:
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. i
#     core type: Variable
#     sub-expressions:
