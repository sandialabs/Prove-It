# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import A, i, m, x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Forall, NotInSet, Union
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([x, A_1_to_m], NotInSet(x, Union(A_1_to_m)), condition = ExprRange(i, NotInSet(x, IndexedVar(A, i)), one, m))
# Out:
# expr: forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, A_{1}, \ldots, A_{m}~|~x \notin A_{1}, \ldots, x \notin A_{m}}~\left(x \notin \left(A_{1} \cup \ldots \cup A_{m}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 23, 15
# 4. {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
