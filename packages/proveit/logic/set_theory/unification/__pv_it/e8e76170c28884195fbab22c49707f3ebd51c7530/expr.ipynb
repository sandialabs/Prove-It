# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nonmembershipFolding">nonmembershipFolding</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.unification._theorems_ import nonmembershipFolding

# %%
# check that the built expression is the same as the stored expression
# %check_expr nonmembershipFolding
# Out:
# Passed sanity check: built 'nonmembershipFolding' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonmembershipFolding.latex())
# Out:
# \vdash \forall_{m \in \mathbb{N}^+}~\left[\forall_{x, A_{1}, \ldots, A_{m}~|~x \notin A_{1}, \ldots, x \notin A_{m}}~\left(x \notin \left(A_{1} \cup \ldots \cup A_{m}\right)\right)\right]

# %%
# display the expression information
nonmembershipFolding.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos} [forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. m -> {forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalsPos.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m})) if m in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, A_{1}, ..A_{_a}.., A_{m} | x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m}} (x not-in (A_{1} union ..A_{_a}.. union A_{m}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. m in NaturalsPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 26, 11
# 9. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 30, 22
# 10. {x not-in (A_{1} union ..A_{_a}.. union A_{m}) if (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m}).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 12. x not-in (A_{1} union ..A_{_a}.. union A_{m})
#     core type: Operation
#     operator: 27
#     operands: 14
# 13. (x not-in A_{1}) and ..(x not-in A_{i}).. and (x not-in A_{m})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, A_{1} union ..A_{_a}.. union A_{m})
#     core type: ExprTuple
#     sub-expressions: 30, 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. A_{1} union ..A_{_a}.. union A_{m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. union
#     core type: Literal
#     sub-expressions:
# 20. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 34
#     body: 23
# 22. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. x not-in A_{i}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> A_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. not-in
#     core type: Literal
#     sub-expressions:
# 28. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. A_{_a}
#     core type: IndexedVar
# variable: 33
# index: 32
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. A_{i}
#     core type: IndexedVar
# variable: 33
# index: 34
# 32. _a
#     core type: Variable
#     sub-expressions:
# 33. A
#     core type: Variable
#     sub-expressions:
# 34. i
#     core type: Variable
#     sub-expressions:
