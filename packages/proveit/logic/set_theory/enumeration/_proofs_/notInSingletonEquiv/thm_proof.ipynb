# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../../_theory_.ipynb">enumeration</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#notInSingletonEquiv">notInSingletonEquiv</a> theorem
# ========
# *** see <a href="../__pv_it/e01334021ef9c34218bff021a7505fe298f897910/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving notInSingletonEquiv
