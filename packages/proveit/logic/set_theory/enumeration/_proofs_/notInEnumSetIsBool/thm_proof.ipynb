# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">enumeration</a>.<a class="ProveItLink" href="../_theorems_.ipynb#notInEnumSetIsBool">notInEnumSetIsBool</a> theorem
# ========

# %%
import proveit
context = proveit.Context() # the theorem's context

# %%
# %proving notInEnumSetIsBool
