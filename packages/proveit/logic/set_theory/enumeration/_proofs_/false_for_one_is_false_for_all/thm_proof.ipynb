# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_theory_.ipynb">enumeration</a>.<a class="ProveItLink" href="../_theorems_.ipynb#false_for_one_is_false_for_all">false_for_one_is_false_for_all</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving false_for_one_is_false_for_all
