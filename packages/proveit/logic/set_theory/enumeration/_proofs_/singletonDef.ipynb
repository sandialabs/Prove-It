# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">enumeration</a>.<a href="../_theorems_.ipynb#singletonDef" class="ProveItLink">singletonDef</a> theorem
# ========
# *** see <a href="../__pv_it/b375ce77e19409a2cd3e0128d32580c0df6fa3340/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit._common_ import n, x, y
from proveit.number import one
from proveit.number.numeral.deci._theorems_ import nat1
from proveit.logic.boolean.disjunction._theorems_ import unaryOrReduction
from proveit.logic.set_theory.enumeration._axioms_ import enumSetDef

# %%
# %proving singletonDef presuming [nat1, unaryOrReduction, proveit.number.numeral.deci.count_to_1_range]
# Out:
# Beginning proof of singletonDef
# Recorded 'presuming' information
# Presuming proveit.logic.boolean.disjunction.unaryOrReduction, proveit.number.numeral.deci.count_to_1_range, proveit.number.numeral.deci.nat1 theorems (applied transitively).
# Presuming previous theorems (applied transitively).
# singletonDef: forall_{x, y} ((x in {y}) = (x = y))

# %%
enumSetDef
# Out:
# |- forall_{n in Naturals} [forall_{x, y_{1}, ..y_{_a}.., y_{n}} ((x in {y_{1}, ..y_{_a}.., y_{n}}) = ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})))]

# %%
enumSetDef.specialize({n:one, x:x, y:[y]})
# Out:
# |- (x in {y}) = (x = y)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{x, y} ((x in {y}) = (x = y))
# 1	instantiation	2, 3, 4, 5*	|- (x in {y}) = (x = y)
# 	n : 1, x : x, y : (y)
# 2	axiom		|- forall_{n in Naturals} [forall_{x, y_{1}, ..y_{_a}.., y_{n}} ((x in {y_{1}, ..y_{_a}.., y_{n}}) = ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})))]
# 	proveit.logic.set_theory.enumeration.enumSetDef
# 3	theorem		|- 1 in Naturals
# 	proveit.number.numeral.deci.nat1
# 4	instantiation	6	|- |(y)| = |(1, ..k.., 1)|
# 	a : y
# 5	instantiation	7, 8	|- [or](x = y) = (x = y)
# 	A : x = y
# 6	theorem		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 	proveit.number.numeral.deci.tuple_len_1_typical_equiv
# 7	theorem		|- forall_{A in BOOLEANS} ([or](A) = A)
# 	proveit.logic.boolean.disjunction.unaryOrReduction
# 8	instantiation	9	|- (x = y) in BOOLEANS
# 	x : x, y : y
# 9	axiom		|- forall_{x, y} ((x = y) in BOOLEANS)
# 	proveit.logic.equality.equalityInBool
