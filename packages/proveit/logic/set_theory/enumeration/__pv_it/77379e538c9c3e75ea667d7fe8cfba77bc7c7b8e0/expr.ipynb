# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#notInSingletonEquiv">notInSingletonEquiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.enumeration._theorems_ import notInSingletonEquiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr notInSingletonEquiv
# Out:
# Passed sanity check: built 'notInSingletonEquiv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(notInSingletonEquiv.latex())
# Out:
# \vdash \forall_{x, y}~\left(\left(x \notin \left\{y\right\}\right) = \left(x \neq y\right)\right)

# %%
# display the expression information
notInSingletonEquiv.exprInfo()
# Out:
# 0. forall_{x, y} ((x not-in {y}) = (x != y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> ((x not-in {y}) = (x != y))
#    core type: Lambda
#    parameters: 11\n   body: 3
# 3. (x not-in {y}) = (x != y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (x not-in {y}, x != y)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x not-in {y}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. x != y
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. not-in
#    core type: Literal
#    sub-expressions:
# 9. (x, {y})
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (x, y)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 12. {y}
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. x
# ...
