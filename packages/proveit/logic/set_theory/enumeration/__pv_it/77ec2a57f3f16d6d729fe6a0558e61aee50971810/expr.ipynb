# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import n, x
from proveit.core_expr_types._common_ import y_1_to_n
from proveit.logic import Forall, InSet, Set
from proveit.logic.set_theory._common_ import x_equals_any_y
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, y_1_to_n], x_equals_any_y, condition = InSet(x, Set(y_1_to_n))), InSet(n, Naturals))
# Out:
# expr: {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y_{1}, \ldots, y_{n}~|~x \in \left\{y_{1}, \ldots, y_{n}\right\}}~\left(\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})) if n in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y_{1}, ..y_{_a}.., y_{n} | x in {y_{1}, ..y_{_a}.., y_{n}}} ((x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in Naturals
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 26, 8
# 6. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 27, 21
# 7. {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. x in {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x, {y_{1}, ..y_{_a}.., y_{n}})
#     core type: ExprTuple
#     sub-expressions: 27, 16
# 15. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 25
#     end_index: 26
# 16. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 30
#     body: 20
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. x = y_{i}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. _a -> y_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. n
#     core type: Variable
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. y_{i}
#     core type: IndexedVar
# variable: 31
# index: 30
# 29. y_{_a}
#     core type: IndexedVar
# variable: 31
# index: 32
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. y
#     core type: Variable
#     sub-expressions:
# 32. _a
#     core type: Variable
#     sub-expressions:
