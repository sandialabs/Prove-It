# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import x
from proveit.core_expr_types._common_ import y_1_to_n
from proveit.logic import InSet, Set
from proveit.logic.set_theory._common_ import x_equals_any_y

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y_1_to_n], Conditional(x_equals_any_y, InSet(x, Set(y_1_to_n))))
# Out:
# expr: (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y_{1}, \ldots, y_{n}\right) \mapsto \left\{\left(x = y_{1}\right) \lor \ldots \lor \left(x = y_{n}\right) \textrm{ if } x \in \left\{y_{1}, \ldots, y_{n}\right\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x, y_{1}, ..y_{_a}.., y_{n}) -> {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 21, 15
# 2. {(x = y_{1}) or ..(x = y_{i}).. or (x = y_{n}) if x in {y_{1}, ..y_{_a}.., y_{n}}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x = y_{1}) or ..(x = y_{i}).. or (x = y_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in {y_{1}, ..y_{_a}.., y_{n}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x = y_{1}, ..x = y_{i}.., x = y_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, {y_{1}, ..y_{_a}.., y_{n}})
#    core type: ExprTuple
#    sub-expressions: 21, 10
# 9. (x = y_{1}), ..(x = y_{i}).., (x = y_{n})
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 19
#    end_index: 20
# 10. {y_{1}, ..y_{_a}.., y_{n}}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. i -> (x = y_{i})
#     core type: Lambda
#     parameter: 24
#     body: 14
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. x = y_{i}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (x, y_{i})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. _a -> y_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 23
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. y_{i}
#     core type: IndexedVar
# variable: 25
# index: 24
# 23. y_{_a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. _a
#     core type: Variable
#     sub-expressions:
