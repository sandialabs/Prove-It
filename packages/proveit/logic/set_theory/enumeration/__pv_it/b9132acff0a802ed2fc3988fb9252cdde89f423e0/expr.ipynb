# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inSingletonEvalFalse">inSingletonEvalFalse</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.enumeration._theorems_ import inSingletonEvalFalse

# %%
# check that the built expression is the same as the stored expression
# %check_expr inSingletonEvalFalse
# Out:
# Passed sanity check: built 'inSingletonEvalFalse' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(inSingletonEvalFalse.latex())
# Out:
# \vdash \forall_{x, y~|~x \neq y}~\left(\left(x \in \left\{y\right\}\right) = \bot\right)

# %%
# display the expression information
inSingletonEvalFalse.exprInfo()
# Out:
# 0. forall_{x, y | x != y} ((x in {y}) = FALSE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {(x in {y}) = FALSE if x != y.
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. {(x in {y}) = FALSE if x != y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x in {y}) = FALSE
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. x != y
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x in {y}, FALSE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. !=
#    core type: Literal
#    sub-expressions:
# 9. (x, y)
#    core type: ExprTuple
#    sub-expressions: 14, 17
# 10. x in {y}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. FALSE
#     core type: Literal
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x, {y})
# ...
