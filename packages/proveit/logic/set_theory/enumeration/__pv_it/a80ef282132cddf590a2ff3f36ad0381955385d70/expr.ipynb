# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inSingletonEvalTrue">inSingletonEvalTrue</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.enumeration._theorems_ import inSingletonEvalTrue

# %%
# check that the built expression is the same as the stored expression
# %check_expr inSingletonEvalTrue
# Out:
# Passed sanity check: built 'inSingletonEvalTrue' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(inSingletonEvalTrue.latex())
# Out:
# \vdash \forall_{x, y~|~x = y}~\left(\left(x \in \left\{y\right\}\right) = \top\right)

# %%
# display the expression information
inSingletonEvalTrue.exprInfo()
# Out:
# 0. forall_{x, y | x = y} ((x in {y}) = TRUE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> {(x in {y}) = TRUE if x = y.
#    core type: Lambda
#    parameters: 8\n   body: 3
# 3. {(x in {y}) = TRUE if x = y.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x in {y}) = TRUE
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. x = y
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in {y}, TRUE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x, y)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. x in {y}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. TRUE
#     core type: Literal
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x, {y})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x
# ...
