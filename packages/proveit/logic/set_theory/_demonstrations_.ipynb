# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.logic.set_theory</a>
# ========

# %%
import proveit
# %begin demonstrations

# %%
# %end demonstrations
