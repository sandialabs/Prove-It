# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">equivalence</a>.<a class="ProveItLink" href="../_theorems_.ipynb#setNotEquivInBool">setNotEquivInBool</a> theorem
# ========

# %%
import proveit
from proveit.logic.set_theory.equivalence._axioms_ import setNotEquivDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving setNotEquivInBool presuming [proveit.logic]

# %%
setNotEquivDef

# %%
setNotEquivDef_inst = setNotEquivDef.instantiate()

# %%
negationInBool = setNotEquivDef_inst.rhs.deduceInBool()

# %%
setNotEquivDef_inst.subLeftSideInto(negationInBool)

# %%
# %qed
