# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">equivalence</a>.<a class="ProveItLink" href="../_theorems_.ipynb#tempIdentity">tempIdentity</a> theorem
# ========

# %%
import proveit
from proveit._common_ import m, x, y, A, B, S, AA
from proveit.number import one, two
from proveit.logic import Set, SubsetEq, Union
from proveit.logic.set_theory.containment._axioms_ import subsetEqDef
from proveit.logic.set_theory.unification._axioms_ import unionDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving tempIdentity presuming [proveit.logic, proveit.number]

# %%
subsetEqDef

# %%
subsetEqDefSpec = subsetEqDef.specialize({A:A, B:Union(A, B)})

# %%
unionDef

# %%
unionDefSpec = unionDef.specialize({m:two, x:y, A:(S, Set(x))})
