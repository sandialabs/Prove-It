# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">equivalence</a>.<a class="ProveItLink" href="../_theorems_.ipynb#setEquivFold">setEquivFold</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic.set_theory.equivalence._axioms_ import setEquivDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving setEquivFold presuming []

# %%
defaults.assumptions = setEquivFold.conditions

# %%
setEquivDef

# %%
setEquivDef.instantiate().deriveLeftViaEquality()

# %%
# %qed
