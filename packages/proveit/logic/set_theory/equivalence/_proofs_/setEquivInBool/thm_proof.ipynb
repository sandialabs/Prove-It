# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_theory_.ipynb">equivalence</a>.<a class="ProveItLink" href="../_theorems_.ipynb#setEquivInBool">setEquivInBool</a> theorem
# ========

# %%
import proveit
from proveit._common_ import A, B
from proveit.logic import Booleans, InSet
from proveit.logic.set_theory.equivalence._axioms_ import setEquivDef
theory = proveit.Theory() # the theorem's theory

# %%
# %proving setEquivInBool

# %%
setEquivDef

# %%
setEquivDef_inst = setEquivDef.instantiate()

# %%
conjunctionOfSubsetsInBool = setEquivDef_inst.rhs.deduceInBool()

# %%
setEquivDef_inst.subLeftSideInto(conjunctionOfSubsetsInBool)

# %%
# %qed
