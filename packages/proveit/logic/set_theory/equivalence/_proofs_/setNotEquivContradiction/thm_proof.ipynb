# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">equivalence</a>.<a class="ProveItLink" href="../_theorems_.ipynb#setNotEquivContradiction">setNotEquivContradiction</a> theorem
# ========

# %%
import proveit
from proveit import defaults
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving setNotEquivContradiction presuming []

# %%
defaults.assumptions = setNotEquivContradiction.allConditions()

# %%
A_not_equiv_B = defaults.assumptions[1]

# %%
not_A_equiv_B = A_not_equiv_B.unfold()

# %%
# %qed
