# %% [markdown]
# Axioms for context <a class="ProveItLink" href="_context_.ipynb">proveit.logic.set_theory.equivalence</a>
# ========

# %%
import proveit
from proveit._common_ import A, B, X
from proveit.logic import And, Equals, Forall, inBool
from proveit.logic.set_theory import SubsetEq, SetEquiv
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %%
# %begin axioms

# %% [markdown]
# **By definition, two sets are either equivalent (i.e. they contain the same elements) if and only if each is an improper subset of the other.**

# %%
setEquivDef = Forall((A, B), Equals(SetEquiv(A, B), And(SubsetEq(A, B), SubsetEq(B, A))))

# %%
# %end axioms
