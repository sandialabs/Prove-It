# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Subset, Superset

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Subset(B, A), Superset(A, B)))
# Out:
# expr: (A, B) -> {B subset A if A supset B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{B \subset A \textrm{ if } A \supset B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {B subset A if A supset B.
#    core type: Lambda
#    parameters: 7\n   body: 1
# 1. {B subset A if A supset B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. B subset A
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. A supset B
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. subset
#    core type: Literal
#    sub-expressions:
# 5. (B, A)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. supset
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
