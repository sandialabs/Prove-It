# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#supersetMembership">supersetMembership</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import supersetMembership

# %%
# check that the built expression is the same as the stored expression
# %check_expr supersetMembership
# Out:
# Passed sanity check: built 'supersetMembership' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(supersetMembership.latex())
# Out:
# \vdash \forall_{A, B~|~A \supset B}~\left[\forall_{x \in B}~\left(x \in A\right)\right]

# %%
# display the expression information
supersetMembership.exprInfo()
# Out:
# 0. forall_{A, B | A supset B} [forall_{x in B} (x in A)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (A, B) -> {forall_{x in B} (x in A) if A supset B.
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. {forall_{x in B} (x in A) if A supset B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A supset B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> {x in A if x in B.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 7. supset
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 9. {x in A if x in B.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. x in A
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. x in B
#     core type: Operation
#     operator: 13
# ...
