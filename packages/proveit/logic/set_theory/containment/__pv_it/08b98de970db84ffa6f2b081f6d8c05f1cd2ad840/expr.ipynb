# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B, C
from proveit.logic import And, Subset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(Subset(A, C), And(SubsetEq(A, B), Subset(B, C)))
# Out:
# expr: {A subset C if A subseteq B ,  B subset C.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \subset C \textrm{ if } A \subseteq B ,  B \subset C\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A subset C if A subseteq B ,  B subset C.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A subset C
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (A subseteq B) and (B subset C)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A, C)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A subseteq B, B subset C)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A subseteq B
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. B subset C
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. subseteq
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. subset
#     core type: Literal
#     sub-expressions:
# 11. (B, C)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
