# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A, B
from proveit.logic import Not, NotSupersetEq, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Conditional(NotSupersetEq(A, B), Not(SupersetEq(A, B)))
# Out:
# expr: {A nsupseteq B if [not](A supseteq B).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \nsupseteq B \textrm{ if } \lnot \left(A \supseteq B\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A nsupseteq B if [not](A supseteq B).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A nsupseteq B
#    core type: Operation
#    operator: 3
#    operands: 7
# 2. [not](A supseteq B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. nsupseteq
#    core type: Literal
#    sub-expressions:
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. A supseteq B
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. supseteq
#    core type: Literal
#    sub-expressions:
# 7. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
