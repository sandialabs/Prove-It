# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import A, B
from proveit.logic import Not, NotSubsetEq, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda([A, B], Conditional(Not(SubsetEq(A, B)), NotSubsetEq(A, B)))
# Out:
# expr: (A, B) -> {[not](A subseteq B) if A nsubseteq B.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\lnot \left(A \subseteq B\right) \textrm{ if } A \nsubseteq B\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A, B) -> {[not](A subseteq B) if A nsubseteq B.
#    core type: Lambda
#    parameters: 8\n   body: 1
# 1. {[not](A subseteq B) if A nsubseteq B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [not](A subseteq B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. A nsubseteq B
#    core type: Operation
#    operator: 6
#    operands: 8
# 4. not
#    core type: Literal
#    sub-expressions:
# 5. A subseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. nsubseteq
#    core type: Literal
#    sub-expressions:
# 7. subseteq
#    core type: Literal
#    sub-expressions:
# 8. (A, B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
