# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import And, Superset

# %%
# build up the expression from sub-expressions
expr = And(Superset(A, B), Superset(B, C))
# Out:
# expr: (A supset B) and (B supset C)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \supset B\right) \land \left(B \supset C\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A supset B) and (B supset C)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A supset B, B supset C)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A supset B
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. B supset C
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A, B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. supset
#    core type: Literal
#    sub-expressions:
# 7. (B, C)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
