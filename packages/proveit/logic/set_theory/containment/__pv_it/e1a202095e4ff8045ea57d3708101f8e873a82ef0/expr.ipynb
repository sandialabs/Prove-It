# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#transitivitySubsetSubsetEq">transitivitySubsetSubsetEq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import transitivitySubsetSubsetEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr transitivitySubsetSubsetEq
# Out:
# Passed sanity check: built 'transitivitySubsetSubsetEq' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transitivitySubsetSubsetEq.latex())
# Out:
# \vdash \forall_{A, B, C~|~A \subset B, B \subseteq C}~\left(A \subset C\right)

# %%
# display the expression information
transitivitySubsetSubsetEq.exprInfo()
# Out:
# 0. forall_{A, B, C | A subset B, B subseteq C} (A subset C)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B, C) -> {A subset C if A subset B ,  B subseteq C.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A, B, C)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18
# 4. {A subset C if A subset B ,  B subseteq C.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. A subset C
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. (A subset B) and (B subseteq C)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A, C)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A subset B, B subseteq C)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A subset B
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. B subseteq C
#     core type: Operation
# ...
