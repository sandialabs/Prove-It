# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldSupsetEq">foldSupsetEq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import foldSupsetEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldSupsetEq
# Out:
# Passed sanity check: built 'foldSupsetEq' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(foldSupsetEq.latex())
# Out:
# \vdash \forall_{A, B}~\left(\left[\forall_{x \in B}~\left(x \in A\right)\right] \Rightarrow \left(A \supseteq B\right)\right)

# %%
# display the expression information
foldSupsetEq.exprInfo()
# Out:
# 0. forall_{A, B} ([forall_{x in B} (x in A)] => (A supseteq B))
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. (A, B) -> ([forall_{x in B} (x in A)] => (A supseteq B))
#    core type: Lambda
#    parameters: 10\n   body: 2
# 2. [forall_{x in B} (x in A)] => (A supseteq B)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x in B} (x in A), A supseteq B)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. A supseteq B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> {x in A if x in B.
#    core type: Lambda
#    parameter: 18
#    body: 11
# 9. supseteq
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 11. {x in A if x in B.
#     core type: Conditional
# ...
