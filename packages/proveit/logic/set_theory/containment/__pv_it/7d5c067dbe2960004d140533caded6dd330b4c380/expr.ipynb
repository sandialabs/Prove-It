# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B
from proveit.logic import And, NotSupersetEq, Subset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Subset(A, B), And(SubsetEq(A, B), NotSupersetEq(A, B)))
# Out:
# expr: (A subset B, (A subseteq B) and (A nsupseteq B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A \subset B, \left(A \subseteq B\right) \land \left(A \nsupseteq B\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A subset B, (A subseteq B) and (A nsupseteq B))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A subset B
#    core type: Operation
#    operator: 3
#    operands: 10
# 2. (A subseteq B) and (A nsupseteq B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. subset
#    core type: Literal
#    sub-expressions:
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (A subseteq B, A nsupseteq B)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A subseteq B
#    core type: Operation
#    operator: 8
#    operands: 10
# 7. A nsupseteq B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. subseteq
#    core type: Literal
#    sub-expressions:
# 9. nsupseteq
#    core type: Literal
#    sub-expressions:
# 10. (A, B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
