# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../../_theory_.ipynb">containment</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#unfoldSubsetEq">unfoldSubsetEq</a> theorem
# ========
# *** see <a href="../__pv_it/d521a5b1c24d27daae62adca805c8a8f7fc71ace0/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit._common_ import A, B
from proveit.logic.set_theory.containment._axioms_ import subsetEqDef
# %proving unfoldSubsetEq

# %%
subsetEqDef

# %%
# old
# definitionSpecialized = SubsetEqDef.instantiate()

# %%
# new
SubsetEqDef_inst = subsetEqDef.instantiate()

# %%
SubsetEqDef_inst.deriveRightViaEquality([SubsetEqDef_inst.lhs])

# %%
# %qed
