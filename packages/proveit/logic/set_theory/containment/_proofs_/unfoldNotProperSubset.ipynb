# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">containment</a>.<a class="ProveItLink" href="../_theorems_.ipynb#unfoldNotProperSubset">unfoldNotProperSubset</a> theorem
# ========

# %%
import proveit
from proveit.logic.set_theory.containment._axioms_ import notProperSubsetDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving unfoldNotProperSubset presuming [proveit.logic]

# %%
# pull in the definition of not proper subset
notProperSubsetDef

# %%
notProperSubsetDef_inst = notProperSubsetDef.instantiate()

# %%
notProperSubsetDef_inst.deriveRightViaEquality([notProperSubsetDef_inst.lhs])

# %%
# %qed
