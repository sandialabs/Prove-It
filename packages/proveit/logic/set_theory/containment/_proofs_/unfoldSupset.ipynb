# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">containment</a>.<a class="ProveItLink" href="../_theorems_.ipynb#unfoldSupset">unfoldSupset</a> theorem
# ========

# %%
import proveit
from proveit.logic.set_theory.containment._axioms_ import supersetDef
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving unfoldSupset presuming [proveit.logic]

# %%
# pull in definition of superset
supersetDef

# %%
supersetDef_inst = supersetDef.instantiate()

# %%
supersetDef_inst.deriveRightViaEquivalence([supersetDef_inst.lhs])

# %%
# %qed
