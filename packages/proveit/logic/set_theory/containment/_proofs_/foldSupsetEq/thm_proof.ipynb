# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_theory_.ipynb">containment</a>.<a href="../_theorems_.ipynb#foldSupsetEq" class="ProveItLink">foldSupsetEq</a> theorem
# ========

# %%
import proveit
from proveit.logic.set_theory.containment._axioms_ import supersetEqDef

# %%
# %proving foldSupsetEq

# %%
# pull in the definition of non-proper superset (SupersetEqDef)
supersetEqDef

# %%
SupersetEqDef_inst = supersetEqDef.instantiate()

# %%
SupersetEqDef_inst.deriveLeftViaEquality([SupersetEqDef_inst.rhs])

# %%
# %qed
