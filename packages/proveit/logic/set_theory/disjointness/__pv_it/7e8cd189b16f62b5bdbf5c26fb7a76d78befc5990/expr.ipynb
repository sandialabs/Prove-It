# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import B, X, m
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import And, Disjoint, Forall, Iff, InSet, Set
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A_1_to_m, B], Iff(Disjoint(A_1_to_m, B), And(Disjoint(A_1_to_m), Forall([X], Disjoint(X, B), domain = Set(A_1_to_m)))).withWrappingAt(2)), InSet(m, Naturals))
# Out:
# expr: {forall_{A_{1}, ..A_{_a}.., A_{m}, B} (disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])) if m in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A_{1}, \ldots, A_{m}, B}~\left(\begin{array}{c} \textrm{disjoint}(A_{1}, \ldots, A_{m}, B) \Leftrightarrow  \\ \left(\textrm{disjoint}(A_{1}, \ldots, A_{m}) \land \left[\forall_{X \in \left\{A_{1}, \ldots, A_{m}\right\}}~\textrm{disjoint}(X, B)\right]\right) \end{array}\right) \textrm{ if } m \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{A_{1}, ..A_{_a}.., A_{m}, B} (disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])) if m in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, ..A_{_a}.., A_{m}, B} (disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)]))
#    core type: Operation
#    operator: 16
#    operand: 3
# 2. m in Naturals
#    core type: Operation
#    operator: 23
#    operands: 4
# 3. (A_{1}, ..A_{_a}.., A_{m}, B) -> (disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)]))
#    core type: Lambda
#    parameters: 11\n   body: 5
# 4. (m, Naturals)
#    core type: ExprTuple
#    sub-expressions: 33, 6
# 5. disjoint(A_{1}, ..A_{_a}.., A_{m}, B) <=>  \\ (disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. Naturals
#    core type: Literal
#    sub-expressions:
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (disjoint(A_{1}, ..A_{_a}.., A_{m}, B), disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. disjoint(A_{1}, ..A_{_a}.., A_{m}, B)
#    core type: Operation
#    operator: 21
#    operands: 11
# 10. disjoint(A_{1}, ..A_{_a}.., A_{m}) and [forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)]
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (A_{1}, ..A_{_a}.., A_{m}, B)
#     core type: ExprTuple
#     sub-expressions: 30, 25
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (disjoint(A_{1}, ..A_{_a}.., A_{m}), forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. disjoint(A_{1}, ..A_{_a}.., A_{m})
#     core type: Operation
#     operator: 21
#     operands: 29
# 15. forall_{X in {A_{1}, ..A_{_a}.., A_{m}}} disjoint(X, B)
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. X -> {disjoint(X, B) if X in {A_{1}, ..A_{_a}.., A_{m}}.
#     core type: Lambda
#     parameter: 26
#     body: 18
# 18. {disjoint(X, B) if X in {A_{1}, ..A_{_a}.., A_{m}}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 19. disjoint(X, B)
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. X in {A_{1}, ..A_{_a}.., A_{m}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. disjoint
#     core type: Literal
#     sub-expressions:
# 22. (X, B)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (X, {A_{1}, ..A_{_a}.., A_{m}})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. B
#     core type: Variable
#     sub-expressions:
# 26. X
#     core type: Variable
#     sub-expressions:
# 27. {A_{1}, ..A_{_a}.., A_{m}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 30
# 30. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 31. _a -> A_{_a}
#     core type: Lambda
#     parameter: 36
#     body: 34
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. A_{_a}
#     core type: IndexedVar
# variable: 35
# index: 36
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. _a
#     core type: Variable
#     sub-expressions:
