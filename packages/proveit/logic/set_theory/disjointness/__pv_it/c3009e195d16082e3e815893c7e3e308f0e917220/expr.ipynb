# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import n, x
from proveit.logic import Disjoint, Distinct, Equals
from proveit.logic.set_theory._common_ import x_singletons_range
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Equals(Distinct(ExprRange(Variable("_a", latexFormat = r"{_{-}a}"), IndexedVar(x, Variable("_a", latexFormat = r"{_{-}a}")), one, n)), Disjoint(x_singletons_range))
# Out:
# expr: distinct(x_{1}, ..x_{_a}.., x_{n}) = disjoint({x_{1}}, ..{x_{i}}.., {x_{n}})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \textrm{distinct}(x_{1}, \ldots, x_{n}) = \textrm{disjoint}(\left\{x_{1}\right\}, \ldots, \left\{x_{n}\right\})

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. distinct(x_{1}, ..x_{_a}.., x_{n}) = disjoint({x_{1}}, ..{x_{i}}.., {x_{n}})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (distinct(x_{1}, ..x_{_a}.., x_{n}), disjoint({x_{1}}, ..{x_{i}}.., {x_{n}}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. distinct(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. disjoint({x_{1}}, ..{x_{i}}.., {x_{n}})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. distinct
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. disjoint
#    core type: Literal
#    sub-expressions:
# 8. ({x_{1}}, ..{x_{i}}.., {x_{n}})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 13
#    end_index: 14
# 10. {x_{1}}, ..{x_{i}}.., {x_{n}}
# ...
