# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#x_singletons_range">x_singletons_range</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory._common_ import x_singletons_range

# %%
# check that the built expression is the same as the stored expression
# %check_expr x_singletons_range
# Out:
# Passed sanity check: built 'x_singletons_range' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(x_singletons_range.latex())
# Out:
# \left\{x_{1}\right\}, \ldots, \left\{x_{n}\right\}

# %%
# display the expression information
x_singletons_range.exprInfo()
# Out:
# 0. {x_{1}}, ..{x_{i}}.., {x_{n}}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. i -> {x_{i}}
#    core type: Lambda
#    parameter: 8
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. {x_{i}}
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. x_{i}
#    core type: IndexedVar
# variable: 7
# index: 8
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. i
#    core type: Variable
#    sub-expressions:
