# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Integers, Reals, frac

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(frac(a, b), And(InSet(a, Integers), InSet(b, Reals))))
# Out:
# expr: (a, b) -> {a / b if a in Integers ,  b in Reals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\frac{a}{b} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{R}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {a / b if a in Integers ,  b in Reals.
#    core type: Lambda
#    parameters: 5\n   body: 1
# 1. {a / b if a in Integers ,  b in Reals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a / b
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Integers) and (b in Reals)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. /
#    core type: Literal
#    sub-expressions:
# 5. (a, b)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integers, b in Reals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. a in Integers
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. b in Reals
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (b, Reals)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. Integers
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. Reals
#     core type: Literal
#     sub-expressions:
