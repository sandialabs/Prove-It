# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b
from proveit.logic import InSet, NotEquals
from proveit.number import Integers, Reals, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Integers), InSet(b, Reals), NotEquals(b, zero))
# Out:
# expr: (a in Integers, b in Reals, b != 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{Z}, b \in \mathbb{R}, b \neq 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Integers, b in Reals, b != 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. a in Integers
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. b in Reals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. b != 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (a, Integers)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, Reals)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 7. !=
#    core type: Literal
#    sub-expressions:
# 8. (b, 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. Integers
#     core type: Literal
#     sub-expressions:
# 11. Reals
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. 0
#     core type: Literal
#     sub-expressions:
