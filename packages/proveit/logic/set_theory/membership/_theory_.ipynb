# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../_theory_.ipynb">set_theory</a>.membership
# ========
#
# Sets are defined by their membership.  Elements may be in a set, $x \in S$, or not in a set, $y \notin S$.

# %%
import proveit
# %theory
