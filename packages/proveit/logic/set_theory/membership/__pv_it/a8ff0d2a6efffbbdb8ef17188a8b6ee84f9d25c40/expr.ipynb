# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import S, x
from proveit.logic import InSet, Not, NotInSet

# %%
# build up the expression from sub-expressions
expr = Conditional(Not(InSet(x, S)), NotInSet(x, S))
# Out:
# expr: {[not](x in S) if x not-in S.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\lnot \left(x \in S\right) \textrm{ if } x \notin S\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not](x in S) if x not-in S.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [not](x in S)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. x not-in S
#    core type: Operation
#    operator: 5
#    operands: 7
# 3. not
#    core type: Literal
#    sub-expressions:
# 4. x in S
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. not-in
#    core type: Literal
#    sub-expressions:
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, S)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. S
#    core type: Variable
#    sub-expressions:
