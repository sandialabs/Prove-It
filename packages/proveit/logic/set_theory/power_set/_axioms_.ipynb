# %% [markdown]
# Axioms for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.logic.set_theory.power_set</a>
# ========

# %%
import proveit
# Automation is not needed when building axiom expressions:
proveit.defaults.automation = False # This will speed things up.
# the theory is in the current directory:
theory = proveit.Theory('.') # adds theory root to sys.path if necessary
from proveit._common_ import x, S
from proveit.logic import Equals, Forall, InSet, PowerSet, SubsetEq

# %%
# %begin axioms

# %%
power_set_def = Forall((x, S), Equals(InSet(x, PowerSet(S)),
                                      SubsetEq(x, S)))

# %%
# %end axioms
