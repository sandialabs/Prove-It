# %% [markdown]
# Theorems for the theory of <a class="ProveItLink" href="_theory_.ipynb">proveit.logic.set_theory.power_set</a>
# ========

# %%
import proveit
# Automation is not needed when building theorem expressions:
proveit.defaults.automation = False # This will speed things up.
# the theory is in the current directory:
theory = proveit.Theory('.') # adds theory root to sys.path if necessary

# %%
# %begin theorems

# %%
# %end theorems
