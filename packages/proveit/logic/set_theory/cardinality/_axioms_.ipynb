# %% [markdown]
# Axioms for context <a href="_context_.ipynb">proveit.logic.set_theory.cardinality</a>
# ========

# %%
from proveit.logic import Card, EmptySet, Equals, Union, Set, NotInSet, Forall
from proveit.number import num, Add
from proveit._common_ import x, S
# %begin_axioms
# Out:
# Defining axioms for context 'proveit.logic.set_theory.cardinality'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %% [markdown]
# **The cardinality of the empty set, $\emptyset$, is zero (the base case of an induction for the cardinality of finite sets):**

# %%
emptyCard = Equals(Card(EmptySet), num(0))
# Out:
# emptyCard: |emptyset| = 0

# %% [markdown]
# **When a new element is added to a set, its cardinality increases by one (the induction rule for the cardinality of finite sets):**

# %%
cardInduction = Forall((x, S), Equals(Card(Union(S, Set(x))), 
                                      Add(Card(S), num(1))), conditions=[NotInSet(x, S)])
# Out:
# cardInduction: forall_{x, S | (x not-in S)} (|S union {x}| = (|S| + 1))

# %%
# %end_axioms
# Out:
# Axioms may be imported from autogenerated _axioms_.py
