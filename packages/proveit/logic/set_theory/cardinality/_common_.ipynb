# %% [markdown]
# Common expressions for context <a href="_context_.ipynb" class="ProveItLink">proveit.logic.set_theory.cardinality</a>
# ========

# %%
import proveit
# Automation is not needed when only building common expressions:
proveit.defaults.automation = False # This will speed things up.
# %begin common
# Out:
# Defining common sub-expressions for context 'proveit.logic.set_theory.cardinality'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
# %end common
# Out:
# Context proveit.logic.set_theory.cardinality has no common expressions
