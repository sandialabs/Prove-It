# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#distinctSubsetExistence">distinctSubsetExistence</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.set_theory.cardinality._theorems_ import distinctSubsetExistence

# %%
# check that the built expression is the same as the stored expression
# %check_expr distinctSubsetExistence
# Out:
# Passed sanity check: built 'distinctSubsetExistence' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distinctSubsetExistence.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{S, N~|~|S| \geq N}~\left[\exists_{x_{1}, \ldots, x_{n} \in S~|~|\left(x_{1}, \ldots, x_{n}\right)| = N}~\textrm{distinct}(x_{1}, \ldots, x_{n})\right]\right]

# %%
# display the expression information
distinctSubsetExistence.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})]]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. {forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})] if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{S, N | |S| >= N} [exists_{x_{1}, ..x_{_a}.., x_{n} in S | |(x_{1}, ..x_{_a}.., x_{n})| = N} distinct(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. forall
#    core type: Literal
# ...
