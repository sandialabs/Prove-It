# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>.<a class="ProveItLink" href="../../_axioms_.ipynb#emptyCard">emptyCard</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.set_theory.cardinality._axioms_ import emptyCard

# %%
# %dependencies emptyCard
# Out:
# <h3>No theorems depend upon emptyCard</h3>
