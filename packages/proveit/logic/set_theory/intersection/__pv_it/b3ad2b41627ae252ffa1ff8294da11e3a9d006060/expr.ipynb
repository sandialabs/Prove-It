# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import m, x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Equals, Forall, InSet, Intersect
from proveit.logic.set_theory._common_ import x_in_every_A
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, A_1_to_m], Equals(InSet(x, Intersect(A_1_to_m)), x_in_every_A)), InSet(m, NaturalsPos))
# Out:
# expr: {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) = ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))) if m in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, A_{1}, \ldots, A_{m}}~\left(\left(x \in \left(A_{1} \cap \ldots \cap A_{m}\right)\right) = \left(\left(x \in A_{1}\right) \land \ldots \land \left(x \in A_{m}\right)\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) = ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))) if m in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, A_{1}, ..A_{_a}.., A_{m}} ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) = ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalsPos
#    core type: Operation
#    operator: 26
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x, A_{1}, ..A_{_a}.., A_{m}) -> ((x in (A_{1} intersect ..A_{_a}.. intersect A_{m})) = ((x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})))
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 25, 8
# 6. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 29, 21
# ...
