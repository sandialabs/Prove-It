# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import m, x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import Forall, InSet, Intersect, NotInSet
from proveit.logic.set_theory._common_ import x_notin_some_A
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, A_1_to_m], NotInSet(x, Intersect(A_1_to_m)), condition = x_notin_some_A), InSet(m, NaturalsPos))
# Out:
# expr: {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, A_{1}, \ldots, A_{m}~|~\left(x \notin A_{1}\right) \lor \ldots \lor \left(x \notin A_{m}\right)}~\left(x \notin \left(A_{1} \cap \ldots \cap A_{m}\right)\right) \textrm{ if } m \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})) if m in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, A_{1}, ..A_{_a}.., A_{m} | (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})} (x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. m in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x, A_{1}, ..A_{_a}.., A_{m}) -> {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 7. (x, A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 28, 20
# 8. {x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m}) if (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. x not-in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (x not-in A_{1}) or ..(x not-in A_{i}).. or (x not-in A_{m})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#     core type: ExprTuple
#     sub-expressions: 28, 15
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (x not-in A_{1}, ..x not-in A_{i}.., x not-in A_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. A_{1} intersect ..A_{_a}.. intersect A_{m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x not-in A_{1}), ..(x not-in A_{i}).., (x not-in A_{m})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. intersect
#     core type: Literal
#     sub-expressions:
# 18. (A_{1}, ..A_{_a}.., A_{m})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. i -> (x not-in A_{i})
#     core type: Lambda
#     parameter: 32
#     body: 21
# 20. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. x not-in A_{i}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> A_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. not-in
#     core type: Literal
#     sub-expressions:
# 26. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. A_{_a}
#     core type: IndexedVar
# variable: 31
# index: 30
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. A_{i}
#     core type: IndexedVar
# variable: 31
# index: 32
# 30. _a
#     core type: Variable
#     sub-expressions:
# 31. A
#     core type: Variable
#     sub-expressions:
# 32. i
#     core type: Variable
#     sub-expressions:
