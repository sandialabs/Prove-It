# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import x
from proveit.core_expr_types._common_ import A_1_to_m
from proveit.logic import InSet, Intersect
from proveit.logic.set_theory._common_ import x_in_every_A

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Intersect(A_1_to_m)), x_in_every_A)
# Out:
# expr: (x in (A_{1} intersect ..A_{_a}.. intersect A_{m}), (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \in \left(A_{1} \cap \ldots \cap A_{m}\right), \left(x \in A_{1}\right) \land \ldots \land \left(x \in A_{m}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in (A_{1} intersect ..A_{_a}.. intersect A_{m}), (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in (A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (x in A_{1}) and ..(x in A_{i}).. and (x in A_{m})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, A_{1} intersect ..A_{_a}.. intersect A_{m})
#    core type: ExprTuple
#    sub-expressions: 19, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (x in A_{1}, ..x in A_{i}.., x in A_{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_{1} intersect ..A_{_a}.. intersect A_{m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in A_{1}), ..(x in A_{i}).., (x in A_{m})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 15
# 8. intersect
#    core type: Literal
#    sub-expressions:
# 9. (A_{1}, ..A_{_a}.., A_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. i -> (x in A_{i})
#     core type: Lambda
#     parameter: 23
#     body: 12
# 11. A_{1}, ..A_{_a}.., A_{m}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. x in A_{i}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. _a -> A_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x, A_{i})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. A_{_a}
#     core type: IndexedVar
# variable: 22
# index: 21
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. A_{i}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. _a
#     core type: Variable
#     sub-expressions:
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. i
#     core type: Variable
#     sub-expressions:
