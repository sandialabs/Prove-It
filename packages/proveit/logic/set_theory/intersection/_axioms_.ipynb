# %% [markdown]
# Axioms for context <a href="_context_.ipynb" class="ProveItLink">proveit.logic.set_theory.intersection</a>
# ========

# %%
from proveit.logic import Forall, Equals, InSet
from proveit._common_ import n, x, AA
from proveit.logic.set_theory.intersection._common_ import intersectedAs, x_in_each_A_conjunction
from proveit.number import NaturalsPos
# %begin axioms
# Out:
# Defining axioms for context 'proveit.logic.set_theory.intersection'
# Subsequent end-of-cell assignments will define axioms
# %end_axioms will finalize the definitions

# %% [markdown]
# **Membership in the intersection of sets is the same as having membership in *all* of the sets being intersected:**

# %%
intersectionDef = Forall(n, Forall((x, AA), Equals(InSet(x, intersectedAs), 
                                                             x_in_each_A_conjunction)), 
                         domain=NaturalsPos)
# Out:
# intersectionDef: forall_{n in NaturalsPos} [forall_{x, A} ((x in (A_(1) intersect  ...  intersect A_(n))) = ((x in A_(1)) and  ...  and (x in A_(n))))]

# %%
# %end axioms
# Out:
# Axioms may be imported from autogenerated _axioms_.py
