# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_theory_.ipynb">intersection</a>.<a href="../_theorems_.ipynb#nonmembershipEquiv" class="ProveItLink">nonmembershipEquiv</a> theorem
# ========
# *** see <a href="../__pv_it/017557b03e19e86b76498fc09b1f9642a6828b810/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
# %proving nonmembershipEquiv
