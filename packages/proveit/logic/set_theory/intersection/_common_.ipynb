# %% [markdown]
# Common expressions for context <a href="_context_.ipynb" class="ProveItLink">proveit.logic.set_theory.intersection</a>
# ========

# %%
import proveit
from proveit import Lambda, Iter, Indexed
from proveit.logic import And, Or, InSet, NotInSet, Intersect
from proveit._common_ import AA, x, i, n
from proveit.number import one
# %begin common
# Out:
# Defining common sub-expressions for context 'proveit.logic.set_theory.intersection'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
intersectedAs = Intersect(Iter(Lambda(i, Indexed(AA, i)), one, n))
# Out:
# intersectedAs: A_(1) intersect  ...  intersect A_(n)

# %%
x_in_each_A = Iter(Lambda(i, InSet(x, Indexed(AA, i))), one, n)
# Out:
# x_in_each_A: (x in A_(1)),...,(x in A_(n))

# %%
x_in_each_A_conjunction = And(Iter(Lambda(i, InSet(x, Indexed(AA, i))), one, n))
# Out:
# x_in_each_A_conjunction: (x in A_(1)) and  ...  and (x in A_(n))

# %%
x_not_in_any_A = Or(Iter(Lambda(i, NotInSet(x, Indexed(AA, i))), one, n))
# Out:
# x_not_in_any_A: (x not-in A_(1)) or  ...  or (x not-in A_(n))

# %%
# %end common
# Out:
# x_in_each_A_conjunction expression notebook is being updated
# intersectedAs expression notebook is being updated
# x_in_each_A expression notebook is being updated
# x_not_in_any_A expression notebook is being updated
# Common expressions may be imported from autogenerated _common_.py
