# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multi_substitution">multi_substitution</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.equality._theorems_ import multi_substitution

# %%
# check that the built expression is the same as the stored expression
# %check_expr multi_substitution
# Out:
# Passed sanity check: built 'multi_substitution' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(multi_substitution.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{f, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~\left(f(x_{1}, \ldots, x_{n}) = f(y_{1}, \ldots, y_{n})\right)\right]

# %%
# display the expression information
multi_substitution.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 30
#    body: 2
# 2. {forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
# ...
