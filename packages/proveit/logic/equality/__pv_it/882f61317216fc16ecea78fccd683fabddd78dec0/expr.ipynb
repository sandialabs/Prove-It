# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, y
from proveit.logic import Equals
from proveit.number import Add, Exp, frac

# %%
# build up the expression from sub-expressions
subExpr1 = frac(c, d)
expr = Equals(Equals(a, Add(b, subExpr1, Exp(c, d))), Equals(a, Add(b, subExpr1, Exp(c, y))))
# Out:
# expr: (a = (b + (c / d) + c^{d})) = (a = (b + (c / d) + c^{y}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a = \left(b + \frac{c}{d} + c^{d}\right)\right) = \left(a = \left(b + \frac{c}{d} + c^{y}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a = (b + (c / d) + c^{d})) = (a = (b + (c / d) + c^{y}))
#    core type: Operation
#    operator: 5
#    operands: 1
# 1. (a = (b + (c / d) + c^{d}), a = (b + (c / d) + c^{y}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. a = (b + (c / d) + c^{d})
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. a = (b + (c / d) + c^{y})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a, b + (c / d) + c^{d})
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a, b + (c / d) + c^{y})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. b + (c / d) + c^{d}
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b + (c / d) + c^{y}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (b, c / d, c^{d})
#     core type: ExprTuple
#     sub-expressions: 14, 15, 13
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (b, c / d, c^{y})
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 13. c^{d}
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. c / d
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. c^{y}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. /
#     core type: Literal
#     sub-expressions:
# 18. (c, d)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 19. Exp
#     core type: Literal
#     sub-expressions:
# 20. (c, y)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. d
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
