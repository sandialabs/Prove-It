# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import a, n, x, y
from proveit.core_expr_types._common_ import P__x_1_to_n
from proveit.logic import Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(P__x_1_to_n, ExprRange(a, Equals(IndexedVar(x, a), IndexedVar(y, a)), one, n))
# Out:
# expr: (P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P(x_{1}, \ldots, x_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 9
#    end_index: 10
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. a -> (x_{a} = y_{a})
#    core type: Lambda
#    parameter: 19
#    body: 7
# 6. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 7. x_{a} = y_{a}
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. _a -> x_{_a}
#    core type: Lambda
#    parameter: 16
#    body: 13
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. x_{_a}
#     core type: IndexedVar
# variable: 17
# index: 16
# 14. x_{a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 15. y_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 16. _a
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
