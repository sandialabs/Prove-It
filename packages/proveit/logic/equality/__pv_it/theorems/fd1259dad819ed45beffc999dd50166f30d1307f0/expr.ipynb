# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = Conditional(P__x_1_to_n, And(P__y_1_to_n, Equals([x_1_to_n], [y_1_to_n])))
# Out:
# expr: {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P(x_{1}, \ldots, x_{n}) \textrm{ if } P(y_{1}, \ldots, y_{n}) ,  \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 7
#    operands: 10
# 2. P(y_{1}, ..y_{_a}.., y_{n}) and ((x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 7
#    operands: 11
# 6. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 16
#     end_index: 17
# 13. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 14. _a -> x_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 18
# 15. _a -> y_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 19
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. x_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 19. y_{_a}
#     core type: IndexedVar
# variable: 21
# index: 22
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. y
#     core type: Variable
#     sub-expressions:
# 22. _a
#     core type: Variable
#     sub-expressions:
