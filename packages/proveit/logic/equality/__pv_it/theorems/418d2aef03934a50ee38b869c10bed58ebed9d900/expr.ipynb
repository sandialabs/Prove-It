# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, P, n
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Forall, InSet
from proveit.logic.equality import elementwise_equality
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([P, x_1_to_n, y_1_to_n], P__x_1_to_n, conditions = [P__y_1_to_n, elementwise_equality]), InSet(n, Natural))
# Out:
# expr: {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(y_{1}, \ldots, y_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(x_{1}, \ldots, x_{n}) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 7. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 19, 15, 23
# 8. {P(x_{1}, ..x_{_a}.., x_{n}) if P(y_{1}, ..y_{_a}.., y_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 19
#     operands: 12
# 11. P(y_{1}, ..y_{_a}.., y_{n}) and (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 26
#     end_index: 27
# 16. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 26
#     end_index: 27
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 22
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 36
#     body: 24
# 22. x_{_a}
#     core type: IndexedVar
# variable: 34
# index: 33
# 23. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. x_{a} = y_{a}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. _a -> y_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 30
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. y_{_a}
#     core type: IndexedVar
# variable: 35
# index: 33
# 31. x_{a}
#     core type: IndexedVar
# variable: 34
# index: 36
# 32. y_{a}
#     core type: IndexedVar
# variable: 35
# index: 36
# 33. _a
#     core type: Variable
#     sub-expressions:
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. y
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
