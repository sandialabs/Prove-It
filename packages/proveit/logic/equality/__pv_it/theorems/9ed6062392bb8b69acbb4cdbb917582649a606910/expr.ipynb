# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import P
from proveit.core_expr_types import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Forall
from proveit.logic.equality import elementwise_equality

# %%
# build up the expression from sub-expressions
expr = Forall([P, x_1_to_n, y_1_to_n], P__y_1_to_n, conditions = [P__x_1_to_n, elementwise_equality])
# Out:
# expr: forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(x_{1}, \ldots, x_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(y_{1}, \ldots, y_{n})

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 14, 18, 10
# 4. {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 14
#    operands: 7
# 6. P(x_{1}, ..x_{_a}.., x_{n}) and (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 21
#     end_index: 22
# 11. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 21
#     end_index: 22
# 13. _a -> y_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 17
# 14. P
#     core type: Variable
#     sub-expressions:
# 15. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 31
#     body: 19
# 17. y_{_a}
#     core type: IndexedVar
# variable: 30
# index: 28
# 18. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. x_{a} = y_{a}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. x_{_a}
#     core type: IndexedVar
# variable: 29
# index: 28
# 26. x_{a}
#     core type: IndexedVar
# variable: 29
# index: 31
# 27. y_{a}
#     core type: IndexedVar
# variable: 30
# index: 31
# 28. _a
#     core type: Variable
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. y
#     core type: Variable
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
