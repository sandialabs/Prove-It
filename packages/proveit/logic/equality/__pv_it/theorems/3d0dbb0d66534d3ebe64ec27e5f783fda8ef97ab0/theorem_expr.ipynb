# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mult_sub_left_into">mult_sub_left_into</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.equality import mult_sub_left_into

# %%
# check that the built expression is the same as the stored expression
assert mult_sub_left_into.expr == stored_expr
assert mult_sub_left_into.expr._style_id == stored_expr._style_id
print("Passed sanity check: mult_sub_left_into matches stored_expr")
# Out:
# Passed sanity check: mult_sub_left_into matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_sub_left_into.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(y_{1}, \ldots, y_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(x_{1}, \ldots, x_{n})\right]

# %%
# display the expression information
mult_sub_left_into.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n}) if n in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(x_{1}, ..x_{_a}.., x_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# ...
