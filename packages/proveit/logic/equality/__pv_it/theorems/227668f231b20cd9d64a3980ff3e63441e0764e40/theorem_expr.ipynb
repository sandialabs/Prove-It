# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#transitivity_chain">transitivity_chain</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.logic.equality import transitivity_chain

# %%
# check that the built expression is the same as the stored expression
assert transitivity_chain.expr == stored_expr
assert transitivity_chain.expr._style_id == stored_expr._style_id
print("Passed sanity check: transitivity_chain matches stored_expr")
# Out:
# Passed sanity check: transitivity_chain matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, x_{2}, \ldots, x_{n + 1}~|~\left(x_{1} = x_{1 + 1}\right), \left(x_{2} = x_{2 + 1}\right), \ldots, \left(x_{n} = x_{n + 1}\right)}~\left(x_{1} = x_{n + 1}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n + 1} | (x_{1} = x_{1 + 1}), (x_{2} = x_{2 + 1}), ..., (x_{n} = x_{n + 1})} (x_{1} = x_{n + 1})]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{x_{1}, x_{2}, ..., x_{n + 1} | (x_{1} = x_{1 + 1}), (x_{2} = x_{2 + 1}), ..., (x_{n} = x_{n + 1})} (x_{1} = x_{n + 1}) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x_{1}, x_{2}, ..., x_{n + 1} | (x_{1} = x_{1 + 1}), (x_{2} = x_{2 + 1}), ..., (x_{n} = x_{n + 1})} (x_{1} = x_{n + 1}) if n in NaturalPos.
#    core type: Lambda
#    parameter: 33
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 33
# 4. {forall_{x_{1}, x_{2}, ..., x_{n + 1} | (x_{1} = x_{1 + 1}), (x_{2} = x_{2 + 1}), ..., (x_{n} = x_{n + 1})} (x_{1} = x_{n + 1}) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# ...
