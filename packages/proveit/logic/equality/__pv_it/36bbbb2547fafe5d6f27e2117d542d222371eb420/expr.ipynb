# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Booleans, Implies, InSet, Not, NotEquals, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(b, Booleans), Implies(Not(b), NotEquals(a, a)))
# Out:
# expr: {b in BOOLEANS, [not](b) => (a != a)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{b \in \mathbb{B}, (\lnot b) \Rightarrow \left(a \neq a\right)\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {b in BOOLEANS, [not](b) => (a != a)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (b in BOOLEANS, [not](b) => (a != a))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. [not](b) => (a != a)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. ([not](b), a != a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. [not](b)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. a != a
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. !=
#     core type: Literal
#     sub-expressions:
# 15. (a, a)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 16. a
#     core type: Variable
#     sub-expressions:
