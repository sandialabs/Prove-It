# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, y
from proveit.logic import Equals, Set
from proveit.number import Add, Exp, frac

# %%
# build up the expression from sub-expressions
expr = Set(Equals(a, Add(b, frac(c, d), Exp(c, d))), Equals(d, y))
# Out:
# expr: {a = (b + (c / d) + c^{d}), d = y}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a = \left(b + \frac{c}{d} + c^{d}\right), d = y\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a = (b + (c / d) + c^{d}), d = y}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (a = (b + (c / d) + c^{d}), d = y)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a = (b + (c / d) + c^{d})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. d = y
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, b + (c / d) + c^{d})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (d, y)
#    core type: ExprTuple
#    sub-expressions: 20, 10
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b + (c / d) + c^{d}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (b, c / d, c^{d})
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. c / d
#     core type: Operation
#     operator: 16
#     operands: 18
# 15. c^{d}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (c, d)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. d
#     core type: Variable
#     sub-expressions:
