# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>.<a class="ProveItLink" href="../../_axioms_.ipynb#equalsTransitivity">equalsTransitivity</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.equality._axioms_ import equalsTransitivity

# %%
# %dependencies equalsTransitivity
# Out:
# <h3>Theorems that depend directly on equalsTransitivity</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../boolean/conjunction/_proofs_/commutation.ipynb">proveit.logic.boolean.conjunction.commutation</a></dt><dd><a class="ProveItLink" href="../../../boolean/conjunction/__pv_it/6dd80a70bb7f373ba48ccb3bb5954eef35f6b9890/expr.ipynb"><img src="../../../boolean/conjunction/__pv_it/6dd80a70bb7f373ba48ccb3bb5954eef35f6b9890/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../boolean/disjunction/_proofs_/demorgansLawAndToOrBinExplicit.ipynb">proveit.logic.boolean.disjunction.demorgansLawAndToOrBinExplicit</a></dt><dd><a class="ProveItLink" href="../../../boolean/disjunction/__pv_it/7a274a0bdefa1bb073d5a6de0bebdab7c77bae8e0/expr.ipynb"><img src="../../../boolean/disjunction/__pv_it/7a274a0bdefa1bb073d5a6de0bebdab7c77bae8e0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
