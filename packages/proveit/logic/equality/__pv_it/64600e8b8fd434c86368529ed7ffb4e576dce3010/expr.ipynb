# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import n
from proveit.core_expr_types._common_ import x_1_to_n, y_1_to_n
from proveit.logic import Equals, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(n, Naturals), Equals([x_1_to_n], [y_1_to_n]))
# Out:
# expr: (n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{N}, \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. n in Naturals
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 15, 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 14
#     end_index: 15
# 11. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. _a -> x_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 16
# 13. _a -> y_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. x_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 17. y_{_a}
#     core type: IndexedVar
# variable: 19
# index: 20
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. _a
#     core type: Variable
#     sub-expressions:
