# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#notEqualsInBool">notEqualsInBool</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.equality._theorems_ import notEqualsInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr notEqualsInBool
# Out:
# Passed sanity check: built 'notEqualsInBool' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(notEqualsInBool.latex())
# Out:
# \vdash \forall_{x, y}~\left(\left(x \neq y\right) \in \mathbb{B}\right)

# %%
# display the expression information
notEqualsInBool.exprInfo()
# Out:
# 0. forall_{x, y} ((x != y) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x, y) -> ((x != y) in BOOLEANS)
#    core type: Lambda
#    parameters: 9\n   body: 3
# 3. (x != y) in BOOLEANS
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (x != y, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x != y
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 8. !=
#    core type: Literal
#    sub-expressions:
# 9. (x, y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. y
#     core type: Variable
#     sub-expressions:
