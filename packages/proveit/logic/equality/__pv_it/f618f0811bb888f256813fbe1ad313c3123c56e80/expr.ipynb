# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#mult_sub_right_into">mult_sub_right_into</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.logic.equality._theorems_ import mult_sub_right_into

# %%
# check that the built expression is the same as the stored expression
# %check_expr mult_sub_right_into
# Out:
# Passed sanity check: built 'mult_sub_right_into' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mult_sub_right_into.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}}~\left[\forall_{P, x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}~|~P(x_{1}, \ldots, x_{n}), x_{1} = y_{1}, \ldots, x_{n} = y_{n}}~P(y_{1}, \ldots, y_{n})\right]

# %%
# display the expression information
mult_sub_right_into.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n}) if n in Naturals.
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. {forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n}) if n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 29, 11
# 9. (P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 21, 25, 17
# 10. {P(y_{1}, ..y_{_a}.., y_{n}) if P(x_{1}, ..x_{_a}.., x_{n}) ,  x_{1} = y_{1} ,  ..x_{a} = y_{a}.. ,  x_{n} = y_{n}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. P(y_{1}, ..y_{_a}.., y_{n})
#     core type: Operation
#     operator: 21
#     operands: 14
# 13. P(x_{1}, ..x_{_a}.., x_{n}) and (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (P(x_{1}, ..x_{_a}.., x_{n}), x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 28
#     end_index: 29
# 18. P(x_{1}, ..x_{_a}.., x_{n})
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (x_{1} = y_{1}), ..(x_{a} = y_{a}).., (x_{n} = y_{n})
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 28
#     end_index: 29
# 20. _a -> y_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 24
# 21. P
#     core type: Variable
#     sub-expressions:
# 22. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 23. a -> (x_{a} = y_{a})
#     core type: Lambda
#     parameter: 38
#     body: 26
# 24. y_{_a}
#     core type: IndexedVar
# variable: 37
# index: 35
# 25. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 29
# 26. x_{a} = y_{a}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. _a -> x_{_a}
#     core type: Lambda
#     parameter: 35
#     body: 32
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. x_{_a}
#     core type: IndexedVar
# variable: 36
# index: 35
# 33. x_{a}
#     core type: IndexedVar
# variable: 36
# index: 38
# 34. y_{a}
#     core type: IndexedVar
# variable: 37
# index: 38
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. y
#     core type: Variable
#     sub-expressions:
# 38. a
#     core type: Variable
#     sub-expressions:
