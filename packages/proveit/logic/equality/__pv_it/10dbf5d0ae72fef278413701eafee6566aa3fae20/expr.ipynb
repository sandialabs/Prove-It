# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import A
from proveit.logic import Booleans, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Conditional(Or(A, Not(A)), InSet(A, Booleans))
# Out:
# expr: {A or [not](A) if A in BOOLEANS.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{A \lor (\lnot A) \textrm{ if } A \in \mathbb{B}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or [not](A) if A in BOOLEANS.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A or [not](A)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (A, [not](A))
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 8
# 7. [not](A)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. A
#     core type: Variable
#     sub-expressions:
