# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n
from proveit.core_expr_types._common_ import P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, InSet, Set
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Set(P__y_1_to_n, InSet(n, Naturals), Equals([x_1_to_n], [y_1_to_n]))
# Out:
# expr: {P(y_{1}, ..y_{_a}.., y_{n}), n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{P(y_{1}, \ldots, y_{n}), n \in \mathbb{N}, \left(x_{1}, \ldots, x_{n}\right) = \left(y_{1}, \ldots, y_{n}\right)\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {P(y_{1}, ..y_{_a}.., y_{n}), n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (P(y_{1}, ..y_{_a}.., y_{n}), n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. P(y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 6
#    operands: 13
# 4. n in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. P
#    core type: Variable
#    sub-expressions:
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. ((x_{1}, ..x_{_a}.., x_{n}), (y_{1}, ..y_{_a}.., y_{n}))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (y_{1}, ..y_{_a}.., y_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 18
#     end_index: 19
# 15. y_{1}, ..y_{_a}.., y_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 20
# 17. _a -> y_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. x_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 21. y_{_a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
