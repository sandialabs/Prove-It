# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#equals_symmetry">equals_symmetry</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x
from proveit.logic import Equals

# %%
# %proving equals_symmetry
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="equals_symmetry">equals_symmetry:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6eaa0fec06de9345737f83f0a1ce382c3a3515530/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/bcac680860811f3ea64d2eb084f4189234c3e4950/dependencies.ipynb">dependencies</a>)<br>
# equals_symmetry may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = equals_symmetry.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a2f273775b34b7bb503fbfadbc586772d723fb0d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_y = defaults.assumptions[0]
# Out:
# <strong id="x_eq_y">x_eq_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8dc625ee9fbf5f96228c059ed58b16ec83d4e40d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_x = Equals(x, x).prove()
# Out:
# <strong id="x_eq_x">x_eq_x:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_equals_symmetry/2b9cbd84c1c4cee6c3da1743995fdedf542915120/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/8dda6f8301315b960e59ecc2c4a6b2bbaea8251e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
x_eq_y.sub_right_side_into(x_eq_x.inner_expr().lhs)
# Out:
# {x = y} |- y = x

# %%
# %qed
# Out:
# proveit.logic.equality.equals_symmetry is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y | x = y} (y = x)
# 1	modus_ponens	2, 3	{x = y} |- y = x
# 2	modus_ponens	4, 5	|- (x = y) => (y = x)
# 3	assumption		{x = y} |- x = y
# 4	instantiation	6	|- (x = x) => ((x = y) => (y = x))
# 	P(_a) : _a = x, x : x, y : y
# 5	instantiation	7	|- x = x
# 	x : x
# 6	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 7	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
