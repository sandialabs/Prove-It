# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#sub_in_right_operands_via_tuple">sub_in_right_operands_via_tuple</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import f, P, x, y
from proveit.core_expr_types.operations  import operands_substitution_via_tuple

# %%
# %proving sub_in_right_operands_via_tuple
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="sub_in_right_operands_via_tuple">sub_in_right_operands_via_tuple:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/317c9123b4e85d725f70af905065e56cd56a952a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/80b7454f359e46c236fc63c409d20e976563fdbc0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = sub_in_right_operands_via_tuple.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_right_operands_via_tuple/501a394003a3691851eee410afb31a4b0887d3d40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
operands_substitution_via_tuple
# Out:
# |- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]

# %%
Px_eq_Py = operands_substitution_via_tuple.instantiate({f:P, y:y}, auto_simplify=False)
# Out:
# <strong id="Px_eq_Py">Px_eq_Py:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../core_expr_types/operations/__pv_it/theorems/4eb6ba36ceadc85529b6f30f34cc1cfd5df14f2a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_right_operands_via_tuple/5cfcb91586d00a841b85b3190819a1defe3e0f070/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_right_operands_via_tuple/f6164c323dc59795fad352d57f0f6d21c1fabdc10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Px_eq_Py.derive_right_via_equality()
# Out:
# {P(x_{1}, x_{2}, ..., x_{n}), n in Natural, (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} |- P(y_{1}, y_{2}, ..., y_{n})
# sub_in_right_operands_via_tuple may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.equality.sub_in_right_operands_via_tuple has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in Natural} [forall_{P, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | P(x_{1}, x_{2}, ..., x_{n}), (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
# 1	instantiation	2, 3, 4	{P(x_{1}, x_{2}, ..., x_{n}), n in Natural, (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} |- P(y_{1}, y_{2}, ..., y_{n})
# 	P : P(x_{1}, x_{2}, ..., x_{n}), Q : P(y_{1}, y_{2}, ..., y_{n})
# 2	conjecture		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 3	assumption		{P(x_{1}, x_{2}, ..., x_{n})} |- P(x_{1}, x_{2}, ..., x_{n})
# 4	instantiation	5, 6, 7	{n in Natural, (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} |- P(x_{1}, x_{2}, ..., x_{n}) =  \\ P(y_{1}, y_{2}, ..., y_{n})
# 	n : n, f : P, x : x, y : y
# 5	conjecture		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution_via_tuple
# 6	assumption		{n in Natural} |- n in Natural
# 7	assumption		{(x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} |- (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})
