# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_equals_def_quantified">not_equals_def_quantified</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, y
from proveit.logic.equality import NotEquals, not_equals_def

# %%
# %proving not_equals_def_quantified
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_equals_def_quantified">not_equals_def_quantified:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/21e7d536885a56ed84171a2270197ecc886755c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/42ff745e812bb833da827410a73799258e499a5b0/dependencies.ipynb">dependencies</a>)<br>
# not_equals_def_quantified may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_equals_def
# Out:
# |- [!=] = [(x, y) -> [not](x = y)]

# %%
not_equals_def.substitution(NotEquals(x, y))
# Out:
# |- (x != y) = [not](x = y)

# %%
# %qed
# Out:
# proveit.logic.equality.not_equals_def_quantified is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y} ((x != y) = [not](x = y))
# 1	instantiation	2, 3	|- (x != y) = [not](x = y)
# 	f(_a) : _a(x, y), x : !=, y(x, _a) : [not](x = _a)
# 2	theorem		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 3	basic_definition		|- [!=] = [(x, y) -> [not](x = y)]
# 	proveit.logic.equality.not_equals_def
