# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#substitution">substitution</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, y, fx
from proveit.logic import Equals

# %%
# %proving substitution
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="substitution">substitution:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fd6beac00a3d5614502b788f4240495d5dc2218f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6b2b45f1d537fd875406c0a1e54cab17671e70d50/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = substitution.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a2f273775b34b7bb503fbfadbc586772d723fb0d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_y = defaults.assumptions[0]
# Out:
# <strong id="x_eq_y">x_eq_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8dc625ee9fbf5f96228c059ed58b16ec83d4e40d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
fx_eq_fx = Equals(fx, fx).prove()
# Out:
# <strong id="fx_eq_fx">fx_eq_fx:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_substitution/7bb6566c8f1bc80b13c7acb206fa389d240a39ee0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_substitution/1a570f10228885e78dbe9d78935df592549e15020/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
x_eq_y.sub_right_side_into(fx_eq_fx.inner_expr().rhs.operand)
# Out:
# {x = y} |- f(x) = f(y)
# substitution may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.equality.substitution is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{f, x, y | x = y} (f(x) = f(y))
# 1	modus_ponens	2, 3	{x = y} |- f(x) = f(y)
# 2	modus_ponens	4, 5	|- (x = y) => (f(x) = f(y))
# 3	assumption		{x = y} |- x = y
# 4	instantiation	6	|- (f(x) = f(x)) => ((x = y) => (f(x) = f(y)))
# 	P(_a) : f(x) = f(_a), x : x, y : y
# 5	instantiation	7	|- f(x) = f(x)
# 	x : f(x)
# 6	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
# 7	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
