# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#equals_transitivity">equals_transitivity</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving equals_transitivity
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="equals_transitivity">equals_transitivity:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f4be685f69d6f35aa60a2a5eb5b59ba252176adc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/03365395f36a9ac961441a270d5f92820ec252e90/dependencies.ipynb">dependencies</a>)<br>
# equals_transitivity may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = equals_transitivity.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f0166e6b0ed88f8bcd7b08dda96f1d59e69078c60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_y, y_eq_z = defaults.assumptions
# Out:
# <strong id="x_eq_y">x_eq_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8dc625ee9fbf5f96228c059ed58b16ec83d4e40d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="y_eq_z">y_eq_z:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86f1f58c0978f786e6b6a43d3d76208bb55c801c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
y_eq_z.sub_right_side_into(x_eq_y.inner_expr().rhs)
# Out:
# {x = y, y = z} |- x = z

# %%
# %qed
# Out:
# proveit.logic.equality.equals_transitivity is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y, z | x = y, y = z} (x = z)
# 1	instantiation	2, 3	{(x = y) and (y = z)} |- x = z
# 	P(_a) : x = _a, x : y, y : z
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	assumption		{(x = y) and (y = z)} |- (x = y) and (y = z)
