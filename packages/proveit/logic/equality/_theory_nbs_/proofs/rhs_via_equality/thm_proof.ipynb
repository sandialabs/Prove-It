# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#rhs_via_equality">rhs_via_equality</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import P, Q
from proveit.logic import Equals

# %%
# %proving rhs_via_equality
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="rhs_via_equality">rhs_via_equality:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b71cc6ded84759b8e6fdf7e824529c371b14ed8e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/7b1cc989ad7cd066f3a06aa89e11d5df7d4f334a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = rhs_via_equality.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_rhs_via_equality/f37eafe0c41f3abc665f152cb1161e191400aa480/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
P_eq_Q = Equals(P, Q)
# Out:
# <strong id="P_eq_Q">P_eq_Q:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2d3be99caaf6995e3fc04e005347f1c167e4945f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
P_eq_Q.sub_right_side_into(P)
# Out:
# {P and (P = Q)} |- Q

# %%
# %qed
# Out:
# proveit.logic.equality.rhs_via_equality is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{P, Q | P, P = Q} Q
# 1	instantiation	2, 3	{P and (P = Q)} |- Q
# 	P(_a) : _a, x : P, y : Q
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	assumption		{P and (P = Q)} |- P and (P = Q)
