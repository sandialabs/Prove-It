# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#equals_transitivity_via_implications">equals_transitivity_via_implications</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, y, z
from proveit.logic import Equals

# %%
# %proving equals_transitivity_via_implications
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="equals_transitivity_via_implications">equals_transitivity_via_implications:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/893fbd39b3a34387dde02cc5018cf5b0081f0a590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ad5d08fd6e2c7ec5be5ce1bf557da2a2a2e9e2f40/dependencies.ipynb">dependencies</a>)<br>
# equals_transitivity_via_implications may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
x_eq_y, y_eq_z = Equals(x, y), Equals(y, z)
# Out:
# <strong id="x_eq_y">x_eq_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8dc625ee9fbf5f96228c059ed58b16ec83d4e40d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="y_eq_z">y_eq_z:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86f1f58c0978f786e6b6a43d3d76208bb55c801c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
y_eq_z.sub_right_side_into(x_eq_y, assumptions=(x_eq_y, y_eq_z))
# Out:
# {x = y, y = z} |- x = z

# %%
# %qed
# Out:
# proveit.logic.equality.equals_transitivity_via_implications is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y, z} ((x = y) => ((y = z) => (x = z)))
# 1	instantiation	2	|- (x = y) => ((y = z) => (x = z))
# 	P(_a) : x = _a, x : y, y : z
# 2	axiom		|- forall_{P, x, y} (P(x) => ((x = y) => P(y)))
# 	proveit.logic.equality.sub_right_side_via_implications
