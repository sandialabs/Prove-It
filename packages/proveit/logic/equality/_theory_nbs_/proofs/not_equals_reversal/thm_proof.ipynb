# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#not_equals_reversal">not_equals_reversal</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, y
from proveit.logic.equality import Equals

# %%
# %proving not_equals_reversal
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="not_equals_reversal">not_equals_reversal:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b63fa92f9552e2ae14e2571bdff5b7fb61390f030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/892b7792eb5283105c266bd07d635b10c35885b40/dependencies.ipynb">dependencies</a>)<br>
# not_equals_reversal may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
x_neq_y = not_equals_reversal.condition
# Out:
# <strong id="x_neq_y">x_neq_y:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/73829d3be05f2b12292db7642d7f9d4a94d650a00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_neq_y.deny_via_contradiction(Equals(y, x), assumptions=[x_neq_y])
# Out:
# {x != y} |- [not](y = x)

# %%
# %qed
# Out:
# proveit.logic.equality.not_equals_reversal is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y | x != y} (y != x)
# 1	instantiation	2, 3	{x != y} |- y != x
# 	x : y, y : x
# 2	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 3	instantiation	4, 5	{x != y} |- [not](y = x)
# 	A : y = x
# 4	theorem		|- forall_{A | A => FALSE} [not](A)
# 	proveit.logic.booleans.negation.fold_negation
# 5	deduction	6	{x != y} |- (y = x) => FALSE
# 6	instantiation	7, 8	{x != y, y = x} |- FALSE
# 	x : x, y : y
# 7	theorem		|- forall_{x, y | x = y, x != y} FALSE
# 	proveit.logic.equality.not_equals_contradiction
# 8	modus_ponens	9, 10	{x != y, y = x} |- (x = y) and (x != y)
# 9	modus_ponens	11, 12	{y = x} |- (x != y) => ((x = y) and (x != y))
# 10	assumption		{x != y} |- x != y
# 11	instantiation	13	|- (x = y) => ((x != y) => ((x = y) and (x != y)))
# 	A : x = y, B : x != y
# 12	instantiation	14, 15	{y = x} |- x = y
# 	x : y, y : x
# 13	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 14	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_symmetry
# 15	assumption		{y = x} |- y = x
