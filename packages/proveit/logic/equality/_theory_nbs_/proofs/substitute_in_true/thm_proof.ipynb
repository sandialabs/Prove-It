# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#substitute_in_true">substitute_in_true</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x, Px

# %%
# %proving substitute_in_true
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="substitute_in_true">substitute_in_true:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0988059a1bd4d61fa0dc7f7468fa4a03d73271540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6c234fd8afa5598f934e46054662f1aa2cd295230/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = substitute_in_true.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_substitute_in_true/c63f24e455c7caa949f7169ed8e45197900336b40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_T = x.evaluation()
# Out:
# <strong id="x_eq_T">x_eq_T:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/f4dee20522cfc6c449d72ada219a9acaf19a31c00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_substitute_in_true/3cfb024ddb58c4c56c63ed0d72b417dce7c4f58d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_substitute_in_true/bf33112201b7d048ccd09879561f49a80b7cd1fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
x_eq_T.sub_right_side_into(Px)
# Out:
# {P(x) and x} |- P(TRUE)

# %%
# %qed
# Out:
# proveit.logic.equality.substitute_in_true is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{P, x | P(x), x} P(TRUE)
# 1	instantiation	2, 3	{P(x) and x} |- P(TRUE)
# 	P(_a) : P(_a), x : x, y : TRUE
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	modus_ponens	4, 5	{P(x) and x} |- P(x) and (x = TRUE)
# 4	modus_ponens	6, 7	{P(x) and x} |- (x = TRUE) => (P(x) and (x = TRUE))
# 5	instantiation	8, 9	{P(x) and x} |- x = TRUE
# 	A : x
# 6	instantiation	10	|- P(x) => ((x = TRUE) => (P(x) and (x = TRUE)))
# 	A : P(x), B : x = TRUE
# 7	instantiation	11, 13	{P(x) and x} |- P(x)
# 	A : P(x), B : x
# 8	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 9	instantiation	12, 13	{P(x) and x} |- x
# 	A : P(x), B : x
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 12	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 13	assumption		{P(x) and x} |- P(x) and x
