# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#substitute_truth">substitute_truth</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import x
from proveit.logic import PofTrue

# %%
# %proving substitute_truth
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="substitute_truth">substitute_truth:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2ab51f701f0ff9fb65cd28c535b1265f4bcde8cf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/4a8e5e858ef892abfd616edcd4391848d829ec390/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = substitute_truth.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_substitute_truth/6782e56f7b1473d6f4b160d58714627989a4ae7b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_eq_T = x.evaluation()
# Out:
# <strong id="x_eq_T">x_eq_T:</strong> &#128522;<span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8e76ab3f5a6be3df6dc0e33df32feebbf48c39340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_substitute_truth/f9b220723aee7da33e71263f38c4f53d136c13230/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_substitute_truth/bf33112201b7d048ccd09879561f49a80b7cd1fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
x_eq_T.sub_left_side_into(PofTrue)
# Out:
# {P(TRUE) and x} |- P(x)

# %%
# %qed
# Out:
# proveit.logic.equality.substitute_truth is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{P, x | P(TRUE), x} P(x)
# 1	instantiation	2, 3	{P(TRUE) and x} |- P(x)
# 	P(_a) : P(_a), x : x, y : TRUE
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	modus_ponens	4, 5	{P(TRUE) and x} |- P(TRUE) and (x = TRUE)
# 4	modus_ponens	6, 7	{P(TRUE) and x} |- (x = TRUE) => (P(TRUE) and (x = TRUE))
# 5	instantiation	8, 9	{P(TRUE) and x} |- x = TRUE
# 	A : x
# 6	instantiation	10	|- P(TRUE) => ((x = TRUE) => (P(TRUE) and (x = TRUE)))
# 	A : P(TRUE), B : x = TRUE
# 7	instantiation	11, 13	{P(TRUE) and x} |- P(TRUE)
# 	A : P(TRUE), B : x
# 8	axiom		|- forall_{A | A} (A = TRUE)
# 	proveit.logic.booleans.eq_true_intro
# 9	instantiation	12, 13	{P(TRUE) and x} |- x
# 	A : P(TRUE), B : x
# 10	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
# 11	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 12	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 13	assumption		{P(TRUE) and x} |- P(TRUE) and x
