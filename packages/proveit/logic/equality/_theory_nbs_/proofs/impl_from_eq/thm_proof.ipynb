# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#impl_from_eq">impl_from_eq</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
defaults.assumptions = [] # often useful to set
defaults.auto_simplify = False # can be convenient to enable

from proveit import A
from proveit.logic import Implies

# %%
# %proving impl_from_eq

# %%
A_eq_B = impl_from_eq.condition

# %%
defaults.assumptions = [A_eq_B]

# %%
A_eq_B.derive_right_via_equality(assumptions=[A_eq_B, A])

# %%
# %qed
