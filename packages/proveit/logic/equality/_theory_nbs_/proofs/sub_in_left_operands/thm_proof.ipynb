# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#sub_in_left_operands">sub_in_left_operands</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import f, P, x, y
from proveit.core_expr_types.operations  import operands_substitution

# %%
# %proving sub_in_left_operands
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="sub_in_left_operands">sub_in_left_operands:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2a2d92cdcc9976ebf0475dddef4c2a1cc1bb67870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3746a35d837f28687496fbbf51302cf6ff4d479c0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = sub_in_left_operands.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_left_operands/6bef0c5636dffbe045cbeee08d870f6b744ec3100/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
operands_substitution
# Out:
# |- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]

# %%
Px_eq_Py = operands_substitution.instantiate({f:P, y:y}, auto_simplify=False)
# Out:
# <strong id="Px_eq_Py">Px_eq_Py:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/1a8a7907b709bbd24c48a9933f16dbe96429f5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../core_expr_types/__pv_it/common/90c14781fde8b99d2d44751db7cdffc2871ba3210/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_left_operands/14e7090fabfef6f071d2a84846b7e263cbfec23b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sub_in_left_operands/f6164c323dc59795fad352d57f0f6d21c1fabdc10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Px_eq_Py.derive_left_via_equality()
# Out:
# {P(y_{1}, y_{2}, ..., y_{n}), n in Natural,(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- P(x_{1}, x_{2}, ..., x_{n})
# sub_in_left_operands may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.equality.sub_in_left_operands has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in Natural} [forall_{P, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | P(y_{1}, y_{2}, ..., y_{n}),(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} P(x_{1}, x_{2}, ..., x_{n})]
# 1	instantiation	2, 3, 4	{P(y_{1}, y_{2}, ..., y_{n}), n in Natural,(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- P(x_{1}, x_{2}, ..., x_{n})
# 	P : P(x_{1}, x_{2}, ..., x_{n}), Q : P(y_{1}, y_{2}, ..., y_{n})
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhs_via_equality
# 3	assumption		{P(y_{1}, y_{2}, ..., y_{n})} |- P(y_{1}, y_{2}, ..., y_{n})
# 4	instantiation	5, 6, 7	{n in Natural,(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- P(x_{1}, x_{2}, ..., x_{n}) =  \\ P(y_{1}, y_{2}, ..., y_{n})
# 	n : n, f : P, x : x, y : y
# 5	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 6	assumption		{n in Natural} |- n in Natural
# 7	assumption		{(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- (x_{1} = y_{1}) and  (x_{2} = y_{2}) and  ... and  (x_{n} = y_{n})
