# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#sub_in_left_operands">sub_in_left_operands</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import f, P, x, y
from proveit.core_expr_types.operations  import operands_substitution

# %%
# %proving sub_in_left_operands
# Out:
# sub_in_left_operands: forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{n})]

# %%
defaults.assumptions = sub_in_left_operands.all_conditions()
# Out:
# defaults.assumptions: (n in Natural, P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))

# %%
operands_substitution
# Out:
# |- forall_{n in Natural} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
Px_eq_Py = operands_substitution.instantiate({f:P, y:y})
# Out:
# Px_eq_Py: {n in Natural, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n}) = P(y_{1}, ..y_{_a}.., y_{n})

# %%
Px_eq_Py.derive_left_via_equality()
# Out:
# {P(y_{1}, ..y_{_a}.., y_{n}), n in Natural, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n})

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in Natural} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{n})]
# 1	instantiation	2, 3, 4	{P(y_{1}, ..y_{_a}.., y_{n}), n in Natural, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n})
# 	P : P(x_{1}, ..x_{_a}.., x_{n}), Q : P(y_{1}, ..y_{_a}.., y_{n})
# 2	conjecture		|- forall_{P, Q | Q, P = Q} P
# 3	assumption		{P(y_{1}, ..y_{_a}.., y_{n})} |- P(y_{1}, ..y_{_a}.., y_{n})
# 4	instantiation	5, 6, 7	{n in Natural, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n}) = P(y_{1}, ..y_{_a}.., y_{n})
# 	n : n, f : P, x : x, y : y
# ...
