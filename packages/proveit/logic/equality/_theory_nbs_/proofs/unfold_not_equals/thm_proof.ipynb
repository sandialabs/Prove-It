# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#unfold_not_equals">unfold_not_equals</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving unfold_not_equals
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="unfold_not_equals">unfold_not_equals:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e42f6f162f844bb3f18b6f3cc764b6573b311a9d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d8342395538288164695495beffa91c497bca55d0/dependencies.ipynb">dependencies</a>)<br>
# unfold_not_equals may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
defaults.assumptions = unfold_not_equals.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_not_equals/4529c0ef731953eece82e7a9a89c13c169064d200/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
x_neq_y__def = defaults.assumptions[0].definition()
# Out:
# <strong id="x_neq_y__def">x_neq_y__def:</strong> &#128522;<span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_unfold_not_equals/d0f0ffff1e21406d5cf8a97d6f36623a9f7aad5e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/b7c05d17ee869aaec969ec8a6bfc0f98838498610/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
x_neq_y__def.derive_right_via_equality()
# Out:
# {x != y} |- [not](x = y)

# %%
# %qed
# Out:
# proveit.logic.equality.unfold_not_equals is now proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y | x != y} [not](x = y)
# 1	instantiation	2, 3	{x != y} |- [not](x = y)
# 	P : x != y, Q : [not](x = y)
# 2	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 3	modus_ponens	4, 5	{x != y} |- (x != y) and ((x != y) = [not](x = y))
# 4	modus_ponens	6, 7	{x != y} |- ((x != y) = [not](x = y)) => ((x != y) and ((x != y) = [not](x = y)))
# 5	instantiation	8	|- (x != y) = [not](x = y)
# 	x : x, y : y
# 6	instantiation	9	|- (x != y) => (((x != y) = [not](x = y)) => ((x != y) and ((x != y) = [not](x = y))))
# 	A : x != y, B : (x != y) = [not](x = y)
# 7	assumption		{x != y} |- x != y
# 8	theorem		|- forall_{x, y} ((x != y) = [not](x = y))
# 	proveit.logic.equality.not_equals_def_quantified
# 9	theorem		|- forall_{A, B} (A => (B => (A and B)))
# 	proveit.logic.booleans.conjunction.conjunction_intro
