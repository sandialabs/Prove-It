# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../theory.ipynb">equality</a>.<a class="ProveItLink" href="../../theorems.ipynb#multi_substitution">multi_substitution</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic import And
from proveit import a, b, i, n, x, y
from proveit.core_expr_types.tuples import tuple_eq_via_elem_eq
from proveit.core_expr_types.operations  import operands_substitution
theory = proveit.Theory() # the theorem's theory

# %%
# %proving multi_substitution
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="multi_substitution">multi_substitution:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ee59572f6557485eadc96d9ac04e35bff7fe4c1e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9916704dbdf0bb8da6a6ca814cd81d2141e6975a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = multi_substitution.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_multi_substitution/6af074d11b97454037bc47da279adff77b19b3820/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
operands_substitution
# Out:
# |- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]

# %%
operands_substitution.instantiate({y:y})
# Out:
# {n in NaturalPos,(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n})
# multi_substitution may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.equality.multi_substitution has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in NaturalPos} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) = f(y_{1}, y_{2}, ..., y_{n}))]
# 1	instantiation	2, 3, 4	{n in NaturalPos,(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n})
# 	n : n, f : f, x : x, y : y
# 2	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 3	instantiation	5, 6, 7	{n in NaturalPos} |- n in Natural
# 	A : NaturalPos, B : Natural, x : n
# 4	assumption		{(x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} |- (x_{1} = y_{1}) and  (x_{2} = y_{2}) and  ... and  (x_{n} = y_{n})
# 5	conjecture		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 6	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 7	assumption		{n in NaturalPos} |- n in NaturalPos
