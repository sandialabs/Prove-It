# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">equality</a>.<a class="ProveItLink" href="../_theorems_.ipynb#multiSubstitution">multiSubstitution</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import n, x, y
from proveit.logic import InSet, Equals
from proveit.number import NaturalsPos
from proveit.logic.equality._axioms_ import substitution
from proveit.logic._common_ import xIter1n, yIter1n, f_xIter1n, f_yIter1n
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving multiSubstitution presuming [proveit.logic]
# Out:
# Beginning proof of multiSubstitution
# Recorded 'presuming' information
# Presuming theorems in proveit.logic (except any that presume this theorem).
# Presuming previous theorems (applied transitively).
# multiSubstitution: forall_{n in NaturalsPos} [forall_{f, x_1,...,x_n, y_1,...,y_n | x_1 = y_1 ,  ...  , x_n = y_n} (f(x_1,...,x_n) = f(y_1,...,y_n))]

# %%
defaults.assumptions = multiSubstitution.allConditions()
# Out:
# defaults.assumptions: (n in NaturalsPos , x_1 = y_1 ,  ...  , x_n = y_n)

# %%
substitution
# Out:
# |= forall_{f, x, y | x = y} (f(x) = f(y))

# %%
substitutionSpec = substitution.specialize({x:xIter1n, y:yIter1n}, assumptions=[Equals(x, y)])
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     409                     # first attempt to prove via implication
# --> 410                     concludedTruth = self.concludeViaImplication(assumptions)
#     411                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     458         from proveit.logic import concludeViaImplication
# --> 459         return concludeViaImplication(self, assumptions)
#     460
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# ...

# %%
substitutionSpec = substitution.specialize({x:xIter1n, y:yIter1n})
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     409                     # first attempt to prove via implication
# --> 410                     concludedTruth = self.concludeViaImplication(assumptions)
#     411                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     458         from proveit.logic import concludeViaImplication
# --> 459         return concludeViaImplication(self, assumptions)
#     460
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# ...

# %%
substitutionSpec.substituted({x:xIter1n, y: yIter1n})
# Out:
# f(x_1,...,x_n) = f(y_1,...,y_n)

# %%
# %qed
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     409                     # first attempt to prove via implication
# --> 410                     concludedTruth = self.concludeViaImplication(assumptions)
#     411                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     458         from proveit.logic import concludeViaImplication
# --> 459         return concludeViaImplication(self, assumptions)
#     460
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# ...
