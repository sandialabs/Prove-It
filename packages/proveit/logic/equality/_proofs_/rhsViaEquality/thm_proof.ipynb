# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">equality</a>.<a href="../_theorems_.ipynb#rhsViaEquality" class="ProveItLink">rhsViaEquality</a> theorem
# ========

# %%
import proveit
from proveit import defaults, Lambda
from proveit._common_ import x, y, P, Q, X
from proveit.logic.equality._theorems_ import subRightSideInto
context = proveit.Context() # the theorem's context

# %%
# %proving rhsViaEquality

# %%
defaults.assumptions = rhsViaEquality.allConditions()

# %%
subRightSideInto

# %%
subRightSideInto.instantiate({P:Lambda(X, X), x:P, y:Q})

# %%
# %qed
