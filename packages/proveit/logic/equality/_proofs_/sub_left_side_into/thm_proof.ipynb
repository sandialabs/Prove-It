# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">equality</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#sub_left_side_into">sub_left_side_into</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import f, x, y, P, Px, Py
from proveit.logic import Equals
from proveit.logic.equality._axioms_ import substitution
theory = proveit.Theory() # the theorem's theory

# %%
# %proving sub_left_side_into

# %%
defaults.assumptions = sub_left_side_into.all_conditions()

# %%
substitution

# %%
# P(x)=P(y) from x=y via substitution
substitution.instantiate({f:P, x:x, y:y})

# %%
# P(x)=TRUE via P(y)=TRUE and transitivity
Px.evaluation()

# %%
# %qed
