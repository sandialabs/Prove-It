# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">equality</a>.<a class="ProveItLink" href="../_theorems_.ipynb#multi_substitution">multi_substitution</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.logic import And
from proveit._common_ import a, b, i, n, x, y
from proveit.core_expr_types.tuples._theorems_ import tuple_eq_via_elem_eq
from proveit.core_expr_types.operations._axioms_ import operands_substitution
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving multi_substitution presuming [tuple_eq_via_elem_eq]
# Out:
# Beginning proof of multi_substitution
# Recorded 'presuming' information
# Presuming proveit.core_expr_types.tuples.tuple_eq_via_elem_eq theorem (applied transitively).
# Presuming previous theorems (applied transitively).
# multi_substitution: forall_{n in NaturalsPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
defaults.assumptions = multi_substitution.allConditions()
# Out:
# defaults.assumptions: (n in NaturalsPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n})

# %%
tuple_eq_via_elem_eq
# Out:
# |- forall_{i in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]

# %%
tuple_eq_via_elem_eq.instantiate({i:n,a:x,b:y})
# Out:
# {n in NaturalsPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})

# %%
operands_substitution
# Out:
# |- forall_{n in Naturals} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
operands_substitution.instantiate({y:y})
# Out:
# {n in NaturalsPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in NaturalsPos} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]
# 1	instantiation	2, 3, 4	{n in NaturalsPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n})
# 	n : n, f : f, x : x, y : y
# 2	axiom		|- forall_{n in Naturals} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 3	instantiation	5, 6, 8	{n in NaturalsPos} |- n in Naturals
# 	A : NaturalsPos, B : Naturals, x : n
# 4	instantiation	7, 8, 9	{n in NaturalsPos, x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})
# 	i : n, a : x, b : y
# 5	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 6	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 7	theorem		|- forall_{i in NaturalsPos} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{i} | a_{1} = b_{1}, ..a_{k} = b_{k}.., a_{i} = b_{i}} ((a_{1}, ..a_{_a}.., a_{i}) = (b_{1}, ..b_{_a}.., b_{i}))]
# 	proveit.core_expr_types.tuples.tuple_eq_via_elem_eq
# 8	assumption		{n in NaturalsPos} |- n in NaturalsPos
# 9	assumption		{x_{1} = y_{1}, ..x_{a} = y_{a}.., x_{n} = y_{n}} |- (x_{1} = y_{1}) and ..(x_{a} = y_{a}).. and (x_{n} = y_{n})
