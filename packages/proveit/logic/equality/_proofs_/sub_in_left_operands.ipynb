# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../_context_.ipynb">equality</a>.<a class="ProveItLink" href="../_theorems_.ipynb#sub_in_left_operands">sub_in_left_operands</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory
from proveit import defaults
from proveit._common_ import f, P, x, y
from proveit.core_expr_types.operations._axioms_ import operands_substitution

# %%
# %proving sub_in_left_operands presuming []
# Out:
# Beginning proof of sub_in_left_operands
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# sub_in_left_operands: forall_{n in Naturals} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{n})]

# %%
defaults.assumptions = sub_in_left_operands.allConditions()
# Out:
# defaults.assumptions: (n in Naturals, P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n}))

# %%
operands_substitution
# Out:
# |- forall_{n in Naturals} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) = f(y_{1}, ..y_{_a}.., y_{n}))]

# %%
Px_eq_Py = operands_substitution.instantiate({f:P, y:y})
# Out:
# Px_eq_Py: {n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n}) = P(y_{1}, ..y_{_a}.., y_{n})

# %%
Px_eq_Py.deriveLeftViaEquivalence()
# Out:
# {P(y_{1}, ..y_{_a}.., y_{n}), n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n})

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{n in Naturals} [forall_{P, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | P(y_{1}, ..y_{_a}.., y_{n}), (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} P(x_{1}, ..x_{_a}.., x_{n})]
# 1	instantiation	2, 3, 4	{P(y_{1}, ..y_{_a}.., y_{n}), n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n})
# 	P : P(x_{1}, ..x_{_a}.., x_{n}), Q : P(y_{1}, ..y_{_a}.., y_{n})
# 2	theorem		|- forall_{P, Q | Q, P = Q} P
# 	proveit.logic.equality.lhsViaEquivalence
# 3	assumption		{P(y_{1}, ..y_{_a}.., y_{n})} |- P(y_{1}, ..y_{_a}.., y_{n})
# 4	instantiation	5, 6, 7	{n in Naturals, (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} |- P(x_{1}, ..x_{_a}.., x_{n}) = P(y_{1}, ..y_{_a}.., y_{n})
# 	n : n, f : P, x : x, y : y
# ...
