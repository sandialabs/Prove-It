# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../../_theory_.ipynb">equality</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#sub_in_right_operands">sub_in_right_operands</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit._common_ import f, P, x, y
from proveit.core_expr_types.operations._axioms_ import operands_substitution

# %%
# %proving sub_in_right_operands

# %%
defaults.assumptions = sub_in_right_operands.all_conditions()

# %%
operands_substitution

# %%
Px_eq_Py = operands_substitution.instantiate({f:P, y:y})

# %%
Px_eq_Py.derive_right_via_equality()

# %%
# %qed
