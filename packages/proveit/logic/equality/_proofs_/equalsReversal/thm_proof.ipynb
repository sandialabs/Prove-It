# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../_theory_.ipynb">equality</a>.<a href="../_theorems_.ipynb#equalsReversal" class="ProveItLink">equalsReversal</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, y
from proveit.logic.equality._axioms_ import equalsSymmetry
theory = proveit.Theory() # the theorem's theory

# %%
# %proving equalsReversal

# %%
defaults.assumptions = equalsReversal.allConditions()

# %%
equalsSymmetry

# %%
eq_sym = equalsSymmetry.instantiate({x:x, y:y})

# %%
eq_sym.deriveLeftViaEquality()

# %%
# %qed
