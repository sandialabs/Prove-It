# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_.ipynb">logic</a>.<a class="ProveItLink" href="../_theory_.ipynb">equality</a>.<a href="../_theorems_.ipynb#substituteTruth" class="ProveItLink">substituteTruth</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import x, P, Px
from proveit.logic._common_ import PofTrue
theory = proveit.Theory() # the theorem's theory

# %%
# %proving substituteTruth

# %%
defaults.assumptions = substituteTruth.allConditions()

# %%
x_eq_T = x.evaluation()

# %%
x_eq_T.subLeftSideInto(PofTrue)

# %%
# %qed
