# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">quantum</a>.circuits
# ========
#
# Provide description here.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#qcircuit_eq_def">proveit.physics.quantum.circuits.qcircuit_eq_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/276b536fec3f74a48c6cda9ff45d7b5f18ea4c880/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# ...
