# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#circuit_equiv_temporal_sub">circuit_equiv_temporal_sub</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving circuit_equiv_temporal_sub
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="circuit_equiv_temporal_sub">circuit_equiv_temporal_sub:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c11ccb3b69ae77c8296c421a1d86cb7d0891bc350/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/0839a6070399f2c0ba65d57e7fb2d82d693d120f0/dependencies.ipynb">dependencies</a>)<br>
