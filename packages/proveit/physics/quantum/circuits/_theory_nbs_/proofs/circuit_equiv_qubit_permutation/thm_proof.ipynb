# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#circuit_equiv_qubit_permutation">circuit_equiv_qubit_permutation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving circuit_equiv_qubit_permutation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="circuit_equiv_qubit_permutation">circuit_equiv_qubit_permutation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f8c61a50cc54dc351c4aab0aa3afe4e28a524fae0/expr.ipynb"><img src="...
