# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#phase_kickbacks_on_register">phase_kickbacks_on_register</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving phase_kickbacks_on_register
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="phase_kickbacks_on_register">phase_kickbacks_on_register:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ca5bc54fd600a448a4c54ad45845ad1b2933af430/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/151ffed1d0b0e5d1e8d064e8b68d60de614cfc5e0/dependencies.ipynb">dependencies</a>)<br>
