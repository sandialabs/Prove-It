# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#register_meas_bijection">register_meas_bijection</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving register_meas_bijection
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="register_meas_bijection">register_meas_bijection:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6c1752e89c6640b5327e76c38299fa58bb1dfb550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e2fcfd6c3261fa8cab19c68374f028f6d62adbb30/dependencies.ipynb">dependencies</a>)<br>
