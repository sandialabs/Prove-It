# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#input_consolidation">input_consolidation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving input_consolidation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="input_consolidation">input_consolidation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/988da03d062a958d2fb1d545f5f7e704b94374590/expr.ipynb"><img src="..." style="disp
