# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, b
from proveit.logic import And, Equals, InSet, Set
from proveit.numbers import Abs, Exp, one, two, zero
from proveit.physics.quantum import Bra, Qmult, QubitSpace, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import qubit_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Prob(qubit_meas), Exp(Abs(Qmult(Bra(b), var_ket_psi)), two)), And(InSet(var_ket_psi, QubitSpace), InSet(b, Set(zero, one)), normalized_var_ket_psi))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right) = \left|\langle b \rvert \thinspace \lvert \psi \rangle\right|^{2} \textrm{ if } \lvert \psi \rangle \in \mathbb{C}^{2} ,  b \in \left\{0, 1\right\} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))) = |〈b| . |psi>|^{2} if |psi> in Complex^{2} ,  b in {0, 1} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))) = |〈b| . |psi>|^{2}
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. (|psi> in Complex^{2}) and (b in {0, 1}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))), |〈b| . |psi>|^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|psi> in Complex^{2}, b in {0, 1}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))))
#    core type: Operation
#    operator: 11
#    operand: 20
# 7. |〈b| . |psi>|^{2}
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. |psi> in Complex^{2}
#    core type: Operation
#    operator: 16
#    operands: 15
# 9. b in {0, 1}
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. |||psi>|| = 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 11. Pr
#     core type: Literal
#     sub-expressions:
# 12. (QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))))
#     core type: ExprTuple
#     sub-expressions: 20
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (|〈b| . |psi>|, 2)
#     core type: ExprTuple
#     sub-expressions: 21, 40
# 15. (|psi>, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 55, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (b, {0, 1})
#     core type: ExprTuple
#     sub-expressions: 61, 23
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 42
# 20. QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. |〈b| . |psi>|
#     core type: Operation
#     operator: 27
#     operand: 38
# 22. Complex^{2}
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. {0, 1}
#     core type: Operation
#     operator: 31
#     operands: 32
# 24. |||psi>||
#     core type: Operation
#     operator: 33
#     operand: 55
# 25. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 26. VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 27. Abs
#     core type: Literal
#     sub-expressions:
# 28. (〈b| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 38
# 29. CartExp
#     core type: Literal
#     sub-expressions:
# 30. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 31. Set
#     core type: Literal
#     sub-expressions:
# 32. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 33. Abs
#     core type: Literal
#     sub-expressions:
# 34. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 55
# 35. ([INPUT]{state:|psi>})
#     core type: ExprTuple
#     sub-expressions: 43
# 36. ([MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 44
# 37. ([OUTPUT]{state:|b〉})
#     core type: ExprTuple
#     sub-expressions: 45
# 38. 〈b| . |psi>
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. 2
#     core type: Literal
#     sub-expressions:
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. [INPUT]{state:|psi>}
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 50
#     operands: 51
# 45. [OUTPUT]{state:|b〉}
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. .
#     core type: Literal
#     sub-expressions:
# 47. (〈b|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. INPUT
#     core type: Literal
#     sub-expressions:
# 49. {state:|psi>}
#     core type: NamedExprs
#     state: 55
# 50. MEASURE
#     core type: Literal
#     sub-expressions:
# 51. {basis:Z}
#     core type: NamedExprs
#     basis: 56
# 52. OUTPUT
#     core type: Literal
#     sub-expressions:
# 53. {state:|b〉}
#     core type: NamedExprs
#     state: 57
# 54. 〈b|
#     core type: Operation
#     operator: 58
#     operand: 61
# 55. |psi>
#     core type: Variable
#     sub-expressions:
# 56. Z
#     core type: Literal
#     sub-expressions:
# 57. |b〉
#     core type: Operation
#     operator: 59
#     operand: 61
# 58. BRA
#     core type: Literal
#     sub-expressions:
# 59. KET
#     core type: Literal
#     sub-expressions:
# 60. (b)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. b
#     core type: Variable
#     sub-expressions:
