# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import U_1_to_i, V_1_to_j
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import one
from proveit.physics.quantum import m_ket_domain, var_ket_psi
from proveit.physics.quantum.circuits import circuit_Ui_Vj, circuit_Ui_psi_m, circuit_psi_m_Vj
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [var_ket_psi], instance_expr = Forall(instance_param_or_params = [U_1_to_i, V_1_to_j], instance_expr = Implies(Equals(Prob(circuit_psi_m_Vj), one), Equals(Prob(circuit_Ui_Vj), Prob(circuit_Ui_psi_m)).with_wrapping_at(2)).with_wrapping_at(2)).with_wrapping(), domain = m_ket_domain).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\lvert \psi \rangle \in \mathbb{C}^{2^{m}}}~\\
# \left[\begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & { /^{m} } \qw
# } \end{array}\right) = 1\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) =  \\ \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \qout{\lvert \psi \rangle}
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{|psi> in Complex^{2^{m}}} [forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (|psi> -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))) if |psi> in Complex^{2^{m}}.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. |psi> -> {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))) if |psi> in Complex^{2^{m}}.
#    core type: Lambda
#    parameter: 73
#    body: 4
# 3. (|psi>)
#    core type: ExprTuple
#    sub-expressions: 73
# 4. {forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))) if |psi> in Complex^{2^{m}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. |psi> in Complex^{2^{m}}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}) -> ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (|psi>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 73, 12
# 11. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}) -> ((Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))))
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. Complex^{2^{m}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 14. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. CartExp
#     core type: Literal
#     sub-expressions:
# 16. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. =>
#     core type: Literal
#     sub-expressions:
# 18. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1, Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Complex
#     core type: Literal
#     sub-expressions:
# 20. 2^{m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. Exp
#     core type: Literal
#     sub-expressions:
# 24. (2, m)
#     core type: ExprTuple
#     sub-expressions: 28, 76
# 25. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))), 1)
#     core type: ExprTuple
#     sub-expressions: 29, 75
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))), Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: Operation
#     operator: 34
#     operand: 36
# 30. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: Operation
#     operator: 34
#     operand: 37
# 31. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 34
#     operand: 38
# 32. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 37
# 34. Pr
#     core type: Literal
#     sub-expressions:
# 35. (QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 38
# 36. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))
#     core type: Operation
#     operator: 41
#     operands: 39
# 37. QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))
#     core type: Operation
#     operator: 41
#     operands: 40
# 38. QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 41. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 42. VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. V_{1}, V_{2}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 75
#     end_index: 49
# 45. U_{1}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 75
#     end_index: 51
# 46. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 52
# 47. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 75
#     end_index: 76
# 48. _a -> V_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 54
# 49. j
#     core type: Variable
#     sub-expressions:
# 50. _a -> U_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 55
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 75
#     end_index: 76
# 53. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 74
#     body: 57
# 54. V_{_a}
#     core type: IndexedVar
# variable: 58
# index: 74
# 55. U_{_a}
#     core type: IndexedVar
# variable: 59
# index: 74
# 56. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 74
#     body: 61
# 57. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 63
#     operands: 62
# 58. V
#     core type: Variable
#     sub-expressions:
# 59. U
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 61. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 65
#     targets: 67
# 63. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 64. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 66
#     targets: 67
# 65. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 68
#     operands: 70
# 66. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. {1 .. m}
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. INPUT
#     core type: Literal
#     sub-expressions:
# 69. OUTPUT
#     core type: Literal
#     sub-expressions:
# 70. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 73
#     part: 74
# 71. Interval
#     core type: Literal
#     sub-expressions:
# 72. (1, m)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. |psi>
#     core type: Variable
#     sub-expressions:
# 74. _a
#     core type: Variable
#     sub-expressions:
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. m
#     core type: Variable
#     sub-expressions:
