# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, n
from proveit.logic import InSet
from proveit.physics.quantum import m_bit_interval
from proveit.physics.quantum.circuits import register_meas

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(register_meas, InSet(n, m_bit_interval))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array} \textrm{ if } n \in \{0~\ldotp \ldotp~2^{m} - 1\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#    core type: Lambda
#    parameter: 57
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 57
# 3. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. n in {0 .. 2^{m} - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 7. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n, {0 .. 2^{m} - 1})
#    core type: ExprTuple
#    sub-expressions: 57, 13
# 10. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 15
# 12. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 48
#     operands: 17
# 14. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 54
#     end_index: 58
# 15. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 54
#     end_index: 58
# 16. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 54
#     end_index: 58
# 17. (0, 2^{m} - 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 53
#     body: 23
# 19. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 53
#     body: 24
# 20. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 53
#     body: 26
# 21. 0
#     core type: Literal
#     sub-expressions:
# 22. 2^{m} - 1
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 32
#     operands: 29
# 24. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (2^{m}, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 36
#     targets: 39
# 30. MEASURE
#     core type: Literal
#     sub-expressions:
# 31. {basis:Z}
#     core type: NamedExprs
#     basis: 37
# 32. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 33. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 38
#     targets: 39
# 34. 2^{m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. -1
#     core type: Operation
#     operator: 42
#     operand: 54
# 36. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. Z
#     core type: Literal
#     sub-expressions:
# 38. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. {1 .. m}
#     core type: Operation
#     operator: 48
#     operands: 49
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (2, m)
#     core type: ExprTuple
#     sub-expressions: 50, 58
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 44. INPUT
#     core type: Literal
#     sub-expressions:
# 45. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 51
#     part: 53
# 46. OUTPUT
#     core type: Literal
#     sub-expressions:
# 47. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 52
#     part: 53
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (1, m)
#     core type: ExprTuple
#     sub-expressions: 54, 58
# 50. 2
#     core type: Literal
#     sub-expressions:
# 51. |psi>
#     core type: Variable
#     sub-expressions:
# 52. |n〉_{m}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. _a
#     core type: Variable
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. NUM_KET
#     core type: Literal
#     sub-expressions:
# 56. (n, m)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. m
#     core type: Variable
#     sub-expressions:
