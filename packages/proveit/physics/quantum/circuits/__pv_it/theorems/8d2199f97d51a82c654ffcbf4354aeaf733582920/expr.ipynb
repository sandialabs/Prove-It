# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.statistics.Prob.html">Prob</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.physics.quantum.circuits import phase_kickback_circuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Prob(phase_kickback_circuit)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U} & \qout{\lvert u \rangle}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Pr
#    core type: Literal
#    sub-expressions:
# 2. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 46
#    operands: 15
# 10. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 82
#     end_index: 21
# 11. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#     core type: Operation
#     operator: 37
#     operands: 17
# 12. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 82
#     end_index: 21
# 13. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: Operation
#     operator: 52
#     operands: 19
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 82
#     end_index: 21
# 15. {state:|+〉}
#     core type: NamedExprs
#     state: 22
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 61
#     body: 23
# 17. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 24
#     targets: 25
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 61
#     body: 26
# 19. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 27
# 20. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 61
#     body: 29
# 21. m + 1
#     core type: Operation
#     operator: 67
#     operands: 30
# 22. |+〉
#     core type: Operation
#     operator: 78
#     operand: 39
# 23. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 37
#     operands: 32
# 24. CONTROL
#     core type: Literal
#     sub-expressions:
# 25. {2}
#     core type: Operation
#     operator: 33
#     operand: 85
# 26. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 37
#     operands: 35
# 27. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 65
#     operands: 36
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 29. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 82
# 31. (+)
#     core type: ExprTuple
#     sub-expressions: 39
# 32. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 40
#     targets: 45
# 33. Set
#     core type: Literal
#     sub-expressions:
# 34. (2)
#     core type: ExprTuple
#     sub-expressions: 85
# 35. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 41
#     targets: 45
# 36. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 37. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 38. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 44
#     targets: 45
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 46
#     operands: 53
# 41. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. 1 / sqrt(2)
#     core type: Operation
#     operator: 74
#     operands: 49
# 43. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 50
#     operands: 51
# 44. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 52
#     operands: 53
# 45. {2 .. m + 2}
#     core type: Operation
#     operator: 54
#     operands: 55
# 46. INPUT
#     core type: Literal
#     sub-expressions:
# 47. GATE
#     core type: Literal
#     sub-expressions:
# 48. {operation:U, part:_a}
#     core type: NamedExprs
#     operation: 56
#     part: 61
# 49. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 82, 57
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 52. OUTPUT
#     core type: Literal
#     sub-expressions:
# 53. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 60
#     part: 61
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 85, 62
# 56. U
#     core type: Variable
#     sub-expressions:
# 57. sqrt(2)
#     core type: Operation
#     operator: 76
#     operands: 63
# 58. |0〉
#     core type: Operation
#     operator: 78
#     operand: 70
# 59. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. |u>
#     core type: Variable
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. m + 2
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 85, 69
# 64. (0)
#     core type: ExprTuple
#     sub-expressions: 70
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. +
#     core type: Literal
#     sub-expressions:
# 68. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 73, 85
# 69. 1 / 2
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. 0
#     core type: Literal
#     sub-expressions:
# 71. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. |1〉
#     core type: Operation
#     operator: 78
#     operand: 82
# 73. m
#     core type: Variable
#     sub-expressions:
# 74. /
#     core type: Literal
#     sub-expressions:
# 75. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 82, 85
# 76. Exp
#     core type: Literal
#     sub-expressions:
# 77. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 78. KET
#     core type: Literal
#     sub-expressions:
# 79. (1)
#     core type: ExprTuple
#     sub-expressions: 82
# 80. e
#     core type: Literal
#     sub-expressions:
# 81. 2 * pi * i * varphi
#     core type: Operation
#     operator: 83
#     operands: 84
# 82. 1
#     core type: Literal
#     sub-expressions:
# 83. *
#     core type: Literal
#     sub-expressions:
# 84. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 85, 86, 87, 88
# 85. 2
#     core type: Literal
#     sub-expressions:
# 86. pi
#     core type: Literal
#     sub-expressions:
# 87. i
#     core type: Literal
#     sub-expressions:
# 88. varphi
#     core type: Variable
#     sub-expressions:
