# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b
from proveit.logic import And, Bijections, InSet, Set, SetOfAll
from proveit.numbers import one, zero
from proveit.physics.quantum import QubitSpace, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import qubit_meas

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(zero, one)
expr = Conditional(InSet(Lambda(b, qubit_meas), Bijections(sub_expr1, SetOfAll(instance_param_or_params = [b], instance_element = qubit_meas, domain = sub_expr1))).with_wrapping_at(2), And(InSet(var_ket_psi, QubitSpace), normalized_var_ket_psi))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left[b \mapsto \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right)\right] \in  \\ \left[\left\{0, 1\right\} \xrightarrow[\text{onto}]{\text{1-to-1}} \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right\}_{b \in \left\{0, 1\right\}}\right] \end{array} \end{array} \textrm{ if } \lvert \psi \rangle \in \mathbb{C}^{2} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {[b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))] in  \\ Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}) if |psi> in Complex^{2} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))] in  \\ Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#    core type: Operation
#    operator: 32
#    operands: 3
# 2. (|psi> in Complex^{2}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))), Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|psi> in Complex^{2}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#    core type: Lambda
#    parameter: 56
#    body: 28
# 7. Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. |psi> in Complex^{2}
#    core type: Operation
#    operator: 32
#    operands: 12
# 9. |||psi>|| = 1
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Bijections
#     core type: Literal
#     sub-expressions:
# 11. ({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#     core type: ExprTuple
#     sub-expressions: 37, 15
# 12. (|psi>, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 51, 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 50
# 15. {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}
#     core type: Operation
#     operator: 18
#     operand: 24
# 16. Complex^{2}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. |||psi>||
#     core type: Operation
#     operator: 22
#     operand: 51
# 18. SetOfAll
#     core type: Literal
#     sub-expressions:
# 19. (b -> {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. CartExp
#     core type: Literal
#     sub-expressions:
# 21. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. Abs
#     core type: Literal
#     sub-expressions:
# 23. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 51
# 24. b -> {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.
#     core type: Lambda
#     parameter: 56
#     body: 27
# 25. Complex
#     core type: Literal
#     sub-expressions:
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 28. QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. b in {0, 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 31. VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (b, {0, 1})
#     core type: ExprTuple
#     sub-expressions: 56, 37
# 34. ([INPUT]{state:|psi>})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. ([MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. ([OUTPUT]{state:|b〉})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. {0, 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. [INPUT]{state:|psi>}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. [OUTPUT]{state:|b〉}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. Set
#     core type: Literal
#     sub-expressions:
# 42. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 43. INPUT
#     core type: Literal
#     sub-expressions:
# 44. {state:|psi>}
#     core type: NamedExprs
#     state: 51
# 45. MEASURE
#     core type: Literal
#     sub-expressions:
# 46. {basis:Z}
#     core type: NamedExprs
#     basis: 52
# 47. OUTPUT
#     core type: Literal
#     sub-expressions:
# 48. {state:|b〉}
#     core type: NamedExprs
#     state: 53
# 49. 0
#     core type: Literal
#     sub-expressions:
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. |psi>
#     core type: Variable
#     sub-expressions:
# 52. Z
#     core type: Literal
#     sub-expressions:
# 53. |b〉
#     core type: Operation
#     operator: 54
#     operand: 56
# 54. KET
#     core type: Literal
#     sub-expressions:
# 55. (b)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. b
#     core type: Variable
#     sub-expressions:
