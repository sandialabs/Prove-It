# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b
from proveit.logic import And, Equals, InSet, Set
from proveit.numbers import Abs, Exp, one, two, zero
from proveit.physics.quantum import Bra, Qmult, QubitSpace, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import qubit_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Lambda([var_ket_psi, b], Conditional(Equals(Prob(qubit_meas), Exp(Abs(Qmult(Bra(b), var_ket_psi)), two)), And(InSet(var_ket_psi, QubitSpace), InSet(b, Set(zero, one)), normalized_var_ket_psi)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\lvert \psi \rangle, b\right) \mapsto \left\{\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right) = \left|\langle b \rvert \thinspace \lvert \psi \rangle\right|^{2} \textrm{ if } \lvert \psi \rangle \in \mathbb{C}^{2} ,  b \in \left\{0, 1\right\} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|psi>, b) -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))) = |〈b| . |psi>|^{2} if |psi> in Complex^{2} ,  b in {0, 1} ,  |||psi>|| = 1.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (|psi>, b)
#    core type: ExprTuple
#    sub-expressions: 57, 63
# 2. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))) = |〈b| . |psi>|^{2} if |psi> in Complex^{2} ,  b in {0, 1} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))) = |〈b| . |psi>|^{2}
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. (|psi> in Complex^{2}) and (b in {0, 1}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))), |〈b| . |psi>|^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (|psi> in Complex^{2}, b in {0, 1}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))))
#    core type: Operation
#    operator: 13
#    operand: 22
# 9. |〈b| . |psi>|^{2}
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. |psi> in Complex^{2}
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. b in {0, 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. |||psi>|| = 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. Pr
#     core type: Literal
#     sub-expressions:
# 14. (QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))))
#     core type: ExprTuple
#     sub-expressions: 22
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (|〈b| . |psi>|, 2)
#     core type: ExprTuple
#     sub-expressions: 23, 42
# 17. (|psi>, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 57, 24
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (b, {0, 1})
#     core type: ExprTuple
#     sub-expressions: 63, 25
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 44
# 22. QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. |〈b| . |psi>|
#     core type: Operation
#     operator: 29
#     operand: 40
# 24. Complex^{2}
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. {0, 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 26. |||psi>||
#     core type: Operation
#     operator: 35
#     operand: 57
# 27. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 28. VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 29. Abs
#     core type: Literal
#     sub-expressions:
# 30. (〈b| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 40
# 31. CartExp
#     core type: Literal
#     sub-expressions:
# 32. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 33. Set
#     core type: Literal
#     sub-expressions:
# 34. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 35. Abs
#     core type: Literal
#     sub-expressions:
# 36. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 57
# 37. ([INPUT]{state:|psi>})
#     core type: ExprTuple
#     sub-expressions: 45
# 38. ([MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 46
# 39. ([OUTPUT]{state:|b〉})
#     core type: ExprTuple
#     sub-expressions: 47
# 40. 〈b| . |psi>
#     core type: Operation
#     operator: 48
#     operands: 49
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. 2
#     core type: Literal
#     sub-expressions:
# 43. 0
#     core type: Literal
#     sub-expressions:
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. [INPUT]{state:|psi>}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. [OUTPUT]{state:|b〉}
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. .
#     core type: Literal
#     sub-expressions:
# 49. (〈b|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 50. INPUT
#     core type: Literal
#     sub-expressions:
# 51. {state:|psi>}
#     core type: NamedExprs
#     state: 57
# 52. MEASURE
#     core type: Literal
#     sub-expressions:
# 53. {basis:Z}
#     core type: NamedExprs
#     basis: 58
# 54. OUTPUT
#     core type: Literal
#     sub-expressions:
# 55. {state:|b〉}
#     core type: NamedExprs
#     state: 59
# 56. 〈b|
#     core type: Operation
#     operator: 60
#     operand: 63
# 57. |psi>
#     core type: Variable
#     sub-expressions:
# 58. Z
#     core type: Literal
#     sub-expressions:
# 59. |b〉
#     core type: Operation
#     operator: 61
#     operand: 63
# 60. BRA
#     core type: Literal
#     sub-expressions:
# 61. KET
#     core type: Literal
#     sub-expressions:
# 62. (b)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. b
#     core type: Variable
#     sub-expressions:
