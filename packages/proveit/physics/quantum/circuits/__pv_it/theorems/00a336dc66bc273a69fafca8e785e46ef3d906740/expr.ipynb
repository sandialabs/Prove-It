# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, U, Variable, t
from proveit.linear_algebra import MatrixMult, ScalarMult
from proveit.logic import Equals, Forall
from proveit.numbers import Exp, Mult, e, i, one, pi, two
from proveit.physics.quantum import m_ket_domain, normalized_var_ket_u, var_ket_u, varphi
from proveit.physics.quantum.circuits import phase_kickback_on_register_circuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(varphi, sub_expr1)
expr = Forall(instance_param_or_params = [var_ket_u], instance_expr = Forall(instance_param_or_params = [ExprRange(sub_expr1, sub_expr2, one, t)], instance_expr = Equals(Prob(phase_kickback_on_register_circuit), one), condition = ExprRange(sub_expr1, Equals(MatrixMult(IndexedVar(U, sub_expr1), var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, sub_expr2)), var_ket_u)), one, t)).with_wrapping(), domain = m_ket_domain, condition = normalized_var_ket_u).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\lvert u \rangle \in \mathbb{C}^{2^{m}}~|~\left \|\lvert u \rangle\right \| = 1}~\\
# \left[\begin{array}{l}\forall_{\varphi_{1}, \varphi_{2}, \ldots, \varphi_{t}~|~\left(\left(U_{1} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{1}} \cdot \lvert u \rangle\right)\right), \left(\left(U_{2} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{2}} \cdot \lvert u \rangle\right)\right), \ldots, \left(\left(U_{t} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{t}} \cdot \lvert u \rangle\right)\right)}~\\
# \left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qw & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{1}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \control{} \qw \qwx[1] & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{2}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} & \qout{\vdots} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \qw \qwx[1] & \gate{\cdots} \qwx[1] & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{t}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U_{1}} & \gate{U_{2}} & \gate{\cdots} & \gate{U_{t}} & \qout{\lvert u \rangle}
# } \end{array}\right) = 1\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi_{1}, varphi_{2}, ..., varphi_{t} | ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (|u> -> {forall_{varphi_{1}, varphi_{2}, ..., varphi_{t} | ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. |u> -> {forall_{varphi_{1}, varphi_{2}, ..., varphi_{t} | ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.
#    core type: Lambda
#    parameter: 95
#    body: 3
# 3. {forall_{varphi_{1}, varphi_{2}, ..., varphi_{t} | ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{varphi_{1}, varphi_{2}, ..., varphi_{t} | ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (|u> in Complex^{2^{m}}) and (|||u>|| = 1)
#    core type: Operation
#    operator: 24
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((varphi_{1}, varphi_{2}, ..., varphi_{t}) -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (|u> in Complex^{2^{m}}, |||u>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (varphi_{1}, varphi_{2}, ..., varphi_{t}) -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 10. |u> in Complex^{2^{m}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. |||u>|| = 1
#     core type: Operation
#     operator: 108
#     operands: 16
# 12. (varphi_{1}, varphi_{2}, ..., varphi_{t})
#     core type: ExprTuple
#     sub-expressions: 17
# 13. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).
#     core type: Conditional
#     value: 18
#     condition: 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (|u>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 95, 20
# 16. (|||u>||, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 148
# 17. varphi_{1}, varphi_{2}, ..., varphi_{t}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 148
#     end_index: 147
# 18. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1
#     core type: Operation
#     operator: 108
#     operands: 23
# 19. ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. Complex^{2^{m}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. |||u>||
#     core type: Operation
#     operator: 28
#     operand: 95
# 22. _a -> varphi_{_a}
#     core type: Lambda
#     parameter: 157
#     body: 154
# 23. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))), 1)
#     core type: ExprTuple
#     sub-expressions: 30, 148
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)))
#     core type: ExprTuple
#     sub-expressions: 31
# 26. CartExp
#     core type: Literal
#     sub-expressions:
# 27. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. Abs
#     core type: Literal
#     sub-expressions:
# 29. (|u>)
#     core type: ExprTuple
#     sub-expressions: 95
# 30. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))))
#     core type: Operation
#     operator: 34
#     operand: 38
# 31. ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 148
#     end_index: 147
# 32. Complex
#     core type: Literal
#     sub-expressions:
# 33. 2^{m}
#     core type: Operation
#     operator: 139
#     operands: 37
# 34. Pr
#     core type: Literal
#     sub-expressions:
# 35. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))))
#     core type: ExprTuple
#     sub-expressions: 38
# 36. _a -> ((U_{_a} . |u>) = (e^{2 * pi * i * varphi_{_a}} * |u>))
#     core type: Lambda
#     parameter: 157
#     body: 39
# 37. (2, m)
#     core type: ExprTuple
#     sub-expressions: 151, 131
# 38. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. (U_{_a} . |u>) = (e^{2 * pi * i * varphi_{_a}} * |u>)
#     core type: Operation
#     operator: 108
#     operands: 42
# 40. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 41. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 42. (U_{_a} . |u>, e^{2 * pi * i * varphi_{_a}} * |u>)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 148
#     end_index: 147
# 45. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 46. U_{_a} . |u>
#     core type: Operation
#     operator: 53
#     operands: 54
# 47. e^{2 * pi * i * varphi_{_a}} * |u>
#     core type: Operation
#     operator: 126
#     operands: 55
# 48. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 148
#     end_index: 147
# 49. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 148
#     end_index: 131
# 50. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#     core type: Lambda
#     parameter: 130
#     body: 58
# 51. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 148
#     end_index: 147
# 52. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 148
#     end_index: 131
# 53. .
#     core type: Literal
#     sub-expressions:
# 54. (U_{_a}, |u>)
#     core type: ExprTuple
#     sub-expressions: 61, 95
# 55. (e^{2 * pi * i * varphi_{_a}}, |u>)
#     core type: ExprTuple
#     sub-expressions: 134, 95
# 56. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 157
#     body: 62
# 57. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 157
#     body: 63
# 58. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 59. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: Lambda
#     parameter: 157
#     body: 66
# 60. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 157
#     body: 67
# 61. U_{_a}
#     core type: IndexedVar
# variable: 121
# index: 157
# 62. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 81
#     operands: 68
# 63. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 106
#     operands: 69
# 64. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 148
#     end_index: 147
# 65. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 148
#     end_index: 131
# 66. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: Operation
#     operator: 86
#     operands: 72
# 67. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 106
#     operands: 73
# 68. {state:|+〉}
#     core type: NamedExprs
#     state: 74
# 69. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 75
#     targets: 92
# 70. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#     core type: Lambda
#     parameter: 157
#     body: 76
# 71. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 157
#     body: 77
# 72. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: NamedExprs
#     state: 78
# 73. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 79
#     targets: 92
# 74. |+〉
#     core type: Operation
#     operator: 141
#     operand: 88
# 75. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 81
#     operands: 87
# 76. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#     core type: Operation
#     operator: 82
#     operands: 83
# 77. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 106
#     operands: 84
# 78. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: Operation
#     operator: 126
#     operands: 85
# 79. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 86
#     operands: 87
# 80. (+)
#     core type: ExprTuple
#     sub-expressions: 88
# 81. INPUT
#     core type: Literal
#     sub-expressions:
# 82. CondSet
#     core type: Literal
#     sub-expressions:
# 83. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a, [GATE]{operation:I} if _b != _a)
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 84. {element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 91
#     targets: 92
# 85. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 86. OUTPUT
#     core type: Literal
#     sub-expressions:
# 87. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 95
#     part: 157
# 88. +
#     core type: Literal
#     sub-expressions:
# 89. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a.
#     core type: Conditional
#     value: 96
#     condition: 97
# 90. {[GATE]{operation:I} if _b != _a.
#     core type: Conditional
#     value: 98
#     condition: 99
# 91. [GATE]{operation:U_{_b}, part:_a}
#     core type: Operation
#     operator: 109
#     operands: 100
# 92. {t + 1 .. t + m}
#     core type: Operation
#     operator: 101
#     operands: 102
# 93. 1 / sqrt(2)
#     core type: Operation
#     operator: 137
#     operands: 103
# 94. |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)
#     core type: Operation
#     operator: 104
#     operands: 105
# 95. |u>
#     core type: Variable
#     sub-expressions:
# 96. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 106
#     operands: 107
# 97. _b = _a
#     core type: Operation
#     operator: 108
#     operands: 112
# 98. [GATE]{operation:I}
#     core type: Operation
#     operator: 109
#     operands: 110
# 99. _b != _a
#     core type: Operation
#     operator: 111
#     operands: 112
# 100. {operation:U_{_b}, part:_a}
#      core type: NamedExprs
#      operation: 113
#      part: 157
# 101. Interval
#      core type: Literal
#      sub-expressions:
# 102. (t + 1, t + m)
#      core type: ExprTuple
#      sub-expressions: 136, 114
# 103. (1, sqrt(2))
#      core type: ExprTuple
#      sub-expressions: 148, 115
# 104. +
#      core type: Literal
#      sub-expressions:
# 105. (|0〉, e^{2 * pi * i * varphi_{_a}} * |1〉)
#      core type: ExprTuple
#      sub-expressions: 116, 117
# 106. MULTI_QUBIT_ELEM
#      core type: Literal
#      sub-expressions:
# 107. {element:CONTROL, targets:{t + 1}}
#      core type: NamedExprs
#      element: 118
#      targets: 119
# 108. =
#      core type: Literal
#      sub-expressions:
# 109. GATE
#      core type: Literal
#      sub-expressions:
# 110. {operation:I}
#      core type: NamedExprs
#      operation: 120
# 111. !=
#      core type: Literal
#      sub-expressions:
# 112. (_b, _a)
#      core type: ExprTuple
#      sub-expressions: 130, 157
# 113. U_{_b}
#      core type: IndexedVar
# variable: 121
# index: 130
# 114. t + m
#      core type: Operation
#      operator: 143
#      operands: 123
# 115. sqrt(2)
#      core type: Operation
#      operator: 139
#      operands: 124
# 116. |0〉
#      core type: Operation
#      operator: 141
#      operand: 133
# 117. e^{2 * pi * i * varphi_{_a}} * |1〉
#      core type: Operation
#      operator: 126
#      operands: 127
# 118. CONTROL
#      core type: Literal
#      sub-expressions:
# 119. {t + 1}
#      core type: Operation
#      operator: 128
#      operand: 136
# 120. I
#      core type: Literal
#      sub-expressions:
# 121. U
#      core type: Variable
#      sub-expressions:
# 122. (_b)
#      core type: ExprTuple
#      sub-expressions: 130
# 123. (t, m)
#      core type: ExprTuple
#      sub-expressions: 147, 131
# 124. (2, 1 / 2)
#      core type: ExprTuple
#      sub-expressions: 151, 132
# 125. (0)
#      core type: ExprTuple
#      sub-expressions: 133
# 126. *
#      core type: Literal
#      sub-expressions:
# 127. (e^{2 * pi * i * varphi_{_a}}, |1〉)
#      core type: ExprTuple
#      sub-expressions: 134, 135
# 128. Set
#      core type: Literal
#      sub-expressions:
# 129. (t + 1)
#      core type: ExprTuple
#      sub-expressions: 136
# 130. _b
#      core type: Variable
#      sub-expressions:
# 131. m
#      core type: Variable
#      sub-expressions:
# 132. 1 / 2
#      core type: Operation
#      operator: 137
#      operands: 138
# 133. 0
#      core type: Literal
#      sub-expressions:
# 134. e^{2 * pi * i * varphi_{_a}}
#      core type: Operation
#      operator: 139
#      operands: 140
# 135. |1〉
#      core type: Operation
#      operator: 141
#      operand: 148
# 136. t + 1
#      core type: Operation
#      operator: 143
#      operands: 144
# 137. /
#      core type: Literal
#      sub-expressions:
# 138. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 148, 151
# 139. Exp
#      core type: Literal
#      sub-expressions:
# 140. (e, 2 * pi * i * varphi_{_a})
#      core type: ExprTuple
#      sub-expressions: 145, 146
# 141. KET
#      core type: Literal
#      sub-expressions:
# 142. (1)
#      core type: ExprTuple
#      sub-expressions: 148
# 143. +
#      core type: Literal
#      sub-expressions:
# 144. (t, 1)
#      core type: ExprTuple
#      sub-expressions: 147, 148
# 145. e
#      core type: Literal
#      sub-expressions:
# 146. 2 * pi * i * varphi_{_a}
#      core type: Operation
#      operator: 149
#      operands: 150
# 147. t
#      core type: Variable
#      sub-expressions:
# 148. 1
#      core type: Literal
#      sub-expressions:
# 149. *
#      core type: Literal
#      sub-expressions:
# 150. (2, pi, i, varphi_{_a})
#      core type: ExprTuple
#      sub-expressions: 151, 152, 153, 154
# 151. 2
#      core type: Literal
#      sub-expressions:
# 152. pi
#      core type: Literal
#      sub-expressions:
# 153. i
#      core type: Literal
#      sub-expressions:
# 154. varphi_{_a}
#      core type: IndexedVar
# variable: 155
# index: 157
# 155. varphi
#      core type: Variable
#      sub-expressions:
# 156. (_a)
#      core type: ExprTuple
#      sub-expressions: 157
# 157. _a
#      core type: Variable
#      sub-expressions:
