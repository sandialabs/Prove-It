# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.core_expr_types import U_1_to_i, V_1_to_j
from proveit.logic import Equals, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuits import circuit_Ui_Vj, circuit_Ui_psi_m, circuit_psi_m_Vj
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Lambda([U_1_to_i, V_1_to_j], Implies(Equals(Prob(circuit_Ui_psi_m), one), Equals(Prob(circuit_Ui_Vj), Prob(circuit_psi_m_Vj)).with_wrapping_at(2)).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}\right) \mapsto \left(\begin{array}{c} \begin{array}{l} \left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \qout{\lvert \psi \rangle}
# } \end{array}\right) = 1\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) =  \\ \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & { /^{m} } \qw
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}) -> ((Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#    core type: ExprTuple
#    sub-expressions: 25, 27
# 2. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1, Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))), 1)
#    core type: ExprTuple
#    sub-expressions: 10, 56
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))), Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 15
#     operand: 17
# 11. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: Operation
#     operator: 15
#     operand: 18
# 12. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 18
# 15. Pr
#     core type: Literal
#     sub-expressions:
# 16. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 19
# 17. QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 22
#     operands: 20
# 18. QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))
#     core type: Operation
#     operator: 22
#     operands: 21
# 19. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 21. VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 22. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 23. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 56
#     end_index: 30
# 26. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 31
# 27. V_{1}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 56
#     end_index: 33
# 28. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 56
#     end_index: 57
# 29. _a -> U_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 35
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 56
#     end_index: 57
# 32. _a -> V_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 37
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 55
#     body: 38
# 35. U_{_a}
#     core type: IndexedVar
# variable: 39
# index: 55
# 36. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 55
#     body: 40
# 37. V_{_a}
#     core type: IndexedVar
# variable: 41
# index: 55
# 38. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 44
#     operands: 43
# 39. U
#     core type: Variable
#     sub-expressions:
# 40. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. V
#     core type: Variable
#     sub-expressions:
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 43. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 46
#     targets: 48
# 44. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 45. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 47
#     targets: 48
# 46. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 49
#     operands: 51
# 47. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. {1 .. m}
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. OUTPUT
#     core type: Literal
#     sub-expressions:
# 50. INPUT
#     core type: Literal
#     sub-expressions:
# 51. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 54
#     part: 55
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (1, m)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. |psi>
#     core type: Variable
#     sub-expressions:
# 55. _a
#     core type: Variable
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. m
#     core type: Variable
#     sub-expressions:
