# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n
from proveit.logic import Equals
from proveit.numbers import Abs, Exp, two
from proveit.physics.quantum import NumBra, Qmult, var_ket_psi
from proveit.physics.quantum.circuits import register_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Equals(Prob(register_meas), Exp(Abs(Qmult(NumBra(n, m), var_ket_psi)), two))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array}\right) = \left|{_{m}}\langle n \rvert \thinspace \lvert \psi \rangle\right|^{2}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))), |{m}_〈n| . |psi>|^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. |{m}_〈n| . |psi>|^{2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. Pr
#    core type: Literal
#    sub-expressions:
# 6. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (|{m}_〈n| . |psi>|, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. |{m}_〈n| . |psi>|
#     core type: Operation
#     operator: 14
#     operand: 19
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 13. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 14. Abs
#     core type: Literal
#     sub-expressions:
# 15. ({m}_〈n| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 20
# 17. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. {m}_〈n| . |psi>
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 52
#     end_index: 56
# 21. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 52
#     end_index: 56
# 22. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 52
#     end_index: 56
# 23. .
#     core type: Literal
#     sub-expressions:
# 24. ({m}_〈n|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 28, 49
# 25. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 51
#     body: 29
# 26. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 51
#     body: 30
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 51
#     body: 32
# 28. {m}_〈n|
#     core type: Operation
#     operator: 33
#     operands: 54
# 29. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 37
#     operands: 34
# 30. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 51
# 32. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 34. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 39
#     targets: 42
# 35. MEASURE
#     core type: Literal
#     sub-expressions:
# 36. {basis:Z}
#     core type: NamedExprs
#     basis: 40
# 37. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 38. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 39. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. Z
#     core type: Literal
#     sub-expressions:
# 41. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. {1 .. m}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. INPUT
#     core type: Literal
#     sub-expressions:
# 44. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 49
#     part: 51
# 45. OUTPUT
#     core type: Literal
#     sub-expressions:
# 46. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 50
#     part: 51
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (1, m)
#     core type: ExprTuple
#     sub-expressions: 52, 56
# 49. |psi>
#     core type: Variable
#     sub-expressions:
# 50. |n〉_{m}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. _a
#     core type: Variable
#     sub-expressions:
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. NUM_KET
#     core type: Literal
#     sub-expressions:
# 54. (n, m)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. m
#     core type: Variable
#     sub-expressions:
