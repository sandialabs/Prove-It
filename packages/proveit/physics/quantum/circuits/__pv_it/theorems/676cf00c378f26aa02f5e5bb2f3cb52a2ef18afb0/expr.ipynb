# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.physics.quantum.circuits import phase_kickback_circuit

# %%
# build up the expression from sub-expressions
expr = ExprTuple(phase_kickback_circuit)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U} & \qout{\lvert u \rangle}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 3. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 6. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 44
#    operands: 13
# 8. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 80
#    end_index: 19
# 9. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#    core type: Operation
#    operator: 35
#    operands: 15
# 10. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 80
#     end_index: 19
# 11. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: Operation
#     operator: 50
#     operands: 17
# 12. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 80
#     end_index: 19
# 13. {state:|+〉}
#     core type: NamedExprs
#     state: 20
# 14. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 59
#     body: 21
# 15. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 22
#     targets: 23
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 59
#     body: 24
# 17. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 25
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 59
#     body: 27
# 19. m + 1
#     core type: Operation
#     operator: 65
#     operands: 28
# 20. |+〉
#     core type: Operation
#     operator: 76
#     operand: 37
# 21. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 35
#     operands: 30
# 22. CONTROL
#     core type: Literal
#     sub-expressions:
# 23. {2}
#     core type: Operation
#     operator: 31
#     operand: 83
# 24. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 35
#     operands: 33
# 25. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 63
#     operands: 34
# 26. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 27. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 28. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 71, 80
# 29. (+)
#     core type: ExprTuple
#     sub-expressions: 37
# 30. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 38
#     targets: 43
# 31. Set
#     core type: Literal
#     sub-expressions:
# 32. (2)
#     core type: ExprTuple
#     sub-expressions: 83
# 33. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 39
#     targets: 43
# 34. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 35. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 36. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 42
#     targets: 43
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 44
#     operands: 51
# 39. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. 1 / sqrt(2)
#     core type: Operation
#     operator: 72
#     operands: 47
# 41. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 43. {2 .. m + 2}
#     core type: Operation
#     operator: 52
#     operands: 53
# 44. INPUT
#     core type: Literal
#     sub-expressions:
# 45. GATE
#     core type: Literal
#     sub-expressions:
# 46. {operation:U, part:_a}
#     core type: NamedExprs
#     operation: 54
#     part: 59
# 47. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 80, 55
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 50. OUTPUT
#     core type: Literal
#     sub-expressions:
# 51. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 58
#     part: 59
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 83, 60
# 54. U
#     core type: Variable
#     sub-expressions:
# 55. sqrt(2)
#     core type: Operation
#     operator: 74
#     operands: 61
# 56. |0〉
#     core type: Operation
#     operator: 76
#     operand: 68
# 57. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 63
#     operands: 64
# 58. |u>
#     core type: Variable
#     sub-expressions:
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. m + 2
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 83, 67
# 62. (0)
#     core type: ExprTuple
#     sub-expressions: 68
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 71, 83
# 67. 1 / 2
#     core type: Operation
#     operator: 72
#     operands: 73
# 68. 0
#     core type: Literal
#     sub-expressions:
# 69. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. |1〉
#     core type: Operation
#     operator: 76
#     operand: 80
# 71. m
#     core type: Variable
#     sub-expressions:
# 72. /
#     core type: Literal
#     sub-expressions:
# 73. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 80, 83
# 74. Exp
#     core type: Literal
#     sub-expressions:
# 75. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 76. KET
#     core type: Literal
#     sub-expressions:
# 77. (1)
#     core type: ExprTuple
#     sub-expressions: 80
# 78. e
#     core type: Literal
#     sub-expressions:
# 79. 2 * pi * i * varphi
#     core type: Operation
#     operator: 81
#     operands: 82
# 80. 1
#     core type: Literal
#     sub-expressions:
# 81. *
#     core type: Literal
#     sub-expressions:
# 82. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 83, 84, 85, 86
# 83. 2
#     core type: Literal
#     sub-expressions:
# 84. pi
#     core type: Literal
#     sub-expressions:
# 85. i
#     core type: Literal
#     sub-expressions:
# 86. varphi
#     core type: Variable
#     sub-expressions:
