# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import U_1_to_i, V_1_to_j
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuits import circuit_Ui_Vj, circuit_Ui_psi_m, circuit_psi_m_Vj
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [U_1_to_i, V_1_to_j], instance_expr = Implies(Equals(Prob(circuit_Ui_psi_m), one), Equals(Prob(circuit_Ui_Vj), Prob(circuit_psi_m_Vj)).with_wrapping_at(2)).with_wrapping_at(2)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{U_{1}, U_{2}, \ldots, U_{i}, V_{1}, V_{2}, \ldots, V_{j}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \qout{\lvert \psi \rangle}
# } \end{array}\right) = 1\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) =  \\ \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & { /^{m} } \qw
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}} ((Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}) -> ((Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (U_{1}, U_{2}, ..., U_{i}, V_{1}, V_{2}, ..., V_{j}) -> ((Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))))
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (U_{1}, U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#    core type: ExprTuple
#    sub-expressions: 28, 30
# 5. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1, Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))) = 1
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))), 1)
#     core type: ExprTuple
#     sub-expressions: 13, 59
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))), Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 18
#     operand: 20
# 14. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: Operation
#     operator: 18
#     operand: 21
# 15. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. (QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 20
# 17. (QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 21
# 18. Pr
#     core type: Literal
#     sub-expressions:
# 19. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 22
# 20. QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 25
#     operands: 23
# 21. QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 24. VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 26. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. U_{1}, U_{2}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 59
#     end_index: 33
# 29. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 34
# 30. V_{1}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 59
#     end_index: 36
# 31. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 59
#     end_index: 60
# 32. _a -> U_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 38
# 33. i
#     core type: Variable
#     sub-expressions:
# 34. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 59
#     end_index: 60
# 35. _a -> V_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 40
# 36. j
#     core type: Variable
#     sub-expressions:
# 37. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 58
#     body: 41
# 38. U_{_a}
#     core type: IndexedVar
# variable: 42
# index: 58
# 39. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 58
#     body: 43
# 40. V_{_a}
#     core type: IndexedVar
# variable: 44
# index: 58
# 41. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 47
#     operands: 46
# 42. U
#     core type: Variable
#     sub-expressions:
# 43. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. V
#     core type: Variable
#     sub-expressions:
# 45. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 46. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 49
#     targets: 51
# 47. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 48. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 50
#     targets: 51
# 49. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 52
#     operands: 54
# 50. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. {1 .. m}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. OUTPUT
#     core type: Literal
#     sub-expressions:
# 53. INPUT
#     core type: Literal
#     sub-expressions:
# 54. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 57
#     part: 58
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (1, m)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. |psi>
#     core type: Variable
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. m
#     core type: Variable
#     sub-expressions:
