# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Abs, Exp, two
from proveit.physics.quantum import NumBra, Qmult, m_bit_interval, m_ket_domain, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import register_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [var_ket_psi], instance_expr = Equals(Prob(register_meas), Exp(Abs(Qmult(NumBra(n, m), var_ket_psi)), two)), domain = m_ket_domain, condition = normalized_var_ket_psi), InSet(n, m_bit_interval))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{\lvert \psi \rangle \in \mathbb{C}^{2^{m}}~|~\left \|\lvert \psi \rangle\right \| = 1}~\left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array}\right) = \left|{_{m}}\langle n \rvert \thinspace \lvert \psi \rangle\right|^{2}\right) \textrm{ if } n \in \{0~\ldotp \ldotp~2^{m} - 1\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.
#    core type: Lambda
#    parameter: 92
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 92
# 3. {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in {0 .. 2^{m} - 1}
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (|psi> -> {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, {0 .. 2^{m} - 1})
#    core type: ExprTuple
#    sub-expressions: 92, 10
# 9. |psi> -> {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#    core type: Lambda
#    parameter: 86
#    body: 11
# 10. {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 84
#     operands: 12
# 11. {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. (0, 2^{m} - 1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}
#     core type: Operation
#     operator: 32
#     operands: 17
# 14. (|psi> in Complex^{2^{m}}) and (|||psi>|| = 1)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. 2^{m} - 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))), |{m}_〈n| . |psi>|^{2})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (|psi> in Complex^{2^{m}}, |||psi>|| = 1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (2^{m}, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 26
# 22. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 27
#     operand: 36
# 23. |{m}_〈n| . |psi>|^{2}
#     core type: Operation
#     operator: 59
#     operands: 29
# 24. |psi> in Complex^{2^{m}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. |||psi>|| = 1
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. -1
#     core type: Operation
#     operator: 34
#     operand: 89
# 27. Pr
#     core type: Literal
#     sub-expressions:
# 28. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 36
# 29. (|{m}_〈n| . |psi>|, 2)
#     core type: ExprTuple
#     sub-expressions: 37, 65
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (|psi>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 86, 38
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 39, 89
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (1)
#     core type: ExprTuple
#     sub-expressions: 89
# 36. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. |{m}_〈n| . |psi>|
#     core type: Operation
#     operator: 42
#     operand: 51
# 38. Complex^{2^{m}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. |||psi>||
#     core type: Operation
#     operator: 46
#     operand: 86
# 40. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 41. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 42. Abs
#     core type: Literal
#     sub-expressions:
# 43. ({m}_〈n| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 51
# 44. CartExp
#     core type: Literal
#     sub-expressions:
# 45. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 46. Abs
#     core type: Literal
#     sub-expressions:
# 47. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 86
# 48. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 55
# 50. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 56
# 51. {m}_〈n| . |psi>
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. 2^{m}
#     core type: Operation
#     operator: 59
#     operands: 60
# 54. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 89
#     end_index: 93
# 55. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 89
#     end_index: 93
# 56. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 89
#     end_index: 93
# 57. .
#     core type: Literal
#     sub-expressions:
# 58. ({m}_〈n|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 64, 86
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, m)
#     core type: ExprTuple
#     sub-expressions: 65, 93
# 61. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 88
#     body: 66
# 62. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 88
#     body: 67
# 63. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 88
#     body: 69
# 64. {m}_〈n|
#     core type: Operation
#     operator: 70
#     operands: 91
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 74
#     operands: 71
# 67. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 72
#     operands: 73
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 88
# 69. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 71. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 76
#     targets: 79
# 72. MEASURE
#     core type: Literal
#     sub-expressions:
# 73. {basis:Z}
#     core type: NamedExprs
#     basis: 77
# 74. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 75. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 78
#     targets: 79
# 76. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 80
#     operands: 81
# 77. Z
#     core type: Literal
#     sub-expressions:
# 78. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 82
#     operands: 83
# 79. {1 .. m}
#     core type: Operation
#     operator: 84
#     operands: 85
# 80. INPUT
#     core type: Literal
#     sub-expressions:
# 81. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 86
#     part: 88
# 82. OUTPUT
#     core type: Literal
#     sub-expressions:
# 83. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 87
#     part: 88
# 84. Interval
#     core type: Literal
#     sub-expressions:
# 85. (1, m)
#     core type: ExprTuple
#     sub-expressions: 89, 93
# 86. |psi>
#     core type: Variable
#     sub-expressions:
# 87. |n〉_{m}
#     core type: Operation
#     operator: 90
#     operands: 91
# 88. _a
#     core type: Variable
#     sub-expressions:
# 89. 1
#     core type: Literal
#     sub-expressions:
# 90. NUM_KET
#     core type: Literal
#     sub-expressions:
# 91. (n, m)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 92. n
#     core type: Variable
#     sub-expressions:
# 93. m
#     core type: Variable
#     sub-expressions:
