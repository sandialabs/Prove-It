# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, U
from proveit.linear_algebra import ScalarMult
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, i, one, pi, two
from proveit.physics.quantum import Qmult, var_ket_u, varphi
from proveit.physics.quantum.circuits import phase_kickback_circuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Prob(phase_kickback_circuit), one), Equals(Qmult(U, var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, varphi)), var_ket_u)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U} & \qout{\lvert u \rangle}
# } \end{array}\right) = 1 \textrm{ if } \left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1 if (U . |u>) = (e^{2 * pi * i * varphi} * |u>).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (U . |u>) = (e^{2 * pi * i * varphi} * |u>)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))), 1)
#    core type: ExprTuple
#    sub-expressions: 6, 93
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (U . |u>, e^{2 * pi * i * varphi} * |u>)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. U . |u>
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. e^{2 * pi * i * varphi} * |u>
#    core type: Operation
#    operator: 76
#    operands: 13
# 9. Pr
#    core type: Literal
#    sub-expressions:
# 10. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#     core type: ExprTuple
#     sub-expressions: 14
# 11. .
#     core type: Literal
#     sub-expressions:
# 12. (U, |u>)
#     core type: ExprTuple
#     sub-expressions: 67, 71
# 13. (e^{2 * pi * i * varphi}, |u>)
#     core type: ExprTuple
#     sub-expressions: 82, 71
# 14. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 16. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 17. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 57
#     operands: 26
# 21. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 93
#     end_index: 32
# 22. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#     core type: Operation
#     operator: 48
#     operands: 28
# 23. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 93
#     end_index: 32
# 24. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: Operation
#     operator: 63
#     operands: 30
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 93
#     end_index: 32
# 26. {state:|+〉}
#     core type: NamedExprs
#     state: 33
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 72
#     body: 34
# 28. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 29. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 72
#     body: 37
# 30. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 38
# 31. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 72
#     body: 40
# 32. m + 1
#     core type: Operation
#     operator: 78
#     operands: 41
# 33. |+〉
#     core type: Operation
#     operator: 89
#     operand: 50
# 34. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 48
#     operands: 43
# 35. CONTROL
#     core type: Literal
#     sub-expressions:
# 36. {2}
#     core type: Operation
#     operator: 44
#     operand: 96
# 37. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 48
#     operands: 46
# 38. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 76
#     operands: 47
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 40. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 41. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 84, 93
# 42. (+)
#     core type: ExprTuple
#     sub-expressions: 50
# 43. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 51
#     targets: 56
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (2)
#     core type: ExprTuple
#     sub-expressions: 96
# 46. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 52
#     targets: 56
# 47. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 48. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 49. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 55
#     targets: 56
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 57
#     operands: 64
# 52. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. 1 / sqrt(2)
#     core type: Operation
#     operator: 85
#     operands: 60
# 54. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 61
#     operands: 62
# 55. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 56. {2 .. m + 2}
#     core type: Operation
#     operator: 65
#     operands: 66
# 57. INPUT
#     core type: Literal
#     sub-expressions:
# 58. GATE
#     core type: Literal
#     sub-expressions:
# 59. {operation:U, part:_a}
#     core type: NamedExprs
#     operation: 67
#     part: 72
# 60. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 93, 68
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 63. OUTPUT
#     core type: Literal
#     sub-expressions:
# 64. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 71
#     part: 72
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 96, 73
# 67. U
#     core type: Variable
#     sub-expressions:
# 68. sqrt(2)
#     core type: Operation
#     operator: 87
#     operands: 74
# 69. |0〉
#     core type: Operation
#     operator: 89
#     operand: 81
# 70. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 76
#     operands: 77
# 71. |u>
#     core type: Variable
#     sub-expressions:
# 72. _a
#     core type: Variable
#     sub-expressions:
# 73. m + 2
#     core type: Operation
#     operator: 78
#     operands: 79
# 74. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 96, 80
# 75. (0)
#     core type: ExprTuple
#     sub-expressions: 81
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 78. +
#     core type: Literal
#     sub-expressions:
# 79. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 84, 96
# 80. 1 / 2
#     core type: Operation
#     operator: 85
#     operands: 86
# 81. 0
#     core type: Literal
#     sub-expressions:
# 82. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 87
#     operands: 88
# 83. |1〉
#     core type: Operation
#     operator: 89
#     operand: 93
# 84. m
#     core type: Variable
#     sub-expressions:
# 85. /
#     core type: Literal
#     sub-expressions:
# 86. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 93, 96
# 87. Exp
#     core type: Literal
#     sub-expressions:
# 88. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 89. KET
#     core type: Literal
#     sub-expressions:
# 90. (1)
#     core type: ExprTuple
#     sub-expressions: 93
# 91. e
#     core type: Literal
#     sub-expressions:
# 92. 2 * pi * i * varphi
#     core type: Operation
#     operator: 94
#     operands: 95
# 93. 1
#     core type: Literal
#     sub-expressions:
# 94. *
#     core type: Literal
#     sub-expressions:
# 95. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 96, 97, 98, 99
# 96. 2
#     core type: Literal
#     sub-expressions:
# 97. pi
#     core type: Literal
#     sub-expressions:
# 98. i
#     core type: Literal
#     sub-expressions:
# 99. varphi
#     core type: Variable
#     sub-expressions:
