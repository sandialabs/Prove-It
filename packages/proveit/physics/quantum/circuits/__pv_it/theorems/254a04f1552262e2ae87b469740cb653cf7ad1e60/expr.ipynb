# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, j, k, l, m
from proveit.core_expr_types import A_1_to_j, B_1_to_k, C_1_to_l, D_1_to_m
from proveit.logic import And, Forall, Implies, InSet
from proveit.numbers import Natural
from proveit.physics.quantum.circuits import QcircuitEquiv, circuit_AjBkCl, circuit_AjDmCl, circuit_Bk, circuit_Dm

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([j, k, l, m], Conditional(Forall(instance_param_or_params = [A_1_to_j, B_1_to_k, C_1_to_l, D_1_to_m], instance_expr = Implies(QcircuitEquiv(circuit_Bk, circuit_Dm), QcircuitEquiv(circuit_AjBkCl, circuit_AjDmCl).with_wrapping_at(1)).with_wrapping_at(2)).with_wrapping(), And(InSet(j, Natural), InSet(k, Natural), InSet(l, Natural), InSet(m, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(j, k, l, m\right) \mapsto \left\{\begin{array}{l}\forall_{A_{1}, A_{2}, \ldots, A_{j}, B_{1}, B_{2}, \ldots, B_{k}, C_{1}, C_{2}, \ldots, C_{l}, D_{1}, D_{2}, \ldots, D_{m}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\B_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{k} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \cong \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\D_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{m} \\ \downarrow\end{array}} & \qw
# } \end{array}\right)\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\A_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{j} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{k} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{l} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \\  \cong \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\A_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{j} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{m} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{l} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\end{array} \textrm{ if } j \in \mathbb{N} ,  k \in \mathbb{N} ,  l \in \mathbb{N} ,  m \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((j, k, l, m) -> {forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))) if j in Natural ,  k in Natural ,  l in Natural ,  m in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (j, k, l, m) -> {forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))) if j in Natural ,  k in Natural ,  l in Natural ,  m in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (j, k, l, m)
#    core type: ExprTuple
#    sub-expressions: 46, 44, 51, 48
# 3. {forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))) if j in Natural ,  k in Natural ,  l in Natural ,  m in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (j in Natural) and (k in Natural) and (l in Natural) and (m in Natural)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}) -> ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (j in Natural, k in Natural, l in Natural, m in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 10. (A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}) -> ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))))
#     core type: Lambda
#     parameters: 15\n    body: 16
# 11. j in Natural
#     core type: Operation
#     operator: 20
#     operands: 17
# 12. k in Natural
#     core type: Operation
#     operator: 20
#     operands: 18
# 13. l in Natural
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. m in Natural
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (A_{1}, A_{2}, ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l},D_{1}, D_{2}, ..., D_{m})
#     core type: ExprTuple
#     sub-expressions: 40, 39, 42, 41
# 16. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 24
# 18. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 44, 24
# 19. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 51, 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 24
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m})), QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. Natural
#     core type: Literal
#     sub-expressions:
# 25. QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))
#     core type: Operation
#     operator: 28
#     operands: 27
# 26. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})), QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m})))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. equiv
#     core type: Literal
#     sub-expressions:
# 29. (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})), QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k}))
#     core type: Operation
#     operator: 37
#     operands: 34
# 31. QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))
#     core type: Operation
#     operator: 37
#     operands: 35
# 32. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. VertExprArray(B_{1}, B_{2}, ..., B_{k})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. VertExprArray(D_{1}, D_{2}, ..., D_{m})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})
#     core type: ExprTuple
#     sub-expressions: 40, 39, 42
# 37. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 38. VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 39. B_{1}, B_{2}, ..., B_{k}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 50
#     end_index: 44
# 40. A_{1}, A_{2}, ..., A_{j}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 46
# 41. D_{1}, D_{2}, ..., D_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 50
#     end_index: 48
# 42. C_{1}, C_{2}, ..., C_{l}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 43. _a -> B_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 52
# 44. k
#     core type: Variable
#     sub-expressions:
# 45. _a -> A_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 53
# 46. j
#     core type: Variable
#     sub-expressions:
# 47. _a -> D_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 48. m
#     core type: Variable
#     sub-expressions:
# 49. _a -> C_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 55
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. l
#     core type: Variable
#     sub-expressions:
# 52. B_{_a}
#     core type: IndexedVar
# variable: 56
# index: 61
# 53. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 61
# 54. D_{_a}
#     core type: IndexedVar
# variable: 58
# index: 61
# 55. C_{_a}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. B
#     core type: Variable
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. D
#     core type: Variable
#     sub-expressions:
# 59. C
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
