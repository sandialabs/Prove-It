# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Abs, Exp, NaturalPos, two
from proveit.physics.quantum import NumBra, Qmult, m_bit_interval, m_ket_domain, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import register_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [m], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [var_ket_psi], instance_expr = Equals(Prob(register_meas), Exp(Abs(Qmult(NumBra(n, m), var_ket_psi)), two)), domain = m_ket_domain, condition = normalized_var_ket_psi), domain = m_bit_interval), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+}~\left[\forall_{n \in \{0~\ldotp \ldotp~2^{m} - 1\}}~\left[\forall_{\lvert \psi \rangle \in \mathbb{C}^{2^{m}}~|~\left \|\lvert \psi \rangle\right \| = 1}~\left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array}\right) = \left|{_{m}}\langle n \rvert \thinspace \lvert \psi \rangle\right|^{2}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in NaturalPos} [forall_{n in {0 .. 2^{m} - 1}} [forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})]]
#    core type: Operation
#    operator: 15
#    operand: 2
# 1. (m -> {forall_{n in {0 .. 2^{m} - 1}} [forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})] if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. m -> {forall_{n in {0 .. 2^{m} - 1}} [forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})] if m in NaturalPos.
#    core type: Lambda
#    parameter: 102
#    body: 4
# 3. (m)
#    core type: ExprTuple
#    sub-expressions: 102
# 4. {forall_{n in {0 .. 2^{m} - 1}} [forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})] if m in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{n in {0 .. 2^{m} - 1}} [forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})]
#    core type: Operation
#    operator: 15
#    operand: 9
# 6. m in NaturalPos
#    core type: Operation
#    operator: 39
#    operands: 8
# 7. (n -> {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 102, 10
# 9. n -> {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.
#    core type: Lambda
#    parameter: 101
#    body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (n)
#     core type: ExprTuple
#     sub-expressions: 101
# 12. {forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}) if n in {0 .. 2^{m} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. forall_{|psi> in Complex^{2^{m}} | |||psi>|| = 1} (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2})
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. n in {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 39
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. (|psi> -> {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (n, {0 .. 2^{m} - 1})
#     core type: ExprTuple
#     sub-expressions: 101, 19
# 18. |psi> -> {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#     core type: Lambda
#     parameter: 95
#     body: 20
# 19. {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 93
#     operands: 21
# 20. {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#     core type: Conditional
#     value: 22
#     condition: 23
# 21. (0, 2^{m} - 1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}
#     core type: Operation
#     operator: 41
#     operands: 26
# 23. (|psi> in Complex^{2^{m}}) and (|||psi>|| = 1)
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. 2^{m} - 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))), |{m}_〈n| . |psi>|^{2})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (|psi> in Complex^{2^{m}}, |||psi>|| = 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (2^{m}, -1)
#     core type: ExprTuple
#     sub-expressions: 62, 35
# 31. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 36
#     operand: 45
# 32. |{m}_〈n| . |psi>|^{2}
#     core type: Operation
#     operator: 68
#     operands: 38
# 33. |psi> in Complex^{2^{m}}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. |||psi>|| = 1
#     core type: Operation
#     operator: 41
#     operands: 42
# 35. -1
#     core type: Operation
#     operator: 43
#     operand: 98
# 36. Pr
#     core type: Literal
#     sub-expressions:
# 37. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 45
# 38. (|{m}_〈n| . |psi>|, 2)
#     core type: ExprTuple
#     sub-expressions: 46, 74
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (|psi>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 95, 47
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 98
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 98
# 45. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. |{m}_〈n| . |psi>|
#     core type: Operation
#     operator: 51
#     operand: 60
# 47. Complex^{2^{m}}
#     core type: Operation
#     operator: 53
#     operands: 54
# 48. |||psi>||
#     core type: Operation
#     operator: 55
#     operand: 95
# 49. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 50. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 57, 58, 59
# 51. Abs
#     core type: Literal
#     sub-expressions:
# 52. ({m}_〈n| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 60
# 53. CartExp
#     core type: Literal
#     sub-expressions:
# 54. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 55. Abs
#     core type: Literal
#     sub-expressions:
# 56. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 95
# 57. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 64
# 59. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 65
# 60. {m}_〈n| . |psi>
#     core type: Operation
#     operator: 66
#     operands: 67
# 61. Complex
#     core type: Literal
#     sub-expressions:
# 62. 2^{m}
#     core type: Operation
#     operator: 68
#     operands: 69
# 63. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 98
#     end_index: 102
# 64. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 98
#     end_index: 102
# 65. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 98
#     end_index: 102
# 66. .
#     core type: Literal
#     sub-expressions:
# 67. ({m}_〈n|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 73, 95
# 68. Exp
#     core type: Literal
#     sub-expressions:
# 69. (2, m)
#     core type: ExprTuple
#     sub-expressions: 74, 102
# 70. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 97
#     body: 75
# 71. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 97
#     body: 76
# 72. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 97
#     body: 78
# 73. {m}_〈n|
#     core type: Operation
#     operator: 79
#     operands: 100
# 74. 2
#     core type: Literal
#     sub-expressions:
# 75. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 83
#     operands: 80
# 76. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 81
#     operands: 82
# 77. (_a)
#     core type: ExprTuple
#     sub-expressions: 97
# 78. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 83
#     operands: 84
# 79. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 80. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 85
#     targets: 88
# 81. MEASURE
#     core type: Literal
#     sub-expressions:
# 82. {basis:Z}
#     core type: NamedExprs
#     basis: 86
# 83. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 84. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 87
#     targets: 88
# 85. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 89
#     operands: 90
# 86. Z
#     core type: Literal
#     sub-expressions:
# 87. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 91
#     operands: 92
# 88. {1 .. m}
#     core type: Operation
#     operator: 93
#     operands: 94
# 89. INPUT
#     core type: Literal
#     sub-expressions:
# 90. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 95
#     part: 97
# 91. OUTPUT
#     core type: Literal
#     sub-expressions:
# 92. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 96
#     part: 97
# 93. Interval
#     core type: Literal
#     sub-expressions:
# 94. (1, m)
#     core type: ExprTuple
#     sub-expressions: 98, 102
# 95. |psi>
#     core type: Variable
#     sub-expressions:
# 96. |n〉_{m}
#     core type: Operation
#     operator: 99
#     operands: 100
# 97. _a
#     core type: Variable
#     sub-expressions:
# 98. 1
#     core type: Literal
#     sub-expressions:
# 99. NUM_KET
#     core type: Literal
#     sub-expressions:
# 100. (n, m)
#      core type: ExprTuple
#      sub-expressions: 101, 102
# 101. n
#      core type: Variable
#      sub-expressions:
# 102. m
#      core type: Variable
#      sub-expressions:
