# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b
from proveit.logic import And, Bijections, InSet, Set, SetOfAll
from proveit.numbers import one, zero
from proveit.physics.quantum import QubitSpace, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import qubit_meas

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(zero, one)
expr = Lambda(var_ket_psi, Conditional(InSet(Lambda(b, qubit_meas), Bijections(sub_expr1, SetOfAll(instance_param_or_params = [b], instance_element = qubit_meas, domain = sub_expr1))).with_wrapping_at(2), And(InSet(var_ket_psi, QubitSpace), normalized_var_ket_psi)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \lvert \psi \rangle \mapsto \left\{\begin{array}{c} \begin{array}{l} \left[b \mapsto \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right)\right] \in  \\ \left[\left\{0, 1\right\} \xrightarrow[\text{onto}]{\text{1-to-1}} \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \meter & \qout{\lvert b \rangle}
# } \end{array}\right\}_{b \in \left\{0, 1\right\}}\right] \end{array} \end{array} \textrm{ if } \lvert \psi \rangle \in \mathbb{C}^{2} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |psi> -> {[b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))] in  \\ Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}) if |psi> in Complex^{2} ,  |||psi>|| = 1.
#    core type: Lambda
#    parameter: 52
#    body: 1
# 1. {[b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))] in  \\ Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}) if |psi> in Complex^{2} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))] in  \\ Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#    core type: Operation
#    operator: 33
#    operands: 4
# 3. (|psi> in Complex^{2}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))), Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (|psi> in Complex^{2}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. b -> QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#    core type: Lambda
#    parameter: 57
#    body: 29
# 8. Bijections({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. |psi> in Complex^{2}
#    core type: Operation
#    operator: 33
#    operands: 13
# 10. |||psi>|| = 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Bijections
#     core type: Literal
#     sub-expressions:
# 12. ({0, 1}, {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}})
#     core type: ExprTuple
#     sub-expressions: 38, 16
# 13. (|psi>, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 52, 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 51
# 16. {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))}_{b in {0, 1}}
#     core type: Operation
#     operator: 19
#     operand: 25
# 17. Complex^{2}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. |||psi>||
#     core type: Operation
#     operator: 23
#     operand: 52
# 19. SetOfAll
#     core type: Literal
#     sub-expressions:
# 20. (b -> {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. CartExp
#     core type: Literal
#     sub-expressions:
# 22. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. Abs
#     core type: Literal
#     sub-expressions:
# 24. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 52
# 25. b -> {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.
#     core type: Lambda
#     parameter: 57
#     body: 28
# 26. Complex
#     core type: Literal
#     sub-expressions:
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. {QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))) if b in {0, 1}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 29. QCIRCUIT(VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉})))
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. b in {0, 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 32. VertExprArray(([INPUT]{state:|psi>}),  \\ ([MEASURE]{basis:Z}),  \\ ([OUTPUT]{state:|b〉}))
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (b, {0, 1})
#     core type: ExprTuple
#     sub-expressions: 57, 38
# 35. ([INPUT]{state:|psi>})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. ([MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. ([OUTPUT]{state:|b〉})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. {0, 1}
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. [INPUT]{state:|psi>}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. [OUTPUT]{state:|b〉}
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. Set
#     core type: Literal
#     sub-expressions:
# 43. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 44. INPUT
#     core type: Literal
#     sub-expressions:
# 45. {state:|psi>}
#     core type: NamedExprs
#     state: 52
# 46. MEASURE
#     core type: Literal
#     sub-expressions:
# 47. {basis:Z}
#     core type: NamedExprs
#     basis: 53
# 48. OUTPUT
#     core type: Literal
#     sub-expressions:
# 49. {state:|b〉}
#     core type: NamedExprs
#     state: 54
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. |psi>
#     core type: Variable
#     sub-expressions:
# 53. Z
#     core type: Literal
#     sub-expressions:
# 54. |b〉
#     core type: Operation
#     operator: 55
#     operand: 57
# 55. KET
#     core type: Literal
#     sub-expressions:
# 56. (b)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. b
#     core type: Variable
#     sub-expressions:
