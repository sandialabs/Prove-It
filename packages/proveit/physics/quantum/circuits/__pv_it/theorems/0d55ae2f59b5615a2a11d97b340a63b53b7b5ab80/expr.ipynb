# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, U, Variable, t
from proveit.linear_algebra import MatrixMult, ScalarMult
from proveit.logic import And, Equals
from proveit.numbers import Exp, Mult, e, i, one, pi, two
from proveit.physics.quantum import var_ket_u, varphi
from proveit.physics.quantum.circuits import phase_kickback_on_register_circuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(varphi, sub_expr1)
expr = ExprTuple(Lambda([ExprRange(sub_expr1, sub_expr2, one, t)], Conditional(Equals(Prob(phase_kickback_on_register_circuit), one), And(ExprRange(sub_expr1, Equals(MatrixMult(IndexedVar(U, sub_expr1), var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, sub_expr2)), var_ket_u)), one, t)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\varphi_{1}, \varphi_{2}, \ldots, \varphi_{t}\right) \mapsto \left\{\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qw & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{1}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \control{} \qw \qwx[1] & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{2}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} & \qout{\vdots} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \qw \qwx[1] & \gate{\cdots} \qwx[1] & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{t}} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U_{1}} & \gate{U_{2}} & \gate{\cdots} & \gate{U_{t}} & \qout{\lvert u \rangle}
# } \end{array}\right) = 1 \textrm{ if } \left(\left(U_{1} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{1}} \cdot \lvert u \rangle\right)\right) \land  \left(\left(U_{2} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{2}} \cdot \lvert u \rangle\right)\right) \land  \ldots \land  \left(\left(U_{t} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{t}} \cdot \lvert u \rangle\right)\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((varphi_{1}, varphi_{2}, ..., varphi_{t}) -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (varphi_{1}, varphi_{2}, ..., varphi_{t}) -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (varphi_{1}, varphi_{2}, ..., varphi_{t})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1 if ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. varphi_{1}, varphi_{2}, ..., varphi_{t}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 126
#    end_index: 125
# 5. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))) = 1
#    core type: Operation
#    operator: 86
#    operands: 8
# 6. ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)) and  ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)) and  ... and  ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. _a -> varphi_{_a}
#    core type: Lambda
#    parameter: 135
#    body: 132
# 8. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))), 1)
#    core type: ExprTuple
#    sub-expressions: 11, 126
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>)))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. ((U_{1} . |u>) = (e^{2 * pi * i * varphi_{1}} * |u>)), ((U_{2} . |u>) = (e^{2 * pi * i * varphi_{2}} * |u>)), ..., ((U_{t} . |u>) = (e^{2 * pi * i * varphi_{t}} * |u>))
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 126
#     end_index: 125
# 13. Pr
#     core type: Literal
#     sub-expressions:
# 14. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))))
#     core type: ExprTuple
#     sub-expressions: 16
# 15. _a -> ((U_{_a} . |u>) = (e^{2 * pi * i * varphi_{_a}} * |u>))
#     core type: Lambda
#     parameter: 135
#     body: 17
# 16. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})))
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (U_{_a} . |u>) = (e^{2 * pi * i * varphi_{_a}} * |u>)
#     core type: Operation
#     operator: 86
#     operands: 20
# 18. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 19. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}))
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 20. (U_{_a} . |u>, e^{2 * pi * i * varphi_{_a}} * |u>)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 126
#     end_index: 125
# 23. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. U_{_a} . |u>
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. e^{2 * pi * i * varphi_{_a}} * |u>
#     core type: Operation
#     operator: 104
#     operands: 33
# 26. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 126
#     end_index: 125
# 27. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 126
#     end_index: 109
# 28. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#     core type: Lambda
#     parameter: 108
#     body: 36
# 29. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 126
#     end_index: 125
# 30. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 126
#     end_index: 109
# 31. .
#     core type: Literal
#     sub-expressions:
# 32. (U_{_a}, |u>)
#     core type: ExprTuple
#     sub-expressions: 39, 73
# 33. (e^{2 * pi * i * varphi_{_a}}, |u>)
#     core type: ExprTuple
#     sub-expressions: 112, 73
# 34. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 135
#     body: 40
# 35. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 135
#     body: 41
# 36. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 37. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: Lambda
#     parameter: 135
#     body: 44
# 38. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 135
#     body: 45
# 39. U_{_a}
#     core type: IndexedVar
# variable: 99
# index: 135
# 40. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 59
#     operands: 46
# 41. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 84
#     operands: 47
# 42. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 126
#     end_index: 125
# 43. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 126
#     end_index: 109
# 44. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: Operation
#     operator: 64
#     operands: 50
# 45. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 84
#     operands: 51
# 46. {state:|+〉}
#     core type: NamedExprs
#     state: 52
# 47. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 53
#     targets: 70
# 48. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#     core type: Lambda
#     parameter: 135
#     body: 54
# 49. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Lambda
#     parameter: 135
#     body: 55
# 50. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#     core type: NamedExprs
#     state: 56
# 51. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 57
#     targets: 70
# 52. |+〉
#     core type: Operation
#     operator: 119
#     operand: 66
# 53. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 59
#     operands: 65
# 54. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: Operation
#     operator: 84
#     operands: 62
# 56. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: Operation
#     operator: 104
#     operands: 63
# 57. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 64
#     operands: 65
# 58. (+)
#     core type: ExprTuple
#     sub-expressions: 66
# 59. INPUT
#     core type: Literal
#     sub-expressions:
# 60. CondSet
#     core type: Literal
#     sub-expressions:
# 61. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a, [GATE]{operation:I} if _b != _a)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 62. {element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 69
#     targets: 70
# 63. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 64. OUTPUT
#     core type: Literal
#     sub-expressions:
# 65. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 73
#     part: 135
# 66. +
#     core type: Literal
#     sub-expressions:
# 67. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a.
#     core type: Conditional
#     value: 74
#     condition: 75
# 68. {[GATE]{operation:I} if _b != _a.
#     core type: Conditional
#     value: 76
#     condition: 77
# 69. [GATE]{operation:U_{_b}, part:_a}
#     core type: Operation
#     operator: 87
#     operands: 78
# 70. {t + 1 .. t + m}
#     core type: Operation
#     operator: 79
#     operands: 80
# 71. 1 / sqrt(2)
#     core type: Operation
#     operator: 115
#     operands: 81
# 72. |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)
#     core type: Operation
#     operator: 82
#     operands: 83
# 73. |u>
#     core type: Variable
#     sub-expressions:
# 74. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 84
#     operands: 85
# 75. _b = _a
#     core type: Operation
#     operator: 86
#     operands: 90
# 76. [GATE]{operation:I}
#     core type: Operation
#     operator: 87
#     operands: 88
# 77. _b != _a
#     core type: Operation
#     operator: 89
#     operands: 90
# 78. {operation:U_{_b}, part:_a}
#     core type: NamedExprs
#     operation: 91
#     part: 135
# 79. Interval
#     core type: Literal
#     sub-expressions:
# 80. (t + 1, t + m)
#     core type: ExprTuple
#     sub-expressions: 114, 92
# 81. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 126, 93
# 82. +
#     core type: Literal
#     sub-expressions:
# 83. (|0〉, e^{2 * pi * i * varphi_{_a}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 84. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 85. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 96
#     targets: 97
# 86. =
#     core type: Literal
#     sub-expressions:
# 87. GATE
#     core type: Literal
#     sub-expressions:
# 88. {operation:I}
#     core type: NamedExprs
#     operation: 98
# 89. !=
#     core type: Literal
#     sub-expressions:
# 90. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 108, 135
# 91. U_{_b}
#     core type: IndexedVar
# variable: 99
# index: 108
# 92. t + m
#     core type: Operation
#     operator: 121
#     operands: 101
# 93. sqrt(2)
#     core type: Operation
#     operator: 117
#     operands: 102
# 94. |0〉
#     core type: Operation
#     operator: 119
#     operand: 111
# 95. e^{2 * pi * i * varphi_{_a}} * |1〉
#     core type: Operation
#     operator: 104
#     operands: 105
# 96. CONTROL
#     core type: Literal
#     sub-expressions:
# 97. {t + 1}
#     core type: Operation
#     operator: 106
#     operand: 114
# 98. I
#     core type: Literal
#     sub-expressions:
# 99. U
#     core type: Variable
#     sub-expressions:
# 100. (_b)
#      core type: ExprTuple
#      sub-expressions: 108
# 101. (t, m)
#      core type: ExprTuple
#      sub-expressions: 125, 109
# 102. (2, 1 / 2)
#      core type: ExprTuple
#      sub-expressions: 129, 110
# 103. (0)
#      core type: ExprTuple
#      sub-expressions: 111
# 104. *
#      core type: Literal
#      sub-expressions:
# 105. (e^{2 * pi * i * varphi_{_a}}, |1〉)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 106. Set
#      core type: Literal
#      sub-expressions:
# 107. (t + 1)
#      core type: ExprTuple
#      sub-expressions: 114
# 108. _b
#      core type: Variable
#      sub-expressions:
# 109. m
#      core type: Variable
#      sub-expressions:
# 110. 1 / 2
#      core type: Operation
#      operator: 115
#      operands: 116
# 111. 0
#      core type: Literal
#      sub-expressions:
# 112. e^{2 * pi * i * varphi_{_a}}
#      core type: Operation
#      operator: 117
#      operands: 118
# 113. |1〉
#      core type: Operation
#      operator: 119
#      operand: 126
# 114. t + 1
#      core type: Operation
#      operator: 121
#      operands: 122
# 115. /
#      core type: Literal
#      sub-expressions:
# 116. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 126, 129
# 117. Exp
#      core type: Literal
#      sub-expressions:
# 118. (e, 2 * pi * i * varphi_{_a})
#      core type: ExprTuple
#      sub-expressions: 123, 124
# 119. KET
#      core type: Literal
#      sub-expressions:
# 120. (1)
#      core type: ExprTuple
#      sub-expressions: 126
# 121. +
#      core type: Literal
#      sub-expressions:
# 122. (t, 1)
#      core type: ExprTuple
#      sub-expressions: 125, 126
# 123. e
#      core type: Literal
#      sub-expressions:
# 124. 2 * pi * i * varphi_{_a}
#      core type: Operation
#      operator: 127
#      operands: 128
# 125. t
#      core type: Variable
#      sub-expressions:
# 126. 1
#      core type: Literal
#      sub-expressions:
# 127. *
#      core type: Literal
#      sub-expressions:
# 128. (2, pi, i, varphi_{_a})
#      core type: ExprTuple
#      sub-expressions: 129, 130, 131, 132
# 129. 2
#      core type: Literal
#      sub-expressions:
# 130. pi
#      core type: Literal
#      sub-expressions:
# 131. i
#      core type: Literal
#      sub-expressions:
# 132. varphi_{_a}
#      core type: IndexedVar
# variable: 133
# index: 135
# 133. varphi
#      core type: Variable
#      sub-expressions:
# 134. (_a)
#      core type: ExprTuple
#      sub-expressions: 135
# 135. _a
#      core type: Variable
#      sub-expressions:
