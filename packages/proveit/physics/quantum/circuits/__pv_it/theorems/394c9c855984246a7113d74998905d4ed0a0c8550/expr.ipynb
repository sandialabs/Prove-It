# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n
from proveit.logic import And, InClass, InSet, SetOfAll
from proveit.numbers import NaturalPos
from proveit.physics.quantum import m_bit_interval, m_ket_domain, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import register_meas
from proveit.statistics import SampleSpaces

# %%
# build up the expression from sub-expressions
expr = Conditional(InClass(SetOfAll(instance_param_or_params = [n], instance_element = register_meas, domain = m_bit_interval), SampleSpaces), And(InSet(m, NaturalPos), InSet(var_ket_psi, m_ket_domain), normalized_var_ket_psi))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array}\right\}_{n \in \{0~\ldotp \ldotp~2^{m} - 1\}} \underset{{\scriptscriptstyle c}}{\in} \textrm{SampleSpaces} \textrm{ if } m \in \mathbb{N}^+ ,  \lvert \psi \rangle \in \mathbb{C}^{2^{m}} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {{QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))}_{n in {0 .. 2^{m} - 1}} in_c SampleSpaces if m in NaturalPos ,  |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))}_{n in {0 .. 2^{m} - 1}} in_c SampleSpaces
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (m in NaturalPos) and (|psi> in Complex^{2^{m}}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in_c
#    core type: Literal
#    sub-expressions:
# 4. ({QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))}_{n in {0 .. 2^{m} - 1}}, SampleSpaces)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (m in NaturalPos, |psi> in Complex^{2^{m}}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))}_{n in {0 .. 2^{m} - 1}}
#    core type: Operation
#    operator: 12
#    operand: 18
# 8. SampleSpaces
#    core type: Literal
#    sub-expressions:
# 9. m in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 14
# 10. |psi> in Complex^{2^{m}}
#     core type: Operation
#     operator: 33
#     operands: 15
# 11. |||psi>|| = 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. SetOfAll
#     core type: Literal
#     sub-expressions:
# 13. (n -> {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 83, 19
# 15. (|psi>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 76, 20
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 79
# 18. n -> {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#     core type: Lambda
#     parameter: 82
#     body: 23
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. Complex^{2^{m}}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. |||psi>||
#     core type: Operation
#     operator: 26
#     operand: 76
# 22. (n)
#     core type: ExprTuple
#     sub-expressions: 82
# 23. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 24. CartExp
#     core type: Literal
#     sub-expressions:
# 25. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 30, 59
# 26. Abs
#     core type: Literal
#     sub-expressions:
# 27. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 76
# 28. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. n in {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 32. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (n, {0 .. 2^{m} - 1})
#     core type: ExprTuple
#     sub-expressions: 82, 38
# 35. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 73
#     operands: 42
# 39. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 79
#     end_index: 83
# 40. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 79
#     end_index: 83
# 41. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 79
#     end_index: 83
# 42. (0, 2^{m} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 78
#     body: 48
# 44. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 78
#     body: 49
# 45. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 78
#     body: 51
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. 2^{m} - 1
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 57
#     operands: 54
# 49. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 51. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (2^{m}, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 54. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 61
#     targets: 64
# 55. MEASURE
#     core type: Literal
#     sub-expressions:
# 56. {basis:Z}
#     core type: NamedExprs
#     basis: 62
# 57. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 58. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 63
#     targets: 64
# 59. 2^{m}
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. -1
#     core type: Operation
#     operator: 67
#     operand: 79
# 61. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 69
#     operands: 70
# 62. Z
#     core type: Literal
#     sub-expressions:
# 63. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 71
#     operands: 72
# 64. {1 .. m}
#     core type: Operation
#     operator: 73
#     operands: 74
# 65. Exp
#     core type: Literal
#     sub-expressions:
# 66. (2, m)
#     core type: ExprTuple
#     sub-expressions: 75, 83
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 69. INPUT
#     core type: Literal
#     sub-expressions:
# 70. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 76
#     part: 78
# 71. OUTPUT
#     core type: Literal
#     sub-expressions:
# 72. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 77
#     part: 78
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (1, m)
#     core type: ExprTuple
#     sub-expressions: 79, 83
# 75. 2
#     core type: Literal
#     sub-expressions:
# 76. |psi>
#     core type: Variable
#     sub-expressions:
# 77. |n〉_{m}
#     core type: Operation
#     operator: 80
#     operands: 81
# 78. _a
#     core type: Variable
#     sub-expressions:
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. NUM_KET
#     core type: Literal
#     sub-expressions:
# 81. (n, m)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 82. n
#     core type: Variable
#     sub-expressions:
# 83. m
#     core type: Variable
#     sub-expressions:
