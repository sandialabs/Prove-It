# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Equals, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuits import circuit_Ui_Vj, circuit_Ui_psi_m, circuit_psi_m_Vj
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Implies(Equals(Prob(circuit_psi_m_Vj), one), Equals(Prob(circuit_Ui_Vj), Prob(circuit_Ui_psi_m)).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert \psi \rangle} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & { /^{m} } \qw
# } \end{array}\right) = 1\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\V_{j} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) =  \\ \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\U_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\U_{i} \\ \downarrow\end{array}} & \qout{\lvert \psi \rangle}
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1) =>  \\ (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1, Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))) = 1
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))) =  \\ Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))), 1)
#    core type: ExprTuple
#    sub-expressions: 8, 54
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))), Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#    core type: Operation
#    operator: 13
#    operand: 15
# 9. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#    core type: Operation
#    operator: 13
#    operand: 16
# 10. Pr(QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: Operation
#     operator: 13
#     operand: 17
# 11. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})))
#     core type: ExprTuple
#     sub-expressions: 16
# 13. Pr
#     core type: Literal
#     sub-expressions:
# 14. (QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 17
# 15. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j}))
#     core type: Operation
#     operator: 20
#     operands: 18
# 16. QCIRCUIT(VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j}))
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. QCIRCUIT(VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}), \\ V_{1}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. VertExprArray(U_{1},  \\ U_{2}, ..., U_{i},V_{1}, V_{2}, ..., V_{j})
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 21. VertExprArray(U_{1},  \\ ..., U_{i}, ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. V_{1}, V_{2}, ..., V_{j}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 54
#     end_index: 28
# 24. U_{1}, ..., U_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 54
#     end_index: 30
# 25. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 31
# 26. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 54
#     end_index: 55
# 27. _a -> V_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 33
# 28. j
#     core type: Variable
#     sub-expressions:
# 29. _a -> U_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 34
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 54
#     end_index: 55
# 32. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 53
#     body: 36
# 33. V_{_a}
#     core type: IndexedVar
# variable: 37
# index: 53
# 34. U_{_a}
#     core type: IndexedVar
# variable: 38
# index: 53
# 35. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 53
#     body: 40
# 36. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 42
#     operands: 41
# 37. V
#     core type: Variable
#     sub-expressions:
# 38. U
#     core type: Variable
#     sub-expressions:
# 39. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 40. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 44
#     targets: 46
# 42. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 43. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 45
#     targets: 46
# 44. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 49
# 45. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. {1 .. m}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. INPUT
#     core type: Literal
#     sub-expressions:
# 48. OUTPUT
#     core type: Literal
#     sub-expressions:
# 49. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 52
#     part: 53
# 50. Interval
#     core type: Literal
#     sub-expressions:
# 51. (1, m)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. |psi>
#     core type: Variable
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. m
#     core type: Variable
#     sub-expressions:
