# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, j, k, l, m
from proveit.core_expr_types import A_1_to_j, B_1_to_k, C_1_to_l, D_1_to_m
from proveit.logic import And, Forall, Implies, InSet
from proveit.numbers import Natural
from proveit.physics.quantum.circuits import QcircuitEquiv, circuit_AjBkCl, circuit_AjDmCl, circuit_Bk, circuit_Dm

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [A_1_to_j, B_1_to_k, C_1_to_l, D_1_to_m], instance_expr = Implies(QcircuitEquiv(circuit_Bk, circuit_Dm), QcircuitEquiv(circuit_AjBkCl, circuit_AjDmCl).with_wrapping_at(1)).with_wrapping_at(2)).with_wrapping(), And(InSet(j, Natural), InSet(k, Natural), InSet(l, Natural), InSet(m, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{A_{1}, A_{2}, \ldots, A_{j}, B_{1}, B_{2}, \ldots, B_{k}, C_{1}, C_{2}, \ldots, C_{l}, D_{1}, D_{2}, \ldots, D_{m}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\B_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{k} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \cong \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\D_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{m} \\ \downarrow\end{array}} & \qw
# } \end{array}\right)\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\A_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{j} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\B_{k} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{l} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \\  \cong \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{\begin{array}{c} \uparrow \\A_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\A_{j} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\D_{m} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{1} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{2} \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\\cdots \\ \downarrow\end{array}} & \gate{\begin{array}{c} \uparrow \\C_{l} \\ \downarrow\end{array}} & \qw
# } \end{array}\right) \end{array} \end{array}\right) \end{array} \end{array}\right)\end{array} \textrm{ if } j \in \mathbb{N} ,  k \in \mathbb{N} ,  l \in \mathbb{N} ,  m \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))) if j in Natural ,  k in Natural ,  l in Natural ,  m in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}} ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (j in Natural) and (k in Natural) and (l in Natural) and (m in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}) -> ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (j in Natural, k in Natural, l in Natural, m in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. (A_{1}, A_{2}, ..., A_{j}, B_{1}, B_{2}, ..., B_{k}, C_{1}, C_{2}, ..., C_{l}, D_{1}, D_{2}, ..., D_{m}) -> ((QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))))
#    core type: Lambda
#    parameters: 12\n   body: 13
# 8. j in Natural
#    core type: Operation
#    operator: 17
#    operands: 14
# 9. k in Natural
#    core type: Operation
#    operator: 17
#    operands: 15
# 10. l in Natural
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. m in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (A_{1}, A_{2}, ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l},D_{1}, D_{2}, ..., D_{m})
#     core type: ExprTuple
#     sub-expressions: 37, 36, 39, 38
# 13. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))) =>  \\ (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 43, 21
# 15. (k, Natural)
#     core type: ExprTuple
#     sub-expressions: 41, 21
# 16. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 21
# 19. =>
#     core type: Literal
#     sub-expressions:
# 20. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m})), QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. Natural
#     core type: Literal
#     sub-expressions:
# 22. QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})) equiv QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))
#     core type: Operation
#     operator: 25
#     operands: 24
# 23. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})) \\  equiv QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k})), QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m})))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. equiv
#     core type: Literal
#     sub-expressions:
# 26. (QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})), QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. QCIRCUIT(VertExprArray(B_{1}, B_{2}, ..., B_{k}))
#     core type: Operation
#     operator: 34
#     operands: 31
# 28. QCIRCUIT(VertExprArray(D_{1}, D_{2}, ..., D_{m}))
#     core type: Operation
#     operator: 34
#     operands: 32
# 29. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 34
#     operands: 33
# 30. QCIRCUIT(VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l}))
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. VertExprArray(B_{1}, B_{2}, ..., B_{k})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. VertExprArray(D_{1}, D_{2}, ..., D_{m})
#     core type: ExprTuple
#     sub-expressions: 38
# 33. VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},B_{1}, B_{2}, ..., B_{k},C_{1}, C_{2}, ..., C_{l})
#     core type: ExprTuple
#     sub-expressions: 37, 36, 39
# 34. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 35. VertExprArray(A_{1},  \\ A_{2},  \\ ..., A_{j},D_{1}, D_{2}, ..., D_{m},C_{1}, C_{2}, ..., C_{l})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 36. B_{1}, B_{2}, ..., B_{k}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 47
#     end_index: 41
# 37. A_{1}, A_{2}, ..., A_{j}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 47
#     end_index: 43
# 38. D_{1}, D_{2}, ..., D_{m}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 39. C_{1}, C_{2}, ..., C_{l}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 40. _a -> B_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 49
# 41. k
#     core type: Variable
#     sub-expressions:
# 42. _a -> A_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 50
# 43. j
#     core type: Variable
#     sub-expressions:
# 44. _a -> D_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 51
# 45. m
#     core type: Variable
#     sub-expressions:
# 46. _a -> C_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. l
#     core type: Variable
#     sub-expressions:
# 49. B_{_a}
#     core type: IndexedVar
# variable: 53
# index: 58
# 50. A_{_a}
#     core type: IndexedVar
# variable: 54
# index: 58
# 51. D_{_a}
#     core type: IndexedVar
# variable: 55
# index: 58
# 52. C_{_a}
#     core type: IndexedVar
# variable: 56
# index: 58
# 53. B
#     core type: Variable
#     sub-expressions:
# 54. A
#     core type: Variable
#     sub-expressions:
# 55. D
#     core type: Variable
#     sub-expressions:
# 56. C
#     core type: Variable
#     sub-expressions:
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. _a
#     core type: Variable
#     sub-expressions:
