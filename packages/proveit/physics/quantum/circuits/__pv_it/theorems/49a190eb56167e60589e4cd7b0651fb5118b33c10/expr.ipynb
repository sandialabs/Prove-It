# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n
from proveit.logic import InSet
from proveit.physics.quantum import m_bit_interval
from proveit.physics.quantum.circuits import register_meas

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(register_meas, InSet(n, m_bit_interval)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array} \textrm{ if } n \in \{0~\ldotp \ldotp~2^{m} - 1\}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#    core type: Lambda
#    parameter: 56
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 56
# 2. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))) if n in {0 .. 2^{m} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in {0 .. 2^{m} - 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 6. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n, {0 .. 2^{m} - 1})
#    core type: ExprTuple
#    sub-expressions: 56, 12
# 9. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 15
# 12. {0 .. 2^{m} - 1}
#     core type: Operation
#     operator: 47
#     operands: 16
# 13. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 53
#     end_index: 57
# 14. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 53
#     end_index: 57
# 15. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 53
#     end_index: 57
# 16. (0, 2^{m} - 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 52
#     body: 22
# 18. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 52
#     body: 23
# 19. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 52
#     body: 25
# 20. 0
#     core type: Literal
#     sub-expressions:
# 21. 2^{m} - 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 31
#     operands: 28
# 23. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (2^{m}, -1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 35
#     targets: 38
# 29. MEASURE
#     core type: Literal
#     sub-expressions:
# 30. {basis:Z}
#     core type: NamedExprs
#     basis: 36
# 31. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 32. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 37
#     targets: 38
# 33. 2^{m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. -1
#     core type: Operation
#     operator: 41
#     operand: 53
# 35. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. Z
#     core type: Literal
#     sub-expressions:
# 37. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 38. {1 .. m}
#     core type: Operation
#     operator: 47
#     operands: 48
# 39. Exp
#     core type: Literal
#     sub-expressions:
# 40. (2, m)
#     core type: ExprTuple
#     sub-expressions: 49, 57
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 43. INPUT
#     core type: Literal
#     sub-expressions:
# 44. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 50
#     part: 52
# 45. OUTPUT
#     core type: Literal
#     sub-expressions:
# 46. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 51
#     part: 52
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (1, m)
#     core type: ExprTuple
#     sub-expressions: 53, 57
# 49. 2
#     core type: Literal
#     sub-expressions:
# 50. |psi>
#     core type: Variable
#     sub-expressions:
# 51. |n〉_{m}
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. _a
#     core type: Variable
#     sub-expressions:
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. NUM_KET
#     core type: Literal
#     sub-expressions:
# 55. (n, m)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. m
#     core type: Variable
#     sub-expressions:
