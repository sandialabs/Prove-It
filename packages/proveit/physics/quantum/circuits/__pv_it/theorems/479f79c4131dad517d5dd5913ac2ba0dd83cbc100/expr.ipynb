# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, m
from proveit.linear_algebra import ScalarMult, Unitary
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Mult, NaturalPos, e, i, one, pi, two
from proveit.physics.quantum import Qmult, m_ket_domain, normalized_var_ket_u, var_ket_u, varphi
from proveit.physics.quantum.circuits import phase_kickback_circuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(m, Conditional(Forall(instance_param_or_params = [U], instance_expr = Forall(instance_param_or_params = [var_ket_u], instance_expr = Forall(instance_param_or_params = [varphi], instance_expr = Equals(Prob(phase_kickback_circuit), one), condition = Equals(Qmult(U, var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, varphi)), var_ket_u))), domain = m_ket_domain, condition = normalized_var_ket_u), domain = Unitary(Exp(two, m))), InSet(m, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m \mapsto \left\{\forall_{U \in \textrm{U}\left(2^{m}\right)}~\left[\forall_{\lvert u \rangle \in \mathbb{C}^{2^{m}}~|~\left \|\lvert u \rangle\right \| = 1}~\left[\forall_{\varphi~|~\left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right)}~\left(\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U} & \qout{\lvert u \rangle}
# } \end{array}\right) = 1\right)\right]\right] \textrm{ if } m \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m -> {forall_{U in U(2^{m})} [forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)]] if m in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {forall_{U in U(2^{m})} [forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)]] if m in NaturalPos.
#    core type: Lambda
#    parameter: 127
#    body: 3
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 127
# 3. {forall_{U in U(2^{m})} [forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)]] if m in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{U in U(2^{m})} [forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)]]
#    core type: Operation
#    operator: 23
#    operand: 8
# 5. m in NaturalPos
#    core type: Operation
#    operator: 32
#    operands: 7
# 6. (U -> {forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)] if U in U(2^{m}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (m, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 127, 9
# 8. U -> {forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)] if U in U(2^{m}).
#    core type: Lambda
#    parameter: 110
#    body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (U)
#     core type: ExprTuple
#     sub-expressions: 110
# 11. {forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)] if U in U(2^{m}).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{|u> in Complex^{2^{m}} | |||u>|| = 1} [forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)]
#     core type: Operation
#     operator: 23
#     operand: 16
# 13. U in U(2^{m})
#     core type: Operation
#     operator: 32
#     operands: 15
# 14. (|u> -> {forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (U, U(2^{m}))
#     core type: ExprTuple
#     sub-expressions: 110, 17
# 16. |u> -> {forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.
#     core type: Lambda
#     parameter: 114
#     body: 18
# 17. U(2^{m})
#     core type: Operation
#     operator: 19
#     operand: 50
# 18. {forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1) if |u> in Complex^{2^{m}} ,  |||u>|| = 1.
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. U
#     core type: Literal
#     sub-expressions:
# 20. (2^{m})
#     core type: ExprTuple
#     sub-expressions: 50
# 21. forall_{varphi | (U . |u>) = (e^{2 * pi * i * varphi} * |u>)} (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1)
#     core type: Operation
#     operator: 23
#     operand: 27
# 22. (|u> in Complex^{2^{m}}) and (|||u>|| = 1)
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (varphi -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1 if (U . |u>) = (e^{2 * pi * i * varphi} * |u>).)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. (|u> in Complex^{2^{m}}, |||u>|| = 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. varphi -> {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1 if (U . |u>) = (e^{2 * pi * i * varphi} * |u>).
#     core type: Lambda
#     parameter: 142
#     body: 31
# 28. |u> in Complex^{2^{m}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. |||u>|| = 1
#     core type: Operation
#     operator: 40
#     operands: 34
# 30. (varphi)
#     core type: ExprTuple
#     sub-expressions: 142
# 31. {Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1 if (U . |u>) = (e^{2 * pi * i * varphi} * |u>).
#     core type: Conditional
#     value: 35
#     condition: 36
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (|u>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 114, 37
# 34. (|||u>||, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 136
# 35. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))) = 1
#     core type: Operation
#     operator: 40
#     operands: 39
# 36. (U . |u>) = (e^{2 * pi * i * varphi} * |u>)
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. Complex^{2^{m}}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. |||u>||
#     core type: Operation
#     operator: 44
#     operand: 114
# 39. (Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))), 1)
#     core type: ExprTuple
#     sub-expressions: 46, 136
# 40. =
#     core type: Literal
#     sub-expressions:
# 41. (U . |u>, e^{2 * pi * i * varphi} * |u>)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 42. CartExp
#     core type: Literal
#     sub-expressions:
# 43. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. Abs
#     core type: Literal
#     sub-expressions:
# 45. (|u>)
#     core type: ExprTuple
#     sub-expressions: 114
# 46. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#     core type: Operation
#     operator: 51
#     operand: 57
# 47. U . |u>
#     core type: Operation
#     operator: 53
#     operands: 54
# 48. e^{2 * pi * i * varphi} * |u>
#     core type: Operation
#     operator: 119
#     operands: 55
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. 2^{m}
#     core type: Operation
#     operator: 130
#     operands: 56
# 51. Pr
#     core type: Literal
#     sub-expressions:
# 52. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))))
#     core type: ExprTuple
#     sub-expressions: 57
# 53. .
#     core type: Literal
#     sub-expressions:
# 54. (U, |u>)
#     core type: ExprTuple
#     sub-expressions: 110, 114
# 55. (e^{2 * pi * i * varphi}, |u>)
#     core type: ExprTuple
#     sub-expressions: 125, 114
# 56. (2, m)
#     core type: ExprTuple
#     sub-expressions: 139, 127
# 57. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))
#     core type: Operation
#     operator: 58
#     operands: 59
# 58. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 59. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62
# 60. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 62. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 63. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 100
#     operands: 69
# 64. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 136
#     end_index: 75
# 65. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#     core type: Operation
#     operator: 91
#     operands: 71
# 66. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 136
#     end_index: 75
# 67. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: Operation
#     operator: 106
#     operands: 73
# 68. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 136
#     end_index: 75
# 69. {state:|+〉}
#     core type: NamedExprs
#     state: 76
# 70. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 115
#     body: 77
# 71. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 78
#     targets: 79
# 72. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 115
#     body: 80
# 73. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 81
# 74. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 115
#     body: 83
# 75. m + 1
#     core type: Operation
#     operator: 121
#     operands: 84
# 76. |+〉
#     core type: Operation
#     operator: 132
#     operand: 93
# 77. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 91
#     operands: 86
# 78. CONTROL
#     core type: Literal
#     sub-expressions:
# 79. {2}
#     core type: Operation
#     operator: 87
#     operand: 139
# 80. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 91
#     operands: 89
# 81. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 119
#     operands: 90
# 82. (_a)
#     core type: ExprTuple
#     sub-expressions: 115
# 83. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 91
#     operands: 92
# 84. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 127, 136
# 85. (+)
#     core type: ExprTuple
#     sub-expressions: 93
# 86. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 94
#     targets: 99
# 87. Set
#     core type: Literal
#     sub-expressions:
# 88. (2)
#     core type: ExprTuple
#     sub-expressions: 139
# 89. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 95
#     targets: 99
# 90. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 91. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 92. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 98
#     targets: 99
# 93. +
#     core type: Literal
#     sub-expressions:
# 94. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 100
#     operands: 107
# 95. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 101
#     operands: 102
# 96. 1 / sqrt(2)
#     core type: Operation
#     operator: 128
#     operands: 103
# 97. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 104
#     operands: 105
# 98. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 106
#     operands: 107
# 99. {2 .. m + 2}
#     core type: Operation
#     operator: 108
#     operands: 109
# 100. INPUT
#      core type: Literal
#      sub-expressions:
# 101. GATE
#      core type: Literal
#      sub-expressions:
# 102. {operation:U, part:_a}
#      core type: NamedExprs
#      operation: 110
#      part: 115
# 103. (1, sqrt(2))
#      core type: ExprTuple
#      sub-expressions: 136, 111
# 104. +
#      core type: Literal
#      sub-expressions:
# 105. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 106. OUTPUT
#      core type: Literal
#      sub-expressions:
# 107. {state:|u>, part:_a}
#      core type: NamedExprs
#      state: 114
#      part: 115
# 108. Interval
#      core type: Literal
#      sub-expressions:
# 109. (2, m + 2)
#      core type: ExprTuple
#      sub-expressions: 139, 116
# 110. U
#      core type: Variable
#      sub-expressions:
# 111. sqrt(2)
#      core type: Operation
#      operator: 130
#      operands: 117
# 112. |0〉
#      core type: Operation
#      operator: 132
#      operand: 124
# 113. e^{2 * pi * i * varphi} * |1〉
#      core type: Operation
#      operator: 119
#      operands: 120
# 114. |u>
#      core type: Variable
#      sub-expressions:
# 115. _a
#      core type: Variable
#      sub-expressions:
# 116. m + 2
#      core type: Operation
#      operator: 121
#      operands: 122
# 117. (2, 1 / 2)
#      core type: ExprTuple
#      sub-expressions: 139, 123
# 118. (0)
#      core type: ExprTuple
#      sub-expressions: 124
# 119. *
#      core type: Literal
#      sub-expressions:
# 120. (e^{2 * pi * i * varphi}, |1〉)
#      core type: ExprTuple
#      sub-expressions: 125, 126
# 121. +
#      core type: Literal
#      sub-expressions:
# 122. (m, 2)
#      core type: ExprTuple
#      sub-expressions: 127, 139
# 123. 1 / 2
#      core type: Operation
#      operator: 128
#      operands: 129
# 124. 0
#      core type: Literal
#      sub-expressions:
# 125. e^{2 * pi * i * varphi}
#      core type: Operation
#      operator: 130
#      operands: 131
# 126. |1〉
#      core type: Operation
#      operator: 132
#      operand: 136
# 127. m
#      core type: Variable
#      sub-expressions:
# 128. /
#      core type: Literal
#      sub-expressions:
# 129. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 136, 139
# 130. Exp
#      core type: Literal
#      sub-expressions:
# 131. (e, 2 * pi * i * varphi)
#      core type: ExprTuple
#      sub-expressions: 134, 135
# 132. KET
#      core type: Literal
#      sub-expressions:
# 133. (1)
#      core type: ExprTuple
#      sub-expressions: 136
# 134. e
#      core type: Literal
#      sub-expressions:
# 135. 2 * pi * i * varphi
#      core type: Operation
#      operator: 137
#      operands: 138
# 136. 1
#      core type: Literal
#      sub-expressions:
# 137. *
#      core type: Literal
#      sub-expressions:
# 138. (2, pi, i, varphi)
#      core type: ExprTuple
#      sub-expressions: 139, 140, 141, 142
# 139. 2
#      core type: Literal
#      sub-expressions:
# 140. pi
#      core type: Literal
#      sub-expressions:
# 141. i
#      core type: Literal
#      sub-expressions:
# 142. varphi
#      core type: Variable
#      sub-expressions:
