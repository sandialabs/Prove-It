# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Equals
from proveit.physics.quantum.circuits import circuit__u_Akl_v, circuit__u_Akl_v__psi_m
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Equals(Prob(circuit__u_Akl_v), Prob(circuit__u_Akl_v__psi_m)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert u \rangle} & \gate{A_{1, 1}} \qwx[1] & \gate{A_{2, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 1}} \qwx[1] & \multiqout{3}{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{A_{1, 2}} \qwx[1] & \gate{A_{2, 2}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 2}} \qwx[1] & \ghostqout{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} \qwx[1] & \ghostqout{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{A_{1, l}} & \gate{A_{2, l}} & \gate{\cdots} & \gate{A_{k, l}} & \ghostqout{\lvert v \rangle}
# } \end{array}\right) =  \\ \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert u \rangle} & \gate{A_{1, 1}} \qwx[1] & \gate{A_{2, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 1}} \qwx[1] & \multiqout{3}{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{A_{1, 2}} \qwx[1] & \gate{A_{2, 2}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 2}} \qwx[1] & \ghostqout{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} \qwx[1] & \ghostqout{\lvert v \rangle} \\
# \ghostqin{\lvert u \rangle} & \gate{A_{1, l}} & \gate{A_{2, l}} & \gate{\cdots} & \gate{A_{k, l}} & \ghostqout{\lvert v \rangle} \\
# \qin{\lvert \psi \rangle} & { /^{m} } \qw & { /^{m} } \qw & \gate{\cdots} & { /^{m} } \qw & \qout{\lvert \psi \rangle}
# } \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}})))) =  \\ Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}})))), Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}}))))
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}))))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}}))))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Pr
#    core type: Literal
#    sub-expressions:
# 7. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}))))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}})))
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}}))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 12. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}))
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 13. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}})
#     core type: ExprTuple
#     sub-expressions: 20
# 14. (A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 78
#     end_index: 23
# 15. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}})
#     core type: ExprTuple
#     sub-expressions: 24
# 16. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 78
#     end_index: 23
# 18. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 19. _b -> (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l})
#     core type: Lambda
#     parameter: 68
#     body: 26
# 20. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 78
#     end_index: 79
# 21. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 78
#     end_index: 80
# 22. _b -> (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#     core type: Lambda
#     parameter: 68
#     body: 30
# 23. k
#     core type: Variable
#     sub-expressions:
# 24. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 78
#     end_index: 79
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 78
#     end_index: 80
# 26. (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l})
#     core type: ExprTuple
#     sub-expressions: 35
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: Lambda
#     parameter: 72
#     body: 33
# 28. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Lambda
#     parameter: 72
#     body: 34
# 29. (_b)
#     core type: ExprTuple
#     sub-expressions: 68
# 30. (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: Lambda
#     parameter: 72
#     body: 37
# 32. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Lambda
#     parameter: 72
#     body: 38
# 33. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: Operation
#     operator: 44
#     operands: 39
# 34. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Operation
#     operator: 44
#     operands: 40
# 35. A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 78
#     end_index: 79
# 36. [GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 78
#     end_index: 80
# 37. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: Operation
#     operator: 44
#     operands: 43
# 38. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. {element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: NamedExprs
#     element: 46
#     targets: 52
# 40. {element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: NamedExprs
#     element: 47
#     targets: 54
# 41. _a -> A_{_b, _a}
#     core type: Lambda
#     parameter: 72
#     body: 48
# 42. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 72
#     body: 50
# 43. {element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: NamedExprs
#     element: 51
#     targets: 52
# 44. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 45. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: NamedExprs
#     element: 53
#     targets: 54
# 46. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 56
#     operands: 55
# 47. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 56
#     operands: 64
# 48. A_{_b, _a}
#     core type: IndexedVar
# variable: 57
# indices: 58
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 50. [GATE]{operation:I}
#     core type: Operation
#     operator: 59
#     operands: 60
# 51. [OUTPUT]{state:|v>, part:_a}
#     core type: Operation
#     operator: 63
#     operands: 61
# 52. {1 .. l}
#     core type: Operation
#     operator: 65
#     operands: 62
# 53. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 54. {l + 1 .. l + m}
#     core type: Operation
#     operator: 65
#     operands: 66
# 55. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 67
#     part: 72
# 56. INPUT
#     core type: Literal
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 68, 72
# 59. GATE
#     core type: Literal
#     sub-expressions:
# 60. {operation:I}
#     core type: NamedExprs
#     operation: 69
# 61. {state:|v>, part:_a}
#     core type: NamedExprs
#     state: 70
#     part: 72
# 62. (1, l)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 63. OUTPUT
#     core type: Literal
#     sub-expressions:
# 64. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 71
#     part: 72
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (l + 1, l + m)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 67. |u>
#     core type: Variable
#     sub-expressions:
# 68. _b
#     core type: Variable
#     sub-expressions:
# 69. I
#     core type: Literal
#     sub-expressions:
# 70. |v>
#     core type: Variable
#     sub-expressions:
# 71. |psi>
#     core type: Variable
#     sub-expressions:
# 72. _a
#     core type: Variable
#     sub-expressions:
# 73. l + 1
#     core type: Operation
#     operator: 76
#     operands: 75
# 74. l + m
#     core type: Operation
#     operator: 76
#     operands: 77
# 75. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 79, 78
# 76. +
#     core type: Literal
#     sub-expressions:
# 77. (l, m)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. l
#     core type: Variable
#     sub-expressions:
# 80. m
#     core type: Variable
#     sub-expressions:
