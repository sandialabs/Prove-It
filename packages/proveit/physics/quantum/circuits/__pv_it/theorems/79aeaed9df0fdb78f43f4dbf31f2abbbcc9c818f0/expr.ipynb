# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Abs, Exp, two
from proveit.physics.quantum import NumBra, Qmult, m_ket_domain, normalized_var_ket_psi, var_ket_psi
from proveit.physics.quantum.circuits import register_meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Prob(register_meas), Exp(Abs(Qmult(NumBra(n, m), var_ket_psi)), two)), And(InSet(var_ket_psi, m_ket_domain), normalized_var_ket_psi))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \psi \rangle} & \meter & \multiqout{3}{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \measure{\begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert n \rangle_{m}} \\
# \ghostqin{\lvert \psi \rangle} & \meter & \ghostqout{\lvert n \rangle_{m}}
# } \end{array}\right) = \left|{_{m}}\langle n \rvert \thinspace \lvert \psi \rangle\right|^{2} \textrm{ if } \lvert \psi \rangle \in \mathbb{C}^{2^{m}} ,  \left \|\lvert \psi \rangle\right \| = 1\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2} if |psi> in Complex^{2^{m}} ,  |||psi>|| = 1.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))) = |{m}_〈n| . |psi>|^{2}
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (|psi> in Complex^{2^{m}}) and (|||psi>|| = 1)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))), |{m}_〈n| . |psi>|^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|psi> in Complex^{2^{m}}, |||psi>|| = 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. Pr(QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#    core type: Operation
#    operator: 10
#    operand: 17
# 7. |{m}_〈n| . |psi>|^{2}
#    core type: Operation
#    operator: 40
#    operands: 12
# 8. |psi> in Complex^{2^{m}}
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. |||psi>|| = 1
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. Pr
#     core type: Literal
#     sub-expressions:
# 11. (QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))))
#     core type: ExprTuple
#     sub-expressions: 17
# 12. (|{m}_〈n| . |psi>|, 2)
#     core type: ExprTuple
#     sub-expressions: 18, 46
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (|psi>, Complex^{2^{m}})
#     core type: ExprTuple
#     sub-expressions: 67, 19
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (|||psi>||, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 70
# 17. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})))
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. |{m}_〈n| . |psi>|
#     core type: Operation
#     operator: 23
#     operand: 32
# 19. Complex^{2^{m}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. |||psi>||
#     core type: Operation
#     operator: 27
#     operand: 67
# 21. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 22. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}))
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31
# 23. Abs
#     core type: Literal
#     sub-expressions:
# 24. ({m}_〈n| . |psi>)
#     core type: ExprTuple
#     sub-expressions: 32
# 25. CartExp
#     core type: Literal
#     sub-expressions:
# 26. (Complex, 2^{m})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 27. Abs
#     core type: Literal
#     sub-expressions:
# 28. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 67
# 29. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 35
# 30. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z})
#     core type: ExprTuple
#     sub-expressions: 36
# 31. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. {m}_〈n| . |psi>
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. Complex
#     core type: Literal
#     sub-expressions:
# 34. 2^{m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 70
#     end_index: 74
# 36. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(m - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 70
#     end_index: 74
# 37. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:1}, targets:{1 .. m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:2}, targets:{1 .. m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:m}, targets:{1 .. m}}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 70
#     end_index: 74
# 38. .
#     core type: Literal
#     sub-expressions:
# 39. ({m}_〈n|, |psi>)
#     core type: ExprTuple
#     sub-expressions: 45, 67
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (2, m)
#     core type: ExprTuple
#     sub-expressions: 46, 74
# 42. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 69
#     body: 47
# 43. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 69
#     body: 48
# 44. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Lambda
#     parameter: 69
#     body: 50
# 45. {m}_〈n|
#     core type: Operation
#     operator: 51
#     operands: 72
# 46. 2
#     core type: Literal
#     sub-expressions:
# 47. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 55
#     operands: 52
# 48. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 50. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 52. {element:[INPUT]{state:|psi>, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 57
#     targets: 60
# 53. MEASURE
#     core type: Literal
#     sub-expressions:
# 54. {basis:Z}
#     core type: NamedExprs
#     basis: 58
# 55. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 56. {element:[OUTPUT]{state:|n〉_{m}, part:_a}, targets:{1 .. m}}
#     core type: NamedExprs
#     element: 59
#     targets: 60
# 57. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. Z
#     core type: Literal
#     sub-expressions:
# 59. [OUTPUT]{state:|n〉_{m}, part:_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. {1 .. m}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. INPUT
#     core type: Literal
#     sub-expressions:
# 62. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 67
#     part: 69
# 63. OUTPUT
#     core type: Literal
#     sub-expressions:
# 64. {state:|n〉_{m}, part:_a}
#     core type: NamedExprs
#     state: 68
#     part: 69
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (1, m)
#     core type: ExprTuple
#     sub-expressions: 70, 74
# 67. |psi>
#     core type: Variable
#     sub-expressions:
# 68. |n〉_{m}
#     core type: Operation
#     operator: 71
#     operands: 72
# 69. _a
#     core type: Variable
#     sub-expressions:
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. NUM_KET
#     core type: Literal
#     sub-expressions:
# 72. (n, m)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 73. n
#     core type: Variable
#     sub-expressions:
# 74. m
#     core type: Variable
#     sub-expressions:
