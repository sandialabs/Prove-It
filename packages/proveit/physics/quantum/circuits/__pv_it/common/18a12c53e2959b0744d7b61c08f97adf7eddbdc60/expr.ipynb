# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, m
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1, var_ket_u, varphi
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, varphi)), ket1)))), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_u, part = sub_expr1), targets = Interval(two, Add(m, two))), one, Add(m, one)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~m + 1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#    core type: Operation
#    operator: 20
#    operands: 3
# 2. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 49
#    end_index: 5
# 3. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#    core type: NamedExprs
#    state: 6
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#    core type: Lambda
#    parameter: 28
#    body: 8
# 5. m + 1
#    core type: Operation
#    operator: 34
#    operands: 9
# 6. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#    core type: Operation
#    operator: 32
#    operands: 10
# 7. (_a)
#    core type: ExprTuple
#    sub-expressions: 28
# 8. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (m, 1)
#    core type: ExprTuple
#    sub-expressions: 40, 49
# 10. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 12. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 15
#     targets: 16
# 13. 1 / sqrt(2)
#     core type: Operation
#     operator: 41
#     operands: 17
# 14. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. {2 .. m + 2}
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 49, 24
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. OUTPUT
#     core type: Literal
#     sub-expressions:
# 21. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 27
#     part: 28
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 52, 29
# 24. sqrt(2)
#     core type: Operation
#     operator: 43
#     operands: 30
# 25. |0〉
#     core type: Operation
#     operator: 45
#     operand: 37
# 26. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. |u>
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
# 29. m + 2
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 52, 36
# 31. (0)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 40, 52
# 36. 1 / 2
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. |1〉
#     core type: Operation
#     operator: 45
#     operand: 49
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. /
#     core type: Literal
#     sub-expressions:
# 42. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 49, 52
# 43. Exp
#     core type: Literal
#     sub-expressions:
# 44. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. KET
#     core type: Literal
#     sub-expressions:
# 46. (1)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. e
#     core type: Literal
#     sub-expressions:
# 48. 2 * pi * i * varphi
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 52, 53, 54, 55
# 52. 2
#     core type: Literal
#     sub-expressions:
# 53. pi
#     core type: Literal
#     sub-expressions:
# 54. i
#     core type: Literal
#     sub-expressions:
# 55. varphi
#     core type: Variable
#     sub-expressions:
