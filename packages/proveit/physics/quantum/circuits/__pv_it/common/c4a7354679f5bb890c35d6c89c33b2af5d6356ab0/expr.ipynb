# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.VertExprArray.html">VertExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, U, Variable, VertExprArray, m
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Set
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import CONTROL, ket0, ket1, ket_plus, var_ket_u, varphi
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(m, one)
sub_expr3 = Interval(two, Add(m, two))
expr = VertExprArray([Input(state = ket_plus), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = var_ket_u, part = sub_expr1), targets = sub_expr3), one, sub_expr2)], [MultiQubitElem(element = CONTROL, targets = Set(two)), ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = U, part = sub_expr1), targets = sub_expr3), one, sub_expr2)], [Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, varphi)), ket1)))), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_u, part = sub_expr1), targets = sub_expr3), one, sub_expr2)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{ccc}
#  \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{2\right\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array} \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U~\mbox{part}~1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array} \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U~\mbox{part}~2~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array} \\
# \vdots & \vdots & \vdots \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~m + 1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U~\mbox{part}~m + 1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~m + 1~\mbox{on}~\{2~\ldotp \ldotp~m + 2\}}
# } \end{array} \\
# \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 2. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 3. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 4. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 41
#    operands: 10
# 5. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 77
#    end_index: 16
# 6. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#    core type: Operation
#    operator: 32
#    operands: 12
# 7. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 77
#    end_index: 16
# 8. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#    core type: Operation
#    operator: 47
#    operands: 14
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 77
#    end_index: 16
# 10. {state:|+〉}
#     core type: NamedExprs
#     state: 17
# 11. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 56
#     body: 18
# 12. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 19
#     targets: 20
# 13. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 56
#     body: 21
# 14. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 22
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 56
#     body: 24
# 16. m + 1
#     core type: Operation
#     operator: 62
#     operands: 25
# 17. |+〉
#     core type: Operation
#     operator: 73
#     operand: 34
# 18. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 32
#     operands: 27
# 19. CONTROL
#     core type: Literal
#     sub-expressions:
# 20. {2}
#     core type: Operation
#     operator: 28
#     operand: 80
# 21. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 32
#     operands: 30
# 22. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 60
#     operands: 31
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 24. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 25. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 68, 77
# 26. (+)
#     core type: ExprTuple
#     sub-expressions: 34
# 27. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 35
#     targets: 40
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (2)
#     core type: ExprTuple
#     sub-expressions: 80
# 30. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 36
#     targets: 40
# 31. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 32. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 33. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 39
#     targets: 40
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 41
#     operands: 48
# 36. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. 1 / sqrt(2)
#     core type: Operation
#     operator: 69
#     operands: 44
# 38. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 45
#     operands: 46
# 39. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 40. {2 .. m + 2}
#     core type: Operation
#     operator: 49
#     operands: 50
# 41. INPUT
#     core type: Literal
#     sub-expressions:
# 42. GATE
#     core type: Literal
#     sub-expressions:
# 43. {operation:U, part:_a}
#     core type: NamedExprs
#     operation: 51
#     part: 56
# 44. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 77, 52
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 47. OUTPUT
#     core type: Literal
#     sub-expressions:
# 48. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 55
#     part: 56
# 49. Interval
#     core type: Literal
#     sub-expressions:
# 50. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 80, 57
# 51. U
#     core type: Variable
#     sub-expressions:
# 52. sqrt(2)
#     core type: Operation
#     operator: 71
#     operands: 58
# 53. |0〉
#     core type: Operation
#     operator: 73
#     operand: 65
# 54. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. |u>
#     core type: Variable
#     sub-expressions:
# 56. _a
#     core type: Variable
#     sub-expressions:
# 57. m + 2
#     core type: Operation
#     operator: 62
#     operands: 63
# 58. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 80, 64
# 59. (0)
#     core type: ExprTuple
#     sub-expressions: 65
# 60. *
#     core type: Literal
#     sub-expressions:
# 61. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 68, 80
# 64. 1 / 2
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. 0
#     core type: Literal
#     sub-expressions:
# 66. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 71
#     operands: 72
# 67. |1〉
#     core type: Operation
#     operator: 73
#     operand: 77
# 68. m
#     core type: Variable
#     sub-expressions:
# 69. /
#     core type: Literal
#     sub-expressions:
# 70. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 77, 80
# 71. Exp
#     core type: Literal
#     sub-expressions:
# 72. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. KET
#     core type: Literal
#     sub-expressions:
# 74. (1)
#     core type: ExprTuple
#     sub-expressions: 77
# 75. e
#     core type: Literal
#     sub-expressions:
# 76. 2 * pi * i * varphi
#     core type: Operation
#     operator: 78
#     operands: 79
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 80, 81, 82, 83
# 80. 2
#     core type: Literal
#     sub-expressions:
# 81. pi
#     core type: Literal
#     sub-expressions:
# 82. i
#     core type: Literal
#     sub-expressions:
# 83. varphi
#     core type: Variable
#     sub-expressions:
