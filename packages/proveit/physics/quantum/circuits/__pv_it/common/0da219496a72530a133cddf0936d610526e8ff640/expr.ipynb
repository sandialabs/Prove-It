# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.physics.quantum.circuits.Qcircuit.html">Qcircuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, U, Variable, VertExprArray, m
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Set
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import CONTROL, ket0, ket1, ket_plus, var_ket_u, varphi
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(m, one)
sub_expr3 = Interval(two, Add(m, two))
expr = Qcircuit(vert_expr_array = VertExprArray([Input(state = ket_plus), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = var_ket_u, part = sub_expr1), targets = sub_expr3), one, sub_expr2)], [MultiQubitElem(element = CONTROL, targets = Set(two)), ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = U, part = sub_expr1), targets = sub_expr3), one, sub_expr2)], [Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, varphi)), ket1)))), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_u, part = sub_expr1), targets = sub_expr3), one, sub_expr2)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U} & \qout{\lvert u \rangle}
# } \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. VertExprArray(([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}),  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. ([INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 5. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 6. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 43
#    operands: 12
# 7. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 79
#    end_index: 18
# 8. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{2}}
#    core type: Operation
#    operator: 34
#    operands: 14
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:(m + 1)}, targets:{2 .. m + 2}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 79
#    end_index: 18
# 10. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: Operation
#     operator: 49
#     operands: 16
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{2 .. m + 2}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{2 .. m + 2}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:(m + 1)}, targets:{2 .. m + 2}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 79
#     end_index: 18
# 12. {state:|+〉}
#     core type: NamedExprs
#     state: 19
# 13. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 58
#     body: 20
# 14. {element:CONTROL, targets:{2}}
#     core type: NamedExprs
#     element: 21
#     targets: 22
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 58
#     body: 23
# 16. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉)))}
#     core type: NamedExprs
#     state: 24
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Lambda
#     parameter: 58
#     body: 26
# 18. m + 1
#     core type: Operation
#     operator: 64
#     operands: 27
# 19. |+〉
#     core type: Operation
#     operator: 75
#     operand: 36
# 20. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 34
#     operands: 29
# 21. CONTROL
#     core type: Literal
#     sub-expressions:
# 22. {2}
#     core type: Operation
#     operator: 30
#     operand: 82
# 23. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 34
#     operands: 32
# 24. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: Operation
#     operator: 62
#     operands: 33
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 70, 79
# 28. (+)
#     core type: ExprTuple
#     sub-expressions: 36
# 29. {element:[INPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 37
#     targets: 42
# 30. Set
#     core type: Literal
#     sub-expressions:
# 31. (2)
#     core type: ExprTuple
#     sub-expressions: 82
# 32. {element:[GATE]{operation:U, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 38
#     targets: 42
# 33. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 35. {element:[OUTPUT]{state:|u>, part:_a}, targets:{2 .. m + 2}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 43
#     operands: 50
# 38. [GATE]{operation:U, part:_a}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. 1 / sqrt(2)
#     core type: Operation
#     operator: 71
#     operands: 46
# 40. |0〉 + (e^{2 * pi * i * varphi} * |1〉)
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 49
#     operands: 50
# 42. {2 .. m + 2}
#     core type: Operation
#     operator: 51
#     operands: 52
# 43. INPUT
#     core type: Literal
#     sub-expressions:
# 44. GATE
#     core type: Literal
#     sub-expressions:
# 45. {operation:U, part:_a}
#     core type: NamedExprs
#     operation: 53
#     part: 58
# 46. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 79, 54
# 47. +
#     core type: Literal
#     sub-expressions:
# 48. (|0〉, e^{2 * pi * i * varphi} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 49. OUTPUT
#     core type: Literal
#     sub-expressions:
# 50. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 57
#     part: 58
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (2, m + 2)
#     core type: ExprTuple
#     sub-expressions: 82, 59
# 53. U
#     core type: Variable
#     sub-expressions:
# 54. sqrt(2)
#     core type: Operation
#     operator: 73
#     operands: 60
# 55. |0〉
#     core type: Operation
#     operator: 75
#     operand: 67
# 56. e^{2 * pi * i * varphi} * |1〉
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. |u>
#     core type: Variable
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. m + 2
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 82, 66
# 61. (0)
#     core type: ExprTuple
#     sub-expressions: 67
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (e^{2 * pi * i * varphi}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (m, 2)
#     core type: ExprTuple
#     sub-expressions: 70, 82
# 66. 1 / 2
#     core type: Operation
#     operator: 71
#     operands: 72
# 67. 0
#     core type: Literal
#     sub-expressions:
# 68. e^{2 * pi * i * varphi}
#     core type: Operation
#     operator: 73
#     operands: 74
# 69. |1〉
#     core type: Operation
#     operator: 75
#     operand: 79
# 70. m
#     core type: Variable
#     sub-expressions:
# 71. /
#     core type: Literal
#     sub-expressions:
# 72. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 79, 82
# 73. Exp
#     core type: Literal
#     sub-expressions:
# 74. (e, 2 * pi * i * varphi)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. KET
#     core type: Literal
#     sub-expressions:
# 76. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 77. e
#     core type: Literal
#     sub-expressions:
# 78. 2 * pi * i * varphi
#     core type: Operation
#     operator: 80
#     operands: 81
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. *
#     core type: Literal
#     sub-expressions:
# 81. (2, pi, i, varphi)
#     core type: ExprTuple
#     sub-expressions: 82, 83, 84, 85
# 82. 2
#     core type: Literal
#     sub-expressions:
# 83. pi
#     core type: Literal
#     sub-expressions:
# 84. i
#     core type: Literal
#     sub-expressions:
# 85. varphi
#     core type: Variable
#     sub-expressions:
