# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, m, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1, var_ket_u, varphi
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, IndexedVar(varphi, sub_expr1))), ket1)))), one, t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_u, part = sub_expr1), targets = Interval(Add(t, one), Add(t, m))), one, m))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{1}} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{2}} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi_{t}} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~m~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{1}} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{2}} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{t}} * |1〉)))}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 50
#    end_index: 32
# 2. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:m}, targets:{t + 1 .. t + m}}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 50
#    end_index: 33
# 3. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#    core type: Lambda
#    parameter: 59
#    body: 5
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#    core type: Lambda
#    parameter: 59
#    body: 6
# 5. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#    core type: Operation
#    operator: 14
#    operands: 7
# 6. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)))}
#    core type: NamedExprs
#    state: 10
# 8. MULTI_QUBIT_ELEM
#    core type: Literal
#    sub-expressions:
# 9. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + m}}
#    core type: NamedExprs
#    element: 11
#    targets: 12
# 10. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: Operation
#     operator: 36
#     operands: 13
# 11. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {t + 1 .. t + m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. OUTPUT
#     core type: Literal
#     sub-expressions:
# 15. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 20
#     part: 59
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (t + 1, t + m)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. 1 / sqrt(2)
#     core type: Operation
#     operator: 42
#     operands: 23
# 19. |0〉 + (e^{2 * pi * i * varphi_{_a}} * |1〉)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. |u>
#     core type: Variable
#     sub-expressions:
# 21. t + 1
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. t + m
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 50, 29
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (|0〉, e^{2 * pi * i * varphi_{_a}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 50
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (t, m)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. sqrt(2)
#     core type: Operation
#     operator: 44
#     operands: 34
# 30. |0〉
#     core type: Operation
#     operator: 46
#     operand: 39
# 31. e^{2 * pi * i * varphi_{_a}} * |1〉
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. t
#     core type: Variable
#     sub-expressions:
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 53, 38
# 35. (0)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. *
#     core type: Literal
#     sub-expressions:
# 37. (e^{2 * pi * i * varphi_{_a}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. 1 / 2
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. e^{2 * pi * i * varphi_{_a}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. |1〉
#     core type: Operation
#     operator: 46
#     operand: 50
# 42. /
#     core type: Literal
#     sub-expressions:
# 43. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 50, 53
# 44. Exp
#     core type: Literal
#     sub-expressions:
# 45. (e, 2 * pi * i * varphi_{_a})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (1)
#     core type: ExprTuple
#     sub-expressions: 50
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * varphi_{_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (2, pi, i, varphi_{_a})
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55, 56
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. pi
#     core type: Literal
#     sub-expressions:
# 55. i
#     core type: Literal
#     sub-expressions:
# 56. varphi_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. varphi
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
