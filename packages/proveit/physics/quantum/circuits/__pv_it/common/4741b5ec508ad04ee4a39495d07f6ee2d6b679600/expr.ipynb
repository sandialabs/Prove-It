# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, IndexedVar, U, Variable, m, t
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import CONTROL, I
from proveit.physics.quantum.circuits import Gate, MultiQubitElem

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr3 = Add(t, one)
expr = ExprRange(sub_expr1, [ExprRange(sub_expr2, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr1, sub_expr2)), Conditional(Gate(operation = I).with_implicit_representation(), NotEquals(sub_expr1, sub_expr2))), one, t).with_case_simplification(), ExprRange(sub_expr2, MultiQubitElem(element = Gate(operation = IndexedVar(U, sub_expr1), part = sub_expr2), targets = Interval(sub_expr3, Add(t, m))), one, m)], one, t).with_case_simplification()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{1}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{1}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{1}~\mbox{part}~m~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{2}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{2}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{2}~\mbox{part}~m~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}\right), \ldots, \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{t}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{t}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U_{t}~\mbox{part}~m~\mbox{on}~\{t + 1~\ldotp \ldotp~t + m\}} & \qw
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')
# style name: front_expansion
# description: The number of instances to display at the front of the range (e.g., before the ellipsis). Default is 2.
# default: 2
# current value: 2
# related methods: ('with_front_expansion', 'get_front_expansion')
# style name: back_expansion
# description: The number of instances to display at the back of the range (e.g., after the ellipsis). Default is 1.
# default: 1
# current value: 1
# related methods: ('with_back_expansion', 'get_back_expansion')
# style name: order
# description: The default order is 'increasing' (a_1 ... a_3) but to represent a 'decreasing' ExprRange (a_6 ... a_2) the order must be set to 'decreasing'
# default: increasing
# current value: increasing
# related methods: ('with_decreasing_order', 'with_increasing_order')
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: case_simplify
# description: If 'True', simplify formatted instances that are ConditionalSets under proper index assumptions
# default: False
# current value: True
# related methods: ('with_case_simplification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{1}, part:m}, targets:{t + 1 .. t + m}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{2}, part:m}, targets:{t + 1 .. t + m}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{t}, part:m}, targets:{t + 1 .. t + m}})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 48
#    end_index: 47
# 1. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 1; [GATE]{operation:I} if _b != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = 2; [GATE]{operation:I} if _b != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = t; [GATE]{operation:I} if _b != t.
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 48
#    end_index: 47
# 4. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:1}, targets:{t + 1 .. t + m}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:2}, targets:{t + 1 .. t + m}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:m}, targets:{t + 1 .. t + m}}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 48
#    end_index: 43
# 5. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#    core type: Lambda
#    parameter: 36
#    body: 7
# 6. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#    core type: Lambda
#    parameter: 36
#    body: 9
# 7. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a; [GATE]{operation:I} if _b != _a.
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (_a)
#    core type: ExprTuple
#    sub-expressions: 36
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#    core type: Operation
#    operator: 24
#    operands: 12
# 10. CondSet
#     core type: Literal
#     sub-expressions:
# 11. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a, [GATE]{operation:I} if _b != _a)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. {element:[GATE]{operation:U_{_b}, part:_a}, targets:{t + 1 .. t + m}}
#     core type: NamedExprs
#     element: 15
#     targets: 16
# 13. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if _b = _a.
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. {[GATE]{operation:I} if _b != _a.
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. [GATE]{operation:U_{_b}, part:_a}
#     core type: Operation
#     operator: 27
#     operands: 21
# 16. {t + 1 .. t + m}
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 24
#     operands: 25
# 18. _b = _a
#     core type: Operation
#     operator: 26
#     operands: 30
# 19. [GATE]{operation:I}
#     core type: Operation
#     operator: 27
#     operands: 28
# 20. _b != _a
#     core type: Operation
#     operator: 29
#     operands: 30
# 21. {operation:U_{_b}, part:_a}
#     core type: NamedExprs
#     operation: 31
#     part: 36
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (t + 1, t + m)
#     core type: ExprTuple
#     sub-expressions: 44, 32
# 24. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 25. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 33
#     targets: 34
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. GATE
#     core type: Literal
#     sub-expressions:
# 28. {operation:I}
#     core type: NamedExprs
#     operation: 35
# 29. !=
#     core type: Literal
#     sub-expressions:
# 30. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 31. U_{_b}
#     core type: IndexedVar
# variable: 37
# index: 42
# 32. t + m
#     core type: Operation
#     operator: 45
#     operands: 39
# 33. CONTROL
#     core type: Literal
#     sub-expressions:
# 34. {t + 1}
#     core type: Operation
#     operator: 40
#     operand: 44
# 35. I
#     core type: Literal
#     sub-expressions:
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. U
#     core type: Variable
#     sub-expressions:
# 38. (_b)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. (t, m)
#     core type: ExprTuple
#     sub-expressions: 47, 43
# 40. Set
#     core type: Literal
#     sub-expressions:
# 41. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. _b
#     core type: Variable
#     sub-expressions:
# 43. m
#     core type: Variable
#     sub-expressions:
# 44. t + 1
#     core type: Operation
#     operator: 45
#     operands: 46
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 47. t
#     core type: Variable
#     sub-expressions:
# 48. 1
#     core type: Literal
#     sub-expressions:
