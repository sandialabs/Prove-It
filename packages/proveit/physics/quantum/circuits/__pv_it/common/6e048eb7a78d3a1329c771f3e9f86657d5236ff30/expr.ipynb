# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.VertExprArray.html">VertExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprRange, IndexedVar, Variable, VertExprArray, k, l, m
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import I, var_ket_psi, var_ket_u, var_ket_v
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = Interval(one, l)
sub_expr4 = Interval(Add(l, one), Add(l, m))
expr = VertExprArray([ExprRange(sub_expr1, MultiQubitElem(element = Input(state = var_ket_u, part = sub_expr1), targets = sub_expr3), one, l), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = var_ket_psi, part = sub_expr1), targets = sub_expr4), one, m)], ExprRange(sub_expr2, [ExprRange(sub_expr1, IndexedVar(A, [sub_expr2, sub_expr1]), one, l), ExprRange(sub_expr1, Gate(operation = I).with_implicit_representation(), one, m)], one, k), [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_v, part = sub_expr1), targets = sub_expr3), one, l), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_psi, part = sub_expr1), targets = sub_expr4), one, m)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{cccccc}
#  \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~l\}} & \qw
# } \end{array} & A_{1, 1} & A_{2, 1} & \cdots & A_{k, 1} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert v \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~l\}}
# } \end{array} \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~l\}} & \qw
# } \end{array} & A_{1, 2} & A_{2, 2} & \cdots & A_{k, 2} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert v \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~l\}}
# } \end{array} \\
# \vdots & \vdots & \vdots & \ddots & \vdots & \vdots \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~l~\mbox{on}~\{1~\ldotp \ldotp~l\}} & \qw
# } \end{array} & A_{1, l} & A_{2, l} & \cdots & A_{k, l} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert v \rangle~\mbox{part}~l~\mbox{on}~\{1~\ldotp \ldotp~l\}}
# } \end{array} \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi \rangle~\mbox{part}~1~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \cdots & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi \rangle~\mbox{part}~1~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}}
# } \end{array} \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi \rangle~\mbox{part}~2~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \cdots & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi \rangle~\mbox{part}~2~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}}
# } \end{array} \\
# \vdots & \begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array} & \begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array} & \ddots & \begin{array}{c}:\\ \left(m - 3\right) \times \\:\end{array} & \vdots \\
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi \rangle~\mbox{part}~m~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}} & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \cdots & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} & \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi \rangle~\mbox{part}~m~\mbox{on}~\{l + 1~\ldotp \ldotp~l + m\}}
# } \end{array} \\
# \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}), \\ (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}),  \\ (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 2. (A_{1, 1}, A_{1, 2}, ..., A_{1, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 61
#    end_index: 7
# 3. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 4. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:l}, targets:{1 .. l}}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 61
#    end_index: 62
# 5. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 61
#    end_index: 63
# 6. _b -> (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#    core type: Lambda
#    parameter: 51
#    body: 13
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:1}, targets:{1 .. l}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:2}, targets:{1 .. l}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:l}, targets:{1 .. l}}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 61
#    end_index: 62
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:1}, targets:{l + 1 .. l + m}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:2}, targets:{l + 1 .. l + m}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:m}, targets:{l + 1 .. l + m}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 61
#    end_index: 63
# 10. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: Lambda
#     parameter: 55
#     body: 16
# 11. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Lambda
#     parameter: 55
#     body: 17
# 12. (_b)
#     core type: ExprTuple
#     sub-expressions: 51
# 13. (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l},[GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: Lambda
#     parameter: 55
#     body: 20
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Lambda
#     parameter: 55
#     body: 21
# 16. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: Operation
#     operator: 27
#     operands: 22
# 17. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Operation
#     operator: 27
#     operands: 23
# 18. A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 61
#     end_index: 62
# 19. [GATE]{operation:I}, [GATE]{operation:I}, ..(m - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 61
#     end_index: 63
# 20. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. {element:[INPUT]{state:|u>, part:_a}, targets:{1 .. l}}
#     core type: NamedExprs
#     element: 29
#     targets: 35
# 23. {element:[INPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: NamedExprs
#     element: 30
#     targets: 37
# 24. _a -> A_{_b, _a}
#     core type: Lambda
#     parameter: 55
#     body: 31
# 25. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 55
#     body: 33
# 26. {element:[OUTPUT]{state:|v>, part:_a}, targets:{1 .. l}}
#     core type: NamedExprs
#     element: 34
#     targets: 35
# 27. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 28. {element:[OUTPUT]{state:|psi>, part:_a}, targets:{l + 1 .. l + m}}
#     core type: NamedExprs
#     element: 36
#     targets: 37
# 29. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 39
#     operands: 38
# 30. [INPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 39
#     operands: 47
# 31. A_{_b, _a}
#     core type: IndexedVar
# variable: 40
# indices: 41
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 33. [GATE]{operation:I}
#     core type: Operation
#     operator: 42
#     operands: 43
# 34. [OUTPUT]{state:|v>, part:_a}
#     core type: Operation
#     operator: 46
#     operands: 44
# 35. {1 .. l}
#     core type: Operation
#     operator: 48
#     operands: 45
# 36. [OUTPUT]{state:|psi>, part:_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 37. {l + 1 .. l + m}
#     core type: Operation
#     operator: 48
#     operands: 49
# 38. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 50
#     part: 55
# 39. INPUT
#     core type: Literal
#     sub-expressions:
# 40. A
#     core type: Variable
#     sub-expressions:
# 41. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 51, 55
# 42. GATE
#     core type: Literal
#     sub-expressions:
# 43. {operation:I}
#     core type: NamedExprs
#     operation: 52
# 44. {state:|v>, part:_a}
#     core type: NamedExprs
#     state: 53
#     part: 55
# 45. (1, l)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 46. OUTPUT
#     core type: Literal
#     sub-expressions:
# 47. {state:|psi>, part:_a}
#     core type: NamedExprs
#     state: 54
#     part: 55
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (l + 1, l + m)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 50. |u>
#     core type: Variable
#     sub-expressions:
# 51. _b
#     core type: Variable
#     sub-expressions:
# 52. I
#     core type: Literal
#     sub-expressions:
# 53. |v>
#     core type: Variable
#     sub-expressions:
# 54. |psi>
#     core type: Variable
#     sub-expressions:
# 55. _a
#     core type: Variable
#     sub-expressions:
# 56. l + 1
#     core type: Operation
#     operator: 59
#     operands: 58
# 57. l + m
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 59. +
#     core type: Literal
#     sub-expressions:
# 60. (l, m)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. l
#     core type: Variable
#     sub-expressions:
# 63. m
#     core type: Variable
#     sub-expressions:
