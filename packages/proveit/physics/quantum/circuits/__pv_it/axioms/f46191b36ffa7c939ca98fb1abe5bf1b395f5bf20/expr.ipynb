# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.circuits</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k, l
from proveit.core_expr_types.expr_arrays import A11_to_Akl, A11_to_Akl_varray, B11_to_Bkl, B11_to_Bkl_varray
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.circuits import circuit_Akl, circuit_Bkl

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [A11_to_Akl, B11_to_Bkl], instance_expr = Equals(Equals(circuit_Akl, circuit_Bkl), Equals(A11_to_Akl_varray, B11_to_Bkl_varray)).with_wrapping_at(2)).with_wrapping(), And(InSet(k, NaturalPos), InSet(l, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{A_{1, 1}, A_{1, 2}, \ldots, A_{1, l}, A_{2, 1}, A_{2, 2}, \ldots, A_{2, l}, \ldots\ldots, A_{k, 1}, A_{k, 2}, \ldots, A_{k, l}, B_{1, 1}, B_{1, 2}, \ldots, B_{1, l}, B_{2, 1}, B_{2, 2}, \ldots, B_{2, l}, \ldots\ldots, B_{k, 1}, B_{k, 2}, \ldots, B_{k, l}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}} \qwx[1] & \gate{A_{2, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 1}} \qwx[1] & \qw \\
# & \gate{A_{1, 2}} \qwx[1] & \gate{A_{2, 2}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{k, 2}} \qwx[1] & \qw \\
# & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} \qwx[1] & \qw \\
# & \gate{A_{1, l}} & \gate{A_{2, l}} & \gate{\cdots} & \gate{A_{k, l}} & \qw
# } \end{array}\right) = \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}} \qwx[1] & \gate{B_{2, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{k, 1}} \qwx[1] & \qw \\
# & \gate{B_{1, 2}} \qwx[1] & \gate{B_{2, 2}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{k, 2}} \qwx[1] & \qw \\
# & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} \qwx[1] & \qw \\
# & \gate{B_{1, l}} & \gate{B_{2, l}} & \gate{\cdots} & \gate{B_{k, l}} & \qw
# } \end{array}\right)\right) =  \\ \left(\left(\begin{array}{cccc}
#  A_{1, 1} & A_{2, 1} & \cdots & A_{k, 1} \\
# A_{1, 2} & A_{2, 2} & \cdots & A_{k, 2} \\
# \vdots & \vdots & \ddots & \vdots \\
# A_{1, l} & A_{2, l} & \cdots & A_{k, l} \\
# \end{array}
# \right) = \left(\begin{array}{cccc}
#  B_{1, 1} & B_{2, 1} & \cdots & B_{k, 1} \\
# B_{1, 2} & B_{2, 2} & \cdots & B_{k, 2} \\
# \vdots & \vdots & \ddots & \vdots \\
# B_{1, l} & B_{2, l} & \cdots & B_{k, l} \\
# \end{array}
# \right)\right) \end{array} \end{array}\right)\end{array} \textrm{ if } k \in \mathbb{N}^+ ,  l \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l}, B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l}} ((QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) =  \\ (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) if k in NaturalPos ,  l in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l}, B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l}} ((QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) =  \\ (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (k in NaturalPos) and (l in NaturalPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l}, B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l}) -> ((QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) =  \\ (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (k in NaturalPos, l in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l}, B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l}) -> ((QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) =  \\ (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))))
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. k in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. l in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l},B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. (QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))) =  \\ (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))
#     core type: Operation
#     operator: 24
#     operands: 17
# 12. (k, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 35, 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 44, 18
# 15. A_{1, 1}, A_{1, 2}, ..., A_{1, l}, A_{2, 1}, A_{2, 2}, ..., A_{2, l}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, l}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 43
#     end_index: 35
# 16. B_{1, 1}, B_{1, 2}, ..., B_{1, l}, B_{2, 1}, B_{2, 2}, ..., B_{2, l}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, l}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 43
#     end_index: 35
# 17. (QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))), VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. _b -> A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l}
#     core type: Lambda
#     parameter: 51
#     body: 39
# 20. _b -> B_{_b, 1}, B_{_b, 2}, ..., B_{_b, l}
#     core type: Lambda
#     parameter: 51
#     body: 40
# 21. QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))) = QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))
#     core type: Operation
#     operator: 24
#     operands: 23
# 22. VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})) = VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))), QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})), VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 26. QCIRCUIT(VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})))
#     core type: Operation
#     operator: 29
#     operands: 28
# 27. QCIRCUIT(VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})))
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. VertExprArray((A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l}))
#     core type: ExprTuple
#     sub-expressions: 31
# 29. QCIRCUIT
#     core type: Literal
#     sub-expressions:
# 30. VertExprArray((B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l}))
#     core type: ExprTuple
#     sub-expressions: 32
# 31. (A_{1, 1}, A_{1, 2}, ..., A_{1, l}), (A_{2, 1}, A_{2, 2}, ..., A_{2, l}), ..., (A_{k, 1}, A_{k, 2}, ..., A_{k, l})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 43
#     end_index: 35
# 32. (B_{1, 1}, B_{1, 2}, ..., B_{1, l}), (B_{2, 1}, B_{2, 2}, ..., B_{2, l}), ..., (B_{k, 1}, B_{k, 2}, ..., B_{k, l})
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 43
#     end_index: 35
# 33. _b -> (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l})
#     core type: Lambda
#     parameter: 51
#     body: 36
# 34. _b -> (B_{_b, 1}, B_{_b, 2}, ..., B_{_b, l})
#     core type: Lambda
#     parameter: 51
#     body: 38
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. (A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l})
#     core type: ExprTuple
#     sub-expressions: 39
# 37. (_b)
#     core type: ExprTuple
#     sub-expressions: 51
# 38. (B_{_b, 1}, B_{_b, 2}, ..., B_{_b, l})
#     core type: ExprTuple
#     sub-expressions: 40
# 39. A_{_b, 1}, A_{_b, 2}, ..., A_{_b, l}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 43
#     end_index: 44
# 40. B_{_b, 1}, B_{_b, 2}, ..., B_{_b, l}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 43
#     end_index: 44
# 41. _a -> A_{_b, _a}
#     core type: Lambda
#     parameter: 52
#     body: 45
# 42. _a -> B_{_b, _a}
#     core type: Lambda
#     parameter: 52
#     body: 47
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. l
#     core type: Variable
#     sub-expressions:
# 45. A_{_b, _a}
#     core type: IndexedVar
# variable: 48
# indices: 50
# 46. (_a)
#     core type: ExprTuple
#     sub-expressions: 52
# 47. B_{_b, _a}
#     core type: IndexedVar
# variable: 49
# indices: 50
# 48. A
#     core type: Variable
#     sub-expressions:
# 49. B
#     core type: Variable
#     sub-expressions:
# 50. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. _b
#     core type: Variable
#     sub-expressions:
# 52. _a
#     core type: Variable
#     sub-expressions:
