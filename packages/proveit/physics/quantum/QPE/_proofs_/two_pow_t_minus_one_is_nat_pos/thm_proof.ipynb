# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">physics</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">quantum</a>.<a class="ProveItLink" href="../../_theory_.ipynb">QPE</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#two_pow_t_minus_one_is_nat_pos">two_pow_t_minus_one_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit.numbers import one, subtract
from proveit.physics.quantum.QPE._common_ import t_
from proveit.physics.quantum.QPE._axioms_ import t_in_natural_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving two_pow_t_minus_one_is_nat_pos

# %%
# Recall that t (represented by the Literal t_)
# denotes the number of Qbits in the input register.
# Considered an axiom that t is a positive natural number
t_in_natural_pos

# %%
subtract(t_, one).deduce_difference_in_natural()

# %%
# %qed
