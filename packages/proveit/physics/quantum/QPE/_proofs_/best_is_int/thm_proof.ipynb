# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_.ipynb">physics</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">quantum</a>.<a class="ProveItLink" href="../../_theory_.ipynb">QPE</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#best_is_int">best_is_int</a> theorem
# ========

# %%
import proveit
from proveit.physics.quantum.QPE  import best_def
theory = proveit.Theory() # the theorem's theory

# %%
# %proving best_is_int

# %%
best_def
