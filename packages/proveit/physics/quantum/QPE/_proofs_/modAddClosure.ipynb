# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">physics</a>.<a class="ProveItLink" href="../../_context_.ipynb">quantum</a>.<a class="ProveItLink" href="../_context_.ipynb">QPE</a>.<a class="ProveItLink" href="../_theorems_.ipynb#modAddClosure">modAddClosure</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit._common_ import a, b
from proveit.logic import InSet
from proveit.number import Add, Integers
from proveit.number.modular._theorems_ import modIntClosure
from proveit.physics.quantum.QPE._axioms_ import modAddDef
from proveit.physics.quantum.QPE._common_ import two_pow_t
from proveit.physics.quantum.QPE._theorems_ import two_pow_t_in_posnats, two_pow_t_not_zero
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving modAddClosure presuming [proveit.logic, proveit.number]
# Out:
# Beginning proof of modAddClosure
# Recorded 'presuming' information
# Presuming theorems in proveit.logic, proveit.number (except any that presume this theorem).
# Presuming previous theorems (applied transitively).
# modAddClosure: forall_{a in Integers, b in Integers} ((a MOD_ADD b) in Integers)

# %%
defaults = modAddClosure.conditions
# Out:
# defaults: (a in Integers, b in Integers)

# %%
modAddDef
# Out:
# |- forall_{a in Integers, b in Integers} ((a MOD_ADD b) = ((a + b) mod  2^{t}))

# %%
modAddDefSpec = modAddDef.specialize({a:a, b:b}, assumptions=defaults)
# Out:
# modAddDefSpec: {a in Integers, b in Integers} |- (a MOD_ADD b) = ((a + b) mod  2^{t})

# %%
# 3/19/2020: consider adding a deduceInNumberSet method to the Mod class;
# that will allow a simplification of this manual part of the proof process
# although it won't shorten the eventual proof.

# %%
modIntClosure
# Out:
# |- forall_{a in Integers, b in Integers | b != 0} ((a mod  b) in Integers)

# %%
two_pow_t_not_zero
# Out:
# |- 2^{t} != 0

# %%
two_pow_t_in_posnats
# Out:
# |- 2^{t} in NaturalsPos

# %%
modIntClosureSpec = modIntClosure.specialize({a:Add(a, b), b:two_pow_t}, assumptions=[InSet(a, Integers), InSet(b, Integers)])
# Out:
# modIntClosureSpec: {a in Integers, b in Integers} |- ((a + b) mod  2^{t}) in Integers

# %%
modAddDefSpec.subLeftSideInto(modIntClosureSpec)
# Out:
# {a in Integers, b in Integers} |- (a MOD_ADD b) in Integers

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{a in Integers, b in Integers} ((a MOD_ADD b) in Integers)
# 1	instantiation	2, 3, 4	{a in Integers, b in Integers} |- (a MOD_ADD b) in Integers
# 	P(_a) : _a in Integers, x : a MOD_ADD b, y : (a + b) mod  2^{t}
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.subLeftSideInto
# 3	instantiation	5, 6, 7, 8	{a in Integers, b in Integers} |- ((a + b) mod  2^{t}) in Integers
# 	a : a + b, b : 2^{t}
# 4	instantiation	9, 11, 12	{a in Integers, b in Integers} |- (a MOD_ADD b) = ((a + b) mod  2^{t})
# 	a : a, b : b
# 5	theorem		|- forall_{a in Integers, b in Integers | b != 0} ((a mod  b) in Integers)
# 	proveit.number.modular.modIntClosure
# 6	instantiation	10, 11, 12	{a in Integers, b in Integers} |- (a + b) in Integers
# 	a : a, b : b
# 7	instantiation	13, 14, 15	|- 2^{t} in Integers
# 	A : NaturalsPos, B : Integers, x : 2^{t}
# 8	theorem		|- 2^{t} != 0
# 	proveit.physics.quantum.QPE.two_pow_t_not_zero
# 9	axiom		|- forall_{a in Integers, b in Integers} ((a MOD_ADD b) = ((a + b) mod  2^{t}))
# 	proveit.physics.quantum.QPE.modAddDef
# 10	theorem		|- forall_{a in Integers, b in Integers} ((a + b) in Integers)
# 	proveit.number.addition.addIntClosureBin
# 11	assumption		{a in Integers} |- a in Integers
# 12	assumption		{b in Integers} |- b in Integers
# 13	theorem		|- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.unfoldSubsetEq
# 14	instantiation	16, 17	|- NaturalsPos subseteq Integers
# 	A : NaturalsPos, B : Integers
# 15	theorem		|- 2^{t} in NaturalsPos
# 	proveit.physics.quantum.QPE.two_pow_t_in_posnats
# 16	theorem		|- forall_{A, B | A subset B} (A subseteq B)
# 	proveit.logic.set_theory.containment.relaxSubset
# 17	theorem		|- NaturalsPos subset Integers
# 	proveit.number.sets.integer.natsPosInInts
