# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">physics</a>.<a class="ProveItLink" href="../../_context_.ipynb">quantum</a>.<a class="ProveItLink" href="../_context_.ipynb">QPE</a>.<a class="ProveItLink" href="../_theorems_.ipynb#two_pow_t_not_zero">two_pow_t_not_zero</a> theorem
# ========

# %%
import proveit
from proveit._common_ import a, b
from proveit.number import two
from proveit.number.exponentiation._theorems_ import expNotEqZero
from proveit.physics.quantum.QPE._axioms_ import tInNaturalsPos
from proveit.physics.quantum.QPE._common_ import t_
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving two_pow_t_not_zero presuming [proveit.logic, proveit.number]
# Out:
# Beginning proof of two_pow_t_not_zero
# Recorded 'presuming' information
# Presuming theorems in proveit.logic, proveit.number (except any that presume this theorem).
# Presuming previous theorems (applied transitively).
# two_pow_t_not_zero: 2^{t} != 0

# %%
tInNaturalsPos
# Out:
# |- t in NaturalsPos

# %%
expNotEqZero
# Out:
# |- forall_{a in Complexes, b in Complexes | a != 0} (a^{b} != 0)

# %%
expNotEqZeroSpec = expNotEqZero.specialize({a:two, b:t_})
# Out:
# two_pow_t_not_zero has been proven.  Now simply execute "%qed".
# expNotEqZeroSpec: |- 2^{t} != 0

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3, 4	|- 2^{t} != 0
# 	a : 2, b : t
# 1	theorem		|- forall_{a in Complexes, b in Complexes | a != 0} (a^{b} != 0)
# 	proveit.number.exponentiation.expNotEqZero
# 2	instantiation	16, 5, 15	|- 2 in Complexes
# 	A : Naturals, B : Complexes, x : 2
# 3	instantiation	16, 5, 6	|- t in Complexes
# 	A : Naturals, B : Complexes, x : t
# 4	instantiation	7, 8, 9, 10	|- 2 != 0
# 	a : 2, b : 0
# 5	instantiation	21, 11	|- Naturals subseteq Complexes
# 	A : Naturals, B : Complexes
# 6	instantiation	12, 13, 14	|- t in Naturals
# 	A : NaturalsPos, B : Naturals, x : t
# 7	theorem		|- forall_{a in Reals, b in Reals | a > b} (a != b)
# 	proveit.number.ordering.gtrIsNotEq
# 8	instantiation	16, 17, 15	|- 2 in Reals
# 	A : Naturals, B : Reals, x : 2
# 9	instantiation	16, 17, 18	|- 0 in Reals
# 	A : Naturals, B : Reals, x : 0
# 10	instantiation	19, 20	|- 2 > 0
# 	x : 0, y : 2
# 11	theorem		|- Naturals subset Complexes
# 	proveit.number.sets.complex.natsInComplexes
# 12	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 13	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 14	axiom		|- t in NaturalsPos
# 	proveit.physics.quantum.QPE.tInNaturalsPos
# 15	theorem		|- 2 in Naturals
# 	proveit.number.numeral.deci.nat2
# 16	theorem		|- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.unfoldSubsetEq
# 17	instantiation	21, 22	|- Naturals subseteq Reals
# 	A : Naturals, B : Reals
# 18	theorem		|- 0 in Naturals
# 	proveit.number.sets.integer.zeroInNats
# 19	theorem		|- forall_{x, y | x < y} (y > x)
# 	proveit.number.ordering.reverseLess
# 20	instantiation	23, 24, 25	|- 0 < 2
# 	x : 0, y : 1, z : 2
# 21	theorem		|- forall_{A, B | A subset B} (A subseteq B)
# 	proveit.logic.set_theory.containment.relaxSubset
# 22	theorem		|- Naturals subset Reals
# 	proveit.number.sets.real.natsInReals
# 23	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.number.ordering.transitivityLessLess
# 24	theorem		|- 0 < 1
# 	proveit.number.numeral.deci.less_0_1
# 25	theorem		|- 1 < 2
# 	proveit.number.numeral.deci.less_1_2
