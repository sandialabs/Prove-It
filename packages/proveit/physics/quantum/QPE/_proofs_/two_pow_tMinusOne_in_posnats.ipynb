# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">physics</a>.<a class="ProveItLink" href="../../_context_.ipynb">quantum</a>.<a class="ProveItLink" href="../_context_.ipynb">QPE</a>.<a class="ProveItLink" href="../_theorems_.ipynb#two_pow_tMinusOne_in_posnats">two_pow_tMinusOne_in_posnats</a> theorem
# ========

# %%
import proveit
from proveit.number import one, subtract
from proveit.physics.quantum.QPE._common_ import t_
from proveit.physics.quantum.QPE._axioms_ import tInNaturalsPos
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving two_pow_tMinusOne_in_posnats presuming [proveit.number, proveit.logic]
# Out:
# Beginning proof of two_pow_tMinusOne_in_posnats
# Recorded 'presuming' information
# Presuming theorems in proveit.logic, proveit.number (except any that presume this theorem).
# Presuming previous theorem (applied transitively).
# two_pow_tMinusOne_in_posnats: 2^{t - 1} in NaturalsPos

# %%
# Recall that t (represented by the Literal t_)
# denotes the number of Qbits in the input register.
# Considered an axiom that t is a positive natural number
tInNaturalsPos
# Out:
# |- t in NaturalsPos

# %%
subtract(t_, one).deduceDifferenceInNaturals()
# Out:
# |- (t - 1) in Naturals

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- 2^{t - 1} in NaturalsPos
# 	a : 2, b : t - 1
# 1	theorem		|- forall_{a in NaturalsPos, b in Naturals} (a^{b} in NaturalsPos)
# 	proveit.number.exponentiation.expNatClosure
# 2	theorem		|- 2 in NaturalsPos
# 	proveit.number.numeral.deci.posnat2
# 3	instantiation	4, 5, 6, 7	|- (t - 1) in Naturals
# 	a : t, b : 1
# 4	theorem		|- forall_{a in Integers, b in Integers | b <= a} ((a - b) in Naturals)
# 	proveit.number.sets.integer.differenceInNaturals
# 5	instantiation	10, 8, 9	|- t in Integers
# 	A : Naturals, B : Integers, x : t
# 6	instantiation	10, 11, 12	|- 1 in Integers
# 	A : NaturalsPos, B : Integers, x : 1
# 7	instantiation	13, 14	|- 1 <= t
# 	x : t, y : 1
# 8	instantiation	18, 15	|- Naturals subseteq Integers
# 	A : Naturals, B : Integers
# 9	instantiation	16, 17, 21	|- t in Naturals
# 	A : NaturalsPos, B : Naturals, x : t
# 10	theorem		|- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.unfoldSubsetEq
# 11	instantiation	18, 19	|- NaturalsPos subseteq Integers
# 	A : NaturalsPos, B : Integers
# 12	theorem		|- 1 in NaturalsPos
# 	proveit.number.numeral.deci.posnat1
# 13	theorem		|- forall_{x, y | x >= y} (y <= x)
# 	proveit.number.ordering.reverseGreaterEq
# 14	instantiation	20, 21	|- t >= 1
# 	n : t
# 15	theorem		|- Naturals subset Integers
# 	proveit.number.sets.integer.natsInInts
# 16	theorem		|- forall_{A, B | A subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.set_theory.containment.supersetMembershipFromSubset
# 17	theorem		|- NaturalsPos subset Naturals
# 	proveit.number.sets.integer.natsPosInNats
# 18	theorem		|- forall_{A, B | A subset B} (A subseteq B)
# 	proveit.logic.set_theory.containment.relaxSubset
# 19	theorem		|- NaturalsPos subset Integers
# 	proveit.number.sets.integer.natsPosInInts
# 20	theorem		|- forall_{n in NaturalsPos} (n >= 1)
# 	proveit.number.sets.integer.naturalsPosLowerBound
# 21	axiom		|- t in NaturalsPos
# 	proveit.physics.quantum.QPE.tInNaturalsPos
