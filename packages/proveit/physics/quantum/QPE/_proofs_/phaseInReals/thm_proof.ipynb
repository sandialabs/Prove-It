# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">physics</a>.<a class="ProveItLink" href="../../_theory_.ipynb">quantum</a>.<a class="ProveItLink" href="../_theory_.ipynb">QPE</a>.<a class="ProveItLink" href="../_theorems_.ipynb#phaseInReals">phaseInReals</a> theorem
# ========

# %%
import proveit
from proveit.physics.quantum.QPE._axioms_ import phaseInInterval
from proveit.physics.quantum.QPE._common_ import phase_
theory = proveit.Theory() # the theorem's theory

# %%
# %proving phaseInReals

# %%
# axiomatically:
phaseInInterval

# %%
interval_0_to_1 = phaseInInterval.operands[1]

# %%
phase_

# %%
# then need to update the sets/real/_theorems_ with the
# interval-related membership theorems.

# %%
interval_0_to_1.deduceMemberInReals(phase_)

# %%
# %qed
