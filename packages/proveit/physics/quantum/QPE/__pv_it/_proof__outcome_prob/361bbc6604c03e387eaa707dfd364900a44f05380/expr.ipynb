# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Variable, m
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import I, NumKet, Z
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
expr = Len(operands = [Lambda(sub_expr1, MultiQubitElem(element = Input(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr2))), Lambda(sub_expr1, Measure(basis = Z)), Lambda(sub_expr1, Gate(operation = I).with_implicit_representation()), Lambda(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t))), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2)))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# |\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |(_a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (_a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 41
#    body: 8
# 4. _a -> [MEASURE]{basis:Z}
#    core type: Lambda
#    parameter: 41
#    body: 9
# 5. _a -> [GATE]{operation:I}
#    core type: Lambda
#    parameter: 41
#    body: 10
# 6. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#    core type: Lambda
#    parameter: 41
#    body: 11
# 7. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 41
#    body: 13
# 8. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Operation
#    operator: 20
#    operands: 14
# 9. [MEASURE]{basis:Z}
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. [GATE]{operation:I}
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 20
#     operands: 19
# 12. (_a)
#     core type: ExprTuple
#     sub-expressions: 41
# 13. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. {element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 22
#     targets: 23
# 15. MEASURE
#     core type: Literal
#     sub-expressions:
# 16. {basis:Z}
#     core type: NamedExprs
#     basis: 24
# 17. GATE
#     core type: Literal
#     sub-expressions:
# 18. {operation:I}
#     core type: NamedExprs
#     operation: 25
# 19. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 26
#     targets: 27
# 20. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 21. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 28
#     targets: 29
# 22. [INPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 30
#     operands: 31
# 23. {1 .. t + s}
#     core type: Operation
#     operator: 37
#     operands: 32
# 24. Z
#     core type: Literal
#     sub-expressions:
# 25. I
#     core type: Literal
#     sub-expressions:
# 26. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 35
#     operands: 33
# 27. {1 .. t}
#     core type: Operation
#     operator: 37
#     operands: 34
# 28. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. {t + 1 .. t + s}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. INPUT
#     core type: Literal
#     sub-expressions:
# 31. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 39
#     part: 41
# 32. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 54, 43
# 33. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 40
#     part: 41
# 34. (1, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 35. OUTPUT
#     core type: Literal
#     sub-expressions:
# 36. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 52
#     part: 41
# 37. Interval
#     core type: Literal
#     sub-expressions:
# 38. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. |Psi> otimes |u>
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. |m〉_{t}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. _a
#     core type: Variable
#     sub-expressions:
# 42. t + 1
#     core type: Operation
#     operator: 49
#     operands: 48
# 43. t + s
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. otimes
#     core type: Literal
#     sub-expressions:
# 45. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 46. NUM_KET
#     core type: Literal
#     sub-expressions:
# 47. (m, t)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 48. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (t, s)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. |Psi>
#     core type: Literal
#     sub-expressions:
# 52. |u>
#     core type: Literal
#     sub-expressions:
# 53. m
#     core type: Variable
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. s
#     core type: Literal
#     sub-expressions:
