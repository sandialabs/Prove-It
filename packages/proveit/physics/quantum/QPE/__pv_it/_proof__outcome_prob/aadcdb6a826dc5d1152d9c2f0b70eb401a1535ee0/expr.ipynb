# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, m
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import NumKet, Z
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
expr = ExprTuple(ExprRange(sub_expr1, MultiQubitElem(element = Input(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr2)), one, sub_expr2), ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire, ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2)), one, _s))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, ..\left(t - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, ..\left(s - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 57
#    end_index: 46
# 2. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 57
#    end_index: 58
# 3. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 57
#    end_index: 59
# 4. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 57
#    end_index: 58
# 5. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 57
#    end_index: 59
# 6. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 44
#    body: 11
# 7. _a -> [MEASURE]{basis:Z}
#    core type: Lambda
#    parameter: 44
#    body: 12
# 8. _a -> [GATE]{operation:I}
#    core type: Lambda
#    parameter: 44
#    body: 13
# 9. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#    core type: Lambda
#    parameter: 44
#    body: 14
# 10. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 44
#     body: 16
# 11. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 23
#     operands: 17
# 12. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. [GATE]{operation:I}
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 23
#     operands: 22
# 15. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 16. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. {element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 25
#     targets: 26
# 18. MEASURE
#     core type: Literal
#     sub-expressions:
# 19. {basis:Z}
#     core type: NamedExprs
#     basis: 27
# 20. GATE
#     core type: Literal
#     sub-expressions:
# 21. {operation:I}
#     core type: NamedExprs
#     operation: 28
# 22. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 29
#     targets: 30
# 23. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 24. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 31
#     targets: 32
# 25. [INPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 33
#     operands: 34
# 26. {1 .. t + s}
#     core type: Operation
#     operator: 40
#     operands: 35
# 27. Z
#     core type: Literal
#     sub-expressions:
# 28. I
#     core type: Literal
#     sub-expressions:
# 29. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 38
#     operands: 36
# 30. {1 .. t}
#     core type: Operation
#     operator: 40
#     operands: 37
# 31. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 38
#     operands: 39
# 32. {t + 1 .. t + s}
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. INPUT
#     core type: Literal
#     sub-expressions:
# 34. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 42
#     part: 44
# 35. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 57, 46
# 36. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 43
#     part: 44
# 37. (1, t)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 38. OUTPUT
#     core type: Literal
#     sub-expressions:
# 39. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 55
#     part: 44
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. |Psi> otimes |u>
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. |m〉_{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. t + 1
#     core type: Operation
#     operator: 52
#     operands: 51
# 46. t + s
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. otimes
#     core type: Literal
#     sub-expressions:
# 48. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 49. NUM_KET
#     core type: Literal
#     sub-expressions:
# 50. (m, t)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 51. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 57
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (t, s)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. |Psi>
#     core type: Literal
#     sub-expressions:
# 55. |u>
#     core type: Literal
#     sub-expressions:
# 56. m
#     core type: Variable
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. t
#     core type: Literal
#     sub-expressions:
# 59. s
#     core type: Literal
#     sub-expressions:
