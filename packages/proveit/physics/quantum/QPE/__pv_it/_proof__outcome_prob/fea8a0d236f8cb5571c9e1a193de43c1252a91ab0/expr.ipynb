# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one, six
from proveit.physics.quantum import ket_plus
from proveit.physics.quantum.QPE import QPE, _Psi_ket, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(one, sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = sub_expr3))
sub_expr5 = Lambda(sub_expr1, MultiQubitElem(element = Output(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = sub_expr3))
expr = ExprTuple(Len(operands = [Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2))), sub_expr4, sub_expr4, sub_expr5, sub_expr5]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, six)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|, |\left(1, 2, \ldots, 6\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})|, |(1, 2, ..., 6)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |(1, 2, ..., 6)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 8, 9, 9
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (1, 2, ..., 6)
#    core type: ExprTuple
#    sub-expressions: 10
# 6. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 44
#    body: 11
# 7. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 44
#    body: 12
# 8. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 44
#    body: 13
# 9. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 44
#    body: 14
# 10. 1, 2, ..., 6
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 53
#     end_index: 16
# 11. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 31
#     operands: 17
# 12. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 20
#     operands: 18
# 13. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. _a -> _a
#     core type: Lambda
#     parameter: 44
#     body: 44
# 16. 6
#     core type: Literal
#     sub-expressions:
# 17. {state:|+〉}
#     core type: NamedExprs
#     state: 23
# 18. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 24
#     targets: 25
# 19. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 26
#     targets: 28
# 20. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 21. {element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 27
#     targets: 28
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 23. |+〉
#     core type: Operation
#     operator: 29
#     operand: 40
# 24. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 31
#     operands: 32
# 25. {t + 1 .. t + s}
#     core type: Operation
#     operator: 38
#     operands: 33
# 26. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. [OUTPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 36
#     operands: 37
# 28. {1 .. t + s}
#     core type: Operation
#     operator: 38
#     operands: 39
# 29. KET
#     core type: Literal
#     sub-expressions:
# 30. (+)
#     core type: ExprTuple
#     sub-expressions: 40
# 31. INPUT
#     core type: Literal
#     sub-expressions:
# 32. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 56
#     part: 44
# 33. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 41, 45
# 34. GATE
#     core type: Literal
#     sub-expressions:
# 35. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 42
#     part: 44
# 36. OUTPUT
#     core type: Literal
#     sub-expressions:
# 37. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 43
#     part: 44
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 53, 45
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. t + 1
#     core type: Operation
#     operator: 51
#     operands: 46
# 42. QPE(U, t)
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. |Psi> otimes |u>
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. t + s
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 53
# 47. QPE
#     core type: Literal
#     sub-expressions:
# 48. (U, t)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 49. otimes
#     core type: Literal
#     sub-expressions:
# 50. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (t, s)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. U
#     core type: Literal
#     sub-expressions:
# 55. |Psi>
#     core type: Literal
#     sub-expressions:
# 56. |u>
#     core type: Literal
#     sub-expressions:
# 57. t
#     core type: Literal
#     sub-expressions:
# 58. s
#     core type: Literal
#     sub-expressions:
