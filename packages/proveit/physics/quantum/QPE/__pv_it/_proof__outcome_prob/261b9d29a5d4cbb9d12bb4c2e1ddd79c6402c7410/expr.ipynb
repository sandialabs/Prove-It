# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Variable
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import ket_plus
from proveit.physics.quantum.QPE import QPE, _Psi_ket, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(one, sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = sub_expr3))
sub_expr5 = Lambda(sub_expr1, MultiQubitElem(element = Output(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = sub_expr3))
expr = ExprTuple(Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2))), sub_expr4, sub_expr4, sub_expr5, sub_expr5)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 3, 4, 4
# 1. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 36
#    body: 5
# 2. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 36
#    body: 6
# 3. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 36
#    body: 7
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 36
#    body: 9
# 5. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 23
#    operands: 10
# 6. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Operation
#    operator: 13
#    operands: 11
# 7. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. (_a)
#    core type: ExprTuple
#    sub-expressions: 36
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. {state:|+〉}
#     core type: NamedExprs
#     state: 15
# 11. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 16
#     targets: 17
# 12. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 18
#     targets: 20
# 13. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 14. {element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 19
#     targets: 20
# 15. |+〉
#     core type: Operation
#     operator: 21
#     operand: 32
# 16. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. {t + 1 .. t + s}
#     core type: Operation
#     operator: 30
#     operands: 25
# 18. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 26
#     operands: 27
# 19. [OUTPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 28
#     operands: 29
# 20. {1 .. t + s}
#     core type: Operation
#     operator: 30
#     operands: 31
# 21. KET
#     core type: Literal
#     sub-expressions:
# 22. (+)
#     core type: ExprTuple
#     sub-expressions: 32
# 23. INPUT
#     core type: Literal
#     sub-expressions:
# 24. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 48
#     part: 36
# 25. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 33, 37
# 26. GATE
#     core type: Literal
#     sub-expressions:
# 27. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 34
#     part: 36
# 28. OUTPUT
#     core type: Literal
#     sub-expressions:
# 29. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 35
#     part: 36
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 45, 37
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. t + 1
#     core type: Operation
#     operator: 43
#     operands: 38
# 34. QPE(U, t)
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. |Psi> otimes |u>
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. t + s
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 45
# 39. QPE
#     core type: Literal
#     sub-expressions:
# 40. (U, t)
#     core type: ExprTuple
#     sub-expressions: 46, 49
# 41. otimes
#     core type: Literal
#     sub-expressions:
# 42. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (t, s)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. U
#     core type: Literal
#     sub-expressions:
# 47. |Psi>
#     core type: Literal
#     sub-expressions:
# 48. |u>
#     core type: Literal
#     sub-expressions:
# 49. t
#     core type: Literal
#     sub-expressions:
# 50. s
#     core type: Literal
#     sub-expressions:
