# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import ket_plus
from proveit.physics.quantum.QPE import QPE, _Psi_ket, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(one, sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = sub_expr3))
expr = Len(operands = [Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2))), sub_expr4, sub_expr4, Lambda(sub_expr1, MultiQubitElem(element = Output(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = sub_expr3))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# |\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 5, 6
# 3. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 38
#    body: 7
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 38
#    body: 8
# 5. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 38
#    body: 9
# 6. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 38
#    body: 11
# 7. [INPUT]{state:|+〉}
#    core type: Operation
#    operator: 25
#    operands: 12
# 8. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Operation
#    operator: 15
#    operands: 13
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. (_a)
#     core type: ExprTuple
#     sub-expressions: 38
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. {state:|+〉}
#     core type: NamedExprs
#     state: 17
# 13. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 18
#     targets: 19
# 14. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 20
#     targets: 22
# 15. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 16. {element:[OUTPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 21
#     targets: 22
# 17. |+〉
#     core type: Operation
#     operator: 23
#     operand: 34
# 18. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. {t + 1 .. t + s}
#     core type: Operation
#     operator: 32
#     operands: 27
# 20. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 28
#     operands: 29
# 21. [OUTPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 30
#     operands: 31
# 22. {1 .. t + s}
#     core type: Operation
#     operator: 32
#     operands: 33
# 23. KET
#     core type: Literal
#     sub-expressions:
# 24. (+)
#     core type: ExprTuple
#     sub-expressions: 34
# 25. INPUT
#     core type: Literal
#     sub-expressions:
# 26. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 50
#     part: 38
# 27. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 35, 39
# 28. GATE
#     core type: Literal
#     sub-expressions:
# 29. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 36
#     part: 38
# 30. OUTPUT
#     core type: Literal
#     sub-expressions:
# 31. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 37
#     part: 38
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 47, 39
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. t + 1
#     core type: Operation
#     operator: 45
#     operands: 40
# 36. QPE(U, t)
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. |Psi> otimes |u>
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. _a
#     core type: Variable
#     sub-expressions:
# 39. t + s
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 51, 47
# 41. QPE
#     core type: Literal
#     sub-expressions:
# 42. (U, t)
#     core type: ExprTuple
#     sub-expressions: 48, 51
# 43. otimes
#     core type: Literal
#     sub-expressions:
# 44. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (t, s)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. U
#     core type: Literal
#     sub-expressions:
# 49. |Psi>
#     core type: Literal
#     sub-expressions:
# 50. |u>
#     core type: Literal
#     sub-expressions:
# 51. t
#     core type: Literal
#     sub-expressions:
# 52. s
#     core type: Literal
#     sub-expressions:
