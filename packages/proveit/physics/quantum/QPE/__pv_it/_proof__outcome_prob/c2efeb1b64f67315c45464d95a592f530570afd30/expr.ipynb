# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, m
from proveit.core_expr_types import Len
from proveit.numbers import Add, Interval, one, two
from proveit.physics.quantum import NumKet, Z
from proveit.physics.quantum.QPE import _ket_u, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Len(operands = [[ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), Add(_t, _s))), one, _s)]]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, two)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, ..\left(t - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, ..\left(s - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))|, |(1, ..., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |(1, ..., 2)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (1, ..., 2)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. 1, ..., 2
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 54
#    end_index: 14
# 9. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 54
#    end_index: 55
# 10. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 54
#     end_index: 56
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 54
#     end_index: 55
# 12. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 54
#     end_index: 56
# 13. _a -> _a
#     core type: Lambda
#     parameter: 45
#     body: 45
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 45
#     body: 19
# 16. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 45
#     body: 20
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 45
#     body: 21
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 45
#     body: 23
# 19. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. [GATE]{operation:I}
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 29
#     operands: 28
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 45
# 23. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. MEASURE
#     core type: Literal
#     sub-expressions:
# 25. {basis:Z}
#     core type: NamedExprs
#     basis: 31
# 26. GATE
#     core type: Literal
#     sub-expressions:
# 27. {operation:I}
#     core type: NamedExprs
#     operation: 32
# 28. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 33
#     targets: 34
# 29. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 30. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 31. Z
#     core type: Literal
#     sub-expressions:
# 32. I
#     core type: Literal
#     sub-expressions:
# 33. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 39
#     operands: 37
# 34. {1 .. t}
#     core type: Operation
#     operator: 41
#     operands: 38
# 35. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. {t + 1 .. t + s}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 43
#     part: 45
# 38. (1, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 39. OUTPUT
#     core type: Literal
#     sub-expressions:
# 40. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 44
#     part: 45
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. |m〉_{t}
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. |u>
#     core type: Literal
#     sub-expressions:
# 45. _a
#     core type: Variable
#     sub-expressions:
# 46. t + 1
#     core type: Operation
#     operator: 51
#     operands: 50
# 47. t + s
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. NUM_KET
#     core type: Literal
#     sub-expressions:
# 49. (m, t)
#     core type: ExprTuple
#     sub-expressions: 53, 55
# 50. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (t, s)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. m
#     core type: Variable
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. s
#     core type: Literal
#     sub-expressions:
