# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, m
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one, three
from proveit.physics.quantum import NumKet, Z
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = Add(_t, _s)
expr = ExprTuple(Len(operands = [ExprRange(sub_expr1, MultiQubitElem(element = Input(state = TensorProd(_Psi_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr3)), one, sub_expr3), ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire, ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr3)), one, _s)]), Len(operands = [ExprRange(sub_expr2, ExprRange(sub_expr1, [sub_expr2, sub_expr1], one, sub_expr3), one, three)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \Psi \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, ..\left(t - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, ..\left(s - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|, |\left(\left(1, 1\right), \left(1, 2\right), \ldots, \left(1, t + s\right), \left(2, 1\right), \left(2, 2\right), \ldots, \left(2, t + s\right), \ldots\ldots, \left(3, 1\right), \left(3, 2\right), \ldots, \left(3, t + s\right)\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})|, |((1, 1), (1, 2), ..., (1, t + s), (2, 1), (2, 2), ..., (2, t + s), ......, (3, 1), (3, 2), ..., (3, t + s))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |((1, 1), (1, 2), ..., (1, t + s), (2, 1), (2, 2), ..., (2, t + s), ......, (3, 1), (3, 2), ..., (3, t + s))|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, 1), (1, 2), ..., (1, t + s), (2, 1), (2, 2), ..., (2, t + s), ......, (3, 1), (3, 2), ..., (3, t + s))
#    core type: ExprTuple
#    sub-expressions: 11
# 6. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 70
#    end_index: 59
# 7. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 70
#    end_index: 71
# 8. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 70
#    end_index: 72
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 70
#    end_index: 71
# 10. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 70
#     end_index: 72
# 11. (1, 1), (1, 2), ..., (1, t + s), (2, 1), (2, 2), ..., (2, t + s), ......, (3, 1), (3, 2), ..., (3, t + s)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 70
#     end_index: 18
# 12. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 57
#     body: 19
# 13. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 57
#     body: 20
# 14. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 57
#     body: 21
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 57
#     body: 22
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 57
#     body: 23
# 17. _b -> (_b, 1), (_b, 2), ..., (_b, t + s)
#     core type: Lambda
#     parameter: 54
#     body: 25
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 32
#     operands: 26
# 20. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 27
#     operands: 28
# 21. [GATE]{operation:I}
#     core type: Operation
#     operator: 29
#     operands: 30
# 22. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 32
#     operands: 31
# 23. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 24. (_b)
#     core type: ExprTuple
#     sub-expressions: 54
# 25. (_b, 1), (_b, 2), ..., (_b, t + s)
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 70
#     end_index: 59
# 26. {element:[INPUT]{state:(|Psi> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 27. MEASURE
#     core type: Literal
#     sub-expressions:
# 28. {basis:Z}
#     core type: NamedExprs
#     basis: 37
# 29. GATE
#     core type: Literal
#     sub-expressions:
# 30. {operation:I}
#     core type: NamedExprs
#     operation: 38
# 31. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 39
#     targets: 40
# 32. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 33. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 34. _a -> (_b, _a)
#     core type: Lambda
#     parameter: 57
#     body: 44
# 35. [INPUT]{state:(|Psi> otimes |u>), part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 36. {1 .. t + s}
#     core type: Operation
#     operator: 52
#     operands: 47
# 37. Z
#     core type: Literal
#     sub-expressions:
# 38. I
#     core type: Literal
#     sub-expressions:
# 39. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 48
# 40. {1 .. t}
#     core type: Operation
#     operator: 52
#     operands: 49
# 41. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 42. {t + 1 .. t + s}
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 44. (_b, _a)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 45. INPUT
#     core type: Literal
#     sub-expressions:
# 46. {state:(|Psi> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 55
#     part: 57
# 47. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 70, 59
# 48. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 56
#     part: 57
# 49. (1, t)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 50. OUTPUT
#     core type: Literal
#     sub-expressions:
# 51. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 68
#     part: 57
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. _b
#     core type: Variable
#     sub-expressions:
# 55. |Psi> otimes |u>
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. |m〉_{t}
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. _a
#     core type: Variable
#     sub-expressions:
# 58. t + 1
#     core type: Operation
#     operator: 65
#     operands: 64
# 59. t + s
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. otimes
#     core type: Literal
#     sub-expressions:
# 61. (|Psi>, |u>)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 62. NUM_KET
#     core type: Literal
#     sub-expressions:
# 63. (m, t)
#     core type: ExprTuple
#     sub-expressions: 69, 71
# 64. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 71, 70
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (t, s)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. |Psi>
#     core type: Literal
#     sub-expressions:
# 68. |u>
#     core type: Literal
#     sub-expressions:
# 69. m
#     core type: Variable
#     sub-expressions:
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. t
#     core type: Literal
#     sub-expressions:
# 72. s
#     core type: Literal
#     sub-expressions:
