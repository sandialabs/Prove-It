# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#negDomain">negDomain</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Interval.html">Interval</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._common_ import negDomain

# %%
# check that the built expression is the same as the stored expression
# %check_expr negDomain
# Out:
# Passed sanity check: built 'negDomain' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negDomain.latex())
# Out:
# \{-2^{t - 1} + 1 \dots -\left(\varepsilon + 1\right)\}

# %%
# display the expression information
negDomain.exprInfo()
# Out:
# 0. {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Interval
#    core type: Literal
#    sub-expressions:
# 2. (-2^{t - 1} + 1, -(eps + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. -2^{t - 1} + 1
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. -(eps + 1)
#    core type: Operation
#    operator: 19
#    operand: 6
# 5. (-2^{t - 1}, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 20
# 6. eps + 1
#    core type: Operation
#    operator: 15
#    operands: 8
# 7. -2^{t - 1}
#    core type: Operation
#    operator: 19
#    operand: 9
# 8. (eps, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 20
# 9. 2^{t - 1}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. eps
#     core type: Variable
#     sub-expressions:
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2
#     core type: Literal
# ...
