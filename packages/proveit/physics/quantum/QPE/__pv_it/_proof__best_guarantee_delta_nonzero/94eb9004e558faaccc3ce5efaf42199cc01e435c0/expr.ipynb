# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Equals
from proveit.numbers import Abs, Exp, Mult, e, frac, i, one, pi, subtract, two
from proveit.physics.quantum.QPE import _delta_b_round, _two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(_delta_b_round)
expr = Equals(frac(Abs(subtract(one, Exp(e, Mult(two, pi, i, _delta_b_round, _two_pow_t)))), Abs(subtract(one, Exp(e, Mult(two, pi, i, _delta_b_round))))), frac(Mult(two, Sin(Mult(_two_pow_t, pi, sub_expr1))), Mult(two, Sin(Mult(pi, sub_expr1))))).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \frac{\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \delta_{b_{\textit{r}}} \cdot 2^{t}}\right|}{\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \delta_{b_{\textit{r}}}}\right|} =  \\ \frac{2 \cdot \sin{\left(2^{t} \cdot \pi \cdot \left|\delta_{b_{\textit{r}}}\right|\right)}}{2 \cdot \sin{\left(\pi \cdot \left|\delta_{b_{\textit{r}}}\right|\right)}} \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|) =  \\ ((2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|, (2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}|, |1 - e^{2 * pi * i * delta_{b_{r}}}|)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (2 * sin(2^{t} * pi * |delta_{b_{r}}|), 2 * sin(pi * |delta_{b_{r}}|))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. |1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}|
#    core type: Operation
#    operator: 41
#    operand: 16
# 9. |1 - e^{2 * pi * i * delta_{b_{r}}}|
#    core type: Operation
#    operator: 41
#    operand: 17
# 10. 2 * sin(2^{t} * pi * |delta_{b_{r}}|)
#     core type: Operation
#     operator: 47
#     operands: 14
# 11. 2 * sin(pi * |delta_{b_{r}}|)
#     core type: Operation
#     operator: 47
#     operands: 15
# 12. (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (1 - e^{2 * pi * i * delta_{b_{r}}})
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (2, sin(2^{t} * pi * |delta_{b_{r}}|))
#     core type: ExprTuple
#     sub-expressions: 57, 18
# 15. (2, sin(pi * |delta_{b_{r}}|))
#     core type: ExprTuple
#     sub-expressions: 57, 19
# 16. 1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
#     core type: Operation
#     operator: 21
#     operands: 20
# 17. 1 - e^{2 * pi * i * delta_{b_{r}}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. sin(2^{t} * pi * |delta_{b_{r}}|)
#     core type: Operation
#     operator: 24
#     operand: 29
# 19. sin(pi * |delta_{b_{r}}|)
#     core type: Operation
#     operator: 24
#     operand: 30
# 20. (1, -e^{2 * pi * i * delta_{b_{r}} * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (1, -e^{2 * pi * i * delta_{b_{r}}})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. (2^{t} * pi * |delta_{b_{r}}|)
#     core type: ExprTuple
#     sub-expressions: 29
# 24. sin
#     core type: Literal
#     sub-expressions:
# 25. (pi * |delta_{b_{r}}|)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. -e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
#     core type: Operation
#     operator: 32
#     operand: 36
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. -e^{2 * pi * i * delta_{b_{r}}}
#     core type: Operation
#     operator: 32
#     operand: 37
# 29. 2^{t} * pi * |delta_{b_{r}}|
#     core type: Operation
#     operator: 47
#     operands: 34
# 30. pi * |delta_{b_{r}}|
#     core type: Operation
#     operator: 47
#     operands: 35
# 31. (e^{2 * pi * i * delta_{b_{r}} * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. (e^{2 * pi * i * delta_{b_{r}}})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. (2^{t}, pi, |delta_{b_{r}}|)
#     core type: ExprTuple
#     sub-expressions: 49, 50, 38
# 35. (pi, |delta_{b_{r}}|)
#     core type: ExprTuple
#     sub-expressions: 50, 38
# 36. e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
#     core type: Operation
#     operator: 53
#     operands: 39
# 37. e^{2 * pi * i * delta_{b_{r}}}
#     core type: Operation
#     operator: 53
#     operands: 40
# 38. |delta_{b_{r}}|
#     core type: Operation
#     operator: 41
#     operand: 52
# 39. (e, 2 * pi * i * delta_{b_{r}} * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44, 43
# 40. (e, 2 * pi * i * delta_{b_{r}})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. Abs
#     core type: Literal
#     sub-expressions:
# 42. (delta_{b_{r}})
#     core type: ExprTuple
#     sub-expressions: 52
# 43. 2 * pi * i * delta_{b_{r}} * 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 46
# 44. e
#     core type: Literal
#     sub-expressions:
# 45. 2 * pi * i * delta_{b_{r}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. (2, pi, i, delta_{b_{r}}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 57, 50, 51, 52, 49
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2, pi, i, delta_{b_{r}})
#     core type: ExprTuple
#     sub-expressions: 57, 50, 51, 52
# 49. 2^{t}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. pi
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Literal
#     sub-expressions:
# 52. delta_{b_{r}}
#     core type: Operation
#     operator: 55
#     operand: 59
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, t)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. delta
#     core type: Literal
#     sub-expressions:
# 56. (b_{r})
#     core type: ExprTuple
#     sub-expressions: 59
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. t
#     core type: Literal
#     sub-expressions:
# 59. b_{r}
#     core type: Literal
#     sub-expressions:
