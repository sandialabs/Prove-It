# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import l
from proveit.number import Add, Exp, Mult, Neg, e, frac, i, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(e, Mult(two, pi, i, Add(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, Exp(two, Literal("t", context = "proveit.physics.quantum.QPE")))))))
# Out:
# expr: (e, 2 * pi * i * (delta - (l / 2^{t})))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(e, 2 \cdot \pi \cdot i \cdot \left(\delta - \frac{l}{2^{t}}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (e, 2 * pi * i * (delta - (l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e
#    core type: Literal
#    sub-expressions:
# 2. 2 * pi * i * (delta - (l / 2^{t}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (2, pi, i, delta - (l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 20, 5, 6, 7
# 5. pi
#    core type: Literal
#    sub-expressions:
# 6. i
#    core type: Literal
#    sub-expressions:
# 7. delta - (l / 2^{t})
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (delta, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. delta
#     core type: Literal
#     sub-expressions:
# 11. -(l / 2^{t})
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. l / 2^{t}
#     core type: Operation
#     operator: 14
# ...
