# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../_theorems_.ipynb#two_pow_t_not_zero">two_pow_t_not_zero</a>
# ***see <a class="ProveItLink" href="../../_proofs_/two_pow_t_not_zero.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE._theorems_ import two_pow_t_not_zero

# %%
# %dependencies two_pow_t_not_zero
# Out:
# <h3>Unproven theorems required (directly or indirectly) to prove two_pow_t_not_zero</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../logic/set_theory/containment/_proofs_/relaxSubset.ipynb">proveit.logic.set_theory.containment.relaxSubset</a></dt><dd><a class="ProveItLink" href="../../../../../logic/set_theory/containment/__pv_it/67d69fc4067f328a5c2eb0f4e944b9678d50896a0/expr.ipynb"><img src="../../../../../logic/set_theory/containment/__pv_it/67d69fc4067f328a5c2eb0f4e944b9678d50896a0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
