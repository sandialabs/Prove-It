# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import l
from proveit.logic import InSet
from proveit.number import Abs, GreaterEq, Reals, zero
from proveit.physics.quantum.QPE import SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = Abs(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l))
expr = ExprTuple(InSet(subExpr1, Reals), GreaterEq(subExpr1, zero))
# Out:
# expr: (|alpha_{l}| in Reals, |alpha_{l}| >= 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\alpha_{l}\right| \in \mathbb{R}, \left|\alpha_{l}\right| \geq 0\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|alpha_{l}| in Reals, |alpha_{l}| >= 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |alpha_{l}| in Reals
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. |alpha_{l}| >= 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. in
#    core type: Literal
#    sub-expressions:
# 4. (|alpha_{l}|, Reals)
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. >=
#    core type: Literal
#    sub-expressions:
# 6. (|alpha_{l}|, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Reals
#    core type: Literal
#    sub-expressions:
# 8. |alpha_{l}|
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. alpha_{l}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 13. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. alpha
#     core type: Literal
#     sub-expressions:
# 15. l
#     core type: Variable
#     sub-expressions:
