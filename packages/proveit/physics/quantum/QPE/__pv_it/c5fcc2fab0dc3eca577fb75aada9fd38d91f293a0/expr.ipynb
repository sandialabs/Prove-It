# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Integers
from proveit.physics.quantum.QPE import ModAdd

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(ModAdd(a, b), Integers), And(InSet(a, Integers), InSet(b, Integers)))
# Out:
# expr: {(a MOD_ADD b) in Integers if a in Integers ,  b in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \oplus b\right) \in \mathbb{Z} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a MOD_ADD b) in Integers if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a MOD_ADD b) in Integers
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in Integers) and (b in Integers)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a MOD_ADD b, Integers)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a MOD_ADD b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in Integers
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in Integers
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. MOD_ADD
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. Integers
#     core type: Literal
#     sub-expressions:
