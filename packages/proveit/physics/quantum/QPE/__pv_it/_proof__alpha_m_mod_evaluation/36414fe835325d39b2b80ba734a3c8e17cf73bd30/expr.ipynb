# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals
from proveit.numbers import Exp, Mod, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _alpha_m_mod_two_pow_t, _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(_alpha_m_mod_two_pow_t, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, Mod(m, _two_pow_t)), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k))), domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \alpha_{m ~\textup{mod}~ 2^{t}} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(m ~\textup{mod}~ 2^{t}\right)}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha_{m mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha_{m mod 2^{t}}
#    core type: Operation
#    operator: 5
#    operand: 51
# 4. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k}))
#    core type: Operation
#    operator: 46
#    operands: 7
# 5. alpha
#    core type: Literal
#    sub-expressions:
# 6. (m mod 2^{t})
#    core type: ExprTuple
#    sub-expressions: 51
# 7. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. 1 / 2^{t}
#    core type: Operation
#    operator: 40
#    operands: 10
# 9. Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k})
#    core type: Operation
#    operator: 11
#    operand: 13
# 10. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45, 55
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 50
#     body: 15
# 14. (k)
#     core type: ExprTuple
#     sub-expressions: 50
# 15. {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 46
#     operands: 18
# 17. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 50, 23
# 21. e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})}
#     core type: Operation
#     operator: 56
#     operands: 24
# 22. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 25
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (e, -((2 * pi * i * k * (m mod 2^{t})) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. -((2 * pi * i * k * (m mod 2^{t})) / 2^{t})
#     core type: Operation
#     operator: 42
#     operand: 37
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 46
#     operands: 34
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. ((2 * pi * i * k * (m mod 2^{t})) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 58, 48, 49, 38, 50
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 39
# 37. (2 * pi * i * k * (m mod 2^{t})) / 2^{t}
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. phase
#     core type: Literal
#     sub-expressions:
# 39. -1
#     core type: Operation
#     operator: 42
#     operand: 45
# 40. /
#     core type: Literal
#     sub-expressions:
# 41. (2 * pi * i * k * (m mod 2^{t}), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44, 55
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. 2 * pi * i * k * (m mod 2^{t})
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2, pi, i, k, m mod 2^{t})
#     core type: ExprTuple
#     sub-expressions: 58, 48, 49, 50, 51
# 48. pi
#     core type: Literal
#     sub-expressions:
# 49. i
#     core type: Literal
#     sub-expressions:
# 50. k
#     core type: Variable
#     sub-expressions:
# 51. m mod 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 52. mod
#     core type: Literal
#     sub-expressions:
# 53. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. m
#     core type: Variable
#     sub-expressions:
# 55. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. t
#     core type: Literal
#     sub-expressions:
