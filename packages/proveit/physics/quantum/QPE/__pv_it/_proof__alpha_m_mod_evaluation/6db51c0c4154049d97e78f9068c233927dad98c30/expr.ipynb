# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, m
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Exp, Mod, Mult, Neg, e, frac, i, pi, two
from proveit.physics.quantum.QPE import _m_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t)))
sub_expr2 = InSet(k, _m_domain)
sub_expr3 = Exp(e, Neg(frac(Mult(two, pi, i, k, Mod(m, _two_pow_t)), _two_pow_t)))
expr = Implies(Forall(instance_param_or_params = [k], instance_expr = Equals(sub_expr3, sub_expr1), domain = _m_domain), Equals(Lambda(k, Conditional(sub_expr3, sub_expr2)), Lambda(k, Conditional(sub_expr1, sub_expr2))).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(m ~\textup{mod}~ 2^{t}\right)}{2^{t}}} = \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(m ~\textup{mod}~ 2^{t}\right)}{2^{t}}} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {0 .. 2^{t} - 1}} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})})] =>  \\ ([k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {0 .. 2^{t} - 1}} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})}), [k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {0 .. 2^{t} - 1}} (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}., k -> {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 54
#    body: 11
# 9. k -> {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 54
#    body: 12
# 10. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 54
#     body: 14
# 11. {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. {e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 21
#     condition: 16
# 13. (k)
#     core type: ExprTuple
#     sub-expressions: 54
# 14. {e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 22
#     condition: 16
# 15. e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})} = e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 23
# 21. e^{-((2 * pi * i * k * (m mod 2^{t})) / 2^{t})}
#     core type: Operation
#     operator: 59
#     operands: 24
# 22. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 59
#     operands: 25
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (e, -((2 * pi * i * k * (m mod 2^{t})) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. -((2 * pi * i * k * (m mod 2^{t})) / 2^{t})
#     core type: Operation
#     operator: 43
#     operand: 37
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 43
#     operand: 38
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. ((2 * pi * i * k * (m mod 2^{t})) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 58, 39
# 37. (2 * pi * i * k * (m mod 2^{t})) / 2^{t}
#     core type: Operation
#     operator: 41
#     operands: 40
# 38. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. -1
#     core type: Operation
#     operator: 43
#     operand: 47
# 40. (2 * pi * i * k * (m mod 2^{t}), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45, 58
# 41. /
#     core type: Literal
#     sub-expressions:
# 42. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46, 58
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 47
# 45. 2 * pi * i * k * (m mod 2^{t})
#     core type: Operation
#     operator: 49
#     operands: 48
# 46. 2 * pi * i * k * m
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. (2, pi, i, k, m mod 2^{t})
#     core type: ExprTuple
#     sub-expressions: 61, 52, 53, 54, 51
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 61, 52, 53, 54, 57
# 51. m mod 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. pi
#     core type: Literal
#     sub-expressions:
# 53. i
#     core type: Literal
#     sub-expressions:
# 54. k
#     core type: Variable
#     sub-expressions:
# 55. mod
#     core type: Literal
#     sub-expressions:
# 56. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. m
#     core type: Variable
#     sub-expressions:
# 58. 2^{t}
#     core type: Operation
#     operator: 59
#     operands: 60
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t
#     core type: Literal
#     sub-expressions:
