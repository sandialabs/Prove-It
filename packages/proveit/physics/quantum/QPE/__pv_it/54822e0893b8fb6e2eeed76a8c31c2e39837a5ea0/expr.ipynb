# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Integers
from proveit.physics.quantum.QPE import ModAdd

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(InSet(ModAdd(a, b), Integers), And(InSet(a, Integers), InSet(b, Integers))))
# Out:
# expr: (a, b) -> {(a MOD_ADD b) in Integers if a in Integers ,  b in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(a \oplus b\right) \in \mathbb{Z} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {(a MOD_ADD b) in Integers if a in Integers ,  b in Integers.
#    core type: Lambda
#    parameters: 11\n   body: 1
# 1. {(a MOD_ADD b) in Integers if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a MOD_ADD b) in Integers
#    core type: Operation
#    operator: 13
#    operands: 4
# 3. (a in Integers) and (b in Integers)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a MOD_ADD b, Integers)
#    core type: ExprTuple
#    sub-expressions: 7, 17
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a MOD_ADD b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a in Integers
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b in Integers
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (a, Integers)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b, Integers)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. Integers
#     core type: Literal
#     sub-expressions:
