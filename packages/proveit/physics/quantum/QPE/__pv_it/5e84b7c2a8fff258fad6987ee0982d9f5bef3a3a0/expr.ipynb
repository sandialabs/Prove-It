# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import eps, l
from proveit.logic import Equals
from proveit.number import Interval, Neg, Sum
from proveit.physics.quantum.QPE import ModAdd, Psuccess
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Psuccess(eps), Sum([l], Prob(Equals(Literal("m", context = "proveit.physics.quantum.QPE"), ModAdd(Literal("b", context = "proveit.physics.quantum.QPE"), l)), Literal("m", context = "proveit.physics.quantum.QPE")), domain = Interval(Neg(eps), eps)))
# Out:
# expr: ([Psuccess](eps), Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[P_{\rm success}\right]\left(\varepsilon\right), \sum_{l=-\varepsilon}^{\varepsilon} Pr_{m}[m = \left(b \oplus l\right)]\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ([Psuccess](eps), Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [Psuccess](eps)
#    core type: Operation
#    operator: 3
#    operand: 25
# 2. Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)]
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. Psuccess
#    core type: Literal
#    sub-expressions:
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. l -> {Pr_{m}[m = (b MOD_ADD l)] if l in {-eps...eps}.
#    core type: Lambda
#    parameter: 27
#    body: 6
# 6. {Pr_{m}[m = (b MOD_ADD l)] if l in {-eps...eps}.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. Pr_{m}[m = (b MOD_ADD l)]
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. l in {-eps...eps}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. PROB
#    core type: Literal
#    sub-expressions:
# 10. (m = (b MOD_ADD l), m)
#     core type: ExprTuple
#     sub-expressions: 13, 19
# 11. in
# ...
