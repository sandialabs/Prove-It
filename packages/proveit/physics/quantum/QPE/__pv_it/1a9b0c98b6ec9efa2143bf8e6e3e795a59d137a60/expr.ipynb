# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#alpha_l_summed_abs">alpha_l_summed_abs</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import alpha_l_summed_abs

# %%
# check that the built expression is the same as the stored expression
# %check_expr alpha_l_summed_abs
# Out:
# Passed sanity check: built 'alpha_l_summed_abs' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(alpha_l_summed_abs.latex())
# Out:
# \vdash \forall_{l \in \mathbb{Z}}~\left(\left|\alpha_{l}\right| = \frac{\left|1 - e^{2 \cdot \pi \cdot i \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right|}{2^{t} \cdot \left|1 - e^{2 \cdot \pi \cdot i \cdot \left(\delta - \frac{l}{2^{t}}\right)}\right|}\right)

# %%
# display the expression information
alpha_l_summed_abs.exprInfo()
# Out:
# 0. forall_{l in Integers} (|alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {|alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)) if l in Integers.
#    core type: Lambda
#    parameter: 56
#    body: 3
# 3. {|alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)) if l in Integers.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. l in Integers
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, Integers)
#    core type: ExprTuple
#    sub-expressions: 56, 12
# 10. |alpha_{l}|
#     core type: Operation
#     operator: 25
#     operand: 13
# 11. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)
#     core type: Operation
#     operator: 54
#     operands: 14
# 12. Integers
#     core type: Literal
#     sub-expressions:
# 13. alpha_{l}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, 2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 16. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 19, 56
# 17. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|
#     core type: Operation
#     operator: 25
#     operand: 20
# 18. 2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|
#     core type: Operation
#     operator: 46
#     operands: 21
# 19. alpha
#     core type: Literal
#     sub-expressions:
# 20. 1 - e^{2 * pi * i * ((2^{t} * delta) - l)}
#     core type: Operation
#     operator: 48
#     operands: 22
# 21. (2^{t}, |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)
#     core type: ExprTuple
#     sub-expressions: 57, 23
# 22. (1, -e^{2 * pi * i * ((2^{t} * delta) - l)})
#     core type: ExprTuple
#     sub-expressions: 30, 24
# 23. |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|
#     core type: Operation
#     operator: 25
#     operand: 26
# 24. -e^{2 * pi * i * ((2^{t} * delta) - l)}
#     core type: Operation
#     operator: 52
#     operand: 27
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. 1 - e^{2 * pi * i * (delta - (l / 2^{t}))}
#     core type: Operation
#     operator: 48
#     operands: 28
# 27. e^{2 * pi * i * ((2^{t} * delta) - l)}
#     core type: Operation
#     operator: 58
#     operands: 29
# 28. (1, -e^{2 * pi * i * (delta - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. (e, 2 * pi * i * ((2^{t} * delta) - l))
#     core type: ExprTuple
#     sub-expressions: 37, 32
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. -e^{2 * pi * i * (delta - (l / 2^{t}))}
#     core type: Operation
#     operator: 52
#     operand: 33
# 32. 2 * pi * i * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 46
#     operands: 34
# 33. e^{2 * pi * i * (delta - (l / 2^{t}))}
#     core type: Operation
#     operator: 58
#     operands: 35
# 34. (2, pi, i, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 60, 43, 44, 36
# 35. (e, 2 * pi * i * (delta - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. (2^{t} * delta) - l
#     core type: Operation
#     operator: 48
#     operands: 39
# 37. e
#     core type: Literal
#     sub-expressions:
# 38. 2 * pi * i * (delta - (l / 2^{t}))
#     core type: Operation
#     operator: 46
#     operands: 40
# 39. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. (2, pi, i, delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 60, 43, 44, 45
# 41. 2^{t} * delta
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. -l
#     core type: Operation
#     operator: 52
#     operand: 56
# 43. pi
#     core type: Literal
#     sub-expressions:
# 44. i
#     core type: Literal
#     sub-expressions:
# 45. delta - (l / 2^{t})
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 57, 50
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. delta
#     core type: Literal
#     sub-expressions:
# 51. -(l / 2^{t})
#     core type: Operation
#     operator: 52
#     operand: 53
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. l / 2^{t}
#     core type: Operation
#     operator: 54
#     operands: 55
# 54. /
#     core type: Literal
#     sub-expressions:
# 55. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. l
#     core type: Variable
#     sub-expressions:
# 57. 2^{t}
#     core type: Operation
#     operator: 58
#     operands: 59
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Literal
#     sub-expressions:
