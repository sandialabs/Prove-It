# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Literal
from proveit._common_ import a, b
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Exp, Integers, Mod, two
from proveit.physics.quantum.QPE import ModAdd

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(ModAdd(a, b), Mod(Add(a, b), Exp(two, Literal("t", context = "proveit.physics.quantum.QPE")))), And(InSet(a, Integers), InSet(b, Integers)))
# Out:
# expr: {(a MOD_ADD b) = ((a + b) mod  2^{t}) if a in Integers ,  b in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a \oplus b\right) = \left(\left(a + b\right) ~\textup{mod}~ 2^{t}\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a MOD_ADD b) = ((a + b) mod  2^{t}) if a in Integers ,  b in Integers.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a MOD_ADD b) = ((a + b) mod  2^{t})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integers) and (b in Integers)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a MOD_ADD b, (a + b) mod  2^{t})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integers, b in Integers)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. a MOD_ADD b
#    core type: Operation
#    operator: 11
#    operands: 21
# 8. (a + b) mod  2^{t}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. a in Integers
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. b in Integers
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. MOD_ADD
# ...
