# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit._common_ import k
from proveit.number import Exp, Mult, e, i, pi, two
from proveit.physics.quantum import Ket

# %%
# build up the expression from sub-expressions
expr = Mult(Exp(e, Mult(two, pi, i, Literal("phase", latexFormat = r"\varphi", context = "proveit.physics.quantum.QPE"), k)), Ket(k))
# Out:
# expr: e^{2 * pi * i * phase * k} * |k〉

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# e^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. |k〉
#    core type: Operation
#    operator: 6
#    operand: 15
# 4. Exp
#    core type: Literal
#    sub-expressions:
# 5. (e, 2 * pi * i * phase * k)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. KET
#    core type: Literal
#    sub-expressions:
# 7. e
#    core type: Literal
#    sub-expressions:
# 8. 2 * pi * i * phase * k
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13, 14, 15
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. pi
#     core type: Literal
#     sub-expressions:
# 13. i
#     core type: Literal
#     sub-expressions:
# 14. phase
#     core type: Literal
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
