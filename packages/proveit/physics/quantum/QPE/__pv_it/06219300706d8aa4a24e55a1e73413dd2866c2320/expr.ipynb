# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import eps, l
from proveit.number import Abs, Add, Exp, Interval, Neg, Sum, one, two
from proveit.physics.quantum.QPE import Pfail, SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = [l]
subExpr2 = Add(eps, one)
subExpr3 = Exp(Abs(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l)), two)
subExpr4 = Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))
expr = ExprTuple(Pfail(eps), Add(Sum(subExpr1, subExpr3, domain = Interval(Add(Neg(subExpr4), one), Neg(subExpr2))), Sum(subExpr1, subExpr3, domain = Interval(subExpr2, subExpr4))))
# Out:
# expr: ([Pfail](eps), (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left[P_{\rm fail}\right]\left(\varepsilon\right), \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ([Pfail](eps), (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [Pfail](eps)
#    core type: Operation
#    operator: 3
#    operand: 38
# 2. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})
#    core type: Operation
#    operator: 43
#    operands: 4
# 3. Pfail
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}, Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 8
#    operand: 7
# 6. Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 34
#    body: 10
# 8. Sum
#    core type: Literal
#    sub-expressions:
# 9. l -> {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 34
#    body: 11
# 10. {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#     core type: Conditional
#     value: 13
#     condition: 12
# 11. {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. l in {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 17
#     operands: 15
# 13. |alpha_{l}|^{2}
#     core type: Operation
#     operator: 39
#     operands: 16
# 14. l in {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (l, {-2^{t - 1} + 1...-(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 34, 19
# 16. (|alpha_{l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 20, 41
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (l, {eps + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 34, 21
# 19. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 25
#     operands: 22
# 20. |alpha_{l}|
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. {eps + 1...2^{t - 1}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. Abs
#     core type: Literal
#     sub-expressions:
# 24. alpha_{l}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 32, 37
# 27. -2^{t - 1} + 1
#     core type: Operation
#     operator: 43
#     operands: 31
# 28. -(eps + 1)
#     core type: Operation
#     operator: 47
#     operand: 32
# 29. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 30. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 48
# 32. eps + 1
#     core type: Operation
#     operator: 43
#     operands: 36
# 33. alpha
#     core type: Literal
#     sub-expressions:
# 34. l
#     core type: Variable
#     sub-expressions:
# 35. -2^{t - 1}
#     core type: Operation
#     operator: 47
#     operand: 37
# 36. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 48
# 37. 2^{t - 1}
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. eps
#     core type: Variable
#     sub-expressions:
# 39. Exp
#     core type: Literal
#     sub-expressions:
# 40. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 2
#     core type: Literal
#     sub-expressions:
# 42. t - 1
#     core type: Operation
#     operator: 43
#     operands: 44
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. t
#     core type: Literal
#     sub-expressions:
# 46. -1
#     core type: Operation
#     operator: 47
#     operand: 48
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. 1
#     core type: Literal
#     sub-expressions:
