# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _ket_u, _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order()
expr = ExprTuple(TensorProd(TensorProd(sub_expr2), _ket_u), TensorProd(sub_expr2, _ket_u))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right) {\otimes} \lvert u \rangle, \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \lvert u \rangle\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) otimes |u>, ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))) otimes |u>)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) otimes |u>
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))) otimes |u>
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))), |u>)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))), |u>)
#    core type: ExprTuple
#    sub-expressions: 9, 6
# 5. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. |u>
#    core type: Literal
#    sub-expressions:
# 7. otimes
#    core type: Literal
#    sub-expressions:
# 8. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 9
# 9. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 32
# 10. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 55
#     body: 12
# 11. -t + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 29
#     operands: 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 42
# 15. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. -t
#     core type: Operation
#     operator: 53
#     operand: 23
# 17. 1 / sqrt(2)
#     core type: Operation
#     operator: 35
#     operands: 20
# 18. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (t)
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 42, 24
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. t
#     core type: Variable
#     sub-expressions:
# 24. sqrt(2)
#     core type: Operation
#     operator: 49
#     operands: 27
# 25. |0〉
#     core type: Operation
#     operator: 38
#     operand: 32
# 26. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 51, 31
# 28. (0)
#     core type: ExprTuple
#     sub-expressions: 32
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. 1 / 2
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 49
#     operands: 37
# 34. |1〉
#     core type: Operation
#     operator: 38
#     operand: 42
# 35. /
#     core type: Literal
#     sub-expressions:
# 36. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 42, 51
# 37. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. KET
#     core type: Literal
#     sub-expressions:
# 39. (1)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. e
#     core type: Literal
#     sub-expressions:
# 41. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 51, 45, 46, 47, 48
# 45. pi
#     core type: Literal
#     sub-expressions:
# 46. i
#     core type: Literal
#     sub-expressions:
# 47. 2^{-_a}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. phase
#     core type: Literal
#     sub-expressions:
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. 2
#     core type: Literal
#     sub-expressions:
# 52. -_a
#     core type: Operation
#     operator: 53
#     operand: 55
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. _a
#     core type: Variable
#     sub-expressions:
