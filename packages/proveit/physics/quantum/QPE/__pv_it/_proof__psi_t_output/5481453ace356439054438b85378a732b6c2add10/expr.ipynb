# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(Add(Neg(t), one))), _phase)), ket1))), part = one)
expr = Equals(MultiQubitElem(element = sub_expr1, targets = Interval(Add(zero, one), one)), MultiQubitElem(element = sub_expr1, targets = Interval(one, one)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{0 + 1~\ldotp \ldotp~1\}}
# } \end{array} = \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~1\}}
# } \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}} = [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}
#    core type: NamedExprs
#    element: 9
#    targets: 8
# 6. MULTI_QUBIT_ELEM
#    core type: Literal
#    sub-expressions:
# 7. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}}
#    core type: NamedExprs
#    element: 9
#    targets: 10
# 8. {0 + 1 .. 1}
#    core type: Operation
#    operator: 14
#    operands: 11
# 9. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {1 .. 1}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (0 + 1, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 58
# 12. OUTPUT
#     core type: Literal
#     sub-expressions:
# 13. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}
#     core type: NamedExprs
#     state: 17
#     part: 58
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (1, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 58
# 16. 0 + 1
#     core type: Operation
#     operator: 55
#     operands: 18
# 17. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: Operation
#     operator: 30
#     operands: 19
# 18. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 58
# 19. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 1 / sqrt(2)
#     core type: Operation
#     operator: 36
#     operands: 22
# 21. |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 58, 25
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (|0〉, e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. sqrt(2)
#     core type: Operation
#     operator: 49
#     operands: 28
# 26. |0〉
#     core type: Operation
#     operator: 39
#     operand: 33
# 27. e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 51, 32
# 29. (0)
#     core type: ExprTuple
#     sub-expressions: 33
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (e^{2 * pi * i * 2^{-(-t + 1)} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. 1 / 2
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. e^{2 * pi * i * 2^{-(-t + 1)} * phase}
#     core type: Operation
#     operator: 49
#     operands: 38
# 35. |1〉
#     core type: Operation
#     operator: 39
#     operand: 58
# 36. /
#     core type: Literal
#     sub-expressions:
# 37. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 38. (e, 2 * pi * i * 2^{-(-t + 1)} * phase)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. KET
#     core type: Literal
#     sub-expressions:
# 40. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 41. e
#     core type: Literal
#     sub-expressions:
# 42. 2 * pi * i * 2^{-(-t + 1)} * phase
#     core type: Operation
#     operator: 43
#     operands: 44
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (2, pi, i, 2^{-(-t + 1)}, phase)
#     core type: ExprTuple
#     sub-expressions: 51, 45, 46, 47, 48
# 45. pi
#     core type: Literal
#     sub-expressions:
# 46. i
#     core type: Literal
#     sub-expressions:
# 47. 2^{-(-t + 1)}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. phase
#     core type: Literal
#     sub-expressions:
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, -(-t + 1))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. 2
#     core type: Literal
#     sub-expressions:
# 52. -(-t + 1)
#     core type: Operation
#     operator: 59
#     operand: 54
# 53. (-t + 1)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. -t + 1
#     core type: Operation
#     operator: 55
#     operands: 56
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. -t
#     core type: Operation
#     operator: 59
#     operand: 61
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (t)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. t
#     core type: Variable
#     sub-expressions:
