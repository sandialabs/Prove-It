# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, t
from proveit.linear_algebra import MatrixExp, MatrixMult, ScalarMult
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, i, one, pi, two, zero
from proveit.physics.quantum.QPE import _U, _ket_u, _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Exp(two, Neg(sub_expr1))
sub_expr3 = Add(Neg(t), one)
sub_expr4 = Equals(MatrixMult(MatrixExp(_U, sub_expr2), _ket_u), ScalarMult(Exp(e, Mult(two, pi, i, Mult(sub_expr2, _phase))), _ket_u))
expr = ExprTuple(Forall(instance_param_or_params = [sub_expr1], instance_expr = sub_expr4, domain = Interval(sub_expr3, zero)), And(ExprRange(sub_expr1, sub_expr4, sub_expr3, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{{_{-}a} \in \{-t + 1~\ldotp \ldotp~0\}}~\left(\left(U^{2^{-{_{-}a}}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-{_{-}a}} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right), \left(\left(U^{2^{-\left(-t + 1\right)}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-\left(-t + 1\right)} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right) \land  \left(\left(U^{2^{-\left(-t + 2\right)}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-\left(-t + 2\right)} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right) \land  \ldots \land  \left(\left(U^{2^{-0}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-0} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{_a in {-t + 1 .. 0}} ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>)), ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)) and  ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)) and  ... and  ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{_a in {-t + 1 .. 0}} ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)) and  ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)) and  ... and  ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (_a -> {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)), ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)), ..., ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>)))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. _a -> {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.
#    core type: Lambda
#    parameter: 57
#    body: 9
# 8. ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)), ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)), ..., ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>))
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 26
#    end_index: 27
# 9. {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.
#    core type: Conditional
#    value: 12
#    condition: 11
# 10. _a -> ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>))
#     core type: Lambda
#     parameter: 57
#     body: 12
# 11. _a in {-t + 1 .. 0}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (_a, {-t + 1 .. 0})
#     core type: ExprTuple
#     sub-expressions: 57, 17
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (U^{2^{-_a}} . |u>, e^{2 * pi * i * (2^{-_a} * phase)} * |u>)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {-t + 1 .. 0}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. U^{2^{-_a}} . |u>
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. e^{2 * pi * i * (2^{-_a} * phase)} * |u>
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (-t + 1, 0)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. .
#     core type: Literal
#     sub-expressions:
# 23. (U^{2^{-_a}}, |u>)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (e^{2 * pi * i * (2^{-_a} * phase)}, |u>)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. -t + 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. 0
#     core type: Literal
#     sub-expressions:
# 28. U^{2^{-_a}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. e^{2 * pi * i * (2^{-_a} * phase)}
#     core type: Operation
#     operator: 51
#     operands: 35
# 30. |u>
#     core type: Literal
#     sub-expressions:
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. ExpM
#     core type: Literal
#     sub-expressions:
# 34. (U, 2^{-_a})
#     core type: ExprTuple
#     sub-expressions: 38, 49
# 35. (e, 2 * pi * i * (2^{-_a} * phase))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. -t
#     core type: Operation
#     operator: 55
#     operand: 43
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. U
#     core type: Literal
#     sub-expressions:
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. 2 * pi * i * (2^{-_a} * phase)
#     core type: Operation
#     operator: 47
#     operands: 42
# 41. (t)
#     core type: ExprTuple
#     sub-expressions: 43
# 42. (2, pi, i, 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 53, 44, 45, 46
# 43. t
#     core type: Variable
#     sub-expressions:
# 44. pi
#     core type: Literal
#     sub-expressions:
# 45. i
#     core type: Literal
#     sub-expressions:
# 46. 2^{-_a} * phase
#     core type: Operation
#     operator: 47
#     operands: 48
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 49. 2^{-_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. phase
#     core type: Literal
#     sub-expressions:
# 51. Exp
#     core type: Literal
#     sub-expressions:
# 52. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. -_a
#     core type: Operation
#     operator: 55
#     operand: 57
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _a
#     core type: Variable
#     sub-expressions:
