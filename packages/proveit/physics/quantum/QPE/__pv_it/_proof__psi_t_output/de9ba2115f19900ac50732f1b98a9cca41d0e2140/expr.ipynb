# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _ket_u, _phase, _s
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Neg(t)
sub_expr3 = Add(sub_expr2, one)
sub_expr4 = frac(one, sqrt(two))
sub_expr5 = ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(t, one), Add(t, _s))), one, _s).with_wrapping_at(2,6)
sub_expr6 = Output(state = ScalarMult(sub_expr4, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))))
expr = Equals([Output(state = ScalarMult(sub_expr4, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr3)), _phase)), ket1)))), ExprRange(sub_expr1, sub_expr6, Add(sub_expr2, two), zero).with_decreasing_order(), sub_expr5], [ExprRange(sub_expr1, sub_expr6, sub_expr3, zero).with_decreasing_order(), sub_expr5]).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 3} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right) =  \\ \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}) =  \\ ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 8
# 4. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: Operation
#    operator: 27
#    operands: 9
# 6. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 10
#    end_index: 55
# 7. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 78
#    end_index: 55
# 8. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 85
#    end_index: 47
# 9. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: NamedExprs
#    state: 13
# 10. -t + 2
#     core type: Operation
#     operator: 81
#     operands: 14
# 11. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Lambda
#     parameter: 86
#     body: 15
# 12. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 86
#     body: 16
# 13. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: Operation
#     operator: 51
#     operands: 17
# 14. (-t, 2)
#     core type: ExprTuple
#     sub-expressions: 84, 79
# 15. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Operation
#     operator: 27
#     operands: 18
# 16. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 32, 21
# 18. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: NamedExprs
#     state: 22
# 19. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 20. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 23
#     targets: 24
# 21. |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: Operation
#     operator: 39
#     operands: 25
# 22. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 51
#     operands: 26
# 23. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. {t + 1 .. t + s}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (|0〉, e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 45, 31
# 26. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. OUTPUT
#     core type: Literal
#     sub-expressions:
# 28. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 34
#     part: 86
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉
#     core type: Operation
#     operator: 51
#     operands: 37
# 32. 1 / sqrt(2)
#     core type: Operation
#     operator: 59
#     operands: 38
# 33. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. |u>
#     core type: Literal
#     sub-expressions:
# 35. t + 1
#     core type: Operation
#     operator: 81
#     operands: 41
# 36. t + s
#     core type: Operation
#     operator: 81
#     operands: 42
# 37. (e^{2 * pi * i * 2^{-(-t + 1)} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 43, 57
# 38. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 85, 44
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 41. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 89, 85
# 42. (t, s)
#     core type: ExprTuple
#     sub-expressions: 89, 47
# 43. e^{2 * pi * i * 2^{-(-t + 1)} * phase}
#     core type: Operation
#     operator: 76
#     operands: 48
# 44. sqrt(2)
#     core type: Operation
#     operator: 76
#     operands: 49
# 45. |0〉
#     core type: Operation
#     operator: 62
#     operand: 55
# 46. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. s
#     core type: Literal
#     sub-expressions:
# 48. (e, 2 * pi * i * 2^{-(-t + 1)} * phase)
#     core type: ExprTuple
#     sub-expressions: 65, 53
# 49. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 79, 54
# 50. (0)
#     core type: ExprTuple
#     sub-expressions: 55
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 53. 2 * pi * i * 2^{-(-t + 1)} * phase
#     core type: Operation
#     operator: 68
#     operands: 58
# 54. 1 / 2
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. 0
#     core type: Literal
#     sub-expressions:
# 56. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 76
#     operands: 61
# 57. |1〉
#     core type: Operation
#     operator: 62
#     operand: 85
# 58. (2, pi, i, 2^{-(-t + 1)}, phase)
#     core type: ExprTuple
#     sub-expressions: 79, 71, 72, 64, 74
# 59. /
#     core type: Literal
#     sub-expressions:
# 60. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 85, 79
# 61. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 62. KET
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 85
# 64. 2^{-(-t + 1)}
#     core type: Operation
#     operator: 76
#     operands: 67
# 65. e
#     core type: Literal
#     sub-expressions:
# 66. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 68
#     operands: 69
# 67. (2, -(-t + 1))
#     core type: ExprTuple
#     sub-expressions: 79, 70
# 68. *
#     core type: Literal
#     sub-expressions:
# 69. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 79, 71, 72, 73, 74
# 70. -(-t + 1)
#     core type: Operation
#     operator: 87
#     operand: 78
# 71. pi
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Literal
#     sub-expressions:
# 73. 2^{-_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 74. phase
#     core type: Literal
#     sub-expressions:
# 75. (-t + 1)
#     core type: ExprTuple
#     sub-expressions: 78
# 76. Exp
#     core type: Literal
#     sub-expressions:
# 77. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 78. -t + 1
#     core type: Operation
#     operator: 81
#     operands: 82
# 79. 2
#     core type: Literal
#     sub-expressions:
# 80. -_a
#     core type: Operation
#     operator: 87
#     operand: 86
# 81. +
#     core type: Literal
#     sub-expressions:
# 82. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 83. (_a)
#     core type: ExprTuple
#     sub-expressions: 86
# 84. -t
#     core type: Operation
#     operator: 87
#     operand: 89
# 85. 1
#     core type: Literal
#     sub-expressions:
# 86. _a
#     core type: Variable
#     sub-expressions:
# 87. -
#     core type: Literal
#     sub-expressions:
# 88. (t)
#     core type: ExprTuple
#     sub-expressions: 89
# 89. t
#     core type: Variable
#     sub-expressions:
