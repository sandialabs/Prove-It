# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(Add(Neg(t), one))), _phase)), ket1))), part = one)
expr = ExprTuple(MultiQubitElem(element = sub_expr1, targets = Interval(Add(zero, one), one)), MultiQubitElem(element = sub_expr1, targets = Interval(one, one)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{0 + 1~\ldotp \ldotp~1\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~1\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{0 + 1 .. 1}}
#    core type: NamedExprs
#    element: 7
#    targets: 6
# 4. MULTI_QUBIT_ELEM
#    core type: Literal
#    sub-expressions:
# 5. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}, targets:{1 .. 1}}
#    core type: NamedExprs
#    element: 7
#    targets: 8
# 6. {0 + 1 .. 1}
#    core type: Operation
#    operator: 12
#    operands: 9
# 7. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. {1 .. 1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (0 + 1, 1)
#    core type: ExprTuple
#    sub-expressions: 14, 56
# 10. OUTPUT
#     core type: Literal
#     sub-expressions:
# 11. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), part:1}
#     core type: NamedExprs
#     state: 15
#     part: 56
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (1, 1)
#     core type: ExprTuple
#     sub-expressions: 56, 56
# 14. 0 + 1
#     core type: Operation
#     operator: 53
#     operands: 16
# 15. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: Operation
#     operator: 28
#     operands: 17
# 16. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 31, 56
# 17. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 1 / sqrt(2)
#     core type: Operation
#     operator: 34
#     operands: 20
# 19. |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 56, 23
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (|0〉, e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. sqrt(2)
#     core type: Operation
#     operator: 47
#     operands: 26
# 24. |0〉
#     core type: Operation
#     operator: 37
#     operand: 31
# 25. e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 49, 30
# 27. (0)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (e^{2 * pi * i * 2^{-(-t + 1)} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. 1 / 2
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. e^{2 * pi * i * 2^{-(-t + 1)} * phase}
#     core type: Operation
#     operator: 47
#     operands: 36
# 33. |1〉
#     core type: Operation
#     operator: 37
#     operand: 56
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 56, 49
# 36. (e, 2 * pi * i * 2^{-(-t + 1)} * phase)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. KET
#     core type: Literal
#     sub-expressions:
# 38. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. 2 * pi * i * 2^{-(-t + 1)} * phase
#     core type: Operation
#     operator: 41
#     operands: 42
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (2, pi, i, 2^{-(-t + 1)}, phase)
#     core type: ExprTuple
#     sub-expressions: 49, 43, 44, 45, 46
# 43. pi
#     core type: Literal
#     sub-expressions:
# 44. i
#     core type: Literal
#     sub-expressions:
# 45. 2^{-(-t + 1)}
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. phase
#     core type: Literal
#     sub-expressions:
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (2, -(-t + 1))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 49. 2
#     core type: Literal
#     sub-expressions:
# 50. -(-t + 1)
#     core type: Operation
#     operator: 57
#     operand: 52
# 51. (-t + 1)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. -t + 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. -t
#     core type: Operation
#     operator: 57
#     operand: 59
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (t)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. t
#     core type: Variable
#     sub-expressions:
