# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, VertExprArray, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _ket_u, _phase, _psi_t_ket, _s
from proveit.physics.quantum.circuits import MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(t, one)
sub_expr3 = Add(t, _s)
sub_expr4 = Add(Neg(t), one)
sub_expr5 = TensorProd(_psi_t_ket, _ket_u)
sub_expr6 = Interval(one, sub_expr3)
expr = ExprTuple(Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1)))), sub_expr4, zero).with_decreasing_order(), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(sub_expr2, sub_expr3)), one, _s).with_wrapping_at(2,6)])), Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, MultiQubitElem(element = Output(state = sub_expr5, part = Add(sub_expr1, t)), targets = sub_expr6), sub_expr4, zero), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = sub_expr5, part = sub_expr1), targets = sub_expr6), sub_expr2, sub_expr3).with_wrapping_at(2,6)])))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\vdots} \\
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\lvert u \rangle}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \multiqout{1}{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle} \\
# & \ghostqout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle} \\
# & \qout{\vdots} \qwx[1] \\
# & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~0 + t~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} \qwx[1] \\
# & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (QCIRCUIT(VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))), QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 1) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. QCIRCUIT(VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 1) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 1) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 1) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 15
#    end_index: 70
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 81
#    end_index: 62
# 10. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 1) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 70
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 44
#     end_index: 47
# 12. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Lambda
#     parameter: 94
#     body: 17
# 13. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 94
#     body: 18
# 14. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 94
#     body: 19
# 15. -t + 1
#     core type: Operation
#     operator: 55
#     operands: 20
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 94
#     body: 21
# 17. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Operation
#     operator: 38
#     operands: 22
# 18. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 26
#     operands: 23
# 19. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 26
#     operands: 24
# 20. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 81
# 21. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: NamedExprs
#     state: 28
# 23. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 29
#     targets: 30
# 24. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 31
#     targets: 33
# 25. -t
#     core type: Operation
#     operator: 92
#     operand: 73
# 26. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 27. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 32
#     targets: 33
# 28. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 65
#     operands: 34
# 29. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 38
#     operands: 35
# 30. {t + 1 .. t + s}
#     core type: Operation
#     operator: 40
#     operands: 36
# 31. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. {1 .. t + s}
#     core type: Operation
#     operator: 40
#     operands: 41
# 34. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 35. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 61
#     part: 94
# 36. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 44, 47
# 37. {state:(|psi_{t}> otimes |u>), part:(_a + t)}
#     core type: NamedExprs
#     state: 46
#     part: 45
# 38. OUTPUT
#     core type: Literal
#     sub-expressions:
# 39. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 46
#     part: 94
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 81, 47
# 42. 1 / sqrt(2)
#     core type: Operation
#     operator: 74
#     operands: 48
# 43. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. t + 1
#     core type: Operation
#     operator: 55
#     operands: 51
# 45. _a + t
#     core type: Operation
#     operator: 55
#     operands: 52
# 46. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 53
#     operands: 54
# 47. t + s
#     core type: Operation
#     operator: 55
#     operands: 56
# 48. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 81, 57
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 51. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 81
# 52. (_a, t)
#     core type: ExprTuple
#     sub-expressions: 94, 73
# 53. otimes
#     core type: Literal
#     sub-expressions:
# 54. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (t, s)
#     core type: ExprTuple
#     sub-expressions: 73, 62
# 57. sqrt(2)
#     core type: Operation
#     operator: 88
#     operands: 63
# 58. |0〉
#     core type: Operation
#     operator: 77
#     operand: 70
# 59. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. |psi_{t}>
#     core type: Operation
#     operator: 67
#     operand: 73
# 61. |u>
#     core type: Literal
#     sub-expressions:
# 62. s
#     core type: Literal
#     sub-expressions:
# 63. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 90, 69
# 64. (0)
#     core type: ExprTuple
#     sub-expressions: 70
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. psi
#     core type: Literal
#     sub-expressions:
# 68. (t)
#     core type: ExprTuple
#     sub-expressions: 73
# 69. 1 / 2
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. 0
#     core type: Literal
#     sub-expressions:
# 71. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 88
#     operands: 76
# 72. |1〉
#     core type: Operation
#     operator: 77
#     operand: 81
# 73. t
#     core type: Variable
#     sub-expressions:
# 74. /
#     core type: Literal
#     sub-expressions:
# 75. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 81, 90
# 76. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. KET
#     core type: Literal
#     sub-expressions:
# 78. (1)
#     core type: ExprTuple
#     sub-expressions: 81
# 79. e
#     core type: Literal
#     sub-expressions:
# 80. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 82
#     operands: 83
# 81. 1
#     core type: Literal
#     sub-expressions:
# 82. *
#     core type: Literal
#     sub-expressions:
# 83. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 90, 84, 85, 86, 87
# 84. pi
#     core type: Literal
#     sub-expressions:
# 85. i
#     core type: Literal
#     sub-expressions:
# 86. 2^{-_a}
#     core type: Operation
#     operator: 88
#     operands: 89
# 87. phase
#     core type: Literal
#     sub-expressions:
# 88. Exp
#     core type: Literal
#     sub-expressions:
# 89. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 90. 2
#     core type: Literal
#     sub-expressions:
# 91. -_a
#     core type: Operation
#     operator: 92
#     operand: 94
# 92. -
#     core type: Literal
#     sub-expressions:
# 93. (_a)
#     core type: ExprTuple
#     sub-expressions: 94
# 94. _a
#     core type: Variable
#     sub-expressions:
