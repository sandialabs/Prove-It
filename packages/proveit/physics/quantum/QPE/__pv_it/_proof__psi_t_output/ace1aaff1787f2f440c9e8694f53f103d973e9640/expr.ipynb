# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase
from proveit.physics.quantum.circuits import Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = frac(one, sqrt(two))
expr = ExprTuple(Lambda(Variable("_b", latex_format = r"{_{-}b}"), Output(state = ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(Add(Neg(t), one))), _phase)), ket1))))), Lambda(sub_expr1, Output(state = ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left({_{-}b} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (_b -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}, _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. _b -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#    core type: Lambda
#    parameter: 61
#    body: 5
# 3. (_b)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. _b
#    core type: Variable
#    sub-expressions:
# 7. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: NamedExprs
#    state: 10
# 8. OUTPUT
#    core type: Literal
#    sub-expressions:
# 9. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#    core type: NamedExprs
#    state: 11
# 10. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: Operation
#     operator: 28
#     operands: 12
# 11. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 28
#     operands: 13
# 12. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 13. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: Operation
#     operator: 19
#     operands: 17
# 15. 1 / sqrt(2)
#     core type: Operation
#     operator: 36
#     operands: 18
# 16. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (|0〉, e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 18. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 65, 22
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉
#     core type: Operation
#     operator: 28
#     operands: 25
# 22. sqrt(2)
#     core type: Operation
#     operator: 53
#     operands: 26
# 23. |0〉
#     core type: Operation
#     operator: 39
#     operand: 32
# 24. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (e^{2 * pi * i * 2^{-(-t + 1)} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 30, 34
# 26. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 56, 31
# 27. (0)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. e^{2 * pi * i * 2^{-(-t + 1)} * phase}
#     core type: Operation
#     operator: 53
#     operands: 35
# 31. 1 / 2
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. 0
#     core type: Literal
#     sub-expressions:
# 33. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 53
#     operands: 38
# 34. |1〉
#     core type: Operation
#     operator: 39
#     operand: 65
# 35. (e, 2 * pi * i * 2^{-(-t + 1)} * phase)
#     core type: ExprTuple
#     sub-expressions: 42, 41
# 36. /
#     core type: Literal
#     sub-expressions:
# 37. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 65, 56
# 38. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. KET
#     core type: Literal
#     sub-expressions:
# 40. (1)
#     core type: ExprTuple
#     sub-expressions: 65
# 41. 2 * pi * i * 2^{-(-t + 1)} * phase
#     core type: Operation
#     operator: 45
#     operands: 44
# 42. e
#     core type: Literal
#     sub-expressions:
# 43. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 45
#     operands: 46
# 44. (2, pi, i, 2^{-(-t + 1)}, phase)
#     core type: ExprTuple
#     sub-expressions: 56, 48, 49, 47, 51
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 56, 48, 49, 50, 51
# 47. 2^{-(-t + 1)}
#     core type: Operation
#     operator: 53
#     operands: 52
# 48. pi
#     core type: Literal
#     sub-expressions:
# 49. i
#     core type: Literal
#     sub-expressions:
# 50. 2^{-_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. phase
#     core type: Literal
#     sub-expressions:
# 52. (2, -(-t + 1))
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. -(-t + 1)
#     core type: Operation
#     operator: 66
#     operand: 60
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. -_a
#     core type: Operation
#     operator: 66
#     operand: 61
# 58. (-t + 1)
#     core type: ExprTuple
#     sub-expressions: 60
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 60. -t + 1
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 64. -t
#     core type: Operation
#     operator: 66
#     operand: 68
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. -
#     core type: Literal
#     sub-expressions:
# 67. (t)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. t
#     core type: Variable
#     sub-expressions:
