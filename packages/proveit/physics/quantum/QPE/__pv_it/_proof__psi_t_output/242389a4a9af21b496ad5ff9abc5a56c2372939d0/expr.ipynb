# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, ExprTuple, Variable, t
from proveit.core_expr_types import Len
from proveit.linear_algebra import MatrixExp
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import CONTROL
from proveit.physics.quantum.QPE import _U, _s
from proveit.physics.quantum.circuits import Gate, Igate, MultiQubitElem

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr3 = Add(t, one)
sub_expr4 = Add(sub_expr1, t)
sub_expr5 = Add(Neg(t), one)
expr = ExprTuple(Len(operands = [ExprRange(sub_expr1, [ExprRange(sub_expr2, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr4, sub_expr2)), Conditional(Igate, NotEquals(sub_expr4, sub_expr2))), one, t).with_case_simplification(), ExprRange(sub_expr2, MultiQubitElem(element = Gate(operation = MatrixExp(_U, Exp(two, Neg(sub_expr1))), part = sub_expr2), targets = Interval(sub_expr3, Add(t, _s))), one, _s)], sub_expr5, zero)]), Add(zero, Neg(sub_expr5), one))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 1\right)}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 1\right)}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 1\right)}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 2\right)}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 2\right)}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-\left(-t + 2\right)}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right), \ldots, \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-0}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-0}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-0}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right)\right)|, 0 - \left(-t + 1\right) + 1\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:s}, targets:{t + 1 .. t + s}}))|, 0 - (-t + 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:s}, targets:{t + 1 .. t + s}}))|
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. 0 - (-t + 1) + 1
#    core type: Operation
#    operator: 63
#    operands: 5
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (0, -(-t + 1), 1)
#    core type: ExprTuple
#    sub-expressions: 9, 7, 68
# 6. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 1)}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-(-t + 2)}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-0}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 12
#    end_index: 9
# 7. -(-t + 1)
#    core type: Operation
#    operator: 69
#    operand: 12
# 8. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: Lambda
#    parameter: 71
#    body: 11
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. (-t + 1)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. -t + 1
#     core type: Operation
#     operator: 63
#     operands: 15
# 13. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 68
#     end_index: 67
# 14. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 68
#     end_index: 59
# 15. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 68
# 16. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#     core type: Lambda
#     parameter: 50
#     body: 19
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 50
#     body: 21
# 18. -t
#     core type: Operation
#     operator: 69
#     operand: 67
# 19. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 21. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 37
#     operands: 25
# 22. (t)
#     core type: ExprTuple
#     sub-expressions: 67
# 23. CondSet
#     core type: Literal
#     sub-expressions:
# 24. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a, [GATE]{operation:I} if (_b + t) != _a)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. {element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 28
#     targets: 29
# 26. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a.
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. {[GATE]{operation:I} if (_b + t) != _a.
#     core type: Conditional
#     value: 32
#     condition: 33
# 28. [GATE]{operation:U^{2^{-_b}}, part:_a}
#     core type: Operation
#     operator: 40
#     operands: 34
# 29. {t + 1 .. t + s}
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 31. (_b + t) = _a
#     core type: Operation
#     operator: 39
#     operands: 43
# 32. [GATE]{operation:I}
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. (_b + t) != _a
#     core type: Operation
#     operator: 42
#     operands: 43
# 34. {operation:U^{2^{-_b}}, part:_a}
#     core type: NamedExprs
#     operation: 44
#     part: 50
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 37. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 38. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 46
#     targets: 47
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. GATE
#     core type: Literal
#     sub-expressions:
# 41. {operation:I}
#     core type: NamedExprs
#     operation: 48
# 42. !=
#     core type: Literal
#     sub-expressions:
# 43. (_b + t, _a)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. U^{2^{-_b}}
#     core type: Operation
#     operator: 51
#     operands: 52
# 45. t + s
#     core type: Operation
#     operator: 63
#     operands: 53
# 46. CONTROL
#     core type: Literal
#     sub-expressions:
# 47. {t + 1}
#     core type: Operation
#     operator: 54
#     operand: 60
# 48. I
#     core type: Literal
#     sub-expressions:
# 49. _b + t
#     core type: Operation
#     operator: 63
#     operands: 56
# 50. _a
#     core type: Variable
#     sub-expressions:
# 51. ExpM
#     core type: Literal
#     sub-expressions:
# 52. (U, 2^{-_b})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 53. (t, s)
#     core type: ExprTuple
#     sub-expressions: 67, 59
# 54. Set
#     core type: Literal
#     sub-expressions:
# 55. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 60
# 56. (_b, t)
#     core type: ExprTuple
#     sub-expressions: 71, 67
# 57. U
#     core type: Literal
#     sub-expressions:
# 58. 2^{-_b}
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. s
#     core type: Literal
#     sub-expressions:
# 60. t + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (2, -_b)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. -_b
#     core type: Operation
#     operator: 69
#     operand: 71
# 67. t
#     core type: Variable
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. -
#     core type: Literal
#     sub-expressions:
# 70. (_b)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. _b
#     core type: Variable
#     sub-expressions:
