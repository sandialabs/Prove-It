# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import MatrixExp, MatrixMult, ScalarMult
from proveit.logic import And, Equals, Forall, Implies
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, i, one, pi, two, zero
from proveit.physics.quantum.QPE import _U, _ket_u, _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Exp(two, Neg(sub_expr1))
sub_expr3 = Add(Neg(t), one)
sub_expr4 = Equals(MatrixMult(MatrixExp(_U, sub_expr2), _ket_u), ScalarMult(Exp(e, Mult(two, pi, i, Mult(sub_expr2, _phase))), _ket_u))
expr = Implies(Forall(instance_param_or_params = [sub_expr1], instance_expr = sub_expr4, domain = Interval(sub_expr3, zero)), And(ExprRange(sub_expr1, sub_expr4, sub_expr3, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{{_{-}a} \in \{-t + 1~\ldotp \ldotp~0\}}~\left(\left(U^{2^{-{_{-}a}}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-{_{-}a}} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right)\right] \Rightarrow \left(\left(\left(U^{2^{-\left(-t + 1\right)}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-\left(-t + 1\right)} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right) \land  \left(\left(U^{2^{-\left(-t + 2\right)}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-\left(-t + 2\right)} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right) \land  \ldots \land  \left(\left(U^{2^{-0}} \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(2^{-0} \cdot \varphi\right)} \cdot \lvert u \rangle\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{_a in {-t + 1 .. 0}} ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>))] => (((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)) and  ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)) and  ... and  ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{_a in {-t + 1 .. 0}} ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>)), ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)) and  ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)) and  ... and  ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{_a in {-t + 1 .. 0}} ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)) and  ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)) and  ... and  ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (_a -> {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)), ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)), ..., ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>)))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. _a -> {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.
#    core type: Lambda
#    parameter: 59
#    body: 11
# 10. ((U^{2^{-(-t + 1)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 1)} * phase)} * |u>)), ((U^{2^{-(-t + 2)}} . |u>) = (e^{2 * pi * i * (2^{-(-t + 2)} * phase)} * |u>)), ..., ((U^{2^{-0}} . |u>) = (e^{2 * pi * i * (2^{-0} * phase)} * |u>))
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 28
#     end_index: 29
# 11. {(U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>) if _a in {-t + 1 .. 0}.
#     core type: Conditional
#     value: 14
#     condition: 13
# 12. _a -> ((U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>))
#     core type: Lambda
#     parameter: 59
#     body: 14
# 13. _a in {-t + 1 .. 0}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (U^{2^{-_a}} . |u>) = (e^{2 * pi * i * (2^{-_a} * phase)} * |u>)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (_a, {-t + 1 .. 0})
#     core type: ExprTuple
#     sub-expressions: 59, 19
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (U^{2^{-_a}} . |u>, e^{2 * pi * i * (2^{-_a} * phase)} * |u>)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. {-t + 1 .. 0}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. U^{2^{-_a}} . |u>
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. e^{2 * pi * i * (2^{-_a} * phase)} * |u>
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (-t + 1, 0)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. .
#     core type: Literal
#     sub-expressions:
# 25. (U^{2^{-_a}}, |u>)
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (e^{2 * pi * i * (2^{-_a} * phase)}, |u>)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. -t + 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. U^{2^{-_a}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. e^{2 * pi * i * (2^{-_a} * phase)}
#     core type: Operation
#     operator: 53
#     operands: 37
# 32. |u>
#     core type: Literal
#     sub-expressions:
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. ExpM
#     core type: Literal
#     sub-expressions:
# 36. (U, 2^{-_a})
#     core type: ExprTuple
#     sub-expressions: 40, 51
# 37. (e, 2 * pi * i * (2^{-_a} * phase))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. -t
#     core type: Operation
#     operator: 57
#     operand: 45
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. U
#     core type: Literal
#     sub-expressions:
# 41. e
#     core type: Literal
#     sub-expressions:
# 42. 2 * pi * i * (2^{-_a} * phase)
#     core type: Operation
#     operator: 49
#     operands: 44
# 43. (t)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. (2, pi, i, 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 55, 46, 47, 48
# 45. t
#     core type: Variable
#     sub-expressions:
# 46. pi
#     core type: Literal
#     sub-expressions:
# 47. i
#     core type: Literal
#     sub-expressions:
# 48. 2^{-_a} * phase
#     core type: Operation
#     operator: 49
#     operands: 50
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. 2^{-_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. phase
#     core type: Literal
#     sub-expressions:
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. -_a
#     core type: Operation
#     operator: 57
#     operand: 59
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
