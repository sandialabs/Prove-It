# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import And, CartExp, Forall, InSet
from proveit.numbers import Add, Complex, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(Neg(t), two)
sub_expr3 = InSet(ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), CartExp(Complex, Exp(two, one)))
expr = ExprTuple(Forall(instance_param_or_params = [sub_expr1], instance_expr = sub_expr3, domain = Interval(sub_expr2, zero)), And(ExprRange(sub_expr1, sub_expr3, sub_expr2, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{{_{-}a} \in \{-t + 2~\ldotp \ldotp~0\}}~\left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right), \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 2\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right) \land  \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 3\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right) \land  \ldots \land  \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{_a in {-t + 2 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{_a in {-t + 2 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}})
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (_a -> {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ((((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}), ..., (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}}))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. _a -> {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.
#    core type: Lambda
#    parameter: 69
#    body: 9
# 8. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}), ..., (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 24
#    end_index: 46
# 9. {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.
#    core type: Conditional
#    value: 12
#    condition: 11
# 10. _a -> (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}})
#     core type: Lambda
#     parameter: 69
#     body: 12
# 11. _a in {-t + 2 .. 0}
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (_a, {-t + 2 .. 0})
#     core type: ExprTuple
#     sub-expressions: 69, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)), Complex^{2^{1}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {-t + 2 .. 0}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 42
#     operands: 21
# 18. Complex^{2^{1}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Interval
#     core type: Literal
#     sub-expressions:
# 20. (-t + 2, 0)
#     core type: ExprTuple
#     sub-expressions: 24, 46
# 21. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. CartExp
#     core type: Literal
#     sub-expressions:
# 23. (Complex, 2^{1})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. -t + 2
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. 1 / sqrt(2)
#     core type: Operation
#     operator: 49
#     operands: 31
# 26. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. 2^{1}
#     core type: Operation
#     operator: 63
#     operands: 34
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (-t, 2)
#     core type: ExprTuple
#     sub-expressions: 35, 65
# 31. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 56, 36
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. (2, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 56
# 35. -t
#     core type: Operation
#     operator: 67
#     operand: 44
# 36. sqrt(2)
#     core type: Operation
#     operator: 63
#     operands: 40
# 37. |0〉
#     core type: Operation
#     operator: 52
#     operand: 46
# 38. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. (t)
#     core type: ExprTuple
#     sub-expressions: 44
# 40. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 65, 45
# 41. (0)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. t
#     core type: Variable
#     sub-expressions:
# 45. 1 / 2
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 63
#     operands: 51
# 48. |1〉
#     core type: Operation
#     operator: 52
#     operand: 56
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 56, 65
# 51. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. KET
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 54. e
#     core type: Literal
#     sub-expressions:
# 55. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 65, 59, 60, 61, 62
# 59. pi
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Literal
#     sub-expressions:
# 61. 2^{-_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. phase
#     core type: Literal
#     sub-expressions:
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. -_a
#     core type: Operation
#     operator: 67
#     operand: 69
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
