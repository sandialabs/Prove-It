# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.statistics.Prob.html">Prob</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, Variable, VertExprArray, t
from proveit.linear_algebra import MatrixExp, ScalarMult, VecAdd
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import CONTROL, ket0, ket1, ket_plus
from proveit.physics.quantum.QPE import _U, _ket_u, _phase, _s
from proveit.physics.quantum.circuits import Gate, Igate, Input, MultiQubitElem, Output, Qcircuit
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = Add(t, one)
sub_expr4 = Add(sub_expr2, t)
sub_expr5 = Interval(sub_expr3, Add(t, _s))
sub_expr6 = Add(Neg(t), one)
expr = Prob(Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Input(state = ket_plus), one, t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)], ExprRange(sub_expr2, [ExprRange(sub_expr1, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr4, sub_expr1)), Conditional(Igate, NotEquals(sub_expr4, sub_expr1))), one, t).with_case_simplification(), ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = MatrixExp(_U, Exp(two, Neg(sub_expr2))), part = sub_expr1), targets = sub_expr5), one, _s)], sub_expr6, zero).with_decreasing_order(), [ExprRange(sub_expr1, Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1)))), sub_expr6, zero).with_decreasing_order(), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)])))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \textrm{Pr}\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \control{} \qw \qwx[1] & \qw & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \control{} \qw \qwx[1] & \gate{\cdots} \qwx[1] & \qw & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\ddots} \qwx[1] & \gate{\vdots} & \qout{\vdots} \\
# \qin{\lvert + \rangle} & \qw \qwx[1] & \qw \qwx[1] & \gate{\cdots} \qwx[1] & \control{} \qw \qwx[1] & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# \qin{\lvert u \rangle} & \gate{U^{2^{t - 1}}} & \gate{U^{2^{t - 2}}} & \gate{\cdots} & \gate{U^{2^{0}}} & \qout{\lvert u \rangle}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Pr(QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Pr
#    core type: Literal
#    sub-expressions:
# 2. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), \\ ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}),  \\ ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}}), ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 18
#    end_index: 97
# 8. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 113
#    end_index: 112
# 10. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 113
#     end_index: 95
# 11. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#     core type: Lambda
#     parameter: 117
#     body: 16
# 12. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 97
# 13. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 113
#     end_index: 95
# 14. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 128
#     body: 20
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 128
#     body: 21
# 16. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 17. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Lambda
#     parameter: 128
#     body: 24
# 18. -t + 1
#     core type: Operation
#     operator: 107
#     operands: 25
# 19. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 128
#     body: 26
# 20. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 42
#     operands: 27
# 21. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 67
#     operands: 28
# 22. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 113
#     end_index: 112
# 23. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 113
#     end_index: 95
# 24. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Operation
#     operator: 47
#     operands: 31
# 25. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 113
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 67
#     operands: 33
# 27. {state:|+〉}
#     core type: NamedExprs
#     state: 34
# 28. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 53
# 29. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#     core type: Lambda
#     parameter: 128
#     body: 36
# 30. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 128
#     body: 37
# 31. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: NamedExprs
#     state: 38
# 32. -t
#     core type: Operation
#     operator: 126
#     operand: 112
# 33. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 40
#     targets: 53
# 34. |+〉
#     core type: Operation
#     operator: 105
#     operand: 49
# 35. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 42
#     operands: 48
# 36. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 67
#     operands: 45
# 38. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 88
#     operands: 46
# 39. (t)
#     core type: ExprTuple
#     sub-expressions: 112
# 40. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. (+)
#     core type: ExprTuple
#     sub-expressions: 49
# 42. INPUT
#     core type: Literal
#     sub-expressions:
# 43. CondSet
#     core type: Literal
#     sub-expressions:
# 44. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a, [GATE]{operation:I} if (_b + t) != _a)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 45. {element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 52
#     targets: 53
# 46. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 47. OUTPUT
#     core type: Literal
#     sub-expressions:
# 48. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 56
#     part: 128
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a.
#     core type: Conditional
#     value: 57
#     condition: 58
# 51. {[GATE]{operation:I} if (_b + t) != _a.
#     core type: Conditional
#     value: 59
#     condition: 60
# 52. [GATE]{operation:U^{2^{-_b}}, part:_a}
#     core type: Operation
#     operator: 70
#     operands: 61
# 53. {t + 1 .. t + s}
#     core type: Operation
#     operator: 62
#     operands: 63
# 54. 1 / sqrt(2)
#     core type: Operation
#     operator: 102
#     operands: 64
# 55. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 65
#     operands: 66
# 56. |u>
#     core type: Literal
#     sub-expressions:
# 57. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 67
#     operands: 68
# 58. (_b + t) = _a
#     core type: Operation
#     operator: 69
#     operands: 73
# 59. [GATE]{operation:I}
#     core type: Operation
#     operator: 70
#     operands: 71
# 60. (_b + t) != _a
#     core type: Operation
#     operator: 72
#     operands: 73
# 61. {operation:U^{2^{-_b}}, part:_a}
#     core type: NamedExprs
#     operation: 74
#     part: 128
# 62. Interval
#     core type: Literal
#     sub-expressions:
# 63. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 100, 75
# 64. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 113, 76
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 67. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 68. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 79
#     targets: 80
# 69. =
#     core type: Literal
#     sub-expressions:
# 70. GATE
#     core type: Literal
#     sub-expressions:
# 71. {operation:I}
#     core type: NamedExprs
#     operation: 81
# 72. !=
#     core type: Literal
#     sub-expressions:
# 73. (_b + t, _a)
#     core type: ExprTuple
#     sub-expressions: 82, 128
# 74. U^{2^{-_b}}
#     core type: Operation
#     operator: 83
#     operands: 84
# 75. t + s
#     core type: Operation
#     operator: 107
#     operands: 85
# 76. sqrt(2)
#     core type: Operation
#     operator: 122
#     operands: 86
# 77. |0〉
#     core type: Operation
#     operator: 105
#     operand: 97
# 78. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 88
#     operands: 89
# 79. CONTROL
#     core type: Literal
#     sub-expressions:
# 80. {t + 1}
#     core type: Operation
#     operator: 90
#     operand: 100
# 81. I
#     core type: Literal
#     sub-expressions:
# 82. _b + t
#     core type: Operation
#     operator: 107
#     operands: 92
# 83. ExpM
#     core type: Literal
#     sub-expressions:
# 84. (U, 2^{-_b})
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 85. (t, s)
#     core type: ExprTuple
#     sub-expressions: 112, 95
# 86. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 124, 96
# 87. (0)
#     core type: ExprTuple
#     sub-expressions: 97
# 88. *
#     core type: Literal
#     sub-expressions:
# 89. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 90. Set
#     core type: Literal
#     sub-expressions:
# 91. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 100
# 92. (_b, t)
#     core type: ExprTuple
#     sub-expressions: 117, 112
# 93. U
#     core type: Literal
#     sub-expressions:
# 94. 2^{-_b}
#     core type: Operation
#     operator: 122
#     operands: 101
# 95. s
#     core type: Literal
#     sub-expressions:
# 96. 1 / 2
#     core type: Operation
#     operator: 102
#     operands: 103
# 97. 0
#     core type: Literal
#     sub-expressions:
# 98. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 122
#     operands: 104
# 99. |1〉
#     core type: Operation
#     operator: 105
#     operand: 113
# 100. t + 1
#      core type: Operation
#      operator: 107
#      operands: 108
# 101. (2, -_b)
#      core type: ExprTuple
#      sub-expressions: 124, 109
# 102. /
#      core type: Literal
#      sub-expressions:
# 103. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 113, 124
# 104. (e, 2 * pi * i * 2^{-_a} * phase)
#      core type: ExprTuple
#      sub-expressions: 110, 111
# 105. KET
#      core type: Literal
#      sub-expressions:
# 106. (1)
#      core type: ExprTuple
#      sub-expressions: 113
# 107. +
#      core type: Literal
#      sub-expressions:
# 108. (t, 1)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 109. -_b
#      core type: Operation
#      operator: 126
#      operand: 117
# 110. e
#      core type: Literal
#      sub-expressions:
# 111. 2 * pi * i * 2^{-_a} * phase
#      core type: Operation
#      operator: 115
#      operands: 116
# 112. t
#      core type: Variable
#      sub-expressions:
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. (_b)
#      core type: ExprTuple
#      sub-expressions: 117
# 115. *
#      core type: Literal
#      sub-expressions:
# 116. (2, pi, i, 2^{-_a}, phase)
#      core type: ExprTuple
#      sub-expressions: 124, 118, 119, 120, 121
# 117. _b
#      core type: Variable
#      sub-expressions:
# 118. pi
#      core type: Literal
#      sub-expressions:
# 119. i
#      core type: Literal
#      sub-expressions:
# 120. 2^{-_a}
#      core type: Operation
#      operator: 122
#      operands: 123
# 121. phase
#      core type: Literal
#      sub-expressions:
# 122. Exp
#      core type: Literal
#      sub-expressions:
# 123. (2, -_a)
#      core type: ExprTuple
#      sub-expressions: 124, 125
# 124. 2
#      core type: Literal
#      sub-expressions:
# 125. -_a
#      core type: Operation
#      operator: 126
#      operand: 128
# 126. -
#      core type: Literal
#      sub-expressions:
# 127. (_a)
#      core type: ExprTuple
#      sub-expressions: 128
# 128. _a
#      core type: Variable
#      sub-expressions:
