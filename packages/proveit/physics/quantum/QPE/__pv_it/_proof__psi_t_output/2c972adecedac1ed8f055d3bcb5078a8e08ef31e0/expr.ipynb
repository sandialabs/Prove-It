# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1)))
expr = ExprTuple(MultiQubitElem(element = Output(state = sub_expr2, part = one), targets = Interval(Add(Add(sub_expr1, Neg(one), t), one), Add(sub_expr1, t))), Output(state = sub_expr2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{\left({_{-}a} - 1 + t\right) + 1~\ldotp \ldotp~{_{-}a} + t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#    core type: Operation
#    operator: 8
#    operands: 5
# 3. MULTI_QUBIT_ELEM
#    core type: Literal
#    sub-expressions:
# 4. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}
#    core type: NamedExprs
#    element: 6
#    targets: 7
# 5. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#    core type: NamedExprs
#    state: 12
# 6. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. {(_a - 1 + t) + 1 .. _a + t}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. OUTPUT
#    core type: Literal
#    sub-expressions:
# 9. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}
#    core type: NamedExprs
#    state: 12
#    part: 46
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. ((_a - 1 + t) + 1, _a + t)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 33
#     operands: 15
# 13. (_a - 1 + t) + 1
#     core type: Operation
#     operator: 24
#     operands: 16
# 14. _a + t
#     core type: Operation
#     operator: 24
#     operands: 17
# 15. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. (_a - 1 + t, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 46
# 17. (_a, t)
#     core type: ExprTuple
#     sub-expressions: 59, 30
# 18. 1 / sqrt(2)
#     core type: Operation
#     operator: 39
#     operands: 21
# 19. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. _a - 1 + t
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 46, 26
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (_a, -1, t)
#     core type: ExprTuple
#     sub-expressions: 59, 29, 30
# 26. sqrt(2)
#     core type: Operation
#     operator: 53
#     operands: 31
# 27. |0〉
#     core type: Operation
#     operator: 42
#     operand: 36
# 28. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. -1
#     core type: Operation
#     operator: 57
#     operand: 46
# 30. t
#     core type: Variable
#     sub-expressions:
# 31. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 55, 35
# 32. (0)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. *
#     core type: Literal
#     sub-expressions:
# 34. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. 1 / 2
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 53
#     operands: 41
# 38. |1〉
#     core type: Operation
#     operator: 42
#     operand: 46
# 39. /
#     core type: Literal
#     sub-expressions:
# 40. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 46, 55
# 41. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. KET
#     core type: Literal
#     sub-expressions:
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. e
#     core type: Literal
#     sub-expressions:
# 45. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 55, 49, 50, 51, 52
# 49. pi
#     core type: Literal
#     sub-expressions:
# 50. i
#     core type: Literal
#     sub-expressions:
# 51. 2^{-_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. phase
#     core type: Literal
#     sub-expressions:
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. -_a
#     core type: Operation
#     operator: 57
#     operand: 59
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
