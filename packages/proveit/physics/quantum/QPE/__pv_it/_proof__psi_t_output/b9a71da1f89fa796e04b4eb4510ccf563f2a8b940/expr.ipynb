# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, Lambda, Variable, t
from proveit.linear_algebra import MatrixExp
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Exp, Interval, Neg, one, two
from proveit.physics.quantum import CONTROL
from proveit.physics.quantum.QPE import _U, _s
from proveit.physics.quantum.circuits import Gate, Igate, MultiQubitElem

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr3 = Add(t, one)
sub_expr4 = Add(sub_expr1, t)
expr = Lambda(sub_expr1, [ExprRange(sub_expr2, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr4, sub_expr2)), Conditional(Igate, NotEquals(sub_expr4, sub_expr2))), one, t).with_case_simplification(), ExprRange(sub_expr2, MultiQubitElem(element = Gate(operation = MatrixExp(_U, Exp(two, Neg(sub_expr1))), part = sub_expr2), targets = Interval(sub_expr3, Add(t, _s))), one, _s)])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# {_{-}b} \mapsto \left(\left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = 1 \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq 1\end{array}\right.., \left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = 2 \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq 2\end{array}\right.., \ldots, \left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = t \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq t\end{array}\right..,\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: Lambda
#    parameter: 57
#    body: 1
# 1. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 54
#    end_index: 53
# 3. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 54
#    end_index: 45
# 4. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#    core type: Lambda
#    parameter: 36
#    body: 6
# 5. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 36
#    body: 8
# 6. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (_a)
#    core type: ExprTuple
#    sub-expressions: 36
# 8. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. CondSet
#    core type: Literal
#    sub-expressions:
# 10. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a, [GATE]{operation:I} if (_b + t) != _a)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. {element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 14
#     targets: 15
# 12. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. {[GATE]{operation:I} if (_b + t) != _a.
#     core type: Conditional
#     value: 18
#     condition: 19
# 14. [GATE]{operation:U^{2^{-_b}}, part:_a}
#     core type: Operation
#     operator: 26
#     operands: 20
# 15. {t + 1 .. t + s}
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. (_b + t) = _a
#     core type: Operation
#     operator: 25
#     operands: 29
# 18. [GATE]{operation:I}
#     core type: Operation
#     operator: 26
#     operands: 27
# 19. (_b + t) != _a
#     core type: Operation
#     operator: 28
#     operands: 29
# 20. {operation:U^{2^{-_b}}, part:_a}
#     core type: NamedExprs
#     operation: 30
#     part: 36
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 46, 31
# 23. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 24. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 32
#     targets: 33
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. GATE
#     core type: Literal
#     sub-expressions:
# 27. {operation:I}
#     core type: NamedExprs
#     operation: 34
# 28. !=
#     core type: Literal
#     sub-expressions:
# 29. (_b + t, _a)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. U^{2^{-_b}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 31. t + s
#     core type: Operation
#     operator: 49
#     operands: 39
# 32. CONTROL
#     core type: Literal
#     sub-expressions:
# 33. {t + 1}
#     core type: Operation
#     operator: 40
#     operand: 46
# 34. I
#     core type: Literal
#     sub-expressions:
# 35. _b + t
#     core type: Operation
#     operator: 49
#     operands: 42
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. ExpM
#     core type: Literal
#     sub-expressions:
# 38. (U, 2^{-_b})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 39. (t, s)
#     core type: ExprTuple
#     sub-expressions: 53, 45
# 40. Set
#     core type: Literal
#     sub-expressions:
# 41. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. (_b, t)
#     core type: ExprTuple
#     sub-expressions: 57, 53
# 43. U
#     core type: Literal
#     sub-expressions:
# 44. 2^{-_b}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. s
#     core type: Literal
#     sub-expressions:
# 46. t + 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (2, -_b)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. 2
#     core type: Literal
#     sub-expressions:
# 52. -_b
#     core type: Operation
#     operator: 55
#     operand: 57
# 53. t
#     core type: Variable
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (_b)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. _b
#     core type: Variable
#     sub-expressions:
