# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, VertExprArray, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _ket_u, _phase, _psi_t_ket, _s
from proveit.physics.quantum.circuits import MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Neg(t)
sub_expr3 = Add(t, one)
sub_expr4 = Add(t, _s)
sub_expr5 = Add(sub_expr2, two)
sub_expr6 = TensorProd(_psi_t_ket, _ket_u)
sub_expr7 = Interval(one, sub_expr4)
sub_expr8 = frac(one, sqrt(two))
expr = ExprTuple(Qcircuit(vert_expr_array = VertExprArray([Output(state = ScalarMult(sub_expr8, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(Add(sub_expr2, one))), _phase)), ket1)))), ExprRange(sub_expr1, Output(state = ScalarMult(sub_expr8, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1)))), sub_expr5, zero).with_decreasing_order(), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(sub_expr3, sub_expr4)), one, _s).with_wrapping_at(2,6)])), Qcircuit(vert_expr_array = VertExprArray([MultiQubitElem(element = Output(state = sub_expr6, part = one), targets = sub_expr7), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = sub_expr6, part = Add(sub_expr1, t)), targets = sub_expr7), sub_expr5, zero), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = sub_expr6, part = sub_expr1), targets = sub_expr7), sub_expr3, sub_expr4).with_wrapping_at(2,6)])))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 3} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\vdots} \\
# & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)} \\
# & \qout{\lvert u \rangle}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \multiqout{2}{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle} \\
# & \ghostqout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle} \\
# & \ghostqout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle} \\
# & \qout{\vdots} \qwx[1] \\
# & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~0 + t~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} \qwx[1] \\
# & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (QCIRCUIT(VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))), QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 3) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. QCIRCUIT(VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 3) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. VertExprArray(([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. VertExprArray(([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 3) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ([OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))},[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 3) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 8. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#    core type: Operation
#    operator: 47
#    operands: 14
# 9. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉)))}, [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 3} * phase} * |1〉)))}, ..., [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 19
#    end_index: 82
# 10. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 112
#     end_index: 73
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 17
# 12. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 2) + t)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:((-t + 3) + t)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(0 + t)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 82
# 13. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 54
#     end_index: 57
# 14. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)))}
#     core type: NamedExprs
#     state: 21
# 15. _a -> [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Lambda
#     parameter: 113
#     body: 22
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 113
#     body: 23
# 17. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 24
#     targets: 41
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 113
#     body: 25
# 19. -t + 2
#     core type: Operation
#     operator: 108
#     operands: 26
# 20. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 113
#     body: 27
# 21. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: Operation
#     operator: 77
#     operands: 28
# 22. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: Operation
#     operator: 47
#     operands: 29
# 23. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 30
# 24. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}
#     core type: Operation
#     operator: 47
#     operands: 31
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 32
# 26. (-t, 2)
#     core type: ExprTuple
#     sub-expressions: 111, 106
# 27. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 52, 35
# 29. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))}
#     core type: NamedExprs
#     state: 36
# 30. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 37
#     targets: 38
# 31. {state:(|psi_{t}> otimes |u>), part:1}
#     core type: NamedExprs
#     state: 56
#     part: 112
# 32. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 39
#     targets: 41
# 33. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 34. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 40
#     targets: 41
# 35. |0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: Operation
#     operator: 60
#     operands: 42
# 36. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 77
#     operands: 43
# 37. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 44
# 38. {t + 1 .. t + s}
#     core type: Operation
#     operator: 49
#     operands: 45
# 39. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:(_a + t)}
#     core type: Operation
#     operator: 47
#     operands: 46
# 40. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. {1 .. t + s}
#     core type: Operation
#     operator: 49
#     operands: 50
# 42. (|0〉, e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 69, 51
# 43. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 44. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 72
#     part: 113
# 45. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 46. {state:(|psi_{t}> otimes |u>), part:(_a + t)}
#     core type: NamedExprs
#     state: 56
#     part: 55
# 47. OUTPUT
#     core type: Literal
#     sub-expressions:
# 48. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 56
#     part: 113
# 49. Interval
#     core type: Literal
#     sub-expressions:
# 50. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 112, 57
# 51. e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉
#     core type: Operation
#     operator: 77
#     operands: 58
# 52. 1 / sqrt(2)
#     core type: Operation
#     operator: 86
#     operands: 59
# 53. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 60
#     operands: 61
# 54. t + 1
#     core type: Operation
#     operator: 108
#     operands: 62
# 55. _a + t
#     core type: Operation
#     operator: 108
#     operands: 63
# 56. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 64
#     operands: 65
# 57. t + s
#     core type: Operation
#     operator: 108
#     operands: 66
# 58. (e^{2 * pi * i * 2^{-(-t + 1)} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 67, 84
# 59. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 112, 68
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 62. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 116, 112
# 63. (_a, t)
#     core type: ExprTuple
#     sub-expressions: 113, 116
# 64. otimes
#     core type: Literal
#     sub-expressions:
# 65. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 66. (t, s)
#     core type: ExprTuple
#     sub-expressions: 116, 73
# 67. e^{2 * pi * i * 2^{-(-t + 1)} * phase}
#     core type: Operation
#     operator: 103
#     operands: 74
# 68. sqrt(2)
#     core type: Operation
#     operator: 103
#     operands: 75
# 69. |0〉
#     core type: Operation
#     operator: 89
#     operand: 82
# 70. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 77
#     operands: 78
# 71. |psi_{t}>
#     core type: Operation
#     operator: 79
#     operand: 116
# 72. |u>
#     core type: Literal
#     sub-expressions:
# 73. s
#     core type: Literal
#     sub-expressions:
# 74. (e, 2 * pi * i * 2^{-(-t + 1)} * phase)
#     core type: ExprTuple
#     sub-expressions: 92, 80
# 75. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 106, 81
# 76. (0)
#     core type: ExprTuple
#     sub-expressions: 82
# 77. *
#     core type: Literal
#     sub-expressions:
# 78. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 79. psi
#     core type: Literal
#     sub-expressions:
# 80. 2 * pi * i * 2^{-(-t + 1)} * phase
#     core type: Operation
#     operator: 95
#     operands: 85
# 81. 1 / 2
#     core type: Operation
#     operator: 86
#     operands: 87
# 82. 0
#     core type: Literal
#     sub-expressions:
# 83. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 103
#     operands: 88
# 84. |1〉
#     core type: Operation
#     operator: 89
#     operand: 112
# 85. (2, pi, i, 2^{-(-t + 1)}, phase)
#     core type: ExprTuple
#     sub-expressions: 106, 98, 99, 91, 101
# 86. /
#     core type: Literal
#     sub-expressions:
# 87. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 112, 106
# 88. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. KET
#     core type: Literal
#     sub-expressions:
# 90. (1)
#     core type: ExprTuple
#     sub-expressions: 112
# 91. 2^{-(-t + 1)}
#     core type: Operation
#     operator: 103
#     operands: 94
# 92. e
#     core type: Literal
#     sub-expressions:
# 93. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 95
#     operands: 96
# 94. (2, -(-t + 1))
#     core type: ExprTuple
#     sub-expressions: 106, 97
# 95. *
#     core type: Literal
#     sub-expressions:
# 96. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 106, 98, 99, 100, 101
# 97. -(-t + 1)
#     core type: Operation
#     operator: 114
#     operand: 105
# 98. pi
#     core type: Literal
#     sub-expressions:
# 99. i
#     core type: Literal
#     sub-expressions:
# 100. 2^{-_a}
#      core type: Operation
#      operator: 103
#      operands: 104
# 101. phase
#      core type: Literal
#      sub-expressions:
# 102. (-t + 1)
#      core type: ExprTuple
#      sub-expressions: 105
# 103. Exp
#      core type: Literal
#      sub-expressions:
# 104. (2, -_a)
#      core type: ExprTuple
#      sub-expressions: 106, 107
# 105. -t + 1
#      core type: Operation
#      operator: 108
#      operands: 109
# 106. 2
#      core type: Literal
#      sub-expressions:
# 107. -_a
#      core type: Operation
#      operator: 114
#      operand: 113
# 108. +
#      core type: Literal
#      sub-expressions:
# 109. (-t, 1)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 110. (_a)
#      core type: ExprTuple
#      sub-expressions: 113
# 111. -t
#      core type: Operation
#      operator: 114
#      operand: 116
# 112. 1
#      core type: Literal
#      sub-expressions:
# 113. _a
#      core type: Variable
#      sub-expressions:
# 114. -
#      core type: Literal
#      sub-expressions:
# 115. (t)
#      core type: ExprTuple
#      sub-expressions: 116
# 116. t
#      core type: Variable
#      sub-expressions:
