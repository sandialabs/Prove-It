# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(sub_expr1, t)
sub_expr3 = Output(state = ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), part = one)
expr = Equals(MultiQubitElem(element = sub_expr3, targets = Interval(Add(Add(sub_expr1, Neg(one), t), one), sub_expr2)), MultiQubitElem(element = sub_expr3, targets = Interval(sub_expr2, sub_expr2)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{\left({_{-}a} - 1 + t\right) + 1~\ldotp \ldotp~{_{-}a} + t\}}
# } \end{array} = \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)~\mbox{part}~1~\mbox{on}~\{{_{-}a} + t~\ldotp \ldotp~{_{-}a} + t\}}
# } \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}} = [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{_a + t .. _a + t}}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{_a + t .. _a + t}})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{_a + t .. _a + t}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{(_a - 1 + t) + 1 .. _a + t}}
#    core type: NamedExprs
#    element: 9
#    targets: 8
# 6. MULTI_QUBIT_ELEM
#    core type: Literal
#    sub-expressions:
# 7. {element:[OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}, targets:{_a + t .. _a + t}}
#    core type: NamedExprs
#    element: 9
#    targets: 10
# 8. {(_a - 1 + t) + 1 .. _a + t}
#    core type: Operation
#    operator: 14
#    operands: 11
# 9. [OUTPUT]{state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {_a + t .. _a + t}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. ((_a - 1 + t) + 1, _a + t)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 12. OUTPUT
#     core type: Literal
#     sub-expressions:
# 13. {state:((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))), part:1}
#     core type: NamedExprs
#     state: 17
#     part: 50
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (_a + t, _a + t)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 16. (_a - 1 + t) + 1
#     core type: Operation
#     operator: 25
#     operands: 19
# 17. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 37
#     operands: 20
# 18. _a + t
#     core type: Operation
#     operator: 25
#     operands: 21
# 19. (_a - 1 + t, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 50
# 20. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (_a, t)
#     core type: ExprTuple
#     sub-expressions: 63, 31
# 22. _a - 1 + t
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. 1 / sqrt(2)
#     core type: Operation
#     operator: 43
#     operands: 27
# 24. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (_a, -1, t)
#     core type: ExprTuple
#     sub-expressions: 63, 30, 31
# 27. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 50, 32
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. -1
#     core type: Operation
#     operator: 61
#     operand: 50
# 31. t
#     core type: Variable
#     sub-expressions:
# 32. sqrt(2)
#     core type: Operation
#     operator: 57
#     operands: 35
# 33. |0〉
#     core type: Operation
#     operator: 46
#     operand: 40
# 34. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 59, 39
# 36. (0)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. *
#     core type: Literal
#     sub-expressions:
# 38. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. 1 / 2
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. 0
#     core type: Literal
#     sub-expressions:
# 41. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 57
#     operands: 45
# 42. |1〉
#     core type: Operation
#     operator: 46
#     operand: 50
# 43. /
#     core type: Literal
#     sub-expressions:
# 44. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 50, 59
# 45. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (1)
#     core type: ExprTuple
#     sub-expressions: 50
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 59, 53, 54, 55, 56
# 53. pi
#     core type: Literal
#     sub-expressions:
# 54. i
#     core type: Literal
#     sub-expressions:
# 55. 2^{-_a}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. phase
#     core type: Literal
#     sub-expressions:
# 57. Exp
#     core type: Literal
#     sub-expressions:
# 58. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. -_a
#     core type: Operation
#     operator: 61
#     operand: 63
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
