# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import And, CartExp, Forall, Implies, InSet
from proveit.numbers import Add, Complex, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(Neg(t), two)
sub_expr3 = InSet(ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), CartExp(Complex, Exp(two, one)))
expr = Implies(Forall(instance_param_or_params = [sub_expr1], instance_expr = sub_expr3, domain = Interval(sub_expr2, zero)), And(ExprRange(sub_expr1, sub_expr3, sub_expr2, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{{_{-}a} \in \{-t + 2~\ldotp \ldotp~0\}}~\left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-{_{-}a}} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right)\right] \Rightarrow \left(\left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 2\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right) \land  \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 3\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right) \land  \ldots \land  \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) \in \mathbb{C}^{2^{1}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{_a in {-t + 2 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}})] => ((((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{_a in {-t + 2 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{_a in {-t + 2 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}})
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (_a -> {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. ((((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}), ..., (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}}))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. _a -> {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.
#    core type: Lambda
#    parameter: 71
#    body: 11
# 10. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2^{1}}), (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 3)} * phase} * |1〉))) in Complex^{2^{1}}), ..., (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2^{1}})
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 26
#     end_index: 48
# 11. {((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}} if _a in {-t + 2 .. 0}.
#     core type: Conditional
#     value: 14
#     condition: 13
# 12. _a -> (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}})
#     core type: Lambda
#     parameter: 71
#     body: 14
# 13. _a in {-t + 2 .. 0}
#     core type: Operation
#     operator: 16
#     operands: 15
# 14. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2^{1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (_a, {-t + 2 .. 0})
#     core type: ExprTuple
#     sub-expressions: 71, 18
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)), Complex^{2^{1}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. {-t + 2 .. 0}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 44
#     operands: 23
# 20. Complex^{2^{1}}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (-t + 2, 0)
#     core type: ExprTuple
#     sub-expressions: 26, 48
# 23. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. CartExp
#     core type: Literal
#     sub-expressions:
# 25. (Complex, 2^{1})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. -t + 2
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. 1 / sqrt(2)
#     core type: Operation
#     operator: 51
#     operands: 33
# 28. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. 2^{1}
#     core type: Operation
#     operator: 65
#     operands: 36
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (-t, 2)
#     core type: ExprTuple
#     sub-expressions: 37, 67
# 33. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 58, 38
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. (2, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 58
# 37. -t
#     core type: Operation
#     operator: 69
#     operand: 46
# 38. sqrt(2)
#     core type: Operation
#     operator: 65
#     operands: 42
# 39. |0〉
#     core type: Operation
#     operator: 54
#     operand: 48
# 40. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (t)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 67, 47
# 43. (0)
#     core type: ExprTuple
#     sub-expressions: 48
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. t
#     core type: Variable
#     sub-expressions:
# 47. 1 / 2
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. 0
#     core type: Literal
#     sub-expressions:
# 49. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 65
#     operands: 53
# 50. |1〉
#     core type: Operation
#     operator: 54
#     operand: 58
# 51. /
#     core type: Literal
#     sub-expressions:
# 52. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 58, 67
# 53. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. KET
#     core type: Literal
#     sub-expressions:
# 55. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 56. e
#     core type: Literal
#     sub-expressions:
# 57. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 67, 61, 62, 63, 64
# 61. pi
#     core type: Literal
#     sub-expressions:
# 62. i
#     core type: Literal
#     sub-expressions:
# 63. 2^{-_a}
#     core type: Operation
#     operator: 65
#     operands: 66
# 64. phase
#     core type: Literal
#     sub-expressions:
# 65. Exp
#     core type: Literal
#     sub-expressions:
# 66. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. -_a
#     core type: Operation
#     operator: 69
#     operand: 71
# 69. -
#     core type: Literal
#     sub-expressions:
# 70. (_a)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. _a
#     core type: Variable
#     sub-expressions:
