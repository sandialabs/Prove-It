# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import k, l
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import ModAdd, SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))
expr = ExprTuple(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l), Mult(frac(one, subExpr1), Sum([k], Mult(Exp(e, frac(Neg(Mult(two, pi, i, k, ModAdd(Literal("b", context = "proveit.physics.quantum.QPE"), l))), subExpr1)), Exp(e, Mult(two, pi, i, Literal("phase", latexFormat = r"\varphi", context = "proveit.physics.quantum.QPE"), k))), domain = Interval(zero, Add(subExpr1, Neg(one))))))
# Out:
# expr: (alpha_{l}, (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha_{l}, \frac{1}{2^{t}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot e^{2 \cdot \pi \cdot i \cdot \varphi \cdot k}\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (alpha_{l}, (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. alpha_{l}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))
#    core type: Operation
#    operator: 44
#    operands: 5
# 3. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 4. (alpha, l)
#    core type: ExprTuple
#    sub-expressions: 6, 55
# 5. (1 / 2^{t}, Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. alpha
#    core type: Literal
#    sub-expressions:
# 7. 1 / 2^{t}
#    core type: Operation
#    operator: 30
#    operands: 9
# 8. Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (1, 2^{t})
#    core type: ExprTuple
#    sub-expressions: 43, 37
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. k -> {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Lambda
#     parameter: 50
#     body: 12
# 12. {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 44
#     operands: 15
# 14. k in {0...2^{t} - 1}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (k, {0...2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 50, 20
# 18. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}
#     core type: Operation
#     operator: 40
#     operands: 21
# 19. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 40
#     operands: 22
# 20. {0...2^{t} - 1}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (e, (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 22. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. e
#     core type: Literal
#     sub-expressions:
# 27. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 44
#     operands: 32
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. 2^{t} - 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. /
#     core type: Literal
#     sub-expressions:
# 31. (-(2 * pi * i * k * (b MOD_ADD l)), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 32. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 47, 48, 49, 36, 50
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. -(2 * pi * i * k * (b MOD_ADD l))
#     core type: Operation
#     operator: 42
#     operand: 39
# 36. phase
#     core type: Literal
#     sub-expressions:
# 37. 2^{t}
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. -1
#     core type: Operation
#     operator: 42
#     operand: 43
# 39. 2 * pi * i * k * (b MOD_ADD l)
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (2, t)
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (2, pi, i, k, b MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 47, 48, 49, 50, 51
# 46. t
#     core type: Literal
#     sub-expressions:
# 47. 2
#     core type: Literal
#     sub-expressions:
# 48. pi
#     core type: Literal
#     sub-expressions:
# 49. i
#     core type: Literal
#     sub-expressions:
# 50. k
#     core type: Variable
#     sub-expressions:
# 51. b MOD_ADD l
#     core type: Operation
#     operator: 52
#     operands: 53
# 52. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 53. (b, l)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. b
#     core type: Literal
#     sub-expressions:
# 55. l
#     core type: Variable
#     sub-expressions:
