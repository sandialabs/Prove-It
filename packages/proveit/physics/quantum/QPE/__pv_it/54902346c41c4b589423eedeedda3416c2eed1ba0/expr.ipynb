# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#Psi_1_def">Psi_1_def</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._axioms_ import Psi_1_def

# %%
# check that the built expression is the same as the stored expression
# %check_expr Psi_1_def
# Out:
# Passed sanity check: built 'Psi_1_def' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(Psi_1_def.latex())
# Out:
# \vdash \Psi_{1} = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(e^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)

# %%
# display the expression information
Psi_1_def.exprInfo()
# Out:
# 0. Psi_1 = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Psi_1, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Psi_1
#    core type: Literal
#    sub-expressions:
# 4. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 33
#    operands: 5
# 5. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} e^{2 * pi * i * phase * k} * |k〉)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 1 / 2^{t / 2}
#    core type: Operation
#    operator: 20
#    operands: 8
# 7. Sum_{k=0}^{2^{t} - 1} e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. (1, 2^{t / 2})
#    core type: ExprTuple
#    sub-expressions: 46, 11
# 9. Sum
#    core type: Literal
# ...
