# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fail_sum">fail_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import fail_sum

# %%
# check that the built expression is the same as the stored expression
# %check_expr fail_sum
# Out:
# Passed sanity check: built 'fail_sum' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fail_sum.latex())
# Out:
# \vdash \forall_{\varepsilon \in \{1 \dots 2^{t - 1} - 2\}}~\left(\left[P_{\rm fail}\right]\left(\varepsilon\right) \leq \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}\right)\right)\right)

# %%
# display the expression information
fail_sum.exprInfo()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} ([Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. eps -> {[Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 51
#    body: 3
# 3. {[Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 30
#    operands: 8
# ...
