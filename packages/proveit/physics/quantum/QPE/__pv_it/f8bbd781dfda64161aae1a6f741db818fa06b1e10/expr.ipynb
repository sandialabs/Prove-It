# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.NotInSet.html">NotInSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit._common_ import l
from proveit.logic import NotInSet
from proveit.number import Add, Exp, Integers, Neg, frac, two

# %%
# build up the expression from sub-expressions
expr = NotInSet(Add(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))))), Integers)
# Out:
# expr: (delta - (l / 2^{t})) not-in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\delta - \frac{l}{2^{t}}\right) \notin \mathbb{Z}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (delta - (l / 2^{t})) not-in Integers
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. not-in
#    core type: Literal
#    sub-expressions:
# 2. (delta - (l / 2^{t}), Integers)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. delta - (l / 2^{t})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Integers
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (delta, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. delta
#    core type: Literal
#    sub-expressions:
# 8. -(l / 2^{t})
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. l / 2^{t}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. l
#     core type: Variable
#     sub-expressions:
# 14. 2^{t}
# ...
