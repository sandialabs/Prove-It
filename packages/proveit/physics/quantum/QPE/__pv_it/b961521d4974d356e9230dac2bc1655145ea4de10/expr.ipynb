# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#negDomainInFullDomain">negDomainInFullDomain</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import negDomainInFullDomain

# %%
# check that the built expression is the same as the stored expression
# %check_expr negDomainInFullDomain
# Out:
# Passed sanity check: built 'negDomainInFullDomain' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negDomainInFullDomain.latex())
# Out:
# \vdash \forall_{\varepsilon \in \mathbb{N}^+}~\left[\forall_{l \in \{-2^{t - 1} + 1 \dots -\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}\right)\right]

# %%
# display the expression information
negDomainInFullDomain.exprInfo()
# Out:
# 0. forall_{eps in NaturalsPos} [forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. eps -> {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalsPos.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. eps in NaturalsPos
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. l -> {l in {-2^{t - 1} + 1...2^{t - 1}} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 16
#    body: 8
# 7. (eps, NaturalsPos)
#    core type: ExprTuple
# ...
