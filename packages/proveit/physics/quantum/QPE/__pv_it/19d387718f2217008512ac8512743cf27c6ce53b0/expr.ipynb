# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Literal
from proveit._common_ import eps, l
from proveit.logic import Forall, InSet
from proveit.number import Add, Exp, Interval, NaturalsPos, Neg, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))
subExpr2 = Add(Neg(subExpr1), one)
expr = Conditional(Forall([l], InSet(l, Interval(subExpr2, subExpr1)), domain = Interval(subExpr2, Neg(Add(eps, one)))), InSet(eps, NaturalsPos))
# Out:
# expr: {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{l \in \{-2^{t - 1} + 1 \dots -\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}\right) \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. eps in NaturalsPos
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. l -> {l in {-2^{t - 1} + 1...2^{t - 1}} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 14
#    body: 6
# 5. (eps, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 26, 7
# 6. {l in {-2^{t - 1} + 1...2^{t - 1}} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. l in {-2^{t - 1} + 1...-(eps + 1)}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (l, {-2^{t - 1} + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (l, {-2^{t - 1} + 1...-(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 16
# 14. l
#     core type: Variable
#     sub-expressions:
# 15. {-2^{t - 1} + 1...-(eps + 1)}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 25
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. -2^{t - 1} + 1
#     core type: Operation
#     operator: 31
#     operands: 21
# 20. -(eps + 1)
#     core type: Operation
#     operator: 35
#     operand: 22
# 21. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 36
# 22. eps + 1
#     core type: Operation
#     operator: 31
#     operands: 24
# 23. -2^{t - 1}
#     core type: Operation
#     operator: 35
#     operand: 25
# 24. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 36
# 25. 2^{t - 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. t - 1
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. t
#     core type: Literal
#     sub-expressions:
# 34. -1
#     core type: Operation
#     operator: 35
#     operand: 36
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. 1
#     core type: Literal
#     sub-expressions:
