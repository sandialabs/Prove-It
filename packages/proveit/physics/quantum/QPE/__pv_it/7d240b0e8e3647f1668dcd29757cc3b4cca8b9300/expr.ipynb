# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Literal
from proveit._common_ import eps, l
from proveit.logic import InSet
from proveit.number import Abs, Add, Exp, Interval, Neg, one, two
from proveit.physics.quantum.QPE import SubIndexed

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(Exp(Abs(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l)), two), InSet(l, Interval(Add(eps, one), Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))))))
# Out:
# expr: l -> {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left|\alpha_{l}\right|^{2} \textrm{ if } l \in \{\varepsilon + 1 \dots 2^{t - 1}\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {|alpha_{l}|^{2} if l in {eps + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |alpha_{l}|^{2}
#    core type: Operation
#    operator: 20
#    operands: 4
# 3. l in {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|alpha_{l}|, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 23
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, {eps + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 18, 8
# 7. |alpha_{l}|
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. alpha_{l}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# ...
