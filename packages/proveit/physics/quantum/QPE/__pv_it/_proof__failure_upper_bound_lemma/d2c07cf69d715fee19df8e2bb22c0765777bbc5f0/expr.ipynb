# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, l
from proveit.numbers import Exp, Mult, Sum, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Sum(index_or_indices = [l], summand = Mult(IndexedVar(a, one), frac(one, Exp(_diff_l_scaled_delta_floor, two)), ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)), domain = _neg_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 38
#    body: 5
# 4. (l)
#    core type: ExprTuple
#    sub-expressions: 38
# 5. {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}
#    core type: Operation
#    operator: 46
#    operands: 8
# 7. l in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a_{1}, 1 / (l - (2^{t} * delta_{b_{f}}))^{2},c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 38, 14
# 11. a_{1}
#     core type: IndexedVar
# variable: 15
# index: 62
# 12. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 62
#     end_index: 19
# 14. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 62, 22
# 18. _a -> c_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 23
# 19. 0
#     core type: Literal
#     sub-expressions:
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 53
#     operands: 26
# 23. c_{_a}
#     core type: IndexedVar
# variable: 27
# index: 32
# 24. -2^{t - 1} + 1
#     core type: Operation
#     operator: 48
#     operands: 29
# 25. -(e + 1)
#     core type: Operation
#     operator: 57
#     operand: 34
# 26. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 31, 59
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 62
# 30. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 48
#     operands: 35
# 32. _a
#     core type: Variable
#     sub-expressions:
# 33. -2^{t - 1}
#     core type: Operation
#     operator: 57
#     operand: 40
# 34. e + 1
#     core type: Operation
#     operator: 48
#     operands: 37
# 35. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 40
# 37. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 62
# 38. l
#     core type: Variable
#     sub-expressions:
# 39. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 57
#     operand: 44
# 40. 2^{t - 1}
#     core type: Operation
#     operator: 53
#     operands: 43
# 41. e
#     core type: Variable
#     sub-expressions:
# 42. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 44
# 43. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 59, 45
# 44. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. t - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 52
# 50. 2^{t}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. delta_{b_{f}}
#     core type: Operation
#     operator: 55
#     operand: 61
# 52. -1
#     core type: Operation
#     operator: 57
#     operand: 62
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, t)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. delta
#     core type: Literal
#     sub-expressions:
# 56. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 61
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. t
#     core type: Literal
#     sub-expressions:
# 61. b_{f}
#     core type: Literal
#     sub-expressions:
# 62. 1
#     core type: Literal
#     sub-expressions:
