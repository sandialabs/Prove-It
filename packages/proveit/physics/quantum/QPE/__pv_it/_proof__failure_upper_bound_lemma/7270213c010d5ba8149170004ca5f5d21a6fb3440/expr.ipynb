# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(_diff_l_scaled_delta_floor, two)
expr = ExprTuple(Lambda(l, Conditional(Equals(frac(one, Mult(four, sub_expr1)), Mult(frac(one, four), frac(one, sub_expr1))), InSet(l, _neg_domain))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(l \mapsto \left\{\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} = \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 40
#    body: 3
# 2. (l)
#    core type: ExprTuple
#    sub-expressions: 40
# 3. {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. l in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#    core type: ExprTuple
#    sub-expressions: 40, 12
# 10. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 24
#     operands: 13
# 11. (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 48
#     operands: 14
# 12. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 54, 17
# 14. (1 / 4, 1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 48
#     operands: 22
# 18. 1 / 4
#     core type: Operation
#     operator: 24
#     operands: 23
# 19. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. -2^{t - 1} + 1
#     core type: Operation
#     operator: 44
#     operands: 26
# 21. -(e + 1)
#     core type: Operation
#     operator: 50
#     operand: 31
# 22. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 23. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 54, 28
# 24. /
#     core type: Literal
#     sub-expressions:
# 25. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 54, 29
# 26. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 54
# 27. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. 4
#     core type: Literal
#     sub-expressions:
# 29. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 55
#     operands: 32
# 30. -2^{t - 1}
#     core type: Operation
#     operator: 50
#     operand: 36
# 31. e + 1
#     core type: Operation
#     operator: 44
#     operands: 34
# 32. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 35, 59
# 33. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 36
# 34. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 54
# 35. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 44
#     operands: 38
# 36. 2^{t - 1}
#     core type: Operation
#     operator: 55
#     operands: 39
# 37. e
#     core type: Variable
#     sub-expressions:
# 38. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 59, 42
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 50
#     operand: 46
# 42. t - 1
#     core type: Operation
#     operator: 44
#     operands: 45
# 43. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 46
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 47
# 46. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. -1
#     core type: Operation
#     operator: 50
#     operand: 54
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. -
#     core type: Literal
#     sub-expressions:
# 51. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 52. 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. delta_{b_{f}}
#     core type: Operation
#     operator: 57
#     operand: 61
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. Exp
#     core type: Literal
#     sub-expressions:
# 56. (2, t)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. delta
#     core type: Literal
#     sub-expressions:
# 58. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 61
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. t
#     core type: Literal
#     sub-expressions:
# 61. b_{f}
#     core type: Literal
#     sub-expressions:
