# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import InSet
from proveit.numbers import Abs, Exp, LessEq, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _pos_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(LessEq(Exp(Abs(_rel_indexed_alpha), two), frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two)))), InSet(l, _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# l \mapsto \left\{\left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 43
#    body: 2
# 1. (l)
#    core type: ExprTuple
#    sub-expressions: 43
# 2. {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in {e + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (|alpha_{b_{f} MOD_ADD l}|^{2}, 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {e + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 43, 11
# ...
