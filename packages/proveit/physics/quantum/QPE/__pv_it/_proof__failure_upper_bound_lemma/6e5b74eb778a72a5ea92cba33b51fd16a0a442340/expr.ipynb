# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, Implies, InSet
from proveit.numbers import Abs, Exp, Real, Sum, two
from proveit.physics.quantum.QPE import _neg_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Exp(Abs(_rel_indexed_alpha), two)
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr2, Real), domain = _neg_domain), InSet(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Real))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2} \in \mathbb{R}\right)\right] \Rightarrow \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) \in \mathbb{R}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD l}|^{2} in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) in Real)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD l}|^{2} in Real), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) in Real)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD l}|^{2} in Real)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) in Real
#    core type: Operation
#    operator: 22
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}, Real)
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 8. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 45
#    body: 10
# 9. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. {|alpha_{b_{f} MOD_ADD l}|^{2} in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 13
#     condition: 20
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. |alpha_{b_{f} MOD_ADD l}|^{2} in Real
#     core type: Operation
#     operator: 22
#     operands: 15
# 14. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 45
#     body: 17
# 15. (|alpha_{b_{f} MOD_ADD l}|^{2}, Real)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. (l)
#     core type: ExprTuple
#     sub-expressions: 45
# 17. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 48
#     operands: 21
# 20. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 50
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 45, 25
# 24. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 26
#     operand: 30
# 25. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. Abs
#     core type: Literal
#     sub-expressions:
# 27. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 30
# 28. Interval
#     core type: Literal
#     sub-expressions:
# 29. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 33
#     operand: 37
# 31. -2^{t - 1} + 1
#     core type: Operation
#     operator: 52
#     operands: 35
# 32. -(e + 1)
#     core type: Operation
#     operator: 56
#     operand: 39
# 33. alpha
#     core type: Literal
#     sub-expressions:
# 34. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 58
# 36. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 39
# 37. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. -2^{t - 1}
#     core type: Operation
#     operator: 56
#     operand: 46
# 39. e + 1
#     core type: Operation
#     operator: 52
#     operands: 43
# 40. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 41. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 47, 58
# 44. b_{f}
#     core type: Literal
#     sub-expressions:
# 45. l
#     core type: Variable
#     sub-expressions:
# 46. 2^{t - 1}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. e
#     core type: Variable
#     sub-expressions:
# 48. Exp
#     core type: Literal
#     sub-expressions:
# 49. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. 2
#     core type: Literal
#     sub-expressions:
# 51. t - 1
#     core type: Operation
#     operator: 52
#     operands: 53
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. t
#     core type: Literal
#     sub-expressions:
# 55. -1
#     core type: Operation
#     operator: 56
#     operand: 58
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. 1
#     core type: Literal
#     sub-expressions:
