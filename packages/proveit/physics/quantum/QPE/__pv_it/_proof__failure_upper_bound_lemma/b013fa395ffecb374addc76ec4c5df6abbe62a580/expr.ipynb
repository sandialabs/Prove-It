# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals, Forall
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(_diff_l_scaled_delta_floor, two)
expr = Forall(instance_param_or_params = [l], instance_expr = Equals(frac(one, Mult(four, sub_expr1)), Mult(frac(one, four), frac(one, sub_expr1))), domain = _pos_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} = \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 41
#    body: 5
# 4. (l)
#    core type: ExprTuple
#    sub-expressions: 41
# 5. {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. l in {e + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 41, 14
# 12. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 26
#     operands: 15
# 13. (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 47
#     operands: 16
# 14. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 43, 19
# 16. (1 / 4, 1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 47
#     operands: 24
# 20. 1 / 4
#     core type: Operation
#     operator: 26
#     operands: 25
# 21. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. e + 1
#     core type: Operation
#     operator: 38
#     operands: 28
# 23. 2^{t - 1}
#     core type: Operation
#     operator: 51
#     operands: 29
# 24. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 25. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 43, 30
# 26. /
#     core type: Literal
#     sub-expressions:
# 27. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 43, 31
# 28. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 43
# 29. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 33
# 30. 4
#     core type: Literal
#     sub-expressions:
# 31. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 51
#     operands: 34
# 32. e
#     core type: Variable
#     sub-expressions:
# 33. t - 1
#     core type: Operation
#     operator: 38
#     operands: 35
# 34. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 36, 55
# 35. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 56, 37
# 36. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. -1
#     core type: Operation
#     operator: 44
#     operand: 43
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. l
#     core type: Variable
#     sub-expressions:
# 42. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 44
#     operand: 46
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 46
# 46. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 49. 2^{t}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. delta_{b_{f}}
#     core type: Operation
#     operator: 53
#     operand: 57
# 51. Exp
#     core type: Literal
#     sub-expressions:
# 52. (2, t)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. delta
#     core type: Literal
#     sub-expressions:
# 54. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 57
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
# 57. b_{f}
#     core type: Literal
#     sub-expressions:
