# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(_diff_l_scaled_delta_floor, two)
expr = Lambda(l, Conditional(Equals(frac(one, Mult(four, sub_expr1)), Mult(frac(one, four), frac(one, sub_expr1))), InSet(l, _neg_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# l \mapsto \left\{\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} = \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 39
#    body: 2
# 1. (l)
#    core type: ExprTuple
#    sub-expressions: 39
# 2. {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#    core type: ExprTuple
#    sub-expressions: 39, 11
# 9. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 23
#    operands: 12
# 10. (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 47
#     operands: 13
# 11. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 53, 16
# 13. (1 / 4, 1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 47
#     operands: 21
# 17. 1 / 4
#     core type: Operation
#     operator: 23
#     operands: 22
# 18. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. -2^{t - 1} + 1
#     core type: Operation
#     operator: 43
#     operands: 25
# 20. -(e + 1)
#     core type: Operation
#     operator: 49
#     operand: 30
# 21. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 53, 27
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 53, 28
# 25. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 53
# 26. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 30
# 27. 4
#     core type: Literal
#     sub-expressions:
# 28. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 54
#     operands: 31
# 29. -2^{t - 1}
#     core type: Operation
#     operator: 49
#     operand: 35
# 30. e + 1
#     core type: Operation
#     operator: 43
#     operands: 33
# 31. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 34, 58
# 32. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 35
# 33. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 36, 53
# 34. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 43
#     operands: 37
# 35. 2^{t - 1}
#     core type: Operation
#     operator: 54
#     operands: 38
# 36. e
#     core type: Variable
#     sub-expressions:
# 37. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 41
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 49
#     operand: 45
# 41. t - 1
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 45
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 46
# 45. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. -1
#     core type: Operation
#     operator: 49
#     operand: 53
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. 2^{t}
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. delta_{b_{f}}
#     core type: Operation
#     operator: 56
#     operand: 60
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. delta
#     core type: Literal
#     sub-expressions:
# 57. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 60
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. t
#     core type: Literal
#     sub-expressions:
# 60. b_{f}
#     core type: Literal
#     sub-expressions:
