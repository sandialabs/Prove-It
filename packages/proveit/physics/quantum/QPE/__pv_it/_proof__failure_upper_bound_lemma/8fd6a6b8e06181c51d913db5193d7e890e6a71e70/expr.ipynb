# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import InSet
from proveit.numbers import Exp, Mult, Real, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
expr = InSet(Sum(index_or_indices = [l], summand = frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two))), domain = _neg_domain), Real)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) \in \mathbb{R}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))) in Real
#    core type: Operation
#    operator: 13
#    operands: 1
# 1. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})), Real)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 4
#    operand: 6
# 3. Real
#    core type: Literal
#    sub-expressions:
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 33
#    body: 8
# 7. (l)
#    core type: ExprTuple
#    sub-expressions: 33
# 8. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 57, 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 33, 16
# 15. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 41
#     operands: 17
# 16. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. 4
#     core type: Literal
#     sub-expressions:
# 21. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 48
#     operands: 24
# 22. -2^{t - 1} + 1
#     core type: Operation
#     operator: 43
#     operands: 25
# 23. -(e + 1)
#     core type: Operation
#     operator: 52
#     operand: 29
# 24. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 27, 54
# 25. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 57
# 26. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 43
#     operands: 30
# 28. -2^{t - 1}
#     core type: Operation
#     operator: 52
#     operand: 35
# 29. e + 1
#     core type: Operation
#     operator: 43
#     operands: 32
# 30. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 36, 57
# 33. l
#     core type: Variable
#     sub-expressions:
# 34. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 52
#     operand: 39
# 35. 2^{t - 1}
#     core type: Operation
#     operator: 48
#     operands: 38
# 36. e
#     core type: Variable
#     sub-expressions:
# 37. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 39
# 38. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 54, 40
# 39. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 41
#     operands: 42
# 40. t - 1
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. *
#     core type: Literal
#     sub-expressions:
# 42. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 47
# 45. 2^{t}
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. delta_{b_{f}}
#     core type: Operation
#     operator: 50
#     operand: 56
# 47. -1
#     core type: Operation
#     operator: 52
#     operand: 57
# 48. Exp
#     core type: Literal
#     sub-expressions:
# 49. (2, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. delta
#     core type: Literal
#     sub-expressions:
# 51. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. b_{f}
#     core type: Literal
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
