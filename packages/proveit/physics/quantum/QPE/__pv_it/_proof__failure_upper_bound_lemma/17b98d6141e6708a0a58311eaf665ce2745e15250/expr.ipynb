# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(_diff_l_scaled_delta_floor, two)
sub_expr2 = frac(one, Mult(four, sub_expr1))
sub_expr3 = Mult(frac(one, four), frac(one, sub_expr1))
sub_expr4 = InSet(l, _neg_domain)
expr = Implies(Forall(instance_param_or_params = [l], instance_expr = Equals(sub_expr2, sub_expr3), domain = _neg_domain), Equals(Lambda(l, Conditional(sub_expr2, sub_expr4)), Lambda(l, Conditional(sub_expr3, sub_expr4))).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} = \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[l \mapsto \left\{\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}\right..\right] =  \\ \left[l \mapsto \left\{\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}\right..\right] \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))] =>  \\ ([l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), [l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.]
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}., l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. l -> {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 51
#    body: 11
# 9. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 51
#    body: 12
# 10. l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 51
#     body: 14
# 11. {(1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 21
#     condition: 16
# 13. (l)
#     core type: ExprTuple
#     sub-expressions: 51
# 14. {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 22
#     condition: 16
# 15. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 51, 23
# 21. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 35
#     operands: 24
# 22. (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 59
#     operands: 25
# 23. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 65, 28
# 25. (1 / 4, 1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 59
#     operands: 33
# 29. 1 / 4
#     core type: Operation
#     operator: 35
#     operands: 34
# 30. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. -2^{t - 1} + 1
#     core type: Operation
#     operator: 55
#     operands: 37
# 32. -(e + 1)
#     core type: Operation
#     operator: 61
#     operand: 42
# 33. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 65, 39
# 35. /
#     core type: Literal
#     sub-expressions:
# 36. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 65, 40
# 37. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 65
# 38. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. 4
#     core type: Literal
#     sub-expressions:
# 40. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 66
#     operands: 43
# 41. -2^{t - 1}
#     core type: Operation
#     operator: 61
#     operand: 47
# 42. e + 1
#     core type: Operation
#     operator: 55
#     operands: 45
# 43. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 46, 70
# 44. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 65
# 46. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 55
#     operands: 49
# 47. 2^{t - 1}
#     core type: Operation
#     operator: 66
#     operands: 50
# 48. e
#     core type: Variable
#     sub-expressions:
# 49. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 70, 53
# 51. l
#     core type: Variable
#     sub-expressions:
# 52. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 61
#     operand: 57
# 53. t - 1
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 57
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 71, 58
# 57. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. -1
#     core type: Operation
#     operator: 61
#     operand: 65
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (1)
#     core type: ExprTuple
#     sub-expressions: 65
# 63. 2^{t}
#     core type: Operation
#     operator: 66
#     operands: 67
# 64. delta_{b_{f}}
#     core type: Operation
#     operator: 68
#     operand: 72
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. Exp
#     core type: Literal
#     sub-expressions:
# 67. (2, t)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. delta
#     core type: Literal
#     sub-expressions:
# 69. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 72
# 70. 2
#     core type: Literal
#     sub-expressions:
# 71. t
#     core type: Literal
#     sub-expressions:
# 72. b_{f}
#     core type: Literal
#     sub-expressions:
