# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(_diff_l_scaled_delta_floor, two)
sub_expr2 = InSet(l, _pos_domain)
expr = Equals(Lambda(l, Conditional(frac(one, Mult(four, sub_expr1)), sub_expr2)), Lambda(l, Conditional(Mult(frac(one, four), frac(one, sub_expr1)), sub_expr2))).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[l \mapsto \left\{\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right..\right] =  \\ \left[l \mapsto \left\{\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right..\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.] =  \\ [l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}., l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 38
#    body: 5
# 4. l -> {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 38
#    body: 7
# 5. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 8
#    condition: 10
# 6. (l)
#    core type: ExprTuple
#    sub-expressions: 38
# 7. {(1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 21
#    operands: 11
# 9. (1 / 4) * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 46
#    operands: 12
# 10. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 45, 15
# 12. (1 / 4, 1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 38, 18
# 15. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 46
#     operands: 19
# 16. 1 / 4
#     core type: Operation
#     operator: 21
#     operands: 20
# 17. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 45, 25
# 21. /
#     core type: Literal
#     sub-expressions:
# 22. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 45, 26
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. 4
#     core type: Literal
#     sub-expressions:
# 26. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 50
#     operands: 29
# 27. e + 1
#     core type: Operation
#     operator: 36
#     operands: 30
# 28. 2^{t - 1}
#     core type: Operation
#     operator: 50
#     operands: 31
# 29. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 32, 54
# 30. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 45
# 31. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 54, 34
# 32. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 36
#     operands: 35
# 33. e
#     core type: Variable
#     sub-expressions:
# 34. t - 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 40
# 38. l
#     core type: Variable
#     sub-expressions:
# 39. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 42
#     operand: 44
# 40. -1
#     core type: Operation
#     operator: 42
#     operand: 45
# 41. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 44
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. delta_{b_{f}}
#     core type: Operation
#     operator: 52
#     operand: 56
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (2, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. delta
#     core type: Literal
#     sub-expressions:
# 53. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 56
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. b_{f}
#     core type: Literal
#     sub-expressions:
