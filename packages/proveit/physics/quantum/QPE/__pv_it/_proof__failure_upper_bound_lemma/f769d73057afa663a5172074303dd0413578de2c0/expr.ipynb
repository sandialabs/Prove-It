# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, c, l
from proveit.numbers import Exp, Mult, Sum, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
expr = ExprTuple(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _neg_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _neg_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a_{1} \cdot \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}, \sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}
#    core type: Operation
#    operator: 52
#    operands: 3
# 2. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (a_{1}, Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}),c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 16, 5, 18
# 4. (l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 43
#    body: 9
# 7. Sum
#    core type: Literal
#    sub-expressions:
# 8. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 11
#    condition: 15
# 10. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 43
#     body: 13
# 11. a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 52
#     operands: 14
# 12. (l)
#     core type: ExprTuple
#     sub-expressions: 43
# 13. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 17
#     condition: 15
# 14. (a_{1}, 1 / (l - (2^{t} * delta_{b_{f}}))^{2},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 15. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. a_{1}
#     core type: IndexedVar
# variable: 21
# index: 69
# 17. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 69
#     end_index: 25
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 43, 26
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 69, 27
# 24. _a -> c_{_a}
#     core type: Lambda
#     parameter: 37
#     body: 28
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 59
#     operands: 31
# 28. c_{_a}
#     core type: IndexedVar
# variable: 32
# index: 37
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 36, 64
# 32. c
#     core type: Variable
#     sub-expressions:
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. -2^{t - 1} + 1
#     core type: Operation
#     operator: 57
#     operands: 38
# 35. -(e + 1)
#     core type: Operation
#     operator: 67
#     operand: 42
# 36. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 57
#     operands: 40
# 37. _a
#     core type: Variable
#     sub-expressions:
# 38. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 69
# 39. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. -2^{t - 1}
#     core type: Operation
#     operator: 67
#     operand: 48
# 42. e + 1
#     core type: Operation
#     operator: 57
#     operands: 46
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 67
#     operand: 50
# 45. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 48
# 46. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 69
# 47. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 50
# 48. 2^{t - 1}
#     core type: Operation
#     operator: 59
#     operands: 51
# 49. e
#     core type: Variable
#     sub-expressions:
# 50. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 64, 54
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. t - 1
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. 2^{t}
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. delta_{b_{f}}
#     core type: Operation
#     operator: 61
#     operand: 66
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 65, 63
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, t)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. delta
#     core type: Literal
#     sub-expressions:
# 62. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 66
# 63. -1
#     core type: Operation
#     operator: 67
#     operand: 69
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. t
#     core type: Literal
#     sub-expressions:
# 66. b_{f}
#     core type: Literal
#     sub-expressions:
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. 1
#     core type: Literal
#     sub-expressions:
