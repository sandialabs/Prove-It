# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp, Mult, Sum, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
expr = Implies(Forall(instance_param_or_params = sub_expr2, instance_expr = InSet(sub_expr5, Complex), domain = _neg_domain), Forall(instance_param_or_params = [sub_expr3, sub_expr4], instance_expr = Equals(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _neg_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _neg_domain)).with_wrapping_at(2), domain = Complex).with_wrapping()).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \in \mathbb{C}\right)\right] \Rightarrow  \\ \left[\begin{array}{l}\forall_{a_{1}, c_{1}, c_{2}, \ldots, c_{0} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right) \end{array} \end{array}\right)\end{array}\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex)] =>  \\ [forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex), forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex)
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 70
#    body: 10
# 9. (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 13
#     condition: 42
# 11. (a_{1},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 12. {(a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Complex
#     core type: Operation
#     operator: 46
#     operands: 16
# 14. (a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (a_{1} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{0} in Complex)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (1 / (l - (2^{t} * delta_{b_{f}}))^{2}, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 38
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (a_{1} in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. a_{1} * (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 79
#     operands: 25
# 22. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})
#     core type: Operation
#     operator: 32
#     operand: 30
# 23. a_{1} in Complex
#     core type: Operation
#     operator: 46
#     operands: 27
# 24. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 96
#     end_index: 52
# 25. (a_{1}, Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}),c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 43, 29, 45
# 26. (l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 30
# 27. (a_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 38
# 28. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 31
# 29. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 32
#     operand: 36
# 30. l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 70
#     body: 34
# 31. c_{_a} in Complex
#     core type: Operation
#     operator: 46
#     operands: 35
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 34. {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 37
#     condition: 42
# 35. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 38
# 36. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 70
#     body: 40
# 37. a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 79
#     operands: 41
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. (l)
#     core type: ExprTuple
#     sub-expressions: 70
# 40. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 44
#     condition: 42
# 41. (a_{1}, 1 / (l - (2^{t} * delta_{b_{f}}))^{2},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 42. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. a_{1}
#     core type: IndexedVar
# variable: 48
# index: 96
# 44. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 96
#     end_index: 52
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 70, 53
# 48. a
#     core type: Variable
#     sub-expressions:
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 96, 54
# 51. _a -> c_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 55
# 52. 0
#     core type: Literal
#     sub-expressions:
# 53. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 86
#     operands: 58
# 55. c_{_a}
#     core type: IndexedVar
# variable: 59
# index: 64
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 58. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 63, 91
# 59. c
#     core type: Variable
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 61. -2^{t - 1} + 1
#     core type: Operation
#     operator: 84
#     operands: 65
# 62. -(e + 1)
#     core type: Operation
#     operator: 94
#     operand: 69
# 63. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 84
#     operands: 67
# 64. _a
#     core type: Variable
#     sub-expressions:
# 65. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 68, 96
# 66. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 69
# 67. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. -2^{t - 1}
#     core type: Operation
#     operator: 94
#     operand: 75
# 69. e + 1
#     core type: Operation
#     operator: 84
#     operands: 73
# 70. l
#     core type: Variable
#     sub-expressions:
# 71. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 94
#     operand: 77
# 72. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 75
# 73. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 76, 96
# 74. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 77
# 75. 2^{t - 1}
#     core type: Operation
#     operator: 86
#     operands: 78
# 76. e
#     core type: Variable
#     sub-expressions:
# 77. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 79
#     operands: 80
# 78. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 91, 81
# 79. *
#     core type: Literal
#     sub-expressions:
# 80. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 81. t - 1
#     core type: Operation
#     operator: 84
#     operands: 85
# 82. 2^{t}
#     core type: Operation
#     operator: 86
#     operands: 87
# 83. delta_{b_{f}}
#     core type: Operation
#     operator: 88
#     operand: 93
# 84. +
#     core type: Literal
#     sub-expressions:
# 85. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 92, 90
# 86. Exp
#     core type: Literal
#     sub-expressions:
# 87. (2, t)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 88. delta
#     core type: Literal
#     sub-expressions:
# 89. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 93
# 90. -1
#     core type: Operation
#     operator: 94
#     operand: 96
# 91. 2
#     core type: Literal
#     sub-expressions:
# 92. t
#     core type: Literal
#     sub-expressions:
# 93. b_{f}
#     core type: Literal
#     sub-expressions:
# 94. -
#     core type: Literal
#     sub-expressions:
# 95. (1)
#     core type: ExprTuple
#     sub-expressions: 96
# 96. 1
#     core type: Literal
#     sub-expressions:
