# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall
from proveit.numbers import Abs, Exp, LessEq, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [l], instance_expr = LessEq(Exp(Abs(_rel_indexed_alpha), two), frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two)))), domain = _neg_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 47
#    body: 5
# 4. (l)
#    core type: ExprTuple
#    sub-expressions: 47
# 5. {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. |alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. l in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. (|alpha_{b_{f} MOD_ADD l}|^{2}, 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 47, 14
# 12. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 62
#     operands: 15
# 13. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 20, 66
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 61, 21
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 24
#     operand: 29
# 21. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 55
#     operands: 26
# 22. -2^{t - 1} + 1
#     core type: Operation
#     operator: 51
#     operands: 27
# 23. -(e + 1)
#     core type: Operation
#     operator: 57
#     operand: 33
# 24. Abs
#     core type: Literal
#     sub-expressions:
# 25. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 61
# 28. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 34
#     operand: 39
# 30. 4
#     core type: Literal
#     sub-expressions:
# 31. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 62
#     operands: 36
# 32. -2^{t - 1}
#     core type: Operation
#     operator: 57
#     operand: 41
# 33. e + 1
#     core type: Operation
#     operator: 51
#     operands: 38
# 34. alpha
#     core type: Literal
#     sub-expressions:
# 35. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 40, 66
# 37. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 42, 61
# 39. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 51
#     operands: 45
# 41. 2^{t - 1}
#     core type: Operation
#     operator: 62
#     operands: 46
# 42. e
#     core type: Variable
#     sub-expressions:
# 43. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 44. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 68, 47
# 45. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 66, 49
# 47. l
#     core type: Variable
#     sub-expressions:
# 48. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 57
#     operand: 53
# 49. t - 1
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 53
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 67, 54
# 53. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. -1
#     core type: Operation
#     operator: 57
#     operand: 61
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (1)
#     core type: ExprTuple
#     sub-expressions: 61
# 59. 2^{t}
#     core type: Operation
#     operator: 62
#     operands: 63
# 60. delta_{b_{f}}
#     core type: Operation
#     operator: 64
#     operand: 68
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. Exp
#     core type: Literal
#     sub-expressions:
# 63. (2, t)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. delta
#     core type: Literal
#     sub-expressions:
# 65. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 68
# 66. 2
#     core type: Literal
#     sub-expressions:
# 67. t
#     core type: Literal
#     sub-expressions:
# 68. b_{f}
#     core type: Literal
#     sub-expressions:
