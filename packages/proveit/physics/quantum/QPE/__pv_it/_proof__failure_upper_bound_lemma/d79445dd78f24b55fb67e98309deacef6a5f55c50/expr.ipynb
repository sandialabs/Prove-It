# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k
from proveit.logic import InSet
from proveit.numbers import Abs, Exp, LessEq, Mult, four, frac, one, subtract, two
from proveit.physics.quantum.QPE import ModAdd, SubIndexed, _alpha, _b_floor, _delta_b_floor, _neg_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Exp(Abs(SubIndexed(_alpha, [ModAdd(_b_floor, k)])), two), frac(one, Mult(four, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)))), InSet(k, _neg_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left|\alpha_{b_{\textit{f}} \oplus k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } k \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. k in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (|alpha_{b_{f} MOD_ADD k}|^{2}, 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, {-2^{t - 1} + 1 .. -(e + 1)})
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. |alpha_{b_{f} MOD_ADD k}|^{2}
#    core type: Operation
#    operator: 57
#    operands: 10
# 8. 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 11
#    operands: 12
# ...
