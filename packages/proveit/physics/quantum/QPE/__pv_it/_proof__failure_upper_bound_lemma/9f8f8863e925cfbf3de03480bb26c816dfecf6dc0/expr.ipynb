# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import e, l
from proveit.numbers import Add, Exp, LessEq, Mult, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import Pfail, _diff_l_scaled_delta_floor, _neg_domain, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two)))
expr = LessEq(Pfail(e), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[P_{\rm fail}\right]\left(e\right) \leq \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [Pfail](e) <= ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. ([Pfail](e), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [Pfail](e)
#    core type: Operation
#    operator: 5
#    operand: 47
# 4. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 54
#    operands: 7
# 5. Pfail
#    core type: Literal
#    sub-expressions:
# 6. (e)
#    core type: ExprTuple
#    sub-expressions: 47
# 7. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})), Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 48
#     body: 15
# 14. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 48
#     body: 17
# 15. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 19
#     condition: 18
# 16. (l)
#     core type: ExprTuple
#     sub-expressions: 48
# 17. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 24
#     operands: 21
# 19. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 48, 26
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 67, 27
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 48, 28
# 26. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 31
#     operands: 29
# 27. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 56
#     operands: 30
# 28. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 41, 46
# 33. -2^{t - 1} + 1
#     core type: Operation
#     operator: 54
#     operands: 37
# 34. -(e + 1)
#     core type: Operation
#     operator: 61
#     operand: 41
# 35. 4
#     core type: Literal
#     sub-expressions:
# 36. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 63
#     operands: 39
# 37. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 40, 67
# 38. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 42, 68
# 40. -2^{t - 1}
#     core type: Operation
#     operator: 61
#     operand: 46
# 41. e + 1
#     core type: Operation
#     operator: 54
#     operands: 44
# 42. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 54
#     operands: 45
# 43. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 46
# 44. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 47, 67
# 45. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. 2^{t - 1}
#     core type: Operation
#     operator: 63
#     operands: 50
# 47. e
#     core type: Variable
#     sub-expressions:
# 48. l
#     core type: Variable
#     sub-expressions:
# 49. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 61
#     operand: 53
# 50. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 68, 52
# 51. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 53
# 52. t - 1
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 69, 58
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 58. -1
#     core type: Operation
#     operator: 61
#     operand: 67
# 59. 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. delta_{b_{f}}
#     core type: Operation
#     operator: 65
#     operand: 70
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (1)
#     core type: ExprTuple
#     sub-expressions: 67
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (2, t)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. delta
#     core type: Literal
#     sub-expressions:
# 66. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 70
# 67. 1
#     core type: Literal
#     sub-expressions:
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. t
#     core type: Literal
#     sub-expressions:
# 70. b_{f}
#     core type: Literal
#     sub-expressions:
