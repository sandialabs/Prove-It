# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, l
from proveit.logic import Forall
from proveit.numbers import Abs, Exp, LessEq, Mult, Sum, four, frac, one, subtract, two
from proveit.physics.quantum.QPE import ModAdd, SubIndexed, _alpha, _b_floor, _delta_b_floor, _diff_l_scaled_delta_floor, _neg_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = ExprTuple(Forall(instance_param_or_params = [k], instance_expr = LessEq(Exp(Abs(SubIndexed(_alpha, [ModAdd(_b_floor, k)])), two), frac(one, Mult(four, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)))), domain = _neg_domain), LessEq(Sum(index_or_indices = sub_expr1, summand = Exp(Abs(_rel_indexed_alpha), two), domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two))), domain = _neg_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\left|\alpha_{b_{\textit{f}} \oplus k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right), \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) \leq \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 6
# ...
