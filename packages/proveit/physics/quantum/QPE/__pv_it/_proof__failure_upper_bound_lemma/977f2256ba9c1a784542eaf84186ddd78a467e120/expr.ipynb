# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, l
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Exp, Mult, Sum, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
expr = Forall(instance_param_or_params = [sub_expr3, sub_expr4], instance_expr = Equals(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _pos_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _pos_domain)).with_wrapping_at(2), domain = Complex).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{a_{1}, c_{1}, c_{2}, \ldots, c_{0} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left(\sum_{l = e + 1}^{2^{t - 1}} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right) \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1},c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 34, 36
# 5. {(a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{0} in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a_{1} in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. a_{1} * (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 70
#     operands: 16
# 13. Sum_{l = e + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0})
#     core type: Operation
#     operator: 23
#     operand: 21
# 14. a_{1} in Complex
#     core type: Operation
#     operator: 37
#     operands: 18
# 15. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 72
#     end_index: 43
# 16. (a_{1}, Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}),c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 34, 20, 36
# 17. (l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (a_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 19. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 55
#     body: 22
# 20. Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 23
#     operand: 27
# 21. l -> {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 61
#     body: 25
# 22. c_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 26
# 23. Sum
#     core type: Literal
#     sub-expressions:
# 24. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. {a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 28
#     condition: 33
# 26. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 46, 29
# 27. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 61
#     body: 31
# 28. a_{1} * (1 / (l - (2^{t} * delta_{b_{f}}))^{2})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 70
#     operands: 32
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. (l)
#     core type: ExprTuple
#     sub-expressions: 61
# 31. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 35
#     condition: 33
# 32. (a_{1}, 1 / (l - (2^{t} * delta_{b_{f}}))^{2},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36
# 33. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. a_{1}
#     core type: IndexedVar
# variable: 39
# index: 72
# 35. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 72
#     end_index: 43
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 61, 44
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. /
#     core type: Literal
#     sub-expressions:
# 41. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 72, 45
# 42. _a -> c_{_a}
#     core type: Lambda
#     parameter: 55
#     body: 46
# 43. 0
#     core type: Literal
#     sub-expressions:
# 44. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 75
#     operands: 49
# 46. c_{_a}
#     core type: IndexedVar
# variable: 50
# index: 55
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 54, 79
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. e + 1
#     core type: Operation
#     operator: 63
#     operands: 56
# 53. 2^{t - 1}
#     core type: Operation
#     operator: 75
#     operands: 57
# 54. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 63
#     operands: 58
# 55. _a
#     core type: Variable
#     sub-expressions:
# 56. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 72
# 57. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 79, 60
# 58. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. e
#     core type: Variable
#     sub-expressions:
# 60. t - 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 61. l
#     core type: Variable
#     sub-expressions:
# 62. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 68
#     operand: 67
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 80, 66
# 65. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 67
# 66. -1
#     core type: Operation
#     operator: 68
#     operand: 72
# 67. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 70
#     operands: 71
# 68. -
#     core type: Literal
#     sub-expressions:
# 69. (1)
#     core type: ExprTuple
#     sub-expressions: 72
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. 2^{t}
#     core type: Operation
#     operator: 75
#     operands: 76
# 74. delta_{b_{f}}
#     core type: Operation
#     operator: 77
#     operand: 81
# 75. Exp
#     core type: Literal
#     sub-expressions:
# 76. (2, t)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. delta
#     core type: Literal
#     sub-expressions:
# 78. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 81
# 79. 2
#     core type: Literal
#     sub-expressions:
# 80. t
#     core type: Literal
#     sub-expressions:
# 81. b_{f}
#     core type: Literal
#     sub-expressions:
