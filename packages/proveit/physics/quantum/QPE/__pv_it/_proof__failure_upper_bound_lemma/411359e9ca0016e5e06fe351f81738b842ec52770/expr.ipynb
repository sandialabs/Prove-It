# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, l
from proveit.logic import Forall
from proveit.numbers import Abs, Exp, LessEq, Mult, Sum, four, frac, one, subtract, two
from proveit.physics.quantum.QPE import ModAdd, SubIndexed, _alpha, _b_floor, _delta_b_floor, _diff_l_scaled_delta_floor, _pos_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = ExprTuple(Forall(instance_param_or_params = [k], instance_expr = LessEq(Exp(Abs(SubIndexed(_alpha, [ModAdd(_b_floor, k)])), two), frac(one, Mult(four, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)))), domain = _pos_domain), LessEq(Sum(index_or_indices = sub_expr1, summand = Exp(Abs(_rel_indexed_alpha), two), domain = _pos_domain), Sum(index_or_indices = sub_expr1, summand = frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two))), domain = _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\left|\alpha_{b_{\textit{f}} \oplus k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right), \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) \leq \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {e + 1 .. 2^{t - 1}}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))), (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {e + 1 .. 2^{t - 1}}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 75
#    body: 10
# 7. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 12
#    operand: 16
# 8. Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 12
#    operand: 17
# 9. (k)
#    core type: ExprTuple
#    sub-expressions: 75
# 10. {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. |alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. k in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 34
#     operands: 20
# 16. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 76
#     body: 21
# 17. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 76
#     body: 23
# 18. <=
#     core type: Literal
#     sub-expressions:
# 19. (|alpha_{b_{f} MOD_ADD k}|^{2}, 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. (k, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 75, 40
# 21. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 26
#     condition: 28
# 22. (l)
#     core type: ExprTuple
#     sub-expressions: 76
# 23. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 24. |alpha_{b_{f} MOD_ADD k}|^{2}
#     core type: Operation
#     operator: 88
#     operands: 29
# 25. 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 32
#     operands: 30
# 26. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 88
#     operands: 31
# 27. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. (|alpha_{b_{f} MOD_ADD k}|, 2)
#     core type: ExprTuple
#     sub-expressions: 36, 92
# 30. (1, 4 * (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 83, 37
# 31. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 38, 92
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 83, 39
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 76, 40
# 36. |alpha_{b_{f} MOD_ADD k}|
#     core type: Operation
#     operator: 43
#     operand: 48
# 37. 4 * (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 84
#     operands: 42
# 38. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 43
#     operand: 50
# 39. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 84
#     operands: 45
# 40. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. (alpha_{b_{f} MOD_ADD k})
#     core type: ExprTuple
#     sub-expressions: 48
# 42. (4, (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 51, 49
# 43. Abs
#     core type: Literal
#     sub-expressions:
# 44. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 50
# 45. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 46. Interval
#     core type: Literal
#     sub-expressions:
# 47. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 48. alpha_{b_{f} MOD_ADD k}
#     core type: Operation
#     operator: 57
#     operand: 62
# 49. (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 88
#     operands: 56
# 50. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 57
#     operand: 64
# 51. 4
#     core type: Literal
#     sub-expressions:
# 52. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 88
#     operands: 59
# 53. e + 1
#     core type: Operation
#     operator: 73
#     operands: 60
# 54. 2^{t - 1}
#     core type: Operation
#     operator: 88
#     operands: 61
# 55. (b_{f} MOD_ADD k)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. (k - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 63, 92
# 57. alpha
#     core type: Literal
#     sub-expressions:
# 58. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 64
# 59. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 65, 92
# 60. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 66, 83
# 61. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 92, 67
# 62. b_{f} MOD_ADD k
#     core type: Operation
#     operator: 70
#     operands: 68
# 63. k - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 73
#     operands: 69
# 64. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 70
#     operands: 71
# 65. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 73
#     operands: 72
# 66. e
#     core type: Variable
#     sub-expressions:
# 67. t - 1
#     core type: Operation
#     operator: 73
#     operands: 74
# 68. (b_{f}, k)
#     core type: ExprTuple
#     sub-expressions: 94, 75
# 69. (k, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 75, 77
# 70. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 71. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 94, 76
# 72. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 73. +
#     core type: Literal
#     sub-expressions:
# 74. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 93, 78
# 75. k
#     core type: Variable
#     sub-expressions:
# 76. l
#     core type: Variable
#     sub-expressions:
# 77. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 80
#     operand: 82
# 78. -1
#     core type: Operation
#     operator: 80
#     operand: 83
# 79. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 82
# 80. -
#     core type: Literal
#     sub-expressions:
# 81. (1)
#     core type: ExprTuple
#     sub-expressions: 83
# 82. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 84
#     operands: 85
# 83. 1
#     core type: Literal
#     sub-expressions:
# 84. *
#     core type: Literal
#     sub-expressions:
# 85. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 86. 2^{t}
#     core type: Operation
#     operator: 88
#     operands: 89
# 87. delta_{b_{f}}
#     core type: Operation
#     operator: 90
#     operand: 94
# 88. Exp
#     core type: Literal
#     sub-expressions:
# 89. (2, t)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. delta
#     core type: Literal
#     sub-expressions:
# 91. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 94
# 92. 2
#     core type: Literal
#     sub-expressions:
# 93. t
#     core type: Literal
#     sub-expressions:
# 94. b_{f}
#     core type: Literal
#     sub-expressions:
