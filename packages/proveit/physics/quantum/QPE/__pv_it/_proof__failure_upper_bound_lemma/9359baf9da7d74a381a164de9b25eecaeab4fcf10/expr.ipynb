# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l
from proveit.logic import Forall, Implies
from proveit.numbers import Abs, Exp, LessEq, Mult, Sum, four, frac, one, subtract, two
from proveit.physics.quantum.QPE import ModAdd, SubIndexed, _alpha, _b_floor, _delta_b_floor, _diff_l_scaled_delta_floor, _pos_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = Implies(Forall(instance_param_or_params = [k], instance_expr = LessEq(Exp(Abs(SubIndexed(_alpha, [ModAdd(_b_floor, k)])), two), frac(one, Mult(four, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)))), domain = _pos_domain), LessEq(Sum(index_or_indices = sub_expr1, summand = Exp(Abs(_rel_indexed_alpha), two), domain = _pos_domain), Sum(index_or_indices = sub_expr1, summand = frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two))), domain = _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{k \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\left|\alpha_{b_{\textit{f}} \oplus k}\right|^{2} \leq \frac{1}{4 \cdot \left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right] \Rightarrow \left(\left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) \leq \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {e + 1 .. 2^{t - 1}}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})))] => ((Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {e + 1 .. 2^{t - 1}}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))), (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {e + 1 .. 2^{t - 1}}} (|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 77
#    body: 12
# 9. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 14
#    operand: 18
# 10. Sum_{l = e + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: Operation
#     operator: 14
#     operand: 19
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 77
# 12. {|alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})) if k in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. Sum
#     core type: Literal
#     sub-expressions:
# 15. (l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. |alpha_{b_{f} MOD_ADD k}|^{2} <= (1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. k in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 22
# 18. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 78
#     body: 23
# 19. l -> {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 78
#     body: 25
# 20. <=
#     core type: Literal
#     sub-expressions:
# 21. (|alpha_{b_{f} MOD_ADD k}|^{2}, 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. (k, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 77, 42
# 23. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 28
#     condition: 30
# 24. (l)
#     core type: ExprTuple
#     sub-expressions: 78
# 25. {1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}) if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. |alpha_{b_{f} MOD_ADD k}|^{2}
#     core type: Operation
#     operator: 90
#     operands: 31
# 27. 1 / (4 * (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 34
#     operands: 32
# 28. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 90
#     operands: 33
# 29. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. (|alpha_{b_{f} MOD_ADD k}|, 2)
#     core type: ExprTuple
#     sub-expressions: 38, 94
# 32. (1, 4 * (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 85, 39
# 33. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 40, 94
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 85, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 78, 42
# 38. |alpha_{b_{f} MOD_ADD k}|
#     core type: Operation
#     operator: 45
#     operand: 50
# 39. 4 * (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 86
#     operands: 44
# 40. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 45
#     operand: 52
# 41. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 86
#     operands: 47
# 42. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 43. (alpha_{b_{f} MOD_ADD k})
#     core type: ExprTuple
#     sub-expressions: 50
# 44. (4, (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 53, 51
# 45. Abs
#     core type: Literal
#     sub-expressions:
# 46. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 52
# 47. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 50. alpha_{b_{f} MOD_ADD k}
#     core type: Operation
#     operator: 59
#     operand: 64
# 51. (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 90
#     operands: 58
# 52. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 59
#     operand: 66
# 53. 4
#     core type: Literal
#     sub-expressions:
# 54. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 90
#     operands: 61
# 55. e + 1
#     core type: Operation
#     operator: 75
#     operands: 62
# 56. 2^{t - 1}
#     core type: Operation
#     operator: 90
#     operands: 63
# 57. (b_{f} MOD_ADD k)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. (k - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 65, 94
# 59. alpha
#     core type: Literal
#     sub-expressions:
# 60. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 66
# 61. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 67, 94
# 62. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 68, 85
# 63. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 94, 69
# 64. b_{f} MOD_ADD k
#     core type: Operation
#     operator: 72
#     operands: 70
# 65. k - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 75
#     operands: 71
# 66. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 72
#     operands: 73
# 67. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 75
#     operands: 74
# 68. e
#     core type: Variable
#     sub-expressions:
# 69. t - 1
#     core type: Operation
#     operator: 75
#     operands: 76
# 70. (b_{f}, k)
#     core type: ExprTuple
#     sub-expressions: 96, 77
# 71. (k, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 77, 79
# 72. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 73. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 96, 78
# 74. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 75. +
#     core type: Literal
#     sub-expressions:
# 76. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 95, 80
# 77. k
#     core type: Variable
#     sub-expressions:
# 78. l
#     core type: Variable
#     sub-expressions:
# 79. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 82
#     operand: 84
# 80. -1
#     core type: Operation
#     operator: 82
#     operand: 85
# 81. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 84
# 82. -
#     core type: Literal
#     sub-expressions:
# 83. (1)
#     core type: ExprTuple
#     sub-expressions: 85
# 84. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 86
#     operands: 87
# 85. 1
#     core type: Literal
#     sub-expressions:
# 86. *
#     core type: Literal
#     sub-expressions:
# 87. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 88. 2^{t}
#     core type: Operation
#     operator: 90
#     operands: 91
# 89. delta_{b_{f}}
#     core type: Operation
#     operator: 92
#     operand: 96
# 90. Exp
#     core type: Literal
#     sub-expressions:
# 91. (2, t)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 92. delta
#     core type: Literal
#     sub-expressions:
# 93. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 96
# 94. 2
#     core type: Literal
#     sub-expressions:
# 95. t
#     core type: Literal
#     sub-expressions:
# 96. b_{f}
#     core type: Literal
#     sub-expressions:
