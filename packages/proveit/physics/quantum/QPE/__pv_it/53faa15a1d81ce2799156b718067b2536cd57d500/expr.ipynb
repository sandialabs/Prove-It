# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import eps
from proveit.number import Add, Exp, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(eps, one), Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one))))
# Out:
# expr: (eps + 1, 2^{t - 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon + 1, 2^{t - 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (eps + 1, 2^{t - 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. eps + 1
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. 2^{t - 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (eps, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 14
# 4. Exp
#    core type: Literal
#    sub-expressions:
# 5. (2, t - 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. eps
#    core type: Variable
#    sub-expressions:
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. t - 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. t
#     core type: Literal
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
