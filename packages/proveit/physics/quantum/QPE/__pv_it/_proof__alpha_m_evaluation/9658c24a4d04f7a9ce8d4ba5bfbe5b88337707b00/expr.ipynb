# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import CartExp, Forall, Implies, InSet
from proveit.numbers import Complex, Exp, Mult, e, i, pi, two
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import _m_domain, _phase, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = CartExp(Complex, _two_pow_t)
sub_expr3 = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, _t))
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr3, sub_expr2), domain = _m_domain), InSet(VecSum(index_or_indices = sub_expr1, summand = sub_expr3, domain = _m_domain), sub_expr2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right) \in \mathbb{C}^{2^{t}}\right)\right] \Rightarrow  \\ \left(\left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right) \in \mathbb{C}^{2^{t}}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}})] =>  \\ ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}}), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}}
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}), Complex^{2^{t}})
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 8. k -> {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 47
#    body: 10
# 9. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 20
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}}
#     core type: Operation
#     operator: 25
#     operands: 15
# 14. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 47
#     body: 17
# 15. (e^{2 * pi * i * phase * k} * |k〉_{t}, Complex^{2^{t}})
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. (k)
#     core type: ExprTuple
#     sub-expressions: 47
# 17. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. Complex^{2^{t}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. CartExp
#     core type: Literal
#     sub-expressions:
# 22. (Complex, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 27, 48
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 47, 30
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 50
#     operands: 31
# 29. |k〉_{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. NUM_KET
#     core type: Literal
#     sub-expressions:
# 33. (k, t)
#     core type: ExprTuple
#     sub-expressions: 47, 55
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. e
#     core type: Literal
#     sub-expressions:
# 37. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. *
#     core type: Literal
#     sub-expressions:
# 41. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 54, 44, 45, 46, 47
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. pi
#     core type: Literal
#     sub-expressions:
# 45. i
#     core type: Literal
#     sub-expressions:
# 46. phase
#     core type: Literal
#     sub-expressions:
# 47. k
#     core type: Variable
#     sub-expressions:
# 48. 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. -1
#     core type: Operation
#     operator: 52
#     operand: 56
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (2, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
