# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import Equals, Implies, InClass
from proveit.numbers import Exp, Mult, Sum, e, i, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult, QmultCodomain
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _phase, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = NumBra(m, _t)
sub_expr3 = InverseFourierTransform(_t)
sub_expr4 = NumKet(k, _t)
sub_expr5 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr6 = Qmult(sub_expr2, sub_expr3, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr5, sub_expr4), domain = _m_domain))
expr = Implies(InClass(sub_expr6, QmultCodomain), Equals(sub_expr6, Sum(index_or_indices = sub_expr1, summand = Mult(sub_expr5, Qmult(sub_expr2, sub_expr3, sub_expr4)), domain = _m_domain)).with_wrapping_at(1)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) \\  = \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right)\right)\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*) =>  \\ (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*, ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Q*
#    core type: Literal
#    sub-expressions:
# 10. {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 32
#     operands: 12
# 11. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. ({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 36, 37, 15
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 60
#     body: 19
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 21
#     condition: 26
# 20. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 60
#     body: 23
# 21. e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: Operation
#     operator: 53
#     operands: 24
# 22. (k)
#     core type: ExprTuple
#     sub-expressions: 60
# 23. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. (e^{2 * pi * i * phase * k}, {t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 34, 27
# 25. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 34, 38
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 60, 35
# 32. .
#     core type: Literal
#     sub-expressions:
# 33. ({t}_〈m|, FT^{dag}_{t}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38
# 34. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 63
#     operands: 39
# 35. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. {t}_〈m|
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. FT^{dag}_{t}
#     core type: Operation
#     operator: 44
#     operand: 68
# 38. |k〉_{t}
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 42. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 43. (m, t)
#     core type: ExprTuple
#     sub-expressions: 52, 68
# 44. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 45. (t)
#     core type: ExprTuple
#     sub-expressions: 68
# 46. NUM_KET
#     core type: Literal
#     sub-expressions:
# 47. (k, t)
#     core type: ExprTuple
#     sub-expressions: 60, 68
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. 2^{t} - 1
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. m
#     core type: Variable
#     sub-expressions:
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 67, 57, 58, 59, 60
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. pi
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Literal
#     sub-expressions:
# 59. phase
#     core type: Literal
#     sub-expressions:
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. -1
#     core type: Operation
#     operator: 65
#     operand: 69
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (2, t)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. t
#     core type: Literal
#     sub-expressions:
# 69. 1
#     core type: Literal
#     sub-expressions:
