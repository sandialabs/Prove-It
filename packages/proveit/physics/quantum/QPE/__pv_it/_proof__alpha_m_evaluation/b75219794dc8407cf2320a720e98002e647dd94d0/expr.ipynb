# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, m
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.numbers import Exp, Mult, e, frac, i, one, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _phase, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = NumBra(m, _t)
sub_expr2 = InverseFourierTransform(_t)
sub_expr3 = frac(one, Exp(two, frac(_t, two)))
sub_expr4 = VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, _t)), domain = _m_domain)
expr = ExprTuple(Qmult(sub_expr1, Qmult(sub_expr2, ScalarMult(sub_expr3, sub_expr4))), Qmult(sub_expr1, ScalarMult(sub_expr3, Qmult(sub_expr2, sub_expr4))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left({_{t}}\langle m \rvert \thinspace \left({\mathrm {FT}}^{\dag}_{t} \thinspace \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right), {_{t}}\langle m \rvert \thinspace \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left({\mathrm {FT}}^{\dag}_{t} \thinspace \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 16
#    operands: 4
# 3. ({t}_〈m|, FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 6, 5
# 4. ({t}_〈m|, (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. {t}_〈m|
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 36
#    operands: 11
# 8. (FT^{dag}_{t}, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 9. NUM_BRA
#    core type: Literal
#    sub-expressions:
# 10. (m, t)
#     core type: ExprTuple
#     sub-expressions: 13, 67
# 11. (1 / 2^{t / 2}, FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 12. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 36
#     operands: 15
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. .
#     core type: Literal
#     sub-expressions:
# 17. (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 34
#     operands: 21
# 19. FT^{dag}_{t}
#     core type: Operation
#     operator: 22
#     operand: 67
# 20. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 24
#     operand: 27
# 21. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 68, 26
# 22. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 23. (t)
#     core type: ExprTuple
#     sub-expressions: 67
# 24. Sum
#     core type: Literal
#     sub-expressions:
# 25. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. 2^{t / 2}
#     core type: Operation
#     operator: 62
#     operands: 28
# 27. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 59
#     body: 30
# 28. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 66, 31
# 29. (k)
#     core type: ExprTuple
#     sub-expressions: 59
# 30. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 31. t / 2
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 67, 66
# 36. *
#     core type: Literal
#     sub-expressions:
# 37. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 42
# 40. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 62
#     operands: 43
# 41. |k〉_{t}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. NUM_KET
#     core type: Literal
#     sub-expressions:
# 45. (k, t)
#     core type: ExprTuple
#     sub-expressions: 59, 67
# 46. Interval
#     core type: Literal
#     sub-expressions:
# 47. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. 2^{t} - 1
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 66, 56, 57, 58, 59
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 56. pi
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Literal
#     sub-expressions:
# 58. phase
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. 2^{t}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. -1
#     core type: Operation
#     operator: 64
#     operand: 68
# 62. Exp
#     core type: Literal
#     sub-expressions:
# 63. (2, t)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (1)
#     core type: ExprTuple
#     sub-expressions: 68
# 66. 2
#     core type: Literal
#     sub-expressions:
# 67. t
#     core type: Literal
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
