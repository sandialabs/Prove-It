# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _m_domain, _phase, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = frac(one, Exp(two, frac(_t, two)))
sub_expr3 = Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))
expr = Equals(Sum(index_or_indices = sub_expr1, summand = Mult(sub_expr2, sub_expr3), domain = _m_domain), Mult(sub_expr2, Sum(index_or_indices = sub_expr1, summand = sub_expr3, domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k = 0}^{2^{t} - 1} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\right) = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: Operation
#    operator: 10
#    operand: 7
# 4. (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: Operation
#    operator: 54
#    operands: 6
# 5. (k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: ExprTuple
#    sub-expressions: 17, 8
# 7. k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 60
#    body: 9
# 8. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 12
#    condition: 19
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: Operation
#     operator: 54
#     operands: 14
# 13. k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 60
#     body: 16
# 14. (1 / 2^{t / 2}, e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (k)
#     core type: ExprTuple
#     sub-expressions: 60
# 16. {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 47
#     operands: 20
# 18. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 54
#     operands: 21
# 19. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 53, 24
# 21. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 60, 27
# 24. 2^{t / 2}
#     core type: Operation
#     operator: 56
#     operands: 28
# 25. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 29
# 26. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 56
#     operands: 30
# 27. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 62, 33
# 29. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 30. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. t / 2
#     core type: Operation
#     operator: 47
#     operands: 39
# 34. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 54
#     operands: 40
# 35. e
#     core type: Literal
#     sub-expressions:
# 36. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 49
#     operand: 45
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 40. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 44, 60
# 41. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 44. phase
#     core type: Literal
#     sub-expressions:
# 45. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. -1
#     core type: Operation
#     operator: 49
#     operand: 53
# 47. /
#     core type: Literal
#     sub-expressions:
# 48. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. 2 * pi * i * k * m
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 60, 61
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. pi
#     core type: Literal
#     sub-expressions:
# 59. i
#     core type: Literal
#     sub-expressions:
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. m
#     core type: Variable
#     sub-expressions:
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. t
#     core type: Literal
#     sub-expressions:
