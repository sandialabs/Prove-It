# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, m
from proveit.linear_algebra import ScalarMult
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Mult, e, i, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _phase, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = NumBra(m, _t)
sub_expr2 = InverseFourierTransform(_t)
sub_expr3 = NumKet(k, _t)
sub_expr4 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr5 = Mult(sub_expr4, Qmult(sub_expr1, sub_expr2, sub_expr3))
sub_expr6 = Qmult(sub_expr1, sub_expr2, ScalarMult(sub_expr4, sub_expr3))
sub_expr7 = InSet(k, _m_domain)
expr = ExprTuple(Forall(instance_param_or_params = [k], instance_expr = Equals(sub_expr6, sub_expr5), domain = _m_domain), Equals(Lambda(k, Conditional(sub_expr6, sub_expr7)), Lambda(k, Conditional(sub_expr5, sub_expr7))).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right)\right)\right), \begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{{_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))), [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}., k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 64
#    body: 9
# 7. k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 64
#    body: 10
# 8. k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 64
#    body: 12
# 9. {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 19
#     condition: 14
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 64
# 12. {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 20
#     condition: 14
# 13. ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 64, 21
# 19. {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 32
#     operands: 22
# 20. e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: Operation
#     operator: 58
#     operands: 23
# 21. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. ({t}_〈m|, FT^{dag}_{t}, e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 26
# 23. (e^{2 * pi * i * phase * k}, {t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 36, 27
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. 2^{t} - 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 36, 39
# 32. .
#     core type: Literal
#     sub-expressions:
# 33. ({t}_〈m|, FT^{dag}_{t}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 49
#     operands: 42
# 37. {t}_〈m|
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. FT^{dag}_{t}
#     core type: Operation
#     operator: 45
#     operand: 56
# 39. |k〉_{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 40. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 41. -1
#     core type: Operation
#     operator: 51
#     operand: 57
# 42. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 43. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 44. (m, t)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 45. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 46. (t)
#     core type: ExprTuple
#     sub-expressions: 56
# 47. NUM_KET
#     core type: Literal
#     sub-expressions:
# 48. (k, t)
#     core type: ExprTuple
#     sub-expressions: 64, 56
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 56
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 57
# 53. e
#     core type: Literal
#     sub-expressions:
# 54. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. m
#     core type: Variable
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. *
#     core type: Literal
#     sub-expressions:
# 59. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62, 63, 64
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. pi
#     core type: Literal
#     sub-expressions:
# 62. i
#     core type: Literal
#     sub-expressions:
# 63. phase
#     core type: Literal
#     sub-expressions:
# 64. k
#     core type: Variable
#     sub-expressions:
