# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, k, m
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [k]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))
expr = Equals(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _m_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _m_domain)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left(\sum_{k = 0}^{2^{t} - 1} \left(a_{1} \cdot \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}
#    core type: Operation
#    operator: 56
#    operands: 5
# 4. Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})
#    core type: Operation
#    operator: 9
#    operand: 8
# 5. (a_{1}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}),c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 18, 7, 20
# 6. (k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 62
#    body: 11
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 17
# 12. k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 62
#     body: 15
# 13. a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 56
#     operands: 16
# 14. (k)
#     core type: ExprTuple
#     sub-expressions: 62
# 15. {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 19
#     condition: 17
# 16. (a_{1}, e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 17. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. a_{1}
#     core type: IndexedVar
# variable: 23
# index: 53
# 19. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 56
#     operands: 24
# 20. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 53
#     end_index: 36
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 62, 26
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. _a -> c_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 29
# 26. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 58
#     operands: 32
# 28. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 58
#     operands: 33
# 29. c_{_a}
#     core type: IndexedVar
# variable: 34
# index: 41
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 33. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. c
#     core type: Variable
#     sub-expressions:
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 41
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 56
#     operands: 44
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 49
#     operand: 48
# 41. _a
#     core type: Variable
#     sub-expressions:
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 46
# 44. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 64, 60, 61, 47, 62
# 45. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48
# 46. -1
#     core type: Operation
#     operator: 49
#     operand: 53
# 47. phase
#     core type: Literal
#     sub-expressions:
# 48. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. /
#     core type: Literal
#     sub-expressions:
# 52. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. 2 * pi * i * k * m
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. 2^{t}
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 64, 60, 61, 62, 63
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, t)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 60. pi
#     core type: Literal
#     sub-expressions:
# 61. i
#     core type: Literal
#     sub-expressions:
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. m
#     core type: Variable
#     sub-expressions:
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. t
#     core type: Literal
#     sub-expressions:
