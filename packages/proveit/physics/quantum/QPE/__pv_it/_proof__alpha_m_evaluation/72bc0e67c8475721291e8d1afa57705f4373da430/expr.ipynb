# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, c, k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Exp, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [k]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))
expr = Forall(instance_param_or_params = [sub_expr3, sub_expr4], instance_expr = Equals(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _m_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _m_domain)).with_wrapping_at(2), domain = Complex).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{a_{1}, c_{1}, c_{2}, \ldots, c_{0} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left(\sum_{k = 0}^{2^{t} - 1} \left(a_{1} \cdot \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right) \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1},c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 34, 36
# 5. {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a_{1} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{0} in Complex)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a_{1} in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 72
#     operands: 16
# 13. Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})
#     core type: Operation
#     operator: 23
#     operand: 21
# 14. a_{1} in Complex
#     core type: Operation
#     operator: 37
#     operands: 18
# 15. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 69
#     end_index: 52
# 16. (a_{1}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}),c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 34, 20, 36
# 17. (k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. (a_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 19. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 57
#     body: 22
# 20. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: Operation
#     operator: 23
#     operand: 27
# 21. k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 78
#     body: 25
# 22. c_{_a} in Complex
#     core type: Operation
#     operator: 37
#     operands: 26
# 23. Sum
#     core type: Literal
#     sub-expressions:
# 24. (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 28
#     condition: 33
# 26. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 45, 29
# 27. k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 78
#     body: 31
# 28. a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 72
#     operands: 32
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. (k)
#     core type: ExprTuple
#     sub-expressions: 78
# 31. {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 35
#     condition: 33
# 32. (a_{1}, e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36
# 33. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. a_{1}
#     core type: IndexedVar
# variable: 39
# index: 69
# 35. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 72
#     operands: 40
# 36. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 69
#     end_index: 52
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 78, 42
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. _a -> c_{_a}
#     core type: Lambda
#     parameter: 57
#     body: 45
# 42. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 74
#     operands: 48
# 44. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 74
#     operands: 49
# 45. c_{_a}
#     core type: IndexedVar
# variable: 50
# index: 57
# 46. Interval
#     core type: Literal
#     sub-expressions:
# 47. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 48. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 49. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 50. c
#     core type: Variable
#     sub-expressions:
# 51. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 52. 0
#     core type: Literal
#     sub-expressions:
# 53. 2^{t} - 1
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 72
#     operands: 60
# 55. e
#     core type: Literal
#     sub-expressions:
# 56. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 65
#     operand: 64
# 57. _a
#     core type: Variable
#     sub-expressions:
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 71, 62
# 60. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 80, 76, 77, 63, 78
# 61. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64
# 62. -1
#     core type: Operation
#     operator: 65
#     operand: 69
# 63. phase
#     core type: Literal
#     sub-expressions:
# 64. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 67. /
#     core type: Literal
#     sub-expressions:
# 68. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. 2 * pi * i * k * m
#     core type: Operation
#     operator: 72
#     operands: 73
# 71. 2^{t}
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. *
#     core type: Literal
#     sub-expressions:
# 73. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 80, 76, 77, 78, 79
# 74. Exp
#     core type: Literal
#     sub-expressions:
# 75. (2, t)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 76. pi
#     core type: Literal
#     sub-expressions:
# 77. i
#     core type: Literal
#     sub-expressions:
# 78. k
#     core type: Variable
#     sub-expressions:
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. 2
#     core type: Literal
#     sub-expressions:
# 81. t
#     core type: Literal
#     sub-expressions:
