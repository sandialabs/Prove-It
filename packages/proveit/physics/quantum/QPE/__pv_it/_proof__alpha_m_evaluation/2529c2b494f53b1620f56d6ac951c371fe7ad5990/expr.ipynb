# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, c, k, m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [k]
sub_expr3 = IndexedVar(a, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, zero)
sub_expr5 = Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))
expr = ExprTuple(Forall(instance_param_or_params = sub_expr2, instance_expr = InSet(sub_expr5, Complex), domain = _m_domain), Forall(instance_param_or_params = [sub_expr3, sub_expr4], instance_expr = Equals(Mult(sub_expr3, Sum(index_or_indices = sub_expr2, summand = sub_expr5, domain = _m_domain), sub_expr4), Sum(index_or_indices = sub_expr2, summand = Mult(sub_expr3, sub_expr5, sub_expr4), domain = _m_domain)).with_wrapping_at(2), domain = Complex).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right) \in \mathbb{C}\right), \begin{array}{l}\forall_{a_{1}, c_{1}, c_{2}, \ldots, c_{0} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(a_{1} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right) =  \\ \left(\sum_{k = 0}^{2^{t} - 1} \left(a_{1} \cdot \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\cdot c_{1} \cdot  c_{2} \cdot  \ldots \cdot  c_{0}\right)\right) \end{array} \end{array}\right)\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex), forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (k -> {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. k -> {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 85
#    body: 8
# 7. (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 11
#    condition: 40
# 9. (a_{1},c_{1}, c_{2}, ..., c_{0})
#    core type: ExprTuple
#    sub-expressions: 41, 43
# 10. {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex
#     core type: Operation
#     operator: 44
#     operands: 14
# 12. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (a_{1} in Complex)and (c_{1} in Complex) and  (c_{2} in Complex) and  ... and  (c_{0} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in Complex,(c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 79
#     operands: 23
# 20. Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})
#     core type: Operation
#     operator: 30
#     operand: 28
# 21. a_{1} in Complex
#     core type: Operation
#     operator: 44
#     operands: 25
# 22. (c_{1} in Complex), (c_{2} in Complex), ..., (c_{0} in Complex)
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 76
#     end_index: 59
# 23. (a_{1}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}),c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 41, 27, 43
# 24. (k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (a_{1}, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 36
# 26. _a -> (c_{_a} in Complex)
#     core type: Lambda
#     parameter: 64
#     body: 29
# 27. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: Operation
#     operator: 30
#     operand: 34
# 28. k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 85
#     body: 32
# 29. c_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 33
# 30. Sum
#     core type: Literal
#     sub-expressions:
# 31. (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 35
#     condition: 40
# 33. (c_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 36
# 34. k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 85
#     body: 38
# 35. a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}
#     core type: Operation
#     operator: 79
#     operands: 39
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. (k)
#     core type: ExprTuple
#     sub-expressions: 85
# 38. {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 42
#     condition: 40
# 39. (a_{1}, e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})},c_{1}, c_{2}, ..., c_{0})
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 40. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. a_{1}
#     core type: IndexedVar
# variable: 46
# index: 76
# 42. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 79
#     operands: 47
# 43. c_{1}, c_{2}, ..., c_{0}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 76
#     end_index: 59
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 85, 49
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. _a -> c_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 52
# 49. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 81
#     operands: 55
# 51. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 81
#     operands: 56
# 52. c_{_a}
#     core type: IndexedVar
# variable: 57
# index: 64
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 56. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 57. c
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 59. 0
#     core type: Literal
#     sub-expressions:
# 60. 2^{t} - 1
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 79
#     operands: 67
# 62. e
#     core type: Literal
#     sub-expressions:
# 63. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 72
#     operand: 71
# 64. _a
#     core type: Variable
#     sub-expressions:
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 78, 69
# 67. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 87, 83, 84, 70, 85
# 68. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 71
# 69. -1
#     core type: Operation
#     operator: 72
#     operand: 76
# 70. phase
#     core type: Literal
#     sub-expressions:
# 71. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. -
#     core type: Literal
#     sub-expressions:
# 73. (1)
#     core type: ExprTuple
#     sub-expressions: 76
# 74. /
#     core type: Literal
#     sub-expressions:
# 75. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 76. 1
#     core type: Literal
#     sub-expressions:
# 77. 2 * pi * i * k * m
#     core type: Operation
#     operator: 79
#     operands: 80
# 78. 2^{t}
#     core type: Operation
#     operator: 81
#     operands: 82
# 79. *
#     core type: Literal
#     sub-expressions:
# 80. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 87, 83, 84, 85, 86
# 81. Exp
#     core type: Literal
#     sub-expressions:
# 82. (2, t)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 83. pi
#     core type: Literal
#     sub-expressions:
# 84. i
#     core type: Literal
#     sub-expressions:
# 85. k
#     core type: Variable
#     sub-expressions:
# 86. m
#     core type: Variable
#     sub-expressions:
# 87. 2
#     core type: Literal
#     sub-expressions:
# 88. t
#     core type: Literal
#     sub-expressions:
