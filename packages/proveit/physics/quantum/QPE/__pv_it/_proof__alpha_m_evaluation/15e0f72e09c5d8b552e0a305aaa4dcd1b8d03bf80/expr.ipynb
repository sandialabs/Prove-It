# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, frac, i, one, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _phase, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = NumBra(m, _t)
sub_expr2 = InverseFourierTransform(_t)
sub_expr3 = frac(one, Exp(two, frac(_t, two)))
sub_expr4 = VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, _t)), domain = _m_domain)
expr = Equals(Qmult(sub_expr1, sub_expr3, sub_expr2, sub_expr4), Qmult(sub_expr3, sub_expr1, sub_expr2, sub_expr4)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left({_{t}}\langle m \rvert \thinspace \frac{1}{2^{\frac{t}{2}}} \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) =  \\ \left(\frac{1}{2^{\frac{t}{2}}} \thinspace {_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ({t}_〈m|, 1 / 2^{t / 2}, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: ExprTuple
#    sub-expressions: 9, 8, 10, 11
# 6. .
#    core type: Literal
#    sub-expressions:
# 7. (1 / 2^{t / 2}, {t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. 1 / 2^{t / 2}
#    core type: Operation
#    operator: 28
#    operands: 12
# 9. {t}_〈m|
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. FT^{dag}_{t}
#     core type: Operation
#     operator: 15
#     operand: 61
# 11. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 17
#     operand: 21
# 12. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 62, 19
# 13. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 14. (m, t)
#     core type: ExprTuple
#     sub-expressions: 20, 61
# 15. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 16. (t)
#     core type: ExprTuple
#     sub-expressions: 61
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. 2^{t / 2}
#     core type: Operation
#     operator: 56
#     operands: 22
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 53
#     body: 24
# 22. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 60, 25
# 23. (k)
#     core type: ExprTuple
#     sub-expressions: 53
# 24. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. t / 2
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. /
#     core type: Literal
#     sub-expressions:
# 29. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 61, 60
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 53, 36
# 34. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 37
# 35. |k〉_{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. NUM_KET
#     core type: Literal
#     sub-expressions:
# 39. (k, t)
#     core type: ExprTuple
#     sub-expressions: 53, 61
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. e
#     core type: Literal
#     sub-expressions:
# 43. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. 0
#     core type: Literal
#     sub-expressions:
# 45. 2^{t} - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 60, 50, 51, 52, 53
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. pi
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Literal
#     sub-expressions:
# 52. phase
#     core type: Literal
#     sub-expressions:
# 53. k
#     core type: Variable
#     sub-expressions:
# 54. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. -1
#     core type: Operation
#     operator: 58
#     operand: 62
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. -
#     core type: Literal
#     sub-expressions:
# 59. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Literal
#     sub-expressions:
# 62. 1
#     core type: Literal
#     sub-expressions:
