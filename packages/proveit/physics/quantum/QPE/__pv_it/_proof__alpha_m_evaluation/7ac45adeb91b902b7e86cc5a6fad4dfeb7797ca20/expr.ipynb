# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [k], instance_expr = Equals(Qmult(NumBra(m, _t), InverseFourierTransform(_t), NumKet(k, _t)), Mult(frac(one, Exp(two, frac(_t, two))), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))), domain = _m_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right) = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 59
#    body: 5
# 4. (k)
#    core type: ExprTuple
#    sub-expressions: 59
# 5. {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. k in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}, (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 14
# 12. {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 53
#     operands: 17
# 14. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. .
#     core type: Literal
#     sub-expressions:
# 16. ({t}_〈m|, FT^{dag}_{t}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 17. (1 / 2^{t / 2}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. {t}_〈m|
#     core type: Operation
#     operator: 27
#     operands: 28
# 21. FT^{dag}_{t}
#     core type: Operation
#     operator: 29
#     operand: 62
# 22. |k〉_{t}
#     core type: Operation
#     operator: 31
#     operands: 32
# 23. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 49
#     operands: 33
# 24. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 55
#     operands: 34
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. 2^{t} - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 27. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 28. (m, t)
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 29. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 30. (t)
#     core type: ExprTuple
#     sub-expressions: 62
# 31. NUM_KET
#     core type: Literal
#     sub-expressions:
# 32. (k, t)
#     core type: ExprTuple
#     sub-expressions: 59, 62
# 33. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 47, 37
# 34. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 40
# 37. 2^{t / 2}
#     core type: Operation
#     operator: 55
#     operands: 41
# 38. e
#     core type: Literal
#     sub-expressions:
# 39. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 43
#     operand: 46
# 40. -1
#     core type: Operation
#     operator: 43
#     operand: 47
# 41. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 61, 45
# 42. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 47
# 45. t / 2
#     core type: Operation
#     operator: 49
#     operands: 48
# 46. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. 2 * pi * i * k * m
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 61, 57, 58, 59, 60
# 55. Exp
#     core type: Literal
#     sub-expressions:
# 56. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. pi
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. m
#     core type: Variable
#     sub-expressions:
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t
#     core type: Literal
#     sub-expressions:
