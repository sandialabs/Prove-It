# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _m_domain, _phase, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr3 = frac(one, Exp(two, frac(_t, two)))
sub_expr4 = Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t)))
expr = Equals(Sum(index_or_indices = sub_expr1, summand = Mult(sub_expr2, sub_expr3, sub_expr4), domain = _m_domain), Sum(index_or_indices = sub_expr1, summand = Mult(sub_expr3, Mult(sub_expr2, sub_expr4)), domain = _m_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \frac{1}{2^{\frac{t}{2}}} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right) = \left(\sum_{k = 0}^{2^{t} - 1} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 60
#    body: 10
# 9. k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 60
#    body: 12
# 10. {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 15
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 60
# 12. {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 54
#     operands: 16
# 14. (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: Operation
#     operator: 54
#     operands: 17
# 15. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (e^{2 * pi * i * phase * k}, 1 / 2^{t / 2}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 28, 20, 29
# 17. (1 / 2^{t / 2}, e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 60, 22
# 20. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 50
#     operands: 23
# 21. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 54
#     operands: 24
# 22. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 49, 27
# 24. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. 2^{t / 2}
#     core type: Operation
#     operator: 56
#     operands: 32
# 28. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 33
# 29. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 56
#     operands: 34
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. 2^{t} - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 62, 37
# 33. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 34. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 41
# 37. t / 2
#     core type: Operation
#     operator: 50
#     operands: 42
# 38. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 54
#     operands: 43
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 45
#     operand: 48
# 41. -1
#     core type: Operation
#     operator: 45
#     operand: 49
# 42. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 43. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 47, 60
# 44. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. -
#     core type: Literal
#     sub-expressions:
# 46. (1)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. phase
#     core type: Literal
#     sub-expressions:
# 48. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. /
#     core type: Literal
#     sub-expressions:
# 51. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. 2 * pi * i * k * m
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 60, 61
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. pi
#     core type: Literal
#     sub-expressions:
# 59. i
#     core type: Literal
#     sub-expressions:
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. m
#     core type: Variable
#     sub-expressions:
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. t
#     core type: Literal
#     sub-expressions:
