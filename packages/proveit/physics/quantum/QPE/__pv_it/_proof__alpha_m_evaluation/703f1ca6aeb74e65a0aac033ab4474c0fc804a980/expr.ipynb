# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.numbers import Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _m_domain, _phase, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(one, Exp(two, frac(_t, two)))
expr = Mult(sub_expr1, sub_expr1, Sum(index_or_indices = [k], summand = Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t)))), domain = _m_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \frac{1}{2^{\frac{t}{2}}} \cdot \frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: Operation
#    operator: 45
#    operands: 1
# 1. (1 / 2^{t / 2}, 1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
#    core type: ExprTuple
#    sub-expressions: 2, 2, 3
# 2. 1 / 2^{t / 2}
#    core type: Operation
#    operator: 38
#    operands: 4
# 3. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1, 2^{t / 2})
#    core type: ExprTuple
#    sub-expressions: 44, 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. 2^{t / 2}
#    core type: Operation
#    operator: 47
#    operands: 9
# 8. k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 51
#    body: 11
# 9. (2, t / 2)
#    core type: ExprTuple
#    sub-expressions: 53, 12
# 10. (k)
#     core type: ExprTuple
#     sub-expressions: 51
# 11. {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. t / 2
#     core type: Operation
#     operator: 38
#     operands: 15
# 13. e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 45
#     operands: 16
# 14. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 16. (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 51, 21
# 19. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 47
#     operands: 22
# 20. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 47
#     operands: 23
# 21. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 23. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 45
#     operands: 31
# 27. e
#     core type: Literal
#     sub-expressions:
# 28. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 40
#     operand: 36
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. 2^{t} - 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 53, 49, 50, 35, 51
# 32. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 36
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 43, 37
# 35. phase
#     core type: Literal
#     sub-expressions:
# 36. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. -1
#     core type: Operation
#     operator: 40
#     operand: 44
# 38. /
#     core type: Literal
#     sub-expressions:
# 39. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. (1)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. 2 * pi * i * k * m
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 53, 49, 50, 51, 52
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (2, t)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. pi
#     core type: Literal
#     sub-expressions:
# 50. i
#     core type: Literal
#     sub-expressions:
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. m
#     core type: Variable
#     sub-expressions:
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. t
#     core type: Literal
#     sub-expressions:
