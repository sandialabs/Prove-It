# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, m
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.numbers import Exp, Mult, e, i, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _phase, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = NumBra(m, _t)
sub_expr3 = InverseFourierTransform(_t)
sub_expr4 = NumKet(k, _t)
sub_expr5 = Exp(e, Mult(two, pi, i, _phase, k))
expr = ExprTuple(VecSum(index_or_indices = sub_expr1, summand = Qmult(sub_expr2, sub_expr3, ScalarMult(sub_expr5, sub_expr4)), domain = _m_domain), VecSum(index_or_indices = sub_expr1, summand = Mult(sub_expr5, Qmult(sub_expr2, sub_expr3, sub_expr4)), domain = _m_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t} - 1} \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right), \sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 56
#    body: 8
# 7. k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 56
#    body: 10
# 8. {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 11
#    condition: 13
# 9. (k)
#    core type: ExprTuple
#    sub-expressions: 56
# 10. {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 23
#     operands: 14
# 12. e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: Operation
#     operator: 47
#     operands: 15
# 13. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. ({t}_〈m|, FT^{dag}_{t}, e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 18
# 15. (e^{2 * pi * i * phase * k}, {t}_〈m| . FT^{dag}_{t} . |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 27, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 18. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 27, 30
# 23. .
#     core type: Literal
#     sub-expressions:
# 24. ({t}_〈m|, FT^{dag}_{t}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 49
#     operands: 33
# 28. {t}_〈m|
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. FT^{dag}_{t}
#     core type: Operation
#     operator: 36
#     operand: 58
# 30. |k〉_{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 34. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 35. (m, t)
#     core type: ExprTuple
#     sub-expressions: 44, 58
# 36. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 37. (t)
#     core type: ExprTuple
#     sub-expressions: 58
# 38. NUM_KET
#     core type: Literal
#     sub-expressions:
# 39. (k, t)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. e
#     core type: Literal
#     sub-expressions:
# 43. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. -1
#     core type: Operation
#     operator: 51
#     operand: 59
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 57, 53, 54, 55, 56
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 59
# 53. pi
#     core type: Literal
#     sub-expressions:
# 54. i
#     core type: Literal
#     sub-expressions:
# 55. phase
#     core type: Literal
#     sub-expressions:
# 56. k
#     core type: Variable
#     sub-expressions:
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. t
#     core type: Literal
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
