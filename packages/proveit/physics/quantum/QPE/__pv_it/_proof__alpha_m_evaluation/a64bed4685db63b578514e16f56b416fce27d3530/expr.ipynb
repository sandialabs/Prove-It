# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, m
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _m_domain, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(k, Conditional(Equals(Qmult(NumBra(m, _t), InverseFourierTransform(_t), NumKet(k, _t)), Mult(frac(one, Exp(two, frac(_t, two))), Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))))), InSet(k, _m_domain))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(k \mapsto \left\{\left({_{t}}\langle m \rvert \thinspace {\mathrm {FT}}^{\dag}_{t} \thinspace \lvert k \rangle_{t}\right) = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 57
#    body: 3
# 2. (k)
#    core type: ExprTuple
#    sub-expressions: 57
# 3. {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. k in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# ...
