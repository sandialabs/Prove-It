# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit._common_ import l
from proveit.logic import InSet
from proveit.number import Add, Exp, IntervalCO, Neg, frac, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = frac(one, two)
expr = InSet(Add(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))))), IntervalCO(Neg(subExpr1), subExpr1))
# Out:
# expr: (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\delta - \frac{l}{2^{t}}\right) \in \left[-\frac{1}{2},\frac{1}{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (delta - (l / 2^{t}), [-(1 / 2),1 / 2))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. delta - (l / 2^{t})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (delta, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. IntervalCO
#    core type: Literal
#    sub-expressions:
# 8. (-(1 / 2), 1 / 2)
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 9. delta
#    core type: Literal
#    sub-expressions:
# 10. -(l / 2^{t})
#     core type: Operation
#     operator: 13
#     operand: 12
# 11. -(1 / 2)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. l / 2^{t}
#     core type: Operation
#     operator: 16
#     operands: 15
# ...
