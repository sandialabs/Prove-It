# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, Lambda, Variable, l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Exp, Sum, two
from proveit.physics.quantum.QPE import _neg_domain, _pos_domain, _rel_indexed_alpha
from proveit.statistics import ProbOfAll

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = [l]
sub_expr3 = Exp(Abs(_rel_indexed_alpha), two)
expr = Lambda(sub_expr1, Equals(ProbOfAll(instance_param_or_params = sub_expr2, instance_element = Function(sub_expr1, sub_expr2)), Add(Sum(index_or_indices = sub_expr2, summand = sub_expr3, domain = _neg_domain), Sum(index_or_indices = sub_expr2, summand = sub_expr3, domain = _pos_domain))).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# {_{-}b} \mapsto \left(\begin{array}{c} \begin{array}{l} \left[\textrm{Prob}_{l}~{_{-}b}\left(l\right)\right] =  \\ \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right)\right) \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. _b -> ([Prob_{l} _b(l)] =  \\ ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})))
#    core type: Lambda
#    parameter: 17
#    body: 2
# 1. (_b)
#    core type: ExprTuple
#    sub-expressions: 17
# 2. [Prob_{l} _b(l)] =  \\ ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Prob_{l} _b(l), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. Prob_{l} _b(l)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
# ...
