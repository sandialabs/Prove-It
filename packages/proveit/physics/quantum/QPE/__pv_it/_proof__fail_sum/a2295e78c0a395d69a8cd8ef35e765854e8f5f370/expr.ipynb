# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, e, l
from proveit.numbers import Abs, Add, Exp, Interval, Neg, Sum, one, subtract, two
from proveit.physics.quantum.QPE import _neg_domain, _pos_domain, _rel_indexed_alpha, _two_pow__t_minus_one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Exp(Abs(_rel_indexed_alpha), two)
sub_expr3 = Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain)
expr = ExprTuple(Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), sub_expr3), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = Interval(Add(Neg(_two_pow__t_minus_one), one), subtract(Neg(e), one))), sub_expr3))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right), \left(\sum_{l = -2^{t - 1} + 1}^{-e - 1} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}), (Sum_{l = -2^{t - 1} + 1}^{-e - 1} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: Operation
#    operator: 64
#    operands: 3
# 2. (Sum_{l = -2^{t - 1} + 1}^{-e - 1} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: Operation
#    operator: 64
#    operands: 4
# 3. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: ExprTuple
#    sub-expressions: 5, 7
# 4. (Sum_{l = -2^{t - 1} + 1}^{-e - 1} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 10
#    operand: 12
# 6. Sum_{l = -2^{t - 1} + 1}^{-e - 1} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 10
#    operand: 13
# 7. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -e - 1}.)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 59
#     body: 15
# 13. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -e - 1}.
#     core type: Lambda
#     parameter: 59
#     body: 16
# 14. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 59
#     body: 18
# 15. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 21
#     condition: 19
# 16. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -e - 1}.
#     core type: Conditional
#     value: 21
#     condition: 20
# 17. (l)
#     core type: ExprTuple
#     sub-expressions: 59
# 18. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 26
#     operands: 23
# 20. l in {-2^{t - 1} + 1 .. -e - 1}
#     core type: Operation
#     operator: 26
#     operands: 24
# 21. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 60
#     operands: 25
# 22. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 59, 28
# 24. (l, {-2^{t - 1} + 1 .. -e - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 29
# 25. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 30, 62
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 59, 31
# 28. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 36
#     operands: 32
# 29. {-2^{t - 1} + 1 .. -e - 1}
#     core type: Operation
#     operator: 36
#     operands: 33
# 30. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 34
#     operand: 41
# 31. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 33. (-2^{t - 1} + 1, -e - 1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. Abs
#     core type: Literal
#     sub-expressions:
# 35. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. Interval
#     core type: Literal
#     sub-expressions:
# 37. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 47, 56
# 38. -(e + 1)
#     core type: Operation
#     operator: 68
#     operand: 47
# 39. -2^{t - 1} + 1
#     core type: Operation
#     operator: 64
#     operands: 43
# 40. -e - 1
#     core type: Operation
#     operator: 64
#     operands: 44
# 41. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 70
# 44. (-e, -1)
#     core type: ExprTuple
#     sub-expressions: 49, 67
# 45. alpha
#     core type: Literal
#     sub-expressions:
# 46. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. e + 1
#     core type: Operation
#     operator: 64
#     operands: 51
# 48. -2^{t - 1}
#     core type: Operation
#     operator: 68
#     operand: 56
# 49. -e
#     core type: Operation
#     operator: 68
#     operand: 57
# 50. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 70
# 52. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. (e)
#     core type: ExprTuple
#     sub-expressions: 57
# 54. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 55. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. 2^{t - 1}
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. e
#     core type: Variable
#     sub-expressions:
# 58. b_{f}
#     core type: Literal
#     sub-expressions:
# 59. l
#     core type: Variable
#     sub-expressions:
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. t - 1
#     core type: Operation
#     operator: 64
#     operands: 65
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. t
#     core type: Literal
#     sub-expressions:
# 67. -1
#     core type: Operation
#     operator: 68
#     operand: 70
# 68. -
#     core type: Literal
#     sub-expressions:
# 69. (1)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. 1
#     core type: Literal
#     sub-expressions:
