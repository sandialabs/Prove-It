# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, Variable, VertExprArray, l
from proveit.logic import Injections
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import ModAdd, QPE, _Omega, _U, _b_floor, _ket_u, _pos_domain, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, one)
sub_expr3 = Add(_t, _s)
sub_expr4 = Interval(sub_expr2, sub_expr3)
sub_expr5 = MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr3))
expr = ExprTuple(Lambda(l, Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Input(state = ket_plus), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr4), one, _s)], [ExprRange(sub_expr1, sub_expr5, one, _t), ExprRange(sub_expr1, sub_expr5, sub_expr2, sub_expr3)], [ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(ModAdd(_b_floor, l), _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr4), one, _s)]))), Injections(_pos_domain, _Omega))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(l \mapsto \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert b_{\textit{f}} \oplus l \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert b_{\textit{f}} \oplus l \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert b_{\textit{f}} \oplus l \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert b_{\textit{f}} \oplus l \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array}\right), \left[\{e + 1~\ldotp \ldotp~2^{t - 1}\} \xrightarrow[]{\text{1-to-1}} \Omega\right]\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (l -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))), Injections({e + 1 .. 2^{t - 1}}, Omega))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. l -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Lambda
#    parameter: 104
#    body: 4
# 2. Injections({e + 1 .. 2^{t - 1}}, Omega)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. (l)
#    core type: ExprTuple
#    sub-expressions: 104
# 4. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. Injections
#    core type: Literal
#    sub-expressions:
# 6. ({e + 1 .. 2^{t - 1}}, Omega)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 8. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. {e + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 78
#    operands: 15
# 10. Omega
#     core type: Literal
#     sub-expressions:
# 11. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 14. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 15. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 16. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 98
#     end_index: 99
# 17. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 98
#     end_index: 100
# 18. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 98
#     end_index: 99
# 19. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 87
#     end_index: 88
# 20. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 98
#     end_index: 99
# 21. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 98
#     end_index: 100
# 22. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 98
#     end_index: 99
# 23. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 98
#     end_index: 100
# 24. e + 1
#     core type: Operation
#     operator: 94
#     operands: 33
# 25. 2^{t - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 26. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 86
#     body: 36
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 86
#     body: 37
# 28. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 86
#     body: 38
# 29. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 86
#     body: 39
# 30. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 86
#     body: 40
# 31. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 86
#     body: 41
# 32. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 86
#     body: 43
# 33. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 98
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 36. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 70
#     operands: 47
# 37. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 48
# 38. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 49
# 39. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 50
#     operands: 51
# 40. [GATE]{operation:I}
#     core type: Operation
#     operator: 71
#     operands: 52
# 41. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 54
#     operands: 53
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 86
# 43. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 55
# 44. e
#     core type: Variable
#     sub-expressions:
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. t - 1
#     core type: Operation
#     operator: 94
#     operands: 56
# 47. {state:|+〉}
#     core type: NamedExprs
#     state: 57
# 48. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 58
#     targets: 66
# 49. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 59
#     targets: 60
# 50. MEASURE
#     core type: Literal
#     sub-expressions:
# 51. {basis:Z}
#     core type: NamedExprs
#     basis: 61
# 52. {operation:I}
#     core type: NamedExprs
#     operation: 62
# 53. {element:[OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 63
#     targets: 64
# 54. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 55. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 65
#     targets: 66
# 56. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 99, 67
# 57. |+〉
#     core type: Operation
#     operator: 68
#     operand: 82
# 58. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 70
#     operands: 77
# 59. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 71
#     operands: 72
# 60. {1 .. t + s}
#     core type: Operation
#     operator: 78
#     operands: 73
# 61. Z
#     core type: Literal
#     sub-expressions:
# 62. I
#     core type: Literal
#     sub-expressions:
# 63. [OUTPUT]{state:|b_{f} MOD_ADD l〉_{t}, part:_a}
#     core type: Operation
#     operator: 76
#     operands: 74
# 64. {1 .. t}
#     core type: Operation
#     operator: 78
#     operands: 75
# 65. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 66. {t + 1 .. t + s}
#     core type: Operation
#     operator: 78
#     operands: 79
# 67. -1
#     core type: Operation
#     operator: 80
#     operand: 98
# 68. KET
#     core type: Literal
#     sub-expressions:
# 69. (+)
#     core type: ExprTuple
#     sub-expressions: 82
# 70. INPUT
#     core type: Literal
#     sub-expressions:
# 71. GATE
#     core type: Literal
#     sub-expressions:
# 72. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 83
#     part: 86
# 73. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 98, 88
# 74. {state:|b_{f} MOD_ADD l〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 84
#     part: 86
# 75. (1, t)
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 76. OUTPUT
#     core type: Literal
#     sub-expressions:
# 77. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 85
#     part: 86
# 78. Interval
#     core type: Literal
#     sub-expressions:
# 79. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 80. -
#     core type: Literal
#     sub-expressions:
# 81. (1)
#     core type: ExprTuple
#     sub-expressions: 98
# 82. +
#     core type: Literal
#     sub-expressions:
# 83. QPE(U, t)
#     core type: Operation
#     operator: 89
#     operands: 90
# 84. |b_{f} MOD_ADD l〉_{t}
#     core type: Operation
#     operator: 91
#     operands: 92
# 85. |u>
#     core type: Literal
#     sub-expressions:
# 86. _a
#     core type: Variable
#     sub-expressions:
# 87. t + 1
#     core type: Operation
#     operator: 94
#     operands: 93
# 88. t + s
#     core type: Operation
#     operator: 94
#     operands: 95
# 89. QPE
#     core type: Literal
#     sub-expressions:
# 90. (U, t)
#     core type: ExprTuple
#     sub-expressions: 96, 99
# 91. NUM_KET
#     core type: Literal
#     sub-expressions:
# 92. (b_{f} MOD_ADD l, t)
#     core type: ExprTuple
#     sub-expressions: 97, 99
# 93. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 99, 98
# 94. +
#     core type: Literal
#     sub-expressions:
# 95. (t, s)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 96. U
#     core type: Literal
#     sub-expressions:
# 97. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 101
#     operands: 102
# 98. 1
#     core type: Literal
#     sub-expressions:
# 99. t
#     core type: Literal
#     sub-expressions:
# 100. s
#      core type: Literal
#      sub-expressions:
# 101. MOD_ADD
#      core type: Literal
#      sub-expressions:
# 102. (b_{f}, l)
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 103. b_{f}
#      core type: Literal
#      sub-expressions:
# 104. l
#      core type: Variable
#      sub-expressions:
