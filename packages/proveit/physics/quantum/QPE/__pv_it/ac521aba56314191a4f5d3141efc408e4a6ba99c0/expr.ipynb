# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit.number import Add, Exp, frac, two

# %%
# build up the expression from sub-expressions
expr = Add(frac(Literal("b", context = "proveit.physics.quantum.QPE"), Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))), Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"))
# Out:
# expr: (b / 2^{t}) + delta

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{b}{2^{t}} + \delta

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b / 2^{t}) + delta
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (b / 2^{t}, delta)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b / 2^{t}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. delta
#    core type: Literal
#    sub-expressions:
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (b, 2^{t})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b
#    core type: Literal
#    sub-expressions:
# 8. 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (2, t)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. t
#     core type: Literal
#     sub-expressions:
