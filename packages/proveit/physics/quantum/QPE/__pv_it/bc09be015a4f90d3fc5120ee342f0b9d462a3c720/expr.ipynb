# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import eps, l
from proveit.number import Add, Exp, Interval, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(l, Interval(Add(eps, one), Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))))
# Out:
# expr: (l, {eps + 1...2^{t - 1}})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l, \{\varepsilon + 1 \dots 2^{t - 1}\}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (l, {eps + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. l
#    core type: Variable
#    sub-expressions:
# 2. {eps + 1...2^{t - 1}}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. Interval
#    core type: Literal
#    sub-expressions:
# 4. (eps + 1, 2^{t - 1})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. eps + 1
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. 2^{t - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (eps, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 18
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (2, t - 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. eps
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. t - 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. t
#     core type: Literal
#     sub-expressions:
# 16. -1
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
