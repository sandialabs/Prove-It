# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import eps
from proveit.number import Add, Exp, ModAbs, Neg, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ModAbs(Add(Literal("m", context = "proveit.physics.quantum.QPE"), Neg(Literal("b", context = "proveit.physics.quantum.QPE"))), Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))), eps)
# Out:
# expr: (|m - b|_{mod 2^{t}}, eps)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|m - b\right|_{\textup{mod}\thinspace 2^{t}}, \varepsilon\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|m - b|_{mod 2^{t}}, eps)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |m - b|_{mod 2^{t}}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. eps
#    core type: Variable
#    sub-expressions:
# 3. ModAbs
#    core type: Literal
#    sub-expressions:
# 4. (m - b, 2^{t})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. m - b
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (m, -b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (2, t)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. m
#     core type: Literal
#     sub-expressions:
# 12. -b
#     core type: Operation
#     operator: 15
#     operand: 16
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. t
#     core type: Literal
#     sub-expressions:
# 15. -
# ...
