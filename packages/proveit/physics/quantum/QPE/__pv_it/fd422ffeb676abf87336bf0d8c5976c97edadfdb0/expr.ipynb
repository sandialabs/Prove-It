# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.RegisterBra.html">RegisterBra</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit._common_ import l
from proveit.physics.quantum import RegisterBra
from proveit.physics.quantum.QPE import ModAdd

# %%
# build up the expression from sub-expressions
expr = RegisterBra(ModAdd(Literal("b", context = "proveit.physics.quantum.QPE"), l), Literal("t", context = "proveit.physics.quantum.QPE"))
# Out:
# expr: {t}_〈b MOD_ADD l|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{t}}\langle b \oplus l \rvert

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {t}_〈b MOD_ADD l|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. REGISTER_BRA
#    core type: Literal
#    sub-expressions:
# 2. (b MOD_ADD l, t)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b MOD_ADD l
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. t
#    core type: Literal
#    sub-expressions:
# 5. MOD_ADD
#    core type: Literal
#    sub-expressions:
# 6. (b, l)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b
#    core type: Literal
#    sub-expressions:
# 8. l
#    core type: Variable
#    sub-expressions:
