# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Literal
from proveit._common_ import eps
from proveit.logic import Equals, InSet
from proveit.number import Add, Exp, LessEq, ModAbs, NaturalsPos, Neg, two
from proveit.physics.quantum.QPE import Psuccess
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Lambda(eps, Conditional(Equals(Psuccess(eps), Prob(LessEq(ModAbs(Add(Literal("m", context = "proveit.physics.quantum.QPE"), Neg(Literal("b", context = "proveit.physics.quantum.QPE"))), Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))), eps), Literal("m", context = "proveit.physics.quantum.QPE"))), InSet(eps, NaturalsPos)))
# Out:
# expr: eps -> {[Psuccess](eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps] if eps in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \varepsilon \mapsto \left\{\left[P_{\rm success}\right]\left(\varepsilon\right) = Pr_{m}[\left|m - b\right|_{\textup{mod}\thinspace 2^{t}} \leq \varepsilon] \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. eps -> {[Psuccess](eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps] if eps in NaturalsPos.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {[Psuccess](eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps] if eps in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [Psuccess](eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. eps in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ([Psuccess](eps), Pr_{m}[|m - b|_{mod 2^{t}} <= eps])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (eps, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. [Psuccess](eps)
#    core type: Operation
#    operator: 11
#    operand: 18
# 9. Pr_{m}[|m - b|_{mod 2^{t}} <= eps]
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. NaturalsPos
# ...
