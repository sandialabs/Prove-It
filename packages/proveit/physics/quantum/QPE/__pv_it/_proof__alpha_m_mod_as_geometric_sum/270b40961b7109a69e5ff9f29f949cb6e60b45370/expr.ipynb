# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, m
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Mult, Neg, e, frac, i, pi, subtract, two
from proveit.physics.quantum.QPE import _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = InSet(k, _m_domain)
sub_expr2 = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k)))
sub_expr3 = Exp(Exp(e, Mult(two, pi, i, subtract(_phase, frac(m, _two_pow_t)))), k)
expr = ExprTuple(Forall(instance_param_or_params = [k], instance_expr = Equals(sub_expr2, sub_expr3), domain = _m_domain), Equals(Lambda(k, Conditional(sub_expr2, sub_expr1)), Lambda(k, Conditional(sub_expr3, sub_expr1))).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right) = (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\varphi - \frac{m}{2^{t}}\right)})^{k}\right), \begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\varphi - \frac{m}{2^{t}}\right)})^{k} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}), [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 59
#    body: 9
# 7. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 59
#    body: 10
# 8. k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 59
#    body: 12
# 9. {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 19
#     condition: 14
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 59
# 12. {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 20
#     condition: 14
# 13. (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 21
# 19. e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 53
#     operands: 22
# 20. (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 65
#     operands: 23
# 21. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (e^{-((2 * pi * i * k * m) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. (e^{2 * pi * i * (phase - (m / 2^{t}))}, k)
#     core type: ExprTuple
#     sub-expressions: 28, 59
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 65
#     operands: 31
# 27. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 65
#     operands: 32
# 28. e^{2 * pi * i * (phase - (m / 2^{t}))}
#     core type: Operation
#     operator: 65
#     operands: 33
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. 2^{t} - 1
#     core type: Operation
#     operator: 48
#     operands: 34
# 31. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 37, 35
# 32. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 33. (e, 2 * pi * i * (phase - (m / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 64, 39
# 35. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 55
#     operand: 44
# 36. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 53
#     operands: 41
# 37. e
#     core type: Literal
#     sub-expressions:
# 38. 2 * pi * i * (phase - (m / 2^{t}))
#     core type: Operation
#     operator: 53
#     operands: 42
# 39. -1
#     core type: Operation
#     operator: 55
#     operand: 46
# 40. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44
# 41. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 67, 57, 58, 51, 59
# 42. (2, pi, i, phase - (m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 67, 57, 58, 45
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 61
#     operands: 47
# 45. phase - (m / 2^{t})
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 50, 64
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (phase, -(m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. 2 * pi * i * k * m
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. phase
#     core type: Literal
#     sub-expressions:
# 52. -(m / 2^{t})
#     core type: Operation
#     operator: 55
#     operand: 60
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 67, 57, 58, 59, 63
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (m / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 60
# 57. pi
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. m / 2^{t}
#     core type: Operation
#     operator: 61
#     operands: 62
# 61. /
#     core type: Literal
#     sub-expressions:
# 62. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. m
#     core type: Variable
#     sub-expressions:
# 64. 2^{t}
#     core type: Operation
#     operator: 65
#     operands: 66
# 65. Exp
#     core type: Literal
#     sub-expressions:
# 66. (2, t)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. t
#     core type: Literal
#     sub-expressions:
