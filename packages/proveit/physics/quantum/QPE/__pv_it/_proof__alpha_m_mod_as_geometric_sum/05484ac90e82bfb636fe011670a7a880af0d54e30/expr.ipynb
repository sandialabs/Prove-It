# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, m
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Exp, Mult, Neg, e, frac, i, pi, subtract, two
from proveit.physics.quantum.QPE import _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = InSet(k, _m_domain)
sub_expr2 = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k)))
sub_expr3 = Exp(Exp(e, Mult(two, pi, i, subtract(_phase, frac(m, _two_pow_t)))), k)
expr = Implies(Forall(instance_param_or_params = [k], instance_expr = Equals(sub_expr2, sub_expr3), domain = _m_domain), Equals(Lambda(k, Conditional(sub_expr2, sub_expr1)), Lambda(k, Conditional(sub_expr3, sub_expr1))).with_wrapping_at(2)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right) = (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\varphi - \frac{m}{2^{t}}\right)})^{k}\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\varphi - \frac{m}{2^{t}}\right)})^{k} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})] =>  \\ ([k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}), [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 61
#    body: 11
# 9. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 61
#    body: 12
# 10. k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 61
#     body: 14
# 11. {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 21
#     condition: 16
# 13. (k)
#     core type: ExprTuple
#     sub-expressions: 61
# 14. {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 22
#     condition: 16
# 15. (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 61, 23
# 21. e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 55
#     operands: 24
# 22. (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 67
#     operands: 25
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (e^{-((2 * pi * i * k * m) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. (e^{2 * pi * i * (phase - (m / 2^{t}))}, k)
#     core type: ExprTuple
#     sub-expressions: 30, 61
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 67
#     operands: 33
# 29. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 67
#     operands: 34
# 30. e^{2 * pi * i * (phase - (m / 2^{t}))}
#     core type: Operation
#     operator: 67
#     operands: 35
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 50
#     operands: 36
# 33. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 34. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. (e, 2 * pi * i * (phase - (m / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 66, 41
# 37. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 57
#     operand: 46
# 38. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 55
#     operands: 43
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. 2 * pi * i * (phase - (m / 2^{t}))
#     core type: Operation
#     operator: 55
#     operands: 44
# 41. -1
#     core type: Operation
#     operator: 57
#     operand: 48
# 42. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 69, 59, 60, 53, 61
# 44. (2, pi, i, phase - (m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 69, 59, 60, 47
# 45. (1)
#     core type: ExprTuple
#     sub-expressions: 48
# 46. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 49
# 47. phase - (m / 2^{t})
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 52, 66
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (phase, -(m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. 2 * pi * i * k * m
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. phase
#     core type: Literal
#     sub-expressions:
# 54. -(m / 2^{t})
#     core type: Operation
#     operator: 57
#     operand: 62
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 69, 59, 60, 61, 65
# 57. -
#     core type: Literal
#     sub-expressions:
# 58. (m / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 62
# 59. pi
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Literal
#     sub-expressions:
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. m / 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 64
# 63. /
#     core type: Literal
#     sub-expressions:
# 64. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. m
#     core type: Variable
#     sub-expressions:
# 66. 2^{t}
#     core type: Operation
#     operator: 67
#     operands: 68
# 67. Exp
#     core type: Literal
#     sub-expressions:
# 68. (2, t)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 69. 2
#     core type: Literal
#     sub-expressions:
# 70. t
#     core type: Literal
#     sub-expressions:
