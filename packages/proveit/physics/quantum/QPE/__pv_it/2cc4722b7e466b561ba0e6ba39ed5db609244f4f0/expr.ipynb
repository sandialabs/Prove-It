# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import l
from proveit.number import Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))
expr = ExprTuple(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l), Mult(frac(one, subExpr1), frac(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Mult(subExpr1, Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE")), Neg(l)))))), Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, subExpr1))))))))))
# Out:
# expr: (alpha_{l}, (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha_{l}, \frac{1}{2^{t}} \cdot \frac{1 - e^{2 \cdot \pi \cdot i \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}}{1 - e^{2 \cdot \pi \cdot i \cdot \left(\delta - \frac{l}{2^{t}}\right)}}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (alpha_{l}, (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. alpha_{l}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))}))
#    core type: Operation
#    operator: 37
#    operands: 5
# 3. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 4. (alpha, l)
#    core type: ExprTuple
#    sub-expressions: 6, 44
# 5. (1 / 2^{t}, (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. alpha
#    core type: Literal
#    sub-expressions:
# 7. 1 / 2^{t}
#    core type: Operation
#    operator: 42
#    operands: 9
# 8. (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: Operation
#    operator: 42
# ...
