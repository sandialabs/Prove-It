# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Variable, m
from proveit.core_expr_types import Len
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import I, NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import QPE, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(Add(_t, one), sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr2)))
expr = Len(operands = [Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr3)), sub_expr4, sub_expr4, Lambda(sub_expr1, Measure(basis = Z)), Lambda(sub_expr1, Gate(operation = I).with_implicit_representation()), Lambda(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t))), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr3))])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# |\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 5, 6, 7, 8, 9
# 3. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 53
#    body: 10
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 53
#    body: 11
# 5. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 53
#    body: 12
# 6. _a -> [MEASURE]{basis:Z}
#    core type: Lambda
#    parameter: 53
#    body: 13
# 7. _a -> [GATE]{operation:I}
#    core type: Lambda
#    parameter: 53
#    body: 14
# 8. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#    core type: Lambda
#    parameter: 53
#    body: 15
# 9. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 53
#    body: 17
# 10. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 39
#     operands: 18
# 11. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 25
#     operands: 19
# 12. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 25
#     operands: 20
# 13. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 21
#     operands: 22
# 14. [GATE]{operation:I}
#     core type: Operation
#     operator: 40
#     operands: 23
# 15. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 25
#     operands: 24
# 16. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 17. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. {state:|+〉}
#     core type: NamedExprs
#     state: 27
# 19. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 28
#     targets: 36
# 20. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 29
#     targets: 30
# 21. MEASURE
#     core type: Literal
#     sub-expressions:
# 22. {basis:Z}
#     core type: NamedExprs
#     basis: 31
# 23. {operation:I}
#     core type: NamedExprs
#     operation: 32
# 24. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 33
#     targets: 34
# 25. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 26. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 27. |+〉
#     core type: Operation
#     operator: 37
#     operand: 49
# 28. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 39
#     operands: 46
# 29. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 40
#     operands: 41
# 30. {1 .. t + s}
#     core type: Operation
#     operator: 47
#     operands: 42
# 31. Z
#     core type: Literal
#     sub-expressions:
# 32. I
#     core type: Literal
#     sub-expressions:
# 33. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 43
# 34. {1 .. t}
#     core type: Operation
#     operator: 47
#     operands: 44
# 35. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 36. {t + 1 .. t + s}
#     core type: Operation
#     operator: 47
#     operands: 48
# 37. KET
#     core type: Literal
#     sub-expressions:
# 38. (+)
#     core type: ExprTuple
#     sub-expressions: 49
# 39. INPUT
#     core type: Literal
#     sub-expressions:
# 40. GATE
#     core type: Literal
#     sub-expressions:
# 41. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 50
#     part: 53
# 42. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 65, 55
# 43. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 51
#     part: 53
# 44. (1, t)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 45. OUTPUT
#     core type: Literal
#     sub-expressions:
# 46. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 52
#     part: 53
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. QPE(U, t)
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. |m〉_{t}
#     core type: Operation
#     operator: 58
#     operands: 59
# 52. |u>
#     core type: Literal
#     sub-expressions:
# 53. _a
#     core type: Variable
#     sub-expressions:
# 54. t + 1
#     core type: Operation
#     operator: 61
#     operands: 60
# 55. t + s
#     core type: Operation
#     operator: 61
#     operands: 62
# 56. QPE
#     core type: Literal
#     sub-expressions:
# 57. (U, t)
#     core type: ExprTuple
#     sub-expressions: 63, 66
# 58. NUM_KET
#     core type: Literal
#     sub-expressions:
# 59. (m, t)
#     core type: ExprTuple
#     sub-expressions: 64, 66
# 60. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 66, 65
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (t, s)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. U
#     core type: Literal
#     sub-expressions:
# 64. m
#     core type: Variable
#     sub-expressions:
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. t
#     core type: Literal
#     sub-expressions:
# 67. s
#     core type: Literal
#     sub-expressions:
