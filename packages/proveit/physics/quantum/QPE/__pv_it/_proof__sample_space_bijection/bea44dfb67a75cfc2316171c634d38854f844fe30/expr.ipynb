# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, m, n
from proveit.logic import NotEquals, Or
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import _ket_u, _s, _t
from proveit.physics.quantum.circuits import MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Interval(one, _t)
sub_expr3 = MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), Add(_t, _s)))
expr = Or(ExprRange(sub_expr1, NotEquals(MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = sub_expr2), MultiQubitElem(element = Output(state = NumKet(n, _t), part = sub_expr1), targets = sub_expr2)), one, _t), Or(ExprRange(sub_expr1, NotEquals(sub_expr3, sub_expr3), one, _s)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert n \rangle_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}\right) \lor  \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert n \rangle_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}\right) \lor  \ldots \lor  \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert n \rangle_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}\right) \lor \left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right) \lor  \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right) \lor  \ldots \lor  \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array} \neq \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:1}, targets:{1 .. t}}) or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:2}, targets:{1 .. t}}) or  ... or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:t}, targets:{1 .. t}}) or (([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}) or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}) or  ... or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: Operation
#    operator: 5
#    operands: 1
# 1. (([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:1}, targets:{1 .. t}}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:2}, targets:{1 .. t}}), ..., ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:t}, targets:{1 .. t}}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}) or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}) or  ... or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:1}, targets:{1 .. t}}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:2}, targets:{1 .. t}}), ..., ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:t}, targets:{1 .. t}})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 48
#    end_index: 49
# 3. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}) or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}) or  ... or  ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. _a -> ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}})
#    core type: Lambda
#    parameter: 42
#    body: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}), ..., ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#    core type: Operation
#    operator: 17
#    operands: 9
# 8. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}), ..., ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 48
#    end_index: 50
# 9. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. _a -> ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#     core type: Lambda
#     parameter: 42
#     body: 14
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 26
#     operands: 15
# 12. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 26
#     operands: 16
# 13. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}} != [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 19
#     targets: 21
# 16. {element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 20
#     targets: 21
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 22, 22
# 19. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 35
#     operands: 23
# 20. [OUTPUT]{state:|n〉_{t}, part:_a}
#     core type: Operation
#     operator: 35
#     operands: 24
# 21. {1 .. t}
#     core type: Operation
#     operator: 37
#     operands: 25
# 22. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 28
#     part: 42
# 24. {state:|n〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 29
#     part: 42
# 25. (1, t)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 26. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 27. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 30
#     targets: 31
# 28. |m〉_{t}
#     core type: Operation
#     operator: 33
#     operands: 32
# 29. |n〉_{t}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. {t + 1 .. t + s}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. (m, t)
#     core type: ExprTuple
#     sub-expressions: 39, 49
# 33. NUM_KET
#     core type: Literal
#     sub-expressions:
# 34. (n, t)
#     core type: ExprTuple
#     sub-expressions: 40, 49
# 35. OUTPUT
#     core type: Literal
#     sub-expressions:
# 36. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 41
#     part: 42
# 37. Interval
#     core type: Literal
#     sub-expressions:
# 38. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
# 41. |u>
#     core type: Literal
#     sub-expressions:
# 42. _a
#     core type: Variable
#     sub-expressions:
# 43. t + 1
#     core type: Operation
#     operator: 46
#     operands: 45
# 44. t + s
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (t, s)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. t
#     core type: Literal
#     sub-expressions:
# 50. s
#     core type: Literal
#     sub-expressions:
