# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, Variable, n
from proveit.core_expr_types import Len
from proveit.numbers import Add, Interval, eight, one
from proveit.physics.quantum import I, NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import QPE, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(Add(_t, one), sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr2)))
expr = ExprTuple(Len(operands = [Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr3)), sub_expr4, sub_expr4, Lambda(sub_expr1, Measure(basis = Z)), Lambda(sub_expr1, Gate(operation = I).with_implicit_representation()), Lambda(sub_expr1, MultiQubitElem(element = Output(state = NumKet(n, _t), part = sub_expr1), targets = Interval(one, _t))), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr3))]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, eight)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert n \rangle_{t}~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|, |\left(1, 2, \ldots, 8\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|, |(1, 2, ..., 8)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |(1, 2, ..., 8)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 8, 9, 10, 11, 12
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (1, 2, ..., 8)
#    core type: ExprTuple
#    sub-expressions: 13
# 6. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 59
#    body: 14
# 7. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 59
#    body: 15
# 8. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 59
#    body: 16
# 9. _a -> [MEASURE]{basis:Z}
#    core type: Lambda
#    parameter: 59
#    body: 17
# 10. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 59
#     body: 18
# 11. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 59
#     body: 19
# 12. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 59
#     body: 20
# 13. 1, 2, ..., 8
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 71
#     end_index: 22
# 14. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 45
#     operands: 23
# 15. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 24
# 16. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 25
# 17. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 26
#     operands: 27
# 18. [GATE]{operation:I}
#     core type: Operation
#     operator: 46
#     operands: 28
# 19. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 30
#     operands: 29
# 20. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 21. _a -> _a
#     core type: Lambda
#     parameter: 59
#     body: 59
# 22. 8
#     core type: Literal
#     sub-expressions:
# 23. {state:|+〉}
#     core type: NamedExprs
#     state: 33
# 24. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 34
#     targets: 42
# 25. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 26. MEASURE
#     core type: Literal
#     sub-expressions:
# 27. {basis:Z}
#     core type: NamedExprs
#     basis: 37
# 28. {operation:I}
#     core type: NamedExprs
#     operation: 38
# 29. {element:[OUTPUT]{state:|n〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 39
#     targets: 40
# 30. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 31. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 33. |+〉
#     core type: Operation
#     operator: 43
#     operand: 55
# 34. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 45
#     operands: 52
# 35. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 36. {1 .. t + s}
#     core type: Operation
#     operator: 53
#     operands: 48
# 37. Z
#     core type: Literal
#     sub-expressions:
# 38. I
#     core type: Literal
#     sub-expressions:
# 39. [OUTPUT]{state:|n〉_{t}, part:_a}
#     core type: Operation
#     operator: 51
#     operands: 49
# 40. {1 .. t}
#     core type: Operation
#     operator: 53
#     operands: 50
# 41. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 42. {t + 1 .. t + s}
#     core type: Operation
#     operator: 53
#     operands: 54
# 43. KET
#     core type: Literal
#     sub-expressions:
# 44. (+)
#     core type: ExprTuple
#     sub-expressions: 55
# 45. INPUT
#     core type: Literal
#     sub-expressions:
# 46. GATE
#     core type: Literal
#     sub-expressions:
# 47. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 56
#     part: 59
# 48. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 71, 61
# 49. {state:|n〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 57
#     part: 59
# 50. (1, t)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 51. OUTPUT
#     core type: Literal
#     sub-expressions:
# 52. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 58
#     part: 59
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. QPE(U, t)
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. |n〉_{t}
#     core type: Operation
#     operator: 64
#     operands: 65
# 58. |u>
#     core type: Literal
#     sub-expressions:
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. t + 1
#     core type: Operation
#     operator: 67
#     operands: 66
# 61. t + s
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. QPE
#     core type: Literal
#     sub-expressions:
# 63. (U, t)
#     core type: ExprTuple
#     sub-expressions: 69, 72
# 64. NUM_KET
#     core type: Literal
#     sub-expressions:
# 65. (n, t)
#     core type: ExprTuple
#     sub-expressions: 70, 72
# 66. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 72, 71
# 67. +
#     core type: Literal
#     sub-expressions:
# 68. (t, s)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 69. U
#     core type: Literal
#     sub-expressions:
# 70. n
#     core type: Variable
#     sub-expressions:
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. t
#     core type: Literal
#     sub-expressions:
# 73. s
#     core type: Literal
#     sub-expressions:
