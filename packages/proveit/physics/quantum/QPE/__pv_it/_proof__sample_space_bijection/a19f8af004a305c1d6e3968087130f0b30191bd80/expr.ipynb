# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, Variable, m
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Add, Interval, eight, one
from proveit.physics.quantum import I, NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import QPE, _U, _ket_u, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(Add(_t, one), sub_expr2)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr2)))
expr = Equals(Len(operands = [Lambda(sub_expr1, Input(state = ket_plus)), Lambda(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr3)), sub_expr4, sub_expr4, Lambda(sub_expr1, Measure(basis = Z)), Lambda(sub_expr1, Gate(operation = I).with_implicit_representation()), Lambda(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = Interval(one, _t))), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr3))]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, eight)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# |\left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}\left(U, t\right)~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \meter
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert m \rangle_{t}~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)| = |\left(1, 2, \ldots, 8\right)|

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})| = |(1, 2, ..., 8)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|, |(1, 2, ..., 8)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. |(1, 2, ..., 8)|
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (_a -> [INPUT]{state:|+〉}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}, _a -> [MEASURE]{basis:Z}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 10, 11, 12, 13, 14
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. (1, 2, ..., 8)
#    core type: ExprTuple
#    sub-expressions: 15
# 8. _a -> [INPUT]{state:|+〉}
#    core type: Lambda
#    parameter: 61
#    body: 16
# 9. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 61
#    body: 17
# 10. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 61
#     body: 18
# 11. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 61
#     body: 19
# 12. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 61
#     body: 20
# 13. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 61
#     body: 21
# 14. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 61
#     body: 22
# 15. 1, 2, ..., 8
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 73
#     end_index: 24
# 16. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 47
#     operands: 25
# 17. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 32
#     operands: 26
# 18. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 32
#     operands: 27
# 19. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 28
#     operands: 29
# 20. [GATE]{operation:I}
#     core type: Operation
#     operator: 48
#     operands: 30
# 21. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 32
#     operands: 31
# 22. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 23. _a -> _a
#     core type: Lambda
#     parameter: 61
#     body: 61
# 24. 8
#     core type: Literal
#     sub-expressions:
# 25. {state:|+〉}
#     core type: NamedExprs
#     state: 35
# 26. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 36
#     targets: 44
# 27. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 37
#     targets: 38
# 28. MEASURE
#     core type: Literal
#     sub-expressions:
# 29. {basis:Z}
#     core type: NamedExprs
#     basis: 39
# 30. {operation:I}
#     core type: NamedExprs
#     operation: 40
# 31. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 32. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 33. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 43
#     targets: 44
# 34. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 35. |+〉
#     core type: Operation
#     operator: 45
#     operand: 57
# 36. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 54
# 37. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 48
#     operands: 49
# 38. {1 .. t + s}
#     core type: Operation
#     operator: 55
#     operands: 50
# 39. Z
#     core type: Literal
#     sub-expressions:
# 40. I
#     core type: Literal
#     sub-expressions:
# 41. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 53
#     operands: 51
# 42. {1 .. t}
#     core type: Operation
#     operator: 55
#     operands: 52
# 43. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 53
#     operands: 54
# 44. {t + 1 .. t + s}
#     core type: Operation
#     operator: 55
#     operands: 56
# 45. KET
#     core type: Literal
#     sub-expressions:
# 46. (+)
#     core type: ExprTuple
#     sub-expressions: 57
# 47. INPUT
#     core type: Literal
#     sub-expressions:
# 48. GATE
#     core type: Literal
#     sub-expressions:
# 49. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 58
#     part: 61
# 50. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 73, 63
# 51. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 59
#     part: 61
# 52. (1, t)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 53. OUTPUT
#     core type: Literal
#     sub-expressions:
# 54. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 60
#     part: 61
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. QPE(U, t)
#     core type: Operation
#     operator: 64
#     operands: 65
# 59. |m〉_{t}
#     core type: Operation
#     operator: 66
#     operands: 67
# 60. |u>
#     core type: Literal
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. t + 1
#     core type: Operation
#     operator: 69
#     operands: 68
# 63. t + s
#     core type: Operation
#     operator: 69
#     operands: 70
# 64. QPE
#     core type: Literal
#     sub-expressions:
# 65. (U, t)
#     core type: ExprTuple
#     sub-expressions: 71, 74
# 66. NUM_KET
#     core type: Literal
#     sub-expressions:
# 67. (m, t)
#     core type: ExprTuple
#     sub-expressions: 72, 74
# 68. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 74, 73
# 69. +
#     core type: Literal
#     sub-expressions:
# 70. (t, s)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 71. U
#     core type: Literal
#     sub-expressions:
# 72. m
#     core type: Variable
#     sub-expressions:
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. t
#     core type: Literal
#     sub-expressions:
# 75. s
#     core type: Literal
#     sub-expressions:
