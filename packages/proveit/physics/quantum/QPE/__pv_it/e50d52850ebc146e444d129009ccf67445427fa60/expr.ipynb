# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Literal
from proveit._common_ import l
from proveit.logic import And, InSet, NotEquals
from proveit.number import Abs, Add, Exp, Interval, LessEq, Mult, Neg, four, frac, one, two, zero
from proveit.physics.quantum.QPE import SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))
expr = Lambda(l, Conditional(LessEq(Exp(Abs(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l)), two), frac(one, Mult(four, Exp(Add(l, Neg(Mult(Exp(two, Literal("t", context = "proveit.physics.quantum.QPE")), Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE")))), two)))), And(InSet(l, Interval(Add(Neg(subExpr1), one), subExpr1)), NotEquals(l, zero))))
# Out:
# expr: l -> {|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})) if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left|\alpha_{l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}} \textrm{ if } l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\} ,  l \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> {|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})) if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 40
#    body: 1
# 1. {|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})) if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (l in {-2^{t - 1} + 1...2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <=
#    core type: Literal
#    sub-expressions:
# 5. (|alpha_{l}|^{2}, 1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (l in {-2^{t - 1} + 1...2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. |alpha_{l}|^{2}
#    core type: Operation
#    operator: 52
#    operands: 12
# ...
