# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.IntervalCO.html">IntervalCO</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.number import IntervalCO, Neg, frac, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = frac(one, two)
expr = IntervalCO(Neg(subExpr1), subExpr1)
# Out:
# expr: [-(1 / 2),1 / 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[-\frac{1}{2},\frac{1}{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. IntervalCO
#    core type: Literal
#    sub-expressions:
# 2. (-(1 / 2), 1 / 2)
#    core type: ExprTuple
#    sub-expressions: 3, 5
# 3. -(1 / 2)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. -
#    core type: Literal
#    sub-expressions:
# 5. 1 / 2
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
