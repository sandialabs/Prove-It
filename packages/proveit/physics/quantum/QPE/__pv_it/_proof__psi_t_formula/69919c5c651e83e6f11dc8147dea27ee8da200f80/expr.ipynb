# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Forall, Implies
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import Ket, NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [t]
sub_expr3 = Add(t, one)
sub_expr4 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr5 = Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))))
expr = Implies(And(Equals(SubIndexed(_psi, [one]), ScalarMult(frac(one, sqrt(two)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, Ket(k)), domain = Interval(zero, one)))), Forall(instance_param_or_params = sub_expr2, instance_expr = Equals(SubIndexed(_psi, [sub_expr3]), ScalarMult(frac(one, Exp(two, frac(sub_expr3, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, NumKet(k, sub_expr3)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), domain = NaturalPos, condition = sub_expr5)), Forall(instance_param_or_params = sub_expr2, instance_expr = sub_expr5, domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\lvert \psi_{1} \rangle = \left(\frac{1}{\sqrt{2}} \cdot \left(\sum_{k=0}^{1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)\right) \land \left[\forall_{t \in \mathbb{N}^+~|~\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)}~\left(\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right)\right)\right]\right) \Rightarrow \left[\forall_{t \in \mathbb{N}^+}~\left(\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))]) => [forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))], forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))]
#    core type: Operation
#    operator: 26
#    operands: 5
# 4. forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 11
#    operand: 9
# 5. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))), forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (t -> {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. |psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 39
#    operands: 10
# 8. forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. t -> {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.
#    core type: Lambda
#    parameter: 127
#    body: 13
# 10. (|psi_{1}>, (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. (t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.
#     core type: Conditional
#     value: 33
#     condition: 32
# 14. |psi_{1}>
#     core type: Operation
#     operator: 54
#     operand: 128
# 15. (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: Operation
#     operator: 90
#     operands: 17
# 16. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Lambda
#     parameter: 127
#     body: 18
# 17. (1 / sqrt(2), Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. 1 / sqrt(2)
#     core type: Operation
#     operator: 88
#     operands: 23
# 20. Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)
#     core type: Operation
#     operator: 68
#     operand: 29
# 21. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: Operation
#     operator: 39
#     operands: 25
# 22. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 128, 28
# 24. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. sqrt(2)
#     core type: Operation
#     operator: 122
#     operands: 34
# 29. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Lambda
#     parameter: 119
#     body: 35
# 30. |psi_{t + 1}>
#     core type: Operation
#     operator: 54
#     operand: 94
# 31. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: Operation
#     operator: 90
#     operands: 37
# 32. t in NaturalPos
#     core type: Operation
#     operator: 92
#     operands: 38
# 33. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 126, 41
# 35. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 36. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 94
# 37. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 38. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 127, 46
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 41. 1 / 2
#     core type: Operation
#     operator: 88
#     operands: 49
# 42. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 90
#     operands: 50
# 43. k in {0 .. 1}
#     core type: Operation
#     operator: 92
#     operands: 51
# 44. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 88
#     operands: 52
# 45. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 68
#     operand: 60
# 46. NaturalPos
#     core type: Literal
#     sub-expressions:
# 47. |psi_{t}>
#     core type: Operation
#     operator: 54
#     operand: 127
# 48. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 90
#     operands: 56
# 49. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 128, 126
# 50. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 96, 57
# 51. (k, {0 .. 1})
#     core type: ExprTuple
#     sub-expressions: 119, 58
# 52. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 128, 59
# 53. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. psi
#     core type: Literal
#     sub-expressions:
# 55. (t)
#     core type: ExprTuple
#     sub-expressions: 127
# 56. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. |k〉
#     core type: Operation
#     operator: 63
#     operand: 119
# 58. {0 .. 1}
#     core type: Operation
#     operator: 104
#     operands: 64
# 59. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 122
#     operands: 65
# 60. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 119
#     body: 66
# 61. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 88
#     operands: 67
# 62. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 68
#     operand: 74
# 63. KET
#     core type: Literal
#     sub-expressions:
# 64. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 109, 128
# 65. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 126, 70
# 66. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 71
#     condition: 72
# 67. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 128, 73
# 68. Sum
#     core type: Literal
#     sub-expressions:
# 69. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 74
# 70. (t + 1) / 2
#     core type: Operation
#     operator: 88
#     operands: 75
# 71. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 90
#     operands: 76
# 72. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 92
#     operands: 77
# 73. 2^{t / 2}
#     core type: Operation
#     operator: 122
#     operands: 78
# 74. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 119
#     body: 80
# 75. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 94, 126
# 76. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 96, 81
# 77. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 119, 82
# 78. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 126, 83
# 79. (k)
#     core type: ExprTuple
#     sub-expressions: 119
# 80. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 84
#     condition: 85
# 81. |k〉_{t + 1}
#     core type: Operation
#     operator: 102
#     operands: 86
# 82. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 104
#     operands: 87
# 83. t / 2
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 90
#     operands: 91
# 85. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 92
#     operands: 93
# 86. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 119, 94
# 87. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 109, 95
# 88. /
#     core type: Literal
#     sub-expressions:
# 89. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 127, 126
# 90. *
#     core type: Literal
#     sub-expressions:
# 91. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 92. in
#     core type: Literal
#     sub-expressions:
# 93. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 119, 98
# 94. t + 1
#     core type: Operation
#     operator: 114
#     operands: 99
# 95. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 114
#     operands: 100
# 96. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 122
#     operands: 101
# 97. |k〉_{t}
#     core type: Operation
#     operator: 102
#     operands: 103
# 98. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 104
#     operands: 105
# 99. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 127, 128
# 100. (2 * 2^{t}, -1)
#      core type: ExprTuple
#      sub-expressions: 106, 121
# 101. (e, 2 * pi * i * phase * k)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 102. NUM_KET
#      core type: Literal
#      sub-expressions:
# 103. (k, t)
#      core type: ExprTuple
#      sub-expressions: 119, 127
# 104. Interval
#      core type: Literal
#      sub-expressions:
# 105. (0, 2^{t} - 1)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 106. 2 * 2^{t}
#      core type: Operation
#      operator: 112
#      operands: 111
# 107. e
#      core type: Literal
#      sub-expressions:
# 108. 2 * pi * i * phase * k
#      core type: Operation
#      operator: 112
#      operands: 113
# 109. 0
#      core type: Literal
#      sub-expressions:
# 110. 2^{t} - 1
#      core type: Operation
#      operator: 114
#      operands: 115
# 111. (2, 2^{t})
#      core type: ExprTuple
#      sub-expressions: 126, 120
# 112. *
#      core type: Literal
#      sub-expressions:
# 113. (2, pi, i, phase, k)
#      core type: ExprTuple
#      sub-expressions: 126, 116, 117, 118, 119
# 114. +
#      core type: Literal
#      sub-expressions:
# 115. (2^{t}, -1)
#      core type: ExprTuple
#      sub-expressions: 120, 121
# 116. pi
#      core type: Literal
#      sub-expressions:
# 117. i
#      core type: Literal
#      sub-expressions:
# 118. phase
#      core type: Literal
#      sub-expressions:
# 119. k
#      core type: Variable
#      sub-expressions:
# 120. 2^{t}
#      core type: Operation
#      operator: 122
#      operands: 123
# 121. -1
#      core type: Operation
#      operator: 124
#      operand: 128
# 122. Exp
#      core type: Literal
#      sub-expressions:
# 123. (2, t)
#      core type: ExprTuple
#      sub-expressions: 126, 127
# 124. -
#      core type: Literal
#      sub-expressions:
# 125. (1)
#      core type: ExprTuple
#      sub-expressions: 128
# 126. 2
#      core type: Literal
#      sub-expressions:
# 127. t
#      core type: Variable
#      sub-expressions:
# 128. 1
#      core type: Literal
#      sub-expressions:
