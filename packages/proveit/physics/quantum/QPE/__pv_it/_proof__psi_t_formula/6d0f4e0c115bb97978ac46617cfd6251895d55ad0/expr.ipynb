# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import Ket, NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
expr = ExprTuple(Equals(SubIndexed(_psi, [one]), ScalarMult(frac(one, sqrt(two)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, Ket(k)), domain = Interval(zero, one)))), Forall(instance_param_or_params = [t], instance_expr = Equals(SubIndexed(_psi, [sub_expr2]), ScalarMult(frac(one, Exp(two, frac(sub_expr2, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), domain = NaturalPos, condition = Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\lvert \psi_{1} \rangle = \left(\frac{1}{\sqrt{2}} \cdot \left(\sum_{k=0}^{1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right), \forall_{t \in \mathbb{N}^+~|~\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)}~\left(\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))), forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 31
#    operands: 3
# 2. forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (|psi_{1}>, (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. |psi_{1}>
#    core type: Operation
#    operator: 46
#    operand: 120
# 7. (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 82
#    operands: 9
# 8. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Lambda
#    parameter: 119
#    body: 10
# 9. (1 / sqrt(2), Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. 1 / sqrt(2)
#     core type: Operation
#     operator: 80
#     operands: 15
# 12. Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)
#     core type: Operation
#     operator: 60
#     operand: 21
# 13. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: Operation
#     operator: 31
#     operands: 17
# 14. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 120, 20
# 16. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 17. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. sqrt(2)
#     core type: Operation
#     operator: 114
#     operands: 26
# 21. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Lambda
#     parameter: 111
#     body: 27
# 22. |psi_{t + 1}>
#     core type: Operation
#     operator: 46
#     operand: 86
# 23. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: Operation
#     operator: 82
#     operands: 29
# 24. t in NaturalPos
#     core type: Operation
#     operator: 84
#     operands: 30
# 25. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 118, 33
# 27. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Conditional
#     value: 34
#     condition: 35
# 28. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 86
# 29. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 119, 38
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. 1 / 2
#     core type: Operation
#     operator: 80
#     operands: 41
# 34. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 82
#     operands: 42
# 35. k in {0 .. 1}
#     core type: Operation
#     operator: 84
#     operands: 43
# 36. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 80
#     operands: 44
# 37. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 60
#     operand: 52
# 38. NaturalPos
#     core type: Literal
#     sub-expressions:
# 39. |psi_{t}>
#     core type: Operation
#     operator: 46
#     operand: 119
# 40. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 82
#     operands: 48
# 41. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 120, 118
# 42. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 88, 49
# 43. (k, {0 .. 1})
#     core type: ExprTuple
#     sub-expressions: 111, 50
# 44. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 120, 51
# 45. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 52
# 46. psi
#     core type: Literal
#     sub-expressions:
# 47. (t)
#     core type: ExprTuple
#     sub-expressions: 119
# 48. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. |k〉
#     core type: Operation
#     operator: 55
#     operand: 111
# 50. {0 .. 1}
#     core type: Operation
#     operator: 96
#     operands: 56
# 51. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 114
#     operands: 57
# 52. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 111
#     body: 58
# 53. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 80
#     operands: 59
# 54. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 60
#     operand: 66
# 55. KET
#     core type: Literal
#     sub-expressions:
# 56. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 101, 120
# 57. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 118, 62
# 58. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 63
#     condition: 64
# 59. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 120, 65
# 60. Sum
#     core type: Literal
#     sub-expressions:
# 61. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 66
# 62. (t + 1) / 2
#     core type: Operation
#     operator: 80
#     operands: 67
# 63. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 82
#     operands: 68
# 64. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 84
#     operands: 69
# 65. 2^{t / 2}
#     core type: Operation
#     operator: 114
#     operands: 70
# 66. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 111
#     body: 72
# 67. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 86, 118
# 68. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 88, 73
# 69. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 111, 74
# 70. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 118, 75
# 71. (k)
#     core type: ExprTuple
#     sub-expressions: 111
# 72. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 76
#     condition: 77
# 73. |k〉_{t + 1}
#     core type: Operation
#     operator: 94
#     operands: 78
# 74. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 96
#     operands: 79
# 75. t / 2
#     core type: Operation
#     operator: 80
#     operands: 81
# 76. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 82
#     operands: 83
# 77. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 84
#     operands: 85
# 78. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 111, 86
# 79. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 101, 87
# 80. /
#     core type: Literal
#     sub-expressions:
# 81. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 119, 118
# 82. *
#     core type: Literal
#     sub-expressions:
# 83. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 84. in
#     core type: Literal
#     sub-expressions:
# 85. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 111, 90
# 86. t + 1
#     core type: Operation
#     operator: 106
#     operands: 91
# 87. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 106
#     operands: 92
# 88. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 114
#     operands: 93
# 89. |k〉_{t}
#     core type: Operation
#     operator: 94
#     operands: 95
# 90. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 96
#     operands: 97
# 91. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 119, 120
# 92. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 98, 113
# 93. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 94. NUM_KET
#     core type: Literal
#     sub-expressions:
# 95. (k, t)
#     core type: ExprTuple
#     sub-expressions: 111, 119
# 96. Interval
#     core type: Literal
#     sub-expressions:
# 97. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 98. 2 * 2^{t}
#     core type: Operation
#     operator: 104
#     operands: 103
# 99. e
#     core type: Literal
#     sub-expressions:
# 100. 2 * pi * i * phase * k
#      core type: Operation
#      operator: 104
#      operands: 105
# 101. 0
#      core type: Literal
#      sub-expressions:
# 102. 2^{t} - 1
#      core type: Operation
#      operator: 106
#      operands: 107
# 103. (2, 2^{t})
#      core type: ExprTuple
#      sub-expressions: 118, 112
# 104. *
#      core type: Literal
#      sub-expressions:
# 105. (2, pi, i, phase, k)
#      core type: ExprTuple
#      sub-expressions: 118, 108, 109, 110, 111
# 106. +
#      core type: Literal
#      sub-expressions:
# 107. (2^{t}, -1)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 108. pi
#      core type: Literal
#      sub-expressions:
# 109. i
#      core type: Literal
#      sub-expressions:
# 110. phase
#      core type: Literal
#      sub-expressions:
# 111. k
#      core type: Variable
#      sub-expressions:
# 112. 2^{t}
#      core type: Operation
#      operator: 114
#      operands: 115
# 113. -1
#      core type: Operation
#      operator: 116
#      operand: 120
# 114. Exp
#      core type: Literal
#      sub-expressions:
# 115. (2, t)
#      core type: ExprTuple
#      sub-expressions: 118, 119
# 116. -
#      core type: Literal
#      sub-expressions:
# 117. (1)
#      core type: ExprTuple
#      sub-expressions: 120
# 118. 2
#      core type: Literal
#      sub-expressions:
# 119. t
#      core type: Variable
#      sub-expressions:
# 120. 1
#      core type: Literal
#      sub-expressions:
