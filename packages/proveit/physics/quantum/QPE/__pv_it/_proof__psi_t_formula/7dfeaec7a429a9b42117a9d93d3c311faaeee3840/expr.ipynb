# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr3 = ScalarMult(sub_expr2, NumKet(k, Add(t, one)))
sub_expr4 = Interval(zero, subtract(two_pow_t, one))
sub_expr5 = VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, t)), domain = sub_expr4)
sub_expr6 = VecSum(index_or_indices = sub_expr1, summand = sub_expr3, domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))
sub_expr7 = ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, sub_expr5))
expr = ExprTuple(Equals(sub_expr6, VecAdd(VecSum(index_or_indices = sub_expr1, summand = sub_expr3, domain = sub_expr4), sub_expr7)), Equals(sub_expr6, VecAdd(TensorProd(ket0, sub_expr5), sub_expr7)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) = \left(\left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right), \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) = \left(\left(\lvert 0 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))), (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 11
#    operands: 9
# 7. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 41
#    operand: 14
# 8. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 10. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 41
#     operand: 21
# 14. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 79
#     body: 18
# 15. |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 30
#     operands: 19
# 16. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 56
#     operands: 20
# 17. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 32
#     condition: 22
# 19. (|0〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 23, 36
# 20. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 79
#     body: 26
# 22. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 58
#     operands: 27
# 23. |0〉
#     core type: Operation
#     operator: 40
#     operand: 70
# 24. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 82
#     operands: 29
# 25. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 32
#     condition: 53
# 27. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 79, 33
# 28. (0)
#     core type: ExprTuple
#     sub-expressions: 70
# 29. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 68, 34
# 30. otimes
#     core type: Literal
#     sub-expressions:
# 31. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 56
#     operands: 37
# 33. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 66
#     operands: 38
# 34. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 39
# 35. |1〉
#     core type: Operation
#     operator: 40
#     operand: 88
# 36. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 41
#     operand: 45
# 37. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 60, 43
# 38. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 70, 44
# 39. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 76, 77, 78, 80
# 40. KET
#     core type: Literal
#     sub-expressions:
# 41. Sum
#     core type: Literal
#     sub-expressions:
# 42. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. |k〉_{t + 1}
#     core type: Operation
#     operator: 64
#     operands: 46
# 44. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 74
#     operands: 47
# 45. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 79
#     body: 49
# 46. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 79, 50
# 47. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 51, 81
# 48. (k)
#     core type: ExprTuple
#     sub-expressions: 79
# 49. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 52
#     condition: 53
# 50. t + 1
#     core type: Operation
#     operator: 74
#     operands: 54
# 51. 2 * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 55
# 52. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 55. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 80
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 79, 62
# 60. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 82
#     operands: 63
# 61. |k〉_{t}
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. NUM_KET
#     core type: Literal
#     sub-expressions:
# 65. (k, t)
#     core type: ExprTuple
#     sub-expressions: 79, 87
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. e
#     core type: Literal
#     sub-expressions:
# 69. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 72
#     operands: 73
# 70. 0
#     core type: Literal
#     sub-expressions:
# 71. 2^{t} - 1
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. *
#     core type: Literal
#     sub-expressions:
# 73. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 86, 76, 77, 78, 79
# 74. +
#     core type: Literal
#     sub-expressions:
# 75. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 76. pi
#     core type: Literal
#     sub-expressions:
# 77. i
#     core type: Literal
#     sub-expressions:
# 78. phase
#     core type: Literal
#     sub-expressions:
# 79. k
#     core type: Variable
#     sub-expressions:
# 80. 2^{t}
#     core type: Operation
#     operator: 82
#     operands: 83
# 81. -1
#     core type: Operation
#     operator: 84
#     operand: 88
# 82. Exp
#     core type: Literal
#     sub-expressions:
# 83. (2, t)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 84. -
#     core type: Literal
#     sub-expressions:
# 85. (1)
#     core type: ExprTuple
#     sub-expressions: 88
# 86. 2
#     core type: Literal
#     sub-expressions:
# 87. t
#     core type: Variable
#     sub-expressions:
# 88. 1
#     core type: Literal
#     sub-expressions:
