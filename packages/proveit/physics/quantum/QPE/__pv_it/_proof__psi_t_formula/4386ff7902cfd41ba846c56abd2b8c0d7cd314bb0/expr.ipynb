# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Add(k, two_pow_t)
sub_expr4 = Interval(zero, subtract(two_pow_t, one))
expr = ExprTuple(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr2)), domain = sub_expr4), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, sub_expr3)), NumKet(sub_expr3, sub_expr2)), domain = sub_expr4))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right), \sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot \left(k + 2^{t}\right)} \cdot \lvert k + 2^{t} \rangle_{t + 1}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1})
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 51
#    body: 8
# 7. k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 51
#    body: 10
# 8. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 11
#    condition: 13
# 9. (k)
#    core type: ExprTuple
#    sub-expressions: 51
# 10. {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (e^{2 * pi * i * phase * (k + 2^{t})}, |k + 2^{t}〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 51, 23
# 19. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 54
#     operands: 24
# 20. |k〉_{t + 1}
#     core type: Operation
#     operator: 27
#     operands: 25
# 21. e^{2 * pi * i * phase * (k + 2^{t})}
#     core type: Operation
#     operator: 54
#     operands: 26
# 22. |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 25. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 51, 34
# 26. (e, 2 * pi * i * phase * (k + 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. NUM_KET
#     core type: Literal
#     sub-expressions:
# 28. (k + 2^{t}, t + 1)
#     core type: ExprTuple
#     sub-expressions: 45, 34
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. e
#     core type: Literal
#     sub-expressions:
# 33. 2 * pi * i * phase * (k + 2^{t})
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. t + 1
#     core type: Operation
#     operator: 47
#     operands: 40
# 35. 0
#     core type: Literal
#     sub-expressions:
# 36. 2^{t} - 1
#     core type: Operation
#     operator: 47
#     operands: 41
# 37. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 56, 42, 43, 44, 51
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (2, pi, i, phase, k + 2^{t})
#     core type: ExprTuple
#     sub-expressions: 56, 42, 43, 44, 45
# 40. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 53
# 41. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 42. pi
#     core type: Literal
#     sub-expressions:
# 43. i
#     core type: Literal
#     sub-expressions:
# 44. phase
#     core type: Literal
#     sub-expressions:
# 45. k + 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. -1
#     core type: Operation
#     operator: 49
#     operand: 53
# 47. +
#     core type: Literal
#     sub-expressions:
# 48. (k, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. k
#     core type: Variable
#     sub-expressions:
# 52. 2^{t}
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (2, t)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. t
#     core type: Variable
#     sub-expressions:
