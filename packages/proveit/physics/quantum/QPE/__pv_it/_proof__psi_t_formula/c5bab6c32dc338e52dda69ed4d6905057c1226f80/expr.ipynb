# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = frac(t, two)
sub_expr4 = frac(sub_expr2, two)
sub_expr5 = Exp(e, Mult(two, pi, i, _phase, k))
expr = ExprTuple(ScalarMult(frac(one, Exp(two, sub_expr4)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr5, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), TensorProd(ScalarMult(frac(one, Exp(two, subtract(sub_expr4, sub_expr3))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))), ScalarMult(frac(one, Exp(two, sub_expr3)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr5, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right), \left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 55
#    operands: 3
# 2. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. otimes
#    core type: Literal
#    sub-expressions:
# 5. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 84
#    operands: 10
# 7. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 26
#    operand: 15
# 8. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#    core type: Operation
#    operator: 55
#    operands: 12
# 9. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 55
#    operands: 13
# 10. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 102, 14
# 11. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 96
#     operands: 20
# 15. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 93
#     body: 21
# 16. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 84
#     operands: 22
# 17. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 84
#     operands: 25
# 19. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 26
#     operand: 34
# 20. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 100, 60
# 21. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 22. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 102, 30
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 25. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 102, 33
# 26. Sum
#     core type: Literal
#     sub-expressions:
# 27. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 28. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 55
#     operands: 35
# 29. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 57
#     operands: 36
# 30. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 96
#     operands: 37
# 31. |0〉
#     core type: Operation
#     operator: 54
#     operand: 80
# 32. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 55
#     operands: 39
# 33. 2^{t / 2}
#     core type: Operation
#     operator: 96
#     operands: 40
# 34. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 93
#     body: 42
# 35. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 63, 43
# 36. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 93, 44
# 37. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 100, 45
# 38. (0)
#     core type: ExprTuple
#     sub-expressions: 80
# 39. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 40. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 100, 77
# 41. (k)
#     core type: ExprTuple
#     sub-expressions: 93
# 42. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 48
#     condition: 49
# 43. |k〉_{t + 1}
#     core type: Operation
#     operator: 71
#     operands: 50
# 44. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 73
#     operands: 51
# 45. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 88
#     operands: 52
# 46. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 96
#     operands: 53
# 47. |1〉
#     core type: Operation
#     operator: 54
#     operand: 102
# 48. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 49. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 57
#     operands: 58
# 50. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 93, 76
# 51. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 80, 59
# 52. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 53. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 78, 62
# 54. KET
#     core type: Literal
#     sub-expressions:
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 93, 65
# 59. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 88
#     operands: 66
# 60. (t + 1) / 2
#     core type: Operation
#     operator: 84
#     operands: 67
# 61. -(t / 2)
#     core type: Operation
#     operator: 98
#     operand: 77
# 62. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 86
#     operands: 69
# 63. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 96
#     operands: 70
# 64. |k〉_{t}
#     core type: Operation
#     operator: 71
#     operands: 72
# 65. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 73
#     operands: 74
# 66. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 75, 95
# 67. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 76, 100
# 68. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 77
# 69. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 100, 90, 91, 92, 94
# 70. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 71. NUM_KET
#     core type: Literal
#     sub-expressions:
# 72. (k, t)
#     core type: ExprTuple
#     sub-expressions: 93, 101
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 75. 2 * 2^{t}
#     core type: Operation
#     operator: 86
#     operands: 82
# 76. t + 1
#     core type: Operation
#     operator: 88
#     operands: 83
# 77. t / 2
#     core type: Operation
#     operator: 84
#     operands: 85
# 78. e
#     core type: Literal
#     sub-expressions:
# 79. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 86
#     operands: 87
# 80. 0
#     core type: Literal
#     sub-expressions:
# 81. 2^{t} - 1
#     core type: Operation
#     operator: 88
#     operands: 89
# 82. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 100, 94
# 83. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 84. /
#     core type: Literal
#     sub-expressions:
# 85. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 101, 100
# 86. *
#     core type: Literal
#     sub-expressions:
# 87. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 100, 90, 91, 92, 93
# 88. +
#     core type: Literal
#     sub-expressions:
# 89. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 90. pi
#     core type: Literal
#     sub-expressions:
# 91. i
#     core type: Literal
#     sub-expressions:
# 92. phase
#     core type: Literal
#     sub-expressions:
# 93. k
#     core type: Variable
#     sub-expressions:
# 94. 2^{t}
#     core type: Operation
#     operator: 96
#     operands: 97
# 95. -1
#     core type: Operation
#     operator: 98
#     operand: 102
# 96. Exp
#     core type: Literal
#     sub-expressions:
# 97. (2, t)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 98. -
#     core type: Literal
#     sub-expressions:
# 99. (1)
#     core type: ExprTuple
#     sub-expressions: 102
# 100. 2
#      core type: Literal
#      sub-expressions:
# 101. t
#      core type: Variable
#      sub-expressions:
# 102. 1
#      core type: Literal
#      sub-expressions:
