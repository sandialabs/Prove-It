# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, t
from proveit.core_expr_types import Len
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Len(operands = [frac(one, Exp(two, subtract(frac(Add(t, one), two), frac(t, two)))), TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)), ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order())]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, two)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}}, \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))|, |(1, ..., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |(1, ..., 2)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (1, ..., 2)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. 1 / 2^{((t + 1) / 2) - (t / 2)}
#    core type: Operation
#    operator: 60
#    operands: 9
# 7. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 1, ..., 2
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 68
#    end_index: 77
# 9. (1, 2^{((t + 1) / 2) - (t / 2)})
#    core type: ExprTuple
#    sub-expressions: 68, 13
# 10. otimes
#     core type: Literal
#     sub-expressions:
# 11. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. _a -> _a
#     core type: Lambda
#     parameter: 81
#     body: 81
# 13. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 75
#     operands: 16
# 14. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 38
#     operands: 17
# 15. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 56
# 16. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 77, 20
# 17. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 44, 21
# 18. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 81
#     body: 22
# 19. -t + 1
#     core type: Operation
#     operator: 46
#     operands: 23
# 20. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 46
#     operands: 24
# 21. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 52
#     operands: 25
# 22. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 52
#     operands: 26
# 23. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 68
# 24. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 30, 58
# 26. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. -t
#     core type: Operation
#     operator: 79
#     operand: 65
# 28. (t + 1) / 2
#     core type: Operation
#     operator: 60
#     operands: 34
# 29. -(t / 2)
#     core type: Operation
#     operator: 79
#     operand: 41
# 30. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 75
#     operands: 36
# 31. 1 / sqrt(2)
#     core type: Operation
#     operator: 60
#     operands: 37
# 32. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. (t)
#     core type: ExprTuple
#     sub-expressions: 65
# 34. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 40, 77
# 35. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 41
# 36. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 42
# 37. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 68, 43
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. t + 1
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. t / 2
#     core type: Operation
#     operator: 60
#     operands: 48
# 42. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 69
#     operands: 49
# 43. sqrt(2)
#     core type: Operation
#     operator: 75
#     operands: 50
# 44. |0〉
#     core type: Operation
#     operator: 63
#     operand: 56
# 45. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 68
# 48. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 65, 77
# 49. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 77, 71, 72, 74, 54
# 50. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 77, 55
# 51. (0)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. 2^{t}
#     core type: Operation
#     operator: 75
#     operands: 59
# 55. 1 / 2
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. 0
#     core type: Literal
#     sub-expressions:
# 57. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 75
#     operands: 62
# 58. |1〉
#     core type: Operation
#     operator: 63
#     operand: 68
# 59. (2, t)
#     core type: ExprTuple
#     sub-expressions: 77, 65
# 60. /
#     core type: Literal
#     sub-expressions:
# 61. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 68, 77
# 62. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. KET
#     core type: Literal
#     sub-expressions:
# 64. (1)
#     core type: ExprTuple
#     sub-expressions: 68
# 65. t
#     core type: Variable
#     sub-expressions:
# 66. e
#     core type: Literal
#     sub-expressions:
# 67. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 69
#     operands: 70
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. *
#     core type: Literal
#     sub-expressions:
# 70. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 77, 71, 72, 73, 74
# 71. pi
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Literal
#     sub-expressions:
# 73. 2^{-_a}
#     core type: Operation
#     operator: 75
#     operands: 76
# 74. phase
#     core type: Literal
#     sub-expressions:
# 75. Exp
#     core type: Literal
#     sub-expressions:
# 76. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 77. 2
#     core type: Literal
#     sub-expressions:
# 78. -_a
#     core type: Operation
#     operator: 79
#     operand: 81
# 79. -
#     core type: Literal
#     sub-expressions:
# 80. (_a)
#     core type: ExprTuple
#     sub-expressions: 81
# 81. _a
#     core type: Variable
#     sub-expressions:
