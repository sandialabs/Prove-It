# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import Ket, NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [t]
sub_expr3 = Add(t, one)
sub_expr4 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr5 = Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))))
expr = ExprTuple(And(Equals(SubIndexed(_psi, [one]), ScalarMult(frac(one, sqrt(two)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, Ket(k)), domain = Interval(zero, one)))), Forall(instance_param_or_params = sub_expr2, instance_expr = Equals(SubIndexed(_psi, [sub_expr3]), ScalarMult(frac(one, Exp(two, frac(sub_expr3, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr4, NumKet(k, sub_expr3)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), domain = NaturalPos, condition = sub_expr5)), Forall(instance_param_or_params = sub_expr2, instance_expr = sub_expr5, domain = NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\lvert \psi_{1} \rangle = \left(\frac{1}{\sqrt{2}} \cdot \left(\sum_{k=0}^{1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)\right) \land \left[\forall_{t \in \mathbb{N}^+~|~\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)}~\left(\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right)\right)\right], \forall_{t \in \mathbb{N}^+}~\left(\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))], forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))]
#    core type: Operation
#    operator: 24
#    operands: 3
# 2. forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 9
#    operand: 7
# 3. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))), forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (t -> {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. |psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 37
#    operands: 8
# 6. forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. t -> {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.
#    core type: Lambda
#    parameter: 125
#    body: 11
# 8. (|psi_{1}>, (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. (t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. {|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) if t in NaturalPos.
#     core type: Conditional
#     value: 31
#     condition: 30
# 12. |psi_{1}>
#     core type: Operation
#     operator: 52
#     operand: 126
# 13. (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: Operation
#     operator: 88
#     operands: 15
# 14. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Lambda
#     parameter: 125
#     body: 16
# 15. (1 / sqrt(2), Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. 1 / sqrt(2)
#     core type: Operation
#     operator: 86
#     operands: 21
# 18. Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)
#     core type: Operation
#     operator: 66
#     operand: 27
# 19. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: Operation
#     operator: 37
#     operands: 23
# 20. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 126, 26
# 22. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. sqrt(2)
#     core type: Operation
#     operator: 120
#     operands: 32
# 27. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Lambda
#     parameter: 117
#     body: 33
# 28. |psi_{t + 1}>
#     core type: Operation
#     operator: 52
#     operand: 92
# 29. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: Operation
#     operator: 88
#     operands: 35
# 30. t in NaturalPos
#     core type: Operation
#     operator: 90
#     operands: 36
# 31. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 124, 39
# 33. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 34. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 92
# 35. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 36. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 125, 44
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 39. 1 / 2
#     core type: Operation
#     operator: 86
#     operands: 47
# 40. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 88
#     operands: 48
# 41. k in {0 .. 1}
#     core type: Operation
#     operator: 90
#     operands: 49
# 42. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 86
#     operands: 50
# 43. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 66
#     operand: 58
# 44. NaturalPos
#     core type: Literal
#     sub-expressions:
# 45. |psi_{t}>
#     core type: Operation
#     operator: 52
#     operand: 125
# 46. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 88
#     operands: 54
# 47. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 126, 124
# 48. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 94, 55
# 49. (k, {0 .. 1})
#     core type: ExprTuple
#     sub-expressions: 117, 56
# 50. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 126, 57
# 51. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. psi
#     core type: Literal
#     sub-expressions:
# 53. (t)
#     core type: ExprTuple
#     sub-expressions: 125
# 54. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. |k〉
#     core type: Operation
#     operator: 61
#     operand: 117
# 56. {0 .. 1}
#     core type: Operation
#     operator: 102
#     operands: 62
# 57. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 120
#     operands: 63
# 58. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 117
#     body: 64
# 59. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 86
#     operands: 65
# 60. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 66
#     operand: 72
# 61. KET
#     core type: Literal
#     sub-expressions:
# 62. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 107, 126
# 63. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 124, 68
# 64. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 69
#     condition: 70
# 65. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 126, 71
# 66. Sum
#     core type: Literal
#     sub-expressions:
# 67. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 72
# 68. (t + 1) / 2
#     core type: Operation
#     operator: 86
#     operands: 73
# 69. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 88
#     operands: 74
# 70. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 90
#     operands: 75
# 71. 2^{t / 2}
#     core type: Operation
#     operator: 120
#     operands: 76
# 72. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 117
#     body: 78
# 73. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 92, 124
# 74. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 94, 79
# 75. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 117, 80
# 76. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 124, 81
# 77. (k)
#     core type: ExprTuple
#     sub-expressions: 117
# 78. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 82
#     condition: 83
# 79. |k〉_{t + 1}
#     core type: Operation
#     operator: 100
#     operands: 84
# 80. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 102
#     operands: 85
# 81. t / 2
#     core type: Operation
#     operator: 86
#     operands: 87
# 82. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 88
#     operands: 89
# 83. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 90
#     operands: 91
# 84. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 117, 92
# 85. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 107, 93
# 86. /
#     core type: Literal
#     sub-expressions:
# 87. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 125, 124
# 88. *
#     core type: Literal
#     sub-expressions:
# 89. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 90. in
#     core type: Literal
#     sub-expressions:
# 91. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 117, 96
# 92. t + 1
#     core type: Operation
#     operator: 112
#     operands: 97
# 93. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 112
#     operands: 98
# 94. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 120
#     operands: 99
# 95. |k〉_{t}
#     core type: Operation
#     operator: 100
#     operands: 101
# 96. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 102
#     operands: 103
# 97. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 125, 126
# 98. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 104, 119
# 99. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 105, 106
# 100. NUM_KET
#      core type: Literal
#      sub-expressions:
# 101. (k, t)
#      core type: ExprTuple
#      sub-expressions: 117, 125
# 102. Interval
#      core type: Literal
#      sub-expressions:
# 103. (0, 2^{t} - 1)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 104. 2 * 2^{t}
#      core type: Operation
#      operator: 110
#      operands: 109
# 105. e
#      core type: Literal
#      sub-expressions:
# 106. 2 * pi * i * phase * k
#      core type: Operation
#      operator: 110
#      operands: 111
# 107. 0
#      core type: Literal
#      sub-expressions:
# 108. 2^{t} - 1
#      core type: Operation
#      operator: 112
#      operands: 113
# 109. (2, 2^{t})
#      core type: ExprTuple
#      sub-expressions: 124, 118
# 110. *
#      core type: Literal
#      sub-expressions:
# 111. (2, pi, i, phase, k)
#      core type: ExprTuple
#      sub-expressions: 124, 114, 115, 116, 117
# 112. +
#      core type: Literal
#      sub-expressions:
# 113. (2^{t}, -1)
#      core type: ExprTuple
#      sub-expressions: 118, 119
# 114. pi
#      core type: Literal
#      sub-expressions:
# 115. i
#      core type: Literal
#      sub-expressions:
# 116. phase
#      core type: Literal
#      sub-expressions:
# 117. k
#      core type: Variable
#      sub-expressions:
# 118. 2^{t}
#      core type: Operation
#      operator: 120
#      operands: 121
# 119. -1
#      core type: Operation
#      operator: 122
#      operand: 126
# 120. Exp
#      core type: Literal
#      sub-expressions:
# 121. (2, t)
#      core type: ExprTuple
#      sub-expressions: 124, 125
# 122. -
#      core type: Literal
#      sub-expressions:
# 123. (1)
#      core type: ExprTuple
#      sub-expressions: 126
# 124. 2
#      core type: Literal
#      sub-expressions:
# 125. t
#      core type: Variable
#      sub-expressions:
# 126. 1
#      core type: Literal
#      sub-expressions:
