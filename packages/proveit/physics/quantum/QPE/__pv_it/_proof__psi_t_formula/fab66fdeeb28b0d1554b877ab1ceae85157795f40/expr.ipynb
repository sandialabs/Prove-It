# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Forall, InSet
from proveit.numbers import Complex, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, QubitSpace, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), TensorProd(ket1, NumKet(k, t)))
sub_expr3 = TensorProd(QubitSpace, CartExp(Complex, two_pow_t))
sub_expr4 = Interval(zero, subtract(two_pow_t, one))
expr = ExprTuple(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr2, sub_expr3), domain = sub_expr4), InSet(VecSum(index_or_indices = sub_expr1, summand = sub_expr2, domain = sub_expr4), sub_expr3))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right)\right) \in \left(\mathbb{C}^{2} {\otimes} \mathbb{C}^{2^{t}}\right)\right), \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right)\right)\right) \in \left(\mathbb{C}^{2} {\otimes} \mathbb{C}^{2^{t}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}})), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))) in (Complex^{2} otimes Complex^{2^{t}}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))) in (Complex^{2} otimes Complex^{2^{t}})
#    core type: Operation
#    operator: 22
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {(e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})), Complex^{2} otimes Complex^{2^{t}})
#    core type: ExprTuple
#    sub-expressions: 7, 16
# 6. k -> {(e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 54
#    body: 8
# 7. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. {(e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 11
#    condition: 18
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (k -> {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}})
#     core type: Operation
#     operator: 22
#     operands: 13
# 12. k -> {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 54
#     body: 15
# 13. (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}), Complex^{2} otimes Complex^{2^{t}})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. (k)
#     core type: ExprTuple
#     sub-expressions: 54
# 15. {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. Complex^{2} otimes Complex^{2^{t}}
#     core type: Operation
#     operator: 33
#     operands: 19
# 17. e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (Complex^{2}, Complex^{2^{t}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (e^{2 * pi * i * phase * k}, |1〉 otimes |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 28
# 24. Complex^{2}
#     core type: Operation
#     operator: 30
#     operands: 29
# 25. Complex^{2^{t}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 57
#     operands: 32
# 27. |1〉 otimes |k〉_{t}
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 37, 61
# 30. CartExp
#     core type: Literal
#     sub-expressions:
# 31. (Complex, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 37, 55
# 32. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 33. otimes
#     core type: Literal
#     sub-expressions:
# 34. (|1〉, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 37. Complex
#     core type: Literal
#     sub-expressions:
# 38. e
#     core type: Literal
#     sub-expressions:
# 39. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. |1〉
#     core type: Operation
#     operator: 46
#     operand: 63
# 41. |k〉_{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. 2^{t} - 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 61, 51, 52, 53, 54
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. NUM_KET
#     core type: Literal
#     sub-expressions:
# 48. (k, t)
#     core type: ExprTuple
#     sub-expressions: 54, 62
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. pi
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Literal
#     sub-expressions:
# 53. phase
#     core type: Literal
#     sub-expressions:
# 54. k
#     core type: Variable
#     sub-expressions:
# 55. 2^{t}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. -1
#     core type: Operation
#     operator: 59
#     operand: 63
# 57. Exp
#     core type: Literal
#     sub-expressions:
# 58. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (1)
#     core type: ExprTuple
#     sub-expressions: 63
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t
#     core type: Variable
#     sub-expressions:
# 63. 1
#     core type: Literal
#     sub-expressions:
