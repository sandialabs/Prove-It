# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
expr = Lambda(t, Conditional(Equals(SubIndexed(_psi, [sub_expr2]), ScalarMult(frac(one, Exp(two, frac(sub_expr2, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), And(InSet(t, NaturalPos), Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one))))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# t \mapsto \left\{\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) \textrm{ if } t \in \mathbb{N}^+ ,  \lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Lambda
#    parameter: 92
#    body: 1
# 1. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |psi_{t + 1}>
#    core type: Operation
#    operator: 23
#    operand: 59
# 8. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 55
#    operands: 12
# 9. t in NaturalPos
#    core type: Operation
#    operator: 57
#    operands: 13
# 10. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 59
# 12. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 92, 18
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 53
#     operands: 21
# 17. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 33
#     operand: 27
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. |psi_{t}>
#     core type: Operation
#     operator: 23
#     operand: 92
# 20. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 55
#     operands: 25
# 21. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 93, 26
# 22. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. psi
#     core type: Literal
#     sub-expressions:
# 24. (t)
#     core type: ExprTuple
#     sub-expressions: 92
# 25. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 87
#     operands: 30
# 27. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 84
#     body: 31
# 28. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 53
#     operands: 32
# 29. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 33
#     operand: 39
# 30. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 91, 35
# 31. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 36
#     condition: 37
# 32. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 93, 38
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 35. (t + 1) / 2
#     core type: Operation
#     operator: 53
#     operands: 40
# 36. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 55
#     operands: 41
# 37. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 57
#     operands: 42
# 38. 2^{t / 2}
#     core type: Operation
#     operator: 87
#     operands: 43
# 39. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 84
#     body: 45
# 40. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 59, 91
# 41. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 61, 46
# 42. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 84, 47
# 43. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 91, 48
# 44. (k)
#     core type: ExprTuple
#     sub-expressions: 84
# 45. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 49
#     condition: 50
# 46. |k〉_{t + 1}
#     core type: Operation
#     operator: 67
#     operands: 51
# 47. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 69
#     operands: 52
# 48. t / 2
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 57
#     operands: 58
# 51. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 84, 59
# 52. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 74, 60
# 53. /
#     core type: Literal
#     sub-expressions:
# 54. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 92, 91
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 84, 63
# 59. t + 1
#     core type: Operation
#     operator: 79
#     operands: 64
# 60. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 79
#     operands: 65
# 61. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 87
#     operands: 66
# 62. |k〉_{t}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 69
#     operands: 70
# 64. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 65. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 71, 86
# 66. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 67. NUM_KET
#     core type: Literal
#     sub-expressions:
# 68. (k, t)
#     core type: ExprTuple
#     sub-expressions: 84, 92
# 69. Interval
#     core type: Literal
#     sub-expressions:
# 70. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 71. 2 * 2^{t}
#     core type: Operation
#     operator: 77
#     operands: 76
# 72. e
#     core type: Literal
#     sub-expressions:
# 73. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 77
#     operands: 78
# 74. 0
#     core type: Literal
#     sub-expressions:
# 75. 2^{t} - 1
#     core type: Operation
#     operator: 79
#     operands: 80
# 76. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 91, 85
# 77. *
#     core type: Literal
#     sub-expressions:
# 78. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 91, 81, 82, 83, 84
# 79. +
#     core type: Literal
#     sub-expressions:
# 80. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 81. pi
#     core type: Literal
#     sub-expressions:
# 82. i
#     core type: Literal
#     sub-expressions:
# 83. phase
#     core type: Literal
#     sub-expressions:
# 84. k
#     core type: Variable
#     sub-expressions:
# 85. 2^{t}
#     core type: Operation
#     operator: 87
#     operands: 88
# 86. -1
#     core type: Operation
#     operator: 89
#     operand: 93
# 87. Exp
#     core type: Literal
#     sub-expressions:
# 88. (2, t)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 89. -
#     core type: Literal
#     sub-expressions:
# 90. (1)
#     core type: ExprTuple
#     sub-expressions: 93
# 91. 2
#     core type: Literal
#     sub-expressions:
# 92. t
#     core type: Variable
#     sub-expressions:
# 93. 1
#     core type: Literal
#     sub-expressions:
