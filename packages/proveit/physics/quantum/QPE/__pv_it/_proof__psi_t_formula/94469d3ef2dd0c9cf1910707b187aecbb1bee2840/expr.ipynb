# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, Variable, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr3 = Interval(zero, subtract(two_pow_t, one))
expr = Equals(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, Add(t, one))), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))), VecAdd(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, Function(Variable("_a", latex_format = r"{_{-}a}"), sub_expr1)), domain = sub_expr3), ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, t)), domain = sub_expr3)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) = \left(\left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot {_{-}a}\left(k\right)\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 36
#    operand: 8
# 4. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k)), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#    core type: Lambda
#    parameter: 74
#    body: 11
# 9. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))
#    core type: Operation
#    operator: 36
#    operand: 16
# 10. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 51
#     operands: 13
# 11. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (k -> {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 51
#     operands: 19
# 15. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 53
#     operands: 20
# 16. k -> {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 74
#     body: 21
# 17. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 77
#     operands: 22
# 18. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 55, 25
# 20. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 74, 26
# 21. {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 27
#     condition: 49
# 22. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 63, 28
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. |k〉_{t + 1}
#     core type: Operation
#     operator: 59
#     operands: 31
# 26. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 61
#     operands: 32
# 27. e^{2 * pi * i * phase * k} * _a(k)
#     core type: Operation
#     operator: 51
#     operands: 33
# 28. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 67
#     operands: 34
# 29. |1〉
#     core type: Operation
#     operator: 35
#     operand: 83
# 30. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 36
#     operand: 41
# 31. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 74, 38
# 32. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 65, 39
# 33. (e^{2 * pi * i * phase * k}, _a(k))
#     core type: ExprTuple
#     sub-expressions: 55, 40
# 34. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 81, 71, 72, 73, 75
# 35. KET
#     core type: Literal
#     sub-expressions:
# 36. Sum
#     core type: Literal
#     sub-expressions:
# 37. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. t + 1
#     core type: Operation
#     operator: 69
#     operands: 42
# 39. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 69
#     operands: 43
# 40. _a(k)
#     core type: Operation
#     operator: 44
#     operand: 74
# 41. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 74
#     body: 46
# 42. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 43. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 47, 76
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. (k)
#     core type: ExprTuple
#     sub-expressions: 74
# 46. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 48
#     condition: 49
# 47. 2 * 2^{t}
#     core type: Operation
#     operator: 67
#     operands: 50
# 48. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 81, 75
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 74, 57
# 55. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 77
#     operands: 58
# 56. |k〉_{t}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 59. NUM_KET
#     core type: Literal
#     sub-expressions:
# 60. (k, t)
#     core type: ExprTuple
#     sub-expressions: 74, 82
# 61. Interval
#     core type: Literal
#     sub-expressions:
# 62. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. e
#     core type: Literal
#     sub-expressions:
# 64. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. 0
#     core type: Literal
#     sub-expressions:
# 66. 2^{t} - 1
#     core type: Operation
#     operator: 69
#     operands: 70
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 81, 71, 72, 73, 74
# 69. +
#     core type: Literal
#     sub-expressions:
# 70. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 71. pi
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Literal
#     sub-expressions:
# 73. phase
#     core type: Literal
#     sub-expressions:
# 74. k
#     core type: Variable
#     sub-expressions:
# 75. 2^{t}
#     core type: Operation
#     operator: 77
#     operands: 78
# 76. -1
#     core type: Operation
#     operator: 79
#     operand: 83
# 77. Exp
#     core type: Literal
#     sub-expressions:
# 78. (2, t)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 79. -
#     core type: Literal
#     sub-expressions:
# 80. (1)
#     core type: ExprTuple
#     sub-expressions: 83
# 81. 2
#     core type: Literal
#     sub-expressions:
# 82. t
#     core type: Variable
#     sub-expressions:
# 83. 1
#     core type: Literal
#     sub-expressions:
