# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = frac(one, sqrt(two))
expr = Equals(SubIndexed(_psi, [Add(t, one)]), ScalarMult(sub_expr2, TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, two_pow_t, _phase)), ket1)), ExprRange(sub_expr1, ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order())))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \lvert \psi_{t + 1} \rangle = \left(\frac{1}{\sqrt{2}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |psi_{t + 1}> = ((1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|psi_{t + 1}>, (1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |psi_{t + 1}>
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 40
#    operands: 7
# 5. psi
#    core type: Literal
#    sub-expressions:
# 6. (t + 1)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1 / sqrt(2), (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 8. t + 1
#    core type: Operation
#    operator: 20
#    operands: 10
# 9. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 56
# 11. otimes
#     core type: Literal
#     sub-expressions:
# 12. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. |0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: Operation
#     operator: 31
#     operands: 15
# 14. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 44
# 15. (|0〉, e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 35, 18
# 16. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 69
#     body: 19
# 17. -t + 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. e^{2 * pi * i * 2^{t} * phase} * |1〉
#     core type: Operation
#     operator: 40
#     operands: 22
# 19. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 40
#     operands: 23
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 56
# 22. (e^{2 * pi * i * 2^{t} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 25, 46
# 23. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. -t
#     core type: Operation
#     operator: 67
#     operand: 53
# 25. e^{2 * pi * i * 2^{t} * phase}
#     core type: Operation
#     operator: 63
#     operands: 29
# 26. 1 / sqrt(2)
#     core type: Operation
#     operator: 48
#     operands: 30
# 27. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (t)
#     core type: ExprTuple
#     sub-expressions: 53
# 29. (e, 2 * pi * i * 2^{t} * phase)
#     core type: ExprTuple
#     sub-expressions: 54, 33
# 30. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 56, 34
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. 2 * pi * i * 2^{t} * phase
#     core type: Operation
#     operator: 57
#     operands: 37
# 34. sqrt(2)
#     core type: Operation
#     operator: 63
#     operands: 38
# 35. |0〉
#     core type: Operation
#     operator: 51
#     operand: 44
# 36. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (2, pi, i, 2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 65, 59, 60, 42, 62
# 38. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 65, 43
# 39. (0)
#     core type: ExprTuple
#     sub-expressions: 44
# 40. *
#     core type: Literal
#     sub-expressions:
# 41. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 47
# 43. 1 / 2
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. 0
#     core type: Literal
#     sub-expressions:
# 45. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 63
#     operands: 50
# 46. |1〉
#     core type: Operation
#     operator: 51
#     operand: 56
# 47. (2, t)
#     core type: ExprTuple
#     sub-expressions: 65, 53
# 48. /
#     core type: Literal
#     sub-expressions:
# 49. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 56, 65
# 50. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 51. KET
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 53. t
#     core type: Variable
#     sub-expressions:
# 54. e
#     core type: Literal
#     sub-expressions:
# 55. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 65, 59, 60, 61, 62
# 59. pi
#     core type: Literal
#     sub-expressions:
# 60. i
#     core type: Literal
#     sub-expressions:
# 61. 2^{-_a}
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. phase
#     core type: Literal
#     sub-expressions:
# 63. Exp
#     core type: Literal
#     sub-expressions:
# 64. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. -_a
#     core type: Operation
#     operator: 67
#     operand: 69
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. _a
#     core type: Variable
#     sub-expressions:
