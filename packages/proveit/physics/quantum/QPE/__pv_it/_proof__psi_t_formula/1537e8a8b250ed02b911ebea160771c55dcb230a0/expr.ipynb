# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(t, one)
sub_expr3 = frac(sub_expr2, two)
expr = Equals(ScalarMult(frac(one, Exp(two, sub_expr3)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), ScalarMult(frac(one, Exp(two, subtract(sub_expr3, frac(t, two)))), TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)), ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order())))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) = \left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) = ((1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 78
#    operands: 5
# 4. (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 78
#    operands: 6
# 5. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 88
#    operands: 11
# 8. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 12
#    operand: 18
# 9. 1 / 2^{((t + 1) / 2) - (t / 2)}
#    core type: Operation
#    operator: 88
#    operands: 14
# 10. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 96, 17
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 96, 19
# 15. otimes
#     core type: Literal
#     sub-expressions:
# 16. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 105
#     operands: 22
# 18. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 80
#     body: 24
# 19. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 105
#     operands: 25
# 20. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 60
#     operands: 26
# 21. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 28
#     end_index: 84
# 22. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 107, 45
# 23. (k)
#     core type: ExprTuple
#     sub-expressions: 80
# 24. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 107, 31
# 26. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 68, 32
# 27. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 111
#     body: 33
# 28. -t + 1
#     core type: Operation
#     operator: 72
#     operands: 34
# 29. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 78
#     operands: 35
# 30. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 72
#     operands: 38
# 32. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 78
#     operands: 39
# 33. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 78
#     operands: 40
# 34. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 96
# 35. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 80, 44
# 38. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 39. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 47, 86
# 40. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 41. -t
#     core type: Operation
#     operator: 109
#     operand: 100
# 42. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 105
#     operands: 51
# 43. |k〉_{t + 1}
#     core type: Operation
#     operator: 52
#     operands: 53
# 44. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 54
#     operands: 55
# 45. (t + 1) / 2
#     core type: Operation
#     operator: 88
#     operands: 56
# 46. -(t / 2)
#     core type: Operation
#     operator: 109
#     operand: 65
# 47. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 105
#     operands: 58
# 48. 1 / sqrt(2)
#     core type: Operation
#     operator: 88
#     operands: 59
# 49. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 60
#     operands: 61
# 50. (t)
#     core type: ExprTuple
#     sub-expressions: 100
# 51. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 94, 62
# 52. NUM_KET
#     core type: Literal
#     sub-expressions:
# 53. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 80, 64
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 84, 63
# 56. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 64, 107
# 57. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 65
# 58. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 94, 66
# 59. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 96, 67
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 62. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 98
#     operands: 70
# 63. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 72
#     operands: 71
# 64. t + 1
#     core type: Operation
#     operator: 72
#     operands: 73
# 65. t / 2
#     core type: Operation
#     operator: 88
#     operands: 74
# 66. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 98
#     operands: 75
# 67. sqrt(2)
#     core type: Operation
#     operator: 105
#     operands: 76
# 68. |0〉
#     core type: Operation
#     operator: 91
#     operand: 84
# 69. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 78
#     operands: 79
# 70. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 107, 101, 102, 104, 80
# 71. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 72. +
#     core type: Literal
#     sub-expressions:
# 73. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 100, 96
# 74. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 100, 107
# 75. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 107, 101, 102, 104, 93
# 76. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 107, 83
# 77. (0)
#     core type: ExprTuple
#     sub-expressions: 84
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 80. k
#     core type: Variable
#     sub-expressions:
# 81. 2 * 2^{t}
#     core type: Operation
#     operator: 98
#     operands: 87
# 82. -1
#     core type: Operation
#     operator: 109
#     operand: 96
# 83. 1 / 2
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. 0
#     core type: Literal
#     sub-expressions:
# 85. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 105
#     operands: 90
# 86. |1〉
#     core type: Operation
#     operator: 91
#     operand: 96
# 87. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 107, 93
# 88. /
#     core type: Literal
#     sub-expressions:
# 89. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 96, 107
# 90. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 91. KET
#     core type: Literal
#     sub-expressions:
# 92. (1)
#     core type: ExprTuple
#     sub-expressions: 96
# 93. 2^{t}
#     core type: Operation
#     operator: 105
#     operands: 97
# 94. e
#     core type: Literal
#     sub-expressions:
# 95. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 98
#     operands: 99
# 96. 1
#     core type: Literal
#     sub-expressions:
# 97. (2, t)
#     core type: ExprTuple
#     sub-expressions: 107, 100
# 98. *
#     core type: Literal
#     sub-expressions:
# 99. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 107, 101, 102, 103, 104
# 100. t
#      core type: Variable
#      sub-expressions:
# 101. pi
#      core type: Literal
#      sub-expressions:
# 102. i
#      core type: Literal
#      sub-expressions:
# 103. 2^{-_a}
#      core type: Operation
#      operator: 105
#      operands: 106
# 104. phase
#      core type: Literal
#      sub-expressions:
# 105. Exp
#      core type: Literal
#      sub-expressions:
# 106. (2, -_a)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 107. 2
#      core type: Literal
#      sub-expressions:
# 108. -_a
#      core type: Operation
#      operator: 109
#      operand: 111
# 109. -
#      core type: Literal
#      sub-expressions:
# 110. (_a)
#      core type: ExprTuple
#      sub-expressions: 111
# 111. _a
#      core type: Variable
#      sub-expressions:
