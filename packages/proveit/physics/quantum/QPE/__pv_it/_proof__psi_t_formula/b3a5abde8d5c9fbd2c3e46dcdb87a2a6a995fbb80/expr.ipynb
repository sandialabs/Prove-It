# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(t, one)
sub_expr2 = frac(sub_expr1, two)
expr = ExprTuple(ScalarMult(frac(one, Exp(two, sub_expr2)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr1)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), TensorProd(ScalarMult(frac(one, Exp(two, subtract(sub_expr2, frac(t, two)))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))), Variable("_a", latex_format = r"{_{-}a}")))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right), \left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} {_{-}a}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes _a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 34
#    operands: 3
# 2. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes _a
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. otimes
#    core type: Literal
#    sub-expressions:
# 5. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), _a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 76
#    operands: 10
# 7. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 11
#    operand: 15
# 8. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#    core type: Operation
#    operator: 34
#    operands: 13
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 79, 14
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 80
#     operands: 18
# 15. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 62
#     body: 20
# 16. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 76
#     operands: 21
# 17. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 82, 53
# 19. (k)
#     core type: ExprTuple
#     sub-expressions: 62
# 20. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 79, 26
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 34
#     operands: 29
# 25. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 80
#     operands: 32
# 27. |0〉
#     core type: Operation
#     operator: 49
#     operand: 51
# 28. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 62, 38
# 32. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 82, 39
# 33. (0)
#     core type: ExprTuple
#     sub-expressions: 51
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 80
#     operands: 42
# 37. |k〉_{t + 1}
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 45
#     operands: 46
# 39. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 74
#     operands: 47
# 40. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 80
#     operands: 48
# 41. |1〉
#     core type: Operation
#     operator: 49
#     operand: 79
# 42. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 55, 50
# 43. NUM_KET
#     core type: Literal
#     sub-expressions:
# 44. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 45. Interval
#     core type: Literal
#     sub-expressions:
# 46. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 47. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 48. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 49. KET
#     core type: Literal
#     sub-expressions:
# 50. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 70
#     operands: 57
# 51. 0
#     core type: Literal
#     sub-expressions:
# 52. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 74
#     operands: 58
# 53. (t + 1) / 2
#     core type: Operation
#     operator: 76
#     operands: 59
# 54. -(t / 2)
#     core type: Operation
#     operator: 72
#     operand: 66
# 55. e
#     core type: Literal
#     sub-expressions:
# 56. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 70
#     operands: 61
# 57. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 82, 67, 68, 69, 62
# 58. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 59. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 65, 82
# 60. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 66
# 61. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 82, 67, 68, 69, 78
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. 2 * 2^{t}
#     core type: Operation
#     operator: 70
#     operands: 71
# 64. -1
#     core type: Operation
#     operator: 72
#     operand: 79
# 65. t + 1
#     core type: Operation
#     operator: 74
#     operands: 75
# 66. t / 2
#     core type: Operation
#     operator: 76
#     operands: 77
# 67. pi
#     core type: Literal
#     sub-expressions:
# 68. i
#     core type: Literal
#     sub-expressions:
# 69. phase
#     core type: Literal
#     sub-expressions:
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 82, 78
# 72. -
#     core type: Literal
#     sub-expressions:
# 73. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 74. +
#     core type: Literal
#     sub-expressions:
# 75. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 83, 79
# 76. /
#     core type: Literal
#     sub-expressions:
# 77. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 83, 82
# 78. 2^{t}
#     core type: Operation
#     operator: 80
#     operands: 81
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. Exp
#     core type: Literal
#     sub-expressions:
# 81. (2, t)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 82. 2
#     core type: Literal
#     sub-expressions:
# 83. t
#     core type: Variable
#     sub-expressions:
