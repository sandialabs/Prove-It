# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(t, one)
sub_expr2 = frac(sub_expr1, two)
expr = Equals(ScalarMult(frac(one, Exp(two, sub_expr2)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr1)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), TensorProd(ScalarMult(frac(one, Exp(two, subtract(sub_expr2, frac(t, two)))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))), _psi_t_ket))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) = \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \lvert \psi_{t} \rangle\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) = (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes |psi_{t}>)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes |psi_{t}>)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 38
#    operands: 5
# 4. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes |psi_{t}>
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. otimes
#    core type: Literal
#    sub-expressions:
# 7. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), |psi_{t}>)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 80
#    operands: 12
# 9. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 13
#    operand: 19
# 10. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: Operation
#     operator: 38
#     operands: 15
# 11. |psi_{t}>
#     core type: Operation
#     operator: 16
#     operand: 87
# 12. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 83, 18
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. psi
#     core type: Literal
#     sub-expressions:
# 17. (t)
#     core type: ExprTuple
#     sub-expressions: 87
# 18. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 84
#     operands: 22
# 19. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 66
#     body: 24
# 20. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 80
#     operands: 25
# 21. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 86, 57
# 23. (k)
#     core type: ExprTuple
#     sub-expressions: 66
# 24. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 83, 30
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 38
#     operands: 33
# 29. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 84
#     operands: 36
# 31. |0〉
#     core type: Operation
#     operator: 53
#     operand: 55
# 32. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 66, 42
# 36. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 86, 43
# 37. (0)
#     core type: ExprTuple
#     sub-expressions: 55
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 84
#     operands: 46
# 41. |k〉_{t + 1}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 78
#     operands: 51
# 44. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 84
#     operands: 52
# 45. |1〉
#     core type: Operation
#     operator: 53
#     operand: 83
# 46. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 59, 54
# 47. NUM_KET
#     core type: Literal
#     sub-expressions:
# 48. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 66, 69
# 49. Interval
#     core type: Literal
#     sub-expressions:
# 50. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 52. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 53. KET
#     core type: Literal
#     sub-expressions:
# 54. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 74
#     operands: 61
# 55. 0
#     core type: Literal
#     sub-expressions:
# 56. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 78
#     operands: 62
# 57. (t + 1) / 2
#     core type: Operation
#     operator: 80
#     operands: 63
# 58. -(t / 2)
#     core type: Operation
#     operator: 76
#     operand: 70
# 59. e
#     core type: Literal
#     sub-expressions:
# 60. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 74
#     operands: 65
# 61. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 86, 71, 72, 73, 66
# 62. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 63. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 69, 86
# 64. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 70
# 65. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 71, 72, 73, 82
# 66. k
#     core type: Variable
#     sub-expressions:
# 67. 2 * 2^{t}
#     core type: Operation
#     operator: 74
#     operands: 75
# 68. -1
#     core type: Operation
#     operator: 76
#     operand: 83
# 69. t + 1
#     core type: Operation
#     operator: 78
#     operands: 79
# 70. t / 2
#     core type: Operation
#     operator: 80
#     operands: 81
# 71. pi
#     core type: Literal
#     sub-expressions:
# 72. i
#     core type: Literal
#     sub-expressions:
# 73. phase
#     core type: Literal
#     sub-expressions:
# 74. *
#     core type: Literal
#     sub-expressions:
# 75. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 82
# 76. -
#     core type: Literal
#     sub-expressions:
# 77. (1)
#     core type: ExprTuple
#     sub-expressions: 83
# 78. +
#     core type: Literal
#     sub-expressions:
# 79. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 87, 83
# 80. /
#     core type: Literal
#     sub-expressions:
# 81. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 87, 86
# 82. 2^{t}
#     core type: Operation
#     operator: 84
#     operands: 85
# 83. 1
#     core type: Literal
#     sub-expressions:
# 84. Exp
#     core type: Literal
#     sub-expressions:
# 85. (2, t)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 86. 2
#     core type: Literal
#     sub-expressions:
# 87. t
#     core type: Variable
#     sub-expressions:
