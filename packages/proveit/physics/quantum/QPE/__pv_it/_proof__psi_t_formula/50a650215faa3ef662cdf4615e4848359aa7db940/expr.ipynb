# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))
expr = ExprTuple(frac(one, Exp(two, frac(Add(t, one), two))), VecAdd(TensorProd(ket0, sub_expr1), ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, sub_expr1))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}}, \left(\lvert 0 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 / 2^{(t + 1) / 2}, (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1, 2^{(t + 1) / 2})
#    core type: ExprTuple
#    sub-expressions: 68, 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 62
#    operands: 9
# 7. |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 20
#    operands: 10
# 8. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 36
#    operands: 11
# 9. (2, (t + 1) / 2)
#    core type: ExprTuple
#    sub-expressions: 66, 12
# 10. (|0〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 13, 25
# 11. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. (t + 1) / 2
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. |0〉
#     core type: Operation
#     operator: 28
#     operand: 50
# 14. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 62
#     operands: 19
# 15. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 22, 66
# 18. (0)
#     core type: ExprTuple
#     sub-expressions: 50
# 19. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48, 23
# 20. otimes
#     core type: Literal
#     sub-expressions:
# 21. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. t + 1
#     core type: Operation
#     operator: 54
#     operands: 26
# 23. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 27
# 24. |1〉
#     core type: Operation
#     operator: 28
#     operand: 68
# 25. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 29
#     operand: 31
# 26. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 27. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 56, 57, 58, 60
# 28. KET
#     core type: Literal
#     sub-expressions:
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 31. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 59
#     body: 33
# 32. (k)
#     core type: ExprTuple
#     sub-expressions: 59
# 33. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 34
#     condition: 35
# 34. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. *
#     core type: Literal
#     sub-expressions:
# 37. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 42
# 40. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 62
#     operands: 43
# 41. |k〉_{t}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 44. NUM_KET
#     core type: Literal
#     sub-expressions:
# 45. (k, t)
#     core type: ExprTuple
#     sub-expressions: 59, 67
# 46. Interval
#     core type: Literal
#     sub-expressions:
# 47. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. 0
#     core type: Literal
#     sub-expressions:
# 51. 2^{t} - 1
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 66, 56, 57, 58, 59
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 56. pi
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Literal
#     sub-expressions:
# 58. phase
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. 2^{t}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. -1
#     core type: Operation
#     operator: 64
#     operand: 68
# 62. Exp
#     core type: Literal
#     sub-expressions:
# 63. (2, t)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (1)
#     core type: ExprTuple
#     sub-expressions: 68
# 66. 2
#     core type: Literal
#     sub-expressions:
# 67. t
#     core type: Variable
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
