# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Add(k, two_pow_t)
expr = Equals(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr2)), domain = Interval(two_pow_t, subtract(Mult(two, two_pow_t), one))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, sub_expr3)), NumKet(sub_expr3, sub_expr2)), domain = Interval(zero, subtract(two_pow_t, one))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=2^{t}}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) = \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot \left(k + 2^{t}\right)} \cdot \lvert k + 2^{t} \rangle_{t + 1}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=2^{t}}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k=2^{t}}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k=2^{t}}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {2^{t} .. (2 * 2^{t}) - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {2^{t} .. (2 * 2^{t}) - 1}.
#    core type: Lambda
#    parameter: 61
#    body: 10
# 9. k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 61
#    body: 12
# 10. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {2^{t} .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 61
# 12. {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 19
#     operands: 17
# 14. k in {2^{t} .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 21
#     operands: 18
# 15. e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. (k, {2^{t} .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 61, 25
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (e^{2 * pi * i * phase * (k + 2^{t})}, |k + 2^{t}〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 61, 28
# 23. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 64
#     operands: 29
# 24. |k〉_{t + 1}
#     core type: Operation
#     operator: 33
#     operands: 30
# 25. {2^{t} .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 35
#     operands: 31
# 26. e^{2 * pi * i * phase * (k + 2^{t})}
#     core type: Operation
#     operator: 64
#     operands: 32
# 27. |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 30. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 61, 41
# 31. (2^{t}, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 62, 38
# 32. (e, 2 * pi * i * phase * (k + 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 33. NUM_KET
#     core type: Literal
#     sub-expressions:
# 34. (k + 2^{t}, t + 1)
#     core type: ExprTuple
#     sub-expressions: 53, 41
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 37. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 55
#     operands: 44
# 38. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 57
#     operands: 45
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. 2 * pi * i * phase * (k + 2^{t})
#     core type: Operation
#     operator: 55
#     operands: 46
# 41. t + 1
#     core type: Operation
#     operator: 57
#     operands: 47
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. 2^{t} - 1
#     core type: Operation
#     operator: 57
#     operands: 48
# 44. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 66, 50, 51, 52, 61
# 45. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 49, 54
# 46. (2, pi, i, phase, k + 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 50, 51, 52, 53
# 47. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 67, 63
# 48. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 62, 54
# 49. 2 * 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. pi
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Literal
#     sub-expressions:
# 52. phase
#     core type: Literal
#     sub-expressions:
# 53. k + 2^{t}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. -1
#     core type: Operation
#     operator: 59
#     operand: 63
# 55. *
#     core type: Literal
#     sub-expressions:
# 56. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 62
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (k, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (1)
#     core type: ExprTuple
#     sub-expressions: 63
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. 2^{t}
#     core type: Operation
#     operator: 64
#     operands: 65
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. Exp
#     core type: Literal
#     sub-expressions:
# 65. (2, t)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. 2
#     core type: Literal
#     sub-expressions:
# 67. t
#     core type: Variable
#     sub-expressions:
