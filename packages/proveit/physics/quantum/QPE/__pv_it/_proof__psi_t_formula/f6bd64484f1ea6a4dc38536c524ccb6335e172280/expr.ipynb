# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(t, one)
sub_expr3 = frac(sub_expr2, two)
expr = ExprTuple(ScalarMult(frac(one, Exp(two, sub_expr3)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), ScalarMult(frac(one, Exp(two, subtract(sub_expr3, frac(t, two)))), TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)), ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order())))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right), \frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 76
#    operands: 3
# 2. (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 76
#    operands: 4
# 3. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 86
#    operands: 9
# 6. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 10
#    operand: 16
# 7. 1 / 2^{((t + 1) / 2) - (t / 2)}
#    core type: Operation
#    operator: 86
#    operands: 12
# 8. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (1, 2^{(t + 1) / 2})
#    core type: ExprTuple
#    sub-expressions: 94, 15
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 94, 17
# 13. otimes
#     core type: Literal
#     sub-expressions:
# 14. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 103
#     operands: 20
# 16. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 78
#     body: 22
# 17. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 103
#     operands: 23
# 18. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 58
#     operands: 24
# 19. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 82
# 20. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 105, 43
# 21. (k)
#     core type: ExprTuple
#     sub-expressions: 78
# 22. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 23. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 105, 29
# 24. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 66, 30
# 25. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 109
#     body: 31
# 26. -t + 1
#     core type: Operation
#     operator: 70
#     operands: 32
# 27. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 76
#     operands: 33
# 28. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 70
#     operands: 36
# 30. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 76
#     operands: 37
# 31. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 76
#     operands: 38
# 32. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 39, 94
# 33. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 78, 42
# 36. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 37. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 45, 84
# 38. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 39. -t
#     core type: Operation
#     operator: 107
#     operand: 98
# 40. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 103
#     operands: 49
# 41. |k〉_{t + 1}
#     core type: Operation
#     operator: 50
#     operands: 51
# 42. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. (t + 1) / 2
#     core type: Operation
#     operator: 86
#     operands: 54
# 44. -(t / 2)
#     core type: Operation
#     operator: 107
#     operand: 63
# 45. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 103
#     operands: 56
# 46. 1 / sqrt(2)
#     core type: Operation
#     operator: 86
#     operands: 57
# 47. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 58
#     operands: 59
# 48. (t)
#     core type: ExprTuple
#     sub-expressions: 98
# 49. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 92, 60
# 50. NUM_KET
#     core type: Literal
#     sub-expressions:
# 51. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 78, 62
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 82, 61
# 54. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 105
# 55. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 63
# 56. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 92, 64
# 57. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 94, 65
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 60. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 96
#     operands: 68
# 61. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 70
#     operands: 69
# 62. t + 1
#     core type: Operation
#     operator: 70
#     operands: 71
# 63. t / 2
#     core type: Operation
#     operator: 86
#     operands: 72
# 64. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 96
#     operands: 73
# 65. sqrt(2)
#     core type: Operation
#     operator: 103
#     operands: 74
# 66. |0〉
#     core type: Operation
#     operator: 89
#     operand: 82
# 67. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 76
#     operands: 77
# 68. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 105, 99, 100, 102, 78
# 69. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 70. +
#     core type: Literal
#     sub-expressions:
# 71. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 98, 94
# 72. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 98, 105
# 73. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 105, 99, 100, 102, 91
# 74. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 105, 81
# 75. (0)
#     core type: ExprTuple
#     sub-expressions: 82
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 78. k
#     core type: Variable
#     sub-expressions:
# 79. 2 * 2^{t}
#     core type: Operation
#     operator: 96
#     operands: 85
# 80. -1
#     core type: Operation
#     operator: 107
#     operand: 94
# 81. 1 / 2
#     core type: Operation
#     operator: 86
#     operands: 87
# 82. 0
#     core type: Literal
#     sub-expressions:
# 83. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 103
#     operands: 88
# 84. |1〉
#     core type: Operation
#     operator: 89
#     operand: 94
# 85. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 105, 91
# 86. /
#     core type: Literal
#     sub-expressions:
# 87. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 94, 105
# 88. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. KET
#     core type: Literal
#     sub-expressions:
# 90. (1)
#     core type: ExprTuple
#     sub-expressions: 94
# 91. 2^{t}
#     core type: Operation
#     operator: 103
#     operands: 95
# 92. e
#     core type: Literal
#     sub-expressions:
# 93. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 96
#     operands: 97
# 94. 1
#     core type: Literal
#     sub-expressions:
# 95. (2, t)
#     core type: ExprTuple
#     sub-expressions: 105, 98
# 96. *
#     core type: Literal
#     sub-expressions:
# 97. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 105, 99, 100, 101, 102
# 98. t
#     core type: Variable
#     sub-expressions:
# 99. pi
#     core type: Literal
#     sub-expressions:
# 100. i
#      core type: Literal
#      sub-expressions:
# 101. 2^{-_a}
#      core type: Operation
#      operator: 103
#      operands: 104
# 102. phase
#      core type: Literal
#      sub-expressions:
# 103. Exp
#      core type: Literal
#      sub-expressions:
# 104. (2, -_a)
#      core type: ExprTuple
#      sub-expressions: 105, 106
# 105. 2
#      core type: Literal
#      sub-expressions:
# 106. -_a
#      core type: Operation
#      operator: 107
#      operand: 109
# 107. -
#      core type: Literal
#      sub-expressions:
# 108. (_a)
#      core type: ExprTuple
#      sub-expressions: 109
# 109. _a
#      core type: Variable
#      sub-expressions:
