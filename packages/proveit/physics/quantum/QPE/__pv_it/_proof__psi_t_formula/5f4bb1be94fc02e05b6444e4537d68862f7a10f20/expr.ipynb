# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, t
from proveit.linear_algebra import ScalarMult, TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(k, two_pow_t)
sub_expr2 = InSet(k, Interval(zero, subtract(two_pow_t, one)))
expr = Equals(Lambda(k, Conditional(ScalarMult(Exp(e, Mult(two, pi, i, _phase, sub_expr1)), NumKet(sub_expr1, Add(t, one))), sub_expr2)), Lambda(k, Conditional(ScalarMult(Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Mult(two, pi, i, _phase, two_pow_t))), TensorProd(ket1, NumKet(k, t))), sub_expr2))).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot \left(k + 2^{t}\right)} \cdot \lvert k + 2^{t} \rangle_{t + 1} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}}\right) \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}., k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 56
#    body: 5
# 4. k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 56
#    body: 7
# 5. {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 8
#    condition: 10
# 6. (k)
#    core type: ExprTuple
#    sub-expressions: 56
# 7. {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. (e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (e^{2 * pi * i * phase * (k + 2^{t})}, |k + 2^{t}〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 56, 20
# 16. e^{2 * pi * i * phase * (k + 2^{t})}
#     core type: Operation
#     operator: 62
#     operands: 21
# 17. |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 41
#     operands: 22
# 18. e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 52
#     operands: 23
# 19. |1〉 otimes |k〉_{t}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. (e, 2 * pi * i * phase * (k + 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 46, 28
# 22. (k + 2^{t}, t + 1)
#     core type: ExprTuple
#     sub-expressions: 44, 29
# 23. (e^{2 * pi * i * phase * k}, e^{2 * pi * i * phase * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 24. otimes
#     core type: Literal
#     sub-expressions:
# 25. (|1〉, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. 2 * pi * i * phase * (k + 2^{t})
#     core type: Operation
#     operator: 52
#     operands: 36
# 29. t + 1
#     core type: Operation
#     operator: 49
#     operands: 37
# 30. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 62
#     operands: 38
# 31. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 62
#     operands: 39
# 32. |1〉
#     core type: Operation
#     operator: 40
#     operand: 61
# 33. |k〉_{t}
#     core type: Operation
#     operator: 41
#     operands: 42
# 34. 0
#     core type: Literal
#     sub-expressions:
# 35. 2^{t} - 1
#     core type: Operation
#     operator: 49
#     operands: 43
# 36. (2, pi, i, phase, k + 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64, 57, 58, 59, 44
# 37. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 61
# 38. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 46, 45
# 39. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 40. KET
#     core type: Literal
#     sub-expressions:
# 41. NUM_KET
#     core type: Literal
#     sub-expressions:
# 42. (k, t)
#     core type: ExprTuple
#     sub-expressions: 56, 65
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 48
# 44. k + 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 52
#     operands: 51
# 46. e
#     core type: Literal
#     sub-expressions:
# 47. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. -1
#     core type: Operation
#     operator: 54
#     operand: 61
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (k, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 56, 60
# 51. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 64, 57, 58, 59, 56
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64, 57, 58, 59, 60
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (1)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. k
#     core type: Variable
#     sub-expressions:
# 57. pi
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Literal
#     sub-expressions:
# 59. phase
#     core type: Literal
#     sub-expressions:
# 60. 2^{t}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. Exp
#     core type: Literal
#     sub-expressions:
# 63. (2, t)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. t
#     core type: Variable
#     sub-expressions:
