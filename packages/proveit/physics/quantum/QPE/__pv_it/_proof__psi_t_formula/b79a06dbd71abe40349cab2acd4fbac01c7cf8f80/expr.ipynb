# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(t, two)
sub_expr2 = frac(one, Exp(two, subtract(frac(Add(t, one), two), sub_expr1)))
sub_expr3 = VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))
sub_expr4 = ScalarMult(frac(one, Exp(two, sub_expr1)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one))))
expr = ExprTuple(TensorProd(ScalarMult(sub_expr2, sub_expr3), sub_expr4), ScalarMult(sub_expr2, TensorProd(sub_expr3, sub_expr4)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right), \frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right) {\otimes} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 47
#    operands: 4
# 3. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 5, 12
# 4. (1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 10, 6
# 5. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#    core type: Operation
#    operator: 47
#    operands: 7
# 6. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. otimes
#    core type: Literal
#    sub-expressions:
# 9. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉), (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 57
#     operands: 13
# 11. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 47
#     operands: 16
# 13. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 84, 17
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 78
#     operands: 22
# 18. |0〉
#     core type: Operation
#     operator: 35
#     operand: 66
# 19. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 47
#     operands: 24
# 20. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 57
#     operands: 25
# 21. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 26
#     operand: 32
# 22. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 82, 28
# 23. (0)
#     core type: ExprTuple
#     sub-expressions: 66
# 24. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 84, 31
# 26. Sum
#     core type: Literal
#     sub-expressions:
# 27. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 70
#     operands: 33
# 29. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 78
#     operands: 34
# 30. |1〉
#     core type: Operation
#     operator: 35
#     operand: 84
# 31. 2^{t / 2}
#     core type: Operation
#     operator: 78
#     operands: 36
# 32. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 75
#     body: 38
# 33. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64, 41
# 35. KET
#     core type: Literal
#     sub-expressions:
# 36. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 82, 52
# 37. (k)
#     core type: ExprTuple
#     sub-expressions: 75
# 38. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 39. (t + 1) / 2
#     core type: Operation
#     operator: 57
#     operands: 44
# 40. -(t / 2)
#     core type: Operation
#     operator: 80
#     operand: 52
# 41. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 68
#     operands: 46
# 42. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 51, 82
# 45. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 52
# 46. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 82, 72, 73, 74, 76
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 75, 55
# 51. t + 1
#     core type: Operation
#     operator: 70
#     operands: 56
# 52. t / 2
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 78
#     operands: 59
# 54. |k〉_{t}
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 62
#     operands: 63
# 56. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 57. /
#     core type: Literal
#     sub-expressions:
# 58. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 83, 82
# 59. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 60. NUM_KET
#     core type: Literal
#     sub-expressions:
# 61. (k, t)
#     core type: ExprTuple
#     sub-expressions: 75, 83
# 62. Interval
#     core type: Literal
#     sub-expressions:
# 63. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. e
#     core type: Literal
#     sub-expressions:
# 65. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 68
#     operands: 69
# 66. 0
#     core type: Literal
#     sub-expressions:
# 67. 2^{t} - 1
#     core type: Operation
#     operator: 70
#     operands: 71
# 68. *
#     core type: Literal
#     sub-expressions:
# 69. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 82, 72, 73, 74, 75
# 70. +
#     core type: Literal
#     sub-expressions:
# 71. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 72. pi
#     core type: Literal
#     sub-expressions:
# 73. i
#     core type: Literal
#     sub-expressions:
# 74. phase
#     core type: Literal
#     sub-expressions:
# 75. k
#     core type: Variable
#     sub-expressions:
# 76. 2^{t}
#     core type: Operation
#     operator: 78
#     operands: 79
# 77. -1
#     core type: Operation
#     operator: 80
#     operand: 84
# 78. Exp
#     core type: Literal
#     sub-expressions:
# 79. (2, t)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 80. -
#     core type: Literal
#     sub-expressions:
# 81. (1)
#     core type: ExprTuple
#     sub-expressions: 84
# 82. 2
#     core type: Literal
#     sub-expressions:
# 83. t
#     core type: Variable
#     sub-expressions:
# 84. 1
#     core type: Literal
#     sub-expressions:
